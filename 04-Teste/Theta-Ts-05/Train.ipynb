# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 5
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
os.makedirs("./scalers", exist_ok=True)

NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)
    
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 1)
# Dimensão da entrada: (1266, 5, 4)
# Dimensão da saida: (1266, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 1)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.architecture = architecture  
        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):
        x = inputs
        for rnn in self.rnn_layers:
            x = rnn(x)
        return self.out_layer(x)

# %%
def PINN_to_RNN(pinn_model):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    # recria arquitetura
    for layer in pinn_model.rnn_layers:
        model.add(
            tf.keras.layers.SimpleRNN(
                units=layer.units,
                activation='tanh',
                return_sequences=layer.return_sequences
            )
        )

    # camada final
    model.add(
        tf.keras.layers.Dense(
            pinn_model.out_layer.units,
            activation='linear'
        )
    )

    model.build((None, TIME_STEPS, INPUT_SIZE))

    model.set_weights(pinn_model.get_weights())

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_denorm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": metrics[name]["R2_Train_1"],
            f"MSE_Train_1_{name}": metrics[name]["MSE_Train_1"],
            f"R2_Train_2_{name}": metrics[name]["R2_Train_2"],
            f"MSE_Train_2_{name}": metrics[name]["MSE_Train_2"],
            f"R2_Val_{name}": metrics[name]["R2_Val"],
            f"MSE_Val_{name}": metrics[name]["MSE_Val"],
            f"R2_Test_1_{name}": metrics[name]["R2_Test_1"],
            f"MSE_Test_1_{name}": metrics[name]["MSE_Test_1"],
            f"R2_Test_2_{name}": metrics[name]["R2_Test_2"],
            f"MSE_Test_2_{name}": metrics[name]["MSE_Test_2"],
            f"R2_Test_3_{name}": metrics[name]["R2_Test_3"],
            f"MSE_Test_3_{name}": metrics[name]["MSE_Test_3"],
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
import os

def ExportModel(pinn_model, model_name):

    os.makedirs("weights", exist_ok=True)

    rnn_model = PINN_to_RNN(pinn_model)

    weights_path = f"weights/{model_name}.weights.h5"

    rnn_model.save_weights(weights_path)

    print(f"Modelo salvo em:\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        pinn_model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )
        pinn_model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(pinn_model.trainable_variables)

        TrainPINN(
            pinn_model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(pinn_model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(pinn_model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.985303 | Val Loss 0.812547
# Epoch 100 | Train Loss 0.765968 | Val Loss 0.577301
# Epoch 200 | Train Loss 0.719265 | Val Loss 0.573159
# Early stopping at epoch 259
# Modelo salvo em:
# weights/model_arch16_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7323, MSE = 6.1039e-02
# Theta | Train_2 -> R² = 0.3744, MSE = 1.4233e-01
# Theta | Test_1 -> R² = 0.4397, MSE = 1.2861e-01
# Theta | Test_2 -> R² = 0.8378, MSE = 3.8332e-02
# Theta | Test_3 -> R² = 0.6411, MSE = 1.1788e-01
# Theta | Val -> R² = -2.4409, MSE = 1.1247e+00
# Theta | LSG_1 -> R² = 0.7572, MSE = 1.0054e-01
# Theta | LSG_2 -> R² = -0.5701, MSE = 5.4387e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 0.983092 | Val Loss 0.808725
# Epoch 100 | Train Loss 0.780153 | Val Loss 0.566742
# Epoch 200 | Train Loss 0.716659 | Val Loss 0.582789
# Early stopping at epoch 271
# Modelo salvo em:
# weights/model_arch16_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7128, MSE = 6.5505e-02
# Theta | Train_2 -> R² = 0.3340, MSE = 1.5153e-01
# Theta | Test_1 -> R² = 0.4680, MSE = 1.2213e-01
# Theta | Test_2 -> R² = 0.8176, MSE = 4.3111e-02
# Theta | Test_3 -> R² = 0.6398, MSE = 1.1831e-01
# Theta | Val -> R² = -2.5834, MSE = 1.1712e+00
# Theta | LSG_1 -> R² = 0.7577, MSE = 1.0032e-01
# Theta | LSG_2 -> R² = -0.5347, MSE = 5.3160e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.998596 | Val Loss 0.828016
# Epoch 100 | Train Loss 0.817095 | Val Loss 0.551464
# Epoch 200 | Train Loss 0.719814 | Val Loss 0.563559
# Early stopping at epoch 298
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7566, MSE = 5.5503e-02
# Theta | Train_2 -> R² = 0.4339, MSE = 1.2880e-01
# Theta | Test_1 -> R² = 0.5885, MSE = 9.4454e-02
# Theta | Test_2 -> R² = 0.8403, MSE = 3.7739e-02
# Theta | Test_3 -> R² = 0.6264, MSE = 1.2268e-01
# Theta | Val -> R² = -2.8095, MSE = 1.2451e+00
# Theta | LSG_1 -> R² = 0.7210, MSE = 1.1553e-01
# Theta | LSG_2 -> R² = -0.8741, MSE = 6.4914e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 0.995206 | Val Loss 0.847895
# Epoch 100 | Train Loss 0.790366 | Val Loss 0.563090
# Epoch 200 | Train Loss 0.713710 | Val Loss 0.593430
# Early stopping at epoch 291
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7774, MSE = 5.0768e-02
# Theta | Train_2 -> R² = 0.4604, MSE = 1.2278e-01
# Theta | Test_1 -> R² = 0.5260, MSE = 1.0881e-01
# Theta | Test_2 -> R² = 0.8600, MSE = 3.3078e-02
# Theta | Test_3 -> R² = 0.6590, MSE = 1.1201e-01
# Theta | Val -> R² = -2.7322, MSE = 1.2199e+00
# Theta | LSG_1 -> R² = 0.7073, MSE = 1.2122e-01
# Theta | LSG_2 -> R² = -1.1076, MSE = 7.3005e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.988389 | Val Loss 0.843966
# Epoch 100 | Train Loss 0.786689 | Val Loss 0.563426
# Epoch 200 | Train Loss 0.728007 | Val Loss 0.580474
# Early stopping at epoch 269
# Modelo salvo em:
# weights/model_arch16_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.6918, MSE = 7.0289e-02
# Theta | Train_2 -> R² = 0.3820, MSE = 1.4060e-01
# Theta | Test_1 -> R² = 0.3336, MSE = 1.5298e-01
# Theta | Test_2 -> R² = 0.8558, MSE = 3.4084e-02
# Theta | Test_3 -> R² = 0.6086, MSE = 1.2854e-01
# Theta | Val -> R² = -3.3331, MSE = 1.4163e+00
# Theta | LSG_1 -> R² = 0.6855, MSE = 1.3024e-01
# Theta | LSG_2 -> R² = -1.0944, MSE = 7.2546e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.987653 | Val Loss 0.797350
# Epoch 100 | Train Loss 0.817734 | Val Loss 0.557188
# Epoch 200 | Train Loss 0.733245 | Val Loss 0.552154
# Epoch 300 | Train Loss 0.708823 | Val Loss 0.544711
# Epoch 400 | Train Loss 0.688338 | Val Loss 0.575687
# Early stopping at epoch 455
# Modelo salvo em:
# weights/model_arch16_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.8804, MSE = 2.7286e-02
# Theta | Train_2 -> R² = 0.8266, MSE = 3.9444e-02
# Theta | Test_1 -> R² = 0.9031, MSE = 2.2245e-02
# Theta | Test_2 -> R² = 0.8792, MSE = 2.8546e-02
# Theta | Test_3 -> R² = 0.1521, MSE = 2.7847e-01
# Theta | Val -> R² = -2.6541, MSE = 1.1944e+00
# Theta | LSG_1 -> R² = 0.6009, MSE = 1.6528e-01
# Theta | LSG_2 -> R² = -1.9953, MSE = 1.0375e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 0.986284 | Val Loss 0.807775
# Epoch 100 | Train Loss 0.792239 | Val Loss 0.560366
# Epoch 200 | Train Loss 0.718127 | Val Loss 0.563517
# Early stopping at epoch 294
# Modelo salvo em:
# weights/model_arch16_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7312, MSE = 6.1307e-02
# Theta | Train_2 -> R² = 0.3711, MSE = 1.4308e-01
# Theta | Test_1 -> R² = 0.4710, MSE = 1.2144e-01
# Theta | Test_2 -> R² = 0.8443, MSE = 3.6797e-02
# Theta | Test_3 -> R² = 0.6398, MSE = 1.1829e-01
# Theta | Val -> R² = -1.9538, MSE = 9.6544e-01
# Theta | LSG_1 -> R² = 0.7692, MSE = 9.5580e-02
# Theta | LSG_2 -> R² = -0.4451, MSE = 5.0057e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.976322 | Val Loss 0.821186
# Epoch 100 | Train Loss 0.759450 | Val Loss 0.575915
# Epoch 200 | Train Loss 0.700470 | Val Loss 0.578726
# Early stopping at epoch 263
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7196, MSE = 6.3945e-02
# Theta | Train_2 -> R² = 0.3771, MSE = 1.4171e-01
# Theta | Test_1 -> R² = 0.4247, MSE = 1.3206e-01
# Theta | Test_2 -> R² = 0.8363, MSE = 3.8688e-02
# Theta | Test_3 -> R² = 0.5986, MSE = 1.3183e-01
# Theta | Val -> R² = -2.7819, MSE = 1.2361e+00
# Theta | LSG_1 -> R² = 0.7513, MSE = 1.0299e-01
# Theta | LSG_2 -> R² = -0.6539, MSE = 5.7290e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 1.001526 | Val Loss 0.868043
# Epoch 100 | Train Loss 0.807194 | Val Loss 0.560617
# Epoch 200 | Train Loss 0.733365 | Val Loss 0.572720
# Epoch 300 | Train Loss 0.705795 | Val Loss 0.568320
# Early stopping at epoch 310
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7646, MSE = 5.3675e-02
# Theta | Train_2 -> R² = 0.4926, MSE = 1.1545e-01
# Theta | Test_1 -> R² = 0.6905, MSE = 7.1041e-02
# Theta | Test_2 -> R² = 0.8331, MSE = 3.9445e-02
# Theta | Test_3 -> R² = 0.6167, MSE = 1.2589e-01
# Theta | Val -> R² = 0.3796, MSE = 2.0277e-01
# Theta | LSG_1 -> R² = 0.4078, MSE = 2.4526e-01
# Theta | LSG_2 -> R² = 0.6030, MSE = 1.3751e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.996375 | Val Loss 0.852811
# Epoch 100 | Train Loss 0.831132 | Val Loss 0.552300
# Epoch 200 | Train Loss 0.742308 | Val Loss 0.556674
# Epoch 300 | Train Loss 0.716140 | Val Loss 0.556918
# Early stopping at epoch 314
# Modelo salvo em:
# weights/model_arch16_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7721, MSE = 5.1974e-02
# Theta | Train_2 -> R² = 0.5227, MSE = 1.0859e-01
# Theta | Test_1 -> R² = 0.6731, MSE = 7.5051e-02
# Theta | Test_2 -> R² = 0.8526, MSE = 3.4829e-02
# Theta | Test_3 -> R² = 0.6551, MSE = 1.1327e-01
# Theta | Val -> R² = -0.5855, MSE = 5.1824e-01
# Theta | LSG_1 -> R² = 0.7391, MSE = 1.0803e-01
# Theta | LSG_2 -> R² = 0.0091, MSE = 3.4323e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 0.984373 | Val Loss 0.843000
# Epoch 100 | Train Loss 0.750854 | Val Loss 0.567954
# Epoch 200 | Train Loss 0.741632 | Val Loss 0.585985
# Early stopping at epoch 249
# Modelo salvo em:
# weights/model_arch16_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.6882, MSE = 7.1117e-02
# Theta | Train_2 -> R² = 0.4397, MSE = 1.2747e-01
# Theta | Test_1 -> R² = 0.2327, MSE = 1.7613e-01
# Theta | Test_2 -> R² = 0.8722, MSE = 3.0195e-02
# Theta | Test_3 -> R² = 0.4298, MSE = 1.8728e-01
# Theta | Val -> R² = -6.3203, MSE = 2.3927e+00
# Theta | LSG_1 -> R² = 0.3722, MSE = 2.5998e-01
# Theta | LSG_2 -> R² = -2.6560, MSE = 1.2664e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 0.995977 | Val Loss 0.844086
# Epoch 100 | Train Loss 0.750389 | Val Loss 0.569506
# Epoch 200 | Train Loss 0.734559 | Val Loss 0.597513
# Early stopping at epoch 249
# Modelo salvo em:
# weights/model_arch16_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.6907, MSE = 7.0529e-02
# Theta | Train_2 -> R² = 0.4136, MSE = 1.3342e-01
# Theta | Test_1 -> R² = 0.2724, MSE = 1.6702e-01
# Theta | Test_2 -> R² = 0.8643, MSE = 3.2073e-02
# Theta | Test_3 -> R² = 0.4549, MSE = 1.7903e-01
# Theta | Val -> R² = -6.1569, MSE = 2.3392e+00
# Theta | LSG_1 -> R² = 0.4282, MSE = 2.3682e-01
# Theta | LSG_2 -> R² = -2.4011, MSE = 1.1781e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.974899 | Val Loss 0.808415
# Epoch 100 | Train Loss 0.749158 | Val Loss 0.565087
# Epoch 200 | Train Loss 0.733741 | Val Loss 0.589794
# Early stopping at epoch 284
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7545, MSE = 5.5984e-02
# Theta | Train_2 -> R² = 0.7142, MSE = 6.5016e-02
# Theta | Test_1 -> R² = 0.2971, MSE = 1.6135e-01
# Theta | Test_2 -> R² = 0.8240, MSE = 4.1608e-02
# Theta | Test_3 -> R² = 0.2227, MSE = 2.5529e-01
# Theta | Val -> R² = -7.5789, MSE = 2.8040e+00
# Theta | LSG_1 -> R² = -0.1681, MSE = 4.8375e-01
# Theta | LSG_2 -> R² = -4.9004, MSE = 2.0438e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 0.971196 | Val Loss 0.792751
# Epoch 100 | Train Loss 0.751722 | Val Loss 0.570848
# Epoch 200 | Train Loss 0.738804 | Val Loss 0.590894
# Early stopping at epoch 247
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.6912, MSE = 7.0416e-02
# Theta | Train_2 -> R² = 0.4891, MSE = 1.1622e-01
# Theta | Test_1 -> R² = 0.2255, MSE = 1.7778e-01
# Theta | Test_2 -> R² = 0.8778, MSE = 2.8880e-02
# Theta | Test_3 -> R² = 0.4197, MSE = 1.9059e-01
# Theta | Val -> R² = -6.3166, MSE = 2.3915e+00
# Theta | LSG_1 -> R² = 0.3306, MSE = 2.7722e-01
# Theta | LSG_2 -> R² = -2.9586, MSE = 1.3712e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.967585 | Val Loss 0.816475
# Epoch 100 | Train Loss 0.751509 | Val Loss 0.565361
# Epoch 200 | Train Loss 0.738434 | Val Loss 0.590959
# Early stopping at epoch 273
# Modelo salvo em:
# weights/model_arch16_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7483, MSE = 5.7398e-02
# Theta | Train_2 -> R² = 0.6482, MSE = 8.0031e-02
# Theta | Test_1 -> R² = 0.2143, MSE = 1.8037e-01
# Theta | Test_2 -> R² = 0.8264, MSE = 4.1027e-02
# Theta | Test_3 -> R² = 0.4614, MSE = 1.7688e-01
# Theta | Val -> R² = -6.8593, MSE = 2.5688e+00
# Theta | LSG_1 -> R² = 0.0729, MSE = 3.8393e-01
# Theta | LSG_2 -> R² = -3.9491, MSE = 1.7143e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.957954 | Val Loss 0.800385
# Epoch 100 | Train Loss 0.746065 | Val Loss 0.574616
# Epoch 200 | Train Loss 0.721243 | Val Loss 0.608936
# Early stopping at epoch 250
# Modelo salvo em:
# weights/model_arch16_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.6582, MSE = 7.7947e-02
# Theta | Train_2 -> R² = 0.3911, MSE = 1.3854e-01
# Theta | Test_1 -> R² = 0.1278, MSE = 2.0021e-01
# Theta | Test_2 -> R² = 0.8385, MSE = 3.8165e-02
# Theta | Test_3 -> R² = 0.4362, MSE = 1.8515e-01
# Theta | Val -> R² = -6.5670, MSE = 2.4733e+00
# Theta | LSG_1 -> R² = 0.3377, MSE = 2.7429e-01
# Theta | LSG_2 -> R² = -2.9018, MSE = 1.3515e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 0.936458 | Val Loss 0.750978
# Epoch 100 | Train Loss 0.746731 | Val Loss 0.570424
# Epoch 200 | Train Loss 0.724440 | Val Loss 0.604322
# Early stopping at epoch 240
# Modelo salvo em:
# weights/model_arch16_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7796, MSE = 5.0263e-02
# Theta | Train_2 -> R² = 0.4436, MSE = 1.2659e-01
# Theta | Test_1 -> R² = 0.3644, MSE = 1.4590e-01
# Theta | Test_2 -> R² = 0.8620, MSE = 3.2619e-02
# Theta | Test_3 -> R² = 0.5875, MSE = 1.3547e-01
# Theta | Val -> R² = -5.7895, MSE = 2.2192e+00
# Theta | LSG_1 -> R² = 0.4391, MSE = 2.3229e-01
# Theta | LSG_2 -> R² = -2.4412, MSE = 1.1920e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.980756 | Val Loss 0.829744
# Epoch 100 | Train Loss 0.750615 | Val Loss 0.560103
# Epoch 200 | Train Loss 0.728075 | Val Loss 0.596719
# Early stopping at epoch 290
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7990, MSE = 4.5828e-02
# Theta | Train_2 -> R² = 0.7141, MSE = 6.5049e-02
# Theta | Test_1 -> R² = 0.4504, MSE = 1.2615e-01
# Theta | Test_2 -> R² = 0.8208, MSE = 4.2352e-02
# Theta | Test_3 -> R² = 0.3651, MSE = 2.0851e-01
# Theta | Val -> R² = -6.1340, MSE = 2.3317e+00
# Theta | LSG_1 -> R² = 0.1008, MSE = 3.7239e-01
# Theta | LSG_2 -> R² = -3.7321, MSE = 1.6391e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 0.966645 | Val Loss 0.806778
# Epoch 100 | Train Loss 0.748125 | Val Loss 0.572593
# Epoch 200 | Train Loss 0.731159 | Val Loss 0.592395
# Early stopping at epoch 242
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.6817, MSE = 7.2583e-02
# Theta | Train_2 -> R² = 0.4638, MSE = 1.2200e-01
# Theta | Test_1 -> R² = 0.1934, MSE = 1.8516e-01
# Theta | Test_2 -> R² = 0.8753, MSE = 2.9471e-02
# Theta | Test_3 -> R² = 0.3610, MSE = 2.0987e-01
# Theta | Val -> R² = -6.9723, MSE = 2.6058e+00
# Theta | LSG_1 -> R² = 0.3534, MSE = 2.6776e-01
# Theta | LSG_2 -> R² = -2.8524, MSE = 1.3344e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.000953 | Val Loss 0.865745
# Epoch 100 | Train Loss 0.753737 | Val Loss 0.555070
# Epoch 200 | Train Loss 0.733843 | Val Loss 0.594303
# Early stopping at epoch 295
# Modelo salvo em:
# weights/model_arch16_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.8327, MSE = 3.8150e-02
# Theta | Train_2 -> R² = 0.6565, MSE = 7.8155e-02
# Theta | Test_1 -> R² = 0.5200, MSE = 1.1019e-01
# Theta | Test_2 -> R² = 0.8540, MSE = 3.4495e-02
# Theta | Test_3 -> R² = 0.6214, MSE = 1.2433e-01
# Theta | Val -> R² = -4.8088, MSE = 1.8986e+00
# Theta | LSG_1 -> R² = 0.5253, MSE = 1.9658e-01
# Theta | LSG_2 -> R² = -2.4142, MSE = 1.1826e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 1.000095 | Val Loss 0.825203
# Epoch 100 | Train Loss 0.729958 | Val Loss 0.565767
# Epoch 200 | Train Loss 0.685727 | Val Loss 0.547173
# Epoch 300 | Train Loss 0.620821 | Val Loss 0.774983
# Early stopping at epoch 382
# Modelo salvo em:
# weights/model_arch32_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7864, MSE = 4.8706e-02
# Theta | Train_2 -> R² = 0.7580, MSE = 5.5047e-02
# Theta | Test_1 -> R² = 0.6761, MSE = 7.4360e-02
# Theta | Test_2 -> R² = 0.8715, MSE = 3.0363e-02
# Theta | Test_3 -> R² = 0.1046, MSE = 2.9408e-01
# Theta | Val -> R² = -2.1195, MSE = 1.0196e+00
# Theta | LSG_1 -> R² = 0.6713, MSE = 1.3611e-01
# Theta | LSG_2 -> R² = -2.1807, MSE = 1.1017e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 1.012543 | Val Loss 0.801298
# Epoch 100 | Train Loss 0.742951 | Val Loss 0.565904
# Epoch 200 | Train Loss 0.692177 | Val Loss 0.549304
# Early stopping at epoch 273
# Modelo salvo em:
# weights/model_arch32_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7658, MSE = 5.3413e-02
# Theta | Train_2 -> R² = 0.5999, MSE = 9.1037e-02
# Theta | Test_1 -> R² = 0.4851, MSE = 1.1820e-01
# Theta | Test_2 -> R² = 0.8711, MSE = 3.0456e-02
# Theta | Test_3 -> R² = 0.5858, MSE = 1.3603e-01
# Theta | Val -> R² = -4.2670, MSE = 1.7215e+00
# Theta | LSG_1 -> R² = 0.5072, MSE = 2.0407e-01
# Theta | LSG_2 -> R² = -2.2405, MSE = 1.1225e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.979187 | Val Loss 0.809313
# Epoch 100 | Train Loss 0.717144 | Val Loss 0.574388
# Epoch 200 | Train Loss 0.690086 | Val Loss 0.612049
# Early stopping at epoch 236
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.6247, MSE = 8.5592e-02
# Theta | Train_2 -> R² = 0.5449, MSE = 1.0355e-01
# Theta | Test_1 -> R² = 0.0965, MSE = 2.0740e-01
# Theta | Test_2 -> R² = 0.8731, MSE = 3.0002e-02
# Theta | Test_3 -> R² = 0.4376, MSE = 1.8470e-01
# Theta | Val -> R² = -5.9588, MSE = 2.2745e+00
# Theta | LSG_1 -> R² = 0.2352, MSE = 3.1672e-01
# Theta | LSG_2 -> R² = -3.4187, MSE = 1.5306e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 0.972652 | Val Loss 0.781870
# Epoch 100 | Train Loss 0.729933 | Val Loss 0.566074
# Epoch 200 | Train Loss 0.692488 | Val Loss 0.566072
# Early stopping at epoch 257
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7514, MSE = 5.6702e-02
# Theta | Train_2 -> R² = 0.5378, MSE = 1.0516e-01
# Theta | Test_1 -> R² = 0.4147, MSE = 1.3436e-01
# Theta | Test_2 -> R² = 0.8672, MSE = 3.1379e-02
# Theta | Test_3 -> R² = 0.5892, MSE = 1.3493e-01
# Theta | Val -> R² = -4.4325, MSE = 1.7756e+00
# Theta | LSG_1 -> R² = 0.4943, MSE = 2.0944e-01
# Theta | LSG_2 -> R² = -2.3536, MSE = 1.1616e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.979618 | Val Loss 0.807674
# Epoch 100 | Train Loss 0.722159 | Val Loss 0.565828
# Epoch 200 | Train Loss 0.689469 | Val Loss 0.564601
# Early stopping at epoch 259
# Modelo salvo em:
# weights/model_arch32_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7692, MSE = 5.2630e-02
# Theta | Train_2 -> R² = 0.5477, MSE = 1.0291e-01
# Theta | Test_1 -> R² = 0.4082, MSE = 1.3584e-01
# Theta | Test_2 -> R² = 0.8720, MSE = 3.0261e-02
# Theta | Test_3 -> R² = 0.6872, MSE = 1.0273e-01
# Theta | Val -> R² = -3.4788, MSE = 1.4639e+00
# Theta | LSG_1 -> R² = 0.4553, MSE = 2.2557e-01
# Theta | LSG_2 -> R² = -2.4459, MSE = 1.1936e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.993240 | Val Loss 0.803343
# Epoch 100 | Train Loss 0.728538 | Val Loss 0.570989
# Epoch 200 | Train Loss 0.692182 | Val Loss 0.575609
# Early stopping at epoch 242
# Modelo salvo em:
# weights/model_arch32_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7632, MSE = 5.3992e-02
# Theta | Train_2 -> R² = 0.5859, MSE = 9.4203e-02
# Theta | Test_1 -> R² = 0.3772, MSE = 1.4296e-01
# Theta | Test_2 -> R² = 0.8666, MSE = 3.1527e-02
# Theta | Test_3 -> R² = 0.5707, MSE = 1.4098e-01
# Theta | Val -> R² = -5.0582, MSE = 1.9801e+00
# Theta | LSG_1 -> R² = 0.4187, MSE = 2.4073e-01
# Theta | LSG_2 -> R² = -2.7957, MSE = 1.3147e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 1.020215 | Val Loss 0.807493
# Epoch 100 | Train Loss 0.741888 | Val Loss 0.576115
# Epoch 200 | Train Loss 0.700730 | Val Loss 0.573530
# Early stopping at epoch 266
# Modelo salvo em:
# weights/model_arch32_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7623, MSE = 5.4205e-02
# Theta | Train_2 -> R² = 0.5928, MSE = 9.2639e-02
# Theta | Test_1 -> R² = 0.4367, MSE = 1.2930e-01
# Theta | Test_2 -> R² = 0.8824, MSE = 2.7800e-02
# Theta | Test_3 -> R² = 0.4664, MSE = 1.7526e-01
# Theta | Val -> R² = -5.1667, MSE = 2.0156e+00
# Theta | LSG_1 -> R² = 0.4673, MSE = 2.2060e-01
# Theta | LSG_2 -> R² = -2.4684, MSE = 1.2014e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.991777 | Val Loss 0.822544
# Epoch 100 | Train Loss 0.722689 | Val Loss 0.573001
# Epoch 200 | Train Loss 0.688715 | Val Loss 0.589345
# Early stopping at epoch 245
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7241, MSE = 6.2918e-02
# Theta | Train_2 -> R² = 0.6291, MSE = 8.4384e-02
# Theta | Test_1 -> R² = 0.2564, MSE = 1.7069e-01
# Theta | Test_2 -> R² = 0.8792, MSE = 2.8547e-02
# Theta | Test_3 -> R² = 0.5176, MSE = 1.5843e-01
# Theta | Val -> R² = -6.0230, MSE = 2.2955e+00
# Theta | LSG_1 -> R² = 0.1351, MSE = 3.5819e-01
# Theta | LSG_2 -> R² = -3.7303, MSE = 1.6385e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 0.999930 | Val Loss 0.819418
# Epoch 100 | Train Loss 0.738138 | Val Loss 0.567751
# Epoch 200 | Train Loss 0.692570 | Val Loss 0.556440
# Early stopping at epoch 262
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7649, MSE = 5.3619e-02
# Theta | Train_2 -> R² = 0.6133, MSE = 8.7976e-02
# Theta | Test_1 -> R² = 0.4067, MSE = 1.3619e-01
# Theta | Test_2 -> R² = 0.8725, MSE = 3.0123e-02
# Theta | Test_3 -> R² = 0.4990, MSE = 1.6453e-01
# Theta | Val -> R² = -5.9923, MSE = 2.2854e+00
# Theta | LSG_1 -> R² = 0.2226, MSE = 3.2193e-01
# Theta | LSG_2 -> R² = -3.4891, MSE = 1.5549e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.982136 | Val Loss 0.815436
# Epoch 100 | Train Loss 0.728228 | Val Loss 0.570940
# Epoch 200 | Train Loss 0.673591 | Val Loss 0.609207
# Early stopping at epoch 238
# Modelo salvo em:
# weights/model_arch32_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7138, MSE = 6.5274e-02
# Theta | Train_2 -> R² = 0.6112, MSE = 8.8448e-02
# Theta | Test_1 -> R² = 0.2083, MSE = 1.8174e-01
# Theta | Test_2 -> R² = 0.8754, MSE = 2.9454e-02
# Theta | Test_3 -> R² = 0.5255, MSE = 1.5583e-01
# Theta | Val -> R² = -6.1037, MSE = 2.3219e+00
# Theta | LSG_1 -> R² = 0.0598, MSE = 3.8935e-01
# Theta | LSG_2 -> R² = -3.9986, MSE = 1.7314e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 0.981570 | Val Loss 0.792666
# Epoch 100 | Train Loss 0.740323 | Val Loss 0.599778
# Epoch 200 | Train Loss 0.703228 | Val Loss 0.648133
# Early stopping at epoch 228
# Modelo salvo em:
# weights/model_arch32_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.6051, MSE = 9.0064e-02
# Theta | Train_2 -> R² = 0.3711, MSE = 1.4309e-01
# Theta | Test_1 -> R² = 0.1226, MSE = 2.0140e-01
# Theta | Test_2 -> R² = 0.7700, MSE = 5.4355e-02
# Theta | Test_3 -> R² = 0.1423, MSE = 2.8171e-01
# Theta | Val -> R² = -8.4429, MSE = 3.0864e+00
# Theta | LSG_1 -> R² = -0.0065, MSE = 4.1684e-01
# Theta | LSG_2 -> R² = -3.8858, MSE = 1.6924e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 0.955615 | Val Loss 0.776625
# Epoch 100 | Train Loss 0.741184 | Val Loss 0.596585
# Epoch 200 | Train Loss 0.668513 | Val Loss 0.734430
# Early stopping at epoch 225
# Modelo salvo em:
# weights/model_arch32_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.6249, MSE = 8.5533e-02
# Theta | Train_2 -> R² = 0.5153, MSE = 1.1027e-01
# Theta | Test_1 -> R² = 0.1770, MSE = 1.8891e-01
# Theta | Test_2 -> R² = 0.8472, MSE = 3.6111e-02
# Theta | Test_3 -> R² = -0.1910, MSE = 3.9116e-01
# Theta | Val -> R² = -8.8541, MSE = 3.2208e+00
# Theta | LSG_1 -> R² = 0.0623, MSE = 3.8833e-01
# Theta | LSG_2 -> R² = -3.9421, MSE = 1.7119e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.931576 | Val Loss 0.728185
# Epoch 100 | Train Loss 0.744497 | Val Loss 0.594262
# Epoch 200 | Train Loss 0.704037 | Val Loss 0.651848
# Early stopping at epoch 219
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.8191, MSE = 4.1263e-02
# Theta | Train_2 -> R² = 0.5147, MSE = 1.1042e-01
# Theta | Test_1 -> R² = 0.6135, MSE = 8.8718e-02
# Theta | Test_2 -> R² = 0.8532, MSE = 3.4694e-02
# Theta | Test_3 -> R² = 0.2477, MSE = 2.4709e-01
# Theta | Val -> R² = -6.4063, MSE = 2.4208e+00
# Theta | LSG_1 -> R² = 0.5125, MSE = 2.0187e-01
# Theta | LSG_2 -> R² = -2.1430, MSE = 1.0887e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 0.984969 | Val Loss 0.789856
# Epoch 100 | Train Loss 0.746111 | Val Loss 0.589806
# Epoch 200 | Train Loss 0.716025 | Val Loss 0.621183
# Early stopping at epoch 225
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.5175, MSE = 1.1004e-01
# Theta | Train_2 -> R² = 0.3509, MSE = 1.4767e-01
# Theta | Test_1 -> R² = -0.0957, MSE = 2.5153e-01
# Theta | Test_2 -> R² = 0.7371, MSE = 6.2145e-02
# Theta | Test_3 -> R² = -0.0535, MSE = 3.4598e-01
# Theta | Val -> R² = -9.3064, MSE = 3.3687e+00
# Theta | LSG_1 -> R² = -0.0796, MSE = 4.4708e-01
# Theta | LSG_2 -> R² = -4.2418, MSE = 1.8157e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.970774 | Val Loss 0.809687
# Epoch 100 | Train Loss 0.741481 | Val Loss 0.599848
# Epoch 200 | Train Loss 0.702940 | Val Loss 0.618619
# Early stopping at epoch 225
# Modelo salvo em:
# weights/model_arch32_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.6370, MSE = 8.2778e-02
# Theta | Train_2 -> R² = 0.4336, MSE = 1.2886e-01
# Theta | Test_1 -> R² = 0.2804, MSE = 1.6519e-01
# Theta | Test_2 -> R² = 0.7979, MSE = 4.7765e-02
# Theta | Test_3 -> R² = -0.1933, MSE = 3.9191e-01
# Theta | Val -> R² = -8.3125, MSE = 3.0438e+00
# Theta | LSG_1 -> R² = 0.2506, MSE = 3.1035e-01
# Theta | LSG_2 -> R² = -3.0557, MSE = 1.4048e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.976826 | Val Loss 0.782138
# Epoch 100 | Train Loss 0.742753 | Val Loss 0.599458
# Epoch 200 | Train Loss 0.721706 | Val Loss 0.618421
# Early stopping at epoch 227
# Modelo salvo em:
# weights/model_arch32_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.5265, MSE = 1.0799e-01
# Theta | Train_2 -> R² = 0.3010, MSE = 1.5904e-01
# Theta | Test_1 -> R² = 0.0690, MSE = 2.1372e-01
# Theta | Test_2 -> R² = 0.6951, MSE = 7.2063e-02
# Theta | Test_3 -> R² = -0.2721, MSE = 4.1778e-01
# Theta | Val -> R² = -9.2437, MSE = 3.3482e+00
# Theta | LSG_1 -> R² = 0.0464, MSE = 3.9493e-01
# Theta | LSG_2 -> R² = -3.6533, MSE = 1.6118e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 0.902299 | Val Loss 0.683527
# Epoch 100 | Train Loss 0.739709 | Val Loss 0.602565
# Epoch 200 | Train Loss 0.701766 | Val Loss 0.657559
# Early stopping at epoch 217
# Modelo salvo em:
# weights/model_arch32_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.8309, MSE = 3.8561e-02
# Theta | Train_2 -> R² = 0.4530, MSE = 1.2444e-01
# Theta | Test_1 -> R² = 0.5468, MSE = 1.0404e-01
# Theta | Test_2 -> R² = 0.8182, MSE = 4.2975e-02
# Theta | Test_3 -> R² = 0.5031, MSE = 1.6320e-01
# Theta | Val -> R² = -6.3420, MSE = 2.3998e+00
# Theta | LSG_1 -> R² = 0.4163, MSE = 2.4171e-01
# Theta | LSG_2 -> R² = -2.4351, MSE = 1.1899e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.982003 | Val Loss 0.836070
# Epoch 100 | Train Loss 0.741369 | Val Loss 0.603919
# Epoch 200 | Train Loss 0.707062 | Val Loss 0.653447
# Early stopping at epoch 230
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7087, MSE = 6.6422e-02
# Theta | Train_2 -> R² = 0.5517, MSE = 1.0199e-01
# Theta | Test_1 -> R² = 0.2770, MSE = 1.6596e-01
# Theta | Test_2 -> R² = 0.8637, MSE = 3.2212e-02
# Theta | Test_3 -> R² = -0.0897, MSE = 3.5789e-01
# Theta | Val -> R² = -8.9688, MSE = 3.2583e+00
# Theta | LSG_1 -> R² = 0.0414, MSE = 3.9697e-01
# Theta | LSG_2 -> R² = -4.0229, MSE = 1.7399e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 1.004875 | Val Loss 0.844795
# Epoch 100 | Train Loss 0.738877 | Val Loss 0.599860
# Epoch 200 | Train Loss 0.706041 | Val Loss 0.632313
# Early stopping at epoch 232
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7643, MSE = 5.3748e-02
# Theta | Train_2 -> R² = 0.5923, MSE = 9.2755e-02
# Theta | Test_1 -> R² = 0.3947, MSE = 1.3895e-01
# Theta | Test_2 -> R² = 0.8671, MSE = 3.1417e-02
# Theta | Test_3 -> R² = -0.0760, MSE = 3.5339e-01
# Theta | Val -> R² = -8.9265, MSE = 3.2445e+00
# Theta | LSG_1 -> R² = 0.0416, MSE = 3.9689e-01
# Theta | LSG_2 -> R² = -4.0883, MSE = 1.7625e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.011370 | Val Loss 0.865190
# Epoch 100 | Train Loss 0.741245 | Val Loss 0.597282
# Epoch 200 | Train Loss 0.701528 | Val Loss 0.660084
# Early stopping at epoch 230
# Modelo salvo em:
# weights/model_arch32_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.6818, MSE = 7.2573e-02
# Theta | Train_2 -> R² = 0.4583, MSE = 1.2324e-01
# Theta | Test_1 -> R² = 0.2216, MSE = 1.7868e-01
# Theta | Test_2 -> R² = 0.8174, MSE = 4.3164e-02
# Theta | Test_3 -> R² = 0.1346, MSE = 2.8423e-01
# Theta | Val -> R² = -8.3216, MSE = 3.0468e+00
# Theta | LSG_1 -> R² = 0.1273, MSE = 3.6140e-01
# Theta | LSG_2 -> R² = -3.6176, MSE = 1.5994e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 1.009343 | Val Loss 0.826333
# Epoch 100 | Train Loss 0.706467 | Val Loss 0.567120
# Epoch 200 | Train Loss 0.661553 | Val Loss 0.662560
# Early stopping at epoch 232
# Modelo salvo em:
# weights/model_arch64_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7271, MSE = 6.2241e-02
# Theta | Train_2 -> R² = 0.6806, MSE = 7.2658e-02
# Theta | Test_1 -> R² = 0.2361, MSE = 1.7535e-01
# Theta | Test_2 -> R² = 0.8488, MSE = 3.5736e-02
# Theta | Test_3 -> R² = 0.3941, MSE = 1.9899e-01
# Theta | Val -> R² = -6.9270, MSE = 2.5909e+00
# Theta | LSG_1 -> R² = -0.2569, MSE = 5.2052e-01
# Theta | LSG_2 -> R² = -5.6765, MSE = 2.3126e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 1.017338 | Val Loss 0.718117
# Epoch 100 | Train Loss 0.710107 | Val Loss 0.569421
# Epoch 200 | Train Loss 0.671224 | Val Loss 0.636721
# Early stopping at epoch 242
# Modelo salvo em:
# weights/model_arch64_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7765, MSE = 5.0959e-02
# Theta | Train_2 -> R² = 0.6982, MSE = 6.8654e-02
# Theta | Test_1 -> R² = 0.3513, MSE = 1.4892e-01
# Theta | Test_2 -> R² = 0.8420, MSE = 3.7334e-02
# Theta | Test_3 -> R² = 0.4041, MSE = 1.9572e-01
# Theta | Val -> R² = -6.4895, MSE = 2.4480e+00
# Theta | LSG_1 -> R² = 0.0729, MSE = 3.8395e-01
# Theta | LSG_2 -> R² = -4.3030, MSE = 1.8369e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.983961 | Val Loss 0.761951
# Epoch 100 | Train Loss 0.705677 | Val Loss 0.575954
# Epoch 200 | Train Loss 0.653872 | Val Loss 0.711494
# Early stopping at epoch 227
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.8279, MSE = 3.9244e-02
# Theta | Train_2 -> R² = 0.6714, MSE = 7.4750e-02
# Theta | Test_1 -> R² = 0.5443, MSE = 1.0460e-01
# Theta | Test_2 -> R² = 0.8676, MSE = 3.1288e-02
# Theta | Test_3 -> R² = 0.4542, MSE = 1.7924e-01
# Theta | Val -> R² = -7.0528, MSE = 2.6321e+00
# Theta | LSG_1 -> R² = -0.1276, MSE = 4.6698e-01
# Theta | LSG_2 -> R² = -5.0235, MSE = 2.0864e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 1.011669 | Val Loss 0.805942
# Epoch 100 | Train Loss 0.708340 | Val Loss 0.570197
# Epoch 200 | Train Loss 0.668989 | Val Loss 0.621394
# Early stopping at epoch 233
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7891, MSE = 4.8090e-02
# Theta | Train_2 -> R² = 0.6252, MSE = 8.5269e-02
# Theta | Test_1 -> R² = 0.4244, MSE = 1.3212e-01
# Theta | Test_2 -> R² = 0.8561, MSE = 3.4006e-02
# Theta | Test_3 -> R² = 0.6879, MSE = 1.0251e-01
# Theta | Val -> R² = -5.1290, MSE = 2.0033e+00
# Theta | LSG_1 -> R² = 0.0178, MSE = 4.0675e-01
# Theta | LSG_2 -> R² = -4.2850, MSE = 1.8306e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.954626 | Val Loss 0.733061
# Epoch 100 | Train Loss 0.704133 | Val Loss 0.571185
# Epoch 200 | Train Loss 0.631400 | Val Loss 0.765261
# Early stopping at epoch 225
# Modelo salvo em:
# weights/model_arch64_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7906, MSE = 4.7753e-02
# Theta | Train_2 -> R² = 0.5889, MSE = 9.3532e-02
# Theta | Test_1 -> R² = 0.4610, MSE = 1.2373e-01
# Theta | Test_2 -> R² = 0.8667, MSE = 3.1510e-02
# Theta | Test_3 -> R² = 0.5498, MSE = 1.4787e-01
# Theta | Val -> R² = -5.7262, MSE = 2.1985e+00
# Theta | LSG_1 -> R² = 0.2743, MSE = 3.0054e-01
# Theta | LSG_2 -> R² = -3.3184, MSE = 1.4958e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.952598 | Val Loss 0.696663
# Epoch 100 | Train Loss 0.706395 | Val Loss 0.568060
# Epoch 200 | Train Loss 0.653627 | Val Loss 0.711231
# Early stopping at epoch 220
# Modelo salvo em:
# weights/model_arch64_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.6311, MSE = 8.4137e-02
# Theta | Train_2 -> R² = 0.6510, MSE = 7.9401e-02
# Theta | Test_1 -> R² = 0.1203, MSE = 2.0192e-01
# Theta | Test_2 -> R² = 0.8574, MSE = 3.3693e-02
# Theta | Test_3 -> R² = 0.3191, MSE = 2.2362e-01
# Theta | Val -> R² = -7.2148, MSE = 2.6850e+00
# Theta | LSG_1 -> R² = -0.3601, MSE = 5.6327e-01
# Theta | LSG_2 -> R² = -5.5503, MSE = 2.2689e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 1.039423 | Val Loss 0.826841
# Epoch 100 | Train Loss 0.710034 | Val Loss 0.572219
# Epoch 200 | Train Loss 0.682199 | Val Loss 0.605510
# Early stopping at epoch 236
# Modelo salvo em:
# weights/model_arch64_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.8085, MSE = 4.3663e-02
# Theta | Train_2 -> R² = 0.6890, MSE = 7.0766e-02
# Theta | Test_1 -> R² = 0.6040, MSE = 9.0905e-02
# Theta | Test_2 -> R² = 0.8893, MSE = 2.6154e-02
# Theta | Test_3 -> R² = -0.0589, MSE = 3.4776e-01
# Theta | Val -> R² = -8.0627, MSE = 2.9622e+00
# Theta | LSG_1 -> R² = 0.1346, MSE = 3.5839e-01
# Theta | LSG_2 -> R² = -3.9639, MSE = 1.7194e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.953314 | Val Loss 0.715344
# Epoch 100 | Train Loss 0.704841 | Val Loss 0.570376
# Epoch 200 | Train Loss 0.645436 | Val Loss 0.679639
# Early stopping at epoch 222
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.6211, MSE = 8.6403e-02
# Theta | Train_2 -> R² = 0.4519, MSE = 1.2470e-01
# Theta | Test_1 -> R² = 0.1445, MSE = 1.9637e-01
# Theta | Test_2 -> R² = 0.7856, MSE = 5.0661e-02
# Theta | Test_3 -> R² = 0.6126, MSE = 1.2724e-01
# Theta | Val -> R² = -5.1804, MSE = 2.0201e+00
# Theta | LSG_1 -> R² = 0.0863, MSE = 3.7841e-01
# Theta | LSG_2 -> R² = -4.0347, MSE = 1.7439e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 1.038305 | Val Loss 0.800904
# Epoch 100 | Train Loss 0.711746 | Val Loss 0.567955
# Epoch 200 | Train Loss 0.682978 | Val Loss 0.569120
# Early stopping at epoch 234
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.8142, MSE = 4.2368e-02
# Theta | Train_2 -> R² = 0.5740, MSE = 9.6908e-02
# Theta | Test_1 -> R² = 0.6351, MSE = 8.3757e-02
# Theta | Test_2 -> R² = 0.8569, MSE = 3.3830e-02
# Theta | Test_3 -> R² = 0.6479, MSE = 1.1565e-01
# Theta | Val -> R² = -4.1335, MSE = 1.6779e+00
# Theta | LSG_1 -> R² = 0.4585, MSE = 2.2427e-01
# Theta | LSG_2 -> R² = -2.6826, MSE = 1.2756e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.984391 | Val Loss 0.756697
# Epoch 100 | Train Loss 0.705352 | Val Loss 0.573333
# Epoch 200 | Train Loss 0.651376 | Val Loss 0.686150
# Early stopping at epoch 229
# Modelo salvo em:
# weights/model_arch64_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.8078, MSE = 4.3843e-02
# Theta | Train_2 -> R² = 0.6484, MSE = 7.9993e-02
# Theta | Test_1 -> R² = 0.3532, MSE = 1.4848e-01
# Theta | Test_2 -> R² = 0.8363, MSE = 3.8686e-02
# Theta | Test_3 -> R² = 0.6692, MSE = 1.0866e-01
# Theta | Val -> R² = -6.3111, MSE = 2.3897e+00
# Theta | LSG_1 -> R² = -0.2436, MSE = 5.1501e-01
# Theta | LSG_2 -> R² = -5.2094, MSE = 2.1508e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 1.039657 | Val Loss 0.797562
# Epoch 100 | Train Loss 0.733757 | Val Loss 0.613085
# Epoch 200 | Train Loss 0.684106 | Val Loss 0.603038
# Early stopping at epoch 216
# Modelo salvo em:
# weights/model_arch64_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.8168, MSE = 4.1772e-02
# Theta | Train_2 -> R² = 0.6615, MSE = 7.7010e-02
# Theta | Test_1 -> R² = 0.6642, MSE = 7.7074e-02
# Theta | Test_2 -> R² = 0.8942, MSE = 2.5015e-02
# Theta | Test_3 -> R² = -0.2603, MSE = 4.1392e-01
# Theta | Val -> R² = -9.1777, MSE = 3.3266e+00
# Theta | LSG_1 -> R² = 0.0972, MSE = 3.7386e-01
# Theta | LSG_2 -> R² = -4.0308, MSE = 1.7426e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 0.975139 | Val Loss 0.755763
# Epoch 100 | Train Loss 0.725060 | Val Loss 0.624177
# Epoch 200 | Train Loss 0.593137 | Val Loss 0.809442
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch64_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7231, MSE = 6.3140e-02
# Theta | Train_2 -> R² = 0.7337, MSE = 6.0590e-02
# Theta | Test_1 -> R² = 0.6525, MSE = 7.9771e-02
# Theta | Test_2 -> R² = 0.9257, MSE = 1.7564e-02
# Theta | Test_3 -> R² = -1.8147, MSE = 9.2441e-01
# Theta | Val -> R² = -13.8975, MSE = 4.8693e+00
# Theta | LSG_1 -> R² = -0.3666, MSE = 5.6597e-01
# Theta | LSG_2 -> R² = -5.1791, MSE = 2.1403e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.920474 | Val Loss 0.701370
# Epoch 100 | Train Loss 0.730272 | Val Loss 0.617659
# Epoch 200 | Train Loss 0.609355 | Val Loss 0.687492
# Early stopping at epoch 208
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.6821, MSE = 7.2493e-02
# Theta | Train_2 -> R² = 0.6604, MSE = 7.7262e-02
# Theta | Test_1 -> R² = 0.3861, MSE = 1.4092e-01
# Theta | Test_2 -> R² = 0.8902, MSE = 2.5953e-02
# Theta | Test_3 -> R² = -0.6353, MSE = 5.3709e-01
# Theta | Val -> R² = -10.9935, MSE = 3.9201e+00
# Theta | LSG_1 -> R² = -0.4416, MSE = 5.9700e-01
# Theta | LSG_2 -> R² = -5.3418, MSE = 2.1967e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 1.027028 | Val Loss 0.765230
# Epoch 100 | Train Loss 0.737838 | Val Loss 0.625196
# Epoch 200 | Train Loss 0.709026 | Val Loss 0.622765
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7963, MSE = 4.6466e-02
# Theta | Train_2 -> R² = 0.6974, MSE = 6.8854e-02
# Theta | Test_1 -> R² = 0.7818, MSE = 5.0098e-02
# Theta | Test_2 -> R² = 0.8407, MSE = 3.7655e-02
# Theta | Test_3 -> R² = -0.7026, MSE = 5.5918e-01
# Theta | Val -> R² = -12.1234, MSE = 4.2894e+00
# Theta | LSG_1 -> R² = -0.3326, MSE = 5.5188e-01
# Theta | LSG_2 -> R² = -5.6268, MSE = 2.2954e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.898102 | Val Loss 0.669783
# Epoch 100 | Train Loss 0.727367 | Val Loss 0.640304
# Epoch 200 | Train Loss 0.577450 | Val Loss 0.943404
# Early stopping at epoch 207
# Modelo salvo em:
# weights/model_arch64_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.6681, MSE = 7.5702e-02
# Theta | Train_2 -> R² = 0.6927, MSE = 6.9913e-02
# Theta | Test_1 -> R² = 0.4516, MSE = 1.2589e-01
# Theta | Test_2 -> R² = 0.8823, MSE = 2.7821e-02
# Theta | Test_3 -> R² = -1.8329, MSE = 9.3039e-01
# Theta | Val -> R² = -14.8362, MSE = 5.1761e+00
# Theta | LSG_1 -> R² = -0.7755, MSE = 7.3528e-01
# Theta | LSG_2 -> R² = -6.3300, MSE = 2.5390e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 1.053059 | Val Loss 0.893044
# Epoch 100 | Train Loss 0.734310 | Val Loss 0.614996
# Epoch 200 | Train Loss 0.692445 | Val Loss 0.620035
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch64_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.8432, MSE = 3.5760e-02
# Theta | Train_2 -> R² = 0.5511, MSE = 1.0213e-01
# Theta | Test_1 -> R² = 0.7939, MSE = 4.7304e-02
# Theta | Test_2 -> R² = 0.8523, MSE = 3.4912e-02
# Theta | Test_3 -> R² = 0.0585, MSE = 3.0922e-01
# Theta | Val -> R² = -8.0680, MSE = 2.9639e+00
# Theta | LSG_1 -> R² = 0.3443, MSE = 2.7155e-01
# Theta | LSG_2 -> R² = -2.6581, MSE = 1.2671e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 0.961413 | Val Loss 0.763841
# Epoch 100 | Train Loss 0.726545 | Val Loss 0.616769
# Epoch 200 | Train Loss 0.594359 | Val Loss 0.834722
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch64_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.8105, MSE = 4.3215e-02
# Theta | Train_2 -> R² = 0.6677, MSE = 7.5609e-02
# Theta | Test_1 -> R² = 0.5434, MSE = 1.0482e-01
# Theta | Test_2 -> R² = 0.8716, MSE = 3.0353e-02
# Theta | Test_3 -> R² = -0.8031, MSE = 5.9218e-01
# Theta | Val -> R² = -13.1340, MSE = 4.6197e+00
# Theta | LSG_1 -> R² = -0.5505, MSE = 6.4213e-01
# Theta | LSG_2 -> R² = -5.8887, MSE = 2.3861e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 1.082812 | Val Loss 0.848981
# Epoch 100 | Train Loss 0.732293 | Val Loss 0.617080
# Epoch 200 | Train Loss 0.676018 | Val Loss 0.590487
# Early stopping at epoch 217
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.8037, MSE = 4.4757e-02
# Theta | Train_2 -> R² = 0.6885, MSE = 7.0861e-02
# Theta | Test_1 -> R² = 0.7120, MSE = 6.6117e-02
# Theta | Test_2 -> R² = 0.8956, MSE = 2.4669e-02
# Theta | Test_3 -> R² = -0.4465, MSE = 4.7507e-01
# Theta | Val -> R² = -10.6458, MSE = 3.8065e+00
# Theta | LSG_1 -> R² = -0.1638, MSE = 4.8197e-01
# Theta | LSG_2 -> R² = -4.8460, MSE = 2.0249e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 1.068904 | Val Loss 0.837040
# Epoch 100 | Train Loss 0.737026 | Val Loss 0.623008
# Epoch 200 | Train Loss 0.711104 | Val Loss 0.624346
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.8511, MSE = 3.3950e-02
# Theta | Train_2 -> R² = 0.6746, MSE = 7.4038e-02
# Theta | Test_1 -> R² = 0.6810, MSE = 7.3237e-02
# Theta | Test_2 -> R² = 0.8742, MSE = 2.9742e-02
# Theta | Test_3 -> R² = -0.6609, MSE = 5.4547e-01
# Theta | Val -> R² = -12.8009, MSE = 4.5108e+00
# Theta | LSG_1 -> R² = -0.4445, MSE = 5.9820e-01
# Theta | LSG_2 -> R² = -5.6220, MSE = 2.2937e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.993702 | Val Loss 0.752742
# Epoch 100 | Train Loss 0.733253 | Val Loss 0.616025
# Epoch 200 | Train Loss 0.661185 | Val Loss 0.654294
# Early stopping at epoch 213
# Modelo salvo em:
# weights/model_arch64_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.8490, MSE = 3.4428e-02
# Theta | Train_2 -> R² = 0.7183, MSE = 6.4085e-02
# Theta | Test_1 -> R² = 0.6886, MSE = 7.1476e-02
# Theta | Test_2 -> R² = 0.8349, MSE = 3.9019e-02
# Theta | Test_3 -> R² = -0.7249, MSE = 5.6649e-01
# Theta | Val -> R² = -12.8347, MSE = 4.5219e+00
# Theta | LSG_1 -> R² = -0.5704, MSE = 6.5035e-01
# Theta | LSG_2 -> R² = -6.3284, MSE = 2.5384e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 1.031197 | Val Loss 0.685866
# Epoch 100 | Train Loss 0.705171 | Val Loss 0.569193
# Epoch 200 | Train Loss 0.671251 | Val Loss 0.595176
# Early stopping at epoch 223
# Modelo salvo em:
# weights/model_arch128_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7672, MSE = 5.3094e-02
# Theta | Train_2 -> R² = 0.5594, MSE = 1.0024e-01
# Theta | Test_1 -> R² = 0.4198, MSE = 1.3318e-01
# Theta | Test_2 -> R² = 0.8262, MSE = 4.1067e-02
# Theta | Test_3 -> R² = 0.3403, MSE = 2.1668e-01
# Theta | Val -> R² = -6.9874, MSE = 2.6107e+00
# Theta | LSG_1 -> R² = 0.1540, MSE = 3.5034e-01
# Theta | LSG_2 -> R² = -3.8740, MSE = 1.6883e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 1.012704 | Val Loss 0.647903
# Epoch 100 | Train Loss 0.703644 | Val Loss 0.566846
# Epoch 200 | Train Loss 0.668011 | Val Loss 0.608932
# Early stopping at epoch 223
# Modelo salvo em:
# weights/model_arch128_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7542, MSE = 5.6052e-02
# Theta | Train_2 -> R² = 0.5923, MSE = 9.2763e-02
# Theta | Test_1 -> R² = 0.3366, MSE = 1.5229e-01
# Theta | Test_2 -> R² = 0.8321, MSE = 3.9692e-02
# Theta | Test_3 -> R² = 0.6675, MSE = 1.0921e-01
# Theta | Val -> R² = -5.0168, MSE = 1.9666e+00
# Theta | LSG_1 -> R² = 0.1529, MSE = 3.5082e-01
# Theta | LSG_2 -> R² = -4.1030, MSE = 1.7676e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 1.250828 | Val Loss 0.786204
# Epoch 100 | Train Loss 0.707420 | Val Loss 0.567186
# Epoch 200 | Train Loss 0.676791 | Val Loss 0.595478
# Early stopping at epoch 233
# Modelo salvo em:
# weights/model_arch128_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7280, MSE = 6.2032e-02
# Theta | Train_2 -> R² = 0.5899, MSE = 9.3303e-02
# Theta | Test_1 -> R² = 0.2470, MSE = 1.7284e-01
# Theta | Test_2 -> R² = 0.8061, MSE = 4.5831e-02
# Theta | Test_3 -> R² = 0.5643, MSE = 1.4309e-01
# Theta | Val -> R² = -6.3863, MSE = 2.4142e+00
# Theta | LSG_1 -> R² = -0.0645, MSE = 4.4086e-01
# Theta | LSG_2 -> R² = -5.0114, MSE = 2.0822e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 1.121181 | Val Loss 0.682569
# Epoch 100 | Train Loss 0.705524 | Val Loss 0.564593
# Epoch 200 | Train Loss 0.672367 | Val Loss 0.612227
# Early stopping at epoch 224
# Modelo salvo em:
# weights/model_arch128_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7754, MSE = 5.1215e-02
# Theta | Train_2 -> R² = 0.7338, MSE = 6.0558e-02
# Theta | Test_1 -> R² = 0.5391, MSE = 1.0580e-01
# Theta | Test_2 -> R² = 0.8717, MSE = 3.0329e-02
# Theta | Test_3 -> R² = 0.0219, MSE = 3.2123e-01
# Theta | Val -> R² = -7.5985, MSE = 2.8104e+00
# Theta | LSG_1 -> R² = -0.0623, MSE = 4.3993e-01
# Theta | LSG_2 -> R² = -5.1943, MSE = 2.1456e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.085752 | Val Loss 0.740515
# Epoch 100 | Train Loss 0.704591 | Val Loss 0.566995
# Epoch 200 | Train Loss 0.686403 | Val Loss 0.607719
# Early stopping at epoch 223
# Modelo salvo em:
# weights/model_arch128_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.8222, MSE = 4.0542e-02
# Theta | Train_2 -> R² = 0.6820, MSE = 7.2337e-02
# Theta | Test_1 -> R² = 0.5541, MSE = 1.0236e-01
# Theta | Test_2 -> R² = 0.8662, MSE = 3.1621e-02
# Theta | Test_3 -> R² = 0.2782, MSE = 2.3705e-01
# Theta | Val -> R² = -7.5731, MSE = 2.8021e+00
# Theta | LSG_1 -> R² = -0.0635, MSE = 4.4042e-01
# Theta | LSG_2 -> R² = -4.8668, MSE = 2.0322e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.981455 | Val Loss 0.665338
# Epoch 100 | Train Loss 0.704061 | Val Loss 0.572672
# Epoch 200 | Train Loss 0.656436 | Val Loss 0.673402
# Early stopping at epoch 221
# Modelo salvo em:
# weights/model_arch128_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.8307, MSE = 3.8605e-02
# Theta | Train_2 -> R² = 0.6170, MSE = 8.7134e-02
# Theta | Test_1 -> R² = 0.5930, MSE = 9.3418e-02
# Theta | Test_2 -> R² = 0.8586, MSE = 3.3431e-02
# Theta | Test_3 -> R² = 0.4650, MSE = 1.7570e-01
# Theta | Val -> R² = -5.9178, MSE = 2.2611e+00
# Theta | LSG_1 -> R² = 0.2770, MSE = 2.9942e-01
# Theta | LSG_2 -> R² = -3.5253, MSE = 1.5675e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 1.114646 | Val Loss 0.782371
# Epoch 100 | Train Loss 0.705889 | Val Loss 0.571805
# Epoch 200 | Train Loss 0.688895 | Val Loss 0.550472
# Early stopping at epoch 221
# Modelo salvo em:
# weights/model_arch128_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.8264, MSE = 3.9591e-02
# Theta | Train_2 -> R² = 0.6328, MSE = 8.3550e-02
# Theta | Test_1 -> R² = 0.6331, MSE = 8.4231e-02
# Theta | Test_2 -> R² = 0.8603, MSE = 3.3014e-02
# Theta | Test_3 -> R² = 0.1332, MSE = 2.8467e-01
# Theta | Val -> R² = -7.4207, MSE = 2.7523e+00
# Theta | LSG_1 -> R² = 0.1945, MSE = 3.3359e-01
# Theta | LSG_2 -> R² = -3.9536, MSE = 1.7158e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 1.001492 | Val Loss 0.685321
# Epoch 100 | Train Loss 0.703195 | Val Loss 0.568659
# Epoch 200 | Train Loss 0.640039 | Val Loss 0.824694
# Early stopping at epoch 221
# Modelo salvo em:
# weights/model_arch128_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7709, MSE = 5.2249e-02
# Theta | Train_2 -> R² = 0.7092, MSE = 6.6159e-02
# Theta | Test_1 -> R² = 0.5443, MSE = 1.0461e-01
# Theta | Test_2 -> R² = 0.8927, MSE = 2.5362e-02
# Theta | Test_3 -> R² = 0.3015, MSE = 2.2939e-01
# Theta | Val -> R² = -5.7218, MSE = 2.1970e+00
# Theta | LSG_1 -> R² = 0.2180, MSE = 3.2383e-01
# Theta | LSG_2 -> R² = -4.0833, MSE = 1.7607e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 1.183316 | Val Loss 0.710588
# Epoch 100 | Train Loss 0.706828 | Val Loss 0.566448
# Epoch 200 | Train Loss 0.680634 | Val Loss 0.572376
# Early stopping at epoch 224
# Modelo salvo em:
# weights/model_arch128_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7722, MSE = 5.1955e-02
# Theta | Train_2 -> R² = 0.6720, MSE = 7.4615e-02
# Theta | Test_1 -> R² = 0.7141, MSE = 6.5637e-02
# Theta | Test_2 -> R² = 0.8075, MSE = 4.5496e-02
# Theta | Test_3 -> R² = 0.4278, MSE = 1.8794e-01
# Theta | Val -> R² = -5.0034, MSE = 1.9622e+00
# Theta | LSG_1 -> R² = 0.2636, MSE = 3.0495e-01
# Theta | LSG_2 -> R² = -4.0318, MSE = 1.7429e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.063026 | Val Loss 0.733229
# Epoch 100 | Train Loss 0.704222 | Val Loss 0.565464
# Epoch 200 | Train Loss 0.668062 | Val Loss 0.626987
# Early stopping at epoch 221
# Modelo salvo em:
# weights/model_arch128_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7996, MSE = 4.5692e-02
# Theta | Train_2 -> R² = 0.6803, MSE = 7.2727e-02
# ...
# Early stopping at epoch 208
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7547, MSE = 5.5936e-02
# Theta | Train_2 -> R² = 0.4760, MSE = 1.1922e-01
# Theta | Test_1 -> R² = 0.1791, MSE = 1.8845e-01
# Theta | Test_2 -> R² = 0.8664, MSE = 3.1580e-02
# Theta | Test_3 -> R² = 0.5344, MSE = 1.5291e-01
# Theta | Val -> R² = -5.9413, MSE = 2.2688e+00
# Theta | LSG_1 -> R² = 0.4120, MSE = 2.4353e-01
# Theta | LSG_2 -> R² = -2.7089, MSE = 1.2847e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 0.977174 | Val Loss 0.749044
# Epoch 100 | Train Loss 0.623416 | Val Loss 0.768183
# Epoch 200 | Train Loss 0.538019 | Val Loss 1.027325
# Early stopping at epoch 218
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.8389, MSE = 3.6739e-02
# Theta | Train_2 -> R² = 0.6613, MSE = 7.7062e-02
# Theta | Test_1 -> R² = 0.5894, MSE = 9.4243e-02
# Theta | Test_2 -> R² = 0.7873, MSE = 5.0279e-02
# Theta | Test_3 -> R² = 0.2570, MSE = 2.4401e-01
# Theta | Val -> R² = -6.4611, MSE = 2.4387e+00
# Theta | LSG_1 -> R² = 0.4169, MSE = 2.4147e-01
# Theta | LSG_2 -> R² = -3.0111, MSE = 1.3894e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.977522 | Val Loss 0.756121
# Epoch 100 | Train Loss 0.664896 | Val Loss 0.565679
# Epoch 200 | Train Loss 0.552853 | Val Loss 0.922217
# Early stopping at epoch 218
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7677, MSE = 5.2975e-02
# Theta | Train_2 -> R² = 0.6799, MSE = 7.2821e-02
# Theta | Test_1 -> R² = 0.3136, MSE = 1.5756e-01
# Theta | Test_2 -> R² = 0.8218, MSE = 4.2122e-02
# Theta | Test_3 -> R² = 0.3156, MSE = 2.2477e-01
# Theta | Val -> R² = -7.1979, MSE = 2.6795e+00
# Theta | LSG_1 -> R² = 0.0943, MSE = 3.7509e-01
# Theta | LSG_2 -> R² = -4.0597, MSE = 1.7526e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 1.020799 | Val Loss 0.712313
# Epoch 100 | Train Loss 0.641310 | Val Loss 0.623129
# Epoch 200 | Train Loss 0.564890 | Val Loss 0.758751
# Early stopping at epoch 205
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.6545, MSE = 7.8781e-02
# Theta | Train_2 -> R² = 0.6949, MSE = 6.9417e-02
# Theta | Test_1 -> R² = 0.1074, MSE = 2.0490e-01
# Theta | Test_2 -> R² = 0.8801, MSE = 2.8341e-02
# Theta | Test_3 -> R² = 0.1747, MSE = 2.7103e-01
# Theta | Val -> R² = -7.4596, MSE = 2.7650e+00
# Theta | LSG_1 -> R² = -0.0473, MSE = 4.3374e-01
# Theta | LSG_2 -> R² = -4.6843, MSE = 1.9689e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 0.956833 | Val Loss 0.641961
# Epoch 100 | Train Loss 0.642132 | Val Loss 0.625582
# Epoch 200 | Train Loss 0.564674 | Val Loss 0.784796
# Early stopping at epoch 206
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7220, MSE = 6.3391e-02
# Theta | Train_2 -> R² = 0.5752, MSE = 9.6642e-02
# Theta | Test_1 -> R² = 0.8435, MSE = 3.5920e-02
# Theta | Test_2 -> R² = 0.8266, MSE = 4.0993e-02
# Theta | Test_3 -> R² = 0.5411, MSE = 1.5072e-01
# Theta | Val -> R² = -2.7828, MSE = 1.2364e+00
# Theta | LSG_1 -> R² = 0.6920, MSE = 1.2756e-01
# Theta | LSG_2 -> R² = -1.1460, MSE = 7.4333e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.957331 | Val Loss 0.661349
# Epoch 100 | Train Loss 0.637640 | Val Loss 0.653807
# Epoch 200 | Train Loss 0.553147 | Val Loss 0.836116
# Early stopping at epoch 253
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.7427, MSE = 5.8685e-02
# Theta | Train_2 -> R² = 0.7940, MSE = 4.6876e-02
# Theta | Test_1 -> R² = 0.6637, MSE = 7.7194e-02
# Theta | Test_2 -> R² = 0.8706, MSE = 3.0581e-02
# Theta | Test_3 -> R² = 0.6159, MSE = 1.2615e-01
# Theta | Val -> R² = -1.2773, MSE = 7.4435e-01
# Theta | LSG_1 -> R² = 0.6722, MSE = 1.3575e-01
# Theta | LSG_2 -> R² = -2.8690, MSE = 1.3401e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 0.973756 | Val Loss 0.561770
# Epoch 100 | Train Loss 0.638587 | Val Loss 0.692508
# Epoch 200 | Train Loss 0.566016 | Val Loss 0.791967
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.6799, MSE = 7.3006e-02
# Theta | Train_2 -> R² = 0.7364, MSE = 5.9968e-02
# Theta | Test_1 -> R² = 0.7194, MSE = 6.4413e-02
# Theta | Test_2 -> R² = 0.9062, MSE = 2.2170e-02
# Theta | Test_3 -> R² = 0.3345, MSE = 2.1857e-01
# Theta | Val -> R² = -2.8994, MSE = 1.2745e+00
# Theta | LSG_1 -> R² = 0.6091, MSE = 1.6188e-01
# Theta | LSG_2 -> R² = -1.8420, MSE = 9.8441e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 0.942685 | Val Loss 0.643731
# Epoch 100 | Train Loss 0.633658 | Val Loss 0.624835
# Epoch 200 | Train Loss 0.556749 | Val Loss 0.835579
# Early stopping at epoch 259
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.6608, MSE = 7.7357e-02
# Theta | Train_2 -> R² = 0.8064, MSE = 4.4046e-02
# Theta | Test_1 -> R² = 0.6896, MSE = 7.1257e-02
# Theta | Test_2 -> R² = 0.8962, MSE = 2.4528e-02
# Theta | Test_3 -> R² = 0.2389, MSE = 2.4995e-01
# Theta | Val -> R² = -1.8112, MSE = 9.1886e-01
# Theta | LSG_1 -> R² = 0.6396, MSE = 1.4924e-01
# Theta | LSG_2 -> R² = -2.2623, MSE = 1.1300e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.993273 | Val Loss 0.672055
# Epoch 100 | Train Loss 0.634439 | Val Loss 0.684684
# Epoch 200 | Train Loss 0.553655 | Val Loss 0.837496
# Early stopping at epoch 257
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7326, MSE = 6.0991e-02
# Theta | Train_2 -> R² = 0.7874, MSE = 4.8370e-02
# Theta | Test_1 -> R² = 0.7473, MSE = 5.7999e-02
# Theta | Test_2 -> R² = 0.9048, MSE = 2.2509e-02
# Theta | Test_3 -> R² = 0.4249, MSE = 1.8888e-01
# Theta | Val -> R² = -1.6087, MSE = 8.5267e-01
# Theta | LSG_1 -> R² = 0.6864, MSE = 1.2985e-01
# Theta | LSG_2 -> R² = -2.4250, MSE = 1.1864e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 0.968985 | Val Loss 0.569136
# Epoch 100 | Train Loss 0.636952 | Val Loss 0.671578
# Epoch 200 | Train Loss 0.558257 | Val Loss 0.859168
# Early stopping at epoch 258
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7848, MSE = 4.9074e-02
# Theta | Train_2 -> R² = 0.7857, MSE = 4.8747e-02
# Theta | Test_1 -> R² = 0.7870, MSE = 4.8893e-02
# Theta | Test_2 -> R² = 0.8891, MSE = 2.6204e-02
# Theta | Test_3 -> R² = -0.0029, MSE = 3.2939e-01
# Theta | Val -> R² = -2.4189, MSE = 1.1175e+00
# Theta | LSG_1 -> R² = 0.6678, MSE = 1.3756e-01
# Theta | LSG_2 -> R² = -2.5627, MSE = 1.2340e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.966646 | Val Loss 0.569143
# Epoch 100 | Train Loss 0.636388 | Val Loss 0.656467
# Epoch 200 | Train Loss 0.560370 | Val Loss 0.789561
# Early stopping at epoch 256
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.6975, MSE = 6.8979e-02
# Theta | Train_2 -> R² = 0.7461, MSE = 5.7756e-02
# Theta | Test_1 -> R² = 0.6699, MSE = 7.5783e-02
# Theta | Test_2 -> R² = 0.8814, MSE = 2.8033e-02
# Theta | Test_3 -> R² = 0.4631, MSE = 1.7633e-01
# Theta | Val -> R² = -2.0139, MSE = 9.8509e-01
# Theta | LSG_1 -> R² = 0.6644, MSE = 1.3897e-01
# Theta | LSG_2 -> R² = -2.1640, MSE = 1.0960e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 0.991350 | Val Loss 0.564659
# Epoch 100 | Train Loss 0.632674 | Val Loss 0.673313
# Epoch 200 | Train Loss 0.558440 | Val Loss 0.814154
# Early stopping at epoch 253
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.7026, MSE = 6.7826e-02
# Theta | Train_2 -> R² = 0.7192, MSE = 6.3887e-02
# Theta | Test_1 -> R² = 0.8008, MSE = 4.5736e-02
# Theta | Test_2 -> R² = 0.8532, MSE = 3.4697e-02
# Theta | Test_3 -> R² = 0.6674, MSE = 1.0922e-01
# Theta | Val -> R² = -0.3335, MSE = 4.3585e-01
# Theta | LSG_1 -> R² = 0.6433, MSE = 1.4774e-01
# Theta | LSG_2 -> R² = -0.6357, MSE = 5.6658e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 1.039617 | Val Loss 0.617573
# Epoch 100 | Train Loss 0.628193 | Val Loss 0.700240
# Epoch 200 | Train Loss 0.558064 | Val Loss 0.818878
# Early stopping at epoch 244
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.7991, MSE = 4.5819e-02
# Theta | Train_2 -> R² = 0.6941, MSE = 6.9601e-02
# Theta | Test_1 -> R² = 0.7401, MSE = 5.9658e-02
# Theta | Test_2 -> R² = 0.8310, MSE = 3.9935e-02
# Theta | Test_3 -> R² = 0.7560, MSE = 8.0133e-02
# Theta | Val -> R² = -2.0132, MSE = 9.8488e-01
# Theta | LSG_1 -> R² = 0.5927, MSE = 1.6866e-01
# Theta | LSG_2 -> R² = -2.5463, MSE = 1.2284e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5803 salvo.
# Epoch 0 | Train Loss 0.999501 | Val Loss 0.612257
# Epoch 100 | Train Loss 0.590282 | Val Loss 0.665043
# Epoch 200 | Train Loss 0.530090 | Val Loss 0.958251
# Early stopping at epoch 275
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.7979, MSE = 4.6089e-02
# Theta | Train_2 -> R² = 0.8150, MSE = 4.2088e-02
# Theta | Test_1 -> R² = 0.7468, MSE = 5.8123e-02
# Theta | Test_2 -> R² = 0.8426, MSE = 3.7203e-02
# Theta | Test_3 -> R² = -2.4134, MSE = 1.1210e+00
# Theta | Val -> R² = -8.9045, MSE = 3.2373e+00
# Theta | LSG_1 -> R² = -0.2678, MSE = 5.2504e-01
# Theta | LSG_2 -> R² = -5.1244, MSE = 2.1214e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8326 salvo.
# Epoch 0 | Train Loss 0.931876 | Val Loss 0.590121
# Epoch 100 | Train Loss 0.647820 | Val Loss 0.487579
# Epoch 200 | Train Loss 0.548334 | Val Loss 0.878989
# Epoch 300 | Train Loss 0.521918 | Val Loss 1.031866
# Early stopping at epoch 303
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.8661, MSE = 3.0540e-02
# Theta | Train_2 -> R² = 0.3336, MSE = 1.5162e-01
# Theta | Test_1 -> R² = 0.8676, MSE = 3.0391e-02
# Theta | Test_2 -> R² = 0.7482, MSE = 5.9511e-02
# Theta | Test_3 -> R² = -0.5158, MSE = 4.9783e-01
# Theta | Val -> R² = -4.4589, MSE = 1.7842e+00
# Theta | LSG_1 -> R² = 0.4067, MSE = 2.4572e-01
# Theta | LSG_2 -> R² = -0.8999, MSE = 6.5808e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8220 salvo.
# Epoch 0 | Train Loss 0.953654 | Val Loss 0.610068
# Epoch 100 | Train Loss 0.592637 | Val Loss 0.593958
# Epoch 200 | Train Loss 0.532192 | Val Loss 0.957330
# Early stopping at epoch 287
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.8858, MSE = 2.6039e-02
# Theta | Train_2 -> R² = -0.0201, MSE = 2.3209e-01
# Theta | Test_1 -> R² = 0.6873, MSE = 7.1772e-02
# Theta | Test_2 -> R² = 0.4040, MSE = 1.4087e-01
# Theta | Test_3 -> R² = 0.4559, MSE = 1.7870e-01
# Theta | Val -> R² = -1.2673, MSE = 7.4106e-01
# Theta | LSG_1 -> R² = 0.0359, MSE = 3.9927e-01
# Theta | LSG_2 -> R² = -0.1168, MSE = 3.8684e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1444 salvo.
# Epoch 0 | Train Loss 0.932780 | Val Loss 0.739032
# Epoch 100 | Train Loss 0.609883 | Val Loss 0.686891
# Epoch 200 | Train Loss 0.530912 | Val Loss 0.986214
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.8493, MSE = 3.4365e-02
# Theta | Train_2 -> R² = 0.7205, MSE = 6.3584e-02
# Theta | Test_1 -> R² = 0.6895, MSE = 7.1284e-02
# Theta | Test_2 -> R² = 0.7890, MSE = 4.9873e-02
# Theta | Test_3 -> R² = 0.4091, MSE = 1.9406e-01
# Theta | Val -> R² = -6.5441, MSE = 2.4658e+00
# Theta | LSG_1 -> R² = -0.0136, MSE = 4.1976e-01
# Theta | LSG_2 -> R² = -4.6922, MSE = 1.9717e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1595 salvo.
# Epoch 0 | Train Loss 1.036336 | Val Loss 0.635751
# Epoch 100 | Train Loss 0.586005 | Val Loss 0.665417
# Epoch 200 | Train Loss 0.526423 | Val Loss 0.988606
# Early stopping at epoch 201
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.4677, MSE = 1.2138e-01
# Theta | Train_2 -> R² = 0.2645, MSE = 1.6734e-01
# Theta | Test_1 -> R² = -0.0587, MSE = 2.4303e-01
# Theta | Test_2 -> R² = 0.6488, MSE = 8.3015e-02
# Theta | Test_3 -> R² = -0.2108, MSE = 3.9765e-01
# Theta | Val -> R² = -8.6543, MSE = 3.1555e+00
# Theta | LSG_1 -> R² = 0.0920, MSE = 3.7604e-01
# Theta | LSG_2 -> R² = -3.5578, MSE = 1.5787e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5803 salvo.
# Epoch 0 | Train Loss 0.936497 | Val Loss 0.660712
# Epoch 100 | Train Loss 0.619506 | Val Loss 0.533430
# Epoch 200 | Train Loss 0.542922 | Val Loss 0.973162
# Early stopping at epoch 292
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed8326.weights.h5
# Theta | Train_1 -> R² = 0.8877, MSE = 2.5600e-02
# Theta | Train_2 -> R² = 0.3849, MSE = 1.3995e-01
# Theta | Test_1 -> R² = 0.8626, MSE = 3.1546e-02
# Theta | Test_2 -> R² = 0.8057, MSE = 4.5922e-02
# Theta | Test_3 -> R² = -1.6676, MSE = 8.7612e-01
# Theta | Val -> R² = -8.9758, MSE = 3.2606e+00
# Theta | LSG_1 -> R² = 0.2260, MSE = 3.2053e-01
# Theta | LSG_2 -> R² = -2.8659, MSE = 1.3391e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8326 salvo.
# Epoch 0 | Train Loss 0.964689 | Val Loss 0.564832
# Epoch 100 | Train Loss 0.623960 | Val Loss 0.614035
# Epoch 200 | Train Loss 0.537675 | Val Loss 0.970870
# Early stopping at epoch 207
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed8220.weights.h5
# Theta | Train_1 -> R² = 0.7493, MSE = 5.7168e-02
# Theta | Train_2 -> R² = 0.6211, MSE = 8.6215e-02
# Theta | Test_1 -> R² = 0.6828, MSE = 7.2804e-02
# Theta | Test_2 -> R² = 0.6884, MSE = 7.3641e-02
# Theta | Test_3 -> R² = 0.4057, MSE = 1.9518e-01
# Theta | Val -> R² = -5.6923, MSE = 2.1874e+00
# Theta | LSG_1 -> R² = 0.1530, MSE = 3.5077e-01
# Theta | LSG_2 -> R² = -3.9465, MSE = 1.7134e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8220 salvo.
# Epoch 0 | Train Loss 0.954768 | Val Loss 0.591724
# Epoch 100 | Train Loss 0.590451 | Val Loss 0.628331
# Epoch 200 | Train Loss 0.529381 | Val Loss 1.011250
# Early stopping at epoch 282
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1444.weights.h5
# Theta | Train_1 -> R² = 0.9431, MSE = 1.2984e-02
# Theta | Train_2 -> R² = 0.5859, MSE = 9.4213e-02
# Theta | Test_1 -> R² = 0.5648, MSE = 9.9901e-02
# Theta | Test_2 -> R² = 0.4694, MSE = 1.2540e-01
# Theta | Test_3 -> R² = -2.6501, MSE = 1.1988e+00
# Theta | Val -> R² = -10.4474, MSE = 3.7416e+00
# Theta | LSG_1 -> R² = -0.6225, MSE = 6.7192e-01
# Theta | LSG_2 -> R² = -4.2472, MSE = 1.8175e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1444 salvo.
# Epoch 0 | Train Loss 0.941643 | Val Loss 0.658243
# Epoch 100 | Train Loss 0.636196 | Val Loss 0.560812
# Epoch 200 | Train Loss 0.535637 | Val Loss 0.955430
# Early stopping at epoch 207
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1595.weights.h5
# Theta | Train_1 -> R² = 0.8750, MSE = 2.8515e-02
# Theta | Train_2 -> R² = 0.6751, MSE = 7.3929e-02
# Theta | Test_1 -> R² = 0.5393, MSE = 1.0575e-01
# Theta | Test_2 -> R² = 0.6657, MSE = 7.9003e-02
# Theta | Test_3 -> R² = 0.2132, MSE = 2.5839e-01
# Theta | Val -> R² = -8.2500, MSE = 3.0234e+00
# Theta | LSG_1 -> R² = -0.0216, MSE = 4.2306e-01
# Theta | LSG_2 -> R² = -5.0520, MSE = 2.0963e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1595 salvo.
# Epoch 0 | Train Loss 0.970307 | Val Loss 0.636801
# Epoch 100 | Train Loss 0.584355 | Val Loss 0.676922
# Epoch 200 | Train Loss 0.526994 | Val Loss 1.012145
# Early stopping at epoch 210
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed5803.weights.h5
# Theta | Train_1 -> R² = 0.8775, MSE = 2.7942e-02
# Theta | Train_2 -> R² = 0.6815, MSE = 7.2460e-02
# Theta | Test_1 -> R² = 0.6604, MSE = 7.7963e-02
# Theta | Test_2 -> R² = 0.8346, MSE = 3.9102e-02
# Theta | Test_3 -> R² = -0.2233, MSE = 4.0177e-01
# Theta | Val -> R² = -7.1426, MSE = 2.6614e+00
# Theta | LSG_1 -> R² = 0.3916, MSE = 2.5194e-01
# Theta | LSG_2 -> R² = -2.9326, MSE = 1.3622e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5803 salvo.

# %%
with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
