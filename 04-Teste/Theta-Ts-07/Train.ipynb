# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 7
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
os.makedirs("./scalers", exist_ok=True)

NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)
    
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 1)
# Dimensão da entrada: (1264, 7, 4)
# Dimensão da saida: (1264, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 1)
# Dimensão da entrada fisica : (1945,)
# Dimensão da entrada fisica: (1945,)

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.architecture = architecture  
        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):
        x = inputs
        for rnn in self.rnn_layers:
            x = rnn(x)
        return self.out_layer(x)

# %%
def PINN_to_RNN(pinn_model):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    # recria arquitetura
    for layer in pinn_model.rnn_layers:
        model.add(
            tf.keras.layers.SimpleRNN(
                units=layer.units,
                activation='tanh',
                return_sequences=layer.return_sequences
            )
        )

    # camada final
    model.add(
        tf.keras.layers.Dense(
            pinn_model.out_layer.units,
            activation='linear'
        )
    )

    model.build((None, TIME_STEPS, INPUT_SIZE))

    model.set_weights(pinn_model.get_weights())

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_denorm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": metrics[name]["R2_Train_1"],
            f"MSE_Train_1_{name}": metrics[name]["MSE_Train_1"],
            f"R2_Train_2_{name}": metrics[name]["R2_Train_2"],
            f"MSE_Train_2_{name}": metrics[name]["MSE_Train_2"],
            f"R2_Val_{name}": metrics[name]["R2_Val"],
            f"MSE_Val_{name}": metrics[name]["MSE_Val"],
            f"R2_Test_1_{name}": metrics[name]["R2_Test_1"],
            f"MSE_Test_1_{name}": metrics[name]["MSE_Test_1"],
            f"R2_Test_2_{name}": metrics[name]["R2_Test_2"],
            f"MSE_Test_2_{name}": metrics[name]["MSE_Test_2"],
            f"R2_Test_3_{name}": metrics[name]["R2_Test_3"],
            f"MSE_Test_3_{name}": metrics[name]["MSE_Test_3"],
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
import os

def ExportModel(pinn_model, model_name):

    os.makedirs("weights", exist_ok=True)

    rnn_model = PINN_to_RNN(pinn_model)

    weights_path = f"weights/{model_name}.weights.h5"

    rnn_model.save_weights(weights_path)

    print(f"Modelo salvo em:\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        pinn_model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )
        pinn_model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(pinn_model.trainable_variables)

        TrainPINN(
            pinn_model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(pinn_model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(pinn_model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.969800 | Val Loss 0.784878
# Epoch 100 | Train Loss 0.770170 | Val Loss 0.598866
# Epoch 200 | Train Loss 0.680603 | Val Loss 0.580835
# Epoch 300 | Train Loss 0.644724 | Val Loss 0.621002
# Early stopping at epoch 369
# Modelo salvo em:
# weights/model_arch16_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7674, MSE = 5.3156e-02
# Theta | Train_2 -> R² = 0.7753, MSE = 5.0937e-02
# Theta | Test_1 -> R² = 0.7958, MSE = 4.6980e-02
# Theta | Test_2 -> R² = 0.8752, MSE = 2.9395e-02
# Theta | Test_3 -> R² = 0.6115, MSE = 1.2777e-01
# Theta | Val -> R² = 0.5496, MSE = 1.4739e-01
# Theta | LSG_1 -> R² = 0.5742, MSE = 1.7491e-01
# Theta | LSG_2 -> R² = -0.3733, MSE = 4.7064e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.014943 | Val Loss 0.844300
# Epoch 100 | Train Loss 0.774547 | Val Loss 0.578753
# Epoch 200 | Train Loss 0.694980 | Val Loss 0.568912
# Early stopping at epoch 268
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7167, MSE = 6.4731e-02
# Theta | Train_2 -> R² = 0.3009, MSE = 1.5851e-01
# Theta | Test_1 -> R² = 0.4954, MSE = 1.1608e-01
# Theta | Test_2 -> R² = 0.7955, MSE = 4.8168e-02
# Theta | Test_3 -> R² = 0.6136, MSE = 1.2705e-01
# Theta | Val -> R² = -3.0583, MSE = 1.3282e+00
# Theta | LSG_1 -> R² = 0.7386, MSE = 1.0739e-01
# Theta | LSG_2 -> R² = -0.4727, MSE = 5.0474e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.994879 | Val Loss 0.845154
# Epoch 100 | Train Loss 0.767542 | Val Loss 0.631279
# Epoch 200 | Train Loss 0.713706 | Val Loss 0.605132
# Epoch 300 | Train Loss 0.667241 | Val Loss 0.632974
# Early stopping at epoch 399
# Modelo salvo em:
# weights/model_arch16_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.8366, MSE = 3.7341e-02
# Theta | Train_2 -> R² = 0.7479, MSE = 5.7163e-02
# Theta | Test_1 -> R² = 0.8056, MSE = 4.4713e-02
# Theta | Test_2 -> R² = 0.8699, MSE = 3.0651e-02
# Theta | Test_3 -> R² = 0.1009, MSE = 2.9564e-01
# Theta | Val -> R² = -4.2165, MSE = 1.7072e+00
# Theta | LSG_1 -> R² = 0.2246, MSE = 3.1852e-01
# Theta | LSG_2 -> R² = -2.1533, MSE = 1.0807e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.987613 | Val Loss 0.816671
# Epoch 100 | Train Loss 0.769230 | Val Loss 0.588677
# Epoch 200 | Train Loss 0.677008 | Val Loss 0.607437
# Early stopping at epoch 282
# Modelo salvo em:
# weights/model_arch16_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.7836, MSE = 4.9448e-02
# Theta | Train_2 -> R² = 0.4548, MSE = 1.2362e-01
# Theta | Test_1 -> R² = 0.5674, MSE = 9.9511e-02
# Theta | Test_2 -> R² = 0.8453, MSE = 3.6447e-02
# Theta | Test_3 -> R² = 0.3830, MSE = 2.0288e-01
# Theta | Val -> R² = -5.3387, MSE = 2.0745e+00
# Theta | LSG_1 -> R² = 0.6286, MSE = 1.5256e-01
# Theta | LSG_2 -> R² = -1.2429, MSE = 7.6870e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 0.997304 | Val Loss 0.740454
# Epoch 100 | Train Loss 0.864696 | Val Loss 0.560509
# Epoch 200 | Train Loss 0.771684 | Val Loss 0.593467
# Early stopping at epoch 299
# Modelo salvo em:
# weights/model_arch16_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7883, MSE = 4.8378e-02
# Theta | Train_2 -> R² = 0.6232, MSE = 8.5422e-02
# Theta | Test_1 -> R² = 0.6264, MSE = 8.5935e-02
# Theta | Test_2 -> R² = 0.8841, MSE = 2.7297e-02
# Theta | Test_3 -> R² = 0.6084, MSE = 1.2878e-01
# Theta | Val -> R² = -3.1948, MSE = 1.3729e+00
# Theta | LSG_1 -> R² = 0.6025, MSE = 1.6328e-01
# Theta | LSG_2 -> R² = -1.0605, MSE = 7.0619e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 0.978893 | Val Loss 0.837182
# Epoch 100 | Train Loss 0.734769 | Val Loss 0.579047
# Epoch 200 | Train Loss 0.666421 | Val Loss 0.602402
# Early stopping at epoch 258
# Modelo salvo em:
# weights/model_arch16_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7682, MSE = 5.2967e-02
# Theta | Train_2 -> R² = 0.4586, MSE = 1.2274e-01
# Theta | Test_1 -> R² = 0.4030, MSE = 1.3733e-01
# Theta | Test_2 -> R² = 0.8644, MSE = 3.1929e-02
# Theta | Test_3 -> R² = 0.4187, MSE = 1.9117e-01
# Theta | Val -> R² = -5.4204, MSE = 2.1012e+00
# Theta | LSG_1 -> R² = 0.5974, MSE = 1.6538e-01
# Theta | LSG_2 -> R² = -1.7528, MSE = 9.4344e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 0.990434 | Val Loss 0.825841
# Epoch 100 | Train Loss 0.759692 | Val Loss 0.592776
# Epoch 200 | Train Loss 0.685367 | Val Loss 0.590026
# Early stopping at epoch 265
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7211, MSE = 6.3739e-02
# Theta | Train_2 -> R² = 0.3437, MSE = 1.4881e-01
# Theta | Test_1 -> R² = 0.4457, MSE = 1.2751e-01
# Theta | Test_2 -> R² = 0.8321, MSE = 3.9538e-02
# Theta | Test_3 -> R² = 0.3156, MSE = 2.2506e-01
# Theta | Val -> R² = -0.8717, MSE = 6.1255e-01
# Theta | LSG_1 -> R² = 0.7230, MSE = 1.1377e-01
# Theta | LSG_2 -> R² = -0.1429, MSE = 3.9169e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 0.995610 | Val Loss 0.841313
# Epoch 100 | Train Loss 0.778531 | Val Loss 0.607173
# Epoch 200 | Train Loss 0.705435 | Val Loss 0.576523
# Epoch 300 | Train Loss 0.667709 | Val Loss 0.533013
# Epoch 400 | Train Loss 0.623547 | Val Loss 0.616755
# Epoch 500 | Train Loss 0.605924 | Val Loss 0.694193
# Early stopping at epoch 509
# Modelo salvo em:
# weights/model_arch16_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.8562, MSE = 3.2871e-02
# Theta | Train_2 -> R² = 0.7024, MSE = 6.7481e-02
# Theta | Test_1 -> R² = 0.7065, MSE = 6.7521e-02
# Theta | Test_2 -> R² = 0.7326, MSE = 6.2983e-02
# Theta | Test_3 -> R² = 0.7173, MSE = 9.2969e-02
# Theta | Val -> R² = 0.3936, MSE = 1.9846e-01
# Theta | LSG_1 -> R² = 0.5980, MSE = 1.6515e-01
# Theta | LSG_2 -> R² = -0.7385, MSE = 5.9582e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.987554 | Val Loss 0.784564
# Epoch 100 | Train Loss 0.775619 | Val Loss 0.583385
# Epoch 200 | Train Loss 0.694094 | Val Loss 0.589125
# Epoch 300 | Train Loss 0.649121 | Val Loss 0.598787
# Early stopping at epoch 364
# Modelo salvo em:
# weights/model_arch16_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.7203, MSE = 6.3923e-02
# Theta | Train_2 -> R² = 0.7779, MSE = 5.0352e-02
# Theta | Test_1 -> R² = 0.6838, MSE = 7.2732e-02
# Theta | Test_2 -> R² = 0.8830, MSE = 2.7550e-02
# Theta | Test_3 -> R² = 0.1930, MSE = 2.6536e-01
# Theta | Val -> R² = -2.3083, MSE = 1.0827e+00
# Theta | LSG_1 -> R² = 0.5743, MSE = 1.7486e-01
# Theta | LSG_2 -> R² = -1.3157, MSE = 7.9365e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 0.971653 | Val Loss 0.747035
# Epoch 100 | Train Loss 0.773227 | Val Loss 0.577929
# Epoch 200 | Train Loss 0.681457 | Val Loss 0.566629
# Early stopping at epoch 278
# Modelo salvo em:
# weights/model_arch16_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7793, MSE = 5.0424e-02
# Theta | Train_2 -> R² = 0.4520, MSE = 1.2425e-01
# Theta | Test_1 -> R² = 0.6344, MSE = 8.4092e-02
# Theta | Test_2 -> R² = 0.8459, MSE = 3.6296e-02
# Theta | Test_3 -> R² = 0.5560, MSE = 1.4602e-01
# Theta | Val -> R² = -4.0803, MSE = 1.6627e+00
# Theta | LSG_1 -> R² = 0.6293, MSE = 1.5227e-01
# Theta | LSG_2 -> R² = -1.1275, MSE = 7.2913e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 0.976185 | Val Loss 0.823709
# Epoch 100 | Train Loss 0.756632 | Val Loss 0.573977
# Epoch 200 | Train Loss 0.710577 | Val Loss 0.606332
# Early stopping at epoch 261
# Modelo salvo em:
# weights/model_arch16_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.6814, MSE = 7.2811e-02
# Theta | Train_2 -> R² = 0.3426, MSE = 1.4904e-01
# Theta | Test_1 -> R² = 0.0141, MSE = 2.2678e-01
# Theta | Test_2 -> R² = 0.8372, MSE = 3.8349e-02
# Theta | Test_3 -> R² = 0.6201, MSE = 1.2492e-01
# Theta | Val -> R² = -6.5778, MSE = 2.4800e+00
# Theta | LSG_1 -> R² = 0.3245, MSE = 2.7750e-01
# Theta | LSG_2 -> R² = -3.1025, MSE = 1.4060e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 0.995952 | Val Loss 0.809078
# Epoch 100 | Train Loss 0.768147 | Val Loss 0.570509
# Epoch 200 | Train Loss 0.723363 | Val Loss 0.625469
# Early stopping at epoch 265
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7089, MSE = 6.6524e-02
# Theta | Train_2 -> R² = 0.4710, MSE = 1.1995e-01
# Theta | Test_1 -> R² = 0.2253, MSE = 1.7820e-01
# Theta | Test_2 -> R² = 0.8549, MSE = 3.4169e-02
# Theta | Test_3 -> R² = 0.6321, MSE = 1.2098e-01
# Theta | Val -> R² = -6.2011, MSE = 2.3567e+00
# Theta | LSG_1 -> R² = 0.1654, MSE = 3.4284e-01
# Theta | LSG_2 -> R² = -3.3614, MSE = 1.4947e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.970131 | Val Loss 0.817405
# Epoch 100 | Train Loss 0.765840 | Val Loss 0.563462
# Epoch 200 | Train Loss 0.714000 | Val Loss 0.610456
# Early stopping at epoch 268
# Modelo salvo em:
# weights/model_arch16_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.7257, MSE = 6.2691e-02
# Theta | Train_2 -> R² = 0.5163, MSE = 1.0966e-01
# Theta | Test_1 -> R² = 0.4413, MSE = 1.2851e-01
# Theta | Test_2 -> R² = 0.8703, MSE = 3.0551e-02
# Theta | Test_3 -> R² = 0.5907, MSE = 1.3459e-01
# Theta | Val -> R² = -4.6878, MSE = 1.8615e+00
# Theta | LSG_1 -> R² = 0.5068, MSE = 2.0259e-01
# Theta | LSG_2 -> R² = -1.8951, MSE = 9.9220e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.966093 | Val Loss 0.795836
# Epoch 100 | Train Loss 0.764643 | Val Loss 0.572328
# Epoch 200 | Train Loss 0.720240 | Val Loss 0.625549
# Early stopping at epoch 257
# Modelo salvo em:
# weights/model_arch16_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.6379, MSE = 8.2747e-02
# Theta | Train_2 -> R² = 0.4642, MSE = 1.2148e-01
# Theta | Test_1 -> R² = 0.0655, MSE = 2.1496e-01
# Theta | Test_2 -> R² = 0.8610, MSE = 3.2746e-02
# Theta | Test_3 -> R² = 0.5036, MSE = 1.6323e-01
# Theta | Val -> R² = -7.1547, MSE = 2.6688e+00
# Theta | LSG_1 -> R² = 0.1821, MSE = 3.3599e-01
# Theta | LSG_2 -> R² = -3.3219, MSE = 1.4812e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 0.929703 | Val Loss 0.720444
# Epoch 100 | Train Loss 0.742639 | Val Loss 0.595363
# Epoch 200 | Train Loss 0.710479 | Val Loss 0.614589
# Early stopping at epoch 247
# Modelo salvo em:
# weights/model_arch16_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.6509, MSE = 7.9767e-02
# Theta | Train_2 -> R² = 0.4627, MSE = 1.2183e-01
# Theta | Test_1 -> R² = 0.0238, MSE = 2.2455e-01
# Theta | Test_2 -> R² = 0.8532, MSE = 3.4589e-02
# Theta | Test_3 -> R² = 0.4843, MSE = 1.6957e-01
# Theta | Val -> R² = -7.7661, MSE = 2.8689e+00
# Theta | LSG_1 -> R² = 0.0436, MSE = 3.9286e-01
# Theta | LSG_2 -> R² = -3.9299, MSE = 1.6896e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 0.991628 | Val Loss 0.856360
# Epoch 100 | Train Loss 0.771350 | Val Loss 0.566673
# Epoch 200 | Train Loss 0.720904 | Val Loss 0.617368
# Early stopping at epoch 275
# Modelo salvo em:
# weights/model_arch16_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7272, MSE = 6.2335e-02
# Theta | Train_2 -> R² = 0.5043, MSE = 1.1239e-01
# Theta | Test_1 -> R² = 0.2670, MSE = 1.6860e-01
# Theta | Test_2 -> R² = 0.8638, MSE = 3.2078e-02
# Theta | Test_3 -> R² = 0.5073, MSE = 1.6202e-01
# Theta | Val -> R² = -6.7443, MSE = 2.5345e+00
# Theta | LSG_1 -> R² = 0.3054, MSE = 2.8532e-01
# Theta | LSG_2 -> R² = -2.9273, MSE = 1.3460e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 0.987499 | Val Loss 0.837761
# Epoch 100 | Train Loss 0.748377 | Val Loss 0.573783
# Epoch 200 | Train Loss 0.709581 | Val Loss 0.600303
# Early stopping at epoch 268
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7343, MSE = 6.0714e-02
# Theta | Train_2 -> R² = 0.5047, MSE = 1.1231e-01
# Theta | Test_1 -> R² = 0.3770, MSE = 1.4330e-01
# Theta | Test_2 -> R² = 0.8671, MSE = 3.1293e-02
# Theta | Test_3 -> R² = 0.5385, MSE = 1.5176e-01
# Theta | Val -> R² = -5.9362, MSE = 2.2700e+00
# Theta | LSG_1 -> R² = 0.4676, MSE = 2.1869e-01
# Theta | LSG_2 -> R² = -2.3985, MSE = 1.1647e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 0.977141 | Val Loss 0.829282
# Epoch 100 | Train Loss 0.760883 | Val Loss 0.573274
# Epoch 200 | Train Loss 0.711245 | Val Loss 0.621125
# Early stopping at epoch 271
# Modelo salvo em:
# weights/model_arch16_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.7450, MSE = 5.8274e-02
# Theta | Train_2 -> R² = 0.5202, MSE = 1.0877e-01
# Theta | Test_1 -> R² = 0.4260, MSE = 1.3203e-01
# Theta | Test_2 -> R² = 0.8725, MSE = 3.0040e-02
# Theta | Test_3 -> R² = 0.5658, MSE = 1.4279e-01
# Theta | Val -> R² = -5.7339, MSE = 2.2038e+00
# Theta | LSG_1 -> R² = 0.4206, MSE = 2.3802e-01
# Theta | LSG_2 -> R² = -2.3184, MSE = 1.1373e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.944898 | Val Loss 0.768243
# Epoch 100 | Train Loss 0.744417 | Val Loss 0.580637
# Epoch 200 | Train Loss 0.702282 | Val Loss 0.610901
# Early stopping at epoch 254
# Modelo salvo em:
# weights/model_arch16_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.6989, MSE = 6.8807e-02
# Theta | Train_2 -> R² = 0.5180, MSE = 1.0929e-01
# Theta | Test_1 -> R² = 0.2367, MSE = 1.7558e-01
# Theta | Test_2 -> R² = 0.8629, MSE = 3.2295e-02
# Theta | Test_3 -> R² = 0.4695, MSE = 1.7446e-01
# Theta | Val -> R² = -6.9040, MSE = 2.5868e+00
# Theta | LSG_1 -> R² = 0.2354, MSE = 3.1406e-01
# Theta | LSG_2 -> R² = -3.2139, MSE = 1.4442e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 0.938790 | Val Loss 0.766887
# Epoch 100 | Train Loss 0.753939 | Val Loss 0.580820
# Epoch 200 | Train Loss 0.707979 | Val Loss 0.601352
# Early stopping at epoch 260
# Modelo salvo em:
# weights/model_arch16_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7385, MSE = 5.9761e-02
# Theta | Train_2 -> R² = 0.5145, MSE = 1.1007e-01
# Theta | Test_1 -> R² = 0.4828, MSE = 1.1896e-01
# Theta | Test_2 -> R² = 0.8744, MSE = 2.9583e-02
# Theta | Test_3 -> R² = 0.4808, MSE = 1.7072e-01
# Theta | Val -> R² = -5.2109, MSE = 2.0327e+00
# Theta | LSG_1 -> R² = 0.5353, MSE = 1.9087e-01
# Theta | LSG_2 -> R² = -1.7993, MSE = 9.5937e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 0.993835 | Val Loss 0.812970
# Epoch 100 | Train Loss 0.706332 | Val Loss 0.596483
# Epoch 200 | Train Loss 0.659557 | Val Loss 0.613728
# Early stopping at epoch 234
# Modelo salvo em:
# weights/model_arch32_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7328, MSE = 6.1061e-02
# Theta | Train_2 -> R² = 0.4143, MSE = 1.3279e-01
# Theta | Test_1 -> R² = 0.4864, MSE = 1.1814e-01
# Theta | Test_2 -> R² = 0.8319, MSE = 3.9585e-02
# Theta | Test_3 -> R² = 0.4978, MSE = 1.6513e-01
# Theta | Val -> R² = -4.6094, MSE = 1.8358e+00
# Theta | LSG_1 -> R² = 0.6125, MSE = 1.5919e-01
# Theta | LSG_2 -> R² = -1.4907, MSE = 8.5361e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.020318 | Val Loss 0.847866
# Epoch 100 | Train Loss 0.724318 | Val Loss 0.589387
# Epoch 200 | Train Loss 0.674187 | Val Loss 0.574665
# Early stopping at epoch 231
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.6893, MSE = 7.0996e-02
# Theta | Train_2 -> R² = 0.5237, MSE = 1.0800e-01
# Theta | Test_1 -> R² = 0.4632, MSE = 1.2347e-01
# Theta | Test_2 -> R² = 0.8940, MSE = 2.4966e-02
# Theta | Test_3 -> R² = 0.4961, MSE = 1.6569e-01
# Theta | Val -> R² = -4.8396, MSE = 1.9111e+00
# Theta | LSG_1 -> R² = 0.3967, MSE = 2.4783e-01
# Theta | LSG_2 -> R² = -2.1703, MSE = 1.0865e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.970832 | Val Loss 0.774296
# Epoch 100 | Train Loss 0.703876 | Val Loss 0.588329
# Epoch 200 | Train Loss 0.626076 | Val Loss 0.633941
# Early stopping at epoch 234
# Modelo salvo em:
# weights/model_arch32_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.6098, MSE = 8.9173e-02
# Theta | Train_2 -> R² = 0.5347, MSE = 1.0549e-01
# Theta | Test_1 -> R² = 0.1329, MSE = 1.9944e-01
# Theta | Test_2 -> R² = 0.8471, MSE = 3.6010e-02
# Theta | Test_3 -> R² = 0.1254, MSE = 2.8761e-01
# Theta | Val -> R² = -7.8299, MSE = 2.8898e+00
# Theta | LSG_1 -> R² = 0.1119, MSE = 3.6480e-01
# Theta | LSG_2 -> R² = -3.7530, MSE = 1.6290e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.993987 | Val Loss 0.822902
# Epoch 100 | Train Loss 0.714107 | Val Loss 0.594317
# Epoch 200 | Train Loss 0.644885 | Val Loss 0.663650
# Early stopping at epoch 239
# Modelo salvo em:
# weights/model_arch32_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.6935, MSE = 7.0037e-02
# Theta | Train_2 -> R² = 0.4147, MSE = 1.3269e-01
# Theta | Test_1 -> R² = 0.5398, MSE = 1.0586e-01
# Theta | Test_2 -> R² = 0.8411, MSE = 3.7440e-02
# Theta | Test_3 -> R² = 0.6060, MSE = 1.2958e-01
# Theta | Val -> R² = -2.4584, MSE = 1.1319e+00
# Theta | LSG_1 -> R² = 0.7177, MSE = 1.1597e-01
# Theta | LSG_2 -> R² = -0.5097, MSE = 5.1741e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 0.996153 | Val Loss 0.826285
# Epoch 100 | Train Loss 0.708786 | Val Loss 0.593218
# Epoch 200 | Train Loss 0.648182 | Val Loss 0.661946
# Early stopping at epoch 231
# Modelo salvo em:
# weights/model_arch32_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.6434, MSE = 8.1484e-02
# Theta | Train_2 -> R² = 0.3384, MSE = 1.5000e-01
# Theta | Test_1 -> R² = 0.4036, MSE = 1.3718e-01
# Theta | Test_2 -> R² = 0.8003, MSE = 4.7049e-02
# Theta | Test_3 -> R² = 0.5491, MSE = 1.4826e-01
# Theta | Val -> R² = -4.0891, MSE = 1.6655e+00
# Theta | LSG_1 -> R² = 0.6255, MSE = 1.5385e-01
# Theta | LSG_2 -> R² = -1.2249, MSE = 7.6253e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 0.995833 | Val Loss 0.818965
# Epoch 100 | Train Loss 0.704587 | Val Loss 0.584643
# Epoch 200 | Train Loss 0.665325 | Val Loss 0.570956
# Early stopping at epoch 234
# Modelo salvo em:
# weights/model_arch32_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.6941, MSE = 6.9903e-02
# Theta | Train_2 -> R² = 0.3978, MSE = 1.3654e-01
# Theta | Test_1 -> R² = 0.3865, MSE = 1.4111e-01
# Theta | Test_2 -> R² = 0.8219, MSE = 4.1962e-02
# Theta | Test_3 -> R² = 0.5813, MSE = 1.3767e-01
# Theta | Val -> R² = -4.0849, MSE = 1.6642e+00
# Theta | LSG_1 -> R² = 0.6250, MSE = 1.5404e-01
# Theta | LSG_2 -> R² = -1.4904, MSE = 8.5350e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 1.009761 | Val Loss 0.815983
# Epoch 100 | Train Loss 0.711359 | Val Loss 0.597783
# Epoch 200 | Train Loss 0.677436 | Val Loss 0.568902
# Early stopping at epoch 237
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7817, MSE = 4.9892e-02
# Theta | Train_2 -> R² = 0.5137, MSE = 1.1026e-01
# Theta | Test_1 -> R² = 0.5689, MSE = 9.9171e-02
# Theta | Test_2 -> R² = 0.8659, MSE = 3.1576e-02
# Theta | Test_3 -> R² = 0.5818, MSE = 1.3751e-01
# Theta | Val -> R² = -3.9345, MSE = 1.6149e+00
# Theta | LSG_1 -> R² = 0.6546, MSE = 1.4187e-01
# Theta | LSG_2 -> R² = -1.3987, MSE = 8.2210e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 0.991287 | Val Loss 0.839145
# Epoch 100 | Train Loss 0.705756 | Val Loss 0.587215
# Epoch 200 | Train Loss 0.645000 | Val Loss 0.654965
# Early stopping at epoch 237
# Modelo salvo em:
# weights/model_arch32_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.7677, MSE = 5.3083e-02
# Theta | Train_2 -> R² = 0.4296, MSE = 1.2933e-01
# Theta | Test_1 -> R² = 0.5443, MSE = 1.0482e-01
# Theta | Test_2 -> R² = 0.8543, MSE = 3.4318e-02
# Theta | Test_3 -> R² = 0.5815, MSE = 1.3763e-01
# Theta | Val -> R² = -4.0105, MSE = 1.6398e+00
# Theta | LSG_1 -> R² = 0.6733, MSE = 1.3420e-01
# Theta | LSG_2 -> R² = -1.1637, MSE = 7.4155e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.990741 | Val Loss 0.774426
# Epoch 100 | Train Loss 0.718156 | Val Loss 0.610959
# Epoch 200 | Train Loss 0.665198 | Val Loss 0.656047
# Early stopping at epoch 237
# Modelo salvo em:
# weights/model_arch32_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.7487, MSE = 5.7426e-02
# Theta | Train_2 -> R² = 0.3181, MSE = 1.5460e-01
# Theta | Test_1 -> R² = 0.5820, MSE = 9.6148e-02
# Theta | Test_2 -> R² = 0.7812, MSE = 5.1527e-02
# Theta | Test_3 -> R² = 0.5778, MSE = 1.3882e-01
# Theta | Val -> R² = -1.6226, MSE = 8.5832e-01
# Theta | LSG_1 -> R² = 0.7299, MSE = 1.1096e-01
# Theta | LSG_2 -> R² = -0.3109, MSE = 4.4927e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 0.985393 | Val Loss 0.807958
# Epoch 100 | Train Loss 0.697621 | Val Loss 0.575464
# Epoch 200 | Train Loss 0.653210 | Val Loss 0.661714
# Early stopping at epoch 233
# Modelo salvo em:
# weights/model_arch32_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7590, MSE = 5.5069e-02
# Theta | Train_2 -> R² = 0.4729, MSE = 1.1951e-01
# Theta | Test_1 -> R² = 0.5537, MSE = 1.0266e-01
# Theta | Test_2 -> R² = 0.8676, MSE = 3.1180e-02
# Theta | Test_3 -> R² = 0.6221, MSE = 1.2428e-01
# Theta | Val -> R² = -3.4556, MSE = 1.4582e+00
# Theta | LSG_1 -> R² = 0.6318, MSE = 1.5126e-01
# Theta | LSG_2 -> R² = -1.2780, MSE = 7.8074e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 1.004778 | Val Loss 0.832763
# Epoch 100 | Train Loss 0.728594 | Val Loss 0.617217
# Epoch 200 | Train Loss 0.670993 | Val Loss 0.577645
# Early stopping at epoch 227
# Modelo salvo em:
# weights/model_arch32_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.6342, MSE = 8.3598e-02
# Theta | Train_2 -> R² = 0.4481, MSE = 1.2513e-01
# Theta | Test_1 -> R² = 0.0388, MSE = 2.2109e-01
# Theta | Test_2 -> R² = 0.8727, MSE = 2.9978e-02
# Theta | Test_3 -> R² = 0.4944, MSE = 1.6626e-01
# Theta | Val -> R² = -6.9899, MSE = 2.6149e+00
# Theta | LSG_1 -> R² = 0.0489, MSE = 3.9070e-01
# Theta | LSG_2 -> R² = -3.7312, MSE = 1.6215e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.094893 | Val Loss 0.872793
# Epoch 100 | Train Loss 0.763706 | Val Loss 0.587261
# Epoch 200 | Train Loss 0.697678 | Val Loss 0.634805
# Early stopping at epoch 235
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7559, MSE = 5.5780e-02
# Theta | Train_2 -> R² = 0.5037, MSE = 1.1253e-01
# Theta | Test_1 -> R² = 0.3158, MSE = 1.5739e-01
# Theta | Test_2 -> R² = 0.8719, MSE = 3.0172e-02
# Theta | Test_3 -> R² = 0.5440, MSE = 1.4994e-01
# Theta | Val -> R² = -6.3795, MSE = 2.4151e+00
# Theta | LSG_1 -> R² = 0.1862, MSE = 3.3429e-01
# Theta | LSG_2 -> R² = -3.4050, MSE = 1.5097e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.972865 | Val Loss 0.819205
# Epoch 100 | Train Loss 0.717867 | Val Loss 0.644716
# Epoch 200 | Train Loss 0.645662 | Val Loss 0.667806
# Early stopping at epoch 233
# Modelo salvo em:
# weights/model_arch32_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.5436, MSE = 1.0430e-01
# Theta | Train_2 -> R² = 0.4493, MSE = 1.2485e-01
# Theta | Test_1 -> R² = -0.2948, MSE = 2.9783e-01
# Theta | Test_2 -> R² = 0.8483, MSE = 3.5744e-02
# Theta | Test_3 -> R² = 0.4129, MSE = 1.9306e-01
# Theta | Val -> R² = -8.7237, MSE = 3.1823e+00
# Theta | LSG_1 -> R² = -0.1802, MSE = 4.8479e-01
# Theta | LSG_2 -> R² = -4.7761, MSE = 1.9796e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.995944 | Val Loss 0.819562
# Epoch 100 | Train Loss 0.722589 | Val Loss 0.626439
# Epoch 200 | Train Loss 0.645198 | Val Loss 0.684547
# Early stopping at epoch 230
# Modelo salvo em:
# weights/model_arch32_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.7147, MSE = 6.5201e-02
# Theta | Train_2 -> R² = 0.4776, MSE = 1.1844e-01
# Theta | Test_1 -> R² = 0.3020, MSE = 1.6055e-01
# Theta | Test_2 -> R² = 0.8927, MSE = 2.5279e-02
# Theta | Test_3 -> R² = 0.5672, MSE = 1.4233e-01
# Theta | Val -> R² = -5.5738, MSE = 2.1514e+00
# Theta | LSG_1 -> R² = 0.3097, MSE = 2.8358e-01
# Theta | LSG_2 -> R² = -2.8404, MSE = 1.3162e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 0.972075 | Val Loss 0.797582
# Epoch 100 | Train Loss 0.714507 | Val Loss 0.634852
# Epoch 200 | Train Loss 0.645574 | Val Loss 0.612692
# Early stopping at epoch 228
# Modelo salvo em:
# weights/model_arch32_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.6705, MSE = 7.5296e-02
# Theta | Train_2 -> R² = 0.4985, MSE = 1.1370e-01
# Theta | Test_1 -> R² = 0.1258, MSE = 2.0107e-01
# Theta | Test_2 -> R² = 0.8887, MSE = 2.6226e-02
# Theta | Test_3 -> R² = 0.4530, MSE = 1.7989e-01
# Theta | Val -> R² = -6.9349, MSE = 2.5969e+00
# Theta | LSG_1 -> R² = 0.1273, MSE = 3.5849e-01
# Theta | LSG_2 -> R² = -3.6128, MSE = 1.5809e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 1.000038 | Val Loss 0.840943
# Epoch 100 | Train Loss 0.724391 | Val Loss 0.633294
# Epoch 200 | Train Loss 0.651605 | Val Loss 0.603075
# Early stopping at epoch 228
# Modelo salvo em:
# weights/model_arch32_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.6603, MSE = 7.7630e-02
# Theta | Train_2 -> R² = 0.3830, MSE = 1.3989e-01
# Theta | Test_1 -> R² = 0.2607, MSE = 1.7005e-01
# Theta | Test_2 -> R² = 0.8589, MSE = 3.3229e-02
# Theta | Test_3 -> R² = 0.4490, MSE = 1.8120e-01
# Theta | Val -> R² = -5.5841, MSE = 2.1548e+00
# Theta | LSG_1 -> R² = 0.5411, MSE = 1.8849e-01
# Theta | LSG_2 -> R² = -2.0114, MSE = 1.0321e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 1.067807 | Val Loss 0.913318
# Epoch 100 | Train Loss 0.729101 | Val Loss 0.604602
# Epoch 200 | Train Loss 0.651951 | Val Loss 0.703517
# Early stopping at epoch 248
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7586, MSE = 5.5156e-02
# Theta | Train_2 -> R² = 0.6432, MSE = 8.0900e-02
# Theta | Test_1 -> R² = 0.2201, MSE = 1.7939e-01
# Theta | Test_2 -> R² = 0.8508, MSE = 3.5154e-02
# Theta | Test_3 -> R² = 0.4457, MSE = 1.8228e-01
# Theta | Val -> R² = -7.8084, MSE = 2.8827e+00
# Theta | LSG_1 -> R² = -0.2589, MSE = 5.1713e-01
# Theta | LSG_2 -> R² = -4.9772, MSE = 2.0485e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 0.981413 | Val Loss 0.812417
# Epoch 100 | Train Loss 0.729827 | Val Loss 0.637763
# Epoch 200 | Train Loss 0.663793 | Val Loss 0.603203
# Early stopping at epoch 227
# Modelo salvo em:
# weights/model_arch32_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.6618, MSE = 7.7296e-02
# Theta | Train_2 -> R² = 0.4425, MSE = 1.2639e-01
# Theta | Test_1 -> R² = 0.2478, MSE = 1.7301e-01
# Theta | Test_2 -> R² = 0.8856, MSE = 2.6940e-02
# Theta | Test_3 -> R² = 0.3986, MSE = 1.9777e-01
# Theta | Val -> R² = -6.5545, MSE = 2.4724e+00
# Theta | LSG_1 -> R² = 0.3237, MSE = 2.7782e-01
# Theta | LSG_2 -> R² = -2.8442, MSE = 1.3175e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.974309 | Val Loss 0.795614
# Epoch 100 | Train Loss 0.721062 | Val Loss 0.639871
# Epoch 200 | Train Loss 0.647066 | Val Loss 0.604742
# Early stopping at epoch 228
# Modelo salvo em:
# weights/model_arch32_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.6877, MSE = 7.1368e-02
# Theta | Train_2 -> R² = 0.4288, MSE = 1.2951e-01
# Theta | Test_1 -> R² = 0.1824, MSE = 1.8807e-01
# Theta | Test_2 -> R² = 0.8918, MSE = 2.5478e-02
# Theta | Test_3 -> R² = 0.4934, MSE = 1.6658e-01
# Theta | Val -> R² = -6.3156, MSE = 2.3942e+00
# Theta | LSG_1 -> R² = 0.3654, MSE = 2.6068e-01
# Theta | LSG_2 -> R² = -2.8202, MSE = 1.3093e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 1.013788 | Val Loss 0.866491
# Epoch 100 | Train Loss 0.718869 | Val Loss 0.642618
# Epoch 200 | Train Loss 0.623711 | Val Loss 0.782057
# Early stopping at epoch 231
# Modelo salvo em:
# weights/model_arch32_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7528, MSE = 5.6494e-02
# Theta | Train_2 -> R² = 0.4308, MSE = 1.2905e-01
# Theta | Test_1 -> R² = 0.3506, MSE = 1.4938e-01
# Theta | Test_2 -> R² = 0.8566, MSE = 3.3789e-02
# Theta | Test_3 -> R² = 0.5094, MSE = 1.6133e-01
# Theta | Val -> R² = -6.7418, MSE = 2.5337e+00
# Theta | LSG_1 -> R² = 0.3235, MSE = 2.7789e-01
# Theta | LSG_2 -> R² = -2.8197, MSE = 1.3091e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 0.985635 | Val Loss 0.688659
# Epoch 100 | Train Loss 0.684396 | Val Loss 0.581313
# Epoch 200 | Train Loss 0.634223 | Val Loss 0.656227
# Early stopping at epoch 217
# Modelo salvo em:
# weights/model_arch64_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7709, MSE = 5.2354e-02
# Theta | Train_2 -> R² = 0.6054, MSE = 8.9475e-02
# Theta | Test_1 -> R² = 0.5028, MSE = 1.1438e-01
# Theta | Test_2 -> R² = 0.8765, MSE = 2.9081e-02
# Theta | Test_3 -> R² = 0.5506, MSE = 1.4780e-01
# Theta | Val -> R² = -5.9409, MSE = 2.2716e+00
# Theta | LSG_1 -> R² = 0.0881, MSE = 3.7458e-01
# Theta | LSG_2 -> R² = -3.7425, MSE = 1.6253e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.004555 | Val Loss 0.776650
# Epoch 100 | Train Loss 0.681426 | Val Loss 0.590056
# Epoch 200 | Train Loss 0.631593 | Val Loss 0.641789
# Early stopping at epoch 224
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.8040, MSE = 4.4783e-02
# Theta | Train_2 -> R² = 0.5972, MSE = 9.1314e-02
# Theta | Test_1 -> R² = 0.4042, MSE = 1.3704e-01
# Theta | Test_2 -> R² = 0.8191, MSE = 4.2601e-02
# Theta | Test_3 -> R² = 0.6148, MSE = 1.2666e-01
# Theta | Val -> R² = -7.4318, MSE = 2.7595e+00
# Theta | LSG_1 -> R² = -0.3686, MSE = 5.6218e-01
# Theta | LSG_2 -> R² = -5.3689, MSE = 2.1828e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.997821 | Val Loss 0.787561
# Epoch 100 | Train Loss 0.683127 | Val Loss 0.577796
# Epoch 200 | Train Loss 0.626275 | Val Loss 0.655730
# Early stopping at epoch 216
# Modelo salvo em:
# weights/model_arch64_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.7857, MSE = 4.8983e-02
# Theta | Train_2 -> R² = 0.5462, MSE = 1.0288e-01
# Theta | Test_1 -> R² = 0.7010, MSE = 6.8779e-02
# Theta | Test_2 -> R² = 0.8737, MSE = 2.9760e-02
# Theta | Test_3 -> R² = 0.5887, MSE = 1.3526e-01
# Theta | Val -> R² = -2.8965, MSE = 1.2752e+00
# Theta | LSG_1 -> R² = 0.6614, MSE = 1.3909e-01
# Theta | LSG_2 -> R² = -1.5610, MSE = 8.7770e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.967129 | Val Loss 0.769196
# Epoch 100 | Train Loss 0.674970 | Val Loss 0.584904
# Epoch 200 | Train Loss 0.604870 | Val Loss 0.704335
# Early stopping at epoch 215
# Modelo salvo em:
# weights/model_arch64_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.8385, MSE = 3.6915e-02
# Theta | Train_2 -> R² = 0.6426, MSE = 8.1032e-02
# Theta | Test_1 -> R² = 0.6410, MSE = 8.2566e-02
# Theta | Test_2 -> R² = 0.8654, MSE = 3.1716e-02
# Theta | Test_3 -> R² = 0.4548, MSE = 1.7928e-01
# Theta | Val -> R² = -6.4538, MSE = 2.4394e+00
# Theta | LSG_1 -> R² = 0.1857, MSE = 3.3448e-01
# Theta | LSG_2 -> R² = -3.6661, MSE = 1.5992e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 1.020399 | Val Loss 0.655737
# Epoch 100 | Train Loss 0.686121 | Val Loss 0.574850
# Epoch 200 | Train Loss 0.631324 | Val Loss 0.707727
# Early stopping at epoch 219
# Modelo salvo em:
# weights/model_arch64_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7218, MSE = 6.3583e-02
# Theta | Train_2 -> R² = 0.4954, MSE = 1.1441e-01
# Theta | Test_1 -> R² = 0.5232, MSE = 1.0967e-01
# Theta | Test_2 -> R² = 0.8216, MSE = 4.2027e-02
# Theta | Test_3 -> R² = 0.3668, MSE = 2.0821e-01
# Theta | Val -> R² = -5.0267, MSE = 1.9724e+00
# Theta | LSG_1 -> R² = 0.5101, MSE = 2.0124e-01
# Theta | LSG_2 -> R² = -2.1075, MSE = 1.0650e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 0.990840 | Val Loss 0.756408
# Epoch 100 | Train Loss 0.676471 | Val Loss 0.588698
# Epoch 200 | Train Loss 0.612731 | Val Loss 0.691130
# Early stopping at epoch 216
# Modelo salvo em:
# weights/model_arch64_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7453, MSE = 5.8209e-02
# Theta | Train_2 -> R² = 0.5906, MSE = 9.2824e-02
# Theta | Test_1 -> R² = 0.5299, MSE = 1.0813e-01
# Theta | Test_2 -> R² = 0.8787, MSE = 2.8577e-02
# Theta | Test_3 -> R² = 0.4936, MSE = 1.6652e-01
# Theta | Val -> R² = -5.7849, MSE = 2.2205e+00
# Theta | LSG_1 -> R² = 0.1602, MSE = 3.4495e-01
# Theta | LSG_2 -> R² = -3.6562, MSE = 1.5958e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 0.981051 | Val Loss 0.698418
# Epoch 100 | Train Loss 0.689556 | Val Loss 0.582898
# Epoch 200 | Train Loss 0.641251 | Val Loss 0.624055
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7841, MSE = 4.9343e-02
# Theta | Train_2 -> R² = 0.4964, MSE = 1.1419e-01
# Theta | Test_1 -> R² = 0.5705, MSE = 9.8784e-02
# Theta | Test_2 -> R² = 0.8064, MSE = 4.5609e-02
# Theta | Test_3 -> R² = 0.5589, MSE = 1.4506e-01
# Theta | Val -> R² = -6.1357, MSE = 2.3353e+00
# Theta | LSG_1 -> R² = 0.1396, MSE = 3.5342e-01
# Theta | LSG_2 -> R² = -3.6474, MSE = 1.5928e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 1.023815 | Val Loss 0.793567
# Epoch 100 | Train Loss 0.681655 | Val Loss 0.586750
# Epoch 200 | Train Loss 0.634996 | Val Loss 0.682461
# Early stopping at epoch 217
# Modelo salvo em:
# weights/model_arch64_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.7858, MSE = 4.8953e-02
# Theta | Train_2 -> R² = 0.4069, MSE = 1.3448e-01
# Theta | Test_1 -> R² = 0.5048, MSE = 1.1390e-01
# Theta | Test_2 -> R² = 0.8293, MSE = 4.0201e-02
# Theta | Test_3 -> R² = 0.6866, MSE = 1.0305e-01
# Theta | Val -> R² = -3.7589, MSE = 1.5574e+00
# Theta | LSG_1 -> R² = 0.6175, MSE = 1.5712e-01
# Theta | LSG_2 -> R² = -1.5928, MSE = 8.8862e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.991365 | Val Loss 0.808437
# Epoch 100 | Train Loss 0.674774 | Val Loss 0.592433
# Epoch 200 | Train Loss 0.612133 | Val Loss 0.670710
# Early stopping at epoch 218
# Modelo salvo em:
# weights/model_arch64_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.7129, MSE = 6.5599e-02
# Theta | Train_2 -> R² = 0.6325, MSE = 8.3330e-02
# Theta | Test_1 -> R² = 0.4001, MSE = 1.3798e-01
# Theta | Test_2 -> R² = 0.8825, MSE = 2.7679e-02
# Theta | Test_3 -> R² = 0.0462, MSE = 3.1365e-01
# Theta | Val -> R² = -7.9193, MSE = 2.9190e+00
# Theta | LSG_1 -> R² = -0.0149, MSE = 4.1691e-01
# Theta | LSG_2 -> R² = -4.4708, MSE = 1.8750e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 1.068098 | Val Loss 0.794820
# Epoch 100 | Train Loss 0.691262 | Val Loss 0.588517
# Epoch 200 | Train Loss 0.642537 | Val Loss 0.625188
# Early stopping at epoch 220
# Modelo salvo em:
# weights/model_arch64_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.6486, MSE = 8.0300e-02
# Theta | Train_2 -> R² = 0.4817, MSE = 1.1750e-01
# Theta | Test_1 -> R² = 0.3083, MSE = 1.5910e-01
# Theta | Test_2 -> R² = 0.8085, MSE = 4.5101e-02
# Theta | Test_3 -> R² = 0.2298, MSE = 2.5328e-01
# Theta | Val -> R² = -6.5379, MSE = 2.4669e+00
# Theta | LSG_1 -> R² = 0.2121, MSE = 3.2365e-01
# Theta | LSG_2 -> R² = -3.3949, MSE = 1.5062e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 1.095090 | Val Loss 0.860146
# Epoch 100 | Train Loss 0.697751 | Val Loss 0.618017
# Epoch 200 | Train Loss 0.597629 | Val Loss 0.672411
# Early stopping at epoch 215
# Modelo salvo em:
# weights/model_arch64_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7580, MSE = 5.5299e-02
# Theta | Train_2 -> R² = 0.2104, MSE = 1.7901e-01
# Theta | Test_1 -> R² = 0.5514, MSE = 1.0319e-01
# Theta | Test_2 -> R² = 0.6278, MSE = 8.7679e-02
# Theta | Test_3 -> R² = 0.4381, MSE = 1.8478e-01
# Theta | Val -> R² = -6.3671, MSE = 2.4110e+00
# Theta | LSG_1 -> R² = 0.3910, MSE = 2.5018e-01
# Theta | LSG_2 -> R² = -2.1808, MSE = 1.0901e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.199838 | Val Loss 0.868203
# Epoch 100 | Train Loss 0.717616 | Val Loss 0.671357
# Epoch 200 | Train Loss 0.640281 | Val Loss 0.572321
# Early stopping at epoch 215
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.8791, MSE = 2.7637e-02
# Theta | Train_2 -> R² = 0.4922, MSE = 1.1512e-01
# Theta | Test_1 -> R² = 0.7492, MSE = 5.7684e-02
# Theta | Test_2 -> R² = 0.8115, MSE = 4.4408e-02
# Theta | Test_3 -> R² = 0.4657, MSE = 1.7569e-01
# Theta | Val -> R² = -7.2049, MSE = 2.6852e+00
# Theta | LSG_1 -> R² = 0.2593, MSE = 3.0425e-01
# Theta | LSG_2 -> R² = -2.9410, MSE = 1.3507e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.962843 | Val Loss 0.733619
# Epoch 100 | Train Loss 0.695602 | Val Loss 0.630241
# Epoch 200 | Train Loss 0.592962 | Val Loss 0.708698
# Early stopping at epoch 210
# Modelo salvo em:
# weights/model_arch64_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.5342, MSE = 1.0645e-01
# Theta | Train_2 -> R² = 0.2449, MSE = 1.7120e-01
# Theta | Test_1 -> R² = 0.0222, MSE = 2.2492e-01
# Theta | Test_2 -> R² = 0.7042, MSE = 6.9678e-02
# Theta | Test_3 -> R² = 0.3434, MSE = 2.1591e-01
# Theta | Val -> R² = -7.1157, MSE = 2.6560e+00
# Theta | LSG_1 -> R² = 0.1291, MSE = 3.5776e-01
# Theta | LSG_2 -> R² = -3.3987, MSE = 1.5075e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.929099 | Val Loss 0.721182
# Epoch 100 | Train Loss 0.671544 | Val Loss 0.610568
# Epoch 200 | Train Loss 0.568804 | Val Loss 0.884247
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch64_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.3197, MSE = 1.5547e-01
# Theta | Train_2 -> R² = 0.0563, MSE = 2.1396e-01
# Theta | Test_1 -> R² = -0.2124, MSE = 2.7887e-01
# Theta | Test_2 -> R² = 0.5086, MSE = 1.1575e-01
# Theta | Test_3 -> R² = -0.2697, MSE = 4.1754e-01
# Theta | Val -> R² = -9.7035, MSE = 3.5030e+00
# Theta | LSG_1 -> R² = -0.1867, MSE = 4.8747e-01
# Theta | LSG_2 -> R² = -4.2631, MSE = 1.8038e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 0.988399 | Val Loss 0.729487
# Epoch 100 | Train Loss 0.702446 | Val Loss 0.623997
# Epoch 200 | Train Loss 0.602063 | Val Loss 0.642039
# Early stopping at epoch 210
# Modelo salvo em:
# weights/model_arch64_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7827, MSE = 4.9668e-02
# Theta | Train_2 -> R² = 0.4557, MSE = 1.2341e-01
# Theta | Test_1 -> R² = 0.4007, MSE = 1.3786e-01
# Theta | Test_2 -> R² = 0.7698, MSE = 5.4225e-02
# Theta | Test_3 -> R² = 0.2813, MSE = 2.3632e-01
# Theta | Val -> R² = -8.5352, MSE = 3.1206e+00
# Theta | LSG_1 -> R² = -0.0004, MSE = 4.1095e-01
# Theta | LSG_2 -> R² = -4.1257, MSE = 1.7567e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 0.950618 | Val Loss 0.722709
# Epoch 100 | Train Loss 0.680623 | Val Loss 0.634285
# Epoch 200 | Train Loss 0.586984 | Val Loss 0.772757
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch64_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.6948, MSE = 6.9736e-02
# Theta | Train_2 -> R² = 0.2533, MSE = 1.6929e-01
# Theta | Test_1 -> R² = 0.3731, MSE = 1.4419e-01
# Theta | Test_2 -> R² = 0.6538, MSE = 8.1551e-02
# Theta | Test_3 -> R² = 0.2023, MSE = 2.6233e-01
# Theta | Val -> R² = -8.5822, MSE = 3.1360e+00
# Theta | LSG_1 -> R² = -0.0184, MSE = 4.1832e-01
# Theta | LSG_2 -> R² = -3.8032, MSE = 1.6462e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 0.945602 | Val Loss 0.700592
# Epoch 100 | Train Loss 0.691112 | Val Loss 0.667244
# Epoch 200 | Train Loss 0.586247 | Val Loss 0.778158
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7159, MSE = 6.4922e-02
# Theta | Train_2 -> R² = 0.6137, MSE = 8.7574e-02
# Theta | Test_1 -> R² = 0.3515, MSE = 1.4917e-01
# Theta | Test_2 -> R² = 0.8382, MSE = 3.8117e-02
# Theta | Test_3 -> R² = -0.5467, MSE = 5.0863e-01
# Theta | Val -> R² = -12.2426, MSE = 4.3339e+00
# Theta | LSG_1 -> R² = -0.7459, MSE = 7.1717e-01
# Theta | LSG_2 -> R² = -6.3904, MSE = 2.5328e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 0.956705 | Val Loss 0.761656
# Epoch 100 | Train Loss 0.681594 | Val Loss 0.611094
# Epoch 200 | Train Loss 0.579041 | Val Loss 0.828343
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch64_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.5310, MSE = 1.0718e-01
# Theta | Train_2 -> R² = 0.4048, MSE = 1.3495e-01
# Theta | Test_1 -> R² = -0.2193, MSE = 2.8046e-01
# Theta | Test_2 -> R² = 0.7538, MSE = 5.7991e-02
# Theta | Test_3 -> R² = 0.3228, MSE = 2.2269e-01
# Theta | Val -> R² = -9.1644, MSE = 3.3265e+00
# Theta | LSG_1 -> R² = -0.4921, MSE = 6.1293e-01
# Theta | LSG_2 -> R² = -5.7121, MSE = 2.3004e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.981777 | Val Loss 0.753345
# Epoch 100 | Train Loss 0.693630 | Val Loss 0.651556
# Epoch 200 | Train Loss 0.585814 | Val Loss 0.765839
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch64_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.6845, MSE = 7.2106e-02
# Theta | Train_2 -> R² = 0.1251, MSE = 1.9837e-01
# Theta | Test_1 -> R² = 0.3641, MSE = 1.4627e-01
# Theta | Test_2 -> R² = 0.5855, MSE = 9.7631e-02
# Theta | Test_3 -> R² = 0.5422, MSE = 1.5054e-01
# Theta | Val -> R² = -6.8595, MSE = 2.5722e+00
# Theta | LSG_1 -> R² = 0.2116, MSE = 3.2388e-01
# Theta | LSG_2 -> R² = -2.7467, MSE = 1.2841e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 0.983413 | Val Loss 0.736822
# Epoch 100 | Train Loss 0.688405 | Val Loss 0.626443
# Epoch 200 | Train Loss 0.591768 | Val Loss 0.719753
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch64_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7224, MSE = 6.3447e-02
# Theta | Train_2 -> R² = 0.3891, MSE = 1.3851e-01
# Theta | Test_1 -> R² = 0.3136, MSE = 1.5788e-01
# Theta | Test_2 -> R² = 0.7658, MSE = 5.5173e-02
# Theta | Test_3 -> R² = 0.2042, MSE = 2.6170e-01
# Theta | Val -> R² = -8.6373, MSE = 3.1540e+00
# Theta | LSG_1 -> R² = 0.0154, MSE = 4.0444e-01
# Theta | LSG_2 -> R² = -3.9200, MSE = 1.6862e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 1.025711 | Val Loss 0.643555
# Epoch 100 | Train Loss 0.676700 | Val Loss 0.585906
# Epoch 200 | Train Loss 0.632621 | Val Loss 0.651842
# Early stopping at epoch 210
# Modelo salvo em:
# weights/model_arch128_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.8323, MSE = 3.8332e-02
# Theta | Train_2 -> R² = 0.5347, MSE = 1.0549e-01
# Theta | Test_1 -> R² = 0.5235, MSE = 1.0961e-01
# Theta | Test_2 -> R² = 0.7948, MSE = 4.8336e-02
# Theta | Test_3 -> R² = 0.5361, MSE = 1.5254e-01
# Theta | Val -> R² = -7.2334, MSE = 2.6946e+00
# Theta | LSG_1 -> R² = -0.0187, MSE = 4.1845e-01
# Theta | LSG_2 -> R² = -4.3501, MSE = 1.8336e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.169319 | Val Loss 0.743182
# Epoch 100 | Train Loss 0.678843 | Val Loss 0.574784
# Epoch 200 | Train Loss 0.630395 | Val Loss 0.666287
# Early stopping at epoch 215
# Modelo salvo em:
# weights/model_arch128_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7501, MSE = 5.7098e-02
# Theta | Train_2 -> R² = 0.7108, MSE = 6.5562e-02
# Theta | Test_1 -> R² = 0.3461, MSE = 1.5041e-01
# Theta | Test_2 -> R² = 0.8398, MSE = 3.7729e-02
# Theta | Test_3 -> R² = 0.0496, MSE = 3.1251e-01
# Theta | Val -> R² = -9.7962, MSE = 3.5333e+00
# Theta | LSG_1 -> R² = -0.8700, MSE = 7.6815e-01
# Theta | LSG_2 -> R² = -7.6499, MSE = 2.9645e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 1.017683 | Val Loss 0.664242
# Epoch 100 | Train Loss 0.671422 | Val Loss 0.579910
# Epoch 200 | Train Loss 0.624631 | Val Loss 0.674274
# Early stopping at epoch 212
# Modelo salvo em:
# weights/model_arch128_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.8224, MSE = 4.0583e-02
# Theta | Train_2 -> R² = 0.7146, MSE = 6.4718e-02
# Theta | Test_1 -> R² = 0.4340, MSE = 1.3020e-01
# Theta | Test_2 -> R² = 0.8221, MSE = 4.1914e-02
# Theta | Test_3 -> R² = -0.0044, MSE = 3.3029e-01
# Theta | Val -> R² = -10.8573, MSE = 3.8806e+00
# Theta | LSG_1 -> R² = -0.8477, MSE = 7.5897e-01
# Theta | LSG_2 -> R² = -7.4712, MSE = 2.9033e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 1.013708 | Val Loss 0.720521
# Epoch 100 | Train Loss 0.671731 | Val Loss 0.580314
# Epoch 200 | Train Loss 0.611092 | Val Loss 0.699833
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch128_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.8520, MSE = 3.3830e-02
# Theta | Train_2 -> R² = 0.7144, MSE = 6.4746e-02
# Theta | Test_1 -> R² = 0.5787, MSE = 9.6903e-02
# Theta | Test_2 -> R² = 0.8013, MSE = 4.6801e-02
# Theta | Test_3 -> R² = 0.3421, MSE = 2.1633e-01
# Theta | Val -> R² = -8.3341, MSE = 3.0548e+00
# Theta | LSG_1 -> R² = -0.5024, MSE = 6.1717e-01
# Theta | LSG_2 -> R² = -6.7676, MSE = 2.6621e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 0.984161 | Val Loss 0.655750
# Epoch 100 | Train Loss 0.663384 | Val Loss 0.610183
# Epoch 200 | Train Loss 0.600422 | Val Loss 0.727669
# Early stopping at epoch 212
# Modelo salvo em:
# weights/model_arch128_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.8230, MSE = 4.0448e-02
# Theta | Train_2 -> R² = 0.6338, MSE = 8.3034e-02
# Theta | Test_1 -> R² = 0.7523, MSE = 5.6965e-02
# Theta | Test_2 -> R² = 0.7327, MSE = 6.2956e-02
# Theta | Test_3 -> R² = -0.1838, MSE = 3.8927e-01
# Theta | Val -> R² = -10.4748, MSE = 3.7554e+00
# Theta | LSG_1 -> R² = -0.3217, MSE = 5.4290e-01
# Theta | LSG_2 -> R² = -5.8362, MSE = 2.3429e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 1.252330 | Val Loss 0.781958
# Epoch 100 | Train Loss 0.681801 | Val Loss 0.578068
# Epoch 200 | Train Loss 0.631034 | Val Loss 0.679932
# Early stopping at epoch 216
# Modelo salvo em:
# weights/model_arch128_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.7594, MSE = 5.4978e-02
# Theta | Train_2 -> R² = 0.6457, MSE = 8.0327e-02
# Theta | Test_1 -> R² = 0.3271, MSE = 1.5478e-01
# Theta | Test_2 -> R² = 0.8282, MSE = 4.0456e-02
# Theta | Test_3 -> R² = 0.2822, MSE = 2.3603e-01
# Theta | Val -> R² = -8.4821, MSE = 3.1032e+00
# Theta | LSG_1 -> R² = -0.4333, MSE = 5.8877e-01
# Theta | LSG_2 -> R² = -6.1475, MSE = 2.4496e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 1.147751 | Val Loss 0.775556
# Epoch 100 | Train Loss 0.679497 | Val Loss 0.583267
# Epoch 200 | Train Loss 0.630216 | Val Loss 0.666982
# Early stopping at epoch 217
# Modelo salvo em:
# weights/model_arch128_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7628, MSE = 5.4206e-02
# Theta | Train_2 -> R² = 0.6694, MSE = 7.4950e-02
# Theta | Test_1 -> R² = 0.6884, MSE = 7.1677e-02
# Theta | Test_2 -> R² = 0.7617, MSE = 5.6139e-02
# Theta | Test_3 -> R² = 0.4007, MSE = 1.9706e-01
# Theta | Val -> R² = -6.1601, MSE = 2.3433e+00
# Theta | LSG_1 -> R² = -0.0852, MSE = 4.4579e-01
# Theta | LSG_2 -> R² = -5.1750, MSE = 2.1163e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 1.045496 | Val Loss 0.751345
# Epoch 100 | Train Loss 0.678183 | Val Loss 0.574689
# Epoch 200 | Train Loss 0.614121 | Val Loss 0.737624
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch128_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.7978, MSE = 4.6200e-02
# Theta | Train_2 -> R² = 0.7489, MSE = 5.6922e-02
# Theta | Test_1 -> R² = 0.5932, MSE = 9.3581e-02
# Theta | Test_2 -> R² = 0.7966, MSE = 4.7921e-02
# Theta | Test_3 -> R² = -0.3865, MSE = 4.5592e-01
# Theta | Val -> R² = -10.9812, MSE = 3.9211e+00
# Theta | LSG_1 -> R² = -0.7892, MSE = 7.3495e-01
# Theta | LSG_2 -> R² = -7.5953, MSE = 2.9458e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 1.030995 | Val Loss 0.687382
# Epoch 100 | Train Loss 0.674823 | Val Loss 0.579883
# Epoch 200 | Train Loss 0.636009 | Val Loss 0.662996
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch128_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.8666, MSE = 3.0483e-02
# Theta | Train_2 -> R² = 0.6562, MSE = 7.7941e-02
# Theta | Test_1 -> R² = 0.7084, MSE = 6.7070e-02
# Theta | Test_2 -> R² = 0.8304, MSE = 3.9948e-02
# Theta | Test_3 -> R² = 0.2329, MSE = 2.5225e-01
# Theta | Val -> R² = -7.7367, MSE = 2.8593e+00
# Theta | LSG_1 -> R² = 0.0963, MSE = 3.7122e-01
# Theta | LSG_2 -> R² = -4.3780, MSE = 1.8432e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 1.154155 | Val Loss 0.656771
# Epoch 100 | Train Loss 0.677483 | Val Loss 0.582608
# Epoch 200 | Train Loss 0.633789 | Val Loss 0.666284
# Early stopping at epoch 215
# Modelo salvo em:
# weights/model_arch128_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.8043, MSE = 4.4714e-02
# ...
# Epoch 200 | Train Loss 0.538319 | Val Loss 0.896146
# Early stopping at epoch 296
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.5527, MSE = 1.0221e-01
# Theta | Train_2 -> R² = 0.7315, MSE = 6.0870e-02
# Theta | Test_1 -> R² = 0.5381, MSE = 1.0625e-01
# Theta | Test_2 -> R² = 0.8470, MSE = 3.6037e-02
# Theta | Test_3 -> R² = -7.4375, MSE = 2.7746e+00
# Theta | Val -> R² = -10.4310, MSE = 3.7410e+00
# Theta | LSG_1 -> R² = -0.4206, MSE = 5.8354e-01
# Theta | LSG_2 -> R² = -7.4210, MSE = 2.8861e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.977706 | Val Loss 0.762645
# Epoch 100 | Train Loss 0.594238 | Val Loss 0.658886
# Epoch 200 | Train Loss 0.529296 | Val Loss 0.969582
# Early stopping at epoch 212
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.8520, MSE = 3.3818e-02
# Theta | Train_2 -> R² = 0.4597, MSE = 1.2251e-01
# Theta | Test_1 -> R² = 0.6532, MSE = 7.9769e-02
# Theta | Test_2 -> R² = 0.8308, MSE = 3.9859e-02
# Theta | Test_3 -> R² = 0.6075, MSE = 1.2905e-01
# Theta | Val -> R² = -3.6549, MSE = 1.5234e+00
# Theta | LSG_1 -> R² = 0.6624, MSE = 1.3867e-01
# Theta | LSG_2 -> R² = -1.4144, MSE = 8.2747e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 1.005423 | Val Loss 0.779936
# Epoch 100 | Train Loss 0.625701 | Val Loss 0.561504
# Epoch 200 | Train Loss 0.540067 | Val Loss 0.872856
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.8396, MSE = 3.6660e-02
# Theta | Train_2 -> R² = 0.5831, MSE = 9.4527e-02
# Theta | Test_1 -> R² = 0.6163, MSE = 8.8254e-02
# Theta | Test_2 -> R² = 0.8675, MSE = 3.1218e-02
# Theta | Test_3 -> R² = 0.6341, MSE = 1.2033e-01
# Theta | Val -> R² = -4.1882, MSE = 1.6980e+00
# Theta | LSG_1 -> R² = 0.5549, MSE = 1.8283e-01
# Theta | LSG_2 -> R² = -1.9690, MSE = 1.0176e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 1.034726 | Val Loss 0.850763
# Epoch 100 | Train Loss 0.605197 | Val Loss 0.682283
# Epoch 200 | Train Loss 0.539126 | Val Loss 0.775406
# Early stopping at epoch 245
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.4883, MSE = 1.1695e-01
# Theta | Train_2 -> R² = 0.7116, MSE = 6.5394e-02
# Theta | Test_1 -> R² = 0.5212, MSE = 1.1012e-01
# Theta | Test_2 -> R² = 0.8895, MSE = 2.6024e-02
# Theta | Test_3 -> R² = 0.4629, MSE = 1.7662e-01
# Theta | Val -> R² = -1.0655, MSE = 6.7598e-01
# Theta | LSG_1 -> R² = 0.5189, MSE = 1.9761e-01
# Theta | LSG_2 -> R² = -1.4872, MSE = 8.5241e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 0.982218 | Val Loss 1.017710
# Epoch 100 | Train Loss 0.619833 | Val Loss 0.650949
# Epoch 200 | Train Loss 0.612467 | Val Loss 0.731777
# Early stopping at epoch 254
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7293, MSE = 6.1871e-02
# Theta | Train_2 -> R² = 0.6522, MSE = 7.8858e-02
# Theta | Test_1 -> R² = 0.7228, MSE = 6.3758e-02
# Theta | Test_2 -> R² = 0.8405, MSE = 3.7566e-02
# Theta | Test_3 -> R² = 0.8146, MSE = 6.0974e-02
# Theta | Val -> R² = 0.1957, MSE = 2.6323e-01
# Theta | LSG_1 -> R² = 0.6706, MSE = 1.3531e-01
# Theta | LSG_2 -> R² = -0.6728, MSE = 5.7332e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.998677 | Val Loss 0.610525
# Epoch 100 | Train Loss 0.590388 | Val Loss 0.666732
# Epoch 200 | Train Loss 0.530971 | Val Loss 0.751066
# Early stopping at epoch 203
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.6154, MSE = 8.7901e-02
# Theta | Train_2 -> R² = 0.5233, MSE = 1.0809e-01
# Theta | Test_1 -> R² = 0.1819, MSE = 1.8818e-01
# Theta | Test_2 -> R² = 0.7919, MSE = 4.9008e-02
# Theta | Test_3 -> R² = 0.6653, MSE = 1.1008e-01
# Theta | Val -> R² = -4.8933, MSE = 1.9287e+00
# Theta | LSG_1 -> R² = 0.2745, MSE = 2.9802e-01
# Theta | LSG_2 -> R² = -3.2225, MSE = 1.4471e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.976121 | Val Loss 0.662049
# Epoch 100 | Train Loss 0.597369 | Val Loss 0.648278
# Epoch 200 | Train Loss 0.521323 | Val Loss 0.715919
# Early stopping at epoch 204
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.8189, MSE = 4.1387e-02
# Theta | Train_2 -> R² = 0.4783, MSE = 1.1828e-01
# Theta | Test_1 -> R² = 0.6806, MSE = 7.3478e-02
# Theta | Test_2 -> R² = 0.8055, MSE = 4.5810e-02
# Theta | Test_3 -> R² = 0.7852, MSE = 7.0629e-02
# Theta | Val -> R² = -2.4736, MSE = 1.1368e+00
# Theta | LSG_1 -> R² = 0.6616, MSE = 1.3902e-01
# Theta | LSG_2 -> R² = -1.1264, MSE = 7.2877e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 1.024632 | Val Loss 0.848373
# Epoch 100 | Train Loss 0.609215 | Val Loss 0.662099
# Epoch 200 | Train Loss 0.541648 | Val Loss 0.783378
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7839, MSE = 4.9374e-02
# Theta | Train_2 -> R² = 0.6427, MSE = 8.1008e-02
# Theta | Test_1 -> R² = 0.6558, MSE = 7.9162e-02
# Theta | Test_2 -> R² = 0.8349, MSE = 3.8893e-02
# Theta | Test_3 -> R² = 0.1415, MSE = 2.8232e-01
# Theta | Val -> R² = -0.8526, MSE = 6.0631e-01
# Theta | LSG_1 -> R² = 0.3515, MSE = 2.6637e-01
# Theta | LSG_2 -> R² = -3.0479, MSE = 1.3873e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 1.028563 | Val Loss 0.796418
# Epoch 100 | Train Loss 0.603315 | Val Loss 0.666761
# Epoch 200 | Train Loss 0.534482 | Val Loss 0.775241
# Early stopping at epoch 204
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.8589, MSE = 3.2235e-02
# Theta | Train_2 -> R² = 0.5032, MSE = 1.1264e-01
# Theta | Test_1 -> R² = 0.6472, MSE = 8.1150e-02
# Theta | Test_2 -> R² = 0.7442, MSE = 6.0260e-02
# Theta | Test_3 -> R² = 0.6813, MSE = 1.0479e-01
# Theta | Val -> R² = -2.3784, MSE = 1.1056e+00
# Theta | LSG_1 -> R² = 0.3152, MSE = 2.8130e-01
# Theta | LSG_2 -> R² = -2.8439, MSE = 1.3174e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 0.977543 | Val Loss 0.691083
# Epoch 100 | Train Loss 0.621182 | Val Loss 0.654641
# Epoch 200 | Train Loss 0.541979 | Val Loss 0.728471
# Early stopping at epoch 203
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.7220, MSE = 6.3531e-02
# Theta | Train_2 -> R² = 0.5421, MSE = 1.0382e-01
# Theta | Test_1 -> R² = 0.6337, MSE = 8.4247e-02
# Theta | Test_2 -> R² = 0.8429, MSE = 3.6998e-02
# Theta | Test_3 -> R² = 0.5680, MSE = 1.4204e-01
# Theta | Val -> R² = -2.1113, MSE = 1.0182e+00
# Theta | LSG_1 -> R² = 0.5625, MSE = 1.7971e-01
# Theta | LSG_2 -> R² = -1.9086, MSE = 9.9685e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 1.017813 | Val Loss 0.626994
# Epoch 100 | Train Loss 0.593658 | Val Loss 0.691926
# Epoch 200 | Train Loss 0.531850 | Val Loss 0.774041
# Early stopping at epoch 203
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.6085, MSE = 8.9478e-02
# Theta | Train_2 -> R² = 0.7402, MSE = 5.8897e-02
# Theta | Test_1 -> R² = 0.3490, MSE = 1.4974e-01
# Theta | Test_2 -> R² = 0.8964, MSE = 2.4394e-02
# Theta | Test_3 -> R² = 0.7014, MSE = 9.8206e-02
# Theta | Val -> R² = -3.6049, MSE = 1.5070e+00
# Theta | LSG_1 -> R² = -0.1921, MSE = 4.8970e-01
# Theta | LSG_2 -> R² = -4.4543, MSE = 1.8693e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 0.978105 | Val Loss 0.669050
# Epoch 100 | Train Loss 0.592297 | Val Loss 0.666281
# Epoch 200 | Train Loss 0.542588 | Val Loss 0.699047
# Early stopping at epoch 203
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.4633, MSE = 1.2264e-01
# Theta | Train_2 -> R² = 0.0789, MSE = 2.0884e-01
# Theta | Test_1 -> R² = 0.1267, MSE = 2.0088e-01
# Theta | Test_2 -> R² = 0.5181, MSE = 1.1350e-01
# Theta | Test_3 -> R² = 0.8117, MSE = 6.1923e-02
# Theta | Val -> R² = -2.3385, MSE = 1.0926e+00
# Theta | LSG_1 -> R² = 0.4307, MSE = 2.3386e-01
# Theta | LSG_2 -> R² = -1.9104, MSE = 9.9745e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 1.006351 | Val Loss 0.675065
# Epoch 100 | Train Loss 0.627031 | Val Loss 0.653697
# Epoch 200 | Train Loss 0.547243 | Val Loss 0.736530
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.7140, MSE = 6.5368e-02
# Theta | Train_2 -> R² = 0.7194, MSE = 6.3618e-02
# Theta | Test_1 -> R² = 0.7579, MSE = 5.5678e-02
# Theta | Test_2 -> R² = 0.7387, MSE = 6.1554e-02
# Theta | Test_3 -> R² = 0.4578, MSE = 1.7828e-01
# Theta | Val -> R² = -3.6864, MSE = 1.5337e+00
# Theta | LSG_1 -> R² = 0.4372, MSE = 2.3120e-01
# Theta | LSG_2 -> R² = -3.1837, MSE = 1.4339e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3087 salvo.
# Epoch 0 | Train Loss 1.014725 | Val Loss 0.773786
# Epoch 100 | Train Loss 0.578646 | Val Loss 0.651964
# Epoch 200 | Train Loss 0.514852 | Val Loss 1.026932
# Early stopping at epoch 279
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.6765, MSE = 7.3931e-02
# Theta | Train_2 -> R² = 0.8250, MSE = 3.9685e-02
# Theta | Test_1 -> R² = 0.3805, MSE = 1.4249e-01
# Theta | Test_2 -> R² = 0.7519, MSE = 5.8449e-02
# Theta | Test_3 -> R² = -5.5657, MSE = 2.1590e+00
# Theta | Val -> R² = -10.7452, MSE = 3.8439e+00
# Theta | LSG_1 -> R² = -0.1418, MSE = 4.6904e-01
# Theta | LSG_2 -> R² = -7.6101, MSE = 2.9509e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4657 salvo.
# Epoch 0 | Train Loss 1.051869 | Val Loss 1.046131
# Epoch 100 | Train Loss 0.589352 | Val Loss 0.590110
# Epoch 200 | Train Loss 0.525319 | Val Loss 0.987817
# Early stopping at epoch 275
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.8575, MSE = 3.2568e-02
# Theta | Train_2 -> R² = 0.8230, MSE = 4.0123e-02
# Theta | Test_1 -> R² = 0.4645, MSE = 1.2317e-01
# Theta | Test_2 -> R² = 0.6704, MSE = 7.7641e-02
# Theta | Test_3 -> R² = -2.9988, MSE = 1.3150e+00
# Theta | Val -> R² = -7.6309, MSE = 2.8247e+00
# Theta | LSG_1 -> R² = 0.1874, MSE = 3.3378e-01
# Theta | LSG_2 -> R² = -6.1928, MSE = 2.4651e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1637 salvo.
# Epoch 0 | Train Loss 0.929018 | Val Loss 0.724028
# Epoch 100 | Train Loss 0.602401 | Val Loss 0.638746
# Epoch 200 | Train Loss 0.523413 | Val Loss 1.033126
# Early stopping at epoch 278
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.9290, MSE = 1.6226e-02
# Theta | Train_2 -> R² = 0.6244, MSE = 8.5155e-02
# Theta | Test_1 -> R² = 0.6507, MSE = 8.0345e-02
# Theta | Test_2 -> R² = 0.5918, MSE = 9.6155e-02
# Theta | Test_3 -> R² = -3.1745, MSE = 1.3727e+00
# Theta | Val -> R² = -8.9892, MSE = 3.2692e+00
# Theta | LSG_1 -> R² = -0.0797, MSE = 4.4351e-01
# Theta | LSG_2 -> R² = -4.0146, MSE = 1.7186e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=9830 salvo.
# Epoch 0 | Train Loss 0.983230 | Val Loss 0.567011
# Epoch 100 | Train Loss 0.564263 | Val Loss 0.655475
# Epoch 200 | Train Loss 0.512475 | Val Loss 1.021024
# Early stopping at epoch 266
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.7962, MSE = 4.6573e-02
# Theta | Train_2 -> R² = 0.8361, MSE = 3.7165e-02
# Theta | Test_1 -> R² = 0.5779, MSE = 9.7088e-02
# Theta | Test_2 -> R² = 0.7506, MSE = 5.8735e-02
# Theta | Test_3 -> R² = -5.5973, MSE = 2.1694e+00
# Theta | Val -> R² = -12.2393, MSE = 4.3328e+00
# Theta | LSG_1 -> R² = -0.1285, MSE = 4.6357e-01
# Theta | LSG_2 -> R² = -6.5887, MSE = 2.6008e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2734 salvo.
# Epoch 0 | Train Loss 1.060744 | Val Loss 0.555965
# Epoch 100 | Train Loss 0.560307 | Val Loss 0.745491
# Epoch 200 | Train Loss 0.537398 | Val Loss 1.011034
# Early stopping at epoch 255
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.8498, MSE = 3.4313e-02
# Theta | Train_2 -> R² = 0.7375, MSE = 5.9507e-02
# Theta | Test_1 -> R² = 0.4883, MSE = 1.1770e-01
# Theta | Test_2 -> R² = 0.6616, MSE = 7.9721e-02
# Theta | Test_3 -> R² = -2.8702, MSE = 1.2727e+00
# Theta | Val -> R² = -10.0204, MSE = 3.6067e+00
# Theta | LSG_1 -> R² = -0.2717, MSE = 5.2239e-01
# Theta | LSG_2 -> R² = -6.4773, MSE = 2.5627e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3087 salvo.
# Epoch 0 | Train Loss 0.964589 | Val Loss 0.553572
# Epoch 100 | Train Loss 0.604998 | Val Loss 0.549772
# Epoch 200 | Train Loss 0.547824 | Val Loss 0.926151
# Early stopping at epoch 294
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed4657.weights.h5
# Theta | Train_1 -> R² = 0.8885, MSE = 2.5487e-02
# Theta | Train_2 -> R² = 0.7630, MSE = 5.3741e-02
# Theta | Test_1 -> R² = 0.6230, MSE = 8.6718e-02
# Theta | Test_2 -> R² = 0.7013, MSE = 7.0355e-02
# Theta | Test_3 -> R² = -2.8816, MSE = 1.2764e+00
# Theta | Val -> R² = -6.7057, MSE = 2.5219e+00
# Theta | LSG_1 -> R² = 0.1723, MSE = 3.4001e-01
# Theta | LSG_2 -> R² = -4.5008, MSE = 1.8852e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4657 salvo.
# Epoch 0 | Train Loss 0.977332 | Val Loss 1.072145
# Epoch 100 | Train Loss 0.596553 | Val Loss 0.572708
# Epoch 200 | Train Loss 0.517409 | Val Loss 1.014392
# Early stopping at epoch 276
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1637.weights.h5
# Theta | Train_1 -> R² = 0.8749, MSE = 2.8595e-02
# Theta | Train_2 -> R² = 0.7865, MSE = 4.8415e-02
# Theta | Test_1 -> R² = 0.5476, MSE = 1.0407e-01
# Theta | Test_2 -> R² = 0.6219, MSE = 8.9067e-02
# Theta | Test_3 -> R² = -2.7666, MSE = 1.2386e+00
# Theta | Val -> R² = -6.6841, MSE = 2.5148e+00
# Theta | LSG_1 -> R² = 0.2456, MSE = 3.0988e-01
# Theta | LSG_2 -> R² = -5.1362, MSE = 2.1030e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1637 salvo.
# Epoch 0 | Train Loss 1.009006 | Val Loss 0.557377
# Epoch 100 | Train Loss 0.589440 | Val Loss 0.645246
# Epoch 200 | Train Loss 0.521504 | Val Loss 1.081293
# Early stopping at epoch 274
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed9830.weights.h5
# Theta | Train_1 -> R² = 0.9323, MSE = 1.5480e-02
# Theta | Train_2 -> R² = 0.7203, MSE = 6.3411e-02
# Theta | Test_1 -> R² = 0.6003, MSE = 9.1943e-02
# Theta | Test_2 -> R² = 0.5946, MSE = 9.5490e-02
# Theta | Test_3 -> R² = -3.2733, MSE = 1.4052e+00
# Theta | Val -> R² = -9.3259, MSE = 3.3794e+00
# Theta | LSG_1 -> R² = 0.0854, MSE = 3.7571e-01
# Theta | LSG_2 -> R² = -5.8168, MSE = 2.3363e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=9830 salvo.
# Epoch 0 | Train Loss 1.044517 | Val Loss 0.753550
# Epoch 100 | Train Loss 0.573445 | Val Loss 0.614918
# Epoch 200 | Train Loss 0.509960 | Val Loss 0.974698
# Early stopping at epoch 280
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed2734.weights.h5
# Theta | Train_1 -> R² = 0.9581, MSE = 9.5839e-03
# Theta | Train_2 -> R² = 0.5964, MSE = 9.1517e-02
# Theta | Test_1 -> R² = 0.6536, MSE = 7.9670e-02
# Theta | Test_2 -> R² = 0.4718, MSE = 1.2442e-01
# Theta | Test_3 -> R² = -1.9881, MSE = 9.8259e-01
# Theta | Val -> R² = -3.9510, MSE = 1.6203e+00
# Theta | LSG_1 -> R² = 0.1929, MSE = 3.3154e-01
# Theta | LSG_2 -> R² = -1.7280, MSE = 9.3496e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2734 salvo.
# Epoch 0 | Train Loss 0.996246 | Val Loss 1.090811
# Epoch 100 | Train Loss 0.606798 | Val Loss 0.558914
# Epoch 200 | Train Loss 0.526630 | Val Loss 0.984805
# Early stopping at epoch 292
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed3087.weights.h5
# Theta | Train_1 -> R² = 0.9285, MSE = 1.6340e-02
# Theta | Train_2 -> R² = 0.4937, MSE = 1.1478e-01
# Theta | Test_1 -> R² = 0.5607, MSE = 1.0105e-01
# Theta | Test_2 -> R² = 0.3833, MSE = 1.4526e-01
# Theta | Test_3 -> R² = -0.7424, MSE = 5.7297e-01
# Theta | Val -> R² = -2.7671, MSE = 1.2329e+00
# Theta | LSG_1 -> R² = -0.4131, MSE = 5.8048e-01
# Theta | LSG_2 -> R² = -2.2782, MSE = 1.1235e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3087 salvo.

# %%
with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
