# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
os.makedirs("./scalers", exist_ok=True)

NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)
    
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 4)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.architecture = architecture  
        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):
        x = inputs
        for rnn in self.rnn_layers:
            x = rnn(x)
        return self.out_layer(x)

# %%
def PINN_to_RNN(pinn_model):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    # recria arquitetura
    for layer in pinn_model.rnn_layers:
        model.add(
            tf.keras.layers.SimpleRNN(
                units=layer.units,
                activation='tanh',
                return_sequences=layer.return_sequences
            )
        )

    # camada final
    model.add(
        tf.keras.layers.Dense(
            pinn_model.out_layer.units,
            activation='linear'
        )
    )

    model.build((None, TIME_STEPS, INPUT_SIZE))

    model.set_weights(pinn_model.get_weights())

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = OUT_SCALER.transform(physics)

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": metrics[name]["R2_Train_1"],
            f"MSE_Train_1_{name}": metrics[name]["MSE_Train_1"],
            f"R2_Train_2_{name}": metrics[name]["R2_Train_2"],
            f"MSE_Train_2_{name}": metrics[name]["MSE_Train_2"],
            f"R2_Val_{name}": metrics[name]["R2_Val"],
            f"MSE_Val_{name}": metrics[name]["MSE_Val"],
            f"R2_Test_1_{name}": metrics[name]["R2_Test_1"],
            f"MSE_Test_1_{name}": metrics[name]["MSE_Test_1"],
            f"R2_Test_2_{name}": metrics[name]["R2_Test_2"],
            f"MSE_Test_2_{name}": metrics[name]["MSE_Test_2"],
            f"R2_Test_3_{name}": metrics[name]["R2_Test_3"],
            f"MSE_Test_3_{name}": metrics[name]["MSE_Test_3"],
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
import os

def ExportModel(pinn_model, model_name):

    os.makedirs("weights", exist_ok=True)

    rnn_model = PINN_to_RNN(pinn_model)

    weights_path = f"weights/{model_name}.weights.h5"

    rnn_model.save_weights(weights_path)

    print(f"Modelo salvo em:\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        pinn_model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )
        pinn_model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(pinn_model.trainable_variables)

        TrainPINN(
            pinn_model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(pinn_model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(pinn_model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.970932 | Val Loss 0.809477
# Epoch 100 | Train Loss 0.772354 | Val Loss 0.552236
# Epoch 200 | Train Loss 0.686009 | Val Loss 0.553840
# Epoch 300 | Train Loss 0.660422 | Val Loss 0.541677
# Early stopping at epoch 351
# Modelo salvo em:
# weights/model_arch16_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7899, MSE = 4.7809e-02
# Theta | Train_2 -> R² = 0.6140, MSE = 8.8118e-02
# Theta | Test_1 -> R² = 0.4692, MSE = 1.2159e-01
# Theta | Test_2 -> R² = 0.8629, MSE = 3.2505e-02
# Theta | Test_3 -> R² = 0.7534, MSE = 8.0897e-02
# Theta | Val -> R² = -1.0643, MSE = 6.7386e-01
# Theta | LSG_1 -> R² = 0.6857, MSE = 1.3120e-01
# Theta | LSG_2 -> R² = -2.3365, MSE = 1.1678e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 1.036390 | Val Loss 0.918502
# Epoch 100 | Train Loss 0.780895 | Val Loss 0.561661
# Epoch 200 | Train Loss 0.702637 | Val Loss 0.536149
# Epoch 300 | Train Loss 0.668025 | Val Loss 0.539550
# Early stopping at epoch 378
# Modelo salvo em:
# weights/model_arch16_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7728, MSE = 5.1700e-02
# Theta | Train_2 -> R² = 0.6102, MSE = 8.8989e-02
# Theta | Test_1 -> R² = 0.4271, MSE = 1.3125e-01
# Theta | Test_2 -> R² = 0.8664, MSE = 3.1680e-02
# Theta | Test_3 -> R² = 0.6998, MSE = 9.8472e-02
# Theta | Val -> R² = -1.7507, MSE = 8.9790e-01
# Theta | LSG_1 -> R² = 0.6810, MSE = 1.3317e-01
# Theta | LSG_2 -> R² = -2.4486, MSE = 1.2070e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.970816 | Val Loss 0.767592
# Epoch 100 | Train Loss 0.772952 | Val Loss 0.563879
# Epoch 200 | Train Loss 0.692799 | Val Loss 0.546754
# Epoch 300 | Train Loss 0.664802 | Val Loss 0.542218
# Epoch 400 | Train Loss 0.652123 | Val Loss 0.571562
# Early stopping at epoch 461
# Modelo salvo em:
# weights/model_arch16_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.8095, MSE = 4.3362e-02
# Theta | Train_2 -> R² = 0.6694, MSE = 7.5467e-02
# Theta | Test_1 -> R² = 0.5680, MSE = 9.8963e-02
# Theta | Test_2 -> R² = 0.8640, MSE = 3.2254e-02
# Theta | Test_3 -> R² = 0.7260, MSE = 8.9886e-02
# Theta | Val -> R² = 0.6179, MSE = 1.2472e-01
# Theta | LSG_1 -> R² = 0.6371, MSE = 1.5150e-01
# Theta | LSG_2 -> R² = -1.0471, MSE = 7.1650e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 0.992124 | Val Loss 0.815658
# Epoch 100 | Train Loss 0.786353 | Val Loss 0.557650
# Epoch 200 | Train Loss 0.710975 | Val Loss 0.539432
# Epoch 300 | Train Loss 0.667564 | Val Loss 0.549221
# Early stopping at epoch 385
# Modelo salvo em:
# weights/model_arch16_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7673, MSE = 5.2967e-02
# Theta | Train_2 -> R² = 0.5385, MSE = 1.0535e-01
# Theta | Test_1 -> R² = 0.3475, MSE = 1.4946e-01
# Theta | Test_2 -> R² = 0.8577, MSE = 3.3733e-02
# Theta | Test_3 -> R² = 0.6988, MSE = 9.8807e-02
# Theta | Val -> R² = -2.7811, MSE = 1.2343e+00
# Theta | LSG_1 -> R² = 0.5297, MSE = 1.9631e-01
# Theta | LSG_2 -> R² = -3.1977, MSE = 1.4692e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 0.991741 | Val Loss 0.849131
# Epoch 100 | Train Loss 0.782862 | Val Loss 0.557966
# Epoch 200 | Train Loss 0.700841 | Val Loss 0.540054
# Epoch 300 | Train Loss 0.663877 | Val Loss 0.558396
# Early stopping at epoch 378
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7869, MSE = 4.8498e-02
# Theta | Train_2 -> R² = 0.5782, MSE = 9.6296e-02
# Theta | Test_1 -> R² = 0.5239, MSE = 1.0906e-01
# Theta | Test_2 -> R² = 0.8701, MSE = 3.0807e-02
# Theta | Test_3 -> R² = 0.7390, MSE = 8.5604e-02
# Theta | Val -> R² = -0.8825, MSE = 6.1449e-01
# Theta | LSG_1 -> R² = 0.7678, MSE = 9.6930e-02
# Theta | LSG_2 -> R² = -1.5914, MSE = 9.0700e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 0.972590 | Val Loss 0.815116
# Epoch 100 | Train Loss 0.783028 | Val Loss 0.557421
# Epoch 200 | Train Loss 0.697307 | Val Loss 0.547470
# Epoch 300 | Train Loss 0.658925 | Val Loss 0.570439
# Early stopping at epoch 361
# Modelo salvo em:
# weights/model_arch16_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7895, MSE = 4.7902e-02
# Theta | Train_2 -> R² = 0.6037, MSE = 9.0479e-02
# Theta | Test_1 -> R² = 0.4586, MSE = 1.2402e-01
# Theta | Test_2 -> R² = 0.8619, MSE = 3.2738e-02
# Theta | Test_3 -> R² = 0.7080, MSE = 9.5777e-02
# Theta | Val -> R² = -2.2705, MSE = 1.0676e+00
# Theta | LSG_1 -> R² = 0.5735, MSE = 1.7805e-01
# Theta | LSG_2 -> R² = -2.9650, MSE = 1.3878e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 0.992260 | Val Loss 0.842153
# Epoch 100 | Train Loss 0.739913 | Val Loss 0.541794
# Epoch 200 | Train Loss 0.679058 | Val Loss 0.575203
# Epoch 300 | Train Loss 0.659430 | Val Loss 0.597652
# Early stopping at epoch 303
# Modelo salvo em:
# weights/model_arch16_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7309, MSE = 6.1247e-02
# Theta | Train_2 -> R² = 0.6284, MSE = 8.4830e-02
# Theta | Test_1 -> R² = 0.1664, MSE = 1.9097e-01
# Theta | Test_2 -> R² = 0.8514, MSE = 3.5228e-02
# Theta | Test_3 -> R² = 0.5831, MSE = 1.3674e-01
# Theta | Val -> R² = -4.2675, MSE = 1.7195e+00
# Theta | LSG_1 -> R² = 0.3288, MSE = 2.8019e-01
# Theta | LSG_2 -> R² = -4.1041, MSE = 1.7865e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 0.995380 | Val Loss 0.766867
# Epoch 100 | Train Loss 0.808139 | Val Loss 0.568427
# Epoch 200 | Train Loss 0.738312 | Val Loss 0.541473
# Epoch 300 | Train Loss 0.676712 | Val Loss 0.564218
# Epoch 400 | Train Loss 0.659851 | Val Loss 0.552167
# Early stopping at epoch 416
# Modelo salvo em:
# weights/model_arch16_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7610, MSE = 5.4397e-02
# Theta | Train_2 -> R² = 0.5966, MSE = 9.2080e-02
# Theta | Test_1 -> R² = 0.3976, MSE = 1.3800e-01
# Theta | Test_2 -> R² = 0.8626, MSE = 3.2572e-02
# Theta | Test_3 -> R² = 0.6993, MSE = 9.8647e-02
# Theta | Val -> R² = -1.8235, MSE = 9.2167e-01
# Theta | LSG_1 -> R² = 0.6705, MSE = 1.3756e-01
# Theta | LSG_2 -> R² = -2.3305, MSE = 1.1657e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 1.021260 | Val Loss 0.866379
# Epoch 100 | Train Loss 0.778303 | Val Loss 0.556904
# Epoch 200 | Train Loss 0.700542 | Val Loss 0.547732
# Epoch 300 | Train Loss 0.670604 | Val Loss 0.566100
# Early stopping at epoch 350
# Modelo salvo em:
# weights/model_arch16_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7311, MSE = 6.1208e-02
# Theta | Train_2 -> R² = 0.5629, MSE = 9.9782e-02
# Theta | Test_1 -> R² = 0.2198, MSE = 1.7873e-01
# Theta | Test_2 -> R² = 0.8591, MSE = 3.3414e-02
# Theta | Test_3 -> R² = 0.7006, MSE = 9.8204e-02
# Theta | Val -> R² = -2.6734, MSE = 1.1991e+00
# Theta | LSG_1 -> R² = 0.5420, MSE = 1.9119e-01
# Theta | LSG_2 -> R² = -3.0107, MSE = 1.4038e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 0.978308 | Val Loss 0.802922
# Epoch 100 | Train Loss 0.799045 | Val Loss 0.562723
# Epoch 200 | Train Loss 0.735730 | Val Loss 0.538158
# Epoch 300 | Train Loss 0.673402 | Val Loss 0.557499
# Epoch 400 | Train Loss 0.652146 | Val Loss 0.560990
# Early stopping at epoch 409
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7879, MSE = 4.8276e-02
# Theta | Train_2 -> R² = 0.6189, MSE = 8.6993e-02
# Theta | Test_1 -> R² = 0.4474, MSE = 1.2659e-01
# Theta | Test_2 -> R² = 0.8636, MSE = 3.2342e-02
# Theta | Test_3 -> R² = 0.5999, MSE = 1.3123e-01
# Theta | Val -> R² = -2.7750, MSE = 1.2323e+00
# Theta | LSG_1 -> R² = 0.6748, MSE = 1.3574e-01
# Theta | LSG_2 -> R² = -2.1136, MSE = 1.0898e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 0.977586 | Val Loss 0.834480
# Epoch 100 | Train Loss 0.685498 | Val Loss 0.619973
# Epoch 200 | Train Loss 0.669543 | Val Loss 0.599294
# Early stopping at epoch 266
# Modelo salvo em:
# weights/model_arch16_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7833, MSE = 4.9307e-02
# Theta | Train_2 -> R² = 0.5451, MSE = 1.0385e-01
# Theta | Test_1 -> R² = 0.4557, MSE = 1.2470e-01
# Theta | Test_2 -> R² = 0.8716, MSE = 3.0439e-02
# Theta | Test_3 -> R² = 0.1075, MSE = 2.9274e-01
# Theta | Val -> R² = -7.5569, MSE = 2.7932e+00
# Theta | LSG_1 -> R² = 0.3647, MSE = 2.6519e-01
# Theta | LSG_2 -> R² = -2.8514, MSE = 1.3480e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 0.988996 | Val Loss 0.850993
# Epoch 100 | Train Loss 0.681979 | Val Loss 0.626014
# Epoch 200 | Train Loss 0.667731 | Val Loss 0.588663
# Early stopping at epoch 264
# Modelo salvo em:
# weights/model_arch16_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7938, MSE = 4.6922e-02
# Theta | Train_2 -> R² = 0.6470, MSE = 8.0581e-02
# Theta | Test_1 -> R² = 0.5181, MSE = 1.1039e-01
# Theta | Test_2 -> R² = 0.8867, MSE = 2.6857e-02
# Theta | Test_3 -> R² = -0.4673, MSE = 4.8131e-01
# Theta | Val -> R² = -9.8009, MSE = 3.5257e+00
# Theta | LSG_1 -> R² = 0.0615, MSE = 3.9176e-01
# Theta | LSG_2 -> R² = -4.1684, MSE = 1.8089e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.965384 | Val Loss 0.788883
# Epoch 100 | Train Loss 0.684624 | Val Loss 0.632816
# Epoch 200 | Train Loss 0.670715 | Val Loss 0.606235
# Early stopping at epoch 255
# Modelo salvo em:
# weights/model_arch16_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7877, MSE = 4.8313e-02
# Theta | Train_2 -> R² = 0.5662, MSE = 9.9032e-02
# Theta | Test_1 -> R² = 0.5388, MSE = 1.0566e-01
# Theta | Test_2 -> R² = 0.8641, MSE = 3.2235e-02
# Theta | Test_3 -> R² = -0.2069, MSE = 3.9589e-01
# Theta | Val -> R² = -8.6964, MSE = 3.1652e+00
# Theta | LSG_1 -> R² = 0.2382, MSE = 3.1804e-01
# Theta | LSG_2 -> R² = -3.2953, MSE = 1.5034e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 1.029296 | Val Loss 0.884638
# Epoch 100 | Train Loss 0.687550 | Val Loss 0.602068
# Epoch 200 | Train Loss 0.670514 | Val Loss 0.607840
# Early stopping at epoch 283
# Modelo salvo em:
# weights/model_arch16_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7947, MSE = 4.6732e-02
# Theta | Train_2 -> R² = 0.5684, MSE = 9.8534e-02
# Theta | Test_1 -> R² = 0.5287, MSE = 1.0797e-01
# Theta | Test_2 -> R² = 0.8737, MSE = 2.9961e-02
# Theta | Test_3 -> R² = -0.1421, MSE = 3.7464e-01
# Theta | Val -> R² = -8.8268, MSE = 3.2078e+00
# Theta | LSG_1 -> R² = 0.2530, MSE = 3.1184e-01
# Theta | LSG_2 -> R² = -3.2319, MSE = 1.4812e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 0.977681 | Val Loss 0.813905
# Epoch 100 | Train Loss 0.687009 | Val Loss 0.630579
# Epoch 200 | Train Loss 0.673007 | Val Loss 0.604970
# Early stopping at epoch 256
# Modelo salvo em:
# weights/model_arch16_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7751, MSE = 5.1185e-02
# Theta | Train_2 -> R² = 0.5782, MSE = 9.6296e-02
# Theta | Test_1 -> R² = 0.5109, MSE = 1.1204e-01
# Theta | Test_2 -> R² = 0.8720, MSE = 3.0349e-02
# Theta | Test_3 -> R² = -0.2960, MSE = 4.2511e-01
# Theta | Val -> R² = -9.0679, MSE = 3.2865e+00
# Theta | LSG_1 -> R² = 0.2190, MSE = 3.2601e-01
# Theta | LSG_2 -> R² = -3.3036, MSE = 1.5063e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 0.973477 | Val Loss 0.821494
# Epoch 100 | Train Loss 0.683220 | Val Loss 0.625722
# Epoch 200 | Train Loss 0.670300 | Val Loss 0.604795
# Early stopping at epoch 256
# Modelo salvo em:
# weights/model_arch16_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7659, MSE = 5.3284e-02
# Theta | Train_2 -> R² = 0.5880, MSE = 9.4044e-02
# Theta | Test_1 -> R² = 0.5020, MSE = 1.1409e-01
# Theta | Test_2 -> R² = 0.8753, MSE = 2.9563e-02
# Theta | Test_3 -> R² = -0.3959, MSE = 4.5789e-01
# Theta | Val -> R² = -9.1073, MSE = 3.2994e+00
# Theta | LSG_1 -> R² = 0.2118, MSE = 3.2906e-01
# Theta | LSG_2 -> R² = -3.3975, MSE = 1.5392e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 0.983773 | Val Loss 0.843602
# Epoch 100 | Train Loss 0.684764 | Val Loss 0.628619
# Epoch 200 | Train Loss 0.673527 | Val Loss 0.604029
# Early stopping at epoch 256
# Modelo salvo em:
# weights/model_arch16_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7980, MSE = 4.5979e-02
# Theta | Train_2 -> R² = 0.6307, MSE = 8.4300e-02
# Theta | Test_1 -> R² = 0.5533, MSE = 1.0232e-01
# Theta | Test_2 -> R² = 0.8831, MSE = 2.7710e-02
# Theta | Test_3 -> R² = -0.4625, MSE = 4.7972e-01
# Theta | Val -> R² = -9.8825, MSE = 3.5524e+00
# Theta | LSG_1 -> R² = 0.0716, MSE = 3.8757e-01
# Theta | LSG_2 -> R² = -4.0443, MSE = 1.7655e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 0.967785 | Val Loss 0.800142
# Epoch 100 | Train Loss 0.685462 | Val Loss 0.640539
# Epoch 200 | Train Loss 0.670657 | Val Loss 0.601072
# Early stopping at epoch 260
# Modelo salvo em:
# weights/model_arch16_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7982, MSE = 4.5937e-02
# Theta | Train_2 -> R² = 0.5623, MSE = 9.9911e-02
# Theta | Test_1 -> R² = 0.5569, MSE = 1.0151e-01
# Theta | Test_2 -> R² = 0.8577, MSE = 3.3754e-02
# Theta | Test_3 -> R² = -0.1932, MSE = 3.9139e-01
# Theta | Val -> R² = -9.1187, MSE = 3.3031e+00
# Theta | LSG_1 -> R² = 0.1534, MSE = 3.5341e-01
# Theta | LSG_2 -> R² = -3.5315, MSE = 1.5860e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 1.019907 | Val Loss 0.872665
# Epoch 100 | Train Loss 0.685316 | Val Loss 0.627318
# Epoch 200 | Train Loss 0.672056 | Val Loss 0.600674
# Early stopping at epoch 270
# Modelo salvo em:
# weights/model_arch16_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7873, MSE = 4.8416e-02
# Theta | Train_2 -> R² = 0.5795, MSE = 9.5986e-02
# Theta | Test_1 -> R² = 0.5014, MSE = 1.1422e-01
# Theta | Test_2 -> R² = 0.8738, MSE = 2.9936e-02
# Theta | Test_3 -> R² = -0.1061, MSE = 3.6283e-01
# Theta | Val -> R² = -8.2801, MSE = 3.0293e+00
# Theta | LSG_1 -> R² = 0.2567, MSE = 3.1031e-01
# Theta | LSG_2 -> R² = -3.2992, MSE = 1.5047e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 0.988941 | Val Loss 0.841532
# Epoch 100 | Train Loss 0.685945 | Val Loss 0.636870
# Epoch 200 | Train Loss 0.669734 | Val Loss 0.605105
# Early stopping at epoch 263
# Modelo salvo em:
# weights/model_arch16_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7906, MSE = 4.7648e-02
# Theta | Train_2 -> R² = 0.6285, MSE = 8.4810e-02
# Theta | Test_1 -> R² = 0.5077, MSE = 1.1277e-01
# Theta | Test_2 -> R² = 0.8842, MSE = 2.7470e-02
# Theta | Test_3 -> R² = -0.4196, MSE = 4.6565e-01
# Theta | Val -> R² = -9.8010, MSE = 3.5258e+00
# Theta | LSG_1 -> R² = 0.0572, MSE = 3.9357e-01
# Theta | LSG_2 -> R² = -4.0446, MSE = 1.7656e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 0.986455 | Val Loss 0.819121
# Epoch 100 | Train Loss 0.714598 | Val Loss 0.544637
# Epoch 200 | Train Loss 0.664999 | Val Loss 0.537827
# Epoch 300 | Train Loss 0.646049 | Val Loss 0.556645
# Early stopping at epoch 323
# Modelo salvo em:
# weights/model_arch32_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7676, MSE = 5.2890e-02
# Theta | Train_2 -> R² = 0.6801, MSE = 7.3024e-02
# Theta | Test_1 -> R² = 0.3407, MSE = 1.5103e-01
# Theta | Test_2 -> R² = 0.8548, MSE = 3.4433e-02
# Theta | Test_3 -> R² = 0.4660, MSE = 1.7516e-01
# Theta | Val -> R² = -3.7981, MSE = 1.5662e+00
# Theta | LSG_1 -> R² = 0.4196, MSE = 2.4227e-01
# Theta | LSG_2 -> R² = -4.4813, MSE = 1.9185e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 1.013807 | Val Loss 0.845777
# Epoch 100 | Train Loss 0.745282 | Val Loss 0.547478
# Epoch 200 | Train Loss 0.667985 | Val Loss 0.525099
# Epoch 300 | Train Loss 0.649975 | Val Loss 0.543266
# Epoch 400 | Train Loss 0.626630 | Val Loss 0.646151
# Early stopping at epoch 414
# Modelo salvo em:
# weights/model_arch32_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.8116, MSE = 4.2874e-02
# Theta | Train_2 -> R² = 0.7154, MSE = 6.4961e-02
# Theta | Test_1 -> R² = 0.5653, MSE = 9.9578e-02
# Theta | Test_2 -> R² = 0.8575, MSE = 3.3802e-02
# Theta | Test_3 -> R² = 0.7491, MSE = 8.2295e-02
# Theta | Val -> R² = -0.0395, MSE = 3.3934e-01
# Theta | LSG_1 -> R² = 0.7637, MSE = 9.8663e-02
# Theta | LSG_2 -> R² = -2.0107, MSE = 1.0538e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.976981 | Val Loss 0.767067
# Epoch 100 | Train Loss 0.728518 | Val Loss 0.541440
# Epoch 200 | Train Loss 0.663493 | Val Loss 0.543085
# Epoch 300 | Train Loss 0.651584 | Val Loss 0.564925
# Early stopping at epoch 309
# Modelo salvo em:
# weights/model_arch32_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7209, MSE = 6.3516e-02
# Theta | Train_2 -> R² = 0.6158, MSE = 8.7702e-02
# Theta | Test_1 -> R² = 0.1133, MSE = 2.0312e-01
# Theta | Test_2 -> R² = 0.8418, MSE = 3.7525e-02
# Theta | Test_3 -> R² = 0.5818, MSE = 1.3718e-01
# Theta | Val -> R² = -4.5723, MSE = 1.8190e+00
# Theta | LSG_1 -> R² = 0.1536, MSE = 3.5335e-01
# Theta | LSG_2 -> R² = -4.9362, MSE = 2.0777e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 0.978954 | Val Loss 0.738999
# Epoch 100 | Train Loss 0.742840 | Val Loss 0.548921
# Epoch 200 | Train Loss 0.665676 | Val Loss 0.529480
# Epoch 300 | Train Loss 0.651756 | Val Loss 0.555379
# Early stopping at epoch 340
# Modelo salvo em:
# weights/model_arch32_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7583, MSE = 5.4999e-02
# Theta | Train_2 -> R² = 0.6325, MSE = 8.3897e-02
# Theta | Test_1 -> R² = 0.2599, MSE = 1.6953e-01
# Theta | Test_2 -> R² = 0.8550, MSE = 3.4384e-02
# Theta | Test_3 -> R² = 0.5365, MSE = 1.5203e-01
# Theta | Val -> R² = -3.8681, MSE = 1.5891e+00
# Theta | LSG_1 -> R² = 0.4624, MSE = 2.2443e-01
# Theta | LSG_2 -> R² = -4.0537, MSE = 1.7688e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 1.000285 | Val Loss 0.817397
# Epoch 100 | Train Loss 0.721590 | Val Loss 0.543636
# Epoch 200 | Train Loss 0.665580 | Val Loss 0.554576
# Epoch 300 | Train Loss 0.650228 | Val Loss 0.559619
# Early stopping at epoch 303
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7571, MSE = 5.5284e-02
# Theta | Train_2 -> R² = 0.6534, MSE = 7.9130e-02
# Theta | Test_1 -> R² = 0.2323, MSE = 1.7586e-01
# Theta | Test_2 -> R² = 0.8426, MSE = 3.7328e-02
# Theta | Test_3 -> R² = 0.5660, MSE = 1.4237e-01
# Theta | Val -> R² = -4.3863, MSE = 1.7583e+00
# Theta | LSG_1 -> R² = 0.2181, MSE = 3.2639e-01
# Theta | LSG_2 -> R² = -5.0976, MSE = 2.1342e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 0.999656 | Val Loss 0.830671
# Epoch 100 | Train Loss 0.737643 | Val Loss 0.544463
# Epoch 200 | Train Loss 0.667643 | Val Loss 0.536305
# Epoch 300 | Train Loss 0.650275 | Val Loss 0.560446
# Early stopping at epoch 322
# Modelo salvo em:
# weights/model_arch32_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7355, MSE = 6.0185e-02
# Theta | Train_2 -> R² = 0.6349, MSE = 8.3357e-02
# Theta | Test_1 -> R² = 0.2284, MSE = 1.7675e-01
# Theta | Test_2 -> R² = 0.8488, MSE = 3.5843e-02
# Theta | Test_3 -> R² = 0.6146, MSE = 1.2642e-01
# Theta | Val -> R² = -3.1801, MSE = 1.3645e+00
# Theta | LSG_1 -> R² = 0.4211, MSE = 2.4167e-01
# Theta | LSG_2 -> R² = -4.0420, MSE = 1.7647e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 0.993149 | Val Loss 0.787153
# Epoch 100 | Train Loss 0.749606 | Val Loss 0.553971
# Epoch 200 | Train Loss 0.668629 | Val Loss 0.532330
# Epoch 300 | Train Loss 0.653677 | Val Loss 0.551891
# Early stopping at epoch 387
# Modelo salvo em:
# weights/model_arch32_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7932, MSE = 4.7057e-02
# Theta | Train_2 -> R² = 0.7034, MSE = 6.7714e-02
# Theta | Test_1 -> R² = 0.5107, MSE = 1.1210e-01
# Theta | Test_2 -> R² = 0.8352, MSE = 3.9086e-02
# Theta | Test_3 -> R² = 0.7453, MSE = 8.3534e-02
# Theta | Val -> R² = 0.2179, MSE = 2.5531e-01
# Theta | LSG_1 -> R² = 0.7564, MSE = 1.0168e-01
# Theta | LSG_2 -> R² = -1.6993, MSE = 9.4478e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 0.977131 | Val Loss 0.783893
# Epoch 100 | Train Loss 0.722643 | Val Loss 0.545196
# Epoch 200 | Train Loss 0.664255 | Val Loss 0.539672
# Epoch 300 | Train Loss 0.648405 | Val Loss 0.580593
# Early stopping at epoch 319
# Modelo salvo em:
# weights/model_arch32_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7435, MSE = 5.8374e-02
# Theta | Train_2 -> R² = 0.6444, MSE = 8.1187e-02
# Theta | Test_1 -> R² = 0.2142, MSE = 1.8002e-01
# Theta | Test_2 -> R² = 0.8462, MSE = 3.6464e-02
# Theta | Test_3 -> R² = 0.5967, MSE = 1.3230e-01
# Theta | Val -> R² = -3.7251, MSE = 1.5424e+00
# Theta | LSG_1 -> R² = 0.2880, MSE = 2.9722e-01
# Theta | LSG_2 -> R² = -4.6185, MSE = 1.9665e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 0.948894 | Val Loss 0.723061
# Epoch 100 | Train Loss 0.713559 | Val Loss 0.543444
# Epoch 200 | Train Loss 0.664009 | Val Loss 0.538449
# Epoch 300 | Train Loss 0.650985 | Val Loss 0.572591
# Early stopping at epoch 371
# Modelo salvo em:
# weights/model_arch32_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.8085, MSE = 4.3586e-02
# Theta | Train_2 -> R² = 0.6960, MSE = 6.9397e-02
# Theta | Test_1 -> R² = 0.5238, MSE = 1.0908e-01
# Theta | Test_2 -> R² = 0.8629, MSE = 3.2507e-02
# Theta | Test_3 -> R² = 0.7558, MSE = 8.0096e-02
# Theta | Val -> R² = -0.0419, MSE = 3.4011e-01
# Theta | LSG_1 -> R² = 0.7573, MSE = 1.0132e-01
# Theta | LSG_2 -> R² = -2.0744, MSE = 1.0760e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 1.001396 | Val Loss 0.796371
# Epoch 100 | Train Loss 0.745198 | Val Loss 0.554232
# Epoch 200 | Train Loss 0.669510 | Val Loss 0.537392
# Epoch 300 | Train Loss 0.654162 | Val Loss 0.532745
# Epoch 400 | Train Loss 0.642821 | Val Loss 0.578367
# Early stopping at epoch 459
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.8252, MSE = 3.9777e-02
# Theta | Train_2 -> R² = 0.7101, MSE = 6.6184e-02
# Theta | Test_1 -> R² = 0.6130, MSE = 8.8659e-02
# Theta | Test_2 -> R² = 0.8586, MSE = 3.3527e-02
# Theta | Test_3 -> R² = 0.7494, MSE = 8.2197e-02
# Theta | Val -> R² = 0.4542, MSE = 1.7816e-01
# Theta | LSG_1 -> R² = 0.6066, MSE = 1.6423e-01
# Theta | LSG_2 -> R² = -1.3602, MSE = 8.2608e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 0.961305 | Val Loss 0.790359
# Epoch 100 | Train Loss 0.682233 | Val Loss 0.625196
# Epoch 200 | Train Loss 0.665517 | Val Loss 0.595334
# Early stopping at epoch 228
# Modelo salvo em:
# weights/model_arch32_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7735, MSE = 5.1550e-02
# Theta | Train_2 -> R² = 0.4925, MSE = 1.1586e-01
# Theta | Test_1 -> R² = 0.6215, MSE = 8.6700e-02
# Theta | Test_2 -> R² = 0.8066, MSE = 4.5869e-02
# Theta | Test_3 -> R² = -0.4980, MSE = 4.9137e-01
# Theta | Val -> R² = -9.6357, MSE = 3.4718e+00
# Theta | LSG_1 -> R² = 0.2264, MSE = 3.2296e-01
# Theta | LSG_2 -> R² = -2.9730, MSE = 1.3906e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 0.986119 | Val Loss 0.826213
# Epoch 100 | Train Loss 0.680405 | Val Loss 0.625284
# Epoch 200 | Train Loss 0.665989 | Val Loss 0.587088
# Epoch 300 | Train Loss 0.624203 | Val Loss 0.598300
# Epoch 400 | Train Loss 0.546644 | Val Loss 0.762786
# Early stopping at epoch 457
# Modelo salvo em:
# weights/model_arch32_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.6944, MSE = 6.9540e-02
# Theta | Train_2 -> R² = 0.8031, MSE = 4.4956e-02
# Theta | Test_1 -> R² = 0.1918, MSE = 1.8514e-01
# Theta | Test_2 -> R² = 0.6903, MSE = 7.3447e-02
# Theta | Test_3 -> R² = -1.7402, MSE = 8.9885e-01
# Theta | Val -> R² = -6.0720, MSE = 2.3085e+00
# Theta | LSG_1 -> R² = 0.0969, MSE = 3.7699e-01
# Theta | LSG_2 -> R² = -6.0570, MSE = 2.4700e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.990354 | Val Loss 0.813099
# Epoch 100 | Train Loss 0.682608 | Val Loss 0.617806
# Epoch 200 | Train Loss 0.664504 | Val Loss 0.592516
# Early stopping at epoch 235
# Modelo salvo em:
# weights/model_arch32_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7739, MSE = 5.1449e-02
# Theta | Train_2 -> R² = 0.5854, MSE = 9.4646e-02
# Theta | Test_1 -> R² = 0.5762, MSE = 9.7077e-02
# Theta | Test_2 -> R² = 0.8543, MSE = 3.4543e-02
# Theta | Test_3 -> R² = -0.8621, MSE = 6.1080e-01
# Theta | Val -> R² = -11.2880, MSE = 4.0112e+00
# Theta | LSG_1 -> R² = -0.0021, MSE = 4.1834e-01
# Theta | LSG_2 -> R² = -3.9580, MSE = 1.7353e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 0.931508 | Val Loss 0.738261
# Epoch 100 | Train Loss 0.678707 | Val Loss 0.612493
# Epoch 200 | Train Loss 0.664266 | Val Loss 0.576952
# Epoch 300 | Train Loss 0.593751 | Val Loss 0.626988
# Epoch 400 | Train Loss 0.545265 | Val Loss 0.778146
# Early stopping at epoch 444
# Modelo salvo em:
# weights/model_arch32_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7307, MSE = 6.1296e-02
# Theta | Train_2 -> R² = 0.8110, MSE = 4.3146e-02
# Theta | Test_1 -> R² = 0.3040, MSE = 1.5945e-01
# Theta | Test_2 -> R² = 0.7229, MSE = 6.5715e-02
# Theta | Test_3 -> R² = -0.6309, MSE = 5.3497e-01
# Theta | Val -> R² = -4.0390, MSE = 1.6449e+00
# Theta | LSG_1 -> R² = 0.3198, MSE = 2.8395e-01
# Theta | LSG_2 -> R² = -5.5358, MSE = 2.2876e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 0.994943 | Val Loss 0.834983
# Epoch 100 | Train Loss 0.680940 | Val Loss 0.634934
# Epoch 200 | Train Loss 0.666469 | Val Loss 0.588244
# Epoch 300 | Train Loss 0.640870 | Val Loss 0.577014
# Epoch 400 | Train Loss 0.574449 | Val Loss 0.680427
# Early stopping at epoch 466
# Modelo salvo em:
# weights/model_arch32_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.6893, MSE = 7.0707e-02
# Theta | Train_2 -> R² = 0.8346, MSE = 3.7769e-02
# Theta | Test_1 -> R² = 0.3511, MSE = 1.4865e-01
# Theta | Test_2 -> R² = 0.6539, MSE = 8.2063e-02
# Theta | Test_3 -> R² = -2.3787, MSE = 1.1083e+00
# Theta | Val -> R² = -5.1948, MSE = 2.0222e+00
# Theta | LSG_1 -> R² = 0.2593, MSE = 3.0920e-01
# Theta | LSG_2 -> R² = -4.7028, MSE = 1.9960e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 1.000929 | Val Loss 0.833658
# Epoch 100 | Train Loss 0.682673 | Val Loss 0.621814
# Epoch 200 | Train Loss 0.669791 | Val Loss 0.595675
# Early stopping at epoch 234
# Modelo salvo em:
# weights/model_arch32_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7453, MSE = 5.7972e-02
# Theta | Train_2 -> R² = 0.5124, MSE = 1.1132e-01
# Theta | Test_1 -> R² = 0.5229, MSE = 1.0930e-01
# Theta | Test_2 -> R² = 0.8206, MSE = 4.2550e-02
# Theta | Test_3 -> R² = -0.5874, MSE = 5.2070e-01
# Theta | Val -> R² = -10.2805, MSE = 3.6823e+00
# Theta | LSG_1 -> R² = 0.0928, MSE = 3.7871e-01
# Theta | LSG_2 -> R² = -3.4917, MSE = 1.5721e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 1.013283 | Val Loss 0.856751
# Epoch 100 | Train Loss 0.683274 | Val Loss 0.630832
# Epoch 200 | Train Loss 0.664388 | Val Loss 0.584218
# Epoch 300 | Train Loss 0.630057 | Val Loss 0.593251
# Epoch 400 | Train Loss 0.557188 | Val Loss 0.783689
# Early stopping at epoch 430
# Modelo salvo em:
# weights/model_arch32_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7276, MSE = 6.1983e-02
# Theta | Train_2 -> R² = 0.8204, MSE = 4.0996e-02
# Theta | Test_1 -> R² = 0.3316, MSE = 1.5311e-01
# Theta | Test_2 -> R² = 0.6260, MSE = 8.8686e-02
# Theta | Test_3 -> R² = -1.7143, MSE = 8.9033e-01
# Theta | Val -> R² = -4.4587, MSE = 1.7819e+00
# Theta | LSG_1 -> R² = 0.2323, MSE = 3.2048e-01
# Theta | LSG_2 -> R² = -4.6146, MSE = 1.9651e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 0.969620 | Val Loss 0.782196
# Epoch 100 | Train Loss 0.682528 | Val Loss 0.633467
# Epoch 200 | Train Loss 0.666543 | Val Loss 0.594630
# Early stopping at epoch 228
# Modelo salvo em:
# weights/model_arch32_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7643, MSE = 5.3649e-02
# Theta | Train_2 -> R² = 0.5269, MSE = 1.0800e-01
# Theta | Test_1 -> R² = 0.6512, MSE = 7.9893e-02
# Theta | Test_2 -> R² = 0.8193, MSE = 4.2843e-02
# Theta | Test_3 -> R² = -0.9138, MSE = 6.2777e-01
# Theta | Val -> R² = -11.1187, MSE = 3.9559e+00
# Theta | LSG_1 -> R² = 0.1213, MSE = 3.6683e-01
# Theta | LSG_2 -> R² = -3.2326, MSE = 1.4814e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 0.964753 | Val Loss 0.791452
# Epoch 100 | Train Loss 0.678425 | Val Loss 0.617693
# Epoch 200 | Train Loss 0.662199 | Val Loss 0.573382
# Epoch 300 | Train Loss 0.628454 | Val Loss 0.587186
# Epoch 400 | Train Loss 0.558733 | Val Loss 0.742334
# Early stopping at epoch 438
# Modelo salvo em:
# weights/model_arch32_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.6510, MSE = 7.9431e-02
# Theta | Train_2 -> R² = 0.8224, MSE = 4.0542e-02
# Theta | Test_1 -> R² = 0.2037, MSE = 1.8243e-01
# Theta | Test_2 -> R² = 0.6694, MSE = 7.8387e-02
# Theta | Test_3 -> R² = -2.8697, MSE = 1.2693e+00
# Theta | Val -> R² = -6.5033, MSE = 2.4493e+00
# Theta | LSG_1 -> R² = 0.2347, MSE = 3.1946e-01
# Theta | LSG_2 -> R² = -4.8918, MSE = 2.0622e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 0.981758 | Val Loss 0.780488
# Epoch 100 | Train Loss 0.683902 | Val Loss 0.638421
# Epoch 200 | Train Loss 0.667999 | Val Loss 0.594878
# Epoch 300 | Train Loss 0.653398 | Val Loss 0.574930
# Epoch 400 | Train Loss 0.584863 | Val Loss 0.698658
# Early stopping at epoch 492
# Modelo salvo em:
# weights/model_arch32_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7054, MSE = 6.7054e-02
# Theta | Train_2 -> R² = 0.8192, MSE = 4.1272e-02
# Theta | Test_1 -> R² = 0.3597, MSE = 1.4668e-01
# Theta | Test_2 -> R² = 0.7116, MSE = 6.8388e-02
# Theta | Test_3 -> R² = -2.6698, MSE = 1.2037e+00
# Theta | Val -> R² = -6.6091, MSE = 2.4838e+00
# Theta | LSG_1 -> R² = 0.1819, MSE = 3.4151e-01
# Theta | LSG_2 -> R² = -4.9844, MSE = 2.0946e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 1.036849 | Val Loss 0.822806
# Epoch 100 | Train Loss 0.686836 | Val Loss 0.536824
# Epoch 200 | Train Loss 0.656651 | Val Loss 0.510131
# Epoch 300 | Train Loss 0.647679 | Val Loss 0.547616
# Early stopping at epoch 391
# Modelo salvo em:
# weights/model_arch64_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.8067, MSE = 4.3981e-02
# Theta | Train_2 -> R² = 0.7259, MSE = 6.2568e-02
# Theta | Test_1 -> R² = 0.5697, MSE = 9.8563e-02
# Theta | Test_2 -> R² = 0.8569, MSE = 3.3925e-02
# Theta | Test_3 -> R² = 0.5455, MSE = 1.4907e-01
# Theta | Val -> R² = -0.8472, MSE = 6.0298e-01
# Theta | LSG_1 -> R² = 0.7537, MSE = 1.0284e-01
# Theta | LSG_2 -> R² = -2.3792, MSE = 1.1827e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 1.123858 | Val Loss 0.816733
# Epoch 100 | Train Loss 0.696434 | Val Loss 0.541138
# Epoch 200 | Train Loss 0.660346 | Val Loss 0.515433
# Epoch 300 | Train Loss 0.650610 | Val Loss 0.534002
# Early stopping at epoch 393
# Modelo salvo em:
# weights/model_arch64_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.8094, MSE = 4.3370e-02
# Theta | Train_2 -> R² = 0.7283, MSE = 6.2034e-02
# Theta | Test_1 -> R² = 0.5593, MSE = 1.0096e-01
# Theta | Test_2 -> R² = 0.8531, MSE = 3.4827e-02
# Theta | Test_3 -> R² = 0.5277, MSE = 1.5494e-01
# Theta | Val -> R² = -1.0767, MSE = 6.7790e-01
# Theta | LSG_1 -> R² = 0.7601, MSE = 1.0015e-01
# Theta | LSG_2 -> R² = -2.6123, MSE = 1.2643e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 1.044381 | Val Loss 0.825031
# Epoch 100 | Train Loss 0.683368 | Val Loss 0.534540
# Epoch 200 | Train Loss 0.656686 | Val Loss 0.510659
# Epoch 300 | Train Loss 0.647090 | Val Loss 0.512592
# Epoch 400 | Train Loss 0.595014 | Val Loss 0.872668
# Early stopping at epoch 425
# Modelo salvo em:
# weights/model_arch64_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.8002, MSE = 4.5472e-02
# Theta | Train_2 -> R² = 0.7292, MSE = 6.1823e-02
# Theta | Test_1 -> R² = 0.6149, MSE = 8.8211e-02
# Theta | Test_2 -> R² = 0.8488, MSE = 3.5846e-02
# Theta | Test_3 -> R² = 0.4550, MSE = 1.7876e-01
# Theta | Val -> R² = -0.1747, MSE = 3.8345e-01
# Theta | LSG_1 -> R² = 0.6059, MSE = 1.6453e-01
# Theta | LSG_2 -> R² = -1.5239, MSE = 8.8337e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 0.982861 | Val Loss 0.763190
# Epoch 100 | Train Loss 0.677120 | Val Loss 0.531072
# Epoch 200 | Train Loss 0.655786 | Val Loss 0.514851
# Epoch 300 | Train Loss 0.649512 | Val Loss 0.516791
# Epoch 400 | Train Loss 0.611907 | Val Loss 0.664226
# Early stopping at epoch 446
# Modelo salvo em:
# weights/model_arch64_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7989, MSE = 4.5765e-02
# Theta | Train_2 -> R² = 0.7119, MSE = 6.5773e-02
# Theta | Test_1 -> R² = 0.5877, MSE = 9.4449e-02
# Theta | Test_2 -> R² = 0.8508, MSE = 3.5386e-02
# Theta | Test_3 -> R² = 0.6457, MSE = 1.1621e-01
# Theta | Val -> R² = 0.2662, MSE = 2.3955e-01
# Theta | LSG_1 -> R² = 0.5543, MSE = 1.8607e-01
# Theta | LSG_2 -> R² = -1.3648, MSE = 8.2771e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 1.006733 | Val Loss 0.838332
# Epoch 100 | Train Loss 0.673755 | Val Loss 0.528305
# Epoch 200 | Train Loss 0.653925 | Val Loss 0.516450
# Epoch 300 | Train Loss 0.617265 | Val Loss 0.615306
# Early stopping at epoch 345
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7919, MSE = 4.7364e-02
# Theta | Train_2 -> R² = 0.7185, MSE = 6.4254e-02
# Theta | Test_1 -> R² = 0.5077, MSE = 1.1277e-01
# Theta | Test_2 -> R² = 0.8479, MSE = 3.6070e-02
# Theta | Test_3 -> R² = 0.5316, MSE = 1.5365e-01
# Theta | Val -> R² = -1.3919, MSE = 7.8080e-01
# Theta | LSG_1 -> R² = 0.7545, MSE = 1.0250e-01
# Theta | LSG_2 -> R² = -2.8656, MSE = 1.3530e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 0.993740 | Val Loss 0.774774
# Epoch 100 | Train Loss 0.677587 | Val Loss 0.532632
# Epoch 200 | Train Loss 0.655025 | Val Loss 0.507815
# Epoch 300 | Train Loss 0.625503 | Val Loss 0.558491
# Epoch 400 | Train Loss 0.580903 | Val Loss 0.889212
# Early stopping at epoch 410
# Modelo salvo em:
# weights/model_arch64_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.8072, MSE = 4.3877e-02
# Theta | Train_2 -> R² = 0.7099, MSE = 6.6236e-02
# Theta | Test_1 -> R² = 0.6014, MSE = 9.1303e-02
# Theta | Test_2 -> R² = 0.8614, MSE = 3.2876e-02
# Theta | Test_3 -> R² = 0.6040, MSE = 1.2989e-01
# Theta | Val -> R² = -0.2512, MSE = 4.0842e-01
# Theta | LSG_1 -> R² = 0.6832, MSE = 1.3226e-01
# Theta | LSG_2 -> R² = -1.8424, MSE = 9.9486e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 1.047027 | Val Loss 0.797569
# Epoch 100 | Train Loss 0.685753 | Val Loss 0.533888
# Epoch 200 | Train Loss 0.655192 | Val Loss 0.519812
# Epoch 300 | Train Loss 0.642711 | Val Loss 0.587665
# Early stopping at epoch 370
# Modelo salvo em:
# weights/model_arch64_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.8130, MSE = 4.2566e-02
# Theta | Train_2 -> R² = 0.7235, MSE = 6.3111e-02
# Theta | Test_1 -> R² = 0.5705, MSE = 9.8399e-02
# Theta | Test_2 -> R² = 0.8559, MSE = 3.4162e-02
# Theta | Test_3 -> R² = 0.6702, MSE = 1.0817e-01
# Theta | Val -> R² = -0.3328, MSE = 4.3507e-01
# Theta | LSG_1 -> R² = 0.7497, MSE = 1.0448e-01
# Theta | LSG_2 -> R² = -2.2116, MSE = 1.1241e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 1.001764 | Val Loss 0.791605
# Epoch 100 | Train Loss 0.676716 | Val Loss 0.530858
# Epoch 200 | Train Loss 0.655714 | Val Loss 0.508845
# Epoch 300 | Train Loss 0.646388 | Val Loss 0.528373
# Epoch 400 | Train Loss 0.588361 | Val Loss 0.881618
# Early stopping at epoch 403
# Modelo salvo em:
# weights/model_arch64_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7992, MSE = 4.5694e-02
# Theta | Train_2 -> R² = 0.7246, MSE = 6.2875e-02
# Theta | Test_1 -> R² = 0.5984, MSE = 9.2002e-02
# Theta | Test_2 -> R² = 0.8446, MSE = 3.6839e-02
# Theta | Test_3 -> R² = 0.5058, MSE = 1.6211e-01
# Theta | Val -> R² = -0.2662, MSE = 4.1334e-01
# Theta | LSG_1 -> R² = 0.6830, MSE = 1.3235e-01
# Theta | LSG_2 -> R² = -1.6993, MSE = 9.4476e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 1.014504 | Val Loss 0.781522
# Epoch 100 | Train Loss 0.680265 | Val Loss 0.532211
# Epoch 200 | Train Loss 0.655571 | Val Loss 0.508361
# Epoch 300 | Train Loss 0.641716 | Val Loss 0.535535
# Early stopping at epoch 388
# Modelo salvo em:
# weights/model_arch64_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.8036, MSE = 4.4705e-02
# Theta | Train_2 -> R² = 0.7234, MSE = 6.3138e-02
# Theta | Test_1 -> R² = 0.5891, MSE = 9.4138e-02
# Theta | Test_2 -> R² = 0.8500, MSE = 3.5563e-02
# Theta | Test_3 -> R² = 0.4745, MSE = 1.7238e-01
# Theta | Val -> R² = -0.6349, MSE = 5.3370e-01
# Theta | LSG_1 -> R² = 0.7336, MSE = 1.1122e-01
# Theta | LSG_2 -> R² = -1.9912, MSE = 1.0469e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 1.006950 | Val Loss 0.752764
# Epoch 100 | Train Loss 0.677108 | Val Loss 0.530421
# Epoch 200 | Train Loss 0.655608 | Val Loss 0.509504
# Epoch 300 | Train Loss 0.648215 | Val Loss 0.531114
# Epoch 400 | Train Loss 0.622082 | Val Loss 0.697859
# Early stopping at epoch 413
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.8037, MSE = 4.4667e-02
# Theta | Train_2 -> R² = 0.7235, MSE = 6.3125e-02
# Theta | Test_1 -> R² = 0.5936, MSE = 9.3089e-02
# Theta | Test_2 -> R² = 0.8530, MSE = 3.4854e-02
# Theta | Test_3 -> R² = 0.5372, MSE = 1.5179e-01
# Theta | Val -> R² = -0.3610, MSE = 4.4427e-01
# Theta | LSG_1 -> R² = 0.6891, MSE = 1.2977e-01
# Theta | LSG_2 -> R² = -1.8553, MSE = 9.9936e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 0.990213 | Val Loss 0.800872
# Epoch 100 | Train Loss 0.675570 | Val Loss 0.599043
# Epoch 200 | Train Loss 0.656529 | Val Loss 0.560405
# Epoch 300 | Train Loss 0.559238 | Val Loss 0.706233
# Epoch 400 | Train Loss 0.522932 | Val Loss 0.874619
# Early stopping at epoch 411
# Modelo salvo em:
# weights/model_arch64_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.6369, MSE = 8.2642e-02
# Theta | Train_2 -> R² = 0.8150, MSE = 4.2228e-02
# Theta | Test_1 -> R² = 0.2430, MSE = 1.7342e-01
# Theta | Test_2 -> R² = 0.5531, MSE = 1.0597e-01
# Theta | Test_3 -> R² = -3.0645, MSE = 1.3332e+00
# Theta | Val -> R² = -6.1494, MSE = 2.3338e+00
# Theta | LSG_1 -> R² = 0.1543, MSE = 3.5303e-01
# Theta | LSG_2 -> R² = -4.4232, MSE = 1.8982e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 0.930464 | Val Loss 0.700805
# Epoch 100 | Train Loss 0.674386 | Val Loss 0.603936
# Epoch 200 | Train Loss 0.653488 | Val Loss 0.559899
# Epoch 300 | Train Loss 0.548819 | Val Loss 0.747280
# Epoch 400 | Train Loss 0.521088 | Val Loss 0.872135
# Early stopping at epoch 408
# Modelo salvo em:
# weights/model_arch64_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7146, MSE = 6.4951e-02
# Theta | Train_2 -> R² = 0.7840, MSE = 4.9306e-02
# Theta | Test_1 -> R² = 0.2813, MSE = 1.6463e-01
# Theta | Test_2 -> R² = 0.7251, MSE = 6.5184e-02
# Theta | Test_3 -> R² = -1.1414, MSE = 7.0242e-01
# Theta | Val -> R² = -4.9732, MSE = 1.9499e+00
# Theta | LSG_1 -> R² = 0.2948, MSE = 2.9440e-01
# Theta | LSG_2 -> R² = -5.2495, MSE = 2.1874e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.966490 | Val Loss 0.754187
# Epoch 100 | Train Loss 0.675391 | Val Loss 0.598295
# Epoch 200 | Train Loss 0.653779 | Val Loss 0.559658
# Epoch 300 | Train Loss 0.552257 | Val Loss 0.746473
# Epoch 400 | Train Loss 0.522732 | Val Loss 0.864265
# Early stopping at epoch 403
# Modelo salvo em:
# weights/model_arch64_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.6715, MSE = 7.4752e-02
# Theta | Train_2 -> R² = 0.8099, MSE = 4.3398e-02
# Theta | Test_1 -> R² = 0.2664, MSE = 1.6806e-01
# Theta | Test_2 -> R² = 0.6484, MSE = 8.3385e-02
# Theta | Test_3 -> R² = -1.7616, MSE = 9.0585e-01
# Theta | Val -> R² = -4.4631, MSE = 1.7833e+00
# Theta | LSG_1 -> R² = 0.3088, MSE = 2.8856e-01
# Theta | LSG_2 -> R² = -4.7773, MSE = 2.0221e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 0.987826 | Val Loss 0.760773
# Epoch 100 | Train Loss 0.676947 | Val Loss 0.612708
# Epoch 200 | Train Loss 0.657485 | Val Loss 0.564613
# Epoch 300 | Train Loss 0.562082 | Val Loss 0.720537
# Epoch 400 | Train Loss 0.531131 | Val Loss 0.818812
# Early stopping at epoch 417
# Modelo salvo em:
# weights/model_arch64_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.6890, MSE = 7.0781e-02
# Theta | Train_2 -> R² = 0.8154, MSE = 4.2131e-02
# Theta | Test_1 -> R² = 0.3039, MSE = 1.5947e-01
# Theta | Test_2 -> R² = 0.6452, MSE = 8.4135e-02
# Theta | Test_3 -> R² = -1.7127, MSE = 8.8981e-01
# Theta | Val -> R² = -5.3609, MSE = 2.0764e+00
# Theta | LSG_1 -> R² = 0.1140, MSE = 3.6985e-01
# Theta | LSG_2 -> R² = -5.0656, MSE = 2.1230e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 1.001558 | Val Loss 0.811569
# Epoch 100 | Train Loss 0.677252 | Val Loss 0.616380
# Epoch 200 | Train Loss 0.657884 | Val Loss 0.568207
# Epoch 300 | Train Loss 0.569872 | Val Loss 0.694559
# Epoch 400 | Train Loss 0.526611 | Val Loss 0.854233
# Early stopping at epoch 414
# Modelo salvo em:
# weights/model_arch64_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.6952, MSE = 6.9370e-02
# Theta | Train_2 -> R² = 0.8177, MSE = 4.1618e-02
# Theta | Test_1 -> R² = 0.2696, MSE = 1.6732e-01
# Theta | Test_2 -> R² = 0.6230, MSE = 8.9393e-02
# Theta | Test_3 -> R² = -2.5960, MSE = 1.1795e+00
# Theta | Val -> R² = -6.6225, MSE = 2.4882e+00
# Theta | LSG_1 -> R² = 0.1123, MSE = 3.7057e-01
# Theta | LSG_2 -> R² = -5.2821, MSE = 2.1988e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 1.012882 | Val Loss 0.816005
# Epoch 100 | Train Loss 0.676020 | Val Loss 0.608270
# Epoch 200 | Train Loss 0.658913 | Val Loss 0.571348
# Epoch 300 | Train Loss 0.561602 | Val Loss 0.698397
# Epoch 400 | Train Loss 0.530015 | Val Loss 0.806119
# Early stopping at epoch 416
# Modelo salvo em:
# weights/model_arch64_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7296, MSE = 6.1542e-02
# Theta | Train_2 -> R² = 0.8096, MSE = 4.3472e-02
# Theta | Test_1 -> R² = 0.3103, MSE = 1.5799e-01
# Theta | Test_2 -> R² = 0.6924, MSE = 7.2938e-02
# Theta | Test_3 -> R² = -1.5878, MSE = 8.4883e-01
# Theta | Val -> R² = -6.5090, MSE = 2.4512e+00
# Theta | LSG_1 -> R² = 0.0675, MSE = 3.8927e-01
# Theta | LSG_2 -> R² = -5.5101, MSE = 2.2786e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 1.036255 | Val Loss 0.779350
# Epoch 100 | Train Loss 0.678899 | Val Loss 0.621749
# Epoch 200 | Train Loss 0.658754 | Val Loss 0.573983
# Epoch 300 | Train Loss 0.569187 | Val Loss 0.688389
# Epoch 400 | Train Loss 0.537589 | Val Loss 0.802138
# Early stopping at epoch 409
# Modelo salvo em:
# weights/model_arch64_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7281, MSE = 6.1883e-02
# Theta | Train_2 -> R² = 0.8176, MSE = 4.1645e-02
# Theta | Test_1 -> R² = 0.2750, MSE = 1.6608e-01
# Theta | Test_2 -> R² = 0.6874, MSE = 7.4122e-02
# Theta | Test_3 -> R² = -1.0427, MSE = 6.7005e-01
# Theta | Val -> R² = -5.4564, MSE = 2.1076e+00
# Theta | LSG_1 -> R² = 0.0510, MSE = 3.9618e-01
# Theta | LSG_2 -> R² = -6.4498, MSE = 2.6075e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 1.002384 | Val Loss 0.786300
# Epoch 100 | Train Loss 0.677004 | Val Loss 0.607500
# Epoch 200 | Train Loss 0.651240 | Val Loss 0.561653
# Epoch 300 | Train Loss 0.550659 | Val Loss 0.761355
# Epoch 400 | Train Loss 0.524883 | Val Loss 0.878576
# Early stopping at epoch 404
# Modelo salvo em:
# weights/model_arch64_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.6197, MSE = 8.6543e-02
# Theta | Train_2 -> R² = 0.8022, MSE = 4.5155e-02
# Theta | Test_1 -> R² = 0.2570, MSE = 1.7020e-01
# Theta | Test_2 -> R² = 0.6279, MSE = 8.8230e-02
# Theta | Test_3 -> R² = -3.6978, MSE = 1.5410e+00
# Theta | Val -> R² = -6.6842, MSE = 2.5084e+00
# Theta | LSG_1 -> R² = 0.3058, MSE = 2.8981e-01
# Theta | LSG_2 -> R² = -3.9678, MSE = 1.7388e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 1.006782 | Val Loss 0.794739
# Epoch 100 | Train Loss 0.677986 | Val Loss 0.621759
# Epoch 200 | Train Loss 0.658118 | Val Loss 0.569380
# Epoch 300 | Train Loss 0.560821 | Val Loss 0.714182
# Epoch 400 | Train Loss 0.528054 | Val Loss 0.861848
# Early stopping at epoch 421
# Modelo salvo em:
# weights/model_arch64_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.6996, MSE = 6.8355e-02
# Theta | Train_2 -> R² = 0.7995, MSE = 4.5777e-02
# Theta | Test_1 -> R² = 0.2998, MSE = 1.6039e-01
# Theta | Test_2 -> R² = 0.6339, MSE = 8.6818e-02
# Theta | Test_3 -> R² = -2.0231, MSE = 9.9163e-01
# Theta | Val -> R² = -5.7179, MSE = 2.1929e+00
# Theta | LSG_1 -> R² = 0.2016, MSE = 3.3329e-01
# Theta | LSG_2 -> R² = -4.7203, MSE = 2.0021e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 1.000312 | Val Loss 0.822413
# Epoch 100 | Train Loss 0.676664 | Val Loss 0.604835
# Epoch 200 | Train Loss 0.654997 | Val Loss 0.560830
# Epoch 300 | Train Loss 0.546841 | Val Loss 0.789316
# Epoch 400 | Train Loss 0.521192 | Val Loss 0.882812
# Early stopping at epoch 408
# Modelo salvo em:
# weights/model_arch64_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.6973, MSE = 6.8894e-02
# Theta | Train_2 -> R² = 0.8021, MSE = 4.5170e-02
# Theta | Test_1 -> R² = 0.3051, MSE = 1.5918e-01
# Theta | Test_2 -> R² = 0.6399, MSE = 8.5385e-02
# Theta | Test_3 -> R² = -2.0584, MSE = 1.0032e+00
# Theta | Val -> R² = -4.8095, MSE = 1.8964e+00
# Theta | LSG_1 -> R² = 0.3949, MSE = 2.5262e-01
# Theta | LSG_2 -> R² = -4.3624, MSE = 1.8769e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 1.072757 | Val Loss 0.725426
# Epoch 100 | Train Loss 0.664317 | Val Loss 0.516402
# Epoch 200 | Train Loss 0.653031 | Val Loss 0.499822
# Epoch 300 | Train Loss 0.647868 | Val Loss 0.508784
# Epoch 400 | Train Loss 0.603288 | Val Loss 0.789938
# Early stopping at epoch 435
# Modelo salvo em:
# weights/model_arch128_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.8039, MSE = 4.4640e-02
# Theta | Train_2 -> R² = 0.7267, MSE = 6.2385e-02
# Theta | Test_1 -> R² = 0.6237, MSE = 8.6192e-02
# Theta | Test_2 -> R² = 0.8458, MSE = 3.6555e-02
# Theta | Test_3 -> R² = 0.3887, MSE = 2.0052e-01
# Theta | Val -> R² = -0.4827, MSE = 4.8401e-01
# Theta | LSG_1 -> R² = 0.6805, MSE = 1.3339e-01
# Theta | LSG_2 -> R² = -1.7381, MSE = 9.5834e-01
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 1.116530 | Val Loss 0.752732
# Epoch 100 | Train Loss 0.668734 | Val Loss 0.521341
# Epoch 200 | Train Loss 0.653011 | Val Loss 0.501587
# Epoch 300 | Train Loss 0.646443 | Val Loss 0.503611
# Epoch 400 | Train Loss 0.591079 | Val Loss 0.797877
# Early stopping at epoch 439
# Modelo salvo em:
# weights/model_arch128_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7954, MSE = 4.6566e-02
# Theta | Train_2 -> R² = 0.7169, MSE = 6.4628e-02
# Theta | Test_1 -> R² = 0.6038, MSE = 9.0772e-02
# Theta | Test_2 -> R² = 0.8420, MSE = 3.7474e-02
# Theta | Test_3 -> R² = 0.4375, MSE = 1.8451e-01
# Theta | Val -> R² = -0.1346, MSE = 3.7037e-01
# Theta | LSG_1 -> R² = 0.6309, MSE = 1.5408e-01
# Theta | LSG_2 -> R² = -1.4752, MSE = 8.6632e-01
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 1.082555 | Val Loss 0.762870
# Epoch 100 | Train Loss 0.666760 | Val Loss 0.521370
# Epoch 200 | Train Loss 0.652399 | Val Loss 0.502184
# Epoch 300 | Train Loss 0.639560 | Val Loss 0.505018
# Epoch 400 | Train Loss 0.589006 | Val Loss 0.760647
# Early stopping at epoch 478
# Modelo salvo em:
# weights/model_arch128_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7259, MSE = 6.2383e-02
# Theta | Train_2 -> R² = 0.7304, MSE = 6.1539e-02
# Theta | Test_1 -> R² = 0.6014, MSE = 9.1321e-02
# Theta | Test_2 -> R² = 0.8424, MSE = 3.7370e-02
# Theta | Test_3 -> R² = 0.4524, MSE = 1.7961e-01
# Theta | Val -> R² = 0.5455, MSE = 1.4837e-01
# Theta | LSG_1 -> R² = 0.4520, MSE = 2.2879e-01
# Theta | LSG_2 -> R² = -1.0120, MSE = 7.0421e-01
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 1.137644 | Val Loss 0.801190
# Epoch 100 | Train Loss 0.666585 | Val Loss 0.521937
# Epoch 200 | Train Loss 0.653339 | Val Loss 0.507087
# Epoch 300 | Train Loss 0.650625 | Val Loss 0.503765
# Epoch 400 | Train Loss 0.641737 | Val Loss 0.548418
# Early stopping at epoch 452
# Modelo salvo em:
# weights/model_arch128_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.8081, MSE = 4.3674e-02
# Theta | Train_2 -> R² = 0.7205, MSE = 6.3807e-02
# Theta | Test_1 -> R² = 0.6076, MSE = 8.9899e-02
# Theta | Test_2 -> R² = 0.8493, MSE = 3.5733e-02
# Theta | Test_3 -> R² = 0.5934, MSE = 1.3337e-01
# Theta | Val -> R² = -0.1699, MSE = 3.8189e-01
# ...
# Epoch 200 | Train Loss 0.536091 | Val Loss 0.847360
# Early stopping at epoch 208
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.8399, MSE = 3.6433e-02
# Theta | Train_2 -> R² = 0.4848, MSE = 1.1762e-01
# Theta | Test_1 -> R² = 0.6332, MSE = 8.4027e-02
# Theta | Test_2 -> R² = 0.8413, MSE = 3.7622e-02
# Theta | Test_3 -> R² = 0.3037, MSE = 2.2840e-01
# Theta | Val -> R² = -6.4082, MSE = 2.4183e+00
# Theta | LSG_1 -> R² = 0.5528, MSE = 1.8667e-01
# Theta | LSG_2 -> R² = -1.8162, MSE = 9.8570e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 0.974347 | Val Loss 0.789390
# Epoch 100 | Train Loss 0.645268 | Val Loss 0.602167
# Epoch 200 | Train Loss 0.539265 | Val Loss 0.857070
# Early stopping at epoch 209
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.8788, MSE = 2.7588e-02
# Theta | Train_2 -> R² = 0.5673, MSE = 9.8790e-02
# Theta | Test_1 -> R² = 0.5098, MSE = 1.1229e-01
# Theta | Test_2 -> R² = 0.8175, MSE = 4.3281e-02
# Theta | Test_3 -> R² = 0.2523, MSE = 2.4524e-01
# Theta | Val -> R² = -8.7400, MSE = 3.1795e+00
# Theta | LSG_1 -> R² = 0.1202, MSE = 3.6726e-01
# Theta | LSG_2 -> R² = -3.7945, MSE = 1.6781e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 0.995568 | Val Loss 0.814392
# Epoch 100 | Train Loss 0.641818 | Val Loss 0.594796
# Epoch 200 | Train Loss 0.542217 | Val Loss 0.853642
# Early stopping at epoch 208
# Modelo salvo em:
# weights/model_arch128-64-32_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.8470, MSE = 3.4822e-02
# Theta | Train_2 -> R² = 0.5685, MSE = 9.8500e-02
# Theta | Test_1 -> R² = 0.6492, MSE = 8.0351e-02
# Theta | Test_2 -> R² = 0.8613, MSE = 3.2884e-02
# Theta | Test_3 -> R² = 0.0747, MSE = 3.0352e-01
# Theta | Val -> R² = -7.9742, MSE = 2.9295e+00
# Theta | LSG_1 -> R² = 0.3297, MSE = 2.7982e-01
# Theta | LSG_2 -> R² = -2.8622, MSE = 1.3518e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 0.965426 | Val Loss 0.666738
# Epoch 100 | Train Loss 0.641371 | Val Loss 0.555388
# Epoch 200 | Train Loss 0.578925 | Val Loss 0.750428
# Early stopping at epoch 281
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7866, MSE = 4.8574e-02
# Theta | Train_2 -> R² = 0.7827, MSE = 4.9607e-02
# Theta | Test_1 -> R² = 0.7545, MSE = 5.6232e-02
# Theta | Test_2 -> R² = 0.8955, MSE = 2.4783e-02
# Theta | Test_3 -> R² = 0.2178, MSE = 2.5657e-01
# Theta | Val -> R² = -0.9816, MSE = 6.4684e-01
# Theta | LSG_1 -> R² = 0.7082, MSE = 1.2181e-01
# Theta | LSG_2 -> R² = -1.2810, MSE = 7.9836e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 1.017941 | Val Loss 0.693960
# Epoch 100 | Train Loss 0.636403 | Val Loss 0.514804
# Epoch 200 | Train Loss 0.559328 | Val Loss 0.786640
# Early stopping at epoch 273
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.8369, MSE = 3.7119e-02
# Theta | Train_2 -> R² = 0.6662, MSE = 7.6205e-02
# Theta | Test_1 -> R² = 0.7757, MSE = 5.1394e-02
# Theta | Test_2 -> R² = 0.7103, MSE = 6.8695e-02
# Theta | Test_3 -> R² = 0.2787, MSE = 2.3660e-01
# Theta | Val -> R² = -0.4442, MSE = 4.7144e-01
# Theta | LSG_1 -> R² = 0.6483, MSE = 1.4682e-01
# Theta | LSG_2 -> R² = -1.2550, MSE = 7.8927e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.968871 | Val Loss 0.626323
# Epoch 100 | Train Loss 0.617904 | Val Loss 0.551993
# Epoch 200 | Train Loss 0.576249 | Val Loss 0.804122
# Early stopping at epoch 261
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.8447, MSE = 3.5333e-02
# Theta | Train_2 -> R² = 0.7721, MSE = 5.2033e-02
# Theta | Test_1 -> R² = 0.8389, MSE = 3.6905e-02
# Theta | Test_2 -> R² = 0.8885, MSE = 2.6429e-02
# Theta | Test_3 -> R² = 0.5366, MSE = 1.5201e-01
# Theta | Val -> R² = -0.2805, MSE = 4.1800e-01
# Theta | LSG_1 -> R² = 0.6197, MSE = 1.5875e-01
# Theta | LSG_2 -> R² = -0.7330, MSE = 6.0655e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 0.991390 | Val Loss 0.610827
# Epoch 100 | Train Loss 0.613449 | Val Loss 0.534876
# Epoch 200 | Train Loss 0.558168 | Val Loss 0.762124
# Early stopping at epoch 280
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.8014, MSE = 4.5196e-02
# Theta | Train_2 -> R² = 0.7084, MSE = 6.6569e-02
# Theta | Test_1 -> R² = 0.8057, MSE = 4.4522e-02
# Theta | Test_2 -> R² = 0.8674, MSE = 3.1433e-02
# Theta | Test_3 -> R² = 0.7813, MSE = 7.1736e-02
# Theta | Val -> R² = 0.2324, MSE = 2.5057e-01
# Theta | LSG_1 -> R² = 0.7199, MSE = 1.1692e-01
# Theta | LSG_2 -> R² = -1.1178, MSE = 7.4124e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 0.989835 | Val Loss 0.627531
# Epoch 100 | Train Loss 0.615842 | Val Loss 0.569446
# Epoch 200 | Train Loss 0.570126 | Val Loss 0.728571
# Early stopping at epoch 268
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7714, MSE = 5.2018e-02
# Theta | Train_2 -> R² = 0.6399, MSE = 8.2195e-02
# Theta | Test_1 -> R² = 0.6802, MSE = 7.3265e-02
# Theta | Test_2 -> R² = 0.8448, MSE = 3.6798e-02
# Theta | Test_3 -> R² = 0.7433, MSE = 8.4192e-02
# Theta | Val -> R² = -0.3243, MSE = 4.3229e-01
# Theta | LSG_1 -> R² = 0.6597, MSE = 1.4205e-01
# Theta | LSG_2 -> R² = -1.5420, MSE = 8.8971e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 0.965470 | Val Loss 0.650610
# Epoch 100 | Train Loss 0.630337 | Val Loss 0.541997
# Epoch 200 | Train Loss 0.560252 | Val Loss 0.780937
# Early stopping at epoch 268
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7953, MSE = 4.6577e-02
# Theta | Train_2 -> R² = 0.7557, MSE = 5.5766e-02
# Theta | Test_1 -> R² = 0.7438, MSE = 5.8682e-02
# Theta | Test_2 -> R² = 0.8458, MSE = 3.6565e-02
# Theta | Test_3 -> R² = 0.4372, MSE = 1.8461e-01
# Theta | Val -> R² = -1.2272, MSE = 7.2704e-01
# Theta | LSG_1 -> R² = 0.7173, MSE = 1.1801e-01
# Theta | LSG_2 -> R² = -2.3055, MSE = 1.1570e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 1.012549 | Val Loss 0.678023
# Epoch 100 | Train Loss 0.613147 | Val Loss 0.576207
# Epoch 200 | Train Loss 0.569345 | Val Loss 0.789076
# Early stopping at epoch 268
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7994, MSE = 4.5644e-02
# Theta | Train_2 -> R² = 0.7773, MSE = 5.0847e-02
# Theta | Test_1 -> R² = 0.7136, MSE = 6.5598e-02
# Theta | Test_2 -> R² = 0.8861, MSE = 2.7004e-02
# Theta | Test_3 -> R² = 0.5581, MSE = 1.4496e-01
# Theta | Val -> R² = -0.6790, MSE = 5.4807e-01
# Theta | LSG_1 -> R² = 0.7312, MSE = 1.1223e-01
# Theta | LSG_2 -> R² = -1.8349, MSE = 9.9223e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 0.959334 | Val Loss 0.626550
# Epoch 100 | Train Loss 0.617039 | Val Loss 0.603320
# Epoch 200 | Train Loss 0.569617 | Val Loss 0.756196
# Early stopping at epoch 261
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.8115, MSE = 4.2889e-02
# Theta | Train_2 -> R² = 0.7556, MSE = 5.5791e-02
# Theta | Test_1 -> R² = 0.6998, MSE = 6.8773e-02
# Theta | Test_2 -> R² = 0.8863, MSE = 2.6955e-02
# Theta | Test_3 -> R² = 0.3796, MSE = 2.0349e-01
# Theta | Val -> R² = -2.5887, MSE = 1.1715e+00
# Theta | LSG_1 -> R² = 0.7217, MSE = 1.1619e-01
# Theta | LSG_2 -> R² = -3.3775, MSE = 1.5321e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 0.994393 | Val Loss 0.612700
# Epoch 100 | Train Loss 0.647261 | Val Loss 0.539253
# Epoch 200 | Train Loss 0.562174 | Val Loss 0.758155
# Early stopping at epoch 267
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.7864, MSE = 4.8618e-02
# Theta | Train_2 -> R² = 0.7732, MSE = 5.1769e-02
# Theta | Test_1 -> R² = 0.7065, MSE = 6.7239e-02
# Theta | Test_2 -> R² = 0.8660, MSE = 3.1777e-02
# Theta | Test_3 -> R² = 0.4877, MSE = 1.6803e-01
# Theta | Val -> R² = -0.7046, MSE = 5.5644e-01
# Theta | LSG_1 -> R² = 0.7465, MSE = 1.0584e-01
# Theta | LSG_2 -> R² = -2.0700, MSE = 1.0745e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 1.013616 | Val Loss 0.698135
# Epoch 100 | Train Loss 0.634068 | Val Loss 0.500570
# Epoch 200 | Train Loss 0.569239 | Val Loss 0.750987
# Early stopping at epoch 273
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7499, MSE = 5.6914e-02
# Theta | Train_2 -> R² = 0.4112, MSE = 1.3441e-01
# Theta | Test_1 -> R² = 0.5663, MSE = 9.9341e-02
# Theta | Test_2 -> R² = 0.7138, MSE = 6.7873e-02
# Theta | Test_3 -> R² = 0.8377, MSE = 5.3237e-02
# Theta | Val -> R² = -0.7634, MSE = 5.7562e-01
# Theta | LSG_1 -> R² = 0.6662, MSE = 1.3936e-01
# Theta | LSG_2 -> R² = -1.5673, MSE = 8.9856e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1137 salvo.
# Epoch 0 | Train Loss 0.996458 | Val Loss 0.694616
# Epoch 100 | Train Loss 0.587947 | Val Loss 0.697789
# Epoch 200 | Train Loss 0.512186 | Val Loss 0.905232
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed480.weights.h5
# Theta | Train_1 -> R² = 0.7774, MSE = 5.0668e-02
# Theta | Train_2 -> R² = 0.5956, MSE = 9.2325e-02
# Theta | Test_1 -> R² = 0.1382, MSE = 1.9741e-01
# Theta | Test_2 -> R² = 0.8098, MSE = 4.5112e-02
# Theta | Test_3 -> R² = 0.4228, MSE = 1.8932e-01
# Theta | Val -> R² = -7.4216, MSE = 2.7491e+00
# Theta | LSG_1 -> R² = 0.1978, MSE = 3.3486e-01
# Theta | LSG_2 -> R² = -3.7024, MSE = 1.6459e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=480 salvo.
# Epoch 0 | Train Loss 0.949655 | Val Loss 0.614481
# Epoch 100 | Train Loss 0.556425 | Val Loss 0.708285
# Epoch 200 | Train Loss 0.514397 | Val Loss 0.899562
# Early stopping at epoch 211
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.6115, MSE = 8.8412e-02
# Theta | Train_2 -> R² = 0.6318, MSE = 8.4044e-02
# Theta | Test_1 -> R² = -0.0312, MSE = 2.3623e-01
# Theta | Test_2 -> R² = 0.8729, MSE = 3.0132e-02
# Theta | Test_3 -> R² = 0.1414, MSE = 2.8165e-01
# Theta | Val -> R² = -8.8576, MSE = 3.2178e+00
# Theta | LSG_1 -> R² = -0.5439, MSE = 6.4449e-01
# Theta | LSG_2 -> R² = -5.5318, MSE = 2.2862e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7865 salvo.
# Epoch 0 | Train Loss 0.981933 | Val Loss 0.663561
# Epoch 100 | Train Loss 0.580441 | Val Loss 0.684383
# Epoch 200 | Train Loss 0.510541 | Val Loss 0.877375
# Early stopping at epoch 213
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.7019, MSE = 6.7850e-02
# Theta | Train_2 -> R² = 0.6628, MSE = 7.6988e-02
# Theta | Test_1 -> R² = 0.0184, MSE = 2.2487e-01
# Theta | Test_2 -> R² = 0.8042, MSE = 4.6428e-02
# Theta | Test_3 -> R² = -0.0164, MSE = 3.3339e-01
# Theta | Val -> R² = -9.9264, MSE = 3.5667e+00
# Theta | LSG_1 -> R² = -0.3112, MSE = 5.4737e-01
# Theta | LSG_2 -> R² = -5.5567, MSE = 2.2949e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4417 salvo.
# Epoch 0 | Train Loss 1.019938 | Val Loss 0.642049
# Epoch 100 | Train Loss 0.555560 | Val Loss 0.745132
# Epoch 200 | Train Loss 0.509815 | Val Loss 0.913587
# Early stopping at epoch 213
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.3873, MSE = 1.3943e-01
# Theta | Train_2 -> R² = 0.4468, MSE = 1.2628e-01
# Theta | Test_1 -> R² = -0.6100, MSE = 3.6882e-01
# Theta | Test_2 -> R² = 0.8103, MSE = 4.4981e-02
# Theta | Test_3 -> R² = -0.0676, MSE = 3.5019e-01
# Theta | Val -> R² = -10.7629, MSE = 3.8398e+00
# Theta | LSG_1 -> R² = -0.3933, MSE = 5.8162e-01
# Theta | LSG_2 -> R² = -5.4179, MSE = 2.2463e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2313 salvo.
# Epoch 0 | Train Loss 0.997353 | Val Loss 0.686780
# Epoch 100 | Train Loss 0.587272 | Val Loss 0.735711
# Epoch 200 | Train Loss 0.515453 | Val Loss 0.880883
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch264-128-64_r0.01_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7216, MSE = 6.3352e-02
# Theta | Train_2 -> R² = 0.6619, MSE = 7.7178e-02
# Theta | Test_1 -> R² = 0.0634, MSE = 2.1456e-01
# Theta | Test_2 -> R² = 0.8201, MSE = 4.2663e-02
# Theta | Test_3 -> R² = -0.0741, MSE = 3.5231e-01
# Theta | Val -> R² = -10.2867, MSE = 3.6843e+00
# Theta | LSG_1 -> R² = -0.4758, MSE = 6.1609e-01
# Theta | LSG_2 -> R² = -5.9274, MSE = 2.4246e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1137 salvo.
# Epoch 0 | Train Loss 0.952868 | Val Loss 0.646376
# Epoch 100 | Train Loss 0.571959 | Val Loss 0.747538
# Epoch 200 | Train Loss 0.511321 | Val Loss 0.890908
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed480.weights.h5
# Theta | Train_1 -> R² = 0.6783, MSE = 7.3205e-02
# Theta | Train_2 -> R² = 0.5866, MSE = 9.4378e-02
# Theta | Test_1 -> R² = -0.1229, MSE = 2.5722e-01
# Theta | Test_2 -> R² = 0.8174, MSE = 4.3288e-02
# Theta | Test_3 -> R² = 0.2627, MSE = 2.4185e-01
# Theta | Val -> R² = -9.5596, MSE = 3.4470e+00
# Theta | LSG_1 -> R² = -0.4280, MSE = 5.9612e-01
# Theta | LSG_2 -> R² = -5.6224, MSE = 2.3179e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=480 salvo.
# Epoch 0 | Train Loss 1.038196 | Val Loss 0.693302
# Epoch 100 | Train Loss 0.571064 | Val Loss 0.704094
# Epoch 200 | Train Loss 0.510655 | Val Loss 0.883542
# Early stopping at epoch 214
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed7865.weights.h5
# Theta | Train_1 -> R² = 0.7730, MSE = 5.1651e-02
# Theta | Train_2 -> R² = 0.6577, MSE = 7.8148e-02
# Theta | Test_1 -> R² = 0.2461, MSE = 1.7270e-01
# Theta | Test_2 -> R² = 0.7754, MSE = 5.3256e-02
# Theta | Test_3 -> R² = 0.0312, MSE = 3.1777e-01
# Theta | Val -> R² = -9.2243, MSE = 3.3375e+00
# Theta | LSG_1 -> R² = -0.0075, MSE = 4.2057e-01
# Theta | LSG_2 -> R² = -4.7280, MSE = 2.0048e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7865 salvo.
# Epoch 0 | Train Loss 0.945715 | Val Loss 0.629024
# Epoch 100 | Train Loss 0.554044 | Val Loss 0.745001
# Epoch 200 | Train Loss 0.507469 | Val Loss 0.898587
# Early stopping at epoch 213
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed4417.weights.h5
# Theta | Train_1 -> R² = 0.5391, MSE = 1.0488e-01
# Theta | Train_2 -> R² = 0.5400, MSE = 1.0501e-01
# Theta | Test_1 -> R² = -0.3167, MSE = 3.0162e-01
# Theta | Test_2 -> R² = 0.8498, MSE = 3.5627e-02
# Theta | Test_3 -> R² = 0.1641, MSE = 2.7420e-01
# Theta | Val -> R² = -9.2124, MSE = 3.3336e+00
# Theta | LSG_1 -> R² = -0.3071, MSE = 5.4565e-01
# Theta | LSG_2 -> R² = -5.0755, MSE = 2.1265e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4417 salvo.
# Epoch 0 | Train Loss 0.974698 | Val Loss 0.615213
# Epoch 100 | Train Loss 0.553872 | Val Loss 0.729124
# Epoch 200 | Train Loss 0.508815 | Val Loss 0.933190
# Early stopping at epoch 210
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed2313.weights.h5
# Theta | Train_1 -> R² = 0.5837, MSE = 9.4735e-02
# Theta | Train_2 -> R² = 0.6353, MSE = 8.3255e-02
# Theta | Test_1 -> R² = -0.2755, MSE = 2.9220e-01
# Theta | Test_2 -> R² = 0.8380, MSE = 3.8411e-02
# Theta | Test_3 -> R² = -0.0009, MSE = 3.2832e-01
# Theta | Val -> R² = -9.8092, MSE = 3.5285e+00
# Theta | LSG_1 -> R² = -0.2645, MSE = 5.2785e-01
# Theta | LSG_2 -> R² = -5.3382, MSE = 2.2184e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2313 salvo.
# Epoch 0 | Train Loss 0.997720 | Val Loss 0.681087
# Epoch 100 | Train Loss 0.561103 | Val Loss 0.707424
# Epoch 200 | Train Loss 0.513524 | Val Loss 0.910160
# Early stopping at epoch 215
# Modelo salvo em:
# weights/model_arch264-128-64_r0.9_seed1137.weights.h5
# Theta | Train_1 -> R² = 0.7079, MSE = 6.6468e-02
# Theta | Train_2 -> R² = 0.5552, MSE = 1.0153e-01
# Theta | Test_1 -> R² = -0.0492, MSE = 2.4035e-01
# Theta | Test_2 -> R² = 0.8026, MSE = 4.6808e-02
# Theta | Test_3 -> R² = 0.3328, MSE = 2.1884e-01
# Theta | Val -> R² = -8.8761, MSE = 3.2239e+00
# Theta | LSG_1 -> R² = -0.1403, MSE = 4.7602e-01
# Theta | LSG_2 -> R² = -4.7626, MSE = 2.0169e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1137 salvo.

# %%
with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
