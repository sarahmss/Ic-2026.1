# %% [markdown]
# # RNN
# - 2 Entradas PwmD, PwmE
# - 1 Saida $\Delta Y $
# - 1 Camada
# - n neurônios

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
TARGET = ["Y"]       
TIME_STEPS = 9

for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    # Criar as colunas de deltas automaticamente
    for var in TARGET:
        Dataset[f"Delta{var}"] = Dataset[var].shift(-1) - Dataset[var]    
           
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")
        
    # Criar as colunas de deltas automaticamente
    for var in TARGET:
        Dataset[f"Delta{var}"] = Dataset[var].shift(-1) - Dataset[var]    
    
    Datasets.append(Dataset)
    

for i in range(len(Datasets)):
    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Dataset.head(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaY
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32     0.0
# 3  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44     0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaY
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32     0.0
# 3  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44     0.0
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaY
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32     0.0
# 3  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44     0.0
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaY
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32     0.0
# 3  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44     0.0
# ++++++++++++++++++++ Dataset 5 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaY
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32     0.0
# 3  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44     0.0
# ++++++++++++++++++++ Dataset 6 +++++++++++++++++++++++
#      X    Y  Theta    Wd   We  WdRef  WeRef   PwmD   PwmE  DeltaY
# 0  0.0  0.7    0.0  0.00  0.0  -0.00   0.00  -0.00   0.00     0.0
# 1  0.0  0.7    0.0  0.00  0.0   3.02   3.02  -0.00   0.00     0.0
# 2  0.0  0.7    0.0  0.00  0.0   3.02   3.02  45.32  45.32     0.0
# 3  0.0  0.7    0.0  0.03  0.0   3.02   3.02  45.32  45.32     0.0
# 4  0.0  0.7    0.0  0.00  0.0   3.02   3.02  63.00  63.44     0.0

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    # Criar as colunas de deltas automaticamente
    for var in TARGET:
        Dataset[f"Delta{var}"] = Dataset[var].shift(-1) - Dataset[var]

    # Dropar apenas uma vez (mantém apenas linhas onde todos os deltas existem)
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET])

    Datasets[i] = Dataset

    print(f"++++++++++++++++++++ Dataset {i+1} +++++++++++++++++++++++")
    print(Datasets[i].tail(5))
# Out:
# ++++++++++++++++++++ Dataset 1 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef   PwmD   PwmE  \
# 971       67.97  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -52.65 -29.75
# 972       68.04  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -47.56 -17.83
# 973       68.11  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -47.56 -17.83
# 974       68.18  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -42.47  -5.67
# 975       68.25  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -42.47  -5.67
#
#      DeltaY
# 971     0.0
# 972     0.0
# 973     0.0
# 974     0.0
# 975     0.0
# ++++++++++++++++++++ Dataset 2 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  \
# 971       67.97  0.04  0.66  -0.78 -2.40 -1.81  -3.20  -3.17 -112.80 -122.28
# 972       68.04  0.04  0.67  -0.79 -2.93 -2.43  -3.27  -3.29 -112.80 -122.28
# 973       68.11  0.03  0.67  -0.79 -3.29 -3.09  -3.14  -3.17 -107.79 -120.76
# 974       68.18  0.03  0.68  -0.79 -3.26 -3.21  -2.96  -3.01 -107.79 -120.76
# 975       68.25  0.02  0.68  -0.79 -3.18 -3.21  -2.74  -2.80  -98.04 -108.00
#
#      DeltaY
# 971    0.01
# 972    0.00
# 973    0.01
# 974    0.00
# 975    0.01
# ++++++++++++++++++++ Dataset 3 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef   PwmD   PwmE  \
# 977       68.39  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -58.81 -46.33
# 978       68.46  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -53.90 -38.47
# 979       68.53  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -53.90 -38.47
# 980       68.60  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -48.98 -26.60
# 981       68.67  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -48.98 -26.60
#
#      DeltaY
# 977     0.0
# 978     0.0
# 979     0.0
# 980     0.0
# 981     0.0
# ++++++++++++++++++++ Dataset 4 +++++++++++++++++++++++
#      Unnamed: 0     X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  \
# 977       68.39  0.04  0.66  -0.77 -3.68 -3.07  -3.27  -3.29 -100.01 -115.88
# 978       68.46  0.04  0.66  -0.78 -3.68 -3.01  -3.07  -3.11 -100.01 -115.88
# 979       68.53  0.03  0.67  -0.79 -3.37 -3.09  -2.09  -2.40  -80.69 -106.52
# 980       68.60  0.03  0.67  -0.78 -2.68 -2.79  -1.25  -2.15  -80.69 -106.52
# 981       68.67  0.02  0.68  -0.78 -2.31 -2.62  -1.12  -2.12  -71.69 -101.95
#
#      DeltaY
# 977    0.00
# 978    0.01
# 979    0.00
# 980    0.01
# 981    0.00
# ++++++++++++++++++++ Dataset 5 +++++++++++++++++++++++
#          X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  DeltaY
# 1415  0.05  0.65  -0.83 -2.76 -3.35  -2.84  -3.05 -103.15 -117.71    0.00
# 1416  0.05  0.65  -0.83 -2.79 -3.12  -2.86  -3.06 -104.13 -115.63    0.01
# 1417  0.04  0.66  -0.83 -3.29 -3.18  -2.88  -3.06 -104.13 -115.63    0.00
# 1418  0.04  0.66  -0.83 -3.26 -3.18  -2.86  -3.05  -96.76 -116.39    0.01
# 1419  0.03  0.67  -0.83 -3.09 -3.01  -2.84  -3.05  -96.76 -116.39    0.00
# ++++++++++++++++++++ Dataset 6 +++++++++++++++++++++++
#          X     Y  Theta    Wd    We  WdRef  WeRef    PwmD    PwmE  DeltaY
# 1266  0.04  0.65  -0.78 -2.73 -2.65  -2.95  -2.66 -108.21 -110.17    0.00
# 1267  0.04  0.65  -0.78 -2.54 -2.54  -2.94  -2.65 -108.21 -110.17    0.00
# 1268  0.04  0.65  -0.79 -2.87 -2.59  -2.93  -2.62 -113.11 -112.34    0.01
# 1269  0.03  0.66  -0.80 -3.07 -2.68  -2.92  -2.61 -113.11 -112.34    0.00
# 1270  0.03  0.66  -0.81 -2.98 -2.37  -2.91  -2.59 -107.17 -110.25    0.01

# %%
NormDatasets = []
TARGET = ["DeltaY"]

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

# ===== TRAIN FASE 1 =====
Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

# ===== TRAIN FASE 2 =====
Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)


for i in range(4):
      CurrentTestDataset = Datasets[i + 2]
      CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
      CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
      NormDatasets.append(CurrentTestDataset)
      print(f"++++++++++++++++++++ Dataset Normalizado {i+2} +++++++++++++++++++++++")
      print(NormDatasets[i].head(5))
# Out:
# ++++++++++++++++++++ Dataset Normalizado 2 +++++++++++++++++++++++
#    Unnamed: 0    X    Y  Theta    Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.0  0.7   0.00  0.00  0.0   0.00   0.00  0.221564  0.111917
# 1        0.07  0.0  0.7   0.00  0.00  0.0   3.28   3.28  0.221564  0.111917
# 2        0.14  0.0  0.7   0.00  0.00  0.0   3.28   3.28  0.803114  0.594038
# 3        0.21  0.0  0.7   0.00  0.06  0.0   3.28   3.28  0.803114  0.594038
# 4        0.28  0.0  0.7   0.01  0.33  0.0   3.28   3.28  1.025343  0.786494
#
#     DeltaY
# 0  0.00264
# 1  0.00264
# 2  0.00264
# 3  0.00264
# 4  0.00264
# ++++++++++++++++++++ Dataset Normalizado 3 +++++++++++++++++++++++
#    Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.219706  0.175547
# 1        0.07  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.159602  0.294682
# 2        0.14  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.159602  0.294682
# 3        0.21  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.099381  0.413720
# 4        0.28  0.01  0.69   -0.8  0.0  0.0   0.85   2.03 -0.099381  0.413720
#
#     DeltaY
# 0  0.00264
# 1  0.00264
# 2  0.00264
# 3  0.00264
# 4  0.00264
# ++++++++++++++++++++ Dataset Normalizado 4 +++++++++++++++++++++++
#    Unnamed: 0    X    Y  Theta    Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.0  0.7    0.0  0.00  0.0   0.00   0.00  0.221564  0.111917
# 1        0.07  0.0  0.7    0.0  0.00  0.0   3.28   3.28  0.221564  0.111917
# 2        0.14  0.0  0.7    0.0  0.00  0.0   3.28   3.28  0.803114  0.594038
# 3        0.21  0.0  0.7    0.0  0.14  0.0   3.28   3.28  0.803114  0.594038
# 4        0.28  0.0  0.7    0.0  0.00  0.0   3.27   3.27  1.009048  0.785417
#
#     DeltaY
# 0  0.00264
# 1  0.00264
# 2  0.00264
# 3  0.00264
# 4  0.00264
# ++++++++++++++++++++ Dataset Normalizado 5 +++++++++++++++++++++++
#    Unnamed: 0     X     Y  Theta   Wd   We  WdRef  WeRef      PwmD      PwmE  \
# 0        0.00  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.298820 -0.032278
# 1        0.07  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.240724  0.083920
# 2        0.14  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.240724  0.083920
# 3        0.21  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.182746  0.200118
# 4        0.28  0.02  0.68  -0.79  0.0  0.0   0.82   1.98 -0.182746  0.200118
#
#     DeltaY
# 0  0.00264
# 1  0.00264
# 2  0.00264
# 3  0.00264
# 4  0.00264

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train1, y_train1 = CreateSequences(Train1[PREDICTORS], Train1[TARGET], TIME_STEPS)

x_train2, y_train2 = CreateSequences(Train2[PREDICTORS], Train2[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)

print(f"Dimensão da entrada: {np.shape(x_train1)}")
print(f"Dimensão da saida: {np.shape(y_train1)}")

print(f"Dimensão da entrada: {np.shape(x_train2)}")
print(f"Dimensão da saida: {np.shape(y_train2)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (967, 9, 2)
# Dimensão da saida: (967, 1)
# Dimensão da entrada: (967, 9, 2)
# Dimensão da saida: (967, 1)
# Dimensão da entrada: (1262, 9, 2)
# Dimensão da saida: (1262, 9, 2)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def PlotOut(ax, title, target_name, y_true, y_pred):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true, marker='o', s=12, label='Amostras Reais', alpha=0.7)
    ax.scatter(time, y_pred, marker='x', s=12, label='Valores Preditos', alpha=0.7)
    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_datasets = len(Datasets)
    n_targets = len(TARGET)
    fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    
    metrics = {name: {"R2_train1": [], "R2_train2": [],
                      "R2_test1": [], "R2_test2": [],
                      "R2_test3": [],"R2_val": [],
                      "MSE_train1": [], "MSE_train2": [],
                      "MSE_test1": [], "MSE_test2": [],
                      "MSE_test3": [], "MSE_val": [],} for name in TARGET}

    for i, dataset in enumerate(NormDatasets):
        x = dataset[PREDICTORS]
        y = dataset[TARGET]
        x, y = CreateSequences(x, y, TIME_STEPS)

        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        y_diff = OUT_SCALER.inverse_transform(y)
        
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)

        # valores iniciais reais (não normalizados)
        init_vals = np.array([
            Datasets[i]["Theta"].iloc[0],
            Datasets[i]["X"].iloc[0],
            Datasets[i]["Y"].iloc[0]
        ])

        # reconstrução cumulativa saída a saída
        for j, name in enumerate(TARGET):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j])
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j])


        # Calcula métricas por saída
        for j, name in enumerate(TARGET):
            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])
            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, MSE = {mse:.4e}")
            
            # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
                axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            )
            PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j])

    plt.tight_layout()

    # Retorna métricas médias para análise posterior
    return metrics, plt, fig

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras import initializers

# tamanho da entrada
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET) 
N_MODELS = 10  # número de inicializações

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

# arquiteturas das camadas ocultas
neurons = [[5, 2], [10, 5], [15, 5], [20, 5], [20, 10], [25, 10], [10, 5 ,2 ], [15, 10, 5]]

results = {}
excel_file = "resultados.xlsx"

for arch in neurons:  # cada arquitetura
    for i, s in enumerate(seeds):

        initializer = initializers.RandomNormal(seed=int(s))

        model = keras.models.Sequential()
        model.add(keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

        # adiciona camadas RNN
        for j, n in enumerate(arch):

            # se não for a última camada RNN
            if j < len(arch) - 1:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        kernel_initializer=initializer
                    )
                )

        # camada de saída
        model.add(
            keras.layers.Dense(
                OUTPUT_SIZE,
                activation="linear",
                kernel_initializer=initializer
            )
        )
        # salva pesos iniciais
        w0 = model.get_weights()

        # compila
        model.compile(loss="mean_squared_error", optimizer="adam")
        early_stopping_monitor = EarlyStopping(
            monitor='val_loss',
            patience=50,
            restore_best_weights=True
        )

        x_train = np.concatenate((x_train1, x_train2), axis=0)
        y_train = np.concatenate((y_train1, y_train2), axis=0)

        history = model.fit(
            x_train, 
            y_train, 
            epochs=1000,
            callbacks=[early_stopping_monitor],
            validation_data=(x_val, y_val),
            verbose=0
        )
        
    
        # salva pesos finais
        wf = model.get_weights()

       # avalia o modelo
        metrics, plt, fig = EvalModel(model)


        row = {
            "model": f"model_{n}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.5 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{n}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{n}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train1 -> R² = -1.5611, MSE = 2.1377e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train2 -> R² = -2.0888, MSE = 3.2977e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test1 -> R² = -1.7669, MSE = 2.2562e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -2.0574, MSE = 3.2190e-01
# 45/45 [==============================] - 0s 2ms/step
# DeltaY | test3 -> R² = -3.2732, MSE = 3.2650e-01
# 40/40 [==============================] - 0s 2ms/step
# DeltaY | val -> R² = -2.6436, MSE = 2.6998e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.4154, MSE = 2.0161e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train2 -> R² = -1.9502, MSE = 3.1497e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test1 -> R² = -1.6134, MSE = 2.1310e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -1.9193, MSE = 3.0736e-01
# 45/45 [==============================] - 0s 2ms/step
# DeltaY | test3 -> R² = -2.9100, MSE = 2.9874e-01
# 40/40 [==============================] - 0s 2ms/step
# DeltaY | val -> R² = -2.3596, MSE = 2.4894e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.6056, MSE = 2.1749e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train2 -> R² = -2.2419, MSE = 3.4612e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test1 -> R² = -1.7994, MSE = 2.2827e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -2.1966, MSE = 3.3656e-01
# 45/45 [==============================] - 0s 2ms/step
# DeltaY | test3 -> R² = -2.8204, MSE = 2.9190e-01
# 40/40 [==============================] - 0s 2ms/step
# DeltaY | val -> R² = -2.3320, MSE = 2.4689e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.4112, MSE = 2.0126e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train2 -> R² = -2.0521, MSE = 3.2586e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.5922, MSE = 2.1138e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -2.0135, MSE = 3.1728e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -2.4393, MSE = 2.6278e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -1.9320, MSE = 2.1725e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.3625, MSE = 1.9720e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -1.5701, MSE = 2.7439e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test1 -> R² = -1.5964, MSE = 2.1172e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -1.5838, MSE = 2.7204e-01
# 45/45 [==============================] - 0s 2ms/step
# DeltaY | test3 -> R² = -4.8807, MSE = 4.4931e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -3.2802, MSE = 3.1715e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.4898, MSE = 2.0782e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train2 -> R² =
-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.2379, MSE = 1.3216e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -0.5535, MSE = 1.2668e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -0.2656, MSE = 1.3325e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -2.0480, MSE = 2.3289e-01
# 40/40 [==============================] - 0s 2ms/step
# DeltaY | val -> R² = -1.7562, MSE = 2.0423e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train1 -> R² = -0.8261, MSE = 1.5243e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.4641, MSE = 1.5632e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -0.9681, MSE = 1.6048e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -0.4642, MSE = 1.5417e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -3.9287, MSE = 3.7658e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -3.1421, MSE = 3.0692e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = 0.2978, MSE = 5.8608e-02
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.0458, MSE = 1.1166e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = 0.0253, MSE = 7.9477e-02
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = 0.1012, MSE = 9.4637e-02
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = 0.0531, MSE = 7.2351e-02
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -0.3230, MSE = 9.8027e-02
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = 0.0153, MSE = 8.2189e-02
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.9223, MSE = 2.0523e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -0.6256, MSE = 1.3256e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -0.5300, MSE = 1.6109e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -1.0805, MSE = 1.5896e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -1.2103, MSE = 1.6378e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -0.7431, MSE = 1.4549e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.4251, MSE = 1.5215e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -0.8461, MSE = 1.5053e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -0.4102, MSE = 1.4848e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -3.5337, MSE = 3.4640e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -1.9338, MSE = 2.1738e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = 0.0281, MSE = 8.1124e-02
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.6886, MSE = 1.8028e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -0.6818, MSE = 1.3714e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -0.4456, MSE = 1.5220e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -2.1824, MSE = 2.4315e-01
# 40/40 [==============================] - 0s 2ms/step
# DeltaY | val -> R² = -2.7734, MSE = 2.7960e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaY | train1 -> R² = -1.4876, MSE = 2.0764e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -1.8393, MSE = 3.0313e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.7238, MSE = 2.2211e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -1.8420, MSE = 2.9922e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -4.5558, MSE = 4.2449e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -2.9928, MSE = 2.9585e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.5547, MSE = 2.1324e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -2.0994, MSE = 3.3091e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.7707, MSE = 2.2594e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -2.0754, MSE = 3.2380e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -3.4367, MSE = 3.3898e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -2.5257, MSE = 2.6125e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaY | train1 -> R² = -1.5408, MSE = 2.1208e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.9141, MSE = 3.1112e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.7672, MSE = 2.2564e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.9074, MSE = 3.0611e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -4.4791, MSE = 4.1863e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -2.9721, MSE = 2.9432e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaY | train1 -> R² = -1.4557, MSE = 2.0498e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -1.6570, MSE = 2.8367e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.7058, MSE = 2.2064e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.6751, MSE = 2.8166e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -5.2601, MSE = 4.7831e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -3.4474, MSE = 3.2954e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.5840, MSE = 2.1569e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -2.1855, MSE = 3.4010e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.7824, MSE = 2.2689e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -2.1463, MSE = 3.3127e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -3.0126, MSE = 3.0658e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -2.3736, MSE = 2.4997e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.3789, MSE = 1.9856e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.6042, MSE = 2.7803e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.6157, MSE = 2.1330e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.6214, MSE = 2.7600e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -4.9354, MSE = 4.5350e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -3.2257, MSE = 3.1311e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaY | train1 -> R² = -1.4387, MSE = 2.0356e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -1.8389, MSE = 3.0309e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.6610, MSE = 2.1698e-01
# 31/31 [==============================] - 0s 5ms/step
# DeltaY | test2 -> R² = -1.8338, MSE = 2.9836e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -4.0718, MSE = 3.8751e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -2.7871, MSE = 2.8061e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.4978, MSE = 2.0849e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.6683, MSE = 2.8488e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.7545, MSE = 2.2461e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -1.6931, MSE = 2.8355e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -5.6925, MSE = 5.1134e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -3.6058, MSE = 3.4128e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.4241, MSE = 2.0234e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.6779, MSE = 2.8590e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.6642, MSE = 2.1725e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -1.6916, MSE = 2.8339e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -4.9311, MSE = 4.5317e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -3.2932, MSE = 3.1811e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# DeltaY | train1 -> R² = -1.4123, MSE = 2.0135e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.8170, MSE = 3.0076e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.6293, MSE = 2.1440e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -1.8090, MSE = 2.9576e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -3.9433, MSE = 3.7769e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -2.6972, MSE = 2.7395e-01
# Modelo 9 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.4248, MSE = 2.0240e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -1.0235, MSE = 2.1603e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.7496, MSE = 2.2421e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.1222, MSE = 2.2344e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -10.5898, MSE = 8.8552e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -5.6981, MSE = 4.9631e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.4223, MSE = 2.0219e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.1451, MSE = 2.2902e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.7424, MSE = 2.2362e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.2302, MSE = 2.3482e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -9.3926, MSE = 7.9404e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -5.6654, MSE = 4.9388e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.4012, MSE = 2.0042e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -1.0999, MSE = 2.2419e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.7001, MSE = 2.2017e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -1.1797, MSE = 2.2950e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -9.1557, MSE = 7.7594e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -5.5107, MSE = 4.8242e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.3115, MSE = 1.9294e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -0.8770, MSE = 2.0040e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.6253, MSE = 2.1408e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -0.9778, MSE = 2.0824e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -10.6438, MSE = 8.8964e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -5.7498, MSE = 5.0014e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaY | train1 -> R² = -1.2807, MSE = 1.9037e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.7777, MSE = 1.8980e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.5891, MSE = 2.1112e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -0.8843, MSE = 1.9839e-01
# 45/45 [==============================] - 0s 2ms/step
# DeltaY | test3 -> R² = -11.0674, MSE = 9.2201e-01
# 40/40 [==============================] - 0s 2ms/step
# DeltaY | val -> R² = -6.1539, MSE = 5.3008e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# DeltaY | train1 -> R² = -1.4831, MSE = 2.0727e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -1.2485, MSE = 2.4005e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.8103, MSE = 2.2916e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.3346, MSE = 2.4580e-01
# 45/45 [==============================] - 0s 3ms/step
# DeltaY | test3 -> R² = -9.3616, MSE = 7.9168e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -5.3661, MSE = 4.7171e-01
# Modelo 5 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.3736, MSE = 1.9813e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.9745, MSE = 2.1080e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.7099, MSE = 2.2098e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.0820, MSE = 2.1921e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -11.0162, MSE = 9.1809e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -5.4952, MSE = 4.8127e-01
# Modelo 6 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.3992, MSE = 2.0026e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train2 -> R² = -0.9512, MSE = 2.0832e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test1 -> R² = -1.7384, MSE = 2.2330e-01
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | test2 -> R² = -1.0625, MSE = 2.1716e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -11.7328, MSE = 9.7285e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -5.7379, MSE = 4.9926e-01
# Modelo 7 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# DeltaY | train1 -> R² = -1.3283, MSE = 1.9434e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | train2 -> R² = -0.9087, MSE = 2.0378e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test1 -> R² = -1.6496, MSE = 2.1606e-01
# 31/31 [==============================] - 0s 4ms/step
# DeltaY | test2 -> R² = -1.0087, MSE = 2.1149e-01
# 45/45 [==============================] - 0s 4ms/step
# DeltaY | test3 -> R² = -10.7302, MSE = 8.9624e-01
# 40/40 [==============================] - 0s 4ms/step
# DeltaY | val -> R² = -5.6237, MSE = 4.9079e-01
# Modelo 8 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# DeltaY | train1 -> R² = -1.4100, MSE = 2.0116e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | train2 -> R² = -0.8846, MSE = 2.0121e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test1 -> R² = -1.7508, MSE = 2.2431e-01
# 31/31 [==============================] - 0s 2ms/step
# DeltaY | test2 -> R² = -0.9972, MSE = 2.1028e-01
# 45/45 [==============================] - 0s 2ms/step
# DeltaY | test3 -> R² = -11.9398, MSE = 9.8866e-01
# 40/40 [==============================] - 0s 3ms/step
# DeltaY | val -> R² = -6.2510, MSE = 5.3728e-01
# Modelo 9 treinado e salvo no Excel
