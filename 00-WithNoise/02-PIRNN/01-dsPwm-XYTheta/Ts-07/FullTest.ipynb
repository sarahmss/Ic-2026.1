# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 7
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    for var in PREDICTORS:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train2, Train1], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 3)
# Dimensão da entrada: (1264, 7, 4)
# Dimensão da saida: (1264, 7, 4)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 3)
# Dimensão da entrada fisica : (1945,)
# Dimensão da entrada fisica: (1945,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, patience=500, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train, theta_train)
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)
        # plt.show()

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.535204 | Val Loss 0.808457
# Epoch 100 | Train Loss 1.232821 | Val Loss 0.674599
# Epoch 200 | Train Loss 1.148187 | Val Loss 0.636949
# Epoch 300 | Train Loss 1.103170 | Val Loss 0.639157
# Epoch 400 | Train Loss 1.063945 | Val Loss 0.643759
# Epoch 500 | Train Loss 1.024295 | Val Loss 0.655856
# Epoch 600 | Train Loss 0.987214 | Val Loss 0.670410
# Epoch 700 | Train Loss 0.952984 | Val Loss 0.684779
# Early stopping at epoch 707
# Theta | train1 -> R² = 0.8001, MSE = 4.5822e-02
# X | train1 -> R² = -0.1419, MSE = 1.2239e-01
# Y | train1 -> R² = -0.5364, MSE = 1.2841e-01
# Theta | train2 -> R² = 0.4963, MSE = 1.1422e-01
# X | train2 -> R² = -0.0418, MSE = 8.7563e-02
# Y | train2 -> R² = -1.2883, MSE = 2.4502e-01
# Theta | test1 -> R² = 0.3705, MSE = 1.4519e-01
# X | test1 -> R² = -0.0821, MSE = 1.1264e-01
# Y | test1 -> R² = -1.8916, MSE = 2.3619e-01
# Theta | test2 -> R² = 0.6954, MSE = 7.1762e-02
# X | test2 -> R² = -0.1177, MSE = 9.1752e-02
# Y | test2 -> R² = -1.3037, MSE = 2.4321e-01
# Theta | test3 -> R² = -1.6108, MSE = 8.6045e-01
# X | test3 -> R² = -2.1357, MSE = 2.8689e-01
# Y | test3 -> R² = -5.3248, MSE = 4.8410e-01
# Theta | val -> R² = -4.1653, MSE = 1.6948e+00
# X | val -> R² = -1.7853, MSE = 2.6472e-01
# Y | val -> R² = -5.0013, MSE = 4.4540e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.584717 | Val Loss 0.802887
# Epoch 100 | Train Loss 1.245786 | Val Loss 0.677654
# Epoch 200 | Train Loss 1.159800 | Val Loss 0.641097
# Epoch 300 | Train Loss 1.111485 | Val Loss 0.635983
# Epoch 400 | Train Loss 1.076265 | Val Loss 0.645640
# Epoch 500 | Train Loss 1.039024 | Val Loss 0.661550
# Epoch 600 | Train Loss 1.005828 | Val Loss 0.683477
# Epoch 700 | Train Loss 0.976744 | Val Loss 0.696492
# Early stopping at epoch 750
# Theta | train1 -> R² = 0.4416, MSE = 1.2799e-01
# X | train1 -> R² = -0.2862, MSE = 1.3785e-01
# Y | train1 -> R² = -0.3271, MSE = 1.1092e-01
# Theta | train2 -> R² = 0.6811, MSE = 7.2301e-02
# X | train2 -> R² = 0.0703, MSE = 7.8137e-02
# Y | train2 -> R² = -1.2350, MSE = 2.3931e-01
# Theta | test1 -> R² = 0.5887, MSE = 9.4867e-02
# X | test1 -> R² = -0.0434, MSE = 1.0862e-01
# Y | test1 -> R² = -1.6399, MSE = 2.1563e-01
# Theta | test2 -> R² = 0.6310, MSE = 8.6919e-02
# X | test2 -> R² = -0.0117, MSE = 8.3057e-02
# Y | test2 -> R² = -1.3521, MSE = 2.4832e-01
# Theta | test3 -> R² = -2.0972, MSE = 1.0208e+00
# X | test3 -> R² = -2.0630, MSE = 2.8025e-01
# Y | test3 -> R² = -6.0319, MSE = 5.3822e-01
# Theta | val -> R² = -2.6759, MSE = 1.2061e+00
# X | val -> R² = -0.7244, MSE = 1.6389e-01
# Y | val -> R² = -5.4567, MSE = 4.7919e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.590318 | Val Loss 0.802955
# Epoch 100 | Train Loss 1.239901 | Val Loss 0.687037
# Epoch 200 | Train Loss 1.153572 | Val Loss 0.654098
# Epoch 300 | Train Loss 1.106535 | Val Loss 0.648951
# Epoch 400 | Train Loss 1.069526 | Val Loss 0.657924
# Epoch 500 | Train Loss 1.032139 | Val Loss 0.670627
# Epoch 600 | Train Loss 0.993073 | Val Loss 0.682843
# Epoch 700 | Train Loss 0.956239 | Val Loss 0.700106
# Early stopping at epoch 775
# Theta | train1 -> R² = 0.8635, MSE = 3.1291e-02
# X | train1 -> R² = -0.2994, MSE = 1.3927e-01
# Y | train1 -> R² = -0.1100, MSE = 9.2778e-02
# Theta | train2 -> R² = 0.5960, MSE = 9.1603e-02
# X | train2 -> R² = 0.1412, MSE = 7.2180e-02
# Y | train2 -> R² = -1.3066, MSE = 2.4698e-01
# Theta | test1 -> R² = 0.1381, MSE = 1.9880e-01
# X | test1 -> R² = -0.0311, MSE = 1.0733e-01
# Y | test1 -> R² = -1.4920, MSE = 2.0355e-01
# Theta | test2 -> R² = 0.7610, MSE = 5.6295e-02
# X | test2 -> R² = -0.0170, MSE = 8.3485e-02
# Y | test2 -> R² = -1.4164, MSE = 2.5511e-01
# Theta | test3 -> R² = -6.2833, MSE = 2.4004e+00
# X | test3 -> R² = -0.3538, MSE = 1.2387e-01
# Y | test3 -> R² = -8.8752, MSE = 7.5585e-01
# Theta | val -> R² = -7.2011, MSE = 2.6909e+00
# X | val -> R² = -0.1750, MSE = 1.1168e-01
# Y | val -> R² = -7.1037, MSE = 6.0142e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.595402 | Val Loss 0.804396
# Epoch 100 | Train Loss 1.247646 | Val Loss 0.679893
# Epoch 200 | Train Loss 1.157666 | Val Loss 0.639091
# Epoch 300 | Train Loss 1.103194 | Val Loss 0.635718
# Epoch 400 | Train Loss 1.057503 | Val Loss 0.650095
# Epoch 500 | Train Loss 1.007916 | Val Loss 0.670264
# Epoch 600 | Train Loss 0.962796 | Val Loss 0.693164
# Epoch 700 | Train Loss 0.922740 | Val Loss 0.705087
# Early stopping at epoch 736
# Theta | train1 -> R² = 0.8761, MSE = 2.8402e-02
# X | train1 -> R² = -0.3129, MSE = 1.4072e-01
# Y | train1 -> R² = -0.2399, MSE = 1.0363e-01
# Theta | train2 -> R² = 0.6439, MSE = 8.0751e-02
# X | train2 -> R² = 0.0677, MSE = 7.8362e-02
# Y | train2 -> R² = -1.2387, MSE = 2.3971e-01
# Theta | test1 -> R² = 0.5240, MSE = 1.0978e-01
# X | test1 -> R² = 0.0401, MSE = 9.9927e-02
# Y | test1 -> R² = -1.6838, MSE = 2.1922e-01
# Theta | test2 -> R² = 0.6833, MSE = 7.4599e-02
# X | test2 -> R² = -0.0681, MSE = 8.7684e-02
# Y | test2 -> R² = -1.3213, MSE = 2.4507e-01
# Theta | test3 -> R² = -3.3286, MSE = 1.4266e+00
# X | test3 -> R² = -1.6446, MSE = 2.4196e-01
# Y | test3 -> R² = -7.2166, MSE = 6.2890e-01
# Theta | val -> R² = -4.2806, MSE = 1.7327e+00
# X | val -> R² = -0.3518, MSE = 1.2848e-01
# Y | val -> R² = -6.7972, MSE = 5.7867e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.660889 | Val Loss 0.787091
# Epoch 100 | Train Loss 1.238763 | Val Loss 0.671267
# Epoch 200 | Train Loss 1.158484 | Val Loss 0.635426
# Epoch 300 | Train Loss 1.114326 | Val Loss 0.626870
# Epoch 400 | Train Loss 1.077143 | Val Loss 0.631473
# Epoch 500 | Train Loss 1.040248 | Val Loss 0.642748
# Epoch 600 | Train Loss 1.000655 | Val Loss 0.662686
# Epoch 700 | Train Loss 0.962946 | Val Loss 0.687271
# Early stopping at epoch 796
# Theta | train1 -> R² = 0.5712, MSE = 9.8274e-02
# X | train1 -> R² = -0.2672, MSE = 1.3581e-01
# Y | train1 -> R² = -0.0791, MSE = 9.0190e-02
# Theta | train2 -> R² = 0.5766, MSE = 9.6002e-02
# X | train2 -> R² = 0.0715, MSE = 7.8038e-02
# Y | train2 -> R² = -1.3142, MSE = 2.4779e-01
# Theta | test1 -> R² = 0.5359, MSE = 1.0705e-01
# X | test1 -> R² = 0.0057, MSE = 1.0350e-01
# Y | test1 -> R² = -1.5640, MSE = 2.0943e-01
# Theta | test2 -> R² = 0.7893, MSE = 4.9637e-02
# X | test2 -> R² = 0.0003, MSE = 8.2069e-02
# Y | test2 -> R² = -1.3498, MSE = 2.4808e-01
# Theta | test3 -> R² = -0.8240, MSE = 6.0114e-01
# X | test3 -> R² = -1.3411, MSE = 2.1420e-01
# Y | test3 -> R² = -7.8784, MSE = 6.7955e-01
# Theta | val -> R² = -0.0749, MSE = 3.5271e-01
# X | val -> R² = -0.7331, MSE = 1.6471e-01
# Y | val -> R² = -7.0199, MSE = 5.9521e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.592162 | Val Loss 0.788631
# Epoch 100 | Train Loss 1.245953 | Val Loss 0.681006
# Epoch 200 | Train Loss 1.171452 | Val Loss 0.653847
# Epoch 300 | Train Loss 1.114717 | Val Loss 0.645353
# Epoch 400 | Train Loss 1.072527 | Val Loss 0.649967
# Epoch 500 | Train Loss 1.035871 | Val Loss 0.660276
# Epoch 600 | Train Loss 1.000397 | Val Loss 0.675358
# Epoch 700 | Train Loss 0.962667 | Val Loss 0.691302
# Epoch 800 | Train Loss 0.929060 | Val Loss 0.713601
# Early stopping at epoch 808
# Theta | train1 -> R² = 0.5195, MSE = 1.1014e-01
# X | train1 -> R² = -0.2957, MSE = 1.3887e-01
# Y | train1 -> R² = -0.0795, MSE = 9.0229e-02
# Theta | train2 -> R² = 0.6024, MSE = 9.0158e-02
# X | train2 -> R² = 0.0996, MSE = 7.5678e-02
# Y | train2 -> R² = -1.4389, MSE = 2.6113e-01
# Theta | test1 -> R² = 0.4721, MSE = 1.2176e-01
# X | test1 -> R² = 0.0051, MSE = 1.0357e-01
# Y | test1 -> R² = -1.6479, MSE = 2.1628e-01
# Theta | test2 -> R² = 0.8155, MSE = 4.3474e-02
# X | test2 -> R² = -0.0122, MSE = 8.3095e-02
# Y | test2 -> R² = -1.4721, MSE = 2.6099e-01
# Theta | test3 -> R² = -5.6138, MSE = 2.1798e+00
# X | test3 -> R² = -2.1211, MSE = 2.8556e-01
# Y | test3 -> R² = -6.1721, MSE = 5.4895e-01
# Theta | val -> R² = -5.1228, MSE = 2.0090e+00
# X | val -> R² = -1.4737, MSE = 2.3510e-01
# Y | val -> R² = -5.3635, MSE = 4.7227e-01
# Figura salva em: ./results/model_64_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.560032 | Val Loss 0.763538
# Epoch 100 | Train Loss 1.238727 | Val Loss 0.670787
# Epoch 200 | Train Loss 1.153581 | Val Loss 0.643658
# Epoch 300 | Train Loss 1.109017 | Val Loss 0.639554
# Epoch 400 | Train Loss 1.069407 | Val Loss 0.654836
# Epoch 500 | Train Loss 1.025496 | Val Loss 0.678884
# Epoch 600 | Train Loss 0.981065 | Val Loss 0.706430
# Epoch 700 | Train Loss 0.938923 | Val Loss 0.735901
# Early stopping at epoch 777
# Theta | train1 -> R² = 0.7011, MSE = 6.8514e-02
# X | train1 -> R² = -0.2406, MSE = 1.3297e-01
# Y | train1 -> R² = -0.2354, MSE = 1.0325e-01
# Theta | train2 -> R² = 0.4266, MSE = 1.3002e-01
# X | train2 -> R² = 0.0983, MSE = 7.5789e-02
# Y | train2 -> R² = -1.3380, MSE = 2.5033e-01
# Theta | test1 -> R² = 0.4820, MSE = 1.1949e-01
# X | test1 -> R² = 0.0451, MSE = 9.9399e-02
# Y | test1 -> R² = -1.6650, MSE = 2.1768e-01
# Theta | test2 -> R² = 0.7065, MSE = 6.9154e-02
# X | test2 -> R² = -0.0976, MSE = 9.0109e-02
# Y | test2 -> R² = -1.1879, MSE = 2.3099e-01
# Theta | test3 -> R² = -0.6412, MSE = 5.4090e-01
# X | test3 -> R² = -1.9160, MSE = 2.6679e-01
# Y | test3 -> R² = -4.1628, MSE = 3.9516e-01
# Theta | val -> R² = -0.5598, MSE = 5.1180e-01
# X | val -> R² = -0.8040, MSE = 1.7146e-01
# Y | val -> R² = -3.9859, MSE = 3.7003e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.592993 | Val Loss 0.791591
# Epoch 100 | Train Loss 1.239045 | Val Loss 0.662039
# Epoch 200 | Train Loss 1.165495 | Val Loss 0.630844
# Epoch 300 | Train Loss 1.118314 | Val Loss 0.626422
# Epoch 400 | Train Loss 1.079452 | Val Loss 0.627195
# Epoch 500 | Train Loss 1.045600 | Val Loss 0.633916
# Epoch 600 | Train Loss 1.011406 | Val Loss 0.650950
# Epoch 700 | Train Loss 0.975681 | Val Loss 0.680950
# Early stopping at epoch 750
# Theta | train1 -> R² = 0.2735, MSE = 1.6653e-01
# X | train1 -> R² = -0.2676, MSE = 1.3586e-01
# Y | train1 -> R² = -0.3668, MSE = 1.1423e-01
# Theta | train2 -> R² = 0.5022, MSE = 1.1287e-01
# X | train2 -> R² = 0.0730, MSE = 7.7915e-02
# Y | train2 -> R² = -1.2607, MSE = 2.4206e-01
# Theta | test1 -> R² = 0.5717, MSE = 9.8791e-02
# X | test1 -> R² = 0.0170, MSE = 1.0233e-01
# Y | test1 -> R² = -1.6782, MSE = 2.1876e-01
# Theta | test2 -> R² = 0.7644, MSE = 5.5505e-02
# X | test2 -> R² = -0.0609, MSE = 8.7096e-02
# Y | test2 -> R² = -1.3075, MSE = 2.4361e-01
# Theta | test3 -> R² = -0.7824, MSE = 5.8744e-01
# X | test3 -> R² = -1.6008, MSE = 2.3796e-01
# Y | test3 -> R² = -6.3439, MSE = 5.6210e-01
# Theta | val -> R² = -1.5621, MSE = 8.4067e-01
# X | val -> R² = -0.4034, MSE = 1.3338e-01
# Y | val -> R² = -6.1010, MSE = 5.2701e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.629576 | Val Loss 0.773656
# Epoch 100 | Train Loss 1.231486 | Val Loss 0.673312
# Epoch 200 | Train Loss 1.162293 | Val Loss 0.638177
# Epoch 300 | Train Loss 1.115420 | Val Loss 0.627718
# Epoch 400 | Train Loss 1.073808 | Val Loss 0.639448
# Epoch 500 | Train Loss 1.033508 | Val Loss 0.662891
# Epoch 600 | Train Loss 0.991944 | Val Loss 0.682523
# Epoch 700 | Train Loss 0.951129 | Val Loss 0.704617
# Early stopping at epoch 779
# Theta | train1 -> R² = 0.8980, MSE = 2.3371e-02
# X | train1 -> R² = -0.1352, MSE = 1.2167e-01
# Y | train1 -> R² = -0.3190, MSE = 1.1024e-01
# Theta | train2 -> R² = 0.4893, MSE = 1.1581e-01
# X | train2 -> R² = 0.0296, MSE = 8.1565e-02
# Y | train2 -> R² = -1.1868, MSE = 2.3414e-01
# Theta | test1 -> R² = 0.3182, MSE = 1.5727e-01
# X | test1 -> R² = 0.0286, MSE = 1.0112e-01
# Y | test1 -> R² = -1.5088, MSE = 2.0492e-01
# Theta | test2 -> R² = 0.6954, MSE = 7.1759e-02
# X | test2 -> R² = -0.0013, MSE = 8.2198e-02
# Y | test2 -> R² = -1.2157, MSE = 2.3393e-01
# Theta | test3 -> R² = -2.4896, MSE = 1.1501e+00
# X | test3 -> R² = -1.0117, MSE = 1.8405e-01
# Y | test3 -> R² = -6.9591, MSE = 6.0919e-01
# Theta | val -> R² = -1.5388, MSE = 8.3303e-01
# X | val -> R² = -0.8382, MSE = 1.7471e-01
# Y | val -> R² = -4.5159, MSE = 4.0937e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.639639 | Val Loss 0.800861
# Epoch 100 | Train Loss 1.246198 | Val Loss 0.681461
# Epoch 200 | Train Loss 1.164916 | Val Loss 0.639942
# Epoch 300 | Train Loss 1.109016 | Val Loss 0.638292
# Epoch 400 | Train Loss 1.067658 | Val Loss 0.648927
# Epoch 500 | Train Loss 1.025666 | Val Loss 0.669720
# Epoch 600 | Train Loss 0.981907 | Val Loss 0.691726
# Early stopping at epoch 684
# Theta | train1 -> R² = 0.9395, MSE = 1.3876e-02
# X | train1 -> R² = -0.0962, MSE = 1.1749e-01
# Y | train1 -> R² = -0.6306, MSE = 1.3628e-01
# Theta | train2 -> R² = 0.7767, MSE = 5.0632e-02
# X | train2 -> R² = -0.0373, MSE = 8.7182e-02
# Y | train2 -> R² = -1.0375, MSE = 2.1816e-01
# Theta | test1 -> R² = 0.3918, MSE = 1.4028e-01
# X | test1 -> R² = 0.0327, MSE = 1.0069e-01
# Y | test1 -> R² = -1.5203, MSE = 2.0586e-01
# Theta | test2 -> R² = 0.5095, MSE = 1.1555e-01
# X | test2 -> R² = -0.0791, MSE = 8.8585e-02
# Y | test2 -> R² = -1.1097, MSE = 2.2274e-01
# Theta | test3 -> R² = -0.1674, MSE = 3.8475e-01
# X | test3 -> R² = -1.5938, MSE = 2.3732e-01
# Y | test3 -> R² = -8.0213, MSE = 6.9049e-01
# Theta | val -> R² = -4.6747, MSE = 1.8620e+00
# X | val -> R² = -0.6290, MSE = 1.5482e-01
# Y | val -> R² = -5.7965, MSE = 5.0441e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.618289 | Val Loss 0.820451
# Epoch 100 | Train Loss 1.203608 | Val Loss 0.667836
# Epoch 200 | Train Loss 1.102718 | Val Loss 0.631128
# Epoch 300 | Train Loss 1.027713 | Val Loss 0.642439
# Epoch 400 | Train Loss 0.953996 | Val Loss 0.658485
# Epoch 500 | Train Loss 0.888954 | Val Loss 0.694716
# Epoch 600 | Train Loss 0.838551 | Val Loss 0.720432
# Epoch 700 | Train Loss 0.800716 | Val Loss 0.754621
# Early stopping at epoch 793
# Theta | train1 -> R² = 0.7791, MSE = 5.0640e-02
# X | train1 -> R² = 0.1684, MSE = 8.9128e-02
# Y | train1 -> R² = -0.2309, MSE = 1.0288e-01
# Theta | train2 -> R² = 0.7006, MSE = 6.7875e-02
# X | train2 -> R² = 0.2407, MSE = 6.3819e-02
# Y | train2 -> R² = -2.1316, MSE = 3.3530e-01
# Theta | test1 -> R² = 0.4657, MSE = 1.2324e-01
# X | test1 -> R² = 0.4662, MSE = 5.5567e-02
# Y | test1 -> R² = -2.8488, MSE = 3.1437e-01
# Theta | test2 -> R² = 0.8230, MSE = 4.1690e-02
# X | test2 -> R² = 0.0132, MSE = 8.1012e-02
# Y | test2 -> R² = -2.4068, MSE = 3.5967e-01
# Theta | test3 -> R² = -2.2306, MSE = 1.0647e+00
# X | test3 -> R² = -1.3211, MSE = 2.1236e-01
# Y | test3 -> R² = -3.7201, MSE = 3.6128e-01
# Theta | val -> R² = 0.7140, MSE = 9.3844e-02
# X | val -> R² = -0.1310, MSE = 1.0749e-01
# Y | val -> R² = -3.8528, MSE = 3.6015e-01
# Figura salva em: ./results/model_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.615671 | Val Loss 0.765158
# Epoch 100 | Train Loss 1.201313 | Val Loss 0.644878
# Epoch 200 | Train Loss 1.108007 | Val Loss 0.624040
# Epoch 300 | Train Loss 1.033975 | Val Loss 0.639368
# Epoch 400 | Train Loss 0.949357 | Val Loss 0.665248
# Epoch 500 | Train Loss 0.881051 | Val Loss 0.671669
# Epoch 600 | Train Loss 0.831132 | Val Loss 0.715088
# Early stopping at epoch 664
# Theta | train1 -> R² = 0.4888, MSE = 1.1717e-01
# X | train1 -> R² = -0.1988, MSE = 1.2849e-01
# Y | train1 -> R² = -0.3744, MSE = 1.1487e-01
# Theta | train2 -> R² = 0.5112, MSE = 1.1084e-01
# X | train2 -> R² = -0.0105, MSE = 8.4929e-02
# Y | train2 -> R² = -1.2207, MSE = 2.3778e-01
# Theta | test1 -> R² = 0.4711, MSE = 1.2199e-01
# X | test1 -> R² = 0.1290, MSE = 9.0664e-02
# Y | test1 -> R² = -1.6299, MSE = 2.1481e-01
# Theta | test2 -> R² = 0.5394, MSE = 1.0850e-01
# X | test2 -> R² = -0.0401, MSE = 8.5386e-02
# Y | test2 -> R² = -1.2975, MSE = 2.4256e-01
# Theta | test3 -> R² = -2.5798, MSE = 1.1798e+00
# X | test3 -> R² = -1.2875, MSE = 2.0929e-01
# Y | test3 -> R² = -8.5747, MSE = 7.3285e-01
# Theta | val -> R² = -3.1478, MSE = 1.3610e+00
# X | val -> R² = -0.5321, MSE = 1.4561e-01
# Y | val -> R² = -6.7248, MSE = 5.7330e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.588993 | Val Loss 0.788104
# Epoch 100 | Train Loss 1.216312 | Val Loss 0.721015
# Epoch 200 | Train Loss 1.110347 | Val Loss 0.657924
# Epoch 300 | Train Loss 1.034590 | Val Loss 0.664825
# Epoch 400 | Train Loss 0.957992 | Val Loss 0.690336
# Epoch 500 | Train Loss 0.894632 | Val Loss 0.743434
# Epoch 600 | Train Loss 0.850993 | Val Loss 0.791723
# Early stopping at epoch 670
# Theta | train1 -> R² = 0.6369, MSE = 8.3219e-02
# X | train1 -> R² = -0.2123, MSE = 1.2993e-01
# Y | train1 -> R² = -0.2016, MSE = 1.0043e-01
# Theta | train2 -> R² = 0.4313, MSE = 1.2896e-01
# X | train2 -> R² = 0.0290, MSE = 8.1616e-02
# Y | train2 -> R² = -1.5522, MSE = 2.7327e-01
# Theta | test1 -> R² = 0.4923, MSE = 1.1710e-01
# X | test1 -> R² = -0.0469, MSE = 1.0898e-01
# Y | test1 -> R² = -1.5547, MSE = 2.0867e-01
# Theta | test2 -> R² = 0.5910, MSE = 9.6345e-02
# X | test2 -> R² = -0.0831, MSE = 8.8914e-02
# Y | test2 -> R² = -1.6353, MSE = 2.7822e-01
# Theta | test3 -> R² = -3.3650, MSE = 1.4386e+00
# X | test3 -> R² = -1.2877, MSE = 2.0931e-01
# Y | test3 -> R² = -7.9826, MSE = 6.8753e-01
# Theta | val -> R² = -6.4465, MSE = 2.4433e+00
# X | val -> R² = -0.8308, MSE = 1.7400e-01
# Y | val -> R² = -6.1463, MSE = 5.3037e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.554289 | Val Loss 0.776172
# Epoch 100 | Train Loss 1.203668 | Val Loss 0.688953
# Epoch 200 | Train Loss 1.099983 | Val Loss 0.660493
# Epoch 300 | Train Loss 1.028164 | Val Loss 0.664797
# Epoch 400 | Train Loss 0.951826 | Val Loss 0.681571
# Epoch 500 | Train Loss 0.884547 | Val Loss 0.715422
# Epoch 600 | Train Loss 0.840607 | Val Loss 0.718112
# Early stopping at epoch 686
# Theta | train1 -> R² = 0.6049, MSE = 9.0554e-02
# X | train1 -> R² = -0.2051, MSE = 1.2917e-01
# Y | train1 -> R² = -0.0786, MSE = 9.0150e-02
# Theta | train2 -> R² = 0.5617, MSE = 9.9371e-02
# X | train2 -> R² = 0.1299, MSE = 7.3128e-02
# Y | train2 -> R² = -1.4377, MSE = 2.6101e-01
# Theta | test1 -> R² = 0.4439, MSE = 1.2827e-01
# X | test1 -> R² = 0.0854, MSE = 9.5211e-02
# Y | test1 -> R² = -1.5230, MSE = 2.0608e-01
# Theta | test2 -> R² = 0.5964, MSE = 9.5078e-02
# X | test2 -> R² = -0.0411, MSE = 8.5472e-02
# Y | test2 -> R² = -1.4033, MSE = 2.5373e-01
# Theta | test3 -> R² = -0.2432, MSE = 4.0975e-01
# X | test3 -> R² = -0.8362, MSE = 1.6800e-01
# Y | test3 -> R² = -8.1312, MSE = 6.9890e-01
# Theta | val -> R² = -4.2123, MSE = 1.7102e+00
# X | val -> R² = -1.0770, MSE = 1.9740e-01
# Y | val -> R² = -5.9882, MSE = 5.1863e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.547323 | Val Loss 0.767627
# Epoch 100 | Train Loss 1.193054 | Val Loss 0.645517
# Epoch 200 | Train Loss 1.105540 | Val Loss 0.629036
# Epoch 300 | Train Loss 1.028052 | Val Loss 0.636557
# Epoch 400 | Train Loss 0.945791 | Val Loss 0.657265
# Epoch 500 | Train Loss 0.878893 | Val Loss 0.680678
# Epoch 600 | Train Loss 0.832833 | Val Loss 0.711101
# Early stopping at epoch 672
# Theta | train1 -> R² = 0.0170, MSE = 2.2530e-01
# X | train1 -> R² = -0.2352, MSE = 1.3238e-01
# Y | train1 -> R² = -0.2124, MSE = 1.0133e-01
# Theta | train2 -> R² = 0.6444, MSE = 8.0619e-02
# X | train2 -> R² = 0.0271, MSE = 8.1769e-02
# Y | train2 -> R² = -1.2400, MSE = 2.3984e-01
# Theta | test1 -> R² = 0.4572, MSE = 1.2520e-01
# X | test1 -> R² = 0.1377, MSE = 8.9758e-02
# Y | test1 -> R² = -1.7351, MSE = 2.2340e-01
# Theta | test2 -> R² = 0.1499, MSE = 2.0027e-01
# X | test2 -> R² = -0.1066, MSE = 9.0842e-02
# Y | test2 -> R² = -1.3606, MSE = 2.4922e-01
# Theta | test3 -> R² = -0.9479, MSE = 6.4199e-01
# X | test3 -> R² = -0.9187, MSE = 1.7554e-01
# Y | test3 -> R² = -7.5937, MSE = 6.5776e-01
# Theta | val -> R² = -2.6504, MSE = 1.1978e+00
# X | val -> R² = -0.3192, MSE = 1.2538e-01
# Y | val -> R² = -6.5402, MSE = 5.5960e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.511660 | Val Loss 0.752615
# Epoch 100 | Train Loss 1.184877 | Val Loss 0.651176
# Epoch 200 | Train Loss 1.095367 | Val Loss 0.618114
# Epoch 300 | Train Loss 1.020494 | Val Loss 0.625960
# Epoch 400 | Train Loss 0.947116 | Val Loss 0.639408
# Epoch 500 | Train Loss 0.888873 | Val Loss 0.659556
# Epoch 600 | Train Loss 0.843319 | Val Loss 0.678398
# Epoch 700 | Train Loss 0.815096 | Val Loss 0.714266
# Epoch 800 | Train Loss 0.777999 | Val Loss 0.725823
# Early stopping at epoch 853
# Theta | train1 -> R² = 0.3472, MSE = 1.4963e-01
# X | train1 -> R² = 0.3511, MSE = 6.9547e-02
# Y | train1 -> R² = -0.1531, MSE = 9.6372e-02
# Theta | train2 -> R² = 0.9383, MSE = 1.3989e-02
# X | train2 -> R² = 0.3193, MSE = 5.7217e-02
# Y | train2 -> R² = -1.8639, MSE = 3.0664e-01
# Theta | test1 -> R² = 0.6462, MSE = 8.1600e-02
# X | test1 -> R² = 0.5292, MSE = 4.9013e-02
# Y | test1 -> R² = -2.4093, MSE = 2.7848e-01
# Theta | test2 -> R² = 0.7295, MSE = 6.3737e-02
# X | test2 -> R² = -0.0677, MSE = 8.7655e-02
# Y | test2 -> R² = -2.1969, MSE = 3.3752e-01
# Theta | test3 -> R² = -2.7524, MSE = 1.2367e+00
# X | test3 -> R² = -1.1752, MSE = 1.9901e-01
# Y | test3 -> R² = -4.1305, MSE = 3.9269e-01
# Theta | val -> R² = -0.7146, MSE = 5.6259e-01
# X | val -> R² = -0.3224, MSE = 1.2569e-01
# Y | val -> R² = -3.4458, MSE = 3.2995e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.665111 | Val Loss 0.768835
# Epoch 100 | Train Loss 1.215592 | Val Loss 0.651890
# Epoch 200 | Train Loss 1.112480 | Val Loss 0.629596
# Epoch 300 | Train Loss 1.040902 | Val Loss 0.648759
# Epoch 400 | Train Loss 0.963242 | Val Loss 0.683186
# Epoch 500 | Train Loss 0.907354 | Val Loss 0.699164
# Epoch 600 | Train Loss 0.840806 | Val Loss 0.731408
# Early stopping at epoch 652
# Theta | train1 -> R² = 0.9532, MSE = 1.0717e-02
# X | train1 -> R² = -0.2081, MSE = 1.2948e-01
# Y | train1 -> R² = -0.3770, MSE = 1.1509e-01
# Theta | train2 -> R² = 0.3910, MSE = 1.3808e-01
# X | train2 -> R² = 0.0723, MSE = 7.7971e-02
# Y | train2 -> R² = -1.2050, MSE = 2.3609e-01
# Theta | test1 -> R² = -0.0500, MSE = 2.4218e-01
# X | test1 -> R² = 0.1089, MSE = 9.2759e-02
# Y | test1 -> R² = -1.5730, MSE = 2.1016e-01
# Theta | test2 -> R² = 0.7896, MSE = 4.9558e-02
# X | test2 -> R² = -0.0423, MSE = 8.5567e-02
# Y | test2 -> R² = -1.2843, MSE = 2.4117e-01
# Theta | test3 -> R² = -4.4774, MSE = 1.8053e+00
# X | test3 -> R² = -1.5264, MSE = 2.3115e-01
# Y | test3 -> R² = -7.2846, MSE = 6.3410e-01
# Theta | val -> R² = -5.0894, MSE = 1.9980e+00
# X | val -> R² = -0.2707, MSE = 1.2077e-01
# Y | val -> R² = -5.9413, MSE = 5.1515e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.605006 | Val Loss 0.774763
# Epoch 100 | Train Loss 1.212326 | Val Loss 0.649864
# Epoch 200 | Train Loss 1.112052 | Val Loss 0.631192
# Epoch 300 | Train Loss 1.036136 | Val Loss 0.633431
# Epoch 400 | Train Loss 0.956348 | Val Loss 0.659227
# Epoch 500 | Train Loss 0.893407 | Val Loss 0.678084
# Epoch 600 | Train Loss 0.841130 | Val Loss 0.688336
# Epoch 700 | Train Loss 0.797697 | Val Loss 0.718151
# Early stopping at epoch 766
# Theta | train1 -> R² = 0.9301, MSE = 1.6026e-02
# X | train1 -> R² = -0.1426, MSE = 1.2247e-01
# Y | train1 -> R² = -0.0382, MSE = 8.6770e-02
# Theta | train2 -> R² = 0.4302, MSE = 1.2921e-01
# X | train2 -> R² = 0.1657, MSE = 7.0122e-02
# Y | train2 -> R² = -1.5371, MSE = 2.7165e-01
# Theta | test1 -> R² = 0.1852, MSE = 1.8795e-01
# X | test1 -> R² = 0.1789, MSE = 8.5478e-02
# Y | test1 -> R² = -1.7250, MSE = 2.2258e-01
# Theta | test2 -> R² = 0.8233, MSE = 4.1630e-02
# X | test2 -> R² = -0.0169, MSE = 8.3479e-02
# Y | test2 -> R² = -1.7046, MSE = 2.8553e-01
# Theta | test3 -> R² = -5.0133, MSE = 1.9819e+00
# X | test3 -> R² = -1.0108, MSE = 1.8397e-01
# Y | test3 -> R² = -4.9259, MSE = 4.5357e-01
# Theta | val -> R² = -5.5230, MSE = 2.1403e+00
# X | val -> R² = -0.4756, MSE = 1.4025e-01
# Y | val -> R² = -4.9804, MSE = 4.4384e-01
# Figura salva em: ./results/model_128_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.616733 | Val Loss 0.762953
# Epoch 100 | Train Loss 1.199283 | Val Loss 0.661839
# Epoch 200 | Train Loss 1.095887 | Val Loss 0.639486
# Epoch 300 | Train Loss 1.015764 | Val Loss 0.667994
# Epoch 400 | Train Loss 0.934684 | Val Loss 0.699407
# Epoch 500 | Train Loss 0.869976 | Val Loss 0.720885
# Epoch 600 | Train Loss 0.832203 | Val Loss 0.729776
# Early stopping at epoch 665
# Theta | train1 -> R² = 0.8017, MSE = 4.5446e-02
# X | train1 -> R² = -0.2829, MSE = 1.3750e-01
# Y | train1 -> R² = -0.1594, MSE = 9.6902e-02
# Theta | train2 -> R² = 0.6144, MSE = 8.7441e-02
# X | train2 -> R² = 0.1010, MSE = 7.5558e-02
# Y | train2 -> R² = -1.3164, MSE = 2.4802e-01
# Theta | test1 -> R² = 0.3398, MSE = 1.5227e-01
# X | test1 -> R² = 0.0512, MSE = 9.8769e-02
# Y | test1 -> R² = -1.5901, MSE = 2.1156e-01
# Theta | test2 -> R² = 0.5859, MSE = 9.7548e-02
# X | test2 -> R² = -0.0012, MSE = 8.2192e-02
# Y | test2 -> R² = -1.4172, MSE = 2.5520e-01
# Theta | test3 -> R² = -0.9509, MSE = 6.4298e-01
# X | test3 -> R² = -1.4330, MSE = 2.2260e-01
# Y | test3 -> R² = -6.8330, MSE = 5.9954e-01
# Theta | val -> R² = -3.2789, MSE = 1.4040e+00
# X | val -> R² = -0.7709, MSE = 1.6831e-01
# Y | val -> R² = -5.3450, MSE = 4.7090e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.587341 | Val Loss 0.780413
# Epoch 100 | Train Loss 1.209971 | Val Loss 0.704422
# Epoch 200 | Train Loss 1.108902 | Val Loss 0.663977
# Epoch 300 | Train Loss 1.033924 | Val Loss 0.666362
# Epoch 400 | Train Loss 0.954941 | Val Loss 0.685575
# Epoch 500 | Train Loss 0.890457 | Val Loss 0.702940
# Epoch 600 | Train Loss 0.843230 | Val Loss 0.726079
# Epoch 700 | Train Loss 0.805466 | Val Loss 0.750779
# Early stopping at epoch 744
# Theta | train1 -> R² = 0.6215, MSE = 8.6760e-02
# X | train1 -> R² = -0.2521, MSE = 1.3420e-01
# Y | train1 -> R² = 0.1435, MSE = 7.1585e-02
# Theta | train2 -> R² = 0.7677, MSE = 5.2666e-02
# X | train2 -> R² = 0.1522, MSE = 7.1261e-02
# Y | train2 -> R² = -1.3308, MSE = 2.4957e-01
# Theta | test1 -> R² = 0.5666, MSE = 9.9980e-02
# X | test1 -> R² = 0.1548, MSE = 8.7981e-02
# Y | test1 -> R² = -1.4486, MSE = 2.0001e-01
# Theta | test2 -> R² = 0.6821, MSE = 7.4893e-02
# X | test2 -> R² = -0.0189, MSE = 8.3645e-02
# Y | test2 -> R² = -1.4216, MSE = 2.5567e-01
# Theta | test3 -> R² = -0.1969, MSE = 3.9447e-01
# X | test3 -> R² = -1.1987, MSE = 2.0117e-01
# Y | test3 -> R² = -6.7677, MSE = 5.9454e-01
# Theta | val -> R² = -3.2442, MSE = 1.3926e+00
# X | val -> R² = -1.2209, MSE = 2.1108e-01
# Y | val -> R² = -6.4355, MSE = 5.5183e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.588824 | Val Loss 0.855518
# Epoch 100 | Train Loss 1.167362 | Val Loss 0.643423
# Epoch 200 | Train Loss 1.031361 | Val Loss 0.629048
# Epoch 300 | Train Loss 0.920669 | Val Loss 0.650607
# Epoch 400 | Train Loss 0.828436 | Val Loss 0.695039
# Epoch 500 | Train Loss 0.765489 | Val Loss 0.740805
# Epoch 600 | Train Loss 0.730733 | Val Loss 0.787217
# Epoch 700 | Train Loss 0.705542 | Val Loss 0.817182
# Early stopping at epoch 719
# Theta | train1 -> R² = 0.8989, MSE = 2.3170e-02
# X | train1 -> R² = 0.1238, MSE = 9.3910e-02
# Y | train1 -> R² = 0.1190, MSE = 7.3633e-02
# Theta | train2 -> R² = 0.0932, MSE = 2.0560e-01
# X | train2 -> R² = 0.2377, MSE = 6.4074e-02
# Y | train2 -> R² = -1.3184, MSE = 2.4824e-01
# Theta | test1 -> R² = -0.4538, MSE = 3.3534e-01
# X | test1 -> R² = 0.3916, MSE = 6.3328e-02
# Y | test1 -> R² = -1.5459, MSE = 2.0795e-01
# Theta | test2 -> R² = 0.7513, MSE = 5.8597e-02
# X | test2 -> R² = -0.0642, MSE = 8.7361e-02
# Y | test2 -> R² = -1.5791, MSE = 2.7229e-01
# Theta | test3 -> R² = -3.2177, MSE = 1.3901e+00
# X | test3 -> R² = -1.3787, MSE = 2.1763e-01
# Y | test3 -> R² = -6.2632, MSE = 5.5593e-01
# Theta | val -> R² = -1.6115, MSE = 8.5689e-01
# X | val -> R² = -0.3652, MSE = 1.2975e-01
# Y | val -> R² = -5.9264, MSE = 5.1405e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.723330 | Val Loss 0.735837
# Epoch 100 | Train Loss 1.184073 | Val Loss 0.676923
# Epoch 200 | Train Loss 1.041348 | Val Loss 0.649757
# Epoch 300 | Train Loss 0.931105 | Val Loss 0.650560
# Epoch 400 | Train Loss 0.828642 | Val Loss 0.683616
# Epoch 500 | Train Loss 0.764851 | Val Loss 0.711698
# Epoch 600 | Train Loss 0.722448 | Val Loss 0.749955
# Early stopping at epoch 698
# Theta | train1 -> R² = 0.5716, MSE = 9.8189e-02
# X | train1 -> R² = 0.0484, MSE = 1.0199e-01
# Y | train1 -> R² = 0.0467, MSE = 7.9680e-02
# Theta | train2 -> R² = 0.8721, MSE = 2.9000e-02
# X | train2 -> R² = 0.2895, MSE = 5.9718e-02
# Y | train2 -> R² = -1.5147, MSE = 2.6926e-01
# Theta | test1 -> R² = 0.4245, MSE = 1.3274e-01
# X | test1 -> R² = 0.3724, MSE = 6.5329e-02
# Y | test1 -> R² = -1.8937, MSE = 2.3636e-01
# Theta | test2 -> R² = 0.4823, MSE = 1.2196e-01
# X | test2 -> R² = 0.0020, MSE = 8.1932e-02
# Y | test2 -> R² = -1.6373, MSE = 2.7843e-01
# Theta | test3 -> R² = -4.4289, MSE = 1.7893e+00
# X | test3 -> R² = -0.8348, MSE = 1.6787e-01
# Y | test3 -> R² = -6.1194, MSE = 5.4492e-01
# Theta | val -> R² = -5.8440, MSE = 2.2456e+00
# X | val -> R² = -0.8532, MSE = 1.7613e-01
# Y | val -> R² = -5.4086, MSE = 4.7562e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.743916 | Val Loss 0.774161
# Epoch 100 | Train Loss 1.197926 | Val Loss 0.670969
# Epoch 200 | Train Loss 1.060086 | Val Loss 0.648656
# Epoch 300 | Train Loss 0.947583 | Val Loss 0.645648
# Epoch 400 | Train Loss 0.853853 | Val Loss 0.685867
# Epoch 500 | Train Loss 0.788355 | Val Loss 0.732922
# Epoch 600 | Train Loss 0.741642 | Val Loss 0.773674
# Epoch 700 | Train Loss 0.704278 | Val Loss 0.800942
# Early stopping at epoch 767
# Theta | train1 -> R² = 0.9411, MSE = 1.3501e-02
# X | train1 -> R² = 0.3880, MSE = 6.5589e-02
# Y | train1 -> R² = -0.2332, MSE = 1.0307e-01
# Theta | train2 -> R² = 0.5587, MSE = 1.0007e-01
# X | train2 -> R² = 0.2864, MSE = 5.9980e-02
# Y | train2 -> R² = -1.8707, MSE = 3.0738e-01
# Theta | test1 -> R² = 0.0376, MSE = 2.2200e-01
# X | test1 -> R² = 0.5333, MSE = 4.8578e-02
# Y | test1 -> R² = -2.5060, MSE = 2.8637e-01
# Theta | test2 -> R² = 0.8279, MSE = 4.0554e-02
# X | test2 -> R² = -0.0736, MSE = 8.8133e-02
# Y | test2 -> R² = -2.3137, MSE = 3.4985e-01
# Theta | test3 -> R² = -1.3278, MSE = 7.6721e-01
# X | test3 -> R² = -0.6556, MSE = 1.5147e-01
# Y | test3 -> R² = -7.5548, MSE = 6.5478e-01
# Theta | val -> R² = 0.5298, MSE = 1.5427e-01
# X | val -> R² = -0.5526, MSE = 1.4756e-01
# Y | val -> R² = -5.7790, MSE = 5.0311e-01
# Figura salva em: ./results/model_264_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.660900 | Val Loss 0.756552
# Epoch 100 | Train Loss 1.192440 | Val Loss 0.675126
# Epoch 200 | Train Loss 1.048941 | Val Loss 0.648481
# Epoch 300 | Train Loss 0.915695 | Val Loss 0.686706
# Epoch 400 | Train Loss 0.814123 | Val Loss 0.688609
# Epoch 500 | Train Loss 0.757003 | Val Loss 0.765018
# Epoch 600 | Train Loss 0.712053 | Val Loss 0.791456
# Epoch 700 | Train Loss 0.698246 | Val Loss 0.833096
# Early stopping at epoch 722
# Theta | train1 -> R² = 0.6377, MSE = 8.3034e-02
# X | train1 -> R² = 0.3062, MSE = 7.4366e-02
# Y | train1 -> R² = -0.1859, MSE = 9.9116e-02
# Theta | train2 -> R² = 0.8366, MSE = 3.7039e-02
# X | train2 -> R² = 0.2684, MSE = 6.1487e-02
# Y | train2 -> R² = -1.7850, MSE = 2.9819e-01
# Theta | test1 -> R² = 0.6398, MSE = 8.3095e-02
# X | test1 -> R² = 0.5238, MSE = 4.9567e-02
# Y | test1 -> R² = -2.1085, MSE = 2.5391e-01
# Theta | test2 -> R² = 0.5806, MSE = 9.8806e-02
# X | test2 -> R² = -0.0781, MSE = 8.8505e-02
# Y | test2 -> R² = -1.9188, MSE = 3.0815e-01
# Theta | test3 -> R² = -1.4343, MSE = 8.0230e-01
# X | test3 -> R² = -0.4483, MSE = 1.3251e-01
# Y | test3 -> R² = -5.8447, MSE = 5.2389e-01
# Theta | val -> R² = -0.0487, MSE = 3.4409e-01
# X | val -> R² = -0.2042, MSE = 1.1445e-01
# Y | val -> R² = -4.4171, MSE = 4.0203e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.539223 | Val Loss 0.871246
# Epoch 100 | Train Loss 1.169520 | Val Loss 0.658109
# Epoch 200 | Train Loss 1.032500 | Val Loss 0.645117
# Epoch 300 | Train Loss 0.909995 | Val Loss 0.690225
# Epoch 400 | Train Loss 0.820695 | Val Loss 0.745442
# Epoch 500 | Train Loss 0.763427 | Val Loss 0.735736
# Epoch 600 | Train Loss 0.718831 | Val Loss 0.768771
# Epoch 700 | Train Loss 0.692825 | Val Loss 0.780681
# Early stopping at epoch 704
# Theta | train1 -> R² = 0.9228, MSE = 1.7689e-02
# X | train1 -> R² = 0.4396, MSE = 6.0058e-02
# Y | train1 -> R² = -0.3847, MSE = 1.1573e-01
# Theta | train2 -> R² = 0.5091, MSE = 1.1131e-01
# X | train2 -> R² = 0.2575, MSE = 6.2408e-02
# Y | train2 -> R² = -2.3635, MSE = 3.6013e-01
# Theta | test1 -> R² = -0.0966, MSE = 2.5295e-01
# X | test1 -> R² = 0.5320, MSE = 4.8716e-02
# Y | test1 -> R² = -2.5625, MSE = 2.9098e-01
# Theta | test2 -> R² = 0.7185, MSE = 6.6319e-02
# X | test2 -> R² = -0.1082, MSE = 9.0976e-02
# Y | test2 -> R² = -2.5259, MSE = 3.7225e-01
# Theta | test3 -> R² = -2.2276, MSE = 1.0637e+00
# X | test3 -> R² = 0.0325, MSE = 8.8519e-02
# Y | test3 -> R² = -7.0465, MSE = 6.1588e-01
# Theta | val -> R² = -1.9830, MSE = 9.7878e-01
# X | val -> R² = -0.0939, MSE = 1.0396e-01
# Y | val -> R² = -5.6854, MSE = 4.9617e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.671581 | Val Loss 0.758052
# Epoch 100 | Train Loss 1.175464 | Val Loss 0.643688
# Epoch 200 | Train Loss 1.050915 | Val Loss 0.634992
# Epoch 300 | Train Loss 0.932662 | Val Loss 0.677318
# Epoch 400 | Train Loss 0.842032 | Val Loss 0.702247
# Epoch 500 | Train Loss 0.787040 | Val Loss 0.758206
# Epoch 600 | Train Loss 0.732850 | Val Loss 0.763402
# Epoch 700 | Train Loss 0.706328 | Val Loss 0.801904
# Early stopping at epoch 711
# Theta | train1 -> R² = 0.8392, MSE = 3.6860e-02
# X | train1 -> R² = 0.2666, MSE = 7.8611e-02
# Y | train1 -> R² = -0.2079, MSE = 1.0096e-01
# Theta | train2 -> R² = 0.4213, MSE = 1.3120e-01
# X | train2 -> R² = 0.2357, MSE = 6.4239e-02
# Y | train2 -> R² = -1.7795, MSE = 2.9761e-01
# Theta | test1 -> R² = 0.0832, MSE = 2.1147e-01
# X | test1 -> R² = 0.5216, MSE = 4.9801e-02
# Y | test1 -> R² = -2.2547, MSE = 2.6585e-01
# Theta | test2 -> R² = 0.8159, MSE = 4.3373e-02
# X | test2 -> R² = -0.0901, MSE = 8.9493e-02
# Y | test2 -> R² = -2.1109, MSE = 3.2843e-01
# Theta | test3 -> R² = -2.4129, MSE = 1.1248e+00
# X | test3 -> R² = -0.9010, MSE = 1.7393e-01
# Y | test3 -> R² = -5.0325, MSE = 4.6172e-01
# Theta | val -> R² = -2.2574, MSE = 1.0688e+00
# X | val -> R² = -0.8427, MSE = 1.7513e-01
# Y | val -> R² = -4.9333, MSE = 4.4035e-01
# Figura salva em: ./results/model_264_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.906258 | Val Loss 0.740353
# Epoch 100 | Train Loss 1.194953 | Val Loss 0.699176
# Epoch 200 | Train Loss 1.073625 | Val Loss 0.626158
# Epoch 300 | Train Loss 0.970870 | Val Loss 0.624305
# Epoch 400 | Train Loss 0.863064 | Val Loss 0.672924
# Epoch 500 | Train Loss 0.792376 | Val Loss 0.697726
# Epoch 600 | Train Loss 0.758783 | Val Loss 0.724594
# Epoch 700 | Train Loss 0.717940 | Val Loss 0.757889
# Early stopping at epoch 789
# Theta | train1 -> R² = 0.9358, MSE = 1.4726e-02
# X | train1 -> R² = 0.3813, MSE = 6.6315e-02
# Y | train1 -> R² = -0.2803, MSE = 1.0701e-01
# Theta | train2 -> R² = 0.7243, MSE = 6.2514e-02
# X | train2 -> R² = 0.2602, MSE = 6.2184e-02
# Y | train2 -> R² = -2.0219, MSE = 3.2356e-01
# Theta | test1 -> R² = 0.3516, MSE = 1.4956e-01
# X | test1 -> R² = 0.5823, MSE = 4.3479e-02
# Y | test1 -> R² = -2.6351, MSE = 2.9692e-01
# Theta | test2 -> R² = 0.7849, MSE = 5.0681e-02
# X | test2 -> R² = -0.1293, MSE = 9.2708e-02
# Y | test2 -> R² = -2.4136, MSE = 3.6040e-01
# Theta | test3 -> R² = -9.4972, MSE = 3.4597e+00
# X | test3 -> R² = -0.6801, MSE = 1.5372e-01
# Y | test3 -> R² = -5.5915, MSE = 5.0451e-01
# Theta | val -> R² = -1.9871, MSE = 9.8010e-01
# X | val -> R² = -0.5869, MSE = 1.5082e-01
# Y | val -> R² = -3.8117, MSE = 3.5711e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.658619 | Val Loss 0.774491
# Epoch 100 | Train Loss 1.192760 | Val Loss 0.650834
# Epoch 200 | Train Loss 1.062966 | Val Loss 0.623651
# Epoch 300 | Train Loss 0.948452 | Val Loss 0.628930
# Epoch 400 | Train Loss 0.849934 | Val Loss 0.656160
# Epoch 500 | Train Loss 0.778670 | Val Loss 0.697614
# Epoch 600 | Train Loss 0.735566 | Val Loss 0.738419
# Epoch 700 | Train Loss 0.710927 | Val Loss 0.787264
# Early stopping at epoch 756
# Theta | train1 -> R² = 0.9618, MSE = 8.7589e-03
# X | train1 -> R² = 0.2815, MSE = 7.7007e-02
# Y | train1 -> R² = -0.0238, MSE = 8.5567e-02
# Theta | train2 -> R² = 0.6750, MSE = 7.3685e-02
# X | train2 -> R² = 0.2511, MSE = 6.2944e-02
# Y | train2 -> R² = -1.5269, MSE = 2.7056e-01
# Theta | test1 -> R² = 0.2886, MSE = 1.6408e-01
# X | test1 -> R² = 0.5047, MSE = 5.1554e-02
# Y | test1 -> R² = -1.9250, MSE = 2.3891e-01
# Theta | test2 -> R² = 0.8216, MSE = 4.2028e-02
# X | test2 -> R² = -0.1194, MSE = 9.1895e-02
# Y | test2 -> R² = -1.8210, MSE = 2.9783e-01
# Theta | test3 -> R² = -2.7988, MSE = 1.2520e+00
# X | test3 -> R² = -1.2652, MSE = 2.0725e-01
# Y | test3 -> R² = -3.8886, MSE = 3.7417e-01
# Theta | val -> R² = -1.4540, MSE = 8.0519e-01
# X | val -> R² = -0.3144, MSE = 1.2492e-01
# Y | val -> R² = -4.2777, MSE = 3.9169e-01
# Figura salva em: ./results/model_264_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.552666 | Val Loss 0.783491
# Epoch 100 | Train Loss 1.171304 | Val Loss 0.677513
# Epoch 200 | Train Loss 1.038091 | Val Loss 0.644352
# Epoch 300 | Train Loss 0.922778 | Val Loss 0.657654
# Epoch 400 | Train Loss 0.834717 | Val Loss 0.709399
# Epoch 500 | Train Loss 0.761642 | Val Loss 0.756853
# Epoch 600 | Train Loss 0.718639 | Val Loss 0.810986
# Early stopping at epoch 678
# Theta | train1 -> R² = 0.5181, MSE = 1.1046e-01
# X | train1 -> R² = 0.5124, MSE = 5.2263e-02
# Y | train1 -> R² = -0.4756, MSE = 1.2333e-01
# Theta | train2 -> R² = 0.6644, MSE = 7.6090e-02
# X | train2 -> R² = 0.1219, MSE = 7.3800e-02
# Y | train2 -> R² = -2.3681, MSE = 3.6063e-01
# Theta | test1 -> R² = 0.6798, MSE = 7.3859e-02
# X | test1 -> R² = 0.6218, MSE = 3.9369e-02
# Y | test1 -> R² = -2.4795, MSE = 2.8421e-01
# Theta | test2 -> R² = 0.5709, MSE = 1.0109e-01
# X | test2 -> R² = -0.1884, MSE = 9.7559e-02
# Y | test2 -> R² = -2.5474, MSE = 3.7452e-01
# Theta | test3 -> R² = 0.4497, MSE = 1.8138e-01
# X | test3 -> R² = -0.0064, MSE = 9.2079e-02
# Y | test3 -> R² = -9.3929, MSE = 7.9547e-01
# Theta | val -> R² = -0.4051, MSE = 4.6103e-01
# X | val -> R² = -0.0468, MSE = 9.9487e-02
# Y | val -> R² = -6.8870, MSE = 5.8534e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.705209 | Val Loss 0.749824
# Epoch 100 | Train Loss 1.175410 | Val Loss 0.667845
# Epoch 200 | Train Loss 1.052101 | Val Loss 0.637500
# Epoch 300 | Train Loss 0.940426 | Val Loss 0.652027
# Epoch 400 | Train Loss 0.848915 | Val Loss 0.700488
# Epoch 500 | Train Loss 0.782276 | Val Loss 0.708987
# Epoch 600 | Train Loss 0.738799 | Val Loss 0.743825
# Epoch 700 | Train Loss 0.710284 | Val Loss 0.769124
# Early stopping at epoch 733
# Theta | train1 -> R² = 0.3333, MSE = 1.5282e-01
# X | train1 -> R² = 0.3195, MSE = 7.2932e-02
# Y | train1 -> R² = -0.4532, MSE = 1.2146e-01
# Theta | train2 -> R² = 0.8141, MSE = 4.2151e-02
# X | train2 -> R² = 0.2980, MSE = 5.9004e-02
# Y | train2 -> R² = -2.1405, MSE = 3.3626e-01
# Theta | test1 -> R² = 0.6192, MSE = 8.7830e-02
# X | test1 -> R² = 0.5092, MSE = 5.1088e-02
# Y | test1 -> R² = -2.8224, MSE = 3.1222e-01
# Theta | test2 -> R² = 0.6143, MSE = 9.0865e-02
# X | test2 -> R² = -0.0431, MSE = 8.5635e-02
# Y | test2 -> R² = -2.5242, MSE = 3.7207e-01
# Theta | test3 -> R² = -5.9977, MSE = 2.3063e+00
# X | test3 -> R² = -1.0447, MSE = 1.8708e-01
# Y | test3 -> R² = -8.5753, MSE = 7.3290e-01
# Theta | val -> R² = -7.7453, MSE = 2.8695e+00
# X | val -> R² = -0.1545, MSE = 1.0972e-01
# Y | val -> R² = -7.3410, MSE = 6.1904e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.571285 | Val Loss 0.806860
# Epoch 100 | Train Loss 1.443283 | Val Loss 0.776290
# Epoch 200 | Train Loss 1.326654 | Val Loss 0.679594
# Epoch 300 | Train Loss 1.282276 | Val Loss 0.668037
# Epoch 400 | Train Loss 1.245343 | Val Loss 0.660753
# Epoch 500 | Train Loss 1.216667 | Val Loss 0.666731
# Epoch 600 | Train Loss 1.203561 | Val Loss 0.677341
# Epoch 700 | Train Loss 1.197418 | Val Loss 0.682672
# Epoch 800 | Train Loss 1.193174 | Val Loss 0.686418
# Epoch 900 | Train Loss 1.189641 | Val Loss 0.689315
# Early stopping at epoch 921
# Theta | train1 -> R² = 0.9068, MSE = 2.1372e-02
# X | train1 -> R² = -0.1844, MSE = 1.2694e-01
# Y | train1 -> R² = -0.9375, MSE = 1.6194e-01
# Theta | train2 -> R² = 0.7624, MSE = 5.3872e-02
# X | train2 -> R² = -0.2021, MSE = 1.0104e-01
# Y | train2 -> R² = -0.9615, MSE = 2.1002e-01
# Theta | test1 -> R² = 0.7190, MSE = 6.4807e-02
# X | test1 -> R² = -0.3568, MSE = 1.4123e-01
# Y | test1 -> R² = -1.3080, MSE = 1.8852e-01
# Theta | test2 -> R² = 0.8748, MSE = 2.9492e-02
# X | test2 -> R² = -0.2685, MSE = 1.0413e-01
# Y | test2 -> R² = -1.0190, MSE = 2.1315e-01
# Theta | test3 -> R² = 0.7299, MSE = 8.9018e-02
# X | test3 -> R² = -1.4680, MSE = 2.2580e-01
# Y | test3 -> R² = -4.6506, MSE = 4.3250e-01
# Theta | val -> R² = -3.9679, MSE = 1.6300e+00
# X | val -> R² = -0.9641, MSE = 1.8668e-01
# Y | val -> R² = -3.2051, MSE = 3.1209e-01
# Figura salva em: ./results/model_8_4_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.571743 | Val Loss 0.803228
# Epoch 100 | Train Loss 1.412055 | Val Loss 0.751483
# Epoch 200 | Train Loss 1.293182 | Val Loss 0.668410
# Epoch 300 | Train Loss 1.254981 | Val Loss 0.667688
# Epoch 400 | Train Loss 1.231781 | Val Loss 0.662531
# Epoch 500 | Train Loss 1.216533 | Val Loss 0.664111
# Epoch 600 | Train Loss 1.204596 | Val Loss 0.664422
# Epoch 700 | Train Loss 1.197628 | Val Loss 0.667723
# Epoch 800 | Train Loss 1.193627 | Val Loss 0.669044
# Early stopping at epoch 878
# Theta | train1 -> R² = 0.9374, MSE = 1.4352e-02
# X | train1 -> R² = -0.1861, MSE = 1.2712e-01
# Y | train1 -> R² = -0.8840, MSE = 1.5747e-01
# Theta | train2 -> R² = 0.4235, MSE = 1.3072e-01
# X | train2 -> R² = -0.2355, MSE = 1.0385e-01
# Y | train2 -> R² = -0.9477, MSE = 2.0855e-01
# Theta | test1 -> R² = 0.5493, MSE = 1.0395e-01
# X | test1 -> R² = -0.3596, MSE = 1.4153e-01
# Y | test1 -> R² = -1.3952, MSE = 1.9564e-01
# Theta | test2 -> R² = 0.9031, MSE = 2.2831e-02
# X | test2 -> R² = -0.2539, MSE = 1.0294e-01
# Y | test2 -> R² = -0.9318, MSE = 2.0395e-01
# Theta | test3 -> R² = -0.5100, MSE = 4.9765e-01
# X | test3 -> R² = -1.0537, MSE = 1.8790e-01
# Y | test3 -> R² = -3.4647, MSE = 3.4173e-01
# Theta | val -> R² = -2.8938, MSE = 1.2776e+00
# X | val -> R² = -0.8713, MSE = 1.7785e-01
# Y | val -> R² = -3.2212, MSE = 3.1328e-01
# Figura salva em: ./results/model_8_4_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570942 | Val Loss 0.803706
# Epoch 100 | Train Loss 1.458023 | Val Loss 0.781984
# Epoch 200 | Train Loss 1.322487 | Val Loss 0.682535
# Epoch 300 | Train Loss 1.265226 | Val Loss 0.671196
# Epoch 400 | Train Loss 1.240995 | Val Loss 0.677055
# Epoch 500 | Train Loss 1.224290 | Val Loss 0.683244
# Epoch 600 | Train Loss 1.211644 | Val Loss 0.697128
# Epoch 700 | Train Loss 1.199359 | Val Loss 0.719957
# Early stopping at epoch 723
# Theta | train1 -> R² = 0.8761, MSE = 2.8406e-02
# X | train1 -> R² = -0.1541, MSE = 1.2370e-01
# Y | train1 -> R² = -0.8199, MSE = 1.5211e-01
# Theta | train2 -> R² = 0.6447, MSE = 8.0567e-02
# X | train2 -> R² = -0.2284, MSE = 1.0324e-01
# Y | train2 -> R² = -0.9968, MSE = 2.1380e-01
# Theta | test1 -> R² = 0.7423, MSE = 5.9438e-02
# X | test1 -> R² = -0.4395, MSE = 1.4985e-01
# Y | test1 -> R² = -1.5051, MSE = 2.0462e-01
# Theta | test2 -> R² = 0.9023, MSE = 2.3010e-02
# X | test2 -> R² = -0.1888, MSE = 9.7591e-02
# Y | test2 -> R² = -0.9143, MSE = 2.0211e-01
# Theta | test3 -> R² = -0.6525, MSE = 5.4463e-01
# X | test3 -> R² = -1.2825, MSE = 2.0883e-01
# Y | test3 -> R² = -4.4468, MSE = 4.1690e-01
# Theta | val -> R² = -4.0068, MSE = 1.6428e+00
# X | val -> R² = -1.6603, MSE = 2.5284e-01
# Y | val -> R² = -4.6564, MSE = 4.1980e-01
# Figura salva em: ./results/model_8_4_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572737 | Val Loss 0.803895
# Epoch 100 | Train Loss 1.434212 | Val Loss 0.762279
# Epoch 200 | Train Loss 1.312461 | Val Loss 0.679003
# Epoch 300 | Train Loss 1.273100 | Val Loss 0.681798
# Epoch 400 | Train Loss 1.249896 | Val Loss 0.704621
# Epoch 500 | Train Loss 1.236165 | Val Loss 0.725732
# Epoch 600 | Train Loss 1.227362 | Val Loss 0.740253
# Epoch 700 | Train Loss 1.220436 | Val Loss 0.753985
# Early stopping at epoch 726
# Theta | train1 -> R² = 0.9173, MSE = 1.8945e-02
# X | train1 -> R² = -0.2648, MSE = 1.3556e-01
# Y | train1 -> R² = -1.0629, MSE = 1.7242e-01
# Theta | train2 -> R² = 0.5002, MSE = 1.1332e-01
# X | train2 -> R² = -0.1447, MSE = 9.6208e-02
# Y | train2 -> R² = -0.8702, MSE = 2.0024e-01
# Theta | test1 -> R² = 0.8611, MSE = 3.2044e-02
# X | test1 -> R² = -0.4550, MSE = 1.5146e-01
# Y | test1 -> R² = -1.4978, MSE = 2.0402e-01
# Theta | test2 -> R² = 0.8602, MSE = 3.2937e-02
# X | test2 -> R² = -0.1567, MSE = 9.4954e-02
# Y | test2 -> R² = -0.8510, MSE = 1.9542e-01
# Theta | test3 -> R² = 0.6681, MSE = 1.0939e-01
# X | test3 -> R² = -1.4760, MSE = 2.2654e-01
# Y | test3 -> R² = -4.5095, MSE = 4.2170e-01
# Theta | val -> R² = -2.3012, MSE = 1.0832e+00
# X | val -> R² = -1.4207, MSE = 2.3006e-01
# Y | val -> R² = -4.1025, MSE = 3.7869e-01
# Figura salva em: ./results/model_8_4_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.573184 | Val Loss 0.804352
# Epoch 100 | Train Loss 1.462045 | Val Loss 0.781874
# Epoch 200 | Train Loss 1.454136 | Val Loss 0.780227
# Epoch 300 | Train Loss 1.385040 | Val Loss 0.735849
# Epoch 400 | Train Loss 1.265312 | Val Loss 0.689748
# Epoch 500 | Train Loss 1.233589 | Val Loss 0.688795
# Epoch 600 | Train Loss 1.220773 | Val Loss 0.692497
# Epoch 700 | Train Loss 1.211507 | Val Loss 0.694639
# Epoch 800 | Train Loss 1.203979 | Val Loss 0.696211
# Early stopping at epoch 862
# Theta | train1 -> R² = 0.7654, MSE = 5.3774e-02
# X | train1 -> R² = -0.2915, MSE = 1.3842e-01
# Y | train1 -> R² = -1.1749, MSE = 1.8178e-01
# Theta | train2 -> R² = 0.1403, MSE = 1.9493e-01
# X | train2 -> R² = -0.1567, MSE = 9.7224e-02
# Y | train2 -> R² = -0.9850, MSE = 2.1254e-01
# Theta | test1 -> R² = 0.8741, MSE = 2.9045e-02
# X | test1 -> R² = -0.5153, MSE = 1.5774e-01
# Y | test1 -> R² = -1.6839, MSE = 2.1923e-01
# Theta | test2 -> R² = 0.8268, MSE = 4.0810e-02
# X | test2 -> R² = -0.1687, MSE = 9.5942e-02
# Y | test2 -> R² = -0.9144, MSE = 2.0211e-01
# Theta | test3 -> R² = 0.2536, MSE = 2.4601e-01
# X | test3 -> R² = -4.0470, MSE = 4.6177e-01
# Y | test3 -> R² = -8.6553, MSE = 7.3902e-01
# Theta | val -> R² = -6.7502, MSE = 2.5430e+00
# X | val -> R² = -3.8243, MSE = 4.5851e-01
# Y | val -> R² = -8.7533, MSE = 7.2385e-01
# Figura salva em: ./results/model_8_4_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572343 | Val Loss 0.804477
# Epoch 100 | Train Loss 1.421345 | Val Loss 0.743075
# Epoch 200 | Train Loss 1.323654 | Val Loss 0.669658
# Epoch 300 | Train Loss 1.288743 | Val Loss 0.668373
# Epoch 400 | Train Loss 1.249660 | Val Loss 0.665428
# Epoch 500 | Train Loss 1.224079 | Val Loss 0.652144
# Epoch 600 | Train Loss 1.209035 | Val Loss 0.640899
# Epoch 700 | Train Loss 1.200200 | Val Loss 0.639493
# Epoch 800 | Train Loss 1.193514 | Val Loss 0.640787
# Epoch 900 | Train Loss 1.187363 | Val Loss 0.637481
# Epoch 1000 | Train Loss 1.182339 | Val Loss 0.641482
# Epoch 1100 | Train Loss 1.178716 | Val Loss 0.644021
# Epoch 1200 | Train Loss 1.175606 | Val Loss 0.644583
# Epoch 1300 | Train Loss 1.172560 | Val Loss 0.646135
# Early stopping at epoch 1371
# Theta | train1 -> R² = 0.8012, MSE = 4.5573e-02
# X | train1 -> R² = -0.1240, MSE = 1.2047e-01
# Y | train1 -> R² = -0.6763, MSE = 1.4011e-01
# Theta | train2 -> R² = 0.4978, MSE = 1.1388e-01
# X | train2 -> R² = -0.1068, MSE = 9.3028e-02
# Y | train2 -> R² = -1.0142, MSE = 2.1566e-01
# Theta | test1 -> R² = 0.7622, MSE = 5.4855e-02
# X | test1 -> R² = -0.2152, MSE = 1.2650e-01
# Y | test1 -> R² = -1.0857, MSE = 1.7036e-01
# Theta | test2 -> R² = 0.7540, MSE = 5.7943e-02
# X | test2 -> R² = -0.1746, MSE = 9.6424e-02
# Y | test2 -> R² = -0.9219, MSE = 2.0290e-01
# Theta | test3 -> R² = -1.2962, MSE = 7.5677e-01
# X | test3 -> R² = -1.0030, MSE = 1.8326e-01
# Y | test3 -> R² = -4.2506, MSE = 4.0188e-01
# Theta | val -> R² = -4.7358, MSE = 1.8820e+00
# X | val -> R² = -0.7233, MSE = 1.6379e-01
# Y | val -> R² = -2.5455, MSE = 2.6313e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.571555 | Val Loss 0.805461
# Epoch 100 | Train Loss 1.444993 | Val Loss 0.773607
# Epoch 200 | Train Loss 1.318032 | Val Loss 0.672831
# Epoch 300 | Train Loss 1.272259 | Val Loss 0.671308
# Epoch 400 | Train Loss 1.254305 | Val Loss 0.675766
# Epoch 500 | Train Loss 1.235247 | Val Loss 0.673083
# Epoch 600 | Train Loss 1.216287 | Val Loss 0.676603
# Epoch 700 | Train Loss 1.208078 | Val Loss 0.683712
# Early stopping at epoch 743
# Theta | train1 -> R² = 0.8183, MSE = 4.1655e-02
# X | train1 -> R² = -0.2321, MSE = 1.3206e-01
# Y | train1 -> R² = -1.0382, MSE = 1.7035e-01
# ...
# Epoch 400 | Train Loss 0.885714 | Val Loss 0.689932
# Epoch 500 | Train Loss 0.810903 | Val Loss 0.744957
# Epoch 600 | Train Loss 0.775731 | Val Loss 0.773094
# Early stopping at epoch 689
# Theta | train1 -> R² = 0.8342, MSE = 3.8012e-02
# X | train1 -> R² = -0.1702, MSE = 1.2542e-01
# Y | train1 -> R² = -0.1297, MSE = 9.4422e-02
# Theta | train2 -> R² = 0.4940, MSE = 1.1474e-01
# X | train2 -> R² = 0.0499, MSE = 7.9858e-02
# Y | train2 -> R² = -1.4295, MSE = 2.6013e-01
# Theta | test1 -> R² = 0.4403, MSE = 1.2910e-01
# X | test1 -> R² = 0.0796, MSE = 9.5810e-02
# Y | test1 -> R² = -1.5417, MSE = 2.0760e-01
# Theta | test2 -> R² = 0.8694, MSE = 3.0767e-02
# X | test2 -> R² = -0.0538, MSE = 8.6514e-02
# Y | test2 -> R² = -1.3277, MSE = 2.4575e-01
# Theta | test3 -> R² = -5.5401, MSE = 2.1555e+00
# X | test3 -> R² = -1.7502, MSE = 2.5162e-01
# Y | test3 -> R² = -3.8304, MSE = 3.6972e-01
# Theta | val -> R² = -0.7744, MSE = 5.8222e-01
# X | val -> R² = -0.6896, MSE = 1.6058e-01
# Y | val -> R² = -4.1840, MSE = 3.8473e-01
# Figura salva em: ./results/model_128_64_32_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.588858 | Val Loss 0.787856
# Epoch 100 | Train Loss 1.166849 | Val Loss 0.640874
# Epoch 200 | Train Loss 1.066013 | Val Loss 0.638956
# Epoch 300 | Train Loss 0.962246 | Val Loss 0.659935
# Epoch 400 | Train Loss 0.875760 | Val Loss 0.729309
# Epoch 500 | Train Loss 0.816003 | Val Loss 0.749320
# Epoch 600 | Train Loss 0.783540 | Val Loss 0.797886
# Early stopping at epoch 640
# Theta | train1 -> R² = 0.6584, MSE = 7.8286e-02
# X | train1 -> R² = -0.2274, MSE = 1.3156e-01
# Y | train1 -> R² = -0.2253, MSE = 1.0241e-01
# Theta | train2 -> R² = 0.4934, MSE = 1.1487e-01
# X | train2 -> R² = 0.0452, MSE = 8.0254e-02
# Y | train2 -> R² = -1.2579, MSE = 2.4176e-01
# Theta | test1 -> R² = 0.6184, MSE = 8.8013e-02
# X | test1 -> R² = -0.0024, MSE = 1.0434e-01
# Y | test1 -> R² = -1.4704, MSE = 2.0178e-01
# Theta | test2 -> R² = 0.8316, MSE = 3.9666e-02
# X | test2 -> R² = -0.0904, MSE = 8.9516e-02
# Y | test2 -> R² = -1.1672, MSE = 2.2880e-01
# Theta | test3 -> R² = -2.8952, MSE = 1.2838e+00
# X | test3 -> R² = -2.2557, MSE = 2.9787e-01
# Y | test3 -> R² = -3.8199, MSE = 3.6892e-01
# Theta | val -> R² = -1.2361, MSE = 7.3368e-01
# X | val -> R² = -1.0960, MSE = 1.9920e-01
# Y | val -> R² = -4.2161, MSE = 3.8712e-01
# Figura salva em: ./results/model_128_64_32_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.589286 | Val Loss 0.796109
# Epoch 100 | Train Loss 1.177072 | Val Loss 0.635144
# Epoch 200 | Train Loss 1.072838 | Val Loss 0.626611
# Epoch 300 | Train Loss 0.961034 | Val Loss 0.669732
# Epoch 400 | Train Loss 0.872649 | Val Loss 0.730879
# Epoch 500 | Train Loss 0.807967 | Val Loss 0.770588
# Epoch 600 | Train Loss 0.771607 | Val Loss 0.803154
# Early stopping at epoch 666
# Theta | train1 -> R² = 0.0864, MSE = 2.0941e-01
# X | train1 -> R² = -0.1639, MSE = 1.2474e-01
# Y | train1 -> R² = -0.2074, MSE = 1.0091e-01
# Theta | train2 -> R² = 0.7108, MSE = 6.5573e-02
# X | train2 -> R² = -0.0256, MSE = 8.6203e-02
# Y | train2 -> R² = -1.3599, MSE = 2.5268e-01
# Theta | test1 -> R² = 0.7028, MSE = 6.8555e-02
# X | test1 -> R² = -0.0766, MSE = 1.1207e-01
# Y | test1 -> R² = -1.7164, MSE = 2.2187e-01
# Theta | test2 -> R² = 0.6294, MSE = 8.7307e-02
# X | test2 -> R² = -0.1418, MSE = 9.3731e-02
# Y | test2 -> R² = -1.1503, MSE = 2.2702e-01
# Theta | test3 -> R² = -2.1184, MSE = 1.0278e+00
# X | test3 -> R² = -2.1473, MSE = 2.8795e-01
# Y | test3 -> R² = -2.3459, MSE = 2.5610e-01
# Theta | val -> R² = -4.4385, MSE = 1.7845e+00
# X | val -> R² = -0.8981, MSE = 1.8039e-01
# Y | val -> R² = -3.4138, MSE = 3.2758e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.593359 | Val Loss 0.840585
# Epoch 100 | Train Loss 1.113124 | Val Loss 0.617797
# Epoch 200 | Train Loss 0.942313 | Val Loss 0.632720
# Epoch 300 | Train Loss 0.799400 | Val Loss 0.711702
# Epoch 400 | Train Loss 0.708114 | Val Loss 0.734198
# Epoch 500 | Train Loss 0.676093 | Val Loss 0.791483
# Epoch 600 | Train Loss 0.671711 | Val Loss 0.867451
# Early stopping at epoch 640
# Theta | train1 -> R² = 0.3585, MSE = 1.4704e-01
# X | train1 -> R² = -0.1865, MSE = 1.2717e-01
# Y | train1 -> R² = 0.0279, MSE = 8.1250e-02
# Theta | train2 -> R² = 0.7511, MSE = 5.6440e-02
# X | train2 -> R² = 0.1389, MSE = 7.2379e-02
# Y | train2 -> R² = -1.2931, MSE = 2.4553e-01
# Theta | test1 -> R² = 0.5607, MSE = 1.0133e-01
# X | test1 -> R² = 0.1397, MSE = 8.9552e-02
# Y | test1 -> R² = -1.6620, MSE = 2.1743e-01
# Theta | test2 -> R² = 0.7227, MSE = 6.5336e-02
# X | test2 -> R² = -0.0107, MSE = 8.2972e-02
# Y | test2 -> R² = -1.5163, MSE = 2.6566e-01
# Theta | test3 -> R² = -0.2368, MSE = 4.0762e-01
# X | test3 -> R² = -0.9723, MSE = 1.8045e-01
# Y | test3 -> R² = -3.9665, MSE = 3.8013e-01
# Theta | val -> R² = -4.5151, MSE = 1.8096e+00
# X | val -> R² = -1.1532, MSE = 2.0464e-01
# Y | val -> R² = -4.4195, MSE = 4.0221e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.583179 | Val Loss 0.764075
# Epoch 100 | Train Loss 1.101838 | Val Loss 0.613869
# Epoch 200 | Train Loss 0.914737 | Val Loss 0.673196
# Epoch 300 | Train Loss 0.781375 | Val Loss 0.730128
# Epoch 400 | Train Loss 0.732243 | Val Loss 0.749120
# Epoch 500 | Train Loss 0.684834 | Val Loss 0.815445
# Epoch 600 | Train Loss 0.664587 | Val Loss 0.849341
# Early stopping at epoch 617
# Theta | train1 -> R² = 0.1724, MSE = 1.8969e-01
# X | train1 -> R² = -0.2503, MSE = 1.3401e-01
# Y | train1 -> R² = -0.1085, MSE = 9.2645e-02
# Theta | train2 -> R² = 0.6088, MSE = 8.8701e-02
# X | train2 -> R² = 0.1068, MSE = 7.5076e-02
# Y | train2 -> R² = -1.5285, MSE = 2.7074e-01
# Theta | test1 -> R² = 0.4216, MSE = 1.3341e-01
# X | test1 -> R² = 0.1322, MSE = 9.0334e-02
# Y | test1 -> R² = -1.7657, MSE = 2.2590e-01
# Theta | test2 -> R² = 0.5365, MSE = 1.0919e-01
# X | test2 -> R² = -0.0256, MSE = 8.4195e-02
# Y | test2 -> R² = -1.6089, MSE = 2.7543e-01
# Theta | test3 -> R² = 0.4472, MSE = 1.8218e-01
# X | test3 -> R² = -1.2449, MSE = 2.0539e-01
# Y | test3 -> R² = -4.6895, MSE = 4.3547e-01
# Theta | val -> R² = -1.5441, MSE = 8.3477e-01
# X | val -> R² = -0.6011, MSE = 1.5217e-01
# Y | val -> R² = -4.8075, MSE = 4.3101e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.648121 | Val Loss 0.780807
# Epoch 100 | Train Loss 1.118877 | Val Loss 0.629687
# Epoch 200 | Train Loss 0.940561 | Val Loss 0.639761
# Epoch 300 | Train Loss 0.808966 | Val Loss 0.684967
# Epoch 400 | Train Loss 0.714965 | Val Loss 0.724409
# Epoch 500 | Train Loss 0.686573 | Val Loss 0.774704
# Epoch 600 | Train Loss 0.664391 | Val Loss 0.776901
# Epoch 700 | Train Loss 0.656627 | Val Loss 0.773456
# Early stopping at epoch 717
# Theta | train1 -> R² = 0.7668, MSE = 5.3448e-02
# X | train1 -> R² = 0.6130, MSE = 4.1483e-02
# Y | train1 -> R² = -0.5537, MSE = 1.2986e-01
# Theta | train2 -> R² = 0.3538, MSE = 1.4652e-01
# X | train2 -> R² = 0.2872, MSE = 5.9909e-02
# Y | train2 -> R² = -2.1977, MSE = 3.4239e-01
# Theta | test1 -> R² = -0.4736, MSE = 3.3990e-01
# X | test1 -> R² = 0.6841, MSE = 3.2886e-02
# Y | test1 -> R² = -3.1873, MSE = 3.4202e-01
# Theta | test2 -> R² = 0.6468, MSE = 8.3200e-02
# X | test2 -> R² = -0.2513, MSE = 1.0273e-01
# Y | test2 -> R² = -3.1676, MSE = 4.4000e-01
# Theta | test3 -> R² = 0.3952, MSE = 1.9935e-01
# X | test3 -> R² = -0.9813, MSE = 1.8127e-01
# Y | test3 -> R² = -4.3150, MSE = 4.0681e-01
# Theta | val -> R² = -0.1426, MSE = 3.7491e-01
# X | val -> R² = 0.4205, MSE = 5.5072e-02
# Y | val -> R² = -5.0176, MSE = 4.4660e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.595749 | Val Loss 0.831263
# Epoch 100 | Train Loss 1.106275 | Val Loss 0.621185
# Epoch 200 | Train Loss 0.935383 | Val Loss 0.639228
# Epoch 300 | Train Loss 0.771325 | Val Loss 0.740409
# Epoch 400 | Train Loss 0.729026 | Val Loss 0.802373
# Epoch 500 | Train Loss 0.680094 | Val Loss 0.814666
# Early stopping at epoch 599
# Theta | train1 -> R² = 0.7200, MSE = 6.4181e-02
# X | train1 -> R² = -0.1846, MSE = 1.2697e-01
# Y | train1 -> R² = -0.2979, MSE = 1.0848e-01
# Theta | train2 -> R² = 0.6405, MSE = 8.1520e-02
# X | train2 -> R² = 0.1001, MSE = 7.5634e-02
# Y | train2 -> R² = -1.1829, MSE = 2.3372e-01
# Theta | test1 -> R² = 0.5069, MSE = 1.1373e-01
# X | test1 -> R² = 0.1545, MSE = 8.8018e-02
# Y | test1 -> R² = -1.7559, MSE = 2.2510e-01
# Theta | test2 -> R² = 0.7904, MSE = 4.9369e-02
# X | test2 -> R² = -0.0043, MSE = 8.2447e-02
# Y | test2 -> R² = -1.2628, MSE = 2.3890e-01
# Theta | test3 -> R² = -1.9024, MSE = 9.5659e-01
# X | test3 -> R² = -0.9740, MSE = 1.8061e-01
# Y | test3 -> R² = -4.1193, MSE = 3.9183e-01
# Theta | val -> R² = -4.6646, MSE = 1.8586e+00
# X | val -> R² = -0.3021, MSE = 1.2376e-01
# Y | val -> R² = -4.7708, MSE = 4.2829e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.549846 | Val Loss 0.789007
# Epoch 100 | Train Loss 1.096089 | Val Loss 0.615646
# Epoch 200 | Train Loss 0.901356 | Val Loss 0.661646
# Epoch 300 | Train Loss 0.817657 | Val Loss 0.735082
# Epoch 400 | Train Loss 0.724113 | Val Loss 0.770895
# Epoch 500 | Train Loss 0.689210 | Val Loss 0.806403
# Epoch 600 | Train Loss 0.667401 | Val Loss 0.839688
# Early stopping at epoch 616
# Theta | train1 -> R² = 0.2882, MSE = 1.6315e-01
# X | train1 -> R² = -0.2798, MSE = 1.3717e-01
# Y | train1 -> R² = 0.1471, MSE = 7.1282e-02
# Theta | train2 -> R² = 0.7632, MSE = 5.3694e-02
# X | train2 -> R² = 0.0770, MSE = 7.7582e-02
# Y | train2 -> R² = -1.3309, MSE = 2.4957e-01
# Theta | test1 -> R² = 0.6040, MSE = 9.1353e-02
# X | test1 -> R² = 0.0775, MSE = 9.6028e-02
# Y | test1 -> R² = -1.4193, MSE = 1.9761e-01
# Theta | test2 -> R² = 0.4860, MSE = 1.2109e-01
# X | test2 -> R² = -0.0037, MSE = 8.2399e-02
# Y | test2 -> R² = -1.3311, MSE = 2.4610e-01
# Theta | test3 -> R² = -1.7637, MSE = 9.1087e-01
# X | test3 -> R² = -2.3397, MSE = 3.0556e-01
# Y | test3 -> R² = -3.9760, MSE = 3.8086e-01
# Theta | val -> R² = -4.5686, MSE = 1.8272e+00
# X | val -> R² = -1.4416, MSE = 2.3206e-01
# Y | val -> R² = -3.6636, MSE = 3.4611e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.601841 | Val Loss 0.785478
# Epoch 100 | Train Loss 1.096484 | Val Loss 0.612036
# Epoch 200 | Train Loss 0.890359 | Val Loss 0.656342
# Epoch 300 | Train Loss 0.769230 | Val Loss 0.697420
# Epoch 400 | Train Loss 0.709331 | Val Loss 0.753135
# Epoch 500 | Train Loss 0.682185 | Val Loss 0.757699
# Epoch 600 | Train Loss 0.677916 | Val Loss 0.845934
# Early stopping at epoch 610
# Theta | train1 -> R² = 0.7353, MSE = 6.0666e-02
# X | train1 -> R² = -0.1051, MSE = 1.1844e-01
# Y | train1 -> R² = -0.1117, MSE = 9.2915e-02
# Theta | train2 -> R² = 0.6722, MSE = 7.4319e-02
# X | train2 -> R² = 0.1632, MSE = 7.0331e-02
# Y | train2 -> R² = -1.4324, MSE = 2.6044e-01
# Theta | test1 -> R² = 0.3604, MSE = 1.4754e-01
# X | test1 -> R² = 0.2522, MSE = 7.7845e-02
# Y | test1 -> R² = -1.7560, MSE = 2.2511e-01
# Theta | test2 -> R² = 0.7065, MSE = 6.9150e-02
# X | test2 -> R² = -0.0252, MSE = 8.4159e-02
# Y | test2 -> R² = -1.4363, MSE = 2.5722e-01
# Theta | test3 -> R² = 0.1532, MSE = 2.7910e-01
# X | test3 -> R² = -1.3078, MSE = 2.1115e-01
# Y | test3 -> R² = -4.2408, MSE = 4.0113e-01
# Theta | val -> R² = -2.7223, MSE = 1.2213e+00
# X | val -> R² = -0.1970, MSE = 1.1376e-01
# Y | val -> R² = -4.8939, MSE = 4.3742e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.552770 | Val Loss 0.867515
# Epoch 100 | Train Loss 1.111076 | Val Loss 0.619532
# Epoch 200 | Train Loss 0.942280 | Val Loss 0.662707
# Epoch 300 | Train Loss 0.790623 | Val Loss 0.710430
# Epoch 400 | Train Loss 0.718473 | Val Loss 0.763576
# Epoch 500 | Train Loss 0.701658 | Val Loss 0.769312
# Epoch 600 | Train Loss 0.666025 | Val Loss 0.809501
# Early stopping at epoch 695
# Theta | train1 -> R² = 0.9760, MSE = 5.5098e-03
# X | train1 -> R² = 0.4037, MSE = 6.3912e-02
# Y | train1 -> R² = -0.7470, MSE = 1.4601e-01
# Theta | train2 -> R² = 0.1546, MSE = 1.9168e-01
# X | train2 -> R² = 0.2424, MSE = 6.3672e-02
# Y | train2 -> R² = -2.8324, MSE = 4.1034e-01
# Theta | test1 -> R² = -0.2628, MSE = 2.9128e-01
# X | test1 -> R² = 0.5754, MSE = 4.4199e-02
# Y | test1 -> R² = -3.6821, MSE = 3.8243e-01
# Theta | test2 -> R² = 0.7034, MSE = 6.9884e-02
# X | test2 -> R² = -0.1065, MSE = 9.0834e-02
# Y | test2 -> R² = -3.7158, MSE = 4.9787e-01
# Theta | test3 -> R² = -1.2768, MSE = 7.5040e-01
# X | test3 -> R² = -0.8007, MSE = 1.6475e-01
# Y | test3 -> R² = -6.0875, MSE = 5.4248e-01
# Theta | val -> R² = 0.5496, MSE = 1.4778e-01
# X | val -> R² = -0.7196, MSE = 1.6344e-01
# Y | val -> R² = -6.5315, MSE = 5.5896e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.579534 | Val Loss 0.709706
# Epoch 100 | Train Loss 1.109141 | Val Loss 0.621354
# Epoch 200 | Train Loss 0.936364 | Val Loss 0.655498
# Epoch 300 | Train Loss 0.801651 | Val Loss 0.708950
# Epoch 400 | Train Loss 0.736740 | Val Loss 0.725175
# Epoch 500 | Train Loss 0.687526 | Val Loss 0.775724
# Epoch 600 | Train Loss 0.670112 | Val Loss 0.794177
# Early stopping at epoch 630
# Theta | train1 -> R² = 0.8669, MSE = 3.0509e-02
# X | train1 -> R² = -0.3091, MSE = 1.4031e-01
# Y | train1 -> R² = 0.0754, MSE = 7.7274e-02
# Theta | train2 -> R² = 0.7239, MSE = 6.2594e-02
# X | train2 -> R² = 0.1877, MSE = 6.8278e-02
# Y | train2 -> R² = -1.4675, MSE = 2.6420e-01
# Theta | test1 -> R² = 0.5125, MSE = 1.1244e-01
# X | test1 -> R² = 0.0845, MSE = 9.5298e-02
# Y | test1 -> R² = -1.6433, MSE = 2.1591e-01
# Theta | test2 -> R² = 0.8052, MSE = 4.5899e-02
# X | test2 -> R² = 0.0363, MSE = 7.9111e-02
# Y | test2 -> R² = -1.4332, MSE = 2.5689e-01
# Theta | test3 -> R² = 0.1150, MSE = 2.9167e-01
# X | test3 -> R² = -1.0435, MSE = 1.8697e-01
# Y | test3 -> R² = -3.4465, MSE = 3.4033e-01
# Theta | val -> R² = -0.0166, MSE = 3.3358e-01
# X | val -> R² = -0.4534, MSE = 1.3813e-01
# Y | val -> R² = -4.0679, MSE = 3.7612e-01
# Figura salva em: ./results/model_264_128_64_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.675675 | Val Loss 0.818475
# Epoch 100 | Train Loss 1.104052 | Val Loss 0.619836
# Epoch 200 | Train Loss 0.927096 | Val Loss 0.618131
# Epoch 300 | Train Loss 0.785813 | Val Loss 0.675640
# Epoch 400 | Train Loss 0.731405 | Val Loss 0.716315
# Epoch 500 | Train Loss 0.685871 | Val Loss 0.775154
# Epoch 600 | Train Loss 0.676644 | Val Loss 0.819838
# Early stopping at epoch 658
# Theta | train1 -> R² = 0.9183, MSE = 1.8715e-02
# X | train1 -> R² = 0.3183, MSE = 7.3060e-02
# Y | train1 -> R² = -0.0799, MSE = 9.0256e-02
# Theta | train2 -> R² = 0.7319, MSE = 6.0794e-02
# X | train2 -> R² = 0.2575, MSE = 6.2408e-02
# Y | train2 -> R² = -2.1482, MSE = 3.3708e-01
# Theta | test1 -> R² = 0.0548, MSE = 2.1802e-01
# X | test1 -> R² = 0.4805, MSE = 5.4081e-02
# Y | test1 -> R² = -2.1259, MSE = 2.5533e-01
# Theta | test2 -> R² = 0.7552, MSE = 5.7672e-02
# X | test2 -> R² = -0.0497, MSE = 8.6174e-02
# Y | test2 -> R² = -2.3966, MSE = 3.5859e-01
# Theta | test3 -> R² = -4.5134, MSE = 1.8171e+00
# X | test3 -> R² = -1.3806, MSE = 2.1780e-01
# Y | test3 -> R² = -3.8687, MSE = 3.7265e-01
# Theta | val -> R² = -4.7576, MSE = 1.8891e+00
# X | val -> R² = -0.5132, MSE = 1.4382e-01
# Y | val -> R² = -4.6923, MSE = 4.2246e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.605729 | Val Loss 0.823297
# Epoch 100 | Train Loss 1.111248 | Val Loss 0.639435
# Epoch 200 | Train Loss 0.949422 | Val Loss 0.648962
# Epoch 300 | Train Loss 0.827944 | Val Loss 0.724155
# Epoch 400 | Train Loss 0.751635 | Val Loss 0.821759
# Epoch 500 | Train Loss 0.701482 | Val Loss 0.824444
# Epoch 600 | Train Loss 0.678227 | Val Loss 0.863870
# Early stopping at epoch 604
# Theta | train1 -> R² = 0.6748, MSE = 7.4532e-02
# X | train1 -> R² = -0.1286, MSE = 1.2097e-01
# Y | train1 -> R² = -0.1175, MSE = 9.3404e-02
# Theta | train2 -> R² = 0.5621, MSE = 9.9281e-02
# X | train2 -> R² = 0.1034, MSE = 7.5358e-02
# Y | train2 -> R² = -1.3401, MSE = 2.5056e-01
# Theta | test1 -> R² = 0.4801, MSE = 1.1992e-01
# X | test1 -> R² = 0.1041, MSE = 9.3265e-02
# Y | test1 -> R² = -1.7123, MSE = 2.2154e-01
# Theta | test2 -> R² = 0.7652, MSE = 5.5317e-02
# X | test2 -> R² = -0.0083, MSE = 8.2778e-02
# Y | test2 -> R² = -1.3953, MSE = 2.5288e-01
# Theta | test3 -> R² = -1.7698, MSE = 9.1287e-01
# X | test3 -> R² = -1.4370, MSE = 2.2297e-01
# Y | test3 -> R² = -5.1716, MSE = 4.7237e-01
# Theta | val -> R² = -2.8040, MSE = 1.2482e+00
# X | val -> R² = -0.6378, MSE = 1.5566e-01
# Y | val -> R² = -4.9276, MSE = 4.3992e-01
# Modelo 9 treinado e salvo no Excel
