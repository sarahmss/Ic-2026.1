# %% [markdown]
# - Entradas: SWdRef, SWeRef
# - Saidas: X
# - Trajetorias: ZZ

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
PREDICTORS = ["sWdRef", "sWeRef"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = Train1

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada fisica : (973,)
# Dimensão da entrada fisica: (973,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 10
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test")
        )

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva.")

        plt.close(fig)

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 0.644128 | Val Loss 0.618338
# Epoch 100 | Train Loss 0.316650 | Val Loss 0.394166
# Epoch 200 | Train Loss 0.314477 | Val Loss 0.394983
# Epoch 300 | Train Loss 0.313247 | Val Loss 0.395456
# Early stopping at epoch 347
# X | train1 -> R² = 0.9612, MSE = 4.1828e-03
# X | train2 -> R² = -1.4325, MSE = 2.0496e-01
# X | test1 -> R² = 0.9241, MSE = 7.9509e-03
# X | test2 -> R² = -1.4643, MSE = 2.0280e-01
# X | test3 -> R² = 0.8859, MSE = 1.0500e-02
# X | val -> R² = 0.8699, MSE = 1.2440e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.675528 | Val Loss 0.643777
# Epoch 100 | Train Loss 0.315986 | Val Loss 0.394697
# Epoch 200 | Train Loss 0.313741 | Val Loss 0.395061
# Epoch 300 | Train Loss 0.312294 | Val Loss 0.395359
# Early stopping at epoch 353
# X | train1 -> R² = 0.9638, MSE = 3.9020e-03
# X | train2 -> R² = -1.4043, MSE = 2.0258e-01
# X | test1 -> R² = 0.9276, MSE = 7.5814e-03
# X | test2 -> R² = -1.4346, MSE = 2.0036e-01
# X | test3 -> R² = 0.8976, MSE = 9.4249e-03
# X | val -> R² = 0.8881, MSE = 1.0696e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.732391 | Val Loss 0.690181
# Epoch 100 | Train Loss 0.316411 | Val Loss 0.394327
# Epoch 200 | Train Loss 0.314431 | Val Loss 0.394953
# Epoch 300 | Train Loss 0.313389 | Val Loss 0.395505
# Early stopping at epoch 353
# X | train1 -> R² = 0.9645, MSE = 3.8310e-03
# X | train2 -> R² = -1.4169, MSE = 2.0365e-01
# X | test1 -> R² = 0.9287, MSE = 7.4699e-03
# X | test2 -> R² = -1.4481, MSE = 2.0146e-01
# X | test3 -> R² = 0.8914, MSE = 9.9960e-03
# X | val -> R² = 0.8787, MSE = 1.1595e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.710858 | Val Loss 0.672877
# Epoch 100 | Train Loss 0.317367 | Val Loss 0.394024
# Epoch 200 | Train Loss 0.315087 | Val Loss 0.394516
# Epoch 300 | Train Loss 0.313978 | Val Loss 0.395228
# Early stopping at epoch 351
# X | train1 -> R² = 0.9588, MSE = 4.4454e-03
# X | train2 -> R² = -1.4228, MSE = 2.0414e-01
# X | test1 -> R² = 0.9185, MSE = 8.5375e-03
# X | test2 -> R² = -1.4525, MSE = 2.0183e-01
# X | test3 -> R² = 0.8849, MSE = 1.0593e-02
# X | val -> R² = 0.8680, MSE = 1.2622e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.682847 | Val Loss 0.650578
# Epoch 100 | Train Loss 0.316390 | Val Loss 0.394794
# Epoch 200 | Train Loss 0.314355 | Val Loss 0.395122
# Epoch 300 | Train Loss 0.313138 | Val Loss 0.395533
# Early stopping at epoch 351
# X | train1 -> R² = 0.9591, MSE = 4.4132e-03
# X | train2 -> R² = -1.3756, MSE = 2.0017e-01
# X | test1 -> R² = 0.9183, MSE = 8.5603e-03
# X | test2 -> R² = -1.4053, MSE = 1.9794e-01
# X | test3 -> R² = 0.8876, MSE = 1.0338e-02
# X | val -> R² = 0.8750, MSE = 1.1954e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.710885 | Val Loss 0.671897
# Epoch 100 | Train Loss 0.316768 | Val Loss 0.394037
# Epoch 200 | Train Loss 0.314583 | Val Loss 0.394427
# Epoch 300 | Train Loss 0.313335 | Val Loss 0.395018
# Early stopping at epoch 356
# X | train1 -> R² = 0.9536, MSE = 5.0063e-03
# X | train2 -> R² = -1.3238, MSE = 1.9580e-01
# X | test1 -> R² = 0.9127, MSE = 9.1416e-03
# X | test2 -> R² = -1.3585, MSE = 1.9409e-01
# X | test3 -> R² = 0.8701, MSE = 1.1950e-02
# X | val -> R² = 0.8568, MSE = 1.3693e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.716201 | Val Loss 0.676370
# Epoch 100 | Train Loss 0.315611 | Val Loss 0.394129
# Epoch 200 | Train Loss 0.313434 | Val Loss 0.394691
# Epoch 300 | Train Loss 0.312020 | Val Loss 0.395400
# Early stopping at epoch 357
# X | train1 -> R² = 0.9645, MSE = 3.8254e-03
# X | train2 -> R² = -1.4137, MSE = 2.0338e-01
# X | test1 -> R² = 0.9312, MSE = 7.2127e-03
# X | test2 -> R² = -1.4488, MSE = 2.0152e-01
# X | test3 -> R² = 0.8870, MSE = 1.0397e-02
# X | val -> R² = 0.8750, MSE = 1.1957e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.699468 | Val Loss 0.661467
# Epoch 100 | Train Loss 0.319230 | Val Loss 0.394159
# Epoch 200 | Train Loss 0.315190 | Val Loss 0.394129
# Epoch 300 | Train Loss 0.313032 | Val Loss 0.394873
# Early stopping at epoch 360
# X | train1 -> R² = 0.9348, MSE = 7.0294e-03
# X | train2 -> R² = -1.3353, MSE = 1.9678e-01
# X | test1 -> R² = 0.8778, MSE = 1.2805e-02
# X | test2 -> R² = -1.3612, MSE = 1.9431e-01
# X | test3 -> R² = 0.8218, MSE = 1.6397e-02
# X | val -> R² = 0.7862, MSE = 2.0441e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.751218 | Val Loss 0.706668
# Epoch 100 | Train Loss 0.318602 | Val Loss 0.393109
# Epoch 200 | Train Loss 0.315312 | Val Loss 0.394166
# Epoch 300 | Train Loss 0.314058 | Val Loss 0.395515
# Early stopping at epoch 355
# X | train1 -> R² = 0.9526, MSE = 5.1134e-03
# X | train2 -> R² = -1.4416, MSE = 2.0573e-01
# X | test1 -> R² = 0.9112, MSE = 9.3029e-03
# X | test2 -> R² = -1.4756, MSE = 2.0373e-01
# X | test3 -> R² = 0.8590, MSE = 1.2974e-02
# X | val -> R² = 0.8318, MSE = 1.6087e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.679010 | Val Loss 0.648651
# Epoch 100 | Train Loss 0.317057 | Val Loss 0.394018
# Epoch 200 | Train Loss 0.314538 | Val Loss 0.394786
# Epoch 300 | Train Loss 0.313406 | Val Loss 0.395331
# Early stopping at epoch 356
# X | train1 -> R² = 0.9515, MSE = 5.2251e-03
# X | train2 -> R² = -1.3549, MSE = 1.9842e-01
# X | test1 -> R² = 0.9054, MSE = 9.9090e-03
# X | test2 -> R² = -1.3833, MSE = 1.9613e-01
# X | test3 -> R² = 0.8416, MSE = 1.4571e-02
# X | val -> R² = 0.8170, MSE = 1.7500e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.696239 | Val Loss 0.660214
# Epoch 100 | Train Loss 0.316827 | Val Loss 0.394170
# Epoch 200 | Train Loss 0.314196 | Val Loss 0.394743
# Epoch 300 | Train Loss 0.312849 | Val Loss 0.395210
# Early stopping at epoch 355
# X | train1 -> R² = 0.9604, MSE = 4.2709e-03
# X | train2 -> R² = -1.4223, MSE = 2.0411e-01
# X | test1 -> R² = 0.9223, MSE = 8.1351e-03
# X | test2 -> R² = -1.4533, MSE = 2.0189e-01
# X | test3 -> R² = 0.8856, MSE = 1.0522e-02
# X | val -> R² = 0.8704, MSE = 1.2391e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.650454 | Val Loss 0.624563
# Epoch 100 | Train Loss 0.316311 | Val Loss 0.394750
# Epoch 200 | Train Loss 0.314026 | Val Loss 0.394918
# Epoch 300 | Train Loss 0.312851 | Val Loss 0.395206
# Early stopping at epoch 353
# X | train1 -> R² = 0.9620, MSE = 4.1027e-03
# X | train2 -> R² = -1.3979, MSE = 2.0205e-01
# X | test1 -> R² = 0.9212, MSE = 8.2550e-03
# X | test2 -> R² = -1.4234, MSE = 1.9943e-01
# X | test3 -> R² = 0.8737, MSE = 1.1620e-02
# X | val -> R² = 0.8562, MSE = 1.3753e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.727110 | Val Loss 0.685317
# Epoch 100 | Train Loss 0.317179 | Val Loss 0.394775
# Epoch 200 | Train Loss 0.315192 | Val Loss 0.395219
# Epoch 300 | Train Loss 0.314146 | Val Loss 0.395606
# Early stopping at epoch 353
# X | train1 -> R² = 0.9629, MSE = 3.9954e-03
# X | train2 -> R² = -1.4277, MSE = 2.0456e-01
# X | test1 -> R² = 0.9240, MSE = 7.9597e-03
# X | test2 -> R² = -1.4548, MSE = 2.0202e-01
# X | test3 -> R² = 0.8933, MSE = 9.8162e-03
# X | val -> R² = 0.8793, MSE = 1.1543e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.755720 | Val Loss 0.707609
# Epoch 100 | Train Loss 0.317317 | Val Loss 0.394733
# Epoch 200 | Train Loss 0.315281 | Val Loss 0.394966
# Epoch 300 | Train Loss 0.314301 | Val Loss 0.395394
# Early stopping at epoch 358
# X | train1 -> R² = 0.9492, MSE = 5.4725e-03
# X | train2 -> R² = -1.2903, MSE = 1.9298e-01
# X | test1 -> R² = 0.9026, MSE = 1.0200e-02
# X | test2 -> R² = -1.3203, MSE = 1.9094e-01
# X | test3 -> R² = 0.8570, MSE = 1.3161e-02
# X | val -> R² = 0.8412, MSE = 1.5184e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.702201 | Val Loss 0.665122
# Epoch 100 | Train Loss 0.317474 | Val Loss 0.394012
# Epoch 200 | Train Loss 0.314960 | Val Loss 0.394536
# Epoch 300 | Train Loss 0.313521 | Val Loss 0.395214
# Early stopping at epoch 356
# X | train1 -> R² = 0.9438, MSE = 6.0623e-03
# X | train2 -> R² = -1.3031, MSE = 1.9406e-01
# X | test1 -> R² = 0.8999, MSE = 1.0489e-02
# X | test2 -> R² = -1.3405, MSE = 1.9261e-01
# X | test3 -> R² = 0.8693, MSE = 1.2028e-02
# X | val -> R² = 0.8555, MSE = 1.3815e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.698491 | Val Loss 0.663922
# Epoch 100 | Train Loss 0.315537 | Val Loss 0.394604
# Epoch 200 | Train Loss 0.313699 | Val Loss 0.395115
# Epoch 300 | Train Loss 0.312539 | Val Loss 0.395491
# Early stopping at epoch 355
# X | train1 -> R² = 0.9617, MSE = 4.1269e-03
# X | train2 -> R² = -1.3379, MSE = 1.9699e-01
# X | test1 -> R² = 0.9254, MSE = 7.8161e-03
# X | test2 -> R² = -1.3725, MSE = 1.9524e-01
# X | test3 -> R² = 0.8801, MSE = 1.1029e-02
# X | val -> R² = 0.8714, MSE = 1.2296e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.631457 | Val Loss 0.609441
# Epoch 100 | Train Loss 0.316043 | Val Loss 0.396116
# Epoch 200 | Train Loss 0.314317 | Val Loss 0.395675
# Epoch 300 | Train Loss 0.313114 | Val Loss 0.395734
# Early stopping at epoch 350
# X | train1 -> R² = 0.9542, MSE = 4.9397e-03
# X | train2 -> R² = -1.2601, MSE = 1.9043e-01
# X | test1 -> R² = 0.9107, MSE = 9.3591e-03
# X | test2 -> R² = -1.2904, MSE = 1.8849e-01
# X | test3 -> R² = 0.8860, MSE = 1.0490e-02
# X | val -> R² = 0.8819, MSE = 1.1298e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.589938 | Val Loss 0.575753
# Epoch 100 | Train Loss 0.317504 | Val Loss 0.394786
# Epoch 200 | Train Loss 0.314689 | Val Loss 0.394976
# Epoch 300 | Train Loss 0.313088 | Val Loss 0.395572
# Early stopping at epoch 345
# X | train1 -> R² = 0.9571, MSE = 4.6254e-03
# X | train2 -> R² = -1.4113, MSE = 2.0317e-01
# X | test1 -> R² = 0.9153, MSE = 8.8684e-03
# X | test2 -> R² = -1.4399, MSE = 2.0079e-01
# X | test3 -> R² = 0.8947, MSE = 9.6892e-03
# X | val -> R² = 0.8836, MSE = 1.1126e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.730613 | Val Loss 0.689573
# Epoch 100 | Train Loss 0.318837 | Val Loss 0.393535
# Epoch 200 | Train Loss 0.315298 | Val Loss 0.394033
# Epoch 300 | Train Loss 0.313644 | Val Loss 0.395263
# Early stopping at epoch 360
# X | train1 -> R² = 0.9325, MSE = 7.2822e-03
# X | train2 -> R² = -1.2998, MSE = 1.9378e-01
# X | test1 -> R² = 0.8792, MSE = 1.2652e-02
# X | test2 -> R² = -1.3316, MSE = 1.9188e-01
# X | test3 -> R² = 0.8072, MSE = 1.7740e-02
# X | val -> R² = 0.7734, MSE = 2.1673e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.726451 | Val Loss 0.686299
# Epoch 100 | Train Loss 0.317947 | Val Loss 0.393365
# Epoch 200 | Train Loss 0.314978 | Val Loss 0.393965
# Epoch 300 | Train Loss 0.313694 | Val Loss 0.394841
# Early stopping at epoch 354
# X | train1 -> R² = 0.9544, MSE = 4.9203e-03
# X | train2 -> R² = -1.4230, MSE = 2.0416e-01
# X | test1 -> R² = 0.9110, MSE = 9.3205e-03
# X | test2 -> R² = -1.4522, MSE = 2.0180e-01
# X | test3 -> R² = 0.8568, MSE = 1.3177e-02
# X | val -> R² = 0.8300, MSE = 1.6256e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.723213 | Val Loss 0.679635
# Epoch 100 | Train Loss 0.316363 | Val Loss 0.394762
# Epoch 200 | Train Loss 0.314119 | Val Loss 0.395141
# Epoch 300 | Train Loss 0.312867 | Val Loss 0.395646
# Early stopping at epoch 354
# X | train1 -> R² = 0.9510, MSE = 5.2800e-03
# X | train2 -> R² = -1.2980, MSE = 1.9363e-01
# X | test1 -> R² = 0.9098, MSE = 9.4482e-03
# X | test2 -> R² = -1.3337, MSE = 1.9205e-01
# X | test3 -> R² = 0.8875, MSE = 1.0351e-02
# X | val -> R² = 0.8817, MSE = 1.1313e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.652947 | Val Loss 0.625248
# Epoch 100 | Train Loss 0.316809 | Val Loss 0.395697
# Epoch 200 | Train Loss 0.315037 | Val Loss 0.395894
# Epoch 300 | Train Loss 0.314079 | Val Loss 0.395940
# Early stopping at epoch 360
# X | train1 -> R² = 0.9506, MSE = 5.3295e-03
# X | train2 -> R² = -1.2438, MSE = 1.8906e-01
# X | test1 -> R² = 0.9041, MSE = 1.0048e-02
# X | test2 -> R² = -1.2729, MSE = 1.8704e-01
# X | test3 -> R² = 0.8370, MSE = 1.4996e-02
# X | val -> R² = 0.8261, MSE = 1.6631e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.721468 | Val Loss 0.682474
# Epoch 100 | Train Loss 0.316482 | Val Loss 0.394102
# Epoch 200 | Train Loss 0.314381 | Val Loss 0.394772
# Epoch 300 | Train Loss 0.313265 | Val Loss 0.395287
# Early stopping at epoch 355
# X | train1 -> R² = 0.9545, MSE = 4.9055e-03
# X | train2 -> R² = -1.3343, MSE = 1.9669e-01
# X | test1 -> R² = 0.9136, MSE = 9.0547e-03
# X | test2 -> R² = -1.3673, MSE = 1.9481e-01
# X | test3 -> R² = 0.8645, MSE = 1.2471e-02
# X | val -> R² = 0.8489, MSE = 1.4448e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.714948 | Val Loss 0.675440
# Epoch 100 | Train Loss 0.317125 | Val Loss 0.394410
# Epoch 200 | Train Loss 0.314920 | Val Loss 0.394894
# Epoch 300 | Train Loss 0.313629 | Val Loss 0.395518
# Early stopping at epoch 353
# X | train1 -> R² = 0.9538, MSE = 4.9796e-03
# X | train2 -> R² = -1.3440, MSE = 1.9751e-01
# X | test1 -> R² = 0.9113, MSE = 9.2969e-03
# X | test2 -> R² = -1.3757, MSE = 1.9550e-01
# X | test3 -> R² = 0.8767, MSE = 1.1340e-02
# X | val -> R² = 0.8625, MSE = 1.3148e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.715195 | Val Loss 0.675246
# Epoch 100 | Train Loss 0.318347 | Val Loss 0.393435
# Epoch 200 | Train Loss 0.315376 | Val Loss 0.393930
# Epoch 300 | Train Loss 0.313616 | Val Loss 0.394740
# Early stopping at epoch 353
# X | train1 -> R² = 0.9567, MSE = 4.6685e-03
# X | train2 -> R² = -1.4480, MSE = 2.0627e-01
# X | test1 -> R² = 0.9168, MSE = 8.7193e-03
# X | test2 -> R² = -1.4798, MSE = 2.0407e-01
# X | test3 -> R² = 0.8719, MSE = 1.1786e-02
# X | val -> R² = 0.8493, MSE = 1.4407e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.702425 | Val Loss 0.666732
# Epoch 100 | Train Loss 0.316137 | Val Loss 0.393940
# Epoch 200 | Train Loss 0.314036 | Val Loss 0.394621
# Epoch 300 | Train Loss 0.312986 | Val Loss 0.395321
# Early stopping at epoch 356
# X | train1 -> R² = 0.9488, MSE = 5.5225e-03
# X | train2 -> R² = -1.2915, MSE = 1.9309e-01
# X | test1 -> R² = 0.9071, MSE = 9.7278e-03
# X | test2 -> R² = -1.3282, MSE = 1.9160e-01
# X | test3 -> R² = 0.8627, MSE = 1.2629e-02
# X | val -> R² = 0.8499, MSE = 1.4357e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.738591 | Val Loss 0.694054
# Epoch 100 | Train Loss 0.315732 | Val Loss 0.394232
# Epoch 200 | Train Loss 0.313676 | Val Loss 0.394586
# Epoch 300 | Train Loss 0.312562 | Val Loss 0.395165
# Early stopping at epoch 356
# X | train1 -> R² = 0.9622, MSE = 4.0779e-03
# X | train2 -> R² = -1.3873, MSE = 2.0116e-01
# X | test1 -> R² = 0.9271, MSE = 7.6408e-03
# X | test2 -> R² = -1.4224, MSE = 1.9935e-01
# X | test3 -> R² = 0.8960, MSE = 9.5706e-03
# X | val -> R² = 0.8879, MSE = 1.0719e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.655767 | Val Loss 0.627243
# Epoch 100 | Train Loss 0.317582 | Val Loss 0.393871
# Epoch 200 | Train Loss 0.314426 | Val Loss 0.394444
# Epoch 300 | Train Loss 0.312588 | Val Loss 0.395298
# Early stopping at epoch 353
# X | train1 -> R² = 0.9564, MSE = 4.6983e-03
# X | train2 -> R² = -1.4308, MSE = 2.0482e-01
# X | test1 -> R² = 0.9148, MSE = 8.9292e-03
# X | test2 -> R² = -1.4597, MSE = 2.0241e-01
# X | test3 -> R² = 0.8782, MSE = 1.1210e-02
# X | val -> R² = 0.8578, MSE = 1.3594e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.720896 | Val Loss 0.681981
# Epoch 100 | Train Loss 0.318876 | Val Loss 0.393453
# Epoch 200 | Train Loss 0.315600 | Val Loss 0.393750
# Epoch 300 | Train Loss 0.314010 | Val Loss 0.394792
# Early stopping at epoch 355
# X | train1 -> R² = 0.9419, MSE = 6.2636e-03
# X | train2 -> R² = -1.3646, MSE = 1.9924e-01
# X | test1 -> R² = 0.8938, MSE = 1.1121e-02
# X | test2 -> R² = -1.3970, MSE = 1.9726e-01
# X | test3 -> R² = 0.8450, MSE = 1.4262e-02
# X | val -> R² = 0.8160, MSE = 1.7592e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.676366 | Val Loss 0.646586
# Epoch 100 | Train Loss 0.317237 | Val Loss 0.394023
# Epoch 200 | Train Loss 0.315103 | Val Loss 0.394676
# Epoch 300 | Train Loss 0.313993 | Val Loss 0.395249
# Early stopping at epoch 351
# X | train1 -> R² = 0.9567, MSE = 4.6710e-03
# X | train2 -> R² = -1.3879, MSE = 2.0120e-01
# X | test1 -> R² = 0.9175, MSE = 8.6478e-03
# X | test2 -> R² = -1.4218, MSE = 1.9929e-01
# X | test3 -> R² = 0.8850, MSE = 1.0581e-02
# X | val -> R² = 0.8715, MSE = 1.2285e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.602526 | Val Loss 0.649276
# Epoch 100 | Train Loss 0.232542 | Val Loss 0.394168
# Epoch 200 | Train Loss 0.229470 | Val Loss 0.395694
# Epoch 300 | Train Loss 0.227741 | Val Loss 0.396664
# Early stopping at epoch 356
# X | train1 -> R² = 0.9526, MSE = 5.1108e-03
# X | train2 -> R² = -1.3585, MSE = 1.9873e-01
# X | test1 -> R² = 0.9096, MSE = 9.4712e-03
# X | test2 -> R² = -1.3916, MSE = 1.9681e-01
# X | test3 -> R² = 0.8538, MSE = 1.3453e-02
# X | val -> R² = 0.8338, MSE = 1.5894e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.566357 | Val Loss 0.621489
# Epoch 100 | Train Loss 0.231680 | Val Loss 0.394837
# Epoch 200 | Train Loss 0.229278 | Val Loss 0.395946
# Epoch 300 | Train Loss 0.227900 | Val Loss 0.396788
# Early stopping at epoch 354
# X | train1 -> R² = 0.9538, MSE = 4.9811e-03
# X | train2 -> R² = -1.3121, MSE = 1.9482e-01
# X | test1 -> R² = 0.9109, MSE = 9.3339e-03
# X | test2 -> R² = -1.3449, MSE = 1.9297e-01
# X | test3 -> R² = 0.8541, MSE = 1.3425e-02
# X | val -> R² = 0.8396, MSE = 1.5336e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.663375 | Val Loss 0.700333
# Epoch 100 | Train Loss 0.233145 | Val Loss 0.393509
# Epoch 200 | Train Loss 0.229301 | Val Loss 0.395463
# Epoch 300 | Train Loss 0.227813 | Val Loss 0.397178
# Early stopping at epoch 360
# X | train1 -> R² = 0.9441, MSE = 6.0242e-03
# X | train2 -> R² = -1.3515, MSE = 1.9814e-01
# X | test1 -> R² = 0.8970, MSE = 1.0794e-02
# X | test2 -> R² = -1.3858, MSE = 1.9634e-01
# X | test3 -> R² = 0.8021, MSE = 1.8206e-02
# X | val -> R² = 0.7719, MSE = 2.1809e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.649618 | Val Loss 0.689365
# Epoch 100 | Train Loss 0.232287 | Val Loss 0.394580
# Epoch 200 | Train Loss 0.229997 | Val Loss 0.395839
# Epoch 300 | Train Loss 0.228854 | Val Loss 0.396821
# Early stopping at epoch 354
# X | train1 -> R² = 0.9608, MSE = 4.2240e-03
# X | train2 -> R² = -1.4198, MSE = 2.0389e-01
# X | test1 -> R² = 0.9191, MSE = 8.4705e-03
# X | test2 -> R² = -1.4478, MSE = 2.0144e-01
# X | test3 -> R² = 0.8679, MSE = 1.2152e-02
# X | val -> R² = 0.8480, MSE = 1.4532e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.692267 | Val Loss 0.722782
# Epoch 100 | Train Loss 0.231675 | Val Loss 0.394736
# Epoch 200 | Train Loss 0.229008 | Val Loss 0.395598
# Epoch 300 | Train Loss 0.227687 | Val Loss 0.396796
# Early stopping at epoch 365
# X | train1 -> R² = 0.9533, MSE = 5.0358e-03
# X | train2 -> R² = -1.3285, MSE = 1.9620e-01
# X | test1 -> R² = 0.9111, MSE = 9.3169e-03
# X | test2 -> R² = -1.3633, MSE = 1.9448e-01
# X | test3 -> R² = 0.8350, MSE = 1.5180e-02
# X | val -> R² = 0.8180, MSE = 1.7404e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.639708 | Val Loss 0.681141
# Epoch 100 | Train Loss 0.232675 | Val Loss 0.393523
# Epoch 200 | Train Loss 0.229146 | Val Loss 0.394456
# Epoch 300 | Train Loss 0.227235 | Val Loss 0.396060
# Early stopping at epoch 359
# X | train1 -> R² = 0.9552, MSE = 4.8298e-03
# X | train2 -> R² = -1.4186, MSE = 2.0379e-01
# X | test1 -> R² = 0.9153, MSE = 8.8730e-03
# X | test2 -> R² = -1.4533, MSE = 2.0189e-01
# X | test3 -> R² = 0.8473, MSE = 1.4047e-02
# X | val -> R² = 0.8224, MSE = 1.6981e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.594994 | Val Loss 0.646110
# Epoch 100 | Train Loss 0.230239 | Val Loss 0.394891
# Epoch 200 | Train Loss 0.227786 | Val Loss 0.396075
# Epoch 300 | Train Loss 0.226473 | Val Loss 0.396834
# Early stopping at epoch 355
# X | train1 -> R² = 0.9580, MSE = 4.5258e-03
# X | train2 -> R² = -1.3411, MSE = 1.9727e-01
# X | test1 -> R² = 0.9171, MSE = 8.6880e-03
# X | test2 -> R² = -1.3732, MSE = 1.9530e-01
# X | test3 -> R² = 0.8641, MSE = 1.2506e-02
# X | val -> R² = 0.8503, MSE = 1.4311e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.559938 | Val Loss 0.616211
# Epoch 100 | Train Loss 0.234318 | Val Loss 0.393655
# Epoch 200 | Train Loss 0.229654 | Val Loss 0.396140
# Epoch 300 | Train Loss 0.227845 | Val Loss 0.397285
# Early stopping at epoch 352
# X | train1 -> R² = 0.9419, MSE = 6.2597e-03
# X | train2 -> R² = -1.3782, MSE = 2.0038e-01
# X | test1 -> R² = 0.8948, MSE = 1.1022e-02
# X | test2 -> R² = -1.4130, MSE = 1.9857e-01
# X | test3 -> R² = 0.8498, MSE = 1.3822e-02
# X | val -> R² = 0.8226, MSE = 1.6966e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.626504 | Val Loss 0.672182
# Epoch 100 | Train Loss 0.233556 | Val Loss 0.393707
# Epoch 200 | Train Loss 0.230239 | Val Loss 0.395253
# Epoch 300 | Train Loss 0.228870 | Val Loss 0.396854
# Early stopping at epoch 353
# X | train1 -> R² = 0.9460, MSE = 5.8263e-03
# X | train2 -> R² = -1.3750, MSE = 2.0012e-01
# X | test1 -> R² = 0.8985, MSE = 1.0629e-02
# X | test2 -> R² = -1.4076, MSE = 1.9813e-01
# X | test3 -> R² = 0.8392, MSE = 1.4791e-02
# X | val -> R² = 0.8107, MSE = 1.8103e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.615721 | Val Loss 0.662834
# Epoch 100 | Train Loss 0.232236 | Val Loss 0.394322
# Epoch 200 | Train Loss 0.229590 | Val Loss 0.395129
# Epoch 300 | Train Loss 0.228229 | Val Loss 0.396509
# Early stopping at epoch 353
# X | train1 -> R² = 0.9572, MSE = 4.6172e-03
# X | train2 -> R² = -1.3868, MSE = 2.0112e-01
# X | test1 -> R² = 0.9168, MSE = 8.7180e-03
# X | test2 -> R² = -1.4210, MSE = 1.9923e-01
# X | test3 -> R² = 0.8831, MSE = 1.0754e-02
# X | val -> R² = 0.8687, MSE = 1.2560e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.605530 | Val Loss 0.653950
# Epoch 100 | Train Loss 0.230254 | Val Loss 0.394384
# Epoch 200 | Train Loss 0.227704 | Val Loss 0.396189
# Epoch 300 | Train Loss 0.226238 | Val Loss 0.396939
# Early stopping at epoch 357
# X | train1 -> R² = 0.9604, MSE = 4.2675e-03
# X | train2 -> R² = -1.3764, MSE = 2.0024e-01
# X | test1 -> R² = 0.9227, MSE = 8.1023e-03
# X | test2 -> R² = -1.4111, MSE = 1.9842e-01
# X | test3 -> R² = 0.8391, MSE = 1.4802e-02
# X | val -> R² = 0.8224, MSE = 1.6986e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.588041 | Val Loss 0.639010
# Epoch 100 | Train Loss 0.230990 | Val Loss 0.396018
# Epoch 200 | Train Loss 0.228544 | Val Loss 0.396128
# Epoch 300 | Train Loss 0.227310 | Val Loss 0.396957
# Early stopping at epoch 351
# X | train1 -> R² = 0.9648, MSE = 3.7993e-03
# X | train2 -> R² = -1.3868, MSE = 2.0111e-01
# X | test1 -> R² = 0.9248, MSE = 7.8745e-03
# X | test2 -> R² = -1.4138, MSE = 1.9864e-01
# X | test3 -> R² = 0.8988, MSE = 9.3066e-03
# X | val -> R² = 0.8896, MSE = 1.0553e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.647136 | Val Loss 0.686736
# Epoch 100 | Train Loss 0.232017 | Val Loss 0.395094
# Epoch 200 | Train Loss 0.229523 | Val Loss 0.395784
# Epoch 300 | Train Loss 0.228262 | Val Loss 0.396939
# Early stopping at epoch 356
# X | train1 -> R² = 0.9465, MSE = 5.7646e-03
# X | train2 -> R² = -1.2649, MSE = 1.9085e-01
# X | test1 -> R² = 0.9011, MSE = 1.0363e-02
# X | test2 -> R² = -1.2997, MSE = 1.8925e-01
# X | test3 -> R² = 0.8697, MSE = 1.1987e-02
# X | val -> R² = 0.8596, MSE = 1.3422e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.589580 | Val Loss 0.642467
# Epoch 100 | Train Loss 0.232708 | Val Loss 0.394006
# Epoch 200 | Train Loss 0.229699 | Val Loss 0.395557
# Epoch 300 | Train Loss 0.228134 | Val Loss 0.396651
# Early stopping at epoch 352
# X | train1 -> R² = 0.9477, MSE = 5.6416e-03
# X | train2 -> R² = -1.3461, MSE = 1.9768e-01
# X | test1 -> R² = 0.9026, MSE = 1.0202e-02
# X | test2 -> R² = -1.3807, MSE = 1.9591e-01
# X | test3 -> R² = 0.8468, MSE = 1.4098e-02
# X | val -> R² = 0.8241, MSE = 1.6821e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.662904 | Val Loss 0.699516
# Epoch 100 | Train Loss 0.232256 | Val Loss 0.394391
# Epoch 200 | Train Loss 0.229489 | Val Loss 0.395939
# Epoch 300 | Train Loss 0.228225 | Val Loss 0.397114
# Early stopping at epoch 356
# X | train1 -> R² = 0.9498, MSE = 5.4144e-03
# X | train2 -> R² = -1.3256, MSE = 1.9595e-01
# X | test1 -> R² = 0.9031, MSE = 1.0151e-02
# X | test2 -> R² = -1.3569, MSE = 1.9396e-01
# X | test3 -> R² = 0.8306, MSE = 1.5589e-02
# X | val -> R² = 0.8090, MSE = 1.8266e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.594799 | Val Loss 0.644060
# Epoch 100 | Train Loss 0.232118 | Val Loss 0.395222
# Epoch 200 | Train Loss 0.229517 | Val Loss 0.396177
# Epoch 300 | Train Loss 0.228020 | Val Loss 0.397416
# Early stopping at epoch 352
# X | train1 -> R² = 0.9599, MSE = 4.3213e-03
# X | train2 -> R² = -1.3661, MSE = 1.9937e-01
# X | test1 -> R² = 0.9204, MSE = 8.3371e-03
# X | test2 -> R² = -1.3987, MSE = 1.9740e-01
# X | test3 -> R² = 0.8923, MSE = 9.9058e-03
# X | val -> R² = 0.8824, MSE = 1.1246e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.604788 | Val Loss 0.653085
# Epoch 100 | Train Loss 0.231672 | Val Loss 0.395223
# Epoch 200 | Train Loss 0.229499 | Val Loss 0.396192
# Epoch 300 | Train Loss 0.228106 | Val Loss 0.396820
# Early stopping at epoch 327
# X | train1 -> R² = 0.9296, MSE = 7.5956e-03
# X | train2 -> R² = -1.1940, MSE = 1.8486e-01
# X | test1 -> R² = 0.8767, MSE = 1.2915e-02
# X | test2 -> R² = -1.2285, MSE = 1.8339e-01
# X | test3 -> R² = 0.8642, MSE = 1.2497e-02
# X | val -> R² = 0.8573, MSE = 1.3650e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.564040 | Val Loss 0.618572
# Epoch 100 | Train Loss 0.233367 | Val Loss 0.394520
# Epoch 200 | Train Loss 0.230003 | Val Loss 0.395711
# Epoch 300 | Train Loss 0.228100 | Val Loss 0.396974
# Early stopping at epoch 354
# X | train1 -> R² = 0.9428, MSE = 6.1693e-03
# X | train2 -> R² = -1.3169, MSE = 1.9522e-01
# X | test1 -> R² = 0.8930, MSE = 1.1213e-02
# X | test2 -> R² = -1.3483, MSE = 1.9325e-01
# X | test3 -> R² = 0.8453, MSE = 1.4235e-02
# X | val -> R² = 0.8225, MSE = 1.6969e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.637249 | Val Loss 0.679474
# Epoch 100 | Train Loss 0.234190 | Val Loss 0.393812
# Epoch 200 | Train Loss 0.230579 | Val Loss 0.394840
# Epoch 300 | Train Loss 0.229154 | Val Loss 0.396641
# Early stopping at epoch 355
# X | train1 -> R² = 0.9339, MSE = 7.1266e-03
# X | train2 -> R² = -1.3243, MSE = 1.9585e-01
# X | test1 -> R² = 0.8798, MSE = 1.2593e-02
# X | test2 -> R² = -1.3561, MSE = 1.9389e-01
# X | test3 -> R² = 0.8169, MSE = 1.6847e-02
# X | val -> R² = 0.7833, MSE = 2.0722e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.611055 | Val Loss 0.659377
# Epoch 100 | Train Loss 0.232735 | Val Loss 0.394369
# Epoch 200 | Train Loss 0.230151 | Val Loss 0.395495
# Epoch 300 | Train Loss 0.228967 | Val Loss 0.396820
# Early stopping at epoch 353
# X | train1 -> R² = 0.9529, MSE = 5.0834e-03
# X | train2 -> R² = -1.3694, MSE = 1.9965e-01
# X | test1 -> R² = 0.9080, MSE = 9.6341e-03
# X | test2 -> R² = -1.4003, MSE = 1.9753e-01
# X | test3 -> R² = 0.8600, MSE = 1.2884e-02
# X | val -> R² = 0.8392, MSE = 1.5374e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.671872 | Val Loss 0.703269
# Epoch 100 | Train Loss 0.231019 | Val Loss 0.395673
# Epoch 200 | Train Loss 0.228801 | Val Loss 0.396172
# Epoch 300 | Train Loss 0.227294 | Val Loss 0.396795
# Early stopping at epoch 358
# X | train1 -> R² = 0.9612, MSE = 4.1804e-03
# X | train2 -> R² = -1.3214, MSE = 1.9560e-01
# X | test1 -> R² = 0.9229, MSE = 8.0729e-03
# X | test2 -> R² = -1.3549, MSE = 1.9380e-01
# X | test3 -> R² = 0.8912, MSE = 1.0010e-02
# X | val -> R² = 0.8859, MSE = 1.0914e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.605291 | Val Loss 0.653212
# Epoch 100 | Train Loss 0.232014 | Val Loss 0.395074
# Epoch 200 | Train Loss 0.229128 | Val Loss 0.395902
# Epoch 300 | Train Loss 0.227477 | Val Loss 0.396947
# Early stopping at epoch 354
# X | train1 -> R² = 0.9579, MSE = 4.5404e-03
# X | train2 -> R² = -1.3986, MSE = 2.0210e-01
# X | test1 -> R² = 0.9131, MSE = 9.1002e-03
# X | test2 -> R² = -1.4241, MSE = 1.9948e-01
# X | test3 -> R² = 0.8659, MSE = 1.2338e-02
# X | val -> R² = 0.8451, MSE = 1.4811e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.654667 | Val Loss 0.693192
# Epoch 100 | Train Loss 0.232789 | Val Loss 0.394380
# Epoch 200 | Train Loss 0.229902 | Val Loss 0.395443
# Epoch 300 | Train Loss 0.228292 | Val Loss 0.396914
# Early stopping at epoch 356
# X | train1 -> R² = 0.9556, MSE = 4.7887e-03
# X | train2 -> R² = -1.3797, MSE = 2.0051e-01
# X | test1 -> R² = 0.9143, MSE = 8.9757e-03
# X | test2 -> R² = -1.4134, MSE = 1.9861e-01
# X | test3 -> R² = 0.8766, MSE = 1.1350e-02
# X | val -> R² = 0.8605, MSE = 1.3337e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.691575 | Val Loss 0.722417
# Epoch 100 | Train Loss 0.232412 | Val Loss 0.393980
# Epoch 200 | Train Loss 0.229014 | Val Loss 0.395223
# Epoch 300 | Train Loss 0.227263 | Val Loss 0.396556
# Early stopping at epoch 362
# X | train1 -> R² = 0.9573, MSE = 4.6048e-03
# X | train2 -> R² = -1.4490, MSE = 2.0635e-01
# X | test1 -> R² = 0.9155, MSE = 8.8534e-03
# X | test2 -> R² = -1.4799, MSE = 2.0408e-01
# X | test3 -> R² = 0.7923, MSE = 1.9109e-02
# X | val -> R² = 0.7628, MSE = 2.2678e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.693406 | Val Loss 0.721226
# Epoch 100 | Train Loss 0.232762 | Val Loss 0.394082
# Epoch 200 | Train Loss 0.229862 | Val Loss 0.395359
# Epoch 300 | Train Loss 0.228415 | Val Loss 0.396865
# Early stopping at epoch 362
# X | train1 -> R² = 0.9432, MSE = 6.1271e-03
# X | train2 -> R² = -1.2916, MSE = 1.9309e-01
# X | test1 -> R² = 0.8957, MSE = 1.0928e-02
# X | test2 -> R² = -1.3258, MSE = 1.9140e-01
# X | test3 -> R² = 0.8019, MSE = 1.8225e-02
# X | val -> R² = 0.7796, MSE = 2.1075e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.620445 | Val Loss 0.665321
# Epoch 100 | Train Loss 0.230905 | Val Loss 0.395148
# Epoch 200 | Train Loss 0.228195 | Val Loss 0.396104
# Epoch 300 | Train Loss 0.226459 | Val Loss 0.396746
# Early stopping at epoch 355
# X | train1 -> R² = 0.9605, MSE = 4.2623e-03
# X | train2 -> R² = -1.3395, MSE = 1.9713e-01
# X | test1 -> R² = 0.9211, MSE = 8.2667e-03
# X | test2 -> R² = -1.3721, MSE = 1.9521e-01
# X | test3 -> R² = 0.8720, MSE = 1.1780e-02
# X | val -> R² = 0.8607, MSE = 1.3325e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.596725 | Val Loss 0.645120
# Epoch 100 | Train Loss 0.232473 | Val Loss 0.395700
# Epoch 200 | Train Loss 0.230146 | Val Loss 0.396416
# Epoch 300 | Train Loss 0.228730 | Val Loss 0.397006
# Early stopping at epoch 354
# X | train1 -> R² = 0.9561, MSE = 4.7363e-03
# X | train2 -> R² = -1.3181, MSE = 1.9532e-01
# X | test1 -> R² = 0.9116, MSE = 9.2603e-03
# X | test2 -> R² = -1.3469, MSE = 1.9314e-01
# X | test3 -> R² = 0.8681, MSE = 1.2136e-02
# X | val -> R² = 0.8552, MSE = 1.3846e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.586815 | Val Loss 0.635489
# Epoch 100 | Train Loss 0.234141 | Val Loss 0.393978
# Epoch 200 | Train Loss 0.230596 | Val Loss 0.395184
# Epoch 300 | Train Loss 0.228789 | Val Loss 0.396870
# Early stopping at epoch 351
# X | train1 -> R² = 0.9511, MSE = 5.2736e-03
# X | train2 -> R² = -1.4192, MSE = 2.0384e-01
# X | test1 -> R² = 0.9043, MSE = 1.0025e-02
# X | test2 -> R² = -1.4479, MSE = 2.0145e-01
# X | test3 -> R² = 0.8546, MSE = 1.3382e-02
# X | val -> R² = 0.8266, MSE = 1.6579e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.639466 | Val Loss 0.682389
# Epoch 100 | Train Loss 0.234472 | Val Loss 0.393745
# Epoch 200 | Train Loss 0.230421 | Val Loss 0.394474
# Epoch 300 | Train Loss 0.228329 | Val Loss 0.396378
# Early stopping at epoch 400
# X | train1 -> R² = 0.9557, MSE = 4.7745e-03
# X | train2 -> R² = -1.4232, MSE = 2.0418e-01
# X | test1 -> R² = 0.9150, MSE = 8.9082e-03
# X | test2 -> R² = -1.4579, MSE = 2.0227e-01
# X | test3 -> R² = 0.7958, MSE = 1.8786e-02
# X | val -> R² = 0.7700, MSE = 2.1996e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.629690 | Val Loss 0.674059
# Epoch 100 | Train Loss 0.232258 | Val Loss 0.394296
# Epoch 200 | Train Loss 0.229407 | Val Loss 0.395132
# Epoch 300 | Train Loss 0.227901 | Val Loss 0.396121
# Early stopping at epoch 356
# X | train1 -> R² = 0.9585, MSE = 4.4748e-03
# X | train2 -> R² = -1.4194, MSE = 2.0386e-01
# X | test1 -> R² = 0.9159, MSE = 8.8117e-03
# X | test2 -> R² = -1.4479, MSE = 2.0144e-01
# X | test3 -> R² = 0.8573, MSE = 1.3131e-02
# X | val -> R² = 0.8338, MSE = 1.5889e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.795926 | Val Loss 0.672063
# Epoch 100 | Train Loss 0.401598 | Val Loss 0.393663
# Epoch 200 | Train Loss 0.398934 | Val Loss 0.393720
# Epoch 300 | Train Loss 0.397488 | Val Loss 0.393920
# Early stopping at epoch 359
# X | train1 -> R² = 0.9500, MSE = 5.3860e-03
# X | train2 -> R² = -1.3328, MSE = 1.9656e-01
# X | test1 -> R² = 0.9063, MSE = 9.8159e-03
# X | test2 -> R² = -1.3638, MSE = 1.9453e-01
# X | test3 -> R² = 0.8467, MSE = 1.4100e-02
# X | val -> R² = 0.8252, MSE = 1.6714e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.717356 | Val Loss 0.612019
# Epoch 100 | Train Loss 0.400713 | Val Loss 0.395681
# Epoch 200 | Train Loss 0.399087 | Val Loss 0.394763
# Epoch 300 | Train Loss 0.397841 | Val Loss 0.394337
# Epoch 400 | Train Loss 0.396640 | Val Loss 0.394225
# Early stopping at epoch 449
# X | train1 -> R² = 0.9737, MSE = 2.8337e-03
# X | train2 -> R² = -1.3788, MSE = 2.0044e-01
# X | test1 -> R² = 0.9491, MSE = 5.3274e-03
# X | test2 -> R² = -1.4202, MSE = 1.9917e-01
# X | test3 -> R² = 0.8568, MSE = 1.3177e-02
# X | val -> R² = 0.8599, MSE = 1.3396e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.797847 | Val Loss 0.677367
# Epoch 100 | Train Loss 0.401376 | Val Loss 0.394212
# Epoch 200 | Train Loss 0.398893 | Val Loss 0.394090
# Epoch 300 | Train Loss 0.397534 | Val Loss 0.394018
# Epoch 400 | Train Loss 0.396235 | Val Loss 0.393901
# Early stopping at epoch 403
# X | train1 -> R² = 0.9659, MSE = 3.6751e-03
# X | train2 -> R² = -1.3796, MSE = 2.0051e-01
# X | test1 -> R² = 0.9342, MSE = 6.8952e-03
# X | test2 -> R² = -1.4149, MSE = 1.9873e-01
# X | test3 -> R² = 0.8220, MSE = 1.6380e-02
# X | val -> R² = 0.8127, MSE = 1.7915e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.780668 | Val Loss 0.662907
# Epoch 100 | Train Loss 0.401839 | Val Loss 0.394307
# Epoch 200 | Train Loss 0.399764 | Val Loss 0.394206
# Epoch 300 | Train Loss 0.398462 | Val Loss 0.394189
# Early stopping at epoch 354
# X | train1 -> R² = 0.9552, MSE = 4.8277e-03
# X | train2 -> R² = -1.3563, MSE = 1.9854e-01
# X | test1 -> R² = 0.9128, MSE = 9.1332e-03
# X | test2 -> R² = -1.3845, MSE = 1.9623e-01
# X | test3 -> R² = 0.8787, MSE = 1.1160e-02
# X | val -> R² = 0.8641, MSE = 1.2999e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.809806 | Val Loss 0.685708
# Epoch 100 | Train Loss 0.400973 | Val Loss 0.394050
# Epoch 200 | Train Loss 0.398629 | Val Loss 0.394163
# Epoch 300 | Train Loss 0.397325 | Val Loss 0.394403
# Early stopping at epoch 353
# X | train1 -> R² = 0.9601, MSE = 4.3015e-03
# X | train2 -> R² = -1.3844, MSE = 2.0091e-01
# X | test1 -> R² = 0.9216, MSE = 8.2176e-03
# X | test2 -> R² = -1.4136, MSE = 1.9862e-01
# X | test3 -> R² = 0.8860, MSE = 1.0485e-02
# X | val -> R² = 0.8724, MSE = 1.2201e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.794208 | Val Loss 0.673069
# Epoch 100 | Train Loss 0.401385 | Val Loss 0.393356
# Epoch 200 | Train Loss 0.398967 | Val Loss 0.393614
# Epoch 300 | Train Loss 0.397623 | Val Loss 0.394215
# Early stopping at epoch 399
# X | train1 -> R² = 0.9634, MSE = 3.9429e-03
# X | train2 -> R² = -1.3966, MSE = 2.0194e-01
# X | test1 -> R² = 0.9322, MSE = 7.1048e-03
# X | test2 -> R² = -1.4362, MSE = 2.0048e-01
# X | test3 -> R² = 0.8462, MSE = 1.4149e-02
# X | val -> R² = 0.8328, MSE = 1.5993e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.781908 | Val Loss 0.662529
# Epoch 100 | Train Loss 0.400987 | Val Loss 0.394772
# Epoch 200 | Train Loss 0.398727 | Val Loss 0.394745
# Epoch 300 | Train Loss 0.397374 | Val Loss 0.394775
# Early stopping at epoch 400
# X | train1 -> R² = 0.9677, MSE = 3.4833e-03
# X | train2 -> R² = -1.3803, MSE = 2.0057e-01
# X | test1 -> R² = 0.9360, MSE = 6.7012e-03
# X | test2 -> R² = -1.4140, MSE = 1.9866e-01
# X | test3 -> R² = 0.8628, MSE = 1.2625e-02
# X | val -> R² = 0.8530, MSE = 1.4054e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.748449 | Val Loss 0.635720
# Epoch 100 | Train Loss 0.401491 | Val Loss 0.394148
# Epoch 200 | Train Loss 0.399375 | Val Loss 0.394192
# Epoch 300 | Train Loss 0.398123 | Val Loss 0.394301
# Early stopping at epoch 353
# X | train1 -> R² = 0.9538, MSE = 4.9803e-03
# X | train2 -> R² = -1.3499, MSE = 1.9800e-01
# X | test1 -> R² = 0.9119, MSE = 9.2259e-03
# X | test2 -> R² = -1.3802, MSE = 1.9587e-01
# X | test3 -> R² = 0.8806, MSE = 1.0987e-02
# X | val -> R² = 0.8675, MSE = 1.2671e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.801145 | Val Loss 0.680454
# Epoch 100 | Train Loss 0.402716 | Val Loss 0.393802
# Epoch 200 | Train Loss 0.399591 | Val Loss 0.393734
# Epoch 300 | Train Loss 0.397900 | Val Loss 0.393847
# Early stopping at epoch 396
# X | train1 -> R² = 0.9603, MSE = 4.2782e-03
# X | train2 -> R² = -1.4118, MSE = 2.0322e-01
# X | test1 -> R² = 0.9238, MSE = 7.9807e-03
# X | test2 -> R² = -1.4441, MSE = 2.0113e-01
# X | test3 -> R² = 0.8499, MSE = 1.3814e-02
# X | val -> R² = 0.8284, MSE = 1.6412e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.790312 | Val Loss 0.672584
# Epoch 100 | Train Loss 0.401337 | Val Loss 0.394498
# Epoch 200 | Train Loss 0.398953 | Val Loss 0.394440
# Epoch 300 | Train Loss 0.397531 | Val Loss 0.394456
# Early stopping at epoch 355
# X | train1 -> R² = 0.9581, MSE = 4.5138e-03
# X | train2 -> R² = -1.3549, MSE = 1.9842e-01
# X | test1 -> R² = 0.9164, MSE = 8.7548e-03
# X | test2 -> R² = -1.3818, MSE = 1.9601e-01
# X | test3 -> R² = 0.8777, MSE = 1.1254e-02
# X | val -> R² = 0.8628, MSE = 1.3123e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.805598 | Val Loss 0.679220
# Epoch 100 | Train Loss 0.401528 | Val Loss 0.393776
# Epoch 200 | Train Loss 0.399086 | Val Loss 0.394016
# Epoch 300 | Train Loss 0.397373 | Val Loss 0.394129
# Early stopping at epoch 362
# X | train1 -> R² = 0.9443, MSE = 6.0040e-03
# X | train2 -> R² = -1.2569, MSE = 1.9016e-01
# X | test1 -> R² = 0.9023, MSE = 1.0237e-02
# X | test2 -> R² = -1.2933, MSE = 1.8872e-01
# X | test3 -> R² = 0.8544, MSE = 1.3394e-02
# X | val -> R² = 0.8416, MSE = 1.5143e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.693890 | Val Loss 0.593738
# Epoch 100 | Train Loss 0.400628 | Val Loss 0.395082
# Epoch 200 | Train Loss 0.398508 | Val Loss 0.394531
# Epoch 300 | Train Loss 0.397126 | Val Loss 0.394494
# Early stopping at epoch 390
# X | train1 -> R² = 0.9673, MSE = 3.5303e-03
# X | train2 -> R² = -1.3757, MSE = 2.0018e-01
# X | test1 -> R² = 0.9346, MSE = 6.8558e-03
# X | test2 -> R² = -1.4082, MSE = 1.9818e-01
# X | test3 -> R² = 0.8729, MSE = 1.1696e-02
# X | val -> R² = 0.8630, MSE = 1.3097e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.771971 | Val Loss 0.656138
# Epoch 100 | Train Loss 0.401852 | Val Loss 0.394155
# Epoch 200 | Train Loss 0.399627 | Val Loss 0.394216
# Epoch 300 | Train Loss 0.398322 | Val Loss 0.394439
# Epoch 400 | Train Loss 0.397252 | Val Loss 0.394421
# Early stopping at epoch 431
# X | train1 -> R² = 0.9682, MSE = 3.4304e-03
# X | train2 -> R² = -1.4066, MSE = 2.0279e-01
# X | test1 -> R² = 0.9395, MSE = 6.3349e-03
# X | test2 -> R² = -1.4459, MSE = 2.0128e-01
# X | test3 -> R² = 0.8516, MSE = 1.3649e-02
# X | val -> R² = 0.8435, MSE = 1.4969e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.814908 | Val Loss 0.690384
# Epoch 100 | Train Loss 0.402540 | Val Loss 0.393763
# Epoch 200 | Train Loss 0.399246 | Val Loss 0.393605
# Epoch 300 | Train Loss 0.397258 | Val Loss 0.394309
# Early stopping at epoch 361
# X | train1 -> R² = 0.9484, MSE = 5.5598e-03
# X | train2 -> R² = -1.3553, MSE = 1.9845e-01
# X | test1 -> R² = 0.9036, MSE = 1.0097e-02
# X | test2 -> R² = -1.3854, MSE = 1.9630e-01
# X | test3 -> R² = 0.8529, MSE = 1.3531e-02
# X | val -> R² = 0.8286, MSE = 1.6390e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.790631 | Val Loss 0.670582
# Epoch 100 | Train Loss 0.401724 | Val Loss 0.393517
# Epoch 200 | Train Loss 0.399454 | Val Loss 0.393709
# Epoch 300 | Train Loss 0.398197 | Val Loss 0.393980
# Early stopping at epoch 355
# X | train1 -> R² = 0.9428, MSE = 6.1691e-03
# X | train2 -> R² = -1.2780, MSE = 1.9194e-01
# X | test1 -> R² = 0.8986, MSE = 1.0620e-02
# X | test2 -> R² = -1.3137, MSE = 1.9040e-01
# X | test3 -> R² = 0.8514, MSE = 1.3673e-02
# X | val -> R² = 0.8341, MSE = 1.5868e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.801355 | Val Loss 0.678538
# Epoch 100 | Train Loss 0.401166 | Val Loss 0.393692
# Epoch 200 | Train Loss 0.398975 | Val Loss 0.393917
# Epoch 300 | Train Loss 0.397718 | Val Loss 0.394342
# Early stopping at epoch 365
# X | train1 -> R² = 0.9439, MSE = 6.0473e-03
# X | train2 -> R² = -1.2625, MSE = 1.9064e-01
# X | test1 -> R² = 0.9018, MSE = 1.0285e-02
# X | test2 -> R² = -1.3007, MSE = 1.8933e-01
# X | test3 -> R² = 0.8610, MSE = 1.2786e-02
# X | val -> R² = 0.8484, MSE = 1.4496e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.783016 | Val Loss 0.664484
# Epoch 100 | Train Loss 0.400225 | Val Loss 0.394549
# Epoch 200 | Train Loss 0.398578 | Val Loss 0.394570
# Epoch 300 | Train Loss 0.397510 | Val Loss 0.394587
# Early stopping at epoch 352
# X | train1 -> R² = 0.9687, MSE = 3.3783e-03
# X | train2 -> R² = -1.4188, MSE = 2.0381e-01
# X | test1 -> R² = 0.9373, MSE = 6.5709e-03
# X | test2 -> R² = -1.4492, MSE = 2.0155e-01
# X | test3 -> R² = 0.9080, MSE = 8.4650e-03
# X | val -> R² = 0.9026, MSE = 9.3114e-03
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.717347 | Val Loss 0.611354
# Epoch 100 | Train Loss 0.402455 | Val Loss 0.394077
# Epoch 200 | Train Loss 0.399196 | Val Loss 0.394059
# Epoch 300 | Train Loss 0.397293 | Val Loss 0.394280
# Early stopping at epoch 352
# X | train1 -> R² = 0.9472, MSE = 5.6879e-03
# X | train2 -> R² = -1.3495, MSE = 1.9797e-01
# X | test1 -> R² = 0.8988, MSE = 1.0601e-02
# X | test2 -> R² = -1.3753, MSE = 1.9547e-01
# X | test3 -> R² = 0.8616, MSE = 1.2733e-02
# X | val -> R² = 0.8396, MSE = 1.5334e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.840620 | Val Loss 0.712294
# Epoch 100 | Train Loss 0.402962 | Val Loss 0.393572
# Epoch 200 | Train Loss 0.399411 | Val Loss 0.393245
# Epoch 300 | Train Loss 0.397608 | Val Loss 0.393598
# Early stopping at epoch 373
# X | train1 -> R² = 0.9365, MSE = 6.8489e-03
# X | train2 -> R² = -1.2773, MSE = 1.9188e-01
# X | test1 -> R² = 0.8882, MSE = 1.1710e-02
# X | test2 -> R² = -1.3107, MSE = 1.9015e-01
# X | test3 -> R² = 0.8053, MSE = 1.7909e-02
# X | val -> R² = 0.7764, MSE = 2.1379e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.791994 | Val Loss 0.672789
# Epoch 100 | Train Loss 0.401755 | Val Loss 0.393865
# Epoch 200 | Train Loss 0.399522 | Val Loss 0.393930
# Epoch 300 | Train Loss 0.397838 | Val Loss 0.394174
# Early stopping at epoch 364
# X | train1 -> R² = 0.9400, MSE = 6.4660e-03
# X | train2 -> R² = -1.2485, MSE = 1.8946e-01
# X | test1 -> R² = 0.8948, MSE = 1.1024e-02
# X | test2 -> R² = -1.2840, MSE = 1.8796e-01
# X | test3 -> R² = 0.8521, MSE = 1.3609e-02
# X | val -> R² = 0.8369, MSE = 1.5598e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.725969 | Val Loss 0.618885
# Epoch 100 | Train Loss 0.402147 | Val Loss 0.393057
# Epoch 200 | Train Loss 0.399095 | Val Loss 0.393807
# Epoch 300 | Train Loss 0.397490 | Val Loss 0.394569
# Early stopping at epoch 351
# X | train1 -> R² = 0.9554, MSE = 4.8084e-03
# X | train2 -> R² = -1.4460, MSE = 2.0610e-01
# X | test1 -> R² = 0.9178, MSE = 8.6104e-03
# X | test2 -> R² = -1.4813, MSE = 2.0420e-01
# X | test3 -> R² = 0.8756, MSE = 1.1447e-02
# X | val -> R² = 0.8557, MSE = 1.3794e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.709516 | Val Loss 0.607213
# Epoch 100 | Train Loss 0.401117 | Val Loss 0.394989
# Epoch 200 | Train Loss 0.398396 | Val Loss 0.394559
# Epoch 300 | Train Loss 0.396864 | Val Loss 0.394323
# Epoch 400 | Train Loss 0.395862 | Val Loss 0.394331
# Early stopping at epoch 422
# X | train1 -> R² = 0.9708, MSE = 3.1463e-03
# X | train2 -> R² = -1.3993, MSE = 2.0217e-01
# X | test1 -> R² = 0.9424, MSE = 6.0351e-03
# X | test2 -> R² = -1.4345, MSE = 2.0034e-01
# X | test3 -> R² = 0.8720, MSE = 1.1775e-02
# X | val -> R² = 0.8644, MSE = 1.2963e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.768330 | Val Loss 0.653727
# Epoch 100 | Train Loss 0.402525 | Val Loss 0.393734
# Epoch 200 | Train Loss 0.399630 | Val Loss 0.393954
# Epoch 300 | Train Loss 0.398037 | Val Loss 0.394231
# Early stopping at epoch 355
# X | train1 -> R² = 0.9471, MSE = 5.7000e-03
# X | train2 -> R² = -1.3503, MSE = 1.9804e-01
# X | test1 -> R² = 0.9003, MSE = 1.0441e-02
# X | test2 -> R² = -1.3780, MSE = 1.9570e-01
# X | test3 -> R² = 0.8588, MSE = 1.2988e-02
# X | val -> R² = 0.8359, MSE = 1.5691e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.823358 | Val Loss 0.696799
# Epoch 100 | Train Loss 0.401377 | Val Loss 0.394595
# Epoch 200 | Train Loss 0.399282 | Val Loss 0.394367
# Epoch 300 | Train Loss 0.398029 | Val Loss 0.394403
# Early stopping at epoch 357
# X | train1 -> R² = 0.9595, MSE = 4.3716e-03
# X | train2 -> R² = -1.3711, MSE = 1.9979e-01
# X | test1 -> R² = 0.9185, MSE = 8.5374e-03
# X | test2 -> R² = -1.3977, MSE = 1.9731e-01
# X | test3 -> R² = 0.8798, MSE = 1.1057e-02
# X | val -> R² = 0.8647, MSE = 1.2942e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.761003 | Val Loss 0.647793
# Epoch 100 | Train Loss 0.401447 | Val Loss 0.394066
# Epoch 200 | Train Loss 0.399077 | Val Loss 0.394221
# Epoch 300 | Train Loss 0.397709 | Val Loss 0.394668
# Early stopping at epoch 353
# X | train1 -> R² = 0.9597, MSE = 4.3444e-03
# X | train2 -> R² = -1.4100, MSE = 2.0307e-01
# X | test1 -> R² = 0.9218, MSE = 8.1901e-03
# X | test2 -> R² = -1.4406, MSE = 2.0084e-01
# X | test3 -> R² = 0.8941, MSE = 9.7465e-03
# X | val -> R² = 0.8826, MSE = 1.1225e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.746559 | Val Loss 0.636751
# Epoch 100 | Train Loss 0.401438 | Val Loss 0.394013
# Epoch 200 | Train Loss 0.399119 | Val Loss 0.394270
# Epoch 300 | Train Loss 0.397633 | Val Loss 0.394468
# Early stopping at epoch 361
# X | train1 -> R² = 0.9422, MSE = 6.2274e-03
# X | train2 -> R² = -1.2535, MSE = 1.8988e-01
# X | test1 -> R² = 0.8977, MSE = 1.0716e-02
# X | test2 -> R² = -1.2885, MSE = 1.8833e-01
# X | test3 -> R² = 0.8572, MSE = 1.3143e-02
# X | val -> R² = 0.8435, MSE = 1.4964e-02
# ...
# X | val -> R² = 0.1042, MSE = 8.5663e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.881006 | Val Loss 0.751795
# Epoch 100 | Train Loss 0.463671 | Val Loss 0.435729
# Epoch 200 | Train Loss 0.417058 | Val Loss 0.457109
# Epoch 300 | Train Loss 0.412920 | Val Loss 0.435677
# Epoch 400 | Train Loss 0.406337 | Val Loss 0.406520
# Epoch 500 | Train Loss 0.401900 | Val Loss 0.397194
# Epoch 600 | Train Loss 0.397876 | Val Loss 0.394316
# Epoch 700 | Train Loss 0.395075 | Val Loss 0.393369
# Epoch 800 | Train Loss 0.393505 | Val Loss 0.392637
# Epoch 900 | Train Loss 0.392676 | Val Loss 0.392281
# Epoch 1000 | Train Loss 0.392125 | Val Loss 0.392163
# Epoch 1100 | Train Loss 0.391643 | Val Loss 0.392162
# Early stopping at epoch 1130
# X | train1 -> R² = 0.9806, MSE = 2.0930e-03
# X | train2 -> R² = -1.3656, MSE = 1.9933e-01
# X | test1 -> R² = 0.9836, MSE = 1.7135e-03
# X | test2 -> R² = -1.3958, MSE = 1.9716e-01
# X | test3 -> R² = 0.8670, MSE = 1.2239e-02
# X | val -> R² = 0.8566, MSE = 1.3708e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.880053 | Val Loss 0.751007
# Epoch 100 | Train Loss 0.455954 | Val Loss 0.427431
# Epoch 200 | Train Loss 0.415746 | Val Loss 0.448277
# Epoch 300 | Train Loss 0.412105 | Val Loss 0.429516
# Epoch 400 | Train Loss 0.404847 | Val Loss 0.403088
# Epoch 500 | Train Loss 0.397792 | Val Loss 0.394911
# Epoch 600 | Train Loss 0.394858 | Val Loss 0.393960
# Epoch 700 | Train Loss 0.393952 | Val Loss 0.393674
# Epoch 800 | Train Loss 0.393482 | Val Loss 0.393882
# Early stopping at epoch 812
# X | train1 -> R² = 0.9761, MSE = 2.5760e-03
# X | train2 -> R² = -1.2998, MSE = 1.9379e-01
# X | test1 -> R² = 0.9631, MSE = 3.8683e-03
# X | test2 -> R² = -1.3339, MSE = 1.9206e-01
# X | test3 -> R² = 0.7082, MSE = 2.6847e-02
# X | val -> R² = 0.7230, MSE = 2.6487e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.875807 | Val Loss 0.747427
# Epoch 100 | Train Loss 0.453684 | Val Loss 0.426135
# Epoch 200 | Train Loss 0.415725 | Val Loss 0.449127
# Epoch 300 | Train Loss 0.412529 | Val Loss 0.438025
# Epoch 400 | Train Loss 0.408739 | Val Loss 0.418047
# Epoch 500 | Train Loss 0.404635 | Val Loss 0.405770
# Epoch 600 | Train Loss 0.401353 | Val Loss 0.400254
# Epoch 700 | Train Loss 0.397997 | Val Loss 0.395954
# Epoch 800 | Train Loss 0.395363 | Val Loss 0.394031
# Epoch 900 | Train Loss 0.394551 | Val Loss 0.393994
# Epoch 1000 | Train Loss 0.394152 | Val Loss 0.394136
# Early stopping at epoch 1058
# X | train1 -> R² = 0.9796, MSE = 2.2030e-03
# X | train2 -> R² = -1.3095, MSE = 1.9460e-01
# X | test1 -> R² = 0.9711, MSE = 3.0290e-03
# X | test2 -> R² = -1.3628, MSE = 1.9444e-01
# X | test3 -> R² = 0.6628, MSE = 3.1026e-02
# X | val -> R² = 0.7180, MSE = 2.6966e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.881054 | Val Loss 0.751913
# Epoch 100 | Train Loss 0.465627 | Val Loss 0.439167
# Epoch 200 | Train Loss 0.416697 | Val Loss 0.461176
# Epoch 300 | Train Loss 0.413864 | Val Loss 0.447525
# Epoch 400 | Train Loss 0.407684 | Val Loss 0.411889
# Epoch 500 | Train Loss 0.402184 | Val Loss 0.405048
# Epoch 600 | Train Loss 0.397619 | Val Loss 0.398342
# Epoch 700 | Train Loss 0.394757 | Val Loss 0.396193
# Epoch 800 | Train Loss 0.393962 | Val Loss 0.396997
# Epoch 900 | Train Loss 0.393628 | Val Loss 0.397491
# Early stopping at epoch 931
# X | train1 -> R² = 0.9769, MSE = 2.4878e-03
# X | train2 -> R² = -1.2956, MSE = 1.9343e-01
# X | test1 -> R² = 0.9734, MSE = 2.7828e-03
# X | test2 -> R² = -1.3253, MSE = 1.9136e-01
# X | test3 -> R² = -0.0921, MSE = 1.0048e-01
# X | val -> R² = 0.1210, MSE = 8.4050e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.880948 | Val Loss 0.751912
# Epoch 100 | Train Loss 0.495036 | Val Loss 0.457512
# Epoch 200 | Train Loss 0.419517 | Val Loss 0.468640
# Epoch 300 | Train Loss 0.415672 | Val Loss 0.473919
# Epoch 400 | Train Loss 0.413517 | Val Loss 0.447896
# Epoch 500 | Train Loss 0.407528 | Val Loss 0.409952
# Epoch 600 | Train Loss 0.404312 | Val Loss 0.404362
# Epoch 700 | Train Loss 0.401939 | Val Loss 0.399418
# Epoch 800 | Train Loss 0.398825 | Val Loss 0.395654
# Epoch 900 | Train Loss 0.395539 | Val Loss 0.394159
# Epoch 1000 | Train Loss 0.394024 | Val Loss 0.393287
# Epoch 1100 | Train Loss 0.393266 | Val Loss 0.392956
# Epoch 1200 | Train Loss 0.392726 | Val Loss 0.392831
# Epoch 1300 | Train Loss 0.392281 | Val Loss 0.392714
# Epoch 1400 | Train Loss 0.391880 | Val Loss 0.392621
# Early stopping at epoch 1452
# X | train1 -> R² = 0.9815, MSE = 1.9904e-03
# X | train2 -> R² = -1.3567, MSE = 1.9858e-01
# X | test1 -> R² = 0.9847, MSE = 1.6049e-03
# X | test2 -> R² = -1.3926, MSE = 1.9689e-01
# X | test3 -> R² = 0.8985, MSE = 9.3397e-03
# X | val -> R² = 0.8966, MSE = 9.8898e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.880844 | Val Loss 0.751983
# Epoch 100 | Train Loss 0.492563 | Val Loss 0.454408
# Epoch 200 | Train Loss 0.417054 | Val Loss 0.464176
# Epoch 300 | Train Loss 0.414912 | Val Loss 0.460472
# Epoch 400 | Train Loss 0.409202 | Val Loss 0.418213
# Epoch 500 | Train Loss 0.402838 | Val Loss 0.400591
# Epoch 600 | Train Loss 0.397505 | Val Loss 0.394935
# Epoch 700 | Train Loss 0.395041 | Val Loss 0.394298
# Epoch 800 | Train Loss 0.394364 | Val Loss 0.395027
# Early stopping at epoch 891
# X | train1 -> R² = 0.9757, MSE = 2.6164e-03
# X | train2 -> R² = -1.2970, MSE = 1.9355e-01
# X | test1 -> R² = 0.9682, MSE = 3.3290e-03
# X | test2 -> R² = -1.3320, MSE = 1.9191e-01
# X | test3 -> R² = 0.5921, MSE = 3.7531e-02
# X | val -> R² = 0.6447, MSE = 3.3979e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.881418 | Val Loss 0.752333
# Epoch 100 | Train Loss 0.496191 | Val Loss 0.455650
# Epoch 200 | Train Loss 0.417058 | Val Loss 0.449579
# Epoch 300 | Train Loss 0.414002 | Val Loss 0.440734
# Epoch 400 | Train Loss 0.407208 | Val Loss 0.408413
# Epoch 500 | Train Loss 0.400821 | Val Loss 0.400896
# Epoch 600 | Train Loss 0.397597 | Val Loss 0.399178
# Epoch 700 | Train Loss 0.396395 | Val Loss 0.399372
# Epoch 800 | Train Loss 0.395737 | Val Loss 0.399874
# Epoch 900 | Train Loss 0.395125 | Val Loss 0.399725
# Early stopping at epoch 913
# X | train1 -> R² = 0.9773, MSE = 2.4470e-03
# X | train2 -> R² = -1.2846, MSE = 1.9250e-01
# X | test1 -> R² = 0.9683, MSE = 3.3204e-03
# X | test2 -> R² = -1.3315, MSE = 1.9186e-01
# X | test3 -> R² = -0.4906, MSE = 1.3714e-01
# X | val -> R² = -0.1260, MSE = 1.0767e-01
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.875742 | Val Loss 0.747512
# Epoch 100 | Train Loss 0.489170 | Val Loss 0.452103
# Epoch 200 | Train Loss 0.415046 | Val Loss 0.433226
# Epoch 300 | Train Loss 0.406196 | Val Loss 0.397673
# Epoch 400 | Train Loss 0.398375 | Val Loss 0.393975
# Epoch 500 | Train Loss 0.395073 | Val Loss 0.394194
# Epoch 600 | Train Loss 0.393907 | Val Loss 0.393822
# Early stopping at epoch 680
# X | train1 -> R² = 0.9644, MSE = 3.8354e-03
# X | train2 -> R² = -1.2719, MSE = 1.9143e-01
# X | test1 -> R² = 0.9533, MSE = 4.8903e-03
# X | test2 -> R² = -1.2990, MSE = 1.8920e-01
# X | test3 -> R² = 0.8162, MSE = 1.6910e-02
# X | val -> R² = 0.8083, MSE = 1.8334e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.871795 | Val Loss 0.744041
# Epoch 100 | Train Loss 0.475753 | Val Loss 0.442126
# Epoch 200 | Train Loss 0.417753 | Val Loss 0.459484
# Epoch 300 | Train Loss 0.414170 | Val Loss 0.448973
# Epoch 400 | Train Loss 0.408912 | Val Loss 0.420169
# Epoch 500 | Train Loss 0.400017 | Val Loss 0.396171
# Epoch 600 | Train Loss 0.395660 | Val Loss 0.394230
# Epoch 700 | Train Loss 0.394721 | Val Loss 0.394971
# Epoch 800 | Train Loss 0.394301 | Val Loss 0.395339
# Early stopping at epoch 813
# X | train1 -> R² = 0.9739, MSE = 2.8180e-03
# X | train2 -> R² = -1.2922, MSE = 1.9314e-01
# X | test1 -> R² = 0.9674, MSE = 3.4167e-03
# X | test2 -> R² = -1.3305, MSE = 1.9178e-01
# X | test3 -> R² = 0.5420, MSE = 4.2135e-02
# X | val -> R² = 0.6021, MSE = 3.8048e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.882593 | Val Loss 0.752896
# Epoch 100 | Train Loss 0.438911 | Val Loss 0.418176
# Epoch 200 | Train Loss 0.413987 | Val Loss 0.435026
# Epoch 300 | Train Loss 0.409704 | Val Loss 0.414122
# Epoch 400 | Train Loss 0.405958 | Val Loss 0.404989
# Epoch 500 | Train Loss 0.404012 | Val Loss 0.402977
# Epoch 600 | Train Loss 0.402691 | Val Loss 0.400859
# Epoch 700 | Train Loss 0.401349 | Val Loss 0.398764
# Epoch 800 | Train Loss 0.399876 | Val Loss 0.396915
# Epoch 900 | Train Loss 0.398090 | Val Loss 0.395225
# Epoch 1000 | Train Loss 0.396098 | Val Loss 0.393983
# Epoch 1100 | Train Loss 0.394548 | Val Loss 0.393304
# Epoch 1200 | Train Loss 0.393708 | Val Loss 0.393230
# Epoch 1300 | Train Loss 0.393308 | Val Loss 0.393438
# Early stopping at epoch 1398
# X | train1 -> R² = 0.9801, MSE = 2.1466e-03
# X | train2 -> R² = -1.3610, MSE = 1.9894e-01
# X | test1 -> R² = 0.9808, MSE = 2.0089e-03
# X | test2 -> R² = -1.4092, MSE = 1.9826e-01
# X | test3 -> R² = 0.8272, MSE = 1.5900e-02
# X | val -> R² = 0.8299, MSE = 1.6266e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.879386 | Val Loss 0.750627
# Epoch 100 | Train Loss 0.461443 | Val Loss 0.439234
# Epoch 200 | Train Loss 0.417702 | Val Loss 0.459648
# Epoch 300 | Train Loss 0.413733 | Val Loss 0.441314
# Epoch 400 | Train Loss 0.408736 | Val Loss 0.409553
# Epoch 500 | Train Loss 0.405269 | Val Loss 0.403916
# Epoch 600 | Train Loss 0.403422 | Val Loss 0.402273
# Epoch 700 | Train Loss 0.402053 | Val Loss 0.400505
# Epoch 800 | Train Loss 0.400648 | Val Loss 0.398712
# Epoch 900 | Train Loss 0.399111 | Val Loss 0.397148
# Epoch 1000 | Train Loss 0.397479 | Val Loss 0.395824
# Epoch 1100 | Train Loss 0.396039 | Val Loss 0.395232
# Epoch 1200 | Train Loss 0.395042 | Val Loss 0.395622
# Epoch 1300 | Train Loss 0.394377 | Val Loss 0.396347
# Early stopping at epoch 1312
# X | train1 -> R² = 0.9778, MSE = 2.3928e-03
# X | train2 -> R² = -1.3193, MSE = 1.9542e-01
# X | test1 -> R² = 0.9718, MSE = 2.9503e-03
# X | test2 -> R² = -1.3687, MSE = 1.9492e-01
# X | test3 -> R² = 0.4871, MSE = 4.7191e-02
# X | val -> R² = 0.5821, MSE = 3.9961e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.881776 | Val Loss 0.752325
# Epoch 100 | Train Loss 0.513192 | Val Loss 0.468886
# Epoch 200 | Train Loss 0.418065 | Val Loss 0.442456
# Epoch 300 | Train Loss 0.409786 | Val Loss 0.414483
# Epoch 400 | Train Loss 0.402782 | Val Loss 0.404359
# Epoch 500 | Train Loss 0.399003 | Val Loss 0.402130
# Epoch 600 | Train Loss 0.397531 | Val Loss 0.402295
# Epoch 700 | Train Loss 0.396885 | Val Loss 0.402309
# Early stopping at epoch 746
# X | train1 -> R² = 0.9656, MSE = 3.7123e-03
# X | train2 -> R² = -1.2749, MSE = 1.9168e-01
# X | test1 -> R² = 0.9578, MSE = 4.4231e-03
# X | test2 -> R² = -1.3205, MSE = 1.9096e-01
# X | test3 -> R² = -1.3799, MSE = 2.1896e-01
# X | val -> R² = -0.7805, MSE = 1.7025e-01
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.875431 | Val Loss 0.747107
# Epoch 100 | Train Loss 0.471682 | Val Loss 0.440101
# Epoch 200 | Train Loss 0.416355 | Val Loss 0.451041
# Epoch 300 | Train Loss 0.409552 | Val Loss 0.414994
# Epoch 400 | Train Loss 0.400353 | Val Loss 0.395178
# Epoch 500 | Train Loss 0.396208 | Val Loss 0.393775
# Epoch 600 | Train Loss 0.394789 | Val Loss 0.394169
# Epoch 700 | Train Loss 0.394125 | Val Loss 0.394776
# Early stopping at epoch 757
# X | train1 -> R² = 0.9780, MSE = 2.3701e-03
# X | train2 -> R² = -1.3252, MSE = 1.9593e-01
# X | test1 -> R² = 0.9804, MSE = 2.0502e-03
# X | test2 -> R² = -1.3690, MSE = 1.9495e-01
# X | test3 -> R² = 0.7950, MSE = 1.8862e-02
# X | val -> R² = 0.8113, MSE = 1.8048e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.881126 | Val Loss 0.751800
# Epoch 100 | Train Loss 0.479075 | Val Loss 0.445581
# Epoch 200 | Train Loss 0.418759 | Val Loss 0.462653
# Epoch 300 | Train Loss 0.414555 | Val Loss 0.458409
# Epoch 400 | Train Loss 0.408656 | Val Loss 0.408504
# Epoch 500 | Train Loss 0.400224 | Val Loss 0.395820
# Epoch 600 | Train Loss 0.395267 | Val Loss 0.394362
# Epoch 700 | Train Loss 0.394023 | Val Loss 0.394413
# Epoch 800 | Train Loss 0.393548 | Val Loss 0.394237
# Early stopping at epoch 817
# X | train1 -> R² = 0.9702, MSE = 3.2104e-03
# X | train2 -> R² = -1.2769, MSE = 1.9185e-01
# X | test1 -> R² = 0.9647, MSE = 3.6989e-03
# X | test2 -> R² = -1.2973, MSE = 1.8905e-01
# X | test3 -> R² = 0.7569, MSE = 2.2363e-02
# X | val -> R² = 0.7559, MSE = 2.3343e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.879860 | Val Loss 0.750875
# Epoch 100 | Train Loss 0.469916 | Val Loss 0.436952
# Epoch 200 | Train Loss 0.421338 | Val Loss 0.448517
# Epoch 300 | Train Loss 0.412360 | Val Loss 0.421277
# Epoch 400 | Train Loss 0.402332 | Val Loss 0.398270
# Epoch 500 | Train Loss 0.395642 | Val Loss 0.393306
# Epoch 600 | Train Loss 0.394573 | Val Loss 0.393601
# Epoch 700 | Train Loss 0.394299 | Val Loss 0.393575
# Early stopping at epoch 743
# X | train1 -> R² = 0.9679, MSE = 3.4587e-03
# X | train2 -> R² = -1.2761, MSE = 1.9179e-01
# X | test1 -> R² = 0.9597, MSE = 4.2270e-03
# X | test2 -> R² = -1.3065, MSE = 1.8981e-01
# X | test3 -> R² = 0.4430, MSE = 5.1243e-02
# X | val -> R² = 0.5019, MSE = 4.7629e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.881127 | Val Loss 0.752203
# Epoch 100 | Train Loss 0.550745 | Val Loss 0.496385
# Epoch 200 | Train Loss 0.415165 | Val Loss 0.426900
# Epoch 300 | Train Loss 0.404372 | Val Loss 0.403353
# Epoch 400 | Train Loss 0.397747 | Val Loss 0.395414
# Epoch 500 | Train Loss 0.395569 | Val Loss 0.394984
# Epoch 600 | Train Loss 0.394502 | Val Loss 0.395050
# Early stopping at epoch 699
# X | train1 -> R² = 0.9698, MSE = 3.2525e-03
# X | train2 -> R² = -1.3078, MSE = 1.9446e-01
# X | test1 -> R² = 0.9695, MSE = 3.1960e-03
# X | test2 -> R² = -1.3516, MSE = 1.9352e-01
# X | test3 -> R² = 0.2516, MSE = 6.8859e-02
# X | val -> R² = 0.3488, MSE = 6.2272e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.879868 | Val Loss 0.750967
# Epoch 100 | Train Loss 0.459573 | Val Loss 0.434037
# Epoch 200 | Train Loss 0.416967 | Val Loss 0.454467
# Epoch 300 | Train Loss 0.410327 | Val Loss 0.417475
# Epoch 400 | Train Loss 0.402220 | Val Loss 0.400167
# Epoch 500 | Train Loss 0.396457 | Val Loss 0.393909
# Epoch 600 | Train Loss 0.394500 | Val Loss 0.394014
# Epoch 700 | Train Loss 0.393994 | Val Loss 0.394330
# Epoch 800 | Train Loss 0.393751 | Val Loss 0.394302
# Early stopping at epoch 810
# X | train1 -> R² = 0.9769, MSE = 2.4874e-03
# X | train2 -> R² = -1.3186, MSE = 1.9537e-01
# X | test1 -> R² = 0.9788, MSE = 2.2199e-03
# X | test2 -> R² = -1.3482, MSE = 1.9324e-01
# X | test3 -> R² = 0.6023, MSE = 3.6592e-02
# X | val -> R² = 0.6298, MSE = 3.5402e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.795567 | Val Loss 0.746163
# Epoch 100 | Train Loss 0.332171 | Val Loss 0.421402
# Epoch 200 | Train Loss 0.320246 | Val Loss 0.408373
# Epoch 300 | Train Loss 0.315525 | Val Loss 0.398654
# Epoch 400 | Train Loss 0.313916 | Val Loss 0.396684
# Epoch 500 | Train Loss 0.312739 | Val Loss 0.395680
# Epoch 600 | Train Loss 0.311889 | Val Loss 0.395870
# Epoch 700 | Train Loss 0.311188 | Val Loss 0.396603
# Early stopping at epoch 716
# X | train1 -> R² = 0.9808, MSE = 2.0693e-03
# X | train2 -> R² = -1.3186, MSE = 1.9537e-01
# X | test1 -> R² = 0.9724, MSE = 2.8902e-03
# X | test2 -> R² = -1.3733, MSE = 1.9531e-01
# X | test3 -> R² = 0.5513, MSE = 4.1284e-02
# X | val -> R² = 0.6572, MSE = 3.2780e-02
# Figura salva.
# Modelo [16, 8] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.793001 | Val Loss 0.745015
# Epoch 100 | Train Loss 0.330268 | Val Loss 0.408499
# Epoch 200 | Train Loss 0.318996 | Val Loss 0.402746
# Epoch 300 | Train Loss 0.314858 | Val Loss 0.398974
# Epoch 400 | Train Loss 0.311992 | Val Loss 0.396611
# Epoch 500 | Train Loss 0.310997 | Val Loss 0.396792
# Epoch 600 | Train Loss 0.310631 | Val Loss 0.397260
