# %% [markdown]
# - Entradas: SWdRef, SWeRef, Theta
# - Saidas: Y
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 10
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test")
        )

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva.")

        plt.close(fig)

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 1.413480 | Val Loss 0.808025
# Epoch 100 | Train Loss 0.941108 | Val Loss 0.861538
# Epoch 200 | Train Loss 0.927191 | Val Loss 0.795128
# Epoch 300 | Train Loss 0.914418 | Val Loss 0.694701
# Epoch 400 | Train Loss 0.905105 | Val Loss 0.652607
# Epoch 500 | Train Loss 0.902857 | Val Loss 0.648272
# Epoch 600 | Train Loss 0.901351 | Val Loss 0.641284
# Epoch 700 | Train Loss 0.900163 | Val Loss 0.637971
# Epoch 800 | Train Loss 0.899136 | Val Loss 0.635584
# Epoch 900 | Train Loss 0.898263 | Val Loss 0.634200
# Epoch 1000 | Train Loss 0.897483 | Val Loss 0.634072
# Epoch 1100 | Train Loss 0.896708 | Val Loss 0.634919
# Epoch 1200 | Train Loss 0.895956 | Val Loss 0.636635
# Early stopping at epoch 1208
# Y | train1 -> R² = 0.6447, MSE = 2.9773e-02
# Y | train2 -> R² = 0.1648, MSE = 8.9935e-02
# Y | test1 -> R² = 0.7618, MSE = 1.9521e-02
# Y | test2 -> R² = 0.1608, MSE = 8.9079e-02
# Y | test3 -> R² = -1.5649, MSE = 1.9701e-01
# Y | val -> R² = -1.7319, MSE = 2.0339e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.422236 | Val Loss 0.820649
# Epoch 100 | Train Loss 0.955223 | Val Loss 0.781256
# Epoch 200 | Train Loss 0.924012 | Val Loss 0.763132
# Epoch 300 | Train Loss 0.908817 | Val Loss 0.670337
# Epoch 400 | Train Loss 0.905816 | Val Loss 0.653174
# Epoch 500 | Train Loss 0.904021 | Val Loss 0.645805
# Epoch 600 | Train Loss 0.902447 | Val Loss 0.637413
# Epoch 700 | Train Loss 0.901034 | Val Loss 0.631240
# Epoch 800 | Train Loss 0.899710 | Val Loss 0.628081
# Epoch 900 | Train Loss 0.898452 | Val Loss 0.625347
# Epoch 1000 | Train Loss 0.897343 | Val Loss 0.624185
# Epoch 1100 | Train Loss 0.896380 | Val Loss 0.627741
# Epoch 1200 | Train Loss 0.895432 | Val Loss 0.633986
# Early stopping at epoch 1241
# Y | train1 -> R² = 0.6447, MSE = 2.9776e-02
# Y | train2 -> R² = 0.1613, MSE = 9.0311e-02
# Y | test1 -> R² = 0.7478, MSE = 2.0670e-02
# Y | test2 -> R² = 0.1578, MSE = 8.9393e-02
# Y | test3 -> R² = -1.2034, MSE = 1.6923e-01
# Y | val -> R² = -1.4627, MSE = 1.8335e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.450388 | Val Loss 0.806117
# Epoch 100 | Train Loss 0.955030 | Val Loss 0.817840
# Epoch 200 | Train Loss 0.929067 | Val Loss 0.802317
# Epoch 300 | Train Loss 0.921958 | Val Loss 0.735548
# Epoch 400 | Train Loss 0.908979 | Val Loss 0.660812
# Epoch 500 | Train Loss 0.905255 | Val Loss 0.645052
# Epoch 600 | Train Loss 0.903604 | Val Loss 0.639028
# Epoch 700 | Train Loss 0.901873 | Val Loss 0.625633
# Epoch 800 | Train Loss 0.900209 | Val Loss 0.616853
# Epoch 900 | Train Loss 0.899096 | Val Loss 0.615666
# Epoch 1000 | Train Loss 0.898294 | Val Loss 0.618098
# Epoch 1100 | Train Loss 0.897610 | Val Loss 0.621116
# Early stopping at epoch 1128
# Y | train1 -> R² = 0.6405, MSE = 3.0121e-02
# Y | train2 -> R² = 0.1656, MSE = 8.9847e-02
# Y | test1 -> R² = 0.7413, MSE = 2.1202e-02
# Y | test2 -> R² = 0.1602, MSE = 8.9142e-02
# Y | test3 -> R² = -0.8934, MSE = 1.4543e-01
# Y | val -> R² = -1.2947, MSE = 1.7084e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.488760 | Val Loss 0.847848
# Epoch 100 | Train Loss 1.033397 | Val Loss 0.715375
# Epoch 200 | Train Loss 0.927523 | Val Loss 0.787952
# Epoch 300 | Train Loss 0.911540 | Val Loss 0.699259
# Epoch 400 | Train Loss 0.906765 | Val Loss 0.665578
# Epoch 500 | Train Loss 0.905129 | Val Loss 0.658767
# Epoch 600 | Train Loss 0.903329 | Val Loss 0.652366
# Epoch 700 | Train Loss 0.901729 | Val Loss 0.644521
# Epoch 800 | Train Loss 0.900294 | Val Loss 0.635715
# Epoch 900 | Train Loss 0.899125 | Val Loss 0.628018
# Epoch 1000 | Train Loss 0.898259 | Val Loss 0.627158
# Epoch 1100 | Train Loss 0.897500 | Val Loss 0.630341
# Epoch 1200 | Train Loss 0.896784 | Val Loss 0.635280
# Early stopping at epoch 1222
# Y | train1 -> R² = 0.6352, MSE = 3.0569e-02
# Y | train2 -> R² = 0.1569, MSE = 9.0781e-02
# Y | test1 -> R² = 0.7351, MSE = 2.1708e-02
# Y | test2 -> R² = 0.1542, MSE = 8.9779e-02
# Y | test3 -> R² = -1.1601, MSE = 1.6591e-01
# Y | val -> R² = -1.4309, MSE = 1.8098e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.461569 | Val Loss 0.834613
# Epoch 100 | Train Loss 1.027731 | Val Loss 0.717604
# Epoch 200 | Train Loss 0.927725 | Val Loss 0.782280
# Epoch 300 | Train Loss 0.915128 | Val Loss 0.690562
# Epoch 400 | Train Loss 0.907782 | Val Loss 0.655729
# Epoch 500 | Train Loss 0.905842 | Val Loss 0.651785
# Epoch 600 | Train Loss 0.904390 | Val Loss 0.645799
# Epoch 700 | Train Loss 0.903081 | Val Loss 0.636079
# Epoch 800 | Train Loss 0.902055 | Val Loss 0.628901
# Epoch 900 | Train Loss 0.901122 | Val Loss 0.624106
# Epoch 1000 | Train Loss 0.900121 | Val Loss 0.621299
# Epoch 1100 | Train Loss 0.899001 | Val Loss 0.620818
# Epoch 1200 | Train Loss 0.897987 | Val Loss 0.619701
# Epoch 1300 | Train Loss 0.897094 | Val Loss 0.619815
# Epoch 1400 | Train Loss 0.896317 | Val Loss 0.620948
# Early stopping at epoch 1466
# Y | train1 -> R² = 0.6425, MSE = 2.9957e-02
# Y | train2 -> R² = 0.1635, MSE = 9.0072e-02
# Y | test1 -> R² = 0.7586, MSE = 1.9783e-02
# Y | test2 -> R² = 0.1592, MSE = 8.9246e-02
# Y | test3 -> R² = -0.6041, MSE = 1.2320e-01
# Y | val -> R² = -0.9408, MSE = 1.4449e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.461622 | Val Loss 0.803547
# Epoch 100 | Train Loss 0.979085 | Val Loss 0.709041
# Epoch 200 | Train Loss 0.925530 | Val Loss 0.755530
# Epoch 300 | Train Loss 0.915783 | Val Loss 0.688821
# Epoch 400 | Train Loss 0.907337 | Val Loss 0.653687
# Epoch 500 | Train Loss 0.905657 | Val Loss 0.652182
# Epoch 600 | Train Loss 0.904634 | Val Loss 0.645826
# Epoch 700 | Train Loss 0.903516 | Val Loss 0.632508
# Epoch 800 | Train Loss 0.902345 | Val Loss 0.621603
# Epoch 900 | Train Loss 0.901239 | Val Loss 0.614828
# Epoch 1000 | Train Loss 0.900244 | Val Loss 0.612665
# Epoch 1100 | Train Loss 0.899327 | Val Loss 0.613368
# Epoch 1200 | Train Loss 0.898441 | Val Loss 0.615429
# Early stopping at epoch 1267
# Y | train1 -> R² = 0.6421, MSE = 2.9988e-02
# Y | train2 -> R² = 0.1739, MSE = 8.8952e-02
# Y | test1 -> R² = 0.7446, MSE = 2.0926e-02
# Y | test2 -> R² = 0.1693, MSE = 8.8174e-02
# Y | test3 -> R² = -0.5044, MSE = 1.1555e-01
# Y | val -> R² = -0.8196, MSE = 1.3547e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.426209 | Val Loss 0.831295
# Epoch 100 | Train Loss 0.964239 | Val Loss 0.790102
# Epoch 200 | Train Loss 0.929115 | Val Loss 0.799449
# Epoch 300 | Train Loss 0.919355 | Val Loss 0.715365
# Epoch 400 | Train Loss 0.906311 | Val Loss 0.650855
# Epoch 500 | Train Loss 0.903980 | Val Loss 0.650154
# Epoch 600 | Train Loss 0.902221 | Val Loss 0.642195
# Epoch 700 | Train Loss 0.900856 | Val Loss 0.631341
# Epoch 800 | Train Loss 0.899976 | Val Loss 0.626153
# Epoch 900 | Train Loss 0.899257 | Val Loss 0.625995
# Epoch 1000 | Train Loss 0.898504 | Val Loss 0.627026
# Epoch 1100 | Train Loss 0.897667 | Val Loss 0.626865
# Early stopping at epoch 1102
# Y | train1 -> R² = 0.6460, MSE = 2.9664e-02
# Y | train2 -> R² = 0.1678, MSE = 8.9611e-02
# Y | test1 -> R² = 0.7527, MSE = 2.0270e-02
# Y | test2 -> R² = 0.1640, MSE = 8.8733e-02
# Y | test3 -> R² = -1.1388, MSE = 1.6428e-01
# Y | val -> R² = -1.5475, MSE = 1.8966e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.415821 | Val Loss 0.816195
# Epoch 100 | Train Loss 0.982064 | Val Loss 0.715369
# Epoch 200 | Train Loss 0.921731 | Val Loss 0.729314
# Epoch 300 | Train Loss 0.910581 | Val Loss 0.668537
# Epoch 400 | Train Loss 0.906494 | Val Loss 0.654790
# Epoch 500 | Train Loss 0.905031 | Val Loss 0.650540
# Epoch 600 | Train Loss 0.903643 | Val Loss 0.640762
# Epoch 700 | Train Loss 0.901930 | Val Loss 0.629080
# Epoch 800 | Train Loss 0.900231 | Val Loss 0.621231
# Epoch 900 | Train Loss 0.898941 | Val Loss 0.618241
# Epoch 1000 | Train Loss 0.897959 | Val Loss 0.616542
# Epoch 1100 | Train Loss 0.897103 | Val Loss 0.616433
# Epoch 1200 | Train Loss 0.896263 | Val Loss 0.616831
# Epoch 1300 | Train Loss 0.895351 | Val Loss 0.617529
# Epoch 1400 | Train Loss 0.894396 | Val Loss 0.618691
# Early stopping at epoch 1453
# Y | train1 -> R² = 0.6389, MSE = 3.0255e-02
# Y | train2 -> R² = 0.1582, MSE = 9.0638e-02
# Y | test1 -> R² = 0.7567, MSE = 1.9939e-02
# Y | test2 -> R² = 0.1466, MSE = 9.0587e-02
# Y | test3 -> R² = -0.6097, MSE = 1.2363e-01
# Y | val -> R² = -0.5048, MSE = 1.1204e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.461132 | Val Loss 0.845201
# Epoch 100 | Train Loss 0.983714 | Val Loss 0.748614
# Epoch 200 | Train Loss 0.932922 | Val Loss 0.856300
# Epoch 300 | Train Loss 0.924877 | Val Loss 0.783197
# Early stopping at epoch 383
# Y | train1 -> R² = 0.8676, MSE = 1.1093e-02
# Y | train2 -> R² = -2.6412, MSE = 3.9208e-01
# Y | test1 -> R² = 0.8301, MSE = 1.3923e-02
# Y | test2 -> R² = -2.5654, MSE = 3.7844e-01
# Y | test3 -> R² = -0.6684, MSE = 1.2814e-01
# Y | val -> R² = -0.3085, MSE = 9.7418e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.407638 | Val Loss 0.821710
# Epoch 100 | Train Loss 0.987142 | Val Loss 0.755999
# Epoch 200 | Train Loss 0.926077 | Val Loss 0.795047
# Epoch 300 | Train Loss 0.912489 | Val Loss 0.698142
# Epoch 400 | Train Loss 0.906461 | Val Loss 0.661642
# Epoch 500 | Train Loss 0.904616 | Val Loss 0.653196
# Epoch 600 | Train Loss 0.903252 | Val Loss 0.641284
# Epoch 700 | Train Loss 0.901933 | Val Loss 0.629660
# Epoch 800 | Train Loss 0.900755 | Val Loss 0.621089
# Epoch 900 | Train Loss 0.899801 | Val Loss 0.617145
# Epoch 1000 | Train Loss 0.898958 | Val Loss 0.617084
# Epoch 1100 | Train Loss 0.898157 | Val Loss 0.618743
# Early stopping at epoch 1188
# Y | train1 -> R² = 0.6418, MSE = 3.0017e-02
# Y | train2 -> R² = 0.1604, MSE = 9.0403e-02
# Y | test1 -> R² = 0.7537, MSE = 2.0182e-02
# Y | test2 -> R² = 0.1565, MSE = 8.9532e-02
# Y | test3 -> R² = -0.9393, MSE = 1.4895e-01
# Y | val -> R² = -1.1138, MSE = 1.5737e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.457797 | Val Loss 0.855513
# Epoch 100 | Train Loss 1.167893 | Val Loss 0.730751
# Epoch 200 | Train Loss 0.924761 | Val Loss 0.760370
# Epoch 300 | Train Loss 0.912445 | Val Loss 0.684837
# Epoch 400 | Train Loss 0.906894 | Val Loss 0.661280
# Epoch 500 | Train Loss 0.905507 | Val Loss 0.664174
# Epoch 600 | Train Loss 0.904581 | Val Loss 0.664660
# Early stopping at epoch 684
# Y | train1 -> R² = 0.6711, MSE = 2.7564e-02
# Y | train2 -> R² = 0.1963, MSE = 8.6537e-02
# Y | test1 -> R² = 0.7539, MSE = 2.0165e-02
# Y | test2 -> R² = 0.1799, MSE = 8.7050e-02
# Y | test3 -> R² = -2.7339, MSE = 2.8679e-01
# Y | val -> R² = -3.1027, MSE = 3.0545e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.403968 | Val Loss 0.803902
# Epoch 100 | Train Loss 0.943635 | Val Loss 0.858911
# Epoch 200 | Train Loss 0.927303 | Val Loss 0.795892
# Epoch 300 | Train Loss 0.916951 | Val Loss 0.721083
# Epoch 400 | Train Loss 0.906772 | Val Loss 0.671654
# Epoch 500 | Train Loss 0.904814 | Val Loss 0.662036
# Epoch 600 | Train Loss 0.903408 | Val Loss 0.654025
# Epoch 700 | Train Loss 0.901993 | Val Loss 0.645830
# Epoch 800 | Train Loss 0.900560 | Val Loss 0.635175
# Epoch 900 | Train Loss 0.899258 | Val Loss 0.624413
# Epoch 1000 | Train Loss 0.898196 | Val Loss 0.619573
# Epoch 1100 | Train Loss 0.897242 | Val Loss 0.619183
# Epoch 1200 | Train Loss 0.896251 | Val Loss 0.621023
# Early stopping at epoch 1292
# Y | train1 -> R² = 0.6401, MSE = 3.0161e-02
# Y | train2 -> R² = 0.1589, MSE = 9.0568e-02
# Y | test1 -> R² = 0.7491, MSE = 2.0557e-02
# Y | test2 -> R² = 0.1557, MSE = 8.9619e-02
# Y | test3 -> R² = -0.5790, MSE = 1.2128e-01
# Y | val -> R² = -0.7792, MSE = 1.3246e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.447369 | Val Loss 0.805895
# Epoch 100 | Train Loss 0.951018 | Val Loss 0.809840
# Epoch 200 | Train Loss 0.926888 | Val Loss 0.769675
# Epoch 300 | Train Loss 0.915008 | Val Loss 0.686369
# Epoch 400 | Train Loss 0.907367 | Val Loss 0.646696
# Epoch 500 | Train Loss 0.905527 | Val Loss 0.645274
# Epoch 600 | Train Loss 0.904106 | Val Loss 0.640943
# Epoch 700 | Train Loss 0.902731 | Val Loss 0.636395
# Epoch 800 | Train Loss 0.901262 | Val Loss 0.630921
# Epoch 900 | Train Loss 0.900003 | Val Loss 0.626200
# Epoch 1000 | Train Loss 0.899056 | Val Loss 0.623629
# Epoch 1100 | Train Loss 0.898334 | Val Loss 0.622612
# Epoch 1200 | Train Loss 0.897716 | Val Loss 0.622992
# Early stopping at epoch 1287
# Y | train1 -> R² = 0.6355, MSE = 3.0542e-02
# Y | train2 -> R² = 0.1691, MSE = 8.9469e-02
# Y | test1 -> R² = 0.7515, MSE = 2.0366e-02
# Y | test2 -> R² = 0.1599, MSE = 8.9172e-02
# Y | test3 -> R² = -0.4488, MSE = 1.1128e-01
# Y | val -> R² = -0.6521, MSE = 1.2300e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.452376 | Val Loss 0.811120
# Epoch 100 | Train Loss 0.963428 | Val Loss 0.757895
# Epoch 200 | Train Loss 0.923413 | Val Loss 0.757412
# Epoch 300 | Train Loss 0.911656 | Val Loss 0.676993
# Epoch 400 | Train Loss 0.905892 | Val Loss 0.644799
# Epoch 500 | Train Loss 0.904317 | Val Loss 0.641650
# Epoch 600 | Train Loss 0.902926 | Val Loss 0.639562
# Epoch 700 | Train Loss 0.901627 | Val Loss 0.635667
# Epoch 800 | Train Loss 0.900301 | Val Loss 0.633280
# Epoch 900 | Train Loss 0.898984 | Val Loss 0.632551
# Epoch 1000 | Train Loss 0.897853 | Val Loss 0.634706
# Epoch 1100 | Train Loss 0.896931 | Val Loss 0.639090
# Early stopping at epoch 1107
# Y | train1 -> R² = 0.6398, MSE = 3.0183e-02
# Y | train2 -> R² = 0.1779, MSE = 8.8518e-02
# Y | test1 -> R² = 0.7376, MSE = 2.1507e-02
# Y | test2 -> R² = 0.1701, MSE = 8.8084e-02
# Y | test3 -> R² = -1.4516, MSE = 1.8830e-01
# Y | val -> R² = -1.7293, MSE = 2.0320e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.413914 | Val Loss 0.820352
# Epoch 100 | Train Loss 0.963980 | Val Loss 0.798343
# Epoch 200 | Train Loss 0.927979 | Val Loss 0.801019
# Epoch 300 | Train Loss 0.914215 | Val Loss 0.705306
# Epoch 400 | Train Loss 0.907915 | Val Loss 0.667779
# Epoch 500 | Train Loss 0.905548 | Val Loss 0.662982
# Epoch 600 | Train Loss 0.903850 | Val Loss 0.656341
# Epoch 700 | Train Loss 0.902209 | Val Loss 0.645069
# Epoch 800 | Train Loss 0.900756 | Val Loss 0.635719
# Epoch 900 | Train Loss 0.899465 | Val Loss 0.629497
# Epoch 1000 | Train Loss 0.898339 | Val Loss 0.626857
# Epoch 1100 | Train Loss 0.897466 | Val Loss 0.627119
# Epoch 1200 | Train Loss 0.896740 | Val Loss 0.628958
# Early stopping at epoch 1285
# Y | train1 -> R² = 0.6452, MSE = 2.9727e-02
# Y | train2 -> R² = 0.1629, MSE = 9.0141e-02
# Y | test1 -> R² = 0.7470, MSE = 2.0732e-02
# Y | test2 -> R² = 0.1615, MSE = 8.8996e-02
# Y | test3 -> R² = -0.6391, MSE = 1.2589e-01
# Y | val -> R² = -0.8935, MSE = 1.4097e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.532740 | Val Loss 0.837617
# Epoch 100 | Train Loss 1.005894 | Val Loss 0.703856
# Epoch 200 | Train Loss 0.930002 | Val Loss 0.803585
# Epoch 300 | Train Loss 0.918262 | Val Loss 0.716123
# Epoch 400 | Train Loss 0.908388 | Val Loss 0.667941
# Epoch 500 | Train Loss 0.905928 | Val Loss 0.657821
# Epoch 600 | Train Loss 0.904069 | Val Loss 0.651392
# Epoch 700 | Train Loss 0.902354 | Val Loss 0.635909
# Epoch 800 | Train Loss 0.901159 | Val Loss 0.625763
# Epoch 900 | Train Loss 0.900240 | Val Loss 0.623911
# Epoch 1000 | Train Loss 0.899441 | Val Loss 0.626792
# Epoch 1100 | Train Loss 0.898692 | Val Loss 0.630623
# Early stopping at epoch 1137
# Y | train1 -> R² = 0.6420, MSE = 3.0000e-02
# Y | train2 -> R² = 0.1649, MSE = 8.9923e-02
# Y | test1 -> R² = 0.7444, MSE = 2.0949e-02
# Y | test2 -> R² = 0.1609, MSE = 8.9059e-02
# Y | test3 -> R² = -1.3787, MSE = 1.8270e-01
# Y | val -> R² = -1.7400, MSE = 2.0399e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 1.408442 | Val Loss 0.834406
# Epoch 100 | Train Loss 1.116740 | Val Loss 0.710601
# Epoch 200 | Train Loss 0.922414 | Val Loss 0.742307
# Epoch 300 | Train Loss 0.908128 | Val Loss 0.666749
# Epoch 400 | Train Loss 0.905990 | Val Loss 0.660499
# Epoch 500 | Train Loss 0.904524 | Val Loss 0.654295
# Epoch 600 | Train Loss 0.902795 | Val Loss 0.641894
# Epoch 700 | Train Loss 0.901117 | Val Loss 0.630943
# Epoch 800 | Train Loss 0.899612 | Val Loss 0.626285
# Epoch 900 | Train Loss 0.898498 | Val Loss 0.625363
# Epoch 1000 | Train Loss 0.897588 | Val Loss 0.627447
# Epoch 1100 | Train Loss 0.896733 | Val Loss 0.630098
# Early stopping at epoch 1111
# Y | train1 -> R² = 0.6443, MSE = 2.9804e-02
# Y | train2 -> R² = 0.1674, MSE = 8.9653e-02
# Y | test1 -> R² = 0.7649, MSE = 1.9263e-02
# Y | test2 -> R² = 0.1655, MSE = 8.8575e-02
# Y | test3 -> R² = -0.7602, MSE = 1.3519e-01
# Y | val -> R² = -1.0250, MSE = 1.5076e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 1.431644 | Val Loss 0.839736
# Epoch 100 | Train Loss 1.024286 | Val Loss 0.718819
# Epoch 200 | Train Loss 0.929733 | Val Loss 0.822488
# Epoch 300 | Train Loss 0.916537 | Val Loss 0.725960
# Epoch 400 | Train Loss 0.906543 | Val Loss 0.673301
# Epoch 500 | Train Loss 0.904245 | Val Loss 0.662254
# Epoch 600 | Train Loss 0.902681 | Val Loss 0.647203
# Epoch 700 | Train Loss 0.901222 | Val Loss 0.634291
# Epoch 800 | Train Loss 0.900089 | Val Loss 0.626525
# Epoch 900 | Train Loss 0.899191 | Val Loss 0.622354
# Epoch 1000 | Train Loss 0.898411 | Val Loss 0.620669
# Epoch 1100 | Train Loss 0.897671 | Val Loss 0.621131
# Epoch 1200 | Train Loss 0.896960 | Val Loss 0.624687
# Early stopping at epoch 1237
# Y | train1 -> R² = 0.6432, MSE = 2.9898e-02
# Y | train2 -> R² = 0.1641, MSE = 9.0008e-02
# Y | test1 -> R² = 0.7484, MSE = 2.0616e-02
# Y | test2 -> R² = 0.1635, MSE = 8.8793e-02
# Y | test3 -> R² = -1.1182, MSE = 1.6269e-01
# Y | val -> R² = -1.3020, MSE = 1.7138e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 1.443663 | Val Loss 0.832328
# Epoch 100 | Train Loss 0.961065 | Val Loss 0.771061
# Epoch 200 | Train Loss 0.930816 | Val Loss 0.821930
# Epoch 300 | Train Loss 0.920244 | Val Loss 0.725669
# Epoch 400 | Train Loss 0.908737 | Val Loss 0.645642
# Epoch 500 | Train Loss 0.905738 | Val Loss 0.637242
# Epoch 600 | Train Loss 0.903825 | Val Loss 0.635043
# Epoch 700 | Train Loss 0.902256 | Val Loss 0.628877
# Epoch 800 | Train Loss 0.901082 | Val Loss 0.623110
# Epoch 900 | Train Loss 0.900111 | Val Loss 0.619458
# Epoch 1000 | Train Loss 0.899192 | Val Loss 0.617103
# Epoch 1100 | Train Loss 0.898271 | Val Loss 0.615764
# Epoch 1200 | Train Loss 0.897339 | Val Loss 0.615286
# Epoch 1300 | Train Loss 0.896447 | Val Loss 0.615942
# Epoch 1400 | Train Loss 0.895618 | Val Loss 0.618624
# Early stopping at epoch 1464
# Y | train1 -> R² = 0.6346, MSE = 3.0620e-02
# Y | train2 -> R² = 0.1656, MSE = 8.9846e-02
# Y | test1 -> R² = 0.7288, MSE = 2.2228e-02
# Y | test2 -> R² = 0.1531, MSE = 8.9896e-02
# Y | test3 -> R² = -0.9650, MSE = 1.5093e-01
# Y | val -> R² = -1.3228, MSE = 1.7293e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 1.396780 | Val Loss 0.805443
# Epoch 100 | Train Loss 0.945334 | Val Loss 0.824600
# Epoch 200 | Train Loss 0.925220 | Val Loss 0.747433
# Epoch 300 | Train Loss 0.911929 | Val Loss 0.669349
# Epoch 400 | Train Loss 0.906329 | Val Loss 0.661167
# Epoch 500 | Train Loss 0.904441 | Val Loss 0.660801
# Epoch 600 | Train Loss 0.902683 | Val Loss 0.652415
# Epoch 700 | Train Loss 0.900734 | Val Loss 0.640399
# Epoch 800 | Train Loss 0.898876 | Val Loss 0.628701
# Epoch 900 | Train Loss 0.897468 | Val Loss 0.621745
# Epoch 1000 | Train Loss 0.896405 | Val Loss 0.618440
# Epoch 1100 | Train Loss 0.895485 | Val Loss 0.616837
# Epoch 1200 | Train Loss 0.894583 | Val Loss 0.616605
# Epoch 1300 | Train Loss 0.893673 | Val Loss 0.618109
# Epoch 1400 | Train Loss 0.892756 | Val Loss 0.620623
# Early stopping at epoch 1411
# Y | train1 -> R² = 0.6432, MSE = 2.9898e-02
# Y | train2 -> R² = 0.1628, MSE = 9.0144e-02
# Y | test1 -> R² = 0.7489, MSE = 2.0574e-02
# Y | test2 -> R² = 0.1639, MSE = 8.8741e-02
# Y | test3 -> R² = -0.1742, MSE = 9.0187e-02
# Y | val -> R² = -0.3761, MSE = 1.0245e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 1.410712 | Val Loss 0.807460
# Epoch 100 | Train Loss 0.941972 | Val Loss 0.860216
# Epoch 200 | Train Loss 0.930852 | Val Loss 0.842853
# Epoch 300 | Train Loss 0.921355 | Val Loss 0.741240
# Epoch 400 | Train Loss 0.908064 | Val Loss 0.643656
# Epoch 500 | Train Loss 0.904639 | Val Loss 0.637298
# Epoch 600 | Train Loss 0.902856 | Val Loss 0.632416
# Epoch 700 | Train Loss 0.901544 | Val Loss 0.625418
# Epoch 800 | Train Loss 0.900460 | Val Loss 0.620118
# Epoch 900 | Train Loss 0.899469 | Val Loss 0.617769
# Epoch 1000 | Train Loss 0.898556 | Val Loss 0.618257
# Epoch 1100 | Train Loss 0.897729 | Val Loss 0.620692
# Epoch 1200 | Train Loss 0.896900 | Val Loss 0.623882
# Early stopping at epoch 1215
# Y | train1 -> R² = 0.6480, MSE = 2.9495e-02
# Y | train2 -> R² = 0.1610, MSE = 9.0337e-02
# Y | test1 -> R² = 0.7581, MSE = 1.9820e-02
# Y | test2 -> R² = 0.1564, MSE = 8.9543e-02
# Y | test3 -> R² = -0.1513, MSE = 8.8428e-02
# Y | val -> R² = -0.3736, MSE = 1.0227e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.405652 | Val Loss 0.803172
# Epoch 100 | Train Loss 0.944828 | Val Loss 0.830339
# Epoch 200 | Train Loss 0.927381 | Val Loss 0.783593
# Epoch 300 | Train Loss 0.916685 | Val Loss 0.688707
# Epoch 400 | Train Loss 0.908678 | Val Loss 0.648852
# Epoch 500 | Train Loss 0.905575 | Val Loss 0.650994
# Epoch 600 | Train Loss 0.903396 | Val Loss 0.647309
# Epoch 700 | Train Loss 0.901644 | Val Loss 0.641502
# Epoch 800 | Train Loss 0.900161 | Val Loss 0.638318
# Epoch 900 | Train Loss 0.898879 | Val Loss 0.637186
# Epoch 1000 | Train Loss 0.897822 | Val Loss 0.639201
# Epoch 1100 | Train Loss 0.896875 | Val Loss 0.643340
# Early stopping at epoch 1110
# Y | train1 -> R² = 0.6416, MSE = 3.0029e-02
# Y | train2 -> R² = 0.1585, MSE = 9.0616e-02
# Y | test1 -> R² = 0.7475, MSE = 2.0694e-02
# Y | test2 -> R² = 0.1536, MSE = 8.9838e-02
# Y | test3 -> R² = -1.6006, MSE = 1.9974e-01
# Y | val -> R² = -1.7558, MSE = 2.0517e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.417368 | Val Loss 0.824392
# Epoch 100 | Train Loss 1.058903 | Val Loss 0.691391
# Epoch 200 | Train Loss 0.921699 | Val Loss 0.726086
# Epoch 300 | Train Loss 0.910115 | Val Loss 0.660117
# Epoch 400 | Train Loss 0.906409 | Val Loss 0.648972
# Epoch 500 | Train Loss 0.904665 | Val Loss 0.650536
# Epoch 600 | Train Loss 0.902952 | Val Loss 0.646134
# Epoch 700 | Train Loss 0.901377 | Val Loss 0.638788
# Epoch 800 | Train Loss 0.900095 | Val Loss 0.634143
# Epoch 900 | Train Loss 0.898993 | Val Loss 0.632014
# Epoch 1000 | Train Loss 0.898022 | Val Loss 0.631773
# Epoch 1100 | Train Loss 0.897113 | Val Loss 0.632285
# Epoch 1200 | Train Loss 0.896218 | Val Loss 0.633583
# Early stopping at epoch 1202
# Y | train1 -> R² = 0.6417, MSE = 3.0028e-02
# Y | train2 -> R² = 0.1693, MSE = 8.9446e-02
# Y | test1 -> R² = 0.7522, MSE = 2.0310e-02
# Y | test2 -> R² = 0.1673, MSE = 8.8385e-02
# Y | test3 -> R² = -1.4672, MSE = 1.8950e-01
# Y | val -> R² = -1.6302, MSE = 1.9582e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.489335 | Val Loss 0.819822
# Epoch 100 | Train Loss 0.959421 | Val Loss 0.818218
# Epoch 200 | Train Loss 0.929733 | Val Loss 0.831046
# Epoch 300 | Train Loss 0.916667 | Val Loss 0.707021
# Epoch 400 | Train Loss 0.908727 | Val Loss 0.633957
# Epoch 500 | Train Loss 0.906469 | Val Loss 0.634334
# Epoch 600 | Train Loss 0.904709 | Val Loss 0.629847
# Epoch 700 | Train Loss 0.903136 | Val Loss 0.620269
# Epoch 800 | Train Loss 0.901726 | Val Loss 0.616129
# Epoch 900 | Train Loss 0.900626 | Val Loss 0.615841
# Epoch 1000 | Train Loss 0.899774 | Val Loss 0.617197
# Epoch 1100 | Train Loss 0.899055 | Val Loss 0.619229
# Early stopping at epoch 1136
# Y | train1 -> R² = 0.6436, MSE = 2.9861e-02
# Y | train2 -> R² = 0.1668, MSE = 8.9718e-02
# Y | test1 -> R² = 0.7567, MSE = 1.9938e-02
# Y | test2 -> R² = 0.1594, MSE = 8.9219e-02
# Y | test3 -> R² = -1.3670, MSE = 1.8180e-01
# Y | val -> R² = -1.4946, MSE = 1.8572e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.458997 | Val Loss 0.849069
# Epoch 100 | Train Loss 1.026012 | Val Loss 0.702074
# Epoch 200 | Train Loss 0.926875 | Val Loss 0.775535
# Epoch 300 | Train Loss 0.913840 | Val Loss 0.692063
# Epoch 400 | Train Loss 0.907194 | Val Loss 0.665358
# Epoch 500 | Train Loss 0.905452 | Val Loss 0.668720
# Epoch 600 | Train Loss 0.904167 | Val Loss 0.668446
# Early stopping at epoch 685
# Y | train1 -> R² = 0.6639, MSE = 2.8163e-02
# Y | train2 -> R² = 0.2041, MSE = 8.5705e-02
# Y | test1 -> R² = 0.7413, MSE = 2.1199e-02
# Y | test2 -> R² = 0.1872, MSE = 8.6275e-02
# Y | test3 -> R² = -3.0519, MSE = 3.1122e-01
# Y | val -> R² = -3.4539, MSE = 3.3159e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.429687 | Val Loss 0.806120
# Epoch 100 | Train Loss 0.950393 | Val Loss 0.805960
# Epoch 200 | Train Loss 0.929236 | Val Loss 0.818498
# Epoch 300 | Train Loss 0.921274 | Val Loss 0.741756
# Epoch 400 | Train Loss 0.910916 | Val Loss 0.680095
# Epoch 500 | Train Loss 0.905583 | Val Loss 0.657121
# Epoch 600 | Train Loss 0.903425 | Val Loss 0.647912
# Epoch 700 | Train Loss 0.901683 | Val Loss 0.637797
# Epoch 800 | Train Loss 0.900344 | Val Loss 0.632029
# Epoch 900 | Train Loss 0.899309 | Val Loss 0.631851
# Epoch 1000 | Train Loss 0.898403 | Val Loss 0.634620
# Epoch 1100 | Train Loss 0.897589 | Val Loss 0.637908
# Early stopping at epoch 1102
# Y | train1 -> R² = 0.6523, MSE = 2.9136e-02
# Y | train2 -> R² = 0.1689, MSE = 8.9486e-02
# Y | test1 -> R² = 0.7570, MSE = 1.9914e-02
# Y | test2 -> R² = 0.1641, MSE = 8.8726e-02
# Y | test3 -> R² = -1.5774, MSE = 1.9797e-01
# Y | val -> R² = -1.9637, MSE = 2.2065e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 1.442048 | Val Loss 0.845210
# Epoch 100 | Train Loss 1.115885 | Val Loss 0.710134
# Epoch 200 | Train Loss 0.920848 | Val Loss 0.716210
# Epoch 300 | Train Loss 0.908929 | Val Loss 0.659742
# Epoch 400 | Train Loss 0.906225 | Val Loss 0.657950
# Epoch 500 | Train Loss 0.904438 | Val Loss 0.654828
# Epoch 600 | Train Loss 0.902561 | Val Loss 0.643676
# Epoch 700 | Train Loss 0.900950 | Val Loss 0.632427
# Epoch 800 | Train Loss 0.899736 | Val Loss 0.625647
# Epoch 900 | Train Loss 0.898741 | Val Loss 0.622833
# Epoch 1000 | Train Loss 0.897882 | Val Loss 0.621520
# Epoch 1100 | Train Loss 0.897103 | Val Loss 0.620982
# Epoch 1200 | Train Loss 0.896296 | Val Loss 0.619970
# Epoch 1300 | Train Loss 0.895415 | Val Loss 0.619367
# Epoch 1400 | Train Loss 0.894442 | Val Loss 0.620032
# Epoch 1500 | Train Loss 0.893369 | Val Loss 0.622577
# Epoch 1600 | Train Loss 0.892203 | Val Loss 0.627792
# Early stopping at epoch 1606
# Y | train1 -> R² = 0.6500, MSE = 2.9328e-02
# Y | train2 -> R² = 0.1662, MSE = 8.9779e-02
# Y | test1 -> R² = 0.7796, MSE = 1.8060e-02
# Y | test2 -> R² = 0.1613, MSE = 8.9027e-02
# Y | test3 -> R² = -1.3510, MSE = 1.8058e-01
# Y | val -> R² = -1.1731, MSE = 1.6179e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 1.469839 | Val Loss 0.865914
# Epoch 100 | Train Loss 1.034260 | Val Loss 0.700565
# Epoch 200 | Train Loss 0.929046 | Val Loss 0.788593
# Epoch 300 | Train Loss 0.914881 | Val Loss 0.693837
# Epoch 400 | Train Loss 0.907304 | Val Loss 0.645675
# Epoch 500 | Train Loss 0.905470 | Val Loss 0.643373
# Epoch 600 | Train Loss 0.904234 | Val Loss 0.638983
# Epoch 700 | Train Loss 0.903224 | Val Loss 0.632814
# Epoch 800 | Train Loss 0.902274 | Val Loss 0.627911
# Epoch 900 | Train Loss 0.901258 | Val Loss 0.623769
# Epoch 1000 | Train Loss 0.900207 | Val Loss 0.621742
# Epoch 1100 | Train Loss 0.899184 | Val Loss 0.622645
# Epoch 1200 | Train Loss 0.898184 | Val Loss 0.624629
# Early stopping at epoch 1259
# Y | train1 -> R² = 0.6383, MSE = 3.0311e-02
# Y | train2 -> R² = 0.1700, MSE = 8.9370e-02
# Y | test1 -> R² = 0.7550, MSE = 2.0074e-02
# Y | test2 -> R² = 0.1627, MSE = 8.8869e-02
# Y | test3 -> R² = -0.6842, MSE = 1.2936e-01
# Y | val -> R² = -0.8264, MSE = 1.3598e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 1.508809 | Val Loss 0.885414
# Epoch 100 | Train Loss 1.034137 | Val Loss 0.704643
# Epoch 200 | Train Loss 0.932413 | Val Loss 0.841768
# Epoch 300 | Train Loss 0.926133 | Val Loss 0.775145
# Early stopping at epoch 393
# Y | train1 -> R² = 0.8335, MSE = 1.3952e-02
# Y | train2 -> R² = -2.6085, MSE = 3.8855e-01
# Y | test1 -> R² = 0.7471, MSE = 2.0726e-02
# Y | test2 -> R² = -2.5218, MSE = 3.7382e-01
# Y | test3 -> R² = -0.0616, MSE = 8.1535e-02
# Y | val -> R² = 0.1910, MSE = 6.0230e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 1.409247 | Val Loss 0.816650
# Epoch 100 | Train Loss 0.986054 | Val Loss 0.724767
# Epoch 200 | Train Loss 0.918503 | Val Loss 0.718021
# Epoch 300 | Train Loss 0.908026 | Val Loss 0.660667
# Epoch 400 | Train Loss 0.905458 | Val Loss 0.655716
# Epoch 500 | Train Loss 0.903805 | Val Loss 0.646514
# Epoch 600 | Train Loss 0.902147 | Val Loss 0.635610
# Epoch 700 | Train Loss 0.900575 | Val Loss 0.627140
# Epoch 800 | Train Loss 0.899318 | Val Loss 0.622353
# Epoch 900 | Train Loss 0.898332 | Val Loss 0.620398
# Epoch 1000 | Train Loss 0.897561 | Val Loss 0.620840
# Epoch 1100 | Train Loss 0.896887 | Val Loss 0.622019
# Early stopping at epoch 1190
# Y | train1 -> R² = 0.6324, MSE = 3.0807e-02
# Y | train2 -> R² = 0.1713, MSE = 8.9231e-02
# Y | test1 -> R² = 0.7326, MSE = 2.1912e-02
# Y | test2 -> R² = 0.1609, MSE = 8.9059e-02
# Y | test3 -> R² = -1.2052, MSE = 1.6938e-01
# Y | val -> R² = -1.2818, MSE = 1.6988e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 1.221804 | Val Loss 0.811958
# Epoch 100 | Train Loss 0.733462 | Val Loss 0.893287
# Epoch 200 | Train Loss 0.681348 | Val Loss 0.736087
# Epoch 300 | Train Loss 0.670188 | Val Loss 0.694518
# Early stopping at epoch 374
# Y | train1 -> R² = 0.8955, MSE = 8.7533e-03
# Y | train2 -> R² = -2.9745, MSE = 4.2797e-01
# Y | test1 -> R² = 0.8323, MSE = 1.3740e-02
# Y | test2 -> R² = -2.8728, MSE = 4.1107e-01
# Y | test3 -> R² = -0.0592, MSE = 8.1355e-02
# Y | val -> R² = 0.0992, MSE = 6.7061e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.234980 | Val Loss 0.801513
# Epoch 100 | Train Loss 0.734599 | Val Loss 0.930865
# Epoch 200 | Train Loss 0.693603 | Val Loss 0.808955
# Epoch 300 | Train Loss 0.679978 | Val Loss 0.762377
# Early stopping at epoch 361
# Y | train1 -> R² = 0.8686, MSE = 1.1015e-02
# Y | train2 -> R² = -2.9411, MSE = 4.2437e-01
# Y | test1 -> R² = 0.7804, MSE = 1.7996e-02
# Y | test2 -> R² = -2.8461, MSE = 4.0823e-01
# Y | test3 -> R² = 0.2185, MSE = 6.0028e-02
# Y | val -> R² = 0.3075, MSE = 5.1554e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.252153 | Val Loss 0.834246
# Epoch 100 | Train Loss 0.738464 | Val Loss 0.916978
# Epoch 200 | Train Loss 0.692275 | Val Loss 0.803643
# Epoch 300 | Train Loss 0.676628 | Val Loss 0.723083
# Early stopping at epoch 367
# Y | train1 -> R² = 0.7521, MSE = 2.0773e-02
# Y | train2 -> R² = -4.4567, MSE = 5.8757e-01
# Y | test1 -> R² = 0.6337, MSE = 3.0019e-02
# Y | test2 -> R² = -4.3658, MSE = 5.6954e-01
# Y | test3 -> R² = 0.4610, MSE = 4.1402e-02
# Y | val -> R² = 0.5468, MSE = 3.3738e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.245312 | Val Loss 0.811346
# Epoch 100 | Train Loss 0.728890 | Val Loss 0.897275
# Epoch 200 | Train Loss 0.689749 | Val Loss 0.807009
# Epoch 300 | Train Loss 0.681246 | Val Loss 0.789246
# Early stopping at epoch 367
# Y | train1 -> R² = 0.8374, MSE = 1.3629e-02
# Y | train2 -> R² = -3.8035, MSE = 5.1723e-01
# Y | test1 -> R² = 0.7219, MSE = 2.2786e-02
# Y | test2 -> R² = -3.7132, MSE = 5.0027e-01
# Y | test3 -> R² = 0.1435, MSE = 6.5786e-02
# Y | val -> R² = 0.2895, MSE = 5.2900e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.252170 | Val Loss 0.838040
# Epoch 100 | Train Loss 0.770877 | Val Loss 0.740995
# Epoch 200 | Train Loss 0.693372 | Val Loss 0.803916
# Epoch 300 | Train Loss 0.680377 | Val Loss 0.737432
# Early stopping at epoch 385
# Y | train1 -> R² = 0.9171, MSE = 6.9457e-03
# Y | train2 -> R² = -3.0828, MSE = 4.3962e-01
# Y | test1 -> R² = 0.8601, MSE = 1.1463e-02
# Y | test2 -> R² = -2.9938, MSE = 4.2391e-01
# Y | test3 -> R² = -0.0671, MSE = 8.1963e-02
# Y | val -> R² = 0.1110, MSE = 6.6185e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.238925 | Val Loss 0.814561
# Epoch 100 | Train Loss 0.740165 | Val Loss 0.789737
# Epoch 200 | Train Loss 0.686800 | Val Loss 0.749931
# Epoch 300 | Train Loss 0.673131 | Val Loss 0.698028
# Early stopping at epoch 375
# Y | train1 -> R² = 0.3953, MSE = 5.0675e-02
# Y | train2 -> R² = -3.1856, MSE = 4.5070e-01
# Y | test1 -> R² = 0.1592, MSE = 6.8905e-02
# Y | test2 -> R² = -3.1067, MSE = 4.3590e-01
# Y | test3 -> R² = 0.9145, MSE = 6.5675e-03
# Y | val -> R² = 0.9562, MSE = 3.2616e-03
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.222703 | Val Loss 0.834239
# Epoch 100 | Train Loss 0.750671 | Val Loss 0.848374
# Epoch 200 | Train Loss 0.696045 | Val Loss 0.857351
# Epoch 300 | Train Loss 0.685539 | Val Loss 0.789090
# Early stopping at epoch 373
# Y | train1 -> R² = 0.7449, MSE = 2.1379e-02
# Y | train2 -> R² = -4.0329, MSE = 5.4193e-01
# Y | test1 -> R² = 0.6075, MSE = 3.2164e-02
# Y | test2 -> R² = -3.9497, MSE = 5.2538e-01
# Y | test3 -> R² = 0.5458, MSE = 3.4886e-02
# Y | val -> R² = 0.6690, MSE = 2.4646e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.203342 | Val Loss 0.820554
# Epoch 100 | Train Loss 0.733373 | Val Loss 0.855634
# Epoch 200 | Train Loss 0.689641 | Val Loss 0.802137
# Epoch 300 | Train Loss 0.680464 | Val Loss 0.778704
# Early stopping at epoch 372
# Y | train1 -> R² = 0.4548, MSE = 4.5684e-02
# Y | train2 -> R² = -2.5011, MSE = 3.7699e-01
# Y | test1 -> R² = 0.2323, MSE = 6.2911e-02
# Y | test2 -> R² = -2.4140, MSE = 3.6237e-01
# Y | test3 -> R² = 0.9007, MSE = 7.6255e-03
# Y | val -> R² = 0.9469, MSE = 3.9564e-03
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.271018 | Val Loss 0.865619
# Epoch 100 | Train Loss 0.824039 | Val Loss 0.699833
# Epoch 200 | Train Loss 0.696813 | Val Loss 0.850747
# Epoch 300 | Train Loss 0.677780 | Val Loss 0.694060
# Epoch 400 | Train Loss 0.669074 | Val Loss 0.648641
# Epoch 500 | Train Loss 0.665386 | Val Loss 0.640402
# Epoch 600 | Train Loss 0.662854 | Val Loss 0.637423
# Epoch 700 | Train Loss 0.660504 | Val Loss 0.635528
# Epoch 800 | Train Loss 0.658520 | Val Loss 0.633741
# Epoch 900 | Train Loss 0.656835 | Val Loss 0.633930
# Epoch 1000 | Train Loss 0.655105 | Val Loss 0.635924
# Epoch 1100 | Train Loss 0.653286 | Val Loss 0.638279
# Early stopping at epoch 1118
# Y | train1 -> R² = 0.3000, MSE = 5.8660e-02
# Y | train2 -> R² = -0.5952, MSE = 1.7177e-01
# Y | test1 -> R² = 0.4961, MSE = 4.1291e-02
# Y | test2 -> R² = -0.6050, MSE = 1.7036e-01
# Y | test3 -> R² = -0.8631, MSE = 1.4310e-01
# Y | val -> R² = -0.9244, MSE = 1.4327e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.203827 | Val Loss 0.809364
# Epoch 100 | Train Loss 0.727737 | Val Loss 0.941212
# Epoch 200 | Train Loss 0.691318 | Val Loss 0.835335
# Epoch 300 | Train Loss 0.677945 | Val Loss 0.752198
# Early stopping at epoch 364
# Y | train1 -> R² = 0.7829, MSE = 1.8195e-02
# Y | train2 -> R² = -4.4634, MSE = 5.8829e-01
# Y | test1 -> R² = 0.6783, MSE = 2.6360e-02
# Y | test2 -> R² = -4.3754, MSE = 5.7056e-01
# Y | test3 -> R² = 0.3503, MSE = 4.9898e-02
# Y | val -> R² = 0.5287, MSE = 3.5085e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.221376 | Val Loss 0.825243
# Epoch 100 | Train Loss 0.744159 | Val Loss 0.892901
# Epoch 200 | Train Loss 0.695829 | Val Loss 0.930579
# Epoch 300 | Train Loss 0.684968 | Val Loss 0.813185
# Early stopping at epoch 372
# Y | train1 -> R² = 0.8025, MSE = 1.6553e-02
# Y | train2 -> R² = -4.4932, MSE = 5.9150e-01
# Y | test1 -> R² = 0.6831, MSE = 2.5972e-02
# Y | test2 -> R² = -4.4116, MSE = 5.7440e-01
# Y | test3 -> R² = 0.2652, MSE = 5.6437e-02
# Y | val -> R² = 0.4635, MSE = 3.9941e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.227315 | Val Loss 0.817899
# Epoch 100 | Train Loss 0.736487 | Val Loss 0.922681
# Epoch 200 | Train Loss 0.689069 | Val Loss 0.793374
# Epoch 300 | Train Loss 0.678026 | Val Loss 0.723084
# Early stopping at epoch 368
# Y | train1 -> R² = 0.7472, MSE = 2.1186e-02
# Y | train2 -> R² = -3.4073, MSE = 4.7457e-01
# Y | test1 -> R² = 0.6368, MSE = 2.9764e-02
# Y | test2 -> R² = -3.3161, MSE = 4.5812e-01
# Y | test3 -> R² = 0.4489, MSE = 4.2327e-02
# Y | val -> R² = 0.5586, MSE = 3.2863e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.244022 | Val Loss 0.829683
# Epoch 100 | Train Loss 0.730264 | Val Loss 0.925503
# Epoch 200 | Train Loss 0.691947 | Val Loss 0.812358
# Epoch 300 | Train Loss 0.681771 | Val Loss 0.777046
# Early stopping at epoch 372
# Y | train1 -> R² = 0.8260, MSE = 1.4585e-02
# Y | train2 -> R² = -3.2550, MSE = 4.5817e-01
# Y | test1 -> R² = 0.7155, MSE = 2.3316e-02
# Y | test2 -> R² = -3.1612, MSE = 4.4168e-01
# Y | test3 -> R² = 0.2211, MSE = 5.9828e-02
# Y | val -> R² = 0.3192, MSE = 5.0687e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.215373 | Val Loss 0.811973
# Epoch 100 | Train Loss 0.723208 | Val Loss 0.926882
# Epoch 200 | Train Loss 0.690209 | Val Loss 0.786645
# Epoch 300 | Train Loss 0.675735 | Val Loss 0.694005
# Early stopping at epoch 364
# Y | train1 -> R² = 0.7182, MSE = 2.3614e-02
# Y | train2 -> R² = -4.0503, MSE = 5.4381e-01
# Y | test1 -> R² = 0.5778, MSE = 3.4596e-02
# Y | test2 -> R² = -3.9587, MSE = 5.2633e-01
# Y | test3 -> R² = 0.5534, MSE = 3.4301e-02
# Y | val -> R² = 0.6514, MSE = 2.5957e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.256612 | Val Loss 0.849005
# Epoch 100 | Train Loss 0.791836 | Val Loss 0.744761
# Epoch 200 | Train Loss 0.696752 | Val Loss 0.882987
# Epoch 300 | Train Loss 0.684486 | Val Loss 0.822867
# Early stopping at epoch 385
# Y | train1 -> R² = 0.6807, MSE = 2.6759e-02
# Y | train2 -> R² = -3.5628, MSE = 4.9131e-01
# Y | test1 -> R² = 0.5330, MSE = 3.8269e-02
# Y | test2 -> R² = -3.4754, MSE = 4.7503e-01
# Y | test3 -> R² = 0.5770, MSE = 3.2490e-02
# Y | val -> R² = 0.7019, MSE = 2.2190e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.240659 | Val Loss 0.839952
# Epoch 100 | Train Loss 0.737421 | Val Loss 0.916027
# Epoch 200 | Train Loss 0.693879 | Val Loss 0.832875
# Epoch 300 | Train Loss 0.686148 | Val Loss 0.817921
# Early stopping at epoch 370
# Y | train1 -> R² = 0.7661, MSE = 1.9599e-02
# Y | train2 -> R² = -3.4261, MSE = 4.7660e-01
# Y | test1 -> R² = 0.6381, MSE = 2.9660e-02
# Y | test2 -> R² = -3.3361, MSE = 4.6025e-01
# Y | test3 -> R² = 0.4909, MSE = 3.9099e-02
# Y | val -> R² = 0.6036, MSE = 2.9510e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 1.224137 | Val Loss 0.840131
# Epoch 100 | Train Loss 0.755162 | Val Loss 0.781625
# Epoch 200 | Train Loss 0.693876 | Val Loss 0.837814
# Epoch 300 | Train Loss 0.681526 | Val Loss 0.751405
# Early stopping at epoch 384
# Y | train1 -> R² = 0.8060, MSE = 1.6260e-02
# Y | train2 -> R² = -3.0445, MSE = 4.3551e-01
# Y | test1 -> R² = 0.6719, MSE = 2.6884e-02
# Y | test2 -> R² = -2.9541, MSE = 4.1970e-01
# Y | test3 -> R² = 0.5728, MSE = 3.2812e-02
# Y | val -> R² = 0.6644, MSE = 2.4988e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 1.211868 | Val Loss 0.816043
# Epoch 100 | Train Loss 0.734654 | Val Loss 0.956019
# Epoch 200 | Train Loss 0.693426 | Val Loss 0.842986
# Epoch 300 | Train Loss 0.683096 | Val Loss 0.793013
# Early stopping at epoch 370
# Y | train1 -> R² = 0.7392, MSE = 2.1854e-02
# Y | train2 -> R² = -3.2739, MSE = 4.6020e-01
# Y | test1 -> R² = 0.6048, MSE = 3.2386e-02
# Y | test2 -> R² = -3.1798, MSE = 4.4366e-01
# Y | test3 -> R² = 0.4191, MSE = 4.4618e-02
# Y | val -> R² = 0.5375, MSE = 3.4435e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 1.233415 | Val Loss 0.842075
# Epoch 100 | Train Loss 0.754969 | Val Loss 0.816073
# Epoch 200 | Train Loss 0.697937 | Val Loss 0.898415
# Epoch 300 | Train Loss 0.683748 | Val Loss 0.788750
# Early stopping at epoch 374
# Y | train1 -> R² = 0.7182, MSE = 2.3615e-02
# Y | train2 -> R² = -3.8930, MSE = 5.2687e-01
# Y | test1 -> R² = 0.5865, MSE = 3.3886e-02
# Y | test2 -> R² = -3.8009, MSE = 5.0958e-01
# Y | test3 -> R² = 0.5067, MSE = 3.7888e-02
# Y | val -> R² = 0.6288, MSE = 2.7636e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 1.203003 | Val Loss 0.788240
# Epoch 100 | Train Loss 0.742121 | Val Loss 0.864464
# Epoch 200 | Train Loss 0.692934 | Val Loss 0.854414
# Epoch 300 | Train Loss 0.676450 | Val Loss 0.705064
# Epoch 400 | Train Loss 0.669429 | Val Loss 0.669446
# Epoch 500 | Train Loss 0.665862 | Val Loss 0.668675
# Epoch 600 | Train Loss 0.663023 | Val Loss 0.662813
# Epoch 700 | Train Loss 0.660401 | Val Loss 0.661849
# Epoch 800 | Train Loss 0.657920 | Val Loss 0.662767
# Epoch 900 | Train Loss 0.655762 | Val Loss 0.666214
# Early stopping at epoch 938
# Y | train1 -> R² = 0.3186, MSE = 5.7096e-02
# Y | train2 -> R² = -0.5614, MSE = 1.6813e-01
# Y | test1 -> R² = 0.5161, MSE = 3.9653e-02
# Y | test2 -> R² = -0.5825, MSE = 1.6797e-01
# Y | test3 -> R² = -2.5767, MSE = 2.7471e-01
# Y | val -> R² = -2.1862, MSE = 2.3721e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 1.198193 | Val Loss 0.799487
# Epoch 100 | Train Loss 0.731436 | Val Loss 0.860949
# Epoch 200 | Train Loss 0.681867 | Val Loss 0.731047
# Epoch 300 | Train Loss 0.669425 | Val Loss 0.668781
# Epoch 400 | Train Loss 0.666472 | Val Loss 0.664194
# Epoch 500 | Train Loss 0.664133 | Val Loss 0.666628
# Epoch 600 | Train Loss 0.661475 | Val Loss 0.670928
# Early stopping at epoch 653
# Y | train1 -> R² = 0.3164, MSE = 5.7281e-02
# Y | train2 -> R² = -0.5444, MSE = 1.6630e-01
# Y | test1 -> R² = 0.4542, MSE = 4.4730e-02
# Y | test2 -> R² = -0.5627, MSE = 1.6587e-01
# Y | test3 -> R² = -3.2232, MSE = 3.2438e-01
# Y | val -> R² = -3.3649, MSE = 3.2497e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.237190 | Val Loss 0.823527
# Epoch 100 | Train Loss 0.729929 | Val Loss 0.896141
# Epoch 200 | Train Loss 0.692129 | Val Loss 0.815911
# Epoch 300 | Train Loss 0.681214 | Val Loss 0.759886
# Early stopping at epoch 370
# Y | train1 -> R² = 0.7908, MSE = 1.7534e-02
# Y | train2 -> R² = -3.7040, MSE = 5.0652e-01
# Y | test1 -> R² = 0.6716, MSE = 2.6911e-02
# Y | test2 -> R² = -3.6081, MSE = 4.8912e-01
# Y | test3 -> R² = 0.4349, MSE = 4.3406e-02
# Y | val -> R² = 0.5176, MSE = 3.5916e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.230973 | Val Loss 0.800532
# Epoch 100 | Train Loss 0.724262 | Val Loss 0.908279
# Epoch 200 | Train Loss 0.688621 | Val Loss 0.772623
# Epoch 300 | Train Loss 0.681081 | Val Loss 0.746689
# Early stopping at epoch 367
# Y | train1 -> R² = 0.7189, MSE = 2.3552e-02
# Y | train2 -> R² = -3.4551, MSE = 4.7971e-01
# Y | test1 -> R² = 0.5796, MSE = 3.4448e-02
# Y | test2 -> R² = -3.3610, MSE = 4.6289e-01
# Y | test3 -> R² = 0.5458, MSE = 3.4886e-02
# Y | val -> R² = 0.6305, MSE = 2.7512e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.213342 | Val Loss 0.808355
# Epoch 100 | Train Loss 0.729160 | Val Loss 0.913025
# Epoch 200 | Train Loss 0.692549 | Val Loss 0.792197
# Epoch 300 | Train Loss 0.683011 | Val Loss 0.751106
# Early stopping at epoch 364
# Y | train1 -> R² = 0.7123, MSE = 2.4107e-02
# Y | train2 -> R² = -2.9491, MSE = 4.2523e-01
# Y | test1 -> R² = 0.5823, MSE = 3.4229e-02
# Y | test2 -> R² = -2.8526, MSE = 4.0893e-01
# Y | test3 -> R² = 0.5976, MSE = 3.0909e-02
# Y | val -> R² = 0.6798, MSE = 2.3840e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.241762 | Val Loss 0.857652
# Epoch 100 | Train Loss 0.791434 | Val Loss 0.722038
# Epoch 200 | Train Loss 0.696946 | Val Loss 0.834753
# Epoch 300 | Train Loss 0.687420 | Val Loss 0.794504
# Early stopping at epoch 383
# Y | train1 -> R² = 0.3440, MSE = 5.4968e-02
# Y | train2 -> R² = -3.8908, MSE = 5.2663e-01
# Y | test1 -> R² = 0.1076, MSE = 7.3134e-02
# Y | test2 -> R² = -3.8020, MSE = 5.0969e-01
# Y | test3 -> R² = 0.8861, MSE = 8.7463e-03
# Y | val -> R² = 0.9468, MSE = 3.9599e-03
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.251703 | Val Loss 0.808652
# Epoch 100 | Train Loss 0.737058 | Val Loss 0.858187
# Epoch 200 | Train Loss 0.690941 | Val Loss 0.763887
# Epoch 300 | Train Loss 0.679295 | Val Loss 0.710647
# Early stopping at epoch 369
# Y | train1 -> R² = 0.7855, MSE = 1.7974e-02
# Y | train2 -> R² = -3.7530, MSE = 5.1180e-01
# Y | test1 -> R² = 0.6634, MSE = 2.7585e-02
# Y | test2 -> R² = -3.6639, MSE = 4.9504e-01
# Y | test3 -> R² = 0.5265, MSE = 3.6369e-02
# Y | val -> R² = 0.5984, MSE = 2.9899e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 1.199926 | Val Loss 0.808858
# Epoch 100 | Train Loss 0.728086 | Val Loss 0.943040
# Epoch 200 | Train Loss 0.691470 | Val Loss 0.817745
# Epoch 300 | Train Loss 0.682143 | Val Loss 0.745152
# Early stopping at epoch 370
# Y | train1 -> R² = 0.7061, MSE = 2.4629e-02
# Y | train2 -> R² = -2.8149, MSE = 4.1078e-01
# Y | test1 -> R² = 0.5571, MSE = 3.6291e-02
# Y | test2 -> R² = -2.7238, MSE = 3.9526e-01
# Y | test3 -> R² = 0.6482, MSE = 2.7023e-02
# Y | val -> R² = 0.7383, MSE = 1.9485e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 1.218324 | Val Loss 0.815914
# Epoch 100 | Train Loss 0.734054 | Val Loss 0.879930
# Epoch 200 | Train Loss 0.689720 | Val Loss 0.808057
# Epoch 300 | Train Loss 0.677037 | Val Loss 0.750251
# Early stopping at epoch 373
# Y | train1 -> R² = 0.6841, MSE = 2.6468e-02
# Y | train2 -> R² = -3.6263, MSE = 4.9816e-01
# Y | test1 -> R² = 0.5368, MSE = 3.7956e-02
# Y | test2 -> R² = -3.5334, MSE = 4.8118e-01
# Y | test3 -> R² = 0.6430, MSE = 2.7423e-02
# Y | val -> R² = 0.7555, MSE = 1.8202e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 1.244879 | Val Loss 0.850900
# Epoch 100 | Train Loss 0.738669 | Val Loss 0.841480
# Epoch 200 | Train Loss 0.694680 | Val Loss 0.839647
# Epoch 300 | Train Loss 0.685278 | Val Loss 0.752843
# Early stopping at epoch 376
# Y | train1 -> R² = 0.8433, MSE = 1.3131e-02
# Y | train2 -> R² = -3.0749, MSE = 4.3878e-01
# Y | test1 -> R² = 0.7426, MSE = 2.1092e-02
# Y | test2 -> R² = -2.9778, MSE = 4.2222e-01
# Y | test3 -> R² = 0.0923, MSE = 6.9721e-02
# Y | val -> R² = 0.2446, MSE = 5.6238e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 1.208069 | Val Loss 0.806952
# Epoch 100 | Train Loss 0.730634 | Val Loss 0.972904
# Epoch 200 | Train Loss 0.691635 | Val Loss 0.826317
# Epoch 300 | Train Loss 0.675455 | Val Loss 0.727455
# Early stopping at epoch 360
# Y | train1 -> R² = 0.8407, MSE = 1.3349e-02
# Y | train2 -> R² = -3.7319, MSE = 5.0952e-01
# Y | test1 -> R² = 0.7625, MSE = 1.9460e-02
# Y | test2 -> R² = -3.6398, MSE = 4.9248e-01
# Y | test3 -> R² = 0.1242, MSE = 6.7269e-02
# Y | val -> R² = 0.3120, MSE = 5.1224e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 1.627480 | Val Loss 0.831833
# Epoch 100 | Train Loss 1.295978 | Val Loss 0.765538
# Epoch 200 | Train Loss 1.048269 | Val Loss 0.639546
# Epoch 300 | Train Loss 1.038830 | Val Loss 0.622841
# Epoch 400 | Train Loss 1.036163 | Val Loss 0.616832
# Epoch 500 | Train Loss 1.034467 | Val Loss 0.612571
# Epoch 600 | Train Loss 1.033246 | Val Loss 0.607994
# Epoch 700 | Train Loss 1.032316 | Val Loss 0.602437
# Epoch 800 | Train Loss 1.031483 | Val Loss 0.596632
# Epoch 900 | Train Loss 1.030643 | Val Loss 0.591204
# Epoch 1000 | Train Loss 1.029765 | Val Loss 0.587139
# Epoch 1100 | Train Loss 1.028884 | Val Loss 0.584816
# Epoch 1200 | Train Loss 1.027987 | Val Loss 0.583783
# Epoch 1300 | Train Loss 1.027009 | Val Loss 0.583430
# Epoch 1400 | Train Loss 1.025915 | Val Loss 0.583141
# Epoch 1500 | Train Loss 1.024712 | Val Loss 0.582682
# Epoch 1600 | Train Loss 1.023353 | Val Loss 0.582094
# Epoch 1700 | Train Loss 1.021657 | Val Loss 0.581371
# Epoch 1800 | Train Loss 1.019602 | Val Loss 0.580026
# Epoch 1900 | Train Loss 1.017312 | Val Loss 0.579046
# Epoch 2000 | Train Loss 1.014933 | Val Loss 0.579811
# Epoch 2100 | Train Loss 1.012671 | Val Loss 0.582487
# Early stopping at epoch 2144
# Y | train1 -> R² = 0.8745, MSE = 1.0520e-02
# Y | train2 -> R² = 0.6846, MSE = 3.3961e-02
# Y | test1 -> R² = 0.9085, MSE = 7.5017e-03
# Y | test2 -> R² = 0.6587, MSE = 3.6230e-02
# Y | test3 -> R² = 0.8068, MSE = 1.4840e-02
# Y | val -> R² = 0.3212, MSE = 5.0537e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.679608 | Val Loss 0.810733
# Epoch 100 | Train Loss 1.180002 | Val Loss 0.747801
# Epoch 200 | Train Loss 1.056768 | Val Loss 0.703275
# Epoch 300 | Train Loss 1.045250 | Val Loss 0.646131
# Epoch 400 | Train Loss 1.041415 | Val Loss 0.635874
# ...
# Y | val -> R² = 0.9860, MSE = 1.0459e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.567088 | Val Loss 0.810149
# Epoch 100 | Train Loss 1.344668 | Val Loss 0.761533
# Epoch 200 | Train Loss 1.194411 | Val Loss 0.692720
# Epoch 300 | Train Loss 1.137575 | Val Loss 0.655341
# Epoch 400 | Train Loss 1.070526 | Val Loss 0.617066
# Epoch 500 | Train Loss 1.047059 | Val Loss 0.586819
# Epoch 600 | Train Loss 1.039687 | Val Loss 0.580526
# Epoch 700 | Train Loss 1.036895 | Val Loss 0.578177
# Epoch 800 | Train Loss 1.035390 | Val Loss 0.576268
# Epoch 900 | Train Loss 1.034370 | Val Loss 0.574709
# Epoch 1000 | Train Loss 1.033594 | Val Loss 0.573465
# Epoch 1100 | Train Loss 1.032941 | Val Loss 0.572520
# Epoch 1200 | Train Loss 1.032351 | Val Loss 0.571909
# Epoch 1300 | Train Loss 1.031803 | Val Loss 0.571648
# Early stopping at epoch 1396
# Y | train1 -> R² = 0.8648, MSE = 1.1333e-02
# Y | train2 -> R² = 0.6719, MSE = 3.5332e-02
# Y | test1 -> R² = 0.8919, MSE = 8.8566e-03
# Y | test2 -> R² = 0.6736, MSE = 3.4647e-02
# Y | test3 -> R² = 0.9874, MSE = 9.6648e-04
# Y | val -> R² = 0.8435, MSE = 1.1653e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.567163 | Val Loss 0.811213
# Epoch 100 | Train Loss 1.355284 | Val Loss 0.767160
# Epoch 200 | Train Loss 1.191649 | Val Loss 0.699029
# Epoch 300 | Train Loss 1.108126 | Val Loss 0.641397
# Epoch 400 | Train Loss 1.065100 | Val Loss 0.607336
# Epoch 500 | Train Loss 1.046727 | Val Loss 0.588841
# Epoch 600 | Train Loss 1.039772 | Val Loss 0.585473
# Epoch 700 | Train Loss 1.036851 | Val Loss 0.582947
# Epoch 800 | Train Loss 1.034995 | Val Loss 0.579353
# Epoch 900 | Train Loss 1.033313 | Val Loss 0.575645
# Epoch 1000 | Train Loss 1.032479 | Val Loss 0.574683
# Epoch 1100 | Train Loss 1.031805 | Val Loss 0.574670
# Epoch 1200 | Train Loss 1.031237 | Val Loss 0.575064
# Early stopping at epoch 1268
# Y | train1 -> R² = 0.8768, MSE = 1.0323e-02
# Y | train2 -> R² = 0.6893, MSE = 3.3459e-02
# Y | test1 -> R² = 0.9100, MSE = 7.3779e-03
# Y | test2 -> R² = 0.6874, MSE = 3.3177e-02
# Y | test3 -> R² = 0.8370, MSE = 1.2523e-02
# Y | val -> R² = 0.6212, MSE = 2.8201e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.568270 | Val Loss 0.810597
# Epoch 100 | Train Loss 1.311988 | Val Loss 0.749669
# Epoch 200 | Train Loss 1.239746 | Val Loss 0.740824
# Epoch 300 | Train Loss 1.231644 | Val Loss 0.736559
# Epoch 400 | Train Loss 1.229035 | Val Loss 0.735884
# Epoch 500 | Train Loss 1.227307 | Val Loss 0.737046
# Epoch 600 | Train Loss 1.225578 | Val Loss 0.738683
# Early stopping at epoch 631
# Y | train1 -> R² = -1.3237, MSE = 1.9471e-01
# Y | train2 -> R² = -3.7055, MSE = 5.0668e-01
# Y | test1 -> R² = -1.1571, MSE = 1.7677e-01
# Y | test2 -> R² = -3.9624, MSE = 5.2672e-01
# Y | test3 -> R² = -9.8640, MSE = 8.3443e-01
# Y | val -> R² = -7.1335, MSE = 6.0554e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.566790 | Val Loss 0.818790
# Epoch 100 | Train Loss 1.299207 | Val Loss 0.800163
# Epoch 200 | Train Loss 1.238764 | Val Loss 0.737784
# Epoch 300 | Train Loss 1.231211 | Val Loss 0.734920
# Epoch 400 | Train Loss 1.228950 | Val Loss 0.734722
# Epoch 500 | Train Loss 1.226490 | Val Loss 0.735985
# Epoch 600 | Train Loss 1.224455 | Val Loss 0.737909
# Early stopping at epoch 613
# Y | train1 -> R² = -1.2920, MSE = 1.9206e-01
# Y | train2 -> R² = -3.7222, MSE = 5.0848e-01
# Y | test1 -> R² = -1.1255, MSE = 1.7418e-01
# Y | test2 -> R² = -3.9736, MSE = 5.2791e-01
# Y | test3 -> R² = -9.7464, MSE = 8.2540e-01
# Y | val -> R² = -7.0508, MSE = 5.9938e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.566464 | Val Loss 0.807475
# Epoch 100 | Train Loss 1.282125 | Val Loss 0.755313
# Epoch 200 | Train Loss 1.236841 | Val Loss 0.737481
# Epoch 300 | Train Loss 1.230494 | Val Loss 0.735353
# Epoch 400 | Train Loss 1.227960 | Val Loss 0.734504
# Epoch 500 | Train Loss 1.212728 | Val Loss 0.719339
# Epoch 600 | Train Loss 1.142044 | Val Loss 0.666168
# Epoch 700 | Train Loss 1.073951 | Val Loss 0.598502
# Epoch 800 | Train Loss 1.052861 | Val Loss 0.576882
# Epoch 900 | Train Loss 1.044767 | Val Loss 0.572388
# Epoch 1000 | Train Loss 1.041121 | Val Loss 0.571696
# Epoch 1100 | Train Loss 1.039082 | Val Loss 0.571244
# Epoch 1200 | Train Loss 1.036348 | Val Loss 0.571433
# Epoch 1300 | Train Loss 1.032961 | Val Loss 0.571634
# Early stopping at epoch 1348
# Y | train1 -> R² = 0.8660, MSE = 1.1226e-02
# Y | train2 -> R² = 0.6342, MSE = 3.9391e-02
# Y | test1 -> R² = 0.8825, MSE = 9.6330e-03
# Y | test2 -> R² = 0.6266, MSE = 3.9631e-02
# Y | test3 -> R² = 0.9419, MSE = 4.4654e-03
# Y | val -> R² = 0.8169, MSE = 1.3634e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.568694 | Val Loss 0.811325
# Epoch 100 | Train Loss 1.293316 | Val Loss 0.742829
# Epoch 200 | Train Loss 1.233498 | Val Loss 0.740327
# Epoch 300 | Train Loss 1.225330 | Val Loss 0.736876
# Epoch 400 | Train Loss 1.213222 | Val Loss 0.722547
# Epoch 500 | Train Loss 1.180458 | Val Loss 0.687512
# Epoch 600 | Train Loss 1.115113 | Val Loss 0.636104
# Epoch 700 | Train Loss 1.060054 | Val Loss 0.601873
# Epoch 800 | Train Loss 1.044392 | Val Loss 0.585974
# Epoch 900 | Train Loss 1.040461 | Val Loss 0.581815
# Epoch 1000 | Train Loss 1.037883 | Val Loss 0.580342
# Epoch 1100 | Train Loss 1.035952 | Val Loss 0.579196
# Epoch 1200 | Train Loss 1.034632 | Val Loss 0.578038
# Epoch 1300 | Train Loss 1.033655 | Val Loss 0.577338
# Epoch 1400 | Train Loss 1.032825 | Val Loss 0.577198
# Early stopping at epoch 1492
# Y | train1 -> R² = 0.8773, MSE = 1.0285e-02
# Y | train2 -> R² = 0.6786, MSE = 3.4612e-02
# Y | test1 -> R² = 0.9018, MSE = 8.0501e-03
# Y | test2 -> R² = 0.6797, MSE = 3.4001e-02
# Y | test3 -> R² = 0.9657, MSE = 2.6315e-03
# Y | val -> R² = 0.8301, MSE = 1.2647e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.565836 | Val Loss 0.815136
# Epoch 100 | Train Loss 1.305211 | Val Loss 0.749523
# Epoch 200 | Train Loss 1.152405 | Val Loss 0.675860
# Epoch 300 | Train Loss 1.124400 | Val Loss 0.665938
# Epoch 400 | Train Loss 1.117211 | Val Loss 0.666529
# Epoch 500 | Train Loss 1.113174 | Val Loss 0.667183
# Early stopping at epoch 583
# Y | train1 -> R² = 0.8334, MSE = 1.3962e-02
# Y | train2 -> R² = 0.6368, MSE = 3.9110e-02
# Y | test1 -> R² = 0.8478, MSE = 1.2475e-02
# Y | test2 -> R² = 0.6209, MSE = 4.0235e-02
# Y | test3 -> R² = -0.4425, MSE = 1.1079e-01
# Y | val -> R² = 0.0239, MSE = 7.2670e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.565856 | Val Loss 0.814093
# Epoch 100 | Train Loss 1.296555 | Val Loss 0.778766
# Epoch 200 | Train Loss 1.237704 | Val Loss 0.737696
# Epoch 300 | Train Loss 1.230633 | Val Loss 0.735334
# Epoch 400 | Train Loss 1.227652 | Val Loss 0.736290
# Epoch 500 | Train Loss 1.225102 | Val Loss 0.737642
# Early stopping at epoch 551
# Y | train1 -> R² = -1.3226, MSE = 1.9462e-01
# Y | train2 -> R² = -3.8166, MSE = 5.1864e-01
# Y | test1 -> R² = -1.1661, MSE = 1.7751e-01
# Y | test2 -> R² = -4.0730, MSE = 5.3846e-01
# Y | test3 -> R² = -9.8212, MSE = 8.3115e-01
# Y | val -> R² = -7.1781, MSE = 6.0886e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.564852 | Val Loss 0.810366
# Epoch 100 | Train Loss 1.297038 | Val Loss 0.748329
# Epoch 200 | Train Loss 1.213041 | Val Loss 0.716259
# Epoch 300 | Train Loss 1.163836 | Val Loss 0.676014
# Epoch 400 | Train Loss 1.123621 | Val Loss 0.661959
# Epoch 500 | Train Loss 1.114006 | Val Loss 0.664688
# Epoch 600 | Train Loss 1.110781 | Val Loss 0.663822
# Early stopping at epoch 653
# Y | train1 -> R² = 0.8291, MSE = 1.4324e-02
# Y | train2 -> R² = 0.6412, MSE = 3.8634e-02
# Y | test1 -> R² = 0.8199, MSE = 1.4755e-02
# Y | test2 -> R² = 0.6262, MSE = 3.9680e-02
# Y | test3 -> R² = 0.2124, MSE = 6.0494e-02
# Y | val -> R² = 0.5412, MSE = 3.4156e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.565394 | Val Loss 0.811334
# Epoch 100 | Train Loss 1.288274 | Val Loss 0.740277
# Epoch 200 | Train Loss 1.234607 | Val Loss 0.736543
# Epoch 300 | Train Loss 1.229656 | Val Loss 0.735572
# Epoch 400 | Train Loss 1.226340 | Val Loss 0.737687
# Epoch 500 | Train Loss 1.224418 | Val Loss 0.738389
# Early stopping at epoch 506
# Y | train1 -> R² = -1.3320, MSE = 1.9541e-01
# Y | train2 -> R² = -3.8474, MSE = 5.2196e-01
# Y | test1 -> R² = -1.1863, MSE = 1.7916e-01
# Y | test2 -> R² = -4.1048, MSE = 5.4184e-01
# Y | test3 -> R² = -9.7924, MSE = 8.2894e-01
# Y | val -> R² = -7.2164, MSE = 6.1171e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.560136 | Val Loss 0.805064
# Epoch 100 | Train Loss 1.335410 | Val Loss 0.761741
# Epoch 200 | Train Loss 1.215149 | Val Loss 0.718376
# Epoch 300 | Train Loss 1.108843 | Val Loss 0.624014
# Epoch 400 | Train Loss 1.071529 | Val Loss 0.593755
# Epoch 500 | Train Loss 1.056873 | Val Loss 0.581805
# Epoch 600 | Train Loss 1.045443 | Val Loss 0.597279
# Epoch 700 | Train Loss 1.040475 | Val Loss 0.624465
# Early stopping at epoch 789
# Y | train1 -> R² = 0.9179, MSE = 6.8814e-03
# Y | train2 -> R² = 0.6438, MSE = 3.8350e-02
# Y | test1 -> R² = 0.9173, MSE = 6.7763e-03
# Y | test2 -> R² = 0.6311, MSE = 3.9151e-02
# Y | test3 -> R² = 0.5772, MSE = 3.2472e-02
# Y | val -> R² = 0.5152, MSE = 3.6093e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 1.569226 | Val Loss 0.813435
# Epoch 100 | Train Loss 1.315443 | Val Loss 0.743317
# Epoch 200 | Train Loss 1.235031 | Val Loss 0.735959
# Epoch 300 | Train Loss 1.199538 | Val Loss 0.699150
# Epoch 400 | Train Loss 1.150670 | Val Loss 0.670307
# Epoch 500 | Train Loss 1.093069 | Val Loss 0.617100
# Epoch 600 | Train Loss 1.059466 | Val Loss 0.593083
# Epoch 700 | Train Loss 1.048791 | Val Loss 0.594045
# Epoch 800 | Train Loss 1.045230 | Val Loss 0.593761
# Epoch 900 | Train Loss 1.042987 | Val Loss 0.590571
# Epoch 1000 | Train Loss 1.041206 | Val Loss 0.586730
# Epoch 1100 | Train Loss 1.039467 | Val Loss 0.582792
# Epoch 1200 | Train Loss 1.037581 | Val Loss 0.579394
# Epoch 1300 | Train Loss 1.035673 | Val Loss 0.577925
# Epoch 1400 | Train Loss 1.033991 | Val Loss 0.577579
# Epoch 1500 | Train Loss 1.032769 | Val Loss 0.576900
# Epoch 1600 | Train Loss 1.031959 | Val Loss 0.576120
# Epoch 1700 | Train Loss 1.031394 | Val Loss 0.575758
# Epoch 1800 | Train Loss 1.030950 | Val Loss 0.575710
# Early stopping at epoch 1845
# Y | train1 -> R² = 0.8743, MSE = 1.0532e-02
# Y | train2 -> R² = 0.6739, MSE = 3.5117e-02
# Y | test1 -> R² = 0.9005, MSE = 8.1505e-03
# Y | test2 -> R² = 0.6732, MSE = 3.4689e-02
# Y | test3 -> R² = 0.8875, MSE = 8.6417e-03
# Y | val -> R² = 0.9892, MSE = 8.0247e-04
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 1.567529 | Val Loss 0.811528
# Epoch 100 | Train Loss 1.309136 | Val Loss 0.742075
# Epoch 200 | Train Loss 1.224269 | Val Loss 0.721563
# Epoch 300 | Train Loss 1.187378 | Val Loss 0.688310
# Epoch 400 | Train Loss 1.132542 | Val Loss 0.650851
# Epoch 500 | Train Loss 1.086740 | Val Loss 0.639716
# Epoch 600 | Train Loss 1.063222 | Val Loss 0.637888
# Epoch 700 | Train Loss 1.053032 | Val Loss 0.635579
# Epoch 800 | Train Loss 1.046454 | Val Loss 0.613109
# Epoch 900 | Train Loss 1.042005 | Val Loss 0.593912
# Epoch 1000 | Train Loss 1.039452 | Val Loss 0.586558
# Epoch 1100 | Train Loss 1.037796 | Val Loss 0.583699
# Epoch 1200 | Train Loss 1.036519 | Val Loss 0.581546
# Epoch 1300 | Train Loss 1.035490 | Val Loss 0.579625
# Epoch 1400 | Train Loss 1.034603 | Val Loss 0.578125
# Epoch 1500 | Train Loss 1.033802 | Val Loss 0.577106
# Epoch 1600 | Train Loss 1.033071 | Val Loss 0.576559
# Epoch 1700 | Train Loss 1.032384 | Val Loss 0.576358
# Epoch 1800 | Train Loss 1.031679 | Val Loss 0.576261
# Early stopping at epoch 1827
# Y | train1 -> R² = 0.8821, MSE = 9.8765e-03
# Y | train2 -> R² = 0.6699, MSE = 3.5541e-02
# Y | test1 -> R² = 0.8986, MSE = 8.3069e-03
# Y | test2 -> R² = 0.6684, MSE = 3.5193e-02
# Y | test3 -> R² = 0.9813, MSE = 1.4364e-03
# Y | val -> R² = 0.8876, MSE = 8.3685e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 1.572241 | Val Loss 0.815401
# Epoch 100 | Train Loss 1.317300 | Val Loss 0.753206
# Epoch 200 | Train Loss 1.236011 | Val Loss 0.735074
# Epoch 300 | Train Loss 1.229638 | Val Loss 0.733952
# Epoch 400 | Train Loss 1.225718 | Val Loss 0.733860
# Epoch 500 | Train Loss 1.201259 | Val Loss 0.712430
# Epoch 600 | Train Loss 1.127027 | Val Loss 0.637490
# Epoch 700 | Train Loss 1.053646 | Val Loss 0.595832
# Epoch 800 | Train Loss 1.040594 | Val Loss 0.588543
# Epoch 900 | Train Loss 1.037183 | Val Loss 0.584514
# Epoch 1000 | Train Loss 1.035677 | Val Loss 0.583401
# Epoch 1100 | Train Loss 1.034495 | Val Loss 0.583055
# Epoch 1200 | Train Loss 1.033402 | Val Loss 0.583270
# Early stopping at epoch 1239
# Y | train1 -> R² = 0.8991, MSE = 8.4510e-03
# Y | train2 -> R² = 0.6836, MSE = 3.4066e-02
# Y | test1 -> R² = 0.9166, MSE = 6.8313e-03
# Y | test2 -> R² = 0.6816, MSE = 3.3793e-02
# Y | test3 -> R² = 0.9071, MSE = 7.1362e-03
# Y | val -> R² = 0.9872, MSE = 9.5397e-04
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 1.568159 | Val Loss 0.811691
# Epoch 100 | Train Loss 1.331656 | Val Loss 0.753398
# Epoch 200 | Train Loss 1.208043 | Val Loss 0.705893
# Epoch 300 | Train Loss 1.138255 | Val Loss 0.660732
# Epoch 400 | Train Loss 1.088001 | Val Loss 0.615129
# Epoch 500 | Train Loss 1.063496 | Val Loss 0.595230
# Epoch 600 | Train Loss 1.051683 | Val Loss 0.586290
# Epoch 700 | Train Loss 1.044734 | Val Loss 0.581813
# Epoch 800 | Train Loss 1.040513 | Val Loss 0.578019
# Epoch 900 | Train Loss 1.037677 | Val Loss 0.574676
# Epoch 1000 | Train Loss 1.035897 | Val Loss 0.573038
# Epoch 1100 | Train Loss 1.034776 | Val Loss 0.572463
# Epoch 1200 | Train Loss 1.033942 | Val Loss 0.572298
# Early stopping at epoch 1283
# Y | train1 -> R² = 0.8798, MSE = 1.0069e-02
# Y | train2 -> R² = 0.6715, MSE = 3.5371e-02
# Y | test1 -> R² = 0.8967, MSE = 8.4680e-03
# Y | test2 -> R² = 0.6700, MSE = 3.5029e-02
# Y | test3 -> R² = 0.9677, MSE = 2.4788e-03
# Y | val -> R² = 0.9499, MSE = 3.7264e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 1.566581 | Val Loss 0.809481
# Epoch 100 | Train Loss 1.315197 | Val Loss 0.756431
# Epoch 200 | Train Loss 1.196842 | Val Loss 0.694026
# Epoch 300 | Train Loss 1.123515 | Val Loss 0.655236
# Epoch 400 | Train Loss 1.085524 | Val Loss 0.624112
# Epoch 500 | Train Loss 1.061910 | Val Loss 0.602160
# Epoch 600 | Train Loss 1.046955 | Val Loss 0.589324
# Epoch 700 | Train Loss 1.039416 | Val Loss 0.590339
# Epoch 800 | Train Loss 1.036378 | Val Loss 0.583144
# Epoch 900 | Train Loss 1.034612 | Val Loss 0.579106
# Epoch 1000 | Train Loss 1.033416 | Val Loss 0.577706
# Epoch 1100 | Train Loss 1.032828 | Val Loss 0.577837
# Epoch 1200 | Train Loss 1.032479 | Val Loss 0.577908
# Early stopping at epoch 1249
# Y | train1 -> R² = 0.8906, MSE = 9.1687e-03
# Y | train2 -> R² = 0.6767, MSE = 3.4807e-02
# Y | test1 -> R² = 0.9081, MSE = 7.5272e-03
# Y | test2 -> R² = 0.6750, MSE = 3.4492e-02
# Y | test3 -> R² = 0.9089, MSE = 6.9957e-03
# Y | val -> R² = 0.6173, MSE = 2.8495e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.565504 | Val Loss 0.814948
# Epoch 100 | Train Loss 1.314578 | Val Loss 0.791378
# Epoch 200 | Train Loss 1.223861 | Val Loss 0.720513
# Epoch 300 | Train Loss 1.174530 | Val Loss 0.678823
# Epoch 400 | Train Loss 1.112725 | Val Loss 0.630295
# Epoch 500 | Train Loss 1.076237 | Val Loss 0.608980
# Epoch 600 | Train Loss 1.051113 | Val Loss 0.588853
# Epoch 700 | Train Loss 1.039865 | Val Loss 0.581866
# Epoch 800 | Train Loss 1.035867 | Val Loss 0.579308
# Epoch 900 | Train Loss 1.034634 | Val Loss 0.578855
# Epoch 1000 | Train Loss 1.033933 | Val Loss 0.578613
# Epoch 1100 | Train Loss 1.033399 | Val Loss 0.578480
# Early stopping at epoch 1128
# Y | train1 -> R² = 0.8844, MSE = 9.6833e-03
# Y | train2 -> R² = 0.6784, MSE = 3.4624e-02
# Y | test1 -> R² = 0.8924, MSE = 8.8162e-03
# Y | test2 -> R² = 0.6778, MSE = 3.4200e-02
# Y | test3 -> R² = 0.8570, MSE = 1.0983e-02
# Y | val -> R² = 0.5865, MSE = 3.0788e-02
