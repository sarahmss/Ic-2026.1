# %% [markdown]
# - Entradas: SWdRef, SWeRef, Theta
# - Saidas: X
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 10
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test")
        )

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva.")

        plt.close(fig)

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 0.518061 | Val Loss 0.691741
# Epoch 100 | Train Loss 0.319591 | Val Loss 0.444694
# Epoch 200 | Train Loss 0.308425 | Val Loss 0.414989
# Epoch 300 | Train Loss 0.303948 | Val Loss 0.412754
# Epoch 400 | Train Loss 0.300617 | Val Loss 0.411286
# Epoch 500 | Train Loss 0.297557 | Val Loss 0.406570
# Epoch 600 | Train Loss 0.294969 | Val Loss 0.404570
# Epoch 700 | Train Loss 0.293953 | Val Loss 0.403966
# Epoch 800 | Train Loss 0.293400 | Val Loss 0.403659
# Epoch 900 | Train Loss 0.292955 | Val Loss 0.404266
# Early stopping at epoch 980
# X | train1 -> R² = -0.0862, MSE = 1.1712e-01
# X | train2 -> R² = -7.0301, MSE = 6.7662e-01
# X | test1 -> R² = -0.2348, MSE = 1.2936e-01
# X | test2 -> R² = -7.0296, MSE = 6.6078e-01
# X | test3 -> R² = 0.7821, MSE = 2.0049e-02
# X | val -> R² = 0.4415, MSE = 5.3409e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.500787 | Val Loss 0.634580
# Epoch 100 | Train Loss 0.313357 | Val Loss 0.421457
# Epoch 200 | Train Loss 0.306755 | Val Loss 0.413544
# Epoch 300 | Train Loss 0.303134 | Val Loss 0.416427
# Epoch 400 | Train Loss 0.300063 | Val Loss 0.413959
# Epoch 500 | Train Loss 0.297994 | Val Loss 0.411144
# Epoch 600 | Train Loss 0.296017 | Val Loss 0.414143
# Epoch 700 | Train Loss 0.294006 | Val Loss 0.425321
# Early stopping at epoch 759
# X | train1 -> R² = -0.0681, MSE = 1.1516e-01
# X | train2 -> R² = -7.1497, MSE = 6.8670e-01
# X | test1 -> R² = -0.1711, MSE = 1.2268e-01
# X | test2 -> R² = -7.1867, MSE = 6.7371e-01
# X | test3 -> R² = 0.9130, MSE = 8.0088e-03
# X | val -> R² = 0.7882, MSE = 2.0253e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.530619 | Val Loss 0.704630
# Epoch 100 | Train Loss 0.316094 | Val Loss 0.426530
# Epoch 200 | Train Loss 0.306608 | Val Loss 0.415282
# Epoch 300 | Train Loss 0.301443 | Val Loss 0.424173
# Epoch 400 | Train Loss 0.297713 | Val Loss 0.427339
# Early stopping at epoch 473
# X | train1 -> R² = -0.0940, MSE = 1.1796e-01
# X | train2 -> R² = -7.0013, MSE = 6.7419e-01
# X | test1 -> R² = -0.0280, MSE = 1.0769e-01
# X | test2 -> R² = -6.8714, MSE = 6.4776e-01
# X | test3 -> R² = 0.7288, MSE = 2.4951e-02
# X | val -> R² = 0.4981, MSE = 4.7996e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.523932 | Val Loss 0.650978
# Epoch 100 | Train Loss 0.316896 | Val Loss 0.431356
# Epoch 200 | Train Loss 0.307759 | Val Loss 0.413004
# Epoch 300 | Train Loss 0.302302 | Val Loss 0.415168
# Epoch 400 | Train Loss 0.298875 | Val Loss 0.416091
# Epoch 500 | Train Loss 0.296509 | Val Loss 0.418666
# Early stopping at epoch 512
# X | train1 -> R² = -0.1078, MSE = 1.1945e-01
# X | train2 -> R² = -7.0707, MSE = 6.8004e-01
# X | test1 -> R² = -0.1071, MSE = 1.1598e-01
# X | test2 -> R² = -6.8628, MSE = 6.4705e-01
# X | test3 -> R² = 0.6398, MSE = 3.3144e-02
# X | val -> R² = 0.4467, MSE = 5.2912e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.516423 | Val Loss 0.666879
# Epoch 100 | Train Loss 0.316939 | Val Loss 0.423630
# Epoch 200 | Train Loss 0.307591 | Val Loss 0.413482
# Epoch 300 | Train Loss 0.302728 | Val Loss 0.423553
# Epoch 400 | Train Loss 0.298884 | Val Loss 0.433687
# Early stopping at epoch 476
# X | train1 -> R² = -0.1017, MSE = 1.1879e-01
# X | train2 -> R² = -7.0330, MSE = 6.7686e-01
# X | test1 -> R² = -0.0723, MSE = 1.1233e-01
# X | test2 -> R² = -6.8717, MSE = 6.4779e-01
# X | test3 -> R² = 0.5912, MSE = 3.7616e-02
# X | val -> R² = 0.3266, MSE = 6.4396e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.512057 | Val Loss 0.662888
# Epoch 100 | Train Loss 0.314975 | Val Loss 0.430295
# Epoch 200 | Train Loss 0.306760 | Val Loss 0.413544
# Epoch 300 | Train Loss 0.302849 | Val Loss 0.419494
# Epoch 400 | Train Loss 0.299447 | Val Loss 0.424828
# Early stopping at epoch 486
# X | train1 -> R² = -0.1023, MSE = 1.1886e-01
# X | train2 -> R² = -7.0417, MSE = 6.7760e-01
# X | test1 -> R² = -0.0888, MSE = 1.1407e-01
# X | test2 -> R² = -6.9102, MSE = 6.5096e-01
# X | test3 -> R² = 0.5613, MSE = 4.0365e-02
# X | val -> R² = 0.3328, MSE = 6.3803e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.525697 | Val Loss 0.711307
# Epoch 100 | Train Loss 0.321135 | Val Loss 0.458867
# Epoch 200 | Train Loss 0.308540 | Val Loss 0.422036
# Epoch 300 | Train Loss 0.301550 | Val Loss 0.408032
# Epoch 400 | Train Loss 0.296854 | Val Loss 0.409369
# Epoch 500 | Train Loss 0.295051 | Val Loss 0.414787
# Epoch 600 | Train Loss 0.294431 | Val Loss 0.418203
# Early stopping at epoch 603
# X | train1 -> R² = -0.2282, MSE = 1.3243e-01
# X | train2 -> R² = -7.2349, MSE = 6.9387e-01
# X | test1 -> R² = -0.2515, MSE = 1.3110e-01
# X | test2 -> R² = -7.1295, MSE = 6.6900e-01
# X | test3 -> R² = -0.1013, MSE = 1.0133e-01
# X | val -> R² = -0.6493, MSE = 1.5771e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.513551 | Val Loss 0.672448
# Epoch 100 | Train Loss 0.320853 | Val Loss 0.466173
# Epoch 200 | Train Loss 0.308761 | Val Loss 0.420378
# Epoch 300 | Train Loss 0.303964 | Val Loss 0.411422
# Epoch 400 | Train Loss 0.300276 | Val Loss 0.412162
# Epoch 500 | Train Loss 0.296909 | Val Loss 0.415186
# Early stopping at epoch 561
# X | train1 -> R² = -0.1171, MSE = 1.2045e-01
# X | train2 -> R² = -7.1593, MSE = 6.8750e-01
# X | test1 -> R² = -0.1490, MSE = 1.2037e-01
# X | test2 -> R² = -7.0712, MSE = 6.6420e-01
# X | test3 -> R² = 0.6596, MSE = 3.1322e-02
# X | val -> R² = 0.4349, MSE = 5.4040e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.529252 | Val Loss 0.689470
# Epoch 100 | Train Loss 0.320015 | Val Loss 0.452950
# Epoch 200 | Train Loss 0.307765 | Val Loss 0.417334
# Epoch 300 | Train Loss 0.301780 | Val Loss 0.411991
# Epoch 400 | Train Loss 0.297814 | Val Loss 0.412765
# Epoch 500 | Train Loss 0.295572 | Val Loss 0.413993
# Early stopping at epoch 580
# X | train1 -> R² = -0.1723, MSE = 1.2640e-01
# X | train2 -> R² = -7.1246, MSE = 6.8458e-01
# X | test1 -> R² = -0.1945, MSE = 1.2514e-01
# X | test2 -> R² = -7.0700, MSE = 6.6410e-01
# X | test3 -> R² = 0.6151, MSE = 3.5411e-02
# X | val -> R² = 0.2007, MSE = 7.6427e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.528068 | Val Loss 0.702547
# Epoch 100 | Train Loss 0.318804 | Val Loss 0.439960
# Epoch 200 | Train Loss 0.306902 | Val Loss 0.414622
# Epoch 300 | Train Loss 0.301487 | Val Loss 0.414392
# Epoch 400 | Train Loss 0.297860 | Val Loss 0.416413
# Epoch 500 | Train Loss 0.295883 | Val Loss 0.426361
# Early stopping at epoch 505
# X | train1 -> R² = -0.1463, MSE = 1.2360e-01
# X | train2 -> R² = -7.1340, MSE = 6.8537e-01
# X | test1 -> R² = -0.1318, MSE = 1.1856e-01
# X | test2 -> R² = -7.0332, MSE = 6.6108e-01
# X | test3 -> R² = 0.4530, MSE = 5.0326e-02
# X | val -> R² = 0.1315, MSE = 8.3048e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.524592 | Val Loss 0.710064
# Epoch 100 | Train Loss 0.315564 | Val Loss 0.428311
# Epoch 200 | Train Loss 0.306481 | Val Loss 0.416221
# Epoch 300 | Train Loss 0.301359 | Val Loss 0.427649
# Epoch 400 | Train Loss 0.297532 | Val Loss 0.442324
# Early stopping at epoch 461
# X | train1 -> R² = -0.0873, MSE = 1.1724e-01
# X | train2 -> R² = -7.0922, MSE = 6.8185e-01
# X | test1 -> R² = -0.0496, MSE = 1.0996e-01
# X | test2 -> R² = -6.9234, MSE = 6.5204e-01
# X | test3 -> R² = 0.5983, MSE = 3.6956e-02
# X | val -> R² = 0.3377, MSE = 6.3335e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.509835 | Val Loss 0.636781
# Epoch 100 | Train Loss 0.316453 | Val Loss 0.428662
# Epoch 200 | Train Loss 0.307997 | Val Loss 0.413787
# Epoch 300 | Train Loss 0.302458 | Val Loss 0.411290
# Epoch 400 | Train Loss 0.298129 | Val Loss 0.406947
# Epoch 500 | Train Loss 0.295342 | Val Loss 0.410997
# Epoch 600 | Train Loss 0.293983 | Val Loss 0.416091
# Early stopping at epoch 683
# X | train1 -> R² = -0.0731, MSE = 1.1571e-01
# X | train2 -> R² = -7.1083, MSE = 6.8321e-01
# X | test1 -> R² = -0.1751, MSE = 1.2311e-01
# X | test2 -> R² = -7.1688, MSE = 6.7224e-01
# X | test3 -> R² = 0.8612, MSE = 1.2766e-02
# X | val -> R² = 0.6092, MSE = 3.7371e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.514894 | Val Loss 0.645635
# Epoch 100 | Train Loss 0.316799 | Val Loss 0.431127
# Epoch 200 | Train Loss 0.307676 | Val Loss 0.413564
# Epoch 300 | Train Loss 0.303613 | Val Loss 0.412933
# Epoch 400 | Train Loss 0.299363 | Val Loss 0.412758
# Epoch 500 | Train Loss 0.296876 | Val Loss 0.418338
# Early stopping at epoch 516
# X | train1 -> R² = -0.1610, MSE = 1.2518e-01
# X | train2 -> R² = -6.9497, MSE = 6.6985e-01
# X | test1 -> R² = -0.1397, MSE = 1.1939e-01
# X | test2 -> R² = -6.7845, MSE = 6.4061e-01
# X | test3 -> R² = 0.7375, MSE = 2.4148e-02
# X | val -> R² = 0.5009, MSE = 4.7727e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.510090 | Val Loss 0.658089
# Epoch 100 | Train Loss 0.319999 | Val Loss 0.461278
# Epoch 200 | Train Loss 0.308434 | Val Loss 0.424412
# Epoch 300 | Train Loss 0.301076 | Val Loss 0.411523
# Epoch 400 | Train Loss 0.295749 | Val Loss 0.416026
# Epoch 500 | Train Loss 0.294642 | Val Loss 0.424781
# Epoch 600 | Train Loss 0.294130 | Val Loss 0.430887
# Early stopping at epoch 631
# X | train1 -> R² = -0.1477, MSE = 1.2375e-01
# X | train2 -> R² = -7.1629, MSE = 6.8781e-01
# X | test1 -> R² = -0.2095, MSE = 1.2671e-01
# X | test2 -> R² = -7.1585, MSE = 6.7139e-01
# X | test3 -> R² = 0.6157, MSE = 3.5360e-02
# X | val -> R² = 0.0094, MSE = 9.4725e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.510336 | Val Loss 0.648703
# Epoch 100 | Train Loss 0.318013 | Val Loss 0.448268
# Epoch 200 | Train Loss 0.309104 | Val Loss 0.422165
# Epoch 300 | Train Loss 0.302657 | Val Loss 0.407930
# Epoch 400 | Train Loss 0.298476 | Val Loss 0.412154
# Epoch 500 | Train Loss 0.295640 | Val Loss 0.427735
# Early stopping at epoch 563
# X | train1 -> R² = -0.1719, MSE = 1.2637e-01
# X | train2 -> R² = -7.2029, MSE = 6.9118e-01
# X | test1 -> R² = -0.2118, MSE = 1.2694e-01
# X | test2 -> R² = -7.0914, MSE = 6.6587e-01
# X | test3 -> R² = 0.4348, MSE = 5.2001e-02
# X | val -> R² = 0.0815, MSE = 8.7831e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.519685 | Val Loss 0.689962
# Epoch 100 | Train Loss 0.314305 | Val Loss 0.427783
# Epoch 200 | Train Loss 0.306813 | Val Loss 0.414612
# Epoch 300 | Train Loss 0.301784 | Val Loss 0.422932
# Epoch 400 | Train Loss 0.297295 | Val Loss 0.425177
# Early stopping at epoch 473
# X | train1 -> R² = -0.0723, MSE = 1.1563e-01
# X | train2 -> R² = -6.9221, MSE = 6.6752e-01
# X | test1 -> R² = -0.0376, MSE = 1.0870e-01
# X | test2 -> R² = -6.7937, MSE = 6.4137e-01
# X | test3 -> R² = 0.5347, MSE = 4.2812e-02
# X | val -> R² = 0.2745, MSE = 6.9373e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.510724 | Val Loss 0.662945
# Epoch 100 | Train Loss 0.317115 | Val Loss 0.440013
# Epoch 200 | Train Loss 0.307579 | Val Loss 0.413445
# Epoch 300 | Train Loss 0.300962 | Val Loss 0.408629
# Epoch 400 | Train Loss 0.297236 | Val Loss 0.411443
# Epoch 500 | Train Loss 0.295056 | Val Loss 0.421832
# Epoch 600 | Train Loss 0.293976 | Val Loss 0.436391
# Early stopping at epoch 613
# X | train1 -> R² = -0.1666, MSE = 1.2578e-01
# X | train2 -> R² = -7.0677, MSE = 6.7979e-01
# X | test1 -> R² = -0.2283, MSE = 1.2868e-01
# X | test2 -> R² = -7.0228, MSE = 6.6022e-01
# X | test3 -> R² = 0.8979, MSE = 9.3929e-03
# X | val -> R² = 0.7061, MSE = 2.8099e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.523790 | Val Loss 0.675582
# Epoch 100 | Train Loss 0.323236 | Val Loss 0.472824
# Epoch 200 | Train Loss 0.308021 | Val Loss 0.416029
# Epoch 300 | Train Loss 0.303115 | Val Loss 0.418576
# Epoch 400 | Train Loss 0.299821 | Val Loss 0.428403
# Epoch 500 | Train Loss 0.296943 | Val Loss 0.441142
# Early stopping at epoch 528
# X | train1 -> R² = -0.0979, MSE = 1.1838e-01
# X | train2 -> R² = -7.1078, MSE = 6.8317e-01
# X | test1 -> R² = -0.1217, MSE = 1.1751e-01
# X | test2 -> R² = -6.9715, MSE = 6.5600e-01
# X | test3 -> R² = 0.5365, MSE = 4.2643e-02
# X | val -> R² = 0.2745, MSE = 6.9378e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.524170 | Val Loss 0.674572
# Epoch 100 | Train Loss 0.319475 | Val Loss 0.447063
# Epoch 200 | Train Loss 0.309559 | Val Loss 0.418174
# Epoch 300 | Train Loss 0.304941 | Val Loss 0.413330
# Epoch 400 | Train Loss 0.301672 | Val Loss 0.418070
# Epoch 500 | Train Loss 0.299180 | Val Loss 0.418076
# Early stopping at epoch 568
# X | train1 -> R² = -0.1321, MSE = 1.2207e-01
# X | train2 -> R² = -7.0987, MSE = 6.8240e-01
# X | test1 -> R² = -0.1611, MSE = 1.2163e-01
# X | test2 -> R² = -6.9382, MSE = 6.5326e-01
# X | test3 -> R² = 0.7454, MSE = 2.3427e-02
# X | val -> R² = 0.5449, MSE = 4.3514e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.515124 | Val Loss 0.656098
# Epoch 100 | Train Loss 0.317132 | Val Loss 0.440565
# Epoch 200 | Train Loss 0.307780 | Val Loss 0.416113
# Epoch 300 | Train Loss 0.303379 | Val Loss 0.415470
# Epoch 400 | Train Loss 0.298995 | Val Loss 0.414630
# Epoch 500 | Train Loss 0.296467 | Val Loss 0.418975
# Early stopping at epoch 513
# X | train1 -> R² = -0.1233, MSE = 1.2112e-01
# X | train2 -> R² = -7.1197, MSE = 6.8417e-01
# X | test1 -> R² = -0.0980, MSE = 1.1503e-01
# X | test2 -> R² = -6.9759, MSE = 6.5636e-01
# X | test3 -> R² = 0.4980, MSE = 4.6185e-02
# X | val -> R² = 0.2948, MSE = 6.7437e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.521585 | Val Loss 0.696630
# Epoch 100 | Train Loss 0.316771 | Val Loss 0.431947
# Epoch 200 | Train Loss 0.307535 | Val Loss 0.414607
# Epoch 300 | Train Loss 0.302444 | Val Loss 0.414175
# Epoch 400 | Train Loss 0.297929 | Val Loss 0.409562
# Epoch 500 | Train Loss 0.295806 | Val Loss 0.412902
# Epoch 600 | Train Loss 0.294688 | Val Loss 0.414786
# Early stopping at epoch 695
# X | train1 -> R² = -0.1058, MSE = 1.1924e-01
# X | train2 -> R² = -7.0622, MSE = 6.7932e-01
# X | test1 -> R² = -0.1760, MSE = 1.2319e-01
# X | test2 -> R² = -7.0923, MSE = 6.6594e-01
# X | test3 -> R² = 0.9458, MSE = 4.9874e-03
# X | val -> R² = 0.7159, MSE = 2.7170e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.514764 | Val Loss 0.671744
# Epoch 100 | Train Loss 0.313741 | Val Loss 0.418256
# Epoch 200 | Train Loss 0.306096 | Val Loss 0.414780
# Epoch 300 | Train Loss 0.300703 | Val Loss 0.409882
# Epoch 400 | Train Loss 0.297159 | Val Loss 0.408346
# Epoch 500 | Train Loss 0.295165 | Val Loss 0.411309
# Epoch 600 | Train Loss 0.294145 | Val Loss 0.413750
# Early stopping at epoch 645
# X | train1 -> R² = -0.1083, MSE = 1.1950e-01
# X | train2 -> R² = -7.1866, MSE = 6.8981e-01
# X | test1 -> R² = -0.1694, MSE = 1.2250e-01
# X | test2 -> R² = -7.1305, MSE = 6.6909e-01
# X | test3 -> R² = 0.8274, MSE = 1.5884e-02
# X | val -> R² = 0.4759, MSE = 5.0114e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.529109 | Val Loss 0.716061
# Epoch 100 | Train Loss 0.318962 | Val Loss 0.449346
# Epoch 200 | Train Loss 0.308503 | Val Loss 0.415775
# Epoch 300 | Train Loss 0.302722 | Val Loss 0.420048
# Epoch 400 | Train Loss 0.298284 | Val Loss 0.425716
# Epoch 500 | Train Loss 0.295423 | Val Loss 0.423725
# Early stopping at epoch 511
# X | train1 -> R² = -0.1221, MSE = 1.2100e-01
# X | train2 -> R² = -6.9709, MSE = 6.7163e-01
# X | test1 -> R² = -0.0938, MSE = 1.1458e-01
# X | test2 -> R² = -6.7866, MSE = 6.4079e-01
# X | test3 -> R² = 0.4911, MSE = 4.6819e-02
# X | val -> R² = 0.1996, MSE = 7.6540e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.519383 | Val Loss 0.651746
# Epoch 100 | Train Loss 0.318006 | Val Loss 0.435404
# Epoch 200 | Train Loss 0.307587 | Val Loss 0.413459
# Epoch 300 | Train Loss 0.301795 | Val Loss 0.411301
# Epoch 400 | Train Loss 0.297945 | Val Loss 0.411879
# Epoch 500 | Train Loss 0.295672 | Val Loss 0.419439
# Epoch 600 | Train Loss 0.294400 | Val Loss 0.425554
# Early stopping at epoch 646
# X | train1 -> R² = -0.1077, MSE = 1.1943e-01
# X | train2 -> R² = -7.1730, MSE = 6.8866e-01
# X | test1 -> R² = -0.1669, MSE = 1.2225e-01
# X | test2 -> R² = -7.1135, MSE = 6.6769e-01
# X | test3 -> R² = 0.9201, MSE = 7.3471e-03
# X | val -> R² = 0.6791, MSE = 3.0688e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.514785 | Val Loss 0.667945
# Epoch 100 | Train Loss 0.317258 | Val Loss 0.443232
# Epoch 200 | Train Loss 0.308683 | Val Loss 0.417496
# Epoch 300 | Train Loss 0.302625 | Val Loss 0.419726
# Epoch 400 | Train Loss 0.298056 | Val Loss 0.418105
# Epoch 500 | Train Loss 0.295390 | Val Loss 0.424320
# Early stopping at epoch 532
# X | train1 -> R² = -0.1010, MSE = 1.1872e-01
# X | train2 -> R² = -7.1447, MSE = 6.8627e-01
# X | test1 -> R² = -0.1134, MSE = 1.1664e-01
# X | test2 -> R² = -7.0015, MSE = 6.5847e-01
# X | test3 -> R² = 0.5224, MSE = 4.3938e-02
# X | val -> R² = 0.2709, MSE = 6.9718e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.525543 | Val Loss 0.690031
# Epoch 100 | Train Loss 0.317545 | Val Loss 0.437709
# Epoch 200 | Train Loss 0.308276 | Val Loss 0.414923
# Epoch 300 | Train Loss 0.302567 | Val Loss 0.414813
# Epoch 400 | Train Loss 0.297431 | Val Loss 0.419435
# Epoch 500 | Train Loss 0.295415 | Val Loss 0.420876
# Early stopping at epoch 520
# X | train1 -> R² = -0.1008, MSE = 1.1869e-01
# X | train2 -> R² = -6.9936, MSE = 6.7355e-01
# X | test1 -> R² = -0.0694, MSE = 1.1203e-01
# X | test2 -> R² = -6.8605, MSE = 6.4687e-01
# X | test3 -> R² = 0.3679, MSE = 5.8157e-02
# X | val -> R² = 0.0877, MSE = 8.7237e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.518028 | Val Loss 0.684992
# Epoch 100 | Train Loss 0.320331 | Val Loss 0.455529
# Epoch 200 | Train Loss 0.308098 | Val Loss 0.415403
# Epoch 300 | Train Loss 0.303891 | Val Loss 0.415247
# Epoch 400 | Train Loss 0.301241 | Val Loss 0.418088
# Epoch 500 | Train Loss 0.297993 | Val Loss 0.421317
# Early stopping at epoch 512
# X | train1 -> R² = -0.1601, MSE = 1.2509e-01
# X | train2 -> R² = -7.0720, MSE = 6.8015e-01
# X | test1 -> R² = -0.1731, MSE = 1.2289e-01
# X | test2 -> R² = -6.8694, MSE = 6.4760e-01
# X | test3 -> R² = 0.5717, MSE = 3.9407e-02
# X | val -> R² = 0.2989, MSE = 6.7039e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.516031 | Val Loss 0.664358
# Epoch 100 | Train Loss 0.315500 | Val Loss 0.431060
# Epoch 200 | Train Loss 0.306994 | Val Loss 0.411723
# Epoch 300 | Train Loss 0.302021 | Val Loss 0.412077
# Epoch 400 | Train Loss 0.298091 | Val Loss 0.411253
# Epoch 500 | Train Loss 0.295891 | Val Loss 0.424363
# Epoch 600 | Train Loss 0.294405 | Val Loss 0.439545
# Early stopping at epoch 632
# X | train1 -> R² = -0.1383, MSE = 1.2273e-01
# X | train2 -> R² = -7.0301, MSE = 6.7662e-01
# X | test1 -> R² = -0.1928, MSE = 1.2495e-01
# X | test2 -> R² = -6.9532, MSE = 6.5450e-01
# X | test3 -> R² = 0.9066, MSE = 8.5903e-03
# X | val -> R² = 0.7327, MSE = 2.5558e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.514819 | Val Loss 0.649837
# Epoch 100 | Train Loss 0.317449 | Val Loss 0.438102
# Epoch 200 | Train Loss 0.306865 | Val Loss 0.414966
# Epoch 300 | Train Loss 0.301570 | Val Loss 0.416569
# Epoch 400 | Train Loss 0.297531 | Val Loss 0.418933
# Epoch 500 | Train Loss 0.295510 | Val Loss 0.428348
# Early stopping at epoch 505
# X | train1 -> R² = -0.1527, MSE = 1.2430e-01
# X | train2 -> R² = -7.1588, MSE = 6.8747e-01
# X | test1 -> R² = -0.1599, MSE = 1.2152e-01
# X | test2 -> R² = -6.9591, MSE = 6.5498e-01
# X | test3 -> R² = 0.5079, MSE = 4.5273e-02
# X | val -> R² = 0.2094, MSE = 7.5599e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.522758 | Val Loss 0.701518
# Epoch 100 | Train Loss 0.317843 | Val Loss 0.435906
# Epoch 200 | Train Loss 0.307612 | Val Loss 0.413774
# Epoch 300 | Train Loss 0.303383 | Val Loss 0.416192
# Epoch 400 | Train Loss 0.298886 | Val Loss 0.413140
# Epoch 500 | Train Loss 0.296127 | Val Loss 0.413759
# Epoch 600 | Train Loss 0.294669 | Val Loss 0.418877
# Early stopping at epoch 692
# X | train1 -> R² = -0.1458, MSE = 1.2355e-01
# X | train2 -> R² = -7.1845, MSE = 6.8962e-01
# X | test1 -> R² = -0.2126, MSE = 1.2703e-01
# X | test2 -> R² = -7.1200, MSE = 6.6822e-01
# X | test3 -> R² = 0.9409, MSE = 5.4383e-03
# X | val -> R² = 0.7192, MSE = 2.6852e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.456849 | Val Loss 0.664054
# Epoch 100 | Train Loss 0.247171 | Val Loss 0.483641
# Epoch 200 | Train Loss 0.234746 | Val Loss 0.448582
# Epoch 300 | Train Loss 0.228675 | Val Loss 0.433631
# Epoch 400 | Train Loss 0.221815 | Val Loss 0.429115
# Epoch 500 | Train Loss 0.218990 | Val Loss 0.434129
# Epoch 600 | Train Loss 0.216907 | Val Loss 0.442821
# Epoch 700 | Train Loss 0.214538 | Val Loss 0.450007
# Early stopping at epoch 706
# X | train1 -> R² = -1.1620, MSE = 2.3312e-01
# X | train2 -> R² = -14.6944, MSE = 1.3224e+00
# X | test1 -> R² = -1.3710, MSE = 2.4839e-01
# X | test2 -> R² = -14.7664, MSE = 1.2975e+00
# X | test3 -> R² = 0.3916, MSE = 5.5976e-02
# X | val -> R² = -0.1016, MSE = 1.0534e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.459765 | Val Loss 0.663195
# Epoch 100 | Train Loss 0.243057 | Val Loss 0.462549
# Epoch 200 | Train Loss 0.231526 | Val Loss 0.442563
# Epoch 300 | Train Loss 0.225210 | Val Loss 0.437969
# Epoch 400 | Train Loss 0.220079 | Val Loss 0.441511
# Epoch 500 | Train Loss 0.216814 | Val Loss 0.458859
# Early stopping at epoch 537
# X | train1 -> R² = -1.2776, MSE = 2.4558e-01
# X | train2 -> R² = -14.9495, MSE = 1.3439e+00
# X | test1 -> R² = -1.4360, MSE = 2.5519e-01
# X | test2 -> R² = -14.9002, MSE = 1.3085e+00
# X | test3 -> R² = 0.0119, MSE = 9.0913e-02
# X | val -> R² = -0.4993, MSE = 1.4337e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.468851 | Val Loss 0.648861
# Epoch 100 | Train Loss 0.242645 | Val Loss 0.463010
# Epoch 200 | Train Loss 0.233156 | Val Loss 0.443675
# Epoch 300 | Train Loss 0.227163 | Val Loss 0.433883
# Epoch 400 | Train Loss 0.221268 | Val Loss 0.430824
# Epoch 500 | Train Loss 0.217249 | Val Loss 0.435183
# Epoch 600 | Train Loss 0.214981 | Val Loss 0.445139
# Early stopping at epoch 653
# X | train1 -> R² = -1.1962, MSE = 2.3681e-01
# X | train2 -> R² = -14.8079, MSE = 1.3320e+00
# X | test1 -> R² = -1.4110, MSE = 2.5258e-01
# X | test2 -> R² = -14.9699, MSE = 1.3142e+00
# X | test3 -> R² = 0.6453, MSE = 3.2637e-02
# X | val -> R² = 0.1868, MSE = 7.7765e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.487165 | Val Loss 0.711860
# Epoch 100 | Train Loss 0.248812 | Val Loss 0.500879
# Epoch 200 | Train Loss 0.235531 | Val Loss 0.458263
# Epoch 300 | Train Loss 0.228788 | Val Loss 0.433446
# Epoch 400 | Train Loss 0.223316 | Val Loss 0.432566
# Epoch 500 | Train Loss 0.218525 | Val Loss 0.443038
# Epoch 600 | Train Loss 0.216086 | Val Loss 0.455850
# Early stopping at epoch 622
# X | train1 -> R² = -1.3401, MSE = 2.5233e-01
# X | train2 -> R² = -14.8305, MSE = 1.3339e+00
# X | test1 -> R² = -1.5059, MSE = 2.6252e-01
# X | test2 -> R² = -14.8699, MSE = 1.3060e+00
# X | test3 -> R² = 0.1712, MSE = 7.6257e-02
# X | val -> R² = -0.3464, MSE = 1.2875e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.482621 | Val Loss 0.692745
# Epoch 100 | Train Loss 0.249753 | Val Loss 0.502330
# Epoch 200 | Train Loss 0.233390 | Val Loss 0.448022
# Epoch 300 | Train Loss 0.227416 | Val Loss 0.429875
# Epoch 400 | Train Loss 0.221920 | Val Loss 0.419809
# Epoch 500 | Train Loss 0.217783 | Val Loss 0.422143
# Epoch 600 | Train Loss 0.214988 | Val Loss 0.426008
# Early stopping at epoch 693
# X | train1 -> R² = -1.1745, MSE = 2.3446e-01
# X | train2 -> R² = -14.7982, MSE = 1.3312e+00
# X | test1 -> R² = -1.3480, MSE = 2.4598e-01
# X | test2 -> R² = -14.9891, MSE = 1.3158e+00
# X | test3 -> R² = -0.4186, MSE = 1.3051e-01
# X | val -> R² = -0.7295, MSE = 1.6538e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.461527 | Val Loss 0.694481
# Epoch 100 | Train Loss 0.245194 | Val Loss 0.485142
# Epoch 200 | Train Loss 0.233832 | Val Loss 0.450155
# Epoch 300 | Train Loss 0.228984 | Val Loss 0.432991
# Epoch 400 | Train Loss 0.222137 | Val Loss 0.427766
# Epoch 500 | Train Loss 0.218273 | Val Loss 0.434267
# Epoch 600 | Train Loss 0.216378 | Val Loss 0.443084
# Early stopping at epoch 690
# X | train1 -> R² = -1.2641, MSE = 2.4413e-01
# X | train2 -> R² = -14.7593, MSE = 1.3279e+00
# X | test1 -> R² = -1.4909, MSE = 2.6095e-01
# X | test2 -> R² = -14.8551, MSE = 1.3048e+00
# X | test3 -> R² = 0.6632, MSE = 3.0983e-02
# X | val -> R² = -0.0039, MSE = 9.5991e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.472175 | Val Loss 0.678297
# Epoch 100 | Train Loss 0.248704 | Val Loss 0.494503
# Epoch 200 | Train Loss 0.233961 | Val Loss 0.454059
# Epoch 300 | Train Loss 0.227853 | Val Loss 0.436777
# Epoch 400 | Train Loss 0.223117 | Val Loss 0.440530
# Epoch 500 | Train Loss 0.218945 | Val Loss 0.455763
# Early stopping at epoch 582
# X | train1 -> R² = -1.3180, MSE = 2.4994e-01
# X | train2 -> R² = -15.0115, MSE = 1.3491e+00
# X | test1 -> R² = -1.4956, MSE = 2.6144e-01
# X | test2 -> R² = -15.1021, MSE = 1.3251e+00
# X | test3 -> R² = -0.2476, MSE = 1.1478e-01
# X | val -> R² = -0.8882, MSE = 1.8056e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.475876 | Val Loss 0.665244
# Epoch 100 | Train Loss 0.251451 | Val Loss 0.507684
# Epoch 200 | Train Loss 0.234953 | Val Loss 0.452524
# Epoch 300 | Train Loss 0.229589 | Val Loss 0.436057
# Epoch 400 | Train Loss 0.225656 | Val Loss 0.430399
# Epoch 500 | Train Loss 0.221795 | Val Loss 0.425374
# Epoch 600 | Train Loss 0.217761 | Val Loss 0.423024
# Epoch 700 | Train Loss 0.215406 | Val Loss 0.426678
# Epoch 800 | Train Loss 0.214117 | Val Loss 0.430399
# Early stopping at epoch 860
# X | train1 -> R² = -1.0925, MSE = 2.2562e-01
# X | train2 -> R² = -14.7408, MSE = 1.3263e+00
# X | test1 -> R² = -1.3541, MSE = 2.4662e-01
# X | test2 -> R² = -14.8721, MSE = 1.3062e+00
# X | test3 -> R² = 0.6738, MSE = 3.0010e-02
# X | val -> R² = 0.3755, MSE = 5.9721e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.477180 | Val Loss 0.679358
# Epoch 100 | Train Loss 0.250175 | Val Loss 0.506432
# Epoch 200 | Train Loss 0.234354 | Val Loss 0.447521
# Epoch 300 | Train Loss 0.227244 | Val Loss 0.430255
# Epoch 400 | Train Loss 0.220745 | Val Loss 0.432071
# Epoch 500 | Train Loss 0.217064 | Val Loss 0.447092
# Early stopping at epoch 589
# X | train1 -> R² = -1.2904, MSE = 2.4697e-01
# X | train2 -> R² = -14.9370, MSE = 1.3429e+00
# X | test1 -> R² = -1.4224, MSE = 2.5378e-01
# X | test2 -> R² = -14.9667, MSE = 1.3140e+00
# X | test3 -> R² = 0.0462, MSE = 8.7755e-02
# X | val -> R² = -0.4615, MSE = 1.3975e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.473886 | Val Loss 0.691897
# Epoch 100 | Train Loss 0.248288 | Val Loss 0.500226
# Epoch 200 | Train Loss 0.234816 | Val Loss 0.459520
# Epoch 300 | Train Loss 0.228019 | Val Loss 0.433240
# Epoch 400 | Train Loss 0.223675 | Val Loss 0.425184
# Epoch 500 | Train Loss 0.219617 | Val Loss 0.427122
# Epoch 600 | Train Loss 0.216055 | Val Loss 0.440825
# Early stopping at epoch 698
# X | train1 -> R² = -1.2112, MSE = 2.3842e-01
# X | train2 -> R² = -14.8762, MSE = 1.3377e+00
# X | test1 -> R² = -1.4075, MSE = 2.5221e-01
# X | test2 -> R² = -14.9805, MSE = 1.3151e+00
# X | test3 -> R² = 0.4067, MSE = 5.4590e-02
# X | val -> R² = -0.0232, MSE = 9.7844e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.472526 | Val Loss 0.725779
# Epoch 100 | Train Loss 0.247480 | Val Loss 0.483379
# Epoch 200 | Train Loss 0.236157 | Val Loss 0.456410
# Epoch 300 | Train Loss 0.228910 | Val Loss 0.435855
# Epoch 400 | Train Loss 0.222373 | Val Loss 0.429057
# Epoch 500 | Train Loss 0.217711 | Val Loss 0.446208
# Epoch 600 | Train Loss 0.216005 | Val Loss 0.470444
# Early stopping at epoch 676
# X | train1 -> R² = -1.1723, MSE = 2.3423e-01
# X | train2 -> R² = -14.9263, MSE = 1.3420e+00
# X | test1 -> R² = -1.3225, MSE = 2.4331e-01
# X | test2 -> R² = -15.0682, MSE = 1.3223e+00
# X | test3 -> R² = 0.5689, MSE = 3.9665e-02
# X | val -> R² = 0.1697, MSE = 7.9397e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.459181 | Val Loss 0.688558
# Epoch 100 | Train Loss 0.243654 | Val Loss 0.481437
# Epoch 200 | Train Loss 0.232854 | Val Loss 0.445076
# Epoch 300 | Train Loss 0.228524 | Val Loss 0.436869
# Epoch 400 | Train Loss 0.224306 | Val Loss 0.427133
# Epoch 500 | Train Loss 0.219954 | Val Loss 0.423793
# Epoch 600 | Train Loss 0.216878 | Val Loss 0.434427
# Epoch 700 | Train Loss 0.214868 | Val Loss 0.441219
# Early stopping at epoch 736
# X | train1 -> R² = -1.1569, MSE = 2.3257e-01
# X | train2 -> R² = -14.7269, MSE = 1.3252e+00
# X | test1 -> R² = -1.3387, MSE = 2.4500e-01
# X | test2 -> R² = -14.9119, MSE = 1.3094e+00
# X | test3 -> R² = 0.3700, MSE = 5.7959e-02
# X | val -> R² = 0.1058, MSE = 8.5509e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.466984 | Val Loss 0.681218
# Epoch 100 | Train Loss 0.249820 | Val Loss 0.529053
# Epoch 200 | Train Loss 0.234898 | Val Loss 0.475670
# Epoch 300 | Train Loss 0.230469 | Val Loss 0.447356
# Epoch 400 | Train Loss 0.225046 | Val Loss 0.426452
# Epoch 500 | Train Loss 0.218696 | Val Loss 0.425775
# Epoch 600 | Train Loss 0.214782 | Val Loss 0.435685
# Epoch 700 | Train Loss 0.212759 | Val Loss 0.441067
# Early stopping at epoch 729
# X | train1 -> R² = -1.1411, MSE = 2.3087e-01
# X | train2 -> R² = -14.8704, MSE = 1.3372e+00
# X | test1 -> R² = -1.2266, MSE = 2.3326e-01
# X | test2 -> R² = -15.0123, MSE = 1.3177e+00
# X | test3 -> R² = -0.4118, MSE = 1.2990e-01
# X | val -> R² = -0.7573, MSE = 1.6804e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.476275 | Val Loss 0.654936
# Epoch 100 | Train Loss 0.249632 | Val Loss 0.512178
# Epoch 200 | Train Loss 0.234271 | Val Loss 0.452889
# Epoch 300 | Train Loss 0.228625 | Val Loss 0.437628
# Epoch 400 | Train Loss 0.224477 | Val Loss 0.437781
# Epoch 500 | Train Loss 0.219612 | Val Loss 0.449122
# Epoch 600 | Train Loss 0.216510 | Val Loss 0.469907
# Early stopping at epoch 616
# X | train1 -> R² = -1.3120, MSE = 2.4929e-01
# X | train2 -> R² = -14.8378, MSE = 1.3345e+00
# X | test1 -> R² = -1.4928, MSE = 2.6115e-01
# X | test2 -> R² = -14.9500, MSE = 1.3126e+00
# X | test3 -> R² = 0.0876, MSE = 8.3943e-02
# X | val -> R² = -0.6012, MSE = 1.5311e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.474608 | Val Loss 0.666701
# Epoch 100 | Train Loss 0.249681 | Val Loss 0.498882
# Epoch 200 | Train Loss 0.233393 | Val Loss 0.449956
# Epoch 300 | Train Loss 0.227164 | Val Loss 0.434695
# Epoch 400 | Train Loss 0.222812 | Val Loss 0.433758
# Epoch 500 | Train Loss 0.217634 | Val Loss 0.431592
# Epoch 600 | Train Loss 0.215163 | Val Loss 0.437477
# Epoch 700 | Train Loss 0.213289 | Val Loss 0.441027
# Early stopping at epoch 759
# X | train1 -> R² = -1.1611, MSE = 2.3302e-01
# X | train2 -> R² = -14.6835, MSE = 1.3215e+00
# X | test1 -> R² = -1.3579, MSE = 2.4701e-01
# X | test2 -> R² = -14.8589, MSE = 1.3051e+00
# X | test3 -> R² = 0.2948, MSE = 6.4879e-02
# X | val -> R² = -0.5599, MSE = 1.4916e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.473894 | Val Loss 0.705941
# Epoch 100 | Train Loss 0.248442 | Val Loss 0.504518
# Epoch 200 | Train Loss 0.233954 | Val Loss 0.466508
# Epoch 300 | Train Loss 0.228286 | Val Loss 0.438395
# Epoch 400 | Train Loss 0.222378 | Val Loss 0.429384
# Epoch 500 | Train Loss 0.217481 | Val Loss 0.451418
# Epoch 600 | Train Loss 0.215534 | Val Loss 0.460542
# Early stopping at epoch 687
# X | train1 -> R² = -1.2304, MSE = 2.4050e-01
# X | train2 -> R² = -14.8380, MSE = 1.3345e+00
# X | test1 -> R² = -1.3946, MSE = 2.5085e-01
# X | test2 -> R² = -15.0033, MSE = 1.3170e+00
# X | test3 -> R² = -0.3174, MSE = 1.2120e-01
# X | val -> R² = -1.0770, MSE = 1.9861e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.465947 | Val Loss 0.678130
# Epoch 100 | Train Loss 0.252327 | Val Loss 0.532938
# Epoch 200 | Train Loss 0.234744 | Val Loss 0.467270
# Epoch 300 | Train Loss 0.229473 | Val Loss 0.440932
# Epoch 400 | Train Loss 0.224820 | Val Loss 0.434365
# Epoch 500 | Train Loss 0.218710 | Val Loss 0.441482
# Epoch 600 | Train Loss 0.214248 | Val Loss 0.465266
# Early stopping at epoch 667
# X | train1 -> R² = -1.2404, MSE = 2.4157e-01
# X | train2 -> R² = -14.8247, MSE = 1.3334e+00
# X | test1 -> R² = -1.3757, MSE = 2.4888e-01
# X | test2 -> R² = -15.0264, MSE = 1.3189e+00
# X | test3 -> R² = 0.2189, MSE = 7.1868e-02
# X | val -> R² = -0.4539, MSE = 1.3903e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.487487 | Val Loss 0.673610
# Epoch 100 | Train Loss 0.246293 | Val Loss 0.484340
# Epoch 200 | Train Loss 0.234942 | Val Loss 0.454794
# Epoch 300 | Train Loss 0.229665 | Val Loss 0.438611
# Epoch 400 | Train Loss 0.225598 | Val Loss 0.433958
# Epoch 500 | Train Loss 0.222882 | Val Loss 0.430587
# Epoch 600 | Train Loss 0.220164 | Val Loss 0.429538
# Epoch 700 | Train Loss 0.216946 | Val Loss 0.433519
# Epoch 800 | Train Loss 0.214323 | Val Loss 0.443187
# Early stopping at epoch 819
# X | train1 -> R² = -1.1521, MSE = 2.3205e-01
# X | train2 -> R² = -14.7179, MSE = 1.3244e+00
# X | test1 -> R² = -1.4714, MSE = 2.5891e-01
# X | test2 -> R² = -14.8693, MSE = 1.3059e+00
# X | test3 -> R² = 0.8123, MSE = 1.7269e-02
# X | val -> R² = 0.6494, MSE = 3.3528e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.472094 | Val Loss 0.718808
# Epoch 100 | Train Loss 0.250581 | Val Loss 0.528156
# Epoch 200 | Train Loss 0.234765 | Val Loss 0.459011
# Epoch 300 | Train Loss 0.228902 | Val Loss 0.439897
# Epoch 400 | Train Loss 0.222354 | Val Loss 0.432264
# Epoch 500 | Train Loss 0.217265 | Val Loss 0.442130
# Epoch 600 | Train Loss 0.215716 | Val Loss 0.453317
# Early stopping at epoch 693
# X | train1 -> R² = -1.2089, MSE = 2.3818e-01
# X | train2 -> R² = -14.8183, MSE = 1.3329e+00
# X | test1 -> R² = -1.3135, MSE = 2.4237e-01
# X | test2 -> R² = -15.0125, MSE = 1.3177e+00
# X | test3 -> R² = 0.3431, MSE = 6.0437e-02
# X | val -> R² = -0.2604, MSE = 1.2052e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.464661 | Val Loss 0.686656
# Epoch 100 | Train Loss 0.245246 | Val Loss 0.486342
# Epoch 200 | Train Loss 0.232823 | Val Loss 0.450270
# Epoch 300 | Train Loss 0.226564 | Val Loss 0.437850
# Epoch 400 | Train Loss 0.220018 | Val Loss 0.441810
# Epoch 500 | Train Loss 0.216657 | Val Loss 0.461889
# Early stopping at epoch 578
# X | train1 -> R² = -1.2952, MSE = 2.4748e-01
# X | train2 -> R² = -14.9485, MSE = 1.3438e+00
# X | test1 -> R² = -1.4439, MSE = 2.5602e-01
# X | test2 -> R² = -15.0105, MSE = 1.3176e+00
# X | test3 -> R² = -0.0637, MSE = 9.7869e-02
# X | val -> R² = -0.6895, MSE = 1.6155e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.464701 | Val Loss 0.696756
# Epoch 100 | Train Loss 0.249572 | Val Loss 0.519644
# Epoch 200 | Train Loss 0.232996 | Val Loss 0.454286
# Epoch 300 | Train Loss 0.225081 | Val Loss 0.428379
# Epoch 400 | Train Loss 0.219472 | Val Loss 0.427275
# Epoch 500 | Train Loss 0.216834 | Val Loss 0.435919
# Epoch 600 | Train Loss 0.215515 | Val Loss 0.441340
# Early stopping at epoch 637
# X | train1 -> R² = -1.1732, MSE = 2.3433e-01
# X | train2 -> R² = -14.8994, MSE = 1.3397e+00
# X | test1 -> R² = -1.2762, MSE = 2.3845e-01
# X | test2 -> R² = -14.9548, MSE = 1.3130e+00
# X | test3 -> R² = -0.7361, MSE = 1.5973e-01
# X | val -> R² = -1.5705, MSE = 2.4580e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.455326 | Val Loss 0.655322
# Epoch 100 | Train Loss 0.240400 | Val Loss 0.458146
# Epoch 200 | Train Loss 0.232125 | Val Loss 0.440458
# Epoch 300 | Train Loss 0.226859 | Val Loss 0.432000
# Epoch 400 | Train Loss 0.222251 | Val Loss 0.424187
# Epoch 500 | Train Loss 0.218902 | Val Loss 0.431831
# Epoch 600 | Train Loss 0.216543 | Val Loss 0.452854
# Early stopping at epoch 677
# X | train1 -> R² = -1.1588, MSE = 2.3277e-01
# X | train2 -> R² = -14.9937, MSE = 1.3476e+00
# X | test1 -> R² = -1.2871, MSE = 2.3960e-01
# X | test2 -> R² = -15.1486, MSE = 1.3289e+00
# X | test3 -> R² = 0.5840, MSE = 3.8272e-02
# X | val -> R² = 0.1516, MSE = 8.1126e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.486950 | Val Loss 0.681557
# Epoch 100 | Train Loss 0.243061 | Val Loss 0.465996
# Epoch 200 | Train Loss 0.232663 | Val Loss 0.443590
# Epoch 300 | Train Loss 0.228009 | Val Loss 0.433743
# Epoch 400 | Train Loss 0.223657 | Val Loss 0.425528
# Epoch 500 | Train Loss 0.219171 | Val Loss 0.426258
# Epoch 600 | Train Loss 0.216102 | Val Loss 0.436602
# Epoch 700 | Train Loss 0.214028 | Val Loss 0.445258
# Early stopping at epoch 738
# X | train1 -> R² = -1.1025, MSE = 2.2670e-01
# X | train2 -> R² = -14.8627, MSE = 1.3366e+00
# X | test1 -> R² = -1.2657, MSE = 2.3735e-01
# X | test2 -> R² = -15.0775, MSE = 1.3231e+00
# X | test3 -> R² = 0.4256, MSE = 5.2849e-02
# X | val -> R² = 0.0916, MSE = 8.6866e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.491526 | Val Loss 0.629880
# Epoch 100 | Train Loss 0.245382 | Val Loss 0.476509
# Epoch 200 | Train Loss 0.235085 | Val Loss 0.454280
# Epoch 300 | Train Loss 0.229362 | Val Loss 0.440266
# Epoch 400 | Train Loss 0.225050 | Val Loss 0.438558
# Epoch 500 | Train Loss 0.221168 | Val Loss 0.435348
# Epoch 600 | Train Loss 0.218242 | Val Loss 0.438846
# Epoch 700 | Train Loss 0.216134 | Val Loss 0.453773
# Early stopping at epoch 787
# X | train1 -> R² = -1.2006, MSE = 2.3728e-01
# X | train2 -> R² = -14.9201, MSE = 1.3414e+00
# X | test1 -> R² = -1.3844, MSE = 2.4979e-01
# X | test2 -> R² = -15.1064, MSE = 1.3254e+00
# X | test3 -> R² = 0.7012, MSE = 2.7492e-02
# X | val -> R² = 0.3095, MSE = 6.6026e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.470441 | Val Loss 0.683506
# Epoch 100 | Train Loss 0.252364 | Val Loss 0.517105
# Epoch 200 | Train Loss 0.235986 | Val Loss 0.471372
# Epoch 300 | Train Loss 0.228385 | Val Loss 0.441840
# Epoch 400 | Train Loss 0.223109 | Val Loss 0.437656
# Epoch 500 | Train Loss 0.217226 | Val Loss 0.450080
# Epoch 600 | Train Loss 0.215441 | Val Loss 0.459148
# Early stopping at epoch 656
# X | train1 -> R² = -1.3329, MSE = 2.5155e-01
# X | train2 -> R² = -15.1005, MSE = 1.3566e+00
# X | test1 -> R² = -1.5112, MSE = 2.6308e-01
# X | test2 -> R² = -15.2584, MSE = 1.3380e+00
# X | test3 -> R² = -0.4669, MSE = 1.3496e-01
# X | val -> R² = -1.4514, MSE = 2.3441e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.460010 | Val Loss 0.630457
# Epoch 100 | Train Loss 0.245094 | Val Loss 0.489266
# Epoch 200 | Train Loss 0.233344 | Val Loss 0.450469
# Epoch 300 | Train Loss 0.226885 | Val Loss 0.432407
# Epoch 400 | Train Loss 0.223275 | Val Loss 0.423916
# Epoch 500 | Train Loss 0.220068 | Val Loss 0.420655
# Epoch 600 | Train Loss 0.216806 | Val Loss 0.424638
# Epoch 700 | Train Loss 0.214303 | Val Loss 0.430135
# Early stopping at epoch 764
# X | train1 -> R² = -1.1364, MSE = 2.3036e-01
# X | train2 -> R² = -14.6107, MSE = 1.3154e+00
# X | test1 -> R² = -1.4197, MSE = 2.5348e-01
# X | test2 -> R² = -14.7776, MSE = 1.2984e+00
# X | test3 -> R² = 0.1112, MSE = 8.1777e-02
# X | val -> R² = 0.0215, MSE = 9.3565e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.459869 | Val Loss 0.648608
# Epoch 100 | Train Loss 0.247146 | Val Loss 0.486267
# Epoch 200 | Train Loss 0.233425 | Val Loss 0.446184
# Epoch 300 | Train Loss 0.227346 | Val Loss 0.436312
# Epoch 400 | Train Loss 0.223069 | Val Loss 0.434465
# Epoch 500 | Train Loss 0.217874 | Val Loss 0.449407
# Epoch 600 | Train Loss 0.215258 | Val Loss 0.473912
# Early stopping at epoch 641
# X | train1 -> R² = -1.2916, MSE = 2.4710e-01
# X | train2 -> R² = -14.7852, MSE = 1.3301e+00
# X | test1 -> R² = -1.5057, MSE = 2.6250e-01
# X | test2 -> R² = -14.8607, MSE = 1.3052e+00
# X | test3 -> R² = 0.8139, MSE = 1.7126e-02
# X | val -> R² = 0.5987, MSE = 3.8369e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.480196 | Val Loss 0.679856
# Epoch 100 | Train Loss 0.249061 | Val Loss 0.513829
# Epoch 200 | Train Loss 0.235599 | Val Loss 0.471228
# Epoch 300 | Train Loss 0.231409 | Val Loss 0.450171
# Epoch 400 | Train Loss 0.226884 | Val Loss 0.434676
# Epoch 500 | Train Loss 0.223785 | Val Loss 0.426499
# Epoch 600 | Train Loss 0.221121 | Val Loss 0.420572
# Epoch 700 | Train Loss 0.217852 | Val Loss 0.423008
# Epoch 800 | Train Loss 0.214369 | Val Loss 0.426945
# Early stopping at epoch 895
# X | train1 -> R² = -1.1351, MSE = 2.3022e-01
# X | train2 -> R² = -14.7181, MSE = 1.3244e+00
# X | test1 -> R² = -1.4187, MSE = 2.5339e-01
# X | test2 -> R² = -14.8673, MSE = 1.3058e+00
# X | test3 -> R² = 0.5735, MSE = 3.9238e-02
# X | val -> R² = 0.1775, MSE = 7.8647e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.486444 | Val Loss 0.670603
# Epoch 100 | Train Loss 0.250373 | Val Loss 0.508027
# Epoch 200 | Train Loss 0.235016 | Val Loss 0.456305
# Epoch 300 | Train Loss 0.229101 | Val Loss 0.437054
# Epoch 400 | Train Loss 0.224678 | Val Loss 0.432371
# Epoch 500 | Train Loss 0.219597 | Val Loss 0.428280
# Epoch 600 | Train Loss 0.216033 | Val Loss 0.429466
# Epoch 700 | Train Loss 0.214162 | Val Loss 0.432447
# Epoch 800 | Train Loss 0.213024 | Val Loss 0.435699
# Early stopping at epoch 809
# X | train1 -> R² = -1.1392, MSE = 2.3066e-01
# X | train2 -> R² = -14.7532, MSE = 1.3274e+00
# X | test1 -> R² = -1.3185, MSE = 2.4288e-01
# X | test2 -> R² = -14.9481, MSE = 1.3124e+00
# X | test3 -> R² = 0.4990, MSE = 4.6092e-02
# X | val -> R² = -0.1812, MSE = 1.1295e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.470133 | Val Loss 0.684047
# Epoch 100 | Train Loss 0.253159 | Val Loss 0.532627
# Epoch 200 | Train Loss 0.234678 | Val Loss 0.454307
# Epoch 300 | Train Loss 0.228362 | Val Loss 0.432603
# Epoch 400 | Train Loss 0.222795 | Val Loss 0.436225
# Epoch 500 | Train Loss 0.218398 | Val Loss 0.452197
# Epoch 600 | Train Loss 0.216328 | Val Loss 0.464057
# Early stopping at epoch 624
# X | train1 -> R² = -1.3393, MSE = 2.5224e-01
# X | train2 -> R² = -14.8234, MSE = 1.3333e+00
# X | test1 -> R² = -1.5338, MSE = 2.6544e-01
# X | test2 -> R² = -14.8523, MSE = 1.3045e+00
# X | test3 -> R² = -0.0231, MSE = 9.4126e-02
# X | val -> R² = -0.6695, MSE = 1.5965e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.568279 | Val Loss 0.670404
# Epoch 100 | Train Loss 0.370776 | Val Loss 0.405666
# Epoch 200 | Train Loss 0.359545 | Val Loss 0.405115
# Epoch 300 | Train Loss 0.354475 | Val Loss 0.411207
# Epoch 400 | Train Loss 0.351721 | Val Loss 0.403343
# Early stopping at epoch 436
# X | train1 -> R² = 0.6501, MSE = 3.7724e-02
# X | train2 -> R² = -1.6934, MSE = 2.2695e-01
# X | test1 -> R² = 0.7324, MSE = 2.8029e-02
# X | test2 -> R² = -1.5579, MSE = 2.1050e-01
# X | test3 -> R² = 0.9162, MSE = 7.7099e-03
# X | val -> R² = 0.8884, MSE = 1.0668e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.561631 | Val Loss 0.656557
# Epoch 100 | Train Loss 0.370364 | Val Loss 0.401743
# Epoch 200 | Train Loss 0.358644 | Val Loss 0.401398
# Epoch 300 | Train Loss 0.353563 | Val Loss 0.404704
# Epoch 400 | Train Loss 0.351149 | Val Loss 0.402082
# Early stopping at epoch 437
# X | train1 -> R² = 0.6100, MSE = 4.2050e-02
# X | train2 -> R² = -1.7726, MSE = 2.3362e-01
# X | test1 -> R² = 0.6964, MSE = 3.1805e-02
# X | test2 -> R² = -1.6441, MSE = 2.1759e-01
# X | test3 -> R² = 0.9040, MSE = 8.8290e-03
# X | val -> R² = 0.9478, MSE = 4.9934e-03
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.563013 | Val Loss 0.652301
# Epoch 100 | Train Loss 0.370694 | Val Loss 0.406967
# Epoch 200 | Train Loss 0.359908 | Val Loss 0.397727
# Epoch 300 | Train Loss 0.354867 | Val Loss 0.404781
# Epoch 400 | Train Loss 0.350635 | Val Loss 0.403086
# Early stopping at epoch 455
# X | train1 -> R² = 0.6501, MSE = 3.7732e-02
# X | train2 -> R² = -1.7622, MSE = 2.3275e-01
# X | test1 -> R² = 0.7187, MSE = 2.9469e-02
# X | test2 -> R² = -1.6087, MSE = 2.1468e-01
# X | test3 -> R² = 0.8826, MSE = 1.0798e-02
# X | val -> R² = 0.8021, MSE = 1.8924e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.571679 | Val Loss 0.686097
# Epoch 100 | Train Loss 0.370268 | Val Loss 0.407288
# Epoch 200 | Train Loss 0.359021 | Val Loss 0.396867
# Epoch 300 | Train Loss 0.354192 | Val Loss 0.402657
# Epoch 400 | Train Loss 0.351791 | Val Loss 0.401382
# Early stopping at epoch 456
# X | train1 -> R² = 0.6631, MSE = 3.6322e-02
# X | train2 -> R² = -1.8721, MSE = 2.4201e-01
# X | test1 -> R² = 0.7351, MSE = 2.7755e-02
# X | test2 -> R² = -1.7230, MSE = 2.2409e-01
# X | test3 -> R² = 0.9288, MSE = 6.5503e-03
# X | val -> R² = 0.9077, MSE = 8.8240e-03
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.551395 | Val Loss 0.622767
# Epoch 100 | Train Loss 0.367255 | Val Loss 0.407923
# Epoch 200 | Train Loss 0.358983 | Val Loss 0.399884
# Epoch 300 | Train Loss 0.353922 | Val Loss 0.411739
# Epoch 400 | Train Loss 0.351770 | Val Loss 0.416596
# Early stopping at epoch 460
# X | train1 -> R² = 0.6411, MSE = 3.8695e-02
# X | train2 -> R² = -1.8376, MSE = 2.3910e-01
# X | test1 -> R² = 0.7095, MSE = 3.0434e-02
# X | test2 -> R² = -1.6877, MSE = 2.2118e-01
# X | test3 -> R² = 0.8543, MSE = 1.3404e-02
# X | val -> R² = 0.8010, MSE = 1.9027e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.572143 | Val Loss 0.678623
# Epoch 100 | Train Loss 0.369422 | Val Loss 0.405695
# Epoch 200 | Train Loss 0.360468 | Val Loss 0.396568
# Epoch 300 | Train Loss 0.354532 | Val Loss 0.405588
# Epoch 400 | Train Loss 0.350304 | Val Loss 0.401122
# Early stopping at epoch 475
# X | train1 -> R² = 0.6315, MSE = 3.9736e-02
# X | train2 -> R² = -1.7523, MSE = 2.3191e-01
# X | test1 -> R² = 0.6947, MSE = 3.1986e-02
# X | test2 -> R² = -1.6116, MSE = 2.1492e-01
# X | test3 -> R² = 0.9398, MSE = 5.5376e-03
# X | val -> R² = 0.8989, MSE = 9.6628e-03
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.561325 | Val Loss 0.653311
# Epoch 100 | Train Loss 0.368269 | Val Loss 0.408501
# Epoch 200 | Train Loss 0.359058 | Val Loss 0.397238
# Epoch 300 | Train Loss 0.353966 | Val Loss 0.405896
# Epoch 400 | Train Loss 0.350753 | Val Loss 0.409011
# Early stopping at epoch 468
# X | train1 -> R² = 0.6655, MSE = 3.6073e-02
# X | train2 -> R² = -1.8507, MSE = 2.4020e-01
# X | test1 -> R² = 0.7227, MSE = 2.9054e-02
# X | test2 -> R² = -1.7175, MSE = 2.2363e-01
# X | test3 -> R² = 0.9312, MSE = 6.3330e-03
# X | val -> R² = 0.8820, MSE = 1.1283e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.574292 | Val Loss 0.680341
# Epoch 100 | Train Loss 0.370040 | Val Loss 0.406299
# Epoch 200 | Train Loss 0.360571 | Val Loss 0.395717
# Epoch 300 | Train Loss 0.354185 | Val Loss 0.397428
# Epoch 400 | Train Loss 0.351245 | Val Loss 0.398086
# Early stopping at epoch 488
# X | train1 -> R² = 0.6258, MSE = 4.0345e-02
# X | train2 -> R² = -1.8773, MSE = 2.4244e-01
# X | test1 -> R² = 0.6843, MSE = 3.3072e-02
# X | test2 -> R² = -1.7264, MSE = 2.2436e-01
# X | test3 -> R² = 0.9404, MSE = 5.4822e-03
# X | val -> R² = 0.8767, MSE = 1.1793e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.577108 | Val Loss 0.689191
# Epoch 100 | Train Loss 0.370381 | Val Loss 0.412619
# Epoch 200 | Train Loss 0.359732 | Val Loss 0.403907
# Epoch 300 | Train Loss 0.355904 | Val Loss 0.410854
# Epoch 400 | Train Loss 0.351946 | Val Loss 0.401447
# Early stopping at epoch 441
# X | train1 -> R² = 0.6498, MSE = 3.7763e-02
# X | train2 -> R² = -1.6782, MSE = 2.2567e-01
# X | test1 -> R² = 0.7322, MSE = 2.8059e-02
# X | test2 -> R² = -1.5336, MSE = 2.0850e-01
# X | test3 -> R² = 0.8405, MSE = 1.4676e-02
# X | val -> R² = 0.8175, MSE = 1.7456e-02
# Figura salva.
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.587299 | Val Loss 0.718491
# Epoch 100 | Train Loss 0.373028 | Val Loss 0.414290
# Epoch 200 | Train Loss 0.358717 | Val Loss 0.405552
# Epoch 300 | Train Loss 0.352886 | Val Loss 0.404640
# Epoch 400 | Train Loss 0.350569 | Val Loss 0.400060
# Epoch 500 | Train Loss 0.349372 | Val Loss 0.398575
# Epoch 600 | Train Loss 0.348639 | Val Loss 0.398016
# Epoch 700 | Train Loss 0.348082 | Val Loss 0.397980
# Epoch 800 | Train Loss 0.347719 | Val Loss 0.398910
# Early stopping at epoch 822
# X | train1 -> R² = 0.5985, MSE = 4.3289e-02
# X | train2 -> R² = -1.8889, MSE = 2.4342e-01
# X | test1 -> R² = 0.5896, MSE = 4.2994e-02
# X | test2 -> R² = -1.7952, MSE = 2.3003e-01
# X | test3 -> R² = 0.9561, MSE = 4.0353e-03
# ...
# Epoch 1300 | Train Loss 0.348396 | Val Loss 0.393694
# Early stopping at epoch 1321
# X | train1 -> R² = 0.6106, MSE = 4.1984e-02
# X | train2 -> R² = -1.9169, MSE = 2.4578e-01
# X | test1 -> R² = 0.6039, MSE = 4.1494e-02
# X | test2 -> R² = -1.7865, MSE = 2.2931e-01
# X | test3 -> R² = 0.7708, MSE = 2.1091e-02
# X | val -> R² = 0.3392, MSE = 6.3191e-02
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.597179 | Val Loss 0.750360
# Epoch 100 | Train Loss 0.463450 | Val Loss 0.490829
# Epoch 200 | Train Loss 0.390919 | Val Loss 0.412937
# Epoch 300 | Train Loss 0.365552 | Val Loss 0.412986
# Epoch 400 | Train Loss 0.362075 | Val Loss 0.406982
# Epoch 500 | Train Loss 0.360748 | Val Loss 0.401590
# Epoch 600 | Train Loss 0.359066 | Val Loss 0.396588
# Epoch 700 | Train Loss 0.355238 | Val Loss 0.394685
# Epoch 800 | Train Loss 0.351706 | Val Loss 0.393117
# Epoch 900 | Train Loss 0.349661 | Val Loss 0.392592
# Epoch 1000 | Train Loss 0.348796 | Val Loss 0.393122
# Early stopping at epoch 1098
# X | train1 -> R² = 0.5687, MSE = 4.6505e-02
# X | train2 -> R² = -1.9924, MSE = 2.5214e-01
# X | test1 -> R² = 0.5659, MSE = 4.5473e-02
# X | test2 -> R² = -1.8529, MSE = 2.3477e-01
# X | test3 -> R² = 0.8985, MSE = 9.3417e-03
# X | val -> R² = 0.7228, MSE = 2.6507e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.598631 | Val Loss 0.753807
# Epoch 100 | Train Loss 0.465322 | Val Loss 0.511747
# Epoch 200 | Train Loss 0.372826 | Val Loss 0.421033
# Epoch 300 | Train Loss 0.363957 | Val Loss 0.415331
# Epoch 400 | Train Loss 0.362431 | Val Loss 0.417339
# Epoch 500 | Train Loss 0.361688 | Val Loss 0.415826
# Early stopping at epoch 551
# X | train1 -> R² = 0.8636, MSE = 1.4706e-02
# X | train2 -> R² = -1.8184, MSE = 2.3748e-01
# X | test1 -> R² = 0.9038, MSE = 1.0073e-02
# X | test2 -> R² = -1.7540, MSE = 2.2663e-01
# X | test3 -> R² = 0.0109, MSE = 9.1000e-02
# X | val -> R² = 0.2992, MSE = 6.7009e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.597303 | Val Loss 0.750906
# Epoch 100 | Train Loss 0.464396 | Val Loss 0.492302
# Epoch 200 | Train Loss 0.373364 | Val Loss 0.421936
# Epoch 300 | Train Loss 0.364749 | Val Loss 0.426915
# Epoch 400 | Train Loss 0.362975 | Val Loss 0.417122
# Epoch 500 | Train Loss 0.361391 | Val Loss 0.408106
# Epoch 600 | Train Loss 0.359681 | Val Loss 0.398909
# Epoch 700 | Train Loss 0.356951 | Val Loss 0.394506
# Epoch 800 | Train Loss 0.353408 | Val Loss 0.400456
# Epoch 900 | Train Loss 0.350534 | Val Loss 0.405100
# Early stopping at epoch 982
# X | train1 -> R² = 0.5836, MSE = 4.4895e-02
# X | train2 -> R² = -1.9328, MSE = 2.4712e-01
# X | test1 -> R² = 0.6209, MSE = 3.9717e-02
# X | test2 -> R² = -1.8151, MSE = 2.3166e-01
# X | test3 -> R² = 0.9071, MSE = 8.5467e-03
# X | val -> R² = 0.9225, MSE = 7.4133e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.599098 | Val Loss 0.754480
# Epoch 100 | Train Loss 0.461962 | Val Loss 0.509182
# Epoch 200 | Train Loss 0.383460 | Val Loss 0.422866
# Epoch 300 | Train Loss 0.363634 | Val Loss 0.412825
# Epoch 400 | Train Loss 0.361242 | Val Loss 0.407476
# Epoch 500 | Train Loss 0.359025 | Val Loss 0.399660
# Epoch 600 | Train Loss 0.356239 | Val Loss 0.392745
# Epoch 700 | Train Loss 0.353202 | Val Loss 0.390289
# Epoch 800 | Train Loss 0.350741 | Val Loss 0.392777
# Epoch 900 | Train Loss 0.349438 | Val Loss 0.395502
# Early stopping at epoch 953
# X | train1 -> R² = 0.5997, MSE = 4.3161e-02
# X | train2 -> R² = -1.9375, MSE = 2.4751e-01
# X | test1 -> R² = 0.6085, MSE = 4.1013e-02
# X | test2 -> R² = -1.8474, MSE = 2.3432e-01
# X | test3 -> R² = 0.7440, MSE = 2.3550e-02
# X | val -> R² = 0.5468, MSE = 4.3341e-02
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.597351 | Val Loss 0.750850
# Epoch 100 | Train Loss 0.457836 | Val Loss 0.472127
# Epoch 200 | Train Loss 0.370618 | Val Loss 0.405696
# Epoch 300 | Train Loss 0.363536 | Val Loss 0.403911
# Epoch 400 | Train Loss 0.362060 | Val Loss 0.407212
# Epoch 500 | Train Loss 0.361402 | Val Loss 0.408112
# Early stopping at epoch 525
# X | train1 -> R² = 0.8680, MSE = 1.4228e-02
# X | train2 -> R² = -1.6233, MSE = 2.2104e-01
# X | test1 -> R² = 0.9058, MSE = 9.8636e-03
# X | test2 -> R² = -1.5268, MSE = 2.0794e-01
# X | test3 -> R² = 0.4952, MSE = 4.6439e-02
# X | val -> R² = 0.6249, MSE = 3.5869e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.602652 | Val Loss 0.760432
# Epoch 100 | Train Loss 0.486927 | Val Loss 0.539941
# Epoch 200 | Train Loss 0.387719 | Val Loss 0.423477
# Epoch 300 | Train Loss 0.361202 | Val Loss 0.406612
# Epoch 400 | Train Loss 0.357817 | Val Loss 0.394793
# Epoch 500 | Train Loss 0.355204 | Val Loss 0.392180
# Epoch 600 | Train Loss 0.353176 | Val Loss 0.388478
# Epoch 700 | Train Loss 0.351261 | Val Loss 0.386356
# Epoch 800 | Train Loss 0.349820 | Val Loss 0.388617
# Epoch 900 | Train Loss 0.348942 | Val Loss 0.391855
# Early stopping at epoch 973
# X | train1 -> R² = 0.6211, MSE = 4.0853e-02
# X | train2 -> R² = -1.9652, MSE = 2.4985e-01
# X | test1 -> R² = 0.5844, MSE = 4.3535e-02
# X | test2 -> R² = -1.8167, MSE = 2.3180e-01
# X | test3 -> R² = 0.7744, MSE = 2.0755e-02
# X | val -> R² = 0.6313, MSE = 3.5252e-02
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.597311 | Val Loss 0.751168
# Epoch 100 | Train Loss 0.445036 | Val Loss 0.512469
# Epoch 200 | Train Loss 0.389207 | Val Loss 0.448478
# Epoch 300 | Train Loss 0.367432 | Val Loss 0.428200
# Epoch 400 | Train Loss 0.364566 | Val Loss 0.418875
# Epoch 500 | Train Loss 0.363245 | Val Loss 0.413526
# Epoch 600 | Train Loss 0.362327 | Val Loss 0.410193
# Epoch 700 | Train Loss 0.361518 | Val Loss 0.408110
# Epoch 800 | Train Loss 0.360570 | Val Loss 0.405106
# Epoch 900 | Train Loss 0.356368 | Val Loss 0.412704
# Epoch 1000 | Train Loss 0.350874 | Val Loss 0.423371
# Epoch 1100 | Train Loss 0.349249 | Val Loss 0.420169
# Early stopping at epoch 1115
# X | train1 -> R² = 0.6363, MSE = 3.9216e-02
# X | train2 -> R² = -1.9343, MSE = 2.4724e-01
# X | test1 -> R² = 0.6723, MSE = 3.4326e-02
# X | test2 -> R² = -1.7810, MSE = 2.2886e-01
# X | test3 -> R² = 0.1079, MSE = 8.2076e-02
# X | val -> R² = 0.5333, MSE = 4.4626e-02
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.597868 | Val Loss 0.752001
# Epoch 100 | Train Loss 0.456054 | Val Loss 0.503214
# Epoch 200 | Train Loss 0.399077 | Val Loss 0.462537
# Epoch 300 | Train Loss 0.368092 | Val Loss 0.456574
# Epoch 400 | Train Loss 0.364925 | Val Loss 0.437685
# Epoch 500 | Train Loss 0.362660 | Val Loss 0.417903
# Epoch 600 | Train Loss 0.361805 | Val Loss 0.414200
# Epoch 700 | Train Loss 0.361096 | Val Loss 0.410269
# Epoch 800 | Train Loss 0.359664 | Val Loss 0.403546
# Epoch 900 | Train Loss 0.356554 | Val Loss 0.399064
# Epoch 1000 | Train Loss 0.352071 | Val Loss 0.394282
# Epoch 1100 | Train Loss 0.349299 | Val Loss 0.398457
# Epoch 1200 | Train Loss 0.348652 | Val Loss 0.401883
# Early stopping at epoch 1278
# X | train1 -> R² = 0.5491, MSE = 4.8617e-02
# X | train2 -> R² = -1.9394, MSE = 2.4768e-01
# X | test1 -> R² = 0.5000, MSE = 5.2378e-02
# X | test2 -> R² = -1.8341, MSE = 2.3323e-01
# X | test3 -> R² = 0.9529, MSE = 4.3314e-03
# X | val -> R² = 0.8746, MSE = 1.1995e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.598226 | Val Loss 0.752646
# Epoch 100 | Train Loss 0.462816 | Val Loss 0.483423
# Epoch 200 | Train Loss 0.397451 | Val Loss 0.413320
# Epoch 300 | Train Loss 0.363978 | Val Loss 0.420140
# Epoch 400 | Train Loss 0.362039 | Val Loss 0.419236
# Early stopping at epoch 481
# X | train1 -> R² = 0.8264, MSE = 1.8720e-02
# X | train2 -> R² = -3.0031, MSE = 3.3730e-01
# X | test1 -> R² = 0.8302, MSE = 1.7792e-02
# X | test2 -> R² = -3.0069, MSE = 3.2974e-01
# X | test3 -> R² = 0.3929, MSE = 5.5860e-02
# X | val -> R² = 0.5040, MSE = 4.7428e-02
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.597445 | Val Loss 0.750919
# Epoch 100 | Train Loss 0.451210 | Val Loss 0.515068
# Epoch 200 | Train Loss 0.407153 | Val Loss 0.457098
# Epoch 300 | Train Loss 0.393922 | Val Loss 0.420390
# Epoch 400 | Train Loss 0.390356 | Val Loss 0.407916
# Epoch 500 | Train Loss 0.389295 | Val Loss 0.408564
# Epoch 600 | Train Loss 0.388374 | Val Loss 0.411648
# Early stopping at epoch 692
# X | train1 -> R² = 0.6722, MSE = 3.5341e-02
# X | train2 -> R² = -2.3789, MSE = 2.8471e-01
# X | test1 -> R² = 0.7308, MSE = 2.8199e-02
# X | test2 -> R² = -2.3698, MSE = 2.7731e-01
# X | test3 -> R² = 0.1862, MSE = 7.4877e-02
# X | val -> R² = 0.6239, MSE = 3.5961e-02
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.599567 | Val Loss 0.755213
# Epoch 100 | Train Loss 0.459447 | Val Loss 0.511078
# Epoch 200 | Train Loss 0.401634 | Val Loss 0.471553
# Epoch 300 | Train Loss 0.368493 | Val Loss 0.413213
# Epoch 400 | Train Loss 0.362106 | Val Loss 0.405137
# Epoch 500 | Train Loss 0.360630 | Val Loss 0.402496
# Epoch 600 | Train Loss 0.359029 | Val Loss 0.399925
# Epoch 700 | Train Loss 0.356690 | Val Loss 0.394887
# Epoch 800 | Train Loss 0.355281 | Val Loss 0.391398
# Epoch 900 | Train Loss 0.354599 | Val Loss 0.390506
# Epoch 1000 | Train Loss 0.354140 | Val Loss 0.390430
# Epoch 1100 | Train Loss 0.353681 | Val Loss 0.390716
# Early stopping at epoch 1129
# X | train1 -> R² = 0.6132, MSE = 4.1703e-02
# X | train2 -> R² = -1.7391, MSE = 2.3080e-01
# X | test1 -> R² = 0.6303, MSE = 3.8725e-02
# X | test2 -> R² = -1.6903, MSE = 2.2140e-01
# X | test3 -> R² = 0.9569, MSE = 3.9665e-03
# X | val -> R² = 0.9408, MSE = 5.6592e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.598503 | Val Loss 0.753156
# Epoch 100 | Train Loss 0.463925 | Val Loss 0.504802
# Epoch 200 | Train Loss 0.433506 | Val Loss 0.488308
# Epoch 300 | Train Loss 0.405546 | Val Loss 0.442762
# Epoch 400 | Train Loss 0.381252 | Val Loss 0.435881
# Epoch 500 | Train Loss 0.366297 | Val Loss 0.419920
# Epoch 600 | Train Loss 0.363688 | Val Loss 0.412485
# Epoch 700 | Train Loss 0.362411 | Val Loss 0.410186
# Epoch 800 | Train Loss 0.361327 | Val Loss 0.407032
# Epoch 900 | Train Loss 0.360122 | Val Loss 0.400704
# Epoch 1000 | Train Loss 0.358465 | Val Loss 0.392807
# Epoch 1100 | Train Loss 0.354660 | Val Loss 0.405241
# Epoch 1200 | Train Loss 0.351990 | Val Loss 0.418590
# Epoch 1300 | Train Loss 0.350446 | Val Loss 0.425966
# Early stopping at epoch 1304
# X | train1 -> R² = 0.5523, MSE = 4.8278e-02
# X | train2 -> R² = -1.9939, MSE = 2.5226e-01
# X | test1 -> R² = 0.5548, MSE = 4.6640e-02
# X | test2 -> R² = -1.8106, MSE = 2.3129e-01
# X | test3 -> R² = 0.9217, MSE = 7.2027e-03
# X | val -> R² = 0.8967, MSE = 9.8736e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.596433 | Val Loss 0.748362
# Epoch 100 | Train Loss 0.460024 | Val Loss 0.472148
# Epoch 200 | Train Loss 0.396927 | Val Loss 0.421554
# Epoch 300 | Train Loss 0.392314 | Val Loss 0.426670
# Epoch 400 | Train Loss 0.387824 | Val Loss 0.416607
# Epoch 500 | Train Loss 0.369523 | Val Loss 0.407184
# Epoch 600 | Train Loss 0.360689 | Val Loss 0.399487
# Epoch 700 | Train Loss 0.357610 | Val Loss 0.390533
# Epoch 800 | Train Loss 0.355176 | Val Loss 0.389164
# Epoch 900 | Train Loss 0.352304 | Val Loss 0.394376
# Epoch 1000 | Train Loss 0.350350 | Val Loss 0.402872
# Early stopping at epoch 1029
# X | train1 -> R² = 0.6057, MSE = 4.2510e-02
# X | train2 -> R² = -2.0036, MSE = 2.5308e-01
# X | test1 -> R² = 0.6091, MSE = 4.0948e-02
# X | test2 -> R² = -1.9239, MSE = 2.4062e-01
# X | test3 -> R² = 0.8996, MSE = 9.2392e-03
# X | val -> R² = 0.9547, MSE = 4.3273e-03
# Figura salva.
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.538271 | Val Loss 0.750948
# Epoch 100 | Train Loss 0.370043 | Val Loss 0.521169
# Epoch 200 | Train Loss 0.322008 | Val Loss 0.479028
# Epoch 300 | Train Loss 0.309503 | Val Loss 0.437920
# Epoch 400 | Train Loss 0.302550 | Val Loss 0.412093
# Epoch 500 | Train Loss 0.296759 | Val Loss 0.407322
# Epoch 600 | Train Loss 0.294837 | Val Loss 0.408863
# Epoch 700 | Train Loss 0.294018 | Val Loss 0.410601
# Early stopping at epoch 737
# X | train1 -> R² = -0.2024, MSE = 1.2965e-01
# X | train2 -> R² = -7.3261, MSE = 7.0156e-01
# X | test1 -> R² = -0.2203, MSE = 1.2784e-01
# X | test2 -> R² = -7.1110, MSE = 6.6748e-01
# X | test3 -> R² = -0.7071, MSE = 1.5706e-01
# X | val -> R² = -1.3038, MSE = 2.2029e-01
# Modelo [16, 8] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.536679 | Val Loss 0.751423
# Epoch 100 | Train Loss 0.365567 | Val Loss 0.509088
# Epoch 200 | Train Loss 0.321577 | Val Loss 0.484727
# Epoch 300 | Train Loss 0.310574 | Val Loss 0.424078
# Epoch 400 | Train Loss 0.308646 | Val Loss 0.417409
# Epoch 500 | Train Loss 0.306281 | Val Loss 0.408577
# Epoch 600 | Train Loss 0.302194 | Val Loss 0.402980
# Epoch 700 | Train Loss 0.298828 | Val Loss 0.408153
# Epoch 800 | Train Loss 0.295426 | Val Loss 0.423880
# Early stopping at epoch 859
# X | train1 -> R² = -0.1350, MSE = 1.2239e-01
# X | train2 -> R² = -7.0362, MSE = 6.7713e-01
# X | test1 -> R² = -0.1605, MSE = 1.2158e-01
# X | test2 -> R² = -6.8953, MSE = 6.4973e-01
# X | test3 -> R² = 0.4729, MSE = 4.8498e-02
# X | val -> R² = 0.1613, MSE = 8.0201e-02
# Modelo [16, 8] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.540432 | Val Loss 0.755506
# Epoch 100 | Train Loss 0.380819 | Val Loss 0.540592
# Epoch 200 | Train Loss 0.328528 | Val Loss 0.530393
# Epoch 300 | Train Loss 0.310994 | Val Loss 0.439205
# Epoch 400 | Train Loss 0.302729 | Val Loss 0.420641
# Epoch 500 | Train Loss 0.296513 | Val Loss 0.430361
# Epoch 600 | Train Loss 0.295033 | Val Loss 0.443699
# Early stopping at epoch 693
# X | train1 -> R² = -0.1456, MSE = 1.2353e-01
# X | train2 -> R² = -7.0624, MSE = 6.7934e-01
# X | test1 -> R² = -0.2064, MSE = 1.2638e-01
# X | test2 -> R² = -6.9367, MSE = 6.5314e-01
# X | test3 -> R² = 0.2556, MSE = 6.8486e-02
# X | val -> R² = -0.4734, MSE = 1.4089e-01
# Modelo [16, 8] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.538841 | Val Loss 0.756329
# Epoch 100 | Train Loss 0.354353 | Val Loss 0.516383
# Epoch 200 | Train Loss 0.315584 | Val Loss 0.476825
# Epoch 300 | Train Loss 0.309727 | Val Loss 0.434803
# Epoch 400 | Train Loss 0.307330 | Val Loss 0.415478
# Epoch 500 | Train Loss 0.305032 | Val Loss 0.404723
# Epoch 600 | Train Loss 0.300776 | Val Loss 0.404942
# Epoch 700 | Train Loss 0.296756 | Val Loss 0.417415
# Epoch 800 | Train Loss 0.294920 | Val Loss 0.430449
# Early stopping at epoch 817
# X | train1 -> R² = -0.0669, MSE = 1.1504e-01
# X | train2 -> R² = -7.0359, MSE = 6.7711e-01
# X | test1 -> R² = -0.0328, MSE = 1.0819e-01
# X | test2 -> R² = -6.9666, MSE = 6.5560e-01
# X | test3 -> R² = 0.6040, MSE = 3.6433e-02
# X | val -> R² = 0.4340, MSE = 5.4126e-02
# Modelo [16, 8] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.538462 | Val Loss 0.751590
# Epoch 100 | Train Loss 0.379337 | Val Loss 0.523813
# Epoch 200 | Train Loss 0.321896 | Val Loss 0.484306
# Epoch 300 | Train Loss 0.310652 | Val Loss 0.441353
# Epoch 400 | Train Loss 0.307137 | Val Loss 0.420952
# Epoch 500 | Train Loss 0.304388 | Val Loss 0.411760
# Epoch 600 | Train Loss 0.297978 | Val Loss 0.419845
# Epoch 700 | Train Loss 0.295329 | Val Loss 0.430765
# Early stopping at epoch 786
# X | train1 -> R² = -0.0223, MSE = 1.1023e-01
# X | train2 -> R² = -7.2108, MSE = 6.9184e-01
# X | test1 -> R² = -0.0385, MSE = 1.0879e-01
# X | test2 -> R² = -7.2009, MSE = 6.7488e-01
# X | test3 -> R² = 0.9059, MSE = 8.6622e-03
# X | val -> R² = 0.8386, MSE = 1.5437e-02
# Figura salva.
# Modelo [16, 8] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.538271 | Val Loss 0.752233
# Epoch 100 | Train Loss 0.362572 | Val Loss 0.515272
# Epoch 200 | Train Loss 0.328363 | Val Loss 0.504636
# Epoch 300 | Train Loss 0.308671 | Val Loss 0.429559
# Epoch 400 | Train Loss 0.300762 | Val Loss 0.410462
# Epoch 500 | Train Loss 0.295752 | Val Loss 0.412608
# Epoch 600 | Train Loss 0.294641 | Val Loss 0.417132
# Epoch 700 | Train Loss 0.294114 | Val Loss 0.421661
# Early stopping at epoch 721
# X | train1 -> R² = -0.2110, MSE = 1.3058e-01
# X | train2 -> R² = -7.1072, MSE = 6.8312e-01
# X | test1 -> R² = -0.2359, MSE = 1.2947e-01
# X | test2 -> R² = -7.0226, MSE = 6.6021e-01
