# %% [markdown]
# - Entradas: SWdRef, SWeRef, Theta
# - Saidas: X e Y
# - Trajetorias: ZZ + ZZRoted`

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 2)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 2)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 10
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test")
        )

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva.")

        plt.close(fig)

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 0.806875 | Val Loss 0.755258
# Epoch 100 | Train Loss 0.580158 | Val Loss 0.556171
# Epoch 200 | Train Loss 0.543865 | Val Loss 0.532294
# Epoch 300 | Train Loss 0.538794 | Val Loss 0.505636
# Epoch 400 | Train Loss 0.536361 | Val Loss 0.502895
# Epoch 500 | Train Loss 0.534378 | Val Loss 0.505532
# Epoch 600 | Train Loss 0.533064 | Val Loss 0.506674
# Early stopping at epoch 647
# X | train1 -> R² = -0.0445, MSE = 1.1262e-01
# Y | train1 -> R² = 0.9953, MSE = 3.9413e-04
# X | train2 -> R² = -7.1592, MSE = 6.8750e-01
# Y | train2 -> R² = 0.3543, MSE = 6.9525e-02
# X | test1 -> R² = -0.0274, MSE = 1.0763e-01
# Y | test1 -> R² = 0.9842, MSE = 1.2921e-03
# X | test2 -> R² = -7.0669, MSE = 6.6385e-01
# Y | test2 -> R² = 0.3582, MSE = 6.8127e-02
# X | test3 -> R² = 0.4348, MSE = 5.2003e-02
# Y | test3 -> R² = 0.2624, MSE = 5.6652e-02
# X | val -> R² = 0.2349, MSE = 7.3159e-02
# Y | val -> R² = 0.1944, MSE = 5.9980e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.817818 | Val Loss 0.763292
# Epoch 100 | Train Loss 0.572776 | Val Loss 0.567141
# Epoch 200 | Train Loss 0.545285 | Val Loss 0.535236
# Epoch 300 | Train Loss 0.538401 | Val Loss 0.515260
# Epoch 400 | Train Loss 0.535148 | Val Loss 0.508479
# Epoch 500 | Train Loss 0.533787 | Val Loss 0.506277
# Epoch 600 | Train Loss 0.532788 | Val Loss 0.505402
# Epoch 700 | Train Loss 0.532072 | Val Loss 0.505352
# Epoch 800 | Train Loss 0.531601 | Val Loss 0.505978
# Epoch 900 | Train Loss 0.531210 | Val Loss 0.506868
# Early stopping at epoch 919
# X | train1 -> R² = -0.0704, MSE = 1.1542e-01
# Y | train1 -> R² = 0.9944, MSE = 4.6983e-04
# X | train2 -> R² = -7.0975, MSE = 6.8230e-01
# Y | train2 -> R² = 0.3386, MSE = 7.1221e-02
# X | test1 -> R² = -0.1539, MSE = 1.2088e-01
# Y | test1 -> R² = 0.9910, MSE = 7.4013e-04
# X | test2 -> R² = -7.0971, MSE = 6.6634e-01
# Y | test2 -> R² = 0.3562, MSE = 6.8331e-02
# X | test3 -> R² = 0.7475, MSE = 2.3233e-02
# Y | test3 -> R² = 0.3734, MSE = 4.8125e-02
# X | val -> R² = 0.4743, MSE = 5.0271e-02
# Y | val -> R² = 0.0743, MSE = 6.8916e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.825733 | Val Loss 0.755176
# Epoch 100 | Train Loss 0.586614 | Val Loss 0.564228
# Epoch 200 | Train Loss 0.547648 | Val Loss 0.545188
# Epoch 300 | Train Loss 0.540327 | Val Loss 0.513245
# Epoch 400 | Train Loss 0.537518 | Val Loss 0.505950
# Epoch 500 | Train Loss 0.535191 | Val Loss 0.505283
# Epoch 600 | Train Loss 0.533682 | Val Loss 0.508488
# Epoch 700 | Train Loss 0.532724 | Val Loss 0.511061
# Early stopping at epoch 726
# X | train1 -> R² = -0.0233, MSE = 1.1034e-01
# Y | train1 -> R² = 0.9960, MSE = 3.3769e-04
# X | train2 -> R² = -7.1128, MSE = 6.8359e-01
# Y | train2 -> R² = 0.3437, MSE = 7.0674e-02
# X | test1 -> R² = -0.0040, MSE = 1.0518e-01
# Y | test1 -> R² = 0.9849, MSE = 1.2364e-03
# X | test2 -> R² = -6.9953, MSE = 6.5796e-01
# Y | test2 -> R² = 0.3462, MSE = 6.9391e-02
# X | test3 -> R² = 0.5937, MSE = 3.7383e-02
# Y | test3 -> R² = 0.1719, MSE = 6.3606e-02
# X | val -> R² = 0.2286, MSE = 7.3761e-02
# Y | val -> R² = 0.1720, MSE = 6.1642e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.828883 | Val Loss 0.742709
# Epoch 100 | Train Loss 0.588562 | Val Loss 0.565271
# Epoch 200 | Train Loss 0.547039 | Val Loss 0.543105
# Epoch 300 | Train Loss 0.539769 | Val Loss 0.515329
# Epoch 400 | Train Loss 0.537392 | Val Loss 0.510627
# Epoch 500 | Train Loss 0.535682 | Val Loss 0.511962
# Epoch 600 | Train Loss 0.534314 | Val Loss 0.514081
# Early stopping at epoch 660
# X | train1 -> R² = -0.0862, MSE = 1.1713e-01
# Y | train1 -> R² = 0.9923, MSE = 6.4917e-04
# X | train2 -> R² = -7.0708, MSE = 6.8005e-01
# Y | train2 -> R² = 0.3670, MSE = 6.8165e-02
# X | test1 -> R² = -0.1559, MSE = 1.2109e-01
# Y | test1 -> R² = 0.9612, MSE = 3.1832e-03
# X | test2 -> R² = -6.9885, MSE = 6.5740e-01
# Y | test2 -> R² = 0.3723, MSE = 6.6626e-02
# X | test3 -> R² = 0.6465, MSE = 3.2524e-02
# Y | test3 -> R² = 0.3218, MSE = 5.2087e-02
# X | val -> R² = 0.4239, MSE = 5.5089e-02
# Y | val -> R² = 0.3249, MSE = 5.0260e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.816099 | Val Loss 0.776482
# Epoch 100 | Train Loss 0.578406 | Val Loss 0.565472
# Epoch 200 | Train Loss 0.545369 | Val Loss 0.544934
# Epoch 300 | Train Loss 0.539206 | Val Loss 0.515720
# Epoch 400 | Train Loss 0.536487 | Val Loss 0.503751
# Epoch 500 | Train Loss 0.534606 | Val Loss 0.500278
# Epoch 600 | Train Loss 0.533224 | Val Loss 0.500988
# Epoch 700 | Train Loss 0.532317 | Val Loss 0.502444
# Early stopping at epoch 798
# X | train1 -> R² = -0.0667, MSE = 1.1502e-01
# Y | train1 -> R² = 0.9947, MSE = 4.4145e-04
# X | train2 -> R² = -7.1144, MSE = 6.8372e-01
# Y | train2 -> R² = 0.3497, MSE = 7.0018e-02
# X | test1 -> R² = -0.1355, MSE = 1.1896e-01
# Y | test1 -> R² = 0.9886, MSE = 9.3361e-04
# X | test2 -> R² = -7.0265, MSE = 6.6053e-01
# Y | test2 -> R² = 0.3546, MSE = 6.8501e-02
# X | test3 -> R² = -0.1001, MSE = 1.0122e-01
# Y | test3 -> R² = 0.4029, MSE = 4.5858e-02
# X | val -> R² = -0.6269, MSE = 1.5557e-01
# Y | val -> R² = 0.3121, MSE = 5.1217e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.816230 | Val Loss 0.769753
# Epoch 100 | Train Loss 0.568540 | Val Loss 0.552151
# Epoch 200 | Train Loss 0.544463 | Val Loss 0.526959
# Epoch 300 | Train Loss 0.539358 | Val Loss 0.510485
# Epoch 400 | Train Loss 0.536439 | Val Loss 0.503742
# Epoch 500 | Train Loss 0.534450 | Val Loss 0.504003
# Epoch 600 | Train Loss 0.533445 | Val Loss 0.504272
# Early stopping at epoch 682
# X | train1 -> R² = -0.0217, MSE = 1.1016e-01
# Y | train1 -> R² = 0.9945, MSE = 4.6019e-04
# X | train2 -> R² = -6.9353, MSE = 6.6863e-01
# Y | train2 -> R² = 0.3500, MSE = 6.9990e-02
# X | test1 -> R² = 0.0003, MSE = 1.0473e-01
# Y | test1 -> R² = 0.9798, MSE = 1.6554e-03
# X | test2 -> R² = -6.8870, MSE = 6.4905e-01
# Y | test2 -> R² = 0.3573, MSE = 6.8216e-02
# X | test3 -> R² = 0.7638, MSE = 2.1731e-02
# Y | test3 -> R² = 0.5331, MSE = 3.5860e-02
# X | val -> R² = 0.4873, MSE = 4.9029e-02
# Y | val -> R² = 0.4923, MSE = 3.7800e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.831935 | Val Loss 0.781645
# Epoch 100 | Train Loss 0.604453 | Val Loss 0.568276
# Epoch 200 | Train Loss 0.548351 | Val Loss 0.538691
# Epoch 300 | Train Loss 0.540457 | Val Loss 0.512715
# Epoch 400 | Train Loss 0.536901 | Val Loss 0.502055
# Epoch 500 | Train Loss 0.534689 | Val Loss 0.501601
# Epoch 600 | Train Loss 0.533358 | Val Loss 0.502395
# Epoch 700 | Train Loss 0.532529 | Val Loss 0.502761
# Early stopping at epoch 742
# X | train1 -> R² = -0.0704, MSE = 1.1541e-01
# Y | train1 -> R² = 0.9954, MSE = 3.8421e-04
# X | train2 -> R² = -6.9488, MSE = 6.6977e-01
# Y | train2 -> R² = 0.3533, MSE = 6.9632e-02
# X | test1 -> R² = -0.1210, MSE = 1.1743e-01
# Y | test1 -> R² = 0.9822, MSE = 1.4606e-03
# X | test2 -> R² = -6.9457, MSE = 6.5388e-01
# Y | test2 -> R² = 0.3625, MSE = 6.7665e-02
# X | test3 -> R² = -0.0356, MSE = 9.5279e-02
# Y | test3 -> R² = 0.5264, MSE = 3.6376e-02
# X | val -> R² = -0.4546, MSE = 1.3909e-01
# Y | val -> R² = 0.5053, MSE = 3.6831e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.843136 | Val Loss 0.835639
# Epoch 100 | Train Loss 0.580778 | Val Loss 0.558844
# Epoch 200 | Train Loss 0.549804 | Val Loss 0.548282
# Epoch 300 | Train Loss 0.541153 | Val Loss 0.516327
# Epoch 400 | Train Loss 0.537817 | Val Loss 0.508097
# Epoch 500 | Train Loss 0.535569 | Val Loss 0.507085
# Epoch 600 | Train Loss 0.534139 | Val Loss 0.507828
# Epoch 700 | Train Loss 0.533134 | Val Loss 0.508481
# Early stopping at epoch 709
# X | train1 -> R² = -0.0666, MSE = 1.1501e-01
# Y | train1 -> R² = 0.9953, MSE = 3.9080e-04
# X | train2 -> R² = -6.9843, MSE = 6.7276e-01
# Y | train2 -> R² = 0.3558, MSE = 6.9365e-02
# X | test1 -> R² = -0.0379, MSE = 1.0873e-01
# Y | test1 -> R² = 0.9838, MSE = 1.3309e-03
# X | test2 -> R² = -6.9014, MSE = 6.5023e-01
# Y | test2 -> R² = 0.3590, MSE = 6.8035e-02
# X | test3 -> R² = 0.6937, MSE = 2.8183e-02
# Y | test3 -> R² = -0.2360, MSE = 9.4932e-02
# X | val -> R² = 0.3836, MSE = 5.8939e-02
# Y | val -> R² = -0.2651, MSE = 9.4190e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.820157 | Val Loss 0.767002
# Epoch 100 | Train Loss 0.584143 | Val Loss 0.559894
# Epoch 200 | Train Loss 0.543821 | Val Loss 0.536585
# Epoch 300 | Train Loss 0.539173 | Val Loss 0.511522
# Epoch 400 | Train Loss 0.536285 | Val Loss 0.501632
# Epoch 500 | Train Loss 0.534463 | Val Loss 0.498914
# Epoch 600 | Train Loss 0.533181 | Val Loss 0.499113
# Epoch 700 | Train Loss 0.532273 | Val Loss 0.501294
# Early stopping at epoch 776
# X | train1 -> R² = -0.0395, MSE = 1.1208e-01
# Y | train1 -> R² = 0.9957, MSE = 3.6254e-04
# X | train2 -> R² = -7.0371, MSE = 6.7721e-01
# Y | train2 -> R² = 0.3492, MSE = 7.0078e-02
# X | test1 -> R² = -0.1071, MSE = 1.1598e-01
# Y | test1 -> R² = 0.9845, MSE = 1.2718e-03
# X | test2 -> R² = -7.0102, MSE = 6.5918e-01
# Y | test2 -> R² = 0.3633, MSE = 6.7582e-02
# X | test3 -> R² = 0.5452, MSE = 4.1847e-02
# Y | test3 -> R² = 0.6037, MSE = 3.0438e-02
# X | val -> R² = 0.1529, MSE = 8.1004e-02
# Y | val -> R² = 0.5510, MSE = 3.3425e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.803545 | Val Loss 0.777374
# Epoch 100 | Train Loss 0.569498 | Val Loss 0.588174
# Epoch 200 | Train Loss 0.548716 | Val Loss 0.545537
# Epoch 300 | Train Loss 0.539859 | Val Loss 0.510267
# Epoch 400 | Train Loss 0.536876 | Val Loss 0.505922
# Epoch 500 | Train Loss 0.534729 | Val Loss 0.504890
# Epoch 600 | Train Loss 0.533529 | Val Loss 0.505830
# Epoch 700 | Train Loss 0.532648 | Val Loss 0.506228
# Early stopping at epoch 719
# X | train1 -> R² = -0.0382, MSE = 1.1194e-01
# Y | train1 -> R² = 0.9946, MSE = 4.4843e-04
# X | train2 -> R² = -7.0135, MSE = 6.7522e-01
# Y | train2 -> R² = 0.3425, MSE = 7.0802e-02
# X | test1 -> R² = -0.0377, MSE = 1.0871e-01
# Y | test1 -> R² = 0.9841, MSE = 1.3040e-03
# X | test2 -> R² = -6.9563, MSE = 6.5475e-01
# Y | test2 -> R² = 0.3475, MSE = 6.9256e-02
# X | test3 -> R² = 0.8176, MSE = 1.6783e-02
# Y | test3 -> R² = 0.0190, MSE = 7.5347e-02
# X | val -> R² = 0.4982, MSE = 4.7980e-02
# Y | val -> R² = -0.0318, MSE = 7.6816e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.826714 | Val Loss 0.779583
# Epoch 100 | Train Loss 0.649437 | Val Loss 0.588243
# Epoch 200 | Train Loss 0.551888 | Val Loss 0.560644
# Epoch 300 | Train Loss 0.540501 | Val Loss 0.514065
# Epoch 400 | Train Loss 0.537164 | Val Loss 0.503662
# Epoch 500 | Train Loss 0.535309 | Val Loss 0.503800
# Epoch 600 | Train Loss 0.534083 | Val Loss 0.505360
# Early stopping at epoch 697
# X | train1 -> R² = -0.0132, MSE = 1.0925e-01
# Y | train1 -> R² = 0.9959, MSE = 3.4406e-04
# X | train2 -> R² = -6.9809, MSE = 6.7247e-01
# Y | train2 -> R² = 0.3474, MSE = 7.0267e-02
# X | test1 -> R² = -0.0123, MSE = 1.0605e-01
# Y | test1 -> R² = 0.9786, MSE = 1.7562e-03
# X | test2 -> R² = -6.8893, MSE = 6.4923e-01
# Y | test2 -> R² = 0.3443, MSE = 6.9594e-02
# X | test3 -> R² = 0.5111, MSE = 4.4976e-02
# Y | test3 -> R² = 0.5790, MSE = 3.2336e-02
# X | val -> R² = 0.1835, MSE = 7.8073e-02
# Y | val -> R² = 0.5514, MSE = 3.3397e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.812267 | Val Loss 0.772292
# Epoch 100 | Train Loss 0.571669 | Val Loss 0.568936
# Epoch 200 | Train Loss 0.545536 | Val Loss 0.544934
# Epoch 300 | Train Loss 0.538974 | Val Loss 0.514370
# Epoch 400 | Train Loss 0.536841 | Val Loss 0.508606
# Epoch 500 | Train Loss 0.535151 | Val Loss 0.505849
# Epoch 600 | Train Loss 0.533791 | Val Loss 0.506501
# Epoch 700 | Train Loss 0.532685 | Val Loss 0.506606
# Early stopping at epoch 756
# X | train1 -> R² = -0.0387, MSE = 1.1200e-01
# Y | train1 -> R² = 0.9956, MSE = 3.6496e-04
# X | train2 -> R² = -7.0126, MSE = 6.7514e-01
# Y | train2 -> R² = 0.3477, MSE = 7.0235e-02
# X | test1 -> R² = -0.0435, MSE = 1.0932e-01
# Y | test1 -> R² = 0.9878, MSE = 1.0019e-03
# X | test2 -> R² = -7.0289, MSE = 6.6072e-01
# Y | test2 -> R² = 0.3575, MSE = 6.8198e-02
# X | test3 -> R² = 0.8697, MSE = 1.1987e-02
# Y | test3 -> R² = 0.1147, MSE = 6.8000e-02
# X | val -> R² = 0.6406, MSE = 3.4371e-02
# Y | val -> R² = 0.1119, MSE = 6.6123e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.807544 | Val Loss 0.766493
# Epoch 100 | Train Loss 0.582049 | Val Loss 0.564204
# Epoch 200 | Train Loss 0.544758 | Val Loss 0.518963
# Epoch 300 | Train Loss 0.537796 | Val Loss 0.505457
# Epoch 400 | Train Loss 0.535186 | Val Loss 0.504865
# Epoch 500 | Train Loss 0.533714 | Val Loss 0.507280
# Epoch 600 | Train Loss 0.532730 | Val Loss 0.509562
# Early stopping at epoch 609
# X | train1 -> R² = -0.0789, MSE = 1.1633e-01
# Y | train1 -> R² = 0.9956, MSE = 3.6814e-04
# X | train2 -> R² = -6.9308, MSE = 6.6825e-01
# Y | train2 -> R² = 0.3513, MSE = 6.9846e-02
# X | test1 -> R² = -0.0808, MSE = 1.1322e-01
# Y | test1 -> R² = 0.9796, MSE = 1.6704e-03
# X | test2 -> R² = -6.9081, MSE = 6.5078e-01
# Y | test2 -> R² = 0.3565, MSE = 6.8307e-02
# X | test3 -> R² = 0.8633, MSE = 1.2579e-02
# Y | test3 -> R² = 0.5792, MSE = 3.2320e-02
# X | val -> R² = 0.6455, MSE = 3.3899e-02
# Y | val -> R² = 0.5870, MSE = 3.0747e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.809141 | Val Loss 0.744901
# Epoch 100 | Train Loss 0.604596 | Val Loss 0.575128
# Epoch 200 | Train Loss 0.545204 | Val Loss 0.523953
# Epoch 300 | Train Loss 0.539081 | Val Loss 0.504552
# Epoch 400 | Train Loss 0.536703 | Val Loss 0.503395
# Epoch 500 | Train Loss 0.534947 | Val Loss 0.502514
# Epoch 600 | Train Loss 0.533641 | Val Loss 0.502000
# Epoch 700 | Train Loss 0.532697 | Val Loss 0.501394
# Epoch 800 | Train Loss 0.532072 | Val Loss 0.500774
# Epoch 900 | Train Loss 0.531584 | Val Loss 0.500144
# Epoch 1000 | Train Loss 0.531130 | Val Loss 0.499847
# Epoch 1100 | Train Loss 0.530687 | Val Loss 0.500281
# Early stopping at epoch 1109
# X | train1 -> R² = -0.1040, MSE = 1.1904e-01
# Y | train1 -> R² = 0.9945, MSE = 4.6488e-04
# X | train2 -> R² = -6.9342, MSE = 6.6854e-01
# Y | train2 -> R² = 0.3476, MSE = 7.0247e-02
# X | test1 -> R² = -0.3034, MSE = 1.3654e-01
# Y | test1 -> R² = 0.9893, MSE = 8.7925e-04
# X | test2 -> R² = -6.9147, MSE = 6.5133e-01
# Y | test2 -> R² = 0.3668, MSE = 6.7206e-02
# X | test3 -> R² = 0.1148, MSE = 8.1445e-02
# Y | test3 -> R² = 0.7741, MSE = 1.7353e-02
# X | val -> R² = -0.7571, MSE = 1.6802e-01
# Y | val -> R² = 0.6968, MSE = 2.2574e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.816318 | Val Loss 0.777500
# Epoch 100 | Train Loss 0.590774 | Val Loss 0.560645
# Epoch 200 | Train Loss 0.544040 | Val Loss 0.534765
# Epoch 300 | Train Loss 0.538181 | Val Loss 0.508895
# Epoch 400 | Train Loss 0.535455 | Val Loss 0.504130
# Epoch 500 | Train Loss 0.533669 | Val Loss 0.504076
# Epoch 600 | Train Loss 0.532641 | Val Loss 0.505160
# Epoch 700 | Train Loss 0.531977 | Val Loss 0.505612
# Early stopping at epoch 726
# X | train1 -> R² = -0.0802, MSE = 1.1648e-01
# Y | train1 -> R² = 0.9957, MSE = 3.5613e-04
# X | train2 -> R² = -7.0368, MSE = 6.7719e-01
# Y | train2 -> R² = 0.3448, MSE = 7.0550e-02
# X | test1 -> R² = -0.1080, MSE = 1.1608e-01
# Y | test1 -> R² = 0.9874, MSE = 1.0289e-03
# X | test2 -> R² = -7.0470, MSE = 6.6222e-01
# Y | test2 -> R² = 0.3508, MSE = 6.8907e-02
# X | test3 -> R² = 0.2488, MSE = 6.9116e-02
# Y | test3 -> R² = 0.1182, MSE = 6.7728e-02
# X | val -> R² = -0.3219, MSE = 1.2640e-01
# Y | val -> R² = 0.0142, MSE = 7.3390e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.824203 | Val Loss 0.788685
# Epoch 100 | Train Loss 0.594150 | Val Loss 0.570007
# Epoch 200 | Train Loss 0.546116 | Val Loss 0.542130
# Epoch 300 | Train Loss 0.539221 | Val Loss 0.511656
# Epoch 400 | Train Loss 0.536640 | Val Loss 0.503867
# Epoch 500 | Train Loss 0.534985 | Val Loss 0.500874
# Epoch 600 | Train Loss 0.533709 | Val Loss 0.500876
# Epoch 700 | Train Loss 0.532652 | Val Loss 0.501579
# Epoch 800 | Train Loss 0.531791 | Val Loss 0.502408
# Early stopping at epoch 808
# X | train1 -> R² = -0.0406, MSE = 1.1220e-01
# Y | train1 -> R² = 0.9945, MSE = 4.6282e-04
# X | train2 -> R² = -7.1219, MSE = 6.8435e-01
# Y | train2 -> R² = 0.3501, MSE = 6.9976e-02
# X | test1 -> R² = -0.1007, MSE = 1.1531e-01
# Y | test1 -> R² = 0.9857, MSE = 1.1701e-03
# X | test2 -> R² = -7.1469, MSE = 6.7043e-01
# Y | test2 -> R² = 0.3613, MSE = 6.7791e-02
# X | test3 -> R² = 0.5040, MSE = 4.5634e-02
# Y | test3 -> R² = 0.0967, MSE = 6.9377e-02
# X | val -> R² = -0.0495, MSE = 1.0036e-01
# Y | val -> R² = -0.0141, MSE = 7.5498e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.825871 | Val Loss 0.754759
# Epoch 100 | Train Loss 0.603195 | Val Loss 0.572438
# Epoch 200 | Train Loss 0.546221 | Val Loss 0.544696
# Epoch 300 | Train Loss 0.538956 | Val Loss 0.514282
# Epoch 400 | Train Loss 0.536694 | Val Loss 0.506368
# Epoch 500 | Train Loss 0.534998 | Val Loss 0.502998
# Epoch 600 | Train Loss 0.533732 | Val Loss 0.501362
# Epoch 700 | Train Loss 0.532826 | Val Loss 0.500932
# Epoch 800 | Train Loss 0.532114 | Val Loss 0.501584
# Early stopping at epoch 857
# X | train1 -> R² = -0.0503, MSE = 1.1324e-01
# Y | train1 -> R² = 0.9951, MSE = 4.1351e-04
# X | train2 -> R² = -7.0897, MSE = 6.8164e-01
# Y | train2 -> R² = 0.3548, MSE = 6.9470e-02
# X | test1 -> R² = -0.1407, MSE = 1.1950e-01
# Y | test1 -> R² = 0.9821, MSE = 1.4699e-03
# X | test2 -> R² = -7.0935, MSE = 6.6604e-01
# Y | test2 -> R² = 0.3727, MSE = 6.6587e-02
# X | test3 -> R² = 0.6463, MSE = 3.2538e-02
# Y | test3 -> R² = 0.3150, MSE = 5.2611e-02
# X | val -> R² = 0.2594, MSE = 7.0818e-02
# Y | val -> R² = 0.2619, MSE = 5.4952e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.838985 | Val Loss 0.835087
# Epoch 100 | Train Loss 0.586679 | Val Loss 0.566360
# Epoch 200 | Train Loss 0.548301 | Val Loss 0.557158
# Epoch 300 | Train Loss 0.540989 | Val Loss 0.519150
# Epoch 400 | Train Loss 0.537867 | Val Loss 0.510763
# Epoch 500 | Train Loss 0.535506 | Val Loss 0.509926
# Epoch 600 | Train Loss 0.533936 | Val Loss 0.509611
# Epoch 700 | Train Loss 0.532883 | Val Loss 0.509372
# Early stopping at epoch 730
# X | train1 -> R² = -0.0627, MSE = 1.1458e-01
# Y | train1 -> R² = 0.9957, MSE = 3.5834e-04
# X | train2 -> R² = -7.0074, MSE = 6.7471e-01
# Y | train2 -> R² = 0.3533, MSE = 6.9636e-02
# X | test1 -> R² = -0.1119, MSE = 1.1648e-01
# Y | test1 -> R² = 0.9828, MSE = 1.4128e-03
# X | test2 -> R² = -6.9934, MSE = 6.5780e-01
# Y | test2 -> R² = 0.3613, MSE = 6.7798e-02
# X | test3 -> R² = 0.8417, MSE = 1.4565e-02
# Y | test3 -> R² = 0.0546, MSE = 7.2615e-02
# X | val -> R² = 0.6043, MSE = 3.7839e-02
# Y | val -> R² = -0.0058, MSE = 7.4880e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.832199 | Val Loss 0.754547
# Epoch 100 | Train Loss 0.585791 | Val Loss 0.566582
# Epoch 200 | Train Loss 0.550154 | Val Loss 0.557469
# Epoch 300 | Train Loss 0.541164 | Val Loss 0.517438
# Epoch 400 | Train Loss 0.537476 | Val Loss 0.506923
# Epoch 500 | Train Loss 0.535305 | Val Loss 0.505112
# Epoch 600 | Train Loss 0.533878 | Val Loss 0.504962
# Epoch 700 | Train Loss 0.533083 | Val Loss 0.505653
# Early stopping at epoch 762
# X | train1 -> R² = -0.0430, MSE = 1.1246e-01
# Y | train1 -> R² = 0.9941, MSE = 4.9561e-04
# X | train2 -> R² = -6.9363, MSE = 6.6871e-01
# Y | train2 -> R² = 0.3570, MSE = 6.9242e-02
# X | test1 -> R² = -0.1006, MSE = 1.1530e-01
# Y | test1 -> R² = 0.9789, MSE = 1.7252e-03
# X | test2 -> R² = -6.8901, MSE = 6.4930e-01
# Y | test2 -> R² = 0.3575, MSE = 6.8193e-02
# X | test3 -> R² = 0.5431, MSE = 4.2038e-02
# Y | test3 -> R² = 0.3231, MSE = 5.1991e-02
# X | val -> R² = 0.2667, MSE = 7.0125e-02
# Y | val -> R² = 0.3355, MSE = 4.9469e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.818146 | Val Loss 0.781188
# Epoch 100 | Train Loss 0.568330 | Val Loss 0.570942
# Epoch 200 | Train Loss 0.543667 | Val Loss 0.530754
# Epoch 300 | Train Loss 0.538858 | Val Loss 0.512302
# Epoch 400 | Train Loss 0.536022 | Val Loss 0.505990
# Epoch 500 | Train Loss 0.534066 | Val Loss 0.505009
# Epoch 600 | Train Loss 0.533104 | Val Loss 0.504547
# Epoch 700 | Train Loss 0.532400 | Val Loss 0.503461
# Epoch 800 | Train Loss 0.531775 | Val Loss 0.503348
# Epoch 900 | Train Loss 0.531156 | Val Loss 0.504119
# Early stopping at epoch 973
# X | train1 -> R² = -0.0955, MSE = 1.1813e-01
# Y | train1 -> R² = 0.9932, MSE = 5.6946e-04
# X | train2 -> R² = -6.9675, MSE = 6.7134e-01
# Y | train2 -> R² = 0.3419, MSE = 7.0865e-02
# X | test1 -> R² = -0.0649, MSE = 1.1156e-01
# Y | test1 -> R² = 0.9930, MSE = 5.7578e-04
# X | test2 -> R² = -6.8976, MSE = 6.4992e-01
# Y | test2 -> R² = 0.3521, MSE = 6.8765e-02
# X | test3 -> R² = -0.2129, MSE = 1.1159e-01
# Y | test3 -> R² = 0.4573, MSE = 4.1682e-02
# X | val -> R² = -1.3190, MSE = 2.2175e-01
# Y | val -> R² = 0.2770, MSE = 5.3830e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.802749 | Val Loss 0.747434
# Epoch 100 | Train Loss 0.580029 | Val Loss 0.545655
# Epoch 200 | Train Loss 0.541359 | Val Loss 0.523521
# Epoch 300 | Train Loss 0.538339 | Val Loss 0.510952
# Epoch 400 | Train Loss 0.536148 | Val Loss 0.505519
# Epoch 500 | Train Loss 0.534279 | Val Loss 0.504962
# Epoch 600 | Train Loss 0.532882 | Val Loss 0.504740
# Epoch 700 | Train Loss 0.531923 | Val Loss 0.503665
# Epoch 800 | Train Loss 0.531205 | Val Loss 0.503202
# Epoch 900 | Train Loss 0.530597 | Val Loss 0.503521
# Early stopping at epoch 954
# X | train1 -> R² = -0.1022, MSE = 1.1885e-01
# Y | train1 -> R² = 0.9946, MSE = 4.4866e-04
# X | train2 -> R² = -6.9917, MSE = 6.7339e-01
# Y | train2 -> R² = 0.3376, MSE = 7.1325e-02
# X | test1 -> R² = -0.1811, MSE = 1.2373e-01
# Y | test1 -> R² = 0.9918, MSE = 6.6850e-04
# X | test2 -> R² = -6.9503, MSE = 6.5425e-01
# Y | test2 -> R² = 0.3508, MSE = 6.8908e-02
# X | test3 -> R² = 0.1921, MSE = 7.4334e-02
# Y | test3 -> R² = 0.5192, MSE = 3.6931e-02
# X | val -> R² = -0.8456, MSE = 1.7649e-01
# Y | val -> R² = 0.3886, MSE = 4.5516e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.824783 | Val Loss 0.779352
# Epoch 100 | Train Loss 0.581602 | Val Loss 0.563355
# Epoch 200 | Train Loss 0.547175 | Val Loss 0.535512
# Epoch 300 | Train Loss 0.539037 | Val Loss 0.508597
# Epoch 400 | Train Loss 0.535700 | Val Loss 0.505377
# Epoch 500 | Train Loss 0.533887 | Val Loss 0.507352
# Epoch 600 | Train Loss 0.532996 | Val Loss 0.510414
# Early stopping at epoch 642
# X | train1 -> R² = -0.0416, MSE = 1.1231e-01
# Y | train1 -> R² = 0.9946, MSE = 4.5011e-04
# X | train2 -> R² = -7.1074, MSE = 6.8313e-01
# Y | train2 -> R² = 0.3591, MSE = 6.9015e-02
# X | test1 -> R² = -0.0762, MSE = 1.1275e-01
# Y | test1 -> R² = 0.9740, MSE = 2.1344e-03
# X | test2 -> R² = -7.0232, MSE = 6.6025e-01
# Y | test2 -> R² = 0.3616, MSE = 6.7761e-02
# X | test3 -> R² = 0.7111, MSE = 2.6577e-02
# Y | test3 -> R² = 0.2604, MSE = 5.6803e-02
# X | val -> R² = 0.5664, MSE = 4.1466e-02
# Y | val -> R² = 0.2637, MSE = 5.4819e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.813235 | Val Loss 0.814167
# Epoch 100 | Train Loss 0.570671 | Val Loss 0.547958
# Epoch 200 | Train Loss 0.542904 | Val Loss 0.518870
# Epoch 300 | Train Loss 0.537790 | Val Loss 0.504094
# Epoch 400 | Train Loss 0.535348 | Val Loss 0.500714
# Epoch 500 | Train Loss 0.533825 | Val Loss 0.502588
# Epoch 600 | Train Loss 0.532817 | Val Loss 0.505199
# Early stopping at epoch 657
# X | train1 -> R² = -0.0550, MSE = 1.1376e-01
# Y | train1 -> R² = 0.9951, MSE = 4.0843e-04
# X | train2 -> R² = -7.0958, MSE = 6.8215e-01
# Y | train2 -> R² = 0.3381, MSE = 7.1275e-02
# X | test1 -> R² = -0.0389, MSE = 1.0884e-01
# Y | test1 -> R² = 0.9873, MSE = 1.0438e-03
# X | test2 -> R² = -7.0573, MSE = 6.6306e-01
# Y | test2 -> R² = 0.3464, MSE = 6.9379e-02
# X | test3 -> R² = 0.6334, MSE = 3.3733e-02
# Y | test3 -> R² = 0.5298, MSE = 3.6111e-02
# X | val -> R² = 0.2758, MSE = 6.9248e-02
# Y | val -> R² = 0.4384, MSE = 4.1809e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.811294 | Val Loss 0.733665
# Epoch 100 | Train Loss 0.587056 | Val Loss 0.561118
# Epoch 200 | Train Loss 0.546330 | Val Loss 0.545579
# Epoch 300 | Train Loss 0.538786 | Val Loss 0.514585
# Epoch 400 | Train Loss 0.535686 | Val Loss 0.507123
# Epoch 500 | Train Loss 0.534176 | Val Loss 0.507831
# Epoch 600 | Train Loss 0.533296 | Val Loss 0.507110
# Epoch 700 | Train Loss 0.532705 | Val Loss 0.506168
# Epoch 800 | Train Loss 0.532244 | Val Loss 0.505647
# Epoch 900 | Train Loss 0.531767 | Val Loss 0.506652
# Early stopping at epoch 952
# X | train1 -> R² = -0.1022, MSE = 1.1885e-01
# Y | train1 -> R² = 0.9941, MSE = 4.9582e-04
# X | train2 -> R² = -6.9564, MSE = 6.7041e-01
# Y | train2 -> R² = 0.3450, MSE = 7.0526e-02
# X | test1 -> R² = -0.2297, MSE = 1.2882e-01
# Y | test1 -> R² = 0.9916, MSE = 6.8796e-04
# X | test2 -> R² = -6.8661, MSE = 6.4733e-01
# Y | test2 -> R² = 0.3575, MSE = 6.8201e-02
# X | test3 -> R² = 0.6347, MSE = 3.3607e-02
# Y | test3 -> R² = 0.5209, MSE = 3.6800e-02
# X | val -> R² = -0.0492, MSE = 1.0033e-01
# Y | val -> R² = 0.3594, MSE = 4.7694e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.806074 | Val Loss 0.759433
# Epoch 100 | Train Loss 0.566781 | Val Loss 0.569494
# Epoch 200 | Train Loss 0.547936 | Val Loss 0.533851
# Epoch 300 | Train Loss 0.539007 | Val Loss 0.505633
# Epoch 400 | Train Loss 0.535561 | Val Loss 0.504238
# Epoch 500 | Train Loss 0.533783 | Val Loss 0.504928
# Epoch 600 | Train Loss 0.532916 | Val Loss 0.505229
# Early stopping at epoch 628
# X | train1 -> R² = -0.0939, MSE = 1.1795e-01
# Y | train1 -> R² = 0.9937, MSE = 5.2853e-04
# X | train2 -> R² = -6.9460, MSE = 6.6953e-01
# Y | train2 -> R² = 0.3577, MSE = 6.9160e-02
# X | test1 -> R² = -0.0613, MSE = 1.1118e-01
# Y | test1 -> R² = 0.9724, MSE = 2.2636e-03
# X | test2 -> R² = -6.8671, MSE = 6.4741e-01
# Y | test2 -> R² = 0.3602, MSE = 6.7913e-02
# X | test3 -> R² = 0.0156, MSE = 9.0572e-02
# Y | test3 -> R² = 0.6592, MSE = 2.6174e-02
# X | val -> R² = -0.4932, MSE = 1.4278e-01
# Y | val -> R² = 0.6505, MSE = 2.6020e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.813060 | Val Loss 0.770430
# Epoch 100 | Train Loss 0.576621 | Val Loss 0.560870
# Epoch 200 | Train Loss 0.548212 | Val Loss 0.554993
# Epoch 300 | Train Loss 0.540528 | Val Loss 0.519317
# Epoch 400 | Train Loss 0.537059 | Val Loss 0.508251
# Epoch 500 | Train Loss 0.534426 | Val Loss 0.506700
# Epoch 600 | Train Loss 0.533119 | Val Loss 0.507028
# Epoch 700 | Train Loss 0.532465 | Val Loss 0.505931
# Epoch 800 | Train Loss 0.531979 | Val Loss 0.505401
# Epoch 900 | Train Loss 0.531491 | Val Loss 0.505304
# Epoch 1000 | Train Loss 0.530980 | Val Loss 0.506352
# Early stopping at epoch 1006
# X | train1 -> R² = -0.0951, MSE = 1.1808e-01
# Y | train1 -> R² = 0.9941, MSE = 4.9383e-04
# X | train2 -> R² = -6.9210, MSE = 6.6742e-01
# Y | train2 -> R² = 0.3551, MSE = 6.9440e-02
# X | test1 -> R² = -0.1899, MSE = 1.2465e-01
# Y | test1 -> R² = 0.9902, MSE = 8.0670e-04
# X | test2 -> R² = -6.9432, MSE = 6.5367e-01
# Y | test2 -> R² = 0.3710, MSE = 6.6762e-02
# X | test3 -> R² = -0.6024, MSE = 1.4743e-01
# Y | test3 -> R² = 0.3866, MSE = 4.7112e-02
# X | val -> R² = -1.9169, MSE = 2.7892e-01
# Y | val -> R² = 0.2389, MSE = 5.6664e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 0.824807 | Val Loss 0.775129
# Epoch 100 | Train Loss 0.573978 | Val Loss 0.566081
# Epoch 200 | Train Loss 0.548308 | Val Loss 0.538473
# Epoch 300 | Train Loss 0.539771 | Val Loss 0.509721
# Epoch 400 | Train Loss 0.537194 | Val Loss 0.503029
# Epoch 500 | Train Loss 0.535528 | Val Loss 0.500876
# Epoch 600 | Train Loss 0.534223 | Val Loss 0.501175
# Epoch 700 | Train Loss 0.533221 | Val Loss 0.502707
# Early stopping at epoch 771
# X | train1 -> R² = -0.0499, MSE = 1.1321e-01
# Y | train1 -> R² = 0.9954, MSE = 3.8413e-04
# X | train2 -> R² = -7.0107, MSE = 6.7498e-01
# Y | train2 -> R² = 0.3465, MSE = 7.0362e-02
# X | test1 -> R² = -0.0512, MSE = 1.1013e-01
# Y | test1 -> R² = 0.9844, MSE = 1.2758e-03
# X | test2 -> R² = -7.0049, MSE = 6.5875e-01
# Y | test2 -> R² = 0.3494, MSE = 6.9061e-02
# X | test3 -> R² = 0.4433, MSE = 5.1215e-02
# Y | test3 -> R² = 0.4590, MSE = 4.1556e-02
# X | val -> R² = 0.0596, MSE = 8.9926e-02
# Y | val -> R² = 0.3299, MSE = 4.9892e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 0.827523 | Val Loss 0.794513
# Epoch 100 | Train Loss 0.568816 | Val Loss 0.558642
# Epoch 200 | Train Loss 0.547423 | Val Loss 0.537444
# Epoch 300 | Train Loss 0.541023 | Val Loss 0.512425
# Epoch 400 | Train Loss 0.537932 | Val Loss 0.502960
# Epoch 500 | Train Loss 0.536017 | Val Loss 0.503004
# Epoch 600 | Train Loss 0.534456 | Val Loss 0.505350
# Epoch 700 | Train Loss 0.533367 | Val Loss 0.507008
# Early stopping at epoch 713
# X | train1 -> R² = -0.0708, MSE = 1.1546e-01
# Y | train1 -> R² = 0.9939, MSE = 5.1385e-04
# X | train2 -> R² = -7.0499, MSE = 6.7829e-01
# Y | train2 -> R² = 0.3572, MSE = 6.9214e-02
# X | test1 -> R² = -0.0877, MSE = 1.1394e-01
# Y | test1 -> R² = 0.9751, MSE = 2.0406e-03
# X | test2 -> R² = -6.9737, MSE = 6.5618e-01
# Y | test2 -> R² = 0.3627, MSE = 6.7649e-02
# X | test3 -> R² = 0.3992, MSE = 5.5272e-02
# Y | test3 -> R² = 0.4433, MSE = 4.2758e-02
# X | val -> R² = 0.2525, MSE = 7.1478e-02
# Y | val -> R² = 0.4373, MSE = 4.1893e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 0.815963 | Val Loss 0.777035
# Epoch 100 | Train Loss 0.577211 | Val Loss 0.564047
# Epoch 200 | Train Loss 0.542830 | Val Loss 0.536258
# Epoch 300 | Train Loss 0.538253 | Val Loss 0.513461
# Epoch 400 | Train Loss 0.535930 | Val Loss 0.502793
# Epoch 500 | Train Loss 0.534412 | Val Loss 0.499959
# Epoch 600 | Train Loss 0.533217 | Val Loss 0.499338
# Epoch 700 | Train Loss 0.532411 | Val Loss 0.498486
# Epoch 800 | Train Loss 0.531840 | Val Loss 0.497093
# Epoch 900 | Train Loss 0.531365 | Val Loss 0.496772
# Epoch 1000 | Train Loss 0.530907 | Val Loss 0.497467
# Early stopping at epoch 1085
# X | train1 -> R² = -0.0849, MSE = 1.1698e-01
# Y | train1 -> R² = 0.9939, MSE = 5.1462e-04
# X | train2 -> R² = -6.9967, MSE = 6.7380e-01
# Y | train2 -> R² = 0.3463, MSE = 7.0388e-02
# X | test1 -> R² = -0.1609, MSE = 1.2162e-01
# Y | test1 -> R² = 0.9918, MSE = 6.6855e-04
# X | test2 -> R² = -6.9860, MSE = 6.5719e-01
# Y | test2 -> R² = 0.3650, MSE = 6.7399e-02
# X | test3 -> R² = -0.8947, MSE = 1.7432e-01
# Y | test3 -> R² = 0.9531, MSE = 3.6058e-03
# X | val -> R² = -2.2449, MSE = 3.1029e-01
# Y | val -> R² = 0.9244, MSE = 5.6303e-03
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 0.820033 | Val Loss 0.792746
# Epoch 100 | Train Loss 0.584944 | Val Loss 0.565689
# Epoch 200 | Train Loss 0.545704 | Val Loss 0.540798
# Epoch 300 | Train Loss 0.538647 | Val Loss 0.508697
# Epoch 400 | Train Loss 0.536789 | Val Loss 0.503634
# Epoch 500 | Train Loss 0.535350 | Val Loss 0.501612
# Epoch 600 | Train Loss 0.534070 | Val Loss 0.501478
# Epoch 700 | Train Loss 0.533040 | Val Loss 0.501174
# Epoch 800 | Train Loss 0.532288 | Val Loss 0.500001
# Epoch 900 | Train Loss 0.531735 | Val Loss 0.499188
# Epoch 1000 | Train Loss 0.531282 | Val Loss 0.498700
# Epoch 1100 | Train Loss 0.530865 | Val Loss 0.498739
# Early stopping at epoch 1175
# X | train1 -> R² = -0.0836, MSE = 1.1684e-01
# Y | train1 -> R² = 0.9938, MSE = 5.1766e-04
# X | train2 -> R² = -7.0217, MSE = 6.7592e-01
# Y | train2 -> R² = 0.3481, MSE = 7.0190e-02
# X | test1 -> R² = -0.2129, MSE = 1.2706e-01
# Y | test1 -> R² = 0.9914, MSE = 7.0413e-04
# X | test2 -> R² = -6.9770, MSE = 6.5645e-01
# Y | test2 -> R² = 0.3680, MSE = 6.7085e-02
# X | test3 -> R² = 0.6175, MSE = 3.5190e-02
# Y | test3 -> R² = 0.7236, MSE = 2.1231e-02
# X | val -> R² = -0.2262, MSE = 1.1725e-01
# Y | val -> R² = 0.6682, MSE = 2.4703e-02
# Figura salva.
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 0.651130 | Val Loss 0.776372
# Epoch 100 | Train Loss 0.426068 | Val Loss 0.576567
# Epoch 200 | Train Loss 0.390711 | Val Loss 0.540703
# Epoch 300 | Train Loss 0.383522 | Val Loss 0.516900
# Epoch 400 | Train Loss 0.380603 | Val Loss 0.509344
# Epoch 500 | Train Loss 0.378776 | Val Loss 0.509097
# Epoch 600 | Train Loss 0.377174 | Val Loss 0.512796
# Epoch 700 | Train Loss 0.375680 | Val Loss 0.518465
# Early stopping at epoch 702
# X | train1 -> R² = -1.0856, MSE = 2.2488e-01
# Y | train1 -> R² = 0.9937, MSE = 5.2657e-04
# X | train2 -> R² = -14.9294, MSE = 1.3422e+00
# Y | train2 -> R² = -0.2085, MSE = 1.3012e-01
# X | test1 -> R² = -1.1713, MSE = 2.2747e-01
# Y | test1 -> R² = 0.9804, MSE = 1.6095e-03
# X | test2 -> R² = -15.1106, MSE = 1.3258e+00
# Y | test2 -> R² = -0.1914, MSE = 1.2646e-01
# X | test3 -> R² = 0.3635, MSE = 5.8564e-02
# Y | test3 -> R² = 0.4805, MSE = 3.9898e-02
# X | val -> R² = -0.1501, MSE = 1.0998e-01
# Y | val -> R² = 0.4842, MSE = 3.8401e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.633308 | Val Loss 0.779723
# Epoch 100 | Train Loss 0.415802 | Val Loss 0.589383
# Epoch 200 | Train Loss 0.387215 | Val Loss 0.532183
# Epoch 300 | Train Loss 0.381932 | Val Loss 0.512081
# Epoch 400 | Train Loss 0.379693 | Val Loss 0.509192
# Epoch 500 | Train Loss 0.377973 | Val Loss 0.509545
# Epoch 600 | Train Loss 0.376487 | Val Loss 0.512041
# Epoch 700 | Train Loss 0.375416 | Val Loss 0.515525
# Early stopping at epoch 717
# X | train1 -> R² = -1.0016, MSE = 2.1582e-01
# Y | train1 -> R² = 0.9913, MSE = 7.3042e-04
# X | train2 -> R² = -14.9165, MSE = 1.3411e+00
# Y | train2 -> R² = -0.1971, MSE = 1.2890e-01
# X | test1 -> R² = -1.0703, MSE = 2.1689e-01
# Y | test1 -> R² = 0.9832, MSE = 1.3739e-03
# X | test2 -> R² = -15.0221, MSE = 1.3185e+00
# Y | test2 -> R² = -0.1780, MSE = 1.2504e-01
# X | test3 -> R² = 0.0467, MSE = 8.7703e-02
# Y | test3 -> R² = 0.4347, MSE = 4.3417e-02
# X | val -> R² = -0.3658, MSE = 1.3060e-01
# Y | val -> R² = 0.4123, MSE = 4.3756e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.644371 | Val Loss 0.758485
# Epoch 100 | Train Loss 0.420002 | Val Loss 0.571235
# Epoch 200 | Train Loss 0.387536 | Val Loss 0.522120
# Epoch 300 | Train Loss 0.381227 | Val Loss 0.509709
# Epoch 400 | Train Loss 0.378831 | Val Loss 0.509801
# Epoch 500 | Train Loss 0.377301 | Val Loss 0.510557
# Early stopping at epoch 585
# X | train1 -> R² = -1.1479, MSE = 2.3160e-01
# Y | train1 -> R² = 0.9913, MSE = 7.3250e-04
# X | train2 -> R² = -14.8582, MSE = 1.3362e+00
# Y | train2 -> R² = -0.1963, MSE = 1.2881e-01
# X | test1 -> R² = -1.2039, MSE = 2.3088e-01
# Y | test1 -> R² = 0.9734, MSE = 2.1778e-03
# X | test2 -> R² = -14.8734, MSE = 1.3063e+00
# Y | test2 -> R² = -0.1821, MSE = 1.2547e-01
# X | test3 -> R² = -0.1175, MSE = 1.0282e-01
# Y | test3 -> R² = 0.6085, MSE = 3.0069e-02
# X | val -> R² = -0.4991, MSE = 1.4335e-01
# Y | val -> R² = 0.5696, MSE = 3.2040e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.629997 | Val Loss 0.746248
# Epoch 100 | Train Loss 0.416856 | Val Loss 0.568321
# Epoch 200 | Train Loss 0.390961 | Val Loss 0.548997
# Epoch 300 | Train Loss 0.382250 | Val Loss 0.520471
# Epoch 400 | Train Loss 0.378959 | Val Loss 0.515049
# Epoch 500 | Train Loss 0.376948 | Val Loss 0.515617
# Epoch 600 | Train Loss 0.375612 | Val Loss 0.517790
# Epoch 700 | Train Loss 0.374518 | Val Loss 0.518911
# Early stopping at epoch 714
# X | train1 -> R² = -1.0756, MSE = 2.2380e-01
# Y | train1 -> R² = 0.9907, MSE = 7.7896e-04
# X | train2 -> R² = -14.8487, MSE = 1.3354e+00
# Y | train2 -> R² = -0.2023, MSE = 1.2947e-01
# X | test1 -> R² = -1.2292, MSE = 2.3353e-01
# Y | test1 -> R² = 0.9793, MSE = 1.6988e-03
# X | test2 -> R² = -14.9420, MSE = 1.3119e+00
# Y | test2 -> R² = -0.1788, MSE = 1.2512e-01
# X | test3 -> R² = -0.9168, MSE = 1.7635e-01
# Y | test3 -> R² = 0.3941, MSE = 4.6541e-02
# X | val -> R² = -1.3621, MSE = 2.2587e-01
# Y | val -> R² = 0.3063, MSE = 5.1644e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.631787 | Val Loss 0.785449
# Epoch 100 | Train Loss 0.412953 | Val Loss 0.584767
# Epoch 200 | Train Loss 0.388549 | Val Loss 0.528764
# Epoch 300 | Train Loss 0.380140 | Val Loss 0.513864
# Epoch 400 | Train Loss 0.377636 | Val Loss 0.512152
# Epoch 500 | Train Loss 0.376432 | Val Loss 0.513212
# Epoch 600 | Train Loss 0.375579 | Val Loss 0.515346
# Early stopping at epoch 623
# X | train1 -> R² = -1.1180, MSE = 2.2838e-01
# Y | train1 -> R² = 0.9910, MSE = 7.5602e-04
# X | train2 -> R² = -14.6361, MSE = 1.3175e+00
# Y | train2 -> R² = -0.1998, MSE = 1.2919e-01
# X | test1 -> R² = -1.2315, MSE = 2.3377e-01
# Y | test1 -> R² = 0.9760, MSE = 1.9638e-03
# X | test2 -> R² = -14.6270, MSE = 1.2860e+00
# Y | test2 -> R² = -0.1866, MSE = 1.2595e-01
# X | test3 -> R² = -0.6851, MSE = 1.5503e-01
# Y | test3 -> R² = 0.7165, MSE = 2.1775e-02
# X | val -> R² = -1.3758, MSE = 2.2718e-01
# Y | val -> R² = 0.7207, MSE = 2.0793e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.631958 | Val Loss 0.771910
# Epoch 100 | Train Loss 0.416401 | Val Loss 0.571066
# Epoch 200 | Train Loss 0.388266 | Val Loss 0.533677
# Epoch 300 | Train Loss 0.382113 | Val Loss 0.520234
# Epoch 400 | Train Loss 0.378542 | Val Loss 0.517150
# Epoch 500 | Train Loss 0.376948 | Val Loss 0.516838
# Epoch 600 | Train Loss 0.376061 | Val Loss 0.516824
# Epoch 700 | Train Loss 0.375348 | Val Loss 0.517947
# Early stopping at epoch 729
# X | train1 -> R² = -1.1214, MSE = 2.2874e-01
# Y | train1 -> R² = 0.9906, MSE = 7.8519e-04
# X | train2 -> R² = -14.7774, MSE = 1.3294e+00
# Y | train2 -> R² = -0.2098, MSE = 1.3027e-01
# X | test1 -> R² = -1.2833, MSE = 2.3920e-01
# Y | test1 -> R² = 0.9833, MSE = 1.3660e-03
# X | test2 -> R² = -14.8208, MSE = 1.3019e+00
# Y | test2 -> R² = -0.1916, MSE = 1.2648e-01
# X | test3 -> R² = 0.1001, MSE = 8.2796e-02
# Y | test3 -> R² = 0.2983, MSE = 5.3896e-02
# X | val -> R² = -0.4912, MSE = 1.4259e-01
# Y | val -> R² = 0.2775, MSE = 5.3787e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.650966 | Val Loss 0.790475
# Epoch 100 | Train Loss 0.414270 | Val Loss 0.572230
# Epoch 200 | Train Loss 0.388008 | Val Loss 0.529379
# Epoch 300 | Train Loss 0.382485 | Val Loss 0.510234
# Epoch 400 | Train Loss 0.379540 | Val Loss 0.508319
# Epoch 500 | Train Loss 0.377585 | Val Loss 0.508959
# Epoch 600 | Train Loss 0.376293 | Val Loss 0.510213
# Early stopping at epoch 635
# X | train1 -> R² = -1.1293, MSE = 2.2959e-01
# Y | train1 -> R² = 0.9910, MSE = 7.5150e-04
# X | train2 -> R² = -14.9374, MSE = 1.3429e+00
# Y | train2 -> R² = -0.2019, MSE = 1.2942e-01
# X | test1 -> R² = -1.2219, MSE = 2.3276e-01
# Y | test1 -> R² = 0.9768, MSE = 1.9020e-03
# X | test2 -> R² = -14.9625, MSE = 1.3136e+00
# Y | test2 -> R² = -0.1827, MSE = 1.2554e-01
# X | test3 -> R² = 0.3587, MSE = 5.8999e-02
# Y | test3 -> R² = 0.4808, MSE = 3.9876e-02
# X | val -> R² = 0.0601, MSE = 8.9881e-02
# Y | val -> R² = 0.4047, MSE = 4.4318e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.631090 | Val Loss 0.770073
# Epoch 100 | Train Loss 0.413054 | Val Loss 0.577899
# Epoch 200 | Train Loss 0.392483 | Val Loss 0.552885
# Epoch 300 | Train Loss 0.382694 | Val Loss 0.520571
# Epoch 400 | Train Loss 0.380440 | Val Loss 0.514974
# Epoch 500 | Train Loss 0.378973 | Val Loss 0.514833
# Epoch 600 | Train Loss 0.377496 | Val Loss 0.518609
# Early stopping at epoch 689
# X | train1 -> R² = -1.0465, MSE = 2.2066e-01
# Y | train1 -> R² = 0.9919, MSE = 6.8118e-04
# X | train2 -> R² = -14.7357, MSE = 1.3259e+00
# Y | train2 -> R² = -0.2050, MSE = 1.2976e-01
# X | test1 -> R² = -1.0446, MSE = 2.1419e-01
# Y | test1 -> R² = 0.9827, MSE = 1.4145e-03
# X | test2 -> R² = -14.9295, MSE = 1.3109e+00
# Y | test2 -> R² = -0.1793, MSE = 1.2518e-01
# X | test3 -> R² = 0.2462, MSE = 6.9353e-02
# Y | test3 -> R² = -0.0538, MSE = 8.0943e-02
# X | val -> R² = -0.0871, MSE = 1.0395e-01
# Y | val -> R² = -0.0791, MSE = 8.0342e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.632598 | Val Loss 0.756024
# Epoch 100 | Train Loss 0.409232 | Val Loss 0.575107
# Epoch 200 | Train Loss 0.391792 | Val Loss 0.546075
# Epoch 300 | Train Loss 0.381497 | Val Loss 0.511381
# Epoch 400 | Train Loss 0.378661 | Val Loss 0.510640
# Epoch 500 | Train Loss 0.377107 | Val Loss 0.513302
# Epoch 600 | Train Loss 0.375964 | Val Loss 0.515660
# Early stopping at epoch 628
# X | train1 -> R² = -1.1057, MSE = 2.2705e-01
# Y | train1 -> R² = 0.9924, MSE = 6.3437e-04
# X | train2 -> R² = -15.0498, MSE = 1.3524e+00
# Y | train2 -> R² = -0.2013, MSE = 1.2935e-01
# X | test1 -> R² = -1.2110, MSE = 2.3162e-01
# Y | test1 -> R² = 0.9796, MSE = 1.6701e-03
# X | test2 -> R² = -15.2032, MSE = 1.3334e+00
# Y | test2 -> R² = -0.1796, MSE = 1.2520e-01
# X | test3 -> R² = -0.1205, MSE = 1.0309e-01
# Y | test3 -> R² = 0.6074, MSE = 3.0153e-02
# X | val -> R² = -0.7747, MSE = 1.6970e-01
# Y | val -> R² = 0.5978, MSE = 2.9944e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.634742 | Val Loss 0.774243
# Epoch 100 | Train Loss 0.409242 | Val Loss 0.569655
# Epoch 200 | Train Loss 0.389237 | Val Loss 0.537635
# Epoch 300 | Train Loss 0.383259 | Val Loss 0.517023
# Epoch 400 | Train Loss 0.380091 | Val Loss 0.509259
# Epoch 500 | Train Loss 0.378004 | Val Loss 0.509824
# Epoch 600 | Train Loss 0.376498 | Val Loss 0.511306
# Early stopping at epoch 683
# X | train1 -> R² = -1.0925, MSE = 2.2563e-01
# Y | train1 -> R² = 0.9912, MSE = 7.3520e-04
# X | train2 -> R² = -14.8044, MSE = 1.3317e+00
# Y | train2 -> R² = -0.1924, MSE = 1.2840e-01
# X | test1 -> R² = -1.1780, MSE = 2.2816e-01
# Y | test1 -> R² = 0.9761, MSE = 1.9575e-03
# X | test2 -> R² = -14.9492, MSE = 1.3125e+00
# Y | test2 -> R² = -0.1672, MSE = 1.2389e-01
# X | test3 -> R² = 0.3867, MSE = 5.6427e-02
# Y | test3 -> R² = 0.4056, MSE = 4.5656e-02
# X | val -> R² = -0.0261, MSE = 9.8122e-02
# Y | val -> R² = 0.3656, MSE = 4.7234e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.636070 | Val Loss 0.745531
# Epoch 100 | Train Loss 0.444268 | Val Loss 0.575518
# Epoch 200 | Train Loss 0.388524 | Val Loss 0.523543
# Epoch 300 | Train Loss 0.381543 | Val Loss 0.514478
# Epoch 400 | Train Loss 0.378103 | Val Loss 0.515596
# Epoch 500 | Train Loss 0.376499 | Val Loss 0.520790
# Epoch 600 | Train Loss 0.375561 | Val Loss 0.524142
# Early stopping at epoch 603
# X | train1 -> R² = -1.1471, MSE = 2.3151e-01
# Y | train1 -> R² = 0.9900, MSE = 8.3590e-04
# X | train2 -> R² = -14.8742, MSE = 1.3376e+00
# Y | train2 -> R² = -0.1837, MSE = 1.2746e-01
# X | test1 -> R² = -1.2601, MSE = 2.3677e-01
# Y | test1 -> R² = 0.9716, MSE = 2.3295e-03
# X | test2 -> R² = -14.8456, MSE = 1.3040e+00
# Y | test2 -> R² = -0.1761, MSE = 1.2483e-01
# X | test3 -> R² = -0.1463, MSE = 1.0547e-01
# Y | test3 -> R² = 0.3733, MSE = 4.8138e-02
# X | val -> R² = -0.5626, MSE = 1.4942e-01
# Y | val -> R² = 0.4322, MSE = 4.2270e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.635133 | Val Loss 0.778853
# Epoch 100 | Train Loss 0.413008 | Val Loss 0.576074
# Epoch 200 | Train Loss 0.390558 | Val Loss 0.539136
# Epoch 300 | Train Loss 0.383030 | Val Loss 0.523373
# Epoch 400 | Train Loss 0.379107 | Val Loss 0.519913
# Epoch 500 | Train Loss 0.377408 | Val Loss 0.517094
# Epoch 600 | Train Loss 0.376309 | Val Loss 0.513976
# Epoch 700 | Train Loss 0.375430 | Val Loss 0.512422
# Epoch 800 | Train Loss 0.374680 | Val Loss 0.511547
# Epoch 900 | Train Loss 0.373951 | Val Loss 0.511502
# Epoch 1000 | Train Loss 0.373159 | Val Loss 0.512973
# Early stopping at epoch 1014
# X | train1 -> R² = -1.1161, MSE = 2.2817e-01
# Y | train1 -> R² = 0.9904, MSE = 8.0109e-04
# X | train2 -> R² = -14.7084, MSE = 1.3236e+00
# Y | train2 -> R² = -0.2187, MSE = 1.3123e-01
# X | test1 -> R² = -1.4314, MSE = 2.5472e-01
# Y | test1 -> R² = 0.9887, MSE = 9.2787e-04
# X | test2 -> R² = -14.8015, MSE = 1.3004e+00
# Y | test2 -> R² = -0.2036, MSE = 1.2775e-01
# X | test3 -> R² = -0.2250, MSE = 1.1271e-01
# Y | test3 -> R² = 0.6269, MSE = 2.8659e-02
# X | val -> R² = -1.1400, MSE = 2.0464e-01
# Y | val -> R² = 0.4746, MSE = 3.9115e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.626843 | Val Loss 0.767219
# Epoch 100 | Train Loss 0.408525 | Val Loss 0.566729
# Epoch 200 | Train Loss 0.387722 | Val Loss 0.525689
# Epoch 300 | Train Loss 0.382856 | Val Loss 0.517880
# Epoch 400 | Train Loss 0.379786 | Val Loss 0.517769
# Epoch 500 | Train Loss 0.377619 | Val Loss 0.522166
# Early stopping at epoch 586
# X | train1 -> R² = -1.3246, MSE = 2.5066e-01
# Y | train1 -> R² = 0.9902, MSE = 8.1934e-04
# X | train2 -> R² = -14.8618, MSE = 1.3365e+00
# Y | train2 -> R² = -0.2061, MSE = 1.2987e-01
# X | test1 -> R² = -1.4348, MSE = 2.5508e-01
# Y | test1 -> R² = 0.9688, MSE = 2.5593e-03
# X | test2 -> R² = -14.9497, MSE = 1.3125e+00
# Y | test2 -> R² = -0.1967, MSE = 1.2702e-01
# X | test3 -> R² = -1.6642, MSE = 2.4512e-01
# Y | test3 -> R² = 0.7430, MSE = 1.9737e-02
# X | val -> R² = -2.3387, MSE = 3.1925e-01
# Y | val -> R² = 0.7472, MSE = 1.8822e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.633396 | Val Loss 0.736346
# Epoch 100 | Train Loss 0.414710 | Val Loss 0.557488
# Epoch 200 | Train Loss 0.388565 | Val Loss 0.523816
# Epoch 300 | Train Loss 0.381931 | Val Loss 0.511327
# Epoch 400 | Train Loss 0.378792 | Val Loss 0.510421
# Epoch 500 | Train Loss 0.377071 | Val Loss 0.512434
# Epoch 600 | Train Loss 0.376016 | Val Loss 0.514634
# Early stopping at epoch 637
# X | train1 -> R² = -1.1405, MSE = 2.3081e-01
# Y | train1 -> R² = 0.9901, MSE = 8.3108e-04
# X | train2 -> R² = -14.8833, MSE = 1.3383e+00
# Y | train2 -> R² = -0.1866, MSE = 1.2777e-01
# X | test1 -> R² = -1.2846, MSE = 2.3934e-01
# Y | test1 -> R² = 0.9674, MSE = 2.6721e-03
# X | test2 -> R² = -14.9347, MSE = 1.3113e+00
# Y | test2 -> R² = -0.1749, MSE = 1.2471e-01
# X | test3 -> R² = -0.7044, MSE = 1.5682e-01
# Y | test3 -> R² = 0.7444, MSE = 1.9633e-02
# X | val -> R² = -1.1906, MSE = 2.0947e-01
# Y | val -> R² = 0.7214, MSE = 2.0744e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.631978 | Val Loss 0.781699
# Epoch 100 | Train Loss 0.413731 | Val Loss 0.577250
# Epoch 200 | Train Loss 0.387477 | Val Loss 0.533119
# Epoch 300 | Train Loss 0.381321 | Val Loss 0.509735
# Epoch 400 | Train Loss 0.378462 | Val Loss 0.508546
# Epoch 500 | Train Loss 0.376763 | Val Loss 0.511326
# Epoch 600 | Train Loss 0.375726 | Val Loss 0.514264
# Early stopping at epoch 629
# X | train1 -> R² = -1.0954, MSE = 2.2594e-01
# Y | train1 -> R² = 0.9921, MSE = 6.6503e-04
# X | train2 -> R² = -14.8409, MSE = 1.3348e+00
# Y | train2 -> R² = -0.1943, MSE = 1.2860e-01
# X | test1 -> R² = -1.1592, MSE = 2.2620e-01
# Y | test1 -> R² = 0.9781, MSE = 1.7974e-03
# X | test2 -> R² = -14.8843, MSE = 1.3072e+00
# Y | test2 -> R² = -0.1749, MSE = 1.2471e-01
# X | test3 -> R² = 0.0267, MSE = 8.9546e-02
# Y | test3 -> R² = 0.4675, MSE = 4.0898e-02
# X | val -> R² = -0.4347, MSE = 1.3719e-01
# Y | val -> R² = 0.4490, MSE = 4.1021e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.633561 | Val Loss 0.774631
# Epoch 100 | Train Loss 0.426684 | Val Loss 0.559862
# Epoch 200 | Train Loss 0.387920 | Val Loss 0.525789
# Epoch 300 | Train Loss 0.381904 | Val Loss 0.512283
# Epoch 400 | Train Loss 0.378495 | Val Loss 0.509683
# Epoch 500 | Train Loss 0.376878 | Val Loss 0.513264
# Epoch 600 | Train Loss 0.375727 | Val Loss 0.516610
# Early stopping at epoch 658
# X | train1 -> R² = -1.1155, MSE = 2.2811e-01
# Y | train1 -> R² = 0.9912, MSE = 7.3676e-04
# X | train2 -> R² = -14.7489, MSE = 1.3270e+00
# Y | train2 -> R² = -0.1980, MSE = 1.2900e-01
# X | test1 -> R² = -1.1873, MSE = 2.2914e-01
# Y | test1 -> R² = 0.9770, MSE = 1.8887e-03
# X | test2 -> R² = -14.7801, MSE = 1.2986e+00
# Y | test2 -> R² = -0.1791, MSE = 1.2515e-01
# X | test3 -> R² = -1.0432, MSE = 1.8798e-01
# Y | test3 -> R² = 0.7901, MSE = 1.6122e-02
# X | val -> R² = -1.4309, MSE = 2.3245e-01
# Y | val -> R² = 0.7892, MSE = 1.5692e-02
# Figura salva.
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.653727 | Val Loss 0.774712
# Epoch 100 | Train Loss 0.436813 | Val Loss 0.581186
# Epoch 200 | Train Loss 0.395251 | Val Loss 0.562957
# Epoch 300 | Train Loss 0.384970 | Val Loss 0.531656
# Epoch 400 | Train Loss 0.380430 | Val Loss 0.511719
# Epoch 500 | Train Loss 0.378337 | Val Loss 0.509224
# Epoch 600 | Train Loss 0.376733 | Val Loss 0.511456
# Epoch 700 | Train Loss 0.375446 | Val Loss 0.515008
# ...
# Y | train2 -> R² = -0.0875, MSE = 1.1711e-01
# X | test1 -> R² = -1.3457, MSE = 2.4573e-01
# Y | test1 -> R² = 0.9723, MSE = 2.2674e-03
# X | test2 -> R² = -17.7774, MSE = 1.5452e+00
# Y | test2 -> R² = -0.1023, MSE = 1.1700e-01
# X | test3 -> R² = -0.2512, MSE = 1.1512e-01
# Y | test3 -> R² = 0.5932, MSE = 3.1245e-02
# X | val -> R² = -0.8027, MSE = 1.7238e-01
# Y | val -> R² = 0.5135, MSE = 3.6217e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.701538 | Val Loss 0.755547
# Epoch 100 | Train Loss 0.393413 | Val Loss 0.559365
# Epoch 200 | Train Loss 0.383148 | Val Loss 0.517924
# Epoch 300 | Train Loss 0.379789 | Val Loss 0.509800
# Epoch 400 | Train Loss 0.379810 | Val Loss 0.511890
# Epoch 500 | Train Loss 0.375899 | Val Loss 0.508866
# Epoch 600 | Train Loss 0.374162 | Val Loss 0.515035
# Early stopping at epoch 697
# X | train1 -> R² = -1.1749, MSE = 2.3451e-01
# Y | train1 -> R² = 0.9968, MSE = 2.6671e-04
# X | train2 -> R² = -16.0057, MSE = 1.4329e+00
# Y | train2 -> R² = -0.0921, MSE = 1.1759e-01
# X | test1 -> R² = -1.3473, MSE = 2.4590e-01
# Y | test1 -> R² = 0.9687, MSE = 2.5684e-03
# X | test2 -> R² = -16.2475, MSE = 1.4193e+00
# Y | test2 -> R² = -0.0998, MSE = 1.1674e-01
# X | test3 -> R² = -0.2991, MSE = 1.1952e-01
# Y | test3 -> R² = 0.6372, MSE = 2.7863e-02
# X | val -> R² = -0.8720, MSE = 1.7900e-01
# Y | val -> R² = 0.5026, MSE = 3.7030e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 0.690330 | Val Loss 0.697887
# Epoch 100 | Train Loss 0.396512 | Val Loss 0.567903
# Epoch 200 | Train Loss 0.382921 | Val Loss 0.522129
# Epoch 300 | Train Loss 0.378420 | Val Loss 0.511668
# Epoch 400 | Train Loss 0.376004 | Val Loss 0.514879
# Epoch 500 | Train Loss 0.374039 | Val Loss 0.519420
# Epoch 600 | Train Loss 0.372506 | Val Loss 0.523323
# Early stopping at epoch 630
# X | train1 -> R² = -1.1969, MSE = 2.3688e-01
# Y | train1 -> R² = 0.9952, MSE = 4.0523e-04
# X | train2 -> R² = -16.6377, MSE = 1.4862e+00
# Y | train2 -> R² = -0.1019, MSE = 1.1865e-01
# X | test1 -> R² = -1.4074, MSE = 2.5220e-01
# Y | test1 -> R² = 0.9747, MSE = 2.0769e-03
# X | test2 -> R² = -16.9008, MSE = 1.4731e+00
# Y | test2 -> R² = -0.1063, MSE = 1.1742e-01
# X | test3 -> R² = -0.4717, MSE = 1.3540e-01
# Y | test3 -> R² = 0.4499, MSE = 4.2255e-02
# X | val -> R² = -1.2290, MSE = 2.1314e-01
# Y | val -> R² = 0.3850, MSE = 4.5790e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 0.660948 | Val Loss 0.694252
# Epoch 100 | Train Loss 0.394360 | Val Loss 0.570895
# Epoch 200 | Train Loss 0.382889 | Val Loss 0.523329
# Epoch 300 | Train Loss 0.379557 | Val Loss 0.507369
# Epoch 400 | Train Loss 0.377330 | Val Loss 0.507010
# Epoch 500 | Train Loss 0.375348 | Val Loss 0.510434
# Epoch 600 | Train Loss 0.373672 | Val Loss 0.518007
# Epoch 700 | Train Loss 0.371812 | Val Loss 0.525256
# Early stopping at epoch 722
# X | train1 -> R² = -1.5331, MSE = 2.7314e-01
# Y | train1 -> R² = 0.9969, MSE = 2.6171e-04
# X | train2 -> R² = -22.5319, MSE = 1.9828e+00
# Y | train2 -> R² = -0.1132, MSE = 1.1986e-01
# X | test1 -> R² = -1.7948, MSE = 2.9279e-01
# Y | test1 -> R² = 0.9572, MSE = 3.5063e-03
# X | test2 -> R² = -22.9032, MSE = 1.9671e+00
# Y | test2 -> R² = -0.1421, MSE = 1.2122e-01
# X | test3 -> R² = -1.1915, MSE = 2.0163e-01
# Y | test3 -> R² = 0.6873, MSE = 2.4020e-02
# X | val -> R² = -2.2038, MSE = 3.0635e-01
# Y | val -> R² = 0.6429, MSE = 2.6587e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 0.655961 | Val Loss 0.727331
# Epoch 100 | Train Loss 0.393438 | Val Loss 0.566100
# Epoch 200 | Train Loss 0.382105 | Val Loss 0.518772
# Epoch 300 | Train Loss 0.379065 | Val Loss 0.507932
# Epoch 400 | Train Loss 0.378447 | Val Loss 0.509716
# Epoch 500 | Train Loss 0.375745 | Val Loss 0.513445
# Epoch 600 | Train Loss 0.373421 | Val Loss 0.521096
# Early stopping at epoch 695
# X | train1 -> R² = -1.4435, MSE = 2.6348e-01
# Y | train1 -> R² = 0.9953, MSE = 3.9488e-04
# X | train2 -> R² = -23.2336, MSE = 2.0419e+00
# Y | train2 -> R² = -0.0990, MSE = 1.1833e-01
# X | test1 -> R² = -1.7511, MSE = 2.8821e-01
# Y | test1 -> R² = 0.9759, MSE = 1.9730e-03
# X | test2 -> R² = -23.7074, MSE = 2.0332e+00
# Y | test2 -> R² = -0.1014, MSE = 1.1690e-01
# X | test3 -> R² = -1.0474, MSE = 1.8837e-01
# Y | test3 -> R² = 0.5011, MSE = 3.8319e-02
# X | val -> R² = -2.0078, MSE = 2.8761e-01
# Y | val -> R² = 0.3305, MSE = 4.9843e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 0.626640 | Val Loss 0.709715
# Epoch 100 | Train Loss 0.394301 | Val Loss 0.570953
# Epoch 200 | Train Loss 0.383208 | Val Loss 0.526622
# Epoch 300 | Train Loss 0.379377 | Val Loss 0.511061
# Epoch 400 | Train Loss 0.376953 | Val Loss 0.505992
# Epoch 500 | Train Loss 0.375895 | Val Loss 0.509078
# Epoch 600 | Train Loss 0.373148 | Val Loss 0.518141
# Early stopping at epoch 686
# X | train1 -> R² = -1.1091, MSE = 2.2742e-01
# Y | train1 -> R² = 0.9937, MSE = 5.2888e-04
# X | train2 -> R² = -15.0778, MSE = 1.3547e+00
# Y | train2 -> R² = -0.1446, MSE = 1.2325e-01
# X | test1 -> R² = -1.3350, MSE = 2.4461e-01
# Y | test1 -> R² = 0.9767, MSE = 1.9057e-03
# X | test2 -> R² = -15.3367, MSE = 1.3444e+00
# Y | test2 -> R² = -0.1320, MSE = 1.2015e-01
# X | test3 -> R² = -0.1273, MSE = 1.0371e-01
# Y | test3 -> R² = 0.5215, MSE = 3.6751e-02
# X | val -> R² = -0.6885, MSE = 1.6146e-01
# Y | val -> R² = 0.3605, MSE = 4.7614e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 0.771091 | Val Loss 0.718557
# Epoch 100 | Train Loss 0.397776 | Val Loss 0.567261
# Epoch 200 | Train Loss 0.385781 | Val Loss 0.540708
# Epoch 300 | Train Loss 0.379362 | Val Loss 0.514390
# Epoch 400 | Train Loss 0.376256 | Val Loss 0.506917
# Epoch 500 | Train Loss 0.375134 | Val Loss 0.514931
# Epoch 600 | Train Loss 0.372907 | Val Loss 0.523394
# Early stopping at epoch 637
# X | train1 -> R² = -1.2226, MSE = 2.3966e-01
# Y | train1 -> R² = 0.9905, MSE = 7.9454e-04
# X | train2 -> R² = -23.2064, MSE = 2.0396e+00
# Y | train2 -> R² = -0.1634, MSE = 1.2528e-01
# X | test1 -> R² = -1.3897, MSE = 2.5035e-01
# Y | test1 -> R² = 0.9733, MSE = 2.1849e-03
# X | test2 -> R² = -23.6445, MSE = 2.0281e+00
# Y | test2 -> R² = -0.1428, MSE = 1.2130e-01
# X | test3 -> R² = -0.4816, MSE = 1.3631e-01
# Y | test3 -> R² = 0.4549, MSE = 4.1869e-02
# X | val -> R² = -1.3535, MSE = 2.2505e-01
# Y | val -> R² = 0.3434, MSE = 4.8882e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.730459 | Val Loss 0.749002
# Epoch 100 | Train Loss 0.396732 | Val Loss 0.576582
# Epoch 200 | Train Loss 0.385005 | Val Loss 0.539180
# Epoch 300 | Train Loss 0.379452 | Val Loss 0.512707
# Epoch 400 | Train Loss 0.377144 | Val Loss 0.511850
# Epoch 500 | Train Loss 0.375399 | Val Loss 0.514116
# Epoch 600 | Train Loss 0.373997 | Val Loss 0.517264
# Epoch 700 | Train Loss 0.372842 | Val Loss 0.519474
# Early stopping at epoch 705
# X | train1 -> R² = -1.4207, MSE = 2.6102e-01
# Y | train1 -> R² = 0.9964, MSE = 3.0452e-04
# X | train2 -> R² = -24.8621, MSE = 2.1791e+00
# Y | train2 -> R² = -0.1250, MSE = 1.2114e-01
# X | test1 -> R² = -1.6988, MSE = 2.8273e-01
# Y | test1 -> R² = 0.9729, MSE = 2.2169e-03
# X | test2 -> R² = -25.2820, MSE = 2.1628e+00
# Y | test2 -> R² = -0.1602, MSE = 1.2314e-01
# X | test3 -> R² = -0.1933, MSE = 1.0978e-01
# Y | test3 -> R² = 0.2869, MSE = 5.4768e-02
# X | val -> R² = -1.1630, MSE = 2.0684e-01
# Y | val -> R² = 0.2847, MSE = 5.3257e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.652891 | Val Loss 0.701397
# Epoch 100 | Train Loss 0.395417 | Val Loss 0.568658
# Epoch 200 | Train Loss 0.381616 | Val Loss 0.526905
# Epoch 300 | Train Loss 0.378056 | Val Loss 0.515889
# Epoch 400 | Train Loss 0.377192 | Val Loss 0.519052
# Epoch 500 | Train Loss 0.374261 | Val Loss 0.525176
# Epoch 600 | Train Loss 0.373286 | Val Loss 0.529995
# Early stopping at epoch 625
# X | train1 -> R² = -1.3194, MSE = 2.5009e-01
# Y | train1 -> R² = 0.9968, MSE = 2.7048e-04
# X | train2 -> R² = -19.2708, MSE = 1.7080e+00
# Y | train2 -> R² = -0.1032, MSE = 1.1879e-01
# X | test1 -> R² = -1.6021, MSE = 2.7260e-01
# Y | test1 -> R² = 0.9716, MSE = 2.3294e-03
# X | test2 -> R² = -19.5954, MSE = 1.6949e+00
# Y | test2 -> R² = -0.1313, MSE = 1.2008e-01
# X | test3 -> R² = -0.3124, MSE = 1.2075e-01
# Y | test3 -> R² = 0.5073, MSE = 3.7839e-02
# X | val -> R² = -1.0542, MSE = 1.9643e-01
# Y | val -> R² = 0.4183, MSE = 4.3308e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.664261 | Val Loss 0.742387
# Epoch 100 | Train Loss 0.394773 | Val Loss 0.568155
# Epoch 200 | Train Loss 0.382191 | Val Loss 0.518516
# Epoch 300 | Train Loss 0.379142 | Val Loss 0.508452
# Epoch 400 | Train Loss 0.377443 | Val Loss 0.509968
# Epoch 500 | Train Loss 0.374643 | Val Loss 0.516938
# Early stopping at epoch 572
# X | train1 -> R² = -1.2204, MSE = 2.3941e-01
# Y | train1 -> R² = 0.9963, MSE = 3.1191e-04
# X | train2 -> R² = -16.9407, MSE = 1.5117e+00
# Y | train2 -> R² = -0.0910, MSE = 1.1748e-01
# X | test1 -> R² = -1.3401, MSE = 2.4515e-01
# Y | test1 -> R² = 0.9664, MSE = 2.7551e-03
# X | test2 -> R² = -17.2167, MSE = 1.4991e+00
# Y | test2 -> R² = -0.1065, MSE = 1.1745e-01
# X | test3 -> R² = 0.1861, MSE = 7.4886e-02
# Y | test3 -> R² = 0.5461, MSE = 3.4865e-02
# X | val -> R² = -0.1550, MSE = 1.1045e-01
# Y | val -> R² = 0.4433, MSE = 4.1445e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.629106 | Val Loss 0.658810
# Epoch 100 | Train Loss 0.395641 | Val Loss 0.569037
# Epoch 200 | Train Loss 0.382012 | Val Loss 0.525716
# Epoch 300 | Train Loss 0.378127 | Val Loss 0.510015
# Epoch 400 | Train Loss 0.376214 | Val Loss 0.508866
# Epoch 500 | Train Loss 0.376186 | Val Loss 0.514902
# Epoch 600 | Train Loss 0.372851 | Val Loss 0.517515
# Early stopping at epoch 625
# X | train1 -> R² = -1.2795, MSE = 2.4579e-01
# Y | train1 -> R² = 0.9890, MSE = 9.1850e-04
# X | train2 -> R² = -23.4864, MSE = 2.0632e+00
# Y | train2 -> R² = -0.2218, MSE = 1.3156e-01
# X | test1 -> R² = -1.4613, MSE = 2.5784e-01
# Y | test1 -> R² = 0.9781, MSE = 1.7938e-03
# X | test2 -> R² = -23.9209, MSE = 2.0508e+00
# Y | test2 -> R² = -0.1961, MSE = 1.2696e-01
# X | test3 -> R² = -0.9745, MSE = 1.8166e-01
# Y | test3 -> R² = 0.3926, MSE = 4.6651e-02
# X | val -> R² = -1.9187, MSE = 2.7909e-01
# Y | val -> R² = 0.2884, MSE = 5.2978e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.749829 | Val Loss 0.767532
# Epoch 100 | Train Loss 0.395234 | Val Loss 0.566837
# Epoch 200 | Train Loss 0.383435 | Val Loss 0.522191
# Epoch 300 | Train Loss 0.379612 | Val Loss 0.509468
# Epoch 400 | Train Loss 0.377308 | Val Loss 0.511026
# Epoch 500 | Train Loss 0.375229 | Val Loss 0.516431
# Early stopping at epoch 567
# X | train1 -> R² = -1.2836, MSE = 2.4623e-01
# Y | train1 -> R² = 0.9957, MSE = 3.5933e-04
# X | train2 -> R² = -18.1554, MSE = 1.6140e+00
# Y | train2 -> R² = -0.1093, MSE = 1.1945e-01
# X | test1 -> R² = -1.3540, MSE = 2.4661e-01
# Y | test1 -> R² = 0.9607, MSE = 3.2179e-03
# X | test2 -> R² = -18.4401, MSE = 1.5998e+00
# Y | test2 -> R² = -0.1429, MSE = 1.2131e-01
# X | test3 -> R² = 0.2623, MSE = 6.7871e-02
# Y | test3 -> R² = 0.6577, MSE = 2.6290e-02
# X | val -> R² = -0.2028, MSE = 1.1502e-01
# Y | val -> R² = 0.5888, MSE = 3.0611e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 0.698447 | Val Loss 0.672242
# Epoch 100 | Train Loss 0.395612 | Val Loss 0.570491
# Epoch 200 | Train Loss 0.383559 | Val Loss 0.522477
# Epoch 300 | Train Loss 0.379342 | Val Loss 0.511920
# Epoch 400 | Train Loss 0.376558 | Val Loss 0.512555
# Epoch 500 | Train Loss 0.374371 | Val Loss 0.518327
# Epoch 600 | Train Loss 0.376090 | Val Loss 0.525906
# Early stopping at epoch 633
# X | train1 -> R² = -1.1398, MSE = 2.3073e-01
# Y | train1 -> R² = 0.9943, MSE = 4.7491e-04
# X | train2 -> R² = -15.2700, MSE = 1.3709e+00
# Y | train2 -> R² = -0.0867, MSE = 1.1702e-01
# X | test1 -> R² = -1.3582, MSE = 2.4705e-01
# Y | test1 -> R² = 0.9780, MSE = 1.8063e-03
# X | test2 -> R² = -15.4853, MSE = 1.3566e+00
# Y | test2 -> R² = -0.1044, MSE = 1.1722e-01
# X | test3 -> R² = -0.2067, MSE = 1.1102e-01
# Y | test3 -> R² = 0.2750, MSE = 5.5688e-02
# X | val -> R² = -0.9268, MSE = 1.8424e-01
# Y | val -> R² = 0.0962, MSE = 6.7287e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 0.635797 | Val Loss 0.697947
# Epoch 100 | Train Loss 0.392290 | Val Loss 0.562205
# Epoch 200 | Train Loss 0.381744 | Val Loss 0.514608
# Epoch 300 | Train Loss 0.378743 | Val Loss 0.510281
# Epoch 400 | Train Loss 0.377057 | Val Loss 0.508379
# Epoch 500 | Train Loss 0.374555 | Val Loss 0.511821
# Epoch 600 | Train Loss 0.372974 | Val Loss 0.515745
# Early stopping at epoch 628
# X | train1 -> R² = -1.2546, MSE = 2.4310e-01
# Y | train1 -> R² = 0.9972, MSE = 2.3351e-04
# X | train2 -> R² = -17.9224, MSE = 1.5944e+00
# Y | train2 -> R² = -0.1260, MSE = 1.2125e-01
# X | test1 -> R² = -1.4248, MSE = 2.5402e-01
# Y | test1 -> R² = 0.9657, MSE = 2.8100e-03
# X | test2 -> R² = -18.2139, MSE = 1.5812e+00
# Y | test2 -> R² = -0.1621, MSE = 1.2335e-01
# X | test3 -> R² = -0.6592, MSE = 1.5265e-01
# Y | test3 -> R² = 0.5733, MSE = 3.2774e-02
# X | val -> R² = -1.4162, MSE = 2.3104e-01
# Y | val -> R² = 0.5681, MSE = 3.2153e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 0.665317 | Val Loss 0.740196
# Epoch 100 | Train Loss 0.394614 | Val Loss 0.559938
# Epoch 200 | Train Loss 0.382545 | Val Loss 0.521186
# Epoch 300 | Train Loss 0.380322 | Val Loss 0.511183
# Epoch 400 | Train Loss 0.376831 | Val Loss 0.512535
# Epoch 500 | Train Loss 0.374804 | Val Loss 0.515833
# Epoch 600 | Train Loss 0.373652 | Val Loss 0.520540
# Early stopping at epoch 602
# X | train1 -> R² = -1.2747, MSE = 2.4527e-01
# Y | train1 -> R² = 0.9965, MSE = 2.9500e-04
# X | train2 -> R² = -21.1309, MSE = 1.8648e+00
# Y | train2 -> R² = -0.2754, MSE = 1.3733e-01
# X | test1 -> R² = -1.4521, MSE = 2.5688e-01
# Y | test1 -> R² = 0.9696, MSE = 2.4917e-03
# X | test2 -> R² = -21.5014, MSE = 1.8517e+00
# Y | test2 -> R² = -0.3411, MSE = 1.4235e-01
# X | test3 -> R² = -0.0855, MSE = 9.9874e-02
# Y | test3 -> R² = 0.6198, MSE = 2.9204e-02
# X | val -> R² = -0.6987, MSE = 1.6243e-01
# Y | val -> R² = 0.5433, MSE = 3.4004e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 0.627791 | Val Loss 0.688241
# Epoch 100 | Train Loss 0.396272 | Val Loss 0.567680
# Epoch 200 | Train Loss 0.382685 | Val Loss 0.526079
# Epoch 300 | Train Loss 0.378790 | Val Loss 0.510509
# Epoch 400 | Train Loss 0.376740 | Val Loss 0.508323
# Epoch 500 | Train Loss 0.374923 | Val Loss 0.513110
# Epoch 600 | Train Loss 0.373307 | Val Loss 0.520797
# Early stopping at epoch 670
# X | train1 -> R² = -1.4283, MSE = 2.6184e-01
# Y | train1 -> R² = 0.9949, MSE = 4.2419e-04
# X | train2 -> R² = -26.4258, MSE = 2.3109e+00
# Y | train2 -> R² = -0.0847, MSE = 1.1680e-01
# X | test1 -> R² = -1.7097, MSE = 2.8386e-01
# Y | test1 -> R² = 0.9772, MSE = 1.8673e-03
# X | test2 -> R² = -26.8785, MSE = 2.2942e+00
# Y | test2 -> R² = -0.0947, MSE = 1.1619e-01
# X | test3 -> R² = 0.0496, MSE = 8.7444e-02
# Y | test3 -> R² = 0.6180, MSE = 2.9339e-02
# X | val -> R² = -0.9053, MSE = 1.8219e-01
# Y | val -> R² = 0.5396, MSE = 3.4280e-02
# Figura salva.
# Modelo [264] | Ld=0.3 Lp=0.7 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 0.646698 | Val Loss 0.662483
# Epoch 100 | Train Loss 0.394767 | Val Loss 0.568571
# Epoch 200 | Train Loss 0.381356 | Val Loss 0.523442
# Epoch 300 | Train Loss 0.377497 | Val Loss 0.509619
# Epoch 400 | Train Loss 0.377414 | Val Loss 0.511670
# Epoch 500 | Train Loss 0.373506 | Val Loss 0.514783
# Epoch 600 | Train Loss 0.372017 | Val Loss 0.515349
# Early stopping at epoch 606
# X | train1 -> R² = -1.2392, MSE = 2.4145e-01
# Y | train1 -> R² = 0.9940, MSE = 5.0270e-04
# X | train2 -> R² = -23.3394, MSE = 2.0508e+00
# Y | train2 -> R² = -0.0791, MSE = 1.1620e-01
# X | test1 -> R² = -1.4704, MSE = 2.5880e-01
# Y | test1 -> R² = 0.9791, MSE = 1.7150e-03
# X | test2 -> R² = -23.8058, MSE = 2.0413e+00
# Y | test2 -> R² = -0.0944, MSE = 1.1616e-01
# X | test3 -> R² = -0.1664, MSE = 1.0731e-01
# Y | test3 -> R² = 0.6275, MSE = 2.8608e-02
