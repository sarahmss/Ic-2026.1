# %% [markdown]
# - Entradas: WdRef, WeRef
# - Saidas: Theta
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    # for var in PREDICTORS:
    #     Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 10
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test")
        )

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva.")

        plt.close(fig)

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 1.046743 | Val Loss 0.842367
# Epoch 100 | Train Loss 0.815505 | Val Loss 0.729943
# Epoch 200 | Train Loss 0.801076 | Val Loss 0.725538
# Epoch 300 | Train Loss 0.785854 | Val Loss 0.720153
# Epoch 400 | Train Loss 0.782133 | Val Loss 0.718996
# Epoch 500 | Train Loss 0.778126 | Val Loss 0.724420
# Epoch 600 | Train Loss 0.771186 | Val Loss 0.728546
# Early stopping at epoch 612
# Theta | train1 -> R² = 0.8481, MSE = 3.4666e-02
# Theta | train2 -> R² = 0.4924, MSE = 1.1588e-01
# Theta | test1 -> R² = 0.6586, MSE = 7.8436e-02
# Theta | test2 -> R² = 0.5016, MSE = 1.1820e-01
# Theta | test3 -> R² = 0.0921, MSE = 2.9846e-01
# Theta | val -> R² = 0.5176, MSE = 1.5790e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.027409 | Val Loss 0.832412
# Epoch 100 | Train Loss 0.811052 | Val Loss 0.729731
# Epoch 200 | Train Loss 0.792720 | Val Loss 0.724289
# Epoch 300 | Train Loss 0.784468 | Val Loss 0.721180
# Epoch 400 | Train Loss 0.781243 | Val Loss 0.721289
# Epoch 500 | Train Loss 0.773567 | Val Loss 0.725647
# Early stopping at epoch 599
# Theta | train1 -> R² = 0.8571, MSE = 3.2618e-02
# Theta | train2 -> R² = 0.4302, MSE = 1.3008e-01
# Theta | test1 -> R² = 0.6832, MSE = 7.2776e-02
# Theta | test2 -> R² = 0.4644, MSE = 1.2703e-01
# Theta | test3 -> R² = 0.4061, MSE = 1.9525e-01
# Theta | val -> R² = 0.6599, MSE = 1.1131e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.042562 | Val Loss 0.841186
# Epoch 100 | Train Loss 0.814059 | Val Loss 0.730790
# Epoch 200 | Train Loss 0.801894 | Val Loss 0.727230
# Epoch 300 | Train Loss 0.786729 | Val Loss 0.721765
# Epoch 400 | Train Loss 0.781897 | Val Loss 0.720952
# Epoch 500 | Train Loss 0.777076 | Val Loss 0.724205
# Epoch 600 | Train Loss 0.769907 | Val Loss 0.722978
# Early stopping at epoch 638
# Theta | train1 -> R² = 0.8572, MSE = 3.2589e-02
# Theta | train2 -> R² = 0.4409, MSE = 1.2765e-01
# Theta | test1 -> R² = 0.6623, MSE = 7.7581e-02
# Theta | test2 -> R² = 0.4687, MSE = 1.2599e-01
# Theta | test3 -> R² = 0.4227, MSE = 1.8978e-01
# Theta | val -> R² = 0.6732, MSE = 1.0696e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.028644 | Val Loss 0.832300
# Epoch 100 | Train Loss 0.811381 | Val Loss 0.729506
# Epoch 200 | Train Loss 0.789652 | Val Loss 0.723432
# Epoch 300 | Train Loss 0.783314 | Val Loss 0.720190
# Epoch 400 | Train Loss 0.780774 | Val Loss 0.721102
# Epoch 500 | Train Loss 0.774626 | Val Loss 0.725966
# Early stopping at epoch 579
# Theta | train1 -> R² = 0.8577, MSE = 3.2480e-02
# Theta | train2 -> R² = 0.4479, MSE = 1.2606e-01
# Theta | test1 -> R² = 0.6720, MSE = 7.5346e-02
# Theta | test2 -> R² = 0.4806, MSE = 1.2319e-01
# Theta | test3 -> R² = 0.4091, MSE = 1.9424e-01
# Theta | val -> R² = 0.6664, MSE = 1.0918e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.025804 | Val Loss 0.831705
# Epoch 100 | Train Loss 0.809334 | Val Loss 0.730296
# Epoch 200 | Train Loss 0.789433 | Val Loss 0.724197
# Epoch 300 | Train Loss 0.784585 | Val Loss 0.721372
# Epoch 400 | Train Loss 0.782431 | Val Loss 0.720263
# Epoch 500 | Train Loss 0.777806 | Val Loss 0.720430
# Epoch 600 | Train Loss 0.768798 | Val Loss 0.728423
# Epoch 700 | Train Loss 0.759451 | Val Loss 0.735888
# Early stopping at epoch 701
# Theta | train1 -> R² = 0.8501, MSE = 3.4227e-02
# Theta | train2 -> R² = 0.4825, MSE = 1.1815e-01
# Theta | test1 -> R² = 0.6599, MSE = 7.8126e-02
# Theta | test2 -> R² = 0.5056, MSE = 1.1724e-01
# Theta | test3 -> R² = 0.2124, MSE = 2.5893e-01
# Theta | val -> R² = 0.5767, MSE = 1.3855e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.050441 | Val Loss 0.845860
# Epoch 100 | Train Loss 0.807646 | Val Loss 0.727609
# Epoch 200 | Train Loss 0.787409 | Val Loss 0.723295
# Epoch 300 | Train Loss 0.782381 | Val Loss 0.721359
# Epoch 400 | Train Loss 0.780807 | Val Loss 0.722343
# Epoch 500 | Train Loss 0.774958 | Val Loss 0.728374
# Early stopping at epoch 562
# Theta | train1 -> R² = 0.8689, MSE = 2.9929e-02
# Theta | train2 -> R² = 0.4212, MSE = 1.3213e-01
# Theta | test1 -> R² = 0.6788, MSE = 7.3776e-02
# Theta | test2 -> R² = 0.4685, MSE = 1.2606e-01
# Theta | test3 -> R² = 0.6274, MSE = 1.2251e-01
# Theta | val -> R² = 0.7514, MSE = 8.1374e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.031232 | Val Loss 0.835305
# Epoch 100 | Train Loss 0.812480 | Val Loss 0.730732
# Epoch 200 | Train Loss 0.794448 | Val Loss 0.723426
# Epoch 300 | Train Loss 0.783906 | Val Loss 0.719642
# Epoch 400 | Train Loss 0.780887 | Val Loss 0.722231
# Epoch 500 | Train Loss 0.774332 | Val Loss 0.726738
# Early stopping at epoch 599
# Theta | train1 -> R² = 0.8601, MSE = 3.1924e-02
# Theta | train2 -> R² = 0.4505, MSE = 1.2545e-01
# Theta | test1 -> R² = 0.6875, MSE = 7.1786e-02
# Theta | test2 -> R² = 0.4790, MSE = 1.2357e-01
# Theta | test3 -> R² = 0.3408, MSE = 2.1671e-01
# Theta | val -> R² = 0.6461, MSE = 1.1582e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.041218 | Val Loss 0.840340
# Epoch 100 | Train Loss 0.811950 | Val Loss 0.728817
# Epoch 200 | Train Loss 0.795788 | Val Loss 0.724737
# Epoch 300 | Train Loss 0.785580 | Val Loss 0.719576
# Epoch 400 | Train Loss 0.783250 | Val Loss 0.719151
# Epoch 500 | Train Loss 0.779320 | Val Loss 0.722142
# Early stopping at epoch 597
# Theta | train1 -> R² = 0.8530, MSE = 3.3555e-02
# Theta | train2 -> R² = 0.5034, MSE = 1.1337e-01
# Theta | test1 -> R² = 0.6567, MSE = 7.8870e-02
# Theta | test2 -> R² = 0.5179, MSE = 1.1434e-01
# Theta | test3 -> R² = 0.0686, MSE = 3.0620e-01
# Theta | val -> R² = 0.5149, MSE = 1.5877e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.031085 | Val Loss 0.834117
# Epoch 100 | Train Loss 0.813769 | Val Loss 0.730804
# Epoch 200 | Train Loss 0.794537 | Val Loss 0.724120
# Epoch 300 | Train Loss 0.782968 | Val Loss 0.719672
# Epoch 400 | Train Loss 0.780694 | Val Loss 0.721928
# Epoch 500 | Train Loss 0.776335 | Val Loss 0.727861
# Early stopping at epoch 561
# Theta | train1 -> R² = 0.8570, MSE = 3.2646e-02
# Theta | train2 -> R² = 0.4742, MSE = 1.2004e-01
# Theta | test1 -> R² = 0.6793, MSE = 7.3675e-02
# Theta | test2 -> R² = 0.4931, MSE = 1.2021e-01
# Theta | test3 -> R² = 0.2288, MSE = 2.5353e-01
# Theta | val -> R² = 0.5888, MSE = 1.3458e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.046643 | Val Loss 0.842483
# Epoch 100 | Train Loss 0.813426 | Val Loss 0.729068
# Epoch 200 | Train Loss 0.793697 | Val Loss 0.723972
# Epoch 300 | Train Loss 0.783470 | Val Loss 0.719421
# Epoch 400 | Train Loss 0.782164 | Val Loss 0.719725
# Epoch 500 | Train Loss 0.779663 | Val Loss 0.723714
# Early stopping at epoch 557
# Theta | train1 -> R² = 0.8627, MSE = 3.1338e-02
# Theta | train2 -> R² = 0.4299, MSE = 1.3014e-01
# Theta | test1 -> R² = 0.6969, MSE = 6.9624e-02
# Theta | test2 -> R² = 0.4539, MSE = 1.2951e-01
# Theta | test3 -> R² = 0.3163, MSE = 2.2478e-01
# Theta | val -> R² = 0.6211, MSE = 1.2400e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.044281 | Val Loss 0.841242
# Epoch 100 | Train Loss 0.810164 | Val Loss 0.728668
# Epoch 200 | Train Loss 0.790052 | Val Loss 0.724500
# Epoch 300 | Train Loss 0.783881 | Val Loss 0.721222
# Epoch 400 | Train Loss 0.782578 | Val Loss 0.720401
# Epoch 500 | Train Loss 0.780491 | Val Loss 0.720900
# Epoch 600 | Train Loss 0.773198 | Val Loss 0.724822
# Early stopping at epoch 628
# Theta | train1 -> R² = 0.8495, MSE = 3.4345e-02
# Theta | train2 -> R² = 0.4767, MSE = 1.1947e-01
# Theta | test1 -> R² = 0.6551, MSE = 7.9222e-02
# Theta | test2 -> R² = 0.4981, MSE = 1.1903e-01
# Theta | test3 -> R² = 0.3217, MSE = 2.2299e-01
# Theta | val -> R² = 0.6098, MSE = 1.2769e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.032399 | Val Loss 0.835081
# Epoch 100 | Train Loss 0.811598 | Val Loss 0.729766
# Epoch 200 | Train Loss 0.791667 | Val Loss 0.724826
# Epoch 300 | Train Loss 0.783741 | Val Loss 0.720843
# Epoch 400 | Train Loss 0.781061 | Val Loss 0.722536
# Epoch 500 | Train Loss 0.773505 | Val Loss 0.730334
# Early stopping at epoch 560
# Theta | train1 -> R² = 0.8550, MSE = 3.3106e-02
# Theta | train2 -> R² = 0.4724, MSE = 1.2045e-01
# Theta | test1 -> R² = 0.6550, MSE = 7.9242e-02
# Theta | test2 -> R² = 0.4961, MSE = 1.1951e-01
# Theta | test3 -> R² = 0.3420, MSE = 2.1630e-01
# Theta | val -> R² = 0.6232, MSE = 1.2333e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.038286 | Val Loss 0.839953
# Epoch 100 | Train Loss 0.807883 | Val Loss 0.728157
# Epoch 200 | Train Loss 0.789966 | Val Loss 0.723609
# Epoch 300 | Train Loss 0.784428 | Val Loss 0.721583
# Epoch 400 | Train Loss 0.782477 | Val Loss 0.721671
# Epoch 500 | Train Loss 0.778496 | Val Loss 0.722347
# Epoch 600 | Train Loss 0.769373 | Val Loss 0.727456
# Early stopping at epoch 602
# Theta | train1 -> R² = 0.8567, MSE = 3.2701e-02
# Theta | train2 -> R² = 0.4683, MSE = 1.2140e-01
# Theta | test1 -> R² = 0.6547, MSE = 7.9313e-02
# Theta | test2 -> R² = 0.4987, MSE = 1.1889e-01
# Theta | test3 -> R² = 0.4499, MSE = 1.8084e-01
# Theta | val -> R² = 0.6785, MSE = 1.0523e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.028666 | Val Loss 0.833325
# Epoch 100 | Train Loss 0.812580 | Val Loss 0.730238
# Epoch 200 | Train Loss 0.793749 | Val Loss 0.724089
# Epoch 300 | Train Loss 0.783753 | Val Loss 0.719608
# Epoch 400 | Train Loss 0.781452 | Val Loss 0.721528
# Epoch 500 | Train Loss 0.776876 | Val Loss 0.727007
# Early stopping at epoch 568
# Theta | train1 -> R² = 0.8633, MSE = 3.1209e-02
# Theta | train2 -> R² = 0.4585, MSE = 1.2363e-01
# Theta | test1 -> R² = 0.6874, MSE = 7.1803e-02
# Theta | test2 -> R² = 0.4845, MSE = 1.2226e-01
# Theta | test3 -> R² = 0.3708, MSE = 2.0686e-01
# Theta | val -> R² = 0.6575, MSE = 1.1210e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.033572 | Val Loss 0.834768
# Epoch 100 | Train Loss 0.815622 | Val Loss 0.731435
# Epoch 200 | Train Loss 0.801587 | Val Loss 0.727403
# Epoch 300 | Train Loss 0.786114 | Val Loss 0.722139
# Epoch 400 | Train Loss 0.782917 | Val Loss 0.720188
# Epoch 500 | Train Loss 0.780721 | Val Loss 0.720937
# Epoch 600 | Train Loss 0.774747 | Val Loss 0.722569
# Early stopping at epoch 646
# Theta | train1 -> R² = 0.8508, MSE = 3.4065e-02
# Theta | train2 -> R² = 0.4704, MSE = 1.2092e-01
# Theta | test1 -> R² = 0.6494, MSE = 8.0544e-02
# Theta | test2 -> R² = 0.4928, MSE = 1.2028e-01
# Theta | test3 -> R² = 0.3461, MSE = 2.1498e-01
# Theta | val -> R² = 0.6268, MSE = 1.2215e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.036156 | Val Loss 0.837956
# Epoch 100 | Train Loss 0.809298 | Val Loss 0.730062
# Epoch 200 | Train Loss 0.791771 | Val Loss 0.723410
# Epoch 300 | Train Loss 0.782905 | Val Loss 0.719105
# Epoch 400 | Train Loss 0.779665 | Val Loss 0.725437
# Epoch 500 | Train Loss 0.773466 | Val Loss 0.731818
# Early stopping at epoch 561
# Theta | train1 -> R² = 0.8592, MSE = 3.2142e-02
# Theta | train2 -> R² = 0.4636, MSE = 1.2246e-01
# Theta | test1 -> R² = 0.6795, MSE = 7.3623e-02
# Theta | test2 -> R² = 0.4832, MSE = 1.2257e-01
# Theta | test3 -> R² = 0.2647, MSE = 2.4174e-01
# Theta | val -> R² = 0.6134, MSE = 1.2652e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 1.044097 | Val Loss 0.842002
# Epoch 100 | Train Loss 0.814000 | Val Loss 0.730010
# Epoch 200 | Train Loss 0.799955 | Val Loss 0.725510
# Epoch 300 | Train Loss 0.785810 | Val Loss 0.720143
# Epoch 400 | Train Loss 0.782377 | Val Loss 0.719539
# Epoch 500 | Train Loss 0.777249 | Val Loss 0.725836
# Epoch 600 | Train Loss 0.768246 | Val Loss 0.734961
# Early stopping at epoch 609
# Theta | train1 -> R² = 0.8581, MSE = 3.2401e-02
# Theta | train2 -> R² = 0.4487, MSE = 1.2586e-01
# Theta | test1 -> R² = 0.6771, MSE = 7.4177e-02
# Theta | test2 -> R² = 0.4648, MSE = 1.2693e-01
# Theta | test3 -> R² = 0.2173, MSE = 2.5731e-01
# Theta | val -> R² = 0.5786, MSE = 1.3792e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 1.037300 | Val Loss 0.837866
# Epoch 100 | Train Loss 0.813895 | Val Loss 0.730339
# Epoch 200 | Train Loss 0.796019 | Val Loss 0.725507
# Epoch 300 | Train Loss 0.783933 | Val Loss 0.720599
# Epoch 400 | Train Loss 0.782257 | Val Loss 0.720208
# Epoch 500 | Train Loss 0.778686 | Val Loss 0.723689
# Epoch 600 | Train Loss 0.768734 | Val Loss 0.731967
# Early stopping at epoch 659
# Theta | train1 -> R² = 0.8539, MSE = 3.3340e-02
# Theta | train2 -> R² = 0.4566, MSE = 1.2405e-01
# Theta | test1 -> R² = 0.6611, MSE = 7.7842e-02
# Theta | test2 -> R² = 0.4850, MSE = 1.2214e-01
# Theta | test3 -> R² = 0.3931, MSE = 1.9950e-01
# Theta | val -> R² = 0.6556, MSE = 1.1273e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 1.041057 | Val Loss 0.839512
# Epoch 100 | Train Loss 0.816621 | Val Loss 0.730190
# Epoch 200 | Train Loss 0.798487 | Val Loss 0.726514
# Epoch 300 | Train Loss 0.783996 | Val Loss 0.719158
# Epoch 400 | Train Loss 0.780684 | Val Loss 0.719643
# Epoch 500 | Train Loss 0.774100 | Val Loss 0.725147
# Early stopping at epoch 592
# Theta | train1 -> R² = 0.8463, MSE = 3.5079e-02
# Theta | train2 -> R² = 0.4833, MSE = 1.1797e-01
# Theta | test1 -> R² = 0.6405, MSE = 8.2590e-02
# Theta | test2 -> R² = 0.5021, MSE = 1.1808e-01
# Theta | test3 -> R² = 0.1795, MSE = 2.6975e-01
# Theta | val -> R² = 0.5665, MSE = 1.4189e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 1.034459 | Val Loss 0.835945
# Epoch 100 | Train Loss 0.812179 | Val Loss 0.730093
# Epoch 200 | Train Loss 0.792751 | Val Loss 0.724345
# Epoch 300 | Train Loss 0.783351 | Val Loss 0.719515
# Epoch 400 | Train Loss 0.780778 | Val Loss 0.722814
# Epoch 500 | Train Loss 0.774361 | Val Loss 0.726508
# Early stopping at epoch 576
# Theta | train1 -> R² = 0.8645, MSE = 3.0939e-02
# Theta | train2 -> R² = 0.4605, MSE = 1.2317e-01
# Theta | test1 -> R² = 0.6897, MSE = 7.1273e-02
# Theta | test2 -> R² = 0.4837, MSE = 1.2245e-01
# Theta | test3 -> R² = 0.3673, MSE = 2.0799e-01
# Theta | val -> R² = 0.6549, MSE = 1.1293e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 1.064393 | Val Loss 0.853838
# Epoch 100 | Train Loss 0.817625 | Val Loss 0.729938
# Epoch 200 | Train Loss 0.808458 | Val Loss 0.727930
# Epoch 300 | Train Loss 0.793474 | Val Loss 0.722174
# Epoch 400 | Train Loss 0.782018 | Val Loss 0.718677
# Epoch 500 | Train Loss 0.779324 | Val Loss 0.722517
# Epoch 600 | Train Loss 0.775078 | Val Loss 0.730284
# Early stopping at epoch 684
# Theta | train1 -> R² = 0.8557, MSE = 3.2939e-02
# Theta | train2 -> R² = 0.4491, MSE = 1.2576e-01
# Theta | test1 -> R² = 0.6734, MSE = 7.5023e-02
# Theta | test2 -> R² = 0.4748, MSE = 1.2456e-01
# Theta | test3 -> R² = 0.3476, MSE = 2.1447e-01
# Theta | val -> R² = 0.6496, MSE = 1.1467e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.034544 | Val Loss 0.836936
# Epoch 100 | Train Loss 0.809205 | Val Loss 0.728688
# Epoch 200 | Train Loss 0.789334 | Val Loss 0.723162
# Epoch 300 | Train Loss 0.783596 | Val Loss 0.720034
# Epoch 400 | Train Loss 0.781940 | Val Loss 0.719852
# Epoch 500 | Train Loss 0.776510 | Val Loss 0.723355
# Early stopping at epoch 553
# Theta | train1 -> R² = 0.8518, MSE = 3.3832e-02
# Theta | train2 -> R² = 0.4799, MSE = 1.1874e-01
# Theta | test1 -> R² = 0.6429, MSE = 8.2031e-02
# Theta | test2 -> R² = 0.4977, MSE = 1.1913e-01
# Theta | test3 -> R² = 0.2981, MSE = 2.3074e-01
# Theta | val -> R² = 0.6115, MSE = 1.2714e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.029396 | Val Loss 0.834028
# Epoch 100 | Train Loss 0.813193 | Val Loss 0.731333
# Epoch 200 | Train Loss 0.797083 | Val Loss 0.726160
# Epoch 300 | Train Loss 0.783691 | Val Loss 0.721237
# Epoch 400 | Train Loss 0.780136 | Val Loss 0.725219
# Epoch 500 | Train Loss 0.774967 | Val Loss 0.729359
# Epoch 600 | Train Loss 0.766206 | Val Loss 0.732457
# Early stopping at epoch 602
# Theta | train1 -> R² = 0.8516, MSE = 3.3869e-02
# Theta | train2 -> R² = 0.4740, MSE = 1.2009e-01
# Theta | test1 -> R² = 0.6580, MSE = 7.8557e-02
# Theta | test2 -> R² = 0.4987, MSE = 1.1889e-01
# Theta | test3 -> R² = 0.3220, MSE = 2.2290e-01
# Theta | val -> R² = 0.6241, MSE = 1.2302e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.029726 | Val Loss 0.833088
# Epoch 100 | Train Loss 0.811395 | Val Loss 0.730188
# Epoch 200 | Train Loss 0.790848 | Val Loss 0.723441
# Epoch 300 | Train Loss 0.783886 | Val Loss 0.719467
# Epoch 400 | Train Loss 0.781626 | Val Loss 0.720487
# Epoch 500 | Train Loss 0.777443 | Val Loss 0.727630
# Early stopping at epoch 594
# Theta | train1 -> R² = 0.8540, MSE = 3.3319e-02
# Theta | train2 -> R² = 0.4743, MSE = 1.2001e-01
# Theta | test1 -> R² = 0.6691, MSE = 7.6019e-02
# Theta | test2 -> R² = 0.4974, MSE = 1.1920e-01
# Theta | test3 -> R² = 0.2736, MSE = 2.3880e-01
# Theta | val -> R² = 0.6172, MSE = 1.2528e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.051125 | Val Loss 0.844609
# Epoch 100 | Train Loss 0.816874 | Val Loss 0.730220
# Epoch 200 | Train Loss 0.802607 | Val Loss 0.726319
# Epoch 300 | Train Loss 0.787094 | Val Loss 0.720037
# Epoch 400 | Train Loss 0.783807 | Val Loss 0.720469
# Epoch 500 | Train Loss 0.781503 | Val Loss 0.723705
# Epoch 600 | Train Loss 0.777858 | Val Loss 0.727260
# Early stopping at epoch 629
# Theta | train1 -> R² = 0.8568, MSE = 3.2696e-02
# Theta | train2 -> R² = 0.4940, MSE = 1.1553e-01
# Theta | test1 -> R² = 0.6715, MSE = 7.5474e-02
# Theta | test2 -> R² = 0.5160, MSE = 1.1479e-01
# Theta | test3 -> R² = 0.1606, MSE = 2.7597e-01
# Theta | val -> R² = 0.5749, MSE = 1.3914e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.051360 | Val Loss 0.846132
# Epoch 100 | Train Loss 0.814623 | Val Loss 0.729053
# Epoch 200 | Train Loss 0.799227 | Val Loss 0.726966
# Epoch 300 | Train Loss 0.784699 | Val Loss 0.721868
# Epoch 400 | Train Loss 0.781958 | Val Loss 0.721753
# Epoch 500 | Train Loss 0.779105 | Val Loss 0.727152
# Early stopping at epoch 598
# Theta | train1 -> R² = 0.8494, MSE = 3.4370e-02
# Theta | train2 -> R² = 0.4929, MSE = 1.1578e-01
# Theta | test1 -> R² = 0.6283, MSE = 8.5386e-02
# Theta | test2 -> R² = 0.5129, MSE = 1.1553e-01
# Theta | test3 -> R² = 0.3224, MSE = 2.2275e-01
# Theta | val -> R² = 0.6088, MSE = 1.2803e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 1.043112 | Val Loss 0.840955
# Epoch 100 | Train Loss 0.815746 | Val Loss 0.730159
# Epoch 200 | Train Loss 0.802393 | Val Loss 0.727145
# Epoch 300 | Train Loss 0.785990 | Val Loss 0.719904
# Epoch 400 | Train Loss 0.781526 | Val Loss 0.718588
# Epoch 500 | Train Loss 0.776919 | Val Loss 0.720549
# Epoch 600 | Train Loss 0.769014 | Val Loss 0.725353
# Early stopping at epoch 644
# Theta | train1 -> R² = 0.8579, MSE = 3.2445e-02
# Theta | train2 -> R² = 0.4238, MSE = 1.3155e-01
# Theta | test1 -> R² = 0.6974, MSE = 6.9518e-02
# Theta | test2 -> R² = 0.4500, MSE = 1.3045e-01
# Theta | test3 -> R² = 0.2984, MSE = 2.3066e-01
# Theta | val -> R² = 0.6302, MSE = 1.2104e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 1.042936 | Val Loss 0.841167
# Epoch 100 | Train Loss 0.814722 | Val Loss 0.730235
# Epoch 200 | Train Loss 0.801370 | Val Loss 0.727293
# Epoch 300 | Train Loss 0.785459 | Val Loss 0.721943
# Epoch 400 | Train Loss 0.781762 | Val Loss 0.720383
# Epoch 500 | Train Loss 0.779561 | Val Loss 0.721770
# Epoch 600 | Train Loss 0.771632 | Val Loss 0.724603
# Early stopping at epoch 617
# Theta | train1 -> R² = 0.8406, MSE = 3.6388e-02
# Theta | train2 -> R² = 0.4914, MSE = 1.1610e-01
# Theta | test1 -> R² = 0.5947, MSE = 9.3106e-02
# Theta | test2 -> R² = 0.5070, MSE = 1.1692e-01
# Theta | test3 -> R² = 0.3834, MSE = 2.0272e-01
# Theta | val -> R² = 0.6418, MSE = 1.1723e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 1.037991 | Val Loss 0.838066
# Epoch 100 | Train Loss 0.809931 | Val Loss 0.729587
# Epoch 200 | Train Loss 0.789793 | Val Loss 0.724066
# Epoch 300 | Train Loss 0.783769 | Val Loss 0.720477
# Epoch 400 | Train Loss 0.781656 | Val Loss 0.722160
# Epoch 500 | Train Loss 0.775657 | Val Loss 0.726718
# Early stopping at epoch 586
# Theta | train1 -> R² = 0.8517, MSE = 3.3858e-02
# Theta | train2 -> R² = 0.4750, MSE = 1.1985e-01
# Theta | test1 -> R² = 0.6478, MSE = 8.0906e-02
# Theta | test2 -> R² = 0.5012, MSE = 1.1829e-01
# Theta | test3 -> R² = 0.3598, MSE = 2.1047e-01
# Theta | val -> R² = 0.6411, MSE = 1.1745e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 1.028563 | Val Loss 0.832424
# Epoch 100 | Train Loss 0.813112 | Val Loss 0.731095
# Epoch 200 | Train Loss 0.794266 | Val Loss 0.725225
# Epoch 300 | Train Loss 0.783648 | Val Loss 0.720474
# Epoch 400 | Train Loss 0.780134 | Val Loss 0.724143
# Epoch 500 | Train Loss 0.773022 | Val Loss 0.729664
# Early stopping at epoch 586
# Theta | train1 -> R² = 0.8612, MSE = 3.1681e-02
# Theta | train2 -> R² = 0.4408, MSE = 1.2767e-01
# Theta | test1 -> R² = 0.6755, MSE = 7.4542e-02
# Theta | test2 -> R² = 0.4716, MSE = 1.2532e-01
# Theta | test3 -> R² = 0.4448, MSE = 1.8251e-01
# Theta | val -> R² = 0.6829, MSE = 1.0378e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 1.094574 | Val Loss 0.853786
# Epoch 100 | Train Loss 0.869817 | Val Loss 0.726679
# Epoch 200 | Train Loss 0.796703 | Val Loss 0.716994
# Epoch 300 | Train Loss 0.783763 | Val Loss 0.719231
# Epoch 400 | Train Loss 0.775262 | Val Loss 0.723351
# Early stopping at epoch 494
# Theta | train1 -> R² = 0.8241, MSE = 4.0149e-02
# Theta | train2 -> R² = 0.3428, MSE = 1.5004e-01
# Theta | test1 -> R² = 0.6863, MSE = 7.2064e-02
# Theta | test2 -> R² = 0.3712, MSE = 1.4914e-01
# Theta | test3 -> R² = 0.3033, MSE = 2.2903e-01
# Theta | val -> R² = 0.6007, MSE = 1.3067e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.060508 | Val Loss 0.835441
# Epoch 100 | Train Loss 0.857616 | Val Loss 0.725307
# Epoch 200 | Train Loss 0.792674 | Val Loss 0.718795
# Epoch 300 | Train Loss 0.782599 | Val Loss 0.722225
# Epoch 400 | Train Loss 0.769213 | Val Loss 0.730309
# Early stopping at epoch 477
# Theta | train1 -> R² = 0.8150, MSE = 4.2234e-02
# Theta | train2 -> R² = 0.3694, MSE = 1.4397e-01
# Theta | test1 -> R² = 0.6360, MSE = 8.3614e-02
# Theta | test2 -> R² = 0.3866, MSE = 1.4546e-01
# Theta | test3 -> R² = 0.2792, MSE = 2.3696e-01
# Theta | val -> R² = 0.5534, MSE = 1.4617e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.075616 | Val Loss 0.844232
# Epoch 100 | Train Loss 0.867445 | Val Loss 0.725839
# Epoch 200 | Train Loss 0.803925 | Val Loss 0.718874
# Epoch 300 | Train Loss 0.785487 | Val Loss 0.719299
# Epoch 400 | Train Loss 0.777983 | Val Loss 0.726424
# Epoch 500 | Train Loss 0.763621 | Val Loss 0.736697
# Early stopping at epoch 510
# Theta | train1 -> R² = 0.8201, MSE = 4.1055e-02
# Theta | train2 -> R² = 0.3320, MSE = 1.5251e-01
# Theta | test1 -> R² = 0.6748, MSE = 7.4704e-02
# Theta | test2 -> R² = 0.3581, MSE = 1.5224e-01
# Theta | test3 -> R² = 0.3609, MSE = 2.1010e-01
# Theta | val -> R² = 0.6033, MSE = 1.2982e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.071157 | Val Loss 0.839348
# Epoch 100 | Train Loss 0.872410 | Val Loss 0.726192
# Epoch 200 | Train Loss 0.802186 | Val Loss 0.717524
# Epoch 300 | Train Loss 0.785718 | Val Loss 0.719426
# Epoch 400 | Train Loss 0.779409 | Val Loss 0.724534
# Early stopping at epoch 494
# Theta | train1 -> R² = 0.8243, MSE = 4.0115e-02
# Theta | train2 -> R² = 0.3677, MSE = 1.4435e-01
# Theta | test1 -> R² = 0.6757, MSE = 7.4507e-02
# Theta | test2 -> R² = 0.3945, MSE = 1.4359e-01
# Theta | test3 -> R² = 0.2789, MSE = 2.3705e-01
# Theta | val -> R² = 0.5877, MSE = 1.3494e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.062486 | Val Loss 0.834807
# Epoch 100 | Train Loss 0.869794 | Val Loss 0.726497
# Epoch 200 | Train Loss 0.804183 | Val Loss 0.719248
# Epoch 300 | Train Loss 0.784760 | Val Loss 0.720355
# Epoch 400 | Train Loss 0.771852 | Val Loss 0.728348
# Epoch 500 | Train Loss 0.754383 | Val Loss 0.740973
# Early stopping at epoch 504
# Theta | train1 -> R² = 0.8218, MSE = 4.0670e-02
# Theta | train2 -> R² = 0.3860, MSE = 1.4017e-01
# Theta | test1 -> R² = 0.6520, MSE = 7.9942e-02
# Theta | test2 -> R² = 0.4128, MSE = 1.3926e-01
# Theta | test3 -> R² = 0.3236, MSE = 2.2236e-01
# Theta | val -> R² = 0.5946, MSE = 1.3269e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.072499 | Val Loss 0.843344
# Epoch 100 | Train Loss 0.871394 | Val Loss 0.725833
# Epoch 200 | Train Loss 0.803819 | Val Loss 0.717293
# Epoch 300 | Train Loss 0.785152 | Val Loss 0.718406
# Epoch 400 | Train Loss 0.777449 | Val Loss 0.726092
# Epoch 500 | Train Loss 0.762108 | Val Loss 0.732756
# Early stopping at epoch 515
# Theta | train1 -> R² = 0.8171, MSE = 4.1756e-02
# Theta | train2 -> R² = 0.2903, MSE = 1.6202e-01
# Theta | test1 -> R² = 0.6939, MSE = 7.0327e-02
# Theta | test2 -> R² = 0.3170, MSE = 1.6197e-01
# Theta | test3 -> R² = 0.3302, MSE = 2.2019e-01
# Theta | val -> R² = 0.6072, MSE = 1.2856e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.076158 | Val Loss 0.843766
# Epoch 100 | Train Loss 0.874909 | Val Loss 0.726171
# Epoch 200 | Train Loss 0.802445 | Val Loss 0.717419
# Epoch 300 | Train Loss 0.784669 | Val Loss 0.719255
# Epoch 400 | Train Loss 0.777803 | Val Loss 0.726901
# Early stopping at epoch 496
# Theta | train1 -> R² = 0.8087, MSE = 4.3677e-02
# Theta | train2 -> R² = 0.3511, MSE = 1.4814e-01
# Theta | test1 -> R² = 0.6193, MSE = 8.7450e-02
# Theta | test2 -> R² = 0.3705, MSE = 1.4929e-01
# Theta | test3 -> R² = 0.3069, MSE = 2.2786e-01
# Theta | val -> R² = 0.5808, MSE = 1.3718e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.060705 | Val Loss 0.834386
# Epoch 100 | Train Loss 0.874970 | Val Loss 0.727038
# Epoch 200 | Train Loss 0.815201 | Val Loss 0.719368
# Epoch 300 | Train Loss 0.785382 | Val Loss 0.719477
# Epoch 400 | Train Loss 0.779950 | Val Loss 0.724327
# Epoch 500 | Train Loss 0.769943 | Val Loss 0.736080
# Early stopping at epoch 521
# Theta | train1 -> R² = 0.8135, MSE = 4.2569e-02
# Theta | train2 -> R² = 0.3424, MSE = 1.5012e-01
# Theta | test1 -> R² = 0.6464, MSE = 8.1231e-02
# Theta | test2 -> R² = 0.3640, MSE = 1.5083e-01
# Theta | test3 -> R² = 0.3143, MSE = 2.2544e-01
# Theta | val -> R² = 0.5848, MSE = 1.3590e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.070792 | Val Loss 0.839580
# Epoch 100 | Train Loss 0.870494 | Val Loss 0.725864
# Epoch 200 | Train Loss 0.804964 | Val Loss 0.719111
# Epoch 300 | Train Loss 0.786525 | Val Loss 0.721075
# Epoch 400 | Train Loss 0.776204 | Val Loss 0.728551
# Epoch 500 | Train Loss 0.759265 | Val Loss 0.746410
# Early stopping at epoch 508
# Theta | train1 -> R² = 0.8178, MSE = 4.1586e-02
# Theta | train2 -> R² = 0.3978, MSE = 1.3748e-01
# Theta | test1 -> R² = 0.6395, MSE = 8.2805e-02
# Theta | test2 -> R² = 0.4214, MSE = 1.3723e-01
# Theta | test3 -> R² = 0.2964, MSE = 2.3130e-01
# Theta | val -> R² = 0.5762, MSE = 1.3869e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.075828 | Val Loss 0.841609
# Epoch 100 | Train Loss 0.872713 | Val Loss 0.726322
# Epoch 200 | Train Loss 0.805215 | Val Loss 0.717166
# Epoch 300 | Train Loss 0.785260 | Val Loss 0.718876
# Epoch 400 | Train Loss 0.777331 | Val Loss 0.729470
# Epoch 500 | Train Loss 0.761094 | Val Loss 0.732162
# Early stopping at epoch 515
# Theta | train1 -> R² = 0.8133, MSE = 4.2626e-02
# Theta | train2 -> R² = 0.3215, MSE = 1.5489e-01
# Theta | test1 -> R² = 0.6641, MSE = 7.7173e-02
# Theta | test2 -> R² = 0.3365, MSE = 1.5735e-01
# Theta | test3 -> R² = 0.2571, MSE = 2.4422e-01
# Theta | val -> R² = 0.5637, MSE = 1.4281e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.069398 | Val Loss 0.837980
# Epoch 100 | Train Loss 0.876038 | Val Loss 0.727085
# Epoch 200 | Train Loss 0.810509 | Val Loss 0.718916
# Epoch 300 | Train Loss 0.787282 | Val Loss 0.718625
# Epoch 400 | Train Loss 0.781487 | Val Loss 0.723517
# Epoch 500 | Train Loss 0.770935 | Val Loss 0.732019
# Early stopping at epoch 510
# Theta | train1 -> R² = 0.8025, MSE = 4.5084e-02
# Theta | train2 -> R² = 0.3962, MSE = 1.3784e-01
# Theta | test1 -> R² = 0.5950, MSE = 9.3047e-02
# Theta | test2 -> R² = 0.4024, MSE = 1.4174e-01
# Theta | test3 -> R² = 0.1844, MSE = 2.6813e-01
# Theta | val -> R² = 0.5115, MSE = 1.5987e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.062808 | Val Loss 0.836143
# Epoch 100 | Train Loss 0.876160 | Val Loss 0.726851
# Epoch 200 | Train Loss 0.812754 | Val Loss 0.718283
# Epoch 300 | Train Loss 0.783152 | Val Loss 0.722186
# Epoch 400 | Train Loss 0.773063 | Val Loss 0.732021
# Epoch 500 | Train Loss 0.759603 | Val Loss 0.746438
# Early stopping at epoch 506
# Theta | train1 -> R² = 0.8222, MSE = 4.0594e-02
# Theta | train2 -> R² = 0.3582, MSE = 1.4652e-01
# Theta | test1 -> R² = 0.6673, MSE = 7.6433e-02
# Theta | test2 -> R² = 0.3736, MSE = 1.4856e-01
# Theta | test3 -> R² = 0.2157, MSE = 2.5785e-01
# Theta | val -> R² = 0.5451, MSE = 1.4886e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.069085 | Val Loss 0.840687
# Epoch 100 | Train Loss 0.870975 | Val Loss 0.726508
# Epoch 200 | Train Loss 0.811424 | Val Loss 0.718465
# Epoch 300 | Train Loss 0.785103 | Val Loss 0.717410
# Epoch 400 | Train Loss 0.779156 | Val Loss 0.722115
# Epoch 500 | Train Loss 0.766563 | Val Loss 0.732641
# Early stopping at epoch 525
# Theta | train1 -> R² = 0.8086, MSE = 4.3700e-02
# Theta | train2 -> R² = 0.3053, MSE = 1.5860e-01
# Theta | test1 -> R² = 0.6544, MSE = 7.9395e-02
# Theta | test2 -> R² = 0.3264, MSE = 1.5974e-01
# Theta | test3 -> R² = 0.3060, MSE = 2.2815e-01
# Theta | val -> R² = 0.5891, MSE = 1.3447e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.064678 | Val Loss 0.836830
# Epoch 100 | Train Loss 0.874209 | Val Loss 0.726508
# Epoch 200 | Train Loss 0.802703 | Val Loss 0.717411
# Epoch 300 | Train Loss 0.784101 | Val Loss 0.719657
# Epoch 400 | Train Loss 0.775069 | Val Loss 0.729700
# Epoch 500 | Train Loss 0.759448 | Val Loss 0.745403
# Early stopping at epoch 511
# Theta | train1 -> R² = 0.8078, MSE = 4.3884e-02
# Theta | train2 -> R² = 0.3887, MSE = 1.3957e-01
# Theta | test1 -> R² = 0.6284, MSE = 8.5369e-02
# Theta | test2 -> R² = 0.4061, MSE = 1.4086e-01
# Theta | test3 -> R² = 0.2321, MSE = 2.5244e-01
# Theta | val -> R² = 0.5678, MSE = 1.4147e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.072597 | Val Loss 0.840616
# Epoch 100 | Train Loss 0.874120 | Val Loss 0.726555
# Epoch 200 | Train Loss 0.811340 | Val Loss 0.719455
# Epoch 300 | Train Loss 0.785840 | Val Loss 0.720320
# Epoch 400 | Train Loss 0.776735 | Val Loss 0.727038
# Epoch 500 | Train Loss 0.759665 | Val Loss 0.743651
# Early stopping at epoch 506
# Theta | train1 -> R² = 0.8316, MSE = 3.8432e-02
# Theta | train2 -> R² = 0.3779, MSE = 1.4203e-01
# Theta | test1 -> R² = 0.6691, MSE = 7.6016e-02
# Theta | test2 -> R² = 0.3998, MSE = 1.4235e-01
# Theta | test3 -> R² = 0.3525, MSE = 2.1287e-01
# Theta | val -> R² = 0.6101, MSE = 1.2759e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.070306 | Val Loss 0.841762
# Epoch 100 | Train Loss 0.872169 | Val Loss 0.726116
# Epoch 200 | Train Loss 0.807529 | Val Loss 0.717217
# Epoch 300 | Train Loss 0.782145 | Val Loss 0.720062
# Epoch 400 | Train Loss 0.774251 | Val Loss 0.731919
# Epoch 500 | Train Loss 0.761455 | Val Loss 0.756345
# Early stopping at epoch 513
# Theta | train1 -> R² = 0.8133, MSE = 4.2619e-02
# Theta | train2 -> R² = 0.3081, MSE = 1.5796e-01
# Theta | test1 -> R² = 0.6645, MSE = 7.7074e-02
# Theta | test2 -> R² = 0.3248, MSE = 1.6013e-01
# Theta | test3 -> R² = 0.2849, MSE = 2.3510e-01
# Theta | val -> R² = 0.5764, MSE = 1.3864e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=5 salvo.
# Epoch 0 | Train Loss 1.065376 | Val Loss 0.836596
# Epoch 100 | Train Loss 0.875179 | Val Loss 0.727302
# Epoch 200 | Train Loss 0.821358 | Val Loss 0.720296
# Epoch 300 | Train Loss 0.786562 | Val Loss 0.717655
# Epoch 400 | Train Loss 0.781342 | Val Loss 0.721246
# Epoch 500 | Train Loss 0.769564 | Val Loss 0.725124
# Early stopping at epoch 548
# Theta | train1 -> R² = 0.8136, MSE = 4.2548e-02
# Theta | train2 -> R² = 0.3186, MSE = 1.5557e-01
# Theta | test1 -> R² = 0.6815, MSE = 7.3167e-02
# Theta | test2 -> R² = 0.3384, MSE = 1.5692e-01
# Theta | test3 -> R² = 0.2771, MSE = 2.3764e-01
# Theta | val -> R² = 0.5821, MSE = 1.3677e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=6 salvo.
# Epoch 0 | Train Loss 1.058088 | Val Loss 0.834026
# Epoch 100 | Train Loss 0.877751 | Val Loss 0.727264
# Epoch 200 | Train Loss 0.824314 | Val Loss 0.720617
# Epoch 300 | Train Loss 0.786167 | Val Loss 0.719129
# Epoch 400 | Train Loss 0.777796 | Val Loss 0.726139
# Epoch 500 | Train Loss 0.758969 | Val Loss 0.740330
# Early stopping at epoch 522
# Theta | train1 -> R² = 0.8203, MSE = 4.1011e-02
# Theta | train2 -> R² = 0.3516, MSE = 1.4804e-01
# Theta | test1 -> R² = 0.6508, MSE = 8.0212e-02
# Theta | test2 -> R² = 0.3661, MSE = 1.5034e-01
# Theta | test3 -> R² = 0.2872, MSE = 2.3432e-01
# Theta | val -> R² = 0.5640, MSE = 1.4269e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=7 salvo.
# Epoch 0 | Train Loss 1.071935 | Val Loss 0.840630
# Epoch 100 | Train Loss 0.872560 | Val Loss 0.725609
# Epoch 200 | Train Loss 0.805915 | Val Loss 0.717930
# Epoch 300 | Train Loss 0.787651 | Val Loss 0.720432
# Epoch 400 | Train Loss 0.779454 | Val Loss 0.728000
# Epoch 500 | Train Loss 0.765412 | Val Loss 0.742562
# Early stopping at epoch 505
# Theta | train1 -> R² = 0.8184, MSE = 4.1449e-02
# Theta | train2 -> R² = 0.4038, MSE = 1.3612e-01
# Theta | test1 -> R² = 0.6440, MSE = 8.1784e-02
# Theta | test2 -> R² = 0.4257, MSE = 1.3620e-01
# Theta | test3 -> R² = 0.2674, MSE = 2.4085e-01
# Theta | val -> R² = 0.5753, MSE = 1.3899e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=8 salvo.
# Epoch 0 | Train Loss 1.067196 | Val Loss 0.836661
# Epoch 100 | Train Loss 0.869762 | Val Loss 0.726489
# Epoch 200 | Train Loss 0.799337 | Val Loss 0.718073
# Epoch 300 | Train Loss 0.783920 | Val Loss 0.720494
# Epoch 400 | Train Loss 0.776660 | Val Loss 0.726565
# Early stopping at epoch 493
# Theta | train1 -> R² = 0.8130, MSE = 4.2691e-02
# Theta | train2 -> R² = 0.3725, MSE = 1.4325e-01
# Theta | test1 -> R² = 0.6250, MSE = 8.6141e-02
# Theta | test2 -> R² = 0.3907, MSE = 1.4449e-01
# Theta | test3 -> R² = 0.2934, MSE = 2.3229e-01
# Theta | val -> R² = 0.5732, MSE = 1.3969e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=9 salvo.
# Epoch 0 | Train Loss 1.061498 | Val Loss 0.834568
# Epoch 100 | Train Loss 0.865931 | Val Loss 0.726269
# Epoch 200 | Train Loss 0.800785 | Val Loss 0.718108
# Epoch 300 | Train Loss 0.784903 | Val Loss 0.721747
# Epoch 400 | Train Loss 0.770816 | Val Loss 0.742069
# Epoch 500 | Train Loss 0.753803 | Val Loss 0.753466
# Early stopping at epoch 503
# Theta | train1 -> R² = 0.8148, MSE = 4.2283e-02
# Theta | train2 -> R² = 0.3976, MSE = 1.3753e-01
# Theta | test1 -> R² = 0.6498, MSE = 8.0445e-02
# Theta | test2 -> R² = 0.4122, MSE = 1.3941e-01
# Theta | test3 -> R² = 0.1813, MSE = 2.6916e-01
# Theta | val -> R² = 0.5253, MSE = 1.5537e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.069599 | Val Loss 0.839743
# Epoch 100 | Train Loss 0.877720 | Val Loss 0.726518
# Epoch 200 | Train Loss 0.814335 | Val Loss 0.718665
# Epoch 300 | Train Loss 0.784250 | Val Loss 0.719619
# Epoch 400 | Train Loss 0.776972 | Val Loss 0.730086
# Epoch 500 | Train Loss 0.766655 | Val Loss 0.742354
# Early stopping at epoch 512
# Theta | train1 -> R² = 0.8234, MSE = 4.0314e-02
# Theta | train2 -> R² = 0.3407, MSE = 1.5052e-01
# Theta | test1 -> R² = 0.6740, MSE = 7.4877e-02
# Theta | test2 -> R² = 0.3623, MSE = 1.5123e-01
# Theta | test3 -> R² = 0.3229, MSE = 2.2261e-01
# Theta | val -> R² = 0.5975, MSE = 1.3171e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.066143 | Val Loss 0.839638
# Epoch 100 | Train Loss 0.861983 | Val Loss 0.725347
# Epoch 200 | Train Loss 0.795739 | Val Loss 0.718631
# Epoch 300 | Train Loss 0.783573 | Val Loss 0.721569
# Epoch 400 | Train Loss 0.770528 | Val Loss 0.730611
# Early stopping at epoch 474
# Theta | train1 -> R² = 0.8246, MSE = 4.0046e-02
# Theta | train2 -> R² = 0.3360, MSE = 1.5160e-01
# Theta | test1 -> R² = 0.6719, MSE = 7.5373e-02
# Theta | test2 -> R² = 0.3573, MSE = 1.5242e-01
# Theta | test3 -> R² = 0.3497, MSE = 2.1380e-01
# Theta | val -> R² = 0.5912, MSE = 1.3380e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.063600 | Val Loss 0.835152
# Epoch 100 | Train Loss 0.875404 | Val Loss 0.726752
# Epoch 200 | Train Loss 0.802643 | Val Loss 0.718982
# Epoch 300 | Train Loss 0.786713 | Val Loss 0.721234
# Epoch 400 | Train Loss 0.777199 | Val Loss 0.731443
# Early stopping at epoch 495
# Theta | train1 -> R² = 0.8051, MSE = 4.4497e-02
# Theta | train2 -> R² = 0.4487, MSE = 1.2586e-01
# Theta | test1 -> R² = 0.5875, MSE = 9.4761e-02
# Theta | test2 -> R² = 0.4570, MSE = 1.2878e-01
# Theta | test3 -> R² = 0.1701, MSE = 2.7284e-01
# Theta | val -> R² = 0.5080, MSE = 1.6101e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.062869 | Val Loss 0.834298
# Epoch 100 | Train Loss 0.877920 | Val Loss 0.727669
# Epoch 200 | Train Loss 0.821733 | Val Loss 0.719754
# Epoch 300 | Train Loss 0.784104 | Val Loss 0.719220
# Epoch 400 | Train Loss 0.777532 | Val Loss 0.726603
# Epoch 500 | Train Loss 0.765966 | Val Loss 0.733681
# Early stopping at epoch 522
# Theta | train1 -> R² = 0.8145, MSE = 4.2352e-02
# Theta | train2 -> R² = 0.3415, MSE = 1.5034e-01
# Theta | test1 -> R² = 0.6422, MSE = 8.2185e-02
# Theta | test2 -> R² = 0.3564, MSE = 1.5263e-01
# Theta | test3 -> R² = 0.2818, MSE = 2.3610e-01
# Theta | val -> R² = 0.5730, MSE = 1.3974e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.064777 | Val Loss 0.839103
# Epoch 100 | Train Loss 0.868107 | Val Loss 0.726097
# Epoch 200 | Train Loss 0.798402 | Val Loss 0.717999
# Epoch 300 | Train Loss 0.783071 | Val Loss 0.720454
# Epoch 400 | Train Loss 0.777919 | Val Loss 0.725734
# Early stopping at epoch 487
# Theta | train1 -> R² = 0.8097, MSE = 4.3429e-02
# Theta | train2 -> R² = 0.3840, MSE = 1.4063e-01
# Theta | test1 -> R² = 0.6112, MSE = 8.9306e-02
# Theta | test2 -> R² = 0.3957, MSE = 1.4332e-01
# Theta | test3 -> R² = 0.2573, MSE = 2.4418e-01
# Theta | val -> R² = 0.5547, MSE = 1.4575e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 1.064207 | Val Loss 0.837881
# Epoch 100 | Train Loss 0.875621 | Val Loss 0.727645
# Epoch 200 | Train Loss 0.812046 | Val Loss 0.720036
# Epoch 300 | Train Loss 0.784097 | Val Loss 0.720633
# Epoch 400 | Train Loss 0.771704 | Val Loss 0.734631
# Epoch 500 | Train Loss 0.754982 | Val Loss 0.755761
# Early stopping at epoch 516
# Theta | train1 -> R² = 0.8143, MSE = 4.2379e-02
# Theta | train2 -> R² = 0.3572, MSE = 1.4676e-01
# Theta | test1 -> R² = 0.6297, MSE = 8.5065e-02
# Theta | test2 -> R² = 0.3794, MSE = 1.4717e-01
# Theta | test3 -> R² = 0.3527, MSE = 2.1278e-01
# Theta | val -> R² = 0.5956, MSE = 1.3235e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 1.062562 | Val Loss 0.837052
# Epoch 100 | Train Loss 0.866122 | Val Loss 0.726443
# Epoch 200 | Train Loss 0.800703 | Val Loss 0.718833
# Epoch 300 | Train Loss 0.784425 | Val Loss 0.721660
# Epoch 400 | Train Loss 0.772353 | Val Loss 0.729933
# Early stopping at epoch 499
# Theta | train1 -> R² = 0.8247, MSE = 4.0005e-02
# Theta | train2 -> R² = 0.3453, MSE = 1.4946e-01
# Theta | test1 -> R² = 0.6753, MSE = 7.4581e-02
# Theta | test2 -> R² = 0.3694, MSE = 1.4955e-01
# Theta | test3 -> R² = 0.3401, MSE = 2.1695e-01
# Theta | val -> R² = 0.5947, MSE = 1.3263e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 1.059296 | Val Loss 0.831491
# Epoch 100 | Train Loss 0.882738 | Val Loss 0.728026
# Epoch 200 | Train Loss 0.833113 | Val Loss 0.721196
# Epoch 300 | Train Loss 0.785071 | Val Loss 0.718514
# Epoch 400 | Train Loss 0.779012 | Val Loss 0.731186
# Epoch 500 | Train Loss 0.772104 | Val Loss 0.745197
# Early stopping at epoch 537
# Theta | train1 -> R² = 0.8210, MSE = 4.0867e-02
# Theta | train2 -> R² = 0.3151, MSE = 1.5636e-01
# Theta | test1 -> R² = 0.6972, MSE = 6.9556e-02
# Theta | test2 -> R² = 0.3455, MSE = 1.5523e-01
# Theta | test3 -> R² = 0.3439, MSE = 2.1569e-01
# Theta | val -> R² = 0.6111, MSE = 1.2728e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 1.070616 | Val Loss 0.838521
# Epoch 100 | Train Loss 0.873707 | Val Loss 0.726208
# Epoch 200 | Train Loss 0.802480 | Val Loss 0.717923
# Epoch 300 | Train Loss 0.785958 | Val Loss 0.718994
# Epoch 400 | Train Loss 0.776673 | Val Loss 0.722593
# Epoch 500 | Train Loss 0.758572 | Val Loss 0.730316
# Early stopping at epoch 513
# Theta | train1 -> R² = 0.8034, MSE = 4.4883e-02
# Theta | train2 -> R² = 0.3839, MSE = 1.4065e-01
# Theta | test1 -> R² = 0.6188, MSE = 8.7579e-02
# Theta | test2 -> R² = 0.3954, MSE = 1.4339e-01
# Theta | test3 -> R² = 0.2393, MSE = 2.5008e-01
# Theta | val -> R² = 0.5539, MSE = 1.4600e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 1.008247 | Val Loss 0.838050
# Epoch 100 | Train Loss 0.742900 | Val Loss 0.736742
# Epoch 200 | Train Loss 0.739896 | Val Loss 0.734158
# Epoch 300 | Train Loss 0.738739 | Val Loss 0.730606
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.7829, MSE = 4.9568e-02
# Theta | train2 -> R² = 0.3098, MSE = 1.5757e-01
# Theta | test1 -> R² = 0.5942, MSE = 9.3217e-02
# Theta | test2 -> R² = 0.3229, MSE = 1.6058e-01
# Theta | test3 -> R² = 0.1629, MSE = 2.7520e-01
# Theta | val -> R² = 0.4582, MSE = 1.7731e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.998953 | Val Loss 0.832533
# Epoch 100 | Train Loss 0.742087 | Val Loss 0.737299
# Epoch 200 | Train Loss 0.739217 | Val Loss 0.734200
# Epoch 300 | Train Loss 0.738302 | Val Loss 0.731032
# Early stopping at epoch 348
# Theta | train1 -> R² = 0.7761, MSE = 5.1101e-02
# Theta | train2 -> R² = 0.1424, MSE = 1.9579e-01
# Theta | test1 -> R² = 0.6541, MSE = 7.9450e-02
# Theta | test2 -> R² = 0.1754, MSE = 1.9555e-01
# Theta | test3 -> R² = 0.3107, MSE = 2.2661e-01
# Theta | val -> R² = 0.5260, MSE = 1.5513e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.019550 | Val Loss 0.843773
# Epoch 100 | Train Loss 0.742385 | Val Loss 0.734544
# Epoch 200 | Train Loss 0.739464 | Val Loss 0.734361
# Epoch 300 | Train Loss 0.738335 | Val Loss 0.730760
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.7744, MSE = 5.1490e-02
# Theta | train2 -> R² = 0.1797, MSE = 1.8728e-01
# Theta | test1 -> R² = 0.6460, MSE = 8.1329e-02
# Theta | test2 -> R² = 0.2069, MSE = 1.8809e-01
# Theta | test3 -> R² = 0.2815, MSE = 2.3619e-01
# Theta | val -> R² = 0.5123, MSE = 1.5960e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.008556 | Val Loss 0.837827
# Epoch 100 | Train Loss 0.742517 | Val Loss 0.737317
# Epoch 200 | Train Loss 0.739496 | Val Loss 0.733840
# Epoch 300 | Train Loss 0.738076 | Val Loss 0.730730
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.7984, MSE = 4.6022e-02
# Theta | train2 -> R² = 0.3471, MSE = 1.4907e-01
# Theta | test1 -> R² = 0.5948, MSE = 9.3090e-02
# Theta | test2 -> R² = 0.3618, MSE = 1.5136e-01
# Theta | test3 -> R² = 0.1786, MSE = 2.7002e-01
# Theta | val -> R² = 0.4790, MSE = 1.7052e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.004930 | Val Loss 0.835255
# Epoch 100 | Train Loss 0.742196 | Val Loss 0.739330
# Epoch 200 | Train Loss 0.739747 | Val Loss 0.735193
# Epoch 300 | Train Loss 0.738830 | Val Loss 0.731437
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.7650, MSE = 5.3632e-02
# Theta | train2 -> R² = 0.1725, MSE = 1.8892e-01
# Theta | test1 -> R² = 0.6232, MSE = 8.6557e-02
# Theta | test2 -> R² = 0.1991, MSE = 1.8995e-01
# Theta | test3 -> R² = 0.2667, MSE = 2.4109e-01
# Theta | val -> R² = 0.4919, MSE = 1.6630e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.018323 | Val Loss 0.843357
# Epoch 100 | Train Loss 0.741772 | Val Loss 0.733174
# Epoch 200 | Train Loss 0.738920 | Val Loss 0.733564
# Epoch 300 | Train Loss 0.737532 | Val Loss 0.730179
# Early stopping at epoch 363
# Theta | train1 -> R² = 0.7924, MSE = 4.7391e-02
# Theta | train2 -> R² = 0.3166, MSE = 1.5602e-01
# Theta | test1 -> R² = 0.6053, MSE = 9.0676e-02
# Theta | test2 -> R² = 0.3349, MSE = 1.5774e-01
# Theta | test3 -> R² = 0.2124, MSE = 2.5891e-01
# Theta | val -> R² = 0.4908, MSE = 1.6666e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.015214 | Val Loss 0.841196
# Epoch 100 | Train Loss 0.742707 | Val Loss 0.736608
# Epoch 200 | Train Loss 0.739633 | Val Loss 0.733221
# Epoch 300 | Train Loss 0.738502 | Val Loss 0.729687
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.7699, MSE = 5.2526e-02
# Theta | train2 -> R² = 0.1716, MSE = 1.8913e-01
# Theta | test1 -> R² = 0.6279, MSE = 8.5469e-02
# Theta | test2 -> R² = 0.1953, MSE = 1.9085e-01
# Theta | test3 -> R² = 0.2307, MSE = 2.5290e-01
# Theta | val -> R² = 0.4762, MSE = 1.7144e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.006480 | Val Loss 0.836853
# Epoch 100 | Train Loss 0.742428 | Val Loss 0.737504
# Epoch 200 | Train Loss 0.740031 | Val Loss 0.734321
# Epoch 300 | Train Loss 0.738467 | Val Loss 0.729854
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.7877, MSE = 4.8465e-02
# Theta | train2 -> R² = 0.3559, MSE = 1.4706e-01
# Theta | test1 -> R² = 0.5798, MSE = 9.6524e-02
# Theta | test2 -> R² = 0.3665, MSE = 1.5025e-01
# Theta | test3 -> R² = 0.1509, MSE = 2.7915e-01
# Theta | val -> R² = 0.4610, MSE = 1.7639e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.007474 | Val Loss 0.837446
# Epoch 100 | Train Loss 0.742460 | Val Loss 0.737025
# Epoch 200 | Train Loss 0.739563 | Val Loss 0.733872
# Epoch 300 | Train Loss 0.738272 | Val Loss 0.729986
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.8058, MSE = 4.4335e-02
# Theta | train2 -> R² = 0.2566, MSE = 1.6973e-01
# Theta | test1 -> R² = 0.6538, MSE = 7.9527e-02
# Theta | test2 -> R² = 0.2864, MSE = 1.6924e-01
# Theta | test3 -> R² = 0.2925, MSE = 2.3258e-01
# Theta | val -> R² = 0.5364, MSE = 1.5174e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.037880 | Val Loss 0.856466
# Epoch 100 | Train Loss 0.743440 | Val Loss 0.735206
# Epoch 200 | Train Loss 0.740694 | Val Loss 0.735378
# Epoch 300 | Train Loss 0.738906 | Val Loss 0.731046
# Early stopping at epoch 362
# Theta | train1 -> R² = 0.7899, MSE = 4.7964e-02
# Theta | train2 -> R² = 0.3153, MSE = 1.5633e-01
# Theta | test1 -> R² = 0.6045, MSE = 9.0861e-02
# Theta | test2 -> R² = 0.3321, MSE = 1.5839e-01
# Theta | test3 -> R² = 0.1959, MSE = 2.6434e-01
# Theta | val -> R² = 0.4814, MSE = 1.6974e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.016670 | Val Loss 0.842481
# Epoch 100 | Train Loss 0.742643 | Val Loss 0.736141
# Epoch 200 | Train Loss 0.739866 | Val Loss 0.735262
# Epoch 300 | Train Loss 0.738394 | Val Loss 0.731220
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.7599, MSE = 5.4795e-02
# Theta | train2 -> R² = 0.2443, MSE = 1.7252e-01
# Theta | test1 -> R² = 0.5800, MSE = 9.6475e-02
# Theta | test2 -> R² = 0.2556, MSE = 1.7654e-01
# Theta | test3 -> R² = 0.1380, MSE = 2.8338e-01
# Theta | val -> R² = 0.4237, MSE = 1.8861e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.014915 | Val Loss 0.841076
# Epoch 100 | Train Loss 0.742677 | Val Loss 0.734054
# Epoch 200 | Train Loss 0.739589 | Val Loss 0.733846
# Epoch 300 | Train Loss 0.738028 | Val Loss 0.729999
# Early stopping at epoch 359
# Theta | train1 -> R² = 0.8067, MSE = 4.4134e-02
# Theta | train2 -> R² = 0.2723, MSE = 1.6613e-01
# Theta | test1 -> R² = 0.6580, MSE = 7.8556e-02
# Theta | test2 -> R² = 0.3004, MSE = 1.6592e-01
# Theta | test3 -> R² = 0.2925, MSE = 2.3258e-01
# Theta | val -> R² = 0.5457, MSE = 1.4868e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.006615 | Val Loss 0.836923
# Epoch 100 | Train Loss 0.741597 | Val Loss 0.737046
# Epoch 200 | Train Loss 0.739238 | Val Loss 0.734245
# Epoch 300 | Train Loss 0.738296 | Val Loss 0.731727
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.7942, MSE = 4.6986e-02
# Theta | train2 -> R² = 0.3533, MSE = 1.4764e-01
# Theta | test1 -> R² = 0.6013, MSE = 9.1592e-02
# Theta | test2 -> R² = 0.3667, MSE = 1.5020e-01
# Theta | test3 -> R² = 0.1828, MSE = 2.6866e-01
# Theta | val -> R² = 0.4817, MSE = 1.6963e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.001549 | Val Loss 0.834135
# Epoch 100 | Train Loss 0.742221 | Val Loss 0.736287
# Epoch 200 | Train Loss 0.739463 | Val Loss 0.732855
# Epoch 300 | Train Loss 0.738088 | Val Loss 0.727990
# Epoch 400 | Train Loss 0.737468 | Val Loss 0.727828
# ...
# Epoch 0 | Train Loss 1.061839 | Val Loss 0.840301
# Epoch 100 | Train Loss 0.927637 | Val Loss 0.743612
# Epoch 200 | Train Loss 0.871406 | Val Loss 0.716143
# Epoch 300 | Train Loss 0.837344 | Val Loss 0.715615
# Epoch 400 | Train Loss 0.795247 | Val Loss 0.709834
# Epoch 500 | Train Loss 0.778956 | Val Loss 0.712945
# Epoch 600 | Train Loss 0.766096 | Val Loss 0.724648
# Early stopping at epoch 685
# Theta | train1 -> R² = 0.7928, MSE = 4.7288e-02
# Theta | train2 -> R² = 0.3114, MSE = 1.5722e-01
# Theta | test1 -> R² = 0.6501, MSE = 8.0389e-02
# Theta | test2 -> R² = 0.3632, MSE = 1.5103e-01
# Theta | test3 -> R² = 0.3592, MSE = 2.1066e-01
# Theta | val -> R² = 0.7276, MSE = 8.9148e-02
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.062822 | Val Loss 0.841678
# Epoch 100 | Train Loss 0.939253 | Val Loss 0.755066
# Epoch 200 | Train Loss 0.871644 | Val Loss 0.716836
# Epoch 300 | Train Loss 0.829930 | Val Loss 0.714084
# Epoch 400 | Train Loss 0.787696 | Val Loss 0.711781
# Epoch 500 | Train Loss 0.775002 | Val Loss 0.715168
# Epoch 600 | Train Loss 0.764137 | Val Loss 0.729956
# Early stopping at epoch 659
# Theta | train1 -> R² = 0.7775, MSE = 5.0787e-02
# Theta | train2 -> R² = 0.3013, MSE = 1.5951e-01
# Theta | test1 -> R² = 0.5968, MSE = 9.2630e-02
# Theta | test2 -> R² = 0.3296, MSE = 1.5899e-01
# Theta | test3 -> R² = 0.2354, MSE = 2.5137e-01
# Theta | val -> R² = 0.6117, MSE = 1.2708e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.062571 | Val Loss 0.841232
# Epoch 100 | Train Loss 0.923216 | Val Loss 0.743222
# Epoch 200 | Train Loss 0.868295 | Val Loss 0.716356
# Epoch 300 | Train Loss 0.834022 | Val Loss 0.713855
# Epoch 400 | Train Loss 0.793590 | Val Loss 0.705914
# Epoch 500 | Train Loss 0.771244 | Val Loss 0.706349
# Epoch 600 | Train Loss 0.755905 | Val Loss 0.719513
# Epoch 700 | Train Loss 0.741575 | Val Loss 0.736994
# Early stopping at epoch 709
# Theta | train1 -> R² = 0.8000, MSE = 4.5650e-02
# Theta | train2 -> R² = 0.2343, MSE = 1.7482e-01
# Theta | test1 -> R² = 0.6400, MSE = 8.2694e-02
# Theta | test2 -> R² = 0.2599, MSE = 1.7553e-01
# Theta | test3 -> R² = 0.2636, MSE = 2.4208e-01
# Theta | val -> R² = 0.6762, MSE = 1.0597e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.061725 | Val Loss 0.840990
# Epoch 100 | Train Loss 0.912280 | Val Loss 0.745271
# Epoch 200 | Train Loss 0.832048 | Val Loss 0.714882
# Epoch 300 | Train Loss 0.801631 | Val Loss 0.711022
# Epoch 400 | Train Loss 0.781515 | Val Loss 0.710211
# Epoch 500 | Train Loss 0.769021 | Val Loss 0.719454
# Epoch 600 | Train Loss 0.760008 | Val Loss 0.729466
# Early stopping at epoch 609
# Theta | train1 -> R² = 0.7691, MSE = 5.2717e-02
# Theta | train2 -> R² = 0.2339, MSE = 1.7490e-01
# Theta | test1 -> R² = 0.5009, MSE = 1.1466e-01
# Theta | test2 -> R² = 0.2598, MSE = 1.7555e-01
# Theta | test3 -> R² = 0.4263, MSE = 1.8859e-01
# Theta | val -> R² = 0.6930, MSE = 1.0047e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.062424 | Val Loss 0.841226
# Epoch 100 | Train Loss 0.914601 | Val Loss 0.733069
# Epoch 200 | Train Loss 0.883123 | Val Loss 0.714567
# Epoch 300 | Train Loss 0.873622 | Val Loss 0.716880
# Epoch 400 | Train Loss 0.860225 | Val Loss 0.749574
# Epoch 500 | Train Loss 0.844481 | Val Loss 0.774158
# Early stopping at epoch 509
# Theta | train1 -> R² = 0.7708, MSE = 5.2320e-02
# Theta | train2 -> R² = 0.2675, MSE = 1.6722e-01
# Theta | test1 -> R² = 0.5418, MSE = 1.0526e-01
# Theta | test2 -> R² = 0.2416, MSE = 1.7986e-01
# Theta | test3 -> R² = -0.3245, MSE = 4.3541e-01
# Theta | val -> R² = 0.2804, MSE = 2.3552e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.062548 | Val Loss 0.841265
# Epoch 100 | Train Loss 0.902390 | Val Loss 0.727066
# Epoch 200 | Train Loss 0.882532 | Val Loss 0.719084
# Epoch 300 | Train Loss 0.873094 | Val Loss 0.718755
# Epoch 400 | Train Loss 0.857199 | Val Loss 0.716819
# Epoch 500 | Train Loss 0.819233 | Val Loss 0.717933
# Epoch 600 | Train Loss 0.782623 | Val Loss 0.728044
# Epoch 700 | Train Loss 0.772615 | Val Loss 0.738992
# Early stopping at epoch 727
# Theta | train1 -> R² = 0.7704, MSE = 5.2410e-02
# Theta | train2 -> R² = 0.3716, MSE = 1.4347e-01
# Theta | test1 -> R² = 0.5772, MSE = 9.7124e-02
# Theta | test2 -> R² = 0.3799, MSE = 1.4706e-01
# Theta | test3 -> R² = -0.0169, MSE = 3.3429e-01
# Theta | val -> R² = 0.5186, MSE = 1.5756e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=5 salvo.
# Epoch 0 | Train Loss 1.062754 | Val Loss 0.841417
# Epoch 100 | Train Loss 0.938531 | Val Loss 0.750086
# Epoch 200 | Train Loss 0.885089 | Val Loss 0.717283
# Epoch 300 | Train Loss 0.872910 | Val Loss 0.717407
# Epoch 400 | Train Loss 0.859008 | Val Loss 0.718947
# Early stopping at epoch 424
# Theta | train1 -> R² = 0.7437, MSE = 5.8515e-02
# Theta | train2 -> R² = 0.1334, MSE = 1.9785e-01
# Theta | test1 -> R² = 0.4554, MSE = 1.2510e-01
# Theta | test2 -> R² = 0.1368, MSE = 2.0471e-01
# Theta | test3 -> R² = 0.0781, MSE = 3.0306e-01
# Theta | val -> R² = 0.4444, MSE = 1.8184e-01
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_18472\1563548962.py:93: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=6 salvo.
# Epoch 0 | Train Loss 1.062780 | Val Loss 0.841516
# Epoch 100 | Train Loss 0.954088 | Val Loss 0.767043
# Epoch 200 | Train Loss 0.852015 | Val Loss 0.715766
# Epoch 300 | Train Loss 0.819138 | Val Loss 0.712914
# Epoch 400 | Train Loss 0.791462 | Val Loss 0.708179
# Epoch 500 | Train Loss 0.772405 | Val Loss 0.708359
# Epoch 600 | Train Loss 0.756385 | Val Loss 0.716144
# Early stopping at epoch 698
# Theta | train1 -> R² = 0.7544, MSE = 5.6064e-02
# Theta | train2 -> R² = 0.2867, MSE = 1.6286e-01
# Theta | test1 -> R² = 0.5587, MSE = 1.0138e-01
# Theta | test2 -> R² = 0.3147, MSE = 1.6252e-01
# Theta | test3 -> R² = 0.1649, MSE = 2.7455e-01
# Theta | val -> R² = 0.6340, MSE = 1.1977e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=7 salvo.
# Epoch 0 | Train Loss 1.063074 | Val Loss 0.841546
# Epoch 100 | Train Loss 0.946093 | Val Loss 0.760073
# Epoch 200 | Train Loss 0.858488 | Val Loss 0.713483
# Epoch 300 | Train Loss 0.823699 | Val Loss 0.710565
# Epoch 400 | Train Loss 0.789340 | Val Loss 0.711565
# Epoch 500 | Train Loss 0.766740 | Val Loss 0.726767
# Epoch 600 | Train Loss 0.753464 | Val Loss 0.746314
# Early stopping at epoch 619
# Theta | train1 -> R² = 0.7619, MSE = 5.4344e-02
# Theta | train2 -> R² = 0.3158, MSE = 1.5620e-01
# Theta | test1 -> R² = 0.5367, MSE = 1.0643e-01
# Theta | test2 -> R² = 0.3247, MSE = 1.6016e-01
# Theta | test3 -> R² = -0.0697, MSE = 3.5167e-01
# Theta | val -> R² = 0.4878, MSE = 1.6764e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=8 salvo.
# Epoch 0 | Train Loss 1.062463 | Val Loss 0.841323
# Epoch 100 | Train Loss 0.946712 | Val Loss 0.764786
# Epoch 200 | Train Loss 0.848526 | Val Loss 0.717200
# Epoch 300 | Train Loss 0.828021 | Val Loss 0.713486
# Epoch 400 | Train Loss 0.805212 | Val Loss 0.710890
# Epoch 500 | Train Loss 0.780398 | Val Loss 0.710577
# Epoch 600 | Train Loss 0.765583 | Val Loss 0.717234
# Epoch 700 | Train Loss 0.749560 | Val Loss 0.734548
# Early stopping at epoch 721
# Theta | train1 -> R² = 0.7685, MSE = 5.2838e-02
# Theta | train2 -> R² = 0.3389, MSE = 1.5092e-01
# Theta | test1 -> R² = 0.5556, MSE = 1.0209e-01
# Theta | test2 -> R² = 0.3625, MSE = 1.5119e-01
# Theta | test3 -> R² = 0.1781, MSE = 2.7019e-01
# Theta | val -> R² = 0.6134, MSE = 1.2652e-01
# Modelo [8, 4] | Ld=0.3 Lp=0.7 r=0.9 seed=9 salvo.
# Epoch 0 | Train Loss 1.010199 | Val Loss 0.840900
# Epoch 100 | Train Loss 0.796669 | Val Loss 0.730779
# Epoch 200 | Train Loss 0.742968 | Val Loss 0.728230
# Epoch 300 | Train Loss 0.741614 | Val Loss 0.728059
# Epoch 400 | Train Loss 0.740721 | Val Loss 0.728282
# Early stopping at epoch 411
# Theta | train1 -> R² = 0.7787, MSE = 5.0509e-02
# Theta | train2 -> R² = 0.1715, MSE = 1.8916e-01
# Theta | test1 -> R² = 0.5786, MSE = 9.6807e-02
# Theta | test2 -> R² = 0.1906, MSE = 1.9195e-01
# Theta | test3 -> R² = 0.2147, MSE = 2.5817e-01
# Theta | val -> R² = 0.5301, MSE = 1.5379e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.011320 | Val Loss 0.841789
# Epoch 100 | Train Loss 0.833121 | Val Loss 0.744666
# Epoch 200 | Train Loss 0.746494 | Val Loss 0.727594
# Epoch 300 | Train Loss 0.741601 | Val Loss 0.729995
# Epoch 400 | Train Loss 0.740016 | Val Loss 0.731062
# Early stopping at epoch 419
# Theta | train1 -> R² = 0.7548, MSE = 5.5978e-02
# Theta | train2 -> R² = 0.1744, MSE = 1.8849e-01
# Theta | test1 -> R² = 0.4644, MSE = 1.2303e-01
# Theta | test2 -> R² = 0.1788, MSE = 1.9476e-01
# Theta | test3 -> R² = 0.0840, MSE = 3.0112e-01
# Theta | val -> R² = 0.4490, MSE = 1.8034e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.010829 | Val Loss 0.841259
# Epoch 100 | Train Loss 0.797829 | Val Loss 0.728975
# Epoch 200 | Train Loss 0.745654 | Val Loss 0.725989
# Epoch 300 | Train Loss 0.742160 | Val Loss 0.725418
# Epoch 400 | Train Loss 0.740754 | Val Loss 0.724678
# Early stopping at epoch 412
# Theta | train1 -> R² = 0.7490, MSE = 5.7287e-02
# Theta | train2 -> R² = 0.1760, MSE = 1.8811e-01
# Theta | test1 -> R² = 0.4596, MSE = 1.2415e-01
# Theta | test2 -> R² = 0.1856, MSE = 1.9314e-01
# Theta | test3 -> R² = 0.1759, MSE = 2.7093e-01
# Theta | val -> R² = 0.5019, MSE = 1.6302e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.013166 | Val Loss 0.842348
# Epoch 100 | Train Loss 0.886675 | Val Loss 0.772373
# Epoch 200 | Train Loss 0.742318 | Val Loss 0.727808
# Epoch 300 | Train Loss 0.740442 | Val Loss 0.727852
# Epoch 400 | Train Loss 0.739484 | Val Loss 0.728144
# Early stopping at epoch 430
# Theta | train1 -> R² = 0.7740, MSE = 5.1577e-02
# Theta | train2 -> R² = 0.1878, MSE = 1.8542e-01
# Theta | test1 -> R² = 0.5488, MSE = 1.0366e-01
# Theta | test2 -> R² = 0.2041, MSE = 1.8875e-01
# Theta | test3 -> R² = 0.1640, MSE = 2.7482e-01
# Theta | val -> R² = 0.5063, MSE = 1.6158e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.011077 | Val Loss 0.841510
# Epoch 100 | Train Loss 0.879862 | Val Loss 0.771023
# Epoch 200 | Train Loss 0.741617 | Val Loss 0.726947
# Epoch 300 | Train Loss 0.739855 | Val Loss 0.728170
# Epoch 400 | Train Loss 0.738712 | Val Loss 0.730313
# Early stopping at epoch 428
# Theta | train1 -> R² = 0.7454, MSE = 5.8107e-02
# Theta | train2 -> R² = 0.1845, MSE = 1.8618e-01
# Theta | test1 -> R² = 0.5356, MSE = 1.0668e-01
# Theta | test2 -> R² = 0.1962, MSE = 1.9063e-01
# Theta | test3 -> R² = 0.2025, MSE = 2.6218e-01
# Theta | val -> R² = 0.5099, MSE = 1.6041e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.010976 | Val Loss 0.841352
# Epoch 100 | Train Loss 0.820199 | Val Loss 0.739505
# Epoch 200 | Train Loss 0.746808 | Val Loss 0.728648
# Epoch 300 | Train Loss 0.742508 | Val Loss 0.728823
# Epoch 400 | Train Loss 0.740614 | Val Loss 0.727949
# Early stopping at epoch 414
# Theta | train1 -> R² = 0.7412, MSE = 5.9081e-02
# Theta | train2 -> R² = 0.1416, MSE = 1.9598e-01
# Theta | test1 -> R² = 0.4912, MSE = 1.1689e-01
# Theta | test2 -> R² = 0.1552, MSE = 2.0036e-01
# Theta | test3 -> R² = 0.1645, MSE = 2.7468e-01
# Theta | val -> R² = 0.4800, MSE = 1.7019e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=5 salvo.
# Epoch 0 | Train Loss 1.011112 | Val Loss 0.841465
# Epoch 100 | Train Loss 0.898083 | Val Loss 0.780825
# Epoch 200 | Train Loss 0.749082 | Val Loss 0.723024
# Epoch 300 | Train Loss 0.744793 | Val Loss 0.724796
# Epoch 400 | Train Loss 0.740973 | Val Loss 0.729667
# Early stopping at epoch 434
# Theta | train1 -> R² = 0.7345, MSE = 6.0608e-02
# Theta | train2 -> R² = 0.2183, MSE = 1.7846e-01
# Theta | test1 -> R² = 0.5147, MSE = 1.1147e-01
# Theta | test2 -> R² = 0.2516, MSE = 1.7748e-01
# Theta | test3 -> R² = 0.2087, MSE = 2.6013e-01
# Theta | val -> R² = 0.5503, MSE = 1.4719e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=6 salvo.
# Epoch 0 | Train Loss 1.010835 | Val Loss 0.841427
# Epoch 100 | Train Loss 0.863522 | Val Loss 0.762398
# Epoch 200 | Train Loss 0.741164 | Val Loss 0.724214
# Epoch 300 | Train Loss 0.739546 | Val Loss 0.725464
# Epoch 400 | Train Loss 0.738351 | Val Loss 0.727720
# Early stopping at epoch 431
# Theta | train1 -> R² = 0.7546, MSE = 5.6009e-02
# Theta | train2 -> R² = 0.2540, MSE = 1.7032e-01
# Theta | test1 -> R² = 0.4970, MSE = 1.1555e-01
# Theta | test2 -> R² = 0.2620, MSE = 1.7502e-01
# Theta | test3 -> R² = 0.1505, MSE = 2.7928e-01
# Theta | val -> R² = 0.4995, MSE = 1.6380e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=7 salvo.
# Epoch 0 | Train Loss 1.010656 | Val Loss 0.841407
# Epoch 100 | Train Loss 0.873664 | Val Loss 0.765777
# Epoch 200 | Train Loss 0.748700 | Val Loss 0.724334
# Epoch 300 | Train Loss 0.742491 | Val Loss 0.725700
# Epoch 400 | Train Loss 0.740398 | Val Loss 0.728190
# Early stopping at epoch 435
# Theta | train1 -> R² = 0.7223, MSE = 6.3382e-02
# Theta | train2 -> R² = 0.1350, MSE = 1.9749e-01
# Theta | test1 -> R² = 0.3962, MSE = 1.3871e-01
# Theta | test2 -> R² = 0.1365, MSE = 2.0479e-01
# Theta | test3 -> R² = 0.0729, MSE = 3.0477e-01
# Theta | val -> R² = 0.4358, MSE = 1.8465e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=8 salvo.
# Epoch 0 | Train Loss 1.011610 | Val Loss 0.841794
# Epoch 100 | Train Loss 0.796904 | Val Loss 0.728190
# Epoch 200 | Train Loss 0.745132 | Val Loss 0.727322
# Epoch 300 | Train Loss 0.741257 | Val Loss 0.728980
# Epoch 400 | Train Loss 0.740023 | Val Loss 0.729608
# Early stopping at epoch 411
# Theta | train1 -> R² = 0.7565, MSE = 5.5593e-02
# Theta | train2 -> R² = 0.1355, MSE = 1.9737e-01
# Theta | test1 -> R² = 0.4835, MSE = 1.1864e-01
# Theta | test2 -> R² = 0.1531, MSE = 2.0086e-01
# Theta | test3 -> R² = 0.2028, MSE = 2.6206e-01
# Theta | val -> R² = 0.5143, MSE = 1.5895e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=9 salvo.
# Epoch 0 | Train Loss 1.010115 | Val Loss 0.840593
# Epoch 100 | Train Loss 0.763128 | Val Loss 0.721650
# Epoch 200 | Train Loss 0.744191 | Val Loss 0.730676
# Epoch 300 | Train Loss 0.741510 | Val Loss 0.730469
# Early stopping at epoch 398
# Theta | train1 -> R² = 0.7660, MSE = 5.3418e-02
# Theta | train2 -> R² = 0.1277, MSE = 1.9914e-01
# Theta | test1 -> R² = 0.5612, MSE = 1.0080e-01
# Theta | test2 -> R² = 0.1478, MSE = 2.0210e-01
# Theta | test3 -> R² = 0.2046, MSE = 2.6149e-01
# Theta | val -> R² = 0.5067, MSE = 1.6143e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.010961 | Val Loss 0.841638
# Epoch 100 | Train Loss 0.810754 | Val Loss 0.733272
# Epoch 200 | Train Loss 0.746356 | Val Loss 0.727389
# Epoch 300 | Train Loss 0.741999 | Val Loss 0.727954
# Epoch 400 | Train Loss 0.740569 | Val Loss 0.728999
# Early stopping at epoch 415
# Theta | train1 -> R² = 0.7454, MSE = 5.8113e-02
# Theta | train2 -> R² = 0.1039, MSE = 2.0459e-01
# Theta | test1 -> R² = 0.4501, MSE = 1.2632e-01
# Theta | test2 -> R² = 0.1146, MSE = 2.0999e-01
# Theta | test3 -> R² = 0.1413, MSE = 2.8229e-01
# Theta | val -> R² = 0.4720, MSE = 1.7279e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.010445 | Val Loss 0.841220
# Epoch 100 | Train Loss 0.835508 | Val Loss 0.745384
# Epoch 200 | Train Loss 0.745239 | Val Loss 0.726345
# Epoch 300 | Train Loss 0.741091 | Val Loss 0.727459
# Epoch 400 | Train Loss 0.739704 | Val Loss 0.727692
# Early stopping at epoch 423
# Theta | train1 -> R² = 0.7597, MSE = 5.4860e-02
# Theta | train2 -> R² = 0.1828, MSE = 1.8656e-01
# Theta | test1 -> R² = 0.4383, MSE = 1.2903e-01
# Theta | test2 -> R² = 0.1928, MSE = 1.9144e-01
# Theta | test3 -> R² = 0.1396, MSE = 2.8285e-01
# Theta | val -> R² = 0.4825, MSE = 1.6937e-01
# Modelo [8, 4] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.013588 | Val Loss 0.842465
# Epoch 100 | Train Loss 0.803113 | Val Loss 0.733445
# Epoch 200 | Train Loss 0.744763 | Val Loss 0.729693
# Epoch 300 | Train Loss 0.741652 | Val Loss 0.726901
# Epoch 400 | Train Loss 0.740200 | Val Loss 0.726565
# Early stopping at epoch 410
# Theta | train1 -> R² = 0.7647, MSE = 5.3706e-02
# Theta | train2 -> R² = 0.1459, MSE = 1.9500e-01
# Theta | test1 -> R² = 0.5641, MSE = 1.0014e-01
# Theta | test2 -> R² = 0.1609, MSE = 1.9901e-01
# Theta | test3 -> R² = 0.1541, MSE = 2.7809e-01
# Theta | val -> R² = 0.4819, MSE = 1.6958e-01
