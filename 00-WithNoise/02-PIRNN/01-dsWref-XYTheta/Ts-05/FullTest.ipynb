# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 5
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    for var in PREDICTORS:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
PREDICTORS = ["dWdRef", "dWeRef", "sWdRef", "sWeRef"]   
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train2, Train1], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada: (1266, 5, 4)
# Dimensão da saida: (1266, 5, 4)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, patience=500, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train, theta_train)
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)
        # plt.show()

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.614942 | Val Loss 0.811783
# Epoch 100 | Train Loss 1.322063 | Val Loss 0.710911
# Epoch 200 | Train Loss 1.289311 | Val Loss 0.704773
# Epoch 300 | Train Loss 1.225034 | Val Loss 0.688064
# Epoch 400 | Train Loss 1.174956 | Val Loss 0.712259
# Epoch 500 | Train Loss 1.138709 | Val Loss 0.725017
# Epoch 600 | Train Loss 1.101015 | Val Loss 0.735311
# Epoch 700 | Train Loss 1.063729 | Val Loss 0.745259
# Early stopping at epoch 753
# Theta | train1 -> R² = 0.8924, MSE = 2.4623e-02
# X | train1 -> R² = -0.0800, MSE = 1.1611e-01
# Y | train1 -> R² = -0.7899, MSE = 1.4979e-01
# Theta | train2 -> R² = -0.1931, MSE = 2.7146e-01
# X | train2 -> R² = -0.1005, MSE = 9.2614e-02
# Y | train2 -> R² = -0.8449, MSE = 1.9810e-01
# Theta | test1 -> R² = 0.8600, MSE = 3.2225e-02
# X | test1 -> R² = 0.0120, MSE = 1.0318e-01
# Y | test1 -> R² = -1.2167, MSE = 1.8136e-01
# Theta | test2 -> R² = 0.0890, MSE = 2.1534e-01
# X | test2 -> R² = -0.0039, MSE = 8.2515e-02
# Y | test2 -> R² = -1.0469, MSE = 2.1669e-01
# Theta | test3 -> R² = 0.4184, MSE = 1.9143e-01
# X | test3 -> R² = 0.1346, MSE = 7.9400e-02
# Y | test3 -> R² = -1.2684, MSE = 1.7393e-01
# Theta | val -> R² = 0.6787, MSE = 1.0531e-01
# X | val -> R² = 0.1422, MSE = 8.1779e-02
# Y | val -> R² = -1.5992, MSE = 1.9321e-01
# Figura salva em: ./results/model_64_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.604264 | Val Loss 0.832527
# Epoch 100 | Train Loss 1.321404 | Val Loss 0.710904
# Epoch 200 | Train Loss 1.277466 | Val Loss 0.698914
# Epoch 300 | Train Loss 1.217969 | Val Loss 0.697324
# Epoch 400 | Train Loss 1.167778 | Val Loss 0.750057
# Epoch 500 | Train Loss 1.127427 | Val Loss 0.787856
# Epoch 600 | Train Loss 1.089868 | Val Loss 0.809444
# Epoch 700 | Train Loss 1.053106 | Val Loss 0.838720
# Early stopping at epoch 732
# Theta | train1 -> R² = 0.8742, MSE = 2.8781e-02
# X | train1 -> R² = -0.1333, MSE = 1.2183e-01
# Y | train1 -> R² = -0.8015, MSE = 1.5077e-01
# Theta | train2 -> R² = 0.0649, MSE = 2.1276e-01
# X | train2 -> R² = -0.1064, MSE = 9.3108e-02
# Y | train2 -> R² = -0.8310, MSE = 1.9660e-01
# Theta | test1 -> R² = 0.7919, MSE = 4.7906e-02
# X | test1 -> R² = -0.1029, MSE = 1.1518e-01
# Y | test1 -> R² = -1.2717, MSE = 1.8586e-01
# Theta | test2 -> R² = 0.4317, MSE = 1.3433e-01
# X | test2 -> R² = -0.0589, MSE = 8.7035e-02
# Y | test2 -> R² = -1.0002, MSE = 2.1174e-01
# Theta | test3 -> R² = -3.1019, MSE = 1.3502e+00
# X | test3 -> R² = -0.0399, MSE = 9.5406e-02
# Y | test3 -> R² = -1.4099, MSE = 1.8478e-01
# Theta | val -> R² = -1.4861, MSE = 8.1468e-01
# X | val -> R² = -0.0480, MSE = 9.9909e-02
# Y | val -> R² = -1.7537, MSE = 2.0469e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.539060 | Val Loss 0.791711
# Epoch 100 | Train Loss 1.321579 | Val Loss 0.711091
# Epoch 200 | Train Loss 1.277610 | Val Loss 0.699660
# Epoch 300 | Train Loss 1.206823 | Val Loss 0.697952
# Epoch 400 | Train Loss 1.156741 | Val Loss 0.709277
# Epoch 500 | Train Loss 1.111989 | Val Loss 0.737391
# Epoch 600 | Train Loss 1.068469 | Val Loss 0.791751
# Epoch 700 | Train Loss 1.030100 | Val Loss 0.839221
# Early stopping at epoch 722
# Theta | train1 -> R² = 0.9048, MSE = 2.1780e-02
# X | train1 -> R² = -0.0802, MSE = 1.1613e-01
# Y | train1 -> R² = -0.8817, MSE = 1.5748e-01
# Theta | train2 -> R² = 0.2811, MSE = 1.6358e-01
# X | train2 -> R² = -0.1148, MSE = 9.3818e-02
# Y | train2 -> R² = -0.7504, MSE = 1.8796e-01
# Theta | test1 -> R² = 0.8475, MSE = 3.5107e-02
# X | test1 -> R² = -0.0905, MSE = 1.1388e-01
# Y | test1 -> R² = -1.3162, MSE = 1.8950e-01
# Theta | test2 -> R² = 0.5592, MSE = 1.0421e-01
# X | test2 -> R² = -0.0324, MSE = 8.4860e-02
# Y | test2 -> R² = -1.0360, MSE = 2.1553e-01
# Theta | test3 -> R² = -0.5941, MSE = 5.2472e-01
# X | test3 -> R² = 0.0043, MSE = 9.1351e-02
# Y | test3 -> R² = -1.5261, MSE = 1.9369e-01
# Theta | val -> R² = 0.4022, MSE = 1.9589e-01
# X | val -> R² = 0.0106, MSE = 9.4328e-02
# Y | val -> R² = -1.8767, MSE = 2.1383e-01
# Figura salva em: ./results/model_64_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.584829 | Val Loss 0.789840
# Epoch 100 | Train Loss 1.321962 | Val Loss 0.711319
# Epoch 200 | Train Loss 1.286465 | Val Loss 0.705073
# Epoch 300 | Train Loss 1.231644 | Val Loss 0.691435
# Epoch 400 | Train Loss 1.177893 | Val Loss 0.707629
# Epoch 500 | Train Loss 1.143717 | Val Loss 0.709493
# Epoch 600 | Train Loss 1.112872 | Val Loss 0.730200
# Epoch 700 | Train Loss 1.083828 | Val Loss 0.769397
# Early stopping at epoch 765
# Theta | train1 -> R² = 0.7497, MSE = 5.7251e-02
# X | train1 -> R² = -0.1270, MSE = 1.2116e-01
# Y | train1 -> R² = -0.7681, MSE = 1.4797e-01
# Theta | train2 -> R² = 0.3690, MSE = 1.4357e-01
# X | train2 -> R² = -0.0928, MSE = 9.1965e-02
# Y | train2 -> R² = -0.8779, MSE = 2.0164e-01
# Theta | test1 -> R² = 0.4883, MSE = 1.1780e-01
# X | test1 -> R² = -0.0914, MSE = 1.1397e-01
# Y | test1 -> R² = -1.1431, MSE = 1.7534e-01
# Theta | test2 -> R² = 0.6309, MSE = 8.7256e-02
# X | test2 -> R² = -0.0228, MSE = 8.4069e-02
# Y | test2 -> R² = -1.0241, MSE = 2.1427e-01
# Theta | test3 -> R² = -3.6074, MSE = 1.5166e+00
# X | test3 -> R² = -0.1673, MSE = 1.0710e-01
# Y | test3 -> R² = -1.1949, MSE = 1.6829e-01
# Theta | val -> R² = -1.6295, MSE = 8.6171e-01
# X | val -> R² = -0.1602, MSE = 1.1061e-01
# Y | val -> R² = -1.3787, MSE = 1.7682e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.535145 | Val Loss 0.758151
# Epoch 100 | Train Loss 1.321765 | Val Loss 0.711814
# Epoch 200 | Train Loss 1.275240 | Val Loss 0.701658
# Epoch 300 | Train Loss 1.209295 | Val Loss 0.716034
# Epoch 400 | Train Loss 1.169883 | Val Loss 0.755346
# Epoch 500 | Train Loss 1.132087 | Val Loss 0.786894
# Epoch 600 | Train Loss 1.093182 | Val Loss 0.810354
# Epoch 700 | Train Loss 1.055895 | Val Loss 0.839700
# Early stopping at epoch 723
# Theta | train1 -> R² = 0.7606, MSE = 5.4769e-02
# X | train1 -> R² = -0.1128, MSE = 1.1963e-01
# Y | train1 -> R² = -0.8250, MSE = 1.5273e-01
# Theta | train2 -> R² = 0.1738, MSE = 1.8797e-01
# X | train2 -> R² = -0.1235, MSE = 9.4547e-02
# Y | train2 -> R² = -0.8362, MSE = 1.9717e-01
# Theta | test1 -> R² = 0.5561, MSE = 1.0217e-01
# X | test1 -> R² = -0.1142, MSE = 1.1636e-01
# Y | test1 -> R² = -1.2992, MSE = 1.8811e-01
# Theta | test2 -> R² = 0.5448, MSE = 1.0759e-01
# X | test2 -> R² = -0.0681, MSE = 8.7789e-02
# Y | test2 -> R² = -0.9650, MSE = 2.0802e-01
# Theta | test3 -> R² = 0.0040, MSE = 3.2784e-01
# X | test3 -> R² = -0.0241, MSE = 9.3960e-02
# Y | test3 -> R² = -1.7000, MSE = 2.0702e-01
# Theta | val -> R² = 0.5782, MSE = 1.3823e-01
# X | val -> R² = -0.0266, MSE = 9.7866e-02
# Y | val -> R² = -1.9850, MSE = 2.2189e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.552510 | Val Loss 0.762024
# Epoch 100 | Train Loss 1.323134 | Val Loss 0.711884
# Epoch 200 | Train Loss 1.296268 | Val Loss 0.708072
# Epoch 300 | Train Loss 1.246088 | Val Loss 0.691861
# Epoch 400 | Train Loss 1.194675 | Val Loss 0.716572
# Epoch 500 | Train Loss 1.162217 | Val Loss 0.734526
# Epoch 600 | Train Loss 1.126677 | Val Loss 0.758141
# Epoch 700 | Train Loss 1.087851 | Val Loss 0.786611
# Early stopping at epoch 774
# Theta | train1 -> R² = 0.7485, MSE = 5.7533e-02
# X | train1 -> R² = -0.1474, MSE = 1.2335e-01
# Y | train1 -> R² = -0.8040, MSE = 1.5098e-01
# Theta | train2 -> R² = 0.4583, MSE = 1.2324e-01
# X | train2 -> R² = -0.1260, MSE = 9.4761e-02
# Y | train2 -> R² = -0.8634, MSE = 2.0009e-01
# Theta | test1 -> R² = 0.6284, MSE = 8.5547e-02
# X | test1 -> R² = -0.1083, MSE = 1.1574e-01
# Y | test1 -> R² = -1.0942, MSE = 1.7134e-01
# Theta | test2 -> R² = 0.6897, MSE = 7.3338e-02
# X | test2 -> R² = -0.0937, MSE = 8.9892e-02
# Y | test2 -> R² = -0.9050, MSE = 2.0166e-01
# Theta | test3 -> R² = -0.6310, MSE = 5.3686e-01
# X | test3 -> R² = -0.0428, MSE = 9.5680e-02
# Y | test3 -> R² = -0.4078, MSE = 1.0794e-01
# Theta | val -> R² = 0.2322, MSE = 2.5161e-01
# X | val -> R² = -0.0477, MSE = 9.9885e-02
# Y | val -> R² = -0.6868, MSE = 1.2538e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.602070 | Val Loss 0.807831
# Epoch 100 | Train Loss 1.322674 | Val Loss 0.711895
# Epoch 200 | Train Loss 1.286551 | Val Loss 0.701328
# Epoch 300 | Train Loss 1.225580 | Val Loss 0.689637
# Epoch 400 | Train Loss 1.183330 | Val Loss 0.708712
# Epoch 500 | Train Loss 1.148123 | Val Loss 0.720052
# Epoch 600 | Train Loss 1.113509 | Val Loss 0.727028
# Epoch 700 | Train Loss 1.078248 | Val Loss 0.750502
# Early stopping at epoch 755
# Theta | train1 -> R² = 0.8234, MSE = 4.0404e-02
# X | train1 -> R² = -0.1492, MSE = 1.2354e-01
# Y | train1 -> R² = -0.7858, MSE = 1.4945e-01
# Theta | train2 -> R² = 0.2918, MSE = 1.6113e-01
# X | train2 -> R² = -0.1352, MSE = 9.5535e-02
# Y | train2 -> R² = -0.8489, MSE = 1.9853e-01
# Theta | test1 -> R² = 0.7565, MSE = 5.6061e-02
# X | test1 -> R² = -0.0821, MSE = 1.1300e-01
# Y | test1 -> R² = -1.1207, MSE = 1.7351e-01
# Theta | test2 -> R² = 0.5158, MSE = 1.1444e-01
# X | test2 -> R² = -0.0375, MSE = 8.5280e-02
# Y | test2 -> R² = -0.9705, MSE = 2.0860e-01
# Theta | test3 -> R² = -0.7190, MSE = 5.6582e-01
# X | test3 -> R² = 0.0472, MSE = 8.7423e-02
# Y | test3 -> R² = -1.2557, MSE = 1.7295e-01
# Theta | val -> R² = 0.0998, MSE = 2.9499e-01
# X | val -> R² = 0.0608, MSE = 8.9537e-02
# Y | val -> R² = -1.4628, MSE = 1.8307e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.559476 | Val Loss 0.797344
# Epoch 100 | Train Loss 1.321043 | Val Loss 0.710779
# Epoch 200 | Train Loss 1.280369 | Val Loss 0.700257
# Epoch 300 | Train Loss 1.217591 | Val Loss 0.694331
# Epoch 400 | Train Loss 1.167503 | Val Loss 0.715268
# Epoch 500 | Train Loss 1.127853 | Val Loss 0.732290
# Epoch 600 | Train Loss 1.088769 | Val Loss 0.759557
# Epoch 700 | Train Loss 1.054597 | Val Loss 0.791503
# Early stopping at epoch 754
# Theta | train1 -> R² = 0.7297, MSE = 6.1818e-02
# X | train1 -> R² = -0.1305, MSE = 1.2154e-01
# Y | train1 -> R² = -0.7359, MSE = 1.4527e-01
# Theta | train2 -> R² = 0.3583, MSE = 1.4600e-01
# X | train2 -> R² = -0.0975, MSE = 9.2361e-02
# Y | train2 -> R² = -0.8603, MSE = 1.9975e-01
# Theta | test1 -> R² = 0.7525, MSE = 5.6975e-02
# X | test1 -> R² = -0.0170, MSE = 1.0621e-01
# Y | test1 -> R² = -1.2289, MSE = 1.8236e-01
# Theta | test2 -> R² = 0.5377, MSE = 1.0927e-01
# X | test2 -> R² = -0.0489, MSE = 8.6211e-02
# Y | test2 -> R² = -1.1050, MSE = 2.2284e-01
# Theta | test3 -> R² = -2.7170, MSE = 1.2235e+00
# X | test3 -> R² = 0.0100, MSE = 9.0832e-02
# Y | test3 -> R² = -1.6036, MSE = 1.9963e-01
# Theta | val -> R² = -0.9395, MSE = 6.3559e-01
# X | val -> R² = 0.0354, MSE = 9.1956e-02
# Y | val -> R² = -1.8811, MSE = 2.1416e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.566701 | Val Loss 0.800412
# Epoch 100 | Train Loss 1.321709 | Val Loss 0.711814
# Epoch 200 | Train Loss 1.276752 | Val Loss 0.698160
# Epoch 300 | Train Loss 1.222282 | Val Loss 0.686762
# Epoch 400 | Train Loss 1.176737 | Val Loss 0.711988
# Epoch 500 | Train Loss 1.138561 | Val Loss 0.717870
# Epoch 600 | Train Loss 1.098097 | Val Loss 0.728585
# Epoch 700 | Train Loss 1.059640 | Val Loss 0.753831
# Early stopping at epoch 763
# Theta | train1 -> R² = 0.7088, MSE = 6.6605e-02
# X | train1 -> R² = -0.1231, MSE = 1.2074e-01
# Y | train1 -> R² = -0.7890, MSE = 1.4972e-01
# Theta | train2 -> R² = 0.2740, MSE = 1.6519e-01
# X | train2 -> R² = -0.1388, MSE = 9.5836e-02
# Y | train2 -> R² = -0.8349, MSE = 1.9703e-01
# Theta | test1 -> R² = 0.2875, MSE = 1.6400e-01
# X | test1 -> R² = -0.1160, MSE = 1.1655e-01
# Y | test1 -> R² = -1.2113, MSE = 1.8092e-01
# Theta | test2 -> R² = 0.5992, MSE = 9.4741e-02
# X | test2 -> R² = -0.0603, MSE = 8.7153e-02
# Y | test2 -> R² = -0.9992, MSE = 2.1163e-01
# Theta | test3 -> R² = -0.6395, MSE = 5.3965e-01
# X | test3 -> R² = 0.0268, MSE = 8.9294e-02
# Y | test3 -> R² = -1.7785, MSE = 2.1304e-01
# Theta | val -> R² = 0.1945, MSE = 2.6396e-01
# X | val -> R² = 0.0190, MSE = 9.3526e-02
# Y | val -> R² = -2.0462, MSE = 2.2643e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.555928 | Val Loss 0.794996
# Epoch 100 | Train Loss 1.322508 | Val Loss 0.711392
# Epoch 200 | Train Loss 1.292375 | Val Loss 0.701276
# Epoch 300 | Train Loss 1.220991 | Val Loss 0.683423
# Epoch 400 | Train Loss 1.168762 | Val Loss 0.701361
# Epoch 500 | Train Loss 1.129270 | Val Loss 0.710457
# Epoch 600 | Train Loss 1.092283 | Val Loss 0.747735
# Epoch 700 | Train Loss 1.054152 | Val Loss 0.819929
# Early stopping at epoch 770
# Theta | train1 -> R² = 0.7352, MSE = 6.0573e-02
# X | train1 -> R² = -0.1560, MSE = 1.2427e-01
# Y | train1 -> R² = -0.7991, MSE = 1.5057e-01
# Theta | train2 -> R² = 0.3872, MSE = 1.3943e-01
# X | train2 -> R² = -0.1028, MSE = 9.2810e-02
# Y | train2 -> R² = -0.7901, MSE = 1.9222e-01
# Theta | test1 -> R² = 0.5660, MSE = 9.9899e-02
# X | test1 -> R² = -0.0175, MSE = 1.0626e-01
# Y | test1 -> R² = -1.2840, MSE = 1.8686e-01
# Theta | test2 -> R² = 0.6280, MSE = 8.7925e-02
# X | test2 -> R² = -0.0167, MSE = 8.3564e-02
# Y | test2 -> R² = -1.0375, MSE = 2.1569e-01
# Theta | test3 -> R² = -3.0772, MSE = 1.3420e+00
# X | test3 -> R² = 0.0795, MSE = 8.4451e-02
# Y | test3 -> R² = -0.5991, MSE = 1.2261e-01
# Theta | val -> R² = -1.0943, MSE = 6.8632e-01
# X | val -> R² = 0.0462, MSE = 9.0933e-02
# Y | val -> R² = -0.8442, MSE = 1.3709e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.589809 | Val Loss 0.766178
# Epoch 100 | Train Loss 1.317290 | Val Loss 0.711424
# Epoch 200 | Train Loss 1.233994 | Val Loss 0.684594
# Epoch 300 | Train Loss 1.151978 | Val Loss 0.720293
# Epoch 400 | Train Loss 1.093549 | Val Loss 0.757628
# Epoch 500 | Train Loss 1.039506 | Val Loss 0.812344
# Epoch 600 | Train Loss 0.989472 | Val Loss 0.842788
# Early stopping at epoch 695
# Theta | train1 -> R² = 0.8517, MSE = 3.3914e-02
# X | train1 -> R² = -0.0849, MSE = 1.1663e-01
# Y | train1 -> R² = -0.8317, MSE = 1.5329e-01
# Theta | train2 -> R² = -0.1631, MSE = 2.6463e-01
# X | train2 -> R² = 0.0270, MSE = 8.1882e-02
# Y | train2 -> R² = -0.8106, MSE = 1.9442e-01
# Theta | test1 -> R² = 0.6938, MSE = 7.0485e-02
# X | test1 -> R² = 0.0652, MSE = 9.7624e-02
# Y | test1 -> R² = -1.3274, MSE = 1.9042e-01
# Theta | test2 -> R² = 0.2918, MSE = 1.6740e-01
# X | test2 -> R² = 0.0529, MSE = 7.7842e-02
# Y | test2 -> R² = -1.0986, MSE = 2.2216e-01
# Theta | test3 -> R² = -1.2898, MSE = 7.5369e-01
# X | test3 -> R² = 0.1657, MSE = 7.6550e-02
# Y | test3 -> R² = -1.0604, MSE = 1.5798e-01
# Theta | val -> R² = -0.3043, MSE = 4.2743e-01
# X | val -> R² = 0.1467, MSE = 8.1344e-02
# Y | val -> R² = -1.3771, MSE = 1.7670e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.609283 | Val Loss 0.771108
# Epoch 100 | Train Loss 1.318611 | Val Loss 0.710690
# Epoch 200 | Train Loss 1.242146 | Val Loss 0.687396
# Epoch 300 | Train Loss 1.163707 | Val Loss 0.728167
# Epoch 400 | Train Loss 1.108241 | Val Loss 0.748964
# Epoch 500 | Train Loss 1.051076 | Val Loss 0.767140
# Epoch 600 | Train Loss 0.998098 | Val Loss 0.817079
# Early stopping at epoch 688
# Theta | train1 -> R² = 0.8988, MSE = 2.3154e-02
# X | train1 -> R² = -0.1244, MSE = 1.2087e-01
# Y | train1 -> R² = -0.7696, MSE = 1.4810e-01
# Theta | train2 -> R² = -0.2090, MSE = 2.7507e-01
# X | train2 -> R² = -0.1061, MSE = 9.3085e-02
# Y | train2 -> R² = -0.8162, MSE = 1.9501e-01
# Theta | test1 -> R² = 0.8267, MSE = 3.9883e-02
# X | test1 -> R² = -0.0841, MSE = 1.1322e-01
# Y | test1 -> R² = -1.1845, MSE = 1.7872e-01
# Theta | test2 -> R² = 0.0605, MSE = 2.2207e-01
# X | test2 -> R² = -0.0213, MSE = 8.3941e-02
# Y | test2 -> R² = -1.0317, MSE = 2.1508e-01
# Theta | test3 -> R² = -0.1748, MSE = 3.8670e-01
# X | test3 -> R² = -0.1253, MSE = 1.0325e-01
# Y | test3 -> R² = -0.6088, MSE = 1.2336e-01
# Theta | val -> R² = 0.4244, MSE = 1.8864e-01
# X | val -> R² = -0.1316, MSE = 1.0788e-01
# Y | val -> R² = -0.9590, MSE = 1.4562e-01
# Figura salva em: ./results/model_128_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.670207 | Val Loss 0.805492
# Epoch 100 | Train Loss 1.318766 | Val Loss 0.710806
# Epoch 200 | Train Loss 1.243719 | Val Loss 0.686494
# Epoch 300 | Train Loss 1.174159 | Val Loss 0.712675
# Epoch 400 | Train Loss 1.122351 | Val Loss 0.733328
# Epoch 500 | Train Loss 1.064192 | Val Loss 0.784825
# Epoch 600 | Train Loss 1.011163 | Val Loss 0.850885
# Early stopping at epoch 692
# Theta | train1 -> R² = 0.8753, MSE = 2.8521e-02
# X | train1 -> R² = -0.1383, MSE = 1.2237e-01
# Y | train1 -> R² = -0.8108, MSE = 1.5155e-01
# Theta | train2 -> R² = 0.0083, MSE = 2.2563e-01
# X | train2 -> R² = -0.0840, MSE = 9.1221e-02
# Y | train2 -> R² = -0.8083, MSE = 1.9417e-01
# Theta | test1 -> R² = 0.8049, MSE = 4.4919e-02
# X | test1 -> R² = -0.0738, MSE = 1.1214e-01
# Y | test1 -> R² = -1.2376, MSE = 1.8307e-01
# Theta | test2 -> R² = 0.2816, MSE = 1.6982e-01
# X | test2 -> R² = -0.0143, MSE = 8.3370e-02
# Y | test2 -> R² = -1.0143, MSE = 2.1323e-01
# Theta | test3 -> R² = -2.1335, MSE = 1.0314e+00
# X | test3 -> R² = 0.0012, MSE = 9.1640e-02
# Y | test3 -> R² = -0.8282, MSE = 1.4017e-01
# Theta | val -> R² = -0.6516, MSE = 5.4122e-01
# X | val -> R² = 0.0068, MSE = 9.4688e-02
# Y | val -> R² = -1.2001, MSE = 1.6354e-01
# Figura salva em: ./results/model_128_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.568308 | Val Loss 0.778932
# Epoch 100 | Train Loss 1.318957 | Val Loss 0.709878
# Epoch 200 | Train Loss 1.242260 | Val Loss 0.685433
# Epoch 300 | Train Loss 1.161426 | Val Loss 0.731975
# Epoch 400 | Train Loss 1.103544 | Val Loss 0.767781
# Epoch 500 | Train Loss 1.051403 | Val Loss 0.812262
# Epoch 600 | Train Loss 1.005228 | Val Loss 0.839974
# Early stopping at epoch 683
# Theta | train1 -> R² = 0.9065, MSE = 2.1390e-02
# X | train1 -> R² = -0.1006, MSE = 1.1832e-01
# Y | train1 -> R² = -0.8210, MSE = 1.5240e-01
# Theta | train2 -> R² = -0.5642, MSE = 3.5589e-01
# X | train2 -> R² = -0.0800, MSE = 9.0888e-02
# Y | train2 -> R² = -0.7889, MSE = 1.9209e-01
# Theta | test1 -> R² = 0.8670, MSE = 3.0618e-02
# X | test1 -> R² = -0.0484, MSE = 1.0948e-01
# Y | test1 -> R² = -1.2761, MSE = 1.8622e-01
# Theta | test2 -> R² = -0.1833, MSE = 2.7970e-01
# X | test2 -> R² = -0.0082, MSE = 8.2866e-02
# Y | test2 -> R² = -1.1061, MSE = 2.2295e-01
# Theta | test3 -> R² = -0.4546, MSE = 4.7878e-01
# X | test3 -> R² = 0.0564, MSE = 8.6578e-02
# Y | test3 -> R² = -1.0650, MSE = 1.5833e-01
# Theta | val -> R² = 0.2059, MSE = 2.6024e-01
# X | val -> R² = 0.0452, MSE = 9.1027e-02
# Y | val -> R² = -1.3237, MSE = 1.7273e-01
# Figura salva em: ./results/model_128_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.592335 | Val Loss 0.768535
# Epoch 100 | Train Loss 1.316620 | Val Loss 0.709611
# Epoch 200 | Train Loss 1.234218 | Val Loss 0.680211
# Epoch 300 | Train Loss 1.149963 | Val Loss 0.716754
# Epoch 400 | Train Loss 1.089045 | Val Loss 0.736940
# Epoch 500 | Train Loss 1.033518 | Val Loss 0.772576
# Epoch 600 | Train Loss 0.983704 | Val Loss 0.794451
# Early stopping at epoch 683
# Theta | train1 -> R² = 0.3630, MSE = 1.4571e-01
# X | train1 -> R² = -0.1201, MSE = 1.2042e-01
# Y | train1 -> R² = -0.7581, MSE = 1.4713e-01
# Theta | train2 -> R² = 0.6111, MSE = 8.8485e-02
# X | train2 -> R² = -0.1141, MSE = 9.3761e-02
# Y | train2 -> R² = -0.7836, MSE = 1.9151e-01
# Theta | test1 -> R² = 0.2031, MSE = 1.8344e-01
# X | test1 -> R² = -0.0160, MSE = 1.0611e-01
# Y | test1 -> R² = -1.2979, MSE = 1.8801e-01
# Theta | test2 -> R² = 0.7257, MSE = 6.4842e-02
# X | test2 -> R² = -0.0422, MSE = 8.5667e-02
# Y | test2 -> R² = -1.1654, MSE = 2.2923e-01
# Theta | test3 -> R² = -3.0468, MSE = 1.3320e+00
# X | test3 -> R² = 0.0443, MSE = 8.7687e-02
# Y | test3 -> R² = -0.7673, MSE = 1.3550e-01
# Theta | val -> R² = -1.2786, MSE = 7.4669e-01
# X | val -> R² = 0.0457, MSE = 9.0978e-02
# Y | val -> R² = -1.1286, MSE = 1.5823e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.687548 | Val Loss 0.816678
# Epoch 100 | Train Loss 1.320737 | Val Loss 0.710695
# Epoch 200 | Train Loss 1.261290 | Val Loss 0.694939
# Epoch 300 | Train Loss 1.195129 | Val Loss 0.719386
# Epoch 400 | Train Loss 1.138069 | Val Loss 0.774470
# Epoch 500 | Train Loss 1.088016 | Val Loss 0.852609
# Epoch 600 | Train Loss 1.031277 | Val Loss 0.963831
# Epoch 700 | Train Loss 0.980156 | Val Loss 1.070883
# Early stopping at epoch 705
# Theta | train1 -> R² = 0.8129, MSE = 4.2792e-02
# X | train1 -> R² = -0.1204, MSE = 1.2045e-01
# Y | train1 -> R² = -0.7465, MSE = 1.4616e-01
# Theta | train2 -> R² = 0.0419, MSE = 2.1800e-01
# X | train2 -> R² = -0.0970, MSE = 9.2322e-02
# Y | train2 -> R² = -0.8732, MSE = 2.0114e-01
# Theta | test1 -> R² = 0.6592, MSE = 7.8444e-02
# X | test1 -> R² = -0.0429, MSE = 1.0892e-01
# Y | test1 -> R² = -1.1816, MSE = 1.7849e-01
# Theta | test2 -> R² = 0.3127, MSE = 1.6245e-01
# X | test2 -> R² = -0.0184, MSE = 8.3709e-02
# Y | test2 -> R² = -1.0698, MSE = 2.1911e-01
# Theta | test3 -> R² = -0.7772, MSE = 5.8498e-01
# X | test3 -> R² = -0.0376, MSE = 9.5198e-02
# Y | test3 -> R² = -0.5924, MSE = 1.2210e-01
# Theta | val -> R² = -0.0932, MSE = 3.5826e-01
# X | val -> R² = -0.0271, MSE = 9.7921e-02
# Y | val -> R² = -0.9054, MSE = 1.4164e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.593266 | Val Loss 0.775903
# Epoch 100 | Train Loss 1.319094 | Val Loss 0.711149
# Epoch 200 | Train Loss 1.240819 | Val Loss 0.686020
# Epoch 300 | Train Loss 1.165298 | Val Loss 0.729266
# Epoch 400 | Train Loss 1.105865 | Val Loss 0.755518
# Epoch 500 | Train Loss 1.048277 | Val Loss 0.795817
# Epoch 600 | Train Loss 0.997647 | Val Loss 0.838183
# Early stopping at epoch 687
# Theta | train1 -> R² = 0.5024, MSE = 1.1382e-01
# X | train1 -> R² = -0.1230, MSE = 1.2073e-01
# Y | train1 -> R² = -0.7995, MSE = 1.5060e-01
# Theta | train2 -> R² = 0.5714, MSE = 9.7508e-02
# X | train2 -> R² = -0.1009, MSE = 9.2645e-02
# Y | train2 -> R² = -0.7743, MSE = 1.9052e-01
# Theta | test1 -> R² = 0.0830, MSE = 2.1109e-01
# X | test1 -> R² = -0.0034, MSE = 1.0478e-01
# Y | test1 -> R² = -1.3507, MSE = 1.9233e-01
# Theta | test2 -> R² = 0.7020, MSE = 7.0447e-02
# X | test2 -> R² = -0.0156, MSE = 8.3473e-02
# Y | test2 -> R² = -1.0692, MSE = 2.1904e-01
# Theta | test3 -> R² = -4.4782, MSE = 1.8032e+00
# X | test3 -> R² = 0.0583, MSE = 8.6399e-02
# Y | test3 -> R² = -0.9029, MSE = 1.4591e-01
# Theta | val -> R² = -2.1836, MSE = 1.0433e+00
# X | val -> R² = 0.0466, MSE = 9.0889e-02
# Y | val -> R² = -1.2064, MSE = 1.6401e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.583250 | Val Loss 0.809139
# Epoch 100 | Train Loss 1.316238 | Val Loss 0.709791
# Epoch 200 | Train Loss 1.223169 | Val Loss 0.683285
# Epoch 300 | Train Loss 1.146230 | Val Loss 0.723353
# Epoch 400 | Train Loss 1.092507 | Val Loss 0.743672
# Epoch 500 | Train Loss 1.034846 | Val Loss 0.794039
# Epoch 600 | Train Loss 0.982864 | Val Loss 0.857259
# Early stopping at epoch 663
# Theta | train1 -> R² = 0.8039, MSE = 4.4864e-02
# X | train1 -> R² = -0.0995, MSE = 1.1821e-01
# Y | train1 -> R² = -0.7423, MSE = 1.4581e-01
# Theta | train2 -> R² = -0.5789, MSE = 3.5925e-01
# X | train2 -> R² = -0.0867, MSE = 9.1453e-02
# Y | train2 -> R² = -0.8108, MSE = 1.9444e-01
# Theta | test1 -> R² = 0.8859, MSE = 2.6275e-02
# X | test1 -> R² = -0.0502, MSE = 1.0968e-01
# Y | test1 -> R² = -1.3259, MSE = 1.9029e-01
# Theta | test2 -> R² = -0.2460, MSE = 2.9452e-01
# X | test2 -> R² = -0.0094, MSE = 8.2964e-02
# Y | test2 -> R² = -1.1301, MSE = 2.2549e-01
# Theta | test3 -> R² = -0.4122, MSE = 4.6483e-01
# X | test3 -> R² = 0.0497, MSE = 8.7193e-02
# Y | test3 -> R² = -0.5641, MSE = 1.1993e-01
# Theta | val -> R² = 0.2969, MSE = 2.3039e-01
# X | val -> R² = 0.0214, MSE = 9.3290e-02
# Y | val -> R² = -0.9106, MSE = 1.4202e-01
# Figura salva em: ./results/model_128_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.560444 | Val Loss 0.770472
# Epoch 100 | Train Loss 1.318805 | Val Loss 0.709558
# Epoch 200 | Train Loss 1.244575 | Val Loss 0.681196
# Epoch 300 | Train Loss 1.166456 | Val Loss 0.725508
# Epoch 400 | Train Loss 1.109347 | Val Loss 0.778252
# Epoch 500 | Train Loss 1.049239 | Val Loss 0.819306
# Epoch 600 | Train Loss 0.997773 | Val Loss 0.860382
# Early stopping at epoch 693
# Theta | train1 -> R² = 0.8002, MSE = 4.5707e-02
# X | train1 -> R² = -0.1195, MSE = 1.2035e-01
# Y | train1 -> R² = -0.7653, MSE = 1.4774e-01
# Theta | train2 -> R² = 0.2479, MSE = 1.7111e-01
# X | train2 -> R² = -0.1219, MSE = 9.4410e-02
# Y | train2 -> R² = -0.8426, MSE = 1.9785e-01
# Theta | test1 -> R² = 0.6843, MSE = 7.2678e-02
# X | test1 -> R² = -0.0132, MSE = 1.0581e-01
# Y | test1 -> R² = -1.1881, MSE = 1.7902e-01
# Theta | test2 -> R² = 0.4304, MSE = 1.3464e-01
# X | test2 -> R² = -0.0454, MSE = 8.5926e-02
# Y | test2 -> R² = -1.0633, MSE = 2.1842e-01
# Theta | test3 -> R² = -1.0196, MSE = 6.6475e-01
# X | test3 -> R² = -0.1679, MSE = 1.0715e-01
# Y | test3 -> R² = -0.8305, MSE = 1.4035e-01
# Theta | val -> R² = -0.1532, MSE = 3.7790e-01
# X | val -> R² = -0.0774, MSE = 1.0272e-01
# Y | val -> R² = -1.1554, MSE = 1.6022e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.595801 | Val Loss 0.780444
# Epoch 100 | Train Loss 1.316399 | Val Loss 0.709432
# Epoch 200 | Train Loss 1.232005 | Val Loss 0.690998
# Epoch 300 | Train Loss 1.148553 | Val Loss 0.735034
# Epoch 400 | Train Loss 1.086920 | Val Loss 0.756454
# Epoch 500 | Train Loss 1.029788 | Val Loss 0.808250
# Epoch 600 | Train Loss 0.979671 | Val Loss 0.886611
# Early stopping at epoch 673
# Theta | train1 -> R² = 0.6316, MSE = 8.4270e-02
# X | train1 -> R² = -0.1322, MSE = 1.2172e-01
# Y | train1 -> R² = -0.7984, MSE = 1.5051e-01
# Theta | train2 -> R² = 0.5868, MSE = 9.4004e-02
# X | train2 -> R² = -0.0746, MSE = 9.0435e-02
# Y | train2 -> R² = -0.8011, MSE = 1.9339e-01
# Theta | test1 -> R² = 0.4068, MSE = 1.3655e-01
# X | test1 -> R² = -0.0474, MSE = 1.0938e-01
# Y | test1 -> R² = -1.2836, MSE = 1.8684e-01
# Theta | test2 -> R² = 0.6743, MSE = 7.6982e-02
# X | test2 -> R² = -0.0170, MSE = 8.3594e-02
# Y | test2 -> R² = -1.0020, MSE = 2.1193e-01
# Theta | test3 -> R² = -3.1258, MSE = 1.3580e+00
# X | test3 -> R² = 0.0748, MSE = 8.4886e-02
# Y | test3 -> R² = -1.4263, MSE = 1.8604e-01
# Theta | val -> R² = -1.3803, MSE = 7.8002e-01
# X | val -> R² = 0.0664, MSE = 8.9001e-02
# Y | val -> R² = -1.7300, MSE = 2.0293e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.558622 | Val Loss 0.745108
# Epoch 100 | Train Loss 1.295836 | Val Loss 0.697170
# Epoch 200 | Train Loss 1.186805 | Val Loss 0.689058
# Epoch 300 | Train Loss 1.109542 | Val Loss 0.727352
# Epoch 400 | Train Loss 1.043230 | Val Loss 0.735893
# Epoch 500 | Train Loss 0.975357 | Val Loss 0.783642
# Epoch 600 | Train Loss 0.927667 | Val Loss 0.847529
# Early stopping at epoch 655
# Theta | train1 -> R² = 0.8573, MSE = 3.2636e-02
# X | train1 -> R² = -0.0414, MSE = 1.1195e-01
# Y | train1 -> R² = -0.8299, MSE = 1.5314e-01
# Theta | train2 -> R² = 0.1546, MSE = 1.9236e-01
# X | train2 -> R² = 0.0168, MSE = 8.2741e-02
# Y | train2 -> R² = -1.0766, MSE = 2.2298e-01
# Theta | test1 -> R² = 0.8177, MSE = 4.1963e-02
# X | test1 -> R² = 0.0748, MSE = 9.6624e-02
# Y | test1 -> R² = -1.5460, MSE = 2.0830e-01
# Theta | test2 -> R² = 0.2905, MSE = 1.6771e-01
# X | test2 -> R² = 0.0154, MSE = 8.0925e-02
# Y | test2 -> R² = -1.4619, MSE = 2.6062e-01
# Theta | test3 -> R² = -1.3749, MSE = 7.8172e-01
# X | test3 -> R² = 0.0797, MSE = 8.4434e-02
# Y | test3 -> R² = -1.3012, MSE = 1.7644e-01
# Theta | val -> R² = -0.2609, MSE = 4.1318e-01
# X | val -> R² = 0.0721, MSE = 8.8461e-02
# Y | val -> R² = -1.5532, MSE = 1.8979e-01
# Figura salva em: ./results/model_264_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.613648 | Val Loss 0.765374
# Epoch 100 | Train Loss 1.304938 | Val Loss 0.702092
# Epoch 200 | Train Loss 1.188829 | Val Loss 0.699662
# Epoch 300 | Train Loss 1.103289 | Val Loss 0.744875
# Epoch 400 | Train Loss 1.034162 | Val Loss 0.752040
# Epoch 500 | Train Loss 0.969640 | Val Loss 0.779533
# Epoch 600 | Train Loss 0.920566 | Val Loss 0.818181
# Early stopping at epoch 652
# Theta | train1 -> R² = 0.8769, MSE = 2.8161e-02
# X | train1 -> R² = 0.1029, MSE = 9.6447e-02
# Y | train1 -> R² = -0.9094, MSE = 1.5980e-01
# Theta | train2 -> R² = 0.0799, MSE = 2.0934e-01
# X | train2 -> R² = 0.0838, MSE = 7.7102e-02
# Y | train2 -> R² = -0.8783, MSE = 2.0168e-01
# Theta | test1 -> R² = 0.8691, MSE = 3.0124e-02
# X | test1 -> R² = 0.1795, MSE = 8.5689e-02
# Y | test1 -> R² = -1.5034, MSE = 2.0482e-01
# Theta | test2 -> R² = 0.3014, MSE = 1.6512e-01
# X | test2 -> R² = 0.0522, MSE = 7.7901e-02
# Y | test2 -> R² = -1.2438, MSE = 2.3753e-01
# Theta | test3 -> R² = -0.1362, MSE = 3.7399e-01
# X | test3 -> R² = 0.2640, MSE = 6.7529e-02
# Y | test3 -> R² = -1.6223, MSE = 2.0106e-01
# Theta | val -> R² = 0.4932, MSE = 1.6607e-01
# X | val -> R² = 0.2509, MSE = 7.1415e-02
# Y | val -> R² = -1.9641, MSE = 2.2034e-01
# Figura salva em: ./results/model_264_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.554578 | Val Loss 0.767147
# Epoch 100 | Train Loss 1.304286 | Val Loss 0.704450
# Epoch 200 | Train Loss 1.194102 | Val Loss 0.701254
# Epoch 300 | Train Loss 1.109889 | Val Loss 0.757093
# Epoch 400 | Train Loss 1.039696 | Val Loss 0.793795
# Epoch 500 | Train Loss 0.980515 | Val Loss 0.856546
# Epoch 600 | Train Loss 0.925018 | Val Loss 0.879546
# Early stopping at epoch 654
# Theta | train1 -> R² = -0.1406, MSE = 2.6090e-01
# X | train1 -> R² = -0.0928, MSE = 1.1748e-01
# Y | train1 -> R² = -0.9856, MSE = 1.6617e-01
# Theta | train2 -> R² = 0.7124, MSE = 6.5448e-02
# X | train2 -> R² = -0.0189, MSE = 8.5744e-02
# Y | train2 -> R² = -1.1648, MSE = 2.3244e-01
# Theta | test1 -> R² = -0.5498, MSE = 3.5676e-01
# X | test1 -> R² = 0.0152, MSE = 1.0284e-01
# Y | test1 -> R² = -1.6872, MSE = 2.1985e-01
# Theta | test2 -> R² = 0.6336, MSE = 8.6598e-02
# X | test2 -> R² = -0.0063, MSE = 8.2715e-02
# Y | test2 -> R² = -1.5280, MSE = 2.6762e-01
# Theta | test3 -> R² = -4.6476, MSE = 1.8590e+00
# X | test3 -> R² = 0.0351, MSE = 8.8531e-02
# Y | test3 -> R² = -1.9001, MSE = 2.2236e-01
# Theta | val -> R² = -2.1830, MSE = 1.0431e+00
# X | val -> R² = -0.0077, MSE = 9.6072e-02
# Y | val -> R² = -2.2713, MSE = 2.4317e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.606239 | Val Loss 0.744423
# Epoch 100 | Train Loss 1.311724 | Val Loss 0.708467
# Epoch 200 | Train Loss 1.215589 | Val Loss 0.681214
# Epoch 300 | Train Loss 1.127940 | Val Loss 0.732255
# Epoch 400 | Train Loss 1.064091 | Val Loss 0.769024
# Epoch 500 | Train Loss 1.006127 | Val Loss 0.824050
# Epoch 600 | Train Loss 0.943613 | Val Loss 0.872475
# Early stopping at epoch 684
# Theta | train1 -> R² = 0.8573, MSE = 3.2649e-02
# X | train1 -> R² = -0.1820, MSE = 1.2707e-01
# Y | train1 -> R² = -0.5555, MSE = 1.3017e-01
# Theta | train2 -> R² = -0.3815, MSE = 3.1433e-01
# X | train2 -> R² = -0.0857, MSE = 9.1365e-02
# Y | train2 -> R² = -0.7360, MSE = 1.8640e-01
# Theta | test1 -> R² = 0.8836, MSE = 2.6801e-02
# X | test1 -> R² = -0.0607, MSE = 1.1077e-01
# Y | test1 -> R² = -1.0762, MSE = 1.6986e-01
# Theta | test2 -> R² = -0.4062, MSE = 3.3240e-01
# X | test2 -> R² = -0.0387, MSE = 8.5375e-02
# Y | test2 -> R² = -1.0332, MSE = 2.1523e-01
# Theta | test3 -> R² = 0.2254, MSE = 2.5496e-01
# X | test3 -> R² = 0.0459, MSE = 8.7539e-02
# Y | test3 -> R² = -0.6547, MSE = 1.2687e-01
# Theta | val -> R² = 0.6088, MSE = 1.2819e-01
# X | val -> R² = 0.0243, MSE = 9.3021e-02
# Y | val -> R² = -1.0074, MSE = 1.4922e-01
# Figura salva em: ./results/model_264_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.617893 | Val Loss 0.746694
# Epoch 100 | Train Loss 1.305061 | Val Loss 0.703101
# Epoch 200 | Train Loss 1.196249 | Val Loss 0.687971
# Epoch 300 | Train Loss 1.120795 | Val Loss 0.734705
# Epoch 400 | Train Loss 1.056201 | Val Loss 0.739826
# Epoch 500 | Train Loss 0.996699 | Val Loss 0.784602
# Epoch 600 | Train Loss 0.947203 | Val Loss 0.818155
# Early stopping at epoch 638
# Theta | train1 -> R² = 0.6921, MSE = 7.0439e-02
# X | train1 -> R² = -0.1116, MSE = 1.1950e-01
# Y | train1 -> R² = -0.6732, MSE = 1.4003e-01
# Theta | train2 -> R² = -0.9837, MSE = 4.5135e-01
# X | train2 -> R² = -0.0767, MSE = 9.0612e-02
# Y | train2 -> R² = -0.7381, MSE = 1.8663e-01
# Theta | test1 -> R² = 0.8154, MSE = 4.2486e-02
# X | test1 -> R² = -0.0606, MSE = 1.1076e-01
# Y | test1 -> R² = -1.3374, MSE = 1.9123e-01
# Theta | test2 -> R² = -0.6387, MSE = 3.8734e-01
# X | test2 -> R² = -0.0185, MSE = 8.3712e-02
# Y | test2 -> R² = -1.0880, MSE = 2.2104e-01
# Theta | test3 -> R² = 0.3595, MSE = 2.1084e-01
# X | test3 -> R² = 0.0097, MSE = 9.0862e-02
# Y | test3 -> R² = -0.8263, MSE = 1.4003e-01
# Theta | val -> R² = 0.6627, MSE = 1.1053e-01
# X | val -> R² = -0.0099, MSE = 9.6276e-02
# Y | val -> R² = -1.1435, MSE = 1.5933e-01
# Figura salva em: ./results/model_264_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.767506 | Val Loss 0.739551
# Epoch 100 | Train Loss 1.313599 | Val Loss 0.707567
# Epoch 200 | Train Loss 1.218463 | Val Loss 0.680380
# Epoch 300 | Train Loss 1.137296 | Val Loss 0.740489
# Epoch 400 | Train Loss 1.074116 | Val Loss 0.774054
# Epoch 500 | Train Loss 1.010098 | Val Loss 0.802448
# Epoch 600 | Train Loss 0.962177 | Val Loss 0.840165
# Epoch 700 | Train Loss 0.909749 | Val Loss 0.907763
# Early stopping at epoch 714
# Theta | train1 -> R² = 0.3517, MSE = 1.4830e-01
# X | train1 -> R² = 0.4680, MSE = 5.7195e-02
# Y | train1 -> R² = -0.6915, MSE = 1.4156e-01
# Theta | train2 -> R² = 0.5987, MSE = 9.1302e-02
# X | train2 -> R² = 0.0797, MSE = 7.7446e-02
# Y | train2 -> R² = -0.9216, MSE = 2.0633e-01
# Theta | test1 -> R² = 0.0450, MSE = 2.1983e-01
# X | test1 -> R² = 0.4370, MSE = 5.8796e-02
# Y | test1 -> R² = -1.2670, MSE = 1.8548e-01
# Theta | test2 -> R² = 0.6578, MSE = 8.0889e-02
# X | test2 -> R² = -0.2590, MSE = 1.0348e-01
# Y | test2 -> R² = -1.2522, MSE = 2.3842e-01
# Theta | test3 -> R² = -5.1940, MSE = 2.0388e+00
# X | test3 -> R² = -0.0644, MSE = 9.7655e-02
# Y | test3 -> R² = -1.8430, MSE = 2.1799e-01
# Theta | val -> R² = -3.1194, MSE = 1.3499e+00
# X | val -> R² = -0.0367, MSE = 9.8834e-02
# Y | val -> R² = -2.1194, MSE = 2.3187e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.588757 | Val Loss 0.756881
# Epoch 100 | Train Loss 1.300556 | Val Loss 0.699203
# Epoch 200 | Train Loss 1.194559 | Val Loss 0.700433
# Epoch 300 | Train Loss 1.111006 | Val Loss 0.750162
# Epoch 400 | Train Loss 1.059866 | Val Loss 0.778269
# Epoch 500 | Train Loss 0.992622 | Val Loss 0.763300
# Epoch 600 | Train Loss 0.929721 | Val Loss 0.822114
# Early stopping at epoch 657
# Theta | train1 -> R² = 0.3376, MSE = 1.5152e-01
# X | train1 -> R² = -0.1109, MSE = 1.1943e-01
# Y | train1 -> R² = -0.7365, MSE = 1.4533e-01
# Theta | train2 -> R² = 0.6257, MSE = 8.5154e-02
# X | train2 -> R² = 0.0087, MSE = 8.3421e-02
# Y | train2 -> R² = -0.8340, MSE = 1.9693e-01
# Theta | test1 -> R² = 0.1189, MSE = 2.0282e-01
# X | test1 -> R² = -0.0245, MSE = 1.0699e-01
# Y | test1 -> R² = -1.2436, MSE = 1.8356e-01
# Theta | test2 -> R² = 0.7628, MSE = 5.6075e-02
# X | test2 -> R² = -0.0021, MSE = 8.2364e-02
# Y | test2 -> R² = -1.0636, MSE = 2.1845e-01
# Theta | test3 -> R² = -3.1506, MSE = 1.3662e+00
# X | test3 -> R² = 0.0664, MSE = 8.5661e-02
# Y | test3 -> R² = -0.9620, MSE = 1.5044e-01
# Theta | val -> R² = -1.1978, MSE = 7.2021e-01
# X | val -> R² = 0.0621, MSE = 8.9410e-02
# Y | val -> R² = -1.2729, MSE = 1.6895e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.644464 | Val Loss 0.773712
# Epoch 100 | Train Loss 1.305981 | Val Loss 0.702023
# Epoch 200 | Train Loss 1.203646 | Val Loss 0.681758
# Epoch 300 | Train Loss 1.123193 | Val Loss 0.746173
# Epoch 400 | Train Loss 1.046913 | Val Loss 0.741741
# Epoch 500 | Train Loss 0.982608 | Val Loss 0.785510
# Epoch 600 | Train Loss 0.928054 | Val Loss 0.838145
# Early stopping at epoch 669
# Theta | train1 -> R² = -0.2558, MSE = 2.8725e-01
# X | train1 -> R² = -0.0671, MSE = 1.1472e-01
# Y | train1 -> R² = -0.6043, MSE = 1.3426e-01
# Theta | train2 -> R² = 0.7581, MSE = 5.5047e-02
# X | train2 -> R² = -0.0573, MSE = 8.8975e-02
# Y | train2 -> R² = -0.7963, MSE = 1.9288e-01
# Theta | test1 -> R² = -0.3513, MSE = 3.1106e-01
# X | test1 -> R² = 0.0424, MSE = 1.0001e-01
# Y | test1 -> R² = -1.1271, MSE = 1.7403e-01
# Theta | test2 -> R² = 0.7424, MSE = 6.0885e-02
# X | test2 -> R² = -0.0365, MSE = 8.5195e-02
# Y | test2 -> R² = -1.0978, MSE = 2.2208e-01
# Theta | test3 -> R² = -4.6543, MSE = 1.8611e+00
# X | test3 -> R² = 0.2415, MSE = 6.9593e-02
# Y | test3 -> R² = -0.9060, MSE = 1.4614e-01
# Theta | val -> R² = -2.5243, MSE = 1.1549e+00
# X | val -> R² = 0.2351, MSE = 7.2918e-02
# Y | val -> R² = -1.2268, MSE = 1.6552e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.639456 | Val Loss 0.776808
# Epoch 100 | Train Loss 1.308717 | Val Loss 0.703858
# Epoch 200 | Train Loss 1.199048 | Val Loss 0.684334
# Epoch 300 | Train Loss 1.107452 | Val Loss 0.719886
# Epoch 400 | Train Loss 1.034763 | Val Loss 0.738591
# Epoch 500 | Train Loss 0.968831 | Val Loss 0.768479
# Epoch 600 | Train Loss 0.913118 | Val Loss 0.827893
# Early stopping at epoch 648
# Theta | train1 -> R² = 0.3316, MSE = 1.5288e-01
# X | train1 -> R² = -0.0668, MSE = 1.1469e-01
# Y | train1 -> R² = -0.9174, MSE = 1.6046e-01
# Theta | train2 -> R² = 0.6159, MSE = 8.7399e-02
# X | train2 -> R² = -0.0941, MSE = 9.2078e-02
# Y | train2 -> R² = -0.9214, MSE = 2.0631e-01
# Theta | test1 -> R² = -0.0528, MSE = 2.4234e-01
# X | test1 -> R² = -0.0395, MSE = 1.0855e-01
# Y | test1 -> R² = -1.5284, MSE = 2.0686e-01
# Theta | test2 -> R² = 0.6277, MSE = 8.8004e-02
# X | test2 -> R² = -0.0375, MSE = 8.5274e-02
# Y | test2 -> R² = -1.2818, MSE = 2.4155e-01
# Theta | test3 -> R² = -4.5271, MSE = 1.8193e+00
# X | test3 -> R² = 0.0668, MSE = 8.5619e-02
# Y | test3 -> R² = -0.9868, MSE = 1.5234e-01
# Theta | val -> R² = -2.2709, MSE = 1.0719e+00
# X | val -> R² = 0.0619, MSE = 8.9431e-02
# Y | val -> R² = -1.3098, MSE = 1.7169e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.653280 | Val Loss 0.748866
# Epoch 100 | Train Loss 1.315387 | Val Loss 0.708899
# Epoch 200 | Train Loss 1.218851 | Val Loss 0.681377
# Epoch 300 | Train Loss 1.130255 | Val Loss 0.728931
# Epoch 400 | Train Loss 1.062638 | Val Loss 0.745391
# Epoch 500 | Train Loss 0.998083 | Val Loss 0.757667
# Epoch 600 | Train Loss 0.943385 | Val Loss 0.777821
# Early stopping at epoch 667
# Theta | train1 -> R² = 0.6744, MSE = 7.4475e-02
# X | train1 -> R² = 0.0066, MSE = 1.0679e-01
# Y | train1 -> R² = -0.9024, MSE = 1.5921e-01
# Theta | train2 -> R² = -1.0395, MSE = 4.6404e-01
# X | train2 -> R² = 0.0042, MSE = 8.3800e-02
# Y | train2 -> R² = -0.8028, MSE = 1.9358e-01
# Theta | test1 -> R² = 0.7922, MSE = 4.7845e-02
# X | test1 -> R² = 0.1107, MSE = 9.2868e-02
# Y | test1 -> R² = -1.4754, MSE = 2.0253e-01
# Theta | test2 -> R² = -0.6912, MSE = 3.9976e-01
# X | test2 -> R² = 0.0042, MSE = 8.1845e-02
# Y | test2 -> R² = -1.1588, MSE = 2.2853e-01
# Theta | test3 -> R² = 0.3164, MSE = 2.2501e-01
# X | test3 -> R² = 0.1206, MSE = 8.0683e-02
# Y | test3 -> R² = -1.5860, MSE = 1.9828e-01
# Theta | val -> R² = 0.6617, MSE = 1.1086e-01
# X | val -> R² = 0.1205, MSE = 8.3850e-02
# Y | val -> R² = -1.8995, MSE = 2.1553e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570372 | Val Loss 0.803432
# Epoch 100 | Train Loss 1.456529 | Val Loss 0.770576
# Epoch 200 | Train Loss 1.415741 | Val Loss 0.753152
# Epoch 300 | Train Loss 1.323014 | Val Loss 0.726639
# Epoch 400 | Train Loss 1.315487 | Val Loss 0.728597
# Epoch 500 | Train Loss 1.308953 | Val Loss 0.734681
# Epoch 600 | Train Loss 1.299316 | Val Loss 0.745589
# Epoch 700 | Train Loss 1.285511 | Val Loss 0.766759
# Early stopping at epoch 731
# Theta | train1 -> R² = 0.6610, MSE = 7.7544e-02
# X | train1 -> R² = -0.3423, MSE = 1.4430e-01
# Y | train1 -> R² = -1.4626, MSE = 2.0609e-01
# Theta | train2 -> R² = -0.3695, MSE = 3.1159e-01
# X | train2 -> R² = -0.3463, MSE = 1.1329e-01
# Y | train2 -> R² = -1.6695, MSE = 2.8664e-01
# Theta | test1 -> R² = 0.7040, MSE = 6.8144e-02
# X | test1 -> R² = -0.4424, MSE = 1.5063e-01
# Y | test1 -> R² = -1.7372, MSE = 2.2395e-01
# Theta | test2 -> R² = -0.3052, MSE = 3.0853e-01
# X | test2 -> R² = -0.2892, MSE = 1.0596e-01
# Y | test2 -> R² = -1.5311, MSE = 2.6794e-01
# Theta | test3 -> R² = 0.7535, MSE = 8.1124e-02
# X | test3 -> R² = -0.8662, MSE = 1.7122e-01
# Y | test3 -> R² = -4.2342, MSE = 4.0133e-01
# Theta | val -> R² = 0.7208, MSE = 9.1485e-02
# X | val -> R² = -0.9036, MSE = 1.8148e-01
# Y | val -> R² = -3.8705, MSE = 3.6204e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572694 | Val Loss 0.808284
# Epoch 100 | Train Loss 1.439354 | Val Loss 0.756836
# Epoch 200 | Train Loss 1.332694 | Val Loss 0.724520
# Epoch 300 | Train Loss 1.323985 | Val Loss 0.729523
# Epoch 400 | Train Loss 1.315169 | Val Loss 0.729591
# Epoch 500 | Train Loss 1.304882 | Val Loss 0.727775
# Epoch 600 | Train Loss 1.294601 | Val Loss 0.724299
# Epoch 700 | Train Loss 1.284841 | Val Loss 0.717649
# Epoch 800 | Train Loss 1.277277 | Val Loss 0.711406
# Epoch 900 | Train Loss 1.270148 | Val Loss 0.707225
# Epoch 1000 | Train Loss 1.262311 | Val Loss 0.700605
# Epoch 1100 | Train Loss 1.253652 | Val Loss 0.698271
# Epoch 1200 | Train Loss 1.243997 | Val Loss 0.709979
# Epoch 1300 | Train Loss 1.236227 | Val Loss 0.723686
# Epoch 1400 | Train Loss 1.231055 | Val Loss 0.728442
# Epoch 1500 | Train Loss 1.227513 | Val Loss 0.732210
# Early stopping at epoch 1543
# Theta | train1 -> R² = 0.6811, MSE = 7.2949e-02
# X | train1 -> R² = -0.1152, MSE = 1.1989e-01
# Y | train1 -> R² = -0.9009, MSE = 1.5908e-01
# Theta | train2 -> R² = 0.4105, MSE = 1.3414e-01
# X | train2 -> R² = -0.2871, MSE = 1.0831e-01
# Y | train2 -> R² = -0.8144, MSE = 1.9483e-01
# Theta | test1 -> R² = 0.6900, MSE = 7.1347e-02
# X | test1 -> R² = -0.0367, MSE = 1.0826e-01
# Y | test1 -> R² = -1.2935, MSE = 1.8764e-01
# Theta | test2 -> R² = 0.4675, MSE = 1.2587e-01
# X | test2 -> R² = -0.1883, MSE = 9.7668e-02
# Y | test2 -> R² = -0.8664, MSE = 1.9758e-01
# Theta | test3 -> R² = -1.1925, MSE = 7.2167e-01
# X | test3 -> R² = -0.5963, MSE = 1.4646e-01
# Y | test3 -> R² = -3.1902, MSE = 3.2128e-01
# Theta | val -> R² = -0.4890, MSE = 4.8795e-01
# X | val -> R² = -0.4278, MSE = 1.3612e-01
# Y | val -> R² = -3.4707, MSE = 3.3232e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570778 | Val Loss 0.804069
# Epoch 100 | Train Loss 1.435166 | Val Loss 0.763012
# Epoch 200 | Train Loss 1.334793 | Val Loss 0.734635
# Epoch 300 | Train Loss 1.322197 | Val Loss 0.747690
# Epoch 400 | Train Loss 1.311581 | Val Loss 0.758524
# Epoch 500 | Train Loss 1.299403 | Val Loss 0.776012
# Epoch 600 | Train Loss 1.287083 | Val Loss 0.800927
# Early stopping at epoch 654
# Theta | train1 -> R² = 0.5473, MSE = 1.0355e-01
# X | train1 -> R² = -0.4945, MSE = 1.6066e-01
# Y | train1 -> R² = -1.1975, MSE = 1.8391e-01
# Theta | train2 -> R² = -0.2104, MSE = 2.7540e-01
# X | train2 -> R² = -0.4202, MSE = 1.1952e-01
# Y | train2 -> R² = -1.3040, MSE = 2.4740e-01
# Theta | test1 -> R² = 0.6642, MSE = 7.7307e-02
# X | test1 -> R² = -0.6749, MSE = 1.7492e-01
# Y | test1 -> R² = -1.5922, MSE = 2.1208e-01
# Theta | test2 -> R² = -0.2659, MSE = 2.9922e-01
# X | test2 -> R² = -0.3680, MSE = 1.1244e-01
# Y | test2 -> R² = -1.2314, MSE = 2.3622e-01
# Theta | test3 -> R² = -1.4269, MSE = 7.9884e-01
# X | test3 -> R² = -0.7145, MSE = 1.5730e-01
# Y | test3 -> R² = -1.8667, MSE = 2.1980e-01
# Theta | val -> R² = -0.4209, MSE = 4.6564e-01
# X | val -> R² = -0.7832, MSE = 1.7000e-01
# Y | val -> R² = -1.9394, MSE = 2.1849e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.569312 | Val Loss 0.803142
# Epoch 100 | Train Loss 1.417945 | Val Loss 0.749336
# Epoch 200 | Train Loss 1.329020 | Val Loss 0.724612
# Epoch 300 | Train Loss 1.323003 | Val Loss 0.729113
# Epoch 400 | Train Loss 1.316397 | Val Loss 0.735522
# Epoch 500 | Train Loss 1.306694 | Val Loss 0.744973
# Epoch 600 | Train Loss 1.298706 | Val Loss 0.753465
# Early stopping at epoch 641
# Theta | train1 -> R² = 0.6338, MSE = 8.3774e-02
# X | train1 -> R² = -0.5451, MSE = 1.6610e-01
# Y | train1 -> R² = -1.4690, MSE = 2.0663e-01
# Theta | train2 -> R² = -0.3129, MSE = 2.9872e-01
# X | train2 -> R² = -0.4840, MSE = 1.2488e-01
# Y | train2 -> R² = -1.5952, MSE = 2.7867e-01
# Theta | test1 -> R² = 0.6646, MSE = 7.7202e-02
# X | test1 -> R² = -0.6538, MSE = 1.7271e-01
# Y | test1 -> R² = -1.7475, MSE = 2.2479e-01
# Theta | test2 -> R² = -0.1995, MSE = 2.8355e-01
# X | test2 -> R² = -0.4457, MSE = 1.1883e-01
# Y | test2 -> R² = -1.4919, MSE = 2.6380e-01
# Theta | test3 -> R² = 0.6478, MSE = 1.1592e-01
# X | test3 -> R² = -1.1628, MSE = 1.9844e-01
# Y | test3 -> R² = -3.9666, MSE = 3.8081e-01
# Theta | val -> R² = 0.5934, MSE = 1.3324e-01
# X | val -> R² = -1.1778, MSE = 2.0762e-01
# Y | val -> R² = -3.6570, MSE = 3.4617e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.569105 | Val Loss 0.800948
# Epoch 100 | Train Loss 1.460783 | Val Loss 0.765233
# Epoch 200 | Train Loss 1.357441 | Val Loss 0.719977
# Epoch 300 | Train Loss 1.330163 | Val Loss 0.732633
# Epoch 400 | Train Loss 1.320566 | Val Loss 0.738311
# Epoch 500 | Train Loss 1.308207 | Val Loss 0.746745
# Epoch 600 | Train Loss 1.294364 | Val Loss 0.758873
# Epoch 700 | Train Loss 1.283055 | Val Loss 0.793843
# Early stopping at epoch 702
# Theta | train1 -> R² = 0.5912, MSE = 9.3516e-02
# X | train1 -> R² = -0.5901, MSE = 1.7094e-01
# Y | train1 -> R² = -1.5580, MSE = 2.1408e-01
# Theta | train2 -> R² = 0.0914, MSE = 2.0673e-01
# X | train2 -> R² = -0.5008, MSE = 1.2630e-01
# Y | train2 -> R² = -1.4897, MSE = 2.6734e-01
# Theta | test1 -> R² = 0.6446, MSE = 8.1799e-02
# X | test1 -> R² = -0.7621, MSE = 1.8402e-01
# Y | test1 -> R² = -1.9192, MSE = 2.3884e-01
# Theta | test2 -> R² = 0.0867, MSE = 2.1588e-01
# X | test2 -> R² = -0.4449, MSE = 1.1876e-01
# Y | test2 -> R² = -1.3972, MSE = 2.5377e-01
# Theta | test3 -> R² = -0.5310, MSE = 5.0395e-01
# X | test3 -> R² = -0.8659, MSE = 1.7120e-01
# Y | test3 -> R² = -2.6546, MSE = 2.8021e-01
# Theta | val -> R² = 0.2818, MSE = 2.3536e-01
# X | val -> R² = -0.9551, MSE = 1.8639e-01
# Y | val -> R² = -2.7081, MSE = 2.7564e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570779 | Val Loss 0.803289
# Epoch 100 | Train Loss 1.445035 | Val Loss 0.750920
# Epoch 200 | Train Loss 1.330312 | Val Loss 0.715601
# Epoch 300 | Train Loss 1.317605 | Val Loss 0.717062
# Epoch 400 | Train Loss 1.307984 | Val Loss 0.720491
# Epoch 500 | Train Loss 1.300545 | Val Loss 0.723621
# Epoch 600 | Train Loss 1.293770 | Val Loss 0.721604
# Early stopping at epoch 669
# Theta | train1 -> R² = 0.6264, MSE = 8.5466e-02
# X | train1 -> R² = -0.2695, MSE = 1.3647e-01
# Y | train1 -> R² = -1.1162, MSE = 1.7710e-01
# Theta | train2 -> R² = -0.2219, MSE = 2.7802e-01
# X | train2 -> R² = -0.3475, MSE = 1.1340e-01
# Y | train2 -> R² = -1.3125, MSE = 2.4831e-01
# Theta | test1 -> R² = 0.7266, MSE = 6.2932e-02
# X | test1 -> R² = -0.3533, MSE = 1.4133e-01
# Y | test1 -> R² = -1.3975, MSE = 1.9615e-01
# Theta | test2 -> R² = -0.2138, MSE = 2.8692e-01
# X | test2 -> R² = -0.3031, MSE = 1.0710e-01
# Y | test2 -> R² = -1.2320, MSE = 2.3628e-01
# Theta | test3 -> R² = 0.6896, MSE = 1.0219e-01
# X | test3 -> R² = -1.0628, MSE = 1.8926e-01
# Y | test3 -> R² = -3.7702, MSE = 3.6575e-01
# Theta | val -> R² = 0.7236, MSE = 9.0567e-02
# X | val -> R² = -1.0197, MSE = 1.9255e-01
# Y | val -> R² = -3.4685, MSE = 3.3216e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570149 | Val Loss 0.802988
# Epoch 100 | Train Loss 1.457758 | Val Loss 0.764402
# Epoch 200 | Train Loss 1.399405 | Val Loss 0.739904
# Epoch 300 | Train Loss 1.320364 | Val Loss 0.717835
# Epoch 400 | Train Loss 1.308490 | Val Loss 0.722879
# Epoch 500 | Train Loss 1.288081 | Val Loss 0.726446
# Epoch 600 | Train Loss 1.275007 | Val Loss 0.740179
# Epoch 700 | Train Loss 1.266434 | Val Loss 0.755144
# Early stopping at epoch 725
# Theta | train1 -> R² = 0.6644, MSE = 7.6762e-02
# X | train1 -> R² = -0.4038, MSE = 1.5091e-01
# Y | train1 -> R² = -1.1513, MSE = 1.8004e-01
# Theta | train2 -> R² = 0.1559, MSE = 1.9206e-01
# X | train2 -> R² = -0.3142, MSE = 1.1060e-01
# Y | train2 -> R² = -1.2223, MSE = 2.3863e-01
# Theta | test1 -> R² = 0.6570, MSE = 7.8948e-02
# X | test1 -> R² = -0.4742, MSE = 1.5395e-01
# Y | test1 -> R² = -1.4014, MSE = 1.9647e-01
# Theta | test2 -> R² = 0.1803, MSE = 1.9376e-01
# X | test2 -> R² = -0.2613, MSE = 1.0367e-01
# Y | test2 -> R² = -1.1152, MSE = 2.2392e-01
# Theta | test3 -> R² = 0.3273, MSE = 2.2142e-01
# X | test3 -> R² = -0.9999, MSE = 1.8349e-01
# Y | test3 -> R² = -3.2409, MSE = 3.2517e-01
# Theta | val -> R² = 0.6528, MSE = 1.1379e-01
# X | val -> R² = -1.0645, MSE = 1.9681e-01
# Y | val -> R² = -3.1055, MSE = 3.0518e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.567628 | Val Loss 0.804632
# Epoch 100 | Train Loss 1.444776 | Val Loss 0.768983
# Epoch 200 | Train Loss 1.346595 | Val Loss 0.727865
# ...
# X | val -> R² = -0.3730, MSE = 1.3089e-01
# Y | val -> R² = -1.6265, MSE = 1.9524e-01
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_4608\1563548962.py:93: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.589253 | Val Loss 0.791467
# Epoch 100 | Train Loss 1.286656 | Val Loss 0.710357
# Epoch 200 | Train Loss 1.190416 | Val Loss 0.719592
# Epoch 300 | Train Loss 1.103179 | Val Loss 0.765103
# Epoch 400 | Train Loss 1.018206 | Val Loss 0.856649
# Epoch 500 | Train Loss 0.947944 | Val Loss 0.921443
# Epoch 600 | Train Loss 0.908121 | Val Loss 0.976232
# Early stopping at epoch 633
# Theta | train1 -> R² = 0.8966, MSE = 2.3642e-02
# X | train1 -> R² = -0.0365, MSE = 1.1143e-01
# Y | train1 -> R² = -0.7532, MSE = 1.4673e-01
# Theta | train2 -> R² = -0.0296, MSE = 2.3427e-01
# X | train2 -> R² = -0.1394, MSE = 9.5890e-02
# Y | train2 -> R² = -0.8999, MSE = 2.0401e-01
# Theta | test1 -> R² = 0.8740, MSE = 2.9002e-02
# X | test1 -> R² = -0.0013, MSE = 1.0457e-01
# Y | test1 -> R² = -1.1393, MSE = 1.7503e-01
# Theta | test2 -> R² = 0.3273, MSE = 1.5901e-01
# X | test2 -> R² = -0.0621, MSE = 8.7301e-02
# Y | test2 -> R² = -1.0167, MSE = 2.1349e-01
# Theta | test3 -> R² = -0.2326, MSE = 4.0573e-01
# X | test3 -> R² = -0.1097, MSE = 1.0181e-01
# Y | test3 -> R² = -3.9304, MSE = 3.7803e-01
# Theta | val -> R² = 0.6362, MSE = 1.1922e-01
# X | val -> R² = -0.0880, MSE = 1.0372e-01
# Y | val -> R² = -3.8762, MSE = 3.6247e-01
# Figura salva em: ./results/model_128_64_32_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.571617 | Val Loss 0.790759
# Epoch 100 | Train Loss 1.279888 | Val Loss 0.713248
# Epoch 200 | Train Loss 1.207921 | Val Loss 0.737219
# Epoch 300 | Train Loss 1.134040 | Val Loss 0.771868
# Epoch 400 | Train Loss 1.044331 | Val Loss 0.822382
# Epoch 500 | Train Loss 0.967909 | Val Loss 0.894156
# Early stopping at epoch 533
# Theta | train1 -> R² = 0.7894, MSE = 4.8183e-02
# X | train1 -> R² = -0.3906, MSE = 1.4949e-01
# Y | train1 -> R² = -1.4033, MSE = 2.0113e-01
# Theta | train2 -> R² = 0.2317, MSE = 1.7480e-01
# X | train2 -> R² = -0.3854, MSE = 1.1659e-01
# Y | train2 -> R² = -1.4385, MSE = 2.6184e-01
# Theta | test1 -> R² = 0.6836, MSE = 7.2839e-02
# X | test1 -> R² = -0.4860, MSE = 1.5518e-01
# Y | test1 -> R² = -1.6452, MSE = 2.1642e-01
# Theta | test2 -> R² = 0.2981, MSE = 1.6592e-01
# X | test2 -> R² = -0.3477, MSE = 1.1077e-01
# Y | test2 -> R² = -1.3336, MSE = 2.4704e-01
# Theta | test3 -> R² = 0.4988, MSE = 1.6498e-01
# X | test3 -> R² = -0.6847, MSE = 1.5457e-01
# Y | test3 -> R² = -3.0741, MSE = 3.1238e-01
# Theta | val -> R² = 0.7112, MSE = 9.4649e-02
# X | val -> R² = -0.7564, MSE = 1.6744e-01
# Y | val -> R² = -2.9013, MSE = 2.9000e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.589507 | Val Loss 0.797901
# Epoch 100 | Train Loss 1.271053 | Val Loss 0.714590
# Epoch 200 | Train Loss 1.179387 | Val Loss 0.721958
# Epoch 300 | Train Loss 1.071375 | Val Loss 0.738924
# Epoch 400 | Train Loss 0.989722 | Val Loss 0.791513
# Epoch 500 | Train Loss 0.933224 | Val Loss 0.848077
# Epoch 600 | Train Loss 0.903203 | Val Loss 0.952035
# Early stopping at epoch 628
# Theta | train1 -> R² = 0.6427, MSE = 8.1720e-02
# X | train1 -> R² = 0.0048, MSE = 1.0699e-01
# Y | train1 -> R² = -0.7845, MSE = 1.4935e-01
# Theta | train2 -> R² = 0.5852, MSE = 9.4386e-02
# X | train2 -> R² = -0.1622, MSE = 9.7810e-02
# Y | train2 -> R² = -0.9000, MSE = 2.0402e-01
# Theta | test1 -> R² = 0.6662, MSE = 7.6840e-02
# X | test1 -> R² = 0.0465, MSE = 9.9570e-02
# Y | test1 -> R² = -1.2312, MSE = 1.8255e-01
# Theta | test2 -> R² = 0.7502, MSE = 5.9051e-02
# X | test2 -> R² = -0.0759, MSE = 8.8431e-02
# Y | test2 -> R² = -1.0017, MSE = 2.1190e-01
# Theta | test3 -> R² = -2.0560, MSE = 1.0059e+00
# X | test3 -> R² = 0.1242, MSE = 8.0357e-02
# Y | test3 -> R² = -4.1183, MSE = 3.9244e-01
# Theta | val -> R² = 0.1441, MSE = 2.8047e-01
# X | val -> R² = 0.1489, MSE = 8.1138e-02
# Y | val -> R² = -4.2222, MSE = 3.8818e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.545824 | Val Loss 0.716515
# Epoch 100 | Train Loss 1.227596 | Val Loss 0.705196
# Epoch 200 | Train Loss 1.093252 | Val Loss 0.752149
# Epoch 300 | Train Loss 0.957965 | Val Loss 0.876059
# Epoch 400 | Train Loss 0.898228 | Val Loss 0.974021
# Epoch 500 | Train Loss 0.831045 | Val Loss 1.047154
# Early stopping at epoch 507
# Theta | train1 -> R² = 0.7769, MSE = 5.1026e-02
# X | train1 -> R² = -0.0796, MSE = 1.1606e-01
# Y | train1 -> R² = -1.0294, MSE = 1.6984e-01
# Theta | train2 -> R² = 0.3784, MSE = 1.4142e-01
# X | train2 -> R² = -0.1485, MSE = 9.6653e-02
# Y | train2 -> R² = -1.3359, MSE = 2.5082e-01
# Theta | test1 -> R² = 0.8972, MSE = 2.3663e-02
# X | test1 -> R² = -0.1605, MSE = 1.2119e-01
# Y | test1 -> R² = -1.2229, MSE = 1.8186e-01
# Theta | test2 -> R² = 0.4239, MSE = 1.3618e-01
# X | test2 -> R² = -0.1105, MSE = 9.1277e-02
# Y | test2 -> R² = -1.2660, MSE = 2.3988e-01
# Theta | test3 -> R² = 0.6640, MSE = 1.1060e-01
# X | test3 -> R² = -0.2071, MSE = 1.1075e-01
# Y | test3 -> R² = -1.6656, MSE = 2.0438e-01
# Theta | val -> R² = 0.7538, MSE = 8.0693e-02
# X | val -> R² = -0.2338, MSE = 1.1762e-01
# Y | val -> R² = -1.5885, MSE = 1.9241e-01
# Figura salva em: ./results/model_264_128_64_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.588101 | Val Loss 0.807695
# Epoch 100 | Train Loss 1.211475 | Val Loss 0.705548
# Epoch 200 | Train Loss 1.074969 | Val Loss 0.720974
# Epoch 300 | Train Loss 0.948773 | Val Loss 0.812847
# Epoch 400 | Train Loss 0.878463 | Val Loss 0.946350
# Epoch 500 | Train Loss 0.829735 | Val Loss 1.066492
# Early stopping at epoch 578
# Theta | train1 -> R² = 0.5966, MSE = 9.2274e-02
# X | train1 -> R² = 0.0647, MSE = 1.0055e-01
# Y | train1 -> R² = -0.7971, MSE = 1.5039e-01
# Theta | train2 -> R² = 0.6707, MSE = 7.4929e-02
# X | train2 -> R² = -0.1363, MSE = 9.5627e-02
# Y | train2 -> R² = -0.8428, MSE = 1.9788e-01
# Theta | test1 -> R² = 0.4686, MSE = 1.2233e-01
# X | test1 -> R² = 0.0878, MSE = 9.5264e-02
# Y | test1 -> R² = -1.2623, MSE = 1.8510e-01
# Theta | test2 -> R² = 0.7433, MSE = 6.0685e-02
# X | test2 -> R² = -0.0413, MSE = 8.5592e-02
# Y | test2 -> R² = -1.0243, MSE = 2.1429e-01
# Theta | test3 -> R² = -1.3658, MSE = 7.7873e-01
# X | test3 -> R² = 0.1806, MSE = 7.5175e-02
# Y | test3 -> R² = -4.1895, MSE = 3.9790e-01
# Theta | val -> R² = 0.2637, MSE = 2.4127e-01
# X | val -> R² = 0.1987, MSE = 7.6395e-02
# Y | val -> R² = -4.2932, MSE = 3.9347e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.640581 | Val Loss 0.757636
# Epoch 100 | Train Loss 1.227143 | Val Loss 0.711355
# Epoch 200 | Train Loss 1.084864 | Val Loss 0.763258
# Epoch 300 | Train Loss 0.950633 | Val Loss 0.811125
# Epoch 400 | Train Loss 0.885942 | Val Loss 0.879208
# Epoch 500 | Train Loss 0.831717 | Val Loss 0.958760
# Early stopping at epoch 565
# Theta | train1 -> R² = 0.8314, MSE = 3.8571e-02
# X | train1 -> R² = 0.0256, MSE = 1.0475e-01
# Y | train1 -> R² = -0.7787, MSE = 1.4886e-01
# Theta | train2 -> R² = 0.4630, MSE = 1.2219e-01
# X | train2 -> R² = -0.2080, MSE = 1.0166e-01
# Y | train2 -> R² = -0.8400, MSE = 1.9757e-01
# Theta | test1 -> R² = 0.6879, MSE = 7.1838e-02
# X | test1 -> R² = 0.0539, MSE = 9.8798e-02
# Y | test1 -> R² = -1.0845, MSE = 1.7055e-01
# Theta | test2 -> R² = 0.6089, MSE = 9.2442e-02
# X | test2 -> R² = -0.0927, MSE = 8.9813e-02
# Y | test2 -> R² = -0.9100, MSE = 2.0220e-01
# Theta | test3 -> R² = 0.4748, MSE = 1.7289e-01
# X | test3 -> R² = -0.0735, MSE = 9.8495e-02
# Y | test3 -> R² = -3.2834, MSE = 3.2843e-01
# Theta | val -> R² = 0.7795, MSE = 7.2251e-02
# X | val -> R² = -0.0462, MSE = 9.9734e-02
# Y | val -> R² = -3.2639, MSE = 3.1695e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572897 | Val Loss 0.774671
# Epoch 100 | Train Loss 1.219754 | Val Loss 0.710719
# Epoch 200 | Train Loss 1.078492 | Val Loss 0.764252
# Epoch 300 | Train Loss 0.955570 | Val Loss 0.839386
# Epoch 400 | Train Loss 0.881526 | Val Loss 0.907722
# Epoch 500 | Train Loss 0.837337 | Val Loss 1.033603
# Early stopping at epoch 553
# Theta | train1 -> R² = 0.7817, MSE = 4.9937e-02
# X | train1 -> R² = -0.0387, MSE = 1.1167e-01
# Y | train1 -> R² = -0.7502, MSE = 1.4647e-01
# Theta | train2 -> R² = 0.5477, MSE = 1.0291e-01
# X | train2 -> R² = -0.1441, MSE = 9.6282e-02
# Y | train2 -> R² = -0.7588, MSE = 1.8886e-01
# Theta | test1 -> R² = 0.6062, MSE = 9.0640e-02
# X | test1 -> R² = -0.0546, MSE = 1.1013e-01
# Y | test1 -> R² = -1.0617, MSE = 1.6868e-01
# Theta | test2 -> R² = 0.5873, MSE = 9.7550e-02
# X | test2 -> R² = -0.0482, MSE = 8.6155e-02
# Y | test2 -> R² = -0.7944, MSE = 1.8996e-01
# Theta | test3 -> R² = 0.4350, MSE = 1.8597e-01
# X | test3 -> R² = -0.0164, MSE = 9.3252e-02
# Y | test3 -> R² = -2.7247, MSE = 2.8559e-01
# Theta | val -> R² = 0.7666, MSE = 7.6486e-02
# X | val -> R² = -0.0298, MSE = 9.8174e-02
# Y | val -> R² = -2.8041, MSE = 2.8277e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.588059 | Val Loss 0.775487
# Epoch 100 | Train Loss 1.215696 | Val Loss 0.706040
# Epoch 200 | Train Loss 1.072459 | Val Loss 0.717782
# Epoch 300 | Train Loss 0.945719 | Val Loss 0.819795
# Epoch 400 | Train Loss 0.869844 | Val Loss 0.914527
# Epoch 500 | Train Loss 0.820600 | Val Loss 1.002766
# Epoch 600 | Train Loss 0.797245 | Val Loss 1.078149
# Early stopping at epoch 684
# Theta | train1 -> R² = 0.9065, MSE = 2.1380e-02
# X | train1 -> R² = 0.3843, MSE = 6.6192e-02
# Y | train1 -> R² = -0.8911, MSE = 1.5826e-01
# Theta | train2 -> R² = -1.0217, MSE = 4.5999e-01
# X | train2 -> R² = 0.2155, MSE = 6.6016e-02
# Y | train2 -> R² = -1.7567, MSE = 2.9600e-01
# Theta | test1 -> R² = 0.9332, MSE = 1.5385e-02
# X | test1 -> R² = 0.4020, MSE = 6.2444e-02
# Y | test1 -> R² = -1.5387, MSE = 2.0771e-01
# Theta | test2 -> R² = -0.7893, MSE = 4.2296e-01
# X | test2 -> R² = 0.0231, MSE = 8.0294e-02
# Y | test2 -> R² = -2.5127, MSE = 3.7186e-01
# Theta | test3 -> R² = 0.1397, MSE = 2.8316e-01
# X | test3 -> R² = 0.4366, MSE = 5.1691e-02
# Y | test3 -> R² = -6.5118, MSE = 5.7596e-01
# Theta | val -> R² = 0.1364, MSE = 2.8299e-01
# X | val -> R² = 0.4693, MSE = 5.0592e-02
# Y | val -> R² = -6.7658, MSE = 5.7726e-01
# Figura salva em: ./results/model_264_128_64_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.519849 | Val Loss 0.744865
# Epoch 100 | Train Loss 1.224959 | Val Loss 0.716126
# Epoch 200 | Train Loss 1.090395 | Val Loss 0.754283
# Epoch 300 | Train Loss 0.997261 | Val Loss 0.898514
# Epoch 400 | Train Loss 0.878015 | Val Loss 0.928741
# Epoch 500 | Train Loss 0.853201 | Val Loss 0.982471
# Early stopping at epoch 508
# Theta | train1 -> R² = 0.8600, MSE = 3.2026e-02
# X | train1 -> R² = 0.2658, MSE = 7.8927e-02
# Y | train1 -> R² = -0.9328, MSE = 1.6175e-01
# Theta | train2 -> R² = 0.5709, MSE = 9.7630e-02
# X | train2 -> R² = 0.0108, MSE = 8.3250e-02
# Y | train2 -> R² = -1.0751, MSE = 2.2282e-01
# Theta | test1 -> R² = 0.6645, MSE = 7.7219e-02
# X | test1 -> R² = 0.1991, MSE = 8.3635e-02
# Y | test1 -> R² = -1.1249, MSE = 1.7385e-01
# Theta | test2 -> R² = 0.5403, MSE = 1.0866e-01
# X | test2 -> R² = 0.0193, MSE = 8.0611e-02
# Y | test2 -> R² = -1.0084, MSE = 2.1261e-01
# Theta | test3 -> R² = -0.2011, MSE = 3.9536e-01
# X | test3 -> R² = 0.1014, MSE = 8.2449e-02
# Y | test3 -> R² = -1.6246, MSE = 2.0124e-01
# Theta | val -> R² = 0.4655, MSE = 1.7514e-01
# X | val -> R² = 0.1511, MSE = 8.0931e-02
# Y | val -> R² = -1.6096, MSE = 1.9398e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.558538 | Val Loss 0.779454
# Epoch 100 | Train Loss 1.222804 | Val Loss 0.703428
# Epoch 200 | Train Loss 1.073661 | Val Loss 0.728994
# Epoch 300 | Train Loss 0.955117 | Val Loss 0.796519
# Epoch 400 | Train Loss 0.943395 | Val Loss 0.852751
# Epoch 500 | Train Loss 0.859398 | Val Loss 0.873514
# Early stopping at epoch 578
# Theta | train1 -> R² = 0.3615, MSE = 1.4604e-01
# X | train1 -> R² = 0.0477, MSE = 1.0238e-01
# Y | train1 -> R² = -0.8037, MSE = 1.5095e-01
# Theta | train2 -> R² = 0.6448, MSE = 8.0828e-02
# X | train2 -> R² = -0.1720, MSE = 9.8634e-02
# Y | train2 -> R² = -0.8434, MSE = 1.9794e-01
# Theta | test1 -> R² = 0.0351, MSE = 2.2211e-01
# X | test1 -> R² = 0.1285, MSE = 9.1015e-02
# Y | test1 -> R² = -1.2097, MSE = 1.8079e-01
# Theta | test2 -> R² = 0.6800, MSE = 7.5644e-02
# X | test2 -> R² = -0.0466, MSE = 8.6021e-02
# Y | test2 -> R² = -1.0287, MSE = 2.1476e-01
# Theta | test3 -> R² = -1.1018, MSE = 6.9182e-01
# X | test3 -> R² = 0.1465, MSE = 7.8307e-02
# Y | test3 -> R² = -4.3735, MSE = 4.1201e-01
# Theta | val -> R² = 0.2492, MSE = 2.4603e-01
# X | val -> R² = 0.1597, MSE = 8.0107e-02
# Y | val -> R² = -4.4554, MSE = 4.0552e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.561627 | Val Loss 0.761149
# Epoch 100 | Train Loss 1.215120 | Val Loss 0.707198
# Epoch 200 | Train Loss 1.085141 | Val Loss 0.739310
# Epoch 300 | Train Loss 0.954865 | Val Loss 0.785585
# Epoch 400 | Train Loss 0.903373 | Val Loss 0.906225
# Epoch 500 | Train Loss 0.836621 | Val Loss 0.963245
# Early stopping at epoch 571
# Theta | train1 -> R² = 0.9086, MSE = 2.0913e-02
# X | train1 -> R² = 0.0587, MSE = 1.0120e-01
# Y | train1 -> R² = -0.7899, MSE = 1.4979e-01
# Theta | train2 -> R² = -0.0450, MSE = 2.3776e-01
# X | train2 -> R² = -0.1307, MSE = 9.5158e-02
# Y | train2 -> R² = -0.8802, MSE = 2.0189e-01
# Theta | test1 -> R² = 0.8316, MSE = 3.8765e-02
# X | test1 -> R² = 0.1160, MSE = 9.2312e-02
# Y | test1 -> R² = -1.1652, MSE = 1.7714e-01
# Theta | test2 -> R² = 0.3198, MSE = 1.6079e-01
# X | test2 -> R² = -0.0308, MSE = 8.4723e-02
# Y | test2 -> R² = -1.0154, MSE = 2.1335e-01
# Theta | test3 -> R² = -0.4796, MSE = 4.8702e-01
# X | test3 -> R² = 0.0081, MSE = 9.1009e-02
# Y | test3 -> R² = -4.3852, MSE = 4.1290e-01
# Theta | val -> R² = 0.5517, MSE = 1.4689e-01
# X | val -> R² = 0.0310, MSE = 9.2379e-02
# Y | val -> R² = -4.2853, MSE = 3.9287e-01
# Figura salva em: ./results/model_264_128_64_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.629933 | Val Loss 0.781110
# Epoch 100 | Train Loss 1.229236 | Val Loss 0.709971
# Epoch 200 | Train Loss 1.097850 | Val Loss 0.736829
# Epoch 300 | Train Loss 0.971727 | Val Loss 0.770288
# Epoch 400 | Train Loss 0.899277 | Val Loss 0.813136
# Epoch 500 | Train Loss 0.866200 | Val Loss 0.854017
# Early stopping at epoch 515
# Theta | train1 -> R² = 0.6956, MSE = 6.9625e-02
# X | train1 -> R² = 0.3661, MSE = 6.8148e-02
# Y | train1 -> R² = -1.1548, MSE = 1.8034e-01
# Theta | train2 -> R² = 0.4477, MSE = 1.2567e-01
# X | train2 -> R² = -0.0242, MSE = 8.6194e-02
# Y | train2 -> R² = -1.1031, MSE = 2.2582e-01
# Theta | test1 -> R² = 0.4747, MSE = 1.2091e-01
# X | test1 -> R² = 0.3224, MSE = 7.0762e-02
# Y | test1 -> R² = -1.4021, MSE = 1.9653e-01
# Theta | test2 -> R² = 0.4223, MSE = 1.3657e-01
# X | test2 -> R² = -0.0255, MSE = 8.4287e-02
# Y | test2 -> R² = -0.9971, MSE = 2.1142e-01
# Theta | test3 -> R² = -0.2350, MSE = 4.0652e-01
# X | test3 -> R² = 0.2221, MSE = 7.1371e-02
# Y | test3 -> R² = -2.5831, MSE = 2.7473e-01
# Theta | val -> R² = 0.3253, MSE = 2.2109e-01
# X | val -> R² = 0.2617, MSE = 7.0387e-02
# Y | val -> R² = -2.4958, MSE = 2.5985e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.549262 | Val Loss 0.754606
# Epoch 100 | Train Loss 1.216039 | Val Loss 0.711554
# Epoch 200 | Train Loss 1.081011 | Val Loss 0.758944
# Epoch 300 | Train Loss 0.981340 | Val Loss 0.781550
# Epoch 400 | Train Loss 0.901882 | Val Loss 0.871175
# Epoch 500 | Train Loss 0.846265 | Val Loss 0.973719
# Early stopping at epoch 562
# Theta | train1 -> R² = 0.5892, MSE = 9.3954e-02
# X | train1 -> R² = 0.1015, MSE = 9.6590e-02
# Y | train1 -> R² = -0.8793, MSE = 1.5728e-01
# Theta | train2 -> R² = 0.6149, MSE = 8.7623e-02
# X | train2 -> R² = -0.2065, MSE = 1.0153e-01
# Y | train2 -> R² = -0.9280, MSE = 2.0702e-01
# Theta | test1 -> R² = 0.2424, MSE = 1.7440e-01
# X | test1 -> R² = 0.1154, MSE = 9.2376e-02
# Y | test1 -> R² = -1.2385, MSE = 1.8315e-01
# Theta | test2 -> R² = 0.6567, MSE = 8.1151e-02
# X | test2 -> R² = -0.0787, MSE = 8.8666e-02
# Y | test2 -> R² = -1.0338, MSE = 2.1530e-01
# Theta | test3 -> R² = -0.1971, MSE = 3.9404e-01
# X | test3 -> R² = 0.1059, MSE = 8.2029e-02
# Y | test3 -> R² = -4.0790, MSE = 3.8943e-01
# Theta | val -> R² = 0.5896, MSE = 1.3448e-01
# X | val -> R² = 0.1682, MSE = 7.9300e-02
# Y | val -> R² = -4.1813, MSE = 3.8514e-01
# Modelo 9 treinado e salvo no Excel
