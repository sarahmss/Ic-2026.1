# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    for var in PREDICTORS:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
PREDICTORS = ["dWdRef", "dWeRef", "sWdRef", "sWeRef"]   
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train2, Train1], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 4)
# Dimensão da saida: (1268, 3, 4)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, patience=500, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train, theta_train)
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)
        # plt.show()

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# Epoch 0 | Train Loss 1.596248 | Val Loss 0.798011
# Epoch 100 | Train Loss 1.272078 | Val Loss 0.717070
# Epoch 200 | Train Loss 1.263339 | Val Loss 0.715710
# Epoch 300 | Train Loss 1.232432 | Val Loss 0.704307
# Epoch 400 | Train Loss 1.202785 | Val Loss 0.693169
# Epoch 500 | Train Loss 1.173192 | Val Loss 0.706687
# Epoch 600 | Train Loss 1.148753 | Val Loss 0.741045
# Epoch 700 | Train Loss 1.129502 | Val Loss 0.771247
# Epoch 800 | Train Loss 1.110822 | Val Loss 0.798237
# Early stopping at epoch 885
# Theta | train1 -> R² = 0.7957, MSE = 4.6644e-02
# X | train1 -> R² = -0.1153, MSE = 1.2025e-01
# Y | train1 -> R² = -0.8455, MSE = 1.5465e-01
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.ops.tensor_array_ops.TensorArray'>):
# <tensorflow.python.ops.tensor_array_ops.TensorArray object at 0x0000021F43BA90F0>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
#   File "d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py", line 5158, in <genexpr>
#     output_ta_t = tuple(  File "d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\tensorflow\python\util\tf_should_use.py", line 288, in wrapped
#     return _add_should_use_warning(fn(*args, **kwargs),
# ==================================
# Theta | train2 -> R² = 0.3425, MSE = 1.5012e-01
# X | train2 -> R² = -0.1750, MSE = 9.9002e-02
# Y | train2 -> R² = -0.7719, MSE = 1.9080e-01
# Theta | test1 -> R² = 0.7346, MSE = 6.0977e-02
# X | test1 -> R² = -0.0982, MSE = 1.1505e-01
# Y | test1 -> R² = -1.2669, MSE = 1.8577e-01
# Theta | test2 -> R² = 0.3102, MSE = 1.6360e-01
# X | test2 -> R² = -0.1147, MSE = 9.1728e-02
# Y | test2 -> R² = -0.9854, MSE = 2.1074e-01
# Theta | test3 -> R² = 0.5873, MSE = 1.3567e-01
# X | test3 -> R² = -0.2687, MSE = 1.1673e-01
# Y | test3 -> R² = -0.9968, MSE = 1.5337e-01
# Theta | val -> R² = 0.7364, MSE = 8.6276e-02
# X | val -> R² = -0.2351, MSE = 1.1810e-01
# Y | val -> R² = -1.1908, MSE = 1.6310e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.624567 | Val Loss 0.810305
# Epoch 100 | Train Loss 1.272202 | Val Loss 0.716836
# Epoch 200 | Train Loss 1.266171 | Val Loss 0.715616
# Epoch 300 | Train Loss 1.239595 | Val Loss 0.701235
# Epoch 400 | Train Loss 1.208958 | Val Loss 0.690427
# Epoch 500 | Train Loss 1.182168 | Val Loss 0.698423
# Epoch 600 | Train Loss 1.151038 | Val Loss 0.717682
# Epoch 700 | Train Loss 1.129931 | Val Loss 0.740775
# Epoch 800 | Train Loss 1.111502 | Val Loss 0.766253
# Early stopping at epoch 862
# Theta | train1 -> R² = 0.7756, MSE = 5.1216e-02
# X | train1 -> R² = -0.1198, MSE = 1.2075e-01
# Y | train1 -> R² = -0.8105, MSE = 1.5171e-01
# Theta | train2 -> R² = 0.4424, MSE = 1.2731e-01
# X | train2 -> R² = -0.1649, MSE = 9.8154e-02
# Y | train2 -> R² = -0.8224, MSE = 1.9623e-01
# Theta | test1 -> R² = 0.7200, MSE = 6.4329e-02
# X | test1 -> R² = -0.1011, MSE = 1.1535e-01
# Y | test1 -> R² = -1.2243, MSE = 1.8228e-01
# Theta | test2 -> R² = 0.4746, MSE = 1.2460e-01
# X | test2 -> R² = -0.0640, MSE = 8.7559e-02
# Y | test2 -> R² = -0.9732, MSE = 2.0944e-01
# Theta | test3 -> R² = 0.1410, MSE = 2.8241e-01
# X | test3 -> R² = -0.1969, MSE = 1.1012e-01
# Y | test3 -> R² = -0.6179, MSE = 1.2427e-01
# Theta | val -> R² = 0.5595, MSE = 1.4418e-01
# X | val -> R² = -0.1793, MSE = 1.1277e-01
# Y | val -> R² = -0.8838, MSE = 1.4025e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.602296 | Val Loss 0.817310
# Epoch 100 | Train Loss 1.271936 | Val Loss 0.716743
# Epoch 200 | Train Loss 1.263429 | Val Loss 0.713175
# Epoch 300 | Train Loss 1.231665 | Val Loss 0.697662
# Epoch 400 | Train Loss 1.201410 | Val Loss 0.689159
# Epoch 500 | Train Loss 1.173704 | Val Loss 0.695915
# Epoch 600 | Train Loss 1.148250 | Val Loss 0.723570
# Epoch 700 | Train Loss 1.126245 | Val Loss 0.762608
# Epoch 800 | Train Loss 1.104775 | Val Loss 0.796398
# Epoch 900 | Train Loss 1.084163 | Val Loss 0.828429
# Early stopping at epoch 903
# Theta | train1 -> R² = 0.7720, MSE = 5.2047e-02
# X | train1 -> R² = -0.1046, MSE = 1.1910e-01
# Y | train1 -> R² = -0.8054, MSE = 1.5128e-01
# Theta | train2 -> R² = 0.3930, MSE = 1.3859e-01
# X | train2 -> R² = -0.1904, MSE = 1.0030e-01
# Y | train2 -> R² = -0.8127, MSE = 1.9519e-01
# Theta | test1 -> R² = 0.6902, MSE = 7.1160e-02
# X | test1 -> R² = -0.0458, MSE = 1.0956e-01
# Y | test1 -> R² = -1.2943, MSE = 1.8802e-01
# Theta | test2 -> R² = 0.4150, MSE = 1.3873e-01
# X | test2 -> R² = -0.1039, MSE = 9.0841e-02
# Y | test2 -> R² = -1.0073, MSE = 2.1306e-01
# Theta | test3 -> R² = -0.2593, MSE = 4.1398e-01
# X | test3 -> R² = -0.1894, MSE = 1.0943e-01
# Y | test3 -> R² = -1.4871, MSE = 1.9103e-01
# Theta | val -> R² = 0.3680, MSE = 2.0686e-01
# X | val -> R² = -0.1513, MSE = 1.1010e-01
# Y | val -> R² = -1.7218, MSE = 2.0264e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.553401 | Val Loss 0.802230
# Epoch 100 | Train Loss 1.272042 | Val Loss 0.716557
# Epoch 200 | Train Loss 1.266295 | Val Loss 0.714923
# Epoch 300 | Train Loss 1.241876 | Val Loss 0.700964
# Epoch 400 | Train Loss 1.205449 | Val Loss 0.688715
# Epoch 500 | Train Loss 1.177978 | Val Loss 0.698500
# Epoch 600 | Train Loss 1.152835 | Val Loss 0.718101
# Epoch 700 | Train Loss 1.128220 | Val Loss 0.748558
# Epoch 800 | Train Loss 1.105925 | Val Loss 0.789083
# Early stopping at epoch 887
# Theta | train1 -> R² = 0.7973, MSE = 4.6265e-02
# X | train1 -> R² = -0.1328, MSE = 1.2215e-01
# Y | train1 -> R² = -0.8633, MSE = 1.5614e-01
# Theta | train2 -> R² = 0.3965, MSE = 1.3778e-01
# X | train2 -> R² = -0.1788, MSE = 9.9323e-02
# Y | train2 -> R² = -0.7957, MSE = 1.9336e-01
# Theta | test1 -> R² = 0.6832, MSE = 7.2780e-02
# X | test1 -> R² = -0.0924, MSE = 1.1444e-01
# Y | test1 -> R² = -1.2402, MSE = 1.8358e-01
# Theta | test2 -> R² = 0.4591, MSE = 1.2827e-01
# X | test2 -> R² = -0.0814, MSE = 8.8993e-02
# Y | test2 -> R² = -0.9688, MSE = 2.0897e-01
# Theta | test3 -> R² = 0.2351, MSE = 2.5147e-01
# X | test3 -> R² = -0.0436, MSE = 9.6013e-02
# Y | test3 -> R² = -1.6089, MSE = 2.0039e-01
# Theta | val -> R² = 0.6650, MSE = 1.0963e-01
# X | val -> R² = -0.0444, MSE = 9.9865e-02
# Y | val -> R² = -1.7821, MSE = 2.0713e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.615606 | Val Loss 0.810817
# Epoch 100 | Train Loss 1.272432 | Val Loss 0.717144
# Epoch 200 | Train Loss 1.267316 | Val Loss 0.717775
# Epoch 300 | Train Loss 1.245723 | Val Loss 0.711670
# Epoch 400 | Train Loss 1.212758 | Val Loss 0.687520
# Epoch 500 | Train Loss 1.185535 | Val Loss 0.683409
# Epoch 600 | Train Loss 1.155586 | Val Loss 0.695592
# Epoch 700 | Train Loss 1.131101 | Val Loss 0.708635
# Epoch 800 | Train Loss 1.110943 | Val Loss 0.717879
# Epoch 900 | Train Loss 1.091253 | Val Loss 0.737451
# Early stopping at epoch 986
# Theta | train1 -> R² = 0.8209, MSE = 4.0884e-02
# X | train1 -> R² = -0.1117, MSE = 1.1987e-01
# Y | train1 -> R² = -0.7336, MSE = 1.4527e-01
# Theta | train2 -> R² = 0.2262, MSE = 1.7667e-01
# X | train2 -> R² = -0.1718, MSE = 9.8738e-02
# Y | train2 -> R² = -0.8456, MSE = 1.9873e-01
# Theta | test1 -> R² = 0.7148, MSE = 6.5510e-02
# X | test1 -> R² = -0.0110, MSE = 1.0591e-01
# Y | test1 -> R² = -1.2511, MSE = 1.8447e-01
# Theta | test2 -> R² = 0.1831, MSE = 1.9373e-01
# X | test2 -> R² = -0.0561, MSE = 8.6907e-02
# Y | test2 -> R² = -1.0708, MSE = 2.1980e-01
# Theta | test3 -> R² = 0.2117, MSE = 2.5915e-01
# X | test3 -> R² = -0.0284, MSE = 9.4618e-02
# Y | test3 -> R² = -1.4925, MSE = 1.9144e-01
# Theta | val -> R² = 0.6956, MSE = 9.9613e-02
# X | val -> R² = -0.0321, MSE = 9.8689e-02
# Y | val -> R² = -1.5592, MSE = 1.9054e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.510765 | Val Loss 0.773158
# Epoch 100 | Train Loss 1.271927 | Val Loss 0.716938
# Epoch 200 | Train Loss 1.262376 | Val Loss 0.714529
# Epoch 300 | Train Loss 1.226623 | Val Loss 0.691444
# Epoch 400 | Train Loss 1.196058 | Val Loss 0.682458
# Epoch 500 | Train Loss 1.164550 | Val Loss 0.688948
# Epoch 600 | Train Loss 1.137151 | Val Loss 0.717567
# Epoch 700 | Train Loss 1.112970 | Val Loss 0.745847
# Epoch 800 | Train Loss 1.089614 | Val Loss 0.767139
# Early stopping at epoch 869
# Theta | train1 -> R² = 0.7643, MSE = 5.3803e-02
# X | train1 -> R² = -0.1265, MSE = 1.2146e-01
# Y | train1 -> R² = -0.8106, MSE = 1.5172e-01
# Theta | train2 -> R² = 0.2518, MSE = 1.7081e-01
# X | train2 -> R² = -0.1379, MSE = 9.5876e-02
# Y | train2 -> R² = -0.8074, MSE = 1.9461e-01
# Theta | test1 -> R² = 0.6582, MSE = 7.8518e-02
# X | test1 -> R² = -0.1000, MSE = 1.1524e-01
# Y | test1 -> R² = -1.2396, MSE = 1.8353e-01
# Theta | test2 -> R² = 0.2612, MSE = 1.7521e-01
# X | test2 -> R² = -0.0666, MSE = 8.7777e-02
# Y | test2 -> R² = -1.0354, MSE = 2.1604e-01
# Theta | test3 -> R² = 0.3104, MSE = 2.2672e-01
# X | test3 -> R² = -0.0542, MSE = 9.6993e-02
# Y | test3 -> R² = -1.2167, MSE = 1.7026e-01
# Theta | val -> R² = 0.6373, MSE = 1.1872e-01
# X | val -> R² = -0.0645, MSE = 1.0179e-01
# Y | val -> R² = -1.3332, MSE = 1.7370e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.601399 | Val Loss 0.826449
# Epoch 100 | Train Loss 1.272247 | Val Loss 0.717101
# Epoch 200 | Train Loss 1.266316 | Val Loss 0.715659
# Epoch 300 | Train Loss 1.240836 | Val Loss 0.701254
# Epoch 400 | Train Loss 1.205440 | Val Loss 0.690167
# Epoch 500 | Train Loss 1.178212 | Val Loss 0.692552
# Epoch 600 | Train Loss 1.151111 | Val Loss 0.713279
# Epoch 700 | Train Loss 1.129508 | Val Loss 0.744223
# Epoch 800 | Train Loss 1.108052 | Val Loss 0.781059
# Early stopping at epoch 879
# Theta | train1 -> R² = 0.8058, MSE = 4.4327e-02
# X | train1 -> R² = -0.1334, MSE = 1.2221e-01
# Y | train1 -> R² = -0.8259, MSE = 1.5301e-01
# Theta | train2 -> R² = 0.3298, MSE = 1.5300e-01
# X | train2 -> R² = -0.1840, MSE = 9.9763e-02
# Y | train2 -> R² = -0.7786, MSE = 1.9152e-01
# Theta | test1 -> R² = 0.6989, MSE = 6.9161e-02
# X | test1 -> R² = -0.1008, MSE = 1.1532e-01
# Y | test1 -> R² = -1.3118, MSE = 1.8945e-01
# Theta | test2 -> R² = 0.3239, MSE = 1.6034e-01
# X | test2 -> R² = -0.0865, MSE = 8.9408e-02
# Y | test2 -> R² = -1.0249, MSE = 2.1493e-01
# Theta | test3 -> R² = -0.0148, MSE = 3.3361e-01
# X | test3 -> R² = -0.1334, MSE = 1.0428e-01
# Y | test3 -> R² = -1.1649, MSE = 1.6628e-01
# Theta | val -> R² = 0.4538, MSE = 1.7877e-01
# X | val -> R² = -0.1001, MSE = 1.0519e-01
# Y | val -> R² = -1.3719, MSE = 1.7659e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.530332 | Val Loss 0.812870
# Epoch 100 | Train Loss 1.270697 | Val Loss 0.717645
# Epoch 200 | Train Loss 1.263281 | Val Loss 0.717716
# Epoch 300 | Train Loss 1.234306 | Val Loss 0.698290
# Epoch 400 | Train Loss 1.195646 | Val Loss 0.684935
# Epoch 500 | Train Loss 1.161502 | Val Loss 0.708626
# Epoch 600 | Train Loss 1.135898 | Val Loss 0.733017
# Epoch 700 | Train Loss 1.114097 | Val Loss 0.752182
# Epoch 800 | Train Loss 1.094859 | Val Loss 0.766878
# Early stopping at epoch 875
# Theta | train1 -> R² = 0.7963, MSE = 4.6494e-02
# X | train1 -> R² = -0.1325, MSE = 1.2212e-01
# Y | train1 -> R² = -0.8427, MSE = 1.5441e-01
# Theta | train2 -> R² = 0.2857, MSE = 1.6307e-01
# X | train2 -> R² = -0.1611, MSE = 9.7832e-02
# Y | train2 -> R² = -0.8049, MSE = 1.9435e-01
# Theta | test1 -> R² = 0.7203, MSE = 6.4253e-02
# X | test1 -> R² = -0.1021, MSE = 1.1546e-01
# Y | test1 -> R² = -1.2275, MSE = 1.8254e-01
# Theta | test2 -> R² = 0.3022, MSE = 1.6549e-01
# X | test2 -> R² = -0.0752, MSE = 8.8480e-02
# Y | test2 -> R² = -1.0510, MSE = 2.1769e-01
# Theta | test3 -> R² = 0.1069, MSE = 2.9361e-01
# X | test3 -> R² = -0.1548, MSE = 1.0624e-01
# Y | test3 -> R² = -1.2979, MSE = 1.7649e-01
# Theta | val -> R² = 0.4802, MSE = 1.7012e-01
# X | val -> R² = -0.1775, MSE = 1.1260e-01
# Y | val -> R² = -1.2866, MSE = 1.7024e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.577304 | Val Loss 0.791013
# Epoch 100 | Train Loss 1.272114 | Val Loss 0.716180
# Epoch 200 | Train Loss 1.267113 | Val Loss 0.716105
# Epoch 300 | Train Loss 1.241773 | Val Loss 0.709605
# Epoch 400 | Train Loss 1.213545 | Val Loss 0.689645
# Epoch 500 | Train Loss 1.186346 | Val Loss 0.687404
# Epoch 600 | Train Loss 1.157547 | Val Loss 0.711110
# Epoch 700 | Train Loss 1.138246 | Val Loss 0.735150
# Epoch 800 | Train Loss 1.120641 | Val Loss 0.754708
# Epoch 900 | Train Loss 1.102867 | Val Loss 0.768585
# Early stopping at epoch 955
# Theta | train1 -> R² = 0.6934, MSE = 6.9978e-02
# X | train1 -> R² = -0.1162, MSE = 1.2036e-01
# Y | train1 -> R² = -0.8073, MSE = 1.5144e-01
# Theta | train2 -> R² = 0.2763, MSE = 1.6523e-01
# X | train2 -> R² = -0.1682, MSE = 9.8434e-02
# Y | train2 -> R² = -0.8279, MSE = 1.9682e-01
# Theta | test1 -> R² = 0.5433, MSE = 1.0491e-01
# X | test1 -> R² = -0.0242, MSE = 1.0729e-01
# Y | test1 -> R² = -1.2248, MSE = 1.8232e-01
# Theta | test2 -> R² = 0.3659, MSE = 1.5038e-01
# X | test2 -> R² = -0.0730, MSE = 8.8302e-02
# Y | test2 -> R² = -1.0158, MSE = 2.1396e-01
# Theta | test3 -> R² = 0.3921, MSE = 1.9985e-01
# X | test3 -> R² = -0.2593, MSE = 1.1586e-01
# Y | test3 -> R² = -1.7351, MSE = 2.1007e-01
# Theta | val -> R² = 0.5770, MSE = 1.3843e-01
# X | val -> R² = -0.2516, MSE = 1.1968e-01
# Y | val -> R² = -1.8752, MSE = 2.1406e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.599640 | Val Loss 0.796508
# Epoch 100 | Train Loss 1.271573 | Val Loss 0.716724
# Epoch 200 | Train Loss 1.263647 | Val Loss 0.715027
# Epoch 300 | Train Loss 1.233598 | Val Loss 0.702099
# Epoch 400 | Train Loss 1.202699 | Val Loss 0.685029
# Epoch 500 | Train Loss 1.174890 | Val Loss 0.687473
# Epoch 600 | Train Loss 1.150267 | Val Loss 0.700528
# Epoch 700 | Train Loss 1.131126 | Val Loss 0.722842
# Epoch 800 | Train Loss 1.111730 | Val Loss 0.753124
# Epoch 900 | Train Loss 1.091095 | Val Loss 0.774513
# Early stopping at epoch 910
# Theta | train1 -> R² = 0.7810, MSE = 4.9983e-02
# X | train1 -> R² = -0.1163, MSE = 1.2036e-01
# Y | train1 -> R² = -0.8119, MSE = 1.5183e-01
# Theta | train2 -> R² = 0.2818, MSE = 1.6397e-01
# X | train2 -> R² = -0.1769, MSE = 9.9167e-02
# Y | train2 -> R² = -0.8132, MSE = 1.9524e-01
# Theta | test1 -> R² = 0.6224, MSE = 8.6736e-02
# X | test1 -> R² = -0.0918, MSE = 1.1438e-01
# Y | test1 -> R² = -1.2231, MSE = 1.8218e-01
# Theta | test2 -> R² = 0.3505, MSE = 1.5404e-01
# X | test2 -> R² = -0.0785, MSE = 8.8753e-02
# Y | test2 -> R² = -0.9978, MSE = 2.1205e-01
# Theta | test3 -> R² = 0.6802, MSE = 1.0514e-01
# X | test3 -> R² = -0.0704, MSE = 9.8486e-02
# Y | test3 -> R² = -1.4810, MSE = 1.9056e-01
# Theta | val -> R² = 0.7557, MSE = 7.9941e-02
# X | val -> R² = -0.0242, MSE = 9.7935e-02
# Y | val -> R² = -1.6414, MSE = 1.9665e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.633917 | Val Loss 0.796277
# Epoch 100 | Train Loss 1.271315 | Val Loss 0.716097
# Epoch 200 | Train Loss 1.258606 | Val Loss 0.711762
# Epoch 300 | Train Loss 1.208176 | Val Loss 0.688517
# Epoch 400 | Train Loss 1.173012 | Val Loss 0.694486
# Epoch 500 | Train Loss 1.134940 | Val Loss 0.737488
# Epoch 600 | Train Loss 1.109176 | Val Loss 0.793052
# Epoch 700 | Train Loss 1.086700 | Val Loss 0.822655
# Epoch 800 | Train Loss 1.064189 | Val Loss 0.832572
# Early stopping at epoch 844
# Theta | train1 -> R² = 0.7335, MSE = 6.0829e-02
# X | train1 -> R² = -0.1218, MSE = 1.2096e-01
# Y | train1 -> R² = -0.7975, MSE = 1.5062e-01
# Theta | train2 -> R² = 0.2242, MSE = 1.7712e-01
# X | train2 -> R² = -0.1385, MSE = 9.5928e-02
# Y | train2 -> R² = -0.7966, MSE = 1.9345e-01
# Theta | test1 -> R² = 0.6440, MSE = 8.1780e-02
# X | test1 -> R² = -0.0894, MSE = 1.1413e-01
# Y | test1 -> R² = -1.2026, MSE = 1.8050e-01
# Theta | test2 -> R² = 0.3180, MSE = 1.6174e-01
# X | test2 -> R² = -0.0944, MSE = 9.0062e-02
# Y | test2 -> R² = -1.0570, MSE = 2.1834e-01
# Theta | test3 -> R² = 0.4114, MSE = 1.9349e-01
# X | test3 -> R² = -0.2502, MSE = 1.1503e-01
# Y | test3 -> R² = -1.2866, MSE = 1.7563e-01
# Theta | val -> R² = 0.7138, MSE = 9.3677e-02
# X | val -> R² = -0.2007, MSE = 1.1482e-01
# Y | val -> R² = -1.4425, MSE = 1.8184e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.598239 | Val Loss 0.797842
# Epoch 100 | Train Loss 1.271239 | Val Loss 0.716198
# Epoch 200 | Train Loss 1.258428 | Val Loss 0.712812
# Epoch 300 | Train Loss 1.202597 | Val Loss 0.687524
# Epoch 400 | Train Loss 1.157214 | Val Loss 0.703092
# Epoch 500 | Train Loss 1.123029 | Val Loss 0.745743
# Epoch 600 | Train Loss 1.092220 | Val Loss 0.785239
# Epoch 700 | Train Loss 1.065867 | Val Loss 0.819712
# Early stopping at epoch 793
# Theta | train1 -> R² = 0.5461, MSE = 1.0361e-01
# X | train1 -> R² = -0.1024, MSE = 1.1887e-01
# Y | train1 -> R² = -0.8586, MSE = 1.5575e-01
# Theta | train2 -> R² = 0.5360, MSE = 1.0592e-01
# X | train2 -> R² = -0.1862, MSE = 9.9949e-02
# Y | train2 -> R² = -0.7640, MSE = 1.8995e-01
# Theta | test1 -> R² = 0.4346, MSE = 1.2989e-01
# X | test1 -> R² = -0.0816, MSE = 1.1331e-01
# Y | test1 -> R² = -1.2129, MSE = 1.8135e-01
# Theta | test2 -> R² = 0.6375, MSE = 8.5971e-02
# X | test2 -> R² = -0.0907, MSE = 8.9758e-02
# Y | test2 -> R² = -0.9934, MSE = 2.1159e-01
# Theta | test3 -> R² = 0.3128, MSE = 2.2591e-01
# X | test3 -> R² = -0.0922, MSE = 1.0049e-01
# Y | test3 -> R² = -0.7606, MSE = 1.3522e-01
# Theta | val -> R² = 0.6003, MSE = 1.3080e-01
# X | val -> R² = -0.0597, MSE = 1.0133e-01
# Y | val -> R² = -0.8611, MSE = 1.3856e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.589914 | Val Loss 0.776698
# Epoch 100 | Train Loss 1.271510 | Val Loss 0.716699
# Epoch 200 | Train Loss 1.257827 | Val Loss 0.710934
# Epoch 300 | Train Loss 1.208725 | Val Loss 0.690102
# Epoch 400 | Train Loss 1.170597 | Val Loss 0.697222
# Epoch 500 | Train Loss 1.134442 | Val Loss 0.741827
# Epoch 600 | Train Loss 1.102184 | Val Loss 0.776611
# Epoch 700 | Train Loss 1.070125 | Val Loss 0.778468
# Epoch 800 | Train Loss 1.038771 | Val Loss 0.777981
# Early stopping at epoch 831
# Theta | train1 -> R² = 0.8570, MSE = 3.2638e-02
# X | train1 -> R² = -0.0957, MSE = 1.1814e-01
# Y | train1 -> R² = -0.8192, MSE = 1.5244e-01
# Theta | train2 -> R² = 0.1149, MSE = 2.0207e-01
# X | train2 -> R² = -0.1566, MSE = 9.7457e-02
# Y | train2 -> R² = -0.7987, MSE = 1.9368e-01
# Theta | test1 -> R² = 0.7635, MSE = 5.4327e-02
# X | test1 -> R² = -0.0457, MSE = 1.0954e-01
# Y | test1 -> R² = -1.2886, MSE = 1.8754e-01
# Theta | test2 -> R² = 0.0976, MSE = 2.1401e-01
# X | test2 -> R² = -0.0785, MSE = 8.8753e-02
# Y | test2 -> R² = -1.0423, MSE = 2.1678e-01
# Theta | test3 -> R² = 0.5632, MSE = 1.4358e-01
# X | test3 -> R² = -0.1804, MSE = 1.0860e-01
# Y | test3 -> R² = -1.4645, MSE = 1.8929e-01
# Theta | val -> R² = 0.7227, MSE = 9.0770e-02
# X | val -> R² = -0.1241, MSE = 1.0749e-01
# Y | val -> R² = -1.6279, MSE = 1.9565e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.558134 | Val Loss 0.762353
# Epoch 100 | Train Loss 1.270282 | Val Loss 0.715750
# Epoch 200 | Train Loss 1.245207 | Val Loss 0.709867
# Epoch 300 | Train Loss 1.199060 | Val Loss 0.682425
# Epoch 400 | Train Loss 1.159085 | Val Loss 0.698295
# Epoch 500 | Train Loss 1.128913 | Val Loss 0.738644
# Epoch 600 | Train Loss 1.099282 | Val Loss 0.799458
# Epoch 700 | Train Loss 1.070665 | Val Loss 0.853995
# Epoch 800 | Train Loss 1.041969 | Val Loss 0.914999
# Early stopping at epoch 806
# Theta | train1 -> R² = 0.7822, MSE = 4.9716e-02
# X | train1 -> R² = -0.1150, MSE = 1.2023e-01
# Y | train1 -> R² = -0.8178, MSE = 1.5232e-01
# Theta | train2 -> R² = 0.2595, MSE = 1.6907e-01
# X | train2 -> R² = -0.1420, MSE = 9.6225e-02
# Y | train2 -> R² = -0.7935, MSE = 1.9312e-01
# Theta | test1 -> R² = 0.6853, MSE = 7.2289e-02
# X | test1 -> R² = -0.0717, MSE = 1.1227e-01
# Y | test1 -> R² = -1.2027, MSE = 1.8051e-01
# Theta | test2 -> R² = 0.2987, MSE = 1.6632e-01
# X | test2 -> R² = -0.0792, MSE = 8.8811e-02
# Y | test2 -> R² = -1.0481, MSE = 2.1739e-01
# Theta | test3 -> R² = 0.6774, MSE = 1.0607e-01
# X | test3 -> R² = -0.0851, MSE = 9.9833e-02
# Y | test3 -> R² = -1.5108, MSE = 1.9285e-01
# Theta | val -> R² = 0.7545, MSE = 8.0357e-02
# X | val -> R² = -0.0491, MSE = 1.0032e-01
# Y | val -> R² = -1.5647, MSE = 1.9094e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.521035 | Val Loss 0.754915
# Epoch 100 | Train Loss 1.270889 | Val Loss 0.716907
# Epoch 200 | Train Loss 1.245138 | Val Loss 0.703120
# Epoch 300 | Train Loss 1.193860 | Val Loss 0.684893
# Epoch 400 | Train Loss 1.149745 | Val Loss 0.717011
# Epoch 500 | Train Loss 1.116610 | Val Loss 0.766354
# Epoch 600 | Train Loss 1.090503 | Val Loss 0.782558
# Epoch 700 | Train Loss 1.065858 | Val Loss 0.794011
# Early stopping at epoch 784
# Theta | train1 -> R² = 0.8230, MSE = 4.0407e-02
# X | train1 -> R² = -0.0829, MSE = 1.1676e-01
# Y | train1 -> R² = -0.8264, MSE = 1.5304e-01
# Theta | train2 -> R² = 0.1170, MSE = 2.0160e-01
# X | train2 -> R² = -0.1263, MSE = 9.4905e-02
# Y | train2 -> R² = -0.8365, MSE = 1.9775e-01
# Theta | test1 -> R² = 0.7447, MSE = 5.8646e-02
# X | test1 -> R² = -0.0528, MSE = 1.1029e-01
# Y | test1 -> R² = -1.1695, MSE = 1.7779e-01
# Theta | test2 -> R² = 0.1875, MSE = 1.9270e-01
# X | test2 -> R² = -0.0895, MSE = 8.9662e-02
# Y | test2 -> R² = -1.0328, MSE = 2.1577e-01
# Theta | test3 -> R² = 0.3802, MSE = 2.0377e-01
# X | test3 -> R² = -0.1146, MSE = 1.0254e-01
# Y | test3 -> R² = -1.5235, MSE = 1.9382e-01
# Theta | val -> R² = 0.6467, MSE = 1.1561e-01
# X | val -> R² = -0.0864, MSE = 1.0389e-01
# Y | val -> R² = -1.6216, MSE = 1.9518e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.633459 | Val Loss 0.786176
# Epoch 100 | Train Loss 1.271570 | Val Loss 0.716445
# Epoch 200 | Train Loss 1.261546 | Val Loss 0.715411
# Epoch 300 | Train Loss 1.210249 | Val Loss 0.686880
# Epoch 400 | Train Loss 1.172049 | Val Loss 0.686866
# Epoch 500 | Train Loss 1.134726 | Val Loss 0.721794
# Epoch 600 | Train Loss 1.103208 | Val Loss 0.748402
# Epoch 700 | Train Loss 1.074311 | Val Loss 0.774090
# Epoch 800 | Train Loss 1.044905 | Val Loss 0.810099
# Early stopping at epoch 849
# Theta | train1 -> R² = 0.7767, MSE = 5.0983e-02
# X | train1 -> R² = -0.0881, MSE = 1.1733e-01
# Y | train1 -> R² = -0.8279, MSE = 1.5317e-01
# Theta | train2 -> R² = 0.2831, MSE = 1.6368e-01
# X | train2 -> R² = -0.1084, MSE = 9.3391e-02
# Y | train2 -> R² = -0.7975, MSE = 1.9355e-01
# Theta | test1 -> R² = 0.6976, MSE = 6.9464e-02
# X | test1 -> R² = -0.0361, MSE = 1.0854e-01
# Y | test1 -> R² = -1.2721, MSE = 1.8620e-01
# Theta | test2 -> R² = 0.2734, MSE = 1.7233e-01
# X | test2 -> R² = -0.0490, MSE = 8.6325e-02
# Y | test2 -> R² = -1.0656, MSE = 2.1925e-01
# Theta | test3 -> R² = -0.3888, MSE = 4.5656e-01
# X | test3 -> R² = 0.0695, MSE = 8.5613e-02
# Y | test3 -> R² = -1.5973, MSE = 1.9949e-01
# Theta | val -> R² = 0.3592, MSE = 2.0973e-01
# X | val -> R² = 0.0582, MSE = 9.0056e-02
# Y | val -> R² = -1.7146, MSE = 2.0210e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.589878 | Val Loss 0.775158
# Epoch 100 | Train Loss 1.271077 | Val Loss 0.716114
# Epoch 200 | Train Loss 1.252908 | Val Loss 0.706976
# Epoch 300 | Train Loss 1.204778 | Val Loss 0.687335
# Epoch 400 | Train Loss 1.166406 | Val Loss 0.714266
# Epoch 500 | Train Loss 1.130938 | Val Loss 0.758812
# Epoch 600 | Train Loss 1.105444 | Val Loss 0.778908
# Epoch 700 | Train Loss 1.079295 | Val Loss 0.796973
# Early stopping at epoch 778
# Theta | train1 -> R² = 0.8044, MSE = 4.4647e-02
# X | train1 -> R² = -0.1017, MSE = 1.1879e-01
# Y | train1 -> R² = -0.8451, MSE = 1.5461e-01
# Theta | train2 -> R² = 0.2556, MSE = 1.6995e-01
# X | train2 -> R² = -0.1559, MSE = 9.7394e-02
# Y | train2 -> R² = -0.7700, MSE = 1.9059e-01
# Theta | test1 -> R² = 0.6682, MSE = 7.6227e-02
# X | test1 -> R² = -0.0744, MSE = 1.1255e-01
# Y | test1 -> R² = -1.2959, MSE = 1.8814e-01
# Theta | test2 -> R² = 0.3176, MSE = 1.6183e-01
# X | test2 -> R² = -0.0933, MSE = 8.9971e-02
# Y | test2 -> R² = -0.9696, MSE = 2.0906e-01
# Theta | test3 -> R² = 0.2038, MSE = 2.6174e-01
# X | test3 -> R² = -0.1377, MSE = 1.0468e-01
# Y | test3 -> R² = -1.1717, MSE = 1.6680e-01
# Theta | val -> R² = 0.5054, MSE = 1.6186e-01
# X | val -> R² = -0.1387, MSE = 1.0888e-01
# Y | val -> R² = -1.3711, MSE = 1.7653e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.599307 | Val Loss 0.778221
# Epoch 100 | Train Loss 1.270817 | Val Loss 0.716327
# Epoch 200 | Train Loss 1.249730 | Val Loss 0.707958
# Epoch 300 | Train Loss 1.194925 | Val Loss 0.686453
# Epoch 400 | Train Loss 1.153111 | Val Loss 0.705488
# Epoch 500 | Train Loss 1.121002 | Val Loss 0.735192
# Epoch 600 | Train Loss 1.094225 | Val Loss 0.776433
# Epoch 700 | Train Loss 1.069268 | Val Loss 0.816563
# Early stopping at epoch 789
# Theta | train1 -> R² = 0.8439, MSE = 3.5639e-02
# X | train1 -> R² = -0.1084, MSE = 1.1952e-01
# Y | train1 -> R² = -0.8393, MSE = 1.5412e-01
# Theta | train2 -> R² = 0.1807, MSE = 1.8705e-01
# X | train2 -> R² = -0.1338, MSE = 9.5538e-02
# Y | train2 -> R² = -0.7875, MSE = 1.9247e-01
# Theta | test1 -> R² = 0.7609, MSE = 5.4931e-02
# X | test1 -> R² = -0.0967, MSE = 1.1489e-01
# Y | test1 -> R² = -1.2555, MSE = 1.8484e-01
# Theta | test2 -> R² = 0.2137, MSE = 1.8649e-01
# X | test2 -> R² = -0.0628, MSE = 8.7460e-02
# Y | test2 -> R² = -1.0097, MSE = 2.1331e-01
# Theta | test3 -> R² = 0.5596, MSE = 1.4478e-01
# X | test3 -> R² = -0.0536, MSE = 9.6935e-02
# Y | test3 -> R² = -1.2823, MSE = 1.7530e-01
# Theta | val -> R² = 0.7404, MSE = 8.4946e-02
# X | val -> R² = -0.0357, MSE = 9.9033e-02
# Y | val -> R² = -1.4451, MSE = 1.8203e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.624452 | Val Loss 0.794595
# Epoch 100 | Train Loss 1.271228 | Val Loss 0.716273
# Epoch 200 | Train Loss 1.257463 | Val Loss 0.713477
# Epoch 300 | Train Loss 1.207216 | Val Loss 0.689245
# Epoch 400 | Train Loss 1.174029 | Val Loss 0.691064
# Epoch 500 | Train Loss 1.140471 | Val Loss 0.726879
# Epoch 600 | Train Loss 1.113723 | Val Loss 0.761488
# Epoch 700 | Train Loss 1.087468 | Val Loss 0.785006
# Epoch 800 | Train Loss 1.061185 | Val Loss 0.793964
# Early stopping at epoch 841
# Theta | train1 -> R² = 0.7427, MSE = 5.8726e-02
# X | train1 -> R² = -0.1002, MSE = 1.1863e-01
# Y | train1 -> R² = -0.8058, MSE = 1.5132e-01
# Theta | train2 -> R² = 0.1554, MSE = 1.9283e-01
# X | train2 -> R² = -0.1533, MSE = 9.7180e-02
# Y | train2 -> R² = -0.7885, MSE = 1.9258e-01
# Theta | test1 -> R² = 0.6161, MSE = 8.8197e-02
# X | test1 -> R² = -0.0888, MSE = 1.1407e-01
# Y | test1 -> R² = -1.2072, MSE = 1.8088e-01
# Theta | test2 -> R² = 0.2140, MSE = 1.8641e-01
# X | test2 -> R² = -0.0783, MSE = 8.8733e-02
# Y | test2 -> R² = -1.0289, MSE = 2.1535e-01
# Theta | test3 -> R² = 0.4286, MSE = 1.8785e-01
# X | test3 -> R² = -0.0228, MSE = 9.4101e-02
# Y | test3 -> R² = -1.4139, MSE = 1.8540e-01
# Theta | val -> R² = 0.6916, MSE = 1.0093e-01
# X | val -> R² = 0.0036, MSE = 9.5277e-02
# Y | val -> R² = -1.6882, MSE = 2.0014e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.598514 | Val Loss 0.795704
# Epoch 100 | Train Loss 1.271694 | Val Loss 0.716408
# Epoch 200 | Train Loss 1.259706 | Val Loss 0.712313
# Epoch 300 | Train Loss 1.207620 | Val Loss 0.686872
# Epoch 400 | Train Loss 1.167145 | Val Loss 0.695775
# Epoch 500 | Train Loss 1.130201 | Val Loss 0.733198
# Epoch 600 | Train Loss 1.099205 | Val Loss 0.772712
# Epoch 700 | Train Loss 1.073943 | Val Loss 0.817550
# Epoch 800 | Train Loss 1.052098 | Val Loss 0.861791
# Early stopping at epoch 815
# Theta | train1 -> R² = 0.8181, MSE = 4.1515e-02
# X | train1 -> R² = -0.1251, MSE = 1.2132e-01
# Y | train1 -> R² = -0.8318, MSE = 1.5350e-01
# Theta | train2 -> R² = 0.1668, MSE = 1.9023e-01
# X | train2 -> R² = -0.1490, MSE = 9.6812e-02
# Y | train2 -> R² = -0.8211, MSE = 1.9609e-01
# Theta | test1 -> R² = 0.7174, MSE = 6.4918e-02
# X | test1 -> R² = -0.0742, MSE = 1.1253e-01
# Y | test1 -> R² = -1.2234, MSE = 1.8220e-01
# Theta | test2 -> R² = 0.2563, MSE = 1.7637e-01
# X | test2 -> R² = -0.0752, MSE = 8.8479e-02
# Y | test2 -> R² = -1.0810, MSE = 2.2088e-01
# Theta | test3 -> R² = 0.6542, MSE = 1.1368e-01
# X | test3 -> R² = -0.1183, MSE = 1.0289e-01
# Y | test3 -> R² = -1.9137, MSE = 2.2379e-01
# Theta | val -> R² = 0.7446, MSE = 8.3572e-02
# X | val -> R² = -0.0768, MSE = 1.0297e-01
# Y | val -> R² = -1.9672, MSE = 2.2091e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.538704 | Val Loss 0.748752
# Epoch 100 | Train Loss 1.267991 | Val Loss 0.714495
# Epoch 200 | Train Loss 1.211578 | Val Loss 0.685473
# Epoch 300 | Train Loss 1.165741 | Val Loss 0.686886
# Epoch 400 | Train Loss 1.128862 | Val Loss 0.707856
# Epoch 500 | Train Loss 1.095463 | Val Loss 0.731402
# Epoch 600 | Train Loss 1.068744 | Val Loss 0.767947
# Epoch 700 | Train Loss 1.043153 | Val Loss 0.834719
# Early stopping at epoch 788
# Theta | train1 -> R² = 0.9184, MSE = 1.8638e-02
# X | train1 -> R² = 0.1585, MSE = 9.0740e-02
# Y | train1 -> R² = -1.3278, MSE = 1.9506e-01
# Theta | train2 -> R² = -0.3526, MSE = 3.0880e-01
# X | train2 -> R² = 0.0379, MSE = 8.1064e-02
# Y | train2 -> R² = -1.4357, MSE = 2.6228e-01
# Theta | test1 -> R² = 0.9086, MSE = 2.0997e-02
# X | test1 -> R² = 0.1715, MSE = 8.6795e-02
# Y | test1 -> R² = -1.8030, MSE = 2.2970e-01
# Theta | test2 -> R² = -0.4170, MSE = 3.3606e-01
# X | test2 -> R² = 0.0064, MSE = 8.1763e-02
# Y | test2 -> R² = -1.7191, MSE = 2.8861e-01
# Theta | test3 -> R² = 0.5006, MSE = 1.6417e-01
# X | test3 -> R² = 0.2800, MSE = 6.6239e-02
# Y | test3 -> R² = -2.8314, MSE = 2.9428e-01
# Theta | val -> R² = 0.7325, MSE = 8.7546e-02
# X | val -> R² = 0.2986, MSE = 6.7072e-02
# Y | val -> R² = -2.7681, MSE = 2.8053e-01
# Figura salva em: ./results/model_264_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.622333 | Val Loss 0.772612
# Epoch 100 | Train Loss 1.268165 | Val Loss 0.715523
# Epoch 200 | Train Loss 1.214072 | Val Loss 0.692407
# Epoch 300 | Train Loss 1.171870 | Val Loss 0.694463
# Epoch 400 | Train Loss 1.134462 | Val Loss 0.719959
# Epoch 500 | Train Loss 1.104473 | Val Loss 0.762773
# Epoch 600 | Train Loss 1.077807 | Val Loss 0.820813
# Epoch 700 | Train Loss 1.051994 | Val Loss 0.878847
# Early stopping at epoch 717
# Theta | train1 -> R² = 0.8537, MSE = 3.3391e-02
# X | train1 -> R² = -0.0873, MSE = 1.1724e-01
# Y | train1 -> R² = -0.9375, MSE = 1.6236e-01
# Theta | train2 -> R² = 0.1370, MSE = 1.9702e-01
# X | train2 -> R² = -0.1335, MSE = 9.5508e-02
# Y | train2 -> R² = -0.7996, MSE = 1.9378e-01
# Theta | test1 -> R² = 0.7976, MSE = 4.6505e-02
# X | test1 -> R² = -0.0438, MSE = 1.0935e-01
# Y | test1 -> R² = -1.3885, MSE = 1.9573e-01
# Theta | test2 -> R² = 0.1164, MSE = 2.0955e-01
# X | test2 -> R² = -0.0608, MSE = 8.7300e-02
# Y | test2 -> R² = -1.0548, MSE = 2.1811e-01
# Theta | test3 -> R² = 0.3658, MSE = 2.0848e-01
# X | test3 -> R² = -0.0166, MSE = 9.3534e-02
# Y | test3 -> R² = -1.5231, MSE = 1.9379e-01
# Theta | val -> R² = 0.6075, MSE = 1.2844e-01
# X | val -> R² = 0.0019, MSE = 9.5445e-02
# Y | val -> R² = -1.7665, MSE = 2.0597e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.664975 | Val Loss 0.777778
# Epoch 100 | Train Loss 1.269499 | Val Loss 0.715862
# Epoch 200 | Train Loss 1.227941 | Val Loss 0.698823
# Epoch 300 | Train Loss 1.176142 | Val Loss 0.693398
# Epoch 400 | Train Loss 1.141562 | Val Loss 0.706875
# Epoch 500 | Train Loss 1.109526 | Val Loss 0.737025
# Epoch 600 | Train Loss 1.080194 | Val Loss 0.778701
# Epoch 700 | Train Loss 1.050514 | Val Loss 0.822750
# Early stopping at epoch 758
# Theta | train1 -> R² = 0.9068, MSE = 2.1266e-02
# X | train1 -> R² = -0.0557, MSE = 1.1383e-01
# Y | train1 -> R² = -0.8839, MSE = 1.5786e-01
# Theta | train2 -> R² = -0.1400, MSE = 2.6027e-01
# X | train2 -> R² = -0.1312, MSE = 9.5313e-02
# Y | train2 -> R² = -0.8228, MSE = 1.9627e-01
# Theta | test1 -> R² = 0.8548, MSE = 3.3358e-02
# X | test1 -> R² = -0.0278, MSE = 1.0767e-01
# Y | test1 -> R² = -1.2167, MSE = 1.8165e-01
# Theta | test2 -> R² = -0.1295, MSE = 2.6787e-01
# X | test2 -> R² = -0.0722, MSE = 8.8236e-02
# Y | test2 -> R² = -1.0141, MSE = 2.1378e-01
# Theta | test3 -> R² = 0.5263, MSE = 1.5573e-01
# X | test3 -> R² = -0.0355, MSE = 9.5270e-02
# Y | test3 -> R² = -1.4093, MSE = 1.8505e-01
# Theta | val -> R² = 0.7069, MSE = 9.5921e-02
# X | val -> R² = 0.0457, MSE = 9.1251e-02
# Y | val -> R² = -1.6495, MSE = 1.9726e-01
# Figura salva em: ./results/model_264_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.631236 | Val Loss 0.754564
# Epoch 100 | Train Loss 1.268620 | Val Loss 0.715199
# Epoch 200 | Train Loss 1.218423 | Val Loss 0.695764
# Epoch 300 | Train Loss 1.169190 | Val Loss 0.698852
# Epoch 400 | Train Loss 1.125532 | Val Loss 0.728777
# Epoch 500 | Train Loss 1.094065 | Val Loss 0.757756
# Epoch 600 | Train Loss 1.067983 | Val Loss 0.795559
# Epoch 700 | Train Loss 1.039043 | Val Loss 0.826992
# Early stopping at epoch 730
# Theta | train1 -> R² = 0.8900, MSE = 2.5119e-02
# X | train1 -> R² = -0.0589, MSE = 1.1418e-01
# Y | train1 -> R² = -0.8609, MSE = 1.5593e-01
# Theta | train2 -> R² = -0.6007, MSE = 3.6545e-01
# X | train2 -> R² = -0.0793, MSE = 9.0939e-02
# Y | train2 -> R² = -0.7928, MSE = 1.9304e-01
# Theta | test1 -> R² = 0.9023, MSE = 2.2433e-02
# X | test1 -> R² = -0.0157, MSE = 1.0640e-01
# Y | test1 -> R² = -1.2663, MSE = 1.8572e-01
# Theta | test2 -> R² = -0.6748, MSE = 3.9720e-01
# X | test2 -> R² = -0.0287, MSE = 8.4654e-02
# Y | test2 -> R² = -1.0508, MSE = 2.1768e-01
# Theta | test3 -> R² = 0.7680, MSE = 7.6275e-02
# X | test3 -> R² = -0.0725, MSE = 9.8674e-02
# Y | test3 -> R² = -1.1918, MSE = 1.6835e-01
# Theta | val -> R² = 0.6715, MSE = 1.0751e-01
# X | val -> R² = -0.0327, MSE = 9.8752e-02
# Y | val -> R² = -1.4567, MSE = 1.8290e-01
# Figura salva em: ./results/model_264_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.577972 | Val Loss 0.741868
# Epoch 100 | Train Loss 1.269968 | Val Loss 0.716023
# Epoch 200 | Train Loss 1.229280 | Val Loss 0.697872
# Epoch 300 | Train Loss 1.180809 | Val Loss 0.687014
# Epoch 400 | Train Loss 1.141040 | Val Loss 0.712419
# Epoch 500 | Train Loss 1.111037 | Val Loss 0.745047
# Epoch 600 | Train Loss 1.083049 | Val Loss 0.785658
# Epoch 700 | Train Loss 1.055017 | Val Loss 0.811718
# Epoch 800 | Train Loss 1.026276 | Val Loss 0.823847
# Early stopping at epoch 816
# Theta | train1 -> R² = 0.8017, MSE = 4.5268e-02
# X | train1 -> R² = 0.2687, MSE = 7.8849e-02
# Y | train1 -> R² = -0.9395, MSE = 1.6252e-01
# Theta | train2 -> R² = 0.1155, MSE = 2.0194e-01
# X | train2 -> R² = 0.1638, MSE = 7.0456e-02
# Y | train2 -> R² = -1.0002, MSE = 2.1538e-01
# Theta | test1 -> R² = 0.7468, MSE = 5.8153e-02
# X | test1 -> R² = 0.3057, MSE = 7.2733e-02
# Y | test1 -> R² = -1.3810, MSE = 1.9512e-01
# Theta | test2 -> R² = 0.1204, MSE = 2.0861e-01
# X | test2 -> R² = 0.0806, MSE = 7.5661e-02
# Y | test2 -> R² = -1.2717, MSE = 2.4112e-01
# Theta | test3 -> R² = 0.4372, MSE = 1.8500e-01
# X | test3 -> R² = 0.3203, MSE = 6.2534e-02
# Y | test3 -> R² = -2.8177, MSE = 2.9323e-01
# Theta | val -> R² = 0.1138, MSE = 2.9005e-01
# X | val -> R² = 0.2928, MSE = 6.7623e-02
# Y | val -> R² = -2.7512, MSE = 2.7928e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.607795 | Val Loss 0.760689
# Epoch 100 | Train Loss 1.269576 | Val Loss 0.715406
# Epoch 200 | Train Loss 1.224026 | Val Loss 0.694738
# Epoch 300 | Train Loss 1.176138 | Val Loss 0.702417
# Epoch 400 | Train Loss 1.135047 | Val Loss 0.749993
# Epoch 500 | Train Loss 1.101441 | Val Loss 0.789682
# Epoch 600 | Train Loss 1.079911 | Val Loss 0.795094
# Epoch 700 | Train Loss 1.047434 | Val Loss 0.842287
# Early stopping at epoch 788
# Theta | train1 -> R² = 0.7888, MSE = 4.8221e-02
# X | train1 -> R² = 0.2928, MSE = 7.6253e-02
# Y | train1 -> R² = -1.2241, MSE = 1.8637e-01
# Theta | train2 -> R² = 0.1708, MSE = 1.8930e-01
# X | train2 -> R² = 0.1584, MSE = 7.0914e-02
# Y | train2 -> R² = -1.2660, MSE = 2.4400e-01
# Theta | test1 -> R² = 0.7557, MSE = 5.6118e-02
# X | test1 -> R² = 0.3272, MSE = 7.0483e-02
# Y | test1 -> R² = -1.7084, MSE = 2.2195e-01
# Theta | test2 -> R² = 0.1175, MSE = 2.0930e-01
# X | test2 -> R² = 0.0746, MSE = 7.6153e-02
# Y | test2 -> R² = -1.5712, MSE = 2.7292e-01
# Theta | test3 -> R² = 0.5552, MSE = 1.4623e-01
# X | test3 -> R² = 0.3159, MSE = 6.2936e-02
# Y | test3 -> R² = -2.8843, MSE = 2.9834e-01
# Theta | val -> R² = 0.7403, MSE = 8.4999e-02
# X | val -> R² = 0.2868, MSE = 6.8201e-02
# Y | val -> R² = -2.9565, MSE = 2.9456e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.535332 | Val Loss 0.747130
# Epoch 100 | Train Loss 1.267931 | Val Loss 0.713966
# Epoch 200 | Train Loss 1.219423 | Val Loss 0.689524
# Epoch 300 | Train Loss 1.172365 | Val Loss 0.695370
# Epoch 400 | Train Loss 1.128545 | Val Loss 0.755056
# Epoch 500 | Train Loss 1.096118 | Val Loss 0.784883
# Epoch 600 | Train Loss 1.068616 | Val Loss 0.799254
# Epoch 700 | Train Loss 1.042681 | Val Loss 0.816083
# Early stopping at epoch 724
# Theta | train1 -> R² = 0.9037, MSE = 2.1971e-02
# X | train1 -> R² = -0.0717, MSE = 1.1556e-01
# Y | train1 -> R² = -0.8106, MSE = 1.5172e-01
# Theta | train2 -> R² = -0.1613, MSE = 2.6513e-01
# X | train2 -> R² = -0.1486, MSE = 9.6780e-02
# Y | train2 -> R² = -0.8022, MSE = 1.9405e-01
# Theta | test1 -> R² = 0.8667, MSE = 3.0620e-02
# X | test1 -> R² = -0.0152, MSE = 1.0635e-01
# Y | test1 -> R² = -1.1693, MSE = 1.7777e-01
# Theta | test2 -> R² = -0.1252, MSE = 2.6685e-01
# X | test2 -> R² = -0.0825, MSE = 8.9083e-02
# Y | test2 -> R² = -1.0127, MSE = 2.1363e-01
# Theta | test3 -> R² = 0.7465, MSE = 8.3324e-02
# X | test3 -> R² = -0.1951, MSE = 1.0996e-01
# Y | test3 -> R² = -1.2425, MSE = 1.7224e-01
# Theta | val -> R² = 0.7246, MSE = 9.0131e-02
# X | val -> R² = -0.1207, MSE = 1.0716e-01
# Y | val -> R² = -1.3299, MSE = 1.7346e-01
# Figura salva em: ./results/model_264_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.627980 | Val Loss 0.774573
# Epoch 100 | Train Loss 1.269417 | Val Loss 0.716157
# Epoch 200 | Train Loss 1.222698 | Val Loss 0.696558
# Epoch 300 | Train Loss 1.171050 | Val Loss 0.690599
# Epoch 400 | Train Loss 1.132270 | Val Loss 0.709493
# Epoch 500 | Train Loss 1.103399 | Val Loss 0.753790
# Epoch 600 | Train Loss 1.076466 | Val Loss 0.764381
# Epoch 700 | Train Loss 1.052939 | Val Loss 0.779742
# Early stopping at epoch 747
# Theta | train1 -> R² = 0.9090, MSE = 2.0769e-02
# X | train1 -> R² = -0.0785, MSE = 1.1629e-01
# Y | train1 -> R² = -0.8363, MSE = 1.5387e-01
# Theta | train2 -> R² = -0.5330, MSE = 3.4999e-01
# X | train2 -> R² = -0.1308, MSE = 9.5278e-02
# Y | train2 -> R² = -0.8426, MSE = 1.9841e-01
# Theta | test1 -> R² = 0.9087, MSE = 2.0969e-02
# X | test1 -> R² = -0.0505, MSE = 1.1005e-01
# Y | test1 -> R² = -1.2287, MSE = 1.8264e-01
# Theta | test2 -> R² = -0.4922, MSE = 3.5389e-01
# X | test2 -> R² = -0.0681, MSE = 8.7899e-02
# Y | test2 -> R² = -1.0948, MSE = 2.2234e-01
# Theta | test3 -> R² = 0.6964, MSE = 9.9804e-02
# X | test3 -> R² = -0.2450, MSE = 1.1455e-01
# Y | test3 -> R² = -1.0572, MSE = 1.5801e-01
# Theta | val -> R² = 0.7177, MSE = 9.2388e-02
# X | val -> R² = -0.1391, MSE = 1.0893e-01
# Y | val -> R² = -1.2135, MSE = 1.6479e-01
# Figura salva em: ./results/model_264_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.638179 | Val Loss 0.754698
# Epoch 100 | Train Loss 1.270249 | Val Loss 0.715312
# Epoch 200 | Train Loss 1.234295 | Val Loss 0.694740
# Epoch 300 | Train Loss 1.186875 | Val Loss 0.683422
# Epoch 400 | Train Loss 1.144008 | Val Loss 0.718062
# Epoch 500 | Train Loss 1.106861 | Val Loss 0.761395
# Epoch 600 | Train Loss 1.080788 | Val Loss 0.816883
# Epoch 700 | Train Loss 1.052238 | Val Loss 0.816292
# Early stopping at epoch 783
# Theta | train1 -> R² = 0.8553, MSE = 3.3040e-02
# X | train1 -> R² = 0.0533, MSE = 1.0208e-01
# Y | train1 -> R² = -0.8506, MSE = 1.5508e-01
# Theta | train2 -> R² = -0.9798, MSE = 4.5199e-01
# X | train2 -> R² = -0.0421, MSE = 8.7804e-02
# Y | train2 -> R² = -0.8538, MSE = 1.9961e-01
# Theta | test1 -> R² = 0.8793, MSE = 2.7738e-02
# X | test1 -> R² = 0.1067, MSE = 9.3586e-02
# Y | test1 -> R² = -1.2653, MSE = 1.8564e-01
# Theta | test2 -> R² = -0.9972, MSE = 4.7365e-01
# X | test2 -> R² = -0.0002, MSE = 8.2307e-02
# Y | test2 -> R² = -1.1194, MSE = 2.2496e-01
# Theta | test3 -> R² = 0.7218, MSE = 9.1449e-02
# X | test3 -> R² = 0.1196, MSE = 8.0996e-02
# Y | test3 -> R² = -1.4924, MSE = 1.9143e-01
# Theta | val -> R² = 0.5627, MSE = 1.4311e-01
# X | val -> R² = 0.1378, MSE = 8.2448e-02
# Y | val -> R² = -1.6115, MSE = 1.9443e-01
# Figura salva em: ./results/model_264_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.652083 | Val Loss 0.765216
# Epoch 100 | Train Loss 1.270159 | Val Loss 0.715378
# Epoch 200 | Train Loss 1.237091 | Val Loss 0.697921
# Epoch 300 | Train Loss 1.188744 | Val Loss 0.685511
# Epoch 400 | Train Loss 1.143669 | Val Loss 0.706214
# Epoch 500 | Train Loss 1.108119 | Val Loss 0.733069
# Epoch 600 | Train Loss 1.078675 | Val Loss 0.761233
# Epoch 700 | Train Loss 1.051103 | Val Loss 0.794934
# Epoch 800 | Train Loss 1.024224 | Val Loss 0.833663
# Early stopping at epoch 845
# Theta | train1 -> R² = 0.7893, MSE = 4.8091e-02
# X | train1 -> R² = 0.3247, MSE = 7.2818e-02
# Y | train1 -> R² = -1.3617, MSE = 1.9790e-01
# Theta | train2 -> R² = -1.7384, MSE = 6.2518e-01
# X | train2 -> R² = 0.1623, MSE = 7.0588e-02
# Y | train2 -> R² = -1.4527, MSE = 2.6410e-01
# Theta | test1 -> R² = 0.9030, MSE = 2.2283e-02
# X | test1 -> R² = 0.3403, MSE = 6.9112e-02
# Y | test1 -> R² = -1.8189, MSE = 2.3101e-01
# Theta | test2 -> R² = -1.5944, MSE = 6.1530e-01
# X | test2 -> R² = 0.0669, MSE = 7.6786e-02
# Y | test2 -> R² = -1.7924, MSE = 2.9639e-01
# Theta | test3 -> R² = 0.6612, MSE = 1.1138e-01
# X | test3 -> R² = 0.2632, MSE = 6.7787e-02
# Y | test3 -> R² = -3.1751, MSE = 3.2068e-01
# Theta | val -> R² = 0.6360, MSE = 1.1912e-01
# X | val -> R² = 0.2734, MSE = 6.9482e-02
# Y | val -> R² = -3.1863, MSE = 3.1167e-01
# Figura salva em: ./results/model_264_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.567719 | Val Loss 0.801292
# Epoch 100 | Train Loss 1.434777 | Val Loss 0.757903
# Epoch 200 | Train Loss 1.292172 | Val Loss 0.721757
# Epoch 300 | Train Loss 1.270285 | Val Loss 0.724064
# Epoch 400 | Train Loss 1.262725 | Val Loss 0.719498
# Epoch 500 | Train Loss 1.253958 | Val Loss 0.715331
# Epoch 600 | Train Loss 1.245498 | Val Loss 0.710682
# Epoch 700 | Train Loss 1.235705 | Val Loss 0.706451
# Epoch 800 | Train Loss 1.226316 | Val Loss 0.704221
# Epoch 900 | Train Loss 1.216737 | Val Loss 0.706443
# Epoch 1000 | Train Loss 1.207327 | Val Loss 0.715305
# Epoch 1100 | Train Loss 1.199408 | Val Loss 0.728589
# Epoch 1200 | Train Loss 1.193290 | Val Loss 0.742058
# Early stopping at epoch 1285
# Theta | train1 -> R² = 0.8624, MSE = 3.1421e-02
# X | train1 -> R² = -0.1876, MSE = 1.2805e-01
# Y | train1 -> R² = -0.7762, MSE = 1.4884e-01
# Theta | train2 -> R² = 0.2974, MSE = 1.6040e-01
# X | train2 -> R² = -0.2116, MSE = 1.0209e-01
# Y | train2 -> R² = -0.8500, MSE = 1.9921e-01
# Theta | test1 -> R² = 0.6556, MSE = 7.9112e-02
# X | test1 -> R² = -0.2375, MSE = 1.2965e-01
# Y | test1 -> R² = -0.9524, MSE = 1.5999e-01
# Theta | test2 -> R² = 0.4327, MSE = 1.3453e-01
# X | test2 -> R² = -0.1658, MSE = 9.5940e-02
# Y | test2 -> R² = -0.7503, MSE = 1.8578e-01
# Theta | test3 -> R² = -0.0106, MSE = 3.3222e-01
# X | test3 -> R² = -0.2250, MSE = 1.1270e-01
# Y | test3 -> R² = -0.2672, MSE = 9.7333e-02
# Theta | val -> R² = 0.3395, MSE = 2.1616e-01
# X | val -> R² = -0.1728, MSE = 1.1215e-01
# Y | val -> R² = -0.4323, MSE = 1.0664e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.569708 | Val Loss 0.802155
# Epoch 100 | Train Loss 1.451609 | Val Loss 0.755946
# Epoch 200 | Train Loss 1.346743 | Val Loss 0.731730
# Epoch 300 | Train Loss 1.269542 | Val Loss 0.725514
# Epoch 400 | Train Loss 1.262136 | Val Loss 0.726743
# Epoch 500 | Train Loss 1.255849 | Val Loss 0.725981
# Epoch 600 | Train Loss 1.250419 | Val Loss 0.725546
# Epoch 700 | Train Loss 1.244578 | Val Loss 0.723202
# Early stopping at epoch 726
# Theta | train1 -> R² = 0.6561, MSE = 7.8492e-02
# X | train1 -> R² = -0.2794, MSE = 1.3796e-01
# Y | train1 -> R² = -1.0905, MSE = 1.7518e-01
# Theta | train2 -> R² = -0.1146, MSE = 2.5447e-01
# X | train2 -> R² = -0.2846, MSE = 1.0824e-01
# Y | train2 -> R² = -1.1598, MSE = 2.3256e-01
# Theta | test1 -> R² = 0.6472, MSE = 8.1046e-02
# X | test1 -> R² = -0.3526, MSE = 1.4170e-01
# Y | test1 -> R² = -1.3044, MSE = 1.8885e-01
# Theta | test2 -> R² = 0.0137, MSE = 2.3391e-01
# X | test2 -> R² = -0.2338, MSE = 1.0153e-01
# Y | test2 -> R² = -1.0473, MSE = 2.1730e-01
# Theta | test3 -> R² = 0.5164, MSE = 1.5899e-01
# X | test3 -> R² = -0.5361, MSE = 1.4133e-01
# Y | test3 -> R² = -2.3412, MSE = 2.5663e-01
# Theta | val -> R² = 0.6081, MSE = 1.2826e-01
# X | val -> R² = -0.5880, MSE = 1.5185e-01
# Y | val -> R² = -2.2874, MSE = 2.4475e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.568827 | Val Loss 0.801473
# Epoch 100 | Train Loss 1.431403 | Val Loss 0.745685
# Epoch 200 | Train Loss 1.281048 | Val Loss 0.724705
# Epoch 300 | Train Loss 1.273208 | Val Loss 0.730640
# Epoch 400 | Train Loss 1.269658 | Val Loss 0.729822
# Epoch 500 | Train Loss 1.265635 | Val Loss 0.728024
# Epoch 600 | Train Loss 1.260071 | Val Loss 0.725645
# Early stopping at epoch 667
# Theta | train1 -> R² = 0.6023, MSE = 9.0783e-02
# X | train1 -> R² = -0.3617, MSE = 1.4682e-01
# Y | train1 -> R² = -1.1568, MSE = 1.8073e-01
# Theta | train2 -> R² = -0.1900, MSE = 2.7167e-01
# X | train2 -> R² = -0.2705, MSE = 1.0706e-01
# Y | train2 -> R² = -1.1587, MSE = 2.3245e-01
# Theta | test1 -> R² = 0.6727, MSE = 7.5193e-02
# X | test1 -> R² = -0.4967, MSE = 1.5679e-01
# Y | test1 -> R² = -1.4476, MSE = 2.0058e-01
# Theta | test2 -> R² = -0.1508, MSE = 2.7293e-01
# X | test2 -> R² = -0.2503, MSE = 1.0289e-01
# Y | test2 -> R² = -1.1030, MSE = 2.2322e-01
# Theta | test3 -> R² = 0.4442, MSE = 1.8273e-01
# X | test3 -> R² = -0.4849, MSE = 1.3661e-01
# Y | test3 -> R² = -1.8563, MSE = 2.1939e-01
# Theta | val -> R² = 0.5664, MSE = 1.4190e-01
# X | val -> R² = -0.5544, MSE = 1.4864e-01
# Y | val -> R² = -1.9338, MSE = 2.1842e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.568506 | Val Loss 0.801965
# Epoch 100 | Train Loss 1.442605 | Val Loss 0.756983
# Epoch 200 | Train Loss 1.297067 | Val Loss 0.720118
# Epoch 300 | Train Loss 1.273503 | Val Loss 0.733123
# Epoch 400 | Train Loss 1.267662 | Val Loss 0.732449
# Epoch 500 | Train Loss 1.260149 | Val Loss 0.729809
# Epoch 600 | Train Loss 1.249480 | Val Loss 0.728332
# Early stopping at epoch 693
# Theta | train1 -> R² = 0.4222, MSE = 1.3190e-01
# X | train1 -> R² = -0.4238, MSE = 1.5353e-01
# Y | train1 -> R² = -1.2018, MSE = 1.8451e-01
# Theta | train2 -> R² = 0.3702, MSE = 1.4379e-01
# X | train2 -> R² = -0.3249, MSE = 1.1164e-01
# Y | train2 -> R² = -1.2962, MSE = 2.4725e-01
# Theta | test1 -> R² = 0.4014, MSE = 1.3751e-01
# X | test1 -> R² = -0.4691, MSE = 1.5391e-01
# Y | test1 -> R² = -1.3736, MSE = 1.9452e-01
# Theta | test2 -> R² = 0.3755, MSE = 1.4811e-01
# X | test2 -> R² = -0.2689, MSE = 1.0442e-01
# Y | test2 -> R² = -1.1713, MSE = 2.3047e-01
# Theta | test3 -> R² = 0.0952, MSE = 2.9744e-01
# X | test3 -> R² = -0.9104, MSE = 1.7576e-01
# Y | test3 -> R² = -3.0433, MSE = 3.1055e-01
# Theta | val -> R² = 0.4550, MSE = 1.7837e-01
# X | val -> R² = -0.9552, MSE = 1.8696e-01
# Y | val -> R² = -2.9070, MSE = 2.9087e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570626 | Val Loss 0.802320
# Epoch 100 | Train Loss 1.451285 | Val Loss 0.759273
# Epoch 200 | Train Loss 1.382794 | Val Loss 0.742703
# Epoch 300 | Train Loss 1.271309 | Val Loss 0.723286
# Epoch 400 | Train Loss 1.266239 | Val Loss 0.723726
# Epoch 500 | Train Loss 1.261840 | Val Loss 0.723317
# Epoch 600 | Train Loss 1.254998 | Val Loss 0.722854
# Epoch 700 | Train Loss 1.247034 | Val Loss 0.722009
# Early stopping at epoch 730
# Theta | train1 -> R² = 0.6141, MSE = 8.8085e-02
# X | train1 -> R² = -0.2946, MSE = 1.3960e-01
# Y | train1 -> R² = -1.0442, MSE = 1.7130e-01
# Theta | train2 -> R² = -0.2350, MSE = 2.8197e-01
# X | train2 -> R² = -0.3057, MSE = 1.1002e-01
# Y | train2 -> R² = -1.1742, MSE = 2.3411e-01
# Theta | test1 -> R² = 0.6843, MSE = 7.2515e-02
# X | test1 -> R² = -0.3624, MSE = 1.4273e-01
# Y | test1 -> R² = -1.2535, MSE = 1.8467e-01
# Theta | test2 -> R² = -0.1672, MSE = 2.7681e-01
# X | test2 -> R² = -0.2461, MSE = 1.0255e-01
# Y | test2 -> R² = -1.0541, MSE = 2.1803e-01
# Theta | test3 -> R² = 0.4557, MSE = 1.7894e-01
# X | test3 -> R² = -0.5192, MSE = 1.3977e-01
# Y | test3 -> R² = -2.1806, MSE = 2.4429e-01
# Theta | val -> R² = 0.5612, MSE = 1.4361e-01
# X | val -> R² = -0.5632, MSE = 1.4948e-01
# Y | val -> R² = -2.1213, MSE = 2.3238e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.568365 | Val Loss 0.800986
# Epoch 100 | Train Loss 1.457012 | Val Loss 0.745296
# Epoch 200 | Train Loss 1.349741 | Val Loss 0.733310
# Epoch 300 | Train Loss 1.272093 | Val Loss 0.731802
# Epoch 400 | Train Loss 1.262629 | Val Loss 0.728093
# Epoch 500 | Train Loss 1.255045 | Val Loss 0.726666
# Epoch 600 | Train Loss 1.248148 | Val Loss 0.726294
# Epoch 700 | Train Loss 1.240811 | Val Loss 0.725486
# Early stopping at epoch 728
# Theta | train1 -> R² = 0.6477, MSE = 8.0425e-02
# X | train1 -> R² = -0.2612, MSE = 1.3599e-01
# Y | train1 -> R² = -1.0622, MSE = 1.7281e-01
# Theta | train2 -> R² = -0.2535, MSE = 2.8618e-01
# X | train2 -> R² = -0.2378, MSE = 1.0430e-01
# ...
# Epoch 0 | Train Loss 1.555271 | Val Loss 0.785436
# Epoch 100 | Train Loss 1.263266 | Val Loss 0.720602
# Epoch 200 | Train Loss 1.190862 | Val Loss 0.710931
# Epoch 300 | Train Loss 1.135255 | Val Loss 0.749304
# Epoch 400 | Train Loss 1.077580 | Val Loss 0.810389
# Epoch 500 | Train Loss 1.030990 | Val Loss 0.842561
# Epoch 600 | Train Loss 0.991441 | Val Loss 0.886565
# Early stopping at epoch 669
# Theta | train1 -> R² = 0.8763, MSE = 2.8228e-02
# X | train1 -> R² = -0.0948, MSE = 1.1805e-01
# Y | train1 -> R² = -0.9096, MSE = 1.6002e-01
# Theta | train2 -> R² = 0.3619, MSE = 1.4569e-01
# X | train2 -> R² = -0.1806, MSE = 9.9481e-02
# Y | train2 -> R² = -0.8715, MSE = 2.0151e-01
# Theta | test1 -> R² = 0.7180, MSE = 6.4790e-02
# X | test1 -> R² = -0.0735, MSE = 1.1246e-01
# Y | test1 -> R² = -1.2613, MSE = 1.8531e-01
# Theta | test2 -> R² = 0.4998, MSE = 1.1864e-01
# X | test2 -> R² = -0.0975, MSE = 9.0319e-02
# Y | test2 -> R² = -0.9381, MSE = 2.0571e-01
# Theta | test3 -> R² = 0.4080, MSE = 1.9461e-01
# X | test3 -> R² = -0.0609, MSE = 9.7606e-02
# Y | test3 -> R² = -3.3362, MSE = 3.3306e-01
# Theta | val -> R² = 0.7373, MSE = 8.5963e-02
# X | val -> R² = -0.0727, MSE = 1.0257e-01
# Y | val -> R² = -3.2612, MSE = 3.1725e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.566470 | Val Loss 0.798226
# Epoch 100 | Train Loss 1.262937 | Val Loss 0.725725
# Epoch 200 | Train Loss 1.197796 | Val Loss 0.718403
# Epoch 300 | Train Loss 1.134816 | Val Loss 0.731741
# Epoch 400 | Train Loss 1.087976 | Val Loss 0.746121
# Epoch 500 | Train Loss 1.040901 | Val Loss 0.771257
# Early stopping at epoch 518
# Theta | train1 -> R² = 0.3659, MSE = 1.4475e-01
# X | train1 -> R² = 0.2344, MSE = 8.2549e-02
# Y | train1 -> R² = -0.7575, MSE = 1.4727e-01
# Theta | train2 -> R² = -0.2356, MSE = 2.8210e-01
# X | train2 -> R² = 0.0358, MSE = 8.1240e-02
# Y | train2 -> R² = -0.8745, MSE = 2.0184e-01
# Theta | test1 -> R² = 0.2613, MSE = 1.6969e-01
# X | test1 -> R² = 0.1545, MSE = 8.8577e-02
# Y | test1 -> R² = -0.9838, MSE = 1.6257e-01
# Theta | test2 -> R² = -0.2678, MSE = 3.0068e-01
# X | test2 -> R² = 0.0342, MSE = 7.9481e-02
# Y | test2 -> R² = -0.8455, MSE = 1.9589e-01
# Theta | test3 -> R² = -1.0377, MSE = 6.6989e-01
# X | test3 -> R² = 0.0339, MSE = 8.8881e-02
# Y | test3 -> R² = -1.1323, MSE = 1.6378e-01
# Theta | val -> R² = -0.4546, MSE = 4.7606e-01
# X | val -> R² = 0.0931, MSE = 8.6719e-02
# Y | val -> R² = -1.1291, MSE = 1.5851e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.556925 | Val Loss 0.793458
# Epoch 100 | Train Loss 1.262588 | Val Loss 0.724670
# Epoch 200 | Train Loss 1.198798 | Val Loss 0.711836
# Epoch 300 | Train Loss 1.138653 | Val Loss 0.758490
# Epoch 400 | Train Loss 1.082551 | Val Loss 0.791263
# Epoch 500 | Train Loss 1.035248 | Val Loss 0.828583
# Epoch 600 | Train Loss 0.990791 | Val Loss 0.926679
# Early stopping at epoch 681
# Theta | train1 -> R² = 0.8984, MSE = 2.3188e-02
# X | train1 -> R² = -0.1121, MSE = 1.1991e-01
# Y | train1 -> R² = -0.8709, MSE = 1.5677e-01
# Theta | train2 -> R² = 0.4381, MSE = 1.2827e-01
# X | train2 -> R² = -0.1909, MSE = 1.0035e-01
# Y | train2 -> R² = -0.7885, MSE = 1.9258e-01
# Theta | test1 -> R² = 0.7040, MSE = 6.7999e-02
# X | test1 -> R² = -0.1371, MSE = 1.1912e-01
# Y | test1 -> R² = -1.1539, MSE = 1.7651e-01
# Theta | test2 -> R² = 0.5622, MSE = 1.0384e-01
# X | test2 -> R² = -0.1397, MSE = 9.3792e-02
# Y | test2 -> R² = -0.8653, MSE = 1.9798e-01
# Theta | test3 -> R² = -0.0862, MSE = 3.5708e-01
# X | test3 -> R² = -0.2661, MSE = 1.1649e-01
# Y | test3 -> R² = -2.9741, MSE = 3.0524e-01
# Theta | val -> R² = 0.7198, MSE = 9.1714e-02
# X | val -> R² = -0.2269, MSE = 1.1732e-01
# Y | val -> R² = -2.8862, MSE = 2.8933e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.582263 | Val Loss 0.748424
# Epoch 100 | Train Loss 1.226087 | Val Loss 0.702783
# Epoch 200 | Train Loss 1.141325 | Val Loss 0.720298
# Epoch 300 | Train Loss 1.056773 | Val Loss 0.753262
# Epoch 400 | Train Loss 0.979207 | Val Loss 0.828029
# Epoch 500 | Train Loss 0.921815 | Val Loss 0.944314
# Epoch 600 | Train Loss 0.881285 | Val Loss 1.068213
# Early stopping at epoch 613
# Theta | train1 -> R² = 0.9058, MSE = 2.1505e-02
# X | train1 -> R² = -0.0344, MSE = 1.1153e-01
# Y | train1 -> R² = -0.8707, MSE = 1.5676e-01
# Theta | train2 -> R² = 0.2594, MSE = 1.6908e-01
# X | train2 -> R² = -0.1673, MSE = 9.8354e-02
# Y | train2 -> R² = -0.8104, MSE = 1.9494e-01
# Theta | test1 -> R² = 0.7819, MSE = 5.0093e-02
# X | test1 -> R² = 0.0129, MSE = 1.0341e-01
# Y | test1 -> R² = -1.2225, MSE = 1.8213e-01
# Theta | test2 -> R² = 0.3633, MSE = 1.5101e-01
# X | test2 -> R² = -0.0844, MSE = 8.9243e-02
# Y | test2 -> R² = -0.9240, MSE = 2.0421e-01
# Theta | test3 -> R² = 0.6153, MSE = 1.2647e-01
# X | test3 -> R² = -0.0571, MSE = 9.7258e-02
# Y | test3 -> R² = -2.5802, MSE = 2.7498e-01
# Theta | val -> R² = 0.7276, MSE = 8.9160e-02
# X | val -> R² = -0.0587, MSE = 1.0123e-01
# Y | val -> R² = -2.6521, MSE = 2.7190e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.549827 | Val Loss 0.763790
# Epoch 100 | Train Loss 1.220142 | Val Loss 0.704536
# Epoch 200 | Train Loss 1.133407 | Val Loss 0.724580
# Epoch 300 | Train Loss 1.049554 | Val Loss 0.767083
# Epoch 400 | Train Loss 0.975986 | Val Loss 0.786420
# Epoch 500 | Train Loss 0.927652 | Val Loss 0.816690
# Epoch 600 | Train Loss 0.895388 | Val Loss 0.867716
# Early stopping at epoch 616
# Theta | train1 -> R² = 0.8246, MSE = 4.0045e-02
# X | train1 -> R² = -0.0589, MSE = 1.1418e-01
# Y | train1 -> R² = -0.8430, MSE = 1.5443e-01
# Theta | train2 -> R² = 0.2446, MSE = 1.7245e-01
# X | train2 -> R² = -0.2080, MSE = 1.0179e-01
# Y | train2 -> R² = -0.7869, MSE = 1.9241e-01
# Theta | test1 -> R² = 0.6846, MSE = 7.2446e-02
# X | test1 -> R² = -0.0596, MSE = 1.1100e-01
# Y | test1 -> R² = -1.2594, MSE = 1.8515e-01
# Theta | test2 -> R² = 0.3776, MSE = 1.4760e-01
# X | test2 -> R² = -0.1070, MSE = 9.1101e-02
# Y | test2 -> R² = -0.9292, MSE = 2.0477e-01
# Theta | test3 -> R² = 0.3782, MSE = 2.0442e-01
# X | test3 -> R² = 0.0228, MSE = 8.9908e-02
# Y | test3 -> R² = -2.6804, MSE = 2.8268e-01
# Theta | val -> R² = 0.7447, MSE = 8.3544e-02
# X | val -> R² = 0.0122, MSE = 9.4453e-02
# Y | val -> R² = -2.7888, MSE = 2.8207e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.545786 | Val Loss 0.778145
# Epoch 100 | Train Loss 1.223284 | Val Loss 0.714828
# Epoch 200 | Train Loss 1.140507 | Val Loss 0.742179
# Epoch 300 | Train Loss 1.063341 | Val Loss 0.785872
# Epoch 400 | Train Loss 1.002937 | Val Loss 0.826632
# Epoch 500 | Train Loss 0.947288 | Val Loss 0.875130
# Early stopping at epoch 533
# Theta | train1 -> R² = 0.8481, MSE = 3.4682e-02
# X | train1 -> R² = 0.0396, MSE = 1.0356e-01
# Y | train1 -> R² = -0.7109, MSE = 1.4337e-01
# Theta | train2 -> R² = 0.5124, MSE = 1.1132e-01
# X | train2 -> R² = -0.1316, MSE = 9.5345e-02
# Y | train2 -> R² = -0.7081, MSE = 1.8393e-01
# Theta | test1 -> R² = 0.7166, MSE = 6.5097e-02
# X | test1 -> R² = -0.0226, MSE = 1.0712e-01
# Y | test1 -> R² = -0.9200, MSE = 1.5734e-01
# Theta | test2 -> R² = 0.5698, MSE = 1.0204e-01
# X | test2 -> R² = -0.1081, MSE = 9.1190e-02
# Y | test2 -> R² = -0.6352, MSE = 1.7357e-01
# Theta | test3 -> R² = 0.5634, MSE = 1.4352e-01
# X | test3 -> R² = -0.0651, MSE = 9.7998e-02
# Y | test3 -> R² = -1.7193, MSE = 2.0886e-01
# Theta | val -> R² = 0.7492, MSE = 8.2081e-02
# X | val -> R² = -0.0778, MSE = 1.0306e-01
# Y | val -> R² = -1.6874, MSE = 2.0008e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.559815 | Val Loss 0.772036
# Epoch 100 | Train Loss 1.220158 | Val Loss 0.696912
# Epoch 200 | Train Loss 1.139417 | Val Loss 0.718706
# Epoch 300 | Train Loss 1.060518 | Val Loss 0.737682
# Epoch 400 | Train Loss 0.995626 | Val Loss 0.742826
# Epoch 500 | Train Loss 0.938967 | Val Loss 0.801870
# Epoch 600 | Train Loss 0.901597 | Val Loss 0.878134
# Early stopping at epoch 610
# Theta | train1 -> R² = 0.2632, MSE = 1.6820e-01
# X | train1 -> R² = -0.1004, MSE = 1.1865e-01
# Y | train1 -> R² = -0.8790, MSE = 1.5745e-01
# Theta | train2 -> R² = 0.6521, MSE = 7.9435e-02
# X | train2 -> R² = -0.2194, MSE = 1.0274e-01
# Y | train2 -> R² = -0.7254, MSE = 1.8579e-01
# Theta | test1 -> R² = -0.0074, MSE = 2.3143e-01
# X | test1 -> R² = -0.1006, MSE = 1.1530e-01
# Y | test1 -> R² = -1.2608, MSE = 1.8527e-01
# Theta | test2 -> R² = 0.6965, MSE = 7.1972e-02
# X | test2 -> R² = -0.1034, MSE = 9.0801e-02
# Y | test2 -> R² = -0.8957, MSE = 2.0121e-01
# Theta | test3 -> R² = -0.9455, MSE = 6.3957e-01
# X | test3 -> R² = 0.0207, MSE = 9.0096e-02
# Y | test3 -> R² = -2.1318, MSE = 2.4055e-01
# Theta | val -> R² = 0.2368, MSE = 2.4978e-01
# X | val -> R² = 0.0279, MSE = 9.2954e-02
# Y | val -> R² = -2.2715, MSE = 2.4356e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.567652 | Val Loss 0.747648
# Epoch 100 | Train Loss 1.222713 | Val Loss 0.697179
# Epoch 200 | Train Loss 1.132886 | Val Loss 0.726855
# Epoch 300 | Train Loss 1.055812 | Val Loss 0.816588
# Epoch 400 | Train Loss 0.991528 | Val Loss 0.905860
# Epoch 500 | Train Loss 0.943995 | Val Loss 1.033052
# Early stopping at epoch 598
# Theta | train1 -> R² = 0.8898, MSE = 2.5156e-02
# X | train1 -> R² = -0.0457, MSE = 1.1275e-01
# Y | train1 -> R² = -0.9011, MSE = 1.5930e-01
# Theta | train2 -> R² = -0.1860, MSE = 2.7077e-01
# X | train2 -> R² = -0.1609, MSE = 9.7814e-02
# Y | train2 -> R² = -0.8092, MSE = 1.9482e-01
# Theta | test1 -> R² = 0.9034, MSE = 2.2186e-02
# X | test1 -> R² = -0.0173, MSE = 1.0658e-01
# Y | test1 -> R² = -1.2697, MSE = 1.8600e-01
# Theta | test2 -> R² = -0.0427, MSE = 2.4729e-01
# X | test2 -> R² = -0.0901, MSE = 8.9711e-02
# Y | test2 -> R² = -0.9425, MSE = 2.0619e-01
# Theta | test3 -> R² = 0.6508, MSE = 1.1481e-01
# X | test3 -> R² = -0.0430, MSE = 9.5959e-02
# Y | test3 -> R² = -2.0517, MSE = 2.3439e-01
# Theta | val -> R² = 0.6696, MSE = 1.0812e-01
# X | val -> R² = -0.0334, MSE = 9.8813e-02
# Y | val -> R² = -2.1837, MSE = 2.3702e-01
# Figura salva em: ./results/model_264_128_64_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.557703 | Val Loss 0.751274
# Epoch 100 | Train Loss 1.220210 | Val Loss 0.702710
# Epoch 200 | Train Loss 1.133358 | Val Loss 0.734837
# Epoch 300 | Train Loss 1.049340 | Val Loss 0.763345
# Epoch 400 | Train Loss 0.975040 | Val Loss 0.858324
# Epoch 500 | Train Loss 0.919848 | Val Loss 0.937430
# Epoch 600 | Train Loss 0.879694 | Val Loss 1.025614
# Early stopping at epoch 605
# Theta | train1 -> R² = 0.7462, MSE = 5.7939e-02
# X | train1 -> R² = -0.0831, MSE = 1.1678e-01
# Y | train1 -> R² = -0.9329, MSE = 1.6197e-01
# Theta | train2 -> R² = 0.5322, MSE = 1.0681e-01
# X | train2 -> R² = -0.1959, MSE = 1.0077e-01
# Y | train2 -> R² = -0.8364, MSE = 1.9774e-01
# Theta | test1 -> R² = 0.5435, MSE = 1.0487e-01
# X | test1 -> R² = -0.0601, MSE = 1.1105e-01
# Y | test1 -> R² = -1.3149, MSE = 1.8970e-01
# Theta | test2 -> R² = 0.6193, MSE = 9.0276e-02
# X | test2 -> R² = -0.1324, MSE = 9.3190e-02
# Y | test2 -> R² = -0.9495, MSE = 2.0693e-01
# Theta | test3 -> R² = 0.4191, MSE = 1.9096e-01
# X | test3 -> R² = 0.0320, MSE = 8.9058e-02
# Y | test3 -> R² = -3.5140, MSE = 3.4671e-01
# Theta | val -> R² = 0.7533, MSE = 8.0733e-02
# X | val -> R² = 0.0248, MSE = 9.3254e-02
# Y | val -> R² = -3.6333, MSE = 3.4495e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.590642 | Val Loss 0.786861
# Epoch 100 | Train Loss 1.226027 | Val Loss 0.698532
# Epoch 200 | Train Loss 1.143478 | Val Loss 0.718472
# Epoch 300 | Train Loss 1.064270 | Val Loss 0.724783
# Epoch 400 | Train Loss 1.023423 | Val Loss 0.752009
# Epoch 500 | Train Loss 0.942402 | Val Loss 0.808524
# Epoch 600 | Train Loss 0.904299 | Val Loss 0.864346
# Early stopping at epoch 608
# Theta | train1 -> R² = 0.8277, MSE = 3.9340e-02
# X | train1 -> R² = -0.0894, MSE = 1.1747e-01
# Y | train1 -> R² = -0.8503, MSE = 1.5505e-01
# Theta | train2 -> R² = 0.3301, MSE = 1.5295e-01
# X | train2 -> R² = -0.2588, MSE = 1.0606e-01
# Y | train2 -> R² = -0.7888, MSE = 1.9262e-01
# Theta | test1 -> R² = 0.6809, MSE = 7.3301e-02
# X | test1 -> R² = -0.0729, MSE = 1.1240e-01
# Y | test1 -> R² = -1.2167, MSE = 1.8166e-01
# Theta | test2 -> R² = 0.4323, MSE = 1.3463e-01
# X | test2 -> R² = -0.0971, MSE = 9.0287e-02
# Y | test2 -> R² = -0.9654, MSE = 2.0861e-01
# Theta | test3 -> R² = 0.4479, MSE = 1.8151e-01
# X | test3 -> R² = -0.0183, MSE = 9.3689e-02
# Y | test3 -> R² = -2.6896, MSE = 2.8339e-01
# Theta | val -> R² = 0.7219, MSE = 9.1029e-02
# X | val -> R² = -0.0427, MSE = 9.9710e-02
# Y | val -> R² = -2.6363, MSE = 2.7072e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572597 | Val Loss 0.759246
# Epoch 100 | Train Loss 1.229252 | Val Loss 0.708785
# Epoch 200 | Train Loss 1.142285 | Val Loss 0.731946
# Epoch 300 | Train Loss 1.064104 | Val Loss 0.760092
# Epoch 400 | Train Loss 0.989593 | Val Loss 0.790168
# Epoch 500 | Train Loss 0.935972 | Val Loss 0.882715
# Epoch 600 | Train Loss 0.895186 | Val Loss 1.001017
# Early stopping at epoch 616
# Theta | train1 -> R² = 0.3803, MSE = 1.4146e-01
# X | train1 -> R² = -0.0134, MSE = 1.0927e-01
# Y | train1 -> R² = -0.7901, MSE = 1.5001e-01
# Theta | train2 -> R² = 0.6689, MSE = 7.5595e-02
# X | train2 -> R² = -0.2220, MSE = 1.0296e-01
# Y | train2 -> R² = -0.8069, MSE = 1.9456e-01
# Theta | test1 -> R² = -0.0329, MSE = 2.3728e-01
# X | test1 -> R² = 0.0312, MSE = 1.0149e-01
# Y | test1 -> R² = -1.2074, MSE = 1.8090e-01
# Theta | test2 -> R² = 0.7035, MSE = 7.0322e-02
# X | test2 -> R² = -0.1169, MSE = 9.1913e-02
# Y | test2 -> R² = -0.8666, MSE = 1.9812e-01
# Theta | test3 -> R² = -0.5352, MSE = 5.0469e-01
# X | test3 -> R² = 0.0865, MSE = 8.4044e-02
# Y | test3 -> R² = -4.3455, MSE = 4.1057e-01
# Theta | val -> R² = 0.6012, MSE = 1.3052e-01
# X | val -> R² = 0.1159, MSE = 8.4540e-02
# Y | val -> R² = -4.2992, MSE = 3.9452e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.573152 | Val Loss 0.775242
# Epoch 100 | Train Loss 1.221485 | Val Loss 0.704830
# Epoch 200 | Train Loss 1.137959 | Val Loss 0.718614
# Epoch 300 | Train Loss 1.059678 | Val Loss 0.738144
# Epoch 400 | Train Loss 1.007561 | Val Loss 0.794820
# Epoch 500 | Train Loss 0.939786 | Val Loss 0.844166
# Epoch 600 | Train Loss 0.895693 | Val Loss 0.899533
# Early stopping at epoch 624
# Theta | train1 -> R² = 0.9225, MSE = 1.7697e-02
# X | train1 -> R² = -0.0121, MSE = 1.0913e-01
# Y | train1 -> R² = -0.9065, MSE = 1.5976e-01
# Theta | train2 -> R² = -0.2388, MSE = 2.8282e-01
# X | train2 -> R² = -0.1850, MSE = 9.9851e-02
# Y | train2 -> R² = -0.8482, MSE = 1.9902e-01
# Theta | test1 -> R² = 0.8876, MSE = 2.5819e-02
# X | test1 -> R² = 0.0272, MSE = 1.0191e-01
# Y | test1 -> R² = -1.2710, MSE = 1.8611e-01
# Theta | test2 -> R² = -0.0230, MSE = 2.4262e-01
# X | test2 -> R² = -0.0961, MSE = 9.0202e-02
# Y | test2 -> R² = -0.9630, MSE = 2.0836e-01
# Theta | test3 -> R² = 0.3090, MSE = 2.2715e-01
# X | test3 -> R² = 0.0733, MSE = 8.5263e-02
# Y | test3 -> R² = -3.5226, MSE = 3.4737e-01
# Theta | val -> R² = 0.6670, MSE = 1.0897e-01
# X | val -> R² = 0.1112, MSE = 8.4988e-02
# Y | val -> R² = -3.4630, MSE = 3.3227e-01
# Figura salva em: ./results/model_264_128_64_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.558225 | Val Loss 0.770637
# Epoch 100 | Train Loss 1.222759 | Val Loss 0.704093
# Epoch 200 | Train Loss 1.137295 | Val Loss 0.735096
# Epoch 300 | Train Loss 1.047039 | Val Loss 0.800986
# Epoch 400 | Train Loss 0.974742 | Val Loss 0.896776
# Epoch 500 | Train Loss 0.921245 | Val Loss 0.958825
# Epoch 600 | Train Loss 0.886906 | Val Loss 1.110863
# Early stopping at epoch 604
# Theta | train1 -> R² = 0.8088, MSE = 4.3640e-02
# X | train1 -> R² = -0.0274, MSE = 1.1078e-01
# Y | train1 -> R² = -0.9025, MSE = 1.5942e-01
# Theta | train2 -> R² = 0.5389, MSE = 1.0526e-01
# X | train2 -> R² = -0.2075, MSE = 1.0174e-01
# Y | train2 -> R² = -0.8489, MSE = 1.9909e-01
# Theta | test1 -> R² = 0.5677, MSE = 9.9314e-02
# X | test1 -> R² = -0.0566, MSE = 1.1069e-01
# Y | test1 -> R² = -1.3304, MSE = 1.9098e-01
# Theta | test2 -> R² = 0.6283, MSE = 8.8158e-02
# X | test2 -> R² = -0.1159, MSE = 9.1834e-02
# Y | test2 -> R² = -0.9706, MSE = 2.0917e-01
# Theta | test3 -> R² = 0.0763, MSE = 3.0366e-01
# X | test3 -> R² = -0.0273, MSE = 9.4518e-02
# Y | test3 -> R² = -4.0939, MSE = 3.9125e-01
# Theta | val -> R² = 0.7006, MSE = 9.7990e-02
# X | val -> R² = -0.0118, MSE = 9.6753e-02
# Y | val -> R² = -3.8864, MSE = 3.6379e-01
# Modelo 9 treinado e salvo no Excel
