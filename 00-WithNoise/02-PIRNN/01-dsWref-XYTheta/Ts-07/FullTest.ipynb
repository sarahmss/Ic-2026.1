# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 7
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    for var in PREDICTORS:
        Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    for var in PREDICTORS:
        Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
PREDICTORS = ["dWdRef", "dWeRef", "sWdRef", "sWeRef"]   
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train2, Train1], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 3)
# Dimensão da entrada: (1264, 7, 4)
# Dimensão da saida: (1264, 7, 4)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 3)
# Dimensão da entrada fisica : (1945,)
# Dimensão da entrada fisica: (1945,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, patience=500, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train, theta_train)
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)
        # plt.show()

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.583327 | Val Loss 0.805360
# Epoch 100 | Train Loss 1.306803 | Val Loss 0.709535
# Epoch 200 | Train Loss 1.242713 | Val Loss 0.705085
# Epoch 300 | Train Loss 1.187354 | Val Loss 0.734270
# Epoch 400 | Train Loss 1.142941 | Val Loss 0.749022
# Epoch 500 | Train Loss 1.099522 | Val Loss 0.779821
# Early stopping at epoch 533
# Theta | train1 -> R² = 0.8444, MSE = 3.5664e-02
# X | train1 -> R² = -0.2106, MSE = 1.2976e-01
# Y | train1 -> R² = -1.2432, MSE = 1.8748e-01
# Theta | train2 -> R² = 0.4435, MSE = 1.2618e-01
# X | train2 -> R² = -0.2583, MSE = 1.0576e-01
# Y | train2 -> R² = -1.0598, MSE = 2.2055e-01
# Theta | test1 -> R² = 0.7592, MSE = 5.5545e-02
# X | test1 -> R² = -0.3198, MSE = 1.3738e-01
# Y | test1 -> R² = -1.5166, MSE = 2.0556e-01
# Theta | test2 -> R² = 0.4585, MSE = 1.2756e-01
# X | test2 -> R² = -0.2394, MSE = 1.0175e-01
# Y | test2 -> R² = -0.9866, MSE = 2.0974e-01
# Theta | test3 -> R² = 0.4190, MSE = 1.9148e-01
# X | test3 -> R² = -0.3945, MSE = 1.2759e-01
# Y | test3 -> R² = -2.5687, MSE = 2.7315e-01
# Theta | val -> R² = 0.6800, MSE = 1.0501e-01
# X | val -> R² = -0.4563, MSE = 1.3841e-01
# Y | val -> R² = -2.4851, MSE = 2.5865e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.605588 | Val Loss 0.785600
# Epoch 100 | Train Loss 1.308446 | Val Loss 0.709077
# Epoch 200 | Train Loss 1.249699 | Val Loss 0.702989
# Epoch 300 | Train Loss 1.194330 | Val Loss 0.697644
# Epoch 400 | Train Loss 1.143258 | Val Loss 0.705849
# Epoch 500 | Train Loss 1.096204 | Val Loss 0.730550
# Early stopping at epoch 529
# Theta | train1 -> R² = 0.8347, MSE = 3.7888e-02
# X | train1 -> R² = -0.0763, MSE = 1.1536e-01
# Y | train1 -> R² = -0.9606, MSE = 1.6387e-01
# Theta | train2 -> R² = 0.3501, MSE = 1.4736e-01
# X | train2 -> R² = -0.2060, MSE = 1.0137e-01
# Y | train2 -> R² = -0.9286, MSE = 2.0650e-01
# Theta | test1 -> R² = 0.7980, MSE = 4.6598e-02
# X | test1 -> R² = -0.1780, MSE = 1.2262e-01
# Y | test1 -> R² = -1.1226, MSE = 1.7338e-01
# Theta | test2 -> R² = 0.4135, MSE = 1.3817e-01
# X | test2 -> R² = -0.1757, MSE = 9.6517e-02
# Y | test2 -> R² = -0.8291, MSE = 1.9311e-01
# Theta | test3 -> R² = 0.6979, MSE = 9.9571e-02
# X | test3 -> R² = -0.1614, MSE = 1.0626e-01
# Y | test3 -> R² = -1.7179, MSE = 2.0803e-01
# Theta | val -> R² = 0.7577, MSE = 7.9501e-02
# X | val -> R² = -0.1698, MSE = 1.1118e-01
# Y | val -> R² = -1.7050, MSE = 2.0075e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.627778 | Val Loss 0.797433
# Epoch 100 | Train Loss 1.305441 | Val Loss 0.704995
# Epoch 200 | Train Loss 1.255408 | Val Loss 0.713465
# Epoch 300 | Train Loss 1.202872 | Val Loss 0.711787
# Epoch 400 | Train Loss 1.161209 | Val Loss 0.725403
# Epoch 500 | Train Loss 1.116741 | Val Loss 0.747271
# Early stopping at epoch 533
# Theta | train1 -> R² = 0.7985, MSE = 4.6193e-02
# X | train1 -> R² = -0.0503, MSE = 1.1257e-01
# Y | train1 -> R² = -1.0565, MSE = 1.7188e-01
# Theta | train2 -> R² = 0.2267, MSE = 1.7534e-01
# X | train2 -> R² = -0.1647, MSE = 9.7893e-02
# Y | train2 -> R² = -1.0198, MSE = 2.1627e-01
# Theta | test1 -> R² = 0.7132, MSE = 6.6147e-02
# X | test1 -> R² = -0.1295, MSE = 1.1757e-01
# Y | test1 -> R² = -1.2549, MSE = 1.8418e-01
# Theta | test2 -> R² = 0.2720, MSE = 1.7150e-01
# X | test2 -> R² = -0.1423, MSE = 9.3774e-02
# Y | test2 -> R² = -0.9383, MSE = 2.0463e-01
# Theta | test3 -> R² = 0.4946, MSE = 1.6656e-01
# X | test3 -> R² = -0.1837, MSE = 1.0830e-01
# Y | test3 -> R² = -1.9380, MSE = 2.2487e-01
# Theta | val -> R² = 0.6278, MSE = 1.2212e-01
# X | val -> R² = -0.2149, MSE = 1.1547e-01
# Y | val -> R² = -1.8835, MSE = 2.1400e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.619138 | Val Loss 0.795569
# Epoch 100 | Train Loss 1.306792 | Val Loss 0.708264
# Epoch 200 | Train Loss 1.238981 | Val Loss 0.712835
# Epoch 300 | Train Loss 1.181735 | Val Loss 0.738111
# Epoch 400 | Train Loss 1.140003 | Val Loss 0.756791
# Epoch 500 | Train Loss 1.099925 | Val Loss 0.773233
# Early stopping at epoch 532
# Theta | train1 -> R² = 0.8666, MSE = 3.0585e-02
# X | train1 -> R² = -0.1754, MSE = 1.2598e-01
# Y | train1 -> R² = -1.1883, MSE = 1.8290e-01
# Theta | train2 -> R² = 0.5531, MSE = 1.0133e-01
# X | train2 -> R² = -0.3445, MSE = 1.1300e-01
# Y | train2 -> R² = -1.1674, MSE = 2.3206e-01
# Theta | test1 -> R² = 0.6942, MSE = 7.0531e-02
# X | test1 -> R² = -0.2712, MSE = 1.3233e-01
# Y | test1 -> R² = -1.4240, MSE = 1.9799e-01
# Theta | test2 -> R² = 0.5507, MSE = 1.0585e-01
# X | test2 -> R² = -0.3008, MSE = 1.0679e-01
# Y | test2 -> R² = -1.0821, MSE = 2.1982e-01
# Theta | test3 -> R² = 0.2054, MSE = 2.6188e-01
# X | test3 -> R² = -0.3620, MSE = 1.2461e-01
# Y | test3 -> R² = -2.3397, MSE = 2.5562e-01
# Theta | val -> R² = 0.5413, MSE = 1.5052e-01
# X | val -> R² = -0.4039, MSE = 1.3343e-01
# Y | val -> R² = -2.2186, MSE = 2.3887e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.597815 | Val Loss 0.819881
# Epoch 100 | Train Loss 1.307970 | Val Loss 0.709452
# Epoch 200 | Train Loss 1.244000 | Val Loss 0.703943
# Epoch 300 | Train Loss 1.192841 | Val Loss 0.725369
# Epoch 400 | Train Loss 1.144900 | Val Loss 0.740079
# Epoch 500 | Train Loss 1.099484 | Val Loss 0.754888
# Early stopping at epoch 537
# Theta | train1 -> R² = 0.8112, MSE = 4.3265e-02
# X | train1 -> R² = -0.1609, MSE = 1.2442e-01
# Y | train1 -> R² = -1.0250, MSE = 1.6925e-01
# Theta | train2 -> R² = 0.2644, MSE = 1.6680e-01
# X | train2 -> R² = -0.2068, MSE = 1.0143e-01
# Y | train2 -> R² = -0.9530, MSE = 2.0911e-01
# Theta | test1 -> R² = 0.7973, MSE = 4.6754e-02
# X | test1 -> R² = -0.2690, MSE = 1.3210e-01
# Y | test1 -> R² = -1.2213, MSE = 1.8144e-01
# Theta | test2 -> R² = 0.3461, MSE = 1.5404e-01
# X | test2 -> R² = -0.1907, MSE = 9.7747e-02
# Y | test2 -> R² = -0.8768, MSE = 1.9814e-01
# Theta | test3 -> R² = 0.6201, MSE = 1.2519e-01
# X | test3 -> R² = -0.2952, MSE = 1.1850e-01
# Y | test3 -> R² = -1.9987, MSE = 2.2952e-01
# Theta | val -> R² = 0.7270, MSE = 8.9560e-02
# X | val -> R² = -0.3339, MSE = 1.2678e-01
# Y | val -> R² = -1.9394, MSE = 2.1815e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.593715 | Val Loss 0.788496
# Epoch 100 | Train Loss 1.306093 | Val Loss 0.704488
# Epoch 200 | Train Loss 1.239126 | Val Loss 0.697897
# Epoch 300 | Train Loss 1.181461 | Val Loss 0.718856
# Epoch 400 | Train Loss 1.135385 | Val Loss 0.757057
# Epoch 500 | Train Loss 1.094637 | Val Loss 0.800088
# Early stopping at epoch 532
# Theta | train1 -> R² = 0.7594, MSE = 5.5144e-02
# X | train1 -> R² = -0.1984, MSE = 1.2844e-01
# Y | train1 -> R² = -1.0598, MSE = 1.7216e-01
# Theta | train2 -> R² = 0.3597, MSE = 1.4518e-01
# X | train2 -> R² = -0.2747, MSE = 1.0714e-01
# Y | train2 -> R² = -1.0048, MSE = 2.1466e-01
# Theta | test1 -> R² = 0.6242, MSE = 8.6677e-02
# X | test1 -> R² = -0.3159, MSE = 1.3698e-01
# Y | test1 -> R² = -1.2942, MSE = 1.8740e-01
# Theta | test2 -> R² = 0.3553, MSE = 1.5188e-01
# X | test2 -> R² = -0.2554, MSE = 1.0306e-01
# Y | test2 -> R² = -0.9331, MSE = 2.0409e-01
# Theta | test3 -> R² = -0.0060, MSE = 3.3155e-01
# X | test3 -> R² = -0.3343, MSE = 1.2208e-01
# Y | test3 -> R² = -1.7498, MSE = 2.1047e-01
# Theta | val -> R² = 0.3659, MSE = 2.0807e-01
# X | val -> R² = -0.3853, MSE = 1.3167e-01
# Y | val -> R² = -1.7629, MSE = 2.0505e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.520309 | Val Loss 0.785869
# Epoch 100 | Train Loss 1.302587 | Val Loss 0.704499
# Epoch 200 | Train Loss 1.241009 | Val Loss 0.718501
# Epoch 300 | Train Loss 1.187811 | Val Loss 0.734593
# Epoch 400 | Train Loss 1.142656 | Val Loss 0.766091
# Epoch 500 | Train Loss 1.100427 | Val Loss 0.790699
# Early stopping at epoch 524
# Theta | train1 -> R² = 0.8432, MSE = 3.5941e-02
# X | train1 -> R² = -0.3286, MSE = 1.4239e-01
# Y | train1 -> R² = -1.0421, MSE = 1.7068e-01
# Theta | train2 -> R² = 0.5772, MSE = 9.5856e-02
# X | train2 -> R² = -0.2221, MSE = 1.0271e-01
# Y | train2 -> R² = -0.9044, MSE = 2.0391e-01
# Theta | test1 -> R² = 0.6410, MSE = 8.2797e-02
# X | test1 -> R² = -0.4103, MSE = 1.4681e-01
# Y | test1 -> R² = -1.2350, MSE = 1.8255e-01
# Theta | test2 -> R² = 0.5868, MSE = 9.7350e-02
# X | test2 -> R² = -0.1949, MSE = 9.8095e-02
# Y | test2 -> R² = -0.8186, MSE = 1.9200e-01
# Theta | test3 -> R² = 0.3490, MSE = 2.1454e-01
# X | test3 -> R² = -0.4665, MSE = 1.3418e-01
# Y | test3 -> R² = -1.9873, MSE = 2.2865e-01
# Theta | val -> R² = 0.6120, MSE = 1.2732e-01
# X | val -> R² = -0.5148, MSE = 1.4397e-01
# Y | val -> R² = -1.9596, MSE = 2.1965e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.587281 | Val Loss 0.843853
# Epoch 100 | Train Loss 1.304203 | Val Loss 0.705472
# Epoch 200 | Train Loss 1.237458 | Val Loss 0.699209
# Epoch 300 | Train Loss 1.183030 | Val Loss 0.727319
# Epoch 400 | Train Loss 1.140733 | Val Loss 0.748798
# Epoch 500 | Train Loss 1.101926 | Val Loss 0.773242
# Epoch 600 | Train Loss 1.063285 | Val Loss 0.814183
# Early stopping at epoch 668
# Theta | train1 -> R² = 0.7683, MSE = 5.3103e-02
# X | train1 -> R² = -0.0399, MSE = 1.1145e-01
# Y | train1 -> R² = -0.6529, MSE = 1.3815e-01
# Theta | train2 -> R² = 0.4511, MSE = 1.2445e-01
# X | train2 -> R² = -0.1541, MSE = 9.7000e-02
# Y | train2 -> R² = -0.9113, MSE = 2.0465e-01
# Theta | test1 -> R² = 0.8318, MSE = 3.8798e-02
# X | test1 -> R² = -0.0430, MSE = 1.0857e-01
# Y | test1 -> R² = -1.1168, MSE = 1.7290e-01
# Theta | test2 -> R² = 0.6275, MSE = 8.7758e-02
# X | test2 -> R² = -0.0425, MSE = 8.5582e-02
# Y | test2 -> R² = -1.0628, MSE = 2.1778e-01
# Theta | test3 -> R² = -2.4890, MSE = 1.1499e+00
# X | test3 -> R² = 0.0459, MSE = 8.7293e-02
# Y | test3 -> R² = -1.5490, MSE = 1.9510e-01
# Theta | val -> R² = -0.7484, MSE = 5.7369e-01
# X | val -> R² = 0.0919, MSE = 8.6309e-02
# Y | val -> R² = -1.8487, MSE = 2.1142e-01
# Figura salva em: ./results/model_64_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.554647 | Val Loss 0.796259
# Epoch 100 | Train Loss 1.298073 | Val Loss 0.709537
# Epoch 200 | Train Loss 1.242992 | Val Loss 0.710790
# Epoch 300 | Train Loss 1.193778 | Val Loss 0.718728
# Epoch 400 | Train Loss 1.153744 | Val Loss 0.729802
# Epoch 500 | Train Loss 1.112038 | Val Loss 0.748976
# Early stopping at epoch 531
# Theta | train1 -> R² = 0.8319, MSE = 3.8521e-02
# X | train1 -> R² = -0.2097, MSE = 1.2966e-01
# Y | train1 -> R² = -1.0454, MSE = 1.7096e-01
# Theta | train2 -> R² = 0.4193, MSE = 1.3166e-01
# X | train2 -> R² = -0.1957, MSE = 1.0050e-01
# Y | train2 -> R² = -0.9028, MSE = 2.0374e-01
# Theta | test1 -> R² = 0.7968, MSE = 4.6881e-02
# X | test1 -> R² = -0.2853, MSE = 1.3380e-01
# Y | test1 -> R² = -1.2684, MSE = 1.8529e-01
# Theta | test2 -> R² = 0.4494, MSE = 1.2972e-01
# X | test2 -> R² = -0.1602, MSE = 9.5246e-02
# Y | test2 -> R² = -0.8053, MSE = 1.9059e-01
# Theta | test3 -> R² = 0.4787, MSE = 1.7181e-01
# X | test3 -> R² = -0.3220, MSE = 1.2096e-01
# Y | test3 -> R² = -2.0142, MSE = 2.3071e-01
# Theta | val -> R² = 0.6876, MSE = 1.0250e-01
# X | val -> R² = -0.3944, MSE = 1.3253e-01
# Y | val -> R² = -2.0067, MSE = 2.2314e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.558625 | Val Loss 0.791210
# Epoch 100 | Train Loss 1.312676 | Val Loss 0.706469
# Epoch 200 | Train Loss 1.242731 | Val Loss 0.699873
# Epoch 300 | Train Loss 1.177522 | Val Loss 0.712682
# Epoch 400 | Train Loss 1.122060 | Val Loss 0.744120
# Epoch 500 | Train Loss 1.075456 | Val Loss 0.787826
# Epoch 600 | Train Loss 1.036148 | Val Loss 0.821402
# Early stopping at epoch 662
# Theta | train1 -> R² = 0.6863, MSE = 7.1897e-02
# X | train1 -> R² = -0.0816, MSE = 1.1592e-01
# Y | train1 -> R² = -0.7973, MSE = 1.5022e-01
# Theta | train2 -> R² = 0.6182, MSE = 8.6576e-02
# X | train2 -> R² = -0.1321, MSE = 9.5153e-02
# Y | train2 -> R² = -0.8891, MSE = 2.0227e-01
# Theta | test1 -> R² = 0.6290, MSE = 8.5572e-02
# X | test1 -> R² = -0.1167, MSE = 1.1624e-01
# Y | test1 -> R² = -1.1394, MSE = 1.7475e-01
# Theta | test2 -> R² = 0.6244, MSE = 8.8484e-02
# X | test2 -> R² = -0.0792, MSE = 8.8597e-02
# Y | test2 -> R² = -0.9195, MSE = 2.0265e-01
# Theta | test3 -> R² = -0.5195, MSE = 5.0078e-01
# X | test3 -> R² = -0.1449, MSE = 1.0475e-01
# Y | test3 -> R² = -1.9762, MSE = 2.2780e-01
# Theta | val -> R² = 0.4582, MSE = 1.7776e-01
# X | val -> R² = -0.1514, MSE = 1.0943e-01
# Y | val -> R² = -2.2000, MSE = 2.3749e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.582986 | Val Loss 0.760017
# Epoch 100 | Train Loss 1.282494 | Val Loss 0.696720
# Epoch 200 | Train Loss 1.188301 | Val Loss 0.718321
# Epoch 300 | Train Loss 1.123393 | Val Loss 0.749875
# Epoch 400 | Train Loss 1.057621 | Val Loss 0.789804
# Epoch 500 | Train Loss 0.997140 | Val Loss 0.856367
# Epoch 600 | Train Loss 0.946264 | Val Loss 0.882651
# Early stopping at epoch 625
# Theta | train1 -> R² = 0.8877, MSE = 2.5747e-02
# X | train1 -> R² = -0.1125, MSE = 1.1924e-01
# Y | train1 -> R² = -0.8299, MSE = 1.5294e-01
# Theta | train2 -> R² = 0.2601, MSE = 1.6776e-01
# X | train2 -> R² = -0.1252, MSE = 9.4569e-02
# Y | train2 -> R² = -0.7687, MSE = 1.8937e-01
# Theta | test1 -> R² = 0.8223, MSE = 4.0993e-02
# X | test1 -> R² = 0.0346, MSE = 1.0050e-01
# Y | test1 -> R² = -1.4381, MSE = 1.9914e-01
# Theta | test2 -> R² = 0.5325, MSE = 1.1014e-01
# X | test2 -> R² = -0.0100, MSE = 8.2915e-02
# Y | test2 -> R² = -1.0494, MSE = 2.1637e-01
# Theta | test3 -> R² = -1.3875, MSE = 7.8686e-01
# X | test3 -> R² = -0.0563, MSE = 9.6645e-02
# Y | test3 -> R² = -1.1867, MSE = 1.6737e-01
# Theta | val -> R² = -0.0938, MSE = 3.5889e-01
# X | val -> R² = -0.0341, MSE = 9.8282e-02
# Y | val -> R² = -1.5754, MSE = 1.9113e-01
# Figura salva em: ./results/model_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.575827 | Val Loss 0.754558
# Epoch 100 | Train Loss 1.301995 | Val Loss 0.706431
# Epoch 200 | Train Loss 1.200074 | Val Loss 0.686932
# Epoch 300 | Train Loss 1.119022 | Val Loss 0.695944
# Epoch 400 | Train Loss 1.032257 | Val Loss 0.730479
# Epoch 500 | Train Loss 0.971087 | Val Loss 0.791098
# Epoch 600 | Train Loss 0.925997 | Val Loss 0.845729
# Early stopping at epoch 639
# Theta | train1 -> R² = 0.8535, MSE = 3.3586e-02
# X | train1 -> R² = -0.0506, MSE = 1.1261e-01
# Y | train1 -> R² = -0.7830, MSE = 1.4903e-01
# Theta | train2 -> R² = -0.3575, MSE = 3.0780e-01
# X | train2 -> R² = -0.0698, MSE = 8.9914e-02
# Y | train2 -> R² = -0.8559, MSE = 1.9872e-01
# Theta | test1 -> R² = 0.8629, MSE = 3.1629e-02
# X | test1 -> R² = 0.0347, MSE = 1.0049e-01
# Y | test1 -> R² = -1.2461, MSE = 1.8346e-01
# Theta | test2 -> R² = 0.1266, MSE = 2.0576e-01
# X | test2 -> R² = 0.0069, MSE = 8.1527e-02
# Y | test2 -> R² = -1.1538, MSE = 2.2738e-01
# Theta | test3 -> R² = 0.3315, MSE = 2.2031e-01
# X | test3 -> R² = 0.1261, MSE = 7.9955e-02
# Y | test3 -> R² = -1.9983, MSE = 2.2949e-01
# Theta | val -> R² = 0.6843, MSE = 1.0357e-01
# X | val -> R² = 0.1517, MSE = 8.0628e-02
# Y | val -> R² = -2.3222, MSE = 2.4656e-01
# Figura salva em: ./results/model_128_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.686208 | Val Loss 0.772526
# Epoch 100 | Train Loss 1.299149 | Val Loss 0.703849
# Epoch 200 | Train Loss 1.211327 | Val Loss 0.693387
# Epoch 300 | Train Loss 1.137677 | Val Loss 0.709994
# Epoch 400 | Train Loss 1.074740 | Val Loss 0.743721
# Epoch 500 | Train Loss 1.011273 | Val Loss 0.806418
# Early stopping at epoch 517
# Theta | train1 -> R² = 0.8280, MSE = 3.9422e-02
# X | train1 -> R² = 0.0120, MSE = 1.0590e-01
# Y | train1 -> R² = -1.0952, MSE = 1.7512e-01
# Theta | train2 -> R² = 0.4892, MSE = 1.1582e-01
# X | train2 -> R² = -0.2633, MSE = 1.0618e-01
# Y | train2 -> R² = -1.2790, MSE = 2.4402e-01
# Theta | test1 -> R² = 0.6002, MSE = 9.2225e-02
# X | test1 -> R² = -0.0925, MSE = 1.1373e-01
# Y | test1 -> R² = -1.3447, MSE = 1.9151e-01
# Theta | test2 -> R² = 0.4589, MSE = 1.2748e-01
# X | test2 -> R² = -0.2455, MSE = 1.0225e-01
# Y | test2 -> R² = -1.2116, MSE = 2.3349e-01
# Theta | test3 -> R² = 0.0674, MSE = 3.0737e-01
# X | test3 -> R² = -0.1079, MSE = 1.0137e-01
# Y | test3 -> R² = -1.9708, MSE = 2.2738e-01
# Theta | val -> R² = 0.4299, MSE = 1.8706e-01
# X | val -> R² = -0.0961, MSE = 1.0417e-01
# Y | val -> R² = -1.8204, MSE = 2.0932e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.621429 | Val Loss 0.769662
# Epoch 100 | Train Loss 1.298268 | Val Loss 0.702014
# Epoch 200 | Train Loss 1.198677 | Val Loss 0.694138
# Epoch 300 | Train Loss 1.130552 | Val Loss 0.731677
# Epoch 400 | Train Loss 1.071865 | Val Loss 0.756348
# Epoch 500 | Train Loss 1.023229 | Val Loss 0.811432
# Epoch 600 | Train Loss 0.969528 | Val Loss 0.800844
# Early stopping at epoch 646
# Theta | train1 -> R² = 0.8894, MSE = 2.5356e-02
# X | train1 -> R² = -0.1381, MSE = 1.2198e-01
# Y | train1 -> R² = -0.7417, MSE = 1.4557e-01
# Theta | train2 -> R² = 0.2623, MSE = 1.6728e-01
# X | train2 -> R² = -0.1130, MSE = 9.3544e-02
# Y | train2 -> R² = -0.8504, MSE = 1.9813e-01
# Theta | test1 -> R² = 0.8114, MSE = 4.3510e-02
# X | test1 -> R² = -0.0621, MSE = 1.1056e-01
# Y | test1 -> R² = -1.2677, MSE = 1.8522e-01
# Theta | test2 -> R² = 0.6017, MSE = 9.3843e-02
# X | test2 -> R² = -0.0539, MSE = 8.6518e-02
# Y | test2 -> R² = -1.0616, MSE = 2.1765e-01
# Theta | test3 -> R² = -1.0560, MSE = 6.7762e-01
# X | test3 -> R² = 0.0544, MSE = 8.6520e-02
# Y | test3 -> R² = -1.1636, MSE = 1.6561e-01
# Theta | val -> R² = 0.0493, MSE = 3.1194e-01
# X | val -> R² = 0.0396, MSE = 9.1274e-02
# Y | val -> R² = -1.5849, MSE = 1.9184e-01
# Figura salva em: ./results/model_128_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.541957 | Val Loss 0.751194
# Epoch 100 | Train Loss 1.276845 | Val Loss 0.695685
# Epoch 200 | Train Loss 1.180688 | Val Loss 0.717054
# Epoch 300 | Train Loss 1.111021 | Val Loss 0.756129
# Epoch 400 | Train Loss 1.049036 | Val Loss 0.829880
# Epoch 500 | Train Loss 0.989166 | Val Loss 0.856350
# Epoch 600 | Train Loss 0.942382 | Val Loss 0.913392
# Early stopping at epoch 616
# Theta | train1 -> R² = 0.8328, MSE = 3.8325e-02
# X | train1 -> R² = -0.1145, MSE = 1.1945e-01
# Y | train1 -> R² = -0.8226, MSE = 1.5233e-01
# Theta | train2 -> R² = 0.4148, MSE = 1.3268e-01
# X | train2 -> R² = -0.0878, MSE = 9.1430e-02
# Y | train2 -> R² = -0.7551, MSE = 1.8792e-01
# Theta | test1 -> R² = 0.7523, MSE = 5.7142e-02
# X | test1 -> R² = -0.0101, MSE = 1.0515e-01
# Y | test1 -> R² = -1.2794, MSE = 1.8618e-01
# Theta | test2 -> R² = 0.6482, MSE = 8.2867e-02
# X | test2 -> R² = 0.0274, MSE = 7.9842e-02
# Y | test2 -> R² = -0.9666, MSE = 2.0763e-01
# Theta | test3 -> R² = -1.2728, MSE = 7.4908e-01
# X | test3 -> R² = -0.0862, MSE = 9.9378e-02
# Y | test3 -> R² = -0.5849, MSE = 1.2131e-01
# Theta | val -> R² = -0.0521, MSE = 3.4521e-01
# X | val -> R² = -0.1201, MSE = 1.0646e-01
# Y | val -> R² = -1.0438, MSE = 1.5168e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.513952 | Val Loss 0.756037
# Epoch 100 | Train Loss 1.271284 | Val Loss 0.696292
# Epoch 200 | Train Loss 1.178389 | Val Loss 0.700797
# Epoch 300 | Train Loss 1.102605 | Val Loss 0.740504
# Epoch 400 | Train Loss 1.034207 | Val Loss 0.829658
# Epoch 500 | Train Loss 0.983677 | Val Loss 0.904763
# Epoch 600 | Train Loss 0.937151 | Val Loss 0.951960
# Early stopping at epoch 622
# Theta | train1 -> R² = 0.8462, MSE = 3.5254e-02
# X | train1 -> R² = -0.0813, MSE = 1.1589e-01
# Y | train1 -> R² = -0.8036, MSE = 1.5075e-01
# Theta | train2 -> R² = 0.5209, MSE = 1.0863e-01
# X | train2 -> R² = -0.1156, MSE = 9.3767e-02
# Y | train2 -> R² = -0.8028, MSE = 1.9303e-01
# Theta | test1 -> R² = 0.7379, MSE = 6.0458e-02
# X | test1 -> R² = -0.0087, MSE = 1.0501e-01
# Y | test1 -> R² = -1.2435, MSE = 1.8325e-01
# Theta | test2 -> R² = 0.6584, MSE = 8.0476e-02
# X | test2 -> R² = -0.0145, MSE = 8.3285e-02
# Y | test2 -> R² = -1.0306, MSE = 2.1438e-01
# Theta | test3 -> R² = -1.6406, MSE = 8.7030e-01
# X | test3 -> R² = 0.1213, MSE = 8.0394e-02
# Y | test3 -> R² = -2.3238, MSE = 2.5441e-01
# Theta | val -> R² = -0.0506, MSE = 3.4472e-01
# X | val -> R² = 0.1255, MSE = 8.3118e-02
# Y | val -> R² = -2.5948, MSE = 2.6679e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.606678 | Val Loss 0.786537
# Epoch 100 | Train Loss 1.283897 | Val Loss 0.701928
# Epoch 200 | Train Loss 1.202961 | Val Loss 0.714456
# Epoch 300 | Train Loss 1.114828 | Val Loss 0.741766
# Epoch 400 | Train Loss 1.043732 | Val Loss 0.780891
# Epoch 500 | Train Loss 0.987893 | Val Loss 0.813858
# Epoch 600 | Train Loss 0.945689 | Val Loss 0.852357
# Early stopping at epoch 624
# Theta | train1 -> R² = 0.7614, MSE = 5.4696e-02
# X | train1 -> R² = -0.0106, MSE = 1.0831e-01
# Y | train1 -> R² = -0.8859, MSE = 1.5762e-01
# Theta | train2 -> R² = -0.4336, MSE = 3.2505e-01
# X | train2 -> R² = -0.1707, MSE = 9.8398e-02
# Y | train2 -> R² = -0.9546, MSE = 2.0928e-01
# Theta | test1 -> R² = 0.8119, MSE = 4.3382e-02
# X | test1 -> R² = 0.0879, MSE = 9.4948e-02
# Y | test1 -> R² = -1.3746, MSE = 1.9396e-01
# Theta | test2 -> R² = -0.1475, MSE = 2.7034e-01
# X | test2 -> R² = -0.0173, MSE = 8.3517e-02
# Y | test2 -> R² = -1.1452, MSE = 2.2648e-01
# Theta | test3 -> R² = 0.7050, MSE = 9.7213e-02
# X | test3 -> R² = 0.1615, MSE = 7.6713e-02
# Y | test3 -> R² = -3.5930, MSE = 3.5155e-01
# Theta | val -> R² = 0.6549, MSE = 1.1323e-01
# X | val -> R² = 0.1667, MSE = 7.9199e-02
# Y | val -> R² = -3.6572, MSE = 3.4564e-01
# Figura salva em: ./results/model_128_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.564096 | Val Loss 0.753371
# Epoch 100 | Train Loss 1.272931 | Val Loss 0.694768
# Epoch 200 | Train Loss 1.176694 | Val Loss 0.721820
# Epoch 300 | Train Loss 1.108824 | Val Loss 0.753739
# Epoch 400 | Train Loss 1.045854 | Val Loss 0.769448
# Epoch 500 | Train Loss 0.985079 | Val Loss 0.798404
# Epoch 600 | Train Loss 0.934084 | Val Loss 0.828363
# Early stopping at epoch 616
# Theta | train1 -> R² = 0.8694, MSE = 2.9945e-02
# X | train1 -> R² = -0.0586, MSE = 1.1346e-01
# Y | train1 -> R² = -0.7935, MSE = 1.4990e-01
# Theta | train2 -> R² = -0.2404, MSE = 2.8125e-01
# X | train2 -> R² = -0.1096, MSE = 9.3260e-02
# Y | train2 -> R² = -0.8681, MSE = 2.0002e-01
# Theta | test1 -> R² = 0.9088, MSE = 2.1027e-02
# X | test1 -> R² = 0.0573, MSE = 9.8129e-02
# Y | test1 -> R² = -1.2581, MSE = 1.8444e-01
# Theta | test2 -> R² = 0.1786, MSE = 1.9350e-01
# X | test2 -> R² = -0.0054, MSE = 8.2541e-02
# Y | test2 -> R² = -0.9959, MSE = 2.1072e-01
# Theta | test3 -> R² = -0.0605, MSE = 3.4952e-01
# X | test3 -> R² = 0.1252, MSE = 8.0035e-02
# Y | test3 -> R² = -1.5080, MSE = 1.9196e-01
# Theta | val -> R² = 0.5947, MSE = 1.3298e-01
# X | val -> R² = 0.1185, MSE = 8.3782e-02
# Y | val -> R² = -1.8590, MSE = 2.1218e-01
# Figura salva em: ./results/model_128_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572578 | Val Loss 0.751334
# Epoch 100 | Train Loss 1.287287 | Val Loss 0.698343
# Epoch 200 | Train Loss 1.197610 | Val Loss 0.696007
# Epoch 300 | Train Loss 1.124438 | Val Loss 0.747225
# Epoch 400 | Train Loss 1.065802 | Val Loss 0.801963
# Epoch 500 | Train Loss 1.011770 | Val Loss 0.828930
# Epoch 600 | Train Loss 0.970119 | Val Loss 0.853566
# Early stopping at epoch 634
# Theta | train1 -> R² = 0.4898, MSE = 1.1695e-01
# X | train1 -> R² = -0.1170, MSE = 1.1972e-01
# Y | train1 -> R² = -0.6952, MSE = 1.4168e-01
# Theta | train2 -> R² = 0.7418, MSE = 5.8547e-02
# X | train2 -> R² = -0.0841, MSE = 9.1121e-02
# Y | train2 -> R² = -0.8818, MSE = 2.0149e-01
# Theta | test1 -> R² = 0.2903, MSE = 1.6369e-01
# X | test1 -> R² = -0.0235, MSE = 1.0654e-01
# Y | test1 -> R² = -1.1713, MSE = 1.7735e-01
# Theta | test2 -> R² = 0.7282, MSE = 6.4033e-02
# X | test2 -> R² = -0.0316, MSE = 8.4689e-02
# Y | test2 -> R² = -1.0210, MSE = 2.1337e-01
# Theta | test3 -> R² = -2.8133, MSE = 1.2568e+00
# X | test3 -> R² = 0.0298, MSE = 8.8764e-02
# Y | test3 -> R² = -0.7286, MSE = 1.3231e-01
# Theta | val -> R² = -1.0956, MSE = 6.8760e-01
# X | val -> R² = 0.0454, MSE = 9.0726e-02
# Y | val -> R² = -1.1273, MSE = 1.5788e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.593709 | Val Loss 0.785493
# Epoch 100 | Train Loss 1.299803 | Val Loss 0.702213
# Epoch 200 | Train Loss 1.212439 | Val Loss 0.700475
# Epoch 300 | Train Loss 1.132784 | Val Loss 0.746225
# Epoch 400 | Train Loss 1.063142 | Val Loss 0.800705
# Epoch 500 | Train Loss 1.000779 | Val Loss 0.854717
# Epoch 600 | Train Loss 0.951768 | Val Loss 0.899256
# Early stopping at epoch 635
# Theta | train1 -> R² = 0.8346, MSE = 3.7902e-02
# X | train1 -> R² = -0.1357, MSE = 1.2172e-01
# Y | train1 -> R² = -0.8634, MSE = 1.5575e-01
# Theta | train2 -> R² = -0.2027, MSE = 2.7270e-01
# X | train2 -> R² = -0.1061, MSE = 9.2966e-02
# Y | train2 -> R² = -0.9030, MSE = 2.0376e-01
# Theta | test1 -> R² = 0.8890, MSE = 2.5601e-02
# X | test1 -> R² = -0.0939, MSE = 1.1387e-01
# Y | test1 -> R² = -1.3881, MSE = 1.9506e-01
# Theta | test2 -> R² = 0.1657, MSE = 1.9656e-01
# X | test2 -> R² = -0.0780, MSE = 8.8494e-02
# Y | test2 -> R² = -1.0280, MSE = 2.1411e-01
# Theta | test3 -> R² = -0.0359, MSE = 3.4142e-01
# X | test3 -> R² = -0.1746, MSE = 1.0747e-01
# Y | test3 -> R² = -1.2934, MSE = 1.7554e-01
# Theta | val -> R² = 0.5375, MSE = 1.5177e-01
# X | val -> R² = -0.1345, MSE = 1.0783e-01
# Y | val -> R² = -1.5951, MSE = 1.9260e-01
# Figura salva em: ./results/model_128_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.630257 | Val Loss 0.760474
# Epoch 100 | Train Loss 1.259325 | Val Loss 0.685374
# Epoch 200 | Train Loss 1.136307 | Val Loss 0.714118
# Epoch 300 | Train Loss 1.036669 | Val Loss 0.739532
# Epoch 400 | Train Loss 0.950273 | Val Loss 0.798371
# Epoch 500 | Train Loss 0.887053 | Val Loss 0.843915
# Epoch 600 | Train Loss 0.842935 | Val Loss 0.893249
# Early stopping at epoch 615
# Theta | train1 -> R² = 0.3446, MSE = 1.5023e-01
# X | train1 -> R² = -0.2257, MSE = 1.3137e-01
# Y | train1 -> R² = -0.5359, MSE = 1.2837e-01
# Theta | train2 -> R² = 0.6760, MSE = 7.3470e-02
# X | train2 -> R² = -0.0943, MSE = 9.1973e-02
# Y | train2 -> R² = -0.7301, MSE = 1.8525e-01
# Theta | test1 -> R² = 0.0987, MSE = 2.0791e-01
# X | test1 -> R² = -0.0624, MSE = 1.1059e-01
# Y | test1 -> R² = -1.1953, MSE = 1.7932e-01
# Theta | test2 -> R² = 0.6931, MSE = 7.2307e-02
# X | test2 -> R² = -0.0382, MSE = 8.5230e-02
# Y | test2 -> R² = -1.1504, MSE = 2.2703e-01
# Theta | test3 -> R² = -4.2256, MSE = 1.7223e+00
# X | test3 -> R² = 0.0653, MSE = 8.5522e-02
# Y | test3 -> R² = -1.0426, MSE = 1.5634e-01
# Theta | val -> R² = -2.1684, MSE = 1.0396e+00
# X | val -> R² = 0.0874, MSE = 8.6737e-02
# Y | val -> R² = -1.4770, MSE = 1.8383e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.538252 | Val Loss 0.827796
# Epoch 100 | Train Loss 1.273558 | Val Loss 0.699857
# Epoch 200 | Train Loss 1.149716 | Val Loss 0.700329
# Epoch 300 | Train Loss 1.058122 | Val Loss 0.745415
# Epoch 400 | Train Loss 0.980851 | Val Loss 0.785866
# Epoch 500 | Train Loss 0.912988 | Val Loss 0.820997
# Epoch 600 | Train Loss 0.862842 | Val Loss 0.876521
# Early stopping at epoch 605
# Theta | train1 -> R² = 0.1929, MSE = 1.8500e-01
# X | train1 -> R² = -0.9014, MSE = 2.0379e-01
# Y | train1 -> R² = -0.3430, MSE = 1.1225e-01
# Theta | train2 -> R² = 0.5059, MSE = 1.1204e-01
# X | train2 -> R² = -0.6801, MSE = 1.4121e-01
# Y | train2 -> R² = -0.3776, MSE = 1.4750e-01
# Theta | test1 -> R² = 0.0362, MSE = 2.2231e-01
# X | test1 -> R² = -0.6434, MSE = 1.7107e-01
# Y | test1 -> R² = -0.8774, MSE = 1.5334e-01
# Theta | test2 -> R² = 0.2506, MSE = 1.7654e-01
# X | test2 -> R² = -0.5065, MSE = 1.2368e-01
# Y | test2 -> R² = -0.6497, MSE = 1.7417e-01
# Theta | test3 -> R² = -4.4269, MSE = 1.7886e+00
# X | test3 -> R² = -0.3388, MSE = 1.2249e-01
# Y | test3 -> R² = -0.8694, MSE = 1.4308e-01
# Theta | val -> R² = -2.2280, MSE = 1.0592e+00
# X | val -> R² = -0.3360, MSE = 1.2698e-01
# Y | val -> R² = -1.1930, MSE = 1.6276e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.618569 | Val Loss 0.781576
# Epoch 100 | Train Loss 1.261243 | Val Loss 0.685385
# Epoch 200 | Train Loss 1.145079 | Val Loss 0.708077
# Epoch 300 | Train Loss 1.054693 | Val Loss 0.768338
# Epoch 400 | Train Loss 0.985427 | Val Loss 0.804452
# Epoch 500 | Train Loss 0.902633 | Val Loss 0.847736
# Epoch 600 | Train Loss 0.854239 | Val Loss 0.886863
# Early stopping at epoch 625
# Theta | train1 -> R² = -0.9974, MSE = 4.5782e-01
# X | train1 -> R² = -0.1500, MSE = 1.2325e-01
# Y | train1 -> R² = -0.5197, MSE = 1.2702e-01
# Theta | train2 -> R² = 0.5686, MSE = 9.7823e-02
# X | train2 -> R² = -0.1243, MSE = 9.4497e-02
# Y | train2 -> R² = -0.7229, MSE = 1.8447e-01
# Theta | test1 -> R² = -0.7878, MSE = 4.1238e-01
# X | test1 -> R² = 0.0891, MSE = 9.4827e-02
# Y | test1 -> R² = -1.2936, MSE = 1.8734e-01
# Theta | test2 -> R² = 0.3435, MSE = 1.5465e-01
# X | test2 -> R² = -0.0499, MSE = 8.6189e-02
# Y | test2 -> R² = -1.0871, MSE = 2.2034e-01
# Theta | test3 -> R² = -7.1855, MSE = 2.6978e+00
# X | test3 -> R² = 0.2175, MSE = 7.1597e-02
# Y | test3 -> R² = -0.9345, MSE = 1.4807e-01
# Theta | val -> R² = -4.1786, MSE = 1.6992e+00
# X | val -> R² = 0.2119, MSE = 7.4901e-02
# Y | val -> R² = -1.4213, MSE = 1.7970e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.590134 | Val Loss 0.745092
# Epoch 100 | Train Loss 1.262032 | Val Loss 0.687811
# Epoch 200 | Train Loss 1.120970 | Val Loss 0.716424
# Epoch 300 | Train Loss 1.010041 | Val Loss 0.801239
# Epoch 400 | Train Loss 0.934506 | Val Loss 0.854149
# Epoch 500 | Train Loss 0.870177 | Val Loss 0.915497
# Epoch 600 | Train Loss 0.827058 | Val Loss 0.984793
# Early stopping at epoch 619
# Theta | train1 -> R² = 0.8978, MSE = 2.3434e-02
# X | train1 -> R² = -0.1663, MSE = 1.2501e-01
# Y | train1 -> R² = -0.6374, MSE = 1.3685e-01
# Theta | train2 -> R² = 0.0006, MSE = 2.2660e-01
# X | train2 -> R² = -0.0682, MSE = 8.9785e-02
# Y | train2 -> R² = -0.9454, MSE = 2.0829e-01
# Theta | test1 -> R² = 0.8731, MSE = 2.9269e-02
# X | test1 -> R² = -0.0166, MSE = 1.0582e-01
# Y | test1 -> R² = -1.5294, MSE = 2.0660e-01
# Theta | test2 -> R² = 0.3372, MSE = 1.5615e-01
# X | test2 -> R² = -0.0366, MSE = 8.5098e-02
# Y | test2 -> R² = -1.3460, MSE = 2.4768e-01
# Theta | test3 -> R² = 0.2491, MSE = 2.4749e-01
# X | test3 -> R² = 0.0785, MSE = 8.4311e-02
# Y | test3 -> R² = -1.5474, MSE = 1.9498e-01
# Theta | val -> R² = 0.6526, MSE = 1.1397e-01
# X | val -> R² = 0.0683, MSE = 8.8553e-02
# Y | val -> R² = -2.0670, MSE = 2.2762e-01
# Figura salva em: ./results/model_264_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.583800 | Val Loss 0.754032
# Epoch 100 | Train Loss 1.262241 | Val Loss 0.688182
# Epoch 200 | Train Loss 1.130206 | Val Loss 0.742136
# Epoch 300 | Train Loss 1.039631 | Val Loss 0.826312
# Epoch 400 | Train Loss 0.979548 | Val Loss 0.907189
# Epoch 500 | Train Loss 0.922496 | Val Loss 0.855616
# Epoch 600 | Train Loss 0.851679 | Val Loss 0.884182
# Early stopping at epoch 609
# Theta | train1 -> R² = 0.7992, MSE = 4.6025e-02
# X | train1 -> R² = -0.1482, MSE = 1.2307e-01
# Y | train1 -> R² = -0.3976, MSE = 1.1681e-01
# Theta | train2 -> R² = -0.3202, MSE = 2.9934e-01
# X | train2 -> R² = -0.0475, MSE = 8.8041e-02
# Y | train2 -> R² = -0.6712, MSE = 1.7894e-01
# Theta | test1 -> R² = 0.8554, MSE = 3.3346e-02
# X | test1 -> R² = -0.0472, MSE = 1.0901e-01
# Y | test1 -> R² = -1.1208, MSE = 1.7323e-01
# Theta | test2 -> R² = -0.0000, MSE = 2.3558e-01
# X | test2 -> R² = -0.0019, MSE = 8.2250e-02
# Y | test2 -> R² = -1.0172, MSE = 2.1297e-01
# Theta | test3 -> R² = 0.5500, MSE = 1.4830e-01
# X | test3 -> R² = 0.1100, MSE = 8.1427e-02
# Y | test3 -> R² = -0.9689, MSE = 1.5070e-01
# Theta | val -> R² = 0.7614, MSE = 7.8288e-02
# X | val -> R² = 0.1024, MSE = 8.5305e-02
# Y | val -> R² = -1.4819, MSE = 1.8419e-01
# Figura salva em: ./results/model_264_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.526949 | Val Loss 0.728732
# Epoch 100 | Train Loss 1.258082 | Val Loss 0.684055
# Epoch 200 | Train Loss 1.132078 | Val Loss 0.705469
# Epoch 300 | Train Loss 1.028058 | Val Loss 0.766621
# Epoch 400 | Train Loss 0.945283 | Val Loss 0.827975
# Epoch 500 | Train Loss 0.879591 | Val Loss 0.891087
# Epoch 600 | Train Loss 0.834836 | Val Loss 0.933960
# Early stopping at epoch 623
# Theta | train1 -> R² = 0.7975, MSE = 4.6426e-02
# X | train1 -> R² = -0.2334, MSE = 1.3219e-01
# Y | train1 -> R² = -0.4362, MSE = 1.2003e-01
# Theta | train2 -> R² = 0.3785, MSE = 1.4092e-01
# X | train2 -> R² = -0.0412, MSE = 8.7514e-02
# Y | train2 -> R² = -0.8008, MSE = 1.9282e-01
# Theta | test1 -> R² = 0.7576, MSE = 5.5919e-02
# X | test1 -> R² = -0.0982, MSE = 1.1432e-01
# Y | test1 -> R² = -1.3588, MSE = 1.9267e-01
# Theta | test2 -> R² = 0.6640, MSE = 7.9164e-02
# X | test2 -> R² = -0.0013, MSE = 8.2198e-02
# Y | test2 -> R² = -1.2002, MSE = 2.3228e-01
# Theta | test3 -> R² = -2.2328, MSE = 1.0655e+00
# X | test3 -> R² = 0.1393, MSE = 7.8746e-02
# Y | test3 -> R² = -1.4809, MSE = 1.8989e-01
# Theta | val -> R² = -0.6601, MSE = 5.4472e-01
# X | val -> R² = 0.1226, MSE = 8.3389e-02
# Y | val -> R² = -1.7829, MSE = 2.0653e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.638323 | Val Loss 0.805947
# Epoch 100 | Train Loss 1.264727 | Val Loss 0.692668
# Epoch 200 | Train Loss 1.133792 | Val Loss 0.711977
# Epoch 300 | Train Loss 1.041645 | Val Loss 0.737831
# Epoch 400 | Train Loss 0.955984 | Val Loss 0.756993
# Epoch 500 | Train Loss 0.909803 | Val Loss 0.798106
# Epoch 600 | Train Loss 0.851304 | Val Loss 0.802018
# Early stopping at epoch 667
# Theta | train1 -> R² = 0.8626, MSE = 3.1502e-02
# X | train1 -> R² = -0.0731, MSE = 1.1502e-01
# Y | train1 -> R² = -0.3766, MSE = 1.1506e-01
# Theta | train2 -> R² = -0.0272, MSE = 2.3292e-01
# X | train2 -> R² = 0.1229, MSE = 7.3723e-02
# Y | train2 -> R² = -0.9478, MSE = 2.0855e-01
# Theta | test1 -> R² = 0.8771, MSE = 2.8360e-02
# X | test1 -> R² = 0.1291, MSE = 9.0663e-02
# Y | test1 -> R² = -1.2153, MSE = 1.8094e-01
# Theta | test2 -> R² = 0.2690, MSE = 1.7221e-01
# X | test2 -> R² = 0.0032, MSE = 8.1832e-02
# Y | test2 -> R² = -1.3167, MSE = 2.4458e-01
# Theta | test3 -> R² = -1.2050, MSE = 7.2673e-01
# X | test3 -> R² = 0.3349, MSE = 6.0852e-02
# Y | test3 -> R² = -2.0774, MSE = 2.3554e-01
# Theta | val -> R² = -0.0057, MSE = 3.2999e-01
# X | val -> R² = 0.3151, MSE = 6.5092e-02
# Y | val -> R² = -2.7133, MSE = 2.7559e-01
# Figura salva em: ./results/model_264_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.655549 | Val Loss 0.716936
# Epoch 100 | Train Loss 1.269493 | Val Loss 0.692805
# Epoch 200 | Train Loss 1.129555 | Val Loss 0.703936
# Epoch 300 | Train Loss 1.025420 | Val Loss 0.764050
# Epoch 400 | Train Loss 0.940899 | Val Loss 0.787895
# Epoch 500 | Train Loss 0.882467 | Val Loss 0.824298
# Epoch 600 | Train Loss 0.847618 | Val Loss 0.871403
# Early stopping at epoch 632
# Theta | train1 -> R² = 0.8265, MSE = 3.9758e-02
# X | train1 -> R² = -0.0907, MSE = 1.1690e-01
# Y | train1 -> R² = -0.6249, MSE = 1.3581e-01
# Theta | train2 -> R² = 0.1508, MSE = 1.9256e-01
# X | train2 -> R² = 0.1072, MSE = 7.5037e-02
# Y | train2 -> R² = -0.9387, MSE = 2.0758e-01
# Theta | test1 -> R² = 0.7866, MSE = 4.9222e-02
# X | test1 -> R² = 0.0619, MSE = 9.7654e-02
# Y | test1 -> R² = -1.4788, MSE = 2.0247e-01
# Theta | test2 -> R² = 0.4767, MSE = 1.2328e-01
# X | test2 -> R² = 0.0220, MSE = 8.0289e-02
# Y | test2 -> R² = -1.3407, MSE = 2.4712e-01
# Theta | test3 -> R² = -0.6916, MSE = 5.5750e-01
# X | test3 -> R² = 0.2450, MSE = 6.9075e-02
# Y | test3 -> R² = -1.6471, MSE = 2.0261e-01
# Theta | val -> R² = 0.3396, MSE = 2.1668e-01
# X | val -> R² = 0.2080, MSE = 7.5277e-02
# Y | val -> R² = -2.1453, MSE = 2.3343e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.581905 | Val Loss 0.852277
# Epoch 100 | Train Loss 1.252937 | Val Loss 0.687397
# Epoch 200 | Train Loss 1.132724 | Val Loss 0.725001
# Epoch 300 | Train Loss 1.027246 | Val Loss 0.777429
# Epoch 400 | Train Loss 0.936579 | Val Loss 0.824181
# Epoch 500 | Train Loss 0.873868 | Val Loss 0.890721
# Epoch 600 | Train Loss 0.836804 | Val Loss 0.936613
# Early stopping at epoch 629
# Theta | train1 -> R² = 0.9224, MSE = 1.7794e-02
# X | train1 -> R² = 0.0715, MSE = 9.9519e-02
# Y | train1 -> R² = -0.6937, MSE = 1.4156e-01
# Theta | train2 -> R² = 0.0420, MSE = 2.1722e-01
# X | train2 -> R² = 0.0105, MSE = 8.3165e-02
# Y | train2 -> R² = -0.8981, MSE = 2.0324e-01
# Theta | test1 -> R² = 0.9249, MSE = 1.7327e-02
# X | test1 -> R² = 0.1827, MSE = 8.5074e-02
# Y | test1 -> R² = -1.4085, MSE = 1.9673e-01
# Theta | test2 -> R² = 0.4753, MSE = 1.2361e-01
# X | test2 -> R² = 0.0093, MSE = 8.1334e-02
# Y | test2 -> R² = -1.2838, MSE = 2.4112e-01
# Theta | test3 -> R² = -1.8389, MSE = 9.3566e-01
# X | test3 -> R² = 0.3612, MSE = 5.8445e-02
# Y | test3 -> R² = -2.3572, MSE = 2.5696e-01
# Theta | val -> R² = -0.1817, MSE = 3.8773e-01
# X | val -> R² = 0.3301, MSE = 6.3672e-02
# Y | val -> R² = -2.5901, MSE = 2.6644e-01
# Figura salva em: ./results/model_264_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.630156 | Val Loss 0.826251
# Epoch 100 | Train Loss 1.269500 | Val Loss 0.692056
# Epoch 200 | Train Loss 1.160382 | Val Loss 0.704111
# Epoch 300 | Train Loss 1.046171 | Val Loss 0.745623
# Epoch 400 | Train Loss 0.957907 | Val Loss 0.788562
# Epoch 500 | Train Loss 0.890042 | Val Loss 0.829244
# Early stopping at epoch 506
# Theta | train1 -> R² = 0.3998, MSE = 1.3758e-01
# X | train1 -> R² = 0.3068, MSE = 7.4293e-02
# Y | train1 -> R² = -1.3295, MSE = 1.9470e-01
# Theta | train2 -> R² = 0.0465, MSE = 2.1620e-01
# X | train2 -> R² = -0.1421, MSE = 9.5994e-02
# Y | train2 -> R² = -1.5867, MSE = 2.7696e-01
# Theta | test1 -> R² = 0.2262, MSE = 1.7849e-01
# X | test1 -> R² = 0.2597, MSE = 7.7068e-02
# Y | test1 -> R² = -1.5367, MSE = 2.0720e-01
# Theta | test2 -> R² = 0.0072, MSE = 2.3388e-01
# X | test2 -> R² = -0.1340, MSE = 9.3093e-02
# Y | test2 -> R² = -1.4873, MSE = 2.6260e-01
# Theta | test3 -> R² = -0.5399, MSE = 5.0752e-01
# X | test3 -> R² = 0.2399, MSE = 6.9545e-02
# Y | test3 -> R² = -2.1900, MSE = 2.4417e-01
# Theta | val -> R² = -0.2858, MSE = 4.2188e-01
# X | val -> R² = 0.2220, MSE = 7.3939e-02
# Y | val -> R² = -2.0340, MSE = 2.2517e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570505 | Val Loss 0.803488
# Epoch 100 | Train Loss 1.458651 | Val Loss 0.771427
# Epoch 200 | Train Loss 1.432272 | Val Loss 0.756166
# Epoch 300 | Train Loss 1.373038 | Val Loss 0.794518
# Epoch 400 | Train Loss 1.342049 | Val Loss 0.741600
# Epoch 500 | Train Loss 1.329281 | Val Loss 0.738169
# Epoch 600 | Train Loss 1.315793 | Val Loss 0.747589
# Epoch 700 | Train Loss 1.299057 | Val Loss 0.751052
# Epoch 800 | Train Loss 1.287481 | Val Loss 0.763346
# Epoch 900 | Train Loss 1.282947 | Val Loss 0.769775
# Early stopping at epoch 946
# Theta | train1 -> R² = 0.6876, MSE = 7.1610e-02
# X | train1 -> R² = -0.1722, MSE = 1.2563e-01
# Y | train1 -> R² = -0.7593, MSE = 1.4704e-01
# Theta | train2 -> R² = 0.4093, MSE = 1.3394e-01
# X | train2 -> R² = -0.2410, MSE = 1.0431e-01
# Y | train2 -> R² = -0.9377, MSE = 2.0747e-01
# Theta | test1 -> R² = 0.8448, MSE = 3.5789e-02
# X | test1 -> R² = -0.1489, MSE = 1.1959e-01
# Y | test1 -> R² = -0.8421, MSE = 1.5046e-01
# Theta | test2 -> R² = 0.4247, MSE = 1.3553e-01
# X | test2 -> R² = -0.2252, MSE = 1.0059e-01
# Y | test2 -> R² = -0.8802, MSE = 1.9850e-01
# Theta | test3 -> R² = -40.9033, MSE = 1.3811e+01
# X | test3 -> R² = -0.1769, MSE = 1.0767e-01
# Y | test3 -> R² = 0.3019, MSE = 5.3430e-02
# Theta | val -> R² = -26.7273, MSE = 9.0978e+00
# X | val -> R² = -0.1116, MSE = 1.0565e-01
# Y | val -> R² = 0.0909, MSE = 6.7468e-02
# Figura salva em: ./results/model_8_4_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.571502 | Val Loss 0.804775
# Epoch 100 | Train Loss 1.453874 | Val Loss 0.764552
# Epoch 200 | Train Loss 1.357580 | Val Loss 0.708740
# Epoch 300 | Train Loss 1.331400 | Val Loss 0.716286
# Epoch 400 | Train Loss 1.308218 | Val Loss 0.722605
# Epoch 500 | Train Loss 1.288023 | Val Loss 0.724982
# Epoch 600 | Train Loss 1.274193 | Val Loss 0.731071
# Epoch 700 | Train Loss 1.265193 | Val Loss 0.741231
# Early stopping at epoch 703
# Theta | train1 -> R² = 0.6220, MSE = 8.6642e-02
# X | train1 -> R² = -0.3309, MSE = 1.4265e-01
# Y | train1 -> R² = -1.0311, MSE = 1.6976e-01
# Theta | train2 -> R² = -0.0029, MSE = 2.2739e-01
# X | train2 -> R² = -0.2921, MSE = 1.0860e-01
# Y | train2 -> R² = -1.1454, MSE = 2.2972e-01
# Theta | test1 -> R² = 0.6252, MSE = 8.6442e-02
# X | test1 -> R² = -0.4767, MSE = 1.5372e-01
# Y | test1 -> R² = -1.4142, MSE = 1.9719e-01
# Theta | test2 -> R² = 0.0127, MSE = 2.3260e-01
# X | test2 -> R² = -0.2739, MSE = 1.0458e-01
# Y | test2 -> R² = -1.0500, MSE = 2.1643e-01
# Theta | test3 -> R² = 0.4028, MSE = 1.9684e-01
# X | test3 -> R² = -0.6285, MSE = 1.4900e-01
# Y | test3 -> R² = -3.0762, MSE = 3.1199e-01
# Theta | val -> R² = 0.6918, MSE = 1.0112e-01
# X | val -> R² = -0.6861, MSE = 1.6025e-01
# Y | val -> R² = -3.0920, MSE = 3.0369e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.568575 | Val Loss 0.801682
# Epoch 100 | Train Loss 1.459452 | Val Loss 0.778303
# Epoch 200 | Train Loss 1.453009 | Val Loss 0.775565
# Epoch 300 | Train Loss 1.429037 | Val Loss 0.769648
# Epoch 400 | Train Loss 1.344342 | Val Loss 0.719656
# Epoch 500 | Train Loss 1.318166 | Val Loss 0.710852
# Epoch 600 | Train Loss 1.304414 | Val Loss 0.714503
# Epoch 700 | Train Loss 1.284919 | Val Loss 0.733844
# Epoch 800 | Train Loss 1.264950 | Val Loss 0.754458
# Epoch 900 | Train Loss 1.254822 | Val Loss 0.759278
# Early stopping at epoch 941
# Theta | train1 -> R² = 0.7261, MSE = 6.2777e-02
# X | train1 -> R² = -0.3698, MSE = 1.4681e-01
# Y | train1 -> R² = -1.0832, MSE = 1.7411e-01
# Theta | train2 -> R² = 0.3446, MSE = 1.4860e-01
# X | train2 -> R² = -0.2408, MSE = 1.0429e-01
# Y | train2 -> R² = -1.0014, MSE = 2.1429e-01
# Theta | test1 -> R² = 0.8786, MSE = 2.8011e-02
# X | test1 -> R² = -0.5466, MSE = 1.6100e-01
# Y | test1 -> R² = -1.4808, MSE = 2.0263e-01
# Theta | test2 -> R² = 0.3583, MSE = 1.5117e-01
# X | test2 -> R² = -0.2687, MSE = 1.0415e-01
# Y | test2 -> R² = -0.9983, MSE = 2.1097e-01
# Theta | test3 -> R² = -8.3457, MSE = 3.0802e+00
# X | test3 -> R² = -1.4258, MSE = 2.2195e-01
# Y | test3 -> R² = -3.2330, MSE = 3.2400e-01
# Theta | val -> R² = -4.9729, MSE = 1.9598e+00
# X | val -> R² = -1.4877, MSE = 2.3643e-01
# Y | val -> R² = -3.1562, MSE = 3.0845e-01
# Figura salva em: ./results/model_8_4_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.575002 | Val Loss 0.804501
# Epoch 100 | Train Loss 1.460089 | Val Loss 0.773113
# Epoch 200 | Train Loss 1.442431 | Val Loss 0.760873
# Epoch 300 | Train Loss 1.322252 | Val Loss 0.728047
# Epoch 400 | Train Loss 1.302738 | Val Loss 0.738614
# Epoch 500 | Train Loss 1.292655 | Val Loss 0.745064
# Epoch 600 | Train Loss 1.281236 | Val Loss 0.752649
# Epoch 700 | Train Loss 1.267808 | Val Loss 0.757306
# Early stopping at epoch 772
# Theta | train1 -> R² = 0.5284, MSE = 1.0810e-01
# X | train1 -> R² = -0.4445, MSE = 1.5482e-01
# Y | train1 -> R² = -1.2055, MSE = 1.8434e-01
# Theta | train2 -> R² = 0.0621, MSE = 2.1266e-01
# X | train2 -> R² = -0.3683, MSE = 1.1501e-01
# Y | train2 -> R² = -1.2599, MSE = 2.4197e-01
# Theta | test1 -> R² = 0.5999, MSE = 9.2297e-02
# X | test1 -> R² = -0.5672, MSE = 1.6314e-01
# Y | test1 -> R² = -1.5549, MSE = 2.0868e-01
# Theta | test2 -> R² = 0.0492, MSE = 2.2400e-01
# X | test2 -> R² = -0.3475, MSE = 1.1062e-01
# Y | test2 -> R² = -1.1848, MSE = 2.3066e-01
# Theta | test3 -> R² = 0.6266, MSE = 1.2306e-01
# X | test3 -> R² = -0.8434, MSE = 1.6866e-01
# Y | test3 -> R² = -2.2384, MSE = 2.4787e-01
# Theta | val -> R² = 0.4687, MSE = 1.7434e-01
# X | val -> R² = -0.9276, MSE = 1.8320e-01
# Y | val -> R² = -2.3579, MSE = 2.4921e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570562 | Val Loss 0.803891
# Epoch 100 | Train Loss 1.445561 | Val Loss 0.775245
# Epoch 200 | Train Loss 1.365900 | Val Loss 0.723574
# Epoch 300 | Train Loss 1.323704 | Val Loss 0.726788
# Epoch 400 | Train Loss 1.307361 | Val Loss 0.727510
# Epoch 500 | Train Loss 1.297444 | Val Loss 0.736329
# Epoch 600 | Train Loss 1.287023 | Val Loss 0.744689
# Epoch 700 | Train Loss 1.272795 | Val Loss 0.749456
# Early stopping at epoch 708
# Theta | train1 -> R² = 0.6544, MSE = 7.9204e-02
# X | train1 -> R² = -0.3062, MSE = 1.4000e-01
# Y | train1 -> R² = -1.1411, MSE = 1.7895e-01
# Theta | train2 -> R² = -0.5658, MSE = 3.5504e-01
# X | train2 -> R² = -0.1312, MSE = 9.5077e-02
# Y | train2 -> R² = -0.8767, MSE = 2.0094e-01
# Theta | test1 -> R² = 0.5247, MSE = 1.0963e-01
# X | test1 -> R² = -0.4843, MSE = 1.5451e-01
# Y | test1 -> R² = -1.4859, MSE = 2.0305e-01
# Theta | test2 -> R² = -0.3661, MSE = 3.2182e-01
# X | test2 -> R² = -0.1405, MSE = 9.3629e-02
# Y | test2 -> R² = -0.8743, MSE = 1.9788e-01
# Theta | test3 -> R² = 0.3531, MSE = 2.1321e-01
# X | test3 -> R² = -2.5994, MSE = 3.2932e-01
# Y | test3 -> R² = -7.4575, MSE = 6.4734e-01
# Theta | val -> R² = 0.5939, MSE = 1.3324e-01
# X | val -> R² = -2.5298, MSE = 3.3548e-01
# Y | val -> R² = -6.7138, MSE = 5.7249e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.570168 | Val Loss 0.804716
# Epoch 100 | Train Loss 1.462162 | Val Loss 0.765340
# Epoch 200 | Train Loss 1.434034 | Val Loss 0.748847
# Epoch 300 | Train Loss 1.323272 | Val Loss 0.715616
# Epoch 400 | Train Loss 1.306269 | Val Loss 0.721911
# Epoch 500 | Train Loss 1.287055 | Val Loss 0.724558
# Epoch 600 | Train Loss 1.273276 | Val Loss 0.730144
# Epoch 700 | Train Loss 1.262710 | Val Loss 0.741184
# Early stopping at epoch 740
# Theta | train1 -> R² = 0.6650, MSE = 7.6780e-02
# X | train1 -> R² = -0.2346, MSE = 1.3233e-01
# Y | train1 -> R² = -1.2127, MSE = 1.8493e-01
# Theta | train2 -> R² = -0.2813, MSE = 2.9051e-01
# X | train2 -> R² = -0.2617, MSE = 1.0605e-01
# Y | train2 -> R² = -1.2370, MSE = 2.3952e-01
# Theta | test1 -> R² = 0.7819, MSE = 5.0309e-02
# X | test1 -> R² = -0.3974, MSE = 1.4547e-01
# Y | test1 -> R² = -1.5634, MSE = 2.0938e-01
# Theta | test2 -> R² = -0.1775, MSE = 2.7740e-01
# X | test2 -> R² = -0.2583, MSE = 1.0330e-01
# Y | test2 -> R² = -1.1810, MSE = 2.3026e-01
# Theta | test3 -> R² = 0.3472, MSE = 2.1516e-01
# X | test3 -> R² = -0.6741, MSE = 1.5317e-01
# Y | test3 -> R² = -2.9692, MSE = 3.0380e-01
# Theta | val -> R² = 0.6239, MSE = 1.2342e-01
# X | val -> R² = -0.6504, MSE = 1.5686e-01
# Y | val -> R² = -2.9165, MSE = 2.9067e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572345 | Val Loss 0.803356
# Epoch 100 | Train Loss 1.462930 | Val Loss 0.776530
# Epoch 200 | Train Loss 1.393895 | Val Loss 0.739078
# Epoch 300 | Train Loss 1.322186 | Val Loss 0.727869
# Epoch 400 | Train Loss 1.303021 | Val Loss 0.742037
# Epoch 500 | Train Loss 1.286220 | Val Loss 0.763238
# Epoch 600 | Train Loss 1.269861 | Val Loss 0.805146
# Epoch 700 | Train Loss 1.260522 | Val Loss 0.851266
# Early stopping at epoch 717
# Theta | train1 -> R² = 0.5659, MSE = 9.9496e-02
# X | train1 -> R² = -0.4463, MSE = 1.5501e-01
# Y | train1 -> R² = -0.9377, MSE = 1.6195e-01
# Theta | train2 -> R² = -0.4361, MSE = 3.2563e-01
# X | train2 -> R² = -0.3312, MSE = 1.1188e-01
# Y | train2 -> R² = -1.0738, MSE = 2.2204e-01
# Theta | test1 -> R² = 0.6475, MSE = 8.1308e-02
# X | test1 -> R² = -0.6293, MSE = 1.6961e-01
# Y | test1 -> R² = -1.3548, MSE = 1.9234e-01
# Theta | test2 -> R² = -0.3936, MSE = 3.2831e-01
# X | test2 -> R² = -0.2906, MSE = 1.0595e-01
# Y | test2 -> R² = -1.0015, MSE = 2.1131e-01
# Theta | test3 -> R² = -3.2366, MSE = 1.3963e+00
# X | test3 -> R² = -0.7222, MSE = 1.5757e-01
# Y | test3 -> R² = -1.9822, MSE = 2.2826e-01
# Theta | val -> R² = -1.5916, MSE = 8.5034e-01
# X | val -> R² = -0.7878, MSE = 1.6991e-01
# Y | val -> R² = -1.9900, MSE = 2.2191e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.576927 | Val Loss 0.806569
# Epoch 100 | Train Loss 1.459935 | Val Loss 0.775548
# Epoch 200 | Train Loss 1.364533 | Val Loss 0.717100
# Epoch 300 | Train Loss 1.326660 | Val Loss 0.706944
# Epoch 400 | Train Loss 1.307541 | Val Loss 0.705169
# Epoch 500 | Train Loss 1.291935 | Val Loss 0.708977
# Epoch 600 | Train Loss 1.279964 | Val Loss 0.709372
# Epoch 700 | Train Loss 1.266252 | Val Loss 0.713489
# Early stopping at epoch 722
# Theta | train1 -> R² = 0.7140, MSE = 6.5548e-02
# X | train1 -> R² = -0.3275, MSE = 1.4228e-01
# Y | train1 -> R² = -1.1036, MSE = 1.7582e-01
# Theta | train2 -> R² = 0.1484, MSE = 1.9309e-01
# X | train2 -> R² = -0.2570, MSE = 1.0565e-01
# Y | train2 -> R² = -1.0713, MSE = 2.2178e-01
# Theta | test1 -> R² = 0.7798, MSE = 5.0795e-02
# X | test1 -> R² = -0.4787, MSE = 1.5392e-01
# Y | test1 -> R² = -1.4347, MSE = 1.9887e-01
# Theta | test2 -> R² = 0.1666, MSE = 1.9632e-01
# X | test2 -> R² = -0.2097, MSE = 9.9308e-02
# Y | test2 -> R² = -0.9959, MSE = 2.1072e-01
# Theta | test3 -> R² = 0.0605, MSE = 3.0963e-01
# X | test3 -> R² = -0.4448, MSE = 1.3219e-01
# Y | test3 -> R² = -1.2844, MSE = 1.7484e-01
# Theta | val -> R² = 0.5983, MSE = 1.3179e-01
# X | val -> R² = -0.4979, MSE = 1.4237e-01
# Y | val -> R² = -1.4661, MSE = 1.8303e-01
# ...
# X | test2 -> R² = -0.1973, MSE = 9.8294e-02
# Y | test2 -> R² = -0.7913, MSE = 1.8912e-01
# Theta | test3 -> R² = 0.6500, MSE = 1.1536e-01
# X | test3 -> R² = -0.4738, MSE = 1.3484e-01
# Y | test3 -> R² = -2.3089, MSE = 2.5327e-01
# Theta | val -> R² = 0.6008, MSE = 1.3098e-01
# X | val -> R² = -0.4875, MSE = 1.4138e-01
# Y | val -> R² = -2.2038, MSE = 2.3777e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.520720 | Val Loss 0.779040
# Epoch 100 | Train Loss 1.247412 | Val Loss 0.715809
# Epoch 200 | Train Loss 1.146650 | Val Loss 0.720956
# Epoch 300 | Train Loss 1.031629 | Val Loss 0.785530
# Epoch 400 | Train Loss 0.943453 | Val Loss 0.845855
# Epoch 500 | Train Loss 0.891781 | Val Loss 0.927135
# Early stopping at epoch 511
# Theta | train1 -> R² = 0.7550, MSE = 5.6151e-02
# X | train1 -> R² = -0.1342, MSE = 1.2157e-01
# Y | train1 -> R² = -0.5814, MSE = 1.3217e-01
# Theta | train2 -> R² = 0.1300, MSE = 1.9727e-01
# X | train2 -> R² = 0.1161, MSE = 7.4292e-02
# Y | train2 -> R² = -0.6374, MSE = 1.7532e-01
# Theta | test1 -> R² = 0.6975, MSE = 6.9784e-02
# X | test1 -> R² = -0.2152, MSE = 1.2649e-01
# Y | test1 -> R² = -0.7776, MSE = 1.4520e-01
# Theta | test2 -> R² = 0.1368, MSE = 2.0336e-01
# X | test2 -> R² = 0.1185, MSE = 7.2369e-02
# Y | test2 -> R² = -0.5840, MSE = 1.6723e-01
# Theta | test3 -> R² = 0.2317, MSE = 2.5323e-01
# X | test3 -> R² = -0.3466, MSE = 1.2321e-01
# Y | test3 -> R² = -0.8470, MSE = 1.4137e-01
# Theta | val -> R² = 0.5115, MSE = 1.6028e-01
# X | val -> R² = -0.3259, MSE = 1.2601e-01
# Y | val -> R² = -0.9837, MSE = 1.4722e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.572086 | Val Loss 0.779727
# Epoch 100 | Train Loss 1.250763 | Val Loss 0.720367
# Epoch 200 | Train Loss 1.168404 | Val Loss 0.719508
# Epoch 300 | Train Loss 1.087248 | Val Loss 0.769726
# Epoch 400 | Train Loss 0.991374 | Val Loss 0.846110
# Epoch 500 | Train Loss 0.944213 | Val Loss 0.986523
# Early stopping at epoch 517
# Theta | train1 -> R² = 0.7878, MSE = 4.8641e-02
# X | train1 -> R² = 0.0226, MSE = 1.0476e-01
# Y | train1 -> R² = -0.4853, MSE = 1.2414e-01
# Theta | train2 -> R² = 0.3414, MSE = 1.4933e-01
# X | train2 -> R² = 0.0190, MSE = 8.2451e-02
# Y | train2 -> R² = -0.6555, MSE = 1.7725e-01
# Theta | test1 -> R² = 0.7451, MSE = 5.8794e-02
# X | test1 -> R² = -0.0220, MSE = 1.0639e-01
# Y | test1 -> R² = -0.6401, MSE = 1.3396e-01
# Theta | test2 -> R² = 0.3781, MSE = 1.4651e-01
# X | test2 -> R² = 0.0428, MSE = 7.8576e-02
# Y | test2 -> R² = -0.5504, MSE = 1.6368e-01
# Theta | test3 -> R² = 0.6309, MSE = 1.2164e-01
# X | test3 -> R² = -0.1772, MSE = 1.0771e-01
# Y | test3 -> R² = -1.2890, MSE = 1.7520e-01
# Theta | val -> R² = 0.8049, MSE = 6.4023e-02
# X | val -> R² = -0.2144, MSE = 1.1542e-01
# Y | val -> R² = -1.3655, MSE = 1.7556e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.584115 | Val Loss 0.781848
# Epoch 100 | Train Loss 1.265885 | Val Loss 0.721336
# Epoch 200 | Train Loss 1.170687 | Val Loss 0.736160
# Epoch 300 | Train Loss 1.076004 | Val Loss 0.796548
# Epoch 400 | Train Loss 0.991400 | Val Loss 0.853497
# Epoch 500 | Train Loss 0.929633 | Val Loss 0.963784
# Early stopping at epoch 515
# Theta | train1 -> R² = 0.7656, MSE = 5.3735e-02
# X | train1 -> R² = -0.1709, MSE = 1.2550e-01
# Y | train1 -> R² = -0.5941, MSE = 1.3323e-01
# Theta | train2 -> R² = 0.4545, MSE = 1.2369e-01
# X | train2 -> R² = 0.0664, MSE = 7.8470e-02
# Y | train2 -> R² = -0.6858, MSE = 1.8051e-01
# Theta | test1 -> R² = 0.6635, MSE = 7.7627e-02
# X | test1 -> R² = -0.2392, MSE = 1.2900e-01
# Y | test1 -> R² = -0.7708, MSE = 1.4464e-01
# Theta | test2 -> R² = 0.4793, MSE = 1.2266e-01
# X | test2 -> R² = 0.0705, MSE = 7.6310e-02
# Y | test2 -> R² = -0.6231, MSE = 1.7136e-01
# Theta | test3 -> R² = 0.5478, MSE = 1.4905e-01
# X | test3 -> R² = -0.3639, MSE = 1.2479e-01
# Y | test3 -> R² = -1.1633, MSE = 1.6558e-01
# Theta | val -> R² = 0.7655, MSE = 7.6932e-02
# X | val -> R² = -0.4182, MSE = 1.3478e-01
# Y | val -> R² = -1.2256, MSE = 1.6518e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.567163 | Val Loss 0.845864
# Epoch 100 | Train Loss 1.198552 | Val Loss 0.702315
# Epoch 200 | Train Loss 1.025487 | Val Loss 0.800607
# Epoch 300 | Train Loss 0.898913 | Val Loss 0.944882
# Epoch 400 | Train Loss 0.832973 | Val Loss 0.963220
# Epoch 500 | Train Loss 0.795034 | Val Loss 1.017472
# Early stopping at epoch 510
# Theta | train1 -> R² = -0.8199, MSE = 4.1713e-01
# X | train1 -> R² = 0.2740, MSE = 7.7814e-02
# Y | train1 -> R² = -0.7103, MSE = 1.4295e-01
# Theta | train2 -> R² = -0.4243, MSE = 3.2294e-01
# X | train2 -> R² = -0.0800, MSE = 9.0771e-02
# Y | train2 -> R² = -0.8109, MSE = 1.9390e-01
# Theta | test1 -> R² = -1.4970, MSE = 5.7595e-01
# X | test1 -> R² = 0.2082, MSE = 8.2423e-02
# Y | test1 -> R² = -0.9839, MSE = 1.6205e-01
# Theta | test2 -> R² = -0.8274, MSE = 4.3051e-01
# X | test2 -> R² = -0.0668, MSE = 8.7577e-02
# Y | test2 -> R² = -0.7341, MSE = 1.8308e-01
# Theta | test3 -> R² = -3.9241, MSE = 1.6229e+00
# X | test3 -> R² = 0.1570, MSE = 7.7128e-02
# Y | test3 -> R² = -1.1981, MSE = 1.6824e-01
# Theta | val -> R² = -1.9530, MSE = 9.6892e-01
# X | val -> R² = 0.1276, MSE = 8.2917e-02
# Y | val -> R² = -1.3214, MSE = 1.7228e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.593941 | Val Loss 0.700930
# Epoch 100 | Train Loss 1.207930 | Val Loss 0.697005
# Epoch 200 | Train Loss 1.063792 | Val Loss 0.722737
# Epoch 300 | Train Loss 0.896546 | Val Loss 0.767918
# Epoch 400 | Train Loss 0.821170 | Val Loss 0.830868
# Epoch 500 | Train Loss 0.776755 | Val Loss 0.874757
# Early stopping at epoch 508
# Theta | train1 -> R² = 0.6331, MSE = 8.4085e-02
# X | train1 -> R² = 0.1596, MSE = 9.0069e-02
# Y | train1 -> R² = -0.8538, MSE = 1.5494e-01
# Theta | train2 -> R² = 0.2647, MSE = 1.6673e-01
# X | train2 -> R² = -0.0787, MSE = 9.0666e-02
# Y | train2 -> R² = -1.1281, MSE = 2.2786e-01
# Theta | test1 -> R² = 0.5102, MSE = 1.1299e-01
# X | test1 -> R² = 0.0670, MSE = 9.7124e-02
# Y | test1 -> R² = -1.0813, MSE = 1.7000e-01
# Theta | test2 -> R² = 0.2460, MSE = 1.7763e-01
# X | test2 -> R² = -0.0521, MSE = 8.6369e-02
# Y | test2 -> R² = -1.0907, MSE = 2.2073e-01
# Theta | test3 -> R² = -0.1250, MSE = 3.7077e-01
# X | test3 -> R² = 0.0159, MSE = 9.0039e-02
# Y | test3 -> R² = -1.0016, MSE = 1.5320e-01
# Theta | val -> R² = 0.2823, MSE = 2.3549e-01
# X | val -> R² = 0.0523, MSE = 9.0070e-02
# Y | val -> R² = -1.1035, MSE = 1.5611e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.540950 | Val Loss 0.755499
# Epoch 100 | Train Loss 1.191003 | Val Loss 0.719260
# Epoch 200 | Train Loss 1.019359 | Val Loss 0.780439
# Epoch 300 | Train Loss 0.915511 | Val Loss 0.867177
# Epoch 400 | Train Loss 0.819350 | Val Loss 0.973949
# Epoch 500 | Train Loss 0.778835 | Val Loss 1.002783
# Early stopping at epoch 506
# Theta | train1 -> R² = 0.7168, MSE = 6.4907e-02
# X | train1 -> R² = 0.0517, MSE = 1.0164e-01
# Y | train1 -> R² = -1.0497, MSE = 1.7131e-01
# Theta | train2 -> R² = 0.3842, MSE = 1.3963e-01
# X | train2 -> R² = -0.0199, MSE = 8.5724e-02
# Y | train2 -> R² = -1.2554, MSE = 2.4149e-01
# Theta | test1 -> R² = 0.5966, MSE = 9.3038e-02
# X | test1 -> R² = -0.0243, MSE = 1.0663e-01
# Y | test1 -> R² = -1.2614, MSE = 1.8471e-01
# Theta | test2 -> R² = 0.3667, MSE = 1.4919e-01
# X | test2 -> R² = 0.0258, MSE = 7.9973e-02
# Y | test2 -> R² = -1.1931, MSE = 2.3154e-01
# Theta | test3 -> R² = 0.2028, MSE = 2.6274e-01
# X | test3 -> R² = -0.0598, MSE = 9.6966e-02
# Y | test3 -> R² = -1.6841, MSE = 2.0544e-01
# Theta | val -> R² = 0.5454, MSE = 1.4917e-01
# X | val -> R² = -0.0588, MSE = 1.0063e-01
# Y | val -> R² = -1.6822, MSE = 1.9906e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.518973 | Val Loss 0.784013
# Epoch 100 | Train Loss 1.188775 | Val Loss 0.699448
# Epoch 200 | Train Loss 1.023503 | Val Loss 0.758322
# Epoch 300 | Train Loss 0.886850 | Val Loss 0.839529
# Epoch 400 | Train Loss 0.827835 | Val Loss 0.939519
# Epoch 500 | Train Loss 0.782672 | Val Loss 0.970881
# Early stopping at epoch 561
# Theta | train1 -> R² = 0.7647, MSE = 5.3942e-02
# X | train1 -> R² = 0.0214, MSE = 1.0488e-01
# Y | train1 -> R² = -0.7755, MSE = 1.4840e-01
# Theta | train2 -> R² = 0.6223, MSE = 8.5634e-02
# X | train2 -> R² = -0.1442, MSE = 9.6167e-02
# Y | train2 -> R² = -0.8428, MSE = 1.9731e-01
# Theta | test1 -> R² = 0.7166, MSE = 6.5379e-02
# X | test1 -> R² = 0.1558, MSE = 8.7877e-02
# Y | test1 -> R² = -1.2055, MSE = 1.8015e-01
# Theta | test2 -> R² = 0.7172, MSE = 6.6620e-02
# X | test2 -> R² = -0.0054, MSE = 8.2539e-02
# Y | test2 -> R² = -1.0156, MSE = 2.1280e-01
# Theta | test3 -> R² = -0.6683, MSE = 5.4984e-01
# X | test3 -> R² = 0.2718, MSE = 6.6626e-02
# Y | test3 -> R² = -3.6796, MSE = 3.5817e-01
# Theta | val -> R² = 0.4453, MSE = 1.8202e-01
# X | val -> R² = 0.3054, MSE = 6.6020e-02
# Y | val -> R² = -3.7235, MSE = 3.5056e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.558788 | Val Loss 0.696867
# Epoch 100 | Train Loss 1.211884 | Val Loss 0.695060
# Epoch 200 | Train Loss 1.055530 | Val Loss 0.726443
# Epoch 300 | Train Loss 0.931551 | Val Loss 0.820400
# Epoch 400 | Train Loss 0.852387 | Val Loss 0.922497
# Epoch 500 | Train Loss 0.802506 | Val Loss 0.981196
# Epoch 600 | Train Loss 0.773936 | Val Loss 1.008646
# Early stopping at epoch 612
# Theta | train1 -> R² = 0.8349, MSE = 3.7835e-02
# X | train1 -> R² = 0.0131, MSE = 1.0578e-01
# Y | train1 -> R² = -0.3440, MSE = 1.1233e-01
# Theta | train2 -> R² = -0.3909, MSE = 3.1537e-01
# X | train2 -> R² = -0.1669, MSE = 9.8074e-02
# Y | train2 -> R² = -0.7612, MSE = 1.8858e-01
# Theta | test1 -> R² = 0.8741, MSE = 2.9051e-02
# X | test1 -> R² = 0.1411, MSE = 8.9405e-02
# Y | test1 -> R² = -0.9674, MSE = 1.6070e-01
# Theta | test2 -> R² = 0.2418, MSE = 1.7862e-01
# X | test2 -> R² = -0.0676, MSE = 8.7644e-02
# Y | test2 -> R² = -1.1240, MSE = 2.2424e-01
# Theta | test3 -> R² = 0.4263, MSE = 1.8909e-01
# X | test3 -> R² = 0.3416, MSE = 6.0236e-02
# Y | test3 -> R² = -2.4749, MSE = 2.6597e-01
# Theta | val -> R² = -0.4128, MSE = 4.6356e-01
# X | val -> R² = 0.3394, MSE = 6.2789e-02
# Y | val -> R² = -2.7530, MSE = 2.7853e-01
# Figura salva em: ./results/model_264_128_64_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.663543 | Val Loss 0.783373
# Epoch 100 | Train Loss 1.198448 | Val Loss 0.713192
# Epoch 200 | Train Loss 1.080128 | Val Loss 0.757089
# Epoch 300 | Train Loss 0.962579 | Val Loss 0.858454
# Epoch 400 | Train Loss 0.831631 | Val Loss 0.922276
# Epoch 500 | Train Loss 0.805480 | Val Loss 0.977884
# Early stopping at epoch 507
# Theta | train1 -> R² = 0.4430, MSE = 1.2767e-01
# X | train1 -> R² = -0.1895, MSE = 1.2749e-01
# Y | train1 -> R² = -1.0103, MSE = 1.6802e-01
# Theta | train2 -> R² = 0.2732, MSE = 1.6479e-01
# X | train2 -> R² = -0.1151, MSE = 9.3725e-02
# Y | train2 -> R² = -1.2687, MSE = 2.4291e-01
# Theta | test1 -> R² = 0.1799, MSE = 1.8918e-01
# X | test1 -> R² = -0.3080, MSE = 1.3616e-01
# Y | test1 -> R² = -1.2137, MSE = 1.8082e-01
# Theta | test2 -> R² = 0.1715, MSE = 1.9519e-01
# X | test2 -> R² = -0.0783, MSE = 8.8520e-02
# Y | test2 -> R² = -1.1957, MSE = 2.3181e-01
# Theta | test3 -> R² = -2.1110, MSE = 1.0253e+00
# X | test3 -> R² = -0.2826, MSE = 1.1735e-01
# Y | test3 -> R² = -1.5166, MSE = 1.9262e-01
# Theta | val -> R² = -0.7550, MSE = 5.7583e-01
# X | val -> R² = -0.2909, MSE = 1.2269e-01
# Y | val -> R² = -1.5297, MSE = 1.8774e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.565446 | Val Loss 0.766998
# Epoch 100 | Train Loss 1.200523 | Val Loss 0.711190
# Epoch 200 | Train Loss 1.042830 | Val Loss 0.790800
# Epoch 300 | Train Loss 0.954569 | Val Loss 0.833784
# Epoch 400 | Train Loss 0.852914 | Val Loss 0.884720
# Epoch 500 | Train Loss 0.805292 | Val Loss 0.938676
# Early stopping at epoch 572
# Theta | train1 -> R² = 0.9201, MSE = 1.8325e-02
# X | train1 -> R² = 0.0089, MSE = 1.0623e-01
# Y | train1 -> R² = -0.7366, MSE = 1.4514e-01
# Theta | train2 -> R² = 0.1816, MSE = 1.8556e-01
# X | train2 -> R² = -0.2248, MSE = 1.0294e-01
# Y | train2 -> R² = -0.8734, MSE = 2.0059e-01
# Theta | test1 -> R² = 0.9100, MSE = 2.0758e-02
# X | test1 -> R² = 0.1325, MSE = 9.0305e-02
# Y | test1 -> R² = -1.2292, MSE = 1.8208e-01
# Theta | test2 -> R² = 0.4427, MSE = 1.3128e-01
# X | test2 -> R² = -0.0510, MSE = 8.6281e-02
# Y | test2 -> R² = -1.1271, MSE = 2.2457e-01
# Theta | test3 -> R² = -0.1388, MSE = 3.7531e-01
# X | test3 -> R² = 0.1205, MSE = 8.0468e-02
# Y | test3 -> R² = -4.3750, MSE = 4.1141e-01
# Theta | val -> R² = 0.6794, MSE = 1.0520e-01
# X | val -> R² = 0.1186, MSE = 8.3775e-02
# Y | val -> R² = -4.4170, MSE = 4.0203e-01
# Figura salva em: ./results/model_264_128_64_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.641783 | Val Loss 0.772942
# Epoch 100 | Train Loss 1.200705 | Val Loss 0.708568
# Epoch 200 | Train Loss 1.039231 | Val Loss 0.769064
# Epoch 300 | Train Loss 0.912571 | Val Loss 0.884848
# Epoch 400 | Train Loss 0.843869 | Val Loss 0.962010
# Epoch 500 | Train Loss 0.795376 | Val Loss 1.039318
# Early stopping at epoch 512
# Theta | train1 -> R² = 0.6113, MSE = 8.9099e-02
# X | train1 -> R² = 0.2382, MSE = 8.1645e-02
# Y | train1 -> R² = -0.5014, MSE = 1.2549e-01
# Theta | train2 -> R² = 0.0989, MSE = 2.0431e-01
# X | train2 -> R² = -0.1251, MSE = 9.4562e-02
# Y | train2 -> R² = -0.4982, MSE = 1.6042e-01
# Theta | test1 -> R² = 0.8186, MSE = 4.1833e-02
# X | test1 -> R² = 0.1623, MSE = 8.7202e-02
# Y | test1 -> R² = -0.7238, MSE = 1.4080e-01
# Theta | test2 -> R² = 0.3147, MSE = 1.6144e-01
# X | test2 -> R² = -0.0786, MSE = 8.8548e-02
# Y | test2 -> R² = -0.4119, MSE = 1.4906e-01
# Theta | test3 -> R² = 0.8407, MSE = 5.2514e-02
# X | test3 -> R² = 0.1415, MSE = 7.8547e-02
# Y | test3 -> R² = -0.8844, MSE = 1.4423e-01
# Theta | val -> R² = 0.5429, MSE = 1.4998e-01
# X | val -> R² = 0.1266, MSE = 8.3005e-02
# Y | val -> R² = -1.0854, MSE = 1.5477e-01
# Figura salva em: ./results/model_264_128_64_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.655278 | Val Loss 0.759369
# Epoch 100 | Train Loss 1.193664 | Val Loss 0.712397
# Epoch 200 | Train Loss 1.028411 | Val Loss 0.770154
# Epoch 300 | Train Loss 0.896897 | Val Loss 0.923107
# Epoch 400 | Train Loss 0.825382 | Val Loss 1.068906
# Epoch 500 | Train Loss 0.781750 | Val Loss 1.124597
# Early stopping at epoch 526
# Theta | train1 -> R² = 0.8890, MSE = 2.5452e-02
# X | train1 -> R² = -0.0193, MSE = 1.0925e-01
# Y | train1 -> R² = -1.0117, MSE = 1.6814e-01
# Theta | train2 -> R² = 0.5990, MSE = 9.0927e-02
# X | train2 -> R² = -0.2030, MSE = 1.0111e-01
# Y | train2 -> R² = -1.1292, MSE = 2.2798e-01
# Theta | test1 -> R² = 0.8630, MSE = 3.1595e-02
# X | test1 -> R² = -0.0524, MSE = 1.0955e-01
# Y | test1 -> R² = -1.2575, MSE = 1.8440e-01
# Theta | test2 -> R² = 0.6290, MSE = 8.7396e-02
# X | test2 -> R² = -0.1231, MSE = 9.2203e-02
# Y | test2 -> R² = -1.0371, MSE = 2.1507e-01
# Theta | test3 -> R² = 0.4368, MSE = 1.8562e-01
# X | test3 -> R² = -0.0746, MSE = 9.8319e-02
# Y | test3 -> R² = -2.4949, MSE = 2.6750e-01
# Theta | val -> R² = 0.7728, MSE = 7.4560e-02
# X | val -> R² = -0.0890, MSE = 1.0350e-01
# Y | val -> R² = -2.5104, MSE = 2.6053e-01
# Figura salva em: ./results/model_264_128_64_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 | Train Loss 1.560085 | Val Loss 0.756432
# Epoch 100 | Train Loss 1.195707 | Val Loss 0.724833
# Epoch 200 | Train Loss 1.017783 | Val Loss 0.813178
# Epoch 300 | Train Loss 0.902216 | Val Loss 0.935507
# Epoch 400 | Train Loss 0.823872 | Val Loss 1.014617
# Epoch 500 | Train Loss 0.783165 | Val Loss 1.109302
# Early stopping at epoch 505
# Theta | train1 -> R² = 0.4574, MSE = 1.2437e-01
# X | train1 -> R² = -0.1077, MSE = 1.1873e-01
# Y | train1 -> R² = -1.3973, MSE = 2.0036e-01
# Theta | train2 -> R² = 0.5188, MSE = 1.0910e-01
# X | train2 -> R² = 0.0492, MSE = 7.9917e-02
# Y | train2 -> R² = -1.6641, MSE = 2.8525e-01
# Theta | test1 -> R² = 0.1708, MSE = 1.9126e-01
# X | test1 -> R² = -0.2030, MSE = 1.2523e-01
# Y | test1 -> R² = -1.6644, MSE = 2.1763e-01
# Theta | test2 -> R² = 0.4298, MSE = 1.3432e-01
# X | test2 -> R² = 0.0649, MSE = 7.6764e-02
# Y | test2 -> R² = -1.6248, MSE = 2.7712e-01
# Theta | test3 -> R² = -0.2896, MSE = 4.2502e-01
# X | test3 -> R² = -0.2795, MSE = 1.1707e-01
# Y | test3 -> R² = -2.2304, MSE = 2.4726e-01
# Theta | val -> R² = 0.2408, MSE = 2.4911e-01
# X | val -> R² = -0.2582, MSE = 1.1958e-01
# Y | val -> R² = -2.1394, MSE = 2.3299e-01
# Modelo 9 treinado e salvo no Excel
