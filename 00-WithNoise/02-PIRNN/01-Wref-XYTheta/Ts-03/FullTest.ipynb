# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 3
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 3, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 Loss 1.555509
# Epoch 50 Loss 1.288449
# Epoch 100 Loss 1.282061
# Epoch 150 Loss 1.278834
# Epoch 200 Loss 1.276949
# Epoch 250 Loss 1.268590
# Epoch 300 Loss 1.257714
# Early stopping at epoch 307
# Theta | train1 -> R² = 0.8253, MSE = 3.9887e-02
# X | train1 -> R² = 0.0739, MSE = 9.9858e-02
# Y | train1 -> R² = -0.9288, MSE = 1.6162e-01
# Theta | train2 -> R² = 0.3701, MSE = 1.4382e-01
# X | train2 -> R² = -0.2716, MSE = 1.0714e-01
# Y | train2 -> R² = -0.8430, MSE = 1.9846e-01
# Theta | test1 -> R² = 0.5206, MSE = 1.1013e-01
# X | test1 -> R² = -0.0241, MSE = 1.0728e-01
# Y | test1 -> R² = -1.0748, MSE = 1.7003e-01
# Theta | test2 -> R² = 0.3751, MSE = 1.4821e-01
# X | test2 -> R² = -0.2841, MSE = 1.0567e-01
# Y | test2 -> R² = -0.7961, MSE = 1.9064e-01
# Theta | test3 -> R² = -0.1339, MSE = 3.7277e-01
# X | test3 -> R² = -0.0376, MSE = 9.5461e-02
# Y | test3 -> R² = -1.4890, MSE = 1.9117e-01
# Theta | val -> R² = 0.3065, MSE = 2.2696e-01
# X | val -> R² = -0.0504, MSE = 1.0044e-01
# Y | val -> R² = -1.4604, MSE = 1.8318e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.584338
# Epoch 50 Loss 1.286347
# Epoch 100 Loss 1.280028
# Epoch 150 Loss 1.277476
# Epoch 200 Loss 1.275811
# Epoch 250 Loss 1.296711
# Epoch 300 Loss 1.265153
# Early stopping at epoch 318
# Theta | train1 -> R² = 0.5871, MSE = 9.4263e-02
# X | train1 -> R² = 0.1508, MSE = 9.1565e-02
# Y | train1 -> R² = -1.0226, MSE = 1.6948e-01
# Theta | train2 -> R² = -0.5893, MSE = 3.6285e-01
# X | train2 -> R² = -0.0357, MSE = 8.7268e-02
# Y | train2 -> R² = -0.8225, MSE = 1.9624e-01
# Theta | test1 -> R² = 0.7112, MSE = 6.6354e-02
# X | test1 -> R² = 0.0893, MSE = 9.5403e-02
# Y | test1 -> R² = -1.2257, MSE = 1.8240e-01
# Theta | test2 -> R² = -0.4562, MSE = 3.4535e-01
# X | test2 -> R² = -0.0477, MSE = 8.6219e-02
# Y | test2 -> R² = -0.7852, MSE = 1.8949e-01
# Theta | test3 -> R² = 0.6591, MSE = 1.1206e-01
# X | test3 -> R² = 0.0483, MSE = 8.7561e-02
# Y | test3 -> R² = -1.8172, MSE = 2.1638e-01
# Theta | val -> R² = 0.6318, MSE = 1.2049e-01
# X | val -> R² = 0.0391, MSE = 9.1884e-02
# Y | val -> R² = -1.7341, MSE = 2.0355e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.586453
# Epoch 50 Loss 1.285994
# Epoch 100 Loss 1.282165
# Epoch 150 Loss 1.277875
# Epoch 200 Loss 1.274895
# Epoch 250 Loss 1.270807
# Epoch 300 Loss 1.269876
# Early stopping at epoch 307
# Theta | train1 -> R² = 0.8703, MSE = 2.9616e-02
# X | train1 -> R² = -0.1260, MSE = 1.2141e-01
# Y | train1 -> R² = -0.9709, MSE = 1.6515e-01
# Theta | train2 -> R² = 0.5864, MSE = 9.4415e-02
# X | train2 -> R² = -0.2715, MSE = 1.0714e-01
# Y | train2 -> R² = -1.0406, MSE = 2.1973e-01
# Theta | test1 -> R² = 0.6150, MSE = 8.8443e-02
# X | test1 -> R² = -0.1932, MSE = 1.2500e-01
# Y | test1 -> R² = -1.1786, MSE = 1.7854e-01
# Theta | test2 -> R² = 0.6144, MSE = 9.1451e-02
# X | test2 -> R² = -0.2822, MSE = 1.0552e-01
# Y | test2 -> R² = -1.0045, MSE = 2.1276e-01
# Theta | test3 -> R² = 0.2857, MSE = 2.3481e-01
# X | test3 -> R² = -0.2631, MSE = 1.1621e-01
# Y | test3 -> R² = -1.6371, MSE = 2.0255e-01
# Theta | val -> R² = 0.5915, MSE = 1.3369e-01
# X | val -> R² = -0.3181, MSE = 1.2604e-01
# Y | val -> R² = -1.5208, MSE = 1.8767e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.555127
# Epoch 50 Loss 1.290524
# Epoch 100 Loss 1.282327
# Epoch 150 Loss 1.278900
# Epoch 200 Loss 1.282516
# Epoch 250 Loss 1.273358
# Epoch 300 Loss 1.268963
# Epoch 350 Loss 1.272612
# Early stopping at epoch 374
# Theta | train1 -> R² = 0.8407, MSE = 3.6374e-02
# X | train1 -> R² = -0.2296, MSE = 1.3258e-01
# Y | train1 -> R² = -0.9137, MSE = 1.6036e-01
# Theta | train2 -> R² = 0.4762, MSE = 1.1958e-01
# X | train2 -> R² = -0.1940, MSE = 1.0061e-01
# Y | train2 -> R² = -0.8510, MSE = 1.9931e-01
# Theta | test1 -> R² = 0.6267, MSE = 8.5756e-02
# X | test1 -> R² = -0.3036, MSE = 1.3657e-01
# Y | test1 -> R² = -1.0978, MSE = 1.7191e-01
# Theta | test2 -> R² = 0.4934, MSE = 1.2015e-01
# X | test2 -> R² = -0.1968, MSE = 9.8485e-02
# Y | test2 -> R² = -0.8088, MSE = 1.9199e-01
# Theta | test3 -> R² = 0.3309, MSE = 2.1998e-01
# X | test3 -> R² = -0.3349, MSE = 1.2282e-01
# Y | test3 -> R² = -1.5610, MSE = 1.9671e-01
# Theta | val -> R² = 0.6017, MSE = 1.3036e-01
# X | val -> R² = -0.3619, MSE = 1.3023e-01
# Y | val -> R² = -1.4845, MSE = 1.8497e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.549034
# Epoch 50 Loss 1.289225
# Epoch 100 Loss 1.282100
# Epoch 150 Loss 1.278381
# Epoch 200 Loss 1.277577
# Epoch 250 Loss 1.275778
# Epoch 300 Loss 1.269435
# Early stopping at epoch 341
# Theta | train1 -> R² = 0.7901, MSE = 4.7909e-02
# X | train1 -> R² = -0.2538, MSE = 1.3519e-01
# Y | train1 -> R² = -1.0248, MSE = 1.6967e-01
# Theta | train2 -> R² = 0.5828, MSE = 9.5241e-02
# X | train2 -> R² = -0.2458, MSE = 1.0497e-01
# Y | train2 -> R² = -0.9202, MSE = 2.0677e-01
# Theta | test1 -> R² = 0.4113, MSE = 1.3523e-01
# X | test1 -> R² = -0.3346, MSE = 1.3981e-01
# Y | test1 -> R² = -1.2188, MSE = 1.8183e-01
# Theta | test2 -> R² = 0.5608, MSE = 1.0417e-01
# X | test2 -> R² = -0.2492, MSE = 1.0280e-01
# Y | test2 -> R² = -0.8777, MSE = 1.9931e-01
# Theta | test3 -> R² = -0.1386, MSE = 3.7432e-01
# X | test3 -> R² = -0.3762, MSE = 1.2662e-01
# Y | test3 -> R² = -1.7617, MSE = 2.1212e-01
# Theta | val -> R² = 0.3384, MSE = 2.1652e-01
# X | val -> R² = -0.4021, MSE = 1.3407e-01
# Y | val -> R² = -1.6729, MSE = 1.9900e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.577777
# Epoch 50 Loss 1.288002
# Epoch 100 Loss 1.282321
# Epoch 150 Loss 1.278535
# Epoch 200 Loss 1.273908
# Epoch 250 Loss 1.266602
# Epoch 300 Loss 1.259366
# Early stopping at epoch 335
# Theta | train1 -> R² = 0.6226, MSE = 8.6139e-02
# X | train1 -> R² = -0.1465, MSE = 1.2363e-01
# Y | train1 -> R² = -0.9754, MSE = 1.6553e-01
# Theta | train2 -> R² = 0.6695, MSE = 7.5465e-02
# X | train2 -> R² = -0.1316, MSE = 9.5351e-02
# Y | train2 -> R² = -0.8786, MSE = 2.0229e-01
# Theta | test1 -> R² = 0.2299, MSE = 1.7691e-01
# X | test1 -> R² = -0.2163, MSE = 1.2742e-01
# Y | test1 -> R² = -1.1642, MSE = 1.7736e-01
# Theta | test2 -> R² = 0.6250, MSE = 8.8935e-02
# X | test2 -> R² = -0.1386, MSE = 9.3699e-02
# Y | test2 -> R² = -0.8373, MSE = 1.9502e-01
# Theta | test3 -> R² = -0.2994, MSE = 4.2716e-01
# X | test3 -> R² = -0.2430, MSE = 1.1437e-01
# Y | test3 -> R² = -1.7007, MSE = 2.0743e-01
# Theta | val -> R² = 0.2244, MSE = 2.5385e-01
# X | val -> R² = -0.2787, MSE = 1.2228e-01
# Y | val -> R² = -1.6115, MSE = 1.9443e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.585068
# Epoch 50 Loss 1.286775
# Epoch 100 Loss 1.281546
# Epoch 150 Loss 1.276719
# Epoch 200 Loss 1.275480
# Epoch 250 Loss 1.270691
# Epoch 300 Loss 1.259191
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.8332, MSE = 3.8067e-02
# X | train1 -> R² = -0.0138, MSE = 1.0932e-01
# Y | train1 -> R² = -1.1085, MSE = 1.7668e-01
# Theta | train2 -> R² = 0.1661, MSE = 1.9038e-01
# X | train2 -> R² = -0.0682, MSE = 9.0007e-02
# Y | train2 -> R² = -1.0482, MSE = 2.2055e-01
# Theta | test1 -> R² = 0.6381, MSE = 8.3136e-02
# X | test1 -> R² = -0.0852, MSE = 1.1369e-01
# Y | test1 -> R² = -1.3062, MSE = 1.8899e-01
# Theta | test2 -> R² = 0.1859, MSE = 1.9306e-01
# X | test2 -> R² = -0.0755, MSE = 8.8506e-02
# Y | test2 -> R² = -1.0054, MSE = 2.1286e-01
# Theta | test3 -> R² = 0.0644, MSE = 3.0756e-01
# X | test3 -> R² = -0.1020, MSE = 1.0139e-01
# Y | test3 -> R² = -1.8856, MSE = 2.2163e-01
# Theta | val -> R² = 0.4034, MSE = 1.9524e-01
# X | val -> R² = -0.1171, MSE = 1.0682e-01
# Y | val -> R² = -1.7741, MSE = 2.0653e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.624311
# Epoch 50 Loss 1.288495
# Epoch 100 Loss 1.282010
# Epoch 150 Loss 1.277043
# Epoch 200 Loss 1.272723
# Epoch 250 Loss 1.267231
# Epoch 300 Loss 1.263521
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.4070, MSE = 1.3536e-01
# X | train1 -> R² = -0.2542, MSE = 1.3524e-01
# Y | train1 -> R² = -0.8901, MSE = 1.5838e-01
# Theta | train2 -> R² = 0.6464, MSE = 8.0736e-02
# X | train2 -> R² = -0.1755, MSE = 9.9045e-02
# Y | train2 -> R² = -0.8869, MSE = 2.0318e-01
# Theta | test1 -> R² = -0.1481, MSE = 2.6374e-01
# X | test1 -> R² = -0.3305, MSE = 1.3938e-01
# Y | test1 -> R² = -1.0647, MSE = 1.6920e-01
# Theta | test2 -> R² = 0.5544, MSE = 1.0569e-01
# X | test2 -> R² = -0.1803, MSE = 9.7134e-02
# Y | test2 -> R² = -0.8454, MSE = 1.9588e-01
# Theta | test3 -> R² = -0.9476, MSE = 6.4025e-01
# X | test3 -> R² = -0.3525, MSE = 1.2443e-01
# Y | test3 -> R² = -1.4424, MSE = 1.8759e-01
# Theta | val -> R² = -0.1892, MSE = 3.8920e-01
# X | val -> R² = -0.3932, MSE = 1.3323e-01
# Y | val -> R² = -1.3811, MSE = 1.7727e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.616501
# Epoch 50 Loss 1.291411
# Epoch 100 Loss 1.282093
# Epoch 150 Loss 1.278123
# Epoch 200 Loss 1.274515
# Epoch 250 Loss 1.269523
# Epoch 300 Loss 1.260621
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.6467, MSE = 8.0639e-02
# X | train1 -> R² = -0.2589, MSE = 1.3574e-01
# Y | train1 -> R² = -0.9319, MSE = 1.6188e-01
# Theta | train2 -> R² = 0.5031, MSE = 1.1345e-01
# X | train2 -> R² = -0.2323, MSE = 1.0383e-01
# Y | train2 -> R² = -0.8907, MSE = 2.0358e-01
# Theta | test1 -> R² = 0.4368, MSE = 1.2937e-01
# X | test1 -> R² = -0.3353, MSE = 1.3989e-01
# Y | test1 -> R² = -1.1180, MSE = 1.7357e-01
# Theta | test2 -> R² = 0.5034, MSE = 1.1778e-01
# X | test2 -> R² = -0.2379, MSE = 1.0187e-01
# Y | test2 -> R² = -0.8505, MSE = 1.9642e-01
# Theta | test3 -> R² = 0.1442, MSE = 2.8135e-01
# X | test3 -> R² = -0.3764, MSE = 1.2663e-01
# Y | test3 -> R² = -1.5636, MSE = 1.9691e-01
# Theta | val -> R² = 0.4301, MSE = 1.8652e-01
# X | val -> R² = -0.4157, MSE = 1.3537e-01
# Y | val -> R² = -1.4833, MSE = 1.8488e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.568573
# Epoch 50 Loss 1.286682
# Epoch 100 Loss 1.281440
# Epoch 150 Loss 1.291610
# Epoch 200 Loss 1.276962
# Epoch 250 Loss 1.267307
# Epoch 300 Loss 1.258434
# Early stopping at epoch 322
# Theta | train1 -> R² = 0.8429, MSE = 3.5863e-02
# X | train1 -> R² = -0.1366, MSE = 1.2255e-01
# Y | train1 -> R² = -0.9018, MSE = 1.5936e-01
# Theta | train2 -> R² = 0.2044, MSE = 1.8165e-01
# X | train2 -> R² = -0.1801, MSE = 9.9432e-02
# Y | train2 -> R² = -0.7429, MSE = 1.8768e-01
# Theta | test1 -> R² = 0.7519, MSE = 5.6990e-02
# X | test1 -> R² = -0.2168, MSE = 1.2747e-01
# Y | test1 -> R² = -1.0733, MSE = 1.6991e-01
# Theta | test2 -> R² = 0.2562, MSE = 1.7640e-01
# X | test2 -> R² = -0.1862, MSE = 9.7618e-02
# Y | test2 -> R² = -0.7011, MSE = 1.8056e-01
# Theta | test3 -> R² = 0.4362, MSE = 1.8535e-01
# X | test3 -> R² = -0.2347, MSE = 1.1359e-01
# Y | test3 -> R² = -1.5221, MSE = 1.9372e-01
# Theta | val -> R² = 0.6283, MSE = 1.2166e-01
# X | val -> R² = -0.2619, MSE = 1.2067e-01
# Y | val -> R² = -1.4818, MSE = 1.8477e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.657503
# Epoch 50 Loss 1.285670
# Epoch 100 Loss 1.282170
# Epoch 150 Loss 1.281786
# Epoch 200 Loss 1.275872
# Epoch 250 Loss 1.275715
# Epoch 300 Loss 1.271879
# Early stopping at epoch 334
# Theta | train1 -> R² = 0.8682, MSE = 3.0084e-02
# X | train1 -> R² = -0.0811, MSE = 1.1657e-01
# Y | train1 -> R² = -0.9050, MSE = 1.5963e-01
# Theta | train2 -> R² = 0.3095, MSE = 1.5765e-01
# X | train2 -> R² = -0.1001, MSE = 9.2698e-02
# Y | train2 -> R² = -0.8442, MSE = 1.9857e-01
# Theta | test1 -> R² = 0.8278, MSE = 3.9564e-02
# X | test1 -> R² = -0.1515, MSE = 1.2063e-01
# Y | test1 -> R² = -1.0581, MSE = 1.6866e-01
# Theta | test2 -> R² = 0.4023, MSE = 1.4175e-01
# X | test2 -> R² = -0.1062, MSE = 9.1030e-02
# Y | test2 -> R² = -0.7960, MSE = 1.9063e-01
# Theta | test3 -> R² = 0.6094, MSE = 1.2840e-01
# X | test3 -> R² = -0.1688, MSE = 1.0754e-01
# Y | test3 -> R² = -1.4894, MSE = 1.9120e-01
# Theta | val -> R² = 0.7293, MSE = 8.8602e-02
# X | val -> R² = -0.1880, MSE = 1.1360e-01
# Y | val -> R² = -1.4334, MSE = 1.8117e-01
# Figura salva em: ./results/model_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.706787
# Epoch 50 Loss 1.285080
# Epoch 100 Loss 1.288892
# Epoch 150 Loss 1.277025
# Epoch 200 Loss 1.275535
# Epoch 250 Loss 1.277012
# Epoch 300 Loss 1.269985
# Early stopping at epoch 311
# Theta | train1 -> R² = 0.8262, MSE = 3.9683e-02
# X | train1 -> R² = 0.0353, MSE = 1.0402e-01
# Y | train1 -> R² = -1.3923, MSE = 2.0047e-01
# Theta | train2 -> R² = 0.7160, MSE = 6.4840e-02
# X | train2 -> R² = -0.1208, MSE = 9.4438e-02
# Y | train2 -> R² = -1.5033, MSE = 2.6955e-01
# Theta | test1 -> R² = 0.4632, MSE = 1.2331e-01
# X | test1 -> R² = -0.0250, MSE = 1.0738e-01
# Y | test1 -> R² = -1.5778, MSE = 2.1124e-01
# Theta | test2 -> R² = 0.7076, MSE = 6.9357e-02
# X | test2 -> R² = -0.1316, MSE = 9.3120e-02
# Y | test2 -> R² = -1.4478, MSE = 2.5982e-01
# Theta | test3 -> R² = 0.0592, MSE = 3.0929e-01
# X | test3 -> R² = -0.0528, MSE = 9.6863e-02
# Y | test3 -> R² = -2.3221, MSE = 2.5516e-01
# Theta | val -> R² = 0.4842, MSE = 1.6880e-01
# X | val -> R² = -0.0808, MSE = 1.0335e-01
# Y | val -> R² = -2.1280, MSE = 2.3288e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.587081
# Epoch 50 Loss 1.284489
# Epoch 100 Loss 1.279361
# Epoch 150 Loss 1.277033
# Epoch 200 Loss 1.276382
# Epoch 250 Loss 1.275360
# Epoch 300 Loss 1.287463
# Early stopping at epoch 327
# Theta | train1 -> R² = 0.6542, MSE = 7.8931e-02
# X | train1 -> R² = -0.1430, MSE = 1.2324e-01
# Y | train1 -> R² = -1.0549, MSE = 1.7220e-01
# Theta | train2 -> R² = 0.5732, MSE = 9.7446e-02
# X | train2 -> R² = -0.2215, MSE = 1.0292e-01
# Y | train2 -> R² = -0.9589, MSE = 2.1094e-01
# Theta | test1 -> R² = 0.3300, MSE = 1.5392e-01
# X | test1 -> R² = -0.2291, MSE = 1.2876e-01
# Y | test1 -> R² = -1.2514, MSE = 1.8450e-01
# Theta | test2 -> R² = 0.5408, MSE = 1.0891e-01
# X | test2 -> R² = -0.2278, MSE = 1.0104e-01
# Y | test2 -> R² = -0.9161, MSE = 2.0338e-01
# Theta | test3 -> R² = -0.1924, MSE = 3.9200e-01
# X | test3 -> R² = -0.2529, MSE = 1.1527e-01
# Y | test3 -> R² = -1.8619, MSE = 2.1981e-01
# Theta | val -> R² = 0.2494, MSE = 2.4565e-01
# X | val -> R² = -0.2639, MSE = 1.2086e-01
# Y | val -> R² = -1.7437, MSE = 2.0427e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.529504
# Epoch 50 Loss 1.286863
# Epoch 100 Loss 1.283095
# Epoch 150 Loss 1.280374
# Epoch 200 Loss 1.276539
# Epoch 250 Loss 1.275647
# Epoch 300 Loss 1.275144
# Early stopping at epoch 304
# Theta | train1 -> R² = -1.0402, MSE = 4.6570e-01
# X | train1 -> R² = -0.8144, MSE = 1.9564e-01
# Y | train1 -> R² = -1.3469, MSE = 1.9666e-01
# Theta | train2 -> R² = -0.1883, MSE = 2.7129e-01
# X | train2 -> R² = -0.7855, MSE = 1.5045e-01
# Y | train2 -> R² = -1.7193, MSE = 2.9281e-01
# Theta | test1 -> R² = -2.3035, MSE = 7.5889e-01
# X | test1 -> R² = -0.9217, MSE = 2.0132e-01
# Y | test1 -> R² = -1.5143, MSE = 2.0605e-01
# Theta | test2 -> R² = -0.4484, MSE = 3.4349e-01
# X | test2 -> R² = -0.7906, MSE = 1.4735e-01
# Y | test2 -> R² = -1.6613, MSE = 2.8248e-01
# Theta | test3 -> R² = -4.3921, MSE = 1.7726e+00
# X | test3 -> R² = -1.1748, MSE = 2.0009e-01
# Y | test3 -> R² = -2.0295, MSE = 2.3269e-01
# Theta | val -> R² = -2.5273, MSE = 1.1544e+00
# X | val -> R² = -1.1481, MSE = 2.0541e-01
# Y | val -> R² = -1.8494, MSE = 2.1214e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.584436
# Epoch 50 Loss 1.285941
# Epoch 100 Loss 1.283275
# Epoch 150 Loss 1.279043
# Epoch 200 Loss 1.276909
# Epoch 250 Loss 1.313499
# Epoch 300 Loss 1.273309
# Epoch 350 Loss 1.271820
# Epoch 400 Loss 1.266397
# Epoch 450 Loss 1.279485
# Epoch 500 Loss 1.258670
# Epoch 550 Loss 1.247108
# Early stopping at epoch 559
# Theta | train1 -> R² = 0.6782, MSE = 7.3451e-02
# X | train1 -> R² = -0.6024, MSE = 1.7278e-01
# Y | train1 -> R² = -0.5147, MSE = 1.2693e-01
# Theta | train2 -> R² = 0.4287, MSE = 1.3042e-01
# X | train2 -> R² = -0.8203, MSE = 1.5338e-01
# Y | train2 -> R² = -0.7105, MSE = 1.8418e-01
# Theta | test1 -> R² = 0.3898, MSE = 1.4017e-01
# X | test1 -> R² = -0.7023, MSE = 1.7833e-01
# Y | test1 -> R² = -0.7187, MSE = 1.4085e-01
# Theta | test2 -> R² = 0.4075, MSE = 1.4052e-01
# X | test2 -> R² = -0.8196, MSE = 1.4974e-01
# Y | test2 -> R² = -0.6693, MSE = 1.7718e-01
# Theta | test3 -> R² = -0.0478, MSE = 3.4446e-01
# X | test3 -> R² = -1.0741, MSE = 1.9083e-01
# Y | test3 -> R² = -1.4040, MSE = 1.8464e-01
# Theta | val -> R² = 0.3848, MSE = 2.0133e-01
# X | val -> R² = -0.8720, MSE = 1.7901e-01
# Y | val -> R² = -1.4042, MSE = 1.7899e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.595409
# Epoch 50 Loss 1.286912
# Epoch 100 Loss 1.283029
# Epoch 150 Loss 1.278567
# Epoch 200 Loss 1.276281
# Epoch 250 Loss 1.274070
# Epoch 300 Loss 1.325552
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.0749, MSE = 2.1118e-01
# X | train1 -> R² = 0.1379, MSE = 9.2953e-02
# Y | train1 -> R² = -1.5676, MSE = 2.1516e-01
# Theta | train2 -> R² = -2.2641, MSE = 7.4520e-01
# X | train2 -> R² = -0.0958, MSE = 9.2334e-02
# Y | train2 -> R² = -1.5388, MSE = 2.7337e-01
# Theta | test1 -> R² = 0.4431, MSE = 1.2793e-01
# X | test1 -> R² = 0.0733, MSE = 9.7084e-02
# Y | test1 -> R² = -1.8152, MSE = 2.3071e-01
# Theta | test2 -> R² = -2.0008, MSE = 7.1167e-01
# X | test2 -> R² = -0.1084, MSE = 9.1213e-02
# Y | test2 -> R² = -1.4954, MSE = 2.6487e-01
# Theta | test3 -> R² = 0.5585, MSE = 1.4515e-01
# X | test3 -> R² = 0.0517, MSE = 8.7247e-02
# Y | test3 -> R² = -2.8096, MSE = 2.9261e-01
# Theta | val -> R² = 0.4062, MSE = 1.9435e-01
# X | val -> R² = 0.0362, MSE = 9.2163e-02
# Y | val -> R² = -2.5366, MSE = 2.6330e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.574668
# Epoch 50 Loss 1.286292
# Epoch 100 Loss 1.282461
# Epoch 150 Loss 1.279333
# Epoch 200 Loss 1.277125
# Epoch 250 Loss 1.274648
# Epoch 300 Loss 1.292170
# Early stopping at epoch 314
# Theta | train1 -> R² = 0.6668, MSE = 7.6068e-02
# X | train1 -> R² = -0.0989, MSE = 1.1849e-01
# Y | train1 -> R² = -1.4471, MSE = 2.0506e-01
# Theta | train2 -> R² = -0.3678, MSE = 3.1227e-01
# X | train2 -> R² = -0.2243, MSE = 1.0316e-01
# Y | train2 -> R² = -1.5613, MSE = 2.7580e-01
# Theta | test1 -> R² = 0.6494, MSE = 8.0549e-02
# X | test1 -> R² = -0.1810, MSE = 1.2372e-01
# Y | test1 -> R² = -1.6299, MSE = 2.1552e-01
# Theta | test2 -> R² = -0.3142, MSE = 3.1167e-01
# X | test2 -> R² = -0.2321, MSE = 1.0139e-01
# Y | test2 -> R² = -1.5039, MSE = 2.6577e-01
# Theta | test3 -> R² = 0.3920, MSE = 1.9987e-01
# X | test3 -> R² = -0.2061, MSE = 1.1097e-01
# Y | test3 -> R² = -2.4048, MSE = 2.6151e-01
# Theta | val -> R² = 0.4923, MSE = 1.6618e-01
# X | val -> R² = -0.2235, MSE = 1.1699e-01
# Y | val -> R² = -2.1998, MSE = 2.3823e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.693020
# Epoch 50 Loss 1.285403
# Epoch 100 Loss 1.282429
# Epoch 150 Loss 1.278902
# Epoch 200 Loss 1.278500
# Epoch 250 Loss 1.273519
# Epoch 300 Loss 1.269859
# Early stopping at epoch 313
# Theta | train1 -> R² = 0.5573, MSE = 1.0105e-01
# X | train1 -> R² = -0.2919, MSE = 1.3930e-01
# Y | train1 -> R² = -1.7306, MSE = 2.2881e-01
# Theta | train2 -> R² = -1.0094, MSE = 4.5874e-01
# X | train2 -> R² = -0.4606, MSE = 1.2307e-01
# Y | train2 -> R² = -1.7098, MSE = 2.9178e-01
# Theta | test1 -> R² = 0.7376, MSE = 6.0268e-02
# X | test1 -> R² = -0.3892, MSE = 1.4554e-01
# Y | test1 -> R² = -1.9490, MSE = 2.4167e-01
# Theta | test2 -> R² = -0.8538, MSE = 4.3965e-01
# X | test2 -> R² = -0.4706, MSE = 1.2102e-01
# Y | test2 -> R² = -1.6559, MSE = 2.8190e-01
# Theta | test3 -> R² = 0.6735, MSE = 1.0732e-01
# X | test3 -> R² = -0.5188, MSE = 1.3974e-01
# Y | test3 -> R² = -3.0908, MSE = 3.1420e-01
# Theta | val -> R² = 0.6368, MSE = 1.1888e-01
# X | val -> R² = -0.5217, MSE = 1.4551e-01
# Y | val -> R² = -2.8011, MSE = 2.8299e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.616214
# Epoch 50 Loss 1.285703
# Epoch 100 Loss 1.281285
# Epoch 150 Loss 1.279676
# Epoch 200 Loss 1.275793
# Epoch 250 Loss 1.276511
# Epoch 300 Loss 1.272386
# Early stopping at epoch 319
# Theta | train1 -> R² = 0.5617, MSE = 1.0004e-01
# X | train1 -> R² = -0.0880, MSE = 1.1732e-01
# Y | train1 -> R² = -1.1310, MSE = 1.7857e-01
# Theta | train2 -> R² = 0.7502, MSE = 5.7023e-02
# X | train2 -> R² = -0.2355, MSE = 1.0411e-01
# Y | train2 -> R² = -1.1663, MSE = 2.3326e-01
# Theta | test1 -> R² = 0.1599, MSE = 1.9299e-01
# X | test1 -> R² = -0.1767, MSE = 1.2327e-01
# Y | test1 -> R² = -1.3383, MSE = 1.9162e-01
# Theta | test2 -> R² = 0.7147, MSE = 6.7659e-02
# X | test2 -> R² = -0.2432, MSE = 1.0231e-01
# Y | test2 -> R² = -1.1236, MSE = 2.2540e-01
# Theta | test3 -> R² = -0.1176, MSE = 3.6741e-01
# X | test3 -> R² = -0.1972, MSE = 1.1015e-01
# Y | test3 -> R² = -1.9320, MSE = 2.2520e-01
# Theta | val -> R² = 0.3289, MSE = 2.1964e-01
# X | val -> R² = -0.2081, MSE = 1.1552e-01
# Y | val -> R² = -1.7849, MSE = 2.0733e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.569675
# Epoch 50 Loss 1.285989
# Epoch 100 Loss 1.281207
# Epoch 150 Loss 1.277966
# Epoch 200 Loss 1.280165
# Epoch 250 Loss 1.275228
# Epoch 300 Loss 1.273431
# Early stopping at epoch 319
# Theta | train1 -> R² = 0.6477, MSE = 8.0421e-02
# X | train1 -> R² = -0.1218, MSE = 1.2095e-01
# Y | train1 -> R² = -1.0768, MSE = 1.7403e-01
# Theta | train2 -> R² = 0.2103, MSE = 1.8030e-01
# X | train2 -> R² = -0.2727, MSE = 1.0724e-01
# Y | train2 -> R² = -1.0540, MSE = 2.2117e-01
# Theta | test1 -> R² = 0.3646, MSE = 1.4596e-01
# X | test1 -> R² = -0.1779, MSE = 1.2339e-01
# Y | test1 -> R² = -1.2654, MSE = 1.8565e-01
# Theta | test2 -> R² = 0.1799, MSE = 1.9449e-01
# X | test2 -> R² = -0.2837, MSE = 1.0564e-01
# Y | test2 -> R² = -1.0092, MSE = 2.1326e-01
# Theta | test3 -> R² = -0.4143, MSE = 4.6496e-01
# X | test3 -> R² = -0.2424, MSE = 1.1431e-01
# Y | test3 -> R² = -1.8314, MSE = 2.1747e-01
# Theta | val -> R² = 0.0426, MSE = 3.1335e-01
# X | val -> R² = -0.3066, MSE = 1.2494e-01
# Y | val -> R² = -1.7154, MSE = 2.0216e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.476313
# Epoch 50 Loss 1.295524
# Epoch 100 Loss 1.283699
# Epoch 150 Loss 1.281807
# Epoch 200 Loss 1.278755
# Epoch 250 Loss 1.276546
# Epoch 300 Loss 1.292196
# Early stopping at epoch 322
# Theta | train1 -> R² = -5.0403, MSE = 1.3788e+00
# X | train1 -> R² = 0.1316, MSE = 9.3640e-02
# Y | train1 -> R² = -0.8897, MSE = 1.5835e-01
# Theta | train2 -> R² = -3.0554, MSE = 9.2586e-01
# X | train2 -> R² = -0.6535, MSE = 1.3933e-01
# Y | train2 -> R² = -0.7468, MSE = 1.8809e-01
# Theta | test1 -> R² = -6.6186, MSE = 1.7501e+00
# X | test1 -> R² = 0.0710, MSE = 9.7318e-02
# Y | test1 -> R² = -1.0342, MSE = 1.6670e-01
# Theta | test2 -> R² = -3.3854, MSE = 1.0400e+00
# X | test2 -> R² = -0.6790, MSE = 1.3817e-01
# Y | test2 -> R² = -0.7008, MSE = 1.8053e-01
# Theta | test3 -> R² = -11.2659, MSE = 4.0324e+00
# X | test3 -> R² = -0.1051, MSE = 1.0168e-01
# Y | test3 -> R² = -1.4487, MSE = 1.8808e-01
# Theta | val -> R² = -7.8421, MSE = 2.8938e+00
# X | val -> R² = -0.1614, MSE = 1.1106e-01
# Y | val -> R² = -1.4299, MSE = 1.8091e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.768566
# Epoch 50 Loss 1.296836
# Epoch 100 Loss 1.284221
# Epoch 150 Loss 1.282557
# Epoch 200 Loss 1.281333
# Epoch 250 Loss 1.279593
# Epoch 300 Loss 1.287449
# Early stopping at epoch 307
# Theta | train1 -> R² = -3.1671, MSE = 9.5121e-01
# X | train1 -> R² = 0.2002, MSE = 8.6242e-02
# Y | train1 -> R² = 0.2049, MSE = 6.6624e-02
# Theta | train2 -> R² = -6.6032, MSE = 1.7358e+00
# X | train2 -> R² = -0.4583, MSE = 1.2288e-01
# Y | train2 -> R² = -0.4833, MSE = 1.5972e-01
# Theta | test1 -> R² = -2.3334, MSE = 7.6574e-01
# X | test1 -> R² = 0.1117, MSE = 9.3062e-02
# Y | test1 -> R² = 0.1370, MSE = 7.0721e-02
# Theta | test2 -> R² = -6.0830, MSE = 1.6798e+00
# X | test2 -> R² = -0.4795, MSE = 1.2175e-01
# Y | test2 -> R² = -0.4780, MSE = 1.5687e-01
# Theta | test3 -> R² = -2.7143, MSE = 1.2211e+00
# X | test3 -> R² = 0.0345, MSE = 8.8833e-02
# Y | test3 -> R² = 0.4998, MSE = 3.8423e-02
# Theta | val -> R² = -2.4853, MSE = 1.1407e+00
# X | val -> R² = 0.0239, MSE = 9.3335e-02
# Y | val -> R² = 0.4939, MSE = 3.7681e-02
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.608883
# Epoch 50 Loss 1.287846
# Epoch 100 Loss 1.306234
# Epoch 150 Loss 1.303421
# Epoch 200 Loss 1.280103
# Epoch 250 Loss 1.356510
# Epoch 300 Loss 1.279600
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.5643, MSE = 9.9447e-02
# X | train1 -> R² = -0.3574, MSE = 1.4637e-01
# Y | train1 -> R² = -2.6596, MSE = 3.0666e-01
# Theta | train2 -> R² = 0.4910, MSE = 1.1620e-01
# X | train2 -> R² = -1.2841, MSE = 1.9246e-01
# Y | train2 -> R² = -2.9119, MSE = 4.2123e-01
# Theta | test1 -> R² = 0.4710, MSE = 1.2152e-01
# X | test1 -> R² = -0.5132, MSE = 1.5852e-01
# Y | test1 -> R² = -2.9424, MSE = 3.2308e-01
# Theta | test2 -> R² = 0.6111, MSE = 9.2232e-02
# X | test2 -> R² = -1.3181, MSE = 1.9076e-01
# Y | test2 -> R² = -2.8569, MSE = 4.0938e-01
# Theta | test3 -> R² = 0.5747, MSE = 1.3980e-01
# X | test3 -> R² = -1.1345, MSE = 1.9638e-01
# Y | test3 -> R² = -4.6437, MSE = 4.3347e-01
# Theta | val -> R² = 0.6224, MSE = 1.2357e-01
# X | val -> R² = -0.9929, MSE = 1.9057e-01
# Y | val -> R² = -4.0685, MSE = 3.7735e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.533986
# Epoch 50 Loss 1.297471
# Epoch 100 Loss 1.286378
# Epoch 150 Loss 1.281857
# Epoch 200 Loss 1.280330
# Epoch 250 Loss 1.287191
# Epoch 300 Loss 1.277198
# Early stopping at epoch 318
# Theta | train1 -> R² = -2.6466, MSE = 8.3240e-01
# X | train1 -> R² = -0.4665, MSE = 1.5812e-01
# Y | train1 -> R² = 0.1846, MSE = 6.8330e-02
# Theta | train2 -> R² = -4.9064, MSE = 1.3485e+00
# X | train2 -> R² = -0.7415, MSE = 1.4674e-01
# Y | train2 -> R² = -0.2396, MSE = 1.3348e-01
# Theta | test1 -> R² = -2.0170, MSE = 6.9307e-01
# X | test1 -> R² = -0.6085, MSE = 1.6851e-01
# Y | test1 -> R² = 0.1119, MSE = 7.2778e-02
# Theta | test2 -> R² = -4.7414, MSE = 1.3616e+00
# X | test2 -> R² = -0.8027, MSE = 1.4835e-01
# Y | test2 -> R² = -0.2331, MSE = 1.3088e-01
# Theta | test3 -> R² = -6.4588, MSE = 2.4521e+00
# X | test3 -> R² = -2.0268, MSE = 2.7848e-01
# Y | test3 -> R² = 0.5183, MSE = 3.7001e-02
# Theta | val -> R² = -5.6164, MSE = 2.1654e+00
# X | val -> R² = -1.6399, MSE = 2.5244e-01
# Y | val -> R² = 0.5397, MSE = 3.4267e-02
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.575426
# Epoch 50 Loss 1.291888
# Epoch 100 Loss 1.282696
# Epoch 150 Loss 1.281277
# Epoch 200 Loss 1.283940
# Epoch 250 Loss 1.281117
# Epoch 300 Loss 1.277157
# Early stopping at epoch 315
# Theta | train1 -> R² = 0.3309, MSE = 1.5274e-01
# X | train1 -> R² = 0.1827, MSE = 8.8125e-02
# Y | train1 -> R² = -2.7085, MSE = 3.1075e-01
# Theta | train2 -> R² = 0.7043, MSE = 6.7517e-02
# X | train2 -> R² = -0.7223, MSE = 1.4512e-01
# Y | train2 -> R² = -3.1321, MSE = 4.4493e-01
# Theta | test1 -> R² = -0.3476, MSE = 3.0958e-01
# X | test1 -> R² = 0.0479, MSE = 9.9746e-02
# Y | test1 -> R² = -3.0575, MSE = 3.3251e-01
# Theta | test2 -> R² = 0.6035, MSE = 9.4043e-02
# X | test2 -> R² = -0.7444, MSE = 1.4356e-01
# Y | test2 -> R² = -3.0891, MSE = 4.3403e-01
# Theta | test3 -> R² = -1.8398, MSE = 9.3358e-01
# X | test3 -> R² = -0.0852, MSE = 9.9844e-02
# Y | test3 -> R² = -4.5420, MSE = 4.2567e-01
# Theta | val -> R² = -0.5713, MSE = 5.1424e-01
# X | val -> R² = -0.0650, MSE = 1.0183e-01
# Y | val -> R² = -3.9424, MSE = 3.6796e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.543020
# Epoch 50 Loss 1.290034
# Epoch 100 Loss 1.283060
# Epoch 150 Loss 1.282401
# Epoch 200 Loss 1.280516
# Epoch 250 Loss 1.277220
# Epoch 300 Loss 1.281398
# Early stopping at epoch 306
# Theta | train1 -> R² = -5.8214, MSE = 1.5571e+00
# X | train1 -> R² = 0.6095, MSE = 4.2104e-02
# Y | train1 -> R² = 0.2816, MSE = 6.0195e-02
# Theta | train2 -> R² = -9.1665, MSE = 2.3211e+00
# X | train2 -> R² = -0.5831, MSE = 1.3339e-01
# Y | train2 -> R² = -0.1389, MSE = 1.2263e-01
# Theta | test1 -> R² = -4.0545, MSE = 1.1611e+00
# X | test1 -> R² = 0.6219, MSE = 3.9607e-02
# Y | test1 -> R² = 0.2492, MSE = 6.1524e-02
# Theta | test2 -> R² = -8.2428, MSE = 2.1920e+00
# X | test2 -> R² = -0.6459, MSE = 1.3545e-01
# Y | test2 -> R² = -0.1518, MSE = 1.2225e-01
# Theta | test3 -> R² = -4.8747, MSE = 1.9313e+00
# X | test3 -> R² = -0.1277, MSE = 1.0376e-01
# Y | test3 -> R² = 0.3605, MSE = 4.9116e-02
# Theta | val -> R² = -4.9160, MSE = 1.9362e+00
# X | val -> R² = 0.2375, MSE = 7.2910e-02
# Y | val -> R² = 0.4237, MSE = 4.2909e-02
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.607943
# Epoch 50 Loss 1.290960
# Epoch 100 Loss 1.284175
# Epoch 150 Loss 1.281815
# Epoch 200 Loss 1.280400
# Epoch 250 Loss 1.282908
# Epoch 300 Loss 1.277976
# Early stopping at epoch 309
# Theta | train1 -> R² = -11.1704, MSE = 2.7781e+00
# X | train1 -> R² = 0.4733, MSE = 5.6794e-02
# Y | train1 -> R² = -0.6573, MSE = 1.3887e-01
# Theta | train2 -> R² = -8.2929, MSE = 2.1216e+00
# X | train2 -> R² = -0.2801, MSE = 1.0786e-01
# Y | train2 -> R² = -1.2239, MSE = 2.3947e-01
# Theta | test1 -> R² = -13.7237, MSE = 3.3823e+00
# X | test1 -> R² = 0.3820, MSE = 6.4745e-02
# Y | test1 -> R² = -0.8184, MSE = 1.4902e-01
# Theta | test2 -> R² = -8.7482, MSE = 2.3119e+00
# X | test2 -> R² = -0.2958, MSE = 1.0664e-01
# Y | test2 -> R² = -1.1861, MSE = 2.3204e-01
# Theta | test3 -> R² = -20.4739, MSE = 7.0595e+00
# X | test3 -> R² = 0.3894, MSE = 5.6175e-02
# Y | test3 -> R² = -0.7845, MSE = 1.3706e-01
# Theta | val -> R² = -14.5491, MSE = 5.0889e+00
# X | val -> R² = 0.4192, MSE = 5.5539e-02
# Y | val -> R² = -0.7135, MSE = 1.2757e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.604015
# Epoch 50 Loss 1.293094
# Epoch 100 Loss 1.283591
# Epoch 150 Loss 1.282279
# Epoch 200 Loss 1.281275
# Epoch 250 Loss 1.280088
# Epoch 300 Loss 1.284675
# Early stopping at epoch 315
# Theta | train1 -> R² = -0.0413, MSE = 2.3768e-01
# X | train1 -> R² = 0.2356, MSE = 8.2423e-02
# Y | train1 -> R² = -2.3977, MSE = 2.8472e-01
# Theta | train2 -> R² = -0.1624, MSE = 2.6538e-01
# X | train2 -> R² = -0.3226, MSE = 1.1145e-01
# Y | train2 -> R² = -2.8794, MSE = 4.1772e-01
# Theta | test1 -> R² = -0.8280, MSE = 4.1993e-01
# X | test1 -> R² = 0.1317, MSE = 9.0967e-02
# Y | test1 -> R² = -2.6831, MSE = 3.0183e-01
# Theta | test2 -> R² = -0.2835, MSE = 3.0441e-01
# X | test2 -> R² = -0.3384, MSE = 1.1015e-01
# Y | test2 -> R² = -2.8282, MSE = 4.0634e-01
# Theta | test3 -> R² = -3.4703, MSE = 1.4696e+00
# X | test3 -> R² = 0.1039, MSE = 8.2445e-02
# Y | test3 -> R² = -3.5362, MSE = 3.4842e-01
# Theta | val -> R² = -1.9695, MSE = 9.7185e-01
# X | val -> R² = 0.1193, MSE = 8.4217e-02
# Y | val -> R² = -3.1773, MSE = 3.1100e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.594982
# Epoch 50 Loss 1.294006
# Epoch 100 Loss 1.284335
# Epoch 150 Loss 1.286373
# Epoch 200 Loss 1.281520
# Epoch 250 Loss 1.280053
# Epoch 300 Loss 1.277228
# Early stopping at epoch 347
# Theta | train1 -> R² = 0.5864, MSE = 9.4404e-02
# X | train1 -> R² = 0.0113, MSE = 1.0661e-01
# Y | train1 -> R² = -0.7629, MSE = 1.4773e-01
# Theta | train2 -> R² = 0.4317, MSE = 1.2973e-01
# X | train2 -> R² = -0.0683, MSE = 9.0012e-02
# Y | train2 -> R² = -0.8511, MSE = 1.9932e-01
# Theta | test1 -> R² = 0.0486, MSE = 2.1856e-01
# X | test1 -> R² = -0.0578, MSE = 1.1081e-01
# Y | test1 -> R² = -0.9569, MSE = 1.6036e-01
# Theta | test2 -> R² = 0.3664, MSE = 1.5028e-01
# X | test2 -> R² = -0.0757, MSE = 8.8521e-02
# Y | test2 -> R² = -0.8163, MSE = 1.9278e-01
# Theta | test3 -> R² = -0.8734, MSE = 6.1588e-01
# X | test3 -> R² = -0.0734, MSE = 9.8761e-02
# Y | test3 -> R² = -1.1335, MSE = 1.6387e-01
# Theta | val -> R² = -0.2088, MSE = 3.9562e-01
# X | val -> R² = -0.0858, MSE = 1.0383e-01
# Y | val -> R² = -1.0966, MSE = 1.5609e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.528369
# Epoch 50 Loss 1.296449
# Epoch 100 Loss 1.284158
# Epoch 150 Loss 1.282082
# Epoch 200 Loss 1.284942
# Epoch 250 Loss 1.280584
# Epoch 300 Loss 1.277617
# Early stopping at epoch 303
# Theta | train1 -> R² = -5.3226, MSE = 1.4432e+00
# X | train1 -> R² = 0.0557, MSE = 1.0182e-01
# Y | train1 -> R² = -0.4289, MSE = 1.1973e-01
# Theta | train2 -> R² = -2.9312, MSE = 8.9751e-01
# X | train2 -> R² = -1.8706, MSE = 2.4188e-01
# Y | train2 -> R² = -0.5625, MSE = 1.6825e-01
# Theta | test1 -> R² = -6.3544, MSE = 1.6894e+00
# X | test1 -> R² = 0.0825, MSE = 9.6120e-02
# Y | test1 -> R² = -0.4996, MSE = 1.2289e-01
# Theta | test2 -> R² = -3.1410, MSE = 9.8209e-01
# X | test2 -> R² = -2.0182, MSE = 2.4837e-01
# Y | test2 -> R² = -0.5134, MSE = 1.6063e-01
# Theta | test3 -> R² = -10.8485, MSE = 3.8952e+00
# X | test3 -> R² = -2.1019, MSE = 2.8539e-01
# Y | test3 -> R² = -0.4578, MSE = 1.1197e-01
# Theta | val -> R² = -7.9645, MSE = 2.9339e+00
# X | val -> R² = -1.0470, MSE = 1.9574e-01
# Y | val -> R² = -0.5131, MSE = 1.1265e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.568207
# Epoch 50 Loss 1.315132
# Epoch 100 Loss 1.292612
# Epoch 150 Loss 1.285922
# Epoch 200 Loss 1.281227
# Epoch 250 Loss 1.276242
# Epoch 300 Loss 1.273888
# Early stopping at epoch 349
# Theta | train1 -> R² = 0.7716, MSE = 5.2126e-02
# X | train1 -> R² = -0.6311, MSE = 1.7587e-01
# Y | train1 -> R² = -1.1771, MSE = 1.8243e-01
# Theta | train2 -> R² = -0.0877, MSE = 2.4832e-01
# X | train2 -> R² = -0.5631, MSE = 1.3170e-01
# Y | train2 -> R² = -1.1454, MSE = 2.3101e-01
# Theta | test1 -> R² = 0.7147, MSE = 6.5544e-02
# X | test1 -> R² = -0.7961, MSE = 1.8816e-01
# Y | test1 -> R² = -1.4686, MSE = 2.0230e-01
# Theta | test2 -> R² = -0.0933, MSE = 2.5929e-01
# X | test2 -> R² = -0.5329, MSE = 1.2614e-01
# Y | test2 -> R² = -1.0827, MSE = 2.2106e-01
# Theta | test3 -> R² = 0.1956, MSE = 2.6446e-01
# X | test3 -> R² = -0.5620, MSE = 1.4371e-01
# Y | test3 -> R² = -0.6680, MSE = 1.2812e-01
# Theta | val -> R² = 0.5212, MSE = 1.5671e-01
# X | val -> R² = -0.6131, MSE = 1.5425e-01
# Y | val -> R² = -0.8599, MSE = 1.3847e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.569842
# Epoch 50 Loss 1.412846
# Epoch 100 Loss 1.285605
# Epoch 150 Loss 1.271913
# Epoch 200 Loss 1.261076
# Epoch 250 Loss 1.256203
# Epoch 300 Loss 1.252915
# Epoch 350 Loss 1.249988
# Early stopping at epoch 359
# Theta | train1 -> R² = 0.6811, MSE = 7.2796e-02
# X | train1 -> R² = 0.0848, MSE = 9.8678e-02
# Y | train1 -> R² = -0.5297, MSE = 1.2818e-01
# Theta | train2 -> R² = 0.1619, MSE = 1.9134e-01
# X | train2 -> R² = -0.0018, MSE = 8.4411e-02
# Y | train2 -> R² = -0.6391, MSE = 1.7649e-01
# Theta | test1 -> R² = 0.6607, MSE = 7.7941e-02
# X | test1 -> R² = -0.0298, MSE = 1.0788e-01
# Y | test1 -> R² = -0.7807, MSE = 1.4593e-01
# Theta | test2 -> R² = 0.0923, MSE = 2.1527e-01
# X | test2 -> R² = 0.0267, MSE = 8.0092e-02
# Y | test2 -> R² = -0.6153, MSE = 1.7145e-01
# Theta | test3 -> R² = -14.8247, MSE = 5.2023e+00
# X | test3 -> R² = -0.1464, MSE = 1.0547e-01
# Y | test3 -> R² = 0.1560, MSE = 6.4827e-02
# Theta | val -> R² = -9.2019, MSE = 3.3389e+00
# X | val -> R² = -0.0056, MSE = 9.6156e-02
# Y | val -> R² = -0.0224, MSE = 7.6119e-02
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.568430
# Epoch 50 Loss 1.303283
# Epoch 100 Loss 1.288170
# Epoch 150 Loss 1.282255
# Epoch 200 Loss 1.276079
# Epoch 250 Loss 1.267469
# Epoch 300 Loss 1.258950
# Epoch 350 Loss 1.252557
# Early stopping at epoch 355
# Theta | train1 -> R² = 0.8220, MSE = 4.0622e-02
# X | train1 -> R² = -0.3012, MSE = 1.4030e-01
# Y | train1 -> R² = -0.8866, MSE = 1.5809e-01
# Theta | train2 -> R² = 0.3222, MSE = 1.5474e-01
# X | train2 -> R² = -0.2562, MSE = 1.0585e-01
# Y | train2 -> R² = -0.8999, MSE = 2.0458e-01
# Theta | test1 -> R² = 0.8001, MSE = 4.5920e-02
# X | test1 -> R² = -0.3777, MSE = 1.4433e-01
# Y | test1 -> R² = -1.0777, MSE = 1.7026e-01
# Theta | test2 -> R² = 0.3720, MSE = 1.4894e-01
# X | test2 -> R² = -0.2508, MSE = 1.0293e-01
# Y | test2 -> R² = -0.8631, MSE = 1.9775e-01
# Theta | test3 -> R² = -0.3997, MSE = 4.6015e-01
# X | test3 -> R² = -0.3901, MSE = 1.2790e-01
# Y | test3 -> R² = -1.1909, MSE = 1.6827e-01
# Theta | val -> R² = 0.5018, MSE = 1.6304e-01
# X | val -> R² = -0.3960, MSE = 1.3349e-01
# Y | val -> R² = -1.1692, MSE = 1.6150e-01
# Figura salva em: ./results/model_8_4_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.568644
# Epoch 50 Loss 1.329192
# Epoch 100 Loss 1.297180
# Epoch 150 Loss 1.287539
# Epoch 200 Loss 1.278807
# Epoch 250 Loss 1.274811
# Epoch 300 Loss 1.270061
# Early stopping at epoch 349
# Theta | train1 -> R² = 0.7147, MSE = 6.5119e-02
# X | train1 -> R² = -0.6019, MSE = 1.7273e-01
# Y | train1 -> R² = -1.0773, MSE = 1.7407e-01
# Theta | train2 -> R² = -0.4962, MSE = 3.4158e-01
# X | train2 -> R² = -0.3634, MSE = 1.1488e-01
# Y | train2 -> R² = -1.0500, MSE = 2.2074e-01
# Theta | test1 -> R² = 0.7775, MSE = 5.1115e-02
# X | test1 -> R² = -0.7618, MSE = 1.8457e-01
# Y | test1 -> R² = -1.3538, MSE = 1.9289e-01
# Theta | test2 -> R² = -0.5561, MSE = 3.6905e-01
# X | test2 -> R² = -0.3570, MSE = 1.1167e-01
# Y | test2 -> R² = -1.0211, MSE = 2.1453e-01
# Theta | test3 -> R² = -0.7479, MSE = 5.7461e-01
# X | test3 -> R² = -0.5658, MSE = 1.4406e-01
# Y | test3 -> R² = -0.7597, MSE = 1.3516e-01
# Theta | val -> R² = -0.0367, MSE = 3.3929e-01
# X | val -> R² = -0.6567, MSE = 1.5842e-01
# Y | val -> R² = -0.9403, MSE = 1.4445e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568933
# Epoch 50 Loss 1.308621
# Epoch 100 Loss 1.292166
# Epoch 150 Loss 1.286623
# Epoch 200 Loss 1.279566
# Epoch 250 Loss 1.268481
# Epoch 300 Loss 1.259273
# Early stopping at epoch 344
# Theta | train1 -> R² = 0.7845, MSE = 4.9198e-02
# X | train1 -> R² = -0.2525, MSE = 1.3506e-01
# Y | train1 -> R² = -1.0312, MSE = 1.7021e-01
# Theta | train2 -> R² = 0.1574, MSE = 1.9237e-01
# X | train2 -> R² = -0.1877, MSE = 1.0008e-01
# Y | train2 -> R² = -1.0033, MSE = 2.1572e-01
# Theta | test1 -> R² = 0.7818, MSE = 5.0115e-02
# X | test1 -> R² = -0.3751, MSE = 1.4405e-01
# Y | test1 -> R² = -1.2747, MSE = 1.8641e-01
# Theta | test2 -> R² = 0.1643, MSE = 1.9820e-01
# X | test2 -> R² = -0.1589, MSE = 9.5371e-02
# Y | test2 -> R² = -0.9446, MSE = 2.0641e-01
# Theta | test3 -> R² = 0.7344, MSE = 8.7304e-02
# X | test3 -> R² = -0.4553, MSE = 1.3389e-01
# Y | test3 -> R² = -0.2398, MSE = 9.5226e-02
# Theta | val -> R² = 0.7190, MSE = 9.1952e-02
# X | val -> R² = -0.2735, MSE = 1.2178e-01
# Y | val -> R² = -0.4350, MSE = 1.0684e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.568942
# Epoch 50 Loss 1.311266
# Epoch 100 Loss 1.298555
# Epoch 150 Loss 1.295738
# Epoch 200 Loss 1.286100
# Epoch 250 Loss 1.282115
# Epoch 300 Loss 1.278771
# Early stopping at epoch 335
# Theta | train1 -> R² = 0.5612, MSE = 1.0016e-01
# X | train1 -> R² = -0.1084, MSE = 1.1951e-01
# Y | train1 -> R² = -1.4156, MSE = 2.0242e-01
# Theta | train2 -> R² = -0.9845, MSE = 4.5306e-01
# X | train2 -> R² = -0.0281, MSE = 8.6627e-02
# Y | train2 -> R² = -1.3736, MSE = 2.5558e-01
# Theta | test1 -> R² = 0.6715, MSE = 7.5460e-02
# X | test1 -> R² = -0.1951, MSE = 1.2520e-01
# Y | test1 -> R² = -1.7006, MSE = 2.2131e-01
# Theta | test2 -> R² = -0.9632, MSE = 4.6558e-01
# X | test2 -> R² = -0.0250, MSE = 8.4350e-02
# Y | test2 -> R² = -1.3355, MSE = 2.4790e-01
# Theta | test3 -> R² = 0.7516, MSE = 8.1654e-02
# X | test3 -> R² = -0.2666, MSE = 1.1654e-01
# Y | test3 -> R² = -1.5417, MSE = 1.9522e-01
# Theta | val -> R² = 0.6695, MSE = 1.0818e-01
# X | val -> R² = -0.2704, MSE = 1.2148e-01
# Y | val -> R² = -1.6219, MSE = 1.9520e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.567939
# Epoch 50 Loss 1.297318
# Epoch 100 Loss 1.285043
# Epoch 150 Loss 1.277993
# Epoch 200 Loss 1.268043
# Epoch 250 Loss 1.257895
# Epoch 300 Loss 1.251570
# Early stopping at epoch 334
# Theta | train1 -> R² = 0.7987, MSE = 4.5942e-02
# X | train1 -> R² = -0.0404, MSE = 1.1218e-01
# Y | train1 -> R² = -0.9434, MSE = 1.6285e-01
# Theta | train2 -> R² = 0.1042, MSE = 2.0450e-01
# X | train2 -> R² = 0.0656, MSE = 7.8733e-02
# Y | train2 -> R² = -0.8384, MSE = 1.9795e-01
# Theta | test1 -> R² = 0.7787, MSE = 5.0826e-02
# X | test1 -> R² = -0.1295, MSE = 1.1833e-01
# Y | test1 -> R² = -1.2013, MSE = 1.8039e-01
# Theta | test2 -> R² = 0.0808, MSE = 2.1799e-01
# X | test2 -> R² = 0.0743, MSE = 7.6182e-02
# Y | test2 -> R² = -0.7954, MSE = 1.9056e-01
# Theta | test3 -> R² = 0.1996, MSE = 2.6313e-01
# X | test3 -> R² = -0.2265, MSE = 1.1285e-01
# Y | test3 -> R² = -1.2651, MSE = 1.7398e-01
# Theta | val -> R² = 0.5921, MSE = 1.3350e-01
# X | val -> R² = -0.2000, MSE = 1.1475e-01
# Y | val -> R² = -1.3615, MSE = 1.7582e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.571205
# Epoch 50 Loss 1.451847
# Epoch 100 Loss 1.307387
# Epoch 150 Loss 1.297521
# Epoch 200 Loss 1.290836
# Epoch 250 Loss 1.281638
# Epoch 300 Loss 1.276544
# Epoch 350 Loss 1.272641
# Early stopping at epoch 376
# Theta | train1 -> R² = 0.6320, MSE = 8.3992e-02
# X | train1 -> R² = 0.0346, MSE = 1.0409e-01
# Y | train1 -> R² = -0.8237, MSE = 1.5282e-01
# Theta | train2 -> R² = -0.2175, MSE = 2.7796e-01
# X | train2 -> R² = 0.0869, MSE = 7.6939e-02
# Y | train2 -> R² = -0.6476, MSE = 1.7741e-01
# Theta | test1 -> R² = 0.6539, MSE = 7.9509e-02
# X | test1 -> R² = -0.0393, MSE = 1.0887e-01
# Y | test1 -> R² = -0.8902, MSE = 1.5490e-01
# Theta | test2 -> R² = -0.1496, MSE = 2.7264e-01
# X | test2 -> R² = 0.0758, MSE = 7.6053e-02
# Y | test2 -> R² = -0.6181, MSE = 1.7175e-01
# Theta | test3 -> R² = 0.6674, MSE = 1.0936e-01
# X | test3 -> R² = -0.2159, MSE = 1.1187e-01
# Y | test3 -> R² = -1.7912, MSE = 2.1438e-01
# Theta | val -> R² = 0.7439, MSE = 8.3805e-02
# X | val -> R² = -0.2435, MSE = 1.1891e-01
# Y | val -> R² = -1.8006, MSE = 2.0851e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.568722
# Epoch 50 Loss 1.356413
# Epoch 100 Loss 1.300732
# Epoch 150 Loss 1.288341
# Epoch 200 Loss 1.283661
# Epoch 250 Loss 1.284189
# Epoch 300 Loss 1.275796
# Epoch 350 Loss 1.272375
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.6843, MSE = 7.2074e-02
# X | train1 -> R² = -0.4727, MSE = 1.5879e-01
# Y | train1 -> R² = -0.8749, MSE = 1.5711e-01
# Theta | train2 -> R² = -0.5655, MSE = 3.5740e-01
# X | train2 -> R² = -0.3573, MSE = 1.1437e-01
# Y | train2 -> R² = -1.0868, MSE = 2.2471e-01
# Theta | test1 -> R² = 0.6733, MSE = 7.5041e-02
# X | test1 -> R² = -0.5808, MSE = 1.6560e-01
# Y | test1 -> R² = -1.1254, MSE = 1.7418e-01
# Theta | test2 -> R² = -0.5420, MSE = 3.6569e-01
# X | test2 -> R² = -0.3293, MSE = 1.0939e-01
# Y | test2 -> R² = -1.0315, MSE = 2.1563e-01
# Theta | test3 -> R² = 0.6918, MSE = 1.0133e-01
# X | test3 -> R² = -0.6431, MSE = 1.5117e-01
# Y | test3 -> R² = -1.2788, MSE = 1.7503e-01
# Theta | val -> R² = 0.5731, MSE = 1.3971e-01
# X | val -> R² = -0.6781, MSE = 1.6047e-01
# Y | val -> R² = -1.2026, MSE = 1.6398e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.568731
# Epoch 50 Loss 1.312806
# Epoch 100 Loss 1.293941
# Epoch 150 Loss 1.282355
# Epoch 200 Loss 1.277562
# Epoch 250 Loss 1.269924
# Epoch 300 Loss 1.260314
# Early stopping at epoch 348
# Theta | train1 -> R² = 0.7065, MSE = 6.7003e-02
# X | train1 -> R² = -0.4320, MSE = 1.5441e-01
# Y | train1 -> R² = -1.0718, MSE = 1.7361e-01
# Theta | train2 -> R² = -0.1104, MSE = 2.5351e-01
# X | train2 -> R² = -0.3875, MSE = 1.1691e-01
# Y | train2 -> R² = -1.1183, MSE = 2.2810e-01
# Theta | test1 -> R² = 0.6500, MSE = 8.0412e-02
# X | test1 -> R² = -0.5176, MSE = 1.5899e-01
# Y | test1 -> R² = -1.2575, MSE = 1.8500e-01
# Theta | test2 -> R² = -0.1289, MSE = 2.6772e-01
# X | test2 -> R² = -0.3699, MSE = 1.1273e-01
# Y | test2 -> R² = -1.0640, MSE = 2.1908e-01
# Theta | test3 -> R² = 0.3683, MSE = 2.0768e-01
# X | test3 -> R² = -0.5513, MSE = 1.4273e-01
# Y | test3 -> R² = -1.5521, MSE = 1.9602e-01
# Theta | val -> R² = 0.5787, MSE = 1.3787e-01
# X | val -> R² = -0.6056, MSE = 1.5353e-01
# Y | val -> R² = -1.5443, MSE = 1.8943e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.568802
# Epoch 50 Loss 1.300391
# Epoch 100 Loss 1.283033
# Epoch 150 Loss 1.278198
# Epoch 200 Loss 1.264237
# Epoch 250 Loss 1.251410
# Epoch 300 Loss 1.247358
# Early stopping at epoch 327
# Theta | train1 -> R² = 0.7398, MSE = 5.9391e-02
# X | train1 -> R² = 0.0929, MSE = 9.7813e-02
# Y | train1 -> R² = -0.2982, MSE = 1.0879e-01
# Theta | train2 -> R² = -0.0264, MSE = 2.3432e-01
# X | train2 -> R² = 0.1911, MSE = 6.8155e-02
# Y | train2 -> R² = -0.4069, MSE = 1.5149e-01
# Theta | test1 -> R² = 0.8103, MSE = 4.3584e-02
# X | test1 -> R² = 0.0409, MSE = 1.0048e-01
# Y | test1 -> R² = -0.4759, MSE = 1.2095e-01
# Theta | test2 -> R² = -0.0419, MSE = 2.4709e-01
# X | test2 -> R² = 0.1799, MSE = 6.7492e-02
# Y | test2 -> R² = -0.3938, MSE = 1.4794e-01
# Theta | test3 -> R² = -0.2618, MSE = 4.1480e-01
# X | test3 -> R² = -0.5218, MSE = 1.4001e-01
# Y | test3 -> R² = 0.0967, MSE = 6.9380e-02
# Theta | val -> R² = 0.3872, MSE = 2.0055e-01
# X | val -> R² = -0.2861, MSE = 1.2298e-01
# Y | val -> R² = -0.0298, MSE = 7.6667e-02
# Figura salva em: ./results/model_16_8_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.569128
# Epoch 50 Loss 1.292404
# Epoch 100 Loss 1.280113
# Epoch 150 Loss 1.272529
# Epoch 200 Loss 1.261928
# Epoch 250 Loss 1.251970
# Epoch 300 Loss 1.244867
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.7868, MSE = 4.8664e-02
# X | train1 -> R² = -0.2632, MSE = 1.3620e-01
# Y | train1 -> R² = -0.8599, MSE = 1.5585e-01
# Theta | train2 -> R² = -0.0909, MSE = 2.4907e-01
# X | train2 -> R² = -0.0871, MSE = 9.1602e-02
# Y | train2 -> R² = -0.8573, MSE = 1.9999e-01
# Theta | test1 -> R² = 0.8090, MSE = 4.3869e-02
# X | test1 -> R² = -0.3340, MSE = 1.3975e-01
# Y | test1 -> R² = -1.0792, MSE = 1.7038e-01
# Theta | test2 -> R² = -0.1130, MSE = 2.6397e-01
# X | test2 -> R² = -0.0640, MSE = 8.7560e-02
# Y | test2 -> R² = -0.8135, MSE = 1.9249e-01
# Theta | test3 -> R² = 0.7802, MSE = 7.2268e-02
# X | test3 -> R² = -0.6777, MSE = 1.5436e-01
# Y | test3 -> R² = 0.0814, MSE = 7.0552e-02
# Theta | val -> R² = 0.6557, MSE = 1.1267e-01
# X | val -> R² = -0.4283, MSE = 1.3658e-01
# Y | val -> R² = -0.1415, MSE = 8.4985e-02
# Figura salva em: ./results/model_16_8_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.566861
# Epoch 50 Loss 1.302908
# Epoch 100 Loss 1.286073
# Epoch 150 Loss 1.276717
# Epoch 200 Loss 1.269174
# Epoch 250 Loss 1.257236
# Epoch 300 Loss 1.245898
# Early stopping at epoch 326
# Theta | train1 -> R² = 0.0729, MSE = 2.1163e-01
# X | train1 -> R² = -0.1732, MSE = 1.2650e-01
# Y | train1 -> R² = -0.5777, MSE = 1.3221e-01
# Theta | train2 -> R² = -1.6656, MSE = 6.0857e-01
# X | train2 -> R² = -0.0455, MSE = 8.8095e-02
# Y | train2 -> R² = -0.6068, MSE = 1.7302e-01
# Theta | test1 -> R² = 0.3104, MSE = 1.5842e-01
# X | test1 -> R² = -0.2328, MSE = 1.2915e-01
# Y | test1 -> R² = -0.7500, MSE = 1.4341e-01
# Theta | test2 -> R² = -1.5674, MSE = 6.0890e-01
# X | test2 -> R² = -0.0466, MSE = 8.6130e-02
# Y | test2 -> R² = -0.5749, MSE = 1.6716e-01
# Theta | test3 -> R² = 0.4673, MSE = 1.7514e-01
# X | test3 -> R² = -0.3440, MSE = 1.2365e-01
# Y | test3 -> R² = -0.8964, MSE = 1.4566e-01
# Theta | val -> R² = 0.1432, MSE = 2.8043e-01
# X | val -> R² = -0.4381, MSE = 1.3751e-01
# Y | val -> R² = -0.9643, MSE = 1.4624e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.570893
# Epoch 50 Loss 1.296414
# Epoch 100 Loss 1.279691
# Epoch 150 Loss 1.270043
# Epoch 200 Loss 1.259846
# Epoch 250 Loss 1.252688
# Epoch 300 Loss 1.243965
# Early stopping at epoch 328
# Theta | train1 -> R² = 0.6871, MSE = 7.1425e-02
# X | train1 -> R² = 0.1791, MSE = 8.8510e-02
# Y | train1 -> R² = -0.4102, MSE = 1.1817e-01
# Theta | train2 -> R² = 0.3281, MSE = 1.5339e-01
# X | train2 -> R² = 0.1631, MSE = 7.0519e-02
# Y | train2 -> R² = -0.3576, MSE = 1.4618e-01
# Theta | test1 -> R² = 0.5115, MSE = 1.1222e-01
# X | test1 -> R² = 0.1288, MSE = 9.1262e-02
# Y | test1 -> R² = -0.5712, MSE = 1.2876e-01
# Theta | test2 -> R² = 0.3030, MSE = 1.6531e-01
# X | test2 -> R² = 0.1484, MSE = 7.0081e-02
# Y | test2 -> R² = -0.3346, MSE = 1.4166e-01
# Theta | test3 -> R² = -0.5071, MSE = 4.9544e-01
# X | test3 -> R² = -0.6567, MSE = 1.5243e-01
# Y | test3 -> R² = 0.1414, MSE = 6.5950e-02
# Theta | val -> R² = 0.1215, MSE = 2.8750e-01
# X | val -> R² = -0.2979, MSE = 1.2411e-01
# Y | val -> R² = -0.0334, MSE = 7.6938e-02
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.573679
# Epoch 50 Loss 1.304726
# Epoch 100 Loss 1.282264
# Epoch 150 Loss 1.279041
# Epoch 200 Loss 1.271310
# Epoch 250 Loss 1.256468
# Epoch 300 Loss 1.247627
# Epoch 350 Loss 1.238688
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.7678, MSE = 5.3001e-02
# X | train1 -> R² = -0.2826, MSE = 1.3830e-01
# Y | train1 -> R² = -0.8599, MSE = 1.5585e-01
# Theta | train2 -> R² = 0.2423, MSE = 1.7300e-01
# X | train2 -> R² = -0.2620, MSE = 1.0634e-01
# Y | train2 -> R² = -0.8946, MSE = 2.0401e-01
# Theta | test1 -> R² = 0.3105, MSE = 1.5839e-01
# X | test1 -> R² = -0.3749, MSE = 1.4403e-01
# Y | test1 -> R² = -1.1129, MSE = 1.7315e-01
# Theta | test2 -> R² = 0.2428, MSE = 1.7958e-01
# X | test2 -> R² = -0.2439, MSE = 1.0236e-01
# Y | test2 -> R² = -0.8556, MSE = 1.9696e-01
# Theta | test3 -> R² = -0.0967, MSE = 3.6055e-01
# X | test3 -> R² = -0.4016, MSE = 1.2896e-01
# Y | test3 -> R² = -1.0360, MSE = 1.5638e-01
# Theta | val -> R² = 0.3392, MSE = 2.1627e-01
# X | val -> R² = -0.4396, MSE = 1.3766e-01
# Y | val -> R² = -1.1041, MSE = 1.5665e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.571932
# Epoch 50 Loss 1.298592
# Epoch 100 Loss 1.281853
# Epoch 150 Loss 1.273163
# Epoch 200 Loss 1.269571
# Epoch 250 Loss 1.260617
# Epoch 300 Loss 1.248544
# Early stopping at epoch 341
# Theta | train1 -> R² = 0.7685, MSE = 5.2849e-02
# X | train1 -> R² = -0.3225, MSE = 1.4260e-01
# Y | train1 -> R² = -1.2634, MSE = 1.8966e-01
# Theta | train2 -> R² = 0.1494, MSE = 1.9419e-01
# ...
# Epoch 0 Loss 1.568138
# Epoch 50 Loss 1.284676
# Epoch 100 Loss 1.278523
# Epoch 150 Loss 1.282862
# Epoch 200 Loss 1.279506
# Epoch 250 Loss 1.307440
# Epoch 300 Loss 1.262931
# Early stopping at epoch 305
# Theta | train1 -> R² = -0.0802, MSE = 2.4658e-01
# X | train1 -> R² = 0.0728, MSE = 9.9978e-02
# Y | train1 -> R² = -0.8080, MSE = 1.5150e-01
# Theta | train2 -> R² = 0.2784, MSE = 1.6474e-01
# X | train2 -> R² = 0.0494, MSE = 8.0097e-02
# Y | train2 -> R² = -0.8989, MSE = 2.0447e-01
# Theta | test1 -> R² = -1.0669, MSE = 4.7481e-01
# X | test1 -> R² = 0.0371, MSE = 1.0087e-01
# Y | test1 -> R² = -0.8660, MSE = 1.5291e-01
# Theta | test2 -> R² = 0.1435, MSE = 2.0312e-01
# X | test2 -> R² = 0.0344, MSE = 7.9463e-02
# Y | test2 -> R² = -0.8348, MSE = 1.9475e-01
# Theta | test3 -> R² = -2.5211, MSE = 1.1575e+00
# X | test3 -> R² = -0.1071, MSE = 1.0186e-01
# Y | test3 -> R² = -1.0153, MSE = 1.5479e-01
# Theta | val -> R² = -1.3076, MSE = 7.5522e-01
# X | val -> R² = -0.1422, MSE = 1.0922e-01
# Y | val -> R² = -1.0870, MSE = 1.5538e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.565042
# Epoch 50 Loss 1.296797
# Epoch 100 Loss 1.285824
# Epoch 150 Loss 1.299816
# Epoch 200 Loss 1.262558
# Epoch 250 Loss 1.286197
# Epoch 300 Loss 1.253713
# Early stopping at epoch 303
# Theta | train1 -> R² = 0.5123, MSE = 1.1132e-01
# X | train1 -> R² = 0.2614, MSE = 7.9643e-02
# Y | train1 -> R² = -0.4061, MSE = 1.1783e-01
# Theta | train2 -> R² = -1.6040, MSE = 5.9449e-01
# X | train2 -> R² = 0.0552, MSE = 7.9606e-02
# Y | train2 -> R² = -0.7720, MSE = 1.9080e-01
# Theta | test1 -> R² = 0.5871, MSE = 9.4846e-02
# X | test1 -> R² = 0.1993, MSE = 8.3884e-02
# Y | test1 -> R² = -0.5715, MSE = 1.2878e-01
# Theta | test2 -> R² = -1.5197, MSE = 5.9758e-01
# X | test2 -> R² = 0.0511, MSE = 7.8087e-02
# Y | test2 -> R² = -0.7460, MSE = 1.8532e-01
# Theta | test3 -> R² = 0.4188, MSE = 1.9106e-01
# X | test3 -> R² = 0.0767, MSE = 8.4946e-02
# Y | test3 -> R² = -0.4634, MSE = 1.1240e-01
# Theta | val -> R² = 0.4566, MSE = 1.7785e-01
# X | val -> R² = 0.1399, MSE = 8.2250e-02
# Y | val -> R² = -0.4580, MSE = 1.0855e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.574178
# Epoch 50 Loss 1.284302
# Epoch 100 Loss 1.284304
# Epoch 150 Loss 1.271108
# Epoch 200 Loss 1.260938
# Epoch 250 Loss 1.245112
# Epoch 300 Loss 1.230317
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.1970, MSE = 1.8330e-01
# X | train1 -> R² = -0.0317, MSE = 1.1124e-01
# Y | train1 -> R² = -1.1505, MSE = 1.8021e-01
# Theta | train2 -> R² = -1.1188, MSE = 4.8372e-01
# X | train2 -> R² = -0.1865, MSE = 9.9976e-02
# Y | train2 -> R² = -1.0843, MSE = 2.2444e-01
# Theta | test1 -> R² = 0.6717, MSE = 7.5427e-02
# X | test1 -> R² = -0.1211, MSE = 1.1744e-01
# Y | test1 -> R² = -1.3419, MSE = 1.9191e-01
# Theta | test2 -> R² = -0.8597, MSE = 4.4104e-01
# X | test2 -> R² = -0.1818, MSE = 9.7254e-02
# Y | test2 -> R² = -1.0265, MSE = 2.1510e-01
# Theta | test3 -> R² = 0.7881, MSE = 6.9647e-02
# X | test3 -> R² = -0.2088, MSE = 1.1121e-01
# Y | test3 -> R² = -2.2687, MSE = 2.5106e-01
# Theta | val -> R² = 0.4018, MSE = 1.9579e-01
# X | val -> R² = -0.2452, MSE = 1.1907e-01
# Y | val -> R² = -2.1815, MSE = 2.3686e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.565333
# Epoch 50 Loss 1.284163
# Epoch 100 Loss 1.282920
# Epoch 150 Loss 1.270027
# Epoch 200 Loss 1.254566
# Epoch 250 Loss 1.256079
# Epoch 300 Loss 1.240812
# Early stopping at epoch 302
# Theta | train1 -> R² = -1.6358, MSE = 6.0167e-01
# X | train1 -> R² = 0.5946, MSE = 4.3717e-02
# Y | train1 -> R² = -0.7068, MSE = 1.4302e-01
# Theta | train2 -> R² = -0.6125, MSE = 3.6813e-01
# X | train2 -> R² = -0.2141, MSE = 1.0230e-01
# Y | train2 -> R² = -0.5138, MSE = 1.6300e-01
# Theta | test1 -> R² = -1.8341, MSE = 6.5104e-01
# X | test1 -> R² = 0.5349, MSE = 4.8720e-02
# Y | test1 -> R² = -0.9166, MSE = 1.5706e-01
# Theta | test2 -> R² = -0.6955, MSE = 4.0210e-01
# X | test2 -> R² = -0.2275, MSE = 1.0101e-01
# Y | test2 -> R² = -0.5014, MSE = 1.5936e-01
# Theta | test3 -> R² = -4.4858, MSE = 1.8034e+00
# X | test3 -> R² = 0.3295, MSE = 6.1692e-02
# Y | test3 -> R² = -0.9641, MSE = 1.5085e-01
# Theta | val -> R² = -3.3651, MSE = 1.4286e+00
# X | val -> R² = 0.4472, MSE = 5.2856e-02
# Y | val -> R² = -1.0556, MSE = 1.5304e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.564104
# Epoch 50 Loss 1.284088
# Epoch 100 Loss 1.291587
# Epoch 150 Loss 1.275094
# Epoch 200 Loss 1.260139
# Epoch 250 Loss 1.240131
# Epoch 300 Loss 1.252995
# Early stopping at epoch 312
# Theta | train1 -> R² = 0.4181, MSE = 1.3284e-01
# X | train1 -> R² = -0.0660, MSE = 1.1494e-01
# Y | train1 -> R² = -1.4311, MSE = 2.0372e-01
# Theta | train2 -> R² = 0.4400, MSE = 1.2785e-01
# X | train2 -> R² = -0.1336, MSE = 9.5514e-02
# Y | train2 -> R² = -1.5694, MSE = 2.7667e-01
# Theta | test1 -> R² = 0.0965, MSE = 2.0755e-01
# X | test1 -> R² = -0.1108, MSE = 1.1636e-01
# Y | test1 -> R² = -1.6265, MSE = 2.1524e-01
# Theta | test2 -> R² = 0.3624, MSE = 1.5121e-01
# X | test2 -> R² = -0.1150, MSE = 9.1753e-02
# Y | test2 -> R² = -1.4687, MSE = 2.6204e-01
# Theta | test3 -> R² = -1.7154, MSE = 8.9267e-01
# X | test3 -> R² = -0.4652, MSE = 1.3481e-01
# Y | test3 -> R² = -4.2194, MSE = 4.0089e-01
# Theta | val -> R² = -0.3515, MSE = 4.4231e-01
# X | val -> R² = -0.4978, MSE = 1.4322e-01
# Y | val -> R² = -3.8168, MSE = 3.5861e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.567124
# Epoch 50 Loss 1.291322
# Epoch 100 Loss 1.298358
# Epoch 150 Loss 1.278146
# Epoch 200 Loss 1.271525
# Epoch 250 Loss 1.294379
# Epoch 300 Loss 1.287436
# Epoch 350 Loss 1.264611
# Epoch 400 Loss 1.256418
# Epoch 450 Loss 1.270304
# Epoch 500 Loss 1.277175
# Epoch 550 Loss 1.273584
# Early stopping at epoch 590
# Theta | train1 -> R² = 0.8203, MSE = 4.1031e-02
# X | train1 -> R² = 0.1334, MSE = 9.3445e-02
# Y | train1 -> R² = -0.2833, MSE = 1.0753e-01
# Theta | train2 -> R² = 0.4606, MSE = 1.2315e-01
# X | train2 -> R² = -0.2903, MSE = 1.0873e-01
# Y | train2 -> R² = -0.3108, MSE = 1.4115e-01
# Theta | test1 -> R² = 0.7968, MSE = 4.6681e-02
# X | test1 -> R² = -0.1195, MSE = 1.1728e-01
# Y | test1 -> R² = -0.2513, MSE = 1.0254e-01
# Theta | test2 -> R² = 0.4808, MSE = 1.2313e-01
# X | test2 -> R² = -0.3306, MSE = 1.0950e-01
# Y | test2 -> R² = -0.2798, MSE = 1.3585e-01
# Theta | test3 -> R² = 0.0674, MSE = 3.0659e-01
# X | test3 -> R² = -1.0138, MSE = 1.8528e-01
# Y | test3 -> R² = -1.2596, MSE = 1.7356e-01
# Theta | val -> R² = 0.6205, MSE = 1.2420e-01
# X | val -> R² = -0.8024, MSE = 1.7235e-01
# Y | val -> R² = -1.1298, MSE = 1.5857e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.569057
# Epoch 50 Loss 1.286608
# Epoch 100 Loss 1.279089
# Epoch 150 Loss 1.281613
# Epoch 200 Loss 1.276935
# Epoch 250 Loss 1.303766
# Epoch 300 Loss 1.275474
# Early stopping at epoch 302
# Theta | train1 -> R² = -4.7493, MSE = 1.3124e+00
# X | train1 -> R² = -0.0020, MSE = 1.0804e-01
# Y | train1 -> R² = -2.6671, MSE = 3.0729e-01
# Theta | train2 -> R² = -8.9172, MSE = 2.2641e+00
# X | train2 -> R² = -0.6248, MSE = 1.3691e-01
# Y | train2 -> R² = -3.5013, MSE = 4.8469e-01
# Theta | test1 -> R² = -4.6906, MSE = 1.3072e+00
# X | test1 -> R² = 0.0015, MSE = 1.0460e-01
# Y | test1 -> R² = -2.8670, MSE = 3.1690e-01
# Theta | test2 -> R² = -8.7349, MSE = 2.3087e+00
# X | test2 -> R² = -0.7076, MSE = 1.4052e-01
# Y | test2 -> R² = -3.4211, MSE = 4.6926e-01
# Theta | test3 -> R² = -6.7971, MSE = 2.5633e+00
# X | test3 -> R² = -3.4950, MSE = 4.1356e-01
# Y | test3 -> R² = -6.0066, MSE = 5.3816e-01
# Theta | val -> R² = -6.0366, MSE = 2.3029e+00
# X | val -> R² = -1.8701, MSE = 2.7445e-01
# Y | val -> R² = -4.9802, MSE = 4.4523e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.569798
# Epoch 50 Loss 1.285978
# Epoch 100 Loss 1.294324
# Epoch 150 Loss 1.289420
# Epoch 200 Loss 1.283992
# Epoch 250 Loss 1.269158
# Epoch 300 Loss 1.270665
# Early stopping at epoch 306
# Theta | train1 -> R² = -0.3220, MSE = 3.0177e-01
# X | train1 -> R² = 0.3013, MSE = 7.5337e-02
# Y | train1 -> R² = -3.6565, MSE = 3.9020e-01
# Theta | train2 -> R² = -0.0357, MSE = 2.3644e-01
# X | train2 -> R² = 0.0154, MSE = 8.2965e-02
# Y | train2 -> R² = -3.3983, MSE = 4.7360e-01
# Theta | test1 -> R² = -0.5223, MSE = 3.4971e-01
# X | test1 -> R² = 0.2680, MSE = 7.6683e-02
# Y | test1 -> R² = -4.0659, MSE = 4.1515e-01
# Theta | test2 -> R² = 0.0681, MSE = 2.2102e-01
# X | test2 -> R² = -0.0037, MSE = 8.2597e-02
# Y | test2 -> R² = -3.3445, MSE = 4.6114e-01
# Theta | test3 -> R² = -5.8692, MSE = 2.2582e+00
# X | test3 -> R² = -2.1780, MSE = 2.9239e-01
# Y | test3 -> R² = -4.6870, MSE = 4.3680e-01
# Theta | val -> R² = -3.9497, MSE = 1.6200e+00
# X | val -> R² = -1.1749, MSE = 2.0797e-01
# Y | val -> R² = -4.4068, MSE = 4.0254e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.627656
# Epoch 50 Loss 1.286056
# Epoch 100 Loss 1.275702
# Epoch 150 Loss 1.272857
# Epoch 200 Loss 1.274334
# Epoch 250 Loss 1.262021
# Epoch 300 Loss 1.281977
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.5476, MSE = 1.0328e-01
# X | train1 -> R² = -0.3854, MSE = 1.4938e-01
# Y | train1 -> R² = -0.3349, MSE = 1.1186e-01
# Theta | train2 -> R² = -0.4098, MSE = 3.2185e-01
# X | train2 -> R² = -0.3568, MSE = 1.1433e-01
# Y | train2 -> R² = -0.4831, MSE = 1.5969e-01
# Theta | test1 -> R² = 0.7520, MSE = 5.6970e-02
# X | test1 -> R² = -0.6285, MSE = 1.7061e-01
# Y | test1 -> R² = -0.5229, MSE = 1.2480e-01
# Theta | test2 -> R² = -0.2201, MSE = 2.8936e-01
# X | test2 -> R² = -0.3311, MSE = 1.0954e-01
# Y | test2 -> R² = -0.4642, MSE = 1.5541e-01
# Theta | test3 -> R² = -4.1314, MSE = 1.6869e+00
# X | test3 -> R² = -5.4365, MSE = 5.9219e-01
# Y | test3 -> R² = -0.6918, MSE = 1.2994e-01
# Theta | val -> R² = -1.8392, MSE = 9.2921e-01
# X | val -> R² = -4.6344, MSE = 5.3877e-01
# Y | val -> R² = -0.7958, MSE = 1.3370e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.583799
# Epoch 50 Loss 1.288204
# Epoch 100 Loss 1.301967
# Epoch 150 Loss 1.276207
# Epoch 200 Loss 1.285839
# Epoch 250 Loss 1.283683
# Epoch 300 Loss 1.292362
# Early stopping at epoch 310
# Theta | train1 -> R² = -2.4297, MSE = 7.8289e-01
# X | train1 -> R² = -2.0420, MSE = 3.2801e-01
# Y | train1 -> R² = -1.3756, MSE = 1.9907e-01
# Theta | train2 -> R² = -0.6815, MSE = 3.8389e-01
# X | train2 -> R² = -2.1589, MSE = 2.6617e-01
# Y | train2 -> R² = -1.2421, MSE = 2.4142e-01
# Theta | test1 -> R² = -2.2660, MSE = 7.5026e-01
# X | test1 -> R² = -2.6724, MSE = 3.8473e-01
# Y | test1 -> R² = -1.6170, MSE = 2.1446e-01
# Theta | test2 -> R² = -0.8311, MSE = 4.3428e-01
# X | test2 -> R² = -2.2650, MSE = 2.6869e-01
# Y | test2 -> R² = -1.2540, MSE = 2.3925e-01
# Theta | test3 -> R² = -5.0339, MSE = 1.9836e+00
# X | test3 -> R² = -2.0278, MSE = 2.7857e-01
# Y | test3 -> R² = 0.6127, MSE = 2.9748e-02
# Theta | val -> R² = -3.2722, MSE = 1.3982e+00
# X | val -> R² = -2.2951, MSE = 3.1509e-01
# Y | val -> R² = 0.5372, MSE = 3.4455e-02
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.564041
# Epoch 50 Loss 1.288369
# Epoch 100 Loss 1.282781
# Epoch 150 Loss 1.285883
# Epoch 200 Loss 1.275882
# Epoch 250 Loss 1.301518
# Epoch 300 Loss 1.282094
# Epoch 350 Loss 1.279013
# Epoch 400 Loss 1.270895
# Epoch 450 Loss 1.263506
# Epoch 500 Loss 1.249533
# Early stopping at epoch 515
# Theta | train1 -> R² = 0.7519, MSE = 5.6628e-02
# X | train1 -> R² = 0.1789, MSE = 8.8533e-02
# Y | train1 -> R² = -1.2943, MSE = 1.9225e-01
# Theta | train2 -> R² = 0.1842, MSE = 1.8625e-01
# X | train2 -> R² = 0.0461, MSE = 8.0376e-02
# Y | train2 -> R² = -1.4687, MSE = 2.6582e-01
# Theta | test1 -> R² = 0.7843, MSE = 4.9557e-02
# X | test1 -> R² = 0.1595, MSE = 8.8051e-02
# Y | test1 -> R² = -1.3019, MSE = 1.8863e-01
# Theta | test2 -> R² = 0.1210, MSE = 2.0846e-01
# X | test2 -> R² = 0.0387, MSE = 7.9111e-02
# Y | test2 -> R² = -1.3531, MSE = 2.4976e-01
# Theta | test3 -> R² = 0.1773, MSE = 2.7045e-01
# X | test3 -> R² = -0.2938, MSE = 1.1904e-01
# Y | test3 -> R² = -1.9966, MSE = 2.3016e-01
# Theta | val -> R² = 0.5014, MSE = 1.6319e-01
# X | val -> R² = -0.3366, MSE = 1.2781e-01
# Y | val -> R² = -1.6175, MSE = 1.9487e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.598531
# Epoch 50 Loss 1.294893
# Epoch 100 Loss 1.293298
# Epoch 150 Loss 1.299213
# Epoch 200 Loss 1.278541
# Epoch 250 Loss 1.282008
# Epoch 300 Loss 1.281136
# Early stopping at epoch 307
# Theta | train1 -> R² = 0.3296, MSE = 1.5304e-01
# X | train1 -> R² = -2.7134, MSE = 4.0040e-01
# Y | train1 -> R² = -3.1179, MSE = 3.4506e-01
# Theta | train2 -> R² = 0.0962, MSE = 2.0634e-01
# X | train2 -> R² = -2.2661, MSE = 2.7520e-01
# Y | train2 -> R² = -2.8012, MSE = 4.0931e-01
# Theta | test1 -> R² = 0.7835, MSE = 4.9743e-02
# X | test1 -> R² = -3.1233, MSE = 4.3196e-01
# Y | test1 -> R² = -3.6614, MSE = 3.8199e-01
# Theta | test2 -> R² = 0.0445, MSE = 2.2660e-01
# X | test2 -> R² = -2.3584, MSE = 2.7638e-01
# Y | test2 -> R² = -2.8739, MSE = 4.1118e-01
# Theta | test3 -> R² = -0.4776, MSE = 4.8576e-01
# X | test3 -> R² = -3.2380, MSE = 3.8991e-01
# Y | test3 -> R² = -0.9963, MSE = 1.5333e-01
# Theta | val -> R² = 0.1594, MSE = 2.7513e-01
# X | val -> R² = -3.1219, MSE = 3.9415e-01
# Y | val -> R² = -0.9858, MSE = 1.4784e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.547930
# Epoch 50 Loss 1.287637
# Epoch 100 Loss 1.275959
# Epoch 150 Loss 1.268575
# Epoch 200 Loss 1.286085
# Epoch 250 Loss 1.273846
# Epoch 300 Loss 1.263628
# Early stopping at epoch 309
# Theta | train1 -> R² = -0.1999, MSE = 2.7389e-01
# X | train1 -> R² = -3.6781, MSE = 5.0442e-01
# Y | train1 -> R² = -1.0534, MSE = 1.7207e-01
# Theta | train2 -> R² = -0.3687, MSE = 3.1248e-01
# X | train2 -> R² = -4.0247, MSE = 4.2338e-01
# Y | train2 -> R² = -1.5418, MSE = 2.7370e-01
# Theta | test1 -> R² = -0.1624, MSE = 2.6703e-01
# X | test1 -> R² = -4.2819, MSE = 5.5334e-01
# Y | test1 -> R² = -1.2560, MSE = 1.8488e-01
# Theta | test2 -> R² = -0.4225, MSE = 3.3736e-01
# X | test2 -> R² = -4.3623, MSE = 4.4128e-01
# Y | test2 -> R² = -1.5015, MSE = 2.6552e-01
# Theta | test3 -> R² = 0.3164, MSE = 2.2474e-01
# X | test3 -> R² = -6.5510, MSE = 6.9473e-01
# Y | test3 -> R² = -0.9371, MSE = 1.4878e-01
# Theta | val -> R² = 0.4638, MSE = 1.7550e-01
# X | val -> R² = -5.8338, MSE = 6.5347e-01
# Y | val -> R² = -0.9794, MSE = 1.4737e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.549680
# Epoch 50 Loss 1.282175
# Epoch 100 Loss 1.272084
# Epoch 150 Loss 1.276453
# Epoch 200 Loss 1.264973
# Epoch 250 Loss 1.277925
# Epoch 300 Loss 1.277107
# Epoch 350 Loss 1.265581
# Epoch 400 Loss 1.251052
# Epoch 450 Loss 1.246123
# Epoch 500 Loss 1.245068
# Early stopping at epoch 518
# Theta | train1 -> R² = -0.9222, MSE = 4.3877e-01
# X | train1 -> R² = -1.2789, MSE = 2.4573e-01
# Y | train1 -> R² = -1.8305, MSE = 2.3718e-01
# Theta | train2 -> R² = 0.5968, MSE = 9.2051e-02
# X | train2 -> R² = -1.9747, MSE = 2.5065e-01
# Y | train2 -> R² = -1.7351, MSE = 2.9451e-01
# Theta | test1 -> R² = 0.1374, MSE = 1.9816e-01
# X | test1 -> R² = -1.4697, MSE = 2.5873e-01
# Y | test1 -> R² = -2.1564, MSE = 2.5867e-01
# Theta | test2 -> R² = 0.4887, MSE = 1.2126e-01
# X | test2 -> R² = -2.0791, MSE = 2.5339e-01
# Y | test2 -> R² = -1.6552, MSE = 2.8183e-01
# Theta | test3 -> R² = 0.1625, MSE = 2.7534e-01
# X | test3 -> R² = -4.2365, MSE = 4.8178e-01
# Y | test3 -> R² = -4.1379, MSE = 3.9463e-01
# Theta | val -> R² = 0.7374, MSE = 8.5957e-02
# X | val -> R² = -3.4752, MSE = 4.2793e-01
# Y | val -> R² = -4.0676, MSE = 3.7728e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.553484
# Epoch 50 Loss 1.289777
# Epoch 100 Loss 1.285716
# Epoch 150 Loss 1.277332
# Epoch 200 Loss 1.284699
# Epoch 250 Loss 1.275978
# Epoch 300 Loss 1.278813
# Epoch 350 Loss 1.305657
# Epoch 400 Loss 1.276618
# Epoch 450 Loss 1.270107
# Early stopping at epoch 473
# Theta | train1 -> R² = -0.0018, MSE = 2.2868e-01
# X | train1 -> R² = -0.9345, MSE = 2.0859e-01
# Y | train1 -> R² = -1.0077, MSE = 1.6824e-01
# Theta | train2 -> R² = -2.6869, MSE = 8.4173e-01
# X | train2 -> R² = -0.9615, MSE = 1.6528e-01
# Y | train2 -> R² = -1.0475, MSE = 2.2047e-01
# Theta | test1 -> R² = 0.1729, MSE = 1.9001e-01
# X | test1 -> R² = -0.7947, MSE = 1.8801e-01
# Y | test1 -> R² = -1.1886, MSE = 1.7936e-01
# Theta | test2 -> R² = -1.9260, MSE = 6.9393e-01
# X | test2 -> R² = -1.0337, MSE = 1.6736e-01
# Y | test2 -> R² = -0.9721, MSE = 2.0933e-01
# Theta | test3 -> R² = -2.4826, MSE = 1.1449e+00
# X | test3 -> R² = -4.9174, MSE = 5.4443e-01
# Y | test3 -> R² = -3.0788, MSE = 3.1328e-01
# Theta | val -> R² = -2.6000, MSE = 1.1782e+00
# X | val -> R² = -3.3984, MSE = 4.2059e-01
# Y | val -> R² = -2.8612, MSE = 2.8747e-01
# Modelo 9 treinado e salvo no Excel
