# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 7
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1945, 7, 2)
# Dimensão da saida: (1945, 3)
# Dimensão da entrada: (1264, 7, 2)
# Dimensão da saida: (1264, 7, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1945, 7, 2)
# Dimensão da saida: (1945, 3)
# Dimensão da entrada fisica : (1945,)
# Dimensão da entrada fisica: (1945,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[8], [16], [32], [64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 Loss 1.586463
# Epoch 50 Loss 1.381183
# Epoch 100 Loss 1.347718
# Epoch 150 Loss 1.316724
# Epoch 200 Loss 1.307044
# Epoch 250 Loss 1.298802
# Epoch 300 Loss 1.298581
# Early stopping at epoch 326
# Theta | train1 -> R² = 0.7504, MSE = 5.7200e-02
# X | train1 -> R² = -0.8157, MSE = 1.9461e-01
# Y | train1 -> R² = -1.8413, MSE = 2.3747e-01
# Theta | train2 -> R² = -0.2187, MSE = 2.7633e-01
# X | train2 -> R² = -0.8335, MSE = 1.5411e-01
# Y | train2 -> R² = -1.5748, MSE = 2.7569e-01
# Theta | test1 -> R² = 0.4001, MSE = 1.3838e-01
# X | test1 -> R² = -1.0758, MSE = 2.1609e-01
# Y | test1 -> R² = -2.1658, MSE = 2.5859e-01
# Theta | test2 -> R² = -0.2426, MSE = 2.9272e-01
# X | test2 -> R² = -0.8273, MSE = 1.5001e-01
# Y | test2 -> R² = -1.5287, MSE = 2.6697e-01
# Theta | test3 -> R² = 0.4320, MSE = 1.8721e-01
# X | test3 -> R² = -0.9978, MSE = 1.8279e-01
# Y | test3 -> R² = -3.0210, MSE = 3.0777e-01
# Theta | val -> R² = 0.4555, MSE = 1.7865e-01
# X | val -> R² = -0.9803, MSE = 1.8821e-01
# Y | val -> R² = -2.9837, MSE = 2.9565e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.574656
# Epoch 50 Loss 1.386156
# Epoch 100 Loss 1.359459
# Epoch 150 Loss 1.327150
# Epoch 200 Loss 1.311561
# Epoch 250 Loss 1.298999
# Epoch 300 Loss 1.292656
# Early stopping at epoch 338
# Theta | train1 -> R² = 0.6921, MSE = 7.0571e-02
# X | train1 -> R² = -0.4504, MSE = 1.5546e-01
# Y | train1 -> R² = -1.0238, MSE = 1.6915e-01
# Theta | train2 -> R² = -0.3723, MSE = 3.1115e-01
# X | train2 -> R² = -0.4237, MSE = 1.1966e-01
# Y | train2 -> R² = -0.9264, MSE = 2.0626e-01
# Theta | test1 -> R² = 0.8237, MSE = 4.0669e-02
# X | test1 -> R² = -0.6159, MSE = 1.6821e-01
# Y | test1 -> R² = -1.2913, MSE = 1.8715e-01
# Theta | test2 -> R² = -0.3611, MSE = 3.2064e-01
# X | test2 -> R² = -0.4212, MSE = 1.1667e-01
# Y | test2 -> R² = -0.8847, MSE = 1.9898e-01
# Theta | test3 -> R² = -0.9098, MSE = 6.2944e-01
# X | test3 -> R² = -0.2883, MSE = 1.1787e-01
# Y | test3 -> R² = -0.3913, MSE = 1.0649e-01
# Theta | val -> R² = -0.0517, MSE = 3.4509e-01
# X | val -> R² = -0.2490, MSE = 1.1870e-01
# Y | val -> R² = -0.5649, MSE = 1.1614e-01
# Figura salva em: ./results/model_8_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.575720
# Epoch 50 Loss 1.372274
# Epoch 100 Loss 1.338879
# Epoch 150 Loss 1.328008
# Epoch 200 Loss 1.319390
# Epoch 250 Loss 1.308300
# Epoch 300 Loss 1.302128
# Early stopping at epoch 334
# Theta | train1 -> R² = 0.7651, MSE = 5.3837e-02
# X | train1 -> R² = 0.1750, MSE = 8.8418e-02
# Y | train1 -> R² = -1.1819, MSE = 1.8236e-01
# Theta | train2 -> R² = -0.2942, MSE = 2.9344e-01
# X | train2 -> R² = 0.0670, MSE = 7.8421e-02
# Y | train2 -> R² = -1.0749, MSE = 2.2216e-01
# Theta | test1 -> R² = 0.7261, MSE = 6.3175e-02
# X | test1 -> R² = 0.0887, MSE = 9.4867e-02
# Y | test1 -> R² = -1.4411, MSE = 1.9939e-01
# Theta | test2 -> R² = -0.1904, MSE = 2.8044e-01
# X | test2 -> R² = 0.0686, MSE = 7.6460e-02
# Y | test2 -> R² = -1.0451, MSE = 2.1592e-01
# Theta | test3 -> R² = 0.6169, MSE = 1.2627e-01
# X | test3 -> R² = -0.0523, MSE = 9.6275e-02
# Y | test3 -> R² = -1.8847, MSE = 2.2079e-01
# Theta | val -> R² = 0.7077, MSE = 9.5910e-02
# X | val -> R² = -0.0200, MSE = 9.6947e-02
# Y | val -> R² = -1.8667, MSE = 2.1276e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.579968
# Epoch 50 Loss 1.374358
# Epoch 100 Loss 1.324477
# Epoch 150 Loss 1.316819
# Epoch 200 Loss 1.309969
# Epoch 250 Loss 1.303784
# Epoch 300 Loss 1.296252
# Epoch 350 Loss 1.289206
# Early stopping at epoch 355
# Theta | train1 -> R² = 0.5338, MSE = 1.0685e-01
# X | train1 -> R² = -0.6391, MSE = 1.7567e-01
# Y | train1 -> R² = -1.8781, MSE = 2.4056e-01
# Theta | train2 -> R² = 0.4440, MSE = 1.2607e-01
# X | train2 -> R² = -0.5704, MSE = 1.3199e-01
# Y | train2 -> R² = -1.8129, MSE = 3.0119e-01
# Theta | test1 -> R² = 0.4355, MSE = 1.3022e-01
# X | test1 -> R² = -0.7732, MSE = 1.8459e-01
# Y | test1 -> R² = -2.1904, MSE = 2.6059e-01
# Theta | test2 -> R² = 0.3946, MSE = 1.4262e-01
# X | test2 -> R² = -0.5469, MSE = 1.2699e-01
# Y | test2 -> R² = -1.7415, MSE = 2.8944e-01
# Theta | test3 -> R² = -3.7298, MSE = 1.5589e+00
# X | test3 -> R² = -0.9435, MSE = 1.7782e-01
# Y | test3 -> R² = -3.5310, MSE = 3.4680e-01
# Theta | val -> R² = -1.7775, MSE = 9.1134e-01
# X | val -> R² = -0.9342, MSE = 1.8383e-01
# Y | val -> R² = -3.3057, MSE = 3.1955e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.573884
# Epoch 50 Loss 1.383892
# Epoch 100 Loss 1.364922
# Epoch 150 Loss 1.344587
# Epoch 200 Loss 1.328477
# Epoch 250 Loss 1.320549
# Epoch 300 Loss 1.315717
# Early stopping at epoch 333
# Theta | train1 -> R² = 0.6543, MSE = 7.9242e-02
# X | train1 -> R² = 0.0324, MSE = 1.0371e-01
# Y | train1 -> R² = -0.7478, MSE = 1.4608e-01
# Theta | train2 -> R² = -0.5444, MSE = 3.5017e-01
# X | train2 -> R² = 0.0878, MSE = 7.6672e-02
# Y | train2 -> R² = -0.7748, MSE = 1.9003e-01
# Theta | test1 -> R² = 0.6925, MSE = 7.0937e-02
# X | test1 -> R² = -0.0118, MSE = 1.0533e-01
# Y | test1 -> R² = -0.9217, MSE = 1.5696e-01
# Theta | test2 -> R² = -0.4036, MSE = 3.3067e-01
# X | test2 -> R² = 0.0842, MSE = 7.5180e-02
# Y | test2 -> R² = -0.7269, MSE = 1.8232e-01
# Theta | test3 -> R² = 0.6526, MSE = 1.1450e-01
# X | test3 -> R² = -0.1968, MSE = 1.0950e-01
# Y | test3 -> R² = -1.6573, MSE = 2.0339e-01
# Theta | val -> R² = 0.6724, MSE = 1.0748e-01
# X | val -> R² = -0.1984, MSE = 1.1390e-01
# Y | val -> R² = -1.6249, MSE = 1.9481e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.562266
# Epoch 50 Loss 1.387828
# Epoch 100 Loss 1.366975
# Epoch 150 Loss 1.353359
# Epoch 200 Loss 1.343247
# Epoch 250 Loss 1.340048
# Epoch 300 Loss 1.339658
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.8044, MSE = 4.4843e-02
# X | train1 -> R² = -0.5227, MSE = 1.6320e-01
# Y | train1 -> R² = -1.4948, MSE = 2.0852e-01
# Theta | train2 -> R² = -0.1670, MSE = 2.6461e-01
# X | train2 -> R² = -0.4851, MSE = 1.2482e-01
# Y | train2 -> R² = -1.3284, MSE = 2.4930e-01
# Theta | test1 -> R² = 0.8097, MSE = 4.3883e-02
# X | test1 -> R² = -0.7069, MSE = 1.7768e-01
# Y | test1 -> R² = -1.8025, MSE = 2.2891e-01
# Theta | test2 -> R² = -0.2001, MSE = 2.8273e-01
# X | test2 -> R² = -0.4671, MSE = 1.2044e-01
# Y | test2 -> R² = -1.2895, MSE = 2.4171e-01
# Theta | test3 -> R² = -1.1869, MSE = 7.2076e-01
# X | test3 -> R² = -0.3515, MSE = 1.2366e-01
# Y | test3 -> R² = -0.9032, MSE = 1.4567e-01
# Theta | val -> R² = -0.3964, MSE = 4.5819e-01
# X | val -> R² = -0.2859, MSE = 1.2222e-01
# Y | val -> R² = -1.0451, MSE = 1.5178e-01
# Figura salva em: ./results/model_8_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.578404
# Epoch 50 Loss 1.355379
# Epoch 100 Loss 1.336832
# Epoch 150 Loss 1.328542
# Epoch 200 Loss 1.316509
# Epoch 250 Loss 1.310722
# Epoch 300 Loss 1.305189
# Epoch 350 Loss 1.301432
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.7066, MSE = 6.7240e-02
# X | train1 -> R² = -0.0287, MSE = 1.1026e-01
# Y | train1 -> R² = -1.1184, MSE = 1.7705e-01
# Theta | train2 -> R² = 0.1663, MSE = 1.8902e-01
# X | train2 -> R² = 0.0023, MSE = 8.3855e-02
# Y | train2 -> R² = -1.0760, MSE = 2.2229e-01
# Theta | test1 -> R² = 0.8110, MSE = 4.3605e-02
# X | test1 -> R² = -0.1100, MSE = 1.1555e-01
# Y | test1 -> R² = -1.3311, MSE = 1.9040e-01
# Theta | test2 -> R² = 0.1744, MSE = 1.9451e-01
# X | test2 -> R² = 0.0201, MSE = 8.0440e-02
# Y | test2 -> R² = -1.0083, MSE = 2.1203e-01
# Theta | test3 -> R² = -3.2750, MSE = 1.4090e+00
# X | test3 -> R² = -0.2239, MSE = 1.1198e-01
# Y | test3 -> R² = -0.8352, MSE = 1.4047e-01
# Theta | val -> R² = -1.3634, MSE = 7.7547e-01
# X | val -> R² = -0.1574, MSE = 1.1000e-01
# Y | val -> R² = -0.9723, MSE = 1.4638e-01
# Figura salva em: ./results/model_8_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.563097
# Epoch 50 Loss 1.338323
# Epoch 100 Loss 1.319691
# Epoch 150 Loss 1.311294
# Epoch 200 Loss 1.304139
# Epoch 250 Loss 1.300058
# Epoch 300 Loss 1.295190
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.6100, MSE = 8.9389e-02
# X | train1 -> R² = -0.0800, MSE = 1.1575e-01
# Y | train1 -> R² = -0.4733, MSE = 1.2314e-01
# Theta | train2 -> R² = -0.0948, MSE = 2.4824e-01
# X | train2 -> R² = -0.1170, MSE = 9.3887e-02
# Y | train2 -> R² = -0.6691, MSE = 1.7872e-01
# Theta | test1 -> R² = 0.8189, MSE = 4.1762e-02
# X | test1 -> R² = -0.1325, MSE = 1.1789e-01
# Y | test1 -> R² = -0.6632, MSE = 1.3585e-01
# Theta | test2 -> R² = 0.0496, MSE = 2.2389e-01
# X | test2 -> R² = -0.0988, MSE = 9.0208e-02
# Y | test2 -> R² = -0.6025, MSE = 1.6918e-01
# Theta | test3 -> R² = -1.8318, MSE = 9.3331e-01
# X | test3 -> R² = -0.1367, MSE = 1.0400e-01
# Y | test3 -> R² = -0.1883, MSE = 9.0949e-02
# Theta | val -> R² = -0.7741, MSE = 5.8212e-01
# X | val -> R² = -0.1270, MSE = 1.0712e-01
# Y | val -> R² = -0.3280, MSE = 9.8562e-02
# Figura salva em: ./results/model_8_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.576690
# Epoch 50 Loss 1.386851
# Epoch 100 Loss 1.363062
# Epoch 150 Loss 1.348800
# Epoch 200 Loss 1.335479
# Epoch 250 Loss 1.326585
# Epoch 300 Loss 1.305918
# Early stopping at epoch 327
# Theta | train1 -> R² = 0.7878, MSE = 4.8630e-02
# X | train1 -> R² = -0.2062, MSE = 1.2928e-01
# Y | train1 -> R² = -1.4662, MSE = 2.0612e-01
# Theta | train2 -> R² = -0.1772, MSE = 2.6691e-01
# X | train2 -> R² = -0.2620, MSE = 1.0607e-01
# Y | train2 -> R² = -1.2752, MSE = 2.4361e-01
# Theta | test1 -> R² = 0.7409, MSE = 5.9768e-02
# X | test1 -> R² = -0.3420, MSE = 1.3970e-01
# Y | test1 -> R² = -1.7298, MSE = 2.2297e-01
# Theta | test2 -> R² = -0.1721, MSE = 2.7612e-01
# X | test2 -> R² = -0.2520, MSE = 1.0278e-01
# Y | test2 -> R² = -1.2313, MSE = 2.3557e-01
# Theta | test3 -> R² = 0.5037, MSE = 1.6358e-01
# X | test3 -> R² = -0.2327, MSE = 1.1278e-01
# Y | test3 -> R² = -1.2712, MSE = 1.7384e-01
# Theta | val -> R² = 0.6325, MSE = 1.2060e-01
# X | val -> R² = -0.2092, MSE = 1.1492e-01
# Y | val -> R² = -1.4313, MSE = 1.8044e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.569257
# Epoch 50 Loss 1.397049
# Epoch 100 Loss 1.338859
# Epoch 150 Loss 1.316423
# Epoch 200 Loss 1.301255
# Epoch 250 Loss 1.292257
# Epoch 300 Loss 1.285702
# Epoch 350 Loss 1.282465
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.7046, MSE = 6.7715e-02
# X | train1 -> R² = -0.2014, MSE = 1.2877e-01
# Y | train1 -> R² = -1.2878, MSE = 1.9122e-01
# Theta | train2 -> R² = -0.0831, MSE = 2.4558e-01
# X | train2 -> R² = -0.1906, MSE = 1.0007e-01
# Y | train2 -> R² = -1.2626, MSE = 2.4226e-01
# Theta | test1 -> R² = 0.6348, MSE = 8.4233e-02
# X | test1 -> R² = -0.3633, MSE = 1.4191e-01
# Y | test1 -> R² = -1.6358, MSE = 2.1529e-01
# Theta | test2 -> R² = -0.1532, MSE = 2.7167e-01
# X | test2 -> R² = -0.1580, MSE = 9.5067e-02
# Y | test2 -> R² = -1.2108, MSE = 2.3340e-01
# Theta | test3 -> R² = -0.4051, MSE = 4.6310e-01
# X | test3 -> R² = -0.2944, MSE = 1.1843e-01
# Y | test3 -> R² = -1.1781, MSE = 1.6671e-01
# Theta | val -> R² = -0.0463, MSE = 3.4330e-01
# X | val -> R² = -0.2365, MSE = 1.1752e-01
# Y | val -> R² = -1.2643, MSE = 1.6805e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.565312
# Epoch 50 Loss 1.344442
# Epoch 100 Loss 1.311486
# Epoch 150 Loss 1.298168
# Epoch 200 Loss 1.283586
# Epoch 250 Loss 1.280329
# Epoch 300 Loss 1.271951
# Epoch 350 Loss 1.264508
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.6190, MSE = 8.7338e-02
# X | train1 -> R² = -0.1762, MSE = 1.2606e-01
# Y | train1 -> R² = -0.6434, MSE = 1.3736e-01
# Theta | train2 -> R² = -0.4069, MSE = 3.1901e-01
# X | train2 -> R² = -0.1276, MSE = 9.4777e-02
# Y | train2 -> R² = -0.6419, MSE = 1.7580e-01
# Theta | test1 -> R² = 0.7699, MSE = 5.3071e-02
# X | test1 -> R² = -0.2749, MSE = 1.3271e-01
# Y | test1 -> R² = -0.8497, MSE = 1.5108e-01
# Theta | test2 -> R² = -0.1944, MSE = 2.8138e-01
# X | test2 -> R² = -0.1259, MSE = 9.2427e-02
# Y | test2 -> R² = -0.5939, MSE = 1.6828e-01
# Theta | test3 -> R² = 0.3653, MSE = 2.0920e-01
# X | test3 -> R² = -0.4248, MSE = 1.3036e-01
# Y | test3 -> R² = -0.0914, MSE = 8.3538e-02
# Theta | val -> R² = 0.5364, MSE = 1.5210e-01
# X | val -> R² = -0.4604, MSE = 1.3880e-01
# Y | val -> R² = -0.2672, MSE = 9.4044e-02
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.565763
# Epoch 50 Loss 1.373835
# Epoch 100 Loss 1.323083
# Epoch 150 Loss 1.307883
# Epoch 200 Loss 1.296819
# Epoch 250 Loss 1.285482
# Epoch 300 Loss 1.275924
# Epoch 350 Loss 1.276820
# Early stopping at epoch 391
# Theta | train1 -> R² = 0.8707, MSE = 2.9634e-02
# X | train1 -> R² = -0.2531, MSE = 1.3431e-01
# Y | train1 -> R² = -0.8226, MSE = 1.5234e-01
# Theta | train2 -> R² = -0.0354, MSE = 2.3476e-01
# X | train2 -> R² = -0.2492, MSE = 1.0500e-01
# Y | train2 -> R² = -0.8539, MSE = 1.9851e-01
# Theta | test1 -> R² = 0.8698, MSE = 3.0038e-02
# X | test1 -> R² = -0.3408, MSE = 1.3957e-01
# Y | test1 -> R² = -1.0950, MSE = 1.7112e-01
# Theta | test2 -> R² = 0.1923, MSE = 1.9028e-01
# X | test2 -> R² = -0.2413, MSE = 1.0190e-01
# Y | test2 -> R² = -0.7883, MSE = 1.8880e-01
# Theta | test3 -> R² = 0.6594, MSE = 1.1225e-01
# X | test3 -> R² = -0.4971, MSE = 1.3698e-01
# Y | test3 -> R² = -0.7422, MSE = 1.3335e-01
# Theta | val -> R² = 0.6802, MSE = 1.0495e-01
# X | val -> R² = -0.4916, MSE = 1.4176e-01
# Y | val -> R² = -0.8694, MSE = 1.3874e-01
# Figura salva em: ./results/model_16_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.561786
# Epoch 50 Loss 1.347935
# Epoch 100 Loss 1.315956
# Epoch 150 Loss 1.302887
# Epoch 200 Loss 1.294699
# Epoch 250 Loss 1.276500
# Epoch 300 Loss 1.267316
# Early stopping at epoch 330
# Theta | train1 -> R² = 0.8493, MSE = 3.4540e-02
# X | train1 -> R² = -0.2335, MSE = 1.3221e-01
# Y | train1 -> R² = -0.9353, MSE = 1.6175e-01
# Theta | train2 -> R² = 0.2093, MSE = 1.7928e-01
# X | train2 -> R² = -0.1542, MSE = 9.7011e-02
# Y | train2 -> R² = -0.9115, MSE = 2.0467e-01
# Theta | test1 -> R² = 0.8635, MSE = 3.1481e-02
# X | test1 -> R² = -0.3298, MSE = 1.3842e-01
# Y | test1 -> R² = -1.1479, MSE = 1.7544e-01
# Theta | test2 -> R² = 0.2537, MSE = 1.7581e-01
# X | test2 -> R² = -0.1525, MSE = 9.4611e-02
# Y | test2 -> R² = -0.8662, MSE = 1.9703e-01
# Theta | test3 -> R² = -0.0332, MSE = 3.4051e-01
# X | test3 -> R² = -0.3600, MSE = 1.2443e-01
# Y | test3 -> R² = -1.1740, MSE = 1.6640e-01
# Theta | val -> R² = 0.4594, MSE = 1.7736e-01
# X | val -> R² = -0.4107, MSE = 1.3408e-01
# Y | val -> R² = -1.2380, MSE = 1.6609e-01
# Figura salva em: ./results/model_16_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.553028
# Epoch 50 Loss 1.332235
# Epoch 100 Loss 1.311491
# Epoch 150 Loss 1.298906
# Epoch 200 Loss 1.282088
# Epoch 250 Loss 1.271812
# Epoch 300 Loss 1.267577
# Early stopping at epoch 338
# Theta | train1 -> R² = 0.7639, MSE = 5.4123e-02
# X | train1 -> R² = 0.1287, MSE = 9.3390e-02
# Y | train1 -> R² = -0.8996, MSE = 1.5877e-01
# Theta | train2 -> R² = 0.3249, MSE = 1.5307e-01
# X | train2 -> R² = 0.0721, MSE = 7.7991e-02
# Y | train2 -> R² = -0.7413, MSE = 1.8645e-01
# Theta | test1 -> R² = 0.8400, MSE = 3.6898e-02
# X | test1 -> R² = 0.1113, MSE = 9.2507e-02
# Y | test1 -> R² = -1.0978, MSE = 1.7135e-01
# Theta | test2 -> R² = 0.3685, MSE = 1.4876e-01
# X | test2 -> R² = 0.0595, MSE = 7.7207e-02
# Y | test2 -> R² = -0.6683, MSE = 1.7613e-01
# Theta | test3 -> R² = -2.2220, MSE = 1.0619e+00
# X | test3 -> R² = -0.0275, MSE = 9.4012e-02
# Y | test3 -> R² = -1.7837, MSE = 2.1306e-01
# Theta | val -> R² = -0.6389, MSE = 5.3776e-01
# X | val -> R² = -0.0596, MSE = 1.0071e-01
# Y | val -> R² = -1.7921, MSE = 2.0722e-01
# Figura salva em: ./results/model_16_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.590110
# Epoch 50 Loss 1.377820
# Epoch 100 Loss 1.335062
# Epoch 150 Loss 1.311530
# Epoch 200 Loss 1.296405
# Epoch 250 Loss 1.289801
# Epoch 300 Loss 1.291759
# Epoch 350 Loss 1.272583
# Early stopping at epoch 387
# Theta | train1 -> R² = 0.4344, MSE = 1.2965e-01
# X | train1 -> R² = -0.2149, MSE = 1.3021e-01
# Y | train1 -> R² = -0.6945, MSE = 1.4163e-01
# Theta | train2 -> R² = -1.5311, MSE = 5.7391e-01
# X | train2 -> R² = -0.1820, MSE = 9.9347e-02
# Y | train2 -> R² = -0.7757, MSE = 1.9013e-01
# Theta | test1 -> R² = 0.6949, MSE = 7.0383e-02
# X | test1 -> R² = -0.2464, MSE = 1.2975e-01
# Y | test1 -> R² = -0.9237, MSE = 1.5713e-01
# Theta | test2 -> R² = -0.9880, MSE = 4.6835e-01
# X | test2 -> R² = -0.1731, MSE = 9.6305e-02
# Y | test2 -> R² = -0.6959, MSE = 1.7905e-01
# Theta | test3 -> R² = 0.5558, MSE = 1.4639e-01
# X | test3 -> R² = -0.4636, MSE = 1.3391e-01
# Y | test3 -> R² = -0.8932, MSE = 1.4491e-01
# Theta | val -> R² = 0.5435, MSE = 1.4978e-01
# X | val -> R² = -0.4271, MSE = 1.3563e-01
# Y | val -> R² = -1.0174, MSE = 1.4972e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.581313
# Epoch 50 Loss 1.382255
# Epoch 100 Loss 1.362703
# Epoch 150 Loss 1.332615
# Epoch 200 Loss 1.305247
# Epoch 250 Loss 1.291945
# Epoch 300 Loss 1.278572
# Early stopping at epoch 319
# Theta | train1 -> R² = 0.6184, MSE = 8.7457e-02
# X | train1 -> R² = -0.0189, MSE = 1.0920e-01
# Y | train1 -> R² = -1.2817, MSE = 1.9070e-01
# Theta | train2 -> R² = 0.2002, MSE = 1.8135e-01
# X | train2 -> R² = -0.1602, MSE = 9.7515e-02
# Y | train2 -> R² = -1.0536, MSE = 2.1988e-01
# Theta | test1 -> R² = 0.4609, MSE = 1.2434e-01
# X | test1 -> R² = -0.1720, MSE = 1.2200e-01
# Y | test1 -> R² = -1.6036, MSE = 2.1267e-01
# Theta | test2 -> R² = 0.1277, MSE = 2.0551e-01
# X | test2 -> R² = -0.1620, MSE = 9.5397e-02
# Y | test2 -> R² = -1.0426, MSE = 2.1565e-01
# Theta | test3 -> R² = -0.8707, MSE = 6.1654e-01
# X | test3 -> R² = -0.0827, MSE = 9.9061e-02
# Y | test3 -> R² = -1.4632, MSE = 1.8853e-01
# Theta | val -> R² = -0.3061, MSE = 4.2855e-01
# X | val -> R² = -0.0319, MSE = 9.8074e-02
# Y | val -> R² = -1.5592, MSE = 1.8993e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.574237
# Epoch 50 Loss 1.349754
# Epoch 100 Loss 1.316714
# Epoch 150 Loss 1.297259
# Epoch 200 Loss 1.286706
# Epoch 250 Loss 1.280769
# Epoch 300 Loss 1.275128
# Early stopping at epoch 317
# Theta | train1 -> R² = 0.7950, MSE = 4.6983e-02
# X | train1 -> R² = -0.2310, MSE = 1.3193e-01
# Y | train1 -> R² = -1.3350, MSE = 1.9516e-01
# Theta | train2 -> R² = -0.4574, MSE = 3.3044e-01
# X | train2 -> R² = -0.2690, MSE = 1.0666e-01
# Y | train2 -> R² = -1.1274, MSE = 2.2778e-01
# Theta | test1 -> R² = 0.7522, MSE = 5.7165e-02
# X | test1 -> R² = -0.3968, MSE = 1.4540e-01
# Y | test1 -> R² = -1.6228, MSE = 2.1423e-01
# Theta | test2 -> R² = -0.3545, MSE = 3.1911e-01
# X | test2 -> R² = -0.2710, MSE = 1.0434e-01
# Y | test2 -> R² = -1.0996, MSE = 2.2166e-01
# Theta | test3 -> R² = -0.1145, MSE = 3.6730e-01
# X | test3 -> R² = -0.2254, MSE = 1.1212e-01
# Y | test3 -> R² = -1.0885, MSE = 1.5985e-01
# Theta | val -> R² = 0.1272, MSE = 2.8637e-01
# X | val -> R² = -0.2233, MSE = 1.1626e-01
# Y | val -> R² = -1.2773, MSE = 1.6901e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.565607
# Epoch 50 Loss 1.346266
# Epoch 100 Loss 1.330443
# Epoch 150 Loss 1.298103
# Epoch 200 Loss 1.287826
# Epoch 250 Loss 1.283500
# Epoch 300 Loss 1.272858
# Epoch 350 Loss 1.266775
# Early stopping at epoch 358
# Theta | train1 -> R² = 0.4540, MSE = 1.2514e-01
# X | train1 -> R² = -0.0332, MSE = 1.1074e-01
# Y | train1 -> R² = -0.6172, MSE = 1.3517e-01
# Theta | train2 -> R² = 0.4974, MSE = 1.1396e-01
# X | train2 -> R² = -0.0209, MSE = 8.5806e-02
# Y | train2 -> R² = -0.7165, MSE = 1.8379e-01
# Theta | test1 -> R² = 0.1087, MSE = 2.0558e-01
# X | test1 -> R² = -0.1086, MSE = 1.1541e-01
# Y | test1 -> R² = -0.8459, MSE = 1.5078e-01
# Theta | test2 -> R² = 0.3693, MSE = 1.4857e-01
# X | test2 -> R² = -0.0008, MSE = 8.2160e-02
# Y | test2 -> R² = -0.6425, MSE = 1.7341e-01
# Theta | test3 -> R² = -0.1634, MSE = 3.8343e-01
# X | test3 -> R² = -0.3107, MSE = 1.1992e-01
# Y | test3 -> R² = -1.9910, MSE = 2.2894e-01
# Theta | val -> R² = 0.3071, MSE = 2.2734e-01
# X | val -> R² = -0.3073, MSE = 1.2425e-01
# Y | val -> R² = -1.9393, MSE = 2.1815e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.565825
# Epoch 50 Loss 1.332333
# Epoch 100 Loss 1.310467
# Epoch 150 Loss 1.297763
# Epoch 200 Loss 1.284131
# Epoch 250 Loss 1.270875
# Epoch 300 Loss 1.261791
# Early stopping at epoch 332
# Theta | train1 -> R² = 0.7602, MSE = 5.4968e-02
# X | train1 -> R² = -0.0353, MSE = 1.1097e-01
# Y | train1 -> R² = -0.7367, MSE = 1.4516e-01
# Theta | train2 -> R² = 0.4700, MSE = 1.2017e-01
# X | train2 -> R² = 0.0087, MSE = 8.3317e-02
# Y | train2 -> R² = -0.7365, MSE = 1.8593e-01
# Theta | test1 -> R² = 0.6437, MSE = 8.2184e-02
# X | test1 -> R² = -0.0947, MSE = 1.1395e-01
# Y | test1 -> R² = -0.9127, MSE = 1.5623e-01
# Theta | test2 -> R² = 0.4685, MSE = 1.2522e-01
# X | test2 -> R² = 0.0045, MSE = 8.1726e-02
# Y | test2 -> R² = -0.6962, MSE = 1.7908e-01
# Theta | test3 -> R² = -0.2392, MSE = 4.0841e-01
# X | test3 -> R² = -0.1402, MSE = 1.0432e-01
# Y | test3 -> R² = -1.2874, MSE = 1.7508e-01
# Theta | val -> R² = 0.3723, MSE = 2.0596e-01
# X | val -> R² = -0.1560, MSE = 1.0987e-01
# Y | val -> R² = -1.2689, MSE = 1.6839e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.579138
# Epoch 50 Loss 1.382255
# Epoch 100 Loss 1.341439
# Epoch 150 Loss 1.301943
# Epoch 200 Loss 1.290050
# Epoch 250 Loss 1.291240
# Epoch 300 Loss 1.271503
# Epoch 350 Loss 1.264087
# Epoch 400 Loss 1.262461
# Epoch 450 Loss 1.251228
# Early stopping at epoch 464
# Theta | train1 -> R² = -0.3132, MSE = 3.0100e-01
# X | train1 -> R² = -0.2811, MSE = 1.3730e-01
# Y | train1 -> R² = -0.5114, MSE = 1.2632e-01
# Theta | train2 -> R² = 0.5616, MSE = 9.9409e-02
# X | train2 -> R² = -0.2792, MSE = 1.0752e-01
# Y | train2 -> R² = -0.7037, MSE = 1.8242e-01
# Theta | test1 -> R² = 0.2914, MSE = 1.6344e-01
# X | test1 -> R² = -0.2854, MSE = 1.3381e-01
# Y | test1 -> R² = -0.5614, MSE = 1.2753e-01
# Theta | test2 -> R² = 0.2320, MSE = 1.8092e-01
# X | test2 -> R² = -0.3458, MSE = 1.1048e-01
# Y | test2 -> R² = -0.6406, MSE = 1.7320e-01
# Theta | test3 -> R² = -0.0781, MSE = 3.5533e-01
# X | test3 -> R² = -0.8678, MSE = 1.7089e-01
# Y | test3 -> R² = -0.2241, MSE = 9.3693e-02
# Theta | val -> R² = 0.3525, MSE = 2.1246e-01
# X | val -> R² = -0.7133, MSE = 1.6283e-01
# Y | val -> R² = -0.2418, MSE = 9.2162e-02
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.582087
# Epoch 50 Loss 1.359111
# Epoch 100 Loss 1.310308
# Epoch 150 Loss 1.293456
# Epoch 200 Loss 1.280004
# Epoch 250 Loss 1.273188
# Epoch 300 Loss 1.276780
# Early stopping at epoch 333
# Theta | train1 -> R² = 0.2852, MSE = 1.6383e-01
# X | train1 -> R² = -0.1628, MSE = 1.2463e-01
# Y | train1 -> R² = -0.9875, MSE = 1.6612e-01
# Theta | train2 -> R² = 0.2882, MSE = 1.6140e-01
# X | train2 -> R² = -0.2310, MSE = 1.0347e-01
# Y | train2 -> R² = -0.9735, MSE = 2.1131e-01
# Theta | test1 -> R² = 0.0429, MSE = 2.2076e-01
# X | test1 -> R² = -0.2415, MSE = 1.2924e-01
# Y | test1 -> R² = -1.1740, MSE = 1.7758e-01
# Theta | test2 -> R² = 0.2197, MSE = 1.8383e-01
# X | test2 -> R² = -0.2295, MSE = 1.0093e-01
# Y | test2 -> R² = -0.9254, MSE = 2.0328e-01
# Theta | test3 -> R² = -0.7799, MSE = 5.8664e-01
# X | test3 -> R² = -0.4067, MSE = 1.2871e-01
# Y | test3 -> R² = -2.1174, MSE = 2.3861e-01
# Theta | val -> R² = -0.3583, MSE = 4.4568e-01
# X | val -> R² = -0.4017, MSE = 1.3322e-01
# Y | val -> R² = -1.9977, MSE = 2.2248e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.615116
# Epoch 50 Loss 1.348775
# Epoch 100 Loss 1.314249
# Epoch 150 Loss 1.301721
# Epoch 200 Loss 1.271747
# Epoch 250 Loss 1.256092
# Epoch 300 Loss 1.245574
# Epoch 350 Loss 1.241184
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.7207, MSE = 6.4022e-02
# X | train1 -> R² = -0.1140, MSE = 1.1940e-01
# Y | train1 -> R² = -1.0880, MSE = 1.7452e-01
# Theta | train2 -> R² = -0.1175, MSE = 2.5338e-01
# X | train2 -> R² = -0.1667, MSE = 9.8062e-02
# Y | train2 -> R² = -1.0520, MSE = 2.1971e-01
# Theta | test1 -> R² = 0.8386, MSE = 3.7221e-02
# X | test1 -> R² = -0.1947, MSE = 1.2437e-01
# Y | test1 -> R² = -1.2773, MSE = 1.8601e-01
# Theta | test2 -> R² = -0.0099, MSE = 2.3792e-01
# X | test2 -> R² = -0.1622, MSE = 9.5410e-02
# Y | test2 -> R² = -0.9722, MSE = 2.0821e-01
# Theta | test3 -> R² = 0.5997, MSE = 1.3193e-01
# X | test3 -> R² = -0.2341, MSE = 1.1291e-01
# Y | test3 -> R² = -2.3057, MSE = 2.5302e-01
# Theta | val -> R² = 0.7107, MSE = 9.4919e-02
# X | val -> R² = -0.2340, MSE = 1.1728e-01
# Y | val -> R² = -2.1366, MSE = 2.3278e-01
# Figura salva em: ./results/model_32_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.588951
# Epoch 50 Loss 1.336094
# Epoch 100 Loss 1.311998
# Epoch 150 Loss 1.301761
# Epoch 200 Loss 1.283878
# Epoch 250 Loss 1.279302
# Epoch 300 Loss 1.263554
# Early stopping at epoch 321
# Theta | train1 -> R² = 0.8160, MSE = 4.2185e-02
# X | train1 -> R² = -0.4531, MSE = 1.5574e-01
# Y | train1 -> R² = -1.6677, MSE = 2.2297e-01
# Theta | train2 -> R² = -0.1147, MSE = 2.5275e-01
# X | train2 -> R² = -0.3096, MSE = 1.1007e-01
# Y | train2 -> R² = -1.5827, MSE = 2.7653e-01
# Theta | test1 -> R² = 0.8715, MSE = 2.9635e-02
# X | test1 -> R² = -0.5456, MSE = 1.6089e-01
# Y | test1 -> R² = -1.9003, MSE = 2.3690e-01
# Theta | test2 -> R² = -0.0359, MSE = 2.4404e-01
# X | test2 -> R² = -0.3021, MSE = 1.0690e-01
# Y | test2 -> R² = -1.5174, MSE = 2.6578e-01
# Theta | test3 -> R² = 0.5714, MSE = 1.4125e-01
# X | test3 -> R² = -0.5398, MSE = 1.4088e-01
# Y | test3 -> R² = -2.6947, MSE = 2.8280e-01
# Theta | val -> R² = 0.7151, MSE = 9.3486e-02
# X | val -> R² = -0.6065, MSE = 1.5268e-01
# Y | val -> R² = -2.5726, MSE = 2.6514e-01
# Figura salva em: ./results/model_32_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.691222
# Epoch 50 Loss 1.349210
# Epoch 100 Loss 1.334679
# Epoch 150 Loss 1.302770
# Epoch 200 Loss 1.288309
# Epoch 250 Loss 1.274259
# Epoch 300 Loss 1.264822
# Epoch 350 Loss 1.254510
# Epoch 400 Loss 1.250365
# Early stopping at epoch 430
# Theta | train1 -> R² = 0.5582, MSE = 1.0126e-01
# X | train1 -> R² = 0.0226, MSE = 1.0476e-01
# Y | train1 -> R² = -0.6027, MSE = 1.3396e-01
# Theta | train2 -> R² = 0.5513, MSE = 1.0173e-01
# X | train2 -> R² = -0.0080, MSE = 8.4723e-02
# Y | train2 -> R² = -0.7191, MSE = 1.8407e-01
# Theta | test1 -> R² = 0.1220, MSE = 2.0253e-01
# X | test1 -> R² = 0.0590, MSE = 9.7954e-02
# Y | test1 -> R² = -0.8185, MSE = 1.4854e-01
# Theta | test2 -> R² = 0.6073, MSE = 9.2519e-02
# X | test2 -> R² = -0.0279, MSE = 8.4388e-02
# Y | test2 -> R² = -0.6295, MSE = 1.7204e-01
# Theta | test3 -> R² = -2.4554, MSE = 1.1388e+00
# X | test3 -> R² = -0.2687, MSE = 1.1608e-01
# Y | test3 -> R² = -0.0451, MSE = 7.9992e-02
# Theta | val -> R² = -1.6218, MSE = 8.6027e-01
# X | val -> R² = -0.2127, MSE = 1.1526e-01
# Y | val -> R² = -0.2592, MSE = 9.3452e-02
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.547647
# Epoch 50 Loss 1.344841
# Epoch 100 Loss 1.319703
# Epoch 150 Loss 1.299143
# Epoch 200 Loss 1.287182
# Epoch 250 Loss 1.279146
# Epoch 300 Loss 1.266405
# Epoch 350 Loss 1.253174
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.7902, MSE = 4.8080e-02
# X | train1 -> R² = -0.1622, MSE = 1.2457e-01
# Y | train1 -> R² = -0.9150, MSE = 1.6005e-01
# Theta | train2 -> R² = 0.3009, MSE = 1.5851e-01
# X | train2 -> R² = -0.1345, MSE = 9.5351e-02
# Y | train2 -> R² = -0.9027, MSE = 2.0373e-01
# Theta | test1 -> R² = 0.6507, MSE = 8.0580e-02
# X | test1 -> R² = -0.2266, MSE = 1.2768e-01
# Y | test1 -> R² = -1.1089, MSE = 1.7225e-01
# Theta | test2 -> R² = 0.2939, MSE = 1.6636e-01
# X | test2 -> R² = -0.1345, MSE = 9.3132e-02
# Y | test2 -> R² = -0.8487, MSE = 1.9518e-01
# Theta | test3 -> R² = 0.0660, MSE = 3.0784e-01
# X | test3 -> R² = -0.2743, MSE = 1.1659e-01
# Y | test3 -> R² = -1.6465, MSE = 2.0256e-01
# Theta | val -> R² = 0.3883, MSE = 2.0071e-01
# X | val -> R² = -0.3073, MSE = 1.2425e-01
# Y | val -> R² = -1.5874, MSE = 1.9203e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.540340
# Epoch 50 Loss 1.370623
# Epoch 100 Loss 1.323951
# Epoch 150 Loss 1.305527
# Epoch 200 Loss 1.286222
# Epoch 250 Loss 1.274511
# Epoch 300 Loss 1.275643
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.2158, MSE = 1.7975e-01
# X | train1 -> R² = -0.1714, MSE = 1.2555e-01
# Y | train1 -> R² = -1.3192, MSE = 1.9384e-01
# Theta | train2 -> R² = -1.1247, MSE = 4.8176e-01
# X | train2 -> R² = -0.3704, MSE = 1.1518e-01
# Y | train2 -> R² = -0.9944, MSE = 2.1354e-01
# Theta | test1 -> R² = 0.5361, MSE = 1.0700e-01
# X | test1 -> R² = -0.3146, MSE = 1.3684e-01
# Y | test1 -> R² = -1.5856, MSE = 2.1119e-01
# Theta | test2 -> R² = -0.9771, MSE = 4.6576e-01
# X | test2 -> R² = -0.3851, MSE = 1.1371e-01
# Y | test2 -> R² = -0.9751, MSE = 2.0853e-01
# Theta | test3 -> R² = 0.7951, MSE = 6.7531e-02
# X | test3 -> R² = -0.3800, MSE = 1.2626e-01
# Y | test3 -> R² = -2.3044, MSE = 2.5292e-01
# Theta | val -> R² = 0.5332, MSE = 1.5318e-01
# X | val -> R² = -0.4461, MSE = 1.3744e-01
# Y | val -> R² = -2.2758, MSE = 2.4311e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.543160
# Epoch 50 Loss 1.342973
# Epoch 100 Loss 1.309407
# Epoch 150 Loss 1.293518
# Epoch 200 Loss 1.276215
# Epoch 250 Loss 1.264979
# Epoch 300 Loss 1.250380
# Early stopping at epoch 344
# Theta | train1 -> R² = 0.6095, MSE = 8.9516e-02
# X | train1 -> R² = -0.2702, MSE = 1.3614e-01
# Y | train1 -> R² = -0.9183, MSE = 1.6033e-01
# Theta | train2 -> R² = -0.0841, MSE = 2.4582e-01
# X | train2 -> R² = -0.2932, MSE = 1.0870e-01
# Y | train2 -> R² = -0.8548, MSE = 1.9859e-01
# Theta | test1 -> R² = 0.7326, MSE = 6.1684e-02
# X | test1 -> R² = -0.3497, MSE = 1.4050e-01
# Y | test1 -> R² = -1.0971, MSE = 1.7129e-01
# Theta | test2 -> R² = 0.0209, MSE = 2.3066e-01
# X | test2 -> R² = -0.3018, MSE = 1.0687e-01
# Y | test2 -> R² = -0.8083, MSE = 1.9091e-01
# Theta | test3 -> R² = 0.2076, MSE = 2.6115e-01
# X | test3 -> R² = -0.5449, MSE = 1.4135e-01
# Y | test3 -> R² = -1.4087, MSE = 1.8436e-01
# Theta | val -> R² = 0.4020, MSE = 1.9623e-01
# X | val -> R² = -0.5075, MSE = 1.4328e-01
# Y | val -> R² = -1.3925, MSE = 1.7756e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.566059
# Epoch 50 Loss 1.342179
# Epoch 100 Loss 1.316651
# Epoch 150 Loss 1.302335
# Epoch 200 Loss 1.279577
# Epoch 250 Loss 1.274482
# Epoch 300 Loss 1.263404
# Early stopping at epoch 343
# Theta | train1 -> R² = 0.5766, MSE = 9.7041e-02
# X | train1 -> R² = -0.1375, MSE = 1.2192e-01
# Y | train1 -> R² = -0.8231, MSE = 1.5237e-01
# Theta | train2 -> R² = -0.5891, MSE = 3.6031e-01
# X | train2 -> R² = -0.1827, MSE = 9.9409e-02
# Y | train2 -> R² = -0.7658, MSE = 1.8907e-01
# Theta | test1 -> R² = 0.7448, MSE = 5.8854e-02
# X | test1 -> R² = -0.2042, MSE = 1.2535e-01
# Y | test1 -> R² = -1.0021, MSE = 1.6354e-01
# Theta | test2 -> R² = -0.4424, MSE = 3.3980e-01
# X | test2 -> R² = -0.1777, MSE = 9.6683e-02
# Y | test2 -> R² = -0.7066, MSE = 1.8017e-01
# Theta | test3 -> R² = 0.7082, MSE = 9.6183e-02
# X | test3 -> R² = -0.3279, MSE = 1.2150e-01
# Y | test3 -> R² = -1.6654, MSE = 2.0401e-01
# Theta | val -> R² = 0.6878, MSE = 1.0243e-01
# X | val -> R² = -0.3285, MSE = 1.2626e-01
# Y | val -> R² = -1.6138, MSE = 1.9399e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.581964
# Epoch 50 Loss 1.331631
# Epoch 100 Loss 1.320457
# Epoch 150 Loss 1.308129
# Epoch 200 Loss 1.275182
# Epoch 250 Loss 1.263220
# Epoch 300 Loss 1.258694
# Early stopping at epoch 323
# Theta | train1 -> R² = 0.6759, MSE = 7.4279e-02
# X | train1 -> R² = -0.0970, MSE = 1.1757e-01
# Y | train1 -> R² = -1.0998, MSE = 1.7551e-01
# Theta | train2 -> R² = 0.4733, MSE = 1.1944e-01
# X | train2 -> R² = -0.1572, MSE = 9.7263e-02
# Y | train2 -> R² = -1.1700, MSE = 2.3235e-01
# Theta | test1 -> R² = 0.5975, MSE = 9.2849e-02
# X | test1 -> R² = -0.1884, MSE = 1.2371e-01
# Y | test1 -> R² = -1.3536, MSE = 1.9224e-01
# Theta | test2 -> R² = 0.4909, MSE = 1.1994e-01
# X | test2 -> R² = -0.1609, MSE = 9.5306e-02
# Y | test2 -> R² = -1.1374, MSE = 2.2566e-01
# Theta | test3 -> R² = 0.3047, MSE = 2.2914e-01
# X | test3 -> R² = -0.2721, MSE = 1.1639e-01
# Y | test3 -> R² = -2.0246, MSE = 2.3150e-01
# Theta | val -> R² = 0.5223, MSE = 1.5674e-01
# X | val -> R² = -0.2789, MSE = 1.2155e-01
# Y | val -> R² = -1.8708, MSE = 2.1306e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.554465
# Epoch 50 Loss 1.355472
# Epoch 100 Loss 1.319234
# Epoch 150 Loss 1.308606
# Epoch 200 Loss 1.290272
# Epoch 250 Loss 1.267284
# Epoch 300 Loss 1.259101
# Early stopping at epoch 337
# Theta | train1 -> R² = 0.5896, MSE = 9.4073e-02
# X | train1 -> R² = -0.0669, MSE = 1.1435e-01
# Y | train1 -> R² = -0.8191, MSE = 1.5204e-01
# Theta | train2 -> R² = -0.4835, MSE = 3.3637e-01
# X | train2 -> R² = -0.0199, MSE = 8.5726e-02
# Y | train2 -> R² = -0.7455, MSE = 1.8690e-01
# Theta | test1 -> R² = 0.7735, MSE = 5.2235e-02
# X | test1 -> R² = -0.1108, MSE = 1.1564e-01
# Y | test1 -> R² = -1.0014, MSE = 1.6347e-01
# Theta | test2 -> R² = -0.3473, MSE = 3.1740e-01
# X | test2 -> R² = -0.0254, MSE = 8.4178e-02
# Y | test2 -> R² = -0.7052, MSE = 1.8002e-01
# Theta | test3 -> R² = 0.7941, MSE = 6.7861e-02
# X | test3 -> R² = -0.2124, MSE = 1.1092e-01
# Y | test3 -> R² = -1.3742, MSE = 1.8172e-01
# Theta | val -> R² = 0.7477, MSE = 8.2781e-02
# X | val -> R² = -0.2461, MSE = 1.1843e-01
# Y | val -> R² = -1.3818, MSE = 1.7677e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.554419
# Epoch 50 Loss 1.353602
# Epoch 100 Loss 1.312234
# Epoch 150 Loss 1.293412
# Epoch 200 Loss 1.273966
# Epoch 250 Loss 1.261216
# Epoch 300 Loss 1.246060
# Early stopping at epoch 319
# Theta | train1 -> R² = -0.4855, MSE = 3.4048e-01
# X | train1 -> R² = -0.0372, MSE = 1.1116e-01
# Y | train1 -> R² = -1.1034, MSE = 1.7581e-01
# Theta | train2 -> R² = 0.2010, MSE = 1.8116e-01
# X | train2 -> R² = -0.1262, MSE = 9.4657e-02
# Y | train2 -> R² = -0.9985, MSE = 2.1399e-01
# Theta | test1 -> R² = -1.1007, MSE = 4.8456e-01
# X | test1 -> R² = -0.1019, MSE = 1.1471e-01
# Y | test1 -> R² = -1.3120, MSE = 1.8885e-01
# Theta | test2 -> R² = 0.0739, MSE = 2.1817e-01
# X | test2 -> R² = -0.1325, MSE = 9.2967e-02
# Y | test2 -> R² = -0.9520, MSE = 2.0608e-01
# Theta | test3 -> R² = -2.5832, MSE = 1.1809e+00
# X | test3 -> R² = -0.1496, MSE = 1.0518e-01
# Y | test3 -> R² = -1.9219, MSE = 2.2365e-01
# Theta | val -> R² = -1.6149, MSE = 8.5800e-01
# X | val -> R² = -0.2018, MSE = 1.1422e-01
# Y | val -> R² = -1.8449, MSE = 2.1114e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.581189
# Epoch 50 Loss 1.326414
# Epoch 100 Loss 1.307383
# Epoch 150 Loss 1.298592
# Epoch 200 Loss 1.287309
# Epoch 250 Loss 1.289808
# Epoch 300 Loss 1.286115
# Early stopping at epoch 315
# Theta | train1 -> R² = 0.7058, MSE = 6.7439e-02
# X | train1 -> R² = 0.2791, MSE = 7.7264e-02
# Y | train1 -> R² = -0.7202, MSE = 1.4378e-01
# Theta | train2 -> R² = 0.0538, MSE = 2.1454e-01
# X | train2 -> R² = 0.0600, MSE = 7.9003e-02
# Y | train2 -> R² = -0.5575, MSE = 1.6677e-01
# Theta | test1 -> R² = 0.5476, MSE = 1.0434e-01
# X | test1 -> R² = 0.2394, MSE = 7.9177e-02
# Y | test1 -> R² = -0.8871, MSE = 1.5414e-01
# Theta | test2 -> R² = 0.0433, MSE = 2.2537e-01
# X | test2 -> R² = 0.0425, MSE = 7.8601e-02
# Y | test2 -> R² = -0.5176, MSE = 1.6022e-01
# Theta | test3 -> R² = -0.3107, MSE = 4.3197e-01
# X | test3 -> R² = 0.0324, MSE = 8.8527e-02
# Y | test3 -> R² = -1.0152, MSE = 1.5424e-01
# Theta | val -> R² = 0.0555, MSE = 3.0990e-01
# X | val -> R² = 0.1089, MSE = 8.4694e-02
# Y | val -> R² = -1.0704, MSE = 1.5366e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.565151
# Epoch 50 Loss 1.339162
# Epoch 100 Loss 1.343111
# Epoch 150 Loss 1.317957
# Epoch 200 Loss 1.275400
# Epoch 250 Loss 1.274240
# Epoch 300 Loss 1.244881
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.1249, MSE = 2.0059e-01
# X | train1 -> R² = -0.1222, MSE = 1.2028e-01
# Y | train1 -> R² = -1.0060, MSE = 1.6766e-01
# Theta | train2 -> R² = -0.5007, MSE = 3.4026e-01
# X | train2 -> R² = -0.3036, MSE = 1.0956e-01
# Y | train2 -> R² = -0.9901, MSE = 2.1308e-01
# Theta | test1 -> R² = 0.2320, MSE = 1.7715e-01
# X | test1 -> R² = -0.1886, MSE = 1.2373e-01
# Y | test1 -> R² = -1.2305, MSE = 1.8219e-01
# Theta | test2 -> R² = -0.2926, MSE = 3.0452e-01
# X | test2 -> R² = -0.3032, MSE = 1.0698e-01
# Y | test2 -> R² = -0.9489, MSE = 2.0576e-01
# Theta | test3 -> R² = 0.2362, MSE = 2.5174e-01
# X | test3 -> R² = -0.3625, MSE = 1.2466e-01
# Y | test3 -> R² = -1.7712, MSE = 2.1211e-01
# Theta | val -> R² = 0.1696, MSE = 2.7245e-01
# X | val -> R² = -0.4269, MSE = 1.3562e-01
# Y | val -> R² = -1.6797, MSE = 1.9888e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.562946
# Epoch 50 Loss 1.341333
# Epoch 100 Loss 1.321229
# Epoch 150 Loss 1.318063
# Epoch 200 Loss 1.337675
# Epoch 250 Loss 1.282551
# Epoch 300 Loss 1.278990
# Early stopping at epoch 324
# Theta | train1 -> R² = 0.7156, MSE = 6.5188e-02
# X | train1 -> R² = 0.0736, MSE = 9.9293e-02
# Y | train1 -> R² = -1.3066, MSE = 1.9279e-01
# Theta | train2 -> R² = -0.6847, MSE = 3.8199e-01
# X | train2 -> R² = -0.0763, MSE = 9.0464e-02
# Y | train2 -> R² = -1.2155, MSE = 2.3722e-01
# Theta | test1 -> R² = 0.6527, MSE = 8.0102e-02
# X | test1 -> R² = -0.0105, MSE = 1.0519e-01
# Y | test1 -> R² = -1.5150, MSE = 2.0543e-01
# Theta | test2 -> R² = -0.6661, MSE = 3.9252e-01
# X | test2 -> R² = -0.0820, MSE = 8.8829e-02
# Y | test2 -> R² = -1.1686, MSE = 2.2895e-01
# Theta | test3 -> R² = 0.0864, MSE = 3.0112e-01
# X | test3 -> R² = -0.0120, MSE = 9.2588e-02
# Y | test3 -> R² = -2.0041, MSE = 2.2993e-01
# Theta | val -> R² = 0.1992, MSE = 2.6275e-01
# X | val -> R² = -0.0138, MSE = 9.6349e-02
# Y | val -> R² = -1.9367, MSE = 2.1795e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.548819
# Epoch 50 Loss 1.354518
# Epoch 100 Loss 1.324033
# Epoch 150 Loss 1.330577
# Epoch 200 Loss 1.282597
# Epoch 250 Loss 1.269846
# Epoch 300 Loss 1.262026
# Early stopping at epoch 326
# Theta | train1 -> R² = 0.2649, MSE = 1.6849e-01
# X | train1 -> R² = 0.3208, MSE = 7.2793e-02
# Y | train1 -> R² = -0.9127, MSE = 1.5986e-01
# Theta | train2 -> R² = -1.2367, MSE = 5.0714e-01
# X | train2 -> R² = -0.0075, MSE = 8.4682e-02
# Y | train2 -> R² = -0.7262, MSE = 1.8483e-01
# Theta | test1 -> R² = 0.6672, MSE = 7.6768e-02
# X | test1 -> R² = 0.2593, MSE = 7.7109e-02
# Y | test1 -> R² = -1.1020, MSE = 1.7169e-01
# Theta | test2 -> R² = -0.9666, MSE = 4.6331e-01
# X | test2 -> R² = -0.0133, MSE = 8.3184e-02
# Y | test2 -> R² = -0.6798, MSE = 1.7735e-01
# Theta | test3 -> R² = 0.6496, MSE = 1.1549e-01
# X | test3 -> R² = 0.1791, MSE = 7.5110e-02
# Y | test3 -> R² = -1.6267, MSE = 2.0105e-01
# Theta | val -> R² = 0.5537, MSE = 1.4643e-01
# X | val -> R² = 0.2335, MSE = 7.2853e-02
# Y | val -> R² = -1.5750, MSE = 1.9110e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.620928
# Epoch 50 Loss 1.343257
# Epoch 100 Loss 1.322735
# Epoch 150 Loss 1.304162
# Epoch 200 Loss 1.284565
# Epoch 250 Loss 1.285825
# Epoch 300 Loss 1.257689
# Early stopping at epoch 323
# Theta | train1 -> R² = -0.5827, MSE = 3.6277e-01
# X | train1 -> R² = 0.1665, MSE = 8.9336e-02
# Y | train1 -> R² = -0.9807, MSE = 1.6555e-01
# Theta | train2 -> R² = -3.1359, MSE = 9.3779e-01
# X | train2 -> R² = -0.0109, MSE = 8.4969e-02
# Y | train2 -> R² = -0.8697, MSE = 2.0019e-01
# Theta | test1 -> R² = -0.0429, MSE = 2.4056e-01
# X | test1 -> R² = 0.1031, MSE = 9.3360e-02
# Y | test1 -> R² = -1.1552, MSE = 1.7604e-01
# Theta | test2 -> R² = -2.8296, MSE = 9.0220e-01
# X | test2 -> R² = -0.0211, MSE = 8.3824e-02
# Y | test2 -> R² = -0.8225, MSE = 1.9241e-01
# Theta | test3 -> R² = 0.1681, MSE = 2.7417e-01
# X | test3 -> R² = 0.0375, MSE = 8.8067e-02
# Y | test3 -> R² = -1.3771, MSE = 1.8194e-01
# Theta | val -> R² = 0.0429, MSE = 3.1405e-01
# X | val -> R² = 0.0511, MSE = 9.0186e-02
# Y | val -> R² = -1.4019, MSE = 1.7826e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.560569
# Epoch 50 Loss 1.344551
# Epoch 100 Loss 1.328007
# Epoch 150 Loss 1.296562
# Epoch 200 Loss 1.272283
# Epoch 250 Loss 1.265595
# Epoch 300 Loss 1.254447
# Early stopping at epoch 343
# Theta | train1 -> R² = 0.8081, MSE = 4.3996e-02
# X | train1 -> R² = -0.1296, MSE = 1.2107e-01
# Y | train1 -> R² = -0.9563, MSE = 1.6351e-01
# Theta | train2 -> R² = -0.0321, MSE = 2.3402e-01
# X | train2 -> R² = -0.2370, MSE = 1.0397e-01
# Y | train2 -> R² = -0.8565, MSE = 1.9878e-01
# Theta | test1 -> R² = 0.8301, MSE = 3.9189e-02
# X | test1 -> R² = -0.2290, MSE = 1.2794e-01
# Y | test1 -> R² = -1.1723, MSE = 1.7744e-01
# Theta | test2 -> R² = 0.0579, MSE = 2.2195e-01
# X | test2 -> R² = -0.2364, MSE = 1.0150e-01
# Y | test2 -> R² = -0.8131, MSE = 1.9141e-01
# Theta | test3 -> R² = 0.6455, MSE = 1.1684e-01
# X | test3 -> R² = -0.2826, MSE = 1.1735e-01
# Y | test3 -> R² = -1.6664, MSE = 2.0409e-01
# Theta | val -> R² = 0.7112, MSE = 9.4776e-02
# X | val -> R² = -0.2882, MSE = 1.2243e-01
# Y | val -> R² = -1.6173, MSE = 1.9425e-01
# Figura salva em: ./results/model_64_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.566743
# Epoch 50 Loss 1.336514
# Epoch 100 Loss 1.331092
# Epoch 150 Loss 1.302664
# Epoch 200 Loss 1.283501
# Epoch 250 Loss 1.275332
# Epoch 300 Loss 1.277340
# Early stopping at epoch 338
# Theta | train1 -> R² = 0.8433, MSE = 3.5922e-02
# X | train1 -> R² = -0.4616, MSE = 1.5665e-01
# Y | train1 -> R² = -0.9311, MSE = 1.6140e-01
# Theta | train2 -> R² = 0.1319, MSE = 1.9683e-01
# X | train2 -> R² = -0.4710, MSE = 1.2364e-01
# Y | train2 -> R² = -0.9547, MSE = 2.0929e-01
# Theta | test1 -> R² = 0.7941, MSE = 4.7492e-02
# X | test1 -> R² = -0.5864, MSE = 1.6514e-01
# Y | test1 -> R² = -1.1425, MSE = 1.7500e-01
# Theta | test2 -> R² = 0.1991, MSE = 1.8868e-01
# X | test2 -> R² = -0.4715, MSE = 1.2080e-01
# Y | test2 -> R² = -0.9070, MSE = 2.0134e-01
# Theta | test3 -> R² = 0.4977, MSE = 1.6554e-01
# X | test3 -> R² = -0.7638, MSE = 1.6137e-01
# Y | test3 -> R² = -1.7659, MSE = 2.1170e-01
# Theta | val -> R² = 0.6203, MSE = 1.2457e-01
# X | val -> R² = -0.7324, MSE = 1.6465e-01
# Y | val -> R² = -1.6563, MSE = 1.9714e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.634273
# Epoch 50 Loss 1.343138
# Epoch 100 Loss 1.361293
# Epoch 150 Loss 1.315544
# Epoch 200 Loss 1.303686
# Epoch 250 Loss 1.289091
# Epoch 300 Loss 1.274640
# Early stopping at epoch 305
# Theta | train1 -> R² = 0.4363, MSE = 1.2920e-01
# X | train1 -> R² = -0.0069, MSE = 1.0791e-01
# Y | train1 -> R² = -0.7986, MSE = 1.5033e-01
# Theta | train2 -> R² = -0.8251, MSE = 4.1383e-01
# X | train2 -> R² = -0.5249, MSE = 1.2817e-01
# Y | train2 -> R² = -0.7395, MSE = 1.8625e-01
# Theta | test1 -> R² = 0.1713, MSE = 1.9115e-01
# X | test1 -> R² = -0.1423, MSE = 1.1891e-01
# Y | test1 -> R² = -0.9490, MSE = 1.5920e-01
# Theta | test2 -> R² = -0.8339, MSE = 4.3204e-01
# X | test2 -> R² = -0.5477, MSE = 1.2706e-01
# Y | test2 -> R² = -0.7057, MSE = 1.8008e-01
# Theta | test3 -> R² = -1.3701, MSE = 7.8115e-01
# X | test3 -> R² = -0.3313, MSE = 1.2181e-01
# Y | test3 -> R² = -1.2204, MSE = 1.6995e-01
# Theta | val -> R² = -0.9005, MSE = 6.2358e-01
# X | val -> R² = -0.3086, MSE = 1.2437e-01
# Y | val -> R² = -1.2371, MSE = 1.6603e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.542429
# Epoch 50 Loss 1.333736
# Epoch 100 Loss 1.319300
# Epoch 150 Loss 1.305927
# Epoch 200 Loss 1.293242
# Epoch 250 Loss 1.274426
# Epoch 300 Loss 1.259865
# Early stopping at epoch 321
# Theta | train1 -> R² = 0.6895, MSE = 7.1169e-02
# X | train1 -> R² = -0.1656, MSE = 1.2492e-01
# Y | train1 -> R² = -1.0299, MSE = 1.6966e-01
# Theta | train2 -> R² = -0.4907, MSE = 3.3801e-01
# X | train2 -> R² = -0.1480, MSE = 9.6493e-02
# Y | train2 -> R² = -0.9526, MSE = 2.0907e-01
# Theta | test1 -> R² = 0.8365, MSE = 3.7723e-02
# X | test1 -> R² = -0.2395, MSE = 1.2903e-01
# Y | test1 -> R² = -1.2042, MSE = 1.8004e-01
# Theta | test2 -> R² = -0.3552, MSE = 3.1926e-01
# X | test2 -> R² = -0.1504, MSE = 9.4441e-02
# Y | test2 -> R² = -0.9010, MSE = 2.0070e-01
# Theta | test3 -> R² = 0.7193, MSE = 9.2521e-02
# X | test3 -> R² = -0.3273, MSE = 1.2144e-01
# Y | test3 -> R² = -1.9289, MSE = 2.2417e-01
# Theta | val -> R² = 0.7103, MSE = 9.5048e-02
# X | val -> R² = -0.3601, MSE = 1.2926e-01
# Y | val -> R² = -1.8195, MSE = 2.0925e-01
# Figura salva em: ./results/model_64_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.603118
# Epoch 50 Loss 1.340627
# Epoch 100 Loss 1.361291
# Epoch 150 Loss 1.314810
# Epoch 200 Loss 1.287227
# Epoch 250 Loss 1.277568
# Epoch 300 Loss 1.281449
# Early stopping at epoch 308
# Theta | train1 -> R² = 0.6654, MSE = 7.6686e-02
# X | train1 -> R² = -0.8124, MSE = 1.9425e-01
# Y | train1 -> R² = -1.4088, MSE = 2.0133e-01
# Theta | train2 -> R² = -0.1496, MSE = 2.6066e-01
# X | train2 -> R² = -1.6036, MSE = 2.1883e-01
# Y | train2 -> R² = -1.3870, MSE = 2.5558e-01
# Theta | test1 -> R² = 0.7147, MSE = 6.5806e-02
# X | test1 -> R² = -1.0536, MSE = 2.1377e-01
# Y | test1 -> R² = -1.6237, MSE = 2.1431e-01
# Theta | test2 -> R² = -0.0574, MSE = 2.4911e-01
# X | test2 -> R² = -1.6426, MSE = 2.1694e-01
# Y | test2 -> R² = -1.3395, MSE = 2.4700e-01
# Theta | test3 -> R² = 0.6954, MSE = 1.0040e-01
# X | test3 -> R² = -2.1676, MSE = 2.8981e-01
# Y | test3 -> R² = -2.4941, MSE = 2.6744e-01
# Theta | val -> R² = 0.6814, MSE = 1.0454e-01
# X | val -> R² = -1.8230, MSE = 2.6831e-01
# Y | val -> R² = -2.2994, MSE = 2.4487e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.573452
# Epoch 50 Loss 1.332784
# Epoch 100 Loss 1.318699
# Epoch 150 Loss 1.327315
# Epoch 200 Loss 1.330694
# Epoch 250 Loss 1.276865
# Epoch 300 Loss 1.300154
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.5441, MSE = 1.0449e-01
# X | train1 -> R² = -1.5286, MSE = 2.7101e-01
# Y | train1 -> R² = -1.0768, MSE = 1.7358e-01
# Theta | train2 -> R² = -0.0952, MSE = 2.4833e-01
# X | train2 -> R² = -2.0096, MSE = 2.5296e-01
# Y | train2 -> R² = -1.2626, MSE = 2.4227e-01
# Theta | test1 -> R² = 0.1170, MSE = 2.0367e-01
# X | test1 -> R² = -1.7296, MSE = 2.8414e-01
# Y | test1 -> R² = -1.2685, MSE = 1.8529e-01
# Theta | test2 -> R² = -0.1221, MSE = 2.6435e-01
# X | test2 -> R² = -2.0596, MSE = 2.5118e-01
# Y | test2 -> R² = -1.2207, MSE = 2.3445e-01
# Theta | test3 -> R² = -1.4792, MSE = 8.1711e-01
# X | test3 -> R² = -3.2956, MSE = 3.9302e-01
# Y | test3 -> R² = -1.6430, MSE = 2.0229e-01
# Theta | val -> R² = -0.8114, MSE = 5.9436e-01
# X | val -> R² = -2.9115, MSE = 3.7175e-01
# Y | val -> R² = -1.5477, MSE = 1.8908e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.567149
# Epoch 50 Loss 1.334045
# Epoch 100 Loss 1.358900
# Epoch 150 Loss 1.340588
# Epoch 200 Loss 1.299250
# Epoch 250 Loss 1.296677
# Epoch 300 Loss 1.276475
# Early stopping at epoch 318
# Theta | train1 -> R² = -1.3518, MSE = 5.3904e-01
# X | train1 -> R² = -0.3848, MSE = 1.4842e-01
# Y | train1 -> R² = -0.5537, MSE = 1.2986e-01
# Theta | train2 -> R² = -3.9585, MSE = 1.1243e+00
# X | train2 -> R² = -0.9130, MSE = 1.6079e-01
# Y | train2 -> R² = -0.5569, MSE = 1.6670e-01
# Theta | test1 -> R² = -0.5442, MSE = 3.5618e-01
# X | test1 -> R² = -0.5631, MSE = 1.6272e-01
# Y | test1 -> R² = -0.7219, MSE = 1.4065e-01
# Theta | test2 -> R² = -3.4728, MSE = 1.0537e+00
# X | test2 -> R² = -0.9289, MSE = 1.5835e-01
# Y | test2 -> R² = -0.5230, MSE = 1.6080e-01
# Theta | test3 -> R² = -0.5821, MSE = 5.2143e-01
# X | test3 -> R² = -0.9095, MSE = 1.7471e-01
# Y | test3 -> R² = -0.8743, MSE = 1.4346e-01
# Theta | val -> R² = -0.6349, MSE = 5.3644e-01
# X | val -> R² = -0.7721, MSE = 1.6843e-01
# Y | val -> R² = -0.8632, MSE = 1.3828e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.582341
# Epoch 50 Loss 1.331400
# Epoch 100 Loss 1.337188
# Epoch 150 Loss 1.327152
# Epoch 200 Loss 1.297530
# Epoch 250 Loss 1.291914
# Epoch 300 Loss 1.298358
# Early stopping at epoch 316
# Theta | train1 -> R² = -1.9222, MSE = 6.6979e-01
# X | train1 -> R² = -1.2391, MSE = 2.3998e-01
# Y | train1 -> R² = -0.8898, MSE = 1.5795e-01
# Theta | train2 -> R² = -0.5432, MSE = 3.4990e-01
# X | train2 -> R² = -1.5809, MSE = 2.1693e-01
# Y | train2 -> R² = -0.7223, MSE = 1.8441e-01
# Theta | test1 -> R² = -2.9178, MSE = 9.0368e-01
# X | test1 -> R² = -1.4098, MSE = 2.5085e-01
# Y | test1 -> R² = -1.0331, MSE = 1.6606e-01
# Theta | test2 -> R² = -0.7881, MSE = 4.2124e-01
# X | test2 -> R² = -1.6067, MSE = 2.1399e-01
# Y | test2 -> R² = -0.6697, MSE = 1.7628e-01
# Theta | test3 -> R² = -4.0293, MSE = 1.6576e+00
# X | test3 -> R² = -2.6042, MSE = 3.2976e-01
# Y | test3 -> R² = -1.6296, MSE = 2.0127e-01
# Theta | val -> R² = -2.9311, MSE = 1.2899e+00
# X | val -> R² = -2.2530, MSE = 3.0917e-01
# Y | val -> R² = -1.5857, MSE = 1.9190e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.551987
# Epoch 50 Loss 1.337057
# Epoch 100 Loss 1.326762
# Epoch 150 Loss 1.331248
# Epoch 200 Loss 1.319700
# Epoch 250 Loss 1.274435
# Epoch 300 Loss 1.323587
# Early stopping at epoch 322
# Theta | train1 -> R² = 0.4406, MSE = 1.2823e-01
# X | train1 -> R² = -0.0597, MSE = 1.1358e-01
# Y | train1 -> R² = -1.7895, MSE = 2.3315e-01
# Theta | train2 -> R² = 0.4847, MSE = 1.1683e-01
# X | train2 -> R² = -0.2424, MSE = 1.0443e-01
# Y | train2 -> R² = -1.6006, MSE = 2.7845e-01
# Theta | test1 -> R² = 0.1087, MSE = 2.0560e-01
# X | test1 -> R² = -0.1820, MSE = 1.2305e-01
# Y | test1 -> R² = -2.1003, MSE = 2.5324e-01
# Theta | test2 -> R² = 0.4199, MSE = 1.3667e-01
# X | test2 -> R² = -0.2435, MSE = 1.0208e-01
# Y | test2 -> R² = -1.5596, MSE = 2.7023e-01
# Theta | test3 -> R² = -0.9894, MSE = 6.5566e-01
# X | test3 -> R² = -0.1432, MSE = 1.0459e-01
# Y | test3 -> R² = -2.9892, MSE = 3.0533e-01
# Theta | val -> R² = -0.3947, MSE = 4.5762e-01
# X | val -> R² = -0.1572, MSE = 1.0998e-01
# Y | val -> R² = -2.8578, MSE = 2.8631e-01
# Modelo 4 treinado e salvo no Excel
# ...
# X | val -> R² = -0.0592, MSE = 1.0067e-01
# Y | val -> R² = -1.8610, MSE = 2.1233e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.584031
# Epoch 50 Loss 1.472057
# Epoch 100 Loss 1.410871
# Epoch 150 Loss 1.384968
# Epoch 200 Loss 1.365718
# Epoch 250 Loss 1.405719
# Epoch 300 Loss 1.359420
# Epoch 350 Loss 1.366031
# Epoch 400 Loss 1.386018
# Epoch 450 Loss 1.359500
# Early stopping at epoch 470
# Theta | train1 -> R² = -0.6646, MSE = 3.8155e-01
# X | train1 -> R² = -0.1666, MSE = 1.2504e-01
# Y | train1 -> R² = -1.0793, MSE = 1.7378e-01
# Theta | train2 -> R² = -2.3607, MSE = 7.6200e-01
# X | train2 -> R² = -0.1070, MSE = 9.3044e-02
# Y | train2 -> R² = -1.1763, MSE = 2.3302e-01
# Theta | test1 -> R² = -0.6717, MSE = 3.8560e-01
# X | test1 -> R² = -0.2756, MSE = 1.3278e-01
# Y | test1 -> R² = -1.1796, MSE = 1.7803e-01
# Theta | test2 -> R² = -2.0981, MSE = 7.2986e-01
# X | test2 -> R² = -0.1355, MSE = 9.3215e-02
# Y | test2 -> R² = -1.1097, MSE = 2.2274e-01
# Theta | test3 -> R² = -3.1547, MSE = 1.3693e+00
# X | test3 -> R² = -2.7207, MSE = 3.4041e-01
# Y | test3 -> R² = -3.2216, MSE = 3.2312e-01
# Theta | val -> R² = -0.6880, MSE = 5.5387e-01
# X | val -> R² = -2.2785, MSE = 3.1160e-01
# Y | val -> R² = -2.7686, MSE = 2.7969e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.528634
# Epoch 50 Loss 1.471646
# Epoch 100 Loss 1.381771
# Epoch 150 Loss 1.372354
# Epoch 200 Loss 1.366504
# Epoch 250 Loss 1.366606
# Epoch 300 Loss 1.367399
# Epoch 350 Loss 1.364456
# Epoch 400 Loss 1.444184
# Early stopping at epoch 416
# Theta | train1 -> R² = 0.6827, MSE = 7.2723e-02
# X | train1 -> R² = -0.2199, MSE = 1.3075e-01
# Y | train1 -> R² = -0.5254, MSE = 1.2749e-01
# Theta | train2 -> R² = -0.2045, MSE = 2.7311e-01
# X | train2 -> R² = -0.0464, MSE = 8.7953e-02
# Y | train2 -> R² = -0.7630, MSE = 1.8876e-01
# Theta | test1 -> R² = 0.7380, MSE = 6.0429e-02
# X | test1 -> R² = -0.3673, MSE = 1.4233e-01
# Y | test1 -> R² = -0.8496, MSE = 1.5108e-01
# Theta | test2 -> R² = -0.1996, MSE = 2.8260e-01
# X | test2 -> R² = -0.0549, MSE = 8.6605e-02
# Y | test2 -> R² = -0.6996, MSE = 1.7943e-01
# Theta | test3 -> R² = -1.5127, MSE = 8.2814e-01
# X | test3 -> R² = -3.3464, MSE = 3.9767e-01
# Y | test3 -> R² = -4.7991, MSE = 4.4386e-01
# Theta | val -> R² = -0.2887, MSE = 4.2283e-01
# X | val -> R² = -2.8301, MSE = 3.6402e-01
# Y | val -> R² = -4.3370, MSE = 3.9609e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.577922
# Epoch 50 Loss 1.366465
# Epoch 100 Loss 1.344092
# Epoch 150 Loss 1.334987
# Epoch 200 Loss 1.323275
# Epoch 250 Loss 1.395501
# Epoch 300 Loss 1.291396
# Epoch 350 Loss 1.303775
# Epoch 400 Loss 1.271055
# Epoch 450 Loss 1.305685
# Epoch 500 Loss 1.290592
# Epoch 550 Loss 1.319240
# Epoch 600 Loss 1.289093
# Early stopping at epoch 607
# Theta | train1 -> R² = 0.3319, MSE = 1.5313e-01
# X | train1 -> R² = -0.3419, MSE = 1.4383e-01
# Y | train1 -> R² = -0.7688, MSE = 1.4784e-01
# Theta | train2 -> R² = -0.4505, MSE = 3.2888e-01
# X | train2 -> R² = -0.6548, MSE = 1.3908e-01
# Y | train2 -> R² = -0.9992, MSE = 2.1406e-01
# Theta | test1 -> R² = -0.3573, MSE = 3.1307e-01
# X | test1 -> R² = -0.8333, MSE = 1.9085e-01
# Y | test1 -> R² = -0.7379, MSE = 1.4195e-01
# Theta | test2 -> R² = 0.0664, MSE = 2.1994e-01
# X | test2 -> R² = -0.5572, MSE = 1.2783e-01
# Y | test2 -> R² = -1.2201, MSE = 2.3439e-01
# Theta | test3 -> R² = -6.2836, MSE = 2.4005e+00
# X | test3 -> R² = -0.8718, MSE = 1.7125e-01
# Y | test3 -> R² = -3.3119, MSE = 3.3003e-01
# Theta | val -> R² = -2.1578, MSE = 1.0361e+00
# X | val -> R² = -0.4394, MSE = 1.3681e-01
# Y | val -> R² = -3.4367, MSE = 3.2928e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.604234
# Epoch 50 Loss 1.416251
# Epoch 100 Loss 1.366002
# Epoch 150 Loss 1.363363
# Epoch 200 Loss 1.355750
# Epoch 250 Loss 1.418531
# Epoch 300 Loss 1.350518
# Epoch 350 Loss 1.353406
# Epoch 400 Loss 1.369345
# Epoch 450 Loss 1.382020
# Epoch 500 Loss 1.344103
# Epoch 550 Loss 1.346656
# Epoch 600 Loss 1.379468
# Epoch 650 Loss 1.359615
# Epoch 700 Loss 1.349220
# Early stopping at epoch 722
# Theta | train1 -> R² = -2.7195, MSE = 8.5255e-01
# X | train1 -> R² = 0.0513, MSE = 1.0168e-01
# Y | train1 -> R² = -0.7740, MSE = 1.4827e-01
# Theta | train2 -> R² = -3.4494, MSE = 1.0089e+00
# X | train2 -> R² = -0.4634, MSE = 1.2300e-01
# Y | train2 -> R² = -0.7382, MSE = 1.8611e-01
# Theta | test1 -> R² = -2.4246, MSE = 7.8992e-01
# X | test1 -> R² = 0.0614, MSE = 9.7702e-02
# Y | test1 -> R² = -1.1497, MSE = 1.7559e-01
# Theta | test2 -> R² = -2.8468, MSE = 9.0624e-01
# X | test2 -> R² = -0.4808, MSE = 1.2156e-01
# Y | test2 -> R² = -0.7344, MSE = 1.8311e-01
# Theta | test3 -> R² = 0.7301, MSE = 8.8955e-02
# X | test3 -> R² = -2.2371, MSE = 2.9617e-01
# Y | test3 -> R² = -6.3787, MSE = 5.6476e-01
# Theta | val -> R² = 0.3279, MSE = 2.2053e-01
# X | val -> R² = -1.9194, MSE = 2.7746e-01
# Y | val -> R² = -5.3502, MSE = 4.7128e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.724704
# Epoch 50 Loss 1.386899
# Epoch 100 Loss 1.386125
# Epoch 150 Loss 1.379295
# Epoch 200 Loss 1.395038
# Epoch 250 Loss 1.363838
# Epoch 300 Loss 1.373191
# Early stopping at epoch 337
# Theta | train1 -> R² = 0.3411, MSE = 1.5103e-01
# X | train1 -> R² = -0.5595, MSE = 1.6715e-01
# Y | train1 -> R² = -1.3165, MSE = 1.9362e-01
# Theta | train2 -> R² = -0.3053, MSE = 2.9597e-01
# X | train2 -> R² = -0.0849, MSE = 9.1184e-02
# Y | train2 -> R² = -1.0317, MSE = 2.1754e-01
# Theta | test1 -> R² = -0.0070, MSE = 2.3227e-01
# X | test1 -> R² = -0.7853, MSE = 1.8585e-01
# Y | test1 -> R² = -1.7048, MSE = 2.2093e-01
# Theta | test2 -> R² = -0.3104, MSE = 3.0871e-01
# X | test2 -> R² = -0.1377, MSE = 9.3401e-02
# Y | test2 -> R² = -1.0557, MSE = 2.1703e-01
# Theta | test3 -> R² = -3.0306, MSE = 1.3284e+00
# X | test3 -> R² = -4.7719, MSE = 5.2809e-01
# Y | test3 -> R² = -7.7546, MSE = 6.7008e-01
# Theta | val -> R² = -0.7829, MSE = 5.8498e-01
# X | val -> R² = -4.4174, MSE = 5.1488e-01
# Y | val -> R² = -7.3727, MSE = 6.2138e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.639327
# Epoch 50 Loss 1.438638
# Epoch 100 Loss 1.461937
# Epoch 150 Loss 1.420092
# Epoch 200 Loss 1.419203
# Epoch 250 Loss 1.395802
# Epoch 300 Loss 1.402066
# Early stopping at epoch 307
# Theta | train1 -> R² = 0.1715, MSE = 1.8990e-01
# X | train1 -> R² = -0.8703, MSE = 2.0046e-01
# Y | train1 -> R² = -1.6608, MSE = 2.2239e-01
# Theta | train2 -> R² = -4.4850, MSE = 1.2437e+00
# X | train2 -> R² = -1.0485, MSE = 1.7217e-01
# Y | train2 -> R² = -1.7786, MSE = 2.9751e-01
# Theta | test1 -> R² = 0.1087, MSE = 2.0559e-01
# X | test1 -> R² = -1.4414, MSE = 2.5414e-01
# Y | test1 -> R² = -1.9698, MSE = 2.4258e-01
# Theta | test2 -> R² = -4.1511, MSE = 1.2135e+00
# X | test2 -> R² = -1.2154, MSE = 1.8187e-01
# Y | test2 -> R² = -1.7740, MSE = 2.9287e-01
# Theta | test3 -> R² = -0.4890, MSE = 4.9076e-01
# X | test3 -> R² = -31.2324, MSE = 2.9490e+00
# Y | test3 -> R² = -13.2212, MSE = 1.0885e+00
# Theta | val -> R² = -1.2794, MSE = 7.4792e-01
# X | val -> R² = -23.8089, MSE = 2.3579e+00
# Y | val -> R² = -9.6712, MSE = 7.9197e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.528728
# Epoch 50 Loss 1.406780
# Epoch 100 Loss 1.411328
# Epoch 150 Loss 1.402455
# Epoch 200 Loss 1.367569
# Epoch 250 Loss 1.361394
# Epoch 300 Loss 1.387744
# Epoch 350 Loss 1.366848
# Epoch 400 Loss 1.372198
# Early stopping at epoch 409
# Theta | train1 -> R² = 0.3199, MSE = 1.5588e-01
# X | train1 -> R² = 0.0421, MSE = 1.0267e-01
# Y | train1 -> R² = -1.5922, MSE = 2.1665e-01
# Theta | train2 -> R² = 0.0106, MSE = 2.2434e-01
# X | train2 -> R² = 0.0418, MSE = 8.0536e-02
# Y | train2 -> R² = -1.4628, MSE = 2.6369e-01
# Theta | test1 -> R² = 0.6044, MSE = 9.1261e-02
# X | test1 -> R² = -0.0922, MSE = 1.1370e-01
# Y | test1 -> R² = -2.0153, MSE = 2.4629e-01
# Theta | test2 -> R² = 0.0209, MSE = 2.3065e-01
# X | test2 -> R² = 0.0036, MSE = 8.1800e-02
# Y | test2 -> R² = -1.5284, MSE = 2.6694e-01
# Theta | test3 -> R² = -37.6210, MSE = 1.2729e+01
# X | test3 -> R² = -3.5044, MSE = 4.1212e-01
# Y | test3 -> R² = -3.5003, MSE = 3.4445e-01
# Theta | val -> R² = -27.2016, MSE = 9.2534e+00
# X | val -> R² = -3.2152, MSE = 4.0062e-01
# Y | val -> R² = -3.4392, MSE = 3.2946e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.586233
# Epoch 50 Loss 1.472745
# Epoch 100 Loss 1.471998
# Epoch 150 Loss 1.471990
# Epoch 200 Loss 1.471975
# Epoch 250 Loss 1.471899
# Epoch 300 Loss 1.474101
# Epoch 350 Loss 1.472015
# Epoch 400 Loss 1.471999
# Epoch 450 Loss 1.471966
# Epoch 500 Loss 1.470943
# Epoch 550 Loss 1.470813
# Epoch 600 Loss 1.472756
# Epoch 650 Loss 1.472017
# Epoch 700 Loss 1.472005
# Epoch 750 Loss 1.472006
# Epoch 800 Loss 1.472005
# Early stopping at epoch 805
# Theta | train1 -> R² = -0.0097, MSE = 2.3142e-01
# X | train1 -> R² = -0.5023, MSE = 1.6101e-01
# Y | train1 -> R² = -1.1041, MSE = 1.7586e-01
# Theta | train2 -> R² = -1.6395, MSE = 5.9847e-01
# X | train2 -> R² = -0.0835, MSE = 9.1071e-02
# Y | train2 -> R² = -1.4740, MSE = 2.6490e-01
# Theta | test1 -> R² = 0.0467, MSE = 2.1988e-01
# X | test1 -> R² = -0.7203, MSE = 1.7908e-01
# Y | test1 -> R² = -1.3408, MSE = 1.9120e-01
# Theta | test2 -> R² = -1.6352, MSE = 6.2080e-01
# X | test2 -> R² = -0.1236, MSE = 9.2241e-02
# Y | test2 -> R² = -1.4609, MSE = 2.5981e-01
# Theta | test3 -> R² = -0.4506, MSE = 4.7809e-01
# X | test3 -> R² = -4.5105, MSE = 5.0417e-01
# Y | test3 -> R² = -3.8097, MSE = 3.6814e-01
# Theta | val -> R² = -0.6925, MSE = 5.5533e-01
# X | val -> R² = -3.8246, MSE = 4.5854e-01
# Y | val -> R² = -3.2745, MSE = 3.1724e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.589545
# Epoch 50 Loss 1.438084
# Epoch 100 Loss 1.381541
# Epoch 150 Loss 1.389799
# Epoch 200 Loss 1.380296
# Epoch 250 Loss 1.385471
# Epoch 300 Loss 1.367594
# Epoch 350 Loss 1.373888
# Epoch 400 Loss 1.369647
# Epoch 450 Loss 1.380613
# Epoch 500 Loss 1.385072
# Epoch 550 Loss 1.379797
# Epoch 600 Loss 1.364709
# Epoch 650 Loss 1.381720
# Epoch 700 Loss 1.348897
# Epoch 750 Loss 1.464607
# Epoch 800 Loss 1.573843
# Early stopping at epoch 823
# Theta | train1 -> R² = 0.6823, MSE = 7.2823e-02
# X | train1 -> R² = 0.2448, MSE = 8.0947e-02
# Y | train1 -> R² = -0.7780, MSE = 1.4860e-01
# Theta | train2 -> R² = 0.3711, MSE = 1.4260e-01
# X | train2 -> R² = -0.1559, MSE = 9.7153e-02
# Y | train2 -> R² = -0.8313, MSE = 1.9608e-01
# Theta | test1 -> R² = 0.7843, MSE = 4.9754e-02
# X | test1 -> R² = 0.0808, MSE = 9.5684e-02
# Y | test1 -> R² = -0.9219, MSE = 1.5699e-01
# Theta | test2 -> R² = 0.4229, MSE = 1.3596e-01
# X | test2 -> R² = -0.1377, MSE = 9.3394e-02
# Y | test2 -> R² = -0.7951, MSE = 1.8952e-01
# Theta | test3 -> R² = -0.1045, MSE = 3.6402e-01
# X | test3 -> R² = -0.8398, MSE = 1.6833e-01
# Y | test3 -> R² = -5.4460, MSE = 4.9338e-01
# Theta | val -> R² = 0.4605, MSE = 1.7703e-01
# X | val -> R² = -0.9835, MSE = 1.8851e-01
# Y | val -> R² = -4.6687, MSE = 4.2071e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.549670
# Epoch 50 Loss 1.406694
# Epoch 100 Loss 1.372490
# Epoch 150 Loss 1.396014
# Epoch 200 Loss 1.386908
# Epoch 250 Loss 1.365469
# Epoch 300 Loss 1.380364
# Early stopping at epoch 317
# Theta | train1 -> R² = -1.5230, MSE = 5.7829e-01
# X | train1 -> R² = -2.1415, MSE = 3.3670e-01
# Y | train1 -> R² = -2.3308, MSE = 2.7839e-01
# Theta | train2 -> R² = -1.0392, MSE = 4.6238e-01
# X | train2 -> R² = -2.1566, MSE = 2.6531e-01
# Y | train2 -> R² = -2.0660, MSE = 3.2828e-01
# Theta | test1 -> R² = -1.2595, MSE = 5.2117e-01
# X | test1 -> R² = -2.6946, MSE = 3.8460e-01
# Y | test1 -> R² = -2.8604, MSE = 3.1532e-01
# Theta | test2 -> R² = -0.8839, MSE = 4.4381e-01
# X | test2 -> R² = -2.3028, MSE = 2.7114e-01
# Y | test2 -> R² = -2.0876, MSE = 3.2597e-01
# Theta | test3 -> R² = -0.1511, MSE = 3.7937e-01
# X | test3 -> R² = -10.0037, MSE = 1.0068e+00
# Y | test3 -> R² = -5.3714, MSE = 4.8766e-01
# Theta | val -> R² = -0.0160, MSE = 3.3338e-01
# X | val -> R² = -9.2410, MSE = 9.7333e-01
# Y | val -> R² = -5.9854, MSE = 5.1843e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.637190
# Epoch 50 Loss 1.471991
# Epoch 100 Loss 1.472623
# Epoch 150 Loss 1.470365
# Epoch 200 Loss 1.473314
# Epoch 250 Loss 1.472011
# Epoch 300 Loss 1.472005
# Early stopping at epoch 303
# Theta | train1 -> R² = -0.4741, MSE = 3.3788e-01
# X | train1 -> R² = -0.7064, MSE = 1.8289e-01
# Y | train1 -> R² = -1.5838, MSE = 2.1596e-01
# Theta | train2 -> R² = -1.0147, MSE = 4.5682e-01
# X | train2 -> R² = -0.8862, MSE = 1.5853e-01
# Y | train2 -> R² = -1.1925, MSE = 2.3475e-01
# Theta | test1 -> R² = -0.2786, MSE = 2.9492e-01
# X | test1 -> R² = -1.2718, MSE = 2.3649e-01
# Y | test1 -> R² = -2.0042, MSE = 2.4539e-01
# Theta | test2 -> R² = -1.0381, MSE = 4.8013e-01
# X | test2 -> R² = -1.0443, MSE = 1.6782e-01
# Y | test2 -> R² = -1.2434, MSE = 2.3685e-01
# Theta | test3 -> R² = -1.5545, MSE = 8.4190e-01
# X | test3 -> R² = -0.7021, MSE = 1.5573e-01
# Y | test3 -> R² = -0.9949, MSE = 1.5269e-01
# Theta | val -> R² = -1.2547, MSE = 7.3980e-01
# X | val -> R² = -2.1897, MSE = 3.0316e-01
# Y | val -> R² = -2.3021, MSE = 2.4507e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.528976
# Epoch 50 Loss 1.385225
# Epoch 100 Loss 1.371949
# Epoch 150 Loss 1.394448
# Epoch 200 Loss 1.381051
# Epoch 250 Loss 1.372366
# Epoch 300 Loss 1.352659
# Epoch 350 Loss 1.367601
# Epoch 400 Loss 1.367530
# Epoch 450 Loss 1.380351
# Epoch 500 Loss 1.387821
# Epoch 550 Loss 1.369866
# Epoch 600 Loss 1.352308
# Epoch 650 Loss 1.343096
# Epoch 700 Loss 1.366069
# Early stopping at epoch 747
# Theta | train1 -> R² = -1.4395, MSE = 5.5915e-01
# X | train1 -> R² = -0.0474, MSE = 1.1226e-01
# Y | train1 -> R² = -1.4048, MSE = 2.0099e-01
# Theta | train2 -> R² = 0.2911, MSE = 1.6075e-01
# X | train2 -> R² = -0.0674, MSE = 8.9713e-02
# Y | train2 -> R² = -1.2624, MSE = 2.4224e-01
# Theta | test1 -> R² = -0.7611, MSE = 4.0622e-01
# X | test1 -> R² = -0.2346, MSE = 1.2852e-01
# Y | test1 -> R² = -1.6323, MSE = 2.1501e-01
# Theta | test2 -> R² = 0.1834, MSE = 1.9238e-01
# X | test2 -> R² = -0.1176, MSE = 9.1745e-02
# Y | test2 -> R² = -1.2767, MSE = 2.4036e-01
# Theta | test3 -> R² = -1.5685, MSE = 8.4654e-01
# X | test3 -> R² = -1.4565, MSE = 2.2475e-01
# Y | test3 -> R² = -5.5014, MSE = 4.9762e-01
# Theta | val -> R² = -2.3034, MSE = 1.0839e+00
# X | val -> R² = -1.5859, MSE = 2.4577e-01
# Y | val -> R² = -5.5905, MSE = 4.8912e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.610000
# Epoch 50 Loss 1.472616
# Epoch 100 Loss 1.471995
# Epoch 150 Loss 1.471959
# Epoch 200 Loss 1.451405
# Epoch 250 Loss 1.472507
# Epoch 300 Loss 1.472008
# Epoch 350 Loss 1.472006
# Epoch 400 Loss 1.472005
# Epoch 450 Loss 1.472005
# Epoch 500 Loss 1.472005
# Early stopping at epoch 519
# Theta | train1 -> R² = -0.4559, MSE = 3.3371e-01
# X | train1 -> R² = -0.1209, MSE = 1.2014e-01
# Y | train1 -> R² = -0.8672, MSE = 1.5606e-01
# Theta | train2 -> R² = -0.9219, MSE = 4.3578e-01
# X | train2 -> R² = 0.0377, MSE = 8.0882e-02
# Y | train2 -> R² = -0.6586, MSE = 1.7759e-01
# Theta | test1 -> R² = 0.2279, MSE = 1.7809e-01
# X | test1 -> R² = -0.3953, MSE = 1.4525e-01
# Y | test1 -> R² = -1.1174, MSE = 1.7295e-01
# Theta | test2 -> R² = -0.7793, MSE = 4.1918e-01
# X | test2 -> R² = 0.0017, MSE = 8.1958e-02
# Y | test2 -> R² = -0.6842, MSE = 1.7782e-01
# Theta | test3 -> R² = -0.3987, MSE = 4.6099e-01
# X | test3 -> R² = -1.5916, MSE = 2.3711e-01
# Y | test3 -> R² = -2.7666, MSE = 2.8830e-01
# Theta | val -> R² = 0.3828, MSE = 2.0251e-01
# X | val -> R² = -2.1873, MSE = 3.0293e-01
# Y | val -> R² = -3.4824, MSE = 3.3266e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.615869
# Epoch 50 Loss 1.472085
# Epoch 100 Loss 1.471999
# Epoch 150 Loss 1.471988
# Epoch 200 Loss 1.471939
# Epoch 250 Loss 1.478666
# Epoch 300 Loss 1.472021
# Early stopping at epoch 306
# Theta | train1 -> R² = -0.8233, MSE = 4.1792e-01
# X | train1 -> R² = -1.0543, MSE = 2.2018e-01
# Y | train1 -> R² = -1.5529, MSE = 2.1337e-01
# Theta | train2 -> R² = -0.7034, MSE = 3.8624e-01
# X | train2 -> R² = -0.5783, MSE = 1.3266e-01
# Y | train2 -> R² = -1.5334, MSE = 2.7125e-01
# Theta | test1 -> R² = -0.5137, MSE = 3.4916e-01
# X | test1 -> R² = -1.3412, MSE = 2.4371e-01
# Y | test1 -> R² = -1.8955, MSE = 2.3651e-01
# Theta | test2 -> R² = -0.7624, MSE = 4.1520e-01
# X | test2 -> R² = -0.6473, MSE = 1.3523e-01
# Y | test2 -> R² = -1.5505, MSE = 2.6927e-01
# Theta | test3 -> R² = -4.2121, MSE = 1.7178e+00
# X | test3 -> R² = -0.6858, MSE = 1.5424e-01
# Y | test3 -> R² = -0.3796, MSE = 1.0560e-01
# Theta | val -> R² = -1.6854, MSE = 8.8114e-01
# X | val -> R² = -1.2436, MSE = 2.1323e-01
# Y | val -> R² = -1.3904, MSE = 1.7741e-01
# Modelo 9 treinado e salvo no Excel
