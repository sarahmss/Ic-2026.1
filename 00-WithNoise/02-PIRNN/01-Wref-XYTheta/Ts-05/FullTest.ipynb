# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 5
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 2)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada: (1266, 5, 2)
# Dimensão da saida: (1266, 5, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 2)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[8], [16], [32], [64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 Loss 1.609663
# Epoch 50 Loss 1.430074
# Epoch 100 Loss 1.325442
# Epoch 150 Loss 1.313903
# Epoch 200 Loss 1.303781
# Epoch 250 Loss 1.297587
# Epoch 300 Loss 1.294641
# Epoch 350 Loss 1.293931
# Early stopping at epoch 377
# Theta | train1 -> R² = 0.8100, MSE = 4.3460e-02
# X | train1 -> R² = -0.3372, MSE = 1.4376e-01
# Y | train1 -> R² = -0.8774, MSE = 1.5712e-01
# Theta | train2 -> R² = 0.2183, MSE = 1.7786e-01
# X | train2 -> R² = -0.2999, MSE = 1.0939e-01
# Y | train2 -> R² = -0.8073, MSE = 1.9406e-01
# Theta | test1 -> R² = 0.7276, MSE = 6.2701e-02
# X | test1 -> R² = -0.4668, MSE = 1.5318e-01
# Y | test1 -> R² = -1.1270, MSE = 1.7402e-01
# Theta | test2 -> R² = 0.2864, MSE = 1.6869e-01
# X | test2 -> R² = -0.2966, MSE = 1.0657e-01
# Y | test2 -> R² = -0.7681, MSE = 1.8717e-01
# Theta | test3 -> R² = 0.3920, MSE = 2.0012e-01
# X | test3 -> R² = -0.2971, MSE = 1.1901e-01
# Y | test3 -> R² = -0.6645, MSE = 1.2762e-01
# Theta | val -> R² = 0.6548, MSE = 1.1311e-01
# X | val -> R² = -0.3311, MSE = 1.2690e-01
# Y | val -> R² = -0.8005, MSE = 1.3384e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.560028
# Epoch 50 Loss 1.352295
# Epoch 100 Loss 1.334362
# Epoch 150 Loss 1.327862
# Epoch 200 Loss 1.321147
# Epoch 250 Loss 1.315804
# Epoch 300 Loss 1.309479
# Epoch 350 Loss 1.304787
# Epoch 400 Loss 1.305465
# Early stopping at epoch 445
# Theta | train1 -> R² = 0.4540, MSE = 1.2489e-01
# X | train1 -> R² = -0.1318, MSE = 1.2167e-01
# Y | train1 -> R² = -0.7725, MSE = 1.4834e-01
# Theta | train2 -> R² = 0.6152, MSE = 8.7545e-02
# X | train2 -> R² = -0.1002, MSE = 9.2590e-02
# Y | train2 -> R² = -0.7909, MSE = 1.9230e-01
# Theta | test1 -> R² = -0.1667, MSE = 2.6857e-01
# X | test1 -> R² = -0.2035, MSE = 1.2568e-01
# Y | test1 -> R² = -0.9823, MSE = 1.6218e-01
# Theta | test2 -> R² = 0.5075, MSE = 1.1643e-01
# X | test2 -> R² = -0.1087, MSE = 9.1132e-02
# Y | test2 -> R² = -0.7219, MSE = 1.8228e-01
# Theta | test3 -> R² = 0.5662, MSE = 1.4280e-01
# X | test3 -> R² = -0.2472, MSE = 1.1443e-01
# Y | test3 -> R² = -0.3937, MSE = 1.0686e-01
# Theta | val -> R² = 0.6738, MSE = 1.0690e-01
# X | val -> R² = -0.2650, MSE = 1.2059e-01
# Y | val -> R² = -0.5494, MSE = 1.1517e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.567848
# Epoch 50 Loss 1.349429
# Epoch 100 Loss 1.331933
# Epoch 150 Loss 1.320349
# Epoch 200 Loss 1.307221
# Epoch 250 Loss 1.296505
# Epoch 300 Loss 1.289291
# Epoch 350 Loss 1.285867
# Epoch 400 Loss 1.283387
# Early stopping at epoch 432
# Theta | train1 -> R² = 0.8652, MSE = 3.0825e-02
# X | train1 -> R² = -0.2149, MSE = 1.3061e-01
# Y | train1 -> R² = -0.8475, MSE = 1.5462e-01
# Theta | train2 -> R² = 0.1241, MSE = 1.9928e-01
# X | train2 -> R² = -0.2206, MSE = 1.0272e-01
# Y | train2 -> R² = -0.8700, MSE = 2.0079e-01
# Theta | test1 -> R² = 0.7180, MSE = 6.4908e-02
# X | test1 -> R² = -0.2902, MSE = 1.3474e-01
# Y | test1 -> R² = -1.0439, MSE = 1.6723e-01
# Theta | test2 -> R² = 0.3340, MSE = 1.5744e-01
# X | test2 -> R² = -0.2102, MSE = 9.9469e-02
# Y | test2 -> R² = -0.7902, MSE = 1.8952e-01
# Theta | test3 -> R² = 0.7663, MSE = 7.6908e-02
# X | test3 -> R² = -0.4465, MSE = 1.3271e-01
# Y | test3 -> R² = -1.5673, MSE = 1.9685e-01
# Theta | val -> R² = 0.7314, MSE = 8.8034e-02
# X | val -> R² = -0.4415, MSE = 1.3742e-01
# Y | val -> R² = -1.4850, MSE = 1.8472e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.570625
# Epoch 50 Loss 1.349907
# Epoch 100 Loss 1.332942
# Epoch 150 Loss 1.328914
# Epoch 200 Loss 1.326107
# Epoch 250 Loss 1.321046
# Epoch 300 Loss 1.315554
# Epoch 350 Loss 1.309774
# Epoch 400 Loss 1.319673
# Early stopping at epoch 411
# Theta | train1 -> R² = 0.7817, MSE = 4.9941e-02
# X | train1 -> R² = -0.2352, MSE = 1.3279e-01
# Y | train1 -> R² = -0.8252, MSE = 1.5275e-01
# Theta | train2 -> R² = 0.3935, MSE = 1.3799e-01
# X | train2 -> R² = -0.1933, MSE = 1.0042e-01
# Y | train2 -> R² = -0.8909, MSE = 2.0304e-01
# Theta | test1 -> R² = 0.5434, MSE = 1.0511e-01
# X | test1 -> R² = -0.2890, MSE = 1.3461e-01
# Y | test1 -> R² = -1.0316, MSE = 1.6622e-01
# Theta | test2 -> R² = 0.4222, MSE = 1.3659e-01
# X | test2 -> R² = -0.1948, MSE = 9.8209e-02
# Y | test2 -> R² = -0.8119, MSE = 1.9181e-01
# Theta | test3 -> R² = -0.2826, MSE = 4.2219e-01
# X | test3 -> R² = -0.2167, MSE = 1.1163e-01
# Y | test3 -> R² = -0.2074, MSE = 9.2577e-02
# Theta | val -> R² = 0.3268, MSE = 2.2062e-01
# X | val -> R² = -0.2433, MSE = 1.1853e-01
# Y | val -> R² = -0.3770, MSE = 1.0236e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.569449
# Epoch 50 Loss 1.347604
# Epoch 100 Loss 1.330623
# Epoch 150 Loss 1.324093
# Epoch 200 Loss 1.317519
# Epoch 250 Loss 1.304303
# Epoch 300 Loss 1.293935
# Epoch 350 Loss 1.287151
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.7072, MSE = 6.6980e-02
# X | train1 -> R² = -0.1065, MSE = 1.1895e-01
# Y | train1 -> R² = -0.8087, MSE = 1.5137e-01
# Theta | train2 -> R² = 0.1553, MSE = 1.9218e-01
# X | train2 -> R² = -0.1003, MSE = 9.2600e-02
# Y | train2 -> R² = -0.7662, MSE = 1.8964e-01
# Theta | test1 -> R² = 0.6955, MSE = 7.0103e-02
# X | test1 -> R² = -0.2159, MSE = 1.2698e-01
# Y | test1 -> R² = -1.0097, MSE = 1.6443e-01
# Theta | test2 -> R² = 0.1502, MSE = 2.0087e-01
# X | test2 -> R² = -0.1025, MSE = 9.0621e-02
# Y | test2 -> R² = -0.7313, MSE = 1.8328e-01
# Theta | test3 -> R² = 0.5170, MSE = 1.5897e-01
# X | test3 -> R² = -0.2030, MSE = 1.1038e-01
# Y | test3 -> R² = -1.0876, MSE = 1.6007e-01
# Theta | val -> R² = 0.6389, MSE = 1.1834e-01
# X | val -> R² = -0.2181, MSE = 1.1612e-01
# Y | val -> R² = -1.1304, MSE = 1.5836e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.566015
# Epoch 50 Loss 1.352538
# Epoch 100 Loss 1.334173
# Epoch 150 Loss 1.334009
# Epoch 200 Loss 1.313294
# Epoch 250 Loss 1.305574
# Epoch 300 Loss 1.299735
# Epoch 350 Loss 1.292809
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.8075, MSE = 4.4030e-02
# X | train1 -> R² = -0.2551, MSE = 1.3493e-01
# Y | train1 -> R² = -0.8320, MSE = 1.5332e-01
# Theta | train2 -> R² = 0.2151, MSE = 1.7860e-01
# X | train2 -> R² = -0.1700, MSE = 9.8459e-02
# Y | train2 -> R² = -0.7939, MSE = 1.9262e-01
# Theta | test1 -> R² = 0.5155, MSE = 1.1153e-01
# X | test1 -> R² = -0.3503, MSE = 1.4101e-01
# Y | test1 -> R² = -0.9952, MSE = 1.6324e-01
# Theta | test2 -> R² = 0.3337, MSE = 1.5750e-01
# X | test2 -> R² = -0.1613, MSE = 9.5449e-02
# Y | test2 -> R² = -0.7313, MSE = 1.8328e-01
# Theta | test3 -> R² = -0.0254, MSE = 3.3752e-01
# X | test3 -> R² = -0.3123, MSE = 1.2040e-01
# Y | test3 -> R² = -0.9598, MSE = 1.5027e-01
# Theta | val -> R² = 0.4632, MSE = 1.7593e-01
# X | val -> R² = -0.3452, MSE = 1.2824e-01
# Y | val -> R² = -1.0471, MSE = 1.5217e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.589802
# Epoch 50 Loss 1.352589
# Epoch 100 Loss 1.330924
# Epoch 150 Loss 1.321016
# Epoch 200 Loss 1.309343
# Epoch 250 Loss 1.305304
# Epoch 300 Loss 1.290588
# Early stopping at epoch 332
# Theta | train1 -> R² = 0.8074, MSE = 4.4061e-02
# X | train1 -> R² = -0.0237, MSE = 1.1005e-01
# Y | train1 -> R² = -1.2447, MSE = 1.8786e-01
# Theta | train2 -> R² = -0.0857, MSE = 2.4702e-01
# X | train2 -> R² = -0.0647, MSE = 8.9598e-02
# Y | train2 -> R² = -1.2007, MSE = 2.3631e-01
# Theta | test1 -> R² = 0.8193, MSE = 4.1601e-02
# X | test1 -> R² = -0.1119, MSE = 1.1611e-01
# Y | test1 -> R² = -1.4697, MSE = 2.0206e-01
# Theta | test2 -> R² = -0.0735, MSE = 2.5374e-01
# X | test2 -> R² = -0.0534, MSE = 8.6584e-02
# Y | test2 -> R² = -1.1470, MSE = 2.2728e-01
# Theta | test3 -> R² = 0.5594, MSE = 1.4503e-01
# X | test3 -> R² = -0.1889, MSE = 1.0908e-01
# Y | test3 -> R² = -1.9615, MSE = 2.2707e-01
# Theta | val -> R² = 0.7311, MSE = 8.8126e-02
# X | val -> R² = -0.1991, MSE = 1.1432e-01
# Y | val -> R² = -1.9899, MSE = 2.2225e-01
# Figura salva em: ./results/model_8_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.579813
# Epoch 50 Loss 1.352488
# Epoch 100 Loss 1.344763
# Epoch 150 Loss 1.341819
# Epoch 200 Loss 1.336734
# Epoch 250 Loss 1.332963
# Epoch 300 Loss 1.329080
# Early stopping at epoch 344
# Theta | train1 -> R² = 0.8320, MSE = 3.8435e-02
# X | train1 -> R² = -0.3057, MSE = 1.4037e-01
# Y | train1 -> R² = -0.9065, MSE = 1.5955e-01
# Theta | train2 -> R² = 0.1430, MSE = 1.9499e-01
# X | train2 -> R² = -0.2575, MSE = 1.0582e-01
# Y | train2 -> R² = -0.8063, MSE = 1.9395e-01
# Theta | test1 -> R² = 0.7661, MSE = 5.3831e-02
# X | test1 -> R² = -0.4400, MSE = 1.5038e-01
# Y | test1 -> R² = -1.1455, MSE = 1.7554e-01
# Theta | test2 -> R² = 0.1914, MSE = 1.9114e-01
# X | test2 -> R² = -0.2536, MSE = 1.0304e-01
# Y | test2 -> R² = -0.7715, MSE = 1.8753e-01
# Theta | test3 -> R² = 0.5533, MSE = 1.4704e-01
# X | test3 -> R² = -0.3505, MSE = 1.2391e-01
# Y | test3 -> R² = -0.8666, MSE = 1.4312e-01
# Theta | val -> R² = 0.7166, MSE = 9.2877e-02
# X | val -> R² = -0.3832, MSE = 1.3186e-01
# Y | val -> R² = -1.0066, MSE = 1.4916e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.574150
# Epoch 50 Loss 1.352949
# Epoch 100 Loss 1.351568
# Epoch 150 Loss 1.339835
# Epoch 200 Loss 1.342371
# Epoch 250 Loss 1.330082
# Epoch 300 Loss 1.329876
# Epoch 350 Loss 1.319475
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.7556, MSE = 5.5910e-02
# X | train1 -> R² = -0.1837, MSE = 1.2725e-01
# Y | train1 -> R² = -0.6197, MSE = 1.3555e-01
# Theta | train2 -> R² = 0.2326, MSE = 1.7461e-01
# X | train2 -> R² = -0.2110, MSE = 1.0191e-01
# Y | train2 -> R² = -0.6301, MSE = 1.7503e-01
# Theta | test1 -> R² = 0.7057, MSE = 6.7739e-02
# X | test1 -> R² = -0.2605, MSE = 1.3163e-01
# Y | test1 -> R² = -0.7854, MSE = 1.4607e-01
# Theta | test2 -> R² = 0.2730, MSE = 1.7185e-01
# X | test2 -> R² = -0.2142, MSE = 9.9800e-02
# Y | test2 -> R² = -0.5973, MSE = 1.6909e-01
# Theta | test3 -> R² = -3.8705, MSE = 1.6032e+00
# X | test3 -> R² = -0.3110, MSE = 1.2028e-01
# Y | test3 -> R² = -0.3389, MSE = 1.0266e-01
# Theta | val -> R² = -1.9187, MSE = 9.5646e-01
# X | val -> R² = -0.3474, MSE = 1.2846e-01
# Y | val -> R² = -0.4982, MSE = 1.1137e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.583757
# Epoch 50 Loss 1.348443
# Epoch 100 Loss 1.330737
# Epoch 150 Loss 1.322318
# Epoch 200 Loss 1.302991
# Epoch 250 Loss 1.294535
# Epoch 300 Loss 1.287049
# Epoch 350 Loss 1.280726
# Early stopping at epoch 377
# Theta | train1 -> R² = 0.8139, MSE = 4.2560e-02
# X | train1 -> R² = -0.2726, MSE = 1.3682e-01
# Y | train1 -> R² = -0.9896, MSE = 1.6651e-01
# Theta | train2 -> R² = 0.4510, MSE = 1.2492e-01
# X | train2 -> R² = -0.1797, MSE = 9.9282e-02
# Y | train2 -> R² = -0.8648, MSE = 2.0024e-01
# Theta | test1 -> R² = 0.6115, MSE = 8.9418e-02
# X | test1 -> R² = -0.3607, MSE = 1.4210e-01
# Y | test1 -> R² = -1.1884, MSE = 1.7904e-01
# Theta | test2 -> R² = 0.4743, MSE = 1.2425e-01
# X | test2 -> R² = -0.1821, MSE = 9.7163e-02
# Y | test2 -> R² = -0.8321, MSE = 1.9395e-01
# Theta | test3 -> R² = 0.0837, MSE = 3.0160e-01
# X | test3 -> R² = -0.3922, MSE = 1.2773e-01
# Y | test3 -> R² = -1.7356, MSE = 2.0975e-01
# Theta | val -> R² = 0.4943, MSE = 1.6571e-01
# X | val -> R² = -0.4428, MSE = 1.3755e-01
# Y | val -> R² = -1.6989, MSE = 2.0062e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.588603
# Epoch 50 Loss 1.349825
# Epoch 100 Loss 1.340881
# Epoch 150 Loss 1.326477
# Epoch 200 Loss 1.312485
# Epoch 250 Loss 1.297731
# Epoch 300 Loss 1.289376
# Epoch 350 Loss 1.282049
# Early stopping at epoch 360
# Theta | train1 -> R² = 0.8284, MSE = 3.9243e-02
# X | train1 -> R² = -0.1613, MSE = 1.2484e-01
# Y | train1 -> R² = -0.9569, MSE = 1.6377e-01
# Theta | train2 -> R² = -0.1938, MSE = 2.7161e-01
# X | train2 -> R² = -0.1683, MSE = 9.8318e-02
# Y | train2 -> R² = -0.8891, MSE = 2.0284e-01
# Theta | test1 -> R² = 0.7815, MSE = 5.0295e-02
# X | test1 -> R² = -0.2303, MSE = 1.2848e-01
# Y | test1 -> R² = -1.1452, MSE = 1.7551e-01
# Theta | test2 -> R² = -0.0785, MSE = 2.5492e-01
# X | test2 -> R² = -0.1651, MSE = 9.5762e-02
# Y | test2 -> R² = -0.8388, MSE = 1.9466e-01
# Theta | test3 -> R² = 0.5013, MSE = 1.6415e-01
# X | test3 -> R² = -0.3562, MSE = 1.2443e-01
# Y | test3 -> R² = -1.8792, MSE = 2.2076e-01
# Theta | val -> R² = 0.6463, MSE = 1.1591e-01
# X | val -> R² = -0.3754, MSE = 1.3113e-01
# Y | val -> R² = -1.7985, MSE = 2.0802e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.580508
# Epoch 50 Loss 1.341114
# Epoch 100 Loss 1.326599
# Epoch 150 Loss 1.312722
# Epoch 200 Loss 1.303136
# Epoch 250 Loss 1.299042
# Epoch 300 Loss 1.285417
# Epoch 350 Loss 1.276049
# Early stopping at epoch 364
# Theta | train1 -> R² = 0.7938, MSE = 4.7160e-02
# X | train1 -> R² = -0.0839, MSE = 1.1652e-01
# Y | train1 -> R² = -0.8729, MSE = 1.5674e-01
# Theta | train2 -> R² = -0.5200, MSE = 3.4584e-01
# X | train2 -> R² = -0.2016, MSE = 1.0112e-01
# Y | train2 -> R² = -0.7754, MSE = 1.9063e-01
# Theta | test1 -> R² = 0.8086, MSE = 4.4049e-02
# X | test1 -> R² = -0.1246, MSE = 1.1745e-01
# Y | test1 -> R² = -1.0903, MSE = 1.7102e-01
# Theta | test2 -> R² = -0.2211, MSE = 2.8865e-01
# X | test2 -> R² = -0.1886, MSE = 9.7695e-02
# Y | test2 -> R² = -0.7190, MSE = 1.8197e-01
# Theta | test3 -> R² = 0.6852, MSE = 1.0363e-01
# X | test3 -> R² = -0.3244, MSE = 1.2151e-01
# Y | test3 -> R² = -2.0100, MSE = 2.3079e-01
# Theta | val -> R² = 0.5273, MSE = 1.5490e-01
# X | val -> R² = -0.3319, MSE = 1.2698e-01
# Y | val -> R² = -1.9575, MSE = 2.1984e-01
# Figura salva em: ./results/model_16_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.549685
# Epoch 50 Loss 1.339344
# Epoch 100 Loss 1.325164
# Epoch 150 Loss 1.314626
# Epoch 200 Loss 1.295270
# Epoch 250 Loss 1.285660
# Epoch 300 Loss 1.277202
# Early stopping at epoch 320
# Theta | train1 -> R² = 0.8190, MSE = 4.1404e-02
# X | train1 -> R² = 0.0755, MSE = 9.9389e-02
# Y | train1 -> R² = -1.1685, MSE = 1.8148e-01
# Theta | train2 -> R² = 0.4326, MSE = 1.2909e-01
# X | train2 -> R² = -0.1259, MSE = 9.4748e-02
# Y | train2 -> R² = -1.0102, MSE = 2.1585e-01
# Theta | test1 -> R² = 0.6977, MSE = 6.9585e-02
# X | test1 -> R² = -0.0256, MSE = 1.0710e-01
# Y | test1 -> R² = -1.4159, MSE = 1.9766e-01
# Theta | test2 -> R² = 0.4120, MSE = 1.3899e-01
# X | test2 -> R² = -0.1319, MSE = 9.3038e-02
# Y | test2 -> R² = -0.9841, MSE = 2.1004e-01
# Theta | test3 -> R² = -0.4123, MSE = 4.6488e-01
# X | test3 -> R² = -0.0509, MSE = 9.6424e-02
# Y | test3 -> R² = -2.0667, MSE = 2.3513e-01
# Theta | val -> R² = 0.2729, MSE = 2.3828e-01
# X | val -> R² = -0.0643, MSE = 1.0146e-01
# Y | val -> R² = -1.9993, MSE = 2.2295e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.575195
# Epoch 50 Loss 1.344833
# Epoch 100 Loss 1.328741
# Epoch 150 Loss 1.310224
# Epoch 200 Loss 1.298425
# Epoch 250 Loss 1.291413
# Epoch 300 Loss 1.284389
# Epoch 350 Loss 1.279217
# Early stopping at epoch 371
# Theta | train1 -> R² = 0.7695, MSE = 5.2716e-02
# X | train1 -> R² = -0.2212, MSE = 1.3128e-01
# Y | train1 -> R² = -0.9273, MSE = 1.6130e-01
# Theta | train2 -> R² = 0.3806, MSE = 1.4094e-01
# X | train2 -> R² = -0.2285, MSE = 1.0339e-01
# Y | train2 -> R² = -0.8543, MSE = 1.9911e-01
# Theta | test1 -> R² = 0.4829, MSE = 1.1903e-01
# X | test1 -> R² = -0.2895, MSE = 1.3466e-01
# Y | test1 -> R² = -1.1166, MSE = 1.7317e-01
# Theta | test2 -> R² = 0.4444, MSE = 1.3134e-01
# X | test2 -> R² = -0.2348, MSE = 1.0149e-01
# Y | test2 -> R² = -0.8008, MSE = 1.9063e-01
# Theta | test3 -> R² = 0.4667, MSE = 1.7554e-01
# X | test3 -> R² = -0.5402, MSE = 1.4131e-01
# Y | test3 -> R² = -1.8691, MSE = 2.1999e-01
# Theta | val -> R² = 0.6331, MSE = 1.2025e-01
# X | val -> R² = -0.5182, MSE = 1.4473e-01
# Y | val -> R² = -1.7753, MSE = 2.0630e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.561105
# Epoch 50 Loss 1.346951
# Epoch 100 Loss 1.326411
# Epoch 150 Loss 1.316628
# Epoch 200 Loss 1.304086
# Epoch 250 Loss 1.292345
# Epoch 300 Loss 1.285945
# Early stopping at epoch 319
# Theta | train1 -> R² = 0.8319, MSE = 3.8449e-02
# X | train1 -> R² = 0.1098, MSE = 9.5702e-02
# Y | train1 -> R² = -1.4912, MSE = 2.0849e-01
# Theta | train2 -> R² = 0.5712, MSE = 9.7571e-02
# X | train2 -> R² = -0.1394, MSE = 9.5883e-02
# Y | train2 -> R² = -1.1524, MSE = 2.3112e-01
# Theta | test1 -> R² = 0.4763, MSE = 1.2055e-01
# X | test1 -> R² = 0.0064, MSE = 1.0376e-01
# Y | test1 -> R² = -1.7563, MSE = 2.2551e-01
# Theta | test2 -> R² = 0.5592, MSE = 1.0421e-01
# X | test2 -> R² = -0.1456, MSE = 9.4158e-02
# Y | test2 -> R² = -1.1266, MSE = 2.2512e-01
# Theta | test3 -> R² = -0.2922, MSE = 4.2532e-01
# X | test3 -> R² = -0.0305, MSE = 9.4552e-02
# Y | test3 -> R² = -2.6361, MSE = 2.7879e-01
# Theta | val -> R² = 0.3115, MSE = 2.2562e-01
# X | val -> R² = -0.0422, MSE = 9.9360e-02
# Y | val -> R² = -2.5767, MSE = 2.6587e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.569262
# Epoch 50 Loss 1.339862
# Epoch 100 Loss 1.324145
# Epoch 150 Loss 1.303731
# Epoch 200 Loss 1.294554
# Epoch 250 Loss 1.283692
# Epoch 300 Loss 1.274256
# Early stopping at epoch 322
# Theta | train1 -> R² = 0.4141, MSE = 1.3401e-01
# X | train1 -> R² = 0.0512, MSE = 1.0200e-01
# Y | train1 -> R² = -1.2039, MSE = 1.8444e-01
# Theta | train2 -> R² = -0.3574, MSE = 3.0883e-01
# X | train2 -> R² = -0.1957, MSE = 1.0063e-01
# Y | train2 -> R² = -1.1146, MSE = 2.2706e-01
# Theta | test1 -> R² = 0.7355, MSE = 6.0874e-02
# X | test1 -> R² = -0.0613, MSE = 1.1083e-01
# Y | test1 -> R² = -1.4983, MSE = 2.0440e-01
# Theta | test2 -> R² = -0.2579, MSE = 2.9733e-01
# X | test2 -> R² = -0.1864, MSE = 9.7514e-02
# Y | test2 -> R² = -1.0698, MSE = 2.1911e-01
# Theta | test3 -> R² = 0.8474, MSE = 5.0232e-02
# X | test3 -> R² = -0.1707, MSE = 1.0741e-01
# Y | test3 -> R² = -2.4441, MSE = 2.6407e-01
# Theta | val -> R² = 0.6271, MSE = 1.2219e-01
# X | val -> R² = -0.1742, MSE = 1.1194e-01
# Y | val -> R² = -2.3282, MSE = 2.4740e-01
# Figura salva em: ./results/model_16_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.567538
# Epoch 50 Loss 1.346921
# Epoch 100 Loss 1.335836
# Epoch 150 Loss 1.321547
# Epoch 200 Loss 1.309877
# Epoch 250 Loss 1.299376
# Epoch 300 Loss 1.286499
# Epoch 350 Loss 1.280282
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.8008, MSE = 4.5566e-02
# X | train1 -> R² = -0.1570, MSE = 1.2438e-01
# Y | train1 -> R² = -0.9153, MSE = 1.6029e-01
# Theta | train2 -> R² = 0.3675, MSE = 1.4390e-01
# X | train2 -> R² = -0.1064, MSE = 9.3108e-02
# Y | train2 -> R² = -0.8702, MSE = 2.0082e-01
# Theta | test1 -> R² = 0.6197, MSE = 8.7535e-02
# X | test1 -> R² = -0.2204, MSE = 1.2745e-01
# Y | test1 -> R² = -1.1090, MSE = 1.7255e-01
# Theta | test2 -> R² = 0.3642, MSE = 1.5029e-01
# X | test2 -> R² = -0.1069, MSE = 9.0979e-02
# Y | test2 -> R² = -0.8252, MSE = 1.9322e-01
# Theta | test3 -> R² = -0.8949, MSE = 6.2372e-01
# X | test3 -> R² = -0.2665, MSE = 1.1620e-01
# Y | test3 -> R² = -1.2328, MSE = 1.7120e-01
# Theta | val -> R² = 0.0222, MSE = 3.2042e-01
# X | val -> R² = -0.2898, MSE = 1.2296e-01
# Y | val -> R² = -1.2551, MSE = 1.6763e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.573337
# Epoch 50 Loss 1.348305
# Epoch 100 Loss 1.336379
# Epoch 150 Loss 1.322342
# Epoch 200 Loss 1.304462
# Epoch 250 Loss 1.296513
# Epoch 300 Loss 1.289066
# Early stopping at epoch 331
# Theta | train1 -> R² = 0.7728, MSE = 5.1975e-02
# X | train1 -> R² = -0.2957, MSE = 1.3929e-01
# Y | train1 -> R² = -0.9261, MSE = 1.6119e-01
# Theta | train2 -> R² = 0.3503, MSE = 1.4782e-01
# X | train2 -> R² = -0.3088, MSE = 1.1015e-01
# Y | train2 -> R² = -0.8133, MSE = 1.9471e-01
# Theta | test1 -> R² = 0.5692, MSE = 9.9159e-02
# X | test1 -> R² = -0.4144, MSE = 1.4771e-01
# Y | test1 -> R² = -1.1462, MSE = 1.7559e-01
# Theta | test2 -> R² = 0.3627, MSE = 1.5065e-01
# X | test2 -> R² = -0.3171, MSE = 1.0826e-01
# Y | test2 -> R² = -0.7832, MSE = 1.8878e-01
# Theta | test3 -> R² = 0.1441, MSE = 2.8172e-01
# X | test3 -> R² = -0.5219, MSE = 1.3963e-01
# Y | test3 -> R² = -1.8132, MSE = 2.1570e-01
# Theta | val -> R² = 0.5416, MSE = 1.5021e-01
# X | val -> R² = -0.5584, MSE = 1.4857e-01
# Y | val -> R² = -1.7903, MSE = 2.0741e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.560565
# Epoch 50 Loss 1.342852
# Epoch 100 Loss 1.331100
# Epoch 150 Loss 1.317676
# Epoch 200 Loss 1.305280
# Epoch 250 Loss 1.297233
# Epoch 300 Loss 1.291749
# Early stopping at epoch 345
# Theta | train1 -> R² = 0.7445, MSE = 5.8447e-02
# X | train1 -> R² = -0.0750, MSE = 1.1557e-01
# Y | train1 -> R² = -0.9158, MSE = 1.6033e-01
# Theta | train2 -> R² = 0.2365, MSE = 1.7373e-01
# X | train2 -> R² = -0.0703, MSE = 9.0070e-02
# Y | train2 -> R² = -0.8634, MSE = 2.0009e-01
# Theta | test1 -> R² = 0.5404, MSE = 1.0580e-01
# X | test1 -> R² = -0.1531, MSE = 1.2042e-01
# Y | test1 -> R² = -1.1357, MSE = 1.7473e-01
# Theta | test2 -> R² = 0.2569, MSE = 1.7565e-01
# X | test2 -> R² = -0.0687, MSE = 8.7837e-02
# Y | test2 -> R² = -0.8219, MSE = 1.9287e-01
# Theta | test3 -> R² = 0.1378, MSE = 2.8379e-01
# X | test3 -> R² = -0.2008, MSE = 1.1018e-01
# Y | test3 -> R² = -1.5899, MSE = 1.9858e-01
# Theta | val -> R² = 0.4691, MSE = 1.7398e-01
# X | val -> R² = -0.2245, MSE = 1.1673e-01
# Y | val -> R² = -1.5560, MSE = 1.8999e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.583546
# Epoch 50 Loss 1.340571
# Epoch 100 Loss 1.322336
# Epoch 150 Loss 1.309751
# Epoch 200 Loss 1.297574
# Epoch 250 Loss 1.291061
# Epoch 300 Loss 1.282235
# Epoch 350 Loss 1.274189
# Early stopping at epoch 398
# Theta | train1 -> R² = 0.8331, MSE = 3.8168e-02
# X | train1 -> R² = -0.2122, MSE = 1.3032e-01
# Y | train1 -> R² = -0.7782, MSE = 1.4882e-01
# Theta | train2 -> R² = 0.3413, MSE = 1.4987e-01
# X | train2 -> R² = -0.1757, MSE = 9.8943e-02
# Y | train2 -> R² = -0.8695, MSE = 2.0074e-01
# Theta | test1 -> R² = 0.6514, MSE = 8.0242e-02
# X | test1 -> R² = -0.2494, MSE = 1.3048e-01
# Y | test1 -> R² = -0.9946, MSE = 1.6319e-01
# Theta | test2 -> R² = 0.4520, MSE = 1.2952e-01
# X | test2 -> R² = -0.1940, MSE = 9.8141e-02
# Y | test2 -> R² = -0.7812, MSE = 1.8856e-01
# Theta | test3 -> R² = 0.2240, MSE = 2.5544e-01
# X | test3 -> R² = -0.7138, MSE = 1.5724e-01
# Y | test3 -> R² = -0.4247, MSE = 1.0924e-01
# Theta | val -> R² = 0.5794, MSE = 1.3784e-01
# X | val -> R² = -0.6133, MSE = 1.5380e-01
# Y | val -> R² = -0.5711, MSE = 1.1679e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.557423
# Epoch 50 Loss 1.340675
# Epoch 100 Loss 1.324141
# Epoch 150 Loss 1.316041
# Epoch 200 Loss 1.291155
# Epoch 250 Loss 1.280025
# Epoch 300 Loss 1.271106
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.3767, MSE = 1.4258e-01
# X | train1 -> R² = -0.0106, MSE = 1.0865e-01
# Y | train1 -> R² = -0.9305, MSE = 1.6156e-01
# Theta | train2 -> R² = 0.4709, MSE = 1.2039e-01
# X | train2 -> R² = -0.2980, MSE = 1.0924e-01
# Y | train2 -> R² = -0.7459, MSE = 1.8746e-01
# Theta | test1 -> R² = -0.1204, MSE = 2.5791e-01
# X | test1 -> R² = -0.1163, MSE = 1.1658e-01
# Y | test1 -> R² = -1.1428, MSE = 1.7531e-01
# Theta | test2 -> R² = 0.3835, MSE = 1.4573e-01
# X | test2 -> R² = -0.3137, MSE = 1.0798e-01
# Y | test2 -> R² = -0.7244, MSE = 1.8255e-01
# Theta | test3 -> R² = -1.2349, MSE = 7.3563e-01
# X | test3 -> R² = -0.1473, MSE = 1.0527e-01
# Y | test3 -> R² = -1.4393, MSE = 1.8703e-01
# Theta | val -> R² = -0.3817, MSE = 4.5277e-01
# X | val -> R² = -0.2022, MSE = 1.1461e-01
# Y | val -> R² = -1.4637, MSE = 1.8314e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.544425
# Epoch 50 Loss 1.332810
# Epoch 100 Loss 1.323495
# Epoch 150 Loss 1.309590
# Epoch 200 Loss 1.291949
# Epoch 250 Loss 1.282733
# Epoch 300 Loss 1.291824
# Early stopping at epoch 308
# Theta | train1 -> R² = 0.3842, MSE = 1.4086e-01
# X | train1 -> R² = -0.1406, MSE = 1.2262e-01
# Y | train1 -> R² = -1.3288, MSE = 1.9489e-01
# Theta | train2 -> R² = 0.3261, MSE = 1.5333e-01
# X | train2 -> R² = -0.2997, MSE = 1.0938e-01
# Y | train2 -> R² = -1.1182, MSE = 2.2745e-01
# Theta | test1 -> R² = 0.0116, MSE = 2.2753e-01
# X | test1 -> R² = -0.2274, MSE = 1.2817e-01
# Y | test1 -> R² = -1.5628, MSE = 2.0968e-01
# Theta | test2 -> R² = 0.2495, MSE = 1.7739e-01
# X | test2 -> R² = -0.3182, MSE = 1.0835e-01
# Y | test2 -> R² = -1.0939, MSE = 2.2166e-01
# Theta | test3 -> R² = -1.2677, MSE = 7.4642e-01
# X | test3 -> R² = -0.2679, MSE = 1.1633e-01
# Y | test3 -> R² = -2.0672, MSE = 2.3518e-01
# Theta | val -> R² = -0.4491, MSE = 4.7489e-01
# X | val -> R² = -0.3979, MSE = 1.3327e-01
# Y | val -> R² = -2.0468, MSE = 2.2648e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.614408
# Epoch 50 Loss 1.334267
# Epoch 100 Loss 1.321232
# Epoch 150 Loss 1.331794
# Epoch 200 Loss 1.294782
# Epoch 250 Loss 1.284327
# Epoch 300 Loss 1.288587
# Early stopping at epoch 313
# Theta | train1 -> R² = 0.6371, MSE = 8.3007e-02
# X | train1 -> R² = 0.1782, MSE = 8.8349e-02
# Y | train1 -> R² = -0.7025, MSE = 1.4248e-01
# Theta | train2 -> R² = -0.4182, MSE = 3.2269e-01
# X | train2 -> R² = 0.0749, MSE = 7.7850e-02
# Y | train2 -> R² = -0.6604, MSE = 1.7829e-01
# Theta | test1 -> R² = 0.8302, MSE = 3.9096e-02
# X | test1 -> R² = 0.1214, MSE = 9.1757e-02
# Y | test1 -> R² = -0.8875, MSE = 1.5442e-01
# Theta | test2 -> R² = -0.2709, MSE = 3.0041e-01
# X | test2 -> R² = 0.0631, MSE = 7.7006e-02
# Y | test2 -> R² = -0.6294, MSE = 1.7249e-01
# Theta | test3 -> R² = 0.7788, MSE = 7.2811e-02
# X | test3 -> R² = -0.0183, MSE = 9.3431e-02
# Y | test3 -> R² = -1.0044, MSE = 1.5368e-01
# Theta | val -> R² = 0.7360, MSE = 8.6510e-02
# X | val -> R² = 0.0206, MSE = 9.3370e-02
# Y | val -> R² = -1.0402, MSE = 1.5166e-01
# Figura salva em: ./results/model_32_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.566794
# Epoch 50 Loss 1.340600
# Epoch 100 Loss 1.330508
# Epoch 150 Loss 1.312013
# Epoch 200 Loss 1.306957
# Epoch 250 Loss 1.287160
# Epoch 300 Loss 1.276691
# Epoch 350 Loss 1.265466
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.8253, MSE = 3.9961e-02
# X | train1 -> R² = -0.1467, MSE = 1.2328e-01
# Y | train1 -> R² = -0.9223, MSE = 1.6088e-01
# Theta | train2 -> R² = 0.2029, MSE = 1.8137e-01
# X | train2 -> R² = -0.1249, MSE = 9.4668e-02
# Y | train2 -> R² = -0.8546, MSE = 1.9914e-01
# Theta | test1 -> R² = 0.7113, MSE = 6.6459e-02
# X | test1 -> R² = -0.2006, MSE = 1.2538e-01
# Y | test1 -> R² = -1.1130, MSE = 1.7287e-01
# Theta | test2 -> R² = 0.2143, MSE = 1.8572e-01
# X | test2 -> R² = -0.1182, MSE = 9.1909e-02
# Y | test2 -> R² = -0.8019, MSE = 1.9075e-01
# Theta | test3 -> R² = 0.1265, MSE = 2.8753e-01
# X | test3 -> R² = -0.3024, MSE = 1.1950e-01
# Y | test3 -> R² = -1.6645, MSE = 2.0430e-01
# Theta | val -> R² = 0.5152, MSE = 1.5888e-01
# X | val -> R² = -0.3363, MSE = 1.2740e-01
# Y | val -> R² = -1.6009, MSE = 1.9334e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.555996
# Epoch 50 Loss 1.335176
# Epoch 100 Loss 1.330391
# Epoch 150 Loss 1.309072
# Epoch 200 Loss 1.314961
# Epoch 250 Loss 1.286790
# Epoch 300 Loss 1.282360
# Early stopping at epoch 309
# Theta | train1 -> R² = 0.3209, MSE = 1.5534e-01
# X | train1 -> R² = -0.6820, MSE = 1.8082e-01
# Y | train1 -> R² = -1.6513, MSE = 2.2188e-01
# Theta | train2 -> R² = -0.9148, MSE = 4.3566e-01
# X | train2 -> R² = -0.6017, MSE = 1.3479e-01
# Y | train2 -> R² = -1.4804, MSE = 2.6634e-01
# Theta | test1 -> R² = 0.6268, MSE = 8.5896e-02
# X | test1 -> R² = -0.7696, MSE = 1.8480e-01
# Y | test1 -> R² = -1.8157, MSE = 2.3037e-01
# Theta | test2 -> R² = -0.7057, MSE = 4.0318e-01
# X | test2 -> R² = -0.6017, MSE = 1.3165e-01
# Y | test2 -> R² = -1.4132, MSE = 2.5547e-01
# Theta | test3 -> R² = 0.6620, MSE = 1.1125e-01
# X | test3 -> R² = -1.0371, MSE = 1.8691e-01
# Y | test3 -> R² = -2.9677, MSE = 3.0422e-01
# Theta | val -> R² = 0.4902, MSE = 1.6705e-01
# X | val -> R² = -1.1004, MSE = 2.0024e-01
# Y | val -> R² = -2.8070, MSE = 2.8298e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.577802
# Epoch 50 Loss 1.337380
# Epoch 100 Loss 1.322197
# Epoch 150 Loss 1.303541
# Epoch 200 Loss 1.295120
# Epoch 250 Loss 1.285988
# Epoch 300 Loss 1.273362
# Early stopping at epoch 311
# Theta | train1 -> R² = 0.8059, MSE = 4.4408e-02
# X | train1 -> R² = 0.0746, MSE = 9.9486e-02
# Y | train1 -> R² = -0.5107, MSE = 1.2643e-01
# Theta | train2 -> R² = -0.2764, MSE = 2.9042e-01
# X | train2 -> R² = -0.0289, MSE = 8.6587e-02
# Y | train2 -> R² = -0.3671, MSE = 1.4679e-01
# Theta | test1 -> R² = 0.8133, MSE = 4.2966e-02
# X | test1 -> R² = 0.0039, MSE = 1.0402e-01
# Y | test1 -> R² = -0.6530, MSE = 1.3524e-01
# Theta | test2 -> R² = -0.1308, MSE = 2.6730e-01
# X | test2 -> R² = -0.0423, MSE = 8.5669e-02
# Y | test2 -> R² = -0.3447, MSE = 1.4235e-01
# Theta | test3 -> R² = 0.7031, MSE = 9.7711e-02
# X | test3 -> R² = -0.0471, MSE = 9.6067e-02
# Y | test3 -> R² = -0.5347, MSE = 1.1768e-01
# Theta | val -> R² = 0.7194, MSE = 9.1953e-02
# X | val -> R² = -0.0656, MSE = 1.0158e-01
# Y | val -> R² = -0.6517, MSE = 1.2278e-01
# Figura salva em: ./results/model_32_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.597732
# Epoch 50 Loss 1.346946
# Epoch 100 Loss 1.330805
# Epoch 150 Loss 1.318496
# Epoch 200 Loss 1.306304
# Epoch 250 Loss 1.300643
# Epoch 300 Loss 1.281446
# Early stopping at epoch 312
# Theta | train1 -> R² = 0.1136, MSE = 2.0275e-01
# X | train1 -> R² = 0.1651, MSE = 8.9758e-02
# Y | train1 -> R² = -1.1370, MSE = 1.7884e-01
# Theta | train2 -> R² = 0.2201, MSE = 1.7744e-01
# X | train2 -> R² = -0.2087, MSE = 1.0172e-01
# Y | train2 -> R² = -0.9085, MSE = 2.0492e-01
# Theta | test1 -> R² = -0.7361, MSE = 3.9963e-01
# X | test1 -> R² = 0.0567, MSE = 9.8510e-02
# Y | test1 -> R² = -1.3941, MSE = 1.9588e-01
# Theta | test2 -> R² = 0.0824, MSE = 2.1690e-01
# X | test2 -> R² = -0.2212, MSE = 1.0038e-01
# Y | test2 -> R² = -0.8879, MSE = 1.9985e-01
# Theta | test3 -> R² = -3.1911, MSE = 1.3795e+00
# X | test3 -> R² = 0.0344, MSE = 8.8590e-02
# Y | test3 -> R² = -1.9932, MSE = 2.2950e-01
# Theta | val -> R² = -1.6211, MSE = 8.5894e-01
# X | val -> R² = 0.0133, MSE = 9.4070e-02
# Y | val -> R² = -1.9458, MSE = 2.1897e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.581230
# Epoch 50 Loss 1.332975
# Epoch 100 Loss 1.323637
# Epoch 150 Loss 1.306590
# Epoch 200 Loss 1.288428
# Epoch 250 Loss 1.277181
# Epoch 300 Loss 1.266965
# Early stopping at epoch 330
# Theta | train1 -> R² = 0.7693, MSE = 5.2776e-02
# X | train1 -> R² = -0.0512, MSE = 1.1301e-01
# Y | train1 -> R² = -0.7413, MSE = 1.4573e-01
# Theta | train2 -> R² = 0.2405, MSE = 1.7280e-01
# X | train2 -> R² = -0.0798, MSE = 9.0875e-02
# Y | train2 -> R² = -0.5959, MSE = 1.7136e-01
# Theta | test1 -> R² = 0.5414, MSE = 1.0557e-01
# X | test1 -> R² = -0.1350, MSE = 1.1853e-01
# Y | test1 -> R² = -0.9193, MSE = 1.5703e-01
# Theta | test2 -> R² = 0.2664, MSE = 1.7341e-01
# X | test2 -> R² = -0.0845, MSE = 8.9142e-02
# Y | test2 -> R² = -0.5622, MSE = 1.6538e-01
# Theta | test3 -> R² = 0.3338, MSE = 2.1927e-01
# X | test3 -> R² = -0.1528, MSE = 1.0577e-01
# Y | test3 -> R² = -1.1589, MSE = 1.6553e-01
# Theta | val -> R² = 0.5447, MSE = 1.4921e-01
# X | val -> R² = -0.1730, MSE = 1.1183e-01
# Y | val -> R² = -1.1854, MSE = 1.6245e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.582933
# Epoch 50 Loss 1.340025
# Epoch 100 Loss 1.327005
# Epoch 150 Loss 1.316803
# Epoch 200 Loss 1.299546
# Epoch 250 Loss 1.329373
# Epoch 300 Loss 1.275820
# Epoch 350 Loss 1.276466
# Early stopping at epoch 361
# Theta | train1 -> R² = 0.6141, MSE = 8.8271e-02
# X | train1 -> R² = -0.1412, MSE = 1.2268e-01
# Y | train1 -> R² = -0.9457, MSE = 1.6283e-01
# Theta | train2 -> R² = 0.5172, MSE = 1.0984e-01
# X | train2 -> R² = -0.1880, MSE = 9.9979e-02
# Y | train2 -> R² = -0.9352, MSE = 2.0780e-01
# Theta | test1 -> R² = 0.1914, MSE = 1.8614e-01
# X | test1 -> R² = -0.1912, MSE = 1.2439e-01
# Y | test1 -> R² = -1.1270, MSE = 1.7402e-01
# Theta | test2 -> R² = 0.4795, MSE = 1.2304e-01
# X | test2 -> R² = -0.1743, MSE = 9.6523e-02
# Y | test2 -> R² = -0.8626, MSE = 1.9718e-01
# Theta | test3 -> R² = -0.0360, MSE = 3.4100e-01
# X | test3 -> R² = -0.3609, MSE = 1.2486e-01
# Y | test3 -> R² = -2.1840, MSE = 2.4413e-01
# Theta | val -> R² = 0.3966, MSE = 1.9773e-01
# X | val -> R² = -0.3554, MSE = 1.2921e-01
# Y | val -> R² = -1.9890, MSE = 2.2219e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.599045
# Epoch 50 Loss 1.345071
# Epoch 100 Loss 1.333832
# Epoch 150 Loss 1.321949
# Epoch 200 Loss 1.299204
# Epoch 250 Loss 1.288555
# Epoch 300 Loss 1.281341
# Early stopping at epoch 331
# Theta | train1 -> R² = 0.8351, MSE = 3.7720e-02
# X | train1 -> R² = -0.1875, MSE = 1.2766e-01
# Y | train1 -> R² = -1.0055, MSE = 1.6784e-01
# Theta | train2 -> R² = 0.0057, MSE = 2.2623e-01
# X | train2 -> R² = -0.2693, MSE = 1.0682e-01
# Y | train2 -> R² = -0.8755, MSE = 2.0139e-01
# Theta | test1 -> R² = 0.8329, MSE = 3.8456e-02
# X | test1 -> R² = -0.2845, MSE = 1.3414e-01
# Y | test1 -> R² = -1.2023, MSE = 1.8018e-01
# Theta | test2 -> R² = 0.0783, MSE = 2.1788e-01
# X | test2 -> R² = -0.2687, MSE = 1.0428e-01
# Y | test2 -> R² = -0.8332, MSE = 1.9407e-01
# Theta | test3 -> R² = 0.3925, MSE = 1.9995e-01
# X | test3 -> R² = -0.3334, MSE = 1.2234e-01
# Y | test3 -> R² = -1.7680, MSE = 2.1223e-01
# Theta | val -> R² = 0.6248, MSE = 1.2297e-01
# X | val -> R² = -0.3521, MSE = 1.2890e-01
# Y | val -> R² = -1.7059, MSE = 2.0114e-01
# Figura salva em: ./results/model_32_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.581036
# Epoch 50 Loss 1.332190
# Epoch 100 Loss 1.321975
# Epoch 150 Loss 1.301109
# Epoch 200 Loss 1.287217
# Epoch 250 Loss 1.270510
# Epoch 300 Loss 1.262928
# Epoch 350 Loss 1.268197
# Epoch 400 Loss 1.265419
# Epoch 450 Loss 1.250443
# Early stopping at epoch 478
# Theta | train1 -> R² = 0.1641, MSE = 1.9120e-01
# X | train1 -> R² = 0.1134, MSE = 9.5314e-02
# Y | train1 -> R² = -1.0419, MSE = 1.7089e-01
# Theta | train2 -> R² = -1.1312, MSE = 4.8491e-01
# X | train2 -> R² = -0.0577, MSE = 8.9014e-02
# Y | train2 -> R² = -1.1831, MSE = 2.3441e-01
# Theta | test1 -> R² = 0.5099, MSE = 1.1282e-01
# X | test1 -> R² = 0.1190, MSE = 9.2005e-02
# Y | test1 -> R² = -1.2315, MSE = 1.8257e-01
# Theta | test2 -> R² = -0.5870, MSE = 3.7513e-01
# X | test2 -> R² = -0.0881, MSE = 8.9437e-02
# Y | test2 -> R² = -1.1312, MSE = 2.2561e-01
# Theta | test3 -> R² = 0.6374, MSE = 1.1935e-01
# X | test3 -> R² = 0.1339, MSE = 7.9468e-02
# Y | test3 -> R² = -1.9605, MSE = 2.2699e-01
# Theta | val -> R² = 0.6198, MSE = 1.2460e-01
# X | val -> R² = 0.1904, MSE = 7.7184e-02
# Y | val -> R² = -2.1114, MSE = 2.3128e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.563771
# Epoch 50 Loss 1.330108
# Epoch 100 Loss 1.319628
# Epoch 150 Loss 1.312463
# Epoch 200 Loss 1.291334
# Epoch 250 Loss 1.274589
# Epoch 300 Loss 1.274743
# Early stopping at epoch 308
# Theta | train1 -> R² = 0.6614, MSE = 7.7459e-02
# X | train1 -> R² = -0.1215, MSE = 1.2057e-01
# Y | train1 -> R² = -1.1890, MSE = 1.8319e-01
# Theta | train2 -> R² = -0.4851, MSE = 3.3789e-01
# X | train2 -> R² = -0.1701, MSE = 9.8474e-02
# Y | train2 -> R² = -1.2070, MSE = 2.3698e-01
# Theta | test1 -> R² = 0.8467, MSE = 3.5282e-02
# X | test1 -> R² = -0.2108, MSE = 1.2644e-01
# Y | test1 -> R² = -1.3929, MSE = 1.9578e-01
# Theta | test2 -> R² = -0.3044, MSE = 3.0833e-01
# X | test2 -> R² = -0.1748, MSE = 9.6563e-02
# Y | test2 -> R² = -1.1626, MSE = 2.2893e-01
# Theta | test3 -> R² = 0.7554, MSE = 8.0505e-02
# X | test3 -> R² = -0.2286, MSE = 1.1272e-01
# Y | test3 -> R² = -2.0666, MSE = 2.3513e-01
# Theta | val -> R² = 0.7000, MSE = 9.8312e-02
# X | val -> R² = -0.2431, MSE = 1.1851e-01
# Y | val -> R² = -1.9301, MSE = 2.1780e-01
# Figura salva em: ./results/model_64_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.642124
# Epoch 50 Loss 1.333905
# Epoch 100 Loss 1.334036
# Epoch 150 Loss 1.341200
# Epoch 200 Loss 1.292818
# Epoch 250 Loss 1.312127
# Epoch 300 Loss 1.286175
# Early stopping at epoch 318
# Theta | train1 -> R² = 0.6737, MSE = 7.4637e-02
# X | train1 -> R² = -0.0249, MSE = 1.1018e-01
# Y | train1 -> R² = -0.9503, MSE = 1.6321e-01
# Theta | train2 -> R² = 0.2893, MSE = 1.6170e-01
# X | train2 -> R² = -0.2507, MSE = 1.0525e-01
# Y | train2 -> R² = -0.8622, MSE = 1.9996e-01
# Theta | test1 -> R² = 0.2107, MSE = 1.8168e-01
# X | test1 -> R² = -0.1029, MSE = 1.1518e-01
# Y | test1 -> R² = -1.1122, MSE = 1.7281e-01
# Theta | test2 -> R² = 0.2429, MSE = 1.7897e-01
# X | test2 -> R² = -0.2561, MSE = 1.0324e-01
# Y | test2 -> R² = -0.8122, MSE = 1.9184e-01
# Theta | test3 -> R² = -0.9944, MSE = 6.5649e-01
# X | test3 -> R² = -0.1760, MSE = 1.0790e-01
# Y | test3 -> R² = -1.7052, MSE = 2.0742e-01
# Theta | val -> R² = -0.2523, MSE = 4.1038e-01
# X | val -> R² = -0.1916, MSE = 1.1360e-01
# Y | val -> R² = -1.6237, MSE = 1.9503e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.593202
# Epoch 50 Loss 1.334573
# Epoch 100 Loss 1.324613
# Epoch 150 Loss 1.313012
# Epoch 200 Loss 1.299426
# Epoch 250 Loss 1.281335
# Epoch 300 Loss 1.271095
# Early stopping at epoch 322
# Theta | train1 -> R² = 0.3441, MSE = 1.5003e-01
# X | train1 -> R² = -0.3459, MSE = 1.4469e-01
# Y | train1 -> R² = -1.0188, MSE = 1.6895e-01
# Theta | train2 -> R² = 0.6179, MSE = 8.6948e-02
# X | train2 -> R² = -0.2949, MSE = 1.0897e-01
# Y | train2 -> R² = -1.0574, MSE = 2.2091e-01
# Theta | test1 -> R² = -0.4286, MSE = 3.2885e-01
# X | test1 -> R² = -0.4403, MSE = 1.5041e-01
# Y | test1 -> R² = -1.2217, MSE = 1.8177e-01
# Theta | test2 -> R² = 0.4985, MSE = 1.1855e-01
# X | test2 -> R² = -0.2949, MSE = 1.0643e-01
# Y | test2 -> R² = -1.0113, MSE = 2.1291e-01
# Theta | test3 -> R² = -1.3328, MSE = 7.6785e-01
# X | test3 -> R² = -0.5063, MSE = 1.3821e-01
# Y | test3 -> R² = -1.7807, MSE = 2.1320e-01
# Theta | val -> R² = -0.4106, MSE = 4.6226e-01
# X | val -> R² = -0.5235, MSE = 1.4524e-01
# Y | val -> R² = -1.6687, MSE = 1.9838e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.526135
# Epoch 50 Loss 1.334267
# Epoch 100 Loss 1.323108
# Epoch 150 Loss 1.307287
# Epoch 200 Loss 1.296336
# Epoch 250 Loss 1.274678
# Epoch 300 Loss 1.315639
# Early stopping at epoch 307
# Theta | train1 -> R² = 0.0872, MSE = 2.0879e-01
# X | train1 -> R² = -0.3051, MSE = 1.4031e-01
# Y | train1 -> R² = -1.0183, MSE = 1.6891e-01
# Theta | train2 -> R² = 0.4247, MSE = 1.3090e-01
# X | train2 -> R² = -0.4512, MSE = 1.2213e-01
# Y | train2 -> R² = -1.0573, MSE = 2.2090e-01
# Theta | test1 -> R² = -0.7419, MSE = 4.0096e-01
# X | test1 -> R² = -0.4068, MSE = 1.4691e-01
# Y | test1 -> R² = -1.2065, MSE = 1.8052e-01
# Theta | test2 -> R² = 0.2757, MSE = 1.7121e-01
# X | test2 -> R² = -0.4593, MSE = 1.1995e-01
# Y | test2 -> R² = -1.0142, MSE = 2.1322e-01
# Theta | test3 -> R² = -2.0370, MSE = 9.9967e-01
# X | test3 -> R² = -0.5478, MSE = 1.4201e-01
# Y | test3 -> R² = -1.7273, MSE = 2.0911e-01
# Theta | val -> R² = -0.9216, MSE = 6.2972e-01
# X | val -> R² = -0.5545, MSE = 1.4820e-01
# Y | val -> R² = -1.6291, MSE = 1.9543e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.589294
# Epoch 50 Loss 1.330625
# Epoch 100 Loss 1.315269
# Epoch 150 Loss 1.295413
# Epoch 200 Loss 1.284618
# Epoch 250 Loss 1.279276
# Epoch 300 Loss 1.259718
# Early stopping at epoch 310
# Theta | train1 -> R² = 0.3774, MSE = 1.4241e-01
# X | train1 -> R² = -0.1898, MSE = 1.2791e-01
# Y | train1 -> R² = -0.7650, MSE = 1.4771e-01
# Theta | train2 -> R² = -0.9702, MSE = 4.4827e-01
# X | train2 -> R² = -0.0853, MSE = 9.1336e-02
# Y | train2 -> R² = -0.8622, MSE = 1.9995e-01
# Theta | test1 -> R² = 0.6454, MSE = 8.1635e-02
# X | test1 -> R² = -0.2747, MSE = 1.3311e-01
# Y | test1 -> R² = -0.9306, MSE = 1.5795e-01
# Theta | test2 -> R² = -0.7740, MSE = 4.1932e-01
# X | test2 -> R² = -0.0881, MSE = 8.9433e-02
# Y | test2 -> R² = -0.8223, MSE = 1.9291e-01
# Theta | test3 -> R² = 0.6679, MSE = 1.0932e-01
# X | test3 -> R² = -0.2814, MSE = 1.1756e-01
# Y | test3 -> R² = -1.1610, MSE = 1.6569e-01
# Theta | val -> R² = 0.5687, MSE = 1.4134e-01
# X | val -> R² = -0.2970, MSE = 1.2365e-01
# Y | val -> R² = -1.1254, MSE = 1.5799e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.593020
# Epoch 50 Loss 1.333047
# Epoch 100 Loss 1.326327
# Epoch 150 Loss 1.310306
# Epoch 200 Loss 1.352412
# Epoch 250 Loss 1.287784
# Epoch 300 Loss 1.282326
# Early stopping at epoch 305
# Theta | train1 -> R² = -0.9986, MSE = 4.5716e-01
# X | train1 -> R² = -0.4349, MSE = 1.5425e-01
# Y | train1 -> R² = -1.4264, MSE = 2.0306e-01
# Theta | train2 -> R² = -0.7550, MSE = 3.9930e-01
# X | train2 -> R² = -0.4807, MSE = 1.2461e-01
# Y | train2 -> R² = -1.4807, MSE = 2.6637e-01
# Theta | test1 -> R² = -1.9856, MSE = 6.8725e-01
# X | test1 -> R² = -0.5427, MSE = 1.6110e-01
# Y | test1 -> R² = -1.6338, MSE = 2.1549e-01
# Theta | test2 -> R² = -0.9408, MSE = 4.5876e-01
# X | test2 -> R² = -0.4896, MSE = 1.2244e-01
# Y | test2 -> R² = -1.4327, MSE = 2.5752e-01
# Theta | test3 -> R² = -5.2975, MSE = 2.0729e+00
# X | test3 -> R² = -0.6416, MSE = 1.5061e-01
# Y | test3 -> R² = -2.3471, MSE = 2.5663e-01
# Theta | val -> R² = -3.4373, MSE = 1.4541e+00
# X | val -> R² = -0.6696, MSE = 1.5917e-01
# Y | val -> R² = -2.1851, MSE = 2.3676e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.596033
# Epoch 50 Loss 1.333838
# Epoch 100 Loss 1.335081
# Epoch 150 Loss 1.330882
# Epoch 200 Loss 1.341680
# Epoch 250 Loss 1.313738
# Epoch 300 Loss 1.275846
# Early stopping at epoch 305
# Theta | train1 -> R² = 0.6120, MSE = 8.8745e-02
# X | train1 -> R² = 0.1859, MSE = 8.7517e-02
# Y | train1 -> R² = -0.6967, MSE = 1.4200e-01
# Theta | train2 -> R² = 0.1901, MSE = 1.8427e-01
# X | train2 -> R² = -0.3532, MSE = 1.1388e-01
# Y | train2 -> R² = -0.6770, MSE = 1.8007e-01
# Theta | test1 -> R² = 0.2435, MSE = 1.7414e-01
# X | test1 -> R² = 0.0660, MSE = 9.7541e-02
# Y | test1 -> R² = -0.8873, MSE = 1.5441e-01
# Theta | test2 -> R² = 0.1563, MSE = 1.9944e-01
# X | test2 -> R² = -0.3721, MSE = 1.1278e-01
# Y | test2 -> R² = -0.6525, MSE = 1.7494e-01
# Theta | test3 -> R² = -0.7756, MSE = 5.8446e-01
# X | test3 -> R² = 0.0595, MSE = 8.6290e-02
# Y | test3 -> R² = -1.0689, MSE = 1.5863e-01
# Theta | val -> R² = -0.1868, MSE = 3.8891e-01
# X | val -> R² = 0.0426, MSE = 9.1271e-02
# Y | val -> R² = -1.0699, MSE = 1.5386e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.593838
# Epoch 50 Loss 1.331333
# Epoch 100 Loss 1.321044
# Epoch 150 Loss 1.328489
# Epoch 200 Loss 1.321387
# Epoch 250 Loss 1.297099
# Epoch 300 Loss 1.273187
# Early stopping at epoch 306
# Theta | train1 -> R² = -0.3639, MSE = 3.1196e-01
# X | train1 -> R² = -0.0559, MSE = 1.1352e-01
# Y | train1 -> R² = -1.1240, MSE = 1.7775e-01
# Theta | train2 -> R² = 0.2028, MSE = 1.8138e-01
# X | train2 -> R² = -0.2284, MSE = 1.0338e-01
# Y | train2 -> R² = -1.1336, MSE = 2.2910e-01
# Theta | test1 -> R² = -1.1330, MSE = 4.9098e-01
# X | test1 -> R² = -0.1481, MSE = 1.1990e-01
# Y | test1 -> R² = -1.3295, MSE = 1.9059e-01
# Theta | test2 -> R² = 0.0412, MSE = 2.2665e-01
# X | test2 -> R² = -0.2417, MSE = 1.0206e-01
# Y | test2 -> R² = -1.0980, MSE = 2.2210e-01
# Theta | test3 -> R² = -2.9364, MSE = 1.2957e+00
# X | test3 -> R² = -0.1630, MSE = 1.0670e-01
# Y | test3 -> R² = -1.7681, MSE = 2.1224e-01
# Theta | val -> R² = -1.5879, MSE = 8.4805e-01
# X | val -> R² = -0.2209, MSE = 1.1640e-01
# Y | val -> R² = -1.6956, MSE = 2.0037e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.585875
# Epoch 50 Loss 1.332717
# Epoch 100 Loss 1.324307
# Epoch 150 Loss 1.314078
# Epoch 200 Loss 1.291814
# Epoch 250 Loss 1.277976
# Epoch 300 Loss 1.275682
# Early stopping at epoch 327
# Theta | train1 -> R² = 0.7816, MSE = 4.9946e-02
# X | train1 -> R² = 0.0741, MSE = 9.9541e-02
# Y | train1 -> R² = -1.0583, MSE = 1.7226e-01
# Theta | train2 -> R² = -0.0045, MSE = 2.2855e-01
# X | train2 -> R² = -0.0591, MSE = 8.9130e-02
# Y | train2 -> R² = -0.9427, MSE = 2.0860e-01
# Theta | test1 -> R² = 0.7851, MSE = 4.9458e-02
# X | test1 -> R² = 0.0229, MSE = 1.0204e-01
# Y | test1 -> R² = -1.2566, MSE = 1.8463e-01
# Theta | test2 -> R² = 0.0870, MSE = 2.1582e-01
# X | test2 -> R² = -0.0690, MSE = 8.7867e-02
# Y | test2 -> R² = -0.8951, MSE = 2.0062e-01
# Theta | test3 -> R² = 0.6355, MSE = 1.1997e-01
# X | test3 -> R² = -0.0405, MSE = 9.5462e-02
# Y | test3 -> R² = -1.9132, MSE = 2.2337e-01
# Theta | val -> R² = 0.7200, MSE = 9.1768e-02
# X | val -> R² = -0.0723, MSE = 1.0223e-01
# Y | val -> R² = -1.8042, MSE = 2.0845e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.577146
# Epoch 50 Loss 1.332482
# Epoch 100 Loss 1.336349
# Epoch 150 Loss 1.333066
# Epoch 200 Loss 1.310249
# Epoch 250 Loss 1.329232
# Epoch 300 Loss 1.291838
# Epoch 350 Loss 1.297812
# Epoch 400 Loss 1.283083
# Early stopping at epoch 446
# Theta | train1 -> R² = -3.6822, MSE = 1.0710e+00
# X | train1 -> R² = 0.0796, MSE = 9.8949e-02
# Y | train1 -> R² = -1.8252, MSE = 2.3644e-01
# Theta | train2 -> R² = -1.5408, MSE = 5.7811e-01
# X | train2 -> R² = -0.2936, MSE = 1.0886e-01
# Y | train2 -> R² = -1.8860, MSE = 3.0989e-01
# Theta | test1 -> R² = -4.2627, MSE = 1.2114e+00
# X | test1 -> R² = 0.0376, MSE = 1.0050e-01
# Y | test1 -> R² = -2.0957, MSE = 2.5328e-01
# Theta | test2 -> R² = -2.0115, MSE = 7.1186e-01
# X | test2 -> R² = -0.3178, MSE = 1.0832e-01
# Y | test2 -> R² = -1.7999, MSE = 2.9640e-01
# Theta | test3 -> R² = -9.4861, MSE = 3.4516e+00
# X | test3 -> R² = -0.1983, MSE = 1.0994e-01
# Y | test3 -> R² = -3.6436, MSE = 3.5605e-01
# Theta | val -> R² = -5.7268, MSE = 2.2044e+00
# X | val -> R² = -0.1275, MSE = 1.0749e-01
# Y | val -> R² = -3.3941, MSE = 3.2663e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.487313
# Epoch 50 Loss 1.333615
# Epoch 100 Loss 1.337895
# Epoch 150 Loss 1.316020
# Epoch 200 Loss 1.324139
# Epoch 250 Loss 1.341362
# Epoch 300 Loss 1.301140
# Early stopping at epoch 326
# Theta | train1 -> R² = 0.7221, MSE = 6.3577e-02
# X | train1 -> R² = 0.0841, MSE = 9.8462e-02
# Y | train1 -> R² = -0.7313, MSE = 1.4489e-01
# Theta | train2 -> R² = 0.2802, MSE = 1.6376e-01
# X | train2 -> R² = -0.1125, MSE = 9.3627e-02
# Y | train2 -> R² = -0.7714, MSE = 1.9021e-01
# Theta | test1 -> R² = 0.5523, MSE = 1.0305e-01
# X | test1 -> R² = 0.0113, MSE = 1.0325e-01
# Y | test1 -> R² = -0.9324, MSE = 1.5810e-01
# Theta | test2 -> R² = 0.2887, MSE = 1.6815e-01
# X | test2 -> R² = -0.1236, MSE = 9.2357e-02
# Y | test2 -> R² = -0.7402, MSE = 1.8422e-01
# Theta | test3 -> R² = 0.1524, MSE = 2.7900e-01
# X | test3 -> R² = -0.0226, MSE = 9.3819e-02
# Y | test3 -> R² = -1.2172, MSE = 1.7000e-01
# Theta | val -> R² = 0.4216, MSE = 1.8956e-01
# X | val -> R² = -0.0252, MSE = 9.7733e-02
# Y | val -> R² = -1.1514, MSE = 1.5992e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.612083
# Epoch 50 Loss 1.330340
# Epoch 100 Loss 1.325960
# Epoch 150 Loss 1.309359
# Epoch 200 Loss 1.319355
# Epoch 250 Loss 1.317517
# Epoch 300 Loss 1.295408
# Epoch 350 Loss 1.275078
# Epoch 400 Loss 1.268936
# Epoch 450 Loss 1.262501
# Early stopping at epoch 466
# Theta | train1 -> R² = 0.7008, MSE = 6.8445e-02
# X | train1 -> R² = 0.1090, MSE = 9.5790e-02
# Y | train1 -> R² = -0.6813, MSE = 1.4071e-01
# Theta | train2 -> R² = -0.5210, MSE = 3.4606e-01
# X | train2 -> R² = 0.0456, MSE = 8.0314e-02
# Y | train2 -> R² = -1.3593, MSE = 2.5333e-01
# Theta | test1 -> R² = 0.8035, MSE = 4.5229e-02
# X | test1 -> R² = 0.0484, MSE = 9.9380e-02
# Y | test1 -> R² = -0.8928, MSE = 1.5486e-01
# Theta | test2 -> R² = -0.2355, MSE = 2.9204e-01
# X | test2 -> R² = 0.0446, MSE = 7.8531e-02
# Y | test2 -> R² = -1.2769, MSE = 2.4103e-01
# Theta | test3 -> R² = 0.5683, MSE = 1.4209e-01
# X | test3 -> R² = -0.1445, MSE = 1.0501e-01
# Y | test3 -> R² = -1.6170, MSE = 2.0065e-01
# Theta | val -> R² = 0.1863, MSE = 2.6665e-01
# X | val -> R² = -0.1442, MSE = 1.0908e-01
# Y | val -> R² = -1.4604, MSE = 1.8289e-01
# Figura salva em: ./results/model_128_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.560804
# Epoch 50 Loss 1.331451
# Epoch 100 Loss 1.323998
# Epoch 150 Loss 1.315213
# Epoch 200 Loss 1.325168
# Epoch 250 Loss 1.312860
# Epoch 300 Loss 1.280986
# Epoch 350 Loss 1.270463
# Epoch 400 Loss 1.291779
# Epoch 450 Loss 1.266245
# Early stopping at epoch 487
# Theta | train1 -> R² = 0.7645, MSE = 5.3875e-02
# X | train1 -> R² = 0.2462, MSE = 8.1041e-02
# Y | train1 -> R² = -0.7827, MSE = 1.4919e-01
# Theta | train2 -> R² = 0.6839, MSE = 7.1927e-02
# X | train2 -> R² = -0.0542, MSE = 8.8715e-02
# Y | train2 -> R² = -1.0779, MSE = 2.2312e-01
# Theta | test1 -> R² = 0.0830, MSE = 2.1109e-01
# X | test1 -> R² = 0.1461, MSE = 8.9178e-02
# Y | test1 -> R² = -1.1029, MSE = 1.7205e-01
# Theta | test2 -> R² = 0.7296, MSE = 6.3926e-02
# X | test2 -> R² = -0.0746, MSE = 8.8329e-02
# Y | test2 -> R² = -1.0384, MSE = 2.1579e-01
# Theta | test3 -> R² = -2.9440, MSE = 1.2982e+00
# X | test3 -> R² = -0.0058, MSE = 9.2279e-02
# Y | test3 -> R² = -1.7827, MSE = 2.1336e-01
# Theta | val -> R² = -1.7503, MSE = 9.0128e-01
# X | val -> R² = -0.0183, MSE = 9.7082e-02
# Y | val -> R² = -1.8320, MSE = 2.1051e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.683041
# Epoch 50 Loss 1.329846
# Epoch 100 Loss 1.331295
# Epoch 150 Loss 1.321023
# Epoch 200 Loss 1.285462
# Epoch 250 Loss 1.277658
# Epoch 300 Loss 1.287246
# Early stopping at epoch 320
# Theta | train1 -> R² = 0.7921, MSE = 4.7561e-02
# X | train1 -> R² = -0.0595, MSE = 1.1390e-01
# Y | train1 -> R² = -0.9729, MSE = 1.6511e-01
# Theta | train2 -> R² = 0.4728, MSE = 1.1995e-01
# X | train2 -> R² = -0.0683, MSE = 8.9907e-02
# Y | train2 -> R² = -1.1162, MSE = 2.2723e-01
# Theta | test1 -> R² = 0.5714, MSE = 9.8650e-02
# X | test1 -> R² = -0.1120, MSE = 1.1613e-01
# Y | test1 -> R² = -1.1611, MSE = 1.7681e-01
# Theta | test2 -> R² = 0.4918, MSE = 1.2013e-01
# X | test2 -> R² = -0.0732, MSE = 8.8212e-02
# Y | test2 -> R² = -1.0693, MSE = 2.1906e-01
# Theta | test3 -> R² = 0.2529, MSE = 2.4593e-01
# X | test3 -> R² = -0.1582, MSE = 1.0627e-01
# ...
# X | test2 -> R² = -0.1659, MSE = 9.5830e-02
# Y | test2 -> R² = -1.2186, MSE = 2.3486e-01
# Theta | test3 -> R² = -3.0670, MSE = 1.3387e+00
# X | test3 -> R² = -0.9839, MSE = 1.8202e-01
# Y | test3 -> R² = -2.5276, MSE = 2.7048e-01
# Theta | val -> R² = -1.3113, MSE = 7.5741e-01
# X | val -> R² = -0.9889, MSE = 1.8961e-01
# Y | val -> R² = -2.4054, MSE = 2.5314e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.579235
# Epoch 50 Loss 1.327398
# Epoch 100 Loss 1.309268
# Epoch 150 Loss 1.306646
# Epoch 200 Loss 1.310292
# Epoch 250 Loss 1.286317
# Epoch 300 Loss 1.288003
# Early stopping at epoch 315
# Theta | train1 -> R² = 0.5625, MSE = 1.0007e-01
# X | train1 -> R² = 0.1210, MSE = 9.4502e-02
# Y | train1 -> R² = -0.7162, MSE = 1.4362e-01
# Theta | train2 -> R² = -1.2748, MSE = 5.1757e-01
# X | train2 -> R² = 0.0839, MSE = 7.7091e-02
# Y | train2 -> R² = -0.8033, MSE = 1.9363e-01
# Theta | test1 -> R² = 0.8154, MSE = 4.2496e-02
# X | test1 -> R² = 0.0701, MSE = 9.7112e-02
# Y | test1 -> R² = -0.9138, MSE = 1.5658e-01
# Theta | test2 -> R² = -0.9291, MSE = 4.5601e-01
# X | test2 -> R² = 0.0899, MSE = 7.4804e-02
# Y | test2 -> R² = -0.7512, MSE = 1.8538e-01
# Theta | test3 -> R² = 0.4714, MSE = 1.7398e-01
# X | test3 -> R² = -0.2979, MSE = 1.1908e-01
# Y | test3 -> R² = -1.1124, MSE = 1.6196e-01
# Theta | val -> R² = 0.0992, MSE = 2.9519e-01
# X | val -> R² = -0.1004, MSE = 1.0490e-01
# Y | val -> R² = -1.1788, MSE = 1.6195e-01
# Figura salva em: ./results/model_128_64_32_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.590190
# Epoch 50 Loss 1.326888
# Epoch 100 Loss 1.297603
# Epoch 150 Loss 1.326366
# Epoch 200 Loss 1.319524
# Epoch 250 Loss 1.293794
# Epoch 300 Loss 1.289549
# Epoch 350 Loss 1.304957
# Epoch 400 Loss 1.275375
# Epoch 450 Loss 1.273529
# Epoch 500 Loss 1.271410
# Epoch 550 Loss 1.298399
# Epoch 600 Loss 1.261531
# Early stopping at epoch 650
# Theta | train1 -> R² = -0.2639, MSE = 2.8909e-01
# X | train1 -> R² = 0.0167, MSE = 1.0571e-01
# Y | train1 -> R² = -0.4359, MSE = 1.2017e-01
# Theta | train2 -> R² = 0.7550, MSE = 5.5746e-02
# X | train2 -> R² = -0.1753, MSE = 9.8904e-02
# Y | train2 -> R² = -0.9031, MSE = 2.0435e-01
# Theta | test1 -> R² = 0.3048, MSE = 1.6004e-01
# X | test1 -> R² = 0.0004, MSE = 1.0439e-01
# Y | test1 -> R² = -0.5160, MSE = 1.2404e-01
# Theta | test2 -> R² = 0.5524, MSE = 1.0581e-01
# X | test2 -> R² = -0.2274, MSE = 1.0089e-01
# Y | test2 -> R² = -0.9064, MSE = 2.0181e-01
# Theta | test3 -> R² = 0.1742, MSE = 2.7182e-01
# X | test3 -> R² = -0.1230, MSE = 1.0304e-01
# Y | test3 -> R² = -2.2432, MSE = 2.4867e-01
# Theta | val -> R² = 0.3953, MSE = 1.9817e-01
# X | val -> R² = 0.1810, MSE = 7.8077e-02
# Y | val -> R² = -2.2423, MSE = 2.4101e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.579511
# Epoch 50 Loss 1.336592
# Epoch 100 Loss 1.326094
# Epoch 150 Loss 1.282290
# Epoch 200 Loss 1.272922
# Epoch 250 Loss 1.281497
# Epoch 300 Loss 1.279122
# Early stopping at epoch 311
# Theta | train1 -> R² = -1.8112, MSE = 6.4302e-01
# X | train1 -> R² = 0.4523, MSE = 5.8878e-02
# Y | train1 -> R² = -0.7737, MSE = 1.4844e-01
# Theta | train2 -> R² = -3.9845, MSE = 1.1341e+00
# X | train2 -> R² = -0.0372, MSE = 8.7290e-02
# Y | train2 -> R² = -0.7225, MSE = 1.8496e-01
# Theta | test1 -> R² = -0.8012, MSE = 4.1461e-01
# X | test1 -> R² = 0.3844, MSE = 6.4284e-02
# Y | test1 -> R² = -1.0234, MSE = 1.6554e-01
# Theta | test2 -> R² = -3.2592, MSE = 1.0068e+00
# X | test2 -> R² = -0.0355, MSE = 8.5114e-02
# Y | test2 -> R² = -0.6924, MSE = 1.7916e-01
# Theta | test3 -> R² = -0.4108, MSE = 4.6436e-01
# X | test3 -> R² = -0.3986, MSE = 1.2832e-01
# Y | test3 -> R² = -1.5864, MSE = 1.9831e-01
# Theta | val -> R² = -1.2952, MSE = 7.5214e-01
# X | val -> R² = -0.0120, MSE = 9.6477e-02
# Y | val -> R² = -1.5847, MSE = 1.9213e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.555774
# Epoch 50 Loss 1.330874
# Epoch 100 Loss 1.315768
# Epoch 150 Loss 1.306705
# Epoch 200 Loss 1.305813
# Epoch 250 Loss 1.311278
# Epoch 300 Loss 1.275045
# Early stopping at epoch 309
# Theta | train1 -> R² = -0.0135, MSE = 2.3182e-01
# X | train1 -> R² = -0.2019, MSE = 1.2921e-01
# Y | train1 -> R² = -0.5736, MSE = 1.3169e-01
# Theta | train2 -> R² = -0.0315, MSE = 2.3469e-01
# X | train2 -> R² = -0.2738, MSE = 1.0720e-01
# Y | train2 -> R² = -0.6399, MSE = 1.7608e-01
# Theta | test1 -> R² = -0.4561, MSE = 3.3517e-01
# X | test1 -> R² = -0.4690, MSE = 1.5341e-01
# Y | test1 -> R² = -0.7894, MSE = 1.4640e-01
# Theta | test2 -> R² = -0.1147, MSE = 2.6350e-01
# X | test2 -> R² = -0.2731, MSE = 1.0464e-01
# Y | test2 -> R² = -0.6052, MSE = 1.6992e-01
# Theta | test3 -> R² = -2.1457, MSE = 1.0354e+00
# X | test3 -> R² = -0.5887, MSE = 1.4576e-01
# Y | test3 -> R² = -1.9463, MSE = 2.2591e-01
# Theta | val -> R² = -0.7015, MSE = 5.5759e-01
# X | val -> R² = -0.5766, MSE = 1.5030e-01
# Y | val -> R² = -1.9601, MSE = 2.2003e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.523568
# Epoch 50 Loss 1.458101
# Epoch 100 Loss 1.348276
# Epoch 150 Loss 1.340694
# Epoch 200 Loss 1.339319
# Epoch 250 Loss 1.334301
# Epoch 300 Loss 1.379978
# Epoch 350 Loss 1.331980
# Epoch 400 Loss 1.334156
# Epoch 450 Loss 1.331614
# Epoch 500 Loss 1.345407
# Early stopping at epoch 535
# Theta | train1 -> R² = -1.1235, MSE = 4.8572e-01
# X | train1 -> R² = -0.1268, MSE = 1.2114e-01
# Y | train1 -> R² = -1.0365, MSE = 1.7044e-01
# Theta | train2 -> R² = 0.3192, MSE = 1.5490e-01
# X | train2 -> R² = -0.1945, MSE = 1.0053e-01
# Y | train2 -> R² = -1.2139, MSE = 2.3772e-01
# Theta | test1 -> R² = -1.0331, MSE = 4.6800e-01
# X | test1 -> R² = -0.3186, MSE = 1.3770e-01
# Y | test1 -> R² = -1.2966, MSE = 1.8790e-01
# Theta | test2 -> R² = -0.1177, MSE = 2.6421e-01
# X | test2 -> R² = -0.2082, MSE = 9.9304e-02
# Y | test2 -> R² = -1.1932, MSE = 2.3217e-01
# Theta | test3 -> R² = 0.2148, MSE = 2.5846e-01
# X | test3 -> R² = -0.8662, MSE = 1.7122e-01
# Y | test3 -> R² = -3.1950, MSE = 3.2165e-01
# Theta | val -> R² = 0.4589, MSE = 1.7730e-01
# X | val -> R² = -1.0326, MSE = 1.9377e-01
# Y | val -> R² = -3.0038, MSE = 2.9762e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.591916
# Epoch 50 Loss 1.469976
# Epoch 100 Loss 1.479506
# Epoch 150 Loss 1.470487
# Epoch 200 Loss 1.470690
# Epoch 250 Loss 1.470581
# Epoch 300 Loss 1.472681
# Epoch 350 Loss 1.476259
# Epoch 400 Loss 1.401720
# Epoch 450 Loss 1.543448
# Epoch 500 Loss 1.385686
# Epoch 550 Loss 1.350639
# Epoch 600 Loss 1.353349
# Epoch 650 Loss 1.341934
# Epoch 700 Loss 1.338963
# Epoch 750 Loss 1.337316
# Epoch 800 Loss 1.350211
# Epoch 850 Loss 1.363704
# Early stopping at epoch 873
# Theta | train1 -> R² = -1.5877, MSE = 5.9191e-01
# X | train1 -> R² = -0.2642, MSE = 1.3591e-01
# Y | train1 -> R² = -1.0227, MSE = 1.6927e-01
# Theta | train2 -> R² = 0.3048, MSE = 1.5818e-01
# X | train2 -> R² = -0.2146, MSE = 1.0222e-01
# Y | train2 -> R² = -1.1988, MSE = 2.3610e-01
# Theta | test1 -> R² = -1.9061, MSE = 6.6896e-01
# X | test1 -> R² = -0.4395, MSE = 1.5032e-01
# Y | test1 -> R² = -1.1496, MSE = 1.7587e-01
# Theta | test2 -> R² = 0.1379, MSE = 2.0378e-01
# X | test2 -> R² = -0.2648, MSE = 1.0396e-01
# Y | test2 -> R² = -1.1708, MSE = 2.2980e-01
# Theta | test3 -> R² = -0.2111, MSE = 3.9865e-01
# X | test3 -> R² = -1.5550, MSE = 2.3442e-01
# Y | test3 -> R² = -0.9139, MSE = 1.4675e-01
# Theta | val -> R² = 0.4051, MSE = 1.9495e-01
# X | val -> R² = -0.7195, MSE = 1.6392e-01
# Y | val -> R² = -0.8984, MSE = 1.4112e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.593596
# Epoch 50 Loss 1.403885
# Epoch 100 Loss 1.390083
# Epoch 150 Loss 1.383529
# Epoch 200 Loss 1.379016
# Epoch 250 Loss 1.369720
# Epoch 300 Loss 1.371229
# Early stopping at epoch 323
# Theta | train1 -> R² = -0.2822, MSE = 2.9328e-01
# X | train1 -> R² = -1.6496, MSE = 2.8484e-01
# Y | train1 -> R² = -0.4621, MSE = 1.2236e-01
# Theta | train2 -> R² = -1.1896, MSE = 4.9819e-01
# X | train2 -> R² = -1.5917, MSE = 2.1811e-01
# Y | train2 -> R² = -0.5772, MSE = 1.6936e-01
# Theta | test1 -> R² = -0.1385, MSE = 2.6207e-01
# X | test1 -> R² = -1.8427, MSE = 2.9687e-01
# Y | test1 -> R² = -0.6160, MSE = 1.3221e-01
# Theta | test2 -> R² = -1.2058, MSE = 5.2140e-01
# X | test2 -> R² = -1.6467, MSE = 2.1754e-01
# Y | test2 -> R² = -0.5372, MSE = 1.6272e-01
# Theta | test3 -> R² = -2.3097, MSE = 1.0894e+00
# X | test3 -> R² = -3.1476, MSE = 3.8054e-01
# Y | test3 -> R² = -0.5481, MSE = 1.1870e-01
# Theta | val -> R² = -2.0089, MSE = 9.8602e-01
# X | val -> R² = -2.9113, MSE = 3.7288e-01
# Y | val -> R² = -0.6795, MSE = 1.2485e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.553480
# Epoch 50 Loss 1.471453
# Epoch 100 Loss 1.470611
# Epoch 150 Loss 1.470504
# Epoch 200 Loss 1.467481
# Epoch 250 Loss 1.453640
# Epoch 300 Loss 1.414071
# Early stopping at epoch 312
# Theta | train1 -> R² = 0.2245, MSE = 1.7739e-01
# X | train1 -> R² = -0.9169, MSE = 2.0607e-01
# Y | train1 -> R² = -1.9748, MSE = 2.4896e-01
# Theta | train2 -> R² = -3.4660, MSE = 1.0161e+00
# X | train2 -> R² = -0.6452, MSE = 1.3845e-01
# Y | train2 -> R² = -1.7564, MSE = 2.9598e-01
# Theta | test1 -> R² = 0.1783, MSE = 1.8916e-01
# X | test1 -> R² = -1.3185, MSE = 2.4212e-01
# Y | test1 -> R² = -2.3806, MSE = 2.7659e-01
# Theta | test2 -> R² = -3.2855, MSE = 1.0130e+00
# X | test2 -> R² = -0.7495, MSE = 1.4380e-01
# Y | test2 -> R² = -1.7872, MSE = 2.9505e-01
# Theta | test3 -> R² = -0.8568, MSE = 6.1119e-01
# X | test3 -> R² = -5.3333, MSE = 5.8108e-01
# Y | test3 -> R² = -7.4059, MSE = 6.4452e-01
# Theta | val -> R² = -1.3711, MSE = 7.7700e-01
# X | val -> R² = -6.2222, MSE = 6.8852e-01
# Y | val -> R² = -7.1365, MSE = 6.0482e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.601992
# Epoch 50 Loss 1.456792
# Epoch 100 Loss 1.474361
# Epoch 150 Loss 1.470670
# Epoch 200 Loss 1.470633
# Epoch 250 Loss 1.470626
# Epoch 300 Loss 1.470601
# Early stopping at epoch 308
# Theta | train1 -> R² = -0.2292, MSE = 2.8116e-01
# X | train1 -> R² = -0.6729, MSE = 1.7985e-01
# Y | train1 -> R² = -1.3843, MSE = 1.9954e-01
# Theta | train2 -> R² = -1.2616, MSE = 5.1456e-01
# X | train2 -> R² = -0.4720, MSE = 1.2387e-01
# Y | train2 -> R² = -1.4330, MSE = 2.6125e-01
# Theta | test1 -> R² = -0.1428, MSE = 2.6306e-01
# X | test1 -> R² = -1.0129, MSE = 2.1021e-01
# Y | test1 -> R² = -1.6874, MSE = 2.1987e-01
# Theta | test2 -> R² = -1.2730, MSE = 5.3729e-01
# X | test2 -> R² = -0.5600, MSE = 1.2822e-01
# Y | test2 -> R² = -1.4455, MSE = 2.5888e-01
# Theta | test3 -> R² = -2.0527, MSE = 1.0048e+00
# X | test3 -> R² = -1.9371, MSE = 2.6947e-01
# Y | test3 -> R² = 0.2968, MSE = 5.3919e-02
# Theta | val -> R² = -1.8566, MSE = 9.3610e-01
# X | val -> R² = -0.8788, MSE = 1.7912e-01
# Y | val -> R² = 0.1579, MSE = 6.2599e-02
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.601082
# Epoch 50 Loss 1.470906
# Epoch 100 Loss 1.470610
# Epoch 150 Loss 1.470403
# Epoch 200 Loss 1.470623
# Epoch 250 Loss 1.515303
# Epoch 300 Loss 1.481461
# Epoch 350 Loss 1.470754
# Epoch 400 Loss 1.470639
# Epoch 450 Loss 1.470639
# Epoch 500 Loss 1.470639
# Epoch 550 Loss 1.470639
# Early stopping at epoch 592
# Theta | train1 -> R² = -1.2250, MSE = 5.0895e-01
# X | train1 -> R² = -0.4570, MSE = 1.5663e-01
# Y | train1 -> R² = -1.3807, MSE = 1.9924e-01
# Theta | train2 -> R² = -0.1752, MSE = 2.6739e-01
# X | train2 -> R² = -0.1292, MSE = 9.5029e-02
# Y | train2 -> R² = -1.0879, MSE = 2.2419e-01
# Theta | test1 -> R² = -0.8023, MSE = 4.1488e-01
# X | test1 -> R² = -0.7038, MSE = 1.7793e-01
# Y | test1 -> R² = -1.7745, MSE = 2.2700e-01
# Theta | test2 -> R² = -0.3257, MSE = 3.1336e-01
# X | test2 -> R² = -0.1911, MSE = 9.7898e-02
# Y | test2 -> R² = -1.1161, MSE = 2.2401e-01
# Theta | test3 -> R² = -12.8317, MSE = 4.5528e+00
# X | test3 -> R² = -6.8718, MSE = 7.2224e-01
# Y | test3 -> R² = -7.9488, MSE = 6.8614e-01
# Theta | val -> R² = -7.2112, MSE = 2.6908e+00
# X | val -> R² = -5.4323, MSE = 6.1321e-01
# Y | val -> R² = -7.0316, MSE = 5.9702e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.573085
# Epoch 50 Loss 1.407188
# Epoch 100 Loss 1.337798
# Epoch 150 Loss 1.329024
# Epoch 200 Loss 1.329008
# Epoch 250 Loss 1.327963
# Epoch 300 Loss 1.325451
# Epoch 350 Loss 1.328226
# Early stopping at epoch 383
# Theta | train1 -> R² = 0.4966, MSE = 1.1515e-01
# X | train1 -> R² = -0.2534, MSE = 1.3474e-01
# Y | train1 -> R² = -1.2595, MSE = 1.8909e-01
# Theta | train2 -> R² = 0.4205, MSE = 1.3184e-01
# X | train2 -> R² = -0.1436, MSE = 9.6237e-02
# Y | train2 -> R² = -1.1678, MSE = 2.3278e-01
# Theta | test1 -> R² = 0.6860, MSE = 7.2274e-02
# X | test1 -> R² = -0.4392, MSE = 1.5029e-01
# Y | test1 -> R² = -1.4002, MSE = 1.9637e-01
# Theta | test2 -> R² = 0.2746, MSE = 1.7146e-01
# X | test2 -> R² = -0.1820, MSE = 9.7156e-02
# Y | test2 -> R² = -1.1756, MSE = 2.3031e-01
# Theta | test3 -> R² = -7.6687, MSE = 2.8534e+00
# X | test3 -> R² = -0.8345, MSE = 1.6831e-01
# Y | test3 -> R² = -3.5272, MSE = 3.4712e-01
# Theta | val -> R² = -9.0523, MSE = 3.2942e+00
# X | val -> R² = -0.9527, MSE = 1.8616e-01
# Y | val -> R² = -3.8479, MSE = 3.6036e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.532244
# Epoch 50 Loss 1.337565
# Epoch 100 Loss 1.323364
# Epoch 150 Loss 1.317106
# Epoch 200 Loss 1.314166
# Epoch 250 Loss 1.319224
# Epoch 300 Loss 1.319237
# Early stopping at epoch 305
# Theta | train1 -> R² = 0.1498, MSE = 1.9447e-01
# X | train1 -> R² = -0.8225, MSE = 1.9592e-01
# Y | train1 -> R² = -2.1240, MSE = 2.6144e-01
# Theta | train2 -> R² = -0.9059, MSE = 4.3363e-01
# X | train2 -> R² = -2.2634, MSE = 2.7463e-01
# Y | train2 -> R² = -2.1669, MSE = 3.4005e-01
# Theta | test1 -> R² = 0.2742, MSE = 1.6707e-01
# X | test1 -> R² = -1.6838, MSE = 2.8027e-01
# Y | test1 -> R² = -2.4738, MSE = 2.8421e-01
# Theta | test2 -> R² = -0.9067, MSE = 4.5071e-01
# X | test2 -> R² = -2.5106, MSE = 2.8855e-01
# Y | test2 -> R² = -2.1933, MSE = 3.3805e-01
# Theta | test3 -> R² = -0.4031, MSE = 4.6183e-01
# X | test3 -> R² = -0.8506, MSE = 1.6979e-01
# Y | test3 -> R² = -3.1308, MSE = 3.1672e-01
# Theta | val -> R² = 0.0452, MSE = 3.1290e-01
# X | val -> R² = 0.3776, MSE = 5.9340e-02
# Y | val -> R² = -2.6319, MSE = 2.6997e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.532596
# Epoch 50 Loss 1.447476
# Epoch 100 Loss 1.354304
# Epoch 150 Loss 1.344244
# Epoch 200 Loss 1.338085
# Epoch 250 Loss 1.330653
# Epoch 300 Loss 1.406239
# Epoch 350 Loss 1.336927
# Epoch 400 Loss 1.332168
# Epoch 450 Loss 1.331370
# Epoch 500 Loss 1.326445
# Early stopping at epoch 532
# Theta | train1 -> R² = 0.7955, MSE = 4.6785e-02
# X | train1 -> R² = 0.0488, MSE = 1.0226e-01
# Y | train1 -> R² = -0.4841, MSE = 1.2421e-01
# Theta | train2 -> R² = 0.2987, MSE = 1.5956e-01
# X | train2 -> R² = -0.0487, MSE = 8.8258e-02
# Y | train2 -> R² = -0.7721, MSE = 1.9028e-01
# Theta | test1 -> R² = 0.7654, MSE = 5.4008e-02
# X | test1 -> R² = -0.0467, MSE = 1.0931e-01
# Y | test1 -> R² = -0.7519, MSE = 1.4333e-01
# Theta | test2 -> R² = 0.6143, MSE = 9.1181e-02
# X | test2 -> R² = -0.0710, MSE = 8.8030e-02
# Y | test2 -> R² = -0.7240, MSE = 1.8251e-01
# Theta | test3 -> R² = -5.4365, MSE = 2.1186e+00
# X | test3 -> R² = -0.6092, MSE = 1.4765e-01
# Y | test3 -> R² = -1.6614, MSE = 2.0406e-01
# Theta | val -> R² = -2.9561, MSE = 1.2964e+00
# X | val -> R² = -0.1084, MSE = 1.0567e-01
# Y | val -> R² = -1.6722, MSE = 1.9864e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.550189
# Epoch 50 Loss 1.344341
# Epoch 100 Loss 1.327293
# Epoch 150 Loss 1.321178
# Epoch 200 Loss 1.323662
# Epoch 250 Loss 1.346410
# Epoch 300 Loss 1.329125
# Epoch 350 Loss 1.317506
# Epoch 400 Loss 1.325416
# Epoch 450 Loss 1.318785
# Epoch 500 Loss 1.330273
# Epoch 550 Loss 1.337169
# Epoch 600 Loss 1.312932
# Epoch 650 Loss 1.314545
# Early stopping at epoch 662
# Theta | train1 -> R² = 0.8691, MSE = 2.9935e-02
# X | train1 -> R² = -0.1697, MSE = 1.2575e-01
# Y | train1 -> R² = -0.8341, MSE = 1.5349e-01
# Theta | train2 -> R² = 0.5290, MSE = 1.0717e-01
# X | train2 -> R² = -0.1448, MSE = 9.6339e-02
# Y | train2 -> R² = -0.9693, MSE = 2.1145e-01
# Theta | test1 -> R² = 0.4117, MSE = 1.3543e-01
# X | test1 -> R² = -0.0280, MSE = 1.0735e-01
# Y | test1 -> R² = -1.0551, MSE = 1.6814e-01
# Theta | test2 -> R² = 0.5237, MSE = 1.1259e-01
# X | test2 -> R² = -0.2335, MSE = 1.0139e-01
# Y | test2 -> R² = -0.9609, MSE = 2.0759e-01
# Theta | test3 -> R² = 0.8014, MSE = 6.5378e-02
# X | test3 -> R² = -0.6887, MSE = 1.5494e-01
# Y | test3 -> R² = -3.9146, MSE = 3.7682e-01
# Theta | val -> R² = 0.3734, MSE = 2.0534e-01
# X | val -> R² = -0.6140, MSE = 1.5387e-01
# Y | val -> R² = -3.3378, MSE = 3.2244e-01
# Figura salva em: ./results/model_264_128_64_9.pdf
# Modelo 9 treinado e salvo no Excel
