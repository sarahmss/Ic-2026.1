# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 5
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 2)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada: (1266, 5, 2)
# Dimensão da saida: (1266, 5, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 2)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[8], [16], [32], [64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 Loss 1.567660
# Epoch 50 Loss 1.386497
# Epoch 100 Loss 1.321332
# Epoch 150 Loss 1.296173
# Epoch 200 Loss 1.279910
# Epoch 250 Loss 1.245265
# Epoch 300 Loss 1.232107
# Epoch 350 Loss 1.224353
# Early stopping at epoch 372
# Theta | train1 -> R² = 0.7968, MSE = 4.6486e-02
# X | train1 -> R² = -0.2413, MSE = 1.3345e-01
# Y | train1 -> R² = -1.1246, MSE = 1.7780e-01
# Theta | train2 -> R² = 0.7737, MSE = 5.1480e-02
# X | train2 -> R² = -0.1225, MSE = 9.4463e-02
# Y | train2 -> R² = -0.8390, MSE = 1.9746e-01
# Theta | test1 -> R² = 0.4240, MSE = 1.3259e-01
# X | test1 -> R² = -0.3638, MSE = 1.4242e-01
# Y | test1 -> R² = -1.3937, MSE = 1.9584e-01
# Theta | test2 -> R² = 0.8223, MSE = 4.2007e-02
# X | test2 -> R² = -0.1916, MSE = 9.7939e-02
# Y | test2 -> R² = -0.8798, MSE = 1.9899e-01
# Theta | test3 -> R² = -0.0037, MSE = 3.3038e-01
# X | test3 -> R² = -1.9861, MSE = 2.7398e-01
# Y | test3 -> R² = -5.2595, MSE = 4.7994e-01
# Theta | val -> R² = -10.7085, MSE = 3.8369e+00
# X | val -> R² = -1.2165, MSE = 2.1131e-01
# Y | val -> R² = -4.0017, MSE = 3.7179e-01
# Figura salva em: ./results/model_8_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.576574
# Epoch 50 Loss 1.342152
# Epoch 100 Loss 1.322520
# Epoch 150 Loss 1.294827
# Epoch 200 Loss 1.282119
# Epoch 250 Loss 1.276650
# Epoch 300 Loss 1.270211
# Epoch 350 Loss 1.263231
# Epoch 400 Loss 1.255541
# Epoch 450 Loss 1.245564
# Epoch 500 Loss 1.236453
# Epoch 550 Loss 1.231677
# Epoch 600 Loss 1.226248
# Epoch 650 Loss 1.222902
# Early stopping at epoch 691
# Theta | train1 -> R² = 0.5416, MSE = 1.0485e-01
# X | train1 -> R² = -0.2228, MSE = 1.3145e-01
# Y | train1 -> R² = -1.0930, MSE = 1.7516e-01
# Theta | train2 -> R² = 0.5056, MSE = 1.1250e-01
# X | train2 -> R² = -0.1255, MSE = 9.4721e-02
# Y | train2 -> R² = -0.8622, MSE = 1.9996e-01
# Theta | test1 -> R² = 0.6737, MSE = 7.5116e-02
# X | test1 -> R² = -0.3112, MSE = 1.3693e-01
# Y | test1 -> R² = -1.5934, MSE = 2.1218e-01
# Theta | test2 -> R² = 0.4509, MSE = 1.2980e-01
# X | test2 -> R² = -0.2264, MSE = 1.0080e-01
# Y | test2 -> R² = -0.8797, MSE = 1.9898e-01
# Theta | test3 -> R² = -2.6395, MSE = 1.1980e+00
# X | test3 -> R² = -3.2109, MSE = 3.8635e-01
# Y | test3 -> R² = -3.5871, MSE = 3.5171e-01
# Theta | val -> R² = -7.3501, MSE = 2.7363e+00
# X | val -> R² = -1.7200, MSE = 2.5931e-01
# Y | val -> R² = -3.6848, MSE = 3.4824e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.575985
# Epoch 50 Loss 1.343019
# Epoch 100 Loss 1.332012
# Epoch 150 Loss 1.325388
# Epoch 200 Loss 1.307154
# Epoch 250 Loss 1.296668
# Epoch 300 Loss 1.288655
# Epoch 350 Loss 1.273182
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.8293, MSE = 3.9045e-02
# X | train1 -> R² = -0.1484, MSE = 1.2346e-01
# Y | train1 -> R² = -0.9280, MSE = 1.6135e-01
# Theta | train2 -> R² = 0.7088, MSE = 6.6245e-02
# X | train2 -> R² = -0.1109, MSE = 9.3486e-02
# Y | train2 -> R² = -0.6965, MSE = 1.8216e-01
# Theta | test1 -> R² = 0.3613, MSE = 1.4702e-01
# X | test1 -> R² = -0.2804, MSE = 1.3372e-01
# Y | test1 -> R² = -1.2132, MSE = 1.8108e-01
# Theta | test2 -> R² = 0.8018, MSE = 4.6844e-02
# X | test2 -> R² = -0.1901, MSE = 9.7822e-02
# Y | test2 -> R² = -0.7587, MSE = 1.8618e-01
# Theta | test3 -> R² = 0.6947, MSE = 1.0050e-01
# X | test3 -> R² = -1.5356, MSE = 2.3264e-01
# Y | test3 -> R² = -4.3620, MSE = 4.1112e-01
# Theta | val -> R² = -5.9543, MSE = 2.2789e+00
# X | val -> R² = -1.0892, MSE = 1.9917e-01
# Y | val -> R² = -3.3852, MSE = 3.2597e-01
# Figura salva em: ./results/model_8_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.578122
# Epoch 50 Loss 1.318987
# Epoch 100 Loss 1.297715
# Epoch 150 Loss 1.285964
# Epoch 200 Loss 1.248331
# Epoch 250 Loss 1.220211
# Epoch 300 Loss 1.209128
# Epoch 350 Loss 1.200850
# Epoch 400 Loss 1.195249
# Epoch 450 Loss 1.192029
# Early stopping at epoch 474
# Theta | train1 -> R² = 0.5746, MSE = 9.7310e-02
# X | train1 -> R² = -0.1129, MSE = 1.1964e-01
# Y | train1 -> R² = -0.9044, MSE = 1.5938e-01
# Theta | train2 -> R² = 0.2132, MSE = 1.7902e-01
# X | train2 -> R² = -0.1667, MSE = 9.8183e-02
# Y | train2 -> R² = -0.7191, MSE = 1.8460e-01
# Theta | test1 -> R² = 0.6012, MSE = 9.1796e-02
# X | test1 -> R² = -0.2511, MSE = 1.3065e-01
# Y | test1 -> R² = -1.2146, MSE = 1.8119e-01
# Theta | test2 -> R² = -0.0841, MSE = 2.5625e-01
# X | test2 -> R² = -0.2804, MSE = 1.0524e-01
# Y | test2 -> R² = -0.8142, MSE = 1.9206e-01
# Theta | test3 -> R² = -0.1462, MSE = 3.7729e-01
# X | test3 -> R² = -1.4586, MSE = 2.2558e-01
# Y | test3 -> R² = -3.7243, MSE = 3.6224e-01
# Theta | val -> R² = -3.6360, MSE = 1.5192e+00
# X | val -> R² = -1.4215, MSE = 2.3085e-01
# Y | val -> R² = -3.1544, MSE = 3.0881e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.598560
# Epoch 50 Loss 1.325649
# Epoch 100 Loss 1.266237
# Epoch 150 Loss 1.234852
# Epoch 200 Loss 1.220191
# Epoch 250 Loss 1.212166
# Epoch 300 Loss 1.207024
# Epoch 350 Loss 1.203869
# Early stopping at epoch 359
# Theta | train1 -> R² = 0.6127, MSE = 8.8590e-02
# X | train1 -> R² = -0.2443, MSE = 1.3377e-01
# Y | train1 -> R² = -0.8356, MSE = 1.5362e-01
# Theta | train2 -> R² = 0.7077, MSE = 6.6510e-02
# X | train2 -> R² = -0.1166, MSE = 9.3964e-02
# Y | train2 -> R² = -0.6942, MSE = 1.8191e-01
# Theta | test1 -> R² = 0.3659, MSE = 1.4596e-01
# X | test1 -> R² = -0.2989, MSE = 1.3564e-01
# Y | test1 -> R² = -1.0492, MSE = 1.6766e-01
# Theta | test2 -> R² = 0.8817, MSE = 2.7968e-02
# X | test2 -> R² = -0.1937, MSE = 9.8116e-02
# Y | test2 -> R² = -0.7724, MSE = 1.8763e-01
# Theta | test3 -> R² = -3.0047, MSE = 1.3182e+00
# X | test3 -> R² = -1.3725, MSE = 2.1768e-01
# Y | test3 -> R² = -3.7353, MSE = 3.6308e-01
# Theta | val -> R² = -10.7493, MSE = 3.8503e+00
# X | val -> R² = -0.4804, MSE = 1.4113e-01
# Y | val -> R² = -2.2647, MSE = 2.4267e-01
# Figura salva em: ./results/model_8_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.668404
# Epoch 50 Loss 1.338469
# Epoch 100 Loss 1.318268
# Epoch 150 Loss 1.271860
# Epoch 200 Loss 1.257481
# Epoch 250 Loss 1.254931
# Epoch 300 Loss 1.246822
# Epoch 350 Loss 1.269639
# Early stopping at epoch 362
# Theta | train1 -> R² = 0.8957, MSE = 2.3846e-02
# X | train1 -> R² = -0.1085, MSE = 1.1917e-01
# Y | train1 -> R² = -1.0051, MSE = 1.6781e-01
# Theta | train2 -> R² = 0.7183, MSE = 6.4103e-02
# X | train2 -> R² = -0.1450, MSE = 9.6361e-02
# Y | train2 -> R² = -0.8673, MSE = 2.0050e-01
# Theta | test1 -> R² = 0.7782, MSE = 5.1060e-02
# X | test1 -> R² = -0.2720, MSE = 1.3284e-01
# Y | test1 -> R² = -1.3386, MSE = 1.9134e-01
# Theta | test2 -> R² = 0.7850, MSE = 5.0819e-02
# X | test2 -> R² = -0.2222, MSE = 1.0046e-01
# Y | test2 -> R² = -0.9411, MSE = 2.0548e-01
# Theta | test3 -> R² = 0.5150, MSE = 1.5964e-01
# X | test3 -> R² = -1.4045, MSE = 2.2061e-01
# Y | test3 -> R² = -4.2766, MSE = 4.0458e-01
# Theta | val -> R² = -2.6987, MSE = 1.2121e+00
# X | val -> R² = -1.1574, MSE = 2.0567e-01
# Y | val -> R² = -3.3911, MSE = 3.2641e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.560061
# Epoch 50 Loss 1.342332
# Epoch 100 Loss 1.330560
# Epoch 150 Loss 1.314579
# Epoch 200 Loss 1.291650
# Epoch 250 Loss 1.276339
# Epoch 300 Loss 1.264309
# Epoch 350 Loss 1.228005
# Epoch 400 Loss 1.220319
# Epoch 450 Loss 1.220107
# Epoch 500 Loss 1.213065
# Epoch 550 Loss 1.213820
# Epoch 600 Loss 1.209387
# Early stopping at epoch 602
# Theta | train1 -> R² = 0.2520, MSE = 1.7110e-01
# X | train1 -> R² = -0.1902, MSE = 1.2795e-01
# Y | train1 -> R² = -0.9682, MSE = 1.6472e-01
# Theta | train2 -> R² = 0.8885, MSE = 2.5376e-02
# X | train2 -> R² = -0.0924, MSE = 9.1932e-02
# Y | train2 -> R² = -0.8950, MSE = 2.0348e-01
# Theta | test1 -> R² = 0.3116, MSE = 1.5846e-01
# X | test1 -> R² = -0.2680, MSE = 1.3242e-01
# Y | test1 -> R² = -1.2759, MSE = 1.8621e-01
# Theta | test2 -> R² = 0.8896, MSE = 2.6092e-02
# X | test2 -> R² = -0.1817, MSE = 9.7127e-02
# Y | test2 -> R² = -0.8680, MSE = 1.9775e-01
# Theta | test3 -> R² = -12.0277, MSE = 4.2882e+00
# X | test3 -> R² = -1.5969, MSE = 2.3827e-01
# Y | test3 -> R² = -2.7402, MSE = 2.8678e-01
# Theta | val -> R² = -20.2729, MSE = 6.9712e+00
# X | val -> R² = -1.1426, MSE = 2.0426e-01
# Y | val -> R² = -2.6854, MSE = 2.7395e-01
# Figura salva em: ./results/model_8_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.573858
# Epoch 50 Loss 1.339180
# Epoch 100 Loss 1.300146
# Epoch 150 Loss 1.258963
# Epoch 200 Loss 1.238946
# Epoch 250 Loss 1.229864
# Epoch 300 Loss 1.222165
# Epoch 350 Loss 1.216274
# Early stopping at epoch 394
# Theta | train1 -> R² = 0.8052, MSE = 4.4552e-02
# X | train1 -> R² = -0.2285, MSE = 1.3207e-01
# Y | train1 -> R² = -1.1032, MSE = 1.7601e-01
# Theta | train2 -> R² = 0.7917, MSE = 4.7384e-02
# X | train2 -> R² = -0.1564, MSE = 9.7321e-02
# Y | train2 -> R² = -0.9094, MSE = 2.0502e-01
# Theta | test1 -> R² = 0.6846, MSE = 7.2596e-02
# X | test1 -> R² = -0.3392, MSE = 1.3985e-01
# Y | test1 -> R² = -1.4025, MSE = 1.9656e-01
# Theta | test2 -> R² = 0.8498, MSE = 3.5495e-02
# X | test2 -> R² = -0.2439, MSE = 1.0224e-01
# Y | test2 -> R² = -0.9759, MSE = 2.0917e-01
# Theta | test3 -> R² = 0.7229, MSE = 9.1221e-02
# X | test3 -> R² = -1.6916, MSE = 2.4695e-01
# Y | test3 -> R² = -4.7322, MSE = 4.3951e-01
# Theta | val -> R² = -0.6533, MSE = 5.4179e-01
# X | val -> R² = -1.2250, MSE = 2.1212e-01
# Y | val -> R² = -3.8231, MSE = 3.5852e-01
# Figura salva em: ./results/model_8_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.590042
# Epoch 50 Loss 1.348264
# Epoch 100 Loss 1.328367
# Epoch 150 Loss 1.305350
# Epoch 200 Loss 1.295798
# Epoch 250 Loss 1.286128
# Epoch 300 Loss 1.268006
# Epoch 350 Loss 1.261924
# Early stopping at epoch 383
# Theta | train1 -> R² = 0.8221, MSE = 4.0684e-02
# X | train1 -> R² = -0.1695, MSE = 1.2573e-01
# Y | train1 -> R² = -1.0135, MSE = 1.6851e-01
# Theta | train2 -> R² = 0.7401, MSE = 5.9130e-02
# X | train2 -> R² = -0.1249, MSE = 9.4666e-02
# Y | train2 -> R² = -0.8251, MSE = 1.9597e-01
# Theta | test1 -> R² = 0.4963, MSE = 1.1595e-01
# X | test1 -> R² = -0.2963, MSE = 1.3538e-01
# Y | test1 -> R² = -1.3269, MSE = 1.9038e-01
# Theta | test2 -> R² = 0.8303, MSE = 4.0106e-02
# X | test2 -> R² = -0.2226, MSE = 1.0049e-01
# Y | test2 -> R² = -0.9010, MSE = 2.0124e-01
# Theta | test3 -> R² = 0.4000, MSE = 1.9751e-01
# X | test3 -> R² = -1.3136, MSE = 2.1227e-01
# Y | test3 -> R² = -4.5373, MSE = 4.2457e-01
# Theta | val -> R² = -6.5387, MSE = 2.4704e+00
# X | val -> R² = -0.9114, MSE = 1.8222e-01
# Y | val -> R² = -3.6402, MSE = 3.4493e-01
# Figura salva em: ./results/model_8_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.565765
# Epoch 50 Loss 1.342562
# Epoch 100 Loss 1.332268
# Epoch 150 Loss 1.307580
# Epoch 200 Loss 1.257266
# Epoch 250 Loss 1.237997
# Epoch 300 Loss 1.229888
# Epoch 350 Loss 1.222651
# Epoch 400 Loss 1.217573
# Epoch 450 Loss 1.215958
# Early stopping at epoch 465
# Theta | train1 -> R² = 0.9313, MSE = 1.5718e-02
# X | train1 -> R² = -0.1525, MSE = 1.2390e-01
# Y | train1 -> R² = -1.1097, MSE = 1.7656e-01
# Theta | train2 -> R² = 0.4645, MSE = 1.2185e-01
# X | train2 -> R² = -0.0619, MSE = 8.9366e-02
# Y | train2 -> R² = -0.7944, MSE = 1.9268e-01
# Theta | test1 -> R² = 0.6024, MSE = 9.1522e-02
# X | test1 -> R² = -0.2155, MSE = 1.2693e-01
# Y | test1 -> R² = -1.3546, MSE = 1.9264e-01
# Theta | test2 -> R² = 0.5416, MSE = 1.0836e-01
# X | test2 -> R² = -0.1278, MSE = 9.2700e-02
# Y | test2 -> R² = -0.8365, MSE = 1.9441e-01
# Theta | test3 -> R² = 0.7031, MSE = 9.7733e-02
# X | test3 -> R² = -2.2710, MSE = 3.0012e-01
# Y | test3 -> R² = -6.0827, MSE = 5.4306e-01
# Theta | val -> R² = -3.6606, MSE = 1.5273e+00
# X | val -> R² = -1.3043, MSE = 2.1967e-01
# Y | val -> R² = -4.1797, MSE = 3.8502e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.563999
# Epoch 50 Loss 1.335691
# Epoch 100 Loss 1.303056
# Epoch 150 Loss 1.260321
# Epoch 200 Loss 1.233959
# Epoch 250 Loss 1.220208
# Epoch 300 Loss 1.210546
# Epoch 350 Loss 1.197765
# Early stopping at epoch 393
# Theta | train1 -> R² = 0.8797, MSE = 2.7512e-02
# X | train1 -> R² = -0.2338, MSE = 1.3264e-01
# Y | train1 -> R² = -1.1263, MSE = 1.7795e-01
# Theta | train2 -> R² = 0.4799, MSE = 1.1834e-01
# X | train2 -> R² = -0.1399, MSE = 9.5925e-02
# Y | train2 -> R² = -0.8555, MSE = 1.9923e-01
# Theta | test1 -> R² = 0.7734, MSE = 5.2163e-02
# X | test1 -> R² = -0.3473, MSE = 1.4070e-01
# Y | test1 -> R² = -1.4462, MSE = 2.0014e-01
# Theta | test2 -> R² = 0.4028, MSE = 1.4115e-01
# X | test2 -> R² = -0.2087, MSE = 9.9350e-02
# Y | test2 -> R² = -0.9106, MSE = 2.0226e-01
# Theta | test3 -> R² = 0.0576, MSE = 3.1019e-01
# X | test3 -> R² = -1.7852, MSE = 2.5554e-01
# Y | test3 -> R² = -5.0946, MSE = 4.6730e-01
# Theta | val -> R² = -3.1749, MSE = 1.3681e+00
# X | val -> R² = -1.0697, MSE = 1.9732e-01
# Y | val -> R² = -4.0634, MSE = 3.7638e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.560342
# Epoch 50 Loss 1.332397
# Epoch 100 Loss 1.306900
# Epoch 150 Loss 1.276927
# Epoch 200 Loss 1.241897
# Epoch 250 Loss 1.227360
# Epoch 300 Loss 1.214759
# Epoch 350 Loss 1.205200
# Early stopping at epoch 365
# Theta | train1 -> R² = 0.8944, MSE = 2.4147e-02
# X | train1 -> R² = -0.2521, MSE = 1.3461e-01
# Y | train1 -> R² = -1.1323, MSE = 1.7845e-01
# Theta | train2 -> R² = 0.7120, MSE = 6.5536e-02
# X | train2 -> R² = -0.2221, MSE = 1.0285e-01
# Y | train2 -> R² = -0.8842, MSE = 2.0232e-01
# Theta | test1 -> R² = 0.5684, MSE = 9.9353e-02
# X | test1 -> R² = -0.3794, MSE = 1.4406e-01
# Y | test1 -> R² = -1.3986, MSE = 1.9625e-01
# Theta | test2 -> R² = 0.6804, MSE = 7.5549e-02
# X | test2 -> R² = -0.3203, MSE = 1.0852e-01
# Y | test2 -> R² = -0.9556, MSE = 2.0702e-01
# Theta | test3 -> R² = 0.5039, MSE = 1.6328e-01
# X | test3 -> R² = -2.2047, MSE = 2.9403e-01
# Y | test3 -> R² = -5.4337, MSE = 4.9330e-01
# Theta | val -> R² = -6.2786, MSE = 2.3852e+00
# X | val -> R² = -1.2976, MSE = 2.1904e-01
# Y | val -> R² = -3.6604, MSE = 3.4643e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.580208
# Epoch 50 Loss 1.330889
# Epoch 100 Loss 1.303762
# Epoch 150 Loss 1.282772
# Epoch 200 Loss 1.277178
# Epoch 250 Loss 1.249185
# Epoch 300 Loss 1.215932
# Early stopping at epoch 345
# Theta | train1 -> R² = 0.8801, MSE = 2.7420e-02
# X | train1 -> R² = -0.0791, MSE = 1.1600e-01
# Y | train1 -> R² = -1.0211, MSE = 1.6915e-01
# Theta | train2 -> R² = 0.6888, MSE = 7.0812e-02
# X | train2 -> R² = -0.0320, MSE = 8.6849e-02
# Y | train2 -> R² = -0.7802, MSE = 1.9115e-01
# Theta | test1 -> R² = 0.8013, MSE = 4.5732e-02
# X | test1 -> R² = -0.2188, MSE = 1.2728e-01
# Y | test1 -> R² = -1.3523, MSE = 1.9245e-01
# Theta | test2 -> R² = 0.6970, MSE = 7.1616e-02
# X | test2 -> R² = -0.1063, MSE = 9.0931e-02
# Y | test2 -> R² = -0.8597, MSE = 1.9687e-01
# Theta | test3 -> R² = 0.1825, MSE = 2.6910e-01
# X | test3 -> R² = -1.2045, MSE = 2.0226e-01
# Y | test3 -> R² = -4.6224, MSE = 4.3109e-01
# Theta | val -> R² = -2.9115, MSE = 1.2818e+00
# X | val -> R² = -0.9648, MSE = 1.8731e-01
# Y | val -> R² = -3.9587, MSE = 3.6860e-01
# Figura salva em: ./results/model_16_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.596502
# Epoch 50 Loss 1.338485
# Epoch 100 Loss 1.321161
# Epoch 150 Loss 1.295300
# Epoch 200 Loss 1.278712
# Epoch 250 Loss 1.241031
# Epoch 300 Loss 1.209364
# Epoch 350 Loss 1.195155
# Epoch 400 Loss 1.187339
# Epoch 450 Loss 1.182651
# Epoch 500 Loss 1.179008
# Early stopping at epoch 515
# Theta | train1 -> R² = 0.7986, MSE = 4.6059e-02
# X | train1 -> R² = -0.2251, MSE = 1.3170e-01
# Y | train1 -> R² = -1.1578, MSE = 1.8058e-01
# Theta | train2 -> R² = 0.5420, MSE = 1.0421e-01
# X | train2 -> R² = -0.1567, MSE = 9.7347e-02
# Y | train2 -> R² = -0.9213, MSE = 2.0630e-01
# Theta | test1 -> R² = 0.6071, MSE = 9.0433e-02
# X | test1 -> R² = -0.2571, MSE = 1.3129e-01
# Y | test1 -> R² = -1.4149, MSE = 1.9758e-01
# Theta | test2 -> R² = 0.4084, MSE = 1.3984e-01
# X | test2 -> R² = -0.1971, MSE = 9.8395e-02
# Y | test2 -> R² = -0.9603, MSE = 2.0751e-01
# Theta | test3 -> R² = -10.3947, MSE = 3.7506e+00
# X | test3 -> R² = -2.0474, MSE = 2.7959e-01
# Y | test3 -> R² = -3.6225, MSE = 3.5442e-01
# Theta | val -> R² = -9.9601, MSE = 3.5916e+00
# X | val -> R² = -1.1534, MSE = 2.0530e-01
# Y | val -> R² = -3.6372, MSE = 3.4470e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.576355
# Epoch 50 Loss 1.335411
# Epoch 100 Loss 1.297754
# Epoch 150 Loss 1.287632
# Epoch 200 Loss 1.269709
# Epoch 250 Loss 1.230372
# Epoch 300 Loss 1.217131
# Epoch 350 Loss 1.205161
# Epoch 400 Loss 1.201098
# Epoch 450 Loss 1.189907
# Early stopping at epoch 496
# Theta | train1 -> R² = 0.7410, MSE = 5.9246e-02
# X | train1 -> R² = -0.1524, MSE = 1.2388e-01
# Y | train1 -> R² = -0.9396, MSE = 1.6232e-01
# Theta | train2 -> R² = 0.7308, MSE = 6.1240e-02
# X | train2 -> R² = -0.1339, MSE = 9.5423e-02
# Y | train2 -> R² = -0.7340, MSE = 1.8619e-01
# Theta | test1 -> R² = 0.6389, MSE = 8.3118e-02
# X | test1 -> R² = -0.2458, MSE = 1.3010e-01
# Y | test1 -> R² = -1.2193, MSE = 1.8157e-01
# Theta | test2 -> R² = 0.6236, MSE = 8.8972e-02
# X | test2 -> R² = -0.1942, MSE = 9.8156e-02
# Y | test2 -> R² = -0.7214, MSE = 1.8223e-01
# Theta | test3 -> R² = -5.5090, MSE = 2.1425e+00
# X | test3 -> R² = -1.6687, MSE = 2.4485e-01
# Y | test3 -> R² = -2.7794, MSE = 2.8978e-01
# Theta | val -> R² = -12.7653, MSE = 4.5109e+00
# X | val -> R² = -1.0333, MSE = 1.9384e-01
# Y | val -> R² = -2.1960, MSE = 2.3757e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.574322
# Epoch 50 Loss 1.332118
# Epoch 100 Loss 1.304332
# Epoch 150 Loss 1.296023
# Epoch 200 Loss 1.265010
# Epoch 250 Loss 1.214363
# Epoch 300 Loss 1.199914
# Epoch 350 Loss 1.189667
# Epoch 400 Loss 1.189303
# Epoch 450 Loss 1.179996
# Early stopping at epoch 483
# Theta | train1 -> R² = 0.8619, MSE = 3.1600e-02
# X | train1 -> R² = -0.2653, MSE = 1.3602e-01
# Y | train1 -> R² = -1.0986, MSE = 1.7563e-01
# Theta | train2 -> R² = 0.4710, MSE = 1.2036e-01
# X | train2 -> R² = -0.1070, MSE = 9.3161e-02
# Y | train2 -> R² = -0.8213, MSE = 1.9557e-01
# Theta | test1 -> R² = 0.7048, MSE = 6.7950e-02
# X | test1 -> R² = -0.3053, MSE = 1.3631e-01
# Y | test1 -> R² = -1.4724, MSE = 2.0228e-01
# Theta | test2 -> R² = 0.3460, MSE = 1.5458e-01
# X | test2 -> R² = -0.1244, MSE = 9.2419e-02
# Y | test2 -> R² = -0.8316, MSE = 1.9390e-01
# Theta | test3 -> R² = -4.7823, MSE = 1.9033e+00
# X | test3 -> R² = -1.7143, MSE = 2.4904e-01
# Y | test3 -> R² = -3.7917, MSE = 3.6740e-01
# Theta | val -> R² = -14.6659, MSE = 5.1337e+00
# X | val -> R² = -0.5908, MSE = 1.5166e-01
# Y | val -> R² = -3.1226, MSE = 3.0645e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.584654
# Epoch 50 Loss 1.310513
# Epoch 100 Loss 1.296967
# Epoch 150 Loss 1.290131
# Epoch 200 Loss 1.244790
# Epoch 250 Loss 1.226638
# Epoch 300 Loss 1.213145
# Early stopping at epoch 340
# Theta | train1 -> R² = 0.8997, MSE = 2.2941e-02
# X | train1 -> R² = -0.2447, MSE = 1.3381e-01
# Y | train1 -> R² = -0.9158, MSE = 1.6033e-01
# Theta | train2 -> R² = 0.5656, MSE = 9.8832e-02
# X | train2 -> R² = -0.0213, MSE = 8.5946e-02
# Y | train2 -> R² = -0.7175, MSE = 1.8442e-01
# Theta | test1 -> R² = 0.8371, MSE = 3.7504e-02
# X | test1 -> R² = -0.3487, MSE = 1.4084e-01
# Y | test1 -> R² = -1.1275, MSE = 1.7406e-01
# Theta | test2 -> R² = 0.8258, MSE = 4.1168e-02
# X | test2 -> R² = -0.0725, MSE = 8.8154e-02
# Y | test2 -> R² = -0.7640, MSE = 1.8673e-01
# Theta | test3 -> R² = -0.5909, MSE = 5.2365e-01
# X | test3 -> R² = -1.9696, MSE = 2.7246e-01
# Y | test3 -> R² = -5.0969, MSE = 4.6747e-01
# Theta | val -> R² = -11.0623, MSE = 3.9528e+00
# X | val -> R² = -1.1753, MSE = 2.0738e-01
# Y | val -> R² = -3.3934, MSE = 3.2658e-01
# Figura salva em: ./results/model_16_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.568196
# Epoch 50 Loss 1.310701
# Epoch 100 Loss 1.286663
# Epoch 150 Loss 1.262865
# Epoch 200 Loss 1.228784
# Epoch 250 Loss 1.216169
# Epoch 300 Loss 1.205918
# Epoch 350 Loss 1.199303
# Epoch 400 Loss 1.192747
# Early stopping at epoch 427
# Theta | train1 -> R² = 0.5893, MSE = 9.3949e-02
# X | train1 -> R² = -0.2366, MSE = 1.3294e-01
# Y | train1 -> R² = -1.1329, MSE = 1.7850e-01
# Theta | train2 -> R² = 0.3700, MSE = 1.4334e-01
# X | train2 -> R² = -0.1289, MSE = 9.5002e-02
# Y | train2 -> R² = -0.8860, MSE = 2.0252e-01
# Theta | test1 -> R² = 0.7197, MSE = 6.4513e-02
# X | test1 -> R² = -0.3623, MSE = 1.4226e-01
# Y | test1 -> R² = -1.4834, MSE = 2.0318e-01
# Theta | test2 -> R² = 0.1546, MSE = 1.9983e-01
# X | test2 -> R² = -0.1921, MSE = 9.7983e-02
# Y | test2 -> R² = -0.9425, MSE = 2.0564e-01
# Theta | test3 -> R² = -6.2118, MSE = 2.3738e+00
# X | test3 -> R² = -1.5571, MSE = 2.3461e-01
# Y | test3 -> R² = -3.9918, MSE = 3.8274e-01
# Theta | val -> R² = -11.1133, MSE = 3.9695e+00
# X | val -> R² = -1.2825, MSE = 2.1760e-01
# Y | val -> R² = -3.5989, MSE = 3.4185e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.612530
# Epoch 50 Loss 1.305248
# Epoch 100 Loss 1.293755
# Epoch 150 Loss 1.275020
# Epoch 200 Loss 1.224330
# Epoch 250 Loss 1.208672
# Epoch 300 Loss 1.199299
# Epoch 350 Loss 1.186866
# Epoch 400 Loss 1.179469
# Epoch 450 Loss 1.174494
# Early stopping at epoch 464
# Theta | train1 -> R² = 0.8063, MSE = 4.4300e-02
# X | train1 -> R² = -0.1988, MSE = 1.2887e-01
# Y | train1 -> R² = -1.0752, MSE = 1.7367e-01
# Theta | train2 -> R² = 0.5227, MSE = 1.0859e-01
# X | train2 -> R² = -0.1101, MSE = 9.3418e-02
# Y | train2 -> R² = -0.8229, MSE = 1.9574e-01
# Theta | test1 -> R² = 0.7406, MSE = 5.9715e-02
# X | test1 -> R² = -0.3873, MSE = 1.4488e-01
# Y | test1 -> R² = -1.5745, MSE = 2.1064e-01
# Theta | test2 -> R² = 0.5162, MSE = 1.1435e-01
# X | test2 -> R² = -0.2158, MSE = 9.9932e-02
# Y | test2 -> R² = -0.8602, MSE = 1.9692e-01
# Theta | test3 -> R² = -5.1176, MSE = 2.0137e+00
# X | test3 -> R² = -1.3071, MSE = 2.1167e-01
# Y | test3 -> R² = -2.8963, MSE = 2.9875e-01
# Theta | val -> R² = -18.6610, MSE = 6.4429e+00
# X | val -> R² = -1.7269, MSE = 2.5997e-01
# Y | val -> R² = -2.8030, MSE = 2.8269e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.571969
# Epoch 50 Loss 1.328664
# Epoch 100 Loss 1.305531
# Epoch 150 Loss 1.282570
# Epoch 200 Loss 1.244223
# Epoch 250 Loss 1.225290
# Epoch 300 Loss 1.211805
# Epoch 350 Loss 1.200263
# Early stopping at epoch 372
# Theta | train1 -> R² = 0.8480, MSE = 3.4766e-02
# X | train1 -> R² = -0.0770, MSE = 1.1579e-01
# Y | train1 -> R² = -0.9806, MSE = 1.6576e-01
# Theta | train2 -> R² = 0.3127, MSE = 1.5637e-01
# X | train2 -> R² = -0.0264, MSE = 8.6381e-02
# Y | train2 -> R² = -0.6957, MSE = 1.8208e-01
# Theta | test1 -> R² = 0.7384, MSE = 6.0228e-02
# X | test1 -> R² = -0.1651, MSE = 1.2167e-01
# Y | test1 -> R² = -1.2202, MSE = 1.8165e-01
# Theta | test2 -> R² = 0.2782, MSE = 1.7062e-01
# X | test2 -> R² = -0.0885, MSE = 8.9466e-02
# Y | test2 -> R² = -0.7379, MSE = 1.8397e-01
# Theta | test3 -> R² = 0.6715, MSE = 1.0813e-01
# X | test3 -> R² = -1.4314, MSE = 2.2308e-01
# Y | test3 -> R² = -4.8153, MSE = 4.4589e-01
# Theta | val -> R² = -5.1527, MSE = 2.0162e+00
# X | val -> R² = -0.7021, MSE = 1.6227e-01
# Y | val -> R² = -3.1389, MSE = 3.0766e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.583320
# Epoch 50 Loss 1.330647
# Epoch 100 Loss 1.302872
# Epoch 150 Loss 1.296766
# Epoch 200 Loss 1.252223
# Epoch 250 Loss 1.220442
# Epoch 300 Loss 1.207260
# Epoch 350 Loss 1.262736
# Epoch 400 Loss 1.184848
# Epoch 450 Loss 1.175977
# Epoch 500 Loss 1.169606
# Early stopping at epoch 505
# Theta | train1 -> R² = 0.6925, MSE = 7.0335e-02
# X | train1 -> R² = -0.1764, MSE = 1.2647e-01
# Y | train1 -> R² = -1.0752, MSE = 1.7367e-01
# Theta | train2 -> R² = 0.4167, MSE = 1.3271e-01
# X | train2 -> R² = -0.0520, MSE = 8.8534e-02
# Y | train2 -> R² = -0.8048, MSE = 1.9379e-01
# Theta | test1 -> R² = 0.7913, MSE = 4.8032e-02
# X | test1 -> R² = -0.1597, MSE = 1.2111e-01
# Y | test1 -> R² = -1.5039, MSE = 2.0486e-01
# Theta | test2 -> R² = 0.5975, MSE = 9.5136e-02
# X | test2 -> R² = -0.1556, MSE = 9.4983e-02
# Y | test2 -> R² = -0.7669, MSE = 1.8705e-01
# Theta | test3 -> R² = -6.8008, MSE = 2.5677e+00
# X | test3 -> R² = -2.7385, MSE = 3.4300e-01
# Y | test3 -> R² = -3.3598, MSE = 3.3429e-01
# Theta | val -> R² = -8.5163, MSE = 3.1185e+00
# X | val -> R² = -1.1937, MSE = 2.0913e-01
# Y | val -> R² = -3.2928, MSE = 3.1910e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.563915
# Epoch 50 Loss 1.313819
# Epoch 100 Loss 1.293961
# Epoch 150 Loss 1.275362
# Epoch 200 Loss 1.253543
# Epoch 250 Loss 1.223747
# Epoch 300 Loss 1.214421
# Early stopping at epoch 308
# Theta | train1 -> R² = -0.1648, MSE = 2.6642e-01
# X | train1 -> R² = -0.1770, MSE = 1.2654e-01
# Y | train1 -> R² = -1.3355, MSE = 1.9545e-01
# Theta | train2 -> R² = -0.7867, MSE = 4.0653e-01
# X | train2 -> R² = -0.2654, MSE = 1.0649e-01
# Y | train2 -> R² = -0.9806, MSE = 2.1267e-01
# Theta | test1 -> R² = -0.5435, MSE = 3.5529e-01
# X | test1 -> R² = -0.3339, MSE = 1.3930e-01
# Y | test1 -> R² = -1.6198, MSE = 2.1434e-01
# Theta | test2 -> R² = -0.3418, MSE = 3.1718e-01
# X | test2 -> R² = -0.3570, MSE = 1.1153e-01
# Y | test2 -> R² = -1.0105, MSE = 2.1283e-01
# Theta | test3 -> R² = -1.5286, MSE = 8.3231e-01
# X | test3 -> R² = -4.1738, MSE = 4.7469e-01
# Y | test3 -> R² = -6.4590, MSE = 5.7191e-01
# Theta | val -> R² = -14.5036, MSE = 5.0806e+00
# X | val -> R² = -2.1796, MSE = 3.0312e-01
# Y | val -> R² = -5.5769, MSE = 4.8888e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.608961
# Epoch 50 Loss 1.306326
# Epoch 100 Loss 1.291977
# Epoch 150 Loss 1.276309
# Epoch 200 Loss 1.246970
# Epoch 250 Loss 1.215166
# Epoch 300 Loss 1.202810
# Epoch 350 Loss 1.184766
# Epoch 400 Loss 1.178295
# Epoch 450 Loss 1.167052
# Epoch 500 Loss 1.165454
# Early stopping at epoch 502
# Theta | train1 -> R² = 0.0817, MSE = 2.1005e-01
# X | train1 -> R² = -0.3304, MSE = 1.4302e-01
# Y | train1 -> R² = -1.1014, MSE = 1.7587e-01
# Theta | train2 -> R² = 0.4184, MSE = 1.3234e-01
# X | train2 -> R² = -0.0994, MSE = 9.2522e-02
# Y | train2 -> R² = -0.9512, MSE = 2.0952e-01
# Theta | test1 -> R² = 0.5546, MSE = 1.0252e-01
# X | test1 -> R² = -0.3174, MSE = 1.3757e-01
# Y | test1 -> R² = -1.5833, MSE = 2.1135e-01
# Theta | test2 -> R² = 0.4390, MSE = 1.3260e-01
# X | test2 -> R² = -0.1859, MSE = 9.7476e-02
# Y | test2 -> R² = -0.9248, MSE = 2.0376e-01
# Theta | test3 -> R² = -7.7695, MSE = 2.8866e+00
# X | test3 -> R² = -2.9277, MSE = 3.6037e-01
# Y | test3 -> R² = -2.0047, MSE = 2.3038e-01
# Theta | val -> R² = -8.5984, MSE = 3.1454e+00
# X | val -> R² = -1.6754, MSE = 2.5505e-01
# Y | val -> R² = -2.7527, MSE = 2.7895e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.588124
# Epoch 50 Loss 1.316147
# Epoch 100 Loss 1.293501
# Epoch 150 Loss 1.282501
# Epoch 200 Loss 1.232280
# Epoch 250 Loss 1.210492
# Epoch 300 Loss 1.199039
# Epoch 350 Loss 1.192764
# Epoch 400 Loss 1.174012
# Early stopping at epoch 449
# Theta | train1 -> R² = 0.4060, MSE = 1.3587e-01
# X | train1 -> R² = -0.2523, MSE = 1.3463e-01
# Y | train1 -> R² = -1.0417, MSE = 1.7086e-01
# Theta | train2 -> R² = 0.7133, MSE = 6.5241e-02
# X | train2 -> R² = -0.1316, MSE = 9.5234e-02
# Y | train2 -> R² = -0.8500, MSE = 1.9865e-01
# Theta | test1 -> R² = 0.4305, MSE = 1.3108e-01
# X | test1 -> R² = -0.2963, MSE = 1.3537e-01
# Y | test1 -> R² = -1.3705, MSE = 1.9394e-01
# Theta | test2 -> R² = 0.7244, MSE = 6.5144e-02
# X | test2 -> R² = -0.2031, MSE = 9.8886e-02
# Y | test2 -> R² = -0.8787, MSE = 1.9888e-01
# Theta | test3 -> R² = -6.7444, MSE = 2.5491e+00
# X | test3 -> R² = -1.7112, MSE = 2.4875e-01
# Y | test3 -> R² = -2.9397, MSE = 3.0207e-01
# Theta | val -> R² = -16.6181, MSE = 5.7735e+00
# X | val -> R² = -1.4216, MSE = 2.3086e-01
# Y | val -> R² = -2.5220, MSE = 2.6180e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.635871
# Epoch 50 Loss 1.327457
# Epoch 100 Loss 1.308030
# Epoch 150 Loss 1.317260
# Epoch 200 Loss 1.295788
# Epoch 250 Loss 1.228648
# Epoch 300 Loss 1.206558
# Epoch 350 Loss 1.194176
# Early stopping at epoch 362
# Theta | train1 -> R² = 0.9319, MSE = 1.5575e-02
# X | train1 -> R² = -0.1439, MSE = 1.2298e-01
# Y | train1 -> R² = -1.0896, MSE = 1.7488e-01
# Theta | train2 -> R² = 0.5071, MSE = 1.1214e-01
# X | train2 -> R² = -0.0676, MSE = 8.9842e-02
# Y | train2 -> R² = -0.8184, MSE = 1.9525e-01
# Theta | test1 -> R² = 0.7280, MSE = 6.2622e-02
# X | test1 -> R² = -0.2796, MSE = 1.3363e-01
# Y | test1 -> R² = -1.4156, MSE = 1.9763e-01
# Theta | test2 -> R² = 0.4275, MSE = 1.3532e-01
# X | test2 -> R² = -0.1409, MSE = 9.3775e-02
# Y | test2 -> R² = -0.8881, MSE = 1.9988e-01
# Theta | test3 -> R² = 0.2998, MSE = 2.3048e-01
# X | test3 -> R² = -1.5412, MSE = 2.3316e-01
# Y | test3 -> R² = -5.2102, MSE = 4.7617e-01
# Theta | val -> R² = -4.5415, MSE = 1.8160e+00
# X | val -> R² = -1.4373, MSE = 2.3235e-01
# Y | val -> R² = -4.3386, MSE = 3.9684e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.615678
# Epoch 50 Loss 1.303208
# Epoch 100 Loss 1.290061
# Epoch 150 Loss 1.254022
# Epoch 200 Loss 1.210011
# Epoch 250 Loss 1.188688
# Epoch 300 Loss 1.179204
# Epoch 350 Loss 1.172517
# Epoch 400 Loss 1.167197
# Early stopping at epoch 428
# Theta | train1 -> R² = 0.5367, MSE = 1.0597e-01
# X | train1 -> R² = -0.2261, MSE = 1.3181e-01
# Y | train1 -> R² = -1.0337, MSE = 1.7019e-01
# Theta | train2 -> R² = 0.7463, MSE = 5.7724e-02
# X | train2 -> R² = -0.1129, MSE = 9.3657e-02
# Y | train2 -> R² = -0.8474, MSE = 1.9837e-01
# Theta | test1 -> R² = 0.2244, MSE = 1.7854e-01
# X | test1 -> R² = -0.3060, MSE = 1.3639e-01
# Y | test1 -> R² = -1.3162, MSE = 1.8950e-01
# Theta | test2 -> R² = 0.7885, MSE = 4.9984e-02
# X | test2 -> R² = -0.1864, MSE = 9.7516e-02
# Y | test2 -> R² = -0.8997, MSE = 2.0110e-01
# Theta | test3 -> R² = -4.0769, MSE = 1.6711e+00
# X | test3 -> R² = -2.0299, MSE = 2.7799e-01
# Y | test3 -> R² = -3.5652, MSE = 3.5004e-01
# Theta | val -> R² = -13.6701, MSE = 4.8074e+00
# X | val -> R² = -1.2270, MSE = 2.1231e-01
# Y | val -> R² = -2.6675, MSE = 2.7262e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.564354
# Epoch 50 Loss 1.301918
# Epoch 100 Loss 1.290423
# Epoch 150 Loss 1.258515
# Epoch 200 Loss 1.249524
# Epoch 250 Loss 1.214244
# Epoch 300 Loss 1.197228
# Early stopping at epoch 334
# Theta | train1 -> R² = 0.8418, MSE = 3.6190e-02
# X | train1 -> R² = -0.1700, MSE = 1.2578e-01
# Y | train1 -> R² = -1.1816, MSE = 1.8257e-01
# Theta | train2 -> R² = 0.5551, MSE = 1.0122e-01
# X | train2 -> R² = -0.0838, MSE = 9.1212e-02
# Y | train2 -> R² = -0.9730, MSE = 2.1185e-01
# Theta | test1 -> R² = 0.6218, MSE = 8.7066e-02
# X | test1 -> R² = -0.2504, MSE = 1.3058e-01
# Y | test1 -> R² = -1.4196, MSE = 1.9796e-01
# Theta | test2 -> R² = 0.4716, MSE = 1.2491e-01
# X | test2 -> R² = -0.1616, MSE = 9.5480e-02
# Y | test2 -> R² = -1.0372, MSE = 2.1566e-01
# Theta | test3 -> R² = -0.8121, MSE = 5.9646e-01
# X | test3 -> R² = -2.0649, MSE = 2.8121e-01
# Y | test3 -> R² = -6.0057, MSE = 5.3716e-01
# Theta | val -> R² = -14.5592, MSE = 5.0988e+00
# X | val -> R² = -1.1879, MSE = 2.0858e-01
# Y | val -> R² = -4.1423, MSE = 3.8225e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.552294
# Epoch 50 Loss 1.309435
# Epoch 100 Loss 1.294956
# Epoch 150 Loss 1.264177
# Epoch 200 Loss 1.225722
# Epoch 250 Loss 1.204294
# Epoch 300 Loss 1.188045
# Epoch 350 Loss 1.211703
# Epoch 400 Loss 1.182241
# Early stopping at epoch 449
# Theta | train1 -> R² = 0.5968, MSE = 9.2234e-02
# X | train1 -> R² = -0.1902, MSE = 1.2796e-01
# Y | train1 -> R² = -1.0482, MSE = 1.7141e-01
# Theta | train2 -> R² = 0.7458, MSE = 5.7840e-02
# X | train2 -> R² = -0.1163, MSE = 9.3944e-02
# Y | train2 -> R² = -0.7985, MSE = 1.9312e-01
# Theta | test1 -> R² = 0.5024, MSE = 1.1453e-01
# X | test1 -> R² = -0.2532, MSE = 1.3087e-01
# Y | test1 -> R² = -1.3876, MSE = 1.9535e-01
# Theta | test2 -> R² = 0.8418, MSE = 3.7398e-02
# X | test2 -> R² = -0.1951, MSE = 9.8227e-02
# Y | test2 -> R² = -0.7580, MSE = 1.8610e-01
# Theta | test3 -> R² = -1.0766, MSE = 6.8354e-01
# X | test3 -> R² = -1.9621, MSE = 2.7177e-01
# Y | test3 -> R² = -3.4726, MSE = 3.4293e-01
# Theta | val -> R² = -6.8607, MSE = 2.5760e+00
# X | val -> R² = -1.1913, MSE = 2.0891e-01
# Y | val -> R² = -2.4081, MSE = 2.5334e-01
# Figura salva em: ./results/model_32_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.564232
# Epoch 50 Loss 1.315533
# Epoch 100 Loss 1.291252
# Epoch 150 Loss 1.313268
# Epoch 200 Loss 1.222872
# Epoch 250 Loss 1.200890
# Epoch 300 Loss 1.191527
# Epoch 350 Loss 1.174659
# Epoch 400 Loss 1.168082
# Epoch 450 Loss 1.166053
# Early stopping at epoch 462
# Theta | train1 -> R² = 0.6597, MSE = 7.7845e-02
# X | train1 -> R² = -0.3704, MSE = 1.4732e-01
# Y | train1 -> R² = -1.0116, MSE = 1.6835e-01
# Theta | train2 -> R² = 0.5855, MSE = 9.4314e-02
# X | train2 -> R² = -0.1643, MSE = 9.7981e-02
# Y | train2 -> R² = -0.9078, MSE = 2.0485e-01
# Theta | test1 -> R² = 0.6282, MSE = 8.5589e-02
# X | test1 -> R² = -0.4724, MSE = 1.5377e-01
# Y | test1 -> R² = -1.5383, MSE = 2.0767e-01
# Theta | test2 -> R² = 0.7555, MSE = 5.7800e-02
# X | test2 -> R² = -0.2762, MSE = 1.0489e-01
# Y | test2 -> R² = -0.8581, MSE = 1.9670e-01
# Theta | test3 -> R² = -1.4259, MSE = 7.9849e-01
# X | test3 -> R² = -3.3896, MSE = 4.0275e-01
# Y | test3 -> R² = -3.4088, MSE = 3.3804e-01
# Theta | val -> R² = -8.1035, MSE = 2.9832e+00
# X | val -> R² = -2.4651, MSE = 3.3034e-01
# Y | val -> R² = -3.8497, MSE = 3.6050e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.568997
# Epoch 50 Loss 1.306740
# Epoch 100 Loss 1.294506
# Epoch 150 Loss 1.280453
# Epoch 200 Loss 1.231122
# Epoch 250 Loss 1.210009
# Epoch 300 Loss 1.198711
# Epoch 350 Loss 1.189477
# Epoch 400 Loss 1.180117
# Epoch 450 Loss 1.173153
# Early stopping at epoch 487
# Theta | train1 -> R² = 0.6004, MSE = 9.1413e-02
# X | train1 -> R² = -0.1521, MSE = 1.2385e-01
# Y | train1 -> R² = -0.9308, MSE = 1.6159e-01
# Theta | train2 -> R² = 0.2838, MSE = 1.6295e-01
# X | train2 -> R² = -0.0812, MSE = 9.0989e-02
# Y | train2 -> R² = -0.7912, MSE = 1.9233e-01
# Theta | test1 -> R² = 0.8266, MSE = 3.9924e-02
# X | test1 -> R² = -0.2802, MSE = 1.3369e-01
# Y | test1 -> R² = -1.3138, MSE = 1.8931e-01
# Theta | test2 -> R² = 0.5328, MSE = 1.1044e-01
# X | test2 -> R² = -0.1799, MSE = 9.6980e-02
# Y | test2 -> R² = -0.7555, MSE = 1.8584e-01
# Theta | test3 -> R² = -2.1875, MSE = 1.0492e+00
# X | test3 -> R² = -2.0961, MSE = 2.8406e-01
# Y | test3 -> R² = -3.1833, MSE = 3.2075e-01
# Theta | val -> R² = -4.1134, MSE = 1.6757e+00
# X | val -> R² = -1.7603, MSE = 2.6315e-01
# Y | val -> R² = -3.6231, MSE = 3.4365e-01
# Figura salva em: ./results/model_32_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.551257
# Epoch 50 Loss 1.299278
# Epoch 100 Loss 1.284303
# Epoch 150 Loss 1.262952
# Epoch 200 Loss 1.220271
# Epoch 250 Loss 1.207839
# Epoch 300 Loss 1.197652
# Epoch 350 Loss 1.335456
# Epoch 400 Loss 1.202083
# Early stopping at epoch 440
# Theta | train1 -> R² = -2.3778, MSE = 7.7263e-01
# X | train1 -> R² = -0.1400, MSE = 1.2256e-01
# Y | train1 -> R² = -1.1760, MSE = 1.8211e-01
# Theta | train2 -> R² = -3.3224, MSE = 9.8347e-01
# X | train2 -> R² = -0.2055, MSE = 1.0145e-01
# Y | train2 -> R² = -0.8936, MSE = 2.0333e-01
# Theta | test1 -> R² = -2.3156, MSE = 7.6321e-01
# X | test1 -> R² = -0.2628, MSE = 1.3188e-01
# Y | test1 -> R² = -1.6837, MSE = 2.1957e-01
# Theta | test2 -> R² = -3.4020, MSE = 1.0405e+00
# X | test2 -> R² = -0.3083, MSE = 1.0753e-01
# Y | test2 -> R² = -0.8540, MSE = 1.9626e-01
# Theta | test3 -> R² = -0.4003, MSE = 4.6091e-01
# X | test3 -> R² = -3.0974, MSE = 3.7594e-01
# Y | test3 -> R² = -3.6949, MSE = 3.5998e-01
# Theta | val -> R² = -0.6591, MSE = 5.4370e-01
# X | val -> R² = -2.5007, MSE = 3.3373e-01
# Y | val -> R² = -4.5720, MSE = 4.1419e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.653606
# Epoch 50 Loss 1.303190
# Epoch 100 Loss 1.296570
# Epoch 150 Loss 1.284978
# Epoch 200 Loss 1.252890
# Epoch 250 Loss 1.254689
# Epoch 300 Loss 1.198844
# Epoch 350 Loss 1.187108
# Epoch 400 Loss 1.180239
# Epoch 450 Loss 1.171018
# Early stopping at epoch 488
# Theta | train1 -> R² = 0.6411, MSE = 8.2100e-02
# X | train1 -> R² = -0.0833, MSE = 1.1646e-01
# Y | train1 -> R² = -1.2695, MSE = 1.8993e-01
# Theta | train2 -> R² = 0.4255, MSE = 1.3071e-01
# X | train2 -> R² = 0.0729, MSE = 7.8022e-02
# Y | train2 -> R² = -1.0663, MSE = 2.2187e-01
# Theta | test1 -> R² = 0.8404, MSE = 3.6728e-02
# X | test1 -> R² = -0.1018, MSE = 1.1506e-01
# Y | test1 -> R² = -1.8390, MSE = 2.3228e-01
# Theta | test2 -> R² = 0.6359, MSE = 8.6076e-02
# X | test2 -> R² = -0.0074, MSE = 8.2801e-02
# Y | test2 -> R² = -1.0481, MSE = 2.1681e-01
# Theta | test3 -> R² = -6.4463, MSE = 2.4510e+00
# X | test3 -> R² = -1.6981, MSE = 2.4755e-01
# Y | test3 -> R² = -2.8935, MSE = 2.9853e-01
# Theta | val -> R² = -7.0826, MSE = 2.6487e+00
# X | val -> R² = -1.0099, MSE = 1.9162e-01
# Y | val -> R² = -3.7087, MSE = 3.5002e-01
# Figura salva em: ./results/model_64_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.606888
# Epoch 50 Loss 1.302945
# Epoch 100 Loss 1.285984
# Epoch 150 Loss 1.271401
# Epoch 200 Loss 1.233463
# Epoch 250 Loss 1.208423
# Epoch 300 Loss 1.203346
# Epoch 350 Loss 1.211057
# Epoch 400 Loss 1.176117
# Epoch 450 Loss 1.168612
# Early stopping at epoch 455
# Theta | train1 -> R² = -0.3143, MSE = 3.0064e-01
# X | train1 -> R² = -0.0744, MSE = 1.1550e-01
# Y | train1 -> R² = -1.2722, MSE = 1.9016e-01
# Theta | train2 -> R² = -1.3380, MSE = 5.3197e-01
# X | train2 -> R² = -0.1305, MSE = 9.5137e-02
# Y | train2 -> R² = -0.8961, MSE = 2.0360e-01
# Theta | test1 -> R² = -0.6509, MSE = 3.8001e-01
# X | test1 -> R² = -0.2171, MSE = 1.2711e-01
# Y | test1 -> R² = -1.9296, MSE = 2.3969e-01
# Theta | test2 -> R² = -1.1907, MSE = 5.1782e-01
# X | test2 -> R² = -0.2172, MSE = 1.0005e-01
# Y | test2 -> R² = -0.8792, MSE = 1.9893e-01
# Theta | test3 -> R² = 0.1460, MSE = 2.8108e-01
# X | test3 -> R² = -2.2695, MSE = 2.9997e-01
# Y | test3 -> R² = -4.6408, MSE = 4.3251e-01
# Theta | val -> R² = 0.2697, MSE = 2.3931e-01
# X | val -> R² = -1.4606, MSE = 2.3458e-01
# Y | val -> R² = -4.8943, MSE = 4.3815e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.650275
# Epoch 50 Loss 1.302485
# Epoch 100 Loss 1.291270
# Epoch 150 Loss 1.274065
# Epoch 200 Loss 1.244083
# Epoch 250 Loss 1.230361
# Epoch 300 Loss 1.192324
# Epoch 350 Loss 1.180192
# Epoch 400 Loss 1.181331
# Epoch 450 Loss 1.165975
# Early stopping at epoch 478
# Theta | train1 -> R² = -2.4716, MSE = 7.9408e-01
# X | train1 -> R² = 0.2008, MSE = 8.5920e-02
# Y | train1 -> R² = -0.8529, MSE = 1.5507e-01
# Theta | train2 -> R² = -4.1204, MSE = 1.1650e+00
# X | train2 -> R² = 0.1366, MSE = 7.2664e-02
# Y | train2 -> R² = -1.1388, MSE = 2.2966e-01
# Theta | test1 -> R² = -2.3540, MSE = 7.7205e-01
# X | test1 -> R² = 0.1543, MSE = 8.8312e-02
# Y | test1 -> R² = -1.2544, MSE = 1.8445e-01
# Theta | test2 -> R² = -4.5127, MSE = 1.3031e+00
# X | test2 -> R² = 0.0613, MSE = 7.7153e-02
# Y | test2 -> R² = -1.1179, MSE = 2.2420e-01
# Theta | test3 -> R² = 0.3810, MSE = 2.0376e-01
# X | test3 -> R² = -0.8405, MSE = 1.6886e-01
# Y | test3 -> R² = -1.4083, MSE = 1.8466e-01
# Theta | val -> R² = -0.1421, MSE = 3.7427e-01
# X | val -> R² = -0.1300, MSE = 1.0773e-01
# Y | val -> R² = -1.4071, MSE = 1.7893e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.591693
# Epoch 50 Loss 1.301717
# Epoch 100 Loss 1.291462
# Epoch 150 Loss 1.282670
# Epoch 200 Loss 1.259166
# Epoch 250 Loss 1.214139
# Epoch 300 Loss 1.329857
# Epoch 350 Loss 1.217981
# Epoch 400 Loss 1.190900
# Epoch 450 Loss 1.182375
# Epoch 500 Loss 1.176232
# Epoch 550 Loss 1.190653
# Epoch 600 Loss 1.152675
# Early stopping at epoch 609
# Theta | train1 -> R² = -1.2730, MSE = 5.1992e-01
# X | train1 -> R² = -0.1805, MSE = 1.2691e-01
# Y | train1 -> R² = -2.3019, MSE = 2.7633e-01
# Theta | train2 -> R² = -0.9715, MSE = 4.4858e-01
# X | train2 -> R² = -0.4509, MSE = 1.2210e-01
# Y | train2 -> R² = -2.2203, MSE = 3.4578e-01
# Theta | test1 -> R² = 0.4274, MSE = 1.3181e-01
# X | test1 -> R² = -0.0778, MSE = 1.1256e-01
# Y | test1 -> R² = -2.5256, MSE = 2.8845e-01
# Theta | test2 -> R² = -0.4237, MSE = 3.3653e-01
# X | test2 -> R² = -0.4720, MSE = 1.2099e-01
# Y | test2 -> R² = -2.2977, MSE = 3.4910e-01
# Theta | test3 -> R² = -1.0545, MSE = 6.7625e-01
# X | test3 -> R² = -5.4049, MSE = 5.8765e-01
# Y | test3 -> R² = -3.1857, MSE = 3.2093e-01
# Theta | val -> R² = -2.0594, MSE = 1.0026e+00
# X | val -> R² = -1.4232, MSE = 2.3102e-01
# Y | val -> R² = -3.1344, MSE = 3.0732e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.552324
# Epoch 50 Loss 1.312070
# Epoch 100 Loss 1.291632
# Epoch 150 Loss 1.278194
# Epoch 200 Loss 1.263930
# Epoch 250 Loss 1.277381
# Epoch 300 Loss 1.321874
# Epoch 350 Loss 1.212453
# Epoch 400 Loss 1.219388
# Epoch 450 Loss 1.181316
# Epoch 500 Loss 1.179635
# Epoch 550 Loss 1.161363
# Early stopping at epoch 554
# Theta | train1 -> R² = 0.3768, MSE = 1.4256e-01
# X | train1 -> R² = -0.1976, MSE = 1.2875e-01
# Y | train1 -> R² = -1.2812, MSE = 1.9091e-01
# Theta | train2 -> R² = 0.6043, MSE = 9.0035e-02
# X | train2 -> R² = -0.1083, MSE = 9.3272e-02
# Y | train2 -> R² = -1.5712, MSE = 2.7609e-01
# Theta | test1 -> R² = 0.2617, MSE = 1.6995e-01
# X | test1 -> R² = -0.1102, MSE = 1.1594e-01
# Y | test1 -> R² = -1.7408, MSE = 2.2424e-01
# Theta | test2 -> R² = 0.8031, MSE = 4.6539e-02
# X | test2 -> R² = -0.2204, MSE = 1.0031e-01
# Y | test2 -> R² = -1.4529, MSE = 2.5967e-01
# Theta | test3 -> R² = -2.4051, MSE = 1.1208e+00
# X | test3 -> R² = -1.8806, MSE = 2.6429e-01
# Y | test3 -> R² = -3.5295, MSE = 3.4729e-01
# Theta | val -> R² = -9.3520, MSE = 3.3924e+00
# X | val -> R² = -0.3017, MSE = 1.2409e-01
# Y | val -> R² = -3.2482, MSE = 3.1578e-01
# Figura salva em: ./results/model_64_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.537609
# Epoch 50 Loss 1.299463
# Epoch 100 Loss 1.291386
# Epoch 150 Loss 1.281951
# Epoch 200 Loss 1.286760
# Epoch 250 Loss 1.288995
# Epoch 300 Loss 1.213112
# Epoch 350 Loss 1.193977
# Epoch 400 Loss 1.178261
# Epoch 450 Loss 1.181615
# Early stopping at epoch 476
# Theta | train1 -> R² = -0.2125, MSE = 2.7735e-01
# X | train1 -> R² = -0.1255, MSE = 1.2100e-01
# Y | train1 -> R² = -1.0931, MSE = 1.7517e-01
# Theta | train2 -> R² = -0.8520, MSE = 4.2139e-01
# X | train2 -> R² = -0.1379, MSE = 9.5757e-02
# Y | train2 -> R² = -0.8147, MSE = 1.9486e-01
# Theta | test1 -> R² = -0.2983, MSE = 2.9885e-01
# X | test1 -> R² = -0.1960, MSE = 1.2490e-01
# Y | test1 -> R² = -1.6334, MSE = 2.1546e-01
# Theta | test2 -> R² = -0.7764, MSE = 4.1990e-01
# X | test2 -> R² = -0.2143, MSE = 9.9808e-02
# Y | test2 -> R² = -0.7817, MSE = 1.8861e-01
# Theta | test3 -> R² = 0.7297, MSE = 8.8961e-02
# X | test3 -> R² = -2.6577, MSE = 3.3560e-01
# Y | test3 -> R² = -3.6861, MSE = 3.5930e-01
# Theta | val -> R² = -2.6386, MSE = 1.1924e+00
# X | val -> R² = -1.8817, MSE = 2.7473e-01
# Y | val -> R² = -3.9499, MSE = 3.6795e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.527838
# Epoch 50 Loss 1.302157
# Epoch 100 Loss 1.285908
# Epoch 150 Loss 1.270576
# Epoch 200 Loss 1.221302
# Epoch 250 Loss 1.200724
# Epoch 300 Loss 1.185176
# Epoch 350 Loss 1.184056
# Epoch 400 Loss 1.162719
# Early stopping at epoch 417
# Theta | train1 -> R² = 0.6868, MSE = 7.1636e-02
# X | train1 -> R² = -0.1379, MSE = 1.2233e-01
# Y | train1 -> R² = -1.2750, MSE = 1.9039e-01
# Theta | train2 -> R² = 0.1779, MSE = 1.8704e-01
# X | train2 -> R² = -0.0767, MSE = 9.0611e-02
# Y | train2 -> R² = -1.0015, MSE = 2.1491e-01
# Theta | test1 -> R² = 0.7021, MSE = 6.8578e-02
# X | test1 -> R² = -0.2143, MSE = 1.2681e-01
# Y | test1 -> R² = -1.7328, MSE = 2.2358e-01
# Theta | test2 -> R² = 0.2417, MSE = 1.7925e-01
# X | test2 -> R² = -0.1561, MSE = 9.5021e-02
# Y | test2 -> R² = -0.9397, MSE = 2.0534e-01
# Theta | test3 -> R² = 0.2305, MSE = 2.5330e-01
# X | test3 -> R² = -1.8144, MSE = 2.5822e-01
# Y | test3 -> R² = -3.5371, MSE = 3.4788e-01
# Theta | val -> R² = -6.3367, MSE = 2.4042e+00
# X | val -> R² = -1.6560, MSE = 2.5320e-01
# Y | val -> R² = -3.2513, MSE = 3.1601e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.614967
# Epoch 50 Loss 1.297232
# Epoch 100 Loss 1.285238
# Epoch 150 Loss 1.381461
# Epoch 200 Loss 1.204564
# Epoch 250 Loss 1.182123
# Epoch 300 Loss 1.244962
# Epoch 350 Loss 1.211499
# Epoch 400 Loss 1.201399
# Epoch 450 Loss 1.189163
# Early stopping at epoch 458
# Theta | train1 -> R² = 0.2862, MSE = 1.6326e-01
# X | train1 -> R² = -0.1897, MSE = 1.2790e-01
# Y | train1 -> R² = -0.9550, MSE = 1.6361e-01
# Theta | train2 -> R² = 0.3402, MSE = 1.5012e-01
# X | train2 -> R² = -0.0730, MSE = 9.0298e-02
# Y | train2 -> R² = -0.8310, MSE = 1.9661e-01
# Theta | test1 -> R² = 0.6084, MSE = 9.0150e-02
# X | test1 -> R² = -0.1299, MSE = 1.1800e-01
# Y | test1 -> R² = -1.3252, MSE = 1.9024e-01
# Theta | test2 -> R² = 0.3383, MSE = 1.5641e-01
# X | test2 -> R² = -0.1865, MSE = 9.7523e-02
# Y | test2 -> R² = -0.7790, MSE = 1.8833e-01
# Theta | test3 -> R² = -0.3365, MSE = 4.3992e-01
# X | test3 -> R² = -2.5071, MSE = 3.2177e-01
# Y | test3 -> R² = -2.7001, MSE = 2.8370e-01
# Theta | val -> R² = 0.2427, MSE = 2.4818e-01
# X | val -> R² = -0.6564, MSE = 1.5791e-01
# Y | val -> R² = -3.3496, MSE = 3.2332e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.568874
# Epoch 50 Loss 1.305372
# Epoch 100 Loss 1.288584
# Epoch 150 Loss 1.268345
# Epoch 200 Loss 1.235193
# Epoch 250 Loss 1.210856
# Epoch 300 Loss 1.205960
# Epoch 350 Loss 1.200511
# Epoch 400 Loss 1.178681
# Epoch 450 Loss 1.159569
# Early stopping at epoch 467
# Theta | train1 -> R² = -3.3489, MSE = 9.9476e-01
# X | train1 -> R² = -0.2255, MSE = 1.3175e-01
# Y | train1 -> R² = -1.3010, MSE = 1.9257e-01
# Theta | train2 -> R² = -3.7283, MSE = 1.0758e+00
# X | train2 -> R² = -0.1743, MSE = 9.8821e-02
# Y | train2 -> R² = -0.8846, MSE = 2.0237e-01
# Theta | test1 -> R² = -3.7510, MSE = 1.0936e+00
# X | test1 -> R² = -0.2896, MSE = 1.3467e-01
# Y | test1 -> R² = -1.8114, MSE = 2.3002e-01
# Theta | test2 -> R² = -3.6934, MSE = 1.1094e+00
# X | test2 -> R² = -0.2728, MSE = 1.0462e-01
# Y | test2 -> R² = -0.8296, MSE = 1.9368e-01
# Theta | test3 -> R² = -2.9320, MSE = 1.2942e+00
# X | test3 -> R² = -2.4267, MSE = 3.1440e-01
# Y | test3 -> R² = -4.0653, MSE = 3.8838e-01
# Theta | val -> R² = 0.3679, MSE = 2.0712e-01
# X | val -> R² = -1.3570, MSE = 2.2470e-01
# Y | val -> R² = -4.7582, MSE = 4.2802e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.601947
# Epoch 50 Loss 1.314550
# Epoch 100 Loss 1.291510
# Epoch 150 Loss 1.287226
# Epoch 200 Loss 1.325201
# Epoch 250 Loss 1.248698
# Epoch 300 Loss 1.260395
# Epoch 350 Loss 1.206382
# Epoch 400 Loss 1.191107
# Epoch 450 Loss 1.497051
# Epoch 500 Loss 1.416245
# Early stopping at epoch 506
# Theta | train1 -> R² = 0.7613, MSE = 5.4607e-02
# X | train1 -> R² = 0.1224, MSE = 9.4349e-02
# Y | train1 -> R² = -1.8133, MSE = 2.3544e-01
# Theta | train2 -> R² = 0.7752, MSE = 5.1141e-02
# X | train2 -> R² = 0.1050, MSE = 7.5321e-02
# Y | train2 -> R² = -1.7385, MSE = 2.9405e-01
# Theta | test1 -> R² = 0.7063, MSE = 6.7603e-02
# X | test1 -> R² = 0.1447, MSE = 8.9321e-02
# Y | test1 -> R² = -2.3900, MSE = 2.7736e-01
# Theta | test2 -> R² = 0.8735, MSE = 2.9912e-02
# X | test2 -> R² = 0.0103, MSE = 8.1348e-02
# Y | test2 -> R² = -1.6589, MSE = 2.8147e-01
# Theta | test3 -> R² = -3.9608, MSE = 1.6329e+00
# X | test3 -> R² = -1.7351, MSE = 2.5095e-01
# Y | test3 -> R² = -4.6944, MSE = 4.3661e-01
# Theta | val -> R² = -19.1915, MSE = 6.6168e+00
# X | val -> R² = -0.9056, MSE = 1.8166e-01
# Y | val -> R² = -5.2794, MSE = 4.6677e-01
# Figura salva em: ./results/model_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.584219
# Epoch 50 Loss 1.297207
# Epoch 100 Loss 1.283411
# Epoch 150 Loss 1.282289
# Epoch 200 Loss 1.257897
# Epoch 250 Loss 1.233086
# Epoch 300 Loss 1.229716
# Epoch 350 Loss 2.312981
# Epoch 400 Loss 1.243671
# Epoch 450 Loss 1.201527
# Epoch 500 Loss 1.221981
# Early stopping at epoch 523
# Theta | train1 -> R² = 0.7401, MSE = 5.9446e-02
# X | train1 -> R² = -0.8884, MSE = 2.0301e-01
# Y | train1 -> R² = -1.2777, MSE = 1.9062e-01
# Theta | train2 -> R² = 0.3384, MSE = 1.5053e-01
# X | train2 -> R² = -1.0076, MSE = 1.6895e-01
# Y | train2 -> R² = -1.5476, MSE = 2.7355e-01
# Theta | test1 -> R² = 0.7894, MSE = 4.8467e-02
# X | test1 -> R² = -1.1035, MSE = 2.1967e-01
# Y | test1 -> R² = -1.8403, MSE = 2.3238e-01
# Theta | test2 -> R² = 0.4402, MSE = 1.3233e-01
# X | test2 -> R² = -1.1581, MSE = 1.7738e-01
# Y | test2 -> R² = -1.4640, MSE = 2.6084e-01
# Theta | test3 -> R² = -0.4066, MSE = 4.6300e-01
# X | test3 -> R² = -5.4187, MSE = 5.8892e-01
# Y | test3 -> R² = -3.1993, MSE = 3.2198e-01
# Theta | val -> R² = -10.4670, MSE = 3.7578e+00
# X | val -> R² = -3.1999, MSE = 4.0039e-01
# Y | val -> R² = -2.4989, MSE = 2.6009e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.549080
# Epoch 50 Loss 1.307331
# Epoch 100 Loss 1.293579
# Epoch 150 Loss 1.287488
# Epoch 200 Loss 1.289943
# Epoch 250 Loss 1.369791
# Epoch 300 Loss 1.273618
# Epoch 350 Loss 1.249627
# Epoch 400 Loss 1.235551
# Epoch 450 Loss 1.243206
# Epoch 500 Loss 1.255249
# Epoch 550 Loss 1.217585
# Epoch 600 Loss 1.204420
# Epoch 650 Loss 1.194025
# Epoch 700 Loss 1.287577
# Early stopping at epoch 717
# Theta | train1 -> R² = 0.7979, MSE = 4.6224e-02
# X | train1 -> R² = -0.4060, MSE = 1.5115e-01
# Y | train1 -> R² = -0.8877, MSE = 1.5798e-01
# Theta | train2 -> R² = 0.2181, MSE = 1.7790e-01
# X | train2 -> R² = -0.7623, MSE = 1.4831e-01
# Y | train2 -> R² = -0.8413, MSE = 1.9771e-01
# Theta | test1 -> R² = 0.7797, MSE = 5.0704e-02
# X | test1 -> R² = -0.6638, MSE = 1.7375e-01
# Y | test1 -> R² = -1.1653, MSE = 1.7716e-01
# ...
# Theta | test2 -> R² = -1.1117, MSE = 4.9916e-01
# X | test2 -> R² = -0.2024, MSE = 9.8828e-02
# Y | test2 -> R² = -0.8666, MSE = 1.9760e-01
# Theta | test3 -> R² = -1.1821, MSE = 7.1826e-01
# X | test3 -> R² = -1.4335, MSE = 2.2327e-01
# Y | test3 -> R² = -3.4367, MSE = 3.4018e-01
# Theta | val -> R² = 0.5008, MSE = 1.6360e-01
# X | val -> R² = -0.7646, MSE = 1.6823e-01
# Y | val -> R² = -2.4241, MSE = 2.5453e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.580486
# Epoch 50 Loss 1.297317
# Epoch 100 Loss 1.224260
# Epoch 150 Loss 1.202473
# Epoch 200 Loss 1.197107
# Epoch 250 Loss 1.197480
# Epoch 300 Loss 1.181524
# Early stopping at epoch 314
# Theta | train1 -> R² = -1.3246, MSE = 5.3173e-01
# X | train1 -> R² = 0.2108, MSE = 8.4840e-02
# Y | train1 -> R² = -0.8979, MSE = 1.5883e-01
# Theta | train2 -> R² = -1.9999, MSE = 6.8255e-01
# X | train2 -> R² = 0.0747, MSE = 7.7868e-02
# Y | train2 -> R² = -1.0094, MSE = 2.1576e-01
# Theta | test1 -> R² = -1.3973, MSE = 5.5183e-01
# X | test1 -> R² = 0.0661, MSE = 9.7526e-02
# Y | test1 -> R² = -1.2522, MSE = 1.8426e-01
# Theta | test2 -> R² = -1.1338, MSE = 5.0439e-01
# X | test2 -> R² = 0.0477, MSE = 7.8275e-02
# Y | test2 -> R² = -1.0384, MSE = 2.1579e-01
# Theta | test3 -> R² = -0.9325, MSE = 6.3610e-01
# X | test3 -> R² = -0.2474, MSE = 1.1445e-01
# Y | test3 -> R² = -2.9408, MSE = 3.0216e-01
# Theta | val -> R² = -4.9760, MSE = 1.9584e+00
# X | val -> R² = -0.3534, MSE = 1.2902e-01
# Y | val -> R² = -2.6194, MSE = 2.6904e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.552390
# Epoch 50 Loss 1.293133
# Epoch 100 Loss 1.236694
# Epoch 150 Loss 1.226333
# Epoch 200 Loss 1.174511
# Epoch 250 Loss 1.167269
# Epoch 300 Loss 1.151408
# Epoch 350 Loss 1.187330
# Early stopping at epoch 374
# Theta | train1 -> R² = 0.5584, MSE = 1.0101e-01
# X | train1 -> R² = -0.3920, MSE = 1.4965e-01
# Y | train1 -> R² = -1.1570, MSE = 1.8052e-01
# Theta | train2 -> R² = -0.0798, MSE = 2.4567e-01
# X | train2 -> R² = -0.2292, MSE = 1.0345e-01
# Y | train2 -> R² = -1.1022, MSE = 2.2573e-01
# Theta | test1 -> R² = 0.6636, MSE = 7.7441e-02
# X | test1 -> R² = -0.5201, MSE = 1.5874e-01
# Y | test1 -> R² = -1.5768, MSE = 2.1082e-01
# Theta | test2 -> R² = 0.0147, MSE = 2.3289e-01
# X | test2 -> R² = -0.2997, MSE = 1.0682e-01
# Y | test2 -> R² = -1.0827, MSE = 2.2047e-01
# Theta | test3 -> R² = 0.0039, MSE = 3.2788e-01
# X | test3 -> R² = -2.7482, MSE = 3.4390e-01
# Y | test3 -> R² = -3.4237, MSE = 3.3918e-01
# Theta | val -> R² = -2.6251, MSE = 1.1879e+00
# X | val -> R² = -1.9188, MSE = 2.7826e-01
# Y | val -> R² = -3.7398, MSE = 3.5233e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.577893
# Epoch 50 Loss 1.309493
# Epoch 100 Loss 1.265202
# Epoch 150 Loss 1.220024
# Epoch 200 Loss 1.200623
# Epoch 250 Loss 1.208353
# Epoch 300 Loss 1.190968
# Epoch 350 Loss 1.169337
# Early stopping at epoch 364
# Theta | train1 -> R² = -2.3629, MSE = 7.6921e-01
# X | train1 -> R² = -0.4812, MSE = 1.5924e-01
# Y | train1 -> R² = -1.0122, MSE = 1.6840e-01
# Theta | train2 -> R² = -2.6066, MSE = 8.2060e-01
# X | train2 -> R² = -0.2487, MSE = 1.0508e-01
# Y | train2 -> R² = -0.9239, MSE = 2.0658e-01
# Theta | test1 -> R² = -3.0112, MSE = 9.2333e-01
# X | test1 -> R² = -0.5405, MSE = 1.6088e-01
# Y | test1 -> R² = -1.5034, MSE = 2.0481e-01
# Theta | test2 -> R² = -2.9756, MSE = 9.3974e-01
# X | test2 -> R² = -0.3833, MSE = 1.1370e-01
# Y | test2 -> R² = -0.8990, MSE = 2.0103e-01
# Theta | test3 -> R² = 0.3714, MSE = 2.0690e-01
# X | test3 -> R² = -3.5449, MSE = 4.1700e-01
# Y | test3 -> R² = -3.1387, MSE = 3.1733e-01
# Theta | val -> R² = 0.6916, MSE = 1.0107e-01
# X | val -> R² = -1.7930, MSE = 2.6627e-01
# Y | val -> R² = -3.0052, MSE = 2.9772e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.546589
# Epoch 50 Loss 1.296551
# Epoch 100 Loss 1.225256
# Epoch 150 Loss 1.215259
# Epoch 200 Loss 1.199336
# Epoch 250 Loss 1.199898
# Epoch 300 Loss 1.200530
# Early stopping at epoch 343
# Theta | train1 -> R² = 0.9589, MSE = 9.4076e-03
# X | train1 -> R² = -0.1447, MSE = 1.2306e-01
# Y | train1 -> R² = -1.0639, MSE = 1.7273e-01
# Theta | train2 -> R² = 0.7656, MSE = 5.3328e-02
# X | train2 -> R² = -0.0688, MSE = 8.9942e-02
# Y | train2 -> R² = -1.1123, MSE = 2.2681e-01
# Theta | test1 -> R² = 0.8119, MSE = 4.3309e-02
# X | test1 -> R² = -0.2474, MSE = 1.3026e-01
# Y | test1 -> R² = -1.4975, MSE = 2.0433e-01
# Theta | test2 -> R² = 0.8389, MSE = 3.8082e-02
# X | test2 -> R² = -0.1533, MSE = 9.4798e-02
# Y | test2 -> R² = -1.1888, MSE = 2.3171e-01
# Theta | test3 -> R² = 0.0738, MSE = 3.0488e-01
# X | test3 -> R² = -1.6136, MSE = 2.3980e-01
# Y | test3 -> R² = -2.9709, MSE = 3.0447e-01
# Theta | val -> R² = -2.3845, MSE = 1.1091e+00
# X | val -> R² = -0.8466, MSE = 1.7604e-01
# Y | val -> R² = -3.0966, MSE = 3.0452e-01
# Figura salva em: ./results/model_128_64_32_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.642849
# Epoch 50 Loss 1.304458
# Epoch 100 Loss 1.293860
# Epoch 150 Loss 1.280815
# Epoch 200 Loss 1.267305
# Epoch 250 Loss 1.285737
# Epoch 300 Loss 1.245418
# Early stopping at epoch 325
# Theta | train1 -> R² = -0.3899, MSE = 3.1791e-01
# X | train1 -> R² = -0.0973, MSE = 1.1796e-01
# Y | train1 -> R² = -0.8250, MSE = 1.5273e-01
# Theta | train2 -> R² = -0.1032, MSE = 2.5100e-01
# X | train2 -> R² = -0.1340, MSE = 9.5434e-02
# Y | train2 -> R² = -0.9572, MSE = 2.1015e-01
# Theta | test1 -> R² = -0.2897, MSE = 2.9687e-01
# X | test1 -> R² = -0.2872, MSE = 1.3442e-01
# Y | test1 -> R² = -1.1871, MSE = 1.7894e-01
# Theta | test2 -> R² = 0.3261, MSE = 1.5930e-01
# X | test2 -> R² = -0.2089, MSE = 9.9365e-02
# Y | test2 -> R² = -0.9837, MSE = 2.0999e-01
# Theta | test3 -> R² = 0.1229, MSE = 2.8872e-01
# X | test3 -> R² = -2.6122, MSE = 3.3142e-01
# Y | test3 -> R² = -2.1775, MSE = 2.4363e-01
# Theta | val -> R² = -2.4452, MSE = 1.1290e+00
# X | val -> R² = -1.0052, MSE = 1.9117e-01
# Y | val -> R² = -1.6999, MSE = 2.0069e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.683460
# Epoch 50 Loss 1.365638
# Epoch 100 Loss 1.284331
# Epoch 150 Loss 1.274766
# Epoch 200 Loss 1.335813
# Epoch 250 Loss 1.232752
# Epoch 300 Loss 1.226655
# Early stopping at epoch 347
# Theta | train1 -> R² = 0.3257, MSE = 1.5425e-01
# X | train1 -> R² = 0.3429, MSE = 7.0644e-02
# Y | train1 -> R² = -0.9925, MSE = 1.6675e-01
# Theta | train2 -> R² = 0.8279, MSE = 3.9157e-02
# X | train2 -> R² = 0.0423, MSE = 8.0595e-02
# Y | train2 -> R² = -0.7318, MSE = 1.8596e-01
# Theta | test1 -> R² = 0.3503, MSE = 1.4955e-01
# X | test1 -> R² = 0.2389, MSE = 7.9483e-02
# Y | test1 -> R² = -1.2661, MSE = 1.8540e-01
# Theta | test2 -> R² = 0.8217, MSE = 4.2144e-02
# X | test2 -> R² = 0.0317, MSE = 7.9591e-02
# Y | test2 -> R² = -0.8173, MSE = 1.9238e-01
# Theta | test3 -> R² = 0.3497, MSE = 2.1404e-01
# X | test3 -> R² = -0.9884, MSE = 1.8244e-01
# Y | test3 -> R² = -6.0304, MSE = 5.3905e-01
# Theta | val -> R² = 0.0358, MSE = 3.1596e-01
# X | val -> R² = -0.1262, MSE = 1.0736e-01
# Y | val -> R² = -4.2619, MSE = 3.9114e-01
# Figura salva em: ./results/model_264_128_64_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.584157
# Epoch 50 Loss 1.423484
# Epoch 100 Loss 1.311987
# Epoch 150 Loss 1.276446
# Epoch 200 Loss 1.265285
# Epoch 250 Loss 1.227876
# Epoch 300 Loss 1.241242
# Epoch 350 Loss 1.221546
# Early stopping at epoch 380
# Theta | train1 -> R² = 0.1908, MSE = 1.8509e-01
# X | train1 -> R² = -0.2858, MSE = 1.3823e-01
# Y | train1 -> R² = -1.3810, MSE = 1.9927e-01
# Theta | train2 -> R² = 0.7324, MSE = 6.0895e-02
# X | train2 -> R² = -0.1594, MSE = 9.7574e-02
# Y | train2 -> R² = -1.1286, MSE = 2.2857e-01
# Theta | test1 -> R² = -0.2803, MSE = 2.9471e-01
# X | test1 -> R² = -0.5573, MSE = 1.6263e-01
# Y | test1 -> R² = -1.7578, MSE = 2.2563e-01
# Theta | test2 -> R² = 0.8445, MSE = 3.6762e-02
# X | test2 -> R² = -0.2433, MSE = 1.0219e-01
# Y | test2 -> R² = -1.1961, MSE = 2.3248e-01
# Theta | test3 -> R² = -1.8822, MSE = 9.4869e-01
# X | test3 -> R² = -1.7612, MSE = 2.5334e-01
# Y | test3 -> R² = -6.8118, MSE = 5.9896e-01
# Theta | val -> R² = -5.8652, MSE = 2.2497e+00
# X | val -> R² = -1.8208, MSE = 2.6892e-01
# Y | val -> R² = -4.2035, MSE = 3.8680e-01
# Figura salva em: ./results/model_264_128_64_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.628423
# Epoch 50 Loss 1.470204
# Epoch 100 Loss 1.486490
# Epoch 150 Loss 1.467882
# Epoch 200 Loss 1.446256
# Epoch 250 Loss 1.469714
# Epoch 300 Loss 1.469270
# Epoch 350 Loss 1.465677
# Epoch 400 Loss 1.473230
# Epoch 450 Loss 1.465842
# Epoch 500 Loss 1.354954
# Epoch 550 Loss 1.221291
# Epoch 600 Loss 1.205356
# Epoch 650 Loss 1.209146
# Epoch 700 Loss 1.198183
# Epoch 750 Loss 1.181543
# Epoch 800 Loss 1.201087
# Early stopping at epoch 819
# Theta | train1 -> R² = 0.3273, MSE = 1.5387e-01
# X | train1 -> R² = -0.0342, MSE = 1.1118e-01
# Y | train1 -> R² = -0.7936, MSE = 1.5010e-01
# Theta | train2 -> R² = 0.6904, MSE = 7.0448e-02
# X | train2 -> R² = -0.3291, MSE = 1.1185e-01
# Y | train2 -> R² = -0.6301, MSE = 1.7503e-01
# Theta | test1 -> R² = 0.7690, MSE = 5.3183e-02
# X | test1 -> R² = -0.1796, MSE = 1.2319e-01
# Y | test1 -> R² = -1.1574, MSE = 1.7651e-01
# Theta | test2 -> R² = 0.8272, MSE = 4.0851e-02
# X | test2 -> R² = -0.4457, MSE = 1.1883e-01
# Y | test2 -> R² = -0.7392, MSE = 1.8411e-01
# Theta | test3 -> R² = -3.7732, MSE = 1.5711e+00
# X | test3 -> R² = -4.2568, MSE = 4.8231e-01
# Y | test3 -> R² = -4.4946, MSE = 4.2130e-01
# Theta | val -> R² = -2.1934, MSE = 1.0465e+00
# X | val -> R² = -0.3142, MSE = 1.2528e-01
# Y | val -> R² = -3.5737, MSE = 3.3998e-01
# Figura salva em: ./results/model_264_128_64_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.543193
# Epoch 50 Loss 1.470831
# Epoch 100 Loss 1.464393
# Epoch 150 Loss 1.469166
# Epoch 200 Loss 1.482153
# Epoch 250 Loss 1.470718
# Epoch 300 Loss 1.471099
# Epoch 350 Loss 1.470067
# Epoch 400 Loss 1.467848
# Early stopping at epoch 407
# Theta | train1 -> R² = -1.3186, MSE = 5.3036e-01
# X | train1 -> R² = -0.7777, MSE = 1.9111e-01
# Y | train1 -> R² = -1.1563, MSE = 1.8046e-01
# Theta | train2 -> R² = -0.1295, MSE = 2.5699e-01
# X | train2 -> R² = -0.5144, MSE = 1.2744e-01
# Y | train2 -> R² = -1.6318, MSE = 2.8260e-01
# Theta | test1 -> R² = -0.7622, MSE = 4.0564e-01
# X | test1 -> R² = -0.9736, MSE = 2.0611e-01
# Y | test1 -> R² = -1.4730, MSE = 2.0233e-01
# Theta | test2 -> R² = -0.1333, MSE = 2.6790e-01
# X | test2 -> R² = -0.4712, MSE = 1.2092e-01
# Y | test2 -> R² = -1.5720, MSE = 2.7227e-01
# Theta | test3 -> R² = -0.4634, MSE = 4.8170e-01
# X | test3 -> R² = -1.4952, MSE = 2.2894e-01
# Y | test3 -> R² = -2.8591, MSE = 2.9589e-01
# Theta | val -> R² = -0.3247, MSE = 4.3409e-01
# X | val -> R² = -1.8236, MSE = 2.6918e-01
# Y | val -> R² = -2.8515, MSE = 2.8629e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.594713
# Epoch 50 Loss 1.380436
# Epoch 100 Loss 1.286206
# Epoch 150 Loss 1.271985
# Epoch 200 Loss 1.247323
# Epoch 250 Loss 1.240713
# Epoch 300 Loss 1.247768
# Epoch 350 Loss 1.226239
# Early stopping at epoch 360
# Theta | train1 -> R² = -2.8345, MSE = 8.7710e-01
# X | train1 -> R² = -0.1351, MSE = 1.2203e-01
# Y | train1 -> R² = -0.6384, MSE = 1.3712e-01
# Theta | train2 -> R² = -2.8367, MSE = 8.7296e-01
# X | train2 -> R² = -0.0152, MSE = 8.5436e-02
# Y | train2 -> R² = -0.5591, MSE = 1.6741e-01
# Theta | test1 -> R² = -1.8001, MSE = 6.4455e-01
# X | test1 -> R² = -0.2753, MSE = 1.3318e-01
# Y | test1 -> R² = -0.8590, MSE = 1.5210e-01
# Theta | test2 -> R² = -1.1727, MSE = 5.1357e-01
# X | test2 -> R² = -0.0637, MSE = 8.7434e-02
# Y | test2 -> R² = -0.5893, MSE = 1.6824e-01
# Theta | test3 -> R² = -29.4898, MSE = 1.0036e+01
# X | test3 -> R² = -2.1745, MSE = 2.9126e-01
# Y | test3 -> R² = -5.6302, MSE = 5.0836e-01
# Theta | val -> R² = -5.5335, MSE = 2.1410e+00
# X | val -> R² = -0.5426, MSE = 1.4706e-01
# Y | val -> R² = -2.3282, MSE = 2.4739e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.610283
# Epoch 50 Loss 1.460423
# Epoch 100 Loss 1.331540
# Epoch 150 Loss 1.306055
# Epoch 200 Loss 1.231578
# Epoch 250 Loss 1.210778
# Epoch 300 Loss 1.202368
# Epoch 350 Loss 1.205239
# Epoch 400 Loss 1.186425
# Early stopping at epoch 443
# Theta | train1 -> R² = 0.9190, MSE = 1.8528e-02
# X | train1 -> R² = -0.1681, MSE = 1.2558e-01
# Y | train1 -> R² = -0.8599, MSE = 1.5565e-01
# Theta | train2 -> R² = 0.7122, MSE = 6.5491e-02
# X | train2 -> R² = -0.0221, MSE = 8.6014e-02
# Y | train2 -> R² = -0.9858, MSE = 2.1323e-01
# Theta | test1 -> R² = 0.6298, MSE = 8.5216e-02
# X | test1 -> R² = -0.2587, MSE = 1.3145e-01
# Y | test1 -> R² = -1.2507, MSE = 1.8414e-01
# Theta | test2 -> R² = 0.8557, MSE = 3.4116e-02
# X | test2 -> R² = -0.1100, MSE = 9.1237e-02
# Y | test2 -> R² = -1.0865, MSE = 2.2088e-01
# Theta | test3 -> R² = 0.5204, MSE = 1.5787e-01
# X | test3 -> R² = -0.6392, MSE = 1.5040e-01
# Y | test3 -> R² = -1.4650, MSE = 1.8900e-01
# Theta | val -> R² = -2.5117, MSE = 1.1508e+00
# X | val -> R² = -0.6234, MSE = 1.5477e-01
# Y | val -> R² = -1.9124, MSE = 2.1649e-01
# Figura salva em: ./results/model_264_128_64_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.593992
# Epoch 50 Loss 1.388688
# Epoch 100 Loss 1.313414
# Epoch 150 Loss 1.279070
# Epoch 200 Loss 1.263732
# Epoch 250 Loss 1.236707
# Epoch 300 Loss 1.275808
# Epoch 350 Loss 1.220579
# Early stopping at epoch 373
# Theta | train1 -> R² = 0.8943, MSE = 2.4173e-02
# X | train1 -> R² = -0.2402, MSE = 1.3333e-01
# Y | train1 -> R² = -1.1161, MSE = 1.7709e-01
# Theta | train2 -> R² = 0.6174, MSE = 8.7042e-02
# X | train2 -> R² = -0.0880, MSE = 9.1562e-02
# Y | train2 -> R² = -0.9585, MSE = 2.1029e-01
# Theta | test1 -> R² = 0.8092, MSE = 4.3919e-02
# X | test1 -> R² = -0.4133, MSE = 1.4759e-01
# Y | test1 -> R² = -1.3830, MSE = 1.9497e-01
# Theta | test2 -> R² = 0.6766, MSE = 7.6453e-02
# X | test2 -> R² = -0.1407, MSE = 9.3762e-02
# Y | test2 -> R² = -1.0567, MSE = 2.1772e-01
# Theta | test3 -> R² = 0.7443, MSE = 8.4161e-02
# X | test3 -> R² = -2.7979, MSE = 3.4846e-01
# Y | test3 -> R² = -7.6655, MSE = 6.6442e-01
# Theta | val -> R² = 0.1752, MSE = 2.7027e-01
# X | val -> R² = -1.3859, MSE = 2.2745e-01
# Y | val -> R² = -4.0673, MSE = 3.7667e-01
# Figura salva em: ./results/model_264_128_64_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.546639
# Epoch 50 Loss 1.470059
# Epoch 100 Loss 1.468773
# Epoch 150 Loss 1.476221
# Epoch 200 Loss 1.469788
# Epoch 250 Loss 1.467743
# Epoch 300 Loss 1.446034
# Epoch 350 Loss 1.426191
# Epoch 400 Loss 1.377037
# Epoch 450 Loss 1.273074
# Epoch 500 Loss 1.235557
# Epoch 550 Loss 1.212533
# Epoch 600 Loss 1.208801
# Epoch 650 Loss 1.209267
# Epoch 700 Loss 1.202662
# Epoch 750 Loss 1.199103
# Early stopping at epoch 758
# Theta | train1 -> R² = -6.6103, MSE = 1.7408e+00
# X | train1 -> R² = -0.2042, MSE = 1.2946e-01
# Y | train1 -> R² = -1.0290, MSE = 1.6980e-01
# Theta | train2 -> R² = -5.1010, MSE = 1.3881e+00
# X | train2 -> R² = -0.1342, MSE = 9.5448e-02
# Y | train2 -> R² = -0.7730, MSE = 1.9038e-01
# Theta | test1 -> R² = -6.1112, MSE = 1.6369e+00
# X | test1 -> R² = -0.3625, MSE = 1.4229e-01
# Y | test1 -> R² = -1.3416, MSE = 1.9158e-01
# Theta | test2 -> R² = -3.9275, MSE = 1.1647e+00
# X | test2 -> R² = -0.1926, MSE = 9.8028e-02
# Y | test2 -> R² = -0.9197, MSE = 2.0323e-01
# Theta | test3 -> R² = 0.1557, MSE = 2.7790e-01
# X | test3 -> R² = -2.1827, MSE = 2.9201e-01
# Y | test3 -> R² = -5.3661, MSE = 4.8812e-01
# Theta | val -> R² = -0.7754, MSE = 5.8181e-01
# X | val -> R² = -0.5174, MSE = 1.4466e-01
# Y | val -> R² = -2.4998, MSE = 2.6015e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.534418
# Epoch 50 Loss 1.466754
# Epoch 100 Loss 1.472791
# Epoch 150 Loss 1.470480
# Epoch 200 Loss 1.471752
# Epoch 250 Loss 1.469159
# Epoch 300 Loss 1.469056
# Early stopping at epoch 304
# Theta | train1 -> R² = 0.2743, MSE = 1.6600e-01
# X | train1 -> R² = 0.6078, MSE = 4.2167e-02
# Y | train1 -> R² = -1.1995, MSE = 1.8408e-01
# Theta | train2 -> R² = -3.3586, MSE = 9.9169e-01
# X | train2 -> R² = -1.0002, MSE = 1.6833e-01
# Y | train2 -> R² = -1.1725, MSE = 2.3328e-01
# Theta | test1 -> R² = 0.2221, MSE = 1.7907e-01
# X | test1 -> R² = 0.4165, MSE = 6.0939e-02
# Y | test1 -> R² = -1.4073, MSE = 1.9696e-01
# Theta | test2 -> R² = -3.1870, MSE = 9.8970e-01
# X | test2 -> R² = -1.0190, MSE = 1.6595e-01
# Y | test2 -> R² = -1.2078, MSE = 2.3372e-01
# Theta | test3 -> R² = -4.8460, MSE = 1.9243e+00
# X | test3 -> R² = -25.1178, MSE = 2.3963e+00
# Y | test3 -> R² = -6.6455, MSE = 5.8622e-01
# Theta | val -> R² = -1.6000, MSE = 8.5203e-01
# X | val -> R² = -7.8443, MSE = 8.4316e-01
# Y | val -> R² = -3.5685, MSE = 3.3959e-01
# Modelo 9 treinado e salvo no Excel
