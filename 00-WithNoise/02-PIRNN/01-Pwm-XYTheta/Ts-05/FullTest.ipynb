# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 5
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 2)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada: (1266, 5, 2)
# Dimensão da saida: (1266, 5, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 2)
# Dimensão da saida: (1947, 3)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[8], [16], [32], [64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 Loss 1.573986
# Epoch 50 Loss 1.348346
# Epoch 100 Loss 1.329843
# Epoch 150 Loss 1.324493
# Epoch 200 Loss 1.320455
# Epoch 250 Loss 1.313834
# Epoch 300 Loss 1.293449
# Epoch 350 Loss 1.286519
# Epoch 400 Loss 1.273868
# Epoch 450 Loss 1.265318
# Early stopping at epoch 477
# Theta | train1 -> R² = 0.8769, MSE = 2.8168e-02
# X | train1 -> R² = -0.2659, MSE = 1.3609e-01
# Y | train1 -> R² = -1.1415, MSE = 1.7922e-01
# Theta | train2 -> R² = 0.4730, MSE = 1.1990e-01
# X | train2 -> R² = -0.1541, MSE = 9.7122e-02
# Y | train2 -> R² = -0.8487, MSE = 1.9850e-01
# Theta | test1 -> R² = 0.7532, MSE = 5.6801e-02
# X | test1 -> R² = -0.4186, MSE = 1.4814e-01
# Y | test1 -> R² = -1.4827, MSE = 2.0312e-01
# Theta | test2 -> R² = 0.3129, MSE = 1.6242e-01
# X | test2 -> R² = -0.2230, MSE = 1.0052e-01
# Y | test2 -> R² = -0.9046, MSE = 2.0163e-01
# Theta | test3 -> R² = 0.6026, MSE = 1.3081e-01
# X | test3 -> R² = -1.7549, MSE = 2.5276e-01
# Y | test3 -> R² = -4.8451, MSE = 4.4817e-01
# Theta | val -> R² = -1.1307, MSE = 6.9823e-01
# X | val -> R² = -1.3807, MSE = 2.2696e-01
# Y | val -> R² = -4.2638, MSE = 3.9128e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.585162
# Epoch 50 Loss 1.326392
# Epoch 100 Loss 1.282101
# Epoch 150 Loss 1.255131
# Epoch 200 Loss 1.236791
# Epoch 250 Loss 1.229689
# Epoch 300 Loss 1.222019
# Epoch 350 Loss 1.216493
# Early stopping at epoch 355
# Theta | train1 -> R² = 0.8853, MSE = 2.6244e-02
# X | train1 -> R² = -0.2564, MSE = 1.3507e-01
# Y | train1 -> R² = -0.9292, MSE = 1.6145e-01
# Theta | train2 -> R² = 0.7157, MSE = 6.4692e-02
# X | train2 -> R² = -0.1154, MSE = 9.3869e-02
# Y | train2 -> R² = -0.6331, MSE = 1.7535e-01
# Theta | test1 -> R² = 0.8270, MSE = 3.9819e-02
# X | test1 -> R² = -0.3470, MSE = 1.4066e-01
# Y | test1 -> R² = -1.1804, MSE = 1.7839e-01
# Theta | test2 -> R² = 0.7745, MSE = 5.3300e-02
# X | test2 -> R² = -0.1902, MSE = 9.7827e-02
# Y | test2 -> R² = -0.6909, MSE = 1.7900e-01
# Theta | test3 -> R² = -0.0033, MSE = 3.3023e-01
# X | test3 -> R² = -2.3157, MSE = 3.0421e-01
# Y | test3 -> R² = -4.7671, MSE = 4.4219e-01
# Theta | val -> R² = -7.1566, MSE = 2.6729e+00
# X | val -> R² = -1.2490, MSE = 2.1441e-01
# Y | val -> R² = -3.4097, MSE = 3.2779e-01
# Figura salva em: ./results/model_8_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.571104
# Epoch 50 Loss 1.311537
# Epoch 100 Loss 1.280946
# Epoch 150 Loss 1.233229
# Epoch 200 Loss 1.215652
# Epoch 250 Loss 1.208909
# Epoch 300 Loss 1.204335
# Early stopping at epoch 348
# Theta | train1 -> R² = 0.7270, MSE = 6.2450e-02
# X | train1 -> R² = -0.1306, MSE = 1.2155e-01
# Y | train1 -> R² = -1.1513, MSE = 1.8004e-01
# Theta | train2 -> R² = 0.8191, MSE = 4.1160e-02
# X | train2 -> R² = -0.0675, MSE = 8.9839e-02
# Y | train2 -> R² = -0.8931, MSE = 2.0328e-01
# Theta | test1 -> R² = 0.4031, MSE = 1.3741e-01
# X | test1 -> R² = -0.2073, MSE = 1.2608e-01
# Y | test1 -> R² = -1.4173, MSE = 1.9777e-01
# Theta | test2 -> R² = 0.8331, MSE = 3.9458e-02
# X | test2 -> R² = -0.1515, MSE = 9.4647e-02
# Y | test2 -> R² = -0.9818, MSE = 2.0979e-01
# Theta | test3 -> R² = -3.2731, MSE = 1.4065e+00
# X | test3 -> R² = -1.6224, MSE = 2.4061e-01
# Y | test3 -> R² = -4.8785, MSE = 4.5073e-01
# Theta | val -> R² = -15.4060, MSE = 5.3763e+00
# X | val -> R² = -0.9787, MSE = 1.8864e-01
# Y | val -> R² = -4.0979, MSE = 3.7894e-01
# Figura salva em: ./results/model_8_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.551327
# Epoch 50 Loss 1.416725
# Epoch 100 Loss 1.309940
# Epoch 150 Loss 1.298951
# Epoch 200 Loss 1.277994
# Epoch 250 Loss 1.240168
# Epoch 300 Loss 1.219839
# Epoch 350 Loss 1.207348
# Early stopping at epoch 373
# Theta | train1 -> R² = 0.9206, MSE = 1.8166e-02
# X | train1 -> R² = -0.2483, MSE = 1.3420e-01
# Y | train1 -> R² = -1.0870, MSE = 1.7466e-01
# Theta | train2 -> R² = 0.5859, MSE = 9.4213e-02
# X | train2 -> R² = -0.1026, MSE = 9.2788e-02
# Y | train2 -> R² = -0.8094, MSE = 1.9429e-01
# Theta | test1 -> R² = 0.8110, MSE = 4.3509e-02
# X | test1 -> R² = -0.3529, MSE = 1.4128e-01
# Y | test1 -> R² = -1.3392, MSE = 1.9138e-01
# Theta | test2 -> R² = 0.7129, MSE = 6.7858e-02
# X | test2 -> R² = -0.1733, MSE = 9.6437e-02
# Y | test2 -> R² = -0.8565, MSE = 1.9653e-01
# Theta | test3 -> R² = 0.7188, MSE = 9.2553e-02
# X | test3 -> R² = -2.5506, MSE = 3.2577e-01
# Y | test3 -> R² = -5.8279, MSE = 5.2353e-01
# Theta | val -> R² = -1.7018, MSE = 8.8537e-01
# X | val -> R² = -1.7036, MSE = 2.5774e-01
# Y | val -> R² = -3.9076, MSE = 3.6480e-01
# Figura salva em: ./results/model_8_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.573501
# Epoch 50 Loss 1.342797
# Epoch 100 Loss 1.327007
# Epoch 150 Loss 1.294242
# Epoch 200 Loss 1.260674
# Epoch 250 Loss 1.236332
# Epoch 300 Loss 1.223629
# Epoch 350 Loss 1.213304
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.7709, MSE = 5.2406e-02
# X | train1 -> R² = -0.1430, MSE = 1.2288e-01
# Y | train1 -> R² = -0.9800, MSE = 1.6571e-01
# Theta | train2 -> R² = 0.7536, MSE = 5.6061e-02
# X | train2 -> R² = -0.0962, MSE = 9.2249e-02
# Y | train2 -> R² = -0.7047, MSE = 1.8305e-01
# Theta | test1 -> R² = 0.4305, MSE = 1.3110e-01
# X | test1 -> R² = -0.2768, MSE = 1.3334e-01
# Y | test1 -> R² = -1.2704, MSE = 1.8575e-01
# Theta | test2 -> R² = 0.8317, MSE = 3.9788e-02
# X | test2 -> R² = -0.1786, MSE = 9.6877e-02
# Y | test2 -> R² = -0.7911, MSE = 1.8961e-01
# Theta | test3 -> R² = 0.1202, MSE = 2.8958e-01
# X | test3 -> R² = -1.9615, MSE = 2.7172e-01
# Y | test3 -> R² = -5.1146, MSE = 4.6884e-01
# Theta | val -> R² = -6.6871, MSE = 2.5191e+00
# X | val -> R² = -1.5039, MSE = 2.3870e-01
# Y | val -> R² = -4.0292, MSE = 3.7384e-01
# Figura salva em: ./results/model_8_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.590985
# Epoch 50 Loss 1.347775
# Epoch 100 Loss 1.324270
# Epoch 150 Loss 1.294992
# Epoch 200 Loss 1.273530
# Epoch 250 Loss 1.249610
# Epoch 300 Loss 1.236012
# Epoch 350 Loss 1.225085
# Early stopping at epoch 373
# Theta | train1 -> R² = 0.8577, MSE = 3.2555e-02
# X | train1 -> R² = -0.1433, MSE = 1.2291e-01
# Y | train1 -> R² = -0.9630, MSE = 1.6428e-01
# Theta | train2 -> R² = 0.7178, MSE = 6.4213e-02
# X | train2 -> R² = -0.1330, MSE = 9.5348e-02
# Y | train2 -> R² = -0.7175, MSE = 1.8442e-01
# Theta | test1 -> R² = 0.6829, MSE = 7.3002e-02
# X | test1 -> R² = -0.3003, MSE = 1.3579e-01
# Y | test1 -> R² = -1.2912, MSE = 1.8745e-01
# Theta | test2 -> R² = 0.7901, MSE = 4.9621e-02
# X | test2 -> R² = -0.2218, MSE = 1.0043e-01
# Y | test2 -> R² = -0.7820, MSE = 1.8864e-01
# Theta | test3 -> R² = 0.7216, MSE = 9.1624e-02
# X | test3 -> R² = -1.8107, MSE = 2.5788e-01
# Y | test3 -> R² = -4.1447, MSE = 3.9447e-01
# Theta | val -> R² = -2.4582, MSE = 1.1333e+00
# X | val -> R² = -1.3629, MSE = 2.2527e-01
# Y | val -> R² = -3.3115, MSE = 3.2049e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.568409
# Epoch 50 Loss 1.349687
# Epoch 100 Loss 1.310570
# Epoch 150 Loss 1.269297
# Epoch 200 Loss 1.235629
# Epoch 250 Loss 1.222549
# Epoch 300 Loss 1.215366
# Epoch 350 Loss 1.209516
# Early stopping at epoch 362
# Theta | train1 -> R² = 0.8272, MSE = 3.9535e-02
# X | train1 -> R² = -0.2950, MSE = 1.3922e-01
# Y | train1 -> R² = -1.0699, MSE = 1.7322e-01
# Theta | train2 -> R² = 0.7503, MSE = 5.6805e-02
# X | train2 -> R² = -0.1496, MSE = 9.6746e-02
# Y | train2 -> R² = -0.8123, MSE = 1.9460e-01
# Theta | test1 -> R² = 0.6314, MSE = 8.4838e-02
# X | test1 -> R² = -0.4151, MSE = 1.4778e-01
# Y | test1 -> R² = -1.3422, MSE = 1.9163e-01
# Theta | test2 -> R² = 0.8469, MSE = 3.6190e-02
# X | test2 -> R² = -0.2325, MSE = 1.0131e-01
# Y | test2 -> R² = -0.8682, MSE = 1.9777e-01
# Theta | test3 -> R² = 0.6877, MSE = 1.0278e-01
# X | test3 -> R² = -2.4484, MSE = 3.1639e-01
# Y | test3 -> R² = -6.2760, MSE = 5.5788e-01
# Theta | val -> R² = -2.6508, MSE = 1.1964e+00
# X | val -> R² = -1.4378, MSE = 2.3240e-01
# Y | val -> R² = -4.4912, MSE = 4.0818e-01
# Figura salva em: ./results/model_8_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.559195
# Epoch 50 Loss 1.339335
# Epoch 100 Loss 1.329450
# Epoch 150 Loss 1.311574
# Epoch 200 Loss 1.290518
# Epoch 250 Loss 1.267637
# Epoch 300 Loss 1.253593
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.8914, MSE = 2.4844e-02
# X | train1 -> R² = -0.2459, MSE = 1.3394e-01
# Y | train1 -> R² = -1.1572, MSE = 1.8054e-01
# Theta | train2 -> R² = 0.7142, MSE = 6.5034e-02
# X | train2 -> R² = -0.0980, MSE = 9.2405e-02
# Y | train2 -> R² = -0.9770, MSE = 2.1228e-01
# Theta | test1 -> R² = 0.8593, MSE = 3.2391e-02
# X | test1 -> R² = -0.3610, MSE = 1.4213e-01
# Y | test1 -> R² = -1.4461, MSE = 2.0013e-01
# Theta | test2 -> R² = 0.8556, MSE = 3.4143e-02
# X | test2 -> R² = -0.1963, MSE = 9.8332e-02
# Y | test2 -> R² = -1.0726, MSE = 2.1941e-01
# Theta | test3 -> R² = 0.3817, MSE = 2.0353e-01
# X | test3 -> R² = -2.7089, MSE = 3.4029e-01
# Y | test3 -> R² = -7.3826, MSE = 6.4273e-01
# Theta | val -> R² = -3.4491, MSE = 1.4580e+00
# X | val -> R² = -1.5242, MSE = 2.4065e-01
# Y | val -> R² = -5.1803, MSE = 4.5941e-01
# Figura salva em: ./results/model_8_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.563735
# Epoch 50 Loss 1.338306
# Epoch 100 Loss 1.329938
# Epoch 150 Loss 1.320196
# Epoch 200 Loss 1.302888
# Epoch 250 Loss 1.275998
# Epoch 300 Loss 1.245165
# Epoch 350 Loss 1.230789
# Epoch 400 Loss 1.224474
# Early stopping at epoch 443
# Theta | train1 -> R² = 0.8646, MSE = 3.0964e-02
# X | train1 -> R² = -0.2162, MSE = 1.3075e-01
# Y | train1 -> R² = -1.0700, MSE = 1.7323e-01
# Theta | train2 -> R² = 0.7731, MSE = 5.1628e-02
# X | train2 -> R² = -0.1270, MSE = 9.4846e-02
# Y | train2 -> R² = -0.7651, MSE = 1.8953e-01
# Theta | test1 -> R² = 0.5535, MSE = 1.0279e-01
# X | test1 -> R² = -0.3755, MSE = 1.4364e-01
# Y | test1 -> R² = -1.4506, MSE = 2.0050e-01
# Theta | test2 -> R² = 0.8053, MSE = 4.6024e-02
# X | test2 -> R² = -0.2087, MSE = 9.9347e-02
# Y | test2 -> R² = -0.8162, MSE = 1.9226e-01
# Theta | test3 -> R² = 0.2283, MSE = 2.5402e-01
# X | test3 -> R² = -1.5428, MSE = 2.3330e-01
# Y | test3 -> R² = -4.0941, MSE = 3.9058e-01
# Theta | val -> R² = -5.8852, MSE = 2.2563e+00
# X | val -> R² = -1.2967, MSE = 2.1895e-01
# Y | val -> R² = -3.4916, MSE = 3.3388e-01
# Figura salva em: ./results/model_8_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.554133
# Epoch 50 Loss 1.345839
# Epoch 100 Loss 1.315298
# Epoch 150 Loss 1.308935
# Epoch 200 Loss 1.274814
# Epoch 250 Loss 1.255043
# Epoch 300 Loss 1.243742
# Epoch 350 Loss 1.233432
# Epoch 400 Loss 1.227970
# Epoch 450 Loss 1.222050
# Early stopping at epoch 476
# Theta | train1 -> R² = 0.4646, MSE = 1.2247e-01
# X | train1 -> R² = -0.1898, MSE = 1.2791e-01
# Y | train1 -> R² = -1.0279, MSE = 1.6971e-01
# Theta | train2 -> R² = -0.4917, MSE = 3.3941e-01
# X | train2 -> R² = -0.0961, MSE = 9.2244e-02
# Y | train2 -> R² = -0.7080, MSE = 1.8340e-01
# Theta | test1 -> R² = 0.5519, MSE = 1.0316e-01
# X | test1 -> R² = -0.2545, MSE = 1.3100e-01
# Y | test1 -> R² = -1.2511, MSE = 1.8418e-01
# Theta | test2 -> R² = -0.7967, MSE = 4.2469e-01
# X | test2 -> R² = -0.1536, MSE = 9.4817e-02
# Y | test2 -> R² = -0.7384, MSE = 1.8403e-01
# Theta | test3 -> R² = 0.5204, MSE = 1.5785e-01
# X | test3 -> R² = -1.7489, MSE = 2.5221e-01
# Y | test3 -> R² = -4.1283, MSE = 3.9321e-01
# Theta | val -> R² = -4.4966, MSE = 1.8012e+00
# X | val -> R² = -0.9424, MSE = 1.8517e-01
# Y | val -> R² = -2.6610, MSE = 2.7213e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.580237
# Epoch 50 Loss 1.335056
# Epoch 100 Loss 1.311530
# Epoch 150 Loss 1.299173
# Epoch 200 Loss 1.276625
# Epoch 250 Loss 1.235052
# Epoch 300 Loss 1.217837
# Epoch 350 Loss 1.205394
# Epoch 400 Loss 1.200757
# Epoch 450 Loss 1.185297
# Early stopping at epoch 494
# Theta | train1 -> R² = 0.1387, MSE = 1.9702e-01
# X | train1 -> R² = -0.1631, MSE = 1.2504e-01
# Y | train1 -> R² = -1.2553, MSE = 1.8875e-01
# Theta | train2 -> R² = -0.2948, MSE = 2.9460e-01
# X | train2 -> R² = -0.0662, MSE = 8.9731e-02
# Y | train2 -> R² = -1.0148, MSE = 2.1634e-01
# Theta | test1 -> R² = 0.5351, MSE = 1.0702e-01
# X | test1 -> R² = -0.1915, MSE = 1.2443e-01
# Y | test1 -> R² = -1.6871, MSE = 2.1985e-01
# Theta | test2 -> R² = -0.2749, MSE = 3.0136e-01
# X | test2 -> R² = -0.1482, MSE = 9.4378e-02
# Y | test2 -> R² = -0.9494, MSE = 2.0636e-01
# Theta | test3 -> R² = -6.3803, MSE = 2.4293e+00
# X | test3 -> R² = -1.4439, MSE = 2.2423e-01
# Y | test3 -> R² = -2.6376, MSE = 2.7891e-01
# Theta | val -> R² = -13.9274, MSE = 4.8917e+00
# X | val -> R² = -1.3027, MSE = 2.1953e-01
# Y | val -> R² = -2.5098, MSE = 2.6089e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.581553
# Epoch 50 Loss 1.325435
# Epoch 100 Loss 1.296749
# Epoch 150 Loss 1.261072
# Epoch 200 Loss 1.226193
# Epoch 250 Loss 1.213525
# Epoch 300 Loss 1.197938
# Epoch 350 Loss 1.190838
# Epoch 400 Loss 1.185291
# Early stopping at epoch 415
# Theta | train1 -> R² = -1.8580, MSE = 6.5373e-01
# X | train1 -> R² = -0.2176, MSE = 1.3090e-01
# Y | train1 -> R² = -1.1029, MSE = 1.7599e-01
# Theta | train2 -> R² = -4.0114, MSE = 1.1402e+00
# X | train2 -> R² = -0.1490, MSE = 9.6695e-02
# Y | train2 -> R² = -0.8037, MSE = 1.9368e-01
# Theta | test1 -> R² = -1.2544, MSE = 5.1894e-01
# X | test1 -> R² = -0.2880, MSE = 1.3451e-01
# Y | test1 -> R² = -1.3405, MSE = 1.9149e-01
# Theta | test2 -> R² = -3.7737, MSE = 1.1284e+00
# X | test2 -> R² = -0.2159, MSE = 9.9940e-02
# Y | test2 -> R² = -0.8545, MSE = 1.9632e-01
# Theta | test3 -> R² = -0.5742, MSE = 5.1816e-01
# X | test3 -> R² = -2.1758, MSE = 2.9138e-01
# Y | test3 -> R² = -4.8338, MSE = 4.4730e-01
# Theta | val -> R² = -3.3952, MSE = 1.4403e+00
# X | val -> R² = -1.3020, MSE = 2.1946e-01
# Y | val -> R² = -3.5821, MSE = 3.4060e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.554208
# Epoch 50 Loss 1.308313
# Epoch 100 Loss 1.288018
# Epoch 150 Loss 1.250469
# Epoch 200 Loss 1.226642
# Epoch 250 Loss 1.212056
# Epoch 300 Loss 1.194752
# Epoch 350 Loss 1.189195
# Epoch 400 Loss 1.184323
# Early stopping at epoch 420
# Theta | train1 -> R² = 0.8688, MSE = 3.0001e-02
# X | train1 -> R² = -0.2047, MSE = 1.2951e-01
# Y | train1 -> R² = -1.1839, MSE = 1.8277e-01
# Theta | train2 -> R² = 0.0571, MSE = 2.1452e-01
# X | train2 -> R² = -0.1351, MSE = 9.5526e-02
# Y | train2 -> R² = -0.8781, MSE = 2.0166e-01
# Theta | test1 -> R² = 0.6973, MSE = 6.9681e-02
# X | test1 -> R² = -0.3209, MSE = 1.3794e-01
# Y | test1 -> R² = -1.5362, MSE = 2.0750e-01
# Theta | test2 -> R² = -0.2382, MSE = 2.9268e-01
# X | test2 -> R² = -0.1887, MSE = 9.7705e-02
# Y | test2 -> R² = -0.9071, MSE = 2.0189e-01
# Theta | test3 -> R² = -2.7484, MSE = 1.2338e+00
# X | test3 -> R² = -1.2660, MSE = 2.0790e-01
# Y | test3 -> R² = -4.3652, MSE = 4.1137e-01
# Theta | val -> R² = -8.0812, MSE = 2.9759e+00
# X | val -> R² = -0.9079, MSE = 1.8189e-01
# Y | val -> R² = -3.5859, MSE = 3.4088e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.568028
# Epoch 50 Loss 1.318120
# Epoch 100 Loss 1.294433
# Epoch 150 Loss 1.272853
# Epoch 200 Loss 1.231529
# Epoch 250 Loss 1.210529
# Epoch 300 Loss 1.193916
# Epoch 350 Loss 1.187745
# Epoch 400 Loss 1.182341
# Early stopping at epoch 446
# Theta | train1 -> R² = 0.8424, MSE = 3.6037e-02
# X | train1 -> R² = -0.1785, MSE = 1.2670e-01
# Y | train1 -> R² = -1.0138, MSE = 1.6853e-01
# Theta | train2 -> R² = 0.7130, MSE = 6.5289e-02
# X | train2 -> R² = -0.0705, MSE = 9.0086e-02
# Y | train2 -> R² = -0.6749, MSE = 1.7984e-01
# Theta | test1 -> R² = 0.7198, MSE = 6.4505e-02
# X | test1 -> R² = -0.3095, MSE = 1.3675e-01
# Y | test1 -> R² = -1.2960, MSE = 1.8785e-01
# Theta | test2 -> R² = 0.6519, MSE = 8.2289e-02
# X | test2 -> R² = -0.1498, MSE = 9.4510e-02
# Y | test2 -> R² = -0.6823, MSE = 1.7808e-01
# Theta | test3 -> R² = -1.5565, MSE = 8.4150e-01
# X | test3 -> R² = -1.3536, MSE = 2.1595e-01
# Y | test3 -> R² = -4.1440, MSE = 3.9441e-01
# Theta | val -> R² = -10.4101, MSE = 3.7391e+00
# X | val -> R² = -1.1911, MSE = 2.0889e-01
# Y | val -> R² = -2.8192, MSE = 2.8389e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.561934
# Epoch 50 Loss 1.307806
# Epoch 100 Loss 1.283402
# Epoch 150 Loss 1.237263
# Epoch 200 Loss 1.220125
# Epoch 250 Loss 1.210307
# Epoch 300 Loss 1.229541
# Epoch 350 Loss 1.193857
# Epoch 400 Loss 1.186889
# Early stopping at epoch 434
# Theta | train1 -> R² = 0.3722, MSE = 1.4359e-01
# X | train1 -> R² = -0.1844, MSE = 1.2733e-01
# Y | train1 -> R² = -1.0213, MSE = 1.6916e-01
# Theta | train2 -> R² = 0.6529, MSE = 7.8972e-02
# X | train2 -> R² = -0.0406, MSE = 8.7568e-02
# Y | train2 -> R² = -0.8148, MSE = 1.9487e-01
# Theta | test1 -> R² = 0.5306, MSE = 1.0804e-01
# X | test1 -> R² = -0.2605, MSE = 1.3163e-01
# Y | test1 -> R² = -1.4517, MSE = 2.0059e-01
# Theta | test2 -> R² = 0.6267, MSE = 8.8246e-02
# X | test2 -> R² = -0.1174, MSE = 9.1846e-02
# Y | test2 -> R² = -0.8089, MSE = 1.9149e-01
# Theta | test3 -> R² = -7.0147, MSE = 2.6381e+00
# X | test3 -> R² = -1.7897, MSE = 2.5595e-01
# Y | test3 -> R² = -3.5692, MSE = 3.5034e-01
# Theta | val -> R² = -9.1202, MSE = 3.3164e+00
# X | val -> R² = -1.5314, MSE = 2.4133e-01
# Y | val -> R² = -3.5256, MSE = 3.3640e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.563934
# Epoch 50 Loss 1.327605
# Epoch 100 Loss 1.293896
# Epoch 150 Loss 1.278360
# Epoch 200 Loss 1.238909
# Epoch 250 Loss 1.217938
# Epoch 300 Loss 1.205455
# Early stopping at epoch 317
# Theta | train1 -> R² = 0.7194, MSE = 6.4176e-02
# X | train1 -> R² = -0.2127, MSE = 1.3037e-01
# Y | train1 -> R² = -1.3775, MSE = 1.9897e-01
# Theta | train2 -> R² = 0.5489, MSE = 1.0263e-01
# X | train2 -> R² = -0.2454, MSE = 1.0480e-01
# Y | train2 -> R² = -0.8946, MSE = 2.0343e-01
# Theta | test1 -> R² = 0.8758, MSE = 2.8600e-02
# X | test1 -> R² = -0.3370, MSE = 1.3963e-01
# Y | test1 -> R² = -1.6905, MSE = 2.2013e-01
# Theta | test2 -> R² = 0.8562, MSE = 3.3981e-02
# X | test2 -> R² = -0.3348, MSE = 1.0971e-01
# Y | test2 -> R² = -0.9098, MSE = 2.0218e-01
# Theta | test3 -> R² = -0.0404, MSE = 3.4247e-01
# X | test3 -> R² = -2.7962, MSE = 3.4830e-01
# Y | test3 -> R² = -6.5115, MSE = 5.7593e-01
# Theta | val -> R² = -5.9240, MSE = 2.2690e+00
# X | val -> R² = -1.1476, MSE = 2.0474e-01
# Y | val -> R² = -5.6123, MSE = 4.9151e-01
# Figura salva em: ./results/model_16_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.571769
# Epoch 50 Loss 1.334781
# Epoch 100 Loss 1.297086
# Epoch 150 Loss 1.256559
# Epoch 200 Loss 1.238963
# Epoch 250 Loss 1.224475
# Epoch 300 Loss 1.211317
# Epoch 350 Loss 1.198628
# Early stopping at epoch 398
# Theta | train1 -> R² = 0.7322, MSE = 6.1250e-02
# X | train1 -> R² = -0.2605, MSE = 1.3551e-01
# Y | train1 -> R² = -1.0447, MSE = 1.7112e-01
# Theta | train2 -> R² = 0.7353, MSE = 6.0226e-02
# X | train2 -> R² = -0.1695, MSE = 9.8424e-02
# Y | train2 -> R² = -0.7957, MSE = 1.9281e-01
# Theta | test1 -> R² = 0.3123, MSE = 1.5831e-01
# X | test1 -> R² = -0.4061, MSE = 1.4684e-01
# Y | test1 -> R² = -1.3549, MSE = 1.9267e-01
# Theta | test2 -> R² = 0.7337, MSE = 6.2939e-02
# X | test2 -> R² = -0.2471, MSE = 1.0251e-01
# Y | test2 -> R² = -0.8554, MSE = 1.9642e-01
# Theta | test3 -> R² = 0.4859, MSE = 1.6923e-01
# X | test3 -> R² = -1.8989, MSE = 2.6597e-01
# Y | test3 -> R² = -4.9779, MSE = 4.5835e-01
# Theta | val -> R² = -6.0694, MSE = 2.3167e+00
# X | val -> R² = -1.4141, MSE = 2.3014e-01
# Y | val -> R² = -4.0069, MSE = 3.7218e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.577983
# Epoch 50 Loss 1.333932
# Epoch 100 Loss 1.307433
# Epoch 150 Loss 1.293861
# Epoch 200 Loss 1.281557
# Epoch 250 Loss 1.254639
# Epoch 300 Loss 1.229856
# Epoch 350 Loss 1.220976
# Epoch 400 Loss 1.213531
# Epoch 450 Loss 1.207469
# Epoch 500 Loss 1.200707
# Early stopping at epoch 509
# Theta | train1 -> R² = -0.6510, MSE = 3.7765e-01
# X | train1 -> R² = -0.2718, MSE = 1.3673e-01
# Y | train1 -> R² = -1.4211, MSE = 2.0262e-01
# Theta | train2 -> R² = -1.5694, MSE = 5.8460e-01
# X | train2 -> R² = -0.1166, MSE = 9.3972e-02
# Y | train2 -> R² = -1.1427, MSE = 2.3008e-01
# Theta | test1 -> R² = 0.2749, MSE = 1.6691e-01
# X | test1 -> R² = -0.3126, MSE = 1.3708e-01
# Y | test1 -> R² = -1.6705, MSE = 2.1849e-01
# Theta | test2 -> R² = -1.5333, MSE = 5.9881e-01
# X | test2 -> R² = -0.1867, MSE = 9.7543e-02
# Y | test2 -> R² = -1.1732, MSE = 2.3006e-01
# Theta | test3 -> R² = -4.1672, MSE = 1.7008e+00
# X | test3 -> R² = -2.2249, MSE = 2.9588e-01
# Y | test3 -> R² = -5.2284, MSE = 4.7756e-01
# Theta | val -> R² = -8.0608, MSE = 2.9692e+00
# X | val -> R² = -1.3192, MSE = 2.2110e-01
# Y | val -> R² = -3.5350, MSE = 3.3711e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.556858
# Epoch 50 Loss 1.327561
# Epoch 100 Loss 1.301776
# Epoch 150 Loss 1.281401
# Epoch 200 Loss 1.252592
# Epoch 250 Loss 1.231592
# Epoch 300 Loss 1.217191
# Epoch 350 Loss 1.205648
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.7345, MSE = 6.0731e-02
# X | train1 -> R² = -0.1600, MSE = 1.2471e-01
# Y | train1 -> R² = -1.0469, MSE = 1.7130e-01
# Theta | train2 -> R² = 0.7034, MSE = 6.7476e-02
# X | train2 -> R² = -0.0982, MSE = 9.2416e-02
# Y | train2 -> R² = -0.7952, MSE = 1.9277e-01
# Theta | test1 -> R² = 0.3700, MSE = 1.4502e-01
# X | test1 -> R² = -0.2887, MSE = 1.3458e-01
# Y | test1 -> R² = -1.3383, MSE = 1.9131e-01
# Theta | test2 -> R² = 0.8736, MSE = 2.9888e-02
# X | test2 -> R² = -0.1787, MSE = 9.6881e-02
# Y | test2 -> R² = -0.8605, MSE = 1.9696e-01
# Theta | test3 -> R² = 0.1753, MSE = 2.7144e-01
# X | test3 -> R² = -1.6912, MSE = 2.4692e-01
# Y | test3 -> R² = -5.0408, MSE = 4.6317e-01
# Theta | val -> R² = -6.8923, MSE = 2.5863e+00
# X | val -> R² = -1.1442, MSE = 2.0442e-01
# Y | val -> R² = -3.8392, MSE = 3.5971e-01
# Figura salva em: ./results/model_16_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.600113
# Epoch 50 Loss 1.308064
# Epoch 100 Loss 1.292248
# Epoch 150 Loss 1.259110
# Epoch 200 Loss 1.229922
# Epoch 250 Loss 1.221911
# Epoch 300 Loss 1.205626
# Early stopping at epoch 339
# Theta | train1 -> R² = 0.9018, MSE = 2.2469e-02
# X | train1 -> R² = -0.0923, MSE = 1.1742e-01
# Y | train1 -> R² = -1.0357, MSE = 1.7036e-01
# Theta | train2 -> R² = 0.6732, MSE = 7.4363e-02
# X | train2 -> R² = -0.1220, MSE = 9.4422e-02
# Y | train2 -> R² = -0.7203, MSE = 1.8472e-01
# Theta | test1 -> R² = 0.6838, MSE = 7.2795e-02
# X | test1 -> R² = -0.2168, MSE = 1.2707e-01
# Y | test1 -> R² = -1.3198, MSE = 1.8980e-01
# Theta | test2 -> R² = 0.7964, MSE = 4.8131e-02
# X | test2 -> R² = -0.2145, MSE = 9.9823e-02
# Y | test2 -> R² = -0.7943, MSE = 1.8995e-01
# Theta | test3 -> R² = 0.4582, MSE = 1.7833e-01
# X | test3 -> R² = -1.9134, MSE = 2.6730e-01
# Y | test3 -> R² = -5.6355, MSE = 5.0877e-01
# Theta | val -> R² = -6.3564, MSE = 2.4107e+00
# X | val -> R² = -1.2930, MSE = 2.1860e-01
# Y | val -> R² = -4.4971, MSE = 4.0862e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.554969
# Epoch 50 Loss 1.313199
# Epoch 100 Loss 1.290985
# Epoch 150 Loss 1.271222
# Epoch 200 Loss 1.239141
# Epoch 250 Loss 1.216868
# Epoch 300 Loss 1.205163
# Epoch 350 Loss 1.199404
# Epoch 400 Loss 1.186319
# Epoch 450 Loss 1.172969
# Early stopping at epoch 463
# Theta | train1 -> R² = -0.6767, MSE = 3.8352e-01
# X | train1 -> R² = -0.1835, MSE = 1.2724e-01
# Y | train1 -> R² = -1.2790, MSE = 1.9073e-01
# Theta | train2 -> R² = -1.9308, MSE = 6.6685e-01
# X | train2 -> R² = -0.0929, MSE = 9.1970e-02
# Y | train2 -> R² = -1.0390, MSE = 2.1894e-01
# Theta | test1 -> R² = -0.7111, MSE = 3.9387e-01
# X | test1 -> R² = -0.3100, MSE = 1.3680e-01
# Y | test1 -> R² = -1.8402, MSE = 2.3238e-01
# Theta | test2 -> R² = -1.9618, MSE = 7.0010e-01
# X | test2 -> R² = -0.1548, MSE = 9.4921e-02
# Y | test2 -> R² = -0.9866, MSE = 2.1030e-01
# Theta | test3 -> R² = -1.4285, MSE = 7.9934e-01
# X | test3 -> R² = -2.0399, MSE = 2.7891e-01
# Y | test3 -> R² = -3.3279, MSE = 3.3184e-01
# Theta | val -> R² = -3.1130, MSE = 1.3479e+00
# X | val -> R² = -1.5677, MSE = 2.4479e-01
# Y | val -> R² = -3.7246, MSE = 3.5119e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.566795
# Epoch 50 Loss 1.328915
# Epoch 100 Loss 1.296381
# Epoch 150 Loss 1.260034
# Epoch 200 Loss 1.233409
# Epoch 250 Loss 1.225494
# Epoch 300 Loss 1.194449
# Epoch 350 Loss 1.195248
# Early stopping at epoch 386
# Theta | train1 -> R² = -1.0281, MSE = 4.6390e-01
# X | train1 -> R² = -0.2313, MSE = 1.3237e-01
# Y | train1 -> R² = -1.2212, MSE = 1.8589e-01
# Theta | train2 -> R² = -2.6484, MSE = 8.3012e-01
# X | train2 -> R² = -0.1516, MSE = 9.6910e-02
# Y | train2 -> R² = -0.9501, MSE = 2.0940e-01
# Theta | test1 -> R² = -0.5799, MSE = 3.6368e-01
# X | test1 -> R² = -0.3116, MSE = 1.3697e-01
# Y | test1 -> R² = -1.5193, MSE = 2.0612e-01
# Theta | test2 -> R² = -2.8963, MSE = 9.2099e-01
# X | test2 -> R² = -0.2403, MSE = 1.0194e-01
# Y | test2 -> R² = -0.9862, MSE = 2.1026e-01
# Theta | test3 -> R² = 0.1802, MSE = 2.6984e-01
# X | test3 -> R² = -2.2674, MSE = 2.9979e-01
# Y | test3 -> R² = -4.8280, MSE = 4.4686e-01
# Theta | val -> R² = -1.7505, MSE = 9.0134e-01
# X | val -> R² = -1.4371, MSE = 2.3233e-01
# Y | val -> R² = -3.4145, MSE = 3.2815e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.572960
# Epoch 50 Loss 1.311145
# Epoch 100 Loss 1.289242
# Epoch 150 Loss 1.272874
# Epoch 200 Loss 1.223064
# Epoch 250 Loss 1.202776
# Epoch 300 Loss 1.194201
# Epoch 350 Loss 1.187163
# Epoch 400 Loss 1.176271
# Epoch 450 Loss 1.168382
# Early stopping at epoch 470
# Theta | train1 -> R² = 0.9334, MSE = 1.5228e-02
# X | train1 -> R² = -0.1624, MSE = 1.2497e-01
# Y | train1 -> R² = -1.0670, MSE = 1.7299e-01
# Theta | train2 -> R² = 0.4748, MSE = 1.1950e-01
# X | train2 -> R² = -0.0629, MSE = 8.9448e-02
# Y | train2 -> R² = -0.9269, MSE = 2.0690e-01
# Theta | test1 -> R² = 0.8708, MSE = 2.9746e-02
# X | test1 -> R² = -0.1962, MSE = 1.2492e-01
# Y | test1 -> R² = -1.5274, MSE = 2.0678e-01
# Theta | test2 -> R² = 0.5613, MSE = 1.0369e-01
# X | test2 -> R² = -0.1273, MSE = 9.2656e-02
# Y | test2 -> R² = -0.8397, MSE = 1.9475e-01
# Theta | test3 -> R² = 0.3272, MSE = 2.2146e-01
# X | test3 -> R² = -2.4845, MSE = 3.1970e-01
# Y | test3 -> R² = -2.7813, MSE = 2.8993e-01
# Theta | val -> R² = -2.4106, MSE = 1.1176e+00
# X | val -> R² = -1.1232, MSE = 2.0241e-01
# Y | val -> R² = -2.7441, MSE = 2.7831e-01
# Figura salva em: ./results/model_32_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.581035
# Epoch 50 Loss 1.322216
# Epoch 100 Loss 1.293416
# Epoch 150 Loss 1.289879
# Epoch 200 Loss 1.238953
# Epoch 250 Loss 1.218144
# Epoch 300 Loss 1.200192
# Epoch 350 Loss 1.188552
# Epoch 400 Loss 1.181869
# Early stopping at epoch 450
# Theta | train1 -> R² = 0.7523, MSE = 5.6668e-02
# X | train1 -> R² = -0.1758, MSE = 1.2640e-01
# Y | train1 -> R² = -0.9428, MSE = 1.6259e-01
# Theta | train2 -> R² = 0.1417, MSE = 1.9528e-01
# X | train2 -> R² = -0.1299, MSE = 9.5083e-02
# Y | train2 -> R² = -0.7669, MSE = 1.8973e-01
# Theta | test1 -> R² = 0.7304, MSE = 6.2048e-02
# X | test1 -> R² = -0.3041, MSE = 1.3618e-01
# Y | test1 -> R² = -1.3582, MSE = 1.9294e-01
# Theta | test2 -> R² = 0.0465, MSE = 2.2538e-01
# X | test2 -> R² = -0.2239, MSE = 1.0060e-01
# Y | test2 -> R² = -0.7994, MSE = 1.9049e-01
# Theta | test3 -> R² = -1.2404, MSE = 7.3744e-01
# X | test3 -> R² = -1.5091, MSE = 2.3021e-01
# Y | test3 -> R² = -2.9409, MSE = 3.0217e-01
# Theta | val -> R² = -5.9895, MSE = 2.2905e+00
# X | val -> R² = -1.6152, MSE = 2.4932e-01
# Y | val -> R² = -3.0714, MSE = 3.0264e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.584646
# Epoch 50 Loss 1.308262
# Epoch 100 Loss 1.290316
# Epoch 150 Loss 1.262225
# Epoch 200 Loss 1.222852
# Epoch 250 Loss 1.211722
# Epoch 300 Loss 1.201159
# Epoch 350 Loss 1.201999
# Epoch 400 Loss 1.181579
# Early stopping at epoch 445
# Theta | train1 -> R² = 0.6296, MSE = 8.4725e-02
# X | train1 -> R² = -0.2323, MSE = 1.3248e-01
# Y | train1 -> R² = -1.1519, MSE = 1.8009e-01
# Theta | train2 -> R² = -0.1521, MSE = 2.6213e-01
# X | train2 -> R² = -0.1091, MSE = 9.3341e-02
# Y | train2 -> R² = -0.8910, MSE = 2.0305e-01
# Theta | test1 -> R² = 0.7060, MSE = 6.7684e-02
# X | test1 -> R² = -0.3731, MSE = 1.4339e-01
# Y | test1 -> R² = -1.5554, MSE = 2.0907e-01
# Theta | test2 -> R² = -0.2220, MSE = 2.8885e-01
# X | test2 -> R² = -0.1996, MSE = 9.8600e-02
# Y | test2 -> R² = -0.8755, MSE = 1.9854e-01
# Theta | test3 -> R² = -3.5025, MSE = 1.4820e+00
# X | test3 -> R² = -2.0515, MSE = 2.7997e-01
# Y | test3 -> R² = -3.1053, MSE = 3.1477e-01
# Theta | val -> R² = -9.5490, MSE = 3.4569e+00
# X | val -> R² = -1.8852, MSE = 2.7506e-01
# Y | val -> R² = -2.7064, MSE = 2.7551e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.551282
# Epoch 50 Loss 1.329627
# Epoch 100 Loss 1.302106
# Epoch 150 Loss 1.284132
# Epoch 200 Loss 1.269758
# Epoch 250 Loss 1.228965
# Epoch 300 Loss 1.201563
# Epoch 350 Loss 1.191813
# Epoch 400 Loss 1.181120
# Epoch 450 Loss 1.174745
# Early stopping at epoch 468
# Theta | train1 -> R² = -5.1164, MSE = 1.3991e+00
# X | train1 -> R² = -0.4268, MSE = 1.5339e-01
# Y | train1 -> R² = -1.0953, MSE = 1.7535e-01
# Theta | train2 -> R² = -7.5583, MSE = 1.9472e+00
# X | train2 -> R² = -0.2791, MSE = 1.0764e-01
# Y | train2 -> R² = -0.8744, MSE = 2.0127e-01
# Theta | test1 -> R² = -4.7515, MSE = 1.3239e+00
# X | test1 -> R² = -0.6240, MSE = 1.6960e-01
# Y | test1 -> R² = -1.6180, MSE = 2.1419e-01
# Theta | test2 -> R² = -7.8002, MSE = 2.0802e+00
# X | test2 -> R² = -0.3477, MSE = 1.1078e-01
# Y | test2 -> R² = -0.8606, MSE = 1.9697e-01
# Theta | test3 -> R² = -0.1930, MSE = 3.9270e-01
# X | test3 -> R² = -2.3348, MSE = 3.0597e-01
# Y | test3 -> R² = -1.9206, MSE = 2.2393e-01
# Theta | val -> R² = -0.1905, MSE = 3.9013e-01
# X | val -> R² = -2.6696, MSE = 3.4984e-01
# Y | val -> R² = -2.8115, MSE = 2.8332e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.562745
# Epoch 50 Loss 1.323768
# Epoch 100 Loss 1.299925
# Epoch 150 Loss 1.288234
# Epoch 200 Loss 1.265946
# Epoch 250 Loss 1.227906
# Epoch 300 Loss 1.209488
# Epoch 350 Loss 1.195106
# Epoch 400 Loss 1.187031
# Epoch 450 Loss 1.174149
# Early stopping at epoch 494
# Theta | train1 -> R² = 0.4619, MSE = 1.2309e-01
# X | train1 -> R² = -0.2653, MSE = 1.3603e-01
# Y | train1 -> R² = -1.0614, MSE = 1.7251e-01
# Theta | train2 -> R² = 0.8040, MSE = 4.4586e-02
# X | train2 -> R² = -0.1576, MSE = 9.7421e-02
# Y | train2 -> R² = -0.8922, MSE = 2.0318e-01
# Theta | test1 -> R² = 0.4988, MSE = 1.1537e-01
# X | test1 -> R² = -0.3565, MSE = 1.4166e-01
# Y | test1 -> R² = -1.5119, MSE = 2.0551e-01
# Theta | test2 -> R² = 0.8688, MSE = 3.1016e-02
# X | test2 -> R² = -0.2139, MSE = 9.9778e-02
# Y | test2 -> R² = -0.8643, MSE = 1.9736e-01
# Theta | test3 -> R² = -10.0934, MSE = 3.6515e+00
# X | test3 -> R² = -2.0867, MSE = 2.8320e-01
# Y | test3 -> R² = -2.6982, MSE = 2.8356e-01
# Theta | val -> R² = -20.0498, MSE = 6.8980e+00
# X | val -> R² = -1.4138, MSE = 2.3012e-01
# Y | val -> R² = -2.6650, MSE = 2.7244e-01
# Figura salva em: ./results/model_32_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.610921
# Epoch 50 Loss 1.316579
# Epoch 100 Loss 1.293153
# Epoch 150 Loss 1.275628
# Epoch 200 Loss 1.224387
# Epoch 250 Loss 1.207471
# Epoch 300 Loss 1.196690
# Epoch 350 Loss 1.180771
# Epoch 400 Loss 1.176106
# Epoch 450 Loss 1.172602
# Early stopping at epoch 457
# Theta | train1 -> R² = 0.6897, MSE = 7.0969e-02
# X | train1 -> R² = -0.2493, MSE = 1.3431e-01
# Y | train1 -> R² = -1.1004, MSE = 1.7578e-01
# Theta | train2 -> R² = 0.7389, MSE = 5.9412e-02
# X | train2 -> R² = -0.0999, MSE = 9.2563e-02
# Y | train2 -> R² = -0.8336, MSE = 1.9689e-01
# Theta | test1 -> R² = 0.5946, MSE = 9.3309e-02
# X | test1 -> R² = -0.3238, MSE = 1.3825e-01
# Y | test1 -> R² = -1.4872, MSE = 2.0349e-01
# Theta | test2 -> R² = 0.6477, MSE = 8.3275e-02
# X | test2 -> R² = -0.1692, MSE = 9.6097e-02
# Y | test2 -> R² = -0.8652, MSE = 1.9745e-01
# Theta | test3 -> R² = -7.5935, MSE = 2.8286e+00
# X | test3 -> R² = -2.3466, MSE = 3.0705e-01
# Y | test3 -> R² = -3.7826, MSE = 3.6670e-01
# Theta | val -> R² = -14.1375, MSE = 4.9606e+00
# X | val -> R² = -1.7061, MSE = 2.5798e-01
# Y | val -> R² = -3.3510, MSE = 3.2343e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.532853
# Epoch 50 Loss 1.303705
# Epoch 100 Loss 1.296510
# Epoch 150 Loss 1.259310
# Epoch 200 Loss 1.222905
# Epoch 250 Loss 1.209918
# Epoch 300 Loss 1.198279
# Epoch 350 Loss 1.189911
# Epoch 400 Loss 1.179034
# Early stopping at epoch 438
# Theta | train1 -> R² = 0.0296, MSE = 2.2197e-01
# X | train1 -> R² = -0.1848, MSE = 1.2737e-01
# Y | train1 -> R² = -1.0284, MSE = 1.6976e-01
# Theta | train2 -> R² = 0.3716, MSE = 1.4298e-01
# X | train2 -> R² = -0.1248, MSE = 9.4660e-02
# Y | train2 -> R² = -0.8358, MSE = 1.9712e-01
# Theta | test1 -> R² = 0.2543, MSE = 1.7166e-01
# X | test1 -> R² = -0.2840, MSE = 1.3409e-01
# Y | test1 -> R² = -1.3510, MSE = 1.9235e-01
# Theta | test2 -> R² = 0.3752, MSE = 1.4768e-01
# X | test2 -> R² = -0.2051, MSE = 9.9048e-02
# Y | test2 -> R² = -0.8720, MSE = 1.9817e-01
# Theta | test3 -> R² = -7.8556, MSE = 2.9149e+00
# X | test3 -> R² = -1.4258, MSE = 2.2257e-01
# Y | test3 -> R² = -3.5991, MSE = 3.5263e-01
# Theta | val -> R² = -12.6791, MSE = 4.4827e+00
# X | val -> R² = -1.6327, MSE = 2.5098e-01
# Y | val -> R² = -2.9731, MSE = 2.9534e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.562260
# Epoch 50 Loss 1.326071
# Epoch 100 Loss 1.303160
# Epoch 150 Loss 1.287304
# Epoch 200 Loss 1.269255
# Epoch 250 Loss 1.228307
# Epoch 300 Loss 1.208126
# Epoch 350 Loss 1.192121
# Early stopping at epoch 370
# Theta | train1 -> R² = 0.5809, MSE = 9.5873e-02
# X | train1 -> R² = -0.1839, MSE = 1.2727e-01
# Y | train1 -> R² = -0.9729, MSE = 1.6511e-01
# Theta | train2 -> R² = 0.7942, MSE = 4.6830e-02
# X | train2 -> R² = -0.1406, MSE = 9.5990e-02
# Y | train2 -> R² = -0.8047, MSE = 1.9378e-01
# Theta | test1 -> R² = 0.4124, MSE = 1.3526e-01
# X | test1 -> R² = -0.3089, MSE = 1.3669e-01
# Y | test1 -> R² = -1.2415, MSE = 1.8339e-01
# Theta | test2 -> R² = 0.7188, MSE = 6.6468e-02
# X | test2 -> R² = -0.2227, MSE = 1.0050e-01
# Y | test2 -> R² = -0.8452, MSE = 1.9533e-01
# Theta | test3 -> R² = -1.7430, MSE = 9.0287e-01
# X | test3 -> R² = -1.7496, MSE = 2.5227e-01
# Y | test3 -> R² = -4.1090, MSE = 3.9173e-01
# Theta | val -> R² = -9.1160, MSE = 3.3150e+00
# X | val -> R² = -1.1109, MSE = 2.0124e-01
# Y | val -> R² = -2.9206, MSE = 2.9143e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.545926
# Epoch 50 Loss 1.304239
# Epoch 100 Loss 1.294702
# Epoch 150 Loss 1.285992
# Epoch 200 Loss 1.229995
# Epoch 250 Loss 1.211879
# Epoch 300 Loss 1.198514
# Epoch 350 Loss 1.174048
# Epoch 400 Loss 1.220210
# Epoch 450 Loss 1.173984
# Early stopping at epoch 461
# Theta | train1 -> R² = 0.4657, MSE = 1.2222e-01
# X | train1 -> R² = -0.0453, MSE = 1.1238e-01
# Y | train1 -> R² = -0.9913, MSE = 1.6665e-01
# Theta | train2 -> R² = -0.3783, MSE = 3.1359e-01
# X | train2 -> R² = -0.0884, MSE = 9.1592e-02
# Y | train2 -> R² = -0.6791, MSE = 1.8029e-01
# Theta | test1 -> R² = 0.7117, MSE = 6.6361e-02
# X | test1 -> R² = -0.0879, MSE = 1.1361e-01
# Y | test1 -> R² = -1.4512, MSE = 2.0054e-01
# Theta | test2 -> R² = -0.2216, MSE = 2.8876e-01
# X | test2 -> R² = -0.1510, MSE = 9.4608e-02
# Y | test2 -> R² = -0.6487, MSE = 1.7453e-01
# Theta | test3 -> R² = -0.5416, MSE = 5.0741e-01
# X | test3 -> R² = -2.4816, MSE = 3.1944e-01
# Y | test3 -> R² = -3.0626, MSE = 3.1150e-01
# Theta | val -> R² = -7.0215, MSE = 2.6287e+00
# X | val -> R² = -1.2642, MSE = 2.1586e-01
# Y | val -> R² = -2.9738, MSE = 2.9539e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.601715
# Epoch 50 Loss 1.310571
# Epoch 100 Loss 1.288354
# Epoch 150 Loss 1.268784
# Epoch 200 Loss 1.275425
# Epoch 250 Loss 1.232881
# Epoch 300 Loss 1.205829
# Epoch 350 Loss 1.191194
# Epoch 400 Loss 1.177856
# Epoch 450 Loss 1.163030
# Early stopping at epoch 483
# Theta | train1 -> R² = 0.3900, MSE = 1.3954e-01
# X | train1 -> R² = -0.2101, MSE = 1.3010e-01
# Y | train1 -> R² = -1.0352, MSE = 1.7032e-01
# Theta | train2 -> R² = -0.5314, MSE = 3.4844e-01
# X | train2 -> R² = -0.1252, MSE = 9.4692e-02
# Y | train2 -> R² = -0.8679, MSE = 2.0057e-01
# Theta | test1 -> R² = 0.2447, MSE = 1.7387e-01
# X | test1 -> R² = -0.3122, MSE = 1.3704e-01
# Y | test1 -> R² = -1.5634, MSE = 2.0972e-01
# Theta | test2 -> R² = -0.7464, MSE = 4.1281e-01
# X | test2 -> R² = -0.2267, MSE = 1.0082e-01
# Y | test2 -> R² = -0.8290, MSE = 1.9362e-01
# Theta | test3 -> R² = -0.6234, MSE = 5.3436e-01
# X | test3 -> R² = -2.5805, MSE = 3.2851e-01
# Y | test3 -> R² = -3.1715, MSE = 3.1984e-01
# Theta | val -> R² = -3.6730, MSE = 1.5313e+00
# X | val -> R² = -1.3768, MSE = 2.2659e-01
# Y | val -> R² = -3.5019, MSE = 3.3464e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.582671
# Epoch 50 Loss 1.298307
# Epoch 100 Loss 1.329078
# Epoch 150 Loss 1.282870
# Epoch 200 Loss 1.220354
# Epoch 250 Loss 1.208907
# Epoch 300 Loss 1.192665
# Epoch 350 Loss 1.186302
# Epoch 400 Loss 1.171585
# Epoch 450 Loss 1.164379
# Early stopping at epoch 460
# Theta | train1 -> R² = 0.8187, MSE = 4.1459e-02
# X | train1 -> R² = -0.2720, MSE = 1.3674e-01
# Y | train1 -> R² = -1.3886, MSE = 1.9990e-01
# Theta | train2 -> R² = 0.4330, MSE = 1.2902e-01
# X | train2 -> R² = -0.1219, MSE = 9.4412e-02
# Y | train2 -> R² = -1.2950, MSE = 2.4643e-01
# Theta | test1 -> R² = 0.8750, MSE = 2.8772e-02
# X | test1 -> R² = -0.1369, MSE = 1.1873e-01
# Y | test1 -> R² = -1.8566, MSE = 2.3372e-01
# Theta | test2 -> R² = 0.6019, MSE = 9.4102e-02
# X | test2 -> R² = -0.2471, MSE = 1.0250e-01
# Y | test2 -> R² = -1.2651, MSE = 2.3979e-01
# Theta | test3 -> R² = -0.8931, MSE = 6.2312e-01
# X | test3 -> R² = -2.6800, MSE = 3.3764e-01
# Y | test3 -> R² = -3.4378, MSE = 3.4026e-01
# Theta | val -> R² = -3.5363, MSE = 1.4866e+00
# X | val -> R² = -0.6199, MSE = 1.5443e-01
# Y | val -> R² = -3.6571, MSE = 3.4618e-01
# Figura salva em: ./results/model_64_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.584749
# Epoch 50 Loss 1.296733
# Epoch 100 Loss 1.281585
# Epoch 150 Loss 1.271305
# Epoch 200 Loss 1.242873
# Epoch 250 Loss 1.214714
# Epoch 300 Loss 1.198825
# Epoch 350 Loss 1.208523
# Epoch 400 Loss 1.188321
# Epoch 450 Loss 1.178197
# Early stopping at epoch 500
# Theta | train1 -> R² = 0.8545, MSE = 3.3285e-02
# X | train1 -> R² = -0.1446, MSE = 1.2305e-01
# Y | train1 -> R² = -0.9811, MSE = 1.6580e-01
# Theta | train2 -> R² = 0.5659, MSE = 9.8758e-02
# X | train2 -> R² = 0.0320, MSE = 8.1464e-02
# Y | train2 -> R² = -1.0802, MSE = 2.2336e-01
# Theta | test1 -> R² = 0.7727, MSE = 5.2318e-02
# X | test1 -> R² = -0.0816, MSE = 1.1295e-01
# Y | test1 -> R² = -1.4077, MSE = 1.9699e-01
# Theta | test2 -> R² = 0.4101, MSE = 1.3944e-01
# X | test2 -> R² = -0.0771, MSE = 8.8532e-02
# Y | test2 -> R² = -0.9765, MSE = 2.0924e-01
# Theta | test3 -> R² = -1.5468, MSE = 8.3831e-01
# X | test3 -> R² = -2.5528, MSE = 3.2597e-01
# Y | test3 -> R² = -3.3004, MSE = 3.2973e-01
# Theta | val -> R² = -6.9438, MSE = 2.6032e+00
# X | val -> R² = -1.0489, MSE = 1.9533e-01
# Y | val -> R² = -3.0434, MSE = 3.0056e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.586765
# Epoch 50 Loss 1.309747
# Epoch 100 Loss 1.293818
# Epoch 150 Loss 1.278167
# Epoch 200 Loss 1.237867
# Epoch 250 Loss 1.220083
# Epoch 300 Loss 1.201146
# Epoch 350 Loss 1.196708
# Epoch 400 Loss 1.174713
# Epoch 450 Loss 1.172843
# Early stopping at epoch 468
# Theta | train1 -> R² = 0.9125, MSE = 2.0006e-02
# X | train1 -> R² = -0.3863, MSE = 1.4903e-01
# Y | train1 -> R² = -0.9839, MSE = 1.6603e-01
# Theta | train2 -> R² = 0.2866, MSE = 1.6231e-01
# X | train2 -> R² = -0.0544, MSE = 8.8733e-02
# Y | train2 -> R² = -1.1170, MSE = 2.2732e-01
# Theta | test1 -> R² = 0.7897, MSE = 4.8417e-02
# X | test1 -> R² = -0.4978, MSE = 1.5641e-01
# Y | test1 -> R² = -1.4256, MSE = 1.9846e-01
# Theta | test2 -> R² = 0.3292, MSE = 1.5855e-01
# X | test2 -> R² = -0.1345, MSE = 9.3249e-02
# Y | test2 -> R² = -1.0602, MSE = 2.1809e-01
# Theta | test3 -> R² = 0.3392, MSE = 2.1751e-01
# X | test3 -> R² = -1.3907, MSE = 2.1934e-01
# Y | test3 -> R² = -2.1927, MSE = 2.4480e-01
# Theta | val -> R² = -5.0915, MSE = 1.9962e+00
# X | val -> R² = -1.3497, MSE = 2.2401e-01
# Y | val -> R² = -2.0545, MSE = 2.2705e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.528266
# Epoch 50 Loss 1.297356
# Epoch 100 Loss 1.289813
# Epoch 150 Loss 1.268737
# Epoch 200 Loss 1.228135
# Epoch 250 Loss 1.206118
# Epoch 300 Loss 1.187773
# Epoch 350 Loss 1.180516
# Epoch 400 Loss 1.330820
# Epoch 450 Loss 1.194752
# Early stopping at epoch 464
# Theta | train1 -> R² = 0.3571, MSE = 1.4706e-01
# X | train1 -> R² = 0.0074, MSE = 1.0671e-01
# Y | train1 -> R² = -0.8111, MSE = 1.5157e-01
# Theta | train2 -> R² = 0.2891, MSE = 1.6176e-01
# X | train2 -> R² = -0.0768, MSE = 9.0620e-02
# Y | train2 -> R² = -0.7579, MSE = 1.8876e-01
# Theta | test1 -> R² = 0.7130, MSE = 6.6053e-02
# X | test1 -> R² = -0.0790, MSE = 1.1268e-01
# Y | test1 -> R² = -1.2362, MSE = 1.8296e-01
# Theta | test2 -> R² = 0.3408, MSE = 1.5581e-01
# X | test2 -> R² = -0.1890, MSE = 9.7731e-02
# Y | test2 -> R² = -0.7131, MSE = 1.8135e-01
# Theta | test3 -> R² = -3.9926, MSE = 1.6434e+00
# X | test3 -> R² = -2.6585, MSE = 3.3566e-01
# Y | test3 -> R² = -2.8569, MSE = 2.9572e-01
# Theta | val -> R² = -11.0002, MSE = 3.9325e+00
# X | val -> R² = -1.3376, MSE = 2.2286e-01
# Y | val -> R² = -2.7764, MSE = 2.8072e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.532727
# Epoch 50 Loss 1.302187
# Epoch 100 Loss 1.288753
# Epoch 150 Loss 1.267465
# Epoch 200 Loss 1.248899
# Epoch 250 Loss 1.240731
# Epoch 300 Loss 1.212223
# Epoch 350 Loss 1.223914
# Epoch 400 Loss 1.177384
# Epoch 450 Loss 1.274421
# Early stopping at epoch 460
# Theta | train1 -> R² = 0.7959, MSE = 4.6675e-02
# X | train1 -> R² = 0.0209, MSE = 1.0526e-01
# Y | train1 -> R² = -1.2635, MSE = 1.8943e-01
# Theta | train2 -> R² = 0.2665, MSE = 1.6690e-01
# X | train2 -> R² = -0.0761, MSE = 9.0563e-02
# Y | train2 -> R² = -1.1373, MSE = 2.2949e-01
# Theta | test1 -> R² = 0.7928, MSE = 4.7691e-02
# X | test1 -> R² = -0.0127, MSE = 1.0576e-01
# Y | test1 -> R² = -1.7027, MSE = 2.2112e-01
# Theta | test2 -> R² = 0.5029, MSE = 1.1750e-01
# X | test2 -> R² = -0.1447, MSE = 9.4084e-02
# Y | test2 -> R² = -1.0319, MSE = 2.1510e-01
# Theta | test3 -> R² = -0.1638, MSE = 3.8309e-01
# X | test3 -> R² = -2.9191, MSE = 3.5958e-01
# Y | test3 -> R² = -3.8001, MSE = 3.6804e-01
# Theta | val -> R² = -5.7575, MSE = 2.2144e+00
# X | val -> R² = -1.6145, MSE = 2.4925e-01
# Y | val -> R² = -3.5826, MSE = 3.4064e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.634332
# Epoch 50 Loss 1.302559
# Epoch 100 Loss 1.290322
# Epoch 150 Loss 1.340171
# Epoch 200 Loss 1.239215
# Epoch 250 Loss 1.201233
# Epoch 300 Loss 1.189055
# Epoch 350 Loss 1.175977
# Epoch 400 Loss 1.223240
# Epoch 450 Loss 1.155712
# Early stopping at epoch 459
# Theta | train1 -> R² = 0.9505, MSE = 1.1312e-02
# X | train1 -> R² = -0.1655, MSE = 1.2530e-01
# Y | train1 -> R² = -0.9343, MSE = 1.6188e-01
# Theta | train2 -> R² = 0.3682, MSE = 1.4374e-01
# X | train2 -> R² = -0.0913, MSE = 9.1838e-02
# Y | train2 -> R² = -0.8858, MSE = 2.0250e-01
# Theta | test1 -> R² = 0.7986, MSE = 4.6354e-02
# X | test1 -> R² = -0.2017, MSE = 1.2549e-01
# Y | test1 -> R² = -1.3117, MSE = 1.8913e-01
# Theta | test2 -> R² = 0.4657, MSE = 1.2630e-01
# X | test2 -> R² = -0.2187, MSE = 1.0017e-01
# Y | test2 -> R² = -0.8757, MSE = 1.9856e-01
# Theta | test3 -> R² = 0.0364, MSE = 3.1717e-01
# X | test3 -> R² = -1.8240, MSE = 2.5910e-01
# Y | test3 -> R² = -2.8476, MSE = 2.9501e-01
# Theta | val -> R² = -8.6805, MSE = 3.1723e+00
# X | val -> R² = -0.9364, MSE = 1.8460e-01
# Y | val -> R² = -2.3335, MSE = 2.4779e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.578924
# Epoch 50 Loss 1.301720
# Epoch 100 Loss 1.290365
# Epoch 150 Loss 1.277482
# Epoch 200 Loss 1.313437
# Epoch 250 Loss 1.225681
# Epoch 300 Loss 1.212982
# Epoch 350 Loss 1.191825
# Epoch 400 Loss 1.177755
# Epoch 450 Loss 1.171050
# Epoch 500 Loss 1.172628
# Early stopping at epoch 503
# Theta | train1 -> R² = 0.3226, MSE = 1.5494e-01
# X | train1 -> R² = -0.3166, MSE = 1.4154e-01
# Y | train1 -> R² = -1.3830, MSE = 1.9943e-01
# Theta | train2 -> R² = -0.3141, MSE = 2.9900e-01
# X | train2 -> R² = -0.2578, MSE = 1.0585e-01
# Y | train2 -> R² = -1.6349, MSE = 2.8293e-01
# Theta | test1 -> R² = 0.5818, MSE = 9.6261e-02
# X | test1 -> R² = -0.4488, MSE = 1.5129e-01
# Y | test1 -> R² = -1.5595, MSE = 2.0941e-01
# Theta | test2 -> R² = -0.2059, MSE = 2.8504e-01
# X | test2 -> R² = -0.3329, MSE = 1.0955e-01
# Y | test2 -> R² = -1.6169, MSE = 2.7702e-01
# Theta | test3 -> R² = 0.4558, MSE = 1.7914e-01
# X | test3 -> R² = -1.4783, MSE = 2.2738e-01
# Y | test3 -> R² = -3.4744, MSE = 3.4307e-01
# Theta | val -> R² = 0.6940, MSE = 1.0028e-01
# X | val -> R² = -1.0152, MSE = 1.9211e-01
# Y | val -> R² = -2.6117, MSE = 2.6847e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.555484
# Epoch 50 Loss 1.295978
# Epoch 100 Loss 1.286170
# Epoch 150 Loss 1.268764
# Epoch 200 Loss 1.238297
# Epoch 250 Loss 1.215078
# Epoch 300 Loss 1.250815
# Epoch 350 Loss 1.182862
# Epoch 400 Loss 1.173957
# Epoch 450 Loss 1.172885
# Early stopping at epoch 488
# Theta | train1 -> R² = 0.7801, MSE = 5.0306e-02
# X | train1 -> R² = -0.3351, MSE = 1.4353e-01
# Y | train1 -> R² = -1.8339, MSE = 2.3717e-01
# Theta | train2 -> R² = 0.1644, MSE = 1.9011e-01
# X | train2 -> R² = -0.4836, MSE = 1.2485e-01
# Y | train2 -> R² = -1.3637, MSE = 2.5380e-01
# Theta | test1 -> R² = 0.8170, MSE = 4.2119e-02
# X | test1 -> R² = -0.4338, MSE = 1.4974e-01
# Y | test1 -> R² = -2.4724, MSE = 2.8410e-01
# Theta | test2 -> R² = 0.2981, MSE = 1.6591e-01
# X | test2 -> R² = -0.6258, MSE = 1.3363e-01
# Y | test2 -> R² = -1.2876, MSE = 2.4217e-01
# Theta | test3 -> R² = -1.1018, MSE = 6.9181e-01
# X | test3 -> R² = -4.6948, MSE = 5.2250e-01
# Y | test3 -> R² = -5.0728, MSE = 4.6563e-01
# Theta | val -> R² = -3.2213, MSE = 1.3833e+00
# X | val -> R² = -2.2301, MSE = 3.0794e-01
# Y | val -> R² = -5.9362, MSE = 5.1559e-01
# Figura salva em: ./results/model_64_9.pdf
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.651797
# Epoch 50 Loss 1.304396
# Epoch 100 Loss 1.304956
# Epoch 150 Loss 1.288782
# Epoch 200 Loss 1.326647
# Epoch 250 Loss 1.287305
# Epoch 300 Loss 1.308151
# Epoch 350 Loss 1.277897
# Epoch 400 Loss 1.239951
# Epoch 450 Loss 1.227900
# Epoch 500 Loss 1.217540
# Epoch 550 Loss 1.201463
# Epoch 600 Loss 1.196886
# Epoch 650 Loss 1.191698
# Early stopping at epoch 653
# Theta | train1 -> R² = 0.5146, MSE = 1.1102e-01
# X | train1 -> R² = -0.0741, MSE = 1.1548e-01
# Y | train1 -> R² = -1.0346, MSE = 1.7027e-01
# Theta | train2 -> R² = 0.6889, MSE = 7.0783e-02
# X | train2 -> R² = -0.2922, MSE = 1.0874e-01
# Y | train2 -> R² = -1.2081, MSE = 2.3710e-01
# Theta | test1 -> R² = 0.6655, MSE = 7.6993e-02
# X | test1 -> R² = -0.0622, MSE = 1.1092e-01
# Y | test1 -> R² = -1.4056, MSE = 1.9681e-01
# Theta | test2 -> R² = 0.9038, MSE = 2.2735e-02
# X | test2 -> R² = -0.4668, MSE = 1.2057e-01
# Y | test2 -> R² = -1.1712, MSE = 2.2984e-01
# Theta | test3 -> R² = -3.9356, MSE = 1.6246e+00
# X | test3 -> R² = -3.2025, MSE = 3.8557e-01
# Y | test3 -> R² = -3.0169, MSE = 3.0799e-01
# Theta | val -> R² = -7.5496, MSE = 2.8017e+00
# X | val -> R² = -1.0016, MSE = 1.9082e-01
# Y | val -> R² = -2.4071, MSE = 2.5326e-01
# Figura salva em: ./results/model_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.610419
# Epoch 50 Loss 1.303118
# Epoch 100 Loss 1.322027
# Epoch 150 Loss 1.368282
# Epoch 200 Loss 1.268768
# Epoch 250 Loss 1.235362
# Epoch 300 Loss 1.227848
# Epoch 350 Loss 1.216970
# Epoch 400 Loss 1.218840
# Epoch 450 Loss 1.219727
# Epoch 500 Loss 1.218269
# Early stopping at epoch 517
# Theta | train1 -> R² = 0.8215, MSE = 4.0823e-02
# X | train1 -> R² = -0.1534, MSE = 1.2400e-01
# Y | train1 -> R² = -0.8411, MSE = 1.5408e-01
# Theta | train2 -> R² = 0.0679, MSE = 2.1207e-01
# X | train2 -> R² = -0.0065, MSE = 8.4700e-02
# Y | train2 -> R² = -1.0040, MSE = 2.1519e-01
# Theta | test1 -> R² = 0.8326, MSE = 3.8539e-02
# X | test1 -> R² = -0.1252, MSE = 1.1750e-01
# Y | test1 -> R² = -1.2139, MSE = 1.8113e-01
# Theta | test2 -> R² = 0.3430, MSE = 1.5529e-01
# X | test2 -> R² = -0.1216, MSE = 9.2192e-02
# Y | test2 -> R² = -0.9443, MSE = 2.0583e-01
# Theta | test3 -> R² = 0.6551, MSE = 1.1353e-01
# X | test3 -> R² = -1.3604, MSE = 2.1656e-01
# Y | test3 -> R² = -2.3630, MSE = 2.5786e-01
# Theta | val -> R² = -2.0602, MSE = 1.0028e+00
# X | val -> R² = -0.4765, MSE = 1.4076e-01
# Y | val -> R² = -1.8605, MSE = 2.1263e-01
# Figura salva em: ./results/model_128_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.551885
# Epoch 50 Loss 1.297281
# Epoch 100 Loss 1.287799
# Epoch 150 Loss 1.258167
# Epoch 200 Loss 1.234972
# Epoch 250 Loss 1.366274
# Epoch 300 Loss 1.231431
# Epoch 350 Loss 1.214041
# Epoch 400 Loss 1.199580
# Early stopping at epoch 448
# Theta | train1 -> R² = 0.8065, MSE = 4.4270e-02
# X | train1 -> R² = -0.3616, MSE = 1.4637e-01
# Y | train1 -> R² = -1.6253, MSE = 2.1971e-01
# Theta | train2 -> R² = 0.1066, MSE = 2.0327e-01
# X | train2 -> R² = -0.2796, MSE = 1.0768e-01
# Y | train2 -> R² = -1.3646, MSE = 2.5390e-01
# Theta | test1 -> R² = 0.7990, MSE = 4.6265e-02
# X | test1 -> R² = -0.5334, MSE = 1.6014e-01
# Y | test1 -> R² = -2.2841, MSE = 2.6869e-01
# Theta | test2 -> R² = 0.3376, MSE = 1.5657e-01
# X | test2 -> R² = -0.3484, MSE = 1.1083e-01
# Y | test2 -> R² = -1.2792, MSE = 2.4128e-01
# Theta | test3 -> R² = 0.6982, MSE = 9.9356e-02
# X | test3 -> R² = -3.2275, MSE = 3.8787e-01
# Y | test3 -> R² = -5.1566, MSE = 4.7205e-01
# Theta | val -> R² = -0.9035, MSE = 6.2377e-01
# ...
# X | test3 -> R² = -1.8390, MSE = 2.6047e-01
# Y | test3 -> R² = -3.2609, MSE = 3.2670e-01
# Theta | val -> R² = -0.0444, MSE = 3.4226e-01
# X | val -> R² = -1.4363, MSE = 2.3226e-01
# Y | val -> R² = -3.7909, MSE = 3.5612e-01
# Figura salva em: ./results/model_128_64_32_5.pdf
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.589232
# Epoch 50 Loss 1.292806
# Epoch 100 Loss 1.266711
# Epoch 150 Loss 1.241055
# Epoch 200 Loss 1.240054
# Epoch 250 Loss 1.215625
# Epoch 300 Loss 1.199338
# Epoch 350 Loss 1.171471
# Early stopping at epoch 392
# Theta | train1 -> R² = -2.6415, MSE = 8.3295e-01
# X | train1 -> R² = -0.1395, MSE = 1.2250e-01
# Y | train1 -> R² = -1.2586, MSE = 1.8902e-01
# Theta | train2 -> R² = -4.7638, MSE = 1.3114e+00
# X | train2 -> R² = -0.1759, MSE = 9.8955e-02
# Y | train2 -> R² = -1.1853, MSE = 2.3465e-01
# Theta | test1 -> R² = -1.6934, MSE = 6.2000e-01
# X | test1 -> R² = -0.3129, MSE = 1.3711e-01
# Y | test1 -> R² = -1.7648, MSE = 2.2620e-01
# Theta | test2 -> R² = -4.5784, MSE = 1.3186e+00
# X | test2 -> R² = -0.2546, MSE = 1.0312e-01
# Y | test2 -> R² = -1.2602, MSE = 2.3927e-01
# Theta | test3 -> R² = 0.4891, MSE = 1.6818e-01
# X | test3 -> R² = -4.3804, MSE = 4.9365e-01
# Y | test3 -> R² = -4.1146, MSE = 3.9216e-01
# Theta | val -> R² = 0.9021, MSE = 3.2094e-02
# X | val -> R² = -1.8163, MSE = 2.6849e-01
# Y | val -> R² = -3.9361, MSE = 3.6692e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.563776
# Epoch 50 Loss 1.291442
# Epoch 100 Loss 1.224895
# Epoch 150 Loss 1.221169
# Epoch 200 Loss 1.198984
# Epoch 250 Loss 1.204163
# Epoch 300 Loss 1.206271
# Epoch 350 Loss 1.204354
# Early stopping at epoch 360
# Theta | train1 -> R² = -3.3504, MSE = 9.9509e-01
# X | train1 -> R² = -0.0365, MSE = 1.1143e-01
# Y | train1 -> R² = -1.4724, MSE = 2.0691e-01
# Theta | train2 -> R² = -5.8577, MSE = 1.5603e+00
# X | train2 -> R² = -0.0812, MSE = 9.0988e-02
# Y | train2 -> R² = -1.2504, MSE = 2.4164e-01
# Theta | test1 -> R² = -2.7441, MSE = 8.6186e-01
# X | test1 -> R² = -0.1090, MSE = 1.1581e-01
# Y | test1 -> R² = -1.9551, MSE = 2.4177e-01
# Theta | test2 -> R² = -6.3896, MSE = 1.7467e+00
# X | test2 -> R² = -0.1573, MSE = 9.5120e-02
# Y | test2 -> R² = -1.3025, MSE = 2.4374e-01
# Theta | test3 -> R² = -0.0245, MSE = 3.3722e-01
# X | test3 -> R² = -1.9972, MSE = 2.7499e-01
# Y | test3 -> R² = -4.6416, MSE = 4.3256e-01
# Theta | val -> R² = -1.4327, MSE = 7.9718e-01
# X | val -> R² = -1.2847, MSE = 2.1781e-01
# Y | val -> R² = -4.6418, MSE = 4.1938e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.563498
# Epoch 50 Loss 1.312853
# Epoch 100 Loss 1.296830
# Epoch 150 Loss 1.245939
# Epoch 200 Loss 1.199439
# Epoch 250 Loss 1.180704
# Epoch 300 Loss 1.168670
# Early stopping at epoch 308
# Theta | train1 -> R² = 0.7540, MSE = 5.6258e-02
# X | train1 -> R² = -0.0361, MSE = 1.1138e-01
# Y | train1 -> R² = -0.5362, MSE = 1.2857e-01
# Theta | train2 -> R² = -0.5487, MSE = 3.5237e-01
# X | train2 -> R² = -0.2941, MSE = 1.0890e-01
# Y | train2 -> R² = -0.7050, MSE = 1.8307e-01
# Theta | test1 -> R² = 0.6316, MSE = 8.4811e-02
# X | test1 -> R² = -0.2858, MSE = 1.3427e-01
# Y | test1 -> R² = -0.7696, MSE = 1.4478e-01
# Theta | test2 -> R² = -0.0577, MSE = 2.5002e-01
# X | test2 -> R² = -0.4215, MSE = 1.1684e-01
# Y | test2 -> R² = -0.7236, MSE = 1.8246e-01
# Theta | test3 -> R² = -0.0020, MSE = 3.2980e-01
# X | test3 -> R² = -2.3752, MSE = 3.0968e-01
# Y | test3 -> R² = -2.2546, MSE = 2.4954e-01
# Theta | val -> R² = -0.2443, MSE = 4.0775e-01
# X | val -> R² = -2.0582, MSE = 2.9155e-01
# Y | val -> R² = -2.1265, MSE = 2.3241e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.557616
# Epoch 50 Loss 1.300155
# Epoch 100 Loss 1.251999
# Epoch 150 Loss 1.248045
# Epoch 200 Loss 1.230819
# Epoch 250 Loss 1.192887
# Epoch 300 Loss 1.189428
# Early stopping at epoch 329
# Theta | train1 -> R² = 0.7370, MSE = 6.0166e-02
# X | train1 -> R² = -0.1782, MSE = 1.2666e-01
# Y | train1 -> R² = -0.9766, MSE = 1.6542e-01
# Theta | train2 -> R² = 0.7297, MSE = 6.1509e-02
# X | train2 -> R² = -0.1910, MSE = 1.0023e-01
# Y | train2 -> R² = -0.9189, MSE = 2.0605e-01
# Theta | test1 -> R² = 0.7696, MSE = 5.3045e-02
# X | test1 -> R² = -0.3368, MSE = 1.3961e-01
# Y | test1 -> R² = -1.3356, MSE = 1.9109e-01
# Theta | test2 -> R² = 0.7459, MSE = 6.0063e-02
# X | test2 -> R² = -0.2968, MSE = 1.0659e-01
# Y | test2 -> R² = -0.9402, MSE = 2.0539e-01
# Theta | test3 -> R² = 0.1478, MSE = 2.8052e-01
# X | test3 -> R² = -2.3880, MSE = 3.1084e-01
# Y | test3 -> R² = -2.9610, MSE = 3.0371e-01
# Theta | val -> R² = -4.0342, MSE = 1.6497e+00
# X | val -> R² = -1.3614, MSE = 2.2512e-01
# Y | val -> R² = -2.4568, MSE = 2.5696e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.520820
# Epoch 50 Loss 1.410034
# Epoch 100 Loss 1.279594
# Epoch 150 Loss 1.290231
# Epoch 200 Loss 1.256979
# Epoch 250 Loss 1.255998
# Epoch 300 Loss 1.262908
# Epoch 350 Loss 1.226427
# Early stopping at epoch 365
# Theta | train1 -> R² = 0.8857, MSE = 2.6146e-02
# X | train1 -> R² = 0.1841, MSE = 8.7710e-02
# Y | train1 -> R² = -1.0938, MSE = 1.7523e-01
# Theta | train2 -> R² = 0.8963, MSE = 2.3600e-02
# X | train2 -> R² = -0.1147, MSE = 9.3805e-02
# Y | train2 -> R² = -0.7596, MSE = 1.8894e-01
# Theta | test1 -> R² = 0.7257, MSE = 6.3131e-02
# X | test1 -> R² = -0.0082, MSE = 1.0529e-01
# Y | test1 -> R² = -1.3744, MSE = 1.9426e-01
# Theta | test2 -> R² = 0.7516, MSE = 5.8710e-02
# X | test2 -> R² = -0.1703, MSE = 9.6193e-02
# Y | test2 -> R² = -0.8434, MSE = 1.9514e-01
# Theta | test3 -> R² = -0.0856, MSE = 3.5732e-01
# X | test3 -> R² = -2.7208, MSE = 3.4138e-01
# Y | test3 -> R² = -4.7977, MSE = 4.4454e-01
# Theta | val -> R² = -1.5251, MSE = 8.2748e-01
# X | val -> R² = -0.8717, MSE = 1.7844e-01
# Y | val -> R² = -3.3553, MSE = 3.2374e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.644235
# Epoch 50 Loss 1.467939
# Epoch 100 Loss 1.467198
# Epoch 150 Loss 1.582827
# Epoch 200 Loss 1.473891
# Epoch 250 Loss 1.459223
# Epoch 300 Loss 1.570584
# Epoch 350 Loss 1.527716
# Epoch 400 Loss 1.475032
# Epoch 450 Loss 1.471446
# Epoch 500 Loss 1.470763
# Epoch 550 Loss 1.483204
# Early stopping at epoch 558
# Theta | train1 -> R² = 0.4410, MSE = 1.2786e-01
# X | train1 -> R² = -1.5330, MSE = 2.7231e-01
# Y | train1 -> R² = -1.3418, MSE = 1.9598e-01
# Theta | train2 -> R² = -3.7553, MSE = 1.0820e+00
# X | train2 -> R² = -1.5193, MSE = 2.1202e-01
# Y | train2 -> R² = -1.1063, MSE = 2.2616e-01
# Theta | test1 -> R² = 0.5351, MSE = 1.0700e-01
# X | test1 -> R² = -1.8270, MSE = 2.9523e-01
# Y | test1 -> R² = -1.6897, MSE = 2.2006e-01
# Theta | test2 -> R² = -2.7995, MSE = 8.9810e-01
# X | test2 -> R² = -1.6573, MSE = 2.1841e-01
# Y | test2 -> R² = -1.1500, MSE = 2.2760e-01
# Theta | test3 -> R² = -1.9134, MSE = 9.5897e-01
# X | test3 -> R² = -6.2788, MSE = 6.6783e-01
# Y | test3 -> R² = -6.5731, MSE = 5.8066e-01
# Theta | val -> R² = -0.7608, MSE = 5.7703e-01
# X | val -> R² = -3.5246, MSE = 4.3135e-01
# Y | val -> R² = -3.9430, MSE = 3.6743e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.574556
# Epoch 50 Loss 1.468253
# Epoch 100 Loss 1.468655
# Epoch 150 Loss 1.469271
# Epoch 200 Loss 1.466699
# Epoch 250 Loss 1.468549
# Epoch 300 Loss 1.455659
# Epoch 350 Loss 1.451901
# Epoch 400 Loss 1.472313
# Epoch 450 Loss 1.469755
# Epoch 500 Loss 1.470042
# Epoch 550 Loss 1.471207
# Epoch 600 Loss 1.470684
# Epoch 650 Loss 1.470588
# Early stopping at epoch 669
# Theta | train1 -> R² = -4.2541, MSE = 1.2018e+00
# X | train1 -> R² = 0.0505, MSE = 1.0208e-01
# Y | train1 -> R² = -1.1458, MSE = 1.7958e-01
# Theta | train2 -> R² = -2.5716, MSE = 8.1263e-01
# X | train2 -> R² = 0.0333, MSE = 8.1352e-02
# Y | train2 -> R² = -1.6838, MSE = 2.8818e-01
# Theta | test1 -> R² = -3.9276, MSE = 1.1343e+00
# X | test1 -> R² = -0.1089, MSE = 1.1580e-01
# Y | test1 -> R² = -1.3342, MSE = 1.9097e-01
# Theta | test2 -> R² = -2.4430, MSE = 8.1384e-01
# X | test2 -> R² = -0.0048, MSE = 8.2591e-02
# Y | test2 -> R² = -1.6574, MSE = 2.8132e-01
# Theta | test3 -> R² = -4.4213, MSE = 1.7845e+00
# X | test3 -> R² = -4.2073, MSE = 4.7777e-01
# Y | test3 -> R² = -2.6676, MSE = 2.8121e-01
# Theta | val -> R² = -4.9003, MSE = 1.9335e+00
# X | val -> R² = -1.9831, MSE = 2.8439e-01
# Y | val -> R² = -2.1568, MSE = 2.3465e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.555331
# Epoch 50 Loss 1.433429
# Epoch 100 Loss 1.251128
# Epoch 150 Loss 1.287221
# Epoch 200 Loss 1.204950
# Epoch 250 Loss 1.202975
# Epoch 300 Loss 1.185098
# Epoch 350 Loss 1.172924
# Early stopping at epoch 360
# Theta | train1 -> R² = -7.0261, MSE = 1.8359e+00
# X | train1 -> R² = -0.5494, MSE = 1.6656e-01
# Y | train1 -> R² = -1.1530, MSE = 1.8018e-01
# Theta | train2 -> R² = -3.5241, MSE = 1.0293e+00
# X | train2 -> R² = -0.1780, MSE = 9.9136e-02
# Y | train2 -> R² = -0.8098, MSE = 1.9433e-01
# Theta | test1 -> R² = -6.3819, MSE = 1.6992e+00
# X | test1 -> R² = -0.7430, MSE = 1.8203e-01
# Y | test1 -> R² = -1.3927, MSE = 1.9576e-01
# Theta | test2 -> R² = -3.1311, MSE = 9.7649e-01
# X | test2 -> R² = -0.2546, MSE = 1.0312e-01
# Y | test2 -> R² = -0.8400, MSE = 1.9478e-01
# Theta | test3 -> R² = -36.3152, MSE = 1.2283e+01
# X | test3 -> R² = -6.1275, MSE = 6.5394e-01
# Y | test3 -> R² = -6.2779, MSE = 5.5803e-01
# Theta | val -> R² = -23.9295, MSE = 8.1694e+00
# X | val -> R² = -3.9348, MSE = 4.7045e-01
# Y | val -> R² = -3.9429, MSE = 3.6742e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.693102
# Epoch 50 Loss 1.468368
# Epoch 100 Loss 1.471537
# Epoch 150 Loss 1.569427
# Epoch 200 Loss 1.890409
# Epoch 250 Loss 1.340070
# Epoch 300 Loss 1.300889
# Epoch 350 Loss 1.289709
# Epoch 400 Loss 1.260679
# Epoch 450 Loss 1.226001
# Epoch 500 Loss 1.219392
# Epoch 550 Loss 1.236243
# Epoch 600 Loss 1.203426
# Epoch 650 Loss 1.216705
# Early stopping at epoch 656
# Theta | train1 -> R² = 0.5687, MSE = 9.8657e-02
# X | train1 -> R² = 0.1361, MSE = 9.2868e-02
# Y | train1 -> R² = -1.2245, MSE = 1.8616e-01
# Theta | train2 -> R² = 0.8860, MSE = 2.5930e-02
# X | train2 -> R² = 0.0205, MSE = 8.2432e-02
# Y | train2 -> R² = -1.0769, MSE = 2.2301e-01
# Theta | test1 -> R² = 0.2520, MSE = 1.7217e-01
# X | test1 -> R² = 0.0727, MSE = 9.6836e-02
# Y | test1 -> R² = -1.5331, MSE = 2.0724e-01
# Theta | test2 -> R² = 0.8795, MSE = 2.8485e-02
# X | test2 -> R² = -0.0641, MSE = 8.7463e-02
# Y | test2 -> R² = -1.1130, MSE = 2.2369e-01
# Theta | test3 -> R² = -1.9039, MSE = 9.5585e-01
# X | test3 -> R² = -2.4551, MSE = 3.1701e-01
# Y | test3 -> R² = -4.9404, MSE = 4.5548e-01
# Theta | val -> R² = 0.4473, MSE = 1.8113e-01
# X | val -> R² = -1.0845, MSE = 1.9872e-01
# Y | val -> R² = -3.9416, MSE = 3.6733e-01
# Figura salva em: ./results/model_264_128_64_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.544425
# Epoch 50 Loss 1.470023
# Epoch 100 Loss 1.469513
# Epoch 150 Loss 1.468087
# Epoch 200 Loss 1.468062
# Epoch 250 Loss 1.464636
# Epoch 300 Loss 1.483894
# Epoch 350 Loss 1.417104
# Epoch 400 Loss 1.297757
# Epoch 450 Loss 1.256543
# Epoch 500 Loss 1.227124
# Epoch 550 Loss 1.221282
# Epoch 600 Loss 1.192119
# Epoch 650 Loss 1.208504
# Early stopping at epoch 660
# Theta | train1 -> R² = 0.3326, MSE = 1.5266e-01
# X | train1 -> R² = -0.0609, MSE = 1.1405e-01
# Y | train1 -> R² = -0.4790, MSE = 1.2378e-01
# Theta | train2 -> R² = -0.0755, MSE = 2.4471e-01
# X | train2 -> R² = -0.0825, MSE = 9.1097e-02
# Y | train2 -> R² = -0.8068, MSE = 1.9401e-01
# Theta | test1 -> R² = 0.3448, MSE = 1.5083e-01
# X | test1 -> R² = -0.1948, MSE = 1.2478e-01
# Y | test1 -> R² = -0.6862, MSE = 1.3796e-01
# Theta | test2 -> R² = 0.0862, MSE = 2.1600e-01
# X | test2 -> R² = -0.1507, MSE = 9.4579e-02
# Y | test2 -> R² = -0.8454, MSE = 1.9536e-01
# Theta | test3 -> R² = -2.1503, MSE = 1.0369e+00
# X | test3 -> R² = -3.5789, MSE = 4.2011e-01
# Y | test3 -> R² = -3.2333, MSE = 3.2459e-01
# Theta | val -> R² = -0.0597, MSE = 3.4727e-01
# X | val -> R² = -1.9789, MSE = 2.8399e-01
# Y | val -> R² = -2.1590, MSE = 2.3482e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.593906
# Epoch 50 Loss 1.471416
# Epoch 100 Loss 1.484484
# Epoch 150 Loss 1.322789
# Epoch 200 Loss 1.231851
# Epoch 250 Loss 1.207815
# Epoch 300 Loss 1.200038
# Epoch 350 Loss 1.191112
# Epoch 400 Loss 1.182161
# Early stopping at epoch 439
# Theta | train1 -> R² = 0.9189, MSE = 1.8554e-02
# X | train1 -> R² = -0.5342, MSE = 1.6493e-01
# Y | train1 -> R² = -1.1199, MSE = 1.7741e-01
# Theta | train2 -> R² = 0.6495, MSE = 7.9746e-02
# X | train2 -> R² = -0.4472, MSE = 1.2179e-01
# Y | train2 -> R² = -1.0087, MSE = 2.1569e-01
# Theta | test1 -> R² = 0.8819, MSE = 2.7184e-02
# X | test1 -> R² = -0.7966, MSE = 1.8762e-01
# Y | test1 -> R² = -1.4478, MSE = 2.0027e-01
# Theta | test2 -> R² = 0.7351, MSE = 6.2620e-02
# X | test2 -> R² = -0.6153, MSE = 1.3277e-01
# Y | test2 -> R² = -1.0818, MSE = 2.2038e-01
# Theta | test3 -> R² = 0.8249, MSE = 5.7642e-02
# X | test3 -> R² = -1.7178, MSE = 2.4936e-01
# Y | test3 -> R² = -3.2649, MSE = 3.2701e-01
# Theta | val -> R² = 0.0640, MSE = 3.0674e-01
# X | val -> R² = -1.6444, MSE = 2.5210e-01
# Y | val -> R² = -2.9814, MSE = 2.9595e-01
# Figura salva em: ./results/model_264_128_64_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.625774
# Epoch 50 Loss 1.381548
# Epoch 100 Loss 1.313954
# Epoch 150 Loss 1.282838
# Epoch 200 Loss 1.274291
# Epoch 250 Loss 1.237477
# Epoch 300 Loss 1.240762
# Epoch 350 Loss 1.212330
# Epoch 400 Loss 1.206262
# Early stopping at epoch 402
# Theta | train1 -> R² = -0.4643, MSE = 3.3494e-01
# X | train1 -> R² = -0.0687, MSE = 1.1489e-01
# Y | train1 -> R² = -1.1568, MSE = 1.8050e-01
# Theta | train2 -> R² = 0.4531, MSE = 1.2443e-01
# X | train2 -> R² = 0.0747, MSE = 7.7872e-02
# Y | train2 -> R² = -1.0642, MSE = 2.2165e-01
# Theta | test1 -> R² = 0.5176, MSE = 1.1105e-01
# X | test1 -> R² = -0.1779, MSE = 1.2301e-01
# Y | test1 -> R² = -1.6121, MSE = 2.1371e-01
# Theta | test2 -> R² = 0.7274, MSE = 6.4438e-02
# X | test2 -> R² = 0.0243, MSE = 8.0200e-02
# Y | test2 -> R² = -1.1714, MSE = 2.2987e-01
# Theta | test3 -> R² = -3.1680, MSE = 1.3719e+00
# X | test3 -> R² = -2.6001, MSE = 3.3031e-01
# Y | test3 -> R² = -4.6949, MSE = 4.3665e-01
# Theta | val -> R² = 0.4083, MSE = 1.9389e-01
# X | val -> R² = -1.7682, MSE = 2.6390e-01
# Y | val -> R² = -3.7751, MSE = 3.5495e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.567828
# Epoch 50 Loss 1.476447
# Epoch 100 Loss 1.472725
# Epoch 150 Loss 1.461918
# Epoch 200 Loss 1.321042
# Epoch 250 Loss 1.281391
# Epoch 300 Loss 1.231646
# Epoch 350 Loss 1.220408
# Epoch 400 Loss 1.214257
# Epoch 450 Loss 1.203804
# Epoch 500 Loss 1.223866
# Epoch 550 Loss 1.191534
# Early stopping at epoch 566
# Theta | train1 -> R² = 0.6554, MSE = 7.8816e-02
# X | train1 -> R² = -0.0401, MSE = 1.1181e-01
# Y | train1 -> R² = -0.9771, MSE = 1.6546e-01
# Theta | train2 -> R² = -0.1187, MSE = 2.5453e-01
# X | train2 -> R² = -0.0997, MSE = 9.2544e-02
# Y | train2 -> R² = -0.8807, MSE = 2.0195e-01
# Theta | test1 -> R² = 0.8159, MSE = 4.2371e-02
# X | test1 -> R² = -0.2447, MSE = 1.2998e-01
# Y | test1 -> R² = -1.2437, MSE = 1.8357e-01
# Theta | test2 -> R² = -0.5445, MSE = 3.6508e-01
# X | test2 -> R² = -0.2086, MSE = 9.9340e-02
# Y | test2 -> R² = -0.9180, MSE = 2.0304e-01
# Theta | test3 -> R² = -4.6560, MSE = 1.8617e+00
# X | test3 -> R² = -2.3956, MSE = 3.1155e-01
# Y | test3 -> R² = -3.8175, MSE = 3.6938e-01
# Theta | val -> R² = 0.7014, MSE = 9.7848e-02
# X | val -> R² = -1.3719, MSE = 2.2612e-01
# Y | val -> R² = -3.1077, MSE = 3.0534e-01
# Figura salva em: ./results/model_264_128_64_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.615106
# Epoch 50 Loss 1.472465
# Epoch 100 Loss 1.471735
# Epoch 150 Loss 1.470654
# Epoch 200 Loss 1.470294
# Epoch 250 Loss 1.470282
# Epoch 300 Loss 1.476247
# Early stopping at epoch 310
# Theta | train1 -> R² = -0.0064, MSE = 2.3019e-01
# X | train1 -> R² = -0.0992, MSE = 1.1817e-01
# Y | train1 -> R² = -1.6220, MSE = 2.1943e-01
# Theta | train2 -> R² = -1.4707, MSE = 5.6216e-01
# X | train2 -> R² = 0.0600, MSE = 7.9109e-02
# Y | train2 -> R² = -1.8545, MSE = 3.0650e-01
# Theta | test1 -> R² = 0.0359, MSE = 2.2193e-01
# X | test1 -> R² = -0.2421, MSE = 1.2972e-01
# Y | test1 -> R² = -1.8306, MSE = 2.3158e-01
# Theta | test2 -> R² = -1.4810, MSE = 5.8645e-01
# X | test2 -> R² = 0.0333, MSE = 7.9458e-02
# Y | test2 -> R² = -1.8319, MSE = 2.9979e-01
# Theta | test3 -> R² = -0.4054, MSE = 4.6259e-01
# X | test3 -> R² = -2.9230, MSE = 3.5993e-01
# Y | test3 -> R² = -3.5873, MSE = 3.5173e-01
# Theta | val -> R² = -0.6360, MSE = 5.3612e-01
# X | val -> R² = -1.5760, MSE = 2.4558e-01
# Y | val -> R² = -2.9138, MSE = 2.9092e-01
# Modelo 9 treinado e salvo no Excel
