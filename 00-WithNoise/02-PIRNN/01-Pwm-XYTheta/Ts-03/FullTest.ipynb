# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 3
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 3, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[8], [16], [32], [64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# Epoch 0 Loss 1.576258
# Epoch 50 Loss 1.293460
# Epoch 100 Loss 1.273560
# Epoch 150 Loss 1.249894
# Epoch 200 Loss 1.238779
# Epoch 250 Loss 1.226204
# Epoch 300 Loss 1.207418
# Epoch 350 Loss 1.180793
# Epoch 400 Loss 1.172200
# Epoch 450 Loss 1.167498
# Early stopping at epoch 479
# Theta | train1 -> R² = 0.9180, MSE = 1.8726e-02
# X | train1 -> R² = -0.1948, MSE = 1.2883e-01
# Y | train1 -> R² = -1.0496, MSE = 1.7175e-01
# Theta | train2 -> R² = 0.6009, MSE = 9.1126e-02
# X | train2 -> R² = -0.1467, MSE = 9.6620e-02
# Y | train2 -> R² = -0.8151, MSE = 1.9545e-01
# Theta | test1 -> R² = 0.6629, MSE = 7.7427e-02
# X | test1 -> R² = -0.2986, MSE = 1.3605e-01
# Y | test1 -> R² = -1.4134, MSE = 1.9778e-01
# Theta | test2 -> R² = 0.4220, MSE = 1.3709e-01
# X | test2 -> R² = -0.2580, MSE = 1.0352e-01
# Y | test2 -> R² = -0.8667, MSE = 1.9814e-01
# Theta | test3 -> R² = 0.3065, MSE = 2.2798e-01
# X | test3 -> R² = -2.1306, MSE = 2.8803e-01
# Y | test3 -> R² = -3.7842, MSE = 3.6746e-01
# Theta | val -> R² = -0.6482, MSE = 5.3942e-01
# X | val -> R² = -1.6464, MSE = 2.5305e-01
# Y | val -> R² = -3.4128, MSE = 3.2853e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.561969
# Epoch 50 Loss 1.297018
# Epoch 100 Loss 1.283328
# Epoch 150 Loss 1.275999
# Epoch 200 Loss 1.260667
# Epoch 250 Loss 1.244950
# Epoch 300 Loss 1.241222
# Epoch 350 Loss 1.236670
# Epoch 400 Loss 1.226789
# Epoch 450 Loss 1.194193
# Epoch 500 Loss 1.183654
# Epoch 550 Loss 1.175594
# Epoch 600 Loss 1.170253
# Early stopping at epoch 637
# Theta | train1 -> R² = 0.9338, MSE = 1.5108e-02
# X | train1 -> R² = -0.1899, MSE = 1.2830e-01
# Y | train1 -> R² = -1.0130, MSE = 1.6868e-01
# Theta | train2 -> R² = 0.6379, MSE = 8.2658e-02
# X | train2 -> R² = -0.1713, MSE = 9.8696e-02
# Y | train2 -> R² = -0.8734, MSE = 2.0173e-01
# Theta | test1 -> R² = 0.7141, MSE = 6.5686e-02
# X | test1 -> R² = -0.2935, MSE = 1.3551e-01
# Y | test1 -> R² = -1.4513, MSE = 2.0088e-01
# Theta | test2 -> R² = 0.4822, MSE = 1.2279e-01
# X | test2 -> R² = -0.2565, MSE = 1.0340e-01
# Y | test2 -> R² = -0.8445, MSE = 1.9578e-01
# Theta | test3 -> R² = -0.3536, MSE = 4.4498e-01
# X | test3 -> R² = -1.9719, MSE = 2.7342e-01
# Y | test3 -> R² = -2.7232, MSE = 2.8597e-01
# Theta | val -> R² = -0.6958, MSE = 5.5501e-01
# X | val -> R² = -1.6317, MSE = 2.5165e-01
# Y | val -> R² = -2.9303, MSE = 2.9261e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.564743
# Epoch 50 Loss 1.298189
# Epoch 100 Loss 1.281989
# Epoch 150 Loss 1.263040
# Epoch 200 Loss 1.225398
# Epoch 250 Loss 1.195767
# Epoch 300 Loss 1.186099
# Epoch 350 Loss 1.177540
# Epoch 400 Loss 1.171132
# Epoch 450 Loss 1.167055
# Early stopping at epoch 457
# Theta | train1 -> R² = 0.6726, MSE = 7.4736e-02
# X | train1 -> R² = -0.2358, MSE = 1.3325e-01
# Y | train1 -> R² = -1.0921, MSE = 1.7531e-01
# Theta | train2 -> R² = 0.6818, MSE = 7.2653e-02
# X | train2 -> R² = -0.1183, MSE = 9.4231e-02
# Y | train2 -> R² = -0.8006, MSE = 1.9388e-01
# Theta | test1 -> R² = 0.2995, MSE = 1.6093e-01
# X | test1 -> R² = -0.4505, MSE = 1.5195e-01
# Y | test1 -> R² = -1.5300, MSE = 2.0733e-01
# Theta | test2 -> R² = 0.7144, MSE = 6.7725e-02
# X | test2 -> R² = -0.2393, MSE = 1.0199e-01
# Y | test2 -> R² = -0.9343, MSE = 2.0532e-01
# Theta | test3 -> R² = -1.8093, MSE = 9.2354e-01
# X | test3 -> R² = -1.2644, MSE = 2.0833e-01
# Y | test3 -> R² = -4.6031, MSE = 4.3036e-01
# Theta | val -> R² = -5.8760, MSE = 2.2504e+00
# X | val -> R² = -1.5219, MSE = 2.4115e-01
# Y | val -> R² = -4.7378, MSE = 4.2718e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.596317
# Epoch 50 Loss 1.292358
# Epoch 100 Loss 1.263134
# Epoch 150 Loss 1.248366
# Epoch 200 Loss 1.244367
# Epoch 250 Loss 1.240346
# Epoch 300 Loss 1.223513
# Epoch 350 Loss 1.206098
# Epoch 400 Loss 1.195246
# Epoch 450 Loss 1.188230
# Epoch 500 Loss 1.184391
# Early stopping at epoch 547
# Theta | train1 -> R² = 0.7028, MSE = 6.7830e-02
# X | train1 -> R² = -0.1818, MSE = 1.2743e-01
# Y | train1 -> R² = -1.0342, MSE = 1.7046e-01
# Theta | train2 -> R² = 0.8229, MSE = 4.0425e-02
# X | train2 -> R² = -0.1804, MSE = 9.9461e-02
# Y | train2 -> R² = -0.7709, MSE = 1.9069e-01
# Theta | test1 -> R² = 0.3933, MSE = 1.3937e-01
# X | test1 -> R² = -0.3266, MSE = 1.3898e-01
# Y | test1 -> R² = -1.4105, MSE = 1.9754e-01
# Theta | test2 -> R² = 0.7793, MSE = 5.2353e-02
# X | test2 -> R² = -0.2846, MSE = 1.0571e-01
# Y | test2 -> R² = -0.8098, MSE = 1.9209e-01
# Theta | test3 -> R² = -0.4659, MSE = 4.8191e-01
# X | test3 -> R² = -1.6820, MSE = 2.4676e-01
# Y | test3 -> R² = -2.9235, MSE = 3.0136e-01
# Theta | val -> R² = -2.8161, MSE = 1.2489e+00
# X | val -> R² = -1.3606, MSE = 2.2573e-01
# Y | val -> R² = -2.6520, MSE = 2.7189e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.575248
# Epoch 50 Loss 1.293976
# Epoch 100 Loss 1.261048
# Epoch 150 Loss 1.245171
# Epoch 200 Loss 1.222165
# Epoch 250 Loss 1.205480
# Epoch 300 Loss 1.195462
# Epoch 350 Loss 1.187631
# Early stopping at epoch 363
# Theta | train1 -> R² = 0.8359, MSE = 3.7451e-02
# X | train1 -> R² = -0.2088, MSE = 1.3034e-01
# Y | train1 -> R² = -1.1249, MSE = 1.7806e-01
# Theta | train2 -> R² = 0.7570, MSE = 5.5466e-02
# X | train2 -> R² = -0.1268, MSE = 9.4942e-02
# Y | train2 -> R² = -0.8349, MSE = 1.9758e-01
# Theta | test1 -> R² = 0.4524, MSE = 1.2580e-01
# X | test1 -> R² = -0.3239, MSE = 1.3870e-01
# Y | test1 -> R² = -1.3982, MSE = 1.9653e-01
# Theta | test2 -> R² = 0.6965, MSE = 7.1973e-02
# X | test2 -> R² = -0.2147, MSE = 9.9962e-02
# Y | test2 -> R² = -0.9160, MSE = 2.0337e-01
# Theta | test3 -> R² = 0.4658, MSE = 1.7561e-01
# X | test3 -> R² = -2.4873, MSE = 3.2085e-01
# Y | test3 -> R² = -6.5915, MSE = 5.8308e-01
# Theta | val -> R² = -4.8535, MSE = 1.9157e+00
# X | val -> R² = -1.9402, MSE = 2.8115e-01
# Y | val -> R² = -5.4901, MSE = 4.8319e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.582022
# Epoch 50 Loss 1.312419
# Epoch 100 Loss 1.282495
# Epoch 150 Loss 1.266712
# Epoch 200 Loss 1.244924
# Epoch 250 Loss 1.218627
# Epoch 300 Loss 1.200199
# Epoch 350 Loss 1.179082
# Epoch 400 Loss 1.173529
# Epoch 450 Loss 1.170537
# Early stopping at epoch 455
# Theta | train1 -> R² = 0.7686, MSE = 5.2821e-02
# X | train1 -> R² = -0.2286, MSE = 1.3247e-01
# Y | train1 -> R² = -1.1045, MSE = 1.7635e-01
# Theta | train2 -> R² = 0.7917, MSE = 4.7548e-02
# X | train2 -> R² = -0.1413, MSE = 9.6164e-02
# Y | train2 -> R² = -0.8252, MSE = 1.9654e-01
# Theta | test1 -> R² = 0.4677, MSE = 1.2228e-01
# X | test1 -> R² = -0.3328, MSE = 1.3962e-01
# Y | test1 -> R² = -1.4816, MSE = 2.0336e-01
# Theta | test2 -> R² = 0.5704, MSE = 1.0188e-01
# X | test2 -> R² = -0.2187, MSE = 1.0029e-01
# Y | test2 -> R² = -0.8772, MSE = 1.9926e-01
# Theta | test3 -> R² = -0.8177, MSE = 5.9756e-01
# X | test3 -> R² = -2.4084, MSE = 3.1358e-01
# Y | test3 -> R² = -5.1482, MSE = 4.7222e-01
# Theta | val -> R² = -5.3317, MSE = 2.0722e+00
# X | val -> R² = -1.7011, MSE = 2.5829e-01
# Y | val -> R² = -4.2901, MSE = 3.9385e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.574901
# Epoch 50 Loss 1.309952
# Epoch 100 Loss 1.286612
# Epoch 150 Loss 1.276377
# Epoch 200 Loss 1.260221
# Epoch 250 Loss 1.237100
# Epoch 300 Loss 1.219020
# Epoch 350 Loss 1.202042
# Epoch 400 Loss 1.187816
# Epoch 450 Loss 1.181493
# Early stopping at epoch 485
# Theta | train1 -> R² = 0.7146, MSE = 6.5138e-02
# X | train1 -> R² = -0.1798, MSE = 1.2722e-01
# Y | train1 -> R² = -1.0637, MSE = 1.7293e-01
# Theta | train2 -> R² = 0.8027, MSE = 4.5054e-02
# X | train2 -> R² = -0.1353, MSE = 9.5660e-02
# Y | train2 -> R² = -0.8884, MSE = 2.0334e-01
# Theta | test1 -> R² = 0.3650, MSE = 1.4587e-01
# X | test1 -> R² = -0.2769, MSE = 1.3377e-01
# Y | test1 -> R² = -1.4100, MSE = 1.9749e-01
# Theta | test2 -> R² = 0.6035, MSE = 9.4024e-02
# X | test2 -> R² = -0.1990, MSE = 9.8672e-02
# Y | test2 -> R² = -0.9489, MSE = 2.0686e-01
# Theta | test3 -> R² = -0.9804, MSE = 6.5104e-01
# X | test3 -> R² = -1.6575, MSE = 2.4450e-01
# Y | test3 -> R² = -4.8164, MSE = 4.4674e-01
# Theta | val -> R² = -3.8182, MSE = 1.5769e+00
# X | val -> R² = -1.0173, MSE = 1.9290e-01
# Y | val -> R² = -3.8107, MSE = 3.5816e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.587081
# Epoch 50 Loss 1.295869
# Epoch 100 Loss 1.276288
# Epoch 150 Loss 1.250954
# Epoch 200 Loss 1.219494
# Epoch 250 Loss 1.189602
# Epoch 300 Loss 1.181355
# Epoch 350 Loss 1.172447
# Epoch 400 Loss 1.167111
# Epoch 450 Loss 1.164393
# Early stopping at epoch 455
# Theta | train1 -> R² = 0.8364, MSE = 3.7349e-02
# X | train1 -> R² = -0.1927, MSE = 1.2861e-01
# Y | train1 -> R² = -1.0046, MSE = 1.6797e-01
# Theta | train2 -> R² = 0.7809, MSE = 5.0014e-02
# X | train2 -> R² = -0.1940, MSE = 1.0061e-01
# Y | train2 -> R² = -0.8317, MSE = 1.9724e-01
# Theta | test1 -> R² = 0.5669, MSE = 9.9494e-02
# X | test1 -> R² = -0.3522, MSE = 1.4166e-01
# Y | test1 -> R² = -1.3892, MSE = 1.9579e-01
# Theta | test2 -> R² = 0.5960, MSE = 9.5817e-02
# X | test2 -> R² = -0.3309, MSE = 1.0952e-01
# Y | test2 -> R² = -0.9709, MSE = 2.0919e-01
# Theta | test3 -> R² = -0.5702, MSE = 5.1621e-01
# X | test3 -> R² = -1.0425, MSE = 1.8792e-01
# Y | test3 -> R² = -3.1887, MSE = 3.2172e-01
# Theta | val -> R² = -0.3150, MSE = 4.3037e-01
# X | val -> R² = -1.0819, MSE = 1.9907e-01
# Y | val -> R² = -3.3422, MSE = 3.2328e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.569155
# Epoch 50 Loss 1.296580
# Epoch 100 Loss 1.275406
# Epoch 150 Loss 1.247842
# Epoch 200 Loss 1.230390
# Epoch 250 Loss 1.204799
# Epoch 300 Loss 1.188514
# Epoch 350 Loss 1.181612
# Epoch 400 Loss 1.176929
# Epoch 450 Loss 1.172968
# Early stopping at epoch 481
# Theta | train1 -> R² = 0.8473, MSE = 3.4853e-02
# X | train1 -> R² = -0.2157, MSE = 1.3108e-01
# Y | train1 -> R² = -1.0380, MSE = 1.7078e-01
# Theta | train2 -> R² = 0.6876, MSE = 7.1316e-02
# X | train2 -> R² = -0.1576, MSE = 9.7542e-02
# Y | train2 -> R² = -0.8392, MSE = 1.9805e-01
# Theta | test1 -> R² = 0.6562, MSE = 7.8966e-02
# X | test1 -> R² = -0.4042, MSE = 1.4710e-01
# Y | test1 -> R² = -1.4579, MSE = 2.0142e-01
# Theta | test2 -> R² = 0.4761, MSE = 1.2425e-01
# X | test2 -> R² = -0.2585, MSE = 1.0357e-01
# Y | test2 -> R² = -0.9544, MSE = 2.0745e-01
# Theta | test3 -> R² = -0.9889, MSE = 6.5384e-01
# X | test3 -> R² = -1.6301, MSE = 2.4198e-01
# Y | test3 -> R² = -4.6715, MSE = 4.3561e-01
# Theta | val -> R² = -0.8788, MSE = 6.1490e-01
# X | val -> R² = -1.9629, MSE = 2.8332e-01
# Y | val -> R² = -4.6406, MSE = 4.1995e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.552790
# Epoch 50 Loss 1.300335
# Epoch 100 Loss 1.279573
# Epoch 150 Loss 1.253712
# Epoch 200 Loss 1.234764
# Epoch 250 Loss 1.219742
# Epoch 300 Loss 1.187113
# Epoch 350 Loss 1.177408
# Epoch 400 Loss 1.177344
# Epoch 450 Loss 1.170033
# Early stopping at epoch 472
# Theta | train1 -> R² = 0.8223, MSE = 4.0558e-02
# X | train1 -> R² = -0.2147, MSE = 1.3097e-01
# Y | train1 -> R² = -1.0167, MSE = 1.6899e-01
# Theta | train2 -> R² = 0.7868, MSE = 4.8673e-02
# X | train2 -> R² = -0.1259, MSE = 9.4870e-02
# Y | train2 -> R² = -0.7258, MSE = 1.8583e-01
# Theta | test1 -> R² = 0.6357, MSE = 8.3694e-02
# X | test1 -> R² = -0.3428, MSE = 1.4068e-01
# Y | test1 -> R² = -1.4258, MSE = 1.9879e-01
# Theta | test2 -> R² = 0.6061, MSE = 9.3421e-02
# X | test2 -> R² = -0.2143, MSE = 9.9930e-02
# Y | test2 -> R² = -0.7942, MSE = 1.9044e-01
# Theta | test3 -> R² = -0.6104, MSE = 5.2941e-01
# X | test3 -> R² = -2.1559, MSE = 2.9036e-01
# Y | test3 -> R² = -3.6062, MSE = 3.5379e-01
# Theta | val -> R² = -1.8941, MSE = 9.4717e-01
# X | val -> R² = -1.9602, MSE = 2.8307e-01
# Y | val -> R² = -3.6942, MSE = 3.4948e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.554000
# Epoch 50 Loss 1.291274
# Epoch 100 Loss 1.268008
# Epoch 150 Loss 1.233298
# Epoch 200 Loss 1.195117
# Epoch 250 Loss 1.174231
# Epoch 300 Loss 1.166170
# Epoch 350 Loss 1.159824
# Epoch 400 Loss 1.154409
# Early stopping at epoch 418
# Theta | train1 -> R² = 0.4622, MSE = 1.2277e-01
# X | train1 -> R² = -0.2047, MSE = 1.2990e-01
# Y | train1 -> R² = -1.0399, MSE = 1.7094e-01
# Theta | train2 -> R² = 0.7782, MSE = 5.0627e-02
# X | train2 -> R² = -0.1460, MSE = 9.6561e-02
# Y | train2 -> R² = -0.8141, MSE = 1.9534e-01
# Theta | test1 -> R² = 0.0146, MSE = 2.2637e-01
# X | test1 -> R² = -0.3086, MSE = 1.3709e-01
# Y | test1 -> R² = -1.4378, MSE = 1.9977e-01
# Theta | test2 -> R² = 0.7407, MSE = 6.1492e-02
# X | test2 -> R² = -0.2502, MSE = 1.0288e-01
# Y | test2 -> R² = -0.8946, MSE = 2.0110e-01
# Theta | test3 -> R² = -1.7244, MSE = 8.9564e-01
# X | test3 -> R² = -2.2673, MSE = 3.0060e-01
# Y | test3 -> R² = -3.4537, MSE = 3.4207e-01
# Theta | val -> R² = -4.2811, MSE = 1.7284e+00
# X | val -> R² = -1.7475, MSE = 2.6272e-01
# Y | val -> R² = -3.6614, MSE = 3.4704e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.556375
# Epoch 50 Loss 1.278956
# Epoch 100 Loss 1.246340
# Epoch 150 Loss 1.226424
# Epoch 200 Loss 1.198478
# Epoch 250 Loss 1.183602
# Epoch 300 Loss 1.166826
# Epoch 350 Loss 1.156380
# Epoch 400 Loss 1.150523
# Early stopping at epoch 412
# Theta | train1 -> R² = 0.8132, MSE = 4.2637e-02
# X | train1 -> R² = -0.1876, MSE = 1.2805e-01
# Y | train1 -> R² = -1.0641, MSE = 1.7296e-01
# Theta | train2 -> R² = 0.7907, MSE = 4.7787e-02
# X | train2 -> R² = -0.1192, MSE = 9.4302e-02
# Y | train2 -> R² = -0.8086, MSE = 1.9475e-01
# Theta | test1 -> R² = 0.4859, MSE = 1.1809e-01
# X | test1 -> R² = -0.2977, MSE = 1.3595e-01
# Y | test1 -> R² = -1.4350, MSE = 1.9954e-01
# Theta | test2 -> R² = 0.7694, MSE = 5.4688e-02
# X | test2 -> R² = -0.2152, MSE = 1.0000e-01
# Y | test2 -> R² = -0.8629, MSE = 1.9773e-01
# Theta | test3 -> R² = -0.6213, MSE = 5.3300e-01
# X | test3 -> R² = -1.6546, MSE = 2.4423e-01
# Y | test3 -> R² = -3.7369, MSE = 3.6383e-01
# Theta | val -> R² = -3.9452, MSE = 1.6185e+00
# X | val -> R² = -1.2646, MSE = 2.1654e-01
# Y | val -> R² = -3.0822, MSE = 3.0392e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.597644
# Epoch 50 Loss 1.291534
# Epoch 100 Loss 1.260147
# Epoch 150 Loss 1.230400
# Epoch 200 Loss 1.195489
# Epoch 250 Loss 1.175563
# Epoch 300 Loss 1.165811
# Epoch 350 Loss 1.156891
# Epoch 400 Loss 1.150193
# Epoch 450 Loss 1.146207
# Early stopping at epoch 457
# Theta | train1 -> R² = 0.8609, MSE = 3.1744e-02
# X | train1 -> R² = -0.2070, MSE = 1.3015e-01
# Y | train1 -> R² = -1.0393, MSE = 1.7088e-01
# Theta | train2 -> R² = 0.5287, MSE = 1.0761e-01
# X | train2 -> R² = -0.1015, MSE = 9.2814e-02
# Y | train2 -> R² = -0.8131, MSE = 1.9523e-01
# Theta | test1 -> R² = 0.7368, MSE = 6.0473e-02
# X | test1 -> R² = -0.2586, MSE = 1.3185e-01
# Y | test1 -> R² = -1.4481, MSE = 2.0062e-01
# Theta | test2 -> R² = 0.3250, MSE = 1.6009e-01
# X | test2 -> R² = -0.1599, MSE = 9.5454e-02
# Y | test2 -> R² = -0.8335, MSE = 1.9461e-01
# Theta | test3 -> R² = -1.6719, MSE = 8.7838e-01
# X | test3 -> R² = -2.3662, MSE = 3.0970e-01
# Y | test3 -> R² = -3.4634, MSE = 3.4282e-01
# Theta | val -> R² = -2.4813, MSE = 1.1394e+00
# X | val -> R² = -1.3365, MSE = 2.2342e-01
# Y | val -> R² = -3.1854, MSE = 3.1161e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.584657
# Epoch 50 Loss 1.287499
# Epoch 100 Loss 1.248677
# Epoch 150 Loss 1.225593
# Epoch 200 Loss 1.188597
# Epoch 250 Loss 1.177637
# Epoch 300 Loss 1.166188
# Epoch 350 Loss 1.159711
# Epoch 400 Loss 1.154231
# Early stopping at epoch 423
# Theta | train1 -> R² = 0.8910, MSE = 2.4880e-02
# X | train1 -> R² = -0.2080, MSE = 1.3026e-01
# Y | train1 -> R² = -1.1055, MSE = 1.7643e-01
# Theta | train2 -> R² = 0.5017, MSE = 1.1377e-01
# X | train2 -> R² = -0.1629, MSE = 9.7985e-02
# Y | train2 -> R² = -0.8198, MSE = 1.9595e-01
# Theta | test1 -> R² = 0.6394, MSE = 8.2833e-02
# X | test1 -> R² = -0.3609, MSE = 1.4257e-01
# Y | test1 -> R² = -1.5069, MSE = 2.0544e-01
# Theta | test2 -> R² = 0.1717, MSE = 1.9644e-01
# X | test2 -> R² = -0.2867, MSE = 1.0588e-01
# Y | test2 -> R² = -0.8858, MSE = 2.0016e-01
# Theta | test3 -> R² = -2.0105, MSE = 9.8969e-01
# X | test3 -> R² = -2.0455, MSE = 2.8020e-01
# Y | test3 -> R² = -4.5313, MSE = 4.2484e-01
# Theta | val -> R² = -2.7081, MSE = 1.2136e+00
# X | val -> R² = -2.3751, MSE = 3.2274e-01
# Y | val -> R² = -4.1677, MSE = 3.8473e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568994
# Epoch 50 Loss 1.276602
# Epoch 100 Loss 1.245738
# Epoch 150 Loss 1.213101
# Epoch 200 Loss 1.191743
# Epoch 250 Loss 1.176641
# Epoch 300 Loss 1.164992
# Epoch 350 Loss 1.157864
# Epoch 400 Loss 1.153453
# Early stopping at epoch 406
# Theta | train1 -> R² = 0.9072, MSE = 2.1182e-02
# X | train1 -> R² = -0.1861, MSE = 1.2790e-01
# Y | train1 -> R² = -1.0937, MSE = 1.7544e-01
# Theta | train2 -> R² = 0.3742, MSE = 1.4287e-01
# X | train2 -> R² = -0.1765, MSE = 9.9132e-02
# Y | train2 -> R² = -0.7926, MSE = 1.9302e-01
# Theta | test1 -> R² = 0.6917, MSE = 7.0832e-02
# X | test1 -> R² = -0.3127, MSE = 1.3752e-01
# Y | test1 -> R² = -1.4726, MSE = 2.0262e-01
# Theta | test2 -> R² = 0.0084, MSE = 2.3517e-01
# X | test2 -> R² = -0.2752, MSE = 1.0494e-01
# Y | test2 -> R² = -0.8430, MSE = 1.9562e-01
# Theta | test3 -> R² = -0.3290, MSE = 4.3689e-01
# X | test3 -> R² = -1.9490, MSE = 2.7132e-01
# Y | test3 -> R² = -4.1756, MSE = 3.9752e-01
# Theta | val -> R² = -3.8107, MSE = 1.5745e+00
# X | val -> R² = -1.4582, MSE = 2.3506e-01
# Y | val -> R² = -3.4339, MSE = 3.3010e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.572108
# Epoch 50 Loss 1.285387
# Epoch 100 Loss 1.256977
# Epoch 150 Loss 1.234383
# Epoch 200 Loss 1.194874
# Epoch 250 Loss 1.173130
# Epoch 300 Loss 1.161637
# Epoch 350 Loss 1.153988
# Epoch 400 Loss 1.148291
# Early stopping at epoch 437
# Theta | train1 -> R² = 0.8800, MSE = 2.7386e-02
# X | train1 -> R² = -0.1769, MSE = 1.2690e-01
# Y | train1 -> R² = -1.0709, MSE = 1.7353e-01
# Theta | train2 -> R² = 0.5416, MSE = 1.0466e-01
# X | train2 -> R² = -0.0931, MSE = 9.2104e-02
# Y | train2 -> R² = -0.7655, MSE = 1.9011e-01
# Theta | test1 -> R² = 0.7437, MSE = 5.8886e-02
# X | test1 -> R² = -0.2789, MSE = 1.3398e-01
# Y | test1 -> R² = -1.3866, MSE = 1.9558e-01
# Theta | test2 -> R² = 0.2413, MSE = 1.7993e-01
# X | test2 -> R² = -0.1759, MSE = 9.6766e-02
# Y | test2 -> R² = -0.7897, MSE = 1.8996e-01
# Theta | test3 -> R² = -0.3586, MSE = 4.4664e-01
# X | test3 -> R² = -1.4373, MSE = 2.2425e-01
# Y | test3 -> R² = -3.9754, MSE = 3.8214e-01
# Theta | val -> R² = -3.6160, MSE = 1.5107e+00
# X | val -> R² = -1.0492, MSE = 1.9595e-01
# Y | val -> R² = -2.9552, MSE = 2.9446e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.565472
# Epoch 50 Loss 1.294696
# Epoch 100 Loss 1.270351
# Epoch 150 Loss 1.244937
# Epoch 200 Loss 1.228695
# Epoch 250 Loss 1.195157
# Epoch 300 Loss 1.180672
# Epoch 350 Loss 1.173012
# Epoch 400 Loss 1.167521
# Epoch 450 Loss 1.162889
# Early stopping at epoch 482
# Theta | train1 -> R² = 0.8625, MSE = 3.1384e-02
# X | train1 -> R² = -0.1859, MSE = 1.2787e-01
# Y | train1 -> R² = -1.0515, MSE = 1.7191e-01
# Theta | train2 -> R² = 0.5975, MSE = 9.1894e-02
# X | train2 -> R² = -0.1250, MSE = 9.4794e-02
# Y | train2 -> R² = -0.7638, MSE = 1.8992e-01
# Theta | test1 -> R² = 0.6628, MSE = 7.7454e-02
# X | test1 -> R² = -0.3072, MSE = 1.3694e-01
# Y | test1 -> R² = -1.3680, MSE = 1.9405e-01
# Theta | test2 -> R² = 0.3126, MSE = 1.6303e-01
# X | test2 -> R² = -0.1985, MSE = 9.8624e-02
# Y | test2 -> R² = -0.7886, MSE = 1.8985e-01
# Theta | test3 -> R² = -0.9160, MSE = 6.2989e-01
# X | test3 -> R² = -1.6262, MSE = 2.4162e-01
# Y | test3 -> R² = -3.7235, MSE = 3.6280e-01
# Theta | val -> R² = -1.9938, MSE = 9.7980e-01
# X | val -> R² = -1.3541, MSE = 2.2510e-01
# Y | val -> R² = -2.7909, MSE = 2.8223e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.575930
# Epoch 50 Loss 1.288756
# Epoch 100 Loss 1.254650
# Epoch 150 Loss 1.222345
# Epoch 200 Loss 1.189493
# Epoch 250 Loss 1.180273
# Epoch 300 Loss 1.172912
# Epoch 350 Loss 1.166296
# Epoch 400 Loss 1.158801
# Early stopping at epoch 415
# Theta | train1 -> R² = 0.8025, MSE = 4.5073e-02
# X | train1 -> R² = -0.2192, MSE = 1.3146e-01
# Y | train1 -> R² = -1.0554, MSE = 1.7223e-01
# Theta | train2 -> R² = 0.7235, MSE = 6.3129e-02
# X | train2 -> R² = -0.1515, MSE = 9.7030e-02
# Y | train2 -> R² = -0.8065, MSE = 1.9452e-01
# Theta | test1 -> R² = 0.6031, MSE = 9.1171e-02
# X | test1 -> R² = -0.3720, MSE = 1.4373e-01
# Y | test1 -> R² = -1.3916, MSE = 1.9599e-01
# Theta | test2 -> R² = 0.4285, MSE = 1.3554e-01
# X | test2 -> R² = -0.2396, MSE = 1.0201e-01
# Y | test2 -> R² = -0.8936, MSE = 2.0099e-01
# Theta | test3 -> R² = 0.0012, MSE = 3.2835e-01
# X | test3 -> R² = -1.8531, MSE = 2.6249e-01
# Y | test3 -> R² = -4.6587, MSE = 4.3463e-01
# Theta | val -> R² = -0.0989, MSE = 3.5966e-01
# X | val -> R² = -1.5915, MSE = 2.4781e-01
# Y | val -> R² = -3.8719, MSE = 3.6271e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.552305
# Epoch 50 Loss 1.284772
# Epoch 100 Loss 1.254432
# Epoch 150 Loss 1.245995
# Epoch 200 Loss 1.220881
# Epoch 250 Loss 1.192142
# Epoch 300 Loss 1.175215
# Epoch 350 Loss 1.165927
# Epoch 400 Loss 1.160695
# Epoch 450 Loss 1.157141
# Early stopping at epoch 460
# Theta | train1 -> R² = 0.7092, MSE = 6.6378e-02
# X | train1 -> R² = -0.1967, MSE = 1.2904e-01
# Y | train1 -> R² = -1.0727, MSE = 1.7369e-01
# Theta | train2 -> R² = 0.7984, MSE = 4.6017e-02
# X | train2 -> R² = -0.1297, MSE = 9.5191e-02
# Y | train2 -> R² = -0.7581, MSE = 1.8931e-01
# Theta | test1 -> R² = 0.5682, MSE = 9.9197e-02
# X | test1 -> R² = -0.3439, MSE = 1.4079e-01
# Y | test1 -> R² = -1.4403, MSE = 1.9998e-01
# Theta | test2 -> R² = 0.6383, MSE = 8.5772e-02
# X | test2 -> R² = -0.1926, MSE = 9.8140e-02
# Y | test2 -> R² = -0.7967, MSE = 1.9071e-01
# Theta | test3 -> R² = -2.8723, MSE = 1.2730e+00
# X | test3 -> R² = -1.5587, MSE = 2.3541e-01
# Y | test3 -> R² = -3.9198, MSE = 3.7788e-01
# Theta | val -> R² = -3.2382, MSE = 1.3871e+00
# X | val -> R² = -1.3308, MSE = 2.2287e-01
# Y | val -> R² = -3.4564, MSE = 3.3178e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.546261
# Epoch 50 Loss 1.280761
# Epoch 100 Loss 1.245593
# Epoch 150 Loss 1.201163
# Epoch 200 Loss 1.186690
# Epoch 250 Loss 1.175124
# Epoch 300 Loss 1.165959
# Epoch 350 Loss 1.159930
# Epoch 400 Loss 1.154917
# Early stopping at epoch 407
# Theta | train1 -> R² = 0.4888, MSE = 1.1669e-01
# X | train1 -> R² = -0.1924, MSE = 1.2857e-01
# Y | train1 -> R² = -1.0203, MSE = 1.6929e-01
# Theta | train2 -> R² = 0.8374, MSE = 3.7133e-02
# X | train2 -> R² = -0.1586, MSE = 9.7628e-02
# Y | train2 -> R² = -0.7818, MSE = 1.9186e-01
# Theta | test1 -> R² = 0.3643, MSE = 1.4604e-01
# X | test1 -> R² = -0.3539, MSE = 1.4184e-01
# Y | test1 -> R² = -1.3386, MSE = 1.9165e-01
# Theta | test2 -> R² = 0.7625, MSE = 5.6323e-02
# X | test2 -> R² = -0.2511, MSE = 1.0296e-01
# Y | test2 -> R² = -0.8452, MSE = 1.9585e-01
# Theta | test3 -> R² = -0.5636, MSE = 5.1403e-01
# X | test3 -> R² = -1.8215, MSE = 2.5959e-01
# Y | test3 -> R² = -4.5769, MSE = 4.2835e-01
# Theta | val -> R² = -0.3010, MSE = 4.2578e-01
# X | val -> R² = -1.5453, MSE = 2.4339e-01
# Y | val -> R² = -3.2415, MSE = 3.1578e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.569850
# Epoch 50 Loss 1.280297
# Epoch 100 Loss 1.248118
# Epoch 150 Loss 1.218482
# Epoch 200 Loss 1.184894
# Epoch 250 Loss 1.173293
# Epoch 300 Loss 1.164450
# Epoch 350 Loss 1.157933
# Epoch 400 Loss 1.152791
# Early stopping at epoch 428
# Theta | train1 -> R² = 0.6215, MSE = 8.6402e-02
# X | train1 -> R² = -0.1628, MSE = 1.2538e-01
# Y | train1 -> R² = -1.0369, MSE = 1.7068e-01
# Theta | train2 -> R² = 0.7994, MSE = 4.5788e-02
# X | train2 -> R² = -0.1258, MSE = 9.4860e-02
# Y | train2 -> R² = -0.8010, MSE = 1.9393e-01
# Theta | test1 -> R² = 0.5310, MSE = 1.0775e-01
# X | test1 -> R² = -0.2301, MSE = 1.2886e-01
# Y | test1 -> R² = -1.5147, MSE = 2.0608e-01
# Theta | test2 -> R² = 0.8236, MSE = 4.1833e-02
# X | test2 -> R² = -0.2053, MSE = 9.9186e-02
# Y | test2 -> R² = -0.8130, MSE = 1.9244e-01
# Theta | test3 -> R² = -1.2172, MSE = 7.2890e-01
# X | test3 -> R² = -2.0281, MSE = 2.7860e-01
# Y | test3 -> R² = -2.8217, MSE = 2.9354e-01
# Theta | val -> R² = -3.5093, MSE = 1.4758e+00
# X | val -> R² = -1.1855, MSE = 2.0898e-01
# Y | val -> R² = -2.6746, MSE = 2.7357e-01
# Figura salva em: ./results/model_32_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.557191
# Epoch 50 Loss 1.277926
# Epoch 100 Loss 1.246313
# Epoch 150 Loss 1.199043
# Epoch 200 Loss 1.180775
# Epoch 250 Loss 1.167665
# Epoch 300 Loss 1.157915
# Epoch 350 Loss 1.151113
# Epoch 400 Loss 1.148257
# Early stopping at epoch 415
# Theta | train1 -> R² = 0.8643, MSE = 3.0974e-02
# X | train1 -> R² = -0.2035, MSE = 1.2977e-01
# Y | train1 -> R² = -1.0734, MSE = 1.7374e-01
# Theta | train2 -> R² = 0.6742, MSE = 7.4386e-02
# X | train2 -> R² = -0.1525, MSE = 9.7107e-02
# Y | train2 -> R² = -0.8099, MSE = 1.9489e-01
# Theta | test1 -> R² = 0.5964, MSE = 9.2724e-02
# X | test1 -> R² = -0.3436, MSE = 1.4076e-01
# Y | test1 -> R² = -1.4664, MSE = 2.0212e-01
# Theta | test2 -> R² = 0.5359, MSE = 1.1006e-01
# X | test2 -> R² = -0.2281, MSE = 1.0107e-01
# Y | test2 -> R² = -0.8716, MSE = 1.9866e-01
# Theta | test3 -> R² = -0.2092, MSE = 3.9753e-01
# X | test3 -> R² = -2.5849, MSE = 3.2982e-01
# Y | test3 -> R² = -3.6577, MSE = 3.5775e-01
# Theta | val -> R² = -1.7144, MSE = 8.8835e-01
# X | val -> R² = -1.7790, MSE = 2.6574e-01
# Y | val -> R² = -3.0747, MSE = 3.0336e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.556740
# Epoch 50 Loss 1.274944
# Epoch 100 Loss 1.247159
# Epoch 150 Loss 1.216578
# Epoch 200 Loss 1.179122
# Epoch 250 Loss 1.166340
# Epoch 300 Loss 1.157224
# Epoch 350 Loss 1.152924
# Epoch 400 Loss 1.145825
# Early stopping at epoch 428
# Theta | train1 -> R² = 0.6554, MSE = 7.8660e-02
# X | train1 -> R² = -0.1998, MSE = 1.2937e-01
# Y | train1 -> R² = -1.0580, MSE = 1.7245e-01
# Theta | train2 -> R² = 0.7995, MSE = 4.5775e-02
# X | train2 -> R² = -0.1270, MSE = 9.4957e-02
# Y | train2 -> R² = -0.7881, MSE = 1.9254e-01
# Theta | test1 -> R² = 0.4433, MSE = 1.2789e-01
# X | test1 -> R² = -0.3102, MSE = 1.3726e-01
# Y | test1 -> R² = -1.4894, MSE = 2.0400e-01
# Theta | test2 -> R² = 0.5892, MSE = 9.7425e-02
# X | test2 -> R² = -0.2049, MSE = 9.9153e-02
# Y | test2 -> R² = -0.8083, MSE = 1.9194e-01
# Theta | test3 -> R² = -4.1941, MSE = 1.7075e+00
# X | test3 -> R² = -1.8940, MSE = 2.6626e-01
# Y | test3 -> R² = -3.1986, MSE = 3.2248e-01
# Theta | val -> R² = -6.4899, MSE = 2.4513e+00
# X | val -> R² = -1.3792, MSE = 2.2751e-01
# Y | val -> R² = -2.7044, MSE = 2.7579e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.553613
# Epoch 50 Loss 1.282670
# Epoch 100 Loss 1.253607
# Epoch 150 Loss 1.232903
# Epoch 200 Loss 1.191901
# Epoch 250 Loss 1.181848
# Epoch 300 Loss 1.173318
# Epoch 350 Loss 1.164827
# Epoch 400 Loss 1.157746
# Early stopping at epoch 447
# Theta | train1 -> R² = 0.7209, MSE = 6.3711e-02
# X | train1 -> R² = -0.1889, MSE = 1.2820e-01
# Y | train1 -> R² = -1.0457, MSE = 1.7142e-01
# Theta | train2 -> R² = 0.7352, MSE = 6.0460e-02
# X | train2 -> R² = -0.1387, MSE = 9.5951e-02
# Y | train2 -> R² = -0.7690, MSE = 1.9049e-01
# Theta | test1 -> R² = 0.5420, MSE = 1.0521e-01
# X | test1 -> R² = -0.2939, MSE = 1.3555e-01
# Y | test1 -> R² = -1.4722, MSE = 2.0259e-01
# Theta | test2 -> R² = 0.5485, MSE = 1.0709e-01
# X | test2 -> R² = -0.2284, MSE = 1.0109e-01
# Y | test2 -> R² = -0.7783, MSE = 1.8875e-01
# Theta | test3 -> R² = -1.0588, MSE = 6.7682e-01
# X | test3 -> R² = -2.2455, MSE = 2.9860e-01
# Y | test3 -> R² = -3.2315, MSE = 3.2501e-01
# Theta | val -> R² = -3.0605, MSE = 1.3289e+00
# X | val -> R² = -1.8088, MSE = 2.6859e-01
# Y | val -> R² = -2.5205, MSE = 2.6210e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.566891
# Epoch 50 Loss 1.277963
# Epoch 100 Loss 1.245024
# Epoch 150 Loss 1.213666
# Epoch 200 Loss 1.182563
# Epoch 250 Loss 1.172362
# Epoch 300 Loss 1.160191
# Epoch 350 Loss 1.159034
# Epoch 400 Loss 1.148836
# Early stopping at epoch 417
# Theta | train1 -> R² = 0.2299, MSE = 1.7580e-01
# X | train1 -> R² = -0.2268, MSE = 1.3228e-01
# Y | train1 -> R² = -1.1748, MSE = 1.8224e-01
# Theta | train2 -> R² = -1.1193, MSE = 4.8385e-01
# X | train2 -> R² = -0.1632, MSE = 9.8009e-02
# Y | train2 -> R² = -0.8642, MSE = 2.0074e-01
# Theta | test1 -> R² = 0.3706, MSE = 1.4459e-01
# X | test1 -> R² = -0.3126, MSE = 1.3751e-01
# Y | test1 -> R² = -1.5812, MSE = 2.1153e-01
# Theta | test2 -> R² = -1.7081, MSE = 6.4225e-01
# X | test2 -> R² = -0.2180, MSE = 1.0023e-01
# Y | test2 -> R² = -0.9375, MSE = 2.0565e-01
# Theta | test3 -> R² = 0.2896, MSE = 2.3353e-01
# X | test3 -> R² = -2.5132, MSE = 3.2323e-01
# Y | test3 -> R² = -4.6902, MSE = 4.3705e-01
# Theta | val -> R² = -0.3656, MSE = 4.4692e-01
# X | val -> R² = -1.7406, MSE = 2.6207e-01
# Y | val -> R² = -4.3364, MSE = 3.9730e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.572770
# Epoch 50 Loss 1.276971
# Epoch 100 Loss 1.242457
# Epoch 150 Loss 1.198774
# Epoch 200 Loss 1.179653
# Epoch 250 Loss 1.170659
# Epoch 300 Loss 1.166372
# Epoch 350 Loss 1.157225
# Epoch 400 Loss 1.150590
# Early stopping at epoch 410
# Theta | train1 -> R² = 0.8963, MSE = 2.3668e-02
# X | train1 -> R² = -0.2055, MSE = 1.2998e-01
# Y | train1 -> R² = -1.0308, MSE = 1.7017e-01
# Theta | train2 -> R² = 0.3231, MSE = 1.5454e-01
# X | train2 -> R² = -0.1488, MSE = 9.6798e-02
# Y | train2 -> R² = -0.7977, MSE = 1.9357e-01
# Theta | test1 -> R² = 0.7146, MSE = 6.5556e-02
# X | test1 -> R² = -0.2849, MSE = 1.3461e-01
# Y | test1 -> R² = -1.4452, MSE = 2.0038e-01
# Theta | test2 -> R² = -0.1332, MSE = 2.6876e-01
# X | test2 -> R² = -0.2333, MSE = 1.0149e-01
# Y | test2 -> R² = -0.8437, MSE = 1.9569e-01
# Theta | test3 -> R² = -0.4159, MSE = 4.6547e-01
# X | test3 -> R² = -2.4964, MSE = 3.2168e-01
# Y | test3 -> R² = -3.6369, MSE = 3.5615e-01
# Theta | val -> R² = -2.0747, MSE = 1.0063e+00
# X | val -> R² = -1.7260, MSE = 2.6067e-01
# Y | val -> R² = -3.3508, MSE = 3.2392e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.601979
# Epoch 50 Loss 1.274361
# Epoch 100 Loss 1.247346
# Epoch 150 Loss 1.218638
# Epoch 200 Loss 1.188886
# Epoch 250 Loss 1.175051
# Epoch 300 Loss 1.158675
# Epoch 350 Loss 1.148520
# Epoch 400 Loss 1.142635
# Early stopping at epoch 423
# Theta | train1 -> R² = 0.8860, MSE = 2.6023e-02
# X | train1 -> R² = -0.1961, MSE = 1.2897e-01
# Y | train1 -> R² = -1.0888, MSE = 1.7503e-01
# Theta | train2 -> R² = 0.4732, MSE = 1.2026e-01
# X | train2 -> R² = -0.1294, MSE = 9.5166e-02
# Y | train2 -> R² = -0.8058, MSE = 1.9444e-01
# Theta | test1 -> R² = 0.7185, MSE = 6.4665e-02
# X | test1 -> R² = -0.2415, MSE = 1.3006e-01
# Y | test1 -> R² = -1.4597, MSE = 2.0157e-01
# Theta | test2 -> R² = 0.1861, MSE = 1.9302e-01
# X | test2 -> R² = -0.2056, MSE = 9.9214e-02
# Y | test2 -> R² = -0.7968, MSE = 1.9071e-01
# Theta | test3 -> R² = -0.2021, MSE = 3.9518e-01
# X | test3 -> R² = -2.7912, MSE = 3.4881e-01
# Y | test3 -> R² = -3.7177, MSE = 3.6235e-01
# Theta | val -> R² = -1.3980, MSE = 7.8483e-01
# X | val -> R² = -1.8007, MSE = 2.6781e-01
# Y | val -> R² = -2.9333, MSE = 2.9283e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.605842
# Epoch 50 Loss 1.285409
# Epoch 100 Loss 1.251533
# Epoch 150 Loss 1.213304
# Epoch 200 Loss 1.187084
# Epoch 250 Loss 1.185603
# Epoch 300 Loss 1.165115
# Epoch 350 Loss 1.156895
# Epoch 400 Loss 1.149264
# Early stopping at epoch 425
# Theta | train1 -> R² = 0.8033, MSE = 4.4910e-02
# X | train1 -> R² = -0.1866, MSE = 1.2794e-01
# Y | train1 -> R² = -1.0650, MSE = 1.7304e-01
# Theta | train2 -> R² = 0.7465, MSE = 5.7879e-02
# X | train2 -> R² = -0.1142, MSE = 9.3879e-02
# Y | train2 -> R² = -0.8269, MSE = 1.9672e-01
# Theta | test1 -> R² = 0.5956, MSE = 9.2901e-02
# X | test1 -> R² = -0.2949, MSE = 1.3566e-01
# Y | test1 -> R² = -1.4701, MSE = 2.0242e-01
# Theta | test2 -> R² = 0.5093, MSE = 1.1637e-01
# X | test2 -> R² = -0.1775, MSE = 9.6903e-02
# Y | test2 -> R² = -0.8724, MSE = 1.9874e-01
# Theta | test3 -> R² = -2.0000, MSE = 9.8624e-01
# X | test3 -> R² = -1.7425, MSE = 2.5232e-01
# Y | test3 -> R² = -4.0581, MSE = 3.8849e-01
# Theta | val -> R² = -6.0483, MSE = 2.3068e+00
# X | val -> R² = -1.0661, MSE = 1.9756e-01
# Y | val -> R² = -3.6877, MSE = 3.4900e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.593385
# Epoch 50 Loss 1.269095
# Epoch 100 Loss 1.246459
# Epoch 150 Loss 1.198693
# Epoch 200 Loss 1.178795
# Epoch 250 Loss 1.167141
# Epoch 300 Loss 1.158099
# Epoch 350 Loss 1.149494
# Epoch 400 Loss 1.144905
# Early stopping at epoch 414
# Theta | train1 -> R² = 0.7039, MSE = 6.7580e-02
# X | train1 -> R² = -0.2170, MSE = 1.3122e-01
# Y | train1 -> R² = -1.0293, MSE = 1.7004e-01
# Theta | train2 -> R² = 0.4547, MSE = 1.2450e-01
# X | train2 -> R² = -0.1492, MSE = 9.6834e-02
# Y | train2 -> R² = -0.7809, MSE = 1.9177e-01
# Theta | test1 -> R² = 0.4885, MSE = 1.1751e-01
# X | test1 -> R² = -0.2824, MSE = 1.3434e-01
# Y | test1 -> R² = -1.4462, MSE = 2.0047e-01
# Theta | test2 -> R² = 0.1444, MSE = 2.0291e-01
# X | test2 -> R² = -0.2418, MSE = 1.0219e-01
# Y | test2 -> R² = -0.8019, MSE = 1.9126e-01
# Theta | test3 -> R² = -1.4577, MSE = 8.0797e-01
# X | test3 -> R² = -2.5311, MSE = 3.2488e-01
# Y | test3 -> R² = -3.9117, MSE = 3.7726e-01
# Theta | val -> R² = -1.5633, MSE = 8.3892e-01
# X | val -> R² = -1.6657, MSE = 2.5490e-01
# Y | val -> R² = -3.2016, MSE = 3.1281e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.581957
# Epoch 50 Loss 1.268230
# Epoch 100 Loss 1.250320
# Epoch 150 Loss 1.216269
# Epoch 200 Loss 1.185930
# Epoch 250 Loss 1.173288
# Epoch 300 Loss 1.165086
# Epoch 350 Loss 1.157895
# Epoch 400 Loss 1.151474
# Early stopping at epoch 429
# Theta | train1 -> R² = 0.7491, MSE = 5.7263e-02
# X | train1 -> R² = -0.1578, MSE = 1.2484e-01
# Y | train1 -> R² = -0.9781, MSE = 1.6576e-01
# Theta | train2 -> R² = -0.0126, MSE = 2.3117e-01
# X | train2 -> R² = -0.1336, MSE = 9.5521e-02
# Y | train2 -> R² = -0.7108, MSE = 1.8421e-01
# Theta | test1 -> R² = 0.7049, MSE = 6.7800e-02
# X | test1 -> R² = -0.2842, MSE = 1.3453e-01
# Y | test1 -> R² = -1.3338, MSE = 1.9125e-01
# Theta | test2 -> R² = -0.6758, MSE = 3.9744e-01
# X | test2 -> R² = -0.2382, MSE = 1.0189e-01
# Y | test2 -> R² = -0.8038, MSE = 1.9146e-01
# Theta | test3 -> R² = -1.4895, MSE = 8.1843e-01
# X | test3 -> R² = -2.2781, MSE = 3.0160e-01
# Y | test3 -> R² = -4.5790, MSE = 4.2850e-01
# Theta | val -> R² = -1.8665, MSE = 9.3814e-01
# X | val -> R² = -2.2860, MSE = 3.1421e-01
# Y | val -> R² = -4.1360, MSE = 3.8237e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.564652
# Epoch 50 Loss 1.263647
# Epoch 100 Loss 1.248443
# Epoch 150 Loss 1.230418
# Epoch 200 Loss 1.191231
# Epoch 250 Loss 1.182451
# Epoch 300 Loss 1.171498
# Epoch 350 Loss 1.163366
# Epoch 400 Loss 1.158444
# Epoch 450 Loss 1.150723
# Early stopping at epoch 455
# Theta | train1 -> R² = 0.6550, MSE = 7.8760e-02
# X | train1 -> R² = -0.0786, MSE = 1.1630e-01
# Y | train1 -> R² = -1.0301, MSE = 1.7011e-01
# Theta | train2 -> R² = 0.7291, MSE = 6.1847e-02
# X | train2 -> R² = -0.1321, MSE = 9.5393e-02
# Y | train2 -> R² = -0.8124, MSE = 1.9516e-01
# Theta | test1 -> R² = 0.6436, MSE = 8.1866e-02
# X | test1 -> R² = -0.1829, MSE = 1.2392e-01
# Y | test1 -> R² = -1.5003, MSE = 2.0490e-01
# Theta | test2 -> R² = 0.5236, MSE = 1.1299e-01
# X | test2 -> R² = -0.2081, MSE = 9.9416e-02
# Y | test2 -> R² = -0.8007, MSE = 1.9113e-01
# Theta | test3 -> R² = -1.5097, MSE = 8.2507e-01
# X | test3 -> R² = -2.0404, MSE = 2.7973e-01
# Y | test3 -> R² = -2.9294, MSE = 3.0180e-01
# Theta | val -> R² = -4.2724, MSE = 1.7256e+00
# X | val -> R² = -1.4292, MSE = 2.3229e-01
# Y | val -> R² = -2.8732, MSE = 2.8836e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.583462
# Epoch 50 Loss 1.275683
# Epoch 100 Loss 1.250004
# Epoch 150 Loss 1.233211
# Epoch 200 Loss 1.188926
# Epoch 250 Loss 1.184261
# Epoch 300 Loss 1.172138
# Epoch 350 Loss 1.163959
# Epoch 400 Loss 1.154740
# Early stopping at epoch 433
# Theta | train1 -> R² = 0.7733, MSE = 5.1738e-02
# X | train1 -> R² = -0.1869, MSE = 1.2798e-01
# Y | train1 -> R² = -1.0861, MSE = 1.7480e-01
# Theta | train2 -> R² = 0.7938, MSE = 4.7075e-02
# X | train2 -> R² = -0.1340, MSE = 9.5547e-02
# Y | train2 -> R² = -0.8430, MSE = 1.9845e-01
# Theta | test1 -> R² = 0.5519, MSE = 1.0294e-01
# X | test1 -> R² = -0.2725, MSE = 1.3330e-01
# Y | test1 -> R² = -1.5320, MSE = 2.0750e-01
# Theta | test2 -> R² = 0.6970, MSE = 7.1855e-02
# X | test2 -> R² = -0.2065, MSE = 9.9288e-02
# Y | test2 -> R² = -0.8678, MSE = 1.9826e-01
# Theta | test3 -> R² = -1.2520, MSE = 7.4032e-01
# X | test3 -> R² = -2.3349, MSE = 3.0682e-01
# Y | test3 -> R² = -3.2959, MSE = 3.2996e-01
# Theta | val -> R² = -5.1977, MSE = 2.0284e+00
# X | val -> R² = -1.5532, MSE = 2.4414e-01
# Y | val -> R² = -3.0567, MSE = 3.0202e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.585115
# Epoch 50 Loss 1.271239
# Epoch 100 Loss 1.251184
# Epoch 150 Loss 1.234136
# Epoch 200 Loss 1.190289
# Epoch 250 Loss 1.175088
# Epoch 300 Loss 1.162003
# Epoch 350 Loss 1.153823
# Epoch 400 Loss 1.147561
# Epoch 450 Loss 1.144095
# Early stopping at epoch 452
# Theta | train1 -> R² = 0.9004, MSE = 2.2742e-02
# X | train1 -> R² = -0.2137, MSE = 1.3087e-01
# Y | train1 -> R² = -1.0179, MSE = 1.6909e-01
# Theta | train2 -> R² = 0.1128, MSE = 2.0255e-01
# X | train2 -> R² = -0.1046, MSE = 9.3071e-02
# Y | train2 -> R² = -0.7850, MSE = 1.9220e-01
# Theta | test1 -> R² = 0.7188, MSE = 6.4590e-02
# X | test1 -> R² = -0.3428, MSE = 1.4067e-01
# Y | test1 -> R² = -1.4813, MSE = 2.0334e-01
# Theta | test2 -> R² = -0.4370, MSE = 3.4080e-01
# X | test2 -> R² = -0.1590, MSE = 9.5380e-02
# Y | test2 -> R² = -0.7682, MSE = 1.8768e-01
# Theta | test3 -> R² = -0.5727, MSE = 5.1703e-01
# X | test3 -> R² = -2.1987, MSE = 2.9430e-01
# Y | test3 -> R² = -2.6364, MSE = 2.7930e-01
# Theta | val -> R² = -2.4170, MSE = 1.1183e+00
# X | val -> R² = -1.5563, MSE = 2.4444e-01
# Y | val -> R² = -2.4225, MSE = 2.5481e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.567365
# Epoch 50 Loss 1.269357
# Epoch 100 Loss 1.247114
# Epoch 150 Loss 1.244641
# Epoch 200 Loss 1.194910
# Epoch 250 Loss 1.176841
# Epoch 300 Loss 1.168105
# Epoch 350 Loss 1.161812
# Epoch 400 Loss 1.172645
# Epoch 450 Loss 1.144626
# Early stopping at epoch 452
# Theta | train1 -> R² = 0.8036, MSE = 4.4833e-02
# X | train1 -> R² = -0.2238, MSE = 1.3196e-01
# Y | train1 -> R² = -1.0546, MSE = 1.7217e-01
# Theta | train2 -> R² = -0.0721, MSE = 2.4475e-01
# X | train2 -> R² = -0.1497, MSE = 9.6875e-02
# Y | train2 -> R² = -0.8995, MSE = 2.0454e-01
# Theta | test1 -> R² = 0.5303, MSE = 1.0790e-01
# X | test1 -> R² = -0.3409, MSE = 1.4047e-01
# Y | test1 -> R² = -1.5488, MSE = 2.0887e-01
# Theta | test2 -> R² = -0.3117, MSE = 3.1109e-01
# X | test2 -> R² = -0.2217, MSE = 1.0054e-01
# Y | test2 -> R² = -0.8526, MSE = 1.9664e-01
# Theta | test3 -> R² = 0.7280, MSE = 8.9430e-02
# X | test3 -> R² = -1.9690, MSE = 2.7316e-01
# Y | test3 -> R² = -3.0270, MSE = 3.0931e-01
# Theta | val -> R² = -2.2574, MSE = 1.0661e+00
# X | val -> R² = -1.5230, MSE = 2.4126e-01
# Y | val -> R² = -3.2303, MSE = 3.1494e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.610902
# Epoch 50 Loss 1.275806
# Epoch 100 Loss 1.251455
# Epoch 150 Loss 1.240838
# Epoch 200 Loss 1.200564
# Epoch 250 Loss 1.177763
# Epoch 300 Loss 1.180987
# Epoch 350 Loss 1.160423
# Epoch 400 Loss 1.156767
# Epoch 450 Loss 1.149157
# Early stopping at epoch 470
# Theta | train1 -> R² = 0.6189, MSE = 8.6984e-02
# X | train1 -> R² = -0.2171, MSE = 1.3124e-01
# Y | train1 -> R² = -1.0478, MSE = 1.7160e-01
# Theta | train2 -> R² = -0.0966, MSE = 2.5036e-01
# X | train2 -> R² = -0.1025, MSE = 9.2899e-02
# Y | train2 -> R² = -0.8265, MSE = 1.9667e-01
# Theta | test1 -> R² = 0.5760, MSE = 9.7400e-02
# X | test1 -> R² = -0.3194, MSE = 1.3822e-01
# Y | test1 -> R² = -1.4811, MSE = 2.0332e-01
# Theta | test2 -> R² = -0.5899, MSE = 3.7706e-01
# X | test2 -> R² = -0.1672, MSE = 9.6054e-02
# Y | test2 -> R² = -0.8462, MSE = 1.9596e-01
# Theta | test3 -> R² = 0.3280, MSE = 2.2091e-01
# X | test3 -> R² = -1.9150, MSE = 2.6819e-01
# Y | test3 -> R² = -2.8317, MSE = 2.9430e-01
# Theta | val -> R² = 0.0729, MSE = 3.0342e-01
# X | val -> R² = -1.1574, MSE = 2.0630e-01
# Y | val -> R² = -2.2266, MSE = 2.4022e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.618708
# Epoch 50 Loss 1.274485
# Epoch 100 Loss 1.254394
# Epoch 150 Loss 1.237698
# Epoch 200 Loss 1.199468
# Epoch 250 Loss 1.179542
# Epoch 300 Loss 1.170577
# Epoch 350 Loss 1.166828
# Epoch 400 Loss 1.165452
# Epoch 450 Loss 1.150320
# Early stopping at epoch 455
# Theta | train1 -> R² = 0.9309, MSE = 1.5771e-02
# X | train1 -> R² = -0.1878, MSE = 1.2807e-01
# Y | train1 -> R² = -1.0738, MSE = 1.7377e-01
# Theta | train2 -> R² = 0.4929, MSE = 1.1577e-01
# X | train2 -> R² = -0.1437, MSE = 9.6369e-02
# Y | train2 -> R² = -0.8147, MSE = 1.9540e-01
# Theta | test1 -> R² = 0.6593, MSE = 7.8258e-02
# X | test1 -> R² = -0.2562, MSE = 1.3160e-01
# Y | test1 -> R² = -1.4870, MSE = 2.0381e-01
# Theta | test2 -> R² = 0.2894, MSE = 1.6852e-01
# X | test2 -> R² = -0.2191, MSE = 1.0032e-01
# Y | test2 -> R² = -0.8246, MSE = 1.9366e-01
# Theta | test3 -> R² = -0.1470, MSE = 3.7707e-01
# X | test3 -> R² = -1.9239, MSE = 2.6901e-01
# Y | test3 -> R² = -2.9047, MSE = 2.9991e-01
# Theta | val -> R² = -5.8763, MSE = 2.2505e+00
# X | val -> R² = -1.2935, MSE = 2.1931e-01
# Y | val -> R² = -2.5202, MSE = 2.6208e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.566857
# Epoch 50 Loss 1.269961
# Epoch 100 Loss 1.250931
# Epoch 150 Loss 1.237672
# Epoch 200 Loss 1.195603
# Epoch 250 Loss 1.177519
# Epoch 300 Loss 1.168008
# Epoch 350 Loss 1.158989
# Epoch 400 Loss 1.153110
# Epoch 450 Loss 1.149580
# Early stopping at epoch 465
# Theta | train1 -> R² = 0.9437, MSE = 1.2852e-02
# X | train1 -> R² = -0.1832, MSE = 1.2758e-01
# Y | train1 -> R² = -1.0582, MSE = 1.7247e-01
# Theta | train2 -> R² = 0.4151, MSE = 1.3354e-01
# X | train2 -> R² = -0.1640, MSE = 9.8077e-02
# Y | train2 -> R² = -0.8820, MSE = 2.0265e-01
# Theta | test1 -> R² = 0.8112, MSE = 4.3382e-02
# X | test1 -> R² = -0.2801, MSE = 1.3410e-01
# Y | test1 -> R² = -1.4966, MSE = 2.0459e-01
# Theta | test2 -> R² = 0.3117, MSE = 1.6325e-01
# X | test2 -> R² = -0.2343, MSE = 1.0157e-01
# Y | test2 -> R² = -0.8566, MSE = 1.9706e-01
# Theta | test3 -> R² = 0.7846, MSE = 7.0817e-02
# X | test3 -> R² = -2.2146, MSE = 2.9576e-01
# Y | test3 -> R² = -2.6885, MSE = 2.8330e-01
# Theta | val -> R² = -0.0990, MSE = 3.5970e-01
# X | val -> R² = -1.9774, MSE = 2.8471e-01
# Y | val -> R² = -2.6744, MSE = 2.7356e-01
# Figura salva em: ./results/model_64_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.549273
# Epoch 50 Loss 1.271786
# Epoch 100 Loss 1.251812
# Epoch 150 Loss 1.243261
# Epoch 200 Loss 1.216462
# Epoch 250 Loss 1.184338
# Epoch 300 Loss 1.176543
# Epoch 350 Loss 1.168493
# Epoch 400 Loss 1.163248
# Epoch 450 Loss 1.159941
# Early stopping at epoch 470
# Theta | train1 -> R² = 0.6429, MSE = 8.1506e-02
# X | train1 -> R² = -0.2447, MSE = 1.3421e-01
# Y | train1 -> R² = -1.1958, MSE = 1.8400e-01
# Theta | train2 -> R² = -0.3717, MSE = 3.1316e-01
# X | train2 -> R² = -0.1515, MSE = 9.7024e-02
# Y | train2 -> R² = -0.9088, MSE = 2.0553e-01
# Theta | test1 -> R² = 0.3776, MSE = 1.4298e-01
# X | test1 -> R² = -0.3576, MSE = 1.4223e-01
# Y | test1 -> R² = -1.6789, MSE = 2.1953e-01
# Theta | test2 -> R² = -0.6798, MSE = 3.9838e-01
# X | test2 -> R² = -0.2148, MSE = 9.9968e-02
# Y | test2 -> R² = -0.9099, MSE = 2.0272e-01
# Theta | test3 -> R² = 0.6000, MSE = 1.3150e-01
# X | test3 -> R² = -2.0751, MSE = 2.8292e-01
# Y | test3 -> R² = -3.4168, MSE = 3.3924e-01
# Theta | val -> R² = -0.0709, MSE = 3.5050e-01
# X | val -> R² = -1.3904, MSE = 2.2858e-01
# Y | val -> R² = -2.9359, MSE = 2.9302e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.592476
# Epoch 50 Loss 1.262866
# Epoch 100 Loss 1.243793
# Epoch 150 Loss 1.213198
# Epoch 200 Loss 1.186774
# Epoch 250 Loss 1.179518
# Epoch 300 Loss 1.193013
# Epoch 350 Loss 1.167108
# Epoch 400 Loss 1.168342
# Early stopping at epoch 424
# Theta | train1 -> R² = 0.6110, MSE = 8.8793e-02
# X | train1 -> R² = -0.1695, MSE = 1.2610e-01
# Y | train1 -> R² = -1.0440, MSE = 1.7128e-01
# Theta | train2 -> R² = -0.4413, MSE = 3.2905e-01
# X | train2 -> R² = -0.1058, MSE = 9.3174e-02
# Y | train2 -> R² = -0.7849, MSE = 1.9220e-01
# Theta | test1 -> R² = 0.4828, MSE = 1.1881e-01
# X | test1 -> R² = -0.2996, MSE = 1.3615e-01
# Y | test1 -> R² = -1.5147, MSE = 2.0608e-01
# Theta | test2 -> R² = -1.2092, MSE = 5.2394e-01
# X | test2 -> R² = -0.1593, MSE = 9.5399e-02
# Y | test2 -> R² = -0.7872, MSE = 1.8970e-01
# Theta | test3 -> R² = 0.5669, MSE = 1.4238e-01
# X | test3 -> R² = -2.0007, MSE = 2.7608e-01
# Y | test3 -> R² = -2.9887, MSE = 3.0636e-01
# Theta | val -> R² = -2.0292, MSE = 9.9139e-01
# X | val -> R² = -1.6625, MSE = 2.5459e-01
# Y | val -> R² = -2.7188, MSE = 2.7687e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.634912
# Epoch 50 Loss 1.267198
# Epoch 100 Loss 1.251636
# Epoch 150 Loss 1.239880
# Epoch 200 Loss 1.209693
# Epoch 250 Loss 1.185971
# Epoch 300 Loss 1.174248
# Epoch 350 Loss 1.171300
# Epoch 400 Loss 1.154680
# Epoch 450 Loss 1.147911
# Early stopping at epoch 453
# Theta | train1 -> R² = 0.4541, MSE = 1.2462e-01
# X | train1 -> R² = -0.2171, MSE = 1.3124e-01
# Y | train1 -> R² = -1.0421, MSE = 1.7112e-01
# Theta | train2 -> R² = 0.1128, MSE = 2.0255e-01
# X | train2 -> R² = -0.1123, MSE = 9.3725e-02
# Y | train2 -> R² = -0.8421, MSE = 1.9835e-01
# Theta | test1 -> R² = 0.7130, MSE = 6.5925e-02
# X | test1 -> R² = -0.3234, MSE = 1.3864e-01
# Y | test1 -> R² = -1.5160, MSE = 2.0619e-01
# Theta | test2 -> R² = -0.4144, MSE = 3.3543e-01
# X | test2 -> R² = -0.1684, MSE = 9.6148e-02
# Y | test2 -> R² = -0.8617, MSE = 1.9761e-01
# Theta | test3 -> R² = -3.6862, MSE = 1.5406e+00
# X | test3 -> R² = -2.0283, MSE = 2.7861e-01
# Y | test3 -> R² = -2.8236, MSE = 2.9368e-01
# Theta | val -> R² = -4.7148, MSE = 1.8703e+00
# X | val -> R² = -1.4444, MSE = 2.3374e-01
# Y | val -> R² = -2.8738, MSE = 2.8841e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.603791
# Epoch 50 Loss 1.268120
# Epoch 100 Loss 1.256099
# Epoch 150 Loss 1.254182
# Epoch 200 Loss 1.251478
# Epoch 250 Loss 1.262884
# Epoch 300 Loss 1.254830
# Epoch 350 Loss 1.185046
# Epoch 400 Loss 1.200523
# Epoch 450 Loss 1.168459
# Epoch 500 Loss 1.168223
# Early stopping at epoch 516
# Theta | train1 -> R² = 0.7434, MSE = 5.8577e-02
# X | train1 -> R² = -0.0082, MSE = 1.0871e-01
# Y | train1 -> R² = -0.6144, MSE = 1.3528e-01
# Theta | train2 -> R² = 0.7885, MSE = 4.8283e-02
# X | train2 -> R² = 0.0282, MSE = 8.1886e-02
# Y | train2 -> R² = -0.5285, MSE = 1.6459e-01
# Theta | test1 -> R² = 0.6454, MSE = 8.1461e-02
# X | test1 -> R² = -0.0660, MSE = 1.1168e-01
# Y | test1 -> R² = -1.0074, MSE = 1.6451e-01
# Theta | test2 -> R² = 0.8125, MSE = 4.4457e-02
# X | test2 -> R² = -0.0365, MSE = 8.5293e-02
# Y | test2 -> R² = -0.5153, MSE = 1.6084e-01
# Theta | test3 -> R² = -2.1810, MSE = 1.0457e+00
# X | test3 -> R² = -1.4166, MSE = 2.2234e-01
# Y | test3 -> R² = -1.6130, MSE = 2.0070e-01
# Theta | val -> R² = -8.4090, MSE = 3.0794e+00
# X | val -> R² = -1.3180, MSE = 2.2165e-01
# Y | val -> R² = -1.6209, MSE = 1.9512e-01
# Figura salva em: ./results/model_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.594532
# Epoch 50 Loss 1.270166
# Epoch 100 Loss 1.257795
# Epoch 150 Loss 1.247508
# Epoch 200 Loss 1.234422
# Epoch 250 Loss 1.246777
# Epoch 300 Loss 1.246418
# Epoch 350 Loss 1.212777
# Epoch 400 Loss 1.184503
# Epoch 450 Loss 1.176062
# Epoch 500 Loss 1.175042
# Epoch 550 Loss 1.159887
# Epoch 600 Loss 1.156420
# Early stopping at epoch 646
# Theta | train1 -> R² = 0.2712, MSE = 1.6637e-01
# X | train1 -> R² = 0.1206, MSE = 9.4818e-02
# Y | train1 -> R² = -0.9110, MSE = 1.6013e-01
# Theta | train2 -> R² = 0.8745, MSE = 2.8643e-02
# X | train2 -> R² = -0.3001, MSE = 1.0955e-01
# Y | train2 -> R² = -1.1374, MSE = 2.3015e-01
# Theta | test1 -> R² = 0.3835, MSE = 1.4163e-01
# X | test1 -> R² = 0.0072, MSE = 1.0401e-01
# Y | test1 -> R² = -1.3005, MSE = 1.8852e-01
# Theta | test2 -> R² = 0.8682, MSE = 3.1256e-02
# X | test2 -> R² = -0.4167, MSE = 1.1659e-01
# Y | test2 -> R² = -1.0495, MSE = 2.1754e-01
# Theta | test3 -> R² = -5.0945, MSE = 2.0035e+00
# X | test3 -> R² = -3.9108, MSE = 4.5182e-01
# Y | test3 -> R² = -2.5382, MSE = 2.7176e-01
# Theta | val -> R² = -6.2992, MSE = 2.3889e+00
# X | val -> R² = -1.5808, MSE = 2.4679e-01
# Y | val -> R² = -2.9868, MSE = 2.9682e-01
# Figura salva em: ./results/model_128_1.pdf
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.536209
# Epoch 50 Loss 1.267544
# Epoch 100 Loss 1.255245
# Epoch 150 Loss 1.249735
# Epoch 200 Loss 1.238212
# Epoch 250 Loss 1.292091
# Epoch 300 Loss 1.181414
# Epoch 350 Loss 1.175798
# Epoch 400 Loss 1.196293
# Epoch 450 Loss 1.159889
# Early stopping at epoch 499
# Theta | train1 -> R² = 0.9542, MSE = 1.0452e-02
# X | train1 -> R² = -0.2106, MSE = 1.3054e-01
# Y | train1 -> R² = -1.0545, MSE = 1.7216e-01
# Theta | train2 -> R² = 0.4480, MSE = 1.2603e-01
# X | train2 -> R² = -0.1055, MSE = 9.3154e-02
# Y | train2 -> R² = -0.9584, MSE = 2.1088e-01
# Theta | test1 -> R² = 0.8038, MSE = 4.5082e-02
# X | test1 -> R² = -0.2749, MSE = 1.3355e-01
# Y | test1 -> R² = -1.5942, MSE = 2.1260e-01
# Theta | test2 -> R² = 0.5099, MSE = 1.1623e-01
# X | test2 -> R² = -0.1878, MSE = 9.7749e-02
# Y | test2 -> R² = -0.8733, MSE = 1.9884e-01
# Theta | test3 -> R² = 0.3390, MSE = 2.1732e-01
# X | test3 -> R² = -2.2254, MSE = 2.9675e-01
# Y | test3 -> R² = -3.7326, MSE = 3.6349e-01
# Theta | val -> R² = -2.2412, MSE = 1.0608e+00
# X | val -> R² = -1.6435, MSE = 2.5278e-01
# Y | val -> R² = -4.0571, MSE = 3.7650e-01
# Figura salva em: ./results/model_128_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.600064
# Epoch 50 Loss 1.265227
# Epoch 100 Loss 1.251252
# Epoch 150 Loss 1.275475
# Epoch 200 Loss 1.465287
# Epoch 250 Loss 1.230232
# Epoch 300 Loss 1.203378
# Epoch 350 Loss 1.186396
# Epoch 400 Loss 1.180419
# Epoch 450 Loss 1.178856
# Epoch 500 Loss 1.169775
# ...
# Figura salva em: ./results/model_128_64_32_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.579664
# Epoch 50 Loss 1.297227
# Epoch 100 Loss 1.199947
# Epoch 150 Loss 1.187392
# Epoch 200 Loss 1.157614
# Epoch 250 Loss 1.146623
# Epoch 300 Loss 1.136615
# Epoch 350 Loss 1.131259
# Early stopping at epoch 368
# Theta | train1 -> R² = 0.3363, MSE = 1.5150e-01
# X | train1 -> R² = 0.0982, MSE = 9.7232e-02
# Y | train1 -> R² = -1.0411, MSE = 1.7104e-01
# Theta | train2 -> R² = -0.0777, MSE = 2.4605e-01
# X | train2 -> R² = 0.0272, MSE = 8.1970e-02
# Y | train2 -> R² = -1.0778, MSE = 2.2374e-01
# Theta | test1 -> R² = 0.2606, MSE = 1.6985e-01
# X | test1 -> R² = 0.0203, MSE = 1.0263e-01
# Y | test1 -> R² = -1.5558, MSE = 2.0944e-01
# Theta | test2 -> R² = 0.4981, MSE = 1.1903e-01
# X | test2 -> R² = -0.0466, MSE = 8.6126e-02
# Y | test2 -> R² = -1.0788, MSE = 2.2065e-01
# Theta | test3 -> R² = -3.5648, MSE = 1.5007e+00
# X | test3 -> R² = -1.0452, MSE = 1.8817e-01
# Y | test3 -> R² = -2.4443, MSE = 2.6454e-01
# Theta | val -> R² = -7.7966, MSE = 2.8790e+00
# X | val -> R² = -1.0893, MSE = 1.9978e-01
# Y | val -> R² = -3.4789, MSE = 3.3345e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.583958
# Epoch 50 Loss 1.258641
# Epoch 100 Loss 1.240896
# Epoch 150 Loss 1.168936
# Epoch 200 Loss 1.151872
# Epoch 250 Loss 1.132722
# Epoch 300 Loss 1.136737
# Epoch 350 Loss 1.113359
# Early stopping at epoch 386
# Theta | train1 -> R² = -1.3150, MSE = 5.2845e-01
# X | train1 -> R² = -0.0442, MSE = 1.1259e-01
# Y | train1 -> R² = -0.9662, MSE = 1.6476e-01
# Theta | train2 -> R² = -1.0815, MSE = 4.7521e-01
# X | train2 -> R² = -0.0896, MSE = 9.1813e-02
# Y | train2 -> R² = -0.7852, MSE = 1.9222e-01
# Theta | test1 -> R² = -1.1713, MSE = 4.9878e-01
# X | test1 -> R² = -0.0565, MSE = 1.1068e-01
# Y | test1 -> R² = -1.4102, MSE = 1.9751e-01
# Theta | test2 -> R² = -1.6508, MSE = 6.2868e-01
# X | test2 -> R² = -0.1737, MSE = 9.6588e-02
# Y | test2 -> R² = -0.7774, MSE = 1.8866e-01
# Theta | test3 -> R² = 0.0861, MSE = 3.0045e-01
# X | test3 -> R² = -2.8746, MSE = 3.5648e-01
# Y | test3 -> R² = -3.5040, MSE = 3.4594e-01
# Theta | val -> R² = -1.2576, MSE = 7.3887e-01
# X | val -> R² = -1.4166, MSE = 2.3108e-01
# Y | val -> R² = -3.2554, MSE = 3.1681e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.574591
# Epoch 50 Loss 1.253085
# Epoch 100 Loss 1.204847
# Epoch 150 Loss 1.175402
# Epoch 200 Loss 1.145607
# Epoch 250 Loss 1.141011
# Epoch 300 Loss 1.131778
# Epoch 350 Loss 1.137363
# Early stopping at epoch 373
# Theta | train1 -> R² = 0.7013, MSE = 6.8174e-02
# X | train1 -> R² = -0.0387, MSE = 1.1200e-01
# Y | train1 -> R² = -1.1552, MSE = 1.8059e-01
# Theta | train2 -> R² = -0.2477, MSE = 2.8486e-01
# X | train2 -> R² = -0.0005, MSE = 8.4305e-02
# Y | train2 -> R² = -1.0563, MSE = 2.2141e-01
# Theta | test1 -> R² = 0.8927, MSE = 2.4652e-02
# X | test1 -> R² = -0.1261, MSE = 1.1797e-01
# Y | test1 -> R² = -1.7542, MSE = 2.2570e-01
# Theta | test2 -> R² = 0.3419, MSE = 1.5607e-01
# X | test2 -> R² = -0.0607, MSE = 8.7288e-02
# Y | test2 -> R² = -0.9833, MSE = 2.1051e-01
# Theta | test3 -> R² = -0.9225, MSE = 6.3201e-01
# X | test3 -> R² = -1.3946, MSE = 2.2032e-01
# Y | test3 -> R² = -2.4530, MSE = 2.6522e-01
# Theta | val -> R² = -3.8661, MSE = 1.5926e+00
# X | val -> R² = -0.9113, MSE = 1.8276e-01
# Y | val -> R² = -3.2552, MSE = 3.1680e-01
# Figura salva em: ./results/model_128_64_32_7.pdf
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.565816
# Epoch 50 Loss 1.252860
# Epoch 100 Loss 1.227226
# Epoch 150 Loss 1.179703
# Epoch 200 Loss 1.160936
# Epoch 250 Loss 1.133711
# Epoch 300 Loss 1.127301
# Epoch 350 Loss 1.128126
# Early stopping at epoch 364
# Theta | train1 -> R² = 0.8563, MSE = 3.2807e-02
# X | train1 -> R² = -0.1763, MSE = 1.2684e-01
# Y | train1 -> R² = -0.9066, MSE = 1.5976e-01
# Theta | train2 -> R² = 0.4654, MSE = 1.2205e-01
# X | train2 -> R² = -0.1184, MSE = 9.4234e-02
# Y | train2 -> R² = -0.8506, MSE = 1.9927e-01
# Theta | test1 -> R² = 0.8347, MSE = 3.7962e-02
# X | test1 -> R² = -0.2931, MSE = 1.3547e-01
# Y | test1 -> R² = -1.3554, MSE = 1.9302e-01
# Theta | test2 -> R² = 0.5600, MSE = 1.0435e-01
# X | test2 -> R² = -0.1947, MSE = 9.8317e-02
# Y | test2 -> R² = -0.8399, MSE = 1.9529e-01
# Theta | test3 -> R² = 0.5118, MSE = 1.6048e-01
# X | test3 -> R² = -1.8513, MSE = 2.6233e-01
# Y | test3 -> R² = -2.7345, MSE = 2.8684e-01
# Theta | val -> R² = -1.7369, MSE = 8.9572e-01
# X | val -> R² = -1.4175, MSE = 2.3117e-01
# Y | val -> R² = -2.9279, MSE = 2.9243e-01
# Figura salva em: ./results/model_128_64_32_8.pdf
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.571463
# Epoch 50 Loss 1.271921
# Epoch 100 Loss 1.198409
# Epoch 150 Loss 1.169718
# Epoch 200 Loss 1.170072
# Epoch 250 Loss 1.162096
# Epoch 300 Loss 1.153024
# Epoch 350 Loss 1.120244
# Early stopping at epoch 373
# Theta | train1 -> R² = 0.3534, MSE = 1.4760e-01
# X | train1 -> R² = -0.1820, MSE = 1.2745e-01
# Y | train1 -> R² = -0.9598, MSE = 1.6422e-01
# Theta | train2 -> R² = 0.4942, MSE = 1.1548e-01
# X | train2 -> R² = -0.1716, MSE = 9.8718e-02
# Y | train2 -> R² = -0.9556, MSE = 2.1058e-01
# Theta | test1 -> R² = 0.6899, MSE = 7.1227e-02
# X | test1 -> R² = -0.3376, MSE = 1.4013e-01
# Y | test1 -> R² = -1.4710, MSE = 2.0249e-01
# Theta | test2 -> R² = 0.5480, MSE = 1.0720e-01
# X | test2 -> R² = -0.2732, MSE = 1.0477e-01
# Y | test2 -> R² = -0.9589, MSE = 2.0793e-01
# Theta | test3 -> R² = 0.7031, MSE = 9.7615e-02
# X | test3 -> R² = -1.8045, MSE = 2.5803e-01
# Y | test3 -> R² = -2.4544, MSE = 2.6532e-01
# Theta | val -> R² = -0.3959, MSE = 4.5684e-01
# X | val -> R² = -1.2107, MSE = 2.1139e-01
# Y | val -> R² = -3.0238, MSE = 2.9957e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.561914
# Epoch 50 Loss 1.194991
# Epoch 100 Loss 1.168526
# Epoch 150 Loss 1.147303
# Epoch 200 Loss 1.166242
# Epoch 250 Loss 1.150334
# Epoch 300 Loss 1.135003
# Early stopping at epoch 312
# Theta | train1 -> R² = -0.2691, MSE = 2.8970e-01
# X | train1 -> R² = 0.6651, MSE = 3.6113e-02
# Y | train1 -> R² = -4.6910, MSE = 4.7689e-01
# Theta | train2 -> R² = 0.1217, MSE = 2.0052e-01
# X | train2 -> R² = -0.5110, MSE = 1.2732e-01
# Y | train2 -> R² = -4.5735, MSE = 6.0014e-01
# Theta | test1 -> R² = -0.4463, MSE = 3.3224e-01
# X | test1 -> R² = 0.6704, MSE = 3.4526e-02
# Y | test1 -> R² = -5.0807, MSE = 4.9831e-01
# Theta | test2 -> R² = 0.3745, MSE = 1.4834e-01
# X | test2 -> R² = -0.4283, MSE = 1.1754e-01
# Y | test2 -> R² = -4.6207, MSE = 5.9660e-01
# Theta | test3 -> R² = -5.9923, MSE = 2.2987e+00
# X | test3 -> R² = -1.5671, MSE = 2.3618e-01
# Y | test3 -> R² = -10.1211, MSE = 8.5418e-01
# Theta | val -> R² = -8.9115, MSE = 3.2438e+00
# X | val -> R² = -0.2386, MSE = 1.1844e-01
# Y | val -> R² = -8.5082, MSE = 7.0789e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.567671
# Epoch 50 Loss 1.214313
# Epoch 100 Loss 1.178680
# Epoch 150 Loss 1.149384
# Epoch 200 Loss 1.145869
# Epoch 250 Loss 1.129562
# Epoch 300 Loss 1.121577
# Early stopping at epoch 323
# Theta | train1 -> R² = 0.5447, MSE = 1.0392e-01
# X | train1 -> R² = 0.1248, MSE = 9.4367e-02
# Y | train1 -> R² = -1.8843, MSE = 2.4169e-01
# Theta | train2 -> R² = 0.3094, MSE = 1.5768e-01
# X | train2 -> R² = -0.2061, MSE = 1.0162e-01
# Y | train2 -> R² = -1.4215, MSE = 2.6074e-01
# Theta | test1 -> R² = 0.5300, MSE = 1.0796e-01
# X | test1 -> R² = -0.0354, MSE = 1.0846e-01
# Y | test1 -> R² = -2.4766, MSE = 2.8490e-01
# Theta | test2 -> R² = 0.7574, MSE = 5.7534e-02
# X | test2 -> R² = -0.2733, MSE = 1.0478e-01
# Y | test2 -> R² = -1.4535, MSE = 2.6042e-01
# Theta | test3 -> R² = -1.2655, MSE = 7.4477e-01
# X | test3 -> R² = -1.9941, MSE = 2.7547e-01
# Y | test3 -> R² = -6.0617, MSE = 5.4239e-01
# Theta | val -> R² = -3.9126, MSE = 1.6078e+00
# X | val -> R² = -0.8621, MSE = 1.7806e-01
# Y | val -> R² = -6.1812, MSE = 5.3464e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.592676
# Epoch 50 Loss 1.215877
# Epoch 100 Loss 1.160233
# Epoch 150 Loss 1.146645
# Epoch 200 Loss 1.135255
# Epoch 250 Loss 1.120548
# Epoch 300 Loss 1.153383
# Early stopping at epoch 305
# Theta | train1 -> R² = -10.6937, MSE = 2.6693e+00
# X | train1 -> R² = -1.3586, MSE = 2.5432e-01
# Y | train1 -> R² = -1.0545, MSE = 1.7216e-01
# Theta | train2 -> R² = -9.9400, MSE = 2.4976e+00
# X | train2 -> R² = -1.7225, MSE = 2.2940e-01
# Y | train2 -> R² = -1.8367, MSE = 3.0545e-01
# Theta | test1 -> R² = -9.9236, MSE = 2.5094e+00
# X | test1 -> R² = -1.6123, MSE = 2.7367e-01
# Y | test1 -> R² = -1.2330, MSE = 1.8299e-01
# Theta | test2 -> R² = -9.9243, MSE = 2.5908e+00
# X | test2 -> R² = -2.1159, MSE = 2.5642e-01
# Y | test2 -> R² = -1.8087, MSE = 2.9812e-01
# Theta | test3 -> R² = -2.1467, MSE = 1.0345e+00
# X | test3 -> R² = -3.4599, MSE = 4.1033e-01
# Y | test3 -> R² = -1.5273, MSE = 1.9411e-01
# Theta | val -> R² = -4.3288, MSE = 1.7440e+00
# X | val -> R² = -3.1487, MSE = 3.9671e-01
# Y | val -> R² = -1.2255, MSE = 1.6569e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.540671
# Epoch 50 Loss 1.213786
# Epoch 100 Loss 1.170197
# Epoch 150 Loss 1.168369
# Epoch 200 Loss 1.140316
# Epoch 250 Loss 1.132008
# Epoch 300 Loss 1.129365
# Early stopping at epoch 320
# Theta | train1 -> R² = 0.7973, MSE = 4.6277e-02
# X | train1 -> R² = -0.9022, MSE = 2.0511e-01
# Y | train1 -> R² = -1.2431, MSE = 1.8797e-01
# Theta | train2 -> R² = 0.4978, MSE = 1.1466e-01
# X | train2 -> R² = -1.0355, MSE = 1.7151e-01
# Y | train2 -> R² = -1.5090, MSE = 2.7016e-01
# Theta | test1 -> R² = 0.9282, MSE = 1.6491e-02
# X | test1 -> R² = -1.1978, MSE = 2.3025e-01
# Y | test1 -> R² = -1.6296, MSE = 2.1549e-01
# Theta | test2 -> R² = 0.7347, MSE = 6.2907e-02
# X | test2 -> R² = -1.1832, MSE = 1.7966e-01
# Y | test2 -> R² = -1.5407, MSE = 2.6967e-01
# Theta | test3 -> R² = -0.2872, MSE = 4.2316e-01
# X | test3 -> R² = -3.4746, MSE = 4.1168e-01
# Y | test3 -> R² = -2.3012, MSE = 2.5355e-01
# Theta | val -> R² = -0.4226, MSE = 4.6557e-01
# X | val -> R² = -2.8784, MSE = 3.7087e-01
# Y | val -> R² = -2.2059, MSE = 2.3868e-01
# Figura salva em: ./results/model_264_128_64_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.580711
# Epoch 50 Loss 1.204529
# Epoch 100 Loss 1.158021
# Epoch 150 Loss 1.147535
# Epoch 200 Loss 1.159879
# Epoch 250 Loss 1.169234
# Epoch 300 Loss 1.126732
# Early stopping at epoch 323
# Theta | train1 -> R² = 0.2150, MSE = 1.7920e-01
# X | train1 -> R² = 0.6280, MSE = 4.0111e-02
# Y | train1 -> R² = -0.2560, MSE = 1.0525e-01
# Theta | train2 -> R² = -1.4344, MSE = 5.5578e-01
# X | train2 -> R² = -0.5741, MSE = 1.3263e-01
# Y | train2 -> R² = -0.2478, MSE = 1.3437e-01
# Theta | test1 -> R² = 0.6213, MSE = 8.6992e-02
# X | test1 -> R² = 0.6742, MSE = 3.4133e-02
# Y | test1 -> R² = -0.5347, MSE = 1.2576e-01
# Theta | test2 -> R² = 0.0257, MSE = 2.3107e-01
# X | test2 -> R² = -0.4791, MSE = 1.2172e-01
# Y | test2 -> R² = -0.3266, MSE = 1.4081e-01
# Theta | test3 -> R² = -4.8138, MSE = 1.9113e+00
# X | test3 -> R² = 0.2523, MSE = 6.8794e-02
# Y | test3 -> R² = -2.0264, MSE = 2.3245e-01
# Theta | val -> R² = 0.7174, MSE = 9.2482e-02
# X | val -> R² = 0.6617, MSE = 3.2352e-02
# Y | val -> R² = -1.7264, MSE = 2.0298e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.556168
# Epoch 50 Loss 1.218661
# Epoch 100 Loss 1.185213
# Epoch 150 Loss 1.156590
# Epoch 200 Loss 1.167387
# Epoch 250 Loss 1.138461
# Epoch 300 Loss 1.141481
# Early stopping at epoch 305
# Theta | train1 -> R² = -5.4118, MSE = 1.4636e+00
# X | train1 -> R² = 0.5232, MSE = 5.1407e-02
# Y | train1 -> R² = -1.5849, MSE = 2.1661e-01
# Theta | train2 -> R² = -7.6561, MSE = 1.9762e+00
# X | train2 -> R² = -0.1986, MSE = 1.0099e-01
# Y | train2 -> R² = -1.1090, MSE = 2.2710e-01
# Theta | test1 -> R² = -3.9759, MSE = 1.1431e+00
# X | test1 -> R² = 0.4144, MSE = 6.1352e-02
# Y | test1 -> R² = -1.9231, MSE = 2.3955e-01
# Theta | test2 -> R² = -7.6573, MSE = 2.0532e+00
# X | test2 -> R² = -0.2063, MSE = 9.9268e-02
# Y | test2 -> R² = -1.0976, MSE = 2.2264e-01
# Theta | test3 -> R² = -1.4480, MSE = 8.0478e-01
# X | test3 -> R² = -0.7182, MSE = 1.5808e-01
# Y | test3 -> R² = -4.8322, MSE = 4.4795e-01
# Theta | val -> R² = -2.6846, MSE = 1.2059e+00
# X | val -> R² = -0.4399, MSE = 1.3769e-01
# Y | val -> R² = -4.5169, MSE = 4.1073e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.567968
# Epoch 50 Loss 1.235455
# Epoch 100 Loss 1.159156
# Epoch 150 Loss 1.152730
# Epoch 200 Loss 1.136304
# Epoch 250 Loss 1.138369
# Epoch 300 Loss 1.129979
# Early stopping at epoch 330
# Theta | train1 -> R² = 0.9221, MSE = 1.7775e-02
# X | train1 -> R² = -0.1040, MSE = 1.1904e-01
# Y | train1 -> R² = -1.0069, MSE = 1.6817e-01
# Theta | train2 -> R² = 0.6257, MSE = 8.5458e-02
# X | train2 -> R² = -0.1635, MSE = 9.8037e-02
# Y | train2 -> R² = -0.9709, MSE = 2.1222e-01
# Theta | test1 -> R² = 0.6061, MSE = 9.0497e-02
# X | test1 -> R² = -0.2497, MSE = 1.3092e-01
# Y | test1 -> R² = -1.3583, MSE = 1.9326e-01
# Theta | test2 -> R² = 0.6168, MSE = 9.0886e-02
# X | test2 -> R² = -0.1989, MSE = 9.8662e-02
# Y | test2 -> R² = -0.8984, MSE = 2.0150e-01
# Theta | test3 -> R² = 0.8073, MSE = 6.3347e-02
# X | test3 -> R² = -1.4088, MSE = 2.2162e-01
# Y | test3 -> R² = -2.4477, MSE = 2.6481e-01
# Theta | val -> R² = -2.1055, MSE = 1.0164e+00
# X | val -> R² = -0.8658, MSE = 1.7842e-01
# Y | val -> R² = -1.9533, MSE = 2.1988e-01
# Figura salva em: ./results/model_264_128_64_6.pdf
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.571145
# Epoch 50 Loss 1.204992
# Epoch 100 Loss 1.188410
# Epoch 150 Loss 1.162000
# Epoch 200 Loss 1.139945
# Epoch 250 Loss 1.129613
# Epoch 300 Loss 1.124038
# Early stopping at epoch 304
# Theta | train1 -> R² = -0.1788, MSE = 2.6908e-01
# X | train1 -> R² = 0.2129, MSE = 8.4869e-02
# Y | train1 -> R² = 0.2032, MSE = 6.6769e-02
# Theta | train2 -> R² = 0.4161, MSE = 1.3331e-01
# X | train2 -> R² = -0.0266, MSE = 8.6502e-02
# Y | train2 -> R² = -0.4002, MSE = 1.5077e-01
# Theta | test1 -> R² = -0.0205, MSE = 2.3442e-01
# X | test1 -> R² = 0.2481, MSE = 7.8768e-02
# Y | test1 -> R² = 0.1980, MSE = 6.5725e-02
# Theta | test2 -> R² = 0.7236, MSE = 6.5545e-02
# X | test2 -> R² = -0.0275, MSE = 8.4559e-02
# Y | test2 -> R² = -0.4037, MSE = 1.4900e-01
# Theta | test3 -> R² = -10.9632, MSE = 3.9329e+00
# X | test3 -> R² = -0.3551, MSE = 1.2468e-01
# Y | test3 -> R² = -0.7996, MSE = 1.3822e-01
# Theta | val -> R² = -9.5023, MSE = 3.4372e+00
# X | val -> R² = -0.0383, MSE = 9.9289e-02
# Y | val -> R² = 0.1428, MSE = 6.3821e-02
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.557729
# Epoch 50 Loss 1.204103
# Epoch 100 Loss 1.215905
# Epoch 150 Loss 1.150719
# Epoch 200 Loss 1.163279
# Epoch 250 Loss 1.152330
# Epoch 300 Loss 1.145407
# Early stopping at epoch 303
# Theta | train1 -> R² = 0.0391, MSE = 2.1933e-01
# X | train1 -> R² = 0.2649, MSE = 7.9262e-02
# Y | train1 -> R² = -1.4223, MSE = 2.0298e-01
# Theta | train2 -> R² = 0.1567, MSE = 1.9252e-01
# X | train2 -> R² = -0.0695, MSE = 9.0116e-02
# Y | train2 -> R² = -1.4488, MSE = 2.6368e-01
# Theta | test1 -> R² = 0.3341, MSE = 1.5297e-01
# X | test1 -> R² = 0.1169, MSE = 9.2517e-02
# Y | test1 -> R² = -1.6435, MSE = 2.1663e-01
# Theta | test2 -> R² = 0.2535, MSE = 1.7705e-01
# X | test2 -> R² = -0.0916, MSE = 8.9834e-02
# Y | test2 -> R² = -1.4549, MSE = 2.6057e-01
# Theta | test3 -> R² = -1.3532, MSE = 7.7360e-01
# X | test3 -> R² = -3.9802, MSE = 4.5820e-01
# Y | test3 -> R² = -6.1712, MSE = 5.5080e-01
# Theta | val -> R² = -3.8261, MSE = 1.5795e+00
# X | val -> R² = -2.1018, MSE = 2.9660e-01
# Y | val -> R² = -4.0410, MSE = 3.7530e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.539377
# Epoch 50 Loss 1.211072
# Epoch 100 Loss 1.165259
# Epoch 150 Loss 1.153918
# Epoch 200 Loss 1.143488
# Epoch 250 Loss 1.137575
# Epoch 300 Loss 1.122383
# Early stopping at epoch 308
# Theta | train1 -> R² = 0.5574, MSE = 1.0102e-01
# X | train1 -> R² = -1.6709, MSE = 2.8799e-01
# Y | train1 -> R² = -3.0836, MSE = 3.4219e-01
# Theta | train2 -> R² = 0.3310, MSE = 1.5273e-01
# X | train2 -> R² = -1.6007, MSE = 2.1913e-01
# Y | train2 -> R² = -2.8212, MSE = 4.1146e-01
# Theta | test1 -> R² = 0.7208, MSE = 6.4140e-02
# X | test1 -> R² = -1.9959, MSE = 3.1385e-01
# Y | test1 -> R² = -3.3534, MSE = 3.5676e-01
# Theta | test2 -> R² = 0.2398, MSE = 1.8028e-01
# X | test2 -> R² = -1.7506, MSE = 2.2636e-01
# Y | test2 -> R² = -2.8074, MSE = 4.0413e-01
# Theta | test3 -> R² = -0.6329, MSE = 5.3681e-01
# X | test3 -> R² = -4.0000, MSE = 4.6002e-01
# Y | test3 -> R² = -5.9840, MSE = 5.3643e-01
# Theta | val -> R² = 0.8580, MSE = 4.6490e-02
# X | val -> R² = -2.6930, MSE = 3.5313e-01
# Y | val -> R² = -5.5023, MSE = 4.8410e-01
# Modelo 9 treinado e salvo no Excel
