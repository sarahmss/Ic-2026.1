# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(Theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "sinTheta"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./Data/Theta.xlsx", sheet_name=title)

    df["Theta_pred"] = df_theta["Theta_pred_model_arch16-8-4_r0.9_Ld0.3_Lp0.7_seed5830"]

    df["sinTheta"] = np.sin(df["Theta_pred"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1943, 3, 5)
# Dimensão da saida: (1943, 1)
# Dimensão da entrada: (1265, 3, 5)
# Dimensão da saida: (1265, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1943, 3, 5)
# Dimensão da saida: (1943, 1)
# Dimensão da entrada fisica : (1943,)
# Dimensão da entrada fisica: (1943,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)
    return [dy_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# Epoch 0 | Train Loss 1.200473 | Val Loss 0.792711
# Epoch 100 | Train Loss 0.727926 | Val Loss 0.937556
# Epoch 200 | Train Loss 0.560453 | Val Loss 0.789871
# Epoch 300 | Train Loss 0.447653 | Val Loss 0.678788
# Epoch 400 | Train Loss 0.410302 | Val Loss 0.627511
# Epoch 500 | Train Loss 0.400074 | Val Loss 0.620567
# Epoch 600 | Train Loss 0.395520 | Val Loss 0.624351
# Early stopping at epoch 658
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9888, MSE = 9.3506e-04
# Y | Train_2 -> R² = 0.9830, MSE = 1.8189e-03
# Y | Test_1 -> R² = 0.9782, MSE = 1.7862e-03
# Y | Test_2 -> R² = 0.9619, MSE = 4.0280e-03
# Y | Test_3 -> R² = -2.1992, MSE = 2.4533e-01
# Y | Val -> R² = 0.9503, MSE = 3.6937e-03
# Y | LSG_1 -> R² = -1.2342, MSE = 7.0747e-01
# Y | LSG_2 -> R² = -0.4183, MSE = 5.4664e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.212467 | Val Loss 0.800861
# Epoch 100 | Train Loss 0.701161 | Val Loss 0.906718
# Epoch 200 | Train Loss 0.505936 | Val Loss 0.743790
# Epoch 300 | Train Loss 0.464107 | Val Loss 0.685732
# Epoch 400 | Train Loss 0.449372 | Val Loss 0.682713
# Epoch 500 | Train Loss 0.413686 | Val Loss 0.692153
# Early stopping at epoch 551
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.8035, MSE = 1.6440e-02
# Y | Train_2 -> R² = 0.9756, MSE = 2.6162e-03
# Y | Test_1 -> R² = 0.8464, MSE = 1.2568e-02
# Y | Test_2 -> R² = 0.9529, MSE = 4.9854e-03
# Y | Test_3 -> R² = -1.2283, MSE = 1.7088e-01
# Y | Val -> R² = 0.7753, MSE = 1.6707e-02
# Y | LSG_1 -> R² = -0.5697, MSE = 4.9703e-01
# Y | LSG_2 -> R² = -0.2300, MSE = 4.7407e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.193398 | Val Loss 0.775589
# Epoch 100 | Train Loss 0.652518 | Val Loss 0.854626
# Epoch 200 | Train Loss 0.415607 | Val Loss 0.703963
# Epoch 300 | Train Loss 0.401874 | Val Loss 0.661750
# Epoch 400 | Train Loss 0.399229 | Val Loss 0.651795
# Epoch 500 | Train Loss 0.397475 | Val Loss 0.652661
# Epoch 600 | Train Loss 0.395657 | Val Loss 0.657113
# Early stopping at epoch 608
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9921, MSE = 6.5741e-04
# Y | Train_2 -> R² = 0.9884, MSE = 1.2451e-03
# Y | Test_1 -> R² = 0.9261, MSE = 6.0461e-03
# Y | Test_2 -> R² = 0.9782, MSE = 2.3051e-03
# Y | Test_3 -> R² = -9.0518, MSE = 7.7083e-01
# Y | Val -> R² = 0.8209, MSE = 1.3322e-02
# Y | LSG_1 -> R² = -1.8821, MSE = 9.1262e-01
# Y | LSG_2 -> R² = -0.7350, MSE = 6.6869e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.211998 | Val Loss 0.814546
# Epoch 100 | Train Loss 0.773947 | Val Loss 0.956231
# Epoch 200 | Train Loss 0.484769 | Val Loss 0.730897
# Epoch 300 | Train Loss 0.423486 | Val Loss 0.655562
# Epoch 400 | Train Loss 0.398672 | Val Loss 0.616081
# Epoch 500 | Train Loss 0.390747 | Val Loss 0.619401
# Epoch 600 | Train Loss 0.388613 | Val Loss 0.619990
# Early stopping at epoch 607
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9904, MSE = 8.0051e-04
# Y | Train_2 -> R² = 0.9898, MSE = 1.0910e-03
# Y | Test_1 -> R² = 0.9417, MSE = 4.7712e-03
# Y | Test_2 -> R² = 0.9347, MSE = 6.8995e-03
# Y | Test_3 -> R² = -1.6754, MSE = 2.0516e-01
# Y | Val -> R² = 0.8749, MSE = 9.3038e-03
# Y | LSG_1 -> R² = -0.3674, MSE = 4.3299e-01
# Y | LSG_2 -> R² = 0.0618, MSE = 3.6160e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.269144 | Val Loss 0.807435
# Epoch 100 | Train Loss 0.757185 | Val Loss 0.920470
# Epoch 200 | Train Loss 0.544091 | Val Loss 0.791639
# Epoch 300 | Train Loss 0.443618 | Val Loss 0.679530
# Epoch 400 | Train Loss 0.405493 | Val Loss 0.637223
# Epoch 500 | Train Loss 0.399997 | Val Loss 0.638907
# Early stopping at epoch 584
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9833, MSE = 1.3932e-03
# Y | Train_2 -> R² = 0.9841, MSE = 1.7100e-03
# Y | Test_1 -> R² = 0.9662, MSE = 2.7644e-03
# Y | Test_2 -> R² = 0.9590, MSE = 4.3377e-03
# Y | Test_3 -> R² = -4.0135, MSE = 3.8446e-01
# Y | Val -> R² = 0.9453, MSE = 4.0691e-03
# Y | LSG_1 -> R² = -0.1952, MSE = 3.7845e-01
# Y | LSG_2 -> R² = 0.1410, MSE = 3.3106e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.234277 | Val Loss 0.800230
# Epoch 100 | Train Loss 0.726892 | Val Loss 0.923550
# Epoch 200 | Train Loss 0.556058 | Val Loss 0.774818
# Epoch 300 | Train Loss 0.448765 | Val Loss 0.677238
# Epoch 400 | Train Loss 0.405714 | Val Loss 0.633005
# Epoch 500 | Train Loss 0.398773 | Val Loss 0.631926
# Epoch 600 | Train Loss 0.394300 | Val Loss 0.639556
# Early stopping at epoch 633
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9890, MSE = 9.1912e-04
# Y | Train_2 -> R² = 0.9706, MSE = 3.1532e-03
# Y | Test_1 -> R² = 0.9598, MSE = 3.2887e-03
# Y | Test_2 -> R² = 0.9489, MSE = 5.4037e-03
# Y | Test_3 -> R² = -3.1361, MSE = 3.1718e-01
# Y | Val -> R² = 0.9622, MSE = 2.8135e-03
# Y | LSG_1 -> R² = -1.2935, MSE = 7.2623e-01
# Y | LSG_2 -> R² = -0.5623, MSE = 6.0212e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.206055 | Val Loss 0.814122
# Epoch 100 | Train Loss 0.732271 | Val Loss 0.926586
# Epoch 200 | Train Loss 0.566775 | Val Loss 0.790626
# Epoch 300 | Train Loss 0.435920 | Val Loss 0.660415
# Epoch 400 | Train Loss 0.401032 | Val Loss 0.635629
# Epoch 500 | Train Loss 0.396190 | Val Loss 0.632079
# Epoch 600 | Train Loss 0.394288 | Val Loss 0.629840
# Epoch 700 | Train Loss 0.393047 | Val Loss 0.628479
# Epoch 800 | Train Loss 0.392039 | Val Loss 0.627720
# Epoch 900 | Train Loss 0.391034 | Val Loss 0.627448
# Early stopping at epoch 919
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9937, MSE = 5.2553e-04
# Y | Train_2 -> R² = 0.9900, MSE = 1.0719e-03
# Y | Test_1 -> R² = 0.9571, MSE = 3.5072e-03
# Y | Test_2 -> R² = 0.9441, MSE = 5.9083e-03
# Y | Test_3 -> R² = -4.5628, MSE = 4.2659e-01
# Y | Val -> R² = 0.8515, MSE = 1.1042e-02
# Y | LSG_1 -> R² = -2.3462, MSE = 1.0596e+00
# Y | LSG_2 -> R² = -0.8049, MSE = 6.9564e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.222267 | Val Loss 0.783792
# Epoch 100 | Train Loss 0.745353 | Val Loss 0.926680
# Epoch 200 | Train Loss 0.495218 | Val Loss 0.793172
# Epoch 300 | Train Loss 0.409072 | Val Loss 0.646428
# Epoch 400 | Train Loss 0.399414 | Val Loss 0.635844
# Epoch 500 | Train Loss 0.395549 | Val Loss 0.629992
# Epoch 600 | Train Loss 0.393233 | Val Loss 0.627391
# Epoch 700 | Train Loss 0.391471 | Val Loss 0.625755
# Epoch 800 | Train Loss 0.390034 | Val Loss 0.625174
# Epoch 900 | Train Loss 0.388717 | Val Loss 0.625278
# Early stopping at epoch 933
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9932, MSE = 5.6625e-04
# Y | Train_2 -> R² = 0.9904, MSE = 1.0323e-03
# Y | Test_1 -> R² = 0.9327, MSE = 5.5021e-03
# Y | Test_2 -> R² = 0.9826, MSE = 1.8378e-03
# Y | Test_3 -> R² = -2.9034, MSE = 2.9934e-01
# Y | Val -> R² = 0.8341, MSE = 1.2339e-02
# Y | LSG_1 -> R² = -2.2241, MSE = 1.0209e+00
# Y | LSG_2 -> R² = -0.6526, MSE = 6.3693e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.235927 | Val Loss 0.773533
# Epoch 100 | Train Loss 0.729805 | Val Loss 0.921253
# Epoch 200 | Train Loss 0.517007 | Val Loss 0.767081
# Epoch 300 | Train Loss 0.434739 | Val Loss 0.658302
# Epoch 400 | Train Loss 0.403071 | Val Loss 0.649830
# Epoch 500 | Train Loss 0.397413 | Val Loss 0.648214
# Epoch 600 | Train Loss 0.394764 | Val Loss 0.639722
# Epoch 700 | Train Loss 0.392648 | Val Loss 0.634489
# Epoch 800 | Train Loss 0.391111 | Val Loss 0.633671
# Epoch 900 | Train Loss 0.389976 | Val Loss 0.635970
# Early stopping at epoch 937
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9937, MSE = 5.3048e-04
# Y | Train_2 -> R² = 0.9924, MSE = 8.1395e-04
# Y | Test_1 -> R² = 0.9652, MSE = 2.8495e-03
# Y | Test_2 -> R² = 0.9829, MSE = 1.8031e-03
# Y | Test_3 -> R² = -2.9963, MSE = 3.0646e-01
# Y | Val -> R² = 0.8921, MSE = 8.0214e-03
# Y | LSG_1 -> R² = 0.2066, MSE = 2.5121e-01
# Y | LSG_2 -> R² = 0.6509, MSE = 1.3454e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.239570 | Val Loss 0.785396
# Epoch 100 | Train Loss 0.720158 | Val Loss 0.889800
# Epoch 200 | Train Loss 0.477954 | Val Loss 0.761626
# Epoch 300 | Train Loss 0.406848 | Val Loss 0.644166
# Epoch 400 | Train Loss 0.399113 | Val Loss 0.645282
# Epoch 500 | Train Loss 0.396472 | Val Loss 0.644527
# Early stopping at epoch 502
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9764, MSE = 1.9716e-03
# Y | Train_2 -> R² = 0.9673, MSE = 3.5060e-03
# Y | Test_1 -> R² = 0.9301, MSE = 5.7201e-03
# Y | Test_2 -> R² = 0.9294, MSE = 7.4681e-03
# Y | Test_3 -> R² = -8.9941, MSE = 7.6640e-01
# Y | Val -> R² = 0.0938, MSE = 6.7393e-02
# Y | LSG_1 -> R² = -1.0706, MSE = 6.5564e-01
# Y | LSG_2 -> R² = -0.3737, MSE = 5.2946e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1815 salvo.
# Epoch 0 | Train Loss 1.605928 | Val Loss 0.790060
# Epoch 100 | Train Loss 1.097933 | Val Loss 0.936582
# Epoch 200 | Train Loss 0.921823 | Val Loss 0.772522
# Epoch 300 | Train Loss 0.849690 | Val Loss 0.689808
# Epoch 400 | Train Loss 0.817544 | Val Loss 0.664996
# Epoch 500 | Train Loss 0.785813 | Val Loss 0.627403
# Epoch 600 | Train Loss 0.775595 | Val Loss 0.618604
# Epoch 700 | Train Loss 0.771107 | Val Loss 0.616468
# Epoch 800 | Train Loss 0.767823 | Val Loss 0.619321
# Early stopping at epoch 838
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8552.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9467e-04
# Y | Train_2 -> R² = 0.9853, MSE = 1.5813e-03
# Y | Test_1 -> R² = 0.9275, MSE = 5.9326e-03
# Y | Test_2 -> R² = 0.9166, MSE = 8.8164e-03
# Y | Test_3 -> R² = -2.4074, MSE = 2.6130e-01
# Y | Val -> R² = 0.9210, MSE = 5.8765e-03
# Y | LSG_1 -> R² = -0.2867, MSE = 4.0744e-01
# Y | LSG_2 -> R² = 0.0222, MSE = 3.7684e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.594219 | Val Loss 0.801956
# Epoch 100 | Train Loss 1.107504 | Val Loss 0.912767
# Epoch 200 | Train Loss 0.886622 | Val Loss 0.728660
# Epoch 300 | Train Loss 0.821064 | Val Loss 0.658004
# Epoch 400 | Train Loss 0.786194 | Val Loss 0.635020
# Epoch 500 | Train Loss 0.774903 | Val Loss 0.628832
# Epoch 600 | Train Loss 0.770442 | Val Loss 0.625998
# Epoch 700 | Train Loss 0.767570 | Val Loss 0.625649
# Epoch 800 | Train Loss 0.765219 | Val Loss 0.624001
# Epoch 900 | Train Loss 0.763026 | Val Loss 0.620569
# Epoch 1000 | Train Loss 0.760840 | Val Loss 0.616115
# Epoch 1100 | Train Loss 0.758566 | Val Loss 0.611982
# Epoch 1200 | Train Loss 0.756283 | Val Loss 0.610397
# Epoch 1300 | Train Loss 0.753983 | Val Loss 0.612553
# Early stopping at epoch 1349
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed6028.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9909, MSE = 7.5833e-04
# Y | Train_2 -> R² = 0.9937, MSE = 6.7919e-04
# Y | Test_1 -> R² = 0.9644, MSE = 2.9093e-03
# Y | Test_2 -> R² = 0.9917, MSE = 8.7305e-04
# Y | Test_3 -> R² = -0.0696, MSE = 8.2020e-02
# Y | Val -> R² = 0.6756, MSE = 2.4122e-02
# Y | LSG_1 -> R² = -0.2796, MSE = 4.0519e-01
# Y | LSG_2 -> R² = 0.3520, MSE = 2.4976e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.619218 | Val Loss 0.794369
# Epoch 100 | Train Loss 1.136173 | Val Loss 0.954793
# Epoch 200 | Train Loss 0.920292 | Val Loss 0.764673
# Epoch 300 | Train Loss 0.825228 | Val Loss 0.663236
# Epoch 400 | Train Loss 0.793115 | Val Loss 0.644921
# Epoch 500 | Train Loss 0.781067 | Val Loss 0.642472
# Epoch 600 | Train Loss 0.776334 | Val Loss 0.639115
# Epoch 700 | Train Loss 0.773354 | Val Loss 0.636702
# Epoch 800 | Train Loss 0.771128 | Val Loss 0.635758
# Epoch 900 | Train Loss 0.769189 | Val Loss 0.634752
# Epoch 1000 | Train Loss 0.767307 | Val Loss 0.633241
# Epoch 1100 | Train Loss 0.765453 | Val Loss 0.632065
# Epoch 1200 | Train Loss 0.763768 | Val Loss 0.631632
# Epoch 1300 | Train Loss 0.762262 | Val Loss 0.631834
# Early stopping at epoch 1301
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed9770.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9943, MSE = 4.7925e-04
# Y | Train_2 -> R² = 0.9897, MSE = 1.1091e-03
# Y | Test_1 -> R² = 0.9005, MSE = 8.1405e-03
# Y | Test_2 -> R² = 0.9765, MSE = 2.4824e-03
# Y | Test_3 -> R² = 0.3293, MSE = 5.1429e-02
# Y | Val -> R² = 0.7081, MSE = 2.1708e-02
# Y | LSG_1 -> R² = 0.1949, MSE = 2.5493e-01
# Y | LSG_2 -> R² = 0.3966, MSE = 2.3255e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.639571 | Val Loss 0.787719
# Epoch 100 | Train Loss 1.156453 | Val Loss 0.962085
# Epoch 200 | Train Loss 0.978308 | Val Loss 0.822775
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed7069.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed7069.weights.h5
# Y | Train_1 -> R² = -1.1113, MSE = 1.7664e-01
# Y | Train_2 -> R² = -3.2041, MSE = 4.5096e-01
# Y | Test_1 -> R² = -1.1741, MSE = 1.7786e-01
# Y | Test_2 -> R² = -3.1108, MSE = 4.3467e-01
# Y | Test_3 -> R² = -1.1032, MSE = 1.6129e-01
# Y | Val -> R² = -1.3863, MSE = 1.7746e-01
# Y | LSG_1 -> R² = 0.1033, MSE = 2.8393e-01
# Y | LSG_2 -> R² = 0.1175, MSE = 3.4015e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.580392 | Val Loss 0.818486
# Epoch 100 | Train Loss 1.165255 | Val Loss 0.961106
# Epoch 200 | Train Loss 0.925695 | Val Loss 0.771625
# Epoch 300 | Train Loss 0.797880 | Val Loss 0.642898
# Epoch 400 | Train Loss 0.781278 | Val Loss 0.620557
# Epoch 500 | Train Loss 0.773653 | Val Loss 0.613411
# Epoch 600 | Train Loss 0.768493 | Val Loss 0.610437
# Epoch 700 | Train Loss 0.765379 | Val Loss 0.608306
# Epoch 800 | Train Loss 0.762907 | Val Loss 0.607733
# Epoch 900 | Train Loss 0.760556 | Val Loss 0.608019
# Early stopping at epoch 904
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1815.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9924, MSE = 6.3523e-04
# Y | Train_2 -> R² = 0.9915, MSE = 9.1402e-04
# Y | Test_1 -> R² = 0.9128, MSE = 7.1348e-03
# Y | Test_2 -> R² = 0.9672, MSE = 3.4685e-03
# Y | Test_3 -> R² = -1.3754, MSE = 1.8216e-01
# Y | Val -> R² = 0.9382, MSE = 4.5978e-03
# Y | LSG_1 -> R² = 0.1370, MSE = 2.7326e-01
# Y | LSG_2 -> R² = 0.3431, MSE = 2.5317e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.601268 | Val Loss 0.793654
# Epoch 100 | Train Loss 1.097327 | Val Loss 0.946719
# Epoch 200 | Train Loss 0.969000 | Val Loss 0.809123
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8552.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8552.weights.h5
# Y | Train_1 -> R² = -0.6802, MSE = 1.4058e-01
# Y | Train_2 -> R² = -2.7432, MSE = 4.0152e-01
# Y | Test_1 -> R² = -0.7307, MSE = 1.4158e-01
# Y | Test_2 -> R² = -2.6670, MSE = 3.8774e-01
# Y | Test_3 -> R² = -0.9264, MSE = 1.4772e-01
# Y | Val -> R² = -1.3072, MSE = 1.7158e-01
# Y | LSG_1 -> R² = 0.0356, MSE = 3.0538e-01
# Y | LSG_2 -> R² = 0.0716, MSE = 3.5783e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.609465 | Val Loss 0.802865
# Epoch 100 | Train Loss 1.118123 | Val Loss 0.910499
# Epoch 200 | Train Loss 0.900106 | Val Loss 0.743383
# Epoch 300 | Train Loss 0.823101 | Val Loss 0.655582
# Epoch 400 | Train Loss 0.788156 | Val Loss 0.626072
# Epoch 500 | Train Loss 0.778409 | Val Loss 0.623464
# Epoch 600 | Train Loss 0.773621 | Val Loss 0.631624
# Early stopping at epoch 638
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed6028.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9927, MSE = 6.1375e-04
# Y | Train_2 -> R² = 0.9782, MSE = 2.3413e-03
# Y | Test_1 -> R² = 0.9581, MSE = 3.4264e-03
# Y | Test_2 -> R² = 0.9263, MSE = 7.7923e-03
# Y | Test_3 -> R² = -5.5644, MSE = 5.0339e-01
# Y | Val -> R² = 0.7246, MSE = 2.0483e-02
# Y | LSG_1 -> R² = -0.4887, MSE = 4.7139e-01
# Y | LSG_2 -> R² = 0.0288, MSE = 3.7430e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.572903 | Val Loss 0.772042
# Epoch 100 | Train Loss 1.115168 | Val Loss 0.939373
# Epoch 200 | Train Loss 0.890027 | Val Loss 0.737820
# Epoch 300 | Train Loss 0.800832 | Val Loss 0.648206
# Epoch 400 | Train Loss 0.780910 | Val Loss 0.631102
# Epoch 500 | Train Loss 0.774709 | Val Loss 0.631137
# Epoch 600 | Train Loss 0.771558 | Val Loss 0.629979
# Epoch 700 | Train Loss 0.769152 | Val Loss 0.628191
# Epoch 800 | Train Loss 0.767167 | Val Loss 0.626702
# Epoch 900 | Train Loss 0.765252 | Val Loss 0.624502
# Epoch 1000 | Train Loss 0.762946 | Val Loss 0.623010
# Epoch 1100 | Train Loss 0.760495 | Val Loss 0.623223
# Early stopping at epoch 1136
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed9770.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9926, MSE = 6.1538e-04
# Y | Train_2 -> R² = 0.9898, MSE = 1.0930e-03
# Y | Test_1 -> R² = 0.8360, MSE = 1.3416e-02
# Y | Test_2 -> R² = 0.9560, MSE = 4.6486e-03
# Y | Test_3 -> R² = 0.4162, MSE = 4.4768e-02
# Y | Val -> R² = 0.9364, MSE = 4.7304e-03
# Y | LSG_1 -> R² = 0.3974, MSE = 1.9082e-01
# Y | LSG_2 -> R² = 0.4211, MSE = 2.2312e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.571632 | Val Loss 0.792209
# Epoch 100 | Train Loss 1.137126 | Val Loss 0.952824
# Epoch 200 | Train Loss 0.856658 | Val Loss 0.699384
# Epoch 300 | Train Loss 0.806517 | Val Loss 0.651441
# Epoch 400 | Train Loss 0.780709 | Val Loss 0.628295
# Epoch 500 | Train Loss 0.775149 | Val Loss 0.624917
# Epoch 600 | Train Loss 0.772544 | Val Loss 0.623230
# Epoch 700 | Train Loss 0.770577 | Val Loss 0.623516
# Early stopping at epoch 786
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed7069.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9940, MSE = 4.9782e-04
# Y | Train_2 -> R² = 0.9918, MSE = 8.8417e-04
# Y | Test_1 -> R² = 0.7837, MSE = 1.7696e-02
# Y | Test_2 -> R² = 0.9723, MSE = 2.9281e-03
# Y | Test_3 -> R² = 0.3264, MSE = 5.1655e-02
# Y | Val -> R² = 0.9557, MSE = 3.2963e-03
# Y | LSG_1 -> R² = 0.3666, MSE = 2.0057e-01
# Y | LSG_2 -> R² = 0.3958, MSE = 2.3287e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.632213 | Val Loss 0.801562
# Epoch 100 | Train Loss 1.137439 | Val Loss 0.934770
# Epoch 200 | Train Loss 0.915260 | Val Loss 0.768516
# Epoch 300 | Train Loss 0.811235 | Val Loss 0.662359
# Epoch 400 | Train Loss 0.782796 | Val Loss 0.645095
# Epoch 500 | Train Loss 0.777148 | Val Loss 0.651255
# Early stopping at epoch 545
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1815.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9806, MSE = 1.6267e-03
# Y | Train_2 -> R² = 0.9773, MSE = 2.4336e-03
# Y | Test_1 -> R² = 0.8494, MSE = 1.2323e-02
# Y | Test_2 -> R² = 0.9158, MSE = 8.9065e-03
# Y | Test_3 -> R² = -2.0073, MSE = 2.3062e-01
# Y | Val -> R² = 0.9051, MSE = 7.0599e-03
# Y | LSG_1 -> R² = 0.3804, MSE = 1.9621e-01
# Y | LSG_2 -> R² = 0.4310, MSE = 2.1929e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1815 salvo.
# Epoch 0 | Train Loss 1.257032 | Val Loss 0.823410
# Epoch 100 | Train Loss 0.645685 | Val Loss 0.873827
# Epoch 200 | Train Loss 0.408187 | Val Loss 0.652875
# Epoch 300 | Train Loss 0.398664 | Val Loss 0.643371
# Epoch 400 | Train Loss 0.394165 | Val Loss 0.629398
# Epoch 500 | Train Loss 0.391502 | Val Loss 0.624654
# Epoch 600 | Train Loss 0.389241 | Val Loss 0.623513
# Epoch 700 | Train Loss 0.387047 | Val Loss 0.625128
# Early stopping at epoch 747
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9935, MSE = 5.4140e-04
# Y | Train_2 -> R² = 0.9919, MSE = 8.7281e-04
# Y | Test_1 -> R² = 0.9451, MSE = 4.4928e-03
# Y | Test_2 -> R² = 0.9840, MSE = 1.6889e-03
# Y | Test_3 -> R² = -5.4328, MSE = 4.9331e-01
# Y | Val -> R² = 0.9670, MSE = 2.4575e-03
# Y | LSG_1 -> R² = -1.8893, MSE = 9.1490e-01
# Y | LSG_2 -> R² = -0.5800, MSE = 6.0895e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.272966 | Val Loss 0.819642
# Epoch 100 | Train Loss 0.660291 | Val Loss 0.872289
# Epoch 200 | Train Loss 0.415684 | Val Loss 0.648747
# Epoch 300 | Train Loss 0.397757 | Val Loss 0.630357
# Epoch 400 | Train Loss 0.392556 | Val Loss 0.628790
# Epoch 500 | Train Loss 0.389713 | Val Loss 0.623755
# Epoch 600 | Train Loss 0.387503 | Val Loss 0.619773
# Epoch 700 | Train Loss 0.385765 | Val Loss 0.619394
# Early stopping at epoch 790
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9935, MSE = 5.4106e-04
# Y | Train_2 -> R² = 0.9926, MSE = 7.9558e-04
# Y | Test_1 -> R² = 0.9653, MSE = 2.8384e-03
# Y | Test_2 -> R² = 0.9822, MSE = 1.8835e-03
# Y | Test_3 -> R² = -1.4820, MSE = 1.9033e-01
# Y | Val -> R² = 0.9020, MSE = 7.2894e-03
# Y | LSG_1 -> R² = 0.2329, MSE = 2.4288e-01
# Y | LSG_2 -> R² = 0.5599, MSE = 1.6963e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.277291 | Val Loss 0.768423
# Epoch 100 | Train Loss 0.676824 | Val Loss 0.912119
# Epoch 200 | Train Loss 0.414102 | Val Loss 0.635688
# Epoch 300 | Train Loss 0.397636 | Val Loss 0.639716
# Epoch 400 | Train Loss 0.392622 | Val Loss 0.633420
# Epoch 500 | Train Loss 0.389258 | Val Loss 0.627137
# Epoch 600 | Train Loss 0.386859 | Val Loss 0.625280
# Epoch 700 | Train Loss 0.384746 | Val Loss 0.626482
# Early stopping at epoch 734
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9930, MSE = 5.8159e-04
# Y | Train_2 -> R² = 0.9926, MSE = 7.9144e-04
# Y | Test_1 -> R² = 0.9565, MSE = 3.5565e-03
# Y | Test_2 -> R² = 0.9844, MSE = 1.6506e-03
# Y | Test_3 -> R² = -4.9364, MSE = 4.5524e-01
# Y | Val -> R² = 0.7834, MSE = 1.6109e-02
# Y | LSG_1 -> R² = -1.6091, MSE = 8.2615e-01
# Y | LSG_2 -> R² = -0.5321, MSE = 5.9048e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.410630 | Val Loss 0.904688
# Epoch 100 | Train Loss 0.752312 | Val Loss 0.951572
# Epoch 200 | Train Loss 0.419799 | Val Loss 0.645892
# Epoch 300 | Train Loss 0.398652 | Val Loss 0.635966
# Epoch 400 | Train Loss 0.393836 | Val Loss 0.632584
# Epoch 500 | Train Loss 0.391033 | Val Loss 0.631351
# Epoch 600 | Train Loss 0.389051 | Val Loss 0.631341
# Early stopping at epoch 613
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9921, MSE = 6.5906e-04
# Y | Train_2 -> R² = 0.9916, MSE = 8.9964e-04
# Y | Test_1 -> R² = 0.9643, MSE = 2.9188e-03
# Y | Test_2 -> R² = 0.9848, MSE = 1.6033e-03
# Y | Test_3 -> R² = -4.8294, MSE = 4.4703e-01
# Y | Val -> R² = 0.9212, MSE = 5.8573e-03
# Y | LSG_1 -> R² = -0.9890, MSE = 6.2981e-01
# Y | LSG_2 -> R² = -0.1482, MSE = 4.4255e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.220861 | Val Loss 0.775147
# Epoch 100 | Train Loss 0.686077 | Val Loss 0.881343
# Epoch 200 | Train Loss 0.434939 | Val Loss 0.658185
# Epoch 300 | Train Loss 0.400053 | Val Loss 0.631327
# Epoch 400 | Train Loss 0.394240 | Val Loss 0.618413
# Epoch 500 | Train Loss 0.390524 | Val Loss 0.614817
# Epoch 600 | Train Loss 0.387972 | Val Loss 0.615977
# Early stopping at epoch 697
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9931, MSE = 5.8114e-04
# Y | Train_2 -> R² = 0.9915, MSE = 9.1125e-04
# Y | Test_1 -> R² = 0.9685, MSE = 2.5748e-03
# Y | Test_2 -> R² = 0.9841, MSE = 1.6854e-03
# Y | Test_3 -> R² = -2.5692, MSE = 2.7371e-01
# Y | Val -> R² = 0.9207, MSE = 5.8989e-03
# Y | LSG_1 -> R² = -0.6715, MSE = 5.2928e-01
# Y | LSG_2 -> R² = 0.1000, MSE = 3.4686e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.238881 | Val Loss 0.810169
# Epoch 100 | Train Loss 0.646422 | Val Loss 0.859889
# Epoch 200 | Train Loss 0.419788 | Val Loss 0.646900
# Epoch 300 | Train Loss 0.401806 | Val Loss 0.631289
# Epoch 400 | Train Loss 0.396348 | Val Loss 0.619729
# Epoch 500 | Train Loss 0.392954 | Val Loss 0.617346
# Epoch 600 | Train Loss 0.390255 | Val Loss 0.615533
# Epoch 700 | Train Loss 0.388121 | Val Loss 0.612962
# Epoch 800 | Train Loss 0.386256 | Val Loss 0.612270
# Epoch 900 | Train Loss 0.384632 | Val Loss 0.613925
# Early stopping at epoch 934
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9934, MSE = 5.5458e-04
# Y | Train_2 -> R² = 0.9919, MSE = 8.6618e-04
# Y | Test_1 -> R² = 0.9761, MSE = 1.9561e-03
# Y | Test_2 -> R² = 0.9772, MSE = 2.4125e-03
# Y | Test_3 -> R² = -1.6848, MSE = 2.0588e-01
# Y | Val -> R² = 0.9784, MSE = 1.6078e-03
# Y | LSG_1 -> R² = -0.7236, MSE = 5.4578e-01
# Y | LSG_2 -> R² = 0.1434, MSE = 3.3016e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.214379 | Val Loss 0.803309
# Epoch 100 | Train Loss 0.662099 | Val Loss 0.850637
# Epoch 200 | Train Loss 0.408472 | Val Loss 0.640384
# Epoch 300 | Train Loss 0.396031 | Val Loss 0.628415
# Epoch 400 | Train Loss 0.392028 | Val Loss 0.619046
# Epoch 500 | Train Loss 0.389477 | Val Loss 0.615820
# Epoch 600 | Train Loss 0.387347 | Val Loss 0.617476
# Early stopping at epoch 652
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9934, MSE = 5.5467e-04
# Y | Train_2 -> R² = 0.9916, MSE = 9.0122e-04
# Y | Test_1 -> R² = 0.9642, MSE = 2.9300e-03
# Y | Test_2 -> R² = 0.9825, MSE = 1.8497e-03
# Y | Test_3 -> R² = -4.2460, MSE = 4.0229e-01
# Y | Val -> R² = 0.9482, MSE = 3.8526e-03
# Y | LSG_1 -> R² = -0.4696, MSE = 4.6536e-01
# Y | LSG_2 -> R² = 0.1901, MSE = 3.1216e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.361383 | Val Loss 0.811945
# Epoch 100 | Train Loss 0.722647 | Val Loss 0.916822
# Epoch 200 | Train Loss 0.416425 | Val Loss 0.651050
# Epoch 300 | Train Loss 0.399674 | Val Loss 0.643970
# Epoch 400 | Train Loss 0.395594 | Val Loss 0.638677
# Epoch 500 | Train Loss 0.393204 | Val Loss 0.631979
# Epoch 600 | Train Loss 0.391139 | Val Loss 0.628913
# Epoch 700 | Train Loss 0.389285 | Val Loss 0.627964
# Epoch 800 | Train Loss 0.387669 | Val Loss 0.628345
# Early stopping at epoch 884
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9931, MSE = 5.8056e-04
# Y | Train_2 -> R² = 0.9920, MSE = 8.6198e-04
# Y | Test_1 -> R² = 0.9500, MSE = 4.0929e-03
# Y | Test_2 -> R² = 0.9843, MSE = 1.6613e-03
# Y | Test_3 -> R² = -5.8330, MSE = 5.2399e-01
# Y | Val -> R² = 0.9094, MSE = 6.7362e-03
# Y | LSG_1 -> R² = -1.3685, MSE = 7.4997e-01
# Y | LSG_2 -> R² = -0.4194, MSE = 5.4707e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.339577 | Val Loss 0.809561
# Epoch 100 | Train Loss 0.672672 | Val Loss 0.879521
# Epoch 200 | Train Loss 0.428025 | Val Loss 0.656931
# Epoch 300 | Train Loss 0.400712 | Val Loss 0.632950
# Epoch 400 | Train Loss 0.393823 | Val Loss 0.631471
# Epoch 500 | Train Loss 0.390025 | Val Loss 0.622729
# Epoch 600 | Train Loss 0.387334 | Val Loss 0.618177
# Epoch 700 | Train Loss 0.385329 | Val Loss 0.618564
# Early stopping at epoch 799
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9935, MSE = 5.4242e-04
# Y | Train_2 -> R² = 0.9921, MSE = 8.4406e-04
# Y | Test_1 -> R² = 0.9468, MSE = 4.3536e-03
# Y | Test_2 -> R² = 0.9673, MSE = 3.4621e-03
# Y | Test_3 -> R² = -3.0555, MSE = 3.1100e-01
# Y | Val -> R² = 0.9299, MSE = 5.2105e-03
# Y | LSG_1 -> R² = -1.5004, MSE = 7.9173e-01
# Y | LSG_2 -> R² = -0.4108, MSE = 5.4373e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.280571 | Val Loss 0.814454
# Epoch 100 | Train Loss 0.692894 | Val Loss 0.889392
# Epoch 200 | Train Loss 0.437208 | Val Loss 0.660896
# Epoch 300 | Train Loss 0.404627 | Val Loss 0.645605
# Epoch 400 | Train Loss 0.397089 | Val Loss 0.628680
# Epoch 500 | Train Loss 0.392662 | Val Loss 0.618674
# Epoch 600 | Train Loss 0.389239 | Val Loss 0.614874
# Epoch 700 | Train Loss 0.386614 | Val Loss 0.613296
# Epoch 800 | Train Loss 0.384667 | Val Loss 0.616748
# Early stopping at epoch 845
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9937, MSE = 5.2590e-04
# Y | Train_2 -> R² = 0.9923, MSE = 8.2906e-04
# Y | Test_1 -> R² = 0.9764, MSE = 1.9300e-03
# Y | Test_2 -> R² = 0.9832, MSE = 1.7769e-03
# Y | Test_3 -> R² = -1.2187, MSE = 1.7014e-01
# Y | Val -> R² = 0.9870, MSE = 9.6473e-04
# Y | LSG_1 -> R² = -0.4144, MSE = 4.4786e-01
# Y | LSG_2 -> R² = 0.1659, MSE = 3.2149e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1815 salvo.
# Epoch 0 | Train Loss 1.613841 | Val Loss 0.787249
# Epoch 100 | Train Loss 1.067469 | Val Loss 0.904995
# Epoch 200 | Train Loss 0.833373 | Val Loss 0.674591
# Epoch 300 | Train Loss 0.781979 | Val Loss 0.624974
# Epoch 400 | Train Loss 0.772760 | Val Loss 0.623688
# Epoch 500 | Train Loss 0.769390 | Val Loss 0.622596
# Early stopping at epoch 526
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8552.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9921, MSE = 6.5734e-04
# Y | Train_2 -> R² = 0.9899, MSE = 1.0844e-03
# Y | Test_1 -> R² = 0.8991, MSE = 8.2574e-03
# Y | Test_2 -> R² = 0.9373, MSE = 6.6304e-03
# Y | Test_3 -> R² = -3.0217, MSE = 3.0841e-01
# Y | Val -> R² = 0.9365, MSE = 4.7259e-03
# Y | LSG_1 -> R² = -0.0242, MSE = 3.2431e-01
# Y | LSG_2 -> R² = 0.3027, MSE = 2.6877e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.576747 | Val Loss 0.817310
# Epoch 100 | Train Loss 1.089569 | Val Loss 0.900830
# Epoch 200 | Train Loss 0.807054 | Val Loss 0.651950
# Epoch 300 | Train Loss 0.777846 | Val Loss 0.624086
# Epoch 400 | Train Loss 0.771575 | Val Loss 0.615877
# Epoch 500 | Train Loss 0.768157 | Val Loss 0.613989
# Epoch 600 | Train Loss 0.764805 | Val Loss 0.613590
# Epoch 700 | Train Loss 0.761381 | Val Loss 0.613451
# Epoch 800 | Train Loss 0.757654 | Val Loss 0.614158
# Early stopping at epoch 818
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed6028.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9916, MSE = 7.0016e-04
# Y | Train_2 -> R² = 0.9926, MSE = 7.9815e-04
# Y | Test_1 -> R² = 0.9660, MSE = 2.7805e-03
# Y | Test_2 -> R² = 0.9905, MSE = 1.0085e-03
# Y | Test_3 -> R² = -3.6892, MSE = 3.5959e-01
# Y | Val -> R² = 0.9618, MSE = 2.8411e-03
# Y | LSG_1 -> R² = -1.3105, MSE = 7.3163e-01
# Y | LSG_2 -> R² = -0.2426, MSE = 4.7893e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.630448 | Val Loss 0.774298
# Epoch 100 | Train Loss 1.051590 | Val Loss 0.879730
# Epoch 200 | Train Loss 0.792646 | Val Loss 0.631556
# Epoch 300 | Train Loss 0.777933 | Val Loss 0.632130
# Epoch 400 | Train Loss 0.772637 | Val Loss 0.624641
# Epoch 500 | Train Loss 0.768340 | Val Loss 0.616425
# Epoch 600 | Train Loss 0.764972 | Val Loss 0.610730
# Epoch 700 | Train Loss 0.761854 | Val Loss 0.610223
# Early stopping at epoch 798
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed9770.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9914, MSE = 7.2031e-04
# Y | Train_2 -> R² = 0.9908, MSE = 9.8558e-04
# Y | Test_1 -> R² = 0.9677, MSE = 2.6422e-03
# Y | Test_2 -> R² = 0.9799, MSE = 2.1291e-03
# Y | Test_3 -> R² = -1.9680, MSE = 2.2761e-01
# Y | Val -> R² = 0.9767, MSE = 1.7352e-03
# Y | LSG_1 -> R² = -1.1749, MSE = 6.8868e-01
# Y | LSG_2 -> R² = -0.2738, MSE = 4.9096e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.689704 | Val Loss 0.851811
# Epoch 100 | Train Loss 1.121773 | Val Loss 0.935353
# Epoch 200 | Train Loss 0.798209 | Val Loss 0.639658
# Epoch 300 | Train Loss 0.777663 | Val Loss 0.631780
# Epoch 400 | Train Loss 0.773276 | Val Loss 0.624291
# Epoch 500 | Train Loss 0.769802 | Val Loss 0.621102
# Epoch 600 | Train Loss 0.766381 | Val Loss 0.621226
# Epoch 700 | Train Loss 0.763034 | Val Loss 0.622192
# Early stopping at epoch 709
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed7069.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9921, MSE = 6.5923e-04
# Y | Train_2 -> R² = 0.9916, MSE = 9.0175e-04
# Y | Test_1 -> R² = 0.9614, MSE = 3.1545e-03
# Y | Test_2 -> R² = 0.9850, MSE = 1.5847e-03
# Y | Test_3 -> R² = -5.3981, MSE = 4.9064e-01
# Y | Val -> R² = 0.9569, MSE = 3.2046e-03
# Y | LSG_1 -> R² = -0.6123, MSE = 5.1053e-01
# Y | LSG_2 -> R² = -0.0437, MSE = 4.0224e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.651178 | Val Loss 0.801102
# Epoch 100 | Train Loss 1.026766 | Val Loss 0.887294
# Epoch 200 | Train Loss 0.789698 | Val Loss 0.679519
# Epoch 300 | Train Loss 0.779130 | Val Loss 0.666551
# Epoch 400 | Train Loss 0.773685 | Val Loss 0.655925
# Epoch 500 | Train Loss 0.769601 | Val Loss 0.653372
# Epoch 600 | Train Loss 0.765871 | Val Loss 0.650227
# Epoch 700 | Train Loss 0.762571 | Val Loss 0.643720
# Epoch 800 | Train Loss 0.759475 | Val Loss 0.635984
# Epoch 900 | Train Loss 0.756224 | Val Loss 0.629188
# Epoch 1000 | Train Loss 0.752822 | Val Loss 0.624942
# Epoch 1100 | Train Loss 0.749331 | Val Loss 0.625863
# Early stopping at epoch 1180
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1815.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9927, MSE = 6.1256e-04
# Y | Train_2 -> R² = 0.9941, MSE = 6.2773e-04
# Y | Test_1 -> R² = 0.8793, MSE = 9.8739e-03
# Y | Test_2 -> R² = 0.9801, MSE = 2.1080e-03
# Y | Test_3 -> R² = -7.9267, MSE = 6.8455e-01
# Y | Val -> R² = 0.7573, MSE = 1.8052e-02
# Y | LSG_1 -> R² = -2.6454, MSE = 1.1543e+00
# Y | LSG_2 -> R² = -1.0838, MSE = 8.0313e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.600378 | Val Loss 0.824607
# Epoch 100 | Train Loss 1.042577 | Val Loss 0.871982
# Epoch 200 | Train Loss 0.809098 | Val Loss 0.647533
# Epoch 300 | Train Loss 0.779817 | Val Loss 0.631859
# Epoch 400 | Train Loss 0.773143 | Val Loss 0.629767
# Epoch 500 | Train Loss 0.768970 | Val Loss 0.621911
# Epoch 600 | Train Loss 0.765381 | Val Loss 0.614226
# Epoch 700 | Train Loss 0.762119 | Val Loss 0.612656
# Epoch 800 | Train Loss 0.759182 | Val Loss 0.615605
# Early stopping at epoch 836
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed8552.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9092e-04
# Y | Train_2 -> R² = 0.9914, MSE = 9.1829e-04
# Y | Test_1 -> R² = 0.9638, MSE = 2.9604e-03
# Y | Test_2 -> R² = 0.9873, MSE = 1.3453e-03
# Y | Test_3 -> R² = -2.3699, MSE = 2.5842e-01
# Y | Val -> R² = 0.9177, MSE = 6.1239e-03
# Y | LSG_1 -> R² = -1.2727, MSE = 7.1963e-01
# Y | LSG_2 -> R² = -0.4161, MSE = 5.4578e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.706860 | Val Loss 0.814017
# Epoch 100 | Train Loss 1.085558 | Val Loss 0.913624
# Epoch 200 | Train Loss 0.832670 | Val Loss 0.675825
# Epoch 300 | Train Loss 0.788706 | Val Loss 0.657258
# Epoch 400 | Train Loss 0.778772 | Val Loss 0.645406
# Epoch 500 | Train Loss 0.772236 | Val Loss 0.632599
# Epoch 600 | Train Loss 0.768118 | Val Loss 0.628713
# Epoch 700 | Train Loss 0.764941 | Val Loss 0.627851
# Epoch 800 | Train Loss 0.762471 | Val Loss 0.631120
# Early stopping at epoch 825
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed6028.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9939, MSE = 5.1356e-04
# Y | Train_2 -> R² = 0.9876, MSE = 1.3303e-03
# Y | Test_1 -> R² = 0.9206, MSE = 6.4947e-03
# Y | Test_2 -> R² = 0.9849, MSE = 1.5994e-03
# Y | Test_3 -> R² = -1.1525, MSE = 1.6507e-01
# Y | Val -> R² = 0.7358, MSE = 1.9644e-02
# Y | LSG_1 -> R² = -0.2104, MSE = 3.8326e-01
# Y | LSG_2 -> R² = 0.1652, MSE = 3.2174e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.657145 | Val Loss 0.805436
# Epoch 100 | Train Loss 1.084293 | Val Loss 0.907159
# Epoch 200 | Train Loss 0.793700 | Val Loss 0.671556
# Epoch 300 | Train Loss 0.780208 | Val Loss 0.654121
# Epoch 400 | Train Loss 0.773739 | Val Loss 0.638807
# Epoch 500 | Train Loss 0.769403 | Val Loss 0.638204
# Epoch 600 | Train Loss 0.766297 | Val Loss 0.641647
# Early stopping at epoch 633
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed9770.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9929, MSE = 5.9076e-04
# Y | Train_2 -> R² = 0.9900, MSE = 1.0757e-03
# Y | Test_1 -> R² = 0.9084, MSE = 7.4917e-03
# Y | Test_2 -> R² = 0.9848, MSE = 1.6020e-03
# Y | Test_3 -> R² = -8.9241, MSE = 7.6104e-01
# Y | Val -> R² = 0.5530, MSE = 3.3242e-02
# Y | LSG_1 -> R² = -2.4168, MSE = 1.0819e+00
# Y | LSG_2 -> R² = -1.1776, MSE = 8.3927e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.641535 | Val Loss 0.789145
# Epoch 100 | Train Loss 1.043158 | Val Loss 0.863527
# Epoch 200 | Train Loss 0.809285 | Val Loss 0.651187
# Epoch 300 | Train Loss 0.782302 | Val Loss 0.632889
# Epoch 400 | Train Loss 0.775459 | Val Loss 0.628295
# Epoch 500 | Train Loss 0.770758 | Val Loss 0.627374
# Epoch 600 | Train Loss 0.766573 | Val Loss 0.625547
# Epoch 700 | Train Loss 0.762998 | Val Loss 0.623330
# Epoch 800 | Train Loss 0.760041 | Val Loss 0.623092
# Early stopping at epoch 890
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed7069.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9920, MSE = 6.7308e-04
# Y | Train_2 -> R² = 0.9911, MSE = 9.5904e-04
# Y | Test_1 -> R² = 0.9169, MSE = 6.7957e-03
# Y | Test_2 -> R² = 0.9748, MSE = 2.6685e-03
# Y | Test_3 -> R² = -1.8842, MSE = 2.2117e-01
# Y | Val -> R² = 0.9332, MSE = 4.9713e-03
# Y | LSG_1 -> R² = 0.2362, MSE = 2.4184e-01
# Y | LSG_2 -> R² = 0.3651, MSE = 2.4470e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.618795 | Val Loss 0.790024
# Epoch 100 | Train Loss 1.030592 | Val Loss 0.856812
# Epoch 200 | Train Loss 0.798202 | Val Loss 0.647118
# Epoch 300 | Train Loss 0.779898 | Val Loss 0.637820
# Epoch 400 | Train Loss 0.771911 | Val Loss 0.626442
# Epoch 500 | Train Loss 0.767255 | Val Loss 0.618781
# Epoch 600 | Train Loss 0.763854 | Val Loss 0.615671
# Epoch 700 | Train Loss 0.760816 | Val Loss 0.615584
# Early stopping at epoch 773
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1815.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9931, MSE = 5.7393e-04
# Y | Train_2 -> R² = 0.9905, MSE = 1.0140e-03
# Y | Test_1 -> R² = 0.9552, MSE = 3.6639e-03
# Y | Test_2 -> R² = 0.9877, MSE = 1.2999e-03
# Y | Test_3 -> R² = -3.4432, MSE = 3.4073e-01
# Y | Val -> R² = 0.9442, MSE = 4.1508e-03
# Y | LSG_1 -> R² = -1.6145, MSE = 8.2786e-01
# Y | LSG_2 -> R² = -0.3988, MSE = 5.3913e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1815 salvo.
# Epoch 0 | Train Loss 1.261355 | Val Loss 0.767524
# Epoch 100 | Train Loss 0.488204 | Val Loss 0.759332
# Epoch 200 | Train Loss 0.398109 | Val Loss 0.639702
# Epoch 300 | Train Loss 0.392808 | Val Loss 0.630040
# Epoch 400 | Train Loss 0.389318 | Val Loss 0.619934
# Epoch 500 | Train Loss 0.386340 | Val Loss 0.618173
# Epoch 600 | Train Loss 0.383260 | Val Loss 0.618516
# Early stopping at epoch 631
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9932, MSE = 5.7093e-04
# Y | Train_2 -> R² = 0.9922, MSE = 8.3757e-04
# Y | Test_1 -> R² = 0.9468, MSE = 4.3533e-03
# Y | Test_2 -> R² = 0.9766, MSE = 2.4750e-03
# Y | Test_3 -> R² = -4.7626, MSE = 4.4191e-01
# Y | Val -> R² = 0.9483, MSE = 3.8444e-03
# Y | LSG_1 -> R² = -1.6671, MSE = 8.4452e-01
# Y | LSG_2 -> R² = -0.5116, MSE = 5.8258e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.478195 | Val Loss 0.853146
# Epoch 100 | Train Loss 0.535789 | Val Loss 0.818658
# Epoch 200 | Train Loss 0.402099 | Val Loss 0.663839
# Epoch 300 | Train Loss 0.395393 | Val Loss 0.645280
# Epoch 400 | Train Loss 0.391205 | Val Loss 0.631136
# Epoch 500 | Train Loss 0.388782 | Val Loss 0.630616
# Epoch 600 | Train Loss 0.386697 | Val Loss 0.634925
# Early stopping at epoch 614
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9936, MSE = 5.3642e-04
# Y | Train_2 -> R² = 0.9905, MSE = 1.0229e-03
# Y | Test_1 -> R² = 0.9355, MSE = 5.2762e-03
# Y | Test_2 -> R² = 0.9842, MSE = 1.6654e-03
# Y | Test_3 -> R² = -6.9189, MSE = 6.0727e-01
# Y | Val -> R² = 0.9506, MSE = 3.6722e-03
# Y | LSG_1 -> R² = -1.1280, MSE = 6.7381e-01
# Y | LSG_2 -> R² = -0.1746, MSE = 4.5270e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.495442 | Val Loss 0.862695
# Epoch 100 | Train Loss 0.514531 | Val Loss 0.771164
# Epoch 200 | Train Loss 0.403057 | Val Loss 0.655597
# Epoch 300 | Train Loss 0.394633 | Val Loss 0.635443
# Epoch 400 | Train Loss 0.390775 | Val Loss 0.626478
# Epoch 500 | Train Loss 0.388029 | Val Loss 0.624826
# Epoch 600 | Train Loss 0.385621 | Val Loss 0.624927
# Early stopping at epoch 641
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9934, MSE = 5.5172e-04
# Y | Train_2 -> R² = 0.9910, MSE = 9.7031e-04
# Y | Test_1 -> R² = 0.9161, MSE = 6.8613e-03
# Y | Test_2 -> R² = 0.9766, MSE = 2.4740e-03
# Y | Test_3 -> R² = -6.3706, MSE = 5.6522e-01
# Y | Val -> R² = 0.9636, MSE = 2.7076e-03
# Y | LSG_1 -> R² = -2.5889, MSE = 1.1364e+00
# Y | LSG_2 -> R² = -1.0059, MSE = 7.7311e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.440561 | Val Loss 0.845352
# Epoch 100 | Train Loss 0.586113 | Val Loss 0.831843
# Epoch 200 | Train Loss 0.406507 | Val Loss 0.657897
# Epoch 300 | Train Loss 0.396577 | Val Loss 0.652602
# Epoch 400 | Train Loss 0.392803 | Val Loss 0.637083
# Epoch 500 | Train Loss 0.389914 | Val Loss 0.631869
# Epoch 600 | Train Loss 0.386764 | Val Loss 0.628633
# Epoch 700 | Train Loss 0.383851 | Val Loss 0.629647
# Early stopping at epoch 771
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9936, MSE = 5.3883e-04
# Y | Train_2 -> R² = 0.9925, MSE = 7.9996e-04
# Y | Test_1 -> R² = 0.9186, MSE = 6.6620e-03
# Y | Test_2 -> R² = 0.9790, MSE = 2.2233e-03
# Y | Test_3 -> R² = -6.0013, MSE = 5.3690e-01
# Y | Val -> R² = 0.9668, MSE = 2.4677e-03
# Y | LSG_1 -> R² = -2.0714, MSE = 9.7254e-01
# Y | LSG_2 -> R² = -0.6966, MSE = 6.5391e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.374080 | Val Loss 0.842269
# Epoch 100 | Train Loss 0.527377 | Val Loss 0.799605
# Epoch 200 | Train Loss 0.402072 | Val Loss 0.659340
# Epoch 300 | Train Loss 0.392969 | Val Loss 0.637136
# Epoch 400 | Train Loss 0.388746 | Val Loss 0.628289
# Epoch 500 | Train Loss 0.385768 | Val Loss 0.632564
# Early stopping at epoch 575
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9934, MSE = 5.5155e-04
# Y | Train_2 -> R² = 0.9912, MSE = 9.4250e-04
# Y | Test_1 -> R² = 0.9152, MSE = 6.9354e-03
# Y | Test_2 -> R² = 0.9815, MSE = 1.9557e-03
# Y | Test_3 -> R² = -6.9189, MSE = 6.0726e-01
# Y | Val -> R² = 0.8625, MSE = 1.0225e-02
# Y | LSG_1 -> R² = -2.6561, MSE = 1.1577e+00
# Y | LSG_2 -> R² = -1.0916, MSE = 8.0614e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.327544 | Val Loss 0.773346
# Epoch 100 | Train Loss 0.506064 | Val Loss 0.749430
# Epoch 200 | Train Loss 0.398288 | Val Loss 0.638418
# Epoch 300 | Train Loss 0.392999 | Val Loss 0.622530
# Epoch 400 | Train Loss 0.389552 | Val Loss 0.614157
# Epoch 500 | Train Loss 0.386800 | Val Loss 0.614365
# Epoch 600 | Train Loss 0.384633 | Val Loss 0.617355
# Early stopping at epoch 613
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9930, MSE = 5.8221e-04
# Y | Train_2 -> R² = 0.9921, MSE = 8.4512e-04
# Y | Test_1 -> R² = 0.9498, MSE = 4.1033e-03
# Y | Test_2 -> R² = 0.9767, MSE = 2.4653e-03
# Y | Test_3 -> R² = -4.6047, MSE = 4.2980e-01
# Y | Val -> R² = 0.9660, MSE = 2.5303e-03
# Y | LSG_1 -> R² = -2.1266, MSE = 9.9001e-01
# Y | LSG_2 -> R² = -0.7187, MSE = 6.6240e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.467136 | Val Loss 0.807596
# Epoch 100 | Train Loss 0.502718 | Val Loss 0.796459
# Epoch 200 | Train Loss 0.400519 | Val Loss 0.665288
# Epoch 300 | Train Loss 0.393670 | Val Loss 0.641930
# Epoch 400 | Train Loss 0.390256 | Val Loss 0.634610
# Epoch 500 | Train Loss 0.387494 | Val Loss 0.634208
# Epoch 600 | Train Loss 0.384964 | Val Loss 0.637810
# Early stopping at epoch 614
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9934, MSE = 5.5609e-04
# Y | Train_2 -> R² = 0.9913, MSE = 9.3421e-04
# Y | Test_1 -> R² = 0.8370, MSE = 1.3335e-02
# Y | Test_2 -> R² = 0.9799, MSE = 2.1282e-03
# Y | Test_3 -> R² = -7.8232, MSE = 6.7662e-01
# Y | Val -> R² = 0.9289, MSE = 5.2866e-03
# Y | LSG_1 -> R² = -3.6809, MSE = 1.4822e+00
# Y | LSG_2 -> R² = -1.7463, MSE = 1.0584e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.368184 | Val Loss 0.829001
# Epoch 100 | Train Loss 0.506760 | Val Loss 0.792494
# Epoch 200 | Train Loss 0.402606 | Val Loss 0.660922
# Epoch 300 | Train Loss 0.394090 | Val Loss 0.635380
# Epoch 400 | Train Loss 0.390262 | Val Loss 0.628664
# Epoch 500 | Train Loss 0.387432 | Val Loss 0.631158
# Early stopping at epoch 562
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9934, MSE = 5.4813e-04
# Y | Train_2 -> R² = 0.9906, MSE = 1.0096e-03
# Y | Test_1 -> R² = 0.9213, MSE = 6.4399e-03
# Y | Test_2 -> R² = 0.9827, MSE = 1.8301e-03
# Y | Test_3 -> R² = -8.6236, MSE = 7.3799e-01
# Y | Val -> R² = 0.8523, MSE = 1.0983e-02
# Y | LSG_1 -> R² = -2.0304, MSE = 9.5957e-01
# Y | LSG_2 -> R² = -0.6011, MSE = 6.1710e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.316632 | Val Loss 0.792524
# Epoch 100 | Train Loss 0.468031 | Val Loss 0.805570
# Epoch 200 | Train Loss 0.401940 | Val Loss 0.661088
# Epoch 300 | Train Loss 0.394010 | Val Loss 0.631303
# Epoch 400 | Train Loss 0.390410 | Val Loss 0.628358
# Epoch 500 | Train Loss 0.387265 | Val Loss 0.630766
# Early stopping at epoch 560
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9929, MSE = 5.9111e-04
# Y | Train_2 -> R² = 0.9894, MSE = 1.1374e-03
# Y | Test_1 -> R² = 0.9348, MSE = 5.3343e-03
# Y | Test_2 -> R² = 0.9800, MSE = 2.1197e-03
# Y | Test_3 -> R² = -7.6540, MSE = 6.6364e-01
# Y | Val -> R² = 0.8803, MSE = 8.9032e-03
# Y | LSG_1 -> R² = -1.0029, MSE = 6.3420e-01
# Y | LSG_2 -> R² = -0.2270, MSE = 4.7289e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.457980 | Val Loss 0.813507
# Epoch 100 | Train Loss 0.451292 | Val Loss 0.814852
# Epoch 200 | Train Loss 0.403348 | Val Loss 0.668674
# Epoch 300 | Train Loss 0.395355 | Val Loss 0.643586
# Epoch 400 | Train Loss 0.391725 | Val Loss 0.636872
# Epoch 500 | Train Loss 0.388712 | Val Loss 0.635389
# Epoch 600 | Train Loss 0.385865 | Val Loss 0.633726
# Epoch 700 | Train Loss 0.383567 | Val Loss 0.632984
# ...
# weights/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9921, MSE = 6.5866e-04
# Y | Train_2 -> R² = 0.9673, MSE = 3.5035e-03
# Y | Test_1 -> R² = 0.9838, MSE = 1.3254e-03
# Y | Test_2 -> R² = 0.8869, MSE = 1.1955e-02
# Y | Test_3 -> R² = -3.3176, MSE = 3.3110e-01
# Y | Val -> R² = 0.8233, MSE = 1.3143e-02
# Y | LSG_1 -> R² = -0.8551, MSE = 5.8741e-01
# Y | LSG_2 -> R² = -0.2368, MSE = 4.7667e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=1815 salvo.
# Epoch 0 | Train Loss 1.191631 | Val Loss 0.852392
# Epoch 100 | Train Loss 0.391333 | Val Loss 0.633548
# Epoch 200 | Train Loss 0.383020 | Val Loss 0.636285
# Epoch 300 | Train Loss 0.374360 | Val Loss 0.656268
# Epoch 400 | Train Loss 0.368168 | Val Loss 0.674694
# Early stopping at epoch 415
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9820, MSE = 1.5046e-03
# Y | Train_2 -> R² = 0.6798, MSE = 3.4343e-02
# Y | Test_1 -> R² = 0.9386, MSE = 5.0249e-03
# Y | Test_2 -> R² = 0.5093, MSE = 5.1889e-02
# Y | Test_3 -> R² = -4.8968, MSE = 4.5220e-01
# Y | Val -> R² = 0.9303, MSE = 5.1859e-03
# Y | LSG_1 -> R² = -3.4015, MSE = 1.3937e+00
# Y | LSG_2 -> R² = -1.6523, MSE = 1.0222e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.240056 | Val Loss 0.839008
# Epoch 100 | Train Loss 0.390485 | Val Loss 0.621690
# Epoch 200 | Train Loss 0.381247 | Val Loss 0.630489
# Early stopping at epoch 291
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9926, MSE = 6.2254e-04
# Y | Train_2 -> R² = 0.9920, MSE = 8.5986e-04
# Y | Test_1 -> R² = 0.9361, MSE = 5.2257e-03
# Y | Test_2 -> R² = 0.9862, MSE = 1.4561e-03
# Y | Test_3 -> R² = -5.9538, MSE = 5.3325e-01
# Y | Val -> R² = 0.9038, MSE = 7.1531e-03
# Y | LSG_1 -> R² = -2.3844, MSE = 1.0717e+00
# Y | LSG_2 -> R² = -1.0441, MSE = 7.8784e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.115469 | Val Loss 0.931809
# Epoch 100 | Train Loss 0.389807 | Val Loss 0.619747
# Epoch 200 | Train Loss 0.382197 | Val Loss 0.624128
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9943, MSE = 4.7849e-04
# Y | Train_2 -> R² = 0.9881, MSE = 1.2779e-03
# Y | Test_1 -> R² = 0.9480, MSE = 4.2559e-03
# Y | Test_2 -> R² = 0.9814, MSE = 1.9642e-03
# Y | Test_3 -> R² = -6.2213, MSE = 5.5377e-01
# Y | Val -> R² = 0.9073, MSE = 6.8922e-03
# Y | LSG_1 -> R² = -2.4258, MSE = 1.0848e+00
# Y | LSG_2 -> R² = -1.1409, MSE = 8.2512e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.114440 | Val Loss 0.938043
# Epoch 100 | Train Loss 0.391618 | Val Loss 0.626121
# Epoch 200 | Train Loss 0.383024 | Val Loss 0.631483
# Epoch 300 | Train Loss 0.375315 | Val Loss 0.641003
# Early stopping at epoch 315
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9928, MSE = 6.0004e-04
# Y | Train_2 -> R² = 0.9911, MSE = 9.5990e-04
# Y | Test_1 -> R² = 0.9718, MSE = 2.3061e-03
# Y | Test_2 -> R² = 0.9822, MSE = 1.8786e-03
# Y | Test_3 -> R² = -7.3208, MSE = 6.3809e-01
# Y | Val -> R² = 0.7295, MSE = 2.0117e-02
# Y | LSG_1 -> R² = -2.9227, MSE = 1.2421e+00
# Y | LSG_2 -> R² = -1.5831, MSE = 9.9555e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.234358 | Val Loss 0.894369
# Epoch 100 | Train Loss 0.391399 | Val Loss 0.620498
# Epoch 200 | Train Loss 0.384476 | Val Loss 0.628109
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9943, MSE = 4.7948e-04
# Y | Train_2 -> R² = 0.9837, MSE = 1.7446e-03
# Y | Test_1 -> R² = 0.9716, MSE = 2.3259e-03
# Y | Test_2 -> R² = 0.9804, MSE = 2.0674e-03
# Y | Test_3 -> R² = -7.4159, MSE = 6.4538e-01
# Y | Val -> R² = 0.3855, MSE = 4.5695e-02
# Y | LSG_1 -> R² = -2.7949, MSE = 1.2017e+00
# Y | LSG_2 -> R² = -1.2594, MSE = 8.7080e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.173138 | Val Loss 0.878627
# Epoch 100 | Train Loss 0.390938 | Val Loss 0.625808
# Epoch 200 | Train Loss 0.383095 | Val Loss 0.637598
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8552.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9800, MSE = 1.6740e-03
# Y | Train_2 -> R² = 0.9834, MSE = 1.7839e-03
# Y | Test_1 -> R² = 0.9729, MSE = 2.2158e-03
# Y | Test_2 -> R² = 0.9828, MSE = 1.8225e-03
# Y | Test_3 -> R² = -5.9142, MSE = 5.3022e-01
# Y | Val -> R² = 0.6601, MSE = 2.5276e-02
# Y | LSG_1 -> R² = -3.3043, MSE = 1.3629e+00
# Y | LSG_2 -> R² = -1.5781, MSE = 9.9365e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.106075 | Val Loss 0.894223
# Epoch 100 | Train Loss 0.390178 | Val Loss 0.620093
# Epoch 200 | Train Loss 0.381998 | Val Loss 0.630195
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed6028.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9920, MSE = 6.6972e-04
# Y | Train_2 -> R² = 0.9902, MSE = 1.0472e-03
# Y | Test_1 -> R² = 0.9537, MSE = 3.7911e-03
# Y | Test_2 -> R² = 0.9846, MSE = 1.6244e-03
# Y | Test_3 -> R² = -5.3648, MSE = 4.8809e-01
# Y | Val -> R² = 0.9351, MSE = 4.8277e-03
# Y | LSG_1 -> R² = -2.2290, MSE = 1.0224e+00
# Y | LSG_2 -> R² = -0.9271, MSE = 7.4272e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.201532 | Val Loss 0.879079
# Epoch 100 | Train Loss 0.391537 | Val Loss 0.629980
# Epoch 200 | Train Loss 0.382934 | Val Loss 0.641751
# Epoch 300 | Train Loss 0.375951 | Val Loss 0.638989
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed9770.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9906, MSE = 7.8803e-04
# Y | Train_2 -> R² = 0.8282, MSE = 1.8433e-02
# Y | Test_1 -> R² = 0.8502, MSE = 1.2254e-02
# Y | Test_2 -> R² = 0.7484, MSE = 2.6604e-02
# Y | Test_3 -> R² = -7.9000, MSE = 6.8250e-01
# Y | Val -> R² = 0.7907, MSE = 1.5566e-02
# Y | LSG_1 -> R² = -4.6251, MSE = 1.7812e+00
# Y | LSG_2 -> R² = -2.3500, MSE = 1.2911e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.260982 | Val Loss 0.848202
# Epoch 100 | Train Loss 0.392478 | Val Loss 0.631690
# Epoch 200 | Train Loss 0.385792 | Val Loss 0.635507
# Epoch 300 | Train Loss 0.377255 | Val Loss 0.650002
# Early stopping at epoch 388
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7069.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9794, MSE = 1.7254e-03
# Y | Train_2 -> R² = 0.6522, MSE = 3.7308e-02
# Y | Test_1 -> R² = 0.9559, MSE = 3.6081e-03
# Y | Test_2 -> R² = 0.5308, MSE = 4.9617e-02
# Y | Test_3 -> R² = -7.7504, MSE = 6.7103e-01
# Y | Val -> R² = 0.8026, MSE = 1.4679e-02
# Y | LSG_1 -> R² = -4.3134, MSE = 1.6825e+00
# Y | LSG_2 -> R² = -2.3415, MSE = 1.2879e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.168917 | Val Loss 0.903920
# Epoch 100 | Train Loss 0.391703 | Val Loss 0.620016
# Epoch 200 | Train Loss 0.382854 | Val Loss 0.635091
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1815.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9927, MSE = 6.0703e-04
# Y | Train_2 -> R² = 0.9875, MSE = 1.3431e-03
# Y | Test_1 -> R² = 0.9261, MSE = 6.0467e-03
# Y | Test_2 -> R² = 0.9827, MSE = 1.8291e-03
# Y | Test_3 -> R² = -8.0166, MSE = 6.9145e-01
# Y | Val -> R² = 0.5907, MSE = 3.0440e-02
# Y | LSG_1 -> R² = -3.6006, MSE = 1.4568e+00
# Y | LSG_2 -> R² = -1.7829, MSE = 1.0726e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1815 salvo.
# Epoch 0 | Train Loss 1.495469 | Val Loss 0.864823
# Epoch 100 | Train Loss 0.769205 | Val Loss 0.630214
# Epoch 200 | Train Loss 0.755910 | Val Loss 0.626238
# Epoch 300 | Train Loss 0.742101 | Val Loss 0.645233
# Early stopping at epoch 336
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8552.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9862, MSE = 1.1542e-03
# Y | Train_2 -> R² = 0.9913, MSE = 9.3654e-04
# Y | Test_1 -> R² = 0.9744, MSE = 2.0949e-03
# Y | Test_2 -> R² = 0.9875, MSE = 1.3220e-03
# Y | Test_3 -> R² = -6.9929, MSE = 6.1294e-01
# Y | Val -> R² = 0.6816, MSE = 2.3675e-02
# Y | LSG_1 -> R² = -4.2062, MSE = 1.6485e+00
# Y | LSG_2 -> R² = -2.4432, MSE = 1.3271e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8552 salvo.
# Epoch 0 | Train Loss 1.523399 | Val Loss 0.878063
# Epoch 100 | Train Loss 0.768327 | Val Loss 0.635461
# Epoch 200 | Train Loss 0.757844 | Val Loss 0.617069
# Epoch 300 | Train Loss 0.749781 | Val Loss 0.619972
# Epoch 400 | Train Loss 0.739987 | Val Loss 0.633075
# Early stopping at epoch 438
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed6028.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9795, MSE = 1.7116e-03
# Y | Train_2 -> R² = 0.9873, MSE = 1.3643e-03
# Y | Test_1 -> R² = 0.9709, MSE = 2.3789e-03
# Y | Test_2 -> R² = 0.9691, MSE = 3.2670e-03
# Y | Test_3 -> R² = -3.6162, MSE = 3.5400e-01
# Y | Val -> R² = 0.8686, MSE = 9.7751e-03
# Y | LSG_1 -> R² = -1.9641, MSE = 9.3857e-01
# Y | LSG_2 -> R² = -1.0493, MSE = 7.8985e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=6028 salvo.
# Epoch 0 | Train Loss 1.571333 | Val Loss 0.906946
# Epoch 100 | Train Loss 0.769184 | Val Loss 0.623028
# Epoch 200 | Train Loss 0.756312 | Val Loss 0.621118
# Epoch 300 | Train Loss 0.743614 | Val Loss 0.630150
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed9770.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9927, MSE = 6.1199e-04
# Y | Train_2 -> R² = 0.9763, MSE = 2.5412e-03
# Y | Test_1 -> R² = 0.9354, MSE = 5.2841e-03
# Y | Test_2 -> R² = 0.9401, MSE = 6.3344e-03
# Y | Test_3 -> R² = -5.0808, MSE = 4.6631e-01
# Y | Val -> R² = 0.7529, MSE = 1.8380e-02
# Y | LSG_1 -> R² = -3.7252, MSE = 1.4962e+00
# Y | LSG_2 -> R² = -2.3185, MSE = 1.2790e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=9770 salvo.
# Epoch 0 | Train Loss 1.567057 | Val Loss 0.845031
# Epoch 100 | Train Loss 0.769747 | Val Loss 0.631235
# Epoch 200 | Train Loss 0.758362 | Val Loss 0.631836
# Epoch 300 | Train Loss 0.745873 | Val Loss 0.662263
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7069.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9938, MSE = 5.2167e-04
# Y | Train_2 -> R² = 0.5952, MSE = 4.3423e-02
# Y | Test_1 -> R² = 0.9562, MSE = 3.5825e-03
# Y | Test_2 -> R² = 0.5193, MSE = 5.0825e-02
# Y | Test_3 -> R² = -7.3594, MSE = 6.4104e-01
# Y | Val -> R² = 0.8550, MSE = 1.0786e-02
# Y | LSG_1 -> R² = -4.9868, MSE = 1.8957e+00
# Y | LSG_2 -> R² = -2.8423, MSE = 1.4809e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7069 salvo.
# Epoch 0 | Train Loss 1.477379 | Val Loss 1.004401
# Epoch 100 | Train Loss 0.769151 | Val Loss 0.633510
# Epoch 200 | Train Loss 0.757984 | Val Loss 0.625276
# Epoch 300 | Train Loss 0.748646 | Val Loss 0.649265
# Early stopping at epoch 339
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1815.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9932, MSE = 5.6633e-04
# Y | Train_2 -> R² = 0.8971, MSE = 1.1038e-02
# Y | Test_1 -> R² = 0.8968, MSE = 8.4402e-03
# Y | Test_2 -> R² = 0.8698, MSE = 1.3767e-02
# Y | Test_3 -> R² = -7.4752, MSE = 6.4993e-01
# Y | Val -> R² = 0.7383, MSE = 1.9460e-02
# Y | LSG_1 -> R² = -3.9527, MSE = 1.5683e+00
# Y | LSG_2 -> R² = -2.0310, MSE = 1.1682e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1815 salvo.
# Epoch 0 | Train Loss 1.567022 | Val Loss 0.832868
# Epoch 100 | Train Loss 0.769865 | Val Loss 0.616180
# Epoch 200 | Train Loss 0.757860 | Val Loss 0.608996
# Epoch 300 | Train Loss 0.749739 | Val Loss 0.616331
# Early stopping at epoch 367
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8552.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8552.weights.h5
# Y | Train_1 -> R² = 0.9941, MSE = 4.9510e-04
# Y | Train_2 -> R² = 0.8587, MSE = 1.5155e-02
# Y | Test_1 -> R² = 0.8593, MSE = 1.1509e-02
# Y | Test_2 -> R² = 0.8233, MSE = 1.8681e-02
# Y | Test_3 -> R² = -6.0334, MSE = 5.3936e-01
# Y | Val -> R² = 0.8275, MSE = 1.2831e-02
# Y | LSG_1 -> R² = -3.7749, MSE = 1.5120e+00
# Y | LSG_2 -> R² = -1.9310, MSE = 1.1297e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8552 salvo.
# Epoch 0 | Train Loss 1.530300 | Val Loss 0.869943
# Epoch 100 | Train Loss 0.767930 | Val Loss 0.621701
# Epoch 200 | Train Loss 0.755899 | Val Loss 0.616962
# Epoch 300 | Train Loss 0.745242 | Val Loss 0.619492
# Early stopping at epoch 379
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed6028.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed6028.weights.h5
# Y | Train_1 -> R² = 0.9767, MSE = 1.9484e-03
# Y | Train_2 -> R² = 0.8618, MSE = 1.4821e-02
# Y | Test_1 -> R² = 0.9538, MSE = 3.7766e-03
# Y | Test_2 -> R² = 0.8107, MSE = 2.0014e-02
# Y | Test_3 -> R² = -5.0935, MSE = 4.6728e-01
# Y | Val -> R² = 0.7797, MSE = 1.6380e-02
# Y | LSG_1 -> R² = -2.7040, MSE = 1.1729e+00
# Y | LSG_2 -> R² = -1.3875, MSE = 9.2019e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=6028 salvo.
# Epoch 0 | Train Loss 1.562630 | Val Loss 0.870185
# Epoch 100 | Train Loss 0.768215 | Val Loss 0.633800
# Epoch 200 | Train Loss 0.754676 | Val Loss 0.629139
# Early stopping at epoch 268
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed9770.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed9770.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9794e-04
# Y | Train_2 -> R² = 0.9841, MSE = 1.7032e-03
# Y | Test_1 -> R² = 0.9031, MSE = 7.9237e-03
# Y | Test_2 -> R² = 0.9851, MSE = 1.5779e-03
# Y | Test_3 -> R² = -9.5147, MSE = 8.0633e-01
# Y | Val -> R² = 0.6866, MSE = 2.3308e-02
# Y | LSG_1 -> R² = -4.7360, MSE = 1.8163e+00
# Y | LSG_2 -> R² = -2.7967, MSE = 1.4633e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=9770 salvo.
# Epoch 0 | Train Loss 1.523163 | Val Loss 0.921019
# Epoch 100 | Train Loss 0.769232 | Val Loss 0.636901
# Epoch 200 | Train Loss 0.757351 | Val Loss 0.633196
# Early stopping at epoch 268
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7069.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7069.weights.h5
# Y | Train_1 -> R² = 0.9816, MSE = 1.5353e-03
# Y | Train_2 -> R² = 0.9784, MSE = 2.3199e-03
# Y | Test_1 -> R² = 0.9569, MSE = 3.5228e-03
# Y | Test_2 -> R² = 0.9808, MSE = 2.0292e-03
# Y | Test_3 -> R² = -8.1405, MSE = 7.0094e-01
# Y | Val -> R² = 0.6909, MSE = 2.2990e-02
# Y | LSG_1 -> R² = -7.0869, MSE = 2.5607e+00
# Y | LSG_2 -> R² = -4.0663, MSE = 1.9526e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7069 salvo.
# Epoch 0 | Train Loss 1.474014 | Val Loss 0.979600
# Epoch 100 | Train Loss 0.769685 | Val Loss 0.628599
# Epoch 200 | Train Loss 0.757860 | Val Loss 0.628392
# Early stopping at epoch 268
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1815.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1815.weights.h5
# Y | Train_1 -> R² = 0.9943, MSE = 4.8087e-04
# Y | Train_2 -> R² = 0.9702, MSE = 3.1977e-03
# Y | Test_1 -> R² = 0.9616, MSE = 3.1384e-03
# Y | Test_2 -> R² = 0.9704, MSE = 3.1282e-03
# Y | Test_3 -> R² = -9.5325, MSE = 8.0769e-01
# Y | Val -> R² = 0.3465, MSE = 4.8598e-02
# Y | LSG_1 -> R² = -3.9358, MSE = 1.5629e+00
# Y | LSG_2 -> R² = -2.1663, MSE = 1.2203e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1815 salvo.
