# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "sin(Theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "sinTheta"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./Data/Theta.xlsx", sheet_name=title)

    df["Theta_ens"] = df_theta["Theta_ens"]

    df["cosTheta"] = np.cos(df["Theta_ens"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1935, 3, 5)
# Dimensão da saida: (1935, 1)
# Dimensão da entrada: (1261, 3, 5)
# Dimensão da saida: (1261, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1935, 3, 5)
# Dimensão da saida: (1935, 1)
# Dimensão da entrada fisica : (1935,)
# Dimensão da entrada fisica: (1935,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)
    return [dy_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 1.216697 | Val Loss 0.800936
# Epoch 100 | Train Loss 0.732294 | Val Loss 0.919891
# Epoch 200 | Train Loss 0.492539 | Val Loss 0.691897
# Epoch 300 | Train Loss 0.414362 | Val Loss 0.627223
# Epoch 400 | Train Loss 0.399075 | Val Loss 0.605347
# Epoch 500 | Train Loss 0.395264 | Val Loss 0.608719
# Early stopping at epoch 592
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9923, MSE = 6.4382e-04
# Y | Train_2 -> R² = 0.9911, MSE = 9.5303e-04
# Y | Test_1 -> R² = 0.9701, MSE = 2.4422e-03
# Y | Test_2 -> R² = 0.9805, MSE = 2.0577e-03
# Y | Test_3 -> R² = -3.6622, MSE = 3.5683e-01
# Y | Val -> R² = 0.5601, MSE = 3.2664e-02
# Y | LSG_1 -> R² = -0.5217, MSE = 4.8368e-01
# Y | LSG_2 -> R² = 0.0267, MSE = 3.7671e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.232706 | Val Loss 0.794420
# Epoch 100 | Train Loss 0.740509 | Val Loss 0.937457
# Epoch 200 | Train Loss 0.519689 | Val Loss 0.720034
# Epoch 300 | Train Loss 0.426884 | Val Loss 0.634086
# Epoch 400 | Train Loss 0.401108 | Val Loss 0.634748
# Epoch 500 | Train Loss 0.395739 | Val Loss 0.634956
# Early stopping at epoch 525
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9728, MSE = 2.2674e-03
# Y | Train_2 -> R² = 0.9751, MSE = 2.6553e-03
# Y | Test_1 -> R² = 0.8910, MSE = 8.8974e-03
# Y | Test_2 -> R² = 0.9459, MSE = 5.6957e-03
# Y | Test_3 -> R² = -3.8045, MSE = 3.6772e-01
# Y | Val -> R² = 0.5478, MSE = 3.3580e-02
# Y | LSG_1 -> R² = 0.1705, MSE = 2.6365e-01
# Y | LSG_2 -> R² = 0.3779, MSE = 2.4076e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.222680 | Val Loss 0.769487
# Epoch 100 | Train Loss 0.723839 | Val Loss 0.930742
# Epoch 200 | Train Loss 0.501769 | Val Loss 0.694572
# Epoch 300 | Train Loss 0.458073 | Val Loss 0.670868
# Epoch 400 | Train Loss 0.433980 | Val Loss 0.648372
# Epoch 500 | Train Loss 0.407906 | Val Loss 0.624947
# Epoch 600 | Train Loss 0.396998 | Val Loss 0.626556
# Epoch 700 | Train Loss 0.394053 | Val Loss 0.628145
# Early stopping at epoch 710
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9765, MSE = 1.9594e-03
# Y | Train_2 -> R² = 0.9906, MSE = 9.9895e-04
# Y | Test_1 -> R² = 0.9552, MSE = 3.6587e-03
# Y | Test_2 -> R² = 0.9808, MSE = 2.0261e-03
# Y | Test_3 -> R² = -2.6205, MSE = 2.7710e-01
# Y | Val -> R² = -0.0178, MSE = 7.5579e-02
# Y | LSG_1 -> R² = -0.5607, MSE = 4.9608e-01
# Y | LSG_2 -> R² = -0.0733, MSE = 4.1540e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.210577 | Val Loss 0.809940
# Epoch 100 | Train Loss 0.771882 | Val Loss 0.930779
# Epoch 200 | Train Loss 0.520793 | Val Loss 0.719482
# Epoch 300 | Train Loss 0.448476 | Val Loss 0.659150
# Epoch 400 | Train Loss 0.407941 | Val Loss 0.628346
# Epoch 500 | Train Loss 0.397378 | Val Loss 0.633844
# Early stopping at epoch 584
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9792, MSE = 1.7385e-03
# Y | Train_2 -> R² = 0.9809, MSE = 2.0352e-03
# Y | Test_1 -> R² = 0.9626, MSE = 3.0519e-03
# Y | Test_2 -> R² = 0.9533, MSE = 4.9130e-03
# Y | Test_3 -> R² = -2.9802, MSE = 3.0463e-01
# Y | Val -> R² = 0.6120, MSE = 2.8810e-02
# Y | LSG_1 -> R² = -0.5046, MSE = 4.7824e-01
# Y | LSG_2 -> R² = 0.0001, MSE = 3.8701e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.237699 | Val Loss 0.786780
# Epoch 100 | Train Loss 0.760191 | Val Loss 0.928410
# Epoch 200 | Train Loss 0.508279 | Val Loss 0.690874
# Epoch 300 | Train Loss 0.425823 | Val Loss 0.639501
# Epoch 400 | Train Loss 0.401608 | Val Loss 0.622945
# Epoch 500 | Train Loss 0.395242 | Val Loss 0.630145
# Early stopping at epoch 561
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.9870, MSE = 1.0886e-03
# Y | Train_2 -> R² = 0.9857, MSE = 1.5256e-03
# Y | Test_1 -> R² = 0.7393, MSE = 2.1275e-02
# Y | Test_2 -> R² = 0.9591, MSE = 4.3051e-03
# Y | Test_3 -> R² = -2.7922, MSE = 2.9024e-01
# Y | Val -> R² = 0.8326, MSE = 1.2429e-02
# Y | LSG_1 -> R² = 0.5962, MSE = 1.2835e-01
# Y | LSG_2 -> R² = 0.5661, MSE = 1.6793e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.235621 | Val Loss 0.792893
# Epoch 100 | Train Loss 0.784250 | Val Loss 0.962276
# Epoch 200 | Train Loss 0.568673 | Val Loss 0.762776
# Epoch 300 | Train Loss 0.441515 | Val Loss 0.649823
# Epoch 400 | Train Loss 0.407881 | Val Loss 0.630132
# Epoch 500 | Train Loss 0.399370 | Val Loss 0.613099
# Epoch 600 | Train Loss 0.395385 | Val Loss 0.611981
# Epoch 700 | Train Loss 0.393093 | Val Loss 0.613055
# Early stopping at epoch 727
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9907, MSE = 7.7539e-04
# Y | Train_2 -> R² = 0.9919, MSE = 8.6412e-04
# Y | Test_1 -> R² = 0.8838, MSE = 9.4779e-03
# Y | Test_2 -> R² = 0.9801, MSE = 2.0972e-03
# Y | Test_3 -> R² = -1.0881, MSE = 1.5981e-01
# Y | Val -> R² = 0.7481, MSE = 1.8708e-02
# Y | LSG_1 -> R² = 0.2300, MSE = 2.4477e-01
# Y | LSG_2 -> R² = 0.3577, MSE = 2.4858e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.222075 | Val Loss 0.801589
# Epoch 100 | Train Loss 0.763995 | Val Loss 0.962391
# Epoch 200 | Train Loss 0.575805 | Val Loss 0.787723
# Epoch 300 | Train Loss 0.423327 | Val Loss 0.631982
# Epoch 400 | Train Loss 0.404717 | Val Loss 0.640383
# Epoch 500 | Train Loss 0.399100 | Val Loss 0.641998
# Early stopping at epoch 510
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9311, MSE = 5.7554e-03
# Y | Train_2 -> R² = 0.9782, MSE = 2.3260e-03
# Y | Test_1 -> R² = 0.9634, MSE = 2.9851e-03
# Y | Test_2 -> R² = 0.9626, MSE = 3.9397e-03
# Y | Test_3 -> R² = -4.6472, MSE = 4.3222e-01
# Y | Val -> R² = -0.0736, MSE = 7.9724e-02
# Y | LSG_1 -> R² = -0.7309, MSE = 5.5018e-01
# Y | LSG_2 -> R² = -0.5107, MSE = 5.8468e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.177909 | Val Loss 0.768605
# Epoch 100 | Train Loss 0.720834 | Val Loss 0.939643
# Epoch 200 | Train Loss 0.509509 | Val Loss 0.717785
# Epoch 300 | Train Loss 0.430712 | Val Loss 0.636070
# Epoch 400 | Train Loss 0.400114 | Val Loss 0.625618
# Epoch 500 | Train Loss 0.395644 | Val Loss 0.630130
# Early stopping at epoch 565
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9923, MSE = 6.4018e-04
# Y | Train_2 -> R² = 0.9681, MSE = 3.4026e-03
# Y | Test_1 -> R² = 0.9796, MSE = 1.6665e-03
# Y | Test_2 -> R² = 0.9636, MSE = 3.8272e-03
# Y | Test_3 -> R² = -4.0750, MSE = 3.8842e-01
# Y | Val -> R² = 0.7744, MSE = 1.6756e-02
# Y | LSG_1 -> R² = -0.6272, MSE = 5.1723e-01
# Y | LSG_2 -> R² = 0.0185, MSE = 3.7987e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.203441 | Val Loss 0.802809
# Epoch 100 | Train Loss 0.739948 | Val Loss 0.905520
# Epoch 200 | Train Loss 0.491616 | Val Loss 0.686097
# Epoch 300 | Train Loss 0.416823 | Val Loss 0.627095
# Epoch 400 | Train Loss 0.397963 | Val Loss 0.618874
# Epoch 500 | Train Loss 0.393665 | Val Loss 0.621653
# Early stopping at epoch 575
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9906, MSE = 7.8855e-04
# Y | Train_2 -> R² = 0.9914, MSE = 9.1804e-04
# Y | Test_1 -> R² = 0.8344, MSE = 1.3516e-02
# Y | Test_2 -> R² = 0.9686, MSE = 3.3086e-03
# Y | Test_3 -> R² = -2.3913, MSE = 2.5956e-01
# Y | Val -> R² = 0.8001, MSE = 1.4846e-02
# Y | LSG_1 -> R² = 0.3346, MSE = 2.1149e-01
# Y | LSG_2 -> R² = 0.4645, MSE = 2.0726e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.259924 | Val Loss 0.801957
# Epoch 100 | Train Loss 0.788641 | Val Loss 0.954017
# Epoch 200 | Train Loss 0.578402 | Val Loss 0.775867
# Epoch 300 | Train Loss 0.436998 | Val Loss 0.652424
# Epoch 400 | Train Loss 0.402855 | Val Loss 0.657294
# Epoch 500 | Train Loss 0.396229 | Val Loss 0.658619
# Early stopping at epoch 514
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.8721, MSE = 1.0676e-02
# Y | Train_2 -> R² = 0.9663, MSE = 3.6022e-03
# Y | Test_1 -> R² = 0.8798, MSE = 9.8092e-03
# Y | Test_2 -> R² = 0.9388, MSE = 6.4393e-03
# Y | Test_3 -> R² = -2.6221, MSE = 2.7722e-01
# Y | Val -> R² = 0.5438, MSE = 3.3875e-02
# Y | LSG_1 -> R² = 0.1862, MSE = 2.5867e-01
# Y | LSG_2 -> R² = 0.2815, MSE = 2.7809e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=421 salvo.
# Epoch 0 | Train Loss 1.558830 | Val Loss 0.800672
# Epoch 100 | Train Loss 1.125895 | Val Loss 0.933722
# Epoch 200 | Train Loss 0.865188 | Val Loss 0.700503
# Epoch 300 | Train Loss 0.800336 | Val Loss 0.672922
# Epoch 400 | Train Loss 0.782451 | Val Loss 0.686219
# Early stopping at epoch 453
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed3631.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed3631.weights.h5
# Y | Train_1 -> R² = 0.4829, MSE = 4.3166e-02
# Y | Train_2 -> R² = 0.9572, MSE = 4.5685e-03
# Y | Test_1 -> R² = 0.9102, MSE = 7.3249e-03
# Y | Test_2 -> R² = 0.9296, MSE = 7.4113e-03
# Y | Test_3 -> R² = -1.2869, MSE = 1.7503e-01
# Y | Val -> R² = 0.6581, MSE = 2.5389e-02
# Y | LSG_1 -> R² = 0.0343, MSE = 3.0696e-01
# Y | LSG_2 -> R² = 0.1330, MSE = 3.3555e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.623381 | Val Loss 0.799685
# Epoch 100 | Train Loss 1.124890 | Val Loss 0.942825
# Epoch 200 | Train Loss 0.978679 | Val Loss 0.800203
# Epoch 300 | Train Loss 0.863758 | Val Loss 0.686683
# Epoch 400 | Train Loss 0.811116 | Val Loss 0.650629
# Epoch 500 | Train Loss 0.783731 | Val Loss 0.627649
# Epoch 600 | Train Loss 0.773631 | Val Loss 0.625023
# Epoch 700 | Train Loss 0.769586 | Val Loss 0.620398
# Epoch 800 | Train Loss 0.767208 | Val Loss 0.615985
# Epoch 900 | Train Loss 0.765260 | Val Loss 0.612659
# Epoch 1000 | Train Loss 0.763561 | Val Loss 0.610409
# Epoch 1100 | Train Loss 0.762062 | Val Loss 0.608965
# Epoch 1200 | Train Loss 0.760685 | Val Loss 0.608046
# Epoch 1300 | Train Loss 0.759321 | Val Loss 0.607364
# Epoch 1400 | Train Loss 0.757850 | Val Loss 0.606646
# Epoch 1500 | Train Loss 0.756191 | Val Loss 0.605998
# Epoch 1600 | Train Loss 0.754286 | Val Loss 0.606371
# Early stopping at epoch 1622
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed7576.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9915, MSE = 7.1008e-04
# Y | Train_2 -> R² = 0.9947, MSE = 5.7109e-04
# Y | Test_1 -> R² = 0.8045, MSE = 1.5950e-02
# Y | Test_2 -> R² = 0.9640, MSE = 3.7879e-03
# Y | Test_3 -> R² = 0.5212, MSE = 3.6644e-02
# Y | Val -> R² = 0.9686, MSE = 2.3335e-03
# Y | LSG_1 -> R² = -0.0372, MSE = 3.2969e-01
# Y | LSG_2 -> R² = 0.2142, MSE = 3.0412e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.534059 | Val Loss 0.765947
# Epoch 100 | Train Loss 1.121484 | Val Loss 0.972451
# Epoch 200 | Train Loss 0.925386 | Val Loss 0.746200
# Epoch 300 | Train Loss 0.829818 | Val Loss 0.657647
# Epoch 400 | Train Loss 0.781502 | Val Loss 0.626899
# Epoch 500 | Train Loss 0.772081 | Val Loss 0.632683
# Early stopping at epoch 586
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed9426.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9692, MSE = 2.5724e-03
# Y | Train_2 -> R² = 0.9871, MSE = 1.3785e-03
# Y | Test_1 -> R² = 0.8441, MSE = 1.2720e-02
# Y | Test_2 -> R² = 0.8925, MSE = 1.1314e-02
# Y | Test_3 -> R² = -1.9130, MSE = 2.2295e-01
# Y | Val -> R² = 0.6612, MSE = 2.5155e-02
# Y | LSG_1 -> R² = 0.1773, MSE = 2.6149e-01
# Y | LSG_2 -> R² = 0.3031, MSE = 2.6973e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.537444 | Val Loss 0.795727
# Epoch 100 | Train Loss 1.082319 | Val Loss 0.935214
# Epoch 200 | Train Loss 0.886548 | Val Loss 0.703996
# Epoch 300 | Train Loss 0.805070 | Val Loss 0.643972
# Epoch 400 | Train Loss 0.783721 | Val Loss 0.620009
# Epoch 500 | Train Loss 0.775695 | Val Loss 0.618656
# Epoch 600 | Train Loss 0.770652 | Val Loss 0.636201
# Early stopping at epoch 645
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed2664.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9881, MSE = 9.9043e-04
# Y | Train_2 -> R² = 0.9914, MSE = 9.1703e-04
# Y | Test_1 -> R² = 0.8446, MSE = 1.2682e-02
# Y | Test_2 -> R² = 0.9638, MSE = 3.8143e-03
# Y | Test_3 -> R² = -2.2438, MSE = 2.4827e-01
# Y | Val -> R² = 0.7044, MSE = 2.1950e-02
# Y | LSG_1 -> R² = 0.2336, MSE = 2.4360e-01
# Y | LSG_2 -> R² = 0.3901, MSE = 2.3606e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.638892 | Val Loss 0.796486
# Epoch 100 | Train Loss 1.132856 | Val Loss 0.933074
# Epoch 200 | Train Loss 0.870421 | Val Loss 0.693433
# Epoch 300 | Train Loss 0.806135 | Val Loss 0.642646
# Epoch 400 | Train Loss 0.782847 | Val Loss 0.618143
# Epoch 500 | Train Loss 0.776058 | Val Loss 0.610241
# Epoch 600 | Train Loss 0.772371 | Val Loss 0.606254
# Epoch 700 | Train Loss 0.769940 | Val Loss 0.604814
# Epoch 800 | Train Loss 0.768031 | Val Loss 0.603997
# Epoch 900 | Train Loss 0.766385 | Val Loss 0.603252
# Epoch 1000 | Train Loss 0.764845 | Val Loss 0.602770
# Epoch 1100 | Train Loss 0.763346 | Val Loss 0.602951
# Early stopping at epoch 1168
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9906, MSE = 7.8165e-04
# Y | Train_2 -> R² = 0.9922, MSE = 8.3704e-04
# Y | Test_1 -> R² = 0.9736, MSE = 2.1559e-03
# Y | Test_2 -> R² = 0.9905, MSE = 9.9694e-04
# Y | Test_3 -> R² = -1.0560, MSE = 1.5736e-01
# Y | Val -> R² = 0.8179, MSE = 1.3521e-02
# Y | LSG_1 -> R² = -0.6395, MSE = 5.2113e-01
# Y | LSG_2 -> R² = -0.1706, MSE = 4.5306e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.609672 | Val Loss 0.806559
# Epoch 100 | Train Loss 1.145613 | Val Loss 0.955789
# Epoch 200 | Train Loss 0.966234 | Val Loss 0.788810
# Epoch 300 | Train Loss 0.868605 | Val Loss 0.689332
# Epoch 400 | Train Loss 0.831304 | Val Loss 0.648542
# Epoch 500 | Train Loss 0.792112 | Val Loss 0.625239
# Epoch 600 | Train Loss 0.774066 | Val Loss 0.639421
# Early stopping at epoch 669
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed3631.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9526, MSE = 3.9595e-03
# Y | Train_2 -> R² = 0.9843, MSE = 1.6752e-03
# Y | Test_1 -> R² = 0.9519, MSE = 3.9280e-03
# Y | Test_2 -> R² = 0.9732, MSE = 2.8173e-03
# Y | Test_3 -> R² = -2.1503, MSE = 2.4111e-01
# Y | Val -> R² = 0.6549, MSE = 2.5629e-02
# Y | LSG_1 -> R² = -0.5640, MSE = 4.9714e-01
# Y | LSG_2 -> R² = -0.1673, MSE = 4.5177e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.579164 | Val Loss 0.823563
# Epoch 100 | Train Loss 1.136901 | Val Loss 0.943363
# Epoch 200 | Train Loss 0.905086 | Val Loss 0.719826
# Epoch 300 | Train Loss 0.823896 | Val Loss 0.653836
# Epoch 400 | Train Loss 0.787861 | Val Loss 0.626002
# Epoch 500 | Train Loss 0.777280 | Val Loss 0.617114
# Epoch 600 | Train Loss 0.772615 | Val Loss 0.611406
# Epoch 700 | Train Loss 0.769833 | Val Loss 0.607856
# Epoch 800 | Train Loss 0.767722 | Val Loss 0.604389
# Epoch 900 | Train Loss 0.765893 | Val Loss 0.602017
# Epoch 1000 | Train Loss 0.764102 | Val Loss 0.601499
# Epoch 1100 | Train Loss 0.762182 | Val Loss 0.602889
# Early stopping at epoch 1147
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed7576.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9920, MSE = 6.6402e-04
# Y | Train_2 -> R² = 0.9920, MSE = 8.5827e-04
# Y | Test_1 -> R² = 0.8974, MSE = 8.3740e-03
# Y | Test_2 -> R² = 0.9399, MSE = 6.3230e-03
# Y | Test_3 -> R² = -0.4195, MSE = 1.0864e-01
# Y | Val -> R² = 0.9111, MSE = 6.6044e-03
# Y | LSG_1 -> R² = 0.0645, MSE = 2.9737e-01
# Y | LSG_2 -> R² = 0.3000, MSE = 2.7094e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.633585 | Val Loss 0.779389
# Epoch 100 | Train Loss 1.133068 | Val Loss 0.941154
# Epoch 200 | Train Loss 0.906403 | Val Loss 0.712064
# Epoch 300 | Train Loss 0.845049 | Val Loss 0.673891
# Epoch 400 | Train Loss 0.828302 | Val Loss 0.665140
# Epoch 500 | Train Loss 0.793975 | Val Loss 0.629428
# Epoch 600 | Train Loss 0.778229 | Val Loss 0.617962
# Epoch 700 | Train Loss 0.772061 | Val Loss 0.613297
# Epoch 800 | Train Loss 0.767884 | Val Loss 0.610703
# Epoch 900 | Train Loss 0.764710 | Val Loss 0.606726
# Epoch 1000 | Train Loss 0.761680 | Val Loss 0.602769
# Epoch 1100 | Train Loss 0.758986 | Val Loss 0.600612
# Epoch 1200 | Train Loss 0.756433 | Val Loss 0.599870
# Epoch 1300 | Train Loss 0.753981 | Val Loss 0.601635
# Early stopping at epoch 1314
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed9426.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9914, MSE = 7.1839e-04
# Y | Train_2 -> R² = 0.9905, MSE = 1.0172e-03
# Y | Test_1 -> R² = 0.9240, MSE = 6.2004e-03
# Y | Test_2 -> R² = 0.7498, MSE = 2.6336e-02
# Y | Test_3 -> R² = 0.6558, MSE = 2.6342e-02
# Y | Val -> R² = 0.9493, MSE = 3.7639e-03
# Y | LSG_1 -> R² = 0.0576, MSE = 2.9956e-01
# Y | LSG_2 -> R² = 0.2473, MSE = 2.9133e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.562997 | Val Loss 0.796741
# Epoch 100 | Train Loss 1.099103 | Val Loss 0.943417
# Epoch 200 | Train Loss 0.935733 | Val Loss 0.757104
# Epoch 300 | Train Loss 0.817092 | Val Loss 0.634937
# Epoch 400 | Train Loss 0.783277 | Val Loss 0.619756
# Epoch 500 | Train Loss 0.773269 | Val Loss 0.614351
# Epoch 600 | Train Loss 0.769003 | Val Loss 0.614435
# Early stopping at epoch 696
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed2664.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9919, MSE = 6.7322e-04
# Y | Train_2 -> R² = 0.9886, MSE = 1.2156e-03
# Y | Test_1 -> R² = 0.9613, MSE = 3.1552e-03
# Y | Test_2 -> R² = 0.9803, MSE = 2.0700e-03
# Y | Test_3 -> R² = -3.3864, MSE = 3.3572e-01
# Y | Val -> R² = 0.4002, MSE = 4.4542e-02
# Y | LSG_1 -> R² = -1.2674, MSE = 7.2072e-01
# Y | LSG_2 -> R² = -0.3203, MSE = 5.1102e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.692858 | Val Loss 0.784926
# Epoch 100 | Train Loss 1.143260 | Val Loss 0.928448
# Epoch 200 | Train Loss 0.937099 | Val Loss 0.759762
# Epoch 300 | Train Loss 0.831948 | Val Loss 0.658970
# Epoch 400 | Train Loss 0.793328 | Val Loss 0.629758
# Epoch 500 | Train Loss 0.781042 | Val Loss 0.617252
# Epoch 600 | Train Loss 0.775132 | Val Loss 0.612264
# Epoch 700 | Train Loss 0.771570 | Val Loss 0.609034
# Epoch 800 | Train Loss 0.768894 | Val Loss 0.605943
# Epoch 900 | Train Loss 0.766611 | Val Loss 0.602660
# Epoch 1000 | Train Loss 0.764499 | Val Loss 0.599498
# Epoch 1100 | Train Loss 0.762603 | Val Loss 0.597450
# Epoch 1200 | Train Loss 0.760887 | Val Loss 0.597622
# Epoch 1300 | Train Loss 0.759194 | Val Loss 0.599331
# Early stopping at epoch 1323
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9921, MSE = 6.6221e-04
# Y | Train_2 -> R² = 0.9935, MSE = 6.9158e-04
# Y | Test_1 -> R² = 0.9602, MSE = 3.2462e-03
# Y | Test_2 -> R² = 0.9826, MSE = 1.8338e-03
# Y | Test_3 -> R² = -1.8244, MSE = 2.1617e-01
# Y | Val -> R² = 0.5859, MSE = 3.0746e-02
# Y | LSG_1 -> R² = -2.3180, MSE = 1.0547e+00
# Y | LSG_2 -> R² = -1.1955, MSE = 8.4973e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=421 salvo.
# Epoch 0 | Train Loss 1.248928 | Val Loss 0.780644
# Epoch 100 | Train Loss 0.644730 | Val Loss 0.832715
# Epoch 200 | Train Loss 0.406650 | Val Loss 0.620285
# Epoch 300 | Train Loss 0.395874 | Val Loss 0.616086
# Epoch 400 | Train Loss 0.392029 | Val Loss 0.612563
# Epoch 500 | Train Loss 0.389030 | Val Loss 0.609063
# Epoch 600 | Train Loss 0.386679 | Val Loss 0.606323
# Epoch 700 | Train Loss 0.384716 | Val Loss 0.604773
# Epoch 800 | Train Loss 0.382773 | Val Loss 0.605162
# Early stopping at epoch 841
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9924, MSE = 6.3113e-04
# Y | Train_2 -> R² = 0.9942, MSE = 6.1992e-04
# Y | Test_1 -> R² = 0.8777, MSE = 9.9783e-03
# Y | Test_2 -> R² = 0.8908, MSE = 1.1495e-02
# Y | Test_3 -> R² = -1.7180, MSE = 2.0802e-01
# Y | Val -> R² = 0.5996, MSE = 2.9728e-02
# Y | LSG_1 -> R² = -1.8701, MSE = 9.1228e-01
# Y | LSG_2 -> R² = -0.6059, MSE = 6.2155e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.405839 | Val Loss 0.803723
# Epoch 100 | Train Loss 0.703314 | Val Loss 0.909515
# Epoch 200 | Train Loss 0.416164 | Val Loss 0.636577
# Epoch 300 | Train Loss 0.400057 | Val Loss 0.626006
# Epoch 400 | Train Loss 0.393594 | Val Loss 0.613537
# Epoch 500 | Train Loss 0.389830 | Val Loss 0.608737
# Epoch 600 | Train Loss 0.387016 | Val Loss 0.609971
# Early stopping at epoch 682
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9904, MSE = 8.0518e-04
# Y | Train_2 -> R² = 0.9921, MSE = 8.4190e-04
# Y | Test_1 -> R² = 0.9016, MSE = 8.0321e-03
# Y | Test_2 -> R² = 0.9767, MSE = 2.4520e-03
# Y | Test_3 -> R² = -3.3588, MSE = 3.3361e-01
# Y | Val -> R² = 0.8551, MSE = 1.0759e-02
# Y | LSG_1 -> R² = -3.0355, MSE = 1.2827e+00
# Y | LSG_2 -> R² = -1.0863, MSE = 8.0748e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.248895 | Val Loss 0.778827
# Epoch 100 | Train Loss 0.637986 | Val Loss 0.859375
# Epoch 200 | Train Loss 0.414177 | Val Loss 0.641313
# Epoch 300 | Train Loss 0.401194 | Val Loss 0.617525
# Epoch 400 | Train Loss 0.395993 | Val Loss 0.609131
# Epoch 500 | Train Loss 0.391754 | Val Loss 0.602733
# Epoch 600 | Train Loss 0.388380 | Val Loss 0.602500
# Early stopping at epoch 697
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9903, MSE = 8.1253e-04
# Y | Train_2 -> R² = 0.9919, MSE = 8.6352e-04
# Y | Test_1 -> R² = 0.9492, MSE = 4.1488e-03
# Y | Test_2 -> R² = 0.9790, MSE = 2.2063e-03
# Y | Test_3 -> R² = -3.7760, MSE = 3.6554e-01
# Y | Val -> R² = 0.5336, MSE = 3.4636e-02
# Y | LSG_1 -> R² = -2.3696, MSE = 1.0711e+00
# Y | LSG_2 -> R² = -0.9528, MSE = 7.5581e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.208390 | Val Loss 0.783044
# Epoch 100 | Train Loss 0.625985 | Val Loss 0.849140
# Epoch 200 | Train Loss 0.412532 | Val Loss 0.637177
# Epoch 300 | Train Loss 0.397718 | Val Loss 0.628582
# Epoch 400 | Train Loss 0.393027 | Val Loss 0.622754
# Epoch 500 | Train Loss 0.390360 | Val Loss 0.621682
# Epoch 600 | Train Loss 0.388182 | Val Loss 0.622208
# Early stopping at epoch 672
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.8942e-04
# Y | Train_2 -> R² = 0.9919, MSE = 8.6292e-04
# Y | Test_1 -> R² = 0.8414, MSE = 1.2942e-02
# Y | Test_2 -> R² = 0.9726, MSE = 2.8875e-03
# Y | Test_3 -> R² = -3.4964, MSE = 3.4414e-01
# Y | Val -> R² = 0.4149, MSE = 4.3445e-02
# Y | LSG_1 -> R² = -2.1879, MSE = 1.0133e+00
# Y | LSG_2 -> R² = -0.8482, MSE = 7.1532e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.295721 | Val Loss 0.769784
# Epoch 100 | Train Loss 0.689727 | Val Loss 0.894984
# Epoch 200 | Train Loss 0.418574 | Val Loss 0.679555
# Epoch 300 | Train Loss 0.399870 | Val Loss 0.636205
# Epoch 400 | Train Loss 0.394479 | Val Loss 0.618345
# Epoch 500 | Train Loss 0.391778 | Val Loss 0.609514
# Epoch 600 | Train Loss 0.389999 | Val Loss 0.605681
# Epoch 700 | Train Loss 0.388430 | Val Loss 0.603652
# Epoch 800 | Train Loss 0.386694 | Val Loss 0.602348
# Epoch 900 | Train Loss 0.384643 | Val Loss 0.601283
# Epoch 1000 | Train Loss 0.382539 | Val Loss 0.600982
# Early stopping at epoch 1079
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.9919, MSE = 6.7610e-04
# Y | Train_2 -> R² = 0.9943, MSE = 6.0669e-04
# Y | Test_1 -> R² = 0.9369, MSE = 5.1515e-03
# Y | Test_2 -> R² = 0.8991, MSE = 1.0623e-02
# Y | Test_3 -> R² = -1.6426, MSE = 2.0226e-01
# Y | Val -> R² = 0.4508, MSE = 4.0785e-02
# Y | LSG_1 -> R² = -1.4350, MSE = 7.7399e-01
# Y | LSG_2 -> R² = -0.4248, MSE = 5.5146e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.284810 | Val Loss 0.823150
# Epoch 100 | Train Loss 0.695069 | Val Loss 0.892044
# Epoch 200 | Train Loss 0.428104 | Val Loss 0.643358
# Epoch 300 | Train Loss 0.404010 | Val Loss 0.621466
# Epoch 400 | Train Loss 0.395600 | Val Loss 0.604847
# Epoch 500 | Train Loss 0.390759 | Val Loss 0.601615
# Epoch 600 | Train Loss 0.387717 | Val Loss 0.599456
# Epoch 700 | Train Loss 0.385403 | Val Loss 0.599091
# Early stopping at epoch 781
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9927, MSE = 6.0718e-04
# Y | Train_2 -> R² = 0.9930, MSE = 7.4752e-04
# Y | Test_1 -> R² = 0.9765, MSE = 1.9195e-03
# Y | Test_2 -> R² = 0.9461, MSE = 5.6739e-03
# Y | Test_3 -> R² = -0.1468, MSE = 8.7772e-02
# Y | Val -> R² = 0.9584, MSE = 3.0865e-03
# Y | LSG_1 -> R² = -0.3841, MSE = 4.3996e-01
# Y | LSG_2 -> R² = 0.2187, MSE = 3.0240e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.276575 | Val Loss 0.816207
# Epoch 100 | Train Loss 0.687373 | Val Loss 0.896205
# Epoch 200 | Train Loss 0.416191 | Val Loss 0.644381
# Epoch 300 | Train Loss 0.398516 | Val Loss 0.641235
# Epoch 400 | Train Loss 0.394545 | Val Loss 0.640797
# Epoch 500 | Train Loss 0.391634 | Val Loss 0.643643
# Early stopping at epoch 508
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9900, MSE = 8.3285e-04
# Y | Train_2 -> R² = 0.9890, MSE = 1.1753e-03
# Y | Test_1 -> R² = 0.9561, MSE = 3.5825e-03
# Y | Test_2 -> R² = 0.9765, MSE = 2.4690e-03
# Y | Test_3 -> R² = -3.5734, MSE = 3.5004e-01
# Y | Val -> R² = -1.4262, MSE = 1.8016e-01
# Y | LSG_1 -> R² = -1.8977, MSE = 9.2108e-01
# Y | LSG_2 -> R² = -0.8180, MSE = 7.0364e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.228686 | Val Loss 0.785937
# Epoch 100 | Train Loss 0.615281 | Val Loss 0.848345
# Epoch 200 | Train Loss 0.402648 | Val Loss 0.620305
# Epoch 300 | Train Loss 0.395456 | Val Loss 0.609388
# Epoch 400 | Train Loss 0.392071 | Val Loss 0.605202
# Epoch 500 | Train Loss 0.389463 | Val Loss 0.605680
# Early stopping at epoch 571
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9904, MSE = 8.0530e-04
# Y | Train_2 -> R² = 0.9899, MSE = 1.0794e-03
# Y | Test_1 -> R² = 0.9612, MSE = 3.1642e-03
# Y | Test_2 -> R² = 0.9795, MSE = 2.1536e-03
# Y | Test_3 -> R² = -2.7562, MSE = 2.8749e-01
# Y | Val -> R² = 0.6671, MSE = 2.4721e-02
# Y | LSG_1 -> R² = -1.1702, MSE = 6.8981e-01
# Y | LSG_2 -> R² = -0.3746, MSE = 5.3202e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.202333 | Val Loss 0.795746
# Epoch 100 | Train Loss 0.696822 | Val Loss 0.898191
# Epoch 200 | Train Loss 0.418143 | Val Loss 0.640899
# Epoch 300 | Train Loss 0.398022 | Val Loss 0.627699
# Epoch 400 | Train Loss 0.393644 | Val Loss 0.615391
# Epoch 500 | Train Loss 0.390092 | Val Loss 0.613659
# Epoch 600 | Train Loss 0.386775 | Val Loss 0.614947
# Early stopping at epoch 634
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9192e-04
# Y | Train_2 -> R² = 0.9925, MSE = 8.0262e-04
# Y | Test_1 -> R² = 0.8612, MSE = 1.1330e-02
# Y | Test_2 -> R² = 0.9775, MSE = 2.3726e-03
# Y | Test_3 -> R² = -3.0066, MSE = 3.0665e-01
# Y | Val -> R² = 0.2484, MSE = 5.5807e-02
# Y | LSG_1 -> R² = -2.5863, MSE = 1.1400e+00
# Y | LSG_2 -> R² = -1.0202, MSE = 7.8188e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.234272 | Val Loss 0.800736
# Epoch 100 | Train Loss 0.667503 | Val Loss 0.875742
# Epoch 200 | Train Loss 0.407598 | Val Loss 0.635294
# Epoch 300 | Train Loss 0.398450 | Val Loss 0.631168
# Epoch 400 | Train Loss 0.394241 | Val Loss 0.624418
# Epoch 500 | Train Loss 0.391435 | Val Loss 0.621303
# Epoch 600 | Train Loss 0.389063 | Val Loss 0.621862
# Epoch 700 | Train Loss 0.386746 | Val Loss 0.623227
# Early stopping at epoch 702
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.9899, MSE = 8.4100e-04
# Y | Train_2 -> R² = 0.9912, MSE = 9.3728e-04
# Y | Test_1 -> R² = 0.9328, MSE = 5.4829e-03
# Y | Test_2 -> R² = 0.9756, MSE = 2.5701e-03
# Y | Test_3 -> R² = -3.1854, MSE = 3.2034e-01
# Y | Val -> R² = -0.0009, MSE = 7.4321e-02
# Y | LSG_1 -> R² = -1.8919, MSE = 9.1921e-01
# Y | LSG_2 -> R² = -1.1175, MSE = 8.1956e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=421 salvo.
# Epoch 0 | Train Loss 1.609129 | Val Loss 0.821610
# Epoch 100 | Train Loss 1.087206 | Val Loss 0.904872
# Epoch 200 | Train Loss 0.826122 | Val Loss 0.652307
# Epoch 300 | Train Loss 0.782121 | Val Loss 0.624771
# Epoch 400 | Train Loss 0.773171 | Val Loss 0.610973
# Epoch 500 | Train Loss 0.767247 | Val Loss 0.601589
# Epoch 600 | Train Loss 0.763311 | Val Loss 0.599801
# Epoch 700 | Train Loss 0.760037 | Val Loss 0.600834
# Early stopping at epoch 726
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed3631.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9927, MSE = 6.0559e-04
# Y | Train_2 -> R² = 0.9880, MSE = 1.2767e-03
# Y | Test_1 -> R² = 0.8731, MSE = 1.0353e-02
# Y | Test_2 -> R² = 0.9859, MSE = 1.4827e-03
# Y | Test_3 -> R² = -0.3067, MSE = 1.0001e-01
# Y | Val -> R² = 0.8278, MSE = 1.2788e-02
# Y | LSG_1 -> R² = 0.0951, MSE = 2.8763e-01
# Y | LSG_2 -> R² = 0.3478, MSE = 2.5241e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.607941 | Val Loss 0.788318
# Epoch 100 | Train Loss 1.094213 | Val Loss 0.910438
# Epoch 200 | Train Loss 0.790469 | Val Loss 0.632187
# Epoch 300 | Train Loss 0.776099 | Val Loss 0.617149
# Epoch 400 | Train Loss 0.771057 | Val Loss 0.613429
# Epoch 500 | Train Loss 0.767780 | Val Loss 0.612977
# Epoch 600 | Train Loss 0.764260 | Val Loss 0.608877
# Epoch 700 | Train Loss 0.760482 | Val Loss 0.608334
# Early stopping at epoch 796
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed7576.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9913, MSE = 7.2280e-04
# Y | Train_2 -> R² = 0.9924, MSE = 8.1073e-04
# Y | Test_1 -> R² = 0.8351, MSE = 1.3457e-02
# Y | Test_2 -> R² = 0.9758, MSE = 2.5507e-03
# Y | Test_3 -> R² = -2.5421, MSE = 2.7110e-01
# Y | Val -> R² = 0.7423, MSE = 1.9133e-02
# Y | LSG_1 -> R² = -2.5845, MSE = 1.1394e+00
# Y | LSG_2 -> R² = -1.1280, MSE = 8.2361e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.630129 | Val Loss 0.818097
# Epoch 100 | Train Loss 1.055686 | Val Loss 0.897540
# Epoch 200 | Train Loss 0.813837 | Val Loss 0.676739
# Epoch 300 | Train Loss 0.782647 | Val Loss 0.625335
# Epoch 400 | Train Loss 0.774076 | Val Loss 0.612212
# Epoch 500 | Train Loss 0.769467 | Val Loss 0.608079
# Epoch 600 | Train Loss 0.764801 | Val Loss 0.606433
# Epoch 700 | Train Loss 0.760720 | Val Loss 0.605703
# Epoch 800 | Train Loss 0.757243 | Val Loss 0.606684
# Epoch 900 | Train Loss 0.754049 | Val Loss 0.615038
# Early stopping at epoch 903
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed9426.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9045e-04
# Y | Train_2 -> R² = 0.9940, MSE = 6.4112e-04
# Y | Test_1 -> R² = 0.8779, MSE = 9.9608e-03
# Y | Test_2 -> R² = 0.9886, MSE = 1.2008e-03
# Y | Test_3 -> R² = 0.0513, MSE = 7.2609e-02
# Y | Val -> R² = 0.9795, MSE = 1.5212e-03
# Y | LSG_1 -> R² = -1.8003, MSE = 8.9011e-01
# Y | LSG_2 -> R² = -0.8291, MSE = 7.0792e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.684489 | Val Loss 0.805882
# Epoch 100 | Train Loss 1.081935 | Val Loss 0.897530
# Epoch 200 | Train Loss 0.825360 | Val Loss 0.652284
# Epoch 300 | Train Loss 0.780180 | Val Loss 0.622481
# Epoch 400 | Train Loss 0.771585 | Val Loss 0.608496
# Epoch 500 | Train Loss 0.766528 | Val Loss 0.601923
# Epoch 600 | Train Loss 0.762748 | Val Loss 0.601139
# Epoch 700 | Train Loss 0.759215 | Val Loss 0.602910
# Early stopping at epoch 710
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed2664.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9912, MSE = 7.3272e-04
# Y | Train_2 -> R² = 0.9896, MSE = 1.1073e-03
# Y | Test_1 -> R² = 0.8552, MSE = 1.1812e-02
# Y | Test_2 -> R² = 0.9862, MSE = 1.4556e-03
# Y | Test_3 -> R² = 0.2918, MSE = 5.4205e-02
# Y | Val -> R² = 0.9537, MSE = 3.4344e-03
# Y | LSG_1 -> R² = 0.2319, MSE = 2.4416e-01
# Y | LSG_2 -> R² = 0.4288, MSE = 2.2107e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.733651 | Val Loss 0.804604
# Epoch 100 | Train Loss 1.124963 | Val Loss 0.929749
# Epoch 200 | Train Loss 0.801442 | Val Loss 0.649614
# Epoch 300 | Train Loss 0.782499 | Val Loss 0.625937
# Epoch 400 | Train Loss 0.774674 | Val Loss 0.613008
# Epoch 500 | Train Loss 0.770483 | Val Loss 0.605563
# Epoch 600 | Train Loss 0.767711 | Val Loss 0.602189
# Epoch 700 | Train Loss 0.765409 | Val Loss 0.601791
# Early stopping at epoch 797
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9904, MSE = 7.9799e-04
# Y | Train_2 -> R² = 0.9923, MSE = 8.2230e-04
# Y | Test_1 -> R² = 0.9707, MSE = 2.3896e-03
# Y | Test_2 -> R² = 0.9886, MSE = 1.2052e-03
# Y | Test_3 -> R² = -2.5632, MSE = 2.7271e-01
# Y | Val -> R² = 0.8712, MSE = 9.5664e-03
# Y | LSG_1 -> R² = -0.2159, MSE = 3.8648e-01
# Y | LSG_2 -> R² = 0.2808, MSE = 2.7834e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.600209 | Val Loss 0.808502
# Epoch 100 | Train Loss 1.071670 | Val Loss 0.863183
# Epoch 200 | Train Loss 0.810000 | Val Loss 0.641629
# Epoch 300 | Train Loss 0.778971 | Val Loss 0.625778
# Epoch 400 | Train Loss 0.772502 | Val Loss 0.620780
# Epoch 500 | Train Loss 0.768319 | Val Loss 0.610869
# Epoch 600 | Train Loss 0.765198 | Val Loss 0.607144
# Epoch 700 | Train Loss 0.762401 | Val Loss 0.608427
# Early stopping at epoch 774
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed3631.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9906, MSE = 7.8722e-04
# Y | Train_2 -> R² = 0.9906, MSE = 1.0023e-03
# Y | Test_1 -> R² = 0.8982, MSE = 8.3102e-03
# Y | Test_2 -> R² = 0.9668, MSE = 3.4951e-03
# Y | Test_3 -> R² = -0.1202, MSE = 8.5736e-02
# Y | Val -> R² = 0.9534, MSE = 3.4609e-03
# Y | LSG_1 -> R² = 0.0360, MSE = 3.0641e-01
# Y | LSG_2 -> R² = 0.3158, MSE = 2.6481e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.660738 | Val Loss 0.772869
# Epoch 100 | Train Loss 0.996141 | Val Loss 0.830666
# Epoch 200 | Train Loss 0.791281 | Val Loss 0.651807
# Epoch 300 | Train Loss 0.778781 | Val Loss 0.640853
# Epoch 400 | Train Loss 0.772055 | Val Loss 0.630817
# Epoch 500 | Train Loss 0.768614 | Val Loss 0.627073
# Epoch 600 | Train Loss 0.765472 | Val Loss 0.624370
# Epoch 700 | Train Loss 0.762454 | Val Loss 0.621626
# Epoch 800 | Train Loss 0.759601 | Val Loss 0.620815
# Epoch 900 | Train Loss 0.756781 | Val Loss 0.621875
# Early stopping at epoch 933
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed7576.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9899, MSE = 8.4142e-04
# Y | Train_2 -> R² = 0.9932, MSE = 7.2500e-04
# Y | Test_1 -> R² = 0.7594, MSE = 1.9634e-02
# Y | Test_2 -> R² = 0.9721, MSE = 2.9418e-03
# Y | Test_3 -> R² = -4.5742, MSE = 4.2663e-01
# Y | Val -> R² = -0.0525, MSE = 7.8155e-02
# Y | LSG_1 -> R² = -3.4355, MSE = 1.4099e+00
# Y | LSG_2 -> R² = -1.5494, MSE = 9.8669e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.619664 | Val Loss 0.801175
# Epoch 100 | Train Loss 1.079293 | Val Loss 0.896433
# Epoch 200 | Train Loss 0.809109 | Val Loss 0.645108
# Epoch 300 | Train Loss 0.776507 | Val Loss 0.620056
# Epoch 400 | Train Loss 0.770517 | Val Loss 0.606703
# Epoch 500 | Train Loss 0.766760 | Val Loss 0.600242
# Epoch 600 | Train Loss 0.763307 | Val Loss 0.597618
# Epoch 700 | Train Loss 0.759676 | Val Loss 0.597722
# Early stopping at epoch 762
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed9426.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9898, MSE = 8.5276e-04
# Y | Train_2 -> R² = 0.9923, MSE = 8.2046e-04
# Y | Test_1 -> R² = 0.9656, MSE = 2.8056e-03
# Y | Test_2 -> R² = 0.9878, MSE = 1.2799e-03
# Y | Test_3 -> R² = -1.7015, MSE = 2.0677e-01
# Y | Val -> R² = 0.7091, MSE = 2.1601e-02
# Y | LSG_1 -> R² = -1.1435, MSE = 6.8132e-01
# Y | LSG_2 -> R² = -0.2887, MSE = 4.9878e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.644298 | Val Loss 0.796951
# Epoch 100 | Train Loss 1.014964 | Val Loss 0.837637
# Epoch 200 | Train Loss 0.792908 | Val Loss 0.653038
# Epoch 300 | Train Loss 0.778172 | Val Loss 0.620686
# Epoch 400 | Train Loss 0.772879 | Val Loss 0.612128
# Epoch 500 | Train Loss 0.769652 | Val Loss 0.610696
# Epoch 600 | Train Loss 0.767013 | Val Loss 0.610782
# Early stopping at epoch 619
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed2664.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9886, MSE = 9.5547e-04
# Y | Train_2 -> R² = 0.9910, MSE = 9.5714e-04
# Y | Test_1 -> R² = 0.9511, MSE = 3.9926e-03
# Y | Test_2 -> R² = 0.9790, MSE = 2.2124e-03
# Y | Test_3 -> R² = -5.3310, MSE = 4.8456e-01
# Y | Val -> R² = 0.4023, MSE = 4.4379e-02
# Y | LSG_1 -> R² = -1.8543, MSE = 9.0728e-01
# Y | LSG_2 -> R² = -0.7772, MSE = 6.8784e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.665163 | Val Loss 0.783671
# Epoch 100 | Train Loss 1.046701 | Val Loss 0.870373
# Epoch 200 | Train Loss 0.797490 | Val Loss 0.654782
# Epoch 300 | Train Loss 0.780952 | Val Loss 0.654653
# Epoch 400 | Train Loss 0.772656 | Val Loss 0.640297
# Epoch 500 | Train Loss 0.768081 | Val Loss 0.625718
# Epoch 600 | Train Loss 0.764679 | Val Loss 0.611937
# Epoch 700 | Train Loss 0.761566 | Val Loss 0.601252
# Epoch 800 | Train Loss 0.758479 | Val Loss 0.594902
# Epoch 900 | Train Loss 0.755666 | Val Loss 0.593026
# Epoch 1000 | Train Loss 0.752961 | Val Loss 0.592203
# Epoch 1100 | Train Loss 0.750072 | Val Loss 0.594643
# Early stopping at epoch 1104
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9915, MSE = 7.0880e-04
# Y | Train_2 -> R² = 0.9936, MSE = 6.7910e-04
# Y | Test_1 -> R² = 0.8959, MSE = 8.4945e-03
# Y | Test_2 -> R² = 0.9097, MSE = 9.5098e-03
# Y | Test_3 -> R² = -2.0594, MSE = 2.3415e-01
# Y | Val -> R² = 0.5327, MSE = 3.4699e-02
# Y | LSG_1 -> R² = -2.0256, MSE = 9.6172e-01
# Y | LSG_2 -> R² = -0.8805, MSE = 7.2782e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=421 salvo.
# Epoch 0 | Train Loss 1.405993 | Val Loss 0.791956
# Epoch 100 | Train Loss 0.511651 | Val Loss 0.789582
# Epoch 200 | Train Loss 0.404969 | Val Loss 0.648912
# Epoch 300 | Train Loss 0.395749 | Val Loss 0.634285
# Epoch 400 | Train Loss 0.390842 | Val Loss 0.629287
# Epoch 500 | Train Loss 0.386953 | Val Loss 0.628937
# Epoch 600 | Train Loss 0.384345 | Val Loss 0.631435
# Early stopping at epoch 609
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9910, MSE = 7.4918e-04
# Y | Train_2 -> R² = 0.9914, MSE = 9.1317e-04
# Y | Test_1 -> R² = 0.8135, MSE = 1.5215e-02
# Y | Test_2 -> R² = 0.9720, MSE = 2.9507e-03
# Y | Test_3 -> R² = -4.4017, MSE = 4.1343e-01
# Y | Val -> R² = 0.5745, MSE = 3.1597e-02
# Y | LSG_1 -> R² = -2.4235, MSE = 1.0882e+00
# Y | LSG_2 -> R² = -1.0277, MSE = 7.8480e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.451521 | Val Loss 0.812686
# Epoch 100 | Train Loss 0.498273 | Val Loss 0.720240
# Epoch 200 | Train Loss 0.401848 | Val Loss 0.634839
# Epoch 300 | Train Loss 0.394820 | Val Loss 0.622819
# Epoch 400 | Train Loss 0.390773 | Val Loss 0.616227
# Epoch 500 | Train Loss 0.387430 | Val Loss 0.618150
# Early stopping at epoch 566
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9902, MSE = 8.1699e-04
# Y | Train_2 -> R² = 0.9909, MSE = 9.6873e-04
# Y | Test_1 -> R² = 0.9097, MSE = 7.3645e-03
# Y | Test_2 -> R² = 0.9785, MSE = 2.2595e-03
# Y | Test_3 -> R² = -4.9567, MSE = 4.5590e-01
# Y | Val -> R² = 0.5575, MSE = 3.2859e-02
# Y | LSG_1 -> R² = -1.4385, MSE = 7.7511e-01
# Y | LSG_2 -> R² = -0.4416, MSE = 5.5794e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.415050 | Val Loss 0.806623
# Epoch 100 | Train Loss 0.482135 | Val Loss 0.723433
# Epoch 200 | Train Loss 0.404186 | Val Loss 0.660833
# Epoch 300 | Train Loss 0.396615 | Val Loss 0.652921
# Epoch 400 | Train Loss 0.391792 | Val Loss 0.642024
# Epoch 500 | Train Loss 0.388585 | Val Loss 0.632727
# Epoch 600 | Train Loss 0.385371 | Val Loss 0.627788
# Epoch 700 | Train Loss 0.381817 | Val Loss 0.619959
# Epoch 800 | Train Loss 0.378426 | Val Loss 0.612697
# Epoch 900 | Train Loss 0.375923 | Val Loss 0.609636
# Epoch 1000 | Train Loss 0.374020 | Val Loss 0.610268
# Early stopping at epoch 1090
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9938, MSE = 5.1419e-04
# Y | Train_2 -> R² = 0.9939, MSE = 6.4939e-04
# Y | Test_1 -> R² = 0.8979, MSE = 8.3335e-03
# Y | Test_2 -> R² = -0.4802, MSE = 1.5581e-01
# Y | Test_3 -> R² = -0.8262, MSE = 1.3977e-01
# Y | Val -> R² = 0.0553, MSE = 7.0147e-02
# Y | LSG_1 -> R² = -1.4498, MSE = 7.7870e-01
# Y | LSG_2 -> R² = -0.6370, MSE = 6.3356e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.267568 | Val Loss 0.809730
# Epoch 100 | Train Loss 0.442673 | Val Loss 0.730315
# Epoch 200 | Train Loss 0.401012 | Val Loss 0.634288
# Epoch 300 | Train Loss 0.393202 | Val Loss 0.615672
# Epoch 400 | Train Loss 0.388647 | Val Loss 0.615241
# Epoch 500 | Train Loss 0.384940 | Val Loss 0.614674
# Early stopping at epoch 502
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9902, MSE = 8.1682e-04
# Y | Train_2 -> R² = 0.9920, MSE = 8.5045e-04
# Y | Test_1 -> R² = 0.8854, MSE = 9.3523e-03
# Y | Test_2 -> R² = 0.9786, MSE = 2.2492e-03
# Y | Test_3 -> R² = -4.3054, MSE = 4.0606e-01
# Y | Val -> R² = 0.3998, MSE = 4.4564e-02
# Y | LSG_1 -> R² = -2.3422, MSE = 1.0624e+00
# Y | LSG_2 -> R² = -0.9386, MSE = 7.5032e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.399287 | Val Loss 0.822583
# Epoch 100 | Train Loss 0.484219 | Val Loss 0.731291
# Epoch 200 | Train Loss 0.400675 | Val Loss 0.630792
# Epoch 300 | Train Loss 0.395316 | Val Loss 0.619737
# Epoch 400 | Train Loss 0.391252 | Val Loss 0.613940
# Epoch 500 | Train Loss 0.387532 | Val Loss 0.614595
# Early stopping at epoch 586
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.9900, MSE = 8.3073e-04
# Y | Train_2 -> R² = 0.9911, MSE = 9.4922e-04
# Y | Test_1 -> R² = 0.8793, MSE = 9.8514e-03
# Y | Test_2 -> R² = 0.9755, MSE = 2.5774e-03
# Y | Test_3 -> R² = -3.7991, MSE = 3.6730e-01
# Y | Val -> R² = 0.7236, MSE = 2.0524e-02
# Y | LSG_1 -> R² = -2.2150, MSE = 1.0219e+00
# Y | LSG_2 -> R² = -0.7340, MSE = 6.7113e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.338093 | Val Loss 0.793124
# Epoch 100 | Train Loss 0.473611 | Val Loss 0.768207
# Epoch 200 | Train Loss 0.403873 | Val Loss 0.625845
# Epoch 300 | Train Loss 0.394478 | Val Loss 0.615229
# Epoch 400 | Train Loss 0.391062 | Val Loss 0.609969
# Epoch 500 | Train Loss 0.388326 | Val Loss 0.607457
# Epoch 600 | Train Loss 0.385171 | Val Loss 0.605768
# Epoch 700 | Train Loss 0.381821 | Val Loss 0.610897
# Early stopping at epoch 738
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9916, MSE = 7.0082e-04
# Y | Train_2 -> R² = 0.9932, MSE = 7.2367e-04
# Y | Test_1 -> R² = 0.9638, MSE = 2.9528e-03
# Y | Test_2 -> R² = 0.9711, MSE = 3.0391e-03
# Y | Test_3 -> R² = -0.4919, MSE = 1.1418e-01
# Y | Val -> R² = 0.9457, MSE = 4.0302e-03
# Y | LSG_1 -> R² = -1.4712, MSE = 7.8551e-01
# Y | LSG_2 -> R² = -0.2764, MSE = 4.9403e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.436206 | Val Loss 0.852307
# Epoch 100 | Train Loss 0.595788 | Val Loss 0.807555
# Epoch 200 | Train Loss 0.402005 | Val Loss 0.615062
# Epoch 300 | Train Loss 0.394537 | Val Loss 0.606162
# Epoch 400 | Train Loss 0.390490 | Val Loss 0.603917
# Epoch 500 | Train Loss 0.386340 | Val Loss 0.605182
# Epoch 600 | Train Loss 0.383072 | Val Loss 0.611687
# Early stopping at epoch 604
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9920, MSE = 6.6913e-04
# Y | Train_2 -> R² = 0.9920, MSE = 8.4893e-04
# Y | Test_1 -> R² = 0.9649, MSE = 2.8660e-03
# Y | Test_2 -> R² = 0.9745, MSE = 2.6873e-03
# Y | Test_3 -> R² = -1.7201, MSE = 2.0819e-01
# Y | Val -> R² = 0.9660, MSE = 2.5228e-03
# Y | LSG_1 -> R² = -1.5524, MSE = 8.1130e-01
# Y | LSG_2 -> R² = -0.3803, MSE = 5.3424e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.365148 | Val Loss 0.816536
# Epoch 100 | Train Loss 0.570018 | Val Loss 0.787760
# Epoch 200 | Train Loss 0.399623 | Val Loss 0.622030
# Epoch 300 | Train Loss 0.393605 | Val Loss 0.613472
# Epoch 400 | Train Loss 0.389148 | Val Loss 0.607896
# Epoch 500 | Train Loss 0.385642 | Val Loss 0.609917
# Early stopping at epoch 562
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9606e-04
# Y | Train_2 -> R² = 0.9920, MSE = 8.5704e-04
# Y | Test_1 -> R² = 0.9496, MSE = 4.1123e-03
# Y | Test_2 -> R² = 0.9657, MSE = 3.6066e-03
# Y | Test_3 -> R² = -2.2767, MSE = 2.5079e-01
# Y | Val -> R² = 0.8343, MSE = 1.2305e-02
# Y | LSG_1 -> R² = -1.8088, MSE = 8.9282e-01
# Y | LSG_2 -> R² = -0.5005, MSE = 5.8074e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.251798 | Val Loss 0.789556
# Epoch 100 | Train Loss 0.451706 | Val Loss 0.713015
# Epoch 200 | Train Loss 0.398795 | Val Loss 0.630953
# Epoch 300 | Train Loss 0.392410 | Val Loss 0.612686
# Epoch 400 | Train Loss 0.388916 | Val Loss 0.613152
# Early stopping at epoch 492
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9899, MSE = 8.4204e-04
# Y | Train_2 -> R² = 0.9910, MSE = 9.6153e-04
# Y | Test_1 -> R² = 0.9171, MSE = 6.7656e-03
# Y | Test_2 -> R² = 0.9721, MSE = 2.9363e-03
# Y | Test_3 -> R² = -3.8123, MSE = 3.6831e-01
# Y | Val -> R² = 0.4515, MSE = 4.0733e-02
# Y | LSG_1 -> R² = -1.5306, MSE = 8.0438e-01
# Y | LSG_2 -> R² = -0.3674, MSE = 5.2924e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.394441 | Val Loss 0.817829
# Epoch 100 | Train Loss 0.571926 | Val Loss 0.786504
# Epoch 200 | Train Loss 0.402139 | Val Loss 0.634800
# Epoch 300 | Train Loss 0.393997 | Val Loss 0.616736
# ...
# Epoch 300 | Train Loss 0.754388 | Val Loss 0.598819
# Epoch 400 | Train Loss 0.744568 | Val Loss 0.633018
# Early stopping at epoch 454
# Modelo salvo em:
# models/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9916, MSE = 6.9787e-04
# Y | Train_2 -> R² = 0.9917, MSE = 8.9088e-04
# Y | Test_1 -> R² = 0.9859, MSE = 1.1470e-03
# Y | Test_2 -> R² = 0.8590, MSE = 1.4837e-02
# Y | Test_3 -> R² = 0.0529, MSE = 7.2485e-02
# Y | Val -> R² = 0.7735, MSE = 1.6819e-02
# Y | LSG_1 -> R² = -0.3855, MSE = 4.4040e-01
# Y | LSG_2 -> R² = 0.1000, MSE = 3.4834e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=421 salvo.
# Epoch 0 | Train Loss 1.130661 | Val Loss 0.916916
# Epoch 100 | Train Loss 0.389537 | Val Loss 0.610286
# Epoch 200 | Train Loss 0.381344 | Val Loss 0.607398
# Epoch 300 | Train Loss 0.371515 | Val Loss 0.613557
# Epoch 400 | Train Loss 0.385096 | Val Loss 0.644581
# Early stopping at epoch 457
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9179, MSE = 6.8546e-03
# Y | Train_2 -> R² = 0.9374, MSE = 6.6822e-03
# Y | Test_1 -> R² = 0.9843, MSE = 1.2829e-03
# Y | Test_2 -> R² = 0.6821, MSE = 3.3463e-02
# Y | Test_3 -> R² = -0.0394, MSE = 7.9554e-02
# Y | Val -> R² = 0.6472, MSE = 2.6194e-02
# Y | LSG_1 -> R² = -1.0455, MSE = 6.5017e-01
# Y | LSG_2 -> R² = -0.3550, MSE = 5.2444e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.132444 | Val Loss 0.908184
# Epoch 100 | Train Loss 0.390753 | Val Loss 0.626161
# Epoch 200 | Train Loss 0.380762 | Val Loss 0.627699
# Epoch 300 | Train Loss 0.378993 | Val Loss 0.654296
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9846, MSE = 1.2843e-03
# Y | Train_2 -> R² = 0.6874, MSE = 3.3377e-02
# Y | Test_1 -> R² = 0.9701, MSE = 2.4405e-03
# Y | Test_2 -> R² = 0.5077, MSE = 5.1817e-02
# Y | Test_3 -> R² = -2.0330, MSE = 2.3214e-01
# Y | Val -> R² = 0.4094, MSE = 4.3855e-02
# Y | LSG_1 -> R² = -2.3040, MSE = 1.0502e+00
# Y | LSG_2 -> R² = -0.8869, MSE = 7.3031e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.132767 | Val Loss 0.888576
# Epoch 100 | Train Loss 0.389728 | Val Loss 0.613208
# Epoch 200 | Train Loss 0.381023 | Val Loss 0.618251
# Early stopping at epoch 290
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9913, MSE = 7.2644e-04
# Y | Train_2 -> R² = 0.9915, MSE = 9.1077e-04
# Y | Test_1 -> R² = 0.8977, MSE = 8.3463e-03
# Y | Test_2 -> R² = 0.9756, MSE = 2.5652e-03
# Y | Test_3 -> R² = -4.0424, MSE = 3.8593e-01
# Y | Val -> R² = 0.0376, MSE = 7.1466e-02
# Y | LSG_1 -> R² = -3.1149, MSE = 1.3080e+00
# Y | LSG_2 -> R² = -1.4221, MSE = 9.3746e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.137850 | Val Loss 0.874712
# Epoch 100 | Train Loss 0.390069 | Val Loss 0.617235
# Epoch 200 | Train Loss 0.381893 | Val Loss 0.629156
# Epoch 300 | Train Loss 0.372995 | Val Loss 0.653649
# Early stopping at epoch 303
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9918, MSE = 6.8358e-04
# Y | Train_2 -> R² = 0.9925, MSE = 8.0510e-04
# Y | Test_1 -> R² = 0.8710, MSE = 1.0527e-02
# Y | Test_2 -> R² = 0.9736, MSE = 2.7749e-03
# Y | Test_3 -> R² = -1.5609, MSE = 1.9600e-01
# Y | Val -> R² = 0.4828, MSE = 3.8408e-02
# Y | LSG_1 -> R² = -1.3171, MSE = 7.3651e-01
# Y | LSG_2 -> R² = -0.6529, MSE = 6.3975e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.202804 | Val Loss 0.871425
# Epoch 100 | Train Loss 0.391366 | Val Loss 0.615754
# Epoch 200 | Train Loss 0.382218 | Val Loss 0.625977
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.9870, MSE = 1.0874e-03
# Y | Train_2 -> R² = 0.9817, MSE = 1.9575e-03
# Y | Test_1 -> R² = 0.9655, MSE = 2.8130e-03
# Y | Test_2 -> R² = 0.9694, MSE = 3.2207e-03
# Y | Test_3 -> R² = -4.5885, MSE = 4.2772e-01
# Y | Val -> R² = 0.0988, MSE = 6.6916e-02
# Y | LSG_1 -> R² = -2.6685, MSE = 1.1661e+00
# Y | LSG_2 -> R² = -1.3639, MSE = 9.1491e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.187682 | Val Loss 0.889978
# Epoch 100 | Train Loss 0.391268 | Val Loss 0.618542
# Epoch 200 | Train Loss 0.390547 | Val Loss 0.623458
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3631.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9893, MSE = 8.9052e-04
# Y | Train_2 -> R² = 0.9897, MSE = 1.0966e-03
# Y | Test_1 -> R² = 0.8993, MSE = 8.2144e-03
# Y | Test_2 -> R² = 0.9792, MSE = 2.1891e-03
# Y | Test_3 -> R² = -4.2710, MSE = 4.0342e-01
# Y | Val -> R² = -0.5381, MSE = 1.1421e-01
# Y | LSG_1 -> R² = -3.5264, MSE = 1.4388e+00
# Y | LSG_2 -> R² = -1.8629, MSE = 1.1081e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.198994 | Val Loss 0.868978
# Epoch 100 | Train Loss 0.391311 | Val Loss 0.621766
# Epoch 200 | Train Loss 0.382940 | Val Loss 0.637983
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7576.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9862, MSE = 1.1506e-03
# Y | Train_2 -> R² = 0.9887, MSE = 1.2063e-03
# Y | Test_1 -> R² = 0.9333, MSE = 5.4409e-03
# Y | Test_2 -> R² = 0.9780, MSE = 2.3192e-03
# Y | Test_3 -> R² = -3.9751, MSE = 3.8078e-01
# Y | Val -> R² = -0.3731, MSE = 1.0196e-01
# Y | LSG_1 -> R² = -3.4734, MSE = 1.4219e+00
# Y | LSG_2 -> R² = -1.6994, MSE = 1.0447e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.226676 | Val Loss 0.831051
# Epoch 100 | Train Loss 0.389914 | Val Loss 0.609028
# Epoch 200 | Train Loss 0.380937 | Val Loss 0.616508
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed9426.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9885, MSE = 9.6099e-04
# Y | Train_2 -> R² = 0.9896, MSE = 1.1067e-03
# Y | Test_1 -> R² = 0.9469, MSE = 4.3311e-03
# Y | Test_2 -> R² = 0.9805, MSE = 2.0564e-03
# Y | Test_3 -> R² = -3.6018, MSE = 3.5221e-01
# Y | Val -> R² = 0.1958, MSE = 5.9714e-02
# Y | LSG_1 -> R² = -1.8631, MSE = 9.1006e-01
# Y | LSG_2 -> R² = -0.7351, MSE = 6.7156e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.160908 | Val Loss 0.842347
# Epoch 100 | Train Loss 0.390653 | Val Loss 0.627071
# Epoch 200 | Train Loss 0.380990 | Val Loss 0.631306
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2664.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9882, MSE = 9.8261e-04
# Y | Train_2 -> R² = 0.9884, MSE = 1.2365e-03
# Y | Test_1 -> R² = 0.8574, MSE = 1.1633e-02
# Y | Test_2 -> R² = 0.9805, MSE = 2.0485e-03
# Y | Test_3 -> R² = -4.9447, MSE = 4.5499e-01
# Y | Val -> R² = -0.7825, MSE = 1.3236e-01
# Y | LSG_1 -> R² = -4.0904, MSE = 1.6181e+00
# Y | LSG_2 -> R² = -2.1288, MSE = 1.2110e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.282658 | Val Loss 0.843808
# Epoch 100 | Train Loss 0.392601 | Val Loss 0.619549
# Epoch 200 | Train Loss 0.383156 | Val Loss 0.622791
# Early stopping at epoch 272
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed421.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed421.weights.h5
# Y | Train_1 -> R² = 0.9917, MSE = 6.9471e-04
# Y | Train_2 -> R² = 0.9856, MSE = 1.5334e-03
# Y | Test_1 -> R² = 0.9020, MSE = 7.9994e-03
# Y | Test_2 -> R² = 0.9803, MSE = 2.0719e-03
# Y | Test_3 -> R² = -5.3172, MSE = 4.8349e-01
# Y | Val -> R² = -0.4071, MSE = 1.0449e-01
# Y | LSG_1 -> R² = -3.5271, MSE = 1.4390e+00
# Y | LSG_2 -> R² = -1.7992, MSE = 1.0834e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=421 salvo.
# Epoch 0 | Train Loss 1.535208 | Val Loss 0.906715
# Epoch 100 | Train Loss 0.766176 | Val Loss 0.613589
# Epoch 200 | Train Loss 0.752755 | Val Loss 0.629045
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3631.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9876, MSE = 1.0378e-03
# Y | Train_2 -> R² = 0.9110, MSE = 9.5015e-03
# Y | Test_1 -> R² = 0.7467, MSE = 2.0673e-02
# Y | Test_2 -> R² = 0.9264, MSE = 7.7513e-03
# Y | Test_3 -> R² = -4.6409, MSE = 4.3173e-01
# Y | Val -> R² = -0.6587, MSE = 1.2317e-01
# Y | LSG_1 -> R² = -5.7453, MSE = 2.1441e+00
# Y | LSG_2 -> R² = -3.2045, MSE = 1.6273e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3631 salvo.
# Epoch 0 | Train Loss 1.480685 | Val Loss 0.934078
# Epoch 100 | Train Loss 0.767984 | Val Loss 0.604373
# Epoch 200 | Train Loss 0.753607 | Val Loss 0.630657
# Early stopping at epoch 285
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7576.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9803, MSE = 1.6428e-03
# Y | Train_2 -> R² = 0.7227, MSE = 2.9603e-02
# Y | Test_1 -> R² = 0.9427, MSE = 4.6796e-03
# Y | Test_2 -> R² = 0.7669, MSE = 2.4535e-02
# Y | Test_3 -> R² = -2.1593, MSE = 2.4180e-01
# Y | Val -> R² = 0.3894, MSE = 4.5339e-02
# Y | LSG_1 -> R² = -5.1995, MSE = 1.9706e+00
# Y | LSG_2 -> R² = -3.4055, MSE = 1.7051e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7576 salvo.
# Epoch 0 | Train Loss 1.663620 | Val Loss 0.814773
# Epoch 100 | Train Loss 0.768397 | Val Loss 0.605684
# Epoch 200 | Train Loss 0.752877 | Val Loss 0.620511
# Epoch 300 | Train Loss 0.741928 | Val Loss 0.647631
# Early stopping at epoch 336
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed9426.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9908, MSE = 7.7049e-04
# Y | Train_2 -> R² = 0.9815, MSE = 1.9732e-03
# Y | Test_1 -> R² = 0.9613, MSE = 3.1570e-03
# Y | Test_2 -> R² = 0.9873, MSE = 1.3415e-03
# Y | Test_3 -> R² = -2.6002, MSE = 2.7554e-01
# Y | Val -> R² = 0.3869, MSE = 4.5525e-02
# Y | LSG_1 -> R² = -2.3958, MSE = 1.0794e+00
# Y | LSG_2 -> R² = -1.3828, MSE = 9.2222e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=9426 salvo.
# Epoch 0 | Train Loss 1.520275 | Val Loss 0.843395
# Epoch 100 | Train Loss 0.766440 | Val Loss 0.609540
# Epoch 200 | Train Loss 0.751088 | Val Loss 0.622939
# Epoch 300 | Train Loss 0.738980 | Val Loss 0.656981
# Early stopping at epoch 325
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2664.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9847, MSE = 1.2806e-03
# Y | Train_2 -> R² = 0.9296, MSE = 7.5140e-03
# Y | Test_1 -> R² = 0.8927, MSE = 8.7581e-03
# Y | Test_2 -> R² = 0.9518, MSE = 5.0685e-03
# Y | Test_3 -> R² = -2.5034, MSE = 2.6813e-01
# Y | Val -> R² = 0.0756, MSE = 6.8643e-02
# Y | LSG_1 -> R² = -4.1810, MSE = 1.6468e+00
# Y | LSG_2 -> R² = -2.2071, MSE = 1.2413e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2664 salvo.
# Epoch 0 | Train Loss 1.554324 | Val Loss 0.894382
# Epoch 100 | Train Loss 0.765845 | Val Loss 0.602868
# Epoch 200 | Train Loss 0.752727 | Val Loss 0.619098
# Epoch 300 | Train Loss 0.741193 | Val Loss 0.646329
# Early stopping at epoch 304
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9896, MSE = 8.7038e-04
# Y | Train_2 -> R² = 0.9537, MSE = 4.9424e-03
# Y | Test_1 -> R² = 0.9624, MSE = 3.0641e-03
# Y | Test_2 -> R² = 0.9586, MSE = 4.3556e-03
# Y | Test_3 -> R² = -4.1637, MSE = 3.9521e-01
# Y | Val -> R² = 0.2407, MSE = 5.6386e-02
# Y | LSG_1 -> R² = -3.5159, MSE = 1.4354e+00
# Y | LSG_2 -> R² = -1.7934, MSE = 1.0812e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=421 salvo.
# Epoch 0 | Train Loss 1.686122 | Val Loss 0.841981
# Epoch 100 | Train Loss 0.769641 | Val Loss 0.606597
# Epoch 200 | Train Loss 0.755093 | Val Loss 0.613525
# Epoch 300 | Train Loss 0.743591 | Val Loss 0.644056
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3631.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3631.weights.h5
# Y | Train_1 -> R² = 0.9785, MSE = 1.7906e-03
# Y | Train_2 -> R² = 0.5281, MSE = 5.0389e-02
# Y | Test_1 -> R² = 0.9600, MSE = 3.2676e-03
# Y | Test_2 -> R² = 0.6150, MSE = 4.0524e-02
# Y | Test_3 -> R² = -1.8396, MSE = 2.1733e-01
# Y | Val -> R² = -0.0136, MSE = 7.5263e-02
# Y | LSG_1 -> R² = -3.2717, MSE = 1.3578e+00
# Y | LSG_2 -> R² = -2.0142, MSE = 1.1666e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3631 salvo.
# Epoch 0 | Train Loss 1.509902 | Val Loss 0.946476
# Epoch 100 | Train Loss 0.764585 | Val Loss 0.612817
# Epoch 200 | Train Loss 0.749523 | Val Loss 0.634242
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7576.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7576.weights.h5
# Y | Train_1 -> R² = 0.9745, MSE = 2.1264e-03
# Y | Train_2 -> R² = 0.6520, MSE = 3.7155e-02
# Y | Test_1 -> R² = 0.8747, MSE = 1.0221e-02
# Y | Test_2 -> R² = 0.6545, MSE = 3.6367e-02
# Y | Test_3 -> R² = -3.0920, MSE = 3.1319e-01
# Y | Val -> R² = 0.3156, MSE = 5.0823e-02
# Y | LSG_1 -> R² = -3.2190, MSE = 1.3411e+00
# Y | LSG_2 -> R² = -2.0204, MSE = 1.1690e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7576 salvo.
# Epoch 0 | Train Loss 1.597588 | Val Loss 0.862422
# Epoch 100 | Train Loss 0.767775 | Val Loss 0.607211
# Epoch 200 | Train Loss 0.752321 | Val Loss 0.615221
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed9426.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed9426.weights.h5
# Y | Train_1 -> R² = 0.9908, MSE = 7.6873e-04
# Y | Train_2 -> R² = 0.9899, MSE = 1.0773e-03
# Y | Test_1 -> R² = 0.9204, MSE = 6.4938e-03
# Y | Test_2 -> R² = 0.9805, MSE = 2.0511e-03
# Y | Test_3 -> R² = -5.6345, MSE = 5.0778e-01
# Y | Val -> R² = -0.2567, MSE = 9.3320e-02
# Y | LSG_1 -> R² = -3.2475, MSE = 1.3501e+00
# Y | LSG_2 -> R² = -1.8045, MSE = 1.0854e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=9426 salvo.
# Epoch 0 | Train Loss 1.539298 | Val Loss 0.857371
# Epoch 100 | Train Loss 0.765340 | Val Loss 0.606760
# Epoch 200 | Train Loss 0.757087 | Val Loss 0.623166
# Epoch 300 | Train Loss 0.740136 | Val Loss 0.670811
# Early stopping at epoch 324
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2664.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2664.weights.h5
# Y | Train_1 -> R² = 0.9839, MSE = 1.3475e-03
# Y | Train_2 -> R² = 0.7434, MSE = 2.7400e-02
# Y | Test_1 -> R² = 0.9478, MSE = 4.2608e-03
# Y | Test_2 -> R² = 0.7953, MSE = 2.1546e-02
# Y | Test_3 -> R² = -2.8491, MSE = 2.9460e-01
# Y | Val -> R² = -0.0204, MSE = 7.5768e-02
# Y | LSG_1 -> R² = -3.7501, MSE = 1.5099e+00
# Y | LSG_2 -> R² = -2.0438, MSE = 1.1781e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2664 salvo.
# Epoch 0 | Train Loss 1.544105 | Val Loss 0.915946
# Epoch 100 | Train Loss 0.767277 | Val Loss 0.610357
# Epoch 200 | Train Loss 0.753384 | Val Loss 0.613216
# Epoch 300 | Train Loss 0.741646 | Val Loss 0.640152
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed421.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed421.weights.h5
# Y | Train_1 -> R² = 0.9843, MSE = 1.3131e-03
# Y | Train_2 -> R² = 0.7283, MSE = 2.9009e-02
# Y | Test_1 -> R² = 0.9667, MSE = 2.7146e-03
# Y | Test_2 -> R² = 0.7838, MSE = 2.2762e-02
# Y | Test_3 -> R² = -1.9487, MSE = 2.2569e-01
# Y | Val -> R² = 0.1267, MSE = 6.4848e-02
# Y | LSG_1 -> R² = -3.2985, MSE = 1.3663e+00
# Y | LSG_2 -> R² = -1.9786, MSE = 1.1528e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=421 salvo.
