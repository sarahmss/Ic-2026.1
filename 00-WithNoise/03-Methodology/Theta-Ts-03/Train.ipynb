# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 4)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.966126 | Val Loss 0.795275
# Epoch 100 | Train Loss 0.793131 | Val Loss 0.560826
# Epoch 200 | Train Loss 0.708483 | Val Loss 0.531739
# Epoch 300 | Train Loss 0.666600 | Val Loss 0.561126
# Early stopping at epoch 390
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7877, MSE = 4.8308e-02
# Theta | Train_2 -> R² = 0.6344, MSE = 8.3461e-02
# Theta | Test_1 -> R² = 0.4908, MSE = 1.1665e-01
# Theta | Test_2 -> R² = 0.8614, MSE = 3.2877e-02
# Theta | Test_3 -> R² = 0.6035, MSE = 1.3006e-01
# Theta | Val -> R² = -1.9679, MSE = 9.6882e-01
# Theta | LSG_1 -> R² = 0.6929, MSE = 1.2818e-01
# Theta | LSG_2 -> R² = -2.5164, MSE = 1.2308e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 0.986005 | Val Loss 0.826872
# Epoch 100 | Train Loss 0.771150 | Val Loss 0.551954
# Epoch 200 | Train Loss 0.693771 | Val Loss 0.559921
# Epoch 300 | Train Loss 0.664664 | Val Loss 0.570096
# Early stopping at epoch 342
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7244, MSE = 6.2719e-02
# Theta | Train_2 -> R² = 0.5457, MSE = 1.0371e-01
# Theta | Test_1 -> R² = 0.2476, MSE = 1.7236e-01
# Theta | Test_2 -> R² = 0.8599, MSE = 3.3214e-02
# Theta | Test_3 -> R² = 0.6901, MSE = 1.0164e-01
# Theta | Val -> R² = -2.6871, MSE = 1.2036e+00
# Theta | LSG_1 -> R² = 0.5122, MSE = 2.0364e-01
# Theta | LSG_2 -> R² = -3.0237, MSE = 1.4083e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.994622 | Val Loss 0.851932
# Epoch 100 | Train Loss 0.777730 | Val Loss 0.555898
# Epoch 200 | Train Loss 0.702241 | Val Loss 0.547632
# Epoch 300 | Train Loss 0.665135 | Val Loss 0.577228
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7925, MSE = 4.7218e-02
# Theta | Train_2 -> R² = 0.6140, MSE = 8.8110e-02
# Theta | Test_1 -> R² = 0.5350, MSE = 1.0653e-01
# Theta | Test_2 -> R² = 0.8673, MSE = 3.1458e-02
# Theta | Test_3 -> R² = 0.7165, MSE = 9.2998e-02
# Theta | Val -> R² = -1.0695, MSE = 6.7554e-01
# Theta | LSG_1 -> R² = 0.7491, MSE = 1.0472e-01
# Theta | LSG_2 -> R² = -1.7729, MSE = 9.7051e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.974681 | Val Loss 0.790591
# Epoch 100 | Train Loss 0.796927 | Val Loss 0.563035
# Epoch 200 | Train Loss 0.724615 | Val Loss 0.536897
# Epoch 300 | Train Loss 0.670177 | Val Loss 0.556881
# Epoch 400 | Train Loss 0.655131 | Val Loss 0.557622
# Early stopping at epoch 412
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7951, MSE = 4.6633e-02
# Theta | Train_2 -> R² = 0.5970, MSE = 9.2007e-02
# Theta | Test_1 -> R² = 0.5406, MSE = 1.0525e-01
# Theta | Test_2 -> R² = 0.8678, MSE = 3.1342e-02
# Theta | Test_3 -> R² = 0.7550, MSE = 8.0357e-02
# Theta | Val -> R² = -0.4840, MSE = 4.8441e-01
# Theta | LSG_1 -> R² = 0.7874, MSE = 8.8760e-02
# Theta | LSG_2 -> R² = -1.0585, MSE = 7.2049e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.983959 | Val Loss 0.826196
# Epoch 100 | Train Loss 0.767561 | Val Loss 0.558490
# Epoch 200 | Train Loss 0.696340 | Val Loss 0.542625
# Epoch 300 | Train Loss 0.667838 | Val Loss 0.546462
# Early stopping at epoch 369
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7584, MSE = 5.4974e-02
# Theta | Train_2 -> R² = 0.6051, MSE = 9.0162e-02
# Theta | Test_1 -> R² = 0.3251, MSE = 1.5460e-01
# Theta | Test_2 -> R² = 0.8563, MSE = 3.4068e-02
# Theta | Test_3 -> R² = 0.7407, MSE = 8.5051e-02
# Theta | Val -> R² = -1.1954, MSE = 7.1665e-01
# Theta | LSG_1 -> R² = 0.6866, MSE = 1.3081e-01
# Theta | LSG_2 -> R² = -2.5709, MSE = 1.2498e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.996320 | Val Loss 0.849384
# Epoch 100 | Train Loss 0.791409 | Val Loss 0.557540
# Epoch 200 | Train Loss 0.706210 | Val Loss 0.543168
# Epoch 300 | Train Loss 0.670042 | Val Loss 0.567779
# Early stopping at epoch 359
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7543, MSE = 5.5918e-02
# Theta | Train_2 -> R² = 0.6225, MSE = 8.6178e-02
# Theta | Test_1 -> R² = 0.2964, MSE = 1.6117e-01
# Theta | Test_2 -> R² = 0.8543, MSE = 3.4559e-02
# Theta | Test_3 -> R² = 0.6956, MSE = 9.9841e-02
# Theta | Val -> R² = -2.0362, MSE = 9.9113e-01
# Theta | LSG_1 -> R² = 0.7319, MSE = 1.1190e-01
# Theta | LSG_2 -> R² = -2.0282, MSE = 1.0599e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.983613 | Val Loss 0.826781
# Epoch 100 | Train Loss 0.793930 | Val Loss 0.564013
# Epoch 200 | Train Loss 0.704825 | Val Loss 0.535879
# Epoch 300 | Train Loss 0.666758 | Val Loss 0.568277
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7837, MSE = 4.9234e-02
# Theta | Train_2 -> R² = 0.6125, MSE = 8.8469e-02
# Theta | Test_1 -> R² = 0.4911, MSE = 1.1657e-01
# Theta | Test_2 -> R² = 0.8626, MSE = 3.2583e-02
# Theta | Test_3 -> R² = 0.6313, MSE = 1.2093e-01
# Theta | Val -> R² = -1.7493, MSE = 8.9744e-01
# Theta | LSG_1 -> R² = 0.6804, MSE = 1.3343e-01
# Theta | LSG_2 -> R² = -2.4359, MSE = 1.2026e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 1.003611 | Val Loss 0.864569
# Epoch 100 | Train Loss 0.793935 | Val Loss 0.558658
# Epoch 200 | Train Loss 0.713368 | Val Loss 0.544128
# Epoch 300 | Train Loss 0.666780 | Val Loss 0.565742
# Early stopping at epoch 364
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7815, MSE = 4.9717e-02
# Theta | Train_2 -> R² = 0.6374, MSE = 8.2778e-02
# Theta | Test_1 -> R² = 0.4826, MSE = 1.1852e-01
# Theta | Test_2 -> R² = 0.8664, MSE = 3.1681e-02
# Theta | Test_3 -> R² = 0.6897, MSE = 1.0177e-01
# Theta | Val -> R² = -1.3337, MSE = 7.6178e-01
# Theta | LSG_1 -> R² = 0.7677, MSE = 9.6965e-02
# Theta | LSG_2 -> R² = -1.4723, MSE = 8.6532e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 1.027615 | Val Loss 0.873571
# Epoch 100 | Train Loss 0.782694 | Val Loss 0.556788
# Epoch 200 | Train Loss 0.710315 | Val Loss 0.536969
# Epoch 300 | Train Loss 0.676506 | Val Loss 0.547390
# Early stopping at epoch 393
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7749, MSE = 5.1231e-02
# Theta | Train_2 -> R² = 0.6354, MSE = 8.3223e-02
# Theta | Test_1 -> R² = 0.4176, MSE = 1.3341e-01
# Theta | Test_2 -> R² = 0.8546, MSE = 3.4477e-02
# Theta | Test_3 -> R² = 0.7237, MSE = 9.0632e-02
# Theta | Val -> R² = -0.6570, MSE = 5.4089e-01
# Theta | LSG_1 -> R² = 0.7934, MSE = 8.6227e-02
# Theta | LSG_2 -> R² = -1.0165, MSE = 7.0577e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.997884 | Val Loss 0.852406
# Epoch 100 | Train Loss 0.781524 | Val Loss 0.555855
# Epoch 200 | Train Loss 0.698775 | Val Loss 0.546323
# Epoch 300 | Train Loss 0.667164 | Val Loss 0.564109
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7700, MSE = 5.2337e-02
# Theta | Train_2 -> R² = 0.5808, MSE = 9.5692e-02
# Theta | Test_1 -> R² = 0.4014, MSE = 1.3714e-01
# Theta | Test_2 -> R² = 0.8658, MSE = 3.1829e-02
# Theta | Test_3 -> R² = 0.7280, MSE = 8.9234e-02
# Theta | Val -> R² = -1.7086, MSE = 8.8418e-01
# Theta | LSG_1 -> R² = 0.7135, MSE = 1.1962e-01
# Theta | LSG_2 -> R² = -2.2481, MSE = 1.1369e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 0.961754 | Val Loss 0.812183
# Epoch 100 | Train Loss 0.685106 | Val Loss 0.626217
# Epoch 200 | Train Loss 0.672408 | Val Loss 0.607758
# Early stopping at epoch 257
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7733, MSE = 5.1604e-02
# Theta | Train_2 -> R² = 0.5542, MSE = 1.0176e-01
# Theta | Test_1 -> R² = 0.4546, MSE = 1.2495e-01
# Theta | Test_2 -> R² = 0.8683, MSE = 3.1236e-02
# Theta | Test_3 -> R² = -0.0234, MSE = 3.3568e-01
# Theta | Val -> R² = -8.2632, MSE = 3.0238e+00
# Theta | LSG_1 -> R² = 0.2364, MSE = 3.1878e-01
# Theta | LSG_2 -> R² = -3.2958, MSE = 1.5036e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 1.028927 | Val Loss 0.878476
# Epoch 100 | Train Loss 0.687652 | Val Loss 0.624657
# Epoch 200 | Train Loss 0.674626 | Val Loss 0.609294
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7971, MSE = 4.6186e-02
# Theta | Train_2 -> R² = 0.5918, MSE = 9.3185e-02
# Theta | Test_1 -> R² = 0.5099, MSE = 1.1227e-01
# Theta | Test_2 -> R² = 0.8767, MSE = 2.9243e-02
# Theta | Test_3 -> R² = -0.1189, MSE = 3.6701e-01
# Theta | Val -> R² = -8.6914, MSE = 3.1636e+00
# Theta | LSG_1 -> R² = 0.1894, MSE = 3.3840e-01
# Theta | LSG_2 -> R² = -3.5356, MSE = 1.5875e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.994554 | Val Loss 0.858576
# Epoch 100 | Train Loss 0.687665 | Val Loss 0.638510
# Epoch 200 | Train Loss 0.673841 | Val Loss 0.608891
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7903, MSE = 4.7730e-02
# Theta | Train_2 -> R² = 0.5707, MSE = 9.8009e-02
# Theta | Test_1 -> R² = 0.4583, MSE = 1.2409e-01
# Theta | Test_2 -> R² = 0.8706, MSE = 3.0695e-02
# Theta | Test_3 -> R² = 0.0352, MSE = 3.1647e-01
# Theta | Val -> R² = -8.4559, MSE = 3.0867e+00
# Theta | LSG_1 -> R² = 0.1573, MSE = 3.5181e-01
# Theta | LSG_2 -> R² = -3.5587, MSE = 1.5956e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.969408 | Val Loss 0.809121
# Epoch 100 | Train Loss 0.684126 | Val Loss 0.627533
# Epoch 200 | Train Loss 0.669085 | Val Loss 0.587477
# Early stopping at epoch 259
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7786, MSE = 5.0387e-02
# Theta | Train_2 -> R² = 0.6121, MSE = 8.8551e-02
# Theta | Test_1 -> R² = 0.5396, MSE = 1.0546e-01
# Theta | Test_2 -> R² = 0.8841, MSE = 2.7481e-02
# Theta | Test_3 -> R² = -0.4672, MSE = 4.8127e-01
# Theta | Val -> R² = -9.2772, MSE = 3.3548e+00
# Theta | LSG_1 -> R² = 0.2238, MSE = 3.2403e-01
# Theta | LSG_2 -> R² = -3.4079, MSE = 1.5428e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.972689 | Val Loss 0.815156
# Epoch 100 | Train Loss 0.684653 | Val Loss 0.624802
# Epoch 200 | Train Loss 0.673972 | Val Loss 0.606699
# Early stopping at epoch 255
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7740, MSE = 5.1423e-02
# Theta | Train_2 -> R² = 0.5908, MSE = 9.3413e-02
# Theta | Test_1 -> R² = 0.4962, MSE = 1.1542e-01
# Theta | Test_2 -> R² = 0.8816, MSE = 2.8088e-02
# Theta | Test_3 -> R² = -0.1822, MSE = 3.8777e-01
# Theta | Val -> R² = -8.4331, MSE = 3.0793e+00
# Theta | LSG_1 -> R² = 0.2655, MSE = 3.0664e-01
# Theta | LSG_2 -> R² = -3.2440, MSE = 1.4854e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.964785 | Val Loss 0.809260
# Epoch 100 | Train Loss 0.684149 | Val Loss 0.631953
# Epoch 200 | Train Loss 0.668765 | Val Loss 0.588284
# Epoch 300 | Train Loss 0.656798 | Val Loss 0.573432
# Epoch 400 | Train Loss 0.616766 | Val Loss 0.627466
# Early stopping at epoch 461
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7822, MSE = 4.9574e-02
# Theta | Train_2 -> R² = 0.8321, MSE = 3.8325e-02
# Theta | Test_1 -> R² = 0.4085, MSE = 1.3551e-01
# Theta | Test_2 -> R² = 0.6550, MSE = 8.1810e-02
# Theta | Test_3 -> R² = -0.7877, MSE = 5.8639e-01
# Theta | Val -> R² = -4.6047, MSE = 1.8295e+00
# Theta | LSG_1 -> R² = 0.1447, MSE = 3.5704e-01
# Theta | LSG_2 -> R² = -5.3349, MSE = 2.2173e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.997124 | Val Loss 0.853860
# Epoch 100 | Train Loss 0.687799 | Val Loss 0.642431
# Epoch 200 | Train Loss 0.672560 | Val Loss 0.613490
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7989, MSE = 4.5758e-02
# Theta | Train_2 -> R² = 0.5846, MSE = 9.4831e-02
# Theta | Test_1 -> R² = 0.5649, MSE = 9.9668e-02
# Theta | Test_2 -> R² = 0.8725, MSE = 3.0244e-02
# Theta | Test_3 -> R² = -0.2792, MSE = 4.1959e-01
# Theta | Val -> R² = -9.2807, MSE = 3.3560e+00
# Theta | LSG_1 -> R² = 0.1715, MSE = 3.4585e-01
# Theta | LSG_2 -> R² = -3.5107, MSE = 1.5788e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 0.980821 | Val Loss 0.834033
# Epoch 100 | Train Loss 0.686596 | Val Loss 0.620111
# Epoch 200 | Train Loss 0.671163 | Val Loss 0.596370
# Early stopping at epoch 265
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7936, MSE = 4.6965e-02
# Theta | Train_2 -> R² = 0.5673, MSE = 9.8776e-02
# Theta | Test_1 -> R² = 0.4653, MSE = 1.2250e-01
# Theta | Test_2 -> R² = 0.8744, MSE = 2.9782e-02
# Theta | Test_3 -> R² = 0.1069, MSE = 2.9294e-01
# Theta | Val -> R² = -7.6781, MSE = 2.8328e+00
# Theta | LSG_1 -> R² = 0.3131, MSE = 2.8674e-01
# Theta | LSG_2 -> R² = -3.0735, MSE = 1.4257e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 0.983535 | Val Loss 0.824408
# Epoch 100 | Train Loss 0.688642 | Val Loss 0.645848
# Epoch 200 | Train Loss 0.673020 | Val Loss 0.608826
# Early stopping at epoch 255
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7921, MSE = 4.7319e-02
# Theta | Train_2 -> R² = 0.5647, MSE = 9.9366e-02
# Theta | Test_1 -> R² = 0.5999, MSE = 9.1659e-02
# Theta | Test_2 -> R² = 0.8594, MSE = 3.3334e-02
# Theta | Test_3 -> R² = -0.3532, MSE = 4.4386e-01
# Theta | Val -> R² = -9.2451, MSE = 3.3443e+00
# Theta | LSG_1 -> R² = 0.2060, MSE = 3.3147e-01
# Theta | LSG_2 -> R² = -3.2857, MSE = 1.5000e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.973109 | Val Loss 0.822500
# Epoch 100 | Train Loss 0.684325 | Val Loss 0.619382
# Epoch 200 | Train Loss 0.669289 | Val Loss 0.590944
# Early stopping at epoch 264
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7827, MSE = 4.9455e-02
# Theta | Train_2 -> R² = 0.5555, MSE = 1.0147e-01
# Theta | Test_1 -> R² = 0.4188, MSE = 1.3313e-01
# Theta | Test_2 -> R² = 0.8709, MSE = 3.0616e-02
# Theta | Test_3 -> R² = 0.1565, MSE = 2.7668e-01
# Theta | Val -> R² = -7.7124, MSE = 2.8440e+00
# Theta | LSG_1 -> R² = 0.2537, MSE = 3.1155e-01
# Theta | LSG_2 -> R² = -3.3071, MSE = 1.5075e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 0.999148 | Val Loss 0.811562
# Epoch 100 | Train Loss 0.742032 | Val Loss 0.543455
# Epoch 200 | Train Loss 0.666782 | Val Loss 0.530217
# Epoch 300 | Train Loss 0.652147 | Val Loss 0.540418
# Epoch 400 | Train Loss 0.614149 | Val Loss 0.661771
# Early stopping at epoch 428
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.8185, MSE = 4.1304e-02
# Theta | Train_2 -> R² = 0.7266, MSE = 6.2413e-02
# Theta | Test_1 -> R² = 0.6636, MSE = 7.7059e-02
# Theta | Test_2 -> R² = 0.8342, MSE = 3.9320e-02
# Theta | Test_3 -> R² = 0.7186, MSE = 9.2315e-02
# Theta | Val -> R² = 0.5617, MSE = 1.4307e-01
# Theta | LSG_1 -> R² = 0.6065, MSE = 1.6428e-01
# Theta | LSG_2 -> R² = -0.9360, MSE = 6.7761e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 1.012106 | Val Loss 0.818390
# Epoch 100 | Train Loss 0.752362 | Val Loss 0.549393
# Epoch 200 | Train Loss 0.669103 | Val Loss 0.539411
# Epoch 300 | Train Loss 0.653069 | Val Loss 0.558020
# Early stopping at epoch 350
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7770, MSE = 5.0761e-02
# Theta | Train_2 -> R² = 0.6140, MSE = 8.8108e-02
# Theta | Test_1 -> R² = 0.3800, MSE = 1.4202e-01
# Theta | Test_2 -> R² = 0.8649, MSE = 3.2028e-02
# Theta | Test_3 -> R² = 0.7344, MSE = 8.7124e-02
# Theta | Val -> R² = -0.5307, MSE = 4.9966e-01
# Theta | LSG_1 -> R² = 0.7729, MSE = 9.4810e-02
# Theta | LSG_2 -> R² = -2.1053, MSE = 1.0869e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.984783 | Val Loss 0.823831
# Epoch 100 | Train Loss 0.735969 | Val Loss 0.545608
# Epoch 200 | Train Loss 0.665089 | Val Loss 0.518004
# Epoch 300 | Train Loss 0.648985 | Val Loss 0.561581
# Early stopping at epoch 388
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.8308, MSE = 3.8504e-02
# Theta | Train_2 -> R² = 0.7379, MSE = 5.9826e-02
# Theta | Test_1 -> R² = 0.6462, MSE = 8.1042e-02
# Theta | Test_2 -> R² = 0.8618, MSE = 3.2763e-02
# Theta | Test_3 -> R² = 0.6709, MSE = 1.0794e-01
# Theta | Val -> R² = -0.5457, MSE = 5.0457e-01
# Theta | LSG_1 -> R² = 0.7660, MSE = 9.7677e-02
# Theta | LSG_2 -> R² = -2.0326, MSE = 1.0614e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.966308 | Val Loss 0.773861
# Epoch 100 | Train Loss 0.726372 | Val Loss 0.542858
# Epoch 200 | Train Loss 0.661296 | Val Loss 0.522582
# Epoch 300 | Train Loss 0.646295 | Val Loss 0.533610
# Epoch 400 | Train Loss 0.603700 | Val Loss 0.719561
# Early stopping at epoch 411
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7989, MSE = 4.5758e-02
# Theta | Train_2 -> R² = 0.7224, MSE = 6.3381e-02
# Theta | Test_1 -> R² = 0.5943, MSE = 9.2937e-02
# Theta | Test_2 -> R² = 0.8409, MSE = 3.7734e-02
# Theta | Test_3 -> R² = 0.6896, MSE = 1.0183e-01
# Theta | Val -> R² = 0.2851, MSE = 2.3338e-01
# Theta | LSG_1 -> R² = 0.6928, MSE = 1.2825e-01
# Theta | LSG_2 -> R² = -1.3792, MSE = 8.3272e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.983765 | Val Loss 0.816630
# Epoch 100 | Train Loss 0.726724 | Val Loss 0.543382
# Epoch 200 | Train Loss 0.664765 | Val Loss 0.535221
# Epoch 300 | Train Loss 0.649963 | Val Loss 0.570237
# Epoch 400 | Train Loss 0.620059 | Val Loss 0.724431
# Early stopping at epoch 404
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.8225, MSE = 4.0396e-02
# Theta | Train_2 -> R² = 0.7195, MSE = 6.4028e-02
# Theta | Test_1 -> R² = 0.6395, MSE = 8.2579e-02
# Theta | Test_2 -> R² = 0.8522, MSE = 3.5049e-02
# Theta | Test_3 -> R² = 0.7653, MSE = 7.7000e-02
# Theta | Val -> R² = 0.6167, MSE = 1.2513e-01
# Theta | LSG_1 -> R² = 0.6176, MSE = 1.5963e-01
# Theta | LSG_2 -> R² = -1.1057, MSE = 7.3701e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.989394 | Val Loss 0.790171
# Epoch 100 | Train Loss 0.731602 | Val Loss 0.544219
# Epoch 200 | Train Loss 0.664013 | Val Loss 0.537849
# Epoch 300 | Train Loss 0.651403 | Val Loss 0.567692
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7923, MSE = 4.7261e-02
# Theta | Train_2 -> R² = 0.6356, MSE = 8.3190e-02
# Theta | Test_1 -> R² = 0.3964, MSE = 1.3827e-01
# Theta | Test_2 -> R² = 0.8621, MSE = 3.2710e-02
# Theta | Test_3 -> R² = 0.7409, MSE = 8.4995e-02
# Theta | Val -> R² = -0.4925, MSE = 4.8720e-01
# Theta | LSG_1 -> R² = 0.7616, MSE = 9.9501e-02
# Theta | LSG_2 -> R² = -2.6586, MSE = 1.2805e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.980255 | Val Loss 0.811952
# Epoch 100 | Train Loss 0.713907 | Val Loss 0.543106
# Epoch 200 | Train Loss 0.661416 | Val Loss 0.544748
# Epoch 300 | Train Loss 0.648541 | Val Loss 0.602119
# Early stopping at epoch 311
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7238, MSE = 6.2855e-02
# Theta | Train_2 -> R² = 0.6090, MSE = 8.9263e-02
# Theta | Test_1 -> R² = 0.1206, MSE = 2.0145e-01
# Theta | Test_2 -> R² = 0.8406, MSE = 3.7788e-02
# Theta | Test_3 -> R² = 0.7119, MSE = 9.4511e-02
# Theta | Val -> R² = -2.5120, MSE = 1.1464e+00
# Theta | LSG_1 -> R² = 0.4022, MSE = 2.4955e-01
# Theta | LSG_2 -> R² = -4.1915, MSE = 1.8171e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 0.969527 | Val Loss 0.793009
# Epoch 100 | Train Loss 0.738333 | Val Loss 0.544020
# Epoch 200 | Train Loss 0.662630 | Val Loss 0.532744
# Epoch 300 | Train Loss 0.631396 | Val Loss 0.587283
# Early stopping at epoch 392
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.8088, MSE = 4.3512e-02
# Theta | Train_2 -> R² = 0.6944, MSE = 6.9773e-02
# Theta | Test_1 -> R² = 0.6075, MSE = 8.9915e-02
# Theta | Test_2 -> R² = 0.8505, MSE = 3.5442e-02
# Theta | Test_3 -> R² = 0.7635, MSE = 7.7565e-02
# Theta | Val -> R² = 0.6170, MSE = 1.2503e-01
# Theta | LSG_1 -> R² = 0.5891, MSE = 1.7153e-01
# Theta | LSG_2 -> R² = -0.9294, MSE = 6.7530e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 0.958668 | Val Loss 0.744389
# Epoch 100 | Train Loss 0.716334 | Val Loss 0.542025
# Epoch 200 | Train Loss 0.660450 | Val Loss 0.532300
# Epoch 300 | Train Loss 0.646821 | Val Loss 0.557329
# Early stopping at epoch 394
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.8071, MSE = 4.3893e-02
# Theta | Train_2 -> R² = 0.7072, MSE = 6.6833e-02
# Theta | Test_1 -> R² = 0.5417, MSE = 1.0499e-01
# Theta | Test_2 -> R² = 0.8588, MSE = 3.3480e-02
# Theta | Test_3 -> R² = 0.7538, MSE = 8.0763e-02
# Theta | Val -> R² = 0.1918, MSE = 2.6382e-01
# Theta | LSG_1 -> R² = 0.7184, MSE = 1.1754e-01
# Theta | LSG_2 -> R² = -1.9616, MSE = 1.0366e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.972166 | Val Loss 0.791290
# Epoch 100 | Train Loss 0.736726 | Val Loss 0.545720
# Epoch 200 | Train Loss 0.665557 | Val Loss 0.533163
# Epoch 300 | Train Loss 0.650481 | Val Loss 0.552444
# Epoch 400 | Train Loss 0.629407 | Val Loss 0.636813
# Early stopping at epoch 419
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.8145, MSE = 4.2209e-02
# Theta | Train_2 -> R² = 0.7344, MSE = 6.0632e-02
# Theta | Test_1 -> R² = 0.6565, MSE = 7.8690e-02
# Theta | Test_2 -> R² = 0.8477, MSE = 3.6115e-02
# Theta | Test_3 -> R² = 0.6702, MSE = 1.0817e-01
# Theta | Val -> R² = 0.5088, MSE = 1.6034e-01
# Theta | LSG_1 -> R² = 0.5275, MSE = 1.9725e-01
# Theta | LSG_2 -> R² = -1.0090, MSE = 7.0317e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 0.973277 | Val Loss 0.805128
# Epoch 100 | Train Loss 0.677088 | Val Loss 0.606514
# Epoch 200 | Train Loss 0.660235 | Val Loss 0.569495
# Epoch 300 | Train Loss 0.587702 | Val Loss 0.638534
# Epoch 400 | Train Loss 0.535829 | Val Loss 0.786894
# Early stopping at epoch 422
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.6206, MSE = 8.6355e-02
# Theta | Train_2 -> R² = 0.8070, MSE = 4.4067e-02
# Theta | Test_1 -> R² = 0.2142, MSE = 1.8001e-01
# Theta | Test_2 -> R² = 0.6546, MSE = 8.1909e-02
# Theta | Test_3 -> R² = -3.0281, MSE = 1.3213e+00
# Theta | Val -> R² = -5.8466, MSE = 2.2350e+00
# Theta | LSG_1 -> R² = 0.3494, MSE = 2.7161e-01
# Theta | LSG_2 -> R² = -3.8199, MSE = 1.6870e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 0.983054 | Val Loss 0.822665
# Epoch 100 | Train Loss 0.681674 | Val Loss 0.627751
# Epoch 200 | Train Loss 0.664336 | Val Loss 0.598620
# Early stopping at epoch 235
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7650, MSE = 5.3478e-02
# Theta | Train_2 -> R² = 0.5058, MSE = 1.1282e-01
# Theta | Test_1 -> R² = 0.6085, MSE = 8.9679e-02
# Theta | Test_2 -> R² = 0.8087, MSE = 4.5359e-02
# Theta | Test_3 -> R² = -0.7283, MSE = 5.6691e-01
# Theta | Val -> R² = -10.4806, MSE = 3.7476e+00
# Theta | LSG_1 -> R² = 0.1599, MSE = 3.5072e-01
# Theta | LSG_2 -> R² = -3.1909, MSE = 1.4668e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.960605 | Val Loss 0.804321
# Epoch 100 | Train Loss 0.679759 | Val Loss 0.619169
# Epoch 200 | Train Loss 0.664797 | Val Loss 0.586124
# Epoch 300 | Train Loss 0.609022 | Val Loss 0.632551
# Epoch 400 | Train Loss 0.541281 | Val Loss 0.805500
# Early stopping at epoch 434
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7102, MSE = 6.5945e-02
# Theta | Train_2 -> R² = 0.8012, MSE = 4.5388e-02
# Theta | Test_1 -> R² = 0.2768, MSE = 1.6567e-01
# Theta | Test_2 -> R² = 0.6975, MSE = 7.1725e-02
# Theta | Test_3 -> R² = -1.7098, MSE = 8.8885e-01
# Theta | Val -> R² = -5.1142, MSE = 1.9959e+00
# Theta | LSG_1 -> R² = 0.1888, MSE = 3.3865e-01
# Theta | LSG_2 -> R² = -5.2866, MSE = 2.2004e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.962435 | Val Loss 0.772845
# Epoch 100 | Train Loss 0.681768 | Val Loss 0.621838
# Epoch 200 | Train Loss 0.663599 | Val Loss 0.593121
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7873, MSE = 4.8412e-02
# Theta | Train_2 -> R² = 0.5409, MSE = 1.0481e-01
# Theta | Test_1 -> R² = 0.6900, MSE = 7.1022e-02
# Theta | Test_2 -> R² = 0.8369, MSE = 3.8669e-02
# Theta | Test_3 -> R² = -0.6666, MSE = 5.4666e-01
# Theta | Val -> R² = -10.0299, MSE = 3.6005e+00
# Theta | LSG_1 -> R² = 0.2476, MSE = 3.1408e-01
# Theta | LSG_2 -> R² = -2.8606, MSE = 1.3512e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.963392 | Val Loss 0.791392
# Epoch 100 | Train Loss 0.681050 | Val Loss 0.621967
# Epoch 200 | Train Loss 0.663282 | Val Loss 0.587608
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7983, MSE = 4.5896e-02
# Theta | Train_2 -> R² = 0.5663, MSE = 9.9009e-02
# Theta | Test_1 -> R² = 0.7132, MSE = 6.5708e-02
# Theta | Test_2 -> R² = 0.8579, MSE = 3.3694e-02
# Theta | Test_3 -> R² = -0.5743, MSE = 5.1640e-01
# Theta | Val -> R² = -9.4992, MSE = 3.4273e+00
# Theta | LSG_1 -> R² = 0.3044, MSE = 2.9037e-01
# Theta | LSG_2 -> R² = -2.7201, MSE = 1.3021e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.974689 | Val Loss 0.812543
# Epoch 100 | Train Loss 0.678784 | Val Loss 0.609238
# Epoch 200 | Train Loss 0.659641 | Val Loss 0.575960
# Epoch 300 | Train Loss 0.619433 | Val Loss 0.610270
# Epoch 400 | Train Loss 0.559501 | Val Loss 0.747676
# Early stopping at epoch 404
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.6723, MSE = 7.4585e-02
# Theta | Train_2 -> R² = 0.8328, MSE = 3.8166e-02
# Theta | Test_1 -> R² = 0.2458, MSE = 1.7278e-01
# Theta | Test_2 -> R² = 0.6735, MSE = 7.7413e-02
# Theta | Test_3 -> R² = -2.8085, MSE = 1.2492e+00
# Theta | Val -> R² = -6.7586, MSE = 2.5327e+00
# Theta | LSG_1 -> R² = 0.1830, MSE = 3.4106e-01
# Theta | LSG_2 -> R² = -5.4051, MSE = 2.2418e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.976265 | Val Loss 0.807546
# Epoch 100 | Train Loss 0.678510 | Val Loss 0.611416
# Epoch 200 | Train Loss 0.665083 | Val Loss 0.579383
# Epoch 300 | Train Loss 0.636114 | Val Loss 0.571087
# Epoch 400 | Train Loss 0.548659 | Val Loss 0.781113
# Early stopping at epoch 463
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.6769, MSE = 7.3540e-02
# Theta | Train_2 -> R² = 0.8206, MSE = 4.0950e-02
# Theta | Test_1 -> R² = 0.3087, MSE = 1.5835e-01
# Theta | Test_2 -> R² = 0.6827, MSE = 7.5243e-02
# Theta | Test_3 -> R² = -2.4303, MSE = 1.1252e+00
# Theta | Val -> R² = -5.9839, MSE = 2.2798e+00
# Theta | LSG_1 -> R² = 0.3126, MSE = 2.8696e-01
# Theta | LSG_2 -> R² = -4.3293, MSE = 1.8653e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 0.984396 | Val Loss 0.835439
# Epoch 100 | Train Loss 0.682791 | Val Loss 0.626130
# Epoch 200 | Train Loss 0.667079 | Val Loss 0.596159
# Early stopping at epoch 235
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7417, MSE = 5.8795e-02
# Theta | Train_2 -> R² = 0.4997, MSE = 1.1421e-01
# Theta | Test_1 -> R² = 0.5363, MSE = 1.0623e-01
# Theta | Test_2 -> R² = 0.7968, MSE = 4.8189e-02
# Theta | Test_3 -> R² = -0.8382, MSE = 6.0297e-01
# Theta | Val -> R² = -11.0497, MSE = 3.9334e+00
# Theta | LSG_1 -> R² = 0.0500, MSE = 3.9659e-01
# Theta | LSG_2 -> R² = -3.6131, MSE = 1.6146e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 0.993476 | Val Loss 0.809158
# Epoch 100 | Train Loss 0.685368 | Val Loss 0.638605
# Epoch 200 | Train Loss 0.668076 | Val Loss 0.597501
# Epoch 300 | Train Loss 0.643067 | Val Loss 0.600091
# Epoch 400 | Train Loss 0.573510 | Val Loss 0.776555
# Early stopping at epoch 458
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7485, MSE = 5.7232e-02
# Theta | Train_2 -> R² = 0.8196, MSE = 4.1178e-02
# Theta | Test_1 -> R² = 0.2967, MSE = 1.6112e-01
# Theta | Test_2 -> R² = 0.6761, MSE = 7.6811e-02
# Theta | Test_3 -> R² = -1.3783, MSE = 7.8011e-01
# Theta | Val -> R² = -6.5808, MSE = 2.4746e+00
# Theta | LSG_1 -> R² = -0.0881, MSE = 4.5424e-01
# Theta | LSG_2 -> R² = -6.7965, MSE = 2.7288e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 1.002776 | Val Loss 0.858672
# Epoch 100 | Train Loss 0.681133 | Val Loss 0.612134
# Epoch 200 | Train Loss 0.666812 | Val Loss 0.592375
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.8002, MSE = 4.5472e-02
# Theta | Train_2 -> R² = 0.5446, MSE = 1.0397e-01
# Theta | Test_1 -> R² = 0.6081, MSE = 8.9770e-02
# Theta | Test_2 -> R² = 0.8421, MSE = 3.7432e-02
# Theta | Test_3 -> R² = -0.3831, MSE = 4.5368e-01
# Theta | Val -> R² = -9.5929, MSE = 3.4579e+00
# Theta | LSG_1 -> R² = 0.1921, MSE = 3.3727e-01
# Theta | LSG_2 -> R² = -3.2654, MSE = 1.4929e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 1.040685 | Val Loss 0.873685
# Epoch 100 | Train Loss 0.682171 | Val Loss 0.535552
# Epoch 200 | Train Loss 0.656488 | Val Loss 0.513279
# Epoch 300 | Train Loss 0.641483 | Val Loss 0.518875
# Epoch 400 | Train Loss 0.596821 | Val Loss 0.709554
# Early stopping at epoch 471
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7815, MSE = 4.9722e-02
# Theta | Train_2 -> R² = 0.6957, MSE = 6.9466e-02
# Theta | Test_1 -> R² = 0.6339, MSE = 8.3858e-02
# Theta | Test_2 -> R² = 0.8364, MSE = 3.8787e-02
# Theta | Test_3 -> R² = 0.6022, MSE = 1.3049e-01
# Theta | Val -> R² = 0.3905, MSE = 1.9896e-01
# Theta | LSG_1 -> R² = 0.4930, MSE = 2.1166e-01
# Theta | LSG_2 -> R² = -1.0716, MSE = 7.2507e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 0.984281 | Val Loss 0.744001
# Epoch 100 | Train Loss 0.676270 | Val Loss 0.530952
# Epoch 200 | Train Loss 0.655303 | Val Loss 0.508999
# Epoch 300 | Train Loss 0.646540 | Val Loss 0.546849
# Early stopping at epoch 391
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.8062, MSE = 4.4096e-02
# Theta | Train_2 -> R² = 0.7196, MSE = 6.4011e-02
# Theta | Test_1 -> R² = 0.5644, MSE = 9.9781e-02
# Theta | Test_2 -> R² = 0.8535, MSE = 3.4746e-02
# Theta | Test_3 -> R² = 0.5862, MSE = 1.3573e-01
# Theta | Val -> R² = -0.6461, MSE = 5.3735e-01
# Theta | LSG_1 -> R² = 0.7504, MSE = 1.0419e-01
# Theta | LSG_2 -> R² = -2.2512, MSE = 1.1380e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 1.026968 | Val Loss 0.801703
# Epoch 100 | Train Loss 0.682292 | Val Loss 0.534528
# Epoch 200 | Train Loss 0.656318 | Val Loss 0.512347
# Epoch 300 | Train Loss 0.648303 | Val Loss 0.536737
# Early stopping at epoch 400
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.8057, MSE = 4.4223e-02
# Theta | Train_2 -> R² = 0.7248, MSE = 6.2825e-02
# Theta | Test_1 -> R² = 0.5808, MSE = 9.6029e-02
# Theta | Test_2 -> R² = 0.8508, MSE = 3.5382e-02
# Theta | Test_3 -> R² = 0.6026, MSE = 1.3036e-01
# Theta | Val -> R² = -0.2716, MSE = 4.1509e-01
# Theta | LSG_1 -> R² = 0.7144, MSE = 1.1923e-01
# Theta | LSG_2 -> R² = -1.9100, MSE = 1.0185e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.987626 | Val Loss 0.750038
# Epoch 100 | Train Loss 0.677606 | Val Loss 0.528753
# Epoch 200 | Train Loss 0.655128 | Val Loss 0.510120
# Epoch 300 | Train Loss 0.639314 | Val Loss 0.528815
# Epoch 400 | Train Loss 0.586518 | Val Loss 0.857514
# Early stopping at epoch 412
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7904, MSE = 4.7707e-02
# Theta | Train_2 -> R² = 0.7099, MSE = 6.6233e-02
# Theta | Test_1 -> R² = 0.5602, MSE = 1.0075e-01
# Theta | Test_2 -> R² = 0.8480, MSE = 3.6043e-02
# Theta | Test_3 -> R² = 0.6199, MSE = 1.2467e-01
# Theta | Val -> R² = -0.1173, MSE = 3.6471e-01
# Theta | LSG_1 -> R² = 0.6936, MSE = 1.2789e-01
# Theta | LSG_2 -> R² = -1.7429, MSE = 9.6004e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 1.003330 | Val Loss 0.783387
# Epoch 100 | Train Loss 0.680919 | Val Loss 0.534583
# Epoch 200 | Train Loss 0.654055 | Val Loss 0.504341
# Epoch 300 | Train Loss 0.622808 | Val Loss 0.557037
# Epoch 400 | Train Loss 0.579851 | Val Loss 0.931327
# Early stopping at epoch 408
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7904, MSE = 4.7696e-02
# Theta | Train_2 -> R² = 0.7117, MSE = 6.5805e-02
# Theta | Test_1 -> R² = 0.6120, MSE = 8.8882e-02
# Theta | Test_2 -> R² = 0.8435, MSE = 3.7110e-02
# Theta | Test_3 -> R² = 0.5100, MSE = 1.6072e-01
# Theta | Val -> R² = -0.0792, MSE = 3.5228e-01
# Theta | LSG_1 -> R² = 0.6464, MSE = 1.4761e-01
# Theta | LSG_2 -> R² = -1.4682, MSE = 8.6389e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.988775 | Val Loss 0.754704
# Epoch 100 | Train Loss 0.674618 | Val Loss 0.526358
# Epoch 200 | Train Loss 0.654437 | Val Loss 0.512171
# Epoch 300 | Train Loss 0.644899 | Val Loss 0.542853
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.8041, MSE = 4.4584e-02
# Theta | Train_2 -> R² = 0.7242, MSE = 6.2958e-02
# Theta | Test_1 -> R² = 0.5929, MSE = 9.3247e-02
# Theta | Test_2 -> R² = 0.8507, MSE = 3.5415e-02
# Theta | Test_3 -> R² = 0.6107, MSE = 1.2769e-01
# Theta | Val -> R² = -0.2591, MSE = 4.1102e-01
# Theta | LSG_1 -> R² = 0.7198, MSE = 1.1698e-01
# Theta | LSG_2 -> R² = -1.7461, MSE = 9.6116e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 1.028519 | Val Loss 0.808713
# Epoch 100 | Train Loss 0.684497 | Val Loss 0.531649
# Epoch 200 | Train Loss 0.657129 | Val Loss 0.502640
# Epoch 300 | Train Loss 0.647276 | Val Loss 0.524433
# Epoch 400 | Train Loss 0.623934 | Val Loss 0.646570
# Early stopping at epoch 402
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.8088, MSE = 4.3503e-02
# Theta | Train_2 -> R² = 0.7313, MSE = 6.1339e-02
# Theta | Test_1 -> R² = 0.6098, MSE = 8.9385e-02
# Theta | Test_2 -> R² = 0.8506, MSE = 3.5417e-02
# Theta | Test_3 -> R² = 0.4325, MSE = 1.8615e-01
# Theta | Val -> R² = -1.1560, MSE = 7.0378e-01
# Theta | LSG_1 -> R² = 0.7560, MSE = 1.0188e-01
# Theta | LSG_2 -> R² = -2.3194, MSE = 1.1618e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 1.053580 | Val Loss 0.820260
# Epoch 100 | Train Loss 0.686559 | Val Loss 0.535921
# Epoch 200 | Train Loss 0.658444 | Val Loss 0.508412
# Epoch 300 | Train Loss 0.649099 | Val Loss 0.519523
# Epoch 400 | Train Loss 0.620241 | Val Loss 0.666890
# Early stopping at epoch 409
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.8059, MSE = 4.4171e-02
# Theta | Train_2 -> R² = 0.7255, MSE = 6.2660e-02
# Theta | Test_1 -> R² = 0.5774, MSE = 9.6807e-02
# Theta | Test_2 -> R² = 0.8485, MSE = 3.5917e-02
# Theta | Test_3 -> R² = 0.5458, MSE = 1.4899e-01
# Theta | Val -> R² = -0.8498, MSE = 6.0382e-01
# Theta | LSG_1 -> R² = 0.7580, MSE = 1.0104e-01
# Theta | LSG_2 -> R² = -2.3798, MSE = 1.1829e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 1.085909 | Val Loss 0.857998
# Epoch 100 | Train Loss 0.689486 | Val Loss 0.535091
# Epoch 200 | Train Loss 0.657568 | Val Loss 0.515394
# Epoch 300 | Train Loss 0.649468 | Val Loss 0.523303
# Early stopping at epoch 395
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.8098, MSE = 4.3291e-02
# Theta | Train_2 -> R² = 0.7150, MSE = 6.5067e-02
# Theta | Test_1 -> R² = 0.5642, MSE = 9.9833e-02
# Theta | Test_2 -> R² = 0.8538, MSE = 3.4665e-02
# Theta | Test_3 -> R² = 0.6905, MSE = 1.0151e-01
# Theta | Val -> R² = -0.4630, MSE = 4.7755e-01
# Theta | LSG_1 -> R² = 0.7663, MSE = 9.7575e-02
# Theta | LSG_2 -> R² = -2.3654, MSE = 1.1779e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.969281 | Val Loss 0.737703
# Epoch 100 | Train Loss 0.674305 | Val Loss 0.528027
# Epoch 200 | Train Loss 0.653347 | Val Loss 0.505484
# Epoch 300 | Train Loss 0.633008 | Val Loss 0.555475
# Early stopping at epoch 371
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.8037, MSE = 4.4667e-02
# Theta | Train_2 -> R² = 0.7261, MSE = 6.2523e-02
# Theta | Test_1 -> R² = 0.5914, MSE = 9.3606e-02
# Theta | Test_2 -> R² = 0.8541, MSE = 3.4585e-02
# Theta | Test_3 -> R² = 0.5086, MSE = 1.6118e-01
# Theta | Val -> R² = -0.6011, MSE = 5.2264e-01
# Theta | LSG_1 -> R² = 0.7416, MSE = 1.0788e-01
# Theta | LSG_2 -> R² = -1.9803, MSE = 1.0431e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 1.037031 | Val Loss 0.841859
# Epoch 100 | Train Loss 0.678739 | Val Loss 0.618204
# Epoch 200 | Train Loss 0.659180 | Val Loss 0.565481
# Epoch 300 | Train Loss 0.558196 | Val Loss 0.750730
# Epoch 400 | Train Loss 0.525513 | Val Loss 0.876689
# Early stopping at epoch 419
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.6015, MSE = 9.0689e-02
# Theta | Train_2 -> R² = 0.8125, MSE = 4.2800e-02
# Theta | Test_1 -> R² = 0.2077, MSE = 1.8151e-01
# Theta | Test_2 -> R² = 0.5818, MSE = 9.9174e-02
# Theta | Test_3 -> R² = -3.0607, MSE = 1.3320e+00
# Theta | Val -> R² = -5.4185, MSE = 2.0952e+00
# Theta | LSG_1 -> R² = 0.3075, MSE = 2.8907e-01
# Theta | LSG_2 -> R² = -4.1408, MSE = 1.7993e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 0.982904 | Val Loss 0.758347
# Epoch 100 | Train Loss 0.679518 | Val Loss 0.618760
# Epoch 200 | Train Loss 0.659547 | Val Loss 0.573508
# Epoch 300 | Train Loss 0.565821 | Val Loss 0.718689
# Epoch 400 | Train Loss 0.528749 | Val Loss 0.866624
# Early stopping at epoch 411
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.6909, MSE = 7.0351e-02
# Theta | Train_2 -> R² = 0.8252, MSE = 3.9904e-02
# Theta | Test_1 -> R² = 0.2607, MSE = 1.6935e-01
# Theta | Test_2 -> R² = 0.6500, MSE = 8.2997e-02
# Theta | Test_3 -> R² = -1.9254, MSE = 9.5957e-01
# Theta | Val -> R² = -6.1938, MSE = 2.3483e+00
# Theta | LSG_1 -> R² = 0.0394, MSE = 4.0100e-01
# Theta | LSG_2 -> R² = -5.8429, MSE = 2.3951e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.998437 | Val Loss 0.765252
# Epoch 100 | Train Loss 0.677877 | Val Loss 0.617600
# Epoch 200 | Train Loss 0.659203 | Val Loss 0.568040
# Epoch 300 | Train Loss 0.561978 | Val Loss 0.707487
# Epoch 400 | Train Loss 0.527849 | Val Loss 0.861891
# Early stopping at epoch 422
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.6248, MSE = 8.5388e-02
# Theta | Train_2 -> R² = 0.8112, MSE = 4.3096e-02
# Theta | Test_1 -> R² = 0.1826, MSE = 1.8726e-01
# Theta | Test_2 -> R² = 0.5665, MSE = 1.0279e-01
# Theta | Test_3 -> R² = -3.2075, MSE = 1.3801e+00
# Theta | Val -> R² = -6.2976, MSE = 2.3822e+00
# Theta | LSG_1 -> R² = 0.1556, MSE = 3.5249e-01
# Theta | LSG_2 -> R² = -4.7919, MSE = 2.0272e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.995878 | Val Loss 0.808535
# Epoch 100 | Train Loss 0.676704 | Val Loss 0.611884
# Epoch 200 | Train Loss 0.641843 | Val Loss 0.563357
# Epoch 300 | Train Loss 0.552371 | Val Loss 0.753106
# Early stopping at epoch 382
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.6416, MSE = 8.1575e-02
# Theta | Train_2 -> R² = 0.8268, MSE = 3.9541e-02
# Theta | Test_1 -> R² = 0.1794, MSE = 1.8799e-01
# Theta | Test_2 -> R² = 0.6564, MSE = 8.1487e-02
# Theta | Test_3 -> R² = -1.3144, MSE = 7.5916e-01
# Theta | Val -> R² = -5.8001, MSE = 2.2198e+00
# Theta | LSG_1 -> R² = -0.0272, MSE = 4.2880e-01
# Theta | LSG_2 -> R² = -5.7395, MSE = 2.3588e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.988610 | Val Loss 0.780134
# Epoch 100 | Train Loss 0.677279 | Val Loss 0.606576
# Epoch 200 | Train Loss 0.655234 | Val Loss 0.560696
# Epoch 300 | Train Loss 0.551391 | Val Loss 0.758251
# Early stopping at epoch 400
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.6733, MSE = 7.4358e-02
# Theta | Train_2 -> R² = 0.8299, MSE = 3.8826e-02
# Theta | Test_1 -> R² = 0.2351, MSE = 1.7523e-01
# Theta | Test_2 -> R² = 0.6276, MSE = 8.8307e-02
# Theta | Test_3 -> R² = -2.0745, MSE = 1.0085e+00
# Theta | Val -> R² = -5.3445, MSE = 2.0711e+00
# Theta | LSG_1 -> R² = 0.2071, MSE = 3.3101e-01
# Theta | LSG_2 -> R² = -5.2630, MSE = 2.1921e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.983495 | Val Loss 0.756549
# Epoch 100 | Train Loss 0.675252 | Val Loss 0.598538
# Epoch 200 | Train Loss 0.660733 | Val Loss 0.561975
# Epoch 300 | Train Loss 0.565469 | Val Loss 0.697347
# Epoch 400 | Train Loss 0.533234 | Val Loss 0.791557
# Early stopping at epoch 417
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.6926, MSE = 6.9948e-02
# Theta | Train_2 -> R² = 0.8389, MSE = 3.6768e-02
# Theta | Test_1 -> R² = 0.3290, MSE = 1.5371e-01
# Theta | Test_2 -> R² = 0.5986, MSE = 9.5173e-02
# Theta | Test_3 -> R² = -1.5902, MSE = 8.4964e-01
# Theta | Val -> R² = -4.8313, MSE = 1.9035e+00
# Theta | LSG_1 -> R² = 0.0769, MSE = 3.8534e-01
# Theta | LSG_2 -> R² = -5.0851, MSE = 2.1298e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.985546 | Val Loss 0.766094
# Epoch 100 | Train Loss 0.678355 | Val Loss 0.616531
# Epoch 200 | Train Loss 0.662503 | Val Loss 0.571147
# Epoch 300 | Train Loss 0.581706 | Val Loss 0.638885
# Epoch 400 | Train Loss 0.537362 | Val Loss 0.802628
# Early stopping at epoch 427
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7024, MSE = 6.7736e-02
# Theta | Train_2 -> R² = 0.8279, MSE = 3.9284e-02
# Theta | Test_1 -> R² = 0.2430, MSE = 1.7341e-01
# Theta | Test_2 -> R² = 0.6637, MSE = 7.9751e-02
# Theta | Test_3 -> R² = -1.6086, MSE = 8.5565e-01
# Theta | Val -> R² = -6.7485, MSE = 2.5294e+00
# Theta | LSG_1 -> R² = 0.0213, MSE = 4.0857e-01
# Theta | LSG_2 -> R² = -6.1367, MSE = 2.4979e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 1.001793 | Val Loss 0.769316
# Epoch 100 | Train Loss 0.680967 | Val Loss 0.633650
# Epoch 200 | Train Loss 0.664145 | Val Loss 0.572976
# Epoch 300 | Train Loss 0.633126 | Val Loss 0.579755
# Epoch 400 | Train Loss 0.533939 | Val Loss 0.838424
# Early stopping at epoch 450
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.6486, MSE = 7.9964e-02
# Theta | Train_2 -> R² = 0.8262, MSE = 3.9669e-02
# Theta | Test_1 -> R² = 0.2434, MSE = 1.7331e-01
# Theta | Test_2 -> R² = 0.5765, MSE = 1.0043e-01
# Theta | Test_3 -> R² = -3.7710, MSE = 1.5650e+00
# Theta | Val -> R² = -7.6913, MSE = 2.8371e+00
# Theta | LSG_1 -> R² = 0.1510, MSE = 3.5440e-01
# Theta | LSG_2 -> R² = -4.6287, MSE = 1.9701e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 0.997572 | Val Loss 0.747501
# Epoch 100 | Train Loss 0.679705 | Val Loss 0.627716
# Epoch 200 | Train Loss 0.661496 | Val Loss 0.566580
# Epoch 300 | Train Loss 0.572207 | Val Loss 0.680601
# Epoch 400 | Train Loss 0.537334 | Val Loss 0.786338
# Early stopping at epoch 435
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.6157, MSE = 8.7465e-02
# Theta | Train_2 -> R² = 0.7809, MSE = 5.0012e-02
# Theta | Test_1 -> R² = 0.1134, MSE = 2.0311e-01
# Theta | Test_2 -> R² = 0.6366, MSE = 8.6172e-02
# Theta | Test_3 -> R² = -1.6561, MSE = 8.7125e-01
# Theta | Val -> R² = -4.6071, MSE = 1.8303e+00
# Theta | LSG_1 -> R² = 0.3477, MSE = 2.7230e-01
# Theta | LSG_2 -> R² = -4.7157, MSE = 2.0005e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.966241 | Val Loss 0.744456
# Epoch 100 | Train Loss 0.677213 | Val Loss 0.610500
# Epoch 200 | Train Loss 0.633565 | Val Loss 0.582429
# Epoch 300 | Train Loss 0.553299 | Val Loss 0.748928
# Early stopping at epoch 377
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed6848.keras
# ...
# models/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.8052, MSE = 4.4322e-02
# Theta | Train_2 -> R² = 0.4237, MSE = 1.3155e-01
# Theta | Test_1 -> R² = 0.2436, MSE = 1.7328e-01
# Theta | Test_2 -> R² = 0.7890, MSE = 5.0030e-02
# Theta | Test_3 -> R² = 0.5788, MSE = 1.3816e-01
# Theta | Val -> R² = -7.0537, MSE = 2.6290e+00
# Theta | LSG_1 -> R² = 0.3168, MSE = 2.8520e-01
# Theta | LSG_2 -> R² = -2.8853, MSE = 1.3599e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 0.984532 | Val Loss 0.637447
# Epoch 100 | Train Loss 0.617213 | Val Loss 0.550787
# Epoch 200 | Train Loss 0.574904 | Val Loss 0.814238
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.7949, MSE = 4.6671e-02
# Theta | Train_2 -> R² = 0.7938, MSE = 4.7079e-02
# Theta | Test_1 -> R² = 0.7570, MSE = 5.5664e-02
# Theta | Test_2 -> R² = 0.9102, MSE = 2.1301e-02
# Theta | Test_3 -> R² = 0.2874, MSE = 2.3374e-01
# Theta | Val -> R² = -1.2763, MSE = 7.4307e-01
# Theta | LSG_1 -> R² = 0.7469, MSE = 1.0567e-01
# Theta | LSG_2 -> R² = -1.7380, MSE = 9.5832e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 1.034621 | Val Loss 0.738035
# Epoch 100 | Train Loss 0.622317 | Val Loss 0.503779
# Epoch 200 | Train Loss 0.559193 | Val Loss 0.772173
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.8164, MSE = 4.1794e-02
# Theta | Train_2 -> R² = 0.7516, MSE = 5.6710e-02
# Theta | Test_1 -> R² = 0.8317, MSE = 3.8548e-02
# Theta | Test_2 -> R² = 0.8824, MSE = 2.7897e-02
# Theta | Test_3 -> R² = 0.6106, MSE = 1.2772e-01
# Theta | Val -> R² = -0.5200, MSE = 4.9616e-01
# Theta | LSG_1 -> R² = 0.7209, MSE = 1.1652e-01
# Theta | LSG_2 -> R² = -1.2935, MSE = 8.0274e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.939991 | Val Loss 0.603032
# Epoch 100 | Train Loss 0.603187 | Val Loss 0.586490
# Epoch 200 | Train Loss 0.554184 | Val Loss 0.766490
# Early stopping at epoch 254
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.8174, MSE = 4.1547e-02
# Theta | Train_2 -> R² = 0.7865, MSE = 4.8736e-02
# Theta | Test_1 -> R² = 0.7893, MSE = 4.8267e-02
# Theta | Test_2 -> R² = 0.8858, MSE = 2.7080e-02
# Theta | Test_3 -> R² = 0.3202, MSE = 2.2300e-01
# Theta | Val -> R² = -0.7740, MSE = 5.7910e-01
# Theta | LSG_1 -> R² = 0.7182, MSE = 1.1763e-01
# Theta | LSG_2 -> R² = -1.1568, MSE = 7.5488e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.954759 | Val Loss 0.594416
# Epoch 100 | Train Loss 0.624082 | Val Loss 0.566759
# Epoch 200 | Train Loss 0.555997 | Val Loss 0.801849
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.8032, MSE = 4.4780e-02
# Theta | Train_2 -> R² = 0.7009, MSE = 6.8277e-02
# Theta | Test_1 -> R² = 0.7429, MSE = 5.8907e-02
# Theta | Test_2 -> R² = 0.7960, MSE = 4.8374e-02
# Theta | Test_3 -> R² = 0.3639, MSE = 2.0866e-01
# Theta | Val -> R² = -0.8276, MSE = 5.9658e-01
# Theta | LSG_1 -> R² = 0.6880, MSE = 1.3023e-01
# Theta | LSG_2 -> R² = -1.6049, MSE = 9.1171e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.953676 | Val Loss 0.609885
# Epoch 100 | Train Loss 0.619855 | Val Loss 0.539230
# Epoch 200 | Train Loss 0.560501 | Val Loss 0.766819
# Early stopping at epoch 265
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7635, MSE = 5.3817e-02
# Theta | Train_2 -> R² = 0.6824, MSE = 7.2502e-02
# Theta | Test_1 -> R² = 0.6676, MSE = 7.6149e-02
# Theta | Test_2 -> R² = 0.8547, MSE = 3.4465e-02
# Theta | Test_3 -> R² = 0.3808, MSE = 2.0312e-01
# Theta | Val -> R² = -1.4488, MSE = 7.9936e-01
# Theta | LSG_1 -> R² = 0.7237, MSE = 1.1534e-01
# Theta | LSG_2 -> R² = -1.9271, MSE = 1.0245e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.975159 | Val Loss 0.626963
# Epoch 100 | Train Loss 0.610534 | Val Loss 0.613504
# Epoch 200 | Train Loss 0.561268 | Val Loss 0.784523
# Early stopping at epoch 257
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5830.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.8262, MSE = 3.9550e-02
# Theta | Train_2 -> R² = 0.7740, MSE = 5.1584e-02
# Theta | Test_1 -> R² = 0.7463, MSE = 5.8112e-02
# Theta | Test_2 -> R² = 0.8762, MSE = 2.9365e-02
# Theta | Test_3 -> R² = 0.4498, MSE = 1.8048e-01
# Theta | Val -> R² = -1.0876, MSE = 6.8144e-01
# Theta | LSG_1 -> R² = 0.7073, MSE = 1.2218e-01
# Theta | LSG_2 -> R² = -2.0862, MSE = 1.0802e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.973228 | Val Loss 0.670017
# Epoch 100 | Train Loss 0.630282 | Val Loss 0.502936
# Epoch 200 | Train Loss 0.561624 | Val Loss 0.784713
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4269.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7959, MSE = 4.6448e-02
# Theta | Train_2 -> R² = 0.7922, MSE = 4.7436e-02
# Theta | Test_1 -> R² = 0.7369, MSE = 6.0270e-02
# Theta | Test_2 -> R² = 0.8893, MSE = 2.6250e-02
# Theta | Test_3 -> R² = 0.4967, MSE = 1.6511e-01
# Theta | Val -> R² = -1.1331, MSE = 6.9632e-01
# Theta | LSG_1 -> R² = 0.7164, MSE = 1.1840e-01
# Theta | LSG_2 -> R² = -2.1424, MSE = 1.0999e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 1.014485 | Val Loss 0.686601
# Epoch 100 | Train Loss 0.643167 | Val Loss 0.493567
# Epoch 200 | Train Loss 0.565963 | Val Loss 0.771873
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2072.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7898, MSE = 4.7832e-02
# Theta | Train_2 -> R² = 0.6946, MSE = 6.9717e-02
# Theta | Test_1 -> R² = 0.7165, MSE = 6.4935e-02
# Theta | Test_2 -> R² = 0.8707, MSE = 3.0649e-02
# Theta | Test_3 -> R² = 0.4966, MSE = 1.6512e-01
# Theta | Val -> R² = -0.8325, MSE = 5.9820e-01
# Theta | LSG_1 -> R² = 0.6627, MSE = 1.4080e-01
# Theta | LSG_2 -> R² = -1.4098, MSE = 8.4344e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 0.992242 | Val Loss 0.614073
# Epoch 100 | Train Loss 0.625226 | Val Loss 0.530943
# Epoch 200 | Train Loss 0.567988 | Val Loss 0.801712
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5960.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.7897, MSE = 4.7871e-02
# Theta | Train_2 -> R² = 0.7638, MSE = 5.3921e-02
# Theta | Test_1 -> R² = 0.6635, MSE = 7.7080e-02
# Theta | Test_2 -> R² = 0.8680, MSE = 3.1304e-02
# Theta | Test_3 -> R² = 0.3748, MSE = 2.0508e-01
# Theta | Val -> R² = -1.0485, MSE = 6.6869e-01
# Theta | LSG_1 -> R² = 0.7293, MSE = 1.1302e-01
# Theta | LSG_2 -> R² = -2.2429, MSE = 1.1350e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.989583 | Val Loss 0.666909
# Epoch 100 | Train Loss 0.630889 | Val Loss 0.514091
# Epoch 200 | Train Loss 0.574106 | Val Loss 0.767920
# Early stopping at epoch 270
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed6848.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.7597, MSE = 5.4687e-02
# Theta | Train_2 -> R² = 0.6843, MSE = 7.2078e-02
# Theta | Test_1 -> R² = 0.5875, MSE = 9.4495e-02
# Theta | Test_2 -> R² = 0.8503, MSE = 3.5494e-02
# Theta | Test_3 -> R² = 0.4749, MSE = 1.7223e-01
# Theta | Val -> R² = -1.4065, MSE = 7.8556e-01
# Theta | LSG_1 -> R² = 0.7226, MSE = 1.1581e-01
# Theta | LSG_2 -> R² = -2.3044, MSE = 1.1565e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=6848 salvo.
# Epoch 0 | Train Loss 0.979734 | Val Loss 0.647641
# Epoch 100 | Train Loss 0.560426 | Val Loss 0.752783
# Epoch 200 | Train Loss 0.510722 | Val Loss 0.891876
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.6797, MSE = 7.2884e-02
# Theta | Train_2 -> R² = 0.5878, MSE = 9.4089e-02
# Theta | Test_1 -> R² = 0.0025, MSE = 2.2851e-01
# Theta | Test_2 -> R² = 0.8614, MSE = 3.2868e-02
# Theta | Test_3 -> R² = 0.2161, MSE = 2.5713e-01
# Theta | Val -> R² = -8.1228, MSE = 2.9780e+00
# Theta | LSG_1 -> R² = 0.2187, MSE = 3.2616e-01
# Theta | LSG_2 -> R² = -3.6073, MSE = 1.6126e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5830 salvo.
# Epoch 0 | Train Loss 0.986599 | Val Loss 0.681860
# Epoch 100 | Train Loss 0.579779 | Val Loss 0.740993
# Epoch 200 | Train Loss 0.512392 | Val Loss 0.879366
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7385, MSE = 5.9508e-02
# Theta | Train_2 -> R² = 0.5541, MSE = 1.0180e-01
# Theta | Test_1 -> R² = -0.0214, MSE = 2.3398e-01
# Theta | Test_2 -> R² = 0.7946, MSE = 4.8710e-02
# Theta | Test_3 -> R² = 0.4491, MSE = 1.8069e-01
# Theta | Val -> R² = -8.8813, MSE = 3.2256e+00
# Theta | LSG_1 -> R² = -0.2400, MSE = 5.1766e-01
# Theta | LSG_2 -> R² = -5.1189, MSE = 2.1416e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4269 salvo.
# Epoch 0 | Train Loss 0.966582 | Val Loss 0.665868
# Epoch 100 | Train Loss 0.573126 | Val Loss 0.724096
# Epoch 200 | Train Loss 0.512967 | Val Loss 0.914246
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.7485, MSE = 5.7229e-02
# Theta | Train_2 -> R² = 0.6447, MSE = 8.1105e-02
# Theta | Test_1 -> R² = 0.3844, MSE = 1.4102e-01
# Theta | Test_2 -> R² = 0.6220, MSE = 8.9646e-02
# Theta | Test_3 -> R² = -0.2693, MSE = 4.1636e-01
# Theta | Val -> R² = -9.3694, MSE = 3.3849e+00
# Theta | LSG_1 -> R² = -0.1677, MSE = 4.8746e-01
# Theta | LSG_2 -> R² = -5.3237, MSE = 2.2133e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2072 salvo.
# Epoch 0 | Train Loss 0.977475 | Val Loss 0.610315
# Epoch 100 | Train Loss 0.553221 | Val Loss 0.725081
# Epoch 200 | Train Loss 0.517029 | Val Loss 0.919663
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.5193, MSE = 1.0940e-01
# Theta | Train_2 -> R² = 0.5573, MSE = 1.0106e-01
# Theta | Test_1 -> R² = -0.2237, MSE = 2.8032e-01
# Theta | Test_2 -> R² = 0.8707, MSE = 3.0658e-02
# Theta | Test_3 -> R² = -0.0395, MSE = 3.4098e-01
# Theta | Val -> R² = -9.7725, MSE = 3.5165e+00
# Theta | LSG_1 -> R² = -0.1776, MSE = 4.9158e-01
# Theta | LSG_2 -> R² = -4.8057, MSE = 2.0320e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5960 salvo.
# Epoch 0 | Train Loss 0.953720 | Val Loss 0.618188
# Epoch 100 | Train Loss 0.558866 | Val Loss 0.717074
# Epoch 200 | Train Loss 0.516762 | Val Loss 0.906218
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.6272, MSE = 8.4853e-02
# Theta | Train_2 -> R² = 0.6593, MSE = 7.7779e-02
# Theta | Test_1 -> R² = -0.0353, MSE = 2.3716e-01
# Theta | Test_2 -> R² = 0.8557, MSE = 3.4224e-02
# Theta | Test_3 -> R² = -0.0359, MSE = 3.3980e-01
# Theta | Val -> R² = -8.7714, MSE = 3.1897e+00
# Theta | LSG_1 -> R² = -0.0703, MSE = 4.4678e-01
# Theta | LSG_2 -> R² = -4.5507, MSE = 1.9428e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=6848 salvo.
# Epoch 0 | Train Loss 0.955567 | Val Loss 0.640348
# Epoch 100 | Train Loss 0.570071 | Val Loss 0.735843
# Epoch 200 | Train Loss 0.509781 | Val Loss 0.867231
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5830.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5830.weights.h5
# Theta | Train_1 -> R² = 0.6006, MSE = 9.0896e-02
# Theta | Train_2 -> R² = 0.6632, MSE = 7.6893e-02
# Theta | Test_1 -> R² = -0.2055, MSE = 2.7615e-01
# Theta | Test_2 -> R² = 0.8222, MSE = 4.2157e-02
# Theta | Test_3 -> R² = -0.0221, MSE = 3.3527e-01
# Theta | Val -> R² = -9.5893, MSE = 3.4567e+00
# Theta | LSG_1 -> R² = -0.3210, MSE = 5.5145e-01
# Theta | LSG_2 -> R² = -5.5030, MSE = 2.2761e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5830 salvo.
# Epoch 0 | Train Loss 0.980481 | Val Loss 0.676176
# Epoch 100 | Train Loss 0.572229 | Val Loss 0.754404
# Epoch 200 | Train Loss 0.509210 | Val Loss 0.907324
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4269.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4269.weights.h5
# Theta | Train_1 -> R² = 0.7901, MSE = 4.7760e-02
# Theta | Train_2 -> R² = 0.6378, MSE = 8.2696e-02
# Theta | Test_1 -> R² = 0.2268, MSE = 1.7712e-01
# Theta | Test_2 -> R² = 0.7431, MSE = 6.0919e-02
# Theta | Test_3 -> R² = 0.1558, MSE = 2.7691e-01
# Theta | Val -> R² = -8.9780, MSE = 3.2571e+00
# Theta | LSG_1 -> R² = -0.2035, MSE = 5.0239e-01
# Theta | LSG_2 -> R² = -5.2829, MSE = 2.1990e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4269 salvo.
# Epoch 0 | Train Loss 0.963462 | Val Loss 0.643434
# Epoch 100 | Train Loss 0.553967 | Val Loss 0.724912
# Epoch 200 | Train Loss 0.517138 | Val Loss 0.888708
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2072.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2072.weights.h5
# Theta | Train_1 -> R² = 0.4651, MSE = 1.2172e-01
# Theta | Train_2 -> R² = 0.3861, MSE = 1.4014e-01
# Theta | Test_1 -> R² = -0.5658, MSE = 3.5868e-01
# Theta | Test_2 -> R² = 0.7964, MSE = 4.8290e-02
# Theta | Test_3 -> R² = 0.4472, MSE = 1.8134e-01
# Theta | Val -> R² = -8.6774, MSE = 3.1590e+00
# Theta | LSG_1 -> R² = -0.1733, MSE = 4.8981e-01
# Theta | LSG_2 -> R² = -4.6300, MSE = 1.9705e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2072 salvo.
# Epoch 0 | Train Loss 0.981977 | Val Loss 0.615658
# Epoch 100 | Train Loss 0.551440 | Val Loss 0.721814
# Epoch 200 | Train Loss 0.518345 | Val Loss 0.907294
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5960.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5960.weights.h5
# Theta | Train_1 -> R² = 0.5803, MSE = 9.5523e-02
# Theta | Train_2 -> R² = 0.5519, MSE = 1.0231e-01
# Theta | Test_1 -> R² = -0.1416, MSE = 2.6153e-01
# Theta | Test_2 -> R² = 0.8809, MSE = 2.8244e-02
# Theta | Test_3 -> R² = 0.1142, MSE = 2.9057e-01
# Theta | Val -> R² = -8.8336, MSE = 3.2100e+00
# Theta | LSG_1 -> R² = 0.0857, MSE = 3.8169e-01
# Theta | LSG_2 -> R² = -4.0164, MSE = 1.7558e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5960 salvo.
# Epoch 0 | Train Loss 0.929377 | Val Loss 0.621013
# Epoch 100 | Train Loss 0.549262 | Val Loss 0.758216
# Epoch 200 | Train Loss 0.510639 | Val Loss 0.902273
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed6848.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed6848.weights.h5
# Theta | Train_1 -> R² = 0.5660, MSE = 9.8768e-02
# Theta | Train_2 -> R² = 0.6364, MSE = 8.2994e-02
# Theta | Test_1 -> R² = -0.1742, MSE = 2.6898e-01
# Theta | Test_2 -> R² = 0.8664, MSE = 3.1679e-02
# Theta | Test_3 -> R² = -0.0178, MSE = 3.3385e-01
# Theta | Val -> R² = -8.5122, MSE = 3.1051e+00
# Theta | LSG_1 -> R² = -0.0114, MSE = 4.2221e-01
# Theta | LSG_2 -> R² = -4.4148, MSE = 1.8952e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=6848 salvo.
