# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "sin(Theta_pred)", "cos(Theta_pred)"
# - Saida: X, Y
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "sinTheta", "cosTheta"]   
TARGET_INT = ["X", "Y"]  
TARGET = ["DeltaX", "DeltaY"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./Data/Theta.xlsx", sheet_name=title)

    df["Theta_ens"] = df_theta["Theta_ens"]

    df["cosTheta"] = np.cos(df["Theta_ens"])
    df["sinTheta"] = np.sin(df["Theta_ens"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1935, 3, 6)
# Dimensão da saida: (1935, 2)
# Dimensão da entrada: (1261, 3, 6)
# Dimensão da saida: (1261, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1935, 3, 6)
# Dimensão da saida: (1935, 2)
# Dimensão da entrada fisica : (1935,)
# Dimensão da entrada fisica: (1935,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)
    return [dx_cin, dy_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.637765 | Val Loss 0.781581
# Epoch 100 | Train Loss 0.302779 | Val Loss 0.600409
# Epoch 200 | Train Loss 0.270344 | Val Loss 0.572640
# Epoch 300 | Train Loss 0.263339 | Val Loss 0.538116
# Epoch 400 | Train Loss 0.259704 | Val Loss 0.529746
# Epoch 500 | Train Loss 0.257392 | Val Loss 0.528557
# Epoch 600 | Train Loss 0.255740 | Val Loss 0.528451
# Early stopping at epoch 623
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8857.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8857.weights.h5
# X | Train_1 -> R² = 0.9917, MSE = 8.8802e-04
# Y | Train_1 -> R² = 0.7658, MSE = 1.9547e-02
# X | Train_2 -> R² = 0.9969, MSE = 2.6211e-04
# Y | Train_2 -> R² = 0.7444, MSE = 2.7291e-02
# X | Test_1 -> R² = 0.6707, MSE = 3.4169e-02
# Y | Test_1 -> R² = 0.9597, MSE = 3.2876e-03
# X | Test_2 -> R² = 0.8068, MSE = 1.5846e-02
# Y | Test_2 -> R² = 0.5452, MSE = 4.7872e-02
# X | Test_3 -> R² = -1.2109, MSE = 2.0197e-01
# Y | Test_3 -> R² = 0.7366, MSE = 2.0162e-02
# X | Val -> R² = 0.5015, MSE = 4.7281e-02
# Y | Val -> R² = 0.9455, MSE = 4.0481e-03
# X | LSG_1 -> R² = -5.4643, MSE = 6.5638e-01
# Y | LSG_1 -> R² = -5.6013, MSE = 2.0983e+00
# X | LSG_2 -> R² = -6.5591, MSE = 6.6564e-01
# Y | LSG_2 -> R² = -5.0492, MSE = 2.3413e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8857 salvo.
# Epoch 0 | Train Loss 0.638150 | Val Loss 0.792322
# Epoch 100 | Train Loss 0.303331 | Val Loss 0.564412
# Epoch 200 | Train Loss 0.268955 | Val Loss 0.565801
# Epoch 300 | Train Loss 0.264046 | Val Loss 0.541423
# Epoch 400 | Train Loss 0.260959 | Val Loss 0.527294
# Epoch 500 | Train Loss 0.258512 | Val Loss 0.519787
# Epoch 600 | Train Loss 0.256883 | Val Loss 0.516770
# Epoch 700 | Train Loss 0.255723 | Val Loss 0.515448
# Epoch 800 | Train Loss 0.254701 | Val Loss 0.514063
# Epoch 900 | Train Loss 0.253780 | Val Loss 0.512437
# Epoch 1000 | Train Loss 0.252987 | Val Loss 0.511441
# Epoch 1100 | Train Loss 0.252319 | Val Loss 0.511366
# Early stopping at epoch 1131
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1586.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1586.weights.h5
# X | Train_1 -> R² = 0.9936, MSE = 6.7972e-04
# Y | Train_1 -> R² = 0.7848, MSE = 1.7963e-02
# X | Train_2 -> R² = 0.9968, MSE = 2.6658e-04
# Y | Train_2 -> R² = 0.7569, MSE = 2.5956e-02
# X | Test_1 -> R² = 0.5894, MSE = 4.2602e-02
# Y | Test_1 -> R² = 0.9110, MSE = 7.2591e-03
# X | Test_2 -> R² = 0.8784, MSE = 9.9779e-03
# Y | Test_2 -> R² = -0.0918, MSE = 1.1493e-01
# X | Test_3 -> R² = -3.1230, MSE = 3.7665e-01
# Y | Test_3 -> R² = 0.8523, MSE = 1.1302e-02
# X | Val -> R² = -0.3743, MSE = 1.3034e-01
# Y | Val -> R² = 0.7107, MSE = 2.1485e-02
# X | LSG_1 -> R² = -1.7887, MSE = 2.8316e-01
# Y | LSG_1 -> R² = -0.3770, MSE = 4.3770e-01
# X | LSG_2 -> R² = -0.3567, MSE = 1.1947e-01
# Y | LSG_2 -> R² = -0.2315, MSE = 4.7664e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1586 salvo.
# Epoch 0 | Train Loss 0.638072 | Val Loss 0.784630
# Epoch 100 | Train Loss 0.308478 | Val Loss 0.574488
# Epoch 200 | Train Loss 0.273475 | Val Loss 0.579224
# Epoch 300 | Train Loss 0.267530 | Val Loss 0.544388
# Epoch 400 | Train Loss 0.262035 | Val Loss 0.519709
# Epoch 500 | Train Loss 0.257989 | Val Loss 0.508214
# Epoch 600 | Train Loss 0.256300 | Val Loss 0.503171
# Epoch 700 | Train Loss 0.255394 | Val Loss 0.501479
# Epoch 800 | Train Loss 0.254667 | Val Loss 0.500994
# Epoch 900 | Train Loss 0.254003 | Val Loss 0.501402
# Early stopping at epoch 950
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1658.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1658.weights.h5
# X | Train_1 -> R² = 0.9963, MSE = 3.9963e-04
# Y | Train_1 -> R² = 0.7951, MSE = 1.7104e-02
# X | Train_2 -> R² = 0.9976, MSE = 2.0485e-04
# Y | Train_2 -> R² = 0.7430, MSE = 2.7435e-02
# X | Test_1 -> R² = 0.8168, MSE = 1.9009e-02
# Y | Test_1 -> R² = 0.9108, MSE = 7.2810e-03
# X | Test_2 -> R² = 0.6590, MSE = 2.7975e-02
# Y | Test_2 -> R² = 0.0244, MSE = 1.0270e-01
# X | Test_3 -> R² = -0.7737, MSE = 1.6203e-01
# Y | Test_3 -> R² = 0.8345, MSE = 1.2663e-02
# X | Val -> R² = 0.5669, MSE = 4.1072e-02
# Y | Val -> R² = 0.9457, MSE = 4.0293e-03
# X | LSG_1 -> R² = 0.5592, MSE = 4.4754e-02
# Y | LSG_1 -> R² = -3.3080, MSE = 1.3693e+00
# X | LSG_2 -> R² = -1.8883, MSE = 2.5433e-01
# Y | LSG_2 -> R² = -3.2991, MSE = 1.6639e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1658 salvo.
# Epoch 0 | Train Loss 0.600914 | Val Loss 0.776654
# Epoch 100 | Train Loss 0.311618 | Val Loss 0.597794
# Epoch 200 | Train Loss 0.273583 | Val Loss 0.577821
# Epoch 300 | Train Loss 0.265361 | Val Loss 0.537694
# Epoch 400 | Train Loss 0.260703 | Val Loss 0.516829
# Epoch 500 | Train Loss 0.258215 | Val Loss 0.508211
# Epoch 600 | Train Loss 0.256878 | Val Loss 0.505085
# Epoch 700 | Train Loss 0.255938 | Val Loss 0.503678
# Epoch 800 | Train Loss 0.255126 | Val Loss 0.502941
# Epoch 900 | Train Loss 0.254374 | Val Loss 0.502719
# Epoch 1000 | Train Loss 0.253654 | Val Loss 0.503193
# Early stopping at epoch 1041
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed9028.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed9028.weights.h5
# X | Train_1 -> R² = 0.9920, MSE = 8.5615e-04
# Y | Train_1 -> R² = 0.7840, MSE = 1.8031e-02
# X | Train_2 -> R² = 0.9982, MSE = 1.5428e-04
# Y | Train_2 -> R² = 0.7292, MSE = 2.8909e-02
# X | Test_1 -> R² = 0.4447, MSE = 5.7621e-02
# Y | Test_1 -> R² = 0.9655, MSE = 2.8176e-03
# X | Test_2 -> R² = 0.8417, MSE = 1.2987e-02
# Y | Test_2 -> R² = 0.5757, MSE = 4.4666e-02
# X | Test_3 -> R² = -0.4560, MSE = 1.3301e-01
# Y | Test_3 -> R² = 0.9206, MSE = 6.0777e-03
# X | Val -> R² = 0.7472, MSE = 2.3972e-02
# Y | Val -> R² = 0.9476, MSE = 3.8911e-03
# X | LSG_1 -> R² = -0.1001, MSE = 1.1170e-01
# Y | LSG_1 -> R² = -1.3840, MSE = 7.5777e-01
# X | LSG_2 -> R² = -4.3220, MSE = 4.6864e-01
# Y | LSG_2 -> R² = -0.6218, MSE = 6.2769e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=9028 salvo.
# Epoch 0 | Train Loss 0.622863 | Val Loss 0.759766
# Epoch 100 | Train Loss 0.320777 | Val Loss 0.569410
# Epoch 200 | Train Loss 0.271481 | Val Loss 0.561091
# Epoch 300 | Train Loss 0.264848 | Val Loss 0.540490
# Epoch 400 | Train Loss 0.260849 | Val Loss 0.526509
# Epoch 500 | Train Loss 0.257892 | Val Loss 0.520344
# Epoch 600 | Train Loss 0.256139 | Val Loss 0.519490
# Epoch 700 | Train Loss 0.254927 | Val Loss 0.519646
# Early stopping at epoch 745
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8478.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8478.weights.h5
# X | Train_1 -> R² = 0.9936, MSE = 6.8800e-04
# Y | Train_1 -> R² = 0.7826, MSE = 1.8144e-02
# X | Train_2 -> R² = 0.9966, MSE = 2.8795e-04
# Y | Train_2 -> R² = 0.7448, MSE = 2.7252e-02
# X | Test_1 -> R² = 0.5273, MSE = 4.9048e-02
# Y | Test_1 -> R² = 0.4318, MSE = 4.6366e-02
# X | Test_2 -> R² = -0.4880, MSE = 1.2206e-01
# Y | Test_2 -> R² = 0.7677, MSE = 2.4453e-02
# X | Test_3 -> R² = 0.3689, MSE = 5.7653e-02
# Y | Test_3 -> R² = 0.3856, MSE = 4.7021e-02
# X | Val -> R² = 0.5452, MSE = 4.3137e-02
# Y | Val -> R² = 0.6754, MSE = 2.4100e-02
# X | LSG_1 -> R² = -0.4177, MSE = 1.4395e-01
# Y | LSG_1 -> R² = -2.5992, MSE = 1.1441e+00
# X | LSG_2 -> R² = -11.6901, MSE = 1.1175e+00
# Y | LSG_2 -> R² = -2.2079, MSE = 1.2416e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8478 salvo.
# Epoch 0 | Train Loss 0.622020 | Val Loss 0.764243
# Epoch 100 | Train Loss 0.308155 | Val Loss 0.575099
# Epoch 200 | Train Loss 0.270809 | Val Loss 0.563740
# Epoch 300 | Train Loss 0.263641 | Val Loss 0.533862
# Epoch 400 | Train Loss 0.257872 | Val Loss 0.513809
# Epoch 500 | Train Loss 0.255402 | Val Loss 0.508142
# Epoch 600 | Train Loss 0.254241 | Val Loss 0.506684
# Epoch 700 | Train Loss 0.253408 | Val Loss 0.507477
# Early stopping at epoch 728
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8857.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8857.weights.h5
# X | Train_1 -> R² = 0.9920, MSE = 8.4931e-04
# Y | Train_1 -> R² = 0.7877, MSE = 1.7720e-02
# X | Train_2 -> R² = 0.9972, MSE = 2.3751e-04
# Y | Train_2 -> R² = 0.7346, MSE = 2.8342e-02
# X | Test_1 -> R² = 0.9206, MSE = 8.2332e-03
# Y | Test_1 -> R² = 0.9125, MSE = 7.1378e-03
# X | Test_2 -> R² = 0.8079, MSE = 1.5760e-02
# Y | Test_2 -> R² = 0.5241, MSE = 5.0096e-02
# X | Test_3 -> R² = -1.1850, MSE = 1.9961e-01
# Y | Test_3 -> R² = 0.9140, MSE = 6.5842e-03
# X | Val -> R² = 0.1142, MSE = 8.4014e-02
# Y | Val -> R² = 0.9149, MSE = 6.3199e-03
# X | LSG_1 -> R² = -0.4086, MSE = 1.4302e-01
# Y | LSG_1 -> R² = -4.6999, MSE = 1.8118e+00
# X | LSG_2 -> R² = -3.0596, MSE = 3.5748e-01
# Y | LSG_2 -> R² = -6.6572, MSE = 2.9636e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8857 salvo.
# Epoch 0 | Train Loss 0.619750 | Val Loss 0.768402
# Epoch 100 | Train Loss 0.296058 | Val Loss 0.563125
# Epoch 200 | Train Loss 0.272507 | Val Loss 0.564997
# Epoch 300 | Train Loss 0.266651 | Val Loss 0.552595
# Epoch 400 | Train Loss 0.261118 | Val Loss 0.542723
# Epoch 500 | Train Loss 0.256729 | Val Loss 0.535378
# Epoch 600 | Train Loss 0.254509 | Val Loss 0.531066
# Epoch 700 | Train Loss 0.253282 | Val Loss 0.530050
# Epoch 800 | Train Loss 0.252449 | Val Loss 0.530117
# Early stopping at epoch 814
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1586.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1586.weights.h5
# X | Train_1 -> R² = 0.9913, MSE = 9.2703e-04
# Y | Train_1 -> R² = 0.7686, MSE = 1.9318e-02
# X | Train_2 -> R² = 0.9967, MSE = 2.7745e-04
# Y | Train_2 -> R² = 0.7449, MSE = 2.7234e-02
# X | Test_1 -> R² = 0.1226, MSE = 9.1037e-02
# Y | Test_1 -> R² = 0.4588, MSE = 4.4161e-02
# X | Test_2 -> R² = 0.0101, MSE = 8.1200e-02
# Y | Test_2 -> R² = 0.6494, MSE = 3.6906e-02
# X | Test_3 -> R² = -0.0422, MSE = 9.5208e-02
# Y | Test_3 -> R² = -0.8621, MSE = 1.4252e-01
# X | Val -> R² = 0.5647, MSE = 4.1281e-02
# Y | Val -> R² = 0.5206, MSE = 3.5598e-02
# X | LSG_1 -> R² = -8.6214, MSE = 9.7696e-01
# Y | LSG_1 -> R² = -0.8751, MSE = 5.9601e-01
# X | LSG_2 -> R² = -19.0480, MSE = 1.7654e+00
# Y | LSG_2 -> R² = -0.5024, MSE = 5.8149e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1586 salvo.
# Epoch 0 | Train Loss 0.651378 | Val Loss 0.777309
# Epoch 100 | Train Loss 0.322552 | Val Loss 0.583533
# Epoch 200 | Train Loss 0.276331 | Val Loss 0.590594
# Epoch 300 | Train Loss 0.269760 | Val Loss 0.563536
# Epoch 400 | Train Loss 0.264587 | Val Loss 0.543122
# Epoch 500 | Train Loss 0.261509 | Val Loss 0.537128
# Epoch 600 | Train Loss 0.259928 | Val Loss 0.535112
# Epoch 700 | Train Loss 0.258672 | Val Loss 0.531318
# Epoch 800 | Train Loss 0.257410 | Val Loss 0.525082
# Epoch 900 | Train Loss 0.256176 | Val Loss 0.520206
# Epoch 1000 | Train Loss 0.255004 | Val Loss 0.519015
# Epoch 1100 | Train Loss 0.253956 | Val Loss 0.519811
# Early stopping at epoch 1132
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1658.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1658.weights.h5
# X | Train_1 -> R² = 0.9938, MSE = 6.6001e-04
# Y | Train_1 -> R² = 0.7920, MSE = 1.7364e-02
# X | Train_2 -> R² = 0.9969, MSE = 2.6104e-04
# Y | Train_2 -> R² = 0.7493, MSE = 2.6771e-02
# X | Test_1 -> R² = 0.8981, MSE = 1.0576e-02
# Y | Test_1 -> R² = 0.8529, MSE = 1.2002e-02
# X | Test_2 -> R² = 0.7990, MSE = 1.6484e-02
# Y | Test_2 -> R² = -0.2567, MSE = 1.3228e-01
# X | Test_3 -> R² = -3.9022, MSE = 4.4783e-01
# Y | Test_3 -> R² = 0.6675, MSE = 2.5451e-02
# X | Val -> R² = 0.1966, MSE = 7.6195e-02
# Y | Val -> R² = 0.9023, MSE = 7.2555e-03
# X | LSG_1 -> R² = -1.0384, MSE = 2.0697e-01
# Y | LSG_1 -> R² = -2.9798, MSE = 1.2650e+00
# X | LSG_2 -> R² = -4.8864, MSE = 5.1834e-01
# Y | LSG_2 -> R² = -2.4712, MSE = 1.3435e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1658 salvo.
# Epoch 0 | Train Loss 0.603614 | Val Loss 0.758513
# Epoch 100 | Train Loss 0.297400 | Val Loss 0.593080
# Epoch 200 | Train Loss 0.272614 | Val Loss 0.577639
# Epoch 300 | Train Loss 0.266238 | Val Loss 0.549217
# Epoch 400 | Train Loss 0.262658 | Val Loss 0.529932
# Epoch 500 | Train Loss 0.260227 | Val Loss 0.520255
# Epoch 600 | Train Loss 0.258165 | Val Loss 0.514704
# Epoch 700 | Train Loss 0.256527 | Val Loss 0.511957
# Epoch 800 | Train Loss 0.255351 | Val Loss 0.510498
# Epoch 900 | Train Loss 0.254397 | Val Loss 0.510766
# Early stopping at epoch 964
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed9028.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed9028.weights.h5
# X | Train_1 -> R² = 0.9897, MSE = 1.1013e-03
# Y | Train_1 -> R² = 0.7939, MSE = 1.7203e-02
# X | Train_2 -> R² = 0.9948, MSE = 4.3939e-04
# Y | Train_2 -> R² = 0.7671, MSE = 2.4864e-02
# X | Test_1 -> R² = -0.1419, MSE = 1.1848e-01
# Y | Test_1 -> R² = 0.6750, MSE = 2.6523e-02
# X | Test_2 -> R² = 0.9722, MSE = 2.2788e-03
# Y | Test_2 -> R² = 0.0268, MSE = 1.0244e-01
# X | Test_3 -> R² = -0.1279, MSE = 1.0304e-01
# Y | Test_3 -> R² = 0.8236, MSE = 1.3499e-02
# X | Val -> R² = 0.8461, MSE = 1.4601e-02
# Y | Val -> R² = 0.9125, MSE = 6.4963e-03
# X | LSG_1 -> R² = 0.3643, MSE = 6.4553e-02
# Y | LSG_1 -> R² = -1.7325, MSE = 8.6855e-01
# X | LSG_2 -> R² = -0.5946, MSE = 1.4042e-01
# Y | LSG_2 -> R² = -2.4740, MSE = 1.3446e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=9028 salvo.
# Epoch 0 | Train Loss 0.597016 | Val Loss 0.742053
# Epoch 100 | Train Loss 0.300687 | Val Loss 0.592390
# Epoch 200 | Train Loss 0.271291 | Val Loss 0.560794
# Epoch 300 | Train Loss 0.264658 | Val Loss 0.537193
# Epoch 400 | Train Loss 0.261208 | Val Loss 0.526982
# Epoch 500 | Train Loss 0.258140 | Val Loss 0.518069
# Epoch 600 | Train Loss 0.255927 | Val Loss 0.513608
# Epoch 700 | Train Loss 0.254816 | Val Loss 0.513209
# Early stopping at epoch 778
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8478.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8478.weights.h5
# X | Train_1 -> R² = 0.9949, MSE = 5.4598e-04
# Y | Train_1 -> R² = 0.7646, MSE = 1.9647e-02
# X | Train_2 -> R² = 0.9951, MSE = 4.1358e-04
# Y | Train_2 -> R² = 0.7661, MSE = 2.4978e-02
# X | Test_1 -> R² = 0.3058, MSE = 7.2023e-02
# Y | Test_1 -> R² = 0.8432, MSE = 1.2794e-02
# X | Test_2 -> R² = 0.5257, MSE = 3.8908e-02
# Y | Test_2 -> R² = 0.2073, MSE = 8.3444e-02
# X | Test_3 -> R² = 0.5509, MSE = 4.1031e-02
# Y | Test_3 -> R² = 0.8417, MSE = 1.2118e-02
# X | Val -> R² = 0.8205, MSE = 1.7026e-02
# Y | Val -> R² = 0.9389, MSE = 4.5395e-03
# X | LSG_1 -> R² = -0.3420, MSE = 1.3626e-01
# Y | LSG_1 -> R² = -4.2708, MSE = 1.6754e+00
# X | LSG_2 -> R² = -3.0576, MSE = 3.5731e-01
# Y | LSG_2 -> R² = -4.6177, MSE = 2.1742e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8478 salvo.
# Epoch 0 | Train Loss 0.991603 | Val Loss 0.761579
# Epoch 100 | Train Loss 0.592886 | Val Loss 0.589284
# Epoch 200 | Train Loss 0.552167 | Val Loss 0.563831
# Epoch 300 | Train Loss 0.542892 | Val Loss 0.546412
# Epoch 400 | Train Loss 0.537259 | Val Loss 0.540438
# Epoch 500 | Train Loss 0.532642 | Val Loss 0.536661
# Epoch 600 | Train Loss 0.528499 | Val Loss 0.538064
# Early stopping at epoch 687
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8857.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8857.weights.h5
# X | Train_1 -> R² = 0.9860, MSE = 1.4921e-03
# Y | Train_1 -> R² = 0.9456, MSE = 4.5371e-03
# X | Train_2 -> R² = 0.9950, MSE = 4.1977e-04
# Y | Train_2 -> R² = 0.9381, MSE = 6.6073e-03
# X | Test_1 -> R² = -1.1330, MSE = 2.2131e-01
# Y | Test_1 -> R² = 0.2264, MSE = 6.3123e-02
# X | Test_2 -> R² = -0.8000, MSE = 1.4765e-01
# Y | Test_2 -> R² = 0.6223, MSE = 3.9753e-02
# X | Test_3 -> R² = 0.6781, MSE = 2.9406e-02
# Y | Test_3 -> R² = -0.2317, MSE = 9.4272e-02
# X | Val -> R² = 0.0119, MSE = 9.3717e-02
# Y | Val -> R² = -0.3742, MSE = 1.0205e-01
# X | LSG_1 -> R² = -13.6826, MSE = 1.4909e+00
# Y | LSG_1 -> R² = -0.8660, MSE = 5.9311e-01
# X | LSG_2 -> R² = -28.5484, MSE = 2.6020e+00
# Y | LSG_2 -> R² = -0.7389, MSE = 6.7302e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8857 salvo.
# Epoch 0 | Train Loss 1.020889 | Val Loss 0.783914
# Epoch 100 | Train Loss 0.627155 | Val Loss 0.577207
# Epoch 200 | Train Loss 0.557342 | Val Loss 0.587694
# Epoch 300 | Train Loss 0.547204 | Val Loss 0.553000
# Epoch 400 | Train Loss 0.537506 | Val Loss 0.525452
# Epoch 500 | Train Loss 0.532255 | Val Loss 0.513059
# Epoch 600 | Train Loss 0.529343 | Val Loss 0.512067
# Epoch 700 | Train Loss 0.527275 | Val Loss 0.512428
# Early stopping at epoch 751
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1586.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1586.weights.h5
# X | Train_1 -> R² = 0.9911, MSE = 9.5229e-04
# Y | Train_1 -> R² = 0.9396, MSE = 5.0379e-03
# X | Train_2 -> R² = 0.9946, MSE = 4.5593e-04
# Y | Train_2 -> R² = 0.9474, MSE = 5.6178e-03
# X | Test_1 -> R² = -0.0616, MSE = 1.1015e-01
# Y | Test_1 -> R² = 0.7328, MSE = 2.1803e-02
# X | Test_2 -> R² = -0.2273, MSE = 1.0067e-01
# Y | Test_2 -> R² = -0.6014, MSE = 1.6856e-01
# X | Test_3 -> R² = 0.8098, MSE = 1.7378e-02
# Y | Test_3 -> R² = 0.7906, MSE = 1.6024e-02
# X | Val -> R² = 0.6123, MSE = 3.6775e-02
# Y | Val -> R² = 0.9040, MSE = 7.1291e-03
# X | LSG_1 -> R² = -11.6502, MSE = 1.2845e+00
# Y | LSG_1 -> R² = -2.3966, MSE = 1.0796e+00
# X | LSG_2 -> R² = -18.1765, MSE = 1.6886e+00
# Y | LSG_2 -> R² = -2.9620, MSE = 1.5335e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1586 salvo.
# Epoch 0 | Train Loss 1.002895 | Val Loss 0.763383
# Epoch 100 | Train Loss 0.606324 | Val Loss 0.594105
# Epoch 200 | Train Loss 0.551225 | Val Loss 0.580414
# Epoch 300 | Train Loss 0.543823 | Val Loss 0.543161
# Epoch 400 | Train Loss 0.537691 | Val Loss 0.524198
# Epoch 500 | Train Loss 0.532914 | Val Loss 0.519653
# Epoch 600 | Train Loss 0.530171 | Val Loss 0.522778
# Early stopping at epoch 675
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1658.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1658.weights.h5
# X | Train_1 -> R² = 0.9920, MSE = 8.5736e-04
# Y | Train_1 -> R² = 0.9182, MSE = 6.8317e-03
# X | Train_2 -> R² = 0.9956, MSE = 3.6869e-04
# Y | Train_2 -> R² = 0.9372, MSE = 6.7012e-03
# X | Test_1 -> R² = -0.3444, MSE = 1.3949e-01
# Y | Test_1 -> R² = 0.9687, MSE = 2.5571e-03
# X | Test_2 -> R² = -0.9972, MSE = 1.6382e-01
# Y | Test_2 -> R² = 0.9209, MSE = 8.3219e-03
# X | Test_3 -> R² = 0.5413, MSE = 4.1905e-02
# Y | Test_3 -> R² = 0.7132, MSE = 2.1947e-02
# X | Val -> R² = 0.7726, MSE = 2.1569e-02
# Y | Val -> R² = 0.5105, MSE = 3.6350e-02
# X | LSG_1 -> R² = -32.4363, MSE = 3.3951e+00
# Y | LSG_1 -> R² = -2.4872, MSE = 1.1084e+00
# X | LSG_2 -> R² = -43.0285, MSE = 3.8770e+00
# Y | LSG_2 -> R² = -1.8614, MSE = 1.1075e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1658 salvo.
# Epoch 0 | Train Loss 0.974563 | Val Loss 0.757538
# Epoch 100 | Train Loss 0.611807 | Val Loss 0.589837
# Epoch 200 | Train Loss 0.554865 | Val Loss 0.568004
# Epoch 300 | Train Loss 0.542136 | Val Loss 0.546586
# Epoch 400 | Train Loss 0.536871 | Val Loss 0.538857
# Epoch 500 | Train Loss 0.533634 | Val Loss 0.533021
# Epoch 600 | Train Loss 0.530975 | Val Loss 0.527933
# Epoch 700 | Train Loss 0.528910 | Val Loss 0.525316
# Epoch 800 | Train Loss 0.527146 | Val Loss 0.524371
# Epoch 900 | Train Loss 0.525334 | Val Loss 0.525460
# Early stopping at epoch 932
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed9028.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed9028.weights.h5
# X | Train_1 -> R² = 0.9931, MSE = 7.3157e-04
# Y | Train_1 -> R² = 0.9485, MSE = 4.3014e-03
# X | Train_2 -> R² = 0.9956, MSE = 3.7318e-04
# Y | Train_2 -> R² = 0.9450, MSE = 5.8681e-03
# X | Test_1 -> R² = 0.7406, MSE = 2.6913e-02
# Y | Test_1 -> R² = 0.6706, MSE = 2.6875e-02
# X | Test_2 -> R² = 0.8326, MSE = 1.3728e-02
# Y | Test_2 -> R² = -0.5592, MSE = 1.6413e-01
# X | Test_3 -> R² = -2.1107, MSE = 2.8417e-01
# Y | Test_3 -> R² = 0.9402, MSE = 4.5776e-03
# X | Val -> R² = 0.4165, MSE = 5.5338e-02
# Y | Val -> R² = 0.6981, MSE = 2.2415e-02
# X | LSG_1 -> R² = -8.0267, MSE = 9.1656e-01
# Y | LSG_1 -> R² = 0.5632, MSE = 1.3883e-01
# X | LSG_2 -> R² = -16.6299, MSE = 1.5524e+00
# Y | LSG_2 -> R² = 0.5076, MSE = 1.9058e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=9028 salvo.
# Epoch 0 | Train Loss 1.010679 | Val Loss 0.787651
# Epoch 100 | Train Loss 0.639913 | Val Loss 0.598995
# Epoch 200 | Train Loss 0.558488 | Val Loss 0.592829
# Epoch 300 | Train Loss 0.545822 | Val Loss 0.596657
# Epoch 400 | Train Loss 0.538549 | Val Loss 0.587479
# Epoch 500 | Train Loss 0.532692 | Val Loss 0.565805
# Epoch 600 | Train Loss 0.528737 | Val Loss 0.548982
# Epoch 700 | Train Loss 0.526532 | Val Loss 0.543450
# Epoch 800 | Train Loss 0.524841 | Val Loss 0.543799
# Early stopping at epoch 886
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8478.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8478.weights.h5
# X | Train_1 -> R² = 0.9813, MSE = 1.9930e-03
# Y | Train_1 -> R² = 0.9269, MSE = 6.1041e-03
# X | Train_2 -> R² = 0.9957, MSE = 3.6167e-04
# Y | Train_2 -> R² = 0.9522, MSE = 5.1052e-03
# X | Test_1 -> R² = -0.9483, MSE = 2.0215e-01
# Y | Test_1 -> R² = 0.4926, MSE = 4.1404e-02
# X | Test_2 -> R² = 0.8450, MSE = 1.2714e-02
# Y | Test_2 -> R² = -1.1714, MSE = 2.2857e-01
# X | Test_3 -> R² = 0.2406, MSE = 6.9375e-02
# Y | Test_3 -> R² = -1.3393, MSE = 1.7904e-01
# X | Val -> R² = 0.5246, MSE = 4.5091e-02
# Y | Val -> R² = -0.1854, MSE = 8.8025e-02
# X | LSG_1 -> R² = -10.1253, MSE = 1.1297e+00
# Y | LSG_1 -> R² = -0.4055, MSE = 4.4675e-01
# X | LSG_2 -> R² = -6.4404, MSE = 6.5518e-01
# Y | LSG_2 -> R² = -0.6840, MSE = 6.5178e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8478 salvo.
# Epoch 0 | Train Loss 0.999679 | Val Loss 0.768510
# Epoch 100 | Train Loss 0.630436 | Val Loss 0.582169
# Epoch 200 | Train Loss 0.548208 | Val Loss 0.545688
# Epoch 300 | Train Loss 0.539910 | Val Loss 0.524476
# Epoch 400 | Train Loss 0.535493 | Val Loss 0.519792
# Epoch 500 | Train Loss 0.532107 | Val Loss 0.521895
# Early stopping at epoch 560
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8857.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8857.weights.h5
# X | Train_1 -> R² = 0.9878, MSE = 1.3039e-03
# Y | Train_1 -> R² = 0.9401, MSE = 4.9990e-03
# X | Train_2 -> R² = 0.9862, MSE = 1.1610e-03
# Y | Train_2 -> R² = 0.9301, MSE = 7.4599e-03
# X | Test_1 -> R² = 0.1811, MSE = 8.4963e-02
# Y | Test_1 -> R² = 0.8853, MSE = 9.3571e-03
# X | Test_2 -> R² = -0.3912, MSE = 1.1412e-01
# Y | Test_2 -> R² = 0.9263, MSE = 7.7581e-03
# X | Test_3 -> R² = -0.2851, MSE = 1.1740e-01
# Y | Test_3 -> R² = 0.4639, MSE = 4.1030e-02
# X | Val -> R² = 0.7206, MSE = 2.6502e-02
# Y | Val -> R² = 0.5032, MSE = 3.6892e-02
# X | LSG_1 -> R² = -7.6939, MSE = 8.8277e-01
# Y | LSG_1 -> R² = -0.2532, MSE = 3.9833e-01
# X | LSG_2 -> R² = -14.0008, MSE = 1.3209e+00
# Y | LSG_2 -> R² = -0.8869, MSE = 7.3031e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8857 salvo.
# Epoch 0 | Train Loss 0.985817 | Val Loss 0.746117
# Epoch 100 | Train Loss 0.594574 | Val Loss 0.586984
# Epoch 200 | Train Loss 0.553232 | Val Loss 0.568698
# Epoch 300 | Train Loss 0.541969 | Val Loss 0.533332
# Epoch 400 | Train Loss 0.535383 | Val Loss 0.517152
# Epoch 500 | Train Loss 0.531731 | Val Loss 0.514699
# Epoch 600 | Train Loss 0.529506 | Val Loss 0.517742
# Early stopping at epoch 631
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1586.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1586.weights.h5
# X | Train_1 -> R² = 0.9925, MSE = 8.0206e-04
# Y | Train_1 -> R² = 0.9267, MSE = 6.1203e-03
# X | Train_2 -> R² = 0.9789, MSE = 1.7757e-03
# Y | Train_2 -> R² = 0.9367, MSE = 6.7607e-03
# X | Test_1 -> R² = 0.8385, MSE = 1.6754e-02
# Y | Test_1 -> R² = 0.8954, MSE = 8.5359e-03
# X | Test_2 -> R² = -1.1762, MSE = 1.7851e-01
# Y | Test_2 -> R² = 0.5583, MSE = 4.6496e-02
# X | Test_3 -> R² = -4.0681, MSE = 4.6299e-01
# Y | Test_3 -> R² = -0.4984, MSE = 1.1468e-01
# X | Val -> R² = 0.3650, MSE = 6.0227e-02
# Y | Val -> R² = 0.1493, MSE = 6.3166e-02
# X | LSG_1 -> R² = -1.1117, MSE = 2.1442e-01
# Y | LSG_1 -> R² = -5.4319, MSE = 2.0444e+00
# X | LSG_2 -> R² = -14.9413, MSE = 1.4038e+00
# Y | LSG_2 -> R² = -3.3525, MSE = 1.6846e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1586 salvo.
# Epoch 0 | Train Loss 1.005383 | Val Loss 0.774904
# Epoch 100 | Train Loss 0.614987 | Val Loss 0.618665
# Epoch 200 | Train Loss 0.550804 | Val Loss 0.607165
# Epoch 300 | Train Loss 0.540342 | Val Loss 0.555616
# Epoch 400 | Train Loss 0.534958 | Val Loss 0.530826
# Epoch 500 | Train Loss 0.532022 | Val Loss 0.519875
# Epoch 600 | Train Loss 0.530071 | Val Loss 0.516497
# Epoch 700 | Train Loss 0.528487 | Val Loss 0.516431
# Epoch 800 | Train Loss 0.527073 | Val Loss 0.516005
# Early stopping at epoch 802
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1658.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1658.weights.h5
# X | Train_1 -> R² = 0.9920, MSE = 8.5026e-04
# Y | Train_1 -> R² = 0.9279, MSE = 6.0219e-03
# X | Train_2 -> R² = 0.9954, MSE = 3.8354e-04
# Y | Train_2 -> R² = 0.9382, MSE = 6.6035e-03
# X | Test_1 -> R² = 0.7686, MSE = 2.4008e-02
# Y | Test_1 -> R² = 0.7768, MSE = 1.8212e-02
# X | Test_2 -> R² = 0.5782, MSE = 3.4596e-02
# Y | Test_2 -> R² = 0.6625, MSE = 3.5527e-02
# X | Test_3 -> R² = -2.5348, MSE = 3.2292e-01
# Y | Test_3 -> R² = -2.1142, MSE = 2.3835e-01
# X | Val -> R² = 0.3764, MSE = 5.9141e-02
# Y | Val -> R² = -0.3787, MSE = 1.0238e-01
# X | LSG_1 -> R² = -1.0276, MSE = 2.0588e-01
# Y | LSG_1 -> R² = -12.4540, MSE = 4.2765e+00
# X | LSG_2 -> R² = -0.8443, MSE = 1.6241e-01
# Y | LSG_2 -> R² = -10.7110, MSE = 4.5326e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1658 salvo.
# Epoch 0 | Train Loss 0.978522 | Val Loss 0.765098
# Epoch 100 | Train Loss 0.611640 | Val Loss 0.593944
# Epoch 200 | Train Loss 0.553126 | Val Loss 0.589784
# Epoch 300 | Train Loss 0.543077 | Val Loss 0.539648
# Epoch 400 | Train Loss 0.536374 | Val Loss 0.514558
# Epoch 500 | Train Loss 0.531642 | Val Loss 0.502989
# Epoch 600 | Train Loss 0.528295 | Val Loss 0.498917
# Epoch 700 | Train Loss 0.526267 | Val Loss 0.499500
# Early stopping at epoch 760
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed9028.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed9028.weights.h5
# X | Train_1 -> R² = 0.9905, MSE = 1.0152e-03
# Y | Train_1 -> R² = 0.9592, MSE = 3.4092e-03
# X | Train_2 -> R² = 0.9822, MSE = 1.4974e-03
# Y | Train_2 -> R² = 0.9377, MSE = 6.6566e-03
# X | Test_1 -> R² = 0.2640, MSE = 7.6370e-02
# Y | Test_1 -> R² = 0.9103, MSE = 7.3168e-03
# X | Test_2 -> R² = 0.4645, MSE = 4.3928e-02
# Y | Test_2 -> R² = -0.3949, MSE = 1.4683e-01
# X | Test_3 -> R² = -0.5198, MSE = 1.3884e-01
# Y | Test_3 -> R² = -0.5844, MSE = 1.2127e-01
# X | Val -> R² = 0.7144, MSE = 2.7085e-02
# Y | Val -> R² = 0.3963, MSE = 4.4829e-02
# X | LSG_1 -> R² = -5.4803, MSE = 6.5800e-01
# Y | LSG_1 -> R² = -1.9974, MSE = 9.5275e-01
# X | LSG_2 -> R² = -13.2893, MSE = 1.2583e+00
# Y | LSG_2 -> R² = -0.7612, MSE = 6.8166e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=9028 salvo.
# Epoch 0 | Train Loss 0.986507 | Val Loss 0.764727
# Epoch 100 | Train Loss 0.629176 | Val Loss 0.596832
# Epoch 200 | Train Loss 0.551937 | Val Loss 0.580002
# Epoch 300 | Train Loss 0.540729 | Val Loss 0.550886
# Epoch 400 | Train Loss 0.534799 | Val Loss 0.539303
# Epoch 500 | Train Loss 0.531050 | Val Loss 0.525649
# Epoch 600 | Train Loss 0.527938 | Val Loss 0.514281
# Epoch 700 | Train Loss 0.525348 | Val Loss 0.506436
# Epoch 800 | Train Loss 0.523332 | Val Loss 0.501365
# Epoch 900 | Train Loss 0.521641 | Val Loss 0.500357
# Epoch 1000 | Train Loss 0.520102 | Val Loss 0.502513
# Early stopping at epoch 1036
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8478.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8478.weights.h5
# X | Train_1 -> R² = 0.9887, MSE = 1.2116e-03
# Y | Train_1 -> R² = 0.9495, MSE = 4.2148e-03
# X | Train_2 -> R² = 0.9940, MSE = 5.0636e-04
# Y | Train_2 -> R² = 0.9547, MSE = 4.8372e-03
# X | Test_1 -> R² = -0.4567, MSE = 1.5114e-01
# Y | Test_1 -> R² = 0.7814, MSE = 1.7841e-02
# X | Test_2 -> R² = 0.5634, MSE = 3.5813e-02
# Y | Test_2 -> R² = -0.1651, MSE = 1.2264e-01
# X | Test_3 -> R² = -2.8455, MSE = 3.5130e-01
# Y | Test_3 -> R² = 0.8235, MSE = 1.3508e-02
# X | Val -> R² = -0.3413, MSE = 1.2721e-01
# Y | Val -> R² = 0.8849, MSE = 8.5471e-03
# X | LSG_1 -> R² = 0.2532, MSE = 7.5830e-02
# Y | LSG_1 -> R² = -4.4110, MSE = 1.7199e+00
# X | LSG_2 -> R² = -0.6623, MSE = 1.4638e-01
# Y | LSG_2 -> R² = -8.6321, MSE = 3.7280e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8478 salvo.
# Epoch 0 | Train Loss 0.617482 | Val Loss 0.765032
# Epoch 100 | Train Loss 0.275350 | Val Loss 0.578739
# Epoch 200 | Train Loss 0.264147 | Val Loss 0.531483
# Epoch 300 | Train Loss 0.257718 | Val Loss 0.509152
# Epoch 400 | Train Loss 0.255426 | Val Loss 0.504858
# Epoch 500 | Train Loss 0.254315 | Val Loss 0.505589
# Early stopping at epoch 568
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8857.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8857.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.7374e-04
# Y | Train_1 -> R² = 0.7702, MSE = 1.9182e-02
# X | Train_2 -> R² = 0.9968, MSE = 2.6478e-04
# Y | Train_2 -> R² = 0.7613, MSE = 2.5487e-02
# X | Test_1 -> R² = 0.4575, MSE = 5.6290e-02
# Y | Test_1 -> R² = 0.9801, MSE = 1.6209e-03
# X | Test_2 -> R² = 0.0928, MSE = 7.4418e-02
# Y | Test_2 -> R² = 0.7260, MSE = 2.8837e-02
# X | Test_3 -> R² = 0.2280, MSE = 7.0527e-02
# Y | Test_3 -> R² = 0.9344, MSE = 5.0205e-03
# X | Val -> R² = 0.5631, MSE = 4.1441e-02
# Y | Val -> R² = 0.9275, MSE = 5.3854e-03
# X | LSG_1 -> R² = -4.1676, MSE = 5.2471e-01
# Y | LSG_1 -> R² = -3.0168, MSE = 1.2768e+00
# X | LSG_2 -> R² = -13.5159, MSE = 1.2782e+00
# Y | LSG_2 -> R² = -1.7532, MSE = 1.0656e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8857 salvo.
# Epoch 0 | Train Loss 0.624276 | Val Loss 0.799555
# Epoch 100 | Train Loss 0.274582 | Val Loss 0.588211
# Epoch 200 | Train Loss 0.264364 | Val Loss 0.537077
# Epoch 300 | Train Loss 0.259078 | Val Loss 0.513426
# Epoch 400 | Train Loss 0.255952 | Val Loss 0.504405
# Epoch 500 | Train Loss 0.254439 | Val Loss 0.505549
# Epoch 600 | Train Loss 0.253277 | Val Loss 0.510242
# Early stopping at epoch 609
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1586.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1586.weights.h5
# X | Train_1 -> R² = 0.9931, MSE = 7.3362e-04
# Y | Train_1 -> R² = 0.7612, MSE = 1.9937e-02
# X | Train_2 -> R² = 0.9971, MSE = 2.4175e-04
# Y | Train_2 -> R² = 0.7484, MSE = 2.6860e-02
# X | Test_1 -> R² = 0.4101, MSE = 6.1207e-02
# Y | Test_1 -> R² = 0.8997, MSE = 8.1804e-03
# X | Test_2 -> R² = 0.8119, MSE = 1.5428e-02
# Y | Test_2 -> R² = 0.4237, MSE = 6.0662e-02
# X | Test_3 -> R² = -0.0123, MSE = 9.2474e-02
# Y | Test_3 -> R² = 0.9114, MSE = 6.7795e-03
# X | Val -> R² = 0.4309, MSE = 5.3976e-02
# Y | Val -> R² = 0.9152, MSE = 6.2993e-03
# X | LSG_1 -> R² = -0.9114, MSE = 1.9408e-01
# Y | LSG_1 -> R² = -5.7817, MSE = 2.1556e+00
# X | LSG_2 -> R² = -3.3678, MSE = 3.8462e-01
# Y | LSG_2 -> R² = -6.7073, MSE = 2.9830e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1586 salvo.
# Epoch 0 | Train Loss 0.668033 | Val Loss 0.758369
# Epoch 100 | Train Loss 0.275720 | Val Loss 0.576227
# Epoch 200 | Train Loss 0.266746 | Val Loss 0.537672
# Epoch 300 | Train Loss 0.260751 | Val Loss 0.525880
# Epoch 400 | Train Loss 0.256858 | Val Loss 0.523063
# Epoch 500 | Train Loss 0.254690 | Val Loss 0.520483
# Epoch 600 | Train Loss 0.253198 | Val Loss 0.518273
# Epoch 700 | Train Loss 0.252148 | Val Loss 0.519240
# Early stopping at epoch 775
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1658.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1658.weights.h5
# X | Train_1 -> R² = 0.9937, MSE = 6.7388e-04
# Y | Train_1 -> R² = 0.7922, MSE = 1.7350e-02
# X | Train_2 -> R² = 0.9981, MSE = 1.6023e-04
# Y | Train_2 -> R² = 0.7546, MSE = 2.6203e-02
# X | Test_1 -> R² = 0.4582, MSE = 5.6219e-02
# Y | Test_1 -> R² = 0.2108, MSE = 6.4399e-02
# X | Test_2 -> R² = 0.7207, MSE = 2.2913e-02
# Y | Test_2 -> R² = 0.3364, MSE = 6.9853e-02
# X | Test_3 -> R² = 0.3354, MSE = 6.0715e-02
# Y | Test_3 -> R² = -0.3561, MSE = 1.0379e-01
# X | Val -> R² = 0.8582, MSE = 1.3450e-02
# Y | Val -> R² = -0.0133, MSE = 7.5245e-02
# X | LSG_1 -> R² = -2.2277, MSE = 3.2774e-01
# Y | LSG_1 -> R² = 0.0671, MSE = 2.9654e-01
# X | LSG_2 -> R² = -5.0468, MSE = 5.3247e-01
# Y | LSG_2 -> R² = -0.0300, MSE = 3.9864e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1658 salvo.
# Epoch 0 | Train Loss 0.620610 | Val Loss 0.771276
# Epoch 100 | Train Loss 0.276132 | Val Loss 0.617818
# Epoch 200 | Train Loss 0.266772 | Val Loss 0.563597
# Epoch 300 | Train Loss 0.260700 | Val Loss 0.524617
# Epoch 400 | Train Loss 0.256897 | Val Loss 0.514648
# Epoch 500 | Train Loss 0.255067 | Val Loss 0.513593
# Epoch 600 | Train Loss 0.253741 | Val Loss 0.514557
# Early stopping at epoch 606
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed9028.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed9028.weights.h5
# X | Train_1 -> R² = 0.9927, MSE = 7.8208e-04
# Y | Train_1 -> R² = 0.7654, MSE = 1.9587e-02
# X | Train_2 -> R² = 0.9968, MSE = 2.6946e-04
# Y | Train_2 -> R² = 0.7433, MSE = 2.7410e-02
# X | Test_1 -> R² = 0.5109, MSE = 5.0744e-02
# Y | Test_1 -> R² = 0.9733, MSE = 2.1818e-03
# X | Test_2 -> R² = 0.9288, MSE = 5.8430e-03
# Y | Test_2 -> R² = 0.1790, MSE = 8.6418e-02
# X | Test_3 -> R² = 0.3867, MSE = 5.6024e-02
# Y | Test_3 -> R² = 0.7420, MSE = 1.9748e-02
# X | Val -> R² = 0.7662, MSE = 2.2170e-02
# Y | Val -> R² = 0.8720, MSE = 9.5020e-03
# X | LSG_1 -> R² = -9.9957, MSE = 1.1165e+00
# Y | LSG_1 -> R² = -2.1874, MSE = 1.0131e+00
# X | LSG_2 -> R² = -12.1935, MSE = 1.1618e+00
# Y | LSG_2 -> R² = -2.9313, MSE = 1.5216e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9028 salvo.
# Epoch 0 | Train Loss 0.594327 | Val Loss 0.742972
# Epoch 100 | Train Loss 0.274704 | Val Loss 0.587794
# Epoch 200 | Train Loss 0.262500 | Val Loss 0.530387
# Epoch 300 | Train Loss 0.257076 | Val Loss 0.510961
# Epoch 400 | Train Loss 0.254946 | Val Loss 0.504475
# Epoch 500 | Train Loss 0.253640 | Val Loss 0.503923
# Epoch 600 | Train Loss 0.252404 | Val Loss 0.507224
# Early stopping at epoch 651
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8478.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8478.weights.h5
# X | Train_1 -> R² = 0.9909, MSE = 9.7228e-04
# Y | Train_1 -> R² = 0.8027, MSE = 1.6467e-02
# X | Train_2 -> R² = 0.9978, MSE = 1.8755e-04
# Y | Train_2 -> R² = 0.7408, MSE = 2.7670e-02
# X | Test_1 -> R² = 0.3081, MSE = 7.1789e-02
# Y | Test_1 -> R² = 0.6918, MSE = 2.5147e-02
# X | Test_2 -> R² = 0.8280, MSE = 1.4111e-02
# Y | Test_2 -> R² = 0.3630, MSE = 6.7051e-02
# X | Test_3 -> R² = 0.0589, MSE = 8.5975e-02
# Y | Test_3 -> R² = 0.9150, MSE = 6.5030e-03
# X | Val -> R² = 0.8469, MSE = 1.4517e-02
# Y | Val -> R² = 0.4955, MSE = 3.7461e-02
# X | LSG_1 -> R² = 0.4302, MSE = 5.7859e-02
# Y | LSG_1 -> R² = -6.2791, MSE = 2.3137e+00
# X | LSG_2 -> R² = -0.0854, MSE = 9.5582e-02
# Y | LSG_2 -> R² = -4.7435, MSE = 2.2230e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8478 salvo.
# Epoch 0 | Train Loss 0.582604 | Val Loss 0.715207
# Epoch 100 | Train Loss 0.276160 | Val Loss 0.604633
# Epoch 200 | Train Loss 0.264242 | Val Loss 0.540499
# Epoch 300 | Train Loss 0.258711 | Val Loss 0.509065
# Epoch 400 | Train Loss 0.256349 | Val Loss 0.500049
# Epoch 500 | Train Loss 0.254557 | Val Loss 0.498015
# Epoch 600 | Train Loss 0.253114 | Val Loss 0.498483
# Early stopping at epoch 658
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8857.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8857.weights.h5
# X | Train_1 -> R² = 0.9958, MSE = 4.4831e-04
# Y | Train_1 -> R² = 0.7697, MSE = 1.9222e-02
# X | Train_2 -> R² = 0.9969, MSE = 2.6053e-04
# Y | Train_2 -> R² = 0.7472, MSE = 2.6989e-02
# X | Test_1 -> R² = 0.7987, MSE = 2.0884e-02
# Y | Test_1 -> R² = 0.9817, MSE = 1.4919e-03
# X | Test_2 -> R² = 0.3756, MSE = 5.1220e-02
# Y | Test_2 -> R² = 0.7331, MSE = 2.8098e-02
# X | Test_3 -> R² = -0.4537, MSE = 1.3280e-01
# Y | Test_3 -> R² = 0.8431, MSE = 1.2006e-02
# X | Val -> R² = 0.4201, MSE = 5.4995e-02
# Y | Val -> R² = 0.9462, MSE = 3.9939e-03
# X | LSG_1 -> R² = 0.3460, MSE = 6.6410e-02
# Y | LSG_1 -> R² = -4.3570, MSE = 1.7028e+00
# X | LSG_2 -> R² = -3.4492, MSE = 3.9179e-01
# Y | LSG_2 -> R² = -3.4587, MSE = 1.7257e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8857 salvo.
# Epoch 0 | Train Loss 0.642043 | Val Loss 0.768348
# Epoch 100 | Train Loss 0.277185 | Val Loss 0.609675
# Epoch 200 | Train Loss 0.266001 | Val Loss 0.542523
# Epoch 300 | Train Loss 0.259184 | Val Loss 0.518834
# Epoch 400 | Train Loss 0.255732 | Val Loss 0.510022
# Epoch 500 | Train Loss 0.254221 | Val Loss 0.509637
# Epoch 600 | Train Loss 0.253181 | Val Loss 0.511980
# Early stopping at epoch 636
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1586.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1586.weights.h5
# X | Train_1 -> R² = 0.9951, MSE = 5.2240e-04
# Y | Train_1 -> R² = 0.7713, MSE = 1.9094e-02
# X | Train_2 -> R² = 0.9974, MSE = 2.1967e-04
# Y | Train_2 -> R² = 0.7538, MSE = 2.6283e-02
# X | Test_1 -> R² = 0.6479, MSE = 3.6537e-02
# Y | Test_1 -> R² = 0.9512, MSE = 3.9818e-03
# X | Test_2 -> R² = -0.0351, MSE = 8.4910e-02
# Y | Test_2 -> R² = 0.6678, MSE = 3.4968e-02
# X | Test_3 -> R² = -1.6982, MSE = 2.4649e-01
# Y | Test_3 -> R² = 0.7276, MSE = 2.0845e-02
# X | Val -> R² = 0.2825, MSE = 6.8046e-02
# Y | Val -> R² = 0.8914, MSE = 8.0656e-03
# X | LSG_1 -> R² = -0.0141, MSE = 1.0297e-01
# Y | LSG_1 -> R² = -3.7736, MSE = 1.5173e+00
# X | LSG_2 -> R² = -3.4160, MSE = 3.8887e-01
# Y | LSG_2 -> R² = -3.3549, MSE = 1.6855e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1586 salvo.
# Epoch 0 | Train Loss 0.661149 | Val Loss 0.768803
# Epoch 100 | Train Loss 0.275262 | Val Loss 0.601691
# Epoch 200 | Train Loss 0.264611 | Val Loss 0.537580
# Epoch 300 | Train Loss 0.259424 | Val Loss 0.514424
# Epoch 400 | Train Loss 0.256524 | Val Loss 0.505435
# Epoch 500 | Train Loss 0.255044 | Val Loss 0.504474
# Epoch 600 | Train Loss 0.253953 | Val Loss 0.506406
# Early stopping at epoch 615
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1658.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1658.weights.h5
# X | Train_1 -> R² = 0.9945, MSE = 5.9012e-04
# Y | Train_1 -> R² = 0.7445, MSE = 2.1329e-02
# X | Train_2 -> R² = 0.9970, MSE = 2.5140e-04
# Y | Train_2 -> R² = 0.7409, MSE = 2.7659e-02
# X | Test_1 -> R² = 0.6228, MSE = 3.9139e-02
# Y | Test_1 -> R² = 0.9722, MSE = 2.2660e-03
# X | Test_2 -> R² = 0.0118, MSE = 8.1062e-02
# Y | Test_2 -> R² = 0.7995, MSE = 2.1106e-02
# X | Test_3 -> R² = 0.3196, MSE = 6.2154e-02
# Y | Test_3 -> R² = 0.8692, MSE = 1.0013e-02
# X | Val -> R² = 0.8355, MSE = 1.5605e-02
# Y | Val -> R² = 0.8530, MSE = 1.0916e-02
# X | LSG_1 -> R² = -2.4492, MSE = 3.5023e-01
# Y | LSG_1 -> R² = -5.7968, MSE = 2.1604e+00
# X | LSG_2 -> R² = -9.5537, MSE = 9.2933e-01
# Y | LSG_2 -> R² = -4.8885, MSE = 2.2791e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1658 salvo.
# Epoch 0 | Train Loss 0.647030 | Val Loss 0.755814
# Epoch 100 | Train Loss 0.276008 | Val Loss 0.590282
# Epoch 200 | Train Loss 0.266979 | Val Loss 0.539110
# Epoch 300 | Train Loss 0.260080 | Val Loss 0.521941
# Epoch 400 | Train Loss 0.256306 | Val Loss 0.517273
# Epoch 500 | Train Loss 0.254774 | Val Loss 0.516660
# Epoch 600 | Train Loss 0.253620 | Val Loss 0.516955
# Early stopping at epoch 619
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed9028.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed9028.weights.h5
# X | Train_1 -> R² = 0.9945, MSE = 5.8586e-04
# Y | Train_1 -> R² = 0.7513, MSE = 2.0763e-02
# X | Train_2 -> R² = 0.9962, MSE = 3.1919e-04
# Y | Train_2 -> R² = 0.7491, MSE = 2.6793e-02
# X | Test_1 -> R² = 0.4814, MSE = 5.3811e-02
# Y | Test_1 -> R² = 0.6808, MSE = 2.6049e-02
# X | Test_2 -> R² = -0.5804, MSE = 1.2964e-01
# Y | Test_2 -> R² = 0.7833, MSE = 2.2807e-02
# X | Test_3 -> R² = 0.6926, MSE = 2.8086e-02
# Y | Test_3 -> R² = 0.3566, MSE = 4.9241e-02
# X | Val -> R² = 0.7222, MSE = 2.6347e-02
# Y | Val -> R² = 0.3466, MSE = 4.8519e-02
# X | LSG_1 -> R² = -8.5145, MSE = 9.6610e-01
# Y | LSG_1 -> R² = -0.5600, MSE = 4.9586e-01
# X | LSG_2 -> R² = -11.4445, MSE = 1.0958e+00
# Y | LSG_2 -> R² = -1.0067, MSE = 7.7665e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9028 salvo.
# Epoch 0 | Train Loss 0.604105 | Val Loss 0.769233
# Epoch 100 | Train Loss 0.274254 | Val Loss 0.584032
# Epoch 200 | Train Loss 0.265407 | Val Loss 0.536222
# Epoch 300 | Train Loss 0.260161 | Val Loss 0.517276
# Epoch 400 | Train Loss 0.256365 | Val Loss 0.512987
# Epoch 500 | Train Loss 0.254584 | Val Loss 0.513806
# Early stopping at epoch 552
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8478.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8478.weights.h5
# X | Train_1 -> R² = 0.9924, MSE = 8.1363e-04
# Y | Train_1 -> R² = 0.7453, MSE = 2.1257e-02
# X | Train_2 -> R² = 0.9969, MSE = 2.6370e-04
# Y | Train_2 -> R² = 0.7302, MSE = 2.8806e-02
# X | Test_1 -> R² = 0.3973, MSE = 6.2540e-02
# Y | Test_1 -> R² = 0.9507, MSE = 4.0248e-03
# X | Test_2 -> R² = 0.5184, MSE = 3.9508e-02
# Y | Test_2 -> R² = 0.6776, MSE = 3.3937e-02
# X | Test_3 -> R² = 0.4951, MSE = 4.6127e-02
# Y | Test_3 -> R² = 0.7222, MSE = 2.1258e-02
# X | Val -> R² = 0.8057, MSE = 1.8427e-02
# Y | Val -> R² = 0.7850, MSE = 1.5965e-02
# X | LSG_1 -> R² = -2.6053, MSE = 3.6608e-01
# Y | LSG_1 -> R² = -4.0719, MSE = 1.6122e+00
# X | LSG_2 -> R² = -6.2798, MSE = 6.4104e-01
# Y | LSG_2 -> R² = -3.6047, MSE = 1.7822e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8478 salvo.
# Epoch 0 | Train Loss 0.956398 | Val Loss 0.723643
# Epoch 100 | Train Loss 0.557394 | Val Loss 0.633571
# Epoch 200 | Train Loss 0.542092 | Val Loss 0.553665
# Epoch 300 | Train Loss 0.533493 | Val Loss 0.516032
# Epoch 400 | Train Loss 0.528551 | Val Loss 0.506604
# Epoch 500 | Train Loss 0.525418 | Val Loss 0.503265
# Epoch 600 | Train Loss 0.523266 | Val Loss 0.503347
# Early stopping at epoch 681
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8857.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8857.weights.h5
# X | Train_1 -> R² = 0.9884, MSE = 1.2373e-03
# Y | Train_1 -> R² = 0.9334, MSE = 5.5568e-03
# X | Train_2 -> R² = 0.9968, MSE = 2.7245e-04
# Y | Train_2 -> R² = 0.9505, MSE = 5.2866e-03
# X | Test_1 -> R² = -0.2429, MSE = 1.2896e-01
# Y | Test_1 -> R² = 0.9894, MSE = 8.6458e-04
# X | Test_2 -> R² = 0.5866, MSE = 3.3912e-02
# Y | Test_2 -> R² = -0.3760, MSE = 1.4484e-01
# X | Test_3 -> R² = 0.5239, MSE = 4.3493e-02
# Y | Test_3 -> R² = 0.7580, MSE = 1.8520e-02
# X | Val -> R² = 0.4770, MSE = 4.9607e-02
# Y | Val -> R² = 0.5291, MSE = 3.4964e-02
# X | LSG_1 -> R² = -7.4043, MSE = 8.5337e-01
# Y | LSG_1 -> R² = -7.7442, MSE = 2.7794e+00
# X | LSG_2 -> R² = -10.9091, MSE = 1.0487e+00
# Y | LSG_2 -> R² = -7.6514, MSE = 3.3484e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8857 salvo.
# Epoch 0 | Train Loss 1.008540 | Val Loss 0.763292
# Epoch 100 | Train Loss 0.557927 | Val Loss 0.622364
# Epoch 200 | Train Loss 0.542148 | Val Loss 0.547132
# Epoch 300 | Train Loss 0.533548 | Val Loss 0.520061
# Epoch 400 | Train Loss 0.529080 | Val Loss 0.512193
# Epoch 500 | Train Loss 0.526219 | Val Loss 0.509568
# Epoch 600 | Train Loss 0.523575 | Val Loss 0.512069
# Early stopping at epoch 657
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1586.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1586.weights.h5
# X | Train_1 -> R² = 0.9871, MSE = 1.3810e-03
# Y | Train_1 -> R² = 0.9276, MSE = 6.0414e-03
# X | Train_2 -> R² = 0.9965, MSE = 2.9439e-04
# Y | Train_2 -> R² = 0.9465, MSE = 5.7100e-03
# X | Test_1 -> R² = -0.0177, MSE = 1.0559e-01
# Y | Test_1 -> R² = 0.9779, MSE = 1.8022e-03
# X | Test_2 -> R² = 0.8782, MSE = 9.9942e-03
# Y | Test_2 -> R² = 0.5723, MSE = 4.5020e-02
# X | Test_3 -> R² = -1.7909, MSE = 2.5496e-01
# Y | Test_3 -> R² = 0.5276, MSE = 3.6156e-02
# X | Val -> R² = 0.3630, MSE = 6.0415e-02
# Y | Val -> R² = 0.8407, MSE = 1.1826e-02
# X | LSG_1 -> R² = -1.4344, MSE = 2.4719e-01
# Y | LSG_1 -> R² = -7.2010, MSE = 2.6068e+00
# X | LSG_2 -> R² = -3.6798, MSE = 4.1209e-01
# Y | LSG_2 -> R² = -5.5585, MSE = 2.5384e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1586 salvo.
# Epoch 0 | Train Loss 1.024730 | Val Loss 0.740408
# Epoch 100 | Train Loss 0.555710 | Val Loss 0.613247
# Epoch 200 | Train Loss 0.542469 | Val Loss 0.550494
# Epoch 300 | Train Loss 0.534380 | Val Loss 0.521625
# Epoch 400 | Train Loss 0.528391 | Val Loss 0.504801
# Epoch 500 | Train Loss 0.525198 | Val Loss 0.498432
# Epoch 600 | Train Loss 0.523269 | Val Loss 0.498305
# Epoch 700 | Train Loss 0.521608 | Val Loss 0.500129
# Early stopping at epoch 731
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1658.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1658.weights.h5
# X | Train_1 -> R² = 0.9917, MSE = 8.8278e-04
# Y | Train_1 -> R² = 0.9430, MSE = 4.7598e-03
# X | Train_2 -> R² = 0.9972, MSE = 2.3671e-04
# Y | Train_2 -> R² = 0.9523, MSE = 5.0896e-03
# X | Test_1 -> R² = -0.6386, MSE = 1.7001e-01
# Y | Test_1 -> R² = 0.7860, MSE = 1.7461e-02
# X | Test_2 -> R² = 0.9866, MSE = 1.1029e-03
# Y | Test_2 -> R² = -0.3810, MSE = 1.4537e-01
# X | Test_3 -> R² = 0.3645, MSE = 5.8053e-02
# Y | Test_3 -> R² = 0.9172, MSE = 6.3401e-03
# X | Val -> R² = 0.6361, MSE = 3.4516e-02
# Y | Val -> R² = 0.9625, MSE = 2.7881e-03
# X | LSG_1 -> R² = 0.2803, MSE = 7.3080e-02
# Y | LSG_1 -> R² = -5.6936, MSE = 2.1276e+00
# X | LSG_2 -> R² = -0.0973, MSE = 9.6627e-02
# Y | LSG_2 -> R² = -7.7196, MSE = 3.3748e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1658 salvo.
# Epoch 0 | Train Loss 1.035861 | Val Loss 0.734607
# Epoch 100 | Train Loss 0.557141 | Val Loss 0.656804
# Epoch 200 | Train Loss 0.544491 | Val Loss 0.575362
# Epoch 300 | Train Loss 0.534689 | Val Loss 0.525961
# Epoch 400 | Train Loss 0.528283 | Val Loss 0.503684
# Epoch 500 | Train Loss 0.525477 | Val Loss 0.499183
# Epoch 600 | Train Loss 0.523527 | Val Loss 0.500510
# Early stopping at epoch 686
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed9028.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed9028.weights.h5
# X | Train_1 -> R² = 0.9885, MSE = 1.2325e-03
# Y | Train_1 -> R² = 0.9350, MSE = 5.4267e-03
# X | Train_2 -> R² = 0.9906, MSE = 7.8748e-04
# Y | Train_2 -> R² = 0.9547, MSE = 4.8336e-03
# X | Test_1 -> R² = -0.2765, MSE = 1.3244e-01
# Y | Test_1 -> R² = 0.9902, MSE = 8.0208e-04
# X | Test_2 -> R² = -0.3688, MSE = 1.1228e-01
# Y | Test_2 -> R² = 0.3157, MSE = 7.2031e-02
# X | Test_3 -> R² = -0.6088, MSE = 1.4697e-01
# Y | Test_3 -> R² = -1.3961, MSE = 1.8339e-01
# X | Val -> R² = 0.3601, MSE = 6.0689e-02
# Y | Val -> R² = -0.5673, MSE = 1.1638e-01
# X | LSG_1 -> R² = -4.4029, MSE = 5.4861e-01
# Y | LSG_1 -> R² = -10.5827, MSE = 3.6817e+00
# X | LSG_2 -> R² = -5.7840, MSE = 5.9739e-01
# Y | LSG_2 -> R² = -11.8530, MSE = 4.9746e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9028 salvo.
# Epoch 0 | Train Loss 0.972065 | Val Loss 0.766395
# Epoch 100 | Train Loss 0.558414 | Val Loss 0.605265
# Epoch 200 | Train Loss 0.540390 | Val Loss 0.538329
# Epoch 300 | Train Loss 0.531431 | Val Loss 0.515144
# Epoch 400 | Train Loss 0.526357 | Val Loss 0.502536
# Epoch 500 | Train Loss 0.523653 | Val Loss 0.499294
# Epoch 600 | Train Loss 0.521541 | Val Loss 0.501756
# Early stopping at epoch 669
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8478.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8478.weights.h5
# X | Train_1 -> R² = 0.9932, MSE = 7.2949e-04
# Y | Train_1 -> R² = 0.9425, MSE = 4.7986e-03
# X | Train_2 -> R² = 0.9977, MSE = 1.8973e-04
# Y | Train_2 -> R² = 0.9614, MSE = 4.1234e-03
# X | Test_1 -> R² = 0.3378, MSE = 6.8707e-02
# Y | Test_1 -> R² = 0.9908, MSE = 7.4792e-04
# X | Test_2 -> R² = 0.5739, MSE = 3.4951e-02
# Y | Test_2 -> R² = 0.0879, MSE = 9.6006e-02
# X | Test_3 -> R² = 0.2878, MSE = 6.5060e-02
# Y | Test_3 -> R² = 0.7719, MSE = 1.7457e-02
# X | Val -> R² = 0.4641, MSE = 5.0829e-02
# Y | Val -> R² = 0.8242, MSE = 1.3054e-02
# X | LSG_1 -> R² = -9.7413, MSE = 1.0907e+00
# Y | LSG_1 -> R² = -1.8267, MSE = 8.9848e-01
# X | LSG_2 -> R² = -22.0670, MSE = 2.0312e+00
# Y | LSG_2 -> R² = -1.1707, MSE = 8.4013e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8478 salvo.
# Epoch 0 | Train Loss 0.993933 | Val Loss 0.793802
# Epoch 100 | Train Loss 0.554716 | Val Loss 0.635418
# Epoch 200 | Train Loss 0.539575 | Val Loss 0.568132
# Epoch 300 | Train Loss 0.531326 | Val Loss 0.530742
# Epoch 400 | Train Loss 0.526939 | Val Loss 0.513796
# Epoch 500 | Train Loss 0.524306 | Val Loss 0.510873
# Epoch 600 | Train Loss 0.522030 | Val Loss 0.515165
# Early stopping at epoch 657
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed8857.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed8857.weights.h5
# X | Train_1 -> R² = 0.9906, MSE = 9.9931e-04
# Y | Train_1 -> R² = 0.9418, MSE = 4.8607e-03
# X | Train_2 -> R² = 0.9978, MSE = 1.8516e-04
# Y | Train_2 -> R² = 0.9450, MSE = 5.8686e-03
# X | Test_1 -> R² = -0.0902, MSE = 1.1312e-01
# Y | Test_1 -> R² = 0.9851, MSE = 1.2183e-03
# X | Test_2 -> R² = 0.8720, MSE = 1.0502e-02
# Y | Test_2 -> R² = -0.7078, MSE = 1.7977e-01
# X | Test_3 -> R² = -0.5067, MSE = 1.3764e-01
# Y | Test_3 -> R² = -1.2420, MSE = 1.7160e-01
# X | Val -> R² = 0.8060, MSE = 1.8400e-02
# Y | Val -> R² = 0.3828, MSE = 4.5831e-02
# X | LSG_1 -> R² = -0.2062, MSE = 1.2247e-01
# Y | LSG_1 -> R² = -21.5039, MSE = 7.1531e+00
# X | LSG_2 -> R² = -0.7198, MSE = 1.5144e-01
# Y | LSG_2 -> R² = -19.3818, MSE = 7.8885e+00
# ...
# X | LSG_2 -> R² = -2.7467, MSE = 3.2993e-01
# Y | LSG_2 -> R² = -1.1947, MSE = 8.4943e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8857 salvo.
# Epoch 0 | Train Loss 0.693262 | Val Loss 0.642561
# Epoch 100 | Train Loss 0.257079 | Val Loss 0.528682
# Epoch 200 | Train Loss 0.251378 | Val Loss 0.539683
# Epoch 300 | Train Loss 0.248360 | Val Loss 0.549042
# Early stopping at epoch 303
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1586.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1586.weights.h5
# X | Train_1 -> R² = 0.9945, MSE = 5.8331e-04
# Y | Train_1 -> R² = 0.6463, MSE = 2.9524e-02
# X | Train_2 -> R² = 0.8875, MSE = 9.4561e-03
# Y | Train_2 -> R² = 0.3843, MSE = 6.5738e-02
# X | Test_1 -> R² = -0.0388, MSE = 1.0778e-01
# Y | Test_1 -> R² = 0.5555, MSE = 3.6273e-02
# X | Test_2 -> R² = 0.9272, MSE = 5.9705e-03
# Y | Test_2 -> R² = -1.0627, MSE = 2.1712e-01
# X | Test_3 -> R² = 0.9321, MSE = 6.2027e-03
# Y | Test_3 -> R² = -1.8589, MSE = 2.1881e-01
# X | Val -> R² = 0.8557, MSE = 1.3687e-02
# Y | Val -> R² = 0.0450, MSE = 7.0915e-02
# X | LSG_1 -> R² = 0.1798, MSE = 8.3284e-02
# Y | LSG_1 -> R² = -3.2334, MSE = 1.3456e+00
# X | LSG_2 -> R² = -1.6304, MSE = 2.3163e-01
# Y | LSG_2 -> R² = -2.5337, MSE = 1.3677e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1586 salvo.
# Epoch 0 | Train Loss 0.661936 | Val Loss 0.680826
# Epoch 100 | Train Loss 0.255954 | Val Loss 0.526112
# Epoch 200 | Train Loss 0.251511 | Val Loss 0.543677
# Early stopping at epoch 268
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1658.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1658.weights.h5
# X | Train_1 -> R² = 0.9944, MSE = 5.9506e-04
# Y | Train_1 -> R² = 0.6860, MSE = 2.6210e-02
# X | Train_2 -> R² = 0.9965, MSE = 2.9207e-04
# Y | Train_2 -> R² = 0.7173, MSE = 3.0186e-02
# X | Test_1 -> R² = 0.2835, MSE = 7.4337e-02
# Y | Test_1 -> R² = 0.6864, MSE = 2.5586e-02
# X | Test_2 -> R² = -0.2193, MSE = 1.0002e-01
# Y | Test_2 -> R² = 0.8189, MSE = 1.9059e-02
# X | Test_3 -> R² = 0.9618, MSE = 3.4909e-03
# Y | Test_3 -> R² = -0.8887, MSE = 1.4455e-01
# X | Val -> R² = 0.7700, MSE = 2.1813e-02
# Y | Val -> R² = 0.4528, MSE = 4.0629e-02
# X | LSG_1 -> R² = -2.4575, MSE = 3.5107e-01
# Y | LSG_1 -> R² = -2.1022, MSE = 9.8608e-01
# X | LSG_2 -> R² = -10.5827, MSE = 1.0199e+00
# Y | LSG_2 -> R² = -1.4249, MSE = 9.3854e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1658 salvo.
# Epoch 0 | Train Loss 0.658733 | Val Loss 0.693324
# Epoch 100 | Train Loss 0.256647 | Val Loss 0.529385
# Epoch 200 | Train Loss 0.251740 | Val Loss 0.546489
# Epoch 300 | Train Loss 0.249096 | Val Loss 0.555951
# Early stopping at epoch 319
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed9028.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed9028.weights.h5
# X | Train_1 -> R² = 0.9954, MSE = 4.8591e-04
# Y | Train_1 -> R² = 0.6903, MSE = 2.5853e-02
# X | Train_2 -> R² = 0.9057, MSE = 7.9264e-03
# Y | Train_2 -> R² = 0.6276, MSE = 3.9767e-02
# X | Test_1 -> R² = 0.2346, MSE = 7.9417e-02
# Y | Test_1 -> R² = 0.7029, MSE = 2.4241e-02
# X | Test_2 -> R² = 0.7598, MSE = 1.9705e-02
# Y | Test_2 -> R² = -0.5245, MSE = 1.6047e-01
# X | Test_3 -> R² = 0.6846, MSE = 2.8812e-02
# Y | Test_3 -> R² = -1.5480, MSE = 1.9501e-01
# X | Val -> R² = 0.7401, MSE = 2.4648e-02
# Y | Val -> R² = 0.1450, MSE = 6.3490e-02
# X | LSG_1 -> R² = -1.0438, MSE = 2.0753e-01
# Y | LSG_1 -> R² = -2.3079, MSE = 1.0514e+00
# X | LSG_2 -> R² = -5.2159, MSE = 5.4736e-01
# Y | LSG_2 -> R² = -1.9178, MSE = 1.1293e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=9028 salvo.
# Epoch 0 | Train Loss 0.678764 | Val Loss 0.705098
# Epoch 100 | Train Loss 0.257841 | Val Loss 0.531952
# Epoch 200 | Train Loss 0.252082 | Val Loss 0.536565
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8478.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8478.weights.h5
# X | Train_1 -> R² = 0.9915, MSE = 9.0711e-04
# Y | Train_1 -> R² = 0.6893, MSE = 2.5938e-02
# X | Train_2 -> R² = 0.9533, MSE = 3.9257e-03
# Y | Train_2 -> R² = 0.8141, MSE = 1.9851e-02
# X | Test_1 -> R² = 0.2362, MSE = 7.9249e-02
# Y | Test_1 -> R² = 0.6951, MSE = 2.4876e-02
# X | Test_2 -> R² = 0.7889, MSE = 1.7314e-02
# Y | Test_2 -> R² = -0.0859, MSE = 1.1431e-01
# X | Test_3 -> R² = 0.9109, MSE = 8.1402e-03
# Y | Test_3 -> R² = -1.0687, MSE = 1.5833e-01
# X | Val -> R² = 0.7389, MSE = 2.4763e-02
# Y | Val -> R² = 0.4374, MSE = 4.1772e-02
# X | LSG_1 -> R² = -0.5419, MSE = 1.5656e-01
# Y | LSG_1 -> R² = -2.3400, MSE = 1.0617e+00
# X | LSG_2 -> R² = -3.8176, MSE = 4.2423e-01
# Y | LSG_2 -> R² = -2.1301, MSE = 1.2115e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8478 salvo.
# Epoch 0 | Train Loss 1.014612 | Val Loss 0.683432
# Epoch 100 | Train Loss 0.529635 | Val Loss 0.519333
# Epoch 200 | Train Loss 0.520660 | Val Loss 0.518865
# Epoch 300 | Train Loss 0.514385 | Val Loss 0.517997
# Epoch 400 | Train Loss 0.508291 | Val Loss 0.518250
# Early stopping at epoch 420
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8857.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8857.weights.h5
# X | Train_1 -> R² = 0.9826, MSE = 1.8614e-03
# Y | Train_1 -> R² = 0.8811, MSE = 9.9275e-03
# X | Train_2 -> R² = 0.9354, MSE = 5.4275e-03
# Y | Train_2 -> R² = -1.7965, MSE = 2.9859e-01
# X | Test_1 -> R² = -0.4097, MSE = 1.4627e-01
# Y | Test_1 -> R² = -1.0636, MSE = 1.6839e-01
# X | Test_2 -> R² = 0.9788, MSE = 1.7414e-03
# Y | Test_2 -> R² = -7.1273, MSE = 8.5550e-01
# X | Test_3 -> R² = 0.2320, MSE = 7.0159e-02
# Y | Test_3 -> R² = -0.4808, MSE = 1.1333e-01
# X | Val -> R² = 0.5975, MSE = 3.8178e-02
# Y | Val -> R² = 0.4560, MSE = 4.0397e-02
# X | LSG_1 -> R² = -1.2671, MSE = 2.3020e-01
# Y | LSG_1 -> R² = -4.4602, MSE = 1.7356e+00
# X | LSG_2 -> R² = -2.4933, MSE = 3.0761e-01
# Y | LSG_2 -> R² = -5.9116, MSE = 2.6750e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8857 salvo.
# Epoch 0 | Train Loss 1.027591 | Val Loss 0.717766
# Epoch 100 | Train Loss 0.532114 | Val Loss 0.510001
# Epoch 200 | Train Loss 0.521597 | Val Loss 0.506383
# Epoch 300 | Train Loss 0.514491 | Val Loss 0.513924
# Epoch 400 | Train Loss 0.509188 | Val Loss 0.534568
# Early stopping at epoch 420
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1586.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1586.weights.h5
# X | Train_1 -> R² = 0.9862, MSE = 1.4713e-03
# Y | Train_1 -> R² = 0.8890, MSE = 9.2683e-03
# X | Train_2 -> R² = 0.8390, MSE = 1.3532e-02
# Y | Train_2 -> R² = -1.0158, MSE = 2.1523e-01
# X | Test_1 -> R² = -0.8164, MSE = 1.8846e-01
# Y | Test_1 -> R² = 0.1749, MSE = 6.7323e-02
# X | Test_2 -> R² = 0.9388, MSE = 5.0184e-03
# Y | Test_2 -> R² = -5.0122, MSE = 6.3285e-01
# X | Test_3 -> R² = -0.3260, MSE = 1.2114e-01
# Y | Test_3 -> R² = 0.2744, MSE = 5.5535e-02
# X | Val -> R² = 0.0788, MSE = 8.7369e-02
# Y | Val -> R² = 0.9389, MSE = 4.5353e-03
# X | LSG_1 -> R² = -0.0085, MSE = 1.0240e-01
# Y | LSG_1 -> R² = -3.4654, MSE = 1.4194e+00
# X | LSG_2 -> R² = -0.9592, MSE = 1.7252e-01
# Y | LSG_2 -> R² = -3.7274, MSE = 1.8297e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1586 salvo.
# Epoch 0 | Train Loss 1.022898 | Val Loss 0.673385
# Epoch 100 | Train Loss 0.530995 | Val Loss 0.516566
# Epoch 200 | Train Loss 0.521688 | Val Loss 0.529437
# Epoch 300 | Train Loss 0.530475 | Val Loss 0.532721
# Early stopping at epoch 324
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1658.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1658.weights.h5
# X | Train_1 -> R² = 0.9931, MSE = 7.3910e-04
# Y | Train_1 -> R² = 0.8809, MSE = 9.9390e-03
# X | Train_2 -> R² = 0.9752, MSE = 2.0835e-03
# Y | Train_2 -> R² = 0.6600, MSE = 3.6306e-02
# X | Test_1 -> R² = -1.0619, MSE = 2.1394e-01
# Y | Test_1 -> R² = 0.6538, MSE = 2.8249e-02
# X | Test_2 -> R² = 0.5816, MSE = 3.4319e-02
# Y | Test_2 -> R² = -1.3952, MSE = 2.5213e-01
# X | Test_3 -> R² = 0.9103, MSE = 8.1917e-03
# Y | Test_3 -> R² = -0.0211, MSE = 7.8151e-02
# X | Val -> R² = 0.7146, MSE = 2.7066e-02
# Y | Val -> R² = 0.9122, MSE = 6.5226e-03
# X | LSG_1 -> R² = -3.6482, MSE = 4.7198e-01
# Y | LSG_1 -> R² = -5.2314, MSE = 1.9807e+00
# X | LSG_2 -> R² = -6.6484, MSE = 6.7350e-01
# Y | LSG_2 -> R² = -5.0326, MSE = 2.3348e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1658 salvo.
# Epoch 0 | Train Loss 0.982678 | Val Loss 0.668133
# Epoch 100 | Train Loss 0.530718 | Val Loss 0.519380
# Epoch 200 | Train Loss 0.521555 | Val Loss 0.544778
# Early stopping at epoch 291
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed9028.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed9028.weights.h5
# X | Train_1 -> R² = 0.9924, MSE = 8.0700e-04
# Y | Train_1 -> R² = 0.8506, MSE = 1.2467e-02
# X | Train_2 -> R² = 0.9746, MSE = 2.1347e-03
# Y | Train_2 -> R² = 0.7660, MSE = 2.4985e-02
# X | Test_1 -> R² = -0.2904, MSE = 1.3389e-01
# Y | Test_1 -> R² = 0.8003, MSE = 1.6294e-02
# X | Test_2 -> R² = 0.6470, MSE = 2.8957e-02
# Y | Test_2 -> R² = -0.9433, MSE = 2.0455e-01
# X | Test_3 -> R² = 0.9513, MSE = 4.4510e-03
# Y | Test_3 -> R² = -1.0561, MSE = 1.5736e-01
# X | Val -> R² = 0.6920, MSE = 2.9213e-02
# Y | Val -> R² = 0.8636, MSE = 1.0129e-02
# X | LSG_1 -> R² = -2.3853, MSE = 3.4374e-01
# Y | LSG_1 -> R² = -3.3301, MSE = 1.3764e+00
# X | LSG_2 -> R² = -5.0266, MSE = 5.3069e-01
# Y | LSG_2 -> R² = -3.5108, MSE = 1.7458e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=9028 salvo.
# Epoch 0 | Train Loss 0.996747 | Val Loss 0.678430
# Epoch 100 | Train Loss 0.529514 | Val Loss 0.518133
# Epoch 200 | Train Loss 0.520873 | Val Loss 0.529339
# Early stopping at epoch 269
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8478.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8478.weights.h5
# X | Train_1 -> R² = 0.9910, MSE = 9.6536e-04
# Y | Train_1 -> R² = 0.8179, MSE = 1.5200e-02
# X | Train_2 -> R² = 0.7757, MSE = 1.8845e-02
# Y | Train_2 -> R² = 0.2123, MSE = 8.4109e-02
# X | Test_1 -> R² = 0.0891, MSE = 9.4509e-02
# Y | Test_1 -> R² = 0.9483, MSE = 4.2157e-03
# X | Test_2 -> R² = 0.9836, MSE = 1.3435e-03
# Y | Test_2 -> R² = -1.0881, MSE = 2.1979e-01
# X | Test_3 -> R² = -0.3109, MSE = 1.1976e-01
# Y | Test_3 -> R² = -0.3980, MSE = 1.0700e-01
# X | Val -> R² = 0.4158, MSE = 5.5408e-02
# Y | Val -> R² = 0.8680, MSE = 9.8044e-03
# X | LSG_1 -> R² = -0.6016, MSE = 1.6262e-01
# Y | LSG_1 -> R² = -2.4212, MSE = 1.0875e+00
# X | LSG_2 -> R² = -2.6652, MSE = 3.2275e-01
# Y | LSG_2 -> R² = -1.7270, MSE = 1.0555e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8478 salvo.
# Epoch 0 | Train Loss 0.929875 | Val Loss 0.609494
# Epoch 100 | Train Loss 0.527403 | Val Loss 0.505795
# Epoch 200 | Train Loss 0.519154 | Val Loss 0.508949
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8857.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8857.weights.h5
# X | Train_1 -> R² = 0.9937, MSE = 6.7224e-04
# Y | Train_1 -> R² = 0.8589, MSE = 1.1776e-02
# X | Train_2 -> R² = 0.9922, MSE = 6.5333e-04
# Y | Train_2 -> R² = 0.9442, MSE = 5.9549e-03
# X | Test_1 -> R² = -1.2762, MSE = 2.3618e-01
# Y | Test_1 -> R² = 0.9612, MSE = 3.1697e-03
# X | Test_2 -> R² = 0.5821, MSE = 3.4279e-02
# Y | Test_2 -> R² = 0.3307, MSE = 7.0446e-02
# X | Test_3 -> R² = 0.8982, MSE = 9.3028e-03
# Y | Test_3 -> R² = 0.7647, MSE = 1.8012e-02
# X | Val -> R² = 0.7181, MSE = 2.6740e-02
# Y | Val -> R² = 0.8657, MSE = 9.9699e-03
# X | LSG_1 -> R² = -2.8098, MSE = 3.8684e-01
# Y | LSG_1 -> R² = -4.3050, MSE = 1.6862e+00
# X | LSG_2 -> R² = -3.4667, MSE = 3.9333e-01
# Y | LSG_2 -> R² = -3.1465, MSE = 1.6048e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8857 salvo.
# Epoch 0 | Train Loss 1.004143 | Val Loss 0.627152
# Epoch 100 | Train Loss 0.530595 | Val Loss 0.518774
# Epoch 200 | Train Loss 0.520941 | Val Loss 0.517358
# Epoch 300 | Train Loss 0.512691 | Val Loss 0.514530
# Epoch 400 | Train Loss 0.506284 | Val Loss 0.515887
# Early stopping at epoch 457
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1586.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1586.weights.h5
# X | Train_1 -> R² = 0.9909, MSE = 9.7334e-04
# Y | Train_1 -> R² = 0.9002, MSE = 8.3346e-03
# X | Train_2 -> R² = 0.9643, MSE = 2.9985e-03
# Y | Train_2 -> R² = -0.6041, MSE = 1.7128e-01
# X | Test_1 -> R² = -0.1293, MSE = 1.1717e-01
# Y | Test_1 -> R² = -0.7875, MSE = 1.4586e-01
# X | Test_2 -> R² = 0.9625, MSE = 3.0777e-03
# Y | Test_2 -> R² = -3.9139, MSE = 5.1725e-01
# X | Test_3 -> R² = -0.0569, MSE = 9.6553e-02
# Y | Test_3 -> R² = -0.3818, MSE = 1.0576e-01
# X | Val -> R² = 0.4213, MSE = 5.4889e-02
# Y | Val -> R² = 0.0757, MSE = 6.8632e-02
# X | LSG_1 -> R² = -0.0540, MSE = 1.0703e-01
# Y | LSG_1 -> R² = -5.0926, MSE = 1.9366e+00
# X | LSG_2 -> R² = -0.6166, MSE = 1.4235e-01
# Y | LSG_2 -> R² = -5.3785, MSE = 2.4687e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1586 salvo.
# Epoch 0 | Train Loss 0.987469 | Val Loss 0.668138
# Epoch 100 | Train Loss 0.530929 | Val Loss 0.522645
# Epoch 200 | Train Loss 0.520004 | Val Loss 0.521190
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1658.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1658.weights.h5
# X | Train_1 -> R² = 0.9940, MSE = 6.3575e-04
# Y | Train_1 -> R² = 0.8128, MSE = 1.5622e-02
# X | Train_2 -> R² = 0.9584, MSE = 3.4964e-03
# Y | Train_2 -> R² = -0.1770, MSE = 1.2567e-01
# X | Test_1 -> R² = -0.7087, MSE = 1.7729e-01
# Y | Test_1 -> R² = 0.7141, MSE = 2.3332e-02
# X | Test_2 -> R² = 0.6657, MSE = 2.7421e-02
# Y | Test_2 -> R² = -2.3183, MSE = 3.4929e-01
# X | Test_3 -> R² = 0.9202, MSE = 7.2934e-03
# Y | Test_3 -> R² = -1.3854, MSE = 1.8257e-01
# X | Val -> R² = 0.8300, MSE = 1.6124e-02
# Y | Val -> R² = 0.5297, MSE = 3.4919e-02
# X | LSG_1 -> R² = -1.8418, MSE = 2.8856e-01
# Y | LSG_1 -> R² = -5.0914, MSE = 1.9362e+00
# X | LSG_2 -> R² = -5.3472, MSE = 5.5892e-01
# Y | LSG_2 -> R² = -4.0981, MSE = 1.9731e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1658 salvo.
# Epoch 0 | Train Loss 0.988633 | Val Loss 0.650252
# Epoch 100 | Train Loss 0.528571 | Val Loss 0.517786
# Epoch 200 | Train Loss 0.519820 | Val Loss 0.533622
# Early stopping at epoch 266
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed9028.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed9028.weights.h5
# X | Train_1 -> R² = 0.9935, MSE = 6.9177e-04
# Y | Train_1 -> R² = 0.8065, MSE = 1.6155e-02
# X | Train_2 -> R² = 0.9644, MSE = 2.9905e-03
# Y | Train_2 -> R² = 0.1448, MSE = 9.1315e-02
# X | Test_1 -> R² = 0.1362, MSE = 8.9624e-02
# Y | Test_1 -> R² = 0.9766, MSE = 1.9095e-03
# X | Test_2 -> R² = 0.3830, MSE = 5.0607e-02
# Y | Test_2 -> R² = -0.8475, MSE = 1.9447e-01
# X | Test_3 -> R² = 0.8714, MSE = 1.1748e-02
# Y | Test_3 -> R² = -0.0142, MSE = 7.7626e-02
# X | Val -> R² = 0.7852, MSE = 2.0374e-02
# Y | Val -> R² = 0.8573, MSE = 1.0600e-02
# X | LSG_1 -> R² = -4.6797, MSE = 5.7671e-01
# Y | LSG_1 -> R² = -2.8644, MSE = 1.2283e+00
# X | LSG_2 -> R² = -11.7292, MSE = 1.1209e+00
# Y | LSG_2 -> R² = -2.0018, MSE = 1.1618e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=9028 salvo.
# Epoch 0 | Train Loss 1.013851 | Val Loss 0.754073
# Epoch 100 | Train Loss 0.528939 | Val Loss 0.518845
# Epoch 200 | Train Loss 0.520658 | Val Loss 0.531467
# Epoch 300 | Train Loss 0.513700 | Val Loss 0.545174
# Early stopping at epoch 313
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8478.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8478.weights.h5
# X | Train_1 -> R² = 0.9917, MSE = 8.8740e-04
# Y | Train_1 -> R² = 0.8516, MSE = 1.2386e-02
# X | Train_2 -> R² = 0.3658, MSE = 5.3293e-02
# Y | Train_2 -> R² = -3.2988, MSE = 4.5899e-01
# X | Test_1 -> R² = -0.7570, MSE = 1.8230e-01
# Y | Test_1 -> R² = 0.7398, MSE = 2.1235e-02
# X | Test_2 -> R² = 0.9147, MSE = 6.9971e-03
# Y | Test_2 -> R² = -8.2710, MSE = 9.7589e-01
# X | Test_3 -> R² = 0.2353, MSE = 6.9855e-02
# Y | Test_3 -> R² = 0.2871, MSE = 5.4566e-02
# X | Val -> R² = 0.5700, MSE = 4.0781e-02
# Y | Val -> R² = 0.9181, MSE = 6.0810e-03
# X | LSG_1 -> R² = -2.0734, MSE = 3.1207e-01
# Y | LSG_1 -> R² = -3.2670, MSE = 1.3563e+00
# X | LSG_2 -> R² = -2.6232, MSE = 3.1905e-01
# Y | LSG_2 -> R² = -3.7753, MSE = 1.8482e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8478 salvo.
