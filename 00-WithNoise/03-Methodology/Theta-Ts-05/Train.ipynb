# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 5
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 1)
# Dimensão da entrada: (1266, 5, 4)
# Dimensão da saida: (1266, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 1)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.988194 | Val Loss 0.824236
# Epoch 100 | Train Loss 0.782197 | Val Loss 0.568970
# Epoch 200 | Train Loss 0.711335 | Val Loss 0.598382
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.6896, MSE = 7.0787e-02
# Theta | Train_2 -> R² = 0.3437, MSE = 1.4931e-01
# Theta | Test_1 -> R² = 0.3055, MSE = 1.5941e-01
# Theta | Test_2 -> R² = 0.8523, MSE = 3.4904e-02
# Theta | Test_3 -> R² = 0.5553, MSE = 1.4604e-01
# Theta | Val -> R² = -2.1801, MSE = 1.0394e+00
# Theta | LSG_1 -> R² = 0.7560, MSE = 1.0104e-01
# Theta | LSG_2 -> R² = -0.6949, MSE = 5.8708e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 1.011147 | Val Loss 0.881435
# Epoch 100 | Train Loss 0.799796 | Val Loss 0.567367
# Epoch 200 | Train Loss 0.716742 | Val Loss 0.551024
# Epoch 300 | Train Loss 0.682170 | Val Loss 0.577898
# Epoch 400 | Train Loss 0.648483 | Val Loss 0.617131
# Early stopping at epoch 403
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.8157, MSE = 4.2020e-02
# Theta | Train_2 -> R² = 0.7856, MSE = 4.8767e-02
# Theta | Test_1 -> R² = 0.7831, MSE = 4.9788e-02
# Theta | Test_2 -> R² = 0.8635, MSE = 3.2268e-02
# Theta | Test_3 -> R² = 0.1759, MSE = 2.7066e-01
# Theta | Val -> R² = -0.8979, MSE = 6.2033e-01
# Theta | LSG_1 -> R² = 0.5393, MSE = 1.9080e-01
# Theta | LSG_2 -> R² = -0.4612, MSE = 5.0615e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 0.980432 | Val Loss 0.826300
# Epoch 100 | Train Loss 0.773048 | Val Loss 0.556857
# Epoch 200 | Train Loss 0.712177 | Val Loss 0.581416
# Early stopping at epoch 287
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7826, MSE = 4.9570e-02
# Theta | Train_2 -> R² = 0.4871, MSE = 1.1670e-01
# Theta | Test_1 -> R² = 0.4953, MSE = 1.1586e-01
# Theta | Test_2 -> R² = 0.8637, MSE = 3.2208e-02
# Theta | Test_3 -> R² = 0.6062, MSE = 1.2935e-01
# Theta | Val -> R² = -3.6735, MSE = 1.5275e+00
# Theta | LSG_1 -> R² = 0.6890, MSE = 1.2881e-01
# Theta | LSG_2 -> R² = -1.3138, MSE = 8.0146e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 0.975839 | Val Loss 0.822820
# Epoch 100 | Train Loss 0.773835 | Val Loss 0.571077
# Epoch 200 | Train Loss 0.711755 | Val Loss 0.583706
# Early stopping at epoch 269
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7292, MSE = 6.1752e-02
# Theta | Train_2 -> R² = 0.3788, MSE = 1.4133e-01
# Theta | Test_1 -> R² = 0.4443, MSE = 1.2756e-01
# Theta | Test_2 -> R² = 0.8493, MSE = 3.5623e-02
# Theta | Test_3 -> R² = 0.6143, MSE = 1.2666e-01
# Theta | Val -> R² = -1.9062, MSE = 9.4990e-01
# Theta | LSG_1 -> R² = 0.7702, MSE = 9.5165e-02
# Theta | LSG_2 -> R² = -0.2604, MSE = 4.3657e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 0.976006 | Val Loss 0.804533
# Epoch 100 | Train Loss 0.792247 | Val Loss 0.555960
# Epoch 200 | Train Loss 0.740320 | Val Loss 0.558676
# Early stopping at epoch 274
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7229, MSE = 6.3182e-02
# Theta | Train_2 -> R² = 0.5380, MSE = 1.0512e-01
# Theta | Test_1 -> R² = 0.3424, MSE = 1.5096e-01
# Theta | Test_2 -> R² = 0.8846, MSE = 2.7280e-02
# Theta | Test_3 -> R² = 0.6509, MSE = 1.1465e-01
# Theta | Val -> R² = -4.0061, MSE = 1.6362e+00
# Theta | LSG_1 -> R² = 0.5503, MSE = 1.8625e-01
# Theta | LSG_2 -> R² = -1.8915, MSE = 1.0016e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 0.981354 | Val Loss 0.811555
# Epoch 100 | Train Loss 0.786354 | Val Loss 0.559440
# Epoch 200 | Train Loss 0.714920 | Val Loss 0.567188
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7992, MSE = 4.5790e-02
# Theta | Train_2 -> R² = 0.4895, MSE = 1.1614e-01
# Theta | Test_1 -> R² = 0.6223, MSE = 8.6695e-02
# Theta | Test_2 -> R² = 0.8543, MSE = 3.4443e-02
# Theta | Test_3 -> R² = 0.6651, MSE = 1.0998e-01
# Theta | Val -> R² = -2.3767, MSE = 1.1037e+00
# Theta | LSG_1 -> R² = 0.7570, MSE = 1.0062e-01
# Theta | LSG_2 -> R² = -0.5070, MSE = 5.2199e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 1.022408 | Val Loss 0.894234
# Epoch 100 | Train Loss 0.825777 | Val Loss 0.558205
# Epoch 200 | Train Loss 0.736916 | Val Loss 0.575933
# Epoch 300 | Train Loss 0.697587 | Val Loss 0.581085
# Early stopping at epoch 308
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.7797, MSE = 5.0237e-02
# Theta | Train_2 -> R² = 0.4789, MSE = 1.1854e-01
# Theta | Test_1 -> R² = 0.7213, MSE = 6.3985e-02
# Theta | Test_2 -> R² = 0.8429, MSE = 3.7125e-02
# Theta | Test_3 -> R² = 0.5557, MSE = 1.4592e-01
# Theta | Val -> R² = -0.0254, MSE = 3.3514e-01
# Theta | LSG_1 -> R² = 0.7568, MSE = 1.0072e-01
# Theta | LSG_2 -> R² = -0.0431, MSE = 3.6132e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 0.968257 | Val Loss 0.775932
# Epoch 100 | Train Loss 0.829976 | Val Loss 0.555517
# Epoch 200 | Train Loss 0.729734 | Val Loss 0.573358
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7313, MSE = 6.1287e-02
# Theta | Train_2 -> R² = 0.4399, MSE = 1.2743e-01
# Theta | Test_1 -> R² = 0.5610, MSE = 1.0077e-01
# Theta | Test_2 -> R² = 0.8419, MSE = 3.7361e-02
# Theta | Test_3 -> R² = 0.6501, MSE = 1.1493e-01
# Theta | Val -> R² = -2.8722, MSE = 1.2656e+00
# Theta | LSG_1 -> R² = 0.6877, MSE = 1.2934e-01
# Theta | LSG_2 -> R² = -0.9957, MSE = 6.9128e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 0.979763 | Val Loss 0.823613
# Epoch 100 | Train Loss 0.786292 | Val Loss 0.555060
# Epoch 200 | Train Loss 0.712961 | Val Loss 0.587906
# Early stopping at epoch 290
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7435, MSE = 5.8492e-02
# Theta | Train_2 -> R² = 0.4485, MSE = 1.2548e-01
# Theta | Test_1 -> R² = 0.6059, MSE = 9.0463e-02
# Theta | Test_2 -> R² = 0.8483, MSE = 3.5856e-02
# Theta | Test_3 -> R² = 0.6884, MSE = 1.0235e-01
# Theta | Val -> R² = -0.9481, MSE = 6.3673e-01
# Theta | LSG_1 -> R² = 0.7520, MSE = 1.0270e-01
# Theta | LSG_2 -> R² = -0.0105, MSE = 3.5001e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 0.978217 | Val Loss 0.807857
# Epoch 100 | Train Loss 0.838580 | Val Loss 0.557625
# Epoch 200 | Train Loss 0.733829 | Val Loss 0.564988
# Epoch 300 | Train Loss 0.703691 | Val Loss 0.586341
# Early stopping at epoch 315
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8054, MSE = 4.4386e-02
# Theta | Train_2 -> R² = 0.5177, MSE = 1.0972e-01
# Theta | Test_1 -> R² = 0.6065, MSE = 9.0316e-02
# Theta | Test_2 -> R² = 0.8560, MSE = 3.4026e-02
# Theta | Test_3 -> R² = 0.7156, MSE = 9.3404e-02
# Theta | Val -> R² = -1.6346, MSE = 8.6111e-01
# Theta | LSG_1 -> R² = 0.7448, MSE = 1.0570e-01
# Theta | LSG_2 -> R² = -0.9321, MSE = 6.6925e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 1.003494 | Val Loss 0.865419
# Epoch 100 | Train Loss 0.753375 | Val Loss 0.564430
# Epoch 200 | Train Loss 0.720549 | Val Loss 0.603304
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.6930, MSE = 7.0011e-02
# Theta | Train_2 -> R² = 0.4929, MSE = 1.1538e-01
# Theta | Test_1 -> R² = 0.1368, MSE = 1.9814e-01
# Theta | Test_2 -> R² = 0.8669, MSE = 3.1469e-02
# Theta | Test_3 -> R² = 0.4963, MSE = 1.6542e-01
# Theta | Val -> R² = -6.1015, MSE = 2.3211e+00
# Theta | LSG_1 -> R² = 0.4372, MSE = 2.3306e-01
# Theta | LSG_2 -> R² = -2.6633, MSE = 1.2689e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 1.012785 | Val Loss 0.853743
# Epoch 100 | Train Loss 0.748840 | Val Loss 0.564318
# Epoch 200 | Train Loss 0.730764 | Val Loss 0.596830
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.6217, MSE = 8.6270e-02
# Theta | Train_2 -> R² = 0.3164, MSE = 1.5554e-01
# Theta | Test_1 -> R² = 0.0376, MSE = 2.2091e-01
# Theta | Test_2 -> R² = 0.8252, MSE = 4.1308e-02
# Theta | Test_3 -> R² = 0.5306, MSE = 1.5416e-01
# Theta | Val -> R² = -6.4634, MSE = 2.4394e+00
# Theta | LSG_1 -> R² = 0.3309, MSE = 2.7710e-01
# Theta | LSG_2 -> R² = -2.6712, MSE = 1.2716e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 0.972324 | Val Loss 0.799956
# Epoch 100 | Train Loss 0.754698 | Val Loss 0.562834
# Epoch 200 | Train Loss 0.738884 | Val Loss 0.586058
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7370, MSE = 5.9987e-02
# Theta | Train_2 -> R² = 0.6418, MSE = 8.1494e-02
# Theta | Test_1 -> R² = 0.1004, MSE = 2.0650e-01
# Theta | Test_2 -> R² = 0.8031, MSE = 4.6533e-02
# Theta | Test_3 -> R² = 0.5372, MSE = 1.5199e-01
# Theta | Val -> R² = -7.4301, MSE = 2.7554e+00
# Theta | LSG_1 -> R² = -0.2836, MSE = 5.3159e-01
# Theta | LSG_2 -> R² = -5.0301, MSE = 2.0887e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 0.981408 | Val Loss 0.845491
# Epoch 100 | Train Loss 0.748780 | Val Loss 0.569126
# Epoch 200 | Train Loss 0.722501 | Val Loss 0.606142
# Early stopping at epoch 283
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7736, MSE = 5.1622e-02
# Theta | Train_2 -> R² = 0.6541, MSE = 7.8703e-02
# Theta | Test_1 -> R² = 0.3029, MSE = 1.6002e-01
# Theta | Test_2 -> R² = 0.8372, MSE = 3.8470e-02
# Theta | Test_3 -> R² = 0.4295, MSE = 1.8737e-01
# Theta | Val -> R² = -7.0356, MSE = 2.6264e+00
# Theta | LSG_1 -> R² = 0.1821, MSE = 3.3872e-01
# Theta | LSG_2 -> R² = -3.6176, MSE = 1.5994e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 0.960107 | Val Loss 0.785457
# Epoch 100 | Train Loss 0.751066 | Val Loss 0.561536
# Epoch 200 | Train Loss 0.738552 | Val Loss 0.591428
# Early stopping at epoch 288
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7839, MSE = 4.9283e-02
# Theta | Train_2 -> R² = 0.6256, MSE = 8.5178e-02
# Theta | Test_1 -> R² = 0.3717, MSE = 1.4422e-01
# Theta | Test_2 -> R² = 0.8446, MSE = 3.6717e-02
# Theta | Test_3 -> R² = 0.5421, MSE = 1.5039e-01
# Theta | Val -> R² = -6.0330, MSE = 2.2987e+00
# Theta | LSG_1 -> R² = 0.3110, MSE = 2.8535e-01
# Theta | LSG_2 -> R² = -2.9917, MSE = 1.3827e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 0.960839 | Val Loss 0.794135
# Epoch 100 | Train Loss 0.750672 | Val Loss 0.567154
# Epoch 200 | Train Loss 0.736323 | Val Loss 0.589900
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7531, MSE = 5.6315e-02
# Theta | Train_2 -> R² = 0.6786, MSE = 7.3133e-02
# Theta | Test_1 -> R² = 0.2768, MSE = 1.6602e-01
# Theta | Test_2 -> R² = 0.8367, MSE = 3.8591e-02
# Theta | Test_3 -> R² = 0.4193, MSE = 1.9071e-01
# Theta | Val -> R² = -7.0498, MSE = 2.6311e+00
# Theta | LSG_1 -> R² = 0.0073, MSE = 4.1113e-01
# Theta | LSG_2 -> R² = -4.1942, MSE = 1.7992e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 0.991298 | Val Loss 0.840862
# Epoch 100 | Train Loss 0.753117 | Val Loss 0.564605
# Epoch 200 | Train Loss 0.737531 | Val Loss 0.606452
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.6592, MSE = 7.7728e-02
# Theta | Train_2 -> R² = 0.3076, MSE = 1.5753e-01
# Theta | Test_1 -> R² = 0.0409, MSE = 2.2017e-01
# Theta | Test_2 -> R² = 0.8431, MSE = 3.7079e-02
# Theta | Test_3 -> R² = 0.5889, MSE = 1.3501e-01
# Theta | Val -> R² = -6.1662, MSE = 2.3423e+00
# Theta | LSG_1 -> R² = 0.4122, MSE = 2.4341e-01
# Theta | LSG_2 -> R² = -2.5623, MSE = 1.2339e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 1.002265 | Val Loss 0.865128
# Epoch 100 | Train Loss 0.755958 | Val Loss 0.551461
# Epoch 200 | Train Loss 0.732548 | Val Loss 0.583472
# Early stopping at epoch 294
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8092, MSE = 4.3520e-02
# Theta | Train_2 -> R² = 0.6711, MSE = 7.4820e-02
# Theta | Test_1 -> R² = 0.4772, MSE = 1.2000e-01
# Theta | Test_2 -> R² = 0.8363, MSE = 3.8688e-02
# Theta | Test_3 -> R² = 0.5857, MSE = 1.3607e-01
# Theta | Val -> R² = -4.6310, MSE = 1.8405e+00
# Theta | LSG_1 -> R² = 0.4217, MSE = 2.3948e-01
# Theta | LSG_2 -> R² = -2.7073, MSE = 1.2842e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 0.964916 | Val Loss 0.812698
# Epoch 100 | Train Loss 0.748511 | Val Loss 0.568574
# Epoch 200 | Train Loss 0.721395 | Val Loss 0.600422
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7291, MSE = 6.1789e-02
# Theta | Train_2 -> R² = 0.6593, MSE = 7.7521e-02
# Theta | Test_1 -> R² = 0.1630, MSE = 1.9213e-01
# Theta | Test_2 -> R² = 0.8333, MSE = 3.9391e-02
# Theta | Test_3 -> R² = 0.3922, MSE = 1.9963e-01
# Theta | Val -> R² = -7.4586, MSE = 2.7647e+00
# Theta | LSG_1 -> R² = 0.0944, MSE = 3.7504e-01
# Theta | LSG_2 -> R² = -4.0132, MSE = 1.7365e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 0.963166 | Val Loss 0.814494
# Epoch 100 | Train Loss 0.747860 | Val Loss 0.570423
# Epoch 200 | Train Loss 0.733345 | Val Loss 0.596958
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7994, MSE = 4.5743e-02
# Theta | Train_2 -> R² = 0.6799, MSE = 7.2818e-02
# Theta | Test_1 -> R² = 0.3510, MSE = 1.4897e-01
# Theta | Test_2 -> R² = 0.8237, MSE = 4.1678e-02
# Theta | Test_3 -> R² = 0.5103, MSE = 1.6083e-01
# Theta | Val -> R² = -6.5140, MSE = 2.4560e+00
# Theta | LSG_1 -> R² = 0.1474, MSE = 3.5308e-01
# Theta | LSG_2 -> R² = -3.9251, MSE = 1.7060e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 0.993940 | Val Loss 0.819194
# Epoch 100 | Train Loss 0.720318 | Val Loss 0.570862
# Epoch 200 | Train Loss 0.691660 | Val Loss 0.553664
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7040, MSE = 6.7511e-02
# Theta | Train_2 -> R² = 0.5511, MSE = 1.0213e-01
# Theta | Test_1 -> R² = 0.1619, MSE = 1.9239e-01
# Theta | Test_2 -> R² = 0.8476, MSE = 3.6013e-02
# Theta | Test_3 -> R² = 0.5464, MSE = 1.4899e-01
# Theta | Val -> R² = -5.8277, MSE = 2.2316e+00
# Theta | LSG_1 -> R² = 0.1977, MSE = 3.3227e-01
# Theta | LSG_2 -> R² = -3.7147, MSE = 1.6331e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 0.972657 | Val Loss 0.808811
# Epoch 100 | Train Loss 0.722186 | Val Loss 0.573723
# Epoch 200 | Train Loss 0.673372 | Val Loss 0.622970
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.7420, MSE = 5.8840e-02
# Theta | Train_2 -> R² = 0.5958, MSE = 9.1953e-02
# Theta | Test_1 -> R² = 0.2545, MSE = 1.7112e-01
# Theta | Test_2 -> R² = 0.8695, MSE = 3.0845e-02
# Theta | Test_3 -> R² = 0.6651, MSE = 1.0998e-01
# Theta | Val -> R² = -4.2062, MSE = 1.7017e+00
# Theta | LSG_1 -> R² = 0.3681, MSE = 2.6169e-01
# Theta | LSG_2 -> R² = -3.0480, MSE = 1.4022e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 0.990673 | Val Loss 0.797129
# Epoch 100 | Train Loss 0.735278 | Val Loss 0.569387
# Epoch 200 | Train Loss 0.698789 | Val Loss 0.583584
# Early stopping at epoch 240
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7411, MSE = 5.9054e-02
# Theta | Train_2 -> R² = 0.6326, MSE = 8.3593e-02
# Theta | Test_1 -> R² = 0.3072, MSE = 1.5904e-01
# Theta | Test_2 -> R² = 0.8799, MSE = 2.8385e-02
# Theta | Test_3 -> R² = 0.3769, MSE = 2.0465e-01
# Theta | Val -> R² = -7.3459, MSE = 2.7279e+00
# Theta | LSG_1 -> R² = -0.0938, MSE = 4.5297e-01
# Theta | LSG_2 -> R² = -4.4238, MSE = 1.8787e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 0.984669 | Val Loss 0.826735
# Epoch 100 | Train Loss 0.731495 | Val Loss 0.565361
# Epoch 200 | Train Loss 0.690088 | Val Loss 0.610894
# Early stopping at epoch 243
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7177, MSE = 6.4381e-02
# Theta | Train_2 -> R² = 0.4499, MSE = 1.2515e-01
# Theta | Test_1 -> R² = 0.3575, MSE = 1.4748e-01
# Theta | Test_2 -> R² = 0.8781, MSE = 2.8802e-02
# Theta | Test_3 -> R² = 0.6082, MSE = 1.2866e-01
# Theta | Val -> R² = -2.3909, MSE = 1.1083e+00
# Theta | LSG_1 -> R² = 0.7301, MSE = 1.1177e-01
# Theta | LSG_2 -> R² = -0.9735, MSE = 6.8358e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 1.013060 | Val Loss 0.853765
# Epoch 100 | Train Loss 0.736848 | Val Loss 0.569974
# Epoch 200 | Train Loss 0.682493 | Val Loss 0.590141
# Early stopping at epoch 253
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7431, MSE = 5.8591e-02
# Theta | Train_2 -> R² = 0.6160, MSE = 8.7374e-02
# Theta | Test_1 -> R² = 0.3491, MSE = 1.4941e-01
# Theta | Test_2 -> R² = 0.8787, MSE = 2.8666e-02
# Theta | Test_3 -> R² = 0.5093, MSE = 1.6115e-01
# Theta | Val -> R² = -5.8599, MSE = 2.2422e+00
# Theta | LSG_1 -> R² = 0.2956, MSE = 2.9170e-01
# Theta | LSG_2 -> R² = -3.1959, MSE = 1.4534e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 1.001635 | Val Loss 0.851742
# Epoch 100 | Train Loss 0.731237 | Val Loss 0.576103
# Epoch 200 | Train Loss 0.690933 | Val Loss 0.614028
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.8096, MSE = 4.3432e-02
# Theta | Train_2 -> R² = 0.5976, MSE = 9.1552e-02
# Theta | Test_1 -> R² = 0.6182, MSE = 8.7644e-02
# Theta | Test_2 -> R² = 0.8760, MSE = 2.9305e-02
# Theta | Test_3 -> R² = 0.4363, MSE = 1.8512e-01
# Theta | Val -> R² = -5.0267, MSE = 1.9698e+00
# Theta | LSG_1 -> R² = 0.4996, MSE = 2.0721e-01
# Theta | LSG_2 -> R² = -2.3150, MSE = 1.1482e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 0.990015 | Val Loss 0.813262
# Epoch 100 | Train Loss 0.727932 | Val Loss 0.568175
# Epoch 200 | Train Loss 0.678442 | Val Loss 0.572514
# Early stopping at epoch 240
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.6974, MSE = 6.9000e-02
# Theta | Train_2 -> R² = 0.5047, MSE = 1.1268e-01
# Theta | Test_1 -> R² = 0.2237, MSE = 1.7820e-01
# Theta | Test_2 -> R² = 0.8555, MSE = 3.4149e-02
# Theta | Test_3 -> R² = 0.4864, MSE = 1.6867e-01
# Theta | Val -> R² = -5.0575, MSE = 1.9799e+00
# Theta | LSG_1 -> R² = 0.5345, MSE = 1.9278e-01
# Theta | LSG_2 -> R² = -2.3046, MSE = 1.1447e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 0.977860 | Val Loss 0.788330
# Epoch 100 | Train Loss 0.726857 | Val Loss 0.571991
# Epoch 200 | Train Loss 0.689391 | Val Loss 0.574228
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7481, MSE = 5.7457e-02
# Theta | Train_2 -> R² = 0.5523, MSE = 1.0186e-01
# Theta | Test_1 -> R² = 0.3609, MSE = 1.4670e-01
# Theta | Test_2 -> R² = 0.8722, MSE = 3.0200e-02
# Theta | Test_3 -> R² = 0.5922, MSE = 1.3393e-01
# Theta | Val -> R² = -4.4211, MSE = 1.7719e+00
# Theta | LSG_1 -> R² = 0.5074, MSE = 2.0399e-01
# Theta | LSG_2 -> R² = -2.3776, MSE = 1.1699e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 1.013973 | Val Loss 0.847581
# Epoch 100 | Train Loss 0.747304 | Val Loss 0.566604
# Epoch 200 | Train Loss 0.696956 | Val Loss 0.595920
# Early stopping at epoch 274
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7497, MSE = 5.7076e-02
# Theta | Train_2 -> R² = 0.5070, MSE = 1.1215e-01
# Theta | Test_1 -> R² = 0.4227, MSE = 1.3253e-01
# Theta | Test_2 -> R² = 0.8715, MSE = 3.0378e-02
# Theta | Test_3 -> R² = 0.6695, MSE = 1.0856e-01
# Theta | Val -> R² = -2.6675, MSE = 1.1987e+00
# Theta | LSG_1 -> R² = 0.7124, MSE = 1.1909e-01
# Theta | LSG_2 -> R² = -1.2683, MSE = 7.8570e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 0.983243 | Val Loss 0.819587
# Epoch 100 | Train Loss 0.722527 | Val Loss 0.570541
# Epoch 200 | Train Loss 0.697121 | Val Loss 0.556188
# Epoch 300 | Train Loss 0.671428 | Val Loss 0.611861
# Epoch 400 | Train Loss 0.607951 | Val Loss 0.802838
# Early stopping at epoch 427
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8728, MSE = 2.9019e-02
# Theta | Train_2 -> R² = 0.7074, MSE = 6.6564e-02
# Theta | Test_1 -> R² = 0.7909, MSE = 4.8009e-02
# Theta | Test_2 -> R² = 0.8006, MSE = 4.7133e-02
# Theta | Test_3 -> R² = 0.1353, MSE = 2.8398e-01
# Theta | Val -> R² = -1.7776, MSE = 9.0786e-01
# Theta | LSG_1 -> R² = 0.5773, MSE = 1.7505e-01
# Theta | LSG_2 -> R² = -2.4276, MSE = 1.1873e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 0.980232 | Val Loss 0.815667
# Epoch 100 | Train Loss 0.742379 | Val Loss 0.592052
# Epoch 200 | Train Loss 0.717022 | Val Loss 0.617901
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.6590, MSE = 7.7768e-02
# Theta | Train_2 -> R² = 0.5149, MSE = 1.1036e-01
# Theta | Test_1 -> R² = 0.1147, MSE = 2.0321e-01
# Theta | Test_2 -> R² = 0.8540, MSE = 3.4514e-02
# Theta | Test_3 -> R² = 0.2626, MSE = 2.4217e-01
# Theta | Val -> R² = -8.0149, MSE = 2.9465e+00
# Theta | LSG_1 -> R² = -0.0347, MSE = 4.2851e-01
# Theta | LSG_2 -> R² = -4.1564, MSE = 1.7861e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 0.999480 | Val Loss 0.799417
# Epoch 100 | Train Loss 0.743234 | Val Loss 0.588282
# Epoch 200 | Train Loss 0.717906 | Val Loss 0.620089
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.4093, MSE = 1.3471e-01
# Theta | Train_2 -> R² = 0.2729, MSE = 1.6543e-01
# Theta | Test_1 -> R² = -0.1385, MSE = 2.6133e-01
# Theta | Test_2 -> R² = 0.6650, MSE = 7.9178e-02
# Theta | Test_3 -> R² = -0.1306, MSE = 3.7133e-01
# Theta | Val -> R² = -8.6129, MSE = 3.1420e+00
# Theta | LSG_1 -> R² = -0.1073, MSE = 4.5858e-01
# Theta | LSG_2 -> R² = -4.3537, MSE = 1.8544e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 0.929949 | Val Loss 0.702604
# Epoch 100 | Train Loss 0.746438 | Val Loss 0.593412
# Epoch 200 | Train Loss 0.683393 | Val Loss 0.699656
# Early stopping at epoch 219
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8561, MSE = 3.2811e-02
# Theta | Train_2 -> R² = 0.5741, MSE = 9.6904e-02
# Theta | Test_1 -> R² = 0.6092, MSE = 8.9702e-02
# Theta | Test_2 -> R² = 0.8556, MSE = 3.4138e-02
# Theta | Test_3 -> R² = 0.4079, MSE = 1.9445e-01
# Theta | Val -> R² = -6.9734, MSE = 2.6061e+00
# Theta | LSG_1 -> R² = 0.2896, MSE = 2.9418e-01
# Theta | LSG_2 -> R² = -3.1678, MSE = 1.4436e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 1.029602 | Val Loss 0.890122
# Epoch 100 | Train Loss 0.742279 | Val Loss 0.577323
# Epoch 200 | Train Loss 0.708171 | Val Loss 0.614536
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7385, MSE = 5.9640e-02
# Theta | Train_2 -> R² = 0.4336, MSE = 1.2886e-01
# Theta | Test_1 -> R² = 0.2945, MSE = 1.6196e-01
# Theta | Test_2 -> R² = 0.8743, MSE = 2.9704e-02
# Theta | Test_3 -> R² = 0.5339, MSE = 1.5308e-01
# Theta | Val -> R² = -5.5015, MSE = 2.1250e+00
# Theta | LSG_1 -> R² = 0.5507, MSE = 1.8607e-01
# Theta | LSG_2 -> R² = -2.1058, MSE = 1.0758e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 0.930488 | Val Loss 0.742556
# Epoch 100 | Train Loss 0.743324 | Val Loss 0.594468
# Epoch 200 | Train Loss 0.707448 | Val Loss 0.649504
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7597, MSE = 5.4802e-02
# Theta | Train_2 -> R² = 0.3562, MSE = 1.4647e-01
# Theta | Test_1 -> R² = 0.4098, MSE = 1.3548e-01
# Theta | Test_2 -> R² = 0.7742, MSE = 5.3361e-02
# Theta | Test_3 -> R² = 0.4574, MSE = 1.7820e-01
# Theta | Val -> R² = -6.4987, MSE = 2.4509e+00
# Theta | LSG_1 -> R² = 0.3940, MSE = 2.5095e-01
# Theta | LSG_2 -> R² = -2.4282, MSE = 1.1874e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 0.970124 | Val Loss 0.816066
# Epoch 100 | Train Loss 0.742929 | Val Loss 0.587368
# Epoch 200 | Train Loss 0.704509 | Val Loss 0.616881
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.5818, MSE = 9.5380e-02
# Theta | Train_2 -> R² = 0.4794, MSE = 1.1844e-01
# Theta | Test_1 -> R² = 0.1239, MSE = 2.0110e-01
# Theta | Test_2 -> R² = 0.8178, MSE = 4.3065e-02
# Theta | Test_3 -> R² = -0.3536, MSE = 4.4456e-01
# Theta | Val -> R² = -9.3415, MSE = 3.3801e+00
# Theta | LSG_1 -> R² = -0.0096, MSE = 4.1809e-01
# Theta | LSG_2 -> R² = -4.0947, MSE = 1.7647e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 1.006105 | Val Loss 0.820868
# Epoch 100 | Train Loss 0.743517 | Val Loss 0.583873
# Epoch 200 | Train Loss 0.705291 | Val Loss 0.600974
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.7887, MSE = 4.8181e-02
# Theta | Train_2 -> R² = 0.5993, MSE = 9.1163e-02
# Theta | Test_1 -> R² = 0.4152, MSE = 1.3424e-01
# Theta | Test_2 -> R² = 0.8762, MSE = 2.9266e-02
# Theta | Test_3 -> R² = 0.2764, MSE = 2.3766e-01
# Theta | Val -> R² = -7.1654, MSE = 2.6689e+00
# Theta | LSG_1 -> R² = 0.2465, MSE = 3.1205e-01
# Theta | LSG_2 -> R² = -3.5108, MSE = 1.5625e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 1.001293 | Val Loss 0.820498
# Epoch 100 | Train Loss 0.743926 | Val Loss 0.599680
# Epoch 200 | Train Loss 0.720938 | Val Loss 0.636138
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.6211, MSE = 8.6420e-02
# Theta | Train_2 -> R² = 0.4350, MSE = 1.2855e-01
# Theta | Test_1 -> R² = -0.0013, MSE = 2.2985e-01
# Theta | Test_2 -> R² = 0.8183, MSE = 4.2951e-02
# Theta | Test_3 -> R² = 0.3854, MSE = 2.0185e-01
# Theta | Val -> R² = -8.0940, MSE = 2.9724e+00
# Theta | LSG_1 -> R² = -0.1474, MSE = 4.7518e-01
# Theta | LSG_2 -> R² = -4.3631, MSE = 1.8577e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 0.994719 | Val Loss 0.843786
# Epoch 100 | Train Loss 0.738374 | Val Loss 0.586047
# Epoch 200 | Train Loss 0.693414 | Val Loss 0.626690
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7204, MSE = 6.3761e-02
# Theta | Train_2 -> R² = 0.5429, MSE = 1.0400e-01
# Theta | Test_1 -> R² = 0.2742, MSE = 1.6660e-01
# Theta | Test_2 -> R² = 0.8712, MSE = 3.0429e-02
# Theta | Test_3 -> R² = 0.2276, MSE = 2.5368e-01
# Theta | Val -> R² = -7.8776, MSE = 2.9016e+00
# Theta | LSG_1 -> R² = 0.1314, MSE = 3.5973e-01
# Theta | LSG_2 -> R² = -3.7315, MSE = 1.6389e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 0.951840 | Val Loss 0.774838
# Epoch 100 | Train Loss 0.741455 | Val Loss 0.590313
# Epoch 200 | Train Loss 0.684986 | Val Loss 0.660015
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7487, MSE = 5.7304e-02
# Theta | Train_2 -> R² = 0.4141, MSE = 1.3330e-01
# Theta | Test_1 -> R² = 0.4304, MSE = 1.3074e-01
# Theta | Test_2 -> R² = 0.8087, MSE = 4.5222e-02
# Theta | Test_3 -> R² = 0.2851, MSE = 2.3479e-01
# Theta | Val -> R² = -6.6178, MSE = 2.4899e+00
# Theta | LSG_1 -> R² = 0.4594, MSE = 2.2389e-01
# Theta | LSG_2 -> R² = -2.2360, MSE = 1.1209e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 0.990356 | Val Loss 0.758556
# Epoch 100 | Train Loss 0.708353 | Val Loss 0.571124
# Epoch 200 | Train Loss 0.669380 | Val Loss 0.628382
# Early stopping at epoch 239
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7507, MSE = 5.6860e-02
# Theta | Train_2 -> R² = 0.6531, MSE = 7.8927e-02
# Theta | Test_1 -> R² = 0.4040, MSE = 1.3682e-01
# Theta | Test_2 -> R² = 0.8814, MSE = 2.8022e-02
# Theta | Test_3 -> R² = 0.4652, MSE = 1.7565e-01
# Theta | Val -> R² = -5.8658, MSE = 2.2441e+00
# Theta | LSG_1 -> R² = 0.0566, MSE = 3.9068e-01
# Theta | LSG_2 -> R² = -4.2570, MSE = 1.8209e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 0.993490 | Val Loss 0.753245
# Epoch 100 | Train Loss 0.706950 | Val Loss 0.571466
# Epoch 200 | Train Loss 0.681579 | Val Loss 0.592241
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.7998, MSE = 4.5662e-02
# Theta | Train_2 -> R² = 0.6711, MSE = 7.4824e-02
# Theta | Test_1 -> R² = 0.5752, MSE = 9.7508e-02
# Theta | Test_2 -> R² = 0.8875, MSE = 2.6598e-02
# Theta | Test_3 -> R² = 0.2815, MSE = 2.3597e-01
# Theta | Val -> R² = -7.1258, MSE = 2.6559e+00
# Theta | LSG_1 -> R² = 0.0295, MSE = 4.0192e-01
# Theta | LSG_2 -> R² = -4.3476, MSE = 1.8523e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 1.020343 | Val Loss 0.801136
# Epoch 100 | Train Loss 0.708409 | Val Loss 0.567169
# Epoch 200 | Train Loss 0.660260 | Val Loss 0.657242
# Early stopping at epoch 235
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8164, MSE = 4.1873e-02
# Theta | Train_2 -> R² = 0.6851, MSE = 7.1634e-02
# Theta | Test_1 -> R² = 0.5166, MSE = 1.1097e-01
# Theta | Test_2 -> R² = 0.8676, MSE = 3.1288e-02
# Theta | Test_3 -> R² = 0.5231, MSE = 1.5661e-01
# Theta | Val -> R² = -6.6862, MSE = 2.5122e+00
# Theta | LSG_1 -> R² = -0.1213, MSE = 4.6438e-01
# Theta | LSG_2 -> R² = -4.7882, MSE = 2.0049e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 1.017403 | Val Loss 0.799742
# Epoch 100 | Train Loss 0.712250 | Val Loss 0.570732
# Epoch 200 | Train Loss 0.676883 | Val Loss 0.593609
# Early stopping at epoch 240
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7876, MSE = 4.8443e-02
# Theta | Train_2 -> R² = 0.5870, MSE = 9.3968e-02
# Theta | Test_1 -> R² = 0.5228, MSE = 1.0955e-01
# Theta | Test_2 -> R² = 0.8727, MSE = 3.0093e-02
# Theta | Test_3 -> R² = 0.6728, MSE = 1.0745e-01
# Theta | Val -> R² = -4.0278, MSE = 1.6433e+00
# Theta | LSG_1 -> R² = 0.3706, MSE = 2.6066e-01
# Theta | LSG_2 -> R² = -2.9463, MSE = 1.3669e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 1.074939 | Val Loss 0.750617
# Epoch 100 | Train Loss 0.712414 | Val Loss 0.563340
# Epoch 200 | Train Loss 0.680846 | Val Loss 0.600314
# Early stopping at epoch 245
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8061, MSE = 4.4211e-02
# Theta | Train_2 -> R² = 0.6619, MSE = 7.6919e-02
# Theta | Test_1 -> R² = 0.5555, MSE = 1.0204e-01
# Theta | Test_2 -> R² = 0.8523, MSE = 3.4910e-02
# Theta | Test_3 -> R² = 0.6381, MSE = 1.1887e-01
# Theta | Val -> R² = -2.5232, MSE = 1.1516e+00
# Theta | LSG_1 -> R² = 0.4147, MSE = 2.4240e-01
# Theta | LSG_2 -> R² = -3.0299, MSE = 1.3959e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 0.993431 | Val Loss 0.786284
# Epoch 100 | Train Loss 0.708424 | Val Loss 0.568357
# Epoch 200 | Train Loss 0.676425 | Val Loss 0.610322
# Early stopping at epoch 239
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7441, MSE = 5.8363e-02
# Theta | Train_2 -> R² = 0.6369, MSE = 8.2602e-02
# Theta | Test_1 -> R² = 0.3178, MSE = 1.5661e-01
# Theta | Test_2 -> R² = 0.8679, MSE = 3.1224e-02
# Theta | Test_3 -> R² = 0.6702, MSE = 1.0831e-01
# Theta | Val -> R² = -3.8505, MSE = 1.5854e+00
# Theta | LSG_1 -> R² = 0.3455, MSE = 2.7105e-01
# Theta | LSG_2 -> R² = -3.4899, MSE = 1.5552e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 1.105016 | Val Loss 0.808059
# Epoch 100 | Train Loss 0.713765 | Val Loss 0.567818
# Epoch 200 | Train Loss 0.690976 | Val Loss 0.559950
# Early stopping at epoch 246
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.7907, MSE = 4.7724e-02
# Theta | Train_2 -> R² = 0.6589, MSE = 7.7605e-02
# Theta | Test_1 -> R² = 0.4679, MSE = 1.2215e-01
# Theta | Test_2 -> R² = 0.8759, MSE = 2.9319e-02
# Theta | Test_3 -> R² = 0.6023, MSE = 1.3061e-01
# Theta | Val -> R² = -5.2390, MSE = 2.0392e+00
# Theta | LSG_1 -> R² = 0.1120, MSE = 3.6776e-01
# Theta | LSG_2 -> R² = -3.9031, MSE = 1.6983e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 0.995858 | Val Loss 0.751503
# Epoch 100 | Train Loss 0.708363 | Val Loss 0.566385
# Epoch 200 | Train Loss 0.672122 | Val Loss 0.601626
# Epoch 300 | Train Loss 0.614576 | Val Loss 0.812629
# Early stopping at epoch 369
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7964, MSE = 4.6437e-02
# Theta | Train_2 -> R² = 0.7577, MSE = 5.5118e-02
# Theta | Test_1 -> R² = 0.6665, MSE = 7.6549e-02
# Theta | Test_2 -> R² = 0.8683, MSE = 3.1121e-02
# Theta | Test_3 -> R² = 0.0925, MSE = 2.9805e-01
# Theta | Val -> R² = -2.6439, MSE = 1.1910e+00
# Theta | LSG_1 -> R² = 0.6897, MSE = 1.2849e-01
# Theta | LSG_2 -> R² = -3.0514, MSE = 1.4033e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 0.968096 | Val Loss 0.730303
# Epoch 100 | Train Loss 0.705981 | Val Loss 0.561292
# Epoch 200 | Train Loss 0.666150 | Val Loss 0.651313
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.8018, MSE = 4.5199e-02
# Theta | Train_2 -> R² = 0.6022, MSE = 9.0495e-02
# Theta | Test_1 -> R² = 0.4724, MSE = 1.2112e-01
# Theta | Test_2 -> R² = 0.8678, MSE = 3.1247e-02
# Theta | Test_3 -> R² = 0.7015, MSE = 9.8048e-02
# Theta | Val -> R² = -3.3815, MSE = 1.4321e+00
# Theta | LSG_1 -> R² = 0.4386, MSE = 2.3249e-01
# Theta | LSG_2 -> R² = -2.9260, MSE = 1.3599e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 1.045954 | Val Loss 0.818203
# Epoch 100 | Train Loss 0.708885 | Val Loss 0.567895
# Epoch 200 | Train Loss 0.677863 | Val Loss 0.621719
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7940, MSE = 4.6985e-02
# Theta | Train_2 -> R² = 0.5708, MSE = 9.7640e-02
# Theta | Test_1 -> R² = 0.4843, MSE = 1.1839e-01
# Theta | Test_2 -> R² = 0.8500, MSE = 3.5448e-02
# Theta | Test_3 -> R² = 0.6504, MSE = 1.1482e-01
# Theta | Val -> R² = -5.0133, MSE = 1.9655e+00
# Theta | LSG_1 -> R² = 0.2127, MSE = 3.2604e-01
# Theta | LSG_2 -> R² = -3.5637, MSE = 1.5808e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 1.011004 | Val Loss 0.784681
# Epoch 100 | Train Loss 0.736062 | Val Loss 0.614408
# Epoch 200 | Train Loss 0.657369 | Val Loss 0.697139
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.8473, MSE = 3.4834e-02
# Theta | Train_2 -> R² = 0.6820, MSE = 7.2344e-02
# Theta | Test_1 -> R² = 0.6881, MSE = 7.1601e-02
# Theta | Test_2 -> R² = 0.8799, MSE = 2.8387e-02
# Theta | Test_3 -> R² = -0.5908, MSE = 5.2247e-01
# Theta | Val -> R² = -11.4527, MSE = 4.0702e+00
# Theta | LSG_1 -> R² = -0.1922, MSE = 4.9374e-01
# Theta | LSG_2 -> R² = -4.9583, MSE = 2.0639e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 1.051654 | Val Loss 0.765819
# Epoch 100 | Train Loss 0.735251 | Val Loss 0.626816
# Epoch 200 | Train Loss 0.699356 | Val Loss 0.617231
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.8341, MSE = 3.7826e-02
# Theta | Train_2 -> R² = 0.6958, MSE = 6.9216e-02
# Theta | Test_1 -> R² = 0.7291, MSE = 6.2181e-02
# Theta | Test_2 -> R² = 0.8137, MSE = 4.4038e-02
# Theta | Test_3 -> R² = -0.6300, MSE = 5.3533e-01
# Theta | Val -> R² = -11.8908, MSE = 4.2134e+00
# Theta | LSG_1 -> R² = -0.3567, MSE = 5.6187e-01
# Theta | LSG_2 -> R² = -5.8153, MSE = 2.3607e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 0.960959 | Val Loss 0.738837
# Epoch 100 | Train Loss 0.729778 | Val Loss 0.629423
# Epoch 200 | Train Loss 0.604427 | Val Loss 0.846310
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8645, MSE = 3.0898e-02
# Theta | Train_2 -> R² = 0.6705, MSE = 7.4957e-02
# Theta | Test_1 -> R² = 0.7254, MSE = 6.3038e-02
# Theta | Test_2 -> R² = 0.8728, MSE = 3.0068e-02
# Theta | Test_3 -> R² = -0.3667, MSE = 4.4885e-01
# Theta | Val -> R² = -10.8646, MSE = 3.8780e+00
# Theta | LSG_1 -> R² = -0.1227, MSE = 4.6494e-01
# Theta | LSG_2 -> R² = -4.7248, MSE = 1.9830e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 1.033425 | Val Loss 0.816234
# Epoch 100 | Train Loss 0.739869 | Val Loss 0.612120
# Epoch 200 | Train Loss 0.703046 | Val Loss 0.633440
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7956, MSE = 4.6610e-02
# Theta | Train_2 -> R² = 0.6636, MSE = 7.6525e-02
# Theta | Test_1 -> R² = 0.7835, MSE = 4.9702e-02
# Theta | Test_2 -> R² = 0.8776, MSE = 2.8925e-02
# Theta | Test_3 -> R² = -0.3707, MSE = 4.5018e-01
# Theta | Val -> R² = -9.0235, MSE = 3.2762e+00
# Theta | LSG_1 -> R² = 0.2382, MSE = 3.1547e-01
# Theta | LSG_2 -> R² = -3.5197, MSE = 1.5655e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 1.067183 | Val Loss 0.841824
# Epoch 100 | Train Loss 0.734577 | Val Loss 0.625216
# Epoch 200 | Train Loss 0.682227 | Val Loss 0.599411
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8337, MSE = 3.7928e-02
# Theta | Train_2 -> R² = 0.6698, MSE = 7.5117e-02
# Theta | Test_1 -> R² = 0.7024, MSE = 6.8319e-02
# Theta | Test_2 -> R² = 0.8795, MSE = 2.8491e-02
# Theta | Test_3 -> R² = -0.0801, MSE = 3.5474e-01
# Theta | Val -> R² = -9.2405, MSE = 3.3471e+00
# Theta | LSG_1 -> R² = -0.0352, MSE = 4.2871e-01
# Theta | LSG_2 -> R² = -4.4707, MSE = 1.8949e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 0.964336 | Val Loss 0.752368
# Epoch 100 | Train Loss 0.730508 | Val Loss 0.623899
# Epoch 200 | Train Loss 0.618959 | Val Loss 0.702271
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.8073, MSE = 4.3937e-02
# Theta | Train_2 -> R² = 0.5406, MSE = 1.0452e-01
# Theta | Test_1 -> R² = 0.6012, MSE = 9.1543e-02
# Theta | Test_2 -> R² = 0.8453, MSE = 3.6565e-02
# Theta | Test_3 -> R² = -0.2239, MSE = 4.0196e-01
# Theta | Val -> R² = -9.4923, MSE = 3.4294e+00
# Theta | LSG_1 -> R² = 0.1558, MSE = 3.4960e-01
# Theta | LSG_2 -> R² = -3.3949, MSE = 1.5223e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 0.973888 | Val Loss 0.754444
# Epoch 100 | Train Loss 0.726449 | Val Loss 0.627203
# Epoch 200 | Train Loss 0.633374 | Val Loss 0.579102
# Epoch 300 | Train Loss 0.560153 | Val Loss 0.813614
# Early stopping at epoch 391
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.6416, MSE = 8.1745e-02
# Theta | Train_2 -> R² = 0.7711, MSE = 5.2083e-02
# Theta | Test_1 -> R² = 0.3637, MSE = 1.4606e-01
# Theta | Test_2 -> R² = 0.8014, MSE = 4.6936e-02
# Theta | Test_3 -> R² = -6.6369, MSE = 2.5082e+00
# Theta | Val -> R² = -19.6522, MSE = 6.7502e+00
# Theta | LSG_1 -> R² = -1.4672, MSE = 1.0217e+00
# Theta | LSG_2 -> R² = -8.6348, MSE = 3.3373e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 1.029945 | Val Loss 0.760594
# Epoch 100 | Train Loss 0.733191 | Val Loss 0.620786
# Epoch 200 | Train Loss 0.686656 | Val Loss 0.609044
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8422, MSE = 3.5977e-02
# Theta | Train_2 -> R² = 0.7139, MSE = 6.5083e-02
# Theta | Test_1 -> R² = 0.6417, MSE = 8.2257e-02
# Theta | Test_2 -> R² = 0.8646, MSE = 3.2004e-02
# Theta | Test_3 -> R² = -0.7399, MSE = 5.7143e-01
# Theta | Val -> R² = -12.5314, MSE = 4.4228e+00
# Theta | LSG_1 -> R² = -0.4349, MSE = 5.9425e-01
# Theta | LSG_2 -> R² = -5.8070, MSE = 2.3578e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 1.073888 | Val Loss 0.837059
# Epoch 100 | Train Loss 0.741821 | Val Loss 0.614334
# Epoch 200 | Train Loss 0.716043 | Val Loss 0.617046
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.8066, MSE = 4.4101e-02
# Theta | Train_2 -> R² = 0.6243, MSE = 8.5479e-02
# Theta | Test_1 -> R² = 0.5621, MSE = 1.0052e-01
# Theta | Test_2 -> R² = 0.8652, MSE = 3.1867e-02
# Theta | Test_3 -> R² = -0.5239, MSE = 5.0047e-01
# Theta | Val -> R² = -10.8558, MSE = 3.8751e+00
# Theta | LSG_1 -> R² = -0.1150, MSE = 4.6177e-01
# Theta | LSG_2 -> R² = -4.5608, MSE = 1.9262e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 0.958940 | Val Loss 0.713361
# Epoch 100 | Train Loss 0.731649 | Val Loss 0.611931
# Epoch 200 | Train Loss 0.645234 | Val Loss 0.648116
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8181, MSE = 4.1485e-02
# Theta | Train_2 -> R² = 0.7165, MSE = 6.4496e-02
# Theta | Test_1 -> R² = 0.6547, MSE = 7.9256e-02
# Theta | Test_2 -> R² = 0.8706, MSE = 3.0588e-02
# Theta | Test_3 -> R² = -0.5624, MSE = 5.1314e-01
# Theta | Val -> R² = -10.8781, MSE = 3.8824e+00
# Theta | LSG_1 -> R² = -0.2347, MSE = 5.1131e-01
# Theta | LSG_2 -> R² = -5.4241, MSE = 2.2252e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 1.063066 | Val Loss 0.722799
# Epoch 100 | Train Loss 0.705097 | Val Loss 0.564925
# Epoch 200 | Train Loss 0.663360 | Val Loss 0.614708
# Epoch 300 | Train Loss 0.604572 | Val Loss 0.819669
# Early stopping at epoch 362
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.8252, MSE = 3.9864e-02
# Theta | Train_2 -> R² = 0.7798, MSE = 5.0102e-02
# Theta | Test_1 -> R² = 0.7795, MSE = 5.0619e-02
# Theta | Test_2 -> R² = 0.8460, MSE = 3.6398e-02
# Theta | Test_3 -> R² = -0.6943, MSE = 5.5644e-01
# Theta | Val -> R² = -3.0072, MSE = 1.3098e+00
# Theta | LSG_1 -> R² = 0.6719, MSE = 1.3586e-01
# Theta | LSG_2 -> R² = -2.4969, MSE = 1.2112e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 1.129836 | Val Loss 0.701460
# Epoch 100 | Train Loss 0.705462 | Val Loss 0.566545
# Epoch 200 | Train Loss 0.673912 | Val Loss 0.599077
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.8049, MSE = 4.4483e-02
# Theta | Train_2 -> R² = 0.7093, MSE = 6.6133e-02
# Theta | Test_1 -> R² = 0.6268, MSE = 8.5663e-02
# Theta | Test_2 -> R² = 0.8780, MSE = 2.8831e-02
# Theta | Test_3 -> R² = 0.3809, MSE = 2.0332e-01
# Theta | Val -> R² = -6.3706, MSE = 2.4091e+00
# Theta | LSG_1 -> R² = 0.0153, MSE = 4.0778e-01
# Theta | LSG_2 -> R² = -4.7811, MSE = 2.0025e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 1.136298 | Val Loss 0.753590
# Epoch 100 | Train Loss 0.704856 | Val Loss 0.567919
# Epoch 200 | Train Loss 0.657740 | Val Loss 0.619591
# Epoch 300 | Train Loss 0.591953 | Val Loss 0.772447
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8259, MSE = 3.9704e-02
# Theta | Train_2 -> R² = 0.7729, MSE = 5.1672e-02
# Theta | Test_1 -> R² = 0.8167, MSE = 4.2085e-02
# Theta | Test_2 -> R² = 0.8507, MSE = 3.5279e-02
# Theta | Test_3 -> R² = 0.0963, MSE = 2.9679e-01
# Theta | Val -> R² = -1.2843, MSE = 7.4663e-01
# Theta | LSG_1 -> R² = 0.6764, MSE = 1.3401e-01
# Theta | LSG_2 -> R² = -1.8693, MSE = 9.9387e-01
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 1.022587 | Val Loss 0.671310
# Epoch 100 | Train Loss 0.704229 | Val Loss 0.567787
# Epoch 200 | Train Loss 0.661929 | Val Loss 0.608243
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed1579.weights.h5
# ...
# Theta | Train_1 -> R² = 0.8656, MSE = 3.0640e-02
# Theta | Train_2 -> R² = 0.6008, MSE = 9.0831e-02
# Theta | Test_1 -> R² = 0.5488, MSE = 1.0357e-01
# Theta | Test_2 -> R² = 0.8258, MSE = 4.1173e-02
# Theta | Test_3 -> R² = 0.5686, MSE = 1.4169e-01
# Theta | Val -> R² = -5.0490, MSE = 1.9771e+00
# Theta | LSG_1 -> R² = 0.5421, MSE = 1.8962e-01
# Theta | LSG_2 -> R² = -2.1584, MSE = 1.0940e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 0.966925 | Val Loss 0.606180
# Epoch 100 | Train Loss 0.632728 | Val Loss 0.645390
# Epoch 200 | Train Loss 0.564251 | Val Loss 0.800504
# Early stopping at epoch 259
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7957, MSE = 4.6596e-02
# Theta | Train_2 -> R² = 0.8259, MSE = 3.9613e-02
# Theta | Test_1 -> R² = 0.7401, MSE = 5.9669e-02
# Theta | Test_2 -> R² = 0.8430, MSE = 3.7109e-02
# Theta | Test_3 -> R² = -0.7307, MSE = 5.6839e-01
# Theta | Val -> R² = -3.1948, MSE = 1.3711e+00
# Theta | LSG_1 -> R² = 0.6462, MSE = 1.4651e-01
# Theta | LSG_2 -> R² = -3.2807, MSE = 1.4828e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 0.977140 | Val Loss 0.569303
# Epoch 100 | Train Loss 0.640676 | Val Loss 0.680663
# Epoch 200 | Train Loss 0.574796 | Val Loss 0.809126
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.7284, MSE = 6.1928e-02
# Theta | Train_2 -> R² = 0.7617, MSE = 5.4222e-02
# Theta | Test_1 -> R² = 0.7336, MSE = 6.1161e-02
# Theta | Test_2 -> R² = 0.8860, MSE = 2.6952e-02
# Theta | Test_3 -> R² = 0.4147, MSE = 1.9223e-01
# Theta | Val -> R² = -1.3506, MSE = 7.6828e-01
# Theta | LSG_1 -> R² = 0.6842, MSE = 1.3077e-01
# Theta | LSG_2 -> R² = -1.9366, MSE = 1.0172e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 1.046328 | Val Loss 0.787903
# Epoch 100 | Train Loss 0.648507 | Val Loss 0.648358
# Epoch 200 | Train Loss 0.571387 | Val Loss 0.787150
# Early stopping at epoch 269
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.7532, MSE = 5.6293e-02
# Theta | Train_2 -> R² = 0.7167, MSE = 6.4459e-02
# Theta | Test_1 -> R² = 0.8102, MSE = 4.3566e-02
# Theta | Test_2 -> R² = 0.8793, MSE = 2.8533e-02
# Theta | Test_3 -> R² = 0.6629, MSE = 1.1072e-01
# Theta | Val -> R² = -0.5867, MSE = 5.1861e-01
# Theta | LSG_1 -> R² = 0.6513, MSE = 1.4440e-01
# Theta | LSG_2 -> R² = -1.2035, MSE = 7.6326e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 1.001787 | Val Loss 0.688055
# Epoch 100 | Train Loss 0.647069 | Val Loss 0.656698
# Epoch 200 | Train Loss 0.563691 | Val Loss 0.791455
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.6230, MSE = 8.5979e-02
# Theta | Train_2 -> R² = 0.7886, MSE = 4.8098e-02
# Theta | Test_1 -> R² = 0.6250, MSE = 8.6072e-02
# Theta | Test_2 -> R² = 0.8779, MSE = 2.8853e-02
# Theta | Test_3 -> R² = -0.1756, MSE = 3.8608e-01
# Theta | Val -> R² = -2.7358, MSE = 1.2211e+00
# Theta | LSG_1 -> R² = 0.6565, MSE = 1.4225e-01
# Theta | LSG_2 -> R² = -2.3059, MSE = 1.1451e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 1.000746 | Val Loss 0.568265
# Epoch 100 | Train Loss 0.645955 | Val Loss 0.637408
# Epoch 200 | Train Loss 0.573950 | Val Loss 0.795495
# Early stopping at epoch 258
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.7029, MSE = 6.7744e-02
# Theta | Train_2 -> R² = 0.7461, MSE = 5.7771e-02
# Theta | Test_1 -> R² = 0.6981, MSE = 6.9307e-02
# Theta | Test_2 -> R² = 0.8637, MSE = 3.2202e-02
# Theta | Test_3 -> R² = 0.3223, MSE = 2.2257e-01
# Theta | Val -> R² = -2.0888, MSE = 1.0096e+00
# Theta | LSG_1 -> R² = 0.6667, MSE = 1.3805e-01
# Theta | LSG_2 -> R² = -2.1231, MSE = 1.0818e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 0.972993 | Val Loss 0.598007
# Epoch 100 | Train Loss 0.626570 | Val Loss 0.684383
# Epoch 200 | Train Loss 0.557939 | Val Loss 0.793162
# Early stopping at epoch 254
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed338.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed338.weights.h5
# Theta | Train_1 -> R² = 0.7640, MSE = 5.3815e-02
# Theta | Train_2 -> R² = 0.7655, MSE = 5.3359e-02
# Theta | Test_1 -> R² = 0.7568, MSE = 5.5827e-02
# Theta | Test_2 -> R² = 0.8616, MSE = 3.2716e-02
# Theta | Test_3 -> R² = 0.7079, MSE = 9.5927e-02
# Theta | Val -> R² = -1.3099, MSE = 7.5500e-01
# Theta | LSG_1 -> R² = 0.6315, MSE = 1.5259e-01
# Theta | LSG_2 -> R² = -2.5338, MSE = 1.2240e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 0.997999 | Val Loss 0.588350
# Epoch 100 | Train Loss 0.632628 | Val Loss 0.699206
# Epoch 200 | Train Loss 0.564969 | Val Loss 0.815571
# Early stopping at epoch 256
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1366.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.6492, MSE = 7.9998e-02
# Theta | Train_2 -> R² = 0.7977, MSE = 4.6027e-02
# Theta | Test_1 -> R² = 0.5592, MSE = 1.0118e-01
# Theta | Test_2 -> R² = 0.8795, MSE = 2.8468e-02
# Theta | Test_3 -> R² = 0.4799, MSE = 1.7082e-01
# Theta | Val -> R² = -1.2849, MSE = 7.4682e-01
# Theta | LSG_1 -> R² = 0.6842, MSE = 1.3078e-01
# Theta | LSG_2 -> R² = -2.5057, MSE = 1.2143e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 0.964292 | Val Loss 0.573096
# Epoch 100 | Train Loss 0.628384 | Val Loss 0.682153
# Epoch 200 | Train Loss 0.576156 | Val Loss 0.815838
# Early stopping at epoch 205
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3221.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.8233, MSE = 4.0290e-02
# Theta | Train_2 -> R² = 0.6332, MSE = 8.3462e-02
# Theta | Test_1 -> R² = 0.6835, MSE = 7.2644e-02
# Theta | Test_2 -> R² = 0.7560, MSE = 5.7660e-02
# Theta | Test_3 -> R² = 0.4505, MSE = 1.8048e-01
# Theta | Val -> R² = -4.9087, MSE = 1.9313e+00
# Theta | LSG_1 -> R² = 0.4643, MSE = 2.2184e-01
# Theta | LSG_2 -> R² = -2.8132, MSE = 1.3208e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 0.979218 | Val Loss 0.621437
# Epoch 100 | Train Loss 0.635344 | Val Loss 0.632410
# Epoch 200 | Train Loss 0.562146 | Val Loss 0.781831
# Early stopping at epoch 258
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1579.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.7502, MSE = 5.6959e-02
# Theta | Train_2 -> R² = 0.7929, MSE = 4.7117e-02
# Theta | Test_1 -> R² = 0.8232, MSE = 4.0579e-02
# Theta | Test_2 -> R² = 0.8732, MSE = 2.9961e-02
# Theta | Test_3 -> R² = 0.6545, MSE = 1.1346e-01
# Theta | Val -> R² = 0.2032, MSE = 2.6044e-01
# Theta | LSG_1 -> R² = 0.6773, MSE = 1.3365e-01
# Theta | LSG_2 -> R² = -0.9301, MSE = 6.6853e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 1.072639 | Val Loss 0.766105
# Epoch 100 | Train Loss 0.646542 | Val Loss 0.637192
# Epoch 200 | Train Loss 0.574337 | Val Loss 0.786685
# Early stopping at epoch 261
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8619.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8082, MSE = 4.3733e-02
# Theta | Train_2 -> R² = 0.7962, MSE = 4.6376e-02
# Theta | Test_1 -> R² = 0.8462, MSE = 3.5301e-02
# Theta | Test_2 -> R² = 0.8973, MSE = 2.4274e-02
# Theta | Test_3 -> R² = 0.4721, MSE = 1.7337e-01
# Theta | Val -> R² = -1.3610, MSE = 7.7170e-01
# Theta | LSG_1 -> R² = 0.6595, MSE = 1.4102e-01
# Theta | LSG_2 -> R² = -2.1246, MSE = 1.0823e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8619 salvo.
# Epoch 0 | Train Loss 0.997902 | Val Loss 0.579890
# Epoch 100 | Train Loss 0.585299 | Val Loss 0.644005
# Epoch 200 | Train Loss 0.529721 | Val Loss 0.964083
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.9592, MSE = 9.2955e-03
# Theta | Train_2 -> R² = 0.6509, MSE = 7.9423e-02
# Theta | Test_1 -> R² = 0.6635, MSE = 7.7232e-02
# Theta | Test_2 -> R² = 0.6363, MSE = 8.5961e-02
# Theta | Test_3 -> R² = -0.9140, MSE = 6.2861e-01
# Theta | Val -> R² = -6.1320, MSE = 2.3311e+00
# Theta | LSG_1 -> R² = -0.0899, MSE = 4.5134e-01
# Theta | LSG_2 -> R² = -3.2159, MSE = 1.4603e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=338 salvo.
# Epoch 0 | Train Loss 0.940107 | Val Loss 0.852004
# Epoch 100 | Train Loss 0.666541 | Val Loss 0.589844
# Epoch 200 | Train Loss 0.535455 | Val Loss 0.943965
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.8387, MSE = 3.6789e-02
# Theta | Train_2 -> R² = 0.7501, MSE = 5.6847e-02
# Theta | Test_1 -> R² = 0.5348, MSE = 1.0678e-01
# Theta | Test_2 -> R² = 0.8570, MSE = 3.3793e-02
# Theta | Test_3 -> R² = 0.1774, MSE = 2.7016e-01
# Theta | Val -> R² = -7.8821, MSE = 2.9031e+00
# Theta | LSG_1 -> R² = -0.1927, MSE = 4.9391e-01
# Theta | LSG_2 -> R² = -5.3057, MSE = 2.1842e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1366 salvo.
# Epoch 0 | Train Loss 1.041135 | Val Loss 0.729887
# Epoch 100 | Train Loss 0.681625 | Val Loss 0.711237
# Epoch 200 | Train Loss 0.544444 | Val Loss 0.876505
# Epoch 300 | Train Loss 0.519589 | Val Loss 1.075563
# Early stopping at epoch 310
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.6226, MSE = 8.6074e-02
# Theta | Train_2 -> R² = 0.6826, MSE = 7.2222e-02
# Theta | Test_1 -> R² = 0.8060, MSE = 4.4525e-02
# Theta | Test_2 -> R² = 0.9417, MSE = 1.3776e-02
# Theta | Test_3 -> R² = -3.3029, MSE = 1.4132e+00
# Theta | Val -> R² = -11.0483, MSE = 3.9380e+00
# Theta | LSG_1 -> R² = -0.1864, MSE = 4.9133e-01
# Theta | LSG_2 -> R² = -4.2629, MSE = 1.8230e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3221 salvo.
# Epoch 0 | Train Loss 1.024300 | Val Loss 0.668840
# Epoch 100 | Train Loss 0.622886 | Val Loss 0.554540
# Epoch 200 | Train Loss 0.530956 | Val Loss 0.996027
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.8211, MSE = 4.0796e-02
# Theta | Train_2 -> R² = 0.8316, MSE = 3.8320e-02
# Theta | Test_1 -> R² = 0.8062, MSE = 4.4483e-02
# Theta | Test_2 -> R² = 0.8602, MSE = 3.3040e-02
# Theta | Test_3 -> R² = -4.5578, MSE = 1.8253e+00
# Theta | Val -> R² = -12.8568, MSE = 4.5291e+00
# Theta | LSG_1 -> R² = -0.4741, MSE = 6.1047e-01
# Theta | LSG_2 -> R² = -6.8338, MSE = 2.7135e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1579 salvo.
# Epoch 0 | Train Loss 0.962402 | Val Loss 0.633448
# Epoch 100 | Train Loss 0.605330 | Val Loss 0.533589
# Epoch 200 | Train Loss 0.530774 | Val Loss 0.988366
# Early stopping at epoch 297
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.8418, MSE = 3.6070e-02
# Theta | Train_2 -> R² = 0.5164, MSE = 1.1002e-01
# Theta | Test_1 -> R² = 0.8461, MSE = 3.5324e-02
# Theta | Test_2 -> R² = 0.8699, MSE = 3.0758e-02
# Theta | Test_3 -> R² = -1.5074, MSE = 8.2350e-01
# Theta | Val -> R² = -5.3783, MSE = 2.0848e+00
# Theta | LSG_1 -> R² = 0.2589, MSE = 3.0693e-01
# Theta | LSG_2 -> R² = -3.0676, MSE = 1.4089e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8619 salvo.
# Epoch 0 | Train Loss 1.019841 | Val Loss 0.675806
# Epoch 100 | Train Loss 0.630179 | Val Loss 0.545824
# Epoch 200 | Train Loss 0.539919 | Val Loss 0.920925
# Epoch 300 | Train Loss 0.517893 | Val Loss 1.078918
# Early stopping at epoch 304
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed338.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed338.weights.h5
# Theta | Train_1 -> R² = 0.6407, MSE = 8.1929e-02
# Theta | Train_2 -> R² = 0.6529, MSE = 7.8962e-02
# Theta | Test_1 -> R² = 0.8633, MSE = 3.1390e-02
# Theta | Test_2 -> R² = 0.9344, MSE = 1.5505e-02
# Theta | Test_3 -> R² = -2.1639, MSE = 1.0391e+00
# Theta | Val -> R² = -3.5531, MSE = 1.4882e+00
# Theta | LSG_1 -> R² = 0.7142, MSE = 1.1834e-01
# Theta | LSG_2 -> R² = -1.8859, MSE = 9.9961e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=338 salvo.
# Epoch 0 | Train Loss 1.036414 | Val Loss 0.610033
# Epoch 100 | Train Loss 0.611995 | Val Loss 0.600859
# Epoch 200 | Train Loss 0.540416 | Val Loss 0.927926
# Early stopping at epoch 291
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1366.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1366.weights.h5
# Theta | Train_1 -> R² = 0.8192, MSE = 4.1222e-02
# Theta | Train_2 -> R² = 0.5262, MSE = 1.0779e-01
# Theta | Test_1 -> R² = 0.6641, MSE = 7.7098e-02
# Theta | Test_2 -> R² = 0.7752, MSE = 5.3126e-02
# Theta | Test_3 -> R² = -2.7779, MSE = 1.2408e+00
# Theta | Val -> R² = -11.0001, MSE = 3.9222e+00
# Theta | LSG_1 -> R² = -0.6227, MSE = 6.7199e-01
# Theta | LSG_2 -> R² = -5.2737, MSE = 2.1731e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1366 salvo.
# Epoch 0 | Train Loss 1.037547 | Val Loss 0.580574
# Epoch 100 | Train Loss 0.578129 | Val Loss 0.722032
# Epoch 200 | Train Loss 0.529626 | Val Loss 1.028211
# Early stopping at epoch 264
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3221.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3221.weights.h5
# Theta | Train_1 -> R² = 0.6375, MSE = 8.2664e-02
# Theta | Train_2 -> R² = 0.7098, MSE = 6.6027e-02
# Theta | Test_1 -> R² = 0.4349, MSE = 1.2972e-01
# Theta | Test_2 -> R² = 0.8001, MSE = 4.7250e-02
# Theta | Test_3 -> R² = -3.6877, MSE = 1.5396e+00
# Theta | Val -> R² = -12.7620, MSE = 4.4981e+00
# Theta | LSG_1 -> R² = -0.6268, MSE = 6.7372e-01
# Theta | LSG_2 -> R² = -7.5454, MSE = 2.9600e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3221 salvo.
# Epoch 0 | Train Loss 1.003878 | Val Loss 0.650256
# Epoch 100 | Train Loss 0.587540 | Val Loss 0.649867
# Epoch 200 | Train Loss 0.523770 | Val Loss 1.017774
# Early stopping at epoch 209
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1579.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1579.weights.h5
# Theta | Train_1 -> R² = 0.8173, MSE = 4.1676e-02
# Theta | Train_2 -> R² = 0.7001, MSE = 6.8228e-02
# Theta | Test_1 -> R² = 0.4335, MSE = 1.3004e-01
# Theta | Test_2 -> R² = 0.8524, MSE = 3.4879e-02
# Theta | Test_3 -> R² = 0.1738, MSE = 2.7134e-01
# Theta | Val -> R² = -7.8690, MSE = 2.8988e+00
# Theta | LSG_1 -> R² = 0.0271, MSE = 4.0290e-01
# Theta | LSG_2 -> R² = -4.3324, MSE = 1.8470e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1579 salvo.
# Epoch 0 | Train Loss 0.977044 | Val Loss 0.779957
# Epoch 100 | Train Loss 0.629631 | Val Loss 0.613841
# Epoch 200 | Train Loss 0.538008 | Val Loss 0.976023
# Early stopping at epoch 210
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8619.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8619.weights.h5
# Theta | Train_1 -> R² = 0.9209, MSE = 1.8048e-02
# Theta | Train_2 -> R² = 0.6809, MSE = 7.2599e-02
# Theta | Test_1 -> R² = 0.6206, MSE = 8.7097e-02
# Theta | Test_2 -> R² = 0.7738, MSE = 5.3453e-02
# Theta | Test_3 -> R² = 0.6348, MSE = 1.1994e-01
# Theta | Val -> R² = -6.6804, MSE = 2.5104e+00
# Theta | LSG_1 -> R² = -0.0170, MSE = 4.2119e-01
# Theta | LSG_2 -> R² = -4.7951, MSE = 2.0073e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8619 salvo.
