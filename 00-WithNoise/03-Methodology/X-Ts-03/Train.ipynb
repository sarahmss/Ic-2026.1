# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(Theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "cosTheta"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./Data/Theta.xlsx", sheet_name=title)

    df["Theta_pred"] = df_theta["Theta_pred_model_arch16-8-4_r0.9_Ld0.3_Lp0.7_seed5830"]

    df["cosTheta"] = np.cos(df["Theta_pred"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1943, 3, 5)
# Dimensão da saida: (1943, 1)
# Dimensão da entrada: (1265, 3, 5)
# Dimensão da saida: (1265, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1943, 3, 5)
# Dimensão da saida: (1943, 1)
# Dimensão da entrada fisica : (1943,)
# Dimensão da entrada fisica: (1943,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    return [dx_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.407709 | Val Loss 0.688292
# Epoch 100 | Train Loss 0.159135 | Val Loss 0.432350
# Epoch 200 | Train Loss 0.152638 | Val Loss 0.422350
# Epoch 300 | Train Loss 0.145365 | Val Loss 0.407834
# Epoch 400 | Train Loss 0.142327 | Val Loss 0.404140
# Epoch 500 | Train Loss 0.141332 | Val Loss 0.404991
# Early stopping at epoch 554
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9932, MSE = 7.3218e-04
# X | Train_2 -> R² = 0.9946, MSE = 4.5390e-04
# X | Test_1 -> R² = 0.9627, MSE = 3.8927e-03
# X | Test_2 -> R² = -0.4160, MSE = 1.1634e-01
# X | Test_3 -> R² = -2.7722, MSE = 3.4600e-01
# X | Val -> R² = -1.1407, MSE = 2.0398e-01
# X | LSG_1 -> R² = -0.8817, MSE = 1.9211e-01
# X | LSG_2 -> R² = -1.1853, MSE = 1.9347e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.394158 | Val Loss 0.665093
# Epoch 100 | Train Loss 0.157175 | Val Loss 0.443321
# Epoch 200 | Train Loss 0.152610 | Val Loss 0.436247
# Epoch 300 | Train Loss 0.148807 | Val Loss 0.425816
# Epoch 400 | Train Loss 0.143941 | Val Loss 0.409480
# Epoch 500 | Train Loss 0.140874 | Val Loss 0.403416
# Epoch 600 | Train Loss 0.139932 | Val Loss 0.403284
# Early stopping at epoch 682
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9962, MSE = 4.0780e-04
# X | Train_2 -> R² = 0.9940, MSE = 5.0508e-04
# X | Test_1 -> R² = 0.9278, MSE = 7.5352e-03
# X | Test_2 -> R² = 0.8320, MSE = 1.3799e-02
# X | Test_3 -> R² = -1.1136, MSE = 1.9386e-01
# X | Val -> R² = -0.1366, MSE = 1.0831e-01
# X | LSG_1 -> R² = 0.6867, MSE = 3.1986e-02
# X | LSG_2 -> R² = -0.1960, MSE = 1.0589e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.457001 | Val Loss 0.708701
# Epoch 100 | Train Loss 0.164307 | Val Loss 0.444628
# Epoch 200 | Train Loss 0.154975 | Val Loss 0.430136
# Epoch 300 | Train Loss 0.150943 | Val Loss 0.418249
# Epoch 400 | Train Loss 0.147270 | Val Loss 0.411098
# Epoch 500 | Train Loss 0.144492 | Val Loss 0.406694
# Epoch 600 | Train Loss 0.142238 | Val Loss 0.403327
# Epoch 700 | Train Loss 0.141310 | Val Loss 0.403293
# Epoch 800 | Train Loss 0.140777 | Val Loss 0.404642
# Early stopping at epoch 815
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9916, MSE = 9.0093e-04
# X | Train_2 -> R² = 0.9956, MSE = 3.6815e-04
# X | Test_1 -> R² = 0.9782, MSE = 2.2751e-03
# X | Test_2 -> R² = -0.3917, MSE = 1.1434e-01
# X | Test_3 -> R² = -4.1905, MSE = 4.7608e-01
# X | Val -> R² = -2.1999, MSE = 3.0491e-01
# X | LSG_1 -> R² = -0.6542, MSE = 1.6888e-01
# X | LSG_2 -> R² = -1.0491, MSE = 1.8141e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.441371 | Val Loss 0.693460
# Epoch 100 | Train Loss 0.164365 | Val Loss 0.439209
# Epoch 200 | Train Loss 0.154283 | Val Loss 0.428783
# Epoch 300 | Train Loss 0.149158 | Val Loss 0.416332
# Epoch 400 | Train Loss 0.143917 | Val Loss 0.409921
# Epoch 500 | Train Loss 0.141112 | Val Loss 0.414414
# Early stopping at epoch 585
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9913, MSE = 9.3421e-04
# X | Train_2 -> R² = 0.9961, MSE = 3.3088e-04
# X | Test_1 -> R² = 0.9528, MSE = 4.9201e-03
# X | Test_2 -> R² = -0.1151, MSE = 9.1617e-02
# X | Test_3 -> R² = -3.9465, MSE = 4.5370e-01
# X | Val -> R² = -1.4530, MSE = 2.3374e-01
# X | LSG_1 -> R² = -0.2565, MSE = 1.2828e-01
# X | LSG_2 -> R² = -0.6777, MSE = 1.4853e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.426260 | Val Loss 0.711922
# Epoch 100 | Train Loss 0.161206 | Val Loss 0.439293
# Epoch 200 | Train Loss 0.153743 | Val Loss 0.434988
# Epoch 300 | Train Loss 0.149777 | Val Loss 0.423885
# Epoch 400 | Train Loss 0.145227 | Val Loss 0.410188
# Epoch 500 | Train Loss 0.141473 | Val Loss 0.402892
# Epoch 600 | Train Loss 0.140185 | Val Loss 0.401495
# Epoch 700 | Train Loss 0.139484 | Val Loss 0.403290
# Early stopping at epoch 728
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9966, MSE = 3.6324e-04
# X | Train_2 -> R² = 0.9958, MSE = 3.5034e-04
# X | Test_1 -> R² = 0.9250, MSE = 7.8269e-03
# X | Test_2 -> R² = 0.7191, MSE = 2.3078e-02
# X | Test_3 -> R² = -1.7260, MSE = 2.5003e-01
# X | Val -> R² = -0.4062, MSE = 1.3399e-01
# X | LSG_1 -> R² = 0.7574, MSE = 2.4765e-02
# X | LSG_2 -> R² = 0.2076, MSE = 7.0152e-02
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.428861 | Val Loss 0.696383
# Epoch 100 | Train Loss 0.158927 | Val Loss 0.441494
# Epoch 200 | Train Loss 0.153673 | Val Loss 0.433628
# Epoch 300 | Train Loss 0.150592 | Val Loss 0.423142
# Epoch 400 | Train Loss 0.147209 | Val Loss 0.416118
# Epoch 500 | Train Loss 0.143262 | Val Loss 0.415873
# Epoch 600 | Train Loss 0.140961 | Val Loss 0.417375
# Early stopping at epoch 604
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9919, MSE = 8.7343e-04
# X | Train_2 -> R² = 0.9928, MSE = 6.0248e-04
# X | Test_1 -> R² = 0.9438, MSE = 5.8669e-03
# X | Test_2 -> R² = 0.2445, MSE = 6.2073e-02
# X | Test_3 -> R² = -2.8822, MSE = 3.5608e-01
# X | Val -> R² = -0.8954, MSE = 1.8060e-01
# X | LSG_1 -> R² = 0.3036, MSE = 7.1092e-02
# X | LSG_2 -> R² = -0.0718, MSE = 9.4891e-02
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.412396 | Val Loss 0.689799
# Epoch 100 | Train Loss 0.161660 | Val Loss 0.442803
# Epoch 200 | Train Loss 0.153966 | Val Loss 0.434599
# Epoch 300 | Train Loss 0.150394 | Val Loss 0.430448
# Epoch 400 | Train Loss 0.146700 | Val Loss 0.429014
# Epoch 500 | Train Loss 0.143001 | Val Loss 0.427701
# Epoch 600 | Train Loss 0.141240 | Val Loss 0.429562
# Early stopping at epoch 672
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9909, MSE = 9.7265e-04
# X | Train_2 -> R² = 0.9901, MSE = 8.3540e-04
# X | Test_1 -> R² = 0.9855, MSE = 1.5098e-03
# X | Test_2 -> R² = 0.6464, MSE = 2.9053e-02
# X | Test_3 -> R² = -1.0624, MSE = 1.8917e-01
# X | Val -> R² = -0.1546, MSE = 1.1001e-01
# X | LSG_1 -> R² = 0.6390, MSE = 3.6858e-02
# X | LSG_2 -> R² = 0.1019, MSE = 7.9513e-02
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.429282 | Val Loss 0.711163
# Epoch 100 | Train Loss 0.163079 | Val Loss 0.442353
# Epoch 200 | Train Loss 0.154154 | Val Loss 0.433167
# Epoch 300 | Train Loss 0.150805 | Val Loss 0.426765
# Epoch 400 | Train Loss 0.146796 | Val Loss 0.416065
# Epoch 500 | Train Loss 0.143372 | Val Loss 0.412043
# Epoch 600 | Train Loss 0.141487 | Val Loss 0.414766
# Early stopping at epoch 644
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9925, MSE = 8.0815e-04
# X | Train_2 -> R² = 0.9934, MSE = 5.5874e-04
# X | Test_1 -> R² = 0.9263, MSE = 7.6932e-03
# X | Test_2 -> R² = 0.3706, MSE = 5.1713e-02
# X | Test_3 -> R² = -2.8206, MSE = 3.5043e-01
# X | Val -> R² = -1.0650, MSE = 1.9676e-01
# X | LSG_1 -> R² = 0.5967, MSE = 4.1170e-02
# X | LSG_2 -> R² = -0.1763, MSE = 1.0414e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.440074 | Val Loss 0.656507
# Epoch 100 | Train Loss 0.162986 | Val Loss 0.441364
# Epoch 200 | Train Loss 0.154366 | Val Loss 0.429407
# Epoch 300 | Train Loss 0.150191 | Val Loss 0.417595
# Epoch 400 | Train Loss 0.145549 | Val Loss 0.407941
# Epoch 500 | Train Loss 0.142316 | Val Loss 0.404598
# Epoch 600 | Train Loss 0.140956 | Val Loss 0.406388
# Early stopping at epoch 678
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9942, MSE = 6.2765e-04
# X | Train_2 -> R² = 0.9928, MSE = 6.0986e-04
# X | Test_1 -> R² = 0.9376, MSE = 6.5063e-03
# X | Test_2 -> R² = 0.0477, MSE = 7.8237e-02
# X | Test_3 -> R² = -1.2147, MSE = 2.0313e-01
# X | Val -> R² = -0.5755, MSE = 1.5013e-01
# X | LSG_1 -> R² = 0.2456, MSE = 7.7022e-02
# X | LSG_2 -> R² = -0.2929, MSE = 1.1446e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.437661 | Val Loss 0.681751
# Epoch 100 | Train Loss 0.160696 | Val Loss 0.442773
# Epoch 200 | Train Loss 0.155201 | Val Loss 0.436407
# Epoch 300 | Train Loss 0.152248 | Val Loss 0.431477
# Epoch 400 | Train Loss 0.149252 | Val Loss 0.424459
# Epoch 500 | Train Loss 0.145431 | Val Loss 0.414895
# Epoch 600 | Train Loss 0.141408 | Val Loss 0.407009
# Epoch 700 | Train Loss 0.139778 | Val Loss 0.406595
# Epoch 800 | Train Loss 0.139077 | Val Loss 0.408625
# Early stopping at epoch 831
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9948, MSE = 5.5400e-04
# X | Train_2 -> R² = 0.9946, MSE = 4.5092e-04
# X | Test_1 -> R² = 0.9827, MSE = 1.8067e-03
# X | Test_2 -> R² = 0.6490, MSE = 2.8834e-02
# X | Test_3 -> R² = -1.5552, MSE = 2.3437e-01
# X | Val -> R² = -0.2700, MSE = 1.2102e-01
# X | LSG_1 -> R² = 0.5741, MSE = 4.3483e-02
# X | LSG_2 -> R² = -0.1265, MSE = 9.9727e-02
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.593915 | Val Loss 0.722297
# Epoch 100 | Train Loss 0.304774 | Val Loss 0.439666
# Epoch 200 | Train Loss 0.298225 | Val Loss 0.439751
# Epoch 300 | Train Loss 0.295185 | Val Loss 0.431294
# Epoch 400 | Train Loss 0.291382 | Val Loss 0.414826
# Epoch 500 | Train Loss 0.286250 | Val Loss 0.400891
# Epoch 600 | Train Loss 0.283438 | Val Loss 0.396919
# Epoch 700 | Train Loss 0.282441 | Val Loss 0.397077
# Early stopping at epoch 759
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9958, MSE = 4.5271e-04
# X | Train_2 -> R² = 0.9948, MSE = 4.4080e-04
# X | Test_1 -> R² = 0.9357, MSE = 6.7076e-03
# X | Test_2 -> R² = -0.0296, MSE = 8.4588e-02
# X | Test_3 -> R² = -2.0133, MSE = 2.7638e-01
# X | Val -> R² = -1.1913, MSE = 2.0880e-01
# X | LSG_1 -> R² = -0.0897, MSE = 1.1125e-01
# X | LSG_2 -> R² = -0.4436, MSE = 1.2780e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.523572 | Val Loss 0.659652
# Epoch 100 | Train Loss 0.305598 | Val Loss 0.441586
# Epoch 200 | Train Loss 0.296523 | Val Loss 0.434881
# Epoch 300 | Train Loss 0.292903 | Val Loss 0.436950
# Early stopping at epoch 362
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9863, MSE = 1.4759e-03
# X | Train_2 -> R² = 0.9802, MSE = 1.6686e-03
# X | Test_1 -> R² = 0.7660, MSE = 2.4417e-02
# X | Test_2 -> R² = 0.0408, MSE = 7.8807e-02
# X | Test_3 -> R² = -7.9395, MSE = 8.1995e-01
# X | Val -> R² = -2.5854, MSE = 3.4164e-01
# X | LSG_1 -> R² = -0.6739, MSE = 1.7089e-01
# X | LSG_2 -> R² = -1.0076, MSE = 1.7773e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.571974 | Val Loss 0.713625
# Epoch 100 | Train Loss 0.305064 | Val Loss 0.438106
# Epoch 200 | Train Loss 0.296973 | Val Loss 0.433809
# Epoch 300 | Train Loss 0.293881 | Val Loss 0.430413
# Epoch 400 | Train Loss 0.291210 | Val Loss 0.428263
# Epoch 500 | Train Loss 0.287624 | Val Loss 0.422762
# Epoch 600 | Train Loss 0.282951 | Val Loss 0.412598
# Epoch 700 | Train Loss 0.281007 | Val Loss 0.408636
# Epoch 800 | Train Loss 0.280087 | Val Loss 0.407826
# Epoch 900 | Train Loss 0.279377 | Val Loss 0.407777
# Early stopping at epoch 908
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9805, MSE = 2.0944e-03
# X | Train_2 -> R² = 0.9949, MSE = 4.2585e-04
# X | Test_1 -> R² = 0.8930, MSE = 1.1161e-02
# X | Test_2 -> R² = 0.3426, MSE = 5.4012e-02
# X | Test_3 -> R² = -0.8683, MSE = 1.7136e-01
# X | Val -> R² = -0.6238, MSE = 1.5472e-01
# X | LSG_1 -> R² = 0.6509, MSE = 3.5639e-02
# X | LSG_2 -> R² = -0.2481, MSE = 1.1049e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.596979 | Val Loss 0.734910
# Epoch 100 | Train Loss 0.305148 | Val Loss 0.434127
# Epoch 200 | Train Loss 0.296277 | Val Loss 0.431365
# Epoch 300 | Train Loss 0.292403 | Val Loss 0.422937
# Epoch 400 | Train Loss 0.287969 | Val Loss 0.413597
# Epoch 500 | Train Loss 0.284278 | Val Loss 0.404833
# Epoch 600 | Train Loss 0.282434 | Val Loss 0.398824
# Epoch 700 | Train Loss 0.281137 | Val Loss 0.397547
# Epoch 800 | Train Loss 0.279926 | Val Loss 0.398800
# Early stopping at epoch 821
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed7182.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed7182.weights.h5
# X | Train_1 -> R² = 0.9930, MSE = 7.5095e-04
# X | Train_2 -> R² = 0.9957, MSE = 3.5862e-04
# X | Test_1 -> R² = 0.9840, MSE = 1.6675e-03
# X | Test_2 -> R² = 0.3383, MSE = 5.4367e-02
# X | Test_3 -> R² = -0.7209, MSE = 1.5785e-01
# X | Val -> R² = -0.9428, MSE = 1.8512e-01
# X | LSG_1 -> R² = 0.6247, MSE = 3.8312e-02
# X | LSG_2 -> R² = 0.1263, MSE = 7.7346e-02
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.552142 | Val Loss 0.648985
# Epoch 100 | Train Loss 0.305877 | Val Loss 0.439698
# Epoch 200 | Train Loss 0.297340 | Val Loss 0.434799
# Epoch 300 | Train Loss 0.293627 | Val Loss 0.426573
# Epoch 400 | Train Loss 0.289675 | Val Loss 0.413700
# Epoch 500 | Train Loss 0.285606 | Val Loss 0.405001
# Epoch 600 | Train Loss 0.282981 | Val Loss 0.402344
# Epoch 700 | Train Loss 0.281550 | Val Loss 0.403737
# Early stopping at epoch 787
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9940, MSE = 6.4832e-04
# X | Train_2 -> R² = 0.9974, MSE = 2.1916e-04
# X | Test_1 -> R² = 0.9690, MSE = 3.2387e-03
# X | Test_2 -> R² = 0.3867, MSE = 5.0385e-02
# X | Test_3 -> R² = -0.8151, MSE = 1.6649e-01
# X | Val -> R² = -0.5926, MSE = 1.5176e-01
# X | LSG_1 -> R² = 0.4639, MSE = 5.4727e-02
# X | LSG_2 -> R² = 0.1207, MSE = 7.7844e-02
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.575665 | Val Loss 0.694583
# Epoch 100 | Train Loss 0.303967 | Val Loss 0.442881
# Epoch 200 | Train Loss 0.295751 | Val Loss 0.433779
# Epoch 300 | Train Loss 0.292910 | Val Loss 0.423934
# Epoch 400 | Train Loss 0.290052 | Val Loss 0.414419
# Epoch 500 | Train Loss 0.286193 | Val Loss 0.406882
# Epoch 600 | Train Loss 0.283664 | Val Loss 0.404314
# Epoch 700 | Train Loss 0.282316 | Val Loss 0.403658
# Epoch 800 | Train Loss 0.281229 | Val Loss 0.403257
# Epoch 900 | Train Loss 0.280362 | Val Loss 0.402642
# Epoch 1000 | Train Loss 0.279683 | Val Loss 0.402157
# Early stopping at epoch 1100
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9838, MSE = 1.7443e-03
# X | Train_2 -> R² = 0.9939, MSE = 5.1407e-04
# X | Test_1 -> R² = 0.9677, MSE = 3.3726e-03
# X | Test_2 -> R² = 0.3602, MSE = 5.2562e-02
# X | Test_3 -> R² = -1.4889, MSE = 2.2829e-01
# X | Val -> R² = -0.6444, MSE = 1.5668e-01
# X | LSG_1 -> R² = 0.6094, MSE = 3.9876e-02
# X | LSG_2 -> R² = -0.3126, MSE = 1.1620e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.513038 | Val Loss 0.632993
# Epoch 100 | Train Loss 0.299643 | Val Loss 0.443665
# Epoch 200 | Train Loss 0.294549 | Val Loss 0.433263
# Epoch 300 | Train Loss 0.290873 | Val Loss 0.425235
# Epoch 400 | Train Loss 0.284416 | Val Loss 0.412936
# Epoch 500 | Train Loss 0.281716 | Val Loss 0.414201
# Early stopping at epoch 596
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9932, MSE = 7.3510e-04
# X | Train_2 -> R² = 0.9900, MSE = 8.4178e-04
# X | Test_1 -> R² = 0.9892, MSE = 1.1249e-03
# X | Test_2 -> R² = 0.5214, MSE = 3.9323e-02
# X | Test_3 -> R² = -0.6561, MSE = 1.5190e-01
# X | Val -> R² = -0.0062, MSE = 9.5877e-02
# X | LSG_1 -> R² = -0.1395, MSE = 1.1634e-01
# X | LSG_2 -> R² = -0.8853, MSE = 1.6690e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.598021 | Val Loss 0.704558
# Epoch 100 | Train Loss 0.313941 | Val Loss 0.445629
# Epoch 200 | Train Loss 0.299049 | Val Loss 0.434479
# Epoch 300 | Train Loss 0.295039 | Val Loss 0.427413
# Epoch 400 | Train Loss 0.291833 | Val Loss 0.423910
# Epoch 500 | Train Loss 0.288680 | Val Loss 0.425211
# Early stopping at epoch 588
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9841, MSE = 1.7069e-03
# X | Train_2 -> R² = 0.9923, MSE = 6.4694e-04
# X | Test_1 -> R² = 0.9610, MSE = 4.0667e-03
# X | Test_2 -> R² = 0.3737, MSE = 5.1452e-02
# X | Test_3 -> R² = -5.3409, MSE = 5.8160e-01
# X | Val -> R² = -2.4038, MSE = 3.2433e-01
# X | LSG_1 -> R² = 0.4923, MSE = 5.1833e-02
# X | LSG_2 -> R² = -0.2538, MSE = 1.1100e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.602986 | Val Loss 0.733405
# Epoch 100 | Train Loss 0.302070 | Val Loss 0.438875
# Epoch 200 | Train Loss 0.296842 | Val Loss 0.438043
# Epoch 300 | Train Loss 0.294101 | Val Loss 0.434610
# Epoch 400 | Train Loss 0.291094 | Val Loss 0.423103
# Epoch 500 | Train Loss 0.286138 | Val Loss 0.405248
# Epoch 600 | Train Loss 0.282746 | Val Loss 0.399055
# Epoch 700 | Train Loss 0.281535 | Val Loss 0.400116
# Early stopping at epoch 767
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed7182.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed7182.weights.h5
# X | Train_1 -> R² = 0.9934, MSE = 7.1071e-04
# X | Train_2 -> R² = 0.9953, MSE = 3.9745e-04
# X | Test_1 -> R² = 0.9829, MSE = 1.7852e-03
# X | Test_2 -> R² = 0.3993, MSE = 4.9349e-02
# X | Test_3 -> R² = -1.9172, MSE = 2.6757e-01
# X | Val -> R² = -1.0552, MSE = 1.9583e-01
# X | LSG_1 -> R² = 0.3787, MSE = 6.3431e-02
# X | LSG_2 -> R² = -0.0360, MSE = 9.1715e-02
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.573285 | Val Loss 0.705764
# Epoch 100 | Train Loss 0.301490 | Val Loss 0.437666
# Epoch 200 | Train Loss 0.295924 | Val Loss 0.436421
# Epoch 300 | Train Loss 0.292951 | Val Loss 0.432303
# Epoch 400 | Train Loss 0.289579 | Val Loss 0.421724
# Epoch 500 | Train Loss 0.285320 | Val Loss 0.410146
# Epoch 600 | Train Loss 0.282853 | Val Loss 0.404839
# Epoch 700 | Train Loss 0.281501 | Val Loss 0.404118
# Epoch 800 | Train Loss 0.280595 | Val Loss 0.405765
# Early stopping at epoch 836
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9828, MSE = 1.8441e-03
# X | Train_2 -> R² = 0.9946, MSE = 4.5366e-04
# X | Test_1 -> R² = 0.9014, MSE = 1.0292e-02
# X | Test_2 -> R² = 0.6936, MSE = 2.5172e-02
# X | Test_3 -> R² = -1.4284, MSE = 2.2274e-01
# X | Val -> R² = -2.2107, MSE = 3.0593e-01
# X | LSG_1 -> R² = 0.6475, MSE = 3.5991e-02
# X | LSG_2 -> R² = -0.0850, MSE = 9.6052e-02
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.391543 | Val Loss 0.635322
# Epoch 100 | Train Loss 0.154858 | Val Loss 0.430948
# Epoch 200 | Train Loss 0.150384 | Val Loss 0.425702
# Epoch 300 | Train Loss 0.144009 | Val Loss 0.411811
# Epoch 400 | Train Loss 0.140895 | Val Loss 0.403123
# Epoch 500 | Train Loss 0.139959 | Val Loss 0.404853
# Early stopping at epoch 582
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9960, MSE = 4.3392e-04
# X | Train_2 -> R² = 0.9966, MSE = 2.8721e-04
# X | Test_1 -> R² = 0.9184, MSE = 8.5130e-03
# X | Test_2 -> R² = 0.3240, MSE = 5.5537e-02
# X | Test_3 -> R² = -1.7534, MSE = 2.5255e-01
# X | Val -> R² = -0.7739, MSE = 1.6903e-01
# X | LSG_1 -> R² = 0.0897, MSE = 9.2930e-02
# X | LSG_2 -> R² = -0.1274, MSE = 9.9811e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.402773 | Val Loss 0.662714
# Epoch 100 | Train Loss 0.155548 | Val Loss 0.425903
# Epoch 200 | Train Loss 0.150486 | Val Loss 0.417306
# Epoch 300 | Train Loss 0.143564 | Val Loss 0.405414
# Epoch 400 | Train Loss 0.140588 | Val Loss 0.405312
# Epoch 500 | Train Loss 0.139489 | Val Loss 0.412655
# Early stopping at epoch 525
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.8087e-04
# X | Train_2 -> R² = 0.9962, MSE = 3.2191e-04
# X | Test_1 -> R² = 0.9672, MSE = 3.4209e-03
# X | Test_2 -> R² = -0.1344, MSE = 9.3201e-02
# X | Test_3 -> R² = -0.8925, MSE = 1.7358e-01
# X | Val -> R² = -0.2966, MSE = 1.2354e-01
# X | LSG_1 -> R² = 0.2583, MSE = 7.5717e-02
# X | LSG_2 -> R² = -0.3453, MSE = 1.1910e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.396032 | Val Loss 0.672242
# Epoch 100 | Train Loss 0.154764 | Val Loss 0.434254
# Epoch 200 | Train Loss 0.150576 | Val Loss 0.431088
# Epoch 300 | Train Loss 0.144865 | Val Loss 0.419413
# Epoch 400 | Train Loss 0.140768 | Val Loss 0.411120
# Epoch 500 | Train Loss 0.139616 | Val Loss 0.412997
# Early stopping at epoch 566
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9951, MSE = 5.3042e-04
# X | Train_2 -> R² = 0.9962, MSE = 3.2314e-04
# X | Test_1 -> R² = 0.9646, MSE = 3.6931e-03
# X | Test_2 -> R² = 0.1546, MSE = 6.9459e-02
# X | Test_3 -> R² = -1.6654, MSE = 2.4448e-01
# X | Val -> R² = -0.5101, MSE = 1.4389e-01
# X | LSG_1 -> R² = 0.0885, MSE = 9.3050e-02
# X | LSG_2 -> R² = -0.1796, MSE = 1.0443e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.394976 | Val Loss 0.642195
# Epoch 100 | Train Loss 0.155504 | Val Loss 0.431849
# Epoch 200 | Train Loss 0.150791 | Val Loss 0.427049
# Epoch 300 | Train Loss 0.143586 | Val Loss 0.412140
# Epoch 400 | Train Loss 0.140628 | Val Loss 0.410025
# Epoch 500 | Train Loss 0.139654 | Val Loss 0.413057
# Early stopping at epoch 532
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9925, MSE = 8.0994e-04
# X | Train_2 -> R² = 0.9967, MSE = 2.7664e-04
# X | Test_1 -> R² = 0.9797, MSE = 2.1140e-03
# X | Test_2 -> R² = 0.1655, MSE = 6.8558e-02
# X | Test_3 -> R² = -1.7457, MSE = 2.5184e-01
# X | Val -> R² = -1.2854, MSE = 2.1777e-01
# X | LSG_1 -> R² = 0.3579, MSE = 6.5555e-02
# X | LSG_2 -> R² = -0.0368, MSE = 9.1787e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.383785 | Val Loss 0.630237
# Epoch 100 | Train Loss 0.154209 | Val Loss 0.434536
# Epoch 200 | Train Loss 0.149107 | Val Loss 0.426112
# Epoch 300 | Train Loss 0.142749 | Val Loss 0.411416
# Epoch 400 | Train Loss 0.139945 | Val Loss 0.405705
# Epoch 500 | Train Loss 0.139024 | Val Loss 0.406853
# Early stopping at epoch 585
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9939, MSE = 6.5772e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3819e-04
# X | Test_1 -> R² = 0.9750, MSE = 2.6115e-03
# X | Test_2 -> R² = 0.6303, MSE = 3.0376e-02
# X | Test_3 -> R² = -1.8652, MSE = 2.6280e-01
# X | Val -> R² = -1.3852, MSE = 2.2727e-01
# X | LSG_1 -> R² = 0.6040, MSE = 4.0426e-02
# X | LSG_2 -> R² = 0.4386, MSE = 4.9701e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.445022 | Val Loss 0.706074
# Epoch 100 | Train Loss 0.154558 | Val Loss 0.430650
# Epoch 200 | Train Loss 0.150033 | Val Loss 0.420968
# Epoch 300 | Train Loss 0.144381 | Val Loss 0.406584
# Epoch 400 | Train Loss 0.141163 | Val Loss 0.400666
# Epoch 500 | Train Loss 0.140096 | Val Loss 0.402059
# Early stopping at epoch 561
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9948, MSE = 5.5691e-04
# X | Train_2 -> R² = 0.9970, MSE = 2.5014e-04
# X | Test_1 -> R² = 0.9418, MSE = 6.0704e-03
# X | Test_2 -> R² = -0.2044, MSE = 9.8955e-02
# X | Test_3 -> R² = -2.2687, MSE = 2.9981e-01
# X | Val -> R² = -1.0262, MSE = 1.9306e-01
# X | LSG_1 -> R² = -0.0041, MSE = 1.0251e-01
# X | LSG_2 -> R² = -0.4545, MSE = 1.2877e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.417791 | Val Loss 0.692043
# Epoch 100 | Train Loss 0.154292 | Val Loss 0.432583
# Epoch 200 | Train Loss 0.148971 | Val Loss 0.426660
# Epoch 300 | Train Loss 0.142391 | Val Loss 0.417805
# Epoch 400 | Train Loss 0.140405 | Val Loss 0.406100
# Epoch 500 | Train Loss 0.139629 | Val Loss 0.405529
# Epoch 600 | Train Loss 0.138961 | Val Loss 0.408155
# Early stopping at epoch 618
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9967, MSE = 3.4961e-04
# X | Train_2 -> R² = 0.9968, MSE = 2.7221e-04
# X | Test_1 -> R² = 0.9472, MSE = 5.5108e-03
# X | Test_2 -> R² = 0.7738, MSE = 1.8583e-02
# X | Test_3 -> R² = -1.4947, MSE = 2.2882e-01
# X | Val -> R² = -0.4075, MSE = 1.3412e-01
# X | LSG_1 -> R² = 0.6666, MSE = 3.4035e-02
# X | LSG_2 -> R² = 0.3266, MSE = 5.9613e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.424499 | Val Loss 0.712246
# Epoch 100 | Train Loss 0.154620 | Val Loss 0.433803
# Epoch 200 | Train Loss 0.150314 | Val Loss 0.430103
# Epoch 300 | Train Loss 0.143361 | Val Loss 0.418397
# Epoch 400 | Train Loss 0.140398 | Val Loss 0.408984
# Epoch 500 | Train Loss 0.139487 | Val Loss 0.408755
# Epoch 600 | Train Loss 0.138867 | Val Loss 0.410791
# Early stopping at epoch 606
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9961, MSE = 4.2397e-04
# X | Train_2 -> R² = 0.9974, MSE = 2.1641e-04
# X | Test_1 -> R² = 0.9519, MSE = 5.0219e-03
# X | Test_2 -> R² = 0.1536, MSE = 6.9538e-02
# X | Test_3 -> R² = -1.3573, MSE = 2.1622e-01
# X | Val -> R² = -0.5802, MSE = 1.5057e-01
# X | LSG_1 -> R² = 0.0853, MSE = 9.3378e-02
# X | LSG_2 -> R² = -0.1717, MSE = 1.0373e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.445974 | Val Loss 0.699465
# Epoch 100 | Train Loss 0.158428 | Val Loss 0.438359
# Epoch 200 | Train Loss 0.152486 | Val Loss 0.428067
# Epoch 300 | Train Loss 0.146882 | Val Loss 0.415475
# Epoch 400 | Train Loss 0.140967 | Val Loss 0.406055
# Epoch 500 | Train Loss 0.139543 | Val Loss 0.407245
# Early stopping at epoch 572
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9932, MSE = 7.3535e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3850e-04
# X | Test_1 -> R² = 0.9768, MSE = 2.4199e-03
# X | Test_2 -> R² = 0.0459, MSE = 7.8386e-02
# X | Test_3 -> R² = -1.7095, MSE = 2.4852e-01
# X | Val -> R² = -0.8866, MSE = 1.7977e-01
# X | LSG_1 -> R² = 0.3376, MSE = 6.7622e-02
# X | LSG_2 -> R² = -0.3055, MSE = 1.1558e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.372793 | Val Loss 0.620398
# Epoch 100 | Train Loss 0.154089 | Val Loss 0.429523
# Epoch 200 | Train Loss 0.149756 | Val Loss 0.423287
# Epoch 300 | Train Loss 0.143863 | Val Loss 0.412369
# Epoch 400 | Train Loss 0.140137 | Val Loss 0.408324
# Epoch 500 | Train Loss 0.139206 | Val Loss 0.412692
# Early stopping at epoch 540
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9944, MSE = 5.9865e-04
# X | Train_2 -> R² = 0.9943, MSE = 4.8338e-04
# X | Test_1 -> R² = 0.9663, MSE = 3.5206e-03
# X | Test_2 -> R² = 0.3687, MSE = 5.1869e-02
# X | Test_3 -> R² = -1.9115, MSE = 2.6705e-01
# X | Val -> R² = -0.7911, MSE = 1.7066e-01
# X | LSG_1 -> R² = 0.6062, MSE = 4.0205e-02
# X | LSG_2 -> R² = 0.1209, MSE = 7.7828e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.600394 | Val Loss 0.629983
# Epoch 100 | Train Loss 0.299239 | Val Loss 0.436246
# Epoch 200 | Train Loss 0.294855 | Val Loss 0.427839
# Epoch 300 | Train Loss 0.290174 | Val Loss 0.411097
# Epoch 400 | Train Loss 0.284147 | Val Loss 0.396802
# Epoch 500 | Train Loss 0.282443 | Val Loss 0.399074
# Epoch 600 | Train Loss 0.281559 | Val Loss 0.404100
# Early stopping at epoch 605
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9932, MSE = 7.3383e-04
# X | Train_2 -> R² = 0.9967, MSE = 2.7505e-04
# X | Test_1 -> R² = 0.9605, MSE = 4.1243e-03
# X | Test_2 -> R² = -0.4320, MSE = 1.1765e-01
# X | Test_3 -> R² = -2.3688, MSE = 3.0899e-01
# X | Val -> R² = -1.9511, MSE = 2.8119e-01
# X | LSG_1 -> R² = -0.0504, MSE = 1.0724e-01
# X | LSG_2 -> R² = -0.7059, MSE = 1.5102e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.497143 | Val Loss 0.618715
# Epoch 100 | Train Loss 0.297935 | Val Loss 0.430317
# Epoch 200 | Train Loss 0.293323 | Val Loss 0.425112
# Epoch 300 | Train Loss 0.289038 | Val Loss 0.418085
# Epoch 400 | Train Loss 0.283235 | Val Loss 0.407640
# Epoch 500 | Train Loss 0.281003 | Val Loss 0.405958
# Epoch 600 | Train Loss 0.279607 | Val Loss 0.409687
# Early stopping at epoch 634
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9725, MSE = 2.9534e-03
# X | Train_2 -> R² = 0.9936, MSE = 5.4128e-04
# X | Test_1 -> R² = 0.9213, MSE = 8.2160e-03
# X | Test_2 -> R² = 0.6847, MSE = 2.5908e-02
# X | Test_3 -> R² = -0.5893, MSE = 1.4578e-01
# X | Val -> R² = -1.4825, MSE = 2.3654e-01
# X | LSG_1 -> R² = 0.5119, MSE = 4.9835e-02
# X | LSG_2 -> R² = 0.1709, MSE = 7.3400e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.515238 | Val Loss 0.634633
# Epoch 100 | Train Loss 0.297925 | Val Loss 0.434010
# Epoch 200 | Train Loss 0.292941 | Val Loss 0.424072
# Epoch 300 | Train Loss 0.285801 | Val Loss 0.405491
# Epoch 400 | Train Loss 0.282188 | Val Loss 0.402121
# Epoch 500 | Train Loss 0.280601 | Val Loss 0.403151
# Early stopping at epoch 536
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9919, MSE = 8.7168e-04
# X | Train_2 -> R² = 0.9957, MSE = 3.6306e-04
# X | Test_1 -> R² = 0.9700, MSE = 3.1349e-03
# X | Test_2 -> R² = 0.1645, MSE = 6.8646e-02
# X | Test_3 -> R² = -0.8812, MSE = 1.7255e-01
# X | Val -> R² = -0.9159, MSE = 1.8256e-01
# X | LSG_1 -> R² = 0.6008, MSE = 4.0754e-02
# X | LSG_2 -> R² = -0.0311, MSE = 9.1281e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.576426 | Val Loss 0.704025
# Epoch 100 | Train Loss 0.298658 | Val Loss 0.432602
# Epoch 200 | Train Loss 0.294324 | Val Loss 0.428436
# Epoch 300 | Train Loss 0.290899 | Val Loss 0.420377
# Epoch 400 | Train Loss 0.285014 | Val Loss 0.404321
# Epoch 500 | Train Loss 0.282005 | Val Loss 0.394701
# Epoch 600 | Train Loss 0.280478 | Val Loss 0.394372
# Early stopping at epoch 693
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed7182.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed7182.weights.h5
# X | Train_1 -> R² = 0.9934, MSE = 7.0363e-04
# X | Train_2 -> R² = 0.9958, MSE = 3.5049e-04
# X | Test_1 -> R² = 0.9840, MSE = 1.6706e-03
# X | Test_2 -> R² = 0.3533, MSE = 5.3130e-02
# X | Test_3 -> R² = -1.2691, MSE = 2.0813e-01
# X | Val -> R² = -0.9775, MSE = 1.8843e-01
# X | LSG_1 -> R² = 0.3654, MSE = 6.4782e-02
# X | LSG_2 -> R² = 0.0440, MSE = 8.4633e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.508027 | Val Loss 0.602911
# Epoch 100 | Train Loss 0.297243 | Val Loss 0.429092
# Epoch 200 | Train Loss 0.290934 | Val Loss 0.416434
# Epoch 300 | Train Loss 0.283678 | Val Loss 0.406190
# Epoch 400 | Train Loss 0.281647 | Val Loss 0.408320
# Early stopping at epoch 481
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9901, MSE = 1.0649e-03
# X | Train_2 -> R² = 0.9960, MSE = 3.4022e-04
# X | Test_1 -> R² = 0.9752, MSE = 2.5921e-03
# X | Test_2 -> R² = -0.4129, MSE = 1.1608e-01
# X | Test_3 -> R² = -1.6823, MSE = 2.4602e-01
# X | Val -> R² = -0.4872, MSE = 1.4171e-01
# X | LSG_1 -> R² = 0.3401, MSE = 6.7367e-02
# X | LSG_2 -> R² = -0.4304, MSE = 1.2663e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.516835 | Val Loss 0.609491
# Epoch 100 | Train Loss 0.296475 | Val Loss 0.429557
# Epoch 200 | Train Loss 0.292363 | Val Loss 0.424423
# Epoch 300 | Train Loss 0.287399 | Val Loss 0.416079
# Epoch 400 | Train Loss 0.283575 | Val Loss 0.406184
# Epoch 500 | Train Loss 0.281006 | Val Loss 0.403181
# Epoch 600 | Train Loss 0.278888 | Val Loss 0.405995
# Early stopping at epoch 637
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9793, MSE = 2.2270e-03
# X | Train_2 -> R² = 0.9936, MSE = 5.3473e-04
# X | Test_1 -> R² = 0.8719, MSE = 1.3370e-02
# X | Test_2 -> R² = 0.1639, MSE = 6.8691e-02
# X | Test_3 -> R² = -0.3194, MSE = 1.2102e-01
# X | Val -> R² = -0.7284, MSE = 1.6469e-01
# X | LSG_1 -> R² = 0.5881, MSE = 4.2049e-02
# X | LSG_2 -> R² = 0.0375, MSE = 8.5207e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.511371 | Val Loss 0.626145
# Epoch 100 | Train Loss 0.296155 | Val Loss 0.425436
# Epoch 200 | Train Loss 0.291232 | Val Loss 0.416642
# Epoch 300 | Train Loss 0.284953 | Val Loss 0.401907
# Epoch 400 | Train Loss 0.282373 | Val Loss 0.400319
# Epoch 500 | Train Loss 0.280963 | Val Loss 0.402522
# Early stopping at epoch 537
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9895, MSE = 1.1321e-03
# X | Train_2 -> R² = 0.9954, MSE = 3.8322e-04
# X | Test_1 -> R² = 0.9783, MSE = 2.2666e-03
# X | Test_2 -> R² = 0.0319, MSE = 7.9542e-02
# X | Test_3 -> R² = -1.5574, MSE = 2.3457e-01
# X | Val -> R² = -1.2255, MSE = 2.1206e-01
# X | LSG_1 -> R² = 0.2640, MSE = 7.5133e-02
# X | LSG_2 -> R² = -0.2478, MSE = 1.1047e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.535954 | Val Loss 0.652722
# Epoch 100 | Train Loss 0.298327 | Val Loss 0.434554
# Epoch 200 | Train Loss 0.294290 | Val Loss 0.432083
# Epoch 300 | Train Loss 0.289018 | Val Loss 0.421411
# Epoch 400 | Train Loss 0.283057 | Val Loss 0.407352
# Epoch 500 | Train Loss 0.281494 | Val Loss 0.409359
# Epoch 600 | Train Loss 0.280652 | Val Loss 0.413281
# Early stopping at epoch 609
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9895, MSE = 1.1275e-03
# X | Train_2 -> R² = 0.9958, MSE = 3.5476e-04
# X | Test_1 -> R² = 0.9844, MSE = 1.6240e-03
# X | Test_2 -> R² = -0.1739, MSE = 9.6448e-02
# X | Test_3 -> R² = -2.0797, MSE = 2.8247e-01
# X | Val -> R² = -0.8854, MSE = 1.7965e-01
# X | LSG_1 -> R² = 0.3223, MSE = 6.9187e-02
# X | LSG_2 -> R² = -0.2682, MSE = 1.1227e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.520038 | Val Loss 0.641862
# Epoch 100 | Train Loss 0.297110 | Val Loss 0.430305
# Epoch 200 | Train Loss 0.293089 | Val Loss 0.431645
# Early stopping at epoch 243
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed7182.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed7182.weights.h5
# X | Train_1 -> R² = 0.9742, MSE = 2.7674e-03
# X | Train_2 -> R² = 0.9332, MSE = 5.6176e-03
# X | Test_1 -> R² = 0.7728, MSE = 2.3703e-02
# X | Test_2 -> R² = 0.2457, MSE = 6.1976e-02
# X | Test_3 -> R² = -7.4340, MSE = 7.7358e-01
# X | Val -> R² = -3.6307, MSE = 4.4123e-01
# X | LSG_1 -> R² = -1.2290, MSE = 2.2756e-01
# X | LSG_2 -> R² = -1.4812, MSE = 2.1967e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.512664 | Val Loss 0.616071
# Epoch 100 | Train Loss 0.296819 | Val Loss 0.428565
# Epoch 200 | Train Loss 0.291267 | Val Loss 0.418222
# Epoch 300 | Train Loss 0.283308 | Val Loss 0.401906
# Epoch 400 | Train Loss 0.281724 | Val Loss 0.407125
# Early stopping at epoch 490
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9915, MSE = 9.1670e-04
# X | Train_2 -> R² = 0.9966, MSE = 2.8730e-04
# X | Test_1 -> R² = 0.9854, MSE = 1.5258e-03
# X | Test_2 -> R² = -0.0976, MSE = 9.0179e-02
# X | Test_3 -> R² = -1.3213, MSE = 2.1291e-01
# X | Val -> R² = -1.0354, MSE = 1.9394e-01
# X | LSG_1 -> R² = 0.4917, MSE = 5.1893e-02
# X | LSG_2 -> R² = -0.3502, MSE = 1.1953e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.415367 | Val Loss 0.613597
# Epoch 100 | Train Loss 0.153570 | Val Loss 0.431476
# Epoch 200 | Train Loss 0.150183 | Val Loss 0.424077
# Epoch 300 | Train Loss 0.144460 | Val Loss 0.409959
# Epoch 400 | Train Loss 0.140838 | Val Loss 0.405778
# Epoch 500 | Train Loss 0.139407 | Val Loss 0.408825
# Early stopping at epoch 550
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9937, MSE = 6.7755e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3418e-04
# X | Test_1 -> R² = 0.9743, MSE = 2.6820e-03
# X | Test_2 -> R² = 0.1919, MSE = 6.6392e-02
# X | Test_3 -> R² = -0.9343, MSE = 1.7741e-01
# X | Val -> R² = -0.4815, MSE = 1.4116e-01
# X | LSG_1 -> R² = 0.2685, MSE = 7.4678e-02
# X | LSG_2 -> R² = 0.0963, MSE = 8.0009e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.429159 | Val Loss 0.679252
# Epoch 100 | Train Loss 0.152775 | Val Loss 0.426859
# Epoch 200 | Train Loss 0.147778 | Val Loss 0.422855
# Epoch 300 | Train Loss 0.141116 | Val Loss 0.408210
# Epoch 400 | Train Loss 0.139465 | Val Loss 0.408893
# Epoch 500 | Train Loss 0.138532 | Val Loss 0.414316
# Early stopping at epoch 521
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9955, MSE = 4.8103e-04
# X | Train_2 -> R² = 0.9965, MSE = 2.9316e-04
# X | Test_1 -> R² = 0.9513, MSE = 5.0782e-03
# X | Test_2 -> R² = 0.3968, MSE = 4.9556e-02
# X | Test_3 -> R² = -1.3600, MSE = 2.1646e-01
# X | Val -> R² = -0.8506, MSE = 1.7634e-01
# X | LSG_1 -> R² = 0.4322, MSE = 5.7971e-02
# X | LSG_2 -> R² = 0.1011, MSE = 7.9576e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.390148 | Val Loss 0.610619
# Epoch 100 | Train Loss 0.152753 | Val Loss 0.426313
# Epoch 200 | Train Loss 0.145496 | Val Loss 0.416208
# Epoch 300 | Train Loss 0.140364 | Val Loss 0.403854
# Epoch 400 | Train Loss 0.138850 | Val Loss 0.407627
# Early stopping at epoch 467
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9932, MSE = 7.2553e-04
# X | Train_2 -> R² = 0.9962, MSE = 3.2333e-04
# X | Test_1 -> R² = 0.9810, MSE = 1.9825e-03
# X | Test_2 -> R² = 0.0266, MSE = 7.9977e-02
# X | Test_3 -> R² = -1.1044, MSE = 1.9301e-01
# X | Val -> R² = -0.9674, MSE = 1.8746e-01
# X | LSG_1 -> R² = 0.3283, MSE = 6.8572e-02
# X | LSG_2 -> R² = -0.1108, MSE = 9.8339e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.375735 | Val Loss 0.564253
# Epoch 100 | Train Loss 0.153416 | Val Loss 0.430214
# Epoch 200 | Train Loss 0.148095 | Val Loss 0.423714
# Epoch 300 | Train Loss 0.142080 | Val Loss 0.410697
# Epoch 400 | Train Loss 0.139927 | Val Loss 0.409143
# Epoch 500 | Train Loss 0.138985 | Val Loss 0.412399
# Early stopping at epoch 540
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.7465e-04
# X | Train_2 -> R² = 0.9963, MSE = 3.0749e-04
# X | Test_1 -> R² = 0.9704, MSE = 3.0920e-03
# X | Test_2 -> R² = 0.1624, MSE = 6.8820e-02
# X | Test_3 -> R² = -1.7107, MSE = 2.4863e-01
# X | Val -> R² = -1.0028, MSE = 1.9084e-01
# X | LSG_1 -> R² = 0.2122, MSE = 8.0427e-02
# X | LSG_2 -> R² = -0.0273, MSE = 9.0944e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.360858 | Val Loss 0.573061
# Epoch 100 | Train Loss 0.153036 | Val Loss 0.428219
# Epoch 200 | Train Loss 0.146753 | Val Loss 0.419195
# Epoch 300 | Train Loss 0.140234 | Val Loss 0.405200
# Epoch 400 | Train Loss 0.138471 | Val Loss 0.409452
# Early stopping at epoch 476
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9887, MSE = 1.2155e-03
# X | Train_2 -> R² = 0.9960, MSE = 3.4038e-04
# X | Test_1 -> R² = 0.9846, MSE = 1.6035e-03
# X | Test_2 -> R² = 0.2636, MSE = 6.0502e-02
# X | Test_3 -> R² = -1.1253, MSE = 1.9493e-01
# X | Val -> R² = -1.2161, MSE = 2.1117e-01
# X | LSG_1 -> R² = 0.5553, MSE = 4.5401e-02
# X | LSG_2 -> R² = -0.0170, MSE = 9.0037e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.570573 | Val Loss 0.697921
# Epoch 100 | Train Loss 0.154876 | Val Loss 0.429495
# Epoch 200 | Train Loss 0.150783 | Val Loss 0.424595
# Epoch 300 | Train Loss 0.145352 | Val Loss 0.413483
# Epoch 400 | Train Loss 0.141903 | Val Loss 0.404983
# Epoch 500 | Train Loss 0.140149 | Val Loss 0.406436
# Early stopping at epoch 595
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.7790e-04
# X | Train_2 -> R² = 0.9971, MSE = 2.4563e-04
# X | Test_1 -> R² = 0.9734, MSE = 2.7747e-03
# X | Test_2 -> R² = -0.0891, MSE = 8.9477e-02
# X | Test_3 -> R² = -0.9040, MSE = 1.7464e-01
# X | Val -> R² = -0.6537, MSE = 1.5757e-01
# X | LSG_1 -> R² = -0.0458, MSE = 1.0676e-01
# X | LSG_2 -> R² = -0.3340, MSE = 1.1810e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.375744 | Val Loss 0.592022
# Epoch 100 | Train Loss 0.152822 | Val Loss 0.426599
# Epoch 200 | Train Loss 0.146886 | Val Loss 0.425276
# Epoch 300 | Train Loss 0.140836 | Val Loss 0.410524
# Epoch 400 | Train Loss 0.138990 | Val Loss 0.411606
# Epoch 500 | Train Loss 0.138054 | Val Loss 0.416991
# Early stopping at epoch 529
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9919, MSE = 8.6828e-04
# X | Train_2 -> R² = 0.9969, MSE = 2.6452e-04
# X | Test_1 -> R² = 0.9768, MSE = 2.4184e-03
# X | Test_2 -> R² = 0.2198, MSE = 6.4097e-02
# X | Test_3 -> R² = -1.3989, MSE = 2.2003e-01
# X | Val -> R² = -1.2756, MSE = 2.1683e-01
# X | LSG_1 -> R² = 0.5235, MSE = 4.8648e-02
# X | LSG_2 -> R² = -0.0175, MSE = 9.0082e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.386786 | Val Loss 0.625255
# Epoch 100 | Train Loss 0.152883 | Val Loss 0.428932
# Epoch 200 | Train Loss 0.148138 | Val Loss 0.432152
# Early stopping at epoch 251
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9881, MSE = 1.2811e-03
# X | Train_2 -> R² = 0.9588, MSE = 3.4665e-03
# X | Test_1 -> R² = 0.8793, MSE = 1.2591e-02
# X | Test_2 -> R² = -0.5922, MSE = 1.3081e-01
# X | Test_3 -> R² = -5.6424, MSE = 6.0925e-01
# X | Val -> R² = -1.8850, MSE = 2.7489e-01
# X | LSG_1 -> R² = -0.9014, MSE = 1.9411e-01
# X | LSG_2 -> R² = -1.6652, MSE = 2.3596e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.411146 | Val Loss 0.665181
# Epoch 100 | Train Loss 0.153518 | Val Loss 0.426986
# Epoch 200 | Train Loss 0.149250 | Val Loss 0.424064
# Epoch 300 | Train Loss 0.142534 | Val Loss 0.413843
# Epoch 400 | Train Loss 0.139778 | Val Loss 0.409105
# Epoch 500 | Train Loss 0.138551 | Val Loss 0.411961
# Early stopping at epoch 548
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9901, MSE = 1.0631e-03
# X | Train_2 -> R² = 0.9954, MSE = 3.8651e-04
# X | Test_1 -> R² = 0.9826, MSE = 1.8116e-03
# X | Test_2 -> R² = 0.3321, MSE = 5.4871e-02
# X | Test_3 -> R² = -0.9160, MSE = 1.7574e-01
# X | Val -> R² = -0.6236, MSE = 1.5471e-01
# X | LSG_1 -> R² = 0.4739, MSE = 5.3708e-02
# X | LSG_2 -> R² = 0.0156, MSE = 8.7147e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.305959 | Val Loss 0.499966
# Epoch 100 | Train Loss 0.152422 | Val Loss 0.428645
# Epoch 200 | Train Loss 0.144049 | Val Loss 0.417831
# Epoch 300 | Train Loss 0.139976 | Val Loss 0.413103
# Epoch 400 | Train Loss 0.138445 | Val Loss 0.415062
# Early stopping at epoch 493
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9910, MSE = 9.6327e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.4039e-04
# X | Test_1 -> R² = 0.9792, MSE = 2.1692e-03
# X | Test_2 -> R² = 0.5888, MSE = 3.3782e-02
# X | Test_3 -> R² = -0.3338, MSE = 1.2234e-01
# X | Val -> R² = -0.3157, MSE = 1.2536e-01
# X | LSG_1 -> R² = 0.6850, MSE = 3.2153e-02
# X | LSG_2 -> R² = 0.2386, MSE = 6.7407e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.922620 | Val Loss 0.766251
# Epoch 100 | Train Loss 0.297587 | Val Loss 0.430491
# Epoch 200 | Train Loss 0.293048 | Val Loss 0.425717
# Epoch 300 | Train Loss 0.288122 | Val Loss 0.414193
# Epoch 400 | Train Loss 0.283811 | Val Loss 0.405483
# Epoch 500 | Train Loss 0.282249 | Val Loss 0.406779
# Epoch 600 | Train Loss 0.281436 | Val Loss 0.409035
# Early stopping at epoch 607
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9927, MSE = 7.8389e-04
# X | Train_2 -> R² = 0.9961, MSE = 3.2589e-04
# X | Test_1 -> R² = 0.9808, MSE = 2.0061e-03
# X | Test_2 -> R² = -0.6439, MSE = 1.3506e-01
# X | Test_3 -> R² = -1.4275, MSE = 2.2265e-01
# X | Val -> R² = -0.9499, MSE = 1.8580e-01
# X | LSG_1 -> R² = -0.2499, MSE = 1.2760e-01
# X | LSG_2 -> R² = -0.7593, MSE = 1.5575e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.487700 | Val Loss 0.567772
# Epoch 100 | Train Loss 0.294112 | Val Loss 0.426787
# Epoch 200 | Train Loss 0.287121 | Val Loss 0.415087
# Epoch 300 | Train Loss 0.282284 | Val Loss 0.403382
# Epoch 400 | Train Loss 0.280308 | Val Loss 0.403800
# Epoch 500 | Train Loss 0.278855 | Val Loss 0.402425
# Epoch 600 | Train Loss 0.277589 | Val Loss 0.402031
# Epoch 700 | Train Loss 0.276266 | Val Loss 0.403014
# Early stopping at epoch 711
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9794, MSE = 2.2148e-03
# X | Train_2 -> R² = 0.9970, MSE = 2.5440e-04
# X | Test_1 -> R² = 0.9314, MSE = 7.1543e-03
# X | Test_2 -> R² = 0.5624, MSE = 3.5953e-02
# X | Test_3 -> R² = -1.2389, MSE = 2.0535e-01
# X | Val -> R² = -1.9289, MSE = 2.7908e-01
# X | LSG_1 -> R² = 0.7217, MSE = 2.8413e-02
# X | LSG_2 -> R² = 0.2061, MSE = 7.0289e-02
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.489937 | Val Loss 0.591404
# Epoch 100 | Train Loss 0.293288 | Val Loss 0.431607
# Epoch 200 | Train Loss 0.286908 | Val Loss 0.427025
# Epoch 300 | Train Loss 0.282354 | Val Loss 0.407863
# Epoch 400 | Train Loss 0.280098 | Val Loss 0.407987
# Epoch 500 | Train Loss 0.278029 | Val Loss 0.410807
# Early stopping at epoch 506
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9775, MSE = 2.4206e-03
# X | Train_2 -> R² = 0.9948, MSE = 4.4022e-04
# X | Test_1 -> R² = 0.9509, MSE = 5.1218e-03
# X | Test_2 -> R² = 0.0062, MSE = 8.1652e-02
# X | Test_3 -> R² = -1.0282, MSE = 1.8603e-01
# X | Val -> R² = -1.8150, MSE = 2.6823e-01
# X | LSG_1 -> R² = 0.5458, MSE = 4.6368e-02
# X | LSG_2 -> R² = -0.1544, MSE = 1.0220e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.501361 | Val Loss 0.577858
# Epoch 100 | Train Loss 0.294993 | Val Loss 0.430571
# ...
# Epoch 100 | Train Loss 0.287690 | Val Loss 0.417948
# Epoch 200 | Train Loss 0.280962 | Val Loss 0.416518
# Epoch 300 | Train Loss 0.278607 | Val Loss 0.423171
# Early stopping at epoch 315
# Modelo salvo em:
# models/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9820, MSE = 1.9379e-03
# X | Train_2 -> R² = 0.9505, MSE = 4.1690e-03
# X | Test_1 -> R² = 0.8286, MSE = 1.7888e-02
# X | Test_2 -> R² = -0.5900, MSE = 1.3064e-01
# X | Test_3 -> R² = -0.2004, MSE = 1.1010e-01
# X | Val -> R² = -0.2589, MSE = 1.1995e-01
# X | LSG_1 -> R² = 0.4615, MSE = 5.4975e-02
# X | LSG_2 -> R² = -0.3778, MSE = 1.2198e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.444132 | Val Loss 0.487668
# Epoch 100 | Train Loss 0.142982 | Val Loss 0.401698
# Epoch 200 | Train Loss 0.138834 | Val Loss 0.411081
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.7963e-04
# X | Train_2 -> R² = 0.9948, MSE = 4.4082e-04
# X | Test_1 -> R² = 0.9845, MSE = 1.6164e-03
# X | Test_2 -> R² = -0.3699, MSE = 1.1255e-01
# X | Test_3 -> R² = -0.3676, MSE = 1.2543e-01
# X | Val -> R² = -0.4419, MSE = 1.3739e-01
# X | LSG_1 -> R² = -0.0378, MSE = 1.0595e-01
# X | LSG_2 -> R² = -0.4786, MSE = 1.3090e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.353081 | Val Loss 0.458776
# Epoch 100 | Train Loss 0.140426 | Val Loss 0.407691
# Epoch 200 | Train Loss 0.137323 | Val Loss 0.415766
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.8508e-04
# X | Train_2 -> R² = 0.9896, MSE = 8.7133e-04
# X | Test_1 -> R² = 0.9793, MSE = 2.1562e-03
# X | Test_2 -> R² = -0.8173, MSE = 1.4930e-01
# X | Test_3 -> R² = -0.7709, MSE = 1.6243e-01
# X | Val -> R² = -0.3557, MSE = 1.2918e-01
# X | LSG_1 -> R² = -1.1081, MSE = 2.1522e-01
# X | LSG_2 -> R² = -1.1599, MSE = 1.9122e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.365583 | Val Loss 0.481810
# Epoch 100 | Train Loss 0.141094 | Val Loss 0.403817
# Epoch 200 | Train Loss 0.137458 | Val Loss 0.414181
# Early stopping at epoch 300
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9961, MSE = 4.1664e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3895e-04
# X | Test_1 -> R² = 0.9575, MSE = 4.4345e-03
# X | Test_2 -> R² = -0.0818, MSE = 8.8880e-02
# X | Test_3 -> R² = 0.1310, MSE = 7.9707e-02
# X | Val -> R² = 0.3097, MSE = 6.5772e-02
# X | LSG_1 -> R² = -0.8309, MSE = 1.8691e-01
# X | LSG_2 -> R² = -0.8168, MSE = 1.6084e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.457669 | Val Loss 0.507083
# Epoch 100 | Train Loss 0.141796 | Val Loss 0.408338
# Epoch 200 | Train Loss 0.138044 | Val Loss 0.413877
# Epoch 300 | Train Loss 0.135909 | Val Loss 0.427904
# Early stopping at epoch 301
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9957, MSE = 4.6157e-04
# X | Train_2 -> R² = 0.9961, MSE = 3.3181e-04
# X | Test_1 -> R² = 0.9838, MSE = 1.6927e-03
# X | Test_2 -> R² = 0.0367, MSE = 7.9147e-02
# X | Test_3 -> R² = -0.7839, MSE = 1.6362e-01
# X | Val -> R² = -0.2736, MSE = 1.2136e-01
# X | LSG_1 -> R² = -0.4817, MSE = 1.5127e-01
# X | LSG_2 -> R² = -0.4701, MSE = 1.3015e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.394615 | Val Loss 0.503942
# Epoch 100 | Train Loss 0.141950 | Val Loss 0.408126
# Epoch 200 | Train Loss 0.138528 | Val Loss 0.419477
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9938, MSE = 6.6581e-04
# X | Train_2 -> R² = 0.9948, MSE = 4.3339e-04
# X | Test_1 -> R² = 0.9393, MSE = 6.3376e-03
# X | Test_2 -> R² = -0.2163, MSE = 9.9926e-02
# X | Test_3 -> R² = 0.1774, MSE = 7.5449e-02
# X | Val -> R² = -0.0132, MSE = 9.6543e-02
# X | LSG_1 -> R² = -0.3976, MSE = 1.4268e-01
# X | LSG_2 -> R² = -0.5744, MSE = 1.3939e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.476766 | Val Loss 0.505111
# Epoch 100 | Train Loss 0.143306 | Val Loss 0.406033
# Epoch 200 | Train Loss 0.138071 | Val Loss 0.408558
# Epoch 300 | Train Loss 0.136574 | Val Loss 0.420009
# Early stopping at epoch 314
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed174.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed174.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.8287e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3988e-04
# X | Test_1 -> R² = 0.9393, MSE = 6.3328e-03
# X | Test_2 -> R² = -0.0809, MSE = 8.8808e-02
# X | Test_3 -> R² = -0.1528, MSE = 1.0574e-01
# X | Val -> R² = 0.0695, MSE = 8.8664e-02
# X | LSG_1 -> R² = -0.1880, MSE = 1.2128e-01
# X | LSG_2 -> R² = -0.4721, MSE = 1.3032e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.400668 | Val Loss 0.457786
# Epoch 100 | Train Loss 0.140029 | Val Loss 0.407804
# Epoch 200 | Train Loss 0.137000 | Val Loss 0.415534
# Epoch 300 | Train Loss 0.135546 | Val Loss 0.426119
# Early stopping at epoch 302
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8808.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8808.weights.h5
# X | Train_1 -> R² = 0.9870, MSE = 1.3972e-03
# X | Train_2 -> R² = -0.0363, MSE = 8.7202e-02
# X | Test_1 -> R² = 0.9528, MSE = 4.9256e-03
# X | Test_2 -> R² = -3.2245, MSE = 3.4708e-01
# X | Test_3 -> R² = -0.1795, MSE = 1.0818e-01
# X | Val -> R² = -0.3682, MSE = 1.3037e-01
# X | LSG_1 -> R² = 0.7293, MSE = 2.7632e-02
# X | LSG_2 -> R² = -0.8758, MSE = 1.6607e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.464866 | Val Loss 0.501446
# Epoch 100 | Train Loss 0.143722 | Val Loss 0.408551
# Epoch 200 | Train Loss 0.138413 | Val Loss 0.412806
# Epoch 300 | Train Loss 0.136569 | Val Loss 0.422635
# Early stopping at epoch 312
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5657.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5657.weights.h5
# X | Train_1 -> R² = 0.9882, MSE = 1.2640e-03
# X | Train_2 -> R² = 0.9959, MSE = 3.4157e-04
# X | Test_1 -> R² = 0.9315, MSE = 7.1466e-03
# X | Test_2 -> R² = -0.1304, MSE = 9.2868e-02
# X | Test_3 -> R² = -0.2681, MSE = 1.1631e-01
# X | Val -> R² = -0.3638, MSE = 1.2995e-01
# X | LSG_1 -> R² = -0.8430, MSE = 1.8815e-01
# X | LSG_2 -> R² = -0.7778, MSE = 1.5739e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.487077 | Val Loss 0.573055
# Epoch 100 | Train Loss 0.142117 | Val Loss 0.403973
# Epoch 200 | Train Loss 0.137567 | Val Loss 0.415242
# Early stopping at epoch 299
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7182.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7182.weights.h5
# X | Train_1 -> R² = 0.9945, MSE = 5.9252e-04
# X | Train_2 -> R² = 0.9964, MSE = 3.0214e-04
# X | Test_1 -> R² = 0.9643, MSE = 3.7304e-03
# X | Test_2 -> R² = -0.1380, MSE = 9.3496e-02
# X | Test_3 -> R² = -0.2722, MSE = 1.1669e-01
# X | Val -> R² = -0.1019, MSE = 1.0499e-01
# X | LSG_1 -> R² = -0.4970, MSE = 1.5283e-01
# X | LSG_2 -> R² = -0.5892, MSE = 1.4069e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.420746 | Val Loss 0.481924
# Epoch 100 | Train Loss 0.141399 | Val Loss 0.410765
# Epoch 200 | Train Loss 0.137740 | Val Loss 0.415900
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7914.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7914.weights.h5
# X | Train_1 -> R² = 0.9910, MSE = 9.6888e-04
# X | Train_2 -> R² = 0.9961, MSE = 3.2804e-04
# X | Test_1 -> R² = 0.9538, MSE = 4.8168e-03
# X | Test_2 -> R² = -0.4212, MSE = 1.1676e-01
# X | Test_3 -> R² = -0.1089, MSE = 1.0171e-01
# X | Val -> R² = -0.4032, MSE = 1.3370e-01
# X | LSG_1 -> R² = -0.7784, MSE = 1.8156e-01
# X | LSG_2 -> R² = -0.8853, MSE = 1.6691e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7914 salvo.
# Epoch 0 | Train Loss 0.560954 | Val Loss 0.502524
# Epoch 100 | Train Loss 0.283779 | Val Loss 0.409628
# Epoch 200 | Train Loss 0.279990 | Val Loss 0.414843
# Early stopping at epoch 283
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9829, MSE = 1.8414e-03
# X | Train_2 -> R² = 0.9951, MSE = 4.1482e-04
# X | Test_1 -> R² = 0.8919, MSE = 1.1276e-02
# X | Test_2 -> R² = -0.1312, MSE = 9.2939e-02
# X | Test_3 -> R² = -0.0442, MSE = 9.5772e-02
# X | Val -> R² = -0.5352, MSE = 1.4628e-01
# X | LSG_1 -> R² = -0.1853, MSE = 1.2101e-01
# X | LSG_2 -> R² = -0.4874, MSE = 1.3168e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=174 salvo.
# Epoch 0 | Train Loss 0.530072 | Val Loss 0.466766
# Epoch 100 | Train Loss 0.281787 | Val Loss 0.411863
# Epoch 200 | Train Loss 0.277567 | Val Loss 0.423114
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9856, MSE = 1.5502e-03
# X | Train_2 -> R² = 0.9483, MSE = 4.3526e-03
# X | Test_1 -> R² = 0.8672, MSE = 1.3860e-02
# X | Test_2 -> R² = -0.9764, MSE = 1.6238e-01
# X | Test_3 -> R² = -0.1260, MSE = 1.0328e-01
# X | Val -> R² = -0.2894, MSE = 1.2286e-01
# X | LSG_1 -> R² = 0.1820, MSE = 8.3512e-02
# X | LSG_2 -> R² = -0.5780, MSE = 1.3970e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8808 salvo.
# Epoch 0 | Train Loss 0.626158 | Val Loss 0.519546
# Epoch 100 | Train Loss 0.284858 | Val Loss 0.409383
# Epoch 200 | Train Loss 0.279851 | Val Loss 0.412487
# Epoch 300 | Train Loss 0.277347 | Val Loss 0.425009
# Early stopping at epoch 303
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9863, MSE = 1.4761e-03
# X | Train_2 -> R² = 0.9944, MSE = 4.7005e-04
# X | Test_1 -> R² = 0.8347, MSE = 1.7246e-02
# X | Test_2 -> R² = -0.0763, MSE = 8.8425e-02
# X | Test_3 -> R² = 0.1763, MSE = 7.5548e-02
# X | Val -> R² = -0.1347, MSE = 1.0812e-01
# X | LSG_1 -> R² = -0.3611, MSE = 1.3896e-01
# X | LSG_2 -> R² = -0.4597, MSE = 1.2923e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5657 salvo.
# Epoch 0 | Train Loss 0.663904 | Val Loss 0.549607
# Epoch 100 | Train Loss 0.284767 | Val Loss 0.405191
# Epoch 200 | Train Loss 0.280086 | Val Loss 0.409940
# Epoch 300 | Train Loss 0.276946 | Val Loss 0.418236
# Early stopping at epoch 307
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7182.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7182.weights.h5
# X | Train_1 -> R² = 0.9868, MSE = 1.4143e-03
# X | Train_2 -> R² = 0.9968, MSE = 2.7184e-04
# X | Test_1 -> R² = 0.9075, MSE = 9.6552e-03
# X | Test_2 -> R² = -0.2409, MSE = 1.0195e-01
# X | Test_3 -> R² = -0.3604, MSE = 1.2478e-01
# X | Val -> R² = -0.6762, MSE = 1.5972e-01
# X | LSG_1 -> R² = 0.0882, MSE = 9.3089e-02
# X | LSG_2 -> R² = -0.3762, MSE = 1.2184e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7182 salvo.
# Epoch 0 | Train Loss 0.680698 | Val Loss 0.568020
# Epoch 100 | Train Loss 0.284438 | Val Loss 0.409912
# Epoch 200 | Train Loss 0.279222 | Val Loss 0.416447
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9726, MSE = 2.9434e-03
# X | Train_2 -> R² = 0.5750, MSE = 3.5763e-02
# X | Test_1 -> R² = 0.7692, MSE = 2.4088e-02
# X | Test_2 -> R² = -2.0756, MSE = 2.5269e-01
# X | Test_3 -> R² = 0.2425, MSE = 6.9480e-02
# X | Val -> R² = -0.6609, MSE = 1.5826e-01
# X | LSG_1 -> R² = 0.6887, MSE = 3.1779e-02
# X | LSG_2 -> R² = -0.5848, MSE = 1.4030e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7914 salvo.
# Epoch 0 | Train Loss 0.647880 | Val Loss 0.520271
# Epoch 100 | Train Loss 0.286711 | Val Loss 0.410505
# Epoch 200 | Train Loss 0.280296 | Val Loss 0.411923
# Epoch 300 | Train Loss 0.277363 | Val Loss 0.416667
# Early stopping at epoch 316
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed174.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed174.weights.h5
# X | Train_1 -> R² = 0.9876, MSE = 1.3330e-03
# X | Train_2 -> R² = 0.9950, MSE = 4.2416e-04
# X | Test_1 -> R² = 0.9355, MSE = 6.7281e-03
# X | Test_2 -> R² = -0.2620, MSE = 1.0368e-01
# X | Test_3 -> R² = -0.3727, MSE = 1.2590e-01
# X | Val -> R² = -0.5052, MSE = 1.4342e-01
# X | LSG_1 -> R² = -0.0680, MSE = 1.0903e-01
# X | LSG_2 -> R² = -0.4050, MSE = 1.2439e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=174 salvo.
# Epoch 0 | Train Loss 0.674338 | Val Loss 0.566724
# Epoch 100 | Train Loss 0.283101 | Val Loss 0.407964
# Epoch 200 | Train Loss 0.279546 | Val Loss 0.411639
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8808.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8808.weights.h5
# X | Train_1 -> R² = 0.9796, MSE = 2.1897e-03
# X | Train_2 -> R² = 0.9962, MSE = 3.2224e-04
# X | Test_1 -> R² = 0.8918, MSE = 1.1287e-02
# X | Test_2 -> R² = -0.4272, MSE = 1.1725e-01
# X | Test_3 -> R² = -0.9286, MSE = 1.7689e-01
# X | Val -> R² = -1.0617, MSE = 1.9645e-01
# X | LSG_1 -> R² = -0.1065, MSE = 1.1296e-01
# X | LSG_2 -> R² = -0.4966, MSE = 1.3249e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8808 salvo.
# Epoch 0 | Train Loss 0.524739 | Val Loss 0.460219
# Epoch 100 | Train Loss 0.282931 | Val Loss 0.410382
# Epoch 200 | Train Loss 0.278961 | Val Loss 0.414355
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5657.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5657.weights.h5
# X | Train_1 -> R² = 0.9869, MSE = 1.4016e-03
# X | Train_2 -> R² = 0.9960, MSE = 3.4041e-04
# X | Test_1 -> R² = 0.9191, MSE = 8.4437e-03
# X | Test_2 -> R² = -0.3199, MSE = 1.0844e-01
# X | Test_3 -> R² = -0.3405, MSE = 1.2296e-01
# X | Val -> R² = -0.4944, MSE = 1.4240e-01
# X | LSG_1 -> R² = 0.1818, MSE = 8.3527e-02
# X | LSG_2 -> R² = -0.3768, MSE = 1.2189e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5657 salvo.
# Epoch 0 | Train Loss 0.597917 | Val Loss 0.493802
# Epoch 100 | Train Loss 0.285167 | Val Loss 0.410553
# Epoch 200 | Train Loss 0.280296 | Val Loss 0.413380
# Epoch 300 | Train Loss 0.277432 | Val Loss 0.423795
# Early stopping at epoch 319
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7182.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7182.weights.h5
# X | Train_1 -> R² = 0.9755, MSE = 2.6346e-03
# X | Train_2 -> R² = 0.3170, MSE = 5.7469e-02
# X | Test_1 -> R² = 0.8367, MSE = 1.7042e-02
# X | Test_2 -> R² = -2.1395, MSE = 2.5794e-01
# X | Test_3 -> R² = 0.0082, MSE = 9.0966e-02
# X | Val -> R² = -0.4230, MSE = 1.3559e-01
# X | LSG_1 -> R² = 0.7188, MSE = 2.8708e-02
# X | LSG_2 -> R² = -0.7689, MSE = 1.5660e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7182 salvo.
# Epoch 0 | Train Loss 0.545454 | Val Loss 0.493804
# Epoch 100 | Train Loss 0.282520 | Val Loss 0.411761
# Epoch 200 | Train Loss 0.278004 | Val Loss 0.423476
# Early stopping at epoch 280
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7914.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7914.weights.h5
# X | Train_1 -> R² = 0.9759, MSE = 2.5892e-03
# X | Train_2 -> R² = 0.7727, MSE = 1.9126e-02
# X | Test_1 -> R² = 0.7554, MSE = 2.5524e-02
# X | Test_2 -> R² = -1.4730, MSE = 2.0318e-01
# X | Test_3 -> R² = -0.0089, MSE = 9.2539e-02
# X | Val -> R² = -0.2962, MSE = 1.2351e-01
# X | LSG_1 -> R² = 0.4015, MSE = 6.1102e-02
# X | LSG_2 -> R² = -0.5557, MSE = 1.3773e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7914 salvo.
