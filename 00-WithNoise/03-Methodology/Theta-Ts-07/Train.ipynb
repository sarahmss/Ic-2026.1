# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 7
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 1)
# Dimensão da entrada: (1264, 7, 4)
# Dimensão da saida: (1264, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1945, 7, 4)
# Dimensão da saida: (1945, 1)
# Dimensão da entrada fisica : (1945,)
# Dimensão da entrada fisica: (1945,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.992689 | Val Loss 0.835757
# Epoch 100 | Train Loss 0.788918 | Val Loss 0.574150
# Epoch 200 | Train Loss 0.679911 | Val Loss 0.632054
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7208, MSE = 6.3804e-02
# Theta | Train_2 -> R² = 0.3971, MSE = 1.3669e-01
# Theta | Test_1 -> R² = 0.5275, MSE = 1.0869e-01
# Theta | Test_2 -> R² = 0.8291, MSE = 4.0246e-02
# Theta | Test_3 -> R² = 0.5609, MSE = 1.4441e-01
# Theta | Val -> R² = -3.3539, MSE = 1.4249e+00
# Theta | LSG_1 -> R² = 0.6928, MSE = 1.2619e-01
# Theta | LSG_2 -> R² = -0.6555, MSE = 5.6738e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 1.002017 | Val Loss 0.830795
# Epoch 100 | Train Loss 0.796734 | Val Loss 0.585004
# Epoch 200 | Train Loss 0.724096 | Val Loss 0.586966
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7347, MSE = 6.0637e-02
# Theta | Train_2 -> R² = 0.3348, MSE = 1.5082e-01
# Theta | Test_1 -> R² = 0.5985, MSE = 9.2344e-02
# Theta | Test_2 -> R² = 0.8165, MSE = 4.3218e-02
# Theta | Test_3 -> R² = 0.3199, MSE = 2.2363e-01
# Theta | Val -> R² = -1.0412, MSE = 6.6804e-01
# Theta | LSG_1 -> R² = 0.6956, MSE = 1.2503e-01
# Theta | LSG_2 -> R² = 0.1487, MSE = 2.9174e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 0.986112 | Val Loss 0.839867
# Epoch 100 | Train Loss 0.769417 | Val Loss 0.594970
# Epoch 200 | Train Loss 0.689733 | Val Loss 0.571018
# Epoch 300 | Train Loss 0.649045 | Val Loss 0.639317
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.8314, MSE = 3.8525e-02
# Theta | Train_2 -> R² = 0.7808, MSE = 4.9697e-02
# Theta | Test_1 -> R² = 0.7866, MSE = 4.9094e-02
# Theta | Test_2 -> R² = 0.8123, MSE = 4.4223e-02
# Theta | Test_3 -> R² = -0.2079, MSE = 3.9722e-01
# Theta | Val -> R² = -1.9811, MSE = 9.7564e-01
# Theta | LSG_1 -> R² = 0.6302, MSE = 1.5189e-01
# Theta | LSG_2 -> R² = -1.2495, MSE = 7.7095e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 1.002009 | Val Loss 0.873510
# Epoch 100 | Train Loss 0.797240 | Val Loss 0.558628
# Epoch 200 | Train Loss 0.687397 | Val Loss 0.579657
# Epoch 300 | Train Loss 0.629350 | Val Loss 0.646343
# Early stopping at epoch 306
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7203, MSE = 6.3929e-02
# Theta | Train_2 -> R² = 0.5288, MSE = 1.0683e-01
# Theta | Test_1 -> R² = 0.2436, MSE = 1.7399e-01
# Theta | Test_2 -> R² = 0.8798, MSE = 2.8318e-02
# Theta | Test_3 -> R² = 0.5986, MSE = 1.3198e-01
# Theta | Val -> R² = -4.2089, MSE = 1.7047e+00
# Theta | LSG_1 -> R² = 0.6151, MSE = 1.5810e-01
# Theta | LSG_2 -> R² = -1.7824, MSE = 9.5358e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 0.978721 | Val Loss 0.812400
# Epoch 100 | Train Loss 0.749825 | Val Loss 0.585358
# Epoch 200 | Train Loss 0.688027 | Val Loss 0.578063
# Early stopping at epoch 256
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7394, MSE = 5.9550e-02
# Theta | Train_2 -> R² = 0.2394, MSE = 1.7244e-01
# Theta | Test_1 -> R² = 0.6385, MSE = 8.3157e-02
# Theta | Test_2 -> R² = 0.7845, MSE = 5.0754e-02
# Theta | Test_3 -> R² = 0.5505, MSE = 1.4781e-01
# Theta | Val -> R² = -2.3851, MSE = 1.1079e+00
# Theta | LSG_1 -> R² = 0.7498, MSE = 1.0279e-01
# Theta | LSG_2 -> R² = -0.1148, MSE = 3.8206e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 0.994187 | Val Loss 0.846164
# Epoch 100 | Train Loss 0.767547 | Val Loss 0.599013
# Epoch 200 | Train Loss 0.695400 | Val Loss 0.578894
# Epoch 300 | Train Loss 0.654384 | Val Loss 0.579009
# Epoch 400 | Train Loss 0.628458 | Val Loss 0.662580
# Early stopping at epoch 448
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.8089, MSE = 4.3679e-02
# Theta | Train_2 -> R² = 0.6702, MSE = 7.4782e-02
# Theta | Test_1 -> R² = 0.6568, MSE = 7.8934e-02
# Theta | Test_2 -> R² = 0.8854, MSE = 2.6988e-02
# Theta | Test_3 -> R² = 0.1307, MSE = 2.8587e-01
# Theta | Val -> R² = -2.5834, MSE = 1.1728e+00
# Theta | LSG_1 -> R² = 0.4929, MSE = 2.0831e-01
# Theta | LSG_2 -> R² = -2.8593, MSE = 1.3227e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 0.996804 | Val Loss 0.837466
# Epoch 100 | Train Loss 0.838551 | Val Loss 0.560753
# Epoch 200 | Train Loss 0.700740 | Val Loss 0.571256
# Epoch 300 | Train Loss 0.672666 | Val Loss 0.605423
# Early stopping at epoch 301
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7872, MSE = 4.8621e-02
# Theta | Train_2 -> R² = 0.5322, MSE = 1.0606e-01
# Theta | Test_1 -> R² = 0.6503, MSE = 8.0440e-02
# Theta | Test_2 -> R² = 0.8631, MSE = 3.2252e-02
# Theta | Test_3 -> R² = 0.6579, MSE = 1.1250e-01
# Theta | Val -> R² = -2.6379, MSE = 1.1906e+00
# Theta | LSG_1 -> R² = 0.5966, MSE = 1.6570e-01
# Theta | LSG_2 -> R² = -1.0998, MSE = 7.1966e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 0.992976 | Val Loss 0.852363
# Epoch 100 | Train Loss 0.740644 | Val Loss 0.591339
# Epoch 200 | Train Loss 0.675178 | Val Loss 0.603095
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.7687, MSE = 5.2847e-02
# Theta | Train_2 -> R² = 0.3382, MSE = 1.5004e-01
# Theta | Test_1 -> R² = 0.4404, MSE = 1.2872e-01
# Theta | Test_2 -> R² = 0.8346, MSE = 3.8969e-02
# Theta | Test_3 -> R² = 0.5464, MSE = 1.4916e-01
# Theta | Val -> R² = -4.3667, MSE = 1.7564e+00
# Theta | LSG_1 -> R² = 0.6958, MSE = 1.2495e-01
# Theta | LSG_2 -> R² = -1.1247, MSE = 7.2820e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 1.006057 | Val Loss 0.876476
# Epoch 100 | Train Loss 0.829486 | Val Loss 0.568583
# Epoch 200 | Train Loss 0.713106 | Val Loss 0.599258
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7799, MSE = 5.0293e-02
# Theta | Train_2 -> R² = 0.4820, MSE = 1.1744e-01
# Theta | Test_1 -> R² = 0.6352, MSE = 8.3913e-02
# Theta | Test_2 -> R² = 0.8537, MSE = 3.4450e-02
# Theta | Test_3 -> R² = 0.4559, MSE = 1.7891e-01
# Theta | Val -> R² = -3.6709, MSE = 1.5287e+00
# Theta | LSG_1 -> R² = 0.6997, MSE = 1.2336e-01
# Theta | LSG_2 -> R² = -0.4095, MSE = 4.8308e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.991846 | Val Loss 0.822222
# Epoch 100 | Train Loss 0.815760 | Val Loss 0.571679
# Epoch 200 | Train Loss 0.689866 | Val Loss 0.600516
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.6764, MSE = 7.3946e-02
# Theta | Train_2 -> R² = 0.3914, MSE = 1.3798e-01
# Theta | Test_1 -> R² = 0.4995, MSE = 1.1511e-01
# Theta | Test_2 -> R² = 0.8159, MSE = 4.3354e-02
# Theta | Test_3 -> R² = 0.5943, MSE = 1.3341e-01
# Theta | Val -> R² = -3.0787, MSE = 1.3349e+00
# Theta | LSG_1 -> R² = 0.6750, MSE = 1.3351e-01
# Theta | LSG_2 -> R² = -0.7605, MSE = 6.0336e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 1.019410 | Val Loss 0.874805
# Epoch 100 | Train Loss 0.774544 | Val Loss 0.561888
# Epoch 200 | Train Loss 0.710027 | Val Loss 0.607087
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6887, MSE = 7.1132e-02
# Theta | Train_2 -> R² = 0.4293, MSE = 1.2939e-01
# Theta | Test_1 -> R² = 0.2352, MSE = 1.7591e-01
# Theta | Test_2 -> R² = 0.8516, MSE = 3.4954e-02
# Theta | Test_3 -> R² = 0.5433, MSE = 1.5017e-01
# Theta | Val -> R² = -6.3675, MSE = 2.4112e+00
# Theta | LSG_1 -> R² = 0.3239, MSE = 2.7773e-01
# Theta | LSG_2 -> R² = -2.7517, MSE = 1.2858e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 0.983557 | Val Loss 0.825736
# Epoch 100 | Train Loss 0.755667 | Val Loss 0.573234
# Epoch 200 | Train Loss 0.706984 | Val Loss 0.609300
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.6394, MSE = 8.2403e-02
# Theta | Train_2 -> R² = 0.4697, MSE = 1.2024e-01
# Theta | Test_1 -> R² = 0.1126, MSE = 2.0411e-01
# Theta | Test_2 -> R² = 0.8584, MSE = 3.3359e-02
# Theta | Test_3 -> R² = 0.5920, MSE = 1.3417e-01
# Theta | Val -> R² = -6.1556, MSE = 2.3418e+00
# Theta | LSG_1 -> R² = 0.1716, MSE = 3.4029e-01
# Theta | LSG_2 -> R² = -3.1072, MSE = 1.4076e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 0.994716 | Val Loss 0.852904
# Epoch 100 | Train Loss 0.753534 | Val Loss 0.563756
# Epoch 200 | Train Loss 0.707338 | Val Loss 0.605519
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6849, MSE = 7.2011e-02
# Theta | Train_2 -> R² = 0.3927, MSE = 1.3768e-01
# Theta | Test_1 -> R² = -0.0283, MSE = 2.3654e-01
# Theta | Test_2 -> R² = 0.8492, MSE = 3.5532e-02
# Theta | Test_3 -> R² = 0.5781, MSE = 1.3873e-01
# Theta | Val -> R² = -6.9981, MSE = 2.6175e+00
# Theta | LSG_1 -> R² = 0.3071, MSE = 2.8461e-01
# Theta | LSG_2 -> R² = -3.2140, MSE = 1.4442e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 0.990056 | Val Loss 0.841795
# Epoch 100 | Train Loss 0.776187 | Val Loss 0.561149
# Epoch 200 | Train Loss 0.704051 | Val Loss 0.605090
# Early stopping at epoch 283
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7359, MSE = 6.0354e-02
# Theta | Train_2 -> R² = 0.5589, MSE = 1.0000e-01
# Theta | Test_1 -> R² = 0.1849, MSE = 1.8749e-01
# Theta | Test_2 -> R² = 0.8671, MSE = 3.1307e-02
# Theta | Test_3 -> R² = 0.7047, MSE = 9.7095e-02
# Theta | Val -> R² = -5.3582, MSE = 2.0809e+00
# Theta | LSG_1 -> R² = 0.0145, MSE = 4.0481e-01
# Theta | LSG_2 -> R² = -3.7193, MSE = 1.6174e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 0.978334 | Val Loss 0.835353
# Epoch 100 | Train Loss 0.766479 | Val Loss 0.562467
# Epoch 200 | Train Loss 0.699651 | Val Loss 0.621010
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7246, MSE = 6.2934e-02
# Theta | Train_2 -> R² = 0.4840, MSE = 1.1698e-01
# Theta | Test_1 -> R² = 0.3469, MSE = 1.5021e-01
# Theta | Test_2 -> R² = 0.8698, MSE = 3.0679e-02
# Theta | Test_3 -> R² = 0.6151, MSE = 1.2658e-01
# Theta | Val -> R² = -5.2639, MSE = 2.0500e+00
# Theta | LSG_1 -> R² = 0.5313, MSE = 1.9252e-01
# Theta | LSG_2 -> R² = -2.1512, MSE = 1.0800e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 0.997811 | Val Loss 0.856900
# Epoch 100 | Train Loss 0.747808 | Val Loss 0.571254
# Epoch 200 | Train Loss 0.696360 | Val Loss 0.588050
# Early stopping at epoch 272
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7104, MSE = 6.6184e-02
# Theta | Train_2 -> R² = 0.4752, MSE = 1.1899e-01
# Theta | Test_1 -> R² = 0.1317, MSE = 1.9972e-01
# Theta | Test_2 -> R² = 0.8717, MSE = 3.0210e-02
# Theta | Test_3 -> R² = 0.6266, MSE = 1.2278e-01
# Theta | Val -> R² = -5.7403, MSE = 2.2059e+00
# Theta | LSG_1 -> R² = 0.1507, MSE = 3.4889e-01
# Theta | LSG_2 -> R² = -3.4184, MSE = 1.5143e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 0.980265 | Val Loss 0.821167
# Epoch 100 | Train Loss 0.760069 | Val Loss 0.568409
# Epoch 200 | Train Loss 0.708094 | Val Loss 0.610998
# Early stopping at epoch 275
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7268, MSE = 6.2429e-02
# Theta | Train_2 -> R² = 0.5038, MSE = 1.1251e-01
# Theta | Test_1 -> R² = 0.3599, MSE = 1.4723e-01
# Theta | Test_2 -> R² = 0.8679, MSE = 3.1112e-02
# Theta | Test_3 -> R² = 0.4444, MSE = 1.8270e-01
# Theta | Val -> R² = -6.4322, MSE = 2.4324e+00
# Theta | LSG_1 -> R² = 0.4304, MSE = 2.3396e-01
# Theta | LSG_2 -> R² = -2.4626, MSE = 1.1867e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 0.973900 | Val Loss 0.832297
# Epoch 100 | Train Loss 0.740941 | Val Loss 0.583750
# Epoch 200 | Train Loss 0.703304 | Val Loss 0.596488
# Early stopping at epoch 268
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6932, MSE = 7.0120e-02
# Theta | Train_2 -> R² = 0.4339, MSE = 1.2834e-01
# Theta | Test_1 -> R² = 0.1951, MSE = 1.8515e-01
# Theta | Test_2 -> R² = 0.8576, MSE = 3.3539e-02
# Theta | Test_3 -> R² = 0.5869, MSE = 1.3583e-01
# Theta | Val -> R² = -6.3818, MSE = 2.4159e+00
# Theta | LSG_1 -> R² = 0.3683, MSE = 2.5950e-01
# Theta | LSG_2 -> R² = -2.6813, MSE = 1.2616e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 0.993349 | Val Loss 0.856900
# Epoch 100 | Train Loss 0.771607 | Val Loss 0.563097
# Epoch 200 | Train Loss 0.715458 | Val Loss 0.619855
# Early stopping at epoch 282
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7214, MSE = 6.3656e-02
# Theta | Train_2 -> R² = 0.4574, MSE = 1.2303e-01
# Theta | Test_1 -> R² = 0.2922, MSE = 1.6282e-01
# Theta | Test_2 -> R² = 0.8612, MSE = 3.2705e-02
# Theta | Test_3 -> R² = 0.5873, MSE = 1.3571e-01
# Theta | Val -> R² = -5.6613, MSE = 2.1801e+00
# Theta | LSG_1 -> R² = 0.5222, MSE = 1.9627e-01
# Theta | LSG_2 -> R² = -2.1217, MSE = 1.0699e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.953276 | Val Loss 0.789437
# Epoch 100 | Train Loss 0.771877 | Val Loss 0.571919
# Epoch 200 | Train Loss 0.714350 | Val Loss 0.623520
# Early stopping at epoch 265
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.6884, MSE = 7.1214e-02
# Theta | Train_2 -> R² = 0.4940, MSE = 1.1473e-01
# Theta | Test_1 -> R² = 0.2705, MSE = 1.6780e-01
# Theta | Test_2 -> R² = 0.8650, MSE = 3.1810e-02
# Theta | Test_3 -> R² = 0.6190, MSE = 1.2528e-01
# Theta | Val -> R² = -5.4091, MSE = 2.0975e+00
# Theta | LSG_1 -> R² = 0.2804, MSE = 2.9561e-01
# Theta | LSG_2 -> R² = -2.6384, MSE = 1.2470e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 1.121444 | Val Loss 0.992571
# Epoch 100 | Train Loss 0.718790 | Val Loss 0.589394
# Epoch 200 | Train Loss 0.658810 | Val Loss 0.622546
# Early stopping at epoch 250
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6220, MSE = 8.6378e-02
# Theta | Train_2 -> R² = 0.3363, MSE = 1.5049e-01
# Theta | Test_1 -> R² = 0.3031, MSE = 1.6029e-01
# Theta | Test_2 -> R² = 0.8050, MSE = 4.5941e-02
# Theta | Test_3 -> R² = 0.4572, MSE = 1.7851e-01
# Theta | Val -> R² = -4.0599, MSE = 1.6560e+00
# Theta | LSG_1 -> R² = 0.6822, MSE = 1.3056e-01
# Theta | LSG_2 -> R² = -1.1788, MSE = 7.4674e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 0.984885 | Val Loss 0.739876
# Epoch 100 | Train Loss 0.715371 | Val Loss 0.599366
# Epoch 200 | Train Loss 0.665642 | Val Loss 0.577438
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.6247, MSE = 8.5760e-02
# Theta | Train_2 -> R² = 0.4303, MSE = 1.2917e-01
# Theta | Test_1 -> R² = 0.3684, MSE = 1.4528e-01
# Theta | Test_2 -> R² = 0.8585, MSE = 3.3322e-02
# Theta | Test_3 -> R² = 0.5797, MSE = 1.3820e-01
# Theta | Val -> R² = -3.4914, MSE = 1.4699e+00
# Theta | LSG_1 -> R² = 0.4996, MSE = 2.0556e-01
# Theta | LSG_2 -> R² = -1.6894, MSE = 9.2170e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 0.969942 | Val Loss 0.771720
# Epoch 100 | Train Loss 0.703302 | Val Loss 0.590218
# Epoch 200 | Train Loss 0.648193 | Val Loss 0.602427
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.5364, MSE = 1.0594e-01
# Theta | Train_2 -> R² = 0.2126, MSE = 1.7853e-01
# Theta | Test_1 -> R² = 0.1930, MSE = 1.8564e-01
# Theta | Test_2 -> R² = 0.7317, MSE = 6.3190e-02
# Theta | Test_3 -> R² = 0.5377, MSE = 1.5203e-01
# Theta | Val -> R² = -4.2246, MSE = 1.7099e+00
# Theta | LSG_1 -> R² = 0.5795, MSE = 1.7272e-01
# Theta | LSG_2 -> R² = -1.4062, MSE = 8.2465e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 0.970788 | Val Loss 0.775490
# Epoch 100 | Train Loss 0.706490 | Val Loss 0.581773
# Epoch 200 | Train Loss 0.664065 | Val Loss 0.572132
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.6096, MSE = 8.9213e-02
# Theta | Train_2 -> R² = 0.3014, MSE = 1.5838e-01
# Theta | Test_1 -> R² = 0.3077, MSE = 1.5924e-01
# Theta | Test_2 -> R² = 0.7882, MSE = 4.9879e-02
# Theta | Test_3 -> R² = 0.6014, MSE = 1.3106e-01
# Theta | Val -> R² = -3.8359, MSE = 1.5827e+00
# Theta | LSG_1 -> R² = 0.6361, MSE = 1.4946e-01
# Theta | LSG_2 -> R² = -1.2843, MSE = 7.8289e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 1.030031 | Val Loss 0.858614
# Epoch 100 | Train Loss 0.722885 | Val Loss 0.594907
# Epoch 200 | Train Loss 0.667326 | Val Loss 0.627754
# Early stopping at epoch 242
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.5918, MSE = 9.3283e-02
# Theta | Train_2 -> R² = 0.2213, MSE = 1.7656e-01
# Theta | Test_1 -> R² = 0.2365, MSE = 1.7562e-01
# Theta | Test_2 -> R² = 0.7356, MSE = 6.2289e-02
# Theta | Test_3 -> R² = 0.6480, MSE = 1.1576e-01
# Theta | Val -> R² = -3.7813, MSE = 1.5648e+00
# Theta | LSG_1 -> R² = 0.6300, MSE = 1.5199e-01
# Theta | LSG_2 -> R² = -1.2580, MSE = 7.7386e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 0.969086 | Val Loss 0.781366
# Epoch 100 | Train Loss 0.707819 | Val Loss 0.581621
# Epoch 200 | Train Loss 0.656287 | Val Loss 0.674283
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6915, MSE = 7.0500e-02
# Theta | Train_2 -> R² = 0.3108, MSE = 1.5625e-01
# Theta | Test_1 -> R² = 0.4537, MSE = 1.2565e-01
# Theta | Test_2 -> R² = 0.7883, MSE = 4.9861e-02
# Theta | Test_3 -> R² = 0.5504, MSE = 1.4785e-01
# Theta | Val -> R² = -4.2278, MSE = 1.7109e+00
# Theta | LSG_1 -> R² = 0.6588, MSE = 1.4015e-01
# Theta | LSG_2 -> R² = -1.1396, MSE = 7.3330e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 0.956495 | Val Loss 0.756932
# Epoch 100 | Train Loss 0.703249 | Val Loss 0.588810
# Epoch 200 | Train Loss 0.667282 | Val Loss 0.541945
# Epoch 300 | Train Loss 0.613488 | Val Loss 0.740226
# Epoch 400 | Train Loss 0.572947 | Val Loss 0.811534
# Early stopping at epoch 403
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7931, MSE = 4.7274e-02
# Theta | Train_2 -> R² = 0.7451, MSE = 5.7781e-02
# Theta | Test_1 -> R² = 0.6405, MSE = 8.2703e-02
# Theta | Test_2 -> R² = 0.8360, MSE = 3.8634e-02
# Theta | Test_3 -> R² = -0.7690, MSE = 5.8172e-01
# Theta | Val -> R² = -3.3887, MSE = 1.4363e+00
# Theta | LSG_1 -> R² = 0.6320, MSE = 1.5116e-01
# Theta | LSG_2 -> R² = -3.2743, MSE = 1.4649e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 0.967557 | Val Loss 0.780807
# Epoch 100 | Train Loss 0.701380 | Val Loss 0.589375
# Epoch 200 | Train Loss 0.638739 | Val Loss 0.614638
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6044, MSE = 9.0394e-02
# Theta | Train_2 -> R² = 0.3003, MSE = 1.5863e-01
# Theta | Test_1 -> R² = 0.3487, MSE = 1.4982e-01
# Theta | Test_2 -> R² = 0.7981, MSE = 4.7547e-02
# Theta | Test_3 -> R² = 0.5536, MSE = 1.4680e-01
# Theta | Val -> R² = -3.2841, MSE = 1.4021e+00
# Theta | LSG_1 -> R² = 0.6817, MSE = 1.3073e-01
# Theta | LSG_2 -> R² = -0.8265, MSE = 6.2600e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 0.991487 | Val Loss 0.836150
# Epoch 100 | Train Loss 0.700240 | Val Loss 0.588427
# Epoch 200 | Train Loss 0.647629 | Val Loss 0.671888
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.6207, MSE = 8.6688e-02
# Theta | Train_2 -> R² = 0.1855, MSE = 1.8467e-01
# Theta | Test_1 -> R² = 0.3492, MSE = 1.4971e-01
# Theta | Test_2 -> R² = 0.7375, MSE = 6.1828e-02
# Theta | Test_3 -> R² = 0.5997, MSE = 1.3163e-01
# Theta | Val -> R² = -2.3728, MSE = 1.1038e+00
# Theta | LSG_1 -> R² = 0.7451, MSE = 1.0471e-01
# Theta | LSG_2 -> R² = -0.2322, MSE = 4.2229e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.972652 | Val Loss 0.788636
# Epoch 100 | Train Loss 0.708244 | Val Loss 0.587453
# Epoch 200 | Train Loss 0.655639 | Val Loss 0.587444
# Early stopping at epoch 231
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.5625, MSE = 9.9970e-02
# Theta | Train_2 -> R² = 0.2326, MSE = 1.7400e-01
# Theta | Test_1 -> R² = 0.1667, MSE = 1.9167e-01
# Theta | Test_2 -> R² = 0.7358, MSE = 6.2232e-02
# Theta | Test_3 -> R² = 0.5534, MSE = 1.4687e-01
# Theta | Val -> R² = -4.3209, MSE = 1.7414e+00
# Theta | LSG_1 -> R² = 0.5479, MSE = 1.8570e-01
# Theta | LSG_2 -> R² = -1.6664, MSE = 9.1385e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 0.956266 | Val Loss 0.777610
# Epoch 100 | Train Loss 0.720684 | Val Loss 0.643590
# Epoch 200 | Train Loss 0.657049 | Val Loss 0.580654
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7582, MSE = 5.5256e-02
# Theta | Train_2 -> R² = 0.3474, MSE = 1.4797e-01
# Theta | Test_1 -> R² = 0.3234, MSE = 1.5564e-01
# Theta | Test_2 -> R² = 0.8686, MSE = 3.0945e-02
# Theta | Test_3 -> R² = 0.5500, MSE = 1.4798e-01
# Theta | Val -> R² = -5.6050, MSE = 2.1616e+00
# Theta | LSG_1 -> R² = 0.4741, MSE = 2.1602e-01
# Theta | LSG_2 -> R² = -2.2776, MSE = 1.1233e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 0.989610 | Val Loss 0.812252
# Epoch 100 | Train Loss 0.717092 | Val Loss 0.633426
# Epoch 200 | Train Loss 0.618824 | Val Loss 0.680561
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.6569, MSE = 7.8417e-02
# Theta | Train_2 -> R² = 0.4302, MSE = 1.2919e-01
# Theta | Test_1 -> R² = 0.1086, MSE = 2.0505e-01
# Theta | Test_2 -> R² = 0.8847, MSE = 2.7165e-02
# Theta | Test_3 -> R² = 0.4772, MSE = 1.7190e-01
# Theta | Val -> R² = -6.6002, MSE = 2.4873e+00
# Theta | LSG_1 -> R² = 0.3262, MSE = 2.7676e-01
# Theta | LSG_2 -> R² = -2.9351, MSE = 1.3486e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 1.004505 | Val Loss 0.837409
# Epoch 100 | Train Loss 0.733598 | Val Loss 0.618578
# Epoch 200 | Train Loss 0.663385 | Val Loss 0.620875
# Early stopping at epoch 242
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6629, MSE = 7.7029e-02
# Theta | Train_2 -> R² = 0.5599, MSE = 9.9786e-02
# Theta | Test_1 -> R² = 0.1179, MSE = 2.0291e-01
# Theta | Test_2 -> R² = 0.8748, MSE = 2.9487e-02
# Theta | Test_3 -> R² = 0.2482, MSE = 2.4723e-01
# Theta | Val -> R² = -8.5959, MSE = 3.1405e+00
# Theta | LSG_1 -> R² = -0.0891, MSE = 4.4736e-01
# Theta | LSG_2 -> R² = -4.3563, MSE = 1.8357e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 0.987087 | Val Loss 0.818605
# Epoch 100 | Train Loss 0.717839 | Val Loss 0.631764
# Epoch 200 | Train Loss 0.601510 | Val Loss 0.698497
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.6362, MSE = 8.3139e-02
# Theta | Train_2 -> R² = 0.4939, MSE = 1.1475e-01
# Theta | Test_1 -> R² = -0.0306, MSE = 2.3706e-01
# Theta | Test_2 -> R² = 0.8671, MSE = 3.1298e-02
# Theta | Test_3 -> R² = 0.5133, MSE = 1.6004e-01
# Theta | Val -> R² = -7.4642, MSE = 2.7701e+00
# Theta | LSG_1 -> R² = -0.0381, MSE = 4.2641e-01
# Theta | LSG_2 -> R² = -4.2436, MSE = 1.7971e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 0.987620 | Val Loss 0.826351
# Epoch 100 | Train Loss 0.737286 | Val Loss 0.614708
# Epoch 200 | Train Loss 0.667234 | Val Loss 0.625036
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.6804, MSE = 7.3045e-02
# Theta | Train_2 -> R² = 0.4485, MSE = 1.2504e-01
# Theta | Test_1 -> R² = 0.0518, MSE = 2.1811e-01
# Theta | Test_2 -> R² = 0.8416, MSE = 3.7313e-02
# Theta | Test_3 -> R² = 0.5598, MSE = 1.4474e-01
# Theta | Val -> R² = -7.4825, MSE = 2.7761e+00
# Theta | LSG_1 -> R² = 0.0005, MSE = 4.1057e-01
# Theta | LSG_2 -> R² = -4.0067, MSE = 1.7159e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 0.986275 | Val Loss 0.790785
# Epoch 100 | Train Loss 0.723881 | Val Loss 0.632798
# Epoch 200 | Train Loss 0.659162 | Val Loss 0.590530
# Early stopping at epoch 226
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7181, MSE = 6.4432e-02
# Theta | Train_2 -> R² = 0.4698, MSE = 1.2021e-01
# Theta | Test_1 -> R² = 0.2066, MSE = 1.8249e-01
# Theta | Test_2 -> R² = 0.8680, MSE = 3.1093e-02
# Theta | Test_3 -> R² = 0.5568, MSE = 1.4573e-01
# Theta | Val -> R² = -6.6372, MSE = 2.4995e+00
# Theta | LSG_1 -> R² = 0.1221, MSE = 3.6062e-01
# Theta | LSG_2 -> R² = -3.5421, MSE = 1.5567e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 0.965487 | Val Loss 0.787456
# Epoch 100 | Train Loss 0.718234 | Val Loss 0.634230
# Epoch 200 | Train Loss 0.662632 | Val Loss 0.608180
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.5068, MSE = 1.1271e-01
# Theta | Train_2 -> R² = 0.2846, MSE = 1.6219e-01
# Theta | Test_1 -> R² = -0.0690, MSE = 2.4589e-01
# Theta | Test_2 -> R² = 0.8013, MSE = 4.6813e-02
# Theta | Test_3 -> R² = 0.3121, MSE = 2.2622e-01
# Theta | Val -> R² = -7.7264, MSE = 2.8559e+00
# Theta | LSG_1 -> R² = 0.2548, MSE = 3.0612e-01
# Theta | LSG_2 -> R² = -3.0535, MSE = 1.3892e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 1.022793 | Val Loss 0.845612
# Epoch 100 | Train Loss 0.749735 | Val Loss 0.595316
# Epoch 200 | Train Loss 0.692441 | Val Loss 0.611832
# Early stopping at epoch 244
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6808, MSE = 7.2941e-02
# Theta | Train_2 -> R² = 0.5812, MSE = 9.4955e-02
# Theta | Test_1 -> R² = 0.1615, MSE = 1.9286e-01
# Theta | Test_2 -> R² = 0.8745, MSE = 2.9557e-02
# Theta | Test_3 -> R² = 0.3275, MSE = 2.2113e-01
# Theta | Val -> R² = -7.9352, MSE = 2.9242e+00
# Theta | LSG_1 -> R² = -0.0075, MSE = 4.1388e-01
# Theta | LSG_2 -> R² = -4.2434, MSE = 1.7970e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 0.980277 | Val Loss 0.801181
# Epoch 100 | Train Loss 0.715167 | Val Loss 0.629936
# Epoch 200 | Train Loss 0.641217 | Val Loss 0.598402
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.6829, MSE = 7.2463e-02
# Theta | Train_2 -> R² = 0.4967, MSE = 1.1410e-01
# Theta | Test_1 -> R² = -0.0516, MSE = 2.4189e-01
# Theta | Test_2 -> R² = 0.8506, MSE = 3.5197e-02
# Theta | Test_3 -> R² = 0.6052, MSE = 1.2983e-01
# Theta | Val -> R² = -7.1343, MSE = 2.6621e+00
# Theta | LSG_1 -> R² = 0.0137, MSE = 4.0516e-01
# Theta | LSG_2 -> R² = -4.1840, MSE = 1.7767e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.985829 | Val Loss 0.801685
# Epoch 100 | Train Loss 0.740537 | Val Loss 0.599824
# Epoch 200 | Train Loss 0.652256 | Val Loss 0.626808
# Early stopping at epoch 240
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.6572, MSE = 7.8333e-02
# Theta | Train_2 -> R² = 0.5290, MSE = 1.0679e-01
# Theta | Test_1 -> R² = 0.1583, MSE = 1.9361e-01
# Theta | Test_2 -> R² = 0.8648, MSE = 3.1846e-02
# Theta | Test_3 -> R² = 0.3160, MSE = 2.2491e-01
# Theta | Val -> R² = -7.7595, MSE = 2.8667e+00
# Theta | LSG_1 -> R² = 0.0326, MSE = 3.9740e-01
# Theta | LSG_2 -> R² = -3.9344, MSE = 1.6911e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 1.039514 | Val Loss 0.793923
# Epoch 100 | Train Loss 0.689873 | Val Loss 0.588371
# Epoch 200 | Train Loss 0.641926 | Val Loss 0.639521
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6842, MSE = 7.2165e-02
# Theta | Train_2 -> R² = 0.4547, MSE = 1.2364e-01
# Theta | Test_1 -> R² = 0.4031, MSE = 1.3730e-01
# Theta | Test_2 -> R² = 0.8313, MSE = 3.9733e-02
# Theta | Test_3 -> R² = 0.6433, MSE = 1.1728e-01
# Theta | Val -> R² = -4.3888, MSE = 1.7636e+00
# Theta | LSG_1 -> R² = 0.2631, MSE = 3.0270e-01
# Theta | LSG_2 -> R² = -2.7467, MSE = 1.2841e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 1.082508 | Val Loss 0.818360
# Epoch 100 | Train Loss 0.696217 | Val Loss 0.591684
# Epoch 200 | Train Loss 0.654802 | Val Loss 0.613113
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7581, MSE = 5.5280e-02
# Theta | Train_2 -> R² = 0.6287, MSE = 8.4182e-02
# Theta | Test_1 -> R² = 0.5054, MSE = 1.1377e-01
# Theta | Test_2 -> R² = 0.8889, MSE = 2.6177e-02
# Theta | Test_3 -> R² = 0.3443, MSE = 2.1563e-01
# Theta | Val -> R² = -6.5451, MSE = 2.4693e+00
# Theta | LSG_1 -> R² = 0.1020, MSE = 3.6888e-01
# Theta | LSG_2 -> R² = -3.8604, MSE = 1.6658e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 0.976334 | Val Loss 0.788919
# Epoch 100 | Train Loss 0.685777 | Val Loss 0.577479
# Epoch 200 | Train Loss 0.632188 | Val Loss 0.677740
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.7984, MSE = 4.6077e-02
# Theta | Train_2 -> R² = 0.6224, MSE = 8.5611e-02
# Theta | Test_1 -> R² = 0.4553, MSE = 1.2528e-01
# Theta | Test_2 -> R² = 0.8642, MSE = 3.1987e-02
# Theta | Test_3 -> R² = 0.2153, MSE = 2.5804e-01
# Theta | Val -> R² = -7.3118, MSE = 2.7202e+00
# Theta | LSG_1 -> R² = 0.1491, MSE = 3.4955e-01
# Theta | LSG_2 -> R² = -3.9532, MSE = 1.6976e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 1.106190 | Val Loss 0.906347
# Epoch 100 | Train Loss 0.690764 | Val Loss 0.585493
# Epoch 200 | Train Loss 0.627815 | Val Loss 0.664435
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7739, MSE = 5.1658e-02
# Theta | Train_2 -> R² = 0.6772, MSE = 7.3195e-02
# Theta | Test_1 -> R² = 0.5832, MSE = 9.5875e-02
# Theta | Test_2 -> R² = 0.9008, MSE = 2.3368e-02
# Theta | Test_3 -> R² = 0.2319, MSE = 2.5259e-01
# Theta | Val -> R² = -6.9473, MSE = 2.6009e+00
# Theta | LSG_1 -> R² = 0.1010, MSE = 3.6928e-01
# Theta | LSG_2 -> R² = -3.9475, MSE = 1.6956e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 1.116214 | Val Loss 0.858369
# Epoch 100 | Train Loss 0.698514 | Val Loss 0.587831
# Epoch 200 | Train Loss 0.650795 | Val Loss 0.597478
# Epoch 300 | Train Loss 0.590994 | Val Loss 0.710172
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7934, MSE = 4.7215e-02
# Theta | Train_2 -> R² = 0.7648, MSE = 5.3323e-02
# Theta | Test_1 -> R² = 0.6991, MSE = 6.9221e-02
# Theta | Test_2 -> R² = 0.8477, MSE = 3.5876e-02
# Theta | Test_3 -> R² = -0.1812, MSE = 3.8841e-01
# Theta | Val -> R² = -3.7270, MSE = 1.5470e+00
# Theta | LSG_1 -> R² = 0.6045, MSE = 1.6247e-01
# Theta | LSG_2 -> R² = -3.7602, MSE = 1.6314e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 0.986575 | Val Loss 0.815025
# Epoch 100 | Train Loss 0.675524 | Val Loss 0.589408
# Epoch 200 | Train Loss 0.627915 | Val Loss 0.674745
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.8509, MSE = 3.4076e-02
# Theta | Train_2 -> R² = 0.6233, MSE = 8.5400e-02
# Theta | Test_1 -> R² = 0.5779, MSE = 9.7081e-02
# Theta | Test_2 -> R² = 0.8443, MSE = 3.6685e-02
# Theta | Test_3 -> R² = 0.6154, MSE = 1.2647e-01
# Theta | Val -> R² = -5.4577, MSE = 2.1134e+00
# Theta | LSG_1 -> R² = 0.2295, MSE = 3.1651e-01
# Theta | LSG_2 -> R² = -3.7143, MSE = 1.6157e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 1.027296 | Val Loss 0.818801
# Epoch 100 | Train Loss 0.682469 | Val Loss 0.579727
# Epoch 200 | Train Loss 0.632554 | Val Loss 0.693991
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.8131, MSE = 4.2719e-02
# Theta | Train_2 -> R² = 0.6277, MSE = 8.4407e-02
# Theta | Test_1 -> R² = 0.6237, MSE = 8.6563e-02
# Theta | Test_2 -> R² = 0.8472, MSE = 3.5999e-02
# Theta | Test_3 -> R² = 0.4290, MSE = 1.8776e-01
# Theta | Val -> R² = -5.6182, MSE = 2.1659e+00
# Theta | LSG_1 -> R² = 0.4105, MSE = 2.4217e-01
# Theta | LSG_2 -> R² = -3.0951, MSE = 1.4035e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 1.025823 | Val Loss 0.802884
# Epoch 100 | Train Loss 0.682333 | Val Loss 0.586917
# Epoch 200 | Train Loss 0.629214 | Val Loss 0.630587
# Early stopping at epoch 219
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.7295, MSE = 6.1814e-02
# Theta | Train_2 -> R² = 0.5010, MSE = 1.1314e-01
# Theta | Test_1 -> R² = 0.4106, MSE = 1.3558e-01
# Theta | Test_2 -> R² = 0.8651, MSE = 3.1780e-02
# Theta | Test_3 -> R² = 0.5592, MSE = 1.4497e-01
# Theta | Val -> R² = -5.4523, MSE = 2.1116e+00
# Theta | LSG_1 -> R² = 0.3228, MSE = 2.7819e-01
# Theta | LSG_2 -> R² = -2.7854, MSE = 1.2973e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 1.018351 | Val Loss 0.819675
# Epoch 100 | Train Loss 0.679007 | Val Loss 0.591737
# Epoch 200 | Train Loss 0.622137 | Val Loss 0.680254
# Early stopping at epoch 221
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7224, MSE = 6.3442e-02
# Theta | Train_2 -> R² = 0.6475, MSE = 7.9929e-02
# Theta | Test_1 -> R² = 0.4553, MSE = 1.2530e-01
# Theta | Test_2 -> R² = 0.9069, MSE = 2.1938e-02
# Theta | Test_3 -> R² = 0.3420, MSE = 2.1638e-01
# Theta | Val -> R² = -6.5520, MSE = 2.4716e+00
# Theta | LSG_1 -> R² = 0.0805, MSE = 3.7770e-01
# Theta | LSG_2 -> R² = -3.7164, MSE = 1.6164e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 1.152953 | Val Loss 0.843666
# Epoch 100 | Train Loss 0.694736 | Val Loss 0.587126
# Epoch 200 | Train Loss 0.652467 | Val Loss 0.653379
# Early stopping at epoch 235
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7748, MSE = 5.1472e-02
# Theta | Train_2 -> R² = 0.6654, MSE = 7.5862e-02
# Theta | Test_1 -> R² = 0.4629, MSE = 1.2354e-01
# Theta | Test_2 -> R² = 0.8828, MSE = 2.7599e-02
# Theta | Test_3 -> R² = 0.3517, MSE = 2.1319e-01
# Theta | Val -> R² = -6.9504, MSE = 2.6019e+00
# Theta | LSG_1 -> R² = 0.0508, MSE = 3.8992e-01
# Theta | LSG_2 -> R² = -4.0843, MSE = 1.7425e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 1.089702 | Val Loss 0.858203
# Epoch 100 | Train Loss 0.692900 | Val Loss 0.622331
# Epoch 200 | Train Loss 0.590764 | Val Loss 0.719520
# Early stopping at epoch 217
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7309, MSE = 6.1506e-02
# Theta | Train_2 -> R² = 0.3056, MSE = 1.5744e-01
# Theta | Test_1 -> R² = 0.4840, MSE = 1.1868e-01
# Theta | Test_2 -> R² = 0.7381, MSE = 6.1681e-02
# Theta | Test_3 -> R² = 0.3669, MSE = 2.0818e-01
# Theta | Val -> R² = -5.9681, MSE = 2.2805e+00
# Theta | LSG_1 -> R² = 0.5151, MSE = 1.9920e-01
# Theta | LSG_2 -> R² = -1.8394, MSE = 9.7311e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 0.905482 | Val Loss 0.659436
# Epoch 100 | Train Loss 0.691328 | Val Loss 0.651058
# Epoch 200 | Train Loss 0.587516 | Val Loss 0.795016
# Early stopping at epoch 207
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.5196, MSE = 1.0978e-01
# Theta | Train_2 -> R² = 0.3581, MSE = 1.4555e-01
# Theta | Test_1 -> R² = -0.0183, MSE = 2.3422e-01
# Theta | Test_2 -> R² = 0.7026, MSE = 7.0062e-02
# Theta | Test_3 -> R² = -0.2239, MSE = 4.0246e-01
# Theta | Val -> R² = -10.4602, MSE = 3.7506e+00
# Theta | LSG_1 -> R² = -0.4603, MSE = 5.9986e-01
# Theta | LSG_2 -> R² = -5.4232, MSE = 2.2014e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 0.969770 | Val Loss 0.742884
# Epoch 100 | Train Loss 0.696143 | Val Loss 0.619836
# Epoch 200 | Train Loss 0.603309 | Val Loss 0.620087
# Epoch 300 | Train Loss 0.555545 | Val Loss 0.866285
# Early stopping at epoch 360
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6997, MSE = 6.8628e-02
# Theta | Train_2 -> R² = 0.8041, MSE = 4.4423e-02
# Theta | Test_1 -> R² = 0.4963, MSE = 1.1587e-01
# Theta | Test_2 -> R² = 0.6485, MSE = 8.2806e-02
# Theta | Test_3 -> R² = -8.6047, MSE = 3.1584e+00
# Theta | Val -> R² = -18.0501, MSE = 6.2346e+00
# Theta | LSG_1 -> R² = -0.9923, MSE = 8.1839e-01
# Theta | LSG_2 -> R² = -8.6224, MSE = 3.2978e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 1.034908 | Val Loss 0.810879
# Epoch 100 | Train Loss 0.705558 | Val Loss 0.633072
# Epoch 200 | Train Loss 0.604199 | Val Loss 0.641489
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7309, MSE = 6.1502e-02
# Theta | Train_2 -> R² = 0.2968, MSE = 1.5944e-01
# Theta | Test_1 -> R² = 0.4609, MSE = 1.2401e-01
# Theta | Test_2 -> R² = 0.7289, MSE = 6.3857e-02
# Theta | Test_3 -> R² = 0.3913, MSE = 2.0016e-01
# Theta | Val -> R² = -5.8945, MSE = 2.2564e+00
# Theta | LSG_1 -> R² = 0.4875, MSE = 2.1051e-01
# Theta | LSG_2 -> R² = -1.9580, MSE = 1.0138e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 1.084713 | Val Loss 0.807372
# Epoch 100 | Train Loss 0.708767 | Val Loss 0.642222
# Epoch 200 | Train Loss 0.598597 | Val Loss 0.657811
# Epoch 300 | Train Loss 0.558168 | Val Loss 0.900254
# Early stopping at epoch 365
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.6251, MSE = 8.5677e-02
# Theta | Train_2 -> R² = 0.8481, MSE = 3.4450e-02
# Theta | Test_1 -> R² = 0.0995, MSE = 2.0712e-01
# Theta | Test_2 -> R² = 0.6751, MSE = 7.6532e-02
# Theta | Test_3 -> R² = -8.1342, MSE = 3.0037e+00
# Theta | Val -> R² = -20.7799, MSE = 7.1280e+00
# Theta | LSG_1 -> R² = -0.4647, MSE = 6.0167e-01
# Theta | LSG_2 -> R² = -10.4138, MSE = 3.9118e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 0.934287 | Val Loss 0.723785
# Epoch 100 | Train Loss 0.675892 | Val Loss 0.602417
# Epoch 200 | Train Loss 0.578788 | Val Loss 0.831908
# Early stopping at epoch 208
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.3187, MSE = 1.5569e-01
# Theta | Train_2 -> R² = 0.1239, MSE = 1.9862e-01
# Theta | Test_1 -> R² = -0.1701, MSE = 2.6914e-01
# Theta | Test_2 -> R² = 0.5543, MSE = 1.0497e-01
# Theta | Test_3 -> R² = -0.3110, MSE = 4.3111e-01
# Theta | Val -> R² = -8.7835, MSE = 3.2019e+00
# Theta | LSG_1 -> R² = -0.1071, MSE = 4.5478e-01
# Theta | LSG_2 -> R² = -4.0851, MSE = 1.7428e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 0.980407 | Val Loss 0.743010
# Epoch 100 | Train Loss 0.690874 | Val Loss 0.639224
# Epoch 200 | Train Loss 0.583729 | Val Loss 0.841454
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7241, MSE = 6.3048e-02
# Theta | Train_2 -> R² = 0.3974, MSE = 1.3663e-01
# Theta | Test_1 -> R² = 0.4984, MSE = 1.1537e-01
# Theta | Test_2 -> R² = 0.7902, MSE = 4.9420e-02
# Theta | Test_3 -> R² = 0.1976, MSE = 2.6386e-01
# Theta | Val -> R² = -7.3336, MSE = 2.7274e+00
# Theta | LSG_1 -> R² = 0.2734, MSE = 2.9848e-01
# Theta | LSG_2 -> R² = -2.7768, MSE = 1.2944e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 1.002214 | Val Loss 0.756407
# Epoch 100 | Train Loss 0.701120 | Val Loss 0.619716
# Epoch 200 | Train Loss 0.583761 | Val Loss 0.787220
# Early stopping at epoch 211
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.7870, MSE = 4.8670e-02
# Theta | Train_2 -> R² = 0.4293, MSE = 1.2938e-01
# Theta | Test_1 -> R² = 0.4482, MSE = 1.2691e-01
# Theta | Test_2 -> R² = 0.7618, MSE = 5.6116e-02
# Theta | Test_3 -> R² = 0.2744, MSE = 2.3861e-01
# Theta | Val -> R² = -8.1592, MSE = 2.9975e+00
# Theta | LSG_1 -> R² = 0.0491, MSE = 3.9061e-01
# Theta | LSG_2 -> R² = -3.8307, MSE = 1.6556e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 1.007448 | Val Loss 0.786783
# Epoch 100 | Train Loss 0.696713 | Val Loss 0.629891
# Epoch 200 | Train Loss 0.593337 | Val Loss 0.702519
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.6341, MSE = 8.3618e-02
# Theta | Train_2 -> R² = 0.1543, MSE = 1.9175e-01
# Theta | Test_1 -> R² = 0.2059, MSE = 1.8265e-01
# Theta | Test_2 -> R² = 0.6271, MSE = 8.7840e-02
# Theta | Test_3 -> R² = 0.5518, MSE = 1.4738e-01
# Theta | Val -> R² = -6.4521, MSE = 2.4389e+00
# Theta | LSG_1 -> R² = 0.2437, MSE = 3.1066e-01
# Theta | LSG_2 -> R² = -2.8515, MSE = 1.3200e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.975874 | Val Loss 0.761422
# Epoch 100 | Train Loss 0.693525 | Val Loss 0.605384
# Epoch 200 | Train Loss 0.585092 | Val Loss 0.767584
# Early stopping at epoch 210
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7451, MSE = 5.8241e-02
# Theta | Train_2 -> R² = 0.4932, MSE = 1.1489e-01
# Theta | Test_1 -> R² = 0.4597, MSE = 1.2429e-01
# Theta | Test_2 -> R² = 0.8246, MSE = 4.1321e-02
# Theta | Test_3 -> R² = 0.1188, MSE = 2.8979e-01
# Theta | Val -> R² = -8.2110, MSE = 3.0145e+00
# Theta | LSG_1 -> R² = 0.0817, MSE = 3.7721e-01
# Theta | LSG_2 -> R² = -3.7841, MSE = 1.6396e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 1.160956 | Val Loss 0.789720
# Epoch 100 | Train Loss 0.677991 | Val Loss 0.578645
# Epoch 200 | Train Loss 0.620104 | Val Loss 0.720996
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7957, MSE = 4.6680e-02
# Theta | Train_2 -> R² = 0.6477, MSE = 7.9868e-02
# Theta | Test_1 -> R² = 0.4015, MSE = 1.3767e-01
# Theta | Test_2 -> R² = 0.8214, MSE = 4.2059e-02
# Theta | Test_3 -> R² = 0.2377, MSE = 2.5069e-01
# Theta | Val -> R² = -9.2686, MSE = 3.3606e+00
# Theta | LSG_1 -> R² = -0.4996, MSE = 6.1599e-01
# Theta | LSG_2 -> R² = -6.2621, MSE = 2.4889e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 1.074757 | Val Loss 0.724025
# Epoch 100 | Train Loss 0.677619 | Val Loss 0.576537
# Epoch 200 | Train Loss 0.620614 | Val Loss 0.685815
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7951, MSE = 4.6823e-02
# Theta | Train_2 -> R² = 0.6529, MSE = 7.8698e-02
# Theta | Test_1 -> R² = 0.5307, MSE = 1.0796e-01
# Theta | Test_2 -> R² = 0.8665, MSE = 3.1440e-02
# Theta | Test_3 -> R² = 0.4730, MSE = 1.7331e-01
# Theta | Val -> R² = -6.4669, MSE = 2.4437e+00
# Theta | LSG_1 -> R² = -0.0307, MSE = 4.2340e-01
# Theta | LSG_2 -> R² = -4.7564, MSE = 1.9729e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 1.152243 | Val Loss 0.727789
# Epoch 100 | Train Loss 0.677846 | Val Loss 0.574938
# Epoch 200 | Train Loss 0.628670 | Val Loss 0.673622
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.7861, MSE = 4.8882e-02
# Theta | Train_2 -> R² = 0.6149, MSE = 8.7320e-02
# Theta | Test_1 -> R² = 0.4390, MSE = 1.2904e-01
# Theta | Test_2 -> R² = 0.8400, MSE = 3.7689e-02
# Theta | Test_3 -> R² = 0.3069, MSE = 2.2793e-01
# Theta | Val -> R² = -7.5153, MSE = 2.7868e+00
# Theta | LSG_1 -> R² = -0.0865, MSE = 4.4631e-01
# Theta | LSG_2 -> R² = -4.9621, MSE = 2.0433e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 1.064668 | Val Loss 0.757764
# Epoch 100 | Train Loss 0.673828 | Val Loss 0.573449
# Epoch 200 | Train Loss 0.624975 | Val Loss 0.682601
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch128_r0.01_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch128_r0.01_Ld0.3_Lp0.7_seed1553.weights.h5
# ...
# Early stopping at epoch 287
# Modelo salvo em:
# models/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch128-64-32_r0.9_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7905, MSE = 4.7874e-02
# Theta | Train_2 -> R² = 0.7763, MSE = 5.0724e-02
# Theta | Test_1 -> R² = 0.5763, MSE = 9.7458e-02
# Theta | Test_2 -> R² = 0.6632, MSE = 7.9340e-02
# Theta | Test_3 -> R² = -5.3086, MSE = 2.0745e+00
# Theta | Val -> R² = -8.7748, MSE = 3.1990e+00
# Theta | LSG_1 -> R² = 0.0162, MSE = 4.0412e-01
# Theta | LSG_2 -> R² = -5.0668, MSE = 2.0792e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 0.936884 | Val Loss 0.642808
# Epoch 100 | Train Loss 0.621308 | Val Loss 0.658954
# Epoch 200 | Train Loss 0.542118 | Val Loss 0.771372
# Early stopping at epoch 203
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6091, MSE = 8.9336e-02
# Theta | Train_2 -> R² = 0.5193, MSE = 1.0898e-01
# Theta | Test_1 -> R² = 0.5245, MSE = 1.0937e-01
# Theta | Test_2 -> R² = 0.8700, MSE = 3.0614e-02
# Theta | Test_3 -> R² = 0.5757, MSE = 1.3951e-01
# Theta | Val -> R² = -2.1122, MSE = 1.0185e+00
# Theta | LSG_1 -> R² = 0.6451, MSE = 1.4578e-01
# Theta | LSG_2 -> R² = -0.7888, MSE = 6.1306e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 1.050218 | Val Loss 0.658001
# Epoch 100 | Train Loss 0.597630 | Val Loss 0.663688
# Epoch 200 | Train Loss 0.541370 | Val Loss 0.734772
# Early stopping at epoch 203
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.5398, MSE = 1.0518e-01
# Theta | Train_2 -> R² = 0.5008, MSE = 1.1319e-01
# Theta | Test_1 -> R² = 0.1878, MSE = 1.8682e-01
# Theta | Test_2 -> R² = 0.8020, MSE = 4.6628e-02
# Theta | Test_3 -> R² = 0.3171, MSE = 2.2457e-01
# Theta | Val -> R² = -4.9612, MSE = 1.9509e+00
# Theta | LSG_1 -> R² = 0.3513, MSE = 2.6648e-01
# Theta | LSG_2 -> R² = -2.8633, MSE = 1.3240e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 1.005389 | Val Loss 0.645045
# Epoch 100 | Train Loss 0.590149 | Val Loss 0.662800
# Epoch 200 | Train Loss 0.526142 | Val Loss 0.748111
# Early stopping at epoch 207
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.8579, MSE = 3.2476e-02
# Theta | Train_2 -> R² = 0.5066, MSE = 1.1186e-01
# Theta | Test_1 -> R² = 0.8210, MSE = 4.1182e-02
# Theta | Test_2 -> R² = 0.7619, MSE = 5.6077e-02
# Theta | Test_3 -> R² = 0.7489, MSE = 8.2559e-02
# Theta | Val -> R² = -1.4735, MSE = 8.0951e-01
# Theta | LSG_1 -> R² = 0.6045, MSE = 1.6246e-01
# Theta | LSG_2 -> R² = -0.0370, MSE = 3.5542e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 0.988747 | Val Loss 0.567739
# Epoch 100 | Train Loss 0.600420 | Val Loss 0.696864
# Epoch 200 | Train Loss 0.523606 | Val Loss 0.766452
# Early stopping at epoch 204
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.7707, MSE = 5.2405e-02
# Theta | Train_2 -> R² = 0.7400, MSE = 5.8949e-02
# Theta | Test_1 -> R² = 0.5573, MSE = 1.0184e-01
# Theta | Test_2 -> R² = 0.8709, MSE = 3.0419e-02
# Theta | Test_3 -> R² = 0.2721, MSE = 2.3935e-01
# Theta | Val -> R² = -5.6920, MSE = 2.1901e+00
# Theta | LSG_1 -> R² = 0.3169, MSE = 2.8060e-01
# Theta | LSG_2 -> R² = -3.3349, MSE = 1.4857e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 1.026392 | Val Loss 0.751536
# Epoch 100 | Train Loss 0.615731 | Val Loss 0.638314
# Epoch 200 | Train Loss 0.537369 | Val Loss 0.719926
# Early stopping at epoch 204
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.5452, MSE = 1.0393e-01
# Theta | Train_2 -> R² = 0.1948, MSE = 1.8257e-01
# Theta | Test_1 -> R² = 0.2395, MSE = 1.7492e-01
# Theta | Test_2 -> R² = 0.6200, MSE = 8.9500e-02
# Theta | Test_3 -> R² = 0.7924, MSE = 6.8255e-02
# Theta | Val -> R² = -3.2821, MSE = 1.4014e+00
# Theta | LSG_1 -> R² = 0.5069, MSE = 2.0256e-01
# Theta | LSG_2 -> R² = -1.7810, MSE = 9.5311e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 1.001735 | Val Loss 0.886464
# Epoch 100 | Train Loss 0.626928 | Val Loss 0.600196
# Epoch 200 | Train Loss 0.540795 | Val Loss 0.708147
# Early stopping at epoch 210
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5542.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.7879, MSE = 4.8471e-02
# Theta | Train_2 -> R² = 0.5875, MSE = 9.3531e-02
# Theta | Test_1 -> R² = 0.7006, MSE = 6.8879e-02
# Theta | Test_2 -> R² = 0.8506, MSE = 3.5183e-02
# Theta | Test_3 -> R² = 0.7717, MSE = 7.5064e-02
# Theta | Val -> R² = -2.0390, MSE = 9.9459e-01
# Theta | LSG_1 -> R² = 0.6654, MSE = 1.3744e-01
# Theta | LSG_2 -> R² = -1.0919, MSE = 7.1694e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 1.013981 | Val Loss 0.550884
# Epoch 100 | Train Loss 0.614928 | Val Loss 0.642360
# Early stopping at epoch 200
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2682.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.5293, MSE = 1.0756e-01
# Theta | Train_2 -> R² = 0.6255, MSE = 8.4918e-02
# Theta | Test_1 -> R² = 0.2540, MSE = 1.7159e-01
# Theta | Test_2 -> R² = 0.8799, MSE = 2.8296e-02
# Theta | Test_3 -> R² = -0.3989, MSE = 4.6001e-01
# Theta | Val -> R² = -7.5608, MSE = 2.8017e+00
# Theta | LSG_1 -> R² = 0.0794, MSE = 3.7816e-01
# Theta | LSG_2 -> R² = -3.7728, MSE = 1.6358e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 0.972695 | Val Loss 0.637100
# Epoch 100 | Train Loss 0.599289 | Val Loss 0.652246
# Epoch 200 | Train Loss 0.565290 | Val Loss 0.755958
# Early stopping at epoch 203
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2423.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.7607, MSE = 5.4694e-02
# Theta | Train_2 -> R² = 0.5035, MSE = 1.1256e-01
# Theta | Test_1 -> R² = 0.6020, MSE = 9.1552e-02
# Theta | Test_2 -> R² = 0.8346, MSE = 3.8951e-02
# Theta | Test_3 -> R² = 0.7594, MSE = 7.9120e-02
# Theta | Val -> R² = -2.1499, MSE = 1.0309e+00
# Theta | LSG_1 -> R² = 0.5982, MSE = 1.6507e-01
# Theta | LSG_2 -> R² = -1.3832, MSE = 8.1677e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 0.968945 | Val Loss 0.694639
# Epoch 100 | Train Loss 0.596827 | Val Loss 0.665806
# Epoch 200 | Train Loss 0.527936 | Val Loss 0.780878
# Early stopping at epoch 201
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1553.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.5887, MSE = 9.3988e-02
# Theta | Train_2 -> R² = 0.2786, MSE = 1.6355e-01
# Theta | Test_1 -> R² = 0.3139, MSE = 1.5782e-01
# Theta | Test_2 -> R² = 0.7381, MSE = 6.1680e-02
# Theta | Test_3 -> R² = 0.6872, MSE = 1.0285e-01
# Theta | Val -> R² = -3.0644, MSE = 1.3302e+00
# Theta | LSG_1 -> R² = 0.6116, MSE = 1.5954e-01
# Theta | LSG_2 -> R² = -1.3115, MSE = 7.9219e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.978661 | Val Loss 0.929255
# Epoch 100 | Train Loss 0.624053 | Val Loss 0.617899
# Epoch 200 | Train Loss 0.538921 | Val Loss 0.780035
# Early stopping at epoch 264
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3544.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.6711, MSE = 7.5150e-02
# Theta | Train_2 -> R² = 0.7534, MSE = 5.5919e-02
# Theta | Test_1 -> R² = 0.6369, MSE = 8.3528e-02
# Theta | Test_2 -> R² = 0.8799, MSE = 2.8298e-02
# Theta | Test_3 -> R² = 0.0220, MSE = 3.2159e-01
# Theta | Val -> R² = -1.6328, MSE = 8.6163e-01
# Theta | LSG_1 -> R² = 0.5557, MSE = 1.8251e-01
# Theta | LSG_2 -> R² = -2.2427, MSE = 1.1114e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3544 salvo.
# Epoch 0 | Train Loss 1.132647 | Val Loss 0.873068
# Epoch 100 | Train Loss 0.585435 | Val Loss 0.671163
# Epoch 200 | Train Loss 0.520970 | Val Loss 1.013529
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6274, MSE = 8.5151e-02
# Theta | Train_2 -> R² = 0.7638, MSE = 5.3551e-02
# Theta | Test_1 -> R² = 0.5468, MSE = 1.0423e-01
# Theta | Test_2 -> R² = 0.8237, MSE = 4.1532e-02
# Theta | Test_3 -> R² = -5.5681, MSE = 2.1598e+00
# Theta | Val -> R² = -12.8302, MSE = 4.5262e+00
# Theta | LSG_1 -> R² = -0.4339, MSE = 5.8902e-01
# Theta | LSG_2 -> R² = -7.4177, MSE = 2.8849e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5542 salvo.
# Epoch 0 | Train Loss 1.034837 | Val Loss 0.836487
# Epoch 100 | Train Loss 0.596797 | Val Loss 0.549201
# Epoch 200 | Train Loss 0.525238 | Val Loss 0.957632
# Early stopping at epoch 285
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.7683, MSE = 5.2951e-02
# Theta | Train_2 -> R² = 0.8392, MSE = 3.6453e-02
# Theta | Test_1 -> R² = 0.6388, MSE = 8.3078e-02
# Theta | Test_2 -> R² = 0.7414, MSE = 6.0914e-02
# Theta | Test_3 -> R² = -3.2497, MSE = 1.3975e+00
# Theta | Val -> R² = -6.0121, MSE = 2.2949e+00
# Theta | LSG_1 -> R² = 0.3197, MSE = 2.7944e-01
# Theta | LSG_2 -> R² = -4.4887, MSE = 1.8811e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2682 salvo.
# Epoch 0 | Train Loss 0.967392 | Val Loss 0.590636
# Epoch 100 | Train Loss 0.554831 | Val Loss 0.802214
# Epoch 200 | Train Loss 0.509179 | Val Loss 1.013148
# Early stopping at epoch 261
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.9290, MSE = 1.6233e-02
# Theta | Train_2 -> R² = 0.5349, MSE = 1.0546e-01
# Theta | Test_1 -> R² = 0.5484, MSE = 1.0388e-01
# Theta | Test_2 -> R² = 0.4238, MSE = 1.3572e-01
# Theta | Test_3 -> R² = -0.9364, MSE = 6.3675e-01
# Theta | Val -> R² = -5.8901, MSE = 2.2550e+00
# Theta | LSG_1 -> R² = -0.4148, MSE = 5.8115e-01
# Theta | LSG_2 -> R² = -3.8254, MSE = 1.6538e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2423 salvo.
# Epoch 0 | Train Loss 0.937243 | Val Loss 0.710331
# Epoch 100 | Train Loss 0.582145 | Val Loss 0.592235
# Epoch 200 | Train Loss 0.531725 | Val Loss 0.981220
# Early stopping at epoch 278
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.8937, MSE = 2.4284e-02
# Theta | Train_2 -> R² = 0.3220, MSE = 1.5373e-01
# Theta | Test_1 -> R² = 0.4602, MSE = 1.2416e-01
# Theta | Test_2 -> R² = 0.2497, MSE = 1.7674e-01
# Theta | Test_3 -> R² = -5.5973, MSE = 2.1694e+00
# Theta | Val -> R² = -11.4564, MSE = 4.0766e+00
# Theta | LSG_1 -> R² = -0.4122, MSE = 5.8010e-01
# Theta | LSG_2 -> R² = -3.1927, MSE = 1.4369e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1553 salvo.
# Epoch 0 | Train Loss 0.942471 | Val Loss 0.649652
# Epoch 100 | Train Loss 0.584239 | Val Loss 0.725538
# Epoch 200 | Train Loss 0.519550 | Val Loss 1.045700
# Early stopping at epoch 207
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.8470, MSE = 3.4963e-02
# Theta | Train_2 -> R² = 0.6227, MSE = 8.5549e-02
# Theta | Test_1 -> R² = 0.8491, MSE = 3.4718e-02
# Theta | Test_2 -> R² = 0.7466, MSE = 5.9686e-02
# Theta | Test_3 -> R² = 0.5254, MSE = 1.5608e-01
# Theta | Val -> R² = -5.8728, MSE = 2.2493e+00
# Theta | LSG_1 -> R² = 0.4070, MSE = 2.4358e-01
# Theta | LSG_2 -> R² = -2.9921, MSE = 1.3682e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3544 salvo.
# Epoch 0 | Train Loss 1.021497 | Val Loss 0.566101
# Epoch 100 | Train Loss 0.558399 | Val Loss 0.770026
# Epoch 200 | Train Loss 0.508659 | Val Loss 1.037760
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5542.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5542.weights.h5
# Theta | Train_1 -> R² = 0.6692, MSE = 7.5597e-02
# Theta | Train_2 -> R² = -0.0919, MSE = 2.4757e-01
# Theta | Test_1 -> R² = -0.0163, MSE = 2.3377e-01
# Theta | Test_2 -> R² = -0.4156, MSE = 3.3344e-01
# Theta | Test_3 -> R² = 0.5619, MSE = 1.4405e-01
# Theta | Val -> R² = -2.1967, MSE = 1.0462e+00
# Theta | LSG_1 -> R² = -1.4264, MSE = 9.9669e-01
# Theta | LSG_2 -> R² = -1.0289, MSE = 6.9535e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5542 salvo.
# Epoch 0 | Train Loss 1.016662 | Val Loss 0.858743
# Epoch 100 | Train Loss 0.576399 | Val Loss 0.607432
# Epoch 200 | Train Loss 0.531880 | Val Loss 1.032361
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2682.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2682.weights.h5
# Theta | Train_1 -> R² = 0.8089, MSE = 4.3679e-02
# Theta | Train_2 -> R² = 0.8218, MSE = 4.0397e-02
# Theta | Test_1 -> R² = 0.5712, MSE = 9.8633e-02
# Theta | Test_2 -> R² = 0.6526, MSE = 8.1824e-02
# Theta | Test_3 -> R² = -3.3893, MSE = 1.4434e+00
# Theta | Val -> R² = -7.8081, MSE = 2.8827e+00
# Theta | LSG_1 -> R² = 0.0328, MSE = 3.9729e-01
# Theta | LSG_2 -> R² = -6.1353, MSE = 2.4454e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2682 salvo.
# Epoch 0 | Train Loss 1.006343 | Val Loss 0.741384
# Epoch 100 | Train Loss 0.572859 | Val Loss 0.621693
# Epoch 200 | Train Loss 0.547461 | Val Loss 1.081460
# Early stopping at epoch 279
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2423.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2423.weights.h5
# Theta | Train_1 -> R² = 0.6437, MSE = 8.1415e-02
# Theta | Train_2 -> R² = 0.8139, MSE = 4.2187e-02
# Theta | Test_1 -> R² = 0.5179, MSE = 1.1089e-01
# Theta | Test_2 -> R² = 0.8139, MSE = 4.3826e-02
# Theta | Test_3 -> R² = -3.2121, MSE = 1.3851e+00
# Theta | Val -> R² = -5.9664, MSE = 2.2799e+00
# Theta | LSG_1 -> R² = 0.1531, MSE = 3.4788e-01
# Theta | LSG_2 -> R² = -5.8919, MSE = 2.3620e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2423 salvo.
# Epoch 0 | Train Loss 0.994708 | Val Loss 0.722721
# Epoch 100 | Train Loss 0.585084 | Val Loss 0.623588
# Epoch 200 | Train Loss 0.514424 | Val Loss 1.062228
# Early stopping at epoch 275
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1553.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1553.weights.h5
# Theta | Train_1 -> R² = 0.6792, MSE = 7.3301e-02
# Theta | Train_2 -> R² = -0.0624, MSE = 2.4087e-01
# Theta | Test_1 -> R² = 0.1432, MSE = 1.9708e-01
# Theta | Test_2 -> R² = -0.3543, MSE = 3.1900e-01
# Theta | Test_3 -> R² = -0.8349, MSE = 6.0337e-01
# Theta | Val -> R² = -4.1539, MSE = 1.6867e+00
# Theta | LSG_1 -> R² = -1.2104, MSE = 9.0797e-01
# Theta | LSG_2 -> R² = -1.2334, MSE = 7.6545e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1553 salvo.
# Epoch 0 | Train Loss 0.941931 | Val Loss 0.669591
# Epoch 100 | Train Loss 0.587897 | Val Loss 0.564038
# Epoch 200 | Train Loss 0.514725 | Val Loss 1.088295
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3544.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3544.weights.h5
# Theta | Train_1 -> R² = 0.7389, MSE = 5.9663e-02
# Theta | Train_2 -> R² = 0.8431, MSE = 3.5570e-02
# Theta | Test_1 -> R² = 0.4067, MSE = 1.3648e-01
# Theta | Test_2 -> R² = 0.7119, MSE = 6.7852e-02
# Theta | Test_3 -> R² = -9.6766, MSE = 3.5109e+00
# Theta | Val -> R² = -11.7590, MSE = 4.1757e+00
# Theta | LSG_1 -> R² = 0.2535, MSE = 3.0664e-01
# Theta | LSG_2 -> R² = -6.0356, MSE = 2.4113e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3544 salvo.
