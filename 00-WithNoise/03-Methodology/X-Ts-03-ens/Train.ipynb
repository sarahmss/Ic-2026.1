# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(Theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "cosTheta"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./Data/Datasets.xlsx", sheet_name=title)
    df_theta = pd.read_excel("./Data/Theta.xlsx", sheet_name=title)

    df["Theta_ens"] = df_theta["Theta_ens"]

    df["cosTheta"] = np.cos(df["Theta_ens"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1937, 3, 5)
# Dimensão da saida: (1937, 1)
# Dimensão da entrada: (1262, 3, 5)
# Dimensão da saida: (1262, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1937, 3, 5)
# Dimensão da saida: (1937, 1)
# Dimensão da entrada fisica : (1937,)
# Dimensão da entrada fisica: (1937,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    return [dx_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 0.420258 | Val Loss 0.714685
# Epoch 100 | Train Loss 0.158936 | Val Loss 0.436354
# Epoch 200 | Train Loss 0.153696 | Val Loss 0.430352
# Epoch 300 | Train Loss 0.150019 | Val Loss 0.418901
# Epoch 400 | Train Loss 0.146240 | Val Loss 0.411926
# Epoch 500 | Train Loss 0.143015 | Val Loss 0.408291
# Epoch 600 | Train Loss 0.141359 | Val Loss 0.408349
# Early stopping at epoch 688
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9931, MSE = 7.3651e-04
# X | Train_2 -> R² = 0.9964, MSE = 3.0008e-04
# X | Test_1 -> R² = 0.9913, MSE = 9.0517e-04
# X | Test_2 -> R² = 0.7038, MSE = 2.4309e-02
# X | Test_3 -> R² = -2.2722, MSE = 2.9922e-01
# X | Val -> R² = 0.1113, MSE = 8.4378e-02
# X | LSG_1 -> R² = -0.2577, MSE = 1.2788e-01
# X | LSG_2 -> R² = -3.1831, MSE = 3.6882e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.433960 | Val Loss 0.687672
# Epoch 100 | Train Loss 0.168258 | Val Loss 0.439612
# Epoch 200 | Train Loss 0.155617 | Val Loss 0.439227
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.6797, MSE = 3.4250e-02
# X | Train_2 -> R² = 0.6532, MSE = 2.9147e-02
# X | Test_1 -> R² = 0.4415, MSE = 5.8030e-02
# X | Test_2 -> R² = 0.7392, MSE = 2.1401e-02
# X | Test_3 -> R² = -11.1492, MSE = 1.1109e+00
# X | Val -> R² = -5.8594, MSE = 6.5130e-01
# X | LSG_1 -> R² = -0.5817, MSE = 1.6083e-01
# X | LSG_2 -> R² = -0.1056, MSE = 9.7478e-02
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.429694 | Val Loss 0.710859
# Epoch 100 | Train Loss 0.160449 | Val Loss 0.441248
# Epoch 200 | Train Loss 0.153812 | Val Loss 0.436157
# Epoch 300 | Train Loss 0.148501 | Val Loss 0.422396
# Epoch 400 | Train Loss 0.142356 | Val Loss 0.406809
# Epoch 500 | Train Loss 0.140578 | Val Loss 0.402232
# Epoch 600 | Train Loss 0.139930 | Val Loss 0.400495
# Epoch 700 | Train Loss 0.139564 | Val Loss 0.400508
# Early stopping at epoch 764
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9962, MSE = 4.0143e-04
# X | Train_2 -> R² = 0.9978, MSE = 1.8441e-04
# X | Test_1 -> R² = 0.8518, MSE = 1.5400e-02
# X | Test_2 -> R² = 0.6871, MSE = 2.5675e-02
# X | Test_3 -> R² = -3.3735, MSE = 3.9992e-01
# X | Val -> R² = -1.1333, MSE = 2.0256e-01
# X | LSG_1 -> R² = 0.1311, MSE = 8.8348e-02
# X | LSG_2 -> R² = -2.5604, MSE = 3.1392e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.411193 | Val Loss 0.699407
# Epoch 100 | Train Loss 0.157519 | Val Loss 0.444633
# Epoch 200 | Train Loss 0.153111 | Val Loss 0.436928
# Epoch 300 | Train Loss 0.149606 | Val Loss 0.424389
# Epoch 400 | Train Loss 0.145118 | Val Loss 0.408957
# Epoch 500 | Train Loss 0.141966 | Val Loss 0.403009
# Epoch 600 | Train Loss 0.140720 | Val Loss 0.401517
# Epoch 700 | Train Loss 0.140064 | Val Loss 0.401845
# Early stopping at epoch 724
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9957, MSE = 4.6362e-04
# X | Train_2 -> R² = 0.9965, MSE = 2.9531e-04
# X | Test_1 -> R² = 0.9099, MSE = 9.3598e-03
# X | Test_2 -> R² = 0.7833, MSE = 1.7782e-02
# X | Test_3 -> R² = -1.8106, MSE = 2.5701e-01
# X | Val -> R² = 0.1576, MSE = 7.9983e-02
# X | LSG_1 -> R² = 0.6130, MSE = 3.9345e-02
# X | LSG_2 -> R² = -2.9698, MSE = 3.5002e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.367735 | Val Loss 0.623190
# Epoch 100 | Train Loss 0.158661 | Val Loss 0.440506
# Epoch 200 | Train Loss 0.154118 | Val Loss 0.430549
# Epoch 300 | Train Loss 0.149946 | Val Loss 0.419443
# Epoch 400 | Train Loss 0.144771 | Val Loss 0.408584
# Epoch 500 | Train Loss 0.141310 | Val Loss 0.403514
# Epoch 600 | Train Loss 0.140094 | Val Loss 0.401506
# Epoch 700 | Train Loss 0.139522 | Val Loss 0.402205
# Early stopping at epoch 731
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9953, MSE = 5.0398e-04
# X | Train_2 -> R² = 0.9974, MSE = 2.2147e-04
# X | Test_1 -> R² = 0.9482, MSE = 5.3863e-03
# X | Test_2 -> R² = 0.4815, MSE = 4.2548e-02
# X | Test_3 -> R² = -1.9015, MSE = 2.6532e-01
# X | Val -> R² = 0.2977, MSE = 6.6688e-02
# X | LSG_1 -> R² = 0.5036, MSE = 5.0476e-02
# X | LSG_2 -> R² = -2.9269, MSE = 3.4623e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.448660 | Val Loss 0.749613
# Epoch 100 | Train Loss 0.159443 | Val Loss 0.435262
# Epoch 200 | Train Loss 0.153548 | Val Loss 0.423641
# Epoch 300 | Train Loss 0.150180 | Val Loss 0.412290
# Epoch 400 | Train Loss 0.147006 | Val Loss 0.403142
# Epoch 500 | Train Loss 0.144229 | Val Loss 0.396051
# Epoch 600 | Train Loss 0.142024 | Val Loss 0.399513
# Epoch 700 | Train Loss 0.140440 | Val Loss 0.413808
# Early stopping at epoch 719
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9945, MSE = 5.8877e-04
# X | Train_2 -> R² = 0.9935, MSE = 5.4622e-04
# X | Test_1 -> R² = 0.9436, MSE = 5.8603e-03
# X | Test_2 -> R² = 0.6889, MSE = 2.5529e-02
# X | Test_3 -> R² = -3.1593, MSE = 3.8033e-01
# X | Val -> R² = -0.5617, MSE = 1.4829e-01
# X | LSG_1 -> R² = -0.7592, MSE = 1.7887e-01
# X | LSG_2 -> R² = -3.0663, MSE = 3.5853e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.370371 | Val Loss 0.634071
# Epoch 100 | Train Loss 0.157616 | Val Loss 0.437032
# Epoch 200 | Train Loss 0.153887 | Val Loss 0.433762
# Epoch 300 | Train Loss 0.150683 | Val Loss 0.427646
# Epoch 400 | Train Loss 0.145673 | Val Loss 0.422322
# Epoch 500 | Train Loss 0.141938 | Val Loss 0.424501
# Early stopping at epoch 566
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9898, MSE = 1.0938e-03
# X | Train_2 -> R² = 0.9922, MSE = 6.5233e-04
# X | Test_1 -> R² = 0.9853, MSE = 1.5303e-03
# X | Test_2 -> R² = 0.2871, MSE = 5.8495e-02
# X | Test_3 -> R² = -4.9841, MSE = 5.4719e-01
# X | Val -> R² = -0.5307, MSE = 1.4534e-01
# X | LSG_1 -> R² = 0.3983, MSE = 6.1176e-02
# X | LSG_2 -> R² = -4.0582, MSE = 4.4598e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.418564 | Val Loss 0.705456
# Epoch 100 | Train Loss 0.159532 | Val Loss 0.445203
# Epoch 200 | Train Loss 0.154394 | Val Loss 0.435437
# Epoch 300 | Train Loss 0.151154 | Val Loss 0.425068
# Epoch 400 | Train Loss 0.148234 | Val Loss 0.414830
# Epoch 500 | Train Loss 0.144653 | Val Loss 0.401499
# Epoch 600 | Train Loss 0.141091 | Val Loss 0.392448
# Epoch 700 | Train Loss 0.139838 | Val Loss 0.391530
# Epoch 800 | Train Loss 0.139261 | Val Loss 0.392700
# Early stopping at epoch 807
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9945, MSE = 5.8595e-04
# X | Train_2 -> R² = 0.9969, MSE = 2.5798e-04
# X | Test_1 -> R² = 0.9730, MSE = 2.8068e-03
# X | Test_2 -> R² = 0.1681, MSE = 6.8263e-02
# X | Test_3 -> R² = -2.7386, MSE = 3.4186e-01
# X | Val -> R² = -0.4987, MSE = 1.4230e-01
# X | LSG_1 -> R² = -0.1457, MSE = 1.1649e-01
# X | LSG_2 -> R² = -2.6057, MSE = 3.1792e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.464039 | Val Loss 0.763812
# Epoch 100 | Train Loss 0.162358 | Val Loss 0.438740
# Epoch 200 | Train Loss 0.153718 | Val Loss 0.441122
# Epoch 300 | Train Loss 0.149631 | Val Loss 0.430029
# Epoch 400 | Train Loss 0.144708 | Val Loss 0.411168
# Epoch 500 | Train Loss 0.140677 | Val Loss 0.402741
# Epoch 600 | Train Loss 0.139729 | Val Loss 0.403410
# Early stopping at epoch 676
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9956, MSE = 4.7235e-04
# X | Train_2 -> R² = 0.9969, MSE = 2.5814e-04
# X | Test_1 -> R² = 0.8107, MSE = 1.9669e-02
# X | Test_2 -> R² = 0.9317, MSE = 5.6042e-03
# X | Test_3 -> R² = -1.9680, MSE = 2.7140e-01
# X | Val -> R² = 0.4281, MSE = 5.4301e-02
# X | LSG_1 -> R² = 0.7980, MSE = 2.0540e-02
# X | LSG_2 -> R² = -2.7048, MSE = 3.2665e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.389541 | Val Loss 0.652623
# Epoch 100 | Train Loss 0.159560 | Val Loss 0.435306
# Epoch 200 | Train Loss 0.153526 | Val Loss 0.427127
# Epoch 300 | Train Loss 0.149575 | Val Loss 0.421247
# Epoch 400 | Train Loss 0.145686 | Val Loss 0.417194
# Epoch 500 | Train Loss 0.141628 | Val Loss 0.412114
# Epoch 600 | Train Loss 0.140128 | Val Loss 0.405048
# Epoch 700 | Train Loss 0.139518 | Val Loss 0.403951
# Epoch 800 | Train Loss 0.139059 | Val Loss 0.405345
# Early stopping at epoch 831
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9952, MSE = 5.1282e-04
# X | Train_2 -> R² = 0.9974, MSE = 2.2053e-04
# X | Test_1 -> R² = 0.9284, MSE = 7.4363e-03
# X | Test_2 -> R² = 0.6950, MSE = 2.5028e-02
# X | Test_3 -> R² = -1.7966, MSE = 2.5572e-01
# X | Val -> R² = 0.3060, MSE = 6.5897e-02
# X | LSG_1 -> R² = 0.5755, MSE = 4.3166e-02
# X | LSG_2 -> R² = -2.4587, MSE = 3.0495e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.624056 | Val Loss 0.744377
# Epoch 100 | Train Loss 0.304489 | Val Loss 0.434124
# Epoch 200 | Train Loss 0.297280 | Val Loss 0.431027
# Epoch 300 | Train Loss 0.293538 | Val Loss 0.424880
# Epoch 400 | Train Loss 0.289118 | Val Loss 0.417644
# Epoch 500 | Train Loss 0.285454 | Val Loss 0.409956
# Epoch 600 | Train Loss 0.283169 | Val Loss 0.409940
# Epoch 700 | Train Loss 0.281852 | Val Loss 0.414589
# Early stopping at epoch 741
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9956, MSE = 4.7065e-04
# X | Train_2 -> R² = 0.9968, MSE = 2.7174e-04
# X | Test_1 -> R² = 0.9867, MSE = 1.3817e-03
# X | Test_2 -> R² = -0.4114, MSE = 1.1581e-01
# X | Test_3 -> R² = -0.8549, MSE = 1.6962e-01
# X | Val -> R² = 0.4130, MSE = 5.5735e-02
# X | LSG_1 -> R² = 0.2039, MSE = 8.0946e-02
# X | LSG_2 -> R² = -3.4628, MSE = 3.9349e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.584898 | Val Loss 0.679406
# Epoch 100 | Train Loss 0.302191 | Val Loss 0.431212
# Epoch 200 | Train Loss 0.295547 | Val Loss 0.423863
# Epoch 300 | Train Loss 0.290838 | Val Loss 0.408503
# Epoch 400 | Train Loss 0.285450 | Val Loss 0.397714
# Epoch 500 | Train Loss 0.283182 | Val Loss 0.394923
# Epoch 600 | Train Loss 0.282272 | Val Loss 0.394431
# Early stopping at epoch 691
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9959, MSE = 4.4016e-04
# X | Train_2 -> R² = 0.9959, MSE = 3.4423e-04
# X | Test_1 -> R² = 0.9902, MSE = 1.0181e-03
# X | Test_2 -> R² = 0.3740, MSE = 5.1368e-02
# X | Test_3 -> R² = -2.1445, MSE = 2.8753e-01
# X | Val -> R² = -0.4087, MSE = 1.3376e-01
# X | LSG_1 -> R² = 0.3367, MSE = 6.7443e-02
# X | LSG_2 -> R² = -2.8408, MSE = 3.3865e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.584639 | Val Loss 0.743077
# Epoch 100 | Train Loss 0.301768 | Val Loss 0.436098
# Epoch 200 | Train Loss 0.296671 | Val Loss 0.427298
# Epoch 300 | Train Loss 0.293277 | Val Loss 0.417725
# Epoch 400 | Train Loss 0.288803 | Val Loss 0.404357
# Epoch 500 | Train Loss 0.283947 | Val Loss 0.393495
# Epoch 600 | Train Loss 0.281896 | Val Loss 0.395990
# Epoch 700 | Train Loss 0.280972 | Val Loss 0.402650
# Early stopping at epoch 709
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed5679.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed5679.weights.h5
# X | Train_1 -> R² = 0.9950, MSE = 5.3638e-04
# X | Train_2 -> R² = 0.9958, MSE = 3.5183e-04
# X | Test_1 -> R² = 0.7715, MSE = 2.3739e-02
# X | Test_2 -> R² = -0.1753, MSE = 9.6445e-02
# X | Test_3 -> R² = -3.2644, MSE = 3.8994e-01
# X | Val -> R² = -1.6205, MSE = 2.4882e-01
# X | LSG_1 -> R² = 0.2075, MSE = 8.0575e-02
# X | LSG_2 -> R² = -3.2594, MSE = 3.7555e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.543762 | Val Loss 0.682809
# Epoch 100 | Train Loss 0.302181 | Val Loss 0.444416
# Epoch 200 | Train Loss 0.296466 | Val Loss 0.437248
# Epoch 300 | Train Loss 0.292668 | Val Loss 0.428201
# Epoch 400 | Train Loss 0.288420 | Val Loss 0.413280
# Epoch 500 | Train Loss 0.283750 | Val Loss 0.399211
# Epoch 600 | Train Loss 0.281937 | Val Loss 0.393466
# Epoch 700 | Train Loss 0.280840 | Val Loss 0.391173
# Epoch 800 | Train Loss 0.279733 | Val Loss 0.389345
# Epoch 900 | Train Loss 0.278719 | Val Loss 0.388039
# Epoch 1000 | Train Loss 0.277889 | Val Loss 0.388296
# Early stopping at epoch 1100
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed2408.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed2408.weights.h5
# X | Train_1 -> R² = 0.9931, MSE = 7.4073e-04
# X | Train_2 -> R² = 0.9977, MSE = 1.9280e-04
# X | Test_1 -> R² = 0.9882, MSE = 1.2243e-03
# X | Test_2 -> R² = 0.7435, MSE = 2.1047e-02
# X | Test_3 -> R² = -2.9992, MSE = 3.6569e-01
# X | Val -> R² = -1.7500, MSE = 2.6111e-01
# X | LSG_1 -> R² = 0.6638, MSE = 3.4186e-02
# X | LSG_2 -> R² = -2.4481, MSE = 3.0402e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.552180 | Val Loss 0.662413
# Epoch 100 | Train Loss 0.306767 | Val Loss 0.440303
# Epoch 200 | Train Loss 0.297752 | Val Loss 0.430493
# Epoch 300 | Train Loss 0.292727 | Val Loss 0.410863
# Epoch 400 | Train Loss 0.287870 | Val Loss 0.396292
# Epoch 500 | Train Loss 0.284880 | Val Loss 0.391084
# Epoch 600 | Train Loss 0.283162 | Val Loss 0.389642
# Epoch 700 | Train Loss 0.281996 | Val Loss 0.389228
# Epoch 800 | Train Loss 0.280922 | Val Loss 0.388960
# Early stopping at epoch 806
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed7125.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed7125.weights.h5
# X | Train_1 -> R² = 0.9935, MSE = 6.9074e-04
# X | Train_2 -> R² = 0.9955, MSE = 3.8023e-04
# X | Test_1 -> R² = 0.8575, MSE = 1.4802e-02
# X | Test_2 -> R² = 0.2187, MSE = 6.4109e-02
# X | Test_3 -> R² = -2.5201, MSE = 3.2188e-01
# X | Val -> R² = -0.9577, MSE = 1.8589e-01
# X | LSG_1 -> R² = 0.2104, MSE = 8.0285e-02
# X | LSG_2 -> R² = -3.3369, MSE = 3.8238e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.583826 | Val Loss 0.725705
# Epoch 100 | Train Loss 0.303567 | Val Loss 0.442462
# Epoch 200 | Train Loss 0.296375 | Val Loss 0.432484
# Epoch 300 | Train Loss 0.292071 | Val Loss 0.418577
# Epoch 400 | Train Loss 0.287110 | Val Loss 0.402374
# Epoch 500 | Train Loss 0.282933 | Val Loss 0.392100
# Epoch 600 | Train Loss 0.281392 | Val Loss 0.391607
# Epoch 700 | Train Loss 0.280627 | Val Loss 0.393834
# Early stopping at epoch 733
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9955, MSE = 4.7803e-04
# X | Train_2 -> R² = 0.9967, MSE = 2.7821e-04
# X | Test_1 -> R² = 0.9751, MSE = 2.5908e-03
# X | Test_2 -> R² = -0.3294, MSE = 1.0909e-01
# X | Test_3 -> R² = -2.6651, MSE = 3.3514e-01
# X | Val -> R² = -1.3024, MSE = 2.1861e-01
# X | LSG_1 -> R² = -0.4895, MSE = 1.5145e-01
# X | LSG_2 -> R² = -4.0045, MSE = 4.4125e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.527096 | Val Loss 0.634472
# Epoch 100 | Train Loss 0.300094 | Val Loss 0.434790
# Epoch 200 | Train Loss 0.295986 | Val Loss 0.429682
# Epoch 300 | Train Loss 0.293543 | Val Loss 0.421414
# Epoch 400 | Train Loss 0.290672 | Val Loss 0.407415
# Epoch 500 | Train Loss 0.285815 | Val Loss 0.392782
# Epoch 600 | Train Loss 0.282559 | Val Loss 0.387616
# Epoch 700 | Train Loss 0.281247 | Val Loss 0.387913
# Early stopping at epoch 800
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9963, MSE = 3.9480e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3959e-04
# X | Test_1 -> R² = 0.9922, MSE = 8.0815e-04
# X | Test_2 -> R² = 0.2894, MSE = 5.8306e-02
# X | Test_3 -> R² = -1.8609, MSE = 2.6161e-01
# X | Val -> R² = -0.3836, MSE = 1.3137e-01
# X | LSG_1 -> R² = 0.4847, MSE = 5.2399e-02
# X | LSG_2 -> R² = -3.1431, MSE = 3.6530e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.569390 | Val Loss 0.731467
# Epoch 100 | Train Loss 0.300474 | Val Loss 0.435123
# Epoch 200 | Train Loss 0.294695 | Val Loss 0.426050
# Epoch 300 | Train Loss 0.290168 | Val Loss 0.435927
# Early stopping at epoch 396
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed5679.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed5679.weights.h5
# X | Train_1 -> R² = 0.9825, MSE = 1.8670e-03
# X | Train_2 -> R² = 0.9918, MSE = 6.8802e-04
# X | Test_1 -> R² = 0.9601, MSE = 4.1435e-03
# X | Test_2 -> R² = -0.2658, MSE = 1.0386e-01
# X | Test_3 -> R² = -7.7877, MSE = 8.0355e-01
# X | Val -> R² = -1.8705, MSE = 2.7256e-01
# X | LSG_1 -> R² = -0.1587, MSE = 1.1782e-01
# X | LSG_2 -> R² = -3.3462, MSE = 3.8320e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.587296 | Val Loss 0.726286
# Epoch 100 | Train Loss 0.309408 | Val Loss 0.438894
# Epoch 200 | Train Loss 0.297519 | Val Loss 0.433607
# Epoch 300 | Train Loss 0.293097 | Val Loss 0.422833
# Epoch 400 | Train Loss 0.288860 | Val Loss 0.408099
# Epoch 500 | Train Loss 0.284920 | Val Loss 0.389778
# Epoch 600 | Train Loss 0.282705 | Val Loss 0.381025
# Epoch 700 | Train Loss 0.281376 | Val Loss 0.377536
# Epoch 800 | Train Loss 0.280481 | Val Loss 0.376435
# Epoch 900 | Train Loss 0.279787 | Val Loss 0.376450
# Early stopping at epoch 956
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed2408.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed2408.weights.h5
# X | Train_1 -> R² = 0.9915, MSE = 9.0549e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3598e-04
# X | Test_1 -> R² = 0.9173, MSE = 8.5968e-03
# X | Test_2 -> R² = 0.5599, MSE = 3.6115e-02
# X | Test_3 -> R² = -1.0981, MSE = 1.9185e-01
# X | Val -> R² = 0.0568, MSE = 8.9554e-02
# X | LSG_1 -> R² = 0.7364, MSE = 2.6807e-02
# X | LSG_2 -> R² = -3.5774, MSE = 4.0359e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.473180 | Val Loss 0.593128
# Epoch 100 | Train Loss 0.302486 | Val Loss 0.440970
# Epoch 200 | Train Loss 0.295501 | Val Loss 0.431065
# Epoch 300 | Train Loss 0.291857 | Val Loss 0.418602
# Epoch 400 | Train Loss 0.287116 | Val Loss 0.401433
# Epoch 500 | Train Loss 0.282806 | Val Loss 0.389876
# Epoch 600 | Train Loss 0.281010 | Val Loss 0.385255
# Epoch 700 | Train Loss 0.280006 | Val Loss 0.385296
# Early stopping at epoch 798
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed7125.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed7125.weights.h5
# X | Train_1 -> R² = 0.9937, MSE = 6.7350e-04
# X | Train_2 -> R² = 0.9946, MSE = 4.5051e-04
# X | Test_1 -> R² = 0.9602, MSE = 4.1321e-03
# X | Test_2 -> R² = 0.7289, MSE = 2.2245e-02
# X | Test_3 -> R² = -2.6908, MSE = 3.3749e-01
# X | Val -> R² = -1.0826, MSE = 1.9774e-01
# X | LSG_1 -> R² = 0.4461, MSE = 5.6318e-02
# X | LSG_2 -> R² = -2.7208, MSE = 3.2807e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.456661 | Val Loss 0.716425
# Epoch 100 | Train Loss 0.156035 | Val Loss 0.435150
# Epoch 200 | Train Loss 0.152043 | Val Loss 0.426100
# Epoch 300 | Train Loss 0.148746 | Val Loss 0.419598
# Epoch 400 | Train Loss 0.144639 | Val Loss 0.410285
# Epoch 500 | Train Loss 0.140634 | Val Loss 0.400554
# Epoch 600 | Train Loss 0.138795 | Val Loss 0.396360
# Epoch 700 | Train Loss 0.137873 | Val Loss 0.398184
# Early stopping at epoch 758
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9950, MSE = 5.3380e-04
# X | Train_2 -> R² = 0.9957, MSE = 3.6473e-04
# X | Test_1 -> R² = 0.9229, MSE = 8.0146e-03
# X | Test_2 -> R² = 0.7678, MSE = 1.9052e-02
# X | Test_3 -> R² = -2.0584, MSE = 2.7966e-01
# X | Val -> R² = -0.2078, MSE = 1.1468e-01
# X | LSG_1 -> R² = 0.5497, MSE = 4.5787e-02
# X | LSG_2 -> R² = -2.3707, MSE = 2.9719e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.473113 | Val Loss 0.639916
# Epoch 100 | Train Loss 0.157968 | Val Loss 0.428718
# Epoch 200 | Train Loss 0.152865 | Val Loss 0.417585
# Epoch 300 | Train Loss 0.147635 | Val Loss 0.403174
# Epoch 400 | Train Loss 0.141813 | Val Loss 0.392894
# Epoch 500 | Train Loss 0.140047 | Val Loss 0.395390
# Early stopping at epoch 588
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9943, MSE = 6.0582e-04
# X | Train_2 -> R² = 0.9970, MSE = 2.5221e-04
# X | Test_1 -> R² = 0.9743, MSE = 2.6712e-03
# X | Test_2 -> R² = -0.0592, MSE = 8.6915e-02
# X | Test_3 -> R² = -2.4434, MSE = 3.1487e-01
# X | Val -> R² = -0.6953, MSE = 1.6096e-01
# X | LSG_1 -> R² = -0.4216, MSE = 1.4455e-01
# X | LSG_2 -> R² = -3.0608, MSE = 3.5804e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.417757 | Val Loss 0.707879
# Epoch 100 | Train Loss 0.154999 | Val Loss 0.431219
# Epoch 200 | Train Loss 0.151797 | Val Loss 0.426615
# Epoch 300 | Train Loss 0.149353 | Val Loss 0.423434
# Epoch 400 | Train Loss 0.145888 | Val Loss 0.415202
# Epoch 500 | Train Loss 0.140854 | Val Loss 0.401804
# Epoch 600 | Train Loss 0.138760 | Val Loss 0.398413
# Epoch 700 | Train Loss 0.137917 | Val Loss 0.400831
# Early stopping at epoch 735
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9940, MSE = 6.4287e-04
# X | Train_2 -> R² = 0.9965, MSE = 2.9574e-04
# X | Test_1 -> R² = 0.9479, MSE = 5.4169e-03
# X | Test_2 -> R² = 0.9352, MSE = 5.3181e-03
# X | Test_3 -> R² = -1.9697, MSE = 2.7155e-01
# X | Val -> R² = -0.1674, MSE = 1.1085e-01
# X | LSG_1 -> R² = 0.6724, MSE = 3.3310e-02
# X | LSG_2 -> R² = -1.8577, MSE = 2.5196e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.399449 | Val Loss 0.659414
# Epoch 100 | Train Loss 0.155278 | Val Loss 0.428895
# Epoch 200 | Train Loss 0.151121 | Val Loss 0.417110
# Epoch 300 | Train Loss 0.144171 | Val Loss 0.399393
# Epoch 400 | Train Loss 0.140173 | Val Loss 0.394878
# Epoch 500 | Train Loss 0.139042 | Val Loss 0.398887
# Early stopping at epoch 543
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9950, MSE = 5.3532e-04
# X | Train_2 -> R² = 0.9965, MSE = 2.9021e-04
# X | Test_1 -> R² = 0.9712, MSE = 2.9969e-03
# X | Test_2 -> R² = 0.3686, MSE = 5.1810e-02
# X | Test_3 -> R² = -1.9115, MSE = 2.6623e-01
# X | Val -> R² = -0.4881, MSE = 1.4129e-01
# X | LSG_1 -> R² = 0.3053, MSE = 7.0631e-02
# X | LSG_2 -> R² = -3.0504, MSE = 3.5712e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.366717 | Val Loss 0.624391
# Epoch 100 | Train Loss 0.153244 | Val Loss 0.427277
# Epoch 200 | Train Loss 0.147001 | Val Loss 0.416095
# Epoch 300 | Train Loss 0.141953 | Val Loss 0.405602
# Epoch 400 | Train Loss 0.140201 | Val Loss 0.401862
# Epoch 500 | Train Loss 0.139227 | Val Loss 0.402845
# Early stopping at epoch 566
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9955, MSE = 4.8332e-04
# X | Train_2 -> R² = 0.9962, MSE = 3.2218e-04
# X | Test_1 -> R² = 0.9895, MSE = 1.0946e-03
# X | Test_2 -> R² = 0.2277, MSE = 6.3376e-02
# X | Test_3 -> R² = -2.4440, MSE = 3.1492e-01
# X | Val -> R² = -0.5670, MSE = 1.4879e-01
# X | LSG_1 -> R² = -0.1608, MSE = 1.1802e-01
# X | LSG_2 -> R² = -2.9403, MSE = 3.4742e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.390622 | Val Loss 0.653074
# Epoch 100 | Train Loss 0.153544 | Val Loss 0.430368
# Epoch 200 | Train Loss 0.149660 | Val Loss 0.423763
# Epoch 300 | Train Loss 0.143652 | Val Loss 0.416105
# Epoch 400 | Train Loss 0.140511 | Val Loss 0.408048
# Epoch 500 | Train Loss 0.139191 | Val Loss 0.408817
# Epoch 600 | Train Loss 0.138234 | Val Loss 0.412283
# Early stopping at epoch 606
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9954, MSE = 4.9185e-04
# X | Train_2 -> R² = 0.9973, MSE = 2.3015e-04
# X | Test_1 -> R² = 0.9886, MSE = 1.1818e-03
# X | Test_2 -> R² = 0.1191, MSE = 7.2280e-02
# X | Test_3 -> R² = -1.3755, MSE = 2.1722e-01
# X | Val -> R² = 0.1542, MSE = 8.0313e-02
# X | LSG_1 -> R² = 0.2371, MSE = 7.7571e-02
# X | LSG_2 -> R² = -3.5388, MSE = 4.0018e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.381596 | Val Loss 0.624365
# Epoch 100 | Train Loss 0.153836 | Val Loss 0.432895
# Epoch 200 | Train Loss 0.147741 | Val Loss 0.422457
# Epoch 300 | Train Loss 0.141805 | Val Loss 0.410564
# Epoch 400 | Train Loss 0.139760 | Val Loss 0.402483
# Epoch 500 | Train Loss 0.139055 | Val Loss 0.402078
# Epoch 600 | Train Loss 0.138484 | Val Loss 0.401477
# Epoch 700 | Train Loss 0.137963 | Val Loss 0.400383
# Epoch 800 | Train Loss 0.137453 | Val Loss 0.398881
# Epoch 900 | Train Loss 0.136905 | Val Loss 0.397922
# Epoch 1000 | Train Loss 0.136363 | Val Loss 0.399501
# Early stopping at epoch 1037
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9957, MSE = 4.6040e-04
# X | Train_2 -> R² = 0.9975, MSE = 2.1377e-04
# X | Test_1 -> R² = 0.9858, MSE = 1.4766e-03
# X | Test_2 -> R² = 0.5637, MSE = 3.5802e-02
# X | Test_3 -> R² = -2.4581, MSE = 3.1621e-01
# X | Val -> R² = -0.0673, MSE = 1.0134e-01
# X | LSG_1 -> R² = 0.5224, MSE = 4.8559e-02
# X | LSG_2 -> R² = -2.2013, MSE = 2.8225e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.409205 | Val Loss 0.667703
# Epoch 100 | Train Loss 0.155678 | Val Loss 0.434759
# Epoch 200 | Train Loss 0.151009 | Val Loss 0.425928
# Epoch 300 | Train Loss 0.145700 | Val Loss 0.415456
# Epoch 400 | Train Loss 0.140454 | Val Loss 0.400052
# Epoch 500 | Train Loss 0.138983 | Val Loss 0.395859
# Epoch 600 | Train Loss 0.138028 | Val Loss 0.399451
# Early stopping at epoch 676
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9951, MSE = 5.2594e-04
# X | Train_2 -> R² = 0.9974, MSE = 2.2232e-04
# X | Test_1 -> R² = 0.6781, MSE = 3.3442e-02
# X | Test_2 -> R² = 0.6990, MSE = 2.4700e-02
# X | Test_3 -> R² = -1.0540, MSE = 1.8782e-01
# X | Val -> R² = -0.1445, MSE = 1.0867e-01
# X | LSG_1 -> R² = 0.6325, MSE = 3.7363e-02
# X | LSG_2 -> R² = -1.9797, MSE = 2.6272e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.434128 | Val Loss 0.685599
# Epoch 100 | Train Loss 0.155181 | Val Loss 0.431501
# Epoch 200 | Train Loss 0.151809 | Val Loss 0.425209
# Epoch 300 | Train Loss 0.147498 | Val Loss 0.419032
# Epoch 400 | Train Loss 0.142067 | Val Loss 0.409598
# Epoch 500 | Train Loss 0.139828 | Val Loss 0.408822
# Epoch 600 | Train Loss 0.138456 | Val Loss 0.413757
# Early stopping at epoch 619
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9942, MSE = 6.2089e-04
# X | Train_2 -> R² = 0.9961, MSE = 3.2714e-04
# X | Test_1 -> R² = 0.9603, MSE = 4.1206e-03
# X | Test_2 -> R² = 0.1671, MSE = 6.8342e-02
# X | Test_3 -> R² = -1.9770, MSE = 2.7222e-01
# X | Val -> R² = 0.0485, MSE = 9.0342e-02
# X | LSG_1 -> R² = 0.3328, MSE = 6.7842e-02
# X | LSG_2 -> R² = -3.6049, MSE = 4.0601e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.430635 | Val Loss 0.712406
# Epoch 100 | Train Loss 0.153750 | Val Loss 0.428095
# Epoch 200 | Train Loss 0.148678 | Val Loss 0.421990
# Epoch 300 | Train Loss 0.143112 | Val Loss 0.416075
# Epoch 400 | Train Loss 0.140053 | Val Loss 0.408326
# Epoch 500 | Train Loss 0.138721 | Val Loss 0.402044
# Epoch 600 | Train Loss 0.137846 | Val Loss 0.402042
# Early stopping at epoch 696
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9953, MSE = 5.0636e-04
# X | Train_2 -> R² = 0.9968, MSE = 2.6544e-04
# X | Test_1 -> R² = 0.7285, MSE = 2.8208e-02
# X | Test_2 -> R² = 0.5465, MSE = 3.7213e-02
# X | Test_3 -> R² = -1.2523, MSE = 2.0595e-01
# X | Val -> R² = 0.1008, MSE = 8.5383e-02
# X | LSG_1 -> R² = 0.6227, MSE = 3.8358e-02
# X | LSG_2 -> R² = -2.7742, MSE = 3.3277e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.554610 | Val Loss 0.687070
# Epoch 100 | Train Loss 0.295636 | Val Loss 0.426522
# Epoch 200 | Train Loss 0.291163 | Val Loss 0.414390
# Epoch 300 | Train Loss 0.284622 | Val Loss 0.407757
# Epoch 400 | Train Loss 0.281654 | Val Loss 0.412905
# Early stopping at epoch 463
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9924, MSE = 8.1487e-04
# X | Train_2 -> R² = 0.9934, MSE = 5.5719e-04
# X | Test_1 -> R² = 0.9174, MSE = 8.5808e-03
# X | Test_2 -> R² = -0.3674, MSE = 1.1221e-01
# X | Test_3 -> R² = -2.9598, MSE = 3.6209e-01
# X | Val -> R² = -0.4313, MSE = 1.3590e-01
# X | LSG_1 -> R² = 0.4224, MSE = 5.8729e-02
# X | LSG_2 -> R² = -3.9894, MSE = 4.3991e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.544424 | Val Loss 0.585682
# Epoch 100 | Train Loss 0.297572 | Val Loss 0.432417
# Epoch 200 | Train Loss 0.291895 | Val Loss 0.419757
# Epoch 300 | Train Loss 0.285609 | Val Loss 0.404231
# Epoch 400 | Train Loss 0.281753 | Val Loss 0.394433
# Epoch 500 | Train Loss 0.280267 | Val Loss 0.391972
# Epoch 600 | Train Loss 0.279065 | Val Loss 0.390324
# Epoch 700 | Train Loss 0.278019 | Val Loss 0.389480
# Epoch 800 | Train Loss 0.277195 | Val Loss 0.389827
# Early stopping at epoch 868
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9926, MSE = 7.9274e-04
# X | Train_2 -> R² = 0.9973, MSE = 2.2474e-04
# X | Test_1 -> R² = 0.9323, MSE = 7.0301e-03
# X | Test_2 -> R² = 0.4389, MSE = 4.6042e-02
# X | Test_3 -> R² = -2.6909, MSE = 3.3750e-01
# X | Val -> R² = -0.3422, MSE = 1.2744e-01
# X | LSG_1 -> R² = 0.4483, MSE = 5.6100e-02
# X | LSG_2 -> R² = -3.4004, MSE = 3.8798e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.597385 | Val Loss 0.729840
# Epoch 100 | Train Loss 0.297660 | Val Loss 0.433291
# Epoch 200 | Train Loss 0.293959 | Val Loss 0.423808
# Epoch 300 | Train Loss 0.291011 | Val Loss 0.414108
# Epoch 400 | Train Loss 0.286466 | Val Loss 0.405337
# Epoch 500 | Train Loss 0.282242 | Val Loss 0.400050
# Epoch 600 | Train Loss 0.280596 | Val Loss 0.397258
# Epoch 700 | Train Loss 0.279246 | Val Loss 0.397267
# Epoch 800 | Train Loss 0.278149 | Val Loss 0.400870
# Early stopping at epoch 821
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed5679.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed5679.weights.h5
# X | Train_1 -> R² = 0.9920, MSE = 8.5893e-04
# X | Train_2 -> R² = 0.9955, MSE = 3.8065e-04
# X | Test_1 -> R² = 0.4179, MSE = 6.0485e-02
# X | Test_2 -> R² = 0.2890, MSE = 5.8343e-02
# X | Test_3 -> R² = -2.5523, MSE = 3.2483e-01
# X | Val -> R² = -1.2856, MSE = 2.1702e-01
# X | LSG_1 -> R² = 0.5825, MSE = 4.2455e-02
# X | LSG_2 -> R² = -2.9513, MSE = 3.4839e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.566564 | Val Loss 0.692524
# Epoch 100 | Train Loss 0.297589 | Val Loss 0.432226
# Epoch 200 | Train Loss 0.292906 | Val Loss 0.421958
# Epoch 300 | Train Loss 0.287234 | Val Loss 0.414702
# Epoch 400 | Train Loss 0.281453 | Val Loss 0.412765
# Epoch 500 | Train Loss 0.280108 | Val Loss 0.417995
# Early stopping at epoch 534
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed2408.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed2408.weights.h5
# X | Train_1 -> R² = 0.9938, MSE = 6.6509e-04
# X | Train_2 -> R² = 0.9931, MSE = 5.7938e-04
# X | Test_1 -> R² = 0.9036, MSE = 1.0016e-02
# X | Test_2 -> R² = -0.0376, MSE = 8.5143e-02
# X | Test_3 -> R² = -1.3858, MSE = 2.1816e-01
# X | Val -> R² = 0.1034, MSE = 8.5132e-02
# X | LSG_1 -> R² = 0.5471, MSE = 4.6055e-02
# X | LSG_2 -> R² = -4.2023, MSE = 4.5868e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.530853 | Val Loss 0.634454
# Epoch 100 | Train Loss 0.296334 | Val Loss 0.428274
# Epoch 200 | Train Loss 0.291319 | Val Loss 0.427897
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed7125.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed7125.weights.h5
# X | Train_1 -> R² = 0.7402, MSE = 2.7775e-02
# X | Train_2 -> R² = 0.8698, MSE = 1.0948e-02
# X | Test_1 -> R² = 0.4468, MSE = 5.7481e-02
# X | Test_2 -> R² = 0.6646, MSE = 2.7522e-02
# X | Test_3 -> R² = -8.6906, MSE = 8.8612e-01
# X | Val -> R² = -3.5628, MSE = 4.3324e-01
# X | LSG_1 -> R² = -0.4304, MSE = 1.4544e-01
# X | LSG_2 -> R² = -0.9646, MSE = 1.7322e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.553685 | Val Loss 0.670725
# Epoch 100 | Train Loss 0.296607 | Val Loss 0.431568
# Epoch 200 | Train Loss 0.293264 | Val Loss 0.423075
# Epoch 300 | Train Loss 0.290614 | Val Loss 0.413951
# Epoch 400 | Train Loss 0.284635 | Val Loss 0.397602
# Epoch 500 | Train Loss 0.280928 | Val Loss 0.399027
# Epoch 600 | Train Loss 0.279195 | Val Loss 0.407765
# Early stopping at epoch 624
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9930, MSE = 7.4569e-04
# X | Train_2 -> R² = 0.9967, MSE = 2.7846e-04
# X | Test_1 -> R² = 0.9838, MSE = 1.6783e-03
# X | Test_2 -> R² = -0.1023, MSE = 9.0452e-02
# X | Test_3 -> R² = -2.4203, MSE = 3.1275e-01
# X | Val -> R² = -1.0415, MSE = 1.9384e-01
# X | LSG_1 -> R² = 0.2571, MSE = 7.5533e-02
# X | LSG_2 -> R² = -3.3719, MSE = 3.8547e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.522399 | Val Loss 0.624006
# Epoch 100 | Train Loss 0.297681 | Val Loss 0.431599
# Epoch 200 | Train Loss 0.291874 | Val Loss 0.419743
# Epoch 300 | Train Loss 0.287359 | Val Loss 0.422011
# Epoch 400 | Train Loss 0.282844 | Val Loss 0.414764
# Epoch 500 | Train Loss 0.280564 | Val Loss 0.400513
# Epoch 600 | Train Loss 0.279019 | Val Loss 0.393964
# Epoch 700 | Train Loss 0.277915 | Val Loss 0.393359
# Early stopping at epoch 799
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9897, MSE = 1.0961e-03
# X | Train_2 -> R² = 0.9964, MSE = 3.0353e-04
# X | Test_1 -> R² = -0.2758, MSE = 1.3256e-01
# X | Test_2 -> R² = 0.5771, MSE = 3.4701e-02
# X | Test_3 -> R² = -2.1114, MSE = 2.8451e-01
# X | Val -> R² = -0.4475, MSE = 1.3744e-01
# X | LSG_1 -> R² = 0.7912, MSE = 2.1229e-02
# X | LSG_2 -> R² = -2.5604, MSE = 3.1392e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.572475 | Val Loss 0.699837
# Epoch 100 | Train Loss 0.297643 | Val Loss 0.431051
# Epoch 200 | Train Loss 0.293112 | Val Loss 0.421236
# Epoch 300 | Train Loss 0.288769 | Val Loss 0.411022
# Epoch 400 | Train Loss 0.283595 | Val Loss 0.400638
# Epoch 500 | Train Loss 0.281505 | Val Loss 0.400045
# Epoch 600 | Train Loss 0.280136 | Val Loss 0.400707
# Early stopping at epoch 604
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed5679.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed5679.weights.h5
# X | Train_1 -> R² = 0.9936, MSE = 6.7949e-04
# X | Train_2 -> R² = 0.9938, MSE = 5.2155e-04
# X | Test_1 -> R² = 0.6187, MSE = 3.9615e-02
# X | Test_2 -> R² = 0.1300, MSE = 7.1387e-02
# X | Test_3 -> R² = -1.3209, MSE = 2.1222e-01
# X | Val -> R² = -0.5333, MSE = 1.4559e-01
# X | LSG_1 -> R² = 0.6051, MSE = 4.0149e-02
# X | LSG_2 -> R² = -3.7290, MSE = 4.1695e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.584313 | Val Loss 0.732208
# Epoch 100 | Train Loss 0.296831 | Val Loss 0.429065
# Epoch 200 | Train Loss 0.292901 | Val Loss 0.418038
# Epoch 300 | Train Loss 0.287999 | Val Loss 0.407372
# Epoch 400 | Train Loss 0.282446 | Val Loss 0.403904
# Epoch 500 | Train Loss 0.280529 | Val Loss 0.404596
# Early stopping at epoch 548
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed2408.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed2408.weights.h5
# X | Train_1 -> R² = 0.9923, MSE = 8.2759e-04
# X | Train_2 -> R² = 0.9947, MSE = 4.4620e-04
# X | Test_1 -> R² = 0.8217, MSE = 1.8526e-02
# X | Test_2 -> R² = -0.1042, MSE = 9.0610e-02
# X | Test_3 -> R² = -2.3682, MSE = 3.0799e-01
# X | Val -> R² = -1.0052, MSE = 1.9039e-01
# X | LSG_1 -> R² = 0.3472, MSE = 6.6374e-02
# X | LSG_2 -> R² = -3.5156, MSE = 3.9814e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.524291 | Val Loss 0.624972
# Epoch 100 | Train Loss 0.296445 | Val Loss 0.427250
# Epoch 200 | Train Loss 0.291393 | Val Loss 0.427111
# Epoch 300 | Train Loss 0.285735 | Val Loss 0.420474
# Epoch 400 | Train Loss 0.282143 | Val Loss 0.410920
# Epoch 500 | Train Loss 0.280542 | Val Loss 0.408821
# Epoch 600 | Train Loss 0.279399 | Val Loss 0.411031
# Early stopping at epoch 642
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed7125.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed7125.weights.h5
# X | Train_1 -> R² = 0.9939, MSE = 6.4750e-04
# X | Train_2 -> R² = 0.9958, MSE = 3.5284e-04
# X | Test_1 -> R² = 0.5977, MSE = 4.1799e-02
# X | Test_2 -> R² = 0.0797, MSE = 7.5514e-02
# X | Test_3 -> R² = -1.0582, MSE = 1.8820e-01
# X | Val -> R² = -0.1503, MSE = 1.0922e-01
# X | LSG_1 -> R² = 0.5229, MSE = 4.8509e-02
# X | LSG_2 -> R² = -2.8438, MSE = 3.3891e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.379298 | Val Loss 0.567760
# Epoch 100 | Train Loss 0.152485 | Val Loss 0.428103
# Epoch 200 | Train Loss 0.146997 | Val Loss 0.421781
# Epoch 300 | Train Loss 0.140144 | Val Loss 0.401527
# Epoch 400 | Train Loss 0.138575 | Val Loss 0.400742
# Epoch 500 | Train Loss 0.137869 | Val Loss 0.403941
# Early stopping at epoch 518
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9961, MSE = 4.1297e-04
# X | Train_2 -> R² = 0.9973, MSE = 2.2410e-04
# X | Test_1 -> R² = 0.9846, MSE = 1.6030e-03
# X | Test_2 -> R² = 0.5843, MSE = 3.4108e-02
# X | Test_3 -> R² = -2.4059, MSE = 3.1144e-01
# X | Val -> R² = -0.5497, MSE = 1.4714e-01
# X | LSG_1 -> R² = 0.6454, MSE = 3.6056e-02
# X | LSG_2 -> R² = -2.9270, MSE = 3.4624e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.328118 | Val Loss 0.540083
# Epoch 100 | Train Loss 0.151203 | Val Loss 0.420777
# Epoch 200 | Train Loss 0.144891 | Val Loss 0.413965
# Epoch 300 | Train Loss 0.139943 | Val Loss 0.400814
# Epoch 400 | Train Loss 0.138179 | Val Loss 0.400301
# Epoch 500 | Train Loss 0.137314 | Val Loss 0.405196
# Early stopping at epoch 513
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9936, MSE = 6.8491e-04
# X | Train_2 -> R² = 0.9956, MSE = 3.6591e-04
# X | Test_1 -> R² = 0.7693, MSE = 2.3971e-02
# X | Test_2 -> R² = 0.3662, MSE = 5.2011e-02
# X | Test_3 -> R² = -1.5474, MSE = 2.3294e-01
# X | Val -> R² = -0.4539, MSE = 1.3805e-01
# X | LSG_1 -> R² = 0.5285, MSE = 4.7939e-02
# X | LSG_2 -> R² = -3.0579, MSE = 3.5778e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.428034 | Val Loss 0.640452
# Epoch 100 | Train Loss 0.153666 | Val Loss 0.428990
# Epoch 200 | Train Loss 0.149804 | Val Loss 0.422546
# Epoch 300 | Train Loss 0.142590 | Val Loss 0.411990
# Epoch 400 | Train Loss 0.139621 | Val Loss 0.399539
# Epoch 500 | Train Loss 0.138796 | Val Loss 0.400685
# Early stopping at epoch 567
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9957, MSE = 4.5904e-04
# X | Train_2 -> R² = 0.9962, MSE = 3.1759e-04
# X | Test_1 -> R² = 0.9155, MSE = 8.7791e-03
# X | Test_2 -> R² = 0.3596, MSE = 5.2549e-02
# X | Test_3 -> R² = -2.4579, MSE = 3.1620e-01
# X | Val -> R² = -0.2595, MSE = 1.1959e-01
# X | LSG_1 -> R² = 0.0770, MSE = 9.3846e-02
# X | LSG_2 -> R² = -2.7628, MSE = 3.3177e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.390939 | Val Loss 0.637039
# Epoch 100 | Train Loss 0.151426 | Val Loss 0.424461
# Epoch 200 | Train Loss 0.146254 | Val Loss 0.426851
# Epoch 300 | Train Loss 0.139975 | Val Loss 0.412966
# Epoch 400 | Train Loss 0.138161 | Val Loss 0.405531
# Epoch 500 | Train Loss 0.137341 | Val Loss 0.408284
# Early stopping at epoch 560
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9950, MSE = 5.3371e-04
# X | Train_2 -> R² = 0.9970, MSE = 2.5114e-04
# X | Test_1 -> R² = 0.9375, MSE = 6.4914e-03
# X | Test_2 -> R² = 0.6947, MSE = 2.5051e-02
# X | Test_3 -> R² = -1.4605, MSE = 2.2499e-01
# X | Val -> R² = -0.1170, MSE = 1.0606e-01
# X | LSG_1 -> R² = 0.6178, MSE = 3.8858e-02
# X | LSG_2 -> R² = -2.2561, MSE = 2.8709e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.335753 | Val Loss 0.531025
# Epoch 100 | Train Loss 0.151303 | Val Loss 0.421444
# Epoch 200 | Train Loss 0.144529 | Val Loss 0.416050
# Epoch 300 | Train Loss 0.139495 | Val Loss 0.403544
# Epoch 400 | Train Loss 0.138242 | Val Loss 0.405194
# Early stopping at epoch 463
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9956, MSE = 4.7475e-04
# X | Train_2 -> R² = 0.9973, MSE = 2.2561e-04
# X | Test_1 -> R² = 0.9713, MSE = 2.9791e-03
# X | Test_2 -> R² = 0.3676, MSE = 5.1891e-02
# X | Test_3 -> R² = -1.0445, MSE = 1.8695e-01
# X | Val -> R² = 0.1017, MSE = 8.5294e-02
# X | LSG_1 -> R² = 0.4622, MSE = 5.4684e-02
# X | LSG_2 -> R² = -2.9791, MSE = 3.5083e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.365209 | Val Loss 0.568424
# Epoch 100 | Train Loss 0.151461 | Val Loss 0.421006
# Epoch 200 | Train Loss 0.142883 | Val Loss 0.412718
# Epoch 300 | Train Loss 0.139689 | Val Loss 0.401401
# Epoch 400 | Train Loss 0.138599 | Val Loss 0.402357
# Early stopping at epoch 478
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9955, MSE = 4.8303e-04
# X | Train_2 -> R² = 0.9973, MSE = 2.2392e-04
# X | Test_1 -> R² = 0.9841, MSE = 1.6546e-03
# X | Test_2 -> R² = 0.3918, MSE = 4.9904e-02
# X | Test_3 -> R² = -2.8967, MSE = 3.5632e-01
# X | Val -> R² = -0.8170, MSE = 1.7253e-01
# X | LSG_1 -> R² = 0.3509, MSE = 6.6003e-02
# X | LSG_2 -> R² = -2.2642, MSE = 2.8780e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.378886 | Val Loss 0.602362
# Epoch 100 | Train Loss 0.152242 | Val Loss 0.424040
# Epoch 200 | Train Loss 0.146141 | Val Loss 0.425382
# Epoch 300 | Train Loss 0.140116 | Val Loss 0.410810
# Epoch 400 | Train Loss 0.138347 | Val Loss 0.404374
# Epoch 500 | Train Loss 0.137546 | Val Loss 0.405287
# Early stopping at epoch 552
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9955, MSE = 4.7971e-04
# X | Train_2 -> R² = 0.9975, MSE = 2.0943e-04
# X | Test_1 -> R² = 0.9651, MSE = 3.6234e-03
# X | Test_2 -> R² = 0.5060, MSE = 4.0534e-02
# X | Test_3 -> R² = -2.1352, MSE = 2.8669e-01
# X | Val -> R² = -0.5852, MSE = 1.5051e-01
# X | LSG_1 -> R² = 0.5074, MSE = 5.0090e-02
# X | LSG_2 -> R² = -2.5204, MSE = 3.1039e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.389488 | Val Loss 0.607786
# Epoch 100 | Train Loss 0.152234 | Val Loss 0.425246
# Epoch 200 | Train Loss 0.148852 | Val Loss 0.421117
# Epoch 300 | Train Loss 0.143094 | Val Loss 0.418609
# Epoch 400 | Train Loss 0.139739 | Val Loss 0.405311
# Epoch 500 | Train Loss 0.138413 | Val Loss 0.405750
# Epoch 600 | Train Loss 0.137504 | Val Loss 0.410768
# Early stopping at epoch 616
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9954, MSE = 4.9527e-04
# X | Train_2 -> R² = 0.9966, MSE = 2.8731e-04
# X | Test_1 -> R² = 0.8952, MSE = 1.0894e-02
# X | Test_2 -> R² = 0.5837, MSE = 3.4162e-02
# X | Test_3 -> R² = -1.8509, MSE = 2.6069e-01
# X | Val -> R² = -0.2687, MSE = 1.2046e-01
# X | LSG_1 -> R² = 0.5372, MSE = 4.7053e-02
# X | LSG_2 -> R² = -2.6337, MSE = 3.2038e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.487066 | Val Loss 0.651920
# Epoch 100 | Train Loss 0.153407 | Val Loss 0.427055
# Epoch 200 | Train Loss 0.149314 | Val Loss 0.416519
# Epoch 300 | Train Loss 0.143027 | Val Loss 0.399523
# Epoch 400 | Train Loss 0.139774 | Val Loss 0.395925
# Epoch 500 | Train Loss 0.138750 | Val Loss 0.397938
# Early stopping at epoch 543
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9947, MSE = 5.6570e-04
# X | Train_2 -> R² = 0.9972, MSE = 2.3267e-04
# X | Test_1 -> R² = 0.9860, MSE = 1.4513e-03
# X | Test_2 -> R² = 0.2217, MSE = 6.3867e-02
# X | Test_3 -> R² = -1.5933, MSE = 2.3714e-01
# X | Val -> R² = -0.3956, MSE = 1.3251e-01
# X | LSG_1 -> R² = 0.3444, MSE = 6.6665e-02
# X | LSG_2 -> R² = -3.1553, MSE = 3.6637e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.570004 | Val Loss 0.581885
# Epoch 100 | Train Loss 0.154240 | Val Loss 0.427937
# Epoch 200 | Train Loss 0.150612 | Val Loss 0.422581
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.8640, MSE = 1.4544e-02
# X | Train_2 -> R² = -0.7297, MSE = 1.4539e-01
# X | Test_1 -> R² = 0.7530, MSE = 2.5663e-02
# X | Test_2 -> R² = -1.8031, MSE = 2.3001e-01
# X | Test_3 -> R² = -4.4417, MSE = 4.9759e-01
# X | Val -> R² = -2.1178, MSE = 2.9604e-01
# X | LSG_1 -> R² = 0.2442, MSE = 7.6844e-02
# X | LSG_2 -> R² = -0.9051, MSE = 1.6797e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.517816 | Val Loss 0.572541
# Epoch 100 | Train Loss 0.294065 | Val Loss 0.422989
# Epoch 200 | Train Loss 0.288550 | Val Loss 0.405567
# Epoch 300 | Train Loss 0.281666 | Val Loss 0.393971
# Epoch 400 | Train Loss 0.279889 | Val Loss 0.400878
# Early stopping at epoch 460
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9951, MSE = 5.2879e-04
# X | Train_2 -> R² = 0.9963, MSE = 3.1291e-04
# X | Test_1 -> R² = 0.8234, MSE = 1.8351e-02
# X | Test_2 -> R² = -0.0064, MSE = 8.2586e-02
# X | Test_3 -> R² = -1.9973, MSE = 2.7408e-01
# X | Val -> R² = -1.0537, MSE = 1.9500e-01
# X | LSG_1 -> R² = 0.1036, MSE = 9.1147e-02
# X | LSG_2 -> R² = -2.7771, MSE = 3.3302e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.453013 | Val Loss 0.537948
# Epoch 100 | Train Loss 0.292279 | Val Loss 0.422002
# Epoch 200 | Train Loss 0.285148 | Val Loss 0.420988
# Epoch 300 | Train Loss 0.280720 | Val Loss 0.405025
# Epoch 400 | Train Loss 0.277937 | Val Loss 0.407067
# Epoch 500 | Train Loss 0.276254 | Val Loss 0.401031
# Epoch 600 | Train Loss 0.274537 | Val Loss 0.400653
# Epoch 700 | Train Loss 0.272967 | Val Loss 0.403932
# Early stopping at epoch 783
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9820, MSE = 1.9201e-03
# X | Train_2 -> R² = 0.9521, MSE = 4.0267e-03
# X | Test_1 -> R² = 0.2563, MSE = 7.7274e-02
# X | Test_2 -> R² = 0.6799, MSE = 2.6265e-02
# X | Test_3 -> R² = -0.5179, MSE = 1.3880e-01
# X | Val -> R² = 0.7470, MSE = 2.4027e-02
# X | LSG_1 -> R² = 0.8050, MSE = 1.9830e-02
# ...
# X | Train_1 -> R² = 0.9948, MSE = 5.5229e-04
# X | Train_2 -> R² = 0.9782, MSE = 1.8329e-03
# X | Test_1 -> R² = 0.6361, MSE = 3.7815e-02
# X | Test_2 -> R² = -0.0955, MSE = 8.9890e-02
# X | Test_3 -> R² = -1.0188, MSE = 1.8460e-01
# X | Val -> R² = -0.1210, MSE = 1.0644e-01
# X | LSG_1 -> R² = 0.4995, MSE = 5.0891e-02
# X | LSG_2 -> R² = -4.3138, MSE = 4.6852e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.388907 | Val Loss 0.465044
# Epoch 100 | Train Loss 0.139938 | Val Loss 0.398881
# Epoch 200 | Train Loss 0.137455 | Val Loss 0.402508
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.7273e-04
# X | Train_2 -> R² = 0.9940, MSE = 5.0131e-04
# X | Test_1 -> R² = 0.9683, MSE = 3.2966e-03
# X | Test_2 -> R² = -0.5997, MSE = 1.3127e-01
# X | Test_3 -> R² = -1.2879, MSE = 2.0921e-01
# X | Val -> R² = -0.6284, MSE = 1.5462e-01
# X | LSG_1 -> R² = -0.1426, MSE = 1.1617e-01
# X | LSG_2 -> R² = -3.6153, MSE = 4.0693e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.437530 | Val Loss 0.478767
# Epoch 100 | Train Loss 0.140529 | Val Loss 0.397490
# Epoch 200 | Train Loss 0.137164 | Val Loss 0.406247
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9955, MSE = 4.8507e-04
# X | Train_2 -> R² = 0.9966, MSE = 2.8533e-04
# X | Test_1 -> R² = 0.7016, MSE = 3.1003e-02
# X | Test_2 -> R² = -0.4359, MSE = 1.1783e-01
# X | Test_3 -> R² = -0.3782, MSE = 1.2603e-01
# X | Val -> R² = 0.4304, MSE = 5.4085e-02
# X | LSG_1 -> R² = -0.5355, MSE = 1.5613e-01
# X | LSG_2 -> R² = -3.4774, MSE = 3.9477e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.398469 | Val Loss 0.510040
# Epoch 100 | Train Loss 0.140992 | Val Loss 0.397694
# Epoch 200 | Train Loss 0.137747 | Val Loss 0.404849
# Early stopping at epoch 285
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9953, MSE = 5.0717e-04
# X | Train_2 -> R² = 0.9948, MSE = 4.3632e-04
# X | Test_1 -> R² = 0.9316, MSE = 7.1037e-03
# X | Test_2 -> R² = -0.5450, MSE = 1.2678e-01
# X | Test_3 -> R² = -0.6970, MSE = 1.5517e-01
# X | Val -> R² = -0.2174, MSE = 1.1559e-01
# X | LSG_1 -> R² = -1.1418, MSE = 2.1777e-01
# X | LSG_2 -> R² = -3.3809, MSE = 3.8627e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.488496 | Val Loss 0.506082
# Epoch 100 | Train Loss 0.140894 | Val Loss 0.397719
# Epoch 200 | Train Loss 0.138074 | Val Loss 0.400454
# Early stopping at epoch 288
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.8151e-04
# X | Train_2 -> R² = 0.9948, MSE = 4.3945e-04
# X | Test_1 -> R² = 0.9300, MSE = 7.2761e-03
# X | Test_2 -> R² = -0.2141, MSE = 9.9627e-02
# X | Test_3 -> R² = -1.3081, MSE = 2.1105e-01
# X | Val -> R² = -0.2733, MSE = 1.2090e-01
# X | LSG_1 -> R² = -0.2196, MSE = 1.2401e-01
# X | LSG_2 -> R² = -3.5577, MSE = 4.0185e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.400799 | Val Loss 0.436191
# Epoch 100 | Train Loss 0.141180 | Val Loss 0.400686
# Epoch 200 | Train Loss 0.137485 | Val Loss 0.402003
# Epoch 300 | Train Loss 0.135650 | Val Loss 0.410087
# Early stopping at epoch 327
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9946, MSE = 5.7544e-04
# X | Train_2 -> R² = 0.9969, MSE = 2.5750e-04
# X | Test_1 -> R² = 0.8954, MSE = 1.0864e-02
# X | Test_2 -> R² = 0.3636, MSE = 5.2223e-02
# X | Test_3 -> R² = -1.7475, MSE = 2.5123e-01
# X | Val -> R² = -0.5523, MSE = 1.4739e-01
# X | LSG_1 -> R² = 0.2256, MSE = 7.8741e-02
# X | LSG_2 -> R² = -3.0052, MSE = 3.5314e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.495057 | Val Loss 0.513176
# Epoch 100 | Train Loss 0.141579 | Val Loss 0.399617
# Epoch 200 | Train Loss 0.137816 | Val Loss 0.397116
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1830.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1830.weights.h5
# X | Train_1 -> R² = 0.9944, MSE = 5.9425e-04
# X | Train_2 -> R² = -0.4971, MSE = 1.2584e-01
# X | Test_1 -> R² = 0.8610, MSE = 1.4447e-02
# X | Test_2 -> R² = -3.8314, MSE = 3.9645e-01
# X | Test_3 -> R² = -1.1074, MSE = 1.9271e-01
# X | Val -> R² = -0.7558, MSE = 1.6671e-01
# X | LSG_1 -> R² = 0.7864, MSE = 2.1716e-02
# X | LSG_2 -> R² = -6.7882, MSE = 6.8669e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.389867 | Val Loss 0.483689
# Epoch 100 | Train Loss 0.141883 | Val Loss 0.394967
# Epoch 200 | Train Loss 0.137155 | Val Loss 0.406260
# Early stopping at epoch 292
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1940.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1940.weights.h5
# X | Train_1 -> R² = 0.9933, MSE = 7.1818e-04
# X | Train_2 -> R² = 0.9963, MSE = 3.0990e-04
# X | Test_1 -> R² = 0.7713, MSE = 2.3764e-02
# X | Test_2 -> R² = -0.5451, MSE = 1.2678e-01
# X | Test_3 -> R² = -0.2036, MSE = 1.1006e-01
# X | Val -> R² = 0.3066, MSE = 6.5837e-02
# X | LSG_1 -> R² = -1.3797, MSE = 2.4197e-01
# X | LSG_2 -> R² = -3.3241, MSE = 3.8125e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.394333 | Val Loss 0.480454
# Epoch 100 | Train Loss 0.140648 | Val Loss 0.393984
# Epoch 200 | Train Loss 0.136136 | Val Loss 0.400449
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5679.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5679.weights.h5
# X | Train_1 -> R² = 0.9954, MSE = 4.8915e-04
# X | Train_2 -> R² = 0.9961, MSE = 3.2805e-04
# X | Test_1 -> R² = 0.8751, MSE = 1.2980e-02
# X | Test_2 -> R² = -0.2010, MSE = 9.8551e-02
# X | Test_3 -> R² = -0.9808, MSE = 1.8112e-01
# X | Val -> R² = -0.1668, MSE = 1.1079e-01
# X | LSG_1 -> R² = 0.0261, MSE = 9.9024e-02
# X | LSG_2 -> R² = -3.6450, MSE = 4.0955e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.444398 | Val Loss 0.531741
# Epoch 100 | Train Loss 0.141944 | Val Loss 0.391546
# Epoch 200 | Train Loss 0.138033 | Val Loss 0.396136
# Early stopping at epoch 296
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2408.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2408.weights.h5
# X | Train_1 -> R² = 0.9934, MSE = 7.0076e-04
# X | Train_2 -> R² = 0.9966, MSE = 2.8561e-04
# X | Test_1 -> R² = 0.8859, MSE = 1.1855e-02
# X | Test_2 -> R² = -0.4255, MSE = 1.1697e-01
# X | Test_3 -> R² = -1.1769, MSE = 1.9906e-01
# X | Val -> R² = -0.3827, MSE = 1.3129e-01
# X | LSG_1 -> R² = -1.0095, MSE = 2.0433e-01
# X | LSG_2 -> R² = -3.2366, MSE = 3.7354e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.446051 | Val Loss 0.504576
# Epoch 100 | Train Loss 0.141332 | Val Loss 0.391210
# Epoch 200 | Train Loss 0.137973 | Val Loss 0.398738
# Early stopping at epoch 290
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7125.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7125.weights.h5
# X | Train_1 -> R² = 0.9938, MSE = 6.5965e-04
# X | Train_2 -> R² = 0.9959, MSE = 3.4210e-04
# X | Test_1 -> R² = 0.8590, MSE = 1.4653e-02
# X | Test_2 -> R² = -0.1103, MSE = 9.1108e-02
# X | Test_3 -> R² = -1.0923, MSE = 1.9132e-01
# X | Val -> R² = -0.2011, MSE = 1.1405e-01
# X | LSG_1 -> R² = -0.6691, MSE = 1.6971e-01
# X | LSG_2 -> R² = -3.2515, MSE = 3.7486e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7125 salvo.
# Epoch 0 | Train Loss 0.613984 | Val Loss 0.501386
# Epoch 100 | Train Loss 0.282763 | Val Loss 0.403908
# Epoch 200 | Train Loss 0.278848 | Val Loss 0.399309
# Epoch 300 | Train Loss 0.276152 | Val Loss 0.397752
# Epoch 400 | Train Loss 0.273739 | Val Loss 0.392707
# Epoch 500 | Train Loss 0.268909 | Val Loss 0.404651
# Early stopping at epoch 588
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9204, MSE = 8.5092e-03
# X | Train_2 -> R² = 0.4410, MSE = 4.6984e-02
# X | Test_1 -> R² = 0.2576, MSE = 7.7142e-02
# X | Test_2 -> R² = -0.3738, MSE = 1.1273e-01
# X | Test_3 -> R² = -1.7530, MSE = 2.5174e-01
# X | Val -> R² = -0.0900, MSE = 1.0349e-01
# X | LSG_1 -> R² = 0.8685, MSE = 1.3369e-02
# X | LSG_2 -> R² = -3.3229, MSE = 3.8115e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1830 salvo.
# Epoch 0 | Train Loss 0.560296 | Val Loss 0.481682
# Epoch 100 | Train Loss 0.282742 | Val Loss 0.394914
# Epoch 200 | Train Loss 0.278753 | Val Loss 0.399799
# Epoch 300 | Train Loss 0.276130 | Val Loss 0.401455
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9830, MSE = 1.8133e-03
# X | Train_2 -> R² = -0.8949, MSE = 1.5927e-01
# X | Test_1 -> R² = 0.0560, MSE = 9.8087e-02
# X | Test_2 -> R² = -4.3804, MSE = 4.4150e-01
# X | Test_3 -> R² = -0.2197, MSE = 1.1153e-01
# X | Val -> R² = 0.3895, MSE = 5.7972e-02
# X | LSG_1 -> R² = 0.7355, MSE = 2.6898e-02
# X | LSG_2 -> R² = -7.3780, MSE = 7.3869e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1940 salvo.
# Epoch 0 | Train Loss 0.638924 | Val Loss 0.553858
# Epoch 100 | Train Loss 0.282953 | Val Loss 0.397117
# Epoch 200 | Train Loss 0.278890 | Val Loss 0.394604
# Epoch 300 | Train Loss 0.276409 | Val Loss 0.397883
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5679.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5679.weights.h5
# X | Train_1 -> R² = 0.9853, MSE = 1.5667e-03
# X | Train_2 -> R² = -0.1232, MSE = 9.4406e-02
# X | Test_1 -> R² = 0.2115, MSE = 8.1932e-02
# X | Test_2 -> R² = -2.9004, MSE = 3.2006e-01
# X | Test_3 -> R² = -0.6361, MSE = 1.4961e-01
# X | Val -> R² = -0.0228, MSE = 9.7114e-02
# X | LSG_1 -> R² = 0.7841, MSE = 2.1955e-02
# X | LSG_2 -> R² = -6.2705, MSE = 6.4104e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5679 salvo.
# Epoch 0 | Train Loss 0.582800 | Val Loss 0.470130
# Epoch 100 | Train Loss 0.282239 | Val Loss 0.396754
# Epoch 200 | Train Loss 0.278910 | Val Loss 0.394383
# Epoch 300 | Train Loss 0.276437 | Val Loss 0.393031
# Epoch 400 | Train Loss 0.274311 | Val Loss 0.391178
# Early stopping at epoch 421
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2408.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2408.weights.h5
# X | Train_1 -> R² = 0.9556, MSE = 4.7524e-03
# X | Train_2 -> R² = -0.5412, MSE = 1.2954e-01
# X | Test_1 -> R² = 0.0753, MSE = 9.6080e-02
# X | Test_2 -> R² = -2.9048, MSE = 3.2042e-01
# X | Test_3 -> R² = -0.4856, MSE = 1.3585e-01
# X | Val -> R² = 0.2009, MSE = 7.5872e-02
# X | LSG_1 -> R² = 0.5793, MSE = 4.2772e-02
# X | LSG_2 -> R² = -6.2271, MSE = 6.3721e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2408 salvo.
# Epoch 0 | Train Loss 0.579943 | Val Loss 0.487925
# Epoch 100 | Train Loss 0.283356 | Val Loss 0.396151
# Epoch 200 | Train Loss 0.279035 | Val Loss 0.393647
# Epoch 300 | Train Loss 0.275892 | Val Loss 0.396156
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7125.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7125.weights.h5
# X | Train_1 -> R² = 0.9835, MSE = 1.7689e-03
# X | Train_2 -> R² = -1.4876, MSE = 2.0909e-01
# X | Test_1 -> R² = 0.2450, MSE = 7.8453e-02
# X | Test_2 -> R² = -4.0831, MSE = 4.1710e-01
# X | Test_3 -> R² = -1.3297, MSE = 2.1303e-01
# X | Val -> R² = -0.9348, MSE = 1.8371e-01
# X | LSG_1 -> R² = 0.3861, MSE = 6.2417e-02
# X | LSG_2 -> R² = -7.7563, MSE = 7.7204e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7125 salvo.
# Epoch 0 | Train Loss 0.577954 | Val Loss 0.503224
# Epoch 100 | Train Loss 0.283677 | Val Loss 0.393043
# Epoch 200 | Train Loss 0.280042 | Val Loss 0.396234
# Epoch 300 | Train Loss 0.277548 | Val Loss 0.397652
# Epoch 400 | Train Loss 0.275556 | Val Loss 0.404520
# Early stopping at epoch 426
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1830.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1830.weights.h5
# X | Train_1 -> R² = 0.9791, MSE = 2.2375e-03
# X | Train_2 -> R² = -1.7025, MSE = 2.2715e-01
# X | Test_1 -> R² = 0.2008, MSE = 8.3042e-02
# X | Test_2 -> R² = -5.0288, MSE = 4.9470e-01
# X | Test_3 -> R² = -1.0391, MSE = 1.8646e-01
# X | Val -> R² = -0.9134, MSE = 1.8168e-01
# X | LSG_1 -> R² = 0.3508, MSE = 6.6007e-02
# X | LSG_2 -> R² = -7.7260, MSE = 7.6937e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1830 salvo.
# Epoch 0 | Train Loss 0.578449 | Val Loss 0.503584
# Epoch 100 | Train Loss 0.283940 | Val Loss 0.399673
# Epoch 200 | Train Loss 0.279731 | Val Loss 0.408094
# Early stopping at epoch 297
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1940.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1940.weights.h5
# X | Train_1 -> R² = 0.9909, MSE = 9.7430e-04
# X | Train_2 -> R² = 0.9936, MSE = 5.3878e-04
# X | Test_1 -> R² = 0.3860, MSE = 6.3798e-02
# X | Test_2 -> R² = -0.5709, MSE = 1.2891e-01
# X | Test_3 -> R² = -0.1843, MSE = 1.0830e-01
# X | Val -> R² = 0.1174, MSE = 8.3803e-02
# X | LSG_1 -> R² = -0.6876, MSE = 1.7159e-01
# X | LSG_2 -> R² = -3.4530, MSE = 3.9262e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1940 salvo.
# Epoch 0 | Train Loss 0.569911 | Val Loss 0.532512
# Epoch 100 | Train Loss 0.283357 | Val Loss 0.396402
# Epoch 200 | Train Loss 0.280426 | Val Loss 0.398098
# Epoch 300 | Train Loss 0.275728 | Val Loss 0.405344
# Early stopping at epoch 398
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5679.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5679.weights.h5
# X | Train_1 -> R² = 0.9673, MSE = 3.4916e-03
# X | Train_2 -> R² = -0.7831, MSE = 1.4988e-01
# X | Test_1 -> R² = -0.2543, MSE = 1.3033e-01
# X | Test_2 -> R² = -3.2640, MSE = 3.4989e-01
# X | Test_3 -> R² = -0.3783, MSE = 1.2603e-01
# X | Val -> R² = 0.1824, MSE = 7.7635e-02
# X | LSG_1 -> R² = 0.6265, MSE = 3.7974e-02
# X | LSG_2 -> R² = -7.0346, MSE = 7.0841e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5679 salvo.
# Epoch 0 | Train Loss 0.531869 | Val Loss 0.475362
# Epoch 100 | Train Loss 0.282503 | Val Loss 0.393493
# Epoch 200 | Train Loss 0.278681 | Val Loss 0.394690
# Epoch 300 | Train Loss 0.276000 | Val Loss 0.400172
# Early stopping at epoch 339
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2408.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2408.weights.h5
# X | Train_1 -> R² = 0.9864, MSE = 1.4586e-03
# X | Train_2 -> R² = -0.3119, MSE = 1.1027e-01
# X | Test_1 -> R² = 0.3772, MSE = 6.4718e-02
# X | Test_2 -> R² = -3.4545, MSE = 3.6552e-01
# X | Test_3 -> R² = -1.1662, MSE = 1.9808e-01
# X | Val -> R² = -0.5859, MSE = 1.5058e-01
# X | LSG_1 -> R² = 0.7929, MSE = 2.1056e-02
# X | LSG_2 -> R² = -6.1025, MSE = 6.2622e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2408 salvo.
# Epoch 0 | Train Loss 0.566005 | Val Loss 0.444897
# Epoch 100 | Train Loss 0.283190 | Val Loss 0.396476
# Epoch 200 | Train Loss 0.279051 | Val Loss 0.396490
# Epoch 300 | Train Loss 0.276719 | Val Loss 0.404020
# Early stopping at epoch 342
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7125.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7125.weights.h5
# X | Train_1 -> R² = 0.9867, MSE = 1.4219e-03
# X | Train_2 -> R² = -0.7311, MSE = 1.4551e-01
# X | Test_1 -> R² = 0.1876, MSE = 8.4409e-02
# X | Test_2 -> R² = -3.9785, MSE = 4.0852e-01
# X | Test_3 -> R² = -1.0314, MSE = 1.8575e-01
# X | Val -> R² = -0.6618, MSE = 1.5779e-01
# X | LSG_1 -> R² = 0.7422, MSE = 2.6211e-02
# X | LSG_2 -> R² = -6.5924, MSE = 6.6942e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7125 salvo.
