# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(Theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Val_1", "Val_2", "Test_1", "Test_2", "LSG_1", "LSG_2"]
PLOT = False
PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "sinTheta"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 15
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./../Theta/Data/Datasets.xlsx", sheet_name=title)
    # df_theta = pd.read_excel("./../Theta/resultados_comparacao.xlsx", sheet_name=title)

    # df["Theta_pred"] = df_theta["Theta_pred_model_arch16-8_r0.9_Ld0.3_Lp0.7_seed6545"]

    df["sinTheta"] = np.sin(df["Theta"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = pd.concat([NormDatasets[2], NormDatasets[3]], ignore_index=True)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1905, 15, 5)
# Dimensão da saida: (1905, 1)
# Dimensão da entrada: (1917, 15, 5)
# Dimensão da saida: (1917, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1905, 15, 5)
# Dimensão da saida: (1905, 1)
# Dimensão da entrada fisica : (1905,)
# Dimensão da entrada fisica: (1905,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)
    return [dy_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    alpha = 3.0
    weights = 1 + alpha * tf.abs(dy)

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(weights * tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_targets = len(TARGET)
    if PLOT == True:
        n_datasets = len(Datasets)
        fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val_1": [], "R2_Val_2": [],
            "R2_Test_1": [], "R2_Test_2": [], 
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val_1": [], "MSE_Val_2": [],
            "MSE_Test_1": [], "MSE_Test_2": [], 
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            if PLOT == True:
                # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
                ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
                    axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
                )
                PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)
    if PLOT == True:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_1_{name}": to_scalar(metrics[name]["R2_Val_1"]),
            f"MSE_Val_1_{name}": to_scalar(metrics[name]["MSE_Val_1"]),
            f"R2_Val_2_{name}": to_scalar(metrics[name]["R2_Val_2"]),
            f"MSE_Val_2_{name}": to_scalar(metrics[name]["MSE_Val_2"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_LSG_1_{name}": to_scalar(metrics[name]["R2_LSG_1"]),
            f"MSE_LSG_1_{name}": to_scalar(metrics[name]["MSE_LSG_1"]),
            f"R2_LSG_2_{name}": to_scalar(metrics[name]["R2_LSG_2"]),
            f"MSE_LSG_2_{name}": to_scalar(metrics[name]["MSE_LSG_2"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 8.798571 | Val Loss 2.789129
# Epoch 100 | Train Loss 3.798920 | Val Loss 1.619642
# Epoch 200 | Train Loss 1.375078 | Val Loss 0.912599
# Epoch 300 | Train Loss 0.390578 | Val Loss 0.335168
# Epoch 400 | Train Loss 0.342372 | Val Loss 0.313112
# Epoch 500 | Train Loss 0.321992 | Val Loss 0.302892
# Epoch 600 | Train Loss 0.297090 | Val Loss 0.289422
# Epoch 700 | Train Loss 0.281505 | Val Loss 0.317959
# Epoch 800 | Train Loss 0.250654 | Val Loss 0.350102
# Early stopping at epoch 891
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9732, MSE = 2.2063e-03
# Y | Train_2 -> R² = 0.8681, MSE = 1.3677e-02
# Y | Val_1 -> R² = 0.6482, MSE = 2.8225e-02
# Y | Val_2 -> R² = 0.9054, MSE = 9.6814e-03
# Y | Test_1 -> R² = -0.2516, MSE = 9.4392e-02
# Y | Test_2 -> R² = 0.9608, MSE = 2.8724e-03
# Y | LSG_1 -> R² = -0.7712, MSE = 5.7451e-01
# Y | LSG_2 -> R² = -0.3041, MSE = 5.1605e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4602 salvo.
# Epoch 0 | Train Loss 9.193933 | Val Loss 2.908677
# Epoch 100 | Train Loss 3.988766 | Val Loss 1.732000
# Epoch 200 | Train Loss 1.699534 | Val Loss 1.169710
# Epoch 300 | Train Loss 1.591781 | Val Loss 1.082458
# Epoch 400 | Train Loss 1.384796 | Val Loss 0.938052
# Epoch 500 | Train Loss 0.370757 | Val Loss 0.365705
# Epoch 600 | Train Loss 0.313412 | Val Loss 0.305172
# Epoch 700 | Train Loss 0.285193 | Val Loss 0.297396
# Epoch 800 | Train Loss 0.271127 | Val Loss 0.325257
# Early stopping at epoch 886
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9412, MSE = 4.8415e-03
# Y | Train_2 -> R² = 0.9813, MSE = 1.9347e-03
# Y | Val_1 -> R² = 0.3551, MSE = 5.1750e-02
# Y | Val_2 -> R² = 0.9606, MSE = 4.0317e-03
# Y | Test_1 -> R² = -1.3912, MSE = 1.8034e-01
# Y | Test_2 -> R² = -0.5712, MSE = 1.1518e-01
# Y | LSG_1 -> R² = -0.2569, MSE = 4.0769e-01
# Y | LSG_2 -> R² = -0.1121, MSE = 4.4009e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8458 salvo.
# Epoch 0 | Train Loss 8.539762 | Val Loss 2.715529
# Epoch 100 | Train Loss 4.095948 | Val Loss 1.898815
# Epoch 200 | Train Loss 1.846483 | Val Loss 1.200949
# Epoch 300 | Train Loss 1.649482 | Val Loss 1.140483
# Epoch 400 | Train Loss 1.587267 | Val Loss 1.069167
# Epoch 500 | Train Loss 0.973691 | Val Loss 0.605345
# Epoch 600 | Train Loss 0.387916 | Val Loss 0.284380
# Epoch 700 | Train Loss 0.331678 | Val Loss 0.260563
# Epoch 800 | Train Loss 0.300598 | Val Loss 0.261285
# Epoch 900 | Train Loss 0.286007 | Val Loss 0.251243
# Epoch 1000 | Train Loss 0.271522 | Val Loss 0.241089
# Early stopping at epoch 1054
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed6756.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9872, MSE = 1.0502e-03
# Y | Train_2 -> R² = 0.9893, MSE = 1.1104e-03
# Y | Val_1 -> R² = 0.8236, MSE = 1.4157e-02
# Y | Val_2 -> R² = 0.9586, MSE = 4.2390e-03
# Y | Test_1 -> R² = 0.2949, MSE = 5.3180e-02
# Y | Test_2 -> R² = 0.8339, MSE = 1.2174e-02
# Y | LSG_1 -> R² = 0.1778, MSE = 2.6669e-01
# Y | LSG_2 -> R² = 0.2674, MSE = 2.8990e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 9.119081 | Val Loss 2.902988
# Epoch 100 | Train Loss 4.000452 | Val Loss 1.669611
# Epoch 200 | Train Loss 1.672953 | Val Loss 1.124050
# Epoch 300 | Train Loss 1.484214 | Val Loss 0.997234
# Epoch 400 | Train Loss 0.548343 | Val Loss 0.390897
# Epoch 500 | Train Loss 0.329153 | Val Loss 0.267055
# Epoch 600 | Train Loss 0.274992 | Val Loss 0.230613
# Epoch 700 | Train Loss 0.270830 | Val Loss 0.195961
# Epoch 800 | Train Loss 0.261199 | Val Loss 0.240316
# Epoch 900 | Train Loss 0.260296 | Val Loss 0.202353
# Epoch 1000 | Train Loss 0.252476 | Val Loss 0.223933
# Epoch 1100 | Train Loss 0.250216 | Val Loss 0.199159
# Epoch 1200 | Train Loss 0.246216 | Val Loss 0.210863
# Early stopping at epoch 1233
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9852, MSE = 1.2167e-03
# Y | Train_2 -> R² = 0.7934, MSE = 2.1424e-02
# Y | Val_1 -> R² = 0.9344, MSE = 5.2644e-03
# Y | Val_2 -> R² = 0.8795, MSE = 1.2339e-02
# Y | Test_1 -> R² = 0.4927, MSE = 3.8263e-02
# Y | Test_2 -> R² = 0.2620, MSE = 5.4107e-02
# Y | LSG_1 -> R² = 0.3703, MSE = 2.0426e-01
# Y | LSG_2 -> R² = 0.3715, MSE = 2.4873e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 8.614438 | Val Loss 2.745791
# Epoch 100 | Train Loss 2.448831 | Val Loss 0.772591
# Epoch 200 | Train Loss 0.549910 | Val Loss 0.315583
# Epoch 300 | Train Loss 0.407223 | Val Loss 0.247632
# Epoch 400 | Train Loss 0.291544 | Val Loss 0.205709
# Epoch 500 | Train Loss 0.245371 | Val Loss 0.179561
# Epoch 600 | Train Loss 0.229312 | Val Loss 0.201095
# Early stopping at epoch 679
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9617, MSE = 3.1523e-03
# Y | Train_2 -> R² = 0.9293, MSE = 7.3304e-03
# Y | Val_1 -> R² = 0.9428, MSE = 4.5874e-03
# Y | Val_2 -> R² = 0.9477, MSE = 5.3554e-03
# Y | Test_1 -> R² = 0.2254, MSE = 5.8421e-02
# Y | Test_2 -> R² = 0.4832, MSE = 3.7885e-02
# Y | LSG_1 -> R² = -3.9327, MSE = 1.6000e+00
# Y | LSG_2 -> R² = -1.6822, MSE = 1.0614e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 8.548173 | Val Loss 2.737589
# Epoch 100 | Train Loss 4.143700 | Val Loss 1.924575
# Epoch 200 | Train Loss 1.757478 | Val Loss 1.182304
# Epoch 300 | Train Loss 1.085958 | Val Loss 0.696741
# Epoch 400 | Train Loss 0.360285 | Val Loss 0.278644
# Epoch 500 | Train Loss 0.284844 | Val Loss 0.223635
# Epoch 600 | Train Loss 0.262596 | Val Loss 0.211532
# Epoch 700 | Train Loss 0.254556 | Val Loss 0.203077
# Epoch 800 | Train Loss 0.248019 | Val Loss 0.194769
# Epoch 900 | Train Loss 0.242590 | Val Loss 0.187331
# Epoch 1000 | Train Loss 0.237597 | Val Loss 0.181764
# Epoch 1100 | Train Loss 0.233309 | Val Loss 0.177845
# Epoch 1200 | Train Loss 0.229874 | Val Loss 0.174910
# Epoch 1300 | Train Loss 0.226642 | Val Loss 0.169841
# Epoch 1400 | Train Loss 0.223519 | Val Loss 0.168738
# Epoch 1500 | Train Loss 0.220499 | Val Loss 0.156372
# Epoch 1600 | Train Loss 0.217077 | Val Loss 0.157131
# Epoch 1700 | Train Loss 0.214034 | Val Loss 0.154502
# Epoch 1800 | Train Loss 0.211510 | Val Loss 0.147813
# Epoch 1900 | Train Loss 0.208754 | Val Loss 0.148315
# Epoch 2000 | Train Loss 0.206893 | Val Loss 0.152160
# Early stopping at epoch 2017
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9942, MSE = 4.7899e-04
# Y | Train_2 -> R² = 0.9840, MSE = 1.6636e-03
# Y | Val_1 -> R² = 0.9229, MSE = 6.1852e-03
# Y | Val_2 -> R² = 0.9881, MSE = 1.2200e-03
# Y | Test_1 -> R² = -1.0614, MSE = 1.5547e-01
# Y | Test_2 -> R² = 0.8148, MSE = 1.3577e-02
# Y | LSG_1 -> R² = -0.2317, MSE = 3.9951e-01
# Y | LSG_2 -> R² = 0.0765, MSE = 3.6544e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 9.034533 | Val Loss 2.881142
# Epoch 100 | Train Loss 4.075805 | Val Loss 1.898333
# Epoch 200 | Train Loss 1.841084 | Val Loss 1.278331
# Epoch 300 | Train Loss 1.644537 | Val Loss 1.168382
# Epoch 400 | Train Loss 1.542992 | Val Loss 1.070941
# Epoch 500 | Train Loss 1.406540 | Val Loss 0.942686
# Epoch 600 | Train Loss 0.643879 | Val Loss 0.432031
# Epoch 700 | Train Loss 0.316229 | Val Loss 0.233729
# Epoch 800 | Train Loss 0.340656 | Val Loss 0.238858
# Epoch 900 | Train Loss 0.264331 | Val Loss 0.195748
# Epoch 1000 | Train Loss 0.285781 | Val Loss 0.231248
# Epoch 1100 | Train Loss 0.266568 | Val Loss 0.210961
# Early stopping at epoch 1149
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9722, MSE = 2.2928e-03
# Y | Train_2 -> R² = 0.9931, MSE = 7.1765e-04
# Y | Val_1 -> R² = 0.9659, MSE = 2.7393e-03
# Y | Val_2 -> R² = 0.9857, MSE = 1.4669e-03
# Y | Test_1 -> R² = -0.5351, MSE = 1.1578e-01
# Y | Test_2 -> R² = -0.8816, MSE = 1.3794e-01
# Y | LSG_1 -> R² = -0.7589, MSE = 5.7052e-01
# Y | LSG_2 -> R² = -0.0131, MSE = 4.0091e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8458 salvo.
# Epoch 0 | Train Loss 8.801909 | Val Loss 2.801731
# Epoch 100 | Train Loss 4.032812 | Val Loss 1.857060
# Epoch 200 | Train Loss 1.671564 | Val Loss 1.175061
# Epoch 300 | Train Loss 1.579266 | Val Loss 1.108768
# Epoch 400 | Train Loss 1.028858 | Val Loss 0.632541
# Epoch 500 | Train Loss 0.377569 | Val Loss 0.323859
# Epoch 600 | Train Loss 0.303287 | Val Loss 0.272355
# Epoch 700 | Train Loss 0.279004 | Val Loss 0.261727
# Epoch 800 | Train Loss 0.259876 | Val Loss 0.255864
# Epoch 900 | Train Loss 0.244757 | Val Loss 0.261899
# Epoch 1000 | Train Loss 0.228757 | Val Loss 0.291204
# Early stopping at epoch 1057
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed6756.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9871, MSE = 1.0605e-03
# Y | Train_2 -> R² = 0.9938, MSE = 6.4232e-04
# Y | Val_1 -> R² = 0.8882, MSE = 8.9705e-03
# Y | Val_2 -> R² = 0.8854, MSE = 1.1732e-02
# Y | Test_1 -> R² = 0.1634, MSE = 6.3092e-02
# Y | Test_2 -> R² = -1.1724, MSE = 1.5926e-01
# Y | LSG_1 -> R² = -0.0413, MSE = 3.3775e-01
# Y | LSG_2 -> R² = 0.3191, MSE = 2.6945e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=6756 salvo.
# Epoch 0 | Train Loss 8.775149 | Val Loss 2.793235
# Epoch 100 | Train Loss 2.952805 | Val Loss 1.247022
# Epoch 200 | Train Loss 1.578707 | Val Loss 1.094602
# Epoch 300 | Train Loss 1.480017 | Val Loss 1.011991
# Epoch 400 | Train Loss 1.336074 | Val Loss 0.886020
# Epoch 500 | Train Loss 0.805338 | Val Loss 0.556122
# Epoch 600 | Train Loss 0.323916 | Val Loss 0.332234
# Epoch 700 | Train Loss 0.280996 | Val Loss 0.248366
# Epoch 800 | Train Loss 0.259671 | Val Loss 0.227503
# Epoch 900 | Train Loss 0.248412 | Val Loss 0.212917
# Epoch 1000 | Train Loss 0.240659 | Val Loss 0.202759
# Epoch 1100 | Train Loss 0.236477 | Val Loss 0.204234
# Epoch 1200 | Train Loss 0.228372 | Val Loss 0.196052
# Epoch 1300 | Train Loss 0.224441 | Val Loss 0.192256
# Epoch 1400 | Train Loss 0.219012 | Val Loss 0.186803
# Epoch 1500 | Train Loss 0.216106 | Val Loss 0.183247
# Epoch 1600 | Train Loss 0.210843 | Val Loss 0.188977
# Early stopping at epoch 1654
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9487, MSE = 4.2255e-03
# Y | Train_2 -> R² = 0.8352, MSE = 1.7093e-02
# Y | Val_1 -> R² = 0.8197, MSE = 1.4467e-02
# Y | Val_2 -> R² = 0.9576, MSE = 4.3391e-03
# Y | Test_1 -> R² = 0.1772, MSE = 6.2051e-02
# Y | Test_2 -> R² = 0.6580, MSE = 2.5075e-02
# Y | LSG_1 -> R² = -0.3644, MSE = 4.4258e-01
# Y | LSG_2 -> R² = 0.2024, MSE = 3.1562e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8792 salvo.
# Epoch 0 | Train Loss 8.669980 | Val Loss 2.746563
# Epoch 100 | Train Loss 1.477089 | Val Loss 0.472274
# Epoch 200 | Train Loss 0.508237 | Val Loss 0.297167
# Epoch 300 | Train Loss 0.392197 | Val Loss 0.248853
# Epoch 400 | Train Loss 0.347945 | Val Loss 0.225221
# Epoch 500 | Train Loss 0.326007 | Val Loss 0.218569
# Epoch 600 | Train Loss 0.312528 | Val Loss 0.216686
# Epoch 700 | Train Loss 0.301817 | Val Loss 0.215366
# Epoch 800 | Train Loss 0.290860 | Val Loss 0.214289
# Epoch 900 | Train Loss 0.274441 | Val Loss 0.221232
# Epoch 1000 | Train Loss 0.263095 | Val Loss 0.234242
# Early stopping at epoch 1050
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9857, MSE = 1.1780e-03
# Y | Train_2 -> R² = 0.9879, MSE = 1.2558e-03
# Y | Val_1 -> R² = 0.9168, MSE = 6.6745e-03
# Y | Val_2 -> R² = 0.9475, MSE = 5.3728e-03
# Y | Test_1 -> R² = -4.9472, MSE = 4.4853e-01
# Y | Test_2 -> R² = 0.9275, MSE = 5.3139e-03
# Y | LSG_1 -> R² = -1.0033, MSE = 6.4981e-01
# Y | LSG_2 -> R² = -0.1670, MSE = 4.6180e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=547 salvo.
# Epoch 0 | Train Loss 16.238602 | Val Loss 2.766542
# Epoch 100 | Train Loss 6.852515 | Val Loss 1.975657
# Epoch 200 | Train Loss 2.581454 | Val Loss 1.517313
# Epoch 300 | Train Loss 2.248396 | Val Loss 1.330104
# Epoch 400 | Train Loss 1.938266 | Val Loss 1.218010
# Epoch 500 | Train Loss 1.800464 | Val Loss 1.112960
# Epoch 600 | Train Loss 0.657628 | Val Loss 0.328916
# Epoch 700 | Train Loss 0.438979 | Val Loss 0.195204
# Epoch 800 | Train Loss 0.388704 | Val Loss 0.185182
# Epoch 900 | Train Loss 0.339513 | Val Loss 0.184459
# Epoch 1000 | Train Loss 0.323635 | Val Loss 0.171931
# Epoch 1100 | Train Loss 0.279236 | Val Loss 0.171044
# Early stopping at epoch 1144
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed4602.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9901, MSE = 8.1321e-04
# Y | Train_2 -> R² = 0.8456, MSE = 1.6014e-02
# Y | Val_1 -> R² = 0.7616, MSE = 1.9131e-02
# Y | Val_2 -> R² = 0.9578, MSE = 4.3161e-03
# Y | Test_1 -> R² = -1.1709, MSE = 1.6373e-01
# Y | Test_2 -> R² = 0.7690, MSE = 1.6938e-02
# Y | LSG_1 -> R² = -0.3427, MSE = 4.3553e-01
# Y | LSG_2 -> R² = 0.0466, MSE = 3.7727e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4602 salvo.
# Epoch 0 | Train Loss 16.515242 | Val Loss 2.779035
# Epoch 100 | Train Loss 4.022421 | Val Loss 1.181205
# Epoch 200 | Train Loss 2.443594 | Val Loss 1.217365
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8458.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8458.weights.h5
# Y | Train_1 -> R² = -1.0827, MSE = 1.7148e-01
# Y | Train_2 -> R² = -0.2209, MSE = 1.2663e-01
# Y | Val_1 -> R² = -10.6263, MSE = 9.3289e-01
# Y | Val_2 -> R² = -0.4434, MSE = 1.4774e-01
# Y | Test_1 -> R² = -27.3758, MSE = 2.1400e+00
# Y | Test_2 -> R² = -9.7158, MSE = 7.8559e-01
# Y | LSG_1 -> R² = -8.1754, MSE = 2.9762e+00
# Y | LSG_2 -> R² = -5.0624, MSE = 2.3990e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8458 salvo.
# Epoch 0 | Train Loss 16.469078 | Val Loss 2.804398
# Epoch 100 | Train Loss 6.956988 | Val Loss 1.969750
# Epoch 200 | Train Loss 5.998475 | Val Loss 1.842292
# Epoch 300 | Train Loss 2.215704 | Val Loss 1.282474
# Epoch 400 | Train Loss 0.628669 | Val Loss 0.287129
# Epoch 500 | Train Loss 0.420214 | Val Loss 0.224015
# Epoch 600 | Train Loss 0.383609 | Val Loss 0.210845
# Epoch 700 | Train Loss 0.361202 | Val Loss 0.201058
# Epoch 800 | Train Loss 0.403881 | Val Loss 0.193558
# Epoch 900 | Train Loss 0.332456 | Val Loss 0.189720
# Epoch 1000 | Train Loss 0.320576 | Val Loss 0.188142
# Early stopping at epoch 1029
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed6756.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9464, MSE = 4.4156e-03
# Y | Train_2 -> R² = 0.9778, MSE = 2.2993e-03
# Y | Val_1 -> R² = 0.9065, MSE = 7.5000e-03
# Y | Val_2 -> R² = 0.9893, MSE = 1.0912e-03
# Y | Test_1 -> R² = -0.1470, MSE = 8.6506e-02
# Y | Test_2 -> R² = 0.8768, MSE = 9.0327e-03
# Y | LSG_1 -> R² = -2.7578, MSE = 1.2189e+00
# Y | LSG_2 -> R² = -1.7004, MSE = 1.0686e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 15.975777 | Val Loss 2.715393
# Epoch 100 | Train Loss 3.260438 | Val Loss 1.339109
# Epoch 200 | Train Loss 2.394233 | Val Loss 1.319336
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed8792.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed8792.weights.h5
# Y | Train_1 -> R² = -6.9999, MSE = 6.5866e-01
# Y | Train_2 -> R² = 0.3091, MSE = 7.1656e-02
# Y | Val_1 -> R² = -7.2017, MSE = 6.5811e-01
# Y | Val_2 -> R² = 0.2337, MSE = 7.8433e-02
# Y | Test_1 -> R² = -12.5107, MSE = 1.0190e+00
# Y | Test_2 -> R² = -5.8932, MSE = 5.0535e-01
# Y | LSG_1 -> R² = -4.2094, MSE = 1.6898e+00
# Y | LSG_2 -> R² = -2.2967, MSE = 1.3046e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 15.660448 | Val Loss 2.671853
# Epoch 100 | Train Loss 2.868495 | Val Loss 1.172808
# Epoch 200 | Train Loss 2.260595 | Val Loss 1.149599
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed547.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed547.weights.h5
# Y | Train_1 -> R² = -8.2848, MSE = 7.6445e-01
# Y | Train_2 -> R² = 0.3577, MSE = 6.6619e-02
# Y | Val_1 -> R² = -8.0847, MSE = 7.2895e-01
# Y | Val_2 -> R² = 0.2512, MSE = 7.6639e-02
# Y | Test_1 -> R² = -30.2055, MSE = 2.3535e+00
# Y | Test_2 -> R² = -15.3654, MSE = 1.1998e+00
# Y | LSG_1 -> R² = -5.9444, MSE = 2.2525e+00
# Y | LSG_2 -> R² = -3.5653, MSE = 1.8066e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 16.090219 | Val Loss 2.729656
# Epoch 100 | Train Loss 6.842422 | Val Loss 1.982704
# Epoch 200 | Train Loss 2.472810 | Val Loss 1.296172
# Epoch 300 | Train Loss 2.129234 | Val Loss 1.222159
# Early stopping at epoch 346
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed4602.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed4602.weights.h5
# Y | Train_1 -> R² = -8.7439, MSE = 8.0224e-01
# Y | Train_2 -> R² = -0.2527, MSE = 1.2993e-01
# Y | Val_1 -> R² = -11.1749, MSE = 9.7691e-01
# Y | Val_2 -> R² = -0.2861, MSE = 1.3163e-01
# Y | Test_1 -> R² = -28.2725, MSE = 2.2077e+00
# Y | Test_2 -> R² = -13.1210, MSE = 1.0352e+00
# Y | LSG_1 -> R² = -9.2385, MSE = 3.3210e+00
# Y | LSG_2 -> R² = -5.8885, MSE = 2.7260e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 16.300783 | Val Loss 2.749880
# Epoch 100 | Train Loss 2.689665 | Val Loss 1.172340
# Epoch 200 | Train Loss 2.257269 | Val Loss 1.241400
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8458.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8458.weights.h5
# Y | Train_1 -> R² = -7.4880, MSE = 6.9884e-01
# Y | Train_2 -> R² = 0.4044, MSE = 6.1777e-02
# Y | Val_1 -> R² = -8.3101, MSE = 7.4704e-01
# Y | Val_2 -> R² = 0.3055, MSE = 7.1083e-02
# Y | Test_1 -> R² = -22.4714, MSE = 1.7702e+00
# Y | Test_2 -> R² = -10.2666, MSE = 8.2598e-01
# Y | LSG_1 -> R² = -6.0108, MSE = 2.2741e+00
# Y | LSG_2 -> R² = -3.6062, MSE = 1.8228e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8458 salvo.
# Epoch 0 | Train Loss 16.534277 | Val Loss 2.782185
# Epoch 100 | Train Loss 6.895680 | Val Loss 1.983821
# Epoch 200 | Train Loss 2.483722 | Val Loss 1.338839
# Epoch 300 | Train Loss 2.170670 | Val Loss 1.298666
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed6756.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed6756.weights.h5
# Y | Train_1 -> R² = -12.0693, MSE = 1.0760e+00
# Y | Train_2 -> R² = 0.2179, MSE = 8.1122e-02
# Y | Val_1 -> R² = -13.6598, MSE = 1.1763e+00
# Y | Val_2 -> R² = 0.1221, MSE = 8.9851e-02
# Y | Test_1 -> R² = -24.4220, MSE = 1.9173e+00
# Y | Test_2 -> R² = -12.7565, MSE = 1.0085e+00
# Y | LSG_1 -> R² = -9.1054, MSE = 3.2779e+00
# Y | LSG_2 -> R² = -6.0493, MSE = 2.7896e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=6756 salvo.
# Epoch 0 | Train Loss 16.648100 | Val Loss 2.801863
# Epoch 100 | Train Loss 6.957259 | Val Loss 1.958917
# Epoch 200 | Train Loss 2.779739 | Val Loss 1.437397
# Epoch 300 | Train Loss 2.263533 | Val Loss 1.271345
# Epoch 400 | Train Loss 1.527846 | Val Loss 0.807886
# Epoch 500 | Train Loss 0.578564 | Val Loss 0.325049
# Epoch 600 | Train Loss 0.403665 | Val Loss 0.235894
# Epoch 700 | Train Loss 0.350908 | Val Loss 0.206715
# Epoch 800 | Train Loss 0.312828 | Val Loss 0.195717
# Epoch 900 | Train Loss 0.278623 | Val Loss 0.184880
# Epoch 1000 | Train Loss 0.258915 | Val Loss 0.203735
# Early stopping at epoch 1067
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed8792.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9888, MSE = 9.1990e-04
# Y | Train_2 -> R² = 0.9962, MSE = 3.8935e-04
# Y | Val_1 -> R² = 0.9021, MSE = 7.8537e-03
# Y | Val_2 -> R² = 0.9219, MSE = 7.9916e-03
# Y | Test_1 -> R² = -0.7257, MSE = 1.3015e-01
# Y | Test_2 -> R² = 0.8255, MSE = 1.2795e-02
# Y | LSG_1 -> R² = -1.7088, MSE = 8.7864e-01
# Y | LSG_2 -> R² = -1.0119, MSE = 7.9615e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8792 salvo.
# Epoch 0 | Train Loss 16.184227 | Val Loss 2.777694
# Epoch 100 | Train Loss 6.317412 | Val Loss 1.495427
# Epoch 200 | Train Loss 0.760695 | Val Loss 0.298748
# Epoch 300 | Train Loss 0.583161 | Val Loss 0.279266
# Epoch 400 | Train Loss 0.514161 | Val Loss 0.256369
# Epoch 500 | Train Loss 0.465895 | Val Loss 0.256625
# Early stopping at epoch 598
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed547.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed547.weights.h5
# Y | Train_1 -> R² = 0.9412, MSE = 4.8428e-03
# Y | Train_2 -> R² = 0.9748, MSE = 2.6180e-03
# Y | Val_1 -> R² = 0.7922, MSE = 1.6671e-02
# Y | Val_2 -> R² = 0.9675, MSE = 3.3233e-03
# Y | Test_1 -> R² = -1.1378, MSE = 1.6123e-01
# Y | Test_2 -> R² = 0.5761, MSE = 3.1080e-02
# Y | LSG_1 -> R² = -2.6152, MSE = 1.1727e+00
# Y | LSG_2 -> R² = -1.5984, MSE = 1.0283e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=547 salvo.
# Epoch 0 | Train Loss 9.051926 | Val Loss 2.876057
# Epoch 100 | Train Loss 1.803452 | Val Loss 1.265535
# Epoch 200 | Train Loss 1.235068 | Val Loss 0.802069
# Epoch 300 | Train Loss 0.297048 | Val Loss 0.218867
# Epoch 400 | Train Loss 0.270327 | Val Loss 0.168322
# Epoch 500 | Train Loss 0.264488 | Val Loss 0.169925
# Epoch 600 | Train Loss 0.235195 | Val Loss 0.135436
# Epoch 700 | Train Loss 0.224855 | Val Loss 0.130764
# Epoch 800 | Train Loss 0.217496 | Val Loss 0.130902
# Epoch 900 | Train Loss 0.213148 | Val Loss 0.132058
# Epoch 1000 | Train Loss 0.225952 | Val Loss 0.148464
# Epoch 1100 | Train Loss 0.205885 | Val Loss 0.136658
# Early stopping at epoch 1197
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9861, MSE = 1.1410e-03
# Y | Train_2 -> R² = 0.9667, MSE = 3.4503e-03
# Y | Val_1 -> R² = 0.9882, MSE = 9.5044e-04
# Y | Val_2 -> R² = 0.9267, MSE = 7.4985e-03
# Y | Test_1 -> R² = 0.0455, MSE = 7.1986e-02
# Y | Test_2 -> R² = 0.9211, MSE = 5.7827e-03
# Y | LSG_1 -> R² = -1.0365, MSE = 6.6058e-01
# Y | LSG_2 -> R² = -0.3706, MSE = 5.4240e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4602 salvo.
# Epoch 0 | Train Loss 9.448385 | Val Loss 3.014231
# Epoch 100 | Train Loss 0.634499 | Val Loss 0.439752
# Epoch 200 | Train Loss 0.359103 | Val Loss 0.242912
# Epoch 300 | Train Loss 0.316136 | Val Loss 0.198305
# Epoch 400 | Train Loss 0.349694 | Val Loss 0.195808
# Epoch 500 | Train Loss 0.232556 | Val Loss 0.166116
# Early stopping at epoch 588
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9507, MSE = 4.0605e-03
# Y | Train_2 -> R² = 0.7900, MSE = 2.1783e-02
# Y | Val_1 -> R² = 0.9539, MSE = 3.6989e-03
# Y | Val_2 -> R² = 0.9255, MSE = 7.6294e-03
# Y | Test_1 -> R² = -7.4568, MSE = 6.3779e-01
# Y | Test_2 -> R² = -3.7495, MSE = 3.4820e-01
# Y | LSG_1 -> R² = -0.7645, MSE = 5.7236e-01
# Y | LSG_2 -> R² = -0.1543, MSE = 4.5678e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8458 salvo.
# Epoch 0 | Train Loss 8.770900 | Val Loss 2.742940
# Epoch 100 | Train Loss 1.940220 | Val Loss 1.345576
# Epoch 200 | Train Loss 0.748546 | Val Loss 0.377574
# Epoch 300 | Train Loss 0.505620 | Val Loss 0.286453
# Epoch 400 | Train Loss 0.303046 | Val Loss 0.228398
# Epoch 500 | Train Loss 0.259713 | Val Loss 0.220679
# Epoch 600 | Train Loss 0.240153 | Val Loss 0.218044
# Epoch 700 | Train Loss 0.256311 | Val Loss 0.171638
# Epoch 800 | Train Loss 0.221410 | Val Loss 0.222929
# Early stopping at epoch 881
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed6756.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9561, MSE = 3.6133e-03
# Y | Train_2 -> R² = 0.9610, MSE = 4.0403e-03
# Y | Val_1 -> R² = 0.9241, MSE = 6.0932e-03
# Y | Val_2 -> R² = 0.9562, MSE = 4.4818e-03
# Y | Test_1 -> R² = -0.1445, MSE = 8.6312e-02
# Y | Test_2 -> R² = 0.6511, MSE = 2.5582e-02
# Y | LSG_1 -> R² = -0.1249, MSE = 3.6489e-01
# Y | LSG_2 -> R² = 0.0109, MSE = 3.9141e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 9.221685 | Val Loss 2.936098
# Epoch 100 | Train Loss 0.601901 | Val Loss 0.366920
# Epoch 200 | Train Loss 0.386955 | Val Loss 0.266420
# Epoch 300 | Train Loss 0.318930 | Val Loss 0.214775
# Epoch 400 | Train Loss 0.284675 | Val Loss 0.200465
# Epoch 500 | Train Loss 0.265814 | Val Loss 0.200893
# Early stopping at epoch 559
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.8252, MSE = 1.4390e-02
# Y | Train_2 -> R² = 0.9929, MSE = 7.3815e-04
# Y | Val_1 -> R² = 0.9445, MSE = 4.4510e-03
# Y | Val_2 -> R² = 0.9468, MSE = 5.4403e-03
# Y | Test_1 -> R² = -0.7377, MSE = 1.3106e-01
# Y | Test_2 -> R² = -0.0125, MSE = 7.4230e-02
# Y | LSG_1 -> R² = -2.0085, MSE = 9.7585e-01
# Y | LSG_2 -> R² = -0.7478, MSE = 6.9165e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 8.763899 | Val Loss 2.794082
# Epoch 100 | Train Loss 1.246768 | Val Loss 0.933241
# Epoch 200 | Train Loss 0.431135 | Val Loss 0.422382
# Epoch 300 | Train Loss 0.325188 | Val Loss 0.279655
# Epoch 400 | Train Loss 0.253206 | Val Loss 0.311141
# Epoch 500 | Train Loss 0.244823 | Val Loss 0.316330
# Early stopping at epoch 505
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9734, MSE = 2.1895e-03
# Y | Train_2 -> R² = 0.9874, MSE = 1.3113e-03
# Y | Val_1 -> R² = 0.8797, MSE = 9.6561e-03
# Y | Val_2 -> R² = 0.9423, MSE = 5.9032e-03
# Y | Test_1 -> R² = -4.4794, MSE = 4.1325e-01
# Y | Test_2 -> R² = -0.7011, MSE = 1.2471e-01
# Y | LSG_1 -> R² = -0.8761, MSE = 6.0855e-01
# Y | LSG_2 -> R² = -0.3446, MSE = 5.3210e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 8.892294 | Val Loss 2.768684
# Epoch 100 | Train Loss 1.689617 | Val Loss 1.088051
# Epoch 200 | Train Loss 0.352886 | Val Loss 0.253350
# Epoch 300 | Train Loss 0.274857 | Val Loss 0.195735
# Epoch 400 | Train Loss 0.339672 | Val Loss 0.193603
# Epoch 500 | Train Loss 0.222512 | Val Loss 0.151078
# Epoch 600 | Train Loss 0.213411 | Val Loss 0.144784
# Epoch 700 | Train Loss 0.209105 | Val Loss 0.140339
# Early stopping at epoch 764
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9883, MSE = 9.6051e-04
# Y | Train_2 -> R² = 0.9551, MSE = 4.6605e-03
# Y | Val_1 -> R² = 0.9481, MSE = 4.1683e-03
# Y | Val_2 -> R² = 0.9781, MSE = 2.2447e-03
# Y | Test_1 -> R² = -4.9986, MSE = 4.5240e-01
# Y | Test_2 -> R² = -0.5824, MSE = 1.1601e-01
# Y | LSG_1 -> R² = -1.1687, MSE = 7.0345e-01
# Y | LSG_2 -> R² = -0.5028, MSE = 5.9470e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 9.760191 | Val Loss 3.061994
# Epoch 100 | Train Loss 1.729839 | Val Loss 1.176659
# Epoch 200 | Train Loss 1.477158 | Val Loss 0.994324
# Epoch 300 | Train Loss 0.326320 | Val Loss 0.242622
# Epoch 400 | Train Loss 0.271707 | Val Loss 0.197271
# Epoch 500 | Train Loss 0.282974 | Val Loss 0.216802
# Epoch 600 | Train Loss 0.301946 | Val Loss 0.196609
# Epoch 700 | Train Loss 0.374731 | Val Loss 0.300429
# Epoch 800 | Train Loss 0.228590 | Val Loss 0.152174
# Early stopping at epoch 891
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9915, MSE = 6.9977e-04
# Y | Train_2 -> R² = 0.7312, MSE = 2.7881e-02
# Y | Val_1 -> R² = 0.9690, MSE = 2.4850e-03
# Y | Val_2 -> R² = 0.8222, MSE = 1.8199e-02
# Y | Test_1 -> R² = -0.0547, MSE = 7.9541e-02
# Y | Test_2 -> R² = -1.5384, MSE = 1.8610e-01
# Y | LSG_1 -> R² = -0.0224, MSE = 3.3163e-01
# Y | LSG_2 -> R² = 0.1638, MSE = 3.3092e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8458 salvo.
# Epoch 0 | Train Loss 8.666490 | Val Loss 2.752293
# Epoch 100 | Train Loss 1.749629 | Val Loss 1.149226
# Epoch 200 | Train Loss 0.742727 | Val Loss 0.562165
# Epoch 300 | Train Loss 0.449617 | Val Loss 0.373018
# Epoch 400 | Train Loss 0.324689 | Val Loss 0.249011
# Epoch 500 | Train Loss 0.288390 | Val Loss 0.225219
# Epoch 600 | Train Loss 0.264130 | Val Loss 0.202000
# Epoch 700 | Train Loss 0.258376 | Val Loss 0.203072
# Epoch 800 | Train Loss 0.214373 | Val Loss 0.187340
# Early stopping at epoch 887
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed6756.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9760, MSE = 1.9782e-03
# Y | Train_2 -> R² = 0.8736, MSE = 1.3113e-02
# Y | Val_1 -> R² = 0.9719, MSE = 2.2557e-03
# Y | Val_2 -> R² = 0.9542, MSE = 4.6910e-03
# Y | Test_1 -> R² = 0.7339, MSE = 2.0070e-02
# Y | Test_2 -> R² = -0.0813, MSE = 7.9271e-02
# Y | LSG_1 -> R² = -0.3027, MSE = 4.2255e-01
# Y | LSG_2 -> R² = 0.2113, MSE = 3.1212e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6756 salvo.
# Epoch 0 | Train Loss 9.039229 | Val Loss 2.839627
# Epoch 100 | Train Loss 1.734577 | Val Loss 1.205625
# Epoch 200 | Train Loss 1.038892 | Val Loss 0.657708
# Epoch 300 | Train Loss 0.271386 | Val Loss 0.186002
# Epoch 400 | Train Loss 0.232417 | Val Loss 0.158495
# Epoch 500 | Train Loss 0.225839 | Val Loss 0.155808
# Epoch 600 | Train Loss 0.208665 | Val Loss 0.169214
# Early stopping at epoch 686
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9903, MSE = 7.9992e-04
# Y | Train_2 -> R² = 0.9934, MSE = 6.8391e-04
# Y | Val_1 -> R² = 0.8980, MSE = 8.1837e-03
# Y | Val_2 -> R² = 0.9832, MSE = 1.7226e-03
# Y | Test_1 -> R² = -0.1721, MSE = 8.8394e-02
# Y | Test_2 -> R² = 0.8135, MSE = 1.3673e-02
# Y | LSG_1 -> R² = 0.2006, MSE = 2.5929e-01
# Y | LSG_2 -> R² = 0.3376, MSE = 2.6212e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=8792 salvo.
# Epoch 0 | Train Loss 8.851281 | Val Loss 2.788787
# Epoch 100 | Train Loss 1.900450 | Val Loss 1.376006
# Epoch 200 | Train Loss 1.470784 | Val Loss 1.009256
# Epoch 300 | Train Loss 0.308271 | Val Loss 0.242250
# Epoch 400 | Train Loss 0.415092 | Val Loss 0.274556
# Epoch 500 | Train Loss 0.248225 | Val Loss 0.181155
# Epoch 600 | Train Loss 0.241689 | Val Loss 0.181811
# Epoch 700 | Train Loss 0.223438 | Val Loss 0.174220
# Early stopping at epoch 769
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9588, MSE = 3.3926e-03
# Y | Train_2 -> R² = 0.9450, MSE = 5.7020e-03
# Y | Val_1 -> R² = 0.9683, MSE = 2.5400e-03
# Y | Val_2 -> R² = 0.9770, MSE = 2.3563e-03
# Y | Test_1 -> R² = 0.4249, MSE = 4.3373e-02
# Y | Test_2 -> R² = 0.7603, MSE = 1.7575e-02
# Y | LSG_1 -> R² = -0.8694, MSE = 6.0638e-01
# Y | LSG_2 -> R² = -0.3176, MSE = 5.2141e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=547 salvo.
# Epoch 0 | Train Loss 16.550205 | Val Loss 2.768293
# Epoch 100 | Train Loss 0.886633 | Val Loss 0.362794
# Epoch 200 | Train Loss 0.569063 | Val Loss 0.253080
# Epoch 300 | Train Loss 0.468757 | Val Loss 0.197191
# Epoch 400 | Train Loss 0.400885 | Val Loss 0.166858
# Epoch 500 | Train Loss 0.360964 | Val Loss 0.151540
# Epoch 600 | Train Loss 0.323540 | Val Loss 0.142419
# Epoch 700 | Train Loss 0.293715 | Val Loss 0.134730
# Epoch 800 | Train Loss 0.279333 | Val Loss 0.152695
# Early stopping at epoch 849
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed4602.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9902, MSE = 8.1096e-04
# Y | Train_2 -> R² = 0.9921, MSE = 8.1928e-04
# Y | Val_1 -> R² = 0.9504, MSE = 3.9795e-03
# Y | Val_2 -> R² = 0.9929, MSE = 7.2382e-04
# Y | Test_1 -> R² = -3.0259, MSE = 3.0363e-01
# Y | Test_2 -> R² = -0.4155, MSE = 1.0377e-01
# Y | LSG_1 -> R² = -2.7304, MSE = 1.2100e+00
# Y | LSG_2 -> R² = -0.9117, MSE = 7.5650e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4602 salvo.
# Epoch 0 | Train Loss 17.560003 | Val Loss 2.987074
# Epoch 100 | Train Loss 2.296648 | Val Loss 1.198466
# Epoch 200 | Train Loss 1.226052 | Val Loss 0.734014
# Epoch 300 | Train Loss 0.515222 | Val Loss 0.268358
# Epoch 400 | Train Loss 0.333937 | Val Loss 0.175093
# Epoch 500 | Train Loss 0.297965 | Val Loss 0.174175
# Early stopping at epoch 554
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8458.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9762, MSE = 1.9556e-03
# Y | Train_2 -> R² = 0.9889, MSE = 1.1473e-03
# Y | Val_1 -> R² = 0.9542, MSE = 3.6725e-03
# Y | Val_2 -> R² = 0.9833, MSE = 1.7056e-03
# Y | Test_1 -> R² = -0.0038, MSE = 7.5707e-02
# Y | Test_2 -> R² = 0.9744, MSE = 1.8744e-03
# Y | LSG_1 -> R² = -0.0227, MSE = 3.3174e-01
# Y | LSG_2 -> R² = 0.2610, MSE = 2.9246e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8458 salvo.
# Epoch 0 | Train Loss 15.853550 | Val Loss 2.649952
# Epoch 100 | Train Loss 2.410859 | Val Loss 1.292281
# Epoch 200 | Train Loss 1.932200 | Val Loss 1.115471
# Epoch 300 | Train Loss 0.671259 | Val Loss 0.318352
# Epoch 400 | Train Loss 0.383910 | Val Loss 0.217574
# Epoch 500 | Train Loss 0.335724 | Val Loss 0.224158
# Early stopping at epoch 503
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed6756.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9774, MSE = 1.8567e-03
# Y | Train_2 -> R² = 0.9746, MSE = 2.6370e-03
# Y | Val_1 -> R² = 0.9069, MSE = 7.4705e-03
# Y | Val_2 -> R² = 0.9407, MSE = 6.0686e-03
# Y | Test_1 -> R² = -3.8014, MSE = 3.6211e-01
# Y | Test_2 -> R² = -0.4133, MSE = 1.0361e-01
# Y | LSG_1 -> R² = -1.2362, MSE = 7.2536e-01
# Y | LSG_2 -> R² = -0.2511, MSE = 4.9509e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 18.047895 | Val Loss 3.036312
# Epoch 100 | Train Loss 2.629041 | Val Loss 1.287408
# Epoch 200 | Train Loss 2.118453 | Val Loss 1.312390
# Epoch 300 | Train Loss 0.975731 | Val Loss 0.587992
# Epoch 400 | Train Loss 0.461121 | Val Loss 0.250067
# Epoch 500 | Train Loss 0.406055 | Val Loss 0.221284
# Epoch 600 | Train Loss 0.386179 | Val Loss 0.206563
# Epoch 700 | Train Loss 0.350112 | Val Loss 0.167467
# Early stopping at epoch 771
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed8792.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed8792.weights.h5
# Y | Train_1 -> R² = 0.8808, MSE = 9.8110e-03
# Y | Train_2 -> R² = 0.8491, MSE = 1.5650e-02
# Y | Val_1 -> R² = 0.9587, MSE = 3.3124e-03
# Y | Val_2 -> R² = 0.9408, MSE = 6.0580e-03
# Y | Test_1 -> R² = -0.3456, MSE = 1.0148e-01
# Y | Test_2 -> R² = 0.5508, MSE = 3.2930e-02
# Y | LSG_1 -> R² = -0.3092, MSE = 4.2467e-01
# Y | LSG_2 -> R² = -0.0204, MSE = 4.0378e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 16.665771 | Val Loss 2.773970
# Epoch 100 | Train Loss 2.220948 | Val Loss 1.293046
# Epoch 200 | Train Loss 1.876390 | Val Loss 1.157083
# Epoch 300 | Train Loss 0.635317 | Val Loss 0.336501
# Epoch 400 | Train Loss 0.372681 | Val Loss 0.187781
# Epoch 500 | Train Loss 0.304525 | Val Loss 0.167346
# Epoch 600 | Train Loss 0.275117 | Val Loss 0.155560
# Epoch 700 | Train Loss 0.259292 | Val Loss 0.175616
# Early stopping at epoch 762
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed547.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed547.weights.h5
# Y | Train_1 -> R² = 0.9611, MSE = 3.2054e-03
# Y | Train_2 -> R² = 0.9824, MSE = 1.8285e-03
# Y | Val_1 -> R² = 0.9459, MSE = 4.3382e-03
# Y | Val_2 -> R² = 0.9488, MSE = 5.2450e-03
# Y | Test_1 -> R² = -0.3008, MSE = 9.8106e-02
# Y | Test_2 -> R² = 0.7101, MSE = 2.1252e-02
# Y | LSG_1 -> R² = -0.5547, MSE = 5.0428e-01
# Y | LSG_2 -> R² = -0.5082, MSE = 5.9683e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 17.315702 | Val Loss 2.906840
# Epoch 100 | Train Loss 0.974121 | Val Loss 0.506889
# Epoch 200 | Train Loss 0.568555 | Val Loss 0.244270
# Epoch 300 | Train Loss 0.438555 | Val Loss 0.215900
# Epoch 400 | Train Loss 0.355442 | Val Loss 0.187671
# Epoch 500 | Train Loss 0.308970 | Val Loss 0.179280
# Epoch 600 | Train Loss 0.284585 | Val Loss 0.178271
# Epoch 700 | Train Loss 0.264997 | Val Loss 0.174906
# Epoch 800 | Train Loss 0.248393 | Val Loss 0.168573
# Epoch 900 | Train Loss 0.237575 | Val Loss 0.163785
# Epoch 1000 | Train Loss 0.230333 | Val Loss 0.162869
# Early stopping at epoch 1045
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed4602.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9957, MSE = 3.5441e-04
# Y | Train_2 -> R² = 0.9722, MSE = 2.8854e-03
# Y | Val_1 -> R² = 0.3459, MSE = 5.2484e-02
# Y | Val_2 -> R² = 0.9820, MSE = 1.8396e-03
# Y | Test_1 -> R² = -1.6703, MSE = 2.0139e-01
# Y | Test_2 -> R² = 0.2965, MSE = 5.1576e-02
# Y | LSG_1 -> R² = -0.9245, MSE = 6.2425e-01
# Y | LSG_2 -> R² = -0.7913, MSE = 7.0887e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 17.986139 | Val Loss 3.090384
# Epoch 100 | Train Loss 2.545796 | Val Loss 1.391924
# Epoch 200 | Train Loss 2.007331 | Val Loss 1.248616
# Epoch 300 | Train Loss 1.129952 | Val Loss 0.405413
# Epoch 400 | Train Loss 0.407012 | Val Loss 0.209161
# Epoch 500 | Train Loss 0.340292 | Val Loss 0.183844
# Epoch 600 | Train Loss 0.344419 | Val Loss 0.185119
# Epoch 700 | Train Loss 0.299879 | Val Loss 0.167438
# Early stopping at epoch 795
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed8458.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9640, MSE = 2.9603e-03
# Y | Train_2 -> R² = 0.9872, MSE = 1.3240e-03
# Y | Val_1 -> R² = 0.9527, MSE = 3.7991e-03
# Y | Val_2 -> R² = 0.9840, MSE = 1.6339e-03
# Y | Test_1 -> R² = 0.6134, MSE = 2.9154e-02
# Y | Test_2 -> R² = 0.9489, MSE = 3.7475e-03
# Y | LSG_1 -> R² = -0.5468, MSE = 5.0172e-01
# Y | LSG_2 -> R² = -0.3200, MSE = 5.2235e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8458 salvo.
# Epoch 0 | Train Loss 16.199844 | Val Loss 2.686773
# Epoch 100 | Train Loss 2.315672 | Val Loss 1.247443
# Epoch 200 | Train Loss 1.023352 | Val Loss 0.601428
# Epoch 300 | Train Loss 0.481792 | Val Loss 0.267311
# Epoch 400 | Train Loss 0.397515 | Val Loss 0.226044
# Epoch 500 | Train Loss 0.338938 | Val Loss 0.203622
# Epoch 600 | Train Loss 0.310294 | Val Loss 0.176261
# Epoch 700 | Train Loss 0.303658 | Val Loss 0.151873
# Epoch 800 | Train Loss 0.277836 | Val Loss 0.153558
# Epoch 900 | Train Loss 0.266501 | Val Loss 0.158588
# Epoch 1000 | Train Loss 0.259170 | Val Loss 0.135189
# Epoch 1100 | Train Loss 0.249767 | Val Loss 0.129107
# Epoch 1200 | Train Loss 0.241429 | Val Loss 0.129789
# Epoch 1300 | Train Loss 0.235814 | Val Loss 0.133847
# Epoch 1400 | Train Loss 0.233695 | Val Loss 0.115303
# Epoch 1500 | Train Loss 0.228865 | Val Loss 0.138993
# Epoch 1600 | Train Loss 0.220782 | Val Loss 0.124478
# Epoch 1700 | Train Loss 0.219844 | Val Loss 0.146392
# Epoch 1800 | Train Loss 0.206929 | Val Loss 0.146558
# Epoch 1900 | Train Loss 0.199135 | Val Loss 0.149170
# Early stopping at epoch 1906
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed6756.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9957, MSE = 3.5339e-04
# Y | Train_2 -> R² = 0.9936, MSE = 6.6686e-04
# Y | Val_1 -> R² = 0.9360, MSE = 5.1370e-03
# Y | Val_2 -> R² = 0.9685, MSE = 3.2283e-03
# Y | Test_1 -> R² = -0.0605, MSE = 7.9981e-02
# Y | Test_2 -> R² = 0.7306, MSE = 1.9751e-02
# Y | LSG_1 -> R² = -0.6657, MSE = 5.4030e-01
# Y | LSG_2 -> R² = -0.3856, MSE = 5.4832e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=6756 salvo.
# Epoch 0 | Train Loss 17.413689 | Val Loss 2.938330
# Epoch 100 | Train Loss 1.107443 | Val Loss 0.509556
# Epoch 200 | Train Loss 0.753308 | Val Loss 0.326216
# Epoch 300 | Train Loss 0.548958 | Val Loss 0.239586
# Epoch 400 | Train Loss 0.428548 | Val Loss 0.213712
# Epoch 500 | Train Loss 0.372898 | Val Loss 0.189355
# Epoch 600 | Train Loss 0.339217 | Val Loss 0.172584
# Epoch 700 | Train Loss 0.316647 | Val Loss 0.162346
# Epoch 800 | Train Loss 0.299223 | Val Loss 0.144467
# Epoch 900 | Train Loss 0.279875 | Val Loss 0.147459
# Epoch 1000 | Train Loss 0.265516 | Val Loss 0.131239
# Epoch 1100 | Train Loss 0.253283 | Val Loss 0.135902
# Epoch 1200 | Train Loss 0.241234 | Val Loss 0.151580
# Early stopping at epoch 1208
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed8792.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9854, MSE = 1.2062e-03
# Y | Train_2 -> R² = 0.9688, MSE = 3.2319e-03
# Y | Val_1 -> R² = 0.8737, MSE = 1.0133e-02
# Y | Val_2 -> R² = 0.9893, MSE = 1.0969e-03
# Y | Test_1 -> R² = -0.6937, MSE = 1.2773e-01
# Y | Test_2 -> R² = 0.9318, MSE = 4.9970e-03
# Y | LSG_1 -> R² = 0.1543, MSE = 2.7430e-01
# Y | LSG_2 -> R² = 0.2781, MSE = 2.8566e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=8792 salvo.
# Epoch 0 | Train Loss 16.471760 | Val Loss 2.796046
# Epoch 100 | Train Loss 2.394987 | Val Loss 1.294103
# Epoch 200 | Train Loss 1.683387 | Val Loss 0.957839
# Epoch 300 | Train Loss 0.430286 | Val Loss 0.167596
# Epoch 400 | Train Loss 0.368076 | Val Loss 0.136895
# Epoch 500 | Train Loss 0.331151 | Val Loss 0.141332
# Epoch 600 | Train Loss 0.311403 | Val Loss 0.140787
# Epoch 700 | Train Loss 0.296025 | Val Loss 0.142312
# Early stopping at epoch 711
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed547.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed547.weights.h5
# Y | Train_1 -> R² = 0.9773, MSE = 1.8705e-03
# Y | Train_2 -> R² = 0.9668, MSE = 3.4450e-03
# Y | Val_1 -> R² = 0.9427, MSE = 4.5979e-03
# Y | Val_2 -> R² = 0.9859, MSE = 1.4390e-03
# Y | Test_1 -> R² = -0.1591, MSE = 8.7418e-02
# Y | Test_2 -> R² = 0.9516, MSE = 3.5492e-03
# Y | LSG_1 -> R² = 0.0174, MSE = 3.1872e-01
# Y | LSG_2 -> R² = 0.1121, MSE = 3.5135e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=547 salvo.
# Epoch 0 | Train Loss 9.272198 | Val Loss 2.762171
# Epoch 100 | Train Loss 0.547755 | Val Loss 0.362909
# Epoch 200 | Train Loss 0.279859 | Val Loss 0.211554
# Epoch 300 | Train Loss 0.247404 | Val Loss 0.227442
# Early stopping at epoch 395
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9815, MSE = 1.5242e-03
# Y | Train_2 -> R² = 0.9956, MSE = 4.5698e-04
# Y | Val_1 -> R² = 0.7745, MSE = 1.8095e-02
# Y | Val_2 -> R² = 0.9871, MSE = 1.3230e-03
# Y | Test_1 -> R² = -0.3078, MSE = 9.8631e-02
# Y | Test_2 -> R² = 0.5443, MSE = 3.3407e-02
# Y | LSG_1 -> R² = -0.3510, MSE = 4.3820e-01
# Y | LSG_2 -> R² = -0.2468, MSE = 4.9339e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4602 salvo.
# Epoch 0 | Train Loss 9.139129 | Val Loss 2.820786
# Epoch 100 | Train Loss 0.377925 | Val Loss 0.276878
# Epoch 200 | Train Loss 0.319456 | Val Loss 0.230767
# Epoch 300 | Train Loss 0.268020 | Val Loss 0.214158
# Epoch 400 | Train Loss 0.304872 | Val Loss 0.212135
# Epoch 500 | Train Loss 0.238428 | Val Loss 0.205982
# Epoch 600 | Train Loss 0.239242 | Val Loss 0.222719
# Epoch 700 | Train Loss 0.216985 | Val Loss 0.193096
# Epoch 800 | Train Loss 0.213210 | Val Loss 0.184832
# Epoch 900 | Train Loss 0.206198 | Val Loss 0.167621
# Epoch 1000 | Train Loss 0.200673 | Val Loss 0.155214
# Epoch 1100 | Train Loss 0.195417 | Val Loss 0.149685
# Early stopping at epoch 1189
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9907, MSE = 7.6651e-04
# Y | Train_2 -> R² = 0.9949, MSE = 5.3007e-04
# Y | Val_1 -> R² = 0.8773, MSE = 9.8431e-03
# Y | Val_2 -> R² = 0.9856, MSE = 1.4695e-03
# Y | Test_1 -> R² = -3.4151, MSE = 3.3298e-01
# Y | Test_2 -> R² = -0.5504, MSE = 1.1366e-01
# Y | LSG_1 -> R² = -6.0899, MSE = 2.2997e+00
# Y | LSG_2 -> R² = -3.6142, MSE = 1.8260e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8458 salvo.
# Epoch 0 | Train Loss 9.828168 | Val Loss 2.983695
# Epoch 100 | Train Loss 0.432665 | Val Loss 0.276831
# Epoch 200 | Train Loss 0.307507 | Val Loss 0.214155
# Epoch 300 | Train Loss 0.251052 | Val Loss 0.197550
# Epoch 400 | Train Loss 0.231323 | Val Loss 0.197140
# Epoch 500 | Train Loss 0.218026 | Val Loss 0.194518
# Epoch 600 | Train Loss 0.208316 | Val Loss 0.200944
# Epoch 700 | Train Loss 0.317432 | Val Loss 0.324138
# Epoch 800 | Train Loss 0.198689 | Val Loss 0.199903
# Epoch 900 | Train Loss 0.207990 | Val Loss 0.260772
# Early stopping at epoch 948
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed6756.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9866, MSE = 1.1070e-03
# Y | Train_2 -> R² = 0.8911, MSE = 1.1291e-02
# Y | Val_1 -> R² = 0.9622, MSE = 3.0369e-03
# Y | Val_2 -> R² = 0.9589, MSE = 4.2051e-03
# Y | Test_1 -> R² = -2.0481, MSE = 2.2988e-01
# Y | Test_2 -> R² = 0.6387, MSE = 2.6484e-02
# Y | LSG_1 -> R² = -3.2890, MSE = 1.3912e+00
# Y | LSG_2 -> R² = -1.5807, MSE = 1.0212e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 9.826111 | Val Loss 3.006351
# Epoch 100 | Train Loss 0.439735 | Val Loss 0.287643
# Epoch 200 | Train Loss 0.298196 | Val Loss 0.227248
# Epoch 300 | Train Loss 0.262675 | Val Loss 0.201801
# Epoch 400 | Train Loss 0.230582 | Val Loss 0.180750
# Epoch 500 | Train Loss 0.215716 | Val Loss 0.175041
# Epoch 600 | Train Loss 0.206342 | Val Loss 0.172791
# Epoch 700 | Train Loss 0.198523 | Val Loss 0.172567
# Epoch 800 | Train Loss 0.187186 | Val Loss 0.173039
# Epoch 900 | Train Loss 0.181561 | Val Loss 0.175702
# Early stopping at epoch 977
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9876, MSE = 1.0233e-03
# Y | Train_2 -> R² = 0.9945, MSE = 5.6666e-04
# Y | Val_1 -> R² = 0.9462, MSE = 4.3162e-03
# Y | Val_2 -> R² = 0.9795, MSE = 2.0993e-03
# Y | Test_1 -> R² = -4.7954, MSE = 4.3708e-01
# Y | Test_2 -> R² = -0.3489, MSE = 9.8891e-02
# Y | LSG_1 -> R² = -7.9303, MSE = 2.8967e+00
# Y | LSG_2 -> R² = -5.3467, MSE = 2.5115e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 9.902914 | Val Loss 2.968843
# Epoch 100 | Train Loss 0.481821 | Val Loss 0.289983
# Epoch 200 | Train Loss 0.334385 | Val Loss 0.241980
# Epoch 300 | Train Loss 0.250337 | Val Loss 0.172375
# Epoch 400 | Train Loss 0.233684 | Val Loss 0.162635
# Epoch 500 | Train Loss 0.223875 | Val Loss 0.157119
# Epoch 600 | Train Loss 0.218420 | Val Loss 0.165985
# Early stopping at epoch 627
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9853, MSE = 1.2097e-03
# Y | Train_2 -> R² = 0.9749, MSE = 2.6016e-03
# Y | Val_1 -> R² = 0.9684, MSE = 2.5369e-03
# Y | Val_2 -> R² = 0.9846, MSE = 1.5800e-03
# Y | Test_1 -> R² = -5.0871, MSE = 4.5907e-01
# Y | Test_2 -> R² = -0.4145, MSE = 1.0370e-01
# Y | LSG_1 -> R² = -2.8459, MSE = 1.2475e+00
# Y | LSG_2 -> R² = -1.4047, MSE = 9.5158e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 9.171093 | Val Loss 2.742732
# Epoch 100 | Train Loss 0.955939 | Val Loss 0.636493
# Epoch 200 | Train Loss 0.264242 | Val Loss 0.201579
# Epoch 300 | Train Loss 0.235803 | Val Loss 0.219717
# Epoch 400 | Train Loss 0.210336 | Val Loss 0.218163
# Early stopping at epoch 485
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9821, MSE = 1.4712e-03
# Y | Train_2 -> R² = 0.9603, MSE = 4.1157e-03
# Y | Val_1 -> R² = 0.6997, MSE = 2.4098e-02
# Y | Val_2 -> R² = 0.9707, MSE = 3.0019e-03
# Y | Test_1 -> R² = 0.0658, MSE = 7.0459e-02
# Y | Test_2 -> R² = 0.0283, MSE = 7.1241e-02
# Y | LSG_1 -> R² = 0.1420, MSE = 2.7832e-01
# Y | LSG_2 -> R² = 0.0952, MSE = 3.5806e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 9.639091 | Val Loss 2.920677
# Epoch 100 | Train Loss 0.503532 | Val Loss 0.344435
# Epoch 200 | Train Loss 0.308810 | Val Loss 0.175979
# Epoch 300 | Train Loss 0.235841 | Val Loss 0.153529
# Epoch 400 | Train Loss 0.218703 | Val Loss 0.160111
# Epoch 500 | Train Loss 0.261427 | Val Loss 0.238058
# Epoch 600 | Train Loss 0.206786 | Val Loss 0.154195
# Early stopping at epoch 693
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9702, MSE = 2.4529e-03
# Y | Train_2 -> R² = 0.6165, MSE = 3.9774e-02
# Y | Val_1 -> R² = 0.9567, MSE = 3.4719e-03
# Y | Val_2 -> R² = 0.7998, MSE = 2.0493e-02
# Y | Test_1 -> R² = -4.7065, MSE = 4.3037e-01
# Y | Test_2 -> R² = 0.1309, MSE = 6.3717e-02
# Y | LSG_1 -> R² = -9.7515, MSE = 3.4874e+00
# Y | LSG_2 -> R² = -5.0268, MSE = 2.3850e+00
# ...
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 8.728918 | Val Loss 2.002185
# Epoch 100 | Train Loss 0.250043 | Val Loss 0.304823
# Epoch 200 | Train Loss 0.354627 | Val Loss 0.194078
# Epoch 300 | Train Loss 0.243558 | Val Loss 0.159298
# Epoch 400 | Train Loss 0.254607 | Val Loss 0.151535
# Epoch 500 | Train Loss 0.241569 | Val Loss 0.126720
# Epoch 600 | Train Loss 0.228052 | Val Loss 0.219061
# Early stopping at epoch 698
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9942, MSE = 4.7649e-04
# Y | Train_2 -> R² = 0.9404, MSE = 6.1802e-03
# Y | Val_1 -> R² = 0.8863, MSE = 9.1250e-03
# Y | Val_2 -> R² = 0.9703, MSE = 3.0386e-03
# Y | Test_1 -> R² = -1.1488, MSE = 1.6206e-01
# Y | Test_2 -> R² = 0.5466, MSE = 3.3242e-02
# Y | LSG_1 -> R² = -3.6181, MSE = 1.4980e+00
# Y | LSG_2 -> R² = -2.0350, MSE = 1.2010e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 8.715401 | Val Loss 2.384662
# Epoch 100 | Train Loss 0.267249 | Val Loss 0.180055
# Epoch 200 | Train Loss 0.327580 | Val Loss 0.231179
# Epoch 300 | Train Loss 0.236659 | Val Loss 0.163917
# Epoch 400 | Train Loss 0.258736 | Val Loss 0.159640
# Epoch 500 | Train Loss 4.150285 | Val Loss 1.989396
# Early stopping at epoch 589
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9797, MSE = 1.6751e-03
# Y | Train_2 -> R² = 0.7653, MSE = 2.4340e-02
# Y | Val_1 -> R² = 0.9840, MSE = 1.2811e-03
# Y | Val_2 -> R² = 0.9424, MSE = 5.8935e-03
# Y | Test_1 -> R² = -1.0413, MSE = 1.5395e-01
# Y | Test_2 -> R² = 0.2656, MSE = 5.3838e-02
# Y | LSG_1 -> R² = -9.5578, MSE = 3.4246e+00
# Y | LSG_2 -> R² = -5.3054, MSE = 2.4952e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 7.962543 | Val Loss 2.045791
# Epoch 100 | Train Loss 0.253029 | Val Loss 0.187776
# Epoch 200 | Train Loss 0.233192 | Val Loss 0.165892
# Epoch 300 | Train Loss 0.339267 | Val Loss 0.213732
# Epoch 400 | Train Loss 0.586778 | Val Loss 0.291561
# Epoch 500 | Train Loss 0.536852 | Val Loss 0.362573
# Early stopping at epoch 577
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4602.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9905, MSE = 7.7945e-04
# Y | Train_2 -> R² = 0.9936, MSE = 6.6619e-04
# Y | Val_1 -> R² = 0.9704, MSE = 2.3761e-03
# Y | Val_2 -> R² = 0.9835, MSE = 1.6867e-03
# Y | Test_1 -> R² = -1.3909, MSE = 1.8032e-01
# Y | Test_2 -> R² = 0.1547, MSE = 6.1969e-02
# Y | LSG_1 -> R² = -8.6952, MSE = 3.1448e+00
# Y | LSG_2 -> R² = -5.0876, MSE = 2.4090e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 7.980946 | Val Loss 1.954097
# Epoch 100 | Train Loss 0.303724 | Val Loss 0.222842
# Epoch 200 | Train Loss 0.480908 | Val Loss 0.290690
# Epoch 300 | Train Loss 0.238900 | Val Loss 0.180551
# Epoch 400 | Train Loss 0.227907 | Val Loss 0.169207
# Epoch 500 | Train Loss 0.657337 | Val Loss 0.250978
# Early stopping at epoch 524
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8458.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9841, MSE = 1.3107e-03
# Y | Train_2 -> R² = 0.9740, MSE = 2.7005e-03
# Y | Val_1 -> R² = 0.9778, MSE = 1.7775e-03
# Y | Val_2 -> R² = 0.9803, MSE = 2.0115e-03
# Y | Test_1 -> R² = -3.6770, MSE = 3.5273e-01
# Y | Test_2 -> R² = -0.0864, MSE = 7.9649e-02
# Y | LSG_1 -> R² = -8.8565, MSE = 3.1971e+00
# Y | LSG_2 -> R² = -5.4561, MSE = 2.5548e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8458 salvo.
# Epoch 0 | Train Loss 8.663950 | Val Loss 2.115750
# Epoch 100 | Train Loss 0.258038 | Val Loss 0.197982
# Epoch 200 | Train Loss 0.243952 | Val Loss 0.223345
# Epoch 300 | Train Loss 0.207037 | Val Loss 0.228610
# Early stopping at epoch 324
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed6756.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9776, MSE = 1.8438e-03
# Y | Train_2 -> R² = 0.5256, MSE = 4.9202e-02
# Y | Val_1 -> R² = 0.8189, MSE = 1.4534e-02
# Y | Val_2 -> R² = 0.8023, MSE = 2.0238e-02
# Y | Test_1 -> R² = 0.5920, MSE = 3.0772e-02
# Y | Test_2 -> R² = 0.9122, MSE = 6.4336e-03
# Y | LSG_1 -> R² = -3.4002, MSE = 1.4273e+00
# Y | LSG_2 -> R² = -2.0186, MSE = 1.1946e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=6756 salvo.
# Epoch 0 | Train Loss 7.677793 | Val Loss 2.002018
# Epoch 100 | Train Loss 0.282186 | Val Loss 0.194764
# Epoch 200 | Train Loss 0.254416 | Val Loss 0.188303
# Epoch 300 | Train Loss 0.223616 | Val Loss 0.223727
# Epoch 400 | Train Loss 0.322568 | Val Loss 0.255652
# Epoch 500 | Train Loss 0.231567 | Val Loss 0.184184
# Epoch 600 | Train Loss 0.215707 | Val Loss 0.209624
# Early stopping at epoch 630
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8792.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9868, MSE = 1.0878e-03
# Y | Train_2 -> R² = 0.9613, MSE = 4.0189e-03
# Y | Val_1 -> R² = 0.9736, MSE = 2.1186e-03
# Y | Val_2 -> R² = 0.9921, MSE = 8.0687e-04
# Y | Test_1 -> R² = -2.4536, MSE = 2.6047e-01
# Y | Test_2 -> R² = 0.1960, MSE = 5.8941e-02
# Y | LSG_1 -> R² = -7.9044, MSE = 2.8883e+00
# Y | LSG_2 -> R² = -4.6101, MSE = 2.2201e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=8792 salvo.
# Epoch 0 | Train Loss 9.043913 | Val Loss 1.955441
# Epoch 100 | Train Loss 0.327430 | Val Loss 0.240199
# Epoch 200 | Train Loss 0.301817 | Val Loss 0.195420
# Epoch 300 | Train Loss 0.210247 | Val Loss 0.191281
# Epoch 400 | Train Loss 0.215223 | Val Loss 0.214919
# Early stopping at epoch 460
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed547.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed547.weights.h5
# Y | Train_1 -> R² = 0.9781, MSE = 1.8022e-03
# Y | Train_2 -> R² = 0.6899, MSE = 3.2165e-02
# Y | Val_1 -> R² = 0.9448, MSE = 4.4279e-03
# Y | Val_2 -> R² = 0.9399, MSE = 6.1495e-03
# Y | Test_1 -> R² = -4.3344, MSE = 4.0231e-01
# Y | Test_2 -> R² = -0.4128, MSE = 1.0357e-01
# Y | LSG_1 -> R² = -8.1855, MSE = 2.9795e+00
# Y | LSG_2 -> R² = -4.6980, MSE = 2.2548e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=547 salvo.
# Epoch 0 | Train Loss 17.639553 | Val Loss 2.347254
# Epoch 100 | Train Loss 0.473052 | Val Loss 0.186741
# Epoch 200 | Train Loss 0.348213 | Val Loss 0.156764
# Epoch 300 | Train Loss 0.342032 | Val Loss 0.128578
# Epoch 400 | Train Loss 0.295003 | Val Loss 0.094993
# Epoch 500 | Train Loss 0.336532 | Val Loss 0.147484
# Epoch 600 | Train Loss 0.262039 | Val Loss 0.079243
# Epoch 700 | Train Loss 0.275559 | Val Loss 0.093632
# Epoch 800 | Train Loss 0.205895 | Val Loss 0.077732
# Epoch 900 | Train Loss 0.272456 | Val Loss 0.130817
# Epoch 1000 | Train Loss 0.254569 | Val Loss 0.138458
# Early stopping at epoch 1022
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4602.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9937, MSE = 5.1562e-04
# Y | Train_2 -> R² = 0.9910, MSE = 9.3704e-04
# Y | Val_1 -> R² = 0.9936, MSE = 5.0994e-04
# Y | Val_2 -> R² = 0.9678, MSE = 3.2981e-03
# Y | Test_1 -> R² = -2.9860, MSE = 3.0062e-01
# Y | Test_2 -> R² = 0.0115, MSE = 7.2470e-02
# Y | LSG_1 -> R² = -13.0442, MSE = 4.5555e+00
# Y | LSG_2 -> R² = -7.7101, MSE = 3.4468e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4602 salvo.
# Epoch 0 | Train Loss 14.937029 | Val Loss 2.080388
# Epoch 100 | Train Loss 0.447015 | Val Loss 0.204248
# Epoch 200 | Train Loss 0.327372 | Val Loss 0.162913
# Epoch 300 | Train Loss 0.297112 | Val Loss 0.129867
# Epoch 400 | Train Loss 0.345983 | Val Loss 0.328731
# Epoch 500 | Train Loss 0.279933 | Val Loss 0.130265
# Early stopping at epoch 599
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8458.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9887, MSE = 9.3415e-04
# Y | Train_2 -> R² = 0.8285, MSE = 1.7791e-02
# Y | Val_1 -> R² = 0.8666, MSE = 1.0703e-02
# Y | Val_2 -> R² = 0.9529, MSE = 4.8214e-03
# Y | Test_1 -> R² = 0.2165, MSE = 5.9093e-02
# Y | Test_2 -> R² = 0.9346, MSE = 4.7957e-03
# Y | LSG_1 -> R² = -6.0243, MSE = 2.2784e+00
# Y | LSG_2 -> R² = -3.7681, MSE = 1.8868e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8458 salvo.
# Epoch 0 | Train Loss 17.804306 | Val Loss 2.170733
# Epoch 100 | Train Loss 0.416072 | Val Loss 0.189811
# Epoch 200 | Train Loss 0.320408 | Val Loss 0.125712
# Epoch 300 | Train Loss 0.608856 | Val Loss 0.213066
# Epoch 400 | Train Loss 0.442028 | Val Loss 0.185130
# Early stopping at epoch 409
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed6756.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9781, MSE = 1.8066e-03
# Y | Train_2 -> R² = 0.8921, MSE = 1.1195e-02
# Y | Val_1 -> R² = 0.9705, MSE = 2.3648e-03
# Y | Val_2 -> R² = 0.9660, MSE = 3.4775e-03
# Y | Test_1 -> R² = -0.2919, MSE = 9.7431e-02
# Y | Test_2 -> R² = 0.1711, MSE = 6.0767e-02
# Y | LSG_1 -> R² = -9.7481, MSE = 3.4863e+00
# Y | LSG_2 -> R² = -6.3730, MSE = 2.9177e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=6756 salvo.
# Epoch 0 | Train Loss 13.471277 | Val Loss 1.832259
# Epoch 100 | Train Loss 0.493402 | Val Loss 0.231411
# Epoch 200 | Train Loss 0.627361 | Val Loss 0.255887
# Epoch 300 | Train Loss 0.410080 | Val Loss 0.269181
# Epoch 400 | Train Loss 1.006902 | Val Loss 0.342496
# Epoch 500 | Train Loss 0.494613 | Val Loss 0.287202
# Early stopping at epoch 562
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8792.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9876, MSE = 1.0200e-03
# Y | Train_2 -> R² = 0.9096, MSE = 9.3734e-03
# Y | Val_1 -> R² = 0.9533, MSE = 3.7444e-03
# Y | Val_2 -> R² = 0.9929, MSE = 7.2293e-04
# Y | Test_1 -> R² = -1.2274, MSE = 1.6798e-01
# Y | Test_2 -> R² = 0.6770, MSE = 2.3682e-02
# Y | LSG_1 -> R² = -9.5945, MSE = 3.4365e+00
# Y | LSG_2 -> R² = -6.8078, MSE = 3.0898e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8792 salvo.
# Epoch 0 | Train Loss 15.316878 | Val Loss 1.919536
# Epoch 100 | Train Loss 0.404397 | Val Loss 0.200444
# Epoch 200 | Train Loss 0.337664 | Val Loss 0.148404
# Epoch 300 | Train Loss 0.325340 | Val Loss 0.139996
# Epoch 400 | Train Loss 0.948781 | Val Loss 0.348073
# Early stopping at epoch 447
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed547.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed547.weights.h5
# Y | Train_1 -> R² = 0.9760, MSE = 1.9773e-03
# Y | Train_2 -> R² = 0.9767, MSE = 2.4160e-03
# Y | Val_1 -> R² = 0.9598, MSE = 3.2221e-03
# Y | Val_2 -> R² = 0.9884, MSE = 1.1883e-03
# Y | Test_1 -> R² = -0.4448, MSE = 1.0896e-01
# Y | Test_2 -> R² = 0.8822, MSE = 8.6387e-03
# Y | LSG_1 -> R² = -7.9544, MSE = 2.9045e+00
# Y | LSG_2 -> R² = -5.0217, MSE = 2.3829e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=547 salvo.
# Epoch 0 | Train Loss 15.983858 | Val Loss 2.063761
# Epoch 100 | Train Loss 0.710756 | Val Loss 0.389211
# Epoch 200 | Train Loss 0.398257 | Val Loss 0.193248
# Epoch 300 | Train Loss 0.328299 | Val Loss 0.141387
# Epoch 400 | Train Loss 0.282185 | Val Loss 0.144570
# Epoch 500 | Train Loss 0.270503 | Val Loss 0.139050
# Epoch 600 | Train Loss 0.387152 | Val Loss 0.155357
# Epoch 700 | Train Loss 0.300898 | Val Loss 0.124973
# Epoch 800 | Train Loss 0.232059 | Val Loss 0.092641
# Epoch 900 | Train Loss 0.260257 | Val Loss 0.104453
# Early stopping at epoch 975
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4602.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4602.weights.h5
# Y | Train_1 -> R² = 0.9900, MSE = 8.2701e-04
# Y | Train_2 -> R² = 0.9773, MSE = 2.3521e-03
# Y | Val_1 -> R² = 0.9554, MSE = 3.5800e-03
# Y | Val_2 -> R² = 0.9827, MSE = 1.7722e-03
# Y | Test_1 -> R² = -5.4018, MSE = 4.8281e-01
# Y | Test_2 -> R² = -1.1332, MSE = 1.5639e-01
# Y | LSG_1 -> R² = -12.5870, MSE = 4.4072e+00
# Y | LSG_2 -> R² = -7.7833, MSE = 3.4758e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4602 salvo.
# Epoch 0 | Train Loss 16.195858 | Val Loss 2.141147
# Epoch 100 | Train Loss 0.443233 | Val Loss 0.171060
# Epoch 200 | Train Loss 0.509032 | Val Loss 0.155318
# Epoch 300 | Train Loss 0.338157 | Val Loss 0.121888
# Epoch 400 | Train Loss 0.330797 | Val Loss 0.141300
# Epoch 500 | Train Loss 0.377902 | Val Loss 0.147622
# Epoch 600 | Train Loss 0.315314 | Val Loss 0.112297
# Epoch 700 | Train Loss 0.276660 | Val Loss 0.116766
# Early stopping at epoch 771
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8458.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8458.weights.h5
# Y | Train_1 -> R² = 0.9948, MSE = 4.2645e-04
# Y | Train_2 -> R² = 0.9916, MSE = 8.6696e-04
# Y | Val_1 -> R² = 0.9846, MSE = 1.2354e-03
# Y | Val_2 -> R² = 0.9677, MSE = 3.3055e-03
# Y | Test_1 -> R² = -1.1395, MSE = 1.6136e-01
# Y | Test_2 -> R² = 0.7308, MSE = 1.9737e-02
# Y | LSG_1 -> R² = -10.9068, MSE = 3.8622e+00
# Y | LSG_2 -> R² = -6.7632, MSE = 3.0721e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8458 salvo.
# Epoch 0 | Train Loss 14.358224 | Val Loss 1.917026
# Epoch 100 | Train Loss 0.358793 | Val Loss 0.170931
# Epoch 200 | Train Loss 0.343094 | Val Loss 0.151911
# Epoch 300 | Train Loss 0.322083 | Val Loss 0.133260
# Epoch 400 | Train Loss 0.444273 | Val Loss 0.194356
# Epoch 500 | Train Loss 0.346689 | Val Loss 0.228381
# Early stopping at epoch 541
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed6756.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed6756.weights.h5
# Y | Train_1 -> R² = 0.9514, MSE = 3.9980e-03
# Y | Train_2 -> R² = 0.8037, MSE = 2.0356e-02
# Y | Val_1 -> R² = 0.9886, MSE = 9.1565e-04
# Y | Val_2 -> R² = 0.8968, MSE = 1.0562e-02
# Y | Test_1 -> R² = -2.5946, MSE = 2.7110e-01
# Y | Test_2 -> R² = -0.4992, MSE = 1.0991e-01
# Y | LSG_1 -> R² = -12.0680, MSE = 4.2388e+00
# Y | LSG_2 -> R² = -6.9136, MSE = 3.1316e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=6756 salvo.
# Epoch 0 | Train Loss 15.500663 | Val Loss 1.816320
# Epoch 100 | Train Loss 0.374056 | Val Loss 0.191722
# Epoch 200 | Train Loss 0.396407 | Val Loss 0.182984
# Epoch 300 | Train Loss 0.294977 | Val Loss 0.167866
# Epoch 400 | Train Loss 0.351599 | Val Loss 0.150599
# Epoch 500 | Train Loss 0.247674 | Val Loss 0.127159
# Epoch 600 | Train Loss 0.301149 | Val Loss 0.162805
# Epoch 700 | Train Loss 0.278213 | Val Loss 0.105741
# Epoch 800 | Train Loss 0.196818 | Val Loss 0.131329
# Epoch 900 | Train Loss 0.175096 | Val Loss 0.097680
# Early stopping at epoch 971
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8792.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed8792.weights.h5
# Y | Train_1 -> R² = 0.9890, MSE = 9.0174e-04
# Y | Train_2 -> R² = 0.9938, MSE = 6.4187e-04
# Y | Val_1 -> R² = 0.9874, MSE = 1.0117e-03
# Y | Val_2 -> R² = 0.9887, MSE = 1.1605e-03
# Y | Test_1 -> R² = -3.3472, MSE = 3.2785e-01
# Y | Test_2 -> R² = 0.0592, MSE = 6.8971e-02
# Y | LSG_1 -> R² = -2.2190, MSE = 1.0441e+00
# Y | LSG_2 -> R² = -0.7433, MSE = 6.8985e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8792 salvo.
# Epoch 0 | Train Loss 16.537447 | Val Loss 2.372786
# Epoch 100 | Train Loss 0.376722 | Val Loss 0.144034
# Epoch 200 | Train Loss 0.368676 | Val Loss 0.179185
# Epoch 300 | Train Loss 0.272723 | Val Loss 0.207437
# Epoch 400 | Train Loss 0.281191 | Val Loss 0.114631
# Epoch 500 | Train Loss 0.383373 | Val Loss 0.151862
# Epoch 600 | Train Loss 0.208327 | Val Loss 0.124268
# Early stopping at epoch 610
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed547.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed547.weights.h5
# Y | Train_1 -> R² = 0.9914, MSE = 7.0913e-04
# Y | Train_2 -> R² = 0.9771, MSE = 2.3727e-03
# Y | Val_1 -> R² = 0.9722, MSE = 2.2324e-03
# Y | Val_2 -> R² = 0.9930, MSE = 7.1507e-04
# Y | Test_1 -> R² = -0.5607, MSE = 1.1770e-01
# Y | Test_2 -> R² = 0.4077, MSE = 4.3422e-02
# Y | LSG_1 -> R² = -10.9471, MSE = 3.8752e+00
# Y | LSG_2 -> R² = -6.7748, MSE = 3.0767e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=547 salvo.
