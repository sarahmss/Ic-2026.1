# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm", "cos(Theta_pred)"
# - Saida: X
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Val_1", "Val_2", "Test_1", "Test_2", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "cosTheta"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
PLOT = False
TIME_STEPS = 15
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
NormDatasets = []

for title in TITLES:
    df = pd.read_excel("./../Theta/Data/Datasets.xlsx", sheet_name=title)
    # df_theta = pd.read_excel("./../Theta/resultados_comparacao.xlsx", sheet_name=title)

    # df["Theta_pred"] = df_theta["Theta_pred_model_arch16-8_r0.9_Ld0.3_Lp0.7_seed6545"]

    df["cosTheta"] = np.cos(df["Theta"])

    for var in TARGET_INT:
        df[f"Delta{var}"] = (df[var].shift(-1) - df[var]) / TS

    df = df.dropna().reset_index(drop=True)

    Datasets.append(df)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

Val = pd.concat([NormDatasets[2], NormDatasets[3]], ignore_index=True)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences(Val[PREDICTORS], Val[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1905, 15, 5)
# Dimensão da saida: (1905, 1)
# Dimensão da entrada: (1917, 15, 5)
# Dimensão da saida: (1917, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1905, 15, 5)
# Dimensão da saida: (1905, 1)
# Dimensão da entrada fisica : (1905,)
# Dimensão da entrada fisica: (1905,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    return [dx_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta, Ld, Lp):

    alpha = 3.0
    weights = 1 + alpha * tf.abs(dy)

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(weights * tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_targets = len(TARGET)
    if PLOT == True:
        n_datasets = len(Datasets)
        fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val_1": [], "R2_Val_2": [],
            "R2_Test_1": [], "R2_Test_2": [], 
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val_1": [], "MSE_Val_2": [],
            "MSE_Test_1": [], "MSE_Test_2": [], 
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            if PLOT == True:
                # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
                ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
                    axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
                )
                PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)
    if PLOT == True:
        plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_1_{name}": to_scalar(metrics[name]["R2_Val_1"]),
            f"MSE_Val_1_{name}": to_scalar(metrics[name]["MSE_Val_1"]),
            f"R2_Val_2_{name}": to_scalar(metrics[name]["R2_Val_2"]),
            f"MSE_Val_2_{name}": to_scalar(metrics[name]["MSE_Val_2"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_LSG_1_{name}": to_scalar(metrics[name]["R2_LSG_1"]),
            f"MSE_LSG_1_{name}": to_scalar(metrics[name]["MSE_LSG_1"]),
            f"R2_LSG_2_{name}": to_scalar(metrics[name]["R2_LSG_2"]),
            f"MSE_LSG_2_{name}": to_scalar(metrics[name]["MSE_LSG_2"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 1.039783 | Val Loss 0.483721
# Epoch 100 | Train Loss 0.153826 | Val Loss 0.154194
# Epoch 200 | Train Loss 0.077105 | Val Loss 0.076342
# Epoch 300 | Train Loss 0.067758 | Val Loss 0.054852
# Epoch 400 | Train Loss 0.056761 | Val Loss 0.048550
# Epoch 500 | Train Loss 0.050155 | Val Loss 0.050393
# Early stopping at epoch 593
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9828, MSE = 1.7745e-03
# X | Train_2 -> R² = 0.9907, MSE = 7.7456e-04
# X | Val_1 -> R² = 0.7967, MSE = 2.0403e-02
# X | Val_2 -> R² = 0.4539, MSE = 4.4312e-02
# X | Test_1 -> R² = -5.2993, MSE = 5.6091e-01
# X | Test_2 -> R² = -1.1332, MSE = 1.9661e-01
# X | LSG_1 -> R² = -4.3484, MSE = 5.2784e-01
# X | LSG_2 -> R² = -2.4438, MSE = 2.9343e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 1.198758 | Val Loss 0.566067
# Epoch 100 | Train Loss 0.140132 | Val Loss 0.131013
# Epoch 200 | Train Loss 0.081557 | Val Loss 0.061059
# Epoch 300 | Train Loss 0.065060 | Val Loss 0.045210
# Epoch 400 | Train Loss 0.054489 | Val Loss 0.040482
# Epoch 500 | Train Loss 0.048224 | Val Loss 0.040661
# Epoch 600 | Train Loss 0.046251 | Val Loss 0.039401
# Early stopping at epoch 634
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9910, MSE = 9.2552e-04
# X | Train_2 -> R² = 0.8057, MSE = 1.6155e-02
# X | Val_1 -> R² = 0.9722, MSE = 2.7914e-03
# X | Val_2 -> R² = 0.8217, MSE = 1.4464e-02
# X | Test_1 -> R² = -0.6964, MSE = 1.5105e-01
# X | Test_2 -> R² = 0.7193, MSE = 2.5875e-02
# X | LSG_1 -> R² = -6.7939, MSE = 7.6919e-01
# X | LSG_2 -> R² = -3.5782, MSE = 3.9010e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.149242 | Val Loss 0.540422
# Epoch 100 | Train Loss 0.129034 | Val Loss 0.140808
# Epoch 200 | Train Loss 0.079878 | Val Loss 0.088667
# Epoch 300 | Train Loss 0.061168 | Val Loss 0.055966
# Epoch 400 | Train Loss 0.067291 | Val Loss 0.054339
# Epoch 500 | Train Loss 0.044003 | Val Loss 0.043194
# Epoch 600 | Train Loss 0.042734 | Val Loss 0.040884
# Epoch 700 | Train Loss 0.047246 | Val Loss 0.044022
# Epoch 800 | Train Loss 0.041433 | Val Loss 0.038504
# Early stopping at epoch 873
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9323, MSE = 7.0033e-03
# X | Train_2 -> R² = 0.7083, MSE = 2.4249e-02
# X | Val_1 -> R² = 0.9169, MSE = 8.3376e-03
# X | Val_2 -> R² = 0.8636, MSE = 1.1068e-02
# X | Test_1 -> R² = -4.0922, MSE = 4.5342e-01
# X | Test_2 -> R² = -1.4282, MSE = 2.2381e-01
# X | LSG_1 -> R² = -10.9122, MSE = 1.1756e+00
# X | LSG_2 -> R² = -8.9809, MSE = 8.5045e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 1.184099 | Val Loss 0.541709
# Epoch 100 | Train Loss 0.125112 | Val Loss 0.095756
# Epoch 200 | Train Loss 0.081536 | Val Loss 0.072669
# Epoch 300 | Train Loss 0.064732 | Val Loss 0.053508
# Epoch 400 | Train Loss 0.047881 | Val Loss 0.047098
# Epoch 500 | Train Loss 0.042260 | Val Loss 0.047307
# Early stopping at epoch 543
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9826, MSE = 1.7949e-03
# X | Train_2 -> R² = 0.9873, MSE = 1.0581e-03
# X | Val_1 -> R² = 0.9718, MSE = 2.8359e-03
# X | Val_2 -> R² = -0.0504, MSE = 8.5226e-02
# X | Test_1 -> R² = -1.9597, MSE = 2.6354e-01
# X | Test_2 -> R² = 0.2343, MSE = 7.0576e-02
# X | LSG_1 -> R² = 0.4985, MSE = 4.9498e-02
# X | LSG_2 -> R² = 0.0654, MSE = 7.9631e-02
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 1.184215 | Val Loss 0.562015
# Epoch 100 | Train Loss 0.165046 | Val Loss 0.123333
# Epoch 200 | Train Loss 0.063976 | Val Loss 0.067608
# Epoch 300 | Train Loss 0.050545 | Val Loss 0.096269
# Early stopping at epoch 366
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9813, MSE = 1.9283e-03
# X | Train_2 -> R² = 0.9025, MSE = 8.1033e-03
# X | Val_1 -> R² = 0.9912, MSE = 8.8027e-04
# X | Val_2 -> R² = 0.1600, MSE = 6.8159e-02
# X | Test_1 -> R² = -3.6951, MSE = 4.1806e-01
# X | Test_2 -> R² = -0.1476, MSE = 1.0578e-01
# X | LSG_1 -> R² = -6.9899, MSE = 7.8854e-01
# X | LSG_2 -> R² = -4.3807, MSE = 4.5847e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 1.185467 | Val Loss 0.558107
# Epoch 100 | Train Loss 0.122514 | Val Loss 0.131490
# Epoch 200 | Train Loss 0.073756 | Val Loss 0.065309
# Epoch 300 | Train Loss 0.053539 | Val Loss 0.036427
# Epoch 400 | Train Loss 0.044105 | Val Loss 0.044159
# Early stopping at epoch 499
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9910, MSE = 9.2749e-04
# X | Train_2 -> R² = 0.6792, MSE = 2.6666e-02
# X | Val_1 -> R² = 0.9145, MSE = 8.5842e-03
# X | Val_2 -> R² = 0.9534, MSE = 3.7775e-03
# X | Test_1 -> R² = -1.4795, MSE = 2.2078e-01
# X | Test_2 -> R² = 0.0769, MSE = 8.5087e-02
# X | LSG_1 -> R² = -12.1056, MSE = 1.2934e+00
# X | LSG_2 -> R² = -7.2202, MSE = 7.0042e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 1.215888 | Val Loss 0.567044
# Epoch 100 | Train Loss 0.155287 | Val Loss 0.162776
# Epoch 200 | Train Loss 0.088786 | Val Loss 0.078644
# Epoch 300 | Train Loss 0.061230 | Val Loss 0.049759
# Epoch 400 | Train Loss 0.048280 | Val Loss 0.044405
# Epoch 500 | Train Loss 0.044909 | Val Loss 0.042204
# Epoch 600 | Train Loss 0.041382 | Val Loss 0.038312
# Epoch 700 | Train Loss 0.037869 | Val Loss 0.035127
# Epoch 800 | Train Loss 0.036759 | Val Loss 0.038386
# Early stopping at epoch 876
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9824, MSE = 1.8233e-03
# X | Train_2 -> R² = 0.8739, MSE = 1.0483e-02
# X | Val_1 -> R² = 0.9699, MSE = 3.0178e-03
# X | Val_2 -> R² = 0.8878, MSE = 9.1041e-03
# X | Test_1 -> R² = -0.5161, MSE = 1.3499e-01
# X | Test_2 -> R² = 0.6618, MSE = 3.1174e-02
# X | LSG_1 -> R² = -9.5227, MSE = 1.0385e+00
# X | LSG_2 -> R² = -6.5893, MSE = 6.4666e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 1.252776 | Val Loss 0.578178
# Epoch 100 | Train Loss 0.139114 | Val Loss 0.116896
# Epoch 200 | Train Loss 0.085749 | Val Loss 0.073128
# Epoch 300 | Train Loss 0.059806 | Val Loss 0.048693
# Epoch 400 | Train Loss 0.050430 | Val Loss 0.036042
# Epoch 500 | Train Loss 0.047223 | Val Loss 0.059921
# Epoch 600 | Train Loss 0.043916 | Val Loss 0.136682
# Early stopping at epoch 611
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9927, MSE = 7.5177e-04
# X | Train_2 -> R² = 0.9937, MSE = 5.2286e-04
# X | Val_1 -> R² = 0.9091, MSE = 9.1258e-03
# X | Val_2 -> R² = 0.7557, MSE = 1.9823e-02
# X | Test_1 -> R² = -1.7570, MSE = 2.4549e-01
# X | Test_2 -> R² = -0.4436, MSE = 1.3306e-01
# X | LSG_1 -> R² = -3.0699, MSE = 4.0166e-01
# X | LSG_2 -> R² = -1.3678, MSE = 2.0175e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 0.982675 | Val Loss 0.451801
# Epoch 100 | Train Loss 0.106892 | Val Loss 0.087639
# Epoch 200 | Train Loss 0.063017 | Val Loss 0.055483
# Epoch 300 | Train Loss 0.062665 | Val Loss 0.044684
# Epoch 400 | Train Loss 0.044103 | Val Loss 0.038145
# Epoch 500 | Train Loss 0.042183 | Val Loss 0.035949
# Epoch 600 | Train Loss 0.039957 | Val Loss 0.033326
# Epoch 700 | Train Loss 0.038807 | Val Loss 0.031292
# Epoch 800 | Train Loss 0.037436 | Val Loss 0.030982
# Early stopping at epoch 874
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9817, MSE = 1.8886e-03
# X | Train_2 -> R² = 0.9860, MSE = 1.1678e-03
# X | Val_1 -> R² = 0.9105, MSE = 8.9831e-03
# X | Val_2 -> R² = 0.9785, MSE = 1.7478e-03
# X | Test_1 -> R² = -3.9146, MSE = 4.3761e-01
# X | Test_2 -> R² = -0.4091, MSE = 1.2988e-01
# X | LSG_1 -> R² = -2.0498, MSE = 3.0099e-01
# X | LSG_2 -> R² = -1.6753, MSE = 2.2795e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 1.168032 | Val Loss 0.554267
# Epoch 100 | Train Loss 0.140616 | Val Loss 0.120709
# Epoch 200 | Train Loss 0.058242 | Val Loss 0.055035
# Epoch 300 | Train Loss 0.054155 | Val Loss 0.056527
# Epoch 400 | Train Loss 0.043815 | Val Loss 0.035659
# Epoch 500 | Train Loss 0.041372 | Val Loss 0.032462
# Epoch 600 | Train Loss 0.039828 | Val Loss 0.030759
# Epoch 700 | Train Loss 0.038356 | Val Loss 0.030369
# Early stopping at epoch 775
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9864, MSE = 1.4061e-03
# X | Train_2 -> R² = 0.9920, MSE = 6.6691e-04
# X | Val_1 -> R² = 0.9651, MSE = 3.5024e-03
# X | Val_2 -> R² = 0.7504, MSE = 2.0254e-02
# X | Test_1 -> R² = -3.3312, MSE = 3.8566e-01
# X | Test_2 -> R² = 0.6467, MSE = 3.2560e-02
# X | LSG_1 -> R² = -5.7022, MSE = 6.6145e-01
# X | LSG_2 -> R² = -3.2508, MSE = 3.6219e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4951 salvo.
# Epoch 0 | Train Loss 1.970110 | Val Loss 0.562532
# Epoch 100 | Train Loss 0.199451 | Val Loss 0.116065
# Epoch 200 | Train Loss 0.123170 | Val Loss 0.095620
# Epoch 300 | Train Loss 0.088453 | Val Loss 0.086876
# Epoch 400 | Train Loss 0.067013 | Val Loss 0.068224
# Epoch 500 | Train Loss 0.056885 | Val Loss 0.048974
# Epoch 600 | Train Loss 0.051347 | Val Loss 0.033385
# Epoch 700 | Train Loss 0.046965 | Val Loss 0.027660
# Epoch 800 | Train Loss 0.044491 | Val Loss 0.025326
# Epoch 900 | Train Loss 0.042136 | Val Loss 0.024848
# Epoch 1000 | Train Loss 0.040058 | Val Loss 0.025367
# Early stopping at epoch 1018
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9898, MSE = 1.0553e-03
# X | Train_2 -> R² = 0.9929, MSE = 5.8875e-04
# X | Val_1 -> R² = 0.9431, MSE = 5.7092e-03
# X | Val_2 -> R² = 0.4815, MSE = 4.2071e-02
# X | Test_1 -> R² = 0.7196, MSE = 2.4968e-02
# X | Test_2 -> R² = 0.4550, MSE = 5.0233e-02
# X | LSG_1 -> R² = -7.4932, MSE = 8.3821e-01
# X | LSG_2 -> R² = -5.3870, MSE = 5.4422e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 2.061585 | Val Loss 0.578536
# Epoch 100 | Train Loss 0.219986 | Val Loss 0.145078
# Epoch 200 | Train Loss 0.116981 | Val Loss 0.064326
# Epoch 300 | Train Loss 0.084657 | Val Loss 0.042750
# Epoch 400 | Train Loss 0.061451 | Val Loss 0.040990
# Epoch 500 | Train Loss 0.054252 | Val Loss 0.037098
# Epoch 600 | Train Loss 0.049193 | Val Loss 0.032240
# Epoch 700 | Train Loss 0.045057 | Val Loss 0.026722
# Epoch 800 | Train Loss 0.042446 | Val Loss 0.023780
# Epoch 900 | Train Loss 0.040639 | Val Loss 0.022128
# Epoch 1000 | Train Loss 0.038091 | Val Loss 0.030246
# Early stopping at epoch 1052
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.9923, MSE = 7.9348e-04
# X | Train_2 -> R² = 0.9943, MSE = 4.6994e-04
# X | Val_1 -> R² = 0.9398, MSE = 6.0440e-03
# X | Val_2 -> R² = 0.7974, MSE = 1.6437e-02
# X | Test_1 -> R² = -2.6225, MSE = 3.2256e-01
# X | Test_2 -> R² = -0.1511, MSE = 1.0610e-01
# X | LSG_1 -> R² = 0.3105, MSE = 6.8047e-02
# X | LSG_2 -> R² = -0.0440, MSE = 8.8956e-02
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.946643 | Val Loss 0.540253
# Epoch 100 | Train Loss 0.217513 | Val Loss 0.133829
# Epoch 200 | Train Loss 0.113035 | Val Loss 0.074845
# Epoch 300 | Train Loss 0.072992 | Val Loss 0.042527
# Epoch 400 | Train Loss 0.056648 | Val Loss 0.030272
# Epoch 500 | Train Loss 0.051395 | Val Loss 0.028707
# Epoch 600 | Train Loss 0.047630 | Val Loss 0.030611
# Early stopping at epoch 643
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9629, MSE = 3.8368e-03
# X | Train_2 -> R² = 0.9920, MSE = 6.6286e-04
# X | Val_1 -> R² = 0.9662, MSE = 3.3896e-03
# X | Val_2 -> R² = 0.5434, MSE = 3.7051e-02
# X | Test_1 -> R² = -1.7299, MSE = 2.4308e-01
# X | Test_2 -> R² = 0.6993, MSE = 2.7716e-02
# X | LSG_1 -> R² = -1.3045, MSE = 2.2744e-01
# X | LSG_2 -> R² = -0.6090, MSE = 1.3710e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 1.687710 | Val Loss 0.455095
# Epoch 100 | Train Loss 0.192158 | Val Loss 0.130797
# Epoch 200 | Train Loss 0.119940 | Val Loss 0.073932
# Epoch 300 | Train Loss 0.086089 | Val Loss 0.044263
# Epoch 400 | Train Loss 0.061583 | Val Loss 0.035925
# Epoch 500 | Train Loss 0.053854 | Val Loss 0.030547
# Epoch 600 | Train Loss 0.050521 | Val Loss 0.027220
# Epoch 700 | Train Loss 0.047876 | Val Loss 0.030690
# Early stopping at epoch 797
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed3227.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed3227.weights.h5
# X | Train_1 -> R² = 0.9927, MSE = 7.5839e-04
# X | Train_2 -> R² = 0.9930, MSE = 5.8333e-04
# X | Val_1 -> R² = 0.9668, MSE = 3.3340e-03
# X | Val_2 -> R² = 0.2861, MSE = 5.7924e-02
# X | Test_1 -> R² = -0.5719, MSE = 1.3997e-01
# X | Test_2 -> R² = 0.8328, MSE = 1.5408e-02
# X | LSG_1 -> R² = -5.1233, MSE = 6.0432e-01
# X | LSG_2 -> R² = -3.3262, MSE = 3.6862e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 1.949634 | Val Loss 0.548273
# Epoch 100 | Train Loss 0.222216 | Val Loss 0.130319
# Epoch 200 | Train Loss 0.113620 | Val Loss 0.066791
# Epoch 300 | Train Loss 0.072022 | Val Loss 0.038679
# Epoch 400 | Train Loss 0.053019 | Val Loss 0.028811
# Epoch 500 | Train Loss 0.048514 | Val Loss 0.028418
# Epoch 600 | Train Loss 0.045751 | Val Loss 0.048309
# Early stopping at epoch 609
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed4951.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed4951.weights.h5
# X | Train_1 -> R² = 0.9794, MSE = 2.1326e-03
# X | Train_2 -> R² = 0.9935, MSE = 5.3702e-04
# X | Val_1 -> R² = 0.9649, MSE = 3.5283e-03
# X | Val_2 -> R² = 0.6387, MSE = 2.9314e-02
# X | Test_1 -> R² = 0.2266, MSE = 6.8868e-02
# X | Test_2 -> R² = 0.8330, MSE = 1.5392e-02
# X | LSG_1 -> R² = -1.1439, MSE = 2.1159e-01
# X | LSG_2 -> R² = -0.5458, MSE = 1.3171e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 1.791559 | Val Loss 0.517275
# Epoch 100 | Train Loss 0.224330 | Val Loss 0.127001
# Epoch 200 | Train Loss 0.114756 | Val Loss 0.072051
# Epoch 300 | Train Loss 0.076286 | Val Loss 0.050953
# Epoch 400 | Train Loss 0.063782 | Val Loss 0.045925
# Epoch 500 | Train Loss 0.054243 | Val Loss 0.042971
# Epoch 600 | Train Loss 0.049429 | Val Loss 0.034130
# Epoch 700 | Train Loss 0.047475 | Val Loss 0.028654
# Epoch 800 | Train Loss 0.045530 | Val Loss 0.025592
# Epoch 900 | Train Loss 0.042892 | Val Loss 0.024057
# Epoch 1000 | Train Loss 0.078201 | Val Loss 0.084507
# Epoch 1100 | Train Loss 0.044723 | Val Loss 0.034139
# Early stopping at epoch 1170
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9847, MSE = 1.5805e-03
# X | Train_2 -> R² = 0.7327, MSE = 2.2220e-02
# X | Val_1 -> R² = 0.9919, MSE = 8.1023e-04
# X | Val_2 -> R² = 0.9520, MSE = 3.8952e-03
# X | Test_1 -> R² = -0.1976, MSE = 1.0664e-01
# X | Test_2 -> R² = 0.9112, MSE = 8.1871e-03
# X | LSG_1 -> R² = -4.5758, MSE = 5.5028e-01
# X | LSG_2 -> R² = -3.4735, MSE = 3.8118e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 1.872535 | Val Loss 0.533435
# Epoch 100 | Train Loss 0.192162 | Val Loss 0.114315
# Epoch 200 | Train Loss 0.097137 | Val Loss 0.077822
# Epoch 300 | Train Loss 0.073586 | Val Loss 0.097092
# Early stopping at epoch 371
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.9890, MSE = 1.1348e-03
# X | Train_2 -> R² = 0.9772, MSE = 1.8947e-03
# X | Val_1 -> R² = 0.8628, MSE = 1.3772e-02
# X | Val_2 -> R² = -0.5734, MSE = 1.2766e-01
# X | Test_1 -> R² = -8.4370, MSE = 8.4030e-01
# X | Test_2 -> R² = -0.2142, MSE = 1.1192e-01
# X | LSG_1 -> R² = -3.6921, MSE = 4.6307e-01
# X | LSG_2 -> R² = -2.1173, MSE = 2.6561e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 2.121622 | Val Loss 0.575901
# Epoch 100 | Train Loss 0.225185 | Val Loss 0.121448
# Epoch 200 | Train Loss 0.122461 | Val Loss 0.084942
# Epoch 300 | Train Loss 0.082313 | Val Loss 0.064249
# Epoch 400 | Train Loss 0.062772 | Val Loss 0.050293
# Epoch 500 | Train Loss 0.056927 | Val Loss 0.047684
# Epoch 600 | Train Loss 0.054631 | Val Loss 0.044203
# Epoch 700 | Train Loss 0.049869 | Val Loss 0.100114
# Epoch 800 | Train Loss 0.047591 | Val Loss 0.100469
# Early stopping at epoch 808
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9828, MSE = 1.7831e-03
# X | Train_2 -> R² = 0.9824, MSE = 1.4645e-03
# X | Val_1 -> R² = 0.7638, MSE = 2.3712e-02
# X | Val_2 -> R² = 0.1715, MSE = 6.7228e-02
# X | Test_1 -> R² = -2.8040, MSE = 3.3872e-01
# X | Test_2 -> R² = 0.3357, MSE = 6.1226e-02
# X | LSG_1 -> R² = -3.3688, MSE = 4.3116e-01
# X | LSG_2 -> R² = -0.4976, MSE = 1.2761e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 1.750790 | Val Loss 0.502370
# Epoch 100 | Train Loss 0.167852 | Val Loss 0.105408
# Epoch 200 | Train Loss 0.072434 | Val Loss 0.068348
# Epoch 300 | Train Loss 0.054916 | Val Loss 0.057130
# Epoch 400 | Train Loss 0.050717 | Val Loss 0.047363
# Epoch 500 | Train Loss 0.048392 | Val Loss 0.044044
# Epoch 600 | Train Loss 0.046711 | Val Loss 0.041122
# Epoch 700 | Train Loss 0.045167 | Val Loss 0.038756
# Epoch 800 | Train Loss 0.043501 | Val Loss 0.038943
# Early stopping at epoch 883
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed3227.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed3227.weights.h5
# X | Train_1 -> R² = 0.9920, MSE = 8.2549e-04
# X | Train_2 -> R² = 0.9949, MSE = 4.2214e-04
# X | Val_1 -> R² = 0.7832, MSE = 2.1767e-02
# X | Val_2 -> R² = 0.2517, MSE = 6.0720e-02
# X | Test_1 -> R² = -0.1792, MSE = 1.0500e-01
# X | Test_2 -> R² = -0.8173, MSE = 1.6750e-01
# X | LSG_1 -> R² = -4.2180, MSE = 5.1497e-01
# X | LSG_2 -> R² = -3.0678, MSE = 3.4660e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 2.159192 | Val Loss 0.611375
# Epoch 100 | Train Loss 0.297321 | Val Loss 0.176302
# Epoch 200 | Train Loss 0.122728 | Val Loss 0.059816
# Epoch 300 | Train Loss 0.079321 | Val Loss 0.046991
# Epoch 400 | Train Loss 0.068920 | Val Loss 0.037279
# Epoch 500 | Train Loss 0.062426 | Val Loss 0.032841
# Epoch 600 | Train Loss 0.054778 | Val Loss 0.033071
# Early stopping at epoch 684
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed4951.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed4951.weights.h5
# X | Train_1 -> R² = 0.9792, MSE = 2.1501e-03
# X | Train_2 -> R² = 0.9916, MSE = 6.9927e-04
# X | Val_1 -> R² = 0.9457, MSE = 5.4552e-03
# X | Val_2 -> R² = 0.5432, MSE = 3.7069e-02
# X | Test_1 -> R² = -3.3281, MSE = 3.8539e-01
# X | Test_2 -> R² = -0.4735, MSE = 1.3582e-01
# X | LSG_1 -> R² = -4.8910, MSE = 5.8139e-01
# X | LSG_2 -> R² = -4.2024, MSE = 4.4328e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4951 salvo.
# Epoch 0 | Train Loss 1.279656 | Val Loss 0.596374
# Epoch 100 | Train Loss 0.063591 | Val Loss 0.068376
# Epoch 200 | Train Loss 0.045130 | Val Loss 0.049724
# Epoch 300 | Train Loss 0.041057 | Val Loss 0.044831
# Epoch 400 | Train Loss 0.038701 | Val Loss 0.045631
# Epoch 500 | Train Loss 0.036769 | Val Loss 0.043693
# Early stopping at epoch 570
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9859, MSE = 1.4610e-03
# X | Train_2 -> R² = 0.9919, MSE = 6.7705e-04
# X | Val_1 -> R² = 0.5730, MSE = 4.2861e-02
# X | Val_2 -> R² = 0.4926, MSE = 4.1171e-02
# X | Test_1 -> R² = 0.0486, MSE = 8.4712e-02
# X | Test_2 -> R² = -0.0368, MSE = 9.5564e-02
# X | LSG_1 -> R² = -5.2381, MSE = 6.1564e-01
# X | LSG_2 -> R² = -4.2536, MSE = 4.4765e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 1.081980 | Val Loss 0.503926
# Epoch 100 | Train Loss 0.090184 | Val Loss 0.085356
# Epoch 200 | Train Loss 0.049294 | Val Loss 0.045032
# Epoch 300 | Train Loss 0.043140 | Val Loss 0.045038
# Epoch 400 | Train Loss 0.038753 | Val Loss 0.053403
# Early stopping at epoch 441
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9877, MSE = 1.2746e-03
# X | Train_2 -> R² = 0.9931, MSE = 5.7231e-04
# X | Val_1 -> R² = 0.9776, MSE = 2.2440e-03
# X | Val_2 -> R² = 0.5582, MSE = 3.5851e-02
# X | Test_1 -> R² = -2.2901, MSE = 2.9296e-01
# X | Test_2 -> R² = 0.7365, MSE = 2.4284e-02
# X | LSG_1 -> R² = -0.9280, MSE = 1.9027e-01
# X | LSG_2 -> R² = -0.0692, MSE = 9.1105e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.037383 | Val Loss 0.433025
# Epoch 100 | Train Loss 0.077856 | Val Loss 0.064682
# Epoch 200 | Train Loss 0.048595 | Val Loss 0.045339
# Epoch 300 | Train Loss 0.043650 | Val Loss 0.046421
# Epoch 400 | Train Loss 0.040092 | Val Loss 0.047501
# Early stopping at epoch 418
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9885, MSE = 1.1938e-03
# X | Train_2 -> R² = 0.9916, MSE = 6.9821e-04
# X | Val_1 -> R² = 0.8529, MSE = 1.4765e-02
# X | Val_2 -> R² = 0.0152, MSE = 7.9909e-02
# X | Test_1 -> R² = -1.7311, MSE = 2.4318e-01
# X | Test_2 -> R² = -0.1702, MSE = 1.0786e-01
# X | LSG_1 -> R² = -8.1730, MSE = 9.0529e-01
# X | LSG_2 -> R² = -6.0233, MSE = 5.9843e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 0.898634 | Val Loss 0.451370
# Epoch 100 | Train Loss 0.077682 | Val Loss 0.063710
# Epoch 200 | Train Loss 0.050961 | Val Loss 0.051194
# Epoch 300 | Train Loss 0.041483 | Val Loss 0.046452
# Epoch 400 | Train Loss 0.037901 | Val Loss 0.038458
# Epoch 500 | Train Loss 0.034102 | Val Loss 0.040720
# Early stopping at epoch 583
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9774, MSE = 2.3409e-03
# X | Train_2 -> R² = 0.9724, MSE = 2.2973e-03
# X | Val_1 -> R² = 0.6171, MSE = 3.8433e-02
# X | Val_2 -> R² = 0.9552, MSE = 3.6357e-03
# X | Test_1 -> R² = -0.3844, MSE = 1.2327e-01
# X | Test_2 -> R² = 0.6692, MSE = 3.0488e-02
# X | LSG_1 -> R² = -0.7455, MSE = 1.7227e-01
# X | LSG_2 -> R² = -0.1534, MSE = 9.8281e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 1.343751 | Val Loss 0.609930
# Epoch 100 | Train Loss 0.070440 | Val Loss 0.077256
# Epoch 200 | Train Loss 0.052591 | Val Loss 0.053137
# Epoch 300 | Train Loss 0.045881 | Val Loss 0.046025
# Epoch 400 | Train Loss 0.039857 | Val Loss 0.047478
# Epoch 500 | Train Loss 0.036821 | Val Loss 0.048686
# Epoch 600 | Train Loss 0.033176 | Val Loss 0.055122
# Early stopping at epoch 612
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9727, MSE = 2.8188e-03
# X | Train_2 -> R² = 0.9336, MSE = 5.5211e-03
# X | Val_1 -> R² = 0.9367, MSE = 6.3511e-03
# X | Val_2 -> R² = 0.9609, MSE = 3.1712e-03
# X | Test_1 -> R² = -1.9546, MSE = 2.6309e-01
# X | Test_2 -> R² = -0.2388, MSE = 1.1418e-01
# X | LSG_1 -> R² = -2.7714, MSE = 3.7220e-01
# X | LSG_2 -> R² = -2.6129, MSE = 3.0785e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 1.148685 | Val Loss 0.521993
# Epoch 100 | Train Loss 0.083110 | Val Loss 0.083941
# Epoch 200 | Train Loss 0.052112 | Val Loss 0.056073
# Epoch 300 | Train Loss 0.043185 | Val Loss 0.045371
# Epoch 400 | Train Loss 0.038604 | Val Loss 0.050223
# Epoch 500 | Train Loss 0.036743 | Val Loss 0.036707
# Epoch 600 | Train Loss 0.034766 | Val Loss 0.042529
# Early stopping at epoch 655
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9886, MSE = 1.1799e-03
# X | Train_2 -> R² = 0.9724, MSE = 2.2981e-03
# X | Val_1 -> R² = 0.9334, MSE = 6.6888e-03
# X | Val_2 -> R² = 0.8568, MSE = 1.1620e-02
# X | Test_1 -> R² = -1.5047, MSE = 2.2302e-01
# X | Test_2 -> R² = -0.2408, MSE = 1.1437e-01
# X | LSG_1 -> R² = -2.2448, MSE = 3.2023e-01
# X | LSG_2 -> R² = -1.7749, MSE = 2.3644e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 1.218864 | Val Loss 0.557126
# Epoch 100 | Train Loss 0.072166 | Val Loss 0.068000
# Epoch 200 | Train Loss 0.048060 | Val Loss 0.044585
# Epoch 300 | Train Loss 0.042861 | Val Loss 0.040727
# Epoch 400 | Train Loss 0.036771 | Val Loss 0.057143
# Epoch 500 | Train Loss 0.033775 | Val Loss 0.084837
# Early stopping at epoch 520
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9881, MSE = 1.2274e-03
# X | Train_2 -> R² = 0.8903, MSE = 9.1208e-03
# X | Val_1 -> R² = 0.9521, MSE = 4.8077e-03
# X | Val_2 -> R² = 0.9810, MSE = 1.5453e-03
# X | Test_1 -> R² = -1.8749, MSE = 2.5599e-01
# X | Test_2 -> R² = -0.0712, MSE = 9.8731e-02
# X | LSG_1 -> R² = -5.2499, MSE = 6.1681e-01
# X | LSG_2 -> R² = -3.4345, MSE = 3.7785e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 1.036373 | Val Loss 0.460985
# Epoch 100 | Train Loss 0.096649 | Val Loss 0.087780
# Epoch 200 | Train Loss 0.056090 | Val Loss 0.050141
# Epoch 300 | Train Loss 0.042049 | Val Loss 0.034607
# Epoch 400 | Train Loss 0.051873 | Val Loss 0.066805
# Early stopping at epoch 486
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9829, MSE = 1.7699e-03
# X | Train_2 -> R² = 0.9940, MSE = 5.0150e-04
# X | Val_1 -> R² = 0.9835, MSE = 1.6553e-03
# X | Val_2 -> R² = 0.6306, MSE = 2.9973e-02
# X | Test_1 -> R² = -2.1651, MSE = 2.8183e-01
# X | Test_2 -> R² = 0.6221, MSE = 3.4830e-02
# X | LSG_1 -> R² = -2.8907, MSE = 3.8397e-01
# X | LSG_2 -> R² = -1.4173, MSE = 2.0597e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 1.237573 | Val Loss 0.545853
# Epoch 100 | Train Loss 0.082424 | Val Loss 0.064957
# Epoch 200 | Train Loss 0.044111 | Val Loss 0.049142
# Epoch 300 | Train Loss 0.038171 | Val Loss 0.044176
# Epoch 400 | Train Loss 0.036247 | Val Loss 0.053745
# Epoch 500 | Train Loss 0.031608 | Val Loss 0.058027
# Epoch 600 | Train Loss 0.030988 | Val Loss 0.063662
# Early stopping at epoch 622
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9776, MSE = 2.3197e-03
# X | Train_2 -> R² = 0.9754, MSE = 2.0438e-03
# X | Val_1 -> R² = 0.8664, MSE = 1.3413e-02
# X | Val_2 -> R² = 0.7187, MSE = 2.2828e-02
# X | Test_1 -> R² = -0.9196, MSE = 1.7093e-01
# X | Test_2 -> R² = 0.5741, MSE = 3.9259e-02
# X | LSG_1 -> R² = -1.8370, MSE = 2.7999e-01
# X | LSG_2 -> R² = -1.7585, MSE = 2.3504e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 1.152670 | Val Loss 0.522809
# Epoch 100 | Train Loss 0.075969 | Val Loss 0.067137
# Epoch 200 | Train Loss 0.045136 | Val Loss 0.054891
# Epoch 300 | Train Loss 0.038266 | Val Loss 0.052326
# Early stopping at epoch 346
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9921, MSE = 8.1377e-04
# X | Train_2 -> R² = 0.9779, MSE = 1.8383e-03
# X | Val_1 -> R² = 0.9745, MSE = 2.5591e-03
# X | Val_2 -> R² = 0.2692, MSE = 5.9294e-02
# X | Test_1 -> R² = -1.2868, MSE = 2.0363e-01
# X | Test_2 -> R² = 0.1883, MSE = 7.4815e-02
# X | LSG_1 -> R² = -6.6202, MSE = 7.5205e-01
# X | LSG_2 -> R² = -3.5772, MSE = 3.9001e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4951 salvo.
# Epoch 0 | Train Loss 1.757480 | Val Loss 0.481192
# Epoch 100 | Train Loss 0.092966 | Val Loss 0.060693
# Epoch 200 | Train Loss 0.056139 | Val Loss 0.036919
# Epoch 300 | Train Loss 0.045418 | Val Loss 0.034150
# Epoch 400 | Train Loss 0.036844 | Val Loss 0.082079
# Early stopping at epoch 462
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9892, MSE = 1.1196e-03
# X | Train_2 -> R² = 0.9936, MSE = 5.3134e-04
# X | Val_1 -> R² = 0.7846, MSE = 2.1626e-02
# X | Val_2 -> R² = 0.5614, MSE = 3.5588e-02
# X | Test_1 -> R² = -2.0224, MSE = 2.6913e-01
# X | Test_2 -> R² = 0.3828, MSE = 5.6884e-02
# X | LSG_1 -> R² = -0.0252, MSE = 1.0118e-01
# X | LSG_2 -> R² = 0.3277, MSE = 5.7280e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 1.827858 | Val Loss 0.501413
# Epoch 100 | Train Loss 0.129410 | Val Loss 0.077619
# Epoch 200 | Train Loss 0.105063 | Val Loss 0.058582
# Epoch 300 | Train Loss 0.059759 | Val Loss 0.034380
# Epoch 400 | Train Loss 0.047478 | Val Loss 0.026949
# Epoch 500 | Train Loss 0.043796 | Val Loss 0.023186
# Epoch 600 | Train Loss 0.041516 | Val Loss 0.025837
# Early stopping at epoch 690
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.9884, MSE = 1.1989e-03
# X | Train_2 -> R² = 0.9939, MSE = 5.0720e-04
# X | Val_1 -> R² = 0.9667, MSE = 3.3457e-03
# X | Val_2 -> R² = 0.9402, MSE = 4.8489e-03
# X | Test_1 -> R² = -1.6631, MSE = 2.3713e-01
# X | Test_2 -> R² = 0.6396, MSE = 3.3217e-02
# X | LSG_1 -> R² = -0.4070, MSE = 1.3885e-01
# X | LSG_2 -> R² = -0.1339, MSE = 9.6617e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.878931 | Val Loss 0.505563
# Epoch 100 | Train Loss 0.129221 | Val Loss 0.086184
# Epoch 200 | Train Loss 0.067579 | Val Loss 0.056410
# Epoch 300 | Train Loss 0.057471 | Val Loss 0.041005
# Epoch 400 | Train Loss 0.052261 | Val Loss 0.037675
# Epoch 500 | Train Loss 0.047033 | Val Loss 0.036281
# Epoch 600 | Train Loss 0.041071 | Val Loss 0.035078
# Epoch 700 | Train Loss 0.036283 | Val Loss 0.034619
# Epoch 800 | Train Loss 0.041024 | Val Loss 0.033022
# Epoch 900 | Train Loss 0.032059 | Val Loss 0.035766
# Epoch 1000 | Train Loss 0.031318 | Val Loss 0.035744
# Early stopping at epoch 1001
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9917, MSE = 8.5640e-04
# X | Train_2 -> R² = 0.9922, MSE = 6.4763e-04
# X | Val_1 -> R² = 0.8681, MSE = 1.3240e-02
# X | Val_2 -> R² = 0.9404, MSE = 4.8330e-03
# X | Test_1 -> R² = -0.8705, MSE = 1.6655e-01
# X | Test_2 -> R² = -2.1792, MSE = 2.9303e-01
# X | LSG_1 -> R² = -0.3541, MSE = 1.3363e-01
# X | LSG_2 -> R² = -1.3398, MSE = 1.9936e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 1.801544 | Val Loss 0.489364
# Epoch 100 | Train Loss 0.108879 | Val Loss 0.076201
# Epoch 200 | Train Loss 0.070567 | Val Loss 0.093469
# Epoch 300 | Train Loss 0.058738 | Val Loss 0.072312
# Epoch 400 | Train Loss 0.052973 | Val Loss 0.074123
# Epoch 500 | Train Loss 0.049010 | Val Loss 0.078652
# Early stopping at epoch 542
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed3227.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed3227.weights.h5
# X | Train_1 -> R² = 0.9764, MSE = 2.4370e-03
# X | Train_2 -> R² = 0.9593, MSE = 3.3804e-03
# X | Val_1 -> R² = 0.9496, MSE = 5.0562e-03
# X | Val_2 -> R² = -0.5040, MSE = 1.2203e-01
# X | Test_1 -> R² = -3.4581, MSE = 3.9697e-01
# X | Test_2 -> R² = 0.0318, MSE = 8.9236e-02
# X | LSG_1 -> R² = -1.0053, MSE = 1.9791e-01
# X | LSG_2 -> R² = -1.6474, MSE = 2.2558e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 1.374132 | Val Loss 0.389811
# Epoch 100 | Train Loss 0.102917 | Val Loss 0.067111
# Epoch 200 | Train Loss 0.076124 | Val Loss 0.043771
# Epoch 300 | Train Loss 0.055836 | Val Loss 0.032936
# Epoch 400 | Train Loss 0.049578 | Val Loss 0.029620
# Epoch 500 | Train Loss 0.044150 | Val Loss 0.044261
# Early stopping at epoch 583
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed4951.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed4951.weights.h5
# X | Train_1 -> R² = 0.9865, MSE = 1.3969e-03
# X | Train_2 -> R² = 0.9935, MSE = 5.4290e-04
# X | Val_1 -> R² = 0.9806, MSE = 1.9438e-03
# X | Val_2 -> R² = 0.2780, MSE = 5.8584e-02
# X | Test_1 -> R² = -2.1427, MSE = 2.7983e-01
# X | Test_2 -> R² = 0.3791, MSE = 5.7231e-02
# X | LSG_1 -> R² = -0.7726, MSE = 1.7494e-01
# X | LSG_2 -> R² = -0.8890, MSE = 1.6095e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 1.728326 | Val Loss 0.488919
# Epoch 100 | Train Loss 0.098702 | Val Loss 0.060600
# Epoch 200 | Train Loss 0.064331 | Val Loss 0.043625
# Epoch 300 | Train Loss 0.051175 | Val Loss 0.035608
# Epoch 400 | Train Loss 0.045242 | Val Loss 0.034657
# Epoch 500 | Train Loss 0.040193 | Val Loss 0.030946
# Epoch 600 | Train Loss 0.036792 | Val Loss 0.032090
# Epoch 700 | Train Loss 0.034036 | Val Loss 0.035720
# Early stopping at epoch 753
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9786, MSE = 2.2115e-03
# X | Train_2 -> R² = 0.9947, MSE = 4.3851e-04
# X | Val_1 -> R² = 0.8722, MSE = 1.2827e-02
# X | Val_2 -> R² = 0.9704, MSE = 2.3996e-03
# X | Test_1 -> R² = -0.8516, MSE = 1.6488e-01
# X | Test_2 -> R² = -0.2702, MSE = 1.1707e-01
# X | LSG_1 -> R² = -7.3344, MSE = 8.2253e-01
# X | LSG_2 -> R² = -5.2810, MSE = 5.3518e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 1.747411 | Val Loss 0.495824
# Epoch 100 | Train Loss 0.118538 | Val Loss 0.080751
# Epoch 200 | Train Loss 0.072128 | Val Loss 0.038707
# Epoch 300 | Train Loss 0.057647 | Val Loss 0.043947
# Epoch 400 | Train Loss 0.061283 | Val Loss 0.036947
# Epoch 500 | Train Loss 0.047886 | Val Loss 0.034008
# Early stopping at epoch 584
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.7952, MSE = 2.1172e-02
# X | Train_2 -> R² = 0.9521, MSE = 3.9798e-03
# X | Val_1 -> R² = 0.8996, MSE = 1.0080e-02
# X | Val_2 -> R² = 0.7327, MSE = 2.1686e-02
# X | Test_1 -> R² = -0.9016, MSE = 1.6933e-01
# X | Test_2 -> R² = 0.5461, MSE = 4.1835e-02
# X | LSG_1 -> R² = -4.6852, MSE = 5.6108e-01
# X | LSG_2 -> R² = -4.1702, MSE = 4.4054e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 1.920792 | Val Loss 0.528425
# Epoch 100 | Train Loss 0.106643 | Val Loss 0.076837
# Epoch 200 | Train Loss 0.072890 | Val Loss 0.049818
# Epoch 300 | Train Loss 0.058289 | Val Loss 0.041799
# Epoch 400 | Train Loss 0.052286 | Val Loss 0.049730
# Epoch 500 | Train Loss 0.047483 | Val Loss 0.055642
# Early stopping at epoch 590
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9931, MSE = 7.1506e-04
# X | Train_2 -> R² = 0.9658, MSE = 2.8452e-03
# X | Val_1 -> R² = 0.9103, MSE = 9.0057e-03
# X | Val_2 -> R² = 0.5399, MSE = 3.7333e-02
# X | Test_1 -> R² = -2.6639, MSE = 3.2624e-01
# X | Test_2 -> R² = 0.7720, MSE = 2.1013e-02
# X | LSG_1 -> R² = -1.5022, MSE = 2.4694e-01
# X | LSG_2 -> R² = -0.9329, MSE = 1.6469e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 1.540891 | Val Loss 0.409793
# Epoch 100 | Train Loss 0.122576 | Val Loss 0.087168
# Epoch 200 | Train Loss 0.070037 | Val Loss 0.059363
# Epoch 300 | Train Loss 0.051411 | Val Loss 0.047235
# Epoch 400 | Train Loss 0.045107 | Val Loss 0.038273
# Epoch 500 | Train Loss 0.039346 | Val Loss 0.073144
# Epoch 600 | Train Loss 0.035728 | Val Loss 0.087098
# Early stopping at epoch 616
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed3227.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed3227.weights.h5
# X | Train_1 -> R² = 0.9863, MSE = 1.4162e-03
# X | Train_2 -> R² = 0.9934, MSE = 5.5232e-04
# X | Val_1 -> R² = 0.9588, MSE = 4.1325e-03
# X | Val_2 -> R² = 0.3383, MSE = 5.3690e-02
# X | Test_1 -> R² = -1.7275, MSE = 2.4287e-01
# X | Test_2 -> R² = 0.6587, MSE = 3.1459e-02
# X | LSG_1 -> R² = 0.5303, MSE = 4.6356e-02
# X | LSG_2 -> R² = 0.3372, MSE = 5.6475e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 1.925606 | Val Loss 0.492847
# Epoch 100 | Train Loss 0.113541 | Val Loss 0.078996
# Epoch 200 | Train Loss 0.068081 | Val Loss 0.051047
# Epoch 300 | Train Loss 0.056152 | Val Loss 0.035628
# Epoch 400 | Train Loss 0.051550 | Val Loss 0.027417
# Epoch 500 | Train Loss 0.046658 | Val Loss 0.022288
# Epoch 600 | Train Loss 0.042923 | Val Loss 0.021022
# Epoch 700 | Train Loss 0.040294 | Val Loss 0.021194
# Early stopping at epoch 788
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed4951.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed4951.weights.h5
# X | Train_1 -> R² = 0.9853, MSE = 1.5217e-03
# X | Train_2 -> R² = 0.9948, MSE = 4.3385e-04
# X | Val_1 -> R² = 0.9236, MSE = 7.6698e-03
# X | Val_2 -> R² = 0.7926, MSE = 1.6825e-02
# X | Test_1 -> R² = -0.6190, MSE = 1.4416e-01
# X | Test_2 -> R² = 0.6685, MSE = 3.0553e-02
# X | LSG_1 -> R² = -0.9083, MSE = 1.8833e-01
# X | LSG_2 -> R² = -0.2482, MSE = 1.0636e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4951 salvo.
# Epoch 0 | Train Loss 0.715346 | Val Loss 0.251958
# Epoch 100 | Train Loss 0.053313 | Val Loss 0.055388
# Epoch 200 | Train Loss 0.038729 | Val Loss 0.047527
# Epoch 300 | Train Loss 0.034497 | Val Loss 0.046999
# Early stopping at epoch 340
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9923, MSE = 7.9350e-04
# X | Train_2 -> R² = 0.9805, MSE = 1.6193e-03
# X | Val_1 -> R² = 0.9654, MSE = 3.4764e-03
# X | Val_2 -> R² = -0.0749, MSE = 8.7214e-02
# X | Test_1 -> R² = -1.1838, MSE = 1.9445e-01
# X | Test_2 -> R² = 0.0099, MSE = 9.1256e-02
# X | LSG_1 -> R² = -1.9903, MSE = 2.9512e-01
# X | LSG_2 -> R² = -1.3746, MSE = 2.0233e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 0.875485 | Val Loss 0.348494
# Epoch 100 | Train Loss 0.045650 | Val Loss 0.045797
# Epoch 200 | Train Loss 0.034714 | Val Loss 0.038050
# Epoch 300 | Train Loss 0.032555 | Val Loss 0.039213
# Epoch 400 | Train Loss 0.033347 | Val Loss 0.040884
# Early stopping at epoch 465
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9783, MSE = 2.2438e-03
# X | Train_2 -> R² = 0.9891, MSE = 9.0818e-04
# X | Val_1 -> R² = 0.9042, MSE = 9.6174e-03
# X | Val_2 -> R² = 0.7659, MSE = 1.8995e-02
# X | Test_1 -> R² = -2.8364, MSE = 3.4160e-01
# X | Test_2 -> R² = -0.4505, MSE = 1.3369e-01
# X | LSG_1 -> R² = -2.7092, MSE = 3.6606e-01
# X | LSG_2 -> R² = -1.6062, MSE = 2.2207e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 0.982588 | Val Loss 0.404233
# Epoch 100 | Train Loss 0.050244 | Val Loss 0.058151
# Epoch 200 | Train Loss 0.048484 | Val Loss 0.061432
# Epoch 300 | Train Loss 0.035860 | Val Loss 0.056000
# Epoch 400 | Train Loss 0.031095 | Val Loss 0.050621
# Early stopping at epoch 498
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9803, MSE = 2.0401e-03
# X | Train_2 -> R² = 0.9157, MSE = 7.0116e-03
# X | Val_1 -> R² = 0.7359, MSE = 2.6508e-02
# X | Val_2 -> R² = 0.7735, MSE = 1.8380e-02
# X | Test_1 -> R² = -0.9808, MSE = 1.7637e-01
# X | Test_2 -> R² = 0.4824, MSE = 4.7707e-02
# X | LSG_1 -> R² = -2.5512, MSE = 3.5047e-01
# X | LSG_2 -> R² = -2.9389, MSE = 3.3562e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 1.073809 | Val Loss 0.486131
# Epoch 100 | Train Loss 0.053496 | Val Loss 0.058069
# Epoch 200 | Train Loss 0.039034 | Val Loss 0.047597
# Epoch 300 | Train Loss 0.033165 | Val Loss 0.044835
# Epoch 400 | Train Loss 0.030373 | Val Loss 0.048379
# Early stopping at epoch 463
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9730, MSE = 2.7940e-03
# X | Train_2 -> R² = 0.9943, MSE = 4.7348e-04
# X | Val_1 -> R² = 0.8613, MSE = 1.3924e-02
# X | Val_2 -> R² = 0.7727, MSE = 1.8447e-02
# X | Test_1 -> R² = -1.8308, MSE = 2.5206e-01
# X | Test_2 -> R² = -0.3989, MSE = 1.2894e-01
# X | LSG_1 -> R² = 0.3616, MSE = 6.3006e-02
# X | LSG_2 -> R² = 0.4420, MSE = 4.7548e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 0.837196 | Val Loss 0.344375
# Epoch 100 | Train Loss 0.048676 | Val Loss 0.057159
# Epoch 200 | Train Loss 0.039233 | Val Loss 0.042529
# Epoch 300 | Train Loss 0.035203 | Val Loss 0.040640
# Epoch 400 | Train Loss 0.032479 | Val Loss 0.043078
# Early stopping at epoch 438
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9917, MSE = 8.6025e-04
# X | Train_2 -> R² = 0.9859, MSE = 1.1684e-03
# X | Val_1 -> R² = 0.9743, MSE = 2.5840e-03
# X | Val_2 -> R² = 0.5311, MSE = 3.8050e-02
# X | Test_1 -> R² = -2.6120, MSE = 3.2162e-01
# X | Test_2 -> R² = 0.5678, MSE = 3.9832e-02
# X | LSG_1 -> R² = -2.4478, MSE = 3.4027e-01
# X | LSG_2 -> R² = -1.3143, MSE = 1.9719e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 0.897835 | Val Loss 0.365224
# Epoch 100 | Train Loss 0.048008 | Val Loss 0.069040
# Epoch 200 | Train Loss 0.039523 | Val Loss 0.047844
# Epoch 300 | Train Loss 0.035073 | Val Loss 0.043013
# Epoch 400 | Train Loss 0.031517 | Val Loss 0.041648
# Early stopping at epoch 482
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9700, MSE = 3.1050e-03
# X | Train_2 -> R² = 0.9302, MSE = 5.8025e-03
# X | Val_1 -> R² = 0.9187, MSE = 8.1602e-03
# X | Val_2 -> R² = 0.6257, MSE = 3.0372e-02
# X | Test_1 -> R² = -1.2935, MSE = 2.0422e-01
# X | Test_2 -> R² = -0.0455, MSE = 9.6361e-02
# X | LSG_1 -> R² = -8.4025, MSE = 9.2794e-01
# X | LSG_2 -> R² = -7.8797, MSE = 7.5661e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 0.735994 | Val Loss 0.286426
# Epoch 100 | Train Loss 0.044912 | Val Loss 0.061638
# Epoch 200 | Train Loss 0.034073 | Val Loss 0.061681
# Epoch 300 | Train Loss 0.030390 | Val Loss 0.056053
# Epoch 400 | Train Loss 0.028981 | Val Loss 0.057944
# Epoch 500 | Train Loss 0.027995 | Val Loss 0.067477
# Epoch 600 | Train Loss 0.027865 | Val Loss 0.079865
# Epoch 700 | Train Loss 0.028130 | Val Loss 0.094820
# Early stopping at epoch 768
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9895, MSE = 1.0867e-03
# X | Train_2 -> R² = 0.8196, MSE = 1.4998e-02
# X | Val_1 -> R² = 0.6702, MSE = 3.3109e-02
# X | Val_2 -> R² = 0.9432, MSE = 4.6056e-03
# X | Test_1 -> R² = -0.6210, MSE = 1.4434e-01
# X | Test_2 -> R² = 0.2510, MSE = 6.9036e-02
# X | LSG_1 -> R² = -0.1697, MSE = 1.1544e-01
# X | LSG_2 -> R² = -1.4757, MSE = 2.1095e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 1.219293 | Val Loss 0.502568
# Epoch 100 | Train Loss 0.049807 | Val Loss 0.057237
# Epoch 200 | Train Loss 0.038132 | Val Loss 0.051089
# Epoch 300 | Train Loss 0.034385 | Val Loss 0.046947
# Epoch 400 | Train Loss 0.030589 | Val Loss 0.046254
# Epoch 500 | Train Loss 0.029330 | Val Loss 0.055427
# Epoch 600 | Train Loss 0.027856 | Val Loss 0.077969
# Early stopping at epoch 623
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9880, MSE = 1.2457e-03
# X | Train_2 -> R² = 0.9487, MSE = 4.2660e-03
# X | Val_1 -> R² = 0.9536, MSE = 4.6591e-03
# X | Val_2 -> R² = 0.9617, MSE = 3.1095e-03
# X | Test_1 -> R² = -1.1538, MSE = 1.9178e-01
# X | Test_2 -> R² = 0.6815, MSE = 2.9358e-02
# X | LSG_1 -> R² = 0.2739, MSE = 7.1664e-02
# X | LSG_2 -> R² = -0.4846, MSE = 1.2650e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 1.264134 | Val Loss 0.532522
# Epoch 100 | Train Loss 0.050934 | Val Loss 0.066805
# Epoch 200 | Train Loss 0.039767 | Val Loss 0.052985
# Epoch 300 | Train Loss 0.032348 | Val Loss 0.075525
# Early stopping at epoch 399
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9882, MSE = 1.2200e-03
# X | Train_2 -> R² = 0.9877, MSE = 1.0201e-03
# X | Val_1 -> R² = 0.9595, MSE = 4.0626e-03
# X | Val_2 -> R² = -0.4498, MSE = 1.1764e-01
# X | Test_1 -> R² = -1.9526, MSE = 2.6291e-01
# X | Test_2 -> R² = -0.1711, MSE = 1.0795e-01
# X | LSG_1 -> R² = -5.1645, MSE = 6.0838e-01
# X | LSG_2 -> R² = -3.8943, MSE = 4.1703e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 0.916393 | Val Loss 0.396453
# Epoch 100 | Train Loss 0.049582 | Val Loss 0.048320
# Epoch 200 | Train Loss 0.039210 | Val Loss 0.044849
# Epoch 300 | Train Loss 0.034324 | Val Loss 0.045088
# Epoch 400 | Train Loss 0.030815 | Val Loss 0.041980
# Epoch 500 | Train Loss 0.029524 | Val Loss 0.046165
# Early stopping at epoch 556
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9717, MSE = 2.9244e-03
# X | Train_2 -> R² = 0.9848, MSE = 1.2669e-03
# X | Val_1 -> R² = 0.8751, MSE = 1.2534e-02
# X | Val_2 -> R² = 0.5591, MSE = 3.5772e-02
# X | Test_1 -> R² = -1.4140, MSE = 2.1495e-01
# X | Test_2 -> R² = 0.4034, MSE = 5.4985e-02
# X | LSG_1 -> R² = -0.9312, MSE = 1.9059e-01
# X | LSG_2 -> R² = -1.3688, MSE = 2.0184e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4951 salvo.
# Epoch 0 | Train Loss 1.672098 | Val Loss 0.375315
# Epoch 100 | Train Loss 0.065933 | Val Loss 0.047438
# Epoch 200 | Train Loss 0.051666 | Val Loss 0.035961
# Epoch 300 | Train Loss 0.045827 | Val Loss 0.032152
# Epoch 400 | Train Loss 0.040952 | Val Loss 0.036125
# Early stopping at epoch 472
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9422, MSE = 5.9772e-03
# X | Train_2 -> R² = 0.9269, MSE = 6.0780e-03
# X | Val_1 -> R² = 0.9752, MSE = 2.4928e-03
# X | Val_2 -> R² = 0.4633, MSE = 4.3549e-02
# X | Test_1 -> R² = -3.0181, MSE = 3.5778e-01
# X | Test_2 -> R² = -0.6271, MSE = 1.4997e-01
# X | LSG_1 -> R² = -1.0752, MSE = 2.0480e-01
# X | LSG_2 -> R² = -0.5005, MSE = 1.2785e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 1.428675 | Val Loss 0.341366
# Epoch 100 | Train Loss 0.071419 | Val Loss 0.071892
# Epoch 200 | Train Loss 0.053860 | Val Loss 0.059350
# Epoch 300 | Train Loss 0.044332 | Val Loss 0.069042
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.9934, MSE = 6.8577e-04
# X | Train_2 -> R² = 0.9861, MSE = 1.1581e-03
# X | Val_1 -> R² = 0.9748, MSE = 2.5345e-03
# X | Val_2 -> R² = -1.2474, MSE = 1.8235e-01
# X | Test_1 -> R² = -3.4916, MSE = 3.9995e-01
# X | Test_2 -> R² = -0.3127, MSE = 1.2099e-01
# X | LSG_1 -> R² = -1.8039, MSE = 2.7672e-01
# X | LSG_2 -> R² = -1.9746, MSE = 2.5346e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.701657 | Val Loss 0.413243
# Epoch 100 | Train Loss 0.063488 | Val Loss 0.056994
# Epoch 200 | Train Loss 0.048512 | Val Loss 0.037603
# Epoch 300 | Train Loss 0.045844 | Val Loss 0.031457
# Epoch 400 | Train Loss 0.039564 | Val Loss 0.033753
# Early stopping at epoch 500
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9941, MSE = 6.1011e-04
# X | Train_2 -> R² = 0.9934, MSE = 5.4717e-04
# X | Val_1 -> R² = 0.9892, MSE = 1.0863e-03
# X | Val_2 -> R² = 0.1961, MSE = 6.5232e-02
# X | Test_1 -> R² = -3.7587, MSE = 4.2373e-01
# X | Test_2 -> R² = 0.4869, MSE = 4.7291e-02
# X | LSG_1 -> R² = -2.2296, MSE = 3.1874e-01
# ...
# X | Val_2 -> R² = 0.6381, MSE = 2.9367e-02
# X | Test_1 -> R² = -1.2050, MSE = 1.9634e-01
# X | Test_2 -> R² = -0.0663, MSE = 9.8281e-02
# X | LSG_1 -> R² = -5.3790, MSE = 6.2955e-01
# X | LSG_2 -> R² = -4.4028, MSE = 4.6036e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 1.093283 | Val Loss 0.203316
# Epoch 100 | Train Loss 0.041914 | Val Loss 0.048974
# Epoch 200 | Train Loss 0.031429 | Val Loss 0.056651
# Epoch 300 | Train Loss 0.024442 | Val Loss 0.054112
# Early stopping at epoch 331
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9593, MSE = 4.2118e-03
# X | Train_2 -> R² = 0.9882, MSE = 9.8161e-04
# X | Val_1 -> R² = 0.9651, MSE = 3.5015e-03
# X | Val_2 -> R² = 0.9474, MSE = 4.2700e-03
# X | Test_1 -> R² = -4.5028, MSE = 4.8998e-01
# X | Test_2 -> R² = -2.3812, MSE = 3.1165e-01
# X | LSG_1 -> R² = -2.8095, MSE = 3.7597e-01
# X | LSG_2 -> R² = -3.6261, MSE = 3.9418e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.812306 | Val Loss 0.292860
# Epoch 100 | Train Loss 0.036164 | Val Loss 0.049544
# Epoch 200 | Train Loss 0.032914 | Val Loss 0.039112
# Epoch 300 | Train Loss 0.028064 | Val Loss 0.035603
# Epoch 400 | Train Loss 0.024976 | Val Loss 0.035554
# Epoch 500 | Train Loss 0.023663 | Val Loss 0.042159
# Early stopping at epoch 546
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9875, MSE = 1.2876e-03
# X | Train_2 -> R² = 0.9702, MSE = 2.4757e-03
# X | Val_1 -> R² = 0.9336, MSE = 6.6672e-03
# X | Val_2 -> R² = 0.9747, MSE = 2.0529e-03
# X | Test_1 -> R² = -1.0212, MSE = 1.7997e-01
# X | Test_2 -> R² = 0.1154, MSE = 8.1536e-02
# X | LSG_1 -> R² = -1.9780, MSE = 2.9391e-01
# X | LSG_2 -> R² = -2.4813, MSE = 2.9663e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 1.409765 | Val Loss 0.208355
# Epoch 100 | Train Loss 0.033180 | Val Loss 0.032974
# Epoch 200 | Train Loss 0.100727 | Val Loss 0.083499
# Epoch 300 | Train Loss 0.034065 | Val Loss 0.049776
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9872, MSE = 1.3270e-03
# X | Train_2 -> R² = 0.6912, MSE = 2.5672e-02
# X | Val_1 -> R² = 0.9770, MSE = 2.3054e-03
# X | Val_2 -> R² = 0.9567, MSE = 3.5159e-03
# X | Test_1 -> R² = -1.3019, MSE = 2.0497e-01
# X | Test_2 -> R² = 0.0362, MSE = 8.8837e-02
# X | LSG_1 -> R² = -2.5257, MSE = 3.4795e-01
# X | LSG_2 -> R² = -2.0361, MSE = 2.5870e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 1.482229 | Val Loss 0.190792
# Epoch 100 | Train Loss 0.035941 | Val Loss 0.037477
# Epoch 200 | Train Loss 0.027227 | Val Loss 0.045678
# Epoch 300 | Train Loss 0.027126 | Val Loss 0.049673
# Epoch 400 | Train Loss 0.027894 | Val Loss 0.037348
# Epoch 500 | Train Loss 0.026425 | Val Loss 0.056962
# Early stopping at epoch 529
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9777, MSE = 2.3052e-03
# X | Train_2 -> R² = 0.9864, MSE = 1.1305e-03
# X | Val_1 -> R² = 0.9889, MSE = 1.1161e-03
# X | Val_2 -> R² = 0.9451, MSE = 4.4567e-03
# X | Test_1 -> R² = -3.5229, MSE = 4.0274e-01
# X | Test_2 -> R² = -0.5052, MSE = 1.3873e-01
# X | LSG_1 -> R² = 0.2342, MSE = 7.5581e-02
# X | LSG_2 -> R² = -0.8366, MSE = 1.5649e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 1.540989 | Val Loss 0.254926
# Epoch 100 | Train Loss 0.037977 | Val Loss 0.034996
# Epoch 200 | Train Loss 0.031584 | Val Loss 0.039295
# Epoch 300 | Train Loss 0.030218 | Val Loss 0.033520
# Epoch 400 | Train Loss 0.052461 | Val Loss 0.076282
# Early stopping at epoch 471
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5848.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed5848.weights.h5
# X | Train_1 -> R² = 0.9744, MSE = 2.6483e-03
# X | Train_2 -> R² = 0.9695, MSE = 2.5357e-03
# X | Val_1 -> R² = 0.9808, MSE = 1.9265e-03
# X | Val_2 -> R² = 0.8030, MSE = 1.5983e-02
# X | Test_1 -> R² = -3.7996, MSE = 4.2737e-01
# X | Test_2 -> R² = -0.8684, MSE = 1.7221e-01
# X | LSG_1 -> R² = -3.4351, MSE = 4.3770e-01
# X | LSG_2 -> R² = -3.3618, MSE = 3.7166e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 1.602058 | Val Loss 0.232905
# Epoch 100 | Train Loss 0.041163 | Val Loss 0.045751
# Epoch 200 | Train Loss 0.041185 | Val Loss 0.039468
# Epoch 300 | Train Loss 0.027481 | Val Loss 0.034020
# Epoch 400 | Train Loss 0.027385 | Val Loss 0.041663
# Early stopping at epoch 488
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3485.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3485.weights.h5
# X | Train_1 -> R² = 0.9861, MSE = 1.4418e-03
# X | Train_2 -> R² = 0.6395, MSE = 2.9967e-02
# X | Val_1 -> R² = 0.9733, MSE = 2.6852e-03
# X | Val_2 -> R² = 0.9893, MSE = 8.6444e-04
# X | Test_1 -> R² = -0.8158, MSE = 1.6169e-01
# X | Test_2 -> R² = 0.5520, MSE = 4.1291e-02
# X | LSG_1 -> R² = 0.2699, MSE = 7.2054e-02
# X | LSG_2 -> R² = 0.3305, MSE = 5.7048e-02
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 1.152890 | Val Loss 0.246230
# Epoch 100 | Train Loss 0.039198 | Val Loss 0.044284
# Epoch 200 | Train Loss 0.038375 | Val Loss 0.041867
# Epoch 300 | Train Loss 0.038657 | Val Loss 0.086830
# Early stopping at epoch 340
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2277.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed2277.weights.h5
# X | Train_1 -> R² = 0.9878, MSE = 1.2583e-03
# X | Train_2 -> R² = 0.9951, MSE = 4.0511e-04
# X | Val_1 -> R² = 0.8791, MSE = 1.2140e-02
# X | Val_2 -> R² = 0.7703, MSE = 1.8641e-02
# X | Test_1 -> R² = -0.9648, MSE = 1.7495e-01
# X | Test_2 -> R² = 0.4413, MSE = 5.1500e-02
# X | LSG_1 -> R² = -1.1493, MSE = 2.1211e-01
# X | LSG_2 -> R² = -1.6648, MSE = 2.2706e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 1.331155 | Val Loss 0.205429
# Epoch 100 | Train Loss 0.035363 | Val Loss 0.049126
# Epoch 200 | Train Loss 0.028775 | Val Loss 0.042924
# Epoch 300 | Train Loss 0.025907 | Val Loss 0.044317
# Early stopping at epoch 362
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3227.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3227.weights.h5
# X | Train_1 -> R² = 0.9020, MSE = 1.0130e-02
# X | Train_2 -> R² = 0.9384, MSE = 5.1241e-03
# X | Val_1 -> R² = 0.7229, MSE = 2.7821e-02
# X | Val_2 -> R² = 0.8579, MSE = 1.1528e-02
# X | Test_1 -> R² = -0.2472, MSE = 1.1105e-01
# X | Test_2 -> R² = -0.0009, MSE = 9.2256e-02
# X | LSG_1 -> R² = -2.8789, MSE = 3.8282e-01
# X | LSG_2 -> R² = -2.8788, MSE = 3.3050e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 1.469800 | Val Loss 0.199183
# Epoch 100 | Train Loss 0.030259 | Val Loss 0.035646
# Epoch 200 | Train Loss 0.029970 | Val Loss 0.047093
# Epoch 300 | Train Loss 0.045507 | Val Loss 0.067639
# Early stopping at epoch 304
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4951.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4951.weights.h5
# X | Train_1 -> R² = 0.9778, MSE = 2.2918e-03
# X | Train_2 -> R² = 0.9806, MSE = 1.6091e-03
# X | Val_1 -> R² = 0.9444, MSE = 5.5823e-03
# X | Val_2 -> R² = 0.9846, MSE = 1.2466e-03
# X | Test_1 -> R² = -0.2680, MSE = 1.1291e-01
# X | Test_2 -> R² = 0.2753, MSE = 6.6797e-02
# X | LSG_1 -> R² = -2.4403, MSE = 3.3953e-01
# X | LSG_2 -> R² = -2.7943, MSE = 3.2330e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4951 salvo.
# Epoch 0 | Train Loss 2.045094 | Val Loss 0.189991
# Epoch 100 | Train Loss 0.048452 | Val Loss 0.047325
# Epoch 200 | Train Loss 0.074600 | Val Loss 0.041594
# Epoch 300 | Train Loss 0.061201 | Val Loss 0.030627
# Early stopping at epoch 369
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9938, MSE = 6.3767e-04
# X | Train_2 -> R² = 0.9960, MSE = 3.3507e-04
# X | Val_1 -> R² = 0.9497, MSE = 5.0519e-03
# X | Val_2 -> R² = 0.8797, MSE = 9.7575e-03
# X | Test_1 -> R² = -1.5817, MSE = 2.2989e-01
# X | Test_2 -> R² = 0.3028, MSE = 6.4264e-02
# X | LSG_1 -> R² = -0.4068, MSE = 1.3884e-01
# X | LSG_2 -> R² = -0.8980, MSE = 1.6172e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5848 salvo.
# Epoch 0 | Train Loss 1.995096 | Val Loss 0.197801
# Epoch 100 | Train Loss 0.056974 | Val Loss 0.036154
# Epoch 200 | Train Loss 0.032002 | Val Loss 0.030546
# Epoch 300 | Train Loss 0.027507 | Val Loss 0.028991
# Epoch 400 | Train Loss 0.124063 | Val Loss 0.054082
# Early stopping at epoch 426
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.9746, MSE = 2.6297e-03
# X | Train_2 -> R² = 0.9759, MSE = 2.0032e-03
# X | Val_1 -> R² = 0.9808, MSE = 1.9307e-03
# X | Val_2 -> R² = 0.8686, MSE = 1.0661e-02
# X | Test_1 -> R² = -0.6556, MSE = 1.4742e-01
# X | Test_2 -> R² = 0.0601, MSE = 8.6629e-02
# X | LSG_1 -> R² = -1.5504, MSE = 2.5170e-01
# X | LSG_2 -> R² = -1.7668, MSE = 2.3575e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3485 salvo.
# Epoch 0 | Train Loss 1.844025 | Val Loss 0.191081
# Epoch 100 | Train Loss 0.049612 | Val Loss 0.029638
# Epoch 200 | Train Loss 0.040749 | Val Loss 0.025315
# Epoch 300 | Train Loss 0.057821 | Val Loss 0.035030
# Epoch 400 | Train Loss 0.027629 | Val Loss 0.033532
# Early stopping at epoch 404
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9361, MSE = 6.6030e-03
# X | Train_2 -> R² = 0.9543, MSE = 3.8000e-03
# X | Val_1 -> R² = 0.9670, MSE = 3.3085e-03
# X | Val_2 -> R² = 0.9806, MSE = 1.5742e-03
# X | Test_1 -> R² = -1.5229, MSE = 2.2465e-01
# X | Test_2 -> R² = 0.2582, MSE = 6.8371e-02
# X | LSG_1 -> R² = -2.6239, MSE = 3.5765e-01
# X | LSG_2 -> R² = -2.1599, MSE = 2.6925e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2277 salvo.
# Epoch 0 | Train Loss 1.272246 | Val Loss 0.162644
# Epoch 100 | Train Loss 0.043215 | Val Loss 0.024302
# Epoch 200 | Train Loss 0.034553 | Val Loss 0.027971
# Epoch 300 | Train Loss 0.025766 | Val Loss 0.025538
# Early stopping at epoch 319
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3227.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3227.weights.h5
# X | Train_1 -> R² = 0.9942, MSE = 5.9536e-04
# X | Train_2 -> R² = 0.9895, MSE = 8.7050e-04
# X | Val_1 -> R² = 0.9280, MSE = 7.2326e-03
# X | Val_2 -> R² = 0.8620, MSE = 1.1199e-02
# X | Test_1 -> R² = -0.7138, MSE = 1.5260e-01
# X | Test_2 -> R² = 0.4977, MSE = 4.6298e-02
# X | LSG_1 -> R² = -0.6583, MSE = 1.6366e-01
# X | LSG_2 -> R² = -1.3816, MSE = 2.0293e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3227 salvo.
# Epoch 0 | Train Loss 1.485549 | Val Loss 0.172676
# Epoch 100 | Train Loss 0.055930 | Val Loss 0.044599
# Epoch 200 | Train Loss 0.044414 | Val Loss 0.035141
# Epoch 300 | Train Loss 0.042656 | Val Loss 0.039756
# Epoch 400 | Train Loss 0.026815 | Val Loss 0.038672
# Early stopping at epoch 448
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4951.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4951.weights.h5
# X | Train_1 -> R² = 0.9662, MSE = 3.4969e-03
# X | Train_2 -> R² = 0.9715, MSE = 2.3717e-03
# X | Val_1 -> R² = 0.9599, MSE = 4.0264e-03
# X | Val_2 -> R² = 0.9814, MSE = 1.5080e-03
# X | Test_1 -> R² = -1.1914, MSE = 1.9513e-01
# X | Test_2 -> R² = 0.4751, MSE = 4.8377e-02
# X | LSG_1 -> R² = -2.2940, MSE = 3.2509e-01
# X | LSG_2 -> R² = -2.2572, MSE = 2.7754e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4951 salvo.
# Epoch 0 | Train Loss 2.504484 | Val Loss 0.296896
# Epoch 100 | Train Loss 0.052282 | Val Loss 0.040592
# Epoch 200 | Train Loss 0.059030 | Val Loss 0.067182
# Epoch 300 | Train Loss 0.036018 | Val Loss 0.055218
# Early stopping at epoch 386
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5848.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed5848.weights.h5
# X | Train_1 -> R² = 0.9773, MSE = 2.3521e-03
# X | Train_2 -> R² = 0.9972, MSE = 2.3346e-04
# X | Val_1 -> R² = 0.9486, MSE = 5.1596e-03
# X | Val_2 -> R² = 0.6277, MSE = 3.0208e-02
# X | Test_1 -> R² = -1.5351, MSE = 2.2574e-01
# X | Test_2 -> R² = 0.2721, MSE = 6.7093e-02
# X | LSG_1 -> R² = -3.1285, MSE = 4.0745e-01
# X | LSG_2 -> R² = -3.3912, MSE = 3.7416e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5848 salvo.
# Epoch 0 | Train Loss 2.166529 | Val Loss 0.251674
# Epoch 100 | Train Loss 0.041161 | Val Loss 0.026064
# Epoch 200 | Train Loss 0.045402 | Val Loss 0.025607
# Epoch 300 | Train Loss 0.031393 | Val Loss 0.032649
# Epoch 400 | Train Loss 0.056720 | Val Loss 0.029301
# Epoch 500 | Train Loss 0.036945 | Val Loss 0.027790
# Epoch 600 | Train Loss 0.026590 | Val Loss 0.023094
# Early stopping at epoch 610
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3485.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3485.weights.h5
# X | Train_1 -> R² = 0.9643, MSE = 3.6891e-03
# X | Train_2 -> R² = 0.9830, MSE = 1.4091e-03
# X | Val_1 -> R² = 0.9465, MSE = 5.3743e-03
# X | Val_2 -> R² = 0.9310, MSE = 5.6009e-03
# X | Test_1 -> R² = -0.8815, MSE = 1.6754e-01
# X | Test_2 -> R² = 0.2336, MSE = 7.0642e-02
# X | LSG_1 -> R² = -9.5269, MSE = 1.0389e+00
# X | LSG_2 -> R² = -7.6272, MSE = 7.3510e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3485 salvo.
# Epoch 0 | Train Loss 1.856653 | Val Loss 0.206955
# Epoch 100 | Train Loss 0.046305 | Val Loss 0.037320
# Epoch 200 | Train Loss 0.038953 | Val Loss 0.044799
# Epoch 300 | Train Loss 0.061147 | Val Loss 0.029922
# Early stopping at epoch 349
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2277.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed2277.weights.h5
# X | Train_1 -> R² = 0.9457, MSE = 5.6166e-03
# X | Train_2 -> R² = 0.9939, MSE = 5.0397e-04
# X | Val_1 -> R² = 0.9643, MSE = 3.5882e-03
# X | Val_2 -> R² = 0.9406, MSE = 4.8221e-03
# X | Test_1 -> R² = -2.1358, MSE = 2.7922e-01
# X | Test_2 -> R² = 0.4248, MSE = 5.3018e-02
# X | LSG_1 -> R² = -0.2634, MSE = 1.2468e-01
# X | LSG_2 -> R² = -0.6652, MSE = 1.4189e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2277 salvo.
# Epoch 0 | Train Loss 2.008409 | Val Loss 0.204686
# Epoch 100 | Train Loss 0.101668 | Val Loss 0.055771
# Epoch 200 | Train Loss 0.033357 | Val Loss 0.026181
# Epoch 300 | Train Loss 0.031471 | Val Loss 0.032118
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3227.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3227.weights.h5
# X | Train_1 -> R² = 0.9885, MSE = 1.1876e-03
# X | Train_2 -> R² = 0.9953, MSE = 3.9218e-04
# X | Val_1 -> R² = 0.9949, MSE = 5.1124e-04
# X | Val_2 -> R² = 0.6268, MSE = 3.0278e-02
# X | Test_1 -> R² = -2.2380, MSE = 2.8832e-01
# X | Test_2 -> R² = 0.6155, MSE = 3.5442e-02
# X | LSG_1 -> R² = -0.4364, MSE = 1.4176e-01
# X | LSG_2 -> R² = -1.5238, MSE = 2.1505e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3227 salvo.
# Epoch 0 | Train Loss 1.249223 | Val Loss 0.135238
# Epoch 100 | Train Loss 0.046852 | Val Loss 0.026591
# Epoch 200 | Train Loss 0.065514 | Val Loss 0.051093
# Epoch 300 | Train Loss 0.047053 | Val Loss 0.029906
# Early stopping at epoch 352
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4951.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4951.weights.h5
# X | Train_1 -> R² = 0.9368, MSE = 6.5353e-03
# X | Train_2 -> R² = 0.9955, MSE = 3.7259e-04
# X | Val_1 -> R² = 0.9773, MSE = 2.2748e-03
# X | Val_2 -> R² = 0.8247, MSE = 1.4220e-02
# X | Test_1 -> R² = -2.1191, MSE = 2.7774e-01
# X | Test_2 -> R² = -0.0305, MSE = 9.4979e-02
# X | LSG_1 -> R² = -4.3409, MSE = 5.2710e-01
# X | LSG_2 -> R² = -3.5099, MSE = 3.8427e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4951 salvo.
