# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 3
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 3, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 10  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[64], [128], [264],
                 [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
                 [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64] ] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 Loss 1.559308
# Epoch 50 Loss 1.310185
# Epoch 100 Loss 1.293507
# Epoch 150 Loss 1.284001
# Epoch 200 Loss 1.280573
# Epoch 250 Loss 1.277724
# Epoch 300 Loss 1.274126
# Epoch 350 Loss 1.268829
# Early stopping at epoch 356
# Theta | train1 -> R² = 0.8125, MSE = 4.2800e-02
# X | train1 -> R² = -0.3986, MSE = 1.5080e-01
# Y | train1 -> R² = -0.9791, MSE = 1.6584e-01
# Theta | train2 -> R² = 0.1701, MSE = 1.8946e-01
# X | train2 -> R² = -0.2949, MSE = 1.0911e-01
# Y | train2 -> R² = -0.9107, MSE = 2.0574e-01
# Theta | test1 -> R² = 0.7471, MSE = 5.8097e-02
# X | test1 -> R² = -0.4938, MSE = 1.5649e-01
# Y | test1 -> R² = -1.1955, MSE = 1.7992e-01
# Theta | test2 -> R² = 0.1755, MSE = 1.9555e-01
# X | test2 -> R² = -0.2967, MSE = 1.0671e-01
# Y | test2 -> R² = -0.8800, MSE = 1.9955e-01
# Theta | test3 -> R² = 0.2376, MSE = 2.5064e-01
# X | test3 -> R² = -0.5007, MSE = 1.3807e-01
# Y | test3 -> R² = -1.4439, MSE = 1.8771e-01
# Theta | val -> R² = 0.5558, MSE = 1.4539e-01
# X | val -> R² = -0.5628, MSE = 1.4944e-01
# Y | val -> R² = -1.4409, MSE = 1.8172e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.573532
# Epoch 50 Loss 1.302668
# Epoch 100 Loss 1.283025
# Epoch 150 Loss 1.280643
# Epoch 200 Loss 1.278840
# Epoch 250 Loss 1.276907
# Epoch 300 Loss 1.272802
# Epoch 350 Loss 1.269830
# Early stopping at epoch 375
# Theta | train1 -> R² = 0.8230, MSE = 4.0402e-02
# X | train1 -> R² = -0.2533, MSE = 1.3514e-01
# Y | train1 -> R² = -0.8925, MSE = 1.5858e-01
# Theta | train2 -> R² = 0.3349, MSE = 1.5184e-01
# X | train2 -> R² = -0.2502, MSE = 1.0534e-01
# Y | train2 -> R² = -0.8412, MSE = 1.9826e-01
# Theta | test1 -> R² = 0.6420, MSE = 8.2248e-02
# X | test1 -> R² = -0.3360, MSE = 1.3996e-01
# Y | test1 -> R² = -1.0906, MSE = 1.7132e-01
# Theta | test2 -> R² = 0.3578, MSE = 1.5230e-01
# X | test2 -> R² = -0.2441, MSE = 1.0238e-01
# Y | test2 -> R² = -0.7923, MSE = 1.9024e-01
# Theta | test3 -> R² = 0.6461, MSE = 1.1635e-01
# X | test3 -> R² = -0.4537, MSE = 1.3375e-01
# Y | test3 -> R² = -1.7627, MSE = 2.1219e-01
# Theta | val -> R² = 0.7453, MSE = 8.3345e-02
# X | val -> R² = -0.4803, MSE = 1.4155e-01
# Y | val -> R² = -1.6981, MSE = 2.0088e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.576498
# Epoch 50 Loss 1.310862
# Epoch 100 Loss 1.285805
# Epoch 150 Loss 1.278505
# Epoch 200 Loss 1.275035
# Epoch 250 Loss 1.271231
# Epoch 300 Loss 1.266658
# Epoch 350 Loss 1.261607
# Early stopping at epoch 373
# Theta | train1 -> R² = 0.8538, MSE = 3.3365e-02
# X | train1 -> R² = -0.2433, MSE = 1.3406e-01
# Y | train1 -> R² = -0.9667, MSE = 1.6480e-01
# Theta | train2 -> R² = 0.4619, MSE = 1.2285e-01
# X | train2 -> R² = -0.1778, MSE = 9.9242e-02
# Y | train2 -> R² = -0.8900, MSE = 2.0351e-01
# Theta | test1 -> R² = 0.7100, MSE = 6.6621e-02
# X | test1 -> R² = -0.3412, MSE = 1.4050e-01
# Y | test1 -> R² = -1.1782, MSE = 1.7850e-01
# Theta | test2 -> R² = 0.4710, MSE = 1.2546e-01
# X | test2 -> R² = -0.1804, MSE = 9.7137e-02
# Y | test2 -> R² = -0.8592, MSE = 1.9734e-01
# Theta | test3 -> R² = -0.2548, MSE = 4.1251e-01
# X | test3 -> R² = -0.2946, MSE = 1.1911e-01
# Y | test3 -> R² = -1.2633, MSE = 1.7384e-01
# Theta | val -> R² = 0.3876, MSE = 2.0042e-01
# X | val -> R² = -0.3311, MSE = 1.2729e-01
# Y | val -> R² = -1.2863, MSE = 1.7022e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.571307
# Epoch 50 Loss 1.310727
# Epoch 100 Loss 1.295081
# Epoch 150 Loss 1.285447
# Epoch 200 Loss 1.281024
# Epoch 250 Loss 1.279336
# Epoch 300 Loss 1.279019
# Early stopping at epoch 336
# Theta | train1 -> R² = 0.7490, MSE = 5.7287e-02
# X | train1 -> R² = -0.2176, MSE = 1.3129e-01
# Y | train1 -> R² = -0.7853, MSE = 1.4960e-01
# Theta | train2 -> R² = 0.0912, MSE = 2.0748e-01
# X | train2 -> R² = -0.1416, MSE = 9.6191e-02
# Y | train2 -> R² = -0.6900, MSE = 1.8197e-01
# Theta | test1 -> R² = 0.5885, MSE = 9.4532e-02
# X | test1 -> R² = -0.2836, MSE = 1.3447e-01
# Y | test1 -> R² = -0.9450, MSE = 1.5939e-01
# Theta | test2 -> R² = 0.1067, MSE = 2.1185e-01
# X | test2 -> R² = -0.1442, MSE = 9.4162e-02
# Y | test2 -> R² = -0.6485, MSE = 1.7498e-01
# Theta | test3 -> R² = 0.2154, MSE = 2.5794e-01
# X | test3 -> R² = -0.3420, MSE = 1.2347e-01
# Y | test3 -> R² = -1.2639, MSE = 1.7388e-01
# Theta | val -> R² = 0.4589, MSE = 1.7710e-01
# X | val -> R² = -0.4020, MSE = 1.3407e-01
# Y | val -> R² = -1.2574, MSE = 1.6806e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568071
# Epoch 50 Loss 1.302935
# Epoch 100 Loss 1.281860
# Epoch 150 Loss 1.274430
# Epoch 200 Loss 1.267454
# Epoch 250 Loss 1.262083
# Epoch 300 Loss 1.259595
# Early stopping at epoch 343
# Theta | train1 -> R² = 0.8185, MSE = 4.1437e-02
# X | train1 -> R² = -0.2533, MSE = 1.3514e-01
# Y | train1 -> R² = -0.8939, MSE = 1.5870e-01
# Theta | train2 -> R² = 0.5167, MSE = 1.1035e-01
# X | train2 -> R² = -0.2227, MSE = 1.0303e-01
# Y | train2 -> R² = -0.8680, MSE = 2.0114e-01
# Theta | test1 -> R² = 0.6232, MSE = 8.6569e-02
# X | test1 -> R² = -0.3349, MSE = 1.3985e-01
# Y | test1 -> R² = -1.0669, MSE = 1.6938e-01
# Theta | test2 -> R² = 0.5252, MSE = 1.1260e-01
# X | test2 -> R² = -0.2146, MSE = 9.9957e-02
# Y | test2 -> R² = -0.8185, MSE = 1.9302e-01
# Theta | test3 -> R² = -0.0586, MSE = 3.4800e-01
# X | test3 -> R² = -0.3563, MSE = 1.2479e-01
# Y | test3 -> R² = -1.3516, MSE = 1.8062e-01
# Theta | val -> R² = 0.4712, MSE = 1.7307e-01
# X | val -> R² = -0.3828, MSE = 1.3222e-01
# Y | val -> R² = -1.3363, MSE = 1.7394e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.572008
# Epoch 50 Loss 1.316418
# Epoch 100 Loss 1.286729
# Epoch 150 Loss 1.280268
# Epoch 200 Loss 1.276096
# Epoch 250 Loss 1.271897
# Epoch 300 Loss 1.267523
# Epoch 350 Loss 1.262560
# Early stopping at epoch 363
# Theta | train1 -> R² = 0.7964, MSE = 4.6468e-02
# X | train1 -> R² = -0.2656, MSE = 1.3647e-01
# Y | train1 -> R² = -1.0315, MSE = 1.7023e-01
# Theta | train2 -> R² = 0.3164, MSE = 1.5607e-01
# X | train2 -> R² = -0.1904, MSE = 1.0031e-01
# Y | train2 -> R² = -0.9821, MSE = 2.1342e-01
# Theta | test1 -> R² = 0.6278, MSE = 8.5492e-02
# X | test1 -> R² = -0.3692, MSE = 1.4344e-01
# Y | test1 -> R² = -1.2475, MSE = 1.8418e-01
# Theta | test2 -> R² = 0.3191, MSE = 1.6149e-01
# X | test2 -> R² = -0.1874, MSE = 9.7716e-02
# Y | test2 -> R² = -0.9404, MSE = 2.0596e-01
# Theta | test3 -> R² = -0.0633, MSE = 3.4957e-01
# X | test3 -> R² = -0.3033, MSE = 1.1991e-01
# Y | test3 -> R² = -1.1719, MSE = 1.6682e-01
# Theta | val -> R² = 0.4453, MSE = 1.8156e-01
# X | val -> R² = -0.3426, MSE = 1.2839e-01
# Y | val -> R² = -1.2214, MSE = 1.6538e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.577311
# Epoch 50 Loss 1.309763
# Epoch 100 Loss 1.297993
# Epoch 150 Loss 1.285081
# Epoch 200 Loss 1.277538
# Epoch 250 Loss 1.271486
# Epoch 300 Loss 1.264934
# Early stopping at epoch 330
# Theta | train1 -> R² = 0.7443, MSE = 5.8369e-02
# X | train1 -> R² = 0.0241, MSE = 1.0523e-01
# Y | train1 -> R² = -0.9693, MSE = 1.6502e-01
# Theta | train2 -> R² = 0.0986, MSE = 2.0579e-01
# X | train2 -> R² = 0.0055, MSE = 8.3794e-02
# Y | train2 -> R² = -0.8809, MSE = 2.0254e-01
# Theta | test1 -> R² = 0.7133, MSE = 6.5865e-02
# X | test1 -> R² = -0.0503, MSE = 1.1003e-01
# Y | test1 -> R² = -1.1618, MSE = 1.7716e-01
# Theta | test2 -> R² = 0.1163, MSE = 2.0957e-01
# X | test2 -> R² = -0.0050, MSE = 8.2707e-02
# Y | test2 -> R² = -0.8474, MSE = 1.9609e-01
# Theta | test3 -> R² = 0.1668, MSE = 2.7392e-01
# X | test3 -> R² = -0.1148, MSE = 1.0256e-01
# Y | test3 -> R² = -1.2348, MSE = 1.7165e-01
# Theta | val -> R² = 0.4993, MSE = 1.6387e-01
# X | val -> R² = -0.1237, MSE = 1.0745e-01
# Y | val -> R² = -1.2908, MSE = 1.7055e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.571128
# Epoch 50 Loss 1.302849
# Epoch 100 Loss 1.281110
# Epoch 150 Loss 1.278245
# Epoch 200 Loss 1.275796
# Epoch 250 Loss 1.271604
# Epoch 300 Loss 1.268482
# Epoch 350 Loss 1.265265
# Early stopping at epoch 392
# Theta | train1 -> R² = 0.8537, MSE = 3.3391e-02
# X | train1 -> R² = -0.1908, MSE = 1.2840e-01
# Y | train1 -> R² = -0.9105, MSE = 1.6009e-01
# Theta | train2 -> R² = 0.4070, MSE = 1.3537e-01
# X | train2 -> R² = -0.2085, MSE = 1.0183e-01
# Y | train2 -> R² = -0.8831, MSE = 2.0277e-01
# Theta | test1 -> R² = 0.7574, MSE = 5.5723e-02
# X | test1 -> R² = -0.2461, MSE = 1.3054e-01
# Y | test1 -> R² = -1.0900, MSE = 1.7127e-01
# Theta | test2 -> R² = 0.4403, MSE = 1.3273e-01
# X | test2 -> R² = -0.2018, MSE = 9.8899e-02
# Y | test2 -> R² = -0.8309, MSE = 1.9434e-01
# Theta | test3 -> R² = 0.3013, MSE = 2.2969e-01
# X | test3 -> R² = -0.3593, MSE = 1.2506e-01
# Y | test3 -> R² = -1.8999, MSE = 2.2273e-01
# Theta | val -> R² = 0.6823, MSE = 1.0396e-01
# X | val -> R² = -0.3759, MSE = 1.3157e-01
# Y | val -> R² = -1.7318, MSE = 2.0338e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.555477
# Epoch 50 Loss 1.309913
# Epoch 100 Loss 1.299668
# Epoch 150 Loss 1.284303
# Epoch 200 Loss 1.276627
# Epoch 250 Loss 1.273736
# Epoch 300 Loss 1.269425
# Early stopping at epoch 337
# Theta | train1 -> R² = 0.8302, MSE = 3.8758e-02
# X | train1 -> R² = -0.0815, MSE = 1.1662e-01
# Y | train1 -> R² = -0.6758, MSE = 1.4043e-01
# Theta | train2 -> R² = 0.5020, MSE = 1.1370e-01
# X | train2 -> R² = -0.1938, MSE = 1.0059e-01
# Y | train2 -> R² = -0.5755, MSE = 1.6965e-01
# Theta | test1 -> R² = 0.6271, MSE = 8.5659e-02
# X | test1 -> R² = -0.2069, MSE = 1.2644e-01
# Y | test1 -> R² = -0.8818, MSE = 1.5421e-01
# Theta | test2 -> R² = 0.5104, MSE = 1.1611e-01
# X | test2 -> R² = -0.1910, MSE = 9.8013e-02
# Y | test2 -> R² = -0.5463, MSE = 1.6413e-01
# Theta | test3 -> R² = 0.4760, MSE = 1.7227e-01
# X | test3 -> R² = -0.1785, MSE = 1.0843e-01
# Y | test3 -> R² = -0.7734, MSE = 1.3621e-01
# Theta | val -> R² = 0.7033, MSE = 9.7115e-02
# X | val -> R² = -0.2068, MSE = 1.1540e-01
# Y | val -> R² = -0.8542, MSE = 1.3805e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.575167
# Epoch 50 Loss 1.305517
# Epoch 100 Loss 1.289560
# Epoch 150 Loss 1.280093
# Epoch 200 Loss 1.278049
# Epoch 250 Loss 1.274144
# Epoch 300 Loss 1.269835
# Early stopping at epoch 332
# Theta | train1 -> R² = 0.7970, MSE = 4.6342e-02
# X | train1 -> R² = -0.0337, MSE = 1.1146e-01
# Y | train1 -> R² = -0.8826, MSE = 1.5776e-01
# Theta | train2 -> R² = 0.2264, MSE = 1.7661e-01
# X | train2 -> R² = 0.0072, MSE = 8.3650e-02
# Y | train2 -> R² = -0.7079, MSE = 1.8390e-01
# Theta | test1 -> R² = 0.6597, MSE = 7.8175e-02
# X | test1 -> R² = -0.1027, MSE = 1.1552e-01
# Y | test1 -> R² = -1.0526, MSE = 1.6821e-01
# Theta | test2 -> R² = 0.2337, MSE = 1.8173e-01
# X | test2 -> R² = 0.0002, MSE = 8.2276e-02
# Y | test2 -> R² = -0.6714, MSE = 1.7741e-01
# Theta | test3 -> R² = 0.0808, MSE = 3.0218e-01
# X | test3 -> R² = -0.1540, MSE = 1.0617e-01
# Y | test3 -> R² = -1.1944, MSE = 1.6855e-01
# Theta | val -> R² = 0.4506, MSE = 1.7981e-01
# X | val -> R² = -0.1790, MSE = 1.1274e-01
# Y | val -> R² = -1.2700, MSE = 1.6900e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.568531
# Epoch 50 Loss 1.294922
# Epoch 100 Loss 1.281002
# Epoch 150 Loss 1.277077
# Epoch 200 Loss 1.267901
# Epoch 250 Loss 1.258314
# Epoch 300 Loss 1.249986
# Epoch 350 Loss 1.239814
# Early stopping at epoch 369
# Theta | train1 -> R² = 0.8440, MSE = 3.5606e-02
# X | train1 -> R² = -0.2138, MSE = 1.3088e-01
# Y | train1 -> R² = -0.9482, MSE = 1.6325e-01
# Theta | train2 -> R² = 0.4294, MSE = 1.3027e-01
# X | train2 -> R² = -0.1615, MSE = 9.7871e-02
# Y | train2 -> R² = -0.8567, MSE = 1.9993e-01
# Theta | test1 -> R² = 0.6914, MSE = 7.0892e-02
# X | test1 -> R² = -0.2955, MSE = 1.3572e-01
# Y | test1 -> R² = -1.1426, MSE = 1.7558e-01
# Theta | test2 -> R² = 0.4479, MSE = 1.3093e-01
# X | test2 -> R² = -0.1626, MSE = 9.5678e-02
# Y | test2 -> R² = -0.8167, MSE = 1.9283e-01
# Theta | test3 -> R² = 0.1313, MSE = 2.8557e-01
# X | test3 -> R² = -0.2783, MSE = 1.1761e-01
# Y | test3 -> R² = -1.3212, MSE = 1.7828e-01
# Theta | val -> R² = 0.5496, MSE = 1.4740e-01
# X | val -> R² = -0.3172, MSE = 1.2596e-01
# Y | val -> R² = -1.3136, MSE = 1.7225e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.543944
# Epoch 50 Loss 1.301041
# Epoch 100 Loss 1.281712
# Epoch 150 Loss 1.280051
# Epoch 200 Loss 1.277755
# Epoch 250 Loss 1.273740
# Epoch 300 Loss 1.268372
# Early stopping at epoch 320
# Theta | train1 -> R² = 0.6211, MSE = 8.6502e-02
# X | train1 -> R² = 0.2007, MSE = 8.6183e-02
# Y | train1 -> R² = -0.7695, MSE = 1.4828e-01
# Theta | train2 -> R² = 0.4643, MSE = 1.2230e-01
# X | train2 -> R² = 0.0266, MSE = 8.2022e-02
# Y | train2 -> R² = -0.5943, MSE = 1.7167e-01
# Theta | test1 -> R² = 0.2928, MSE = 1.6246e-01
# X | test1 -> R² = 0.1414, MSE = 8.9949e-02
# Y | test1 -> R² = -0.9576, MSE = 1.6042e-01
# Theta | test2 -> R² = 0.4182, MSE = 1.3798e-01
# X | test2 -> R² = 0.0155, MSE = 8.1014e-02
# Y | test2 -> R² = -0.5668, MSE = 1.6630e-01
# Theta | test3 -> R² = -0.4996, MSE = 4.9299e-01
# X | test3 -> R² = 0.0599, MSE = 8.6494e-02
# Y | test3 -> R² = -1.2015, MSE = 1.6909e-01
# Theta | val -> R² = 0.0773, MSE = 3.0197e-01
# X | val -> R² = 0.0789, MSE = 8.8076e-02
# Y | val -> R² = -1.2250, MSE = 1.6565e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.556756
# Epoch 50 Loss 1.302470
# Epoch 100 Loss 1.282131
# Epoch 150 Loss 1.279095
# Epoch 200 Loss 1.274857
# Epoch 250 Loss 1.270199
# Epoch 300 Loss 1.265578
# Epoch 350 Loss 1.258700
# Early stopping at epoch 371
# Theta | train1 -> R² = 0.8343, MSE = 3.7816e-02
# X | train1 -> R² = -0.2230, MSE = 1.3187e-01
# Y | train1 -> R² = -0.9348, MSE = 1.6213e-01
# Theta | train2 -> R² = 0.4668, MSE = 1.2174e-01
# X | train2 -> R² = -0.1716, MSE = 9.8720e-02
# Y | train2 -> R² = -0.8588, MSE = 2.0015e-01
# Theta | test1 -> R² = 0.6254, MSE = 8.6045e-02
# X | test1 -> R² = -0.3190, MSE = 1.3818e-01
# Y | test1 -> R² = -1.1561, MSE = 1.7669e-01
# Theta | test2 -> R² = 0.4761, MSE = 1.2424e-01
# X | test2 -> R² = -0.1724, MSE = 9.6480e-02
# Y | test2 -> R² = -0.8253, MSE = 1.9374e-01
# Theta | test3 -> R² = 0.3771, MSE = 2.0477e-01
# X | test3 -> R² = -0.3137, MSE = 1.2087e-01
# Y | test3 -> R² = -1.1078, MSE = 1.6190e-01
# Theta | val -> R² = 0.6370, MSE = 1.1881e-01
# X | val -> R² = -0.3529, MSE = 1.2937e-01
# Y | val -> R² = -1.1684, MSE = 1.6144e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.576710
# Epoch 50 Loss 1.298478
# Epoch 100 Loss 1.282779
# Epoch 150 Loss 1.278734
# Epoch 200 Loss 1.274920
# Epoch 250 Loss 1.269474
# Epoch 300 Loss 1.263099
# Early stopping at epoch 347
# Theta | train1 -> R² = 0.8427, MSE = 3.5903e-02
# X | train1 -> R² = -0.2032, MSE = 1.2973e-01
# Y | train1 -> R² = -0.9387, MSE = 1.6245e-01
# Theta | train2 -> R² = 0.1598, MSE = 1.9182e-01
# X | train2 -> R² = -0.1267, MSE = 9.4933e-02
# Y | train2 -> R² = -0.8356, MSE = 1.9765e-01
# Theta | test1 -> R² = 0.7803, MSE = 5.0473e-02
# X | test1 -> R² = -0.2733, MSE = 1.3339e-01
# Y | test1 -> R² = -1.1162, MSE = 1.7342e-01
# Theta | test2 -> R² = 0.2077, MSE = 1.8789e-01
# X | test2 -> R² = -0.1268, MSE = 9.2727e-02
# Y | test2 -> R² = -0.7929, MSE = 1.9030e-01
# Theta | test3 -> R² = 0.4092, MSE = 1.9422e-01
# X | test3 -> R² = -0.2868, MSE = 1.1839e-01
# Y | test3 -> R² = -1.3702, MSE = 1.8205e-01
# Theta | val -> R² = 0.6434, MSE = 1.1671e-01
# X | val -> R² = -0.3293, MSE = 1.2711e-01
# Y | val -> R² = -1.3784, MSE = 1.7707e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.594957
# Epoch 50 Loss 1.296121
# Epoch 100 Loss 1.282292
# Epoch 150 Loss 1.276322
# Epoch 200 Loss 1.268372
# Epoch 250 Loss 1.261316
# Epoch 300 Loss 1.256363
# Epoch 350 Loss 1.250170
# Early stopping at epoch 368
# Theta | train1 -> R² = 0.8275, MSE = 3.9383e-02
# X | train1 -> R² = -0.2207, MSE = 1.3162e-01
# Y | train1 -> R² = -0.9511, MSE = 1.6349e-01
# Theta | train2 -> R² = 0.4539, MSE = 1.2469e-01
# X | train2 -> R² = -0.1884, MSE = 1.0014e-01
# Y | train2 -> R² = -0.8539, MSE = 1.9962e-01
# Theta | test1 -> R² = 0.5871, MSE = 9.4853e-02
# X | test1 -> R² = -0.3067, MSE = 1.3689e-01
# Y | test1 -> R² = -1.1360, MSE = 1.7504e-01
# Theta | test2 -> R² = 0.4795, MSE = 1.2345e-01
# X | test2 -> R² = -0.1918, MSE = 9.8076e-02
# Y | test2 -> R² = -0.8096, MSE = 1.9208e-01
# Theta | test3 -> R² = 0.4788, MSE = 1.7134e-01
# X | test3 -> R² = -0.2921, MSE = 1.1888e-01
# Y | test3 -> R² = -1.4148, MSE = 1.8547e-01
# Theta | val -> R² = 0.6763, MSE = 1.0593e-01
# X | val -> R² = -0.3316, MSE = 1.2733e-01
# Y | val -> R² = -1.3966, MSE = 1.7843e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.550758
# Epoch 50 Loss 1.304154
# Epoch 100 Loss 1.282017
# Epoch 150 Loss 1.277654
# Epoch 200 Loss 1.270538
# Epoch 250 Loss 1.261969
# Epoch 300 Loss 1.255023
# Epoch 350 Loss 1.249743
# Early stopping at epoch 375
# Theta | train1 -> R² = 0.8433, MSE = 3.5774e-02
# X | train1 -> R² = -0.2064, MSE = 1.3008e-01
# Y | train1 -> R² = -0.9306, MSE = 1.6178e-01
# Theta | train2 -> R² = 0.3980, MSE = 1.3745e-01
# X | train2 -> R² = -0.2104, MSE = 1.0199e-01
# Y | train2 -> R² = -0.8671, MSE = 2.0105e-01
# Theta | test1 -> R² = 0.6521, MSE = 7.9908e-02
# X | test1 -> R² = -0.2866, MSE = 1.3478e-01
# Y | test1 -> R² = -1.1234, MSE = 1.7401e-01
# Theta | test2 -> R² = 0.4104, MSE = 1.3982e-01
# X | test2 -> R² = -0.2144, MSE = 9.9938e-02
# Y | test2 -> R² = -0.8292, MSE = 1.9416e-01
# Theta | test3 -> R² = 0.5295, MSE = 1.5468e-01
# X | test3 -> R² = -0.3211, MSE = 1.2155e-01
# Y | test3 -> R² = -1.3927, MSE = 1.8378e-01
# Theta | val -> R² = 0.7143, MSE = 9.3501e-02
# X | val -> R² = -0.3517, MSE = 1.2925e-01
# Y | val -> R² = -1.3587, MSE = 1.7560e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.587927
# Epoch 50 Loss 1.302579
# Epoch 100 Loss 1.283669
# Epoch 150 Loss 1.278857
# Epoch 200 Loss 1.271934
# Epoch 250 Loss 1.264521
# Epoch 300 Loss 1.258907
# Early stopping at epoch 337
# Theta | train1 -> R² = 0.7417, MSE = 5.8967e-02
# X | train1 -> R² = -0.1154, MSE = 1.2026e-01
# Y | train1 -> R² = -0.9995, MSE = 1.6755e-01
# Theta | train2 -> R² = 0.3845, MSE = 1.4051e-01
# X | train2 -> R² = -0.0434, MSE = 8.7917e-02
# Y | train2 -> R² = -0.9195, MSE = 2.0669e-01
# Theta | test1 -> R² = 0.5379, MSE = 1.0615e-01
# X | test1 -> R² = -0.1886, MSE = 1.2452e-01
# Y | test1 -> R² = -1.2206, MSE = 1.8198e-01
# Theta | test2 -> R² = 0.3672, MSE = 1.5008e-01
# X | test2 -> R² = -0.0485, MSE = 8.6282e-02
# Y | test2 -> R² = -0.8857, MSE = 2.0015e-01
# Theta | test3 -> R² = -0.0701, MSE = 3.5180e-01
# X | test3 -> R² = -0.2019, MSE = 1.1058e-01
# Y | test3 -> R² = -1.2744, MSE = 1.7469e-01
# Theta | val -> R² = 0.3861, MSE = 2.0093e-01
# X | val -> R² = -0.2338, MSE = 1.1798e-01
# Y | val -> R² = -1.3083, MSE = 1.7186e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.572162
# Epoch 50 Loss 1.298795
# Epoch 100 Loss 1.282347
# Epoch 150 Loss 1.278185
# Epoch 200 Loss 1.271676
# Epoch 250 Loss 1.268348
# Epoch 300 Loss 1.258544
# Epoch 350 Loss 1.260750
# Early stopping at epoch 371
# Theta | train1 -> R² = 0.8417, MSE = 3.6145e-02
# X | train1 -> R² = -0.1836, MSE = 1.2762e-01
# Y | train1 -> R² = -0.9686, MSE = 1.6496e-01
# Theta | train2 -> R² = 0.3923, MSE = 1.3874e-01
# X | train2 -> R² = -0.2004, MSE = 1.0115e-01
# Y | train2 -> R² = -0.9148, MSE = 2.0619e-01
# Theta | test1 -> R² = 0.6691, MSE = 7.6012e-02
# X | test1 -> R² = -0.2370, MSE = 1.2959e-01
# Y | test1 -> R² = -1.1564, MSE = 1.7671e-01
# Theta | test2 -> R² = 0.4085, MSE = 1.4029e-01
# X | test2 -> R² = -0.2088, MSE = 9.9472e-02
# Y | test2 -> R² = -0.8750, MSE = 1.9902e-01
# Theta | test3 -> R² = 0.2854, MSE = 2.3493e-01
# X | test3 -> R² = -0.2422, MSE = 1.1429e-01
# Y | test3 -> R² = -1.5308, MSE = 1.9439e-01
# Theta | val -> R² = 0.6513, MSE = 1.1412e-01
# X | val -> R² = -0.2661, MSE = 1.2107e-01
# Y | val -> R² = -1.4555, MSE = 1.8281e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.582332
# Epoch 50 Loss 1.298422
# Epoch 100 Loss 1.281801
# Epoch 150 Loss 1.277298
# Epoch 200 Loss 1.269099
# Epoch 250 Loss 1.261987
# Epoch 300 Loss 1.255147
# Early stopping at epoch 325
# Theta | train1 -> R² = 0.6424, MSE = 8.1623e-02
# X | train1 -> R² = -0.0762, MSE = 1.1604e-01
# Y | train1 -> R² = -0.8442, MSE = 1.5454e-01
# Theta | train2 -> R² = 0.5451, MSE = 1.0385e-01
# X | train2 -> R² = -0.1493, MSE = 9.6841e-02
# Y | train2 -> R² = -0.6834, MSE = 1.8127e-01
# Theta | test1 -> R² = 0.3502, MSE = 1.4926e-01
# X | test1 -> R² = -0.1529, MSE = 1.2078e-01
# Y | test1 -> R² = -1.0408, MSE = 1.6724e-01
# Theta | test2 -> R² = 0.5056, MSE = 1.1725e-01
# X | test2 -> R² = -0.1563, MSE = 9.5153e-02
# Y | test2 -> R² = -0.6522, MSE = 1.7537e-01
# Theta | test3 -> R² = -0.4158, MSE = 4.6543e-01
# X | test3 -> R² = -0.1821, MSE = 1.0876e-01
# Y | test3 -> R² = -1.3261, MSE = 1.7866e-01
# Theta | val -> R² = 0.1614, MSE = 2.7445e-01
# X | val -> R² = -0.2394, MSE = 1.1851e-01
# Y | val -> R² = -1.3422, MSE = 1.7438e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.583530
# Epoch 50 Loss 1.300127
# Epoch 100 Loss 1.283651
# Epoch 150 Loss 1.277864
# Epoch 200 Loss 1.272380
# Epoch 250 Loss 1.266725
# Epoch 300 Loss 1.260765
# Epoch 350 Loss 1.256112
# Early stopping at epoch 375
# Theta | train1 -> R² = 0.8154, MSE = 4.2137e-02
# X | train1 -> R² = -0.2848, MSE = 1.3854e-01
# Y | train1 -> R² = -0.9216, MSE = 1.6102e-01
# Theta | train2 -> R² = 0.4650, MSE = 1.2214e-01
# X | train2 -> R² = -0.2299, MSE = 1.0363e-01
# Y | train2 -> R² = -0.8393, MSE = 1.9805e-01
# Theta | test1 -> R² = 0.6401, MSE = 8.2674e-02
# X | test1 -> R² = -0.3789, MSE = 1.4445e-01
# Y | test1 -> R² = -1.1496, MSE = 1.7616e-01
# Theta | test2 -> R² = 0.4435, MSE = 1.3198e-01
# X | test2 -> R² = -0.2305, MSE = 1.0126e-01
# Y | test2 -> R² = -0.8081, MSE = 1.9191e-01
# Theta | test3 -> R² = -0.3822, MSE = 4.5438e-01
# X | test3 -> R² = -0.3774, MSE = 1.2672e-01
# Y | test3 -> R² = -1.2143, MSE = 1.7007e-01
# Theta | val -> R² = 0.2405, MSE = 2.4856e-01
# X | val -> R² = -0.4203, MSE = 1.3581e-01
# Y | val -> R² = -1.2712, MSE = 1.6909e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.565516
# Epoch 50 Loss 1.291339
# Epoch 100 Loss 1.281291
# Epoch 150 Loss 1.276795
# Epoch 200 Loss 1.271109
# Epoch 250 Loss 1.265140
# Epoch 300 Loss 1.256960
# Early stopping at epoch 329
# Theta | train1 -> R² = 0.7802, MSE = 5.0164e-02
# X | train1 -> R² = -0.1754, MSE = 1.2674e-01
# Y | train1 -> R² = -1.1218, MSE = 1.7780e-01
# Theta | train2 -> R² = 0.3134, MSE = 1.5675e-01
# X | train2 -> R² = -0.1052, MSE = 9.3129e-02
# Y | train2 -> R² = -1.0457, MSE = 2.2028e-01
# Theta | test1 -> R² = 0.6015, MSE = 9.1536e-02
# X | test1 -> R² = -0.2537, MSE = 1.3134e-01
# Y | test1 -> R² = -1.3440, MSE = 1.9209e-01
# Theta | test2 -> R² = 0.3055, MSE = 1.6471e-01
# X | test2 -> R² = -0.1114, MSE = 9.1460e-02
# Y | test2 -> R² = -1.0129, MSE = 2.1366e-01
# Theta | test3 -> R² = -0.2467, MSE = 4.0984e-01
# X | test3 -> R² = -0.2613, MSE = 1.1605e-01
# Y | test3 -> R² = -1.7721, MSE = 2.1292e-01
# Theta | val -> R² = 0.2612, MSE = 2.4180e-01
# X | val -> R² = -0.3035, MSE = 1.2465e-01
# Y | val -> R² = -1.7113, MSE = 2.0185e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.558120
# Epoch 50 Loss 1.294051
# Epoch 100 Loss 1.279948
# Epoch 150 Loss 1.275503
# Epoch 200 Loss 1.271675
# Epoch 250 Loss 1.263544
# Epoch 300 Loss 1.251290
# Epoch 350 Loss 1.245835
# Early stopping at epoch 370
# Theta | train1 -> R² = 0.8377, MSE = 3.7041e-02
# X | train1 -> R² = -0.2332, MSE = 1.3297e-01
# Y | train1 -> R² = -0.9968, MSE = 1.6733e-01
# Theta | train2 -> R² = 0.4309, MSE = 1.2992e-01
# X | train2 -> R² = -0.2178, MSE = 1.0261e-01
# Y | train2 -> R² = -0.9419, MSE = 2.0910e-01
# Theta | test1 -> R² = 0.6842, MSE = 7.2538e-02
# X | test1 -> R² = -0.3102, MSE = 1.3725e-01
# Y | test1 -> R² = -1.1988, MSE = 1.8019e-01
# Theta | test2 -> R² = 0.4461, MSE = 1.3135e-01
# X | test2 -> R² = -0.2200, MSE = 1.0039e-01
# Y | test2 -> R² = -0.9007, MSE = 2.0175e-01
# Theta | test3 -> R² = 0.2720, MSE = 2.3932e-01
# X | test3 -> R² = -0.3516, MSE = 1.2435e-01
# Y | test3 -> R² = -1.7933, MSE = 2.1455e-01
# Theta | val -> R² = 0.6189, MSE = 1.2472e-01
# X | val -> R² = -0.3747, MSE = 1.3146e-01
# Y | val -> R² = -1.6943, MSE = 2.0059e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.549212
# Epoch 50 Loss 1.294977
# Epoch 100 Loss 1.281616
# Epoch 150 Loss 1.279009
# Epoch 200 Loss 1.276122
# Epoch 250 Loss 1.271754
# Epoch 300 Loss 1.265762
# Early stopping at epoch 325
# Theta | train1 -> R² = 0.5150, MSE = 1.1070e-01
# X | train1 -> R² = -0.0796, MSE = 1.1641e-01
# Y | train1 -> R² = -0.8699, MSE = 1.5669e-01
# Theta | train2 -> R² = 0.3714, MSE = 1.4350e-01
# X | train2 -> R² = -0.1085, MSE = 9.3403e-02
# Y | train2 -> R² = -0.7484, MSE = 1.8826e-01
# Theta | test1 -> R² = 0.1691, MSE = 1.9088e-01
# X | test1 -> R² = -0.1497, MSE = 1.2045e-01
# Y | test1 -> R² = -1.0540, MSE = 1.6832e-01
# Theta | test2 -> R² = 0.3220, MSE = 1.6079e-01
# X | test2 -> R² = -0.1160, MSE = 9.1837e-02
# Y | test2 -> R² = -0.7133, MSE = 1.8186e-01
# Theta | test3 -> R² = -0.6090, MSE = 5.2896e-01
# X | test3 -> R² = -0.1642, MSE = 1.0711e-01
# Y | test3 -> R² = -1.3918, MSE = 1.8371e-01
# Theta | val -> R² = -0.0826, MSE = 3.5430e-01
# X | val -> R² = -0.2020, MSE = 1.1494e-01
# Y | val -> R² = -1.3707, MSE = 1.7650e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.578697
# Epoch 50 Loss 1.288740
# Epoch 100 Loss 1.281321
# Epoch 150 Loss 1.277446
# Epoch 200 Loss 1.272478
# Epoch 250 Loss 1.283130
# Epoch 300 Loss 1.257848
# Epoch 350 Loss 1.251277
# Epoch 400 Loss 1.246621
# Early stopping at epoch 432
# Theta | train1 -> R² = 0.8418, MSE = 3.6102e-02
# X | train1 -> R² = -0.1953, MSE = 1.2888e-01
# Y | train1 -> R² = -0.8914, MSE = 1.5849e-01
# Theta | train2 -> R² = 0.4705, MSE = 1.2089e-01
# X | train2 -> R² = -0.1999, MSE = 1.0111e-01
# Y | train2 -> R² = -0.8715, MSE = 2.0152e-01
# Theta | test1 -> R² = 0.6458, MSE = 8.1357e-02
# X | test1 -> R² = -0.2371, MSE = 1.2960e-01
# Y | test1 -> R² = -1.1058, MSE = 1.7257e-01
# Theta | test2 -> R² = 0.4954, MSE = 1.1967e-01
# X | test2 -> R² = -0.1989, MSE = 9.8658e-02
# Y | test2 -> R² = -0.8281, MSE = 1.9404e-01
# Theta | test3 -> R² = 0.2702, MSE = 2.3991e-01
# X | test3 -> R² = -0.5298, MSE = 1.4075e-01
# Y | test3 -> R² = -1.1048, MSE = 1.6166e-01
# Theta | val -> R² = 0.5930, MSE = 1.3321e-01
# X | val -> R² = -0.5010, MSE = 1.4353e-01
# Y | val -> R² = -1.1486, MSE = 1.5997e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.560938
# Epoch 50 Loss 1.296709
# Epoch 100 Loss 1.281630
# Epoch 150 Loss 1.278043
# Epoch 200 Loss 1.273373
# Epoch 250 Loss 1.270861
# Epoch 300 Loss 1.261896
# Epoch 350 Loss 1.276774
# Early stopping at epoch 370
# Theta | train1 -> R² = 0.8486, MSE = 3.4552e-02
# X | train1 -> R² = -0.2241, MSE = 1.3199e-01
# Y | train1 -> R² = -0.9953, MSE = 1.6720e-01
# Theta | train2 -> R² = 0.4139, MSE = 1.3381e-01
# X | train2 -> R² = -0.1889, MSE = 1.0018e-01
# Y | train2 -> R² = -0.9011, MSE = 2.0471e-01
# Theta | test1 -> R² = 0.7036, MSE = 6.8096e-02
# X | test1 -> R² = -0.3045, MSE = 1.3666e-01
# Y | test1 -> R² = -1.1884, MSE = 1.7934e-01
# Theta | test2 -> R² = 0.4386, MSE = 1.3314e-01
# X | test2 -> R² = -0.1914, MSE = 9.8048e-02
# Y | test2 -> R² = -0.8607, MSE = 1.9750e-01
# Theta | test3 -> R² = 0.4157, MSE = 1.9207e-01
# X | test3 -> R² = -0.3253, MSE = 1.2194e-01
# Y | test3 -> R² = -1.6520, MSE = 2.0369e-01
# Theta | val -> R² = 0.6531, MSE = 1.1352e-01
# X | val -> R² = -0.3603, MSE = 1.3008e-01
# Y | val -> R² = -1.5873, MSE = 1.9263e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.578313
# Epoch 50 Loss 1.290489
# Epoch 100 Loss 1.281227
# Epoch 150 Loss 1.277275
# Epoch 200 Loss 1.272706
# Epoch 250 Loss 1.267286
# Epoch 300 Loss 1.268671
# Early stopping at epoch 312
# Theta | train1 -> R² = 0.6594, MSE = 7.7756e-02
# X | train1 -> R² = -0.0515, MSE = 1.1337e-01
# Y | train1 -> R² = -1.0152, MSE = 1.6887e-01
# Theta | train2 -> R² = -0.2595, MSE = 2.8756e-01
# X | train2 -> R² = -0.0626, MSE = 8.9533e-02
# Y | train2 -> R² = -0.9233, MSE = 2.0709e-01
# Theta | test1 -> R² = 0.7684, MSE = 5.3200e-02
# X | test1 -> R² = -0.1051, MSE = 1.1577e-01
# Y | test1 -> R² = -1.2238, MSE = 1.8224e-01
# Theta | test2 -> R² = -0.1621, MSE = 2.7560e-01
# X | test2 -> R² = -0.0752, MSE = 8.8479e-02
# Y | test2 -> R² = -0.8899, MSE = 2.0060e-01
# Theta | test3 -> R² = 0.6744, MSE = 1.0704e-01
# X | test3 -> R² = -0.1425, MSE = 1.0512e-01
# Y | test3 -> R² = -1.7065, MSE = 2.0788e-01
# Theta | val -> R² = 0.6873, MSE = 1.0233e-01
# X | val -> R² = -0.2086, MSE = 1.1557e-01
# Y | val -> R² = -1.6304, MSE = 1.9584e-01
# Modelo 5 treinado e salvo no Excel
# Epoch 0 Loss 1.555457
# Epoch 50 Loss 1.294124
# Epoch 100 Loss 1.280568
# Epoch 150 Loss 1.276911
# Epoch 200 Loss 1.275063
# Epoch 250 Loss 1.266358
# Epoch 300 Loss 1.259273
# Epoch 350 Loss 1.255908
# Early stopping at epoch 358
# Theta | train1 -> R² = 0.8257, MSE = 3.9792e-02
# X | train1 -> R² = -0.2935, MSE = 1.3948e-01
# Y | train1 -> R² = -1.0123, MSE = 1.6862e-01
# Theta | train2 -> R² = 0.4021, MSE = 1.3650e-01
# X | train2 -> R² = -0.2398, MSE = 1.0447e-01
# Y | train2 -> R² = -0.9308, MSE = 2.0790e-01
# Theta | test1 -> R² = 0.6581, MSE = 7.8537e-02
# X | test1 -> R² = -0.3830, MSE = 1.4488e-01
# Y | test1 -> R² = -1.2274, MSE = 1.8253e-01
# Theta | test2 -> R² = 0.4105, MSE = 1.3980e-01
# X | test2 -> R² = -0.2425, MSE = 1.0225e-01
# Y | test2 -> R² = -0.8967, MSE = 2.0132e-01
# Theta | test3 -> R² = 0.3368, MSE = 2.1803e-01
# X | test3 -> R² = -0.3942, MSE = 1.2827e-01
# Y | test3 -> R² = -1.6424, MSE = 2.0296e-01
# Theta | val -> R² = 0.6077, MSE = 1.2838e-01
# X | val -> R² = -0.4278, MSE = 1.3653e-01
# Y | val -> R² = -1.6082, MSE = 1.9418e-01
# Modelo 6 treinado e salvo no Excel
# Epoch 0 Loss 1.544434
# Epoch 50 Loss 1.291713
# Epoch 100 Loss 1.281082
# Epoch 150 Loss 1.277015
# Epoch 200 Loss 1.273740
# Epoch 250 Loss 1.272669
# Epoch 300 Loss 1.257691
# Epoch 350 Loss 1.251235
# Early stopping at epoch 384
# Theta | train1 -> R² = 0.8050, MSE = 4.4512e-02
# X | train1 -> R² = -0.2040, MSE = 1.2983e-01
# Y | train1 -> R² = -0.9379, MSE = 1.6239e-01
# Theta | train2 -> R² = 0.5972, MSE = 9.1968e-02
# X | train2 -> R² = -0.1871, MSE = 1.0002e-01
# Y | train2 -> R² = -0.8673, MSE = 2.0106e-01
# Theta | test1 -> R² = 0.5325, MSE = 1.0739e-01
# X | test1 -> R² = -0.2765, MSE = 1.3373e-01
# Y | test1 -> R² = -1.1352, MSE = 1.7498e-01
# Theta | test2 -> R² = 0.5929, MSE = 9.6539e-02
# X | test2 -> R² = -0.1921, MSE = 9.8103e-02
# Y | test2 -> R² = -0.8243, MSE = 1.9364e-01
# Theta | test3 -> R² = 0.2070, MSE = 2.6071e-01
# X | test3 -> R² = -0.3111, MSE = 1.2062e-01
# Y | test3 -> R² = -1.4270, MSE = 1.8641e-01
# Theta | val -> R² = 0.5732, MSE = 1.3968e-01
# X | val -> R² = -0.3316, MSE = 1.2734e-01
# Y | val -> R² = -1.4059, MSE = 1.7912e-01
# Modelo 7 treinado e salvo no Excel
# Epoch 0 Loss 1.569499
# Epoch 50 Loss 1.293330
# Epoch 100 Loss 1.281782
# Epoch 150 Loss 1.278139
# Epoch 200 Loss 1.268767
# Epoch 250 Loss 1.261287
# Epoch 300 Loss 1.256559
# Epoch 350 Loss 1.249375
# Epoch 400 Loss 1.242789
# Early stopping at epoch 417
# Theta | train1 -> R² = 0.8528, MSE = 3.3611e-02
# X | train1 -> R² = -0.2019, MSE = 1.2960e-01
# Y | train1 -> R² = -0.9310, MSE = 1.6181e-01
# Theta | train2 -> R² = 0.4508, MSE = 1.2538e-01
# X | train2 -> R² = -0.1863, MSE = 9.9959e-02
# Y | train2 -> R² = -0.8627, MSE = 2.0057e-01
# Theta | test1 -> R² = 0.6889, MSE = 7.1473e-02
# X | test1 -> R² = -0.2661, MSE = 1.3264e-01
# Y | test1 -> R² = -1.1339, MSE = 1.7487e-01
# Theta | test2 -> R² = 0.4714, MSE = 1.2537e-01
# X | test2 -> R² = -0.1930, MSE = 9.8174e-02
# Y | test2 -> R² = -0.8308, MSE = 1.9432e-01
# Theta | test3 -> R² = 0.2107, MSE = 2.5947e-01
# X | test3 -> R² = -0.2905, MSE = 1.1873e-01
# Y | test3 -> R² = -1.2868, MSE = 1.7564e-01
# Theta | val -> R² = 0.5824, MSE = 1.3666e-01
# X | val -> R² = -0.3110, MSE = 1.2536e-01
# Y | val -> R² = -1.2780, MSE = 1.6960e-01
# Modelo 8 treinado e salvo no Excel
# Epoch 0 Loss 1.588700
# Epoch 50 Loss 1.295153
# Epoch 100 Loss 1.281980
# Epoch 150 Loss 1.278204
# Epoch 200 Loss 1.273051
# Epoch 250 Loss 1.267716
# Epoch 300 Loss 1.264355
# Epoch 350 Loss 1.254206
# Epoch 400 Loss 1.248173
# Early stopping at epoch 441
# Theta | train1 -> R² = 0.8307, MSE = 3.8643e-02
# X | train1 -> R² = -0.1870, MSE = 1.2799e-01
# Y | train1 -> R² = -0.8825, MSE = 1.5774e-01
# Theta | train2 -> R² = 0.4692, MSE = 1.2118e-01
# X | train2 -> R² = -0.2056, MSE = 1.0159e-01
# Y | train2 -> R² = -0.8718, MSE = 2.0155e-01
# Theta | test1 -> R² = 0.6078, MSE = 9.0099e-02
# X | test1 -> R² = -0.2340, MSE = 1.2927e-01
# Y | test1 -> R² = -1.0819, MSE = 1.7061e-01
# Theta | test2 -> R² = 0.4928, MSE = 1.2029e-01
# X | test2 -> R² = -0.1994, MSE = 9.8706e-02
# Y | test2 -> R² = -0.8159, MSE = 1.9274e-01
# Theta | test3 -> R² = 0.4352, MSE = 1.8567e-01
# X | test3 -> R² = -0.5247, MSE = 1.4028e-01
# Y | test3 -> R² = -1.3027, MSE = 1.7687e-01
# Theta | val -> R² = 0.6846, MSE = 1.0323e-01
# X | val -> R² = -0.4749, MSE = 1.4104e-01
# Y | val -> R² = -1.2908, MSE = 1.7055e-01
# Modelo 9 treinado e salvo no Excel
# Epoch 0 Loss 1.537407
# Epoch 50 Loss 1.287204
# Epoch 100 Loss 1.283139
# Epoch 150 Loss 1.280017
# Epoch 200 Loss 1.277493
# Epoch 250 Loss 1.273825
# Epoch 300 Loss 1.269911
# Early stopping at epoch 306
# Theta | train1 -> R² = 0.5871, MSE = 9.4261e-02
# X | train1 -> R² = -0.2689, MSE = 1.3683e-01
# Y | train1 -> R² = -1.0823, MSE = 1.7449e-01
# Theta | train2 -> R² = -0.6034, MSE = 3.6606e-01
# X | train2 -> R² = -0.4075, MSE = 1.1860e-01
# Y | train2 -> R² = -1.2177, MSE = 2.3879e-01
# Theta | test1 -> R² = 0.7489, MSE = 5.7679e-02
# X | test1 -> R² = -0.3451, MSE = 1.4092e-01
# Y | test1 -> R² = -1.2679, MSE = 1.8585e-01
# Theta | test2 -> R² = -0.4504, MSE = 3.4399e-01
# X | test2 -> R² = -0.4163, MSE = 1.1655e-01
# Y | test2 -> R² = -1.1728, MSE = 2.3063e-01
# Theta | test3 -> R² = 0.6986, MSE = 9.9081e-02
# X | test3 -> R² = -0.4515, MSE = 1.3355e-01
# Y | test3 -> R² = -1.7478, MSE = 2.1105e-01
# Theta | val -> R² = 0.6520, MSE = 1.1389e-01
# X | val -> R² = -0.4948, MSE = 1.4294e-01
# Y | val -> R² = -1.6221, MSE = 1.9522e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.603484
# Epoch 50 Loss 1.288368
# Epoch 100 Loss 1.282279
# Epoch 150 Loss 1.278532
# Epoch 200 Loss 1.275975
# Epoch 250 Loss 1.272254
# Epoch 300 Loss 1.270492
# Epoch 350 Loss 1.259697
# Epoch 400 Loss 1.251783
# Epoch 450 Loss 1.245308
# Epoch 500 Loss 1.237078
# Epoch 550 Loss 1.245285
# Epoch 600 Loss 1.224473
# Epoch 650 Loss 1.221523
# Epoch 700 Loss 1.218877
# Early stopping at epoch 733
# Theta | train1 -> R² = -4.0230, MSE = 1.1466e+00
# X | train1 -> R² = -1.5005, MSE = 2.6962e-01
# Y | train1 -> R² = -0.0016, MSE = 8.3926e-02
# Theta | train2 -> R² = -6.6174, MSE = 1.7391e+00
# X | train2 -> R² = -2.4594, MSE = 2.9149e-01
# Y | train2 -> R² = -0.3098, MSE = 1.4104e-01
# Theta | test1 -> R² = -3.8090, MSE = 1.1047e+00
# X | test1 -> R² = -1.8514, MSE = 2.9871e-01
# Y | test1 -> R² = -0.0611, MSE = 8.6954e-02
# Theta | test2 -> R² = -5.5770, MSE = 1.5598e+00
# X | test2 -> R² = -2.4479, MSE = 2.8374e-01
# Y | test2 -> R² = -0.3178, MSE = 1.3987e-01
# Theta | test3 -> R² = 0.8002, MSE = 6.5694e-02
# X | test3 -> R² = -1.4018, MSE = 2.2097e-01
# Y | test3 -> R² = -1.8250, MSE = 2.1698e-01
# Theta | val -> R² = 0.2169, MSE = 2.5631e-01
# X | val -> R² = -1.0716, MSE = 1.9810e-01
# Y | val -> R² = -2.0035, MSE = 2.2361e-01
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 70
#      60 save_fig = any(
#      61     any(v > 0.8 for v in metrics[name][key])
#      62     if isinstance(metrics[name][key], (list, tuple))
#    (...)
#      65     for key in metrics[name]
#      66     if key.startswith("R2_test"))
#      69 if save_fig:
# ---> 70     plt.savefig(
#      71         f"./results/model_{arch_name}_{i}.pdf",
#      72         format="pdf",
#      73         bbox_inches="tight"
#      74     )
#      75     print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")
#      77 plt.close(fig)
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\pyplot.py:1251, in savefig(*args, **kwargs)
#    1248 fig = gcf()
#    1249 # savefig default implementation has no return, so mypy is unhappy
#    1250 # presumably this is here because subclasses can return?
# -> 1251 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1252 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1253 return res
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\figure.py:3490, in Figure.savefig(self, fname, transparent, **kwargs)
#    3488     for ax in self.axes:
#    3489         _recursively_make_axes_transparent(stack, ax)
# -> 3490 self.canvas.print_figure(fname, **kwargs)
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\backend_bases.py:2184, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2180 try:
#    2181     # _get_renderer may change the figure dpi (as vector formats
#    2182     # force the figure dpi to 72), so we need to set it again here.
#    2183     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184         result = print_method(
#    2185             filename,
#    2186             facecolor=facecolor,
#    2187             edgecolor=edgecolor,
#    2188             orientation=orientation,
#    2189             bbox_inches_restore=_bbox_inches_restore,
#    2190             **kwargs)
#    2191 finally:
#    2192     if bbox_inches and restore_bbox:
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\backend_bases.py:2040, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2036     optional_kws = {  # Passed by print_figure for other renderers.
#    2037         "dpi", "facecolor", "edgecolor", "orientation",
#    2038         "bbox_inches_restore"}
#    2039     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042 else:  # Let third-parties do as they see fit.
#    2043     print_method = meth
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\backends\backend_pdf.py:2779, in FigureCanvasPdf.print_pdf(self, filename, bbox_inches_restore, metadata)
#    2777     file = filename._ensure_file()
#    2778 else:
# -> 2779     file = PdfFile(filename, metadata=metadata)
#    2780 try:
#    2781     file.newPage(width, height)
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\backends\backend_pdf.py:687, in PdfFile.__init__(self, filename, metadata)
#     685 self.original_file_like = None
#     686 self.tell_base = 0
# --> 687 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     688 if not opened:
#     689     try:
#
# File d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\matplotlib\cbook.py:546, in to_filehandle(fname, flag, return_opened, encoding)
#     544         fh = bz2.BZ2File(fname, flag)
#     545     else:
# --> 546         fh = open(fname, flag, encoding=encoding)
#     547     opened = True
#     548 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/model_64_1.pdf'
