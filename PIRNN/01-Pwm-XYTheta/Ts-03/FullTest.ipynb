# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
TIME_STEPS = 3
TS = 0.07
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(x_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 3, 2)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta0):

    dtheta_cin = (R / (2 * L)) * (Wd - We)

    theta_cin = theta0 + tf.cumsum(dtheta_cin * dt)

    dx_cin = (R / 2) * tf.cos(theta_cin) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_cin) * (Wd + We)

    return [dtheta_cin, dx_cin, dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer

                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(OUTPUT_SIZE,
                                               activation="linear",                 kernel_initializer = initializer
)

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        theta0 = tf.constant(Train["Theta"].values[0], dtype=tf.float32)
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights

def TrainPINN(model, optimizer, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, Wd_train, We_train)
        best_loss, counter, best_weights =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 50 == 0:
            print(f"Epoch {epoch} Loss {loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(dataset["Wd"].values, dataset["We"].values, dataset["Theta"].values[0])
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):

    n_datasets = len(NormDatasets)
    n_targets = len(TARGET)

    fig, axs = plt.subplots(
        n_datasets,
        n_targets,
        figsize=(6*n_targets, 4*n_datasets)
    )

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

            # seleção robusta do eixo
            if n_datasets > 1 and n_targets > 1:
                ax = axs[i, j]
            elif n_datasets > 1:
                ax = axs[i]
            elif n_targets > 1:
                ax = axs[j]
            else:
                ax = axs

            PlotOut(
                ax,
                TITLES[i],
                name,
                y_true[:, j],
                y_cin[:, j],
                y_pred[:, j],
                
            )

    plt.tight_layout()
    return metrics, plt, fig

# %%
from tensorflow.keras.optimizers import Adam

N_MODELS = 5  # número de inicializações
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[5, 2], [10, 5], [15, 5], [20, 5],
                [64, 32], [128, 64], [264, 128], [62, 32, 16],
                [128, 64, 32]] 

results = {}
excel_file = "resultados.xlsx"

for arch in architectures:
    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))

        model = PINN(architecture=arch, initializer=init)

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.01)
        opt.build(model.trainable_variables)
        
        TrainPINN(model, optimizer=opt)
        
        wf = model.get_weights()

        metrics, plt, fig = EvalModel(model)
        
        arch_name = "_".join(map(str, arch))
        row = {
            "model": f"model_{arch_name}_{i}",
            "Neurons": arch,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        save_fig = any(
            any(v > 0.8 for v in metrics[name][key])
            if isinstance(metrics[name][key], (list, tuple))
            else metrics[name][key] > 0.5
            for name in TARGET_INT
            for key in metrics[name]
            if key.startswith("R2_test"))
    

        if save_fig:
            plt.savefig(
                f"./results/model_{arch_name}_{i}.pdf",
                format="pdf",
                bbox_inches="tight"
            )
            print(f"Figura salva em: ./results/model_{arch_name}_{i}.pdf")

        plt.close(fig)

        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# Epoch 0 Loss 1.565966
# Epoch 50 Loss 1.456056
# Epoch 100 Loss 1.300690
# Epoch 150 Loss 1.272936
# Epoch 200 Loss 1.244510
# Epoch 250 Loss 1.218166
# Epoch 300 Loss 1.200778
# Epoch 350 Loss 1.189007
# Epoch 400 Loss 1.183053
# Epoch 450 Loss 1.180242
# Early stopping at epoch 490
# Theta | train1 -> R² = 0.6512, MSE = 7.9625e-02
# X | train1 -> R² = -0.0816, MSE = 1.1662e-01
# Y | train1 -> R² = -0.8535, MSE = 1.5531e-01
# Theta | train2 -> R² = 0.1686, MSE = 1.8981e-01
# X | train2 -> R² = -0.0811, MSE = 9.1092e-02
# Y | train2 -> R² = -0.7353, MSE = 1.8685e-01
# Theta | test1 -> R² = 0.6671, MSE = 7.6478e-02
# X | test1 -> R² = -0.2234, MSE = 1.2817e-01
# Y | test1 -> R² = -1.1510, MSE = 1.7627e-01
# Theta | test2 -> R² = -0.3877, MSE = 3.2910e-01
# X | test2 -> R² = -0.1500, MSE = 9.4640e-02
# Y | test2 -> R² = -0.8032, MSE = 1.9140e-01
# Theta | test3 -> R² = 0.5804, MSE = 1.3796e-01
# X | test3 -> R² = -1.4424, MSE = 2.2471e-01
# Y | test3 -> R² = -4.9072, MSE = 4.5371e-01
# Theta | val -> R² = 0.6818, MSE = 1.0416e-01
# X | val -> R² = -0.9738, MSE = 1.8874e-01
# Y | val -> R² = -3.7265, MSE = 3.5189e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.568897
# Epoch 50 Loss 1.455377
# Epoch 100 Loss 1.294051
# Epoch 150 Loss 1.271238
# Epoch 200 Loss 1.250864
# Epoch 250 Loss 1.223388
# Epoch 300 Loss 1.193850
# Epoch 350 Loss 1.180188
# Early stopping at epoch 390
# Theta | train1 -> R² = 0.8993, MSE = 2.2990e-02
# X | train1 -> R² = -0.0841, MSE = 1.1689e-01
# Y | train1 -> R² = -0.6142, MSE = 1.3526e-01
# Theta | train2 -> R² = 0.3455, MSE = 1.4943e-01
# X | train2 -> R² = 0.0714, MSE = 7.8240e-02
# Y | train2 -> R² = -0.6289, MSE = 1.7539e-01
# Theta | test1 -> R² = 0.6819, MSE = 7.3063e-02
# X | test1 -> R² = -0.1728, MSE = 1.2286e-01
# Y | test1 -> R² = -0.8011, MSE = 1.4760e-01
# Theta | test2 -> R² = 0.7115, MSE = 6.8421e-02
# X | test2 -> R² = 0.0807, MSE = 7.5651e-02
# Y | test2 -> R² = -0.5561, MSE = 1.6517e-01
# Theta | test3 -> R² = 0.0993, MSE = 2.9611e-01
# X | test3 -> R² = -0.7485, MSE = 1.6087e-01
# Y | test3 -> R² = -3.0335, MSE = 3.0980e-01
# Theta | val -> R² = -3.3301, MSE = 1.4172e+00
# X | val -> R² = -0.2473, MSE = 1.1927e-01
# Y | val -> R² = -1.5784, MSE = 1.9196e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.568486
# Epoch 50 Loss 1.457420
# Epoch 100 Loss 1.296903
# Epoch 150 Loss 1.273480
# Epoch 200 Loss 1.265792
# Epoch 250 Loss 1.255764
# Epoch 300 Loss 1.239725
# Epoch 350 Loss 1.220796
# Epoch 400 Loss 1.214380
# Epoch 450 Loss 1.210329
# Early stopping at epoch 485
# Theta | train1 -> R² = 0.8810, MSE = 2.7169e-02
# X | train1 -> R² = -0.2180, MSE = 1.3133e-01
# Y | train1 -> R² = -1.0787, MSE = 1.7418e-01
# Theta | train2 -> R² = 0.8233, MSE = 4.0331e-02
# X | train2 -> R² = -0.1649, MSE = 9.8153e-02
# Y | train2 -> R² = -0.8514, MSE = 1.9935e-01
# Theta | test1 -> R² = 0.5440, MSE = 1.0475e-01
# X | test1 -> R² = -0.4162, MSE = 1.4837e-01
# Y | test1 -> R² = -1.4735, MSE = 2.0270e-01
# Theta | test2 -> R² = 0.7805, MSE = 5.2054e-02
# X | test2 -> R² = -0.2292, MSE = 1.0116e-01
# Y | test2 -> R² = -0.8753, MSE = 1.9905e-01
# Theta | test3 -> R² = -0.4799, MSE = 4.8652e-01
# X | test3 -> R² = -1.4152, MSE = 2.2221e-01
# Y | test3 -> R² = -4.6510, MSE = 4.3404e-01
# Theta | val -> R² = -8.0089, MSE = 2.9484e+00
# X | val -> R² = -1.2682, MSE = 2.1689e-01
# Y | val -> R² = -3.9089, MSE = 3.6547e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.568707
# Epoch 50 Loss 1.458865
# Epoch 100 Loss 1.452516
# Epoch 150 Loss 1.352432
# Epoch 200 Loss 1.272498
# Epoch 250 Loss 1.219278
# Epoch 300 Loss 1.210212
# Epoch 350 Loss 1.202427
# Epoch 400 Loss 1.199792
# Epoch 450 Loss 1.198403
# Early stopping at epoch 474
# Theta | train1 -> R² = 0.9068, MSE = 2.1264e-02
# X | train1 -> R² = -0.2087, MSE = 1.3033e-01
# Y | train1 -> R² = -1.0704, MSE = 1.7349e-01
# Theta | train2 -> R² = 0.7221, MSE = 6.3442e-02
# X | train2 -> R² = -0.1444, MSE = 9.6426e-02
# Y | train2 -> R² = -0.9870, MSE = 2.1396e-01
# Theta | test1 -> R² = 0.7383, MSE = 6.0125e-02
# X | test1 -> R² = -0.3360, MSE = 1.3996e-01
# Y | test1 -> R² = -1.4278, MSE = 1.9896e-01
# Theta | test2 -> R² = 0.7339, MSE = 6.3113e-02
# X | test2 -> R² = -0.2795, MSE = 1.0529e-01
# Y | test2 -> R² = -1.0990, MSE = 2.2279e-01
# Theta | test3 -> R² = 0.6003, MSE = 1.3141e-01
# X | test3 -> R² = -1.0260, MSE = 1.8640e-01
# Y | test3 -> R² = -3.8019, MSE = 3.6882e-01
# Theta | val -> R² = -0.5429, MSE = 5.0495e-01
# X | val -> R² = -0.5361, MSE = 1.4689e-01
# Y | val -> R² = -2.8264, MSE = 2.8488e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568593
# Epoch 50 Loss 1.460670
# Epoch 100 Loss 1.455428
# Epoch 150 Loss 1.445048
# Epoch 200 Loss 1.290438
# Epoch 250 Loss 1.276198
# Epoch 300 Loss 1.258623
# Epoch 350 Loss 1.234063
# Epoch 400 Loss 1.225972
# Epoch 450 Loss 1.221466
# Early stopping at epoch 498
# Theta | train1 -> R² = 0.9395, MSE = 1.3812e-02
# X | train1 -> R² = -0.5558, MSE = 1.6776e-01
# Y | train1 -> R² = -1.1277, MSE = 1.7830e-01
# Theta | train2 -> R² = 0.7194, MSE = 6.4059e-02
# X | train2 -> R² = -0.4029, MSE = 1.1821e-01
# Y | train2 -> R² = -1.0077, MSE = 2.1618e-01
# Theta | test1 -> R² = 0.6678, MSE = 7.6316e-02
# X | test1 -> R² = -0.7147, MSE = 1.7963e-01
# Y | test1 -> R² = -1.4486, MSE = 2.0066e-01
# Theta | test2 -> R² = 0.3400, MSE = 1.5652e-01
# X | test2 -> R² = -0.5682, MSE = 1.2905e-01
# Y | test2 -> R² = -1.1084, MSE = 2.2379e-01
# Theta | test3 -> R² = 0.0219, MSE = 3.2154e-01
# X | test3 -> R² = -1.8343, MSE = 2.6077e-01
# Y | test3 -> R² = -3.9162, MSE = 3.7760e-01
# Theta | val -> R² = -2.6611, MSE = 1.1982e+00
# X | val -> R² = -1.0869, MSE = 1.9956e-01
# Y | val -> R² = -2.8322, MSE = 2.8531e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.568459
# Epoch 50 Loss 1.285692
# Epoch 100 Loss 1.276718
# Epoch 150 Loss 1.256657
# Epoch 200 Loss 1.201541
# Epoch 250 Loss 1.184727
# Epoch 300 Loss 1.174499
# Epoch 350 Loss 1.170375
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.9012, MSE = 2.2561e-02
# X | train1 -> R² = 0.0706, MSE = 1.0021e-01
# Y | train1 -> R² = -1.1969, MSE = 1.8409e-01
# Theta | train2 -> R² = 0.7707, MSE = 5.2357e-02
# X | train2 -> R² = 0.0669, MSE = 7.8623e-02
# Y | train2 -> R² = -0.8855, MSE = 2.0303e-01
# Theta | test1 -> R² = 0.7294, MSE = 6.2158e-02
# X | test1 -> R² = -0.0925, MSE = 1.1445e-01
# Y | test1 -> R² = -1.6575, MSE = 2.1778e-01
# Theta | test2 -> R² = 0.6349, MSE = 8.6578e-02
# X | test2 -> R² = 0.0204, MSE = 8.0616e-02
# Y | test2 -> R² = -0.9612, MSE = 2.0817e-01
# Theta | test3 -> R² = 0.1768, MSE = 2.7063e-01
# X | test3 -> R² = -0.6635, MSE = 1.5305e-01
# Y | test3 -> R² = -4.5210, MSE = 4.2405e-01
# Theta | val -> R² = -2.5703, MSE = 1.1685e+00
# X | val -> R² = -0.6265, MSE = 1.5553e-01
# Y | val -> R² = -4.4165, MSE = 4.0326e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.567171
# Epoch 50 Loss 1.403068
# Epoch 100 Loss 1.265470
# Epoch 150 Loss 1.225429
# Epoch 200 Loss 1.184007
# Epoch 250 Loss 1.171898
# Epoch 300 Loss 1.166565
# Epoch 350 Loss 1.163127
# Early stopping at epoch 396
# Theta | train1 -> R² = 0.8327, MSE = 3.8198e-02
# X | train1 -> R² = -0.2371, MSE = 1.3339e-01
# Y | train1 -> R² = -1.0764, MSE = 1.7399e-01
# Theta | train2 -> R² = 0.8243, MSE = 4.0105e-02
# X | train2 -> R² = -0.2316, MSE = 1.0377e-01
# Y | train2 -> R² = -0.9181, MSE = 2.0653e-01
# Theta | test1 -> R² = 0.6787, MSE = 7.3820e-02
# X | test1 -> R² = -0.4250, MSE = 1.4929e-01
# Y | test1 -> R² = -1.4399, MSE = 1.9995e-01
# Theta | test2 -> R² = 0.5784, MSE = 9.9983e-02
# X | test2 -> R² = -0.3056, MSE = 1.0744e-01
# Y | test2 -> R² = -0.9756, MSE = 2.0970e-01
# Theta | test3 -> R² = -1.5010, MSE = 8.2220e-01
# X | test3 -> R² = -1.6791, MSE = 2.4649e-01
# Y | test3 -> R² = -4.9228, MSE = 4.5492e-01
# Theta | val -> R² = -2.5826, MSE = 1.1725e+00
# X | val -> R² = -1.3183, MSE = 2.2168e-01
# Y | val -> R² = -4.0020, MSE = 3.7240e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.569110
# Epoch 50 Loss 1.296451
# Epoch 100 Loss 1.265362
# Epoch 150 Loss 1.230084
# Epoch 200 Loss 1.197186
# Epoch 250 Loss 1.178774
# Epoch 300 Loss 1.167294
# Early stopping at epoch 339
# Theta | train1 -> R² = 0.9223, MSE = 1.7730e-02
# X | train1 -> R² = -0.1197, MSE = 1.2073e-01
# Y | train1 -> R² = -1.0162, MSE = 1.6895e-01
# Theta | train2 -> R² = 0.3445, MSE = 1.4965e-01
# X | train2 -> R² = -0.0197, MSE = 8.5921e-02
# Y | train2 -> R² = -0.8015, MSE = 1.9398e-01
# Theta | test1 -> R² = 0.5882, MSE = 9.4598e-02
# X | test1 -> R² = -0.2909, MSE = 1.3524e-01
# Y | test1 -> R² = -1.3438, MSE = 1.9207e-01
# Theta | test2 -> R² = 0.6935, MSE = 7.2680e-02
# X | test2 -> R² = -0.0530, MSE = 8.6651e-02
# Y | test2 -> R² = -0.8221, MSE = 1.9341e-01
# Theta | test3 -> R² = 0.5561, MSE = 1.4593e-01
# X | test3 -> R² = -1.4857, MSE = 2.2869e-01
# Y | test3 -> R² = -4.5764, MSE = 4.2830e-01
# Theta | val -> R² = -3.4854, MSE = 1.4680e+00
# X | val -> R² = -1.5167, MSE = 2.4066e-01
# Y | val -> R² = -4.1538, MSE = 3.8370e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.568004
# Epoch 50 Loss 1.277366
# Epoch 100 Loss 1.253799
# Epoch 150 Loss 1.229123
# Epoch 200 Loss 1.201790
# Epoch 250 Loss 1.191546
# Epoch 300 Loss 1.183863
# Epoch 350 Loss 1.174395
# Epoch 400 Loss 1.168600
# Early stopping at epoch 438
# Theta | train1 -> R² = 0.8435, MSE = 3.5724e-02
# X | train1 -> R² = -0.1270, MSE = 1.2152e-01
# Y | train1 -> R² = -0.9103, MSE = 1.6007e-01
# Theta | train2 -> R² = 0.6286, MSE = 8.4788e-02
# X | train2 -> R² = -0.1047, MSE = 9.3079e-02
# Y | train2 -> R² = -0.7050, MSE = 1.8359e-01
# Theta | test1 -> R² = 0.7690, MSE = 5.3061e-02
# X | test1 -> R² = -0.3199, MSE = 1.3828e-01
# Y | test1 -> R² = -1.3832, MSE = 1.9530e-01
# Theta | test2 -> R² = 0.3454, MSE = 1.5524e-01
# X | test2 -> R² = -0.1729, MSE = 9.6518e-02
# Y | test2 -> R² = -0.7776, MSE = 1.8868e-01
# Theta | test3 -> R² = -0.4292, MSE = 4.6985e-01
# X | test3 -> R² = -0.8390, MSE = 1.6920e-01
# Y | test3 -> R² = -3.2851, MSE = 3.2913e-01
# Theta | val -> R² = -0.4695, MSE = 4.8093e-01
# X | val -> R² = -0.9388, MSE = 1.8539e-01
# Y | val -> R² = -3.4496, MSE = 3.3127e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568540
# Epoch 50 Loss 1.287235
# Epoch 100 Loss 1.268382
# Epoch 150 Loss 1.242124
# Epoch 200 Loss 1.184688
# Epoch 250 Loss 1.169749
# Epoch 300 Loss 1.160969
# Epoch 350 Loss 1.155939
# Epoch 400 Loss 1.152968
# Early stopping at epoch 443
# Theta | train1 -> R² = 0.8482, MSE = 3.4658e-02
# X | train1 -> R² = -0.1569, MSE = 1.2475e-01
# Y | train1 -> R² = -0.9256, MSE = 1.6135e-01
# Theta | train2 -> R² = 0.7523, MSE = 5.6561e-02
# X | train2 -> R² = -0.1342, MSE = 9.5567e-02
# Y | train2 -> R² = -0.7175, MSE = 1.8494e-01
# Theta | test1 -> R² = 0.6758, MSE = 7.4467e-02
# X | test1 -> R² = -0.2956, MSE = 1.3573e-01
# Y | test1 -> R² = -1.2559, MSE = 1.8487e-01
# Theta | test2 -> R² = 0.5395, MSE = 1.0921e-01
# X | test2 -> R² = -0.2124, MSE = 9.9772e-02
# Y | test2 -> R² = -0.7855, MSE = 1.8952e-01
# Theta | test3 -> R² = -0.5313, MSE = 5.0341e-01
# X | test3 -> R² = -1.1250, MSE = 1.9551e-01
# Y | test3 -> R² = -3.7177, MSE = 3.6235e-01
# Theta | val -> R² = -2.8330, MSE = 1.2545e+00
# X | val -> R² = -1.1519, MSE = 2.0577e-01
# Y | val -> R² = -3.3444, MSE = 3.2344e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.567475
# Epoch 50 Loss 1.284752
# Epoch 100 Loss 1.266375
# Epoch 150 Loss 1.212800
# Epoch 200 Loss 1.209465
# Epoch 250 Loss 1.175574
# Epoch 300 Loss 1.164814
# Early stopping at epoch 335
# Theta | train1 -> R² = 0.3435, MSE = 1.4986e-01
# X | train1 -> R² = 0.1124, MSE = 9.5708e-02
# Y | train1 -> R² = -0.6591, MSE = 1.3903e-01
# Theta | train2 -> R² = 0.7261, MSE = 6.2531e-02
# X | train2 -> R² = -0.0786, MSE = 9.0879e-02
# Y | train2 -> R² = -0.6891, MSE = 1.8188e-01
# Theta | test1 -> R² = -1.0561, MSE = 4.7233e-01
# X | test1 -> R² = 0.0382, MSE = 1.0076e-01
# Y | test1 -> R² = -0.9177, MSE = 1.5715e-01
# Theta | test2 -> R² = 0.6332, MSE = 8.6985e-02
# X | test2 -> R² = -0.1491, MSE = 9.4563e-02
# Y | test2 -> R² = -0.7152, MSE = 1.8206e-01
# Theta | test3 -> R² = -0.6949, MSE = 5.5718e-01
# X | test3 -> R² = -0.7067, MSE = 1.5702e-01
# Y | test3 -> R² = -2.2258, MSE = 2.4776e-01
# Theta | val -> R² = -14.0019, MSE = 4.9098e+00
# X | val -> R² = -0.4367, MSE = 1.3738e-01
# Y | val -> R² = -1.9482, MSE = 2.1950e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.566166
# Epoch 50 Loss 1.294322
# Epoch 100 Loss 1.275247
# Epoch 150 Loss 1.245109
# Epoch 200 Loss 1.187203
# Epoch 250 Loss 1.167846
# Epoch 300 Loss 1.161242
# Epoch 350 Loss 1.157131
# Epoch 400 Loss 1.155137
# Early stopping at epoch 447
# Theta | train1 -> R² = 0.8191, MSE = 4.1300e-02
# X | train1 -> R² = -0.0936, MSE = 1.1792e-01
# Y | train1 -> R² = -0.8414, MSE = 1.5430e-01
# Theta | train2 -> R² = 0.8223, MSE = 4.0577e-02
# X | train2 -> R² = -0.0863, MSE = 9.1536e-02
# Y | train2 -> R² = -0.8332, MSE = 1.9739e-01
# Theta | test1 -> R² = 0.7604, MSE = 5.5051e-02
# X | test1 -> R² = -0.2661, MSE = 1.3263e-01
# Y | test1 -> R² = -1.4537, MSE = 2.0108e-01
# Theta | test2 -> R² = 0.5554, MSE = 1.0545e-01
# X | test2 -> R² = -0.1350, MSE = 9.3405e-02
# Y | test2 -> R² = -0.9083, MSE = 2.0256e-01
# Theta | test3 -> R² = -1.1287, MSE = 6.9980e-01
# X | test3 -> R² = -1.2045, MSE = 2.0282e-01
# Y | test3 -> R² = -2.9599, MSE = 3.0415e-01
# Theta | val -> R² = -2.2267, MSE = 1.0560e+00
# X | val -> R² = -1.0624, MSE = 1.9722e-01
# Y | val -> R² = -4.0733, MSE = 3.7771e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.566545
# Epoch 50 Loss 1.288186
# Epoch 100 Loss 1.274256
# Epoch 150 Loss 1.236379
# Epoch 200 Loss 1.201069
# Epoch 250 Loss 1.180665
# Epoch 300 Loss 1.171189
# Epoch 350 Loss 1.162822
# Early stopping at epoch 391
# Theta | train1 -> R² = 0.9084, MSE = 2.0916e-02
# X | train1 -> R² = -0.1486, MSE = 1.2385e-01
# Y | train1 -> R² = -0.9362, MSE = 1.6225e-01
# Theta | train2 -> R² = 0.7681, MSE = 5.2949e-02
# X | train2 -> R² = -0.1760, MSE = 9.9091e-02
# Y | train2 -> R² = -0.7839, MSE = 1.9208e-01
# Theta | test1 -> R² = 0.6165, MSE = 8.8087e-02
# X | test1 -> R² = -0.3209, MSE = 1.3837e-01
# Y | test1 -> R² = -1.3998, MSE = 1.9667e-01
# Theta | test2 -> R² = 0.7550, MSE = 5.8111e-02
# X | test2 -> R² = -0.2603, MSE = 1.0372e-01
# Y | test2 -> R² = -0.8344, MSE = 1.9471e-01
# Theta | test3 -> R² = 0.5237, MSE = 1.5659e-01
# X | test3 -> R² = -1.2476, MSE = 2.0679e-01
# Y | test3 -> R² = -3.2801, MSE = 3.2874e-01
# Theta | val -> R² = -3.3189, MSE = 1.4135e+00
# X | val -> R² = -1.4144, MSE = 2.3087e-01
# Y | val -> R² = -3.6984, MSE = 3.4980e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.568236
# Epoch 50 Loss 1.287334
# Epoch 100 Loss 1.261631
# Epoch 150 Loss 1.226193
# Epoch 200 Loss 1.207264
# Epoch 250 Loss 1.184952
# Epoch 300 Loss 1.175428
# Epoch 350 Loss 1.169977
# Early stopping at epoch 359
# Theta | train1 -> R² = 0.9008, MSE = 2.2653e-02
# X | train1 -> R² = -0.2036, MSE = 1.2978e-01
# Y | train1 -> R² = -1.0372, MSE = 1.7071e-01
# Theta | train2 -> R² = 0.6937, MSE = 6.9921e-02
# X | train2 -> R² = -0.1559, MSE = 9.7395e-02
# Y | train2 -> R² = -0.8999, MSE = 2.0458e-01
# Theta | test1 -> R² = 0.8134, MSE = 4.2863e-02
# X | test1 -> R² = -0.4176, MSE = 1.4851e-01
# Y | test1 -> R² = -1.5264, MSE = 2.0704e-01
# Theta | test2 -> R² = 0.7710, MSE = 5.4302e-02
# X | test2 -> R² = -0.2551, MSE = 1.0329e-01
# Y | test2 -> R² = -1.0044, MSE = 2.1275e-01
# Theta | test3 -> R² = 0.6872, MSE = 1.0283e-01
# X | test3 -> R² = -1.0251, MSE = 1.8632e-01
# Y | test3 -> R² = -3.9483, MSE = 3.8007e-01
# Theta | val -> R² = -1.2071, MSE = 7.2234e-01
# X | val -> R² = -1.3559, MSE = 2.2528e-01
# Y | val -> R² = -4.4649, MSE = 4.0686e-01
# Figura salva em: ./results/model_15_5_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568793
# Epoch 50 Loss 1.284366
# Epoch 100 Loss 1.269571
# Epoch 150 Loss 1.223461
# Epoch 200 Loss 1.180778
# Epoch 250 Loss 1.174957
# Epoch 300 Loss 1.167926
# Epoch 350 Loss 1.164414
# Epoch 400 Loss 1.161223
# Early stopping at epoch 437
# Theta | train1 -> R² = 0.4214, MSE = 1.3207e-01
# X | train1 -> R² = -0.1842, MSE = 1.2769e-01
# Y | train1 -> R² = -1.0306, MSE = 1.7015e-01
# Theta | train2 -> R² = 0.7486, MSE = 5.7388e-02
# X | train2 -> R² = -0.1931, MSE = 1.0053e-01
# Y | train2 -> R² = -0.8142, MSE = 1.9535e-01
# Theta | test1 -> R² = 0.3382, MSE = 1.5202e-01
# X | test1 -> R² = -0.3929, MSE = 1.4592e-01
# Y | test1 -> R² = -1.4829, MSE = 2.0347e-01
# Theta | test2 -> R² = 0.9042, MSE = 2.2711e-02
# X | test2 -> R² = -0.2644, MSE = 1.0405e-01
# Y | test2 -> R² = -0.8847, MSE = 2.0005e-01
# Theta | test3 -> R² = -3.7093, MSE = 1.5482e+00
# X | test3 -> R² = -1.1643, MSE = 1.9913e-01
# Y | test3 -> R² = -3.5563, MSE = 3.4995e-01
# Theta | val -> R² = -4.6848, MSE = 1.8605e+00
# X | val -> R² = -1.0690, MSE = 1.9784e-01
# Y | val -> R² = -3.6524, MSE = 3.4637e-01
# Figura salva em: ./results/model_15_5_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.567763
# Epoch 50 Loss 1.284421
# Epoch 100 Loss 1.257445
# Epoch 150 Loss 1.219774
# Epoch 200 Loss 1.200926
# Epoch 250 Loss 1.167075
# Epoch 300 Loss 1.158719
# Early stopping at epoch 331
# Theta | train1 -> R² = 0.7066, MSE = 6.6980e-02
# X | train1 -> R² = 0.1489, MSE = 9.1773e-02
# Y | train1 -> R² = -0.8480, MSE = 1.5485e-01
# Theta | train2 -> R² = 0.4821, MSE = 1.1823e-01
# X | train2 -> R² = -0.0301, MSE = 8.6794e-02
# Y | train2 -> R² = -0.8884, MSE = 2.0334e-01
# Theta | test1 -> R² = 0.2510, MSE = 1.7207e-01
# X | test1 -> R² = 0.0007, MSE = 1.0469e-01
# Y | test1 -> R² = -1.1607, MSE = 1.7707e-01
# Theta | test2 -> R² = 0.8199, MSE = 4.2709e-02
# X | test2 -> R² = -0.0812, MSE = 8.8974e-02
# Y | test2 -> R² = -0.9734, MSE = 2.0946e-01
# Theta | test3 -> R² = 0.4488, MSE = 1.8121e-01
# X | test3 -> R² = -0.2789, MSE = 1.1767e-01
# Y | test3 -> R² = -3.3010, MSE = 3.3035e-01
# Theta | val -> R² = -6.6043, MSE = 2.4887e+00
# X | val -> R² = -0.4354, MSE = 1.3726e-01
# Y | val -> R² = -2.8437, MSE = 2.8616e-01
# Figura salva em: ./results/model_20_5_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.566350
# Epoch 50 Loss 1.285513
# Epoch 100 Loss 1.262743
# Epoch 150 Loss 1.217446
# Epoch 200 Loss 1.190476
# Epoch 250 Loss 1.178802
# Epoch 300 Loss 1.163230
# Epoch 350 Loss 1.155870
# Epoch 400 Loss 1.151291
# Early stopping at epoch 428
# Theta | train1 -> R² = 0.8634, MSE = 3.1179e-02
# X | train1 -> R² = -0.1121, MSE = 1.1992e-01
# Y | train1 -> R² = -1.0009, MSE = 1.6767e-01
# Theta | train2 -> R² = 0.7935, MSE = 4.7145e-02
# X | train2 -> R² = -0.0977, MSE = 9.2497e-02
# Y | train2 -> R² = -0.7688, MSE = 1.9046e-01
# Theta | test1 -> R² = 0.7647, MSE = 5.4056e-02
# X | test1 -> R² = -0.2605, MSE = 1.3205e-01
# Y | test1 -> R² = -1.3710, MSE = 1.9430e-01
# Theta | test2 -> R² = 0.5484, MSE = 1.0711e-01
# X | test2 -> R² = -0.1650, MSE = 9.5869e-02
# Y | test2 -> R² = -0.8284, MSE = 1.9407e-01
# Theta | test3 -> R² = -0.4666, MSE = 4.8213e-01
# X | test3 -> R² = -1.3879, MSE = 2.1970e-01
# Y | test3 -> R² = -4.0390, MSE = 3.8703e-01
# Theta | val -> R² = -1.4640, MSE = 8.0641e-01
# X | val -> R² = -1.0399, MSE = 1.9506e-01
# Y | val -> R² = -3.2519, MSE = 3.1656e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.567362
# Epoch 50 Loss 1.282084
# Epoch 100 Loss 1.237014
# Epoch 150 Loss 1.183986
# Epoch 200 Loss 1.173281
# Epoch 250 Loss 1.164982
# Epoch 300 Loss 1.159731
# Epoch 350 Loss 1.156817
# Early stopping at epoch 363
# Theta | train1 -> R² = 0.7528, MSE = 5.6432e-02
# X | train1 -> R² = -0.0429, MSE = 1.1245e-01
# Y | train1 -> R² = -0.6304, MSE = 1.3662e-01
# Theta | train2 -> R² = 0.7339, MSE = 6.0761e-02
# X | train2 -> R² = -0.0604, MSE = 8.9348e-02
# Y | train2 -> R² = -0.4985, MSE = 1.6136e-01
# Theta | test1 -> R² = 0.6762, MSE = 7.4390e-02
# X | test1 -> R² = -0.2084, MSE = 1.2659e-01
# Y | test1 -> R² = -0.9696, MSE = 1.6141e-01
# Theta | test2 -> R² = 0.8617, MSE = 3.2796e-02
# X | test2 -> R² = -0.1131, MSE = 9.1597e-02
# Y | test2 -> R² = -0.5566, MSE = 1.6522e-01
# Theta | test3 -> R² = -0.7129, MSE = 5.6311e-01
# X | test3 -> R² = -1.2070, MSE = 2.0305e-01
# Y | test3 -> R² = -3.2923, MSE = 3.2968e-01
# Theta | val -> R² = -1.6271, MSE = 8.5979e-01
# X | val -> R² = -0.6761, MSE = 1.6028e-01
# Y | val -> R² = -2.7636, MSE = 2.8020e-01
# Figura salva em: ./results/model_20_5_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.565957
# Epoch 50 Loss 1.286260
# Epoch 100 Loss 1.273970
# Epoch 150 Loss 1.243233
# Epoch 200 Loss 1.189862
# Epoch 250 Loss 1.174473
# Epoch 300 Loss 1.166373
# Epoch 350 Loss 1.161659
# Epoch 400 Loss 1.157530
# Epoch 450 Loss 1.152304
# Early stopping at epoch 463
# Theta | train1 -> R² = 0.9035, MSE = 2.2022e-02
# X | train1 -> R² = -0.1613, MSE = 1.2522e-01
# Y | train1 -> R² = -0.9730, MSE = 1.6533e-01
# Theta | train2 -> R² = 0.8141, MSE = 4.2435e-02
# X | train2 -> R² = -0.1051, MSE = 9.3112e-02
# Y | train2 -> R² = -0.8221, MSE = 1.9620e-01
# Theta | test1 -> R² = 0.8443, MSE = 3.5776e-02
# X | test1 -> R² = -0.3162, MSE = 1.3789e-01
# Y | test1 -> R² = -1.4151, MSE = 1.9791e-01
# Theta | test2 -> R² = 0.7252, MSE = 6.5163e-02
# X | test2 -> R² = -0.1548, MSE = 9.5031e-02
# Y | test2 -> R² = -0.8296, MSE = 1.9420e-01
# Theta | test3 -> R² = 0.6406, MSE = 1.1816e-01
# X | test3 -> R² = -1.4308, MSE = 2.2365e-01
# Y | test3 -> R² = -3.8482, MSE = 3.7238e-01
# Theta | val -> R² = 0.7598, MSE = 7.8615e-02
# X | val -> R² = -1.1581, MSE = 2.0637e-01
# Y | val -> R² = -3.8906, MSE = 3.6411e-01
# Figura salva em: ./results/model_20_5_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.562920
# Epoch 50 Loss 1.290002
# Epoch 100 Loss 1.250557
# Epoch 150 Loss 1.199310
# Epoch 200 Loss 1.175600
# Epoch 250 Loss 1.164967
# Epoch 300 Loss 1.157009
# Epoch 350 Loss 1.153151
# Epoch 400 Loss 1.149577
# Early stopping at epoch 408
# Theta | train1 -> R² = 0.7932, MSE = 4.7212e-02
# X | train1 -> R² = -0.1180, MSE = 1.2055e-01
# Y | train1 -> R² = -0.8809, MSE = 1.5761e-01
# Theta | train2 -> R² = 0.8192, MSE = 4.1284e-02
# X | train2 -> R² = -0.1268, MSE = 9.4946e-02
# Y | train2 -> R² = -0.7186, MSE = 1.8505e-01
# Theta | test1 -> R² = 0.7620, MSE = 5.4682e-02
# X | test1 -> R² = -0.3163, MSE = 1.3790e-01
# Y | test1 -> R² = -1.3216, MSE = 1.9025e-01
# Theta | test2 -> R² = 0.7182, MSE = 6.6831e-02
# X | test2 -> R² = -0.2148, MSE = 9.9970e-02
# Y | test2 -> R² = -0.8170, MSE = 1.9287e-01
# Theta | test3 -> R² = -2.5243, MSE = 1.1586e+00
# X | test3 -> R² = -0.8048, MSE = 1.6605e-01
# Y | test3 -> R² = -3.1527, MSE = 3.1895e-01
# Theta | val -> R² = -2.9282, MSE = 1.2856e+00
# X | val -> R² = -0.9917, MSE = 1.9045e-01
# Y | val -> R² = -3.3537, MSE = 3.2413e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.576483
# Epoch 50 Loss 1.265391
# Epoch 100 Loss 1.260791
# Epoch 150 Loss 1.212260
# Epoch 200 Loss 1.176898
# Epoch 250 Loss 1.157930
# Epoch 300 Loss 1.146654
# Epoch 350 Loss 1.147012
# Epoch 400 Loss 1.131323
# Early stopping at epoch 428
# Theta | train1 -> R² = 0.8533, MSE = 3.3490e-02
# X | train1 -> R² = -0.0907, MSE = 1.1760e-01
# Y | train1 -> R² = -0.8050, MSE = 1.5125e-01
# Theta | train2 -> R² = 0.7609, MSE = 5.4589e-02
# X | train2 -> R² = -0.0479, MSE = 8.8297e-02
# Y | train2 -> R² = -0.6899, MSE = 1.8197e-01
# Theta | test1 -> R² = 0.7299, MSE = 6.2059e-02
# X | test1 -> R² = -0.1375, MSE = 1.1917e-01
# Y | test1 -> R² = -1.2144, MSE = 1.8146e-01
# Theta | test2 -> R² = 0.7778, MSE = 5.2699e-02
# X | test2 -> R² = -0.1092, MSE = 9.1280e-02
# Y | test2 -> R² = -0.6567, MSE = 1.7585e-01
# Theta | test3 -> R² = -0.8894, MSE = 6.2114e-01
# X | test3 -> R² = -1.8296, MSE = 2.6034e-01
# Y | test3 -> R² = -2.0020, MSE = 2.3057e-01
# Theta | val -> R² = -4.1789, MSE = 1.6950e+00
# X | val -> R² = -1.1193, MSE = 2.0265e-01
# Y | val -> R² = -1.9633, MSE = 2.2062e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.568252
# Epoch 50 Loss 1.270413
# Epoch 100 Loss 1.245152
# Epoch 150 Loss 1.225012
# Epoch 200 Loss 1.177578
# Epoch 250 Loss 1.155240
# Epoch 300 Loss 1.147470
# Epoch 350 Loss 1.138586
# Epoch 400 Loss 1.129818
# Epoch 450 Loss 1.120663
# Early stopping at epoch 459
# Theta | train1 -> R² = 0.5515, MSE = 1.0237e-01
# X | train1 -> R² = -0.2964, MSE = 1.3978e-01
# Y | train1 -> R² = -1.3690, MSE = 1.9851e-01
# Theta | train2 -> R² = 0.0455, MSE = 2.1792e-01
# X | train2 -> R² = -0.1278, MSE = 9.5032e-02
# Y | train2 -> R² = -1.2560, MSE = 2.4292e-01
# Theta | test1 -> R² = 0.5829, MSE = 9.5805e-02
# X | test1 -> R² = -0.4548, MSE = 1.5241e-01
# Y | test1 -> R² = -1.7910, MSE = 2.2872e-01
# Theta | test2 -> R² = -0.1580, MSE = 2.7462e-01
# X | test2 -> R² = -0.2078, MSE = 9.9392e-02
# Y | test2 -> R² = -1.1732, MSE = 2.3067e-01
# Theta | test3 -> R² = 0.4426, MSE = 1.8325e-01
# X | test3 -> R² = -1.9594, MSE = 2.7227e-01
# Y | test3 -> R² = -3.9262, MSE = 3.7837e-01
# Theta | val -> R² = -1.5994, MSE = 8.5075e-01
# X | val -> R² = -1.3325, MSE = 2.2304e-01
# Y | val -> R² = -3.0777, MSE = 3.0358e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.572760
# Epoch 50 Loss 1.261913
# Epoch 100 Loss 1.237688
# Epoch 150 Loss 1.186159
# Epoch 200 Loss 1.154197
# Epoch 250 Loss 1.141929
# Epoch 300 Loss 1.141447
# Epoch 350 Loss 1.133908
# Early stopping at epoch 394
# Theta | train1 -> R² = 0.5454, MSE = 1.0376e-01
# X | train1 -> R² = -0.1243, MSE = 1.2123e-01
# Y | train1 -> R² = -0.9286, MSE = 1.6161e-01
# Theta | train2 -> R² = 0.2877, MSE = 1.6261e-01
# X | train2 -> R² = -0.0898, MSE = 9.1830e-02
# Y | train2 -> R² = -0.6867, MSE = 1.8162e-01
# Theta | test1 -> R² = 0.6410, MSE = 8.2464e-02
# X | test1 -> R² = -0.2300, MSE = 1.2886e-01
# Y | test1 -> R² = -1.4044, MSE = 1.9704e-01
# Theta | test2 -> R² = -0.0077, MSE = 2.3899e-01
# X | test2 -> R² = -0.1263, MSE = 9.2687e-02
# Y | test2 -> R² = -0.6619, MSE = 1.7640e-01
# Theta | test3 -> R² = -1.1066, MSE = 6.9256e-01
# X | test3 -> R² = -1.5432, MSE = 2.3398e-01
# Y | test3 -> R² = -2.8027, MSE = 2.9207e-01
# Theta | val -> R² = -5.2242, MSE = 2.0371e+00
# X | val -> R² = -1.0460, MSE = 1.9564e-01
# Y | val -> R² = -2.6448, MSE = 2.7135e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.581650
# Epoch 50 Loss 1.275673
# Epoch 100 Loss 1.247415
# Epoch 150 Loss 1.223915
# Epoch 200 Loss 1.172843
# Epoch 250 Loss 1.159656
# Epoch 300 Loss 1.146918
# Epoch 350 Loss 1.138226
# Epoch 400 Loss 1.130258
# Epoch 450 Loss 1.124120
# Early stopping at epoch 471
# Theta | train1 -> R² = 0.6890, MSE = 7.0997e-02
# X | train1 -> R² = -0.2512, MSE = 1.3491e-01
# Y | train1 -> R² = -0.8191, MSE = 1.5244e-01
# Theta | train2 -> R² = 0.4578, MSE = 1.2378e-01
# X | train2 -> R² = -0.0272, MSE = 8.6555e-02
# Y | train2 -> R² = -1.0098, MSE = 2.1641e-01
# Theta | test1 -> R² = 0.7685, MSE = 5.3173e-02
# X | test1 -> R² = -0.2773, MSE = 1.3381e-01
# Y | test1 -> R² = -1.2040, MSE = 1.8062e-01
# Theta | test2 -> R² = 0.1646, MSE = 1.9813e-01
# X | test2 -> R² = -0.0790, MSE = 8.8796e-02
# Y | test2 -> R² = -0.9181, MSE = 2.0359e-01
# Theta | test3 -> R² = -3.3989, MSE = 1.4461e+00
# X | test3 -> R² = -1.8403, MSE = 2.6132e-01
# Y | test3 -> R² = -2.6953, MSE = 2.8383e-01
# Theta | val -> R² = -1.1216, MSE = 6.9435e-01
# X | val -> R² = -0.9670, MSE = 1.8809e-01
# Y | val -> R² = -2.9150, MSE = 2.9147e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.577326
# Epoch 50 Loss 1.275708
# Epoch 100 Loss 1.250906
# Epoch 150 Loss 1.239497
# Epoch 200 Loss 1.195380
# Epoch 250 Loss 1.167303
# Epoch 300 Loss 1.150157
# Epoch 350 Loss 1.144178
# Epoch 400 Loss 1.142213
# Epoch 450 Loss 1.130115
# Early stopping at epoch 476
# Theta | train1 -> R² = 0.7915, MSE = 4.7586e-02
# X | train1 -> R² = -0.2443, MSE = 1.3417e-01
# Y | train1 -> R² = -1.0162, MSE = 1.6895e-01
# Theta | train2 -> R² = 0.7572, MSE = 5.5441e-02
# X | train2 -> R² = -0.0673, MSE = 8.9932e-02
# Y | train2 -> R² = -1.1245, MSE = 2.2876e-01
# Theta | test1 -> R² = 0.8311, MSE = 3.8796e-02
# X | test1 -> R² = -0.3609, MSE = 1.4257e-01
# Y | test1 -> R² = -1.6961, MSE = 2.2094e-01
# Theta | test2 -> R² = 0.8988, MSE = 2.4005e-02
# X | test2 -> R² = -0.1148, MSE = 9.1740e-02
# Y | test2 -> R² = -0.9733, MSE = 2.0945e-01
# Theta | test3 -> R² = -1.9503, MSE = 9.6990e-01
# X | test3 -> R² = -2.1451, MSE = 2.8936e-01
# Y | test3 -> R² = -3.6452, MSE = 3.5678e-01
# Theta | val -> R² = -3.9081, MSE = 1.6063e+00
# X | val -> R² = -1.7194, MSE = 2.6004e-01
# Y | val -> R² = -4.0954, MSE = 3.7935e-01
# Figura salva em: ./results/model_64_32_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.574937
# Epoch 50 Loss 1.265704
# Epoch 100 Loss 1.255440
# Epoch 150 Loss 1.236861
# Epoch 200 Loss 1.205104
# Epoch 250 Loss 1.187733
# Epoch 300 Loss 1.162269
# Epoch 350 Loss 1.156863
# Epoch 400 Loss 1.134256
# Early stopping at epoch 442
# Theta | train1 -> R² = 0.5301, MSE = 1.0727e-01
# X | train1 -> R² = 0.1389, MSE = 9.2847e-02
# Y | train1 -> R² = -0.5824, MSE = 1.3259e-01
# Theta | train2 -> R² = -0.0264, MSE = 2.3433e-01
# X | train2 -> R² = 0.1200, MSE = 7.4151e-02
# Y | train2 -> R² = -0.4659, MSE = 1.5784e-01
# Theta | test1 -> R² = 0.4511, MSE = 1.2609e-01
# X | test1 -> R² = 0.1507, MSE = 8.8975e-02
# Y | test1 -> R² = -0.8451, MSE = 1.5120e-01
# Theta | test2 -> R² = -0.3764, MSE = 3.2644e-01
# X | test2 -> R² = 0.0515, MSE = 7.8053e-02
# Y | test2 -> R² = -0.4694, MSE = 1.5597e-01
# Theta | test3 -> R² = 0.5877, MSE = 1.3555e-01
# X | test3 -> R² = -1.4669, MSE = 2.2696e-01
# Y | test3 -> R² = -2.7765, MSE = 2.9006e-01
# Theta | val -> R² = -1.9826, MSE = 9.7614e-01
# X | val -> R² = -0.6813, MSE = 1.6077e-01
# Y | val -> R² = -2.6588, MSE = 2.7239e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.545711
# Epoch 50 Loss 1.260814
# Epoch 100 Loss 1.236181
# Epoch 150 Loss 1.189155
# Epoch 200 Loss 1.162977
# Epoch 250 Loss 1.175752
# Epoch 300 Loss 1.132003
# Epoch 350 Loss 1.127325
# Early stopping at epoch 383
# Theta | train1 -> R² = 0.8026, MSE = 4.5065e-02
# X | train1 -> R² = -0.2709, MSE = 1.3704e-01
# Y | train1 -> R² = -1.2519, MSE = 1.8870e-01
# Theta | train2 -> R² = 0.1859, MSE = 1.8586e-01
# X | train2 -> R² = -0.1870, MSE = 1.0002e-01
# Y | train2 -> R² = -1.1230, MSE = 2.2860e-01
# Theta | test1 -> R² = 0.6190, MSE = 8.7530e-02
# X | test1 -> R² = -0.3071, MSE = 1.3694e-01
# Y | test1 -> R² = -1.6583, MSE = 2.1784e-01
# Theta | test2 -> R² = -0.1275, MSE = 2.6741e-01
# X | test2 -> R² = -0.2639, MSE = 1.0401e-01
# Y | test2 -> R² = -1.1007, MSE = 2.2297e-01
# Theta | test3 -> R² = 0.5692, MSE = 1.4163e-01
# X | test3 -> R² = -2.3630, MSE = 3.0941e-01
# Y | test3 -> R² = -3.5475, MSE = 3.4928e-01
# Theta | val -> R² = -3.1782, MSE = 1.3675e+00
# X | val -> R² = -1.8008, MSE = 2.6783e-01
# Y | val -> R² = -3.6533, MSE = 3.4644e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.549800
# Epoch 50 Loss 1.263765
# Epoch 100 Loss 1.247559
# Epoch 150 Loss 1.237749
# Epoch 200 Loss 1.223773
# Epoch 250 Loss 1.184472
# Epoch 300 Loss 1.162884
# Epoch 350 Loss 1.144902
# Epoch 400 Loss 1.135998
# Epoch 450 Loss 1.128212
# Early stopping at epoch 473
# Theta | train1 -> R² = 0.7146, MSE = 6.5145e-02
# X | train1 -> R² = -0.1735, MSE = 1.2653e-01
# Y | train1 -> R² = -1.0165, MSE = 1.6898e-01
# Theta | train2 -> R² = 0.6923, MSE = 7.0244e-02
# X | train2 -> R² = -0.0688, MSE = 9.0059e-02
# Y | train2 -> R² = -1.0119, MSE = 2.1663e-01
# Theta | test1 -> R² = 0.8489, MSE = 3.4708e-02
# X | test1 -> R² = -0.1978, MSE = 1.2549e-01
# Y | test1 -> R² = -1.4671, MSE = 2.0217e-01
# Theta | test2 -> R² = 0.6041, MSE = 9.3883e-02
# X | test2 -> R² = -0.1552, MSE = 9.5064e-02
# Y | test2 -> R² = -0.9453, MSE = 2.0648e-01
# Theta | test3 -> R² = -0.9670, MSE = 6.4665e-01
# X | test3 -> R² = -2.0881, MSE = 2.8412e-01
# Y | test3 -> R² = -3.6049, MSE = 3.5369e-01
# Theta | val -> R² = -2.9579, MSE = 1.2954e+00
# X | val -> R² = -1.0503, MSE = 1.9606e-01
# Y | val -> R² = -3.6190, MSE = 3.4388e-01
# Figura salva em: ./results/model_128_64_2.pdf
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.560222
# Epoch 50 Loss 1.265767
# Epoch 100 Loss 1.246429
# Epoch 150 Loss 1.245934
# Epoch 200 Loss 1.180840
# Epoch 250 Loss 1.157028
# Epoch 300 Loss 1.146184
# Epoch 350 Loss 1.150096
# Epoch 400 Loss 1.129503
# Early stopping at epoch 419
# Theta | train1 -> R² = -12.1361, MSE = 2.9985e+00
# X | train1 -> R² = -0.5264, MSE = 1.6458e-01
# Y | train1 -> R² = -0.7739, MSE = 1.4865e-01
# Theta | train2 -> R² = -17.4794, MSE = 4.2189e+00
# X | train2 -> R² = -0.2799, MSE = 1.0785e-01
# Y | train2 -> R² = -0.7180, MSE = 1.8499e-01
# Theta | test1 -> R² = -11.7370, MSE = 2.9259e+00
# X | test1 -> R² = -0.7626, MSE = 1.8465e-01
# Y | test1 -> R² = -1.1956, MSE = 1.7992e-01
# Theta | test2 -> R² = -18.9406, MSE = 4.7291e+00
# X | test2 -> R² = -0.3234, MSE = 1.0891e-01
# Y | test2 -> R² = -0.6764, MSE = 1.7794e-01
# Theta | test3 -> R² = -1.5156, MSE = 8.2701e-01
# X | test3 -> R² = -2.2661, MSE = 3.0050e-01
# Y | test3 -> R² = -2.1965, MSE = 2.4552e-01
# Theta | val -> R² = 0.0653, MSE = 3.0590e-01
# X | val -> R² = -2.1242, MSE = 2.9875e-01
# Y | val -> R² = -2.5897, MSE = 2.6726e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.550716
# Epoch 50 Loss 1.312851
# Epoch 100 Loss 1.248757
# Epoch 150 Loss 1.237288
# Epoch 200 Loss 1.191990
# Epoch 250 Loss 1.158051
# Epoch 300 Loss 1.141100
# Epoch 350 Loss 1.169705
# Epoch 400 Loss 1.156718
# Early stopping at epoch 407
# Theta | train1 -> R² = 0.8823, MSE = 2.6863e-02
# X | train1 -> R² = -0.2341, MSE = 1.3307e-01
# Y | train1 -> R² = -0.9143, MSE = 1.6041e-01
# Theta | train2 -> R² = 0.5631, MSE = 9.9742e-02
# X | train2 -> R² = -0.1179, MSE = 9.4198e-02
# Y | train2 -> R² = -0.8545, MSE = 1.9969e-01
# Theta | test1 -> R² = 0.8927, MSE = 2.4641e-02
# X | test1 -> R² = -0.2839, MSE = 1.3450e-01
# Y | test1 -> R² = -1.3302, MSE = 1.9096e-01
# Theta | test2 -> R² = 0.7095, MSE = 6.8906e-02
# X | test2 -> R² = -0.2140, MSE = 9.9903e-02
# Y | test2 -> R² = -0.8124, MSE = 1.9237e-01
# Theta | test3 -> R² = 0.5643, MSE = 1.4324e-01
# X | test3 -> R² = -2.3300, MSE = 3.0638e-01
# Y | test3 -> R² = -2.7685, MSE = 2.8945e-01
# Theta | val -> R² = -1.2382, MSE = 7.3253e-01
# X | val -> R² = -1.6170, MSE = 2.5024e-01
# Y | val -> R² = -2.5793, MSE = 2.6648e-01
# Figura salva em: ./results/model_128_64_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.579979
# Epoch 50 Loss 1.234770
# Epoch 100 Loss 1.214754
# Epoch 150 Loss 1.178346
# Epoch 200 Loss 1.159014
# Epoch 250 Loss 1.163296
# Epoch 300 Loss 1.132962
# Early stopping at epoch 322
# Theta | train1 -> R² = 0.5104, MSE = 1.1176e-01
# X | train1 -> R² = -0.2844, MSE = 1.3850e-01
# Y | train1 -> R² = -0.3276, MSE = 1.1125e-01
# Theta | train2 -> R² = 0.7086, MSE = 6.6522e-02
# X | train2 -> R² = -1.3121, MSE = 1.9482e-01
# Y | train2 -> R² = -0.8782, MSE = 2.0224e-01
# Theta | test1 -> R² = 0.4063, MSE = 1.3640e-01
# X | test1 -> R² = -0.2369, MSE = 1.2958e-01
# Y | test1 -> R² = -0.4896, MSE = 1.2207e-01
# Theta | test2 -> R² = 0.8641, MSE = 3.2219e-02
# X | test2 -> R² = -1.1723, MSE = 1.7876e-01
# Y | test2 -> R² = -0.9164, MSE = 2.0341e-01
# Theta | test3 -> R² = -20.5667, MSE = 7.0900e+00
# X | test3 -> R² = -0.1059, MSE = 1.0175e-01
# Y | test3 -> R² = -1.9879, MSE = 2.2950e-01
# Theta | val -> R² = -14.8726, MSE = 5.1948e+00
# X | val -> R² = -0.4356, MSE = 1.3727e-01
# Y | val -> R² = -1.2490, MSE = 1.6744e-01
# Figura salva em: ./results/model_264_128_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.528168
# Epoch 50 Loss 1.226641
# Epoch 100 Loss 1.181833
# Epoch 150 Loss 1.164893
# Epoch 200 Loss 1.156571
# Epoch 250 Loss 1.156246
# Epoch 300 Loss 1.150631
# Early stopping at epoch 306
# Theta | train1 -> R² = -32.1919, MSE = 7.5766e+00
# X | train1 -> R² = -1.6020, MSE = 2.8057e-01
# Y | train1 -> R² = -12.2069, MSE = 1.1067e+00
# Theta | train2 -> R² = -35.4917, MSE = 8.3312e+00
# X | train2 -> R² = -2.0710, MSE = 2.5876e-01
# Y | train2 -> R² = -11.4062, MSE = 1.3359e+00
# Theta | test1 -> R² = -29.2656, MSE = 6.9526e+00
# X | test1 -> R² = -1.8322, MSE = 2.9671e-01
# Y | test1 -> R² = -12.8076, MSE = 1.1315e+00
# Theta | test2 -> R² = -33.5303, MSE = 8.1892e+00
# X | test2 -> R² = -2.4406, MSE = 2.8314e-01
# Y | test2 -> R² = -11.4434, MSE = 1.3208e+00
# Theta | test3 -> R² = -12.4644, MSE = 4.4264e+00
# X | test3 -> R² = -8.4866, MSE = 8.7280e-01
# Y | test3 -> R² = -23.9017, MSE = 1.9126e+00
# Theta | val -> R² = -0.1234, MSE = 3.6766e-01
# X | val -> R² = -3.5391, MSE = 4.3404e-01
# Y | val -> R² = -17.8014, MSE = 1.3998e+00
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.599072
# Epoch 50 Loss 1.246720
# Epoch 100 Loss 1.204923
# Epoch 150 Loss 1.188653
# Epoch 200 Loss 1.161319
# Epoch 250 Loss 1.156073
# Epoch 300 Loss 1.147133
# Early stopping at epoch 336
# Theta | train1 -> R² = -1.9563, MSE = 6.7483e-01
# X | train1 -> R² = 0.4110, MSE = 6.3515e-02
# Y | train1 -> R² = -0.7082, MSE = 1.4314e-01
# Theta | train2 -> R² = -1.0712, MSE = 4.7285e-01
# X | train2 -> R² = -0.0048, MSE = 8.4662e-02
# Y | train2 -> R² = -0.5465, MSE = 1.6653e-01
# Theta | test1 -> R² = -1.5145, MSE = 5.7763e-01
# X | test1 -> R² = 0.3203, MSE = 7.1202e-02
# Y | test1 -> R² = -0.9692, MSE = 1.6137e-01
# Theta | test2 -> R² = 0.0125, MSE = 2.3418e-01
# X | test2 -> R² = -0.0114, MSE = 8.3232e-02
# Y | test2 -> R² = -0.5160, MSE = 1.6091e-01
# Theta | test3 -> R² = -23.8816, MSE = 8.1798e+00
# X | test3 -> R² = -0.4277, MSE = 1.3135e-01
# Y | test3 -> R² = -3.1823, MSE = 3.2123e-01
# Theta | val -> R² = -2.7087, MSE = 1.2138e+00
# X | val -> R² = -0.1522, MSE = 1.1018e-01
# Y | val -> R² = -2.4376, MSE = 2.5593e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.594906
# Epoch 50 Loss 1.230471
# Epoch 100 Loss 1.201698
# Epoch 150 Loss 1.181732
# Epoch 200 Loss 1.152470
# Epoch 250 Loss 1.148376
# Epoch 300 Loss 1.149303
# Early stopping at epoch 320
# Theta | train1 -> R² = 0.1184, MSE = 2.0125e-01
# X | train1 -> R² = 0.1403, MSE = 9.2692e-02
# Y | train1 -> R² = -0.3525, MSE = 1.1333e-01
# Theta | train2 -> R² = -0.2664, MSE = 2.8912e-01
# X | train2 -> R² = -0.2804, MSE = 1.0788e-01
# Y | train2 -> R² = -0.2418, MSE = 1.3371e-01
# Theta | test1 -> R² = 0.2687, MSE = 1.6800e-01
# X | test1 -> R² = 0.1054, MSE = 9.3723e-02
# Y | test1 -> R² = -0.5556, MSE = 1.2748e-01
# Theta | test2 -> R² = -0.7834, MSE = 4.2295e-01
# X | test2 -> R² = -0.2710, MSE = 1.0460e-01
# Y | test2 -> R² = -0.2492, MSE = 1.3259e-01
# Theta | test3 -> R² = -12.0101, MSE = 4.2770e+00
# X | test3 -> R² = -0.0368, MSE = 9.5387e-02
# Y | test3 -> R² = -1.3902, MSE = 1.8358e-01
# Theta | val -> R² = -2.7921, MSE = 1.2411e+00
# X | val -> R² = 0.1095, MSE = 8.5152e-02
# Y | val -> R² = -1.7065, MSE = 2.0150e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.597934
# Epoch 50 Loss 1.263929
# Epoch 100 Loss 1.207069
# Epoch 150 Loss 1.156737
# Epoch 200 Loss 1.145115
# Epoch 250 Loss 1.143412
# Epoch 300 Loss 1.134085
# Epoch 350 Loss 1.137060
# Early stopping at epoch 389
# Theta | train1 -> R² = -0.7956, MSE = 4.0987e-01
# X | train1 -> R² = -0.4956, MSE = 1.6126e-01
# Y | train1 -> R² = -1.9485, MSE = 2.4707e-01
# Theta | train2 -> R² = -2.2025, MSE = 7.3113e-01
# X | train2 -> R² = -0.5039, MSE = 1.2672e-01
# Y | train2 -> R² = -1.5692, MSE = 2.7665e-01
# Theta | test1 -> R² = -1.1031, MSE = 4.8313e-01
# X | test1 -> R² = -0.5720, MSE = 1.6468e-01
# Y | test1 -> R² = -2.5780, MSE = 2.9321e-01
# Theta | test2 -> R² = -3.1082, MSE = 9.7429e-01
# X | test2 -> R² = -0.5017, MSE = 1.2358e-01
# Y | test2 -> R² = -1.6180, MSE = 2.7788e-01
# Theta | test3 -> R² = -0.3001, MSE = 4.2741e-01
# X | test3 -> R² = -3.7125, MSE = 4.3357e-01
# Y | test3 -> R² = -4.6793, MSE = 4.3621e-01
# Theta | val -> R² = -2.9387, MSE = 1.2891e+00
# X | val -> R² = -2.6091, MSE = 3.4511e-01
# Y | val -> R² = -5.4072, MSE = 4.7702e-01
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.570735
# Epoch 50 Loss 1.267872
# Epoch 100 Loss 1.198024
# Epoch 150 Loss 1.163024
# Epoch 200 Loss 1.168399
# Epoch 250 Loss 1.145677
# Epoch 300 Loss 1.135259
# Epoch 350 Loss 1.132983
# Early stopping at epoch 362
# Theta | train1 -> R² = 0.9202, MSE = 1.8219e-02
# X | train1 -> R² = -0.2006, MSE = 1.2946e-01
# Y | train1 -> R² = -0.9326, MSE = 1.6194e-01
# Theta | train2 -> R² = 0.8101, MSE = 4.3352e-02
# X | train2 -> R² = -0.1465, MSE = 9.6608e-02
# Y | train2 -> R² = -0.9625, MSE = 2.1131e-01
# Theta | test1 -> R² = 0.7727, MSE = 5.2220e-02
# X | test1 -> R² = -0.3532, MSE = 1.4177e-01
# Y | test1 -> R² = -1.3742, MSE = 1.9456e-01
# Theta | test2 -> R² = 0.8319, MSE = 3.9875e-02
# X | test2 -> R² = -0.2340, MSE = 1.0155e-01
# Y | test2 -> R² = -1.0093, MSE = 2.1327e-01
# Theta | test3 -> R² = -0.3023, MSE = 4.2813e-01
# X | test3 -> R² = -0.9608, MSE = 1.8040e-01
# Y | test3 -> R² = -2.6951, MSE = 2.8381e-01
# Theta | val -> R² = -2.3304, MSE = 1.0900e+00
# X | val -> R² = -1.0827, MSE = 1.9916e-01
# Y | val -> R² = -3.4762, MSE = 3.3325e-01
# Figura salva em: ./results/model_62_32_16_0.pdf
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.562432
# Epoch 50 Loss 1.273660
# Epoch 100 Loss 1.229863
# Epoch 150 Loss 1.186276
# Epoch 200 Loss 1.152226
# Epoch 250 Loss 1.149041
# Epoch 300 Loss 1.134629
# Epoch 350 Loss 1.129099
# Epoch 400 Loss 1.125609
# Early stopping at epoch 413
# Theta | train1 -> R² = -3.1607, MSE = 9.4975e-01
# X | train1 -> R² = 0.3500, MSE = 7.0087e-02
# Y | train1 -> R² = -0.5900, MSE = 1.3324e-01
# Theta | train2 -> R² = -2.8610, MSE = 8.8147e-01
# X | train2 -> R² = 0.0315, MSE = 8.1610e-02
# Y | train2 -> R² = -0.3951, MSE = 1.5022e-01
# Theta | test1 -> R² = -3.0174, MSE = 9.2287e-01
# X | test1 -> R² = 0.2892, MSE = 7.4460e-02
# Y | test1 -> R² = -1.1896, MSE = 1.7943e-01
# Theta | test2 -> R² = -1.8707, MSE = 6.8081e-01
# X | test2 -> R² = 0.0491, MSE = 7.8249e-02
# Y | test2 -> R² = -0.4182, MSE = 1.5054e-01
# Theta | test3 -> R² = -9.9565, MSE = 3.6019e+00
# X | test3 -> R² = -0.4201, MSE = 1.3066e-01
# Y | test3 -> R² = -1.0061, MSE = 1.5408e-01
# Theta | val -> R² = -4.5291, MSE = 1.8096e+00
# X | val -> R² = -0.4018, MSE = 1.3404e-01
# Y | val -> R² = -1.7697, MSE = 2.0620e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.569993
# Epoch 50 Loss 1.273343
# Epoch 100 Loss 1.232927
# Epoch 150 Loss 1.185051
# Epoch 200 Loss 1.163355
# Epoch 250 Loss 1.146341
# Epoch 300 Loss 1.152488
# Epoch 350 Loss 1.129261
# Early stopping at epoch 379
# Theta | train1 -> R² = 0.0020, MSE = 2.2780e-01
# X | train1 -> R² = -0.0600, MSE = 1.1430e-01
# Y | train1 -> R² = -0.7472, MSE = 1.4641e-01
# Theta | train2 -> R² = -0.2737, MSE = 2.9078e-01
# X | train2 -> R² = -0.0350, MSE = 8.7208e-02
# Y | train2 -> R² = -0.7185, MSE = 1.8504e-01
# Theta | test1 -> R² = 0.0041, MSE = 2.2878e-01
# X | test1 -> R² = -0.2202, MSE = 1.2783e-01
# Y | test1 -> R² = -1.2604, MSE = 1.8524e-01
# Theta | test2 -> R² = -0.9094, MSE = 4.5284e-01
# X | test2 -> R² = -0.1146, MSE = 9.1726e-02
# Y | test2 -> R² = -0.7527, MSE = 1.8603e-01
# Theta | test3 -> R² = 0.2021, MSE = 2.6232e-01
# X | test3 -> R² = -0.8561, MSE = 1.7076e-01
# Y | test3 -> R² = -2.0442, MSE = 2.3382e-01
# Theta | val -> R² = -0.9532, MSE = 6.3923e-01
# X | val -> R² = -1.2910, MSE = 2.1908e-01
# Y | val -> R² = -3.0248, MSE = 2.9965e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.568041
# Epoch 50 Loss 1.273457
# Epoch 100 Loss 1.236485
# Epoch 150 Loss 1.175895
# Epoch 200 Loss 1.156935
# Epoch 250 Loss 1.146618
# Epoch 300 Loss 1.134905
# Epoch 350 Loss 1.127813
# Early stopping at epoch 381
# Theta | train1 -> R² = 0.8009, MSE = 4.5444e-02
# X | train1 -> R² = -0.0531, MSE = 1.1355e-01
# Y | train1 -> R² = -0.7810, MSE = 1.4924e-01
# Theta | train2 -> R² = 0.6369, MSE = 8.2894e-02
# X | train2 -> R² = -0.0812, MSE = 9.1105e-02
# Y | train2 -> R² = -0.6202, MSE = 1.7446e-01
# Theta | test1 -> R² = 0.7435, MSE = 5.8919e-02
# X | test1 -> R² = -0.1548, MSE = 1.2098e-01
# Y | test1 -> R² = -1.2047, MSE = 1.8068e-01
# Theta | test2 -> R² = 0.2771, MSE = 1.7145e-01
# X | test2 -> R² = -0.1558, MSE = 9.5116e-02
# Y | test2 -> R² = -0.6371, MSE = 1.7376e-01
# Theta | test3 -> R² = 0.0344, MSE = 3.1744e-01
# X | test3 -> R² = -2.1623, MSE = 2.9095e-01
# Y | test3 -> R² = -2.7466, MSE = 2.8777e-01
# Theta | val -> R² = -2.3259, MSE = 1.0885e+00
# X | val -> R² = -1.2103, MSE = 2.1135e-01
# Y | val -> R² = -2.8229, MSE = 2.8462e-01
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.568761
# Epoch 50 Loss 1.265896
# Epoch 100 Loss 1.211354
# Epoch 150 Loss 1.200667
# Epoch 200 Loss 1.145903
# Epoch 250 Loss 1.142598
# Epoch 300 Loss 1.137691
# Epoch 350 Loss 1.126753
# Early stopping at epoch 357
# Theta | train1 -> R² = 0.7585, MSE = 5.5136e-02
# X | train1 -> R² = -0.2571, MSE = 1.3555e-01
# Y | train1 -> R² = -1.0995, MSE = 1.7593e-01
# Theta | train2 -> R² = 0.6948, MSE = 6.9667e-02
# X | train2 -> R² = -0.2831, MSE = 1.0811e-01
# Y | train2 -> R² = -0.9531, MSE = 2.1031e-01
# Theta | test1 -> R² = 0.5602, MSE = 1.0103e-01
# X | test1 -> R² = -0.3851, MSE = 1.4511e-01
# Y | test1 -> R² = -1.5435, MSE = 2.0844e-01
# Theta | test2 -> R² = 0.9024, MSE = 2.3137e-02
# X | test2 -> R² = -0.3854, MSE = 1.1401e-01
# Y | test2 -> R² = -0.9723, MSE = 2.0934e-01
# Theta | test3 -> R² = -1.4670, MSE = 8.1103e-01
# X | test3 -> R² = -1.6233, MSE = 2.4135e-01
# Y | test3 -> R² = -3.3555, MSE = 3.3454e-01
# Theta | val -> R² = -5.5427, MSE = 2.1413e+00
# X | val -> R² = -1.3499, MSE = 2.2470e-01
# Y | val -> R² = -3.3450, MSE = 3.2349e-01
# Figura salva em: ./results/model_62_32_16_4.pdf
# Modelo 4 treinado e salvo no Excel
# Epoch 0 Loss 1.586738
# Epoch 50 Loss 1.261281
# Epoch 100 Loss 1.223322
# Epoch 150 Loss 1.188857
# Epoch 200 Loss 1.171741
# Epoch 250 Loss 1.138997
# Epoch 300 Loss 1.134469
# Epoch 350 Loss 1.126833
# Early stopping at epoch 395
# Theta | train1 -> R² = -0.3344, MSE = 3.0460e-01
# X | train1 -> R² = 0.0092, MSE = 1.0684e-01
# Y | train1 -> R² = -0.9883, MSE = 1.6661e-01
# Theta | train2 -> R² = -1.5829, MSE = 5.8968e-01
# X | train2 -> R² = -0.0162, MSE = 8.5624e-02
# Y | train2 -> R² = -0.9313, MSE = 2.0796e-01
# Theta | test1 -> R² = -0.4561, MSE = 3.3448e-01
# X | test1 -> R² = -0.0850, MSE = 1.1366e-01
# Y | test1 -> R² = -1.5541, MSE = 2.0931e-01
# Theta | test2 -> R² = -0.3083, MSE = 3.1027e-01
# X | test2 -> R² = -0.0760, MSE = 8.8549e-02
# Y | test2 -> R² = -0.8852, MSE = 2.0011e-01
# Theta | test3 -> R² = -1.9272, MSE = 9.6232e-01
# X | test3 -> R² = -1.3922, MSE = 2.2009e-01
# Y | test3 -> R² = -2.9195, MSE = 3.0104e-01
# Theta | val -> R² = -4.0144, MSE = 1.6411e+00
# X | val -> R² = -0.9224, MSE = 1.8383e-01
# Y | val -> R² = -3.3210, MSE = 3.2170e-01
# Modelo 0 treinado e salvo no Excel
# Epoch 0 Loss 1.545786
# Epoch 50 Loss 1.255535
# Epoch 100 Loss 1.385768
# Epoch 150 Loss 1.181652
# Epoch 200 Loss 1.152340
# Epoch 250 Loss 1.153152
# Epoch 300 Loss 1.144277
# Epoch 350 Loss 1.132915
# Early stopping at epoch 361
# Theta | train1 -> R² = 0.2606, MSE = 1.6878e-01
# X | train1 -> R² = -0.0303, MSE = 1.1110e-01
# Y | train1 -> R² = -1.1201, MSE = 1.7765e-01
# Theta | train2 -> R² = -0.3373, MSE = 3.0531e-01
# X | train2 -> R² = -0.0576, MSE = 8.9112e-02
# Y | train2 -> R² = -1.0057, MSE = 2.1597e-01
# Theta | test1 -> R² = 0.4962, MSE = 1.1572e-01
# X | test1 -> R² = -0.1670, MSE = 1.2226e-01
# Y | test1 -> R² = -1.6882, MSE = 2.2030e-01
# Theta | test2 -> R² = 0.2594, MSE = 1.7563e-01
# X | test2 -> R² = -0.1153, MSE = 9.1783e-02
# Y | test2 -> R² = -0.9930, MSE = 2.1155e-01
# Theta | test3 -> R² = -1.2451, MSE = 7.3807e-01
# X | test3 -> R² = -1.2016, MSE = 2.0255e-01
# Y | test3 -> R² = -2.6626, MSE = 2.8132e-01
# Theta | val -> R² = -3.7089, MSE = 1.5411e+00
# X | val -> R² = -0.9781, MSE = 1.8915e-01
# Y | val -> R² = -3.5438, MSE = 3.3829e-01
# Modelo 1 treinado e salvo no Excel
# Epoch 0 Loss 1.561930
# Epoch 50 Loss 1.265392
# Epoch 100 Loss 1.238590
# Epoch 150 Loss 1.199214
# Epoch 200 Loss 1.159925
# Epoch 250 Loss 1.141278
# Epoch 300 Loss 1.144584
# Epoch 350 Loss 1.166177
# Early stopping at epoch 380
# Theta | train1 -> R² = 0.6721, MSE = 7.4849e-02
# X | train1 -> R² = -0.5270, MSE = 1.6465e-01
# Y | train1 -> R² = -1.2935, MSE = 1.9218e-01
# Theta | train2 -> R² = 0.2963, MSE = 1.6065e-01
# X | train2 -> R² = -0.4723, MSE = 1.2405e-01
# Y | train2 -> R² = -1.3166, MSE = 2.4945e-01
# Theta | test1 -> R² = 0.5432, MSE = 1.0493e-01
# X | test1 -> R² = -0.6456, MSE = 1.7240e-01
# Y | test1 -> R² = -1.8801, MSE = 2.3602e-01
# Theta | test2 -> R² = 0.2040, MSE = 1.8877e-01
# X | test2 -> R² = -0.5778, MSE = 1.2984e-01
# Y | test2 -> R² = -1.2118, MSE = 2.3476e-01
# Theta | test3 -> R² = 0.6228, MSE = 1.2400e-01
# X | test3 -> R² = -2.8380, MSE = 3.5311e-01
# Y | test3 -> R² = -3.0355, MSE = 3.0996e-01
# Theta | val -> R² = -3.9071, MSE = 1.6060e+00
# X | val -> R² = -2.1085, MSE = 2.9724e-01
# Y | val -> R² = -3.6362, MSE = 3.4517e-01
# Modelo 2 treinado e salvo no Excel
# Epoch 0 Loss 1.572797
# Epoch 50 Loss 1.255567
# Epoch 100 Loss 1.224076
# Epoch 150 Loss 1.193093
# Epoch 200 Loss 1.154442
# Epoch 250 Loss 1.142758
# Epoch 300 Loss 1.131141
# Early stopping at epoch 306
# Theta | train1 -> R² = 0.8919, MSE = 2.4683e-02
# X | train1 -> R² = 0.1357, MSE = 9.3190e-02
# Y | train1 -> R² = -1.4745, MSE = 2.0735e-01
# Theta | train2 -> R² = 0.0214, MSE = 2.2341e-01
# X | train2 -> R² = -0.0328, MSE = 8.7021e-02
# Y | train2 -> R² = -1.4718, MSE = 2.6616e-01
# Theta | test1 -> R² = 0.8223, MSE = 4.0828e-02
# X | test1 -> R² = 0.0302, MSE = 1.0160e-01
# Y | test1 -> R² = -1.7418, MSE = 2.2469e-01
# Theta | test2 -> R² = 0.4698, MSE = 1.2575e-01
# X | test2 -> R² = -0.1063, MSE = 9.1044e-02
# Y | test2 -> R² = -1.4590, MSE = 2.6100e-01
# Theta | test3 -> R² = 0.7967, MSE = 6.6832e-02
# X | test3 -> R² = -1.5310, MSE = 2.3286e-01
# Y | test3 -> R² = -4.5866, MSE = 4.2909e-01
# Theta | val -> R² = -2.9139, MSE = 1.2810e+00
# X | val -> R² = -0.4856, MSE = 1.4206e-01
# Y | val -> R² = -3.9676, MSE = 3.6984e-01
# Figura salva em: ./results/model_128_64_32_3.pdf
# Modelo 3 treinado e salvo no Excel
# Epoch 0 Loss 1.564776
# Epoch 50 Loss 1.282743
# Epoch 100 Loss 1.240392
# Epoch 150 Loss 1.168954
# Epoch 200 Loss 1.160287
# Epoch 250 Loss 1.143139
# Epoch 300 Loss 1.134908
# Epoch 350 Loss 1.126095
# Early stopping at epoch 383
# Theta | train1 -> R² = 0.9156, MSE = 1.9266e-02
# X | train1 -> R² = -0.0663, MSE = 1.1498e-01
# Y | train1 -> R² = -0.8556, MSE = 1.5549e-01
# Theta | train2 -> R² = 0.3467, MSE = 1.4915e-01
# X | train2 -> R² = -0.0918, MSE = 9.1995e-02
# Y | train2 -> R² = -0.7039, MSE = 1.8347e-01
# Theta | test1 -> R² = 0.9299, MSE = 1.6096e-02
# X | test1 -> R² = -0.1729, MSE = 1.2288e-01
# Y | test1 -> R² = -1.2270, MSE = 1.8250e-01
# Theta | test2 -> R² = 0.7100, MSE = 6.8787e-02
# X | test2 -> R² = -0.1759, MSE = 9.6766e-02
# Y | test2 -> R² = -0.6684, MSE = 1.7709e-01
# Theta | test3 -> R² = 0.5201, MSE = 1.5776e-01
# X | test3 -> R² = -1.8199, MSE = 2.5944e-01
# Y | test3 -> R² = -3.1315, MSE = 3.1733e-01
# Theta | val -> R² = -3.2433, MSE = 1.3888e+00
# X | val -> R² = -1.3372, MSE = 2.2349e-01
# Y | val -> R² = -3.0935, MSE = 3.0476e-01
# Figura salva em: ./results/model_128_64_32_4.pdf
# Modelo 4 treinado e salvo no Excel
