# %% [markdown]
# - Entradas: PwmD, PwmE, Theta
# - Saidas: X
# - Trajetorias: ZZ + ZZr

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE", "Theta"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 0.502002 | Val Loss 0.604195
# Epoch 100 | Train Loss 0.303221 | Val Loss 0.459080
# Epoch 200 | Train Loss 0.296618 | Val Loss 0.442543
# Epoch 300 | Train Loss 0.293566 | Val Loss 0.426166
# Epoch 400 | Train Loss 0.292335 | Val Loss 0.418330
# Epoch 500 | Train Loss 0.291430 | Val Loss 0.412544
# Epoch 600 | Train Loss 0.290451 | Val Loss 0.406955
# Epoch 700 | Train Loss 0.289774 | Val Loss 0.404804
# Epoch 800 | Train Loss 0.289288 | Val Loss 0.403317
# Epoch 900 | Train Loss 0.288818 | Val Loss 0.402359
# Epoch 1000 | Train Loss 0.288356 | Val Loss 0.403778
# Epoch 1100 | Train Loss 0.287917 | Val Loss 0.406597
# Early stopping at epoch 1159
# X | train1 -> R² = -0.0384, MSE = 1.1196e-01
# X | train2 -> R² = -7.1172, MSE = 6.8396e-01
# X | test1 -> R² = -0.1010, MSE = 1.1535e-01
# X | test2 -> R² = -6.9022, MSE = 6.5030e-01
# X | test3 -> R² = 0.8506, MSE = 1.3745e-02
# X | val -> R² = -0.1230, MSE = 1.0739e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.514883 | Val Loss 0.665180
# Epoch 100 | Train Loss 0.307034 | Val Loss 0.470205
# Epoch 200 | Train Loss 0.299034 | Val Loss 0.446836
# Epoch 300 | Train Loss 0.294436 | Val Loss 0.423381
# Epoch 400 | Train Loss 0.292329 | Val Loss 0.407630
# Epoch 500 | Train Loss 0.291189 | Val Loss 0.404737
# Epoch 600 | Train Loss 0.290075 | Val Loss 0.406351
# Epoch 700 | Train Loss 0.289375 | Val Loss 0.408935
# Early stopping at epoch 732
# X | train1 -> R² = -0.0607, MSE = 1.1437e-01
# X | train2 -> R² = -7.4310, MSE = 7.1040e-01
# X | test1 -> R² = -0.0503, MSE = 1.1003e-01
# X | test2 -> R² = -7.1204, MSE = 6.6826e-01
# X | test3 -> R² = 0.9265, MSE = 6.7624e-03
# X | val -> R² = -0.1671, MSE = 1.1160e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.515273 | Val Loss 0.650600
# Epoch 100 | Train Loss 0.304664 | Val Loss 0.481267
# Epoch 200 | Train Loss 0.298720 | Val Loss 0.450425
# Epoch 300 | Train Loss 0.295577 | Val Loss 0.431854
# Epoch 400 | Train Loss 0.293301 | Val Loss 0.416485
# Epoch 500 | Train Loss 0.291290 | Val Loss 0.407564
# Epoch 600 | Train Loss 0.289983 | Val Loss 0.410047
# Epoch 700 | Train Loss 0.289389 | Val Loss 0.412127
# Early stopping at epoch 800
# X | train1 -> R² = -0.0449, MSE = 1.1266e-01
# X | train2 -> R² = -7.3802, MSE = 7.0612e-01
# X | test1 -> R² = -0.0651, MSE = 1.1158e-01
# X | test2 -> R² = -7.0668, MSE = 6.6384e-01
# X | test3 -> R² = 0.8654, MSE = 1.2382e-02
# X | val -> R² = -0.4661, MSE = 1.4019e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.519157 | Val Loss 0.684609
# Epoch 100 | Train Loss 0.304619 | Val Loss 0.466366
# Epoch 200 | Train Loss 0.298375 | Val Loss 0.447463
# Epoch 300 | Train Loss 0.295074 | Val Loss 0.429730
# Epoch 400 | Train Loss 0.292815 | Val Loss 0.415972
# Epoch 500 | Train Loss 0.291434 | Val Loss 0.408247
# Epoch 600 | Train Loss 0.290317 | Val Loss 0.403530
# Epoch 700 | Train Loss 0.289570 | Val Loss 0.402602
# Epoch 800 | Train Loss 0.289045 | Val Loss 0.401718
# Epoch 900 | Train Loss 0.288667 | Val Loss 0.399575
# Epoch 1000 | Train Loss 0.288352 | Val Loss 0.398253
# Epoch 1100 | Train Loss 0.288026 | Val Loss 0.397148
# Epoch 1200 | Train Loss 0.287644 | Val Loss 0.395711
# Epoch 1300 | Train Loss 0.287159 | Val Loss 0.393820
# Epoch 1400 | Train Loss 0.286561 | Val Loss 0.392150
# Epoch 1500 | Train Loss 0.285919 | Val Loss 0.391756
# Epoch 1600 | Train Loss 0.285353 | Val Loss 0.392695
# Early stopping at epoch 1673
# X | train1 -> R² = -0.0244, MSE = 1.1045e-01
# X | train2 -> R² = -7.2074, MSE = 6.9156e-01
# X | test1 -> R² = -0.2153, MSE = 1.2732e-01
# X | test2 -> R² = -6.9341, MSE = 6.5292e-01
# X | test3 -> R² = 0.8772, MSE = 1.1302e-02
# X | val -> R² = 0.3546, MSE = 6.1718e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.501123 | Val Loss 0.625159
# Epoch 100 | Train Loss 0.302609 | Val Loss 0.465004
# Epoch 200 | Train Loss 0.297418 | Val Loss 0.444093
# Epoch 300 | Train Loss 0.294220 | Val Loss 0.425202
# Epoch 400 | Train Loss 0.292519 | Val Loss 0.413608
# Epoch 500 | Train Loss 0.291323 | Val Loss 0.406400
# Epoch 600 | Train Loss 0.290318 | Val Loss 0.405016
# Epoch 700 | Train Loss 0.289557 | Val Loss 0.409505
# Epoch 800 | Train Loss 0.288977 | Val Loss 0.415348
# Early stopping at epoch 825
# X | train1 -> R² = -0.0564, MSE = 1.1391e-01
# X | train2 -> R² = -7.3781, MSE = 7.0595e-01
# X | test1 -> R² = -0.0190, MSE = 1.0675e-01
# X | test2 -> R² = -7.0255, MSE = 6.6045e-01
# X | test3 -> R² = 0.9466, MSE = 4.9131e-03
# X | val -> R² = -0.3113, MSE = 1.2539e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.509855 | Val Loss 0.607890
# Epoch 100 | Train Loss 0.304368 | Val Loss 0.457291
# Epoch 200 | Train Loss 0.297043 | Val Loss 0.433805
# Epoch 300 | Train Loss 0.293951 | Val Loss 0.416000
# Epoch 400 | Train Loss 0.292356 | Val Loss 0.403147
# Epoch 500 | Train Loss 0.291353 | Val Loss 0.399397
# Epoch 600 | Train Loss 0.290378 | Val Loss 0.400250
# Epoch 700 | Train Loss 0.289549 | Val Loss 0.403304
# Early stopping at epoch 791
# X | train1 -> R² = -0.0610, MSE = 1.1440e-01
# X | train2 -> R² = -7.4416, MSE = 7.1129e-01
# X | test1 -> R² = -0.0290, MSE = 1.0780e-01
# X | test2 -> R² = -7.1332, MSE = 6.6931e-01
# X | test3 -> R² = 0.9535, MSE = 4.2783e-03
# X | val -> R² = 0.1283, MSE = 8.3350e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.524268 | Val Loss 0.705176
# Epoch 100 | Train Loss 0.310320 | Val Loss 0.474382
# Epoch 200 | Train Loss 0.299558 | Val Loss 0.446460
# Epoch 300 | Train Loss 0.295112 | Val Loss 0.424347
# Epoch 400 | Train Loss 0.293138 | Val Loss 0.411637
# Epoch 500 | Train Loss 0.291872 | Val Loss 0.406975
# Epoch 600 | Train Loss 0.290561 | Val Loss 0.405449
# Epoch 700 | Train Loss 0.289617 | Val Loss 0.405055
# Epoch 800 | Train Loss 0.289028 | Val Loss 0.405682
# Epoch 900 | Train Loss 0.288601 | Val Loss 0.405703
# Early stopping at epoch 919
# X | train1 -> R² = -0.0521, MSE = 1.1344e-01
# X | train2 -> R² = -7.2229, MSE = 6.9286e-01
# X | test1 -> R² = -0.0747, MSE = 1.1258e-01
# X | test2 -> R² = -6.8378, MSE = 6.4500e-01
# X | test3 -> R² = 0.8750, MSE = 1.1501e-02
# X | val -> R² = -0.0190, MSE = 9.7438e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.516472 | Val Loss 0.654114
# Epoch 100 | Train Loss 0.303559 | Val Loss 0.462200
# Epoch 200 | Train Loss 0.298087 | Val Loss 0.441332
# Epoch 300 | Train Loss 0.294897 | Val Loss 0.426052
# Epoch 400 | Train Loss 0.292829 | Val Loss 0.412614
# Epoch 500 | Train Loss 0.291592 | Val Loss 0.404493
# Epoch 600 | Train Loss 0.290563 | Val Loss 0.402117
# Epoch 700 | Train Loss 0.289714 | Val Loss 0.406099
# Epoch 800 | Train Loss 0.289178 | Val Loss 0.408905
# Early stopping at epoch 879
# X | train1 -> R² = -0.0472, MSE = 1.1291e-01
# X | train2 -> R² = -7.3560, MSE = 7.0408e-01
# X | test1 -> R² = -0.0669, MSE = 1.1177e-01
# X | test2 -> R² = -7.0651, MSE = 6.6370e-01
# X | test3 -> R² = 0.9413, MSE = 5.4038e-03
# X | val -> R² = -0.2584, MSE = 1.2034e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.525642 | Val Loss 0.704408
# Epoch 100 | Train Loss 0.310633 | Val Loss 0.481821
# Epoch 200 | Train Loss 0.299694 | Val Loss 0.459909
# Epoch 300 | Train Loss 0.295018 | Val Loss 0.432914
# Epoch 400 | Train Loss 0.292958 | Val Loss 0.418424
# Epoch 500 | Train Loss 0.291905 | Val Loss 0.412160
# Epoch 600 | Train Loss 0.290877 | Val Loss 0.408621
# Epoch 700 | Train Loss 0.289958 | Val Loss 0.407449
# Epoch 800 | Train Loss 0.289288 | Val Loss 0.407739
# Epoch 900 | Train Loss 0.288717 | Val Loss 0.410035
# Early stopping at epoch 914
# X | train1 -> R² = -0.0548, MSE = 1.1374e-01
# X | train2 -> R² = -7.3135, MSE = 7.0050e-01
# X | test1 -> R² = -0.0444, MSE = 1.0941e-01
# X | test2 -> R² = -6.9953, MSE = 6.5796e-01
# X | test3 -> R² = 0.8659, MSE = 1.2338e-02
# X | val -> R² = -0.4362, MSE = 1.3734e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.513240 | Val Loss 0.617206
# Epoch 100 | Train Loss 0.306856 | Val Loss 0.461490
# Epoch 200 | Train Loss 0.299186 | Val Loss 0.441863
# Epoch 300 | Train Loss 0.295151 | Val Loss 0.423075
# Epoch 400 | Train Loss 0.293382 | Val Loss 0.413072
# Epoch 500 | Train Loss 0.292033 | Val Loss 0.406408
# Epoch 600 | Train Loss 0.290733 | Val Loss 0.403254
# Epoch 700 | Train Loss 0.289716 | Val Loss 0.404353
# Epoch 800 | Train Loss 0.289154 | Val Loss 0.406949
# Early stopping at epoch 885
# X | train1 -> R² = -0.0576, MSE = 1.1404e-01
# X | train2 -> R² = -7.3441, MSE = 7.0308e-01
# X | test1 -> R² = -0.0438, MSE = 1.0935e-01
# X | test2 -> R² = -7.0245, MSE = 6.6036e-01
# X | test3 -> R² = 0.9560, MSE = 4.0483e-03
# X | val -> R² = -0.2787, MSE = 1.2228e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.500929 | Val Loss 0.601334
# Epoch 100 | Train Loss 0.303124 | Val Loss 0.465779
# Epoch 200 | Train Loss 0.296734 | Val Loss 0.431878
# Epoch 300 | Train Loss 0.294151 | Val Loss 0.416994
# Epoch 400 | Train Loss 0.293041 | Val Loss 0.410734
# Epoch 500 | Train Loss 0.292053 | Val Loss 0.405340
# Epoch 600 | Train Loss 0.291121 | Val Loss 0.402071
# Epoch 700 | Train Loss 0.290229 | Val Loss 0.401941
# Epoch 800 | Train Loss 0.289461 | Val Loss 0.403869
# Early stopping at epoch 893
# X | train1 -> R² = -0.0735, MSE = 1.1575e-01
# X | train2 -> R² = -7.3217, MSE = 7.0119e-01
# X | test1 -> R² = -0.0774, MSE = 1.1287e-01
# X | test2 -> R² = -6.9326, MSE = 6.5280e-01
# X | test3 -> R² = 0.9535, MSE = 4.2801e-03
# X | val -> R² = -0.3231, MSE = 1.2652e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.528950 | Val Loss 0.684988
# Epoch 100 | Train Loss 0.307564 | Val Loss 0.470318
# Epoch 200 | Train Loss 0.299098 | Val Loss 0.449134
# Epoch 300 | Train Loss 0.295544 | Val Loss 0.429654
# Epoch 400 | Train Loss 0.293437 | Val Loss 0.417202
# Epoch 500 | Train Loss 0.292070 | Val Loss 0.409303
# Epoch 600 | Train Loss 0.290895 | Val Loss 0.404106
# Epoch 700 | Train Loss 0.290094 | Val Loss 0.402758
# Epoch 800 | Train Loss 0.289631 | Val Loss 0.402490
# Epoch 900 | Train Loss 0.289226 | Val Loss 0.402168
# Epoch 1000 | Train Loss 0.288838 | Val Loss 0.402378
# Early stopping at epoch 1062
# X | train1 -> R² = -0.0443, MSE = 1.1260e-01
# X | train2 -> R² = -7.1795, MSE = 6.8921e-01
# X | test1 -> R² = -0.1007, MSE = 1.1531e-01
# X | test2 -> R² = -7.0404, MSE = 6.6167e-01
# X | test3 -> R² = 0.8968, MSE = 9.4993e-03
# X | val -> R² = -0.1073, MSE = 1.0589e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.513891 | Val Loss 0.661667
# Epoch 100 | Train Loss 0.307127 | Val Loss 0.475015
# Epoch 200 | Train Loss 0.298129 | Val Loss 0.449119
# Epoch 300 | Train Loss 0.294556 | Val Loss 0.429319
# Epoch 400 | Train Loss 0.292630 | Val Loss 0.418384
# Epoch 500 | Train Loss 0.291477 | Val Loss 0.410019
# Epoch 600 | Train Loss 0.290407 | Val Loss 0.404204
# Epoch 700 | Train Loss 0.289760 | Val Loss 0.401912
# Epoch 800 | Train Loss 0.289326 | Val Loss 0.401647
# Epoch 900 | Train Loss 0.288986 | Val Loss 0.401460
# Epoch 1000 | Train Loss 0.288644 | Val Loss 0.400575
# Epoch 1100 | Train Loss 0.288264 | Val Loss 0.398626
# Epoch 1200 | Train Loss 0.287875 | Val Loss 0.398163
# Epoch 1300 | Train Loss 0.287412 | Val Loss 0.399280
# Early stopping at epoch 1376
# X | train1 -> R² = -0.0538, MSE = 1.1363e-01
# X | train2 -> R² = -7.4974, MSE = 7.1600e-01
# X | test1 -> R² = -0.1478, MSE = 1.2025e-01
# X | test2 -> R² = -7.2992, MSE = 6.8297e-01
# X | test3 -> R² = 0.9358, MSE = 5.9063e-03
# X | val -> R² = 0.3015, MSE = 6.6791e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.525375 | Val Loss 0.696954
# Epoch 100 | Train Loss 0.310758 | Val Loss 0.487227
# Epoch 200 | Train Loss 0.299160 | Val Loss 0.453882
# Epoch 300 | Train Loss 0.294838 | Val Loss 0.431693
# Epoch 400 | Train Loss 0.292876 | Val Loss 0.421939
# Epoch 500 | Train Loss 0.291678 | Val Loss 0.416603
# Epoch 600 | Train Loss 0.290522 | Val Loss 0.413272
# Epoch 700 | Train Loss 0.289818 | Val Loss 0.412974
# Epoch 800 | Train Loss 0.289381 | Val Loss 0.412804
# Epoch 900 | Train Loss 0.288881 | Val Loss 0.413536
# Early stopping at epoch 904
# X | train1 -> R² = -0.0524, MSE = 1.1348e-01
# X | train2 -> R² = -7.2141, MSE = 6.9213e-01
# X | test1 -> R² = -0.0812, MSE = 1.1327e-01
# X | test2 -> R² = -6.8121, MSE = 6.4288e-01
# X | test3 -> R² = 0.6723, MSE = 3.0147e-02
# X | val -> R² = -1.1019, MSE = 2.0099e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.497844 | Val Loss 0.595271
# Epoch 100 | Train Loss 0.302737 | Val Loss 0.455345
# Epoch 200 | Train Loss 0.297036 | Val Loss 0.438810
# Epoch 300 | Train Loss 0.293957 | Val Loss 0.422502
# Epoch 400 | Train Loss 0.292075 | Val Loss 0.411889
# Epoch 500 | Train Loss 0.290830 | Val Loss 0.407071
# Epoch 600 | Train Loss 0.289872 | Val Loss 0.407180
# Epoch 700 | Train Loss 0.289317 | Val Loss 0.409834
# Early stopping at epoch 799
# X | train1 -> R² = -0.0569, MSE = 1.1396e-01
# X | train2 -> R² = -7.3579, MSE = 7.0424e-01
# X | test1 -> R² = -0.0545, MSE = 1.1047e-01
# X | test2 -> R² = -7.0201, MSE = 6.6000e-01
# X | test3 -> R² = 0.8652, MSE = 1.2399e-02
# X | val -> R² = -0.4781, MSE = 1.4134e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.453871 | Val Loss 0.643822
# Epoch 100 | Train Loss 0.232267 | Val Loss 0.515677
# Epoch 200 | Train Loss 0.218778 | Val Loss 0.479535
# Epoch 300 | Train Loss 0.215241 | Val Loss 0.458491
# Epoch 400 | Train Loss 0.213173 | Val Loss 0.447106
# Epoch 500 | Train Loss 0.211592 | Val Loss 0.438845
# Epoch 600 | Train Loss 0.209883 | Val Loss 0.435516
# Epoch 700 | Train Loss 0.208169 | Val Loss 0.440971
# Epoch 800 | Train Loss 0.207196 | Val Loss 0.446777
# Early stopping at epoch 844
# X | train1 -> R² = -1.0785, MSE = 2.2412e-01
# X | train2 -> R² = -15.4129, MSE = 1.3830e+00
# X | test1 -> R² = -1.0497, MSE = 2.1473e-01
# X | test2 -> R² = -15.0162, MSE = 1.3180e+00
# X | test3 -> R² = 0.4911, MSE = 4.6822e-02
# X | val -> R² = -1.9073, MSE = 2.7801e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.481066 | Val Loss 0.684701
# Epoch 100 | Train Loss 0.237943 | Val Loss 0.526666
# Epoch 200 | Train Loss 0.222473 | Val Loss 0.474829
# Epoch 300 | Train Loss 0.216714 | Val Loss 0.452912
# Epoch 400 | Train Loss 0.214189 | Val Loss 0.442493
# Epoch 500 | Train Loss 0.212567 | Val Loss 0.436733
# Epoch 600 | Train Loss 0.210927 | Val Loss 0.433760
# Epoch 700 | Train Loss 0.209628 | Val Loss 0.435991
# Epoch 800 | Train Loss 0.208468 | Val Loss 0.438957
# Early stopping at epoch 865
# X | train1 -> R² = -1.0658, MSE = 2.2275e-01
# X | train2 -> R² = -15.2357, MSE = 1.3680e+00
# X | test1 -> R² = -1.0514, MSE = 2.1491e-01
# X | test2 -> R² = -14.8504, MSE = 1.3044e+00
# X | test3 -> R² = 0.1393, MSE = 7.9187e-02
# X | val -> R² = -2.0849, MSE = 2.9498e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.471527 | Val Loss 0.727706
# Epoch 100 | Train Loss 0.233286 | Val Loss 0.507216
# Epoch 200 | Train Loss 0.219950 | Val Loss 0.479070
# Epoch 300 | Train Loss 0.216456 | Val Loss 0.462002
# Epoch 400 | Train Loss 0.214259 | Val Loss 0.445066
# Epoch 500 | Train Loss 0.212451 | Val Loss 0.436275
# Epoch 600 | Train Loss 0.210728 | Val Loss 0.438072
# Epoch 700 | Train Loss 0.209596 | Val Loss 0.439905
# Early stopping at epoch 796
# X | train1 -> R² = -1.0695, MSE = 2.2315e-01
# X | train2 -> R² = -15.2660, MSE = 1.3706e+00
# X | test1 -> R² = -1.0703, MSE = 2.1688e-01
# X | test2 -> R² = -14.8350, MSE = 1.3031e+00
# X | test3 -> R² = 0.2797, MSE = 6.6275e-02
# X | val -> R² = -2.3068, MSE = 3.1620e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.458024 | Val Loss 0.671867
# Epoch 100 | Train Loss 0.232771 | Val Loss 0.511913
# Epoch 200 | Train Loss 0.218948 | Val Loss 0.477303
# Epoch 300 | Train Loss 0.215497 | Val Loss 0.455316
# Epoch 400 | Train Loss 0.213590 | Val Loss 0.445731
# Epoch 500 | Train Loss 0.211868 | Val Loss 0.440469
# Epoch 600 | Train Loss 0.210147 | Val Loss 0.440333
# Epoch 700 | Train Loss 0.209037 | Val Loss 0.443140
# Epoch 800 | Train Loss 0.208011 | Val Loss 0.443075
# Early stopping at epoch 819
# X | train1 -> R² = -1.0545, MSE = 2.2153e-01
# X | train2 -> R² = -15.2717, MSE = 1.3711e+00
# X | test1 -> R² = -1.0481, MSE = 2.1456e-01
# X | test2 -> R² = -15.0799, MSE = 1.3233e+00
# X | test3 -> R² = 0.2279, MSE = 7.1038e-02
# X | val -> R² = -2.5854, MSE = 3.4285e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.449009 | Val Loss 0.606587
# Epoch 100 | Train Loss 0.226404 | Val Loss 0.486089
# Epoch 200 | Train Loss 0.218493 | Val Loss 0.468714
# Epoch 300 | Train Loss 0.214760 | Val Loss 0.453874
# Epoch 400 | Train Loss 0.212337 | Val Loss 0.438623
# Epoch 500 | Train Loss 0.210657 | Val Loss 0.435936
# Epoch 600 | Train Loss 0.209174 | Val Loss 0.444725
# Epoch 700 | Train Loss 0.208110 | Val Loss 0.457242
# Early stopping at epoch 767
# X | train1 -> R² = -1.0829, MSE = 2.2459e-01
# X | train2 -> R² = -15.2795, MSE = 1.3717e+00
# X | test1 -> R² = -1.0795, MSE = 2.1785e-01
# X | test2 -> R² = -14.8890, MSE = 1.3076e+00
# X | test3 -> R² = 0.2466, MSE = 6.9314e-02
# X | val -> R² = -2.1310, MSE = 2.9940e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.460554 | Val Loss 0.666869
# Epoch 100 | Train Loss 0.233583 | Val Loss 0.501708
# Epoch 200 | Train Loss 0.219005 | Val Loss 0.471892
# Epoch 300 | Train Loss 0.215077 | Val Loss 0.456335
# Epoch 400 | Train Loss 0.213003 | Val Loss 0.444793
# Epoch 500 | Train Loss 0.211465 | Val Loss 0.436708
# Epoch 600 | Train Loss 0.209932 | Val Loss 0.435686
# Epoch 700 | Train Loss 0.208543 | Val Loss 0.439950
# Epoch 800 | Train Loss 0.207265 | Val Loss 0.439790
# Early stopping at epoch 848
# X | train1 -> R² = -1.0737, MSE = 2.2359e-01
# X | train2 -> R² = -15.3081, MSE = 1.3741e+00
# X | test1 -> R² = -1.0705, MSE = 2.1690e-01
# X | test2 -> R² = -14.9869, MSE = 1.3156e+00
# X | test3 -> R² = 0.2103, MSE = 7.2653e-02
# X | val -> R² = -2.1381, MSE = 3.0008e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.458830 | Val Loss 0.647884
# Epoch 100 | Train Loss 0.227376 | Val Loss 0.495505
# Epoch 200 | Train Loss 0.218079 | Val Loss 0.470418
# Epoch 300 | Train Loss 0.215198 | Val Loss 0.452880
# Epoch 400 | Train Loss 0.213293 | Val Loss 0.440656
# Epoch 500 | Train Loss 0.211691 | Val Loss 0.436201
# Epoch 600 | Train Loss 0.210042 | Val Loss 0.442224
# Epoch 700 | Train Loss 0.208625 | Val Loss 0.452410
# Early stopping at epoch 767
# X | train1 -> R² = -1.0742, MSE = 2.2365e-01
# X | train2 -> R² = -15.3925, MSE = 1.3812e+00
# X | test1 -> R² = -1.0313, MSE = 2.1280e-01
# X | test2 -> R² = -15.0444, MSE = 1.3203e+00
# X | test3 -> R² = 0.4852, MSE = 4.7362e-02
# X | val -> R² = -2.2462, MSE = 3.1041e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.463157 | Val Loss 0.664465
# Epoch 100 | Train Loss 0.235417 | Val Loss 0.521667
# Epoch 200 | Train Loss 0.219277 | Val Loss 0.475327
# Epoch 300 | Train Loss 0.215176 | Val Loss 0.448917
# Epoch 400 | Train Loss 0.212645 | Val Loss 0.436978
# Epoch 500 | Train Loss 0.210139 | Val Loss 0.438781
# Epoch 600 | Train Loss 0.208427 | Val Loss 0.445194
# Epoch 700 | Train Loss 0.207217 | Val Loss 0.450930
# Early stopping at epoch 702
# X | train1 -> R² = -1.0885, MSE = 2.2519e-01
# X | train2 -> R² = -15.4520, MSE = 1.3862e+00
# X | test1 -> R² = -1.0494, MSE = 2.1469e-01
# X | test2 -> R² = -15.1168, MSE = 1.3263e+00
# X | test3 -> R² = 0.3479, MSE = 5.9992e-02
# X | val -> R² = -2.2125, MSE = 3.0719e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.456720 | Val Loss 0.686735
# Epoch 100 | Train Loss 0.238061 | Val Loss 0.539881
# Epoch 200 | Train Loss 0.222186 | Val Loss 0.502860
# Epoch 300 | Train Loss 0.216724 | Val Loss 0.481356
# Epoch 400 | Train Loss 0.213304 | Val Loss 0.458374
# Epoch 500 | Train Loss 0.211199 | Val Loss 0.445121
# Epoch 600 | Train Loss 0.209154 | Val Loss 0.449529
# Epoch 700 | Train Loss 0.207877 | Val Loss 0.462184
# Epoch 800 | Train Loss 0.207109 | Val Loss 0.465368
# Early stopping at epoch 807
# X | train1 -> R² = -1.0576, MSE = 2.2186e-01
# X | train2 -> R² = -15.2982, MSE = 1.3733e+00
# X | test1 -> R² = -1.0643, MSE = 2.1625e-01
# X | test2 -> R² = -14.8598, MSE = 1.3052e+00
# X | test3 -> R² = 0.0430, MSE = 8.8047e-02
# X | val -> R² = -2.4599, MSE = 3.3084e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.466262 | Val Loss 0.696639
# Epoch 100 | Train Loss 0.231043 | Val Loss 0.507400
# Epoch 200 | Train Loss 0.219113 | Val Loss 0.480258
# Epoch 300 | Train Loss 0.215060 | Val Loss 0.453881
# Epoch 400 | Train Loss 0.212778 | Val Loss 0.437069
# Epoch 500 | Train Loss 0.211120 | Val Loss 0.435308
# Epoch 600 | Train Loss 0.209471 | Val Loss 0.442802
# Epoch 700 | Train Loss 0.208387 | Val Loss 0.450013
# Early stopping at epoch 748
# X | train1 -> R² = -1.0806, MSE = 2.2434e-01
# X | train2 -> R² = -15.4346, MSE = 1.3848e+00
# X | test1 -> R² = -1.0936, MSE = 2.1933e-01
# X | test2 -> R² = -15.0214, MSE = 1.3185e+00
# X | test3 -> R² = 0.4150, MSE = 5.3823e-02
# X | val -> R² = -1.9675, MSE = 2.8376e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.473454 | Val Loss 0.642855
# Epoch 100 | Train Loss 0.235909 | Val Loss 0.514292
# Epoch 200 | Train Loss 0.222185 | Val Loss 0.478201
# Epoch 300 | Train Loss 0.216340 | Val Loss 0.449967
# Epoch 400 | Train Loss 0.214077 | Val Loss 0.435585
# Epoch 500 | Train Loss 0.212250 | Val Loss 0.429692
# Epoch 600 | Train Loss 0.210287 | Val Loss 0.427782
# Epoch 700 | Train Loss 0.208966 | Val Loss 0.429033
# Epoch 800 | Train Loss 0.207984 | Val Loss 0.427681
# Epoch 900 | Train Loss 0.207017 | Val Loss 0.424061
# Epoch 1000 | Train Loss 0.205870 | Val Loss 0.423036
# Epoch 1100 | Train Loss 0.204284 | Val Loss 0.429745
# Epoch 1200 | Train Loss 0.202876 | Val Loss 0.437391
# Early stopping at epoch 1254
# X | train1 -> R² = -1.0295, MSE = 2.1884e-01
# X | train2 -> R² = -15.0281, MSE = 1.3505e+00
# X | test1 -> R² = -1.1524, MSE = 2.2549e-01
# X | test2 -> R² = -14.8313, MSE = 1.3028e+00
# X | test3 -> R² = 0.8138, MSE = 1.7135e-02
# X | val -> R² = -1.0218, MSE = 1.9333e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.479196 | Val Loss 0.673054
# Epoch 100 | Train Loss 0.236894 | Val Loss 0.512549
# Epoch 200 | Train Loss 0.221186 | Val Loss 0.474243
# Epoch 300 | Train Loss 0.215921 | Val Loss 0.457111
# Epoch 400 | Train Loss 0.213773 | Val Loss 0.444388
# Epoch 500 | Train Loss 0.212217 | Val Loss 0.437504
# Epoch 600 | Train Loss 0.210533 | Val Loss 0.433989
# Epoch 700 | Train Loss 0.209092 | Val Loss 0.439918
# Epoch 800 | Train Loss 0.207940 | Val Loss 0.448712
# Early stopping at epoch 894
# X | train1 -> R² = -1.0700, MSE = 2.2320e-01
# X | train2 -> R² = -15.2447, MSE = 1.3688e+00
# X | test1 -> R² = -1.0570, MSE = 2.1549e-01
# X | test2 -> R² = -14.8318, MSE = 1.3029e+00
# X | test3 -> R² = 0.3456, MSE = 6.0203e-02
# X | val -> R² = -1.9686, MSE = 2.8386e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.457060 | Val Loss 0.643061
# Epoch 100 | Train Loss 0.234059 | Val Loss 0.510910
# Epoch 200 | Train Loss 0.218860 | Val Loss 0.477355
# Epoch 300 | Train Loss 0.215005 | Val Loss 0.462556
# Epoch 400 | Train Loss 0.212674 | Val Loss 0.445663
# Epoch 500 | Train Loss 0.210884 | Val Loss 0.433007
# Epoch 600 | Train Loss 0.209115 | Val Loss 0.429940
# Epoch 700 | Train Loss 0.207886 | Val Loss 0.434377
# Epoch 800 | Train Loss 0.206756 | Val Loss 0.437702
# Early stopping at epoch 870
# X | train1 -> R² = -1.0668, MSE = 2.2285e-01
# X | train2 -> R² = -14.7298, MSE = 1.3254e+00
# X | test1 -> R² = -1.1561, MSE = 2.2588e-01
# X | test2 -> R² = -14.4695, MSE = 1.2730e+00
# X | test3 -> R² = 0.4946, MSE = 4.6495e-02
# X | val -> R² = -1.9131, MSE = 2.7856e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.449991 | Val Loss 0.647466
# Epoch 100 | Train Loss 0.232688 | Val Loss 0.501018
# Epoch 200 | Train Loss 0.219147 | Val Loss 0.465677
# Epoch 300 | Train Loss 0.215880 | Val Loss 0.456865
# Epoch 400 | Train Loss 0.213332 | Val Loss 0.443065
# Epoch 500 | Train Loss 0.211316 | Val Loss 0.433633
# Epoch 600 | Train Loss 0.209595 | Val Loss 0.439706
# Epoch 700 | Train Loss 0.208085 | Val Loss 0.448948
# Early stopping at epoch 777
# X | train1 -> R² = -1.0906, MSE = 2.2542e-01
# X | train2 -> R² = -15.6722, MSE = 1.4048e+00
# X | test1 -> R² = -1.0212, MSE = 2.1174e-01
# X | test2 -> R² = -15.3183, MSE = 1.3429e+00
# X | test3 -> R² = 0.4283, MSE = 5.2596e-02
# X | val -> R² = -2.0784, MSE = 2.9437e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.461612 | Val Loss 0.615750
# Epoch 100 | Train Loss 0.227669 | Val Loss 0.498038
# Epoch 200 | Train Loss 0.218842 | Val Loss 0.478316
# Epoch 300 | Train Loss 0.215516 | Val Loss 0.455552
# Epoch 400 | Train Loss 0.213260 | Val Loss 0.444452
# Epoch 500 | Train Loss 0.211084 | Val Loss 0.437234
# Epoch 600 | Train Loss 0.209163 | Val Loss 0.435581
# Epoch 700 | Train Loss 0.207877 | Val Loss 0.438895
# Epoch 800 | Train Loss 0.206859 | Val Loss 0.442772
# Epoch 900 | Train Loss 0.206083 | Val Loss 0.446200
# Early stopping at epoch 906
# X | train1 -> R² = -1.0341, MSE = 2.1932e-01
# X | train2 -> R² = -13.5633, MSE = 1.2271e+00
# X | test1 -> R² = -1.0721, MSE = 2.1707e-01
# X | test2 -> R² = -13.4278, MSE = 1.1873e+00
# X | test3 -> R² = 0.2972, MSE = 6.4661e-02
# X | val -> R² = -1.8892, MSE = 2.7627e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.563677 | Val Loss 0.655292
# Epoch 100 | Train Loss 0.359542 | Val Loss 0.443805
# Epoch 200 | Train Loss 0.353231 | Val Loss 0.422669
# Epoch 300 | Train Loss 0.349615 | Val Loss 0.408176
# Epoch 400 | Train Loss 0.347200 | Val Loss 0.397108
# Epoch 500 | Train Loss 0.346085 | Val Loss 0.391267
# Epoch 600 | Train Loss 0.345124 | Val Loss 0.387445
# Epoch 700 | Train Loss 0.344531 | Val Loss 0.387540
# Epoch 800 | Train Loss 0.344185 | Val Loss 0.387995
# Epoch 900 | Train Loss 0.343923 | Val Loss 0.387390
# Early stopping at epoch 905
# X | train1 -> R² = 0.6250, MSE = 4.0434e-02
# X | train2 -> R² = -1.9644, MSE = 2.4978e-01
# X | test1 -> R² = 0.5936, MSE = 4.2577e-02
# X | test2 -> R² = -1.7293, MSE = 2.2460e-01
# X | test3 -> R² = 0.9604, MSE = 3.6478e-03
# X | val -> R² = 0.3944, MSE = 5.7910e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.579225 | Val Loss 0.694186
# Epoch 100 | Train Loss 0.360928 | Val Loss 0.448956
# Epoch 200 | Train Loss 0.354720 | Val Loss 0.427161
# Epoch 300 | Train Loss 0.350399 | Val Loss 0.409647
# Epoch 400 | Train Loss 0.347533 | Val Loss 0.397042
# Epoch 500 | Train Loss 0.346708 | Val Loss 0.395419
# Epoch 600 | Train Loss 0.345892 | Val Loss 0.394275
# Epoch 700 | Train Loss 0.345094 | Val Loss 0.391781
# Epoch 800 | Train Loss 0.344550 | Val Loss 0.389956
# Epoch 900 | Train Loss 0.344124 | Val Loss 0.388367
# Epoch 1000 | Train Loss 0.343717 | Val Loss 0.386352
# Epoch 1100 | Train Loss 0.343296 | Val Loss 0.383679
# Epoch 1200 | Train Loss 0.342838 | Val Loss 0.381380
# Epoch 1300 | Train Loss 0.342337 | Val Loss 0.380515
# Epoch 1400 | Train Loss 0.341813 | Val Loss 0.382164
# Epoch 1500 | Train Loss 0.341293 | Val Loss 0.386004
# Early stopping at epoch 1527
# X | train1 -> R² = 0.6411, MSE = 3.8695e-02
# X | train2 -> R² = -1.8032, MSE = 2.3620e-01
# X | test1 -> R² = 0.5801, MSE = 4.3988e-02
# X | test2 -> R² = -1.6468, MSE = 2.1781e-01
# X | test3 -> R² = 0.8504, MSE = 1.3763e-02
# X | val -> R² = 0.9103, MSE = 8.5733e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.559586 | Val Loss 0.649175
# Epoch 100 | Train Loss 0.367703 | Val Loss 0.445314
# Epoch 200 | Train Loss 0.353107 | Val Loss 0.420884
# Epoch 300 | Train Loss 0.349229 | Val Loss 0.403703
# Epoch 400 | Train Loss 0.347394 | Val Loss 0.395390
# Epoch 500 | Train Loss 0.346223 | Val Loss 0.391282
# Epoch 600 | Train Loss 0.345353 | Val Loss 0.388012
# Epoch 700 | Train Loss 0.344666 | Val Loss 0.386389
# Epoch 800 | Train Loss 0.344205 | Val Loss 0.385988
# Epoch 900 | Train Loss 0.343861 | Val Loss 0.385887
# Early stopping at epoch 980
# X | train1 -> R² = 0.6253, MSE = 4.0397e-02
# X | train2 -> R² = -1.9617, MSE = 2.4955e-01
# X | test1 -> R² = 0.5888, MSE = 4.3078e-02
# X | test2 -> R² = -1.6907, MSE = 2.2143e-01
# X | test3 -> R² = 0.8573, MSE = 1.3124e-02
# X | val -> R² = 0.5311, MSE = 4.4837e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.569690 | Val Loss 0.673716
# Epoch 100 | Train Loss 0.359885 | Val Loss 0.442262
# Epoch 200 | Train Loss 0.353793 | Val Loss 0.420879
# Epoch 300 | Train Loss 0.348649 | Val Loss 0.403315
# Epoch 400 | Train Loss 0.346923 | Val Loss 0.395302
# Epoch 500 | Train Loss 0.345893 | Val Loss 0.391850
# Epoch 600 | Train Loss 0.345013 | Val Loss 0.390295
# Epoch 700 | Train Loss 0.344310 | Val Loss 0.389723
# Epoch 800 | Train Loss 0.343871 | Val Loss 0.389462
# Epoch 900 | Train Loss 0.343547 | Val Loss 0.388631
# Epoch 1000 | Train Loss 0.343240 | Val Loss 0.387715
# Epoch 1100 | Train Loss 0.342929 | Val Loss 0.387482
# Epoch 1200 | Train Loss 0.342593 | Val Loss 0.387803
# Early stopping at epoch 1273
# X | train1 -> R² = 0.6369, MSE = 3.9153e-02
# X | train2 -> R² = -1.9238, MSE = 2.4636e-01
# X | test1 -> R² = 0.5603, MSE = 4.6060e-02
# X | test2 -> R² = -1.7443, MSE = 2.2584e-01
# X | test3 -> R² = 0.9643, MSE = 3.2818e-03
# X | val -> R² = 0.3003, MSE = 6.6911e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.573494 | Val Loss 0.680577
# Epoch 100 | Train Loss 0.359331 | Val Loss 0.446895
# Epoch 200 | Train Loss 0.353786 | Val Loss 0.426496
# Epoch 300 | Train Loss 0.350235 | Val Loss 0.413091
# Epoch 400 | Train Loss 0.346860 | Val Loss 0.400894
# Epoch 500 | Train Loss 0.345336 | Val Loss 0.395117
# Epoch 600 | Train Loss 0.344486 | Val Loss 0.393392
# Epoch 700 | Train Loss 0.344011 | Val Loss 0.391756
# Epoch 800 | Train Loss 0.343663 | Val Loss 0.388828
# Epoch 900 | Train Loss 0.343342 | Val Loss 0.386090
# Epoch 1000 | Train Loss 0.343023 | Val Loss 0.384063
# Epoch 1100 | Train Loss 0.342690 | Val Loss 0.382907
# Epoch 1200 | Train Loss 0.342307 | Val Loss 0.382211
# Epoch 1300 | Train Loss 0.341841 | Val Loss 0.381541
# Epoch 1400 | Train Loss 0.341275 | Val Loss 0.380641
# Epoch 1500 | Train Loss 0.340465 | Val Loss 0.379649
# Epoch 1600 | Train Loss 0.339377 | Val Loss 0.381190
# Epoch 1700 | Train Loss 0.338376 | Val Loss 0.384989
# Early stopping at epoch 1779
# X | train1 -> R² = 0.6828, MSE = 3.4203e-02
# X | train2 -> R² = -2.4841, MSE = 2.9357e-01
# X | test1 -> R² = 0.6227, MSE = 3.9525e-02
# X | test2 -> R² = -2.3547, MSE = 2.7607e-01
# X | test3 -> R² = 0.5161, MSE = 4.4518e-02
# X | val -> R² = 0.8831, MSE = 1.1181e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.563910 | Val Loss 0.654461
# Epoch 100 | Train Loss 0.360978 | Val Loss 0.444564
# Epoch 200 | Train Loss 0.354237 | Val Loss 0.427620
# Epoch 300 | Train Loss 0.350142 | Val Loss 0.411395
# Epoch 400 | Train Loss 0.346946 | Val Loss 0.399472
# Epoch 500 | Train Loss 0.345887 | Val Loss 0.394806
# Epoch 600 | Train Loss 0.345048 | Val Loss 0.392488
# Epoch 700 | Train Loss 0.344427 | Val Loss 0.392692
# Epoch 800 | Train Loss 0.344063 | Val Loss 0.392835
# Early stopping at epoch 859
# X | train1 -> R² = 0.6276, MSE = 4.0158e-02
# X | train2 -> R² = -1.9883, MSE = 2.5180e-01
# X | test1 -> R² = 0.6073, MSE = 4.1135e-02
# X | test2 -> R² = -1.8039, MSE = 2.3074e-01
# X | test3 -> R² = 0.9348, MSE = 5.9942e-03
# X | val -> R² = 0.3224, MSE = 6.4799e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.586567 | Val Loss 0.709243
# Epoch 100 | Train Loss 0.362053 | Val Loss 0.445540
# Epoch 200 | Train Loss 0.353700 | Val Loss 0.423752
# Epoch 300 | Train Loss 0.349507 | Val Loss 0.409373
# Epoch 400 | Train Loss 0.347236 | Val Loss 0.399887
# Epoch 500 | Train Loss 0.346201 | Val Loss 0.393190
# Epoch 600 | Train Loss 0.345331 | Val Loss 0.389297
# Epoch 700 | Train Loss 0.344613 | Val Loss 0.388466
# Epoch 800 | Train Loss 0.344147 | Val Loss 0.388402
# Epoch 900 | Train Loss 0.343817 | Val Loss 0.387324
# Epoch 1000 | Train Loss 0.343524 | Val Loss 0.385992
# Epoch 1100 | Train Loss 0.343220 | Val Loss 0.384878
# Epoch 1200 | Train Loss 0.342898 | Val Loss 0.383968
# Epoch 1300 | Train Loss 0.342571 | Val Loss 0.383297
# Epoch 1400 | Train Loss 0.342244 | Val Loss 0.382863
# Epoch 1500 | Train Loss 0.341873 | Val Loss 0.382716
# Epoch 1600 | Train Loss 0.341407 | Val Loss 0.381699
# Epoch 1700 | Train Loss 0.340781 | Val Loss 0.379699
# Epoch 1800 | Train Loss 0.339901 | Val Loss 0.379640
# Epoch 1900 | Train Loss 0.338776 | Val Loss 0.384437
# Early stopping at epoch 1978
# X | train1 -> R² = 0.6385, MSE = 3.8975e-02
# X | train2 -> R² = -1.9429, MSE = 2.4797e-01
# X | test1 -> R² = 0.5479, MSE = 4.7360e-02
# X | test2 -> R² = -1.7939, MSE = 2.2992e-01
# X | test3 -> R² = 0.6238, MSE = 3.4611e-02
# X | val -> R² = 0.9353, MSE = 6.1906e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.565685 | Val Loss 0.663637
# Epoch 100 | Train Loss 0.359813 | Val Loss 0.455923
# Epoch 200 | Train Loss 0.353293 | Val Loss 0.423550
# Epoch 300 | Train Loss 0.349680 | Val Loss 0.409604
# Epoch 400 | Train Loss 0.347289 | Val Loss 0.401563
# Epoch 500 | Train Loss 0.346271 | Val Loss 0.397802
# Epoch 600 | Train Loss 0.345346 | Val Loss 0.394074
# Epoch 700 | Train Loss 0.344663 | Val Loss 0.392492
# Epoch 800 | Train Loss 0.344270 | Val Loss 0.391407
# Epoch 900 | Train Loss 0.343974 | Val Loss 0.389243
# Epoch 1000 | Train Loss 0.343702 | Val Loss 0.387067
# Epoch 1100 | Train Loss 0.343432 | Val Loss 0.385012
# Epoch 1200 | Train Loss 0.343151 | Val Loss 0.383185
# Epoch 1300 | Train Loss 0.342850 | Val Loss 0.381690
# Epoch 1400 | Train Loss 0.342527 | Val Loss 0.380674
# Epoch 1500 | Train Loss 0.342095 | Val Loss 0.380412
# Epoch 1600 | Train Loss 0.341581 | Val Loss 0.380879
# Early stopping at epoch 1629
# X | train1 -> R² = 0.6212, MSE = 4.0841e-02
# X | train2 -> R² = -1.8333, MSE = 2.3873e-01
# X | test1 -> R² = 0.5673, MSE = 4.5328e-02
# X | test2 -> R² = -1.6779, MSE = 2.2037e-01
# X | test3 -> R² = 0.9260, MSE = 6.8104e-03
# X | val -> R² = 0.7756, MSE = 2.1458e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.573922 | Val Loss 0.676390
# Epoch 100 | Train Loss 0.361092 | Val Loss 0.442170
# Epoch 200 | Train Loss 0.354000 | Val Loss 0.422185
# Epoch 300 | Train Loss 0.349420 | Val Loss 0.404078
# Epoch 400 | Train Loss 0.347028 | Val Loss 0.393558
# Epoch 500 | Train Loss 0.345955 | Val Loss 0.389780
# Epoch 600 | Train Loss 0.345143 | Val Loss 0.386832
# Epoch 700 | Train Loss 0.344421 | Val Loss 0.384462
# Epoch 800 | Train Loss 0.343832 | Val Loss 0.383582
# Epoch 900 | Train Loss 0.343453 | Val Loss 0.383315
# Epoch 1000 | Train Loss 0.343083 | Val Loss 0.382467
# Epoch 1100 | Train Loss 0.342709 | Val Loss 0.381385
# Epoch 1200 | Train Loss 0.342300 | Val Loss 0.380101
# Epoch 1300 | Train Loss 0.341844 | Val Loss 0.378630
# Epoch 1400 | Train Loss 0.341320 | Val Loss 0.378207
# Epoch 1500 | Train Loss 0.340663 | Val Loss 0.380084
# Early stopping at epoch 1573
# X | train1 -> R² = 0.6361, MSE = 3.9236e-02
# X | train2 -> R² = -1.9494, MSE = 2.4852e-01
# X | test1 -> R² = 0.5818, MSE = 4.3809e-02
# X | test2 -> R² = -1.7802, MSE = 2.2879e-01
# X | test3 -> R² = 0.7226, MSE = 2.5519e-02
# X | val -> R² = 0.8945, MSE = 1.0086e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.562194 | Val Loss 0.653651
# Epoch 100 | Train Loss 0.359721 | Val Loss 0.440895
# Epoch 200 | Train Loss 0.353012 | Val Loss 0.418794
# Epoch 300 | Train Loss 0.349105 | Val Loss 0.404937
# Epoch 400 | Train Loss 0.346422 | Val Loss 0.392534
# Epoch 500 | Train Loss 0.344877 | Val Loss 0.388705
# Epoch 600 | Train Loss 0.344300 | Val Loss 0.389013
# Epoch 700 | Train Loss 0.343919 | Val Loss 0.388468
# Epoch 800 | Train Loss 0.343539 | Val Loss 0.388212
# Epoch 900 | Train Loss 0.343160 | Val Loss 0.388191
# Epoch 1000 | Train Loss 0.342767 | Val Loss 0.388270
# Early stopping at epoch 1046
# X | train1 -> R² = 0.6373, MSE = 3.9105e-02
# X | train2 -> R² = -1.9011, MSE = 2.4444e-01
# X | test1 -> R² = 0.5644, MSE = 4.5635e-02
# X | test2 -> R² = -1.7725, MSE = 2.2816e-01
# X | test3 -> R² = 0.9676, MSE = 2.9812e-03
# X | val -> R² = 0.2865, MSE = 6.8225e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.557190 | Val Loss 0.638333
# Epoch 100 | Train Loss 0.361325 | Val Loss 0.452633
# Epoch 200 | Train Loss 0.354141 | Val Loss 0.426221
# Epoch 300 | Train Loss 0.350522 | Val Loss 0.409946
# Epoch 400 | Train Loss 0.347449 | Val Loss 0.397924
# Epoch 500 | Train Loss 0.346288 | Val Loss 0.393293
# Epoch 600 | Train Loss 0.345438 | Val Loss 0.391108
# Epoch 700 | Train Loss 0.344714 | Val Loss 0.390246
# Epoch 800 | Train Loss 0.344239 | Val Loss 0.389264
# Epoch 900 | Train Loss 0.343926 | Val Loss 0.388002
# Epoch 1000 | Train Loss 0.343632 | Val Loss 0.387312
# Epoch 1100 | Train Loss 0.343296 | Val Loss 0.387593
# Epoch 1200 | Train Loss 0.342882 | Val Loss 0.388678
# Early stopping at epoch 1238
# X | train1 -> R² = 0.6356, MSE = 3.9288e-02
# X | train2 -> R² = -1.9182, MSE = 2.4589e-01
# X | test1 -> R² = 0.5652, MSE = 4.5550e-02
# X | test2 -> R² = -1.7554, MSE = 2.2675e-01
# X | test3 -> R² = 0.9635, MSE = 3.3620e-03
# X | val -> R² = 0.2701, MSE = 6.9796e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.583905 | Val Loss 0.709581
# Epoch 100 | Train Loss 0.361325 | Val Loss 0.450767
# Epoch 200 | Train Loss 0.353998 | Val Loss 0.424651
# Epoch 300 | Train Loss 0.348638 | Val Loss 0.403671
# Epoch 400 | Train Loss 0.346717 | Val Loss 0.393265
# Epoch 500 | Train Loss 0.345941 | Val Loss 0.389703
# Epoch 600 | Train Loss 0.345325 | Val Loss 0.386587
# Epoch 700 | Train Loss 0.344792 | Val Loss 0.384778
# Epoch 800 | Train Loss 0.344343 | Val Loss 0.384593
# Epoch 900 | Train Loss 0.344035 | Val Loss 0.385001
# Epoch 1000 | Train Loss 0.343731 | Val Loss 0.385191
# Early stopping at epoch 1011
# X | train1 -> R² = 0.6300, MSE = 3.9897e-02
# X | train2 -> R² = -1.9923, MSE = 2.5213e-01
# X | test1 -> R² = 0.5698, MSE = 4.5073e-02
# X | test2 -> R² = -1.7880, MSE = 2.2944e-01
# X | test3 -> R² = 0.8564, MSE = 1.3210e-02
# X | val -> R² = 0.3218, MSE = 6.4855e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.559033 | Val Loss 0.640108
# Epoch 100 | Train Loss 0.360031 | Val Loss 0.447545
# Epoch 200 | Train Loss 0.353396 | Val Loss 0.424027
# Epoch 300 | Train Loss 0.348716 | Val Loss 0.407091
# Epoch 400 | Train Loss 0.346354 | Val Loss 0.396590
# Epoch 500 | Train Loss 0.345322 | Val Loss 0.393012
# Epoch 600 | Train Loss 0.344472 | Val Loss 0.390994
# Epoch 700 | Train Loss 0.343995 | Val Loss 0.390101
# Epoch 800 | Train Loss 0.343656 | Val Loss 0.389075
# Epoch 900 | Train Loss 0.343329 | Val Loss 0.388262
# Epoch 1000 | Train Loss 0.342991 | Val Loss 0.387395
# Epoch 1100 | Train Loss 0.342565 | Val Loss 0.386790
# Epoch 1200 | Train Loss 0.342088 | Val Loss 0.386205
# Epoch 1300 | Train Loss 0.341492 | Val Loss 0.385981
# Epoch 1400 | Train Loss 0.340732 | Val Loss 0.386550
# Epoch 1500 | Train Loss 0.339901 | Val Loss 0.388781
# Early stopping at epoch 1522
# X | train1 -> R² = 0.6492, MSE = 3.7825e-02
# X | train2 -> R² = -2.0326, MSE = 2.5553e-01
# X | test1 -> R² = 0.6035, MSE = 4.1538e-02
# X | test2 -> R² = -1.8572, MSE = 2.3513e-01
# X | test3 -> R² = 0.7397, MSE = 2.3947e-02
# X | val -> R² = 0.9559, MSE = 4.2149e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.566838 | Val Loss 0.667652
# Epoch 100 | Train Loss 0.359566 | Val Loss 0.457278
# Epoch 200 | Train Loss 0.354397 | Val Loss 0.431075
# Epoch 300 | Train Loss 0.349187 | Val Loss 0.404823
# Epoch 400 | Train Loss 0.346992 | Val Loss 0.392777
# Epoch 500 | Train Loss 0.346279 | Val Loss 0.390126
# Epoch 600 | Train Loss 0.345690 | Val Loss 0.387851
# Epoch 700 | Train Loss 0.345076 | Val Loss 0.385830
# Epoch 800 | Train Loss 0.344459 | Val Loss 0.384971
# Epoch 900 | Train Loss 0.344042 | Val Loss 0.384761
# Epoch 1000 | Train Loss 0.343772 | Val Loss 0.383708
# Epoch 1100 | Train Loss 0.343530 | Val Loss 0.382551
# Epoch 1200 | Train Loss 0.343287 | Val Loss 0.381621
# Epoch 1300 | Train Loss 0.343045 | Val Loss 0.380985
# Epoch 1400 | Train Loss 0.342795 | Val Loss 0.380774
# Epoch 1500 | Train Loss 0.342537 | Val Loss 0.380869
# Early stopping at epoch 1562
# X | train1 -> R² = 0.6322, MSE = 3.9661e-02
# X | train2 -> R² = -1.9179, MSE = 2.4586e-01
# X | test1 -> R² = 0.5516, MSE = 4.6975e-02
# X | test2 -> R² = -1.7443, MSE = 2.2584e-01
# X | test3 -> R² = 0.7976, MSE = 1.8621e-02
# X | val -> R² = 0.8334, MSE = 1.5931e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.574266 | Val Loss 0.685979
# Epoch 100 | Train Loss 0.360772 | Val Loss 0.448227
# Epoch 200 | Train Loss 0.355539 | Val Loss 0.431660
# Epoch 300 | Train Loss 0.351426 | Val Loss 0.415802
# Epoch 400 | Train Loss 0.347817 | Val Loss 0.400862
# Epoch 500 | Train Loss 0.346115 | Val Loss 0.396662
# Epoch 600 | Train Loss 0.344842 | Val Loss 0.394113
# Epoch 700 | Train Loss 0.344053 | Val Loss 0.391262
# Epoch 800 | Train Loss 0.343503 | Val Loss 0.388051
# Epoch 900 | Train Loss 0.343008 | Val Loss 0.385249
# Epoch 1000 | Train Loss 0.342545 | Val Loss 0.383415
# Epoch 1100 | Train Loss 0.342123 | Val Loss 0.382879
# Epoch 1200 | Train Loss 0.341685 | Val Loss 0.382715
# Epoch 1300 | Train Loss 0.341174 | Val Loss 0.382187
# Epoch 1400 | Train Loss 0.340511 | Val Loss 0.381252
# Epoch 1500 | Train Loss 0.339859 | Val Loss 0.381060
# Epoch 1600 | Train Loss 0.339250 | Val Loss 0.380442
# Epoch 1700 | Train Loss 0.338589 | Val Loss 0.379834
# Epoch 1800 | Train Loss 0.337795 | Val Loss 0.379829
# Epoch 1900 | Train Loss 0.336878 | Val Loss 0.381213
# Early stopping at epoch 1968
# X | train1 -> R² = 0.6736, MSE = 3.5192e-02
# X | train2 -> R² = -2.2767, MSE = 2.7609e-01
# X | test1 -> R² = 0.6831, MSE = 3.3199e-02
# X | test2 -> R² = -2.1126, MSE = 2.5615e-01
# X | test3 -> R² = -0.0288, MSE = 9.4651e-02
# X | val -> R² = 0.8893, MSE = 1.0583e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.520726 | Val Loss 0.604780
# Epoch 100 | Train Loss 0.301087 | Val Loss 0.450229
# Epoch 200 | Train Loss 0.294636 | Val Loss 0.424459
# Epoch 300 | Train Loss 0.292562 | Val Loss 0.412029
# Epoch 400 | Train Loss 0.291309 | Val Loss 0.405236
# Epoch 500 | Train Loss 0.289865 | Val Loss 0.401591
# Epoch 600 | Train Loss 0.288881 | Val Loss 0.406779
# Epoch 700 | Train Loss 0.288086 | Val Loss 0.409239
# Early stopping at epoch 759
# X | train1 -> R² = -0.0494, MSE = 1.1316e-01
# X | train2 -> R² = -7.3202, MSE = 7.0106e-01
# X | test1 -> R² = -0.0570, MSE = 1.1073e-01
# X | test2 -> R² = -7.0465, MSE = 6.6217e-01
# X | test3 -> R² = 0.9536, MSE = 4.2704e-03
# X | val -> R² = -0.2384, MSE = 1.1842e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.504351 | Val Loss 0.611506
# Epoch 100 | Train Loss 0.299637 | Val Loss 0.446864
# Epoch 200 | Train Loss 0.294061 | Val Loss 0.425481
# Epoch 300 | Train Loss 0.291944 | Val Loss 0.412321
# Epoch 400 | Train Loss 0.290900 | Val Loss 0.405243
# Epoch 500 | Train Loss 0.289799 | Val Loss 0.407529
# Epoch 600 | Train Loss 0.289099 | Val Loss 0.413855
# Epoch 700 | Train Loss 0.288540 | Val Loss 0.415336
# Early stopping at epoch 729
# X | train1 -> R² = -0.0443, MSE = 1.1260e-01
# X | train2 -> R² = -7.0604, MSE = 6.7917e-01
# X | test1 -> R² = -0.0877, MSE = 1.1394e-01
# X | test2 -> R² = -6.7892, MSE = 6.4100e-01
# X | test3 -> R² = 0.9364, MSE = 5.8545e-03
# X | val -> R² = -0.6443, MSE = 1.5723e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.537259 | Val Loss 0.597992
# Epoch 100 | Train Loss 0.302588 | Val Loss 0.449883
# Epoch 200 | Train Loss 0.296095 | Val Loss 0.428103
# Epoch 300 | Train Loss 0.293265 | Val Loss 0.414343
# Epoch 400 | Train Loss 0.292014 | Val Loss 0.407003
# Epoch 500 | Train Loss 0.291010 | Val Loss 0.401973
# Epoch 600 | Train Loss 0.289916 | Val Loss 0.401067
# Epoch 700 | Train Loss 0.289130 | Val Loss 0.407003
# Epoch 800 | Train Loss 0.288498 | Val Loss 0.410531
# Early stopping at epoch 816
# X | train1 -> R² = -0.0555, MSE = 1.1381e-01
# X | train2 -> R² = -7.3697, MSE = 7.0524e-01
# X | test1 -> R² = -0.0721, MSE = 1.1231e-01
# X | test2 -> R² = -7.0207, MSE = 6.6005e-01
# X | test3 -> R² = 0.9544, MSE = 4.1951e-03
# X | val -> R² = -0.4690, MSE = 1.4047e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.499614 | Val Loss 0.573661
# Epoch 100 | Train Loss 0.300073 | Val Loss 0.446666
# Epoch 200 | Train Loss 0.293383 | Val Loss 0.418537
# Epoch 300 | Train Loss 0.292034 | Val Loss 0.409930
# Epoch 400 | Train Loss 0.291089 | Val Loss 0.403282
# Epoch 500 | Train Loss 0.290203 | Val Loss 0.398824
# Epoch 600 | Train Loss 0.289218 | Val Loss 0.403425
# Epoch 700 | Train Loss 0.288551 | Val Loss 0.407691
# Epoch 800 | Train Loss 0.288088 | Val Loss 0.410388
# Early stopping at epoch 816
# X | train1 -> R² = -0.0235, MSE = 1.1036e-01
# X | train2 -> R² = -6.2330, MSE = 6.0945e-01
# X | test1 -> R² = -0.0434, MSE = 1.0930e-01
# X | test2 -> R² = -5.9240, MSE = 5.6979e-01
# X | test3 -> R² = 0.9523, MSE = 4.3908e-03
# X | val -> R² = 0.0781, MSE = 8.8152e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.528090 | Val Loss 0.587051
# Epoch 100 | Train Loss 0.301154 | Val Loss 0.448786
# Epoch 200 | Train Loss 0.295128 | Val Loss 0.424785
# Epoch 300 | Train Loss 0.292245 | Val Loss 0.406893
# Epoch 400 | Train Loss 0.291206 | Val Loss 0.400728
# Epoch 500 | Train Loss 0.290188 | Val Loss 0.400068
# Epoch 600 | Train Loss 0.289261 | Val Loss 0.406346
# Epoch 700 | Train Loss 0.288498 | Val Loss 0.413614
# Early stopping at epoch 743
# X | train1 -> R² = -0.0601, MSE = 1.1431e-01
# X | train2 -> R² = -7.3752, MSE = 7.0570e-01
# X | test1 -> R² = -0.0417, MSE = 1.0913e-01
# X | test2 -> R² = -7.0745, MSE = 6.6448e-01
# X | test3 -> R² = 0.9581, MSE = 3.8537e-03
# X | val -> R² = -0.1933, MSE = 1.1411e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.509137 | Val Loss 0.557710
# Epoch 100 | Train Loss 0.301022 | Val Loss 0.456584
# Epoch 200 | Train Loss 0.295891 | Val Loss 0.435477
# Epoch 300 | Train Loss 0.292596 | Val Loss 0.415505
# Epoch 400 | Train Loss 0.291269 | Val Loss 0.408576
# Epoch 500 | Train Loss 0.289967 | Val Loss 0.406765
# Epoch 600 | Train Loss 0.289043 | Val Loss 0.411297
# Epoch 700 | Train Loss 0.288424 | Val Loss 0.411512
# Early stopping at epoch 753
# X | train1 -> R² = -0.0490, MSE = 1.1311e-01
# X | train2 -> R² = -6.7517, MSE = 6.5316e-01
# X | test1 -> R² = -0.0436, MSE = 1.0933e-01
# X | test2 -> R² = -6.4075, MSE = 6.0959e-01
# X | test3 -> R² = 0.9373, MSE = 5.7694e-03
# X | val -> R² = -0.7355, MSE = 1.6596e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.502984 | Val Loss 0.581653
# Epoch 100 | Train Loss 0.300224 | Val Loss 0.452850
# Epoch 200 | Train Loss 0.294979 | Val Loss 0.430462
# Epoch 300 | Train Loss 0.291541 | Val Loss 0.405419
# Epoch 400 | Train Loss 0.290301 | Val Loss 0.402786
# Epoch 500 | Train Loss 0.289311 | Val Loss 0.407538
# Epoch 600 | Train Loss 0.288622 | Val Loss 0.412581
# Early stopping at epoch 620
# X | train1 -> R² = -0.0416, MSE = 1.1232e-01
# X | train2 -> R² = -6.8611, MSE = 6.6238e-01
# X | test1 -> R² = -0.0239, MSE = 1.0726e-01
# X | test2 -> R² = -6.5804, MSE = 6.2381e-01
# X | test3 -> R² = 0.9547, MSE = 4.1670e-03
# X | val -> R² = -0.0974, MSE = 1.0493e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.512992 | Val Loss 0.629454
# Epoch 100 | Train Loss 0.300609 | Val Loss 0.446460
# Epoch 200 | Train Loss 0.294895 | Val Loss 0.426307
# Epoch 300 | Train Loss 0.292743 | Val Loss 0.410181
# Epoch 400 | Train Loss 0.291658 | Val Loss 0.404721
# Epoch 500 | Train Loss 0.290627 | Val Loss 0.400359
# Epoch 600 | Train Loss 0.289554 | Val Loss 0.404980
# Epoch 700 | Train Loss 0.288853 | Val Loss 0.408217
# Epoch 800 | Train Loss 0.288113 | Val Loss 0.405762
# Early stopping at epoch 817
# X | train1 -> R² = -0.0484, MSE = 1.1304e-01
# X | train2 -> R² = -7.1089, MSE = 6.8326e-01
# X | test1 -> R² = -0.0662, MSE = 1.1169e-01
# X | test2 -> R² = -6.7813, MSE = 6.4035e-01
# X | test3 -> R² = 0.9586, MSE = 3.8072e-03
# X | val -> R² = -0.0936, MSE = 1.0457e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.512151 | Val Loss 0.622050
# Epoch 100 | Train Loss 0.299686 | Val Loss 0.444476
# Epoch 200 | Train Loss 0.294545 | Val Loss 0.424843
# Epoch 300 | Train Loss 0.292130 | Val Loss 0.407136
# Epoch 400 | Train Loss 0.291115 | Val Loss 0.400548
# Epoch 500 | Train Loss 0.290141 | Val Loss 0.399423
# Epoch 600 | Train Loss 0.289090 | Val Loss 0.405204
# Epoch 700 | Train Loss 0.288406 | Val Loss 0.405974
# Early stopping at epoch 771
# X | train1 -> R² = -0.0376, MSE = 1.1188e-01
# ...
# Epoch 100 | Train Loss 0.216320 | Val Loss 0.463045
# Epoch 200 | Train Loss 0.209876 | Val Loss 0.431722
# Epoch 300 | Train Loss 0.205959 | Val Loss 0.439958
# Epoch 400 | Train Loss 0.203842 | Val Loss 0.439125
# Early stopping at epoch 444
# X | train1 -> R² = -0.5692, MSE = 1.6920e-01
# X | train2 -> R² = -4.7169, MSE = 4.8170e-01
# X | test1 -> R² = -0.4933, MSE = 1.5644e-01
# X | test2 -> R² = -4.4829, MSE = 4.5120e-01
# X | test3 -> R² = 0.9037, MSE = 8.8576e-03
# X | val -> R² = -0.1332, MSE = 1.0836e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.504956 | Val Loss 0.645075
# Epoch 100 | Train Loss 0.216745 | Val Loss 0.456352
# Epoch 200 | Train Loss 0.208937 | Val Loss 0.435190
# Epoch 300 | Train Loss 0.205344 | Val Loss 0.443686
# Epoch 400 | Train Loss 0.204539 | Val Loss 0.447200
# Early stopping at epoch 468
# X | train1 -> R² = -1.0776, MSE = 2.2401e-01
# X | train2 -> R² = -9.3883, MSE = 8.7532e-01
# X | test1 -> R² = -0.9852, MSE = 2.0797e-01
# X | test2 -> R² = -9.1831, MSE = 8.3800e-01
# X | test3 -> R² = 0.8888, MSE = 1.0228e-02
# X | val -> R² = -0.6578, MSE = 1.5853e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.474981 | Val Loss 0.562872
# Epoch 100 | Train Loss 0.214591 | Val Loss 0.439276
# Epoch 200 | Train Loss 0.208067 | Val Loss 0.439958
# Epoch 300 | Train Loss 0.205518 | Val Loss 0.447297
# Epoch 400 | Train Loss 0.203413 | Val Loss 0.442753
# Early stopping at epoch 410
# X | train1 -> R² = -0.7355, MSE = 1.8713e-01
# X | train2 -> R² = -10.3893, MSE = 9.5967e-01
# X | test1 -> R² = -0.6192, MSE = 1.6963e-01
# X | test2 -> R² = -10.1631, MSE = 9.1864e-01
# X | test3 -> R² = 0.9258, MSE = 6.8250e-03
# X | val -> R² = -0.1076, MSE = 1.0591e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.478398 | Val Loss 0.603130
# Epoch 100 | Train Loss 0.215928 | Val Loss 0.450887
# Epoch 200 | Train Loss 0.207602 | Val Loss 0.440438
# Epoch 300 | Train Loss 0.204309 | Val Loss 0.436223
# Epoch 400 | Train Loss 0.202775 | Val Loss 0.438872
# Epoch 500 | Train Loss 0.201652 | Val Loss 0.434717
# Early stopping at epoch 540
# X | train1 -> R² = -0.5769, MSE = 1.7003e-01
# X | train2 -> R² = -5.9968, MSE = 5.8956e-01
# X | test1 -> R² = -0.4098, MSE = 1.4769e-01
# X | test2 -> R² = -5.6901, MSE = 5.5055e-01
# X | test3 -> R² = 0.9081, MSE = 8.4548e-03
# X | val -> R² = -0.4937, MSE = 1.4283e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.489711 | Val Loss 0.564503
# Epoch 100 | Train Loss 0.216851 | Val Loss 0.450535
# Epoch 200 | Train Loss 0.208834 | Val Loss 0.433115
# Epoch 300 | Train Loss 0.205659 | Val Loss 0.447444
# Epoch 400 | Train Loss 0.203182 | Val Loss 0.443418
# Early stopping at epoch 437
# X | train1 -> R² = -0.7713, MSE = 1.9099e-01
# X | train2 -> R² = -6.8880, MSE = 6.6465e-01
# X | test1 -> R² = -0.6938, MSE = 1.7745e-01
# X | test2 -> R² = -6.6041, MSE = 6.2576e-01
# X | test3 -> R² = 0.9060, MSE = 8.6468e-03
# X | val -> R² = -0.2959, MSE = 1.2392e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.489398 | Val Loss 0.639195
# Epoch 100 | Train Loss 0.217248 | Val Loss 0.478327
# Epoch 200 | Train Loss 0.210550 | Val Loss 0.448326
# Epoch 300 | Train Loss 0.207225 | Val Loss 0.460496
# Epoch 400 | Train Loss 0.205427 | Val Loss 0.470596
# Epoch 500 | Train Loss 0.203971 | Val Loss 0.458805
# Early stopping at epoch 522
# X | train1 -> R² = -0.9986, MSE = 2.1550e-01
# X | train2 -> R² = -9.3830, MSE = 8.7487e-01
# X | test1 -> R² = -0.9101, MSE = 2.0010e-01
# X | test2 -> R² = -9.0279, MSE = 8.2523e-01
# X | test3 -> R² = 0.8064, MSE = 1.7816e-02
# X | val -> R² = -1.3153, MSE = 2.2140e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.583936 | Val Loss 0.483332
# Epoch 100 | Train Loss 0.349768 | Val Loss 0.406965
# Epoch 200 | Train Loss 0.345870 | Val Loss 0.391810
# Epoch 300 | Train Loss 0.343683 | Val Loss 0.389377
# Epoch 400 | Train Loss 0.342585 | Val Loss 0.385235
# Epoch 500 | Train Loss 0.341016 | Val Loss 0.377777
# Epoch 600 | Train Loss 0.339563 | Val Loss 0.376599
# Epoch 700 | Train Loss 0.338282 | Val Loss 0.378111
# Epoch 800 | Train Loss 0.336872 | Val Loss 0.380021
# Early stopping at epoch 835
# X | train1 -> R² = 0.6018, MSE = 4.2941e-02
# X | train2 -> R² = -3.4599, MSE = 3.7579e-01
# X | test1 -> R² = 0.6181, MSE = 4.0010e-02
# X | test2 -> R² = -3.2914, MSE = 3.5315e-01
# X | test3 -> R² = 0.7501, MSE = 2.2993e-02
# X | val -> R² = 0.9419, MSE = 5.5558e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.587476 | Val Loss 0.501192
# Epoch 100 | Train Loss 0.350346 | Val Loss 0.410746
# Epoch 200 | Train Loss 0.345264 | Val Loss 0.388740
# Epoch 300 | Train Loss 0.347303 | Val Loss 0.388309
# Epoch 400 | Train Loss 0.342460 | Val Loss 0.383196
# Epoch 500 | Train Loss 0.341142 | Val Loss 0.378505
# Epoch 600 | Train Loss 0.339619 | Val Loss 0.378876
# Epoch 700 | Train Loss 0.338340 | Val Loss 0.379561
# Epoch 800 | Train Loss 0.339899 | Val Loss 0.381963
# Early stopping at epoch 835
# X | train1 -> R² = 0.5988, MSE = 4.3255e-02
# X | train2 -> R² = -2.7128, MSE = 3.1285e-01
# X | test1 -> R² = 0.6583, MSE = 3.5797e-02
# X | test2 -> R² = -2.5166, MSE = 2.8939e-01
# X | test3 -> R² = 0.5760, MSE = 3.9009e-02
# X | val -> R² = 0.9231, MSE = 7.3525e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.595609 | Val Loss 0.512479
# Epoch 100 | Train Loss 0.350080 | Val Loss 0.403729
# Epoch 200 | Train Loss 0.344985 | Val Loss 0.392246
# Epoch 300 | Train Loss 0.343353 | Val Loss 0.389840
# Epoch 400 | Train Loss 0.342005 | Val Loss 0.386374
# Epoch 500 | Train Loss 0.343122 | Val Loss 0.390779
# Epoch 600 | Train Loss 0.341132 | Val Loss 0.383096
# Epoch 700 | Train Loss 0.338598 | Val Loss 0.382585
# Epoch 800 | Train Loss 0.336543 | Val Loss 0.382952
# Early stopping at epoch 819
# X | train1 -> R² = 0.6046, MSE = 4.2638e-02
# X | train2 -> R² = -3.1017, MSE = 3.4561e-01
# X | test1 -> R² = 0.6513, MSE = 3.6526e-02
# X | test2 -> R² = -2.9293, MSE = 3.2336e-01
# X | test3 -> R² = 0.4937, MSE = 4.6585e-02
# X | val -> R² = 0.8610, MSE = 1.3291e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.607239 | Val Loss 0.519418
# Epoch 100 | Train Loss 0.350304 | Val Loss 0.412207
# Epoch 200 | Train Loss 0.345032 | Val Loss 0.393523
# Epoch 300 | Train Loss 0.344984 | Val Loss 0.388175
# Epoch 400 | Train Loss 0.342203 | Val Loss 0.383393
# Epoch 500 | Train Loss 0.339970 | Val Loss 0.382134
# Epoch 600 | Train Loss 0.338790 | Val Loss 0.382636
# Epoch 700 | Train Loss 0.336655 | Val Loss 0.383830
# Early stopping at epoch 705
# X | train1 -> R² = 0.5908, MSE = 4.4123e-02
# X | train2 -> R² = -3.3645, MSE = 3.6776e-01
# X | test1 -> R² = 0.6247, MSE = 3.9320e-02
# X | test2 -> R² = -3.1921, MSE = 3.4498e-01
# X | test3 -> R² = 0.8165, MSE = 1.6882e-02
# X | val -> R² = 0.8327, MSE = 1.5999e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.616369 | Val Loss 0.498530
# Epoch 100 | Train Loss 0.352720 | Val Loss 0.418184
# Epoch 200 | Train Loss 0.345942 | Val Loss 0.394471
# Epoch 300 | Train Loss 0.343876 | Val Loss 0.393562
# Epoch 400 | Train Loss 0.343364 | Val Loss 0.388087
# Epoch 500 | Train Loss 0.341950 | Val Loss 0.383992
# Epoch 600 | Train Loss 0.340551 | Val Loss 0.381523
# Epoch 700 | Train Loss 0.339611 | Val Loss 0.380601
# Epoch 800 | Train Loss 0.339359 | Val Loss 0.378570
# Epoch 900 | Train Loss 0.336623 | Val Loss 0.381305
# Early stopping at epoch 981
# X | train1 -> R² = 0.6585, MSE = 3.6826e-02
# X | train2 -> R² = -1.9425, MSE = 2.4794e-01
# X | test1 -> R² = 0.6928, MSE = 3.2178e-02
# X | test2 -> R² = -1.8408, MSE = 2.3378e-01
# X | test3 -> R² = 0.3622, MSE = 5.8677e-02
# X | val -> R² = 0.9166, MSE = 7.9716e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.562622 | Val Loss 0.492968
# Epoch 100 | Train Loss 0.351673 | Val Loss 0.414930
# Epoch 200 | Train Loss 0.351766 | Val Loss 0.392139
# Epoch 300 | Train Loss 0.345341 | Val Loss 0.393374
# Epoch 400 | Train Loss 0.342926 | Val Loss 0.387088
# Epoch 500 | Train Loss 0.341647 | Val Loss 0.380854
# Epoch 600 | Train Loss 0.339821 | Val Loss 0.380242
# Epoch 700 | Train Loss 0.338604 | Val Loss 0.379457
# Epoch 800 | Train Loss 0.337245 | Val Loss 0.379906
# Epoch 900 | Train Loss 0.335522 | Val Loss 0.382121
# Epoch 1000 | Train Loss 0.333393 | Val Loss 0.383686
# Early stopping at epoch 1050
# X | train1 -> R² = 0.6163, MSE = 4.1374e-02
# X | train2 -> R² = -3.9163, MSE = 4.1425e-01
# X | test1 -> R² = 0.6410, MSE = 3.7609e-02
# X | test2 -> R² = -3.8244, MSE = 3.9701e-01
# X | test3 -> R² = 0.5819, MSE = 3.8467e-02
# X | val -> R² = 0.9254, MSE = 7.1370e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.613551 | Val Loss 0.525717
# Epoch 100 | Train Loss 0.349694 | Val Loss 0.405015
# Epoch 200 | Train Loss 0.346276 | Val Loss 0.391057
# Epoch 300 | Train Loss 0.344395 | Val Loss 0.386528
# Epoch 400 | Train Loss 0.343098 | Val Loss 0.384012
# Epoch 500 | Train Loss 0.341635 | Val Loss 0.378083
# Epoch 600 | Train Loss 0.340253 | Val Loss 0.376509
# Epoch 700 | Train Loss 0.339044 | Val Loss 0.379318
# Epoch 800 | Train Loss 0.337758 | Val Loss 0.382831
# Early stopping at epoch 841
# X | train1 -> R² = 0.6135, MSE = 4.1676e-02
# X | train2 -> R² = -2.4690, MSE = 2.9230e-01
# X | test1 -> R² = 0.6541, MSE = 3.6238e-02
# X | test2 -> R² = -2.2590, MSE = 2.6819e-01
# X | test3 -> R² = 0.7159, MSE = 2.6141e-02
# X | val -> R² = 0.9443, MSE = 5.3248e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.655308 | Val Loss 0.576832
# Epoch 100 | Train Loss 0.352853 | Val Loss 0.418228
# Epoch 200 | Train Loss 0.345163 | Val Loss 0.389641
# Epoch 300 | Train Loss 0.343517 | Val Loss 0.388572
# Epoch 400 | Train Loss 0.341954 | Val Loss 0.388235
# Epoch 500 | Train Loss 0.341124 | Val Loss 0.384307
# Epoch 600 | Train Loss 0.339139 | Val Loss 0.383502
# Epoch 700 | Train Loss 0.337353 | Val Loss 0.381769
# Epoch 800 | Train Loss 0.335393 | Val Loss 0.381922
# Epoch 900 | Train Loss 0.333761 | Val Loss 0.383866
# Early stopping at epoch 976
# X | train1 -> R² = 0.5875, MSE = 4.4474e-02
# X | train2 -> R² = -4.9093, MSE = 4.9792e-01
# X | test1 -> R² = 0.6508, MSE = 3.6579e-02
# X | test2 -> R² = -4.7405, MSE = 4.7241e-01
# X | test3 -> R² = 0.2850, MSE = 6.5787e-02
# X | val -> R² = 0.9146, MSE = 8.1708e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.582191 | Val Loss 0.515670
# Epoch 100 | Train Loss 0.356223 | Val Loss 0.406686
# Epoch 200 | Train Loss 0.345178 | Val Loss 0.388211
# Epoch 300 | Train Loss 0.343400 | Val Loss 0.385661
# Epoch 400 | Train Loss 0.342033 | Val Loss 0.379201
# Epoch 500 | Train Loss 0.340595 | Val Loss 0.374059
# Epoch 600 | Train Loss 0.339369 | Val Loss 0.375697
# Epoch 700 | Train Loss 0.337847 | Val Loss 0.377248
# Early stopping at epoch 780
# X | train1 -> R² = 0.6771, MSE = 3.4812e-02
# X | train2 -> R² = -1.2245, MSE = 1.8744e-01
# X | test1 -> R² = 0.6913, MSE = 3.2335e-02
# X | test2 -> R² = -1.0735, MSE = 1.7063e-01
# X | test3 -> R² = 0.6668, MSE = 3.0652e-02
# X | val -> R² = 0.9324, MSE = 6.4678e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.572075 | Val Loss 0.454369
# Epoch 100 | Train Loss 0.352042 | Val Loss 0.416576
# Epoch 200 | Train Loss 0.346540 | Val Loss 0.392794
# Epoch 300 | Train Loss 0.347272 | Val Loss 0.386598
# Epoch 400 | Train Loss 0.343465 | Val Loss 0.385531
# Epoch 500 | Train Loss 0.342665 | Val Loss 0.385654
# Epoch 600 | Train Loss 0.340917 | Val Loss 0.381604
# Epoch 700 | Train Loss 0.346563 | Val Loss 0.386498
# Epoch 800 | Train Loss 0.337768 | Val Loss 0.379401
# Epoch 900 | Train Loss 0.336798 | Val Loss 0.381149
# Epoch 1000 | Train Loss 0.337372 | Val Loss 0.390421
# Early stopping at epoch 1007
# X | train1 -> R² = 0.6416, MSE = 3.8640e-02
# X | train2 -> R² = -3.7494, MSE = 4.0018e-01
# X | test1 -> R² = 0.6726, MSE = 3.4294e-02
# X | test2 -> R² = -3.5591, MSE = 3.7518e-01
# X | test3 -> R² = 0.5092, MSE = 4.5153e-02
# X | val -> R² = 0.9358, MSE = 6.1360e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.602847 | Val Loss 0.533729
# Epoch 100 | Train Loss 0.350550 | Val Loss 0.411910
# Epoch 200 | Train Loss 0.344453 | Val Loss 0.393670
# Epoch 300 | Train Loss 0.343156 | Val Loss 0.389078
# Epoch 400 | Train Loss 0.341706 | Val Loss 0.381589
# Epoch 500 | Train Loss 0.345024 | Val Loss 0.380888
# Epoch 600 | Train Loss 0.338759 | Val Loss 0.377954
# Epoch 700 | Train Loss 0.338407 | Val Loss 0.377196
# Epoch 800 | Train Loss 0.335249 | Val Loss 0.380774
# Early stopping at epoch 809
# X | train1 -> R² = 0.6008, MSE = 4.3043e-02
# X | train2 -> R² = -3.7614, MSE = 4.0120e-01
# X | test1 -> R² = 0.6571, MSE = 3.5928e-02
# X | test2 -> R² = -3.5626, MSE = 3.7547e-01
# X | test3 -> R² = 0.7229, MSE = 2.5497e-02
# X | val -> R² = 0.9179, MSE = 7.8528e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.598163 | Val Loss 0.495009
# Epoch 100 | Train Loss 0.349330 | Val Loss 0.405738
# Epoch 200 | Train Loss 0.345691 | Val Loss 0.389844
# Epoch 300 | Train Loss 0.343940 | Val Loss 0.388244
# Epoch 400 | Train Loss 0.342945 | Val Loss 0.385088
# Epoch 500 | Train Loss 0.341835 | Val Loss 0.380753
# Epoch 600 | Train Loss 0.340245 | Val Loss 0.376588
# Epoch 700 | Train Loss 0.338820 | Val Loss 0.378721
# Epoch 800 | Train Loss 0.337294 | Val Loss 0.380972
# Early stopping at epoch 882
# X | train1 -> R² = 0.6495, MSE = 3.7792e-02
# X | train2 -> R² = -3.0734, MSE = 3.4322e-01
# X | test1 -> R² = 0.6675, MSE = 3.4835e-02
# X | test2 -> R² = -2.9001, MSE = 3.2095e-01
# X | test3 -> R² = 0.7487, MSE = 2.3119e-02
# X | val -> R² = 0.9658, MSE = 3.2740e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.567183 | Val Loss 0.475583
# Epoch 100 | Train Loss 0.349408 | Val Loss 0.403473
# Epoch 200 | Train Loss 0.344490 | Val Loss 0.386274
# Epoch 300 | Train Loss 0.342138 | Val Loss 0.377646
# Epoch 400 | Train Loss 0.340657 | Val Loss 0.376270
# Epoch 500 | Train Loss 0.339367 | Val Loss 0.377370
# Epoch 600 | Train Loss 0.337838 | Val Loss 0.379300
# Epoch 700 | Train Loss 0.335798 | Val Loss 0.381142
# Early stopping at epoch 729
# X | train1 -> R² = 0.6361, MSE = 3.9242e-02
# X | train2 -> R² = -1.9130, MSE = 2.4545e-01
# X | test1 -> R² = 0.6987, MSE = 3.1569e-02
# X | test2 -> R² = -1.7545, MSE = 2.2668e-01
# X | test3 -> R² = 0.5509, MSE = 4.1319e-02
# X | val -> R² = 0.9312, MSE = 6.5810e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.584172 | Val Loss 0.496106
# Epoch 100 | Train Loss 0.348830 | Val Loss 0.402185
# Epoch 200 | Train Loss 0.344653 | Val Loss 0.389807
# Epoch 300 | Train Loss 0.342499 | Val Loss 0.380432
# Epoch 400 | Train Loss 0.341085 | Val Loss 0.377142
# Epoch 500 | Train Loss 0.341789 | Val Loss 0.379649
# Epoch 600 | Train Loss 0.339768 | Val Loss 0.379121
# Epoch 700 | Train Loss 0.338148 | Val Loss 0.382091
# Early stopping at epoch 779
# X | train1 -> R² = 0.6562, MSE = 3.7073e-02
# X | train2 -> R² = -1.5745, MSE = 2.1693e-01
# X | test1 -> R² = 0.7183, MSE = 2.9515e-02
# X | test2 -> R² = -1.4462, MSE = 2.0131e-01
# X | test3 -> R² = 0.6830, MSE = 2.9170e-02
# X | val -> R² = 0.8601, MSE = 1.3376e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.608117 | Val Loss 0.478154
# Epoch 100 | Train Loss 0.352035 | Val Loss 0.419667
# Epoch 200 | Train Loss 0.347247 | Val Loss 0.394714
# Epoch 300 | Train Loss 0.343875 | Val Loss 0.390554
# Epoch 400 | Train Loss 0.350751 | Val Loss 0.387760
# Epoch 500 | Train Loss 0.342341 | Val Loss 0.381298
# Epoch 600 | Train Loss 0.342412 | Val Loss 0.375415
# Epoch 700 | Train Loss 0.338707 | Val Loss 0.376536
# Epoch 800 | Train Loss 0.338243 | Val Loss 0.378553
# Early stopping at epoch 896
# X | train1 -> R² = 0.6527, MSE = 3.7447e-02
# X | train2 -> R² = -1.9009, MSE = 2.4443e-01
# X | test1 -> R² = 0.6801, MSE = 3.3508e-02
# X | test2 -> R² = -1.7630, MSE = 2.2738e-01
# X | test3 -> R² = 0.6934, MSE = 2.8206e-02
# X | val -> R² = 0.9516, MSE = 4.6281e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
