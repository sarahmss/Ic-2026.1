# %% [markdown]
# - Entradas: PwmD, PwmE + Theta
#
# - Saidas: X
# - Trajetorias: ZZx + ZZy

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef", "Theta"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.519871 | Val Loss 0.678910
# Epoch 100 | Train Loss 0.314729 | Val Loss 0.432304
# Epoch 200 | Train Loss 0.307423 | Val Loss 0.413985
# Epoch 300 | Train Loss 0.302688 | Val Loss 0.417393
# Epoch 400 | Train Loss 0.298509 | Val Loss 0.420794
# Epoch 500 | Train Loss 0.296459 | Val Loss 0.424823
# Early stopping at epoch 511
# X | train1 -> R² = -0.0948, MSE = 1.1805e-01
# X | train2 -> R² = -7.0206, MSE = 6.7582e-01
# X | test1 -> R² = -0.0686, MSE = 1.1194e-01
# X | test2 -> R² = -6.9059, MSE = 6.5060e-01
# X | test3 -> R² = 0.6247, MSE = 3.4533e-02
# X | val -> R² = 0.4100, MSE = 5.6422e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.513135 | Val Loss 0.606217
# Epoch 100 | Train Loss 0.317241 | Val Loss 0.436072
# Epoch 200 | Train Loss 0.308132 | Val Loss 0.414487
# Epoch 300 | Train Loss 0.302535 | Val Loss 0.409291
# Epoch 400 | Train Loss 0.298834 | Val Loss 0.404013
# Epoch 500 | Train Loss 0.297013 | Val Loss 0.401061
# Epoch 600 | Train Loss 0.295567 | Val Loss 0.400559
# Epoch 700 | Train Loss 0.294051 | Val Loss 0.402334
# Epoch 800 | Train Loss 0.292272 | Val Loss 0.405943
# Early stopping at epoch 830
# X | train1 -> R² = -0.0703, MSE = 1.1540e-01
# X | train2 -> R² = -7.0872, MSE = 6.8143e-01
# X | test1 -> R² = -0.2207, MSE = 1.2788e-01
# X | test2 -> R² = -7.1686, MSE = 6.7222e-01
# X | test3 -> R² = 0.9156, MSE = 7.7666e-03
# X | val -> R² = 0.7951, MSE = 1.9597e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.521885 | Val Loss 0.697226
# Epoch 100 | Train Loss 0.315675 | Val Loss 0.432706
# Epoch 200 | Train Loss 0.307168 | Val Loss 0.414864
# Epoch 300 | Train Loss 0.301947 | Val Loss 0.413169
# Epoch 400 | Train Loss 0.297520 | Val Loss 0.412201
# Epoch 500 | Train Loss 0.295632 | Val Loss 0.414908
# Epoch 600 | Train Loss 0.294063 | Val Loss 0.417822
# Early stopping at epoch 664
# X | train1 -> R² = -0.1291, MSE = 1.2175e-01
# X | train2 -> R² = -7.0977, MSE = 6.8232e-01
# X | test1 -> R² = -0.1795, MSE = 1.2357e-01
# X | test2 -> R² = -7.1117, MSE = 6.6754e-01
# X | test3 -> R² = 0.9487, MSE = 4.7219e-03
# X | val -> R² = 0.6951, MSE = 2.9158e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.521322 | Val Loss 0.682150
# Epoch 100 | Train Loss 0.318037 | Val Loss 0.449793
# Epoch 200 | Train Loss 0.308047 | Val Loss 0.419848
# Epoch 300 | Train Loss 0.302393 | Val Loss 0.410020
# Epoch 400 | Train Loss 0.297432 | Val Loss 0.411372
# Epoch 500 | Train Loss 0.294459 | Val Loss 0.416097
# Early stopping at epoch 568
# X | train1 -> R² = -0.1846, MSE = 1.2773e-01
# X | train2 -> R² = -7.2328, MSE = 6.9370e-01
# X | test1 -> R² = -0.1856, MSE = 1.2420e-01
# X | test2 -> R² = -7.1255, MSE = 6.6867e-01
# X | test3 -> R² = 0.4115, MSE = 5.4142e-02
# X | val -> R² = 0.0014, MSE = 9.5489e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.531651 | Val Loss 0.654539
# Epoch 100 | Train Loss 0.315827 | Val Loss 0.435615
# Epoch 200 | Train Loss 0.307199 | Val Loss 0.415162
# Epoch 300 | Train Loss 0.303043 | Val Loss 0.415182
# Epoch 400 | Train Loss 0.299560 | Val Loss 0.418391
# Epoch 500 | Train Loss 0.297204 | Val Loss 0.423011
# Early stopping at epoch 521
# X | train1 -> R² = -0.1199, MSE = 1.2075e-01
# X | train2 -> R² = -6.9702, MSE = 6.7157e-01
# X | test1 -> R² = -0.1143, MSE = 1.1673e-01
# X | test2 -> R² = -6.8397, MSE = 6.4515e-01
# X | test3 -> R² = 0.5658, MSE = 3.9945e-02
# X | val -> R² = 0.3030, MSE = 6.6650e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.523419 | Val Loss 0.666235
# Epoch 100 | Train Loss 0.317573 | Val Loss 0.437102
# Epoch 200 | Train Loss 0.307317 | Val Loss 0.413501
# Epoch 300 | Train Loss 0.300890 | Val Loss 0.406527
# Epoch 400 | Train Loss 0.296441 | Val Loss 0.411612
# Epoch 500 | Train Loss 0.294547 | Val Loss 0.417722
# Early stopping at epoch 553
# X | train1 -> R² = -0.1675, MSE = 1.2589e-01
# X | train2 -> R² = -7.0943, MSE = 6.8203e-01
# X | test1 -> R² = -0.1661, MSE = 1.2216e-01
# X | test2 -> R² = -6.9714, MSE = 6.5599e-01
# X | test3 -> R² = 0.7153, MSE = 2.6194e-02
# X | val -> R² = 0.4847, MSE = 4.9279e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.511094 | Val Loss 0.616306
# Epoch 100 | Train Loss 0.320061 | Val Loss 0.453087
# Epoch 200 | Train Loss 0.307308 | Val Loss 0.417648
# Epoch 300 | Train Loss 0.301503 | Val Loss 0.417096
# Epoch 400 | Train Loss 0.297116 | Val Loss 0.423072
# Epoch 500 | Train Loss 0.294518 | Val Loss 0.424677
# Early stopping at epoch 522
# X | train1 -> R² = -0.1864, MSE = 1.2792e-01
# X | train2 -> R² = -7.1322, MSE = 6.8522e-01
# X | test1 -> R² = -0.2254, MSE = 1.2837e-01
# X | test2 -> R² = -6.9645, MSE = 6.5543e-01
# X | test3 -> R² = 0.4571, MSE = 4.9949e-02
# X | val -> R² = 0.0594, MSE = 8.9940e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.517182 | Val Loss 0.677520
# Epoch 100 | Train Loss 0.317189 | Val Loss 0.437289
# Epoch 200 | Train Loss 0.304675 | Val Loss 0.415229
# Epoch 300 | Train Loss 0.298332 | Val Loss 0.414698
# Epoch 400 | Train Loss 0.295169 | Val Loss 0.414053
# Epoch 500 | Train Loss 0.293864 | Val Loss 0.416982
# Early stopping at epoch 522
# X | train1 -> R² = -0.1865, MSE = 1.2794e-01
# X | train2 -> R² = -7.0903, MSE = 6.8169e-01
# X | test1 -> R² = -0.1824, MSE = 1.2386e-01
# X | test2 -> R² = -7.0393, MSE = 6.6158e-01
# X | test3 -> R² = 0.7130, MSE = 2.6407e-02
# X | val -> R² = 0.2887, MSE = 6.8018e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.527959 | Val Loss 0.650895
# Epoch 100 | Train Loss 0.318083 | Val Loss 0.442648
# Epoch 200 | Train Loss 0.308442 | Val Loss 0.418231
# Epoch 300 | Train Loss 0.302811 | Val Loss 0.409801
# Epoch 400 | Train Loss 0.299026 | Val Loss 0.409672
# Epoch 500 | Train Loss 0.296162 | Val Loss 0.412605
# Early stopping at epoch 567
# X | train1 -> R² = -0.1301, MSE = 1.2186e-01
# X | train2 -> R² = -7.0882, MSE = 6.8152e-01
# X | test1 -> R² = -0.1429, MSE = 1.1973e-01
# X | test2 -> R² = -7.0219, MSE = 6.6015e-01
# X | test3 -> R² = 0.7333, MSE = 2.4539e-02
# X | val -> R² = 0.5009, MSE = 4.7727e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.512826 | Val Loss 0.622040
# Epoch 100 | Train Loss 0.315198 | Val Loss 0.428400
# Epoch 200 | Train Loss 0.307544 | Val Loss 0.415143
# Epoch 300 | Train Loss 0.302554 | Val Loss 0.414771
# Epoch 400 | Train Loss 0.298888 | Val Loss 0.413323
# Epoch 500 | Train Loss 0.296825 | Val Loss 0.416328
# Epoch 600 | Train Loss 0.295019 | Val Loss 0.420681
# Early stopping at epoch 640
# X | train1 -> R² = -0.1275, MSE = 1.2157e-01
# X | train2 -> R² = -7.0985, MSE = 6.8238e-01
# X | test1 -> R² = -0.1430, MSE = 1.1974e-01
# X | test2 -> R² = -7.0493, MSE = 6.6240e-01
# X | test3 -> R² = 0.9342, MSE = 6.0572e-03
# X | val -> R² = 0.8483, MSE = 1.4503e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.535421 | Val Loss 0.655086
# Epoch 100 | Train Loss 0.320630 | Val Loss 0.436771
# Epoch 200 | Train Loss 0.307030 | Val Loss 0.415745
# Epoch 300 | Train Loss 0.300857 | Val Loss 0.416269
# Epoch 400 | Train Loss 0.297641 | Val Loss 0.415860
# Epoch 500 | Train Loss 0.295489 | Val Loss 0.419126
# Early stopping at epoch 518
# X | train1 -> R² = -0.1481, MSE = 1.2379e-01
# X | train2 -> R² = -7.1638, MSE = 6.8789e-01
# X | test1 -> R² = -0.1358, MSE = 1.1898e-01
# X | test2 -> R² = -7.0412, MSE = 6.6174e-01
# X | test3 -> R² = 0.4730, MSE = 4.8488e-02
# X | val -> R² = 0.1176, MSE = 8.4377e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.508221 | Val Loss 0.639524
# Epoch 100 | Train Loss 0.314629 | Val Loss 0.431577
# Epoch 200 | Train Loss 0.305960 | Val Loss 0.413986
# Epoch 300 | Train Loss 0.300953 | Val Loss 0.420290
# Epoch 400 | Train Loss 0.296934 | Val Loss 0.425201
# Early stopping at epoch 488
# X | train1 -> R² = -0.1196, MSE = 1.2072e-01
# X | train2 -> R² = -7.0282, MSE = 6.7646e-01
# X | test1 -> R² = -0.1023, MSE = 1.1548e-01
# X | test2 -> R² = -6.9058, MSE = 6.5059e-01
# X | test3 -> R² = 0.6927, MSE = 2.8277e-02
# X | val -> R² = 0.4391, MSE = 5.3635e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.518375 | Val Loss 0.685138
# Epoch 100 | Train Loss 0.319346 | Val Loss 0.439871
# Epoch 200 | Train Loss 0.307687 | Val Loss 0.414764
# Epoch 300 | Train Loss 0.300168 | Val Loss 0.409418
# Epoch 400 | Train Loss 0.296466 | Val Loss 0.410603
# Epoch 500 | Train Loss 0.294367 | Val Loss 0.418497
# Epoch 600 | Train Loss 0.293505 | Val Loss 0.420031
# Early stopping at epoch 608
# X | train1 -> R² = -0.1659, MSE = 1.2572e-01
# X | train2 -> R² = -7.1575, MSE = 6.8736e-01
# X | test1 -> R² = -0.1766, MSE = 1.2326e-01
# X | test2 -> R² = -7.0833, MSE = 6.6520e-01
# X | test3 -> R² = 0.8473, MSE = 1.4046e-02
# X | val -> R² = 0.5774, MSE = 4.0409e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.545091 | Val Loss 0.713113
# Epoch 100 | Train Loss 0.331565 | Val Loss 0.439722
# Epoch 200 | Train Loss 0.308795 | Val Loss 0.416875
# Epoch 300 | Train Loss 0.303048 | Val Loss 0.410078
# Epoch 400 | Train Loss 0.298472 | Val Loss 0.413294
# Epoch 500 | Train Loss 0.295624 | Val Loss 0.423797
# Early stopping at epoch 544
# X | train1 -> R² = -0.1523, MSE = 1.2425e-01
# X | train2 -> R² = -7.1112, MSE = 6.8345e-01
# X | test1 -> R² = -0.1639, MSE = 1.2193e-01
# X | test2 -> R² = -6.9908, MSE = 6.5759e-01
# X | test3 -> R² = 0.4831, MSE = 4.7555e-02
# X | val -> R² = 0.1491, MSE = 8.1364e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.519733 | Val Loss 0.659197
# Epoch 100 | Train Loss 0.321708 | Val Loss 0.469684
# Epoch 200 | Train Loss 0.307875 | Val Loss 0.415105
# Epoch 300 | Train Loss 0.303611 | Val Loss 0.418610
# Epoch 400 | Train Loss 0.299998 | Val Loss 0.432859
# Epoch 500 | Train Loss 0.296036 | Val Loss 0.431978
# Early stopping at epoch 510
# X | train1 -> R² = -0.0898, MSE = 1.1751e-01
# X | train2 -> R² = -6.9991, MSE = 6.7400e-01
# X | test1 -> R² = -0.0810, MSE = 1.1325e-01
# X | test2 -> R² = -6.8263, MSE = 6.4405e-01
# X | test3 -> R² = 0.4953, MSE = 4.6431e-02
# X | val -> R² = 0.1415, MSE = 8.2088e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.459258 | Val Loss 0.654614
# Epoch 100 | Train Loss 0.242836 | Val Loss 0.474556
# Epoch 200 | Train Loss 0.230777 | Val Loss 0.443040
# Epoch 300 | Train Loss 0.223939 | Val Loss 0.432278
# Epoch 400 | Train Loss 0.218423 | Val Loss 0.426509
# Epoch 500 | Train Loss 0.215868 | Val Loss 0.434099
# Epoch 600 | Train Loss 0.214214 | Val Loss 0.438038
# Early stopping at epoch 656
# X | train1 -> R² = -1.1234, MSE = 2.2896e-01
# X | train2 -> R² = -14.8042, MSE = 1.3317e+00
# X | test1 -> R² = -1.2884, MSE = 2.3974e-01
# X | test2 -> R² = -14.8989, MSE = 1.3084e+00
# X | test3 -> R² = 0.4490, MSE = 5.0694e-02
# X | val -> R² = -0.0076, MSE = 9.6351e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.463389 | Val Loss 0.649141
# Epoch 100 | Train Loss 0.245204 | Val Loss 0.485274
# Epoch 200 | Train Loss 0.231806 | Val Loss 0.446742
# Epoch 300 | Train Loss 0.225740 | Val Loss 0.431883
# Epoch 400 | Train Loss 0.220231 | Val Loss 0.424340
# Epoch 500 | Train Loss 0.216493 | Val Loss 0.427241
# Epoch 600 | Train Loss 0.214301 | Val Loss 0.435764
# Epoch 700 | Train Loss 0.212694 | Val Loss 0.438283
# Early stopping at epoch 723
# X | train1 -> R² = -1.1162, MSE = 2.2818e-01
# X | train2 -> R² = -14.7793, MSE = 1.3296e+00
# X | test1 -> R² = -1.2980, MSE = 2.4074e-01
# X | test2 -> R² = -14.9498, MSE = 1.3126e+00
# X | test3 -> R² = 0.7520, MSE = 2.2814e-02
# X | val -> R² = 0.4417, MSE = 5.3388e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.484479 | Val Loss 0.688519
# Epoch 100 | Train Loss 0.246434 | Val Loss 0.480378
# Epoch 200 | Train Loss 0.232330 | Val Loss 0.442451
# Epoch 300 | Train Loss 0.226616 | Val Loss 0.434346
# Epoch 400 | Train Loss 0.221982 | Val Loss 0.437635
# Epoch 500 | Train Loss 0.217160 | Val Loss 0.433041
# Epoch 600 | Train Loss 0.214387 | Val Loss 0.437859
# Epoch 700 | Train Loss 0.213018 | Val Loss 0.439741
# Early stopping at epoch 759
# X | train1 -> R² = -1.1363, MSE = 2.3035e-01
# X | train2 -> R² = -14.8804, MSE = 1.3381e+00
# X | test1 -> R² = -1.4046, MSE = 2.5191e-01
# X | test2 -> R² = -15.0811, MSE = 1.3234e+00
# X | test3 -> R² = 0.9009, MSE = 9.1152e-03
# X | val -> R² = 0.8153, MSE = 1.7665e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.474197 | Val Loss 0.631994
# Epoch 100 | Train Loss 0.240814 | Val Loss 0.472245
# Epoch 200 | Train Loss 0.231869 | Val Loss 0.447242
# Epoch 300 | Train Loss 0.227316 | Val Loss 0.435723
# Epoch 400 | Train Loss 0.223740 | Val Loss 0.432100
# Epoch 500 | Train Loss 0.220424 | Val Loss 0.426126
# Epoch 600 | Train Loss 0.216741 | Val Loss 0.421872
# Epoch 700 | Train Loss 0.213510 | Val Loss 0.426129
# Epoch 800 | Train Loss 0.211402 | Val Loss 0.428712
# Early stopping at epoch 866
# X | train1 -> R² = -1.1413, MSE = 2.3089e-01
# X | train2 -> R² = -14.6413, MSE = 1.3179e+00
# X | test1 -> R² = -1.4630, MSE = 2.5802e-01
# X | test2 -> R² = -14.9694, MSE = 1.3142e+00
# X | test3 -> R² = 0.2829, MSE = 6.5975e-02
# X | val -> R² = -0.0767, MSE = 1.0296e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.454059 | Val Loss 0.629171
# Epoch 100 | Train Loss 0.240308 | Val Loss 0.475010
# Epoch 200 | Train Loss 0.230522 | Val Loss 0.443897
# Epoch 300 | Train Loss 0.224917 | Val Loss 0.435275
# Epoch 400 | Train Loss 0.220612 | Val Loss 0.424588
# Epoch 500 | Train Loss 0.216059 | Val Loss 0.419288
# Epoch 600 | Train Loss 0.212748 | Val Loss 0.426011
# Epoch 700 | Train Loss 0.211256 | Val Loss 0.433417
# Early stopping at epoch 763
# X | train1 -> R² = -1.1026, MSE = 2.2672e-01
# X | train2 -> R² = -14.9380, MSE = 1.3429e+00
# X | test1 -> R² = -1.3236, MSE = 2.4342e-01
# X | test2 -> R² = -15.1217, MSE = 1.3267e+00
# X | test3 -> R² = 0.2105, MSE = 7.2640e-02
# X | val -> R² = -0.3778, MSE = 1.3175e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.476724 | Val Loss 0.613274
# Epoch 100 | Train Loss 0.244003 | Val Loss 0.476768
# Epoch 200 | Train Loss 0.232808 | Val Loss 0.448473
# Epoch 300 | Train Loss 0.228540 | Val Loss 0.436735
# Epoch 400 | Train Loss 0.224837 | Val Loss 0.434305
# Epoch 500 | Train Loss 0.222476 | Val Loss 0.431744
# Epoch 600 | Train Loss 0.219486 | Val Loss 0.425317
# Epoch 700 | Train Loss 0.215912 | Val Loss 0.423269
# Epoch 800 | Train Loss 0.213202 | Val Loss 0.434144
# Epoch 900 | Train Loss 0.211897 | Val Loss 0.443789
# Early stopping at epoch 951
# X | train1 -> R² = -1.1068, MSE = 2.2717e-01
# X | train2 -> R² = -14.8000, MSE = 1.3313e+00
# X | test1 -> R² = -1.3731, MSE = 2.4861e-01
# X | test2 -> R² = -14.8922, MSE = 1.3078e+00
# X | test3 -> R² = 0.6338, MSE = 3.3691e-02
# X | val -> R² = 0.3707, MSE = 6.0177e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.476823 | Val Loss 0.680851
# Epoch 100 | Train Loss 0.251240 | Val Loss 0.536332
# Epoch 200 | Train Loss 0.233671 | Val Loss 0.461577
# Epoch 300 | Train Loss 0.227286 | Val Loss 0.440138
# Epoch 400 | Train Loss 0.222305 | Val Loss 0.431415
# Epoch 500 | Train Loss 0.216925 | Val Loss 0.431778
# Epoch 600 | Train Loss 0.214201 | Val Loss 0.443613
# Epoch 700 | Train Loss 0.212942 | Val Loss 0.448280
# Early stopping at epoch 733
# X | train1 -> R² = -1.1738, MSE = 2.3439e-01
# X | train2 -> R² = -14.7512, MSE = 1.3272e+00
# X | test1 -> R² = -1.3154, MSE = 2.4256e-01
# X | test2 -> R² = -15.0195, MSE = 1.3183e+00
# X | test3 -> R² = 0.4693, MSE = 4.8829e-02
# X | val -> R² = -0.0743, MSE = 1.0273e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.461792 | Val Loss 0.660312
# Epoch 100 | Train Loss 0.246029 | Val Loss 0.491044
# Epoch 200 | Train Loss 0.232957 | Val Loss 0.456807
# Epoch 300 | Train Loss 0.226035 | Val Loss 0.432184
# Epoch 400 | Train Loss 0.222059 | Val Loss 0.425020
# Epoch 500 | Train Loss 0.218127 | Val Loss 0.420593
# Epoch 600 | Train Loss 0.214653 | Val Loss 0.420069
# Epoch 700 | Train Loss 0.212260 | Val Loss 0.423228
# Early stopping at epoch 794
# X | train1 -> R² = -1.1267, MSE = 2.2931e-01
# X | train2 -> R² = -14.6812, MSE = 1.3213e+00
# X | test1 -> R² = -1.4158, MSE = 2.5308e-01
# X | test2 -> R² = -14.9217, MSE = 1.3103e+00
# X | test3 -> R² = 0.5446, MSE = 4.1900e-02
# X | val -> R² = 0.2839, MSE = 6.8472e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.487313 | Val Loss 0.619830
# Epoch 100 | Train Loss 0.246438 | Val Loss 0.482816
# Epoch 200 | Train Loss 0.231813 | Val Loss 0.442506
# Epoch 300 | Train Loss 0.226660 | Val Loss 0.436607
# Epoch 400 | Train Loss 0.224082 | Val Loss 0.432246
# Epoch 500 | Train Loss 0.221894 | Val Loss 0.424791
# Epoch 600 | Train Loss 0.218995 | Val Loss 0.419335
# Epoch 700 | Train Loss 0.216142 | Val Loss 0.421087
# Epoch 800 | Train Loss 0.214158 | Val Loss 0.428148
# Early stopping at epoch 893
# X | train1 -> R² = -1.1614, MSE = 2.3305e-01
# X | train2 -> R² = -14.6167, MSE = 1.3159e+00
# X | test1 -> R² = -1.4028, MSE = 2.5172e-01
# X | test2 -> R² = -14.7511, MSE = 1.2962e+00
# X | test3 -> R² = 0.3986, MSE = 5.5332e-02
# X | val -> R² = 0.3106, MSE = 6.5924e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.528818 | Val Loss 0.626613
# Epoch 100 | Train Loss 0.245953 | Val Loss 0.488817
# Epoch 200 | Train Loss 0.234097 | Val Loss 0.452734
# Epoch 300 | Train Loss 0.228701 | Val Loss 0.437932
# Epoch 400 | Train Loss 0.225283 | Val Loss 0.435405
# Epoch 500 | Train Loss 0.223195 | Val Loss 0.435541
# Epoch 600 | Train Loss 0.221401 | Val Loss 0.433645
# Epoch 700 | Train Loss 0.218919 | Val Loss 0.433650
# Epoch 800 | Train Loss 0.216101 | Val Loss 0.437378
# Early stopping at epoch 895
# X | train1 -> R² = -1.1552, MSE = 2.3238e-01
# X | train2 -> R² = -14.6466, MSE = 1.3184e+00
# X | test1 -> R² = -1.5150, MSE = 2.6347e-01
# X | test2 -> R² = -14.9133, MSE = 1.3096e+00
# X | test3 -> R² = 0.7803, MSE = 2.0212e-02
# X | val -> R² = 0.5277, MSE = 4.5166e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.462278 | Val Loss 0.664495
# Epoch 100 | Train Loss 0.243719 | Val Loss 0.489432
# Epoch 200 | Train Loss 0.232256 | Val Loss 0.453225
# Epoch 300 | Train Loss 0.227309 | Val Loss 0.437359
# Epoch 400 | Train Loss 0.223021 | Val Loss 0.436488
# Epoch 500 | Train Loss 0.219403 | Val Loss 0.434873
# Epoch 600 | Train Loss 0.215924 | Val Loss 0.452612
# Epoch 700 | Train Loss 0.213353 | Val Loss 0.472974
# Early stopping at epoch 755
# X | train1 -> R² = -1.1698, MSE = 2.3396e-01
# X | train2 -> R² = -14.8794, MSE = 1.3380e+00
# X | test1 -> R² = -1.3843, MSE = 2.4978e-01
# X | test2 -> R² = -15.0241, MSE = 1.3187e+00
# X | test3 -> R² = 0.8748, MSE = 1.1520e-02
# X | val -> R² = 0.6478, MSE = 3.3675e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.457528 | Val Loss 0.663605
# Epoch 100 | Train Loss 0.242109 | Val Loss 0.484194
# Epoch 200 | Train Loss 0.230720 | Val Loss 0.445608
# Epoch 300 | Train Loss 0.224949 | Val Loss 0.432384
# Epoch 400 | Train Loss 0.220388 | Val Loss 0.429326
# Epoch 500 | Train Loss 0.215929 | Val Loss 0.442600
# Epoch 600 | Train Loss 0.213591 | Val Loss 0.457357
# Early stopping at epoch 653
# X | train1 -> R² = -1.2111, MSE = 2.3841e-01
# X | train2 -> R² = -15.0752, MSE = 1.3545e+00
# X | test1 -> R² = -1.3313, MSE = 2.4423e-01
# X | test2 -> R² = -15.2504, MSE = 1.3373e+00
# X | test3 -> R² = 0.6857, MSE = 2.8920e-02
# X | val -> R² = 0.3068, MSE = 6.6282e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.461586 | Val Loss 0.694646
# Epoch 100 | Train Loss 0.250085 | Val Loss 0.533558
# Epoch 200 | Train Loss 0.232611 | Val Loss 0.470565
# Epoch 300 | Train Loss 0.225723 | Val Loss 0.444124
# Epoch 400 | Train Loss 0.218595 | Val Loss 0.434842
# Epoch 500 | Train Loss 0.215351 | Val Loss 0.435902
# Epoch 600 | Train Loss 0.213733 | Val Loss 0.432632
# Epoch 700 | Train Loss 0.212387 | Val Loss 0.431172
# Epoch 800 | Train Loss 0.211127 | Val Loss 0.431291
# Epoch 900 | Train Loss 0.210146 | Val Loss 0.429345
# Epoch 1000 | Train Loss 0.209236 | Val Loss 0.427320
# Epoch 1100 | Train Loss 0.208465 | Val Loss 0.427560
# Epoch 1200 | Train Loss 0.207805 | Val Loss 0.430071
# Early stopping at epoch 1270
# X | train1 -> R² = -1.1153, MSE = 2.2808e-01
# X | train2 -> R² = -14.8887, MSE = 1.3388e+00
# X | test1 -> R² = -1.2055, MSE = 2.3105e-01
# X | test2 -> R² = -15.2018, MSE = 1.3333e+00
# X | test3 -> R² = 0.9177, MSE = 7.5726e-03
# X | val -> R² = 0.3484, MSE = 6.2307e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.482293 | Val Loss 0.691103
# Epoch 100 | Train Loss 0.249841 | Val Loss 0.527032
# Epoch 200 | Train Loss 0.232868 | Val Loss 0.457800
# Epoch 300 | Train Loss 0.227154 | Val Loss 0.434181
# Epoch 400 | Train Loss 0.222762 | Val Loss 0.432789
# Epoch 500 | Train Loss 0.216897 | Val Loss 0.427204
# Epoch 600 | Train Loss 0.214048 | Val Loss 0.430137
# Epoch 700 | Train Loss 0.212489 | Val Loss 0.428252
# Early stopping at epoch 792
# X | train1 -> R² = -1.1041, MSE = 2.2687e-01
# X | train2 -> R² = -14.6750, MSE = 1.3208e+00
# X | test1 -> R² = -1.2965, MSE = 2.4058e-01
# X | test2 -> R² = -14.8527, MSE = 1.3046e+00
# X | test3 -> R² = 0.8311, MSE = 1.5537e-02
# X | val -> R² = 0.4353, MSE = 5.4002e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.471451 | Val Loss 0.581295
# Epoch 100 | Train Loss 0.244080 | Val Loss 0.488481
# Epoch 200 | Train Loss 0.233090 | Val Loss 0.453442
# Epoch 300 | Train Loss 0.226507 | Val Loss 0.432220
# Epoch 400 | Train Loss 0.221426 | Val Loss 0.432281
# Epoch 500 | Train Loss 0.217850 | Val Loss 0.442771
# Epoch 600 | Train Loss 0.215499 | Val Loss 0.458087
# Early stopping at epoch 622
# X | train1 -> R² = -1.2330, MSE = 2.4077e-01
# X | train2 -> R² = -14.8503, MSE = 1.3355e+00
# X | test1 -> R² = -1.3553, MSE = 2.4674e-01
# X | test2 -> R² = -14.9378, MSE = 1.3116e+00
# X | test3 -> R² = 0.4338, MSE = 5.2095e-02
# X | val -> R² = -0.1004, MSE = 1.0522e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.548647 | Val Loss 0.605821
# Epoch 100 | Train Loss 0.368374 | Val Loss 0.406300
# Epoch 200 | Train Loss 0.359805 | Val Loss 0.398926
# Epoch 300 | Train Loss 0.354817 | Val Loss 0.406125
# Epoch 400 | Train Loss 0.352292 | Val Loss 0.403535
# Early stopping at epoch 474
# X | train1 -> R² = 0.6275, MSE = 4.0160e-02
# X | train2 -> R² = -1.8757, MSE = 2.4231e-01
# X | test1 -> R² = 0.6831, MSE = 3.3196e-02
# X | test2 -> R² = -1.7241, MSE = 2.2418e-01
# X | test3 -> R² = 0.9571, MSE = 3.9470e-03
# X | val -> R² = 0.9339, MSE = 6.3175e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.542999 | Val Loss 0.584916
# Epoch 100 | Train Loss 0.365899 | Val Loss 0.404120
# Epoch 200 | Train Loss 0.359132 | Val Loss 0.396093
# Epoch 300 | Train Loss 0.353950 | Val Loss 0.407369
# Epoch 400 | Train Loss 0.350867 | Val Loss 0.407975
# Early stopping at epoch 463
# X | train1 -> R² = 0.6361, MSE = 3.9238e-02
# X | train2 -> R² = -1.8887, MSE = 2.4340e-01
# X | test1 -> R² = 0.6921, MSE = 3.2257e-02
# X | test2 -> R² = -1.7666, MSE = 2.2768e-01
# X | test3 -> R² = 0.9265, MSE = 6.7618e-03
# X | val -> R² = 0.8210, MSE = 1.7119e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.567381 | Val Loss 0.670181
# Epoch 100 | Train Loss 0.371801 | Val Loss 0.406896
# Epoch 200 | Train Loss 0.358474 | Val Loss 0.407596
# Epoch 300 | Train Loss 0.354326 | Val Loss 0.415407
# Epoch 400 | Train Loss 0.351324 | Val Loss 0.409318
# Early stopping at epoch 432
# X | train1 -> R² = 0.6636, MSE = 3.6267e-02
# X | train2 -> R² = -1.6902, MSE = 2.2668e-01
# X | test1 -> R² = 0.7481, MSE = 2.6390e-02
# X | test2 -> R² = -1.5465, MSE = 2.0956e-01
# X | test3 -> R² = 0.9221, MSE = 7.1659e-03
# X | val -> R² = 0.8913, MSE = 1.0397e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.569511 | Val Loss 0.672829
# Epoch 100 | Train Loss 0.369328 | Val Loss 0.410480
# Epoch 200 | Train Loss 0.359918 | Val Loss 0.396563
# Epoch 300 | Train Loss 0.354831 | Val Loss 0.406307
# Epoch 400 | Train Loss 0.352463 | Val Loss 0.404264
# Early stopping at epoch 480
# X | train1 -> R² = 0.6406, MSE = 3.8749e-02
# X | train2 -> R² = -1.8570, MSE = 2.4073e-01
# X | test1 -> R² = 0.7042, MSE = 3.0993e-02
# X | test2 -> R² = -1.7188, MSE = 2.2373e-01
# X | test3 -> R² = 0.8558, MSE = 1.3272e-02
# X | val -> R² = 0.7664, MSE = 2.2341e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.578880 | Val Loss 0.659425
# Epoch 100 | Train Loss 0.372517 | Val Loss 0.410135
# Epoch 200 | Train Loss 0.362021 | Val Loss 0.399136
# Epoch 300 | Train Loss 0.357219 | Val Loss 0.396399
# Epoch 400 | Train Loss 0.353227 | Val Loss 0.406650
# Epoch 500 | Train Loss 0.350355 | Val Loss 0.414562
# Early stopping at epoch 543
# X | train1 -> R² = 0.6330, MSE = 3.9568e-02
# X | train2 -> R² = -1.8469, MSE = 2.3988e-01
# X | test1 -> R² = 0.6864, MSE = 3.2856e-02
# X | test2 -> R² = -1.7100, MSE = 2.2302e-01
# X | test3 -> R² = 0.9047, MSE = 8.7691e-03
# X | val -> R² = 0.7961, MSE = 1.9495e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.570997 | Val Loss 0.676105
# Epoch 100 | Train Loss 0.372987 | Val Loss 0.408405
# Epoch 200 | Train Loss 0.360828 | Val Loss 0.398827
# Epoch 300 | Train Loss 0.355898 | Val Loss 0.409648
# Epoch 400 | Train Loss 0.352750 | Val Loss 0.403477
# Early stopping at epoch 479
# X | train1 -> R² = 0.6265, MSE = 4.0269e-02
# X | train2 -> R² = -1.8340, MSE = 2.3880e-01
# X | test1 -> R² = 0.7061, MSE = 3.0792e-02
# X | test2 -> R² = -1.7092, MSE = 2.2295e-01
# X | test3 -> R² = 0.9444, MSE = 5.1129e-03
# X | val -> R² = 0.9046, MSE = 9.1233e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.571024 | Val Loss 0.654156
# Epoch 100 | Train Loss 0.370968 | Val Loss 0.411769
# Epoch 200 | Train Loss 0.361136 | Val Loss 0.396143
# Epoch 300 | Train Loss 0.356637 | Val Loss 0.401631
# Epoch 400 | Train Loss 0.352397 | Val Loss 0.413641
# Early stopping at epoch 482
# X | train1 -> R² = 0.6649, MSE = 3.6128e-02
# X | train2 -> R² = -1.7616, MSE = 2.3270e-01
# X | test1 -> R² = 0.7289, MSE = 2.8404e-02
# X | test2 -> R² = -1.6323, MSE = 2.1662e-01
# X | test3 -> R² = 0.8991, MSE = 9.2839e-03
# X | val -> R² = 0.8099, MSE = 1.8180e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.558715 | Val Loss 0.644391
# Epoch 100 | Train Loss 0.379801 | Val Loss 0.406725
# Epoch 200 | Train Loss 0.357059 | Val Loss 0.403282
# Epoch 300 | Train Loss 0.353232 | Val Loss 0.404143
# Epoch 400 | Train Loss 0.350710 | Val Loss 0.400565
# Early stopping at epoch 448
# X | train1 -> R² = 0.6070, MSE = 4.2371e-02
# X | train2 -> R² = -1.6994, MSE = 2.2745e-01
# X | test1 -> R² = 0.6912, MSE = 3.2354e-02
# X | test2 -> R² = -1.5668, MSE = 2.1123e-01
# X | test3 -> R² = 0.9344, MSE = 6.0340e-03
# X | val -> R² = 0.9077, MSE = 8.8234e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.559741 | Val Loss 0.650019
# Epoch 100 | Train Loss 0.369557 | Val Loss 0.408867
# Epoch 200 | Train Loss 0.358951 | Val Loss 0.396636
# Epoch 300 | Train Loss 0.353148 | Val Loss 0.397661
# Epoch 400 | Train Loss 0.350048 | Val Loss 0.397427
# Early stopping at epoch 459
# X | train1 -> R² = 0.6693, MSE = 3.5662e-02
# X | train2 -> R² = -1.8377, MSE = 2.3910e-01
# X | test1 -> R² = 0.7347, MSE = 2.7793e-02
# X | test2 -> R² = -1.6802, MSE = 2.2056e-01
# X | test3 -> R² = 0.9206, MSE = 7.3095e-03
# X | val -> R² = 0.8395, MSE = 1.5345e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.540264 | Val Loss 0.570880
# Epoch 100 | Train Loss 0.365205 | Val Loss 0.403440
# Epoch 200 | Train Loss 0.358341 | Val Loss 0.397489
# Epoch 300 | Train Loss 0.353127 | Val Loss 0.408342
# Epoch 400 | Train Loss 0.350307 | Val Loss 0.411855
# Early stopping at epoch 446
# X | train1 -> R² = 0.6436, MSE = 3.8425e-02
# X | train2 -> R² = -1.8470, MSE = 2.3989e-01
# X | test1 -> R² = 0.7105, MSE = 3.0325e-02
# X | test2 -> R² = -1.7306, MSE = 2.2471e-01
# X | test3 -> R² = 0.8898, MSE = 1.0142e-02
# X | val -> R² = 0.7879, MSE = 2.0281e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.542282 | Val Loss 0.581870
# Epoch 100 | Train Loss 0.367797 | Val Loss 0.406734
# Epoch 200 | Train Loss 0.359995 | Val Loss 0.394914
# Epoch 300 | Train Loss 0.355150 | Val Loss 0.401139
# Epoch 400 | Train Loss 0.351851 | Val Loss 0.405280
# Early stopping at epoch 482
# X | train1 -> R² = 0.6248, MSE = 4.0452e-02
# X | train2 -> R² = -1.8832, MSE = 2.4294e-01
# X | test1 -> R² = 0.6806, MSE = 3.3461e-02
# X | test2 -> R² = -1.7653, MSE = 2.2756e-01
# X | test3 -> R² = 0.8523, MSE = 1.3594e-02
# X | val -> R² = 0.7169, MSE = 2.7074e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.558638 | Val Loss 0.643453
# Epoch 100 | Train Loss 0.368378 | Val Loss 0.405365
# Epoch 200 | Train Loss 0.358571 | Val Loss 0.401176
# Epoch 300 | Train Loss 0.352345 | Val Loss 0.404256
# Epoch 400 | Train Loss 0.349419 | Val Loss 0.401788
# Early stopping at epoch 440
# X | train1 -> R² = 0.6554, MSE = 3.7162e-02
# X | train2 -> R² = -1.7124, MSE = 2.2855e-01
# X | test1 -> R² = 0.7191, MSE = 2.9425e-02
# X | test2 -> R² = -1.5503, MSE = 2.0988e-01
# X | test3 -> R² = 0.9388, MSE = 5.6330e-03
# X | val -> R² = 0.8736, MSE = 1.2082e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.578984 | Val Loss 0.701661
# Epoch 100 | Train Loss 0.368767 | Val Loss 0.407375
# Epoch 200 | Train Loss 0.358078 | Val Loss 0.401102
# Epoch 300 | Train Loss 0.353014 | Val Loss 0.406022
# Epoch 400 | Train Loss 0.350552 | Val Loss 0.402224
# Early stopping at epoch 450
# X | train1 -> R² = 0.6483, MSE = 3.7926e-02
# X | train2 -> R² = -1.7785, MSE = 2.3412e-01
# X | test1 -> R² = 0.7108, MSE = 3.0294e-02
# X | test2 -> R² = -1.6290, MSE = 2.1635e-01
# X | test3 -> R² = 0.9459, MSE = 4.9813e-03
# X | val -> R² = 0.9029, MSE = 9.2828e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.562042 | Val Loss 0.652283
# Epoch 100 | Train Loss 0.371626 | Val Loss 0.405252
# Epoch 200 | Train Loss 0.357570 | Val Loss 0.403172
# Epoch 300 | Train Loss 0.352841 | Val Loss 0.404428
# Epoch 400 | Train Loss 0.350520 | Val Loss 0.402448
# Early stopping at epoch 436
# X | train1 -> R² = 0.6471, MSE = 3.8049e-02
# X | train2 -> R² = -1.9389, MSE = 2.4763e-01
# X | test1 -> R² = 0.7272, MSE = 2.8579e-02
# X | test2 -> R² = -1.7848, MSE = 2.2917e-01
# X | test3 -> R² = 0.9351, MSE = 5.9737e-03
# X | val -> R² = 0.9356, MSE = 6.1623e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.542275 | Val Loss 0.572856
# Epoch 100 | Train Loss 0.365293 | Val Loss 0.402966
# Epoch 200 | Train Loss 0.358426 | Val Loss 0.398848
# Epoch 300 | Train Loss 0.353437 | Val Loss 0.404382
# Epoch 400 | Train Loss 0.350972 | Val Loss 0.399249
# Early stopping at epoch 444
# X | train1 -> R² = 0.6399, MSE = 3.8831e-02
# X | train2 -> R² = -1.8893, MSE = 2.4345e-01
# X | test1 -> R² = 0.7025, MSE = 3.1168e-02
# X | test2 -> R² = -1.7528, MSE = 2.2654e-01
# X | test3 -> R² = 0.9032, MSE = 8.9046e-03
# X | val -> R² = 0.8256, MSE = 1.6676e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.525397 | Val Loss 0.636716
# Epoch 100 | Train Loss 0.313246 | Val Loss 0.442460
# Epoch 200 | Train Loss 0.306547 | Val Loss 0.419182
# Epoch 300 | Train Loss 0.299900 | Val Loss 0.406625
# Epoch 400 | Train Loss 0.295983 | Val Loss 0.412195
# Epoch 500 | Train Loss 0.293809 | Val Loss 0.419471
# Early stopping at epoch 565
# X | train1 -> R² = -0.1420, MSE = 1.2314e-01
# X | train2 -> R² = -7.1342, MSE = 6.8539e-01
# X | test1 -> R² = -0.1440, MSE = 1.1984e-01
# X | test2 -> R² = -7.0834, MSE = 6.6521e-01
# X | test3 -> R² = 0.5580, MSE = 4.0669e-02
# X | val -> R² = 0.2518, MSE = 7.1544e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.497522 | Val Loss 0.570311
# Epoch 100 | Train Loss 0.307189 | Val Loss 0.415373
# Epoch 200 | Train Loss 0.303305 | Val Loss 0.419418
# Epoch 300 | Train Loss 0.299020 | Val Loss 0.424089
# Epoch 400 | Train Loss 0.295277 | Val Loss 0.418512
# Early stopping at epoch 413
# X | train1 -> R² = -0.0605, MSE = 1.1435e-01
# X | train2 -> R² = -7.0416, MSE = 6.7759e-01
# X | test1 -> R² = -0.0469, MSE = 1.0967e-01
# X | test2 -> R² = -6.9183, MSE = 6.5163e-01
# X | test3 -> R² = 0.6122, MSE = 3.5675e-02
# X | val -> R² = 0.3786, MSE = 5.9424e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.515699 | Val Loss 0.636918
# Epoch 100 | Train Loss 0.309798 | Val Loss 0.419806
# Epoch 200 | Train Loss 0.303590 | Val Loss 0.412753
# Epoch 300 | Train Loss 0.299376 | Val Loss 0.407365
# Epoch 400 | Train Loss 0.295689 | Val Loss 0.400597
# Epoch 500 | Train Loss 0.292554 | Val Loss 0.402356
# Epoch 600 | Train Loss 0.291594 | Val Loss 0.399317
# Epoch 700 | Train Loss 0.290872 | Val Loss 0.397488
# Epoch 800 | Train Loss 0.290177 | Val Loss 0.397657
# Epoch 900 | Train Loss 0.289520 | Val Loss 0.398982
# Early stopping at epoch 962
# X | train1 -> R² = -0.0995, MSE = 1.1855e-01
# X | train2 -> R² = -7.1811, MSE = 6.8935e-01
# X | test1 -> R² = -0.2321, MSE = 1.2907e-01
# X | test2 -> R² = -7.2838, MSE = 6.8170e-01
# X | test3 -> R² = 0.0462, MSE = 8.7754e-02
# X | val -> R² = -0.2488, MSE = 1.1942e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.510629 | Val Loss 0.626262
# Epoch 100 | Train Loss 0.307198 | Val Loss 0.414679
# Epoch 200 | Train Loss 0.303060 | Val Loss 0.417281
# Epoch 300 | Train Loss 0.296860 | Val Loss 0.413898
# Epoch 400 | Train Loss 0.293799 | Val Loss 0.415439
# Epoch 500 | Train Loss 0.292605 | Val Loss 0.419523
# Epoch 600 | Train Loss 0.291956 | Val Loss 0.426320
# Early stopping at epoch 610
# X | train1 -> R² = -0.1551, MSE = 1.2454e-01
# X | train2 -> R² = -8.7430, MSE = 8.2094e-01
# X | test1 -> R² = -0.2623, MSE = 1.3223e-01
# X | test2 -> R² = -8.7449, MSE = 8.0194e-01
# X | test3 -> R² = 0.9544, MSE = 4.1996e-03
# X | val -> R² = 0.6605, MSE = 3.2464e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.504042 | Val Loss 0.561930
# Epoch 100 | Train Loss 0.307919 | Val Loss 0.416540
# Epoch 200 | Train Loss 0.303390 | Val Loss 0.413841
# Epoch 300 | Train Loss 0.298860 | Val Loss 0.419520
# Epoch 400 | Train Loss 0.294897 | Val Loss 0.418646
# Early stopping at epoch 448
# X | train1 -> R² = -0.0967, MSE = 1.1825e-01
# X | train2 -> R² = -7.0688, MSE = 6.7988e-01
# X | test1 -> R² = -0.1058, MSE = 1.1584e-01
# X | test2 -> R² = -6.9809, MSE = 6.5677e-01
# X | test3 -> R² = 0.4770, MSE = 4.8118e-02
# X | val -> R² = 0.2145, MSE = 7.5113e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.535997 | Val Loss 0.600528
# Epoch 100 | Train Loss 0.311680 | Val Loss 0.425987
# Epoch 200 | Train Loss 0.305171 | Val Loss 0.413472
# Epoch 300 | Train Loss 0.301135 | Val Loss 0.418544
# Epoch 400 | Train Loss 0.298054 | Val Loss 0.417970
# Early stopping at epoch 485
# X | train1 -> R² = -0.0964, MSE = 1.1822e-01
# X | train2 -> R² = -7.0829, MSE = 6.8107e-01
# X | test1 -> R² = -0.1053, MSE = 1.1579e-01
# X | test2 -> R² = -6.9810, MSE = 6.5678e-01
# X | test3 -> R² = 0.5415, MSE = 4.2188e-02
# X | val -> R² = 0.2811, MSE = 6.8746e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.502169 | Val Loss 0.605711
# Epoch 100 | Train Loss 0.308768 | Val Loss 0.417431
# Epoch 200 | Train Loss 0.302955 | Val Loss 0.415667
# Epoch 300 | Train Loss 0.298569 | Val Loss 0.419068
# Epoch 400 | Train Loss 0.294503 | Val Loss 0.424324
# Early stopping at epoch 441
# X | train1 -> R² = -0.0991, MSE = 1.1851e-01
# X | train2 -> R² = -7.1245, MSE = 6.8457e-01
# X | test1 -> R² = -0.0994, MSE = 1.1517e-01
# X | test2 -> R² = -7.0342, MSE = 6.6116e-01
# X | test3 -> R² = 0.5336, MSE = 4.2906e-02
# X | val -> R² = 0.2845, MSE = 6.8415e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.507222 | Val Loss 0.606610
# Epoch 100 | Train Loss 0.308707 | Val Loss 0.416154
# Epoch 200 | Train Loss 0.303207 | Val Loss 0.414395
# Epoch 300 | Train Loss 0.298118 | Val Loss 0.413505
# Epoch 400 | Train Loss 0.294909 | Val Loss 0.421200
# Early stopping at epoch 444
# X | train1 -> R² = -0.1033, MSE = 1.1896e-01
# X | train2 -> R² = -6.9447, MSE = 6.6943e-01
# X | test1 -> R² = -0.0741, MSE = 1.1252e-01
# X | test2 -> R² = -6.8208, MSE = 6.4360e-01
# X | test3 -> R² = 0.6704, MSE = 3.0327e-02
# X | val -> R² = 0.4451, MSE = 5.3061e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.503314 | Val Loss 0.580800
# Epoch 100 | Train Loss 0.306886 | Val Loss 0.413968
# Epoch 200 | Train Loss 0.301761 | Val Loss 0.415992
# Epoch 300 | Train Loss 0.296302 | Val Loss 0.412772
# Epoch 400 | Train Loss 0.293617 | Val Loss 0.418695
# Epoch 500 | Train Loss 0.292432 | Val Loss 0.419398
# Early stopping at epoch 586
# X | train1 -> R² = -0.0986, MSE = 1.1846e-01
# X | train2 -> R² = -7.2164, MSE = 6.9232e-01
# X | test1 -> R² = -0.1616, MSE = 1.2169e-01
# X | test2 -> R² = -7.2267, MSE = 6.7700e-01
# X | test3 -> R² = 0.9478, MSE = 4.8062e-03
# X | val -> R² = 0.7689, MSE = 2.2103e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.500037 | Val Loss 0.558052
# Epoch 100 | Train Loss 0.307728 | Val Loss 0.414649
# Epoch 200 | Train Loss 0.303052 | Val Loss 0.413127
# Epoch 300 | Train Loss 0.298317 | Val Loss 0.408087
# Epoch 400 | Train Loss 0.294618 | Val Loss 0.405714
# Epoch 500 | Train Loss 0.292438 | Val Loss 0.403598
# Epoch 600 | Train Loss 0.291580 | Val Loss 0.402149
# Epoch 700 | Train Loss 0.290811 | Val Loss 0.401702
# Epoch 800 | Train Loss 0.290018 | Val Loss 0.401558
# Epoch 900 | Train Loss 0.289369 | Val Loss 0.401067
# Epoch 1000 | Train Loss 0.288466 | Val Loss 0.401119
# Epoch 1100 | Train Loss 0.287734 | Val Loss 0.402575
# Early stopping at epoch 1191
# X | train1 -> R² = -0.2374, MSE = 1.3342e-01
# X | train2 -> R² = -8.0430, MSE = 7.6197e-01
# X | test1 -> R² = -0.3462, MSE = 1.4103e-01
# X | test2 -> R² = -8.1841, MSE = 7.5579e-01
# X | test3 -> R² = 0.3724, MSE = 5.7745e-02
# X | val -> R² = -0.4001, MSE = 1.3388e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.500760 | Val Loss 0.588338
# Epoch 100 | Train Loss 0.307247 | Val Loss 0.416055
# Epoch 200 | Train Loss 0.302212 | Val Loss 0.416282
# Epoch 300 | Train Loss 0.297131 | Val Loss 0.412666
# Epoch 400 | Train Loss 0.293782 | Val Loss 0.409326
# Epoch 500 | Train Loss 0.292125 | Val Loss 0.408253
# Epoch 600 | Train Loss 0.290972 | Val Loss 0.408721
# Epoch 700 | Train Loss 0.289791 | Val Loss 0.409525
# Early stopping at epoch 800
# X | train1 -> R² = -0.1195, MSE = 1.2072e-01
# X | train2 -> R² = -7.5052, MSE = 7.1665e-01
# X | test1 -> R² = -0.2727, MSE = 1.3333e-01
# X | test2 -> R² = -7.5653, MSE = 7.0487e-01
# X | test3 -> R² = 0.9566, MSE = 3.9948e-03
# X | val -> R² = 0.5391, MSE = 4.4070e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.520730 | Val Loss 0.582733
# Epoch 100 | Train Loss 0.310666 | Val Loss 0.424201
# Epoch 200 | Train Loss 0.304788 | Val Loss 0.411585
# Epoch 300 | Train Loss 0.300140 | Val Loss 0.408156
# Epoch 400 | Train Loss 0.296544 | Val Loss 0.400425
# Epoch 500 | Train Loss 0.293146 | Val Loss 0.404164
# Epoch 600 | Train Loss 0.291365 | Val Loss 0.413441
# Early stopping at epoch 694
# X | train1 -> R² = -0.0746, MSE = 1.1587e-01
# X | train2 -> R² = -7.1719, MSE = 6.8856e-01
# X | test1 -> R² = -0.1965, MSE = 1.2535e-01
# X | test2 -> R² = -7.2163, MSE = 6.7614e-01
# X | test3 -> R² = 0.8898, MSE = 1.0137e-02
# X | val -> R² = 0.6668, MSE = 3.1866e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.506206 | Val Loss 0.616623
# Epoch 100 | Train Loss 0.308217 | Val Loss 0.415791
# Epoch 200 | Train Loss 0.303595 | Val Loss 0.416542
# Epoch 300 | Train Loss 0.299490 | Val Loss 0.424332
# Epoch 400 | Train Loss 0.295706 | Val Loss 0.418053
# Early stopping at epoch 437
# X | train1 -> R² = -0.1154, MSE = 1.2027e-01
# X | train2 -> R² = -7.0003, MSE = 6.7411e-01
# X | test1 -> R² = -0.1045, MSE = 1.1571e-01
# X | test2 -> R² = -6.9007, MSE = 6.5018e-01
# X | test3 -> R² = 0.6143, MSE = 3.5490e-02
# X | val -> R² = 0.3921, MSE = 5.8132e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.501813 | Val Loss 0.590579
# Epoch 100 | Train Loss 0.308600 | Val Loss 0.417136
# Epoch 200 | Train Loss 0.303435 | Val Loss 0.413451
# Epoch 300 | Train Loss 0.298732 | Val Loss 0.416026
# Epoch 400 | Train Loss 0.295394 | Val Loss 0.410864
# Epoch 500 | Train Loss 0.293144 | Val Loss 0.408494
# Epoch 600 | Train Loss 0.291994 | Val Loss 0.410516
# Early stopping at epoch 699
# X | train1 -> R² = -0.1240, MSE = 1.2120e-01
# X | train2 -> R² = -8.0978, MSE = 7.6658e-01
# X | test1 -> R² = -0.1947, MSE = 1.2516e-01
# X | test2 -> R² = -8.1436, MSE = 7.5246e-01
# X | test3 -> R² = 0.9360, MSE = 5.8887e-03
# X | val -> R² = 0.4722, MSE = 5.0470e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.502510 | Val Loss 0.551807
# Epoch 100 | Train Loss 0.307465 | Val Loss 0.414348
# Epoch 200 | Train Loss 0.302905 | Val Loss 0.415435
# Epoch 300 | Train Loss 0.297903 | Val Loss 0.410558
# Epoch 400 | Train Loss 0.294480 | Val Loss 0.409308
# Epoch 500 | Train Loss 0.292599 | Val Loss 0.408742
# Epoch 600 | Train Loss 0.291424 | Val Loss 0.404994
# Epoch 700 | Train Loss 0.290451 | Val Loss 0.401133
# Epoch 800 | Train Loss 0.289613 | Val Loss 0.404293
# Epoch 900 | Train Loss 0.288927 | Val Loss 0.410614
# Early stopping at epoch 966
# X | train1 -> R² = -0.0875, MSE = 1.1726e-01
# X | train2 -> R² = -7.2024, MSE = 6.9114e-01
# X | test1 -> R² = -0.1639, MSE = 1.2193e-01
# X | test2 -> R² = -7.2648, MSE = 6.8014e-01
# X | test3 -> R² = 0.6381, MSE = 3.3299e-02
# X | val -> R² = -0.1695, MSE = 1.1183e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.498393 | Val Loss 0.566113
# Epoch 100 | Train Loss 0.237490 | Val Loss 0.464900
# Epoch 200 | Train Loss 0.229108 | Val Loss 0.438553
# Epoch 300 | Train Loss 0.223029 | Val Loss 0.429087
# Epoch 400 | Train Loss 0.218516 | Val Loss 0.429114
# Epoch 500 | Train Loss 0.215829 | Val Loss 0.438002
# Epoch 600 | Train Loss 0.213725 | Val Loss 0.447094
# Early stopping at epoch 618
# X | train1 -> R² = -1.1717, MSE = 2.3417e-01
# X | train2 -> R² = -14.9552, MSE = 1.3444e+00
# X | test1 -> R² = -1.3429, MSE = 2.4545e-01
# X | test2 -> R² = -15.1291, MSE = 1.3273e+00
# X | test3 -> R² = 0.8084, MSE = 1.7626e-02
# X | val -> R² = 0.4370, MSE = 5.3832e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.461632 | Val Loss 0.577493
# Epoch 100 | Train Loss 0.233950 | Val Loss 0.458120
# Epoch 200 | Train Loss 0.226910 | Val Loss 0.434076
# Epoch 300 | Train Loss 0.221043 | Val Loss 0.424669
# Epoch 400 | Train Loss 0.216811 | Val Loss 0.425623
# Epoch 500 | Train Loss 0.214020 | Val Loss 0.430240
# Epoch 600 | Train Loss 0.212517 | Val Loss 0.431609
# Early stopping at epoch 610
# X | train1 -> R² = -1.1461, MSE = 2.3141e-01
# X | train2 -> R² = -14.9577, MSE = 1.3446e+00
# X | test1 -> R² = -1.3501, MSE = 2.4620e-01
# X | test2 -> R² = -15.2091, MSE = 1.3339e+00
# X | test3 -> R² = 0.8212, MSE = 1.6447e-02
# X | val -> R² = 0.3699, MSE = 6.0252e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.457122 | Val Loss 0.609981
# Epoch 100 | Train Loss 0.233281 | Val Loss 0.449503
# Epoch 200 | Train Loss 0.226505 | Val Loss 0.436814
# Epoch 300 | Train Loss 0.222342 | Val Loss 0.433902
# Epoch 400 | Train Loss 0.217561 | Val Loss 0.424153
# Epoch 500 | Train Loss 0.212452 | Val Loss 0.427481
# Epoch 600 | Train Loss 0.210483 | Val Loss 0.433832
# Early stopping at epoch 674
# X | train1 -> R² = -1.2517, MSE = 2.4279e-01
# X | train2 -> R² = -16.4726, MSE = 1.4723e+00
# X | test1 -> R² = -1.5276, MSE = 2.6479e-01
# X | test2 -> R² = -16.7014, MSE = 1.4567e+00
# X | test3 -> R² = 0.8924, MSE = 9.8982e-03
# X | val -> R² = 0.5996, MSE = 3.8285e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.471584 | Val Loss 0.615764
# Epoch 100 | Train Loss 0.236534 | Val Loss 0.466921
# Epoch 200 | Train Loss 0.228453 | Val Loss 0.438504
# Epoch 300 | Train Loss 0.222531 | Val Loss 0.426847
# Epoch 400 | Train Loss 0.215843 | Val Loss 0.425357
# Epoch 500 | Train Loss 0.212778 | Val Loss 0.446312
# Epoch 600 | Train Loss 0.211581 | Val Loss 0.455438
# Early stopping at epoch 638
# X | train1 -> R² = -1.1633, MSE = 2.3326e-01
# X | train2 -> R² = -14.7309, MSE = 1.3255e+00
# X | test1 -> R² = -1.4462, MSE = 2.5626e-01
# X | test2 -> R² = -14.9315, MSE = 1.3111e+00
# X | test3 -> R² = 0.7078, MSE = 2.6887e-02
# X | val -> R² = 0.4461, MSE = 5.2963e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.500457 | Val Loss 0.572684
# Epoch 100 | Train Loss 0.236212 | Val Loss 0.459540
# Epoch 200 | Train Loss 0.229826 | Val Loss 0.440705
# Epoch 300 | Train Loss 0.225216 | Val Loss 0.432645
# Epoch 400 | Train Loss 0.221461 | Val Loss 0.422780
# Epoch 500 | Train Loss 0.218312 | Val Loss 0.417267
# Epoch 600 | Train Loss 0.215301 | Val Loss 0.418953
# Epoch 700 | Train Loss 0.212525 | Val Loss 0.427131
# Epoch 800 | Train Loss 0.210985 | Val Loss 0.435805
# Early stopping at epoch 818
# X | train1 -> R² = -1.0718, MSE = 2.2339e-01
# X | train2 -> R² = -14.8209, MSE = 1.3331e+00
# X | test1 -> R² = -1.3090, MSE = 2.4190e-01
# X | test2 -> R² = -15.0147, MSE = 1.3179e+00
# X | test3 -> R² = 0.4820, MSE = 4.7659e-02
# X | val -> R² = -0.0338, MSE = 9.8851e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.478090 | Val Loss 0.611256
# Epoch 100 | Train Loss 0.238577 | Val Loss 0.478741
# Epoch 200 | Train Loss 0.229807 | Val Loss 0.445544
# Epoch 300 | Train Loss 0.224756 | Val Loss 0.435689
# Epoch 400 | Train Loss 0.222006 | Val Loss 0.428246
# Epoch 500 | Train Loss 0.218987 | Val Loss 0.425354
# Epoch 600 | Train Loss 0.215314 | Val Loss 0.436619
# Epoch 700 | Train Loss 0.212840 | Val Loss 0.457360
# Early stopping at epoch 759
# X | train1 -> R² = -1.1536, MSE = 2.3221e-01
# X | train2 -> R² = -14.7334, MSE = 1.3257e+00
# X | test1 -> R² = -1.4152, MSE = 2.5302e-01
# X | test2 -> R² = -14.9442, MSE = 1.3121e+00
# X | test3 -> R² = 0.8699, MSE = 1.1971e-02
# X | val -> R² = 0.7871, MSE = 2.0356e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.544128 | Val Loss 0.605652
# Epoch 100 | Train Loss 0.245735 | Val Loss 0.498837
# Epoch 200 | Train Loss 0.230815 | Val Loss 0.448514
# Epoch 300 | Train Loss 0.223899 | Val Loss 0.429355
# Epoch 400 | Train Loss 0.218352 | Val Loss 0.429709
# Epoch 500 | Train Loss 0.214913 | Val Loss 0.449676
# Epoch 600 | Train Loss 0.212762 | Val Loss 0.456276
# Early stopping at epoch 640
# X | train1 -> R² = -1.1432, MSE = 2.3109e-01
# X | train2 -> R² = -14.7259, MSE = 1.3251e+00
# X | test1 -> R² = -1.2907, MSE = 2.3997e-01
# X | test2 -> R² = -14.9690, MSE = 1.3141e+00
# X | test3 -> R² = 0.6218, MSE = 3.4797e-02
# X | val -> R² = 0.2366, MSE = 7.3000e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.454940 | Val Loss 0.626414
# Epoch 100 | Train Loss 0.234020 | Val Loss 0.452014
# Epoch 200 | Train Loss 0.227294 | Val Loss 0.436371
# Epoch 300 | Train Loss 0.223260 | Val Loss 0.429414
# Epoch 400 | Train Loss 0.220544 | Val Loss 0.419113
# Epoch 500 | Train Loss 0.215399 | Val Loss 0.414338
# Epoch 600 | Train Loss 0.211513 | Val Loss 0.422065
# Epoch 700 | Train Loss 0.210235 | Val Loss 0.427374
# Early stopping at epoch 763
# X | train1 -> R² = -1.0781, MSE = 2.2407e-01
# X | train2 -> R² = -15.0067, MSE = 1.3487e+00
# X | test1 -> R² = -1.2659, MSE = 2.3737e-01
# X | test2 -> R² = -15.2342, MSE = 1.3360e+00
# X | test3 -> R² = 0.2818, MSE = 6.6075e-02
# X | val -> R² = -0.2122, MSE = 1.1592e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.461541 | Val Loss 0.562538
# Epoch 100 | Train Loss 0.233668 | Val Loss 0.452233
# Epoch 200 | Train Loss 0.227902 | Val Loss 0.436308
# Epoch 300 | Train Loss 0.223730 | Val Loss 0.429695
# Epoch 400 | Train Loss 0.220811 | Val Loss 0.420202
# Epoch 500 | Train Loss 0.215878 | Val Loss 0.418194
# Epoch 600 | Train Loss 0.212606 | Val Loss 0.421705
# Epoch 700 | Train Loss 0.211221 | Val Loss 0.425313
# Early stopping at epoch 736
# X | train1 -> R² = -1.0831, MSE = 2.2461e-01
# X | train2 -> R² = -14.9402, MSE = 1.3431e+00
# X | test1 -> R² = -1.2811, MSE = 2.3897e-01
# X | test2 -> R² = -15.1149, MSE = 1.3262e+00
# X | test3 -> R² = 0.4165, MSE = 5.3688e-02
# X | val -> R² = 0.1429, MSE = 8.1962e-02
# ...
# X | test3 -> R² = -0.2285, MSE = 1.1303e-01
# X | val -> R² = -0.7950, MSE = 1.7165e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.488836 | Val Loss 0.622024
# Epoch 100 | Train Loss 0.227229 | Val Loss 0.439294
# Epoch 200 | Train Loss 0.216787 | Val Loss 0.435572
# Epoch 300 | Train Loss 0.212305 | Val Loss 0.440048
# Epoch 400 | Train Loss 0.210371 | Val Loss 0.436521
# Early stopping at epoch 459
# X | train1 -> R² = -1.1941, MSE = 2.3658e-01
# X | train2 -> R² = -14.7093, MSE = 1.3237e+00
# X | test1 -> R² = -1.4105, MSE = 2.5253e-01
# X | test2 -> R² = -14.9563, MSE = 1.3131e+00
# X | test3 -> R² = 0.6396, MSE = 3.3159e-02
# X | val -> R² = -0.0156, MSE = 9.7110e-02
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.474171 | Val Loss 0.571149
# Epoch 100 | Train Loss 0.225271 | Val Loss 0.423383
# Epoch 200 | Train Loss 0.213000 | Val Loss 0.444190
# Epoch 300 | Train Loss 0.210990 | Val Loss 0.445760
# Epoch 400 | Train Loss 0.212651 | Val Loss 0.451759
# Early stopping at epoch 447
# X | train1 -> R² = -1.5348, MSE = 2.7332e-01
# X | train2 -> R² = -21.3233, MSE = 1.8810e+00
# X | test1 -> R² = -1.7121, MSE = 2.8412e-01
# X | test2 -> R² = -21.7573, MSE = 1.8728e+00
# X | test3 -> R² = 0.1747, MSE = 7.5933e-02
# X | val -> R² = -0.6169, MSE = 1.5461e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.513759 | Val Loss 0.666411
# Epoch 100 | Train Loss 0.225934 | Val Loss 0.432248
# Epoch 200 | Train Loss 0.214541 | Val Loss 0.425633
# Epoch 300 | Train Loss 0.211025 | Val Loss 0.434572
# Epoch 400 | Train Loss 0.209192 | Val Loss 0.430793
# Early stopping at epoch 454
# X | train1 -> R² = -1.4228, MSE = 2.6124e-01
# X | train2 -> R² = -17.4320, MSE = 1.5531e+00
# X | test1 -> R² = -1.6980, MSE = 2.8265e-01
# X | test2 -> R² = -17.6690, MSE = 1.5363e+00
# X | test3 -> R² = 0.2176, MSE = 7.1983e-02
# X | val -> R² = -0.0442, MSE = 9.9849e-02
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.484547 | Val Loss 0.589070
# Epoch 100 | Train Loss 0.221338 | Val Loss 0.433234
# Epoch 200 | Train Loss 0.212845 | Val Loss 0.437258
# Epoch 300 | Train Loss 0.211522 | Val Loss 0.436293
# Epoch 400 | Train Loss 0.215352 | Val Loss 0.438767
# Early stopping at epoch 422
# X | train1 -> R² = -1.1781, MSE = 2.3485e-01
# X | train2 -> R² = -14.5121, MSE = 1.3071e+00
# X | test1 -> R² = -1.4102, MSE = 2.5249e-01
# X | test2 -> R² = -14.7200, MSE = 1.2937e+00
# X | test3 -> R² = 0.0658, MSE = 8.5953e-02
# X | val -> R² = -0.7911, MSE = 1.7127e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.487766 | Val Loss 0.593152
# Epoch 100 | Train Loss 0.224175 | Val Loss 0.430743
# Epoch 200 | Train Loss 0.214103 | Val Loss 0.433279
# Epoch 300 | Train Loss 0.211461 | Val Loss 0.439031
# Epoch 400 | Train Loss 0.210048 | Val Loss 0.431522
# Early stopping at epoch 428
# X | train1 -> R² = -1.6027, MSE = 2.8064e-01
# X | train2 -> R² = -20.9668, MSE = 1.8509e+00
# X | test1 -> R² = -1.8336, MSE = 2.9685e-01
# X | test2 -> R² = -21.3214, MSE = 1.8369e+00
# X | test3 -> R² = 0.3478, MSE = 6.0001e-02
# X | val -> R² = -0.3794, MSE = 1.3190e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.455466 | Val Loss 0.596588
# Epoch 100 | Train Loss 0.226164 | Val Loss 0.433290
# Epoch 200 | Train Loss 0.216007 | Val Loss 0.436036
# Epoch 300 | Train Loss 0.210481 | Val Loss 0.444715
# Epoch 400 | Train Loss 0.208667 | Val Loss 0.446519
# Early stopping at epoch 427
# X | train1 -> R² = -1.2088, MSE = 2.3816e-01
# X | train2 -> R² = -14.8023, MSE = 1.3315e+00
# X | test1 -> R² = -1.4817, MSE = 2.5999e-01
# X | test2 -> R² = -15.1092, MSE = 1.3257e+00
# X | test3 -> R² = -0.1825, MSE = 1.0880e-01
# X | val -> R² = -0.7656, MSE = 1.6884e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.503546 | Val Loss 0.599272
# Epoch 100 | Train Loss 0.224045 | Val Loss 0.432973
# Epoch 200 | Train Loss 0.213937 | Val Loss 0.434788
# Epoch 300 | Train Loss 0.211905 | Val Loss 0.450020
# Epoch 400 | Train Loss 0.210418 | Val Loss 0.451196
# Early stopping at epoch 461
# X | train1 -> R² = -1.5207, MSE = 2.7180e-01
# X | train2 -> R² = -18.5855, MSE = 1.6503e+00
# X | test1 -> R² = -1.7752, MSE = 2.9073e-01
# X | test2 -> R² = -19.0074, MSE = 1.6465e+00
# X | test3 -> R² = 0.6135, MSE = 3.5558e-02
# X | val -> R² = 0.2021, MSE = 7.6300e-02
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.512218 | Val Loss 0.667986
# Epoch 100 | Train Loss 0.223765 | Val Loss 0.436699
# Epoch 200 | Train Loss 0.214151 | Val Loss 0.431341
# Epoch 300 | Train Loss 0.211908 | Val Loss 0.430730
# Epoch 400 | Train Loss 0.210128 | Val Loss 0.431116
# Epoch 500 | Train Loss 0.209260 | Val Loss 0.438102
# Epoch 600 | Train Loss 0.208283 | Val Loss 0.442477
# Early stopping at epoch 655
# X | train1 -> R² = -1.9652, MSE = 3.1972e-01
# X | train2 -> R² = -16.4654, MSE = 1.4716e+00
# X | test1 -> R² = -2.1519, MSE = 3.3019e-01
# X | test2 -> R² = -16.7097, MSE = 1.4574e+00
# X | test3 -> R² = 0.1800, MSE = 7.5443e-02
# X | val -> R² = -1.1835, MSE = 2.0880e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.481568 | Val Loss 0.647898
# Epoch 100 | Train Loss 0.221091 | Val Loss 0.431475
# Epoch 200 | Train Loss 0.212686 | Val Loss 0.440240
# Epoch 300 | Train Loss 0.212143 | Val Loss 0.437881
# Epoch 400 | Train Loss 0.209577 | Val Loss 0.446535
# Early stopping at epoch 406
# X | train1 -> R² = -1.5656, MSE = 2.7663e-01
# X | train2 -> R² = -20.8511, MSE = 1.8412e+00
# X | test1 -> R² = -1.7170, MSE = 2.8463e-01
# X | test2 -> R² = -21.2561, MSE = 1.8315e+00
# X | test3 -> R² = -0.5530, MSE = 1.4289e-01
# X | val -> R² = -1.5986, MSE = 2.4849e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.492537 | Val Loss 0.600380
# Epoch 100 | Train Loss 0.225367 | Val Loss 0.436482
# Epoch 200 | Train Loss 0.214342 | Val Loss 0.446934
# Epoch 300 | Train Loss 0.211845 | Val Loss 0.463618
# Epoch 400 | Train Loss 0.210269 | Val Loss 0.468146
# Early stopping at epoch 437
# X | train1 -> R² = -1.5292, MSE = 2.7272e-01
# X | train2 -> R² = -24.8109, MSE = 2.1748e+00
# X | test1 -> R² = -1.6550, MSE = 2.7814e-01
# X | test2 -> R² = -25.2976, MSE = 2.1641e+00
# X | test3 -> R² = 0.0508, MSE = 8.7334e-02
# X | val -> R² = -1.5859, MSE = 2.4727e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.484681 | Val Loss 0.621174
# Epoch 100 | Train Loss 0.227670 | Val Loss 0.437756
# Epoch 200 | Train Loss 0.216935 | Val Loss 0.424112
# Epoch 300 | Train Loss 0.211843 | Val Loss 0.436810
# Epoch 400 | Train Loss 0.209729 | Val Loss 0.429881
# Epoch 500 | Train Loss 0.208418 | Val Loss 0.429988
# Early stopping at epoch 502
# X | train1 -> R² = -2.3031, MSE = 3.5616e-01
# X | train2 -> R² = -29.0915, MSE = 2.5355e+00
# X | test1 -> R² = -2.6404, MSE = 3.8137e-01
# X | test2 -> R² = -29.7093, MSE = 2.5272e+00
# X | test3 -> R² = -0.8747, MSE = 1.7248e-01
# X | val -> R² = -2.2854, MSE = 3.1416e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.593271 | Val Loss 0.476845
# Epoch 100 | Train Loss 0.359244 | Val Loss 0.393833
# Epoch 200 | Train Loss 0.347895 | Val Loss 0.397977
# Epoch 300 | Train Loss 0.350642 | Val Loss 0.394221
# Epoch 400 | Train Loss 0.344236 | Val Loss 0.392701
# Epoch 500 | Train Loss 0.342966 | Val Loss 0.392565
# Epoch 600 | Train Loss 0.341596 | Val Loss 0.397789
# Early stopping at epoch 654
# X | train1 -> R² = 0.2999, MSE = 7.5490e-02
# X | train2 -> R² = -7.2182, MSE = 6.9247e-01
# X | test1 -> R² = 0.2472, MSE = 7.8868e-02
# X | test2 -> R² = -7.3204, MSE = 6.8471e-01
# X | test3 -> R² = 0.9760, MSE = 2.2079e-03
# X | val -> R² = 0.9074, MSE = 8.8509e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.624971 | Val Loss 0.543974
# Epoch 100 | Train Loss 0.353904 | Val Loss 0.397185
# Epoch 200 | Train Loss 0.350360 | Val Loss 0.403204
# Epoch 300 | Train Loss 0.346840 | Val Loss 0.392862
# Epoch 400 | Train Loss 0.344924 | Val Loss 0.393844
# Epoch 500 | Train Loss 0.343877 | Val Loss 0.395083
# Epoch 600 | Train Loss 0.342642 | Val Loss 0.396501
# Early stopping at epoch 636
# X | train1 -> R² = 0.3430, MSE = 7.0840e-02
# X | train2 -> R² = -5.8720, MSE = 5.7904e-01
# X | test1 -> R² = 0.2954, MSE = 7.3815e-02
# X | test2 -> R² = -5.9288, MSE = 5.7019e-01
# X | test3 -> R² = 0.9201, MSE = 7.3516e-03
# X | val -> R² = 0.7480, MSE = 2.4095e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.596967 | Val Loss 0.558266
# Epoch 100 | Train Loss 0.354808 | Val Loss 0.399814
# Epoch 200 | Train Loss 0.347089 | Val Loss 0.408374
# Epoch 300 | Train Loss 0.345373 | Val Loss 0.414359
# Early stopping at epoch 392
# X | train1 -> R² = 0.3965, MSE = 6.5075e-02
# X | train2 -> R² = -9.0478, MSE = 8.4663e-01
# X | test1 -> R² = 0.4182, MSE = 6.0945e-02
# X | test2 -> R² = -9.0638, MSE = 8.2818e-01
# X | test3 -> R² = 0.8821, MSE = 1.0847e-02
# X | val -> R² = 0.4502, MSE = 5.2570e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.644421 | Val Loss 0.562651
# Epoch 100 | Train Loss 0.353413 | Val Loss 0.396767
# Epoch 200 | Train Loss 0.350807 | Val Loss 0.396769
# Epoch 300 | Train Loss 0.346305 | Val Loss 0.406480
# Early stopping at epoch 374
# X | train1 -> R² = 0.6902, MSE = 3.3409e-02
# X | train2 -> R² = -1.8099, MSE = 2.3677e-01
# X | test1 -> R² = 0.7288, MSE = 2.8414e-02
# X | test2 -> R² = -1.6850, MSE = 2.2096e-01
# X | test3 -> R² = 0.8828, MSE = 1.0787e-02
# X | val -> R² = 0.7639, MSE = 2.2576e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.556538 | Val Loss 0.439601
# Epoch 100 | Train Loss 0.354210 | Val Loss 0.394866
# Epoch 200 | Train Loss 0.346508 | Val Loss 0.404971
# Epoch 300 | Train Loss 0.344836 | Val Loss 0.410186
# Early stopping at epoch 387
# X | train1 -> R² = 0.2761, MSE = 7.8053e-02
# X | train2 -> R² = -9.9475, MSE = 9.2244e-01
# X | test1 -> R² = 0.2940, MSE = 7.3966e-02
# X | test2 -> R² = -9.9744, MSE = 9.0312e-01
# X | test3 -> R² = 0.8110, MSE = 1.7389e-02
# X | val -> R² = 0.4751, MSE = 5.0191e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.555063 | Val Loss 0.456033
# Epoch 100 | Train Loss 0.354421 | Val Loss 0.397219
# Epoch 200 | Train Loss 0.347253 | Val Loss 0.393439
# Epoch 300 | Train Loss 0.345127 | Val Loss 0.402413
# Epoch 400 | Train Loss 0.343946 | Val Loss 0.402656
# Early stopping at epoch 424
# X | train1 -> R² = 0.3459, MSE = 7.0524e-02
# X | train2 -> R² = -5.6053, MSE = 5.5657e-01
# X | test1 -> R² = 0.3279, MSE = 7.0412e-02
# X | test2 -> R² = -5.5731, MSE = 5.4092e-01
# X | test3 -> R² = 0.9820, MSE = 1.6560e-03
# X | val -> R² = 0.7617, MSE = 2.2784e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.590232 | Val Loss 0.505285
# Epoch 100 | Train Loss 0.352940 | Val Loss 0.395781
# Epoch 200 | Train Loss 0.347348 | Val Loss 0.401787
# Epoch 300 | Train Loss 0.345863 | Val Loss 0.408275
# Early stopping at epoch 382
# X | train1 -> R² = 0.4361, MSE = 6.0800e-02
# X | train2 -> R² = -6.5370, MSE = 6.3507e-01
# X | test1 -> R² = 0.5019, MSE = 5.2186e-02
# X | test2 -> R² = -6.4711, MSE = 6.1482e-01
# X | test3 -> R² = 0.7741, MSE = 2.0786e-02
# X | val -> R² = 0.3876, MSE = 5.8563e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.611067 | Val Loss 0.575822
# Epoch 100 | Train Loss 0.351297 | Val Loss 0.392217
# Epoch 200 | Train Loss 0.346487 | Val Loss 0.396721
# Epoch 300 | Train Loss 0.345032 | Val Loss 0.396886
# Early stopping at epoch 380
# X | train1 -> R² = 0.4875, MSE = 5.5265e-02
# X | train2 -> R² = -5.3009, MSE = 5.3091e-01
# X | test1 -> R² = 0.5145, MSE = 5.0859e-02
# X | test2 -> R² = -5.2504, MSE = 5.1437e-01
# X | test3 -> R² = 0.7600, MSE = 2.2081e-02
# X | val -> R² = 0.3374, MSE = 6.3358e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.617962 | Val Loss 0.521890
# Epoch 100 | Train Loss 0.353399 | Val Loss 0.397210
# Epoch 200 | Train Loss 0.347313 | Val Loss 0.401849
# Epoch 300 | Train Loss 0.345984 | Val Loss 0.398973
# Epoch 400 | Train Loss 0.345028 | Val Loss 0.402049
# Early stopping at epoch 407
# X | train1 -> R² = 0.4622, MSE = 5.7987e-02
# X | train2 -> R² = -5.2741, MSE = 5.2866e-01
# X | test1 -> R² = 0.4699, MSE = 5.5533e-02
# X | test2 -> R² = -5.2216, MSE = 5.1200e-01
# X | test3 -> R² = 0.9782, MSE = 2.0012e-03
# X | val -> R² = 0.8427, MSE = 1.5038e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.596357 | Val Loss 0.470777
# Epoch 100 | Train Loss 0.355575 | Val Loss 0.396927
# Epoch 200 | Train Loss 0.347219 | Val Loss 0.396008
# Epoch 300 | Train Loss 0.345404 | Val Loss 0.399916
# Epoch 400 | Train Loss 0.344560 | Val Loss 0.399791
# Epoch 500 | Train Loss 0.343077 | Val Loss 0.405461
# Early stopping at epoch 517
# X | train1 -> R² = 0.2870, MSE = 7.6883e-02
# X | train2 -> R² = -7.5246, MSE = 7.1828e-01
# X | test1 -> R² = 0.2241, MSE = 8.1283e-02
# X | test2 -> R² = -7.5954, MSE = 7.0735e-01
# X | test3 -> R² = 0.7584, MSE = 2.2231e-02
# X | val -> R² = 0.1860, MSE = 7.7842e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.582532 | Val Loss 0.455898
# Epoch 100 | Train Loss 0.358845 | Val Loss 0.389507
# Epoch 200 | Train Loss 0.347491 | Val Loss 0.392886
# Epoch 300 | Train Loss 0.345464 | Val Loss 0.392632
# Early stopping at epoch 398
# X | train1 -> R² = 0.5202, MSE = 5.1729e-02
# X | train2 -> R² = -5.3836, MSE = 5.3789e-01
# X | test1 -> R² = 0.5355, MSE = 4.8658e-02
# X | test2 -> R² = -5.3334, MSE = 5.2119e-01
# X | test3 -> R² = 0.9716, MSE = 2.6103e-03
# X | val -> R² = 0.7548, MSE = 2.3451e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.597441 | Val Loss 0.522094
# Epoch 100 | Train Loss 0.354465 | Val Loss 0.395230
# Epoch 200 | Train Loss 0.347646 | Val Loss 0.406931
# Epoch 300 | Train Loss 0.346079 | Val Loss 0.409961
# Early stopping at epoch 394
# X | train1 -> R² = 0.3062, MSE = 7.4812e-02
# X | train2 -> R² = -8.4586, MSE = 7.9699e-01
# X | test1 -> R² = 0.3451, MSE = 6.8606e-02
# X | test2 -> R² = -8.4219, MSE = 7.7536e-01
# X | test3 -> R² = 0.9821, MSE = 1.6430e-03
# X | val -> R² = 0.7488, MSE = 2.4018e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.595107 | Val Loss 0.558556
# Epoch 100 | Train Loss 0.353770 | Val Loss 0.395679
# Epoch 200 | Train Loss 0.347134 | Val Loss 0.399596
# Epoch 300 | Train Loss 0.345290 | Val Loss 0.405065
# Epoch 400 | Train Loss 0.343841 | Val Loss 0.401626
# Early stopping at epoch 405
# X | train1 -> R² = 0.4235, MSE = 6.2157e-02
# X | train2 -> R² = -7.0042, MSE = 6.7443e-01
# X | test1 -> R² = 0.4300, MSE = 5.9709e-02
# X | test2 -> R² = -7.0068, MSE = 6.5890e-01
# X | test3 -> R² = 0.9810, MSE = 1.7495e-03
# X | val -> R² = 0.8508, MSE = 1.4268e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.615106 | Val Loss 0.517026
# Epoch 100 | Train Loss 0.355886 | Val Loss 0.392825
# Epoch 200 | Train Loss 0.353064 | Val Loss 0.392956
# Epoch 300 | Train Loss 0.345143 | Val Loss 0.401310
# Epoch 400 | Train Loss 0.344062 | Val Loss 0.403734
# Early stopping at epoch 423
# X | train1 -> R² = 0.3382, MSE = 7.1356e-02
# X | train2 -> R² = -6.0394, MSE = 5.9314e-01
# X | test1 -> R² = 0.3270, MSE = 7.0500e-02
# X | test2 -> R² = -6.0848, MSE = 5.8303e-01
# X | test3 -> R² = 0.9785, MSE = 1.9821e-03
# X | val -> R² = 0.8759, MSE = 1.1868e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.563266 | Val Loss 0.445819
# Epoch 100 | Train Loss 0.353231 | Val Loss 0.390022
# Epoch 200 | Train Loss 0.346710 | Val Loss 0.393581
# Epoch 300 | Train Loss 0.345217 | Val Loss 0.390225
# Epoch 400 | Train Loss 0.351881 | Val Loss 0.391579
# Early stopping at epoch 487
# X | train1 -> R² = 0.3183, MSE = 7.3504e-02
# X | train2 -> R² = -5.7847, MSE = 5.7168e-01
# X | test1 -> R² = 0.2895, MSE = 7.4428e-02
# X | test2 -> R² = -5.7820, MSE = 5.5811e-01
# X | test3 -> R² = 0.5606, MSE = 4.0427e-02
# X | val -> R² = -0.0766, MSE = 1.0295e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
