# %% [markdown]
# - Entradas: WdRef, WeRef
# - Saidas: Theta
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.024565 | Val Loss 0.829564
# Epoch 100 | Train Loss 0.810193 | Val Loss 0.729504
# Epoch 200 | Train Loss 0.788823 | Val Loss 0.722753
# Epoch 300 | Train Loss 0.784321 | Val Loss 0.719284
# Epoch 400 | Train Loss 0.782444 | Val Loss 0.719366
# Epoch 500 | Train Loss 0.778106 | Val Loss 0.722638
# Early stopping at epoch 584
# Theta | train1 -> R² = 0.8638, MSE = 3.1086e-02
# Theta | train2 -> R² = 0.4388, MSE = 1.2813e-01
# Theta | test1 -> R² = 0.7020, MSE = 6.8465e-02
# Theta | test2 -> R² = 0.4713, MSE = 1.2540e-01
# Theta | test3 -> R² = 0.3470, MSE = 2.1469e-01
# Theta | val -> R² = 0.6483, MSE = 1.1511e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.044181 | Val Loss 0.841543
# Epoch 100 | Train Loss 0.814519 | Val Loss 0.730035
# Epoch 200 | Train Loss 0.798382 | Val Loss 0.726423
# Epoch 300 | Train Loss 0.784617 | Val Loss 0.720818
# Epoch 400 | Train Loss 0.782267 | Val Loss 0.720193
# Epoch 500 | Train Loss 0.779382 | Val Loss 0.721538
# Epoch 600 | Train Loss 0.772941 | Val Loss 0.732160
# Early stopping at epoch 613
# Theta | train1 -> R² = 0.8574, MSE = 3.2546e-02
# Theta | train2 -> R² = 0.4465, MSE = 1.2636e-01
# Theta | test1 -> R² = 0.6712, MSE = 7.5521e-02
# Theta | test2 -> R² = 0.4759, MSE = 1.2430e-01
# Theta | test3 -> R² = 0.4045, MSE = 1.9577e-01
# Theta | val -> R² = 0.6654, MSE = 1.0952e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.031944 | Val Loss 0.835428
# Epoch 100 | Train Loss 0.814113 | Val Loss 0.731279
# Epoch 200 | Train Loss 0.798431 | Val Loss 0.726030
# Epoch 300 | Train Loss 0.784313 | Val Loss 0.720216
# Epoch 400 | Train Loss 0.781683 | Val Loss 0.721735
# Epoch 500 | Train Loss 0.777803 | Val Loss 0.725621
# Epoch 600 | Train Loss 0.770084 | Val Loss 0.733186
# Early stopping at epoch 609
# Theta | train1 -> R² = 0.8636, MSE = 3.1139e-02
# Theta | train2 -> R² = 0.4504, MSE = 1.2548e-01
# Theta | test1 -> R² = 0.6759, MSE = 7.4446e-02
# Theta | test2 -> R² = 0.4865, MSE = 1.2179e-01
# Theta | test3 -> R² = 0.5042, MSE = 1.6301e-01
# Theta | val -> R² = 0.7175, MSE = 9.2462e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.033655 | Val Loss 0.836885
# Epoch 100 | Train Loss 0.812353 | Val Loss 0.730591
# Epoch 200 | Train Loss 0.795386 | Val Loss 0.725198
# Epoch 300 | Train Loss 0.783831 | Val Loss 0.720548
# Epoch 400 | Train Loss 0.781823 | Val Loss 0.719907
# Epoch 500 | Train Loss 0.778868 | Val Loss 0.720911
# Epoch 600 | Train Loss 0.769350 | Val Loss 0.729735
# Epoch 700 | Train Loss 0.760199 | Val Loss 0.741483
# Early stopping at epoch 703
# Theta | train1 -> R² = 0.8484, MSE = 3.4607e-02
# Theta | train2 -> R² = 0.4665, MSE = 1.2180e-01
# Theta | test1 -> R² = 0.6699, MSE = 7.5837e-02
# Theta | test2 -> R² = 0.4912, MSE = 1.2068e-01
# Theta | test3 -> R² = 0.2870, MSE = 2.3439e-01
# Theta | val -> R² = 0.6192, MSE = 1.2463e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.037827 | Val Loss 0.838207
# Epoch 100 | Train Loss 0.814145 | Val Loss 0.730362
# Epoch 200 | Train Loss 0.799539 | Val Loss 0.725025
# Epoch 300 | Train Loss 0.784729 | Val Loss 0.719204
# Epoch 400 | Train Loss 0.782164 | Val Loss 0.718902
# Epoch 500 | Train Loss 0.780549 | Val Loss 0.720545
# Early stopping at epoch 600
# Theta | train1 -> R² = 0.8598, MSE = 3.2004e-02
# Theta | train2 -> R² = 0.4472, MSE = 1.2621e-01
# Theta | test1 -> R² = 0.6769, MSE = 7.4230e-02
# Theta | test2 -> R² = 0.4727, MSE = 1.2505e-01
# Theta | test3 -> R² = 0.3624, MSE = 2.0960e-01
# Theta | val -> R² = 0.6562, MSE = 1.1253e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.019488 | Val Loss 0.826506
# Epoch 100 | Train Loss 0.813945 | Val Loss 0.731454
# Epoch 200 | Train Loss 0.793855 | Val Loss 0.725479
# Epoch 300 | Train Loss 0.783743 | Val Loss 0.720976
# Epoch 400 | Train Loss 0.780479 | Val Loss 0.725062
# Epoch 500 | Train Loss 0.774655 | Val Loss 0.729923
# Early stopping at epoch 555
# Theta | train1 -> R² = 0.8652, MSE = 3.0765e-02
# Theta | train2 -> R² = 0.4624, MSE = 1.2273e-01
# Theta | test1 -> R² = 0.6775, MSE = 7.4092e-02
# Theta | test2 -> R² = 0.4933, MSE = 1.2018e-01
# Theta | test3 -> R² = 0.4587, MSE = 1.7795e-01
# Theta | val -> R² = 0.6846, MSE = 1.0322e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.026973 | Val Loss 0.832261
# Epoch 100 | Train Loss 0.815486 | Val Loss 0.731803
# Epoch 200 | Train Loss 0.800911 | Val Loss 0.726011
# Epoch 300 | Train Loss 0.784872 | Val Loss 0.720378
# Epoch 400 | Train Loss 0.781778 | Val Loss 0.720742
# Epoch 500 | Train Loss 0.778186 | Val Loss 0.722908
# Early stopping at epoch 579
# Theta | train1 -> R² = 0.8566, MSE = 3.2739e-02
# Theta | train2 -> R² = 0.4647, MSE = 1.2221e-01
# Theta | test1 -> R² = 0.6587, MSE = 7.8400e-02
# Theta | test2 -> R² = 0.4822, MSE = 1.2281e-01
# Theta | test3 -> R² = 0.2870, MSE = 2.3438e-01
# Theta | val -> R² = 0.6160, MSE = 1.2568e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.035479 | Val Loss 0.838060
# Epoch 100 | Train Loss 0.814443 | Val Loss 0.730272
# Epoch 200 | Train Loss 0.797458 | Val Loss 0.725408
# Epoch 300 | Train Loss 0.783913 | Val Loss 0.720153
# Epoch 400 | Train Loss 0.782088 | Val Loss 0.719778
# Epoch 500 | Train Loss 0.779332 | Val Loss 0.721624
# Epoch 600 | Train Loss 0.772074 | Val Loss 0.727283
# Epoch 700 | Train Loss 0.762144 | Val Loss 0.737867
# Early stopping at epoch 717
# Theta | train1 -> R² = 0.8575, MSE = 3.2537e-02
# Theta | train2 -> R² = 0.4510, MSE = 1.2534e-01
# Theta | test1 -> R² = 0.6797, MSE = 7.3587e-02
# Theta | test2 -> R² = 0.4818, MSE = 1.2290e-01
# Theta | test3 -> R² = 0.4445, MSE = 1.8263e-01
# Theta | val -> R² = 0.6840, MSE = 1.0343e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.051148 | Val Loss 0.845827
# Epoch 100 | Train Loss 0.816658 | Val Loss 0.729588
# Epoch 200 | Train Loss 0.805548 | Val Loss 0.727203
# Epoch 300 | Train Loss 0.790004 | Val Loss 0.720353
# Epoch 400 | Train Loss 0.782812 | Val Loss 0.718508
# Epoch 500 | Train Loss 0.781350 | Val Loss 0.719290
# Epoch 600 | Train Loss 0.779080 | Val Loss 0.720006
# Early stopping at epoch 622
# Theta | train1 -> R² = 0.8456, MSE = 3.5242e-02
# Theta | train2 -> R² = 0.4872, MSE = 1.1707e-01
# Theta | test1 -> R² = 0.6287, MSE = 8.5285e-02
# Theta | test2 -> R² = 0.4981, MSE = 1.1903e-01
# Theta | test3 -> R² = 0.1765, MSE = 2.7074e-01
# Theta | val -> R² = 0.5819, MSE = 1.3684e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.040784 | Val Loss 0.840409
# Epoch 100 | Train Loss 0.814813 | Val Loss 0.729280
# Epoch 200 | Train Loss 0.796017 | Val Loss 0.725765
# Epoch 300 | Train Loss 0.784693 | Val Loss 0.721373
# Epoch 400 | Train Loss 0.781164 | Val Loss 0.720305
# Epoch 500 | Train Loss 0.774898 | Val Loss 0.727714
# Epoch 600 | Train Loss 0.766035 | Val Loss 0.738218
# Early stopping at epoch 639
# Theta | train1 -> R² = 0.8562, MSE = 3.2832e-02
# Theta | train2 -> R² = 0.4670, MSE = 1.2168e-01
# Theta | test1 -> R² = 0.6705, MSE = 7.5698e-02
# Theta | test2 -> R² = 0.5040, MSE = 1.1763e-01
# Theta | test3 -> R² = 0.4137, MSE = 1.9273e-01
# Theta | val -> R² = 0.6748, MSE = 1.0642e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.041051 | Val Loss 0.838730
# Epoch 100 | Train Loss 0.809925 | Val Loss 0.728662
# Epoch 200 | Train Loss 0.789701 | Val Loss 0.723843
# Epoch 300 | Train Loss 0.783718 | Val Loss 0.720268
# Epoch 400 | Train Loss 0.781262 | Val Loss 0.719557
# Epoch 500 | Train Loss 0.775797 | Val Loss 0.722141
# Epoch 600 | Train Loss 0.765657 | Val Loss 0.729690
# Early stopping at epoch 656
# Theta | train1 -> R² = 0.8522, MSE = 3.3731e-02
# Theta | train2 -> R² = 0.4683, MSE = 1.2138e-01
# Theta | test1 -> R² = 0.6560, MSE = 7.9031e-02
# Theta | test2 -> R² = 0.4923, MSE = 1.2040e-01
# Theta | test3 -> R² = 0.3166, MSE = 2.2468e-01
# Theta | val -> R² = 0.6197, MSE = 1.2447e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.042329 | Val Loss 0.840265
# Epoch 100 | Train Loss 0.812390 | Val Loss 0.729452
# Epoch 200 | Train Loss 0.794807 | Val Loss 0.725394
# Epoch 300 | Train Loss 0.783942 | Val Loss 0.720074
# Epoch 400 | Train Loss 0.782089 | Val Loss 0.719714
# Epoch 500 | Train Loss 0.779112 | Val Loss 0.721532
# Epoch 600 | Train Loss 0.771574 | Val Loss 0.729342
# Early stopping at epoch 613
# Theta | train1 -> R² = 0.8697, MSE = 2.9738e-02
# Theta | train2 -> R² = 0.3859, MSE = 1.4021e-01
# Theta | test1 -> R² = 0.7419, MSE = 5.9292e-02
# Theta | test2 -> R² = 0.4276, MSE = 1.3575e-01
# Theta | test3 -> R² = 0.4649, MSE = 1.7593e-01
# Theta | val -> R² = 0.6981, MSE = 9.8813e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.037868 | Val Loss 0.838199
# Epoch 100 | Train Loss 0.813750 | Val Loss 0.729862
# Epoch 200 | Train Loss 0.796138 | Val Loss 0.724101
# Epoch 300 | Train Loss 0.783140 | Val Loss 0.718829
# Epoch 400 | Train Loss 0.779599 | Val Loss 0.725342
# Epoch 500 | Train Loss 0.773007 | Val Loss 0.730804
# Early stopping at epoch 593
# Theta | train1 -> R² = 0.8648, MSE = 3.0872e-02
# Theta | train2 -> R² = 0.4667, MSE = 1.2176e-01
# Theta | test1 -> R² = 0.7005, MSE = 6.8808e-02
# Theta | test2 -> R² = 0.4933, MSE = 1.2016e-01
# Theta | test3 -> R² = 0.3258, MSE = 2.2164e-01
# Theta | val -> R² = 0.6544, MSE = 1.1311e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.039776 | Val Loss 0.839581
# Epoch 100 | Train Loss 0.813193 | Val Loss 0.730963
# Epoch 200 | Train Loss 0.797451 | Val Loss 0.726518
# Epoch 300 | Train Loss 0.784354 | Val Loss 0.720584
# Epoch 400 | Train Loss 0.781399 | Val Loss 0.720751
# Epoch 500 | Train Loss 0.774586 | Val Loss 0.725809
# Early stopping at epoch 598
# Theta | train1 -> R² = 0.8517, MSE = 3.3859e-02
# Theta | train2 -> R² = 0.4735, MSE = 1.2019e-01
# Theta | test1 -> R² = 0.6562, MSE = 7.8986e-02
# Theta | test2 -> R² = 0.4947, MSE = 1.1984e-01
# Theta | test3 -> R² = 0.2932, MSE = 2.3236e-01
# Theta | val -> R² = 0.6093, MSE = 1.2785e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.034606 | Val Loss 0.836824
# Epoch 100 | Train Loss 0.816748 | Val Loss 0.732288
# Epoch 200 | Train Loss 0.808732 | Val Loss 0.728438
# Epoch 300 | Train Loss 0.799418 | Val Loss 0.724593
# Epoch 400 | Train Loss 0.785677 | Val Loss 0.720414
# Epoch 500 | Train Loss 0.781181 | Val Loss 0.718130
# Epoch 600 | Train Loss 0.777054 | Val Loss 0.721085
# Epoch 700 | Train Loss 0.769558 | Val Loss 0.725877
# Early stopping at epoch 766
# Theta | train1 -> R² = 0.8454, MSE = 3.5292e-02
# Theta | train2 -> R² = 0.4598, MSE = 1.2334e-01
# Theta | test1 -> R² = 0.6575, MSE = 7.8668e-02
# Theta | test2 -> R² = 0.4834, MSE = 1.2252e-01
# Theta | test3 -> R² = 0.3074, MSE = 2.2770e-01
# Theta | val -> R² = 0.6280, MSE = 1.2176e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.066218 | Val Loss 0.835959
# Epoch 100 | Train Loss 0.865421 | Val Loss 0.725022
# Epoch 200 | Train Loss 0.794839 | Val Loss 0.717028
# Epoch 300 | Train Loss 0.785955 | Val Loss 0.720105
# Epoch 400 | Train Loss 0.776647 | Val Loss 0.726572
# Early stopping at epoch 473
# Theta | train1 -> R² = 0.8243, MSE = 4.0109e-02
# Theta | train2 -> R² = 0.4029, MSE = 1.3631e-01
# Theta | test1 -> R² = 0.6581, MSE = 7.8545e-02
# Theta | test2 -> R² = 0.4241, MSE = 1.3659e-01
# Theta | test3 -> R² = 0.2462, MSE = 2.4782e-01
# Theta | val -> R² = 0.5791, MSE = 1.3776e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.068918 | Val Loss 0.840111
# Epoch 100 | Train Loss 0.870207 | Val Loss 0.726417
# Epoch 200 | Train Loss 0.805443 | Val Loss 0.719111
# Epoch 300 | Train Loss 0.785742 | Val Loss 0.720371
# Epoch 400 | Train Loss 0.771938 | Val Loss 0.731755
# Epoch 500 | Train Loss 0.753417 | Val Loss 0.754374
# Early stopping at epoch 503
# Theta | train1 -> R² = 0.8292, MSE = 3.8998e-02
# Theta | train2 -> R² = 0.3823, MSE = 1.4102e-01
# Theta | test1 -> R² = 0.6786, MSE = 7.3821e-02
# Theta | test2 -> R² = 0.4022, MSE = 1.4178e-01
# Theta | test3 -> R² = 0.2660, MSE = 2.4129e-01
# Theta | val -> R² = 0.5722, MSE = 1.4001e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.063054 | Val Loss 0.838107
# Epoch 100 | Train Loss 0.868075 | Val Loss 0.726301
# Epoch 200 | Train Loss 0.799953 | Val Loss 0.718282
# Epoch 300 | Train Loss 0.783317 | Val Loss 0.721091
# Epoch 400 | Train Loss 0.776243 | Val Loss 0.726199
# Early stopping at epoch 493
# Theta | train1 -> R² = 0.8192, MSE = 4.1271e-02
# Theta | train2 -> R² = 0.3757, MSE = 1.4253e-01
# Theta | test1 -> R² = 0.6537, MSE = 7.9560e-02
# Theta | test2 -> R² = 0.3986, MSE = 1.4264e-01
# Theta | test3 -> R² = 0.2924, MSE = 2.3261e-01
# Theta | val -> R² = 0.5778, MSE = 1.3818e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.063541 | Val Loss 0.836900
# Epoch 100 | Train Loss 0.866364 | Val Loss 0.726199
# Epoch 200 | Train Loss 0.799200 | Val Loss 0.718304
# Epoch 300 | Train Loss 0.783294 | Val Loss 0.721735
# Epoch 400 | Train Loss 0.771608 | Val Loss 0.727643
# Early stopping at epoch 484
# Theta | train1 -> R² = 0.8298, MSE = 3.8862e-02
# Theta | train2 -> R² = 0.3161, MSE = 1.5614e-01
# Theta | test1 -> R² = 0.7089, MSE = 6.6868e-02
# Theta | test2 -> R² = 0.3507, MSE = 1.5398e-01
# Theta | test3 -> R² = 0.3692, MSE = 2.0737e-01
# Theta | val -> R² = 0.6187, MSE = 1.2479e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.066255 | Val Loss 0.838018
# Epoch 100 | Train Loss 0.876329 | Val Loss 0.726833
# Epoch 200 | Train Loss 0.812682 | Val Loss 0.719735
# Epoch 300 | Train Loss 0.786546 | Val Loss 0.720716
# Epoch 400 | Train Loss 0.778315 | Val Loss 0.727183
# Epoch 500 | Train Loss 0.762670 | Val Loss 0.742119
# Early stopping at epoch 512
# Theta | train1 -> R² = 0.8263, MSE = 3.9640e-02
# Theta | train2 -> R² = 0.3877, MSE = 1.3978e-01
# Theta | test1 -> R² = 0.6687, MSE = 7.6100e-02
# Theta | test2 -> R² = 0.4095, MSE = 1.4005e-01
# Theta | test3 -> R² = 0.2713, MSE = 2.3954e-01
# Theta | val -> R² = 0.5711, MSE = 1.4037e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.048553 | Val Loss 0.825020
# Epoch 100 | Train Loss 0.851524 | Val Loss 0.725427
# Epoch 200 | Train Loss 0.794787 | Val Loss 0.719241
# Epoch 300 | Train Loss 0.785852 | Val Loss 0.721157
# Epoch 400 | Train Loss 0.773846 | Val Loss 0.725588
# Early stopping at epoch 467
# Theta | train1 -> R² = 0.8218, MSE = 4.0670e-02
# Theta | train2 -> R² = 0.3939, MSE = 1.3838e-01
# Theta | test1 -> R² = 0.6400, MSE = 8.2700e-02
# Theta | test2 -> R² = 0.4121, MSE = 1.3943e-01
# Theta | test3 -> R² = 0.3105, MSE = 2.2668e-01
# Theta | val -> R² = 0.5738, MSE = 1.3950e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.077009 | Val Loss 0.844529
# Epoch 100 | Train Loss 0.864221 | Val Loss 0.725200
# Epoch 200 | Train Loss 0.799432 | Val Loss 0.717866
# Epoch 300 | Train Loss 0.784302 | Val Loss 0.721061
# Epoch 400 | Train Loss 0.770254 | Val Loss 0.731471
# Early stopping at epoch 493
# Theta | train1 -> R² = 0.8198, MSE = 4.1138e-02
# Theta | train2 -> R² = 0.3928, MSE = 1.3862e-01
# Theta | test1 -> R² = 0.6454, MSE = 8.1450e-02
# Theta | test2 -> R² = 0.4114, MSE = 1.3959e-01
# Theta | test3 -> R² = 0.2198, MSE = 2.5648e-01
# Theta | val -> R² = 0.5506, MSE = 1.4706e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.059093 | Val Loss 0.835145
# Epoch 100 | Train Loss 0.875100 | Val Loss 0.727386
# Epoch 200 | Train Loss 0.817645 | Val Loss 0.720578
# Epoch 300 | Train Loss 0.782343 | Val Loss 0.721501
# Epoch 400 | Train Loss 0.770811 | Val Loss 0.733160
# Epoch 500 | Train Loss 0.754919 | Val Loss 0.743643
# Early stopping at epoch 517
# Theta | train1 -> R² = 0.8214, MSE = 4.0774e-02
# Theta | train2 -> R² = 0.3570, MSE = 1.4679e-01
# Theta | test1 -> R² = 0.6557, MSE = 7.9101e-02
# Theta | test2 -> R² = 0.3793, MSE = 1.4719e-01
# Theta | test3 -> R² = 0.3271, MSE = 2.2122e-01
# Theta | val -> R² = 0.5832, MSE = 1.3640e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.059893 | Val Loss 0.835482
# Epoch 100 | Train Loss 0.868529 | Val Loss 0.726741
# Epoch 200 | Train Loss 0.797381 | Val Loss 0.718678
# Epoch 300 | Train Loss 0.783745 | Val Loss 0.722979
# Epoch 400 | Train Loss 0.770276 | Val Loss 0.736998
# Early stopping at epoch 487
# Theta | train1 -> R² = 0.8174, MSE = 4.1672e-02
# Theta | train2 -> R² = 0.3981, MSE = 1.3741e-01
# Theta | test1 -> R² = 0.6299, MSE = 8.5018e-02
# Theta | test2 -> R² = 0.4149, MSE = 1.3877e-01
# Theta | test3 -> R² = 0.2460, MSE = 2.4789e-01
# Theta | val -> R² = 0.5537, MSE = 1.4607e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.066107 | Val Loss 0.838437
# Epoch 100 | Train Loss 0.867660 | Val Loss 0.725847
# Epoch 200 | Train Loss 0.794592 | Val Loss 0.718624
# Epoch 300 | Train Loss 0.783466 | Val Loss 0.721398
# Epoch 400 | Train Loss 0.770789 | Val Loss 0.726171
# Early stopping at epoch 477
# Theta | train1 -> R² = 0.8182, MSE = 4.1507e-02
# Theta | train2 -> R² = 0.4100, MSE = 1.3470e-01
# Theta | test1 -> R² = 0.6309, MSE = 8.4797e-02
# Theta | test2 -> R² = 0.4275, MSE = 1.3577e-01
# Theta | test3 -> R² = 0.2734, MSE = 2.3888e-01
# Theta | val -> R² = 0.5626, MSE = 1.4317e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.066159 | Val Loss 0.834735
# Epoch 100 | Train Loss 0.872184 | Val Loss 0.726391
# Epoch 200 | Train Loss 0.798616 | Val Loss 0.717981
# Epoch 300 | Train Loss 0.784785 | Val Loss 0.718968
# Epoch 400 | Train Loss 0.776633 | Val Loss 0.725568
# Early stopping at epoch 497
# Theta | train1 -> R² = 0.8036, MSE = 4.4832e-02
# Theta | train2 -> R² = 0.4078, MSE = 1.3520e-01
# Theta | test1 -> R² = 0.6024, MSE = 9.1326e-02
# Theta | test2 -> R² = 0.4252, MSE = 1.3632e-01
# Theta | test3 -> R² = 0.2405, MSE = 2.4970e-01
# Theta | val -> R² = 0.5539, MSE = 1.4600e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.066609 | Val Loss 0.837328
# Epoch 100 | Train Loss 0.875620 | Val Loss 0.727321
# Epoch 200 | Train Loss 0.810252 | Val Loss 0.719049
# Epoch 300 | Train Loss 0.784619 | Val Loss 0.719513
# Epoch 400 | Train Loss 0.776279 | Val Loss 0.728111
# Epoch 500 | Train Loss 0.760625 | Val Loss 0.742802
# Early stopping at epoch 508
# Theta | train1 -> R² = 0.8098, MSE = 4.3408e-02
# Theta | train2 -> R² = 0.3857, MSE = 1.4024e-01
# Theta | test1 -> R² = 0.6087, MSE = 8.9896e-02
# Theta | test2 -> R² = 0.3990, MSE = 1.4253e-01
# Theta | test3 -> R² = 0.2645, MSE = 2.4178e-01
# Theta | val -> R² = 0.5559, MSE = 1.4535e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.062231 | Val Loss 0.838166
# Epoch 100 | Train Loss 0.863109 | Val Loss 0.725989
# Epoch 200 | Train Loss 0.795539 | Val Loss 0.718940
# Epoch 300 | Train Loss 0.783791 | Val Loss 0.722274
# Epoch 400 | Train Loss 0.771008 | Val Loss 0.734214
# Early stopping at epoch 483
# Theta | train1 -> R² = 0.8179, MSE = 4.1562e-02
# Theta | train2 -> R² = 0.3621, MSE = 1.4563e-01
# Theta | test1 -> R² = 0.6282, MSE = 8.5412e-02
# Theta | test2 -> R² = 0.3828, MSE = 1.4639e-01
# Theta | test3 -> R² = 0.3494, MSE = 2.1389e-01
# Theta | val -> R² = 0.5895, MSE = 1.3435e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.062386 | Val Loss 0.837189
# Epoch 100 | Train Loss 0.870130 | Val Loss 0.726490
# Epoch 200 | Train Loss 0.810914 | Val Loss 0.718080
# Epoch 300 | Train Loss 0.783366 | Val Loss 0.720690
# Epoch 400 | Train Loss 0.778993 | Val Loss 0.729669
# Epoch 500 | Train Loss 0.771761 | Val Loss 0.741478
# Early stopping at epoch 505
# Theta | train1 -> R² = 0.8209, MSE = 4.0892e-02
# Theta | train2 -> R² = 0.2950, MSE = 1.6096e-01
# Theta | test1 -> R² = 0.7080, MSE = 6.7069e-02
# Theta | test2 -> R² = 0.3241, MSE = 1.6030e-01
# Theta | test3 -> R² = 0.3418, MSE = 2.1638e-01
# Theta | val -> R² = 0.6099, MSE = 1.2766e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.065921 | Val Loss 0.838143
# Epoch 100 | Train Loss 0.873889 | Val Loss 0.726539
# Epoch 200 | Train Loss 0.803596 | Val Loss 0.718144
# Epoch 300 | Train Loss 0.784976 | Val Loss 0.721144
# Epoch 400 | Train Loss 0.777401 | Val Loss 0.729925
# Early stopping at epoch 487
# Theta | train1 -> R² = 0.8329, MSE = 3.8152e-02
# Theta | train2 -> R² = 0.3200, MSE = 1.5526e-01
# Theta | test1 -> R² = 0.7027, MSE = 6.8306e-02
# Theta | test2 -> R² = 0.3594, MSE = 1.5193e-01
# Theta | test3 -> R² = 0.4088, MSE = 1.9436e-01
# Theta | val -> R² = 0.6412, MSE = 1.1743e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.012712 | Val Loss 0.839569
# Epoch 100 | Train Loss 0.742421 | Val Loss 0.734093
# Epoch 200 | Train Loss 0.738973 | Val Loss 0.733675
# Epoch 300 | Train Loss 0.737688 | Val Loss 0.730740
# Early stopping at epoch 358
# Theta | train1 -> R² = 0.8024, MSE = 4.5108e-02
# Theta | train2 -> R² = 0.2286, MSE = 1.7611e-01
# Theta | test1 -> R² = 0.6578, MSE = 7.8599e-02
# Theta | test2 -> R² = 0.2624, MSE = 1.7492e-01
# Theta | test3 -> R² = 0.3147, MSE = 2.2530e-01
# Theta | val -> R² = 0.5480, MSE = 1.4793e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.033715 | Val Loss 0.852810
# Epoch 100 | Train Loss 0.742870 | Val Loss 0.734767
# Epoch 200 | Train Loss 0.740063 | Val Loss 0.735022
# Epoch 300 | Train Loss 0.738533 | Val Loss 0.731428
# Early stopping at epoch 363
# Theta | train1 -> R² = 0.7958, MSE = 4.6620e-02
# Theta | train2 -> R² = 0.3240, MSE = 1.5433e-01
# Theta | test1 -> R² = 0.6120, MSE = 8.9130e-02
# Theta | test2 -> R² = 0.3399, MSE = 1.5655e-01
# Theta | test3 -> R² = 0.2083, MSE = 2.6029e-01
# Theta | val -> R² = 0.4955, MSE = 1.6512e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.001205 | Val Loss 0.834583
# Epoch 100 | Train Loss 0.742669 | Val Loss 0.737469
# Epoch 200 | Train Loss 0.739526 | Val Loss 0.734028
# Epoch 300 | Train Loss 0.738155 | Val Loss 0.729841
# Early stopping at epoch 349
# Theta | train1 -> R² = 0.7911, MSE = 4.7680e-02
# Theta | train2 -> R² = 0.0716, MSE = 2.1195e-01
# Theta | test1 -> R² = 0.6970, MSE = 6.9600e-02
# Theta | test2 -> R² = 0.1140, MSE = 2.1013e-01
# Theta | test3 -> R² = 0.3553, MSE = 2.1194e-01
# Theta | val -> R² = 0.5535, MSE = 1.4614e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.007337 | Val Loss 0.837841
# Epoch 100 | Train Loss 0.742334 | Val Loss 0.737584
# Epoch 200 | Train Loss 0.739999 | Val Loss 0.734240
# Epoch 300 | Train Loss 0.738093 | Val Loss 0.729521
# Early stopping at epoch 349
# Theta | train1 -> R² = 0.7858, MSE = 4.8897e-02
# Theta | train2 -> R² = 0.1116, MSE = 2.0283e-01
# Theta | test1 -> R² = 0.6819, MSE = 7.3068e-02
# Theta | test2 -> R² = 0.1499, MSE = 2.0162e-01
# Theta | test3 -> R² = 0.3450, MSE = 2.1533e-01
# Theta | val -> R² = 0.5478, MSE = 1.4800e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.004551 | Val Loss 0.835978
# Epoch 100 | Train Loss 0.742693 | Val Loss 0.738910
# Epoch 200 | Train Loss 0.740608 | Val Loss 0.734677
# Epoch 300 | Train Loss 0.738962 | Val Loss 0.730426
# Early stopping at epoch 347
# Theta | train1 -> R² = 0.7852, MSE = 4.9031e-02
# Theta | train2 -> R² = 0.0982, MSE = 2.0589e-01
# Theta | test1 -> R² = 0.6864, MSE = 7.2031e-02
# Theta | test2 -> R² = 0.1371, MSE = 2.0465e-01
# Theta | test3 -> R² = 0.3458, MSE = 2.1507e-01
# Theta | val -> R² = 0.5484, MSE = 1.4779e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.992412 | Val Loss 0.828701
# Epoch 100 | Train Loss 0.743246 | Val Loss 0.737659
# Epoch 200 | Train Loss 0.739546 | Val Loss 0.732245
# Epoch 300 | Train Loss 0.738035 | Val Loss 0.730625
# Early stopping at epoch 347
# Theta | train1 -> R² = 0.8039, MSE = 4.4768e-02
# Theta | train2 -> R² = 0.1647, MSE = 1.9071e-01
# Theta | test1 -> R² = 0.6900, MSE = 7.1217e-02
# Theta | test2 -> R² = 0.2028, MSE = 1.8907e-01
# Theta | test3 -> R² = 0.3484, MSE = 2.1420e-01
# Theta | val -> R² = 0.5657, MSE = 1.4214e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.012455 | Val Loss 0.840474
# Epoch 100 | Train Loss 0.742104 | Val Loss 0.735568
# Epoch 200 | Train Loss 0.739309 | Val Loss 0.733439
# Epoch 300 | Train Loss 0.737918 | Val Loss 0.729757
# Early stopping at epoch 355
# Theta | train1 -> R² = 0.8071, MSE = 4.4022e-02
# Theta | train2 -> R² = 0.2788, MSE = 1.6464e-01
# Theta | test1 -> R² = 0.6403, MSE = 8.2637e-02
# Theta | test2 -> R² = 0.3053, MSE = 1.6476e-01
# Theta | test3 -> R² = 0.2692, MSE = 2.4024e-01
# Theta | val -> R² = 0.5273, MSE = 1.5471e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.004646 | Val Loss 0.835854
# Epoch 100 | Train Loss 0.742962 | Val Loss 0.737333
# Epoch 200 | Train Loss 0.740074 | Val Loss 0.734096
# Epoch 300 | Train Loss 0.738280 | Val Loss 0.730296
# Early stopping at epoch 350
# Theta | train1 -> R² = 0.7885, MSE = 4.8286e-02
# Theta | train2 -> R² = 0.1030, MSE = 2.0478e-01
# Theta | test1 -> R² = 0.6791, MSE = 7.3720e-02
# Theta | test2 -> R² = 0.1389, MSE = 2.0422e-01
# Theta | test3 -> R² = 0.3104, MSE = 2.2671e-01
# Theta | val -> R² = 0.5291, MSE = 1.5412e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.010694 | Val Loss 0.839421
# Epoch 100 | Train Loss 0.742234 | Val Loss 0.737210
# Epoch 200 | Train Loss 0.739407 | Val Loss 0.734348
# Epoch 300 | Train Loss 0.738287 | Val Loss 0.730544
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.7648, MSE = 5.3679e-02
# Theta | train2 -> R² = 0.1953, MSE = 1.8371e-01
# Theta | test1 -> R² = 0.6031, MSE = 9.1179e-02
# Theta | test2 -> R² = 0.2122, MSE = 1.8684e-01
# Theta | test3 -> R² = 0.1821, MSE = 2.6888e-01
# Theta | val -> R² = 0.4461, MSE = 1.8130e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.003567 | Val Loss 0.835342
# Epoch 100 | Train Loss 0.742490 | Val Loss 0.737879
# Epoch 200 | Train Loss 0.739293 | Val Loss 0.732705
# Epoch 300 | Train Loss 0.738276 | Val Loss 0.730160
# Early stopping at epoch 350
# Theta | train1 -> R² = 0.8064, MSE = 4.4184e-02
# Theta | train2 -> R² = 0.3210, MSE = 1.5503e-01
# Theta | test1 -> R² = 0.6219, MSE = 8.6850e-02
# Theta | test2 -> R² = 0.3395, MSE = 1.5664e-01
# Theta | test3 -> R² = 0.2035, MSE = 2.6184e-01
# Theta | val -> R² = 0.4957, MSE = 1.6505e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.999731 | Val Loss 0.833040
# Epoch 100 | Train Loss 0.742553 | Val Loss 0.737150
# Epoch 200 | Train Loss 0.739573 | Val Loss 0.732142
# Epoch 300 | Train Loss 0.738712 | Val Loss 0.729030
# Epoch 400 | Train Loss 0.738025 | Val Loss 0.727369
# Epoch 500 | Train Loss 0.737335 | Val Loss 0.726303
# Epoch 600 | Train Loss 0.736606 | Val Loss 0.726025
# Epoch 700 | Train Loss 0.735760 | Val Loss 0.727201
# Epoch 800 | Train Loss 0.734810 | Val Loss 0.727673
# Early stopping at epoch 801
# Theta | train1 -> R² = 0.9046, MSE = 2.1778e-02
# Theta | train2 -> R² = 0.5102, MSE = 1.1182e-01
# Theta | test1 -> R² = 0.7221, MSE = 6.3840e-02
# Theta | test2 -> R² = 0.5442, MSE = 1.0811e-01
# Theta | test3 -> R² = 0.2388, MSE = 2.5023e-01
# Theta | val -> R² = 0.6285, MSE = 1.2158e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.009654 | Val Loss 0.838637
# Epoch 100 | Train Loss 0.742556 | Val Loss 0.736085
# Epoch 200 | Train Loss 0.739361 | Val Loss 0.733787
# Epoch 300 | Train Loss 0.738195 | Val Loss 0.730745
# Early stopping at epoch 354
# Theta | train1 -> R² = 0.8041, MSE = 4.4728e-02
# Theta | train2 -> R² = 0.2588, MSE = 1.6922e-01
# Theta | test1 -> R² = 0.6562, MSE = 7.8966e-02
# Theta | test2 -> R² = 0.2853, MSE = 1.6950e-01
# Theta | test3 -> R² = 0.2748, MSE = 2.3841e-01
# Theta | val -> R² = 0.5291, MSE = 1.5411e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.007857 | Val Loss 0.837399
# Epoch 100 | Train Loss 0.742198 | Val Loss 0.736321
# Epoch 200 | Train Loss 0.739502 | Val Loss 0.733678
# Epoch 300 | Train Loss 0.738365 | Val Loss 0.730034
# Early stopping at epoch 353
# Theta | train1 -> R² = 0.7964, MSE = 4.6470e-02
# Theta | train2 -> R² = 0.3057, MSE = 1.5851e-01
# Theta | test1 -> R² = 0.6129, MSE = 8.8914e-02
# Theta | test2 -> R² = 0.3252, MSE = 1.6005e-01
# Theta | test3 -> R² = 0.2149, MSE = 2.5809e-01
# Theta | val -> R² = 0.4935, MSE = 1.6575e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.029975 | Val Loss 0.849907
# Epoch 100 | Train Loss 0.743062 | Val Loss 0.733309
# Epoch 200 | Train Loss 0.739625 | Val Loss 0.732735
# Epoch 300 | Train Loss 0.738496 | Val Loss 0.728728
# Epoch 400 | Train Loss 0.738068 | Val Loss 0.727729
# Epoch 500 | Train Loss 0.737698 | Val Loss 0.727207
# Epoch 600 | Train Loss 0.737337 | Val Loss 0.727132
# Epoch 700 | Train Loss 0.736922 | Val Loss 0.727547
# Early stopping at epoch 769
# Theta | train1 -> R² = 0.9017, MSE = 2.2437e-02
# Theta | train2 -> R² = 0.5285, MSE = 1.0764e-01
# Theta | test1 -> R² = 0.7140, MSE = 6.5705e-02
# Theta | test2 -> R² = 0.5556, MSE = 1.0539e-01
# Theta | test3 -> R² = 0.2599, MSE = 2.4329e-01
# Theta | val -> R² = 0.6443, MSE = 1.1641e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.013954 | Val Loss 0.840823
# Epoch 100 | Train Loss 0.742452 | Val Loss 0.735618
# Epoch 200 | Train Loss 0.739230 | Val Loss 0.733334
# Epoch 300 | Train Loss 0.738265 | Val Loss 0.729700
# Early stopping at epoch 356
# Theta | train1 -> R² = 0.8156, MSE = 4.2101e-02
# Theta | train2 -> R² = 0.2425, MSE = 1.7294e-01
# Theta | test1 -> R² = 0.6809, MSE = 7.3312e-02
# Theta | test2 -> R² = 0.2811, MSE = 1.7050e-01
# Theta | test3 -> R² = 0.3519, MSE = 2.1307e-01
# Theta | val -> R² = 0.5737, MSE = 1.3951e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.061903 | Val Loss 0.846629
# Epoch 100 | Train Loss 0.807660 | Val Loss 0.730862
# Epoch 200 | Train Loss 0.788592 | Val Loss 0.724654
# Epoch 300 | Train Loss 0.784458 | Val Loss 0.721265
# Epoch 400 | Train Loss 0.782050 | Val Loss 0.720632
# Epoch 500 | Train Loss 0.776083 | Val Loss 0.723447
# Epoch 600 | Train Loss 0.765069 | Val Loss 0.732600
# Early stopping at epoch 614
# Theta | train1 -> R² = 0.8562, MSE = 3.2814e-02
# Theta | train2 -> R² = 0.4752, MSE = 1.1981e-01
# Theta | test1 -> R² = 0.6815, MSE = 7.3164e-02
# Theta | test2 -> R² = 0.4991, MSE = 1.1880e-01
# Theta | test3 -> R² = 0.2559, MSE = 2.4463e-01
# Theta | val -> R² = 0.5844, MSE = 1.3603e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.051391 | Val Loss 0.840440
# Epoch 100 | Train Loss 0.811649 | Val Loss 0.730932
# Epoch 200 | Train Loss 0.789615 | Val Loss 0.724864
# Epoch 300 | Train Loss 0.784393 | Val Loss 0.721101
# Epoch 400 | Train Loss 0.780673 | Val Loss 0.721791
# Epoch 500 | Train Loss 0.769668 | Val Loss 0.731938
# Early stopping at epoch 569
# Theta | train1 -> R² = 0.8691, MSE = 2.9879e-02
# Theta | train2 -> R² = 0.3977, MSE = 1.3750e-01
# Theta | test1 -> R² = 0.7382, MSE = 6.0144e-02
# Theta | test2 -> R² = 0.4438, MSE = 1.3191e-01
# Theta | test3 -> R² = 0.4588, MSE = 1.7792e-01
# Theta | val -> R² = 0.6840, MSE = 1.0341e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.030943 | Val Loss 0.832351
# Epoch 100 | Train Loss 0.806591 | Val Loss 0.730707
# Epoch 200 | Train Loss 0.785344 | Val Loss 0.723191
# Epoch 300 | Train Loss 0.782773 | Val Loss 0.721827
# Epoch 400 | Train Loss 0.780035 | Val Loss 0.721969
# Epoch 500 | Train Loss 0.773434 | Val Loss 0.732719
# Early stopping at epoch 534
# Theta | train1 -> R² = 0.8593, MSE = 3.2121e-02
# Theta | train2 -> R² = 0.4122, MSE = 1.3420e-01
# Theta | test1 -> R² = 0.6859, MSE = 7.2153e-02
# Theta | test2 -> R² = 0.4497, MSE = 1.3050e-01
# Theta | test3 -> R² = 0.4471, MSE = 1.8177e-01
# Theta | val -> R² = 0.6675, MSE = 1.0883e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.047013 | Val Loss 0.839382
# Epoch 100 | Train Loss 0.811475 | Val Loss 0.730833
# Epoch 200 | Train Loss 0.790512 | Val Loss 0.725493
# Epoch 300 | Train Loss 0.783560 | Val Loss 0.721541
# Epoch 400 | Train Loss 0.782025 | Val Loss 0.720623
# Epoch 500 | Train Loss 0.776696 | Val Loss 0.724314
# Epoch 600 | Train Loss 0.763766 | Val Loss 0.730013
# Early stopping at epoch 666
# Theta | train1 -> R² = 0.8522, MSE = 3.3733e-02
# Theta | train2 -> R² = 0.4723, MSE = 1.2048e-01
# Theta | test1 -> R² = 0.6711, MSE = 7.5543e-02
# Theta | test2 -> R² = 0.4914, MSE = 1.2061e-01
# Theta | test3 -> R² = 0.2218, MSE = 2.5582e-01
# Theta | val -> R² = 0.5610, MSE = 1.4367e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.050294 | Val Loss 0.843103
# Epoch 100 | Train Loss 0.803373 | Val Loss 0.728788
# Epoch 200 | Train Loss 0.785007 | Val Loss 0.722604
# Epoch 300 | Train Loss 0.782859 | Val Loss 0.721386
# Epoch 400 | Train Loss 0.776998 | Val Loss 0.725152
# Epoch 500 | Train Loss 0.767031 | Val Loss 0.735807
# Early stopping at epoch 552
# Theta | train1 -> R² = 0.8579, MSE = 3.2441e-02
# Theta | train2 -> R² = 0.4810, MSE = 1.1849e-01
# Theta | test1 -> R² = 0.6789, MSE = 7.3765e-02
# Theta | test2 -> R² = 0.5074, MSE = 1.1683e-01
# Theta | test3 -> R² = 0.3377, MSE = 2.1774e-01
# Theta | val -> R² = 0.6263, MSE = 1.2231e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.078689 | Val Loss 0.855256
# Epoch 100 | Train Loss 0.811455 | Val Loss 0.732544
# Epoch 200 | Train Loss 0.789843 | Val Loss 0.725367
# Epoch 300 | Train Loss 0.783963 | Val Loss 0.721004
# Epoch 400 | Train Loss 0.780614 | Val Loss 0.722870
# Epoch 500 | Train Loss 0.772504 | Val Loss 0.733199
# Early stopping at epoch 565
# Theta | train1 -> R² = 0.8657, MSE = 3.0648e-02
# Theta | train2 -> R² = 0.4351, MSE = 1.2897e-01
# Theta | test1 -> R² = 0.7148, MSE = 6.5519e-02
# Theta | test2 -> R² = 0.4732, MSE = 1.2493e-01
# Theta | test3 -> R² = 0.4213, MSE = 1.9023e-01
# Theta | val -> R² = 0.6622, MSE = 1.1055e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.024413 | Val Loss 0.826222
# Epoch 100 | Train Loss 0.806608 | Val Loss 0.730547
# Epoch 200 | Train Loss 0.786198 | Val Loss 0.722808
# Epoch 300 | Train Loss 0.783627 | Val Loss 0.721060
# Epoch 400 | Train Loss 0.777629 | Val Loss 0.723232
# Epoch 500 | Train Loss 0.765625 | Val Loss 0.738583
# Epoch 600 | Train Loss 0.757802 | Val Loss 0.750678
# Early stopping at epoch 608
# Theta | train1 -> R² = 0.8538, MSE = 3.3369e-02
# Theta | train2 -> R² = 0.4821, MSE = 1.1824e-01
# Theta | test1 -> R² = 0.6619, MSE = 7.7675e-02
# Theta | test2 -> R² = 0.5091, MSE = 1.1643e-01
# Theta | test3 -> R² = 0.2545, MSE = 2.4508e-01
# Theta | val -> R² = 0.5951, MSE = 1.3252e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.050664 | Val Loss 0.842811
# Epoch 100 | Train Loss 0.803055 | Val Loss 0.728647
# Epoch 200 | Train Loss 0.785010 | Val Loss 0.722314
# Epoch 300 | Train Loss 0.782787 | Val Loss 0.719668
# Epoch 400 | Train Loss 0.776217 | Val Loss 0.721722
# Epoch 500 | Train Loss 0.764371 | Val Loss 0.739121
# Epoch 600 | Train Loss 0.755655 | Val Loss 0.757912
# Early stopping at epoch 626
# Theta | train1 -> R² = 0.8435, MSE = 3.5718e-02
# Theta | train2 -> R² = 0.5006, MSE = 1.1402e-01
# Theta | test1 -> R² = 0.6503, MSE = 8.0333e-02
# Theta | test2 -> R² = 0.5134, MSE = 1.1539e-01
# Theta | test3 -> R² = -0.0270, MSE = 3.3763e-01
# Theta | val -> R² = 0.4687, MSE = 1.7389e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.058423 | Val Loss 0.846262
# Epoch 100 | Train Loss 0.810782 | Val Loss 0.730653
# Epoch 200 | Train Loss 0.791657 | Val Loss 0.725418
# Epoch 300 | Train Loss 0.783609 | Val Loss 0.719978
# Epoch 400 | Train Loss 0.780493 | Val Loss 0.723226
# Epoch 500 | Train Loss 0.772300 | Val Loss 0.725097
# Early stopping at epoch 572
# Theta | train1 -> R² = 0.8526, MSE = 3.3637e-02
# Theta | train2 -> R² = 0.4883, MSE = 1.1682e-01
# Theta | test1 -> R² = 0.6689, MSE = 7.6067e-02
# Theta | test2 -> R² = 0.5019, MSE = 1.1814e-01
# Theta | test3 -> R² = 0.1337, MSE = 2.8478e-01
# Theta | val -> R² = 0.5212, MSE = 1.5671e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.044780 | Val Loss 0.839330
# Epoch 100 | Train Loss 0.808121 | Val Loss 0.730037
# Epoch 200 | Train Loss 0.785753 | Val Loss 0.723475
# Epoch 300 | Train Loss 0.783415 | Val Loss 0.722332
# Epoch 400 | Train Loss 0.781304 | Val Loss 0.723397
# Epoch 500 | Train Loss 0.774166 | Val Loss 0.728472
# Early stopping at epoch 543
# Theta | train1 -> R² = 0.8599, MSE = 3.1970e-02
# Theta | train2 -> R² = 0.4640, MSE = 1.2237e-01
# Theta | test1 -> R² = 0.6861, MSE = 7.2111e-02
# Theta | test2 -> R² = 0.4967, MSE = 1.1936e-01
# Theta | test3 -> R² = 0.3948, MSE = 1.9897e-01
# Theta | val -> R² = 0.6438, MSE = 1.1658e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.109337 | Val Loss 0.874716
# Epoch 100 | Train Loss 0.811789 | Val Loss 0.732905
# Epoch 200 | Train Loss 0.792292 | Val Loss 0.725219
# Epoch 300 | Train Loss 0.784314 | Val Loss 0.720199
# Epoch 400 | Train Loss 0.782265 | Val Loss 0.720544
# Epoch 500 | Train Loss 0.777725 | Val Loss 0.724612
# Early stopping at epoch 582
# Theta | train1 -> R² = 0.8572, MSE = 3.2589e-02
# Theta | train2 -> R² = 0.4808, MSE = 1.1854e-01
# Theta | test1 -> R² = 0.6833, MSE = 7.2748e-02
# Theta | test2 -> R² = 0.4941, MSE = 1.1998e-01
# Theta | test3 -> R² = 0.1627, MSE = 2.7527e-01
# Theta | val -> R² = 0.5417, MSE = 1.4999e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.058105 | Val Loss 0.844858
# Epoch 100 | Train Loss 0.807407 | Val Loss 0.730237
# Epoch 200 | Train Loss 0.786603 | Val Loss 0.723845
# Epoch 300 | Train Loss 0.783809 | Val Loss 0.721757
# Epoch 400 | Train Loss 0.778932 | Val Loss 0.723433
# Epoch 500 | Train Loss 0.767996 | Val Loss 0.731036
# Epoch 600 | Train Loss 0.757872 | Val Loss 0.743048
# Early stopping at epoch 607
# Theta | train1 -> R² = 0.8520, MSE = 3.3773e-02
# Theta | train2 -> R² = 0.4751, MSE = 1.1983e-01
# Theta | test1 -> R² = 0.6560, MSE = 7.9014e-02
# Theta | test2 -> R² = 0.4995, MSE = 1.1869e-01
# Theta | test3 -> R² = 0.3346, MSE = 2.1874e-01
# Theta | val -> R² = 0.6132, MSE = 1.2661e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.052570 | Val Loss 0.843878
# Epoch 100 | Train Loss 0.808770 | Val Loss 0.729919
# Epoch 200 | Train Loss 0.787061 | Val Loss 0.723922
# Epoch 300 | Train Loss 0.783532 | Val Loss 0.721190
# Epoch 400 | Train Loss 0.780804 | Val Loss 0.720886
# Epoch 500 | Train Loss 0.770231 | Val Loss 0.727942
# Epoch 600 | Train Loss 0.759530 | Val Loss 0.740618
# Early stopping at epoch 668
# Theta | train1 -> R² = 0.8530, MSE = 3.3554e-02
# Theta | train2 -> R² = 0.4699, MSE = 1.2102e-01
# Theta | test1 -> R² = 0.6628, MSE = 7.7466e-02
# Theta | test2 -> R² = 0.4970, MSE = 1.1929e-01
# Theta | test3 -> R² = 0.3093, MSE = 2.2706e-01
# Theta | val -> R² = 0.6207, MSE = 1.2413e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.080275 | Val Loss 0.858980
# Epoch 100 | Train Loss 0.810224 | Val Loss 0.731131
# Epoch 200 | Train Loss 0.790873 | Val Loss 0.725497
# Epoch 300 | Train Loss 0.784568 | Val Loss 0.720506
# Epoch 400 | Train Loss 0.782167 | Val Loss 0.720796
# Epoch 500 | Train Loss 0.775450 | Val Loss 0.722761
# Early stopping at epoch 600
# Theta | train1 -> R² = 0.8567, MSE = 3.2706e-02
# Theta | train2 -> R² = 0.4788, MSE = 1.1898e-01
# Theta | test1 -> R² = 0.6803, MSE = 7.3445e-02
# Theta | test2 -> R² = 0.4979, MSE = 1.1909e-01
# Theta | test3 -> R² = 0.2103, MSE = 2.5961e-01
# Theta | val -> R² = 0.5603, MSE = 1.4391e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.060888 | Val Loss 0.847854
# Epoch 100 | Train Loss 0.810227 | Val Loss 0.730283
# Epoch 200 | Train Loss 0.790033 | Val Loss 0.724754
# Epoch 300 | Train Loss 0.783431 | Val Loss 0.721433
# Epoch 400 | Train Loss 0.781651 | Val Loss 0.721443
# Epoch 500 | Train Loss 0.776116 | Val Loss 0.727069
# Early stopping at epoch 547
# Theta | train1 -> R² = 0.8585, MSE = 3.2289e-02
# Theta | train2 -> R² = 0.4278, MSE = 1.3063e-01
# Theta | test1 -> R² = 0.6876, MSE = 7.1765e-02
# Theta | test2 -> R² = 0.4583, MSE = 1.2846e-01
# Theta | test3 -> R² = 0.4077, MSE = 1.9472e-01
# Theta | val -> R² = 0.6472, MSE = 1.1547e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.067537 | Val Loss 0.831729
# Epoch 100 | Train Loss 0.842581 | Val Loss 0.725812
# Epoch 200 | Train Loss 0.790250 | Val Loss 0.720261
# Epoch 300 | Train Loss 0.779834 | Val Loss 0.723840
# Epoch 400 | Train Loss 0.759371 | Val Loss 0.738591
# Early stopping at epoch 465
# Theta | train1 -> R² = 0.8136, MSE = 4.2542e-02
# Theta | train2 -> R² = 0.3748, MSE = 1.4273e-01
# Theta | test1 -> R² = 0.6486, MSE = 8.0733e-02
# Theta | test2 -> R² = 0.3964, MSE = 1.4315e-01
# Theta | test3 -> R² = 0.2959, MSE = 2.3149e-01
# Theta | val -> R² = 0.5655, MSE = 1.4220e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.081179 | Val Loss 0.840732
# Epoch 100 | Train Loss 0.847796 | Val Loss 0.725361
# Epoch 200 | Train Loss 0.790196 | Val Loss 0.719995
# Epoch 300 | Train Loss 0.780187 | Val Loss 0.726777
# Epoch 400 | Train Loss 0.759440 | Val Loss 0.742721
# Early stopping at epoch 446
# Theta | train1 -> R² = 0.8229, MSE = 4.0423e-02
# Theta | train2 -> R² = 0.3850, MSE = 1.4040e-01
# Theta | test1 -> R² = 0.6444, MSE = 8.1688e-02
# Theta | test2 -> R² = 0.4001, MSE = 1.4228e-01
# Theta | test3 -> R² = 0.2686, MSE = 2.4044e-01
# Theta | val -> R² = 0.5517, MSE = 1.4671e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.082136 | Val Loss 0.843142
# Epoch 100 | Train Loss 0.861790 | Val Loss 0.726206
# Epoch 200 | Train Loss 0.790203 | Val Loss 0.719579
# Epoch 300 | Train Loss 0.777878 | Val Loss 0.728094
# Epoch 400 | Train Loss 0.757273 | Val Loss 0.745406
# Early stopping at epoch 464
# Theta | train1 -> R² = 0.8208, MSE = 4.0905e-02
# Theta | train2 -> R² = 0.3810, MSE = 1.4131e-01
# Theta | test1 -> R² = 0.6488, MSE = 8.0678e-02
# Theta | test2 -> R² = 0.3948, MSE = 1.4353e-01
# Theta | test3 -> R² = 0.2559, MSE = 2.4463e-01
# Theta | val -> R² = 0.5457, MSE = 1.4869e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.083255 | Val Loss 0.843585
# Epoch 100 | Train Loss 0.859962 | Val Loss 0.726194
# Epoch 200 | Train Loss 0.790412 | Val Loss 0.719858
# Epoch 300 | Train Loss 0.781451 | Val Loss 0.725602
# Epoch 400 | Train Loss 0.761661 | Val Loss 0.740166
# Early stopping at epoch 462
# Theta | train1 -> R² = 0.8287, MSE = 3.9095e-02
# Theta | train2 -> R² = 0.3354, MSE = 1.5173e-01
# Theta | test1 -> R² = 0.6850, MSE = 7.2359e-02
# Theta | test2 -> R² = 0.3642, MSE = 1.5078e-01
# Theta | test3 -> R² = 0.3706, MSE = 2.0691e-01
# Theta | val -> R² = 0.6046, MSE = 1.2942e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.064499 | Val Loss 0.834683
# Epoch 100 | Train Loss 0.841569 | Val Loss 0.725424
# Epoch 200 | Train Loss 0.789429 | Val Loss 0.721325
# Epoch 300 | Train Loss 0.773708 | Val Loss 0.733286
# Epoch 400 | Train Loss 0.750233 | Val Loss 0.748345
# Early stopping at epoch 441
# Theta | train1 -> R² = 0.8222, MSE = 4.0584e-02
# Theta | train2 -> R² = 0.3931, MSE = 1.3855e-01
# Theta | test1 -> R² = 0.6480, MSE = 8.0855e-02
# Theta | test2 -> R² = 0.4112, MSE = 1.3964e-01
# Theta | test3 -> R² = 0.2919, MSE = 2.3279e-01
# Theta | val -> R² = 0.5629, MSE = 1.4306e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.157365 | Val Loss 0.883817
# Epoch 100 | Train Loss 0.865558 | Val Loss 0.727760
# Epoch 200 | Train Loss 0.799553 | Val Loss 0.718409
# Epoch 300 | Train Loss 0.787926 | Val Loss 0.719474
# Epoch 400 | Train Loss 0.780103 | Val Loss 0.725663
# Epoch 500 | Train Loss 0.764786 | Val Loss 0.745970
# Early stopping at epoch 507
# Theta | train1 -> R² = 0.8207, MSE = 4.0937e-02
# Theta | train2 -> R² = 0.3435, MSE = 1.4989e-01
# Theta | test1 -> R² = 0.6831, MSE = 7.2787e-02
# Theta | test2 -> R² = 0.3587, MSE = 1.5208e-01
# Theta | test3 -> R² = 0.2596, MSE = 2.4342e-01
# Theta | val -> R² = 0.5495, MSE = 1.4745e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.084358 | Val Loss 0.842281
# Epoch 100 | Train Loss 0.853172 | Val Loss 0.725829
# Epoch 200 | Train Loss 0.792162 | Val Loss 0.720123
# Epoch 300 | Train Loss 0.781044 | Val Loss 0.725869
# Epoch 400 | Train Loss 0.761538 | Val Loss 0.740927
# Early stopping at epoch 459
# Theta | train1 -> R² = 0.8220, MSE = 4.0633e-02
# Theta | train2 -> R² = 0.3940, MSE = 1.3835e-01
# Theta | test1 -> R² = 0.6407, MSE = 8.2543e-02
# Theta | test2 -> R² = 0.4127, MSE = 1.3927e-01
# Theta | test3 -> R² = 0.3025, MSE = 2.2932e-01
# Theta | val -> R² = 0.5633, MSE = 1.4291e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.085381 | Val Loss 0.845590
# Epoch 100 | Train Loss 0.858204 | Val Loss 0.726091
# Epoch 200 | Train Loss 0.790173 | Val Loss 0.720448
# Epoch 300 | Train Loss 0.780589 | Val Loss 0.722211
# Epoch 400 | Train Loss 0.761889 | Val Loss 0.741204
# Early stopping at epoch 470
# Theta | train1 -> R² = 0.8211, MSE = 4.0835e-02
# Theta | train2 -> R² = 0.3165, MSE = 1.5604e-01
# Theta | test1 -> R² = 0.6897, MSE = 7.1285e-02
# Theta | test2 -> R² = 0.3439, MSE = 1.5560e-01
# Theta | test3 -> R² = 0.3535, MSE = 2.1253e-01
# Theta | val -> R² = 0.5947, MSE = 1.3264e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.086462 | Val Loss 0.845967
# Epoch 100 | Train Loss 0.837335 | Val Loss 0.724602
# Epoch 200 | Train Loss 0.792385 | Val Loss 0.720555
# Epoch 300 | Train Loss 0.783733 | Val Loss 0.723557
# Epoch 400 | Train Loss 0.763146 | Val Loss 0.735844
# Early stopping at epoch 448
# Theta | train1 -> R² = 0.8286, MSE = 3.9124e-02
# Theta | train2 -> R² = 0.3942, MSE = 1.3831e-01
# Theta | test1 -> R² = 0.6619, MSE = 7.7661e-02
# Theta | test2 -> R² = 0.4127, MSE = 1.3929e-01
# Theta | test3 -> R² = 0.2689, MSE = 2.4036e-01
# Theta | val -> R² = 0.5541, MSE = 1.4592e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.072992 | Val Loss 0.838838
# Epoch 100 | Train Loss 0.856949 | Val Loss 0.726168
# Epoch 200 | Train Loss 0.791190 | Val Loss 0.719573
# Epoch 300 | Train Loss 0.779382 | Val Loss 0.722802
# Epoch 400 | Train Loss 0.760315 | Val Loss 0.737293
# Early stopping at epoch 459
# Theta | train1 -> R² = 0.8217, MSE = 4.0696e-02
# Theta | train2 -> R² = 0.1926, MSE = 1.8434e-01
# Theta | test1 -> R² = 0.7629, MSE = 5.4470e-02
# Theta | test2 -> R² = 0.2499, MSE = 1.7791e-01
# Theta | test3 -> R² = 0.5314, MSE = 1.5406e-01
# Theta | val -> R² = 0.6852, MSE = 1.0302e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.090319 | Val Loss 0.845482
# Epoch 100 | Train Loss 0.835265 | Val Loss 0.725150
# Epoch 200 | Train Loss 0.794464 | Val Loss 0.719959
# Epoch 300 | Train Loss 0.785203 | Val Loss 0.718561
# Epoch 400 | Train Loss 0.764515 | Val Loss 0.732802
# Epoch 500 | Train Loss 0.746851 | Val Loss 0.759912
# Early stopping at epoch 570
# Theta | train1 -> R² = 0.8065, MSE = 4.4162e-02
# Theta | train2 -> R² = 0.3614, MSE = 1.4578e-01
# Theta | test1 -> R² = 0.6749, MSE = 7.4689e-02
# Theta | test2 -> R² = 0.3803, MSE = 1.4698e-01
# Theta | test3 -> R² = 0.1485, MSE = 2.7994e-01
# Theta | val -> R² = 0.5003, MSE = 1.6356e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.089717 | Val Loss 0.845182
# Epoch 100 | Train Loss 0.853873 | Val Loss 0.725847
# Epoch 200 | Train Loss 0.790423 | Val Loss 0.719997
# Epoch 300 | Train Loss 0.781735 | Val Loss 0.723939
# Epoch 400 | Train Loss 0.762061 | Val Loss 0.737971
# Early stopping at epoch 455
# Theta | train1 -> R² = 0.8286, MSE = 3.9132e-02
# Theta | train2 -> R² = 0.3366, MSE = 1.5145e-01
# Theta | test1 -> R² = 0.6849, MSE = 7.2378e-02
# Theta | test2 -> R² = 0.3670, MSE = 1.5013e-01
# Theta | test3 -> R² = 0.3724, MSE = 2.0631e-01
# Theta | val -> R² = 0.6039, MSE = 1.2964e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.081337 | Val Loss 0.843884
# Epoch 100 | Train Loss 0.840862 | Val Loss 0.724256
# Epoch 200 | Train Loss 0.790357 | Val Loss 0.720986
# Epoch 300 | Train Loss 0.782039 | Val Loss 0.725700
# Epoch 400 | Train Loss 0.762333 | Val Loss 0.741815
# Early stopping at epoch 436
# Theta | train1 -> R² = 0.8308, MSE = 3.8613e-02
# Theta | train2 -> R² = 0.3685, MSE = 1.4417e-01
# Theta | test1 -> R² = 0.6695, MSE = 7.5917e-02
# Theta | test2 -> R² = 0.3948, MSE = 1.4352e-01
# Theta | test3 -> R² = 0.3360, MSE = 2.1828e-01
# Theta | val -> R² = 0.5851, MSE = 1.3578e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# ...
# Theta | test3 -> R² = 0.2601, MSE = 2.4323e-01
# Theta | val -> R² = 0.5555, MSE = 1.4546e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.012620 | Val Loss 0.837203
# Epoch 100 | Train Loss 0.738212 | Val Loss 0.732933
# Epoch 200 | Train Loss 0.736953 | Val Loss 0.732378
# Epoch 300 | Train Loss 0.734850 | Val Loss 0.730186
# Early stopping at epoch 331
# Theta | train1 -> R² = 0.8145, MSE = 4.2352e-02
# Theta | train2 -> R² = 0.3196, MSE = 1.5535e-01
# Theta | test1 -> R² = 0.6559, MSE = 7.9044e-02
# Theta | test2 -> R² = 0.3574, MSE = 1.5239e-01
# Theta | test3 -> R² = 0.3761, MSE = 2.0509e-01
# Theta | val -> R² = 0.6242, MSE = 1.2298e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.005819 | Val Loss 0.833459
# Epoch 100 | Train Loss 0.738811 | Val Loss 0.734218
# Epoch 200 | Train Loss 0.737614 | Val Loss 0.732877
# Epoch 300 | Train Loss 0.735811 | Val Loss 0.730284
# Early stopping at epoch 328
# Theta | train1 -> R² = 0.8317, MSE = 3.8412e-02
# Theta | train2 -> R² = 0.3496, MSE = 1.4850e-01
# Theta | test1 -> R² = 0.5879, MSE = 9.4667e-02
# Theta | test2 -> R² = 0.3730, MSE = 1.4870e-01
# Theta | test3 -> R² = 0.2842, MSE = 2.3533e-01
# Theta | val -> R² = 0.5738, MSE = 1.3948e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.010523 | Val Loss 0.838214
# Epoch 100 | Train Loss 0.738903 | Val Loss 0.734958
# Epoch 200 | Train Loss 0.737635 | Val Loss 0.732430
# Epoch 300 | Train Loss 0.735646 | Val Loss 0.729594
# Early stopping at epoch 334
# Theta | train1 -> R² = 0.8237, MSE = 4.0248e-02
# Theta | train2 -> R² = 0.1530, MSE = 1.9338e-01
# Theta | test1 -> R² = 0.6868, MSE = 7.1945e-02
# Theta | test2 -> R² = 0.2180, MSE = 1.8547e-01
# Theta | test3 -> R² = 0.5181, MSE = 1.5841e-01
# Theta | val -> R² = 0.6999, MSE = 9.8227e-02
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.011509 | Val Loss 0.836261
# Epoch 100 | Train Loss 0.738590 | Val Loss 0.734272
# Epoch 200 | Train Loss 0.736533 | Val Loss 0.734306
# Epoch 300 | Train Loss 0.732699 | Val Loss 0.730095
# Early stopping at epoch 333
# Theta | train1 -> R² = 0.8108, MSE = 4.3198e-02
# Theta | train2 -> R² = 0.3866, MSE = 1.4004e-01
# Theta | test1 -> R² = 0.5607, MSE = 1.0092e-01
# Theta | test2 -> R² = 0.4085, MSE = 1.4027e-01
# Theta | test3 -> R² = 0.3086, MSE = 2.2731e-01
# Theta | val -> R² = 0.6007, MSE = 1.3068e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.012921 | Val Loss 0.839118
# Epoch 100 | Train Loss 0.739071 | Val Loss 0.734819
# Epoch 200 | Train Loss 0.737688 | Val Loss 0.732393
# Epoch 300 | Train Loss 0.736079 | Val Loss 0.731776
# Early stopping at epoch 332
# Theta | train1 -> R² = 0.8295, MSE = 3.8916e-02
# Theta | train2 -> R² = 0.2575, MSE = 1.6953e-01
# Theta | test1 -> R² = 0.6474, MSE = 8.0991e-02
# Theta | test2 -> R² = 0.3003, MSE = 1.6595e-01
# Theta | test3 -> R² = 0.3699, MSE = 2.0715e-01
# Theta | val -> R² = 0.6445, MSE = 1.1634e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.011218 | Val Loss 0.836526
# Epoch 100 | Train Loss 0.738624 | Val Loss 0.736670
# Epoch 200 | Train Loss 0.737739 | Val Loss 0.733897
# Epoch 300 | Train Loss 0.736366 | Val Loss 0.731815
# Early stopping at epoch 313
# Theta | train1 -> R² = 0.8139, MSE = 4.2475e-02
# Theta | train2 -> R² = 0.1759, MSE = 1.8813e-01
# Theta | test1 -> R² = 0.7238, MSE = 6.3459e-02
# Theta | test2 -> R² = 0.2432, MSE = 1.7949e-01
# Theta | test3 -> R² = 0.4956, MSE = 1.6581e-01
# Theta | val -> R² = 0.6745, MSE = 1.0654e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.012020 | Val Loss 0.837541
# Epoch 100 | Train Loss 0.738721 | Val Loss 0.733557
# Epoch 200 | Train Loss 0.737143 | Val Loss 0.733603
# Epoch 300 | Train Loss 0.735494 | Val Loss 0.730250
# Early stopping at epoch 331
# Theta | train1 -> R² = 0.8284, MSE = 3.9159e-02
# Theta | train2 -> R² = 0.3615, MSE = 1.4578e-01
# Theta | test1 -> R² = 0.6044, MSE = 9.0879e-02
# Theta | test2 -> R² = 0.3808, MSE = 1.4684e-01
# Theta | test3 -> R² = 0.2343, MSE = 2.5172e-01
# Theta | val -> R² = 0.5540, MSE = 1.4595e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.010683 | Val Loss 0.838554
# Epoch 100 | Train Loss 0.739283 | Val Loss 0.734404
# Epoch 200 | Train Loss 0.737893 | Val Loss 0.733158
# Epoch 300 | Train Loss 0.736849 | Val Loss 0.730844
# Early stopping at epoch 332
# Theta | train1 -> R² = 0.8249, MSE = 3.9963e-02
# Theta | train2 -> R² = 0.1624, MSE = 1.9122e-01
# Theta | test1 -> R² = 0.7434, MSE = 5.8939e-02
# Theta | test2 -> R² = 0.2389, MSE = 1.8051e-01
# Theta | test3 -> R² = 0.5443, MSE = 1.4981e-01
# Theta | val -> R² = 0.7248, MSE = 9.0077e-02
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.013313 | Val Loss 0.837790
# Epoch 100 | Train Loss 0.738683 | Val Loss 0.733508
# Epoch 200 | Train Loss 0.736776 | Val Loss 0.731068
# Epoch 300 | Train Loss 0.733939 | Val Loss 0.729536
# Early stopping at epoch 334
# Theta | train1 -> R² = 0.8082, MSE = 4.3781e-02
# Theta | train2 -> R² = 0.4078, MSE = 1.3520e-01
# Theta | test1 -> R² = 0.5372, MSE = 1.0632e-01
# Theta | test2 -> R² = 0.4223, MSE = 1.3700e-01
# Theta | test3 -> R² = 0.2417, MSE = 2.4930e-01
# Theta | val -> R² = 0.5564, MSE = 1.4518e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.011039 | Val Loss 0.838069
# Epoch 100 | Train Loss 0.738541 | Val Loss 0.732670
# Epoch 200 | Train Loss 0.737149 | Val Loss 0.731942
# Epoch 300 | Train Loss 0.734972 | Val Loss 0.733701
# Early stopping at epoch 330
# Theta | train1 -> R² = 0.7928, MSE = 4.7305e-02
# Theta | train2 -> R² = 0.4359, MSE = 1.2878e-01
# Theta | test1 -> R² = 0.4990, MSE = 1.1509e-01
# Theta | test2 -> R² = 0.4410, MSE = 1.3257e-01
# Theta | test3 -> R² = 0.1516, MSE = 2.7892e-01
# Theta | val -> R² = 0.4952, MSE = 1.6522e-01
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.046796 | Val Loss 0.832912
# Epoch 100 | Train Loss 0.783273 | Val Loss 0.722758
# Epoch 200 | Train Loss 0.777651 | Val Loss 0.733767
# Epoch 300 | Train Loss 0.744334 | Val Loss 0.771467
# Early stopping at epoch 339
# Theta | train1 -> R² = 0.8459, MSE = 3.5170e-02
# Theta | train2 -> R² = 0.2307, MSE = 1.7563e-01
# Theta | test1 -> R² = 0.7090, MSE = 6.6852e-02
# Theta | test2 -> R² = 0.2888, MSE = 1.6866e-01
# Theta | test3 -> R² = 0.4956, MSE = 1.6583e-01
# Theta | val -> R² = 0.6701, MSE = 1.0798e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.036898 | Val Loss 0.815539
# Epoch 100 | Train Loss 0.782624 | Val Loss 0.721433
# Epoch 200 | Train Loss 0.775225 | Val Loss 0.719334
# Epoch 300 | Train Loss 0.753503 | Val Loss 0.762729
# Epoch 400 | Train Loss 0.730115 | Val Loss 0.761700
# Early stopping at epoch 493
# Theta | train1 -> R² = 0.8635, MSE = 3.1161e-02
# Theta | train2 -> R² = 0.1841, MSE = 1.8627e-01
# Theta | test1 -> R² = 0.7690, MSE = 5.3063e-02
# Theta | test2 -> R² = 0.2715, MSE = 1.7277e-01
# Theta | test3 -> R² = 0.4733, MSE = 1.7314e-01
# Theta | val -> R² = 0.6694, MSE = 1.0820e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.048358 | Val Loss 0.834988
# Epoch 100 | Train Loss 0.782853 | Val Loss 0.721945
# Epoch 200 | Train Loss 0.785394 | Val Loss 0.734581
# Epoch 300 | Train Loss 0.741461 | Val Loss 0.747460
# Epoch 400 | Train Loss 0.761109 | Val Loss 0.794654
# Epoch 500 | Train Loss 0.718337 | Val Loss 0.755168
# Early stopping at epoch 512
# Theta | train1 -> R² = 0.8653, MSE = 3.0739e-02
# Theta | train2 -> R² = -0.1493, MSE = 2.6238e-01
# Theta | test1 -> R² = 0.8557, MSE = 3.3154e-02
# Theta | test2 -> R² = -0.0116, MSE = 2.3992e-01
# Theta | test3 -> R² = 0.7136, MSE = 9.4147e-02
# Theta | val -> R² = 0.7257, MSE = 8.9780e-02
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.045415 | Val Loss 0.841057
# Epoch 100 | Train Loss 0.782357 | Val Loss 0.721844
# Epoch 200 | Train Loss 0.786497 | Val Loss 0.724470
# Epoch 300 | Train Loss 0.746501 | Val Loss 0.745592
# Epoch 400 | Train Loss 0.727535 | Val Loss 0.757352
# Epoch 500 | Train Loss 0.715554 | Val Loss 0.749715
# Early stopping at epoch 503
# Theta | train1 -> R² = 0.6760, MSE = 7.3957e-02
# Theta | train2 -> R² = 0.5338, MSE = 1.0644e-01
# Theta | test1 -> R² = 0.3914, MSE = 1.3981e-01
# Theta | test2 -> R² = 0.5160, MSE = 1.1479e-01
# Theta | test3 -> R² = -0.6383, MSE = 5.3859e-01
# Theta | val -> R² = 0.1677, MSE = 2.7241e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.033334 | Val Loss 0.821609
# Epoch 100 | Train Loss 0.783116 | Val Loss 0.722234
# Epoch 200 | Train Loss 0.780161 | Val Loss 0.734168
# Epoch 300 | Train Loss 0.744976 | Val Loss 0.755657
# Early stopping at epoch 339
# Theta | train1 -> R² = 0.8424, MSE = 3.5967e-02
# Theta | train2 -> R² = 0.0942, MSE = 2.0681e-01
# Theta | test1 -> R² = 0.7449, MSE = 5.8593e-02
# Theta | test2 -> R² = 0.1780, MSE = 1.9496e-01
# Theta | test3 -> R² = 0.5796, MSE = 1.3822e-01
# Theta | val -> R² = 0.7119, MSE = 9.4291e-02
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.039792 | Val Loss 0.842249
# Epoch 100 | Train Loss 0.783240 | Val Loss 0.722268
# Epoch 200 | Train Loss 0.788586 | Val Loss 0.759791
# Epoch 300 | Train Loss 0.743870 | Val Loss 0.771593
# Early stopping at epoch 339
# Theta | train1 -> R² = 0.8014, MSE = 4.5324e-02
# Theta | train2 -> R² = 0.4091, MSE = 1.3490e-01
# Theta | test1 -> R² = 0.5918, MSE = 9.3773e-02
# Theta | test2 -> R² = 0.4119, MSE = 1.3948e-01
# Theta | test3 -> R² = 0.2600, MSE = 2.4328e-01
# Theta | val -> R² = 0.5658, MSE = 1.4211e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.027890 | Val Loss 0.814456
# Epoch 100 | Train Loss 0.783120 | Val Loss 0.722372
# Epoch 200 | Train Loss 0.777582 | Val Loss 0.721871
# Epoch 300 | Train Loss 0.747246 | Val Loss 0.754960
# Epoch 400 | Train Loss 0.726607 | Val Loss 0.762393
# Early stopping at epoch 451
# Theta | train1 -> R² = 0.8669, MSE = 3.0377e-02
# Theta | train2 -> R² = 0.3153, MSE = 1.5632e-01
# Theta | test1 -> R² = 0.7576, MSE = 5.5684e-02
# Theta | test2 -> R² = 0.3717, MSE = 1.4901e-01
# Theta | test3 -> R² = 0.5115, MSE = 1.6059e-01
# Theta | val -> R² = 0.6982, MSE = 9.8769e-02
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.027759 | Val Loss 0.814145
# Epoch 100 | Train Loss 0.782876 | Val Loss 0.722013
# Epoch 200 | Train Loss 0.775139 | Val Loss 0.725626
# Epoch 300 | Train Loss 0.761487 | Val Loss 0.778838
# Early stopping at epoch 360
# Theta | train1 -> R² = 0.8402, MSE = 3.6484e-02
# Theta | train2 -> R² = 0.3402, MSE = 1.5063e-01
# Theta | test1 -> R² = 0.6356, MSE = 8.3712e-02
# Theta | test2 -> R² = 0.3757, MSE = 1.4806e-01
# Theta | test3 -> R² = 0.4875, MSE = 1.6847e-01
# Theta | val -> R² = 0.6770, MSE = 1.0572e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.027556 | Val Loss 0.815924
# Epoch 100 | Train Loss 0.782683 | Val Loss 0.723249
# Epoch 200 | Train Loss 0.794444 | Val Loss 0.734513
# Epoch 300 | Train Loss 0.746620 | Val Loss 0.747058
# Early stopping at epoch 351
# Theta | train1 -> R² = 0.8303, MSE = 3.8727e-02
# Theta | train2 -> R² = 0.3567, MSE = 1.4686e-01
# Theta | test1 -> R² = 0.5858, MSE = 9.5148e-02
# Theta | test2 -> R² = 0.3895, MSE = 1.4478e-01
# Theta | test3 -> R² = 0.4397, MSE = 1.8419e-01
# Theta | val -> R² = 0.6451, MSE = 1.1615e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.038636 | Val Loss 0.828684
# Epoch 100 | Train Loss 0.782647 | Val Loss 0.722952
# Epoch 200 | Train Loss 0.773664 | Val Loss 0.728781
# Epoch 300 | Train Loss 0.740469 | Val Loss 0.758279
# Early stopping at epoch 348
# Theta | train1 -> R² = 0.8408, MSE = 3.6344e-02
# Theta | train2 -> R² = 0.2758, MSE = 1.6533e-01
# Theta | test1 -> R² = 0.6591, MSE = 7.8305e-02
# Theta | test2 -> R² = 0.3291, MSE = 1.5910e-01
# Theta | test3 -> R² = 0.5351, MSE = 1.5285e-01
# Theta | val -> R² = 0.6928, MSE = 1.0053e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.028871 | Val Loss 0.807959
# Epoch 100 | Train Loss 0.782431 | Val Loss 0.723206
# Epoch 200 | Train Loss 0.772252 | Val Loss 0.744478
# Epoch 300 | Train Loss 0.744657 | Val Loss 0.762789
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.8458, MSE = 3.5189e-02
# Theta | train2 -> R² = 0.2405, MSE = 1.7339e-01
# Theta | test1 -> R² = 0.6941, MSE = 7.0269e-02
# Theta | test2 -> R² = 0.2955, MSE = 1.6708e-01
# Theta | test3 -> R² = 0.5483, MSE = 1.4849e-01
# Theta | val -> R² = 0.6974, MSE = 9.9027e-02
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.037978 | Val Loss 0.828278
# Epoch 100 | Train Loss 0.782268 | Val Loss 0.722494
# Epoch 200 | Train Loss 0.771499 | Val Loss 0.731236
# Epoch 300 | Train Loss 0.740516 | Val Loss 0.774340
# Early stopping at epoch 336
# Theta | train1 -> R² = 0.8290, MSE = 3.9025e-02
# Theta | train2 -> R² = 0.2360, MSE = 1.7442e-01
# Theta | test1 -> R² = 0.6745, MSE = 7.4771e-02
# Theta | test2 -> R² = 0.2873, MSE = 1.6903e-01
# Theta | test3 -> R² = 0.5129, MSE = 1.6014e-01
# Theta | val -> R² = 0.6730, MSE = 1.0701e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.042885 | Val Loss 0.837051
# Epoch 100 | Train Loss 0.782431 | Val Loss 0.721491
# Epoch 200 | Train Loss 0.770537 | Val Loss 0.728836
# Epoch 300 | Train Loss 0.739510 | Val Loss 0.777233
# Early stopping at epoch 336
# Theta | train1 -> R² = 0.8350, MSE = 3.7656e-02
# Theta | train2 -> R² = 0.2563, MSE = 1.6978e-01
# Theta | test1 -> R² = 0.6423, MSE = 8.2172e-02
# Theta | test2 -> R² = 0.3050, MSE = 1.6482e-01
# Theta | test3 -> R² = 0.4510, MSE = 1.8047e-01
# Theta | val -> R² = 0.6507, MSE = 1.1431e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.052927 | Val Loss 0.846215
# Epoch 100 | Train Loss 0.782223 | Val Loss 0.720819
# Epoch 200 | Train Loss 0.769448 | Val Loss 0.727063
# Epoch 300 | Train Loss 0.735607 | Val Loss 0.745558
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.8285, MSE = 3.9142e-02
# Theta | train2 -> R² = 0.3544, MSE = 1.4739e-01
# Theta | test1 -> R² = 0.6140, MSE = 8.8669e-02
# Theta | test2 -> R² = 0.3737, MSE = 1.4853e-01
# Theta | test3 -> R² = 0.3912, MSE = 2.0013e-01
# Theta | val -> R² = 0.6258, MSE = 1.2246e-01
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.036613 | Val Loss 0.827716
# Epoch 100 | Train Loss 0.782563 | Val Loss 0.722238
# Epoch 200 | Train Loss 0.775424 | Val Loss 0.723464
# Epoch 300 | Train Loss 0.746625 | Val Loss 0.755071
# Early stopping at epoch 349
# Theta | train1 -> R² = 0.8384, MSE = 3.6890e-02
# Theta | train2 -> R² = 0.2513, MSE = 1.7094e-01
# Theta | test1 -> R² = 0.6701, MSE = 7.5781e-02
# Theta | test2 -> R² = 0.3127, MSE = 1.6299e-01
# Theta | test3 -> R² = 0.5319, MSE = 1.5389e-01
# Theta | val -> R² = 0.6979, MSE = 9.8882e-02
# Modelo [264, 128, 64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.057743 | Val Loss 0.838749
# Epoch 100 | Train Loss 0.778798 | Val Loss 0.720922
# Epoch 200 | Train Loss 0.749333 | Val Loss 0.728152
# Epoch 300 | Train Loss 0.706093 | Val Loss 0.736411
# Early stopping at epoch 341
# Theta | train1 -> R² = 0.7753, MSE = 5.1302e-02
# Theta | train2 -> R² = -0.1372, MSE = 2.5962e-01
# Theta | test1 -> R² = 0.7434, MSE = 5.8943e-02
# Theta | test2 -> R² = -0.0684, MSE = 2.5339e-01
# Theta | test3 -> R² = 0.5688, MSE = 1.4174e-01
# Theta | val -> R² = 0.6923, MSE = 1.0072e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.073640 | Val Loss 0.849993
# Epoch 100 | Train Loss 0.778452 | Val Loss 0.721427
# Epoch 200 | Train Loss 0.744169 | Val Loss 0.734808
# Epoch 300 | Train Loss 0.715347 | Val Loss 0.746021
# Early stopping at epoch 341
# Theta | train1 -> R² = 0.7975, MSE = 4.6229e-02
# Theta | train2 -> R² = 0.0005, MSE = 2.2818e-01
# Theta | test1 -> R² = 0.6688, MSE = 7.6075e-02
# Theta | test2 -> R² = 0.0440, MSE = 2.2673e-01
# Theta | test3 -> R² = 0.3762, MSE = 2.0506e-01
# Theta | val -> R² = 0.6019, MSE = 1.3030e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
