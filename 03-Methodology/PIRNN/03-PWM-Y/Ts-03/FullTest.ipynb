# %% [markdown]
# - Entradas: PwmD, PWME, Theta
# - Saidas: Y
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE", "Theta"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    # for var in PREDICTORS:
    #     Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 1.479476 | Val Loss 0.834788
# Epoch 100 | Train Loss 0.994056 | Val Loss 0.659778
# Epoch 200 | Train Loss 0.929237 | Val Loss 0.759190
# Epoch 300 | Train Loss 0.921250 | Val Loss 0.732132
# Early stopping at epoch 397
# Y | train1 -> R² = 0.9390, MSE = 5.1085e-03
# Y | train2 -> R² = -1.0014, MSE = 2.1551e-01
# Y | test1 -> R² = 0.8880, MSE = 9.1823e-03
# Y | test2 -> R² = -1.0710, MSE = 2.1982e-01
# Y | test3 -> R² = 0.4285, MSE = 4.3899e-02
# Y | val -> R² = 0.1584, MSE = 6.2661e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.403895 | Val Loss 0.801422
# Epoch 100 | Train Loss 0.944882 | Val Loss 0.765027
# Epoch 200 | Train Loss 0.930872 | Val Loss 0.783014
# Epoch 300 | Train Loss 0.925486 | Val Loss 0.763359
# Early stopping at epoch 381
# Y | train1 -> R² = 0.8503, MSE = 1.2545e-02
# Y | train2 -> R² = -1.2942, MSE = 2.4703e-01
# Y | test1 -> R² = 0.7271, MSE = 2.2365e-02
# Y | test2 -> R² = -1.3881, MSE = 2.5348e-01
# Y | test3 -> R² = 0.8080, MSE = 1.4749e-02
# Y | val -> R² = 0.8606, MSE = 1.0382e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.436280 | Val Loss 0.836758
# Epoch 100 | Train Loss 0.948585 | Val Loss 0.731769
# Epoch 200 | Train Loss 0.931509 | Val Loss 0.786264
# Epoch 300 | Train Loss 0.926960 | Val Loss 0.773069
# Early stopping at epoch 382
# Y | train1 -> R² = 0.8681, MSE = 1.1055e-02
# Y | train2 -> R² = -1.5850, MSE = 2.7835e-01
# Y | test1 -> R² = 0.7663, MSE = 1.9148e-02
# Y | test2 -> R² = -1.6734, MSE = 2.8377e-01
# Y | test3 -> R² = 0.8041, MSE = 1.5044e-02
# Y | val -> R² = 0.7920, MSE = 1.5486e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.418371 | Val Loss 0.805981
# Epoch 100 | Train Loss 1.001566 | Val Loss 0.660937
# Epoch 200 | Train Loss 0.927253 | Val Loss 0.756928
# Epoch 300 | Train Loss 0.916213 | Val Loss 0.720767
# Early stopping at epoch 394
# Y | train1 -> R² = 0.8343, MSE = 1.3882e-02
# Y | train2 -> R² = -1.9739, MSE = 3.2022e-01
# Y | test1 -> R² = 0.7203, MSE = 2.2922e-02
# Y | test2 -> R² = -2.0767, MSE = 3.2656e-01
# Y | test3 -> R² = 0.8053, MSE = 1.4955e-02
# Y | val -> R² = 0.8308, MSE = 1.2596e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.419612 | Val Loss 0.822624
# Epoch 100 | Train Loss 0.962994 | Val Loss 0.687385
# Epoch 200 | Train Loss 0.931514 | Val Loss 0.784616
# Epoch 300 | Train Loss 0.926672 | Val Loss 0.775919
# Early stopping at epoch 391
# Y | train1 -> R² = 0.8443, MSE = 1.3047e-02
# Y | train2 -> R² = -1.1838, MSE = 2.3515e-01
# Y | test1 -> R² = 0.7073, MSE = 2.3982e-02
# Y | test2 -> R² = -1.2736, MSE = 2.4133e-01
# Y | test3 -> R² = 0.7436, MSE = 1.9691e-02
# Y | val -> R² = 0.7331, MSE = 1.9874e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.424757 | Val Loss 0.792306
# Epoch 100 | Train Loss 0.939585 | Val Loss 0.782448
# Epoch 200 | Train Loss 0.930685 | Val Loss 0.782946
# Epoch 300 | Train Loss 0.923816 | Val Loss 0.756731
# Early stopping at epoch 375
# Y | train1 -> R² = 0.8798, MSE = 1.0073e-02
# Y | train2 -> R² = -1.8035, MSE = 3.0187e-01
# Y | test1 -> R² = 0.7985, MSE = 1.6510e-02
# Y | test2 -> R² = -1.8974, MSE = 3.0754e-01
# Y | test3 -> R² = 0.7345, MSE = 2.0395e-02
# Y | val -> R² = 0.4289, MSE = 4.2516e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.404091 | Val Loss 0.815410
# Epoch 100 | Train Loss 1.019743 | Val Loss 0.653961
# Epoch 200 | Train Loss 0.925149 | Val Loss 0.730269
# Epoch 300 | Train Loss 0.915540 | Val Loss 0.713079
# Epoch 400 | Train Loss 0.910675 | Val Loss 0.706648
# Early stopping at epoch 401
# Y | train1 -> R² = 0.9132, MSE = 7.2756e-03
# Y | train2 -> R² = -0.7891, MSE = 1.9264e-01
# Y | test1 -> R² = 0.8322, MSE = 1.3749e-02
# Y | test2 -> R² = -0.8681, MSE = 1.9829e-01
# Y | test3 -> R² = 0.6143, MSE = 2.9623e-02
# Y | val -> R² = 0.5675, MSE = 3.2200e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.438637 | Val Loss 0.833428
# Epoch 100 | Train Loss 0.943787 | Val Loss 0.755050
# Epoch 200 | Train Loss 0.928778 | Val Loss 0.785779
# Epoch 300 | Train Loss 0.918999 | Val Loss 0.744455
# Early stopping at epoch 379
# Y | train1 -> R² = 0.8961, MSE = 8.7081e-03
# Y | train2 -> R² = -1.5250, MSE = 2.7188e-01
# Y | test1 -> R² = 0.9248, MSE = 6.1659e-03
# Y | test2 -> R² = -1.6111, MSE = 2.7715e-01
# Y | test3 -> R² = -0.0921, MSE = 8.3881e-02
# Y | val -> R² = -0.0656, MSE = 7.9333e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.439196 | Val Loss 0.792017
# Epoch 100 | Train Loss 0.962856 | Val Loss 0.706008
# Epoch 200 | Train Loss 0.931783 | Val Loss 0.786755
# Epoch 300 | Train Loss 0.927101 | Val Loss 0.769288
# Early stopping at epoch 387
# Y | train1 -> R² = 0.6311, MSE = 3.0912e-02
# Y | train2 -> R² = -1.4332, MSE = 2.6200e-01
# Y | test1 -> R² = 0.4006, MSE = 4.9119e-02
# Y | test2 -> R² = -1.5072, MSE = 2.6612e-01
# Y | test3 -> R² = 0.8648, MSE = 1.0387e-02
# Y | val -> R² = 0.9139, MSE = 6.4112e-03
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.433509 | Val Loss 0.802850
# Epoch 100 | Train Loss 0.944267 | Val Loss 0.784824
# Epoch 200 | Train Loss 0.931352 | Val Loss 0.798477
# Epoch 300 | Train Loss 0.925314 | Val Loss 0.771177
# Early stopping at epoch 373
# Y | train1 -> R² = 0.8775, MSE = 1.0266e-02
# Y | train2 -> R² = -2.4574, MSE = 3.7228e-01
# Y | test1 -> R² = 0.7922, MSE = 1.7031e-02
# Y | test2 -> R² = -2.5726, MSE = 3.7920e-01
# Y | test3 -> R² = 0.7603, MSE = 1.8410e-02
# Y | val -> R² = 0.8022, MSE = 1.4724e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.465746 | Val Loss 0.836971
# Epoch 100 | Train Loss 0.955676 | Val Loss 0.715126
# Epoch 200 | Train Loss 0.931932 | Val Loss 0.779886
# Epoch 300 | Train Loss 0.927216 | Val Loss 0.758732
# Early stopping at epoch 381
# Y | train1 -> R² = 0.7791, MSE = 1.8511e-02
# Y | train2 -> R² = -1.9233, MSE = 3.1478e-01
# Y | test1 -> R² = 0.6377, MSE = 2.9688e-02
# Y | test2 -> R² = -2.0503, MSE = 3.2376e-01
# Y | test3 -> R² = 0.8895, MSE = 8.4903e-03
# Y | val -> R² = 0.9300, MSE = 5.2091e-03
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.394231 | Val Loss 0.791536
# Epoch 100 | Train Loss 0.943926 | Val Loss 0.771553
# Epoch 200 | Train Loss 0.929406 | Val Loss 0.780192
# Epoch 300 | Train Loss 0.921717 | Val Loss 0.750595
# Early stopping at epoch 379
# Y | train1 -> R² = 0.8665, MSE = 1.1190e-02
# Y | train2 -> R² = -1.6821, MSE = 2.8881e-01
# Y | test1 -> R² = 0.7578, MSE = 1.9848e-02
# Y | test2 -> R² = -1.7838, MSE = 2.9548e-01
# Y | test3 -> R² = 0.8111, MSE = 1.4510e-02
# Y | val -> R² = 0.8821, MSE = 8.7767e-03
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.422670 | Val Loss 0.829660
# Epoch 100 | Train Loss 0.943483 | Val Loss 0.761424
# Epoch 200 | Train Loss 0.931320 | Val Loss 0.796251
# Epoch 300 | Train Loss 0.924360 | Val Loss 0.765241
# Early stopping at epoch 374
# Y | train1 -> R² = 0.9140, MSE = 7.2098e-03
# Y | train2 -> R² = -2.0871, MSE = 3.3241e-01
# Y | test1 -> R² = 0.8801, MSE = 9.8248e-03
# Y | test2 -> R² = -2.1889, MSE = 3.3847e-01
# Y | test3 -> R² = 0.5005, MSE = 3.8369e-02
# Y | val -> R² = 0.4636, MSE = 3.9937e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.414415 | Val Loss 0.796933
# Epoch 100 | Train Loss 0.956102 | Val Loss 0.691045
# Epoch 200 | Train Loss 0.924508 | Val Loss 0.750507
# Epoch 300 | Train Loss 0.914199 | Val Loss 0.717528
# Early stopping at epoch 387
# Y | train1 -> R² = 0.8323, MSE = 1.4049e-02
# Y | train2 -> R² = -1.3177, MSE = 2.4957e-01
# Y | test1 -> R² = 0.7071, MSE = 2.4002e-02
# Y | test2 -> R² = -1.4260, MSE = 2.5750e-01
# Y | test3 -> R² = 0.8073, MSE = 1.4799e-02
# Y | val -> R² = 0.8701, MSE = 9.6718e-03
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.391820 | Val Loss 0.811361
# Epoch 100 | Train Loss 0.947536 | Val Loss 0.748300
# Epoch 200 | Train Loss 0.931065 | Val Loss 0.792222
# Epoch 300 | Train Loss 0.927239 | Val Loss 0.774228
# Early stopping at epoch 381
# Y | train1 -> R² = 0.6147, MSE = 3.2290e-02
# Y | train2 -> R² = -1.9367, MSE = 3.1622e-01
# Y | test1 -> R² = 0.4096, MSE = 4.8384e-02
# Y | test2 -> R² = -2.0423, MSE = 3.2292e-01
# Y | test3 -> R² = 0.8715, MSE = 9.8695e-03
# Y | val -> R² = 0.9483, MSE = 3.8524e-03
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.270536 | Val Loss 0.848220
# Epoch 100 | Train Loss 0.734216 | Val Loss 0.793946
# Epoch 200 | Train Loss 0.697822 | Val Loss 0.814036
# Epoch 300 | Train Loss 0.687199 | Val Loss 0.797878
# Early stopping at epoch 377
# Y | train1 -> R² = 0.7373, MSE = 2.2016e-02
# Y | train2 -> R² = -2.1659, MSE = 3.4089e-01
# Y | test1 -> R² = 0.5864, MSE = 3.3898e-02
# Y | test2 -> R² = -2.1972, MSE = 3.3936e-01
# Y | test3 -> R² = 0.8724, MSE = 9.8035e-03
# Y | val -> R² = 0.8037, MSE = 1.4614e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.231940 | Val Loss 0.819985
# Epoch 100 | Train Loss 0.730914 | Val Loss 0.827296
# Epoch 200 | Train Loss 0.693712 | Val Loss 0.816476
# Epoch 300 | Train Loss 0.681245 | Val Loss 0.822172
# Early stopping at epoch 367
# Y | train1 -> R² = 0.6925, MSE = 2.5764e-02
# Y | train2 -> R² = -3.4896, MSE = 4.8343e-01
# Y | test1 -> R² = 0.5248, MSE = 3.8945e-02
# Y | test2 -> R² = -3.5566, MSE = 4.8365e-01
# Y | test3 -> R² = 0.8913, MSE = 8.3462e-03
# Y | val -> R² = 0.9486, MSE = 3.8235e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.242173 | Val Loss 0.834962
# Epoch 100 | Train Loss 0.727613 | Val Loss 0.872050
# Epoch 200 | Train Loss 0.699250 | Val Loss 0.868066
# Epoch 300 | Train Loss 0.686017 | Val Loss 0.828354
# Early stopping at epoch 363
# Y | train1 -> R² = 0.9161, MSE = 7.0264e-03
# Y | train2 -> R² = -3.0333, MSE = 4.3430e-01
# Y | test1 -> R² = 0.8459, MSE = 1.2627e-02
# Y | test2 -> R² = -3.0456, MSE = 4.2941e-01
# Y | test3 -> R² = 0.6290, MSE = 2.8495e-02
# Y | val -> R² = 0.5344, MSE = 3.4663e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.223373 | Val Loss 0.804856
# Epoch 100 | Train Loss 0.721164 | Val Loss 0.801004
# Epoch 200 | Train Loss 0.690994 | Val Loss 0.787061
# Epoch 300 | Train Loss 0.681571 | Val Loss 0.804891
# Early stopping at epoch 370
# Y | train1 -> R² = 0.3331, MSE = 5.5886e-02
# Y | train2 -> R² = -1.9014, MSE = 3.1241e-01
# Y | test1 -> R² = 0.0629, MSE = 7.6792e-02
# Y | test2 -> R² = -1.9269, MSE = 3.1067e-01
# Y | test3 -> R² = 0.7532, MSE = 1.8959e-02
# Y | val -> R² = 0.9127, MSE = 6.4973e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.221944 | Val Loss 0.799310
# Epoch 100 | Train Loss 0.733639 | Val Loss 0.833971
# Epoch 200 | Train Loss 0.688966 | Val Loss 0.844026
# Epoch 300 | Train Loss 0.678670 | Val Loss 0.816629
# Early stopping at epoch 367
# Y | train1 -> R² = 0.7574, MSE = 2.0332e-02
# Y | train2 -> R² = -4.3796, MSE = 5.7926e-01
# Y | test1 -> R² = 0.6008, MSE = 3.2716e-02
# Y | test2 -> R² = -4.4192, MSE = 5.7521e-01
# Y | test3 -> R² = 0.8296, MSE = 1.3089e-02
# Y | val -> R² = 0.8668, MSE = 9.9204e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.256383 | Val Loss 0.839632
# Epoch 100 | Train Loss 0.754839 | Val Loss 0.686997
# Epoch 200 | Train Loss 0.691665 | Val Loss 0.777187
# Epoch 300 | Train Loss 0.680587 | Val Loss 0.780060
# Early stopping at epoch 383
# Y | train1 -> R² = 0.3496, MSE = 5.4497e-02
# Y | train2 -> R² = -2.4144, MSE = 3.6765e-01
# Y | test1 -> R² = 0.0921, MSE = 7.4398e-02
# Y | test2 -> R² = -2.4757, MSE = 3.6892e-01
# Y | test3 -> R² = 0.7820, MSE = 1.6741e-02
# Y | val -> R² = 0.9287, MSE = 5.3048e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.201529 | Val Loss 0.780768
# Epoch 100 | Train Loss 0.723679 | Val Loss 0.853625
# Epoch 200 | Train Loss 0.693189 | Val Loss 0.817045
# Epoch 300 | Train Loss 0.682702 | Val Loss 0.805295
# Early stopping at epoch 359
# Y | train1 -> R² = 0.7759, MSE = 1.8779e-02
# Y | train2 -> R² = -3.6273, MSE = 4.9826e-01
# Y | test1 -> R² = 0.6309, MSE = 3.0247e-02
# Y | test2 -> R² = -3.6686, MSE = 4.9554e-01
# Y | test3 -> R² = 0.8581, MSE = 1.0897e-02
# Y | val -> R² = 0.9277, MSE = 5.3832e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.236009 | Val Loss 0.838286
# Epoch 100 | Train Loss 0.737382 | Val Loss 0.793660
# Epoch 200 | Train Loss 0.694810 | Val Loss 0.809670
# Epoch 300 | Train Loss 0.680646 | Val Loss 0.817914
# Early stopping at epoch 373
# Y | train1 -> R² = 0.6553, MSE = 2.8886e-02
# Y | train2 -> R² = -2.5373, MSE = 3.8089e-01
# Y | test1 -> R² = 0.4590, MSE = 4.4335e-02
# Y | test2 -> R² = -2.5791, MSE = 3.7989e-01
# Y | test3 -> R² = 0.9029, MSE = 7.4593e-03
# Y | val -> R² = 0.9602, MSE = 2.9648e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.225799 | Val Loss 0.796114
# Epoch 100 | Train Loss 0.727947 | Val Loss 0.844689
# Epoch 200 | Train Loss 0.691496 | Val Loss 0.787069
# Epoch 300 | Train Loss 0.682020 | Val Loss 0.787232
# Early stopping at epoch 365
# Y | train1 -> R² = 0.5947, MSE = 3.3961e-02
# Y | train2 -> R² = -2.8447, MSE = 4.1400e-01
# Y | test1 -> R² = 0.3868, MSE = 5.0251e-02
# Y | test2 -> R² = -2.9062, MSE = 4.1462e-01
# Y | test3 -> R² = 0.8680, MSE = 1.0135e-02
# Y | val -> R² = 0.8803, MSE = 8.9089e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.238995 | Val Loss 0.840604
# Epoch 100 | Train Loss 0.761354 | Val Loss 0.721513
# Epoch 200 | Train Loss 0.694848 | Val Loss 0.843268
# Epoch 300 | Train Loss 0.681026 | Val Loss 0.833637
# Early stopping at epoch 384
# Y | train1 -> R² = 0.4541, MSE = 4.5742e-02
# Y | train2 -> R² = -2.1786, MSE = 3.4226e-01
# Y | test1 -> R² = 0.2031, MSE = 6.5307e-02
# Y | test2 -> R² = -2.2341, MSE = 3.4328e-01
# Y | test3 -> R² = 0.8620, MSE = 1.0597e-02
# Y | val -> R² = 0.9253, MSE = 5.5630e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.286052 | Val Loss 0.874203
# Epoch 100 | Train Loss 0.803441 | Val Loss 0.651596
# Epoch 200 | Train Loss 0.692331 | Val Loss 0.786422
# Epoch 300 | Train Loss 0.681291 | Val Loss 0.806361
# Early stopping at epoch 392
# Y | train1 -> R² = 0.5570, MSE = 3.7123e-02
# Y | train2 -> R² = -3.2469, MSE = 4.5730e-01
# Y | test1 -> R² = 0.3447, MSE = 5.3697e-02
# Y | test2 -> R² = -3.3171, MSE = 4.5823e-01
# Y | test3 -> R² = 0.9125, MSE = 6.7213e-03
# Y | val -> R² = 0.9543, MSE = 3.4059e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.205113 | Val Loss 0.790013
# Epoch 100 | Train Loss 0.724377 | Val Loss 0.870011
# Epoch 200 | Train Loss 0.691485 | Val Loss 0.822997
# Epoch 300 | Train Loss 0.678536 | Val Loss 0.819771
# Early stopping at epoch 359
# Y | train1 -> R² = 0.7929, MSE = 1.7357e-02
# Y | train2 -> R² = -3.0032, MSE = 4.3106e-01
# Y | test1 -> R² = 0.6661, MSE = 2.7365e-02
# Y | test2 -> R² = -3.0327, MSE = 4.2804e-01
# Y | test3 -> R² = 0.8756, MSE = 9.5557e-03
# Y | val -> R² = 0.8972, MSE = 7.6500e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.226179 | Val Loss 0.826398
# Epoch 100 | Train Loss 0.731780 | Val Loss 0.794597
# Epoch 200 | Train Loss 0.691016 | Val Loss 0.798464
# Epoch 300 | Train Loss 0.680234 | Val Loss 0.815024
# Early stopping at epoch 369
# Y | train1 -> R² = 0.3654, MSE = 5.3180e-02
# Y | train2 -> R² = -3.4910, MSE = 4.8359e-01
# Y | test1 -> R² = 0.1117, MSE = 7.2793e-02
# Y | test2 -> R² = -3.5568, MSE = 4.8367e-01
# Y | test3 -> R² = 0.7725, MSE = 1.7470e-02
# Y | val -> R² = 0.8732, MSE = 9.4378e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.246005 | Val Loss 0.822078
# Epoch 100 | Train Loss 0.737284 | Val Loss 0.737553
# Epoch 200 | Train Loss 0.693990 | Val Loss 0.786132
# Epoch 300 | Train Loss 0.687999 | Val Loss 0.782061
# Early stopping at epoch 378
# Y | train1 -> R² = 0.6182, MSE = 3.1995e-02
# Y | train2 -> R² = -3.0154, MSE = 4.3237e-01
# Y | test1 -> R² = 0.4124, MSE = 4.8152e-02
# Y | test2 -> R² = -3.0649, MSE = 4.3146e-01
# Y | test3 -> R² = 0.8685, MSE = 1.0097e-02
# Y | val -> R² = 0.9275, MSE = 5.3970e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.206096 | Val Loss 0.791920
# Epoch 100 | Train Loss 0.734152 | Val Loss 0.831571
# Epoch 200 | Train Loss 0.687487 | Val Loss 0.800858
# Epoch 300 | Train Loss 0.672180 | Val Loss 0.769309
# Early stopping at epoch 363
# Y | train1 -> R² = 0.8632, MSE = 1.1460e-02
# Y | train2 -> R² = -3.1945, MSE = 4.5166e-01
# Y | test1 -> R² = 0.7618, MSE = 1.9517e-02
# Y | test2 -> R² = -3.2309, MSE = 4.4908e-01
# Y | test3 -> R² = 0.8081, MSE = 1.4742e-02
# Y | val -> R² = 0.8891, MSE = 8.2576e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.692564 | Val Loss 0.855866
# Epoch 100 | Train Loss 1.348089 | Val Loss 0.797034
# Epoch 200 | Train Loss 1.058697 | Val Loss 0.663911
# Epoch 300 | Train Loss 1.051556 | Val Loss 0.671830
# Epoch 400 | Train Loss 1.048495 | Val Loss 0.667814
# Early stopping at epoch 453
# Y | train1 -> R² = 0.9840, MSE = 1.3446e-03
# Y | train2 -> R² = 0.3479, MSE = 7.0217e-02
# Y | test1 -> R² = 0.9588, MSE = 3.3783e-03
# Y | test2 -> R² = 0.2579, MSE = 7.8770e-02
# Y | test3 -> R² = -1.2297, MSE = 1.7125e-01
# Y | val -> R² = -0.6702, MSE = 1.2434e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.661066 | Val Loss 0.832824
# Epoch 100 | Train Loss 1.330206 | Val Loss 0.789087
# Epoch 200 | Train Loss 1.060631 | Val Loss 0.660255
# Epoch 300 | Train Loss 1.048465 | Val Loss 0.653734
# Epoch 400 | Train Loss 1.045153 | Val Loss 0.648244
# Early stopping at epoch 447
# Y | train1 -> R² = 0.9585, MSE = 3.4807e-03
# Y | train2 -> R² = 0.4883, MSE = 5.5097e-02
# Y | test1 -> R² = 0.9417, MSE = 4.7817e-03
# Y | test2 -> R² = 0.4401, MSE = 5.9426e-02
# Y | test3 -> R² = -0.6243, MSE = 1.2476e-01
# Y | val -> R² = -0.0605, MSE = 7.8955e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.647318 | Val Loss 0.828772
# Epoch 100 | Train Loss 1.237634 | Val Loss 0.727224
# Epoch 200 | Train Loss 1.057455 | Val Loss 0.684205
# Epoch 300 | Train Loss 1.051653 | Val Loss 0.671753
# Epoch 400 | Train Loss 1.048878 | Val Loss 0.671844
# Epoch 500 | Train Loss 1.046675 | Val Loss 0.669788
# Epoch 600 | Train Loss 1.044413 | Val Loss 0.667981
# Epoch 700 | Train Loss 1.041779 | Val Loss 0.667130
# Epoch 800 | Train Loss 1.039035 | Val Loss 0.665378
# Epoch 900 | Train Loss 1.036932 | Val Loss 0.663696
# Epoch 1000 | Train Loss 1.035237 | Val Loss 0.663595
# Epoch 1100 | Train Loss 1.033805 | Val Loss 0.662980
# Epoch 1200 | Train Loss 1.032470 | Val Loss 0.661664
# Epoch 1300 | Train Loss 1.031066 | Val Loss 0.659453
# Epoch 1400 | Train Loss 1.029505 | Val Loss 0.655147
# Epoch 1500 | Train Loss 1.027802 | Val Loss 0.648264
# Epoch 1600 | Train Loss 1.026005 | Val Loss 0.640553
# Epoch 1700 | Train Loss 1.024109 | Val Loss 0.632367
# Epoch 1800 | Train Loss 1.022076 | Val Loss 0.624508
# Epoch 1900 | Train Loss 1.019834 | Val Loss 0.619010
# Epoch 2000 | Train Loss 1.017254 | Val Loss 0.617772
# Epoch 2100 | Train Loss 1.014158 | Val Loss 0.623689
# Epoch 2200 | Train Loss 1.010408 | Val Loss 0.637908
# Early stopping at epoch 2256
# Y | train1 -> R² = 0.8719, MSE = 1.0734e-02
# Y | train2 -> R² = 0.7032, MSE = 3.1958e-02
# Y | test1 -> R² = 0.9139, MSE = 7.0581e-03
# Y | test2 -> R² = 0.7200, MSE = 2.9718e-02
# Y | test3 -> R² = -0.2654, MSE = 9.7193e-02
# Y | val -> R² = -0.1585, MSE = 8.6247e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.641777 | Val Loss 0.811744
# Epoch 100 | Train Loss 1.255119 | Val Loss 0.722824
# Epoch 200 | Train Loss 1.053528 | Val Loss 0.675801
# Epoch 300 | Train Loss 1.049718 | Val Loss 0.674507
# Epoch 400 | Train Loss 1.047434 | Val Loss 0.674822
# Early stopping at epoch 423
# Y | train1 -> R² = 0.9383, MSE = 5.1704e-03
# Y | train2 -> R² = 0.1801, MSE = 8.8286e-02
# Y | test1 -> R² = 0.9575, MSE = 3.4840e-03
# Y | test2 -> R² = 0.0826, MSE = 9.7371e-02
# Y | test3 -> R² = -1.3235, MSE = 1.7846e-01
# Y | val -> R² = -1.1897, MSE = 1.6302e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.635177 | Val Loss 0.830888
# Epoch 100 | Train Loss 1.353419 | Val Loss 0.810990
# Epoch 200 | Train Loss 1.058950 | Val Loss 0.670440
# Epoch 300 | Train Loss 1.049397 | Val Loss 0.667609
# Epoch 400 | Train Loss 1.047188 | Val Loss 0.665601
# Early stopping at epoch 462
# Y | train1 -> R² = 0.9733, MSE = 2.2384e-03
# Y | train2 -> R² = 0.4289, MSE = 6.1492e-02
# Y | test1 -> R² = 0.9549, MSE = 3.6952e-03
# Y | test2 -> R² = 0.3491, MSE = 6.9089e-02
# Y | test3 -> R² = -1.0929, MSE = 1.6075e-01
# Y | val -> R² = -0.4659, MSE = 1.0914e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.651103 | Val Loss 0.831217
# Epoch 100 | Train Loss 1.223435 | Val Loss 0.713602
# Epoch 200 | Train Loss 1.053687 | Val Loss 0.674686
# Epoch 300 | Train Loss 1.049995 | Val Loss 0.673717
# Epoch 400 | Train Loss 1.047901 | Val Loss 0.672128
# Early stopping at epoch 421
# Y | train1 -> R² = 0.8137, MSE = 1.5609e-02
# Y | train2 -> R² = 0.1135, MSE = 9.5458e-02
# Y | test1 -> R² = 0.8824, MSE = 9.6362e-03
# Y | test2 -> R² = 0.0121, MSE = 1.0486e-01
# Y | test3 -> R² = -3.3480, MSE = 3.3396e-01
# Y | val -> R² = -2.6282, MSE = 2.7012e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.635592 | Val Loss 0.807310
# Epoch 100 | Train Loss 1.131186 | Val Loss 0.684766
# Epoch 200 | Train Loss 1.058301 | Val Loss 0.713504
# Epoch 300 | Train Loss 1.051079 | Val Loss 0.685127
# Early stopping at epoch 395
# Y | train1 -> R² = 0.8035, MSE = 1.6464e-02
# Y | train2 -> R² = -1.1758, MSE = 2.3429e-01
# Y | test1 -> R² = 0.8685, MSE = 1.0779e-02
# Y | test2 -> R² = -1.3504, MSE = 2.4947e-01
# Y | test3 -> R² = -0.6600, MSE = 1.2750e-01
# Y | val -> R² = -0.8129, MSE = 1.3497e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.620922 | Val Loss 0.815419
# Epoch 100 | Train Loss 1.199011 | Val Loss 0.703842
# Epoch 200 | Train Loss 1.055639 | Val Loss 0.698027
# Epoch 300 | Train Loss 1.050501 | Val Loss 0.681435
# Epoch 400 | Train Loss 1.048369 | Val Loss 0.678989
# Epoch 500 | Train Loss 1.046348 | Val Loss 0.676688
# Epoch 600 | Train Loss 1.044297 | Val Loss 0.674428
# Epoch 700 | Train Loss 1.042137 | Val Loss 0.672964
# Epoch 800 | Train Loss 1.039833 | Val Loss 0.672079
# Epoch 900 | Train Loss 1.037548 | Val Loss 0.669523
# Epoch 1000 | Train Loss 1.035284 | Val Loss 0.660688
# Epoch 1100 | Train Loss 1.032988 | Val Loss 0.649579
# Epoch 1200 | Train Loss 1.030652 | Val Loss 0.642107
# Epoch 1300 | Train Loss 1.028493 | Val Loss 0.639385
# Epoch 1400 | Train Loss 1.026566 | Val Loss 0.638072
# Epoch 1500 | Train Loss 1.024604 | Val Loss 0.635075
# Epoch 1600 | Train Loss 1.022716 | Val Loss 0.630409
# Epoch 1700 | Train Loss 1.020695 | Val Loss 0.627013
# Epoch 1800 | Train Loss 1.018536 | Val Loss 0.629072
# Epoch 1900 | Train Loss 1.016487 | Val Loss 0.633555
# Early stopping at epoch 1988
# Y | train1 -> R² = 0.8808, MSE = 9.9914e-03
# Y | train2 -> R² = 0.7014, MSE = 3.2151e-02
# Y | test1 -> R² = 0.9164, MSE = 6.8480e-03
# Y | test2 -> R² = 0.7222, MSE = 2.9489e-02
# Y | test3 -> R² = -0.2625, MSE = 9.6966e-02
# Y | val -> R² = -0.4802, MSE = 1.1020e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.629219 | Val Loss 0.793473
# Epoch 100 | Train Loss 1.229213 | Val Loss 0.711157
# Epoch 200 | Train Loss 1.059993 | Val Loss 0.660587
# Epoch 300 | Train Loss 1.050268 | Val Loss 0.666391
# Epoch 400 | Train Loss 1.047192 | Val Loss 0.667709
# Early stopping at epoch 436
# Y | train1 -> R² = 0.9543, MSE = 3.8285e-03
# Y | train2 -> R² = 0.6081, MSE = 4.2198e-02
# Y | test1 -> R² = 0.9266, MSE = 6.0121e-03
# Y | test2 -> R² = 0.5642, MSE = 4.6259e-02
# Y | test3 -> R² = -0.3444, MSE = 1.0326e-01
# Y | val -> R² = 0.2532, MSE = 5.5601e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.643775 | Val Loss 0.819919
# Epoch 100 | Train Loss 1.271116 | Val Loss 0.744564
# Epoch 200 | Train Loss 1.067000 | Val Loss 0.652077
# Epoch 300 | Train Loss 1.050155 | Val Loss 0.673113
# Epoch 400 | Train Loss 1.046826 | Val Loss 0.665524
# Early stopping at epoch 448
# Y | train1 -> R² = 0.9287, MSE = 5.9734e-03
# Y | train2 -> R² = 0.4863, MSE = 5.5313e-02
# Y | test1 -> R² = 0.8920, MSE = 8.8537e-03
# Y | test2 -> R² = 0.4204, MSE = 6.1518e-02
# Y | test3 -> R² = -0.0974, MSE = 8.4291e-02
# Y | val -> R² = 0.4412, MSE = 4.1603e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.653444 | Val Loss 0.851991
# Epoch 100 | Train Loss 1.250574 | Val Loss 0.717868
# Epoch 200 | Train Loss 1.054197 | Val Loss 0.677778
# Epoch 300 | Train Loss 1.050167 | Val Loss 0.671954
# Epoch 400 | Train Loss 1.047659 | Val Loss 0.669185
# Early stopping at epoch 425
# Y | train1 -> R² = 0.9652, MSE = 2.9129e-03
# Y | train2 -> R² = 0.0890, MSE = 9.8099e-02
# Y | test1 -> R² = 0.9556, MSE = 3.6348e-03
# Y | test2 -> R² = -0.0318, MSE = 1.0952e-01
# Y | test3 -> R² = -1.1755, MSE = 1.6710e-01
# Y | val -> R² = -0.6683, MSE = 1.2420e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.654909 | Val Loss 0.833716
# Epoch 100 | Train Loss 1.198883 | Val Loss 0.705152
# Epoch 200 | Train Loss 1.059572 | Val Loss 0.723758
# Epoch 300 | Train Loss 1.051938 | Val Loss 0.696441
# Epoch 400 | Train Loss 1.048726 | Val Loss 0.692097
# Epoch 500 | Train Loss 1.046713 | Val Loss 0.691553
# Epoch 600 | Train Loss 1.044681 | Val Loss 0.685493
# Epoch 700 | Train Loss 1.042760 | Val Loss 0.677494
# Epoch 800 | Train Loss 1.041072 | Val Loss 0.671671
# Epoch 900 | Train Loss 1.039463 | Val Loss 0.669561
# Epoch 1000 | Train Loss 1.037936 | Val Loss 0.669584
# Epoch 1100 | Train Loss 1.036438 | Val Loss 0.669827
# Early stopping at epoch 1156
# Y | train1 -> R² = 0.8832, MSE = 9.7902e-03
# Y | train2 -> R² = 0.7047, MSE = 3.1795e-02
# Y | test1 -> R² = 0.8894, MSE = 9.0645e-03
# Y | test2 -> R² = 0.7082, MSE = 3.0976e-02
# Y | test3 -> R² = -3.2482, MSE = 3.2629e-01
# Y | val -> R² = -4.1017, MSE = 3.7983e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.610483 | Val Loss 0.816562
# Epoch 100 | Train Loss 1.160940 | Val Loss 0.691197
# Epoch 200 | Train Loss 1.056850 | Val Loss 0.687874
# Epoch 300 | Train Loss 1.049217 | Val Loss 0.668178
# Epoch 400 | Train Loss 1.046512 | Val Loss 0.669008
# Epoch 500 | Train Loss 1.044330 | Val Loss 0.666948
# Epoch 600 | Train Loss 1.041891 | Val Loss 0.661840
# Epoch 700 | Train Loss 1.039358 | Val Loss 0.656953
# Epoch 800 | Train Loss 1.037131 | Val Loss 0.654978
# Epoch 900 | Train Loss 1.035365 | Val Loss 0.654664
# Epoch 1000 | Train Loss 1.033906 | Val Loss 0.654735
# Epoch 1100 | Train Loss 1.032452 | Val Loss 0.653849
# Epoch 1200 | Train Loss 1.030786 | Val Loss 0.651362
# Epoch 1300 | Train Loss 1.028874 | Val Loss 0.646505
# Epoch 1400 | Train Loss 1.026814 | Val Loss 0.640138
# Epoch 1500 | Train Loss 1.024619 | Val Loss 0.634598
# Epoch 1600 | Train Loss 1.022368 | Val Loss 0.633275
# Epoch 1700 | Train Loss 1.019920 | Val Loss 0.636712
# Epoch 1800 | Train Loss 1.017092 | Val Loss 0.643454
# Early stopping at epoch 1836
# Y | train1 -> R² = 0.8750, MSE = 1.0472e-02
# Y | train2 -> R² = 0.7047, MSE = 3.1792e-02
# Y | test1 -> R² = 0.8952, MSE = 8.5844e-03
# Y | test2 -> R² = 0.7252, MSE = 2.9163e-02
# Y | test3 -> R² = -1.0091, MSE = 1.5431e-01
# Y | val -> R² = -1.1428, MSE = 1.5953e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.642706 | Val Loss 0.791988
# Epoch 100 | Train Loss 1.280880 | Val Loss 0.756702
# Epoch 200 | Train Loss 1.082316 | Val Loss 0.638855
# Epoch 300 | Train Loss 1.054785 | Val Loss 0.633319
# Epoch 400 | Train Loss 1.047523 | Val Loss 0.624459
# Epoch 500 | Train Loss 1.043354 | Val Loss 0.622309
# Epoch 600 | Train Loss 1.039975 | Val Loss 0.624019
# Epoch 700 | Train Loss 1.037307 | Val Loss 0.625643
# Early stopping at epoch 748
# Y | train1 -> R² = 0.8951, MSE = 8.7897e-03
# Y | train2 -> R² = 0.6890, MSE = 3.3483e-02
# Y | test1 -> R² = 0.8846, MSE = 9.4576e-03
# Y | test2 -> R² = 0.6789, MSE = 3.4083e-02
# Y | test3 -> R² = -1.1222, MSE = 1.6300e-01
# Y | val -> R² = -0.9624, MSE = 1.4610e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.615878 | Val Loss 0.797452
# Epoch 100 | Train Loss 1.168606 | Val Loss 0.691712
# Epoch 200 | Train Loss 1.057055 | Val Loss 0.707402
# Epoch 300 | Train Loss 1.050298 | Val Loss 0.683263
# Epoch 400 | Train Loss 1.047658 | Val Loss 0.681594
# Epoch 500 | Train Loss 1.045571 | Val Loss 0.680869
# Epoch 600 | Train Loss 1.043573 | Val Loss 0.678724
# Epoch 700 | Train Loss 1.041515 | Val Loss 0.676085
# Epoch 800 | Train Loss 1.039217 | Val Loss 0.672212
# Epoch 900 | Train Loss 1.037074 | Val Loss 0.668920
# Epoch 1000 | Train Loss 1.035283 | Val Loss 0.664190
# Epoch 1100 | Train Loss 1.033529 | Val Loss 0.657526
# Epoch 1200 | Train Loss 1.032008 | Val Loss 0.652761
# Epoch 1300 | Train Loss 1.030602 | Val Loss 0.650018
# Epoch 1400 | Train Loss 1.029101 | Val Loss 0.648175
# Epoch 1500 | Train Loss 1.027379 | Val Loss 0.647761
# Epoch 1600 | Train Loss 1.025479 | Val Loss 0.650667
# Epoch 1700 | Train Loss 1.023280 | Val Loss 0.657113
# Epoch 1800 | Train Loss 1.020815 | Val Loss 0.667751
# Early stopping at epoch 1807
# Y | train1 -> R² = 0.8657, MSE = 1.1250e-02
# Y | train2 -> R² = 0.6937, MSE = 3.2987e-02
# Y | test1 -> R² = 0.9008, MSE = 8.1312e-03
# Y | test2 -> R² = 0.7073, MSE = 3.1063e-02
# Y | test3 -> R² = -1.1390, MSE = 1.6429e-01
# Y | val -> R² = -0.2921, MSE = 9.6200e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.457105 | Val Loss 0.819274
# Epoch 100 | Train Loss 0.937269 | Val Loss 0.777848
# Epoch 200 | Train Loss 0.930979 | Val Loss 0.802219
# Epoch 300 | Train Loss 0.926048 | Val Loss 0.787886
# Early stopping at epoch 360
# Y | train1 -> R² = 0.8785, MSE = 1.0184e-02
# Y | train2 -> R² = -1.1523, MSE = 2.3175e-01
# Y | test1 -> R² = 0.7841, MSE = 1.7691e-02
# Y | test2 -> R² = -1.2218, MSE = 2.3582e-01
# Y | test3 -> R² = 0.7884, MSE = 1.6252e-02
# Y | val -> R² = 0.7955, MSE = 1.5227e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.558827 | Val Loss 0.863816
# Epoch 100 | Train Loss 0.938469 | Val Loss 0.798472
# Epoch 200 | Train Loss 0.930774 | Val Loss 0.788910
# Epoch 300 | Train Loss 0.926051 | Val Loss 0.767371
# Early stopping at epoch 360
# Y | train1 -> R² = 0.8564, MSE = 1.2036e-02
# Y | train2 -> R² = -1.8667, MSE = 3.0868e-01
# Y | test1 -> R² = 0.7340, MSE = 2.1800e-02
# Y | test2 -> R² = -1.9411, MSE = 3.1217e-01
# Y | test3 -> R² = 0.8757, MSE = 9.5500e-03
# Y | val -> R² = 0.9236, MSE = 5.6870e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.543709 | Val Loss 0.852779
# Epoch 100 | Train Loss 0.941118 | Val Loss 0.832994
# Epoch 200 | Train Loss 0.931066 | Val Loss 0.789095
# Epoch 300 | Train Loss 0.924377 | Val Loss 0.749708
# Early stopping at epoch 372
# Y | train1 -> R² = 0.8262, MSE = 1.4560e-02
# Y | train2 -> R² = -1.5252, MSE = 2.7191e-01
# Y | test1 -> R² = 0.7041, MSE = 2.4252e-02
# Y | test2 -> R² = -1.6021, MSE = 2.7619e-01
# Y | test3 -> R² = 0.8664, MSE = 1.0263e-02
# Y | val -> R² = 0.7803, MSE = 1.6354e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.451102 | Val Loss 0.799901
# Epoch 100 | Train Loss 0.937874 | Val Loss 0.756209
# Epoch 200 | Train Loss 0.929675 | Val Loss 0.783333
# Epoch 300 | Train Loss 0.921723 | Val Loss 0.750190
# Early stopping at epoch 355
# Y | train1 -> R² = 0.7334, MSE = 2.2337e-02
# Y | train2 -> R² = -0.9222, MSE = 2.0698e-01
# Y | test1 -> R² = 0.5387, MSE = 3.7805e-02
# Y | test2 -> R² = -0.9838, MSE = 2.1057e-01
# Y | test3 -> R² = 0.9116, MSE = 6.7898e-03
# Y | val -> R² = 0.9493, MSE = 3.7724e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.504777 | Val Loss 0.807407
# Epoch 100 | Train Loss 0.938691 | Val Loss 0.778517
# Epoch 200 | Train Loss 0.930414 | Val Loss 0.787048
# Epoch 300 | Train Loss 0.921454 | Val Loss 0.749085
# Early stopping at epoch 361
# Y | train1 -> R² = 0.8519, MSE = 1.2410e-02
# Y | train2 -> R² = -1.3959, MSE = 2.5799e-01
# Y | test1 -> R² = 0.7289, MSE = 2.2219e-02
# Y | test2 -> R² = -1.4693, MSE = 2.6210e-01
# Y | test3 -> R² = 0.8795, MSE = 9.2553e-03
# Y | val -> R² = 0.9274, MSE = 5.4042e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.515596 | Val Loss 0.837747
# Epoch 100 | Train Loss 0.937664 | Val Loss 0.790045
# Epoch 200 | Train Loss 0.931789 | Val Loss 0.799994
# Epoch 300 | Train Loss 0.927265 | Val Loss 0.782443
# Early stopping at epoch 356
# Y | train1 -> R² = 0.8353, MSE = 1.3805e-02
# Y | train2 -> R² = -1.7453, MSE = 2.9561e-01
# Y | test1 -> R² = 0.7251, MSE = 2.2530e-02
# Y | test2 -> R² = -1.8131, MSE = 2.9859e-01
# Y | test3 -> R² = 0.8663, MSE = 1.0267e-02
# Y | val -> R² = 0.8849, MSE = 8.5726e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.500651 | Val Loss 0.815115
# Epoch 100 | Train Loss 0.936206 | Val Loss 0.774433
# Epoch 200 | Train Loss 0.929131 | Val Loss 0.781745
# Epoch 300 | Train Loss 0.916868 | Val Loss 0.737731
# Early stopping at epoch 353
# Y | train1 -> R² = 0.9122, MSE = 7.3561e-03
# Y | train2 -> R² = -1.5605, MSE = 2.7571e-01
# Y | test1 -> R² = 0.8566, MSE = 1.1748e-02
# Y | test2 -> R² = -1.6186, MSE = 2.7795e-01
# Y | test3 -> R² = 0.7119, MSE = 2.2129e-02
# Y | val -> R² = 0.6339, MSE = 2.7253e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.533247 | Val Loss 0.847609
# Epoch 100 | Train Loss 0.937770 | Val Loss 0.777610
# Epoch 200 | Train Loss 0.930282 | Val Loss 0.787856
# Epoch 300 | Train Loss 0.923282 | Val Loss 0.758981
# Early stopping at epoch 363
# Y | train1 -> R² = 0.8272, MSE = 1.4479e-02
# Y | train2 -> R² = -1.2605, MSE = 2.4340e-01
# Y | test1 -> R² = 0.6874, MSE = 2.5613e-02
# Y | test2 -> R² = -1.3333, MSE = 2.4766e-01
# Y | test3 -> R² = 0.8780, MSE = 9.3735e-03
# Y | val -> R² = 0.8336, MSE = 1.2390e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.480908 | Val Loss 0.811415
# Epoch 100 | Train Loss 0.938020 | Val Loss 0.776253
# Epoch 200 | Train Loss 0.931290 | Val Loss 0.793735
# Epoch 300 | Train Loss 0.925278 | Val Loss 0.769246
# Early stopping at epoch 354
# Y | train1 -> R² = 0.8887, MSE = 9.3224e-03
# Y | train2 -> R² = -1.1321, MSE = 2.2958e-01
# Y | test1 -> R² = 0.8024, MSE = 1.6192e-02
# Y | test2 -> R² = -1.1880, MSE = 2.3224e-01
# Y | test3 -> R² = 0.8223, MSE = 1.3647e-02
# Y | val -> R² = 0.7747, MSE = 1.6776e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.435447 | Val Loss 0.777021
# Epoch 100 | Train Loss 0.939566 | Val Loss 0.745590
# Epoch 200 | Train Loss 0.928722 | Val Loss 0.779221
# Epoch 300 | Train Loss 0.913468 | Val Loss 0.721348
# Early stopping at epoch 363
# Y | train1 -> R² = 0.7979, MSE = 1.6938e-02
# Y | train2 -> R² = -1.2650, MSE = 2.4389e-01
# Y | test1 -> R² = 0.6437, MSE = 2.9198e-02
# Y | test2 -> R² = -1.3222, MSE = 2.4649e-01
# Y | test3 -> R² = 0.8990, MSE = 7.7604e-03
# Y | val -> R² = 0.9407, MSE = 4.4166e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.597065 | Val Loss 0.868937
# Epoch 100 | Train Loss 0.938526 | Val Loss 0.814205
# Epoch 200 | Train Loss 0.932093 | Val Loss 0.798356
# Epoch 300 | Train Loss 0.927395 | Val Loss 0.786606
# Early stopping at epoch 358
# Y | train1 -> R² = 0.8403, MSE = 1.3384e-02
# Y | train2 -> R² = -1.6478, MSE = 2.8511e-01
# Y | test1 -> R² = 0.7384, MSE = 2.1437e-02
# Y | test2 -> R² = -1.7168, MSE = 2.8836e-01
# Y | test3 -> R² = 0.8624, MSE = 1.0565e-02
# Y | val -> R² = 0.8718, MSE = 9.5456e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.554175 | Val Loss 0.887859
# Epoch 100 | Train Loss 0.942988 | Val Loss 0.818952
# Epoch 200 | Train Loss 0.932055 | Val Loss 0.792870
# Epoch 300 | Train Loss 0.926030 | Val Loss 0.770652
# Early stopping at epoch 368
# Y | train1 -> R² = 0.7518, MSE = 2.0795e-02
# Y | train2 -> R² = -1.3365, MSE = 2.5159e-01
# Y | test1 -> R² = 0.5898, MSE = 3.3617e-02
# Y | test2 -> R² = -1.4243, MSE = 2.5733e-01
# Y | test3 -> R² = 0.8897, MSE = 8.4741e-03
# Y | val -> R² = 0.9420, MSE = 4.3207e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.555707 | Val Loss 0.866425
# Epoch 100 | Train Loss 0.945102 | Val Loss 0.836554
# Epoch 200 | Train Loss 0.929778 | Val Loss 0.783709
# Epoch 300 | Train Loss 0.921917 | Val Loss 0.750288
# Early stopping at epoch 376
# Y | train1 -> R² = 0.7594, MSE = 2.0157e-02
# Y | train2 -> R² = -1.2459, MSE = 2.4183e-01
# Y | test1 -> R² = 0.5879, MSE = 3.3773e-02
# Y | test2 -> R² = -1.3277, MSE = 2.4707e-01
# Y | test3 -> R² = 0.8738, MSE = 9.6922e-03
# Y | val -> R² = 0.8984, MSE = 7.5656e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.562866 | Val Loss 0.882651
# Epoch 100 | Train Loss 0.940053 | Val Loss 0.817312
# Epoch 200 | Train Loss 0.931877 | Val Loss 0.790544
# Epoch 300 | Train Loss 0.925377 | Val Loss 0.761556
# Early stopping at epoch 360
# Y | train1 -> R² = 0.6835, MSE = 2.6520e-02
# Y | train2 -> R² = -1.7558, MSE = 2.9674e-01
# Y | test1 -> R² = 0.5011, MSE = 4.0884e-02
# Y | test2 -> R² = -1.8337, MSE = 3.0078e-01
# Y | test3 -> R² = 0.8547, MSE = 1.1164e-02
# Y | val -> R² = 0.8879, MSE = 8.3422e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.446795 | Val Loss 0.794677
# Epoch 100 | Train Loss 0.935567 | Val Loss 0.793355
# Epoch 200 | Train Loss 0.916860 | Val Loss 0.710388
# Epoch 300 | Train Loss 0.909999 | Val Loss 0.703317
# Early stopping at epoch 366
# Y | train1 -> R² = 0.9188, MSE = 6.8009e-03
# Y | train2 -> R² = -1.6759, MSE = 2.8813e-01
# Y | test1 -> R² = 0.8769, MSE = 1.0086e-02
# Y | test2 -> R² = -1.7602, MSE = 2.9298e-01
# Y | test3 -> R² = 0.5924, MSE = 3.1306e-02
# Y | val -> R² = 0.6874, MSE = 2.3273e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.280066 | Val Loss 0.829706
# Epoch 100 | Train Loss 0.711068 | Val Loss 0.832361
# Epoch 200 | Train Loss 0.687542 | Val Loss 0.791457
# Epoch 300 | Train Loss 0.673827 | Val Loss 0.806532
# Early stopping at epoch 346
# Y | train1 -> R² = 0.7184, MSE = 2.3596e-02
# Y | train2 -> R² = -2.2339, MSE = 3.4822e-01
# Y | test1 -> R² = 0.5496, MSE = 3.6910e-02
# Y | test2 -> R² = -2.2300, MSE = 3.4284e-01
# Y | test3 -> R² = 0.9087, MSE = 7.0126e-03
# Y | val -> R² = 0.9438, MSE = 4.1845e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.257643 | Val Loss 0.819865
# Epoch 100 | Train Loss 0.706039 | Val Loss 0.816279
# Epoch 200 | Train Loss 0.682693 | Val Loss 0.789820
# Epoch 300 | Train Loss 0.671813 | Val Loss 0.801497
# Early stopping at epoch 344
# Y | train1 -> R² = 0.7175, MSE = 2.3670e-02
# Y | train2 -> R² = -2.6753, MSE = 3.9575e-01
# Y | test1 -> R² = 0.5409, MSE = 3.7625e-02
# Y | test2 -> R² = -2.6846, MSE = 3.9109e-01
# Y | test3 -> R² = 0.8929, MSE = 8.2283e-03
# Y | val -> R² = 0.9463, MSE = 3.9944e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.267238 | Val Loss 0.827627
# Epoch 100 | Train Loss 0.711610 | Val Loss 0.835874
# Epoch 200 | Train Loss 0.684519 | Val Loss 0.810816
# Epoch 300 | Train Loss 0.673945 | Val Loss 0.815208
# Early stopping at epoch 351
# Y | train1 -> R² = 0.7323, MSE = 2.2430e-02
# Y | train2 -> R² = -2.3582, MSE = 3.6161e-01
# Y | test1 -> R² = 0.5523, MSE = 3.6691e-02
# Y | test2 -> R² = -2.3587, MSE = 3.5651e-01
# Y | test3 -> R² = 0.9060, MSE = 7.2210e-03
# Y | val -> R² = 0.9507, MSE = 3.6719e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.244394 | Val Loss 0.792899
# Epoch 100 | Train Loss 0.712282 | Val Loss 0.862513
# Epoch 200 | Train Loss 0.684320 | Val Loss 0.815091
# Epoch 300 | Train Loss 0.673047 | Val Loss 0.824758
# Early stopping at epoch 346
# Y | train1 -> R² = 0.7157, MSE = 2.3821e-02
# Y | train2 -> R² = -2.4108, MSE = 3.6727e-01
# Y | test1 -> R² = 0.5443, MSE = 3.7341e-02
# Y | test2 -> R² = -2.4268, MSE = 3.6373e-01
# Y | test3 -> R² = 0.8989, MSE = 7.7689e-03
# Y | val -> R² = 0.9517, MSE = 3.5985e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.245020 | Val Loss 0.793902
# Epoch 100 | Train Loss 0.713658 | Val Loss 0.816610
# Epoch 200 | Train Loss 0.683392 | Val Loss 0.798970
# Epoch 300 | Train Loss 0.671160 | Val Loss 0.815801
# Early stopping at epoch 350
# Y | train1 -> R² = 0.5110, MSE = 4.0980e-02
# Y | train2 -> R² = -3.3579, MSE = 4.6925e-01
# Y | test1 -> R² = 0.2667, MSE = 6.0094e-02
# Y | test2 -> R² = -3.3801, MSE = 4.6492e-01
# Y | test3 -> R² = 0.7939, MSE = 1.5833e-02
# Y | val -> R² = 0.7572, MSE = 1.8075e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.250576 | Val Loss 0.817684
# Epoch 100 | Train Loss 0.710030 | Val Loss 0.861819
# Epoch 200 | Train Loss 0.684788 | Val Loss 0.810838
# Epoch 300 | Train Loss 0.671343 | Val Loss 0.813270
# Early stopping at epoch 347
# Y | train1 -> R² = 0.7489, MSE = 2.1040e-02
# Y | train2 -> R² = -3.3470, MSE = 4.6808e-01
# Y | test1 -> R² = 0.6010, MSE = 3.2697e-02
# Y | test2 -> R² = -3.3628, MSE = 4.6308e-01
# Y | test3 -> R² = 0.8840, MSE = 8.9122e-03
# Y | val -> R² = 0.9380, MSE = 4.6135e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.305956 | Val Loss 0.844860
# Epoch 100 | Train Loss 0.719838 | Val Loss 0.800037
# Epoch 200 | Train Loss 0.685758 | Val Loss 0.780185
# Epoch 300 | Train Loss 0.669911 | Val Loss 0.747073
# Early stopping at epoch 354
# Y | train1 -> R² = 0.7657, MSE = 1.9632e-02
# Y | train2 -> R² = -2.7644, MSE = 4.0534e-01
# Y | test1 -> R² = 0.6089, MSE = 3.2052e-02
# Y | test2 -> R² = -2.7540, MSE = 3.9846e-01
# Y | test3 -> R² = 0.9008, MSE = 7.6186e-03
# Y | val -> R² = 0.9317, MSE = 5.0856e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.275424 | Val Loss 0.831954
# Epoch 100 | Train Loss 0.714136 | Val Loss 0.847467
# Epoch 200 | Train Loss 0.685803 | Val Loss 0.817378
# Epoch 300 | Train Loss 0.674379 | Val Loss 0.795250
# Early stopping at epoch 356
# Y | train1 -> R² = 0.9188, MSE = 6.8043e-03
# Y | train2 -> R² = -2.7316, MSE = 4.0181e-01
# Y | test1 -> R² = 0.8350, MSE = 1.3525e-02
# Y | test2 -> R² = -2.7427, MSE = 3.9726e-01
# Y | test3 -> R² = 0.6986, MSE = 2.3150e-02
# Y | val -> R² = 0.5984, MSE = 2.9900e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.269380 | Val Loss 0.824303
# Epoch 100 | Train Loss 0.711768 | Val Loss 0.879001
# Epoch 200 | Train Loss 0.682138 | Val Loss 0.818276
# Epoch 300 | Train Loss 0.670268 | Val Loss 0.796065
# Early stopping at epoch 347
# Y | train1 -> R² = 0.7326, MSE = 2.2408e-02
# Y | train2 -> R² = -2.6116, MSE = 3.8889e-01
# Y | test1 -> R² = 0.5893, MSE = 3.3655e-02
# Y | test2 -> R² = -2.6254, MSE = 3.8481e-01
# Y | test3 -> R² = 0.8806, MSE = 9.1687e-03
# Y | val -> R² = 0.9302, MSE = 5.1999e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.228786 | Val Loss 0.777727
# Epoch 100 | Train Loss 0.706984 | Val Loss 0.803793
# Epoch 200 | Train Loss 0.681948 | Val Loss 0.802451
# Epoch 300 | Train Loss 0.669452 | Val Loss 0.786699
# Early stopping at epoch 344
# Y | train1 -> R² = 0.6639, MSE = 2.8161e-02
# Y | train2 -> R² = -3.6752, MSE = 5.0342e-01
# Y | test1 -> R² = 0.4740, MSE = 4.3103e-02
# Y | test2 -> R² = -3.6893, MSE = 4.9774e-01
# Y | test3 -> R² = 0.8731, MSE = 9.7472e-03
# Y | val -> R² = 0.8935, MSE = 7.9257e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.319586 | Val Loss 0.854382
# Epoch 100 | Train Loss 0.714313 | Val Loss 0.877110
# Epoch 200 | Train Loss 0.688192 | Val Loss 0.811460
# Epoch 300 | Train Loss 0.674512 | Val Loss 0.804635
# Early stopping at epoch 351
# Y | train1 -> R² = 0.7090, MSE = 2.4385e-02
# Y | train2 -> R² = -2.4046, MSE = 3.6660e-01
# Y | test1 -> R² = 0.5544, MSE = 3.6518e-02
# Y | test2 -> R² = -2.3983, MSE = 3.6071e-01
# Y | test3 -> R² = 0.8968, MSE = 7.9261e-03
# Y | val -> R² = 0.9319, MSE = 5.0698e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.299950 | Val Loss 0.871042
# Epoch 100 | Train Loss 0.721366 | Val Loss 0.836818
# Epoch 200 | Train Loss 0.685699 | Val Loss 0.815870
# Epoch 300 | Train Loss 0.672811 | Val Loss 0.814877
# Early stopping at epoch 352
# Y | train1 -> R² = 0.7166, MSE = 2.3745e-02
# Y | train2 -> R² = -2.8536, MSE = 4.1495e-01
# Y | test1 -> R² = 0.5606, MSE = 3.6008e-02
# Y | test2 -> R² = -2.8682, MSE = 4.1058e-01
# Y | test3 -> R² = 0.8866, MSE = 8.7105e-03
# Y | val -> R² = 0.9423, MSE = 4.2939e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.319395 | Val Loss 0.845753
# Epoch 100 | Train Loss 0.712854 | Val Loss 0.815924
# Epoch 200 | Train Loss 0.686628 | Val Loss 0.786424
# Epoch 300 | Train Loss 0.672872 | Val Loss 0.751296
# Early stopping at epoch 353
# Y | train1 -> R² = 0.7873, MSE = 1.7823e-02
# Y | train2 -> R² = -2.6953, MSE = 3.9790e-01
# Y | test1 -> R² = 0.6350, MSE = 2.9912e-02
# Y | test2 -> R² = -2.7059, MSE = 3.9336e-01
# Y | test3 -> R² = 0.8976, MSE = 7.8664e-03
# Y | val -> R² = 0.9465, MSE = 3.9802e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.280439 | Val Loss 0.827045
# Epoch 100 | Train Loss 0.713719 | Val Loss 0.866911
# Epoch 200 | Train Loss 0.687818 | Val Loss 0.811419
# Epoch 300 | Train Loss 0.672751 | Val Loss 0.782906
# Early stopping at epoch 343
# Y | train1 -> R² = 0.7500, MSE = 2.0947e-02
# Y | train2 -> R² = -2.8533, MSE = 4.1492e-01
# Y | test1 -> R² = 0.6012, MSE = 3.2683e-02
# Y | test2 -> R² = -2.8503, MSE = 4.0868e-01
# Y | test3 -> R² = 0.8847, MSE = 8.8591e-03
# Y | val -> R² = 0.9268, MSE = 5.4514e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.221419 | Val Loss 0.788555
# Epoch 100 | Train Loss 0.709228 | Val Loss 0.798699
# Epoch 200 | Train Loss 0.683081 | Val Loss 0.807792
# Epoch 300 | Train Loss 0.670654 | Val Loss 0.813226
# Early stopping at epoch 348
# Y | train1 -> R² = 0.5295, MSE = 3.9426e-02
# Y | train2 -> R² = -3.0971, MSE = 4.4117e-01
# Y | test1 -> R² = 0.2910, MSE = 5.8100e-02
# Y | test2 -> R² = -3.1198, MSE = 4.3729e-01
# Y | test3 -> R² = 0.7932, MSE = 1.5883e-02
# Y | val -> R² = 0.7785, MSE = 1.6490e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.650507 | Val Loss 0.790116
# Epoch 100 | Train Loss 1.067631 | Val Loss 0.738932
# Epoch 200 | Train Loss 1.057503 | Val Loss 0.708513
# Epoch 300 | Train Loss 1.049227 | Val Loss 0.678721
# Epoch 400 | Train Loss 1.047046 | Val Loss 0.681197
# Epoch 500 | Train Loss 1.045168 | Val Loss 0.677862
# Epoch 600 | Train Loss 1.042221 | Val Loss 0.668704
# Epoch 700 | Train Loss 1.038755 | Val Loss 0.655908
# Epoch 800 | Train Loss 1.036078 | Val Loss 0.641784
# Epoch 900 | Train Loss 1.033854 | Val Loss 0.632025
# Epoch 1000 | Train Loss 1.031920 | Val Loss 0.626596
# Epoch 1100 | Train Loss 1.029959 | Val Loss 0.624825
# Epoch 1200 | Train Loss 1.028078 | Val Loss 0.626613
# Epoch 1300 | Train Loss 1.026157 | Val Loss 0.629340
# Early stopping at epoch 1382
# Y | train1 -> R² = 0.8755, MSE = 1.0432e-02
# Y | train2 -> R² = 0.6890, MSE = 3.3488e-02
# Y | test1 -> R² = 0.8875, MSE = 9.2211e-03
# Y | test2 -> R² = 0.6916, MSE = 3.2735e-02
# Y | test3 -> R² = -1.3057, MSE = 1.7709e-01
# Y | val -> R² = -1.2526, MSE = 1.6771e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.690815 | Val Loss 0.825220
# Epoch 100 | Train Loss 1.083412 | Val Loss 0.679295
# Epoch 200 | Train Loss 1.050845 | Val Loss 0.670891
# Epoch 300 | Train Loss 1.047704 | Val Loss 0.675921
# Early stopping at epoch 393
# Y | train1 -> R² = 0.9164, MSE = 7.0033e-03
# Y | train2 -> R² = -0.0640, MSE = 1.1457e-01
# Y | test1 -> R² = 0.9267, MSE = 6.0058e-03
# Y | test2 -> R² = -0.1713, MSE = 1.2432e-01
# Y | test3 -> R² = -0.4245, MSE = 1.0942e-01
# Y | val -> R² = -0.5776, MSE = 1.1745e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.746299 | Val Loss 0.840794
# Epoch 100 | Train Loss 1.091130 | Val Loss 0.676429
# Epoch 200 | Train Loss 1.051115 | Val Loss 0.683595
# Epoch 300 | Train Loss 1.047885 | Val Loss 0.684135
# Early stopping at epoch 394
# Y | train1 -> R² = 0.9141, MSE = 7.1971e-03
# Y | train2 -> R² = -0.3553, MSE = 1.4593e-01
# Y | test1 -> R² = 0.9330, MSE = 5.4910e-03
# Y | test2 -> R² = -0.4893, MSE = 1.5808e-01
# Y | test3 -> R² = -0.7880, MSE = 1.3733e-01
# Y | val -> R² = -0.9391, MSE = 1.4437e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.763981 | Val Loss 0.855799
# Epoch 100 | Train Loss 1.074044 | Val Loss 0.784479
# Epoch 200 | Train Loss 1.058222 | Val Loss 0.717170
# Epoch 300 | Train Loss 1.049203 | Val Loss 0.676934
# Early stopping at epoch 379
# Y | train1 -> R² = 0.9156, MSE = 7.0690e-03
# Y | train2 -> R² = -0.5893, MSE = 1.7114e-01
# Y | test1 -> R² = 0.9149, MSE = 6.9753e-03
# Y | test2 -> R² = -0.7273, MSE = 1.8334e-01
# Y | test3 -> R² = 0.0090, MSE = 7.6114e-02
# Y | val -> R² = -0.1312, MSE = 8.4220e-02
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.667248 | Val Loss 0.805379
# ...
# Epoch 600 | Train Loss 0.905274 | Val Loss 0.642533
# Epoch 700 | Train Loss 0.903163 | Val Loss 0.639449
# Epoch 800 | Train Loss 0.901952 | Val Loss 0.641079
# Epoch 900 | Train Loss 0.900763 | Val Loss 0.641853
# Early stopping at epoch 956
# Y | train1 -> R² = 0.6657, MSE = 2.8016e-02
# Y | train2 -> R² = 0.1479, MSE = 9.1755e-02
# Y | test1 -> R² = 0.6975, MSE = 2.4793e-02
# Y | test2 -> R² = 0.1391, MSE = 9.1378e-02
# Y | test3 -> R² = -0.5711, MSE = 1.2067e-01
# Y | val -> R² = -1.4745, MSE = 1.8423e-01
# Modelo [32, 16, 8] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.191753 | Val Loss 0.809180
# Epoch 100 | Train Loss 0.741892 | Val Loss 0.834135
# Epoch 200 | Train Loss 0.681997 | Val Loss 0.842102
# Epoch 300 | Train Loss 0.672667 | Val Loss 0.827877
# Early stopping at epoch 367
# Y | train1 -> R² = 0.8392, MSE = 1.3477e-02
# Y | train2 -> R² = -4.3610, MSE = 5.7726e-01
# Y | test1 -> R² = 0.7819, MSE = 1.7873e-02
# Y | test2 -> R² = -4.4412, MSE = 5.7754e-01
# Y | test3 -> R² = -0.2406, MSE = 9.5291e-02
# Y | val -> R² = 0.1102, MSE = 6.6249e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.192928 | Val Loss 0.810401
# Epoch 100 | Train Loss 0.949250 | Val Loss 0.679719
# Epoch 200 | Train Loss 0.681565 | Val Loss 0.720320
# Epoch 300 | Train Loss 0.669443 | Val Loss 0.733543
# Epoch 400 | Train Loss 0.666403 | Val Loss 0.739136
# Early stopping at epoch 422
# Y | train1 -> R² = 0.6519, MSE = 2.9170e-02
# Y | train2 -> R² = -4.1340, MSE = 5.5282e-01
# Y | test1 -> R² = 0.7096, MSE = 2.3799e-02
# Y | test2 -> R² = -4.1717, MSE = 5.4893e-01
# Y | test3 -> R² = -2.9839, MSE = 3.0599e-01
# Y | val -> R² = -2.4331, MSE = 2.5559e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.190576 | Val Loss 0.808853
# Epoch 100 | Train Loss 0.847993 | Val Loss 0.673330
# Epoch 200 | Train Loss 0.679612 | Val Loss 0.828334
# Epoch 300 | Train Loss 0.672993 | Val Loss 0.839273
# Early stopping at epoch 394
# Y | train1 -> R² = 0.9495, MSE = 4.2334e-03
# Y | train2 -> R² = -3.6477, MSE = 5.0045e-01
# Y | test1 -> R² = 0.9513, MSE = 3.9895e-03
# Y | test2 -> R² = -3.7262, MSE = 5.0165e-01
# Y | test3 -> R² = -0.9096, MSE = 1.4667e-01
# Y | val -> R² = -0.7791, MSE = 1.3246e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.193140 | Val Loss 0.811941
# Epoch 100 | Train Loss 0.995681 | Val Loss 0.703608
# Epoch 200 | Train Loss 0.685288 | Val Loss 0.696953
# Epoch 300 | Train Loss 0.668317 | Val Loss 0.713557
# Epoch 400 | Train Loss 0.665184 | Val Loss 0.718272
# Early stopping at epoch 446
# Y | train1 -> R² = 0.7818, MSE = 1.8284e-02
# Y | train2 -> R² = -3.5967, MSE = 4.9496e-01
# Y | test1 -> R² = 0.8278, MSE = 1.4108e-02
# Y | test2 -> R² = -3.6367, MSE = 4.9215e-01
# Y | test3 -> R² = -3.3040, MSE = 3.3058e-01
# Y | val -> R² = -1.8687, MSE = 2.1357e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.192130 | Val Loss 0.811112
# Epoch 100 | Train Loss 0.981351 | Val Loss 0.700495
# Epoch 200 | Train Loss 0.694930 | Val Loss 0.842264
# Epoch 300 | Train Loss 0.676472 | Val Loss 0.787036
# Epoch 400 | Train Loss 0.672539 | Val Loss 0.766170
# Early stopping at epoch 415
# Y | train1 -> R² = 0.9304, MSE = 5.8296e-03
# Y | train2 -> R² = -2.4236, MSE = 3.6864e-01
# Y | test1 -> R² = 0.9617, MSE = 3.1415e-03
# Y | test2 -> R² = -2.4876, MSE = 3.7018e-01
# Y | test3 -> R² = -2.0099, MSE = 2.3118e-01
# Y | val -> R² = -1.7444, MSE = 2.0432e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.191693 | Val Loss 0.808202
# Epoch 100 | Train Loss 0.900806 | Val Loss 0.659932
# Epoch 200 | Train Loss 0.668586 | Val Loss 0.711608
# Epoch 300 | Train Loss 0.665652 | Val Loss 0.722279
# Epoch 400 | Train Loss 0.663805 | Val Loss 0.726584
# Early stopping at epoch 412
# Y | train1 -> R² = 0.9308, MSE = 5.8007e-03
# Y | train2 -> R² = -2.7192, MSE = 4.0047e-01
# Y | test1 -> R² = 0.9450, MSE = 4.5057e-03
# Y | test2 -> R² = -2.7438, MSE = 3.9738e-01
# Y | test3 -> R² = -0.8224, MSE = 1.3997e-01
# Y | val -> R² = -0.1999, MSE = 8.9331e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.192409 | Val Loss 0.810869
# Epoch 100 | Train Loss 0.745930 | Val Loss 0.817168
# Epoch 200 | Train Loss 0.684656 | Val Loss 0.803390
# Epoch 300 | Train Loss 0.678576 | Val Loss 0.771084
# Early stopping at epoch 372
# Y | train1 -> R² = 0.8625, MSE = 1.1524e-02
# Y | train2 -> R² = -4.3459, MSE = 5.7563e-01
# Y | test1 -> R² = 0.9167, MSE = 6.8267e-03
# Y | test2 -> R² = -4.4659, MSE = 5.8016e-01
# Y | test3 -> R² = -2.6323, MSE = 2.7899e-01
# Y | val -> R² = -1.1151, MSE = 1.5747e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.192039 | Val Loss 0.810743
# Epoch 100 | Train Loss 0.867657 | Val Loss 0.664303
# Epoch 200 | Train Loss 0.683476 | Val Loss 0.834445
# Epoch 300 | Train Loss 0.674344 | Val Loss 0.774093
# Early stopping at epoch 396
# Y | train1 -> R² = 0.7161, MSE = 2.3793e-02
# Y | train2 -> R² = -4.3039, MSE = 5.7111e-01
# Y | test1 -> R² = 0.5428, MSE = 3.7465e-02
# Y | test2 -> R² = -4.3853, MSE = 5.7161e-01
# Y | test3 -> R² = 0.7319, MSE = 2.0592e-02
# Y | val -> R² = 0.7393, MSE = 1.9410e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.192469 | Val Loss 0.811861
# Epoch 100 | Train Loss 0.954917 | Val Loss 0.692206
# Epoch 200 | Train Loss 0.668893 | Val Loss 0.695478
# Epoch 300 | Train Loss 0.664299 | Val Loss 0.690107
# Epoch 400 | Train Loss 0.660767 | Val Loss 0.701855
# Early stopping at epoch 430
# Y | train1 -> R² = 0.8175, MSE = 1.5290e-02
# Y | train2 -> R² = -3.3388, MSE = 4.6719e-01
# Y | test1 -> R² = 0.8409, MSE = 1.3037e-02
# Y | test2 -> R² = -3.3125, MSE = 4.5774e-01
# Y | test3 -> R² = -1.1683, MSE = 1.6654e-01
# Y | val -> R² = -0.8168, MSE = 1.3526e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.192805 | Val Loss 0.812690
# Epoch 100 | Train Loss 0.921327 | Val Loss 0.700490
# Epoch 200 | Train Loss 0.686859 | Val Loss 0.821079
# Epoch 300 | Train Loss 0.670259 | Val Loss 0.806027
# Epoch 400 | Train Loss 0.664933 | Val Loss 0.781902
# Early stopping at epoch 405
# Y | train1 -> R² = 0.7119, MSE = 2.4142e-02
# Y | train2 -> R² = -3.4850, MSE = 4.8294e-01
# Y | test1 -> R² = 0.5811, MSE = 3.4328e-02
# Y | test2 -> R² = -3.5503, MSE = 4.8298e-01
# Y | test3 -> R² = 0.3765, MSE = 4.7887e-02
# Y | val -> R² = 0.1223, MSE = 6.5342e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.191158 | Val Loss 0.807103
# Epoch 100 | Train Loss 0.975706 | Val Loss 0.696838
# Epoch 200 | Train Loss 0.691132 | Val Loss 0.775581
# Epoch 300 | Train Loss 0.672450 | Val Loss 0.761962
# Epoch 400 | Train Loss 0.667770 | Val Loss 0.695807
# Early stopping at epoch 428
# Y | train1 -> R² = 0.5273, MSE = 3.9612e-02
# Y | train2 -> R² = -4.4314, MSE = 5.8484e-01
# Y | test1 -> R² = 0.5768, MSE = 3.4684e-02
# Y | test2 -> R² = -4.4370, MSE = 5.7710e-01
# Y | test3 -> R² = -2.3364, MSE = 2.5626e-01
# Y | val -> R² = -1.8884, MSE = 2.1504e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.192973 | Val Loss 0.811056
# Epoch 100 | Train Loss 0.907798 | Val Loss 0.681067
# Epoch 200 | Train Loss 0.670819 | Val Loss 0.699045
# Epoch 300 | Train Loss 0.666484 | Val Loss 0.702285
# Epoch 400 | Train Loss 0.664346 | Val Loss 0.713899
# Early stopping at epoch 414
# Y | train1 -> R² = 0.7616, MSE = 1.9978e-02
# Y | train2 -> R² = -2.3143, MSE = 3.5688e-01
# Y | test1 -> R² = 0.8039, MSE = 1.6072e-02
# Y | test2 -> R² = -2.3454, MSE = 3.5509e-01
# Y | test3 -> R² = -1.2358, MSE = 1.7173e-01
# Y | val -> R² = -0.7766, MSE = 1.3227e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.192232 | Val Loss 0.811279
# Epoch 100 | Train Loss 0.802540 | Val Loss 0.685281
# Epoch 200 | Train Loss 0.683819 | Val Loss 0.873004
# Epoch 300 | Train Loss 0.672959 | Val Loss 0.816546
# Early stopping at epoch 387
# Y | train1 -> R² = 0.7428, MSE = 2.1556e-02
# Y | train2 -> R² = -3.0661, MSE = 4.3783e-01
# Y | test1 -> R² = 0.6064, MSE = 3.2254e-02
# Y | test2 -> R² = -3.1466, MSE = 4.4013e-01
# Y | test3 -> R² = 0.6639, MSE = 2.5814e-02
# Y | val -> R² = 0.6377, MSE = 2.6971e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.191598 | Val Loss 0.810239
# Epoch 100 | Train Loss 0.964676 | Val Loss 0.685565
# Epoch 200 | Train Loss 0.675709 | Val Loss 0.762923
# Epoch 300 | Train Loss 0.669265 | Val Loss 0.711452
# Epoch 400 | Train Loss 0.666138 | Val Loss 0.709640
# Early stopping at epoch 430
# Y | train1 -> R² = 0.8218, MSE = 1.4933e-02
# Y | train2 -> R² = -4.1648, MSE = 5.5614e-01
# Y | test1 -> R² = 0.8498, MSE = 1.2310e-02
# Y | test2 -> R² = -4.1553, MSE = 5.4720e-01
# Y | test3 -> R² = -1.4471, MSE = 1.8795e-01
# Y | val -> R² = -0.7971, MSE = 1.3380e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.192120 | Val Loss 0.811084
# Epoch 100 | Train Loss 0.814190 | Val Loss 0.647304
# Epoch 200 | Train Loss 0.691726 | Val Loss 0.764778
# Epoch 300 | Train Loss 0.673290 | Val Loss 0.777356
# Early stopping at epoch 400
# Y | train1 -> R² = 0.6571, MSE = 2.8737e-02
# Y | train2 -> R² = -2.1360, MSE = 3.3768e-01
# Y | test1 -> R² = 0.3622, MSE = 5.2265e-02
# Y | test2 -> R² = -2.2228, MSE = 3.4207e-01
# Y | test3 -> R² = 0.7023, MSE = 2.2868e-02
# Y | val -> R² = 0.8177, MSE = 1.3573e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.571391 | Val Loss 0.811218
# Epoch 100 | Train Loss 1.211224 | Val Loss 0.746781
# Epoch 200 | Train Loss 1.128587 | Val Loss 0.658344
# Epoch 300 | Train Loss 1.119256 | Val Loss 0.661660
# Epoch 400 | Train Loss 1.057379 | Val Loss 0.672343
# Epoch 500 | Train Loss 1.042681 | Val Loss 0.678603
# Epoch 600 | Train Loss 1.037079 | Val Loss 0.672031
# Early stopping at epoch 659
# Y | train1 -> R² = 0.9448, MSE = 4.6257e-03
# Y | train2 -> R² = 0.6683, MSE = 3.5712e-02
# Y | test1 -> R² = 0.9204, MSE = 6.5234e-03
# Y | test2 -> R² = 0.6535, MSE = 3.6780e-02
# Y | test3 -> R² = -0.9421, MSE = 1.4916e-01
# Y | val -> R² = 0.0041, MSE = 7.4148e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.566563 | Val Loss 0.811342
# Epoch 100 | Train Loss 1.159708 | Val Loss 0.680423
# Epoch 200 | Train Loss 1.074348 | Val Loss 0.656992
# Epoch 300 | Train Loss 1.053275 | Val Loss 0.661845
# Epoch 400 | Train Loss 1.041208 | Val Loss 0.652124
# Early stopping at epoch 437
# Y | train1 -> R² = 0.9504, MSE = 4.1576e-03
# Y | train2 -> R² = 0.6979, MSE = 3.2526e-02
# Y | test1 -> R² = 0.9335, MSE = 5.4464e-03
# Y | test2 -> R² = 0.6635, MSE = 3.5718e-02
# Y | test3 -> R² = -1.1985, MSE = 1.6886e-01
# Y | val -> R² = -0.1346, MSE = 8.4467e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.566328 | Val Loss 0.810394
# Epoch 100 | Train Loss 1.226385 | Val Loss 0.757884
# Epoch 200 | Train Loss 1.188497 | Val Loss 0.712351
# Epoch 300 | Train Loss 1.070305 | Val Loss 0.667936
# Epoch 400 | Train Loss 1.048638 | Val Loss 0.651268
# Epoch 500 | Train Loss 1.038810 | Val Loss 0.635297
# Epoch 600 | Train Loss 1.032966 | Val Loss 0.620886
# Epoch 700 | Train Loss 1.028619 | Val Loss 0.614249
# Epoch 800 | Train Loss 1.024647 | Val Loss 0.609734
# Epoch 900 | Train Loss 1.021592 | Val Loss 0.610629
# Epoch 1000 | Train Loss 1.019032 | Val Loss 0.619402
# Early stopping at epoch 1074
# Y | train1 -> R² = 0.8854, MSE = 9.6025e-03
# Y | train2 -> R² = 0.6636, MSE = 3.6224e-02
# Y | test1 -> R² = 0.8919, MSE = 8.8571e-03
# Y | test2 -> R² = 0.6667, MSE = 3.5375e-02
# Y | test3 -> R² = -0.0171, MSE = 7.8120e-02
# Y | val -> R² = -0.8967, MSE = 1.4121e-01
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.569202 | Val Loss 0.811075
# Epoch 100 | Train Loss 1.206929 | Val Loss 0.735807
# Epoch 200 | Train Loss 1.081517 | Val Loss 0.655764
# Epoch 300 | Train Loss 1.054659 | Val Loss 0.659944
# Epoch 400 | Train Loss 1.042241 | Val Loss 0.628216
# Epoch 500 | Train Loss 1.035997 | Val Loss 0.612967
# Epoch 600 | Train Loss 1.032909 | Val Loss 0.609483
# Epoch 700 | Train Loss 1.030533 | Val Loss 0.612657
# Epoch 800 | Train Loss 1.028354 | Val Loss 0.618742
# Early stopping at epoch 869
# Y | train1 -> R² = 0.8667, MSE = 1.1172e-02
# Y | train2 -> R² = 0.6948, MSE = 3.2862e-02
# Y | test1 -> R² = 0.8968, MSE = 8.4552e-03
# Y | test2 -> R² = 0.6938, MSE = 3.2506e-02
# Y | test3 -> R² = 0.1978, MSE = 6.1615e-02
# Y | val -> R² = 0.2102, MSE = 5.8801e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.566744 | Val Loss 0.812106
# Epoch 100 | Train Loss 1.227462 | Val Loss 0.766394
# Epoch 200 | Train Loss 1.206698 | Val Loss 0.732594
# Epoch 300 | Train Loss 1.079815 | Val Loss 0.669841
# Epoch 400 | Train Loss 1.054059 | Val Loss 0.701204
# Epoch 500 | Train Loss 1.045349 | Val Loss 0.711916
# Early stopping at epoch 573
# Y | train1 -> R² = 0.8895, MSE = 9.2587e-03
# Y | train2 -> R² = 0.5670, MSE = 4.6625e-02
# Y | test1 -> R² = 0.9063, MSE = 7.6826e-03
# Y | test2 -> R² = 0.5064, MSE = 5.2393e-02
# Y | test3 -> R² = -2.7155, MSE = 2.8537e-01
# Y | val -> R² = -0.6614, MSE = 1.2369e-01
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.569442 | Val Loss 0.809495
# Epoch 100 | Train Loss 1.207445 | Val Loss 0.727566
# Epoch 200 | Train Loss 1.123476 | Val Loss 0.656469
# Epoch 300 | Train Loss 1.060236 | Val Loss 0.656055
# Epoch 400 | Train Loss 1.043702 | Val Loss 0.649313
# Epoch 500 | Train Loss 1.035353 | Val Loss 0.639580
# Epoch 600 | Train Loss 1.030764 | Val Loss 0.634658
# Epoch 700 | Train Loss 1.026442 | Val Loss 0.630289
# Epoch 800 | Train Loss 1.023209 | Val Loss 0.631956
# Epoch 900 | Train Loss 1.020533 | Val Loss 0.633654
# Early stopping at epoch 1000
# Y | train1 -> R² = 0.8864, MSE = 9.5163e-03
# Y | train2 -> R² = 0.6904, MSE = 3.3338e-02
# Y | test1 -> R² = 0.9052, MSE = 7.7724e-03
# Y | test2 -> R² = 0.7122, MSE = 3.0550e-02
# Y | test3 -> R² = -1.2929, MSE = 1.7611e-01
# Y | val -> R² = -1.4643, MSE = 1.8347e-01
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.567421 | Val Loss 0.809123
# Epoch 100 | Train Loss 1.217021 | Val Loss 0.750496
# Epoch 200 | Train Loss 1.129091 | Val Loss 0.662090
# Epoch 300 | Train Loss 1.057512 | Val Loss 0.654284
# Epoch 400 | Train Loss 1.045310 | Val Loss 0.629741
# Epoch 500 | Train Loss 1.038514 | Val Loss 0.622129
# Epoch 600 | Train Loss 1.033818 | Val Loss 0.613940
# Epoch 700 | Train Loss 1.030300 | Val Loss 0.611499
# Epoch 800 | Train Loss 1.027192 | Val Loss 0.614293
# Epoch 900 | Train Loss 1.023960 | Val Loss 0.618170
# Early stopping at epoch 957
# Y | train1 -> R² = 0.8745, MSE = 1.0517e-02
# Y | train2 -> R² = 0.6935, MSE = 3.3000e-02
# Y | test1 -> R² = 0.8940, MSE = 8.6858e-03
# Y | test2 -> R² = 0.7101, MSE = 3.0766e-02
# Y | test3 -> R² = -0.3554, MSE = 1.0410e-01
# Y | val -> R² = -0.5286, MSE = 1.1381e-01
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.563533 | Val Loss 0.805859
# Epoch 100 | Train Loss 1.216314 | Val Loss 0.744239
# Epoch 200 | Train Loss 1.141204 | Val Loss 0.691296
# Epoch 300 | Train Loss 1.085668 | Val Loss 0.705050
# Epoch 400 | Train Loss 1.063906 | Val Loss 0.717613
# Epoch 500 | Train Loss 1.055815 | Val Loss 0.708802
# Early stopping at epoch 509
# Y | train1 -> R² = 0.5302, MSE = 3.9367e-02
# Y | train2 -> R² = 0.1077, MSE = 9.6081e-02
# Y | test1 -> R² = 0.5420, MSE = 3.7530e-02
# Y | test2 -> R² = 0.0374, MSE = 1.0217e-01
# Y | test3 -> R² = -5.2992, MSE = 4.8382e-01
# Y | val -> R² = -1.9179, MSE = 2.1723e-01
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.568948 | Val Loss 0.809959
# Epoch 100 | Train Loss 1.219070 | Val Loss 0.749121
# Epoch 200 | Train Loss 1.137524 | Val Loss 0.654723
# Epoch 300 | Train Loss 1.067782 | Val Loss 0.666147
# Epoch 400 | Train Loss 1.057416 | Val Loss 0.673167
# Epoch 500 | Train Loss 1.050335 | Val Loss 0.655293
# Early stopping at epoch 524
# Y | train1 -> R² = 0.9510, MSE = 4.1087e-03
# Y | train2 -> R² = 0.6655, MSE = 3.6016e-02
# Y | test1 -> R² = 0.9485, MSE = 4.2228e-03
# Y | test2 -> R² = 0.6289, MSE = 3.9385e-02
# Y | test3 -> R² = -1.6750, MSE = 2.0546e-01
# Y | val -> R² = -0.3961, MSE = 1.0394e-01
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
