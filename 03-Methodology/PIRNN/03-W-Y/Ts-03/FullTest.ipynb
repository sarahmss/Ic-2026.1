# %% [markdown]
# - Entradas: PwmD, PWME, Theta
# - Saidas: Y
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef", "Theta"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    # for var in PREDICTORS:
    #     Dataset[f"s{var}"] = (Dataset[var].shift(-1) + Dataset[var]) 
    
    # for var in PREDICTORS:
    #     Dataset[f"d{var}"] = (Dataset[var].shift(-1) - Dataset[var])  
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dy_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.431415 | Val Loss 0.795099
# Epoch 100 | Train Loss 0.950298 | Val Loss 0.833543
# Epoch 200 | Train Loss 0.927235 | Val Loss 0.781200
# Epoch 300 | Train Loss 0.912170 | Val Loss 0.684696
# Epoch 400 | Train Loss 0.904756 | Val Loss 0.652208
# Epoch 500 | Train Loss 0.902438 | Val Loss 0.649294
# Epoch 600 | Train Loss 0.900813 | Val Loss 0.643369
# Epoch 700 | Train Loss 0.899592 | Val Loss 0.635697
# Epoch 800 | Train Loss 0.898575 | Val Loss 0.630378
# Epoch 900 | Train Loss 0.897651 | Val Loss 0.626910
# Epoch 1000 | Train Loss 0.896740 | Val Loss 0.625055
# Epoch 1100 | Train Loss 0.895806 | Val Loss 0.624310
# Epoch 1200 | Train Loss 0.894862 | Val Loss 0.623368
# Epoch 1300 | Train Loss 0.893795 | Val Loss 0.623360
# Epoch 1400 | Train Loss 0.892706 | Val Loss 0.622848
# Epoch 1500 | Train Loss 0.891509 | Val Loss 0.623249
# Epoch 1600 | Train Loss 0.890271 | Val Loss 0.623820
# Early stopping at epoch 1678
# Y | train1 -> R² = 0.6383, MSE = 3.0312e-02
# Y | train2 -> R² = 0.1638, MSE = 9.0036e-02
# Y | test1 -> R² = 0.7697, MSE = 1.8870e-02
# Y | test2 -> R² = 0.1550, MSE = 8.9691e-02
# Y | test3 -> R² = -0.1747, MSE = 9.0228e-02
# Y | val -> R² = 0.1161, MSE = 6.5805e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.392479 | Val Loss 0.818309
# Epoch 100 | Train Loss 0.992540 | Val Loss 0.706257
# Epoch 200 | Train Loss 0.916169 | Val Loss 0.703107
# Epoch 300 | Train Loss 0.906988 | Val Loss 0.658961
# Epoch 400 | Train Loss 0.903891 | Val Loss 0.649768
# Epoch 500 | Train Loss 0.902030 | Val Loss 0.644310
# Epoch 600 | Train Loss 0.900477 | Val Loss 0.637230
# Epoch 700 | Train Loss 0.898976 | Val Loss 0.629786
# Epoch 800 | Train Loss 0.897665 | Val Loss 0.626450
# Epoch 900 | Train Loss 0.896534 | Val Loss 0.626596
# Epoch 1000 | Train Loss 0.895516 | Val Loss 0.628789
# Epoch 1100 | Train Loss 0.894530 | Val Loss 0.633390
# Early stopping at epoch 1116
# Y | train1 -> R² = 0.6439, MSE = 2.9843e-02
# Y | train2 -> R² = 0.1707, MSE = 8.9299e-02
# Y | test1 -> R² = 0.7318, MSE = 2.1978e-02
# Y | test2 -> R² = 0.1650, MSE = 8.8633e-02
# Y | test3 -> R² = -1.5027, MSE = 1.9223e-01
# Y | val -> R² = -1.8994, MSE = 2.1586e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.426334 | Val Loss 0.803827
# Epoch 100 | Train Loss 0.947588 | Val Loss 0.856797
# Epoch 200 | Train Loss 0.931910 | Val Loss 0.828286
# Epoch 300 | Train Loss 0.922083 | Val Loss 0.738471
# Epoch 400 | Train Loss 0.907437 | Val Loss 0.672140
# Epoch 500 | Train Loss 0.903610 | Val Loss 0.657610
# Epoch 600 | Train Loss 0.901462 | Val Loss 0.647277
# Epoch 700 | Train Loss 0.899549 | Val Loss 0.635191
# Epoch 800 | Train Loss 0.897895 | Val Loss 0.628796
# Epoch 900 | Train Loss 0.896272 | Val Loss 0.623810
# Epoch 1000 | Train Loss 0.894695 | Val Loss 0.621149
# Epoch 1100 | Train Loss 0.893128 | Val Loss 0.621648
# Epoch 1200 | Train Loss 0.891479 | Val Loss 0.623200
# Early stopping at epoch 1275
# Y | train1 -> R² = 0.6410, MSE = 3.0085e-02
# Y | train2 -> R² = 0.1661, MSE = 8.9790e-02
# Y | test1 -> R² = 0.7449, MSE = 2.0902e-02
# Y | test2 -> R² = 0.1661, MSE = 8.8510e-02
# Y | test3 -> R² = -0.8902, MSE = 1.4518e-01
# Y | val -> R² = -0.9153, MSE = 1.4259e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.405481 | Val Loss 0.817015
# Epoch 100 | Train Loss 0.979250 | Val Loss 0.745938
# Epoch 200 | Train Loss 0.928932 | Val Loss 0.781241
# Epoch 300 | Train Loss 0.918759 | Val Loss 0.707495
# Epoch 400 | Train Loss 0.905020 | Val Loss 0.661382
# Epoch 500 | Train Loss 0.901914 | Val Loss 0.653454
# Epoch 600 | Train Loss 0.900020 | Val Loss 0.642855
# Epoch 700 | Train Loss 0.898418 | Val Loss 0.632469
# Epoch 800 | Train Loss 0.897054 | Val Loss 0.623996
# Epoch 900 | Train Loss 0.895933 | Val Loss 0.619729
# Epoch 1000 | Train Loss 0.894816 | Val Loss 0.617682
# Epoch 1100 | Train Loss 0.893610 | Val Loss 0.617377
# Epoch 1200 | Train Loss 0.892316 | Val Loss 0.618679
# Early stopping at epoch 1289
# Y | train1 -> R² = 0.6429, MSE = 2.9927e-02
# Y | train2 -> R² = 0.1658, MSE = 8.9823e-02
# Y | test1 -> R² = 0.7560, MSE = 1.9994e-02
# Y | test2 -> R² = 0.1671, MSE = 8.8409e-02
# Y | test3 -> R² = -0.1416, MSE = 8.7681e-02
# Y | val -> R² = -0.2738, MSE = 9.4835e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.404547 | Val Loss 0.810775
# Epoch 100 | Train Loss 0.955239 | Val Loss 0.778655
# Epoch 200 | Train Loss 0.922204 | Val Loss 0.732356
# Epoch 300 | Train Loss 0.908282 | Val Loss 0.637114
# Epoch 400 | Train Loss 0.904906 | Val Loss 0.636745
# Epoch 500 | Train Loss 0.902454 | Val Loss 0.633239
# Epoch 600 | Train Loss 0.900441 | Val Loss 0.626623
# Epoch 700 | Train Loss 0.898956 | Val Loss 0.625599
# Epoch 800 | Train Loss 0.897731 | Val Loss 0.625668
# Epoch 900 | Train Loss 0.896571 | Val Loss 0.624434
# Epoch 1000 | Train Loss 0.895409 | Val Loss 0.623658
# Epoch 1100 | Train Loss 0.894246 | Val Loss 0.623693
# Epoch 1200 | Train Loss 0.893026 | Val Loss 0.625467
# Epoch 1300 | Train Loss 0.891711 | Val Loss 0.628468
# Early stopping at epoch 1325
# Y | train1 -> R² = 0.6340, MSE = 3.0672e-02
# Y | train2 -> R² = 0.1652, MSE = 8.9885e-02
# Y | test1 -> R² = 0.7417, MSE = 2.1171e-02
# Y | test2 -> R² = 0.1593, MSE = 8.9230e-02
# Y | test3 -> R² = -1.4904, MSE = 1.9128e-01
# Y | val -> R² = -1.5345, MSE = 1.8869e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.425795 | Val Loss 0.818321
# Epoch 100 | Train Loss 0.966613 | Val Loss 0.746550
# Epoch 200 | Train Loss 0.927722 | Val Loss 0.761766
# Epoch 300 | Train Loss 0.912518 | Val Loss 0.678830
# Epoch 400 | Train Loss 0.905138 | Val Loss 0.647926
# Epoch 500 | Train Loss 0.902829 | Val Loss 0.645339
# Epoch 600 | Train Loss 0.900733 | Val Loss 0.640464
# Epoch 700 | Train Loss 0.898768 | Val Loss 0.630683
# Epoch 800 | Train Loss 0.897449 | Val Loss 0.622636
# Epoch 900 | Train Loss 0.896303 | Val Loss 0.616320
# Epoch 1000 | Train Loss 0.895270 | Val Loss 0.613482
# Epoch 1100 | Train Loss 0.894302 | Val Loss 0.613230
# Epoch 1200 | Train Loss 0.893290 | Val Loss 0.614852
# Early stopping at epoch 1271
# Y | train1 -> R² = 0.6405, MSE = 3.0123e-02
# Y | train2 -> R² = 0.1692, MSE = 8.9464e-02
# Y | test1 -> R² = 0.7407, MSE = 2.1251e-02
# Y | test2 -> R² = 0.1660, MSE = 8.8523e-02
# Y | test3 -> R² = -0.7509, MSE = 1.3448e-01
# Y | val -> R² = -0.9295, MSE = 1.4365e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.477222 | Val Loss 0.867654
# Epoch 100 | Train Loss 1.216301 | Val Loss 0.766963
# Epoch 200 | Train Loss 0.915659 | Val Loss 0.622389
# Epoch 300 | Train Loss 0.907683 | Val Loss 0.618279
# Epoch 400 | Train Loss 0.904797 | Val Loss 0.616182
# Epoch 500 | Train Loss 0.903172 | Val Loss 0.617173
# Epoch 600 | Train Loss 0.901824 | Val Loss 0.617858
# Early stopping at epoch 637
# Y | train1 -> R² = 0.6696, MSE = 2.7688e-02
# Y | train2 -> R² = 0.1748, MSE = 8.8860e-02
# Y | test1 -> R² = 0.7294, MSE = 2.2177e-02
# Y | test2 -> R² = 0.1632, MSE = 8.8818e-02
# Y | test3 -> R² = -0.7220, MSE = 1.3226e-01
# Y | val -> R² = -1.2582, MSE = 1.6813e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.418867 | Val Loss 0.823459
# Epoch 100 | Train Loss 1.088222 | Val Loss 0.687604
# Epoch 200 | Train Loss 0.915291 | Val Loss 0.683182
# Epoch 300 | Train Loss 0.907429 | Val Loss 0.643906
# Epoch 400 | Train Loss 0.904404 | Val Loss 0.643310
# Epoch 500 | Train Loss 0.902136 | Val Loss 0.636499
# Epoch 600 | Train Loss 0.900346 | Val Loss 0.629573
# Epoch 700 | Train Loss 0.898793 | Val Loss 0.624924
# Epoch 800 | Train Loss 0.897404 | Val Loss 0.623045
# Epoch 900 | Train Loss 0.896151 | Val Loss 0.624945
# Epoch 1000 | Train Loss 0.894946 | Val Loss 0.628472
# Early stopping at epoch 1038
# Y | train1 -> R² = 0.6365, MSE = 3.0463e-02
# Y | train2 -> R² = 0.1702, MSE = 8.9348e-02
# Y | test1 -> R² = 0.7338, MSE = 2.1818e-02
# Y | test2 -> R² = 0.1642, MSE = 8.8714e-02
# Y | test3 -> R² = -1.3752, MSE = 1.8243e-01
# Y | val -> R² = -1.6929, MSE = 2.0049e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.474425 | Val Loss 0.807858
# Epoch 100 | Train Loss 1.003361 | Val Loss 0.685809
# Epoch 200 | Train Loss 0.919132 | Val Loss 0.727649
# Epoch 300 | Train Loss 0.908603 | Val Loss 0.670087
# Epoch 400 | Train Loss 0.905098 | Val Loss 0.649484
# Epoch 500 | Train Loss 0.903092 | Val Loss 0.642943
# Epoch 600 | Train Loss 0.901439 | Val Loss 0.639955
# Epoch 700 | Train Loss 0.899916 | Val Loss 0.637356
# Epoch 800 | Train Loss 0.898588 | Val Loss 0.634265
# Epoch 900 | Train Loss 0.897434 | Val Loss 0.630806
# Epoch 1000 | Train Loss 0.896439 | Val Loss 0.628404
# Epoch 1100 | Train Loss 0.895463 | Val Loss 0.627740
# Epoch 1200 | Train Loss 0.894443 | Val Loss 0.628038
# Epoch 1300 | Train Loss 0.893415 | Val Loss 0.628153
# Early stopping at epoch 1346
# Y | train1 -> R² = 0.6377, MSE = 3.0356e-02
# Y | train2 -> R² = 0.1663, MSE = 8.9772e-02
# Y | test1 -> R² = 0.7258, MSE = 2.2474e-02
# Y | test2 -> R² = 0.1671, MSE = 8.8403e-02
# Y | test3 -> R² = -0.7397, MSE = 1.3362e-01
# Y | val -> R² = -0.7666, MSE = 1.3152e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.430185 | Val Loss 0.820255
# Epoch 100 | Train Loss 0.943016 | Val Loss 0.895196
# Epoch 200 | Train Loss 0.933690 | Val Loss 0.868975
# Epoch 300 | Train Loss 0.927134 | Val Loss 0.807645
# Early stopping at epoch 372
# Y | train1 -> R² = 0.8777, MSE = 1.0250e-02
# Y | train2 -> R² = -2.4727, MSE = 3.7393e-01
# Y | test1 -> R² = 0.8295, MSE = 1.3970e-02
# Y | test2 -> R² = -2.3852, MSE = 3.5931e-01
# Y | test3 -> R² = -0.6007, MSE = 1.2295e-01
# Y | val -> R² = -0.3278, MSE = 9.8851e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.425437 | Val Loss 0.804097
# Epoch 100 | Train Loss 0.947814 | Val Loss 0.833710
# Epoch 200 | Train Loss 0.926479 | Val Loss 0.772634
# Epoch 300 | Train Loss 0.911928 | Val Loss 0.684739
# Epoch 400 | Train Loss 0.906359 | Val Loss 0.653017
# Epoch 500 | Train Loss 0.904615 | Val Loss 0.651279
# Epoch 600 | Train Loss 0.902985 | Val Loss 0.647557
# Epoch 700 | Train Loss 0.901231 | Val Loss 0.637961
# Epoch 800 | Train Loss 0.899546 | Val Loss 0.628410
# Epoch 900 | Train Loss 0.898095 | Val Loss 0.622432
# Epoch 1000 | Train Loss 0.896873 | Val Loss 0.619355
# Epoch 1100 | Train Loss 0.895780 | Val Loss 0.617860
# Epoch 1200 | Train Loss 0.894764 | Val Loss 0.617445
# Epoch 1300 | Train Loss 0.893666 | Val Loss 0.617871
# Epoch 1400 | Train Loss 0.892350 | Val Loss 0.619388
# Early stopping at epoch 1449
# Y | train1 -> R² = 0.6363, MSE = 3.0478e-02
# Y | train2 -> R² = 0.1610, MSE = 9.0343e-02
# Y | test1 -> R² = 0.7283, MSE = 2.2265e-02
# Y | test2 -> R² = 0.1593, MSE = 8.9235e-02
# Y | test3 -> R² = -1.0906, MSE = 1.6057e-01
# Y | val -> R² = -1.3835, MSE = 1.7745e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.428702 | Val Loss 0.836216
# Epoch 100 | Train Loss 1.082266 | Val Loss 0.700407
# Epoch 200 | Train Loss 0.929309 | Val Loss 0.781681
# Epoch 300 | Train Loss 0.915539 | Val Loss 0.674038
# Epoch 400 | Train Loss 0.907663 | Val Loss 0.633129
# Epoch 500 | Train Loss 0.904613 | Val Loss 0.640332
# Epoch 600 | Train Loss 0.902134 | Val Loss 0.643092
# Early stopping at epoch 682
# Y | train1 -> R² = 0.6581, MSE = 2.8646e-02
# Y | train2 -> R² = 0.1982, MSE = 8.6334e-02
# Y | test1 -> R² = 0.7417, MSE = 2.1163e-02
# Y | test2 -> R² = 0.1801, MSE = 8.7021e-02
# Y | test3 -> R² = -1.5755, MSE = 1.9782e-01
# Y | val -> R² = -1.8750, MSE = 2.1404e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.414633 | Val Loss 0.818401
# Epoch 100 | Train Loss 1.015517 | Val Loss 0.699245
# Epoch 200 | Train Loss 0.915780 | Val Loss 0.705052
# Epoch 300 | Train Loss 0.906616 | Val Loss 0.665200
# Epoch 400 | Train Loss 0.903677 | Val Loss 0.659298
# Epoch 500 | Train Loss 0.901442 | Val Loss 0.654601
# Epoch 600 | Train Loss 0.899688 | Val Loss 0.647721
# Epoch 700 | Train Loss 0.898005 | Val Loss 0.640462
# Epoch 800 | Train Loss 0.896404 | Val Loss 0.631434
# Epoch 900 | Train Loss 0.894808 | Val Loss 0.628479
# Epoch 1000 | Train Loss 0.893075 | Val Loss 0.628403
# Epoch 1100 | Train Loss 0.891180 | Val Loss 0.627378
# Epoch 1200 | Train Loss 0.889162 | Val Loss 0.626338
# Epoch 1300 | Train Loss 0.887043 | Val Loss 0.624889
# Epoch 1400 | Train Loss 0.884874 | Val Loss 0.623432
# Epoch 1500 | Train Loss 0.882935 | Val Loss 0.627295
# Epoch 1600 | Train Loss 0.881196 | Val Loss 0.639449
# Early stopping at epoch 1639
# Y | train1 -> R² = 0.6425, MSE = 2.9953e-02
# Y | train2 -> R² = 0.1705, MSE = 8.9320e-02
# Y | test1 -> R² = 0.7792, MSE = 1.8094e-02
# Y | test2 -> R² = 0.1583, MSE = 8.9343e-02
# Y | test3 -> R² = 0.6458, MSE = 2.7209e-02
# Y | val -> R² = 0.4748, MSE = 3.9101e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.438083 | Val Loss 0.788799
# Epoch 100 | Train Loss 0.954071 | Val Loss 0.767654
# Epoch 200 | Train Loss 0.925788 | Val Loss 0.753462
# Epoch 300 | Train Loss 0.912264 | Val Loss 0.685474
# Epoch 400 | Train Loss 0.906222 | Val Loss 0.655974
# Epoch 500 | Train Loss 0.903557 | Val Loss 0.646876
# Epoch 600 | Train Loss 0.901696 | Val Loss 0.640858
# Epoch 700 | Train Loss 0.899964 | Val Loss 0.638729
# Epoch 800 | Train Loss 0.898383 | Val Loss 0.637088
# Epoch 900 | Train Loss 0.896997 | Val Loss 0.633625
# Epoch 1000 | Train Loss 0.895984 | Val Loss 0.630475
# Epoch 1100 | Train Loss 0.895006 | Val Loss 0.628596
# Epoch 1200 | Train Loss 0.893772 | Val Loss 0.629082
# Epoch 1300 | Train Loss 0.892334 | Val Loss 0.631065
# Early stopping at epoch 1344
# Y | train1 -> R² = 0.6437, MSE = 2.9854e-02
# Y | train2 -> R² = 0.1721, MSE = 8.9145e-02
# Y | test1 -> R² = 0.7475, MSE = 2.0690e-02
# Y | test2 -> R² = 0.1694, MSE = 8.8167e-02
# Y | test3 -> R² = -0.6392, MSE = 1.2590e-01
# Y | val -> R² = -0.6551, MSE = 1.2323e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.436278 | Val Loss 0.848602
# Epoch 100 | Train Loss 0.975670 | Val Loss 0.732222
# Epoch 200 | Train Loss 0.926544 | Val Loss 0.777406
# Epoch 300 | Train Loss 0.914160 | Val Loss 0.695020
# Epoch 400 | Train Loss 0.906335 | Val Loss 0.644457
# Epoch 500 | Train Loss 0.903527 | Val Loss 0.640164
# Epoch 600 | Train Loss 0.901877 | Val Loss 0.637141
# Epoch 700 | Train Loss 0.900274 | Val Loss 0.631098
# Epoch 800 | Train Loss 0.898586 | Val Loss 0.622953
# Epoch 900 | Train Loss 0.897173 | Val Loss 0.617169
# Epoch 1000 | Train Loss 0.896058 | Val Loss 0.615728
# Epoch 1100 | Train Loss 0.894984 | Val Loss 0.617255
# Epoch 1200 | Train Loss 0.893932 | Val Loss 0.620108
# Early stopping at epoch 1231
# Y | train1 -> R² = 0.6432, MSE = 2.9898e-02
# Y | train2 -> R² = 0.1663, MSE = 8.9768e-02
# Y | test1 -> R² = 0.7302, MSE = 2.2109e-02
# Y | test2 -> R² = 0.1667, MSE = 8.8448e-02
# Y | test3 -> R² = -0.8134, MSE = 1.3928e-01
# Y | val -> R² = -1.2547, MSE = 1.6786e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.197272 | Val Loss 0.785902
# Epoch 100 | Train Loss 0.730648 | Val Loss 0.980160
# Epoch 200 | Train Loss 0.695430 | Val Loss 0.827134
# Epoch 300 | Train Loss 0.684008 | Val Loss 0.793327
# Early stopping at epoch 359
# Y | train1 -> R² = 0.8162, MSE = 1.5405e-02
# Y | train2 -> R² = -3.9254, MSE = 5.3036e-01
# Y | test1 -> R² = 0.7073, MSE = 2.3989e-02
# Y | test2 -> R² = -3.8299, MSE = 5.1266e-01
# Y | test3 -> R² = 0.2653, MSE = 5.6429e-02
# Y | val -> R² = 0.4324, MSE = 4.2256e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.247575 | Val Loss 0.848522
# Epoch 100 | Train Loss 0.742964 | Val Loss 0.872351
# Epoch 200 | Train Loss 0.693236 | Val Loss 0.815806
# Epoch 300 | Train Loss 0.682148 | Val Loss 0.749996
# Early stopping at epoch 372
# Y | train1 -> R² = 0.7172, MSE = 2.3700e-02
# Y | train2 -> R² = -3.1064, MSE = 4.4217e-01
# Y | test1 -> R² = 0.5946, MSE = 3.3219e-02
# Y | test2 -> R² = -3.0153, MSE = 4.2620e-01
# Y | test3 -> R² = 0.4962, MSE = 3.8695e-02
# Y | val -> R² = 0.6135, MSE = 2.8777e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.210474 | Val Loss 0.794317
# Epoch 100 | Train Loss 0.729594 | Val Loss 0.966802
# Epoch 200 | Train Loss 0.690745 | Val Loss 0.841433
# Epoch 300 | Train Loss 0.677782 | Val Loss 0.798148
# Early stopping at epoch 363
# Y | train1 -> R² = 0.5818, MSE = 3.5044e-02
# Y | train2 -> R² = -3.5874, MSE = 4.9396e-01
# Y | test1 -> R² = 0.4158, MSE = 4.7874e-02
# Y | test2 -> R² = -3.5015, MSE = 4.7780e-01
# Y | test3 -> R² = 0.6817, MSE = 2.4448e-02
# Y | val -> R² = 0.7923, MSE = 1.5462e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.239729 | Val Loss 0.802521
# Epoch 100 | Train Loss 0.737169 | Val Loss 0.904301
# Epoch 200 | Train Loss 0.690941 | Val Loss 0.805572
# Epoch 300 | Train Loss 0.675264 | Val Loss 0.722064
# Early stopping at epoch 368
# Y | train1 -> R² = 0.7125, MSE = 2.4089e-02
# Y | train2 -> R² = -3.7167, MSE = 5.0789e-01
# Y | test1 -> R² = 0.5801, MSE = 3.4409e-02
# Y | test2 -> R² = -3.6215, MSE = 4.9054e-01
# Y | test3 -> R² = 0.6355, MSE = 2.7998e-02
# Y | val -> R² = 0.7056, MSE = 2.1917e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.235976 | Val Loss 0.848651
# Epoch 100 | Train Loss 0.737193 | Val Loss 0.877109
# Epoch 200 | Train Loss 0.691371 | Val Loss 0.794583
# Epoch 300 | Train Loss 0.678878 | Val Loss 0.737299
# Early stopping at epoch 375
# Y | train1 -> R² = 0.8610, MSE = 1.1645e-02
# Y | train2 -> R² = -3.1149, MSE = 4.4309e-01
# Y | test1 -> R² = 0.7571, MSE = 1.9902e-02
# Y | test2 -> R² = -3.0252, MSE = 4.2725e-01
# Y | test3 -> R² = 0.0942, MSE = 6.9575e-02
# Y | val -> R² = 0.2230, MSE = 5.7847e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.204536 | Val Loss 0.786310
# Epoch 100 | Train Loss 0.729443 | Val Loss 0.958717
# Epoch 200 | Train Loss 0.684612 | Val Loss 0.749975
# Epoch 300 | Train Loss 0.668538 | Val Loss 0.655158
# Epoch 400 | Train Loss 0.664339 | Val Loss 0.651837
# Epoch 500 | Train Loss 0.661727 | Val Loss 0.644137
# Epoch 600 | Train Loss 0.659458 | Val Loss 0.643705
# Epoch 700 | Train Loss 0.657375 | Val Loss 0.643929
# Epoch 800 | Train Loss 0.655536 | Val Loss 0.644552
# Early stopping at epoch 832
# Y | train1 -> R² = 0.3091, MSE = 5.7895e-02
# Y | train2 -> R² = -0.5578, MSE = 1.6774e-01
# Y | test1 -> R² = 0.4755, MSE = 4.2980e-02
# Y | test2 -> R² = -0.5703, MSE = 1.6668e-01
# Y | test3 -> R² = -1.6355, MSE = 2.0242e-01
# Y | val -> R² = -1.6896, MSE = 2.0024e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.259258 | Val Loss 0.855273
# Epoch 100 | Train Loss 0.780101 | Val Loss 0.720133
# Epoch 200 | Train Loss 0.691644 | Val Loss 0.751525
# Epoch 300 | Train Loss 0.676766 | Val Loss 0.704783
# Epoch 400 | Train Loss 0.666099 | Val Loss 0.659292
# Epoch 500 | Train Loss 0.663673 | Val Loss 0.659437
# Epoch 600 | Train Loss 0.662056 | Val Loss 0.661343
# Epoch 700 | Train Loss 0.660444 | Val Loss 0.663781
# Early stopping at epoch 718
# Y | train1 -> R² = 0.3068, MSE = 5.8086e-02
# Y | train2 -> R² = -0.5495, MSE = 1.6685e-01
# Y | test1 -> R² = 0.4482, MSE = 4.5220e-02
# Y | test2 -> R² = -0.5665, MSE = 1.6627e-01
# Y | test3 -> R² = -2.1537, MSE = 2.4223e-01
# Y | val -> R² = -2.5300, MSE = 2.6281e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.204862 | Val Loss 0.787963
# Epoch 100 | Train Loss 0.731051 | Val Loss 0.910120
# Epoch 200 | Train Loss 0.689598 | Val Loss 0.788524
# Epoch 300 | Train Loss 0.674296 | Val Loss 0.715789
# Early stopping at epoch 367
# Y | train1 -> R² = 0.7798, MSE = 1.8450e-02
# Y | train2 -> R² = -3.4408, MSE = 4.7818e-01
# Y | test1 -> R² = 0.6565, MSE = 2.8147e-02
# Y | test2 -> R² = -3.3559, MSE = 4.6235e-01
# Y | test3 -> R² = 0.4329, MSE = 4.3560e-02
# Y | val -> R² = 0.5758, MSE = 3.1584e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.234982 | Val Loss 0.799902
# Epoch 100 | Train Loss 0.726755 | Val Loss 0.861068
# Epoch 200 | Train Loss 0.688058 | Val Loss 0.780746
# Epoch 300 | Train Loss 0.677210 | Val Loss 0.742488
# Early stopping at epoch 367
# Y | train1 -> R² = 0.7215, MSE = 2.3338e-02
# Y | train2 -> R² = -3.4955, MSE = 4.8407e-01
# Y | test1 -> R² = 0.5715, MSE = 3.5117e-02
# Y | test2 -> R² = -3.4084, MSE = 4.6792e-01
# Y | test3 -> R² = 0.6238, MSE = 2.8892e-02
# Y | val -> R² = 0.7041, MSE = 2.2027e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.235957 | Val Loss 0.844326
# Epoch 100 | Train Loss 0.747280 | Val Loss 0.859377
# Epoch 200 | Train Loss 0.696582 | Val Loss 0.862205
# Epoch 300 | Train Loss 0.684387 | Val Loss 0.766410
# Early stopping at epoch 374
# Y | train1 -> R² = 0.7256, MSE = 2.2995e-02
# Y | train2 -> R² = -3.4859, MSE = 4.8303e-01
# Y | test1 -> R² = 0.5862, MSE = 3.3914e-02
# Y | test2 -> R² = -3.3948, MSE = 4.6648e-01
# Y | test3 -> R² = 0.4861, MSE = 3.9472e-02
# Y | val -> R² = 0.6126, MSE = 2.8840e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.232889 | Val Loss 0.802379
# Epoch 100 | Train Loss 0.729730 | Val Loss 0.902444
# Epoch 200 | Train Loss 0.692761 | Val Loss 0.808486
# Epoch 300 | Train Loss 0.683367 | Val Loss 0.770810
# Early stopping at epoch 362
# Y | train1 -> R² = 0.6889, MSE = 2.6072e-02
# Y | train2 -> R² = -5.1327, MSE = 6.6036e-01
# Y | test1 -> R² = 0.5279, MSE = 3.8690e-02
# Y | test2 -> R² = -5.0493, MSE = 6.4209e-01
# Y | test3 -> R² = 0.6051, MSE = 3.0330e-02
# Y | val -> R² = 0.7164, MSE = 2.1114e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.247365 | Val Loss 0.832632
# Epoch 100 | Train Loss 0.754502 | Val Loss 0.844143
# Epoch 200 | Train Loss 0.696099 | Val Loss 0.875211
# Epoch 300 | Train Loss 0.679612 | Val Loss 0.766185
# Early stopping at epoch 377
# Y | train1 -> R² = 0.7281, MSE = 2.2786e-02
# Y | train2 -> R² = -3.5880, MSE = 4.9402e-01
# Y | test1 -> R² = 0.5811, MSE = 3.4330e-02
# Y | test2 -> R² = -3.4952, MSE = 4.7713e-01
# Y | test3 -> R² = 0.5985, MSE = 3.0838e-02
# Y | val -> R² = 0.7302, MSE = 2.0087e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.193735 | Val Loss 0.800390
# Epoch 100 | Train Loss 0.732359 | Val Loss 0.926630
# Epoch 200 | Train Loss 0.681937 | Val Loss 0.754549
# Epoch 300 | Train Loss 0.667705 | Val Loss 0.666562
# Epoch 400 | Train Loss 0.663680 | Val Loss 0.658448
# Epoch 500 | Train Loss 0.660947 | Val Loss 0.651200
# Epoch 600 | Train Loss 0.658672 | Val Loss 0.647694
# Epoch 700 | Train Loss 0.656679 | Val Loss 0.651796
# Epoch 800 | Train Loss 0.654806 | Val Loss 0.657904
# Early stopping at epoch 863
# Y | train1 -> R² = 0.3066, MSE = 5.8108e-02
# Y | train2 -> R² = -0.5600, MSE = 1.6798e-01
# Y | test1 -> R² = 0.4902, MSE = 4.1779e-02
# Y | test2 -> R² = -0.5756, MSE = 1.6724e-01
# Y | test3 -> R² = -2.3994, MSE = 2.6110e-01
# Y | val -> R² = -2.3216, MSE = 2.4729e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.250005 | Val Loss 0.830188
# Epoch 100 | Train Loss 0.750257 | Val Loss 0.780996
# Epoch 200 | Train Loss 0.689122 | Val Loss 0.780012
# Epoch 300 | Train Loss 0.680002 | Val Loss 0.756172
# Early stopping at epoch 378
# Y | train1 -> R² = 0.4436, MSE = 4.6626e-02
# Y | train2 -> R² = -2.9859, MSE = 4.2920e-01
# Y | test1 -> R² = 0.2271, MSE = 6.3342e-02
# Y | test2 -> R² = -2.9014, MSE = 4.1410e-01
# Y | test3 -> R² = 0.8834, MSE = 8.9526e-03
# Y | val -> R² = 0.9358, MSE = 4.7782e-03
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.220054 | Val Loss 0.824082
# Epoch 100 | Train Loss 0.736659 | Val Loss 0.934042
# Epoch 200 | Train Loss 0.693455 | Val Loss 0.841440
# Epoch 300 | Train Loss 0.678436 | Val Loss 0.743480
# Early stopping at epoch 370
# Y | train1 -> R² = 0.7024, MSE = 2.4935e-02
# Y | train2 -> R² = -3.5385, MSE = 4.8870e-01
# Y | test1 -> R² = 0.5563, MSE = 3.6362e-02
# Y | test2 -> R² = -3.4460, MSE = 4.7191e-01
# Y | test3 -> R² = 0.5084, MSE = 3.7760e-02
# Y | val -> R² = 0.6256, MSE = 2.7877e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.636583 | Val Loss 0.800151
# Epoch 100 | Train Loss 1.150834 | Val Loss 0.753546
# Epoch 200 | Train Loss 1.052575 | Val Loss 0.684399
# Epoch 300 | Train Loss 1.044636 | Val Loss 0.646560
# Epoch 400 | Train Loss 1.040630 | Val Loss 0.633431
# Epoch 500 | Train Loss 1.037476 | Val Loss 0.623651
# Epoch 600 | Train Loss 1.034274 | Val Loss 0.617410
# Epoch 700 | Train Loss 1.031958 | Val Loss 0.614386
# Epoch 800 | Train Loss 1.030302 | Val Loss 0.614603
# Epoch 900 | Train Loss 1.028643 | Val Loss 0.615901
# Early stopping at epoch 963
# Y | train1 -> R² = 0.8746, MSE = 1.0508e-02
# Y | train2 -> R² = 0.6855, MSE = 3.3864e-02
# Y | test1 -> R² = 0.9063, MSE = 7.6817e-03
# Y | test2 -> R² = 0.6806, MSE = 3.3906e-02
# Y | test3 -> R² = -0.5926, MSE = 1.2232e-01
# Y | val -> R² = -1.0557, MSE = 1.5305e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.599214 | Val Loss 0.808437
# Epoch 100 | Train Loss 1.198385 | Val Loss 0.691611
# Epoch 200 | Train Loss 1.046471 | Val Loss 0.619126
# Epoch 300 | Train Loss 1.039842 | Val Loss 0.617362
# Epoch 400 | Train Loss 1.036925 | Val Loss 0.620781
# Epoch 500 | Train Loss 1.034422 | Val Loss 0.621089
# Early stopping at epoch 533
# Y | train1 -> R² = 0.8909, MSE = 9.1453e-03
# Y | train2 -> R² = 0.6644, MSE = 3.6136e-02
# Y | test1 -> R² = 0.9166, MSE = 6.8333e-03
# Y | test2 -> R² = 0.6550, MSE = 3.6618e-02
# Y | test3 -> R² = -0.8001, MSE = 1.3826e-01
# Y | val -> R² = -1.1099, MSE = 1.5708e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.631404 | Val Loss 0.824666
# Epoch 100 | Train Loss 1.306636 | Val Loss 0.772799
# Epoch 200 | Train Loss 1.089392 | Val Loss 0.616412
# Epoch 300 | Train Loss 1.042863 | Val Loss 0.593271
# Epoch 400 | Train Loss 1.035262 | Val Loss 0.597007
# Epoch 500 | Train Loss 1.033102 | Val Loss 0.599425
# Early stopping at epoch 587
# Y | train1 -> R² = 0.9394, MSE = 5.0745e-03
# Y | train2 -> R² = 0.6689, MSE = 3.5652e-02
# Y | test1 -> R² = 0.9460, MSE = 4.4237e-03
# Y | test2 -> R² = 0.6614, MSE = 3.5939e-02
# Y | test3 -> R² = -0.2295, MSE = 9.4437e-02
# Y | val -> R² = -0.3378, MSE = 9.9597e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.659331 | Val Loss 0.798669
# Epoch 100 | Train Loss 1.282103 | Val Loss 0.753079
# Epoch 200 | Train Loss 1.050611 | Val Loss 0.647914
# Epoch 300 | Train Loss 1.045053 | Val Loss 0.627509
# Epoch 400 | Train Loss 1.041205 | Val Loss 0.621980
# Epoch 500 | Train Loss 1.037311 | Val Loss 0.619390
# Epoch 600 | Train Loss 1.034081 | Val Loss 0.616359
# Epoch 700 | Train Loss 1.031614 | Val Loss 0.616210
# Epoch 800 | Train Loss 1.029526 | Val Loss 0.616583
# Epoch 900 | Train Loss 1.027538 | Val Loss 0.612984
# Epoch 1000 | Train Loss 1.025450 | Val Loss 0.608424
# Epoch 1100 | Train Loss 1.023329 | Val Loss 0.610565
# Epoch 1200 | Train Loss 1.021161 | Val Loss 0.615469
# Early stopping at epoch 1298
# Y | train1 -> R² = 0.8672, MSE = 1.1132e-02
# Y | train2 -> R² = 0.6869, MSE = 3.3714e-02
# Y | test1 -> R² = 0.9088, MSE = 7.4726e-03
# Y | test2 -> R² = 0.6889, MSE = 3.3022e-02
# Y | test3 -> R² = -0.7425, MSE = 1.3384e-01
# Y | val -> R² = -0.9004, MSE = 1.4149e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.617028 | Val Loss 0.831779
# Epoch 100 | Train Loss 1.292952 | Val Loss 0.761646
# Epoch 200 | Train Loss 1.052305 | Val Loss 0.624955
# Epoch 300 | Train Loss 1.043249 | Val Loss 0.617877
# Epoch 400 | Train Loss 1.038854 | Val Loss 0.616684
# Epoch 500 | Train Loss 1.035777 | Val Loss 0.615804
# Epoch 600 | Train Loss 1.033222 | Val Loss 0.614257
# Epoch 700 | Train Loss 1.030999 | Val Loss 0.612733
# Epoch 800 | Train Loss 1.029117 | Val Loss 0.611242
# Epoch 900 | Train Loss 1.027207 | Val Loss 0.608669
# Epoch 1000 | Train Loss 1.025082 | Val Loss 0.606552
# Epoch 1100 | Train Loss 1.022852 | Val Loss 0.608567
# Epoch 1200 | Train Loss 1.020559 | Val Loss 0.614074
# Early stopping at epoch 1246
# Y | train1 -> R² = 0.8675, MSE = 1.1106e-02
# Y | train2 -> R² = 0.6946, MSE = 3.2880e-02
# Y | test1 -> R² = 0.9020, MSE = 8.0309e-03
# Y | test2 -> R² = 0.6959, MSE = 3.2279e-02
# Y | test3 -> R² = -0.6056, MSE = 1.2332e-01
# Y | val -> R² = -1.0323, MSE = 1.5130e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.631119 | Val Loss 0.811305
# Epoch 100 | Train Loss 1.198110 | Val Loss 0.719457
# Epoch 200 | Train Loss 1.049032 | Val Loss 0.657822
# Epoch 300 | Train Loss 1.041208 | Val Loss 0.636666
# Epoch 400 | Train Loss 1.037598 | Val Loss 0.631255
# Epoch 500 | Train Loss 1.035182 | Val Loss 0.625498
# Epoch 600 | Train Loss 1.032885 | Val Loss 0.620301
# Epoch 700 | Train Loss 1.031193 | Val Loss 0.617814
# Epoch 800 | Train Loss 1.029899 | Val Loss 0.616801
# Epoch 900 | Train Loss 1.028568 | Val Loss 0.615395
# Epoch 1000 | Train Loss 1.026932 | Val Loss 0.613224
# Epoch 1100 | Train Loss 1.024784 | Val Loss 0.610656
# Epoch 1200 | Train Loss 1.022151 | Val Loss 0.607880
# Epoch 1300 | Train Loss 1.019071 | Val Loss 0.607074
# Epoch 1400 | Train Loss 1.015855 | Val Loss 0.610186
# Epoch 1500 | Train Loss 1.012295 | Val Loss 0.610937
# Early stopping at epoch 1556
# Y | train1 -> R² = 0.8674, MSE = 1.1109e-02
# Y | train2 -> R² = 0.6915, MSE = 3.3214e-02
# Y | test1 -> R² = 0.9123, MSE = 7.1838e-03
# Y | test2 -> R² = 0.6950, MSE = 3.2373e-02
# Y | test3 -> R² = 0.0253, MSE = 7.4866e-02
# Y | val -> R² = -0.1085, MSE = 8.2527e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.606728 | Val Loss 0.815620
# Epoch 100 | Train Loss 1.270660 | Val Loss 0.746462
# Epoch 200 | Train Loss 1.087198 | Val Loss 0.618730
# Epoch 300 | Train Loss 1.049798 | Val Loss 0.595255
# Epoch 400 | Train Loss 1.038928 | Val Loss 0.592216
# Epoch 500 | Train Loss 1.036069 | Val Loss 0.593941
# Epoch 600 | Train Loss 1.034628 | Val Loss 0.594874
# Early stopping at epoch 618
# Y | train1 -> R² = 0.9234, MSE = 6.4192e-03
# Y | train2 -> R² = 0.6609, MSE = 3.6513e-02
# Y | test1 -> R² = 0.9249, MSE = 6.1507e-03
# Y | test2 -> R² = 0.6516, MSE = 3.6979e-02
# Y | test3 -> R² = -0.4443, MSE = 1.1093e-01
# Y | val -> R² = -0.7126, MSE = 1.2751e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.612079 | Val Loss 0.803909
# Epoch 100 | Train Loss 1.168559 | Val Loss 0.711206
# Epoch 200 | Train Loss 1.046089 | Val Loss 0.641245
# Epoch 300 | Train Loss 1.040806 | Val Loss 0.626412
# Epoch 400 | Train Loss 1.038689 | Val Loss 0.625721
# Epoch 500 | Train Loss 1.037010 | Val Loss 0.624693
# Epoch 600 | Train Loss 1.035135 | Val Loss 0.621584
# Epoch 700 | Train Loss 1.033359 | Val Loss 0.616109
# Epoch 800 | Train Loss 1.031775 | Val Loss 0.611461
# Epoch 900 | Train Loss 1.030180 | Val Loss 0.608518
# Epoch 1000 | Train Loss 1.028559 | Val Loss 0.606528
# Epoch 1100 | Train Loss 1.026868 | Val Loss 0.605394
# Epoch 1200 | Train Loss 1.025066 | Val Loss 0.605154
# Epoch 1300 | Train Loss 1.022875 | Val Loss 0.607770
# Early stopping at epoch 1386
# Y | train1 -> R² = 0.8635, MSE = 1.1436e-02
# Y | train2 -> R² = 0.6785, MSE = 3.4618e-02
# Y | test1 -> R² = 0.9064, MSE = 7.6664e-03
# Y | test2 -> R² = 0.6820, MSE = 3.3755e-02
# Y | test3 -> R² = -0.6094, MSE = 1.2361e-01
# Y | val -> R² = -1.0403, MSE = 1.5190e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.694847 | Val Loss 0.813316
# Epoch 100 | Train Loss 1.218444 | Val Loss 0.733693
# Epoch 200 | Train Loss 1.050492 | Val Loss 0.664370
# Epoch 300 | Train Loss 1.042348 | Val Loss 0.633751
# Epoch 400 | Train Loss 1.039442 | Val Loss 0.625951
# Epoch 500 | Train Loss 1.037215 | Val Loss 0.621658
# Epoch 600 | Train Loss 1.035131 | Val Loss 0.617256
# Epoch 700 | Train Loss 1.033169 | Val Loss 0.614108
# Epoch 800 | Train Loss 1.031450 | Val Loss 0.611215
# Epoch 900 | Train Loss 1.029917 | Val Loss 0.608785
# Epoch 1000 | Train Loss 1.028406 | Val Loss 0.607355
# Epoch 1100 | Train Loss 1.026809 | Val Loss 0.608760
# Epoch 1200 | Train Loss 1.025071 | Val Loss 0.614981
# Early stopping at epoch 1236
# Y | train1 -> R² = 0.8666, MSE = 1.1178e-02
# Y | train2 -> R² = 0.6795, MSE = 3.4509e-02
# Y | test1 -> R² = 0.9001, MSE = 8.1891e-03
# Y | test2 -> R² = 0.6778, MSE = 3.4200e-02
# Y | test3 -> R² = -0.7750, MSE = 1.3633e-01
# Y | val -> R² = -1.3144, MSE = 1.7231e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.623065 | Val Loss 0.838309
# Epoch 100 | Train Loss 1.193027 | Val Loss 0.722187
# Epoch 200 | Train Loss 1.050659 | Val Loss 0.649598
# Epoch 300 | Train Loss 1.044102 | Val Loss 0.631883
# Epoch 400 | Train Loss 1.040215 | Val Loss 0.627794
# Epoch 500 | Train Loss 1.037602 | Val Loss 0.620132
# Epoch 600 | Train Loss 1.035335 | Val Loss 0.609865
# Epoch 700 | Train Loss 1.033005 | Val Loss 0.598732
# Epoch 800 | Train Loss 1.031182 | Val Loss 0.591801
# Epoch 900 | Train Loss 1.029575 | Val Loss 0.587462
# Epoch 1000 | Train Loss 1.027903 | Val Loss 0.584099
# Epoch 1100 | Train Loss 1.026105 | Val Loss 0.581725
# Epoch 1200 | Train Loss 1.024169 | Val Loss 0.579747
# Epoch 1300 | Train Loss 1.021974 | Val Loss 0.579126
# Epoch 1400 | Train Loss 1.019151 | Val Loss 0.581577
# Epoch 1500 | Train Loss 1.015649 | Val Loss 0.585582
# Early stopping at epoch 1567
# Y | train1 -> R² = 0.8690, MSE = 1.0981e-02
# Y | train2 -> R² = 0.6853, MSE = 3.3886e-02
# Y | test1 -> R² = 0.9144, MSE = 7.0129e-03
# Y | test2 -> R² = 0.6875, MSE = 3.3174e-02
# Y | test3 -> R² = 0.6441, MSE = 2.7333e-02
# Y | val -> R² = 0.4771, MSE = 3.8932e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.602037 | Val Loss 0.786191
# Epoch 100 | Train Loss 1.177116 | Val Loss 0.680489
# Epoch 200 | Train Loss 1.046700 | Val Loss 0.624352
# Epoch 300 | Train Loss 1.041272 | Val Loss 0.610397
# Epoch 400 | Train Loss 1.038565 | Val Loss 0.607968
# Epoch 500 | Train Loss 1.036876 | Val Loss 0.607779
# Epoch 600 | Train Loss 1.034820 | Val Loss 0.606461
# Epoch 700 | Train Loss 1.032418 | Val Loss 0.604457
# Epoch 800 | Train Loss 1.030413 | Val Loss 0.604558
# Epoch 900 | Train Loss 1.028650 | Val Loss 0.605954
# Early stopping at epoch 984
# Y | train1 -> R² = 0.8718, MSE = 1.0745e-02
# Y | train2 -> R² = 0.6781, MSE = 3.4659e-02
# Y | test1 -> R² = 0.9030, MSE = 7.9466e-03
# Y | test2 -> R² = 0.6732, MSE = 3.4688e-02
# Y | test3 -> R² = -0.5705, MSE = 1.2063e-01
# Y | val -> R² = -1.1427, MSE = 1.5953e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.644421 | Val Loss 0.857238
# Epoch 100 | Train Loss 1.337631 | Val Loss 0.799033
# Epoch 200 | Train Loss 1.092404 | Val Loss 0.618837
# Epoch 300 | Train Loss 1.049360 | Val Loss 0.598270
# Epoch 400 | Train Loss 1.037219 | Val Loss 0.600083
# Epoch 500 | Train Loss 1.034580 | Val Loss 0.603077
# Early stopping at epoch 598
# Y | train1 -> R² = 0.9378, MSE = 5.2107e-03
# Y | train2 -> R² = 0.6562, MSE = 3.7023e-02
# Y | test1 -> R² = 0.9412, MSE = 4.8179e-03
# Y | test2 -> R² = 0.6499, MSE = 3.7162e-02
# Y | test3 -> R² = -0.3662, MSE = 1.0493e-01
# Y | val -> R² = -0.4157, MSE = 1.0540e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.580788 | Val Loss 0.794492
# Epoch 100 | Train Loss 1.247781 | Val Loss 0.738970
# Epoch 200 | Train Loss 1.067001 | Val Loss 0.615353
# Epoch 300 | Train Loss 1.040992 | Val Loss 0.602926
# Epoch 400 | Train Loss 1.037012 | Val Loss 0.604103
# Epoch 500 | Train Loss 1.034835 | Val Loss 0.601786
# Early stopping at epoch 547
# Y | train1 -> R² = 0.9406, MSE = 4.9780e-03
# Y | train2 -> R² = 0.6563, MSE = 3.7005e-02
# Y | test1 -> R² = 0.9500, MSE = 4.0980e-03
# Y | test2 -> R² = 0.6491, MSE = 3.7249e-02
# Y | test3 -> R² = -0.5136, MSE = 1.1626e-01
# Y | val -> R² = -0.6780, MSE = 1.2493e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.637083 | Val Loss 0.818252
# Epoch 100 | Train Loss 1.321487 | Val Loss 0.771182
# Epoch 200 | Train Loss 1.050064 | Val Loss 0.644530
# Epoch 300 | Train Loss 1.042384 | Val Loss 0.626457
# Epoch 400 | Train Loss 1.038306 | Val Loss 0.621791
# Epoch 500 | Train Loss 1.035502 | Val Loss 0.617796
# Epoch 600 | Train Loss 1.032717 | Val Loss 0.613437
# Epoch 700 | Train Loss 1.030230 | Val Loss 0.609926
# Epoch 800 | Train Loss 1.028027 | Val Loss 0.611009
# Epoch 900 | Train Loss 1.025555 | Val Loss 0.613728
# Early stopping at epoch 967
# Y | train1 -> R² = 0.8759, MSE = 1.0398e-02
# Y | train2 -> R² = 0.6851, MSE = 3.3912e-02
# Y | test1 -> R² = 0.9054, MSE = 7.7506e-03
# Y | test2 -> R² = 0.6814, MSE = 3.3821e-02
# Y | test3 -> R² = -0.9126, MSE = 1.4690e-01
# Y | val -> R² = -1.4344, MSE = 1.8124e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.606073 | Val Loss 0.823198
# Epoch 100 | Train Loss 1.271864 | Val Loss 0.752418
# Epoch 200 | Train Loss 1.049584 | Val Loss 0.635886
# Epoch 300 | Train Loss 1.042485 | Val Loss 0.624308
# Epoch 400 | Train Loss 1.038264 | Val Loss 0.624357
# Epoch 500 | Train Loss 1.036047 | Val Loss 0.618029
# Epoch 600 | Train Loss 1.034279 | Val Loss 0.611118
# Epoch 700 | Train Loss 1.032460 | Val Loss 0.605325
# Epoch 800 | Train Loss 1.030862 | Val Loss 0.600606
# Epoch 900 | Train Loss 1.029580 | Val Loss 0.596950
# Epoch 1000 | Train Loss 1.028279 | Val Loss 0.594144
# Epoch 1100 | Train Loss 1.026844 | Val Loss 0.592514
# Epoch 1200 | Train Loss 1.025174 | Val Loss 0.592757
# Epoch 1300 | Train Loss 1.023202 | Val Loss 0.594809
# Early stopping at epoch 1387
# Y | train1 -> R² = 0.8655, MSE = 1.1273e-02
# Y | train2 -> R² = 0.6893, MSE = 3.3460e-02
# Y | test1 -> R² = 0.9049, MSE = 7.7927e-03
# Y | test2 -> R² = 0.6875, MSE = 3.3175e-02
# Y | test3 -> R² = -0.2260, MSE = 9.4168e-02
# Y | val -> R² = -0.5840, MSE = 1.1793e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.457694 | Val Loss 0.808113
# Epoch 100 | Train Loss 0.937430 | Val Loss 0.832593
# Epoch 200 | Train Loss 0.925413 | Val Loss 0.750302
# Epoch 300 | Train Loss 0.912655 | Val Loss 0.654915
# Epoch 400 | Train Loss 0.902385 | Val Loss 0.632459
# Epoch 500 | Train Loss 0.899972 | Val Loss 0.630462
# Epoch 600 | Train Loss 0.898403 | Val Loss 0.627557
# Epoch 700 | Train Loss 0.897004 | Val Loss 0.626412
# Epoch 800 | Train Loss 0.895599 | Val Loss 0.629153
# Epoch 900 | Train Loss 0.893985 | Val Loss 0.633523
# Early stopping at epoch 939
# Y | train1 -> R² = 0.6417, MSE = 3.0023e-02
# Y | train2 -> R² = 0.1731, MSE = 8.9037e-02
# Y | test1 -> R² = 0.7470, MSE = 2.0733e-02
# Y | test2 -> R² = 0.1712, MSE = 8.7969e-02
# Y | test3 -> R² = -1.5207, MSE = 1.9361e-01
# Y | val -> R² = -1.6814, MSE = 1.9963e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.572871 | Val Loss 0.894358
# Epoch 100 | Train Loss 0.947641 | Val Loss 0.906214
# Epoch 200 | Train Loss 0.931985 | Val Loss 0.818587
# Epoch 300 | Train Loss 0.913361 | Val Loss 0.673768
# Epoch 400 | Train Loss 0.904120 | Val Loss 0.640276
# Epoch 500 | Train Loss 0.901232 | Val Loss 0.640632
# Epoch 600 | Train Loss 0.899403 | Val Loss 0.630847
# Epoch 700 | Train Loss 0.897965 | Val Loss 0.624590
# Epoch 800 | Train Loss 0.896443 | Val Loss 0.621725
# Epoch 900 | Train Loss 0.894920 | Val Loss 0.623946
# Epoch 1000 | Train Loss 0.893278 | Val Loss 0.626557
# Early stopping at epoch 1054
# Y | train1 -> R² = 0.6435, MSE = 2.9875e-02
# Y | train2 -> R² = 0.1691, MSE = 8.9466e-02
# Y | test1 -> R² = 0.7282, MSE = 2.2273e-02
# Y | test2 -> R² = 0.1674, MSE = 8.8377e-02
# Y | test3 -> R² = -1.2416, MSE = 1.7217e-01
# Y | val -> R² = -1.3359, MSE = 1.7390e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.480109 | Val Loss 0.838451
# Epoch 100 | Train Loss 0.939457 | Val Loss 0.860193
# Epoch 200 | Train Loss 0.924229 | Val Loss 0.762379
# Epoch 300 | Train Loss 0.905747 | Val Loss 0.643935
# Epoch 400 | Train Loss 0.902422 | Val Loss 0.644188
# Epoch 500 | Train Loss 0.900335 | Val Loss 0.637672
# Epoch 600 | Train Loss 0.898123 | Val Loss 0.631010
# Epoch 700 | Train Loss 0.896142 | Val Loss 0.626271
# Epoch 800 | Train Loss 0.894375 | Val Loss 0.624684
# Epoch 900 | Train Loss 0.892881 | Val Loss 0.625314
# Epoch 1000 | Train Loss 0.891565 | Val Loss 0.626250
# Epoch 1100 | Train Loss 0.890291 | Val Loss 0.628210
# Early stopping at epoch 1167
# Y | train1 -> R² = 0.6256, MSE = 3.1371e-02
# Y | train2 -> R² = 0.1309, MSE = 9.3583e-02
# Y | test1 -> R² = 0.7285, MSE = 2.2245e-02
# Y | test2 -> R² = 0.1109, MSE = 9.4369e-02
# Y | test3 -> R² = -0.8796, MSE = 1.4436e-01
# Y | val -> R² = -1.2081, MSE = 1.6439e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.480682 | Val Loss 0.850730
# Epoch 100 | Train Loss 0.939535 | Val Loss 0.876665
# Epoch 200 | Train Loss 0.930213 | Val Loss 0.837881
# Epoch 300 | Train Loss 0.913422 | Val Loss 0.698988
# Epoch 400 | Train Loss 0.903320 | Val Loss 0.641008
# Epoch 500 | Train Loss 0.901056 | Val Loss 0.633611
# Epoch 600 | Train Loss 0.899583 | Val Loss 0.628738
# Epoch 700 | Train Loss 0.898355 | Val Loss 0.627059
# Epoch 800 | Train Loss 0.897165 | Val Loss 0.628911
# Epoch 900 | Train Loss 0.896011 | Val Loss 0.630026
# Epoch 1000 | Train Loss 0.894853 | Val Loss 0.630701
# Early stopping at epoch 1080
# Y | train1 -> R² = 0.6295, MSE = 3.1049e-02
# Y | train2 -> R² = 0.1482, MSE = 9.1724e-02
# Y | test1 -> R² = 0.7398, MSE = 2.1322e-02
# Y | test2 -> R² = 0.1276, MSE = 9.2595e-02
# Y | test3 -> R² = -1.5466, MSE = 1.9560e-01
# Y | val -> R² = -1.6826, MSE = 1.9972e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.424487 | Val Loss 0.795715
# Epoch 100 | Train Loss 0.937937 | Val Loss 0.831618
# Epoch 200 | Train Loss 0.918224 | Val Loss 0.717078
# Epoch 300 | Train Loss 0.904549 | Val Loss 0.636571
# Epoch 400 | Train Loss 0.901085 | Val Loss 0.632662
# Epoch 500 | Train Loss 0.899034 | Val Loss 0.625116
# Epoch 600 | Train Loss 0.897426 | Val Loss 0.622816
# Epoch 700 | Train Loss 0.895995 | Val Loss 0.625450
# Epoch 800 | Train Loss 0.894603 | Val Loss 0.630171
# Early stopping at epoch 866
# Y | train1 -> R² = 0.6360, MSE = 3.0504e-02
# Y | train2 -> R² = 0.1772, MSE = 8.8595e-02
# Y | test1 -> R² = 0.7405, MSE = 2.1267e-02
# Y | test2 -> R² = 0.1685, MSE = 8.8258e-02
# Y | test3 -> R² = -1.4947, MSE = 1.9161e-01
# Y | val -> R² = -1.7329, MSE = 2.0347e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.483876 | Val Loss 0.796246
# Epoch 100 | Train Loss 0.938483 | Val Loss 0.853301
# Epoch 200 | Train Loss 0.927062 | Val Loss 0.797338
# Epoch 300 | Train Loss 0.912017 | Val Loss 0.677600
# Epoch 400 | Train Loss 0.903339 | Val Loss 0.648594
# Epoch 500 | Train Loss 0.900972 | Val Loss 0.645000
# Epoch 600 | Train Loss 0.899152 | Val Loss 0.637539
# Epoch 700 | Train Loss 0.897232 | Val Loss 0.632342
# Epoch 800 | Train Loss 0.895220 | Val Loss 0.631483
# Epoch 900 | Train Loss 0.892681 | Val Loss 0.632305
# Epoch 1000 | Train Loss 0.889606 | Val Loss 0.633498
# Epoch 1100 | Train Loss 0.886874 | Val Loss 0.628039
# Epoch 1200 | Train Loss 0.884769 | Val Loss 0.624308
# Epoch 1300 | Train Loss 0.882840 | Val Loss 0.622902
# Epoch 1400 | Train Loss 0.880700 | Val Loss 0.620806
# Epoch 1500 | Train Loss 0.878348 | Val Loss 0.616964
# Epoch 1600 | Train Loss 0.875674 | Val Loss 0.617710
# Epoch 1700 | Train Loss 0.873142 | Val Loss 0.621819
# Early stopping at epoch 1800
# Y | train1 -> R² = 0.6416, MSE = 3.0032e-02
# Y | train2 -> R² = 0.1468, MSE = 9.1872e-02
# Y | test1 -> R² = 0.7556, MSE = 2.0026e-02
# Y | test2 -> R² = 0.1308, MSE = 9.2256e-02
# Y | test3 -> R² = 0.3080, MSE = 5.3151e-02
# Y | val -> R² = 0.1556, MSE = 6.2867e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.608484 | Val Loss 0.890559
# Epoch 100 | Train Loss 0.946742 | Val Loss 0.849524
# Epoch 200 | Train Loss 0.926737 | Val Loss 0.749520
# Epoch 300 | Train Loss 0.908883 | Val Loss 0.643450
# Epoch 400 | Train Loss 0.904317 | Val Loss 0.641879
# Epoch 500 | Train Loss 0.901304 | Val Loss 0.632642
# Epoch 600 | Train Loss 0.899213 | Val Loss 0.621037
# Epoch 700 | Train Loss 0.897766 | Val Loss 0.615261
# Epoch 800 | Train Loss 0.896630 | Val Loss 0.613952
# Epoch 900 | Train Loss 0.895592 | Val Loss 0.614133
# Epoch 1000 | Train Loss 0.894561 | Val Loss 0.614942
# Epoch 1100 | Train Loss 0.893467 | Val Loss 0.616712
# Early stopping at epoch 1171
# Y | train1 -> R² = 0.6307, MSE = 3.0947e-02
# Y | train2 -> R² = 0.1699, MSE = 8.9380e-02
# Y | test1 -> R² = 0.7309, MSE = 2.2050e-02
# Y | test2 -> R² = 0.1576, MSE = 8.9410e-02
# Y | test3 -> R² = -0.3851, MSE = 1.0639e-01
# Y | val -> R² = -0.5165, MSE = 1.1290e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.454639 | Val Loss 0.804002
# Epoch 100 | Train Loss 0.938855 | Val Loss 0.863146
# Epoch 200 | Train Loss 0.928405 | Val Loss 0.808406
# Epoch 300 | Train Loss 0.908271 | Val Loss 0.659895
# Epoch 400 | Train Loss 0.902794 | Val Loss 0.648462
# Epoch 500 | Train Loss 0.900425 | Val Loss 0.639460
# Epoch 600 | Train Loss 0.898730 | Val Loss 0.633206
# Epoch 700 | Train Loss 0.897310 | Val Loss 0.630959
# Epoch 800 | Train Loss 0.896033 | Val Loss 0.630695
# Epoch 900 | Train Loss 0.895180 | Val Loss 0.633217
# Epoch 1000 | Train Loss 0.893638 | Val Loss 0.632926
# Early stopping at epoch 1022
# Y | train1 -> R² = 0.6122, MSE = 3.2497e-02
# Y | train2 -> R² = 0.1400, MSE = 9.2602e-02
# Y | test1 -> R² = 0.7074, MSE = 2.3980e-02
# Y | test2 -> R² = 0.1161, MSE = 9.3816e-02
# Y | test3 -> R² = -1.2533, MSE = 1.7307e-01
# Y | val -> R² = -1.4325, MSE = 1.8110e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.613943 | Val Loss 0.918097
# Epoch 100 | Train Loss 0.947189 | Val Loss 0.936823
# Epoch 200 | Train Loss 0.931062 | Val Loss 0.814298
# Epoch 300 | Train Loss 0.910400 | Val Loss 0.670206
# Epoch 400 | Train Loss 0.904870 | Val Loss 0.643777
# Epoch 500 | Train Loss 0.901945 | Val Loss 0.648077
# Epoch 600 | Train Loss 0.899953 | Val Loss 0.641692
# Epoch 700 | Train Loss 0.898330 | Val Loss 0.637068
# Epoch 800 | Train Loss 0.896996 | Val Loss 0.635468
# Epoch 900 | Train Loss 0.895584 | Val Loss 0.632806
# Epoch 1000 | Train Loss 0.894440 | Val Loss 0.632304
# Epoch 1100 | Train Loss 0.893412 | Val Loss 0.633601
# Epoch 1200 | Train Loss 0.892501 | Val Loss 0.636514
# Early stopping at epoch 1259
# Y | train1 -> R² = 0.6395, MSE = 3.0205e-02
# Y | train2 -> R² = 0.1608, MSE = 9.0363e-02
# Y | test1 -> R² = 0.7289, MSE = 2.2218e-02
# Y | test2 -> R² = 0.1511, MSE = 9.0103e-02
# Y | test3 -> R² = -1.1484, MSE = 1.6501e-01
# Y | val -> R² = -1.0674, MSE = 1.5392e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.438896 | Val Loss 0.814084
# Epoch 100 | Train Loss 0.939389 | Val Loss 0.820434
# Epoch 200 | Train Loss 0.919434 | Val Loss 0.704826
# Epoch 300 | Train Loss 0.905600 | Val Loss 0.645747
# Epoch 400 | Train Loss 0.902455 | Val Loss 0.645820
# Epoch 500 | Train Loss 0.900304 | Val Loss 0.638722
# Epoch 600 | Train Loss 0.898621 | Val Loss 0.635003
# Epoch 700 | Train Loss 0.897030 | Val Loss 0.633550
# Epoch 800 | Train Loss 0.895526 | Val Loss 0.632938
# Epoch 900 | Train Loss 0.893914 | Val Loss 0.632434
# Epoch 1000 | Train Loss 0.892072 | Val Loss 0.631047
# Epoch 1100 | Train Loss 0.890023 | Val Loss 0.624853
# Epoch 1200 | Train Loss 0.887895 | Val Loss 0.612802
# Epoch 1300 | Train Loss 0.885534 | Val Loss 0.603667
# Epoch 1400 | Train Loss 0.884101 | Val Loss 0.598221
# Epoch 1500 | Train Loss 0.881171 | Val Loss 0.597720
# Epoch 1600 | Train Loss 0.879039 | Val Loss 0.599598
# Epoch 1700 | Train Loss 0.877100 | Val Loss 0.602706
# Early stopping at epoch 1741
# Y | train1 -> R² = 0.6437, MSE = 2.9852e-02
# Y | train2 -> R² = 0.1679, MSE = 8.9594e-02
# Y | test1 -> R² = 0.8200, MSE = 1.4751e-02
# Y | test2 -> R² = 0.1666, MSE = 8.8458e-02
# Y | test3 -> R² = -0.1206, MSE = 8.6069e-02
# Y | val -> R² = 0.2864, MSE = 5.3125e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.448613 | Val Loss 0.799759
# Epoch 100 | Train Loss 0.937736 | Val Loss 0.863008
# Epoch 200 | Train Loss 0.927293 | Val Loss 0.811039
# Epoch 300 | Train Loss 0.913196 | Val Loss 0.684678
# Epoch 400 | Train Loss 0.902840 | Val Loss 0.641312
# Epoch 500 | Train Loss 0.900413 | Val Loss 0.633688
# Epoch 600 | Train Loss 0.898694 | Val Loss 0.625949
# Epoch 700 | Train Loss 0.897319 | Val Loss 0.624542
# Epoch 800 | Train Loss 0.896124 | Val Loss 0.626270
# Epoch 900 | Train Loss 0.894960 | Val Loss 0.629274
# Early stopping at epoch 939
# Y | train1 -> R² = 0.6363, MSE = 3.0474e-02
# Y | train2 -> R² = 0.1717, MSE = 8.9188e-02
# Y | test1 -> R² = 0.7323, MSE = 2.1937e-02
# Y | test2 -> R² = 0.1545, MSE = 8.9749e-02
# Y | test3 -> R² = -1.4424, MSE = 1.8759e-01
# Y | val -> R² = -1.7604, MSE = 2.0551e-01
# ...
# Epoch 900 | Train Loss 0.875914 | Val Loss 0.636647
# Epoch 1000 | Train Loss 0.872960 | Val Loss 0.660441
# Early stopping at epoch 1031
# Y | train1 -> R² = 0.8214, MSE = 1.4966e-02
# Y | train2 -> R² = -0.2967, MSE = 1.3963e-01
# Y | test1 -> R² = 0.8978, MSE = 8.3745e-03
# Y | test2 -> R² = -0.3740, MSE = 1.4584e-01
# Y | test3 -> R² = -0.1238, MSE = 8.6317e-02
# Y | val -> R² = -0.3924, MSE = 1.0366e-01
# Modelo [264, 128] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.297835 | Val Loss 0.677001
# Epoch 100 | Train Loss 0.686402 | Val Loss 0.808059
# Epoch 200 | Train Loss 0.663516 | Val Loss 0.671733
# Epoch 300 | Train Loss 0.659011 | Val Loss 0.673554
# Epoch 400 | Train Loss 0.654775 | Val Loss 0.661596
# Epoch 500 | Train Loss 0.651232 | Val Loss 0.666874
# Epoch 600 | Train Loss 0.649059 | Val Loss 0.656900
# Early stopping at epoch 603
# Y | train1 -> R² = 0.4217, MSE = 4.8460e-02
# Y | train2 -> R² = -1.6846, MSE = 2.8908e-01
# Y | test1 -> R² = 0.5982, MSE = 3.2924e-02
# Y | test2 -> R² = -1.8362, MSE = 3.0104e-01
# Y | test3 -> R² = -2.0029, MSE = 2.3065e-01
# Y | val -> R² = -2.1409, MSE = 2.3384e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.219567 | Val Loss 0.693594
# Epoch 100 | Train Loss 0.682012 | Val Loss 0.780536
# Epoch 200 | Train Loss 0.661396 | Val Loss 0.683396
# Epoch 300 | Train Loss 0.657430 | Val Loss 0.677757
# Epoch 400 | Train Loss 0.653433 | Val Loss 0.671040
# Epoch 500 | Train Loss 0.650289 | Val Loss 0.674058
# Epoch 600 | Train Loss 0.647971 | Val Loss 0.692332
# Epoch 700 | Train Loss 0.645039 | Val Loss 0.718759
# Early stopping at epoch 728
# Y | train1 -> R² = 0.5486, MSE = 3.7828e-02
# Y | train2 -> R² = -1.0759, MSE = 2.2353e-01
# Y | test1 -> R² = 0.7051, MSE = 2.4163e-02
# Y | test2 -> R² = -1.1531, MSE = 2.2853e-01
# Y | test3 -> R² = -1.8121, MSE = 2.1599e-01
# Y | val -> R² = -2.0270, MSE = 2.2536e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.172929 | Val Loss 0.688120
# Epoch 100 | Train Loss 0.686518 | Val Loss 0.813425
# Epoch 200 | Train Loss 0.666324 | Val Loss 0.715674
# Epoch 300 | Train Loss 0.659040 | Val Loss 0.678759
# Early stopping at epoch 317
# Y | train1 -> R² = 0.5431, MSE = 3.8288e-02
# Y | train2 -> R² = -7.1802, MSE = 8.8083e-01
# Y | test1 -> R² = 0.3103, MSE = 5.6519e-02
# Y | test2 -> R² = -7.0878, MSE = 8.5846e-01
# Y | test3 -> R² = 0.7290, MSE = 2.0812e-02
# Y | val -> R² = 0.8148, MSE = 1.3785e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.217777 | Val Loss 0.701113
# Epoch 100 | Train Loss 0.689525 | Val Loss 0.808974
# Epoch 200 | Train Loss 0.663445 | Val Loss 0.693897
# Epoch 300 | Train Loss 0.658708 | Val Loss 0.671058
# Epoch 400 | Train Loss 0.655111 | Val Loss 0.666410
# Epoch 500 | Train Loss 0.652286 | Val Loss 0.667164
# Epoch 600 | Train Loss 0.649437 | Val Loss 0.670268
# Epoch 700 | Train Loss 0.646911 | Val Loss 0.678208
# Epoch 800 | Train Loss 0.643881 | Val Loss 0.680162
# Epoch 900 | Train Loss 0.640984 | Val Loss 0.681273
# Early stopping at epoch 940
# Y | train1 -> R² = 0.7909, MSE = 1.7522e-02
# Y | train2 -> R² = -1.9566, MSE = 3.1836e-01
# Y | test1 -> R² = 0.8510, MSE = 1.2210e-02
# Y | test2 -> R² = -2.0823, MSE = 3.2716e-01
# Y | test3 -> R² = -0.4855, MSE = 1.1410e-01
# Y | val -> R² = -0.3940, MSE = 1.0378e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.167362 | Val Loss 0.852255
# Epoch 100 | Train Loss 0.683638 | Val Loss 0.802052
# Epoch 200 | Train Loss 0.663639 | Val Loss 0.675352
# Epoch 300 | Train Loss 0.659789 | Val Loss 0.663790
# Epoch 400 | Train Loss 0.659656 | Val Loss 0.654013
# Epoch 500 | Train Loss 0.652680 | Val Loss 0.656995
# Epoch 600 | Train Loss 0.649711 | Val Loss 0.652334
# Epoch 700 | Train Loss 0.646572 | Val Loss 0.656414
# Epoch 800 | Train Loss 0.643373 | Val Loss 0.661969
# Early stopping at epoch 824
# Y | train1 -> R² = 0.5638, MSE = 3.6551e-02
# Y | train2 -> R² = -1.3129, MSE = 2.4905e-01
# Y | test1 -> R² = 0.7285, MSE = 2.2253e-02
# Y | test2 -> R² = -1.4113, MSE = 2.5594e-01
# Y | test3 -> R² = -0.7503, MSE = 1.3444e-01
# Y | val -> R² = -0.9435, MSE = 1.4469e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.260239 | Val Loss 0.671565
# Epoch 100 | Train Loss 0.690267 | Val Loss 0.832973
# Epoch 200 | Train Loss 0.664483 | Val Loss 0.663052
# Epoch 300 | Train Loss 0.658829 | Val Loss 0.659249
# Epoch 400 | Train Loss 0.655712 | Val Loss 0.649748
# Epoch 500 | Train Loss 0.653002 | Val Loss 0.646384
# Epoch 600 | Train Loss 0.650629 | Val Loss 0.645773
# Epoch 700 | Train Loss 0.647809 | Val Loss 0.648708
# Epoch 800 | Train Loss 0.645118 | Val Loss 0.657432
# Early stopping at epoch 858
# Y | train1 -> R² = 0.7646, MSE = 1.9729e-02
# Y | train2 -> R² = -2.0487, MSE = 3.2828e-01
# Y | test1 -> R² = 0.8526, MSE = 1.2076e-02
# Y | test2 -> R² = -2.1798, MSE = 3.3752e-01
# Y | test3 -> R² = 0.4260, MSE = 4.4089e-02
# Y | val -> R² = 0.3622, MSE = 4.7485e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.309404 | Val Loss 0.690292
# Epoch 100 | Train Loss 0.680668 | Val Loss 0.778571
# Epoch 200 | Train Loss 0.661387 | Val Loss 0.667367
# Epoch 300 | Train Loss 0.657443 | Val Loss 0.661565
# Epoch 400 | Train Loss 0.654224 | Val Loss 0.655581
# Epoch 500 | Train Loss 0.651144 | Val Loss 0.654740
# Epoch 600 | Train Loss 0.648592 | Val Loss 0.650711
# Epoch 700 | Train Loss 0.646329 | Val Loss 0.657911
# Epoch 800 | Train Loss 0.642224 | Val Loss 0.676794
# Early stopping at epoch 830
# Y | train1 -> R² = 0.5600, MSE = 3.6868e-02
# Y | train2 -> R² = -1.3141, MSE = 2.4918e-01
# Y | test1 -> R² = 0.7326, MSE = 2.1911e-02
# Y | test2 -> R² = -1.4063, MSE = 2.5541e-01
# Y | test3 -> R² = -0.5506, MSE = 1.1910e-01
# Y | val -> R² = -0.6746, MSE = 1.2467e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.165515 | Val Loss 0.729701
# Epoch 100 | Train Loss 0.691522 | Val Loss 0.825891
# Epoch 200 | Train Loss 0.663185 | Val Loss 0.685391
# Epoch 300 | Train Loss 0.659057 | Val Loss 0.673063
# Early stopping at epoch 307
# Y | train1 -> R² = 0.5921, MSE = 3.4180e-02
# Y | train2 -> R² = -16.7226, MSE = 1.9083e+00
# Y | test1 -> R² = 0.4915, MSE = 4.1674e-02
# Y | test2 -> R² = -16.7207, MSE = 1.8809e+00
# Y | test3 -> R² = 0.7414, MSE = 1.9860e-02
# Y | val -> R² = 0.7136, MSE = 2.1320e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.226028 | Val Loss 0.691648
# Epoch 100 | Train Loss 0.691274 | Val Loss 0.828856
# Epoch 200 | Train Loss 0.663388 | Val Loss 0.673698
# Epoch 300 | Train Loss 0.659969 | Val Loss 0.656766
# Epoch 400 | Train Loss 0.655656 | Val Loss 0.655086
# Epoch 500 | Train Loss 0.653937 | Val Loss 0.653924
# Epoch 600 | Train Loss 0.650145 | Val Loss 0.658310
# Epoch 700 | Train Loss 0.647857 | Val Loss 0.669701
# Early stopping at epoch 782
# Y | train1 -> R² = 0.3844, MSE = 5.1581e-02
# Y | train2 -> R² = -1.0984, MSE = 2.2595e-01
# Y | test1 -> R² = 0.5725, MSE = 3.5031e-02
# Y | test2 -> R² = -1.1709, MSE = 2.3043e-01
# Y | test3 -> R² = -1.6380, MSE = 2.0262e-01
# Y | val -> R² = -1.4218, MSE = 1.8031e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.216992 | Val Loss 0.709489
# Epoch 100 | Train Loss 0.687203 | Val Loss 0.840881
# Epoch 200 | Train Loss 0.662178 | Val Loss 0.679157
# Epoch 300 | Train Loss 0.657826 | Val Loss 0.677086
# Epoch 400 | Train Loss 0.654646 | Val Loss 0.671670
# Epoch 500 | Train Loss 0.651689 | Val Loss 0.676165
# Epoch 600 | Train Loss 0.647862 | Val Loss 0.679572
# Early stopping at epoch 609
# Y | train1 -> R² = 0.1839, MSE = 6.8383e-02
# Y | train2 -> R² = -1.3860, MSE = 2.5692e-01
# Y | test1 -> R² = 0.4356, MSE = 4.6253e-02
# Y | test2 -> R² = -1.5102, MSE = 2.6644e-01
# Y | test3 -> R² = -3.0534, MSE = 3.1133e-01
# Y | val -> R² = -3.0911, MSE = 3.0458e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.182037 | Val Loss 0.684962
# Epoch 100 | Train Loss 0.686861 | Val Loss 0.794616
# Epoch 200 | Train Loss 0.664127 | Val Loss 0.682826
# Epoch 300 | Train Loss 0.659414 | Val Loss 0.674486
# Epoch 400 | Train Loss 0.656000 | Val Loss 0.664281
# Epoch 500 | Train Loss 0.655827 | Val Loss 0.656997
# Epoch 600 | Train Loss 0.650274 | Val Loss 0.671812
# Epoch 700 | Train Loss 0.647465 | Val Loss 0.677722
# Early stopping at epoch 792
# Y | train1 -> R² = 0.5935, MSE = 3.4062e-02
# Y | train2 -> R² = -1.2640, MSE = 2.4378e-01
# Y | test1 -> R² = 0.7138, MSE = 2.3456e-02
# Y | test2 -> R² = -1.3556, MSE = 2.5003e-01
# Y | test3 -> R² = -2.0244, MSE = 2.3229e-01
# Y | val -> R² = -2.2596, MSE = 2.4268e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.154020 | Val Loss 0.744992
# Epoch 100 | Train Loss 0.692695 | Val Loss 0.869697
# Epoch 200 | Train Loss 0.663193 | Val Loss 0.676174
# Epoch 300 | Train Loss 0.659720 | Val Loss 0.671958
# Epoch 400 | Train Loss 0.656241 | Val Loss 0.658625
# Epoch 500 | Train Loss 0.653800 | Val Loss 0.651872
# Epoch 600 | Train Loss 0.650890 | Val Loss 0.650725
# Epoch 700 | Train Loss 0.648304 | Val Loss 0.649901
# Epoch 800 | Train Loss 0.645048 | Val Loss 0.656772
# Epoch 900 | Train Loss 0.641456 | Val Loss 0.674029
# Early stopping at epoch 926
# Y | train1 -> R² = 0.6926, MSE = 2.5759e-02
# Y | train2 -> R² = -1.7121, MSE = 2.9203e-01
# Y | test1 -> R² = 0.8197, MSE = 1.4778e-02
# Y | test2 -> R² = -1.8241, MSE = 2.9976e-01
# Y | test3 -> R² = -0.0513, MSE = 8.0746e-02
# Y | val -> R² = 0.0382, MSE = 7.1608e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.159123 | Val Loss 0.684538
# Epoch 100 | Train Loss 0.689438 | Val Loss 0.811707
# Epoch 200 | Train Loss 0.662598 | Val Loss 0.689828
# Epoch 300 | Train Loss 0.658851 | Val Loss 0.674694
# Early stopping at epoch 319
# Y | train1 -> R² = 0.6173, MSE = 3.2067e-02
# Y | train2 -> R² = -7.7438, MSE = 9.4152e-01
# Y | test1 -> R² = 0.4416, MSE = 4.5761e-02
# Y | test2 -> R² = -7.6373, MSE = 9.1679e-01
# Y | test3 -> R² = 0.6769, MSE = 2.4818e-02
# Y | val -> R² = 0.7240, MSE = 2.0546e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.275462 | Val Loss 0.679910
# Epoch 100 | Train Loss 0.687108 | Val Loss 0.837464
# Epoch 200 | Train Loss 0.668991 | Val Loss 0.681602
# Epoch 300 | Train Loss 0.658738 | Val Loss 0.689496
# Early stopping at epoch 309
# Y | train1 -> R² = 0.4721, MSE = 4.4237e-02
# Y | train2 -> R² = -8.5575, MSE = 1.0291e+00
# Y | test1 -> R² = 0.3478, MSE = 5.3450e-02
# Y | test2 -> R² = -8.4642, MSE = 1.0046e+00
# Y | test3 -> R² = 0.8501, MSE = 1.1511e-02
# Y | val -> R² = 0.8761, MSE = 9.2219e-03
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.174632 | Val Loss 1.076198
# Epoch 100 | Train Loss 0.688554 | Val Loss 0.818451
# Epoch 200 | Train Loss 0.662461 | Val Loss 0.672624
# Epoch 300 | Train Loss 0.658894 | Val Loss 0.669458
# Epoch 400 | Train Loss 0.655807 | Val Loss 0.665088
# Epoch 500 | Train Loss 0.652916 | Val Loss 0.662058
# Epoch 600 | Train Loss 0.649885 | Val Loss 0.665992
# Epoch 700 | Train Loss 0.647481 | Val Loss 0.668378
# Early stopping at epoch 783
# Y | train1 -> R² = 0.3963, MSE = 5.0589e-02
# Y | train2 -> R² = -1.6187, MSE = 2.8198e-01
# Y | test1 -> R² = 0.6186, MSE = 3.1253e-02
# Y | test2 -> R² = -1.7317, MSE = 2.8995e-01
# Y | test3 -> R² = -1.4968, MSE = 1.9177e-01
# Y | val -> R² = -1.0555, MSE = 1.5303e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.543336 | Val Loss 0.866434
# Epoch 100 | Train Loss 1.055677 | Val Loss 0.738148
# Epoch 200 | Train Loss 1.036067 | Val Loss 0.621154
# Epoch 300 | Train Loss 1.030613 | Val Loss 0.608538
# Epoch 400 | Train Loss 1.026501 | Val Loss 0.596327
# Epoch 500 | Train Loss 1.021730 | Val Loss 0.597965
# Epoch 600 | Train Loss 1.019552 | Val Loss 0.598417
# Early stopping at epoch 660
# Y | train1 -> R² = 0.8858, MSE = 9.5687e-03
# Y | train2 -> R² = 0.5886, MSE = 4.4297e-02
# Y | test1 -> R² = 0.9237, MSE = 6.2520e-03
# Y | test2 -> R² = 0.5495, MSE = 4.7814e-02
# Y | test3 -> R² = -0.0810, MSE = 8.3030e-02
# Y | val -> R² = -0.4306, MSE = 1.0651e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.617906 | Val Loss 0.762352
# Epoch 100 | Train Loss 1.050135 | Val Loss 0.694201
# Epoch 200 | Train Loss 1.035222 | Val Loss 0.623923
# Epoch 300 | Train Loss 1.029120 | Val Loss 0.612814
# Epoch 400 | Train Loss 1.024734 | Val Loss 0.626350
# Epoch 500 | Train Loss 1.020456 | Val Loss 0.671068
# Epoch 600 | Train Loss 1.015470 | Val Loss 0.677678
# Early stopping at epoch 606
# Y | train1 -> R² = 0.8673, MSE = 1.1120e-02
# Y | train2 -> R² = 0.6846, MSE = 3.3959e-02
# Y | test1 -> R² = 0.9086, MSE = 7.4914e-03
# Y | test2 -> R² = 0.6832, MSE = 3.3630e-02
# Y | test3 -> R² = -1.1164, MSE = 1.6256e-01
# Y | val -> R² = -1.6965, MSE = 2.0075e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.588192 | Val Loss 0.803914
# Epoch 100 | Train Loss 1.047312 | Val Loss 0.663592
# Epoch 200 | Train Loss 1.035740 | Val Loss 0.632004
# Epoch 300 | Train Loss 1.031121 | Val Loss 0.613389
# Epoch 400 | Train Loss 1.026139 | Val Loss 0.601701
# Epoch 500 | Train Loss 1.021196 | Val Loss 0.607290
# Epoch 600 | Train Loss 1.016043 | Val Loss 0.610417
# Epoch 700 | Train Loss 1.010007 | Val Loss 0.606820
# Epoch 800 | Train Loss 1.003415 | Val Loss 0.605054
# Early stopping at epoch 820
# Y | train1 -> R² = 0.8909, MSE = 9.1449e-03
# Y | train2 -> R² = -0.0551, MSE = 1.1361e-01
# Y | test1 -> R² = 0.9378, MSE = 5.0996e-03
# Y | test2 -> R² = -0.1555, MSE = 1.2264e-01
# Y | test3 -> R² = -0.6784, MSE = 1.2891e-01
# Y | val -> R² = -0.8391, MSE = 1.3692e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.686849 | Val Loss 0.753954
# Epoch 100 | Train Loss 1.053220 | Val Loss 0.710657
# Epoch 200 | Train Loss 1.038852 | Val Loss 0.613327
# Epoch 300 | Train Loss 1.032657 | Val Loss 0.601028
# Epoch 400 | Train Loss 1.026684 | Val Loss 0.596648
# Epoch 500 | Train Loss 1.024851 | Val Loss 0.590598
# Epoch 600 | Train Loss 1.018384 | Val Loss 0.600807
# Epoch 700 | Train Loss 1.013000 | Val Loss 0.610601
# Epoch 800 | Train Loss 1.006889 | Val Loss 0.615160
# Early stopping at epoch 814
# Y | train1 -> R² = 0.9314, MSE = 5.7520e-03
# Y | train2 -> R² = 0.6717, MSE = 3.5349e-02
# Y | test1 -> R² = 0.9525, MSE = 3.8901e-03
# Y | test2 -> R² = 0.6665, MSE = 3.5401e-02
# Y | test3 -> R² = 0.1117, MSE = 6.8230e-02
# Y | val -> R² = -0.1188, MSE = 8.3297e-02
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.486362 | Val Loss 0.918999
# Epoch 100 | Train Loss 1.047240 | Val Loss 0.653073
# Epoch 200 | Train Loss 1.039956 | Val Loss 0.614308
# Epoch 300 | Train Loss 1.031506 | Val Loss 0.598666
# Epoch 400 | Train Loss 1.024748 | Val Loss 0.596833
# Epoch 500 | Train Loss 1.022374 | Val Loss 0.597320
# Epoch 600 | Train Loss 1.018204 | Val Loss 0.597164
# Epoch 700 | Train Loss 1.008161 | Val Loss 0.604240
# Early stopping at epoch 720
# Y | train1 -> R² = 0.8545, MSE = 1.2191e-02
# Y | train2 -> R² = -0.0365, MSE = 1.1161e-01
# Y | test1 -> R² = 0.9029, MSE = 7.9603e-03
# Y | test2 -> R² = -0.1406, MSE = 1.2106e-01
# Y | test3 -> R² = 0.5167, MSE = 3.7123e-02
# Y | val -> R² = 0.1160, MSE = 6.5814e-02
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.645513 | Val Loss 0.908882
# Epoch 100 | Train Loss 1.048189 | Val Loss 0.656898
# Epoch 200 | Train Loss 1.037218 | Val Loss 0.615802
# Epoch 300 | Train Loss 1.033477 | Val Loss 0.605329
# Epoch 400 | Train Loss 1.025803 | Val Loss 0.611751
# Epoch 500 | Train Loss 1.021961 | Val Loss 0.615416
# Epoch 600 | Train Loss 1.017116 | Val Loss 0.622868
# Early stopping at epoch 613
# Y | train1 -> R² = 0.8633, MSE = 1.1452e-02
# Y | train2 -> R² = 0.4796, MSE = 5.6038e-02
# Y | test1 -> R² = 0.9200, MSE = 6.5587e-03
# Y | test2 -> R² = 0.4341, MSE = 6.0063e-02
# Y | test3 -> R² = -0.7357, MSE = 1.3331e-01
# Y | val -> R² = -0.9378, MSE = 1.4427e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.590290 | Val Loss 0.779422
# Epoch 100 | Train Loss 1.050862 | Val Loss 0.699348
# Epoch 200 | Train Loss 1.036104 | Val Loss 0.620761
# Epoch 300 | Train Loss 1.030307 | Val Loss 0.599913
# Epoch 400 | Train Loss 1.026036 | Val Loss 0.593173
