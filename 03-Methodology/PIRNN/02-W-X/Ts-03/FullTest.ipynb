# %% [markdown]
# - Entradas: PwmD, PwmE
# - Saidas: X
# - Trajetorias: ZZ

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = Train1

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada fisica : (973,)
# Dimensão da entrada fisica: (973,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.708102 | Val Loss 0.672233
# Epoch 100 | Train Loss 0.315510 | Val Loss 0.395078
# Epoch 200 | Train Loss 0.313840 | Val Loss 0.395101
# Epoch 300 | Train Loss 0.312753 | Val Loss 0.395324
# Early stopping at epoch 355
# X | train1 -> R² = 0.9608, MSE = 4.2228e-03
# X | train2 -> R² = -1.3475, MSE = 1.9780e-01
# X | test1 -> R² = 0.9239, MSE = 7.9682e-03
# X | test2 -> R² = -1.3838, MSE = 1.9617e-01
# X | test3 -> R² = 0.8931, MSE = 9.8333e-03
# X | val -> R² = 0.8846, MSE = 1.1034e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.780715 | Val Loss 0.724074
# Epoch 100 | Train Loss 0.318330 | Val Loss 0.393444
# Epoch 200 | Train Loss 0.315290 | Val Loss 0.393736
# Epoch 300 | Train Loss 0.313620 | Val Loss 0.394841
# Early stopping at epoch 359
# X | train1 -> R² = 0.9477, MSE = 5.6374e-03
# X | train2 -> R² = -1.4033, MSE = 2.0251e-01
# X | test1 -> R² = 0.9024, MSE = 1.0230e-02
# X | test2 -> R² = -1.4372, MSE = 2.0056e-01
# X | test3 -> R² = 0.8368, MSE = 1.5018e-02
# X | val -> R² = 0.8038, MSE = 1.8765e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.723134 | Val Loss 0.679541
# Epoch 100 | Train Loss 0.316224 | Val Loss 0.394528
# Epoch 200 | Train Loss 0.314494 | Val Loss 0.394714
# Epoch 300 | Train Loss 0.313629 | Val Loss 0.395155
# Early stopping at epoch 354
# X | train1 -> R² = 0.9587, MSE = 4.4529e-03
# X | train2 -> R² = -1.3643, MSE = 1.9922e-01
# X | test1 -> R² = 0.9190, MSE = 8.4829e-03
# X | test2 -> R² = -1.3977, MSE = 1.9732e-01
# X | test3 -> R² = 0.8822, MSE = 1.0837e-02
# X | val -> R² = 0.8680, MSE = 1.2621e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.732570 | Val Loss 0.689954
# Epoch 100 | Train Loss 0.316249 | Val Loss 0.394450
# Epoch 200 | Train Loss 0.314126 | Val Loss 0.394617
# Epoch 300 | Train Loss 0.313082 | Val Loss 0.395163
# Early stopping at epoch 355
# X | train1 -> R² = 0.9466, MSE = 5.7613e-03
# X | train2 -> R² = -1.3046, MSE = 1.9419e-01
# X | test1 -> R² = 0.8998, MSE = 1.0497e-02
# X | test2 -> R² = -1.3373, MSE = 1.9235e-01
# X | test3 -> R² = 0.8557, MSE = 1.3276e-02
# X | val -> R² = 0.8355, MSE = 1.5735e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.768895 | Val Loss 0.718023
# Epoch 100 | Train Loss 0.315878 | Val Loss 0.394295
# Epoch 200 | Train Loss 0.314022 | Val Loss 0.394504
# Epoch 300 | Train Loss 0.313066 | Val Loss 0.395017
# Early stopping at epoch 359
# X | train1 -> R² = 0.9576, MSE = 4.5719e-03
# X | train2 -> R² = -1.3572, MSE = 1.9862e-01
# X | test1 -> R² = 0.9188, MSE = 8.5086e-03
# X | test2 -> R² = -1.3931, MSE = 1.9694e-01
# X | test3 -> R² = 0.8705, MSE = 1.1914e-02
# X | val -> R² = 0.8544, MSE = 1.3922e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.738650 | Val Loss 0.695634
# Epoch 100 | Train Loss 0.314976 | Val Loss 0.394995
# Epoch 200 | Train Loss 0.313443 | Val Loss 0.395032
# Epoch 300 | Train Loss 0.312759 | Val Loss 0.395207
# Early stopping at epoch 357
# X | train1 -> R² = 0.9626, MSE = 4.0334e-03
# X | train2 -> R² = -1.3611, MSE = 1.9895e-01
# X | test1 -> R² = 0.9230, MSE = 8.0696e-03
# X | test2 -> R² = -1.3916, MSE = 1.9681e-01
# X | test3 -> R² = 0.8591, MSE = 1.2963e-02
# X | val -> R² = 0.8426, MSE = 1.5051e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.714398 | Val Loss 0.674729
# Epoch 100 | Train Loss 0.317429 | Val Loss 0.393328
# Epoch 200 | Train Loss 0.314015 | Val Loss 0.394340
# Epoch 300 | Train Loss 0.312611 | Val Loss 0.395300
# Early stopping at epoch 356
# X | train1 -> R² = 0.9502, MSE = 5.3732e-03
# X | train2 -> R² = -1.4091, MSE = 2.0299e-01
# X | test1 -> R² = 0.9059, MSE = 9.8528e-03
# X | test2 -> R² = -1.4422, MSE = 2.0097e-01
# X | test3 -> R² = 0.8374, MSE = 1.4964e-02
# X | val -> R² = 0.8045, MSE = 1.8690e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.734416 | Val Loss 0.690191
# Epoch 100 | Train Loss 0.315470 | Val Loss 0.394654
# Epoch 200 | Train Loss 0.313873 | Val Loss 0.394868
# Epoch 300 | Train Loss 0.313021 | Val Loss 0.395239
# Early stopping at epoch 354
# X | train1 -> R² = 0.9655, MSE = 3.7174e-03
# X | train2 -> R² = -1.4073, MSE = 2.0284e-01
# X | test1 -> R² = 0.9303, MSE = 7.3022e-03
# X | test2 -> R² = -1.4403, MSE = 2.0082e-01
# X | test3 -> R² = 0.8964, MSE = 9.5326e-03
# X | val -> R² = 0.8854, MSE = 1.0963e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.707109 | Val Loss 0.670397
# Epoch 100 | Train Loss 0.315939 | Val Loss 0.394614
# Epoch 200 | Train Loss 0.313868 | Val Loss 0.394633
# Epoch 300 | Train Loss 0.312885 | Val Loss 0.395096
# Early stopping at epoch 354
# X | train1 -> R² = 0.9518, MSE = 5.1970e-03
# X | train2 -> R² = -1.3295, MSE = 1.9628e-01
# X | test1 -> R² = 0.9060, MSE = 9.8491e-03
# X | test2 -> R² = -1.3599, MSE = 1.9421e-01
# X | test3 -> R² = 0.8620, MSE = 1.2700e-02
# X | val -> R² = 0.8422, MSE = 1.5089e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.705029 | Val Loss 0.667407
# Epoch 100 | Train Loss 0.316565 | Val Loss 0.393646
# Epoch 200 | Train Loss 0.314162 | Val Loss 0.394074
# Epoch 300 | Train Loss 0.312817 | Val Loss 0.394777
# Early stopping at epoch 355
# X | train1 -> R² = 0.9497, MSE = 5.4238e-03
# X | train2 -> R² = -1.3571, MSE = 1.9861e-01
# X | test1 -> R² = 0.9061, MSE = 9.8350e-03
# X | test2 -> R² = -1.3922, MSE = 1.9686e-01
# X | test3 -> R² = 0.8515, MSE = 1.3659e-02
# X | val -> R² = 0.8274, MSE = 1.6504e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.694047 | Val Loss 0.660308
# Epoch 100 | Train Loss 0.315901 | Val Loss 0.394973
# Epoch 200 | Train Loss 0.314175 | Val Loss 0.395260
# Epoch 300 | Train Loss 0.313370 | Val Loss 0.395390
# Early stopping at epoch 353
# X | train1 -> R² = 0.9630, MSE = 3.9900e-03
# X | train2 -> R² = -1.3936, MSE = 2.0169e-01
# X | test1 -> R² = 0.9233, MSE = 8.0365e-03
# X | test2 -> R² = -1.4223, MSE = 1.9934e-01
# X | test3 -> R² = 0.8705, MSE = 1.1911e-02
# X | val -> R² = 0.8518, MSE = 1.4171e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.657510 | Val Loss 0.629394
# Epoch 100 | Train Loss 0.316761 | Val Loss 0.393553
# Epoch 200 | Train Loss 0.314092 | Val Loss 0.394072
# Epoch 300 | Train Loss 0.312752 | Val Loss 0.395096
# Early stopping at epoch 363
# X | train1 -> R² = 0.9433, MSE = 6.1096e-03
# X | train2 -> R² = -1.2978, MSE = 1.9361e-01
# X | test1 -> R² = 0.8982, MSE = 1.0665e-02
# X | test2 -> R² = -1.3345, MSE = 1.9212e-01
# X | test3 -> R² = 0.8263, MSE = 1.5986e-02
# X | val -> R² = 0.8018, MSE = 1.8952e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.654323 | Val Loss 0.628991
# Epoch 100 | Train Loss 0.314207 | Val Loss 0.396263
# Epoch 200 | Train Loss 0.312958 | Val Loss 0.395526
# Epoch 300 | Train Loss 0.312258 | Val Loss 0.395444
# Epoch 400 | Train Loss 0.311623 | Val Loss 0.395495
# Early stopping at epoch 491
# X | train1 -> R² = 0.9783, MSE = 2.3392e-03
# X | train2 -> R² = -1.3671, MSE = 1.9945e-01
# X | test1 -> R² = 0.9578, MSE = 4.4252e-03
# X | test2 -> R² = -1.4168, MSE = 1.9888e-01
# X | test3 -> R² = 0.7948, MSE = 1.8875e-02
# X | val -> R² = 0.8199, MSE = 1.7225e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.735813 | Val Loss 0.693106
# Epoch 100 | Train Loss 0.316791 | Val Loss 0.393995
# Epoch 200 | Train Loss 0.314388 | Val Loss 0.394309
# Epoch 300 | Train Loss 0.313088 | Val Loss 0.394908
# Early stopping at epoch 356
# X | train1 -> R² = 0.9563, MSE = 4.7117e-03
# X | train2 -> R² = -1.3939, MSE = 2.0171e-01
# X | test1 -> R² = 0.9172, MSE = 8.6787e-03
# X | test2 -> R² = -1.4300, MSE = 1.9998e-01
# X | test3 -> R² = 0.8663, MSE = 1.2300e-02
# X | val -> R² = 0.8449, MSE = 1.4835e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.683632 | Val Loss 0.650522
# Epoch 100 | Train Loss 0.315758 | Val Loss 0.394408
# Epoch 200 | Train Loss 0.313457 | Val Loss 0.394681
# Epoch 300 | Train Loss 0.312335 | Val Loss 0.395366
# Early stopping at epoch 350
# X | train1 -> R² = 0.9613, MSE = 4.1720e-03
# X | train2 -> R² = -1.4181, MSE = 2.0375e-01
# X | test1 -> R² = 0.9231, MSE = 8.0526e-03
# X | test2 -> R² = -1.4506, MSE = 2.0167e-01
# X | test3 -> R² = 0.8897, MSE = 1.0151e-02
# X | val -> R² = 0.8736, MSE = 1.2090e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.691227 | Val Loss 0.723166
# Epoch 100 | Train Loss 0.229586 | Val Loss 0.394872
# Epoch 200 | Train Loss 0.227413 | Val Loss 0.395366
# Epoch 300 | Train Loss 0.226463 | Val Loss 0.396421
# Early stopping at epoch 360
# X | train1 -> R² = 0.9528, MSE = 5.0905e-03
# X | train2 -> R² = -1.2955, MSE = 1.9342e-01
# X | test1 -> R² = 0.9104, MSE = 9.3885e-03
# X | test2 -> R² = -1.3315, MSE = 1.9187e-01
# X | test3 -> R² = 0.8595, MSE = 1.2926e-02
# X | val -> R² = 0.8456, MSE = 1.4765e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.611874 | Val Loss 0.657607
# Epoch 100 | Train Loss 0.230790 | Val Loss 0.393832
# Epoch 200 | Train Loss 0.227984 | Val Loss 0.395007
# Epoch 300 | Train Loss 0.226533 | Val Loss 0.396451
# Early stopping at epoch 353
# X | train1 -> R² = 0.9574, MSE = 4.5942e-03
# X | train2 -> R² = -1.4191, MSE = 2.0384e-01
# X | test1 -> R² = 0.9174, MSE = 8.6557e-03
# X | test2 -> R² = -1.4547, MSE = 2.0200e-01
# X | test3 -> R² = 0.8634, MSE = 1.2568e-02
# X | val -> R² = 0.8403, MSE = 1.5270e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.633238 | Val Loss 0.674442
# Epoch 100 | Train Loss 0.230635 | Val Loss 0.394448
# Epoch 200 | Train Loss 0.227949 | Val Loss 0.395128
# Epoch 300 | Train Loss 0.226758 | Val Loss 0.396165
# Early stopping at epoch 357
# X | train1 -> R² = 0.9601, MSE = 4.2972e-03
# X | train2 -> R² = -1.4368, MSE = 2.0533e-01
# X | test1 -> R² = 0.9176, MSE = 8.6305e-03
# X | test2 -> R² = -1.4650, MSE = 2.0285e-01
# X | test3 -> R² = 0.8509, MSE = 1.3722e-02
# X | val -> R² = 0.8241, MSE = 1.6817e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.616251 | Val Loss 0.663624
# Epoch 100 | Train Loss 0.230580 | Val Loss 0.394662
# Epoch 200 | Train Loss 0.228333 | Val Loss 0.395825
# Epoch 300 | Train Loss 0.227356 | Val Loss 0.396718
# Early stopping at epoch 354
# X | train1 -> R² = 0.9540, MSE = 4.9583e-03
# X | train2 -> R² = -1.3670, MSE = 1.9945e-01
# X | test1 -> R² = 0.9087, MSE = 9.5699e-03
# X | test2 -> R² = -1.3977, MSE = 1.9732e-01
# X | test3 -> R² = 0.8388, MSE = 1.4832e-02
# X | val -> R² = 0.8139, MSE = 1.7792e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.653341 | Val Loss 0.692350
# Epoch 100 | Train Loss 0.230742 | Val Loss 0.394039
# Epoch 200 | Train Loss 0.227658 | Val Loss 0.395009
# Epoch 300 | Train Loss 0.226501 | Val Loss 0.396509
# Early stopping at epoch 364
# X | train1 -> R² = 0.9492, MSE = 5.4735e-03
# X | train2 -> R² = -1.3765, MSE = 2.0024e-01
# X | test1 -> R² = 0.9045, MSE = 1.0006e-02
# X | test2 -> R² = -1.4117, MSE = 1.9846e-01
# X | test3 -> R² = 0.7739, MSE = 2.0799e-02
# X | val -> R² = 0.7430, MSE = 2.4576e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.639377 | Val Loss 0.682227
# Epoch 100 | Train Loss 0.228844 | Val Loss 0.395212
# Epoch 200 | Train Loss 0.226997 | Val Loss 0.395868
# Epoch 300 | Train Loss 0.226022 | Val Loss 0.396670
# Early stopping at epoch 357
# X | train1 -> R² = 0.9630, MSE = 3.9948e-03
# X | train2 -> R² = -1.3632, MSE = 1.9912e-01
# X | test1 -> R² = 0.9248, MSE = 7.8765e-03
# X | test2 -> R² = -1.3973, MSE = 1.9728e-01
# X | test3 -> R² = 0.8671, MSE = 1.2230e-02
# X | val -> R² = 0.8531, MSE = 1.4048e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.585176 | Val Loss 0.636535
# Epoch 100 | Train Loss 0.231809 | Val Loss 0.393849
# Epoch 200 | Train Loss 0.228438 | Val Loss 0.395307
# Epoch 300 | Train Loss 0.227075 | Val Loss 0.396670
# Early stopping at epoch 356
# X | train1 -> R² = 0.9371, MSE = 6.7782e-03
# X | train2 -> R² = -1.3356, MSE = 1.9680e-01
# X | test1 -> R² = 0.8878, MSE = 1.1756e-02
# X | test2 -> R² = -1.3728, MSE = 1.9527e-01
# X | test3 -> R² = 0.8191, MSE = 1.6641e-02
# X | val -> R² = 0.7868, MSE = 2.0390e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.613627 | Val Loss 0.660497
# Epoch 100 | Train Loss 0.230132 | Val Loss 0.393740
# Epoch 200 | Train Loss 0.227310 | Val Loss 0.394838
# Epoch 300 | Train Loss 0.225875 | Val Loss 0.396437
# Early stopping at epoch 356
# X | train1 -> R² = 0.9513, MSE = 5.2465e-03
# X | train2 -> R² = -1.3561, MSE = 1.9853e-01
# X | test1 -> R² = 0.9110, MSE = 9.3287e-03
# X | test2 -> R² = -1.3960, MSE = 1.9718e-01
# X | test3 -> R² = 0.8576, MSE = 1.3103e-02
# X | val -> R² = 0.8381, MSE = 1.5485e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.645930 | Val Loss 0.687003
# Epoch 100 | Train Loss 0.229705 | Val Loss 0.395172
# Epoch 200 | Train Loss 0.227824 | Val Loss 0.395758
# Epoch 300 | Train Loss 0.227044 | Val Loss 0.396641
# Early stopping at epoch 355
# X | train1 -> R² = 0.9582, MSE = 4.5110e-03
# X | train2 -> R² = -1.3303, MSE = 1.9635e-01
# X | test1 -> R² = 0.9175, MSE = 8.6451e-03
# X | test2 -> R² = -1.3647, MSE = 1.9460e-01
# X | test3 -> R² = 0.8735, MSE = 1.1639e-02
# X | val -> R² = 0.8607, MSE = 1.3323e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.660972 | Val Loss 0.697374
# Epoch 100 | Train Loss 0.231587 | Val Loss 0.393940
# Epoch 200 | Train Loss 0.228295 | Val Loss 0.395111
# Epoch 300 | Train Loss 0.226434 | Val Loss 0.397339
# Early stopping at epoch 357
# X | train1 -> R² = 0.9500, MSE = 5.3967e-03
# X | train2 -> R² = -1.3850, MSE = 2.0096e-01
# X | test1 -> R² = 0.9075, MSE = 9.6949e-03
# X | test2 -> R² = -1.4231, MSE = 1.9941e-01
# X | test3 -> R² = 0.8572, MSE = 1.3137e-02
# X | val -> R² = 0.8330, MSE = 1.5966e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.682220 | Val Loss 0.716479
# Epoch 100 | Train Loss 0.228785 | Val Loss 0.395423
# Epoch 200 | Train Loss 0.227141 | Val Loss 0.395693
# Epoch 300 | Train Loss 0.226293 | Val Loss 0.396474
# Early stopping at epoch 359
# X | train1 -> R² = 0.9637, MSE = 3.9148e-03
# X | train2 -> R² = -1.3450, MSE = 1.9759e-01
# X | test1 -> R² = 0.9280, MSE = 7.5385e-03
# X | test2 -> R² = -1.3825, MSE = 1.9607e-01
# X | test3 -> R² = 0.8937, MSE = 9.7787e-03
# X | val -> R² = 0.8869, MSE = 1.0818e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.575460 | Val Loss 0.628471
# Epoch 100 | Train Loss 0.233073 | Val Loss 0.393772
# Epoch 200 | Train Loss 0.228930 | Val Loss 0.394632
# Epoch 300 | Train Loss 0.226958 | Val Loss 0.396650
# Early stopping at epoch 357
# X | train1 -> R² = 0.9306, MSE = 7.4859e-03
# X | train2 -> R² = -1.3356, MSE = 1.9680e-01
# X | test1 -> R² = 0.8771, MSE = 1.2879e-02
# X | test2 -> R² = -1.3710, MSE = 1.9512e-01
# X | test3 -> R² = 0.8114, MSE = 1.7352e-02
# X | val -> R² = 0.7734, MSE = 2.1668e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.607614 | Val Loss 0.654147
# Epoch 100 | Train Loss 0.229568 | Val Loss 0.395452
# Epoch 200 | Train Loss 0.227794 | Val Loss 0.395806
# Epoch 300 | Train Loss 0.226907 | Val Loss 0.396515
# Early stopping at epoch 350
# X | train1 -> R² = 0.9635, MSE = 3.9360e-03
# X | train2 -> R² = -1.3306, MSE = 1.9638e-01
# X | test1 -> R² = 0.9262, MSE = 7.7291e-03
# X | test2 -> R² = -1.3652, MSE = 1.9464e-01
# X | test3 -> R² = 0.8838, MSE = 1.0689e-02
# X | val -> R² = 0.8756, MSE = 1.1897e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.629706 | Val Loss 0.674062
# Epoch 100 | Train Loss 0.230441 | Val Loss 0.394161
# Epoch 200 | Train Loss 0.227909 | Val Loss 0.395467
# Epoch 300 | Train Loss 0.226876 | Val Loss 0.396637
# Early stopping at epoch 355
# X | train1 -> R² = 0.9580, MSE = 4.5271e-03
# X | train2 -> R² = -1.4187, MSE = 2.0380e-01
# X | test1 -> R² = 0.9150, MSE = 8.9043e-03
# X | test2 -> R² = -1.4480, MSE = 2.0145e-01
# X | test3 -> R² = 0.8310, MSE = 1.5547e-02
# X | val -> R² = 0.8014, MSE = 1.8995e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.645096 | Val Loss 0.684459
# Epoch 100 | Train Loss 0.231066 | Val Loss 0.394400
# Epoch 200 | Train Loss 0.228083 | Val Loss 0.395503
# Epoch 300 | Train Loss 0.226406 | Val Loss 0.397549
# Early stopping at epoch 359
# X | train1 -> R² = 0.9421, MSE = 6.2480e-03
# X | train2 -> R² = -1.2817, MSE = 1.9225e-01
# X | test1 -> R² = 0.8952, MSE = 1.0982e-02
# X | test2 -> R² = -1.3186, MSE = 1.9080e-01
# X | test3 -> R² = 0.8439, MSE = 1.4363e-02
# X | val -> R² = 0.8243, MSE = 1.6805e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.803045 | Val Loss 0.682576
# Epoch 100 | Train Loss 0.400929 | Val Loss 0.394516
# Epoch 200 | Train Loss 0.399121 | Val Loss 0.394370
# Epoch 300 | Train Loss 0.398225 | Val Loss 0.394306
# Early stopping at epoch 398
# X | train1 -> R² = 0.9684, MSE = 3.4102e-03
# X | train2 -> R² = -1.3638, MSE = 1.9917e-01
# X | test1 -> R² = 0.9378, MSE = 6.5128e-03
# X | test2 -> R² = -1.4017, MSE = 1.9764e-01
# X | test3 -> R² = 0.8228, MSE = 1.6304e-02
# X | val -> R² = 0.8171, MSE = 1.7488e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.797555 | Val Loss 0.676827
# Epoch 100 | Train Loss 0.403666 | Val Loss 0.392966
# Epoch 200 | Train Loss 0.399647 | Val Loss 0.393170
# Epoch 300 | Train Loss 0.397868 | Val Loss 0.393718
# Early stopping at epoch 361
# X | train1 -> R² = 0.9437, MSE = 6.0712e-03
# X | train2 -> R² = -1.3809, MSE = 2.0062e-01
# X | test1 -> R² = 0.8996, MSE = 1.0515e-02
# X | test2 -> R² = -1.4177, MSE = 1.9896e-01
# X | test3 -> R² = 0.7955, MSE = 1.8819e-02
# X | val -> R² = 0.7565, MSE = 2.3287e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.743728 | Val Loss 0.634262
# Epoch 100 | Train Loss 0.400424 | Val Loss 0.394297
# Epoch 200 | Train Loss 0.398597 | Val Loss 0.393957
# Epoch 300 | Train Loss 0.397426 | Val Loss 0.393979
# Early stopping at epoch 352
# X | train1 -> R² = 0.9560, MSE = 4.7473e-03
# X | train2 -> R² = -1.3073, MSE = 1.9441e-01
# X | test1 -> R² = 0.9168, MSE = 8.7179e-03
# X | test2 -> R² = -1.3422, MSE = 1.9275e-01
# X | test3 -> R² = 0.8838, MSE = 1.0690e-02
# X | val -> R² = 0.8748, MSE = 1.1975e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.792211 | Val Loss 0.674518
# Epoch 100 | Train Loss 0.402178 | Val Loss 0.393598
# Epoch 200 | Train Loss 0.399689 | Val Loss 0.393620
# Epoch 300 | Train Loss 0.398441 | Val Loss 0.393880
# Early stopping at epoch 395
# X | train1 -> R² = 0.9625, MSE = 4.0484e-03
# X | train2 -> R² = -1.4050, MSE = 2.0264e-01
# X | test1 -> R² = 0.9294, MSE = 7.3949e-03
# X | test2 -> R² = -1.4442, MSE = 2.0114e-01
# X | test3 -> R² = 0.8412, MSE = 1.4611e-02
# X | val -> R² = 0.8230, MSE = 1.6927e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.832826 | Val Loss 0.704330
# Epoch 100 | Train Loss 0.402071 | Val Loss 0.393407
# Epoch 200 | Train Loss 0.399554 | Val Loss 0.393393
# Epoch 300 | Train Loss 0.398345 | Val Loss 0.393865
# Epoch 400 | Train Loss 0.397585 | Val Loss 0.393987
# Early stopping at epoch 401
# X | train1 -> R² = 0.9626, MSE = 4.0333e-03
# X | train2 -> R² = -1.4022, MSE = 2.0241e-01
# X | test1 -> R² = 0.9295, MSE = 7.3875e-03
# X | test2 -> R² = -1.4409, MSE = 2.0087e-01
# X | test3 -> R² = 0.8146, MSE = 1.7060e-02
# X | val -> R² = 0.7969, MSE = 1.9418e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.825894 | Val Loss 0.699015
# Epoch 100 | Train Loss 0.401203 | Val Loss 0.394532
# Epoch 200 | Train Loss 0.399352 | Val Loss 0.394341
# Epoch 300 | Train Loss 0.398246 | Val Loss 0.394382
# Early stopping at epoch 357
# X | train1 -> R² = 0.9576, MSE = 4.5744e-03
# X | train2 -> R² = -1.3272, MSE = 1.9609e-01
# X | test1 -> R² = 0.9191, MSE = 8.4707e-03
# X | test2 -> R² = -1.3619, MSE = 1.9437e-01
# X | test3 -> R² = 0.8793, MSE = 1.1104e-02
# X | val -> R² = 0.8670, MSE = 1.2720e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.794458 | Val Loss 0.672542
# Epoch 100 | Train Loss 0.402092 | Val Loss 0.393269
# Epoch 200 | Train Loss 0.399533 | Val Loss 0.393689
# Epoch 300 | Train Loss 0.398249 | Val Loss 0.393933
# Early stopping at epoch 396
# X | train1 -> R² = 0.9630, MSE = 3.9900e-03
# X | train2 -> R² = -1.4060, MSE = 2.0273e-01
# X | test1 -> R² = 0.9322, MSE = 7.1007e-03
# X | test2 -> R² = -1.4480, MSE = 2.0146e-01
# X | test3 -> R² = 0.8422, MSE = 1.4522e-02
# X | val -> R² = 0.8256, MSE = 1.6673e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.780274 | Val Loss 0.662340
# Epoch 100 | Train Loss 0.400242 | Val Loss 0.394616
# Epoch 200 | Train Loss 0.398428 | Val Loss 0.394252
# Epoch 300 | Train Loss 0.397415 | Val Loss 0.394205
# Epoch 400 | Train Loss 0.396608 | Val Loss 0.394072
# Early stopping at epoch 428
# X | train1 -> R² = 0.9728, MSE = 2.9311e-03
# X | train2 -> R² = -1.3865, MSE = 2.0109e-01
# X | test1 -> R² = 0.9472, MSE = 5.5276e-03
# X | test2 -> R² = -1.4281, MSE = 1.9982e-01
# X | test3 -> R² = 0.8636, MSE = 1.2549e-02
# X | val -> R² = 0.8602, MSE = 1.3370e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.815389 | Val Loss 0.692785
# Epoch 100 | Train Loss 0.402218 | Val Loss 0.393814
# Epoch 200 | Train Loss 0.399668 | Val Loss 0.393528
# Epoch 300 | Train Loss 0.398235 | Val Loss 0.393785
# Early stopping at epoch 400
# X | train1 -> R² = 0.9628, MSE = 4.0105e-03
# X | train2 -> R² = -1.4077, MSE = 2.0287e-01
# X | test1 -> R² = 0.9298, MSE = 7.3521e-03
# X | test2 -> R² = -1.4467, MSE = 2.0135e-01
# X | test3 -> R² = 0.8516, MSE = 1.3655e-02
# X | val -> R² = 0.8337, MSE = 1.5906e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.743529 | Val Loss 0.633429
# Epoch 100 | Train Loss 0.401774 | Val Loss 0.394646
# Epoch 200 | Train Loss 0.399448 | Val Loss 0.394198
# Epoch 300 | Train Loss 0.398197 | Val Loss 0.394092
# Epoch 400 | Train Loss 0.397358 | Val Loss 0.394056
# Early stopping at epoch 447
# X | train1 -> R² = 0.9708, MSE = 3.1462e-03
# X | train2 -> R² = -1.4003, MSE = 2.0225e-01
# X | test1 -> R² = 0.9440, MSE = 5.8672e-03
# X | test2 -> R² = -1.4417, MSE = 2.0093e-01
# X | test3 -> R² = 0.8657, MSE = 1.2352e-02
# X | val -> R² = 0.8584, MSE = 1.3545e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.820700 | Val Loss 0.694772
# Epoch 100 | Train Loss 0.401529 | Val Loss 0.394206
# Epoch 200 | Train Loss 0.399475 | Val Loss 0.394155
# Epoch 300 | Train Loss 0.398171 | Val Loss 0.394161
# Early stopping at epoch 358
# X | train1 -> R² = 0.9480, MSE = 5.6106e-03
# X | train2 -> R² = -1.2872, MSE = 1.9272e-01
# X | test1 -> R² = 0.9068, MSE = 9.7608e-03
# X | test2 -> R² = -1.3251, MSE = 1.9134e-01
# X | test3 -> R² = 0.8719, MSE = 1.1787e-02
# X | val -> R² = 0.8596, MSE = 1.3421e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.805899 | Val Loss 0.680481
# Epoch 100 | Train Loss 0.403422 | Val Loss 0.393243
# Epoch 200 | Train Loss 0.399915 | Val Loss 0.393058
# Epoch 300 | Train Loss 0.398104 | Val Loss 0.393672
# Epoch 400 | Train Loss 0.396915 | Val Loss 0.394042
# Early stopping at epoch 403
# X | train1 -> R² = 0.9574, MSE = 4.5888e-03
# X | train2 -> R² = -1.4130, MSE = 2.0332e-01
# X | test1 -> R² = 0.9224, MSE = 8.1304e-03
# X | test2 -> R² = -1.4526, MSE = 2.0183e-01
# X | test3 -> R² = 0.8292, MSE = 1.5711e-02
# X | val -> R² = 0.8045, MSE = 1.8694e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.774205 | Val Loss 0.657800
# Epoch 100 | Train Loss 0.400402 | Val Loss 0.394963
# Epoch 200 | Train Loss 0.398220 | Val Loss 0.394316
# Epoch 300 | Train Loss 0.397217 | Val Loss 0.394023
# Epoch 400 | Train Loss 0.396394 | Val Loss 0.393754
# Epoch 500 | Train Loss 0.395648 | Val Loss 0.393728
# Epoch 600 | Train Loss 0.394912 | Val Loss 0.393977
# Early stopping at epoch 661
# X | train1 -> R² = 0.9788, MSE = 2.2884e-03
# X | train2 -> R² = -1.3348, MSE = 1.9673e-01
# X | test1 -> R² = 0.9632, MSE = 3.8526e-03
# X | test2 -> R² = -1.3990, MSE = 1.9742e-01
# X | test3 -> R² = 0.8578, MSE = 1.3084e-02
# X | val -> R² = 0.8801, MSE = 1.1469e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.836092 | Val Loss 0.708363
# Epoch 100 | Train Loss 0.401941 | Val Loss 0.394392
# Epoch 200 | Train Loss 0.399728 | Val Loss 0.393828
# Epoch 300 | Train Loss 0.398179 | Val Loss 0.393763
# Epoch 400 | Train Loss 0.396931 | Val Loss 0.394169
# Early stopping at epoch 466
# X | train1 -> R² = 0.9707, MSE = 3.1628e-03
# X | train2 -> R² = -1.3967, MSE = 2.0195e-01
# X | test1 -> R² = 0.9452, MSE = 5.7440e-03
# X | test2 -> R² = -1.4419, MSE = 2.0095e-01
# X | test3 -> R² = 0.8423, MSE = 1.4512e-02
# X | val -> R² = 0.8393, MSE = 1.5369e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.789227 | Val Loss 0.670446
# Epoch 100 | Train Loss 0.402005 | Val Loss 0.393718
# Epoch 200 | Train Loss 0.399091 | Val Loss 0.393599
# Epoch 300 | Train Loss 0.397716 | Val Loss 0.393698
# Early stopping at epoch 358
# X | train1 -> R² = 0.9470, MSE = 5.7096e-03
# X | train2 -> R² = -1.3246, MSE = 1.9587e-01
# X | test1 -> R² = 0.8999, MSE = 1.0489e-02
# X | test2 -> R² = -1.3545, MSE = 1.9376e-01
# X | test3 -> R² = 0.8271, MSE = 1.5905e-02
# X | val -> R² = 0.7980, MSE = 1.9315e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.560072 | Val Loss 0.541716
# Epoch 100 | Train Loss 0.314758 | Val Loss 0.395690
# Epoch 200 | Train Loss 0.313438 | Val Loss 0.394986
# Epoch 300 | Train Loss 0.312476 | Val Loss 0.394922
# Early stopping at epoch 310
# X | train1 -> R² = 0.9571, MSE = 4.6281e-03
# X | train2 -> R² = -1.2780, MSE = 1.9194e-01
# X | test1 -> R² = 0.9196, MSE = 8.4235e-03
# X | test2 -> R² = -1.3173, MSE = 1.9070e-01
# X | test3 -> R² = 0.9102, MSE = 8.2622e-03
# X | val -> R² = 0.9190, MSE = 7.7439e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.647456 | Val Loss 0.604387
# Epoch 100 | Train Loss 0.313914 | Val Loss 0.395975
# Epoch 200 | Train Loss 0.312511 | Val Loss 0.395079
# Epoch 300 | Train Loss 0.311621 | Val Loss 0.395046
# Early stopping at epoch 341
# X | train1 -> R² = 0.9549, MSE = 4.8678e-03
# X | train2 -> R² = -1.1962, MSE = 1.8505e-01
# X | test1 -> R² = 0.9170, MSE = 8.6973e-03
# X | test2 -> R² = -1.2339, MSE = 1.8383e-01
# X | test3 -> R² = 0.9020, MSE = 9.0205e-03
# X | val -> R² = 0.9109, MSE = 8.5229e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.520983 | Val Loss 0.514598
# Epoch 100 | Train Loss 0.313843 | Val Loss 0.395507
# Epoch 200 | Train Loss 0.312252 | Val Loss 0.394924
# Epoch 300 | Train Loss 0.311257 | Val Loss 0.395350
# Early stopping at epoch 309
# X | train1 -> R² = 0.9396, MSE = 6.5143e-03
# X | train2 -> R² = -1.1830, MSE = 1.8394e-01
# X | test1 -> R² = 0.8950, MSE = 1.0996e-02
# X | test2 -> R² = -1.2213, MSE = 1.8280e-01
# X | test3 -> R² = 0.8878, MSE = 1.0322e-02
# X | val -> R² = 0.8934, MSE = 1.0192e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.650412 | Val Loss 0.614052
# Epoch 100 | Train Loss 0.314333 | Val Loss 0.395556
# Epoch 200 | Train Loss 0.313051 | Val Loss 0.395070
# Epoch 300 | Train Loss 0.312147 | Val Loss 0.395101
# Early stopping at epoch 342
# X | train1 -> R² = 0.9474, MSE = 5.6740e-03
# X | train2 -> R² = -1.1777, MSE = 1.8349e-01
# X | test1 -> R² = 0.9091, MSE = 9.5186e-03
# X | test2 -> R² = -1.2190, MSE = 1.8261e-01
# X | test3 -> R² = 0.8877, MSE = 1.0335e-02
# X | val -> R² = 0.8920, MSE = 1.0330e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.594087 | Val Loss 0.571135
# Epoch 100 | Train Loss 0.314129 | Val Loss 0.395719
# Epoch 200 | Train Loss 0.312811 | Val Loss 0.395002
# Epoch 300 | Train Loss 0.311875 | Val Loss 0.395165
# Early stopping at epoch 312
# X | train1 -> R² = 0.9394, MSE = 6.5353e-03
# X | train2 -> R² = -1.1681, MSE = 1.8269e-01
# X | test1 -> R² = 0.8981, MSE = 1.0675e-02
# X | test2 -> R² = -1.2093, MSE = 1.8181e-01
# X | test3 -> R² = 0.8865, MSE = 1.0439e-02
# X | val -> R² = 0.8936, MSE = 1.0176e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.662198 | Val Loss 0.619707
# Epoch 100 | Train Loss 0.314261 | Val Loss 0.394824
# Epoch 200 | Train Loss 0.312935 | Val Loss 0.394826
# Epoch 300 | Train Loss 0.312175 | Val Loss 0.394874
# Early stopping at epoch 333
# X | train1 -> R² = 0.9564, MSE = 4.6959e-03
# X | train2 -> R² = -1.2744, MSE = 1.9164e-01
# X | test1 -> R² = 0.9195, MSE = 8.4369e-03
# X | test2 -> R² = -1.3129, MSE = 1.9033e-01
# X | test3 -> R² = 0.8992, MSE = 9.2757e-03
# X | val -> R² = 0.9003, MSE = 9.5381e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.561801 | Val Loss 0.541488
# Epoch 100 | Train Loss 0.313422 | Val Loss 0.395503
# Epoch 200 | Train Loss 0.312253 | Val Loss 0.394970
# Epoch 300 | Train Loss 0.311450 | Val Loss 0.395301
# Epoch 400 | Train Loss 0.310384 | Val Loss 0.396094
# Early stopping at epoch 432
# X | train1 -> R² = 0.9787, MSE = 2.2932e-03
# X | train2 -> R² = -1.3795, MSE = 2.0050e-01
# X | test1 -> R² = 0.9608, MSE = 4.1107e-03
# X | test2 -> R² = -1.4329, MSE = 2.0021e-01
# X | test3 -> R² = 0.8814, MSE = 1.0907e-02
# X | val -> R² = 0.8925, MSE = 1.0284e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.608152 | Val Loss 0.578483
# Epoch 100 | Train Loss 0.313782 | Val Loss 0.394967
# Epoch 200 | Train Loss 0.312440 | Val Loss 0.394730
# Epoch 300 | Train Loss 0.311619 | Val Loss 0.395104
# Early stopping at epoch 312
# X | train1 -> R² = 0.9418, MSE = 6.2729e-03
# X | train2 -> R² = -1.1830, MSE = 1.8394e-01
# X | test1 -> R² = 0.8996, MSE = 1.0515e-02
# X | test2 -> R² = -1.2225, MSE = 1.8290e-01
# X | test3 -> R² = 0.8901, MSE = 1.0107e-02
# X | val -> R² = 0.8971, MSE = 9.8356e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.693060 | Val Loss 0.647274
# Epoch 100 | Train Loss 0.314247 | Val Loss 0.394932
# Epoch 200 | Train Loss 0.312919 | Val Loss 0.394975
# Epoch 300 | Train Loss 0.312065 | Val Loss 0.395155
# Early stopping at epoch 335
# X | train1 -> R² = 0.9543, MSE = 4.9223e-03
# X | train2 -> R² = -1.2596, MSE = 1.9040e-01
# X | test1 -> R² = 0.9199, MSE = 8.3957e-03
# X | test2 -> R² = -1.3032, MSE = 1.8954e-01
# X | test3 -> R² = 0.8991, MSE = 9.2873e-03
# X | val -> R² = 0.9018, MSE = 9.3935e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.635709 | Val Loss 0.600170
# Epoch 100 | Train Loss 0.313887 | Val Loss 0.395582
# Epoch 200 | Train Loss 0.312573 | Val Loss 0.395031
# Epoch 300 | Train Loss 0.311746 | Val Loss 0.395251
# Early stopping at epoch 331
# X | train1 -> R² = 0.9687, MSE = 3.3715e-03
# X | train2 -> R² = -1.3177, MSE = 1.9529e-01
# X | test1 -> R² = 0.9397, MSE = 6.3135e-03
# X | test2 -> R² = -1.3581, MSE = 1.9405e-01
# X | test3 -> R² = 0.9236, MSE = 7.0337e-03
# X | val -> R² = 0.9342, MSE = 6.2923e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.581016 | Val Loss 0.559952
# Epoch 100 | Train Loss 0.314303 | Val Loss 0.395076
# Epoch 200 | Train Loss 0.312826 | Val Loss 0.394940
# Epoch 300 | Train Loss 0.311923 | Val Loss 0.395067
# Early stopping at epoch 339
# X | train1 -> R² = 0.9437, MSE = 6.0708e-03
# X | train2 -> R² = -1.2100, MSE = 1.8622e-01
# X | test1 -> R² = 0.9046, MSE = 9.9917e-03
# X | test2 -> R² = -1.2530, MSE = 1.8540e-01
# X | test3 -> R² = 0.8818, MSE = 1.0873e-02
# X | val -> R² = 0.8814, MSE = 1.1339e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.614025 | Val Loss 0.579482
# Epoch 100 | Train Loss 0.313772 | Val Loss 0.395718
# Epoch 200 | Train Loss 0.312381 | Val Loss 0.394997
# Epoch 300 | Train Loss 0.311520 | Val Loss 0.395159
# Early stopping at epoch 329
# X | train1 -> R² = 0.9635, MSE = 3.9305e-03
# X | train2 -> R² = -1.2541, MSE = 1.8993e-01
# X | test1 -> R² = 0.9303, MSE = 7.3060e-03
# X | test2 -> R² = -1.2912, MSE = 1.8855e-01
# X | test3 -> R² = 0.9153, MSE = 7.7896e-03
# X | val -> R² = 0.9268, MSE = 6.9994e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.536925 | Val Loss 0.523424
# Epoch 100 | Train Loss 0.314363 | Val Loss 0.395481
# Epoch 200 | Train Loss 0.312866 | Val Loss 0.394843
# Epoch 300 | Train Loss 0.311834 | Val Loss 0.395061
# Early stopping at epoch 309
# X | train1 -> R² = 0.9434, MSE = 6.0991e-03
# X | train2 -> R² = -1.2004, MSE = 1.8541e-01
# X | test1 -> R² = 0.9020, MSE = 1.0264e-02
# X | test2 -> R² = -1.2412, MSE = 1.8443e-01
# X | test3 -> R² = 0.8935, MSE = 9.7960e-03
# X | val -> R² = 0.9009, MSE = 9.4802e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.627260 | Val Loss 0.596207
# Epoch 100 | Train Loss 0.314530 | Val Loss 0.395355
# Epoch 200 | Train Loss 0.312917 | Val Loss 0.395117
# Epoch 300 | Train Loss 0.311820 | Val Loss 0.395466
# Early stopping at epoch 313
# X | train1 -> R² = 0.9386, MSE = 6.6163e-03
# X | train2 -> R² = -1.2057, MSE = 1.8585e-01
# X | test1 -> R² = 0.8949, MSE = 1.1007e-02
# X | test2 -> R² = -1.2453, MSE = 1.8477e-01
# X | test3 -> R² = 0.8831, MSE = 1.0756e-02
# X | val -> R² = 0.8846, MSE = 1.1034e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.562832 | Val Loss 0.545855
# Epoch 100 | Train Loss 0.314028 | Val Loss 0.395434
# Epoch 200 | Train Loss 0.312684 | Val Loss 0.395036
# Epoch 300 | Train Loss 0.311695 | Val Loss 0.395244
# Early stopping at epoch 311
# X | train1 -> R² = 0.9495, MSE = 5.4472e-03
# X | train2 -> R² = -1.2445, MSE = 1.8912e-01
# X | test1 -> R² = 0.9086, MSE = 9.5718e-03
# X | test2 -> R² = -1.2835, MSE = 1.8792e-01
# X | test3 -> R² = 0.8988, MSE = 9.3115e-03
# X | val -> R² = 0.9041, MSE = 9.1703e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.568307 | Val Loss 0.612145
# Epoch 100 | Train Loss 0.228395 | Val Loss 0.395029
# Epoch 200 | Train Loss 0.226643 | Val Loss 0.395776
# Epoch 300 | Train Loss 0.225821 | Val Loss 0.396543
# Early stopping at epoch 315
# X | train1 -> R² = 0.9470, MSE = 5.7105e-03
# X | train2 -> R² = -1.2463, MSE = 1.8927e-01
# X | test1 -> R² = 0.9094, MSE = 9.4871e-03
# X | test2 -> R² = -1.2904, MSE = 1.8848e-01
# X | test3 -> R² = 0.8970, MSE = 9.4790e-03
# X | val -> R² = 0.9028, MSE = 9.2955e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.483846 | Val Loss 0.543819
# Epoch 100 | Train Loss 0.227953 | Val Loss 0.396151
# Epoch 200 | Train Loss 0.226377 | Val Loss 0.396077
# Epoch 300 | Train Loss 0.225149 | Val Loss 0.396506
# Early stopping at epoch 310
# X | train1 -> R² = 0.9524, MSE = 5.1296e-03
# X | train2 -> R² = -1.2619, MSE = 1.9059e-01
# X | test1 -> R² = 0.9124, MSE = 9.1792e-03
# X | test2 -> R² = -1.3001, MSE = 1.8928e-01
# X | test3 -> R² = 0.9024, MSE = 8.9785e-03
# X | val -> R² = 0.9094, MSE = 8.6616e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.535483 | Val Loss 0.584184
# Epoch 100 | Train Loss 0.228037 | Val Loss 0.395606
# Epoch 200 | Train Loss 0.225906 | Val Loss 0.395943
# Epoch 300 | Train Loss 0.224873 | Val Loss 0.397074
# Early stopping at epoch 312
# X | train1 -> R² = 0.9536, MSE = 5.0080e-03
# X | train2 -> R² = -1.2548, MSE = 1.8999e-01
# X | test1 -> R² = 0.9182, MSE = 8.5731e-03
# X | test2 -> R² = -1.2974, MSE = 1.8906e-01
# X | test3 -> R² = 0.9061, MSE = 8.6370e-03
# X | val -> R² = 0.9165, MSE = 7.9865e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.592729 | Val Loss 0.631380
# Epoch 100 | Train Loss 0.228572 | Val Loss 0.395246
# Epoch 200 | Train Loss 0.226795 | Val Loss 0.395902
# Epoch 300 | Train Loss 0.225774 | Val Loss 0.396529
# Early stopping at epoch 315
# X | train1 -> R² = 0.9405, MSE = 6.4106e-03
# X | train2 -> R² = -1.2259, MSE = 1.8755e-01
# X | test1 -> R² = 0.8985, MSE = 1.0629e-02
# X | test2 -> R² = -1.2679, MSE = 1.8663e-01
# X | test3 -> R² = 0.8855, MSE = 1.0538e-02
# X | val -> R² = 0.8862, MSE = 1.0880e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.546270 | Val Loss 0.594122
# Epoch 100 | Train Loss 0.228476 | Val Loss 0.395868
# Epoch 200 | Train Loss 0.226756 | Val Loss 0.395874
# Epoch 300 | Train Loss 0.225779 | Val Loss 0.396242
# Early stopping at epoch 330
# X | train1 -> R² = 0.9645, MSE = 3.8229e-03
# X | train2 -> R² = -1.3073, MSE = 1.9442e-01
# X | test1 -> R² = 0.9319, MSE = 7.1315e-03
# X | test2 -> R² = -1.3467, MSE = 1.9312e-01
# X | test3 -> R² = 0.9144, MSE = 7.8780e-03
# X | val -> R² = 0.9203, MSE = 7.6242e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.515391 | Val Loss 0.572615
# Epoch 100 | Train Loss 0.228468 | Val Loss 0.395197
# Epoch 200 | Train Loss 0.226897 | Val Loss 0.395885
# Epoch 300 | Train Loss 0.225864 | Val Loss 0.396387
# Early stopping at epoch 313
# X | train1 -> R² = 0.9283, MSE = 7.7261e-03
# X | train2 -> R² = -1.1757, MSE = 1.8332e-01
# X | test1 -> R² = 0.8811, MSE = 1.2456e-02
# X | test2 -> R² = -1.2164, MSE = 1.8240e-01
# X | test3 -> R² = 0.8683, MSE = 1.2118e-02
# X | val -> R² = 0.8659, MSE = 1.2824e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.494949 | Val Loss 0.550650
# Epoch 100 | Train Loss 0.227916 | Val Loss 0.396260
# Epoch 200 | Train Loss 0.226119 | Val Loss 0.395972
# Epoch 300 | Train Loss 0.225000 | Val Loss 0.396815
# Early stopping at epoch 310
# X | train1 -> R² = 0.9471, MSE = 5.7021e-03
# X | train2 -> R² = -1.1736, MSE = 1.8315e-01
# X | test1 -> R² = 0.9087, MSE = 9.5641e-03
# X | test2 -> R² = -1.2148, MSE = 1.8226e-01
# X | test3 -> R² = 0.8990, MSE = 9.2964e-03
# X | val -> R² = 0.9119, MSE = 8.4233e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.458482 | Val Loss 0.525580
# Epoch 100 | Train Loss 0.228774 | Val Loss 0.395704
# Epoch 200 | Train Loss 0.226469 | Val Loss 0.396002
# Epoch 300 | Train Loss 0.225253 | Val Loss 0.396791
# Early stopping at epoch 309
# X | train1 -> R² = 0.9520, MSE = 5.1775e-03
# X | train2 -> R² = -1.2356, MSE = 1.8837e-01
# X | test1 -> R² = 0.9122, MSE = 9.2017e-03
# X | test2 -> R² = -1.2747, MSE = 1.8720e-01
# X | test3 -> R² = 0.9043, MSE = 8.8073e-03
# X | val -> R² = 0.9129, MSE = 8.3250e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.576837 | Val Loss 0.619802
# Epoch 100 | Train Loss 0.228717 | Val Loss 0.395507
# Epoch 200 | Train Loss 0.226590 | Val Loss 0.395983
# Epoch 300 | Train Loss 0.225423 | Val Loss 0.396745
# Early stopping at epoch 331
# X | train1 -> R² = 0.9459, MSE = 5.8299e-03
# X | train2 -> R² = -1.2587, MSE = 1.9032e-01
# X | test1 -> R² = 0.9086, MSE = 9.5742e-03
# X | test2 -> R² = -1.3043, MSE = 1.8962e-01
# X | test3 -> R² = 0.8874, MSE = 1.0362e-02
# X | val -> R² = 0.8858, MSE = 1.0918e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.507389 | Val Loss 0.564842
# Epoch 100 | Train Loss 0.228404 | Val Loss 0.396372
# Epoch 200 | Train Loss 0.226017 | Val Loss 0.396023
# Epoch 300 | Train Loss 0.224026 | Val Loss 0.397652
# Early stopping at epoch 311
# X | train1 -> R² = 0.9494, MSE = 5.4564e-03
# X | train2 -> R² = -1.2374, MSE = 1.8852e-01
# X | test1 -> R² = 0.9071, MSE = 9.7295e-03
# X | test2 -> R² = -1.2751, MSE = 1.8723e-01
# X | test3 -> R² = 0.8983, MSE = 9.3589e-03
# X | val -> R² = 0.9030, MSE = 9.2746e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.484998 | Val Loss 0.549617
# Epoch 100 | Train Loss 0.228490 | Val Loss 0.395551
# Epoch 200 | Train Loss 0.226285 | Val Loss 0.395978
# Epoch 300 | Train Loss 0.224979 | Val Loss 0.396907
# Early stopping at epoch 311
# X | train1 -> R² = 0.9026, MSE = 1.0498e-02
# X | train2 -> R² = -1.1210, MSE = 1.7872e-01
# X | test1 -> R² = 0.8505, MSE = 1.5666e-02
# X | test2 -> R² = -1.1635, MSE = 1.7805e-01
# X | test3 -> R² = 0.8371, MSE = 1.4985e-02
# X | val -> R² = 0.8280, MSE = 1.6447e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.515057 | Val Loss 0.565991
# Epoch 100 | Train Loss 0.228104 | Val Loss 0.396134
# Epoch 200 | Train Loss 0.226011 | Val Loss 0.395942
# Epoch 300 | Train Loss 0.224965 | Val Loss 0.396579
# Early stopping at epoch 311
# X | train1 -> R² = 0.9546, MSE = 4.8998e-03
# X | train2 -> R² = -1.2482, MSE = 1.8944e-01
# X | test1 -> R² = 0.9142, MSE = 8.9932e-03
# X | test2 -> R² = -1.2855, MSE = 1.8809e-01
# X | test3 -> R² = 0.9061, MSE = 8.6369e-03
# X | val -> R² = 0.9142, MSE = 8.2029e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.509607 | Val Loss 0.563875
# Epoch 100 | Train Loss 0.228506 | Val Loss 0.395587
# Epoch 200 | Train Loss 0.226407 | Val Loss 0.395875
# Epoch 300 | Train Loss 0.225466 | Val Loss 0.396614
# Early stopping at epoch 311
# X | train1 -> R² = 0.9342, MSE = 7.0952e-03
# X | train2 -> R² = -1.1756, MSE = 1.8332e-01
# X | test1 -> R² = 0.8903, MSE = 1.1488e-02
# X | test2 -> R² = -1.2173, MSE = 1.8247e-01
# X | test3 -> R² = 0.8816, MSE = 1.0898e-02
# X | val -> R² = 0.8854, MSE = 1.0961e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.621536 | Val Loss 0.654733
# Epoch 100 | Train Loss 0.228597 | Val Loss 0.395271
# Epoch 200 | Train Loss 0.226893 | Val Loss 0.395971
# Epoch 300 | Train Loss 0.225993 | Val Loss 0.396449
# Early stopping at epoch 335
# X | train1 -> R² = 0.9551, MSE = 4.8464e-03
# X | train2 -> R² = -1.3009, MSE = 1.9387e-01
# X | test1 -> R² = 0.9208, MSE = 8.2988e-03
# X | test2 -> R² = -1.3458, MSE = 1.9304e-01
# X | test3 -> R² = 0.8991, MSE = 9.2801e-03
# X | val -> R² = 0.8994, MSE = 9.6203e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.555823 | Val Loss 0.602457
# Epoch 100 | Train Loss 0.228226 | Val Loss 0.395783
# Epoch 200 | Train Loss 0.226348 | Val Loss 0.396054
# Epoch 300 | Train Loss 0.225193 | Val Loss 0.396755
# Early stopping at epoch 332
# X | train1 -> R² = 0.9554, MSE = 4.8105e-03
# X | train2 -> R² = -1.2642, MSE = 1.9078e-01
# X | test1 -> R² = 0.9208, MSE = 8.2994e-03
# X | test2 -> R² = -1.3075, MSE = 1.8989e-01
# X | test3 -> R² = 0.9020, MSE = 9.0158e-03
# X | val -> R² = 0.9062, MSE = 8.9688e-03
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.697522 | Val Loss 0.586792
# Epoch 100 | Train Loss 0.399444 | Val Loss 0.394535
# Epoch 200 | Train Loss 0.398193 | Val Loss 0.394199
# Epoch 300 | Train Loss 0.396966 | Val Loss 0.393851
# Early stopping at epoch 313
# X | train1 -> R² = 0.9524, MSE = 5.1277e-03
# X | train2 -> R² = -1.2760, MSE = 1.9178e-01
# X | test1 -> R² = 0.9166, MSE = 8.7384e-03
# X | test2 -> R² = -1.3182, MSE = 1.9077e-01
# X | test3 -> R² = 0.9014, MSE = 9.0738e-03
# X | val -> R² = 0.9095, MSE = 8.6494e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.582707 | Val Loss 0.497315
# Epoch 100 | Train Loss 0.399116 | Val Loss 0.395368
# Epoch 200 | Train Loss 0.397982 | Val Loss 0.394450
# Epoch 300 | Train Loss 0.396732 | Val Loss 0.394242
# Epoch 400 | Train Loss 0.395231 | Val Loss 0.394875
# Epoch 500 | Train Loss 0.393851 | Val Loss 0.396339
# Early stopping at epoch 517
# X | train1 -> R² = 0.9783, MSE = 2.3349e-03
# X | train2 -> R² = -1.3587, MSE = 1.9875e-01
# X | test1 -> R² = 0.9617, MSE = 4.0169e-03
# X | test2 -> R² = -1.4167, MSE = 1.9887e-01
# X | test3 -> R² = 0.8827, MSE = 1.0789e-02
# X | val -> R² = 0.8975, MSE = 9.8056e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.644613 | Val Loss 0.544988
# Epoch 100 | Train Loss 0.398711 | Val Loss 0.394436
# Epoch 200 | Train Loss 0.397454 | Val Loss 0.394018
# Epoch 300 | Train Loss 0.396626 | Val Loss 0.394084
# Early stopping at epoch 311
# X | train1 -> R² = 0.9469, MSE = 5.7257e-03
# X | train2 -> R² = -1.2261, MSE = 1.8758e-01
# X | test1 -> R² = 0.9064, MSE = 9.8038e-03
# X | test2 -> R² = -1.2661, MSE = 1.8648e-01
# X | test3 -> R² = 0.8956, MSE = 9.6041e-03
# X | val -> R² = 0.9010, MSE = 9.4623e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.788215 | Val Loss 0.656771
# Epoch 100 | Train Loss 0.399555 | Val Loss 0.394653
# Epoch 200 | Train Loss 0.398077 | Val Loss 0.394351
# Epoch 300 | Train Loss 0.397062 | Val Loss 0.394109
# Early stopping at epoch 335
# X | train1 -> R² = 0.9556, MSE = 4.7883e-03
# X | train2 -> R² = -1.2670, MSE = 1.9102e-01
# X | test1 -> R² = 0.9203, MSE = 8.3515e-03
# X | test2 -> R² = -1.3077, MSE = 1.8991e-01
# X | test3 -> R² = 0.9012, MSE = 9.0899e-03
# X | val -> R² = 0.9053, MSE = 9.0583e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.728134 | Val Loss 0.610131
# Epoch 100 | Train Loss 0.399231 | Val Loss 0.394879
# Epoch 200 | Train Loss 0.398025 | Val Loss 0.394339
# Epoch 300 | Train Loss 0.397156 | Val Loss 0.394152
# Early stopping at epoch 331
# X | train1 -> R² = 0.9584, MSE = 4.4885e-03
# X | train2 -> R² = -1.2653, MSE = 1.9087e-01
# X | test1 -> R² = 0.9246, MSE = 7.8997e-03
# X | test2 -> R² = -1.3062, MSE = 1.8978e-01
# X | test3 -> R² = 0.9062, MSE = 8.6324e-03
# X | val -> R² = 0.9126, MSE = 8.3607e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.636732 | Val Loss 0.538903
# Epoch 100 | Train Loss 0.399557 | Val Loss 0.394697
# Epoch 200 | Train Loss 0.398289 | Val Loss 0.394129
# Epoch 300 | Train Loss 0.397313 | Val Loss 0.393923
# Early stopping at epoch 362
# X | train1 -> R² = 0.9668, MSE = 3.5777e-03
# X | train2 -> R² = -1.3392, MSE = 1.9710e-01
# X | test1 -> R² = 0.9390, MSE = 6.3945e-03
# X | test2 -> R² = -1.3821, MSE = 1.9603e-01
# X | test3 -> R² = 0.9128, MSE = 8.0270e-03
# X | val -> R² = 0.9153, MSE = 8.0978e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.593840 | Val Loss 0.504445
# Epoch 100 | Train Loss 0.398994 | Val Loss 0.395516
# Epoch 200 | Train Loss 0.397718 | Val Loss 0.394471
# Epoch 300 | Train Loss 0.396536 | Val Loss 0.394279
# Epoch 400 | Train Loss 0.395240 | Val Loss 0.394616
# Early stopping at epoch 443
# X | train1 -> R² = 0.9777, MSE = 2.4031e-03
# X | train2 -> R² = -1.3815, MSE = 2.0067e-01
# X | test1 -> R² = 0.9594, MSE = 4.2518e-03
# X | test2 -> R² = -1.4317, MSE = 2.0011e-01
# X | test3 -> R² = 0.9191, MSE = 7.4450e-03
# X | val -> R² = 0.9249, MSE = 7.1773e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.685494 | Val Loss 0.577342
# Epoch 100 | Train Loss 0.398799 | Val Loss 0.394578
# Epoch 200 | Train Loss 0.397532 | Val Loss 0.393930
# Epoch 300 | Train Loss 0.396731 | Val Loss 0.393934
# Epoch 400 | Train Loss 0.395837 | Val Loss 0.394108
# Early stopping at epoch 439
# X | train1 -> R² = 0.9766, MSE = 2.5191e-03
# X | train2 -> R² = -1.3842, MSE = 2.0089e-01
# X | test1 -> R² = 0.9580, MSE = 4.3952e-03
# X | test2 -> R² = -1.4370, MSE = 2.0054e-01
# X | test3 -> R² = 0.9039, MSE = 8.8442e-03
# X | val -> R² = 0.9092, MSE = 8.6853e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.739760 | Val Loss 0.620371
# Epoch 100 | Train Loss 0.399595 | Val Loss 0.394920
# Epoch 200 | Train Loss 0.398146 | Val Loss 0.394429
# Epoch 300 | Train Loss 0.397199 | Val Loss 0.394210
# Early stopping at epoch 332
# X | train1 -> R² = 0.9579, MSE = 4.5377e-03
# X | train2 -> R² = -1.2799, MSE = 1.9210e-01
# X | test1 -> R² = 0.9247, MSE = 7.8837e-03
# X | test2 -> R² = -1.3220, MSE = 1.9109e-01
# X | test3 -> R² = 0.9065, MSE = 8.6045e-03
# X | val -> R² = 0.9128, MSE = 8.3372e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.743409 | Val Loss 0.621299
# Epoch 100 | Train Loss 0.399317 | Val Loss 0.394944
# Epoch 200 | Train Loss 0.398146 | Val Loss 0.394387
# Epoch 300 | Train Loss 0.397154 | Val Loss 0.394034
# Epoch 400 | Train Loss 0.396122 | Val Loss 0.394150
# Epoch 500 | Train Loss 0.394979 | Val Loss 0.394722
# Early stopping at epoch 522
# X | train1 -> R² = 0.9781, MSE = 2.3610e-03
# X | train2 -> R² = -1.3620, MSE = 1.9902e-01
# X | test1 -> R² = 0.9615, MSE = 4.0345e-03
# X | test2 -> R² = -1.4195, MSE = 1.9911e-01
# X | test3 -> R² = 0.8850, MSE = 1.0583e-02
# X | val -> R² = 0.8982, MSE = 9.7370e-03
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.599948 | Val Loss 0.513229
# Epoch 100 | Train Loss 0.399346 | Val Loss 0.394623
# Epoch 200 | Train Loss 0.397937 | Val Loss 0.394159
# Epoch 300 | Train Loss 0.396983 | Val Loss 0.394077
# Early stopping at epoch 309
# X | train1 -> R² = 0.9341, MSE = 7.1069e-03
# X | train2 -> R² = -1.1874, MSE = 1.8431e-01
# X | test1 -> R² = 0.8910, MSE = 1.1417e-02
# X | test2 -> R² = -1.2290, MSE = 1.8344e-01
# X | test3 -> R² = 0.8805, MSE = 1.0993e-02
# X | val -> R² = 0.8833, MSE = 1.1155e-02
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.615059 | Val Loss 0.521038
# Epoch 100 | Train Loss 0.398965 | Val Loss 0.395296
# ...
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.716347 | Val Loss 0.749678
# Epoch 100 | Train Loss 0.248760 | Val Loss 0.490320
# Epoch 200 | Train Loss 0.235302 | Val Loss 0.460257
# Epoch 300 | Train Loss 0.231902 | Val Loss 0.429797
# Epoch 400 | Train Loss 0.227392 | Val Loss 0.404443
# Epoch 500 | Train Loss 0.224190 | Val Loss 0.399729
# Epoch 600 | Train Loss 0.223087 | Val Loss 0.400126
# Epoch 700 | Train Loss 0.221528 | Val Loss 0.399487
# Early stopping at epoch 757
# X | train1 -> R² = 0.9833, MSE = 1.8061e-03
# X | train2 -> R² = -1.3813, MSE = 2.0065e-01
# X | test1 -> R² = 0.9789, MSE = 2.2153e-03
# X | test2 -> R² = -1.4068, MSE = 1.9806e-01
# X | test3 -> R² = 0.0058, MSE = 9.1466e-02
# X | val -> R² = 0.1894, MSE = 7.7511e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.717622 | Val Loss 0.751091
# Epoch 100 | Train Loss 0.247939 | Val Loss 0.503318
# Epoch 200 | Train Loss 0.237796 | Val Loss 0.489001
# Epoch 300 | Train Loss 0.236940 | Val Loss 0.476444
# Early stopping at epoch 351
# X | train1 -> R² = 0.2939, MSE = 7.6139e-02
# X | train2 -> R² = -0.6994, MSE = 1.4319e-01
# X | test1 -> R² = -0.1249, MSE = 1.1784e-01
# X | test2 -> R² = -0.7631, MSE = 1.4509e-01
# X | test3 -> R² = -6.0730, MSE = 6.5075e-01
# X | val -> R² = -5.6630, MSE = 6.3713e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.717580 | Val Loss 0.750600
# Epoch 100 | Train Loss 0.245808 | Val Loss 0.476932
# Epoch 200 | Train Loss 0.233956 | Val Loss 0.442089
# Epoch 300 | Train Loss 0.229039 | Val Loss 0.408061
# Epoch 400 | Train Loss 0.225128 | Val Loss 0.402311
# Epoch 500 | Train Loss 0.224397 | Val Loss 0.402757
# Epoch 600 | Train Loss 0.223696 | Val Loss 0.402226
# Early stopping at epoch 648
# X | train1 -> R² = 0.9820, MSE = 1.9399e-03
# X | train2 -> R² = -1.3514, MSE = 1.9813e-01
# X | test1 -> R² = 0.9729, MSE = 2.8368e-03
# X | test2 -> R² = -1.3759, MSE = 1.9552e-01
# X | test3 -> R² = -0.2072, MSE = 1.1107e-01
# X | val -> R² = 0.0437, MSE = 9.1449e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.718486 | Val Loss 0.750928
# Epoch 100 | Train Loss 0.265054 | Val Loss 0.605277
# Epoch 200 | Train Loss 0.260067 | Val Loss 0.634061
# Epoch 300 | Train Loss 0.259530 | Val Loss 0.634857
# Early stopping at epoch 357
# X | train1 -> R² = 0.6557, MSE = 3.7127e-02
# X | train2 -> R² = -1.1465, MSE = 1.8087e-01
# X | test1 -> R² = 0.2557, MSE = 7.7972e-02
# X | test2 -> R² = -1.1277, MSE = 1.7509e-01
# X | test3 -> R² = -1.3024, MSE = 2.1183e-01
# X | val -> R² = -2.1676, MSE = 3.0289e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.715775 | Val Loss 0.748963
# Epoch 100 | Train Loss 0.245358 | Val Loss 0.508717
# Epoch 200 | Train Loss 0.237564 | Val Loss 0.486539
# Epoch 300 | Train Loss 0.236035 | Val Loss 0.468071
# Early stopping at epoch 349
# X | train1 -> R² = 0.2466, MSE = 8.1234e-02
# X | train2 -> R² = -0.6523, MSE = 1.3923e-01
# X | test1 -> R² = -0.1618, MSE = 1.2171e-01
# X | test2 -> R² = -0.7235, MSE = 1.4183e-01
# X | test3 -> R² = -6.2066, MSE = 6.6304e-01
# X | val -> R² = -5.6344, MSE = 6.3440e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.715572 | Val Loss 0.748861
# Epoch 100 | Train Loss 0.246003 | Val Loss 0.498219
# Epoch 200 | Train Loss 0.236068 | Val Loss 0.467013
# Epoch 300 | Train Loss 0.233024 | Val Loss 0.436095
# Epoch 400 | Train Loss 0.227288 | Val Loss 0.403231
# Epoch 500 | Train Loss 0.225180 | Val Loss 0.399666
# Epoch 600 | Train Loss 0.224300 | Val Loss 0.399570
# Epoch 700 | Train Loss 0.222984 | Val Loss 0.399130
# Early stopping at epoch 759
# X | train1 -> R² = 0.9826, MSE = 1.8793e-03
# X | train2 -> R² = -1.3838, MSE = 2.0086e-01
# X | test1 -> R² = 0.9778, MSE = 2.3286e-03
# X | test2 -> R² = -1.4064, MSE = 1.9803e-01
# X | test3 -> R² = -0.0195, MSE = 9.3799e-02
# X | val -> R² = 0.1711, MSE = 7.9262e-02
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.719556 | Val Loss 0.752593
# Epoch 100 | Train Loss 0.245401 | Val Loss 0.498567
# Epoch 200 | Train Loss 0.234501 | Val Loss 0.468081
# Epoch 300 | Train Loss 0.227339 | Val Loss 0.421436
# Epoch 400 | Train Loss 0.225261 | Val Loss 0.413124
# Epoch 500 | Train Loss 0.224456 | Val Loss 0.410238
# Epoch 600 | Train Loss 0.222550 | Val Loss 0.405524
# Epoch 700 | Train Loss 0.217828 | Val Loss 0.402938
# Epoch 800 | Train Loss 0.213073 | Val Loss 0.403241
# Epoch 900 | Train Loss 0.207396 | Val Loss 0.410370
# Early stopping at epoch 996
# X | train1 -> R² = 0.9876, MSE = 1.3343e-03
# X | train2 -> R² = -1.3764, MSE = 2.0023e-01
# X | test1 -> R² = 0.9831, MSE = 1.7705e-03
# X | test2 -> R² = -1.3809, MSE = 1.9594e-01
# X | test3 -> R² = -1.3070, MSE = 2.1225e-01
# X | val -> R² = -0.6840, MSE = 1.6103e-01
# Modelo [32, 16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.880785 | Val Loss 0.750614
# Epoch 100 | Train Loss 0.423995 | Val Loss 0.493362
# Epoch 200 | Train Loss 0.413999 | Val Loss 0.460632
# Epoch 300 | Train Loss 0.407122 | Val Loss 0.412650
# Epoch 400 | Train Loss 0.401688 | Val Loss 0.399107
# Epoch 500 | Train Loss 0.395511 | Val Loss 0.394739
# Epoch 600 | Train Loss 0.393550 | Val Loss 0.396404
# Epoch 700 | Train Loss 0.391846 | Val Loss 0.398919
# Early stopping at epoch 780
# X | train1 -> R² = 0.9808, MSE = 2.0750e-03
# X | train2 -> R² = -1.3205, MSE = 1.9553e-01
# X | test1 -> R² = 0.9760, MSE = 2.5114e-03
# X | test2 -> R² = -1.3798, MSE = 1.9584e-01
# X | test3 -> R² = 0.8022, MSE = 1.8198e-02
# X | val -> R² = 0.8246, MSE = 1.6769e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.881608 | Val Loss 0.751448
# Epoch 100 | Train Loss 0.421560 | Val Loss 0.455316
# Epoch 200 | Train Loss 0.406526 | Val Loss 0.405737
# Epoch 300 | Train Loss 0.401499 | Val Loss 0.400856
# Epoch 400 | Train Loss 0.398045 | Val Loss 0.398698
# Epoch 500 | Train Loss 0.391330 | Val Loss 0.398155
# Epoch 600 | Train Loss 0.389163 | Val Loss 0.406305
# Epoch 700 | Train Loss 0.386224 | Val Loss 0.433437
# Early stopping at epoch 733
# X | train1 -> R² = 0.9793, MSE = 2.2330e-03
# X | train2 -> R² = -1.3148, MSE = 1.9504e-01
# X | test1 -> R² = 0.9811, MSE = 1.9759e-03
# X | test2 -> R² = -1.3424, MSE = 1.9276e-01
# X | test3 -> R² = 0.3719, MSE = 5.7790e-02
# X | val -> R² = 0.4628, MSE = 5.1366e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.881164 | Val Loss 0.751402
# Epoch 100 | Train Loss 0.420483 | Val Loss 0.487840
# Epoch 200 | Train Loss 0.413302 | Val Loss 0.451791
# Epoch 300 | Train Loss 0.400741 | Val Loss 0.398850
# Epoch 400 | Train Loss 0.394088 | Val Loss 0.396639
# Epoch 500 | Train Loss 0.392177 | Val Loss 0.398739
# Epoch 600 | Train Loss 0.390392 | Val Loss 0.402243
# Early stopping at epoch 652
# X | train1 -> R² = 0.9825, MSE = 1.8913e-03
# X | train2 -> R² = -1.3190, MSE = 1.9540e-01
# X | test1 -> R² = 0.9779, MSE = 2.3147e-03
# X | test2 -> R² = -1.3645, MSE = 1.9458e-01
# X | test3 -> R² = 0.5423, MSE = 4.2108e-02
# X | val -> R² = 0.5920, MSE = 3.9017e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.877777 | Val Loss 0.748509
# Epoch 100 | Train Loss 0.423373 | Val Loss 0.491623
# Epoch 200 | Train Loss 0.415110 | Val Loss 0.469254
# Epoch 300 | Train Loss 0.407174 | Val Loss 0.417864
# Epoch 400 | Train Loss 0.398720 | Val Loss 0.395738
# Epoch 500 | Train Loss 0.394930 | Val Loss 0.394619
# Epoch 600 | Train Loss 0.393537 | Val Loss 0.395608
# Epoch 700 | Train Loss 0.392152 | Val Loss 0.396105
# Early stopping at epoch 721
# X | train1 -> R² = 0.9800, MSE = 2.1536e-03
# X | train2 -> R² = -1.3258, MSE = 1.9597e-01
# X | test1 -> R² = 0.9811, MSE = 1.9759e-03
# X | test2 -> R² = -1.3864, MSE = 1.9638e-01
# X | test3 -> R² = 0.7639, MSE = 2.1726e-02
# X | val -> R² = 0.8001, MSE = 1.9111e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.881842 | Val Loss 0.752048
# Epoch 100 | Train Loss 0.425116 | Val Loss 0.506277
# Epoch 200 | Train Loss 0.416329 | Val Loss 0.485296
# Epoch 300 | Train Loss 0.414436 | Val Loss 0.464947
# Epoch 400 | Train Loss 0.402913 | Val Loss 0.404355
# Epoch 500 | Train Loss 0.394587 | Val Loss 0.420586
# Epoch 600 | Train Loss 0.391857 | Val Loss 0.436540
# Epoch 700 | Train Loss 0.390193 | Val Loss 0.443327
# Early stopping at epoch 703
# X | train1 -> R² = 0.9781, MSE = 2.3590e-03
# X | train2 -> R² = -1.2340, MSE = 1.8824e-01
# X | test1 -> R² = 0.9738, MSE = 2.7416e-03
# X | test2 -> R² = -1.2497, MSE = 1.8514e-01
# X | test3 -> R² = 0.9176, MSE = 7.5808e-03
# X | val -> R² = 0.9273, MSE = 6.9556e-03
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.879465 | Val Loss 0.749940
# Epoch 100 | Train Loss 0.420838 | Val Loss 0.465585
# Epoch 200 | Train Loss 0.408635 | Val Loss 0.416913
# Epoch 300 | Train Loss 0.399620 | Val Loss 0.398079
# Epoch 400 | Train Loss 0.394821 | Val Loss 0.397579
# Epoch 500 | Train Loss 0.391938 | Val Loss 0.398995
# Epoch 600 | Train Loss 0.389718 | Val Loss 0.401483
# Early stopping at epoch 626
# X | train1 -> R² = 0.9806, MSE = 2.0920e-03
# X | train2 -> R² = -1.2978, MSE = 1.9361e-01
# X | test1 -> R² = 0.9728, MSE = 2.8512e-03
# X | test2 -> R² = -1.3360, MSE = 1.9223e-01
# X | test3 -> R² = 0.8329, MSE = 1.5374e-02
# X | val -> R² = 0.8418, MSE = 1.5130e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.880849 | Val Loss 0.750492
# Epoch 100 | Train Loss 0.430490 | Val Loss 0.496525
# Epoch 200 | Train Loss 0.414324 | Val Loss 0.466725
# Epoch 300 | Train Loss 0.401424 | Val Loss 0.400365
# Epoch 400 | Train Loss 0.394873 | Val Loss 0.396089
# Epoch 500 | Train Loss 0.393317 | Val Loss 0.395210
# Epoch 600 | Train Loss 0.391824 | Val Loss 0.394395
# Epoch 700 | Train Loss 0.390461 | Val Loss 0.394095
# Epoch 800 | Train Loss 0.388023 | Val Loss 0.395908
# Early stopping at epoch 882
# X | train1 -> R² = 0.9846, MSE = 1.6627e-03
# X | train2 -> R² = -1.3189, MSE = 1.9539e-01
# X | test1 -> R² = 0.9871, MSE = 1.3498e-03
# X | test2 -> R² = -1.3490, MSE = 1.9331e-01
# X | test3 -> R² = 0.8504, MSE = 1.3768e-02
# X | val -> R² = 0.8701, MSE = 1.2418e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.880674 | Val Loss 0.750886
# Epoch 100 | Train Loss 0.419805 | Val Loss 0.419001
# Epoch 200 | Train Loss 0.403749 | Val Loss 0.398340
# Epoch 300 | Train Loss 0.398858 | Val Loss 0.396449
# Epoch 400 | Train Loss 0.395136 | Val Loss 0.395303
# Epoch 500 | Train Loss 0.392463 | Val Loss 0.394539
# Epoch 600 | Train Loss 0.390284 | Val Loss 0.396175
# Epoch 700 | Train Loss 0.387829 | Val Loss 0.408484
# Early stopping at epoch 742
# X | train1 -> R² = 0.9815, MSE = 1.9984e-03
# X | train2 -> R² = -1.3341, MSE = 1.9667e-01
# X | test1 -> R² = 0.9861, MSE = 1.4549e-03
# X | test2 -> R² = -1.3809, MSE = 1.9594e-01
# X | test3 -> R² = 0.4579, MSE = 4.9876e-02
# X | val -> R² = 0.5161, MSE = 4.6271e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.881091 | Val Loss 0.751070
# Epoch 100 | Train Loss 0.421415 | Val Loss 0.490897
# Epoch 200 | Train Loss 0.413731 | Val Loss 0.456172
# Epoch 300 | Train Loss 0.402668 | Val Loss 0.401373
# Epoch 400 | Train Loss 0.395576 | Val Loss 0.395006
# Epoch 500 | Train Loss 0.394019 | Val Loss 0.395239
# Epoch 600 | Train Loss 0.393005 | Val Loss 0.396041
# Early stopping at epoch 654
# X | train1 -> R² = 0.9804, MSE = 2.1137e-03
# X | train2 -> R² = -1.3375, MSE = 1.9696e-01
# X | test1 -> R² = 0.9817, MSE = 1.9137e-03
# X | test2 -> R² = -1.3892, MSE = 1.9661e-01
# X | test3 -> R² = 0.8154, MSE = 1.6986e-02
# X | val -> R² = 0.8230, MSE = 1.6924e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.881324 | Val Loss 0.751677
# Epoch 100 | Train Loss 0.426042 | Val Loss 0.497752
# Epoch 200 | Train Loss 0.414781 | Val Loss 0.476566
# Epoch 300 | Train Loss 0.407987 | Val Loss 0.428613
# Epoch 400 | Train Loss 0.395141 | Val Loss 0.395165
# Epoch 500 | Train Loss 0.390698 | Val Loss 0.395373
# Epoch 600 | Train Loss 0.388568 | Val Loss 0.395611
# Early stopping at epoch 694
# X | train1 -> R² = 0.9812, MSE = 2.0231e-03
# X | train2 -> R² = -1.2861, MSE = 1.9262e-01
# X | test1 -> R² = 0.9820, MSE = 1.8877e-03
# X | test2 -> R² = -1.3152, MSE = 1.9052e-01
# X | test3 -> R² = 0.4632, MSE = 4.9386e-02
# X | val -> R² = 0.5836, MSE = 3.9815e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.882046 | Val Loss 0.752151
# Epoch 100 | Train Loss 0.424442 | Val Loss 0.486274
# Epoch 200 | Train Loss 0.413604 | Val Loss 0.451798
# Epoch 300 | Train Loss 0.405683 | Val Loss 0.410922
# Epoch 400 | Train Loss 0.399594 | Val Loss 0.396830
# Epoch 500 | Train Loss 0.393668 | Val Loss 0.394337
# Epoch 600 | Train Loss 0.391010 | Val Loss 0.394607
# Epoch 700 | Train Loss 0.389691 | Val Loss 0.398536
# Epoch 800 | Train Loss 0.385022 | Val Loss 0.432547
# Early stopping at epoch 829
# X | train1 -> R² = 0.9826, MSE = 1.8790e-03
# X | train2 -> R² = -1.3273, MSE = 1.9610e-01
# X | test1 -> R² = 0.9829, MSE = 1.7917e-03
# X | test2 -> R² = -1.3732, MSE = 1.9530e-01
# X | test3 -> R² = 0.9430, MSE = 5.2400e-03
# X | val -> R² = 0.9542, MSE = 4.3796e-03
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.880806 | Val Loss 0.750788
# Epoch 100 | Train Loss 0.427057 | Val Loss 0.488194
# Epoch 200 | Train Loss 0.414191 | Val Loss 0.456417
# Epoch 300 | Train Loss 0.405108 | Val Loss 0.410341
# Epoch 400 | Train Loss 0.396338 | Val Loss 0.395314
# Epoch 500 | Train Loss 0.394075 | Val Loss 0.395294
# Epoch 600 | Train Loss 0.392732 | Val Loss 0.396198
# Early stopping at epoch 683
# X | train1 -> R² = 0.9804, MSE = 2.1083e-03
# X | train2 -> R² = -1.3211, MSE = 1.9557e-01
# X | test1 -> R² = 0.9832, MSE = 1.7570e-03
# X | test2 -> R² = -1.3739, MSE = 1.9536e-01
# X | test3 -> R² = 0.7013, MSE = 2.7479e-02
# X | val -> R² = 0.7491, MSE = 2.3990e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.882848 | Val Loss 0.752300
# Epoch 100 | Train Loss 0.422706 | Val Loss 0.477514
# Epoch 200 | Train Loss 0.410003 | Val Loss 0.427179
# Epoch 300 | Train Loss 0.401685 | Val Loss 0.397764
# Epoch 400 | Train Loss 0.395266 | Val Loss 0.393894
# Epoch 500 | Train Loss 0.393868 | Val Loss 0.393866
# Epoch 600 | Train Loss 0.392398 | Val Loss 0.393679
# Early stopping at epoch 694
# X | train1 -> R² = 0.9815, MSE = 1.9964e-03
# X | train2 -> R² = -1.3340, MSE = 1.9667e-01
# X | test1 -> R² = 0.9834, MSE = 1.7378e-03
# X | test2 -> R² = -1.3796, MSE = 1.9583e-01
# X | test3 -> R² = 0.8173, MSE = 1.6808e-02
# X | val -> R² = 0.8185, MSE = 1.7355e-02
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.882444 | Val Loss 0.752274
# Epoch 100 | Train Loss 0.423911 | Val Loss 0.495040
# Epoch 200 | Train Loss 0.414376 | Val Loss 0.463162
# Epoch 300 | Train Loss 0.406552 | Val Loss 0.413568
# Epoch 400 | Train Loss 0.397198 | Val Loss 0.397184
# Epoch 500 | Train Loss 0.393967 | Val Loss 0.395149
# Epoch 600 | Train Loss 0.391651 | Val Loss 0.393269
# Epoch 700 | Train Loss 0.389495 | Val Loss 0.393804
# Epoch 800 | Train Loss 0.387049 | Val Loss 0.402130
# Early stopping at epoch 876
# X | train1 -> R² = 0.9851, MSE = 1.6085e-03
# X | train2 -> R² = -1.3046, MSE = 1.9418e-01
# X | test1 -> R² = 0.9851, MSE = 1.5622e-03
# X | test2 -> R² = -1.3361, MSE = 1.9225e-01
# X | test3 -> R² = 0.9260, MSE = 6.8056e-03
# X | val -> R² = 0.9369, MSE = 6.0318e-03
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.879843 | Val Loss 0.750391
# Epoch 100 | Train Loss 0.428044 | Val Loss 0.497217
# Epoch 200 | Train Loss 0.416506 | Val Loss 0.482238
# Epoch 300 | Train Loss 0.414431 | Val Loss 0.459411
# Epoch 400 | Train Loss 0.406467 | Val Loss 0.409910
# Epoch 500 | Train Loss 0.396142 | Val Loss 0.416584
# Epoch 600 | Train Loss 0.390923 | Val Loss 0.476093
# Epoch 700 | Train Loss 0.386666 | Val Loss 0.500109
# Early stopping at epoch 745
# X | train1 -> R² = 0.9762, MSE = 2.5612e-03
# X | train2 -> R² = -1.2704, MSE = 1.9131e-01
# X | test1 -> R² = 0.9802, MSE = 2.0706e-03
# X | test2 -> R² = -1.3065, MSE = 1.8981e-01
# X | test3 -> R² = 0.8733, MSE = 1.1655e-02
# X | val -> R² = 0.8987, MSE = 9.6831e-03
# Modelo [32, 16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
