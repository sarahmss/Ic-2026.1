# %% [markdown]
# - Entradas: PwmD, PwmE
# - Saidas: X
# - Trajetorias: ZZ

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = Train1

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada fisica : (973,)
# Dimensão da entrada fisica: (973,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# Epoch 0 | Train Loss 0.643433 | Val Loss 0.623833
# Epoch 100 | Train Loss 0.307958 | Val Loss 0.460067
# Epoch 200 | Train Loss 0.306420 | Val Loss 0.454563
# Epoch 300 | Train Loss 0.305259 | Val Loss 0.449474
# Early stopping at epoch 322
# X | train1 -> R² = 0.8423, MSE = 1.7005e-02
# X | train2 -> R² = -0.8883, MSE = 1.5911e-01
# X | test1 -> R² = 0.7622, MSE = 2.4917e-02
# X | test2 -> R² = -0.9184, MSE = 1.5787e-01
# X | test3 -> R² = -7.6065, MSE = 7.9184e-01
# X | val -> R² = -1.7390, MSE = 2.6191e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.664929 | Val Loss 0.638797
# Epoch 100 | Train Loss 0.308079 | Val Loss 0.454643
# Epoch 200 | Train Loss 0.306489 | Val Loss 0.452633
# Epoch 300 | Train Loss 0.305147 | Val Loss 0.448616
# Early stopping at epoch 322
# X | train1 -> R² = 0.8314, MSE = 1.8177e-02
# X | train2 -> R² = -0.9239, MSE = 1.6211e-01
# X | test1 -> R² = 0.7392, MSE = 2.7322e-02
# X | test2 -> R² = -0.9438, MSE = 1.5997e-01
# X | test3 -> R² = -8.3172, MSE = 8.5723e-01
# X | val -> R² = -2.4818, MSE = 3.3294e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.697710 | Val Loss 0.661958
# Epoch 100 | Train Loss 0.308080 | Val Loss 0.457201
# Epoch 200 | Train Loss 0.306274 | Val Loss 0.453439
# Epoch 300 | Train Loss 0.304797 | Val Loss 0.448040
# Early stopping at epoch 324
# X | train1 -> R² = 0.7993, MSE = 2.1643e-02
# X | train2 -> R² = -0.8273, MSE = 1.5397e-01
# X | test1 -> R² = 0.7051, MSE = 3.0893e-02
# X | test2 -> R² = -0.8614, MSE = 1.5318e-01
# X | test3 -> R² = -7.9139, MSE = 8.2012e-01
# X | val -> R² = -2.1736, MSE = 3.0347e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.736370 | Val Loss 0.690773
# Epoch 100 | Train Loss 0.307945 | Val Loss 0.459041
# Epoch 200 | Train Loss 0.306314 | Val Loss 0.454753
# Epoch 300 | Train Loss 0.304951 | Val Loss 0.449461
# Epoch 400 | Train Loss 0.303617 | Val Loss 0.444675
# Epoch 500 | Train Loss 0.302089 | Val Loss 0.439838
# Epoch 600 | Train Loss 0.299968 | Val Loss 0.432979
# Epoch 700 | Train Loss 0.297314 | Val Loss 0.422128
# Epoch 800 | Train Loss 0.295915 | Val Loss 0.415947
# Epoch 900 | Train Loss 0.295535 | Val Loss 0.415875
# Epoch 1000 | Train Loss 0.295307 | Val Loss 0.415846
# Early stopping at epoch 1087
# X | train1 -> R² = 0.9911, MSE = 9.6029e-04
# X | train2 -> R² = -1.9556, MSE = 2.4904e-01
# X | test1 -> R² = 0.9892, MSE = 1.1365e-03
# X | test2 -> R² = -2.0437, MSE = 2.5048e-01
# X | test3 -> R² = -5.8334, MSE = 6.2871e-01
# X | val -> R² = -2.1383, MSE = 3.0009e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.733205 | Val Loss 0.689907
# Epoch 100 | Train Loss 0.307353 | Val Loss 0.452223
# Epoch 200 | Train Loss 0.305627 | Val Loss 0.450290
# Epoch 300 | Train Loss 0.304337 | Val Loss 0.447712
# Early stopping at epoch 330
# X | train1 -> R² = 0.8171, MSE = 1.9725e-02
# X | train2 -> R² = -0.8901, MSE = 1.5926e-01
# X | test1 -> R² = 0.7219, MSE = 2.9136e-02
# X | test2 -> R² = -0.9068, MSE = 1.5691e-01
# X | test3 -> R² = -8.2858, MSE = 8.5434e-01
# X | val -> R² = -2.7221, MSE = 3.5592e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.707436 | Val Loss 0.668946
# Epoch 100 | Train Loss 0.308305 | Val Loss 0.463091
# Epoch 200 | Train Loss 0.306641 | Val Loss 0.455500
# Epoch 300 | Train Loss 0.305187 | Val Loss 0.449132
# Epoch 400 | Train Loss 0.303747 | Val Loss 0.444201
# Epoch 500 | Train Loss 0.302038 | Val Loss 0.439071
# Epoch 600 | Train Loss 0.299504 | Val Loss 0.430808
# Epoch 700 | Train Loss 0.297195 | Val Loss 0.420963
# Epoch 800 | Train Loss 0.296233 | Val Loss 0.417715
# Epoch 900 | Train Loss 0.295790 | Val Loss 0.417050
# Epoch 1000 | Train Loss 0.295548 | Val Loss 0.416776
# Epoch 1100 | Train Loss 0.295368 | Val Loss 0.416380
# Epoch 1200 | Train Loss 0.295216 | Val Loss 0.415941
# Epoch 1300 | Train Loss 0.295077 | Val Loss 0.415529
# Epoch 1400 | Train Loss 0.294939 | Val Loss 0.415150
# Epoch 1500 | Train Loss 0.294796 | Val Loss 0.414787
# Epoch 1600 | Train Loss 0.294639 | Val Loss 0.414418
# Epoch 1700 | Train Loss 0.294460 | Val Loss 0.414107
# Epoch 1800 | Train Loss 0.294247 | Val Loss 0.413787
# Epoch 1900 | Train Loss 0.293978 | Val Loss 0.413496
# Epoch 2000 | Train Loss 0.293601 | Val Loss 0.412872
# Epoch 2100 | Train Loss 0.293016 | Val Loss 0.411690
# Epoch 2200 | Train Loss 0.292208 | Val Loss 0.411597
# Epoch 2300 | Train Loss 0.290896 | Val Loss 0.410578
# Epoch 2400 | Train Loss 0.288777 | Val Loss 0.404933
# Epoch 2500 | Train Loss 0.285624 | Val Loss 0.411268
# Epoch 2600 | Train Loss 0.283959 | Val Loss 0.414060
# Epoch 2700 | Train Loss 0.282951 | Val Loss 0.411844
# Early stopping at epoch 2711
# X | train1 -> R² = 0.9944, MSE = 6.0636e-04
# X | train2 -> R² = -1.9195, MSE = 2.4600e-01
# X | test1 -> R² = 0.9862, MSE = 1.4488e-03
# X | test2 -> R² = -2.0090, MSE = 2.4762e-01
# X | test3 -> R² = -4.0322, MSE = 4.6298e-01
# X | val -> R² = -2.7117, MSE = 3.5493e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.712366 | Val Loss 0.673747
# Epoch 100 | Train Loss 0.307820 | Val Loss 0.454074
# Epoch 200 | Train Loss 0.306181 | Val Loss 0.452056
# Epoch 300 | Train Loss 0.304935 | Val Loss 0.448460
# Early stopping at epoch 325
# X | train1 -> R² = 0.8217, MSE = 1.9229e-02
# X | train2 -> R² = -0.8807, MSE = 1.5847e-01
# X | test1 -> R² = 0.7313, MSE = 2.8149e-02
# X | test2 -> R² = -0.9045, MSE = 1.5672e-01
# X | test3 -> R² = -8.0296, MSE = 8.3076e-01
# X | val -> R² = -2.3309, MSE = 3.1851e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.685877 | Val Loss 0.653001
# Epoch 100 | Train Loss 0.308021 | Val Loss 0.453387
# Epoch 200 | Train Loss 0.306235 | Val Loss 0.451197
# Epoch 300 | Train Loss 0.304990 | Val Loss 0.447858
# Early stopping at epoch 323
# X | train1 -> R² = 0.8276, MSE = 1.8586e-02
# X | train2 -> R² = -0.9179, MSE = 1.6161e-01
# X | test1 -> R² = 0.7331, MSE = 2.7956e-02
# X | test2 -> R² = -0.9351, MSE = 1.5925e-01
# X | test3 -> R² = -8.3805, MSE = 8.6305e-01
# X | val -> R² = -2.5778, MSE = 3.4212e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.635787 | Val Loss 0.617785
# Epoch 100 | Train Loss 0.307974 | Val Loss 0.465116
# Epoch 200 | Train Loss 0.306383 | Val Loss 0.457061
# Epoch 300 | Train Loss 0.305028 | Val Loss 0.450581
# Epoch 400 | Train Loss 0.303885 | Val Loss 0.446369
# Epoch 500 | Train Loss 0.302587 | Val Loss 0.442339
# Epoch 600 | Train Loss 0.300343 | Val Loss 0.435170
# Epoch 700 | Train Loss 0.297238 | Val Loss 0.422449
# Epoch 800 | Train Loss 0.296034 | Val Loss 0.415981
# Epoch 900 | Train Loss 0.295529 | Val Loss 0.415436
# Epoch 1000 | Train Loss 0.295277 | Val Loss 0.415321
# Epoch 1100 | Train Loss 0.295109 | Val Loss 0.414993
# Early stopping at epoch 1124
# X | train1 -> R² = 0.9915, MSE = 9.1118e-04
# X | train2 -> R² = -1.9534, MSE = 2.4886e-01
# X | test1 -> R² = 0.9898, MSE = 1.0732e-03
# X | test2 -> R² = -2.0548, MSE = 2.5139e-01
# X | test3 -> R² = -5.9531, MSE = 6.3972e-01
# X | val -> R² = -1.8524, MSE = 2.7275e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.609206 | Val Loss 0.598630
# Epoch 100 | Train Loss 0.308115 | Val Loss 0.457499
# Epoch 200 | Train Loss 0.306134 | Val Loss 0.453752
# Epoch 300 | Train Loss 0.304391 | Val Loss 0.448278
# Early stopping at epoch 320
# X | train1 -> R² = 0.7666, MSE = 2.5166e-02
# X | train2 -> R² = -0.7883, MSE = 1.5068e-01
# X | test1 -> R² = 0.6644, MSE = 3.5153e-02
# X | test2 -> R² = -0.8328, MSE = 1.5083e-01
# X | test3 -> R² = -8.0265, MSE = 8.3048e-01
# X | val -> R² = -2.3168, MSE = 3.1716e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.705593 | Val Loss 0.667707
# Epoch 100 | Train Loss 0.307952 | Val Loss 0.457722
# Epoch 200 | Train Loss 0.306529 | Val Loss 0.454710
# Epoch 300 | Train Loss 0.305215 | Val Loss 0.449885
# Early stopping at epoch 324
# X | train1 -> R² = 0.8327, MSE = 1.8034e-02
# X | train2 -> R² = -0.8842, MSE = 1.5876e-01
# X | test1 -> R² = 0.7502, MSE = 2.6171e-02
# X | test2 -> R² = -0.9147, MSE = 1.5757e-01
# X | test3 -> R² = -7.7026, MSE = 8.0067e-01
# X | val -> R² = -1.9338, MSE = 2.8054e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.658831 | Val Loss 0.635092
# Epoch 100 | Train Loss 0.307742 | Val Loss 0.454493
# Epoch 200 | Train Loss 0.305876 | Val Loss 0.451627
# Epoch 300 | Train Loss 0.304503 | Val Loss 0.448077
# Early stopping at epoch 322
# X | train1 -> R² = 0.8319, MSE = 1.8121e-02
# X | train2 -> R² = -0.9275, MSE = 1.6241e-01
# X | test1 -> R² = 0.7387, MSE = 2.7370e-02
# X | test2 -> R² = -0.9441, MSE = 1.5998e-01
# X | test3 -> R² = -8.4184, MSE = 8.6654e-01
# X | val -> R² = -2.5643, MSE = 3.4083e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.671525 | Val Loss 0.643474
# Epoch 100 | Train Loss 0.307892 | Val Loss 0.457642
# Epoch 200 | Train Loss 0.305986 | Val Loss 0.453093
# Epoch 300 | Train Loss 0.304534 | Val Loss 0.447815
# Early stopping at epoch 325
# X | train1 -> R² = 0.8268, MSE = 1.8672e-02
# X | train2 -> R² = -0.8827, MSE = 1.5864e-01
# X | test1 -> R² = 0.7369, MSE = 2.7561e-02
# X | test2 -> R² = -0.9085, MSE = 1.5706e-01
# X | test3 -> R² = -8.0875, MSE = 8.3609e-01
# X | val -> R² = -2.1662, MSE = 3.0276e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.654997 | Val Loss 0.630397
# Epoch 100 | Train Loss 0.307602 | Val Loss 0.455687
# Epoch 200 | Train Loss 0.305738 | Val Loss 0.451455
# Epoch 300 | Train Loss 0.304321 | Val Loss 0.446454
# Early stopping at epoch 322
# X | train1 -> R² = 0.8493, MSE = 1.6245e-02
# X | train2 -> R² = -0.9383, MSE = 1.6333e-01
# X | test1 -> R² = 0.7642, MSE = 2.4699e-02
# X | test2 -> R² = -0.9532, MSE = 1.6074e-01
# X | test3 -> R² = -8.1512, MSE = 8.4195e-01
# X | val -> R² = -2.2328, MSE = 3.0913e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.680179 | Val Loss 0.650247
# Epoch 100 | Train Loss 0.308339 | Val Loss 0.455375
# Epoch 200 | Train Loss 0.306430 | Val Loss 0.452381
# Epoch 300 | Train Loss 0.304849 | Val Loss 0.447724
# Early stopping at epoch 326
# X | train1 -> R² = 0.8289, MSE = 1.8454e-02
# X | train2 -> R² = -0.9110, MSE = 1.6102e-01
# X | test1 -> R² = 0.7361, MSE = 2.7644e-02
# X | test2 -> R² = -0.9313, MSE = 1.5893e-01
# X | test3 -> R² = -8.2935, MSE = 8.5504e-01
# X | val -> R² = -2.4115, MSE = 3.2622e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.636418 | Val Loss 0.677960
# Epoch 100 | Train Loss 0.218214 | Val Loss 0.458102
# Epoch 200 | Train Loss 0.216254 | Val Loss 0.455490
# Epoch 300 | Train Loss 0.214594 | Val Loss 0.450910
# Early stopping at epoch 325
# X | train1 -> R² = 0.8367, MSE = 1.7606e-02
# X | train2 -> R² = -0.9142, MSE = 1.6129e-01
# X | test1 -> R² = 0.7508, MSE = 2.6110e-02
# X | test2 -> R² = -0.9410, MSE = 1.5973e-01
# X | test3 -> R² = -8.0183, MSE = 8.2972e-01
# X | val -> R² = -2.1475, MSE = 3.0097e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.593265 | Val Loss 0.646703
# Epoch 100 | Train Loss 0.218591 | Val Loss 0.457834
# Epoch 200 | Train Loss 0.216393 | Val Loss 0.454375
# Epoch 300 | Train Loss 0.214667 | Val Loss 0.449221
# Early stopping at epoch 324
# X | train1 -> R² = 0.8248, MSE = 1.8896e-02
# X | train2 -> R² = -0.9165, MSE = 1.6149e-01
# X | test1 -> R² = 0.7288, MSE = 2.8409e-02
# X | test2 -> R² = -0.9390, MSE = 1.5957e-01
# X | test3 -> R² = -8.5219, MSE = 8.7606e-01
# X | val -> R² = -2.4974, MSE = 3.3444e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.660396 | Val Loss 0.696115
# Epoch 100 | Train Loss 0.218435 | Val Loss 0.459587
# Epoch 200 | Train Loss 0.216732 | Val Loss 0.456897
# Epoch 300 | Train Loss 0.215248 | Val Loss 0.452371
# Early stopping at epoch 327
# X | train1 -> R² = 0.8138, MSE = 2.0072e-02
# X | train2 -> R² = -0.8652, MSE = 1.5716e-01
# X | test1 -> R² = 0.7234, MSE = 2.8972e-02
# X | test2 -> R² = -0.9001, MSE = 1.5636e-01
# X | test3 -> R² = -7.9513, MSE = 8.2356e-01
# X | val -> R² = -2.1228, MSE = 2.9861e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.562413 | Val Loss 0.622573
# Epoch 100 | Train Loss 0.217521 | Val Loss 0.458156
# Epoch 200 | Train Loss 0.215334 | Val Loss 0.454486
# Epoch 300 | Train Loss 0.213343 | Val Loss 0.449886
# Early stopping at epoch 321
# X | train1 -> R² = 0.8458, MSE = 1.6627e-02
# X | train2 -> R² = -0.9249, MSE = 1.6220e-01
# X | test1 -> R² = 0.7646, MSE = 2.4657e-02
# X | test2 -> R² = -0.9490, MSE = 1.6039e-01
# X | test3 -> R² = -7.8564, MSE = 8.1483e-01
# X | val -> R² = -2.0462, MSE = 2.9129e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.592291 | Val Loss 0.645645
# Epoch 100 | Train Loss 0.218177 | Val Loss 0.456980
# Epoch 200 | Train Loss 0.215975 | Val Loss 0.453669
# Epoch 300 | Train Loss 0.214315 | Val Loss 0.449339
# Early stopping at epoch 324
# X | train1 -> R² = 0.7839, MSE = 2.3300e-02
# X | train2 -> R² = -0.8179, MSE = 1.5317e-01
# X | test1 -> R² = 0.6840, MSE = 3.3102e-02
# X | test2 -> R² = -0.8542, MSE = 1.5259e-01
# X | test3 -> R² = -8.1293, MSE = 8.3994e-01
# X | val -> R² = -2.4099, MSE = 3.2606e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.492647 | Val Loss 0.577005
# Epoch 100 | Train Loss 0.218427 | Val Loss 0.464845
# Epoch 200 | Train Loss 0.216121 | Val Loss 0.455018
# Epoch 300 | Train Loss 0.213741 | Val Loss 0.448133
# Epoch 400 | Train Loss 0.211351 | Val Loss 0.443545
# Epoch 500 | Train Loss 0.208905 | Val Loss 0.438336
# Epoch 600 | Train Loss 0.206629 | Val Loss 0.430988
# Epoch 700 | Train Loss 0.205334 | Val Loss 0.429109
# Epoch 800 | Train Loss 0.204467 | Val Loss 0.428375
# Epoch 900 | Train Loss 0.202432 | Val Loss 0.425120
# Epoch 1000 | Train Loss 0.198243 | Val Loss 0.418106
# Epoch 1100 | Train Loss 0.196313 | Val Loss 0.417137
# Epoch 1200 | Train Loss 0.195108 | Val Loss 0.421598
# Epoch 1300 | Train Loss 0.194219 | Val Loss 0.430227
# Early stopping at epoch 1319
# X | train1 -> R² = 0.9949, MSE = 5.4497e-04
# X | train2 -> R² = -1.9741, MSE = 2.5060e-01
# X | test1 -> R² = 0.9830, MSE = 1.7823e-03
# X | test2 -> R² = -2.0667, MSE = 2.5237e-01
# X | test3 -> R² = -3.2120, MSE = 3.8752e-01
# X | val -> R² = -0.5561, MSE = 1.4880e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.571012 | Val Loss 0.631605
# Epoch 100 | Train Loss 0.218152 | Val Loss 0.455517
# Epoch 200 | Train Loss 0.215941 | Val Loss 0.452755
# Epoch 300 | Train Loss 0.214365 | Val Loss 0.448705
# Early stopping at epoch 323
# X | train1 -> R² = 0.7929, MSE = 2.2334e-02
# X | train2 -> R² = -0.8660, MSE = 1.5723e-01
# X | test1 -> R² = 0.6890, MSE = 3.2584e-02
# X | test2 -> R² = -0.8951, MSE = 1.5595e-01
# X | test3 -> R² = -8.5344, MSE = 8.7720e-01
# X | val -> R² = -2.7266, MSE = 3.5634e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.565409 | Val Loss 0.625912
# Epoch 100 | Train Loss 0.217737 | Val Loss 0.459269
# Epoch 200 | Train Loss 0.215736 | Val Loss 0.455545
# Epoch 300 | Train Loss 0.213960 | Val Loss 0.450253
# Early stopping at epoch 321
# X | train1 -> R² = 0.8422, MSE = 1.7011e-02
# X | train2 -> R² = -0.9166, MSE = 1.6149e-01
# X | test1 -> R² = 0.7613, MSE = 2.5004e-02
# X | test2 -> R² = -0.9434, MSE = 1.5993e-01
# X | test3 -> R² = -7.8030, MSE = 8.0991e-01
# X | val -> R² = -2.0157, MSE = 2.8837e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.553625 | Val Loss 0.617309
# Epoch 100 | Train Loss 0.218205 | Val Loss 0.462873
# Epoch 200 | Train Loss 0.216242 | Val Loss 0.455718
# Epoch 300 | Train Loss 0.214608 | Val Loss 0.450168
# Epoch 400 | Train Loss 0.213037 | Val Loss 0.446539
# Epoch 500 | Train Loss 0.211253 | Val Loss 0.443484
# Epoch 600 | Train Loss 0.208847 | Val Loss 0.437233
# Epoch 700 | Train Loss 0.206350 | Val Loss 0.428230
# Epoch 800 | Train Loss 0.205538 | Val Loss 0.428045
# Epoch 900 | Train Loss 0.205142 | Val Loss 0.429141
# Epoch 1000 | Train Loss 0.204570 | Val Loss 0.429610
# Early stopping at epoch 1021
# X | train1 -> R² = 0.9921, MSE = 8.4966e-04
# X | train2 -> R² = -2.0308, MSE = 2.5537e-01
# X | test1 -> R² = 0.9879, MSE = 1.2693e-03
# X | test2 -> R² = -2.0793, MSE = 2.5341e-01
# X | test3 -> R² = -8.0803, MSE = 8.3542e-01
# X | val -> R² = -2.8031, MSE = 3.6367e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.607258 | Val Loss 0.657936
# Epoch 100 | Train Loss 0.217007 | Val Loss 0.456935
# Epoch 200 | Train Loss 0.214571 | Val Loss 0.453361
# Epoch 300 | Train Loss 0.212701 | Val Loss 0.449152
# Early stopping at epoch 328
# X | train1 -> R² = 0.8089, MSE = 2.0608e-02
# X | train2 -> R² = -0.8741, MSE = 1.5791e-01
# X | test1 -> R² = 0.7100, MSE = 3.0384e-02
# X | test2 -> R² = -0.8965, MSE = 1.5607e-01
# X | test3 -> R² = -8.4471, MSE = 8.6917e-01
# X | val -> R² = -2.5992, MSE = 3.4416e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.616975 | Val Loss 0.663958
# Epoch 100 | Train Loss 0.217764 | Val Loss 0.458977
# Epoch 200 | Train Loss 0.215869 | Val Loss 0.454463
# Epoch 300 | Train Loss 0.213998 | Val Loss 0.449690
# Early stopping at epoch 323
# X | train1 -> R² = 0.8355, MSE = 1.7733e-02
# X | train2 -> R² = -0.8789, MSE = 1.5832e-01
# X | test1 -> R² = 0.7574, MSE = 2.5412e-02
# X | test2 -> R² = -0.9129, MSE = 1.5742e-01
# X | test3 -> R² = -7.4737, MSE = 7.7962e-01
# X | val -> R² = -1.7750, MSE = 2.6536e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.595697 | Val Loss 0.648176
# Epoch 100 | Train Loss 0.218263 | Val Loss 0.457487
# Epoch 200 | Train Loss 0.216275 | Val Loss 0.454566
# Epoch 300 | Train Loss 0.214577 | Val Loss 0.450132
# Early stopping at epoch 322
# X | train1 -> R² = 0.8069, MSE = 2.0820e-02
# X | train2 -> R² = -0.8651, MSE = 1.5715e-01
# X | test1 -> R² = 0.7128, MSE = 3.0087e-02
# X | test2 -> R² = -0.8972, MSE = 1.5613e-01
# X | test3 -> R² = -8.0856, MSE = 8.3591e-01
# X | val -> R² = -2.3160, MSE = 3.1709e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.624568 | Val Loss 0.669663
# Epoch 100 | Train Loss 0.218232 | Val Loss 0.460261
# Epoch 200 | Train Loss 0.216392 | Val Loss 0.457616
# Epoch 300 | Train Loss 0.214717 | Val Loss 0.452966
# Early stopping at epoch 326
# X | train1 -> R² = 0.8230, MSE = 1.9087e-02
# X | train2 -> R² = -0.8689, MSE = 1.5747e-01
# X | test1 -> R² = 0.7393, MSE = 2.7309e-02
# X | test2 -> R² = -0.9054, MSE = 1.5680e-01
# X | test3 -> R² = -7.6657, MSE = 7.9728e-01
# X | val -> R² = -1.9156, MSE = 2.7880e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.604783 | Val Loss 0.653230
# Epoch 100 | Train Loss 0.217734 | Val Loss 0.459553
# Epoch 200 | Train Loss 0.215523 | Val Loss 0.453989
# Epoch 300 | Train Loss 0.213555 | Val Loss 0.448506
# Epoch 400 | Train Loss 0.211813 | Val Loss 0.445304
# Epoch 500 | Train Loss 0.210386 | Val Loss 0.443593
# Epoch 600 | Train Loss 0.209232 | Val Loss 0.441570
# Epoch 700 | Train Loss 0.208031 | Val Loss 0.437751
# Epoch 800 | Train Loss 0.206640 | Val Loss 0.432263
# Epoch 900 | Train Loss 0.205657 | Val Loss 0.427953
# Epoch 1000 | Train Loss 0.205095 | Val Loss 0.426498
# Epoch 1100 | Train Loss 0.204530 | Val Loss 0.425967
# Epoch 1200 | Train Loss 0.203519 | Val Loss 0.425270
# Epoch 1300 | Train Loss 0.201209 | Val Loss 0.425556
# Epoch 1400 | Train Loss 0.198374 | Val Loss 0.425182
# Epoch 1500 | Train Loss 0.196460 | Val Loss 0.422828
# Epoch 1600 | Train Loss 0.194964 | Val Loss 0.423412
# Epoch 1700 | Train Loss 0.193706 | Val Loss 0.427144
# Early stopping at epoch 1777
# X | train1 -> R² = 0.9944, MSE = 6.0034e-04
# X | train2 -> R² = -1.9894, MSE = 2.5189e-01
# X | test1 -> R² = 0.9898, MSE = 1.0695e-03
# X | test2 -> R² = -2.1301, MSE = 2.5758e-01
# X | test3 -> R² = -2.8923, MSE = 3.5811e-01
# X | val -> R² = 0.1518, MSE = 8.1104e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.554457 | Val Loss 0.617350
# Epoch 100 | Train Loss 0.218362 | Val Loss 0.456268
# Epoch 200 | Train Loss 0.216056 | Val Loss 0.453598
# Epoch 300 | Train Loss 0.214442 | Val Loss 0.449603
# Early stopping at epoch 321
# X | train1 -> R² = 0.7948, MSE = 2.2126e-02
# X | train2 -> R² = -0.8900, MSE = 1.5925e-01
# X | test1 -> R² = 0.6877, MSE = 3.2717e-02
# X | test2 -> R² = -0.9185, MSE = 1.5788e-01
# X | test3 -> R² = -8.8013, MSE = 9.0176e-01
# X | val -> R² = -2.8277, MSE = 3.6602e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.787088 | Val Loss 0.667678
# Epoch 100 | Train Loss 0.397132 | Val Loss 0.450611
# Epoch 200 | Train Loss 0.395323 | Val Loss 0.448842
# Epoch 300 | Train Loss 0.393791 | Val Loss 0.444961
# Early stopping at epoch 325
# X | train1 -> R² = 0.8213, MSE = 1.9270e-02
# X | train2 -> R² = -0.8860, MSE = 1.5892e-01
# X | test1 -> R² = 0.7295, MSE = 2.8334e-02
# X | test2 -> R² = -0.9054, MSE = 1.5680e-01
# X | test3 -> R² = -8.0392, MSE = 8.3164e-01
# X | val -> R² = -2.4918, MSE = 3.3389e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.737572 | Val Loss 0.631562
# Epoch 100 | Train Loss 0.397275 | Val Loss 0.454000
# Epoch 200 | Train Loss 0.395774 | Val Loss 0.450985
# Epoch 300 | Train Loss 0.394349 | Val Loss 0.446770
# Early stopping at epoch 321
# X | train1 -> R² = 0.8182, MSE = 1.9603e-02
# X | train2 -> R² = -0.8635, MSE = 1.5702e-01
# X | test1 -> R² = 0.7290, MSE = 2.8393e-02
# X | test2 -> R² = -0.8888, MSE = 1.5544e-01
# X | test3 -> R² = -7.8133, MSE = 8.1086e-01
# X | val -> R² = -2.2383, MSE = 3.0965e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.802197 | Val Loss 0.679069
# Epoch 100 | Train Loss 0.397236 | Val Loss 0.457479
# Epoch 200 | Train Loss 0.395530 | Val Loss 0.452938
# Epoch 300 | Train Loss 0.394104 | Val Loss 0.447739
# Epoch 400 | Train Loss 0.392721 | Val Loss 0.443062
# Epoch 500 | Train Loss 0.390608 | Val Loss 0.436935
# Epoch 600 | Train Loss 0.386550 | Val Loss 0.424928
# Epoch 700 | Train Loss 0.383290 | Val Loss 0.411944
# Epoch 800 | Train Loss 0.382085 | Val Loss 0.406791
# Epoch 900 | Train Loss 0.381357 | Val Loss 0.404581
# Epoch 1000 | Train Loss 0.380861 | Val Loss 0.404324
# Epoch 1100 | Train Loss 0.380486 | Val Loss 0.404556
# Epoch 1200 | Train Loss 0.380204 | Val Loss 0.404319
# Early stopping at epoch 1201
# X | train1 -> R² = 0.9884, MSE = 1.2459e-03
# X | train2 -> R² = -1.9002, MSE = 2.4437e-01
# X | test1 -> R² = 0.9899, MSE = 1.0541e-03
# X | test2 -> R² = -2.0460, MSE = 2.5066e-01
# X | test3 -> R² = -3.5094, MSE = 4.1488e-01
# X | val -> R² = -1.2714, MSE = 2.1720e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.755724 | Val Loss 0.643921
# Epoch 100 | Train Loss 0.397044 | Val Loss 0.461851
# Epoch 200 | Train Loss 0.395361 | Val Loss 0.454284
# Epoch 300 | Train Loss 0.393823 | Val Loss 0.447408
# Epoch 400 | Train Loss 0.391941 | Val Loss 0.440866
# Epoch 500 | Train Loss 0.388965 | Val Loss 0.432643
# Epoch 600 | Train Loss 0.384869 | Val Loss 0.420770
# Epoch 700 | Train Loss 0.382729 | Val Loss 0.410708
# Epoch 800 | Train Loss 0.381910 | Val Loss 0.406935
# Epoch 900 | Train Loss 0.381464 | Val Loss 0.405481
# Epoch 1000 | Train Loss 0.381117 | Val Loss 0.404735
# Epoch 1100 | Train Loss 0.380771 | Val Loss 0.404318
# Epoch 1200 | Train Loss 0.380415 | Val Loss 0.404375
# Epoch 1300 | Train Loss 0.380084 | Val Loss 0.404016
# Early stopping at epoch 1318
# X | train1 -> R² = 0.9888, MSE = 1.2120e-03
# X | train2 -> R² = -1.9044, MSE = 2.4472e-01
# X | test1 -> R² = 0.9913, MSE = 9.0928e-04
# X | test2 -> R² = -2.0378, MSE = 2.4999e-01
# X | test3 -> R² = -3.3891, MSE = 4.0382e-01
# X | val -> R² = -1.2172, MSE = 2.1201e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.782945 | Val Loss 0.665383
# Epoch 100 | Train Loss 0.397917 | Val Loss 0.453445
# Epoch 200 | Train Loss 0.395516 | Val Loss 0.449669
# Epoch 300 | Train Loss 0.393676 | Val Loss 0.444963
# Epoch 400 | Train Loss 0.391528 | Val Loss 0.439217
# Epoch 500 | Train Loss 0.387977 | Val Loss 0.430130
# Epoch 600 | Train Loss 0.383966 | Val Loss 0.417483
# Epoch 700 | Train Loss 0.382608 | Val Loss 0.410549
# Epoch 800 | Train Loss 0.381852 | Val Loss 0.408025
# Epoch 900 | Train Loss 0.381266 | Val Loss 0.406735
# Epoch 1000 | Train Loss 0.380836 | Val Loss 0.406060
# Epoch 1100 | Train Loss 0.380497 | Val Loss 0.405845
# Epoch 1200 | Train Loss 0.380205 | Val Loss 0.405583
# Epoch 1300 | Train Loss 0.379950 | Val Loss 0.405052
# Epoch 1400 | Train Loss 0.379715 | Val Loss 0.404254
# Epoch 1500 | Train Loss 0.379479 | Val Loss 0.403300
# Epoch 1600 | Train Loss 0.379207 | Val Loss 0.401842
# Epoch 1700 | Train Loss 0.378799 | Val Loss 0.400386
# Epoch 1800 | Train Loss 0.378094 | Val Loss 0.397882
# Epoch 1900 | Train Loss 0.376656 | Val Loss 0.394485
# Epoch 2000 | Train Loss 0.374808 | Val Loss 0.392703
# Epoch 2100 | Train Loss 0.373525 | Val Loss 0.393138
# Epoch 2200 | Train Loss 0.371564 | Val Loss 0.393844
# Early stopping at epoch 2237
# X | train1 -> R² = 0.9916, MSE = 9.0158e-04
# X | train2 -> R² = -1.9071, MSE = 2.4495e-01
# X | test1 -> R² = 0.9912, MSE = 9.1957e-04
# X | test2 -> R² = -2.0684, MSE = 2.5251e-01
# X | test3 -> R² = -2.2947, MSE = 3.0312e-01
# X | val -> R² = -0.8356, MSE = 1.7552e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.753223 | Val Loss 0.643042
# Epoch 100 | Train Loss 0.396825 | Val Loss 0.453530
# Epoch 200 | Train Loss 0.395221 | Val Loss 0.450255
# Epoch 300 | Train Loss 0.393814 | Val Loss 0.446031
# Early stopping at epoch 322
# X | train1 -> R² = 0.8303, MSE = 1.8295e-02
# X | train2 -> R² = -0.8757, MSE = 1.5805e-01
# X | test1 -> R² = 0.7462, MSE = 2.6592e-02
# X | test2 -> R² = -0.9008, MSE = 1.5643e-01
# X | test3 -> R² = -7.6932, MSE = 7.9981e-01
# X | val -> R² = -2.0478, MSE = 2.9144e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.780542 | Val Loss 0.665362
# Epoch 100 | Train Loss 0.397108 | Val Loss 0.451657
# Epoch 200 | Train Loss 0.395274 | Val Loss 0.449424
# Epoch 300 | Train Loss 0.393898 | Val Loss 0.445951
# Early stopping at epoch 325
# X | train1 -> R² = 0.8218, MSE = 1.9213e-02
# X | train2 -> R² = -0.8785, MSE = 1.5828e-01
# X | test1 -> R² = 0.7313, MSE = 2.8146e-02
# X | test2 -> R² = -0.8989, MSE = 1.5627e-01
# X | test3 -> R² = -7.9772, MSE = 8.2594e-01
# X | val -> R² = -2.3762, MSE = 3.2285e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.813371 | Val Loss 0.690041
# Epoch 100 | Train Loss 0.397709 | Val Loss 0.453536
# Epoch 200 | Train Loss 0.395496 | Val Loss 0.449418
# Epoch 300 | Train Loss 0.393783 | Val Loss 0.445401
# Early stopping at epoch 331
# X | train1 -> R² = 0.7990, MSE = 2.1670e-02
# X | train2 -> R² = -0.8537, MSE = 1.5619e-01
# X | test1 -> R² = 0.6969, MSE = 3.1757e-02
# X | test2 -> R² = -0.8767, MSE = 1.5444e-01
# X | test3 -> R² = -8.4202, MSE = 8.6670e-01
# X | val -> R² = -2.6481, MSE = 3.4884e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.747189 | Val Loss 0.637040
# Epoch 100 | Train Loss 0.396835 | Val Loss 0.452752
# Epoch 200 | Train Loss 0.395373 | Val Loss 0.450373
# Epoch 300 | Train Loss 0.394009 | Val Loss 0.446615
# Early stopping at epoch 321
# X | train1 -> R² = 0.8104, MSE = 2.0446e-02
# X | train2 -> R² = -0.8395, MSE = 1.5500e-01
# X | test1 -> R² = 0.7229, MSE = 2.9029e-02
# X | test2 -> R² = -0.8715, MSE = 1.5401e-01
# X | test3 -> R² = -7.5954, MSE = 7.9082e-01
# X | val -> R² = -2.1103, MSE = 2.9742e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.697882 | Val Loss 0.603610
# Epoch 100 | Train Loss 0.397030 | Val Loss 0.454134
# Epoch 200 | Train Loss 0.395207 | Val Loss 0.450158
# Epoch 300 | Train Loss 0.393718 | Val Loss 0.445935
# Early stopping at epoch 321
# X | train1 -> R² = 0.8262, MSE = 1.8743e-02
# X | train2 -> R² = -0.8962, MSE = 1.5977e-01
# X | test1 -> R² = 0.7357, MSE = 2.7691e-02
# X | test2 -> R² = -0.9215, MSE = 1.5812e-01
# X | test3 -> R² = -8.1113, MSE = 8.3828e-01
# X | val -> R² = -2.2657, MSE = 3.1228e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.773040 | Val Loss 0.659468
# Epoch 100 | Train Loss 0.396604 | Val Loss 0.451462
# Epoch 200 | Train Loss 0.394958 | Val Loss 0.449416
# Epoch 300 | Train Loss 0.393632 | Val Loss 0.446000
# Early stopping at epoch 326
# X | train1 -> R² = 0.8204, MSE = 1.9370e-02
# X | train2 -> R² = -0.8694, MSE = 1.5751e-01
# X | test1 -> R² = 0.7318, MSE = 2.8092e-02
# X | test2 -> R² = -0.8926, MSE = 1.5575e-01
# X | test3 -> R² = -7.8267, MSE = 8.1209e-01
# X | val -> R² = -2.2706, MSE = 3.1275e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.801876 | Val Loss 0.681412
# Epoch 100 | Train Loss 0.397327 | Val Loss 0.449606
# Epoch 200 | Train Loss 0.395443 | Val Loss 0.448396
# Epoch 300 | Train Loss 0.394020 | Val Loss 0.445556
# Early stopping at epoch 326
# X | train1 -> R² = 0.8093, MSE = 2.0563e-02
# X | train2 -> R² = -0.8757, MSE = 1.5805e-01
# X | test1 -> R² = 0.7118, MSE = 3.0190e-02
# X | test2 -> R² = -0.8944, MSE = 1.5590e-01
# X | test3 -> R² = -8.2224, MSE = 8.4851e-01
# X | val -> R² = -2.7067, MSE = 3.5445e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.777894 | Val Loss 0.661295
# Epoch 100 | Train Loss 0.397236 | Val Loss 0.458887
# Epoch 200 | Train Loss 0.395496 | Val Loss 0.453389
# Epoch 300 | Train Loss 0.393810 | Val Loss 0.446882
# Epoch 400 | Train Loss 0.391958 | Val Loss 0.440916
# Epoch 500 | Train Loss 0.389233 | Val Loss 0.433488
# Epoch 600 | Train Loss 0.385341 | Val Loss 0.422136
# Epoch 700 | Train Loss 0.383353 | Val Loss 0.413148
# Epoch 800 | Train Loss 0.382465 | Val Loss 0.410075
# Epoch 900 | Train Loss 0.381658 | Val Loss 0.408043
# Epoch 1000 | Train Loss 0.380947 | Val Loss 0.406417
# Epoch 1100 | Train Loss 0.380458 | Val Loss 0.406032
# Epoch 1200 | Train Loss 0.380122 | Val Loss 0.405784
# Epoch 1300 | Train Loss 0.379888 | Val Loss 0.405337
# Epoch 1400 | Train Loss 0.379701 | Val Loss 0.404976
# Epoch 1500 | Train Loss 0.379536 | Val Loss 0.404512
# Epoch 1600 | Train Loss 0.379372 | Val Loss 0.404175
# Epoch 1700 | Train Loss 0.379192 | Val Loss 0.403984
# Epoch 1800 | Train Loss 0.378987 | Val Loss 0.403717
# Epoch 1900 | Train Loss 0.378737 | Val Loss 0.403294
# Epoch 2000 | Train Loss 0.378386 | Val Loss 0.403082
# Epoch 2100 | Train Loss 0.377765 | Val Loss 0.402234
# Epoch 2200 | Train Loss 0.376388 | Val Loss 0.399774
# Epoch 2300 | Train Loss 0.373544 | Val Loss 0.395227
# Epoch 2400 | Train Loss 0.370965 | Val Loss 0.396708
# Epoch 2500 | Train Loss 0.369564 | Val Loss 0.397341
# Early stopping at epoch 2571
# X | train1 -> R² = 0.9905, MSE = 1.0226e-03
# X | train2 -> R² = -1.7571, MSE = 2.3231e-01
# X | test1 -> R² = 0.9900, MSE = 1.0518e-03
# X | test2 -> R² = -2.0242, MSE = 2.4887e-01
# X | test3 -> R² = -2.9015, MSE = 3.5895e-01
# X | val -> R² = -1.0940, MSE = 2.0023e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.725182 | Val Loss 0.621950
# Epoch 100 | Train Loss 0.396942 | Val Loss 0.457896
# Epoch 200 | Train Loss 0.395422 | Val Loss 0.451611
# Epoch 300 | Train Loss 0.393829 | Val Loss 0.445707
# Epoch 400 | Train Loss 0.391916 | Val Loss 0.439765
# Epoch 500 | Train Loss 0.388469 | Val Loss 0.430556
# Epoch 600 | Train Loss 0.383428 | Val Loss 0.413436
# Epoch 700 | Train Loss 0.381987 | Val Loss 0.408137
# Epoch 800 | Train Loss 0.381307 | Val Loss 0.407028
# Epoch 900 | Train Loss 0.380844 | Val Loss 0.406235
# Epoch 1000 | Train Loss 0.380427 | Val Loss 0.405589
# Epoch 1100 | Train Loss 0.380065 | Val Loss 0.404856
# Epoch 1200 | Train Loss 0.379757 | Val Loss 0.404835
# Epoch 1300 | Train Loss 0.379474 | Val Loss 0.404438
# Epoch 1400 | Train Loss 0.379165 | Val Loss 0.403968
# Epoch 1500 | Train Loss 0.378760 | Val Loss 0.404029
# Epoch 1600 | Train Loss 0.378025 | Val Loss 0.404066
# Early stopping at epoch 1681
# X | train1 -> R² = 0.9899, MSE = 1.0864e-03
# X | train2 -> R² = -1.9250, MSE = 2.4646e-01
# X | test1 -> R² = 0.9908, MSE = 9.6208e-04
# X | test2 -> R² = -2.0723, MSE = 2.5283e-01
# X | test3 -> R² = -2.7544, MSE = 3.4542e-01
# X | val -> R² = -0.9299, MSE = 1.8454e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.701988 | Val Loss 0.605704
# Epoch 100 | Train Loss 0.397335 | Val Loss 0.454406
# Epoch 200 | Train Loss 0.395428 | Val Loss 0.450068
# Epoch 300 | Train Loss 0.393727 | Val Loss 0.445161
# Early stopping at epoch 320
# X | train1 -> R² = 0.8274, MSE = 1.8616e-02
# X | train2 -> R² = -0.9120, MSE = 1.6111e-01
# X | test1 -> R² = 0.7340, MSE = 2.7865e-02
# X | test2 -> R² = -0.9346, MSE = 1.5920e-01
# X | test3 -> R² = -8.3056, MSE = 8.5616e-01
# X | val -> R² = -2.3950, MSE = 3.2464e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.554455 | Val Loss 0.548415
# Epoch 100 | Train Loss 0.306613 | Val Loss 0.453179
# Epoch 200 | Train Loss 0.304580 | Val Loss 0.448261
# Epoch 300 | Train Loss 0.302826 | Val Loss 0.444288
# Early stopping at epoch 308
# X | train1 -> R² = 0.8934, MSE = 1.1492e-02
# X | train2 -> R² = -1.0364, MSE = 1.7159e-01
# X | test1 -> R² = 0.8277, MSE = 1.8053e-02
# X | test2 -> R² = -1.0418, MSE = 1.6803e-01
# X | test3 -> R² = -7.6950, MSE = 7.9997e-01
# X | val -> R² = -1.8855, MSE = 2.7592e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.539319 | Val Loss 0.538800
# Epoch 100 | Train Loss 0.306560 | Val Loss 0.452600
# Epoch 200 | Train Loss 0.304852 | Val Loss 0.447731
# Epoch 300 | Train Loss 0.302789 | Val Loss 0.443113
# Epoch 400 | Train Loss 0.300266 | Val Loss 0.436907
# Epoch 500 | Train Loss 0.296056 | Val Loss 0.419829
# Epoch 600 | Train Loss 0.295122 | Val Loss 0.416353
# Epoch 700 | Train Loss 0.294851 | Val Loss 0.416019
# Epoch 800 | Train Loss 0.294573 | Val Loss 0.415267
# Epoch 900 | Train Loss 0.294176 | Val Loss 0.413057
# Epoch 1000 | Train Loss 0.293177 | Val Loss 0.410552
# Epoch 1100 | Train Loss 0.290152 | Val Loss 0.407646
# Epoch 1200 | Train Loss 0.287150 | Val Loss 0.399715
# Epoch 1300 | Train Loss 0.284998 | Val Loss 0.408399
# Epoch 1400 | Train Loss 0.283777 | Val Loss 0.419771
# Epoch 1500 | Train Loss 0.282772 | Val Loss 0.423378
# Early stopping at epoch 1502
# X | train1 -> R² = 0.9958, MSE = 4.5284e-04
# X | train2 -> R² = -1.8356, MSE = 2.3893e-01
# X | test1 -> R² = 0.9896, MSE = 1.0921e-03
# X | test2 -> R² = -2.0342, MSE = 2.4970e-01
# X | test3 -> R² = -2.8054, MSE = 3.5011e-01
# X | val -> R² = -1.5558, MSE = 2.4440e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.573940 | Val Loss 0.560052
# Epoch 100 | Train Loss 0.306645 | Val Loss 0.452457
# Epoch 200 | Train Loss 0.305075 | Val Loss 0.449054
# Epoch 300 | Train Loss 0.303470 | Val Loss 0.445236
# Early stopping at epoch 308
# X | train1 -> R² = 0.8225, MSE = 1.9137e-02
# X | train2 -> R² = -0.8496, MSE = 1.5584e-01
# X | test1 -> R² = 0.7431, MSE = 2.6918e-02
# X | test2 -> R² = -0.8788, MSE = 1.5461e-01
# X | test3 -> R² = -7.2497, MSE = 7.5900e-01
# X | val -> R² = -1.9653, MSE = 2.8355e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.557805 | Val Loss 0.549809
# Epoch 100 | Train Loss 0.306551 | Val Loss 0.454446
# Epoch 200 | Train Loss 0.304961 | Val Loss 0.449147
# Epoch 300 | Train Loss 0.303375 | Val Loss 0.446254
# Epoch 400 | Train Loss 0.302028 | Val Loss 0.442912
# Epoch 500 | Train Loss 0.300132 | Val Loss 0.437276
# Epoch 600 | Train Loss 0.296021 | Val Loss 0.419859
# Epoch 700 | Train Loss 0.295016 | Val Loss 0.415898
# Epoch 800 | Train Loss 0.294768 | Val Loss 0.415751
# Epoch 900 | Train Loss 0.294538 | Val Loss 0.415385
# Epoch 1000 | Train Loss 0.294274 | Val Loss 0.413420
# Epoch 1100 | Train Loss 0.293775 | Val Loss 0.412799
# Epoch 1200 | Train Loss 0.292845 | Val Loss 0.410566
# Epoch 1300 | Train Loss 0.291480 | Val Loss 0.406455
# Epoch 1400 | Train Loss 0.289950 | Val Loss 0.402702
# Epoch 1500 | Train Loss 0.288287 | Val Loss 0.400058
# Epoch 1600 | Train Loss 0.286604 | Val Loss 0.399730
# Epoch 1700 | Train Loss 0.284990 | Val Loss 0.402522
# Epoch 1800 | Train Loss 0.283802 | Val Loss 0.405184
# Epoch 1900 | Train Loss 0.283003 | Val Loss 0.407711
# Early stopping at epoch 1903
# X | train1 -> R² = 0.9784, MSE = 2.3282e-03
# X | train2 -> R² = -1.9505, MSE = 2.4861e-01
# X | test1 -> R² = 0.9913, MSE = 9.1508e-04
# X | test2 -> R² = -2.1705, MSE = 2.6091e-01
# X | test3 -> R² = -2.5624, MSE = 3.2776e-01
# X | val -> R² = -0.8427, MSE = 1.7620e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.674370 | Val Loss 0.630968
# Epoch 100 | Train Loss 0.306535 | Val Loss 0.450967
# Epoch 200 | Train Loss 0.304686 | Val Loss 0.449357
# Epoch 300 | Train Loss 0.303127 | Val Loss 0.445748
# Early stopping at epoch 313
# X | train1 -> R² = 0.8924, MSE = 1.1601e-02
# X | train2 -> R² = -1.0607, MSE = 1.7364e-01
# X | test1 -> R² = 0.8240, MSE = 1.8439e-02
# X | test2 -> R² = -1.0608, MSE = 1.6959e-01
# X | test3 -> R² = -7.8874, MSE = 8.1768e-01
# X | val -> R² = -2.1964, MSE = 3.0565e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.568649 | Val Loss 0.556005
# Epoch 100 | Train Loss 0.306724 | Val Loss 0.452788
# Epoch 200 | Train Loss 0.304937 | Val Loss 0.448105
# Epoch 300 | Train Loss 0.302959 | Val Loss 0.443989
# Epoch 400 | Train Loss 0.301067 | Val Loss 0.439298
# Epoch 500 | Train Loss 0.297336 | Val Loss 0.426230
# Epoch 600 | Train Loss 0.295306 | Val Loss 0.416318
# Epoch 700 | Train Loss 0.294974 | Val Loss 0.415800
# Epoch 800 | Train Loss 0.294737 | Val Loss 0.415169
# Epoch 900 | Train Loss 0.294489 | Val Loss 0.415013
# Epoch 1000 | Train Loss 0.294157 | Val Loss 0.414488
# Epoch 1100 | Train Loss 0.293525 | Val Loss 0.411471
# Epoch 1200 | Train Loss 0.292011 | Val Loss 0.409657
# Epoch 1300 | Train Loss 0.287660 | Val Loss 0.405668
# Epoch 1400 | Train Loss 0.284943 | Val Loss 0.401036
# Epoch 1500 | Train Loss 0.283738 | Val Loss 0.404089
# Epoch 1600 | Train Loss 0.283066 | Val Loss 0.405218
# Early stopping at epoch 1696
# X | train1 -> R² = 0.9923, MSE = 8.3455e-04
# X | train2 -> R² = -1.8227, MSE = 2.3784e-01
# X | test1 -> R² = 0.9879, MSE = 1.2648e-03
# X | test2 -> R² = -2.0307, MSE = 2.4941e-01
# X | test3 -> R² = -3.4449, MSE = 4.0895e-01
# X | val -> R² = -2.2357, MSE = 3.0941e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.646004 | Val Loss 0.610456
# Epoch 100 | Train Loss 0.306688 | Val Loss 0.451496
# Epoch 200 | Train Loss 0.305063 | Val Loss 0.449161
# Epoch 300 | Train Loss 0.303593 | Val Loss 0.445760
# Early stopping at epoch 311
# X | train1 -> R² = 0.8513, MSE = 1.6031e-02
# X | train2 -> R² = -0.9190, MSE = 1.6170e-01
# X | test1 -> R² = 0.7779, MSE = 2.3263e-02
# X | test2 -> R² = -0.9437, MSE = 1.5995e-01
# X | test3 -> R² = -7.4323, MSE = 7.7581e-01
# X | val -> R² = -1.9080, MSE = 2.7807e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.607637 | Val Loss 0.584194
# Epoch 100 | Train Loss 0.306742 | Val Loss 0.453837
# Epoch 200 | Train Loss 0.305376 | Val Loss 0.450706
# Epoch 300 | Train Loss 0.303855 | Val Loss 0.446879
# Early stopping at epoch 335
# X | train1 -> R² = 0.9691, MSE = 3.3346e-03
# X | train2 -> R² = -1.4568, MSE = 2.0701e-01
# X | test1 -> R² = 0.9272, MSE = 7.6245e-03
# X | test2 -> R² = -1.4016, MSE = 1.9763e-01
# X | test3 -> R² = -8.6561, MSE = 8.8840e-01
# X | val -> R² = -2.2252, MSE = 3.0841e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.588583 | Val Loss 0.568315
# Epoch 100 | Train Loss 0.306582 | Val Loss 0.453932
# Epoch 200 | Train Loss 0.304791 | Val Loss 0.449249
# Epoch 300 | Train Loss 0.303108 | Val Loss 0.445650
# Early stopping at epoch 309
# X | train1 -> R² = 0.8948, MSE = 1.1340e-02
# X | train2 -> R² = -1.0029, MSE = 1.6876e-01
# X | test1 -> R² = 0.8369, MSE = 1.7090e-02
# X | test2 -> R² = -1.0181, MSE = 1.6607e-01
# X | test3 -> R² = -7.1791, MSE = 7.5251e-01
# X | val -> R² = -1.4772, MSE = 2.3688e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.624592 | Val Loss 0.596649
# Epoch 100 | Train Loss 0.306719 | Val Loss 0.452869
# Epoch 200 | Train Loss 0.305034 | Val Loss 0.448789
# Epoch 300 | Train Loss 0.303294 | Val Loss 0.444821
# Epoch 400 | Train Loss 0.301324 | Val Loss 0.439863
# Epoch 500 | Train Loss 0.298142 | Val Loss 0.429228
# Epoch 600 | Train Loss 0.295656 | Val Loss 0.417052
# Epoch 700 | Train Loss 0.295062 | Val Loss 0.416246
# Epoch 800 | Train Loss 0.294762 | Val Loss 0.415834
# Epoch 900 | Train Loss 0.294444 | Val Loss 0.414930
# Epoch 1000 | Train Loss 0.293964 | Val Loss 0.413438
# Epoch 1100 | Train Loss 0.292939 | Val Loss 0.409967
# Epoch 1200 | Train Loss 0.291060 | Val Loss 0.404112
# Epoch 1300 | Train Loss 0.288307 | Val Loss 0.396641
# Epoch 1400 | Train Loss 0.285991 | Val Loss 0.402584
# Epoch 1500 | Train Loss 0.283635 | Val Loss 0.412451
# Early stopping at epoch 1576
# X | train1 -> R² = 0.9956, MSE = 4.7600e-04
# X | train2 -> R² = -1.9103, MSE = 2.4522e-01
# X | test1 -> R² = 0.9902, MSE = 1.0235e-03
# X | test2 -> R² = -2.0273, MSE = 2.4912e-01
# X | test3 -> R² = -2.7089, MSE = 3.4123e-01
# X | val -> R² = -2.4931, MSE = 3.3402e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.583037 | Val Loss 0.568253
# Epoch 100 | Train Loss 0.306330 | Val Loss 0.454211
# Epoch 200 | Train Loss 0.304781 | Val Loss 0.449317
# Epoch 300 | Train Loss 0.303025 | Val Loss 0.445342
# Epoch 400 | Train Loss 0.301070 | Val Loss 0.439613
# Epoch 500 | Train Loss 0.297682 | Val Loss 0.429082
# Epoch 600 | Train Loss 0.295163 | Val Loss 0.417837
# Epoch 700 | Train Loss 0.294835 | Val Loss 0.415634
# Epoch 800 | Train Loss 0.294567 | Val Loss 0.415505
# Epoch 900 | Train Loss 0.294221 | Val Loss 0.414467
# Epoch 1000 | Train Loss 0.293513 | Val Loss 0.413107
# Epoch 1100 | Train Loss 0.291819 | Val Loss 0.409294
# Epoch 1200 | Train Loss 0.289161 | Val Loss 0.405881
# Epoch 1300 | Train Loss 0.286524 | Val Loss 0.403833
# Epoch 1400 | Train Loss 0.283606 | Val Loss 0.404622
# Epoch 1500 | Train Loss 0.282175 | Val Loss 0.410607
# Early stopping at epoch 1547
# X | train1 -> R² = 0.9959, MSE = 4.3809e-04
# X | train2 -> R² = -1.8883, MSE = 2.4337e-01
# X | test1 -> R² = 0.9873, MSE = 1.3284e-03
# X | test2 -> R² = -2.0445, MSE = 2.5054e-01
# X | test3 -> R² = -1.8819, MSE = 2.6515e-01
# X | val -> R² = -0.1644, MSE = 1.1134e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.557642 | Val Loss 0.552189
# Epoch 100 | Train Loss 0.306773 | Val Loss 0.455015
# Epoch 200 | Train Loss 0.305375 | Val Loss 0.449848
# Epoch 300 | Train Loss 0.303643 | Val Loss 0.445509
# Epoch 400 | Train Loss 0.301835 | Val Loss 0.441030
# Epoch 500 | Train Loss 0.298667 | Val Loss 0.431333
# Epoch 600 | Train Loss 0.295709 | Val Loss 0.417830
# Epoch 700 | Train Loss 0.295127 | Val Loss 0.415827
# Epoch 800 | Train Loss 0.294856 | Val Loss 0.415300
# Epoch 900 | Train Loss 0.294599 | Val Loss 0.414644
# Epoch 1000 | Train Loss 0.294282 | Val Loss 0.414254
# Epoch 1100 | Train Loss 0.293834 | Val Loss 0.413399
# Epoch 1200 | Train Loss 0.292750 | Val Loss 0.411043
# Epoch 1300 | Train Loss 0.290221 | Val Loss 0.412445
# Epoch 1400 | Train Loss 0.288441 | Val Loss 0.410123
# Epoch 1500 | Train Loss 0.286275 | Val Loss 0.405250
# Epoch 1600 | Train Loss 0.283971 | Val Loss 0.406754
# Epoch 1700 | Train Loss 0.282900 | Val Loss 0.410799
# Epoch 1800 | Train Loss 0.282142 | Val Loss 0.414220
# Epoch 1900 | Train Loss 0.281454 | Val Loss 0.417210
# Early stopping at epoch 1927
# X | train1 -> R² = 0.9355, MSE = 6.9569e-03
# X | train2 -> R² = -2.0435, MSE = 2.5644e-01
# X | test1 -> R² = 0.9703, MSE = 3.1143e-03
# X | test2 -> R² = -2.3807, MSE = 2.7821e-01
# X | test3 -> R² = -2.0752, MSE = 2.8293e-01
# X | val -> R² = 0.1388, MSE = 8.2353e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.625412 | Val Loss 0.595099
# Epoch 100 | Train Loss 0.306613 | Val Loss 0.450853
# Epoch 200 | Train Loss 0.305084 | Val Loss 0.449100
# Epoch 300 | Train Loss 0.303660 | Val Loss 0.446122
# Early stopping at epoch 311
# X | train1 -> R² = 0.8866, MSE = 1.2223e-02
# X | train2 -> R² = -1.0618, MSE = 1.7373e-01
# X | test1 -> R² = 0.8144, MSE = 1.9446e-02
# X | test2 -> R² = -1.0642, MSE = 1.6987e-01
# X | test3 -> R² = -8.0813, MSE = 8.3552e-01
# X | val -> R² = -2.3067, MSE = 3.1619e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.537838 | Val Loss 0.541036
# Epoch 100 | Train Loss 0.306289 | Val Loss 0.454762
# Epoch 200 | Train Loss 0.304568 | Val Loss 0.449406
# Epoch 300 | Train Loss 0.303090 | Val Loss 0.445563
# Epoch 400 | Train Loss 0.301631 | Val Loss 0.441287
# Epoch 500 | Train Loss 0.298484 | Val Loss 0.431103
# Epoch 600 | Train Loss 0.295382 | Val Loss 0.416983
# Epoch 700 | Train Loss 0.294765 | Val Loss 0.415541
# Epoch 800 | Train Loss 0.294206 | Val Loss 0.413977
# Epoch 900 | Train Loss 0.292911 | Val Loss 0.410887
# Epoch 1000 | Train Loss 0.289804 | Val Loss 0.403145
# Epoch 1100 | Train Loss 0.285898 | Val Loss 0.400132
# Epoch 1200 | Train Loss 0.283963 | Val Loss 0.402379
# Epoch 1300 | Train Loss 0.282767 | Val Loss 0.405525
# Early stopping at epoch 1344
# X | train1 -> R² = 0.9834, MSE = 1.7897e-03
# X | train2 -> R² = -1.9071, MSE = 2.4496e-01
# X | test1 -> R² = 0.9928, MSE = 7.4983e-04
# X | test2 -> R² = -2.0575, MSE = 2.5162e-01
# X | test3 -> R² = -1.6053, MSE = 2.3970e-01
# X | val -> R² = -0.6454, MSE = 1.5734e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.648469 | Val Loss 0.614505
# Epoch 100 | Train Loss 0.306173 | Val Loss 0.453654
# Epoch 200 | Train Loss 0.304741 | Val Loss 0.449816
# Epoch 300 | Train Loss 0.303370 | Val Loss 0.446253
# Early stopping at epoch 312
# X | train1 -> R² = 0.8893, MSE = 1.1932e-02
# X | train2 -> R² = -0.9827, MSE = 1.6706e-01
# X | test1 -> R² = 0.8314, MSE = 1.7666e-02
# X | test2 -> R² = -1.0018, MSE = 1.6474e-01
# X | test3 -> R² = -7.1124, MSE = 7.4638e-01
# X | val -> R² = -1.4655, MSE = 2.3576e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.466939 | Val Loss 0.545047
# Epoch 100 | Train Loss 0.216644 | Val Loss 0.453188
# Epoch 200 | Train Loss 0.213536 | Val Loss 0.449775
# Epoch 300 | Train Loss 0.210687 | Val Loss 0.445862
# Early stopping at epoch 308
# X | train1 -> R² = 0.8614, MSE = 1.4944e-02
# X | train2 -> R² = -0.9616, MSE = 1.6529e-01
# X | test1 -> R² = 0.7877, MSE = 2.2236e-02
# X | test2 -> R² = -0.9760, MSE = 1.6261e-01
# X | test3 -> R² = -7.6113, MSE = 7.9228e-01
# X | val -> R² = -2.1292, MSE = 2.9923e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.580614 | Val Loss 0.624181
# Epoch 100 | Train Loss 0.216786 | Val Loss 0.453761
# Epoch 200 | Train Loss 0.214409 | Val Loss 0.451122
# Epoch 300 | Train Loss 0.212143 | Val Loss 0.447505
# Early stopping at epoch 312
# X | train1 -> R² = 0.8557, MSE = 1.5565e-02
# X | train2 -> R² = -0.9205, MSE = 1.6183e-01
# X | test1 -> R² = 0.7851, MSE = 2.2514e-02
# X | test2 -> R² = -0.9451, MSE = 1.6006e-01
# X | test3 -> R² = -7.3079, MSE = 7.6436e-01
# X | val -> R² = -1.7958, MSE = 2.6734e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.523100 | Val Loss 0.582817
# Epoch 100 | Train Loss 0.216964 | Val Loss 0.453329
# Epoch 200 | Train Loss 0.214286 | Val Loss 0.450994
# Epoch 300 | Train Loss 0.211929 | Val Loss 0.447501
# Early stopping at epoch 310
# X | train1 -> R² = 0.8794, MSE = 1.3001e-02
# X | train2 -> R² = -1.0271, MSE = 1.7080e-01
# X | test1 -> R² = 0.8084, MSE = 2.0071e-02
# X | test2 -> R² = -1.0406, MSE = 1.6793e-01
# X | test3 -> R² = -7.8606, MSE = 8.1522e-01
# X | val -> R² = -2.0815, MSE = 2.9467e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.538245 | Val Loss 0.589725
# Epoch 100 | Train Loss 0.217103 | Val Loss 0.454602
# Epoch 200 | Train Loss 0.213988 | Val Loss 0.451065
# Epoch 300 | Train Loss 0.211349 | Val Loss 0.447260
# Early stopping at epoch 310
# X | train1 -> R² = 0.8500, MSE = 1.6177e-02
# X | train2 -> R² = -0.9317, MSE = 1.6277e-01
# X | test1 -> R² = 0.7741, MSE = 2.3668e-02
# X | test2 -> R² = -0.9568, MSE = 1.6103e-01
# X | test3 -> R² = -7.5935, MSE = 7.9064e-01
# X | val -> R² = -1.9591, MSE = 2.8296e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.516401 | Val Loss 0.581447
# Epoch 100 | Train Loss 0.216725 | Val Loss 0.455921
# Epoch 200 | Train Loss 0.213777 | Val Loss 0.449896
# Epoch 300 | Train Loss 0.211197 | Val Loss 0.445427
# Epoch 400 | Train Loss 0.209035 | Val Loss 0.440073
# Epoch 500 | Train Loss 0.206709 | Val Loss 0.429797
# Epoch 600 | Train Loss 0.205789 | Val Loss 0.426967
# Epoch 700 | Train Loss 0.205309 | Val Loss 0.426496
# Epoch 800 | Train Loss 0.204728 | Val Loss 0.426368
# Epoch 900 | Train Loss 0.203503 | Val Loss 0.422171
# Epoch 1000 | Train Loss 0.199164 | Val Loss 0.411757
# Epoch 1100 | Train Loss 0.195698 | Val Loss 0.409217
# Epoch 1200 | Train Loss 0.193794 | Val Loss 0.422166
# Epoch 1300 | Train Loss 0.192816 | Val Loss 0.427910
# Early stopping at epoch 1341
# X | train1 -> R² = 0.9950, MSE = 5.4316e-04
# X | train2 -> R² = -1.9650, MSE = 2.4983e-01
# ...
# Epoch 600 | Train Loss 0.284429 | Val Loss 0.407320
# Epoch 700 | Train Loss 0.283107 | Val Loss 0.408518
# Early stopping at epoch 728
# X | train1 -> R² = 0.9180, MSE = 8.8413e-03
# X | train2 -> R² = -2.0727, MSE = 2.5891e-01
# X | test1 -> R² = 0.9503, MSE = 5.2027e-03
# X | test2 -> R² = -2.3438, MSE = 2.7517e-01
# X | test3 -> R² = -1.7655, MSE = 2.5444e-01
# X | val -> R² = 0.2758, MSE = 6.9254e-02
# Modelo [264, 128] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.639847 | Val Loss 0.450821
# Epoch 100 | Train Loss 0.305219 | Val Loss 0.450222
# Epoch 200 | Train Loss 0.302918 | Val Loss 0.445542
# Epoch 300 | Train Loss 0.292590 | Val Loss 0.410928
# Epoch 400 | Train Loss 0.286442 | Val Loss 0.403622
# Epoch 500 | Train Loss 0.284801 | Val Loss 0.406806
# Epoch 600 | Train Loss 0.283219 | Val Loss 0.409218
# Early stopping at epoch 616
# X | train1 -> R² = 0.6120, MSE = 4.1832e-02
# X | train2 -> R² = -2.6599, MSE = 3.0838e-01
# X | test1 -> R² = 0.6765, MSE = 3.3891e-02
# X | test2 -> R² = -2.8158, MSE = 3.1401e-01
# X | test3 -> R² = 0.0839, MSE = 8.4285e-02
# X | val -> R² = 0.6607, MSE = 3.2446e-02
# Modelo [264, 128] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.829522 | Val Loss 0.443421
# Epoch 100 | Train Loss 0.305605 | Val Loss 0.449619
# Epoch 200 | Train Loss 0.303340 | Val Loss 0.445124
# Epoch 300 | Train Loss 0.290489 | Val Loss 0.404319
# Epoch 400 | Train Loss 0.286600 | Val Loss 0.403330
# Epoch 500 | Train Loss 0.285507 | Val Loss 0.408076
# Epoch 600 | Train Loss 0.283724 | Val Loss 0.418522
# Early stopping at epoch 616
# X | train1 -> R² = 0.9960, MSE = 4.3605e-04
# X | train2 -> R² = -1.8954, MSE = 2.4397e-01
# X | test1 -> R² = 0.9809, MSE = 1.9982e-03
# X | test2 -> R² = -2.0452, MSE = 2.5060e-01
# X | test3 -> R² = -4.1231, MSE = 4.7135e-01
# X | val -> R² = -1.8206, MSE = 2.6972e-01
# Modelo [264, 128] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.685639 | Val Loss 0.442042
# Epoch 100 | Train Loss 0.213750 | Val Loss 0.452057
# Epoch 200 | Train Loss 0.209662 | Val Loss 0.447239
# Epoch 300 | Train Loss 0.196410 | Val Loss 0.405622
# Epoch 400 | Train Loss 0.194467 | Val Loss 0.410774
# Epoch 500 | Train Loss 0.193076 | Val Loss 0.410704
# Early stopping at epoch 577
# X | train1 -> R² = 0.9939, MSE = 6.5981e-04
# X | train2 -> R² = -1.9563, MSE = 2.4910e-01
# X | test1 -> R² = 0.9770, MSE = 2.4101e-03
# X | test2 -> R² = -2.0675, MSE = 2.5243e-01
# X | test3 -> R² = -4.3760, MSE = 4.9461e-01
# X | val -> R² = -2.1711, MSE = 3.0323e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.643506 | Val Loss 0.441314
# Epoch 100 | Train Loss 0.213919 | Val Loss 0.452402
# Epoch 200 | Train Loss 0.209181 | Val Loss 0.444054
# Epoch 300 | Train Loss 0.196236 | Val Loss 0.405527
# Epoch 400 | Train Loss 0.194047 | Val Loss 0.410011
# Epoch 500 | Train Loss 0.192561 | Val Loss 0.414403
# Early stopping at epoch 582
# X | train1 -> R² = 0.9947, MSE = 5.7665e-04
# X | train2 -> R² = -1.9577, MSE = 2.4922e-01
# X | test1 -> R² = 0.9802, MSE = 2.0708e-03
# X | test2 -> R² = -2.0882, MSE = 2.5414e-01
# X | test3 -> R² = -3.9270, MSE = 4.5331e-01
# X | val -> R² = -1.8126, MSE = 2.6895e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.782620 | Val Loss 0.455244
# Epoch 100 | Train Loss 0.214073 | Val Loss 0.451395
# Epoch 200 | Train Loss 0.210128 | Val Loss 0.446240
# Epoch 300 | Train Loss 0.201975 | Val Loss 0.421594
# Epoch 400 | Train Loss 0.194464 | Val Loss 0.409928
# Epoch 500 | Train Loss 0.192751 | Val Loss 0.413970
# Epoch 600 | Train Loss 0.191439 | Val Loss 0.419204
# Early stopping at epoch 634
# X | train1 -> R² = 0.9951, MSE = 5.3124e-04
# X | train2 -> R² = -1.9544, MSE = 2.4894e-01
# X | test1 -> R² = 0.9869, MSE = 1.3753e-03
# X | test2 -> R² = -2.1213, MSE = 2.5687e-01
# X | test3 -> R² = -3.1481, MSE = 3.8164e-01
# X | val -> R² = -0.6414, MSE = 1.5695e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.572533 | Val Loss 0.453418
# Epoch 100 | Train Loss 0.213846 | Val Loss 0.451773
# Epoch 200 | Train Loss 0.210287 | Val Loss 0.449332
# Epoch 300 | Train Loss 0.196973 | Val Loss 0.404868
# Epoch 400 | Train Loss 0.194308 | Val Loss 0.414258
# Epoch 500 | Train Loss 0.192941 | Val Loss 0.420430
# Early stopping at epoch 596
# X | train1 -> R² = 0.9948, MSE = 5.6603e-04
# X | train2 -> R² = -1.9306, MSE = 2.4693e-01
# X | test1 -> R² = 0.9723, MSE = 2.9039e-03
# X | test2 -> R² = -2.0699, MSE = 2.5263e-01
# X | test3 -> R² = -3.8670, MSE = 4.4778e-01
# X | val -> R² = -1.8088, MSE = 2.6859e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.571307 | Val Loss 0.438230
# Epoch 100 | Train Loss 0.213552 | Val Loss 0.452112
# Epoch 200 | Train Loss 0.208490 | Val Loss 0.441177
# Epoch 300 | Train Loss 0.195551 | Val Loss 0.403785
# Epoch 400 | Train Loss 0.193295 | Val Loss 0.409806
# Epoch 500 | Train Loss 0.191815 | Val Loss 0.415509
# Epoch 600 | Train Loss 0.190709 | Val Loss 0.414028
# Early stopping at epoch 675
# X | train1 -> R² = 0.9085, MSE = 9.8607e-03
# X | train2 -> R² = -2.1285, MSE = 2.6361e-01
# X | test1 -> R² = 0.9531, MSE = 4.9151e-03
# X | test2 -> R² = -2.3388, MSE = 2.7476e-01
# X | test3 -> R² = -2.4146, MSE = 3.1416e-01
# X | val -> R² = -0.3553, MSE = 1.2960e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.530341 | Val Loss 0.446967
# Epoch 100 | Train Loss 0.213477 | Val Loss 0.451665
# Epoch 200 | Train Loss 0.208568 | Val Loss 0.442776
# Epoch 300 | Train Loss 0.195838 | Val Loss 0.408472
# Epoch 400 | Train Loss 0.193846 | Val Loss 0.411877
# Epoch 500 | Train Loss 0.193405 | Val Loss 0.415944
# Epoch 600 | Train Loss 0.190981 | Val Loss 0.419223
# Early stopping at epoch 674
# X | train1 -> R² = 0.8191, MSE = 1.9509e-02
# X | train2 -> R² = -2.2455, MSE = 2.7347e-01
# X | test1 -> R² = 0.8987, MSE = 1.0609e-02
# X | test2 -> R² = -2.4805, MSE = 2.8642e-01
# X | test3 -> R² = -1.4450, MSE = 2.2495e-01
# X | val -> R² = 0.2899, MSE = 6.7902e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.731515 | Val Loss 0.452827
# Epoch 100 | Train Loss 0.213694 | Val Loss 0.451803
# Epoch 200 | Train Loss 0.209471 | Val Loss 0.444041
# Epoch 300 | Train Loss 0.200092 | Val Loss 0.409207
# Epoch 400 | Train Loss 0.195084 | Val Loss 0.402867
# Epoch 500 | Train Loss 0.193032 | Val Loss 0.412381
# Epoch 600 | Train Loss 0.192078 | Val Loss 0.414059
# Early stopping at epoch 647
# X | train1 -> R² = 0.9488, MSE = 5.5209e-03
# X | train2 -> R² = -2.0628, MSE = 2.5807e-01
# X | test1 -> R² = 0.9796, MSE = 2.1390e-03
# X | test2 -> R² = -2.1749, MSE = 2.6127e-01
# X | test3 -> R² = -2.1967, MSE = 2.9411e-01
# X | val -> R² = -1.3838, MSE = 2.2795e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.691578 | Val Loss 0.449429
# Epoch 100 | Train Loss 0.213316 | Val Loss 0.450521
# Epoch 200 | Train Loss 0.208318 | Val Loss 0.440855
# Epoch 300 | Train Loss 0.196150 | Val Loss 0.404746
# Epoch 400 | Train Loss 0.194416 | Val Loss 0.409512
# Epoch 500 | Train Loss 0.193207 | Val Loss 0.426774
# Epoch 600 | Train Loss 0.191180 | Val Loss 0.425513
# Early stopping at epoch 688
# X | train1 -> R² = 0.8544, MSE = 1.5702e-02
# X | train2 -> R² = -2.2264, MSE = 2.7185e-01
# X | test1 -> R² = 0.9149, MSE = 8.9198e-03
# X | test2 -> R² = -2.4975, MSE = 2.8782e-01
# X | test3 -> R² = -1.8645, MSE = 2.6355e-01
# X | val -> R² = 0.1932, MSE = 7.7149e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.916837 | Val Loss 0.468659
# Epoch 100 | Train Loss 0.214224 | Val Loss 0.452481
# Epoch 200 | Train Loss 0.210873 | Val Loss 0.448303
# Epoch 300 | Train Loss 0.207445 | Val Loss 0.441197
# Early stopping at epoch 307
# X | train1 -> R² = 0.9160, MSE = 9.0607e-03
# X | train2 -> R² = -1.0481, MSE = 1.7257e-01
# X | test1 -> R² = 0.8835, MSE = 1.2200e-02
# X | test2 -> R² = -0.9931, MSE = 1.6402e-01
# X | test3 -> R² = -5.3040, MSE = 5.7999e-01
# X | val -> R² = -1.1734, MSE = 2.0783e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.660428 | Val Loss 0.439754
# Epoch 100 | Train Loss 0.213911 | Val Loss 0.452563
# Epoch 200 | Train Loss 0.209936 | Val Loss 0.445300
# Epoch 300 | Train Loss 0.200041 | Val Loss 0.414229
# Epoch 400 | Train Loss 0.195014 | Val Loss 0.405457
# Epoch 500 | Train Loss 0.192901 | Val Loss 0.418242
# Epoch 600 | Train Loss 0.191076 | Val Loss 0.424192
# Early stopping at epoch 603
# X | train1 -> R² = 0.8409, MSE = 1.7154e-02
# X | train2 -> R² = -2.3652, MSE = 2.8355e-01
# X | test1 -> R² = 0.8836, MSE = 1.2196e-02
# X | test2 -> R² = -2.4294, MSE = 2.8221e-01
# X | test3 -> R² = -1.1594, MSE = 1.9868e-01
# X | val -> R² = 0.0492, MSE = 9.0920e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.565574 | Val Loss 0.449069
# Epoch 100 | Train Loss 0.213520 | Val Loss 0.451524
# Epoch 200 | Train Loss 0.208379 | Val Loss 0.443532
# Epoch 300 | Train Loss 0.195679 | Val Loss 0.405487
# Epoch 400 | Train Loss 0.193706 | Val Loss 0.412002
# Epoch 500 | Train Loss 0.192885 | Val Loss 0.415069
# Early stopping at epoch 575
# X | train1 -> R² = 0.9950, MSE = 5.3405e-04
# X | train2 -> R² = -1.9573, MSE = 2.4919e-01
# X | test1 -> R² = 0.9814, MSE = 1.9439e-03
# X | test2 -> R² = -2.1241, MSE = 2.5709e-01
# X | test3 -> R² = -3.3563, MSE = 4.0080e-01
# X | val -> R² = -0.7094, MSE = 1.6345e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.759925 | Val Loss 0.451431
# Epoch 100 | Train Loss 0.213872 | Val Loss 0.452068
# Epoch 200 | Train Loss 0.210104 | Val Loss 0.446130
# Epoch 300 | Train Loss 0.199512 | Val Loss 0.411127
# Epoch 400 | Train Loss 0.195063 | Val Loss 0.404293
# Epoch 500 | Train Loss 0.193590 | Val Loss 0.409890
# Epoch 600 | Train Loss 0.192200 | Val Loss 0.419516
# Epoch 700 | Train Loss 0.190372 | Val Loss 0.420971
# Early stopping at epoch 751
# X | train1 -> R² = 0.8428, MSE = 1.6956e-02
# X | train2 -> R² = -2.1649, MSE = 2.6668e-01
# X | test1 -> R² = 0.9102, MSE = 9.4075e-03
# X | test2 -> R² = -2.4246, MSE = 2.8182e-01
# X | test3 -> R² = -1.6034, MSE = 2.3953e-01
# X | val -> R² = 0.1320, MSE = 8.3001e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.850370 | Val Loss 0.480297
# Epoch 100 | Train Loss 0.213949 | Val Loss 0.452383
# Epoch 200 | Train Loss 0.210823 | Val Loss 0.448317
# Epoch 300 | Train Loss 0.205499 | Val Loss 0.429227
# Epoch 400 | Train Loss 0.195601 | Val Loss 0.408531
# Epoch 500 | Train Loss 0.193541 | Val Loss 0.413249
# Epoch 600 | Train Loss 0.193146 | Val Loss 0.408384
# Early stopping at epoch 678
# X | train1 -> R² = 0.9634, MSE = 3.9431e-03
# X | train2 -> R² = -2.0351, MSE = 2.5574e-01
# X | test1 -> R² = 0.9862, MSE = 1.4467e-03
# X | test2 -> R² = -2.2317, MSE = 2.6595e-01
# X | test3 -> R² = -1.8422, MSE = 2.6149e-01
# X | val -> R² = 0.1336, MSE = 8.2851e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.587057 | Val Loss 0.439410
# Epoch 100 | Train Loss 0.213447 | Val Loss 0.451154
# Epoch 200 | Train Loss 0.208767 | Val Loss 0.442793
# Epoch 300 | Train Loss 0.196422 | Val Loss 0.405090
# Epoch 400 | Train Loss 0.194569 | Val Loss 0.418175
# Epoch 500 | Train Loss 0.192332 | Val Loss 0.421737
# Early stopping at epoch 578
# X | train1 -> R² = 0.9948, MSE = 5.5765e-04
# X | train2 -> R² = -1.9489, MSE = 2.4848e-01
# X | test1 -> R² = 0.9826, MSE = 1.8190e-03
# X | test2 -> R² = -2.0873, MSE = 2.5406e-01
# X | test3 -> R² = -3.3721, MSE = 4.0226e-01
# X | val -> R² = -1.4806, MSE = 2.3720e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.850390 | Val Loss 0.461886
# Epoch 100 | Train Loss 0.214264 | Val Loss 0.452603
# Epoch 200 | Train Loss 0.209939 | Val Loss 0.444643
# Epoch 300 | Train Loss 0.205974 | Val Loss 0.433806
# Epoch 400 | Train Loss 0.197173 | Val Loss 0.402172
# Epoch 500 | Train Loss 0.194509 | Val Loss 0.408139
# Epoch 600 | Train Loss 0.193536 | Val Loss 0.427242
# Early stopping at epoch 688
# X | train1 -> R² = 0.9922, MSE = 8.4561e-04
# X | train2 -> R² = -1.9628, MSE = 2.4964e-01
# X | test1 -> R² = 0.9928, MSE = 7.5038e-04
# X | test2 -> R² = -2.1129, MSE = 2.5617e-01
# X | test3 -> R² = -2.5851, MSE = 3.2984e-01
# X | val -> R² = -0.5319, MSE = 1.4648e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.712284 | Val Loss 0.448054
# Epoch 100 | Train Loss 0.394651 | Val Loss 0.448867
# Epoch 200 | Train Loss 0.392451 | Val Loss 0.442267
# Epoch 300 | Train Loss 0.377316 | Val Loss 0.411487
# Epoch 400 | Train Loss 0.375671 | Val Loss 0.415356
# Epoch 500 | Train Loss 0.371854 | Val Loss 0.414280
# Early stopping at epoch 555
# X | train1 -> R² = 0.9935, MSE = 7.0233e-04
# X | train2 -> R² = -1.8362, MSE = 2.3898e-01
# X | test1 -> R² = 0.9663, MSE = 3.5331e-03
# X | test2 -> R² = -1.9244, MSE = 2.4066e-01
# X | test3 -> R² = -2.8716, MSE = 3.5620e-01
# X | val -> R² = -1.2256, MSE = 2.1282e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.851913 | Val Loss 0.443731
# Epoch 100 | Train Loss 0.394855 | Val Loss 0.448655
# Epoch 200 | Train Loss 0.393574 | Val Loss 0.445102
# Epoch 300 | Train Loss 0.382439 | Val Loss 0.410426
# Epoch 400 | Train Loss 0.374070 | Val Loss 0.409442
# Epoch 500 | Train Loss 0.371878 | Val Loss 0.404189
# Epoch 600 | Train Loss 0.369937 | Val Loss 0.403463
# Epoch 700 | Train Loss 0.367639 | Val Loss 0.412951
# Epoch 800 | Train Loss 0.364977 | Val Loss 0.417585
# Early stopping at epoch 822
# X | train1 -> R² = 0.8904, MSE = 1.1821e-02
# X | train2 -> R² = -1.9244, MSE = 2.4641e-01
# X | test1 -> R² = 0.8940, MSE = 1.1100e-02
# X | test2 -> R² = -2.3373, MSE = 2.7463e-01
# X | test3 -> R² = -1.1881, MSE = 2.0132e-01
# X | val -> R² = 0.6491, MSE = 3.3558e-02
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.009469 | Val Loss 0.472202
# Epoch 100 | Train Loss 0.395123 | Val Loss 0.449825
# Epoch 200 | Train Loss 0.393904 | Val Loss 0.446740
# Epoch 300 | Train Loss 0.388971 | Val Loss 0.435484
# Early stopping at epoch 307
# X | train1 -> R² = 0.9512, MSE = 5.2587e-03
# X | train2 -> R² = -1.3679, MSE = 1.9952e-01
# X | test1 -> R² = 0.9349, MSE = 6.8190e-03
# X | test2 -> R² = -1.2711, MSE = 1.8690e-01
# X | test3 -> R² = -5.8435, MSE = 6.2964e-01
# X | val -> R² = -1.4153, MSE = 2.3096e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.940509 | Val Loss 0.458760
# Epoch 100 | Train Loss 0.394911 | Val Loss 0.448846
# Epoch 200 | Train Loss 0.393737 | Val Loss 0.445946
# Epoch 300 | Train Loss 0.391488 | Val Loss 0.435383
# Epoch 400 | Train Loss 0.375284 | Val Loss 0.402831
# Epoch 500 | Train Loss 0.372702 | Val Loss 0.395880
# Epoch 600 | Train Loss 0.370868 | Val Loss 0.399167
# Epoch 700 | Train Loss 0.369743 | Val Loss 0.397271
# Epoch 800 | Train Loss 0.369253 | Val Loss 0.399391
# Epoch 900 | Train Loss 0.363860 | Val Loss 0.407299
# Early stopping at epoch 921
# X | train1 -> R² = 0.9541, MSE = 4.9456e-03
# X | train2 -> R² = -1.6940, MSE = 2.2700e-01
# X | test1 -> R² = 0.9573, MSE = 4.4731e-03
# X | test2 -> R² = -2.0291, MSE = 2.4927e-01
# X | test3 -> R² = -1.6827, MSE = 2.4682e-01
# X | val -> R² = 0.3719, MSE = 6.0063e-02
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.002285 | Val Loss 0.464184
# Epoch 100 | Train Loss 0.394997 | Val Loss 0.448650
# Epoch 200 | Train Loss 0.393849 | Val Loss 0.446151
# Epoch 300 | Train Loss 0.386309 | Val Loss 0.424546
# Epoch 400 | Train Loss 0.377092 | Val Loss 0.411127
# Epoch 500 | Train Loss 0.374041 | Val Loss 0.407787
# Epoch 600 | Train Loss 0.375779 | Val Loss 0.394944
# Epoch 700 | Train Loss 0.369322 | Val Loss 0.398791
# Epoch 800 | Train Loss 0.368956 | Val Loss 0.405072
# Early stopping at epoch 897
# X | train1 -> R² = 0.9368, MSE = 6.8172e-03
# X | train2 -> R² = -1.2009, MSE = 1.8545e-01
# X | test1 -> R² = 0.9316, MSE = 7.1705e-03
# X | test2 -> R² = -1.4478, MSE = 2.0144e-01
# X | test3 -> R² = -3.2296, MSE = 3.8914e-01
# X | val -> R² = -0.4186, MSE = 1.3565e-01
# Modelo [264, 128] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.007305 | Val Loss 0.465714
# Epoch 100 | Train Loss 0.394946 | Val Loss 0.449388
# Epoch 200 | Train Loss 0.393890 | Val Loss 0.446344
# Epoch 300 | Train Loss 0.391909 | Val Loss 0.433686
