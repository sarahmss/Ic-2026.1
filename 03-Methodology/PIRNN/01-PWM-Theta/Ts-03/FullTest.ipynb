# %% [markdown]
# - Entradas: WdRef, WeRef
# - Saidas: Theta
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.035581 | Val Loss 0.814306
# Epoch 100 | Train Loss 0.796981 | Val Loss 0.649309
# Epoch 200 | Train Loss 0.764531 | Val Loss 0.581506
# Epoch 300 | Train Loss 0.734483 | Val Loss 0.537380
# Epoch 400 | Train Loss 0.683092 | Val Loss 0.580645
# Epoch 500 | Train Loss 0.629379 | Val Loss 0.808124
# Early stopping at epoch 595
# Theta | train1 -> R² = 0.6890, MSE = 7.0983e-02
# Theta | train2 -> R² = 0.8066, MSE = 4.4164e-02
# Theta | test1 -> R² = 0.3926, MSE = 1.3952e-01
# Theta | test2 -> R² = 0.5629, MSE = 1.0366e-01
# Theta | test3 -> R² = -2.7488, MSE = 1.2324e+00
# Theta | val -> R² = -5.6126, MSE = 2.1642e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.034375 | Val Loss 0.825433
# Epoch 100 | Train Loss 0.791799 | Val Loss 0.633148
# Epoch 200 | Train Loss 0.754710 | Val Loss 0.560261
# Epoch 300 | Train Loss 0.719603 | Val Loss 0.536045
# Epoch 400 | Train Loss 0.645607 | Val Loss 0.726716
# Epoch 500 | Train Loss 0.623443 | Val Loss 0.797280
# Early stopping at epoch 558
# Theta | train1 -> R² = 0.6700, MSE = 7.5335e-02
# Theta | train2 -> R² = 0.8007, MSE = 4.5491e-02
# Theta | test1 -> R² = 0.3334, MSE = 1.5312e-01
# Theta | test2 -> R² = 0.5736, MSE = 1.0113e-01
# Theta | test3 -> R² = -2.0448, MSE = 1.0010e+00
# Theta | val -> R² = -2.5693, MSE = 1.1682e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.030438 | Val Loss 0.812343
# Epoch 100 | Train Loss 0.797119 | Val Loss 0.647541
# Epoch 200 | Train Loss 0.765899 | Val Loss 0.572183
# Epoch 300 | Train Loss 0.735448 | Val Loss 0.526667
# Epoch 400 | Train Loss 0.687940 | Val Loss 0.568942
# Epoch 500 | Train Loss 0.639515 | Val Loss 0.704338
# Epoch 600 | Train Loss 0.618492 | Val Loss 0.770563
# Early stopping at epoch 620
# Theta | train1 -> R² = 0.7632, MSE = 5.4059e-02
# Theta | train2 -> R² = 0.7784, MSE = 5.0593e-02
# Theta | test1 -> R² = 0.4808, MSE = 1.1928e-01
# Theta | test2 -> R² = 0.5656, MSE = 1.0303e-01
# Theta | test3 -> R² = -2.0918, MSE = 1.0164e+00
# Theta | val -> R² = -5.5371, MSE = 2.1395e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.036634 | Val Loss 0.816690
# Epoch 100 | Train Loss 0.794459 | Val Loss 0.655324
# Epoch 200 | Train Loss 0.762995 | Val Loss 0.595026
# Epoch 300 | Train Loss 0.734108 | Val Loss 0.535791
# Epoch 400 | Train Loss 0.659317 | Val Loss 0.655665
# Epoch 500 | Train Loss 0.629607 | Val Loss 0.799933
# Epoch 600 | Train Loss 0.612094 | Val Loss 0.838875
# Early stopping at epoch 604
# Theta | train1 -> R² = 0.6927, MSE = 7.0155e-02
# Theta | train2 -> R² = 0.8087, MSE = 4.3671e-02
# Theta | test1 -> R² = 0.3510, MSE = 1.4909e-01
# Theta | test2 -> R² = 0.6831, MSE = 7.5163e-02
# Theta | test3 -> R² = -1.5545, MSE = 8.3979e-01
# Theta | val -> R² = -2.4468, MSE = 1.1281e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.045571 | Val Loss 0.818548
# Epoch 100 | Train Loss 0.798849 | Val Loss 0.652584
# Epoch 200 | Train Loss 0.768888 | Val Loss 0.587669
# Epoch 300 | Train Loss 0.736972 | Val Loss 0.535553
# Epoch 400 | Train Loss 0.686921 | Val Loss 0.566251
# Epoch 500 | Train Loss 0.632956 | Val Loss 0.771848
# Epoch 600 | Train Loss 0.614761 | Val Loss 0.834230
# Early stopping at epoch 627
# Theta | train1 -> R² = 0.7319, MSE = 6.1189e-02
# Theta | train2 -> R² = 0.8163, MSE = 4.1931e-02
# Theta | test1 -> R² = 0.4405, MSE = 1.2853e-01
# Theta | test2 -> R² = 0.6514, MSE = 8.2673e-02
# Theta | test3 -> R² = -2.8923, MSE = 1.2796e+00
# Theta | val -> R² = -5.1047, MSE = 1.9979e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.037184 | Val Loss 0.808343
# Epoch 100 | Train Loss 0.795131 | Val Loss 0.647632
# Epoch 200 | Train Loss 0.760190 | Val Loss 0.581280
# Epoch 300 | Train Loss 0.733925 | Val Loss 0.543271
# Epoch 400 | Train Loss 0.673413 | Val Loss 0.580727
# Epoch 500 | Train Loss 0.636590 | Val Loss 0.711236
# Epoch 600 | Train Loss 0.615461 | Val Loss 0.796956
# Early stopping at epoch 620
# Theta | train1 -> R² = 0.7293, MSE = 6.1798e-02
# Theta | train2 -> R² = 0.8188, MSE = 4.1363e-02
# Theta | test1 -> R² = 0.4532, MSE = 1.2562e-01
# Theta | test2 -> R² = 0.7218, MSE = 6.5983e-02
# Theta | test3 -> R² = -1.6001, MSE = 8.5478e-01
# Theta | val -> R² = -7.1657, MSE = 2.6725e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.039652 | Val Loss 0.820888
# Epoch 100 | Train Loss 0.800463 | Val Loss 0.670505
# Epoch 200 | Train Loss 0.778034 | Val Loss 0.611583
# Epoch 300 | Train Loss 0.756024 | Val Loss 0.577030
# Epoch 400 | Train Loss 0.711197 | Val Loss 0.562784
# Epoch 500 | Train Loss 0.648835 | Val Loss 0.701489
# Epoch 600 | Train Loss 0.627778 | Val Loss 0.800202
# Early stopping at epoch 668
# Theta | train1 -> R² = 0.7843, MSE = 4.9246e-02
# Theta | train2 -> R² = 0.7966, MSE = 4.6435e-02
# Theta | test1 -> R² = 0.4488, MSE = 1.2663e-01
# Theta | test2 -> R² = 0.7594, MSE = 5.7062e-02
# Theta | test3 -> R² = -0.9219, MSE = 6.3181e-01
# Theta | val -> R² = -3.3731, MSE = 1.4312e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.040969 | Val Loss 0.823529
# Epoch 100 | Train Loss 0.796710 | Val Loss 0.650292
# Epoch 200 | Train Loss 0.769254 | Val Loss 0.590051
# Epoch 300 | Train Loss 0.741545 | Val Loss 0.540577
# Epoch 400 | Train Loss 0.704265 | Val Loss 0.531085
# Epoch 500 | Train Loss 0.639493 | Val Loss 0.743179
# Epoch 600 | Train Loss 0.616661 | Val Loss 0.828143
# Early stopping at epoch 666
# Theta | train1 -> R² = 0.6911, MSE = 7.0521e-02
# Theta | train2 -> R² = 0.7919, MSE = 4.7501e-02
# Theta | test1 -> R² = 0.3911, MSE = 1.3986e-01
# Theta | test2 -> R² = 0.6380, MSE = 8.5864e-02
# Theta | test3 -> R² = -2.3181, MSE = 1.0908e+00
# Theta | val -> R² = -3.8437, MSE = 1.5853e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.048875 | Val Loss 0.819492
# Epoch 100 | Train Loss 0.795901 | Val Loss 0.660777
# Epoch 200 | Train Loss 0.764008 | Val Loss 0.592568
# Epoch 300 | Train Loss 0.734980 | Val Loss 0.527409
# Epoch 400 | Train Loss 0.695486 | Val Loss 0.530807
# Epoch 500 | Train Loss 0.636599 | Val Loss 0.717168
# Epoch 600 | Train Loss 0.614354 | Val Loss 0.815027
# Early stopping at epoch 658
# Theta | train1 -> R² = 0.7590, MSE = 5.5007e-02
# Theta | train2 -> R² = 0.7544, MSE = 5.6069e-02
# Theta | test1 -> R² = 0.4853, MSE = 1.1823e-01
# Theta | test2 -> R² = 0.4884, MSE = 1.2133e-01
# Theta | test3 -> R² = -1.9909, MSE = 9.8325e-01
# Theta | val -> R² = -3.1223, MSE = 1.3491e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.034102 | Val Loss 0.816098
# Epoch 100 | Train Loss 0.791125 | Val Loss 0.627901
# Epoch 200 | Train Loss 0.754410 | Val Loss 0.557717
# Epoch 300 | Train Loss 0.733593 | Val Loss 0.529903
# Epoch 400 | Train Loss 0.676293 | Val Loss 0.579581
# Epoch 500 | Train Loss 0.640144 | Val Loss 0.677699
# Epoch 600 | Train Loss 0.620493 | Val Loss 0.729999
# Early stopping at epoch 638
# Theta | train1 -> R² = 0.7250, MSE = 6.2776e-02
# Theta | train2 -> R² = 0.8104, MSE = 4.3276e-02
# Theta | test1 -> R² = 0.4550, MSE = 1.2519e-01
# Theta | test2 -> R² = 0.7650, MSE = 5.5727e-02
# Theta | test3 -> R² = -1.6828, MSE = 8.8197e-01
# Theta | val -> R² = -6.6594, MSE = 2.5068e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.038732 | Val Loss 0.816599
# Epoch 100 | Train Loss 0.796713 | Val Loss 0.662187
# Epoch 200 | Train Loss 0.763511 | Val Loss 0.596217
# Epoch 300 | Train Loss 0.739423 | Val Loss 0.546894
# Epoch 400 | Train Loss 0.716404 | Val Loss 0.527423
# Epoch 500 | Train Loss 0.639781 | Val Loss 0.696467
# Epoch 600 | Train Loss 0.614130 | Val Loss 0.787531
# Epoch 700 | Train Loss 0.603327 | Val Loss 0.847110
# Early stopping at epoch 702
# Theta | train1 -> R² = 0.6483, MSE = 8.0292e-02
# Theta | train2 -> R² = 0.7536, MSE = 5.6252e-02
# Theta | test1 -> R² = 0.4634, MSE = 1.2326e-01
# Theta | test2 -> R² = 0.5769, MSE = 1.0035e-01
# Theta | test3 -> R² = -3.0410, MSE = 1.3285e+00
# Theta | val -> R² = -6.7907, MSE = 2.5497e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.029358 | Val Loss 0.809138
# Epoch 100 | Train Loss 0.798377 | Val Loss 0.664073
# Epoch 200 | Train Loss 0.773881 | Val Loss 0.590412
# Epoch 300 | Train Loss 0.740145 | Val Loss 0.540549
# Epoch 400 | Train Loss 0.675380 | Val Loss 0.625648
# Epoch 500 | Train Loss 0.641035 | Val Loss 0.794470
# Early stopping at epoch 595
# Theta | train1 -> R² = 0.7769, MSE = 5.0922e-02
# Theta | train2 -> R² = 0.7950, MSE = 4.6800e-02
# Theta | test1 -> R² = 0.4714, MSE = 1.2144e-01
# Theta | test2 -> R² = 0.6114, MSE = 9.2170e-02
# Theta | test3 -> R² = -1.8267, MSE = 9.2928e-01
# Theta | val -> R² = -3.3542, MSE = 1.4250e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.028903 | Val Loss 0.809403
# Epoch 100 | Train Loss 0.796709 | Val Loss 0.640645
# Epoch 200 | Train Loss 0.766809 | Val Loss 0.570060
# Epoch 300 | Train Loss 0.738403 | Val Loss 0.536603
# Epoch 400 | Train Loss 0.701357 | Val Loss 0.527181
# Epoch 500 | Train Loss 0.641080 | Val Loss 0.715992
# Epoch 600 | Train Loss 0.617059 | Val Loss 0.788146
# Early stopping at epoch 671
# Theta | train1 -> R² = 0.7639, MSE = 5.3892e-02
# Theta | train2 -> R² = 0.7943, MSE = 4.6967e-02
# Theta | test1 -> R² = 0.5005, MSE = 1.1474e-01
# Theta | test2 -> R² = 0.6748, MSE = 7.7118e-02
# Theta | test3 -> R² = -1.0203, MSE = 6.6416e-01
# Theta | val -> R² = -3.3682, MSE = 1.4296e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.032386 | Val Loss 0.811788
# Epoch 100 | Train Loss 0.795120 | Val Loss 0.646791
# Epoch 200 | Train Loss 0.756487 | Val Loss 0.572325
# Epoch 300 | Train Loss 0.732416 | Val Loss 0.532464
# Epoch 400 | Train Loss 0.651718 | Val Loss 0.691630
# Epoch 500 | Train Loss 0.625803 | Val Loss 0.869368
# Epoch 600 | Train Loss 0.610188 | Val Loss 0.864848
# Early stopping at epoch 609
# Theta | train1 -> R² = 0.7515, MSE = 5.6729e-02
# Theta | train2 -> R² = 0.7879, MSE = 4.8430e-02
# Theta | test1 -> R² = 0.4649, MSE = 1.2293e-01
# Theta | test2 -> R² = 0.5377, MSE = 1.0964e-01
# Theta | test3 -> R² = -1.5484, MSE = 8.3777e-01
# Theta | val -> R² = -3.1878, MSE = 1.3706e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.038299 | Val Loss 0.818264
# Epoch 100 | Train Loss 0.797492 | Val Loss 0.639765
# Epoch 200 | Train Loss 0.774589 | Val Loss 0.590142
# Epoch 300 | Train Loss 0.751701 | Val Loss 0.558085
# Epoch 400 | Train Loss 0.727753 | Val Loss 0.522363
# Epoch 500 | Train Loss 0.663815 | Val Loss 0.608034
# Epoch 600 | Train Loss 0.630088 | Val Loss 0.788304
# Epoch 700 | Train Loss 0.610189 | Val Loss 0.839149
# Early stopping at epoch 714
# Theta | train1 -> R² = 0.7276, MSE = 6.2187e-02
# Theta | train2 -> R² = 0.7852, MSE = 4.9030e-02
# Theta | test1 -> R² = 0.4555, MSE = 1.2509e-01
# Theta | test2 -> R² = 0.5871, MSE = 9.7925e-02
# Theta | test3 -> R² = -1.2321, MSE = 7.3380e-01
# Theta | val -> R² = -3.3821, MSE = 1.4342e+00
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.064828 | Val Loss 0.801392
# Epoch 100 | Train Loss 0.858363 | Val Loss 0.615499
# Epoch 200 | Train Loss 0.772298 | Val Loss 0.544152
# Epoch 300 | Train Loss 0.730281 | Val Loss 0.516397
# Epoch 400 | Train Loss 0.714603 | Val Loss 0.498806
# Epoch 500 | Train Loss 0.687586 | Val Loss 0.538312
# Epoch 600 | Train Loss 0.635272 | Val Loss 0.774883
# Early stopping at epoch 697
# Theta | train1 -> R² = 0.8985, MSE = 2.3171e-02
# Theta | train2 -> R² = 0.6724, MSE = 7.4795e-02
# Theta | test1 -> R² = 0.7492, MSE = 5.7617e-02
# Theta | test2 -> R² = 0.7050, MSE = 6.9970e-02
# Theta | test3 -> R² = 0.5494, MSE = 1.4813e-01
# Theta | val -> R² = -0.7021, MSE = 5.5705e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.063692 | Val Loss 0.816915
# Epoch 100 | Train Loss 0.851535 | Val Loss 0.600715
# Epoch 200 | Train Loss 0.764294 | Val Loss 0.540286
# Epoch 300 | Train Loss 0.721090 | Val Loss 0.517632
# Epoch 400 | Train Loss 0.709532 | Val Loss 0.498128
# Epoch 500 | Train Loss 0.691573 | Val Loss 0.501647
# Epoch 600 | Train Loss 0.658913 | Val Loss 0.616517
# Epoch 700 | Train Loss 0.632195 | Val Loss 0.778542
# Early stopping at epoch 723
# Theta | train1 -> R² = 0.8697, MSE = 2.9751e-02
# Theta | train2 -> R² = 0.7483, MSE = 5.7471e-02
# Theta | test1 -> R² = 0.8273, MSE = 3.9680e-02
# Theta | test2 -> R² = 0.7869, MSE = 5.0532e-02
# Theta | test3 -> R² = 0.7265, MSE = 8.9927e-02
# Theta | val -> R² = -1.0237, MSE = 6.6233e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.065421 | Val Loss 0.815375
# Epoch 100 | Train Loss 0.862455 | Val Loss 0.617130
# Epoch 200 | Train Loss 0.791146 | Val Loss 0.555952
# Epoch 300 | Train Loss 0.736392 | Val Loss 0.524686
# Epoch 400 | Train Loss 0.719160 | Val Loss 0.507903
# Epoch 500 | Train Loss 0.667587 | Val Loss 0.596233
# Epoch 600 | Train Loss 0.627885 | Val Loss 0.791434
# Epoch 700 | Train Loss 0.603353 | Val Loss 0.901068
# Early stopping at epoch 710
# Theta | train1 -> R² = 0.8054, MSE = 4.4417e-02
# Theta | train2 -> R² = 0.7597, MSE = 5.4865e-02
# Theta | test1 -> R² = 0.7004, MSE = 6.8830e-02
# Theta | test2 -> R² = 0.7472, MSE = 5.9947e-02
# Theta | test3 -> R² = 0.1415, MSE = 2.8222e-01
# Theta | val -> R² = -0.4064, MSE = 4.6029e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.065177 | Val Loss 0.802243
# Epoch 100 | Train Loss 0.856914 | Val Loss 0.602751
# Epoch 200 | Train Loss 0.766750 | Val Loss 0.535847
# Epoch 300 | Train Loss 0.721367 | Val Loss 0.507907
# Epoch 400 | Train Loss 0.710201 | Val Loss 0.499231
# Epoch 500 | Train Loss 0.690171 | Val Loss 0.507543
# Epoch 600 | Train Loss 0.642612 | Val Loss 0.749939
# Epoch 700 | Train Loss 0.619646 | Val Loss 0.835416
# Early stopping at epoch 745
# Theta | train1 -> R² = 0.7917, MSE = 4.7557e-02
# Theta | train2 -> R² = 0.7286, MSE = 6.1959e-02
# Theta | test1 -> R² = 0.7020, MSE = 6.8452e-02
# Theta | test2 -> R² = 0.7865, MSE = 5.0627e-02
# Theta | test3 -> R² = 0.5127, MSE = 1.6020e-01
# Theta | val -> R² = 0.1535, MSE = 2.7705e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.066433 | Val Loss 0.819403
# Epoch 100 | Train Loss 0.847934 | Val Loss 0.596102
# Epoch 200 | Train Loss 0.754982 | Val Loss 0.534324
# Epoch 300 | Train Loss 0.724167 | Val Loss 0.515094
# Epoch 400 | Train Loss 0.711521 | Val Loss 0.506249
# Epoch 500 | Train Loss 0.691940 | Val Loss 0.507472
# Epoch 600 | Train Loss 0.639896 | Val Loss 0.746447
# Epoch 700 | Train Loss 0.609666 | Val Loss 0.956573
# Early stopping at epoch 751
# Theta | train1 -> R² = 0.8067, MSE = 4.4128e-02
# Theta | train2 -> R² = 0.7396, MSE = 5.9449e-02
# Theta | test1 -> R² = 0.7698, MSE = 5.2885e-02
# Theta | test2 -> R² = 0.7827, MSE = 5.1524e-02
# Theta | test3 -> R² = 0.6215, MSE = 1.2444e-01
# Theta | val -> R² = 0.4429, MSE = 1.8234e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.058858 | Val Loss 0.793463
# Epoch 100 | Train Loss 0.862322 | Val Loss 0.625536
# Epoch 200 | Train Loss 0.778710 | Val Loss 0.558223
# Epoch 300 | Train Loss 0.734524 | Val Loss 0.532500
# Epoch 400 | Train Loss 0.719671 | Val Loss 0.511700
# Epoch 500 | Train Loss 0.708234 | Val Loss 0.502191
# Epoch 600 | Train Loss 0.689618 | Val Loss 0.505407
# Epoch 700 | Train Loss 0.660156 | Val Loss 0.638267
# Epoch 800 | Train Loss 0.635617 | Val Loss 0.892635
# Early stopping at epoch 850
# Theta | train1 -> R² = 0.8849, MSE = 2.6277e-02
# Theta | train2 -> R² = 0.7460, MSE = 5.7990e-02
# Theta | test1 -> R² = 0.7973, MSE = 4.6575e-02
# Theta | test2 -> R² = 0.8127, MSE = 4.4427e-02
# Theta | test3 -> R² = 0.6918, MSE = 1.0131e-01
# Theta | val -> R² = -0.1180, MSE = 3.6589e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.064464 | Val Loss 0.814678
# Epoch 100 | Train Loss 0.861518 | Val Loss 0.615642
# Epoch 200 | Train Loss 0.795339 | Val Loss 0.554132
# Epoch 300 | Train Loss 0.730668 | Val Loss 0.527610
# Epoch 400 | Train Loss 0.714985 | Val Loss 0.503080
# Epoch 500 | Train Loss 0.682033 | Val Loss 0.514025
# Epoch 600 | Train Loss 0.638641 | Val Loss 0.732554
# Epoch 700 | Train Loss 0.621062 | Val Loss 0.824874
# Early stopping at epoch 720
# Theta | train1 -> R² = 0.8561, MSE = 3.2836e-02
# Theta | train2 -> R² = 0.7349, MSE = 6.0513e-02
# Theta | test1 -> R² = 0.7655, MSE = 5.3859e-02
# Theta | test2 -> R² = 0.7932, MSE = 4.9035e-02
# Theta | test3 -> R² = 0.7000, MSE = 9.8616e-02
# Theta | val -> R² = -1.4275, MSE = 7.9448e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.059897 | Val Loss 0.806902
# Epoch 100 | Train Loss 0.863944 | Val Loss 0.629905
# Epoch 200 | Train Loss 0.793888 | Val Loss 0.550544
# Epoch 300 | Train Loss 0.728823 | Val Loss 0.527792
# Epoch 400 | Train Loss 0.716308 | Val Loss 0.510071
# Epoch 500 | Train Loss 0.705154 | Val Loss 0.496980
# Epoch 600 | Train Loss 0.671199 | Val Loss 0.536943
# Epoch 700 | Train Loss 0.631435 | Val Loss 0.761563
# Epoch 800 | Train Loss 0.616634 | Val Loss 0.813617
# Early stopping at epoch 845
# Theta | train1 -> R² = 0.8616, MSE = 3.1600e-02
# Theta | train2 -> R² = 0.7847, MSE = 4.9148e-02
# Theta | test1 -> R² = 0.8568, MSE = 3.2890e-02
# Theta | test2 -> R² = 0.7918, MSE = 4.9369e-02
# Theta | test3 -> R² = 0.3864, MSE = 2.0173e-01
# Theta | val -> R² = -0.4334, MSE = 4.6913e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.076513 | Val Loss 0.826671
# Epoch 100 | Train Loss 0.849080 | Val Loss 0.642280
# Epoch 200 | Train Loss 0.774779 | Val Loss 0.576091
# Epoch 300 | Train Loss 0.733340 | Val Loss 0.529089
# Epoch 400 | Train Loss 0.680978 | Val Loss 0.542251
# Epoch 500 | Train Loss 0.630731 | Val Loss 0.708600
# Epoch 600 | Train Loss 0.603339 | Val Loss 0.775519
# Early stopping at epoch 633
# Theta | train1 -> R² = 0.8086, MSE = 4.3693e-02
# Theta | train2 -> R² = 0.7066, MSE = 6.6989e-02
# Theta | test1 -> R² = 0.6329, MSE = 8.4323e-02
# Theta | test2 -> R² = 0.6400, MSE = 8.5377e-02
# Theta | test3 -> R² = -2.3795, MSE = 1.1110e+00
# Theta | val -> R² = -6.3928, MSE = 2.4195e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.067240 | Val Loss 0.820070
# Epoch 100 | Train Loss 0.859358 | Val Loss 0.596757
# Epoch 200 | Train Loss 0.788163 | Val Loss 0.541576
# Epoch 300 | Train Loss 0.725948 | Val Loss 0.512503
# Epoch 400 | Train Loss 0.703872 | Val Loss 0.497368
# Epoch 500 | Train Loss 0.661219 | Val Loss 0.579782
# Epoch 600 | Train Loss 0.635121 | Val Loss 0.720524
# Early stopping at epoch 681
# Theta | train1 -> R² = 0.8179, MSE = 4.1564e-02
# Theta | train2 -> R² = 0.7256, MSE = 6.2635e-02
# Theta | test1 -> R² = 0.7026, MSE = 6.8315e-02
# Theta | test2 -> R² = 0.7669, MSE = 5.5288e-02
# Theta | test3 -> R² = 0.4592, MSE = 1.7780e-01
# Theta | val -> R² = -1.5041, MSE = 8.1955e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.060901 | Val Loss 0.805785
# Epoch 100 | Train Loss 0.865543 | Val Loss 0.625582
# Epoch 200 | Train Loss 0.806630 | Val Loss 0.554774
# Epoch 300 | Train Loss 0.731416 | Val Loss 0.529191
# Epoch 400 | Train Loss 0.717579 | Val Loss 0.510247
# Epoch 500 | Train Loss 0.707002 | Val Loss 0.499820
# Epoch 600 | Train Loss 0.665517 | Val Loss 0.566299
# Epoch 700 | Train Loss 0.632268 | Val Loss 0.790151
# Epoch 800 | Train Loss 0.621582 | Val Loss 0.807822
# Early stopping at epoch 840
# Theta | train1 -> R² = 0.8398, MSE = 3.6560e-02
# Theta | train2 -> R² = 0.7383, MSE = 5.9746e-02
# Theta | test1 -> R² = 0.8296, MSE = 3.9143e-02
# Theta | test2 -> R² = 0.6804, MSE = 7.5800e-02
# Theta | test3 -> R² = 0.3277, MSE = 2.2102e-01
# Theta | val -> R² = -0.1210, MSE = 3.6689e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.068490 | Val Loss 0.812621
# Epoch 100 | Train Loss 0.857997 | Val Loss 0.607974
# Epoch 200 | Train Loss 0.781174 | Val Loss 0.545799
# Epoch 300 | Train Loss 0.728759 | Val Loss 0.523056
# Epoch 400 | Train Loss 0.715019 | Val Loss 0.506362
# Epoch 500 | Train Loss 0.697972 | Val Loss 0.501872
# Epoch 600 | Train Loss 0.652550 | Val Loss 0.618634
# Epoch 700 | Train Loss 0.621368 | Val Loss 0.852085
# Early stopping at epoch 758
# Theta | train1 -> R² = 0.7936, MSE = 4.7110e-02
# Theta | train2 -> R² = 0.7497, MSE = 5.7143e-02
# Theta | test1 -> R² = 0.6535, MSE = 7.9594e-02
# Theta | test2 -> R² = 0.7996, MSE = 4.7519e-02
# Theta | test3 -> R² = 0.3752, MSE = 2.0540e-01
# Theta | val -> R² = -0.4290, MSE = 4.6767e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.059287 | Val Loss 0.814036
# Epoch 100 | Train Loss 0.850515 | Val Loss 0.627595
# Epoch 200 | Train Loss 0.764590 | Val Loss 0.558766
# Epoch 300 | Train Loss 0.733882 | Val Loss 0.524304
# Epoch 400 | Train Loss 0.712821 | Val Loss 0.506153
# Epoch 500 | Train Loss 0.667148 | Val Loss 0.594802
# Epoch 600 | Train Loss 0.637608 | Val Loss 0.740709
# Early stopping at epoch 688
# Theta | train1 -> R² = 0.8594, MSE = 3.2089e-02
# Theta | train2 -> R² = 0.7221, MSE = 6.3446e-02
# Theta | test1 -> R² = 0.6754, MSE = 7.4576e-02
# Theta | test2 -> R² = 0.8042, MSE = 4.6432e-02
# Theta | test3 -> R² = 0.6356, MSE = 1.1979e-01
# Theta | val -> R² = -1.1996, MSE = 7.1987e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.079777 | Val Loss 0.820306
# Epoch 100 | Train Loss 0.865320 | Val Loss 0.616041
# Epoch 200 | Train Loss 0.810499 | Val Loss 0.570986
# Epoch 300 | Train Loss 0.743843 | Val Loss 0.555893
# Epoch 400 | Train Loss 0.725852 | Val Loss 0.523612
# Epoch 500 | Train Loss 0.713418 | Val Loss 0.504599
# Epoch 600 | Train Loss 0.698723 | Val Loss 0.495704
# Epoch 700 | Train Loss 0.647744 | Val Loss 0.685102
# Epoch 800 | Train Loss 0.616910 | Val Loss 0.844626
# Early stopping at epoch 867
# Theta | train1 -> R² = 0.8787, MSE = 2.7682e-02
# Theta | train2 -> R² = 0.7280, MSE = 6.2106e-02
# Theta | test1 -> R² = 0.8441, MSE = 3.5823e-02
# Theta | test2 -> R² = 0.6061, MSE = 9.3412e-02
# Theta | test3 -> R² = 0.0505, MSE = 3.1214e-01
# Theta | val -> R² = -1.3485, MSE = 7.6863e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.073226 | Val Loss 0.816772
# Epoch 100 | Train Loss 0.865844 | Val Loss 0.620539
# Epoch 200 | Train Loss 0.814303 | Val Loss 0.566487
# Epoch 300 | Train Loss 0.732740 | Val Loss 0.537121
# Epoch 400 | Train Loss 0.718337 | Val Loss 0.511608
# Epoch 500 | Train Loss 0.709018 | Val Loss 0.496434
# Epoch 600 | Train Loss 0.700590 | Val Loss 0.480102
# Epoch 700 | Train Loss 0.680867 | Val Loss 0.507400
# Epoch 800 | Train Loss 0.630403 | Val Loss 0.693902
# Epoch 900 | Train Loss 0.596773 | Val Loss 0.989741
# Early stopping at epoch 914
# Theta | train1 -> R² = 0.8196, MSE = 4.1169e-02
# Theta | train2 -> R² = 0.7725, MSE = 5.1928e-02
# Theta | test1 -> R² = 0.7793, MSE = 5.0707e-02
# Theta | test2 -> R² = 0.7410, MSE = 6.1436e-02
# Theta | test3 -> R² = -0.5487, MSE = 5.0914e-01
# Theta | val -> R² = -1.4209, MSE = 7.9230e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.016401 | Val Loss 0.810613
# Epoch 100 | Train Loss 0.724177 | Val Loss 0.703070
# Epoch 200 | Train Loss 0.702288 | Val Loss 0.627683
# Epoch 300 | Train Loss 0.671344 | Val Loss 0.590104
# Epoch 400 | Train Loss 0.581296 | Val Loss 0.835641
# Epoch 500 | Train Loss 0.558821 | Val Loss 0.928928
# Early stopping at epoch 575
# Theta | train1 -> R² = 0.6206, MSE = 8.6608e-02
# Theta | train2 -> R² = 0.8276, MSE = 3.9367e-02
# Theta | test1 -> R² = 0.2711, MSE = 1.6744e-01
# Theta | test2 -> R² = 0.3685, MSE = 1.4977e-01
# Theta | test3 -> R² = -4.5260, MSE = 1.8167e+00
# Theta | val -> R² = -6.0342, MSE = 2.3021e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.006316 | Val Loss 0.821963
# Epoch 100 | Train Loss 0.723984 | Val Loss 0.698443
# Epoch 200 | Train Loss 0.700051 | Val Loss 0.639468
# Epoch 300 | Train Loss 0.649880 | Val Loss 0.640090
# Early stopping at epoch 344
# Theta | train1 -> R² = 0.8196, MSE = 4.1177e-02
# Theta | train2 -> R² = 0.4530, MSE = 1.2489e-01
# Theta | test1 -> R² = 0.8581, MSE = 3.2593e-02
# Theta | test2 -> R² = 0.7580, MSE = 5.7382e-02
# Theta | test3 -> R² = -0.7616, MSE = 5.7912e-01
# Theta | val -> R² = -11.8114, MSE = 4.1929e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.010249 | Val Loss 0.813429
# Epoch 100 | Train Loss 0.724283 | Val Loss 0.691687
# Epoch 200 | Train Loss 0.706121 | Val Loss 0.644552
# Epoch 300 | Train Loss 0.674098 | Val Loss 0.622582
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.7997, MSE = 4.5732e-02
# Theta | train2 -> R² = 0.4140, MSE = 1.3379e-01
# Theta | test1 -> R² = 0.8254, MSE = 4.0103e-02
# Theta | test2 -> R² = 0.7257, MSE = 6.5051e-02
# Theta | test3 -> R² = -0.8633, MSE = 6.1257e-01
# Theta | val -> R² = -11.5679, MSE = 4.1132e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.011681 | Val Loss 0.819420
# Epoch 100 | Train Loss 0.720970 | Val Loss 0.686495
# Epoch 200 | Train Loss 0.698304 | Val Loss 0.628768
# Epoch 300 | Train Loss 0.663122 | Val Loss 0.673956
# Early stopping at epoch 352
# Theta | train1 -> R² = 0.7726, MSE = 5.1910e-02
# Theta | train2 -> R² = 0.4584, MSE = 1.2366e-01
# Theta | test1 -> R² = 0.8069, MSE = 4.4347e-02
# Theta | test2 -> R² = 0.7557, MSE = 5.7937e-02
# Theta | test3 -> R² = -1.1809, MSE = 7.1695e-01
# Theta | val -> R² = -12.0889, MSE = 4.2837e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.012808 | Val Loss 0.814989
# Epoch 100 | Train Loss 0.724552 | Val Loss 0.707550
# Epoch 200 | Train Loss 0.696273 | Val Loss 0.657617
# Epoch 300 | Train Loss 0.640820 | Val Loss 0.704324
# Early stopping at epoch 347
# Theta | train1 -> R² = 0.7923, MSE = 4.7407e-02
# Theta | train2 -> R² = 0.3865, MSE = 1.4007e-01
# Theta | test1 -> R² = 0.8399, MSE = 3.6777e-02
# Theta | test2 -> R² = 0.6997, MSE = 7.1230e-02
# Theta | test3 -> R² = -0.8328, MSE = 6.0253e-01
# Theta | val -> R² = -11.5207, MSE = 4.0978e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.014894 | Val Loss 0.824230
# Epoch 100 | Train Loss 0.725810 | Val Loss 0.704842
# Epoch 200 | Train Loss 0.706666 | Val Loss 0.630888
# Epoch 300 | Train Loss 0.677070 | Val Loss 0.610682
# Early stopping at epoch 345
# Theta | train1 -> R² = 0.8112, MSE = 4.3104e-02
# Theta | train2 -> R² = 0.2952, MSE = 1.6090e-01
# Theta | test1 -> R² = 0.8518, MSE = 3.4035e-02
# Theta | test2 -> R² = 0.6295, MSE = 8.7857e-02
# Theta | test3 -> R² = -0.4496, MSE = 4.7656e-01
# Theta | val -> R² = -10.3017, MSE = 3.6988e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.000148 | Val Loss 0.800025
# Epoch 100 | Train Loss 0.725027 | Val Loss 0.712109
# Epoch 200 | Train Loss 0.699908 | Val Loss 0.672293
# Epoch 300 | Train Loss 0.646785 | Val Loss 0.686815
# Early stopping at epoch 343
# Theta | train1 -> R² = 0.8144, MSE = 4.2371e-02
# Theta | train2 -> R² = 0.4522, MSE = 1.2507e-01
# Theta | test1 -> R² = 0.8629, MSE = 3.1495e-02
# Theta | test2 -> R² = 0.7559, MSE = 5.7895e-02
# Theta | test3 -> R² = -0.7897, MSE = 5.8837e-01
# Theta | val -> R² = -11.8367, MSE = 4.2012e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.000453 | Val Loss 0.809530
# Epoch 100 | Train Loss 0.726341 | Val Loss 0.710986
# Epoch 200 | Train Loss 0.705786 | Val Loss 0.646343
# Epoch 300 | Train Loss 0.663616 | Val Loss 0.638560
# Early stopping at epoch 342
# Theta | train1 -> R² = 0.7964, MSE = 4.6475e-02
# Theta | train2 -> R² = 0.2964, MSE = 1.6062e-01
# Theta | test1 -> R² = 0.7867, MSE = 4.8991e-02
# Theta | test2 -> R² = 0.6224, MSE = 8.9546e-02
# Theta | test3 -> R² = -0.7863, MSE = 5.8724e-01
# Theta | val -> R² = -11.8853, MSE = 4.2171e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.018850 | Val Loss 0.815274
# Epoch 100 | Train Loss 0.721186 | Val Loss 0.693500
# Epoch 200 | Train Loss 0.697264 | Val Loss 0.638793
# Epoch 300 | Train Loss 0.658954 | Val Loss 0.647397
# Early stopping at epoch 354
# Theta | train1 -> R² = 0.7794, MSE = 5.0354e-02
# Theta | train2 -> R² = 0.4875, MSE = 1.1701e-01
# Theta | test1 -> R² = 0.8546, MSE = 3.3393e-02
# Theta | test2 -> R² = 0.7835, MSE = 5.1357e-02
# Theta | test3 -> R² = -1.0504, MSE = 6.7407e-01
# Theta | val -> R² = -11.5165, MSE = 4.0964e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.001310 | Val Loss 0.813899
# Epoch 100 | Train Loss 0.719183 | Val Loss 0.677149
# Epoch 200 | Train Loss 0.699972 | Val Loss 0.611289
# Epoch 300 | Train Loss 0.684905 | Val Loss 0.586453
# Epoch 400 | Train Loss 0.596746 | Val Loss 0.730425
# Epoch 500 | Train Loss 0.564352 | Val Loss 0.880970
# Epoch 600 | Train Loss 0.551737 | Val Loss 0.954617
# Early stopping at epoch 604
# Theta | train1 -> R² = 0.6165, MSE = 8.7542e-02
# Theta | train2 -> R² = 0.8394, MSE = 3.6673e-02
# Theta | test1 -> R² = 0.2214, MSE = 1.7886e-01
# Theta | test2 -> R² = 0.5515, MSE = 1.0636e-01
# Theta | test3 -> R² = -4.5866, MSE = 1.8366e+00
# Theta | val -> R² = -8.5387, MSE = 3.1218e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.012358 | Val Loss 0.809889
# Epoch 100 | Train Loss 0.726278 | Val Loss 0.711644
# Epoch 200 | Train Loss 0.700445 | Val Loss 0.660038
# Epoch 300 | Train Loss 0.648216 | Val Loss 0.648295
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.8091, MSE = 4.3580e-02
# Theta | train2 -> R² = 0.3300, MSE = 1.5296e-01
# Theta | test1 -> R² = 0.8575, MSE = 3.2724e-02
# Theta | test2 -> R² = 0.6541, MSE = 8.2043e-02
# Theta | test3 -> R² = -0.5726, MSE = 5.1699e-01
# Theta | val -> R² = -10.9231, MSE = 3.9022e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.011463 | Val Loss 0.824204
# Epoch 100 | Train Loss 0.721453 | Val Loss 0.686470
# Epoch 200 | Train Loss 0.697733 | Val Loss 0.611189
# Epoch 300 | Train Loss 0.664668 | Val Loss 0.608804
# Epoch 400 | Train Loss 0.590261 | Val Loss 0.806100
# Epoch 500 | Train Loss 0.566680 | Val Loss 0.897790
# Early stopping at epoch 550
# Theta | train1 -> R² = 0.6442, MSE = 8.1217e-02
# Theta | train2 -> R² = 0.8432, MSE = 3.5808e-02
# Theta | test1 -> R² = 0.1617, MSE = 1.9258e-01
# Theta | test2 -> R² = 0.5682, MSE = 1.0240e-01
# Theta | test3 -> R² = -4.0178, MSE = 1.6496e+00
# Theta | val -> R² = -9.0887, MSE = 3.3018e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.007064 | Val Loss 0.819419
# Epoch 100 | Train Loss 0.722820 | Val Loss 0.679701
# Epoch 200 | Train Loss 0.704172 | Val Loss 0.620655
# Epoch 300 | Train Loss 0.672188 | Val Loss 0.627152
# Early stopping at epoch 346
# Theta | train1 -> R² = 0.8352, MSE = 3.7614e-02
# Theta | train2 -> R² = 0.3754, MSE = 1.4260e-01
# Theta | test1 -> R² = 0.8304, MSE = 3.8961e-02
# Theta | test2 -> R² = 0.6987, MSE = 7.1446e-02
# Theta | test3 -> R² = -0.4766, MSE = 4.8544e-01
# Theta | val -> R² = -11.0078, MSE = 3.9299e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.001655 | Val Loss 0.807300
# Epoch 100 | Train Loss 0.720880 | Val Loss 0.685648
# Epoch 200 | Train Loss 0.696253 | Val Loss 0.638783
# Epoch 300 | Train Loss 0.645239 | Val Loss 0.674643
# Early stopping at epoch 345
# Theta | train1 -> R² = 0.7862, MSE = 4.8810e-02
# Theta | train2 -> R² = 0.4624, MSE = 1.2274e-01
# Theta | test1 -> R² = 0.8647, MSE = 3.1081e-02
# Theta | test2 -> R² = 0.7666, MSE = 5.5344e-02
# Theta | test3 -> R² = -0.8263, MSE = 6.0040e-01
# Theta | val -> R² = -10.8040, MSE = 3.8632e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.017506 | Val Loss 0.812473
# Epoch 100 | Train Loss 0.724522 | Val Loss 0.705567
# Epoch 200 | Train Loss 0.702009 | Val Loss 0.667411
# Epoch 300 | Train Loss 0.654856 | Val Loss 0.671874
# Early stopping at epoch 349
# Theta | train1 -> R² = 0.7853, MSE = 4.9020e-02
# Theta | train2 -> R² = 0.4330, MSE = 1.2945e-01
# Theta | test1 -> R² = 0.8100, MSE = 4.3654e-02
# Theta | test2 -> R² = 0.7341, MSE = 6.3068e-02
# Theta | test3 -> R² = -1.1236, MSE = 6.9814e-01
# Theta | val -> R² = -12.6652, MSE = 4.4724e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.082081 | Val Loss 0.814753
# Epoch 100 | Train Loss 0.796961 | Val Loss 0.705754
# Epoch 200 | Train Loss 0.754025 | Val Loss 0.561652
# Epoch 300 | Train Loss 0.729175 | Val Loss 0.519434
# Epoch 400 | Train Loss 0.656479 | Val Loss 0.638791
# Epoch 500 | Train Loss 0.626004 | Val Loss 0.786548
# Epoch 600 | Train Loss 0.609704 | Val Loss 0.805794
# Early stopping at epoch 604
# Theta | train1 -> R² = 0.8873, MSE = 2.5717e-02
# Theta | train2 -> R² = 0.6842, MSE = 7.2099e-02
# Theta | test1 -> R² = 0.6595, MSE = 7.8223e-02
# Theta | test2 -> R² = 0.3274, MSE = 1.5952e-01
# Theta | test3 -> R² = -1.3155, MSE = 7.6120e-01
# Theta | val -> R² = -3.7475, MSE = 1.5538e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.047674 | Val Loss 0.785596
# Epoch 100 | Train Loss 0.796072 | Val Loss 0.689497
# Epoch 200 | Train Loss 0.748286 | Val Loss 0.555060
# Epoch 300 | Train Loss 0.730215 | Val Loss 0.523555
# Epoch 400 | Train Loss 0.657907 | Val Loss 0.649670
# Epoch 500 | Train Loss 0.624580 | Val Loss 0.808982
# Epoch 600 | Train Loss 0.607001 | Val Loss 0.887760
# Early stopping at epoch 621
# Theta | train1 -> R² = 0.7708, MSE = 5.2326e-02
# Theta | train2 -> R² = 0.7247, MSE = 6.2855e-02
# Theta | test1 -> R² = 0.5315, MSE = 1.0762e-01
# Theta | test2 -> R² = 0.3776, MSE = 1.4762e-01
# Theta | test3 -> R² = -3.1379, MSE = 1.3603e+00
# Theta | val -> R² = -4.3706, MSE = 1.7577e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.031834 | Val Loss 0.799132
# Epoch 100 | Train Loss 0.789303 | Val Loss 0.662246
# Epoch 200 | Train Loss 0.740468 | Val Loss 0.539021
# Epoch 300 | Train Loss 0.702726 | Val Loss 0.529633
# Epoch 400 | Train Loss 0.632721 | Val Loss 0.760469
# Epoch 500 | Train Loss 0.612204 | Val Loss 0.847577
# Early stopping at epoch 557
# Theta | train1 -> R² = 0.6935, MSE = 6.9959e-02
# Theta | train2 -> R² = 0.7963, MSE = 4.6504e-02
# Theta | test1 -> R² = 0.3786, MSE = 1.4275e-01
# Theta | test2 -> R² = 0.5571, MSE = 1.0504e-01
# Theta | test3 -> R² = -3.2508, MSE = 1.3974e+00
# Theta | val -> R² = -5.2894, MSE = 2.0584e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.024789 | Val Loss 0.770664
# Epoch 100 | Train Loss 0.789785 | Val Loss 0.683771
# Epoch 200 | Train Loss 0.740991 | Val Loss 0.544843
# Epoch 300 | Train Loss 0.683390 | Val Loss 0.567570
# Epoch 400 | Train Loss 0.641046 | Val Loss 0.698327
# Epoch 500 | Train Loss 0.615057 | Val Loss 0.801568
# Early stopping at epoch 558
# Theta | train1 -> R² = 0.7003, MSE = 6.8417e-02
# Theta | train2 -> R² = 0.7920, MSE = 4.7492e-02
# Theta | test1 -> R² = 0.4065, MSE = 1.3634e-01
# Theta | test2 -> R² = 0.5378, MSE = 1.0962e-01
# Theta | test3 -> R² = -2.6921, MSE = 1.2138e+00
# Theta | val -> R² = -5.2005, MSE = 2.0293e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.065846 | Val Loss 0.816227
# Epoch 100 | Train Loss 0.783600 | Val Loss 0.706740
# Epoch 200 | Train Loss 0.740295 | Val Loss 0.553772
# Epoch 300 | Train Loss 0.690011 | Val Loss 0.536304
# Epoch 400 | Train Loss 0.633742 | Val Loss 0.700081
# Epoch 500 | Train Loss 0.610504 | Val Loss 0.809178
# Early stopping at epoch 573
# Theta | train1 -> R² = 0.7109, MSE = 6.5994e-02
# Theta | train2 -> R² = 0.7589, MSE = 5.5033e-02
# Theta | test1 -> R² = 0.4134, MSE = 1.3474e-01
# Theta | test2 -> R² = 0.5943, MSE = 9.6207e-02
# Theta | test3 -> R² = -1.3215, MSE = 7.6320e-01
# Theta | val -> R² = -4.4098, MSE = 1.7705e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.036858 | Val Loss 0.787314
# Epoch 100 | Train Loss 0.790680 | Val Loss 0.676680
# Epoch 200 | Train Loss 0.741373 | Val Loss 0.548353
# Epoch 300 | Train Loss 0.684414 | Val Loss 0.544891
# Epoch 400 | Train Loss 0.630375 | Val Loss 0.757190
# Epoch 500 | Train Loss 0.610646 | Val Loss 0.829218
# Early stopping at epoch 572
# Theta | train1 -> R² = 0.6697, MSE = 7.5403e-02
# Theta | train2 -> R² = 0.7787, MSE = 5.0517e-02
# Theta | test1 -> R² = 0.4230, MSE = 1.3255e-01
# Theta | test2 -> R² = 0.5990, MSE = 9.5095e-02
# Theta | test3 -> R² = -1.8700, MSE = 9.4351e-01
# Theta | val -> R² = -4.1733, MSE = 1.6931e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.047169 | Val Loss 0.807740
# Epoch 100 | Train Loss 0.792244 | Val Loss 0.675956
# Epoch 200 | Train Loss 0.741874 | Val Loss 0.545772
# Epoch 300 | Train Loss 0.665716 | Val Loss 0.607938
# Epoch 400 | Train Loss 0.634622 | Val Loss 0.731588
# Epoch 500 | Train Loss 0.610515 | Val Loss 0.838595
# Early stopping at epoch 541
# Theta | train1 -> R² = 0.6902, MSE = 7.0720e-02
# Theta | train2 -> R² = 0.7753, MSE = 5.1298e-02
# Theta | test1 -> R² = 0.4165, MSE = 1.3405e-01
# Theta | test2 -> R² = 0.4922, MSE = 1.2044e-01
# Theta | test3 -> R² = -2.8085, MSE = 1.2520e+00
# Theta | val -> R² = -4.7263, MSE = 1.8741e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.031101 | Val Loss 0.793070
# Epoch 100 | Train Loss 0.784144 | Val Loss 0.687139
# Epoch 200 | Train Loss 0.740217 | Val Loss 0.549217
# Epoch 300 | Train Loss 0.661450 | Val Loss 0.645570
# Epoch 400 | Train Loss 0.624982 | Val Loss 0.790806
# Epoch 500 | Train Loss 0.605897 | Val Loss 0.850780
# Early stopping at epoch 552
# Theta | train1 -> R² = 0.6154, MSE = 8.7792e-02
# Theta | train2 -> R² = 0.7508, MSE = 5.6894e-02
# Theta | test1 -> R² = 0.2783, MSE = 1.6579e-01
# Theta | test2 -> R² = 0.6058, MSE = 9.3479e-02
# Theta | test3 -> R² = -4.2230, MSE = 1.7171e+00
# Theta | val -> R² = -7.3762, MSE = 2.7413e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.036853 | Val Loss 0.763041
# Epoch 100 | Train Loss 0.797391 | Val Loss 0.708410
# Epoch 200 | Train Loss 0.749014 | Val Loss 0.559243
# Epoch 300 | Train Loss 0.728642 | Val Loss 0.522175
# Epoch 400 | Train Loss 0.636718 | Val Loss 0.754206
# Epoch 500 | Train Loss 0.609765 | Val Loss 0.889421
# Early stopping at epoch 589
# Theta | train1 -> R² = 0.8198, MSE = 4.1142e-02
# Theta | train2 -> R² = 0.6417, MSE = 8.1807e-02
# Theta | test1 -> R² = 0.5359, MSE = 1.0660e-01
# Theta | test2 -> R² = 0.1938, MSE = 1.9120e-01
# Theta | test3 -> R² = -3.1908, MSE = 1.3777e+00
# Theta | val -> R² = -4.3231, MSE = 1.7422e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.085071 | Val Loss 0.811008
# Epoch 100 | Train Loss 0.793236 | Val Loss 0.711278
# Epoch 200 | Train Loss 0.747953 | Val Loss 0.562945
# Epoch 300 | Train Loss 0.699778 | Val Loss 0.536835
# Epoch 400 | Train Loss 0.638531 | Val Loss 0.739197
# Epoch 500 | Train Loss 0.616395 | Val Loss 0.811548
# Early stopping at epoch 577
# Theta | train1 -> R² = 0.7266, MSE = 6.2412e-02
# Theta | train2 -> R² = 0.7880, MSE = 4.8406e-02
# Theta | test1 -> R² = 0.4863, MSE = 1.1801e-01
# Theta | test2 -> R² = 0.5730, MSE = 1.0127e-01
# Theta | test3 -> R² = -2.1175, MSE = 1.0249e+00
# Theta | val -> R² = -2.8417, MSE = 1.2573e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.044564 | Val Loss 0.796797
# Epoch 100 | Train Loss 0.785239 | Val Loss 0.667529
# Epoch 200 | Train Loss 0.742045 | Val Loss 0.544201
# Epoch 300 | Train Loss 0.697314 | Val Loss 0.536566
# Epoch 400 | Train Loss 0.640271 | Val Loss 0.708928
# Epoch 500 | Train Loss 0.616132 | Val Loss 0.807646
# Early stopping at epoch 575
# Theta | train1 -> R² = 0.7206, MSE = 6.3780e-02
# Theta | train2 -> R² = 0.7778, MSE = 5.0726e-02
# Theta | test1 -> R² = 0.4058, MSE = 1.3649e-01
# Theta | test2 -> R² = 0.5831, MSE = 9.8867e-02
# Theta | test3 -> R² = -2.0250, MSE = 9.9446e-01
# Theta | val -> R² = -5.2461, MSE = 2.0442e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.057066 | Val Loss 0.787632
# Epoch 100 | Train Loss 0.797780 | Val Loss 0.697025
# Epoch 200 | Train Loss 0.755872 | Val Loss 0.563034
# Epoch 300 | Train Loss 0.722842 | Val Loss 0.525581
# Epoch 400 | Train Loss 0.643660 | Val Loss 0.726719
# Epoch 500 | Train Loss 0.621730 | Val Loss 0.813349
# Early stopping at epoch 567
# Theta | train1 -> R² = 0.7504, MSE = 5.6979e-02
# Theta | train2 -> R² = 0.7497, MSE = 5.7137e-02
# Theta | test1 -> R² = 0.4514, MSE = 1.2603e-01
# Theta | test2 -> R² = 0.4133, MSE = 1.3914e-01
# Theta | test3 -> R² = -2.4646, MSE = 1.1390e+00
# Theta | val -> R² = -3.1859, MSE = 1.3700e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.045329 | Val Loss 0.797631
# Epoch 100 | Train Loss 0.792147 | Val Loss 0.682596
# Epoch 200 | Train Loss 0.744902 | Val Loss 0.549655
# Epoch 300 | Train Loss 0.723958 | Val Loss 0.520100
# Epoch 400 | Train Loss 0.638721 | Val Loss 0.716949
# Epoch 500 | Train Loss 0.612849 | Val Loss 0.832346
# Epoch 600 | Train Loss 0.601622 | Val Loss 0.888274
# Early stopping at epoch 601
# Theta | train1 -> R² = 0.7825, MSE = 4.9659e-02
# Theta | train2 -> R² = 0.7201, MSE = 6.3908e-02
# Theta | test1 -> R² = 0.5281, MSE = 1.0841e-01
# Theta | test2 -> R² = 0.3818, MSE = 1.4661e-01
# Theta | test3 -> R² = -3.1479, MSE = 1.3636e+00
# Theta | val -> R² = -3.6797, MSE = 1.5316e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.038251 | Val Loss 0.786318
# Epoch 100 | Train Loss 0.782512 | Val Loss 0.695575
# Epoch 200 | Train Loss 0.737500 | Val Loss 0.545301
# Epoch 300 | Train Loss 0.651220 | Val Loss 0.663520
# Epoch 400 | Train Loss 0.620911 | Val Loss 0.790871
# Epoch 500 | Train Loss 0.605375 | Val Loss 0.839194
# Early stopping at epoch 527
# Theta | train1 -> R² = 0.6190, MSE = 8.6973e-02
# Theta | train2 -> R² = 0.7475, MSE = 5.7643e-02
# Theta | test1 -> R² = 0.3034, MSE = 1.6002e-01
# Theta | test2 -> R² = 0.6831, MSE = 7.5150e-02
# Theta | test3 -> R² = -1.0086, MSE = 6.6031e-01
# Theta | val -> R² = -5.2013, MSE = 2.0296e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.072036 | Val Loss 0.821923
# Epoch 100 | Train Loss 0.790914 | Val Loss 0.698068
# Epoch 200 | Train Loss 0.741800 | Val Loss 0.546085
# Epoch 300 | Train Loss 0.725467 | Val Loss 0.516014
# Epoch 400 | Train Loss 0.654524 | Val Loss 0.652225
# Epoch 500 | Train Loss 0.628663 | Val Loss 0.731811
# Epoch 600 | Train Loss 0.607112 | Val Loss 0.810285
# Early stopping at epoch 612
# Theta | train1 -> R² = 0.6483, MSE = 8.0276e-02
# Theta | train2 -> R² = 0.7534, MSE = 5.6310e-02
# Theta | test1 -> R² = 0.3625, MSE = 1.4644e-01
# Theta | test2 -> R² = 0.5159, MSE = 1.1482e-01
# Theta | test3 -> R² = -2.8564, MSE = 1.2678e+00
# Theta | val -> R² = -4.1831, MSE = 1.6963e+00
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.066510 | Val Loss 0.785934
# Epoch 100 | Train Loss 0.840607 | Val Loss 0.630769
# Epoch 200 | Train Loss 0.739831 | Val Loss 0.544389
# Epoch 300 | Train Loss 0.717421 | Val Loss 0.500466
# Epoch 400 | Train Loss 0.665995 | Val Loss 0.585640
# Epoch 500 | Train Loss 0.636186 | Val Loss 0.748118
# Epoch 600 | Train Loss 0.620251 | Val Loss 0.777213
# Early stopping at epoch 630
# Theta | train1 -> R² = 0.7391, MSE = 5.9545e-02
# Theta | train2 -> R² = 0.5994, MSE = 9.1460e-02
# Theta | test1 -> R² = 0.5233, MSE = 1.0951e-01
# Theta | test2 -> R² = 0.7239, MSE = 6.5476e-02
# Theta | test3 -> R² = 0.2417, MSE = 2.4928e-01
# Theta | val -> R² = -2.8510, MSE = 1.2604e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.079776 | Val Loss 0.799717
# Epoch 100 | Train Loss 0.838159 | Val Loss 0.639926
# Epoch 200 | Train Loss 0.741719 | Val Loss 0.545173
# Epoch 300 | Train Loss 0.724147 | Val Loss 0.510396
# Epoch 400 | Train Loss 0.705754 | Val Loss 0.496824
# Epoch 500 | Train Loss 0.659475 | Val Loss 0.679965
# Epoch 600 | Train Loss 0.629224 | Val Loss 0.844728
# Early stopping at epoch 680
# Theta | train1 -> R² = 0.8654, MSE = 3.0736e-02
# Theta | train2 -> R² = 0.7042, MSE = 6.7524e-02
# Theta | test1 -> R² = 0.6840, MSE = 7.2581e-02
# Theta | test2 -> R² = 0.7952, MSE = 4.8577e-02
# Theta | test3 -> R² = 0.6286, MSE = 1.2210e-01
# Theta | val -> R² = -1.8446, MSE = 9.3099e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.071226 | Val Loss 0.798368
# Epoch 100 | Train Loss 0.833739 | Val Loss 0.643455
# Epoch 200 | Train Loss 0.737451 | Val Loss 0.534148
# Epoch 300 | Train Loss 0.720170 | Val Loss 0.505784
# Epoch 400 | Train Loss 0.690289 | Val Loss 0.496028
# Epoch 500 | Train Loss 0.646355 | Val Loss 0.656505
# Epoch 600 | Train Loss 0.625839 | Val Loss 0.739148
# Early stopping at epoch 660
# Theta | train1 -> R² = 0.8834, MSE = 2.6611e-02
# Theta | train2 -> R² = 0.6200, MSE = 8.6753e-02
# Theta | test1 -> R² = 0.8000, MSE = 4.5951e-02
# Theta | test2 -> R² = 0.6170, MSE = 9.0825e-02
# Theta | test3 -> R² = 0.7319, MSE = 8.8145e-02
# Theta | val -> R² = -0.0302, MSE = 3.3716e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.075950 | Val Loss 0.767103
# Epoch 100 | Train Loss 0.845942 | Val Loss 0.662031
# Epoch 200 | Train Loss 0.741408 | Val Loss 0.550144
# Epoch 300 | Train Loss 0.724015 | Val Loss 0.514491
# Epoch 400 | Train Loss 0.704601 | Val Loss 0.488257
# Epoch 500 | Train Loss 0.658051 | Val Loss 0.644367
# Epoch 600 | Train Loss 0.633686 | Val Loss 0.774259
# Early stopping at epoch 697
# Theta | train1 -> R² = 0.8473, MSE = 3.4850e-02
# Theta | train2 -> R² = 0.6824, MSE = 7.2505e-02
# Theta | test1 -> R² = 0.7392, MSE = 5.9909e-02
# Theta | test2 -> R² = 0.7968, MSE = 4.8201e-02
# Theta | test3 -> R² = 0.7750, MSE = 7.3966e-02
# Theta | val -> R² = -0.7287, MSE = 5.6576e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.124246 | Val Loss 0.820981
# Epoch 100 | Train Loss 0.846321 | Val Loss 0.659181
# Epoch 200 | Train Loss 0.742398 | Val Loss 0.538707
# Epoch 300 | Train Loss 0.724734 | Val Loss 0.514766
# Epoch 400 | Train Loss 0.711068 | Val Loss 0.499721
# Epoch 500 | Train Loss 0.663864 | Val Loss 0.590905
# Epoch 600 | Train Loss 0.632285 | Val Loss 0.734222
# Epoch 700 | Train Loss 0.609530 | Val Loss 0.768389
# Early stopping at epoch 731
# Theta | train1 -> R² = 0.7810, MSE = 5.0001e-02
# Theta | train2 -> R² = 0.7003, MSE = 6.8428e-02
# Theta | test1 -> R² = 0.6983, MSE = 6.9301e-02
# Theta | test2 -> R² = 0.6957, MSE = 7.2168e-02
# Theta | test3 -> R² = 0.5066, MSE = 1.6221e-01
# Theta | val -> R² = -0.1044, MSE = 3.6145e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.075469 | Val Loss 0.792157
# Epoch 100 | Train Loss 0.831845 | Val Loss 0.623373
# Epoch 200 | Train Loss 0.740553 | Val Loss 0.540051
# Epoch 300 | Train Loss 0.716633 | Val Loss 0.494549
# Epoch 400 | Train Loss 0.668563 | Val Loss 0.550746
# Epoch 500 | Train Loss 0.631073 | Val Loss 0.695095
# Epoch 600 | Train Loss 0.610490 | Val Loss 0.763942
# Early stopping at epoch 621
# Theta | train1 -> R² = 0.8070, MSE = 4.4045e-02
# Theta | train2 -> R² = 0.6269, MSE = 8.5175e-02
# Theta | test1 -> R² = 0.6794, MSE = 7.3656e-02
# Theta | test2 -> R² = 0.6662, MSE = 7.9173e-02
# Theta | test3 -> R² = 0.6461, MSE = 1.1633e-01
# Theta | val -> R² = -0.0807, MSE = 3.5369e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.077034 | Val Loss 0.805473
# Epoch 100 | Train Loss 0.830473 | Val Loss 0.658240
# Epoch 200 | Train Loss 0.737318 | Val Loss 0.540236
# Epoch 300 | Train Loss 0.717941 | Val Loss 0.495936
# Epoch 400 | Train Loss 0.674589 | Val Loss 0.542113
# Epoch 500 | Train Loss 0.634228 | Val Loss 0.706496
# Epoch 600 | Train Loss 0.611164 | Val Loss 0.751926
# Early stopping at epoch 644
# Theta | train1 -> R² = 0.7477, MSE = 5.7596e-02
# Theta | train2 -> R² = 0.6798, MSE = 7.3092e-02
# Theta | test1 -> R² = 0.6431, MSE = 8.1993e-02
# Theta | test2 -> R² = 0.7363, MSE = 6.2546e-02
# Theta | test3 -> R² = 0.4266, MSE = 1.8850e-01
# Theta | val -> R² = -0.2523, MSE = 4.0986e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.081271 | Val Loss 0.796376
# Epoch 100 | Train Loss 0.829949 | Val Loss 0.663413
# Epoch 200 | Train Loss 0.743850 | Val Loss 0.555909
# Epoch 300 | Train Loss 0.726103 | Val Loss 0.516295
# Epoch 400 | Train Loss 0.709341 | Val Loss 0.491892
# Epoch 500 | Train Loss 0.670550 | Val Loss 0.552372
# Epoch 600 | Train Loss 0.633341 | Val Loss 0.801355
# Epoch 700 | Train Loss 0.620347 | Val Loss 0.880362
# Early stopping at epoch 701
# Theta | train1 -> R² = 0.8937, MSE = 2.4274e-02
# Theta | train2 -> R² = 0.6602, MSE = 7.7576e-02
# Theta | test1 -> R² = 0.7955, MSE = 4.6968e-02
# Theta | test2 -> R² = 0.6931, MSE = 7.2778e-02
# Theta | test3 -> R² = 0.6788, MSE = 1.0559e-01
# Theta | val -> R² = -1.2476, MSE = 7.3561e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.089577 | Val Loss 0.812370
# ...
# Theta | test3 -> R² = 0.0571, MSE = 3.0997e-01
# Theta | val -> R² = -9.0793, MSE = 3.2988e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.037699 | Val Loss 0.829072
# Epoch 100 | Train Loss 0.742293 | Val Loss 0.553779
# Epoch 200 | Train Loss 0.655269 | Val Loss 0.646742
# Epoch 300 | Train Loss 0.611866 | Val Loss 0.805683
# Epoch 400 | Train Loss 0.597986 | Val Loss 0.897963
# Early stopping at epoch 460
# Theta | train1 -> R² = 0.8320, MSE = 3.8358e-02
# Theta | train2 -> R² = 0.7874, MSE = 4.8547e-02
# Theta | test1 -> R² = 0.6950, MSE = 7.0057e-02
# Theta | test2 -> R² = 0.6911, MSE = 7.3250e-02
# Theta | test3 -> R² = -0.2594, MSE = 4.1402e-01
# Theta | val -> R² = -2.4818, MSE = 1.1395e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.037142 | Val Loss 0.834659
# Epoch 100 | Train Loss 0.751564 | Val Loss 0.571102
# Epoch 200 | Train Loss 0.663250 | Val Loss 0.581927
# Epoch 300 | Train Loss 0.609636 | Val Loss 0.737523
# Epoch 400 | Train Loss 0.598179 | Val Loss 0.791093
# Early stopping at epoch 467
# Theta | train1 -> R² = 0.7691, MSE = 5.2710e-02
# Theta | train2 -> R² = 0.8361, MSE = 3.7426e-02
# Theta | test1 -> R² = 0.6161, MSE = 8.8190e-02
# Theta | test2 -> R² = 0.8474, MSE = 3.6193e-02
# Theta | test3 -> R² = -2.4237, MSE = 1.1255e+00
# Theta | val -> R² = -5.8666, MSE = 2.2473e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.038599 | Val Loss 0.833260
# Epoch 100 | Train Loss 0.745508 | Val Loss 0.568506
# Epoch 200 | Train Loss 0.678666 | Val Loss 0.566381
# Epoch 300 | Train Loss 0.608887 | Val Loss 0.853686
# Epoch 400 | Train Loss 0.596214 | Val Loss 0.914850
# Early stopping at epoch 465
# Theta | train1 -> R² = 0.8137, MSE = 4.2530e-02
# Theta | train2 -> R² = 0.8406, MSE = 3.6401e-02
# Theta | test1 -> R² = 0.6518, MSE = 7.9980e-02
# Theta | test2 -> R² = 0.7665, MSE = 5.5380e-02
# Theta | test3 -> R² = -1.1610, MSE = 7.1043e-01
# Theta | val -> R² = -5.0786, MSE = 1.9894e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.035456 | Val Loss 0.828580
# Epoch 100 | Train Loss 0.755558 | Val Loss 0.549327
# Epoch 200 | Train Loss 0.688230 | Val Loss 0.541332
# Epoch 300 | Train Loss 0.628197 | Val Loss 0.689558
# Epoch 400 | Train Loss 0.613417 | Val Loss 0.805263
# Early stopping at epoch 483
# Theta | train1 -> R² = 0.8143, MSE = 4.2388e-02
# Theta | train2 -> R² = 0.7629, MSE = 5.4126e-02
# Theta | test1 -> R² = 0.7245, MSE = 6.3297e-02
# Theta | test2 -> R² = 0.6386, MSE = 8.5719e-02
# Theta | test3 -> R² = -0.7139, MSE = 5.6345e-01
# Theta | val -> R² = -4.1027, MSE = 1.6700e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.043891 | Val Loss 0.843191
# Epoch 100 | Train Loss 0.741405 | Val Loss 0.553375
# Epoch 200 | Train Loss 0.641845 | Val Loss 0.714768
# Epoch 300 | Train Loss 0.603968 | Val Loss 0.833813
# Epoch 400 | Train Loss 0.593517 | Val Loss 0.889319
# Early stopping at epoch 431
# Theta | train1 -> R² = 0.8181, MSE = 4.1525e-02
# Theta | train2 -> R² = 0.8300, MSE = 3.8820e-02
# Theta | test1 -> R² = 0.6234, MSE = 8.6512e-02
# Theta | test2 -> R² = 0.7979, MSE = 4.7920e-02
# Theta | test3 -> R² = -0.3239, MSE = 4.3524e-01
# Theta | val -> R² = -3.4789, MSE = 1.4658e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.037678 | Val Loss 0.834205
# Epoch 100 | Train Loss 0.741915 | Val Loss 0.556874
# Epoch 200 | Train Loss 0.644688 | Val Loss 0.674000
# Epoch 300 | Train Loss 0.622414 | Val Loss 0.741623
# Epoch 400 | Train Loss 0.597821 | Val Loss 0.854594
# Early stopping at epoch 449
# Theta | train1 -> R² = 0.7951, MSE = 4.6776e-02
# Theta | train2 -> R² = 0.7983, MSE = 4.6043e-02
# Theta | test1 -> R² = 0.6854, MSE = 7.2269e-02
# Theta | test2 -> R² = 0.7264, MSE = 6.4892e-02
# Theta | test3 -> R² = -1.3770, MSE = 7.8144e-01
# Theta | val -> R² = -3.9103, MSE = 1.6071e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.036719 | Val Loss 0.837814
# Epoch 100 | Train Loss 0.750249 | Val Loss 0.573617
# Epoch 200 | Train Loss 0.668475 | Val Loss 0.561686
# Epoch 300 | Train Loss 0.608857 | Val Loss 0.752018
# Epoch 400 | Train Loss 0.596608 | Val Loss 0.816773
# Early stopping at epoch 465
# Theta | train1 -> R² = 0.7648, MSE = 5.3698e-02
# Theta | train2 -> R² = 0.8469, MSE = 3.4961e-02
# Theta | test1 -> R² = 0.6218, MSE = 8.6884e-02
# Theta | test2 -> R² = 0.8303, MSE = 4.0247e-02
# Theta | test3 -> R² = -4.7523, MSE = 1.8910e+00
# Theta | val -> R² = -8.2232, MSE = 3.0186e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.038990 | Val Loss 0.839160
# Epoch 100 | Train Loss 0.741742 | Val Loss 0.548198
# Epoch 200 | Train Loss 0.664482 | Val Loss 0.572015
# Epoch 300 | Train Loss 0.619514 | Val Loss 0.734629
# Epoch 400 | Train Loss 0.606358 | Val Loss 0.872219
# Early stopping at epoch 469
# Theta | train1 -> R² = 0.8004, MSE = 4.5570e-02
# Theta | train2 -> R² = 0.5604, MSE = 1.0036e-01
# Theta | test1 -> R² = 0.7588, MSE = 5.5402e-02
# Theta | test2 -> R² = 0.2554, MSE = 1.7658e-01
# Theta | test3 -> R² = -0.1267, MSE = 3.7040e-01
# Theta | val -> R² = -2.0062, MSE = 9.8388e-01
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.039154 | Val Loss 0.835233
# Epoch 100 | Train Loss 0.746735 | Val Loss 0.567859
# Epoch 200 | Train Loss 0.662643 | Val Loss 0.594121
# Epoch 300 | Train Loss 0.613016 | Val Loss 0.762926
# Epoch 400 | Train Loss 0.597881 | Val Loss 0.856647
# Early stopping at epoch 475
# Theta | train1 -> R² = 0.8388, MSE = 3.6794e-02
# Theta | train2 -> R² = 0.8184, MSE = 4.1449e-02
# Theta | test1 -> R² = 0.7741, MSE = 5.1897e-02
# Theta | test2 -> R² = 0.6709, MSE = 7.8060e-02
# Theta | test3 -> R² = -1.1774, MSE = 7.1583e-01
# Theta | val -> R² = -2.7843, MSE = 1.2385e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.035273 | Val Loss 0.831190
# Epoch 100 | Train Loss 0.740182 | Val Loss 0.549563
# Epoch 200 | Train Loss 0.646782 | Val Loss 0.656695
# Epoch 300 | Train Loss 0.609125 | Val Loss 0.755396
# Epoch 400 | Train Loss 0.594591 | Val Loss 0.838026
# Early stopping at epoch 456
# Theta | train1 -> R² = 0.7942, MSE = 4.6979e-02
# Theta | train2 -> R² = 0.8224, MSE = 4.0538e-02
# Theta | test1 -> R² = 0.7264, MSE = 6.2859e-02
# Theta | test2 -> R² = 0.7600, MSE = 5.6928e-02
# Theta | test3 -> R² = -1.4844, MSE = 8.1674e-01
# Theta | val -> R² = -3.4292, MSE = 1.4496e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.037156 | Val Loss 0.831928
# Epoch 100 | Train Loss 0.749552 | Val Loss 0.574160
# Epoch 200 | Train Loss 0.654280 | Val Loss 0.626164
# Epoch 300 | Train Loss 0.613778 | Val Loss 0.750959
# Epoch 400 | Train Loss 0.596131 | Val Loss 0.855500
# Early stopping at epoch 468
# Theta | train1 -> R² = 0.7986, MSE = 4.5970e-02
# Theta | train2 -> R² = 0.7587, MSE = 5.5088e-02
# Theta | test1 -> R² = 0.6087, MSE = 8.9886e-02
# Theta | test2 -> R² = 0.7492, MSE = 5.9483e-02
# Theta | test3 -> R² = 0.1833, MSE = 2.6848e-01
# Theta | val -> R² = -1.9175, MSE = 9.5482e-01
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.038341 | Val Loss 0.835261
# Epoch 100 | Train Loss 0.743368 | Val Loss 0.557205
# Epoch 200 | Train Loss 0.702422 | Val Loss 0.524581
# Epoch 300 | Train Loss 0.633862 | Val Loss 0.750994
# Epoch 400 | Train Loss 0.609550 | Val Loss 0.839189
# Early stopping at epoch 480
# Theta | train1 -> R² = 0.8788, MSE = 2.7666e-02
# Theta | train2 -> R² = 0.7662, MSE = 5.3377e-02
# Theta | test1 -> R² = 0.7190, MSE = 6.4545e-02
# Theta | test2 -> R² = 0.6389, MSE = 8.5632e-02
# Theta | test3 -> R² = 0.0906, MSE = 2.9898e-01
# Theta | val -> R² = -3.4120, MSE = 1.4440e+00
# Modelo [128, 64, 32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.062094 | Val Loss 0.833992
# Epoch 100 | Train Loss 0.729299 | Val Loss 0.533982
# Epoch 200 | Train Loss 0.665769 | Val Loss 0.500327
# Epoch 300 | Train Loss 0.618605 | Val Loss 0.713495
# Epoch 400 | Train Loss 0.593434 | Val Loss 0.794146
# Early stopping at epoch 484
# Theta | train1 -> R² = 0.6571, MSE = 7.8269e-02
# Theta | train2 -> R² = 0.7773, MSE = 5.0836e-02
# Theta | test1 -> R² = 0.7332, MSE = 6.1283e-02
# Theta | test2 -> R² = 0.7988, MSE = 4.7707e-02
# Theta | test3 -> R² = -0.4471, MSE = 4.7573e-01
# Theta | val -> R² = -1.1272, MSE = 6.9619e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.063767 | Val Loss 0.834058
# Epoch 100 | Train Loss 0.725867 | Val Loss 0.535878
# Epoch 200 | Train Loss 0.682962 | Val Loss 0.492442
# Epoch 300 | Train Loss 0.629643 | Val Loss 0.716848
# Epoch 400 | Train Loss 0.611267 | Val Loss 0.745349
# Early stopping at epoch 484
# Theta | train1 -> R² = 0.8182, MSE = 4.1495e-02
# Theta | train2 -> R² = 0.7659, MSE = 5.3448e-02
# Theta | test1 -> R² = 0.7550, MSE = 5.6274e-02
# Theta | test2 -> R² = 0.8461, MSE = 3.6510e-02
# Theta | test3 -> R² = 0.5555, MSE = 1.4613e-01
# Theta | val -> R² = -0.3372, MSE = 4.3764e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.067220 | Val Loss 0.841675
# Epoch 100 | Train Loss 0.727022 | Val Loss 0.537593
# Epoch 200 | Train Loss 0.694201 | Val Loss 0.493129
# Epoch 300 | Train Loss 0.640251 | Val Loss 0.688602
# Epoch 400 | Train Loss 0.609963 | Val Loss 0.778422
# Early stopping at epoch 499
# Theta | train1 -> R² = 0.7906, MSE = 4.7803e-02
# Theta | train2 -> R² = 0.7781, MSE = 5.0660e-02
# Theta | test1 -> R² = 0.6760, MSE = 7.4418e-02
# Theta | test2 -> R² = 0.8592, MSE = 3.3402e-02
# Theta | test3 -> R² = 0.3384, MSE = 2.1751e-01
# Theta | val -> R² = -1.2503, MSE = 7.3648e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.064863 | Val Loss 0.836892
# Epoch 100 | Train Loss 0.741345 | Val Loss 0.548267
# Epoch 200 | Train Loss 0.667170 | Val Loss 0.534410
# Epoch 300 | Train Loss 0.624122 | Val Loss 0.762374
# Epoch 400 | Train Loss 0.601300 | Val Loss 0.824472
# Early stopping at epoch 469
# Theta | train1 -> R² = 0.7486, MSE = 5.7384e-02
# Theta | train2 -> R² = 0.7805, MSE = 5.0105e-02
# Theta | test1 -> R² = 0.6759, MSE = 7.4441e-02
# Theta | test2 -> R² = 0.8576, MSE = 3.3776e-02
# Theta | test3 -> R² = 0.5292, MSE = 1.5477e-01
# Theta | val -> R² = -0.4844, MSE = 4.8582e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.063417 | Val Loss 0.836242
# Epoch 100 | Train Loss 0.732016 | Val Loss 0.539141
# Epoch 200 | Train Loss 0.701718 | Val Loss 0.497786
# Epoch 300 | Train Loss 0.659321 | Val Loss 0.578320
# Epoch 400 | Train Loss 0.625433 | Val Loss 0.720314
# Epoch 500 | Train Loss 0.600741 | Val Loss 0.804005
# Early stopping at epoch 504
# Theta | train1 -> R² = 0.7800, MSE = 5.0218e-02
# Theta | train2 -> R² = 0.7682, MSE = 5.2929e-02
# Theta | test1 -> R² = 0.6722, MSE = 7.5298e-02
# Theta | test2 -> R² = 0.8574, MSE = 3.3812e-02
# Theta | test3 -> R² = 0.2216, MSE = 2.5591e-01
# Theta | val -> R² = -0.8414, MSE = 6.0264e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.069362 | Val Loss 0.842313
# Epoch 100 | Train Loss 0.732728 | Val Loss 0.549519
# Epoch 200 | Train Loss 0.699029 | Val Loss 0.477527
# Epoch 300 | Train Loss 0.637210 | Val Loss 0.694144
# Epoch 400 | Train Loss 0.611710 | Val Loss 0.769990
# Early stopping at epoch 498
# Theta | train1 -> R² = 0.8496, MSE = 3.4339e-02
# Theta | train2 -> R² = 0.6530, MSE = 7.9211e-02
# Theta | test1 -> R² = 0.8027, MSE = 4.5315e-02
# Theta | test2 -> R² = 0.7158, MSE = 6.7411e-02
# Theta | test3 -> R² = 0.5269, MSE = 1.5553e-01
# Theta | val -> R² = -0.6400, MSE = 5.3673e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 1.065513 | Val Loss 0.836655
# Epoch 100 | Train Loss 0.731196 | Val Loss 0.532671
# Epoch 200 | Train Loss 0.667556 | Val Loss 0.522777
# Epoch 300 | Train Loss 0.621375 | Val Loss 0.781544
# Epoch 400 | Train Loss 0.591414 | Val Loss 0.852992
# Early stopping at epoch 470
# Theta | train1 -> R² = 0.7389, MSE = 5.9601e-02
# Theta | train2 -> R² = 0.7786, MSE = 5.0552e-02
# Theta | test1 -> R² = 0.7607, MSE = 5.4973e-02
# Theta | test2 -> R² = 0.8472, MSE = 3.6234e-02
# Theta | test3 -> R² = 0.4520, MSE = 1.8017e-01
# Theta | val -> R² = -0.1778, MSE = 3.8547e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 1.061657 | Val Loss 0.831554
# Epoch 100 | Train Loss 0.728954 | Val Loss 0.533592
# Epoch 200 | Train Loss 0.665243 | Val Loss 0.497026
# Epoch 300 | Train Loss 0.623338 | Val Loss 0.690656
# Epoch 400 | Train Loss 0.590716 | Val Loss 0.822481
# Early stopping at epoch 494
# Theta | train1 -> R² = 0.5662, MSE = 9.9026e-02
# Theta | train2 -> R² = 0.6516, MSE = 7.9545e-02
# Theta | test1 -> R² = 0.7512, MSE = 5.7159e-02
# Theta | test2 -> R² = 0.5437, MSE = 1.0822e-01
# Theta | test3 -> R² = -1.1560, MSE = 7.0879e-01
# Theta | val -> R² = -0.8290, MSE = 5.9859e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 1.067420 | Val Loss 0.839133
# Epoch 100 | Train Loss 0.734585 | Val Loss 0.532232
# Epoch 200 | Train Loss 0.654345 | Val Loss 0.617316
# Epoch 300 | Train Loss 0.617842 | Val Loss 0.764168
# Epoch 400 | Train Loss 0.593185 | Val Loss 0.895218
# Early stopping at epoch 443
# Theta | train1 -> R² = 0.7993, MSE = 4.5810e-02
# Theta | train2 -> R² = 0.7858, MSE = 4.8896e-02
# Theta | test1 -> R² = 0.7916, MSE = 4.7864e-02
# Theta | test2 -> R² = 0.8017, MSE = 4.7029e-02
# Theta | test3 -> R² = 0.1997, MSE = 2.6311e-01
# Theta | val -> R² = -1.4015, MSE = 7.8596e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 1.059854 | Val Loss 0.829643
# Epoch 100 | Train Loss 0.747847 | Val Loss 0.548936
# Epoch 200 | Train Loss 0.693248 | Val Loss 0.533551
# Epoch 300 | Train Loss 0.634944 | Val Loss 0.979582
# Epoch 400 | Train Loss 0.611414 | Val Loss 1.055956
# Early stopping at epoch 461
# Theta | train1 -> R² = 0.7972, MSE = 4.6293e-02
# Theta | train2 -> R² = 0.4438, MSE = 1.2699e-01
# Theta | test1 -> R² = 0.8329, MSE = 3.8389e-02
# Theta | test2 -> R² = 0.4793, MSE = 1.2348e-01
# Theta | test3 -> R² = 0.6072, MSE = 1.2914e-01
# Theta | val -> R² = -0.0759, MSE = 3.5212e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 1.057654 | Val Loss 0.823479
# Epoch 100 | Train Loss 0.731943 | Val Loss 0.529633
# Epoch 200 | Train Loss 0.687967 | Val Loss 0.496927
# Epoch 300 | Train Loss 0.643128 | Val Loss 0.703920
# Epoch 400 | Train Loss 0.605360 | Val Loss 0.830135
# Early stopping at epoch 476
# Theta | train1 -> R² = 0.8069, MSE = 4.4069e-02
# Theta | train2 -> R² = 0.7815, MSE = 4.9877e-02
# Theta | test1 -> R² = 0.7263, MSE = 6.2871e-02
# Theta | test2 -> R² = 0.8421, MSE = 3.7459e-02
# Theta | test3 -> R² = 0.4667, MSE = 1.7533e-01
# Theta | val -> R² = -0.3519, MSE = 4.4244e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.065119 | Val Loss 0.840166
# Epoch 100 | Train Loss 0.729991 | Val Loss 0.542999
# Epoch 200 | Train Loss 0.696856 | Val Loss 0.487969
# Epoch 300 | Train Loss 0.660885 | Val Loss 0.510073
# Epoch 400 | Train Loss 0.615193 | Val Loss 0.904983
# Epoch 500 | Train Loss 0.586155 | Val Loss 0.949363
# Early stopping at epoch 567
# Theta | train1 -> R² = 0.5290, MSE = 1.0751e-01
# Theta | train2 -> R² = -0.0402, MSE = 2.3749e-01
# Theta | test1 -> R² = 0.6617, MSE = 7.7723e-02
# Theta | test2 -> R² = -0.0570, MSE = 2.5068e-01
# Theta | test3 -> R² = 0.0103, MSE = 3.2536e-01
# Theta | val -> R² = 0.1806, MSE = 2.6816e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.068361 | Val Loss 0.841289
# Epoch 100 | Train Loss 0.733651 | Val Loss 0.535504
# Epoch 200 | Train Loss 0.689218 | Val Loss 0.481340
# Epoch 300 | Train Loss 0.634197 | Val Loss 0.699008
# Epoch 400 | Train Loss 0.626355 | Val Loss 0.774477
# Epoch 500 | Train Loss 0.598956 | Val Loss 0.804575
# Early stopping at epoch 508
# Theta | train1 -> R² = 0.7805, MSE = 5.0098e-02
# Theta | train2 -> R² = 0.6968, MSE = 6.9223e-02
# Theta | test1 -> R² = 0.8367, MSE = 3.7513e-02
# Theta | test2 -> R² = 0.6383, MSE = 8.5790e-02
# Theta | test3 -> R² = 0.0111, MSE = 3.2509e-01
# Theta | val -> R² = -0.7888, MSE = 5.8545e-01
# Modelo [128, 64, 32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
