# %% [markdown]
# - Entradas: WdRef, WeRef
# - Saidas: Theta
# - Trajetorias: ZZ + ZZRoted

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
            
    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
import joblib

joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")
# Out:
# ['out_scaler.pkl']

# %%
for i in range(6):
    print(NormDatasets[i].shape)
# Out:
# (976, 11)
# (976, 11)
# (982, 11)
# (982, 11)
# (1420, 10)
# (1271, 10)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    # dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dtheta_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16, 8],
[264, 128],
[32, 16, 8],
[264],
[16, 8, 4],
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01,  0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}"
        weights_path = f"weights/{model_name}.weights.h5"

        wf = model.get_weights()
        # salva pesos em arquivo
        model.save_weights(weights_path)
        model.save(f"./model/{model_name}.keras")
        metrics = EvalModel(model)

        row = {
            "model": model_name,
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 1.062636 | Val Loss 0.841633
# Epoch 100 | Train Loss 0.864887 | Val Loss 0.570218
# Epoch 200 | Train Loss 0.848282 | Val Loss 0.561393
# Epoch 300 | Train Loss 0.816063 | Val Loss 0.546408
# Epoch 400 | Train Loss 0.752349 | Val Loss 0.510074
# Epoch 500 | Train Loss 0.718121 | Val Loss 0.503205
# Epoch 600 | Train Loss 0.709922 | Val Loss 0.495630
# Epoch 700 | Train Loss 0.700397 | Val Loss 0.486240
# Epoch 800 | Train Loss 0.686662 | Val Loss 0.480796
# Epoch 900 | Train Loss 0.669054 | Val Loss 0.502559
# Epoch 1000 | Train Loss 0.648101 | Val Loss 0.580658
# Early stopping at epoch 1067
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8360, MSE = 3.7430e-02
# Theta | train2 -> R² = 0.7474, MSE = 5.7663e-02
# Theta | test1 -> R² = 0.6684, MSE = 7.6179e-02
# Theta | test2 -> R² = 0.7672, MSE = 5.5210e-02
# Theta | test3 -> R² = -1.9592, MSE = 9.7281e-01
# Theta | val -> R² = -1.7978, MSE = 9.1566e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.063328 | Val Loss 0.843154
# Epoch 100 | Train Loss 0.861104 | Val Loss 0.568114
# Epoch 200 | Train Loss 0.834020 | Val Loss 0.548995
# Epoch 300 | Train Loss 0.781791 | Val Loss 0.524802
# Epoch 400 | Train Loss 0.733790 | Val Loss 0.509734
# Epoch 500 | Train Loss 0.712583 | Val Loss 0.500079
# Epoch 600 | Train Loss 0.699163 | Val Loss 0.499243
# Epoch 700 | Train Loss 0.670402 | Val Loss 0.564869
# Epoch 800 | Train Loss 0.640388 | Val Loss 0.696691
# Early stopping at epoch 859
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8508, MSE = 3.4048e-02
# Theta | train2 -> R² = 0.7351, MSE = 6.0485e-02
# Theta | test1 -> R² = 0.7824, MSE = 4.9990e-02
# Theta | test2 -> R² = 0.7111, MSE = 6.8512e-02
# Theta | test3 -> R² = 0.0324, MSE = 3.1810e-01
# Theta | val -> R² = -0.7490, MSE = 5.7241e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.063168 | Val Loss 0.840982
# Epoch 100 | Train Loss 0.864810 | Val Loss 0.572548
# Epoch 200 | Train Loss 0.842737 | Val Loss 0.560536
# Epoch 300 | Train Loss 0.803385 | Val Loss 0.546097
# Epoch 400 | Train Loss 0.745058 | Val Loss 0.519100
# Epoch 500 | Train Loss 0.718633 | Val Loss 0.508625
# Epoch 600 | Train Loss 0.710798 | Val Loss 0.504295
# Epoch 700 | Train Loss 0.706282 | Val Loss 0.501293
# Epoch 800 | Train Loss 0.702265 | Val Loss 0.499890
# Epoch 900 | Train Loss 0.697644 | Val Loss 0.499888
# Epoch 1000 | Train Loss 0.690710 | Val Loss 0.503451
# Epoch 1100 | Train Loss 0.678604 | Val Loss 0.521382
# Epoch 1200 | Train Loss 0.655783 | Val Loss 0.578205
# Early stopping at epoch 1208
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8065, MSE = 4.4178e-02
# Theta | train2 -> R² = 0.2966, MSE = 1.6058e-01
# Theta | test1 -> R² = 0.7700, MSE = 5.2837e-02
# Theta | test2 -> R² = 0.1948, MSE = 1.9097e-01
# Theta | test3 -> R² = 0.5492, MSE = 1.4820e-01
# Theta | val -> R² = 0.7300, MSE = 8.8377e-02
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.062768 | Val Loss 0.841502
# Epoch 100 | Train Loss 0.852313 | Val Loss 0.572233
# Epoch 200 | Train Loss 0.799321 | Val Loss 0.549579
# Epoch 300 | Train Loss 0.728864 | Val Loss 0.521602
# Epoch 400 | Train Loss 0.710906 | Val Loss 0.511557
# Epoch 500 | Train Loss 0.702380 | Val Loss 0.517235
# Epoch 600 | Train Loss 0.692397 | Val Loss 0.551574
# Early stopping at epoch 700
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8907, MSE = 2.4951e-02
# Theta | train2 -> R² = 0.7045, MSE = 6.7468e-02
# Theta | test1 -> R² = 0.7963, MSE = 4.6802e-02
# Theta | test2 -> R² = 0.7816, MSE = 5.1793e-02
# Theta | test3 -> R² = 0.5279, MSE = 1.5521e-01
# Theta | val -> R² = -1.3640, MSE = 7.7370e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.063459 | Val Loss 0.843361
# Epoch 100 | Train Loss 0.864362 | Val Loss 0.569786
# Epoch 200 | Train Loss 0.834717 | Val Loss 0.557111
# Epoch 300 | Train Loss 0.762367 | Val Loss 0.529593
# Epoch 400 | Train Loss 0.716082 | Val Loss 0.510196
# Epoch 500 | Train Loss 0.705682 | Val Loss 0.491474
# Epoch 600 | Train Loss 0.696776 | Val Loss 0.476979
# Epoch 700 | Train Loss 0.682776 | Val Loss 0.473586
# Epoch 800 | Train Loss 0.650826 | Val Loss 0.570485
# Epoch 900 | Train Loss 0.618542 | Val Loss 0.688102
# Early stopping at epoch 938
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8933, MSE = 2.4366e-02
# Theta | train2 -> R² = 0.8143, MSE = 4.2396e-02
# Theta | test1 -> R² = 0.8277, MSE = 3.9581e-02
# Theta | test2 -> R² = 0.8128, MSE = 4.4389e-02
# Theta | test3 -> R² = -0.7663, MSE = 5.8065e-01
# Theta | val -> R² = -1.5385, MSE = 8.3078e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.061946 | Val Loss 0.838779
# Epoch 100 | Train Loss 0.862808 | Val Loss 0.567550
# Epoch 200 | Train Loss 0.837208 | Val Loss 0.547217
# Epoch 300 | Train Loss 0.799375 | Val Loss 0.524749
# Epoch 400 | Train Loss 0.744682 | Val Loss 0.521292
# Epoch 500 | Train Loss 0.717762 | Val Loss 0.515839
# Epoch 600 | Train Loss 0.709123 | Val Loss 0.493262
# Epoch 700 | Train Loss 0.700723 | Val Loss 0.490691
# Epoch 800 | Train Loss 0.685984 | Val Loss 0.519603
# Epoch 900 | Train Loss 0.656891 | Val Loss 0.602351
# Early stopping at epoch 938
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8110, MSE = 4.3147e-02
# Theta | train2 -> R² = 0.7351, MSE = 6.0486e-02
# Theta | test1 -> R² = 0.7397, MSE = 5.9792e-02
# Theta | test2 -> R² = 0.7206, MSE = 6.6266e-02
# Theta | test3 -> R² = -0.5909, MSE = 5.2301e-01
# Theta | val -> R² = -1.9438, MSE = 9.6346e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.062162 | Val Loss 0.841055
# Epoch 100 | Train Loss 0.861423 | Val Loss 0.567783
# Epoch 200 | Train Loss 0.829538 | Val Loss 0.555956
# Epoch 300 | Train Loss 0.758668 | Val Loss 0.528138
# Epoch 400 | Train Loss 0.700407 | Val Loss 0.533305
# Epoch 500 | Train Loss 0.669458 | Val Loss 0.579330
# Epoch 600 | Train Loss 0.638147 | Val Loss 0.688329
# Early stopping at epoch 642
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8859, MSE = 2.6052e-02
# Theta | train2 -> R² = 0.6369, MSE = 8.2897e-02
# Theta | test1 -> R² = 0.7910, MSE = 4.8018e-02
# Theta | test2 -> R² = 0.4654, MSE = 1.2679e-01
# Theta | test3 -> R² = 0.3223, MSE = 2.2280e-01
# Theta | val -> R² = 0.6892, MSE = 1.0172e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.062544 | Val Loss 0.842137
# Epoch 100 | Train Loss 0.848796 | Val Loss 0.571986
# Epoch 200 | Train Loss 0.803464 | Val Loss 0.556594
# Epoch 300 | Train Loss 0.727246 | Val Loss 0.517924
# Epoch 400 | Train Loss 0.709281 | Val Loss 0.503844
# Epoch 500 | Train Loss 0.696209 | Val Loss 0.484452
# Epoch 600 | Train Loss 0.655730 | Val Loss 0.520292
# Epoch 700 | Train Loss 0.615607 | Val Loss 0.689952
# Epoch 800 | Train Loss 0.599196 | Val Loss 0.710110
# Early stopping at epoch 817
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8533, MSE = 3.3497e-02
# Theta | train2 -> R² = 0.7434, MSE = 5.8580e-02
# Theta | test1 -> R² = 0.7895, MSE = 4.8354e-02
# Theta | test2 -> R² = 0.7826, MSE = 5.1561e-02
# Theta | test3 -> R² = -0.3260, MSE = 4.3593e-01
# Theta | val -> R² = -3.3824, MSE = 1.4343e+00
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.062627 | Val Loss 0.843877
# Epoch 100 | Train Loss 0.860646 | Val Loss 0.573016
# Epoch 200 | Train Loss 0.824873 | Val Loss 0.562530
# Epoch 300 | Train Loss 0.745594 | Val Loss 0.533425
# Epoch 400 | Train Loss 0.717779 | Val Loss 0.508417
# Epoch 500 | Train Loss 0.706159 | Val Loss 0.501302
# Epoch 600 | Train Loss 0.694745 | Val Loss 0.527371
# Epoch 700 | Train Loss 0.669524 | Val Loss 0.600849
# Early stopping at epoch 777
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8734, MSE = 2.8900e-02
# Theta | train2 -> R² = 0.7254, MSE = 6.2681e-02
# Theta | test1 -> R² = 0.7826, MSE = 4.9948e-02
# Theta | test2 -> R² = 0.8047, MSE = 4.6324e-02
# Theta | test3 -> R² = -0.6763, MSE = 5.5107e-01
# Theta | val -> R² = -1.5070, MSE = 8.2049e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.063250 | Val Loss 0.845326
# Epoch 100 | Train Loss 0.858880 | Val Loss 0.568978
# Epoch 200 | Train Loss 0.823116 | Val Loss 0.556672
# Epoch 300 | Train Loss 0.760822 | Val Loss 0.519973
# Epoch 400 | Train Loss 0.721781 | Val Loss 0.524299
# Epoch 500 | Train Loss 0.713126 | Val Loss 0.518126
# Epoch 600 | Train Loss 0.708065 | Val Loss 0.503009
# Epoch 700 | Train Loss 0.702599 | Val Loss 0.489931
# Epoch 800 | Train Loss 0.695674 | Val Loss 0.476804
# Epoch 900 | Train Loss 0.685221 | Val Loss 0.465685
# Epoch 1000 | Train Loss 0.657287 | Val Loss 0.537805
# Epoch 1100 | Train Loss 0.630922 | Val Loss 0.761770
# Early stopping at epoch 1191
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7813, MSE = 4.9915e-02
# Theta | train2 -> R² = 0.6832, MSE = 7.2320e-02
# Theta | test1 -> R² = 0.7930, MSE = 4.7552e-02
# Theta | test2 -> R² = 0.7849, MSE = 5.1012e-02
# Theta | test3 -> R² = 0.6603, MSE = 1.1168e-01
# Theta | val -> R² = -0.1915, MSE = 3.8996e-01
# Modelo [16, 8] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.009620 | Val Loss 0.839294
# Epoch 100 | Train Loss 0.714729 | Val Loss 0.604441
# Epoch 200 | Train Loss 0.699001 | Val Loss 0.598461
# Epoch 300 | Train Loss 0.685249 | Val Loss 0.591232
# Early stopping at epoch 372
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7639, MSE = 5.3904e-02
# Theta | train2 -> R² = 0.5149, MSE = 1.1075e-01
# Theta | test1 -> R² = 0.3006, MSE = 1.6066e-01
# Theta | test2 -> R² = 0.8607, MSE = 3.3031e-02
# Theta | test3 -> R² = 0.2920, MSE = 2.3276e-01
# Theta | val -> R² = -7.2501, MSE = 2.7001e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.010793 | Val Loss 0.841574
# Epoch 100 | Train Loss 0.717231 | Val Loss 0.585162
# Epoch 200 | Train Loss 0.700407 | Val Loss 0.595465
# Epoch 300 | Train Loss 0.682354 | Val Loss 0.594921
# Early stopping at epoch 383
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7637, MSE = 5.3935e-02
# Theta | train2 -> R² = 0.4219, MSE = 1.3198e-01
# Theta | test1 -> R² = 0.3028, MSE = 1.6017e-01
# Theta | test2 -> R² = 0.8602, MSE = 3.3155e-02
# Theta | test3 -> R² = 0.5247, MSE = 1.5626e-01
# Theta | val -> R² = -5.7230, MSE = 2.2003e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.012803 | Val Loss 0.842506
# Epoch 100 | Train Loss 0.713438 | Val Loss 0.595329
# Epoch 200 | Train Loss 0.700973 | Val Loss 0.598948
# Epoch 300 | Train Loss 0.691888 | Val Loss 0.594694
# Early stopping at epoch 383
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7856, MSE = 4.8944e-02
# Theta | train2 -> R² = 0.5288, MSE = 1.0759e-01
# Theta | test1 -> R² = 0.4511, MSE = 1.2609e-01
# Theta | test2 -> R² = 0.8705, MSE = 3.0715e-02
# Theta | test3 -> R² = 0.2236, MSE = 2.5523e-01
# Theta | val -> R² = -6.7893, MSE = 2.5493e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.013040 | Val Loss 0.838579
# Epoch 100 | Train Loss 0.714317 | Val Loss 0.599063
# Epoch 200 | Train Loss 0.697800 | Val Loss 0.589535
# Epoch 300 | Train Loss 0.651245 | Val Loss 0.605477
# Early stopping at epoch 379
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7630, MSE = 5.4094e-02
# Theta | train2 -> R² = 0.5004, MSE = 1.1405e-01
# Theta | test1 -> R² = 0.3455, MSE = 1.5036e-01
# Theta | test2 -> R² = 0.8643, MSE = 3.2194e-02
# Theta | test3 -> R² = 0.3544, MSE = 2.1225e-01
# Theta | val -> R² = -6.5467, MSE = 2.4699e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.011059 | Val Loss 0.842153
# Epoch 100 | Train Loss 0.714420 | Val Loss 0.599300
# Epoch 200 | Train Loss 0.695768 | Val Loss 0.597430
# Epoch 300 | Train Loss 0.667867 | Val Loss 0.625569
# Early stopping at epoch 380
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7433, MSE = 5.8595e-02
# Theta | train2 -> R² = 0.5203, MSE = 1.0951e-01
# Theta | test1 -> R² = 0.2775, MSE = 1.6597e-01
# Theta | test2 -> R² = 0.8663, MSE = 3.1714e-02
# Theta | test3 -> R² = 0.2848, MSE = 2.3513e-01
# Theta | val -> R² = -7.1707, MSE = 2.6741e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.010468 | Val Loss 0.839466
# Epoch 100 | Train Loss 0.713884 | Val Loss 0.605445
# Epoch 200 | Train Loss 0.695223 | Val Loss 0.594072
# Epoch 300 | Train Loss 0.655859 | Val Loss 0.603294
# Early stopping at epoch 379
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7467, MSE = 5.7829e-02
# Theta | train2 -> R² = 0.5431, MSE = 1.0432e-01
# Theta | test1 -> R² = 0.3213, MSE = 1.5590e-01
# Theta | test2 -> R² = 0.8745, MSE = 2.9775e-02
# Theta | test3 -> R² = 0.1755, MSE = 2.7104e-01
# Theta | val -> R² = -7.4785, MSE = 2.7749e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.010666 | Val Loss 0.839835
# Epoch 100 | Train Loss 0.715290 | Val Loss 0.603714
# Epoch 200 | Train Loss 0.698403 | Val Loss 0.595797
# Epoch 300 | Train Loss 0.676278 | Val Loss 0.588295
# Early stopping at epoch 374
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7709, MSE = 5.2285e-02
# Theta | train2 -> R² = 0.4891, MSE = 1.1664e-01
# Theta | test1 -> R² = 0.3089, MSE = 1.5877e-01
# Theta | test2 -> R² = 0.8542, MSE = 3.4583e-02
# Theta | test3 -> R² = 0.4368, MSE = 1.8514e-01
# Theta | val -> R² = -6.5419, MSE = 2.4683e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.012897 | Val Loss 0.842629
# Epoch 100 | Train Loss 0.712462 | Val Loss 0.593950
# Epoch 200 | Train Loss 0.693002 | Val Loss 0.589567
# Epoch 300 | Train Loss 0.655942 | Val Loss 0.627568
# Early stopping at epoch 385
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7696, MSE = 5.2590e-02
# Theta | train2 -> R² = 0.5713, MSE = 9.7866e-02
# Theta | test1 -> R² = 0.3423, MSE = 1.5109e-01
# Theta | test2 -> R² = 0.8711, MSE = 3.0579e-02
# Theta | test3 -> R² = 0.1446, MSE = 2.8121e-01
# Theta | val -> R² = -7.8356, MSE = 2.8917e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.010433 | Val Loss 0.841258
# Epoch 100 | Train Loss 0.709110 | Val Loss 0.597488
# Epoch 200 | Train Loss 0.678737 | Val Loss 0.602863
# Epoch 300 | Train Loss 0.652933 | Val Loss 0.669744
# Early stopping at epoch 381
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7794, MSE = 5.0364e-02
# Theta | train2 -> R² = 0.5784, MSE = 9.6255e-02
# Theta | test1 -> R² = 0.4616, MSE = 1.2367e-01
# Theta | test2 -> R² = 0.8775, MSE = 2.9053e-02
# Theta | test3 -> R² = -0.0192, MSE = 3.3507e-01
# Theta | val -> R² = -7.8003, MSE = 2.8802e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.011138 | Val Loss 0.841446
# Epoch 100 | Train Loss 0.717008 | Val Loss 0.583844
# Epoch 200 | Train Loss 0.700132 | Val Loss 0.586730
# Epoch 300 | Train Loss 0.674737 | Val Loss 0.588340
# Early stopping at epoch 387
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7533, MSE = 5.6312e-02
# Theta | train2 -> R² = 0.4369, MSE = 1.2855e-01
# Theta | test1 -> R² = 0.2306, MSE = 1.7674e-01
# Theta | test2 -> R² = 0.8578, MSE = 3.3714e-02
# Theta | test3 -> R² = 0.4871, MSE = 1.6862e-01
# Theta | val -> R² = -6.5115, MSE = 2.4584e+00
# Modelo [16, 8] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 1.063587 | Val Loss 0.725173
# Epoch 100 | Train Loss 0.726129 | Val Loss 0.514679
# Epoch 200 | Train Loss 0.698880 | Val Loss 0.489714
# Epoch 300 | Train Loss 0.658092 | Val Loss 0.572443
# Epoch 400 | Train Loss 0.627419 | Val Loss 0.697065
# Early stopping at epoch 488
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8808, MSE = 2.7212e-02
# Theta | train2 -> R² = 0.5289, MSE = 1.0755e-01
# Theta | test1 -> R² = 0.8249, MSE = 4.0219e-02
# Theta | test2 -> R² = 0.5111, MSE = 1.1594e-01
# Theta | test3 -> R² = 0.5219, MSE = 1.5718e-01
# Theta | val -> R² = -0.5044, MSE = 4.9238e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.074021 | Val Loss 0.998329
# Epoch 100 | Train Loss 0.728557 | Val Loss 0.529637
# Epoch 200 | Train Loss 0.713738 | Val Loss 0.480356
# Epoch 300 | Train Loss 0.697325 | Val Loss 0.469451
# Epoch 400 | Train Loss 0.652195 | Val Loss 0.592383
# Epoch 500 | Train Loss 0.630389 | Val Loss 0.748925
# Early stopping at epoch 596
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.6626, MSE = 7.7023e-02
# Theta | train2 -> R² = -0.0171, MSE = 2.3221e-01
# Theta | test1 -> R² = 0.6953, MSE = 6.9989e-02
# Theta | test2 -> R² = -0.1201, MSE = 2.6564e-01
# Theta | test3 -> R² = 0.7167, MSE = 9.3145e-02
# Theta | val -> R² = 0.8124, MSE = 6.1392e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.064615 | Val Loss 0.762305
# Epoch 100 | Train Loss 0.713682 | Val Loss 0.510323
# Epoch 200 | Train Loss 0.698997 | Val Loss 0.484311
# Epoch 300 | Train Loss 0.687069 | Val Loss 0.528428
# Epoch 400 | Train Loss 0.636747 | Val Loss 0.710024
# Epoch 500 | Train Loss 0.614642 | Val Loss 0.743505
# Early stopping at epoch 526
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7766, MSE = 5.0999e-02
# Theta | train2 -> R² = 0.3708, MSE = 1.4365e-01
# Theta | test1 -> R² = 0.8157, MSE = 4.2342e-02
# Theta | test2 -> R² = 0.3151, MSE = 1.6242e-01
# Theta | test3 -> R² = 0.3398, MSE = 2.1703e-01
# Theta | val -> R² = -0.2355, MSE = 4.0437e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.075037 | Val Loss 0.805274
# Epoch 100 | Train Loss 0.721319 | Val Loss 0.526456
# Epoch 200 | Train Loss 0.702938 | Val Loss 0.484304
# Epoch 300 | Train Loss 0.698005 | Val Loss 0.489406
# Epoch 400 | Train Loss 0.660317 | Val Loss 0.562922
# Epoch 500 | Train Loss 0.627268 | Val Loss 0.714496
# Early stopping at epoch 585
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.0335, MSE = 2.2062e-01
# Theta | train2 -> R² = -0.9220, MSE = 4.3880e-01
# Theta | test1 -> R² = 0.2997, MSE = 1.6088e-01
# Theta | test2 -> R² = -1.1083, MSE = 5.0001e-01
# Theta | test3 -> R² = 0.3234, MSE = 2.2244e-01
# Theta | val -> R² = 0.2902, MSE = 2.3230e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.064016 | Val Loss 0.773692
# Epoch 100 | Train Loss 0.720845 | Val Loss 0.525029
# Epoch 200 | Train Loss 0.704029 | Val Loss 0.496249
# Epoch 300 | Train Loss 0.692534 | Val Loss 0.492960
# Epoch 400 | Train Loss 0.642018 | Val Loss 0.674745
# Epoch 500 | Train Loss 0.618027 | Val Loss 0.721956
# Early stopping at epoch 577
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.9011, MSE = 2.2572e-02
# Theta | train2 -> R² = 0.6137, MSE = 8.8192e-02
# Theta | test1 -> R² = 0.8053, MSE = 4.4723e-02
# Theta | test2 -> R² = 0.6319, MSE = 8.7308e-02
# Theta | test3 -> R² = 0.6420, MSE = 1.1768e-01
# Theta | val -> R² = 0.3467, MSE = 2.1380e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.071563 | Val Loss 0.800254
# Epoch 100 | Train Loss 0.721396 | Val Loss 0.515997
# Epoch 200 | Train Loss 0.699357 | Val Loss 0.479828
# Epoch 300 | Train Loss 0.686108 | Val Loss 0.494104
# Epoch 400 | Train Loss 0.637450 | Val Loss 0.626361
# Epoch 500 | Train Loss 0.608751 | Val Loss 0.718979
# Early stopping at epoch 556
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.2054, MSE = 1.8139e-01
# Theta | train2 -> R² = -0.8416, MSE = 4.2045e-01
# Theta | test1 -> R² = 0.3552, MSE = 1.4812e-01
# Theta | test2 -> R² = -1.0012, MSE = 4.7460e-01
# Theta | test3 -> R² = 0.6078, MSE = 1.2895e-01
# Theta | val -> R² = 0.7882, MSE = 6.9324e-02
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.079178 | Val Loss 0.957219
# Epoch 100 | Train Loss 0.724923 | Val Loss 0.528925
# Epoch 200 | Train Loss 0.703090 | Val Loss 0.485087
# Epoch 300 | Train Loss 0.695300 | Val Loss 0.486779
# Epoch 400 | Train Loss 0.650004 | Val Loss 0.598418
# Epoch 500 | Train Loss 0.628103 | Val Loss 0.711379
# Early stopping at epoch 582
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.6116, MSE = 8.8659e-02
# Theta | train2 -> R² = -0.0798, MSE = 2.4653e-01
# Theta | test1 -> R² = 0.7144, MSE = 6.5618e-02
# Theta | test2 -> R² = -0.2240, MSE = 2.9028e-01
# Theta | test3 -> R² = 0.3599, MSE = 2.1042e-01
# Theta | val -> R² = -0.0374, MSE = 3.3954e-01
# Modelo [264, 128] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.066197 | Val Loss 0.800484
# Epoch 100 | Train Loss 0.720372 | Val Loss 0.522410
# Epoch 200 | Train Loss 0.702111 | Val Loss 0.486432
# Epoch 300 | Train Loss 0.686411 | Val Loss 0.497155
# Epoch 400 | Train Loss 0.634901 | Val Loss 0.697066
# Epoch 500 | Train Loss 0.611184 | Val Loss 0.788655
# Early stopping at epoch 578
# ...
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8580, MSE = 3.2411e-02
# Theta | train2 -> R² = 0.4664, MSE = 1.2183e-01
# Theta | test1 -> R² = 0.6610, MSE = 7.7883e-02
# Theta | test2 -> R² = 0.8127, MSE = 4.4413e-02
# Theta | test3 -> R² = 0.6216, MSE = 1.2441e-01
# Theta | val -> R² = -3.4407, MSE = 1.4534e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 1.010831 | Val Loss 0.841140
# Epoch 100 | Train Loss 0.765528 | Val Loss 0.593208
# Epoch 200 | Train Loss 0.707072 | Val Loss 0.563170
# Epoch 300 | Train Loss 0.680188 | Val Loss 0.575339
# Epoch 400 | Train Loss 0.640356 | Val Loss 0.631840
# Early stopping at epoch 445
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8576, MSE = 3.2515e-02
# Theta | train2 -> R² = 0.3510, MSE = 1.4817e-01
# Theta | test1 -> R² = 0.7032, MSE = 6.8182e-02
# Theta | test2 -> R² = 0.8171, MSE = 4.3385e-02
# Theta | test3 -> R² = 0.6807, MSE = 1.0495e-01
# Theta | val -> R² = -2.5944, MSE = 1.1764e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 1.011001 | Val Loss 0.841350
# Epoch 100 | Train Loss 0.754546 | Val Loss 0.580168
# Epoch 200 | Train Loss 0.706386 | Val Loss 0.563755
# Epoch 300 | Train Loss 0.693871 | Val Loss 0.572651
# Epoch 400 | Train Loss 0.648728 | Val Loss 0.577808
# Early stopping at epoch 445
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8047, MSE = 4.4586e-02
# Theta | train2 -> R² = 0.4184, MSE = 1.3278e-01
# Theta | test1 -> R² = 0.4462, MSE = 1.2721e-01
# Theta | test2 -> R² = 0.8410, MSE = 3.7709e-02
# Theta | test3 -> R² = 0.6454, MSE = 1.1658e-01
# Theta | val -> R² = -4.3353, MSE = 1.7461e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 1.011006 | Val Loss 0.841392
# Epoch 100 | Train Loss 0.760444 | Val Loss 0.586756
# Epoch 200 | Train Loss 0.713181 | Val Loss 0.558327
# Epoch 300 | Train Loss 0.703967 | Val Loss 0.571747
# Epoch 400 | Train Loss 0.669541 | Val Loss 0.560217
# Early stopping at epoch 471
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8646, MSE = 3.0898e-02
# Theta | train2 -> R² = 0.4568, MSE = 1.2402e-01
# Theta | test1 -> R² = 0.6780, MSE = 7.3962e-02
# Theta | test2 -> R² = 0.8215, MSE = 4.2326e-02
# Theta | test3 -> R² = 0.6400, MSE = 1.1835e-01
# Theta | val -> R² = -3.0989, MSE = 1.3415e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 1.011038 | Val Loss 0.841370
# Epoch 100 | Train Loss 0.753975 | Val Loss 0.585878
# Epoch 200 | Train Loss 0.708802 | Val Loss 0.562285
# Epoch 300 | Train Loss 0.700299 | Val Loss 0.571949
# Epoch 400 | Train Loss 0.696525 | Val Loss 0.578408
# Early stopping at epoch 487
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8015, MSE = 4.5317e-02
# Theta | train2 -> R² = 0.5270, MSE = 1.0799e-01
# Theta | test1 -> R² = 0.2578, MSE = 1.7050e-01
# Theta | test2 -> R² = 0.8120, MSE = 4.4592e-02
# Theta | test3 -> R² = 0.6040, MSE = 1.3018e-01
# Theta | val -> R² = -5.5982, MSE = 2.1595e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 1.010992 | Val Loss 0.841328
# Epoch 100 | Train Loss 0.772732 | Val Loss 0.589816
# Epoch 200 | Train Loss 0.705983 | Val Loss 0.555259
# Epoch 300 | Train Loss 0.665555 | Val Loss 0.547168
# Epoch 400 | Train Loss 0.626083 | Val Loss 0.585215
# Epoch 500 | Train Loss 0.590151 | Val Loss 0.703729
# Early stopping at epoch 571
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.9370, MSE = 1.4392e-02
# Theta | train2 -> R² = 0.5151, MSE = 1.1070e-01
# Theta | test1 -> R² = 0.7983, MSE = 4.6338e-02
# Theta | test2 -> R² = 0.9024, MSE = 2.3149e-02
# Theta | test3 -> R² = -1.0773, MSE = 6.8291e-01
# Theta | val -> R² = -2.3514, MSE = 1.0968e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 1.011050 | Val Loss 0.841196
# Epoch 100 | Train Loss 0.766629 | Val Loss 0.585248
# Epoch 200 | Train Loss 0.726121 | Val Loss 0.560299
# Epoch 300 | Train Loss 0.708609 | Val Loss 0.565145
# Epoch 400 | Train Loss 0.681510 | Val Loss 0.574225
# Early stopping at epoch 489
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.7827, MSE = 4.9601e-02
# Theta | train2 -> R² = 0.6023, MSE = 9.0795e-02
# Theta | test1 -> R² = 0.3858, MSE = 1.4108e-01
# Theta | test2 -> R² = 0.8363, MSE = 3.8830e-02
# Theta | test3 -> R² = 0.5086, MSE = 1.6154e-01
# Theta | val -> R² = -4.8427, MSE = 1.9122e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 1.010947 | Val Loss 0.841056
# Epoch 100 | Train Loss 0.764981 | Val Loss 0.594779
# Epoch 200 | Train Loss 0.709925 | Val Loss 0.557034
# Epoch 300 | Train Loss 0.698083 | Val Loss 0.566117
# Epoch 400 | Train Loss 0.668601 | Val Loss 0.581386
# Early stopping at epoch 488
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8566, MSE = 3.2730e-02
# Theta | train2 -> R² = 0.4883, MSE = 1.1683e-01
# Theta | test1 -> R² = 0.6416, MSE = 8.2325e-02
# Theta | test2 -> R² = 0.8624, MSE = 3.2633e-02
# Theta | test3 -> R² = 0.6360, MSE = 1.1966e-01
# Theta | val -> R² = -3.3027, MSE = 1.4082e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 1.011036 | Val Loss 0.841272
# Epoch 100 | Train Loss 0.771022 | Val Loss 0.594654
# Epoch 200 | Train Loss 0.712568 | Val Loss 0.557186
# Epoch 300 | Train Loss 0.686116 | Val Loss 0.563371
# Epoch 400 | Train Loss 0.650027 | Val Loss 0.603495
# Early stopping at epoch 492
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.8647, MSE = 3.0876e-02
# Theta | train2 -> R² = 0.4087, MSE = 1.3499e-01
# Theta | test1 -> R² = 0.5847, MSE = 9.5401e-02
# Theta | test2 -> R² = 0.8558, MSE = 3.4208e-02
# Theta | test3 -> R² = 0.6616, MSE = 1.1124e-01
# Theta | val -> R² = -3.8580, MSE = 1.5899e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 1.010999 | Val Loss 0.841140
# Epoch 100 | Train Loss 0.756148 | Val Loss 0.589929
# Epoch 200 | Train Loss 0.720916 | Val Loss 0.569194
# Epoch 300 | Train Loss 0.707149 | Val Loss 0.570874
# Epoch 400 | Train Loss 0.704184 | Val Loss 0.581861
# Epoch 500 | Train Loss 0.701893 | Val Loss 0.586861
# Early stopping at epoch 525
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# WARNING:tensorflow:Model's `__init__()` arguments contain non-serializable objects. Please implement a `get_config()` method in the subclassed Model for proper saving and loading. Defaulting to empty config.
# Theta | train1 -> R² = 0.6625, MSE = 7.7050e-02
# Theta | train2 -> R² = 0.5552, MSE = 1.0156e-01
# Theta | test1 -> R² = -0.1162, MSE = 2.5642e-01
# Theta | test2 -> R² = 0.7384, MSE = 6.2030e-02
# Theta | test3 -> R² = 0.4717, MSE = 1.7368e-01
# Theta | val -> R² = -7.3556, MSE = 2.7346e+00
# Modelo [16, 8, 4] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
