# %% [markdown]
# # RNN
# - 2 Entradas PwmD, PwmE
# - 1 Saida $\Delta \theta $
# - 1 Camada
# - n neurônios

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
# Train = pd.concat([Train1, Train2], ignore_index=True)
Train = Train1

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (973, 3, 2)
# Dimensão da saida: (973, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def PlotOut(ax, title, target_name, y_true, y_pred):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true, marker='o', s=12, label='Amostras Reais', alpha=0.7)
    ax.scatter(time, y_pred, marker='x', s=12, label='Valores Preditos', alpha=0.7)
    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_targets = len(TARGET)

    metrics = {name: {"R2_train1": [], "R2_train2": [],
                      "R2_test1": [], "R2_test2": [],
                      "R2_test3": [],"R2_val": [],
                      "MSE_train1": [], "MSE_train2": [],
                      "MSE_test1": [], "MSE_test2": [],
                      "MSE_test3": [], "MSE_val": [],} for name in TARGET_INT}

    for i, dataset in enumerate(NormDatasets):
        x = dataset[PREDICTORS]
        y = dataset[TARGET]
        x, y = CreateSequences(x, y, TIME_STEPS)

        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        y_diff = OUT_SCALER.inverse_transform(y)
        
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)

        # valores iniciais reais (não normalizados)
        init_vals = np.array([
            Datasets[i]["Theta"].iloc[0],
            Datasets[i]["X"].iloc[0],
            Datasets[i]["Y"].iloc[0]
        ])

        # reconstrução cumulativa saída a saída
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)


        # Calcula métricas por saída
        for j, name in enumerate(TARGET_INT):
            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])
            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, MSE = {mse:.4e}")
            
    # Retorna métricas médias para análise posterior
    return metrics

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras import initializers
from keras import regularizers
from itertools import product

# tamanho da entrada
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET) 
N_MODELS = 5  # número de inicializações

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

# arquiteturas das camadas ocultas
architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

for arch,  r in product(architectures, r_values):
    for i, s in enumerate(seeds):

        initializer = initializers.RandomNormal(seed=int(s))
        regularizer = regularizers.l2(r)

        model = keras.models.Sequential()
        model.add(keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

        # adiciona camadas RNN
        for j, n in enumerate(arch):

            # se não for a última camada RNN
            if j < len(arch) - 1:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada de saída
        model.add(
            keras.layers.Dense(
                OUTPUT_SIZE,
                activation="linear",
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )
        # salva pesos iniciais
        w0 = model.get_weights()

        # compila
        model.compile(loss="mean_squared_error", optimizer="adam")
        early_stopping_monitor = EarlyStopping(
            monitor='val_loss',
            patience=50,
            restore_best_weights=True
        )

        history = model.fit(
            x_train, 
            y_train, 
            epochs=1000,
            callbacks=[early_stopping_monitor],
            validation_data=(x_val, y_val),
            verbose=0
        )
        
    
        # salva pesos finais
        wf = model.get_weights()

       # avalia o modelo
        metrics = EvalModel(model)


        row = {
            "model": f"model_{n}_{i}",
            "Neurons": n,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9628, MSE = 4.0095e-03
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.2425, MSE = 1.8895e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9402, MSE = 6.2689e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2862, MSE = 1.8814e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.9093, MSE = 8.3471e-03
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.9393, MSE = 5.8084e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# X | train1 -> R² = 0.9559, MSE = 4.7498e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2428, MSE = 1.8898e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = 0.9230, MSE = 8.0670e-03
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.2844, MSE = 1.8799e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.9077, MSE = 8.4895e-03
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.9236, MSE = 7.3100e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.9590, MSE = 4.4181e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2369, MSE = 1.8848e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.9287, MSE = 7.4669e-03
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2789, MSE = 1.8754e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.9113, MSE = 8.1620e-03
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.9289, MSE = 6.8002e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.9466, MSE = 5.7546e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.1911, MSE = 1.8462e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.9087, MSE = 9.5654e-03
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.2332, MSE = 1.8378e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.8983, MSE = 9.3533e-03
# 40/40 [==============================] - 1s 5ms/step
# X | val -> R² = 0.9089, MSE = 8.7123e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9661, MSE = 3.6573e-03
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.2560, MSE = 1.9009e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9496, MSE = 5.2766e-03
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2989, MSE = 1.8918e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.9048, MSE = 8.7590e-03
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.9456, MSE = 5.2036e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.8103, MSE = 2.0460e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1493, MSE = 1.8110e-01
# 31/31 [==============================] - 0s 8ms/step
# X | test1 -> R² = 0.6880, MSE = 3.2687e-02
# 31/31 [==============================] - 1s 11ms/step
# X | test2 -> R² = -1.1728, MSE = 1.7881e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.6308, MSE = 3.3969e-02
# 40/40 [==============================] - 1s 8ms/step
# X | val -> R² = 0.5536, MSE = 4.2682e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.7136, MSE = 3.0887e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1088, MSE = 1.7769e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.5635, MSE = 4.5727e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.1414, MSE = 1.7622e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.4163, MSE = 5.3700e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.3279, MSE = 6.4264e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.7785, MSE = 2.3881e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1599, MSE = 1.8200e-01
# 31/31 [==============================] - 1s 4ms/step
# X | test1 -> R² = 0.6480, MSE = 3.6878e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.1892, MSE = 1.8016e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.5466, MSE = 4.1711e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.4689, MSE = 5.0785e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.8215, MSE = 1.9251e-02
# 31/31 [==============================] - 0s 11ms/step
# X | train2 -> R² = -1.0668, MSE = 1.7415e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.7103, MSE = 3.0345e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.0879, MSE = 1.7182e-01
# 45/45 [==============================] - 1s 6ms/step
# X | test3 -> R² = 0.6863, MSE = 2.8866e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.6205, MSE = 3.6294e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.8107, MSE = 2.0416e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.2051, MSE = 1.8581e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.6812, MSE = 3.3402e-02
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.2271, MSE = 1.8327e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.6105, MSE = 3.5832e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.5223, MSE = 4.5675e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# X | train1 -> R² = 0.5833, MSE = 4.4933e-02
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.1127, MSE = 1.7802e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = 0.3923, MSE = 6.3662e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.1539, MSE = 1.7725e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.1461, MSE = 7.8561e-02
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = 0.0448, MSE = 9.1337e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# X | train1 -> R² = 0.4859, MSE = 5.5432e-02
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2197, MSE = 1.8703e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = 0.2641, MSE = 7.7095e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2745, MSE = 1.8718e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -0.2054, MSE = 1.1090e-01
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = -0.2877, MSE = 1.2313e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.5218, MSE = 5.1559e-02
# 31/31 [==============================] - 0s 3ms/step
# X | train2 -> R² = -1.0944, MSE = 1.7647e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = 0.3155, MSE = 7.1706e-02
# 31/31 [==============================] - 0s 3ms/step
# X | test2 -> R² = -1.1412, MSE = 1.7621e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = -0.0149, MSE = 9.3373e-02
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = -0.1183, MSE = 1.0693e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.6472, MSE = 3.8041e-02
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.1822, MSE = 1.8387e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.4573, MSE = 5.6855e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2156, MSE = 1.8233e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.2906, MSE = 6.5263e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.1598, MSE = 8.0345e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.7325, MSE = 2.8845e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1531, MSE = 1.8142e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.5740, MSE = 4.4629e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.1779, MSE = 1.7923e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.4960, MSE = 4.6373e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.3826, MSE = 5.9034e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# X | train1 -> R² = 0.9649, MSE = 3.7863e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2621, MSE = 1.9061e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = 0.9427, MSE = 5.9993e-03
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.3069, MSE = 1.8984e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.9121, MSE = 8.0908e-03
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = 0.9428, MSE = 5.4727e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9621, MSE = 4.0857e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2687, MSE = 1.9116e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.9350, MSE = 6.8138e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.3131, MSE = 1.9035e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.9137, MSE = 7.9372e-03
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = 0.9362, MSE = 6.1053e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.9542, MSE = 4.9386e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2292, MSE = 1.8784e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.9201, MSE = 8.3756e-03
# 31/31 [==============================] - 0s 3ms/step
# X | test2 -> R² = -1.2731, MSE = 1.8706e-01
# 45/45 [==============================] - 1s 4ms/step
# X | test3 -> R² = 0.9081, MSE = 8.4522e-03
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.9219, MSE = 7.4722e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.9531, MSE = 5.0615e-03
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1624, MSE = 1.8220e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9268, MSE = 7.6728e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2057, MSE = 1.8151e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.8973, MSE = 9.4524e-03
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.9264, MSE = 7.0407e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9499, MSE = 5.4052e-03
# 31/31 [==============================] - 1s 4ms/step
# X | train2 -> R² = -1.1959, MSE = 1.8503e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9141, MSE = 8.9942e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2381, MSE = 1.8418e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.9021, MSE = 9.0049e-03
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.9167, MSE = 7.9653e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.7893, MSE = 2.2720e-02
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.1779, MSE = 1.8351e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.6739, MSE = 3.4160e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.2118, MSE = 1.8202e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.6000, MSE = 3.6806e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.5390, MSE = 4.4083e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.7406, MSE = 2.7968e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.2647, MSE = 1.9083e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.6055, MSE = 4.1325e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.3038, MSE = 1.8959e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.4558, MSE = 5.0071e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.3917, MSE = 5.8170e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.8223, MSE = 1.9165e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1832, MSE = 1.8396e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.7133, MSE = 3.0035e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2119, MSE = 1.8203e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.6723, MSE = 3.0147e-02
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.6072, MSE = 3.7561e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9307, MSE = 7.4671e-03
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.2158, MSE = 1.8670e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.8675, MSE = 1.3881e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2284, MSE = 1.8338e-01
# 45/45 [==============================] - 1s 5ms/step
# X | test3 -> R² = 0.8631, MSE = 1.2598e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.8611, MSE = 1.3283e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.8497, MSE = 1.6208e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.0889, MSE = 1.7601e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.7557, MSE = 2.5597e-02
# 31/31 [==============================] - 1s 6ms/step
# X | test2 -> R² = -1.1127, MSE = 1.7386e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.7492, MSE = 2.3074e-02
# 40/40 [==============================] - 1s 6ms/step
# X | val -> R² = 0.7005, MSE = 2.8636e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.8759, MSE = 1.3377e-02
# 31/31 [==============================] - 1s 6ms/step
# X | train2 -> R² = -1.1919, MSE = 1.8469e-01
# 31/31 [==============================] - 1s 6ms/step
# X | test1 -> R² = 0.7796, MSE = 2.3090e-02
# 31/31 [==============================] - 1s 7ms/step
# X | test2 -> R² = -1.2070, MSE = 1.8162e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.7975, MSE = 1.8635e-02
# 40/40 [==============================] - 1s 5ms/step
# X | val -> R² = 0.7468, MSE = 2.4214e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.8276, MSE = 1.8586e-02
# 31/31 [==============================] - 0s 3ms/step
# X | train2 -> R² = -1.1081, MSE = 1.7763e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.7188, MSE = 2.9458e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.1298, MSE = 1.7527e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.7123, MSE = 2.6470e-02
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = 0.6489, MSE = 3.3576e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.7162, MSE = 3.0605e-02
# 31/31 [==============================] - 1s 11ms/step
# X | train2 -> R² = -1.2510, MSE = 1.8967e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.5627, MSE = 4.5816e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2857, MSE = 1.8810e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.4161, MSE = 5.3719e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.3253, MSE = 6.4515e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.8212, MSE = 1.9280e-02
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.1203, MSE = 1.7866e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.7062, MSE = 3.0783e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.1402, MSE = 1.7612e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.7050, MSE = 2.7141e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.6338, MSE = 3.5016e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = 0.7836, MSE = 2.3329e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1766, MSE = 1.8340e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.6548, MSE = 3.6164e-02
# 31/31 [==============================] - 0s 9ms/step
# X | test2 -> R² = -1.2028, MSE = 1.8128e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.6120, MSE = 3.5694e-02
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = 0.5275, MSE = 4.5178e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.9543, MSE = 4.9237e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1749, MSE = 1.8325e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9267, MSE = 7.6752e-03
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2195, MSE = 1.8265e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = 0.9022, MSE = 8.9939e-03
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.9290, MSE = 6.7895e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.9563, MSE = 4.7147e-03
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.2465, MSE = 1.8929e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9232, MSE = 8.0429e-03
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2917, MSE = 1.8859e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.9116, MSE = 8.1287e-03
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.9258, MSE = 7.0944e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.9607, MSE = 4.2367e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.2139, MSE = 1.8654e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9444, MSE = 5.8206e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2597, MSE = 1.8596e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.8934, MSE = 9.8074e-03
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.9384, MSE = 5.8928e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9650, MSE = 3.7689e-03
# 31/31 [==============================] - 0s 10ms/step
# X | train2 -> R² = -1.2754, MSE = 1.9173e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9414, MSE = 6.1347e-03
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.3207, MSE = 1.9098e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.9151, MSE = 7.8103e-03
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.9420, MSE = 5.5439e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.9587, MSE = 4.4544e-03
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.2540, MSE = 1.8992e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.9308, MSE = 7.2452e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.3000, MSE = 1.8927e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.9101, MSE = 8.2721e-03
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.9306, MSE = 6.6315e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.8961, MSE = 1.1208e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1125, MSE = 1.7800e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.8266, MSE = 1.8166e-02
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.1409, MSE = 1.7618e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.8269, MSE = 1.5927e-02
# 40/40 [==============================] - 1s 6ms/step
# X | val -> R² = 0.8072, MSE = 1.8437e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.9089, MSE = 9.8183e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1577, MSE = 1.8181e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.8419, MSE = 1.6562e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.1836, MSE = 1.7970e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.8442, MSE = 1.4338e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.8260, MSE = 1.6634e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# X | train1 -> R² = 0.9331, MSE = 7.2176e-03
# 31/31 [==============================] - 1s 6ms/step
# X | train2 -> R² = -1.2398, MSE = 1.8872e-01
# 31/31 [==============================] - 1s 8ms/step
# X | test1 -> R² = 0.8760, MSE = 1.2990e-02
# 31/31 [==============================] - 1s 9ms/step
# X | test2 -> R² = -1.2666, MSE = 1.8652e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.8760, MSE = 1.1411e-02
# 40/40 [==============================] - 1s 6ms/step
# X | val -> R² = 0.8668, MSE = 1.2741e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = 0.9128, MSE = 9.4042e-03
# 31/31 [==============================] - 0s 10ms/step
# X | train2 -> R² = -1.1719, MSE = 1.8300e-01
# 31/31 [==============================] - 1s 7ms/step
# X | test1 -> R² = 0.8487, MSE = 1.5850e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.1988, MSE = 1.8095e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.8491, MSE = 1.3884e-02
# 40/40 [==============================] - 1s 5ms/step
# X | val -> R² = 0.8327, MSE = 1.5995e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.8868, MSE = 1.2205e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1903, MSE = 1.8455e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.8080, MSE = 2.0110e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.2189, MSE = 1.8260e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.8040, MSE = 1.8034e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.7674, MSE = 2.2239e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = 0.8209, MSE = 1.9309e-02
# 31/31 [==============================] - 0s 3ms/step
# X | train2 -> R² = -1.0530, MSE = 1.7299e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.7221, MSE = 2.9115e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.0808, MSE = 1.7123e-01
# 45/45 [==============================] - 1s 6ms/step
# X | test3 -> R² = 0.7102, MSE = 2.6663e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.6655, MSE = 3.1982e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.8816, MSE = 1.2769e-02
# 31/31 [==============================] - 1s 6ms/step
# X | train2 -> R² = -1.1184, MSE = 1.7850e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.8012, MSE = 2.0832e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.1425, MSE = 1.7631e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.8077, MSE = 1.7694e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.7767, MSE = 2.1355e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.9057, MSE = 1.0165e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.2141, MSE = 1.8656e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.8302, MSE = 1.7784e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2353, MSE = 1.8395e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.8400, MSE = 1.4718e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.8110, MSE = 1.8070e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.8162, MSE = 1.9815e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.0325, MSE = 1.7126e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.7209, MSE = 2.9235e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.0625, MSE = 1.6973e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.7044, MSE = 2.7201e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.6646, MSE = 3.2068e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# X | train1 -> R² = 0.8250, MSE = 1.8866e-02
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.1962, MSE = 1.8505e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = 0.7186, MSE = 2.9485e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2254, MSE = 1.8313e-01
# 45/45 [==============================] - 1s 5ms/step
# X | test3 -> R² = 0.6926, MSE = 2.8286e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.6306, MSE = 3.5318e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 8ms/step
# X | train1 -> R² = 0.9507, MSE = 5.3106e-03
# 31/31 [==============================] - 1s 9ms/step
# X | train2 -> R² = -1.1983, MSE = 1.8523e-01
# 31/31 [==============================] - 0s 8ms/step
# X | test1 -> R² = 0.9177, MSE = 8.6219e-03
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2433, MSE = 1.8461e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.9034, MSE = 8.8873e-03
# 40/40 [==============================] - 1s 9ms/step
# X | val -> R² = 0.9206, MSE = 7.5888e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = 0.9491, MSE = 5.4911e-03
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.1872, MSE = 1.8429e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9161, MSE = 8.7875e-03
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2319, MSE = 1.8367e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.9004, MSE = 9.1652e-03
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.9182, MSE = 7.8219e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.9529, MSE = 5.0800e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.2531, MSE = 1.8985e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9178, MSE = 8.6117e-03
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.2987, MSE = 1.8916e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.9080, MSE = 8.4669e-03
# 40/40 [==============================] - 0s 8ms/step
# X | val -> R² = 0.9190, MSE = 7.7502e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# X | train1 -> R² = 0.9433, MSE = 6.1084e-03
# 31/31 [==============================] - 0s 8ms/step
# X | train2 -> R² = -1.2215, MSE = 1.8718e-01
# 31/31 [==============================] - 0s 8ms/step
# X | test1 -> R² = 0.9030, MSE = 1.0160e-02
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.2668, MSE = 1.8654e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.8967, MSE = 9.5081e-03
# 40/40 [==============================] - 1s 10ms/step
# X | val -> R² = 0.9028, MSE = 9.2938e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# X | train1 -> R² = 0.9515, MSE = 5.2335e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1633, MSE = 1.8228e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9228, MSE = 8.0866e-03
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.2073, MSE = 1.8165e-01
# 45/45 [==============================] - 1s 9ms/step
# X | test3 -> R² = 0.8981, MSE = 9.3788e-03
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.9239, MSE = 7.2751e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 7ms/step
# X | train1 -> R² = 0.9243, MSE = 8.1651e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2010, MSE = 1.8546e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.8645, MSE = 1.4198e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2292, MSE = 1.8345e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = 0.8650, MSE = 1.2420e-02
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = 0.8530, MSE = 1.4054e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# X | train1 -> R² = 0.8844, MSE = 1.2467e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1543, MSE = 1.8153e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.8080, MSE = 2.0119e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.1853, MSE = 1.7983e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.8055, MSE = 1.7892e-02
# 40/40 [==============================] - 1s 9ms/step
# X | val -> R² = 0.7771, MSE = 2.1311e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.9228, MSE = 8.3210e-03
# 31/31 [==============================] - 1s 10ms/step
# X | train2 -> R² = -1.1686, MSE = 1.8272e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.8638, MSE = 1.4264e-02
# 31/31 [==============================] - 1s 8ms/step
# X | test2 -> R² = -1.1961, MSE = 1.8073e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = 0.8636, MSE = 1.2550e-02
# 40/40 [==============================] - 1s 7ms/step
# X | val -> R² = 0.8559, MSE = 1.3780e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.9129, MSE = 9.3871e-03
# 31/31 [==============================] - 0s 10ms/step
# X | train2 -> R² = -1.1293, MSE = 1.7942e-01
# 31/31 [==============================] - 1s 5ms/step
# X | test1 -> R² = 0.8524, MSE = 1.5463e-02
# 31/31 [==============================] - 1s 9ms/step
# X | test2 -> R² = -1.1589, MSE = 1.7767e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.8522, MSE = 1.3600e-02
# 40/40 [==============================] - 1s 9ms/step
# X | val -> R² = 0.8426, MSE = 1.5050e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = 0.9037, MSE = 1.0384e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1660, MSE = 1.8250e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.8371, MSE = 1.7070e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.1969, MSE = 1.8079e-01
# 45/45 [==============================] - 1s 6ms/step
# X | test3 -> R² = 0.8360, MSE = 1.5089e-02
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.8148, MSE = 1.7706e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.9406, MSE = 6.4006e-03
# 31/31 [==============================] - 0s 8ms/step
# X | train2 -> R² = -1.1862, MSE = 1.8421e-01
# 31/31 [==============================] - 0s 8ms/step
# X | test1 -> R² = 0.8945, MSE = 1.1053e-02
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.2088, MSE = 1.8177e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.8705, MSE = 1.1918e-02
# 40/40 [==============================] - 1s 6ms/step
# X | val -> R² = 0.8945, MSE = 1.0090e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# X | train1 -> R² = 0.9524, MSE = 5.1296e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.2741, MSE = 1.9161e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9068, MSE = 9.7686e-03
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2941, MSE = 1.8879e-01
# 45/45 [==============================] - 1s 10ms/step
# X | test3 -> R² = 0.8900, MSE = 1.0122e-02
# 40/40 [==============================] - 1s 10ms/step
# X | val -> R² = 0.9098, MSE = 8.6210e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# X | train1 -> R² = 0.9564, MSE = 4.7050e-03
# 31/31 [==============================] - 0s 9ms/step
# X | train2 -> R² = -1.2662, MSE = 1.9095e-01
# 31/31 [==============================] - 1s 10ms/step
# X | test1 -> R² = 0.9278, MSE = 7.5599e-03
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.2876, MSE = 1.8825e-01
# 45/45 [==============================] - 1s 9ms/step
# X | test3 -> R² = 0.8483, MSE = 1.3961e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.9202, MSE = 7.6331e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.8857, MSE = 1.2328e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.0786, MSE = 1.7515e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.8114, MSE = 1.9760e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.1034, MSE = 1.7310e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = 0.8178, MSE = 1.6760e-02
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.7969, MSE = 1.9423e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.8240, MSE = 1.8974e-02
# 31/31 [==============================] - 1s 10ms/step
# X | train2 -> R² = -1.1408, MSE = 1.8038e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.7247, MSE = 2.8841e-02
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.1719, MSE = 1.7873e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.7046, MSE = 2.7174e-02
# 40/40 [==============================] - 1s 9ms/step
# X | val -> R² = 0.6558, MSE = 3.2913e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# X | train1 -> R² = 0.9473, MSE = 5.6868e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.1747, MSE = 1.8324e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9055, MSE = 9.9034e-03
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.2054, MSE = 1.8149e-01
# 45/45 [==============================] - 1s 6ms/step
# X | test3 -> R² = 0.8624, MSE = 1.2656e-02
# 40/40 [==============================] - 1s 7ms/step
# X | val -> R² = 0.8560, MSE = 1.3766e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 4s 8ms/step
# X | train1 -> R² = 0.9484, MSE = 5.5644e-03
# 31/31 [==============================] - 1s 6ms/step
# X | train2 -> R² = -1.2068, MSE = 1.8595e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.9041, MSE = 1.0050e-02
# 31/31 [==============================] - 1s 6ms/step
# X | test2 -> R² = -1.2393, MSE = 1.8428e-01
# 45/45 [==============================] - 1s 7ms/step
# X | test3 -> R² = 0.7931, MSE = 1.9038e-02
# 40/40 [==============================] - 1s 8ms/step
# X | val -> R² = 0.7816, MSE = 2.0888e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# X | train1 -> R² = 0.9533, MSE = 5.0316e-03
# 31/31 [==============================] - 0s 3ms/step
# X | train2 -> R² = -1.2011, MSE = 1.8546e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9150, MSE = 8.9014e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2295, MSE = 1.8347e-01
# 45/45 [==============================] - 0s 3ms/step
# X | test3 -> R² = 0.8663, MSE = 1.2298e-02
# 40/40 [==============================] - 0s 3ms/step
# X | val -> R² = 0.8591, MSE = 1.3476e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 4s 9ms/step
# X | train1 -> R² = 0.9533, MSE = 5.0301e-03
# 31/31 [==============================] - 1s 7ms/step
# X | train2 -> R² = -1.3670, MSE = 1.9944e-01
# 31/31 [==============================] - 1s 8ms/step
# X | test1 -> R² = 0.9579, MSE = 4.4136e-03
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.3819, MSE = 1.9601e-01
# 45/45 [==============================] - 1s 5ms/step
# X | test3 -> R² = 0.9001, MSE = 9.1888e-03
# 40/40 [==============================] - 1s 7ms/step
# X | val -> R² = 0.9451, MSE = 5.2475e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.9542, MSE = 4.9407e-03
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.2101, MSE = 1.8623e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.9155, MSE = 8.8568e-03
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.2365, MSE = 1.8405e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.8728, MSE = 1.1700e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.8659, MSE = 1.2821e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = -2.3706, MSE = 3.6343e-01
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.5145, MSE = 2.1187e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = -2.4598, MSE = 3.6245e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.4989, MSE = 2.0565e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -2.8409, MSE = 3.5338e-01
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = -2.8144, MSE = 3.6475e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = -2.3780, MSE = 3.6423e-01
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.5234, MSE = 2.1262e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = -2.4674, MSE = 3.6325e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.5079, MSE = 2.0638e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -2.8527, MSE = 3.5447e-01
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = -2.8246, MSE = 3.6572e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = -2.3821, MSE = 3.6467e-01
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.5283, MSE = 2.1303e-01
# 31/31 [==============================] - 0s 3ms/step
# X | test1 -> R² = -2.4717, MSE = 3.6370e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.5128, MSE = 2.0679e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -2.8593, MSE = 3.5507e-01
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = -2.8302, MSE = 3.6626e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# X | train1 -> R² = 0.5185, MSE = 5.1923e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -0.8767, MSE = 1.5814e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = 0.2160, MSE = 8.2128e-02
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -0.9115, MSE = 1.5730e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = -0.2211, MSE = 1.1234e-01
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = -0.4971, MSE = 1.4316e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.4176, MSE = 6.2797e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -0.8532, MSE = 1.5615e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.1124, MSE = 9.2982e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -0.9098, MSE = 1.5717e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -0.7582, MSE = 1.6176e-01
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = -0.9504, MSE = 1.8650e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# X | train1 -> R² = -2.3829, MSE = 3.6477e-01
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.5293, MSE = 2.1312e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = -2.4726, MSE = 3.6379e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.5139, MSE = 2.0688e-01
# 45/45 [==============================] - 1s 12ms/step
# X | test3 -> R² = -2.8607, MSE = 3.5520e-01
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = -2.8315, MSE = 3.6638e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = -2.3775, MSE = 3.6418e-01
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.5229, MSE = 2.1258e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = -2.4670, MSE = 3.6320e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.5073, MSE = 2.0634e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = -2.8520, MSE = 3.5440e-01
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = -2.8240, MSE = 3.6566e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = -2.3781, MSE = 3.6425e-01
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.5236, MSE = 2.1264e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = -2.4676, MSE = 3.6327e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.5081, MSE = 2.0640e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = -2.8530, MSE = 3.5449e-01
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = -2.8248, MSE = 3.6574e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# X | train1 -> R² = -2.3805, MSE = 3.6451e-01
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.5264, MSE = 2.1288e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = -2.4701, MSE = 3.6353e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.5109, MSE = 2.0663e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = -2.8568, MSE = 3.5484e-01
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = -2.8281, MSE = 3.6606e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# X | train1 -> R² = -2.3833, MSE = 3.6481e-01
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.5298, MSE = 2.1316e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test1 -> R² = -2.4730, MSE = 3.6383e-01
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.5143, MSE = 2.0691e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -2.8613, MSE = 3.5525e-01
# 40/40 [==============================] - 0s 4ms/step
# X | val -> R² = -2.8320, MSE = 3.6642e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = 0.9460, MSE = 5.8233e-03
# 31/31 [==============================] - 1s 6ms/step
# X | train2 -> R² = -1.1751, MSE = 1.8327e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9065, MSE = 9.7953e-03
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2116, MSE = 1.8200e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = 0.8796, MSE = 1.1076e-02
# 40/40 [==============================] - 1s 6ms/step
# X | val -> R² = 0.8799, MSE = 1.1481e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# X | train1 -> R² = 0.9379, MSE = 6.6950e-03
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.1735, MSE = 1.8314e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.8926, MSE = 1.1252e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.2129, MSE = 1.8210e-01
# 45/45 [==============================] - 0s 5ms/step
# X | test3 -> R² = 0.8623, MSE = 1.2665e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.8576, MSE = 1.3618e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 7ms/step
# X | train1 -> R² = 0.9632, MSE = 3.9726e-03
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.2644, MSE = 1.9080e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.9357, MSE = 6.7369e-03
# 31/31 [==============================] - 0s 4ms/step
# X | test2 -> R² = -1.2997, MSE = 1.8925e-01
# 45/45 [==============================] - 0s 8ms/step
# X | test3 -> R² = 0.9085, MSE = 8.4184e-03
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.9175, MSE = 7.8872e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 3s 4ms/step
# X | train1 -> R² = 0.9441, MSE = 6.0297e-03
# ...
# X | train1 -> R² = 0.9426, MSE = 6.1855e-03
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.1981, MSE = 1.8521e-01
# 31/31 [==============================] - 0s 9ms/step
# X | test1 -> R² = 0.8986, MSE = 1.0627e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2355, MSE = 1.8397e-01
# 45/45 [==============================] - 1s 12ms/step
# X | test3 -> R² = 0.8802, MSE = 1.1023e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.8780, MSE = 1.1669e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.6549, MSE = 3.7213e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.0273, MSE = 1.7082e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = 0.4292, MSE = 5.9796e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.0594, MSE = 1.6947e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.3134, MSE = 6.3175e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = -0.0545, MSE = 1.0083e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 4s 7ms/step
# X | train1 -> R² = 0.8991, MSE = 1.0878e-02
# 31/31 [==============================] - 0s 8ms/step
# X | train2 -> R² = -1.2790, MSE = 1.9203e-01
# 31/31 [==============================] - 0s 9ms/step
# X | test1 -> R² = 0.7600, MSE = 2.5137e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.2515, MSE = 1.8528e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = 0.7155, MSE = 2.6175e-02
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.4356, MSE = 5.3967e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.9033, MSE = 1.0424e-02
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.2195, MSE = 1.8702e-01
# 31/31 [==============================] - 0s 11ms/step
# X | test1 -> R² = 0.8729, MSE = 1.3317e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.1814, MSE = 1.7951e-01
# 45/45 [==============================] - 1s 9ms/step
# X | test3 -> R² = 0.7685, MSE = 2.1300e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.7449, MSE = 2.4393e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# X | train1 -> R² = -0.0117, MSE = 1.0909e-01
# 31/31 [==============================] - 0s 4ms/step
# X | train2 -> R² = -1.5325, MSE = 2.1339e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = -0.4181, MSE = 1.4856e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.6540, MSE = 2.1841e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = -0.9234, MSE = 1.7696e-01
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = -1.2231, MSE = 2.1258e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.6784, MSE = 3.4673e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -0.9541, MSE = 1.6465e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.4657, MSE = 5.5971e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -0.9798, MSE = 1.6292e-01
# 45/45 [==============================] - 0s 8ms/step
# X | test3 -> R² = 0.0281, MSE = 8.9415e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = -0.3031, MSE = 1.2461e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 7ms/step
# X | train1 -> R² = 0.7198, MSE = 3.0217e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -0.8132, MSE = 1.5278e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.5425, MSE = 4.7925e-02
# 31/31 [==============================] - 0s 9ms/step
# X | test2 -> R² = -0.8267, MSE = 1.5033e-01
# 45/45 [==============================] - 0s 4ms/step
# X | test3 -> R² = -0.1410, MSE = 1.0498e-01
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = -0.3280, MSE = 1.2699e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# X | train1 -> R² = 0.2710, MSE = 7.8601e-02
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.2220, MSE = 1.8723e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = -0.0648, MSE = 1.1155e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.3030, MSE = 1.8952e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.1847, MSE = 7.5009e-02
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = -0.1961, MSE = 1.1438e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# X | train1 -> R² = 0.8259, MSE = 1.8767e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.0243, MSE = 1.7057e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test1 -> R² = 0.6709, MSE = 3.4479e-02
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.0158, MSE = 1.6589e-01
# 45/45 [==============================] - 0s 6ms/step
# X | test3 -> R² = 0.5263, MSE = 4.3578e-02
# 40/40 [==============================] - 0s 5ms/step
# X | val -> R² = 0.3430, MSE = 6.2824e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# X | train1 -> R² = 0.7719, MSE = 2.4593e-02
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.0047, MSE = 1.6892e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.5779, MSE = 4.4218e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -0.9998, MSE = 1.6457e-01
# 45/45 [==============================] - 0s 8ms/step
# X | test3 -> R² = 0.4776, MSE = 4.8059e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.1941, MSE = 7.7061e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 9ms/step
# X | train1 -> R² = 0.6568, MSE = 3.7006e-02
# 31/31 [==============================] - 0s 8ms/step
# X | train2 -> R² = -1.1197, MSE = 1.7861e-01
# 31/31 [==============================] - 0s 8ms/step
# X | test1 -> R² = 0.4081, MSE = 6.2005e-02
# 31/31 [==============================] - 0s 10ms/step
# X | test2 -> R² = -1.1403, MSE = 1.7614e-01
# 45/45 [==============================] - 1s 8ms/step
# X | test3 -> R² = -0.5447, MSE = 1.4211e-01
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = -0.7006, MSE = 1.6262e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 10ms/step
# X | train1 -> R² = 0.9623, MSE = 4.0596e-03
# 31/31 [==============================] - 1s 15ms/step
# X | train2 -> R² = -1.2467, MSE = 1.8931e-01
# 31/31 [==============================] - 1s 19ms/step
# X | test1 -> R² = 0.9477, MSE = 5.4836e-03
# 31/31 [==============================] - 0s 12ms/step
# X | test2 -> R² = -1.2827, MSE = 1.8785e-01
# 45/45 [==============================] - 1s 19ms/step
# X | test3 -> R² = 0.8894, MSE = 1.0174e-02
# 40/40 [==============================] - 1s 12ms/step
# X | val -> R² = 0.9386, MSE = 5.8732e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.9628, MSE = 4.0083e-03
# 31/31 [==============================] - 0s 7ms/step
# X | train2 -> R² = -1.2901, MSE = 1.9296e-01
# 31/31 [==============================] - 0s 11ms/step
# X | test1 -> R² = 0.9579, MSE = 4.4099e-03
# 31/31 [==============================] - 0s 13ms/step
# X | test2 -> R² = -1.3284, MSE = 1.9161e-01
# 45/45 [==============================] - 0s 8ms/step
# X | test3 -> R² = 0.8909, MSE = 1.0037e-02
# 40/40 [==============================] - 1s 12ms/step
# X | val -> R² = 0.9453, MSE = 5.2260e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 11ms/step
# X | train1 -> R² = 0.9269, MSE = 7.8795e-03
# 31/31 [==============================] - 0s 10ms/step
# X | train2 -> R² = -1.1909, MSE = 1.8461e-01
# 31/31 [==============================] - 0s 10ms/step
# X | test1 -> R² = 0.8743, MSE = 1.3170e-02
# 31/31 [==============================] - 1s 9ms/step
# X | test2 -> R² = -1.2324, MSE = 1.8371e-01
# 45/45 [==============================] - 1s 17ms/step
# X | test3 -> R² = 0.8491, MSE = 1.3881e-02
# 40/40 [==============================] - 1s 12ms/step
# X | val -> R² = 0.8411, MSE = 1.5198e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 3s 10ms/step
# X | train1 -> R² = 0.9411, MSE = 6.3535e-03
# 31/31 [==============================] - 0s 9ms/step
# X | train2 -> R² = -1.2128, MSE = 1.8645e-01
# 31/31 [==============================] - 1s 13ms/step
# X | test1 -> R² = 0.8950, MSE = 1.1001e-02
# 31/31 [==============================] - 0s 12ms/step
# X | test2 -> R² = -1.2536, MSE = 1.8545e-01
# 45/45 [==============================] - 1s 13ms/step
# X | test3 -> R² = 0.8709, MSE = 1.1874e-02
# 40/40 [==============================] - 1s 11ms/step
# X | val -> R² = 0.8660, MSE = 1.2817e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 4s 11ms/step
# X | train1 -> R² = 0.9579, MSE = 4.5443e-03
# 31/31 [==============================] - 0s 11ms/step
# X | train2 -> R² = -1.1977, MSE = 1.8518e-01
# 31/31 [==============================] - 0s 9ms/step
# X | test1 -> R² = 0.9308, MSE = 7.2484e-03
# 31/31 [==============================] - 1s 13ms/step
# X | test2 -> R² = -1.2341, MSE = 1.8385e-01
# 45/45 [==============================] - 1s 20ms/step
# X | test3 -> R² = 0.9016, MSE = 9.0512e-03
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.9242, MSE = 7.2477e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 10ms/step
# X | train1 -> R² = 0.9213, MSE = 8.4842e-03
# 31/31 [==============================] - 0s 9ms/step
# X | train2 -> R² = -1.3936, MSE = 2.0169e-01
# 31/31 [==============================] - 0s 12ms/step
# X | test1 -> R² = 0.7971, MSE = 2.1258e-02
# 31/31 [==============================] - 0s 8ms/step
# X | test2 -> R² = -1.3663, MSE = 1.9473e-01
# 45/45 [==============================] - 1s 15ms/step
# X | test3 -> R² = 0.5019, MSE = 4.5825e-02
# 40/40 [==============================] - 1s 11ms/step
# X | val -> R² = 0.2067, MSE = 7.5861e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# X | train1 -> R² = 0.7532, MSE = 2.6613e-02
# 31/31 [==============================] - 0s 9ms/step
# X | train2 -> R² = -1.1484, MSE = 1.8102e-01
# 31/31 [==============================] - 0s 9ms/step
# X | test1 -> R² = 0.5818, MSE = 4.3811e-02
# 31/31 [==============================] - 0s 7ms/step
# X | test2 -> R² = -1.1738, MSE = 1.7889e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = 0.0044, MSE = 9.1599e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = -0.1593, MSE = 1.1086e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.8776, MSE = 1.3195e-02
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -1.0244, MSE = 1.7057e-01
# 31/31 [==============================] - 0s 8ms/step
# X | test1 -> R² = 0.7832, MSE = 2.2716e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -1.0332, MSE = 1.6732e-01
# 45/45 [==============================] - 0s 9ms/step
# X | test3 -> R² = 0.7889, MSE = 1.9420e-02
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = 0.7495, MSE = 2.3955e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# X | train1 -> R² = 0.9261, MSE = 7.9632e-03
# 31/31 [==============================] - 1s 12ms/step
# X | train2 -> R² = -1.2125, MSE = 1.8643e-01
# 31/31 [==============================] - 0s 11ms/step
# X | test1 -> R² = 0.8724, MSE = 1.3364e-02
# 31/31 [==============================] - 0s 10ms/step
# X | test2 -> R² = -1.1817, MSE = 1.7954e-01
# 45/45 [==============================] - 1s 11ms/step
# X | test3 -> R² = 0.6284, MSE = 3.4187e-02
# 40/40 [==============================] - 1s 16ms/step
# X | val -> R² = 0.8324, MSE = 1.6031e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 4s 11ms/step
# X | train1 -> R² = 0.6822, MSE = 3.4266e-02
# 31/31 [==============================] - 1s 11ms/step
# X | train2 -> R² = -1.0716, MSE = 1.7455e-01
# 31/31 [==============================] - 1s 15ms/step
# X | test1 -> R² = 0.4952, MSE = 5.2880e-02
# 31/31 [==============================] - 1s 14ms/step
# X | test2 -> R² = -1.1037, MSE = 1.7312e-01
# 45/45 [==============================] - 1s 13ms/step
# X | test3 -> R² = 0.6631, MSE = 3.1000e-02
# 40/40 [==============================] - 1s 12ms/step
# X | val -> R² = 0.5619, MSE = 4.1893e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 3s 10ms/step
# X | train1 -> R² = 0.7546, MSE = 2.6465e-02
# 31/31 [==============================] - 0s 10ms/step
# X | train2 -> R² = -0.9655, MSE = 1.6561e-01
# 31/31 [==============================] - 0s 10ms/step
# X | test1 -> R² = 0.5726, MSE = 4.4775e-02
# 31/31 [==============================] - 0s 9ms/step
# X | test2 -> R² = -0.9803, MSE = 1.6296e-01
# 45/45 [==============================] - 1s 12ms/step
# X | test3 -> R² = 0.6881, MSE = 2.8696e-02
# 40/40 [==============================] - 1s 10ms/step
# X | val -> R² = 0.5352, MSE = 4.4446e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 11ms/step
# X | train1 -> R² = 0.7610, MSE = 2.5769e-02
# 31/31 [==============================] - 0s 10ms/step
# X | train2 -> R² = -1.2226, MSE = 1.8727e-01
# 31/31 [==============================] - 1s 14ms/step
# X | test1 -> R² = 0.5683, MSE = 4.5226e-02
# 31/31 [==============================] - 1s 12ms/step
# X | test2 -> R² = -1.2313, MSE = 1.8362e-01
# 45/45 [==============================] - 1s 11ms/step
# X | test3 -> R² = 0.5914, MSE = 3.7590e-02
# 40/40 [==============================] - 1s 10ms/step
# X | val -> R² = 0.4164, MSE = 5.5808e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# X | train1 -> R² = 0.7971, MSE = 2.1877e-02
# 31/31 [==============================] - 0s 6ms/step
# X | train2 -> R² = -0.8648, MSE = 1.5713e-01
# 31/31 [==============================] - 0s 7ms/step
# X | test1 -> R² = 0.6723, MSE = 3.4333e-02
# 31/31 [==============================] - 0s 6ms/step
# X | test2 -> R² = -0.8774, MSE = 1.5450e-01
# 45/45 [==============================] - 0s 7ms/step
# X | test3 -> R² = 0.5460, MSE = 4.1765e-02
# 40/40 [==============================] - 0s 6ms/step
# X | val -> R² = 0.4259, MSE = 5.4895e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# X | train1 -> R² = 0.6027, MSE = 4.2838e-02
# 31/31 [==============================] - 0s 9ms/step
# X | train2 -> R² = -1.0759, MSE = 1.7492e-01
# 31/31 [==============================] - 0s 12ms/step
# X | test1 -> R² = 0.3841, MSE = 6.4526e-02
# 31/31 [==============================] - 0s 9ms/step
# X | test2 -> R² = -1.1222, MSE = 1.7464e-01
# 45/45 [==============================] - 1s 10ms/step
# X | test3 -> R² = -0.0363, MSE = 9.5341e-02
# 40/40 [==============================] - 1s 11ms/step
# X | val -> R² = -0.2320, MSE = 1.1781e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# X | train1 -> R² = -0.3643, MSE = 1.4711e-01
# 31/31 [==============================] - 0s 5ms/step
# X | train2 -> R² = -1.5910, MSE = 2.1832e-01
# 31/31 [==============================] - 0s 6ms/step
# X | test1 -> R² = -0.7891, MSE = 1.8743e-01
# 31/31 [==============================] - 0s 5ms/step
# X | test2 -> R² = -1.7300, MSE = 2.2466e-01
# 45/45 [==============================] - 0s 8ms/step
# X | test3 -> R² = -2.8817, MSE = 3.5714e-01
# 40/40 [==============================] - 0s 7ms/step
# X | val -> R² = -3.0625, MSE = 3.8847e-01
# Modelo 4 treinado e salvo no Excel
