# %% [markdown]
# # RNN
# - 2 Entradas PwmD, PwmE
# - 1 Saida $\Delta \theta $
# - 1 Camada
# - n neurônios

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
TIME_STEPS = 3
TS = 0.07

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 2)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 2)
# Dimensão da saida: (1268, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def PlotOut(ax, title, target_name, y_true, y_pred):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true, marker='o', s=12, label='Amostras Reais', alpha=0.7)
    ax.scatter(time, y_pred, marker='x', s=12, label='Valores Preditos', alpha=0.7)
    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_targets = len(TARGET)

    metrics = {name: {"R2_train1": [], "R2_train2": [],
                      "R2_test1": [], "R2_test2": [],
                      "R2_test3": [],"R2_val": [],
                      "MSE_train1": [], "MSE_train2": [],
                      "MSE_test1": [], "MSE_test2": [],
                      "MSE_test3": [], "MSE_val": [],} for name in TARGET_INT}

    for i, dataset in enumerate(NormDatasets):
        x = dataset[PREDICTORS]
        y = dataset[TARGET]
        x, y = CreateSequences(x, y, TIME_STEPS)

        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        y_diff = OUT_SCALER.inverse_transform(y)
        
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)

        # valores iniciais reais (não normalizados)
        init_vals = np.array([
            Datasets[i]["Theta"].iloc[0],
            Datasets[i]["X"].iloc[0],
            Datasets[i]["Y"].iloc[0]
        ])

        # reconstrução cumulativa saída a saída
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)


        # Calcula métricas por saída
        for j, name in enumerate(TARGET_INT):
            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])
            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, MSE = {mse:.4e}")
            
    # Retorna métricas médias para análise posterior
    return metrics

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras import initializers
from keras import regularizers
from itertools import product

# tamanho da entrada
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET) 
N_MODELS = 5  # número de inicializações

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

# arquiteturas das camadas ocultas
architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

for arch,  r in product(architectures, r_values):
    for i, s in enumerate(seeds):

        initializer = initializers.RandomNormal(seed=int(s))
        regularizer = regularizers.l2(r)

        model = keras.models.Sequential()
        model.add(keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

        # adiciona camadas RNN
        for j, n in enumerate(arch):

            # se não for a última camada RNN
            if j < len(arch) - 1:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada de saída
        model.add(
            keras.layers.Dense(
                OUTPUT_SIZE,
                activation="linear",
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )
        # salva pesos iniciais
        w0 = model.get_weights()

        # compila
        model.compile(loss="mean_squared_error", optimizer="adam")
        early_stopping_monitor = EarlyStopping(
            monitor='val_loss',
            patience=50,
            restore_best_weights=True
        )

        history = model.fit(
            x_train, 
            y_train, 
            epochs=1000,
            callbacks=[early_stopping_monitor],
            validation_data=(x_val, y_val),
            verbose=0
        )
        
    
        # salva pesos finais
        wf = model.get_weights()

       # avalia o modelo
        metrics = EvalModel(model)


        row = {
            "model": f"model_{n}_{i}",
            "Neurons": n,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# 31/31 [==============================] - 0s 2ms/step
# Theta | train1 -> R² = -1.5474, MSE = 5.8148e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | train2 -> R² = 0.5256, MSE = 1.0831e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test1 -> R² = -3.2473, MSE = 9.7569e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test2 -> R² = 0.2300, MSE = 1.8263e-01
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = -7.1626, MSE = 2.6834e+00
# 40/40 [==============================] - 0s 2ms/step
# Theta | val -> R² = -27.6688, MSE = 9.3827e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# Theta | train1 -> R² = -0.1401, MSE = 2.6025e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | train2 -> R² = 0.7851, MSE = 4.9071e-02
# 31/31 [==============================] - 0s 2ms/step
# Theta | test1 -> R² = -0.8278, MSE = 4.1988e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test2 -> R² = 0.6280, MSE = 8.8216e-02
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = -6.1314, MSE = 2.3444e+00
# 40/40 [==============================] - 0s 2ms/step
# Theta | val -> R² = -23.5957, MSE = 8.0497e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# Theta | train1 -> R² = 0.4914, MSE = 1.1609e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | train2 -> R² = 0.2298, MSE = 1.7584e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test1 -> R² = 0.7767, MSE = 5.1306e-02
# 31/31 [==============================] - 0s 2ms/step
# Theta | test2 -> R² = 0.5675, MSE = 1.0256e-01
# 45/45 [==============================] - 0s 2ms/step
# Theta | test3 -> R² = 0.2824, MSE = 2.3591e-01
# 40/40 [==============================] - 0s 2ms/step
# Theta | val -> R² = -4.6956, MSE = 1.8640e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# Theta | train1 -> R² = 0.6718, MSE = 7.4917e-02
# 31/31 [==============================] - 0s 2ms/step
# Theta | train2 -> R² = -0.9260, MSE = 4.3971e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test1 -> R² = 0.0529, MSE = 2.1756e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test2 -> R² = -1.7480, MSE = 6.5172e-01
# 45/45 [==============================] - 0s 2ms/step
# Theta | test3 -> R² = -0.7135, MSE = 5.6330e-01
# 40/40 [==============================] - 0s 2ms/step
# Theta | val -> R² = -17.7315, MSE = 6.1304e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 0s 2ms/step
# Theta | train1 -> R² = 0.2797, MSE = 1.6442e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | train2 -> R² = 0.0753, MSE = 2.1111e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test1 -> R² = 0.6237, MSE = 8.6433e-02
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = 0.4216, MSE = 1.3718e-01
# 45/45 [==============================] - 0s 2ms/step
# Theta | test3 -> R² = 0.4881, MSE = 1.6828e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -5.1675, MSE = 2.0185e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Theta | train1 -> R² = -0.2724, MSE = 2.9044e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | train2 -> R² = -1.6827, MSE = 6.1247e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.3046, MSE = 1.5974e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -1.8602, MSE = 6.7833e-01
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = 0.1888, MSE = 2.6667e-01
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = -4.3884, MSE = 1.7635e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -0.4852, MSE = 3.3902e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | train2 -> R² = -2.1253, MSE = 7.1352e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.0527, MSE = 2.1762e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = -2.2677, MSE = 7.7498e-01
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = 0.0561, MSE = 3.1029e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -3.4402, MSE = 1.4532e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 0s 3ms/step
# Theta | train1 -> R² = -2.3092, MSE = 7.5538e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | train2 -> R² = -4.5473, MSE = 1.2665e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | test1 -> R² = -1.1381, MSE = 4.9116e-01
# 31/31 [==============================] - 0s 2ms/step
# Theta | test2 -> R² = -4.7929, MSE = 1.3739e+00
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = -0.8162, MSE = 5.9709e-01
# 40/40 [==============================] - 0s 2ms/step
# Theta | val -> R² = -2.1775, MSE = 1.0399e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Theta | train1 -> R² = 0.4429, MSE = 1.2718e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | train2 -> R² = -0.8866, MSE = 4.3072e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.4842, MSE = 1.1849e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -1.2306, MSE = 5.2902e-01
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = 0.3874, MSE = 2.0139e-01
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = -6.9072, MSE = 2.5879e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Theta | train1 -> R² = 0.8449, MSE = 3.5413e-02
# 31/31 [==============================] - 0s 3ms/step
# Theta | train2 -> R² = 0.2515, MSE = 1.7089e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | test1 -> R² = 0.5067, MSE = 1.1332e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = 0.1167, MSE = 2.0948e-01
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = 0.3520, MSE = 2.1304e-01
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = -8.4054, MSE = 3.0782e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -5.9599, MSE = 1.5887e+00
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -8.6973, MSE = 2.2139e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | test1 -> R² = -3.9210, MSE = 1.1304e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = -9.0114, MSE = 2.3743e+00
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = -3.4388, MSE = 1.4592e+00
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = 0.0465, MSE = 3.1206e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Theta | train1 -> R² = -8.1235, MSE = 2.0826e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | train2 -> R² = -11.1220, MSE = 2.7675e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | test1 -> R² = -6.1184, MSE = 1.6352e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = -11.2639, MSE = 2.9085e+00
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = -6.7291, MSE = 2.5409e+00
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = 0.6262, MSE = 1.2235e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = 0.3921, MSE = 1.3877e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -0.6446, MSE = 3.7548e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.6320, MSE = 8.4526e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -0.4900, MSE = 3.5336e-01
# 45/45 [==============================] - 0s 8ms/step
# Theta | test3 -> R² = 0.1986, MSE = 2.6345e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -2.2856, MSE = 1.0753e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -1.1406, MSE = 4.8863e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -2.4290, MSE = 7.8285e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -0.0730, MSE = 2.4649e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test2 -> R² = -2.5752, MSE = 8.4791e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -0.3775, MSE = 4.5285e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -2.3245, MSE = 1.0880e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Theta | train1 -> R² = -1.2051, MSE = 5.0336e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -2.8709, MSE = 8.8374e-01
# 31/31 [==============================] - 1s 5ms/step
# Theta | test1 -> R² = -0.3415, MSE = 3.0817e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -2.9683, MSE = 9.4113e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -0.9223, MSE = 6.3195e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -1.3312, MSE = 7.6295e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Theta | train1 -> R² = 0.8308, MSE = 3.8623e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -0.1063, MSE = 2.5258e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.3246, MSE = 1.5516e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -0.6265, MSE = 3.8575e-01
# 45/45 [==============================] - 1s 5ms/step
# Theta | test3 -> R² = -0.3373, MSE = 4.3962e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -13.3681, MSE = 4.7024e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -0.2922, MSE = 2.9497e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -3.1474, MSE = 9.4686e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.0611, MSE = 2.4376e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -3.9369, MSE = 1.1709e+00
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -0.9562, MSE = 6.4311e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -16.4758, MSE = 5.7195e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Theta | train1 -> R² = 0.7474, MSE = 5.7650e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = 0.0754, MSE = 2.1108e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = 0.4369, MSE = 1.2936e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -0.6624, MSE = 3.9425e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -1.6173, MSE = 8.6042e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -13.5382, MSE = 4.7580e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = 0.8279, MSE = 3.9296e-02
# 31/31 [==============================] - 1s 5ms/step
# Theta | train2 -> R² = 0.4724, MSE = 1.2046e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = 0.4572, MSE = 1.2468e-01
# 31/31 [==============================] - 1s 7ms/step
# Theta | test2 -> R² = -0.0019, MSE = 2.3762e-01
# 45/45 [==============================] - 1s 6ms/step
# Theta | test3 -> R² = -2.4942, MSE = 1.1487e+00
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -10.5251, MSE = 3.7719e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Theta | train1 -> R² = 0.7077, MSE = 6.6728e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = 0.2415, MSE = 1.7317e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = 0.4058, MSE = 1.3650e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -0.2387, MSE = 2.9378e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -2.6083, MSE = 1.1862e+00
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -18.0185, MSE = 6.2244e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Theta | train1 -> R² = -0.4979, MSE = 3.4192e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -2.3505, MSE = 7.6494e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.1167, MSE = 2.5654e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -2.5535, MSE = 8.4275e-01
# 45/45 [==============================] - 0s 7ms/step
# Theta | test3 -> R² = 0.1406, MSE = 2.8251e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -4.3938, MSE = 1.7653e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -3.9358, MSE = 1.1267e+00
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -6.4878, MSE = 1.7095e+00
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -2.5268, MSE = 8.1016e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -6.5953, MSE = 1.8013e+00
# 45/45 [==============================] - 0s 7ms/step
# Theta | test3 -> R² = -1.2224, MSE = 7.3059e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -1.8103, MSE = 9.1975e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -6.2948, MSE = 1.6652e+00
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -9.2501, MSE = 2.3401e+00
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -4.5418, MSE = 1.2731e+00
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -9.2954, MSE = 2.4417e+00
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -2.6727, MSE = 1.2074e+00
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -0.6970, MSE = 5.5539e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = -4.4047, MSE = 1.2337e+00
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -6.3436, MSE = 1.6766e+00
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -3.0554, MSE = 9.3161e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = -6.2241, MSE = 1.7133e+00
# 45/45 [==============================] - 1s 6ms/step
# Theta | test3 -> R² = -2.1927, MSE = 1.0496e+00
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -0.2942, MSE = 4.2355e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 13ms/step
# Theta | train1 -> R² = -1.2900, MSE = 5.2273e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -3.2039, MSE = 9.5975e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.3719, MSE = 3.1515e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -3.4073, MSE = 1.0452e+00
# 45/45 [==============================] - 1s 8ms/step
# Theta | test3 -> R² = 0.0465, MSE = 3.1346e-01
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -4.8615, MSE = 1.9184e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = 0.0212, MSE = 2.2343e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = -1.2608, MSE = 5.1614e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = 0.4095, MSE = 1.3564e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.3543, MSE = 5.5835e-01
# 45/45 [==============================] - 0s 6ms/step
# Theta | test3 -> R² = 0.4199, MSE = 1.9071e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -5.1492, MSE = 2.0125e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = 0.7265, MSE = 6.2420e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = 0.4192, MSE = 1.3259e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = 0.0415, MSE = 2.2019e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = 0.7536, MSE = 5.8441e-02
# 45/45 [==============================] - 1s 4ms/step
# Theta | test3 -> R² = 0.5717, MSE = 1.4081e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -7.2787, MSE = 2.7095e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Theta | train1 -> R² = -2.6811, MSE = 8.4028e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -5.0795, MSE = 1.3880e+00
# 31/31 [==============================] - 0s 3ms/step
# Theta | test1 -> R² = -1.6124, MSE = 6.0011e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = -5.2695, MSE = 1.4869e+00
# 45/45 [==============================] - 0s 3ms/step
# Theta | test3 -> R² = -1.2972, MSE = 7.5519e-01
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = -1.6766, MSE = 8.7601e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -0.6455, MSE = 3.7562e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.9376, MSE = 6.7066e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -0.2237, MSE = 2.8110e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -1.7111, MSE = 6.4296e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -0.7672, MSE = 5.8097e-01
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = -0.8858, MSE = 6.1719e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = 0.8433, MSE = 3.5778e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = 0.5700, MSE = 9.8172e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.6503, MSE = 8.0341e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = 0.8056, MSE = 4.6111e-02
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = 0.3272, MSE = 2.2117e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -6.0685, MSE = 2.3134e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -1.3220, MSE = 5.3004e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -2.4481, MSE = 7.8721e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.1604, MSE = 2.6657e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -2.1843, MSE = 7.5520e-01
# 45/45 [==============================] - 1s 6ms/step
# Theta | test3 -> R² = -0.6445, MSE = 5.4061e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -4.9471, MSE = 1.9464e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Theta | train1 -> R² = 0.8348, MSE = 3.7707e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = 0.0177, MSE = 2.2426e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = 0.3365, MSE = 1.5243e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -0.4596, MSE = 3.4616e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -0.6245, MSE = 5.3404e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -13.9541, MSE = 4.8942e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = 0.2693, MSE = 1.6680e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = 0.8009, MSE = 4.5463e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -1.0263, MSE = 4.6548e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = 0.3687, MSE = 1.4972e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -4.0445, MSE = 1.6584e+00
# 40/40 [==============================] - 1s 5ms/step
# Theta | val -> R² = -25.2589, MSE = 8.5940e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = 0.5501, MSE = 1.0269e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -1.0170, MSE = 4.6049e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = 0.3603, MSE = 1.4696e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -1.2759, MSE = 5.3975e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = 0.4676, MSE = 1.7503e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -8.4044, MSE = 3.0779e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = -2.7784, MSE = 8.6247e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -0.7176, MSE = 3.9213e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -3.6122, MSE = 1.0595e+00
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -0.2868, MSE = 3.0518e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -10.0914, MSE = 3.6463e+00
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -28.8080, MSE = 9.7555e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -3.7709, MSE = 1.0890e+00
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -5.5550, MSE = 1.4965e+00
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = -2.3015, MSE = 7.5841e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -5.3455, MSE = 1.5049e+00
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -0.3020, MSE = 4.2803e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -3.4767, MSE = 1.4651e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = 0.3757, MSE = 1.4251e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = 0.7756, MSE = 5.1225e-02
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.0488, MSE = 2.4092e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = 0.6897, MSE = 7.3588e-02
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -2.9419, MSE = 1.2959e+00
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -16.2045, MSE = 5.6307e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = -2.9555, MSE = 9.0291e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -4.9476, MSE = 1.3579e+00
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = -2.0021, MSE = 6.8964e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -4.9111, MSE = 1.4019e+00
# 45/45 [==============================] - 0s 6ms/step
# Theta | test3 -> R² = -1.0832, MSE = 6.8484e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -1.9718, MSE = 9.7260e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -0.0263, MSE = 2.3426e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -0.7489, MSE = 3.9928e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.5155, MSE = 1.1129e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -0.7029, MSE = 4.0386e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -0.1321, MSE = 3.7219e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -7.4157, MSE = 2.7543e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = 0.1097, MSE = 2.0322e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = 0.4014, MSE = 1.3667e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.8916, MSE = 4.3453e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = 0.6345, MSE = 8.6679e-02
# 45/45 [==============================] - 0s 6ms/step
# Theta | test3 -> R² = -0.9625, MSE = 6.4517e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -14.0900, MSE = 4.9387e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Theta | train1 -> R² = -0.7951, MSE = 4.0975e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -1.9282, MSE = 6.6853e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -0.1565, MSE = 2.6567e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = -1.7689, MSE = 6.5668e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = 0.1543, MSE = 2.7802e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -2.4035, MSE = 1.1139e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Theta | train1 -> R² = 0.9010, MSE = 2.2593e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = 0.5450, MSE = 1.0387e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = 0.6411, MSE = 8.2451e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = 0.7111, MSE = 6.8525e-02
# 45/45 [==============================] - 1s 6ms/step
# Theta | test3 -> R² = 0.3567, MSE = 2.1149e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -7.3045, MSE = 2.7179e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Theta | train1 -> R² = -0.6264, MSE = 3.7126e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -2.1255, MSE = 7.1356e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.1255, MSE = 2.5855e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -2.1249, MSE = 7.4111e-01
# 45/45 [==============================] - 0s 6ms/step
# Theta | test3 -> R² = 0.2101, MSE = 2.5968e-01
# 40/40 [==============================] - 1s 7ms/step
# Theta | val -> R² = -3.5431, MSE = 1.4869e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -0.6139, MSE = 3.6841e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -1.9415, MSE = 6.7156e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.0373, MSE = 2.3829e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -1.8801, MSE = 6.8304e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = 0.2101, MSE = 2.5968e-01
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -2.9954, MSE = 1.3076e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Theta | train1 -> R² = -0.6383, MSE = 3.7397e-01
# 31/31 [==============================] - 1s 13ms/step
# Theta | train2 -> R² = -1.7141, MSE = 6.1963e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.0900, MSE = 2.5039e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.5070, MSE = 5.9457e-01
# 45/45 [==============================] - 1s 8ms/step
# Theta | test3 -> R² = -0.0177, MSE = 3.3457e-01
# 40/40 [==============================] - 1s 6ms/step
# Theta | val -> R² = -1.6548, MSE = 8.6887e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Theta | train1 -> R² = 0.0684, MSE = 2.1265e-01
# 31/31 [==============================] - 1s 10ms/step
# Theta | train2 -> R² = 0.7349, MSE = 6.0513e-02
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.4067, MSE = 3.2315e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = 0.7863, MSE = 5.0671e-02
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = -2.9650, MSE = 1.3035e+00
# 40/40 [==============================] - 1s 7ms/step
# Theta | val -> R² = -11.8866, MSE = 4.2175e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = 0.5493, MSE = 1.0288e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = 0.7728, MSE = 5.1874e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -0.3051, MSE = 2.9981e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = 0.7215, MSE = 6.6049e-02
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -1.7538, MSE = 9.0531e-01
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -15.1392, MSE = 5.2820e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Theta | train1 -> R² = 0.7345, MSE = 6.0595e-02
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = 0.7538, MSE = 5.6216e-02
# 31/31 [==============================] - 1s 7ms/step
# Theta | test1 -> R² = 0.0431, MSE = 2.1982e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = 0.6266, MSE = 8.8562e-02
# 45/45 [==============================] - 1s 7ms/step
# Theta | test3 -> R² = -1.3854, MSE = 7.8421e-01
# 40/40 [==============================] - 1s 8ms/step
# Theta | val -> R² = -14.2493, MSE = 4.9908e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Theta | train1 -> R² = -2.2969, MSE = 7.5258e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = -5.8827, MSE = 1.5713e+00
# 31/31 [==============================] - 0s 9ms/step
# Theta | test1 -> R² = -1.1327, MSE = 4.8991e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = -6.3945, MSE = 1.7537e+00
# 45/45 [==============================] - 1s 7ms/step
# Theta | test3 -> R² = -0.3799, MSE = 4.5364e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -7.5744, MSE = 2.8062e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -1.6438, MSE = 6.0349e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -0.4475, MSE = 3.3046e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -3.0119, MSE = 9.2162e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = 0.0224, MSE = 2.3186e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -2.4737, MSE = 1.1420e+00
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -17.2565, MSE = 5.9750e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Theta | train1 -> R² = -0.9299, MSE = 4.4054e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -2.1779, MSE = 7.2553e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = -0.2071, MSE = 2.7728e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test2 -> R² = -2.0927, MSE = 7.3347e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = 0.2532, MSE = 2.4550e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -4.1331, MSE = 1.6800e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 15ms/step
# Theta | train1 -> R² = 0.9275, MSE = 1.6557e-02
# 31/31 [==============================] - 1s 10ms/step
# Theta | train2 -> R² = 0.7327, MSE = 6.1032e-02
# 31/31 [==============================] - 1s 9ms/step
# Theta | test1 -> R² = 0.6599, MSE = 7.8130e-02
# 31/31 [==============================] - 1s 8ms/step
# Theta | test2 -> R² = 0.6957, MSE = 7.2172e-02
# 45/45 [==============================] - 1s 7ms/step
# Theta | test3 -> R² = -0.2961, MSE = 4.2611e-01
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -9.5618, MSE = 3.4567e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Theta | train1 -> R² = -0.1312, MSE = 2.5822e-01
# 31/31 [==============================] - 1s 11ms/step
# Theta | train2 -> R² = -1.3893, MSE = 5.4548e-01
# 31/31 [==============================] - 1s 9ms/step
# Theta | test1 -> R² = 0.2198, MSE = 1.7922e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -1.3287, MSE = 5.5228e-01
# 45/45 [==============================] - 1s 8ms/step
# Theta | test3 -> R² = 0.4464, MSE = 1.8198e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -5.2791, MSE = 2.0550e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Theta | train1 -> R² = -0.3129, MSE = 2.9970e-01
# 31/31 [==============================] - 1s 8ms/step
# Theta | train2 -> R² = -1.3726, MSE = 5.4166e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = 0.0804, MSE = 2.1126e-01
# 31/31 [==============================] - 1s 10ms/step
# Theta | test2 -> R² = -1.1881, MSE = 5.1892e-01
# 45/45 [==============================] - 1s 13ms/step
# Theta | test3 -> R² = 0.3071, MSE = 2.2778e-01
# 40/40 [==============================] - 1s 7ms/step
# Theta | val -> R² = -3.5999, MSE = 1.5055e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Theta | train1 -> R² = -1.4659, MSE = 5.6289e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -2.5687, MSE = 8.1475e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.6508, MSE = 3.7923e-01
# 31/31 [==============================] - 1s 7ms/step
# Theta | test2 -> R² = -2.3737, MSE = 8.0011e-01
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = 0.2793, MSE = 2.3693e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -4.4543, MSE = 1.7851e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = 0.7936, MSE = 4.7107e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = 0.3434, MSE = 1.4990e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = 0.8039, MSE = 4.5049e-02
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = 0.4936, MSE = 1.2011e-01
# 45/45 [==============================] - 1s 10ms/step
# Theta | test3 -> R² = 0.3222, MSE = 2.2282e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -7.1943, MSE = 2.6818e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -1.4829, MSE = 5.6677e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -2.8054, MSE = 8.6878e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.9460, MSE = 4.4704e-01
# 31/31 [==============================] - 0s 11ms/step
# Theta | test2 -> R² = -2.6121, MSE = 8.5664e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -0.9232, MSE = 6.3225e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -1.5495, MSE = 8.3439e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 9ms/step
# Theta | train1 -> R² = 0.8340, MSE = 3.7890e-02
# 31/31 [==============================] - 1s 10ms/step
# Theta | train2 -> R² = 0.1699, MSE = 1.8951e-01
# 31/31 [==============================] - 1s 7ms/step
# Theta | test1 -> R² = 0.7562, MSE = 5.6012e-02
# 31/31 [==============================] - 1s 11ms/step
# Theta | test2 -> R² = 0.3068, MSE = 1.6441e-01
# 45/45 [==============================] - 1s 7ms/step
# Theta | test3 -> R² = 0.6417, MSE = 1.1780e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -7.0334, MSE = 2.6292e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Theta | train1 -> R² = -1.4205, MSE = 5.5251e-01
# 31/31 [==============================] - 1s 7ms/step
# Theta | train2 -> R² = -2.8722, MSE = 8.8404e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.7173, MSE = 3.9449e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -2.7537, MSE = 8.9024e-01
# 45/45 [==============================] - 0s 8ms/step
# Theta | test3 -> R² = -0.5181, MSE = 4.9907e-01
# 40/40 [==============================] - 1s 6ms/step
# Theta | val -> R² = -1.7411, MSE = 8.9712e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Theta | train1 -> R² = -0.6035, MSE = 3.6602e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -1.3842, MSE = 5.4433e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.1686, MSE = 2.6845e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test2 -> R² = -1.4186, MSE = 5.7359e-01
# 45/45 [==============================] - 1s 8ms/step
# Theta | test3 -> R² = 0.4445, MSE = 1.8263e-01
# 40/40 [==============================] - 1s 8ms/step
# Theta | val -> R² = -3.2722, MSE = 1.3982e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Theta | train1 -> R² = -0.0392, MSE = 2.3720e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = 0.0126, MSE = 2.2544e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | test1 -> R² = -1.4846, MSE = 5.7076e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = 0.4699, MSE = 1.2571e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = 0.4320, MSE = 1.8673e-01
# 40/40 [==============================] - 1s 9ms/step
# Theta | val -> R² = -10.9079, MSE = 3.8972e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = 0.6122, MSE = 8.8517e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = 0.6225, MSE = 8.6195e-02
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = 0.5601, MSE = 1.0104e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = 0.9336, MSE = 1.5759e-02
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -0.5221, MSE = 5.0039e-01
# 40/40 [==============================] - 0s 4ms/step
# Theta | val -> R² = -6.6205, MSE = 2.4940e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 5ms/step
# Theta | train1 -> R² = 0.0500, MSE = 2.1685e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -0.3759, MSE = 3.1412e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.5099, MSE = 3.4686e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = 0.3083, MSE = 1.6404e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = 0.0848, MSE = 3.0085e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -5.7850, MSE = 2.2206e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 3s 9ms/step
# Theta | train1 -> R² = 0.1981, MSE = 1.8306e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = 0.6850, MSE = 7.1909e-02
# 31/31 [==============================] - 1s 6ms/step
# Theta | test1 -> R² = -1.0745, MSE = 4.7654e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = 0.7185, MSE = 6.6755e-02
# 45/45 [==============================] - 0s 7ms/step
# Theta | test3 -> R² = -0.3244, MSE = 4.3540e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -12.3976, MSE = 4.3847e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Theta | train1 -> R² = 0.7878, MSE = 4.8437e-02
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = 0.5678, MSE = 9.8662e-02
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = 0.5999, MSE = 9.1900e-02
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = 0.8477, MSE = 3.6119e-02
# 45/45 [==============================] - 1s 8ms/step
# Theta | test3 -> R² = 0.2946, MSE = 2.3189e-01
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -5.9526, MSE = 2.2755e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = -0.1251, MSE = 2.5683e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.4923, MSE = 5.6899e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.0640, MSE = 2.4442e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4867, MSE = 5.8976e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -1.1283, MSE = 6.9968e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -1.1184, MSE = 6.9329e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Theta | train1 -> R² = -0.1115, MSE = 2.5372e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -1.5044, MSE = 5.7177e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.0515, MSE = 2.4156e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | test2 -> R² = -1.4986, MSE = 5.9257e-01
# 45/45 [==============================] - 0s 6ms/step
# Theta | test3 -> R² = -1.0916, MSE = 6.8760e-01
# 40/40 [==============================] - 1s 7ms/step
# Theta | val -> R² = -1.0864, MSE = 6.8282e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 8ms/step
# Theta | train1 -> R² = -0.1179, MSE = 2.5518e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = -1.4986, MSE = 5.7044e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.0574, MSE = 2.4291e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4929, MSE = 5.9122e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -1.1089, MSE = 6.9331e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -1.1015, MSE = 6.8777e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Theta | train1 -> R² = -0.0883, MSE = 2.4842e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.5274, MSE = 5.7700e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.0304, MSE = 2.3670e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test2 -> R² = -1.5209, MSE = 5.9786e-01
# 45/45 [==============================] - 0s 6ms/step
# Theta | test3 -> R² = -1.0275, MSE = 6.6653e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -1.0304, MSE = 6.6452e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Theta | train1 -> R² = -0.1164, MSE = 2.5484e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.4999, MSE = 5.7074e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | test1 -> R² = -0.0560, MSE = 2.4259e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test2 -> R² = -1.4942, MSE = 5.9153e-01
# 45/45 [==============================] - 0s 4ms/step
# Theta | test3 -> R² = -1.1049, MSE = 6.9199e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -1.0980, MSE = 6.8663e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Theta | train1 -> R² = -0.1607, MSE = 2.6495e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.4641, MSE = 5.6257e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -0.0968, MSE = 2.5195e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4594, MSE = 5.8326e-01
# 45/45 [==============================] - 0s 7ms/step
# Theta | test3 -> R² = -1.2220, MSE = 7.3047e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -1.1997, MSE = 7.1993e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 6ms/step
# Theta | train1 -> R² = -0.1639, MSE = 2.6568e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | train2 -> R² = -1.4619, MSE = 5.6205e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.0997, MSE = 2.5263e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4571, MSE = 5.8273e-01
# 45/45 [==============================] - 1s 6ms/step
# Theta | test3 -> R² = -1.2302, MSE = 7.3319e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -1.2069, MSE = 7.2228e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -0.1746, MSE = 2.6811e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | train2 -> R² = -1.4545, MSE = 5.6036e-01
# 31/31 [==============================] - 0s 4ms/step
# Theta | test1 -> R² = -0.1096, MSE = 2.5489e-01
# 31/31 [==============================] - 0s 3ms/step
# Theta | test2 -> R² = -1.4499, MSE = 5.8103e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -1.2576, MSE = 7.4218e-01
# 40/40 [==============================] - 0s 3ms/step
# Theta | val -> R² = -1.2306, MSE = 7.3003e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = -0.1486, MSE = 2.6220e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.4731, MSE = 5.6462e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test1 -> R² = -0.0856, MSE = 2.4939e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4681, MSE = 5.8534e-01
# 45/45 [==============================] - 1s 7ms/step
# Theta | test3 -> R² = -1.1906, MSE = 7.2015e-01
# 40/40 [==============================] - 1s 6ms/step
# Theta | val -> R² = -1.1725, MSE = 7.1101e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Theta | train1 -> R² = -0.1512, MSE = 2.6277e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.4712, MSE = 5.6418e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.0880, MSE = 2.4993e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = -1.4662, MSE = 5.8489e-01
# 45/45 [==============================] - 0s 5ms/step
# Theta | test3 -> R² = -1.1972, MSE = 7.2232e-01
# 40/40 [==============================] - 1s 6ms/step
# Theta | val -> R² = -1.1782, MSE = 7.1289e-01
# Modelo 4 treinado e salvo no Excel
# ...
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.5144, MSE = 5.7406e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test1 -> R² = -0.0420, MSE = 2.3936e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = -1.5083, MSE = 5.9488e-01
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = -1.0628, MSE = 6.7814e-01
# 40/40 [==============================] - 1s 9ms/step
# Theta | val -> R² = -1.0613, MSE = 6.7461e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 6ms/step
# Theta | train1 -> R² = -0.1040, MSE = 2.5200e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = -1.5116, MSE = 5.7340e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test1 -> R² = -0.0447, MSE = 2.3998e-01
# 31/31 [==============================] - 1s 8ms/step
# Theta | test2 -> R² = -1.5055, MSE = 5.9421e-01
# 45/45 [==============================] - 1s 11ms/step
# Theta | test3 -> R² = -1.0710, MSE = 6.8083e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -1.0684, MSE = 6.7695e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Theta | train1 -> R² = -0.0888, MSE = 2.4855e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.5268, MSE = 5.7687e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test1 -> R² = -0.0309, MSE = 2.3682e-01
# 31/31 [==============================] - 1s 12ms/step
# Theta | test2 -> R² = -1.5204, MSE = 5.9773e-01
# 45/45 [==============================] - 0s 9ms/step
# Theta | test3 -> R² = -1.0290, MSE = 6.6704e-01
# 40/40 [==============================] - 0s 8ms/step
# Theta | val -> R² = -1.0318, MSE = 6.6497e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 4s 10ms/step
# Theta | train1 -> R² = -0.0722, MSE = 2.4474e-01
# 31/31 [==============================] - 1s 11ms/step
# Theta | train2 -> R² = -1.5451, MSE = 5.8106e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.0158, MSE = 2.3335e-01
# 31/31 [==============================] - 1s 13ms/step
# Theta | test2 -> R² = -1.5382, MSE = 6.0196e-01
# 45/45 [==============================] - 1s 8ms/step
# Theta | test3 -> R² = -0.9819, MSE = 6.5153e-01
# 40/40 [==============================] - 1s 9ms/step
# Theta | val -> R² = -0.9905, MSE = 6.5146e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Theta | train1 -> R² = -0.1209, MSE = 2.5587e-01
# 31/31 [==============================] - 0s 5ms/step
# Theta | train2 -> R² = -1.4959, MSE = 5.6983e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.0602, MSE = 2.4354e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4903, MSE = 5.9060e-01
# 45/45 [==============================] - 1s 7ms/step
# Theta | test3 -> R² = -1.1171, MSE = 6.9598e-01
# 40/40 [==============================] - 1s 9ms/step
# Theta | val -> R² = -1.1086, MSE = 6.9009e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Theta | train1 -> R² = -0.1821, MSE = 2.6983e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.4495, MSE = 5.5922e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test1 -> R² = -0.1166, MSE = 2.5650e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4451, MSE = 5.7987e-01
# 45/45 [==============================] - 1s 10ms/step
# Theta | test3 -> R² = -1.2768, MSE = 7.4849e-01
# 40/40 [==============================] - 0s 5ms/step
# Theta | val -> R² = -1.2472, MSE = 7.3547e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 9ms/step
# Theta | train1 -> R² = -0.1695, MSE = 2.6697e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.4579, MSE = 5.6115e-01
# 31/31 [==============================] - 1s 10ms/step
# Theta | test1 -> R² = -0.1050, MSE = 2.5383e-01
# 31/31 [==============================] - 1s 7ms/step
# Theta | test2 -> R² = -1.4533, MSE = 5.8182e-01
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = -1.2448, MSE = 7.3796e-01
# 40/40 [==============================] - 0s 6ms/step
# Theta | val -> R² = -1.2195, MSE = 7.2640e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Theta | train1 -> R² = -0.1902, MSE = 2.7167e-01
# 31/31 [==============================] - 0s 12ms/step
# Theta | train2 -> R² = -1.4443, MSE = 5.5804e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.1241, MSE = 2.5822e-01
# 31/31 [==============================] - 0s 11ms/step
# Theta | test2 -> R² = -1.4400, MSE = 5.7868e-01
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = -1.2972, MSE = 7.5521e-01
# 40/40 [==============================] - 0s 8ms/step
# Theta | val -> R² = -1.2650, MSE = 7.4127e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Theta | train1 -> R² = -0.1585, MSE = 2.6445e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.4657, MSE = 5.6294e-01
# 31/31 [==============================] - 1s 9ms/step
# Theta | test1 -> R² = -0.0947, MSE = 2.5148e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test2 -> R² = -1.4609, MSE = 5.8363e-01
# 45/45 [==============================] - 1s 12ms/step
# Theta | test3 -> R² = -1.2162, MSE = 7.2858e-01
# 40/40 [==============================] - 0s 8ms/step
# Theta | val -> R² = -1.1948, MSE = 7.1830e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 4s 13ms/step
# Theta | train1 -> R² = -0.1575, MSE = 2.6421e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.4665, MSE = 5.6311e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.0938, MSE = 2.5126e-01
# 31/31 [==============================] - 1s 8ms/step
# Theta | test2 -> R² = -1.4617, MSE = 5.8381e-01
# 45/45 [==============================] - 1s 10ms/step
# Theta | test3 -> R² = -1.2136, MSE = 7.2771e-01
# 40/40 [==============================] - 1s 9ms/step
# Theta | val -> R² = -1.1925, MSE = 7.1755e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 5s 26ms/step
# Theta | train1 -> R² = 0.0596, MSE = 2.1466e-01
# 31/31 [==============================] - 1s 15ms/step
# Theta | train2 -> R² = -1.6676, MSE = 6.0902e-01
# 31/31 [==============================] - 1s 18ms/step
# Theta | test1 -> R² = 0.2410, MSE = 1.7435e-01
# 31/31 [==============================] - 1s 15ms/step
# Theta | test2 -> R² = -2.0361, MSE = 7.2004e-01
# 45/45 [==============================] - 1s 15ms/step
# Theta | test3 -> R² = 0.3703, MSE = 2.0703e-01
# 40/40 [==============================] - 1s 10ms/step
# Theta | val -> R² = -8.7209, MSE = 3.1815e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 4s 13ms/step
# Theta | train1 -> R² = 0.1311, MSE = 1.9834e-01
# 31/31 [==============================] - 1s 16ms/step
# Theta | train2 -> R² = -1.0646, MSE = 4.7135e-01
# 31/31 [==============================] - 1s 16ms/step
# Theta | test1 -> R² = -0.0704, MSE = 2.4589e-01
# 31/31 [==============================] - 1s 12ms/step
# Theta | test2 -> R² = -1.8297, MSE = 6.7109e-01
# 45/45 [==============================] - 1s 19ms/step
# Theta | test3 -> R² = 0.5965, MSE = 1.3265e-01
# 40/40 [==============================] - 1s 13ms/step
# Theta | val -> R² = -3.6361, MSE = 1.5173e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Theta | train1 -> R² = 0.2146, MSE = 1.7927e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = -1.7867, MSE = 6.3622e-01
# 31/31 [==============================] - 1s 13ms/step
# Theta | test1 -> R² = -0.2310, MSE = 2.8277e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | test2 -> R² = -2.2525, MSE = 7.7138e-01
# 45/45 [==============================] - 1s 11ms/step
# Theta | test3 -> R² = 0.3980, MSE = 1.9789e-01
# 40/40 [==============================] - 0s 10ms/step
# Theta | val -> R² = -7.7301, MSE = 2.8572e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 5s 12ms/step
# Theta | train1 -> R² = 0.4550, MSE = 1.2441e-01
# 31/31 [==============================] - 1s 14ms/step
# Theta | train2 -> R² = -1.0735, MSE = 4.7340e-01
# 31/31 [==============================] - 1s 10ms/step
# Theta | test1 -> R² = 0.3106, MSE = 1.5836e-01
# 31/31 [==============================] - 1s 11ms/step
# Theta | test2 -> R² = -1.5805, MSE = 6.1201e-01
# 45/45 [==============================] - 1s 12ms/step
# Theta | test3 -> R² = 0.2620, MSE = 2.4261e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -11.5237, MSE = 4.0988e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 5s 15ms/step
# Theta | train1 -> R² = 0.4250, MSE = 1.3126e-01
# 31/31 [==============================] - 1s 17ms/step
# Theta | train2 -> R² = 0.1910, MSE = 1.8469e-01
# 31/31 [==============================] - 1s 16ms/step
# Theta | test1 -> R² = 0.6165, MSE = 8.8099e-02
# 31/31 [==============================] - 1s 11ms/step
# Theta | test2 -> R² = -0.0316, MSE = 2.4464e-01
# 45/45 [==============================] - 1s 12ms/step
# Theta | test3 -> R² = 0.3576, MSE = 2.1119e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -2.5411, MSE = 1.1589e+00
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 3s 18ms/step
# Theta | train1 -> R² = -1.0402, MSE = 4.6572e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | train2 -> R² = -2.4319, MSE = 7.8352e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test1 -> R² = -0.3392, MSE = 3.0764e-01
# 31/31 [==============================] - 1s 14ms/step
# Theta | test2 -> R² = -2.3594, MSE = 7.9672e-01
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = 0.0080, MSE = 3.2613e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -3.1264, MSE = 1.3505e+00
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 11ms/step
# Theta | train1 -> R² = 0.9252, MSE = 1.7066e-02
# 31/31 [==============================] - 0s 10ms/step
# Theta | train2 -> R² = 0.3001, MSE = 1.5978e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | test1 -> R² = 0.7586, MSE = 5.5451e-02
# 31/31 [==============================] - 0s 10ms/step
# Theta | test2 -> R² = 0.5331, MSE = 1.1074e-01
# 45/45 [==============================] - 1s 9ms/step
# Theta | test3 -> R² = 0.7405, MSE = 8.5325e-02
# 40/40 [==============================] - 1s 8ms/step
# Theta | val -> R² = -5.8656, MSE = 2.2470e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 8ms/step
# Theta | train1 -> R² = -3.0240, MSE = 9.1855e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -4.0485, MSE = 1.1526e+00
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = -2.1097, MSE = 7.1436e-01
# 31/31 [==============================] - 1s 15ms/step
# Theta | test2 -> R² = -3.8588, MSE = 1.1523e+00
# 45/45 [==============================] - 1s 11ms/step
# Theta | test3 -> R² = -1.8878, MSE = 9.4934e-01
# 40/40 [==============================] - 1s 8ms/step
# Theta | val -> R² = -0.2501, MSE = 4.0913e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 14ms/step
# Theta | train1 -> R² = -0.5583, MSE = 3.5571e-01
# 31/31 [==============================] - 1s 12ms/step
# Theta | train2 -> R² = -1.1311, MSE = 4.8653e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = 0.1507, MSE = 1.9511e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | test2 -> R² = -0.8939, MSE = 4.4916e-01
# 45/45 [==============================] - 1s 12ms/step
# Theta | test3 -> R² = 0.3477, MSE = 2.1445e-01
# 40/40 [==============================] - 1s 10ms/step
# Theta | val -> R² = -3.2205, MSE = 1.3813e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 9ms/step
# Theta | train1 -> R² = -1.5034, MSE = 5.7145e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | train2 -> R² = -2.9180, MSE = 8.9450e-01
# 31/31 [==============================] - 0s 11ms/step
# Theta | test1 -> R² = -1.0868, MSE = 4.7937e-01
# 31/31 [==============================] - 0s 12ms/step
# Theta | test2 -> R² = -2.7518, MSE = 8.8979e-01
# 45/45 [==============================] - 1s 12ms/step
# Theta | test3 -> R² = -1.7939, MSE = 9.1848e-01
# 40/40 [==============================] - 1s 10ms/step
# Theta | val -> R² = -0.6303, MSE = 5.3358e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 4s 8ms/step
# Theta | train1 -> R² = -0.1668, MSE = 2.6634e-01
# 31/31 [==============================] - 1s 9ms/step
# Theta | train2 -> R² = -1.4598, MSE = 5.6158e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | test1 -> R² = -0.1024, MSE = 2.5324e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test2 -> R² = -1.4551, MSE = 5.8226e-01
# 45/45 [==============================] - 1s 10ms/step
# Theta | test3 -> R² = -1.2377, MSE = 7.3562e-01
# 40/40 [==============================] - 1s 9ms/step
# Theta | val -> R² = -1.2133, MSE = 7.2438e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 10ms/step
# Theta | train1 -> R² = -0.1453, MSE = 2.6144e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | train2 -> R² = -1.4757, MSE = 5.6521e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | test1 -> R² = -0.0826, MSE = 2.4869e-01
# 31/31 [==============================] - 0s 10ms/step
# Theta | test2 -> R² = -1.4706, MSE = 5.8593e-01
# 45/45 [==============================] - 1s 11ms/step
# Theta | test3 -> R² = -1.1819, MSE = 7.1728e-01
# 40/40 [==============================] - 0s 8ms/step
# Theta | val -> R² = -1.1649, MSE = 7.0853e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 3s 9ms/step
# Theta | train1 -> R² = -0.1416, MSE = 2.6059e-01
# 31/31 [==============================] - 1s 8ms/step
# Theta | train2 -> R² = -1.4786, MSE = 5.6588e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test1 -> R² = -0.0792, MSE = 2.4790e-01
# 31/31 [==============================] - 0s 8ms/step
# Theta | test2 -> R² = -1.4734, MSE = 5.8661e-01
# 45/45 [==============================] - 1s 11ms/step
# Theta | test3 -> R² = -1.1721, MSE = 7.1406e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -1.1564, MSE = 7.0575e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Theta | train1 -> R² = 0.2845, MSE = 1.6333e-01
# 31/31 [==============================] - 0s 9ms/step
# Theta | train2 -> R² = -0.7691, MSE = 4.0390e-01
# 31/31 [==============================] - 1s 11ms/step
# Theta | test1 -> R² = 0.4973, MSE = 1.1548e-01
# 31/31 [==============================] - 1s 13ms/step
# Theta | test2 -> R² = -0.6134, MSE = 3.8264e-01
# 45/45 [==============================] - 1s 13ms/step
# Theta | test3 -> R² = 0.4260, MSE = 1.8872e-01
# 40/40 [==============================] - 1s 11ms/step
# Theta | val -> R² = -3.4180, MSE = 1.4459e+00
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 8ms/step
# Theta | train1 -> R² = -0.1325, MSE = 2.5851e-01
# 31/31 [==============================] - 0s 7ms/step
# Theta | train2 -> R² = -1.4860, MSE = 5.6757e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test1 -> R² = -0.0708, MSE = 2.4598e-01
# 31/31 [==============================] - 0s 6ms/step
# Theta | test2 -> R² = -1.4807, MSE = 5.8832e-01
# 45/45 [==============================] - 1s 15ms/step
# Theta | test3 -> R² = -1.1479, MSE = 7.0613e-01
# 40/40 [==============================] - 0s 7ms/step
# Theta | val -> R² = -1.1354, MSE = 6.9889e-01
# Modelo 4 treinado e salvo no Excel
