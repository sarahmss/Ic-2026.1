# %% [markdown]
# # RNN
# - 2 Entradas PwmD, PwmE
# - 1 Saida $\Delta \theta $
# - 1 Camada
# - n neurônios

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE", "Theta"]   
TARGET_INT = ["Y"]  
TARGET = ["DeltaY"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
print(OUT_SCALER.mean_, OUT_SCALER.scale_)
# Out:
# [-0.00014637] [0.0554414]

# %%
NormDatasets[0]
# Out:
#      Unnamed: 0     X     Y     Theta    Wd   We  WdRef  WeRef      PwmD  \
# 0          0.00  0.00  0.70 -0.032459  0.00  0.0   0.00   0.00  0.221564
# 1          0.07  0.00  0.70 -0.032459  0.00  0.0   3.28   3.28  0.221564
# 2          0.14  0.00  0.70 -0.032459  0.00  0.0   3.28   3.28  0.803114
# 3          0.21  0.00  0.70 -0.032459  0.06  0.0   3.28   3.28  0.803114
# 4          0.28  0.00  0.70 -0.011465  0.33  0.0   3.28   3.28  1.025343
# ..          ...   ...   ...       ...   ...  ...    ...    ...       ...
# 971       67.97  0.01  0.69 -1.711986  0.00  0.0   0.85   2.03 -0.400134
# 972       68.04  0.01  0.69 -1.711986  0.00  0.0   0.85   2.03 -0.340030
# 973       68.11  0.01  0.69 -1.711986  0.00  0.0   0.85   2.03 -0.340030
# 974       68.18  0.01  0.69 -1.711986  0.00  0.0   0.85   2.03 -0.279927
# 975       68.25  0.01  0.69 -1.711986  0.00  0.0   0.85   2.03 -0.279927
#
#          PwmE   DeltaY
# 0    0.111917  0.00264
# 1    0.111917  0.00264
# 2    0.594038  0.00264
# 3    0.594038  0.00264
# 4    0.786494  0.00264
# ..        ...      ...
# 971 -0.179313  0.00264
# 972 -0.062625  0.00264
# 973 -0.062625  0.00264
# 974  0.056412  0.00264
# 975  0.056412  0.00264
#
# [976 rows x 11 columns]

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
import matplotlib.pyplot as plt

def PlotHistory(history):
    plt.figure(figsize=(8, 5))
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('MSE Loss')
    plt.title('Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def PlotOut(ax, title, target_name, y_true, y_pred):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true, marker='o', s=12, label='Amostras Reais', alpha=0.7)
    ax.scatter(time, y_pred, marker='x', s=12, label='Valores Preditos', alpha=0.7)
    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    n_targets = len(TARGET)

    metrics = {name: {"R2_train1": [], "R2_train2": [],
                      "R2_test1": [], "R2_test2": [],
                      "R2_test3": [],"R2_val": [],
                      "MSE_train1": [], "MSE_train2": [],
                      "MSE_test1": [], "MSE_test2": [],
                      "MSE_test3": [], "MSE_val": [],} for name in TARGET_INT}

    for i, dataset in enumerate(NormDatasets):
        x = dataset[PREDICTORS]
        y = dataset[TARGET]
        x, y = CreateSequences(x, y, TIME_STEPS)

        y_pred_diff = OUT_SCALER.inverse_transform(model.predict(x))
        y_diff = OUT_SCALER.inverse_transform(y)
        
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)

        # valores iniciais reais (não normalizados)
        init_vals = np.array([
            Datasets[i]["Theta"].iloc[0],
            Datasets[i]["X"].iloc[0],
            Datasets[i]["Y"].iloc[0]
        ])

        # reconstrução cumulativa saída a saída
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)


        # Calcula métricas por saída
        for j, name in enumerate(TARGET_INT):
            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])
            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> R² = {r2:.4f}, MSE = {mse:.4e}")
            
    # Retorna métricas médias para análise posterior
    return metrics

# %%
import numpy as np
import pandas as pd
from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras import initializers
from keras import regularizers
from itertools import product

# tamanho da entrada
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET) 
N_MODELS = 5  # número de inicializações

seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

# arquiteturas das camadas ocultas
architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

for arch,  r in product(architectures, r_values):
    for i, s in enumerate(seeds):

        initializer = initializers.RandomNormal(seed=int(s))
        regularizer = regularizers.l2(r)

        model = keras.models.Sequential()
        model.add(keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

        # adiciona camadas RNN
        for j, n in enumerate(arch):

            # se não for a última camada RNN
            if j < len(arch) - 1:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                model.add(
                    keras.layers.SimpleRNN(
                        n,
                        activation="tanh",
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada de saída
        model.add(
            keras.layers.Dense(
                OUTPUT_SIZE,
                activation="linear",
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )
        # salva pesos iniciais
        w0 = model.get_weights()

        # compila
        model.compile(loss="mean_squared_error", optimizer="adam")
        early_stopping_monitor = EarlyStopping(
            monitor='val_loss',
            patience=50,
            restore_best_weights=True
        )

        history = model.fit(
            x_train, 
            y_train, 
            epochs=1000,
            callbacks=[early_stopping_monitor],
            validation_data=(x_val, y_val),
            verbose=0
        )
        
    
        # salva pesos finais
        wf = model.get_weights()

       # avalia o modelo
        metrics = EvalModel(model)


        row = {
            "model": f"model_{n}_{i}",
            "Neurons": n,
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }


        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })
        
        df = pd.DataFrame([row])

        # salva/atualiza Excel incrementalmente
        try:
            # tenta abrir existente e adicionar linha
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            # se não existir, cria arquivo novo
            df.to_excel(excel_file, index=False)

        print(f"Modelo {i} treinado e salvo no Excel")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.7993, MSE = 1.6822e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.5647, MSE = 4.6877e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.7404, MSE = 2.1277e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = 0.4475, MSE = 5.8646e-02
# 45/45 [==============================] - 1s 7ms/step
# Y | test3 -> R² = 0.7687, MSE = 1.7765e-02
# 40/40 [==============================] - 1s 8ms/step
# Y | val -> R² = 0.5499, MSE = 3.3512e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 8ms/step
# Y | train1 -> R² = 0.7584, MSE = 2.0242e-02
# 31/31 [==============================] - 1s 5ms/step
# Y | train2 -> R² = 0.6741, MSE = 3.5087e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.6864, MSE = 2.5698e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.7624, MSE = 2.5216e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.5067, MSE = 3.7890e-02
# 40/40 [==============================] - 1s 8ms/step
# Y | val -> R² = 0.4049, MSE = 4.4308e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 8ms/step
# Y | train1 -> R² = 0.0991, MSE = 7.5495e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.8250, MSE = 1.8848e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.0434, MSE = 8.5508e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.7516, MSE = 2.6370e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.9621, MSE = 2.9122e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9427, MSE = 4.2673e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Y | train1 -> R² = 0.6616, MSE = 2.8352e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.9086, MSE = 9.8415e-03
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.5891, MSE = 3.3671e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.9405, MSE = 6.3160e-03
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.8359, MSE = 1.2606e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.7410, MSE = 1.9280e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.4665, MSE = 4.4707e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.9429, MSE = 6.1483e-03
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.3573, MSE = 5.2669e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = 0.9565, MSE = 4.6154e-03
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.9702, MSE = 2.2915e-03
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = 0.9232, MSE = 5.7160e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.6499, MSE = 2.9335e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.7942, MSE = 2.2155e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | test1 -> R² = 0.5775, MSE = 3.4621e-02
# 31/31 [==============================] - 1s 7ms/step
# Y | test2 -> R² = 0.7227, MSE = 2.9433e-02
# 45/45 [==============================] - 1s 7ms/step
# Y | test3 -> R² = 0.5685, MSE = 3.3146e-02
# 40/40 [==============================] - 1s 9ms/step
# Y | val -> R² = 0.9139, MSE = 6.4083e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.4664, MSE = 4.4714e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.8022, MSE = 2.1295e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.3761, MSE = 5.1127e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.8475, MSE = 1.6191e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.8960, MSE = 7.9862e-03
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.9251, MSE = 5.5726e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.6545, MSE = 2.8949e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.8422, MSE = 1.6993e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.5637, MSE = 3.5753e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.8562, MSE = 1.5259e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.8429, MSE = 1.2065e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9557, MSE = 3.2944e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.6702, MSE = 2.7633e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | train2 -> R² = 0.8235, MSE = 1.9004e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.5968, MSE = 3.3044e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = 0.7329, MSE = 2.8350e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.7878, MSE = 1.6301e-02
# 40/40 [==============================] - 1s 7ms/step
# Y | val -> R² = 0.9325, MSE = 5.0290e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.7555, MSE = 2.0492e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.9164, MSE = 9.0004e-03
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.6777, MSE = 2.6411e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.9369, MSE = 6.6927e-03
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.5754, MSE = 3.2613e-02
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.6921, MSE = 2.2924e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 3ms/step
# Y | train1 -> R² = 0.6901, MSE = 2.5971e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | train2 -> R² = 0.2481, MSE = 8.0964e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test1 -> R² = 0.6269, MSE = 3.0575e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test2 -> R² = 0.0491, MSE = 1.0093e-01
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.7661, MSE = 1.7969e-02
# 40/40 [==============================] - 0s 3ms/step
# Y | val -> R² = 0.9000, MSE = 7.4438e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.6346, MSE = 3.0617e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.1031, MSE = 9.6576e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test1 -> R² = 0.5573, MSE = 3.6277e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test2 -> R² = -0.0980, MSE = 1.1655e-01
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.8746, MSE = 9.6346e-03
# 40/40 [==============================] - 0s 3ms/step
# Y | val -> R² = 0.8862, MSE = 8.4745e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.4149, MSE = 4.9025e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.6225, MSE = 4.0650e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.2897, MSE = 5.8210e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.6659, MSE = 3.5461e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.9363, MSE = 4.8895e-03
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.9234, MSE = 5.7048e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.7945, MSE = 1.7224e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.8727, MSE = 1.3709e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.7354, MSE = 2.1685e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.8589, MSE = 1.4975e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.6955, MSE = 2.3388e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.8252, MSE = 1.3017e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.6644, MSE = 2.8121e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.8178, MSE = 1.9620e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test1 -> R² = 0.6065, MSE = 3.2250e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.7540, MSE = 2.6112e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.7935, MSE = 1.5862e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9209, MSE = 5.8904e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.3654, MSE = 5.3177e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -0.0574, MSE = 1.1386e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.2723, MSE = 5.9638e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.1209, MSE = 9.3306e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.8888, MSE = 8.5399e-03
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.8656, MSE = 1.0007e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -0.0878, MSE = 9.1151e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.9823, MSE = 1.9110e-03
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -0.2524, MSE = 1.0263e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.9660, MSE = 3.6094e-03
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.8358, MSE = 1.2612e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.9725, MSE = 2.0445e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.2221, MSE = 6.5184e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.9866, MSE = 1.4443e-03
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.1058, MSE = 7.3281e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.9608, MSE = 4.1570e-03
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.9741, MSE = 1.9908e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9148, MSE = 6.3445e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Y | train1 -> R² = 0.0785, MSE = 7.7217e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.9774, MSE = 2.4309e-03
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.0525, MSE = 8.6252e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.9585, MSE = 4.3997e-03
# 45/45 [==============================] - 1s 6ms/step
# Y | test3 -> R² = 0.8957, MSE = 8.0073e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9633, MSE = 2.7304e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Y | train1 -> R² = 0.4031, MSE = 5.0015e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.5328, MSE = 5.0305e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.3156, MSE = 5.6090e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.4435, MSE = 5.9068e-02
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.9718, MSE = 2.1651e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.8648, MSE = 1.0062e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.4189, MSE = 4.8696e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.9408, MSE = 6.3728e-03
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.2932, MSE = 5.7925e-02
# 31/31 [==============================] - 1s 4ms/step
# Y | test2 -> R² = 0.9485, MSE = 5.4703e-03
# 45/45 [==============================] - 1s 6ms/step
# Y | test3 -> R² = 0.9394, MSE = 4.6559e-03
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.9056, MSE = 7.0291e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = -0.4693, MSE = 1.2312e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = -0.2852, MSE = 1.3838e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.6987, MSE = 1.3921e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -0.4333, MSE = 1.5213e-01
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.3506, MSE = 4.9879e-02
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.7320, MSE = 1.9951e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.4785, MSE = 4.3698e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.9430, MSE = 6.1423e-03
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.3925, MSE = 4.9784e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.9536, MSE = 4.9262e-03
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.8482, MSE = 1.1662e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.8873, MSE = 8.3911e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.7685, MSE = 1.9398e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -0.7288, MSE = 1.8615e-01
# 31/31 [==============================] - 1s 6ms/step
# Y | test1 -> R² = 0.6950, MSE = 2.4995e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -0.4219, MSE = 1.5092e-01
# 45/45 [==============================] - 1s 7ms/step
# Y | test3 -> R² = 0.5062, MSE = 3.7927e-02
# 40/40 [==============================] - 1s 6ms/step
# Y | val -> R² = 0.8458, MSE = 1.1477e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.6455, MSE = 2.9708e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = -0.3623, MSE = 1.4669e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.5484, MSE = 3.7008e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = -0.0636, MSE = 1.1289e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.8203, MSE = 1.3804e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.8046, MSE = 1.4545e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.3584, MSE = 5.3764e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.8331, MSE = 1.7974e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.2200, MSE = 6.3921e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test2 -> R² = 0.7392, MSE = 2.7686e-02
# 45/45 [==============================] - 0s 3ms/step
# Y | test3 -> R² = 0.9336, MSE = 5.1012e-03
# 40/40 [==============================] - 0s 3ms/step
# Y | val -> R² = 0.9413, MSE = 4.3680e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.5300, MSE = 3.9380e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.8232, MSE = 1.9034e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.4360, MSE = 4.6218e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.7168, MSE = 3.0062e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.6098, MSE = 2.9969e-02
# 40/40 [==============================] - 1s 5ms/step
# Y | val -> R² = 0.9350, MSE = 4.8369e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Y | train1 -> R² = 0.5895, MSE = 3.4398e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.8319, MSE = 1.8101e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.5392, MSE = 3.7758e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test2 -> R² = 0.7399, MSE = 2.7607e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.7890, MSE = 1.6203e-02
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.9498, MSE = 3.7373e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Y | train1 -> R² = 0.8956, MSE = 8.7508e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.5657, MSE = 4.6762e-02
# 31/31 [==============================] - 1s 8ms/step
# Y | test1 -> R² = 0.8723, MSE = 1.0461e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.4154, MSE = 6.2053e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.1475, MSE = 6.5475e-02
# 40/40 [==============================] - 1s 6ms/step
# Y | val -> R² = 0.6312, MSE = 2.7457e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = -0.1074, MSE = 9.2798e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.8164, MSE = 1.9766e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -0.2397, MSE = 1.0159e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.7206, MSE = 2.9655e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.9536, MSE = 3.5624e-03
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.8720, MSE = 9.5279e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.4208, MSE = 4.8532e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.0061, MSE = 1.0702e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.3062, MSE = 5.6856e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -0.1691, MSE = 1.2409e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.9185, MSE = 6.2618e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.8624, MSE = 1.0247e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.7207, MSE = 2.3404e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.6354, MSE = 3.9258e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.6590, MSE = 2.7944e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.6754, MSE = 3.4456e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.9050, MSE = 7.2930e-03
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.7619, MSE = 1.7729e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.1366, MSE = 7.2345e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.9498, MSE = 5.4079e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.0431, MSE = 7.8414e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.9397, MSE = 6.3957e-03
# 45/45 [==============================] - 1s 6ms/step
# Y | test3 -> R² = 0.9112, MSE = 6.8223e-03
# 40/40 [==============================] - 1s 8ms/step
# Y | val -> R² = 0.8252, MSE = 1.3012e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.6454, MSE = 2.9716e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -0.2537, MSE = 1.3499e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.5708, MSE = 3.5173e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = -0.5392, MSE = 1.6338e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.8898, MSE = 8.4617e-03
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.8676, MSE = 9.8582e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.1971, MSE = 6.7281e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.8685, MSE = 1.4161e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.1067, MSE = 7.3204e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.8389, MSE = 1.7102e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.7320, MSE = 2.0588e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9928, MSE = 5.3724e-04
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -0.2764, MSE = 1.0696e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.8509, MSE = 1.6051e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -0.3774, MSE = 1.1288e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.7592, MSE = 2.5555e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.8161, MSE = 1.4122e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.8948, MSE = 7.8318e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 7ms/step
# Y | train1 -> R² = 0.5332, MSE = 3.9120e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.9718, MSE = 3.0326e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.4300, MSE = 4.6710e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.9362, MSE = 6.7700e-03
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.9595, MSE = 3.1119e-03
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.8994, MSE = 7.4870e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = -0.6048, MSE = 1.3448e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.8712, MSE = 1.3872e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.8167, MSE = 1.4887e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.7824, MSE = 2.3101e-02
# 45/45 [==============================] - 1s 8ms/step
# Y | test3 -> R² = 0.7104, MSE = 2.2245e-02
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.8543, MSE = 1.0846e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.6513, MSE = 2.9223e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.6235, MSE = 4.0538e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.6070, MSE = 3.2209e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.6749, MSE = 3.4502e-02
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.7533, MSE = 1.8945e-02
# 40/40 [==============================] - 1s 5ms/step
# Y | val -> R² = 0.7853, MSE = 1.5988e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -0.2058, MSE = 1.0104e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = -1.5510, MSE = 2.7469e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.4081, MSE = 1.1539e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -1.1919, MSE = 2.3265e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.8960, MSE = 7.9865e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9397, MSE = 4.4898e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.1218, MSE = 7.3592e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | train2 -> R² = -0.7751, MSE = 1.9114e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -0.0139, MSE = 8.3088e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -0.5613, MSE = 1.6572e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.8283, MSE = 1.3187e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9751, MSE = 1.8533e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.5405, MSE = 3.8507e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -1.0213, MSE = 2.1765e-01
# 31/31 [==============================] - 1s 8ms/step
# Y | test1 -> R² = 0.5032, MSE = 4.0709e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = -1.1442, MSE = 2.2760e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.0692, MSE = 7.1490e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.2135, MSE = 5.8556e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.1077, MSE = 7.4769e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.7410, MSE = 2.7891e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.0477, MSE = 8.5855e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.7729, MSE = 2.4102e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.9527, MSE = 3.6318e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9780, MSE = 1.6342e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.4137, MSE = 4.9130e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.9310, MSE = 7.4323e-03
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.3145, MSE = 5.6175e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.9214, MSE = 8.3435e-03
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.9394, MSE = 4.6559e-03
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.9406, MSE = 4.4198e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = -0.1923, MSE = 9.9914e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -1.7062, MSE = 2.9140e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -0.3066, MSE = 1.0708e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = -1.8023, MSE = 2.9745e-01
# 45/45 [==============================] - 0s 7ms/step
# Y | test3 -> R² = 0.9534, MSE = 3.5824e-03
# 40/40 [==============================] - 1s 6ms/step
# Y | val -> R² = 0.6944, MSE = 2.2752e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.1699, MSE = 6.9561e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.8893, MSE = 1.1916e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.0738, MSE = 7.5900e-02
# 31/31 [==============================] - 1s 9ms/step
# Y | test2 -> R² = 0.8185, MSE = 1.9270e-02
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.9472, MSE = 4.0578e-03
# 40/40 [==============================] - 1s 8ms/step
# Y | val -> R² = 0.8396, MSE = 1.1944e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Y | train1 -> R² = 0.6916, MSE = 2.5839e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.6877, MSE = 3.3623e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.6464, MSE = 2.8978e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.7837, MSE = 2.2955e-02
# 45/45 [==============================] - 1s 8ms/step
# Y | test3 -> R² = 0.7208, MSE = 2.1441e-02
# 40/40 [==============================] - 1s 9ms/step
# Y | val -> R² = 0.3498, MSE = 4.8406e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.6967, MSE = 2.5415e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.9099, MSE = 9.7041e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.6316, MSE = 3.0188e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.8367, MSE = 1.7335e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.8065, MSE = 1.4859e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.6575, MSE = 2.5501e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Y | train1 -> R² = -0.1669, MSE = 9.7782e-02
# 31/31 [==============================] - 1s 6ms/step
# Y | train2 -> R² = 0.9228, MSE = 8.3129e-03
# 31/31 [==============================] - 0s 8ms/step
# Y | test1 -> R² = -0.2665, MSE = 1.0379e-01
# 31/31 [==============================] - 1s 7ms/step
# Y | test2 -> R² = 0.8570, MSE = 1.5181e-02
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.9262, MSE = 5.6650e-03
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = 0.8524, MSE = 1.0992e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.0268, MSE = 8.1554e-02
# 31/31 [==============================] - 1s 6ms/step
# Y | train2 -> R² = 0.6566, MSE = 3.6975e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -0.0695, MSE = 8.7641e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = 0.7505, MSE = 2.6483e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.9401, MSE = 4.6040e-03
# 40/40 [==============================] - 1s 9ms/step
# Y | val -> R² = 0.7482, MSE = 1.8744e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.0361, MSE = 8.0768e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -2.5898, MSE = 3.8654e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.2022, MSE = 9.8518e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -2.9760, MSE = 4.2203e-01
# 45/45 [==============================] - 0s 8ms/step
# Y | test3 -> R² = 0.9179, MSE = 6.3053e-03
# 40/40 [==============================] - 1s 7ms/step
# Y | val -> R² = 0.9748, MSE = 1.8758e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Y | train1 -> R² = 0.3034, MSE = 5.8372e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.7135, MSE = 3.0848e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.2213, MSE = 6.3817e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.8025, MSE = 2.0968e-02
# 45/45 [==============================] - 1s 8ms/step
# Y | test3 -> R² = 0.8989, MSE = 7.7618e-03
# 40/40 [==============================] - 1s 7ms/step
# Y | val -> R² = 0.9089, MSE = 6.7830e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 10ms/step
# Y | train1 -> R² = 0.6188, MSE = 3.1944e-02
# 31/31 [==============================] - 1s 10ms/step
# Y | train2 -> R² = 0.9002, MSE = 1.0744e-02
# 31/31 [==============================] - 1s 8ms/step
# Y | test1 -> R² = 0.5132, MSE = 3.9896e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | test2 -> R² = 0.8320, MSE = 1.7832e-02
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.9108, MSE = 6.8488e-03
# 40/40 [==============================] - 1s 7ms/step
# Y | val -> R² = 0.9136, MSE = 6.4337e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Y | train1 -> R² = -0.4358, MSE = 1.2031e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -1.9087, MSE = 3.1320e-01
# 31/31 [==============================] - 1s 9ms/step
# Y | test1 -> R² = -0.6495, MSE = 1.3518e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = -2.2664, MSE = 3.4671e-01
# 45/45 [==============================] - 1s 7ms/step
# Y | test3 -> R² = 0.1861, MSE = 6.2516e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.6413, MSE = 2.6704e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.8035, MSE = 1.6466e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.7926, MSE = 2.2337e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.7356, MSE = 2.1670e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.6969, MSE = 3.2174e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.8723, MSE = 9.8116e-03
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.8577, MSE = 1.0596e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.2240, MSE = 6.5030e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.9333, MSE = 7.1794e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.0978, MSE = 7.3935e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.9429, MSE = 6.0606e-03
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.9521, MSE = 3.6811e-03
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = 0.9573, MSE = 3.1816e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.7722, MSE = 1.9090e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.9824, MSE = 1.8902e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.6982, MSE = 2.4729e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.9720, MSE = 2.9770e-03
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.5622, MSE = 3.3629e-02
# 40/40 [==============================] - 0s 8ms/step
# Y | val -> R² = 0.5652, MSE = 3.2373e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = -0.2638, MSE = 1.0590e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.9203, MSE = 8.5776e-03
# 31/31 [==============================] - 0s 9ms/step
# Y | test1 -> R² = -0.4274, MSE = 1.1698e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = 0.8893, MSE = 1.1753e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.4070, MSE = 4.5545e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.8290, MSE = 1.2730e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = 0.5679, MSE = 3.6210e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.1394, MSE = 9.2670e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.4711, MSE = 4.3343e-02
# 31/31 [==============================] - 0s 3ms/step
# Y | test2 -> R² = 0.3024, MSE = 7.4042e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.5886, MSE = 3.1599e-02
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.6880, MSE = 2.3231e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.0766, MSE = 7.7380e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.5951, MSE = 4.3596e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -0.0898, MSE = 8.9311e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.6980, MSE = 3.2051e-02
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.9166, MSE = 6.4070e-03
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.9347, MSE = 4.8621e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Y | train1 -> R² = 0.8078, MSE = 1.6101e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.9659, MSE = 3.6679e-03
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.7680, MSE = 1.9013e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.9677, MSE = 3.4323e-03
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.6543, MSE = 2.6556e-02
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.7028, MSE = 2.2127e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Y | train1 -> R² = -3.6973, MSE = 3.9361e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -3.7872, MSE = 5.1547e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -3.4167, MSE = 3.6195e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -4.2455, MSE = 5.5677e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = -16.5185, MSE = 1.3456e+00
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = -12.7123, MSE = 1.0209e+00
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Y | train1 -> R² = -3.8356, MSE = 4.0521e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -4.0159, MSE = 5.4010e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -3.5473, MSE = 3.7265e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = -4.4753, MSE = 5.8116e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -17.0258, MSE = 1.3845e+00
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = -13.1523, MSE = 1.0536e+00
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.7880, MSE = 1.7763e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.5679, MSE = 4.6525e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.7505, MSE = 2.0444e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.4281, MSE = 6.0700e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.6980, MSE = 2.3196e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.7357, MSE = 1.9680e-02
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.4726, MSE = 4.4198e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = 0.4977, MSE = 5.4089e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = 0.5526, MSE = 3.6668e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.3764, MSE = 6.6194e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = -3.8721, MSE = 3.7421e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -1.6171, MSE = 1.9484e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Y | train1 -> R² = -1.5179, MSE = 2.1099e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.2677, MSE = 3.5186e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -1.6858, MSE = 2.2010e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = -2.2077, MSE = 3.4047e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0410, MSE = 2.3357e-01
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = -1.8285, MSE = 2.1058e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Y | train1 -> R² = -1.5189, MSE = 2.1107e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -2.2686, MSE = 3.5195e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -1.6869, MSE = 2.2018e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.2085, MSE = 3.4056e-01
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = -2.0428, MSE = 2.3371e-01
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = -1.8301, MSE = 2.1070e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Y | train1 -> R² = -1.5139, MSE = 2.1065e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = -2.2643, MSE = 3.5149e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -1.6816, MSE = 2.1975e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.2042, MSE = 3.4011e-01
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = -2.0337, MSE = 2.3301e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -1.8221, MSE = 2.1011e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 5ms/step
# Y | train1 -> R² = -1.5201, MSE = 2.1117e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -2.2696, MSE = 3.5207e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -1.6881, MSE = 2.2029e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = -2.2096, MSE = 3.4067e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = -2.0450, MSE = 2.3388e-01
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = -1.8320, MSE = 2.1084e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -1.5194, MSE = 2.1112e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.2690, MSE = 3.5200e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -1.6874, MSE = 2.2023e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.2090, MSE = 3.4061e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0437, MSE = 2.3378e-01
# 40/40 [==============================] - 0s 8ms/step
# Y | val -> R² = -1.8309, MSE = 2.1076e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -1.5226, MSE = 2.1138e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.2718, MSE = 3.5230e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -1.6908, MSE = 2.2051e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.2117, MSE = 3.4090e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0495, MSE = 2.3422e-01
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = -1.8360, MSE = 2.1114e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = -1.5315, MSE = 2.1213e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -2.2795, MSE = 3.5313e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -1.7002, MSE = 2.2128e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -2.2193, MSE = 3.4170e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0657, MSE = 2.3547e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -1.8501, MSE = 2.1219e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Y | train1 -> R² = -1.5234, MSE = 2.1145e-01
# 31/31 [==============================] - 1s 6ms/step
# Y | train2 -> R² = -2.2725, MSE = 3.5238e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -1.6916, MSE = 2.2058e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = -2.2124, MSE = 3.4097e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0510, MSE = 2.3434e-01
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = -1.8373, MSE = 2.1124e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -1.5303, MSE = 2.1203e-01
# 31/31 [==============================] - 0s 3ms/step
# Y | train2 -> R² = -2.2784, MSE = 3.5302e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -1.6989, MSE = 2.2117e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.2182, MSE = 3.4159e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0635, MSE = 2.3530e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -1.8482, MSE = 2.1205e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 4ms/step
# Y | train1 -> R² = -1.5257, MSE = 2.1164e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.2745, MSE = 3.5259e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -1.6940, MSE = 2.2077e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.2143, MSE = 3.4118e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -2.0551, MSE = 2.3465e-01
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = -1.8409, MSE = 2.1150e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.7714, MSE = 1.9159e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = 0.8135, MSE = 2.0084e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.7172, MSE = 2.3172e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.7231, MSE = 2.9389e-02
# 45/45 [==============================] - 0s 4ms/step
# Y | test3 -> R² = 0.7446, MSE = 1.9616e-02
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = 0.7840, MSE = 1.6081e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.9302, MSE = 5.8496e-03
# 31/31 [==============================] - 0s 8ms/step
# Y | train2 -> R² = 0.4510, MSE = 5.9111e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.8884, MSE = 9.1436e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = 0.4070, MSE = 6.2938e-02
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = 0.4837, MSE = 3.9657e-02
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = 0.3855, MSE = 4.5746e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 11ms/step
# Y | train1 -> R² = 0.7307, MSE = 2.2563e-02
# 31/31 [==============================] - 0s 6ms/step
# ...
# Y | train1 -> R² = 0.1896, MSE = 6.7909e-02
# 31/31 [==============================] - 1s 16ms/step
# Y | train2 -> R² = 0.5640, MSE = 4.6950e-02
# 31/31 [==============================] - 1s 13ms/step
# Y | test1 -> R² = 0.0612, MSE = 7.6935e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | test2 -> R² = 0.4878, MSE = 5.4362e-02
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = 0.9394, MSE = 4.6565e-03
# 40/40 [==============================] - 0s 8ms/step
# Y | val -> R² = 0.9703, MSE = 2.2149e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = 0.6388, MSE = 3.0266e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -1.9369, MSE = 3.1624e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = 0.6958, MSE = 2.4929e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | test2 -> R² = -2.1079, MSE = 3.2988e-01
# 45/45 [==============================] - 1s 15ms/step
# Y | test3 -> R² = -3.9898, MSE = 3.8326e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -1.3742, MSE = 1.7676e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Y | train1 -> R² = 0.6890, MSE = 2.6064e-02
# 31/31 [==============================] - 1s 18ms/step
# Y | train2 -> R² = -1.9311, MSE = 3.1562e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.7443, MSE = 2.0957e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = -2.2571, MSE = 3.4572e-01
# 45/45 [==============================] - 1s 8ms/step
# Y | test3 -> R² = -2.8326, MSE = 2.9437e-01
# 40/40 [==============================] - 1s 7ms/step
# Y | val -> R² = -1.1006, MSE = 1.5639e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 5ms/step
# Y | train1 -> R² = 0.4423, MSE = 4.6730e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.1743, MSE = 3.4180e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.4869, MSE = 4.2050e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.4467, MSE = 3.6584e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -3.5818, MSE = 3.5192e-01
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = -1.8202, MSE = 2.0997e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 3s 8ms/step
# Y | train1 -> R² = 0.5537, MSE = 3.7400e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | train2 -> R² = -2.3120, MSE = 3.5664e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test1 -> R² = 0.6082, MSE = 3.2107e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | test2 -> R² = -2.6092, MSE = 3.8309e-01
# 45/45 [==============================] - 0s 7ms/step
# Y | test3 -> R² = -4.6559, MSE = 4.3442e-01
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = -1.8499, MSE = 2.1218e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Y | train1 -> R² = -0.0300, MSE = 8.6310e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | train2 -> R² = -2.3465, MSE = 3.6034e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test1 -> R² = 0.0200, MSE = 8.0310e-02
# 31/31 [==============================] - 1s 14ms/step
# Y | test2 -> R² = -2.6548, MSE = 3.8793e-01
# 45/45 [==============================] - 1s 10ms/step
# Y | test3 -> R² = -6.2794, MSE = 5.5911e-01
# 40/40 [==============================] - 1s 8ms/step
# Y | val -> R² = -3.3889, MSE = 3.2676e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 3s 7ms/step
# Y | train1 -> R² = -0.1276, MSE = 9.4490e-02
# 31/31 [==============================] - 0s 13ms/step
# Y | train2 -> R² = -3.3997, MSE = 4.7375e-01
# 31/31 [==============================] - 1s 17ms/step
# Y | test1 -> R² = -0.0140, MSE = 8.3097e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | test2 -> R² = -3.6837, MSE = 4.9714e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -5.3753, MSE = 4.8967e-01
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = -3.5965, MSE = 3.4221e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 3s 6ms/step
# Y | train1 -> R² = 0.0538, MSE = 7.9286e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | train2 -> R² = -4.4098, MSE = 5.8252e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.1591, MSE = 6.8914e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = -4.7861, MSE = 6.1415e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -4.0675, MSE = 3.8922e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -3.1057, MSE = 3.0567e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 1s 7ms/step
# Y | train1 -> R² = -1.7234, MSE = 2.2821e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.6827, MSE = 3.9655e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | test1 -> R² = -1.5577, MSE = 2.0960e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.9788, MSE = 4.2233e-01
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = -11.2057, MSE = 9.3749e-01
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = -7.8781, MSE = 6.6097e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 4s 10ms/step
# Y | train1 -> R² = -0.7545, MSE = 1.4702e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -1.9449, MSE = 3.1710e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = -0.6279, MSE = 1.3340e-01
# 31/31 [==============================] - 1s 13ms/step
# Y | test2 -> R² = -2.1564, MSE = 3.3503e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = -5.7353, MSE = 5.1732e-01
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = -5.0467, MSE = 4.5018e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 4ms/step
# Y | train1 -> R² = -1.2309, MSE = 1.8694e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = -2.4921, MSE = 3.7603e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -1.0806, MSE = 1.7050e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = -2.7596, MSE = 3.9905e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = -9.1803, MSE = 7.8192e-01
# 40/40 [==============================] - 0s 4ms/step
# Y | val -> R² = -6.5835, MSE = 5.6459e-01
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 5s 18ms/step
# Y | train1 -> R² = 0.1403, MSE = 7.2040e-02
# 31/31 [==============================] - 1s 12ms/step
# Y | train2 -> R² = -1.6763, MSE = 2.8818e-01
# 31/31 [==============================] - 1s 18ms/step
# Y | test1 -> R² = 0.0486, MSE = 7.7968e-02
# 31/31 [==============================] - 1s 16ms/step
# Y | test2 -> R² = -1.9350, MSE = 3.1153e-01
# 45/45 [==============================] - 1s 15ms/step
# Y | test3 -> R² = 0.9326, MSE = 5.1784e-03
# 40/40 [==============================] - 1s 12ms/step
# Y | val -> R² = 0.9110, MSE = 6.6286e-03
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Y | train1 -> R² = 0.5416, MSE = 3.8409e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = 0.9215, MSE = 8.4551e-03
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = 0.4697, MSE = 4.3458e-02
# 31/31 [==============================] - 0s 11ms/step
# Y | test2 -> R² = 0.8606, MSE = 1.4802e-02
# 45/45 [==============================] - 0s 8ms/step
# Y | test3 -> R² = 0.9411, MSE = 4.5273e-03
# 40/40 [==============================] - 0s 8ms/step
# Y | val -> R² = 0.9220, MSE = 5.8054e-03
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 4s 12ms/step
# Y | train1 -> R² = -0.3132, MSE = 1.1004e-01
# 31/31 [==============================] - 1s 12ms/step
# Y | train2 -> R² = -1.7233, MSE = 2.9323e-01
# 31/31 [==============================] - 1s 13ms/step
# Y | test1 -> R² = -0.4407, MSE = 1.1806e-01
# 31/31 [==============================] - 1s 11ms/step
# Y | test2 -> R² = -2.1853, MSE = 3.3810e-01
# 45/45 [==============================] - 1s 12ms/step
# Y | test3 -> R² = 0.5060, MSE = 3.7945e-02
# 40/40 [==============================] - 1s 10ms/step
# Y | val -> R² = 0.9609, MSE = 2.9101e-03
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = -0.1536, MSE = 9.6667e-02
# 31/31 [==============================] - 0s 4ms/step
# Y | train2 -> R² = 0.9083, MSE = 9.8725e-03
# 31/31 [==============================] - 0s 4ms/step
# Y | test1 -> R² = -0.2872, MSE = 1.0549e-01
# 31/31 [==============================] - 0s 4ms/step
# Y | test2 -> R² = 0.9378, MSE = 6.6056e-03
# 45/45 [==============================] - 0s 5ms/step
# Y | test3 -> R² = 0.6202, MSE = 2.9173e-02
# 40/40 [==============================] - 0s 5ms/step
# Y | val -> R² = 0.9570, MSE = 3.1981e-03
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 3s 12ms/step
# Y | train1 -> R² = 0.4706, MSE = 4.4360e-02
# 31/31 [==============================] - 0s 9ms/step
# Y | train2 -> R² = 0.8596, MSE = 1.5117e-02
# 31/31 [==============================] - 0s 10ms/step
# Y | test1 -> R² = 0.3676, MSE = 5.1828e-02
# 31/31 [==============================] - 1s 13ms/step
# Y | test2 -> R² = 0.7397, MSE = 2.7627e-02
# 45/45 [==============================] - 1s 11ms/step
# Y | test3 -> R² = 0.9705, MSE = 2.2676e-03
# 40/40 [==============================] - 1s 12ms/step
# Y | val -> R² = 0.9667, MSE = 2.4823e-03
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 2s 8ms/step
# Y | train1 -> R² = 0.9422, MSE = 4.8404e-03
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -1.5314, MSE = 2.7257e-01
# 31/31 [==============================] - 0s 8ms/step
# Y | test1 -> R² = 0.9243, MSE = 6.2047e-03
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = -1.7431, MSE = 2.9117e-01
# 45/45 [==============================] - 0s 7ms/step
# Y | test3 -> R² = 0.0750, MSE = 7.1045e-02
# 40/40 [==============================] - 0s 7ms/step
# Y | val -> R² = 0.8248, MSE = 1.3040e-02
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 6ms/step
# Y | train1 -> R² = 0.8440, MSE = 1.3074e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | train2 -> R² = -1.9385, MSE = 3.1641e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.8641, MSE = 1.1140e-02
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -2.0716, MSE = 3.2603e-01
# 45/45 [==============================] - 0s 7ms/step
# Y | test3 -> R² = -0.7150, MSE = 1.3172e-01
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.3100, MSE = 5.1368e-02
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 4s 14ms/step
# Y | train1 -> R² = 0.9524, MSE = 3.9853e-03
# 31/31 [==============================] - 0s 10ms/step
# Y | train2 -> R² = 0.4841, MSE = 5.5550e-02
# 31/31 [==============================] - 0s 11ms/step
# Y | test1 -> R² = 0.9399, MSE = 4.9234e-03
# 31/31 [==============================] - 1s 13ms/step
# Y | test2 -> R² = 0.4018, MSE = 6.3492e-02
# 45/45 [==============================] - 1s 10ms/step
# Y | test3 -> R² = -0.2814, MSE = 9.8420e-02
# 40/40 [==============================] - 1s 10ms/step
# Y | val -> R² = 0.7542, MSE = 1.8298e-02
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 1s 7ms/step
# Y | train1 -> R² = 0.8322, MSE = 1.4061e-02
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = -0.9409, MSE = 2.0899e-01
# 31/31 [==============================] - 0s 10ms/step
# Y | test1 -> R² = 0.8679, MSE = 1.0824e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = -1.1249, MSE = 2.2554e-01
# 45/45 [==============================] - 0s 8ms/step
# Y | test3 -> R² = -2.8174, MSE = 2.9320e-01
# 40/40 [==============================] - 0s 8ms/step
# Y | val -> R² = -0.4953, MSE = 1.1132e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.9462, MSE = 4.5107e-03
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -0.0435, MSE = 1.1237e-01
# 31/31 [==============================] - 0s 7ms/step
# Y | test1 -> R² = 0.9557, MSE = 3.6269e-03
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = -0.1757, MSE = 1.2479e-01
# 45/45 [==============================] - 1s 9ms/step
# Y | test3 -> R² = -0.9079, MSE = 1.4654e-01
# 40/40 [==============================] - 0s 6ms/step
# Y | val -> R² = 0.5335, MSE = 3.4734e-02
# Modelo 4 treinado e salvo no Excel
# 31/31 [==============================] - 4s 11ms/step
# Y | train1 -> R² = 0.3729, MSE = 5.2549e-02
# 31/31 [==============================] - 1s 10ms/step
# Y | train2 -> R² = -4.3116, MSE = 5.7195e-01
# 31/31 [==============================] - 1s 14ms/step
# Y | test1 -> R² = 0.4507, MSE = 4.5019e-02
# 31/31 [==============================] - 0s 10ms/step
# Y | test2 -> R² = -4.6342, MSE = 5.9803e-01
# 45/45 [==============================] - 1s 11ms/step
# Y | test3 -> R² = -2.9306, MSE = 3.0190e-01
# 40/40 [==============================] - 1s 12ms/step
# Y | val -> R² = -1.8530, MSE = 2.1240e-01
# Modelo 0 treinado e salvo no Excel
# 31/31 [==============================] - 2s 10ms/step
# Y | train1 -> R² = 0.4986, MSE = 4.2015e-02
# 31/31 [==============================] - 0s 10ms/step
# Y | train2 -> R² = -2.3646, MSE = 3.6230e-01
# 31/31 [==============================] - 1s 13ms/step
# Y | test1 -> R² = 0.5666, MSE = 3.5519e-02
# 31/31 [==============================] - 0s 10ms/step
# Y | test2 -> R² = -2.6338, MSE = 3.8570e-01
# 45/45 [==============================] - 1s 12ms/step
# Y | test3 -> R² = -4.8069, MSE = 4.4601e-01
# 40/40 [==============================] - 1s 13ms/step
# Y | val -> R² = -1.7465, MSE = 2.0447e-01
# Modelo 1 treinado e salvo no Excel
# 31/31 [==============================] - 2s 7ms/step
# Y | train1 -> R² = 0.2403, MSE = 6.3660e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | train2 -> R² = -3.3523, MSE = 4.6864e-01
# 31/31 [==============================] - 0s 10ms/step
# Y | test1 -> R² = 0.3316, MSE = 5.4776e-02
# 31/31 [==============================] - 0s 7ms/step
# Y | test2 -> R² = -3.7150, MSE = 5.0046e-01
# 45/45 [==============================] - 0s 8ms/step
# Y | test3 -> R² = -3.9808, MSE = 3.8256e-01
# 40/40 [==============================] - 0s 8ms/step
# Y | val -> R² = -2.4844, MSE = 2.5941e-01
# Modelo 2 treinado e salvo no Excel
# 31/31 [==============================] - 2s 9ms/step
# Y | train1 -> R² = 0.1663, MSE = 6.9857e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | train2 -> R² = -3.4149, MSE = 4.7538e-01
# 31/31 [==============================] - 0s 10ms/step
# Y | test1 -> R² = 0.2467, MSE = 6.1734e-02
# 31/31 [==============================] - 0s 8ms/step
# Y | test2 -> R² = -3.8186, MSE = 5.1146e-01
# 45/45 [==============================] - 1s 8ms/step
# Y | test3 -> R² = -5.2387, MSE = 4.7918e-01
# 40/40 [==============================] - 0s 9ms/step
# Y | val -> R² = -2.9300, MSE = 2.9259e-01
# Modelo 3 treinado e salvo no Excel
# 31/31 [==============================] - 1s 6ms/step
# Y | train1 -> R² = -0.6193, MSE = 1.3569e-01
# 31/31 [==============================] - 0s 5ms/step
# Y | train2 -> R² = -1.6263, MSE = 2.8280e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test1 -> R² = -0.5102, MSE = 1.2376e-01
# 31/31 [==============================] - 0s 6ms/step
# Y | test2 -> R² = -1.8473, MSE = 3.0222e-01
# 45/45 [==============================] - 0s 6ms/step
# Y | test3 -> R² = -7.6470, MSE = 6.6415e-01
# 40/40 [==============================] - 0s 9ms/step
# Y | val -> R² = -5.1312, MSE = 4.5647e-01
# Modelo 4 treinado e salvo no Excel
