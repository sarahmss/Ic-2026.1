# %%
import pandas as pd
import numpy as np

def load_data(file_path):
    colunas = ["x(Wd,We)","y(Wd,We)","theta(Wd,We)","Wd_true","We_true","Wd","We","tempo"]
    df = pd.read_csv(file_path, header=None, names=colunas)
    return df

Data = load_data("./Data2Smooth4.csv")
print(Data.head())
Data.to_csv("Data2SmoothSpline4.csv")
print("Data saved to Data2SmoothSpline.csv")
# Out:
#    x(Wd,We)      y(Wd,We)  theta(Wd,We)   Wd_true   We_true        Wd  \
# 0  0.000011  6.048734e-07      0.000161  0.007790  0.005081  2.329832
# 1  0.000024  1.641459e-06      0.000160  0.007788  0.005099  2.329536
# 2  0.000037  2.678029e-06      0.000159  0.007785  0.005118  2.329241
# 3  0.000050  3.714539e-06      0.000157  0.007782  0.005136  2.328945
# 4  0.000063  4.750897e-06      0.000156  0.007778  0.005154  2.328650
#
#          We  tempo
# 0  2.329343   0.00
# 1  2.329338   0.07
# 2  2.329333   0.14
# 3  2.329328   0.21
# 4  2.329323   0.28
# Data saved to Data2SmoothSpline.csv
