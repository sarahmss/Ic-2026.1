# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07

# %%
Datasets = []
for title in TITLES:
    df = pd.read_excel("../Data/SplinesDatasets.xlsx", sheet_name=title)
    Datasets.append(df)

# %%
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
            f"R2_LSG_1{name}": to_scalar(metrics[name]["R2_LSG_1"]),
            f"MSE_LSG_1_{name}": to_scalar(metrics[name]["MSE_LSG_1"]),
            f"R2_LSG_2_{name}": to_scalar(metrics[name]["R2_LSG_2"]),
            f"MSE_LSG_2_{name}": to_scalar(metrics[name]["MSE_LSG_2"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_Ld{Ld}_Lp{Lp}_seed{s}"
        ExportModel(model, model_name=model_name)
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# Epoch 0 | Train Loss 1.973970 | Val Loss 2.473981
# Epoch 100 | Train Loss 1.387608 | Val Loss 0.959638
# Epoch 200 | Train Loss 1.286460 | Val Loss 0.754006
# Epoch 300 | Train Loss 1.264725 | Val Loss 0.840993
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.7716, MSE = 5.0043e-02
# Theta | Train_2 -> R² = 0.5995, MSE = 8.7680e-02
# Theta | Test_1 -> R² = 0.8246, MSE = 3.8519e-02
# Theta | Test_2 -> R² = 0.7247, MSE = 6.2789e-02
# Theta | Test_3 -> R² = 0.2662, MSE = 2.3198e-01
# Theta | Val -> R² = -0.9492, MSE = 6.1291e-01
# Theta | LSG_1 -> R² = 0.6209, MSE = 1.5418e-01
# Theta | LSG_2 -> R² = -0.3493, MSE = 4.5015e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.947854 | Val Loss 2.417284
# Epoch 100 | Train Loss 1.377413 | Val Loss 0.938217
# Epoch 200 | Train Loss 1.286733 | Val Loss 0.755159
# Epoch 300 | Train Loss 1.256650 | Val Loss 0.808528
# Early stopping at epoch 393
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.7742, MSE = 4.9461e-02
# Theta | Train_2 -> R² = 0.6039, MSE = 8.6705e-02
# Theta | Test_1 -> R² = 0.7909, MSE = 4.5927e-02
# Theta | Test_2 -> R² = 0.7274, MSE = 6.2167e-02
# Theta | Test_3 -> R² = -0.0480, MSE = 3.3132e-01
# Theta | Val -> R² = -1.6549, MSE = 8.3479e-01
# Theta | LSG_1 -> R² = 0.6540, MSE = 1.4074e-01
# Theta | LSG_2 -> R² = -0.5202, MSE = 5.0714e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.930415 | Val Loss 2.362842
# Epoch 100 | Train Loss 1.364747 | Val Loss 0.913225
# Epoch 200 | Train Loss 1.284895 | Val Loss 0.766580
# Epoch 300 | Train Loss 1.257756 | Val Loss 0.852229
# Early stopping at epoch 380
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7705, MSE = 5.0278e-02
# Theta | Train_2 -> R² = 0.5979, MSE = 8.8019e-02
# Theta | Test_1 -> R² = 0.8013, MSE = 4.3648e-02
# Theta | Test_2 -> R² = 0.7201, MSE = 6.3823e-02
# Theta | Test_3 -> R² = 0.1769, MSE = 2.6021e-01
# Theta | Val -> R² = -1.4444, MSE = 7.6861e-01
# Theta | LSG_1 -> R² = 0.6447, MSE = 1.4452e-01
# Theta | LSG_2 -> R² = -0.6218, MSE = 5.4104e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 1.958739 | Val Loss 2.409666
# Epoch 100 | Train Loss 1.381359 | Val Loss 0.946758
# Epoch 200 | Train Loss 1.284742 | Val Loss 0.766502
# Epoch 300 | Train Loss 1.259786 | Val Loss 0.860021
# Early stopping at epoch 369
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.7393, MSE = 5.7120e-02
# Theta | Train_2 -> R² = 0.5540, MSE = 9.7625e-02
# Theta | Test_1 -> R² = 0.7920, MSE = 4.5695e-02
# Theta | Test_2 -> R² = 0.6709, MSE = 7.5043e-02
# Theta | Test_3 -> R² = 0.3486, MSE = 2.0592e-01
# Theta | Val -> R² = -0.6398, MSE = 5.1560e-01
# Theta | LSG_1 -> R² = 0.6203, MSE = 1.5441e-01
# Theta | LSG_2 -> R² = -0.2130, MSE = 4.0468e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 2.013356 | Val Loss 2.436353
# Epoch 100 | Train Loss 1.376325 | Val Loss 0.953058
# Epoch 200 | Train Loss 1.284465 | Val Loss 0.765264
# Epoch 300 | Train Loss 1.258429 | Val Loss 0.862403
# Early stopping at epoch 377
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch16_r0.01_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7637, MSE = 5.1774e-02
# Theta | Train_2 -> R² = 0.5899, MSE = 8.9781e-02
# Theta | Test_1 -> R² = 0.8092, MSE = 4.1918e-02
# Theta | Test_2 -> R² = 0.7096, MSE = 6.6221e-02
# Theta | Test_3 -> R² = 0.2942, MSE = 2.2312e-01
# Theta | Val -> R² = -0.9464, MSE = 6.1202e-01
# Theta | LSG_1 -> R² = 0.6273, MSE = 1.5156e-01
# Theta | LSG_2 -> R² = -0.3264, MSE = 4.4248e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.973533 | Val Loss 2.456122
# Epoch 100 | Train Loss 1.384271 | Val Loss 0.974530
# Epoch 200 | Train Loss 1.278543 | Val Loss 0.799079
# Epoch 300 | Train Loss 1.251213 | Val Loss 0.891327
# Early stopping at epoch 366
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.7707, MSE = 5.0243e-02
# Theta | Train_2 -> R² = 0.5655, MSE = 9.5108e-02
# Theta | Test_1 -> R² = 0.8054, MSE = 4.2740e-02
# Theta | Test_2 -> R² = 0.6877, MSE = 7.1218e-02
# Theta | Test_3 -> R² = 0.2944, MSE = 2.2306e-01
# Theta | Val -> R² = -0.8883, MSE = 5.9373e-01
# Theta | LSG_1 -> R² = 0.6289, MSE = 1.5093e-01
# Theta | LSG_2 -> R² = -0.3079, MSE = 4.3631e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.960161 | Val Loss 2.429555
# Epoch 100 | Train Loss 1.370724 | Val Loss 0.923109
# Epoch 200 | Train Loss 1.276582 | Val Loss 0.804276
# Epoch 300 | Train Loss 1.247895 | Val Loss 0.888832
# Early stopping at epoch 358
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.7960, MSE = 4.4687e-02
# Theta | Train_2 -> R² = 0.5849, MSE = 9.0858e-02
# Theta | Test_1 -> R² = 0.8418, MSE = 3.4743e-02
# Theta | Test_2 -> R² = 0.7116, MSE = 6.5760e-02
# Theta | Test_3 -> R² = 0.1840, MSE = 2.5796e-01
# Theta | Val -> R² = -0.9873, MSE = 6.2488e-01
# Theta | LSG_1 -> R² = 0.6129, MSE = 1.5745e-01
# Theta | LSG_2 -> R² = -0.2735, MSE = 4.2485e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.949813 | Val Loss 2.405712
# Epoch 100 | Train Loss 1.367862 | Val Loss 0.923654
# Epoch 200 | Train Loss 1.283752 | Val Loss 0.768676
# Epoch 300 | Train Loss 1.258228 | Val Loss 0.825362
# Early stopping at epoch 374
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7532, MSE = 5.4067e-02
# Theta | Train_2 -> R² = 0.5839, MSE = 9.1084e-02
# Theta | Test_1 -> R² = 0.7777, MSE = 4.8836e-02
# Theta | Test_2 -> R² = 0.7133, MSE = 6.5380e-02
# Theta | Test_3 -> R² = 0.2345, MSE = 2.4200e-01
# Theta | Val -> R² = -1.4204, MSE = 7.6105e-01
# Theta | LSG_1 -> R² = 0.6583, MSE = 1.3899e-01
# Theta | LSG_2 -> R² = -0.6962, MSE = 5.6586e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.966650 | Val Loss 2.448468
# Epoch 100 | Train Loss 1.387387 | Val Loss 0.952226
# Epoch 200 | Train Loss 1.287555 | Val Loss 0.786180
# Epoch 300 | Train Loss 1.263356 | Val Loss 0.879309
# Early stopping at epoch 382
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.7808, MSE = 4.8023e-02
# Theta | Train_2 -> R² = 0.6029, MSE = 8.6936e-02
# Theta | Test_1 -> R² = 0.8016, MSE = 4.3587e-02
# Theta | Test_2 -> R² = 0.7256, MSE = 6.2580e-02
# Theta | Test_3 -> R² = 0.1086, MSE = 2.8182e-01
# Theta | Val -> R² = -1.5492, MSE = 8.0155e-01
# Theta | LSG_1 -> R² = 0.6583, MSE = 1.3899e-01
# Theta | LSG_2 -> R² = -0.6387, MSE = 5.4669e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 1.937608 | Val Loss 2.363767
# Epoch 100 | Train Loss 1.380165 | Val Loss 0.942674
# Epoch 200 | Train Loss 1.285323 | Val Loss 0.769131
# Epoch 300 | Train Loss 1.265186 | Val Loss 0.850638
# Early stopping at epoch 371
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch16_r0.9_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7720, MSE = 4.9950e-02
# Theta | Train_2 -> R² = 0.5977, MSE = 8.8064e-02
# Theta | Test_1 -> R² = 0.8142, MSE = 4.0814e-02
# Theta | Test_2 -> R² = 0.7251, MSE = 6.2701e-02
# Theta | Test_3 -> R² = 0.2743, MSE = 2.2942e-01
# Theta | Val -> R² = -1.0156, MSE = 6.3376e-01
# Theta | LSG_1 -> R² = 0.6393, MSE = 1.4670e-01
# Theta | LSG_2 -> R² = -0.4325, MSE = 4.7790e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7265 salvo.
# Epoch 0 | Train Loss 1.632390 | Val Loss 2.526890
# Epoch 100 | Train Loss 0.940980 | Val Loss 0.958334
# Epoch 200 | Train Loss 0.822566 | Val Loss 0.717471
# Epoch 300 | Train Loss 0.806325 | Val Loss 0.744786
# Early stopping at epoch 391
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.8054, MSE = 4.2627e-02
# Theta | Train_2 -> R² = 0.6943, MSE = 6.6922e-02
# Theta | Test_1 -> R² = 0.8444, MSE = 3.4179e-02
# Theta | Test_2 -> R² = 0.7935, MSE = 4.7087e-02
# Theta | Test_3 -> R² = 0.3587, MSE = 2.0274e-01
# Theta | Val -> R² = -0.4751, MSE = 4.6383e-01
# Theta | LSG_1 -> R² = 0.6067, MSE = 1.5996e-01
# Theta | LSG_2 -> R² = -0.5078, MSE = 5.0303e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.563133 | Val Loss 2.366816
# Epoch 100 | Train Loss 0.928491 | Val Loss 0.915054
# Epoch 200 | Train Loss 0.823528 | Val Loss 0.716725
# Epoch 300 | Train Loss 0.811574 | Val Loss 0.750430
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8096, MSE = 4.1720e-02
# Theta | Train_2 -> R² = 0.7014, MSE = 6.5367e-02
# Theta | Test_1 -> R² = 0.8545, MSE = 3.1966e-02
# Theta | Test_2 -> R² = 0.7964, MSE = 4.6424e-02
# Theta | Test_3 -> R² = 0.3837, MSE = 1.9484e-01
# Theta | Val -> R² = -0.4423, MSE = 4.5352e-01
# Theta | LSG_1 -> R² = 0.5979, MSE = 1.6353e-01
# Theta | LSG_2 -> R² = -0.5121, MSE = 5.0443e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.572589 | Val Loss 2.395328
# Epoch 100 | Train Loss 0.920490 | Val Loss 0.900295
# Epoch 200 | Train Loss 0.823706 | Val Loss 0.745601
# Epoch 300 | Train Loss 0.802131 | Val Loss 0.803047
# Early stopping at epoch 380
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8008, MSE = 4.3649e-02
# Theta | Train_2 -> R² = 0.6800, MSE = 7.0045e-02
# Theta | Test_1 -> R² = 0.8304, MSE = 3.7253e-02
# Theta | Test_2 -> R² = 0.7853, MSE = 4.8966e-02
# Theta | Test_3 -> R² = 0.2846, MSE = 2.2616e-01
# Theta | Val -> R² = -0.9378, MSE = 6.0932e-01
# Theta | LSG_1 -> R² = 0.6367, MSE = 1.4777e-01
# Theta | LSG_2 -> R² = -0.7752, MSE = 5.9221e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 1.564314 | Val Loss 2.363957
# Epoch 100 | Train Loss 0.930041 | Val Loss 0.918011
# Epoch 200 | Train Loss 0.821858 | Val Loss 0.734525
# Epoch 300 | Train Loss 0.805695 | Val Loss 0.775475
# Early stopping at epoch 374
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.7958, MSE = 4.4747e-02
# Theta | Train_2 -> R² = 0.6699, MSE = 7.2266e-02
# Theta | Test_1 -> R² = 0.8374, MSE = 3.5722e-02
# Theta | Test_2 -> R² = 0.7586, MSE = 5.5041e-02
# Theta | Test_3 -> R² = 0.3821, MSE = 1.9533e-01
# Theta | Val -> R² = -0.4357, MSE = 4.5143e-01
# Theta | LSG_1 -> R² = 0.6071, MSE = 1.5980e-01
# Theta | LSG_2 -> R² = -0.4027, MSE = 4.6796e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.634819 | Val Loss 2.440877
# Epoch 100 | Train Loss 0.933068 | Val Loss 0.926772
# Epoch 200 | Train Loss 0.826568 | Val Loss 0.732150
# Epoch 300 | Train Loss 0.812418 | Val Loss 0.772240
# Early stopping at epoch 388
# Modelo salvo em:
# models/model_arch16_r0.01_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch16_r0.01_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7981, MSE = 4.4243e-02
# Theta | Train_2 -> R² = 0.6761, MSE = 7.0900e-02
# Theta | Test_1 -> R² = 0.8377, MSE = 3.5641e-02
# Theta | Test_2 -> R² = 0.7772, MSE = 5.0806e-02
# Theta | Test_3 -> R² = 0.4921, MSE = 1.6058e-01
# Theta | Val -> R² = -0.4332, MSE = 4.5066e-01
# Theta | LSG_1 -> R² = 0.6186, MSE = 1.5511e-01
# Theta | LSG_2 -> R² = -0.5903, MSE = 5.3053e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.626328 | Val Loss 2.522307
# Epoch 100 | Train Loss 0.956062 | Val Loss 0.993327
# Epoch 200 | Train Loss 0.820546 | Val Loss 0.709567
# Epoch 300 | Train Loss 0.800811 | Val Loss 0.725970
# Epoch 400 | Train Loss 0.779457 | Val Loss 0.761808
# Early stopping at epoch 402
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.8004, MSE = 4.3733e-02
# Theta | Train_2 -> R² = 0.7093, MSE = 6.3638e-02
# Theta | Test_1 -> R² = 0.8163, MSE = 4.0348e-02
# Theta | Test_2 -> R² = 0.8041, MSE = 4.4676e-02
# Theta | Test_3 -> R² = 0.1105, MSE = 2.8122e-01
# Theta | Val -> R² = -0.8579, MSE = 5.8419e-01
# Theta | LSG_1 -> R² = 0.6462, MSE = 1.4390e-01
# Theta | LSG_2 -> R² = -0.6646, MSE = 5.5532e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.577356 | Val Loss 2.423784
# Epoch 100 | Train Loss 0.941868 | Val Loss 0.943924
# Epoch 200 | Train Loss 0.827916 | Val Loss 0.742557
# Epoch 300 | Train Loss 0.805854 | Val Loss 0.798213
# Early stopping at epoch 390
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8123, MSE = 4.1115e-02
# Theta | Train_2 -> R² = 0.6736, MSE = 7.1446e-02
# Theta | Test_1 -> R² = 0.8452, MSE = 3.4006e-02
# Theta | Test_2 -> R² = 0.7807, MSE = 5.0015e-02
# Theta | Test_3 -> R² = 0.3552, MSE = 2.0386e-01
# Theta | Val -> R² = -0.7296, MSE = 5.4385e-01
# Theta | LSG_1 -> R² = 0.6264, MSE = 1.5196e-01
# Theta | LSG_2 -> R² = -0.6610, MSE = 5.5412e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.627921 | Val Loss 2.521590
# Epoch 100 | Train Loss 0.937059 | Val Loss 0.935721
# Epoch 200 | Train Loss 0.822686 | Val Loss 0.731469
# Epoch 300 | Train Loss 0.808443 | Val Loss 0.771052
# Early stopping at epoch 391
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8287, MSE = 3.7537e-02
# Theta | Train_2 -> R² = 0.7079, MSE = 6.3949e-02
# Theta | Test_1 -> R² = 0.8660, MSE = 2.9433e-02
# Theta | Test_2 -> R² = 0.8114, MSE = 4.3002e-02
# Theta | Test_3 -> R² = 0.1684, MSE = 2.6291e-01
# Theta | Val -> R² = -0.8140, MSE = 5.7038e-01
# Theta | LSG_1 -> R² = 0.6161, MSE = 1.5613e-01
# Theta | LSG_2 -> R² = -0.6385, MSE = 5.4663e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.608827 | Val Loss 2.474081
# Epoch 100 | Train Loss 0.944853 | Val Loss 0.942882
# Epoch 200 | Train Loss 0.832157 | Val Loss 0.744919
# Epoch 300 | Train Loss 0.809076 | Val Loss 0.772925
# Epoch 400 | Train Loss 0.785916 | Val Loss 0.783637
# Early stopping at epoch 415
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8139, MSE = 4.0782e-02
# Theta | Train_2 -> R² = 0.6940, MSE = 6.6980e-02
# Theta | Test_1 -> R² = 0.8467, MSE = 3.3668e-02
# Theta | Test_2 -> R² = 0.8084, MSE = 4.3685e-02
# Theta | Test_3 -> R² = 0.2754, MSE = 2.2907e-01
# Theta | Val -> R² = -0.9661, MSE = 6.1822e-01
# Theta | LSG_1 -> R² = 0.6399, MSE = 1.4647e-01
# Theta | LSG_2 -> R² = -0.7518, MSE = 5.8440e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 1.636479 | Val Loss 2.477710
# Epoch 100 | Train Loss 0.933125 | Val Loss 0.926369
# Epoch 200 | Train Loss 0.830448 | Val Loss 0.738814
# Epoch 300 | Train Loss 0.810999 | Val Loss 0.800818
# Early stopping at epoch 390
# Modelo salvo em:
# models/model_arch16_r0.9_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch16_r0.9_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8026, MSE = 4.3238e-02
# Theta | Train_2 -> R² = 0.6661, MSE = 7.3087e-02
# Theta | Test_1 -> R² = 0.8442, MSE = 3.4226e-02
# Theta | Test_2 -> R² = 0.7815, MSE = 4.9833e-02
# Theta | Test_3 -> R² = 0.5081, MSE = 1.5551e-01
# Theta | Val -> R² = -0.4294, MSE = 4.4946e-01
# Theta | LSG_1 -> R² = 0.6173, MSE = 1.5564e-01
# Theta | LSG_2 -> R² = -0.5278, MSE = 5.0969e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7265 salvo.
# Epoch 0 | Train Loss 1.970797 | Val Loss 2.433689
# Epoch 100 | Train Loss 1.310631 | Val Loss 0.821858
# Epoch 200 | Train Loss 1.278274 | Val Loss 0.726241
# Epoch 300 | Train Loss 1.249590 | Val Loss 0.795199
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.7889, MSE = 4.6243e-02
# Theta | Train_2 -> R² = 0.6798, MSE = 7.0092e-02
# Theta | Test_1 -> R² = 0.8120, MSE = 4.1306e-02
# Theta | Test_2 -> R² = 0.7976, MSE = 4.6165e-02
# Theta | Test_3 -> R² = -0.3110, MSE = 4.1447e-01
# Theta | Val -> R² = -2.7130, MSE = 1.1675e+00
# Theta | LSG_1 -> R² = 0.6249, MSE = 1.5257e-01
# Theta | LSG_2 -> R² = -1.0767, MSE = 6.9281e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.945152 | Val Loss 2.248356
# Epoch 100 | Train Loss 1.308037 | Val Loss 0.818744
# Epoch 200 | Train Loss 1.277212 | Val Loss 0.726993
# Epoch 300 | Train Loss 1.257329 | Val Loss 0.794739
# Early stopping at epoch 390
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.7945, MSE = 4.5026e-02
# Theta | Train_2 -> R² = 0.6869, MSE = 6.8528e-02
# Theta | Test_1 -> R² = 0.8238, MSE = 3.8700e-02
# Theta | Test_2 -> R² = 0.8059, MSE = 4.4274e-02
# Theta | Test_3 -> R² = -0.3048, MSE = 4.1250e-01
# Theta | Val -> R² = -2.6248, MSE = 1.1398e+00
# Theta | LSG_1 -> R² = 0.6317, MSE = 1.4981e-01
# Theta | LSG_2 -> R² = -0.9588, MSE = 6.5348e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.930925 | Val Loss 2.295921
# Epoch 100 | Train Loss 1.310037 | Val Loss 0.819028
# Epoch 200 | Train Loss 1.279244 | Val Loss 0.717076
# Epoch 300 | Train Loss 1.262393 | Val Loss 0.721520
# Epoch 400 | Train Loss 1.186645 | Val Loss 0.806705
# Early stopping at epoch 441
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7922, MSE = 4.5528e-02
# Theta | Train_2 -> R² = 0.7004, MSE = 6.5591e-02
# Theta | Test_1 -> R² = 0.8433, MSE = 3.4412e-02
# Theta | Test_2 -> R² = 0.8098, MSE = 4.3385e-02
# Theta | Test_3 -> R² = -0.2672, MSE = 4.0062e-01
# Theta | Val -> R² = -2.2686, MSE = 1.0278e+00
# Theta | LSG_1 -> R² = 0.6227, MSE = 1.5344e-01
# Theta | LSG_2 -> R² = -0.7282, MSE = 5.7655e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 2.005661 | Val Loss 2.491506
# Epoch 100 | Train Loss 1.311886 | Val Loss 0.822063
# Epoch 200 | Train Loss 1.269473 | Val Loss 0.731324
# Epoch 300 | Train Loss 1.232789 | Val Loss 0.872785
# Early stopping at epoch 363
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.7937, MSE = 4.5198e-02
# Theta | Train_2 -> R² = 0.6824, MSE = 6.9524e-02
# Theta | Test_1 -> R² = 0.8147, MSE = 4.0707e-02
# Theta | Test_2 -> R² = 0.7930, MSE = 4.7205e-02
# Theta | Test_3 -> R² = -0.3914, MSE = 4.3989e-01
# Theta | Val -> R² = -2.4263, MSE = 1.0774e+00
# Theta | LSG_1 -> R² = 0.6367, MSE = 1.4774e-01
# Theta | LSG_2 -> R² = -0.9418, MSE = 6.4782e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.995229 | Val Loss 2.373481
# Epoch 100 | Train Loss 1.304564 | Val Loss 0.811516
# Epoch 200 | Train Loss 1.277722 | Val Loss 0.722883
# Epoch 300 | Train Loss 1.261223 | Val Loss 0.769751
# Early stopping at epoch 394
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch32_r0.01_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7910, MSE = 4.5780e-02
# Theta | Train_2 -> R² = 0.6905, MSE = 6.7761e-02
# Theta | Test_1 -> R² = 0.8187, MSE = 3.9828e-02
# Theta | Test_2 -> R² = 0.8020, MSE = 4.5150e-02
# Theta | Test_3 -> R² = -0.4904, MSE = 4.7117e-01
# Theta | Val -> R² = -2.8940, MSE = 1.2244e+00
# Theta | LSG_1 -> R² = 0.6263, MSE = 1.5198e-01
# Theta | LSG_2 -> R² = -0.9713, MSE = 6.5764e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.932683 | Val Loss 2.347338
# Epoch 100 | Train Loss 1.303713 | Val Loss 0.809979
# Epoch 200 | Train Loss 1.274382 | Val Loss 0.714078
# Epoch 300 | Train Loss 1.254702 | Val Loss 0.776275
# Epoch 400 | Train Loss 1.187508 | Val Loss 0.910757
# Early stopping at epoch 408
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.7940, MSE = 4.5141e-02
# Theta | Train_2 -> R² = 0.6973, MSE = 6.6264e-02
# Theta | Test_1 -> R² = 0.8293, MSE = 3.7507e-02
# Theta | Test_2 -> R² = 0.8056, MSE = 4.4322e-02
# Theta | Test_3 -> R² = -0.4472, MSE = 4.5752e-01
# Theta | Val -> R² = -2.4844, MSE = 1.0956e+00
# Theta | LSG_1 -> R² = 0.6332, MSE = 1.4918e-01
# Theta | LSG_2 -> R² = -0.7720, MSE = 5.9117e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.946306 | Val Loss 2.258404
# Epoch 100 | Train Loss 1.310608 | Val Loss 0.825853
# Epoch 200 | Train Loss 1.280563 | Val Loss 0.726269
# Epoch 300 | Train Loss 1.261863 | Val Loss 0.748333
# Epoch 400 | Train Loss 1.206587 | Val Loss 0.846614
# Early stopping at epoch 431
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.7971, MSE = 4.4444e-02
# Theta | Train_2 -> R² = 0.6958, MSE = 6.6590e-02
# Theta | Test_1 -> R² = 0.8330, MSE = 3.6687e-02
# Theta | Test_2 -> R² = 0.8077, MSE = 4.3857e-02
# Theta | Test_3 -> R² = -0.4374, MSE = 4.5443e-01
# Theta | Val -> R² = -2.7639, MSE = 1.1835e+00
# Theta | LSG_1 -> R² = 0.6218, MSE = 1.5383e-01
# Theta | LSG_2 -> R² = -0.9383, MSE = 6.4664e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.934765 | Val Loss 2.366465
# Epoch 100 | Train Loss 1.301744 | Val Loss 0.784240
# Epoch 200 | Train Loss 1.273998 | Val Loss 0.748481
# Epoch 300 | Train Loss 1.237691 | Val Loss 0.859175
# Early stopping at epoch 346
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7914, MSE = 4.5711e-02
# Theta | Train_2 -> R² = 0.6797, MSE = 7.0117e-02
# Theta | Test_1 -> R² = 0.8116, MSE = 4.1377e-02
# Theta | Test_2 -> R² = 0.7847, MSE = 4.9092e-02
# Theta | Test_3 -> R² = -0.5889, MSE = 5.0231e-01
# Theta | Val -> R² = -2.8503, MSE = 1.2107e+00
# Theta | LSG_1 -> R² = 0.6338, MSE = 1.4892e-01
# Theta | LSG_2 -> R² = -0.8990, MSE = 6.3354e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.948551 | Val Loss 2.357802
# Epoch 100 | Train Loss 1.306468 | Val Loss 0.806813
# Epoch 200 | Train Loss 1.273728 | Val Loss 0.714459
# Epoch 300 | Train Loss 1.243551 | Val Loss 0.826473
# Early stopping at epoch 361
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.7876, MSE = 4.6524e-02
# Theta | Train_2 -> R² = 0.6828, MSE = 6.9445e-02
# Theta | Test_1 -> R² = 0.8175, MSE = 4.0096e-02
# Theta | Test_2 -> R² = 0.7940, MSE = 4.6969e-02
# Theta | Test_3 -> R² = -0.2924, MSE = 4.0858e-01
# Theta | Val -> R² = -2.2280, MSE = 1.0150e+00
# Theta | LSG_1 -> R² = 0.6317, MSE = 1.4981e-01
# Theta | LSG_2 -> R² = -0.8114, MSE = 6.0428e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 1.933929 | Val Loss 2.274670
# Epoch 100 | Train Loss 1.304111 | Val Loss 0.812720
# Epoch 200 | Train Loss 1.275374 | Val Loss 0.732990
# Epoch 300 | Train Loss 1.242296 | Val Loss 0.818841
# Early stopping at epoch 384
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch32_r0.9_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7947, MSE = 4.4972e-02
# Theta | Train_2 -> R² = 0.6926, MSE = 6.7297e-02
# Theta | Test_1 -> R² = 0.8115, MSE = 4.1397e-02
# Theta | Test_2 -> R² = 0.7993, MSE = 4.5772e-02
# Theta | Test_3 -> R² = -0.5197, MSE = 4.8045e-01
# Theta | Val -> R² = -2.9045, MSE = 1.2277e+00
# Theta | LSG_1 -> R² = 0.6363, MSE = 1.4792e-01
# Theta | LSG_2 -> R² = -0.9726, MSE = 6.5807e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7265 salvo.
# Epoch 0 | Train Loss 1.590503 | Val Loss 2.377228
# Epoch 100 | Train Loss 0.854091 | Val Loss 0.820325
# Epoch 200 | Train Loss 0.812674 | Val Loss 0.708454
# Epoch 300 | Train Loss 0.803368 | Val Loss 0.704482
# Epoch 400 | Train Loss 0.745940 | Val Loss 0.738330
# Early stopping at epoch 465
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.8098, MSE = 4.1667e-02
# Theta | Train_2 -> R² = 0.7569, MSE = 5.3218e-02
# Theta | Test_1 -> R² = 0.8580, MSE = 3.1193e-02
# Theta | Test_2 -> R² = 0.8528, MSE = 3.3567e-02
# Theta | Test_3 -> R² = -0.0296, MSE = 3.2550e-01
# Theta | Val -> R² = -1.5779, MSE = 8.1058e-01
# Theta | LSG_1 -> R² = 0.5955, MSE = 1.6452e-01
# Theta | LSG_2 -> R² = -1.0212, MSE = 6.7428e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.611382 | Val Loss 2.401819
# Epoch 100 | Train Loss 0.843370 | Val Loss 0.787318
# Epoch 200 | Train Loss 0.812789 | Val Loss 0.712895
# Epoch 300 | Train Loss 0.797610 | Val Loss 0.723896
# Epoch 400 | Train Loss 0.760150 | Val Loss 0.751145
# Early stopping at epoch 410
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8160, MSE = 4.0320e-02
# Theta | Train_2 -> R² = 0.7612, MSE = 5.2282e-02
# Theta | Test_1 -> R² = 0.8385, MSE = 3.5473e-02
# Theta | Test_2 -> R² = 0.8498, MSE = 3.4259e-02
# Theta | Test_3 -> R² = -0.4957, MSE = 4.7287e-01
# Theta | Val -> R² = -2.3944, MSE = 1.0673e+00
# Theta | LSG_1 -> R² = 0.6185, MSE = 1.5514e-01
# Theta | LSG_2 -> R² = -1.1295, MSE = 7.1041e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.563991 | Val Loss 2.350835
# Epoch 100 | Train Loss 0.853859 | Val Loss 0.806830
# Epoch 200 | Train Loss 0.810911 | Val Loss 0.703747
# Epoch 300 | Train Loss 0.787297 | Val Loss 0.740621
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8110, MSE = 4.1400e-02
# Theta | Train_2 -> R² = 0.7524, MSE = 5.4190e-02
# Theta | Test_1 -> R² = 0.8301, MSE = 3.7332e-02
# Theta | Test_2 -> R² = 0.8517, MSE = 3.3829e-02
# Theta | Test_3 -> R² = -0.3192, MSE = 4.1707e-01
# Theta | Val -> R² = -2.1391, MSE = 9.8704e-01
# Theta | LSG_1 -> R² = 0.6258, MSE = 1.5220e-01
# Theta | LSG_2 -> R² = -1.0873, MSE = 6.9632e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 1.567918 | Val Loss 2.337442
# Epoch 100 | Train Loss 0.853379 | Val Loss 0.811191
# Epoch 200 | Train Loss 0.812566 | Val Loss 0.708136
# Epoch 300 | Train Loss 0.795711 | Val Loss 0.705112
# Epoch 400 | Train Loss 0.751261 | Val Loss 0.748061
# Early stopping at epoch 449
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8139, MSE = 4.0771e-02
# Theta | Train_2 -> R² = 0.7591, MSE = 5.2731e-02
# Theta | Test_1 -> R² = 0.8488, MSE = 3.3205e-02
# Theta | Test_2 -> R² = 0.8521, MSE = 3.3740e-02
# Theta | Test_3 -> R² = -0.2021, MSE = 3.8004e-01
# Theta | Val -> R² = -1.8100, MSE = 8.8356e-01
# Theta | LSG_1 -> R² = 0.6144, MSE = 1.5681e-01
# Theta | LSG_2 -> R² = -1.0673, MSE = 6.8968e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.559190 | Val Loss 2.225491
# Epoch 100 | Train Loss 0.843206 | Val Loss 0.798240
# Epoch 200 | Train Loss 0.811264 | Val Loss 0.700395
# Epoch 300 | Train Loss 0.799637 | Val Loss 0.687865
# Epoch 400 | Train Loss 0.758432 | Val Loss 0.714657
# Early stopping at epoch 488
# Modelo salvo em:
# models/model_arch32_r0.01_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch32_r0.01_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8134, MSE = 4.0891e-02
# Theta | Train_2 -> R² = 0.7702, MSE = 5.0312e-02
# Theta | Test_1 -> R² = 0.8498, MSE = 3.2996e-02
# Theta | Test_2 -> R² = 0.8524, MSE = 3.3669e-02
# Theta | Test_3 -> R² = -0.3907, MSE = 4.3965e-01
# Theta | Val -> R² = -1.7848, MSE = 8.7563e-01
# Theta | LSG_1 -> R² = 0.6147, MSE = 1.5670e-01
# Theta | LSG_2 -> R² = -0.8835, MSE = 6.2836e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.553444 | Val Loss 2.318840
# Epoch 100 | Train Loss 0.848614 | Val Loss 0.812307
# Epoch 200 | Train Loss 0.813171 | Val Loss 0.707645
# Epoch 300 | Train Loss 0.801667 | Val Loss 0.691672
# Epoch 400 | Train Loss 0.765631 | Val Loss 0.712554
# Epoch 500 | Train Loss 0.674553 | Val Loss 0.745452
# Early stopping at epoch 506
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.8169, MSE = 4.0116e-02
# Theta | Train_2 -> R² = 0.7713, MSE = 5.0070e-02
# Theta | Test_1 -> R² = 0.8363, MSE = 3.5969e-02
# Theta | Test_2 -> R² = 0.8520, MSE = 3.3757e-02
# Theta | Test_3 -> R² = -0.8062, MSE = 5.7102e-01
# Theta | Val -> R² = -2.3158, MSE = 1.0426e+00
# Theta | LSG_1 -> R² = 0.6154, MSE = 1.5643e-01
# Theta | LSG_2 -> R² = -1.0207, MSE = 6.7414e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.651709 | Val Loss 2.421343
# Epoch 100 | Train Loss 0.851525 | Val Loss 0.806589
# Epoch 200 | Train Loss 0.812987 | Val Loss 0.720113
# Epoch 300 | Train Loss 0.800605 | Val Loss 0.716192
# Epoch 400 | Train Loss 0.772531 | Val Loss 0.734529
# Early stopping at epoch 449
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8224, MSE = 3.8911e-02
# Theta | Train_2 -> R² = 0.7660, MSE = 5.1219e-02
# Theta | Test_1 -> R² = 0.8398, MSE = 3.5185e-02
# Theta | Test_2 -> R² = 0.8510, MSE = 3.3982e-02
# Theta | Test_3 -> R² = -0.5006, MSE = 4.7440e-01
# Theta | Val -> R² = -2.5228, MSE = 1.1077e+00
# Theta | LSG_1 -> R² = 0.6158, MSE = 1.5626e-01
# Theta | LSG_2 -> R² = -1.2611, MSE = 7.5432e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.633113 | Val Loss 2.499010
# Epoch 100 | Train Loss 0.853360 | Val Loss 0.808603
# Epoch 200 | Train Loss 0.812645 | Val Loss 0.697339
# Epoch 300 | Train Loss 0.802517 | Val Loss 0.685490
# Epoch 400 | Train Loss 0.762767 | Val Loss 0.714612
# Early stopping at epoch 476
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8098, MSE = 4.1674e-02
# Theta | Train_2 -> R² = 0.7615, MSE = 5.2199e-02
# Theta | Test_1 -> R² = 0.8544, MSE = 3.1973e-02
# Theta | Test_2 -> R² = 0.8493, MSE = 3.4364e-02
# Theta | Test_3 -> R² = -0.4546, MSE = 4.5985e-01
# Theta | Val -> R² = -1.6769, MSE = 8.4172e-01
# Theta | LSG_1 -> R² = 0.6038, MSE = 1.6116e-01
# Theta | LSG_2 -> R² = -0.7629, MSE = 5.8811e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.605811 | Val Loss 2.401565
# Epoch 100 | Train Loss 0.849746 | Val Loss 0.797900
# Epoch 200 | Train Loss 0.810698 | Val Loss 0.713949
# Epoch 300 | Train Loss 0.794812 | Val Loss 0.711312
# Epoch 400 | Train Loss 0.760423 | Val Loss 0.734955
# Early stopping at epoch 444
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8092, MSE = 4.1803e-02
# Theta | Train_2 -> R² = 0.7587, MSE = 5.2811e-02
# Theta | Test_1 -> R² = 0.8241, MSE = 3.8630e-02
# Theta | Test_2 -> R² = 0.8543, MSE = 3.3221e-02
# Theta | Test_3 -> R² = -0.2651, MSE = 3.9995e-01
# Theta | Val -> R² = -2.2764, MSE = 1.0302e+00
# Theta | LSG_1 -> R² = 0.6096, MSE = 1.5877e-01
# Theta | LSG_2 -> R² = -1.4589, MSE = 8.2031e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 1.577514 | Val Loss 2.329112
# Epoch 100 | Train Loss 0.843806 | Val Loss 0.800529
# Epoch 200 | Train Loss 0.816226 | Val Loss 0.724499
# Epoch 300 | Train Loss 0.802639 | Val Loss 0.731190
# Epoch 400 | Train Loss 0.772053 | Val Loss 0.770644
# Early stopping at epoch 411
# Modelo salvo em:
# models/model_arch32_r0.9_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch32_r0.9_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8098, MSE = 4.1664e-02
# Theta | Train_2 -> R² = 0.7546, MSE = 5.3718e-02
# Theta | Test_1 -> R² = 0.8230, MSE = 3.8882e-02
# Theta | Test_2 -> R² = 0.8526, MSE = 3.3611e-02
# Theta | Test_3 -> R² = -0.3824, MSE = 4.3704e-01
# Theta | Val -> R² = -2.6680, MSE = 1.1534e+00
# Theta | LSG_1 -> R² = 0.6089, MSE = 1.5908e-01
# Theta | LSG_2 -> R² = -1.4240, MSE = 8.0867e-01
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7265 salvo.
# Epoch 0 | Train Loss 1.933981 | Val Loss 2.193378
# Epoch 100 | Train Loss 1.300300 | Val Loss 0.865079
# Epoch 200 | Train Loss 1.270175 | Val Loss 0.704105
# Epoch 300 | Train Loss 1.225338 | Val Loss 0.722887
# Epoch 400 | Train Loss 1.038139 | Val Loss 0.928526
# Early stopping at epoch 454
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.7946, MSE = 4.5001e-02
# Theta | Train_2 -> R² = 0.7126, MSE = 6.2923e-02
# Theta | Test_1 -> R² = 0.8465, MSE = 3.3717e-02
# Theta | Test_2 -> R² = 0.8204, MSE = 4.0969e-02
# Theta | Test_3 -> R² = -0.5445, MSE = 4.8828e-01
# Theta | Val -> R² = -2.3938, MSE = 1.0671e+00
# Theta | LSG_1 -> R² = 0.6186, MSE = 1.5511e-01
# Theta | LSG_2 -> R² = -0.6979, MSE = 5.6643e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.996908 | Val Loss 2.348413
# Epoch 100 | Train Loss 1.290869 | Val Loss 0.826729
# Epoch 200 | Train Loss 1.263263 | Val Loss 0.687525
# Epoch 300 | Train Loss 1.183091 | Val Loss 0.745983
# Epoch 400 | Train Loss 1.047553 | Val Loss 0.890625
# Early stopping at epoch 421
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.7850, MSE = 4.7110e-02
# Theta | Train_2 -> R² = 0.7031, MSE = 6.4989e-02
# Theta | Test_1 -> R² = 0.8544, MSE = 3.1993e-02
# Theta | Test_2 -> R² = 0.8176, MSE = 4.1590e-02
# Theta | Test_3 -> R² = -0.2352, MSE = 3.9051e-01
# Theta | Val -> R² = -2.0156, MSE = 9.4821e-01
# Theta | LSG_1 -> R² = 0.6121, MSE = 1.5776e-01
# Theta | LSG_2 -> R² = -0.7343, MSE = 5.7859e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.957999 | Val Loss 2.219174
# Epoch 100 | Train Loss 1.306256 | Val Loss 0.886629
# Epoch 200 | Train Loss 1.274191 | Val Loss 0.718932
# Epoch 300 | Train Loss 1.251011 | Val Loss 0.695194
# Epoch 400 | Train Loss 1.104030 | Val Loss 0.792199
# Early stopping at epoch 462
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7969, MSE = 4.4493e-02
# Theta | Train_2 -> R² = 0.7126, MSE = 6.2923e-02
# Theta | Test_1 -> R² = 0.8525, MSE = 3.2398e-02
# Theta | Test_2 -> R² = 0.8205, MSE = 4.0937e-02
# Theta | Test_3 -> R² = -0.5579, MSE = 4.9251e-01
# Theta | Val -> R² = -2.6459, MSE = 1.1464e+00
# Theta | LSG_1 -> R² = 0.6154, MSE = 1.5641e-01
# Theta | LSG_2 -> R² = -0.6691, MSE = 5.5683e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 1.897329 | Val Loss 2.184369
# Epoch 100 | Train Loss 1.294604 | Val Loss 0.856143
# Epoch 200 | Train Loss 1.262772 | Val Loss 0.718285
# Epoch 300 | Train Loss 1.181809 | Val Loss 0.821256
# Epoch 400 | Train Loss 1.023956 | Val Loss 1.078521
# Early stopping at epoch 410
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8000, MSE = 4.3819e-02
# Theta | Train_2 -> R² = 0.7121, MSE = 6.3020e-02
# Theta | Test_1 -> R² = 0.8332, MSE = 3.6636e-02
# Theta | Test_2 -> R² = 0.8245, MSE = 4.0012e-02
# Theta | Test_3 -> R² = -0.7420, MSE = 5.5073e-01
# Theta | Val -> R² = -3.6907, MSE = 1.4749e+00
# Theta | LSG_1 -> R² = 0.6014, MSE = 1.6210e-01
# Theta | LSG_2 -> R² = -1.1878, MSE = 7.2985e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.970212 | Val Loss 2.092196
# Epoch 100 | Train Loss 1.294876 | Val Loss 0.847940
# Epoch 200 | Train Loss 1.264030 | Val Loss 0.693381
# Epoch 300 | Train Loss 1.185555 | Val Loss 0.794040
# Epoch 400 | Train Loss 1.033771 | Val Loss 0.928121
# Early stopping at epoch 425
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch64_r0.01_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7959, MSE = 4.4714e-02
# Theta | Train_2 -> R² = 0.7155, MSE = 6.2282e-02
# Theta | Test_1 -> R² = 0.8418, MSE = 3.4753e-02
# Theta | Test_2 -> R² = 0.8240, MSE = 4.0138e-02
# Theta | Test_3 -> R² = -0.5040, MSE = 4.7549e-01
# Theta | Val -> R² = -2.5847, MSE = 1.1271e+00
# Theta | LSG_1 -> R² = 0.6225, MSE = 1.5355e-01
# Theta | LSG_2 -> R² = -0.7842, MSE = 5.9522e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.914306 | Val Loss 2.201886
# Epoch 100 | Train Loss 1.294855 | Val Loss 0.865413
# Epoch 200 | Train Loss 1.264629 | Val Loss 0.701840
# Epoch 300 | Train Loss 1.184023 | Val Loss 0.843154
# Epoch 400 | Train Loss 1.043998 | Val Loss 1.001533
# Early stopping at epoch 422
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.7977, MSE = 4.4317e-02
# Theta | Train_2 -> R² = 0.7167, MSE = 6.2010e-02
# Theta | Test_1 -> R² = 0.8350, MSE = 3.6251e-02
# Theta | Test_2 -> R² = 0.8285, MSE = 3.9113e-02
# Theta | Test_3 -> R² = -0.6514, MSE = 5.2208e-01
# Theta | Val -> R² = -2.8677, MSE = 1.2162e+00
# Theta | LSG_1 -> R² = 0.6306, MSE = 1.5023e-01
# Theta | LSG_2 -> R² = -0.8514, MSE = 6.1765e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 2.010853 | Val Loss 2.340820
# Epoch 100 | Train Loss 1.291743 | Val Loss 0.823593
# Epoch 200 | Train Loss 1.267379 | Val Loss 0.705625
# Epoch 300 | Train Loss 1.203448 | Val Loss 0.690689
# Epoch 400 | Train Loss 1.038745 | Val Loss 0.857300
# Early stopping at epoch 460
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.7829, MSE = 4.7572e-02
# Theta | Train_2 -> R² = 0.7123, MSE = 6.2987e-02
# Theta | Test_1 -> R² = 0.8675, MSE = 2.9104e-02
# Theta | Test_2 -> R² = 0.8154, MSE = 4.2093e-02
# Theta | Test_3 -> R² = -0.0874, MSE = 3.4377e-01
# Theta | Val -> R² = -1.8044, MSE = 8.8181e-01
# Theta | LSG_1 -> R² = 0.6013, MSE = 1.6218e-01
# Theta | LSG_2 -> R² = -0.7909, MSE = 5.9747e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.909707 | Val Loss 2.157627
# Epoch 100 | Train Loss 1.291909 | Val Loss 0.834404
# Epoch 200 | Train Loss 1.265077 | Val Loss 0.695302
# Epoch 300 | Train Loss 1.158536 | Val Loss 0.821854
# Epoch 400 | Train Loss 1.033092 | Val Loss 0.997410
# Early stopping at epoch 432
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7887, MSE = 4.6297e-02
# Theta | Train_2 -> R² = 0.7124, MSE = 6.2957e-02
# Theta | Test_1 -> R² = 0.8474, MSE = 3.3528e-02
# Theta | Test_2 -> R² = 0.8243, MSE = 4.0071e-02
# Theta | Test_3 -> R² = -0.5462, MSE = 4.8881e-01
# Theta | Val -> R² = -2.8405, MSE = 1.2076e+00
# Theta | LSG_1 -> R² = 0.6115, MSE = 1.5801e-01
# Theta | LSG_2 -> R² = -0.8589, MSE = 6.2014e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.920956 | Val Loss 2.207983
# Epoch 100 | Train Loss 1.294477 | Val Loss 0.841319
# Epoch 200 | Train Loss 1.268392 | Val Loss 0.712046
# Epoch 300 | Train Loss 1.208510 | Val Loss 0.849664
# Epoch 400 | Train Loss 1.039784 | Val Loss 0.905599
# Early stopping at epoch 414
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8061, MSE = 4.2476e-02
# Theta | Train_2 -> R² = 0.7145, MSE = 6.2505e-02
# Theta | Test_1 -> R² = 0.8464, MSE = 3.3732e-02
# Theta | Test_2 -> R² = 0.8206, MSE = 4.0910e-02
# Theta | Test_3 -> R² = -0.4796, MSE = 4.6777e-01
# Theta | Val -> R² = -2.9162, MSE = 1.2314e+00
# Theta | LSG_1 -> R² = 0.6203, MSE = 1.5444e-01
# Theta | LSG_2 -> R² = -0.8779, MSE = 6.2649e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 2.075530 | Val Loss 2.195830
# Epoch 100 | Train Loss 1.297685 | Val Loss 0.855799
# Epoch 200 | Train Loss 1.270239 | Val Loss 0.708503
# Epoch 300 | Train Loss 1.239341 | Val Loss 0.744186
# Epoch 400 | Train Loss 1.072014 | Val Loss 0.873303
# Early stopping at epoch 440
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch64_r0.9_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7963, MSE = 4.4625e-02
# Theta | Train_2 -> R² = 0.7120, MSE = 6.3041e-02
# Theta | Test_1 -> R² = 0.8443, MSE = 3.4205e-02
# Theta | Test_2 -> R² = 0.8250, MSE = 3.9910e-02
# Theta | Test_3 -> R² = -0.5917, MSE = 5.0319e-01
# Theta | Val -> R² = -2.9835, MSE = 1.2526e+00
# Theta | LSG_1 -> R² = 0.6187, MSE = 1.5510e-01
# Theta | LSG_2 -> R² = -0.8632, MSE = 6.2158e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7265 salvo.
# Epoch 0 | Train Loss 1.668823 | Val Loss 2.392403
# Epoch 100 | Train Loss 0.828947 | Val Loss 0.822120
# Epoch 200 | Train Loss 0.802986 | Val Loss 0.692522
# Epoch 300 | Train Loss 0.779539 | Val Loss 0.673519
# Epoch 400 | Train Loss 0.696959 | Val Loss 0.765335
# Early stopping at epoch 466
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.8148, MSE = 4.0581e-02
# Theta | Train_2 -> R² = 0.7764, MSE = 4.8952e-02
# Theta | Test_1 -> R² = 0.8383, MSE = 3.5524e-02
# Theta | Test_2 -> R² = 0.8611, MSE = 3.1669e-02
# Theta | Test_3 -> R² = -0.8812, MSE = 5.9472e-01
# Theta | Val -> R² = -2.4175, MSE = 1.0746e+00
# Theta | LSG_1 -> R² = 0.6117, MSE = 1.5792e-01
# Theta | LSG_2 -> R² = -1.0797, MSE = 6.9380e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.646265 | Val Loss 2.320942
# Epoch 100 | Train Loss 0.827660 | Val Loss 0.811517
# Epoch 200 | Train Loss 0.800072 | Val Loss 0.683997
# Epoch 300 | Train Loss 0.765084 | Val Loss 0.677540
# Epoch 400 | Train Loss 0.669023 | Val Loss 0.848709
# Early stopping at epoch 451
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8076, MSE = 4.2162e-02
# Theta | Train_2 -> R² = 0.7745, MSE = 4.9368e-02
# Theta | Test_1 -> R² = 0.8410, MSE = 3.4930e-02
# Theta | Test_2 -> R² = 0.8581, MSE = 3.2359e-02
# Theta | Test_3 -> R² = -1.1426, MSE = 6.7738e-01
# Theta | Val -> R² = -2.7026, MSE = 1.1642e+00
# Theta | LSG_1 -> R² = 0.6060, MSE = 1.6024e-01
# Theta | LSG_2 -> R² = -1.0389, MSE = 6.8018e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.546192 | Val Loss 2.140504
# Epoch 100 | Train Loss 0.830689 | Val Loss 0.832072
# Epoch 200 | Train Loss 0.798847 | Val Loss 0.689628
# Epoch 300 | Train Loss 0.751457 | Val Loss 0.668805
# Epoch 400 | Train Loss 0.661785 | Val Loss 0.847368
# Early stopping at epoch 469
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.7777, MSE = 4.8714e-02
# Theta | Train_2 -> R² = 0.7772, MSE = 4.8765e-02
# Theta | Test_1 -> R² = 0.8534, MSE = 3.2193e-02
# Theta | Test_2 -> R² = 0.8428, MSE = 3.5839e-02
# Theta | Test_3 -> R² = -1.0655, MSE = 6.5301e-01
# Theta | Val -> R² = -1.5734, MSE = 8.0915e-01
# Theta | LSG_1 -> R² = 0.5767, MSE = 1.7217e-01
# Theta | LSG_2 -> R² = -0.7079, MSE = 5.6977e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 1.457225 | Val Loss 2.032659
# Epoch 100 | Train Loss 0.832459 | Val Loss 0.843280
# Epoch 200 | Train Loss 0.795326 | Val Loss 0.682100
# Epoch 300 | Train Loss 0.716896 | Val Loss 0.750456
# Epoch 400 | Train Loss 0.593955 | Val Loss 0.925460
# Early stopping at epoch 406
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8130, MSE = 4.0979e-02
# Theta | Train_2 -> R² = 0.7762, MSE = 4.8986e-02
# Theta | Test_1 -> R² = 0.8323, MSE = 3.6832e-02
# Theta | Test_2 -> R² = 0.8650, MSE = 3.0789e-02
# Theta | Test_3 -> R² = -0.8667, MSE = 5.9015e-01
# Theta | Val -> R² = -2.6453, MSE = 1.1462e+00
# Theta | LSG_1 -> R² = 0.6276, MSE = 1.5144e-01
# Theta | LSG_2 -> R² = -1.1290, MSE = 7.1024e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.645716 | Val Loss 2.025117
# Epoch 100 | Train Loss 0.839790 | Val Loss 0.860983
# Epoch 200 | Train Loss 0.808979 | Val Loss 0.726447
# Epoch 300 | Train Loss 0.785922 | Val Loss 0.688978
# Epoch 400 | Train Loss 0.689018 | Val Loss 0.804397
# Early stopping at epoch 494
# Modelo salvo em:
# models/model_arch64_r0.01_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch64_r0.01_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8111, MSE = 4.1376e-02
# Theta | Train_2 -> R² = 0.7717, MSE = 4.9966e-02
# Theta | Test_1 -> R² = 0.8480, MSE = 3.3399e-02
# Theta | Test_2 -> R² = 0.8521, MSE = 3.3721e-02
# Theta | Test_3 -> R² = -0.9601, MSE = 6.1968e-01
# Theta | Val -> R² = -2.6832, MSE = 1.1581e+00
# Theta | LSG_1 -> R² = 0.5863, MSE = 1.6824e-01
# Theta | LSG_2 -> R² = -1.1986, MSE = 7.3347e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.560118 | Val Loss 2.192478
# Epoch 100 | Train Loss 0.827876 | Val Loss 0.812187
# Epoch 200 | Train Loss 0.800974 | Val Loss 0.692128
# Epoch 300 | Train Loss 0.754126 | Val Loss 0.731556
# Epoch 400 | Train Loss 0.625170 | Val Loss 0.902172
# Early stopping at epoch 410
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.8098, MSE = 4.1666e-02
# Theta | Train_2 -> R² = 0.7717, MSE = 4.9983e-02
# Theta | Test_1 -> R² = 0.8268, MSE = 3.8038e-02
# Theta | Test_2 -> R² = 0.8628, MSE = 3.1290e-02
# Theta | Test_3 -> R² = -1.0151, MSE = 6.3707e-01
# Theta | Val -> R² = -3.0695, MSE = 1.2796e+00
# Theta | LSG_1 -> R² = 0.6193, MSE = 1.5484e-01
# Theta | LSG_2 -> R² = -1.1854, MSE = 7.2907e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.750648 | Val Loss 2.487851
# Epoch 100 | Train Loss 0.833143 | Val Loss 0.826162
# Epoch 200 | Train Loss 0.805675 | Val Loss 0.709337
# Epoch 300 | Train Loss 0.783328 | Val Loss 0.707407
# Epoch 400 | Train Loss 0.690922 | Val Loss 0.751982
# Early stopping at epoch 444
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8112, MSE = 4.1373e-02
# Theta | Train_2 -> R² = 0.7711, MSE = 5.0102e-02
# Theta | Test_1 -> R² = 0.8253, MSE = 3.8379e-02
# Theta | Test_2 -> R² = 0.8634, MSE = 3.1147e-02
# Theta | Test_3 -> R² = -1.0309, MSE = 6.4205e-01
# Theta | Val -> R² = -3.3233, MSE = 1.3594e+00
# Theta | LSG_1 -> R² = 0.6101, MSE = 1.5859e-01
# Theta | LSG_2 -> R² = -1.3617, MSE = 7.8789e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.605189 | Val Loss 2.275307
# Epoch 100 | Train Loss 0.828273 | Val Loss 0.814080
# Epoch 200 | Train Loss 0.802121 | Val Loss 0.707235
# Epoch 300 | Train Loss 0.742663 | Val Loss 0.763059
# Epoch 400 | Train Loss 0.614483 | Val Loss 0.873908
# Early stopping at epoch 405
# Modelo salvo em:
# models/model_arch64_r0.9_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch64_r0.9_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8118, MSE = 4.1230e-02
# Theta | Train_2 -> R² = 0.7693, MSE = 5.0502e-02
# Theta | Test_1 -> R² = 0.8317, MSE = 3.6972e-02
# Theta | Test_2 -> R² = 0.8625, MSE = 3.1348e-02
# Theta | Test_3 -> R² = -0.8594, MSE = 5.8785e-01
# Theta | Val -> R² = -3.3893, MSE = 1.3802e+00
# Theta | LSG_1 -> R² = 0.5941, MSE = 1.6509e-01
# Theta | LSG_2 -> R² = -1.4085, MSE = 8.0348e-01
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.570838 | Val Loss 2.258526
# ...
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8740, MSE = 2.7595e-02
# Theta | Train_2 -> R² = 0.3442, MSE = 1.4356e-01
# Theta | Test_1 -> R² = 0.8502, MSE = 3.2900e-02
# Theta | Test_2 -> R² = 0.1798, MSE = 1.8704e-01
# Theta | Test_3 -> R² = -3.3524, MSE = 1.3760e+00
# Theta | Val -> R² = 0.0845, MSE = 2.8787e-01
# Theta | LSG_1 -> R² = -0.1964, MSE = 4.8658e-01
# Theta | LSG_2 -> R² = 0.6341, MSE = 1.2207e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.930014 | Val Loss 1.897129
# Epoch 100 | Train Loss 1.138468 | Val Loss 0.901548
# Epoch 200 | Train Loss 0.959186 | Val Loss 0.939953
# Epoch 300 | Train Loss 0.926965 | Val Loss 1.078664
# Early stopping at epoch 343
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8497, MSE = 3.2929e-02
# Theta | Train_2 -> R² = 0.3230, MSE = 1.4820e-01
# Theta | Test_1 -> R² = 0.7521, MSE = 5.4464e-02
# Theta | Test_2 -> R² = 0.2517, MSE = 1.7064e-01
# Theta | Test_3 -> R² = -3.3207, MSE = 1.3660e+00
# Theta | Val -> R² = 0.2361, MSE = 2.4019e-01
# Theta | LSG_1 -> R² = -0.2824, MSE = 5.2158e-01
# Theta | LSG_2 -> R² = 0.6619, MSE = 1.1281e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 2.000428 | Val Loss 2.036751
# Epoch 100 | Train Loss 1.102253 | Val Loss 0.857497
# Epoch 200 | Train Loss 0.959589 | Val Loss 0.859836
# Epoch 300 | Train Loss 0.924458 | Val Loss 1.055653
# Early stopping at epoch 354
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8869, MSE = 2.4787e-02
# Theta | Train_2 -> R² = 0.7910, MSE = 4.5749e-02
# Theta | Test_1 -> R² = 0.9168, MSE = 1.8281e-02
# Theta | Test_2 -> R² = 0.7319, MSE = 6.1148e-02
# Theta | Test_3 -> R² = -10.3648, MSE = 3.5929e+00
# Theta | Val -> R² = -1.6847, MSE = 8.4417e-01
# Theta | LSG_1 -> R² = 0.4052, MSE = 2.4193e-01
# Theta | LSG_2 -> R² = -0.3465, MSE = 4.4922e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.904060 | Val Loss 1.756702
# Epoch 100 | Train Loss 1.105909 | Val Loss 0.840922
# Epoch 200 | Train Loss 0.962820 | Val Loss 0.855847
# Epoch 300 | Train Loss 0.945176 | Val Loss 1.048314
# Epoch 400 | Train Loss 0.907990 | Val Loss 1.494208
# Early stopping at epoch 444
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch264-128-64_r0.01_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8664, MSE = 2.9274e-02
# Theta | Train_2 -> R² = 0.4268, MSE = 1.2548e-01
# Theta | Test_1 -> R² = 0.7873, MSE = 4.6730e-02
# Theta | Test_2 -> R² = 0.2153, MSE = 1.7894e-01
# Theta | Test_3 -> R² = -13.1149, MSE = 4.4623e+00
# Theta | Val -> R² = -0.7383, MSE = 5.4658e-01
# Theta | LSG_1 -> R² = -0.0511, MSE = 4.2751e-01
# Theta | LSG_2 -> R² = 0.5067, MSE = 1.6456e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.874340 | Val Loss 1.721753
# Epoch 100 | Train Loss 1.125357 | Val Loss 0.786894
# Epoch 200 | Train Loss 0.956789 | Val Loss 0.940344
# Epoch 300 | Train Loss 0.936796 | Val Loss 1.045202
# Epoch 400 | Train Loss 0.907879 | Val Loss 1.306701
# Early stopping at epoch 405
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1481.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.6193, MSE = 8.3401e-02
# Theta | Train_2 -> R² = -0.1016, MSE = 2.4115e-01
# Theta | Test_1 -> R² = 0.4989, MSE = 1.1008e-01
# Theta | Test_2 -> R² = -0.1893, MSE = 2.7122e-01
# Theta | Test_3 -> R² = -4.7583, MSE = 1.8205e+00
# Theta | Val -> R² = 0.7750, MSE = 7.0736e-02
# Theta | LSG_1 -> R² = -0.4628, MSE = 5.9494e-01
# Theta | LSG_2 -> R² = 0.6280, MSE = 1.2410e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.891115 | Val Loss 1.811800
# Epoch 100 | Train Loss 1.103669 | Val Loss 0.845171
# Epoch 200 | Train Loss 1.023026 | Val Loss 1.494411
# Epoch 300 | Train Loss 0.922649 | Val Loss 1.328336
# Early stopping at epoch 330
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4490.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8620, MSE = 3.0242e-02
# Theta | Train_2 -> R² = 0.7970, MSE = 4.4441e-02
# Theta | Test_1 -> R² = 0.9003, MSE = 2.1909e-02
# Theta | Test_2 -> R² = 0.4554, MSE = 1.2420e-01
# Theta | Test_3 -> R² = -10.1072, MSE = 3.5115e+00
# Theta | Val -> R² = -1.8034, MSE = 8.8149e-01
# Theta | LSG_1 -> R² = 0.2424, MSE = 3.0811e-01
# Theta | LSG_2 -> R² = -0.0305, MSE = 3.4377e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.938433 | Val Loss 1.943256
# Epoch 100 | Train Loss 1.132057 | Val Loss 0.869547
# Epoch 200 | Train Loss 0.963857 | Val Loss 1.059410
# Epoch 300 | Train Loss 0.947628 | Val Loss 1.220923
# Early stopping at epoch 387
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed631.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed631.weights.h5
# Theta | Train_1 -> R² = 0.8346, MSE = 3.6235e-02
# Theta | Train_2 -> R² = 0.7552, MSE = 5.3586e-02
# Theta | Test_1 -> R² = 0.8675, MSE = 2.9106e-02
# Theta | Test_2 -> R² = 0.3890, MSE = 1.3933e-01
# Theta | Test_3 -> R² = -15.9556, MSE = 5.3604e+00
# Theta | Val -> R² = -1.0993, MSE = 6.6011e-01
# Theta | LSG_1 -> R² = -0.1400, MSE = 4.6365e-01
# Theta | LSG_2 -> R² = 0.6269, MSE = 1.2449e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.973428 | Val Loss 1.912384
# Epoch 100 | Train Loss 1.122922 | Val Loss 0.840193
# Epoch 200 | Train Loss 0.994919 | Val Loss 1.094326
# Epoch 300 | Train Loss 0.922404 | Val Loss 1.124958
# Early stopping at epoch 344
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3344.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.8998, MSE = 2.1955e-02
# Theta | Train_2 -> R² = 0.6182, MSE = 8.3574e-02
# Theta | Test_1 -> R² = 0.9369, MSE = 1.3869e-02
# Theta | Test_2 -> R² = 0.3466, MSE = 1.4902e-01
# Theta | Test_3 -> R² = -6.1383, MSE = 2.2567e+00
# Theta | Val -> R² = 0.3105, MSE = 2.1679e-01
# Theta | LSG_1 -> R² = -0.2089, MSE = 4.9168e-01
# Theta | LSG_2 -> R² = 0.7261, MSE = 9.1374e-02
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 1.903619 | Val Loss 1.718139
# Epoch 100 | Train Loss 1.084500 | Val Loss 0.833102
# Epoch 200 | Train Loss 0.957759 | Val Loss 0.933951
# Epoch 300 | Train Loss 0.920146 | Val Loss 1.290446
# Early stopping at epoch 334
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7265.keras
# weights/model_arch264-128-64_r0.9_Ld0.3_Lp0.7_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8660, MSE = 2.9352e-02
# Theta | Train_2 -> R² = 0.3123, MSE = 1.5054e-01
# Theta | Test_1 -> R² = 0.7994, MSE = 4.4059e-02
# Theta | Test_2 -> R² = 0.1769, MSE = 1.8772e-01
# Theta | Test_3 -> R² = -3.6911, MSE = 1.4831e+00
# Theta | Val -> R² = 0.6767, MSE = 1.0167e-01
# Theta | LSG_1 -> R² = -0.5840, MSE = 6.4422e-01
# Theta | LSG_2 -> R² = 0.8086, MSE = 6.3841e-02
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7265 salvo.
# Epoch 0 | Train Loss 1.498831 | Val Loss 1.724999
# Epoch 100 | Train Loss 0.697008 | Val Loss 0.727635
# Epoch 200 | Train Loss 0.575859 | Val Loss 0.736510
# Epoch 300 | Train Loss 0.547217 | Val Loss 0.891920
# Epoch 400 | Train Loss 0.530964 | Val Loss 1.005912
# Early stopping at epoch 444
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.9496, MSE = 1.1040e-02
# Theta | Train_2 -> R² = 0.3300, MSE = 1.4666e-01
# Theta | Test_1 -> R² = 0.8899, MSE = 2.4183e-02
# Theta | Test_2 -> R² = 0.6870, MSE = 7.1380e-02
# Theta | Test_3 -> R² = -9.5325, MSE = 3.3298e+00
# Theta | Val -> R² = -0.3346, MSE = 4.1964e-01
# Theta | LSG_1 -> R² = 0.4478, MSE = 2.2459e-01
# Theta | LSG_2 -> R² = -0.7207, MSE = 5.7404e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1481 salvo.
# Epoch 0 | Train Loss 1.591562 | Val Loss 1.952476
# Epoch 100 | Train Loss 0.711018 | Val Loss 0.764070
# Epoch 200 | Train Loss 0.578680 | Val Loss 1.247231
# Epoch 300 | Train Loss 0.547683 | Val Loss 1.030307
# Early stopping at epoch 398
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.5131, MSE = 1.0668e-01
# Theta | Train_2 -> R² = -0.4937, MSE = 3.2698e-01
# Theta | Test_1 -> R² = 0.7552, MSE = 5.3772e-02
# Theta | Test_2 -> R² = 0.1057, MSE = 2.0393e-01
# Theta | Test_3 -> R² = -4.8969, MSE = 1.8643e+00
# Theta | Val -> R² = 0.5770, MSE = 1.3302e-01
# Theta | LSG_1 -> R² = -0.6946, MSE = 6.8922e-01
# Theta | LSG_2 -> R² = 0.8003, MSE = 6.6617e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4490 salvo.
# Epoch 0 | Train Loss 1.505248 | Val Loss 1.857500
# Epoch 100 | Train Loss 0.704111 | Val Loss 0.825625
# Epoch 200 | Train Loss 0.567935 | Val Loss 0.817426
# Epoch 300 | Train Loss 0.553524 | Val Loss 0.807909
# Early stopping at epoch 332
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.9067, MSE = 2.0435e-02
# Theta | Train_2 -> R² = 0.8067, MSE = 4.2317e-02
# Theta | Test_1 -> R² = 0.8790, MSE = 2.6573e-02
# Theta | Test_2 -> R² = 0.5856, MSE = 9.4507e-02
# Theta | Test_3 -> R² = -5.0900, MSE = 1.9253e+00
# Theta | Val -> R² = -2.9860, MSE = 1.2533e+00
# Theta | LSG_1 -> R² = 0.4821, MSE = 2.1063e-01
# Theta | LSG_2 -> R² = -1.3147, MSE = 7.7220e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=631 salvo.
# Epoch 0 | Train Loss 1.614064 | Val Loss 1.975746
# Epoch 100 | Train Loss 0.697177 | Val Loss 0.760163
# Epoch 200 | Train Loss 0.568646 | Val Loss 0.802164
# Epoch 300 | Train Loss 0.554150 | Val Loss 0.870595
# Epoch 400 | Train Loss 0.531920 | Val Loss 1.188823
# Early stopping at epoch 411
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.9503, MSE = 1.0884e-02
# Theta | Train_2 -> R² = 0.5101, MSE = 1.0725e-01
# Theta | Test_1 -> R² = 0.8538, MSE = 3.2117e-02
# Theta | Test_2 -> R² = 0.6649, MSE = 7.6413e-02
# Theta | Test_3 -> R² = -11.1620, MSE = 3.8449e+00
# Theta | Val -> R² = -0.1810, MSE = 3.7134e-01
# Theta | LSG_1 -> R² = 0.2222, MSE = 3.1635e-01
# Theta | LSG_2 -> R² = -0.1052, MSE = 3.6870e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3344 salvo.
# Epoch 0 | Train Loss 1.632701 | Val Loss 1.902156
# Epoch 100 | Train Loss 0.748499 | Val Loss 0.764563
# Epoch 200 | Train Loss 0.584513 | Val Loss 0.832020
# Epoch 300 | Train Loss 0.563969 | Val Loss 0.923598
# Epoch 400 | Train Loss 0.537141 | Val Loss 1.106048
# Early stopping at epoch 457
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch264-128-64_r0.01_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.7239, MSE = 6.0498e-02
# Theta | Train_2 -> R² = 0.7833, MSE = 4.7427e-02
# Theta | Test_1 -> R² = 0.3997, MSE = 1.3186e-01
# Theta | Test_2 -> R² = 0.5013, MSE = 1.1373e-01
# Theta | Test_3 -> R² = -23.7481, MSE = 7.8240e+00
# Theta | Val -> R² = -2.9391, MSE = 1.2386e+00
# Theta | LSG_1 -> R² = 0.1678, MSE = 3.3845e-01
# Theta | LSG_2 -> R² = -0.2712, MSE = 4.2408e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7265 salvo.
# Epoch 0 | Train Loss 1.532586 | Val Loss 1.832189
# Epoch 100 | Train Loss 0.680984 | Val Loss 0.776362
# Epoch 200 | Train Loss 0.594941 | Val Loss 0.887505
# Epoch 300 | Train Loss 0.594715 | Val Loss 0.888036
# Epoch 400 | Train Loss 0.537754 | Val Loss 0.900141
# Epoch 500 | Train Loss 0.523115 | Val Loss 1.047694
# Early stopping at epoch 506
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1481.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed1481.weights.h5
# Theta | Train_1 -> R² = 0.9225, MSE = 1.6977e-02
# Theta | Train_2 -> R² = 0.6419, MSE = 7.8382e-02
# Theta | Test_1 -> R² = 0.4680, MSE = 1.1686e-01
# Theta | Test_2 -> R² = 0.7279, MSE = 6.2052e-02
# Theta | Test_3 -> R² = -17.8780, MSE = 5.9681e+00
# Theta | Val -> R² = -3.1943, MSE = 1.3188e+00
# Theta | LSG_1 -> R² = 0.5039, MSE = 2.0177e-01
# Theta | LSG_2 -> R² = -2.2985, MSE = 1.1004e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1481 salvo.
# Epoch 0 | Train Loss 1.585761 | Val Loss 1.888430
# Epoch 100 | Train Loss 0.708812 | Val Loss 0.772651
# Epoch 200 | Train Loss 0.577043 | Val Loss 0.796984
# Epoch 300 | Train Loss 0.549628 | Val Loss 0.921206
# Epoch 400 | Train Loss 0.530889 | Val Loss 1.228778
# Early stopping at epoch 483
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4490.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed4490.weights.h5
# Theta | Train_1 -> R² = 0.8160, MSE = 4.0304e-02
# Theta | Train_2 -> R² = 0.7438, MSE = 5.6092e-02
# Theta | Test_1 -> R² = 0.2996, MSE = 1.5385e-01
# Theta | Test_2 -> R² = 0.5289, MSE = 1.0743e-01
# Theta | Test_3 -> R² = -24.0818, MSE = 7.9294e+00
# Theta | Val -> R² = -5.2980, MSE = 1.9803e+00
# Theta | LSG_1 -> R² = 0.2635, MSE = 2.9956e-01
# Theta | LSG_2 -> R² = -0.4681, MSE = 4.8978e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4490 salvo.
# Epoch 0 | Train Loss 1.490672 | Val Loss 1.802788
# Epoch 100 | Train Loss 0.725170 | Val Loss 0.776142
# Epoch 200 | Train Loss 0.629628 | Val Loss 0.981972
# Epoch 300 | Train Loss 0.558095 | Val Loss 0.883301
# Epoch 400 | Train Loss 0.539710 | Val Loss 1.136242
# Early stopping at epoch 460
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed631.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed631.weights.h5
# Theta | Train_1 -> R² = 0.1714, MSE = 1.8154e-01
# Theta | Train_2 -> R² = -1.0753, MSE = 4.5428e-01
# Theta | Test_1 -> R² = 0.4981, MSE = 1.1026e-01
# Theta | Test_2 -> R² = -0.2168, MSE = 2.7749e-01
# Theta | Test_3 -> R² = -2.5418, MSE = 1.1197e+00
# Theta | Val -> R² = 0.7654, MSE = 7.3758e-02
# Theta | LSG_1 -> R² = -2.0951, MSE = 1.2588e+00
# Theta | LSG_2 -> R² = 0.8463, MSE = 5.1275e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=631 salvo.
# Epoch 0 | Train Loss 1.591113 | Val Loss 1.948898
# Epoch 100 | Train Loss 0.684285 | Val Loss 0.787327
# Epoch 200 | Train Loss 0.575364 | Val Loss 0.809308
# Epoch 300 | Train Loss 0.546977 | Val Loss 0.870200
# Epoch 400 | Train Loss 0.529934 | Val Loss 1.103234
# Epoch 500 | Train Loss 0.531267 | Val Loss 1.208919
# Early stopping at epoch 537
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3344.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed3344.weights.h5
# Theta | Train_1 -> R² = 0.6092, MSE = 8.5625e-02
# Theta | Train_2 -> R² = -0.3290, MSE = 2.9092e-01
# Theta | Test_1 -> R² = 0.9391, MSE = 1.3387e-02
# Theta | Test_2 -> R² = 0.3532, MSE = 1.4751e-01
# Theta | Test_3 -> R² = -12.2576, MSE = 4.1913e+00
# Theta | Val -> R² = -1.0584, MSE = 6.4725e-01
# Theta | LSG_1 -> R² = -0.0596, MSE = 4.3096e-01
# Theta | LSG_2 -> R² = 0.6309, MSE = 1.2313e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3344 salvo.
# Epoch 0 | Train Loss 1.596785 | Val Loss 1.788485
# Epoch 100 | Train Loss 0.717001 | Val Loss 0.783191
# Epoch 200 | Train Loss 0.577786 | Val Loss 0.782332
# Epoch 300 | Train Loss 0.552018 | Val Loss 0.888113
# Epoch 400 | Train Loss 0.544921 | Val Loss 1.151084
# Early stopping at epoch 428
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7265.keras
# weights/model_arch264-128-64_r0.9_Ld0.7_Lp0.3_seed7265.weights.h5
# Theta | Train_1 -> R² = 0.8988, MSE = 2.2181e-02
# Theta | Train_2 -> R² = 0.6178, MSE = 8.3675e-02
# Theta | Test_1 -> R² = 0.7452, MSE = 5.5977e-02
# Theta | Test_2 -> R² = 0.6133, MSE = 8.8182e-02
# Theta | Test_3 -> R² = -13.7010, MSE = 4.6476e+00
# Theta | Val -> R² = -0.3147, MSE = 4.1338e-01
# Theta | LSG_1 -> R² = 0.1364, MSE = 3.5123e-01
# Theta | LSG_2 -> R² = 0.1446, MSE = 2.8536e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7265 salvo.
