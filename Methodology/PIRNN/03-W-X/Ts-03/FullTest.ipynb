# %% [markdown]
# - Entradas: PwmD, PwmE
# - Saidas: X
# - Trajetorias: ZZ

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["WdRef", "WeRef", "Theta"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.521132 | Val Loss 0.691506
# Epoch 100 | Train Loss 0.315320 | Val Loss 0.427710
# Epoch 200 | Train Loss 0.305937 | Val Loss 0.414281
# Epoch 300 | Train Loss 0.301403 | Val Loss 0.419161
# Epoch 400 | Train Loss 0.298523 | Val Loss 0.414678
# Epoch 500 | Train Loss 0.295844 | Val Loss 0.411213
# Epoch 600 | Train Loss 0.293589 | Val Loss 0.412703
# Epoch 700 | Train Loss 0.292416 | Val Loss 0.413070
# Early stopping at epoch 784
# X | train1 -> R² = -0.0432, MSE = 1.1248e-01
# X | train2 -> R² = -7.2128, MSE = 6.9202e-01
# X | test1 -> R² = -0.1471, MSE = 1.2017e-01
# X | test2 -> R² = -7.2767, MSE = 6.8112e-01
# X | test3 -> R² = 0.9507, MSE = 4.5384e-03
# X | val -> R² = 0.7121, MSE = 2.7529e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.512567 | Val Loss 0.596525
# Epoch 100 | Train Loss 0.317279 | Val Loss 0.433349
# Epoch 200 | Train Loss 0.306766 | Val Loss 0.413441
# Epoch 300 | Train Loss 0.300553 | Val Loss 0.416868
# Epoch 400 | Train Loss 0.296507 | Val Loss 0.426662
# Epoch 500 | Train Loss 0.293945 | Val Loss 0.443766
# Early stopping at epoch 507
# X | train1 -> R² = -0.0794, MSE = 1.1639e-01
# X | train2 -> R² = -7.2137, MSE = 6.9209e-01
# X | test1 -> R² = -0.0837, MSE = 1.1353e-01
# X | test2 -> R² = -7.1058, MSE = 6.6706e-01
# X | test3 -> R² = 0.6396, MSE = 3.3158e-02
# X | val -> R² = 0.4035, MSE = 5.7035e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.515289 | Val Loss 0.658227
# Epoch 100 | Train Loss 0.317252 | Val Loss 0.447379
# Epoch 200 | Train Loss 0.307539 | Val Loss 0.418044
# Epoch 300 | Train Loss 0.300710 | Val Loss 0.410582
# Epoch 400 | Train Loss 0.295933 | Val Loss 0.408087
# Epoch 500 | Train Loss 0.294162 | Val Loss 0.409195
# Epoch 600 | Train Loss 0.293301 | Val Loss 0.408330
# Epoch 700 | Train Loss 0.292673 | Val Loss 0.406418
# Epoch 800 | Train Loss 0.292171 | Val Loss 0.404251
# Epoch 900 | Train Loss 0.291751 | Val Loss 0.402499
# Epoch 1000 | Train Loss 0.291335 | Val Loss 0.401304
# Epoch 1100 | Train Loss 0.290848 | Val Loss 0.400774
# Epoch 1200 | Train Loss 0.290300 | Val Loss 0.401296
# Epoch 1300 | Train Loss 0.289756 | Val Loss 0.402604
# Early stopping at epoch 1314
# X | train1 -> R² = -0.0865, MSE = 1.1715e-01
# X | train2 -> R² = -7.0278, MSE = 6.7642e-01
# X | test1 -> R² = -0.2331, MSE = 1.2918e-01
# X | test2 -> R² = -7.0990, MSE = 6.6649e-01
# X | test3 -> R² = 0.4208, MSE = 5.3292e-02
# X | val -> R² = -0.2321, MSE = 1.1781e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.506435 | Val Loss 0.650745
# Epoch 100 | Train Loss 0.317577 | Val Loss 0.450104
# Epoch 200 | Train Loss 0.308213 | Val Loss 0.422577
# Epoch 300 | Train Loss 0.303187 | Val Loss 0.408996
# Epoch 400 | Train Loss 0.297919 | Val Loss 0.407486
# Epoch 500 | Train Loss 0.294237 | Val Loss 0.411697
# Epoch 600 | Train Loss 0.292668 | Val Loss 0.413554
# Early stopping at epoch 668
# X | train1 -> R² = -0.1304, MSE = 1.2188e-01
# X | train2 -> R² = -7.1862, MSE = 6.8978e-01
# X | test1 -> R² = -0.1341, MSE = 1.1881e-01
# X | test2 -> R² = -7.1256, MSE = 6.6868e-01
# X | test3 -> R² = 0.7727, MSE = 2.0911e-02
# X | val -> R² = 0.3922, MSE = 5.8116e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.521027 | Val Loss 0.694753
# Epoch 100 | Train Loss 0.317690 | Val Loss 0.441878
# Epoch 200 | Train Loss 0.306676 | Val Loss 0.413588
# Epoch 300 | Train Loss 0.302302 | Val Loss 0.417274
# Epoch 400 | Train Loss 0.298945 | Val Loss 0.420734
# Early stopping at epoch 492
# X | train1 -> R² = -0.1415, MSE = 1.2308e-01
# X | train2 -> R² = -7.0425, MSE = 6.7767e-01
# X | test1 -> R² = -0.1319, MSE = 1.1858e-01
# X | test2 -> R² = -6.8900, MSE = 6.4930e-01
# X | test3 -> R² = 0.5761, MSE = 3.9000e-02
# X | val -> R² = 0.2817, MSE = 6.8689e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.514064 | Val Loss 0.670702
# Epoch 100 | Train Loss 0.313542 | Val Loss 0.425470
# Epoch 200 | Train Loss 0.306537 | Val Loss 0.413521
# Epoch 300 | Train Loss 0.301630 | Val Loss 0.412789
# Epoch 400 | Train Loss 0.297489 | Val Loss 0.409360
# Epoch 500 | Train Loss 0.295079 | Val Loss 0.413326
# Epoch 600 | Train Loss 0.293810 | Val Loss 0.417600
# Early stopping at epoch 673
# X | train1 -> R² = -0.1050, MSE = 1.1915e-01
# X | train2 -> R² = -7.1203, MSE = 6.8422e-01
# X | test1 -> R² = -0.1324, MSE = 1.1863e-01
# X | test2 -> R² = -7.0535, MSE = 6.6275e-01
# X | test3 -> R² = 0.8537, MSE = 1.3464e-02
# X | val -> R² = 0.5085, MSE = 4.7003e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.510774 | Val Loss 0.638547
# Epoch 100 | Train Loss 0.317356 | Val Loss 0.442168
# Epoch 200 | Train Loss 0.307015 | Val Loss 0.416159
# Epoch 300 | Train Loss 0.299934 | Val Loss 0.411579
# Epoch 400 | Train Loss 0.295292 | Val Loss 0.412153
# Epoch 500 | Train Loss 0.293596 | Val Loss 0.415769
# Early stopping at epoch 544
# X | train1 -> R² = -0.1771, MSE = 1.2692e-01
# X | train2 -> R² = -7.2336, MSE = 6.9376e-01
# X | test1 -> R² = -0.1920, MSE = 1.2487e-01
# X | test2 -> R² = -7.1454, MSE = 6.7031e-01
# X | test3 -> R² = 0.5757, MSE = 3.9034e-02
# X | val -> R² = 0.1710, MSE = 7.9272e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.506070 | Val Loss 0.610933
# Epoch 100 | Train Loss 0.314746 | Val Loss 0.442976
# Epoch 200 | Train Loss 0.307214 | Val Loss 0.418268
# Epoch 300 | Train Loss 0.301181 | Val Loss 0.407517
# Epoch 400 | Train Loss 0.295918 | Val Loss 0.405628
# Epoch 500 | Train Loss 0.293800 | Val Loss 0.409720
# Epoch 600 | Train Loss 0.292828 | Val Loss 0.408111
# Early stopping at epoch 638
# X | train1 -> R² = -0.1337, MSE = 1.2225e-01
# X | train2 -> R² = -7.0248, MSE = 6.7617e-01
# X | test1 -> R² = -0.1698, MSE = 1.2255e-01
# X | test2 -> R² = -7.0140, MSE = 6.5950e-01
# X | test3 -> R² = 0.7690, MSE = 2.1249e-02
# X | val -> R² = 0.2833, MSE = 6.8530e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.511031 | Val Loss 0.624903
# Epoch 100 | Train Loss 0.316281 | Val Loss 0.441980
# Epoch 200 | Train Loss 0.306286 | Val Loss 0.417226
# Epoch 300 | Train Loss 0.300160 | Val Loss 0.412972
# Epoch 400 | Train Loss 0.296745 | Val Loss 0.415453
# Epoch 500 | Train Loss 0.294878 | Val Loss 0.421441
# Early stopping at epoch 539
# X | train1 -> R² = -0.1764, MSE = 1.2684e-01
# X | train2 -> R² = -7.2604, MSE = 6.9602e-01
# X | test1 -> R² = -0.2010, MSE = 1.2581e-01
# X | test2 -> R² = -7.1461, MSE = 6.7037e-01
# X | test3 -> R² = 0.5577, MSE = 4.0698e-02
# X | val -> R² = 0.1607, MSE = 8.0256e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.508730 | Val Loss 0.637473
# Epoch 100 | Train Loss 0.315408 | Val Loss 0.443966
# Epoch 200 | Train Loss 0.306971 | Val Loss 0.418399
# Epoch 300 | Train Loss 0.300339 | Val Loss 0.413592
# Epoch 400 | Train Loss 0.295866 | Val Loss 0.416203
# Epoch 500 | Train Loss 0.294179 | Val Loss 0.427611
# Early stopping at epoch 537
# X | train1 -> R² = -0.1482, MSE = 1.2381e-01
# X | train2 -> R² = -7.0492, MSE = 6.7823e-01
# X | test1 -> R² = -0.1487, MSE = 1.2034e-01
# X | test2 -> R² = -6.9724, MSE = 6.5607e-01
# X | test3 -> R² = 0.3209, MSE = 6.2484e-02
# X | val -> R² = -0.1104, MSE = 1.0618e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.514911 | Val Loss 0.658648
# Epoch 100 | Train Loss 0.316025 | Val Loss 0.424432
# Epoch 200 | Train Loss 0.306903 | Val Loss 0.413306
# Epoch 300 | Train Loss 0.302518 | Val Loss 0.417301
# Epoch 400 | Train Loss 0.299157 | Val Loss 0.416863
# Epoch 500 | Train Loss 0.296448 | Val Loss 0.422343
# Early stopping at epoch 503
# X | train1 -> R² = -0.1032, MSE = 1.1896e-01
# X | train2 -> R² = -7.1049, MSE = 6.8292e-01
# X | test1 -> R² = -0.0932, MSE = 1.1452e-01
# X | test2 -> R² = -7.0029, MSE = 6.5858e-01
# X | test3 -> R² = 0.8564, MSE = 1.3208e-02
# X | val -> R² = 0.6661, MSE = 3.1932e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.518453 | Val Loss 0.651288
# Epoch 100 | Train Loss 0.317752 | Val Loss 0.432435
# Epoch 200 | Train Loss 0.307935 | Val Loss 0.415143
# Epoch 300 | Train Loss 0.302635 | Val Loss 0.411232
# Epoch 400 | Train Loss 0.298139 | Val Loss 0.409688
# Epoch 500 | Train Loss 0.295838 | Val Loss 0.414749
# Epoch 600 | Train Loss 0.294259 | Val Loss 0.418404
# Early stopping at epoch 644
# X | train1 -> R² = -0.1254, MSE = 1.2135e-01
# X | train2 -> R² = -7.0492, MSE = 6.7823e-01
# X | test1 -> R² = -0.1580, MSE = 1.2131e-01
# X | test2 -> R² = -6.9933, MSE = 6.5780e-01
# X | test3 -> R² = 0.9326, MSE = 6.2047e-03
# X | val -> R² = 0.8412, MSE = 1.5183e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.496703 | Val Loss 0.595593
# Epoch 100 | Train Loss 0.316859 | Val Loss 0.446082
# Epoch 200 | Train Loss 0.304470 | Val Loss 0.415415
# Epoch 300 | Train Loss 0.298661 | Val Loss 0.416703
# Epoch 400 | Train Loss 0.294974 | Val Loss 0.415212
# Epoch 500 | Train Loss 0.293309 | Val Loss 0.416736
# Early stopping at epoch 511
# X | train1 -> R² = -0.1502, MSE = 1.2402e-01
# X | train2 -> R² = -7.1470, MSE = 6.8647e-01
# X | test1 -> R² = -0.1747, MSE = 1.2306e-01
# X | test2 -> R² = -7.0874, MSE = 6.6553e-01
# X | test3 -> R² = 0.7633, MSE = 2.1774e-02
# X | val -> R² = 0.4282, MSE = 5.4680e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.502653 | Val Loss 0.625104
# Epoch 100 | Train Loss 0.314953 | Val Loss 0.433786
# Epoch 200 | Train Loss 0.306356 | Val Loss 0.412835
# Epoch 300 | Train Loss 0.299201 | Val Loss 0.404957
# Epoch 400 | Train Loss 0.294978 | Val Loss 0.405346
# Epoch 500 | Train Loss 0.293207 | Val Loss 0.408918
# Epoch 600 | Train Loss 0.292291 | Val Loss 0.410375
# Early stopping at epoch 627
# X | train1 -> R² = -0.1118, MSE = 1.1988e-01
# X | train2 -> R² = -7.1519, MSE = 6.8688e-01
# X | test1 -> R² = -0.1647, MSE = 1.2202e-01
# X | test2 -> R² = -7.1686, MSE = 6.7222e-01
# X | test3 -> R² = 0.7225, MSE = 2.5528e-02
# X | val -> R² = 0.2922, MSE = 6.7684e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.526669 | Val Loss 0.696472
# Epoch 100 | Train Loss 0.317089 | Val Loss 0.439942
# Epoch 200 | Train Loss 0.306779 | Val Loss 0.411162
# Epoch 300 | Train Loss 0.301586 | Val Loss 0.406311
# Epoch 400 | Train Loss 0.298432 | Val Loss 0.410159
# Epoch 500 | Train Loss 0.296020 | Val Loss 0.420968
# Early stopping at epoch 599
# X | train1 -> R² = -0.1615, MSE = 1.2524e-01
# X | train2 -> R² = -7.0894, MSE = 6.8162e-01
# X | test1 -> R² = -0.1710, MSE = 1.2268e-01
# X | test2 -> R² = -7.0417, MSE = 6.6178e-01
# X | test3 -> R² = 0.8645, MSE = 1.2466e-02
# X | val -> R² = 0.6659, MSE = 3.1952e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.457220 | Val Loss 0.690587
# Epoch 100 | Train Loss 0.241774 | Val Loss 0.468111
# Epoch 200 | Train Loss 0.229722 | Val Loss 0.441808
# Epoch 300 | Train Loss 0.223345 | Val Loss 0.433771
# Epoch 400 | Train Loss 0.217134 | Val Loss 0.432177
# Epoch 500 | Train Loss 0.214374 | Val Loss 0.438677
# Epoch 600 | Train Loss 0.212964 | Val Loss 0.437092
# Early stopping at epoch 632
# X | train1 -> R² = -1.2264, MSE = 2.4006e-01
# X | train2 -> R² = -14.8853, MSE = 1.3385e+00
# X | test1 -> R² = -1.3710, MSE = 2.4839e-01
# X | test2 -> R² = -15.0291, MSE = 1.3191e+00
# X | test3 -> R² = 0.3134, MSE = 6.3170e-02
# X | val -> R² = -0.4036, MSE = 1.3422e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.476138 | Val Loss 0.670849
# Epoch 100 | Train Loss 0.244596 | Val Loss 0.479051
# Epoch 200 | Train Loss 0.231853 | Val Loss 0.445732
# Epoch 300 | Train Loss 0.227221 | Val Loss 0.433702
# Epoch 400 | Train Loss 0.223489 | Val Loss 0.428924
# Epoch 500 | Train Loss 0.220046 | Val Loss 0.423053
# Epoch 600 | Train Loss 0.217676 | Val Loss 0.421791
# Epoch 700 | Train Loss 0.215413 | Val Loss 0.425355
# Epoch 800 | Train Loss 0.213186 | Val Loss 0.432414
# Early stopping at epoch 822
# X | train1 -> R² = -1.1133, MSE = 2.2786e-01
# X | train2 -> R² = -14.6654, MSE = 1.3200e+00
# X | test1 -> R² = -1.3837, MSE = 2.4972e-01
# X | test2 -> R² = -14.8500, MSE = 1.3043e+00
# X | test3 -> R² = 0.5670, MSE = 3.9834e-02
# X | val -> R² = 0.2548, MSE = 7.1254e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.461843 | Val Loss 0.551088
# Epoch 100 | Train Loss 0.243627 | Val Loss 0.487025
# Epoch 200 | Train Loss 0.231799 | Val Loss 0.445330
# Epoch 300 | Train Loss 0.227039 | Val Loss 0.432877
# Epoch 400 | Train Loss 0.221448 | Val Loss 0.425545
# Epoch 500 | Train Loss 0.217655 | Val Loss 0.427053
# Epoch 600 | Train Loss 0.215412 | Val Loss 0.433151
# Epoch 700 | Train Loss 0.213490 | Val Loss 0.437988
# Early stopping at epoch 710
# X | train1 -> R² = -1.2253, MSE = 2.3994e-01
# X | train2 -> R² = -15.0197, MSE = 1.3498e+00
# X | test1 -> R² = -1.4160, MSE = 2.5310e-01
# X | test2 -> R² = -15.1818, MSE = 1.3316e+00
# X | test3 -> R² = 0.1105, MSE = 8.1837e-02
# X | val -> R² = -0.4566, MSE = 1.3928e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.461471 | Val Loss 0.624832
# Epoch 100 | Train Loss 0.246808 | Val Loss 0.487940
# Epoch 200 | Train Loss 0.232563 | Val Loss 0.449291
# Epoch 300 | Train Loss 0.226876 | Val Loss 0.434984
# Epoch 400 | Train Loss 0.222339 | Val Loss 0.429599
# Epoch 500 | Train Loss 0.218361 | Val Loss 0.425604
# Epoch 600 | Train Loss 0.215570 | Val Loss 0.430330
# Epoch 700 | Train Loss 0.213712 | Val Loss 0.438422
# Early stopping at epoch 781
# X | train1 -> R² = -1.0951, MSE = 2.2591e-01
# X | train2 -> R² = -14.8518, MSE = 1.3357e+00
# X | test1 -> R² = -1.3415, MSE = 2.4529e-01
# X | test2 -> R² = -15.0614, MSE = 1.3217e+00
# X | test3 -> R² = 0.8478, MSE = 1.4007e-02
# X | val -> R² = 0.4220, MSE = 5.5268e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.457641 | Val Loss 0.646393
# Epoch 100 | Train Loss 0.248024 | Val Loss 0.521393
# Epoch 200 | Train Loss 0.233813 | Val Loss 0.467774
# Epoch 300 | Train Loss 0.228049 | Val Loss 0.443139
# Epoch 400 | Train Loss 0.223362 | Val Loss 0.435906
# Epoch 500 | Train Loss 0.217775 | Val Loss 0.432859
# Epoch 600 | Train Loss 0.213667 | Val Loss 0.431081
# Epoch 700 | Train Loss 0.211962 | Val Loss 0.428474
# Epoch 800 | Train Loss 0.210716 | Val Loss 0.427236
# Epoch 900 | Train Loss 0.209739 | Val Loss 0.426498
# Epoch 1000 | Train Loss 0.208844 | Val Loss 0.427483
# Epoch 1100 | Train Loss 0.208176 | Val Loss 0.429882
# Early stopping at epoch 1144
# X | train1 -> R² = -1.1203, MSE = 2.2862e-01
# X | train2 -> R² = -14.9287, MSE = 1.3422e+00
# X | test1 -> R² = -1.1351, MSE = 2.2368e-01
# X | test2 -> R² = -15.0574, MSE = 1.3214e+00
# X | test3 -> R² = 0.0825, MSE = 8.4416e-02
# X | val -> R² = -0.6072, MSE = 1.5368e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.464038 | Val Loss 0.711328
# Epoch 100 | Train Loss 0.243653 | Val Loss 0.474745
# Epoch 200 | Train Loss 0.231044 | Val Loss 0.445937
# Epoch 300 | Train Loss 0.224692 | Val Loss 0.437891
# Epoch 400 | Train Loss 0.219153 | Val Loss 0.433022
# Epoch 500 | Train Loss 0.215475 | Val Loss 0.442710
# Epoch 600 | Train Loss 0.214129 | Val Loss 0.448204
# Early stopping at epoch 687
# X | train1 -> R² = -1.1504, MSE = 2.3187e-01
# X | train2 -> R² = -14.8765, MSE = 1.3378e+00
# X | test1 -> R² = -1.3352, MSE = 2.4464e-01
# X | test2 -> R² = -15.0863, MSE = 1.3238e+00
# X | test3 -> R² = 0.6576, MSE = 3.1500e-02
# X | val -> R² = -0.0347, MSE = 9.8939e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.465459 | Val Loss 0.637536
# Epoch 100 | Train Loss 0.251545 | Val Loss 0.541940
# Epoch 200 | Train Loss 0.236136 | Val Loss 0.475247
# Epoch 300 | Train Loss 0.228470 | Val Loss 0.442101
# Epoch 400 | Train Loss 0.223012 | Val Loss 0.433735
# Epoch 500 | Train Loss 0.217223 | Val Loss 0.434897
# Epoch 600 | Train Loss 0.213628 | Val Loss 0.452337
# Epoch 700 | Train Loss 0.212362 | Val Loss 0.468263
# Early stopping at epoch 739
# X | train1 -> R² = -1.1587, MSE = 2.3276e-01
# X | train2 -> R² = -14.7857, MSE = 1.3301e+00
# X | test1 -> R² = -1.3454, MSE = 2.4571e-01
# X | test2 -> R² = -15.1007, MSE = 1.3250e+00
# X | test3 -> R² = 0.8335, MSE = 1.5316e-02
# X | val -> R² = 0.2254, MSE = 7.4068e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.455330 | Val Loss 0.627508
# Epoch 100 | Train Loss 0.243385 | Val Loss 0.497126
# Epoch 200 | Train Loss 0.231692 | Val Loss 0.454948
# Epoch 300 | Train Loss 0.224854 | Val Loss 0.430587
# Epoch 400 | Train Loss 0.218967 | Val Loss 0.425053
# Epoch 500 | Train Loss 0.215531 | Val Loss 0.436045
# Epoch 600 | Train Loss 0.212942 | Val Loss 0.442707
# Early stopping at epoch 652
# X | train1 -> R² = -1.1706, MSE = 2.3404e-01
# X | train2 -> R² = -14.8945, MSE = 1.3393e+00
# X | test1 -> R² = -1.2946, MSE = 2.4038e-01
# X | test2 -> R² = -15.0294, MSE = 1.3191e+00
# X | test3 -> R² = 0.5582, MSE = 4.0643e-02
# X | val -> R² = 0.0618, MSE = 8.9714e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.473038 | Val Loss 0.669347
# Epoch 100 | Train Loss 0.245330 | Val Loss 0.496707
# Epoch 200 | Train Loss 0.231205 | Val Loss 0.455349
# Epoch 300 | Train Loss 0.224653 | Val Loss 0.433073
# Epoch 400 | Train Loss 0.218955 | Val Loss 0.424068
# Epoch 500 | Train Loss 0.215677 | Val Loss 0.426446
# Epoch 600 | Train Loss 0.214231 | Val Loss 0.431931
# Early stopping at epoch 693
# X | train1 -> R² = -1.1358, MSE = 2.3029e-01
# X | train2 -> R² = -14.7046, MSE = 1.3233e+00
# X | test1 -> R² = -1.2417, MSE = 2.3484e-01
# X | test2 -> R² = -14.8941, MSE = 1.3080e+00
# X | test3 -> R² = 0.2392, MSE = 6.9999e-02
# X | val -> R² = -0.3491, MSE = 1.2900e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.467799 | Val Loss 0.727812
# Epoch 100 | Train Loss 0.249629 | Val Loss 0.520493
# Epoch 200 | Train Loss 0.233695 | Val Loss 0.468151
# Epoch 300 | Train Loss 0.229623 | Val Loss 0.445896
# Epoch 400 | Train Loss 0.224954 | Val Loss 0.437220
# Epoch 500 | Train Loss 0.219978 | Val Loss 0.429088
# Epoch 600 | Train Loss 0.215964 | Val Loss 0.433562
# Epoch 700 | Train Loss 0.213319 | Val Loss 0.455264
# Epoch 800 | Train Loss 0.211789 | Val Loss 0.475197
# Early stopping at epoch 816
# X | train1 -> R² = -1.1473, MSE = 2.3153e-01
# X | train2 -> R² = -14.8331, MSE = 1.3341e+00
# X | test1 -> R² = -1.3681, MSE = 2.4809e-01
# X | test2 -> R² = -15.0506, MSE = 1.3209e+00
# X | test3 -> R² = 0.8594, MSE = 1.2935e-02
# X | val -> R² = 0.5350, MSE = 4.4463e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.458715 | Val Loss 0.689437
# Epoch 100 | Train Loss 0.240040 | Val Loss 0.461042
# Epoch 200 | Train Loss 0.230463 | Val Loss 0.438519
# Epoch 300 | Train Loss 0.224637 | Val Loss 0.426731
# Epoch 400 | Train Loss 0.219651 | Val Loss 0.421207
# Epoch 500 | Train Loss 0.216855 | Val Loss 0.423353
# Epoch 600 | Train Loss 0.214434 | Val Loss 0.425153
# Early stopping at epoch 671
# X | train1 -> R² = -1.0820, MSE = 2.2449e-01
# X | train2 -> R² = -14.9645, MSE = 1.3452e+00
# X | test1 -> R² = -1.2041, MSE = 2.3091e-01
# X | test2 -> R² = -15.0910, MSE = 1.3242e+00
# X | test3 -> R² = 0.5990, MSE = 3.6895e-02
# X | val -> R² = 0.1333, MSE = 8.2875e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.464087 | Val Loss 0.628540
# Epoch 100 | Train Loss 0.248478 | Val Loss 0.516542
# Epoch 200 | Train Loss 0.233300 | Val Loss 0.467201
# Epoch 300 | Train Loss 0.226962 | Val Loss 0.438429
# Epoch 400 | Train Loss 0.220902 | Val Loss 0.433310
# Epoch 500 | Train Loss 0.215682 | Val Loss 0.443722
# Epoch 600 | Train Loss 0.214558 | Val Loss 0.462181
# Early stopping at epoch 698
# X | train1 -> R² = -1.2264, MSE = 2.4006e-01
# X | train2 -> R² = -14.8395, MSE = 1.3346e+00
# X | test1 -> R² = -1.4216, MSE = 2.5369e-01
# X | test2 -> R² = -15.0883, MSE = 1.3240e+00
# X | test3 -> R² = 0.2935, MSE = 6.5003e-02
# X | val -> R² = -0.4546, MSE = 1.3909e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.458561 | Val Loss 0.641452
# Epoch 100 | Train Loss 0.242047 | Val Loss 0.486746
# Epoch 200 | Train Loss 0.231641 | Val Loss 0.451282
# Epoch 300 | Train Loss 0.226651 | Val Loss 0.434014
# Epoch 400 | Train Loss 0.221389 | Val Loss 0.428078
# Epoch 500 | Train Loss 0.218039 | Val Loss 0.433096
# Epoch 600 | Train Loss 0.215617 | Val Loss 0.445509
# Early stopping at epoch 667
# X | train1 -> R² = -1.2003, MSE = 2.3725e-01
# X | train2 -> R² = -14.8170, MSE = 1.3327e+00
# X | test1 -> R² = -1.3727, MSE = 2.4857e-01
# X | test2 -> R² = -14.9737, MSE = 1.3145e+00
# X | test3 -> R² = 0.3710, MSE = 5.7875e-02
# X | val -> R² = -0.0378, MSE = 9.9234e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.476630 | Val Loss 0.683429
# Epoch 100 | Train Loss 0.249524 | Val Loss 0.511412
# Epoch 200 | Train Loss 0.233427 | Val Loss 0.462724
# Epoch 300 | Train Loss 0.227301 | Val Loss 0.434457
# Epoch 400 | Train Loss 0.221729 | Val Loss 0.423278
# Epoch 500 | Train Loss 0.217292 | Val Loss 0.426855
# Epoch 600 | Train Loss 0.214759 | Val Loss 0.436235
# Epoch 700 | Train Loss 0.213456 | Val Loss 0.438287
# Early stopping at epoch 712
# X | train1 -> R² = -1.1549, MSE = 2.3235e-01
# X | train2 -> R² = -14.9032, MSE = 1.3400e+00
# X | test1 -> R² = -1.2635, MSE = 2.3713e-01
# X | test2 -> R² = -15.1218, MSE = 1.3267e+00
# X | test3 -> R² = 0.1248, MSE = 8.0525e-02
# X | val -> R² = -0.2348, MSE = 1.1807e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.460068 | Val Loss 0.681005
# Epoch 100 | Train Loss 0.250706 | Val Loss 0.528728
# Epoch 200 | Train Loss 0.232417 | Val Loss 0.466072
# Epoch 300 | Train Loss 0.224465 | Val Loss 0.442591
# Epoch 400 | Train Loss 0.218615 | Val Loss 0.432292
# Epoch 500 | Train Loss 0.215948 | Val Loss 0.432415
# Epoch 600 | Train Loss 0.214940 | Val Loss 0.438661
# Epoch 700 | Train Loss 0.214199 | Val Loss 0.443771
# Early stopping at epoch 724
# X | train1 -> R² = -1.1095, MSE = 2.2745e-01
# X | train2 -> R² = -14.8408, MSE = 1.3348e+00
# X | test1 -> R² = -1.1978, MSE = 2.3024e-01
# X | test2 -> R² = -15.0277, MSE = 1.3190e+00
# X | test3 -> R² = -2.7897, MSE = 3.4867e-01
# X | val -> R² = -3.7314, MSE = 4.5243e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.572024 | Val Loss 0.677400
# Epoch 100 | Train Loss 0.369198 | Val Loss 0.406295
# Epoch 200 | Train Loss 0.360407 | Val Loss 0.395732
# Epoch 300 | Train Loss 0.354568 | Val Loss 0.406112
# Epoch 400 | Train Loss 0.350855 | Val Loss 0.408503
# Early stopping at epoch 480
# X | train1 -> R² = 0.6637, MSE = 3.6265e-02
# X | train2 -> R² = -1.9507, MSE = 2.4863e-01
# X | test1 -> R² = 0.7190, MSE = 2.9439e-02
# X | test2 -> R² = -1.7961, MSE = 2.3010e-01
# X | test3 -> R² = 0.9359, MSE = 5.8997e-03
# X | val -> R² = 0.8731, MSE = 1.2132e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.555321 | Val Loss 0.634194
# Epoch 100 | Train Loss 0.367025 | Val Loss 0.409010
# Epoch 200 | Train Loss 0.358665 | Val Loss 0.397469
# Epoch 300 | Train Loss 0.353083 | Val Loss 0.401845
# Epoch 400 | Train Loss 0.349479 | Val Loss 0.400849
# Early stopping at epoch 474
# X | train1 -> R² = 0.6364, MSE = 3.9210e-02
# X | train2 -> R² = -1.8769, MSE = 2.4241e-01
# X | test1 -> R² = 0.6997, MSE = 3.1455e-02
# X | test2 -> R² = -1.7419, MSE = 2.2564e-01
# X | test3 -> R² = 0.9185, MSE = 7.4966e-03
# X | val -> R² = 0.8481, MSE = 1.4521e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.549212 | Val Loss 0.612541
# Epoch 100 | Train Loss 0.367055 | Val Loss 0.404931
# Epoch 200 | Train Loss 0.359013 | Val Loss 0.398454
# Epoch 300 | Train Loss 0.354837 | Val Loss 0.406321
# Epoch 400 | Train Loss 0.351233 | Val Loss 0.403492
# Early stopping at epoch 449
# X | train1 -> R² = 0.6600, MSE = 3.6661e-02
# X | train2 -> R² = -1.9337, MSE = 2.4719e-01
# X | test1 -> R² = 0.7151, MSE = 2.9849e-02
# X | test2 -> R² = -1.7814, MSE = 2.2889e-01
# X | test3 -> R² = 0.9281, MSE = 6.6143e-03
# X | val -> R² = 0.8730, MSE = 1.2143e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.559841 | Val Loss 0.650615
# Epoch 100 | Train Loss 0.369984 | Val Loss 0.412142
# Epoch 200 | Train Loss 0.360583 | Val Loss 0.394628
# Epoch 300 | Train Loss 0.353786 | Val Loss 0.399249
# Epoch 400 | Train Loss 0.350956 | Val Loss 0.401440
# Epoch 500 | Train Loss 0.348978 | Val Loss 0.404458
# Early stopping at epoch 506
# X | train1 -> R² = 0.6394, MSE = 3.8882e-02
# X | train2 -> R² = -1.8648, MSE = 2.4139e-01
# X | test1 -> R² = 0.6857, MSE = 3.2929e-02
# X | test2 -> R² = -1.7382, MSE = 2.2534e-01
# X | test3 -> R² = 0.9310, MSE = 6.3452e-03
# X | val -> R² = 0.8493, MSE = 1.4407e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.565734 | Val Loss 0.665315
# Epoch 100 | Train Loss 0.371727 | Val Loss 0.404492
# Epoch 200 | Train Loss 0.358951 | Val Loss 0.404539
# Epoch 300 | Train Loss 0.353846 | Val Loss 0.409842
# Epoch 400 | Train Loss 0.351327 | Val Loss 0.407574
# Early stopping at epoch 443
# X | train1 -> R² = 0.6406, MSE = 3.8752e-02
# X | train2 -> R² = -1.8790, MSE = 2.4259e-01
# X | test1 -> R² = 0.7100, MSE = 3.0382e-02
# X | test2 -> R² = -1.7319, MSE = 2.2482e-01
# X | test3 -> R² = 0.9461, MSE = 4.9589e-03
# X | val -> R² = 0.9326, MSE = 6.4474e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.547834 | Val Loss 0.608153
# Epoch 100 | Train Loss 0.366515 | Val Loss 0.404671
# Epoch 200 | Train Loss 0.358579 | Val Loss 0.400222
# Epoch 300 | Train Loss 0.353381 | Val Loss 0.406701
# Epoch 400 | Train Loss 0.350782 | Val Loss 0.401133
# Early stopping at epoch 439
# X | train1 -> R² = 0.6576, MSE = 3.6923e-02
# X | train2 -> R² = -1.7530, MSE = 2.3197e-01
# X | test1 -> R² = 0.7304, MSE = 2.8242e-02
# X | test2 -> R² = -1.6329, MSE = 2.1667e-01
# X | test3 -> R² = 0.8978, MSE = 9.4013e-03
# X | val -> R² = 0.8260, MSE = 1.6643e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.560865 | Val Loss 0.628305
# Epoch 100 | Train Loss 0.371808 | Val Loss 0.405890
# Epoch 200 | Train Loss 0.359963 | Val Loss 0.397267
# Epoch 300 | Train Loss 0.354917 | Val Loss 0.404444
# Epoch 400 | Train Loss 0.351971 | Val Loss 0.400887
# Early stopping at epoch 465
# X | train1 -> R² = 0.6602, MSE = 3.6640e-02
# X | train2 -> R² = -1.8734, MSE = 2.4211e-01
# X | test1 -> R² = 0.7212, MSE = 2.9212e-02
# X | test2 -> R² = -1.7395, MSE = 2.2544e-01
# X | test3 -> R² = 0.9430, MSE = 5.2479e-03
# X | val -> R² = 0.9082, MSE = 8.7744e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.548875 | Val Loss 0.607075
# Epoch 100 | Train Loss 0.366011 | Val Loss 0.403906
# Epoch 200 | Train Loss 0.359365 | Val Loss 0.396291
# Epoch 300 | Train Loss 0.354053 | Val Loss 0.407749
# Epoch 400 | Train Loss 0.350716 | Val Loss 0.413372
# Early stopping at epoch 457
# X | train1 -> R² = 0.6597, MSE = 3.6691e-02
# X | train2 -> R² = -1.8789, MSE = 2.4258e-01
# X | test1 -> R² = 0.7128, MSE = 3.0088e-02
# X | test2 -> R² = -1.7238, MSE = 2.2415e-01
# X | test3 -> R² = 0.9185, MSE = 7.5016e-03
# X | val -> R² = 0.8512, MSE = 1.4225e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.574626 | Val Loss 0.678420
# Epoch 100 | Train Loss 0.369972 | Val Loss 0.416279
# Epoch 200 | Train Loss 0.359934 | Val Loss 0.393967
# Epoch 300 | Train Loss 0.353380 | Val Loss 0.398213
# Epoch 400 | Train Loss 0.350662 | Val Loss 0.399125
# Epoch 500 | Train Loss 0.349301 | Val Loss 0.399730
# Early stopping at epoch 508
# X | train1 -> R² = 0.6221, MSE = 4.0750e-02
# X | train2 -> R² = -1.8507, MSE = 2.4020e-01
# X | test1 -> R² = 0.6718, MSE = 3.4382e-02
# X | test2 -> R² = -1.6896, MSE = 2.2134e-01
# X | test3 -> R² = 0.9446, MSE = 5.0972e-03
# X | val -> R² = 0.8644, MSE = 1.2966e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.576833 | Val Loss 0.693113
# Epoch 100 | Train Loss 0.372261 | Val Loss 0.406188
# Epoch 200 | Train Loss 0.358004 | Val Loss 0.411327
# Epoch 300 | Train Loss 0.352469 | Val Loss 0.409505
# Epoch 400 | Train Loss 0.350137 | Val Loss 0.403876
# Early stopping at epoch 429
# X | train1 -> R² = 0.6808, MSE = 3.4417e-02
# X | train2 -> R² = -1.9113, MSE = 2.4530e-01
# X | test1 -> R² = 0.7567, MSE = 2.5487e-02
# X | test2 -> R² = -1.7418, MSE = 2.2563e-01
# X | test3 -> R² = 0.9277, MSE = 6.6543e-03
# X | val -> R² = 0.9010, MSE = 9.4622e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.576701 | Val Loss 0.694381
# Epoch 100 | Train Loss 0.370026 | Val Loss 0.402940
# Epoch 200 | Train Loss 0.358020 | Val Loss 0.404426
# Epoch 300 | Train Loss 0.353423 | Val Loss 0.408898
# Epoch 400 | Train Loss 0.351009 | Val Loss 0.402210
# Early stopping at epoch 429
# X | train1 -> R² = 0.6438, MSE = 3.8409e-02
# X | train2 -> R² = -1.9764, MSE = 2.5079e-01
# X | test1 -> R² = 0.7227, MSE = 2.9050e-02
# X | test2 -> R² = -1.8503, MSE = 2.3456e-01
# X | test3 -> R² = 0.8990, MSE = 9.2955e-03
# X | val -> R² = 0.8427, MSE = 1.5042e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.549740 | Val Loss 0.623829
# Epoch 100 | Train Loss 0.375071 | Val Loss 0.405767
# Epoch 200 | Train Loss 0.357634 | Val Loss 0.406695
# Epoch 300 | Train Loss 0.352986 | Val Loss 0.408102
# Epoch 400 | Train Loss 0.350419 | Val Loss 0.399806
# Epoch 500 | Train Loss 0.348646 | Val Loss 0.397327
# Epoch 600 | Train Loss 0.347669 | Val Loss 0.396389
# Epoch 700 | Train Loss 0.346920 | Val Loss 0.397571
# Epoch 800 | Train Loss 0.346301 | Val Loss 0.397730
# Early stopping at epoch 810
# X | train1 -> R² = 0.6026, MSE = 4.2848e-02
# X | train2 -> R² = -1.8760, MSE = 2.4233e-01
# X | test1 -> R² = 0.5773, MSE = 4.4283e-02
# X | test2 -> R² = -1.7961, MSE = 2.3010e-01
# X | test3 -> R² = 0.9126, MSE = 8.0445e-03
# X | val -> R² = 0.4313, MSE = 5.4381e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.546468 | Val Loss 0.605946
# Epoch 100 | Train Loss 0.365953 | Val Loss 0.402419
# Epoch 200 | Train Loss 0.357770 | Val Loss 0.397882
# Epoch 300 | Train Loss 0.350775 | Val Loss 0.398744
# Epoch 400 | Train Loss 0.348534 | Val Loss 0.398427
# Early stopping at epoch 450
# X | train1 -> R² = 0.6385, MSE = 3.8984e-02
# X | train2 -> R² = -1.9113, MSE = 2.4531e-01
# X | test1 -> R² = 0.6996, MSE = 3.1472e-02
# X | test2 -> R² = -1.7644, MSE = 2.2749e-01
# X | test3 -> R² = 0.9290, MSE = 6.5366e-03
# X | val -> R² = 0.8623, MSE = 1.3163e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.548483 | Val Loss 0.596415
# Epoch 100 | Train Loss 0.366483 | Val Loss 0.403845
# Epoch 200 | Train Loss 0.359573 | Val Loss 0.396922
# Epoch 300 | Train Loss 0.353606 | Val Loss 0.410319
# Epoch 400 | Train Loss 0.350408 | Val Loss 0.418449
# Early stopping at epoch 467
# X | train1 -> R² = 0.6466, MSE = 3.8105e-02
# X | train2 -> R² = -1.9200, MSE = 2.4604e-01
# X | test1 -> R² = 0.6948, MSE = 3.1976e-02
# X | test2 -> R² = -1.7660, MSE = 2.2762e-01
# X | test3 -> R² = 0.9288, MSE = 6.5479e-03
# X | val -> R² = 0.8529, MSE = 1.4070e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.562313 | Val Loss 0.656088
# Epoch 100 | Train Loss 0.381483 | Val Loss 0.410433
# Epoch 200 | Train Loss 0.358870 | Val Loss 0.401986
# Epoch 300 | Train Loss 0.354152 | Val Loss 0.408283
# Epoch 400 | Train Loss 0.350916 | Val Loss 0.401111
# Early stopping at epoch 459
# X | train1 -> R² = 0.6025, MSE = 4.2863e-02
# X | train2 -> R² = -1.9005, MSE = 2.4439e-01
# X | test1 -> R² = 0.6718, MSE = 3.4385e-02
# X | test2 -> R² = -1.7561, MSE = 2.2681e-01
# X | test3 -> R² = 0.9094, MSE = 8.3346e-03
# X | val -> R² = 0.8614, MSE = 1.3253e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.508893 | Val Loss 0.583676
# Epoch 100 | Train Loss 0.307844 | Val Loss 0.413460
# Epoch 200 | Train Loss 0.303546 | Val Loss 0.412796
# Epoch 300 | Train Loss 0.300218 | Val Loss 0.412457
# Epoch 400 | Train Loss 0.296094 | Val Loss 0.404705
# Epoch 500 | Train Loss 0.292895 | Val Loss 0.406266
# Epoch 600 | Train Loss 0.291363 | Val Loss 0.404206
# Epoch 700 | Train Loss 0.290421 | Val Loss 0.402622
# Epoch 800 | Train Loss 0.289781 | Val Loss 0.401650
# Epoch 900 | Train Loss 0.289280 | Val Loss 0.400694
# Epoch 1000 | Train Loss 0.288751 | Val Loss 0.400436
# Epoch 1100 | Train Loss 0.288263 | Val Loss 0.400655
# Epoch 1200 | Train Loss 0.287809 | Val Loss 0.401824
# Epoch 1300 | Train Loss 0.287370 | Val Loss 0.404602
# Early stopping at epoch 1322
# X | train1 -> R² = -0.1930, MSE = 1.2863e-01
# X | train2 -> R² = -8.2077, MSE = 7.7585e-01
# X | test1 -> R² = -0.4186, MSE = 1.4862e-01
# X | test2 -> R² = -8.2813, MSE = 7.6378e-01
# X | test3 -> R² = 0.6037, MSE = 3.6464e-02
# X | val -> R² = 0.3732, MSE = 5.9937e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.502417 | Val Loss 0.615713
# Epoch 100 | Train Loss 0.308828 | Val Loss 0.418497
# Epoch 200 | Train Loss 0.302579 | Val Loss 0.416825
# Epoch 300 | Train Loss 0.297365 | Val Loss 0.424048
# Epoch 400 | Train Loss 0.293245 | Val Loss 0.432182
# Early stopping at epoch 437
# X | train1 -> R² = -0.0926, MSE = 1.1781e-01
# X | train2 -> R² = -7.0404, MSE = 6.7749e-01
# X | test1 -> R² = -0.1010, MSE = 1.1534e-01
# X | test2 -> R² = -6.9414, MSE = 6.5353e-01
# X | test3 -> R² = 0.4652, MSE = 4.9205e-02
# X | val -> R² = 0.1634, MSE = 8.0002e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.528995 | Val Loss 0.511109
# Epoch 100 | Train Loss 0.312188 | Val Loss 0.428773
# Epoch 200 | Train Loss 0.306199 | Val Loss 0.412952
# Epoch 300 | Train Loss 0.301368 | Val Loss 0.412340
# Epoch 400 | Train Loss 0.297621 | Val Loss 0.413566
# Epoch 500 | Train Loss 0.295102 | Val Loss 0.419266
# Early stopping at epoch 520
# X | train1 -> R² = -0.0956, MSE = 1.1813e-01
# X | train2 -> R² = -7.0792, MSE = 6.8076e-01
# X | test1 -> R² = -0.0973, MSE = 1.1496e-01
# X | test2 -> R² = -6.9834, MSE = 6.5698e-01
# X | test3 -> R² = 0.4452, MSE = 5.1047e-02
# X | val -> R² = 0.1620, MSE = 8.0133e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.504819 | Val Loss 0.607711
# Epoch 100 | Train Loss 0.307630 | Val Loss 0.414958
# Epoch 200 | Train Loss 0.303421 | Val Loss 0.416261
# Epoch 300 | Train Loss 0.298818 | Val Loss 0.417788
# Epoch 400 | Train Loss 0.295314 | Val Loss 0.413244
# Early stopping at epoch 445
# X | train1 -> R² = -0.1104, MSE = 1.1973e-01
# X | train2 -> R² = -7.0396, MSE = 6.7742e-01
# X | test1 -> R² = -0.1079, MSE = 1.1606e-01
# X | test2 -> R² = -6.9336, MSE = 6.5288e-01
# X | test3 -> R² = 0.8015, MSE = 1.8264e-02
# X | val -> R² = 0.5935, MSE = 3.8868e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.507251 | Val Loss 0.582636
# Epoch 100 | Train Loss 0.308193 | Val Loss 0.414553
# Epoch 200 | Train Loss 0.303685 | Val Loss 0.415254
# Epoch 300 | Train Loss 0.298488 | Val Loss 0.420310
# Epoch 400 | Train Loss 0.294851 | Val Loss 0.419235
# Early stopping at epoch 447
# X | train1 -> R² = -0.0746, MSE = 1.1587e-01
# X | train2 -> R² = -7.1149, MSE = 6.8376e-01
# X | test1 -> R² = -0.0708, MSE = 1.1217e-01
# X | test2 -> R² = -7.0250, MSE = 6.6040e-01
# X | test3 -> R² = 0.8111, MSE = 1.7377e-02
# X | val -> R² = 0.6335, MSE = 3.5050e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.512299 | Val Loss 0.585206
# Epoch 100 | Train Loss 0.309746 | Val Loss 0.420778
# Epoch 200 | Train Loss 0.304965 | Val Loss 0.412340
# Epoch 300 | Train Loss 0.300310 | Val Loss 0.417522
# Epoch 400 | Train Loss 0.296257 | Val Loss 0.415975
# Early stopping at epoch 483
# X | train1 -> R² = -0.1017, MSE = 1.1879e-01
# X | train2 -> R² = -7.0119, MSE = 6.7509e-01
# X | test1 -> R² = -0.1073, MSE = 1.1600e-01
# X | test2 -> R² = -6.9078, MSE = 6.5076e-01
# X | test3 -> R² = 0.5719, MSE = 3.9383e-02
# X | val -> R² = 0.3297, MSE = 6.4097e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.509894 | Val Loss 0.605548
# Epoch 100 | Train Loss 0.310399 | Val Loss 0.423934
# Epoch 200 | Train Loss 0.304136 | Val Loss 0.413556
# Epoch 300 | Train Loss 0.298303 | Val Loss 0.416258
# Epoch 400 | Train Loss 0.294458 | Val Loss 0.411272
# Epoch 500 | Train Loss 0.292935 | Val Loss 0.409708
# Epoch 600 | Train Loss 0.292167 | Val Loss 0.408098
# Epoch 700 | Train Loss 0.291883 | Val Loss 0.407988
# Epoch 800 | Train Loss 0.290677 | Val Loss 0.406178
# Epoch 900 | Train Loss 0.289758 | Val Loss 0.405670
# Epoch 1000 | Train Loss 0.288973 | Val Loss 0.404728
# Epoch 1100 | Train Loss 0.288376 | Val Loss 0.405290
# Epoch 1200 | Train Loss 0.287908 | Val Loss 0.407518
# Early stopping at epoch 1250
# X | train1 -> R² = -0.2314, MSE = 1.3277e-01
# X | train2 -> R² = -8.6866, MSE = 8.1620e-01
# X | test1 -> R² = -0.3134, MSE = 1.3759e-01
# X | test2 -> R² = -8.8790, MSE = 8.1298e-01
# X | test3 -> R² = 0.7260, MSE = 2.5210e-02
# X | val -> R² = 0.1041, MSE = 8.5667e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.508039 | Val Loss 0.555391
# Epoch 100 | Train Loss 0.309004 | Val Loss 0.417585
# Epoch 200 | Train Loss 0.303992 | Val Loss 0.414374
# Epoch 300 | Train Loss 0.299726 | Val Loss 0.415585
# Epoch 400 | Train Loss 0.295567 | Val Loss 0.411675
# Epoch 500 | Train Loss 0.293292 | Val Loss 0.415327
# Epoch 600 | Train Loss 0.292068 | Val Loss 0.418128
# Epoch 700 | Train Loss 0.291305 | Val Loss 0.417395
# Early stopping at epoch 706
# X | train1 -> R² = -0.0995, MSE = 1.1855e-01
# X | train2 -> R² = -7.7927, MSE = 7.4088e-01
# X | test1 -> R² = -0.2131, MSE = 1.2709e-01
# X | test2 -> R² = -7.8090, MSE = 7.2492e-01
# X | test3 -> R² = 0.9302, MSE = 6.4224e-03
# X | val -> R² = 0.5441, MSE = 4.3597e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.515848 | Val Loss 0.606009
# Epoch 100 | Train Loss 0.309680 | Val Loss 0.419831
# Epoch 200 | Train Loss 0.304146 | Val Loss 0.415608
# Epoch 300 | Train Loss 0.300302 | Val Loss 0.424086
# Epoch 400 | Train Loss 0.296678 | Val Loss 0.424669
# Early stopping at epoch 453
# X | train1 -> R² = -0.1144, MSE = 1.2016e-01
# X | train2 -> R² = -7.0858, MSE = 6.8131e-01
# X | test1 -> R² = -0.1164, MSE = 1.1696e-01
# X | test2 -> R² = -6.9800, MSE = 6.5670e-01
# X | test3 -> R² = 0.7259, MSE = 2.5222e-02
# X | val -> R² = 0.4952, MSE = 4.8271e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.500645 | Val Loss 0.589791
# Epoch 100 | Train Loss 0.307168 | Val Loss 0.414247
# Epoch 200 | Train Loss 0.301882 | Val Loss 0.416190
# Epoch 300 | Train Loss 0.296225 | Val Loss 0.412955
# Epoch 400 | Train Loss 0.293058 | Val Loss 0.417549
# Epoch 500 | Train Loss 0.291850 | Val Loss 0.422933
# Early stopping at epoch 583
# X | train1 -> R² = -0.1354, MSE = 1.2242e-01
# X | train2 -> R² = -8.0525, MSE = 7.6277e-01
# X | test1 -> R² = -0.2457, MSE = 1.3051e-01
# X | test2 -> R² = -8.1530, MSE = 7.5323e-01
# X | test3 -> R² = 0.9240, MSE = 6.9906e-03
# X | val -> R² = 0.8389, MSE = 1.5408e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.504978 | Val Loss 0.590801
# Epoch 100 | Train Loss 0.309460 | Val Loss 0.418022
# Epoch 200 | Train Loss 0.304556 | Val Loss 0.413121
# Epoch 300 | Train Loss 0.300162 | Val Loss 0.418226
# Epoch 400 | Train Loss 0.295663 | Val Loss 0.427222
# Early stopping at epoch 448
# X | train1 -> R² = -0.1055, MSE = 1.1920e-01
# X | train2 -> R² = -7.0406, MSE = 6.7750e-01
# X | test1 -> R² = -0.0885, MSE = 1.1403e-01
# X | test2 -> R² = -6.9408, MSE = 6.5347e-01
# X | test3 -> R² = 0.6018, MSE = 3.6639e-02
# X | val -> R² = 0.3684, MSE = 6.0392e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.512724 | Val Loss 0.599225
# Epoch 100 | Train Loss 0.309730 | Val Loss 0.419496
# Epoch 200 | Train Loss 0.304206 | Val Loss 0.412628
# Epoch 300 | Train Loss 0.299525 | Val Loss 0.411661
# Epoch 400 | Train Loss 0.296849 | Val Loss 0.411976
# Epoch 500 | Train Loss 0.294216 | Val Loss 0.416437
# Epoch 600 | Train Loss 0.292249 | Val Loss 0.417593
# Early stopping at epoch 604
# X | train1 -> R² = -0.0921, MSE = 1.1776e-01
# X | train2 -> R² = -7.0994, MSE = 6.8245e-01
# X | test1 -> R² = -0.1639, MSE = 1.2193e-01
# X | test2 -> R² = -7.1188, MSE = 6.6812e-01
# X | test3 -> R² = 0.8886, MSE = 1.0246e-02
# X | val -> R² = 0.9227, MSE = 7.3886e-03
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.493631 | Val Loss 0.559568
# Epoch 100 | Train Loss 0.307400 | Val Loss 0.414587
# Epoch 200 | Train Loss 0.302757 | Val Loss 0.412961
# Epoch 300 | Train Loss 0.297827 | Val Loss 0.407569
# Epoch 400 | Train Loss 0.294383 | Val Loss 0.406746
# Epoch 500 | Train Loss 0.292387 | Val Loss 0.408932
# Epoch 600 | Train Loss 0.291155 | Val Loss 0.408752
# Early stopping at epoch 604
# X | train1 -> R² = -0.1841, MSE = 1.2768e-01
# X | train2 -> R² = -8.6582, MSE = 8.1381e-01
# X | test1 -> R² = -0.2845, MSE = 1.3457e-01
# X | test2 -> R² = -8.7078, MSE = 7.9888e-01
# X | test3 -> R² = 0.9501, MSE = 4.5932e-03
# X | val -> R² = 0.7972, MSE = 1.9395e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.516125 | Val Loss 0.662552
# Epoch 100 | Train Loss 0.307944 | Val Loss 0.415426
# Epoch 200 | Train Loss 0.303527 | Val Loss 0.419292
# Epoch 300 | Train Loss 0.298516 | Val Loss 0.423358
# Epoch 400 | Train Loss 0.294725 | Val Loss 0.424792
# Early stopping at epoch 420
# X | train1 -> R² = -0.0646, MSE = 1.1479e-01
# X | train2 -> R² = -7.1180, MSE = 6.8402e-01
# X | test1 -> R² = -0.0385, MSE = 1.0879e-01
# X | test2 -> R² = -7.0075, MSE = 6.5896e-01
# X | test3 -> R² = 0.6647, MSE = 3.0849e-02
# X | val -> R² = 0.4334, MSE = 5.4183e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.500403 | Val Loss 0.590459
# Epoch 100 | Train Loss 0.307306 | Val Loss 0.414017
# Epoch 200 | Train Loss 0.303582 | Val Loss 0.416207
# Epoch 300 | Train Loss 0.299925 | Val Loss 0.418375
# Epoch 400 | Train Loss 0.295615 | Val Loss 0.408419
# Epoch 500 | Train Loss 0.292673 | Val Loss 0.407835
# Epoch 600 | Train Loss 0.291555 | Val Loss 0.407496
# Epoch 700 | Train Loss 0.290750 | Val Loss 0.407839
# Early stopping at epoch 759
# X | train1 -> R² = -0.1790, MSE = 1.2713e-01
# X | train2 -> R² = -8.5534, MSE = 8.0497e-01
# X | test1 -> R² = -0.3456, MSE = 1.4096e-01
# X | test2 -> R² = -8.6546, MSE = 7.9451e-01
# X | test3 -> R² = 0.8268, MSE = 1.5938e-02
# X | val -> R² = 0.1399, MSE = 8.2249e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.475111 | Val Loss 0.567393
# Epoch 100 | Train Loss 0.236339 | Val Loss 0.460659
# Epoch 200 | Train Loss 0.228115 | Val Loss 0.438453
# Epoch 300 | Train Loss 0.222739 | Val Loss 0.432176
# Epoch 400 | Train Loss 0.217034 | Val Loss 0.423699
# Epoch 500 | Train Loss 0.213180 | Val Loss 0.430828
# Epoch 600 | Train Loss 0.211433 | Val Loss 0.429747
# Early stopping at epoch 684
# X | train1 -> R² = -1.1185, MSE = 2.2843e-01
# X | train2 -> R² = -14.9668, MSE = 1.3454e+00
# X | test1 -> R² = -1.2962, MSE = 2.4056e-01
# X | test2 -> R² = -15.1732, MSE = 1.3309e+00
# X | test3 -> R² = 0.9016, MSE = 9.0519e-03
# X | val -> R² = 0.6790, MSE = 3.0694e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.479255 | Val Loss 0.600472
# Epoch 100 | Train Loss 0.236735 | Val Loss 0.465906
# Epoch 200 | Train Loss 0.228497 | Val Loss 0.438941
# Epoch 300 | Train Loss 0.224067 | Val Loss 0.433585
# Epoch 400 | Train Loss 0.220594 | Val Loss 0.429416
# Epoch 500 | Train Loss 0.216649 | Val Loss 0.433363
# Epoch 600 | Train Loss 0.213839 | Val Loss 0.439414
# Epoch 700 | Train Loss 0.212019 | Val Loss 0.443612
# Early stopping at epoch 706
# X | train1 -> R² = -1.1309, MSE = 2.2977e-01
# X | train2 -> R² = -14.7647, MSE = 1.3283e+00
# X | test1 -> R² = -1.4104, MSE = 2.5251e-01
# X | test2 -> R² = -14.9021, MSE = 1.3086e+00
# X | test3 -> R² = 0.8473, MSE = 1.4045e-02
# X | val -> R² = 0.6198, MSE = 3.6358e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.479994 | Val Loss 0.513193
# Epoch 100 | Train Loss 0.235600 | Val Loss 0.455810
# Epoch 200 | Train Loss 0.228611 | Val Loss 0.436311
# Epoch 300 | Train Loss 0.221659 | Val Loss 0.430830
# Epoch 400 | Train Loss 0.216690 | Val Loss 0.442208
# Epoch 500 | Train Loss 0.214260 | Val Loss 0.457452
# Early stopping at epoch 584
# X | train1 -> R² = -1.1938, MSE = 2.3655e-01
# X | train2 -> R² = -14.9197, MSE = 1.3414e+00
# X | test1 -> R² = -1.3205, MSE = 2.4310e-01
# X | test2 -> R² = -15.1133, MSE = 1.3260e+00
# X | test3 -> R² = 0.8807, MSE = 1.0977e-02
# X | val -> R² = 0.5600, MSE = 4.2076e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.502816 | Val Loss 0.651164
# Epoch 100 | Train Loss 0.235014 | Val Loss 0.453518
# Epoch 200 | Train Loss 0.229455 | Val Loss 0.438394
# Epoch 300 | Train Loss 0.225374 | Val Loss 0.435177
# Epoch 400 | Train Loss 0.221080 | Val Loss 0.423254
# Epoch 500 | Train Loss 0.218279 | Val Loss 0.419150
# Epoch 600 | Train Loss 0.215835 | Val Loss 0.422538
# Epoch 700 | Train Loss 0.213074 | Val Loss 0.424639
# Early stopping at epoch 759
# X | train1 -> R² = -1.0822, MSE = 2.2451e-01
# X | train2 -> R² = -14.8702, MSE = 1.3372e+00
# X | test1 -> R² = -1.2865, MSE = 2.3954e-01
# X | test2 -> R² = -15.0067, MSE = 1.3172e+00
# X | test3 -> R² = 0.4342, MSE = 5.2054e-02
# X | val -> R² = -0.0995, MSE = 1.0514e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.463004 | Val Loss 0.620094
# Epoch 100 | Train Loss 0.234453 | Val Loss 0.454805
# Epoch 200 | Train Loss 0.227957 | Val Loss 0.438125
# Epoch 300 | Train Loss 0.222027 | Val Loss 0.431087
# Epoch 400 | Train Loss 0.217228 | Val Loss 0.428552
# Epoch 500 | Train Loss 0.213763 | Val Loss 0.438862
# Epoch 600 | Train Loss 0.211183 | Val Loss 0.434506
# Early stopping at epoch 644
# X | train1 -> R² = -1.1083, MSE = 2.2733e-01
# X | train2 -> R² = -14.9518, MSE = 1.3441e+00
# X | test1 -> R² = -1.2785, MSE = 2.3869e-01
# X | test2 -> R² = -15.1595, MSE = 1.3298e+00
# X | test3 -> R² = 0.6607, MSE = 3.1213e-02
# X | val -> R² = 0.1377, MSE = 8.2453e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.498501 | Val Loss 0.598283
# Epoch 100 | Train Loss 0.236921 | Val Loss 0.458636
# Epoch 200 | Train Loss 0.229016 | Val Loss 0.439197
# Epoch 300 | Train Loss 0.224314 | Val Loss 0.438615
# Epoch 400 | Train Loss 0.220222 | Val Loss 0.431628
# Epoch 500 | Train Loss 0.215407 | Val Loss 0.432284
# Epoch 600 | Train Loss 0.213188 | Val Loss 0.442968
# Epoch 700 | Train Loss 0.211955 | Val Loss 0.441382
# Early stopping at epoch 737
# X | train1 -> R² = -1.0851, MSE = 2.2483e-01
# X | train2 -> R² = -14.9131, MSE = 1.3408e+00
# X | test1 -> R² = -1.2861, MSE = 2.3950e-01
# X | test2 -> R² = -15.1220, MSE = 1.3267e+00
# X | test3 -> R² = 0.8913, MSE = 9.9995e-03
# X | val -> R² = 0.6360, MSE = 3.4806e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.463508 | Val Loss 0.593403
# Epoch 100 | Train Loss 0.234896 | Val Loss 0.462133
# Epoch 200 | Train Loss 0.228064 | Val Loss 0.437704
# Epoch 300 | Train Loss 0.223613 | Val Loss 0.434182
# Epoch 400 | Train Loss 0.219977 | Val Loss 0.423301
# Epoch 500 | Train Loss 0.215282 | Val Loss 0.418811
# Epoch 600 | Train Loss 0.212259 | Val Loss 0.424483
# Epoch 700 | Train Loss 0.210866 | Val Loss 0.427117
# Early stopping at epoch 754
# X | train1 -> R² = -1.2349, MSE = 2.4098e-01
# X | train2 -> R² = -16.0025, MSE = 1.4326e+00
# X | test1 -> R² = -1.4889, MSE = 2.6074e-01
# X | test2 -> R² = -16.2041, MSE = 1.4158e+00
# X | test3 -> R² = 0.7006, MSE = 2.7548e-02
# X | val -> R² = 0.4585, MSE = 5.1782e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.461462 | Val Loss 0.580628
# Epoch 100 | Train Loss 0.232974 | Val Loss 0.448109
# Epoch 200 | Train Loss 0.226931 | Val Loss 0.437632
# Epoch 300 | Train Loss 0.222507 | Val Loss 0.438613
# Epoch 400 | Train Loss 0.217686 | Val Loss 0.433140
# Epoch 500 | Train Loss 0.214134 | Val Loss 0.440251
# Epoch 600 | Train Loss 0.211904 | Val Loss 0.447351
# Early stopping at epoch 680
# X | train1 -> R² = -1.2637, MSE = 2.4408e-01
# X | train2 -> R² = -16.5422, MSE = 1.4781e+00
# X | test1 -> R² = -1.5276, MSE = 2.6480e-01
# X | test2 -> R² = -16.7827, MSE = 1.4634e+00
# X | test3 -> R² = 0.9292, MSE = 6.5098e-03
# X | val -> R² = 0.8887, MSE = 1.0640e-02
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.500030 | Val Loss 0.626416
# Epoch 100 | Train Loss 0.238534 | Val Loss 0.467158
# Epoch 200 | Train Loss 0.229161 | Val Loss 0.438447
# Epoch 300 | Train Loss 0.224747 | Val Loss 0.430399
# Epoch 400 | Train Loss 0.221177 | Val Loss 0.422086
# Epoch 500 | Train Loss 0.218195 | Val Loss 0.418858
# Epoch 600 | Train Loss 0.215474 | Val Loss 0.419918
# ...
# X | val -> R² = -0.7665, MSE = 1.6892e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.494238 | Val Loss 0.630473
# Epoch 100 | Train Loss 0.226294 | Val Loss 0.439632
# Epoch 200 | Train Loss 0.214199 | Val Loss 0.430584
# Epoch 300 | Train Loss 0.211634 | Val Loss 0.433990
# Epoch 400 | Train Loss 0.210366 | Val Loss 0.431663
# Epoch 500 | Train Loss 0.212535 | Val Loss 0.427835
# Epoch 600 | Train Loss 0.209708 | Val Loss 0.425024
# Early stopping at epoch 681
# X | train1 -> R² = -2.1025, MSE = 3.3453e-01
# X | train2 -> R² = -20.9600, MSE = 1.8504e+00
# X | test1 -> R² = -2.3691, MSE = 3.5295e-01
# X | test2 -> R² = -21.3327, MSE = 1.8378e+00
# X | test3 -> R² = -1.2866, MSE = 2.1038e-01
# X | val -> R² = -1.8896, MSE = 2.7631e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.482164 | Val Loss 0.526079
# Epoch 100 | Train Loss 0.221468 | Val Loss 0.433492
# Epoch 200 | Train Loss 0.212485 | Val Loss 0.438737
# Epoch 300 | Train Loss 0.210596 | Val Loss 0.436074
# Epoch 400 | Train Loss 0.208952 | Val Loss 0.439780
# Early stopping at epoch 411
# X | train1 -> R² = -1.3112, MSE = 2.4921e-01
# X | train2 -> R² = -17.3454, MSE = 1.5458e+00
# X | test1 -> R² = -1.4312, MSE = 2.5470e-01
# X | test2 -> R² = -17.6369, MSE = 1.5337e+00
# X | test3 -> R² = -0.0045, MSE = 9.2420e-02
# X | val -> R² = -1.3724, MSE = 2.2685e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.475136 | Val Loss 0.601908
# Epoch 100 | Train Loss 0.224855 | Val Loss 0.435844
# Epoch 200 | Train Loss 0.214259 | Val Loss 0.435000
# Epoch 300 | Train Loss 0.214896 | Val Loss 0.433010
# Epoch 400 | Train Loss 0.210350 | Val Loss 0.436935
# Early stopping at epoch 431
# X | train1 -> R² = -1.5801, MSE = 2.7820e-01
# X | train2 -> R² = -22.6245, MSE = 1.9906e+00
# X | test1 -> R² = -1.6827, MSE = 2.8105e-01
# X | test2 -> R² = -23.0378, MSE = 1.9782e+00
# X | test3 -> R² = -0.2159, MSE = 1.1187e-01
# X | val -> R² = -1.3353, MSE = 2.2331e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.498956 | Val Loss 0.614654
# Epoch 100 | Train Loss 0.226356 | Val Loss 0.433724
# Epoch 200 | Train Loss 0.216951 | Val Loss 0.431506
# Epoch 300 | Train Loss 0.211648 | Val Loss 0.440315
# Epoch 400 | Train Loss 0.209778 | Val Loss 0.439991
# Early stopping at epoch 479
# X | train1 -> R² = -1.8025, MSE = 3.0218e-01
# X | train2 -> R² = -24.4144, MSE = 2.1414e+00
# X | test1 -> R² = -2.1322, MSE = 3.2813e-01
# X | test2 -> R² = -24.8710, MSE = 2.1290e+00
# X | test3 -> R² = -0.3992, MSE = 1.2873e-01
# X | val -> R² = -0.8441, MSE = 1.7634e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.471746 | Val Loss 0.502456
# Epoch 100 | Train Loss 0.224442 | Val Loss 0.431010
# Epoch 200 | Train Loss 0.213991 | Val Loss 0.427561
# Epoch 300 | Train Loss 0.211378 | Val Loss 0.434936
# Epoch 400 | Train Loss 0.210201 | Val Loss 0.436208
# Early stopping at epoch 431
# X | train1 -> R² = -1.8380, MSE = 3.0601e-01
# X | train2 -> R² = -21.5381, MSE = 1.8991e+00
# X | test1 -> R² = -2.1252, MSE = 3.2740e-01
# X | test2 -> R² = -21.8783, MSE = 1.8827e+00
# X | test3 -> R² = 0.3290, MSE = 6.1736e-02
# X | val -> R² = -0.2815, MSE = 1.2254e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.486627 | Val Loss 0.623099
# Epoch 100 | Train Loss 0.226023 | Val Loss 0.433235
# Epoch 200 | Train Loss 0.214466 | Val Loss 0.428280
# Epoch 300 | Train Loss 0.211368 | Val Loss 0.431694
# Epoch 400 | Train Loss 0.209647 | Val Loss 0.429121
# Early stopping at epoch 456
# X | train1 -> R² = -2.1057, MSE = 3.3487e-01
# X | train2 -> R² = -25.2912, MSE = 2.2153e+00
# X | test1 -> R² = -2.3463, MSE = 3.5056e-01
# X | test2 -> R² = -25.7227, MSE = 2.1991e+00
# X | test3 -> R² = -0.2946, MSE = 1.1911e-01
# X | val -> R² = -0.9820, MSE = 1.8952e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.458560 | Val Loss 0.474765
# Epoch 100 | Train Loss 0.221882 | Val Loss 0.427237
# Epoch 200 | Train Loss 0.213426 | Val Loss 0.429578
# Epoch 300 | Train Loss 0.211154 | Val Loss 0.430095
# Epoch 400 | Train Loss 0.211421 | Val Loss 0.432794
# Early stopping at epoch 452
# X | train1 -> R² = -1.1860, MSE = 2.3571e-01
# X | train2 -> R² = -15.6035, MSE = 1.3990e+00
# X | test1 -> R² = -1.3270, MSE = 2.4377e-01
# X | test2 -> R² = -15.8775, MSE = 1.3889e+00
# X | test3 -> R² = 0.3535, MSE = 5.9483e-02
# X | val -> R² = -0.7387, MSE = 1.6626e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.465158 | Val Loss 0.574212
# Epoch 100 | Train Loss 0.222260 | Val Loss 0.433229
# Epoch 200 | Train Loss 0.213760 | Val Loss 0.446580
# Epoch 300 | Train Loss 0.211939 | Val Loss 0.456224
# Epoch 400 | Train Loss 0.210467 | Val Loss 0.446863
# Early stopping at epoch 422
# X | train1 -> R² = -1.8784, MSE = 3.1037e-01
# X | train2 -> R² = -24.3042, MSE = 2.1321e+00
# X | test1 -> R² = -2.0584, MSE = 3.2040e-01
# X | test2 -> R² = -24.7145, MSE = 2.1161e+00
# X | test3 -> R² = 0.2743, MSE = 6.6763e-02
# X | val -> R² = -0.9956, MSE = 1.9083e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.448065 | Val Loss 0.503114
# Epoch 100 | Train Loss 0.224542 | Val Loss 0.430982
# Epoch 200 | Train Loss 0.213309 | Val Loss 0.431713
# Epoch 300 | Train Loss 0.210100 | Val Loss 0.440789
# Epoch 400 | Train Loss 0.208551 | Val Loss 0.446827
# Early stopping at epoch 442
# X | train1 -> R² = -1.6788, MSE = 2.8885e-01
# X | train2 -> R² = -22.0799, MSE = 1.9447e+00
# X | test1 -> R² = -1.9549, MSE = 3.0956e-01
# X | test2 -> R² = -22.5105, MSE = 1.9348e+00
# X | test3 -> R² = -0.3155, MSE = 1.2103e-01
# X | val -> R² = -1.4701, MSE = 2.3620e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.478536 | Val Loss 0.607420
# Epoch 100 | Train Loss 0.225670 | Val Loss 0.431097
# Epoch 200 | Train Loss 0.214870 | Val Loss 0.424335
# Epoch 300 | Train Loss 0.210825 | Val Loss 0.427317
# Epoch 400 | Train Loss 0.208932 | Val Loss 0.424695
# Early stopping at epoch 466
# X | train1 -> R² = -1.5237, MSE = 2.7212e-01
# X | train2 -> R² = -20.0951, MSE = 1.7775e+00
# X | test1 -> R² = -1.7526, MSE = 2.8837e-01
# X | test2 -> R² = -20.4353, MSE = 1.7640e+00
# X | test3 -> R² = -0.7582, MSE = 1.6177e-01
# X | val -> R² = -1.7383, MSE = 2.6185e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.515413 | Val Loss 0.618123
# Epoch 100 | Train Loss 0.224213 | Val Loss 0.434303
# Epoch 200 | Train Loss 0.213637 | Val Loss 0.439086
# Epoch 300 | Train Loss 0.211411 | Val Loss 0.430033
# Epoch 400 | Train Loss 0.209077 | Val Loss 0.427112
# Epoch 500 | Train Loss 0.207809 | Val Loss 0.431943
# Epoch 600 | Train Loss 0.207156 | Val Loss 0.441374
# Early stopping at epoch 667
# X | train1 -> R² = -1.9612, MSE = 3.1929e-01
# X | train2 -> R² = -17.4265, MSE = 1.5526e+00
# X | test1 -> R² = -2.4502, MSE = 3.6145e-01
# X | test2 -> R² = -17.7953, MSE = 1.5467e+00
# X | test3 -> R² = 0.7491, MSE = 2.3086e-02
# X | val -> R² = -0.3779, MSE = 1.3176e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.572568 | Val Loss 0.475194
# Epoch 100 | Train Loss 0.353413 | Val Loss 0.399523
# Epoch 200 | Train Loss 0.347314 | Val Loss 0.396935
# Epoch 300 | Train Loss 0.345551 | Val Loss 0.402120
# Epoch 400 | Train Loss 0.345403 | Val Loss 0.400649
# Early stopping at epoch 449
# X | train1 -> R² = 0.3346, MSE = 7.1745e-02
# X | train2 -> R² = -8.7434, MSE = 8.2098e-01
# X | test1 -> R² = 0.3488, MSE = 6.8218e-02
# X | test2 -> R² = -8.8086, MSE = 8.0718e-01
# X | test3 -> R² = 0.9230, MSE = 7.0846e-03
# X | val -> R² = 0.3325, MSE = 6.3832e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.630722 | Val Loss 0.554420
# Epoch 100 | Train Loss 0.353496 | Val Loss 0.399253
# Epoch 200 | Train Loss 0.347340 | Val Loss 0.395608
# Epoch 300 | Train Loss 0.345327 | Val Loss 0.401577
# Epoch 400 | Train Loss 0.344251 | Val Loss 0.404369
# Early stopping at epoch 401
# X | train1 -> R² = 0.4387, MSE = 6.0526e-02
# X | train2 -> R² = -5.1291, MSE = 5.1644e-01
# X | test1 -> R² = 0.4495, MSE = 5.7669e-02
# X | test2 -> R² = -5.0751, MSE = 4.9994e-01
# X | test3 -> R² = 0.9720, MSE = 2.5764e-03
# X | val -> R² = 0.7326, MSE = 2.5573e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.600245 | Val Loss 0.502947
# Epoch 100 | Train Loss 0.355580 | Val Loss 0.394379
# Epoch 200 | Train Loss 0.347495 | Val Loss 0.396448
# Epoch 300 | Train Loss 0.345551 | Val Loss 0.396792
# Epoch 400 | Train Loss 0.344272 | Val Loss 0.401084
# Early stopping at epoch 444
# X | train1 -> R² = 0.4307, MSE = 6.1382e-02
# X | train2 -> R² = -6.5711, MSE = 6.3795e-01
# X | test1 -> R² = 0.4181, MSE = 6.0962e-02
# X | test2 -> R² = -6.5831, MSE = 6.2404e-01
# X | test3 -> R² = 0.9757, MSE = 2.2330e-03
# X | val -> R² = 0.6925, MSE = 2.9406e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.595504 | Val Loss 0.498063
# Epoch 100 | Train Loss 0.353004 | Val Loss 0.400528
# Epoch 200 | Train Loss 0.347563 | Val Loss 0.392544
# Epoch 300 | Train Loss 0.345624 | Val Loss 0.392410
# Epoch 400 | Train Loss 0.344521 | Val Loss 0.390038
# Epoch 500 | Train Loss 0.347803 | Val Loss 0.397396
# Epoch 600 | Train Loss 0.342251 | Val Loss 0.403951
# Epoch 700 | Train Loss 0.340953 | Val Loss 0.416534
# Early stopping at epoch 718
# X | train1 -> R² = 0.0583, MSE = 1.0154e-01
# X | train2 -> R² = -5.9001, MSE = 5.8140e-01
# X | test1 -> R² = -0.0988, MSE = 1.1511e-01
# X | test2 -> R² = -6.0144, MSE = 5.7724e-01
# X | test3 -> R² = 0.8276, MSE = 1.5863e-02
# X | val -> R² = 0.6898, MSE = 2.9660e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.612916 | Val Loss 0.534668
# Epoch 100 | Train Loss 0.357959 | Val Loss 0.405904
# Epoch 200 | Train Loss 0.348099 | Val Loss 0.400998
# Epoch 300 | Train Loss 0.345514 | Val Loss 0.403361
# Early stopping at epoch 399
# X | train1 -> R² = 0.4481, MSE = 5.9511e-02
# X | train2 -> R² = -6.5861, MSE = 6.3921e-01
# X | test1 -> R² = 0.4788, MSE = 5.4604e-02
# X | test2 -> R² = -6.5424, MSE = 6.2068e-01
# X | test3 -> R² = 0.9641, MSE = 3.2987e-03
# X | val -> R² = 0.7183, MSE = 2.6938e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.623239 | Val Loss 0.510808
# Epoch 100 | Train Loss 0.352567 | Val Loss 0.398156
# Epoch 200 | Train Loss 0.347502 | Val Loss 0.398969
# Epoch 300 | Train Loss 0.345903 | Val Loss 0.398572
# Epoch 400 | Train Loss 0.344727 | Val Loss 0.399918
# Early stopping at epoch 409
# X | train1 -> R² = 0.4531, MSE = 5.8965e-02
# X | train2 -> R² = -6.2283, MSE = 6.0906e-01
# X | test1 -> R² = 0.4854, MSE = 5.3906e-02
# X | test2 -> R² = -6.1809, MSE = 5.9094e-01
# X | test3 -> R² = 0.9840, MSE = 1.4695e-03
# X | val -> R² = 0.7556, MSE = 2.3371e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.613638 | Val Loss 0.530642
# Epoch 100 | Train Loss 0.354140 | Val Loss 0.397242
# Epoch 200 | Train Loss 0.351197 | Val Loss 0.395777
# Epoch 300 | Train Loss 0.345846 | Val Loss 0.395861
# Epoch 400 | Train Loss 0.344975 | Val Loss 0.400403
# Early stopping at epoch 423
# X | train1 -> R² = 0.4452, MSE = 5.9825e-02
# X | train2 -> R² = -6.0340, MSE = 5.9269e-01
# X | test1 -> R² = 0.4532, MSE = 5.7285e-02
# X | test2 -> R² = -5.9996, MSE = 5.7602e-01
# X | test3 -> R² = 0.9802, MSE = 1.8224e-03
# X | val -> R² = 0.7058, MSE = 2.8128e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.605718 | Val Loss 0.499656
# Epoch 100 | Train Loss 0.354207 | Val Loss 0.402474
# Epoch 200 | Train Loss 0.347560 | Val Loss 0.401458
# Epoch 300 | Train Loss 0.346206 | Val Loss 0.400783
# Early stopping at epoch 371
# X | train1 -> R² = 0.6833, MSE = 3.4148e-02
# X | train2 -> R² = -1.8733, MSE = 2.4211e-01
# X | test1 -> R² = 0.7225, MSE = 2.9075e-02
# X | test2 -> R² = -1.7538, MSE = 2.2662e-01
# X | test3 -> R² = 0.9027, MSE = 8.9534e-03
# X | val -> R² = 0.7463, MSE = 2.4264e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.626889 | Val Loss 0.510206
# Epoch 100 | Train Loss 0.352989 | Val Loss 0.403058
# Epoch 200 | Train Loss 0.347577 | Val Loss 0.396113
# Epoch 300 | Train Loss 0.348014 | Val Loss 0.394139
# Epoch 400 | Train Loss 0.346267 | Val Loss 0.396096
# Epoch 500 | Train Loss 0.343890 | Val Loss 0.396109
# Early stopping at epoch 598
# X | train1 -> R² = 0.0707, MSE = 1.0021e-01
# X | train2 -> R² = -4.6691, MSE = 4.7768e-01
# X | test1 -> R² = 0.0070, MSE = 1.0403e-01
# X | test2 -> R² = -4.7333, MSE = 4.7181e-01
# X | test3 -> R² = 0.8224, MSE = 1.6336e-02
# X | val -> R² = 0.3367, MSE = 6.3425e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.581875 | Val Loss 0.500598
# Epoch 100 | Train Loss 0.352826 | Val Loss 0.392695
# Epoch 200 | Train Loss 0.346954 | Val Loss 0.396119
# Epoch 300 | Train Loss 0.345492 | Val Loss 0.392584
# Early stopping at epoch 386
# X | train1 -> R² = 0.3974, MSE = 6.4974e-02
# X | train2 -> R² = -8.7788, MSE = 8.2396e-01
# X | test1 -> R² = 0.4465, MSE = 5.7980e-02
# X | test2 -> R² = -8.7476, MSE = 8.0216e-01
# X | test3 -> R² = 0.7959, MSE = 1.8776e-02
# X | val -> R² = 0.4450, MSE = 5.3072e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.609214 | Val Loss 0.521377
# Epoch 100 | Train Loss 0.354518 | Val Loss 0.400979
# Epoch 200 | Train Loss 0.347434 | Val Loss 0.407183
# Epoch 300 | Train Loss 0.345941 | Val Loss 0.405622
# Early stopping at epoch 375
# X | train1 -> R² = 0.6828, MSE = 3.4204e-02
# X | train2 -> R² = -1.8200, MSE = 2.3762e-01
# X | test1 -> R² = 0.7278, MSE = 2.8511e-02
# X | test2 -> R² = -1.6958, MSE = 2.2184e-01
# X | test3 -> R² = 0.8022, MSE = 1.8195e-02
# X | val -> R² = 0.6556, MSE = 3.2930e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.585115 | Val Loss 0.487542
# Epoch 100 | Train Loss 0.354040 | Val Loss 0.389585
# Epoch 200 | Train Loss 0.347130 | Val Loss 0.396026
# Epoch 300 | Train Loss 0.346051 | Val Loss 0.393018
# Early stopping at epoch 388
# X | train1 -> R² = 0.4248, MSE = 6.2026e-02
# X | train2 -> R² = -6.8741, MSE = 6.6348e-01
# X | test1 -> R² = 0.4390, MSE = 5.8770e-02
# X | test2 -> R² = -6.8734, MSE = 6.4793e-01
# X | test3 -> R² = 0.7371, MSE = 2.4192e-02
# X | val -> R² = 0.4482, MSE = 5.2769e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.580221 | Val Loss 0.482409
# Epoch 100 | Train Loss 0.356468 | Val Loss 0.394069
# Epoch 200 | Train Loss 0.348297 | Val Loss 0.396605
# Epoch 300 | Train Loss 0.346481 | Val Loss 0.396661
# Epoch 400 | Train Loss 0.345324 | Val Loss 0.393486
# Early stopping at epoch 444
# X | train1 -> R² = 0.4498, MSE = 5.9326e-02
# X | train2 -> R² = -6.8084, MSE = 6.5793e-01
# X | test1 -> R² = 0.4596, MSE = 5.6617e-02
# X | test2 -> R² = -6.7892, MSE = 6.4100e-01
# X | test3 -> R² = 0.9115, MSE = 8.1404e-03
# X | val -> R² = 0.4630, MSE = 5.1352e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.580363 | Val Loss 0.473524
# Epoch 100 | Train Loss 0.356164 | Val Loss 0.396227
# Epoch 200 | Train Loss 0.350208 | Val Loss 0.391010
# Epoch 300 | Train Loss 0.345954 | Val Loss 0.396495
# Epoch 400 | Train Loss 0.344841 | Val Loss 0.397300
# Early stopping at epoch 412
# X | train1 -> R² = 0.3457, MSE = 7.0547e-02
# X | train2 -> R² = -8.3192, MSE = 7.8524e-01
# X | test1 -> R² = 0.3623, MSE = 6.6808e-02
# X | test2 -> R² = -8.3115, MSE = 7.6627e-01
# X | test3 -> R² = 0.9798, MSE = 1.8619e-03
# X | val -> R² = 0.8941, MSE = 1.0127e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.611799 | Val Loss 0.530731
# Epoch 100 | Train Loss 0.354063 | Val Loss 0.399448
# Epoch 200 | Train Loss 0.347694 | Val Loss 0.404950
# Epoch 300 | Train Loss 0.347749 | Val Loss 0.403915
# Early stopping at epoch 391
# X | train1 -> R² = 0.4406, MSE = 6.0320e-02
# X | train2 -> R² = -5.4993, MSE = 5.4763e-01
# X | test1 -> R² = 0.4679, MSE = 5.5746e-02
# X | test2 -> R² = -5.4390, MSE = 5.2989e-01
# X | test3 -> R² = 0.9258, MSE = 6.8223e-03
# X | val -> R² = 0.9406, MSE = 5.6772e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
