# %% [markdown]
# - Entradas: PwmD, PwmE, Theta
# - Saidas: X
# - Trajetorias: ZZ + ZZr

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers

Datasets = []
PREDICTORS = ["PwmD", "PwmE", "Theta"]   
PHYSICAL_PREDICTORS = ["Wd", "We"]   
TARGET_INT = ["X"]  
TARGET = ["DeltaX"]
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
for i in range(4):
    Dataset = pd.read_excel(f"../../../../RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(2):   
    Dataset = pd.read_csv(f"../../../../Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
# PREDICTORS = ["dPwmD", "dPwmE", "sPwmD", "sPwmE"]   
# PREDICTORS = ["sWdRef", "sWeRef", "Theta"]   

INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(4):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

# %%
x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 3)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

# %%
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 3)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %%
import matplotlib.pyplot as plt
import numpy as np

def PlotOut(ax, title, target_name, y_true, y_cin, y_pred):

    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.scatter(time, y_true,
               marker='o',
               s=12,
               color='tab:blue',
               label='Amostras Reais',
               alpha=0.7)

    ax.scatter(time, y_pred,
               marker='x',
               s=12,
               color='tab:red',
               label='Modelo PIRNN',
               alpha=0.7)

    ax.plot(time, y_cin,
            linewidth=2,
            color='tab:green',
            label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)

    ax.legend()
    ax.grid(True)

# %%
import tensorflow as tf

R = tf.constant(0.0341, dtype=tf.float32)
L = tf.constant(0.0606, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

# %%
def CinematicModel(Wd, We, theta):

    # dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta) * (Wd + We)
    # dy_cin = (R / 2) * tf.sin(theta) * (Wd + We)

    # return [dtheta_cin, dx_cin, dy_cin]
    return [dx_cin]

# %%
class PINN(tf.keras.Model):

    def __init__(self, architecture, initializer, regularizer):
        super(PINN, self).__init__()

        self.rnn_layers = []

        for i, units in enumerate(architecture):

            if i < len(architecture) - 1:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        return_sequences=True,
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )
            else:
                self.rnn_layers.append(
                    tf.keras.layers.SimpleRNN(
                        units,
                        activation='tanh',
                        kernel_initializer=initializer,
                        kernel_regularizer=regularizer,
                        recurrent_regularizer=regularizer,
                        bias_regularizer=regularizer
                    )
                )

        # camada densa final
        self.out_layer = tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )

    def call(self, inputs):

        x = inputs

        for rnn in self.rnn_layers:
            x = rnn(x)

        return self.out_layer(x)

# %%
mean = OUT_SCALER.mean_[0]
std  = OUT_SCALER.scale_[0]
mean_tf = tf.constant(mean, dtype=tf.float32)
std_tf  = tf.constant(std, dtype=tf.float32)

# %%
@tf.function
def train_step(model, optimizer, x, y, Wd, We, theta, Ld, Lp):

    with tf.GradientTape() as tape:

        pred = model(x, training=True)

        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(pred - y))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta), axis=1)   
             
        # normalização correta
        physics_denorm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(pred - physics_denorm))

        loss = data_loss + physics_loss
        loss = Ld * data_loss +  Lp * physics_loss


    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=300, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
TITLES = ["train1", "train2", "test1", "test2", "test3", "val"]

def EvalModel(model):
    n_targets = len(TARGET)

    # estrutura das métricas
    metrics = {
        name: {
            "R2_train1": [], "R2_train2": [],
            "R2_val": [],
            "R2_test1": [], "R2_test2": [], "R2_test3": [],
            "MSE_train1": [], "MSE_train2": [],
            "MSE_val": [],
            "MSE_test1": [], "MSE_test2": [], "MSE_test3": [],
        }
        for name in TARGET_INT
    }

    for i, dataset in enumerate(NormDatasets):

        x = dataset[PREDICTORS]
        y = dataset[TARGET]

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)
        y_diff = OUT_SCALER.inverse_transform(y)

        # arrays reconstruídos
        y_true = np.zeros_like(y_diff)
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        n = y_true.shape[0]
        y_cin = y_cin[:n]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_true[:, j] = init_vals[j] + np.cumsum(y_diff[:, j] * TS)
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(
                f"{name} | {TITLES[i]} -> "
                f"R² = {r2:.4f}, MSE = {mse:.4e}"
            )

    return metrics

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.5,0.5], [0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.5, 0.9]

results = {}
excel_file = "resultados.xlsx"

# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)

        model = PINN(
            architecture=arch,
            initializer=init,
            regularizer=reg
        )

        model.build((None, TIME_STEPS, len(PREDICTORS)))

        w0 = model.get_weights()

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )

        wf = model.get_weights()

        metrics = EvalModel(model)

        arch_name = "_".join(map(str, arch))

        row = {
            "model": f"model_{arch_name}_Ld{Ld}_Lp{Lp}_r{r}_seed{i}",
            "Neurons": arch,
            "Ld": Ld,
            "Lp": Lp,
            "reg": r,
            "seed": int(s),
            "W0": str([w.round(4).tolist() for w in w0]),
            "Wf": str([w.round(4).tolist() for w in wf]),
        }

        for name in TARGET_INT:
            row.update({
                f"R2_Train_1_{name}": metrics[name]["R2_train1"],
                f"MSE_Train_1_{name}": metrics[name]["MSE_train1"],
                f"R2_Train_2_{name}": metrics[name]["R2_train2"],
                f"MSE_Train_2_{name}": metrics[name]["MSE_train2"],
                f"R2_Val_{name}": metrics[name]["R2_val"],
                f"MSE_Val_{name}": metrics[name]["MSE_val"],
                f"R2_Test_1_{name}": metrics[name]["R2_test1"],
                f"MSE_Test_1_{name}": metrics[name]["MSE_test1"],
                f"R2_Test_2_{name}": metrics[name]["R2_test2"],
                f"MSE_Test_2_{name}": metrics[name]["MSE_test2"],
                f"R2_Test_3_{name}": metrics[name]["R2_test3"],
                f"MSE_Test_3_{name}": metrics[name]["MSE_test3"],
            })

        df = pd.DataFrame([row])

        try:
            old = pd.read_excel(excel_file)
            new_df = pd.concat([old, df], ignore_index=True)
            new_df.to_excel(excel_file, index=False)
        except FileNotFoundError:
            df.to_excel(excel_file, index=False)

        print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={i} salvo.")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\engine\base_layer_utils.py:189: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# Epoch 0 | Train Loss 0.517311 | Val Loss 0.618036
# Epoch 100 | Train Loss 0.307842 | Val Loss 0.474294
# Epoch 200 | Train Loss 0.299642 | Val Loss 0.451879
# Epoch 300 | Train Loss 0.294827 | Val Loss 0.430485
# Epoch 400 | Train Loss 0.293006 | Val Loss 0.418918
# Epoch 500 | Train Loss 0.292154 | Val Loss 0.412701
# Epoch 600 | Train Loss 0.291460 | Val Loss 0.406573
# Epoch 700 | Train Loss 0.290831 | Val Loss 0.401904
# Epoch 800 | Train Loss 0.290179 | Val Loss 0.400122
# Epoch 900 | Train Loss 0.289528 | Val Loss 0.402747
# Epoch 1000 | Train Loss 0.288982 | Val Loss 0.406016
# Early stopping at epoch 1044
# X | train1 -> R² = -0.0521, MSE = 1.1345e-01
# X | train2 -> R² = -7.2850, MSE = 6.9810e-01
# X | test1 -> R² = -0.0705, MSE = 1.1215e-01
# X | test2 -> R² = -6.9524, MSE = 6.5443e-01
# X | test3 -> R² = 0.9553, MSE = 4.1146e-03
# X | val -> R² = -0.3436, MSE = 1.2848e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.525942 | Val Loss 0.677861
# Epoch 100 | Train Loss 0.305577 | Val Loss 0.464693
# Epoch 200 | Train Loss 0.298365 | Val Loss 0.444415
# Epoch 300 | Train Loss 0.295250 | Val Loss 0.424991
# Epoch 400 | Train Loss 0.292805 | Val Loss 0.413496
# Epoch 500 | Train Loss 0.291640 | Val Loss 0.407952
# Epoch 600 | Train Loss 0.290734 | Val Loss 0.405937
# Epoch 700 | Train Loss 0.289955 | Val Loss 0.405863
# Epoch 800 | Train Loss 0.289466 | Val Loss 0.406856
# Early stopping at epoch 886
# X | train1 -> R² = -0.0575, MSE = 1.1402e-01
# X | train2 -> R² = -7.3232, MSE = 7.0132e-01
# X | test1 -> R² = -0.0924, MSE = 1.1444e-01
# X | test2 -> R² = -6.8842, MSE = 6.4882e-01
# X | test3 -> R² = 0.9132, MSE = 7.9819e-03
# X | val -> R² = -0.7948, MSE = 1.7162e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.533108 | Val Loss 0.712772
# Epoch 100 | Train Loss 0.307837 | Val Loss 0.461966
# Epoch 200 | Train Loss 0.298454 | Val Loss 0.442492
# Epoch 300 | Train Loss 0.294293 | Val Loss 0.421771
# Epoch 400 | Train Loss 0.292337 | Val Loss 0.409013
# Epoch 500 | Train Loss 0.290945 | Val Loss 0.404584
# Epoch 600 | Train Loss 0.289960 | Val Loss 0.407694
# Epoch 700 | Train Loss 0.289434 | Val Loss 0.410634
# Early stopping at epoch 776
# X | train1 -> R² = -0.0530, MSE = 1.1354e-01
# X | train2 -> R² = -7.3716, MSE = 7.0539e-01
# X | test1 -> R² = -0.0732, MSE = 1.1243e-01
# X | test2 -> R² = -6.9685, MSE = 6.5575e-01
# X | test3 -> R² = 0.9275, MSE = 6.6711e-03
# X | val -> R² = -0.2921, MSE = 1.2356e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.516613 | Val Loss 0.664952
# Epoch 100 | Train Loss 0.305203 | Val Loss 0.466282
# Epoch 200 | Train Loss 0.298574 | Val Loss 0.446826
# Epoch 300 | Train Loss 0.295083 | Val Loss 0.429095
# Epoch 400 | Train Loss 0.292786 | Val Loss 0.414686
# Epoch 500 | Train Loss 0.291364 | Val Loss 0.406667
# Epoch 600 | Train Loss 0.290196 | Val Loss 0.406667
# Epoch 700 | Train Loss 0.289529 | Val Loss 0.407341
# Early stopping at epoch 800
# X | train1 -> R² = -0.0514, MSE = 1.1337e-01
# X | train2 -> R² = -7.3112, MSE = 7.0030e-01
# X | test1 -> R² = -0.0612, MSE = 1.1118e-01
# X | test2 -> R² = -6.9585, MSE = 6.5493e-01
# X | test3 -> R² = 0.8936, MSE = 9.7878e-03
# X | val -> R² = -0.4555, MSE = 1.3918e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.525681 | Val Loss 0.712248
# Epoch 100 | Train Loss 0.307530 | Val Loss 0.471520
# Epoch 200 | Train Loss 0.299395 | Val Loss 0.452970
# Epoch 300 | Train Loss 0.296569 | Val Loss 0.439303
# Epoch 400 | Train Loss 0.293529 | Val Loss 0.423617
# Epoch 500 | Train Loss 0.291850 | Val Loss 0.413172
# Epoch 600 | Train Loss 0.290829 | Val Loss 0.405996
# Epoch 700 | Train Loss 0.290246 | Val Loss 0.402175
# Epoch 800 | Train Loss 0.289809 | Val Loss 0.400575
# Epoch 900 | Train Loss 0.289367 | Val Loss 0.399874
# Epoch 1000 | Train Loss 0.288914 | Val Loss 0.399109
# Epoch 1100 | Train Loss 0.288467 | Val Loss 0.398459
# Epoch 1200 | Train Loss 0.288042 | Val Loss 0.398056
# Epoch 1300 | Train Loss 0.287561 | Val Loss 0.398766
# Early stopping at epoch 1314
# X | train1 -> R² = -0.0471, MSE = 1.1290e-01
# X | train2 -> R² = -7.1310, MSE = 6.8512e-01
# X | test1 -> R² = -0.1520, MSE = 1.2069e-01
# X | test2 -> R² = -6.9236, MSE = 6.5206e-01
# X | test3 -> R² = 0.9347, MSE = 6.0065e-03
# X | val -> R² = 0.1986, MSE = 7.6635e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.515328 | Val Loss 0.624997
# Epoch 100 | Train Loss 0.305663 | Val Loss 0.467654
# Epoch 200 | Train Loss 0.297921 | Val Loss 0.445625
# Epoch 300 | Train Loss 0.294132 | Val Loss 0.426688
# Epoch 400 | Train Loss 0.292505 | Val Loss 0.415783
# Epoch 500 | Train Loss 0.291532 | Val Loss 0.408711
# Epoch 600 | Train Loss 0.290799 | Val Loss 0.403914
# Epoch 700 | Train Loss 0.290102 | Val Loss 0.403408
# Epoch 800 | Train Loss 0.289360 | Val Loss 0.406114
# Epoch 900 | Train Loss 0.288797 | Val Loss 0.409429
# Early stopping at epoch 910
# X | train1 -> R² = -0.0613, MSE = 1.1443e-01
# X | train2 -> R² = -7.3612, MSE = 7.0452e-01
# X | test1 -> R² = -0.0766, MSE = 1.1278e-01
# X | test2 -> R² = -7.0600, MSE = 6.6328e-01
# X | test3 -> R² = 0.9173, MSE = 7.6133e-03
# X | val -> R² = -0.5910, MSE = 1.5213e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.529098 | Val Loss 0.685407
# Epoch 100 | Train Loss 0.307286 | Val Loss 0.471000
# Epoch 200 | Train Loss 0.300611 | Val Loss 0.455748
# Epoch 300 | Train Loss 0.297248 | Val Loss 0.442305
# Epoch 400 | Train Loss 0.294142 | Val Loss 0.427483
# Epoch 500 | Train Loss 0.292174 | Val Loss 0.414725
# Epoch 600 | Train Loss 0.291159 | Val Loss 0.407270
# Epoch 700 | Train Loss 0.290377 | Val Loss 0.404376
# Epoch 800 | Train Loss 0.289630 | Val Loss 0.403911
# Epoch 900 | Train Loss 0.289074 | Val Loss 0.403973
# Epoch 1000 | Train Loss 0.288662 | Val Loss 0.402749
# Epoch 1100 | Train Loss 0.288305 | Val Loss 0.401432
# Epoch 1200 | Train Loss 0.287952 | Val Loss 0.401964
# Epoch 1300 | Train Loss 0.287595 | Val Loss 0.404067
# Early stopping at epoch 1319
# X | train1 -> R² = -0.0511, MSE = 1.1334e-01
# X | train2 -> R² = -7.6683, MSE = 7.3039e-01
# X | test1 -> R² = -0.1319, MSE = 1.1858e-01
# X | test2 -> R² = -7.3683, MSE = 6.8865e-01
# X | test3 -> R² = 0.8889, MSE = 1.0220e-02
# X | val -> R² = -0.0626, MSE = 1.0161e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.549114 | Val Loss 0.646036
# Epoch 100 | Train Loss 0.309994 | Val Loss 0.470151
# Epoch 200 | Train Loss 0.301414 | Val Loss 0.455579
# Epoch 300 | Train Loss 0.296591 | Val Loss 0.436772
# Epoch 400 | Train Loss 0.293603 | Val Loss 0.420050
# Epoch 500 | Train Loss 0.292117 | Val Loss 0.407868
# Epoch 600 | Train Loss 0.291064 | Val Loss 0.402519
# Epoch 700 | Train Loss 0.290091 | Val Loss 0.401122
# Epoch 800 | Train Loss 0.289278 | Val Loss 0.403881
# Epoch 900 | Train Loss 0.288492 | Val Loss 0.407623
# Early stopping at epoch 938
# X | train1 -> R² = -0.0554, MSE = 1.1380e-01
# X | train2 -> R² = -7.3163, MSE = 7.0073e-01
# X | test1 -> R² = -0.0575, MSE = 1.1078e-01
# X | test2 -> R² = -6.8946, MSE = 6.4967e-01
# X | test3 -> R² = 0.9224, MSE = 7.1380e-03
# X | val -> R² = -0.2635, MSE = 1.2082e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.510421 | Val Loss 0.645924
# Epoch 100 | Train Loss 0.306263 | Val Loss 0.460916
# Epoch 200 | Train Loss 0.298724 | Val Loss 0.446929
# Epoch 300 | Train Loss 0.295008 | Val Loss 0.431676
# Epoch 400 | Train Loss 0.292599 | Val Loss 0.415894
# Epoch 500 | Train Loss 0.291479 | Val Loss 0.408194
# Epoch 600 | Train Loss 0.290317 | Val Loss 0.405775
# Epoch 700 | Train Loss 0.289571 | Val Loss 0.407385
# Epoch 800 | Train Loss 0.288899 | Val Loss 0.409421
# Early stopping at epoch 844
# X | train1 -> R² = -0.0579, MSE = 1.1407e-01
# X | train2 -> R² = -7.3259, MSE = 7.0154e-01
# X | test1 -> R² = -0.0875, MSE = 1.1393e-01
# X | test2 -> R² = -6.9255, MSE = 6.5222e-01
# X | test3 -> R² = 0.9222, MSE = 7.1608e-03
# X | val -> R² = -0.7328, MSE = 1.6569e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.533696 | Val Loss 0.736282
# Epoch 100 | Train Loss 0.316840 | Val Loss 0.460860
# Epoch 200 | Train Loss 0.298682 | Val Loss 0.446022
# Epoch 300 | Train Loss 0.295442 | Val Loss 0.432755
# Epoch 400 | Train Loss 0.293535 | Val Loss 0.421806
# Epoch 500 | Train Loss 0.292262 | Val Loss 0.413528
# Epoch 600 | Train Loss 0.291182 | Val Loss 0.410612
# Epoch 700 | Train Loss 0.290160 | Val Loss 0.412962
# Epoch 800 | Train Loss 0.289373 | Val Loss 0.412668
# Early stopping at epoch 874
# X | train1 -> R² = -0.0550, MSE = 1.1376e-01
# X | train2 -> R² = -7.3443, MSE = 7.0309e-01
# X | test1 -> R² = -0.0709, MSE = 1.1219e-01
# X | test2 -> R² = -6.9486, MSE = 6.5412e-01
# X | test3 -> R² = 0.8127, MSE = 1.7231e-02
# X | val -> R² = -0.7190, MSE = 1.6437e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.514201 | Val Loss 0.613132
# Epoch 100 | Train Loss 0.306134 | Val Loss 0.459775
# Epoch 200 | Train Loss 0.298151 | Val Loss 0.441797
# Epoch 300 | Train Loss 0.294491 | Val Loss 0.425135
# Epoch 400 | Train Loss 0.292365 | Val Loss 0.415015
# Epoch 500 | Train Loss 0.290799 | Val Loss 0.407504
# Epoch 600 | Train Loss 0.289599 | Val Loss 0.406188
# Epoch 700 | Train Loss 0.288923 | Val Loss 0.409103
# Epoch 800 | Train Loss 0.288256 | Val Loss 0.411921
# Early stopping at epoch 833
# X | train1 -> R² = -0.0423, MSE = 1.1239e-01
# X | train2 -> R² = -7.2333, MSE = 6.9374e-01
# X | test1 -> R² = -0.0750, MSE = 1.1261e-01
# X | test2 -> R² = -6.8953, MSE = 6.4973e-01
# X | test3 -> R² = 0.8177, MSE = 1.6768e-02
# X | val -> R² = -0.5135, MSE = 1.4472e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.547183 | Val Loss 0.704681
# Epoch 100 | Train Loss 0.306573 | Val Loss 0.476713
# Epoch 200 | Train Loss 0.300802 | Val Loss 0.461807
# Epoch 300 | Train Loss 0.298016 | Val Loss 0.449629
# Epoch 400 | Train Loss 0.295442 | Val Loss 0.440412
# Epoch 500 | Train Loss 0.293013 | Val Loss 0.430891
# Epoch 600 | Train Loss 0.291991 | Val Loss 0.423390
# Epoch 700 | Train Loss 0.291229 | Val Loss 0.416263
# Epoch 800 | Train Loss 0.290480 | Val Loss 0.411988
# Epoch 900 | Train Loss 0.289840 | Val Loss 0.409551
# Epoch 1000 | Train Loss 0.289365 | Val Loss 0.408799
# Epoch 1100 | Train Loss 0.288978 | Val Loss 0.409310
# Epoch 1200 | Train Loss 0.288691 | Val Loss 0.408875
# Early stopping at epoch 1207
# X | train1 -> R² = -0.0481, MSE = 1.1301e-01
# X | train2 -> R² = -7.2182, MSE = 6.9247e-01
# X | test1 -> R² = -0.1246, MSE = 1.1781e-01
# X | test2 -> R² = -6.9367, MSE = 6.5314e-01
# X | test3 -> R² = 0.8243, MSE = 1.6166e-02
# X | val -> R² = -0.7850, MSE = 1.7069e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.527543 | Val Loss 0.667691
# Epoch 100 | Train Loss 0.306359 | Val Loss 0.476958
# Epoch 200 | Train Loss 0.299519 | Val Loss 0.447516
# Epoch 300 | Train Loss 0.295341 | Val Loss 0.424623
# Epoch 400 | Train Loss 0.292721 | Val Loss 0.409139
# Epoch 500 | Train Loss 0.291258 | Val Loss 0.402797
# Epoch 600 | Train Loss 0.290210 | Val Loss 0.403434
# Epoch 700 | Train Loss 0.289622 | Val Loss 0.405985
# Early stopping at epoch 787
# X | train1 -> R² = -0.0513, MSE = 1.1336e-01
# X | train2 -> R² = -7.3878, MSE = 7.0676e-01
# X | test1 -> R² = -0.0724, MSE = 1.1234e-01
# X | test2 -> R² = -7.0591, MSE = 6.6321e-01
# X | test3 -> R² = 0.8616, MSE = 1.2734e-02
# X | val -> R² = -0.3442, MSE = 1.2854e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.517145 | Val Loss 0.667064
# Epoch 100 | Train Loss 0.306670 | Val Loss 0.465521
# Epoch 200 | Train Loss 0.297625 | Val Loss 0.442718
# Epoch 300 | Train Loss 0.294658 | Val Loss 0.426319
# Epoch 400 | Train Loss 0.292939 | Val Loss 0.413648
# Epoch 500 | Train Loss 0.291857 | Val Loss 0.406870
# Epoch 600 | Train Loss 0.290846 | Val Loss 0.405102
# Epoch 700 | Train Loss 0.289947 | Val Loss 0.408121
# Epoch 800 | Train Loss 0.289460 | Val Loss 0.410265
# Early stopping at epoch 873
# X | train1 -> R² = -0.0540, MSE = 1.1365e-01
# X | train2 -> R² = -7.3553, MSE = 7.0402e-01
# X | test1 -> R² = -0.0650, MSE = 1.1157e-01
# X | test2 -> R² = -7.0887, MSE = 6.6564e-01
# X | test3 -> R² = 0.8959, MSE = 9.5814e-03
# X | val -> R² = -0.4132, MSE = 1.3513e-01
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.531638 | Val Loss 0.717542
# Epoch 100 | Train Loss 0.306649 | Val Loss 0.469604
# Epoch 200 | Train Loss 0.299068 | Val Loss 0.446956
# Epoch 300 | Train Loss 0.294965 | Val Loss 0.425118
# Epoch 400 | Train Loss 0.292803 | Val Loss 0.407135
# Epoch 500 | Train Loss 0.291662 | Val Loss 0.399536
# Epoch 600 | Train Loss 0.290487 | Val Loss 0.399768
# Epoch 700 | Train Loss 0.289846 | Val Loss 0.403993
# Epoch 800 | Train Loss 0.289412 | Val Loss 0.405767
# Early stopping at epoch 816
# X | train1 -> R² = -0.0422, MSE = 1.1238e-01
# X | train2 -> R² = -7.3933, MSE = 7.0722e-01
# X | test1 -> R² = -0.0560, MSE = 1.1062e-01
# X | test2 -> R² = -7.1013, MSE = 6.6668e-01
# X | test3 -> R² = 0.9542, MSE = 4.2163e-03
# X | val -> R² = 0.1756, MSE = 7.8828e-02
# Modelo [32] | Ld=0.5 Lp=0.5 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.468922 | Val Loss 0.648639
# Epoch 100 | Train Loss 0.232762 | Val Loss 0.510636
# Epoch 200 | Train Loss 0.220427 | Val Loss 0.481870
# Epoch 300 | Train Loss 0.215726 | Val Loss 0.459296
# Epoch 400 | Train Loss 0.213261 | Val Loss 0.445510
# Epoch 500 | Train Loss 0.211243 | Val Loss 0.441511
# Epoch 600 | Train Loss 0.209644 | Val Loss 0.448873
# Epoch 700 | Train Loss 0.208148 | Val Loss 0.459192
# Early stopping at epoch 771
# X | train1 -> R² = -1.0875, MSE = 2.2509e-01
# X | train2 -> R² = -15.2901, MSE = 1.3726e+00
# X | test1 -> R² = -1.0475, MSE = 2.1450e-01
# X | test2 -> R² = -14.8265, MSE = 1.3024e+00
# X | test3 -> R² = 0.0764, MSE = 8.4977e-02
# X | val -> R² = -2.9995, MSE = 3.8244e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.503723 | Val Loss 0.705289
# Epoch 100 | Train Loss 0.236212 | Val Loss 0.520178
# Epoch 200 | Train Loss 0.223424 | Val Loss 0.491060
# Epoch 300 | Train Loss 0.218802 | Val Loss 0.465587
# Epoch 400 | Train Loss 0.215828 | Val Loss 0.444899
# Epoch 500 | Train Loss 0.213245 | Val Loss 0.435792
# Epoch 600 | Train Loss 0.211326 | Val Loss 0.434265
# Epoch 700 | Train Loss 0.209598 | Val Loss 0.433959
# Epoch 800 | Train Loss 0.208440 | Val Loss 0.434499
# Epoch 900 | Train Loss 0.207703 | Val Loss 0.433817
# Epoch 1000 | Train Loss 0.207103 | Val Loss 0.431231
# Epoch 1100 | Train Loss 0.206590 | Val Loss 0.429379
# Epoch 1200 | Train Loss 0.206123 | Val Loss 0.429160
# Epoch 1300 | Train Loss 0.205662 | Val Loss 0.430062
# Epoch 1400 | Train Loss 0.205191 | Val Loss 0.431689
# Early stopping at epoch 1432
# X | train1 -> R² = -1.0526, MSE = 2.2132e-01
# X | train2 -> R² = -14.7163, MSE = 1.3243e+00
# X | test1 -> R² = -0.9934, MSE = 2.0883e-01
# X | test2 -> R² = -14.2427, MSE = 1.2544e+00
# X | test3 -> R² = 0.8212, MSE = 1.6450e-02
# X | val -> R² = 0.3284, MSE = 6.4220e-02
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.491460 | Val Loss 0.668887
# Epoch 100 | Train Loss 0.236889 | Val Loss 0.509883
# Epoch 200 | Train Loss 0.220744 | Val Loss 0.481444
# Epoch 300 | Train Loss 0.216578 | Val Loss 0.462698
# Epoch 400 | Train Loss 0.213868 | Val Loss 0.448415
# Epoch 500 | Train Loss 0.212132 | Val Loss 0.435966
# Epoch 600 | Train Loss 0.210605 | Val Loss 0.428989
# Epoch 700 | Train Loss 0.209333 | Val Loss 0.427749
# Epoch 800 | Train Loss 0.208124 | Val Loss 0.431826
# Epoch 900 | Train Loss 0.206950 | Val Loss 0.440698
# Early stopping at epoch 938
# X | train1 -> R² = -1.0682, MSE = 2.2300e-01
# X | train2 -> R² = -15.0698, MSE = 1.3541e+00
# X | test1 -> R² = -1.1342, MSE = 2.2358e-01
# X | test2 -> R² = -14.7734, MSE = 1.2980e+00
# X | test3 -> R² = 0.3524, MSE = 5.9586e-02
# X | val -> R² = -1.8379, MSE = 2.7137e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.464026 | Val Loss 0.644523
# Epoch 100 | Train Loss 0.235330 | Val Loss 0.514747
# Epoch 200 | Train Loss 0.218108 | Val Loss 0.470823
# Epoch 300 | Train Loss 0.214096 | Val Loss 0.454104
# Epoch 400 | Train Loss 0.212169 | Val Loss 0.441516
# Epoch 500 | Train Loss 0.210659 | Val Loss 0.439437
# Epoch 600 | Train Loss 0.209190 | Val Loss 0.444596
# Epoch 700 | Train Loss 0.208016 | Val Loss 0.450838
# Early stopping at epoch 735
# X | train1 -> R² = -1.0800, MSE = 2.2428e-01
# X | train2 -> R² = -15.3739, MSE = 1.3797e+00
# X | test1 -> R² = -1.0726, MSE = 2.1713e-01
# X | test2 -> R² = -14.9353, MSE = 1.3114e+00
# X | test3 -> R² = 0.3059, MSE = 6.3860e-02
# X | val -> R² = -2.9497, MSE = 3.7768e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.470252 | Val Loss 0.723098
# Epoch 100 | Train Loss 0.232864 | Val Loss 0.517590
# Epoch 200 | Train Loss 0.220034 | Val Loss 0.484381
# Epoch 300 | Train Loss 0.216349 | Val Loss 0.464439
# Epoch 400 | Train Loss 0.213650 | Val Loss 0.448515
# Epoch 500 | Train Loss 0.211534 | Val Loss 0.445203
# Epoch 600 | Train Loss 0.209940 | Val Loss 0.445267
# Epoch 700 | Train Loss 0.209078 | Val Loss 0.444693
# Epoch 800 | Train Loss 0.208419 | Val Loss 0.444869
# Epoch 900 | Train Loss 0.207862 | Val Loss 0.445775
# Early stopping at epoch 999
# X | train1 -> R² = -1.0534, MSE = 2.2141e-01
# X | train2 -> R² = -14.9586, MSE = 1.3447e+00
# X | test1 -> R² = -1.1196, MSE = 2.2205e-01
# X | test2 -> R² = -14.7049, MSE = 1.2924e+00
# X | test3 -> R² = -0.1924, MSE = 1.0971e-01
# X | val -> R² = -2.3481, MSE = 3.2015e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.485516 | Val Loss 0.623461
# Epoch 100 | Train Loss 0.232387 | Val Loss 0.507837
# Epoch 200 | Train Loss 0.220941 | Val Loss 0.482516
# Epoch 300 | Train Loss 0.216700 | Val Loss 0.468594
# Epoch 400 | Train Loss 0.214139 | Val Loss 0.453379
# Epoch 500 | Train Loss 0.212526 | Val Loss 0.443646
# Epoch 600 | Train Loss 0.210828 | Val Loss 0.442698
# Epoch 700 | Train Loss 0.209193 | Val Loss 0.449588
# Epoch 800 | Train Loss 0.207899 | Val Loss 0.464395
# Early stopping at epoch 854
# X | train1 -> R² = -1.0756, MSE = 2.2380e-01
# X | train2 -> R² = -15.3484, MSE = 1.3775e+00
# X | test1 -> R² = -1.0397, MSE = 2.1368e-01
# X | test2 -> R² = -14.9130, MSE = 1.3095e+00
# X | test3 -> R² = 0.0589, MSE = 8.6588e-02
# X | val -> R² = -2.4453, MSE = 3.2945e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.491221 | Val Loss 0.717570
# Epoch 100 | Train Loss 0.236311 | Val Loss 0.527687
# Epoch 200 | Train Loss 0.221276 | Val Loss 0.487707
# Epoch 300 | Train Loss 0.216505 | Val Loss 0.465155
# Epoch 400 | Train Loss 0.214429 | Val Loss 0.450529
# Epoch 500 | Train Loss 0.213121 | Val Loss 0.441531
# Epoch 600 | Train Loss 0.212044 | Val Loss 0.435922
# Epoch 700 | Train Loss 0.210888 | Val Loss 0.432996
# Epoch 800 | Train Loss 0.209460 | Val Loss 0.434659
# Epoch 900 | Train Loss 0.208501 | Val Loss 0.440254
# Early stopping at epoch 967
# X | train1 -> R² = -1.0911, MSE = 2.2548e-01
# X | train2 -> R² = -15.3165, MSE = 1.3748e+00
# X | test1 -> R² = -1.0867, MSE = 2.1860e-01
# X | test2 -> R² = -14.9100, MSE = 1.3093e+00
# X | test3 -> R² = 0.6573, MSE = 3.1531e-02
# X | val -> R² = -1.9864, MSE = 2.8557e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.488915 | Val Loss 0.673016
# Epoch 100 | Train Loss 0.235681 | Val Loss 0.516856
# Epoch 200 | Train Loss 0.220898 | Val Loss 0.479276
# Epoch 300 | Train Loss 0.216186 | Val Loss 0.463949
# Epoch 400 | Train Loss 0.213835 | Val Loss 0.451167
# Epoch 500 | Train Loss 0.211874 | Val Loss 0.441896
# Epoch 600 | Train Loss 0.209939 | Val Loss 0.436297
# Epoch 700 | Train Loss 0.208739 | Val Loss 0.436403
# Epoch 800 | Train Loss 0.207884 | Val Loss 0.439937
# Early stopping at epoch 888
# X | train1 -> R² = -1.0608, MSE = 2.2221e-01
# X | train2 -> R² = -15.1097, MSE = 1.3574e+00
# X | test1 -> R² = -1.0848, MSE = 2.1841e-01
# X | test2 -> R² = -14.9066, MSE = 1.3090e+00
# X | test3 -> R² = -0.0083, MSE = 9.2766e-02
# X | val -> R² = -2.0390, MSE = 2.9060e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.466592 | Val Loss 0.671261
# Epoch 100 | Train Loss 0.236086 | Val Loss 0.518237
# Epoch 200 | Train Loss 0.219451 | Val Loss 0.484149
# Epoch 300 | Train Loss 0.214722 | Val Loss 0.462066
# Epoch 400 | Train Loss 0.212449 | Val Loss 0.446879
# Epoch 500 | Train Loss 0.210652 | Val Loss 0.441432
# Epoch 600 | Train Loss 0.209341 | Val Loss 0.441823
# Epoch 700 | Train Loss 0.208173 | Val Loss 0.445235
# Early stopping at epoch 771
# X | train1 -> R² = -1.0941, MSE = 2.2580e-01
# X | train2 -> R² = -15.1328, MSE = 1.3594e+00
# X | test1 -> R² = -1.1277, MSE = 2.2290e-01
# X | test2 -> R² = -14.7968, MSE = 1.3000e+00
# X | test3 -> R² = 0.0011, MSE = 9.1900e-02
# X | val -> R² = -3.0969, MSE = 3.9176e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.465149 | Val Loss 0.703411
# Epoch 100 | Train Loss 0.233780 | Val Loss 0.523059
# Epoch 200 | Train Loss 0.220525 | Val Loss 0.495645
# Epoch 300 | Train Loss 0.216973 | Val Loss 0.483379
# Epoch 400 | Train Loss 0.213651 | Val Loss 0.466770
# Epoch 500 | Train Loss 0.211196 | Val Loss 0.452225
# Epoch 600 | Train Loss 0.209613 | Val Loss 0.450535
# Epoch 700 | Train Loss 0.208553 | Val Loss 0.453314
# Epoch 800 | Train Loss 0.207680 | Val Loss 0.453604
# Early stopping at epoch 823
# X | train1 -> R² = -1.0626, MSE = 2.2240e-01
# X | train2 -> R² = -15.2051, MSE = 1.3654e+00
# X | test1 -> R² = -1.0972, MSE = 2.1971e-01
# X | test2 -> R² = -14.8644, MSE = 1.3055e+00
# X | test3 -> R² = -0.0881, MSE = 1.0011e-01
# X | val -> R² = -2.8993, MSE = 3.7287e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.466179 | Val Loss 0.689776
# Epoch 100 | Train Loss 0.236020 | Val Loss 0.522357
# Epoch 200 | Train Loss 0.220346 | Val Loss 0.484712
# Epoch 300 | Train Loss 0.215931 | Val Loss 0.460039
# Epoch 400 | Train Loss 0.214142 | Val Loss 0.444852
# Epoch 500 | Train Loss 0.212672 | Val Loss 0.434786
# Epoch 600 | Train Loss 0.210853 | Val Loss 0.430672
# Epoch 700 | Train Loss 0.209114 | Val Loss 0.445349
# Epoch 800 | Train Loss 0.207437 | Val Loss 0.460994
# Early stopping at epoch 855
# X | train1 -> R² = -1.0598, MSE = 2.2210e-01
# X | train2 -> R² = -15.2321, MSE = 1.3677e+00
# X | test1 -> R² = -1.0549, MSE = 2.1527e-01
# X | test2 -> R² = -14.7763, MSE = 1.2983e+00
# X | test3 -> R² = 0.4335, MSE = 5.2119e-02
# X | val -> R² = -1.7409, MSE = 2.6210e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.504241 | Val Loss 0.690055
# Epoch 100 | Train Loss 0.233657 | Val Loss 0.506070
# Epoch 200 | Train Loss 0.222525 | Val Loss 0.488658
# Epoch 300 | Train Loss 0.218301 | Val Loss 0.473516
# Epoch 400 | Train Loss 0.215899 | Val Loss 0.457739
# Epoch 500 | Train Loss 0.213883 | Val Loss 0.448339
# Epoch 600 | Train Loss 0.211732 | Val Loss 0.445001
# Epoch 700 | Train Loss 0.209611 | Val Loss 0.443811
# Epoch 800 | Train Loss 0.208266 | Val Loss 0.438078
# Epoch 900 | Train Loss 0.207481 | Val Loss 0.432800
# Epoch 1000 | Train Loss 0.206871 | Val Loss 0.430634
# Epoch 1100 | Train Loss 0.206210 | Val Loss 0.431839
# Epoch 1200 | Train Loss 0.205491 | Val Loss 0.435065
# Epoch 1300 | Train Loss 0.204787 | Val Loss 0.438552
# Early stopping at epoch 1301
# X | train1 -> R² = -1.0515, MSE = 2.2120e-01
# X | train2 -> R² = -14.9691, MSE = 1.3456e+00
# X | test1 -> R² = -1.1635, MSE = 2.2664e-01
# X | test2 -> R² = -14.8145, MSE = 1.3014e+00
# X | test3 -> R² = 0.7527, MSE = 2.2753e-02
# X | val -> R² = -1.0172, MSE = 1.9290e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.464717 | Val Loss 0.662523
# Epoch 100 | Train Loss 0.239596 | Val Loss 0.540098
# Epoch 200 | Train Loss 0.220099 | Val Loss 0.482944
# Epoch 300 | Train Loss 0.214377 | Val Loss 0.463262
# Epoch 400 | Train Loss 0.212661 | Val Loss 0.445163
# Epoch 500 | Train Loss 0.211702 | Val Loss 0.434976
# Epoch 600 | Train Loss 0.210647 | Val Loss 0.429968
# Epoch 700 | Train Loss 0.209461 | Val Loss 0.431139
# Epoch 800 | Train Loss 0.208418 | Val Loss 0.436020
# Epoch 900 | Train Loss 0.207605 | Val Loss 0.441177
# Early stopping at epoch 941
# X | train1 -> R² = -1.0768, MSE = 2.2394e-01
# X | train2 -> R² = -14.7255, MSE = 1.3250e+00
# X | test1 -> R² = -1.0861, MSE = 2.1854e-01
# X | test2 -> R² = -14.1840, MSE = 1.2495e+00
# X | test3 -> R² = 0.3386, MSE = 6.0848e-02
# X | val -> R² = -1.5504, MSE = 2.4387e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.462962 | Val Loss 0.651753
# Epoch 100 | Train Loss 0.237851 | Val Loss 0.516392
# Epoch 200 | Train Loss 0.220318 | Val Loss 0.476194
# Epoch 300 | Train Loss 0.214478 | Val Loss 0.456764
# Epoch 400 | Train Loss 0.212482 | Val Loss 0.440852
# Epoch 500 | Train Loss 0.210933 | Val Loss 0.435482
# Epoch 600 | Train Loss 0.209057 | Val Loss 0.436072
# Epoch 700 | Train Loss 0.207573 | Val Loss 0.440891
# Early stopping at epoch 793
# X | train1 -> R² = -1.1032, MSE = 2.2678e-01
# X | train2 -> R² = -15.3765, MSE = 1.3799e+00
# X | test1 -> R² = -1.0723, MSE = 2.1709e-01
# X | test2 -> R² = -14.9417, MSE = 1.3119e+00
# X | test3 -> R² = 0.2961, MSE = 6.4765e-02
# X | val -> R² = -2.3584, MSE = 3.2114e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.468826 | Val Loss 0.722728
# Epoch 100 | Train Loss 0.237251 | Val Loss 0.529826
# Epoch 200 | Train Loss 0.221217 | Val Loss 0.486930
# Epoch 300 | Train Loss 0.217103 | Val Loss 0.468223
# Epoch 400 | Train Loss 0.214407 | Val Loss 0.459352
# Epoch 500 | Train Loss 0.212717 | Val Loss 0.453824
# Epoch 600 | Train Loss 0.211271 | Val Loss 0.447666
# Epoch 700 | Train Loss 0.210088 | Val Loss 0.442540
# Epoch 800 | Train Loss 0.209134 | Val Loss 0.439967
# Epoch 900 | Train Loss 0.208284 | Val Loss 0.442715
# Epoch 1000 | Train Loss 0.207467 | Val Loss 0.446761
# Early stopping at epoch 1087
# X | train1 -> R² = -1.0897, MSE = 2.2532e-01
# X | train2 -> R² = -15.6341, MSE = 1.4016e+00
# X | test1 -> R² = -1.1469, MSE = 2.2491e-01
# X | test2 -> R² = -15.3734, MSE = 1.3474e+00
# X | test3 -> R² = 0.0213, MSE = 9.0042e-02
# X | val -> R² = -2.5348, MSE = 3.3801e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.577941 | Val Loss 0.693894
# Epoch 100 | Train Loss 0.363185 | Val Loss 0.445448
# Epoch 200 | Train Loss 0.353887 | Val Loss 0.426133
# Epoch 300 | Train Loss 0.349378 | Val Loss 0.407740
# Epoch 400 | Train Loss 0.346892 | Val Loss 0.395776
# Epoch 500 | Train Loss 0.345945 | Val Loss 0.392660
# Epoch 600 | Train Loss 0.345218 | Val Loss 0.390547
# Epoch 700 | Train Loss 0.344520 | Val Loss 0.389162
# Epoch 800 | Train Loss 0.343951 | Val Loss 0.389227
# Epoch 900 | Train Loss 0.343528 | Val Loss 0.389398
# Early stopping at epoch 984
# X | train1 -> R² = 0.6243, MSE = 4.0506e-02
# X | train2 -> R² = -1.9551, MSE = 2.4900e-01
# X | test1 -> R² = 0.6081, MSE = 4.1059e-02
# X | test2 -> R² = -1.7531, MSE = 2.2656e-01
# X | test3 -> R² = 0.9542, MSE = 4.2172e-03
# X | val -> R² = 0.4115, MSE = 5.6271e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.576160 | Val Loss 0.692332
# Epoch 100 | Train Loss 0.361676 | Val Loss 0.446696
# Epoch 200 | Train Loss 0.354747 | Val Loss 0.424947
# Epoch 300 | Train Loss 0.349547 | Val Loss 0.405119
# Epoch 400 | Train Loss 0.346875 | Val Loss 0.390810
# Epoch 500 | Train Loss 0.345986 | Val Loss 0.387435
# Epoch 600 | Train Loss 0.345252 | Val Loss 0.386570
# Epoch 700 | Train Loss 0.344660 | Val Loss 0.386725
# Epoch 800 | Train Loss 0.344254 | Val Loss 0.386628
# Early stopping at epoch 813
# X | train1 -> R² = 0.6232, MSE = 4.0627e-02
# X | train2 -> R² = -2.0014, MSE = 2.5290e-01
# X | test1 -> R² = 0.6101, MSE = 4.0849e-02
# X | test2 -> R² = -1.8117, MSE = 2.3138e-01
# X | test3 -> R² = 0.8449, MSE = 1.4271e-02
# X | val -> R² = 0.5332, MSE = 4.4639e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.585867 | Val Loss 0.686485
# Epoch 100 | Train Loss 0.360273 | Val Loss 0.449968
# Epoch 200 | Train Loss 0.355189 | Val Loss 0.430165
# Epoch 300 | Train Loss 0.351611 | Val Loss 0.412911
# Epoch 400 | Train Loss 0.348366 | Val Loss 0.401696
# Epoch 500 | Train Loss 0.346299 | Val Loss 0.393401
# Epoch 600 | Train Loss 0.345382 | Val Loss 0.388315
# Epoch 700 | Train Loss 0.344769 | Val Loss 0.385998
# Epoch 800 | Train Loss 0.344241 | Val Loss 0.385382
# Epoch 900 | Train Loss 0.343834 | Val Loss 0.386009
# Early stopping at epoch 981
# X | train1 -> R² = 0.6250, MSE = 4.0430e-02
# X | train2 -> R² = -2.0011, MSE = 2.5287e-01
# X | test1 -> R² = 0.5799, MSE = 4.4008e-02
# X | test2 -> R² = -1.7766, MSE = 2.2850e-01
# X | test3 -> R² = 0.8820, MSE = 1.0852e-02
# X | val -> R² = 0.3713, MSE = 6.0119e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.581253 | Val Loss 0.678220
# Epoch 100 | Train Loss 0.361268 | Val Loss 0.435513
# Epoch 200 | Train Loss 0.354695 | Val Loss 0.422263
# Epoch 300 | Train Loss 0.349724 | Val Loss 0.405034
# Epoch 400 | Train Loss 0.347188 | Val Loss 0.395910
# Epoch 500 | Train Loss 0.346182 | Val Loss 0.394306
# Epoch 600 | Train Loss 0.345185 | Val Loss 0.393146
# Epoch 700 | Train Loss 0.344396 | Val Loss 0.392636
# Epoch 800 | Train Loss 0.344011 | Val Loss 0.391153
# Epoch 900 | Train Loss 0.343713 | Val Loss 0.389834
# Epoch 1000 | Train Loss 0.343406 | Val Loss 0.389159
# Epoch 1100 | Train Loss 0.343087 | Val Loss 0.389095
# Epoch 1200 | Train Loss 0.342738 | Val Loss 0.389141
# Early stopping at epoch 1210
# X | train1 -> R² = 0.6368, MSE = 3.9160e-02
# X | train2 -> R² = -1.9136, MSE = 2.4550e-01
# X | test1 -> R² = 0.5869, MSE = 4.3275e-02
# X | test2 -> R² = -1.7338, MSE = 2.2497e-01
# X | test3 -> R² = 0.9642, MSE = 3.2896e-03
# X | val -> R² = 0.3924, MSE = 5.8096e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.585213 | Val Loss 0.715692
# Epoch 100 | Train Loss 0.362521 | Val Loss 0.444029
# Epoch 200 | Train Loss 0.355166 | Val Loss 0.425172
# Epoch 300 | Train Loss 0.351374 | Val Loss 0.408711
# Epoch 400 | Train Loss 0.347511 | Val Loss 0.393856
# Epoch 500 | Train Loss 0.345500 | Val Loss 0.390782
# Epoch 600 | Train Loss 0.344845 | Val Loss 0.391213
# Epoch 700 | Train Loss 0.344416 | Val Loss 0.390364
# Epoch 800 | Train Loss 0.344101 | Val Loss 0.388921
# Epoch 900 | Train Loss 0.343820 | Val Loss 0.387442
# Epoch 1000 | Train Loss 0.343535 | Val Loss 0.385935
# Epoch 1100 | Train Loss 0.343248 | Val Loss 0.384284
# Epoch 1200 | Train Loss 0.342935 | Val Loss 0.382409
# Epoch 1300 | Train Loss 0.342556 | Val Loss 0.380675
# Epoch 1400 | Train Loss 0.342007 | Val Loss 0.379137
# Epoch 1500 | Train Loss 0.341170 | Val Loss 0.377670
# Epoch 1600 | Train Loss 0.340024 | Val Loss 0.376798
# Epoch 1700 | Train Loss 0.338873 | Val Loss 0.376103
# Epoch 1800 | Train Loss 0.337892 | Val Loss 0.376092
# Epoch 1900 | Train Loss 0.337031 | Val Loss 0.377943
# Epoch 2000 | Train Loss 0.336220 | Val Loss 0.381261
# Early stopping at epoch 2033
# X | train1 -> R² = 0.6607, MSE = 3.6583e-02
# X | train2 -> R² = -2.1402, MSE = 2.6459e-01
# X | test1 -> R² = 0.6186, MSE = 3.9952e-02
# X | test2 -> R² = -1.8835, MSE = 2.3729e-01
# X | test3 -> R² = 0.4242, MSE = 5.2979e-02
# X | val -> R² = 0.8188, MSE = 1.7324e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.570813 | Val Loss 0.656359
# Epoch 100 | Train Loss 0.359037 | Val Loss 0.432487
# Epoch 200 | Train Loss 0.352843 | Val Loss 0.417739
# Epoch 300 | Train Loss 0.349442 | Val Loss 0.404517
# Epoch 400 | Train Loss 0.347239 | Val Loss 0.394162
# Epoch 500 | Train Loss 0.346100 | Val Loss 0.390320
# Epoch 600 | Train Loss 0.345032 | Val Loss 0.388726
# Epoch 700 | Train Loss 0.344266 | Val Loss 0.388898
# Epoch 800 | Train Loss 0.343863 | Val Loss 0.388066
# Epoch 900 | Train Loss 0.343546 | Val Loss 0.386002
# Epoch 1000 | Train Loss 0.343235 | Val Loss 0.383880
# Epoch 1100 | Train Loss 0.342886 | Val Loss 0.382218
# Epoch 1200 | Train Loss 0.342479 | Val Loss 0.381430
# Epoch 1300 | Train Loss 0.341992 | Val Loss 0.381096
# Epoch 1400 | Train Loss 0.341422 | Val Loss 0.380319
# Epoch 1500 | Train Loss 0.340786 | Val Loss 0.379074
# Epoch 1600 | Train Loss 0.340109 | Val Loss 0.378221
# Epoch 1700 | Train Loss 0.339386 | Val Loss 0.378365
# Epoch 1800 | Train Loss 0.338595 | Val Loss 0.380081
# Early stopping at epoch 1837
# X | train1 -> R² = 0.6440, MSE = 3.8391e-02
# X | train2 -> R² = -1.9520, MSE = 2.4874e-01
# X | test1 -> R² = 0.6433, MSE = 3.7363e-02
# X | test2 -> R² = -1.7940, MSE = 2.2992e-01
# X | test3 -> R² = 0.4098, MSE = 5.4305e-02
# X | val -> R² = 0.7849, MSE = 2.0567e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.574175 | Val Loss 0.685762
# Epoch 100 | Train Loss 0.361965 | Val Loss 0.450119
# Epoch 200 | Train Loss 0.355617 | Val Loss 0.433250
# Epoch 300 | Train Loss 0.351158 | Val Loss 0.417251
# Epoch 400 | Train Loss 0.347500 | Val Loss 0.403812
# Epoch 500 | Train Loss 0.346415 | Val Loss 0.397656
# Epoch 600 | Train Loss 0.345696 | Val Loss 0.393110
# Epoch 700 | Train Loss 0.344982 | Val Loss 0.390183
# Epoch 800 | Train Loss 0.344345 | Val Loss 0.388959
# Epoch 900 | Train Loss 0.343820 | Val Loss 0.388638
# Epoch 1000 | Train Loss 0.343306 | Val Loss 0.388263
# Epoch 1100 | Train Loss 0.342728 | Val Loss 0.386866
# Epoch 1200 | Train Loss 0.342093 | Val Loss 0.383925
# Epoch 1300 | Train Loss 0.341388 | Val Loss 0.380574
# Epoch 1400 | Train Loss 0.340557 | Val Loss 0.377961
# Epoch 1500 | Train Loss 0.339712 | Val Loss 0.377502
# Epoch 1600 | Train Loss 0.338953 | Val Loss 0.378962
# Epoch 1700 | Train Loss 0.338283 | Val Loss 0.380883
# Early stopping at epoch 1701
# X | train1 -> R² = 0.6605, MSE = 3.6603e-02
# X | train2 -> R² = -2.0223, MSE = 2.5466e-01
# X | test1 -> R² = 0.6261, MSE = 3.9169e-02
# X | test2 -> R² = -1.8808, MSE = 2.3707e-01
# X | test3 -> R² = 0.6107, MSE = 3.5818e-02
# X | val -> R² = 0.9643, MSE = 3.4185e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.567512 | Val Loss 0.627925
# Epoch 100 | Train Loss 0.361044 | Val Loss 0.443119
# Epoch 200 | Train Loss 0.354419 | Val Loss 0.422325
# Epoch 300 | Train Loss 0.350147 | Val Loss 0.406518
# Epoch 400 | Train Loss 0.347572 | Val Loss 0.394809
# Epoch 500 | Train Loss 0.346418 | Val Loss 0.391132
# Epoch 600 | Train Loss 0.345384 | Val Loss 0.388908
# Epoch 700 | Train Loss 0.344524 | Val Loss 0.388684
# Epoch 800 | Train Loss 0.344001 | Val Loss 0.388917
# Early stopping at epoch 871
# X | train1 -> R² = 0.6235, MSE = 4.0591e-02
# X | train2 -> R² = -2.0250, MSE = 2.5489e-01
# X | test1 -> R² = 0.6239, MSE = 3.9396e-02
# X | test2 -> R² = -1.8124, MSE = 2.3144e-01
# X | test3 -> R² = 0.9088, MSE = 8.3950e-03
# X | val -> R² = 0.4851, MSE = 4.9236e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.561204 | Val Loss 0.641850
# Epoch 100 | Train Loss 0.360427 | Val Loss 0.446580
# Epoch 200 | Train Loss 0.354930 | Val Loss 0.431050
# Epoch 300 | Train Loss 0.350932 | Val Loss 0.414259
# Epoch 400 | Train Loss 0.347422 | Val Loss 0.402049
# Epoch 500 | Train Loss 0.346217 | Val Loss 0.395862
# Epoch 600 | Train Loss 0.345460 | Val Loss 0.391427
# Epoch 700 | Train Loss 0.344785 | Val Loss 0.387200
# Epoch 800 | Train Loss 0.344249 | Val Loss 0.384939
# Epoch 900 | Train Loss 0.343840 | Val Loss 0.385502
# Epoch 1000 | Train Loss 0.343478 | Val Loss 0.386369
# Epoch 1100 | Train Loss 0.343078 | Val Loss 0.386737
# Early stopping at epoch 1101
# X | train1 -> R² = 0.6295, MSE = 3.9947e-02
# X | train2 -> R² = -1.8342, MSE = 2.3881e-01
# X | test1 -> R² = 0.6006, MSE = 4.1843e-02
# X | test2 -> R² = -1.6297, MSE = 2.1640e-01
# X | test3 -> R² = 0.9685, MSE = 2.8946e-03
# X | val -> R² = 0.5537, MSE = 4.2672e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.592871 | Val Loss 0.733896
# Epoch 100 | Train Loss 0.378023 | Val Loss 0.436929
# Epoch 200 | Train Loss 0.353803 | Val Loss 0.419448
# Epoch 300 | Train Loss 0.350403 | Val Loss 0.407096
# Epoch 400 | Train Loss 0.347445 | Val Loss 0.396022
# Epoch 500 | Train Loss 0.346216 | Val Loss 0.392009
# Epoch 600 | Train Loss 0.345244 | Val Loss 0.389679
# Epoch 700 | Train Loss 0.344587 | Val Loss 0.388848
# Epoch 800 | Train Loss 0.344251 | Val Loss 0.388777
# Epoch 900 | Train Loss 0.344028 | Val Loss 0.388386
# Early stopping at epoch 944
# X | train1 -> R² = 0.6355, MSE = 3.9305e-02
# X | train2 -> R² = -1.9596, MSE = 2.4938e-01
# X | test1 -> R² = 0.5776, MSE = 4.4249e-02
# X | test2 -> R² = -1.7432, MSE = 2.2575e-01
# X | test3 -> R² = 0.9658, MSE = 3.1504e-03
# X | val -> R² = 0.3267, MSE = 6.4380e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.542435 | Val Loss 0.591665
# Epoch 100 | Train Loss 0.357869 | Val Loss 0.443111
# Epoch 200 | Train Loss 0.351596 | Val Loss 0.414210
# Epoch 300 | Train Loss 0.347287 | Val Loss 0.397696
# Epoch 400 | Train Loss 0.346127 | Val Loss 0.391422
# Epoch 500 | Train Loss 0.345275 | Val Loss 0.388238
# Epoch 600 | Train Loss 0.344539 | Val Loss 0.386712
# Epoch 700 | Train Loss 0.344119 | Val Loss 0.386998
# Epoch 800 | Train Loss 0.343814 | Val Loss 0.386712
# Early stopping at epoch 840
# X | train1 -> R² = 0.6236, MSE = 4.0587e-02
# X | train2 -> R² = -1.9811, MSE = 2.5119e-01
# X | test1 -> R² = 0.5994, MSE = 4.1967e-02
# X | test2 -> R² = -1.8235, MSE = 2.3236e-01
# X | test3 -> R² = 0.9354, MSE = 5.9435e-03
# X | val -> R² = 0.3240, MSE = 6.4639e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.577190 | Val Loss 0.695802
# Epoch 100 | Train Loss 0.362027 | Val Loss 0.446936
# Epoch 200 | Train Loss 0.355387 | Val Loss 0.431266
# Epoch 300 | Train Loss 0.350427 | Val Loss 0.416057
# Epoch 400 | Train Loss 0.346788 | Val Loss 0.401308
# Epoch 500 | Train Loss 0.345728 | Val Loss 0.394260
# Epoch 600 | Train Loss 0.344938 | Val Loss 0.390073
# Epoch 700 | Train Loss 0.344444 | Val Loss 0.388584
# Epoch 800 | Train Loss 0.344093 | Val Loss 0.387720
# Epoch 900 | Train Loss 0.343791 | Val Loss 0.386618
# Epoch 1000 | Train Loss 0.343530 | Val Loss 0.385278
# Epoch 1100 | Train Loss 0.343227 | Val Loss 0.384054
# Epoch 1200 | Train Loss 0.342948 | Val Loss 0.383125
# Epoch 1300 | Train Loss 0.342664 | Val Loss 0.382468
# Epoch 1400 | Train Loss 0.342334 | Val Loss 0.382027
# Epoch 1500 | Train Loss 0.341933 | Val Loss 0.381574
# Epoch 1600 | Train Loss 0.341404 | Val Loss 0.380970
# Epoch 1700 | Train Loss 0.340684 | Val Loss 0.381105
# Epoch 1800 | Train Loss 0.339880 | Val Loss 0.380803
# Epoch 1900 | Train Loss 0.339142 | Val Loss 0.380588
# Early stopping at epoch 1923
# X | train1 -> R² = 0.6423, MSE = 3.8575e-02
# X | train2 -> R² = -1.9289, MSE = 2.4679e-01
# X | test1 -> R² = 0.5696, MSE = 4.5094e-02
# X | test2 -> R² = -1.7925, MSE = 2.2980e-01
# X | test3 -> R² = 0.7625, MSE = 2.1855e-02
# X | val -> R² = 0.9214, MSE = 7.5146e-03
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.568785 | Val Loss 0.656741
# Epoch 100 | Train Loss 0.360665 | Val Loss 0.445906
# Epoch 200 | Train Loss 0.353939 | Val Loss 0.424686
# Epoch 300 | Train Loss 0.349408 | Val Loss 0.405608
# Epoch 400 | Train Loss 0.347263 | Val Loss 0.395637
# Epoch 500 | Train Loss 0.346204 | Val Loss 0.392633
# Epoch 600 | Train Loss 0.345078 | Val Loss 0.389907
# Epoch 700 | Train Loss 0.344309 | Val Loss 0.388981
# Epoch 800 | Train Loss 0.343988 | Val Loss 0.388800
# Epoch 900 | Train Loss 0.343723 | Val Loss 0.387994
# Epoch 1000 | Train Loss 0.343449 | Val Loss 0.387025
# Epoch 1100 | Train Loss 0.343138 | Val Loss 0.386309
# Epoch 1200 | Train Loss 0.342777 | Val Loss 0.385693
# Epoch 1300 | Train Loss 0.342320 | Val Loss 0.384944
# Epoch 1400 | Train Loss 0.341715 | Val Loss 0.383432
# Epoch 1500 | Train Loss 0.340894 | Val Loss 0.381437
# Epoch 1600 | Train Loss 0.339859 | Val Loss 0.380020
# Epoch 1700 | Train Loss 0.338709 | Val Loss 0.379916
# Epoch 1800 | Train Loss 0.337741 | Val Loss 0.380722
# Epoch 1900 | Train Loss 0.336949 | Val Loss 0.382307
# Early stopping at epoch 1932
# X | train1 -> R² = 0.6508, MSE = 3.7654e-02
# X | train2 -> R² = -2.2908, MSE = 2.7729e-01
# X | test1 -> R² = 0.6120, MSE = 4.0651e-02
# X | test2 -> R² = -2.1521, MSE = 2.5940e-01
# X | test3 -> R² = 0.6981, MSE = 2.7778e-02
# X | val -> R² = 0.7759, MSE = 2.1429e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.563688 | Val Loss 0.654012
# Epoch 100 | Train Loss 0.360906 | Val Loss 0.445067
# Epoch 200 | Train Loss 0.353971 | Val Loss 0.423748
# Epoch 300 | Train Loss 0.350248 | Val Loss 0.405721
# Epoch 400 | Train Loss 0.346896 | Val Loss 0.396796
# Epoch 500 | Train Loss 0.345919 | Val Loss 0.392932
# Epoch 600 | Train Loss 0.345247 | Val Loss 0.391213
# Epoch 700 | Train Loss 0.344750 | Val Loss 0.390528
# Epoch 800 | Train Loss 0.344377 | Val Loss 0.390925
# Epoch 900 | Train Loss 0.344046 | Val Loss 0.391623
# Early stopping at epoch 928
# X | train1 -> R² = 0.6217, MSE = 4.0786e-02
# X | train2 -> R² = -1.9714, MSE = 2.5037e-01
# X | test1 -> R² = 0.5935, MSE = 4.2584e-02
# X | test2 -> R² = -1.7150, MSE = 2.2342e-01
# X | test3 -> R² = 0.9637, MSE = 3.3442e-03
# X | val -> R² = 0.0347, MSE = 9.2304e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.573906 | Val Loss 0.687200
# Epoch 100 | Train Loss 0.362036 | Val Loss 0.446192
# Epoch 200 | Train Loss 0.355708 | Val Loss 0.431174
# Epoch 300 | Train Loss 0.351230 | Val Loss 0.415811
# Epoch 400 | Train Loss 0.346865 | Val Loss 0.401687
# Epoch 500 | Train Loss 0.345559 | Val Loss 0.397412
# Epoch 600 | Train Loss 0.344749 | Val Loss 0.394418
# Epoch 700 | Train Loss 0.344237 | Val Loss 0.392116
# Epoch 800 | Train Loss 0.343824 | Val Loss 0.389853
# Epoch 900 | Train Loss 0.343458 | Val Loss 0.388187
# Epoch 1000 | Train Loss 0.343091 | Val Loss 0.387170
# Epoch 1100 | Train Loss 0.342725 | Val Loss 0.386717
# Epoch 1200 | Train Loss 0.342351 | Val Loss 0.386616
# Epoch 1300 | Train Loss 0.341968 | Val Loss 0.386737
# Early stopping at epoch 1314
# X | train1 -> R² = 0.6372, MSE = 3.9119e-02
# X | train2 -> R² = -1.9374, MSE = 2.4751e-01
# X | test1 -> R² = 0.5448, MSE = 4.7683e-02
# X | test2 -> R² = -1.8003, MSE = 2.3044e-01
# X | test3 -> R² = 0.9657, MSE = 3.1544e-03
# X | val -> R² = 0.3151, MSE = 6.5490e-02
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.519827 | Val Loss 0.650585
# Epoch 100 | Train Loss 0.301295 | Val Loss 0.455660
# Epoch 200 | Train Loss 0.295512 | Val Loss 0.434433
# Epoch 300 | Train Loss 0.292714 | Val Loss 0.417431
# Epoch 400 | Train Loss 0.291712 | Val Loss 0.412094
# Epoch 500 | Train Loss 0.290749 | Val Loss 0.405934
# Epoch 600 | Train Loss 0.289747 | Val Loss 0.404267
# Epoch 700 | Train Loss 0.288938 | Val Loss 0.404000
# Epoch 800 | Train Loss 0.288288 | Val Loss 0.402233
# Epoch 900 | Train Loss 0.287644 | Val Loss 0.403745
# Epoch 1000 | Train Loss 0.286853 | Val Loss 0.404530
# Early stopping at epoch 1048
# X | train1 -> R² = -0.0410, MSE = 1.1224e-01
# X | train2 -> R² = -7.1951, MSE = 6.9052e-01
# X | test1 -> R² = -0.1230, MSE = 1.1764e-01
# X | test2 -> R² = -6.9679, MSE = 6.5570e-01
# X | test3 -> R² = 0.9310, MSE = 6.3519e-03
# X | val -> R² = -0.2161, MSE = 1.1628e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.502705 | Val Loss 0.580408
# Epoch 100 | Train Loss 0.299472 | Val Loss 0.444198
# Epoch 200 | Train Loss 0.293617 | Val Loss 0.419078
# Epoch 300 | Train Loss 0.292014 | Val Loss 0.408225
# Epoch 400 | Train Loss 0.291088 | Val Loss 0.401768
# Epoch 500 | Train Loss 0.290344 | Val Loss 0.399759
# Epoch 600 | Train Loss 0.289537 | Val Loss 0.402249
# Epoch 700 | Train Loss 0.288831 | Val Loss 0.407914
# Early stopping at epoch 747
# X | train1 -> R² = -0.0756, MSE = 1.1597e-01
# X | train2 -> R² = -7.6266, MSE = 7.2688e-01
# X | test1 -> R² = -0.0729, MSE = 1.1240e-01
# X | test2 -> R² = -7.2727, MSE = 6.8079e-01
# X | test3 -> R² = 0.9583, MSE = 3.8322e-03
# X | val -> R² = -0.1454, MSE = 1.0953e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.535884 | Val Loss 0.610952
# Epoch 100 | Train Loss 0.303698 | Val Loss 0.454672
# Epoch 200 | Train Loss 0.295689 | Val Loss 0.427774
# Epoch 300 | Train Loss 0.292949 | Val Loss 0.414460
# Epoch 400 | Train Loss 0.291863 | Val Loss 0.408559
# Epoch 500 | Train Loss 0.290805 | Val Loss 0.402649
# Epoch 600 | Train Loss 0.289633 | Val Loss 0.404833
# Epoch 700 | Train Loss 0.288995 | Val Loss 0.410119
# Epoch 800 | Train Loss 0.288412 | Val Loss 0.412941
# Early stopping at epoch 846
# X | train1 -> R² = -0.0529, MSE = 1.1354e-01
# X | train2 -> R² = -7.2003, MSE = 6.9096e-01
# X | test1 -> R² = -0.0809, MSE = 1.1323e-01
# X | test2 -> R² = -6.9084, MSE = 6.5081e-01
# X | test3 -> R² = 0.9525, MSE = 4.3693e-03
# X | val -> R² = -0.2690, MSE = 1.2135e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.516154 | Val Loss 0.571859
# Epoch 100 | Train Loss 0.302217 | Val Loss 0.451294
# Epoch 200 | Train Loss 0.295335 | Val Loss 0.427803
# Epoch 300 | Train Loss 0.292585 | Val Loss 0.414029
# Epoch 400 | Train Loss 0.291522 | Val Loss 0.408590
# Epoch 500 | Train Loss 0.290628 | Val Loss 0.403114
# Epoch 600 | Train Loss 0.289554 | Val Loss 0.403394
# Epoch 700 | Train Loss 0.289160 | Val Loss 0.410301
# Epoch 800 | Train Loss 0.288128 | Val Loss 0.414430
# Early stopping at epoch 821
# X | train1 -> R² = -0.0661, MSE = 1.1496e-01
# X | train2 -> R² = -7.3109, MSE = 7.0028e-01
# X | test1 -> R² = -0.0521, MSE = 1.1022e-01
# X | test2 -> R² = -6.9510, MSE = 6.5431e-01
# X | test3 -> R² = 0.9523, MSE = 4.3850e-03
# X | val -> R² = -0.3468, MSE = 1.2879e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.504624 | Val Loss 0.596142
# Epoch 100 | Train Loss 0.300164 | Val Loss 0.446684
# Epoch 200 | Train Loss 0.294084 | Val Loss 0.422209
# Epoch 300 | Train Loss 0.292237 | Val Loss 0.409389
# Epoch 400 | Train Loss 0.291349 | Val Loss 0.403251
# Epoch 500 | Train Loss 0.290719 | Val Loss 0.398993
# Epoch 600 | Train Loss 0.290018 | Val Loss 0.398715
# Epoch 700 | Train Loss 0.289282 | Val Loss 0.403160
# Epoch 800 | Train Loss 0.288620 | Val Loss 0.406099
# Early stopping at epoch 863
# X | train1 -> R² = -0.0445, MSE = 1.1263e-01
# X | train2 -> R² = -7.1855, MSE = 6.8971e-01
# X | test1 -> R² = -0.0806, MSE = 1.1321e-01
# X | test2 -> R² = -6.9175, MSE = 6.5156e-01
# X | test3 -> R² = 0.9555, MSE = 4.0915e-03
# X | val -> R² = -0.0171, MSE = 9.7262e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.512475 | Val Loss 0.595432
# Epoch 100 | Train Loss 0.301527 | Val Loss 0.455407
# Epoch 200 | Train Loss 0.295906 | Val Loss 0.432376
# Epoch 300 | Train Loss 0.292842 | Val Loss 0.409979
# Epoch 400 | Train Loss 0.291668 | Val Loss 0.402596
# Epoch 500 | Train Loss 0.290715 | Val Loss 0.399666
# Epoch 600 | Train Loss 0.289710 | Val Loss 0.403001
# Epoch 700 | Train Loss 0.288693 | Val Loss 0.409542
# Epoch 800 | Train Loss 0.287921 | Val Loss 0.412144
# Early stopping at epoch 808
# X | train1 -> R² = -0.0745, MSE = 1.1586e-01
# X | train2 -> R² = -7.2068, MSE = 6.9150e-01
# X | test1 -> R² = -0.0527, MSE = 1.1028e-01
# X | test2 -> R² = -6.8528, MSE = 6.4623e-01
# X | test3 -> R² = 0.9521, MSE = 4.4036e-03
# X | val -> R² = 0.1391, MSE = 8.2320e-02
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.516922 | Val Loss 0.630653
# Epoch 100 | Train Loss 0.301046 | Val Loss 0.448108
# Epoch 200 | Train Loss 0.294612 | Val Loss 0.427521
# Epoch 300 | Train Loss 0.292395 | Val Loss 0.412980
# Epoch 400 | Train Loss 0.291203 | Val Loss 0.406380
# Epoch 500 | Train Loss 0.289920 | Val Loss 0.405350
# Epoch 600 | Train Loss 0.289080 | Val Loss 0.410840
# Epoch 700 | Train Loss 0.288408 | Val Loss 0.411112
# Early stopping at epoch 748
# X | train1 -> R² = -0.0507, MSE = 1.1329e-01
# X | train2 -> R² = -7.1338, MSE = 6.8536e-01
# X | test1 -> R² = -0.0752, MSE = 1.1263e-01
# X | test2 -> R² = -6.7738, MSE = 6.3973e-01
# X | test3 -> R² = 0.9307, MSE = 6.3798e-03
# X | val -> R² = -0.3625, MSE = 1.3028e-01
# Modelo [64] | Ld=0.5 Lp=0.5 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.507954 | Val Loss 0.619971
# Epoch 100 | Train Loss 0.301166 | Val Loss 0.458764
# Epoch 200 | Train Loss 0.294714 | Val Loss 0.432339
# Epoch 300 | Train Loss 0.292427 | Val Loss 0.414548
# Epoch 400 | Train Loss 0.291374 | Val Loss 0.407551
# Epoch 500 | Train Loss 0.290019 | Val Loss 0.404465
# Epoch 600 | Train Loss 0.289052 | Val Loss 0.408236
# Epoch 700 | Train Loss 0.288128 | Val Loss 0.409007
# Early stopping at epoch 761
# X | train1 -> R² = -0.0515, MSE = 1.1338e-01
# X | train2 -> R² = -6.9604, MSE = 6.7075e-01
# X | test1 -> R² = -0.0879, MSE = 1.1396e-01
# ...
# Epoch 0 | Train Loss 0.472454 | Val Loss 0.565726
# Epoch 100 | Train Loss 0.213941 | Val Loss 0.433357
# Epoch 200 | Train Loss 0.210840 | Val Loss 0.425594
# Epoch 300 | Train Loss 0.205743 | Val Loss 0.455377
# Epoch 400 | Train Loss 0.203102 | Val Loss 0.459397
# Early stopping at epoch 466
# X | train1 -> R² = -0.8766, MSE = 2.0234e-01
# X | train2 -> R² = -9.1758, MSE = 8.5742e-01
# X | test1 -> R² = -0.8323, MSE = 1.9195e-01
# X | test2 -> R² = -8.7877, MSE = 8.0546e-01
# X | test3 -> R² = 0.9219, MSE = 7.1883e-03
# X | val -> R² = -0.2445, MSE = 1.1901e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.499874 | Val Loss 0.607783
# Epoch 100 | Train Loss 0.217406 | Val Loss 0.466990
# Epoch 200 | Train Loss 0.209878 | Val Loss 0.436658
# Epoch 300 | Train Loss 0.209136 | Val Loss 0.448580
# Epoch 400 | Train Loss 0.204618 | Val Loss 0.450805
# Epoch 500 | Train Loss 0.201975 | Val Loss 0.454624
# Early stopping at epoch 523
# X | train1 -> R² = -0.8299, MSE = 1.9731e-01
# X | train2 -> R² = -7.5715, MSE = 7.2224e-01
# X | test1 -> R² = -0.8237, MSE = 1.9105e-01
# X | test2 -> R² = -7.3543, MSE = 6.8750e-01
# X | test3 -> R² = 0.8241, MSE = 1.6183e-02
# X | val -> R² = -1.2448, MSE = 2.1465e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.480111 | Val Loss 0.586602
# Epoch 100 | Train Loss 0.215533 | Val Loss 0.461836
# Epoch 200 | Train Loss 0.209885 | Val Loss 0.452679
# Epoch 300 | Train Loss 0.206114 | Val Loss 0.452969
# Epoch 400 | Train Loss 0.202928 | Val Loss 0.452834
# Early stopping at epoch 441
# X | train1 -> R² = -0.7292, MSE = 1.8646e-01
# X | train2 -> R² = -6.5894, MSE = 6.3949e-01
# X | test1 -> R² = -0.6670, MSE = 1.7463e-01
# X | test2 -> R² = -6.3485, MSE = 6.0473e-01
# X | test3 -> R² = 0.9301, MSE = 6.4287e-03
# X | val -> R² = -0.6672, MSE = 1.5942e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.496423 | Val Loss 0.610399
# Epoch 100 | Train Loss 0.216502 | Val Loss 0.457773
# Epoch 200 | Train Loss 0.208870 | Val Loss 0.434624
# Epoch 300 | Train Loss 0.205444 | Val Loss 0.447232
# Epoch 400 | Train Loss 0.203196 | Val Loss 0.449088
# Early stopping at epoch 462
# X | train1 -> R² = -0.7458, MSE = 1.8824e-01
# X | train2 -> R² = -8.1088, MSE = 7.6751e-01
# X | test1 -> R² = -0.6893, MSE = 1.7697e-01
# X | test2 -> R² = -7.7869, MSE = 7.2310e-01
# X | test3 -> R² = 0.9157, MSE = 7.7532e-03
# X | val -> R² = -0.4512, MSE = 1.3876e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.481116 | Val Loss 0.523955
# Epoch 100 | Train Loss 0.216973 | Val Loss 0.463763
# Epoch 200 | Train Loss 0.209649 | Val Loss 0.439088
# Epoch 300 | Train Loss 0.209721 | Val Loss 0.446786
# Epoch 400 | Train Loss 0.204262 | Val Loss 0.451984
# Epoch 500 | Train Loss 0.202552 | Val Loss 0.452051
# Early stopping at epoch 506
# X | train1 -> R² = -0.5978, MSE = 1.7228e-01
# X | train2 -> R² = -3.2495, MSE = 3.5806e-01
# X | test1 -> R² = -0.6137, MSE = 1.6905e-01
# X | test2 -> R² = -3.0337, MSE = 3.3195e-01
# X | test3 -> R² = 0.9121, MSE = 8.0857e-03
# X | val -> R² = -0.3315, MSE = 1.2732e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.501454 | Val Loss 0.647184
# Epoch 100 | Train Loss 0.214181 | Val Loss 0.436700
# Epoch 200 | Train Loss 0.207564 | Val Loss 0.438797
# Epoch 300 | Train Loss 0.209690 | Val Loss 0.452772
# Epoch 400 | Train Loss 0.202233 | Val Loss 0.451383
# Early stopping at epoch 419
# X | train1 -> R² = -0.8744, MSE = 2.0211e-01
# X | train2 -> R² = -9.5820, MSE = 8.9164e-01
# X | test1 -> R² = -0.7933, MSE = 1.8787e-01
# X | test2 -> R² = -9.3773, MSE = 8.5398e-01
# X | test3 -> R² = 0.9366, MSE = 5.8346e-03
# X | val -> R² = -0.5531, MSE = 1.4851e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4 salvo.
# Epoch 0 | Train Loss 0.612676 | Val Loss 0.509871
# Epoch 100 | Train Loss 0.351497 | Val Loss 0.414649
# Epoch 200 | Train Loss 0.345851 | Val Loss 0.391105
# Epoch 300 | Train Loss 0.343827 | Val Loss 0.387645
# Epoch 400 | Train Loss 0.342862 | Val Loss 0.386461
# Epoch 500 | Train Loss 0.342054 | Val Loss 0.378156
# Epoch 600 | Train Loss 0.342925 | Val Loss 0.376659
# Epoch 700 | Train Loss 0.341187 | Val Loss 0.386715
# Epoch 800 | Train Loss 0.337187 | Val Loss 0.382701
# Epoch 900 | Train Loss 0.335291 | Val Loss 0.386190
# Early stopping at epoch 909
# X | train1 -> R² = 0.5996, MSE = 4.3168e-02
# X | train2 -> R² = -2.6593, MSE = 3.0833e-01
# X | test1 -> R² = 0.6312, MSE = 3.8632e-02
# X | test2 -> R² = -2.4961, MSE = 2.8770e-01
# X | test3 -> R² = 0.5742, MSE = 3.9173e-02
# X | val -> R² = 0.9101, MSE = 8.5924e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=0 salvo.
# Epoch 0 | Train Loss 0.612334 | Val Loss 0.532961
# Epoch 100 | Train Loss 0.350139 | Val Loss 0.410504
# Epoch 200 | Train Loss 0.345823 | Val Loss 0.391877
# Epoch 300 | Train Loss 0.346940 | Val Loss 0.392429
# Epoch 400 | Train Loss 0.342753 | Val Loss 0.386463
# Epoch 500 | Train Loss 0.341194 | Val Loss 0.378309
# Epoch 600 | Train Loss 0.339919 | Val Loss 0.377062
# Epoch 700 | Train Loss 0.339022 | Val Loss 0.380625
# Epoch 800 | Train Loss 0.337688 | Val Loss 0.390782
# Early stopping at epoch 872
# X | train1 -> R² = 0.6433, MSE = 3.8457e-02
# X | train2 -> R² = -2.2930, MSE = 2.7747e-01
# X | test1 -> R² = 0.6636, MSE = 3.5245e-02
# X | test2 -> R² = -2.0919, MSE = 2.5444e-01
# X | test3 -> R² = 0.6131, MSE = 3.5593e-02
# X | val -> R² = 0.9211, MSE = 7.5433e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1 salvo.
# Epoch 0 | Train Loss 0.616303 | Val Loss 0.541638
# Epoch 100 | Train Loss 0.351176 | Val Loss 0.418520
# Epoch 200 | Train Loss 0.345363 | Val Loss 0.390873
# Epoch 300 | Train Loss 0.343616 | Val Loss 0.387430
# Epoch 400 | Train Loss 0.342280 | Val Loss 0.380181
# Epoch 500 | Train Loss 0.340844 | Val Loss 0.375838
# Epoch 600 | Train Loss 0.339522 | Val Loss 0.378069
# Epoch 700 | Train Loss 0.338156 | Val Loss 0.379544
# Early stopping at epoch 781
# X | train1 -> R² = 0.5903, MSE = 4.4172e-02
# X | train2 -> R² = -2.9441, MSE = 3.3233e-01
# X | test1 -> R² = 0.6291, MSE = 3.8859e-02
# X | test2 -> R² = -2.8100, MSE = 3.1354e-01
# X | test3 -> R² = 0.7053, MSE = 2.7114e-02
# X | val -> R² = 0.8996, MSE = 9.5991e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2 salvo.
# Epoch 0 | Train Loss 0.578060 | Val Loss 0.480699
# Epoch 100 | Train Loss 0.350420 | Val Loss 0.410856
# Epoch 200 | Train Loss 0.346761 | Val Loss 0.392252
# Epoch 300 | Train Loss 0.344045 | Val Loss 0.390197
# Epoch 400 | Train Loss 0.342551 | Val Loss 0.385008
# Epoch 500 | Train Loss 0.340977 | Val Loss 0.379457
# Epoch 600 | Train Loss 0.339639 | Val Loss 0.377558
# Epoch 700 | Train Loss 0.338193 | Val Loss 0.379082
# Epoch 800 | Train Loss 0.336701 | Val Loss 0.382340
# Early stopping at epoch 852
# X | train1 -> R² = 0.6558, MSE = 3.7116e-02
# X | train2 -> R² = -1.9160, MSE = 2.4570e-01
# X | test1 -> R² = 0.6597, MSE = 3.5652e-02
# X | test2 -> R² = -1.8056, MSE = 2.3089e-01
# X | test3 -> R² = 0.6668, MSE = 3.0654e-02
# X | val -> R² = 0.9442, MSE = 5.3380e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3 salvo.
# Epoch 0 | Train Loss 0.596296 | Val Loss 0.553411
# Epoch 100 | Train Loss 0.348712 | Val Loss 0.401186
# Epoch 200 | Train Loss 0.346921 | Val Loss 0.393257
# Epoch 300 | Train Loss 0.343253 | Val Loss 0.387956
# Epoch 400 | Train Loss 0.342166 | Val Loss 0.386531
# Epoch 500 | Train Loss 0.340920 | Val Loss 0.383951
# Epoch 600 | Train Loss 0.339352 | Val Loss 0.384165
# Epoch 700 | Train Loss 0.337804 | Val Loss 0.388480
# Epoch 800 | Train Loss 0.336140 | Val Loss 0.391488
# Early stopping at epoch 860
# X | train1 -> R² = 0.6593, MSE = 3.6733e-02
# X | train2 -> R² = -2.5620, MSE = 3.0013e-01
# X | test1 -> R² = 0.6933, MSE = 3.2135e-02
# X | test2 -> R² = -2.3527, MSE = 2.7590e-01
# X | test3 -> R² = 0.4543, MSE = 5.0208e-02
# X | val -> R² = 0.9118, MSE = 8.4370e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4 salvo.
# Epoch 0 | Train Loss 0.615506 | Val Loss 0.524340
# Epoch 100 | Train Loss 0.350043 | Val Loss 0.408249
# Epoch 200 | Train Loss 0.344927 | Val Loss 0.389953
# Epoch 300 | Train Loss 0.343049 | Val Loss 0.389344
# Epoch 400 | Train Loss 0.341713 | Val Loss 0.382327
# Epoch 500 | Train Loss 0.340464 | Val Loss 0.380643
# Epoch 600 | Train Loss 0.339474 | Val Loss 0.380275
# Epoch 700 | Train Loss 0.337817 | Val Loss 0.380900
# Epoch 800 | Train Loss 0.349210 | Val Loss 0.387560
# Early stopping at epoch 881
# X | train1 -> R² = 0.6261, MSE = 4.0321e-02
# X | train2 -> R² = -4.7565, MSE = 4.8504e-01
# X | test1 -> R² = 0.6833, MSE = 3.3180e-02
# X | test2 -> R² = -4.6115, MSE = 4.6179e-01
# X | test3 -> R² = 0.5509, MSE = 4.1317e-02
# X | val -> R² = 0.9154, MSE = 8.0909e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=0 salvo.
# Epoch 0 | Train Loss 0.594369 | Val Loss 0.506776
# Epoch 100 | Train Loss 0.350254 | Val Loss 0.415176
# Epoch 200 | Train Loss 0.344927 | Val Loss 0.389999
# Epoch 300 | Train Loss 0.342951 | Val Loss 0.385077
# Epoch 400 | Train Loss 0.341306 | Val Loss 0.377689
# Epoch 500 | Train Loss 0.339979 | Val Loss 0.375899
# Epoch 600 | Train Loss 0.339114 | Val Loss 0.379751
# Epoch 700 | Train Loss 0.346746 | Val Loss 0.396806
# Early stopping at epoch 737
# X | train1 -> R² = 0.6127, MSE = 4.1762e-02
# X | train2 -> R² = -3.3225, MSE = 3.6421e-01
# X | test1 -> R² = 0.6507, MSE = 3.6596e-02
# X | test2 -> R² = -3.1860, MSE = 3.4448e-01
# X | test3 -> R² = 0.7822, MSE = 2.0038e-02
# X | val -> R² = 0.9591, MSE = 3.9148e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=1 salvo.
# Epoch 0 | Train Loss 0.618303 | Val Loss 0.541437
# Epoch 100 | Train Loss 0.351496 | Val Loss 0.416229
# Epoch 200 | Train Loss 0.347431 | Val Loss 0.392255
# Epoch 300 | Train Loss 0.343902 | Val Loss 0.390532
# Epoch 400 | Train Loss 0.342624 | Val Loss 0.385446
# Epoch 500 | Train Loss 0.341036 | Val Loss 0.378879
# Epoch 600 | Train Loss 0.339547 | Val Loss 0.379016
# Epoch 700 | Train Loss 0.338166 | Val Loss 0.380608
# Epoch 800 | Train Loss 0.336493 | Val Loss 0.381436
# Early stopping at epoch 867
# X | train1 -> R² = 0.6455, MSE = 3.8229e-02
# X | train2 -> R² = -2.5093, MSE = 2.9570e-01
# X | test1 -> R² = 0.6997, MSE = 3.1459e-02
# X | test2 -> R² = -2.3311, MSE = 2.7413e-01
# X | test3 -> R² = 0.6481, MSE = 3.2380e-02
# X | val -> R² = 0.9086, MSE = 8.7371e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=2 salvo.
# Epoch 0 | Train Loss 0.621906 | Val Loss 0.527890
# Epoch 100 | Train Loss 0.352698 | Val Loss 0.420162
# Epoch 200 | Train Loss 0.346606 | Val Loss 0.393507
# Epoch 300 | Train Loss 0.345920 | Val Loss 0.386103
# Epoch 400 | Train Loss 0.358409 | Val Loss 0.388590
# Epoch 500 | Train Loss 0.341543 | Val Loss 0.377443
# Epoch 600 | Train Loss 0.340426 | Val Loss 0.377692
# Epoch 700 | Train Loss 0.342438 | Val Loss 0.385148
# Epoch 800 | Train Loss 0.337904 | Val Loss 0.384015
# Early stopping at epoch 844
# X | train1 -> R² = 0.6281, MSE = 4.0101e-02
# X | train2 -> R² = -2.1024, MSE = 2.6141e-01
# X | test1 -> R² = 0.6693, MSE = 3.4640e-02
# X | test2 -> R² = -1.9355, MSE = 2.4157e-01
# X | test3 -> R² = 0.7734, MSE = 2.0848e-02
# X | val -> R² = 0.8739, MSE = 1.2056e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=3 salvo.
# Epoch 0 | Train Loss 0.605759 | Val Loss 0.566973
# Epoch 100 | Train Loss 0.349425 | Val Loss 0.406992
# Epoch 200 | Train Loss 0.354012 | Val Loss 0.390485
# Epoch 300 | Train Loss 0.343608 | Val Loss 0.384842
# Epoch 400 | Train Loss 0.342238 | Val Loss 0.380721
# Epoch 500 | Train Loss 0.340719 | Val Loss 0.376217
# Epoch 600 | Train Loss 0.339151 | Val Loss 0.376225
# Epoch 700 | Train Loss 0.338286 | Val Loss 0.379539
# Epoch 800 | Train Loss 0.335778 | Val Loss 0.382257
# Early stopping at epoch 827
# X | train1 -> R² = 0.6527, MSE = 3.7448e-02
# X | train2 -> R² = -2.1611, MSE = 2.6635e-01
# X | test1 -> R² = 0.6672, MSE = 3.4860e-02
# X | test2 -> R² = -2.0399, MSE = 2.5016e-01
# X | test3 -> R² = 0.4933, MSE = 4.6614e-02
# X | val -> R² = 0.9209, MSE = 7.5686e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.5 seed=4 salvo.
# Epoch 0 | Train Loss 0.609598 | Val Loss 0.507658
# Epoch 100 | Train Loss 0.351470 | Val Loss 0.415653
# Epoch 200 | Train Loss 0.346487 | Val Loss 0.393750
# Epoch 300 | Train Loss 0.344333 | Val Loss 0.391109
# Epoch 400 | Train Loss 0.343964 | Val Loss 0.388320
# Epoch 500 | Train Loss 0.341335 | Val Loss 0.381971
# Epoch 600 | Train Loss 0.348321 | Val Loss 0.383790
# Epoch 700 | Train Loss 0.344359 | Val Loss 0.384936
# Epoch 800 | Train Loss 0.337051 | Val Loss 0.384126
# Epoch 900 | Train Loss 0.335488 | Val Loss 0.387042
# Early stopping at epoch 902
# X | train1 -> R² = 0.5678, MSE = 4.6600e-02
# X | train2 -> R² = -5.7886, MSE = 5.7201e-01
# X | test1 -> R² = 0.6453, MSE = 3.7161e-02
# X | test2 -> R² = -5.6376, MSE = 5.4623e-01
# X | test3 -> R² = 0.6396, MSE = 3.3161e-02
# X | val -> R² = 0.8825, MSE = 1.1237e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=0 salvo.
# Epoch 0 | Train Loss 0.608562 | Val Loss 0.534094
# Epoch 100 | Train Loss 0.349654 | Val Loss 0.410273
# Epoch 200 | Train Loss 0.344709 | Val Loss 0.391776
# Epoch 300 | Train Loss 0.343268 | Val Loss 0.388656
# Epoch 400 | Train Loss 0.342193 | Val Loss 0.385841
# Epoch 500 | Train Loss 0.344191 | Val Loss 0.385297
# Epoch 600 | Train Loss 0.340105 | Val Loss 0.377765
# Epoch 700 | Train Loss 0.338277 | Val Loss 0.380390
# Epoch 800 | Train Loss 0.336963 | Val Loss 0.382449
# Early stopping at epoch 900
# X | train1 -> R² = 0.6059, MSE = 4.2492e-02
# X | train2 -> R² = -3.1958, MSE = 3.5354e-01
# X | test1 -> R² = 0.6474, MSE = 3.6939e-02
# X | test2 -> R² = -3.0817, MSE = 3.3590e-01
# X | test3 -> R² = 0.5252, MSE = 4.3680e-02
# X | val -> R² = 0.8861, MSE = 1.0893e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1 salvo.
# Epoch 0 | Train Loss 0.602886 | Val Loss 0.518028
# Epoch 100 | Train Loss 0.349298 | Val Loss 0.407067
# Epoch 200 | Train Loss 0.345202 | Val Loss 0.387503
# Epoch 300 | Train Loss 0.343403 | Val Loss 0.387848
# Epoch 400 | Train Loss 0.342194 | Val Loss 0.382947
# Epoch 500 | Train Loss 0.340827 | Val Loss 0.379041
# Epoch 600 | Train Loss 0.339162 | Val Loss 0.377893
# Epoch 700 | Train Loss 0.337760 | Val Loss 0.379669
# Epoch 800 | Train Loss 0.335935 | Val Loss 0.381955
# Early stopping at epoch 860
# X | train1 -> R² = 0.6502, MSE = 3.7713e-02
# X | train2 -> R² = -2.4255, MSE = 2.8863e-01
# X | test1 -> R² = 0.6862, MSE = 3.2869e-02
# X | test2 -> R² = -2.2300, MSE = 2.6581e-01
# X | test3 -> R² = 0.4640, MSE = 4.9310e-02
# X | val -> R² = 0.9440, MSE = 5.3580e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2 salvo.
# Epoch 0 | Train Loss 0.624439 | Val Loss 0.527754
# Epoch 100 | Train Loss 0.352398 | Val Loss 0.417990
# Epoch 200 | Train Loss 0.345146 | Val Loss 0.395184
# Epoch 300 | Train Loss 0.345548 | Val Loss 0.399423
# Epoch 400 | Train Loss 0.342715 | Val Loss 0.386916
# Epoch 500 | Train Loss 0.341152 | Val Loss 0.382998
# Epoch 600 | Train Loss 0.339250 | Val Loss 0.381989
# Epoch 700 | Train Loss 0.338268 | Val Loss 0.381907
# Epoch 800 | Train Loss 0.336141 | Val Loss 0.383079
# Early stopping at epoch 882
# X | train1 -> R² = 0.5814, MSE = 4.5131e-02
# X | train2 -> R² = -4.1115, MSE = 4.3070e-01
# X | test1 -> R² = 0.6538, MSE = 3.6267e-02
# X | test2 -> R² = -3.9470, MSE = 4.0711e-01
# X | test3 -> R² = 0.2792, MSE = 6.6319e-02
# X | val -> R² = 0.8946, MSE = 1.0082e-02
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3 salvo.
# Epoch 0 | Train Loss 0.621214 | Val Loss 0.590028
# Epoch 100 | Train Loss 0.349373 | Val Loss 0.405611
# Epoch 200 | Train Loss 0.346440 | Val Loss 0.394944
# Epoch 300 | Train Loss 0.343084 | Val Loss 0.388597
# Epoch 400 | Train Loss 0.341468 | Val Loss 0.385014
# Epoch 500 | Train Loss 0.348927 | Val Loss 0.384068
# Epoch 600 | Train Loss 0.338706 | Val Loss 0.381929
# Epoch 700 | Train Loss 0.337522 | Val Loss 0.381537
# Epoch 800 | Train Loss 0.335721 | Val Loss 0.382714
# Epoch 900 | Train Loss 0.343889 | Val Loss 0.390418
# Early stopping at epoch 938
# X | train1 -> R² = 0.6829, MSE = 3.4190e-02
# X | train2 -> R² = -5.3388, MSE = 5.3411e-01
# X | test1 -> R² = 0.7332, MSE = 2.7955e-02
# X | test2 -> R² = -5.0832, MSE = 5.0061e-01
# X | test3 -> R² = 0.3067, MSE = 6.3787e-02
# X | val -> R² = 0.9105, MSE = 8.5621e-03
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4 salvo.
