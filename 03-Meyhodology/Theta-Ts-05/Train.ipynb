# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 5
TS = 0.07

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 1)
# Dimensão da entrada: (1266, 5, 4)
# Dimensão da saida: (1266, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1947, 5, 4)
# Dimensão da saida: (1947, 1)
# Dimensão da entrada fisica : (1947,)
# Dimensão da entrada fisica: (1947,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# Epoch 0 | Train Loss 0.986128 | Val Loss 0.823098
# Epoch 100 | Train Loss 0.818114 | Val Loss 0.559467
# Epoch 200 | Train Loss 0.725318 | Val Loss 0.593476
# Early stopping at epoch 288
# Modelo salvo em:
# models/model_arch16_r0.01_seed5288.keras
# weights/model_arch16_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7705, MSE = 5.2328e-02
# Theta | Train_2 -> R² = 0.4865, MSE = 1.1683e-01
# Theta | Test_1 -> R² = 0.6594, MSE = 7.8183e-02
# Theta | Test_2 -> R² = 0.8545, MSE = 3.4378e-02
# Theta | Test_3 -> R² = 0.5724, MSE = 1.4045e-01
# Theta | Val -> R² = -0.0887, MSE = 3.5583e-01
# Theta | LSG_1 -> R² = 0.6795, MSE = 1.3273e-01
# Theta | LSG_2 -> R² = 0.2100, MSE = 2.7365e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 0.982699 | Val Loss 0.830580
# Epoch 100 | Train Loss 0.808282 | Val Loss 0.551160
# Epoch 200 | Train Loss 0.719258 | Val Loss 0.566446
# Early stopping at epoch 293
# Modelo salvo em:
# models/model_arch16_r0.01_seed3859.keras
# weights/model_arch16_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7776, MSE = 5.0729e-02
# Theta | Train_2 -> R² = 0.5067, MSE = 1.1222e-01
# Theta | Test_1 -> R² = 0.5757, MSE = 9.7397e-02
# Theta | Test_2 -> R² = 0.8688, MSE = 3.1020e-02
# Theta | Test_3 -> R² = 0.6774, MSE = 1.0595e-01
# Theta | Val -> R² = -2.2979, MSE = 1.0779e+00
# Theta | LSG_1 -> R² = 0.7192, MSE = 1.1630e-01
# Theta | LSG_2 -> R² = -1.0202, MSE = 6.9975e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.991744 | Val Loss 0.813145
# Epoch 100 | Train Loss 0.835667 | Val Loss 0.563635
# Epoch 200 | Train Loss 0.739094 | Val Loss 0.552127
# Epoch 300 | Train Loss 0.707763 | Val Loss 0.558663
# Early stopping at epoch 371
# Modelo salvo em:
# models/model_arch16_r0.01_seed9517.keras
# weights/model_arch16_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.8138, MSE = 4.2474e-02
# Theta | Train_2 -> R² = 0.6327, MSE = 8.3565e-02
# Theta | Test_1 -> R² = 0.6934, MSE = 7.0382e-02
# Theta | Test_2 -> R² = 0.8779, MSE = 2.8851e-02
# Theta | Test_3 -> R² = 0.5708, MSE = 1.4095e-01
# Theta | Val -> R² = -0.5884, MSE = 5.1916e-01
# Theta | LSG_1 -> R² = 0.7299, MSE = 1.1187e-01
# Theta | LSG_2 -> R² = -1.1923, MSE = 7.5937e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 0.987185 | Val Loss 0.838390
# Epoch 100 | Train Loss 0.774341 | Val Loss 0.564655
# Epoch 200 | Train Loss 0.706793 | Val Loss 0.628568
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch16_r0.01_seed6052.keras
# weights/model_arch16_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.6943, MSE = 6.9706e-02
# Theta | Train_2 -> R² = 0.3712, MSE = 1.4305e-01
# Theta | Test_1 -> R² = 0.3528, MSE = 1.4855e-01
# Theta | Test_2 -> R² = 0.8441, MSE = 3.6845e-02
# Theta | Test_3 -> R² = 0.6049, MSE = 1.2977e-01
# Theta | Val -> R² = -3.8151, MSE = 1.5738e+00
# Theta | LSG_1 -> R² = 0.6658, MSE = 1.3838e-01
# Theta | LSG_2 -> R² = -1.2363, MSE = 7.7461e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.993418 | Val Loss 0.853782
# Epoch 100 | Train Loss 0.769242 | Val Loss 0.570887
# Epoch 200 | Train Loss 0.717538 | Val Loss 0.568362
# Early stopping at epoch 269
# Modelo salvo em:
# models/model_arch16_r0.01_seed5866.keras
# weights/model_arch16_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7037, MSE = 6.7566e-02
# Theta | Train_2 -> R² = 0.3958, MSE = 1.3747e-01
# Theta | Test_1 -> R² = 0.3033, MSE = 1.5993e-01
# Theta | Test_2 -> R² = 0.8555, MSE = 3.4146e-02
# Theta | Test_3 -> R² = 0.6131, MSE = 1.2708e-01
# Theta | Val -> R² = -3.6335, MSE = 1.5145e+00
# Theta | LSG_1 -> R² = 0.7001, MSE = 1.2419e-01
# Theta | LSG_2 -> R² = -1.2292, MSE = 7.7214e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 0.969286 | Val Loss 0.804271
# Epoch 100 | Train Loss 0.779208 | Val Loss 0.562680
# Epoch 200 | Train Loss 0.705003 | Val Loss 0.586705
# Early stopping at epoch 286
# Modelo salvo em:
# models/model_arch16_r0.9_seed5288.keras
# weights/model_arch16_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7401, MSE = 5.9271e-02
# Theta | Train_2 -> R² = 0.4640, MSE = 1.2194e-01
# Theta | Test_1 -> R² = 0.4882, MSE = 1.1749e-01
# Theta | Test_2 -> R² = 0.8609, MSE = 3.2868e-02
# Theta | Test_3 -> R² = 0.6768, MSE = 1.0616e-01
# Theta | Val -> R² = -1.5782, MSE = 8.4269e-01
# Theta | LSG_1 -> R² = 0.7227, MSE = 1.1484e-01
# Theta | LSG_2 -> R² = -1.0754, MSE = 7.1887e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.974011 | Val Loss 0.817546
# Epoch 100 | Train Loss 0.777168 | Val Loss 0.557310
# Epoch 200 | Train Loss 0.719162 | Val Loss 0.578414
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch16_r0.9_seed3859.keras
# weights/model_arch16_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7344, MSE = 6.0566e-02
# Theta | Train_2 -> R² = 0.4924, MSE = 1.1547e-01
# Theta | Test_1 -> R² = 0.5134, MSE = 1.1170e-01
# Theta | Test_2 -> R² = 0.8576, MSE = 3.3651e-02
# Theta | Test_3 -> R² = 0.4670, MSE = 1.7504e-01
# Theta | Val -> R² = -3.0462, MSE = 1.3225e+00
# Theta | LSG_1 -> R² = 0.7139, MSE = 1.1847e-01
# Theta | LSG_2 -> R² = -1.3512, MSE = 8.1441e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 0.980863 | Val Loss 0.818538
# Epoch 100 | Train Loss 0.804320 | Val Loss 0.583277
# Epoch 200 | Train Loss 0.716934 | Val Loss 0.580932
# Early stopping at epoch 269
# Modelo salvo em:
# models/model_arch16_r0.9_seed9517.keras
# weights/model_arch16_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7712, MSE = 5.2179e-02
# Theta | Train_2 -> R² = 0.4517, MSE = 1.2474e-01
# Theta | Test_1 -> R² = 0.6101, MSE = 8.9500e-02
# Theta | Test_2 -> R² = 0.8348, MSE = 3.9043e-02
# Theta | Test_3 -> R² = 0.6808, MSE = 1.0483e-01
# Theta | Val -> R² = -1.8360, MSE = 9.2695e-01
# Theta | LSG_1 -> R² = 0.7217, MSE = 1.1526e-01
# Theta | LSG_2 -> R² = -0.6075, MSE = 5.5680e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 0.991570 | Val Loss 0.831667
# Epoch 100 | Train Loss 0.817996 | Val Loss 0.555136
# Epoch 200 | Train Loss 0.724653 | Val Loss 0.573673
# Early stopping at epoch 298
# Modelo salvo em:
# models/model_arch16_r0.9_seed6052.keras
# weights/model_arch16_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7583, MSE = 5.5125e-02
# Theta | Train_2 -> R² = 0.5081, MSE = 1.1192e-01
# Theta | Test_1 -> R² = 0.5101, MSE = 1.1245e-01
# Theta | Test_2 -> R² = 0.8667, MSE = 3.1503e-02
# Theta | Test_3 -> R² = 0.6246, MSE = 1.2327e-01
# Theta | Val -> R² = -3.1010, MSE = 1.3404e+00
# Theta | LSG_1 -> R² = 0.7340, MSE = 1.1017e-01
# Theta | LSG_2 -> R² = -0.8220, MSE = 6.3110e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.991137 | Val Loss 0.842423
# Epoch 100 | Train Loss 0.810311 | Val Loss 0.544484
# Epoch 200 | Train Loss 0.723009 | Val Loss 0.580082
# Early stopping at epoch 300
# Modelo salvo em:
# models/model_arch16_r0.9_seed5866.keras
# weights/model_arch16_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7474, MSE = 5.7597e-02
# Theta | Train_2 -> R² = 0.5873, MSE = 9.3900e-02
# Theta | Test_1 -> R² = 0.5186, MSE = 1.1051e-01
# Theta | Test_2 -> R² = 0.8756, MSE = 2.9412e-02
# Theta | Test_3 -> R² = 0.4838, MSE = 1.6954e-01
# Theta | Val -> R² = -4.3530, MSE = 1.7496e+00
# Theta | LSG_1 -> R² = 0.5649, MSE = 1.8019e-01
# Theta | LSG_2 -> R² = -1.9314, MSE = 1.0154e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 0.972493 | Val Loss 0.824287
# Epoch 100 | Train Loss 0.749124 | Val Loss 0.568328
# Epoch 200 | Train Loss 0.726566 | Val Loss 0.611644
# Early stopping at epoch 256
# Modelo salvo em:
# models/model_arch16_r0.01_seed5288.keras
# weights/model_arch16_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.6565, MSE = 7.8340e-02
# Theta | Train_2 -> R² = 0.3861, MSE = 1.3967e-01
# Theta | Test_1 -> R² = 0.0574, MSE = 2.1637e-01
# Theta | Test_2 -> R² = 0.8416, MSE = 3.7435e-02
# Theta | Test_3 -> R² = 0.4319, MSE = 1.8659e-01
# Theta | Val -> R² = -7.1915, MSE = 2.6774e+00
# Theta | LSG_1 -> R² = 0.3350, MSE = 2.7542e-01
# Theta | LSG_2 -> R² = -2.8112, MSE = 1.3201e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 0.970643 | Val Loss 0.819973
# Epoch 100 | Train Loss 0.752351 | Val Loss 0.562573
# Epoch 200 | Train Loss 0.739918 | Val Loss 0.581744
# Early stopping at epoch 274
# Modelo salvo em:
# models/model_arch16_r0.01_seed3859.keras
# weights/model_arch16_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7714, MSE = 5.2122e-02
# Theta | Train_2 -> R² = 0.6092, MSE = 8.8903e-02
# Theta | Test_1 -> R² = 0.2476, MSE = 1.7271e-01
# Theta | Test_2 -> R² = 0.8412, MSE = 3.7527e-02
# Theta | Test_3 -> R² = 0.6132, MSE = 1.2703e-01
# Theta | Val -> R² = -6.1102, MSE = 2.3240e+00
# Theta | LSG_1 -> R² = 0.2462, MSE = 3.1218e-01
# Theta | LSG_2 -> R² = -3.5333, MSE = 1.5703e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.986112 | Val Loss 0.826728
# Epoch 100 | Train Loss 0.752287 | Val Loss 0.567382
# Epoch 200 | Train Loss 0.734894 | Val Loss 0.596247
# Early stopping at epoch 252
# Modelo salvo em:
# models/model_arch16_r0.01_seed9517.keras
# weights/model_arch16_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.6759, MSE = 7.3916e-02
# Theta | Train_2 -> R² = 0.3321, MSE = 1.5196e-01
# Theta | Test_1 -> R² = 0.1136, MSE = 2.0348e-01
# Theta | Test_2 -> R² = 0.8424, MSE = 3.7242e-02
# Theta | Test_3 -> R² = 0.5054, MSE = 1.6244e-01
# Theta | Val -> R² = -6.7235, MSE = 2.5244e+00
# Theta | LSG_1 -> R² = 0.4424, MSE = 2.3092e-01
# Theta | LSG_2 -> R² = -2.3989, MSE = 1.1773e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 0.973149 | Val Loss 0.809062
# Epoch 100 | Train Loss 0.751699 | Val Loss 0.563162
# Epoch 200 | Train Loss 0.739009 | Val Loss 0.581375
# Early stopping at epoch 277
# Modelo salvo em:
# models/model_arch16_r0.01_seed6052.keras
# weights/model_arch16_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7672, MSE = 5.3098e-02
# Theta | Train_2 -> R² = 0.7246, MSE = 6.2662e-02
# Theta | Test_1 -> R² = 0.2784, MSE = 1.6564e-01
# Theta | Test_2 -> R² = 0.8127, MSE = 4.4259e-02
# Theta | Test_3 -> R² = 0.2842, MSE = 2.3507e-01
# Theta | Val -> R² = -7.0760, MSE = 2.6396e+00
# Theta | LSG_1 -> R² = 0.1355, MSE = 3.5803e-01
# Theta | LSG_2 -> R² = -4.2351, MSE = 1.8133e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.974023 | Val Loss 0.822848
# Epoch 100 | Train Loss 0.749765 | Val Loss 0.568697
# Epoch 200 | Train Loss 0.732596 | Val Loss 0.600078
# Early stopping at epoch 280
# Modelo salvo em:
# models/model_arch16_r0.01_seed5866.keras
# weights/model_arch16_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7420, MSE = 5.8828e-02
# Theta | Train_2 -> R² = 0.6699, MSE = 7.5096e-02
# Theta | Test_1 -> R² = 0.1626, MSE = 1.9223e-01
# Theta | Test_2 -> R² = 0.8258, MSE = 4.1171e-02
# Theta | Test_3 -> R² = 0.4549, MSE = 1.7903e-01
# Theta | Val -> R² = -7.6921, MSE = 2.8410e+00
# Theta | LSG_1 -> R² = -0.0650, MSE = 4.4106e-01
# Theta | LSG_2 -> R² = -4.7251, MSE = 1.9831e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 0.978952 | Val Loss 0.836371
# Epoch 100 | Train Loss 0.751248 | Val Loss 0.566747
# Epoch 200 | Train Loss 0.738730 | Val Loss 0.596336
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch16_r0.9_seed5288.keras
# weights/model_arch16_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7395, MSE = 5.9405e-02
# Theta | Train_2 -> R² = 0.6414, MSE = 8.1586e-02
# Theta | Test_1 -> R² = 0.1811, MSE = 1.8798e-01
# Theta | Test_2 -> R² = 0.8369, MSE = 3.8554e-02
# Theta | Test_3 -> R² = 0.3974, MSE = 1.9791e-01
# Theta | Val -> R² = -7.7731, MSE = 2.8675e+00
# Theta | LSG_1 -> R² = -0.0769, MSE = 4.4596e-01
# Theta | LSG_2 -> R² = -4.5692, MSE = 1.9291e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.958784 | Val Loss 0.808538
# Epoch 100 | Train Loss 0.748172 | Val Loss 0.574248
# Epoch 200 | Train Loss 0.734925 | Val Loss 0.603354
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch16_r0.9_seed3859.keras
# weights/model_arch16_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7596, MSE = 5.4816e-02
# Theta | Train_2 -> R² = 0.7012, MSE = 6.7979e-02
# Theta | Test_1 -> R² = 0.2767, MSE = 1.6604e-01
# Theta | Test_2 -> R² = 0.8242, MSE = 4.1544e-02
# Theta | Test_3 -> R² = 0.4181, MSE = 1.9112e-01
# Theta | Val -> R² = -7.1055, MSE = 2.6493e+00
# Theta | LSG_1 -> R² = -0.0742, MSE = 4.4487e-01
# Theta | LSG_2 -> R² = -4.5699, MSE = 1.9293e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 0.960975 | Val Loss 0.802287
# Epoch 100 | Train Loss 0.750321 | Val Loss 0.568099
# Epoch 200 | Train Loss 0.737820 | Val Loss 0.598390
# Early stopping at epoch 276
# Modelo salvo em:
# models/model_arch16_r0.9_seed9517.keras
# weights/model_arch16_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7756, MSE = 5.1166e-02
# Theta | Train_2 -> R² = 0.6941, MSE = 6.9598e-02
# Theta | Test_1 -> R² = 0.3833, MSE = 1.4157e-01
# Theta | Test_2 -> R² = 0.8357, MSE = 3.8842e-02
# Theta | Test_3 -> R² = 0.3581, MSE = 2.1080e-01
# Theta | Val -> R² = -6.5135, MSE = 2.4558e+00
# Theta | LSG_1 -> R² = 0.0959, MSE = 3.7443e-01
# Theta | LSG_2 -> R² = -3.8551, MSE = 1.6817e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 0.985606 | Val Loss 0.841066
# Epoch 100 | Train Loss 0.748921 | Val Loss 0.567792
# Epoch 200 | Train Loss 0.737408 | Val Loss 0.595352
# Early stopping at epoch 283
# Modelo salvo em:
# models/model_arch16_r0.9_seed6052.keras
# weights/model_arch16_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.8174, MSE = 4.1645e-02
# Theta | Train_2 -> R² = 0.7112, MSE = 6.5707e-02
# Theta | Test_1 -> R² = 0.4474, MSE = 1.2685e-01
# Theta | Test_2 -> R² = 0.8288, MSE = 4.0452e-02
# Theta | Test_3 -> R² = 0.3972, MSE = 1.9797e-01
# Theta | Val -> R² = -6.4367, MSE = 2.4307e+00
# Theta | LSG_1 -> R² = 0.1372, MSE = 3.5730e-01
# Theta | LSG_2 -> R² = -3.9931, MSE = 1.7295e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.977541 | Val Loss 0.814179
# Epoch 100 | Train Loss 0.753478 | Val Loss 0.567557
# Epoch 200 | Train Loss 0.734207 | Val Loss 0.582779
# Early stopping at epoch 252
# Modelo salvo em:
# models/model_arch16_r0.9_seed5866.keras
# weights/model_arch16_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.6719, MSE = 7.4823e-02
# Theta | Train_2 -> R² = 0.3804, MSE = 1.4098e-01
# Theta | Test_1 -> R² = 0.0069, MSE = 2.2797e-01
# Theta | Test_2 -> R² = 0.8496, MSE = 3.5545e-02
# Theta | Test_3 -> R² = 0.6106, MSE = 1.2789e-01
# Theta | Val -> R² = -5.9153, MSE = 2.2603e+00
# Theta | LSG_1 -> R² = 0.3058, MSE = 2.8750e-01
# Theta | LSG_2 -> R² = -2.9658, MSE = 1.3737e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 1.005473 | Val Loss 0.847775
# Epoch 100 | Train Loss 0.744565 | Val Loss 0.569493
# Epoch 200 | Train Loss 0.696921 | Val Loss 0.564310
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch32_r0.01_seed5288.keras
# weights/model_arch32_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7608, MSE = 5.4541e-02
# Theta | Train_2 -> R² = 0.5720, MSE = 9.7384e-02
# Theta | Test_1 -> R² = 0.4556, MSE = 1.2496e-01
# Theta | Test_2 -> R² = 0.8820, MSE = 2.7884e-02
# Theta | Test_3 -> R² = 0.6732, MSE = 1.0732e-01
# Theta | Val -> R² = -2.9597, MSE = 1.2942e+00
# Theta | LSG_1 -> R² = 0.6208, MSE = 1.5704e-01
# Theta | LSG_2 -> R² = -1.9284, MSE = 1.0143e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 0.985717 | Val Loss 0.789079
# Epoch 100 | Train Loss 0.733876 | Val Loss 0.569708
# Epoch 200 | Train Loss 0.695450 | Val Loss 0.554804
# Epoch 300 | Train Loss 0.657076 | Val Loss 0.638547
# Early stopping at epoch 398
# Modelo salvo em:
# models/model_arch32_r0.01_seed3859.keras
# weights/model_arch32_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.8614, MSE = 3.1610e-02
# Theta | Train_2 -> R² = 0.7790, MSE = 5.0276e-02
# Theta | Test_1 -> R² = 0.7517, MSE = 5.7007e-02
# Theta | Test_2 -> R² = 0.8737, MSE = 2.9861e-02
# Theta | Test_3 -> R² = 0.5169, MSE = 1.5868e-01
# Theta | Val -> R² = -1.4468, MSE = 7.9975e-01
# Theta | LSG_1 -> R² = 0.7044, MSE = 1.2243e-01
# Theta | LSG_2 -> R² = -2.7121, MSE = 1.2858e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.992118 | Val Loss 0.834145
# Epoch 100 | Train Loss 0.721927 | Val Loss 0.566209
# Epoch 200 | Train Loss 0.689787 | Val Loss 0.576448
# Early stopping at epoch 241
# Modelo salvo em:
# models/model_arch32_r0.01_seed9517.keras
# weights/model_arch32_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.6975, MSE = 6.8986e-02
# Theta | Train_2 -> R² = 0.5709, MSE = 9.7616e-02
# Theta | Test_1 -> R² = 0.1772, MSE = 1.8888e-01
# Theta | Test_2 -> R² = 0.8747, MSE = 2.9624e-02
# Theta | Test_3 -> R² = 0.4609, MSE = 1.7707e-01
# Theta | Val -> R² = -5.9622, MSE = 2.2756e+00
# Theta | LSG_1 -> R² = 0.3181, MSE = 2.8241e-01
# Theta | LSG_2 -> R² = -3.2521, MSE = 1.4729e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 0.974374 | Val Loss 0.752502
# Epoch 100 | Train Loss 0.723695 | Val Loss 0.576672
# Epoch 200 | Train Loss 0.687603 | Val Loss 0.563946
# Early stopping at epoch 254
# Modelo salvo em:
# models/model_arch32_r0.01_seed6052.keras
# weights/model_arch32_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7624, MSE = 5.4180e-02
# Theta | Train_2 -> R² = 0.5696, MSE = 9.7928e-02
# Theta | Test_1 -> R² = 0.4158, MSE = 1.3411e-01
# Theta | Test_2 -> R² = 0.8601, MSE = 3.3059e-02
# Theta | Test_3 -> R² = 0.6858, MSE = 1.0320e-01
# Theta | Val -> R² = -4.9834, MSE = 1.9557e+00
# Theta | LSG_1 -> R² = 0.0994, MSE = 3.7297e-01
# Theta | LSG_2 -> R² = -3.6338, MSE = 1.6051e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.979081 | Val Loss 0.806627
# Epoch 100 | Train Loss 0.727326 | Val Loss 0.562398
# Epoch 200 | Train Loss 0.695101 | Val Loss 0.584030
# Early stopping at epoch 241
# Modelo salvo em:
# models/model_arch32_r0.01_seed5866.keras
# weights/model_arch32_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7422, MSE = 5.8795e-02
# Theta | Train_2 -> R² = 0.5860, MSE = 9.4188e-02
# Theta | Test_1 -> R² = 0.3537, MSE = 1.4835e-01
# Theta | Test_2 -> R² = 0.8868, MSE = 2.6758e-02
# Theta | Test_3 -> R² = 0.4967, MSE = 1.6530e-01
# Theta | Val -> R² = -5.4562, MSE = 2.1102e+00
# Theta | LSG_1 -> R² = 0.3547, MSE = 2.6724e-01
# Theta | LSG_2 -> R² = -2.9501, MSE = 1.3683e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 1.029951 | Val Loss 0.918319
# Epoch 100 | Train Loss 0.738719 | Val Loss 0.565871
# Epoch 200 | Train Loss 0.692549 | Val Loss 0.577871
# Early stopping at epoch 251
# Modelo salvo em:
# models/model_arch32_r0.9_seed5288.keras
# weights/model_arch32_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7120, MSE = 6.5681e-02
# Theta | Train_2 -> R² = 0.5679, MSE = 9.8306e-02
# Theta | Test_1 -> R² = 0.2526, MSE = 1.7155e-01
# Theta | Test_2 -> R² = 0.8834, MSE = 2.7553e-02
# Theta | Test_3 -> R² = 0.5519, MSE = 1.4718e-01
# Theta | Val -> R² = -4.9917, MSE = 1.9584e+00
# Theta | LSG_1 -> R² = 0.4018, MSE = 2.4771e-01
# Theta | LSG_2 -> R² = -2.8871, MSE = 1.3464e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.974661 | Val Loss 0.774727
# Epoch 100 | Train Loss 0.735698 | Val Loss 0.573181
# Epoch 200 | Train Loss 0.677569 | Val Loss 0.597693
# Early stopping at epoch 261
# Modelo salvo em:
# models/model_arch32_r0.9_seed3859.keras
# weights/model_arch32_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7922, MSE = 4.7393e-02
# Theta | Train_2 -> R² = 0.6474, MSE = 8.0228e-02
# Theta | Test_1 -> R² = 0.4163, MSE = 1.3399e-01
# Theta | Test_2 -> R² = 0.8696, MSE = 3.0829e-02
# Theta | Test_3 -> R² = 0.6457, MSE = 1.1636e-01
# Theta | Val -> R² = -5.0157, MSE = 1.9662e+00
# Theta | LSG_1 -> R² = 0.1923, MSE = 3.3448e-01
# Theta | LSG_2 -> R² = -3.7418, MSE = 1.6425e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 0.984149 | Val Loss 0.781887
# Epoch 100 | Train Loss 0.744725 | Val Loss 0.560645
# Epoch 200 | Train Loss 0.700256 | Val Loss 0.561899
# Early stopping at epoch 241
# Modelo salvo em:
# models/model_arch32_r0.9_seed9517.keras
# weights/model_arch32_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7474, MSE = 5.7602e-02
# Theta | Train_2 -> R² = 0.5758, MSE = 9.6519e-02
# Theta | Test_1 -> R² = 0.3700, MSE = 1.4461e-01
# Theta | Test_2 -> R² = 0.8866, MSE = 2.6810e-02
# Theta | Test_3 -> R² = 0.6325, MSE = 1.2068e-01
# Theta | Val -> R² = -4.3860, MSE = 1.7604e+00
# Theta | LSG_1 -> R² = 0.4039, MSE = 2.4686e-01
# Theta | LSG_2 -> R² = -2.6561, MSE = 1.2664e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 1.007129 | Val Loss 0.749278
# Epoch 100 | Train Loss 0.732142 | Val Loss 0.588403
# Epoch 200 | Train Loss 0.700788 | Val Loss 0.592420
# Early stopping at epoch 255
# Modelo salvo em:
# models/model_arch32_r0.9_seed6052.keras
# weights/model_arch32_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7710, MSE = 5.2227e-02
# Theta | Train_2 -> R² = 0.5932, MSE = 9.2551e-02
# Theta | Test_1 -> R² = 0.5076, MSE = 1.1304e-01
# Theta | Test_2 -> R² = 0.8725, MSE = 3.0125e-02
# Theta | Test_3 -> R² = 0.4815, MSE = 1.7028e-01
# Theta | Val -> R² = -5.6967, MSE = 2.1888e+00
# Theta | LSG_1 -> R² = 0.2355, MSE = 3.1658e-01
# Theta | LSG_2 -> R² = -3.3908, MSE = 1.5209e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 1.028962 | Val Loss 0.873925
# Epoch 100 | Train Loss 0.759138 | Val Loss 0.567233
# Epoch 200 | Train Loss 0.701719 | Val Loss 0.571077
# Early stopping at epoch 273
# Modelo salvo em:
# models/model_arch32_r0.9_seed5866.keras
# weights/model_arch32_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7560, MSE = 5.5637e-02
# Theta | Train_2 -> R² = 0.5294, MSE = 1.0707e-01
# Theta | Test_1 -> R² = 0.4476, MSE = 1.2680e-01
# Theta | Test_2 -> R² = 0.8767, MSE = 2.9142e-02
# Theta | Test_3 -> R² = 0.6408, MSE = 1.1798e-01
# Theta | Val -> R² = -1.9140, MSE = 9.5244e-01
# Theta | LSG_1 -> R² = 0.6989, MSE = 1.2470e-01
# Theta | LSG_2 -> R² = -1.2398, MSE = 7.7581e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 0.972410 | Val Loss 0.812267
# Epoch 100 | Train Loss 0.745100 | Val Loss 0.583488
# Epoch 200 | Train Loss 0.719701 | Val Loss 0.607507
# Early stopping at epoch 227
# Modelo salvo em:
# models/model_arch32_r0.01_seed5288.keras
# weights/model_arch32_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.5953, MSE = 9.2283e-02
# Theta | Train_2 -> R² = 0.4809, MSE = 1.1809e-01
# Theta | Test_1 -> R² = -0.0196, MSE = 2.3405e-01
# Theta | Test_2 -> R² = 0.8560, MSE = 3.4029e-02
# Theta | Test_3 -> R² = 0.3180, MSE = 2.2398e-01
# Theta | Val -> R² = -7.7713, MSE = 2.8669e+00
# Theta | LSG_1 -> R² = 0.0060, MSE = 4.1164e-01
# Theta | LSG_2 -> R² = -4.0382, MSE = 1.7451e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 0.930479 | Val Loss 0.727032
# Epoch 100 | Train Loss 0.743716 | Val Loss 0.597642
# Epoch 200 | Train Loss 0.716958 | Val Loss 0.623828
# Early stopping at epoch 218
# Modelo salvo em:
# models/model_arch32_r0.01_seed3859.keras
# weights/model_arch32_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.8437, MSE = 3.5652e-02
# Theta | Train_2 -> R² = 0.4859, MSE = 1.1696e-01
# Theta | Test_1 -> R² = 0.6543, MSE = 7.9361e-02
# Theta | Test_2 -> R² = 0.8374, MSE = 3.8432e-02
# Theta | Test_3 -> R² = 0.3735, MSE = 2.0576e-01
# Theta | Val -> R² = -6.3070, MSE = 2.3883e+00
# Theta | LSG_1 -> R² = 0.4965, MSE = 2.0853e-01
# Theta | LSG_2 -> R² = -2.0640, MSE = 1.0613e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.982146 | Val Loss 0.804908
# Epoch 100 | Train Loss 0.746333 | Val Loss 0.588619
# Epoch 200 | Train Loss 0.722893 | Val Loss 0.610047
# Early stopping at epoch 225
# Modelo salvo em:
# models/model_arch32_r0.01_seed9517.keras
# weights/model_arch32_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.4517, MSE = 1.2504e-01
# Theta | Train_2 -> R² = 0.1921, MSE = 1.8382e-01
# Theta | Test_1 -> R² = -0.0870, MSE = 2.4951e-01
# Theta | Test_2 -> R² = 0.6431, MSE = 8.4347e-02
# Theta | Test_3 -> R² = -0.0418, MSE = 3.4216e-01
# Theta | Val -> R² = -8.5924, MSE = 3.1353e+00
# Theta | LSG_1 -> R² = 0.0864, MSE = 3.7834e-01
# Theta | LSG_2 -> R² = -3.4971, MSE = 1.5577e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 0.982813 | Val Loss 0.801749
# Epoch 100 | Train Loss 0.737061 | Val Loss 0.603840
# Epoch 200 | Train Loss 0.710626 | Val Loss 0.622824
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch32_r0.01_seed6052.keras
# weights/model_arch32_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.6255, MSE = 8.5415e-02
# Theta | Train_2 -> R² = 0.4592, MSE = 1.2304e-01
# Theta | Test_1 -> R² = 0.1357, MSE = 1.9839e-01
# Theta | Test_2 -> R² = 0.8180, MSE = 4.3009e-02
# Theta | Test_3 -> R² = -0.0243, MSE = 3.3641e-01
# Theta | Val -> R² = -9.1585, MSE = 3.3203e+00
# Theta | LSG_1 -> R² = -0.0640, MSE = 4.4063e-01
# Theta | LSG_2 -> R² = -4.2593, MSE = 1.8217e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.978490 | Val Loss 0.831688
# Epoch 100 | Train Loss 0.738346 | Val Loss 0.590858
# Epoch 200 | Train Loss 0.705478 | Val Loss 0.606082
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch32_r0.01_seed5866.keras
# weights/model_arch32_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.6410, MSE = 8.1867e-02
# Theta | Train_2 -> R² = 0.4050, MSE = 1.3538e-01
# Theta | Test_1 -> R² = 0.1154, MSE = 2.0305e-01
# Theta | Test_2 -> R² = 0.8572, MSE = 3.3752e-02
# Theta | Test_3 -> R² = 0.3434, MSE = 2.1566e-01
# Theta | Val -> R² = -6.8879, MSE = 2.5782e+00
# Theta | LSG_1 -> R² = 0.4401, MSE = 2.3188e-01
# Theta | LSG_2 -> R² = -2.5353, MSE = 1.2246e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 0.964683 | Val Loss 0.814938
# Epoch 100 | Train Loss 0.747459 | Val Loss 0.583875
# Epoch 200 | Train Loss 0.711366 | Val Loss 0.618946
# Early stopping at epoch 224
# Modelo salvo em:
# models/model_arch32_r0.9_seed5288.keras
# weights/model_arch32_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.6229, MSE = 8.5994e-02
# Theta | Train_2 -> R² = 0.4301, MSE = 1.2966e-01
# Theta | Test_1 -> R² = 0.0952, MSE = 2.0770e-01
# Theta | Test_2 -> R² = 0.8186, MSE = 4.2877e-02
# Theta | Test_3 -> R² = 0.1970, MSE = 2.6372e-01
# Theta | Val -> R² = -7.7632, MSE = 2.8643e+00
# Theta | LSG_1 -> R² = 0.0959, MSE = 3.7440e-01
# Theta | LSG_2 -> R² = -3.7620, MSE = 1.6495e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.946862 | Val Loss 0.759719
# Epoch 100 | Train Loss 0.742690 | Val Loss 0.594239
# Epoch 200 | Train Loss 0.710577 | Val Loss 0.627805
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch32_r0.9_seed3859.keras
# weights/model_arch32_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.6672, MSE = 7.5889e-02
# Theta | Train_2 -> R² = 0.3603, MSE = 1.4555e-01
# Theta | Test_1 -> R² = 0.2821, MSE = 1.6480e-01
# Theta | Test_2 -> R² = 0.7712, MSE = 5.4084e-02
# Theta | Test_3 -> R² = 0.1129, MSE = 2.9133e-01
# Theta | Val -> R² = -7.7352, MSE = 2.8551e+00
# Theta | LSG_1 -> R² = 0.2799, MSE = 2.9823e-01
# Theta | LSG_2 -> R² = -2.8714, MSE = 1.3410e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 1.025246 | Val Loss 0.880250
# Epoch 100 | Train Loss 0.745638 | Val Loss 0.579111
# Epoch 200 | Train Loss 0.693963 | Val Loss 0.638040
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch32_r0.9_seed9517.keras
# weights/model_arch32_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7744, MSE = 5.1441e-02
# Theta | Train_2 -> R² = 0.4971, MSE = 1.1442e-01
# Theta | Test_1 -> R² = 0.3978, MSE = 1.3824e-01
# Theta | Test_2 -> R² = 0.8792, MSE = 2.8562e-02
# Theta | Test_3 -> R² = 0.4741, MSE = 1.7273e-01
# Theta | Val -> R² = -6.2466, MSE = 2.3686e+00
# Theta | LSG_1 -> R² = 0.4076, MSE = 2.4534e-01
# Theta | LSG_2 -> R² = -2.6134, MSE = 1.2516e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 1.021365 | Val Loss 0.809461
# Epoch 100 | Train Loss 0.738214 | Val Loss 0.599770
# Epoch 200 | Train Loss 0.719131 | Val Loss 0.622194
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch32_r0.9_seed6052.keras
# weights/model_arch32_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.6420, MSE = 8.1635e-02
# Theta | Train_2 -> R² = 0.4838, MSE = 1.1744e-01
# Theta | Test_1 -> R² = 0.1552, MSE = 1.9392e-01
# Theta | Test_2 -> R² = 0.8226, MSE = 4.1925e-02
# Theta | Test_3 -> R² = 0.1640, MSE = 2.7456e-01
# Theta | Val -> R² = -8.4384, MSE = 3.0850e+00
# Theta | LSG_1 -> R² = -0.0289, MSE = 4.2608e-01
# Theta | LSG_2 -> R² = -4.1349, MSE = 1.7786e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 1.025018 | Val Loss 0.876777
# Epoch 100 | Train Loss 0.743900 | Val Loss 0.584808
# Epoch 200 | Train Loss 0.698317 | Val Loss 0.622743
# Early stopping at epoch 235
# Modelo salvo em:
# models/model_arch32_r0.9_seed5866.keras
# weights/model_arch32_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7212, MSE = 6.3580e-02
# Theta | Train_2 -> R² = 0.5447, MSE = 1.0358e-01
# Theta | Test_1 -> R² = 0.2763, MSE = 1.6613e-01
# Theta | Test_2 -> R² = 0.8761, MSE = 2.9288e-02
# Theta | Test_3 -> R² = 0.1833, MSE = 2.6824e-01
# Theta | Val -> R² = -7.7089, MSE = 2.8465e+00
# Theta | LSG_1 -> R² = 0.2529, MSE = 3.0939e-01
# Theta | LSG_2 -> R² = -3.3113, MSE = 1.4934e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 0.999144 | Val Loss 0.756766
# Epoch 100 | Train Loss 0.707688 | Val Loss 0.564833
# Epoch 200 | Train Loss 0.675627 | Val Loss 0.627126
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch64_r0.01_seed5288.keras
# weights/model_arch64_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7954, MSE = 4.6660e-02
# Theta | Train_2 -> R² = 0.6159, MSE = 8.7382e-02
# Theta | Test_1 -> R² = 0.5719, MSE = 9.8276e-02
# Theta | Test_2 -> R² = 0.8846, MSE = 2.7276e-02
# Theta | Test_3 -> R² = 0.6268, MSE = 1.2257e-01
# Theta | Val -> R² = -3.7485, MSE = 1.5521e+00
# Theta | LSG_1 -> R² = 0.5159, MSE = 2.0046e-01
# Theta | LSG_2 -> R² = -2.3999, MSE = 1.1777e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 0.987390 | Val Loss 0.759225
# Epoch 100 | Train Loss 0.708342 | Val Loss 0.570650
# Epoch 200 | Train Loss 0.675690 | Val Loss 0.653437
# Early stopping at epoch 235
# Modelo salvo em:
# models/model_arch64_r0.01_seed3859.keras
# weights/model_arch64_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7769, MSE = 5.0871e-02
# Theta | Train_2 -> R² = 0.6246, MSE = 8.5404e-02
# Theta | Test_1 -> R² = 0.4981, MSE = 1.1520e-01
# Theta | Test_2 -> R² = 0.8885, MSE = 2.6361e-02
# Theta | Test_3 -> R² = 0.6304, MSE = 1.2139e-01
# Theta | Val -> R² = -3.6863, MSE = 1.5317e+00
# Theta | LSG_1 -> R² = 0.4410, MSE = 2.3151e-01
# Theta | LSG_2 -> R² = -2.6932, MSE = 1.2792e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.994798 | Val Loss 0.746352
# Epoch 100 | Train Loss 0.709837 | Val Loss 0.567091
# Epoch 200 | Train Loss 0.651999 | Val Loss 0.680587
# Early stopping at epoch 238
# Modelo salvo em:
# models/model_arch64_r0.01_seed9517.keras
# weights/model_arch64_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.8020, MSE = 4.5158e-02
# Theta | Train_2 -> R² = 0.6416, MSE = 8.1530e-02
# Theta | Test_1 -> R² = 0.4761, MSE = 1.2027e-01
# Theta | Test_2 -> R² = 0.8388, MSE = 3.8109e-02
# Theta | Test_3 -> R² = 0.6387, MSE = 1.1866e-01
# Theta | Val -> R² = -2.9641, MSE = 1.2957e+00
# Theta | LSG_1 -> R² = 0.5694, MSE = 1.7834e-01
# Theta | LSG_2 -> R² = -2.4522, MSE = 1.1958e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 1.026869 | Val Loss 0.725746
# Epoch 100 | Train Loss 0.708194 | Val Loss 0.568890
# Epoch 200 | Train Loss 0.676972 | Val Loss 0.637044
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch64_r0.01_seed6052.keras
# weights/model_arch64_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7518, MSE = 5.6604e-02
# Theta | Train_2 -> R² = 0.7282, MSE = 6.1848e-02
# Theta | Test_1 -> R² = 0.3665, MSE = 1.4541e-01
# Theta | Test_2 -> R² = 0.8679, MSE = 3.1228e-02
# Theta | Test_3 -> R² = 0.2577, MSE = 2.4379e-01
# Theta | Val -> R² = -7.4091, MSE = 2.7485e+00
# Theta | LSG_1 -> R² = -0.1864, MSE = 4.9133e-01
# Theta | LSG_2 -> R² = -5.2497, MSE = 2.1648e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.997153 | Val Loss 0.812643
# Epoch 100 | Train Loss 0.704826 | Val Loss 0.568790
# Epoch 200 | Train Loss 0.648444 | Val Loss 0.733981
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch64_r0.01_seed5866.keras
# weights/model_arch64_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7174, MSE = 6.4458e-02
# Theta | Train_2 -> R² = 0.6378, MSE = 8.2409e-02
# Theta | Test_1 -> R² = 0.2770, MSE = 1.6595e-01
# Theta | Test_2 -> R² = 0.8679, MSE = 3.1225e-02
# Theta | Test_3 -> R² = 0.2596, MSE = 2.4317e-01
# Theta | Val -> R² = -7.5762, MSE = 2.8032e+00
# Theta | LSG_1 -> R² = -0.0943, MSE = 4.5320e-01
# Theta | LSG_2 -> R² = -4.6605, MSE = 1.9607e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 0.991545 | Val Loss 0.740564
# Epoch 100 | Train Loss 0.710577 | Val Loss 0.568919
# Epoch 200 | Train Loss 0.678178 | Val Loss 0.654541
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch64_r0.9_seed5288.keras
# weights/model_arch64_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.8025, MSE = 4.5036e-02
# Theta | Train_2 -> R² = 0.5368, MSE = 1.0538e-01
# Theta | Test_1 -> R² = 0.5804, MSE = 9.6313e-02
# Theta | Test_2 -> R² = 0.8634, MSE = 3.2283e-02
# Theta | Test_3 -> R² = 0.6143, MSE = 1.2666e-01
# Theta | Val -> R² = -4.3960, MSE = 1.7637e+00
# Theta | LSG_1 -> R² = 0.4903, MSE = 2.1107e-01
# Theta | LSG_2 -> R² = -2.3001, MSE = 1.1431e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.973001 | Val Loss 0.718649
# Epoch 100 | Train Loss 0.708545 | Val Loss 0.567489
# Epoch 200 | Train Loss 0.651726 | Val Loss 0.688600
# Early stopping at epoch 230
# Modelo salvo em:
# models/model_arch64_r0.9_seed3859.keras
# weights/model_arch64_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7847, MSE = 4.9103e-02
# Theta | Train_2 -> R² = 0.6353, MSE = 8.2979e-02
# Theta | Test_1 -> R² = 0.4132, MSE = 1.3469e-01
# Theta | Test_2 -> R² = 0.8565, MSE = 3.3915e-02
# Theta | Test_3 -> R² = 0.2970, MSE = 2.3089e-01
# Theta | Val -> R² = -8.5086, MSE = 3.1079e+00
# Theta | LSG_1 -> R² = -0.2799, MSE = 5.3003e-01
# Theta | LSG_2 -> R² = -5.0412, MSE = 2.0926e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 1.004211 | Val Loss 0.800730
# Epoch 100 | Train Loss 0.705806 | Val Loss 0.570715
# Epoch 200 | Train Loss 0.648033 | Val Loss 0.708921
# Early stopping at epoch 229
# Modelo salvo em:
# models/model_arch64_r0.9_seed9517.keras
# weights/model_arch64_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7648, MSE = 5.3645e-02
# Theta | Train_2 -> R² = 0.5987, MSE = 9.1302e-02
# Theta | Test_1 -> R² = 0.1939, MSE = 1.8504e-01
# Theta | Test_2 -> R² = 0.8240, MSE = 4.1600e-02
# Theta | Test_3 -> R² = 0.6407, MSE = 1.1801e-01
# Theta | Val -> R² = -7.1036, MSE = 2.6487e+00
# Theta | LSG_1 -> R² = -0.3352, MSE = 5.5295e-01
# Theta | LSG_2 -> R² = -5.2579, MSE = 2.1676e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 1.034026 | Val Loss 0.791100
# Epoch 100 | Train Loss 0.710203 | Val Loss 0.570799
# Epoch 200 | Train Loss 0.677513 | Val Loss 0.626581
# Early stopping at epoch 239
# Modelo salvo em:
# models/model_arch64_r0.9_seed6052.keras
# weights/model_arch64_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7634, MSE = 5.3963e-02
# Theta | Train_2 -> R² = 0.6426, MSE = 8.1309e-02
# Theta | Test_1 -> R² = 0.5057, MSE = 1.1348e-01
# Theta | Test_2 -> R² = 0.8911, MSE = 2.5735e-02
# Theta | Test_3 -> R² = 0.4668, MSE = 1.7511e-01
# Theta | Val -> R² = -5.0519, MSE = 1.9781e+00
# Theta | LSG_1 -> R² = 0.2958, MSE = 2.9162e-01
# Theta | LSG_2 -> R² = -3.4668, MSE = 1.5472e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.974296 | Val Loss 0.774083
# Epoch 100 | Train Loss 0.709251 | Val Loss 0.575297
# Epoch 200 | Train Loss 0.648675 | Val Loss 0.724776
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch64_r0.9_seed5866.keras
# weights/model_arch64_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.8033, MSE = 4.4847e-02
# Theta | Train_2 -> R² = 0.5659, MSE = 9.8758e-02
# Theta | Test_1 -> R² = 0.3468, MSE = 1.4994e-01
# Theta | Test_2 -> R² = 0.8172, MSE = 4.3206e-02
# Theta | Test_3 -> R² = 0.5603, MSE = 1.4439e-01
# Theta | Val -> R² = -7.0856, MSE = 2.6428e+00
# Theta | LSG_1 -> R² = -0.0654, MSE = 4.4123e-01
# Theta | LSG_2 -> R² = -4.5677, MSE = 1.9286e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 1.007829 | Val Loss 0.784716
# Epoch 100 | Train Loss 0.734028 | Val Loss 0.611932
# Epoch 200 | Train Loss 0.663190 | Val Loss 0.619700
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch64_r0.01_seed5288.keras
# weights/model_arch64_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.8504, MSE = 3.4116e-02
# Theta | Train_2 -> R² = 0.6174, MSE = 8.7041e-02
# Theta | Test_1 -> R² = 0.6987, MSE = 6.9173e-02
# Theta | Test_2 -> R² = 0.8734, MSE = 2.9910e-02
# Theta | Test_3 -> R² = 0.0566, MSE = 3.0982e-01
# Theta | Val -> R² = -8.2103, MSE = 3.0104e+00
# Theta | LSG_1 -> R² = 0.2381, MSE = 3.1551e-01
# Theta | LSG_2 -> R² = -3.4302, MSE = 1.5345e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 1.018247 | Val Loss 0.812711
# Epoch 100 | Train Loss 0.728990 | Val Loss 0.618334
# Epoch 200 | Train Loss 0.642410 | Val Loss 0.665659
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch64_r0.01_seed3859.keras
# weights/model_arch64_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.8407, MSE = 3.6325e-02
# Theta | Train_2 -> R² = 0.6119, MSE = 8.8296e-02
# Theta | Test_1 -> R² = 0.5930, MSE = 9.3415e-02
# Theta | Test_2 -> R² = 0.8618, MSE = 3.2655e-02
# Theta | Test_3 -> R² = -0.0718, MSE = 3.5201e-01
# Theta | Val -> R² = -9.3580, MSE = 3.3855e+00
# Theta | LSG_1 -> R² = 0.0313, MSE = 4.0116e-01
# Theta | LSG_2 -> R² = -4.1813, MSE = 1.7947e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.971337 | Val Loss 0.757926
# Epoch 100 | Train Loss 0.734768 | Val Loss 0.615256
# Epoch 200 | Train Loss 0.679736 | Val Loss 0.661474
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.01_seed9517.keras
# weights/model_arch64_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.8290, MSE = 3.9001e-02
# Theta | Train_2 -> R² = 0.6537, MSE = 7.8780e-02
# Theta | Test_1 -> R² = 0.5242, MSE = 1.0922e-01
# Theta | Test_2 -> R² = 0.8694, MSE = 3.0861e-02
# Theta | Test_3 -> R² = -0.2443, MSE = 4.0867e-01
# Theta | Val -> R² = -9.8429, MSE = 3.5440e+00
# Theta | LSG_1 -> R² = 0.0036, MSE = 4.1263e-01
# Theta | LSG_2 -> R² = -4.4278, MSE = 1.8801e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 1.030170 | Val Loss 0.838434
# Epoch 100 | Train Loss 0.730833 | Val Loss 0.613571
# Epoch 200 | Train Loss 0.671918 | Val Loss 0.570667
# Epoch 300 | Train Loss 0.569785 | Val Loss 0.781356
# Epoch 400 | Train Loss 0.545619 | Val Loss 0.965432
# Early stopping at epoch 410
# Modelo salvo em:
# models/model_arch64_r0.01_seed6052.keras
# weights/model_arch64_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7180, MSE = 6.4306e-02
# Theta | Train_2 -> R² = 0.8020, MSE = 4.5056e-02
# Theta | Test_1 -> R² = 0.3989, MSE = 1.3799e-01
# Theta | Test_2 -> R² = 0.7718, MSE = 5.3926e-02
# Theta | Test_3 -> R² = -9.4250, MSE = 3.4238e+00
# Theta | Val -> R² = -23.3421, MSE = 7.9563e+00
# Theta | LSG_1 -> R² = -1.4486, MSE = 1.0140e+00
# Theta | LSG_2 -> R² = -8.6630, MSE = 3.3471e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.945536 | Val Loss 0.750022
# Epoch 100 | Train Loss 0.726943 | Val Loss 0.630816
# Epoch 200 | Train Loss 0.604043 | Val Loss 0.740258
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.01_seed5866.keras
# weights/model_arch64_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7898, MSE = 4.7946e-02
# Theta | Train_2 -> R² = 0.5452, MSE = 1.0347e-01
# Theta | Test_1 -> R² = 0.4720, MSE = 1.2121e-01
# Theta | Test_2 -> R² = 0.8290, MSE = 4.0426e-02
# Theta | Test_3 -> R² = -0.1522, MSE = 3.7842e-01
# Theta | Val -> R² = -10.0590, MSE = 3.6147e+00
# Theta | LSG_1 -> R² = -0.0902, MSE = 4.5148e-01
# Theta | LSG_2 -> R² = -4.3292, MSE = 1.8459e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 1.014253 | Val Loss 0.839306
# Epoch 100 | Train Loss 0.727966 | Val Loss 0.624172
# Epoch 200 | Train Loss 0.613731 | Val Loss 0.685085
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch64_r0.9_seed5288.keras
# weights/model_arch64_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.8368, MSE = 3.7223e-02
# Theta | Train_2 -> R² = 0.4937, MSE = 1.1519e-01
# Theta | Test_1 -> R² = 0.7051, MSE = 6.7697e-02
# Theta | Test_2 -> R² = 0.7893, MSE = 4.9798e-02
# Theta | Test_3 -> R² = -0.3556, MSE = 4.4522e-01
# Theta | Val -> R² = -10.5040, MSE = 3.7601e+00
# Theta | LSG_1 -> R² = 0.0860, MSE = 3.7852e-01
# Theta | LSG_2 -> R² = -3.4442, MSE = 1.5394e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.966754 | Val Loss 0.761502
# Epoch 100 | Train Loss 0.730699 | Val Loss 0.620960
# Epoch 200 | Train Loss 0.629448 | Val Loss 0.653495
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.9_seed3859.keras
# weights/model_arch64_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.8650, MSE = 3.0779e-02
# Theta | Train_2 -> R² = 0.6367, MSE = 8.2665e-02
# Theta | Test_1 -> R² = 0.6245, MSE = 8.6189e-02
# Theta | Test_2 -> R² = 0.8553, MSE = 3.4192e-02
# Theta | Test_3 -> R² = -0.0813, MSE = 3.5511e-01
# Theta | Val -> R² = -10.2566, MSE = 3.6792e+00
# Theta | LSG_1 -> R² = -0.2008, MSE = 4.9728e-01
# Theta | LSG_2 -> R² = -4.9555, MSE = 2.0629e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 0.953023 | Val Loss 0.714989
# Epoch 100 | Train Loss 0.734908 | Val Loss 0.606924
# Epoch 200 | Train Loss 0.680896 | Val Loss 0.587298
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.9_seed9517.keras
# weights/model_arch64_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.8025, MSE = 4.5030e-02
# Theta | Train_2 -> R² = 0.7022, MSE = 6.7743e-02
# Theta | Test_1 -> R² = 0.6279, MSE = 8.5421e-02
# Theta | Test_2 -> R² = 0.8654, MSE = 3.1816e-02
# Theta | Test_3 -> R² = -0.4335, MSE = 4.7079e-01
# Theta | Val -> R² = -9.8954, MSE = 3.5612e+00
# Theta | LSG_1 -> R² = -0.0619, MSE = 4.3978e-01
# Theta | LSG_2 -> R² = -4.7191, MSE = 1.9810e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 0.966572 | Val Loss 0.734399
# Epoch 100 | Train Loss 0.732318 | Val Loss 0.630237
# Epoch 200 | Train Loss 0.644982 | Val Loss 0.649565
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.9_seed6052.keras
# weights/model_arch64_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.8402, MSE = 3.6432e-02
# Theta | Train_2 -> R² = 0.7105, MSE = 6.5866e-02
# Theta | Test_1 -> R² = 0.7425, MSE = 5.9111e-02
# Theta | Test_2 -> R² = 0.8607, MSE = 3.2933e-02
# Theta | Test_3 -> R² = -0.7943, MSE = 5.8930e-01
# Theta | Val -> R² = -12.7474, MSE = 4.4934e+00
# Theta | LSG_1 -> R² = -0.4107, MSE = 5.8421e-01
# Theta | LSG_2 -> R² = -5.8207, MSE = 2.3626e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.964166 | Val Loss 0.764018
# Epoch 100 | Train Loss 0.731891 | Val Loss 0.630363
# Epoch 200 | Train Loss 0.616479 | Val Loss 0.764020
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch64_r0.9_seed5866.keras
# weights/model_arch64_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.8658, MSE = 3.0604e-02
# Theta | Train_2 -> R² = 0.5981, MSE = 9.1442e-02
# Theta | Test_1 -> R² = 0.6244, MSE = 8.6216e-02
# Theta | Test_2 -> R² = 0.8478, MSE = 3.5970e-02
# Theta | Test_3 -> R² = -0.0903, MSE = 3.5808e-01
# Theta | Val -> R² = -10.3748, MSE = 3.7179e+00
# Theta | LSG_1 -> R² = -0.1231, MSE = 4.6511e-01
# Theta | LSG_2 -> R² = -4.4633, MSE = 1.8924e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 1.171220 | Val Loss 0.744241
# Epoch 100 | Train Loss 0.706990 | Val Loss 0.566860
# Epoch 200 | Train Loss 0.686583 | Val Loss 0.574925
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch128_r0.01_seed5288.keras
# weights/model_arch128_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7788, MSE = 5.0451e-02
# Theta | Train_2 -> R² = 0.7094, MSE = 6.6105e-02
# Theta | Test_1 -> R² = 0.7088, MSE = 6.6835e-02
# Theta | Test_2 -> R² = 0.8782, MSE = 2.8798e-02
# Theta | Test_3 -> R² = 0.2162, MSE = 2.5743e-01
# Theta | Val -> R² = -6.8265, MSE = 2.5581e+00
# Theta | LSG_1 -> R² = 0.0641, MSE = 3.8760e-01
# Theta | LSG_2 -> R² = -4.4776, MSE = 1.8973e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 1.090402 | Val Loss 0.668819
# Epoch 100 | Train Loss 0.705831 | Val Loss 0.570975
# Epoch 200 | Train Loss 0.680721 | Val Loss 0.597472
# Early stopping at epoch 222
# Modelo salvo em:
# models/model_arch128_r0.01_seed3859.keras
# weights/model_arch128_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7610, MSE = 5.4500e-02
# Theta | Train_2 -> R² = 0.7051, MSE = 6.7091e-02
# Theta | Test_1 -> R² = 0.6831, MSE = 7.2752e-02
# Theta | Test_2 -> R² = 0.8824, MSE = 2.7792e-02
# Theta | Test_3 -> R² = 0.1549, MSE = 2.7757e-01
# Theta | Val -> R² = -6.0665, MSE = 2.3097e+00
# Theta | LSG_1 -> R² = 0.2628, MSE = 3.0530e-01
# Theta | LSG_2 -> R² = -3.8482, MSE = 1.6793e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 0.982119 | Val Loss 0.695769
# Epoch 100 | Train Loss 0.701804 | Val Loss 0.567897
# Epoch 200 | Train Loss 0.634279 | Val Loss 0.785147
# Early stopping at epoch 215
# Modelo salvo em:
# models/model_arch128_r0.01_seed9517.keras
# weights/model_arch128_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7489, MSE = 5.7261e-02
# Theta | Train_2 -> R² = 0.6605, MSE = 7.7232e-02
# Theta | Test_1 -> R² = 0.4057, MSE = 1.3643e-01
# Theta | Test_2 -> R² = 0.8468, MSE = 3.6198e-02
# Theta | Test_3 -> R² = 0.0764, MSE = 3.0334e-01
# Theta | Val -> R² = -8.9526, MSE = 3.2530e+00
# Theta | LSG_1 -> R² = -0.4600, MSE = 6.0462e-01
# Theta | LSG_2 -> R² = -6.3960, MSE = 2.5618e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 1.089348 | Val Loss 0.710826
# Epoch 100 | Train Loss 0.705076 | Val Loss 0.567312
# Epoch 200 | Train Loss 0.662198 | Val Loss 0.610724
# Epoch 300 | Train Loss 0.606818 | Val Loss 0.782459
# Early stopping at epoch 368
# Modelo salvo em:
# models/model_arch128_r0.01_seed6052.keras
# weights/model_arch128_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7934, MSE = 4.7119e-02
# Theta | Train_2 -> R² = 0.7356, MSE = 6.0147e-02
# Theta | Test_1 -> R² = 0.7335, MSE = 6.1179e-02
# Theta | Test_2 -> R² = 0.8402, MSE = 3.7761e-02
# Theta | Test_3 -> R² = -0.4087, MSE = 4.6266e-01
# Theta | Val -> R² = -3.4012, MSE = 1.4385e+00
# Theta | LSG_1 -> R² = 0.6338, MSE = 1.5166e-01
# Theta | LSG_2 -> R² = -2.8277, MSE = 1.3259e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 1.034163 | Val Loss 0.704836
# Epoch 100 | Train Loss 0.703589 | Val Loss 0.570760
# Epoch 200 | Train Loss 0.668746 | Val Loss 0.635420
# Early stopping at epoch 220
# Modelo salvo em:
# models/model_arch128_r0.01_seed5866.keras
# weights/model_arch128_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7683, MSE = 5.2846e-02
# Theta | Train_2 -> R² = 0.6780, MSE = 7.3264e-02
# Theta | Test_1 -> R² = 0.5081, MSE = 1.1291e-01
# Theta | Test_2 -> R² = 0.8834, MSE = 2.7547e-02
# Theta | Test_3 -> R² = 0.1367, MSE = 2.8352e-01
# Theta | Val -> R² = -7.8248, MSE = 2.8844e+00
# Theta | LSG_1 -> R² = -0.1133, MSE = 4.6107e-01
# Theta | LSG_2 -> R² = -5.0119, MSE = 2.0824e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 1.157330 | Val Loss 0.732777
# Epoch 100 | Train Loss 0.706643 | Val Loss 0.568585
# Epoch 200 | Train Loss 0.685210 | Val Loss 0.556003
# Early stopping at epoch 223
# Modelo salvo em:
# models/model_arch128_r0.9_seed5288.keras
# weights/model_arch128_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7860, MSE = 4.8795e-02
# Theta | Train_2 -> R² = 0.6762, MSE = 7.3658e-02
# Theta | Test_1 -> R² = 0.7153, MSE = 6.5359e-02
# Theta | Test_2 -> R² = 0.8909, MSE = 2.5792e-02
# Theta | Test_3 -> R² = 0.3659, MSE = 2.0825e-01
# Theta | Val -> R² = -5.9075, MSE = 2.2577e+00
# Theta | LSG_1 -> R² = 0.2216, MSE = 3.2238e-01
# Theta | LSG_2 -> R² = -3.6850, MSE = 1.6228e+00
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 1.114969 | Val Loss 0.769975
# Epoch 100 | Train Loss 0.705336 | Val Loss 0.570693
# ...
# Theta | Test_2 -> R² = 0.8268, MSE = 4.0934e-02
# Theta | Test_3 -> R² = 0.3358, MSE = 2.1814e-01
# Theta | Val -> R² = -6.9955, MSE = 2.6133e+00
# Theta | LSG_1 -> R² = 0.2597, MSE = 3.0659e-01
# Theta | LSG_2 -> R² = -3.4956, MSE = 1.5572e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.967386 | Val Loss 0.757162
# Epoch 100 | Train Loss 0.669027 | Val Loss 0.558198
# Epoch 200 | Train Loss 0.538007 | Val Loss 0.966367
# Early stopping at epoch 219
# Modelo salvo em:
# models/model_arch128-64-32_r0.9_seed5866.keras
# weights/model_arch128-64-32_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.8020, MSE = 4.5144e-02
# Theta | Train_2 -> R² = 0.5701, MSE = 9.7817e-02
# Theta | Test_1 -> R² = 0.4976, MSE = 1.1532e-01
# Theta | Test_2 -> R² = 0.8698, MSE = 3.0761e-02
# Theta | Test_3 -> R² = 0.4777, MSE = 1.7155e-01
# Theta | Val -> R² = -5.3780, MSE = 2.0847e+00
# Theta | LSG_1 -> R² = 0.5378, MSE = 1.9141e-01
# Theta | LSG_2 -> R² = -2.1466, MSE = 1.0899e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 0.973238 | Val Loss 0.766203
# Epoch 100 | Train Loss 0.656145 | Val Loss 0.580247
# Epoch 200 | Train Loss 0.563770 | Val Loss 0.806034
# Early stopping at epoch 264
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed5288.keras
# weights/model_arch264-128-64_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.7605, MSE = 5.4612e-02
# Theta | Train_2 -> R² = 0.7900, MSE = 4.7768e-02
# Theta | Test_1 -> R² = 0.7802, MSE = 5.0466e-02
# Theta | Test_2 -> R² = 0.8988, MSE = 2.3908e-02
# Theta | Test_3 -> R² = 0.2307, MSE = 2.5265e-01
# Theta | Val -> R² = -2.1605, MSE = 1.0330e+00
# Theta | LSG_1 -> R² = 0.6721, MSE = 1.3581e-01
# Theta | LSG_2 -> R² = -2.3352, MSE = 1.1552e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 0.988904 | Val Loss 0.721386
# Epoch 100 | Train Loss 0.647244 | Val Loss 0.623076
# Epoch 200 | Train Loss 0.563681 | Val Loss 0.807916
# Early stopping at epoch 208
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed3859.keras
# weights/model_arch264-128-64_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.8306, MSE = 3.8636e-02
# Theta | Train_2 -> R² = 0.6007, MSE = 9.0855e-02
# Theta | Test_1 -> R² = 0.8290, MSE = 3.9246e-02
# Theta | Test_2 -> R² = 0.8416, MSE = 3.7435e-02
# Theta | Test_3 -> R² = 0.6254, MSE = 1.2303e-01
# Theta | Val -> R² = -2.9693, MSE = 1.2974e+00
# Theta | LSG_1 -> R² = 0.7079, MSE = 1.2097e-01
# Theta | LSG_2 -> R² = -1.1374, MSE = 7.4037e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 1.009198 | Val Loss 0.677169
# Epoch 100 | Train Loss 0.625708 | Val Loss 0.682548
# Epoch 200 | Train Loss 0.555343 | Val Loss 0.811538
# Early stopping at epoch 253
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed9517.keras
# weights/model_arch264-128-64_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7810, MSE = 4.9951e-02
# Theta | Train_2 -> R² = 0.7360, MSE = 6.0071e-02
# Theta | Test_1 -> R² = 0.8434, MSE = 3.5953e-02
# Theta | Test_2 -> R² = 0.8888, MSE = 2.6291e-02
# Theta | Test_3 -> R² = -0.0460, MSE = 3.4354e-01
# Theta | Val -> R² = -2.2866, MSE = 1.0742e+00
# Theta | LSG_1 -> R² = 0.6674, MSE = 1.3772e-01
# Theta | LSG_2 -> R² = -1.2539, MSE = 7.8070e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 0.920948 | Val Loss 0.596918
# Epoch 100 | Train Loss 0.648918 | Val Loss 0.608488
# Epoch 200 | Train Loss 0.563154 | Val Loss 0.788073
# Early stopping at epoch 264
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed6052.keras
# weights/model_arch264-128-64_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7817, MSE = 4.9790e-02
# Theta | Train_2 -> R² = 0.7783, MSE = 5.0447e-02
# Theta | Test_1 -> R² = 0.7489, MSE = 5.7642e-02
# Theta | Test_2 -> R² = 0.8886, MSE = 2.6327e-02
# Theta | Test_3 -> R² = 0.2330, MSE = 2.5192e-01
# Theta | Val -> R² = -1.8655, MSE = 9.3661e-01
# Theta | LSG_1 -> R² = 0.7083, MSE = 1.2079e-01
# Theta | LSG_2 -> R² = -1.9954, MSE = 1.0375e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.982965 | Val Loss 0.703167
# Epoch 100 | Train Loss 0.631686 | Val Loss 0.637474
# Epoch 200 | Train Loss 0.558628 | Val Loss 0.781419
# Early stopping at epoch 254
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed5866.keras
# weights/model_arch264-128-64_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.7348, MSE = 6.0487e-02
# Theta | Train_2 -> R² = 0.8167, MSE = 4.1699e-02
# Theta | Test_1 -> R² = 0.7522, MSE = 5.6881e-02
# Theta | Test_2 -> R² = 0.8808, MSE = 2.8179e-02
# Theta | Test_3 -> R² = 0.0756, MSE = 3.0359e-01
# Theta | Val -> R² = -1.4859, MSE = 8.1252e-01
# Theta | LSG_1 -> R² = 0.6912, MSE = 1.2788e-01
# Theta | LSG_2 -> R² = -2.2852, MSE = 1.1379e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 1.007251 | Val Loss 0.595270
# Epoch 100 | Train Loss 0.633375 | Val Loss 0.686982
# Epoch 200 | Train Loss 0.562742 | Val Loss 0.816104
# Early stopping at epoch 251
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed5288.keras
# weights/model_arch264-128-64_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.6759, MSE = 7.3910e-02
# Theta | Train_2 -> R² = 0.7644, MSE = 5.3612e-02
# Theta | Test_1 -> R² = 0.6123, MSE = 8.9002e-02
# Theta | Test_2 -> R² = 0.8795, MSE = 2.8481e-02
# Theta | Test_3 -> R² = 0.5549, MSE = 1.4618e-01
# Theta | Val -> R² = -2.7852, MSE = 1.2372e+00
# Theta | LSG_1 -> R² = 0.5395, MSE = 1.9071e-01
# Theta | LSG_2 -> R² = -3.2991, MSE = 1.4891e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 0.959348 | Val Loss 0.685977
# Epoch 100 | Train Loss 0.641826 | Val Loss 0.629560
# Epoch 200 | Train Loss 0.568424 | Val Loss 0.803155
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed3859.keras
# weights/model_arch264-128-64_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.6673, MSE = 7.5865e-02
# Theta | Train_2 -> R² = 0.8096, MSE = 4.3315e-02
# Theta | Test_1 -> R² = 0.6514, MSE = 8.0024e-02
# Theta | Test_2 -> R² = 0.8904, MSE = 2.5900e-02
# Theta | Test_3 -> R² = 0.5429, MSE = 1.5013e-01
# Theta | Val -> R² = -1.2749, MSE = 7.4356e-01
# Theta | LSG_1 -> R² = 0.6534, MSE = 1.4353e-01
# Theta | LSG_2 -> R² = -2.4589, MSE = 1.1981e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 0.988905 | Val Loss 0.658159
# Epoch 100 | Train Loss 0.629461 | Val Loss 0.673955
# Epoch 200 | Train Loss 0.590341 | Val Loss 0.804688
# Early stopping at epoch 258
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed9517.keras
# weights/model_arch264-128-64_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.7804, MSE = 5.0081e-02
# Theta | Train_2 -> R² = 0.6845, MSE = 7.1779e-02
# Theta | Test_1 -> R² = 0.8500, MSE = 3.4438e-02
# Theta | Test_2 -> R² = 0.8356, MSE = 3.8860e-02
# Theta | Test_3 -> R² = 0.7242, MSE = 9.0596e-02
# Theta | Val -> R² = 0.0946, MSE = 2.9595e-01
# Theta | LSG_1 -> R² = 0.6604, MSE = 1.4064e-01
# Theta | LSG_2 -> R² = -0.6080, MSE = 5.5697e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 0.988911 | Val Loss 0.692895
# Epoch 100 | Train Loss 0.646255 | Val Loss 0.616824
# Epoch 200 | Train Loss 0.581431 | Val Loss 0.735629
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed6052.keras
# weights/model_arch264-128-64_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7154, MSE = 6.4913e-02
# Theta | Train_2 -> R² = 0.7854, MSE = 4.8816e-02
# Theta | Test_1 -> R² = 0.7152, MSE = 6.5381e-02
# Theta | Test_2 -> R² = 0.9023, MSE = 2.3097e-02
# Theta | Test_3 -> R² = 0.6243, MSE = 1.2340e-01
# Theta | Val -> R² = -0.8136, MSE = 5.9277e-01
# Theta | LSG_1 -> R² = 0.6864, MSE = 1.2989e-01
# Theta | LSG_2 -> R² = -1.7308, MSE = 9.4591e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.982767 | Val Loss 0.686135
# Epoch 100 | Train Loss 0.627341 | Val Loss 0.657393
# Epoch 200 | Train Loss 0.573586 | Val Loss 0.795377
# Early stopping at epoch 251
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed5866.keras
# weights/model_arch264-128-64_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.6549, MSE = 7.8708e-02
# Theta | Train_2 -> R² = 0.7489, MSE = 5.7120e-02
# Theta | Test_1 -> R² = 0.6451, MSE = 8.1466e-02
# Theta | Test_2 -> R² = 0.8608, MSE = 3.2904e-02
# Theta | Test_3 -> R² = 0.1530, MSE = 2.7817e-01
# Theta | Val -> R² = -2.3723, MSE = 1.1023e+00
# Theta | LSG_1 -> R² = 0.6342, MSE = 1.5151e-01
# Theta | LSG_2 -> R² = -2.2549, MSE = 1.1274e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=5866 salvo.
# Epoch 0 | Train Loss 0.999269 | Val Loss 0.633332
# Epoch 100 | Train Loss 0.598930 | Val Loss 0.594438
# Epoch 200 | Train Loss 0.538212 | Val Loss 0.950726
# Early stopping at epoch 294
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed5288.keras
# weights/model_arch264-128-64_r0.01_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.4170, MSE = 1.3296e-01
# Theta | Train_2 -> R² = 0.6939, MSE = 6.9644e-02
# Theta | Test_1 -> R² = 0.6562, MSE = 7.8923e-02
# Theta | Test_2 -> R² = 0.9133, MSE = 2.0494e-02
# Theta | Test_3 -> R² = -4.9690, MSE = 1.9604e+00
# Theta | Val -> R² = -9.0610, MSE = 3.2885e+00
# Theta | LSG_1 -> R² = -0.6633, MSE = 6.8882e-01
# Theta | LSG_2 -> R² = -5.4923, MSE = 2.2488e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5288 salvo.
# Epoch 0 | Train Loss 1.030270 | Val Loss 0.743285
# Epoch 100 | Train Loss 0.614315 | Val Loss 0.622584
# Epoch 200 | Train Loss 0.532932 | Val Loss 0.979654
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed3859.keras
# weights/model_arch264-128-64_r0.01_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.8812, MSE = 2.7091e-02
# Theta | Train_2 -> R² = 0.7449, MSE = 5.8037e-02
# Theta | Test_1 -> R² = 0.6254, MSE = 8.5984e-02
# Theta | Test_2 -> R² = 0.7880, MSE = 5.0106e-02
# Theta | Test_3 -> R² = -0.0849, MSE = 3.5632e-01
# Theta | Val -> R² = -7.4928, MSE = 2.7759e+00
# Theta | LSG_1 -> R² = 0.2377, MSE = 3.1568e-01
# Theta | LSG_2 -> R² = -4.0897, MSE = 1.7630e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3859 salvo.
# Epoch 0 | Train Loss 1.031203 | Val Loss 0.622979
# Epoch 100 | Train Loss 0.580306 | Val Loss 0.726302
# Epoch 200 | Train Loss 0.532646 | Val Loss 1.046544
# Early stopping at epoch 208
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed9517.keras
# weights/model_arch264-128-64_r0.01_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.8356, MSE = 3.7493e-02
# Theta | Train_2 -> R² = 0.6881, MSE = 7.0956e-02
# Theta | Test_1 -> R² = 0.6493, MSE = 8.0508e-02
# Theta | Test_2 -> R² = 0.7993, MSE = 4.7431e-02
# Theta | Test_3 -> R² = 0.2777, MSE = 2.3722e-01
# Theta | Val -> R² = -6.2561, MSE = 2.3717e+00
# Theta | LSG_1 -> R² = 0.3772, MSE = 2.5790e-01
# Theta | LSG_2 -> R² = -3.3624, MSE = 1.5111e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=9517 salvo.
# Epoch 0 | Train Loss 0.987782 | Val Loss 0.650270
# Epoch 100 | Train Loss 0.617600 | Val Loss 0.572716
# Epoch 200 | Train Loss 0.533208 | Val Loss 0.973509
# Early stopping at epoch 289
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed6052.keras
# weights/model_arch264-128-64_r0.01_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.8993, MSE = 2.2966e-02
# Theta | Train_2 -> R² = 0.4652, MSE = 1.2167e-01
# Theta | Test_1 -> R² = 0.7075, MSE = 6.7153e-02
# Theta | Test_2 -> R² = 0.7226, MSE = 6.5556e-02
# Theta | Test_3 -> R² = -0.7197, MSE = 5.6481e-01
# Theta | Val -> R² = -6.8584, MSE = 2.5685e+00
# Theta | LSG_1 -> R² = -0.1613, MSE = 4.8094e-01
# Theta | LSG_2 -> R² = -3.1882, MSE = 1.4507e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=6052 salvo.
# Epoch 0 | Train Loss 0.937184 | Val Loss 0.600905
# Epoch 100 | Train Loss 0.619713 | Val Loss 0.572623
# Epoch 200 | Train Loss 0.543343 | Val Loss 0.979159
# Early stopping at epoch 281
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed5866.keras
# weights/model_arch264-128-64_r0.01_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.6926, MSE = 7.0095e-02
# Theta | Train_2 -> R² = 0.8490, MSE = 3.4350e-02
# Theta | Test_1 -> R² = 0.5821, MSE = 9.5931e-02
# Theta | Test_2 -> R² = 0.8582, MSE = 3.3521e-02
# Theta | Test_3 -> R² = -6.5889, MSE = 2.4924e+00
# Theta | Val -> R² = -16.8189, MSE = 5.8241e+00
# Theta | LSG_1 -> R² = -1.3101, MSE = 9.5667e-01
# Theta | LSG_2 -> R² = -8.8926, MSE = 3.4266e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=5866 salvo.
# Epoch 0 | Train Loss 0.935248 | Val Loss 0.571441
# Epoch 100 | Train Loss 0.570440 | Val Loss 0.778812
# Epoch 200 | Train Loss 0.523265 | Val Loss 1.078113
# Early stopping at epoch 207
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed5288.keras
# weights/model_arch264-128-64_r0.9_seed5288.weights.h5
# Theta | Train_1 -> R² = 0.8221, MSE = 4.0582e-02
# Theta | Train_2 -> R² = 0.6857, MSE = 7.1510e-02
# Theta | Test_1 -> R² = 0.6652, MSE = 7.6855e-02
# Theta | Test_2 -> R² = 0.6809, MSE = 7.5410e-02
# Theta | Test_3 -> R² = 0.1681, MSE = 2.7321e-01
# Theta | Val -> R² = -7.9285, MSE = 2.9183e+00
# Theta | LSG_1 -> R² = -0.1304, MSE = 4.6813e-01
# Theta | LSG_2 -> R² = -5.6248, MSE = 2.2947e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5288 salvo.
# Epoch 0 | Train Loss 1.003560 | Val Loss 0.718424
# Epoch 100 | Train Loss 0.630097 | Val Loss 0.570866
# Epoch 200 | Train Loss 0.534618 | Val Loss 0.989408
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed3859.keras
# weights/model_arch264-128-64_r0.9_seed3859.weights.h5
# Theta | Train_1 -> R² = 0.7338, MSE = 6.0708e-02
# Theta | Train_2 -> R² = 0.6338, MSE = 8.3322e-02
# Theta | Test_1 -> R² = 0.2574, MSE = 1.7047e-01
# Theta | Test_2 -> R² = 0.8257, MSE = 4.1187e-02
# Theta | Test_3 -> R² = -0.0242, MSE = 3.3638e-01
# Theta | Val -> R² = -8.4794, MSE = 3.0983e+00
# Theta | LSG_1 -> R² = -0.0534, MSE = 4.3623e-01
# Theta | LSG_2 -> R² = -4.6916, MSE = 1.9715e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3859 salvo.
# Epoch 0 | Train Loss 0.972072 | Val Loss 0.599074
# Epoch 100 | Train Loss 0.585652 | Val Loss 0.732576
# Epoch 200 | Train Loss 0.548482 | Val Loss 0.987036
# Early stopping at epoch 208
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed9517.keras
# weights/model_arch264-128-64_r0.9_seed9517.weights.h5
# Theta | Train_1 -> R² = 0.8400, MSE = 3.6482e-02
# Theta | Train_2 -> R² = 0.5482, MSE = 1.0279e-01
# Theta | Test_1 -> R² = 0.3609, MSE = 1.4670e-01
# Theta | Test_2 -> R² = 0.8197, MSE = 4.2602e-02
# Theta | Test_3 -> R² = 0.7605, MSE = 7.8664e-02
# Theta | Val -> R² = -5.4502, MSE = 2.1082e+00
# Theta | LSG_1 -> R² = 0.0595, MSE = 3.8948e-01
# Theta | LSG_2 -> R² = -3.8819, MSE = 1.6910e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=9517 salvo.
# Epoch 0 | Train Loss 0.950210 | Val Loss 0.633172
# Epoch 100 | Train Loss 0.622996 | Val Loss 0.589526
# Epoch 200 | Train Loss 0.528594 | Val Loss 0.982639
# Early stopping at epoch 284
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed6052.keras
# weights/model_arch264-128-64_r0.9_seed6052.weights.h5
# Theta | Train_1 -> R² = 0.7889, MSE = 4.8134e-02
# Theta | Train_2 -> R² = 0.7818, MSE = 4.9643e-02
# Theta | Test_1 -> R² = 0.4918, MSE = 1.1667e-01
# Theta | Test_2 -> R² = 0.7695, MSE = 5.4471e-02
# Theta | Test_3 -> R² = -5.5286, MSE = 2.1441e+00
# Theta | Val -> R² = -17.4865, MSE = 6.0423e+00
# Theta | LSG_1 -> R² = -1.3896, MSE = 9.8961e-01
# Theta | LSG_2 -> R² = -8.7971, MSE = 3.3935e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=6052 salvo.
# Epoch 0 | Train Loss 0.993875 | Val Loss 0.686898
# Epoch 100 | Train Loss 0.595212 | Val Loss 0.636794
# Epoch 200 | Train Loss 0.525645 | Val Loss 0.988687
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed5866.keras
# weights/model_arch264-128-64_r0.9_seed5866.weights.h5
# Theta | Train_1 -> R² = 0.6466, MSE = 8.0599e-02
# Theta | Train_2 -> R² = 0.7339, MSE = 6.0540e-02
# Theta | Test_1 -> R² = 0.2312, MSE = 1.7648e-01
# Theta | Test_2 -> R² = 0.8873, MSE = 2.6648e-02
# Theta | Test_3 -> R² = -0.5362, MSE = 5.0451e-01
# Theta | Val -> R² = -9.0481, MSE = 3.2842e+00
# Theta | LSG_1 -> R² = -0.1639, MSE = 4.8200e-01
# Theta | LSG_2 -> R² = -5.0452, MSE = 2.0939e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=5866 salvo.
