# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm"]   
TARGET_INT = ["Theta"]  
TARGET = ["DeltaTheta"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada: (1268, 3, 4)
# Dimensão da saida: (1268, 1)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
theta_train = Train["Theta"].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 4)
# Dimensão da saida: (1949, 1)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta):

    dtheta_cin = (R / (2 * L)) * (Wd - We)
    return [dtheta_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dy, Wd, We, theta0, Ld, Lp):

    with tf.GradientTape() as tape:

        dy_pred = model(x, training=True)
        
        # loss dos dados
        data_loss = tf.reduce_mean(tf.square(dy_pred - dy))
        
        # termo físico
        physics = tf.stack(CinematicModel(Wd, We, theta0), axis=1)   
             
        # normalização correta
        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean(tf.square(dy_pred - physics_norm))

        loss = Ld * data_loss +  Lp * physics_loss 

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train = tf.convert_to_tensor(We_train, dtype=tf.float32)
theta_train = tf.convert_to_tensor(theta_train, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf,
                          Wd_train, We_train, theta_train, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# Epoch 0 | Train Loss 0.986144 | Val Loss 0.830966
# Epoch 100 | Train Loss 0.774739 | Val Loss 0.555344
# Epoch 200 | Train Loss 0.699017 | Val Loss 0.553000
# Epoch 300 | Train Loss 0.663724 | Val Loss 0.570228
# Early stopping at epoch 355
# Modelo salvo em:
# models/model_arch16_r0.01_seed6590.keras
# weights/model_arch16_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.8003, MSE = 4.5453e-02
# Theta | Train_2 -> R² = 0.5486, MSE = 1.0306e-01
# Theta | Test_1 -> R² = 0.4854, MSE = 1.1789e-01
# Theta | Test_2 -> R² = 0.8642, MSE = 3.2196e-02
# Theta | Test_3 -> R² = 0.6953, MSE = 9.9940e-02
# Theta | Val -> R² = -0.4634, MSE = 4.7769e-01
# Theta | LSG_1 -> R² = 0.7524, MSE = 1.0337e-01
# Theta | LSG_2 -> R² = -1.7503, MSE = 9.6263e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.992052 | Val Loss 0.839015
# Epoch 100 | Train Loss 0.776759 | Val Loss 0.555035
# Epoch 200 | Train Loss 0.699151 | Val Loss 0.561005
# Epoch 300 | Train Loss 0.667015 | Val Loss 0.567234
# Early stopping at epoch 340
# Modelo salvo em:
# models/model_arch16_r0.01_seed1209.keras
# weights/model_arch16_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7385, MSE = 5.9523e-02
# Theta | Train_2 -> R² = 0.5558, MSE = 1.0141e-01
# Theta | Test_1 -> R² = 0.2182, MSE = 1.7909e-01
# Theta | Test_2 -> R² = 0.8550, MSE = 3.4382e-02
# Theta | Test_3 -> R² = 0.6630, MSE = 1.1053e-01
# Theta | Val -> R² = -3.5878, MSE = 1.4976e+00
# Theta | LSG_1 -> R² = 0.3190, MSE = 2.8428e-01
# Theta | LSG_2 -> R² = -3.6541, MSE = 1.6290e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.979445 | Val Loss 0.810757
# Epoch 100 | Train Loss 0.797702 | Val Loss 0.564201
# Epoch 200 | Train Loss 0.710123 | Val Loss 0.547875
# Epoch 300 | Train Loss 0.672393 | Val Loss 0.546001
# Epoch 400 | Train Loss 0.651661 | Val Loss 0.543462
# Epoch 500 | Train Loss 0.619307 | Val Loss 0.634646
# Early stopping at epoch 557
# Modelo salvo em:
# models/model_arch16_r0.01_seed2894.keras
# weights/model_arch16_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.8182, MSE = 4.1368e-02
# Theta | Train_2 -> R² = 0.7187, MSE = 6.4222e-02
# Theta | Test_1 -> R² = 0.6735, MSE = 7.4784e-02
# Theta | Test_2 -> R² = 0.8128, MSE = 4.4389e-02
# Theta | Test_3 -> R² = 0.7478, MSE = 8.2738e-02
# Theta | Val -> R² = 0.7570, MSE = 7.9339e-02
# Theta | LSG_1 -> R² = 0.3801, MSE = 2.5879e-01
# Theta | LSG_2 -> R² = -0.2767, MSE = 4.4686e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 1.019136 | Val Loss 0.844831
# Epoch 100 | Train Loss 0.785230 | Val Loss 0.572548
# Epoch 200 | Train Loss 0.711444 | Val Loss 0.538442
# Epoch 300 | Train Loss 0.673490 | Val Loss 0.529710
# Epoch 400 | Train Loss 0.654799 | Val Loss 0.529329
# Epoch 500 | Train Loss 0.640684 | Val Loss 0.521850
# Epoch 600 | Train Loss 0.616498 | Val Loss 0.531713
# Epoch 700 | Train Loss 0.583152 | Val Loss 0.688384
# Early stopping at epoch 734
# Modelo salvo em:
# models/model_arch16_r0.01_seed4968.keras
# weights/model_arch16_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.8415, MSE = 3.6082e-02
# Theta | Train_2 -> R² = 0.7391, MSE = 5.9563e-02
# Theta | Test_1 -> R² = 0.8046, MSE = 4.4766e-02
# Theta | Test_2 -> R² = 0.8295, MSE = 4.0426e-02
# Theta | Test_3 -> R² = 0.4518, MSE = 1.7981e-01
# Theta | Val -> R² = 0.5885, MSE = 1.3434e-01
# Theta | LSG_1 -> R² = -0.3049, MSE = 5.4475e-01
# Theta | LSG_2 -> R² = 0.3545, MSE = 2.2593e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 0.968251 | Val Loss 0.797327
# Epoch 100 | Train Loss 0.786748 | Val Loss 0.559774
# Epoch 200 | Train Loss 0.706819 | Val Loss 0.566664
# Epoch 300 | Train Loss 0.663511 | Val Loss 0.609131
# Early stopping at epoch 348
# Modelo salvo em:
# models/model_arch16_r0.01_seed7530.keras
# weights/model_arch16_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7575, MSE = 5.5191e-02
# Theta | Train_2 -> R² = 0.5852, MSE = 9.4691e-02
# Theta | Test_1 -> R² = 0.3393, MSE = 1.5135e-01
# Theta | Test_2 -> R² = 0.8628, MSE = 3.2534e-02
# Theta | Test_3 -> R² = 0.7059, MSE = 9.6478e-02
# Theta | Val -> R² = -2.5264, MSE = 1.1511e+00
# Theta | LSG_1 -> R² = 0.5436, MSE = 1.9054e-01
# Theta | LSG_2 -> R² = -2.8654, MSE = 1.3529e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.994376 | Val Loss 0.841757
# Epoch 100 | Train Loss 0.798092 | Val Loss 0.563335
# Epoch 200 | Train Loss 0.716693 | Val Loss 0.542300
# Epoch 300 | Train Loss 0.673906 | Val Loss 0.556933
# Early stopping at epoch 377
# Modelo salvo em:
# models/model_arch16_r0.9_seed6590.keras
# weights/model_arch16_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7734, MSE = 5.1567e-02
# Theta | Train_2 -> R² = 0.5937, MSE = 9.2756e-02
# Theta | Test_1 -> R² = 0.5305, MSE = 1.0756e-01
# Theta | Test_2 -> R² = 0.8673, MSE = 3.1460e-02
# Theta | Test_3 -> R² = 0.6307, MSE = 1.2113e-01
# Theta | Val -> R² = -1.7834, MSE = 9.0860e-01
# Theta | LSG_1 -> R² = 0.7224, MSE = 1.1586e-01
# Theta | LSG_2 -> R² = -1.5545, MSE = 8.9408e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.999182 | Val Loss 0.857056
# Epoch 100 | Train Loss 0.798553 | Val Loss 0.562798
# Epoch 200 | Train Loss 0.706597 | Val Loss 0.536353
# Epoch 300 | Train Loss 0.671624 | Val Loss 0.561558
# Early stopping at epoch 386
# Modelo salvo em:
# models/model_arch16_r0.9_seed1209.keras
# weights/model_arch16_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7665, MSE = 5.3135e-02
# Theta | Train_2 -> R² = 0.6635, MSE = 7.6810e-02
# Theta | Test_1 -> R² = 0.4088, MSE = 1.3542e-01
# Theta | Test_2 -> R² = 0.8560, MSE = 3.4145e-02
# Theta | Test_3 -> R² = 0.4273, MSE = 1.8786e-01
# Theta | Val -> R² = -3.1301, MSE = 1.3482e+00
# Theta | LSG_1 -> R² = 0.5250, MSE = 1.9831e-01
# Theta | LSG_2 -> R² = -3.5333, MSE = 1.5867e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.973156 | Val Loss 0.798466
# Epoch 100 | Train Loss 0.778945 | Val Loss 0.554178
# Epoch 200 | Train Loss 0.700625 | Val Loss 0.543244
# Epoch 300 | Train Loss 0.666620 | Val Loss 0.551078
# Early stopping at epoch 392
# Modelo salvo em:
# models/model_arch16_r0.9_seed2894.keras
# weights/model_arch16_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.8138, MSE = 4.2377e-02
# Theta | Train_2 -> R² = 0.5924, MSE = 9.3050e-02
# Theta | Test_1 -> R² = 0.5399, MSE = 1.0541e-01
# Theta | Test_2 -> R² = 0.8686, MSE = 3.1167e-02
# Theta | Test_3 -> R² = 0.7159, MSE = 9.3197e-02
# Theta | Val -> R² = -0.0426, MSE = 3.4032e-01
# Theta | LSG_1 -> R² = 0.7921, MSE = 8.6788e-02
# Theta | LSG_2 -> R² = -1.4890, MSE = 8.7115e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 1.002935 | Val Loss 0.807739
# Epoch 100 | Train Loss 0.794019 | Val Loss 0.562863
# Epoch 200 | Train Loss 0.709401 | Val Loss 0.530039
# Epoch 300 | Train Loss 0.672283 | Val Loss 0.532710
# Epoch 400 | Train Loss 0.655845 | Val Loss 0.550593
# Early stopping at epoch 403
# Modelo salvo em:
# models/model_arch16_r0.9_seed4968.keras
# weights/model_arch16_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7744, MSE = 5.1342e-02
# Theta | Train_2 -> R² = 0.6279, MSE = 8.4942e-02
# Theta | Test_1 -> R² = 0.4742, MSE = 1.2044e-01
# Theta | Test_2 -> R² = 0.8623, MSE = 3.2647e-02
# Theta | Test_3 -> R² = 0.6296, MSE = 1.2150e-01
# Theta | Val -> R² = -1.8727, MSE = 9.3773e-01
# Theta | LSG_1 -> R² = 0.6721, MSE = 1.3688e-01
# Theta | LSG_2 -> R² = -2.3512, MSE = 1.1729e+00
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.983702 | Val Loss 0.825896
# Epoch 100 | Train Loss 0.776815 | Val Loss 0.557432
# Epoch 200 | Train Loss 0.707493 | Val Loss 0.545404
# Epoch 300 | Train Loss 0.676528 | Val Loss 0.544551
# Epoch 400 | Train Loss 0.657042 | Val Loss 0.572907
# Early stopping at epoch 446
# Modelo salvo em:
# models/model_arch16_r0.9_seed7530.keras
# weights/model_arch16_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.8127, MSE = 4.2618e-02
# Theta | Train_2 -> R² = 0.6539, MSE = 7.9004e-02
# Theta | Test_1 -> R² = 0.6110, MSE = 8.9115e-02
# Theta | Test_2 -> R² = 0.8504, MSE = 3.5479e-02
# Theta | Test_3 -> R² = 0.6909, MSE = 1.0140e-01
# Theta | Val -> R² = 0.6140, MSE = 1.2600e-01
# Theta | LSG_1 -> R² = 0.6792, MSE = 1.3390e-01
# Theta | LSG_2 -> R² = -0.3840, MSE = 4.8440e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 0.969013 | Val Loss 0.807835
# Epoch 100 | Train Loss 0.686607 | Val Loss 0.619133
# Epoch 200 | Train Loss 0.675613 | Val Loss 0.602636
# Early stopping at epoch 260
# Modelo salvo em:
# models/model_arch16_r0.01_seed6590.keras
# weights/model_arch16_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7626, MSE = 5.4036e-02
# Theta | Train_2 -> R² = 0.5449, MSE = 1.0390e-01
# Theta | Test_1 -> R² = 0.3926, MSE = 1.3913e-01
# Theta | Test_2 -> R² = 0.8721, MSE = 3.0327e-02
# Theta | Test_3 -> R² = 0.1629, MSE = 2.7459e-01
# Theta | Val -> R² = -7.5223, MSE = 2.7820e+00
# Theta | LSG_1 -> R² = 0.2952, MSE = 2.9421e-01
# Theta | LSG_2 -> R² = -3.0594, MSE = 1.4208e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.991020 | Val Loss 0.854908
# Epoch 100 | Train Loss 0.687383 | Val Loss 0.629810
# Epoch 200 | Train Loss 0.674970 | Val Loss 0.603992
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch16_r0.01_seed1209.keras
# weights/model_arch16_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7993, MSE = 4.5681e-02
# Theta | Train_2 -> R² = 0.5838, MSE = 9.5022e-02
# Theta | Test_1 -> R² = 0.5503, MSE = 1.0301e-01
# Theta | Test_2 -> R² = 0.8791, MSE = 2.8675e-02
# Theta | Test_3 -> R² = -0.0955, MSE = 3.5933e-01
# Theta | Val -> R² = -8.0885, MSE = 2.9668e+00
# Theta | LSG_1 -> R² = 0.3139, MSE = 2.8643e-01
# Theta | LSG_2 -> R² = -3.0480, MSE = 1.4168e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.967800 | Val Loss 0.814479
# Epoch 100 | Train Loss 0.684124 | Val Loss 0.614880
# Epoch 200 | Train Loss 0.672145 | Val Loss 0.606323
# Early stopping at epoch 257
# Modelo salvo em:
# models/model_arch16_r0.01_seed2894.keras
# weights/model_arch16_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7748, MSE = 5.1258e-02
# Theta | Train_2 -> R² = 0.5745, MSE = 9.7139e-02
# Theta | Test_1 -> R² = 0.4011, MSE = 1.3719e-01
# Theta | Test_2 -> R² = 0.8747, MSE = 2.9702e-02
# Theta | Test_3 -> R² = 0.0918, MSE = 2.9791e-01
# Theta | Val -> R² = -7.8488, MSE = 2.8885e+00
# Theta | LSG_1 -> R² = 0.2498, MSE = 3.1316e-01
# Theta | LSG_2 -> R² = -3.3939, MSE = 1.5379e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 0.978471 | Val Loss 0.825859
# Epoch 100 | Train Loss 0.683969 | Val Loss 0.626439
# Epoch 200 | Train Loss 0.670004 | Val Loss 0.601270
# Early stopping at epoch 257
# Modelo salvo em:
# models/model_arch16_r0.01_seed4968.keras
# weights/model_arch16_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7970, MSE = 4.6208e-02
# Theta | Train_2 -> R² = 0.5691, MSE = 9.8358e-02
# Theta | Test_1 -> R² = 0.5185, MSE = 1.1030e-01
# Theta | Test_2 -> R² = 0.8734, MSE = 3.0016e-02
# Theta | Test_3 -> R² = 0.1208, MSE = 2.8840e-01
# Theta | Val -> R² = -7.7006, MSE = 2.8402e+00
# Theta | LSG_1 -> R² = 0.2677, MSE = 3.0569e-01
# Theta | LSG_2 -> R² = -3.2718, MSE = 1.4951e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 0.944863 | Val Loss 0.779246
# Epoch 100 | Train Loss 0.681019 | Val Loss 0.602974
# Epoch 200 | Train Loss 0.671189 | Val Loss 0.600424
# Early stopping at epoch 252
# Modelo salvo em:
# models/model_arch16_r0.01_seed7530.keras
# weights/model_arch16_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7993, MSE = 4.5684e-02
# Theta | Train_2 -> R² = 0.5450, MSE = 1.0387e-01
# Theta | Test_1 -> R² = 0.4222, MSE = 1.3236e-01
# Theta | Test_2 -> R² = 0.8674, MSE = 3.1447e-02
# Theta | Test_3 -> R² = 0.3309, MSE = 2.1948e-01
# Theta | Val -> R² = -6.8266, MSE = 2.5549e+00
# Theta | LSG_1 -> R² = 0.3798, MSE = 2.5891e-01
# Theta | LSG_2 -> R² = -2.8797, MSE = 1.3579e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.983279 | Val Loss 0.835088
# Epoch 100 | Train Loss 0.685434 | Val Loss 0.627761
# Epoch 200 | Train Loss 0.672920 | Val Loss 0.607255
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch16_r0.9_seed6590.keras
# weights/model_arch16_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7712, MSE = 5.2075e-02
# Theta | Train_2 -> R² = 0.5778, MSE = 9.6382e-02
# Theta | Test_1 -> R² = 0.4661, MSE = 1.2232e-01
# Theta | Test_2 -> R² = 0.8799, MSE = 2.8490e-02
# Theta | Test_3 -> R² = -0.0940, MSE = 3.5883e-01
# Theta | Val -> R² = -8.3404, MSE = 3.0490e+00
# Theta | LSG_1 -> R² = 0.2746, MSE = 3.0283e-01
# Theta | LSG_2 -> R² = -3.1822, MSE = 1.4638e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.981509 | Val Loss 0.833788
# Epoch 100 | Train Loss 0.686085 | Val Loss 0.650404
# Epoch 200 | Train Loss 0.671689 | Val Loss 0.609415
# Early stopping at epoch 264
# Modelo salvo em:
# models/model_arch16_r0.9_seed1209.keras
# weights/model_arch16_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.8055, MSE = 4.4258e-02
# Theta | Train_2 -> R² = 0.5891, MSE = 9.3792e-02
# Theta | Test_1 -> R² = 0.5660, MSE = 9.9432e-02
# Theta | Test_2 -> R² = 0.8675, MSE = 3.1411e-02
# Theta | Test_3 -> R² = -0.3456, MSE = 4.4138e-01
# Theta | Val -> R² = -9.9683, MSE = 3.5804e+00
# Theta | LSG_1 -> R² = 0.0493, MSE = 3.9687e-01
# Theta | LSG_2 -> R² = -3.8756, MSE = 1.7065e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.967169 | Val Loss 0.815629
# Epoch 100 | Train Loss 0.686153 | Val Loss 0.619915
# Epoch 200 | Train Loss 0.674958 | Val Loss 0.600193
# Early stopping at epoch 261
# Modelo salvo em:
# models/model_arch16_r0.9_seed2894.keras
# weights/model_arch16_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7743, MSE = 5.1361e-02
# Theta | Train_2 -> R² = 0.5394, MSE = 1.0515e-01
# Theta | Test_1 -> R² = 0.3898, MSE = 1.3979e-01
# Theta | Test_2 -> R² = 0.8704, MSE = 3.0722e-02
# Theta | Test_3 -> R² = 0.1637, MSE = 2.7433e-01
# Theta | Val -> R² = -7.7993, MSE = 2.8724e+00
# Theta | LSG_1 -> R² = 0.3176, MSE = 2.8489e-01
# Theta | LSG_2 -> R² = -3.0347, MSE = 1.4122e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 0.976601 | Val Loss 0.823975
# Epoch 100 | Train Loss 0.682772 | Val Loss 0.627906
# Epoch 200 | Train Loss 0.669592 | Val Loss 0.604225
# Early stopping at epoch 259
# Modelo salvo em:
# models/model_arch16_r0.9_seed4968.keras
# weights/model_arch16_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7938, MSE = 4.6922e-02
# Theta | Train_2 -> R² = 0.6099, MSE = 8.9051e-02
# Theta | Test_1 -> R² = 0.4896, MSE = 1.1693e-01
# Theta | Test_2 -> R² = 0.8769, MSE = 2.9179e-02
# Theta | Test_3 -> R² = -0.1838, MSE = 3.8831e-01
# Theta | Val -> R² = -9.0006, MSE = 3.2645e+00
# Theta | LSG_1 -> R² = 0.1457, MSE = 3.5663e-01
# Theta | LSG_2 -> R² = -3.7696, MSE = 1.6694e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.959165 | Val Loss 0.803497
# Epoch 100 | Train Loss 0.682613 | Val Loss 0.613317
# Epoch 200 | Train Loss 0.670829 | Val Loss 0.595206
# Early stopping at epoch 256
# Modelo salvo em:
# models/model_arch16_r0.9_seed7530.keras
# weights/model_arch16_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7874, MSE = 4.8392e-02
# Theta | Train_2 -> R² = 0.5722, MSE = 9.7665e-02
# Theta | Test_1 -> R² = 0.4804, MSE = 1.1903e-01
# Theta | Test_2 -> R² = 0.8794, MSE = 2.8596e-02
# Theta | Test_3 -> R² = 0.0524, MSE = 3.1084e-01
# Theta | Val -> R² = -7.7331, MSE = 2.8508e+00
# Theta | LSG_1 -> R² = 0.3298, MSE = 2.7978e-01
# Theta | LSG_2 -> R² = -3.0157, MSE = 1.4055e+00
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 0.995984 | Val Loss 0.800571
# Epoch 100 | Train Loss 0.759273 | Val Loss 0.552540
# Epoch 200 | Train Loss 0.671681 | Val Loss 0.531530
# Epoch 300 | Train Loss 0.653306 | Val Loss 0.544499
# Epoch 400 | Train Loss 0.640176 | Val Loss 0.602647
# Early stopping at epoch 422
# Modelo salvo em:
# models/model_arch32_r0.01_seed6590.keras
# weights/model_arch32_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.8107, MSE = 4.3089e-02
# Theta | Train_2 -> R² = 0.7222, MSE = 6.3412e-02
# Theta | Test_1 -> R² = 0.6401, MSE = 8.2451e-02
# Theta | Test_2 -> R² = 0.8390, MSE = 3.8169e-02
# Theta | Test_3 -> R² = 0.7527, MSE = 8.1132e-02
# Theta | Val -> R² = 0.5771, MSE = 1.3806e-01
# Theta | LSG_1 -> R² = 0.6011, MSE = 1.6654e-01
# Theta | LSG_2 -> R² = -0.9219, MSE = 6.7268e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.961600 | Val Loss 0.747250
# Epoch 100 | Train Loss 0.747193 | Val Loss 0.550617
# Epoch 200 | Train Loss 0.662831 | Val Loss 0.536656
# Epoch 300 | Train Loss 0.638456 | Val Loss 0.601069
# Early stopping at epoch 385
# Modelo salvo em:
# models/model_arch32_r0.01_seed1209.keras
# weights/model_arch32_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.8252, MSE = 3.9779e-02
# Theta | Train_2 -> R² = 0.7153, MSE = 6.5000e-02
# Theta | Test_1 -> R² = 0.6186, MSE = 8.7380e-02
# Theta | Test_2 -> R² = 0.8634, MSE = 3.2382e-02
# Theta | Test_3 -> R² = 0.7568, MSE = 7.9764e-02
# Theta | Val -> R² = 0.5684, MSE = 1.4090e-01
# Theta | LSG_1 -> R² = 0.6682, MSE = 1.3852e-01
# Theta | LSG_2 -> R² = -1.4579, MSE = 8.6027e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.990890 | Val Loss 0.820035
# Epoch 100 | Train Loss 0.722619 | Val Loss 0.546134
# Epoch 200 | Train Loss 0.667516 | Val Loss 0.531268
# Epoch 300 | Train Loss 0.650861 | Val Loss 0.559994
# Early stopping at epoch 383
# Modelo salvo em:
# models/model_arch32_r0.01_seed2894.keras
# weights/model_arch32_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7950, MSE = 4.6658e-02
# Theta | Train_2 -> R² = 0.7099, MSE = 6.6231e-02
# Theta | Test_1 -> R² = 0.5461, MSE = 1.0398e-01
# Theta | Test_2 -> R² = 0.8464, MSE = 3.6414e-02
# Theta | Test_3 -> R² = 0.7533, MSE = 8.0911e-02
# Theta | Val -> R² = 0.2403, MSE = 2.4798e-01
# Theta | LSG_1 -> R² = 0.7425, MSE = 1.0748e-01
# Theta | LSG_2 -> R² = -1.4672, MSE = 8.6355e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 1.003529 | Val Loss 0.832093
# Epoch 100 | Train Loss 0.720500 | Val Loss 0.543456
# Epoch 200 | Train Loss 0.664115 | Val Loss 0.535581
# Epoch 300 | Train Loss 0.651188 | Val Loss 0.543949
# Early stopping at epoch 321
# Modelo salvo em:
# models/model_arch32_r0.01_seed4968.keras
# weights/model_arch32_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7578, MSE = 5.5121e-02
# Theta | Train_2 -> R² = 0.6495, MSE = 8.0024e-02
# Theta | Test_1 -> R² = 0.2454, MSE = 1.7287e-01
# Theta | Test_2 -> R² = 0.8423, MSE = 3.7399e-02
# Theta | Test_3 -> R² = 0.6715, MSE = 1.0774e-01
# Theta | Val -> R² = -3.3447, MSE = 1.4182e+00
# Theta | LSG_1 -> R² = 0.3044, MSE = 2.9039e-01
# Theta | LSG_2 -> R² = -4.6872, MSE = 1.9905e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 0.977489 | Val Loss 0.828416
# Epoch 100 | Train Loss 0.736371 | Val Loss 0.545046
# Epoch 200 | Train Loss 0.664922 | Val Loss 0.525016
# Epoch 300 | Train Loss 0.652152 | Val Loss 0.545502
# Epoch 400 | Train Loss 0.626679 | Val Loss 0.661451
# Early stopping at epoch 406
# Modelo salvo em:
# models/model_arch32_r0.01_seed7530.keras
# weights/model_arch32_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.8145, MSE = 4.2226e-02
# Theta | Train_2 -> R² = 0.7093, MSE = 6.6369e-02
# Theta | Test_1 -> R² = 0.6057, MSE = 9.0316e-02
# Theta | Test_2 -> R² = 0.8456, MSE = 3.6616e-02
# Theta | Test_3 -> R² = 0.7099, MSE = 9.5154e-02
# Theta | Val -> R² = 0.2328, MSE = 2.5045e-01
# Theta | LSG_1 -> R² = 0.6821, MSE = 1.3271e-01
# Theta | LSG_2 -> R² = -1.2963, MSE = 8.0371e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.980898 | Val Loss 0.807534
# Epoch 100 | Train Loss 0.752548 | Val Loss 0.549975
# Epoch 200 | Train Loss 0.668038 | Val Loss 0.538181
# Epoch 300 | Train Loss 0.652168 | Val Loss 0.575218
# Epoch 400 | Train Loss 0.637304 | Val Loss 0.672933
# Early stopping at epoch 408
# Modelo salvo em:
# models/model_arch32_r0.9_seed6590.keras
# weights/model_arch32_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.8244, MSE = 3.9972e-02
# Theta | Train_2 -> R² = 0.7262, MSE = 6.2495e-02
# Theta | Test_1 -> R² = 0.6426, MSE = 8.1868e-02
# Theta | Test_2 -> R² = 0.8616, MSE = 3.2821e-02
# Theta | Test_3 -> R² = 0.7524, MSE = 8.1219e-02
# Theta | Val -> R² = 0.5324, MSE = 1.5264e-01
# Theta | LSG_1 -> R² = 0.5824, MSE = 1.7434e-01
# Theta | LSG_2 -> R² = -1.1142, MSE = 7.3997e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.988434 | Val Loss 0.823211
# Epoch 100 | Train Loss 0.730058 | Val Loss 0.539459
# Epoch 200 | Train Loss 0.664118 | Val Loss 0.531473
# Epoch 300 | Train Loss 0.644525 | Val Loss 0.555681
# Early stopping at epoch 341
# Modelo salvo em:
# models/model_arch32_r0.9_seed1209.keras
# weights/model_arch32_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7809, MSE = 4.9873e-02
# Theta | Train_2 -> R² = 0.6762, MSE = 7.3911e-02
# Theta | Test_1 -> R² = 0.4820, MSE = 1.1867e-01
# Theta | Test_2 -> R² = 0.8642, MSE = 3.2202e-02
# Theta | Test_3 -> R² = 0.5825, MSE = 1.3694e-01
# Theta | Val -> R² = -1.6163, MSE = 8.5404e-01
# Theta | LSG_1 -> R² = 0.7110, MSE = 1.2065e-01
# Theta | LSG_2 -> R² = -2.8506, MSE = 1.3477e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 1.003039 | Val Loss 0.846134
# Epoch 100 | Train Loss 0.749936 | Val Loss 0.552642
# Epoch 200 | Train Loss 0.665423 | Val Loss 0.556145
# Epoch 300 | Train Loss 0.651426 | Val Loss 0.574730
# Early stopping at epoch 327
# Modelo salvo em:
# models/model_arch32_r0.9_seed2894.keras
# weights/model_arch32_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7472, MSE = 5.7539e-02
# Theta | Train_2 -> R² = 0.5902, MSE = 9.3554e-02
# Theta | Test_1 -> R² = 0.2575, MSE = 1.7010e-01
# Theta | Test_2 -> R² = 0.8467, MSE = 3.6352e-02
# Theta | Test_3 -> R² = 0.6786, MSE = 1.0543e-01
# Theta | Val -> R² = -3.1047, MSE = 1.3399e+00
# Theta | LSG_1 -> R² = 0.3258, MSE = 2.8147e-01
# Theta | LSG_2 -> R² = -4.4038, MSE = 1.8914e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 1.027649 | Val Loss 0.847076
# Epoch 100 | Train Loss 0.733551 | Val Loss 0.550786
# Epoch 200 | Train Loss 0.668242 | Val Loss 0.527851
# Epoch 300 | Train Loss 0.654955 | Val Loss 0.553507
# Early stopping at epoch 400
# Modelo salvo em:
# models/model_arch32_r0.9_seed4968.keras
# weights/model_arch32_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.8293, MSE = 3.8852e-02
# Theta | Train_2 -> R² = 0.7171, MSE = 6.4576e-02
# Theta | Test_1 -> R² = 0.5813, MSE = 9.5916e-02
# Theta | Test_2 -> R² = 0.8604, MSE = 3.3092e-02
# Theta | Test_3 -> R² = 0.7541, MSE = 8.0663e-02
# Theta | Val -> R² = -0.3909, MSE = 4.5402e-01
# Theta | LSG_1 -> R² = 0.7703, MSE = 9.5904e-02
# Theta | LSG_2 -> R² = -2.5142, MSE = 1.2300e+00
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 1.001219 | Val Loss 0.868404
# Epoch 100 | Train Loss 0.721902 | Val Loss 0.541581
# Epoch 200 | Train Loss 0.664856 | Val Loss 0.534932
# Epoch 300 | Train Loss 0.651045 | Val Loss 0.591688
# Early stopping at epoch 396
# Modelo salvo em:
# models/model_arch32_r0.9_seed7530.keras
# weights/model_arch32_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.8208, MSE = 4.0791e-02
# Theta | Train_2 -> R² = 0.7186, MSE = 6.4247e-02
# Theta | Test_1 -> R² = 0.6211, MSE = 8.6788e-02
# Theta | Test_2 -> R² = 0.8586, MSE = 3.3519e-02
# Theta | Test_3 -> R² = 0.7614, MSE = 7.8281e-02
# Theta | Val -> R² = 0.5739, MSE = 1.3908e-01
# Theta | LSG_1 -> R² = 0.5270, MSE = 1.9746e-01
# Theta | LSG_2 -> R² = -0.9427, MSE = 6.7994e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 1.004826 | Val Loss 0.842988
# Epoch 100 | Train Loss 0.679975 | Val Loss 0.611581
# Epoch 200 | Train Loss 0.666761 | Val Loss 0.586299
# Epoch 300 | Train Loss 0.628288 | Val Loss 0.593531
# Epoch 400 | Train Loss 0.543140 | Val Loss 0.782614
# Early stopping at epoch 463
# Modelo salvo em:
# models/model_arch32_r0.01_seed6590.keras
# weights/model_arch32_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7378, MSE = 5.9674e-02
# Theta | Train_2 -> R² = 0.8170, MSE = 4.1779e-02
# Theta | Test_1 -> R² = 0.3265, MSE = 1.5429e-01
# Theta | Test_2 -> R² = 0.6968, MSE = 7.1894e-02
# Theta | Test_3 -> R² = -1.5726, MSE = 8.4385e-01
# Theta | Val -> R² = -6.3419, MSE = 2.3966e+00
# Theta | LSG_1 -> R² = 0.0843, MSE = 3.8227e-01
# Theta | LSG_2 -> R² = -6.0251, MSE = 2.4588e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.984381 | Val Loss 0.833263
# Epoch 100 | Train Loss 0.680321 | Val Loss 0.617858
# Epoch 200 | Train Loss 0.667201 | Val Loss 0.587246
# Epoch 300 | Train Loss 0.642613 | Val Loss 0.577529
# Epoch 400 | Train Loss 0.549362 | Val Loss 0.756289
# Early stopping at epoch 472
# Modelo salvo em:
# models/model_arch32_r0.01_seed1209.keras
# weights/model_arch32_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7227, MSE = 6.3100e-02
# Theta | Train_2 -> R² = 0.8083, MSE = 4.3760e-02
# Theta | Test_1 -> R² = 0.2409, MSE = 1.7389e-01
# Theta | Test_2 -> R² = 0.6958, MSE = 7.2136e-02
# Theta | Test_3 -> R² = -1.6457, MSE = 8.6784e-01
# Theta | Val -> R² = -5.9827, MSE = 2.2794e+00
# Theta | LSG_1 -> R² = 0.2565, MSE = 3.1037e-01
# Theta | LSG_2 -> R² = -5.0422, MSE = 2.1148e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.995399 | Val Loss 0.834641
# Epoch 100 | Train Loss 0.679557 | Val Loss 0.624164
# Epoch 200 | Train Loss 0.662293 | Val Loss 0.589414
# Early stopping at epoch 240
# Modelo salvo em:
# models/model_arch32_r0.01_seed2894.keras
# weights/model_arch32_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.8036, MSE = 4.4698e-02
# Theta | Train_2 -> R² = 0.5161, MSE = 1.1046e-01
# Theta | Test_1 -> R² = 0.6820, MSE = 7.2846e-02
# Theta | Test_2 -> R² = 0.8090, MSE = 4.5298e-02
# Theta | Test_3 -> R² = -0.7393, MSE = 5.7053e-01
# Theta | Val -> R² = -10.9045, MSE = 3.8860e+00
# Theta | LSG_1 -> R² = 0.1466, MSE = 3.5626e-01
# Theta | LSG_2 -> R² = -3.1781, MSE = 1.4624e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 1.034078 | Val Loss 0.866608
# Epoch 100 | Train Loss 0.683810 | Val Loss 0.636436
# Epoch 200 | Train Loss 0.667873 | Val Loss 0.596287
# Epoch 300 | Train Loss 0.648558 | Val Loss 0.574160
# Epoch 400 | Train Loss 0.571317 | Val Loss 0.709968
# Early stopping at epoch 484
# Modelo salvo em:
# models/model_arch32_r0.01_seed4968.keras
# weights/model_arch32_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7189, MSE = 6.3971e-02
# Theta | Train_2 -> R² = 0.8058, MSE = 4.4339e-02
# Theta | Test_1 -> R² = 0.3389, MSE = 1.5144e-01
# Theta | Test_2 -> R² = 0.6945, MSE = 7.2445e-02
# Theta | Test_3 -> R² = -1.4533, MSE = 8.0473e-01
# Theta | Val -> R² = -5.4446, MSE = 2.1037e+00
# Theta | LSG_1 -> R² = 0.1884, MSE = 3.3879e-01
# Theta | LSG_2 -> R² = -5.4964, MSE = 2.2738e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 1.000871 | Val Loss 0.866792
# Epoch 100 | Train Loss 0.677767 | Val Loss 0.602679
# Epoch 200 | Train Loss 0.659200 | Val Loss 0.588413
# Early stopping at epoch 242
# Modelo salvo em:
# models/model_arch32_r0.01_seed7530.keras
# weights/model_arch32_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7807, MSE = 4.9911e-02
# Theta | Train_2 -> R² = 0.5392, MSE = 1.0520e-01
# Theta | Test_1 -> R² = 0.5597, MSE = 1.0087e-01
# Theta | Test_2 -> R² = 0.8377, MSE = 3.8483e-02
# Theta | Test_3 -> R² = -0.4653, MSE = 4.8063e-01
# Theta | Val -> R² = -9.4745, MSE = 3.4192e+00
# Theta | LSG_1 -> R² = 0.2166, MSE = 3.2704e-01
# Theta | LSG_2 -> R² = -3.2670, MSE = 1.4935e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.980693 | Val Loss 0.807956
# Epoch 100 | Train Loss 0.680062 | Val Loss 0.610859
# Epoch 200 | Train Loss 0.665287 | Val Loss 0.587410
# Early stopping at epoch 236
# Modelo salvo em:
# models/model_arch32_r0.9_seed6590.keras
# weights/model_arch32_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7363, MSE = 6.0019e-02
# Theta | Train_2 -> R² = 0.4923, MSE = 1.1590e-01
# Theta | Test_1 -> R² = 0.5097, MSE = 1.1231e-01
# Theta | Test_2 -> R² = 0.7946, MSE = 4.8715e-02
# Theta | Test_3 -> R² = -0.6513, MSE = 5.4165e-01
# Theta | Val -> R² = -10.1555, MSE = 3.6415e+00
# Theta | LSG_1 -> R² = 0.1269, MSE = 3.6447e-01
# Theta | LSG_2 -> R² = -3.4695, MSE = 1.5643e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.953367 | Val Loss 0.777604
# Epoch 100 | Train Loss 0.681597 | Val Loss 0.619271
# Epoch 200 | Train Loss 0.663998 | Val Loss 0.589425
# Early stopping at epoch 228
# Modelo salvo em:
# models/model_arch32_r0.9_seed1209.keras
# weights/model_arch32_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7639, MSE = 5.3737e-02
# Theta | Train_2 -> R² = 0.5188, MSE = 1.0985e-01
# Theta | Test_1 -> R² = 0.5931, MSE = 9.3205e-02
# Theta | Test_2 -> R² = 0.8254, MSE = 4.1394e-02
# Theta | Test_3 -> R² = -0.5865, MSE = 5.2040e-01
# Theta | Val -> R² = -9.9017, MSE = 3.5587e+00
# Theta | LSG_1 -> R² = 0.1813, MSE = 3.4177e-01
# Theta | LSG_2 -> R² = -3.2035, MSE = 1.4712e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.960071 | Val Loss 0.809131
# Epoch 100 | Train Loss 0.679054 | Val Loss 0.619107
# Epoch 200 | Train Loss 0.665965 | Val Loss 0.589655
# Early stopping at epoch 233
# Modelo salvo em:
# models/model_arch32_r0.9_seed2894.keras
# weights/model_arch32_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7545, MSE = 5.5864e-02
# Theta | Train_2 -> R² = 0.5547, MSE = 1.0166e-01
# Theta | Test_1 -> R² = 0.5654, MSE = 9.9558e-02
# Theta | Test_2 -> R² = 0.8364, MSE = 3.8784e-02
# Theta | Test_3 -> R² = -0.8745, MSE = 6.1486e-01
# Theta | Val -> R² = -10.9837, MSE = 3.9118e+00
# Theta | LSG_1 -> R² = 0.0601, MSE = 3.9238e-01
# Theta | LSG_2 -> R² = -3.6892, MSE = 1.6412e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 0.977849 | Val Loss 0.810255
# Epoch 100 | Train Loss 0.678075 | Val Loss 0.611163
# Epoch 200 | Train Loss 0.664912 | Val Loss 0.571898
# Epoch 300 | Train Loss 0.640076 | Val Loss 0.568628
# Epoch 400 | Train Loss 0.552683 | Val Loss 0.791439
# Early stopping at epoch 459
# Modelo salvo em:
# models/model_arch32_r0.9_seed4968.keras
# weights/model_arch32_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.6551, MSE = 7.8490e-02
# Theta | Train_2 -> R² = 0.8170, MSE = 4.1768e-02
# Theta | Test_1 -> R² = 0.2886, MSE = 1.6297e-01
# Theta | Test_2 -> R² = 0.5793, MSE = 9.9766e-02
# Theta | Test_3 -> R² = -2.9158, MSE = 1.2845e+00
# Theta | Val -> R² = -4.3752, MSE = 1.7546e+00
# Theta | LSG_1 -> R² = 0.4307, MSE = 2.3768e-01
# Theta | LSG_2 -> R² = -3.7063, MSE = 1.6472e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.986898 | Val Loss 0.849583
# Epoch 100 | Train Loss 0.680833 | Val Loss 0.624982
# Epoch 200 | Train Loss 0.661687 | Val Loss 0.604114
# Early stopping at epoch 237
# Modelo salvo em:
# models/model_arch32_r0.9_seed7530.keras
# weights/model_arch32_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7494, MSE = 5.7029e-02
# Theta | Train_2 -> R² = 0.4762, MSE = 1.1959e-01
# Theta | Test_1 -> R² = 0.5321, MSE = 1.0719e-01
# Theta | Test_2 -> R² = 0.7932, MSE = 4.9033e-02
# Theta | Test_3 -> R² = -0.5662, MSE = 5.1375e-01
# Theta | Val -> R² = -10.0619, MSE = 3.6110e+00
# Theta | LSG_1 -> R² = 0.1564, MSE = 3.5216e-01
# Theta | LSG_2 -> R² = -3.2739, MSE = 1.4959e+00
# Modelo [32] | Ld=0.7 Lp=0.3 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 0.981808 | Val Loss 0.790953
# Epoch 100 | Train Loss 0.677599 | Val Loss 0.533748
# Epoch 200 | Train Loss 0.653753 | Val Loss 0.517625
# Epoch 300 | Train Loss 0.620835 | Val Loss 0.616236
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch64_r0.01_seed6590.keras
# weights/model_arch64_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.8038, MSE = 4.4660e-02
# Theta | Train_2 -> R² = 0.7243, MSE = 6.2943e-02
# Theta | Test_1 -> R² = 0.5786, MSE = 9.6531e-02
# Theta | Test_2 -> R² = 0.8519, MSE = 3.5126e-02
# Theta | Test_3 -> R² = 0.6322, MSE = 1.2064e-01
# Theta | Val -> R² = -0.1916, MSE = 3.8896e-01
# Theta | LSG_1 -> R² = 0.7109, MSE = 1.2068e-01
# Theta | LSG_2 -> R² = -1.9562, MSE = 1.0347e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.951797 | Val Loss 0.736750
# Epoch 100 | Train Loss 0.674535 | Val Loss 0.529892
# Epoch 200 | Train Loss 0.651079 | Val Loss 0.511683
# Epoch 300 | Train Loss 0.599786 | Val Loss 0.768170
# Early stopping at epoch 381
# Modelo salvo em:
# models/model_arch64_r0.01_seed1209.keras
# weights/model_arch64_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7960, MSE = 4.6430e-02
# Theta | Train_2 -> R² = 0.7195, MSE = 6.4023e-02
# Theta | Test_1 -> R² = 0.5926, MSE = 9.3317e-02
# Theta | Test_2 -> R² = 0.8495, MSE = 3.5691e-02
# Theta | Test_3 -> R² = 0.5919, MSE = 1.3386e-01
# Theta | Val -> R² = -0.1592, MSE = 3.7839e-01
# Theta | LSG_1 -> R² = 0.6976, MSE = 1.2625e-01
# Theta | LSG_2 -> R² = -1.7976, MSE = 9.7917e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.992167 | Val Loss 0.763434
# Epoch 100 | Train Loss 0.675422 | Val Loss 0.534171
# Epoch 200 | Train Loss 0.653623 | Val Loss 0.515265
# Epoch 300 | Train Loss 0.642850 | Val Loss 0.595280
# Early stopping at epoch 375
# Modelo salvo em:
# models/model_arch64_r0.01_seed2894.keras
# weights/model_arch64_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.8047, MSE = 4.4451e-02
# Theta | Train_2 -> R² = 0.7176, MSE = 6.4466e-02
# Theta | Test_1 -> R² = 0.5611, MSE = 1.0055e-01
# Theta | Test_2 -> R² = 0.8593, MSE = 3.3375e-02
# Theta | Test_3 -> R² = 0.5664, MSE = 1.4223e-01
# Theta | Val -> R² = -0.7245, MSE = 5.6293e-01
# Theta | LSG_1 -> R² = 0.7368, MSE = 1.0987e-01
# Theta | LSG_2 -> R² = -2.2783, MSE = 1.1474e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 1.011833 | Val Loss 0.774679
# Epoch 100 | Train Loss 0.676411 | Val Loss 0.525848
# Epoch 200 | Train Loss 0.656206 | Val Loss 0.502578
# Epoch 300 | Train Loss 0.650247 | Val Loss 0.503405
# Epoch 400 | Train Loss 0.635099 | Val Loss 0.581709
# Early stopping at epoch 439
# Modelo salvo em:
# models/model_arch64_r0.01_seed4968.keras
# weights/model_arch64_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7968, MSE = 4.6240e-02
# Theta | Train_2 -> R² = 0.7197, MSE = 6.3988e-02
# Theta | Test_1 -> R² = 0.6078, MSE = 8.9853e-02
# Theta | Test_2 -> R² = 0.8400, MSE = 3.7945e-02
# Theta | Test_3 -> R² = 0.4627, MSE = 1.7625e-01
# Theta | Val -> R² = -0.2875, MSE = 4.2030e-01
# Theta | LSG_1 -> R² = 0.6780, MSE = 1.3440e-01
# Theta | LSG_2 -> R² = -1.6005, MSE = 9.1018e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 0.966472 | Val Loss 0.755444
# Epoch 100 | Train Loss 0.674371 | Val Loss 0.533068
# Epoch 200 | Train Loss 0.653584 | Val Loss 0.519195
# Epoch 300 | Train Loss 0.632190 | Val Loss 0.598472
# Early stopping at epoch 397
# Modelo salvo em:
# models/model_arch64_r0.01_seed7530.keras
# weights/model_arch64_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.8010, MSE = 4.5278e-02
# Theta | Train_2 -> R² = 0.7458, MSE = 5.8020e-02
# Theta | Test_1 -> R² = 0.6199, MSE = 8.7065e-02
# Theta | Test_2 -> R² = 0.8484, MSE = 3.5938e-02
# Theta | Test_3 -> R² = 0.4581, MSE = 1.7774e-01
# Theta | Val -> R² = -0.0159, MSE = 3.3164e-01
# Theta | LSG_1 -> R² = 0.6064, MSE = 1.6433e-01
# Theta | LSG_2 -> R² = -1.6555, MSE = 9.2943e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.982979 | Val Loss 0.776852
# Epoch 100 | Train Loss 0.680722 | Val Loss 0.535783
# Epoch 200 | Train Loss 0.654779 | Val Loss 0.517023
# Epoch 300 | Train Loss 0.643597 | Val Loss 0.588941
# Early stopping at epoch 364
# Modelo salvo em:
# models/model_arch64_r0.9_seed6590.keras
# weights/model_arch64_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.8143, MSE = 4.2258e-02
# Theta | Train_2 -> R² = 0.7269, MSE = 6.2337e-02
# Theta | Test_1 -> R² = 0.5878, MSE = 9.4420e-02
# Theta | Test_2 -> R² = 0.8559, MSE = 3.4160e-02
# Theta | Test_3 -> R² = 0.6767, MSE = 1.0606e-01
# Theta | Val -> R² = -0.5294, MSE = 4.9925e-01
# Theta | LSG_1 -> R² = 0.7616, MSE = 9.9520e-02
# Theta | LSG_2 -> R² = -2.3208, MSE = 1.1623e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 1.039523 | Val Loss 0.816125
# Epoch 100 | Train Loss 0.688819 | Val Loss 0.530303
# Epoch 200 | Train Loss 0.655255 | Val Loss 0.512458
# Epoch 300 | Train Loss 0.643620 | Val Loss 0.553214
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch64_r0.9_seed1209.keras
# weights/model_arch64_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.8016, MSE = 4.5161e-02
# Theta | Train_2 -> R² = 0.7260, MSE = 6.2543e-02
# Theta | Test_1 -> R² = 0.5676, MSE = 9.9062e-02
# Theta | Test_2 -> R² = 0.8517, MSE = 3.5155e-02
# Theta | Test_3 -> R² = 0.5224, MSE = 1.5665e-01
# Theta | Val -> R² = -0.5759, MSE = 5.1442e-01
# Theta | LSG_1 -> R² = 0.7282, MSE = 1.1347e-01
# Theta | LSG_2 -> R² = -2.0852, MSE = 1.0798e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.984414 | Val Loss 0.759553
# Epoch 100 | Train Loss 0.673758 | Val Loss 0.530706
# Epoch 200 | Train Loss 0.654657 | Val Loss 0.511042
# Epoch 300 | Train Loss 0.645578 | Val Loss 0.525580
# Early stopping at epoch 370
# Modelo salvo em:
# models/model_arch64_r0.9_seed2894.keras
# weights/model_arch64_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7999, MSE = 4.5546e-02
# Theta | Train_2 -> R² = 0.7127, MSE = 6.5597e-02
# Theta | Test_1 -> R² = 0.5437, MSE = 1.0453e-01
# Theta | Test_2 -> R² = 0.8557, MSE = 3.4209e-02
# Theta | Test_3 -> R² = 0.5778, MSE = 1.3848e-01
# Theta | Val -> R² = -0.7741, MSE = 5.7911e-01
# Theta | LSG_1 -> R² = 0.7609, MSE = 9.9827e-02
# Theta | LSG_2 -> R² = -2.3935, MSE = 1.1878e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 0.986569 | Val Loss 0.775881
# Epoch 100 | Train Loss 0.674437 | Val Loss 0.531285
# Epoch 200 | Train Loss 0.654390 | Val Loss 0.517148
# Epoch 300 | Train Loss 0.641575 | Val Loss 0.566672
# Early stopping at epoch 373
# Modelo salvo em:
# models/model_arch64_r0.9_seed4968.keras
# weights/model_arch64_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.7980, MSE = 4.5983e-02
# Theta | Train_2 -> R² = 0.7129, MSE = 6.5533e-02
# Theta | Test_1 -> R² = 0.5343, MSE = 1.0667e-01
# Theta | Test_2 -> R² = 0.8463, MSE = 3.6446e-02
# Theta | Test_3 -> R² = 0.6670, MSE = 1.0924e-01
# Theta | Val -> R² = -0.3553, MSE = 4.4240e-01
# Theta | LSG_1 -> R² = 0.7561, MSE = 1.0180e-01
# Theta | LSG_2 -> R² = -2.2642, MSE = 1.1425e+00
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.956298 | Val Loss 0.737661
# Epoch 100 | Train Loss 0.675871 | Val Loss 0.532760
# Epoch 200 | Train Loss 0.652969 | Val Loss 0.513594
# Epoch 300 | Train Loss 0.601687 | Val Loss 0.745287
# Epoch 400 | Train Loss 0.570333 | Val Loss 0.902267
# Early stopping at epoch 409
# Modelo salvo em:
# models/model_arch64_r0.9_seed7530.keras
# weights/model_arch64_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7545, MSE = 5.5877e-02
# Theta | Train_2 -> R² = 0.7561, MSE = 5.5672e-02
# Theta | Test_1 -> R² = 0.5720, MSE = 9.8052e-02
# Theta | Test_2 -> R² = 0.8524, MSE = 3.4993e-02
# Theta | Test_3 -> R² = 0.2719, MSE = 2.3881e-01
# Theta | Val -> R² = 0.0739, MSE = 3.0230e-01
# Theta | LSG_1 -> R² = 0.5682, MSE = 1.8026e-01
# Theta | LSG_2 -> R² = -1.5220, MSE = 8.8272e-01
# Modelo [64] | Ld=0.3 Lp=0.7 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 0.995837 | Val Loss 0.790440
# Epoch 100 | Train Loss 0.677872 | Val Loss 0.617189
# Epoch 200 | Train Loss 0.658426 | Val Loss 0.567692
# Epoch 300 | Train Loss 0.561553 | Val Loss 0.692737
# Epoch 400 | Train Loss 0.525193 | Val Loss 0.854444
# Early stopping at epoch 419
# Modelo salvo em:
# models/model_arch64_r0.01_seed6590.keras
# weights/model_arch64_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.6902, MSE = 7.0508e-02
# Theta | Train_2 -> R² = 0.8248, MSE = 3.9990e-02
# Theta | Test_1 -> R² = 0.3147, MSE = 1.5698e-01
# Theta | Test_2 -> R² = 0.6466, MSE = 8.3801e-02
# Theta | Test_3 -> R² = -2.6257, MSE = 1.1893e+00
# Theta | Val -> R² = -6.3149, MSE = 2.3878e+00
# Theta | LSG_1 -> R² = 0.2216, MSE = 3.2495e-01
# Theta | LSG_2 -> R² = -4.9383, MSE = 2.0784e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.945505 | Val Loss 0.731448
# Epoch 100 | Train Loss 0.677439 | Val Loss 0.609780
# Epoch 200 | Train Loss 0.655371 | Val Loss 0.568909
# Epoch 300 | Train Loss 0.546733 | Val Loss 0.811403
# Epoch 400 | Train Loss 0.520062 | Val Loss 0.882930
# Early stopping at epoch 402
# Modelo salvo em:
# models/model_arch64_r0.01_seed1209.keras
# weights/model_arch64_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.6651, MSE = 7.6213e-02
# Theta | Train_2 -> R² = 0.8249, MSE = 3.9976e-02
# Theta | Test_1 -> R² = 0.3053, MSE = 1.5913e-01
# Theta | Test_2 -> R² = 0.6191, MSE = 9.0314e-02
# Theta | Test_3 -> R² = -2.7276, MSE = 1.2227e+00
# Theta | Val -> R² = -5.8258, MSE = 2.2281e+00
# Theta | LSG_1 -> R² = 0.1305, MSE = 3.6296e-01
# Theta | LSG_2 -> R² = -4.7476, MSE = 2.0117e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 1.007477 | Val Loss 0.810625
# Epoch 100 | Train Loss 0.677533 | Val Loss 0.616465
# Epoch 200 | Train Loss 0.631587 | Val Loss 0.588383
# Epoch 300 | Train Loss 0.549980 | Val Loss 0.759982
# Early stopping at epoch 379
# Modelo salvo em:
# models/model_arch64_r0.01_seed2894.keras
# weights/model_arch64_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.6726, MSE = 7.4507e-02
# Theta | Train_2 -> R² = 0.8075, MSE = 4.3949e-02
# Theta | Test_1 -> R² = 0.1128, MSE = 2.0324e-01
# Theta | Test_2 -> R² = 0.6466, MSE = 8.3793e-02
# Theta | Test_3 -> R² = -0.9407, MSE = 6.3659e-01
# Theta | Val -> R² = -6.2855, MSE = 2.3782e+00
# Theta | LSG_1 -> R² = -0.4376, MSE = 6.0015e-01
# Theta | LSG_2 -> R² = -6.8828, MSE = 2.7590e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 0.967078 | Val Loss 0.741172
# Epoch 100 | Train Loss 0.676510 | Val Loss 0.605188
# Epoch 200 | Train Loss 0.658889 | Val Loss 0.566156
# Epoch 300 | Train Loss 0.561326 | Val Loss 0.728996
# Epoch 400 | Train Loss 0.525317 | Val Loss 0.860270
# Early stopping at epoch 410
# Modelo salvo em:
# models/model_arch64_r0.01_seed4968.keras
# weights/model_arch64_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.6535, MSE = 7.8851e-02
# Theta | Train_2 -> R² = 0.8382, MSE = 3.6948e-02
# Theta | Test_1 -> R² = 0.2708, MSE = 1.6704e-01
# Theta | Test_2 -> R² = 0.6101, MSE = 9.2447e-02
# Theta | Test_3 -> R² = -2.7315, MSE = 1.2240e+00
# Theta | Val -> R² = -6.6789, MSE = 2.5066e+00
# Theta | LSG_1 -> R² = 0.0998, MSE = 3.7580e-01
# Theta | LSG_2 -> R² = -5.2463, MSE = 2.1862e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 1.000721 | Val Loss 0.802132
# Epoch 100 | Train Loss 0.677391 | Val Loss 0.618349
# Epoch 200 | Train Loss 0.657608 | Val Loss 0.570448
# Epoch 300 | Train Loss 0.552064 | Val Loss 0.765342
# Epoch 400 | Train Loss 0.523219 | Val Loss 0.877508
# Early stopping at epoch 409
# Modelo salvo em:
# models/model_arch64_r0.01_seed7530.keras
# weights/model_arch64_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7266, MSE = 6.2224e-02
# Theta | Train_2 -> R² = 0.8128, MSE = 4.2730e-02
# Theta | Test_1 -> R² = 0.2804, MSE = 1.6484e-01
# Theta | Test_2 -> R² = 0.6913, MSE = 7.3211e-02
# Theta | Test_3 -> R² = -1.5469, MSE = 8.3543e-01
# Theta | Val -> R² = -5.6262, MSE = 2.1630e+00
# Theta | LSG_1 -> R² = 0.1761, MSE = 3.4394e-01
# Theta | LSG_2 -> R² = -5.9369, MSE = 2.4279e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.943147 | Val Loss 0.735817
# Epoch 100 | Train Loss 0.675981 | Val Loss 0.600373
# Epoch 200 | Train Loss 0.648228 | Val Loss 0.560570
# Epoch 300 | Train Loss 0.543275 | Val Loss 0.769686
# Early stopping at epoch 388
# Modelo salvo em:
# models/model_arch64_r0.9_seed6590.keras
# weights/model_arch64_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.6758, MSE = 7.3788e-02
# Theta | Train_2 -> R² = 0.8289, MSE = 3.9061e-02
# Theta | Test_1 -> R² = 0.2807, MSE = 1.6479e-01
# Theta | Test_2 -> R² = 0.6349, MSE = 8.6587e-02
# Theta | Test_3 -> R² = -2.1310, MSE = 1.0270e+00
# Theta | Val -> R² = -5.5245, MSE = 2.1298e+00
# Theta | LSG_1 -> R² = 0.2197, MSE = 3.2576e-01
# Theta | LSG_2 -> R² = -5.0234, MSE = 2.1082e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.950485 | Val Loss 0.751195
# Epoch 100 | Train Loss 0.675953 | Val Loss 0.603521
# Epoch 200 | Train Loss 0.647383 | Val Loss 0.562623
# Epoch 300 | Train Loss 0.549003 | Val Loss 0.756930
# Early stopping at epoch 392
# Modelo salvo em:
# models/model_arch64_r0.9_seed1209.keras
# weights/model_arch64_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.6710, MSE = 7.4880e-02
# Theta | Train_2 -> R² = 0.8103, MSE = 4.3307e-02
# Theta | Test_1 -> R² = 0.2620, MSE = 1.6907e-01
# Theta | Test_2 -> R² = 0.6868, MSE = 7.4274e-02
# Theta | Test_3 -> R² = -2.1556, MSE = 1.0351e+00
# Theta | Val -> R² = -5.9405, MSE = 2.2656e+00
# Theta | LSG_1 -> R² = 0.2182, MSE = 3.2635e-01
# Theta | LSG_2 -> R² = -5.1552, MSE = 2.1543e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.993299 | Val Loss 0.785823
# Epoch 100 | Train Loss 0.676990 | Val Loss 0.609261
# Epoch 200 | Train Loss 0.659519 | Val Loss 0.568507
# Epoch 300 | Train Loss 0.557970 | Val Loss 0.733191
# Epoch 400 | Train Loss 0.526581 | Val Loss 0.860235
# Early stopping at epoch 423
# Modelo salvo em:
# models/model_arch64_r0.9_seed2894.keras
# weights/model_arch64_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.7104, MSE = 6.5911e-02
# Theta | Train_2 -> R² = 0.8151, MSE = 4.2220e-02
# Theta | Test_1 -> R² = 0.3285, MSE = 1.5383e-01
# Theta | Test_2 -> R² = 0.6428, MSE = 8.4699e-02
# Theta | Test_3 -> R² = -1.9119, MSE = 9.5514e-01
# Theta | Val -> R² = -4.9259, MSE = 1.9344e+00
# Theta | LSG_1 -> R² = 0.2787, MSE = 3.0111e-01
# Theta | LSG_2 -> R² = -4.8277, MSE = 2.0397e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 1.032491 | Val Loss 0.827372
# Epoch 100 | Train Loss 0.678754 | Val Loss 0.609578
# Epoch 200 | Train Loss 0.661258 | Val Loss 0.563818
# Epoch 300 | Train Loss 0.573184 | Val Loss 0.678693
# Epoch 400 | Train Loss 0.527073 | Val Loss 0.877403
# Early stopping at epoch 436
# Modelo salvo em:
# models/model_arch64_r0.9_seed4968.keras
# weights/model_arch64_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.5999, MSE = 9.1057e-02
# Theta | Train_2 -> R² = 0.8022, MSE = 4.5163e-02
# Theta | Test_1 -> R² = 0.1868, MSE = 1.8630e-01
# Theta | Test_2 -> R² = 0.5865, MSE = 9.8059e-02
# Theta | Test_3 -> R² = -3.1549, MSE = 1.3629e+00
# Theta | Val -> R² = -6.2256, MSE = 2.3587e+00
# Theta | LSG_1 -> R² = 0.2272, MSE = 3.2260e-01
# Theta | LSG_2 -> R² = -4.2818, MSE = 1.8487e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.956396 | Val Loss 0.764416
# Epoch 100 | Train Loss 0.677181 | Val Loss 0.604374
# Epoch 200 | Train Loss 0.638057 | Val Loss 0.583205
# Epoch 300 | Train Loss 0.552516 | Val Loss 0.738776
# Early stopping at epoch 378
# Modelo salvo em:
# models/model_arch64_r0.9_seed7530.keras
# weights/model_arch64_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7697, MSE = 5.2424e-02
# Theta | Train_2 -> R² = 0.8328, MSE = 3.8164e-02
# Theta | Test_1 -> R² = 0.3353, MSE = 1.5226e-01
# Theta | Test_2 -> R² = 0.6763, MSE = 7.6763e-02
# Theta | Test_3 -> R² = -0.4543, MSE = 4.7703e-01
# Theta | Val -> R² = -5.1348, MSE = 2.0026e+00
# Theta | LSG_1 -> R² = -0.0584, MSE = 4.4183e-01
# Theta | LSG_2 -> R² = -6.5370, MSE = 2.6380e+00
# Modelo [64] | Ld=0.7 Lp=0.3 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 1.151366 | Val Loss 0.783564
# Epoch 100 | Train Loss 0.667816 | Val Loss 0.521984
# Epoch 200 | Train Loss 0.653822 | Val Loss 0.507402
# Epoch 300 | Train Loss 0.649215 | Val Loss 0.503267
# Epoch 400 | Train Loss 0.609565 | Val Loss 0.617869
# Early stopping at epoch 475
# Modelo salvo em:
# models/model_arch128_r0.01_seed6590.keras
# weights/model_arch128_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7958, MSE = 4.6477e-02
# Theta | Train_2 -> R² = 0.7158, MSE = 6.4879e-02
# Theta | Test_1 -> R² = 0.6158, MSE = 8.8013e-02
# Theta | Test_2 -> R² = 0.8407, MSE = 3.7765e-02
# Theta | Test_3 -> R² = 0.4622, MSE = 1.7641e-01
# Theta | Val -> R² = 0.0016, MSE = 3.2591e-01
# Theta | LSG_1 -> R² = 0.5951, MSE = 1.6901e-01
# Theta | LSG_2 -> R² = -1.4379, MSE = 8.5329e-01
# Modelo [128] | Ld=0.3 Lp=0.7 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 1.047933 | Val Loss 0.689422
# Epoch 100 | Train Loss 0.664598 | Val Loss 0.518026
# Epoch 200 | Train Loss 0.652274 | Val Loss 0.506244
# Epoch 300 | Train Loss 0.646695 | Val Loss 0.509032
# Epoch 400 | Train Loss 0.593855 | Val Loss 0.728710
# Early stopping at epoch 458
# Modelo salvo em:
# models/model_arch128_r0.01_seed1209.keras
# weights/model_arch128_r0.01_seed1209.weights.h5
# ...
# Theta | Test_2 -> R² = 0.8447, MSE = 3.6826e-02
# Theta | Test_3 -> R² = 0.1055, MSE = 2.9342e-01
# Theta | Val -> R² = -9.2652, MSE = 3.3509e+00
# Theta | LSG_1 -> R² = 0.0245, MSE = 4.0721e-01
# Theta | LSG_2 -> R² = -4.1667, MSE = 1.8084e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.975388 | Val Loss 0.809199
# Epoch 100 | Train Loss 0.649104 | Val Loss 0.580619
# Epoch 200 | Train Loss 0.538624 | Val Loss 0.856679
# Early stopping at epoch 232
# Modelo salvo em:
# models/model_arch128-64-32_r0.9_seed7530.keras
# weights/model_arch128-64-32_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7371, MSE = 5.9842e-02
# Theta | Train_2 -> R² = 0.6692, MSE = 7.5518e-02
# Theta | Test_1 -> R² = -0.0073, MSE = 2.3075e-01
# Theta | Test_2 -> R² = 0.7668, MSE = 5.5289e-02
# Theta | Test_3 -> R² = 0.2512, MSE = 2.4561e-01
# Theta | Val -> R² = -8.8802, MSE = 3.2252e+00
# Theta | LSG_1 -> R² = -0.2552, MSE = 5.2397e-01
# Theta | LSG_2 -> R² = -5.3113, MSE = 2.2090e+00
# Modelo [128, 64, 32] | Ld=0.7 Lp=0.3 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 1.017331 | Val Loss 0.669527
# Epoch 100 | Train Loss 0.619592 | Val Loss 0.560266
# Epoch 200 | Train Loss 0.556220 | Val Loss 0.826447
# Early stopping at epoch 267
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed6590.keras
# weights/model_arch264-128-64_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.8278, MSE = 3.9181e-02
# Theta | Train_2 -> R² = 0.7548, MSE = 5.5972e-02
# Theta | Test_1 -> R² = 0.8245, MSE = 4.0213e-02
# Theta | Test_2 -> R² = 0.8972, MSE = 2.4388e-02
# Theta | Test_3 -> R² = 0.4498, MSE = 1.8048e-01
# Theta | Val -> R² = -1.2779, MSE = 7.4358e-01
# Theta | LSG_1 -> R² = 0.7193, MSE = 1.1719e-01
# Theta | LSG_2 -> R² = -1.4084, MSE = 8.4294e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.969916 | Val Loss 0.668274
# Epoch 100 | Train Loss 0.607014 | Val Loss 0.568114
# Epoch 200 | Train Loss 0.551367 | Val Loss 0.793087
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed1209.keras
# weights/model_arch264-128-64_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7959, MSE = 4.6455e-02
# Theta | Train_2 -> R² = 0.8230, MSE = 4.0410e-02
# Theta | Test_1 -> R² = 0.7859, MSE = 4.9053e-02
# Theta | Test_2 -> R² = 0.8921, MSE = 2.5592e-02
# Theta | Test_3 -> R² = 0.5477, MSE = 1.4836e-01
# Theta | Val -> R² = -0.4518, MSE = 4.7391e-01
# Theta | LSG_1 -> R² = 0.7578, MSE = 1.0110e-01
# Theta | LSG_2 -> R² = -1.9563, MSE = 1.0347e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.973301 | Val Loss 0.643958
# Epoch 100 | Train Loss 0.613609 | Val Loss 0.607035
# Epoch 200 | Train Loss 0.553022 | Val Loss 0.791977
# Early stopping at epoch 262
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed2894.keras
# weights/model_arch264-128-64_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.8049, MSE = 4.4405e-02
# Theta | Train_2 -> R² = 0.6406, MSE = 8.2036e-02
# Theta | Test_1 -> R² = 0.7734, MSE = 5.1918e-02
# Theta | Test_2 -> R² = 0.8578, MSE = 3.3708e-02
# Theta | Test_3 -> R² = 0.7452, MSE = 8.3565e-02
# Theta | Val -> R² = -0.1475, MSE = 3.7457e-01
# Theta | LSG_1 -> R² = 0.5642, MSE = 1.8191e-01
# Theta | LSG_2 -> R² = -0.8178, MSE = 6.3626e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 0.990651 | Val Loss 0.640037
# Epoch 100 | Train Loss 0.623138 | Val Loss 0.536390
# Epoch 200 | Train Loss 0.556407 | Val Loss 0.837702
# Early stopping at epoch 271
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed4968.keras
# weights/model_arch264-128-64_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.8175, MSE = 4.1536e-02
# Theta | Train_2 -> R² = 0.7048, MSE = 6.7398e-02
# Theta | Test_1 -> R² = 0.7073, MSE = 6.7056e-02
# Theta | Test_2 -> R² = 0.8745, MSE = 2.9767e-02
# Theta | Test_3 -> R² = 0.7171, MSE = 9.2788e-02
# Theta | Val -> R² = -0.7786, MSE = 5.8058e-01
# Theta | LSG_1 -> R² = 0.7075, MSE = 1.2211e-01
# Theta | LSG_2 -> R² = -2.0184, MSE = 1.0564e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 0.968327 | Val Loss 0.651437
# Epoch 100 | Train Loss 0.624443 | Val Loss 0.549411
# Epoch 200 | Train Loss 0.550174 | Val Loss 0.811987
# Early stopping at epoch 265
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed7530.keras
# weights/model_arch264-128-64_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7997, MSE = 4.5587e-02
# Theta | Train_2 -> R² = 0.8087, MSE = 4.3674e-02
# Theta | Test_1 -> R² = 0.7101, MSE = 6.6416e-02
# Theta | Test_2 -> R² = 0.8956, MSE = 2.4757e-02
# Theta | Test_3 -> R² = 0.3166, MSE = 2.2415e-01
# Theta | Val -> R² = -1.3064, MSE = 7.5288e-01
# Theta | LSG_1 -> R² = 0.7369, MSE = 1.0982e-01
# Theta | LSG_2 -> R² = -2.4955, MSE = 1.2234e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.984945 | Val Loss 0.630577
# Epoch 100 | Train Loss 0.603606 | Val Loss 0.592090
# Epoch 200 | Train Loss 0.557517 | Val Loss 0.750169
# Early stopping at epoch 265
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed6590.keras
# weights/model_arch264-128-64_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7812, MSE = 4.9805e-02
# Theta | Train_2 -> R² = 0.7021, MSE = 6.8013e-02
# Theta | Test_1 -> R² = 0.7718, MSE = 5.2271e-02
# Theta | Test_2 -> R² = 0.8678, MSE = 3.1337e-02
# Theta | Test_3 -> R² = 0.8023, MSE = 6.4839e-02
# Theta | Val -> R² = 0.3449, MSE = 2.1385e-01
# Theta | LSG_1 -> R² = 0.6483, MSE = 1.4683e-01
# Theta | LSG_2 -> R² = -0.7847, MSE = 6.2467e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.973580 | Val Loss 0.677247
# Epoch 100 | Train Loss 0.621136 | Val Loss 0.566647
# Epoch 200 | Train Loss 0.566954 | Val Loss 0.786330
# Early stopping at epoch 268
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed1209.keras
# weights/model_arch264-128-64_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.8216, MSE = 4.0607e-02
# Theta | Train_2 -> R² = 0.7601, MSE = 5.4758e-02
# Theta | Test_1 -> R² = 0.8085, MSE = 4.3859e-02
# Theta | Test_2 -> R² = 0.8969, MSE = 2.4451e-02
# Theta | Test_3 -> R² = 0.7027, MSE = 9.7512e-02
# Theta | Val -> R² = -0.0601, MSE = 3.4605e-01
# Theta | LSG_1 -> R² = 0.5895, MSE = 1.7136e-01
# Theta | LSG_2 -> R² = -1.1867, MSE = 7.6534e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.994900 | Val Loss 0.669370
# Epoch 100 | Train Loss 0.626147 | Val Loss 0.587257
# Epoch 200 | Train Loss 0.565569 | Val Loss 0.780875
# Early stopping at epoch 263
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed2894.keras
# weights/model_arch264-128-64_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.8215, MSE = 4.0613e-02
# Theta | Train_2 -> R² = 0.7291, MSE = 6.1849e-02
# Theta | Test_1 -> R² = 0.7949, MSE = 4.6985e-02
# Theta | Test_2 -> R² = 0.8006, MSE = 4.7277e-02
# Theta | Test_3 -> R² = 0.4097, MSE = 1.9364e-01
# Theta | Val -> R² = -1.2128, MSE = 7.2234e-01
# Theta | LSG_1 -> R² = 0.7025, MSE = 1.2418e-01
# Theta | LSG_2 -> R² = -2.0539, MSE = 1.0689e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 0.973933 | Val Loss 0.604655
# Epoch 100 | Train Loss 0.614764 | Val Loss 0.550761
# Epoch 200 | Train Loss 0.563551 | Val Loss 0.758016
# Early stopping at epoch 266
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed4968.keras
# weights/model_arch264-128-64_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.8241, MSE = 4.0039e-02
# Theta | Train_2 -> R² = 0.7274, MSE = 6.2239e-02
# Theta | Test_1 -> R² = 0.7268, MSE = 6.2575e-02
# Theta | Test_2 -> R² = 0.8655, MSE = 3.1898e-02
# Theta | Test_3 -> R² = 0.7275, MSE = 8.9392e-02
# Theta | Val -> R² = -0.4365, MSE = 4.6893e-01
# Theta | LSG_1 -> R² = 0.7048, MSE = 1.2325e-01
# Theta | LSG_2 -> R² = -1.6787, MSE = 9.3756e-01
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.995389 | Val Loss 0.666241
# Epoch 100 | Train Loss 0.611369 | Val Loss 0.580214
# Epoch 200 | Train Loss 0.583404 | Val Loss 0.787327
# Early stopping at epoch 261
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed7530.keras
# weights/model_arch264-128-64_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7912, MSE = 4.7525e-02
# Theta | Train_2 -> R² = 0.7548, MSE = 5.5966e-02
# Theta | Test_1 -> R² = 0.6505, MSE = 8.0059e-02
# Theta | Test_2 -> R² = 0.8719, MSE = 3.0384e-02
# Theta | Test_3 -> R² = 0.7223, MSE = 9.1080e-02
# Theta | Val -> R² = -0.6713, MSE = 5.4558e-01
# Theta | LSG_1 -> R² = 0.7465, MSE = 1.0584e-01
# Theta | LSG_2 -> R² = -2.1995, MSE = 1.1199e+00
# Modelo [264, 128, 64] | Ld=0.3 Lp=0.7 r=0.9 seed=7530 salvo.
# Epoch 0 | Train Loss 0.958955 | Val Loss 0.639086
# Epoch 100 | Train Loss 0.559157 | Val Loss 0.705032
# Epoch 200 | Train Loss 0.508326 | Val Loss 0.910928
# Early stopping at epoch 214
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed6590.keras
# weights/model_arch264-128-64_r0.01_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.7292, MSE = 6.1621e-02
# Theta | Train_2 -> R² = 0.6274, MSE = 8.5060e-02
# Theta | Test_1 -> R² = 0.0527, MSE = 2.1700e-01
# Theta | Test_2 -> R² = 0.8211, MSE = 4.2430e-02
# Theta | Test_3 -> R² = 0.0519, MSE = 3.1100e-01
# Theta | Val -> R² = -9.2020, MSE = 3.3302e+00
# Theta | LSG_1 -> R² = 0.0450, MSE = 3.9866e-01
# Theta | LSG_2 -> R² = -4.3580, MSE = 1.8753e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=6590 salvo.
# Epoch 0 | Train Loss 0.992375 | Val Loss 0.695700
# Epoch 100 | Train Loss 0.575235 | Val Loss 0.740997
# Epoch 200 | Train Loss 0.515222 | Val Loss 0.873609
# Early stopping at epoch 216
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed1209.keras
# weights/model_arch264-128-64_r0.01_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.7193, MSE = 6.3887e-02
# Theta | Train_2 -> R² = 0.5463, MSE = 1.0357e-01
# Theta | Test_1 -> R² = -0.0744, MSE = 2.4613e-01
# Theta | Test_2 -> R² = 0.8116, MSE = 4.4668e-02
# Theta | Test_3 -> R² = 0.4157, MSE = 1.9165e-01
# Theta | Val -> R² = -8.4128, MSE = 3.0726e+00
# Theta | LSG_1 -> R² = -0.0110, MSE = 4.2203e-01
# Theta | LSG_2 -> R² = -4.3536, MSE = 1.8738e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1209 salvo.
# Epoch 0 | Train Loss 0.978175 | Val Loss 0.634267
# Epoch 100 | Train Loss 0.562609 | Val Loss 0.701870
# Epoch 200 | Train Loss 0.515460 | Val Loss 0.878090
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed2894.keras
# weights/model_arch264-128-64_r0.01_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.5086, MSE = 1.1183e-01
# Theta | Train_2 -> R² = 0.5950, MSE = 9.2448e-02
# Theta | Test_1 -> R² = -0.2807, MSE = 2.9338e-01
# Theta | Test_2 -> R² = 0.8618, MSE = 3.2760e-02
# Theta | Test_3 -> R² = -0.2398, MSE = 4.0668e-01
# Theta | Val -> R² = -10.6258, MSE = 3.7950e+00
# Theta | LSG_1 -> R² = -0.3344, MSE = 5.5707e-01
# Theta | LSG_2 -> R² = -5.2864, MSE = 2.2003e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2894 salvo.
# Epoch 0 | Train Loss 1.003062 | Val Loss 0.647587
# Epoch 100 | Train Loss 0.551631 | Val Loss 0.743226
# Epoch 200 | Train Loss 0.510656 | Val Loss 0.941143
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed4968.keras
# weights/model_arch264-128-64_r0.01_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.6099, MSE = 8.8785e-02
# Theta | Train_2 -> R² = 0.5996, MSE = 9.1395e-02
# Theta | Test_1 -> R² = -0.1702, MSE = 2.6807e-01
# Theta | Test_2 -> R² = 0.8611, MSE = 3.2947e-02
# Theta | Test_3 -> R² = 0.0608, MSE = 3.0807e-01
# Theta | Val -> R² = -10.1626, MSE = 3.6438e+00
# Theta | LSG_1 -> R² = -0.3093, MSE = 5.4658e-01
# Theta | LSG_2 -> R² = -5.2811, MSE = 2.1984e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4968 salvo.
# Epoch 0 | Train Loss 0.972289 | Val Loss 0.656321
# Epoch 100 | Train Loss 0.575935 | Val Loss 0.724196
# Epoch 200 | Train Loss 0.510491 | Val Loss 0.880185
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed7530.keras
# weights/model_arch264-128-64_r0.01_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7624, MSE = 5.4064e-02
# Theta | Train_2 -> R² = 0.6600, MSE = 7.7622e-02
# Theta | Test_1 -> R² = 0.1669, MSE = 1.9086e-01
# Theta | Test_2 -> R² = 0.7621, MSE = 5.6423e-02
# Theta | Test_3 -> R² = 0.1850, MSE = 2.6732e-01
# Theta | Val -> R² = -8.6815, MSE = 3.1604e+00
# Theta | LSG_1 -> R² = -0.2271, MSE = 5.1226e-01
# Theta | LSG_2 -> R² = -5.3264, MSE = 2.2143e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=7530 salvo.
# Epoch 0 | Train Loss 0.960272 | Val Loss 0.630761
# Epoch 100 | Train Loss 0.545699 | Val Loss 0.755063
# Epoch 200 | Train Loss 0.511255 | Val Loss 0.908793
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed6590.keras
# weights/model_arch264-128-64_r0.9_seed6590.weights.h5
# Theta | Train_1 -> R² = 0.5202, MSE = 1.0920e-01
# Theta | Train_2 -> R² = 0.5660, MSE = 9.9082e-02
# Theta | Test_1 -> R² = -0.2748, MSE = 2.9202e-01
# Theta | Test_2 -> R² = 0.8743, MSE = 2.9797e-02
# Theta | Test_3 -> R² = 0.0201, MSE = 3.2143e-01
# Theta | Val -> R² = -9.0697, MSE = 3.2871e+00
# Theta | LSG_1 -> R² = -0.0618, MSE = 4.4324e-01
# Theta | LSG_2 -> R² = -4.4628, MSE = 1.9120e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=6590 salvo.
# Epoch 0 | Train Loss 0.974778 | Val Loss 0.664755
# Epoch 100 | Train Loss 0.556110 | Val Loss 0.737910
# Epoch 200 | Train Loss 0.510626 | Val Loss 0.890232
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed1209.keras
# weights/model_arch264-128-64_r0.9_seed1209.weights.h5
# Theta | Train_1 -> R² = 0.5897, MSE = 9.3374e-02
# Theta | Train_2 -> R² = 0.6250, MSE = 8.5603e-02
# Theta | Test_1 -> R² = -0.0858, MSE = 2.4873e-01
# Theta | Test_2 -> R² = 0.8747, MSE = 2.9712e-02
# Theta | Test_3 -> R² = 0.0783, MSE = 3.0234e-01
# Theta | Val -> R² = -8.8972, MSE = 3.2308e+00
# Theta | LSG_1 -> R² = -0.3313, MSE = 5.5575e-01
# Theta | LSG_2 -> R² = -5.1364, MSE = 2.1478e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1209 salvo.
# Epoch 0 | Train Loss 0.941274 | Val Loss 0.626472
# Epoch 100 | Train Loss 0.558146 | Val Loss 0.699251
# Epoch 200 | Train Loss 0.509205 | Val Loss 0.902550
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed2894.keras
# weights/model_arch264-128-64_r0.9_seed2894.weights.h5
# Theta | Train_1 -> R² = 0.5014, MSE = 1.1347e-01
# Theta | Train_2 -> R² = 0.6161, MSE = 8.7630e-02
# Theta | Test_1 -> R² = -0.3515, MSE = 3.0960e-01
# Theta | Test_2 -> R² = 0.8459, MSE = 3.6543e-02
# Theta | Test_3 -> R² = -0.1191, MSE = 3.6709e-01
# Theta | Val -> R² = -9.9028, MSE = 3.5590e+00
# Theta | LSG_1 -> R² = -0.2383, MSE = 5.1693e-01
# Theta | LSG_2 -> R² = -5.1255, MSE = 2.1440e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2894 salvo.
# Epoch 0 | Train Loss 0.964671 | Val Loss 0.638586
# Epoch 100 | Train Loss 0.554598 | Val Loss 0.702455
# Epoch 200 | Train Loss 0.510879 | Val Loss 0.895371
# Early stopping at epoch 212
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed4968.keras
# weights/model_arch264-128-64_r0.9_seed4968.weights.h5
# Theta | Train_1 -> R² = 0.4406, MSE = 1.2731e-01
# Theta | Train_2 -> R² = 0.4913, MSE = 1.1613e-01
# Theta | Test_1 -> R² = -0.4547, MSE = 3.3324e-01
# Theta | Test_2 -> R² = 0.8204, MSE = 4.2592e-02
# Theta | Test_3 -> R² = 0.0747, MSE = 3.0350e-01
# Theta | Val -> R² = -9.5329, MSE = 3.4383e+00
# Theta | LSG_1 -> R² = -0.2750, MSE = 5.3226e-01
# Theta | LSG_2 -> R² = -5.0598, MSE = 2.1210e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4968 salvo.
# Epoch 0 | Train Loss 0.975783 | Val Loss 0.663223
# Epoch 100 | Train Loss 0.576302 | Val Loss 0.723630
# Epoch 200 | Train Loss 0.511920 | Val Loss 0.900100
# Early stopping at epoch 213
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed7530.keras
# weights/model_arch264-128-64_r0.9_seed7530.weights.h5
# Theta | Train_1 -> R² = 0.7559, MSE = 5.5547e-02
# Theta | Train_2 -> R² = 0.6755, MSE = 7.4083e-02
# Theta | Test_1 -> R² = 0.1570, MSE = 1.9312e-01
# Theta | Test_2 -> R² = 0.7860, MSE = 5.0736e-02
# Theta | Test_3 -> R² = 0.1133, MSE = 2.9086e-01
# Theta | Val -> R² = -9.5473, MSE = 3.4430e+00
# Theta | LSG_1 -> R² = -0.3496, MSE = 5.6340e-01
# Theta | LSG_2 -> R² = -5.6276, MSE = 2.3197e+00
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=7530 salvo.
