# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "SinTheta", "CosTheta"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]
    Dataset["SinTheta"] = np.sin(Dataset["Theta"])
    Dataset["CosTheta"] = np.cos(Dataset["Theta"])

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 6)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 6)
# Dimensão da saida: (1268, 3)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
q_real = Train[TARGET_INT].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 6)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta_pred):
    dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta_pred) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_pred) * (Wd + We)
    return [dtheta_cin, dx_cin, dy_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dq, q_real, Wd, We, q0, Ld, Lp):

    with tf.GradientTape() as tape:

        # =========================
        # 1. Forward
        # =========================
        dq_pred = model(x, training=True)

        # =========================
        # 2. Desnormaliza
        # =========================
        dq_pred_denorm = (dq_pred * std_tf) + mean_tf

        dtheta_pred = dq_pred_denorm[:, 0]
        dx_pred     = dq_pred_denorm[:, 1]
        dy_pred     = dq_pred_denorm[:, 2]

        # =========================
        # 3. Integração (estado)
        # =========================
        theta_pred = q0[0] + tf.cumsum(dtheta_pred * dt, axis=0)
        x_pred     = q0[1] + tf.cumsum(dx_pred * dt, axis=0)
        y_pred     = q0[2] + tf.cumsum(dy_pred * dt, axis=0)

        # =========================
        # 4. Estados reais
        # =========================
        theta_real = q_real[:, 0]
        x_real     = q_real[:, 1]
        y_real     = q_real[:, 2]

        # =========================
        # 5. LOSS DE DADOS (θ, x, y)
        # =========================
        loss_theta = tf.reduce_mean((theta_pred - theta_real)**2)
        loss_x     = tf.reduce_mean((x_pred - x_real)**2)
        loss_y     = tf.reduce_mean((y_pred - y_real)**2)
        loss_dq = tf.reduce_mean((dq - dq_pred)**2)

        data_loss = loss_theta + loss_x + loss_y + loss_dq

        # =========================
        # 6. FÍSICA
        # =========================
        physics = tf.stack(CinematicModel(Wd, We, theta_real), axis=1)

        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean((dq_pred - physics_norm)**2)

        # =========================
        # 7. LOSS TOTAL
        # =========================
        loss = Ld * data_loss + Lp * physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train_tf = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train_tf = tf.convert_to_tensor(We_train, dtype=tf.float32)
q0_tf = tf.convert_to_tensor(q_real[0], dtype=tf.float32)
q_real_tf = tf.convert_to_tensor(q_real, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, q_real_tf,
                          Wd_train_tf, We_train_tf, q0_tf, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# WARNING:tensorflow:From d:\Users\sarah\Educ\Ic-2026.1\tf-env\lib\site-packages\keras\src\backend.py:277: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
#
# Epoch 0 | Train Loss 2.050070 | Val Loss 0.802924
# Epoch 100 | Train Loss 0.675244 | Val Loss 0.704428
# Epoch 200 | Train Loss 0.574479 | Val Loss 0.650779
# Epoch 300 | Train Loss 0.542828 | Val Loss 0.639438
# Epoch 400 | Train Loss 0.525207 | Val Loss 0.633854
# Epoch 500 | Train Loss 0.502215 | Val Loss 0.623238
# Epoch 600 | Train Loss 0.480765 | Val Loss 0.610949
# Epoch 700 | Train Loss 0.469297 | Val Loss 0.604608
# Epoch 800 | Train Loss 0.460509 | Val Loss 0.601341
# Epoch 900 | Train Loss 0.452416 | Val Loss 0.599256
# Epoch 1000 | Train Loss 0.445669 | Val Loss 0.598489
# Epoch 1100 | Train Loss 0.440645 | Val Loss 0.598773
# Early stopping at epoch 1186
# Modelo salvo em:
# models/model_arch16_r0.01_seed6134.keras
# weights/model_arch16_r0.01_seed6134.weights.h5
# Theta | Train_1 -> R² = 0.9351, MSE = 1.4777e-02
# X | Train_1 -> R² = 0.2735, MSE = 7.8344e-02
# Y | Train_1 -> R² = -1.3657, MSE = 1.9825e-01
# Theta | Train_2 -> R² = 0.9074, MSE = 2.1148e-02
# X | Train_2 -> R² = 0.6568, MSE = 2.8924e-02
# Y | Train_2 -> R² = -1.3416, MSE = 2.5214e-01
# Theta | Test_1 -> R² = 0.5542, MSE = 1.0212e-01
# X | Test_1 -> R² = 0.1438, MSE = 8.9718e-02
# Y | Test_1 -> R² = -1.4803, MSE = 2.0330e-01
# Theta | Test_2 -> R² = 0.8229, MSE = 4.1990e-02
# X | Test_2 -> R² = 0.6655, MSE = 2.7526e-02
# Y | Test_2 -> R² = -1.3854, MSE = 2.5320e-01
# Theta | Test_3 -> R² = 0.6741, MSE = 1.0691e-01
# X | Test_3 -> R² = -0.1212, MSE = 1.0318e-01
# Y | Test_3 -> R² = -1.4733, MSE = 1.9001e-01
# Theta | Val -> R² = 0.0816, MSE = 2.9979e-01
# X | Val -> R² = 0.1407, MSE = 8.2183e-02
# Y | Val -> R² = -1.5864, MSE = 1.9261e-01
# Theta | LSG_1 -> R² = 0.1577, MSE = 3.5162e-01
# X | LSG_1 -> R² = 0.3897, MSE = 6.2549e-02
# Y | LSG_1 -> R² = -0.1898, MSE = 3.7567e-01
# Theta | LSG_2 -> R² = -3.9173, MSE = 1.7211e+00
# X | LSG_2 -> R² = 0.4491, MSE = 4.8981e-02
# Y | LSG_2 -> R² = 0.0310, MSE = 3.7231e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=6134 salvo.
# Epoch 0 | Train Loss 1.897861 | Val Loss 0.795349
# Epoch 100 | Train Loss 0.622772 | Val Loss 0.679667
# Epoch 200 | Train Loss 0.547216 | Val Loss 0.643914
# Epoch 300 | Train Loss 0.519895 | Val Loss 0.634547
# Epoch 400 | Train Loss 0.493974 | Val Loss 0.618927
# Epoch 500 | Train Loss 0.475969 | Val Loss 0.606973
# Epoch 600 | Train Loss 0.464867 | Val Loss 0.602081
# Epoch 700 | Train Loss 0.455725 | Val Loss 0.602601
# Early stopping at epoch 798
# Modelo salvo em:
# models/model_arch16_r0.01_seed4092.keras
# weights/model_arch16_r0.01_seed4092.weights.h5
# Theta | Train_1 -> R² = 0.9455, MSE = 1.2397e-02
# X | Train_1 -> R² = 0.2610, MSE = 7.9695e-02
# Y | Train_1 -> R² = -1.3665, MSE = 1.9832e-01
# Theta | Train_2 -> R² = 0.8756, MSE = 2.8391e-02
# X | Train_2 -> R² = 0.6575, MSE = 2.8861e-02
# Y | Train_2 -> R² = -1.3392, MSE = 2.5188e-01
# Theta | Test_1 -> R² = 0.2479, MSE = 1.7229e-01
# X | Test_1 -> R² = 0.1504, MSE = 8.9024e-02
# Y | Test_1 -> R² = -1.4924, MSE = 2.0428e-01
# Theta | Test_2 -> R² = 0.8630, MSE = 3.2497e-02
# X | Test_2 -> R² = 0.6734, MSE = 2.6874e-02
# Y | Test_2 -> R² = -1.3061, MSE = 2.4478e-01
# Theta | Test_3 -> R² = 0.5670, MSE = 1.4203e-01
# X | Test_3 -> R² = -1.5268, MSE = 2.3253e-01
# Y | Test_3 -> R² = -1.0794, MSE = 1.5975e-01
# Theta | Val -> R² = -2.3813, MSE = 1.1038e+00
# X | Val -> R² = -1.1607, MSE = 2.0664e-01
# Y | Val -> R² = -0.5664, MSE = 1.1665e-01
# Theta | LSG_1 -> R² = -1.1138, MSE = 8.8241e-01
# X | LSG_1 -> R² = 0.4953, MSE = 5.1734e-02
# Y | LSG_1 -> R² = -0.3372, MSE = 4.2221e-01
# Theta | LSG_2 -> R² = 0.2294, MSE = 2.6970e-01
# X | LSG_2 -> R² = 0.4738, MSE = 4.6781e-02
# Y | LSG_2 -> R² = -0.0504, MSE = 4.0356e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4092 salvo.
# Epoch 0 | Train Loss 1.762370 | Val Loss 0.804504
# Epoch 100 | Train Loss 0.635251 | Val Loss 0.687122
# Epoch 200 | Train Loss 0.538382 | Val Loss 0.632541
# Epoch 300 | Train Loss 0.506972 | Val Loss 0.620508
# Epoch 400 | Train Loss 0.489353 | Val Loss 0.612213
# Epoch 500 | Train Loss 0.478416 | Val Loss 0.607476
# Epoch 600 | Train Loss 0.468031 | Val Loss 0.604645
# Epoch 700 | Train Loss 0.458619 | Val Loss 0.605911
# Early stopping at epoch 793
# Modelo salvo em:
# models/model_arch16_r0.01_seed8653.keras
# weights/model_arch16_r0.01_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9361, MSE = 1.4537e-02
# X | Train_1 -> R² = 0.2552, MSE = 8.0312e-02
# Y | Train_1 -> R² = -1.3542, MSE = 1.9729e-01
# Theta | Train_2 -> R² = 0.9001, MSE = 2.2808e-02
# X | Train_2 -> R² = 0.6543, MSE = 2.9130e-02
# Y | Train_2 -> R² = -1.3034, MSE = 2.4802e-01
# Theta | Test_1 -> R² = 0.2876, MSE = 1.6319e-01
# X | Test_1 -> R² = 0.1731, MSE = 8.6638e-02
# Y | Test_1 -> R² = -1.4765, MSE = 2.0299e-01
# Theta | Test_2 -> R² = 0.8783, MSE = 2.8870e-02
# X | Test_2 -> R² = 0.6721, MSE = 2.6985e-02
# Y | Test_2 -> R² = -1.3524, MSE = 2.4969e-01
# Theta | Test_3 -> R² = 0.6721, MSE = 1.0754e-01
# X | Test_3 -> R² = -0.4906, MSE = 1.3717e-01
# Y | Test_3 -> R² = -1.2081, MSE = 1.6964e-01
# Theta | Val -> R² = -5.4973, MSE = 2.1209e+00
# X | Val -> R² = 0.0547, MSE = 9.0409e-02
# Y | Val -> R² = -0.6767, MSE = 1.2486e-01
# Theta | LSG_1 -> R² = -1.0458, MSE = 8.5402e-01
# X | LSG_1 -> R² = 0.4146, MSE = 6.0000e-02
# Y | LSG_1 -> R² = -0.2568, MSE = 3.9682e-01
# Theta | LSG_2 -> R² = -6.5279, MSE = 2.6348e+00
# X | LSG_2 -> R² = 0.3295, MSE = 5.9613e-02
# Y | LSG_2 -> R² = -0.0007, MSE = 3.8449e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=8653 salvo.
# Epoch 0 | Train Loss 2.087253 | Val Loss 0.792609
# Epoch 100 | Train Loss 0.645332 | Val Loss 0.697780
# Epoch 200 | Train Loss 0.563738 | Val Loss 0.651454
# Epoch 300 | Train Loss 0.537033 | Val Loss 0.643760
# Epoch 400 | Train Loss 0.514505 | Val Loss 0.630888
# Epoch 500 | Train Loss 0.493258 | Val Loss 0.617095
# Epoch 600 | Train Loss 0.482279 | Val Loss 0.609197
# Epoch 700 | Train Loss 0.474612 | Val Loss 0.605563
# Epoch 800 | Train Loss 0.468531 | Val Loss 0.603958
# Epoch 900 | Train Loss 0.459593 | Val Loss 0.607233
# Early stopping at epoch 923
# Modelo salvo em:
# models/model_arch16_r0.01_seed3163.keras
# weights/model_arch16_r0.01_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9386, MSE = 1.3970e-02
# X | Train_1 -> R² = 0.2528, MSE = 8.0578e-02
# Y | Train_1 -> R² = -1.3726, MSE = 1.9883e-01
# Theta | Train_2 -> R² = 0.8720, MSE = 2.9225e-02
# X | Train_2 -> R² = 0.6488, MSE = 2.9593e-02
# Y | Train_2 -> R² = -1.3347, MSE = 2.5140e-01
# Theta | Test_1 -> R² = 0.4493, MSE = 1.2615e-01
# X | Test_1 -> R² = 0.1703, MSE = 8.6941e-02
# Y | Test_1 -> R² = -1.5561, MSE = 2.0951e-01
# Theta | Test_2 -> R² = 0.9155, MSE = 2.0041e-02
# X | Test_2 -> R² = 0.6647, MSE = 2.7596e-02
# Y | Test_2 -> R² = -1.3516, MSE = 2.4960e-01
# Theta | Test_3 -> R² = 0.7347, MSE = 8.7030e-02
# X | Test_3 -> R² = -0.4047, MSE = 1.2927e-01
# Y | Test_3 -> R² = -1.0220, MSE = 1.5534e-01
# Theta | Val -> R² = -5.1121, MSE = 1.9952e+00
# X | Val -> R² = 0.0578, MSE = 9.0116e-02
# Y | Val -> R² = -0.9204, MSE = 1.4301e-01
# Theta | LSG_1 -> R² = 0.2527, MSE = 3.1198e-01
# X | LSG_1 -> R² = 0.3752, MSE = 6.4036e-02
# Y | LSG_1 -> R² = -0.3302, MSE = 4.2000e-01
# Theta | LSG_2 -> R² = -3.5831, MSE = 1.6041e+00
# X | LSG_2 -> R² = 0.3605, MSE = 5.6856e-02
# Y | LSG_2 -> R² = -0.0932, MSE = 4.2003e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=3163 salvo.
# Epoch 0 | Train Loss 1.462225 | Val Loss 0.792838
# Epoch 100 | Train Loss 0.627403 | Val Loss 0.676703
# Epoch 200 | Train Loss 0.531734 | Val Loss 0.630678
# Epoch 300 | Train Loss 0.500109 | Val Loss 0.621766
# Epoch 400 | Train Loss 0.487703 | Val Loss 0.615964
# Epoch 500 | Train Loss 0.480039 | Val Loss 0.610918
# Epoch 600 | Train Loss 0.474014 | Val Loss 0.609125
# Epoch 700 | Train Loss 0.468961 | Val Loss 0.607754
# Epoch 800 | Train Loss 0.463817 | Val Loss 0.606156
# Epoch 900 | Train Loss 0.456635 | Val Loss 0.605918
# Early stopping at epoch 1000
# Modelo salvo em:
# models/model_arch16_r0.01_seed4006.keras
# weights/model_arch16_r0.01_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9414, MSE = 1.3333e-02
# X | Train_1 -> R² = 0.2529, MSE = 8.0563e-02
# Y | Train_1 -> R² = -1.3672, MSE = 1.9838e-01
# Theta | Train_2 -> R² = 0.7042, MSE = 6.7525e-02
# X | Train_2 -> R² = 0.6884, MSE = 2.6260e-02
# Y | Train_2 -> R² = -1.3135, MSE = 2.4911e-01
# Theta | Test_1 -> R² = 0.4700, MSE = 1.2142e-01
# X | Test_1 -> R² = 0.1793, MSE = 8.5991e-02
# Y | Test_1 -> R² = -1.5988, MSE = 2.1301e-01
# Theta | Test_2 -> R² = 0.8899, MSE = 2.6119e-02
# X | Test_2 -> R² = 0.6975, MSE = 2.4890e-02
# Y | Test_2 -> R² = -1.3945, MSE = 2.5416e-01
# Theta | Test_3 -> R² = 0.7704, MSE = 7.5298e-02
# X | Test_3 -> R² = -0.3965, MSE = 1.2851e-01
# Y | Test_3 -> R² = -1.0995, MSE = 1.6129e-01
# Theta | Val -> R² = -2.9427, MSE = 1.2870e+00
# X | Val -> R² = 0.1585, MSE = 8.0485e-02
# Y | Val -> R² = -1.9981, MSE = 2.2326e-01
# Theta | LSG_1 -> R² = -0.4610, MSE = 6.0991e-01
# X | LSG_1 -> R² = 0.1605, MSE = 8.6045e-02
# Y | LSG_1 -> R² = -0.6165, MSE = 5.1038e-01
# Theta | LSG_2 -> R² = -5.5470, MSE = 2.2915e+00
# X | LSG_2 -> R² = -0.2767, MSE = 1.1351e-01
# Y | LSG_2 -> R² = -0.3617, MSE = 5.2317e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=4006 salvo.
# Epoch 0 | Train Loss 2.103806 | Val Loss 0.779565
# Epoch 100 | Train Loss 0.657656 | Val Loss 0.692113
# Epoch 200 | Train Loss 0.556385 | Val Loss 0.637005
# Epoch 300 | Train Loss 0.520532 | Val Loss 0.628812
# Epoch 400 | Train Loss 0.493071 | Val Loss 0.618364
# Epoch 500 | Train Loss 0.467316 | Val Loss 0.607109
# Epoch 600 | Train Loss 0.453327 | Val Loss 0.602858
# Epoch 700 | Train Loss 0.446316 | Val Loss 0.603327
# Early stopping at epoch 764
# Modelo salvo em:
# models/model_arch16_r0.9_seed6134.keras
# weights/model_arch16_r0.9_seed6134.weights.h5
# Theta | Train_1 -> R² = 0.9529, MSE = 1.0729e-02
# X | Train_1 -> R² = 0.2322, MSE = 8.2795e-02
# Y | Train_1 -> R² = -1.3685, MSE = 1.9849e-01
# Theta | Train_2 -> R² = 0.9296, MSE = 1.6077e-02
# X | Train_2 -> R² = 0.6957, MSE = 2.5640e-02
# Y | Train_2 -> R² = -1.4722, MSE = 2.6620e-01
# Theta | Test_1 -> R² = 0.5572, MSE = 1.0144e-01
# X | Test_1 -> R² = 0.1326, MSE = 9.0892e-02
# Y | Test_1 -> R² = -1.5116, MSE = 2.0586e-01
# Theta | Test_2 -> R² = 0.7714, MSE = 5.4215e-02
# X | Test_2 -> R² = 0.7016, MSE = 2.4560e-02
# Y | Test_2 -> R² = -1.4931, MSE = 2.6462e-01
# Theta | Test_3 -> R² = 0.2855, MSE = 2.3435e-01
# X | Test_3 -> R² = -1.0796, MSE = 1.9138e-01
# Y | Test_3 -> R² = -1.1753, MSE = 1.6711e-01
# Theta | Val -> R² = -0.3369, MSE = 4.3641e-01
# X | Val -> R² = -0.8541, MSE = 1.7733e-01
# Y | Val -> R² = -0.7394, MSE = 1.2953e-01
# Theta | LSG_1 -> R² = -2.0626, MSE = 1.2785e+00
# X | LSG_1 -> R² = 0.3672, MSE = 6.4861e-02
# Y | LSG_1 -> R² = -0.1993, MSE = 3.7867e-01
# Theta | LSG_2 -> R² = 0.3392, MSE = 2.3127e-01
# X | LSG_2 -> R² = 0.0595, MSE = 8.3611e-02
# Y | LSG_2 -> R² = 0.0135, MSE = 3.7903e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=6134 salvo.
# Epoch 0 | Train Loss 1.632580 | Val Loss 0.792973
# Epoch 100 | Train Loss 0.643390 | Val Loss 0.692902
# Epoch 200 | Train Loss 0.549095 | Val Loss 0.646757
# Epoch 300 | Train Loss 0.531358 | Val Loss 0.641227
# Epoch 400 | Train Loss 0.505013 | Val Loss 0.623335
# Epoch 500 | Train Loss 0.480354 | Val Loss 0.607600
# Epoch 600 | Train Loss 0.468229 | Val Loss 0.603610
# Epoch 700 | Train Loss 0.458680 | Val Loss 0.602698
# Epoch 800 | Train Loss 0.450177 | Val Loss 0.602566
# Epoch 900 | Train Loss 0.446460 | Val Loss 0.604581
# Early stopping at epoch 954
# Modelo salvo em:
# models/model_arch16_r0.9_seed4092.keras
# weights/model_arch16_r0.9_seed4092.weights.h5
# Theta | Train_1 -> R² = 0.9452, MSE = 1.2473e-02
# X | Train_1 -> R² = 0.2576, MSE = 8.0061e-02
# Y | Train_1 -> R² = -1.3399, MSE = 1.9609e-01
# Theta | Train_2 -> R² = 0.8986, MSE = 2.3141e-02
# X | Train_2 -> R² = 0.7009, MSE = 2.5206e-02
# Y | Train_2 -> R² = -1.3650, MSE = 2.5466e-01
# Theta | Test_1 -> R² = 0.4786, MSE = 1.1943e-01
# X | Test_1 -> R² = 0.1856, MSE = 8.5332e-02
# Y | Test_1 -> R² = -1.5370, MSE = 2.0795e-01
# Theta | Test_2 -> R² = 0.8282, MSE = 4.0737e-02
# X | Test_2 -> R² = 0.7196, MSE = 2.3073e-02
# Y | Test_2 -> R² = -1.3526, MSE = 2.4972e-01
# Theta | Test_3 -> R² = 0.7984, MSE = 6.6117e-02
# X | Test_3 -> R² = -0.6952, MSE = 1.5601e-01
# Y | Test_3 -> R² = -1.1856, MSE = 1.6790e-01
# Theta | Val -> R² = -1.3997, MSE = 7.8332e-01
# X | Val -> R² = -0.0698, MSE = 1.0232e-01
# Y | Val -> R² = -1.1445, MSE = 1.5969e-01
# Theta | LSG_1 -> R² = -3.5787, MSE = 1.9114e+00
# X | LSG_1 -> R² = 0.2565, MSE = 7.6203e-02
# Y | LSG_1 -> R² = -0.4724, MSE = 4.6489e-01
# Theta | LSG_2 -> R² = 0.3632, MSE = 2.2289e-01
# X | LSG_2 -> R² = -0.1441, MSE = 1.0171e-01
# Y | LSG_2 -> R² = -0.1319, MSE = 4.3487e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4092 salvo.
# Epoch 0 | Train Loss 1.271833 | Val Loss 0.820110
# Epoch 100 | Train Loss 0.621346 | Val Loss 0.681383
# Epoch 200 | Train Loss 0.514582 | Val Loss 0.636052
# Epoch 300 | Train Loss 0.489896 | Val Loss 0.623683
# Epoch 400 | Train Loss 0.479858 | Val Loss 0.618413
# Epoch 500 | Train Loss 0.471862 | Val Loss 0.614501
# Epoch 600 | Train Loss 0.463487 | Val Loss 0.611858
# Epoch 700 | Train Loss 0.455111 | Val Loss 0.611363
# Epoch 800 | Train Loss 0.448301 | Val Loss 0.614769
# Early stopping at epoch 838
# Modelo salvo em:
# models/model_arch16_r0.9_seed8653.keras
# weights/model_arch16_r0.9_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9411, MSE = 1.3394e-02
# X | Train_1 -> R² = 0.2585, MSE = 7.9957e-02
# Y | Train_1 -> R² = -1.3713, MSE = 1.9872e-01
# Theta | Train_2 -> R² = 0.8973, MSE = 2.3449e-02
# X | Train_2 -> R² = 0.6698, MSE = 2.7828e-02
# Y | Train_2 -> R² = -1.3342, MSE = 2.5134e-01
# Theta | Test_1 -> R² = 0.4267, MSE = 1.3134e-01
# X | Test_1 -> R² = 0.1450, MSE = 8.9593e-02
# Y | Test_1 -> R² = -1.4903, MSE = 2.0411e-01
# Theta | Test_2 -> R² = 0.8647, MSE = 3.2089e-02
# X | Test_2 -> R² = 0.6927, MSE = 2.5287e-02
# Y | Test_2 -> R² = -1.3783, MSE = 2.5244e-01
# Theta | Test_3 -> R² = 0.8079, MSE = 6.3004e-02
# X | Test_3 -> R² = -0.3754, MSE = 1.2657e-01
# Y | Test_3 -> R² = -1.9349, MSE = 2.2547e-01
# Theta | Val -> R² = -2.7152, MSE = 1.2127e+00
# X | Val -> R² = -0.1098, MSE = 1.0614e-01
# Y | Val -> R² = -1.7613, MSE = 2.0563e-01
# Theta | LSG_1 -> R² = -0.5298, MSE = 6.3860e-01
# X | LSG_1 -> R² = 0.4188, MSE = 5.9567e-02
# Y | LSG_1 -> R² = -0.3544, MSE = 4.2764e-01
# Theta | LSG_2 -> R² = -8.2125, MSE = 3.2244e+00
# X | LSG_2 -> R² = 0.2217, MSE = 6.9193e-02
# Y | LSG_2 -> R² = -0.0461, MSE = 4.0191e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=8653 salvo.
# Epoch 0 | Train Loss 2.075046 | Val Loss 0.799870
# Epoch 100 | Train Loss 0.631628 | Val Loss 0.674405
# Epoch 200 | Train Loss 0.563846 | Val Loss 0.646733
# Epoch 300 | Train Loss 0.544939 | Val Loss 0.646577
# Epoch 400 | Train Loss 0.530739 | Val Loss 0.639861
# Epoch 500 | Train Loss 0.513069 | Val Loss 0.629521
# Epoch 600 | Train Loss 0.493609 | Val Loss 0.615906
# Epoch 700 | Train Loss 0.481688 | Val Loss 0.605045
# Epoch 800 | Train Loss 0.474970 | Val Loss 0.600008
# Epoch 900 | Train Loss 0.468955 | Val Loss 0.597697
# Epoch 1000 | Train Loss 0.462788 | Val Loss 0.598520
# Early stopping at epoch 1086
# Modelo salvo em:
# models/model_arch16_r0.9_seed3163.keras
# weights/model_arch16_r0.9_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9521, MSE = 1.0906e-02
# X | Train_1 -> R² = 0.2614, MSE = 7.9649e-02
# Y | Train_1 -> R² = -1.3444, MSE = 1.9647e-01
# Theta | Train_2 -> R² = 0.8590, MSE = 3.2193e-02
# X | Train_2 -> R² = 0.6764, MSE = 2.7271e-02
# Y | Train_2 -> R² = -1.3550, MSE = 2.5358e-01
# Theta | Test_1 -> R² = 0.6095, MSE = 8.9463e-02
# X | Test_1 -> R² = 0.2225, MSE = 8.1466e-02
# Y | Test_1 -> R² = -1.5962, MSE = 2.1279e-01
# Theta | Test_2 -> R² = 0.8959, MSE = 2.4685e-02
# X | Test_2 -> R² = 0.7012, MSE = 2.4591e-02
# Y | Test_2 -> R² = -1.3575, MSE = 2.5024e-01
# Theta | Test_3 -> R² = 0.6723, MSE = 1.0750e-01
# X | Test_3 -> R² = -0.7921, MSE = 1.6492e-01
# Y | Test_3 -> R² = -0.6995, MSE = 1.3056e-01
# Theta | Val -> R² = -1.9356, MSE = 9.5829e-01
# X | Val -> R² = 0.2007, MSE = 7.6441e-02
# Y | Val -> R² = -1.0031, MSE = 1.4916e-01
# Theta | LSG_1 -> R² = -1.0198, MSE = 8.4319e-01
# X | LSG_1 -> R² = 0.4147, MSE = 5.9991e-02
# Y | LSG_1 -> R² = -0.0976, MSE = 3.4655e-01
# Theta | LSG_2 -> R² = 0.7148, MSE = 9.9806e-02
# X | LSG_2 -> R² = 0.3945, MSE = 5.3829e-02
# Y | LSG_2 -> R² = 0.0737, MSE = 3.5588e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=3163 salvo.
# Epoch 0 | Train Loss 1.489642 | Val Loss 0.793469
# Epoch 100 | Train Loss 0.596977 | Val Loss 0.658258
# Epoch 200 | Train Loss 0.537715 | Val Loss 0.641940
# Epoch 300 | Train Loss 0.509466 | Val Loss 0.628609
# Epoch 400 | Train Loss 0.481696 | Val Loss 0.610938
# Epoch 500 | Train Loss 0.467637 | Val Loss 0.603858
# Epoch 600 | Train Loss 0.459958 | Val Loss 0.605395
# Early stopping at epoch 682
# Modelo salvo em:
# models/model_arch16_r0.9_seed4006.keras
# weights/model_arch16_r0.9_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9395, MSE = 1.3773e-02
# X | Train_1 -> R² = 0.2338, MSE = 8.2626e-02
# Y | Train_1 -> R² = -1.3743, MSE = 1.9898e-01
# Theta | Train_2 -> R² = 0.8934, MSE = 2.4329e-02
# X | Train_2 -> R² = 0.6652, MSE = 2.8211e-02
# Y | Train_2 -> R² = -1.3291, MSE = 2.5079e-01
# Theta | Test_1 -> R² = 0.6091, MSE = 8.9538e-02
# X | Test_1 -> R² = 0.1414, MSE = 8.9961e-02
# Y | Test_1 -> R² = -1.5582, MSE = 2.0968e-01
# Theta | Test_2 -> R² = 0.8212, MSE = 4.2403e-02
# X | Test_2 -> R² = 0.6881, MSE = 2.5670e-02
# Y | Test_2 -> R² = -1.3259, MSE = 2.4688e-01
# Theta | Test_3 -> R² = -0.0603, MSE = 3.4778e-01
# X | Test_3 -> R² = -0.2879, MSE = 1.1852e-01
# Y | Test_3 -> R² = -1.1915, MSE = 1.6836e-01
# Theta | Val -> R² = -2.6335, MSE = 1.1861e+00
# X | Val -> R² = 0.2441, MSE = 7.2294e-02
# Y | Val -> R² = -1.0396, MSE = 1.5188e-01
# Theta | LSG_1 -> R² = 0.4965, MSE = 2.1020e-01
# X | LSG_1 -> R² = 0.2753, MSE = 7.4274e-02
# Y | LSG_1 -> R² = -0.5368, MSE = 4.8523e-01
# Theta | LSG_2 -> R² = -0.7754, MSE = 6.2141e-01
# X | LSG_2 -> R² = 0.3206, MSE = 6.0400e-02
# Y | LSG_2 -> R² = -0.1716, MSE = 4.5013e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=4006 salvo.
# Epoch 0 | Train Loss 2.779585 | Val Loss 0.805861
# Epoch 100 | Train Loss 1.056289 | Val Loss 0.687002
# Epoch 200 | Train Loss 0.863274 | Val Loss 0.630200
# Epoch 300 | Train Loss 0.804353 | Val Loss 0.633689
# Epoch 400 | Train Loss 0.750301 | Val Loss 0.624618
# Epoch 500 | Train Loss 0.724013 | Val Loss 0.615383
# Epoch 600 | Train Loss 0.719118 | Val Loss 0.612381
# Epoch 700 | Train Loss 0.716397 | Val Loss 0.610788
# Epoch 800 | Train Loss 0.714199 | Val Loss 0.609462
# Epoch 900 | Train Loss 0.712318 | Val Loss 0.608259
# Epoch 1000 | Train Loss 0.710723 | Val Loss 0.607153
# Epoch 1100 | Train Loss 0.709279 | Val Loss 0.606269
# Epoch 1200 | Train Loss 0.708058 | Val Loss 0.605458
# Epoch 1300 | Train Loss 0.707119 | Val Loss 0.604680
# Epoch 1400 | Train Loss 0.705997 | Val Loss 0.604106
# Epoch 1500 | Train Loss 0.705325 | Val Loss 0.603462
# Epoch 1600 | Train Loss 0.704258 | Val Loss 0.603009
# Epoch 1700 | Train Loss 0.703496 | Val Loss 0.602444
# Epoch 1800 | Train Loss 0.702677 | Val Loss 0.602155
# Early stopping at epoch 1844
# Modelo salvo em:
# models/model_arch16_r0.01_seed6134.keras
# weights/model_arch16_r0.01_seed6134.weights.h5
# Theta | Train_1 -> R² = 0.9480, MSE = 1.1844e-02
# X | Train_1 -> R² = 0.2794, MSE = 7.7708e-02
# Y | Train_1 -> R² = -1.3666, MSE = 1.9833e-01
# Theta | Train_2 -> R² = 0.9431, MSE = 1.2991e-02
# X | Train_2 -> R² = 0.6890, MSE = 2.6206e-02
# Y | Train_2 -> R² = -1.1626, MSE = 2.3287e-01
# Theta | Test_1 -> R² = 0.0886, MSE = 2.0878e-01
# X | Test_1 -> R² = 0.1598, MSE = 8.8038e-02
# Y | Test_1 -> R² = -1.3213, MSE = 1.9026e-01
# Theta | Test_2 -> R² = 0.3805, MSE = 1.4690e-01
# X | Test_2 -> R² = 0.7193, MSE = 2.3096e-02
# Y | Test_2 -> R² = -1.0918, MSE = 2.2203e-01
# Theta | Test_3 -> R² = 0.6206, MSE = 1.2444e-01
# X | Test_3 -> R² = -0.6732, MSE = 1.5398e-01
# Y | Test_3 -> R² = -0.7976, MSE = 1.3810e-01
# Theta | Val -> R² = -4.0986, MSE = 1.6643e+00
# X | Val -> R² = -0.6289, MSE = 1.5579e-01
# Y | Val -> R² = -0.3210, MSE = 9.8373e-02
# Theta | LSG_1 -> R² = -0.5620, MSE = 6.5206e-01
# X | LSG_1 -> R² = 0.5415, MSE = 4.6999e-02
# Y | LSG_1 -> R² = -0.3656, MSE = 4.3116e-01
# Theta | LSG_2 -> R² = 0.3286, MSE = 2.3501e-01
# X | LSG_2 -> R² = 0.4551, MSE = 4.8441e-02
# Y | LSG_2 -> R² = 0.0644, MSE = 3.5947e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=6134 salvo.
# Epoch 0 | Train Loss 2.826895 | Val Loss 0.806183
# Epoch 100 | Train Loss 0.982335 | Val Loss 0.670348
# Epoch 200 | Train Loss 0.813635 | Val Loss 0.653475
# Epoch 300 | Train Loss 0.748129 | Val Loss 0.634768
# Epoch 400 | Train Loss 0.722444 | Val Loss 0.620291
# Epoch 500 | Train Loss 0.714974 | Val Loss 0.612526
# Epoch 600 | Train Loss 0.710136 | Val Loss 0.607748
# Epoch 700 | Train Loss 0.706741 | Val Loss 0.604907
# Epoch 800 | Train Loss 0.704508 | Val Loss 0.603097
# Epoch 900 | Train Loss 0.702625 | Val Loss 0.602090
# Epoch 1000 | Train Loss 0.701313 | Val Loss 0.601364
# Epoch 1100 | Train Loss 0.700891 | Val Loss 0.600828
# Early stopping at epoch 1152
# Modelo salvo em:
# models/model_arch16_r0.01_seed4092.keras
# weights/model_arch16_r0.01_seed4092.weights.h5
# Theta | Train_1 -> R² = 0.9517, MSE = 1.1001e-02
# X | Train_1 -> R² = 0.2935, MSE = 7.6189e-02
# Y | Train_1 -> R² = -1.3598, MSE = 1.9776e-01
# Theta | Train_2 -> R² = 0.9386, MSE = 1.4017e-02
# X | Train_2 -> R² = 0.6940, MSE = 2.5785e-02
# Y | Train_2 -> R² = -1.2041, MSE = 2.3733e-01
# Theta | Test_1 -> R² = 0.0718, MSE = 2.1263e-01
# X | Test_1 -> R² = 0.1422, MSE = 8.9878e-02
# Y | Test_1 -> R² = -1.4156, MSE = 1.9799e-01
# Theta | Test_2 -> R² = 0.6568, MSE = 8.1389e-02
# X | Test_2 -> R² = 0.7189, MSE = 2.3129e-02
# Y | Test_2 -> R² = -1.3227, MSE = 2.4654e-01
# Theta | Test_3 -> R² = 0.5596, MSE = 1.4445e-01
# X | Test_3 -> R² = -0.3312, MSE = 1.2250e-01
# Y | Test_3 -> R² = -1.8634, MSE = 2.1998e-01
# Theta | Val -> R² = -8.1745, MSE = 2.9949e+00
# X | Val -> R² = -0.3379, MSE = 1.2796e-01
# Y | Val -> R² = -1.7542, MSE = 2.0510e-01
# Theta | LSG_1 -> R² = -1.6606, MSE = 1.1107e+00
# X | LSG_1 -> R² = 0.2935, MSE = 7.2413e-02
# Y | LSG_1 -> R² = -0.2726, MSE = 4.0182e-01
# Theta | LSG_2 -> R² = -7.6281, MSE = 3.0199e+00
# X | LSG_2 -> R² = 0.3743, MSE = 5.5625e-02
# Y | LSG_2 -> R² = 0.0022, MSE = 3.8336e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4092 salvo.
# Epoch 0 | Train Loss 3.026498 | Val Loss 0.812973
# Epoch 100 | Train Loss 1.008526 | Val Loss 0.672638
# Epoch 200 | Train Loss 0.813937 | Val Loss 0.640257
# Epoch 300 | Train Loss 0.757377 | Val Loss 0.636049
# Epoch 400 | Train Loss 0.734743 | Val Loss 0.632895
# Epoch 500 | Train Loss 0.724658 | Val Loss 0.630431
# Epoch 600 | Train Loss 0.719070 | Val Loss 0.627338
# Epoch 700 | Train Loss 0.715732 | Val Loss 0.624201
# Epoch 800 | Train Loss 0.713311 | Val Loss 0.621121
# Epoch 900 | Train Loss 0.711262 | Val Loss 0.618374
# Epoch 1000 | Train Loss 0.709518 | Val Loss 0.615996
# Epoch 1100 | Train Loss 0.708023 | Val Loss 0.614001
# Epoch 1200 | Train Loss 0.706690 | Val Loss 0.612418
# Epoch 1300 | Train Loss 0.705547 | Val Loss 0.611160
# Epoch 1400 | Train Loss 0.704978 | Val Loss 0.610057
# Epoch 1500 | Train Loss 0.703669 | Val Loss 0.609307
# Epoch 1600 | Train Loss 0.702874 | Val Loss 0.608608
# Epoch 1700 | Train Loss 0.702098 | Val Loss 0.607902
# Epoch 1800 | Train Loss 0.701396 | Val Loss 0.607389
# Epoch 1900 | Train Loss 0.700769 | Val Loss 0.606854
# Epoch 2000 | Train Loss 0.704125 | Val Loss 0.606383
# Early stopping at epoch 2060
# Modelo salvo em:
# models/model_arch16_r0.01_seed8653.keras
# weights/model_arch16_r0.01_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9531, MSE = 1.0673e-02
# X | Train_1 -> R² = 0.2814, MSE = 7.7490e-02
# Y | Train_1 -> R² = -1.3665, MSE = 1.9832e-01
# Theta | Train_2 -> R² = 0.9452, MSE = 1.2504e-02
# X | Train_2 -> R² = 0.6869, MSE = 2.6383e-02
# Y | Train_2 -> R² = -1.1670, MSE = 2.3333e-01
# Theta | Test_1 -> R² = 0.0014, MSE = 2.2877e-01
# X | Test_1 -> R² = 0.1498, MSE = 8.9086e-02
# Y | Test_1 -> R² = -1.4004, MSE = 1.9675e-01
# Theta | Test_2 -> R² = 0.5999, MSE = 9.4867e-02
# X | Test_2 -> R² = 0.6935, MSE = 2.5221e-02
# Y | Test_2 -> R² = -1.2065, MSE = 2.3420e-01
# Theta | Test_3 -> R² = 0.6468, MSE = 1.1586e-01
# X | Test_3 -> R² = -0.2746, MSE = 1.1730e-01
# Y | Test_3 -> R² = -2.6166, MSE = 2.7784e-01
# Theta | Val -> R² = -5.4424, MSE = 2.1030e+00
# X | Val -> R² = -0.3079, MSE = 1.2508e-01
# Y | Val -> R² = -2.0914, MSE = 2.3021e-01
# Theta | LSG_1 -> R² = -3.5112, MSE = 1.8832e+00
# X | LSG_1 -> R² = 0.3841, MSE = 6.3131e-02
# Y | LSG_1 -> R² = -0.1329, MSE = 3.5771e-01
# Theta | LSG_2 -> R² = -11.2576, MSE = 4.2902e+00
# X | LSG_2 -> R² = 0.4767, MSE = 4.6522e-02
# Y | LSG_2 -> R² = 0.0127, MSE = 3.7933e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=8653 salvo.
# Epoch 0 | Train Loss 3.861016 | Val Loss 0.809848
# Epoch 100 | Train Loss 0.983290 | Val Loss 0.672887
# Epoch 200 | Train Loss 0.863807 | Val Loss 0.660444
# Epoch 300 | Train Loss 0.851194 | Val Loss 0.652846
# Epoch 400 | Train Loss 0.829953 | Val Loss 0.644599
# Epoch 500 | Train Loss 0.774313 | Val Loss 0.631645
# Epoch 600 | Train Loss 0.727934 | Val Loss 0.615483
# Epoch 700 | Train Loss 0.720671 | Val Loss 0.607629
# Epoch 800 | Train Loss 0.717438 | Val Loss 0.603455
# Epoch 900 | Train Loss 0.714242 | Val Loss 0.600891
# Epoch 1000 | Train Loss 0.712059 | Val Loss 0.599052
# Epoch 1100 | Train Loss 0.710294 | Val Loss 0.597763
# Epoch 1200 | Train Loss 0.709444 | Val Loss 0.596732
# Epoch 1300 | Train Loss 0.707578 | Val Loss 0.596258
# Epoch 1400 | Train Loss 0.706528 | Val Loss 0.595890
# Epoch 1500 | Train Loss 0.706929 | Val Loss 0.595618
# Early stopping at epoch 1530
# Modelo salvo em:
# models/model_arch16_r0.01_seed3163.keras
# weights/model_arch16_r0.01_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9475, MSE = 1.1947e-02
# X | Train_1 -> R² = 0.2704, MSE = 7.8676e-02
# Y | Train_1 -> R² = -1.3481, MSE = 1.9678e-01
# Theta | Train_2 -> R² = 0.9171, MSE = 1.8934e-02
# X | Train_2 -> R² = 0.7079, MSE = 2.4617e-02
# Y | Train_2 -> R² = -1.1611, MSE = 2.3271e-01
# Theta | Test_1 -> R² = 0.1388, MSE = 1.9728e-01
# X | Test_1 -> R² = 0.1625, MSE = 8.7750e-02
# Y | Test_1 -> R² = -1.4688, MSE = 2.0235e-01
# Theta | Test_2 -> R² = 0.5946, MSE = 9.6129e-02
# X | Test_2 -> R² = 0.7150, MSE = 2.3452e-02
# Y | Test_2 -> R² = -1.2537, MSE = 2.3921e-01
# Theta | Test_3 -> R² = 0.2612, MSE = 2.4233e-01
# X | Test_3 -> R² = -0.9789, MSE = 1.8211e-01
# Y | Test_3 -> R² = -0.8405, MSE = 1.4140e-01
# Theta | Val -> R² = -7.8776, MSE = 2.8979e+00
# X | Val -> R² = -1.1152, MSE = 2.0230e-01
# Y | Val -> R² = -0.6633, MSE = 1.2386e-01
# Theta | LSG_1 -> R² = -0.1177, MSE = 4.6658e-01
# X | LSG_1 -> R² = 0.1529, MSE = 8.6825e-02
# Y | LSG_1 -> R² = -1.2375, MSE = 7.0647e-01
# Theta | LSG_2 -> R² = -3.9086, MSE = 1.7180e+00
# X | LSG_2 -> R² = -0.2594, MSE = 1.1197e-01
# Y | LSG_2 -> R² = -0.4084, MSE = 5.4112e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=3163 salvo.
# Epoch 0 | Train Loss 2.443467 | Val Loss 0.811827
# Epoch 100 | Train Loss 1.020921 | Val Loss 0.680029
# Epoch 200 | Train Loss 0.813093 | Val Loss 0.625552
# Epoch 300 | Train Loss 0.734692 | Val Loss 0.623050
# Epoch 400 | Train Loss 0.720275 | Val Loss 0.619674
# Epoch 500 | Train Loss 0.714984 | Val Loss 0.616306
# Epoch 600 | Train Loss 0.711703 | Val Loss 0.613683
# Epoch 700 | Train Loss 0.709802 | Val Loss 0.611682
# Epoch 800 | Train Loss 0.707906 | Val Loss 0.610137
# Epoch 900 | Train Loss 0.706672 | Val Loss 0.608764
# Epoch 1000 | Train Loss 0.705829 | Val Loss 0.607435
# Epoch 1100 | Train Loss 0.704721 | Val Loss 0.606410
# Epoch 1200 | Train Loss 0.703933 | Val Loss 0.605494
# Epoch 1300 | Train Loss 0.703420 | Val Loss 0.604647
# Epoch 1400 | Train Loss 0.702559 | Val Loss 0.603998
# Epoch 1500 | Train Loss 0.705147 | Val Loss 0.603310
# Epoch 1600 | Train Loss 0.701377 | Val Loss 0.602827
# Epoch 1700 | Train Loss 0.703607 | Val Loss 0.602220
# Epoch 1800 | Train Loss 0.700342 | Val Loss 0.601823
# Epoch 1900 | Train Loss 0.699847 | Val Loss 0.601305
# Epoch 2000 | Train Loss 0.699424 | Val Loss 0.600826
# Epoch 2100 | Train Loss 0.698928 | Val Loss 0.600273
# Early stopping at epoch 2151
# Modelo salvo em:
# models/model_arch16_r0.01_seed4006.keras
# weights/model_arch16_r0.01_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9543, MSE = 1.0395e-02
# X | Train_1 -> R² = 0.2849, MSE = 7.7113e-02
# Y | Train_1 -> R² = -1.3624, MSE = 1.9798e-01
# Theta | Train_2 -> R² = 0.9111, MSE = 2.0283e-02
# X | Train_2 -> R² = 0.7057, MSE = 2.4798e-02
# Y | Train_2 -> R² = -1.2050, MSE = 2.3743e-01
# Theta | Test_1 -> R² = 0.2094, MSE = 1.8112e-01
# X | Test_1 -> R² = 0.1351, MSE = 9.0629e-02
# Y | Test_1 -> R² = -1.5017, MSE = 2.0505e-01
# Theta | Test_2 -> R² = 0.4037, MSE = 1.4141e-01
# X | Test_2 -> R² = 0.7239, MSE = 2.2722e-02
# Y | Test_2 -> R² = -1.2328, MSE = 2.3699e-01
# Theta | Test_3 -> R² = 0.0170, MSE = 3.2244e-01
# X | Test_3 -> R² = -0.0656, MSE = 9.8060e-02
# Y | Test_3 -> R² = -1.4468, MSE = 1.8797e-01
# Theta | Val -> R² = -6.8629, MSE = 2.5667e+00
# X | Val -> R² = -0.1630, MSE = 1.1123e-01
# Y | Val -> R² = -1.1967, MSE = 1.6358e-01
# Theta | LSG_1 -> R² = -0.0219, MSE = 4.2661e-01
# X | LSG_1 -> R² = 0.1999, MSE = 8.2004e-02
# Y | LSG_1 -> R² = -0.2531, MSE = 3.9565e-01
# Theta | LSG_2 -> R² = -4.8710, MSE = 2.0549e+00
# X | LSG_2 -> R² = -0.3140, MSE = 1.1682e-01
# Y | LSG_2 -> R² = 0.0262, MSE = 3.7413e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=4006 salvo.
# Epoch 0 | Train Loss 4.934530 | Val Loss 0.818532
# Epoch 100 | Train Loss 1.030744 | Val Loss 0.687882
# Epoch 200 | Train Loss 0.865440 | Val Loss 0.666953
# Epoch 300 | Train Loss 0.857183 | Val Loss 0.667664
# Early stopping at epoch 351
# Modelo salvo em:
# models/model_arch16_r0.9_seed6134.keras
# weights/model_arch16_r0.9_seed6134.weights.h5
# Theta | Train_1 -> R² = 0.8920, MSE = 2.4574e-02
# X | Train_1 -> R² = -0.1394, MSE = 1.2287e-01
# Y | Train_1 -> R² = -1.5425, MSE = 2.1307e-01
# Theta | Train_2 -> R² = 0.4666, MSE = 1.2176e-01
# X | Train_2 -> R² = 0.4777, MSE = 4.4016e-02
# Y | Train_2 -> R² = -2.4903, MSE = 3.7583e-01
# Theta | Test_1 -> R² = 0.7238, MSE = 6.3267e-02
# X | Test_1 -> R² = -0.2151, MSE = 1.2732e-01
# Y | Test_1 -> R² = -1.7763, MSE = 2.2755e-01
# Theta | Test_2 -> R² = 0.7572, MSE = 5.7572e-02
# X | Test_2 -> R² = 0.4709, MSE = 4.3542e-02
# Y | Test_2 -> R² = -2.4380, MSE = 3.6492e-01
# Theta | Test_3 -> R² = 0.1858, MSE = 2.6707e-01
# X | Test_3 -> R² = -0.5521, MSE = 1.4283e-01
# Y | Test_3 -> R² = -3.2693, MSE = 3.2799e-01
# Theta | Val -> R² = -10.4429, MSE = 3.7353e+00
# X | Val -> R² = -0.4826, MSE = 1.4180e-01
# Y | Val -> R² = -2.7294, MSE = 2.7772e-01
# Theta | LSG_1 -> R² = -2.4382, MSE = 1.4353e+00
# X | LSG_1 -> R² = -0.5313, MSE = 1.5695e-01
# Y | LSG_1 -> R² = -0.0429, MSE = 3.2930e-01
# Theta | LSG_2 -> R² = -9.4276, MSE = 3.6497e+00
# X | LSG_2 -> R² = -0.3043, MSE = 1.1596e-01
# Y | LSG_2 -> R² = -0.0277, MSE = 3.9485e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=6134 salvo.
# Epoch 0 | Train Loss 3.650600 | Val Loss 0.799528
# Epoch 100 | Train Loss 1.036729 | Val Loss 0.689941
# Epoch 200 | Train Loss 0.843263 | Val Loss 0.650488
# Epoch 300 | Train Loss 0.791228 | Val Loss 0.648643
# Epoch 400 | Train Loss 0.741627 | Val Loss 0.631415
# Epoch 500 | Train Loss 0.722220 | Val Loss 0.620414
# Epoch 600 | Train Loss 0.716113 | Val Loss 0.614997
# Epoch 700 | Train Loss 0.712340 | Val Loss 0.611688
# Epoch 800 | Train Loss 0.709887 | Val Loss 0.609901
# Epoch 900 | Train Loss 0.708170 | Val Loss 0.608863
# Epoch 1000 | Train Loss 0.708122 | Val Loss 0.608126
# Epoch 1100 | Train Loss 0.705875 | Val Loss 0.607523
# Epoch 1200 | Train Loss 0.705009 | Val Loss 0.606856
# Epoch 1300 | Train Loss 0.704328 | Val Loss 0.606079
# Epoch 1400 | Train Loss 0.703430 | Val Loss 0.605524
# Epoch 1500 | Train Loss 0.702698 | Val Loss 0.604890
# Epoch 1600 | Train Loss 0.701926 | Val Loss 0.604286
# Epoch 1700 | Train Loss 0.701228 | Val Loss 0.603733
# Epoch 1800 | Train Loss 0.700470 | Val Loss 0.603192
# Epoch 1900 | Train Loss 0.699774 | Val Loss 0.602683
# Epoch 2000 | Train Loss 0.698999 | Val Loss 0.602169
# Epoch 2100 | Train Loss 0.698288 | Val Loss 0.601672
# Epoch 2200 | Train Loss 0.697530 | Val Loss 0.601149
# Epoch 2300 | Train Loss 0.696770 | Val Loss 0.600518
# Epoch 2400 | Train Loss 0.695979 | Val Loss 0.600031
# Epoch 2500 | Train Loss 0.695667 | Val Loss 0.599343
# Epoch 2600 | Train Loss 0.694309 | Val Loss 0.598770
# Epoch 2700 | Train Loss 0.693512 | Val Loss 0.598035
# Epoch 2800 | Train Loss 0.692495 | Val Loss 0.597416
# Epoch 2900 | Train Loss 0.705352 | Val Loss 0.596700
# Epoch 3000 | Train Loss 0.690484 | Val Loss 0.596048
# Epoch 3100 | Train Loss 0.694942 | Val Loss 0.595419
# Epoch 3200 | Train Loss 0.688286 | Val Loss 0.594900
# Early stopping at epoch 3291
# Modelo salvo em:
# models/model_arch16_r0.9_seed4092.keras
# weights/model_arch16_r0.9_seed4092.weights.h5
# Theta | Train_1 -> R² = 0.9589, MSE = 9.3503e-03
# X | Train_1 -> R² = 0.2809, MSE = 7.7542e-02
# Y | Train_1 -> R² = -1.3629, MSE = 1.9802e-01
# Theta | Train_2 -> R² = 0.9536, MSE = 1.0590e-02
# X | Train_2 -> R² = 0.6794, MSE = 2.7018e-02
# Y | Train_2 -> R² = -1.2227, MSE = 2.3934e-01
# Theta | Test_1 -> R² = 0.2254, MSE = 1.7745e-01
# X | Test_1 -> R² = 0.2211, MSE = 8.1619e-02
# Y | Test_1 -> R² = -1.5012, MSE = 2.0501e-01
# Theta | Test_2 -> R² = 0.5299, MSE = 1.1147e-01
# X | Test_2 -> R² = 0.7107, MSE = 2.3804e-02
# Y | Test_2 -> R² = -1.2855, MSE = 2.4259e-01
# Theta | Test_3 -> R² = -0.3909, MSE = 4.5623e-01
# X | Test_3 -> R² = -0.0995, MSE = 1.0118e-01
# Y | Test_3 -> R² = -1.6461, MSE = 2.0329e-01
# Theta | Val -> R² = -6.3836, MSE = 2.4102e+00
# X | Val -> R² = -0.2000, MSE = 1.1477e-01
# Y | Val -> R² = -1.9623, MSE = 2.2060e-01
# Theta | LSG_1 -> R² = -0.3701, MSE = 5.7197e-01
# X | LSG_1 -> R² = 0.1021, MSE = 9.2035e-02
# Y | LSG_1 -> R² = 0.0194, MSE = 3.0962e-01
# Theta | LSG_2 -> R² = -2.2012, MSE = 1.1204e+00
# X | LSG_2 -> R² = 0.3548, MSE = 5.7357e-02
# Y | LSG_2 -> R² = 0.0689, MSE = 3.5772e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4092 salvo.
# Epoch 0 | Train Loss 3.444565 | Val Loss 0.823476
# Epoch 100 | Train Loss 1.001408 | Val Loss 0.673961
# Epoch 200 | Train Loss 0.845280 | Val Loss 0.642219
# Epoch 300 | Train Loss 0.784994 | Val Loss 0.630800
# Epoch 400 | Train Loss 0.743341 | Val Loss 0.619636
# Epoch 500 | Train Loss 0.727189 | Val Loss 0.612176
# Epoch 600 | Train Loss 0.719689 | Val Loss 0.607735
# Epoch 700 | Train Loss 0.715966 | Val Loss 0.605460
# Epoch 800 | Train Loss 0.713490 | Val Loss 0.604068
# Epoch 900 | Train Loss 0.712694 | Val Loss 0.603046
# Epoch 1000 | Train Loss 0.709630 | Val Loss 0.602692
# Early stopping at epoch 1090
# Modelo salvo em:
# models/model_arch16_r0.9_seed8653.keras
# weights/model_arch16_r0.9_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9289, MSE = 1.6181e-02
# X | Train_1 -> R² = 0.2753, MSE = 7.8146e-02
# Y | Train_1 -> R² = -1.3667, MSE = 1.9834e-01
# Theta | Train_2 -> R² = 0.9103, MSE = 2.0486e-02
# X | Train_2 -> R² = 0.7151, MSE = 2.4010e-02
# Y | Train_2 -> R² = -1.2033, MSE = 2.3724e-01
# Theta | Test_1 -> R² = -0.1884, MSE = 2.7223e-01
# X | Test_1 -> R² = 0.1983, MSE = 8.4001e-02
# Y | Test_1 -> R² = -1.4578, MSE = 2.0145e-01
# Theta | Test_2 -> R² = 0.6441, MSE = 8.4403e-02
# X | Test_2 -> R² = 0.7230, MSE = 2.2798e-02
# Y | Test_2 -> R² = -1.2704, MSE = 2.4099e-01
# Theta | Test_3 -> R² = 0.3348, MSE = 2.1819e-01
# X | Test_3 -> R² = -0.7460, MSE = 1.6068e-01
# Y | Test_3 -> R² = -1.7736, MSE = 2.1308e-01
# Theta | Val -> R² = -10.9140, MSE = 3.8891e+00
# X | Val -> R² = -0.3966, MSE = 1.3357e-01
# Y | Val -> R² = -1.5863, MSE = 1.9259e-01
# Theta | LSG_1 -> R² = -1.4629, MSE = 1.0281e+00
# X | LSG_1 -> R² = 0.3846, MSE = 6.3073e-02
# Y | LSG_1 -> R² = -0.4478, MSE = 4.5711e-01
# Theta | LSG_2 -> R² = -8.4679, MSE = 3.3138e+00
# X | LSG_2 -> R² = 0.2077, MSE = 7.0436e-02
# Y | LSG_2 -> R² = -0.1558, MSE = 4.4405e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=8653 salvo.
# Epoch 0 | Train Loss 1.850432 | Val Loss 0.786452
# Epoch 100 | Train Loss 0.893381 | Val Loss 0.646822
# Epoch 200 | Train Loss 0.832015 | Val Loss 0.656684
# Epoch 300 | Train Loss 0.773948 | Val Loss 0.638851
# Epoch 400 | Train Loss 0.727710 | Val Loss 0.621520
# Epoch 500 | Train Loss 0.722031 | Val Loss 0.615772
# Epoch 600 | Train Loss 0.717089 | Val Loss 0.613467
# Epoch 700 | Train Loss 0.714540 | Val Loss 0.612007
# Epoch 800 | Train Loss 0.713542 | Val Loss 0.611047
# Epoch 900 | Train Loss 0.710604 | Val Loss 0.610331
# Epoch 1000 | Train Loss 0.709073 | Val Loss 0.609943
# Early stopping at epoch 1072
# Modelo salvo em:
# models/model_arch16_r0.9_seed3163.keras
# weights/model_arch16_r0.9_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9293, MSE = 1.6080e-02
# X | Train_1 -> R² = 0.2797, MSE = 7.7670e-02
# Y | Train_1 -> R² = -1.3785, MSE = 1.9933e-01
# Theta | Train_2 -> R² = 0.9322, MSE = 1.5473e-02
# X | Train_2 -> R² = 0.6863, MSE = 2.6437e-02
# Y | Train_2 -> R² = -1.2101, MSE = 2.3798e-01
# Theta | Test_1 -> R² = -0.0510, MSE = 2.4076e-01
# X | Test_1 -> R² = 0.1280, MSE = 9.1368e-02
# Y | Test_1 -> R² = -1.3066, MSE = 1.8906e-01
# Theta | Test_2 -> R² = 0.6886, MSE = 7.3833e-02
# X | Test_2 -> R² = 0.7103, MSE = 2.3841e-02
# Y | Test_2 -> R² = -1.1352, MSE = 2.2664e-01
# Theta | Test_3 -> R² = 0.6036, MSE = 1.3003e-01
# X | Test_3 -> R² = -0.5826, MSE = 1.4564e-01
# Y | Test_3 -> R² = -1.2012, MSE = 1.6911e-01
# Theta | Val -> R² = -8.7480, MSE = 3.1821e+00
# X | Val -> R² = -0.8599, MSE = 1.7788e-01
# Y | Val -> R² = -0.7421, MSE = 1.2973e-01
# Theta | LSG_1 -> R² = -0.6216, MSE = 6.7696e-01
# X | LSG_1 -> R² = 0.0626, MSE = 9.6076e-02
# Y | LSG_1 -> R² = -0.1788, MSE = 3.7218e-01
# Theta | LSG_2 -> R² = -6.5500, MSE = 2.6425e+00
# X | LSG_2 -> R² = 0.4681, MSE = 4.7288e-02
# Y | LSG_2 -> R² = -0.0054, MSE = 3.8628e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=3163 salvo.
# Epoch 0 | Train Loss 2.241555 | Val Loss 0.793116
# Epoch 100 | Train Loss 0.923813 | Val Loss 0.650596
# Epoch 200 | Train Loss 0.788552 | Val Loss 0.630311
# Epoch 300 | Train Loss 0.729686 | Val Loss 0.618437
# Epoch 400 | Train Loss 0.715012 | Val Loss 0.616643
# Epoch 500 | Train Loss 0.710320 | Val Loss 0.615936
# Epoch 600 | Train Loss 0.708445 | Val Loss 0.615167
# Epoch 700 | Train Loss 0.707173 | Val Loss 0.614407
# Epoch 800 | Train Loss 0.706147 | Val Loss 0.613716
# Epoch 900 | Train Loss 0.705265 | Val Loss 0.613070
# Epoch 1000 | Train Loss 0.704521 | Val Loss 0.612472
# Epoch 1100 | Train Loss 0.703839 | Val Loss 0.611875
# Epoch 1200 | Train Loss 0.703209 | Val Loss 0.611254
# Epoch 1300 | Train Loss 0.702601 | Val Loss 0.610570
# Epoch 1400 | Train Loss 0.702082 | Val Loss 0.609869
# Epoch 1500 | Train Loss 0.704112 | Val Loss 0.609227
# Early stopping at epoch 1578
# Modelo salvo em:
# models/model_arch16_r0.9_seed4006.keras
# weights/model_arch16_r0.9_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9522, MSE = 1.0883e-02
# X | Train_1 -> R² = 0.2823, MSE = 7.7392e-02
# Y | Train_1 -> R² = -1.3579, MSE = 1.9760e-01
# Theta | Train_2 -> R² = 0.9329, MSE = 1.5317e-02
# X | Train_2 -> R² = 0.6997, MSE = 2.5306e-02
# Y | Train_2 -> R² = -1.2073, MSE = 2.3768e-01
# Theta | Test_1 -> R² = 0.2685, MSE = 1.6757e-01
# X | Test_1 -> R² = 0.1478, MSE = 8.9297e-02
# Y | Test_1 -> R² = -1.4814, MSE = 2.0339e-01
# Theta | Test_2 -> R² = 0.5949, MSE = 9.6058e-02
# X | Test_2 -> R² = 0.7354, MSE = 2.1778e-02
# Y | Test_2 -> R² = -1.3040, MSE = 2.4455e-01
# Theta | Test_3 -> R² = 0.4585, MSE = 1.7762e-01
# X | Test_3 -> R² = -0.0111, MSE = 9.3050e-02
# Y | Test_3 -> R² = -2.2382, MSE = 2.4877e-01
# Theta | Val -> R² = -6.4985, MSE = 2.4477e+00
# X | Val -> R² = -0.3045, MSE = 1.2476e-01
# Y | Val -> R² = -2.1573, MSE = 2.3512e-01
# Theta | LSG_1 -> R² = 0.1493, MSE = 3.5511e-01
# X | LSG_1 -> R² = -0.3349, MSE = 1.3682e-01
# Y | LSG_1 -> R² = -0.3013, MSE = 4.1086e-01
# Theta | LSG_2 -> R² = -2.8442, MSE = 1.3455e+00
# X | LSG_2 -> R² = -1.2841, MSE = 2.0307e-01
# Y | LSG_2 -> R² = -0.0775, MSE = 4.1400e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=4006 salvo.
# Epoch 0 | Train Loss 1.920179 | Val Loss 0.819974
# Epoch 100 | Train Loss 0.582590 | Val Loss 0.645043
# Epoch 200 | Train Loss 0.515043 | Val Loss 0.626183
# Epoch 300 | Train Loss 0.485583 | Val Loss 0.617593
# Epoch 400 | Train Loss 0.470200 | Val Loss 0.609792
# Epoch 500 | Train Loss 0.458855 | Val Loss 0.608771
# Epoch 600 | Train Loss 0.447739 | Val Loss 0.610711
# Early stopping at epoch 623
# Modelo salvo em:
# models/model_arch32_r0.01_seed6134.keras
# weights/model_arch32_r0.01_seed6134.weights.h5
# Theta | Train_1 -> R² = 0.9379, MSE = 1.4124e-02
# X | Train_1 -> R² = 0.2585, MSE = 7.9959e-02
# Y | Train_1 -> R² = -1.3697, MSE = 1.9859e-01
# Theta | Train_2 -> R² = 0.8768, MSE = 2.8115e-02
# X | Train_2 -> R² = 0.6652, MSE = 2.8215e-02
# Y | Train_2 -> R² = -1.3674, MSE = 2.5492e-01
# Theta | Test_1 -> R² = 0.4546, MSE = 1.2494e-01
# X | Test_1 -> R² = 0.1652, MSE = 8.7466e-02
# Y | Test_1 -> R² = -1.5551, MSE = 2.0943e-01
# Theta | Test_2 -> R² = 0.8880, MSE = 2.6550e-02
# X | Test_2 -> R² = 0.6901, MSE = 2.5505e-02
# Y | Test_2 -> R² = -1.3714, MSE = 2.5170e-01
# Theta | Test_3 -> R² = 0.7581, MSE = 7.9349e-02
# X | Test_3 -> R² = -0.3647, MSE = 1.2558e-01
# Y | Test_3 -> R² = -1.8603, MSE = 2.1974e-01
# Theta | Val -> R² = -2.5183, MSE = 1.1485e+00
# X | Val -> R² = -0.5234, MSE = 1.4570e-01
# Y | Val -> R² = -0.7676, MSE = 1.3163e-01
# Theta | LSG_1 -> R² = -3.0995, MSE = 1.7113e+00
# X | LSG_1 -> R² = 0.1737, MSE = 8.4694e-02
# Y | LSG_1 -> R² = -0.5047, MSE = 4.7509e-01
# Theta | LSG_2 -> R² = -11.7042, MSE = 4.4465e+00
# X | LSG_2 -> R² = -0.2027, MSE = 1.0693e-01
# Y | LSG_2 -> R² = -0.2579, MSE = 4.8329e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=6134 salvo.
# Epoch 0 | Train Loss 2.082227 | Val Loss 0.818533
# Epoch 100 | Train Loss 0.591605 | Val Loss 0.653584
# Epoch 200 | Train Loss 0.502205 | Val Loss 0.620695
# Epoch 300 | Train Loss 0.481677 | Val Loss 0.613892
# Epoch 400 | Train Loss 0.466815 | Val Loss 0.608444
# Epoch 500 | Train Loss 0.454287 | Val Loss 0.607119
# Epoch 600 | Train Loss 0.445284 | Val Loss 0.609164
# Early stopping at epoch 648
# Modelo salvo em:
# models/model_arch32_r0.01_seed4092.keras
# weights/model_arch32_r0.01_seed4092.weights.h5
# Theta | Train_1 -> R² = 0.9292, MSE = 1.6115e-02
# X | Train_1 -> R² = 0.2532, MSE = 8.0536e-02
# Y | Train_1 -> R² = -1.3684, MSE = 1.9848e-01
# Theta | Train_2 -> R² = 0.8313, MSE = 3.8504e-02
# X | Train_2 -> R² = 0.6833, MSE = 2.6688e-02
# Y | Train_2 -> R² = -1.3088, MSE = 2.4861e-01
# Theta | Test_1 -> R² = 0.3721, MSE = 1.4384e-01
# X | Test_1 -> R² = 0.1590, MSE = 8.8122e-02
# Y | Test_1 -> R² = -1.5626, MSE = 2.1004e-01
# Theta | Test_2 -> R² = 0.8652, MSE = 3.1968e-02
# X | Test_2 -> R² = 0.7050, MSE = 2.4280e-02
# Y | Test_2 -> R² = -1.3660, MSE = 2.5114e-01
# Theta | Test_3 -> R² = 0.7734, MSE = 7.4322e-02
# X | Test_3 -> R² = -0.2967, MSE = 1.1933e-01
# Y | Test_3 -> R² = -1.5956, MSE = 1.9940e-01
# Theta | Val -> R² = -2.9921, MSE = 1.3031e+00
# X | Val -> R² = 0.1206, MSE = 8.4103e-02
# Y | Val -> R² = -1.6836, MSE = 1.9984e-01
# Theta | LSG_1 -> R² = -0.6960, MSE = 7.0800e-01
# X | LSG_1 -> R² = 0.4311, MSE = 5.8308e-02
# Y | LSG_1 -> R² = -0.3210, MSE = 4.1708e-01
# Theta | LSG_2 -> R² = -7.2042, MSE = 2.8715e+00
# X | LSG_2 -> R² = 0.2349, MSE = 6.8023e-02
# Y | LSG_2 -> R² = -0.1092, MSE = 4.2618e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4092 salvo.
# Epoch 0 | Train Loss 1.272003 | Val Loss 0.811867
# Epoch 100 | Train Loss 0.550605 | Val Loss 0.645455
# Epoch 200 | Train Loss 0.500654 | Val Loss 0.629796
# Epoch 300 | Train Loss 0.475210 | Val Loss 0.610785
# Epoch 400 | Train Loss 0.462486 | Val Loss 0.601176
# Epoch 500 | Train Loss 0.449816 | Val Loss 0.596968
# Epoch 600 | Train Loss 0.441673 | Val Loss 0.595822
# Epoch 700 | Train Loss 0.436828 | Val Loss 0.596626
# Early stopping at epoch 787
# Modelo salvo em:
# models/model_arch32_r0.01_seed8653.keras
# weights/model_arch32_r0.01_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9396, MSE = 1.3735e-02
# X | Train_1 -> R² = 0.2509, MSE = 8.0777e-02
# Y | Train_1 -> R² = -1.3534, MSE = 1.9722e-01
# Theta | Train_2 -> R² = 0.8808, MSE = 2.7223e-02
# X | Train_2 -> R² = 0.6960, MSE = 2.5619e-02
# Y | Train_2 -> R² = -1.3365, MSE = 2.5158e-01
# Theta | Test_1 -> R² = 0.4782, MSE = 1.1953e-01
# X | Test_1 -> R² = 0.1721, MSE = 8.6746e-02
# Y | Test_1 -> R² = -1.5451, MSE = 2.0861e-01
# Theta | Test_2 -> R² = 0.7264, MSE = 6.4874e-02
# X | Test_2 -> R² = 0.7097, MSE = 2.3892e-02
# Y | Test_2 -> R² = -1.4089, MSE = 2.5569e-01
# Theta | Test_3 -> R² = 0.7775, MSE = 7.2986e-02
# X | Test_3 -> R² = -0.8069, MSE = 1.6628e-01
# Y | Test_3 -> R² = -0.6532, MSE = 1.2701e-01
# Theta | Val -> R² = -0.8400, MSE = 6.0062e-01
# X | Val -> R² = -0.2765, MSE = 1.2208e-01
# Y | Val -> R² = -0.7453, MSE = 1.2997e-01
# Theta | LSG_1 -> R² = 0.4639, MSE = 2.2379e-01
# X | LSG_1 -> R² = 0.3373, MSE = 6.7919e-02
# Y | LSG_1 -> R² = -0.4318, MSE = 4.5206e-01
# Theta | LSG_2 -> R² = -4.2996, MSE = 1.8549e+00
# X | LSG_2 -> R² = 0.0296, MSE = 8.6272e-02
# Y | LSG_2 -> R² = -0.0973, MSE = 4.2157e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=8653 salvo.
# Epoch 0 | Train Loss 1.876648 | Val Loss 0.795465
# Epoch 100 | Train Loss 0.553097 | Val Loss 0.650422
# Epoch 200 | Train Loss 0.497649 | Val Loss 0.623950
# Epoch 300 | Train Loss 0.474984 | Val Loss 0.606571
# Epoch 400 | Train Loss 0.458600 | Val Loss 0.596954
# Epoch 500 | Train Loss 0.445895 | Val Loss 0.596140
# Epoch 600 | Train Loss 0.439888 | Val Loss 0.598661
# Early stopping at epoch 637
# Modelo salvo em:
# models/model_arch32_r0.01_seed3163.keras
# weights/model_arch32_r0.01_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9400, MSE = 1.3645e-02
# X | Train_1 -> R² = 0.2432, MSE = 8.1608e-02
# Y | Train_1 -> R² = -1.3845, MSE = 1.9983e-01
# Theta | Train_2 -> R² = 0.8867, MSE = 2.5874e-02
# X | Train_2 -> R² = 0.6884, MSE = 2.6261e-02
# Y | Train_2 -> R² = -1.2573, MSE = 2.4306e-01
# Theta | Test_1 -> R² = 0.3572, MSE = 1.4725e-01
# X | Test_1 -> R² = 0.1634, MSE = 8.7658e-02
# Y | Test_1 -> R² = -1.4713, MSE = 2.0256e-01
# Theta | Test_2 -> R² = 0.8753, MSE = 2.9568e-02
# X | Test_2 -> R² = 0.7034, MSE = 2.4409e-02
# Y | Test_2 -> R² = -1.2516, MSE = 2.3899e-01
# Theta | Test_3 -> R² = 0.4811, MSE = 1.7022e-01
# X | Test_3 -> R² = -0.8349, MSE = 1.6886e-01
# Y | Test_3 -> R² = -0.4053, MSE = 1.0796e-01
# Theta | Val -> R² = -1.4120, MSE = 7.8734e-01
# X | Val -> R² = -0.4627, MSE = 1.3989e-01
# Y | Val -> R² = -0.1841, MSE = 8.8177e-02
# Theta | LSG_1 -> R² = 0.1789, MSE = 3.4278e-01
# X | LSG_1 -> R² = 0.3665, MSE = 6.4930e-02
# Y | LSG_1 -> R² = -0.5590, MSE = 4.9223e-01
# Theta | LSG_2 -> R² = -4.0320, MSE = 1.7612e+00
# X | LSG_2 -> R² = 0.2385, MSE = 6.7698e-02
# Y | LSG_2 -> R² = -0.0452, MSE = 4.0159e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=3163 salvo.
# Epoch 0 | Train Loss 2.824282 | Val Loss 0.793790
# Epoch 100 | Train Loss 0.610074 | Val Loss 0.662231
# Epoch 200 | Train Loss 0.545356 | Val Loss 0.638336
# Epoch 300 | Train Loss 0.521423 | Val Loss 0.632550
# Epoch 400 | Train Loss 0.489127 | Val Loss 0.619613
# Epoch 500 | Train Loss 0.468652 | Val Loss 0.609040
# Epoch 600 | Train Loss 0.459556 | Val Loss 0.606139
# Epoch 700 | Train Loss 0.452547 | Val Loss 0.605037
# Epoch 800 | Train Loss 0.453359 | Val Loss 0.605008
# Early stopping at epoch 858
# Modelo salvo em:
# models/model_arch32_r0.01_seed4006.keras
# weights/model_arch32_r0.01_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9376, MSE = 1.4207e-02
# X | Train_1 -> R² = 0.2508, MSE = 8.0789e-02
# Y | Train_1 -> R² = -1.3606, MSE = 1.9783e-01
# Theta | Train_2 -> R² = 0.8599, MSE = 3.1992e-02
# X | Train_2 -> R² = 0.6960, MSE = 2.5620e-02
# Y | Train_2 -> R² = -1.3704, MSE = 2.5524e-01
# Theta | Test_1 -> R² = 0.2868, MSE = 1.6338e-01
# X | Test_1 -> R² = 0.1700, MSE = 8.6972e-02
# Y | Test_1 -> R² = -1.5589, MSE = 2.0974e-01
# Theta | Test_2 -> R² = 0.8857, MSE = 2.7108e-02
# X | Test_2 -> R² = 0.7049, MSE = 2.4281e-02
# Y | Test_2 -> R² = -1.3808, MSE = 2.5270e-01
# Theta | Test_3 -> R² = 0.5810, MSE = 1.3744e-01
# X | Test_3 -> R² = -0.4338, MSE = 1.3195e-01
# Y | Test_3 -> R² = -1.2132, MSE = 1.7002e-01
# Theta | Val -> R² = -2.3492, MSE = 1.0933e+00
# X | Val -> R² = -0.2044, MSE = 1.1519e-01
# Y | Val -> R² = -0.7349, MSE = 1.2919e-01
# Theta | LSG_1 -> R² = -0.9588, MSE = 8.1771e-01
# X | LSG_1 -> R² = 0.3451, MSE = 6.7124e-02
# Y | LSG_1 -> R² = -0.4963, MSE = 4.7243e-01
# Theta | LSG_2 -> R² = -6.1272, MSE = 2.4946e+00
# X | LSG_2 -> R² = 0.1562, MSE = 7.5020e-02
# Y | LSG_2 -> R² = -0.1775, MSE = 4.5239e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=4006 salvo.
# Epoch 0 | Train Loss 1.584378 | Val Loss 0.817405
# Epoch 100 | Train Loss 0.583838 | Val Loss 0.645127
# Epoch 200 | Train Loss 0.503123 | Val Loss 0.623402
# Epoch 300 | Train Loss 0.481894 | Val Loss 0.614384
# Epoch 400 | Train Loss 0.469513 | Val Loss 0.606063
# Epoch 500 | Train Loss 0.456505 | Val Loss 0.601550
# Epoch 600 | Train Loss 0.445526 | Val Loss 0.603797
# Early stopping at epoch 677
# Modelo salvo em:
# models/model_arch32_r0.9_seed6134.keras
# ...
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4092 salvo.
# Epoch 0 | Train Loss 4.846772 | Val Loss 0.837066
# Epoch 100 | Train Loss 0.829477 | Val Loss 0.624476
# Epoch 200 | Train Loss 0.732684 | Val Loss 0.623691
# Epoch 300 | Train Loss 0.755686 | Val Loss 0.615958
# Epoch 400 | Train Loss 0.706603 | Val Loss 0.613264
# Epoch 500 | Train Loss 0.703474 | Val Loss 0.609978
# Epoch 600 | Train Loss 0.701763 | Val Loss 0.607925
# Epoch 700 | Train Loss 0.700217 | Val Loss 0.606228
# Epoch 800 | Train Loss 0.698529 | Val Loss 0.603560
# Epoch 900 | Train Loss 0.697404 | Val Loss 0.602131
# Epoch 1000 | Train Loss 0.698507 | Val Loss 0.601214
# Epoch 1100 | Train Loss 0.694397 | Val Loss 0.599747
# Epoch 1200 | Train Loss 0.693602 | Val Loss 0.598925
# Epoch 1300 | Train Loss 0.691048 | Val Loss 0.596104
# Early stopping at epoch 1333
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed8653.keras
# weights/model_arch264-128-64_r0.01_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9510, MSE = 1.1151e-02
# X | Train_1 -> R² = 0.2934, MSE = 7.6196e-02
# Y | Train_1 -> R² = -1.3711, MSE = 1.9870e-01
# Theta | Train_2 -> R² = -1.1929, MSE = 5.0061e-01
# X | Train_2 -> R² = 0.6388, MSE = 3.0440e-02
# Y | Train_2 -> R² = -1.2198, MSE = 2.3903e-01
# Theta | Test_1 -> R² = 0.3865, MSE = 1.4054e-01
# X | Test_1 -> R² = 0.2397, MSE = 7.9669e-02
# Y | Test_1 -> R² = -1.4631, MSE = 2.0188e-01
# Theta | Test_2 -> R² = -0.2801, MSE = 3.0355e-01
# X | Test_2 -> R² = 0.6821, MSE = 2.6158e-02
# Y | Test_2 -> R² = -1.2763, MSE = 2.4161e-01
# Theta | Test_3 -> R² = 0.2909, MSE = 2.3261e-01
# X | Test_3 -> R² = 0.0524, MSE = 8.7208e-02
# Y | Test_3 -> R² = -2.5640, MSE = 2.7380e-01
# Theta | Val -> R² = -6.3825, MSE = 2.4099e+00
# X | Val -> R² = 0.0563, MSE = 9.0250e-02
# Y | Val -> R² = -1.9974, MSE = 2.2321e-01
# Theta | LSG_1 -> R² = -0.2300, MSE = 5.1347e-01
# X | LSG_1 -> R² = 0.0001, MSE = 1.0248e-01
# Y | LSG_1 -> R² = -0.0942, MSE = 3.4549e-01
# Theta | LSG_2 -> R² = -5.4611, MSE = 2.2614e+00
# X | LSG_2 -> R² = -0.3487, MSE = 1.1990e-01
# Y | LSG_2 -> R² = -0.0358, MSE = 3.9797e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=8653 salvo.
# Epoch 0 | Train Loss 4.410738 | Val Loss 0.795925
# Epoch 100 | Train Loss 0.764658 | Val Loss 0.628157
# Epoch 200 | Train Loss 0.731635 | Val Loss 0.617028
# Epoch 300 | Train Loss 0.711675 | Val Loss 0.613544
# Epoch 400 | Train Loss 0.710493 | Val Loss 0.608380
# Epoch 500 | Train Loss 0.704195 | Val Loss 0.608515
# Epoch 600 | Train Loss 0.910180 | Val Loss 0.607313
# Epoch 700 | Train Loss 0.701126 | Val Loss 0.605661
# Epoch 800 | Train Loss 0.699229 | Val Loss 0.603403
# Epoch 900 | Train Loss 0.698667 | Val Loss 0.602956
# Epoch 1000 | Train Loss 0.696439 | Val Loss 0.600106
# Early stopping at epoch 1016
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed3163.keras
# weights/model_arch264-128-64_r0.01_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9504, MSE = 1.1292e-02
# X | Train_1 -> R² = 0.2938, MSE = 7.6149e-02
# Y | Train_1 -> R² = -1.3688, MSE = 1.9851e-01
# Theta | Train_2 -> R² = -1.4681, MSE = 5.6344e-01
# X | Train_2 -> R² = 0.6306, MSE = 3.1124e-02
# Y | Train_2 -> R² = -0.9429, MSE = 2.0921e-01
# Theta | Test_1 -> R² = 0.2888, MSE = 1.6293e-01
# X | Test_1 -> R² = 0.2216, MSE = 8.1564e-02
# Y | Test_1 -> R² = -1.6293, MSE = 2.1551e-01
# Theta | Test_2 -> R² = -0.4186, MSE = 3.3638e-01
# X | Test_2 -> R² = 0.6717, MSE = 2.7016e-02
# Y | Test_2 -> R² = -1.0694, MSE = 2.1965e-01
# Theta | Test_3 -> R² = 0.3290, MSE = 2.2010e-01
# X | Test_3 -> R² = 0.0125, MSE = 9.0878e-02
# Y | Test_3 -> R² = -2.2106, MSE = 2.4665e-01
# Theta | Val -> R² = -6.5633, MSE = 2.4689e+00
# X | Val -> R² = 0.0078, MSE = 9.4889e-02
# Y | Val -> R² = -2.3375, MSE = 2.4854e-01
# Theta | LSG_1 -> R² = 0.1461, MSE = 3.5646e-01
# X | LSG_1 -> R² = 0.0585, MSE = 9.6504e-02
# Y | LSG_1 -> R² = -0.1529, MSE = 3.6402e-01
# Theta | LSG_2 -> R² = -3.4685, MSE = 1.5640e+00
# X | LSG_2 -> R² = -0.4199, MSE = 1.2623e-01
# Y | LSG_2 -> R² = -0.0609, MSE = 4.0760e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=3163 salvo.
# Epoch 0 | Train Loss 4.816408 | Val Loss 0.815249
# Epoch 100 | Train Loss 0.777105 | Val Loss 0.623857
# Epoch 200 | Train Loss 0.722174 | Val Loss 0.619812
# Epoch 300 | Train Loss 0.745371 | Val Loss 0.615106
# Epoch 400 | Train Loss 0.708988 | Val Loss 0.614719
# Epoch 500 | Train Loss 0.705645 | Val Loss 0.613051
# Epoch 600 | Train Loss 0.704548 | Val Loss 0.612012
# Epoch 700 | Train Loss 0.701993 | Val Loss 0.609378
# Epoch 800 | Train Loss 0.719701 | Val Loss 0.606007
# Epoch 900 | Train Loss 0.699308 | Val Loss 0.605709
# Epoch 1000 | Train Loss 0.734835 | Val Loss 0.605213
# Epoch 1100 | Train Loss 0.694727 | Val Loss 0.601977
# Epoch 1200 | Train Loss 0.693782 | Val Loss 0.601608
# Epoch 1300 | Train Loss 0.689394 | Val Loss 0.598366
# Early stopping at epoch 1335
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed4006.keras
# weights/model_arch264-128-64_r0.01_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9359, MSE = 1.4583e-02
# X | Train_1 -> R² = 0.2975, MSE = 7.5753e-02
# Y | Train_1 -> R² = -1.3470, MSE = 1.9669e-01
# Theta | Train_2 -> R² = -1.8845, MSE = 6.5849e-01
# X | Train_2 -> R² = 0.6676, MSE = 2.8008e-02
# Y | Train_2 -> R² = -1.1570, MSE = 2.3227e-01
# Theta | Test_1 -> R² = 0.3792, MSE = 1.4222e-01
# X | Test_1 -> R² = 0.2533, MSE = 7.8237e-02
# Y | Test_1 -> R² = -1.4813, MSE = 2.0338e-01
# Theta | Test_2 -> R² = -0.5978, MSE = 3.7889e-01
# X | Test_2 -> R² = 0.6799, MSE = 2.6342e-02
# Y | Test_2 -> R² = -1.2571, MSE = 2.3957e-01
# Theta | Test_3 -> R² = 0.2061, MSE = 2.6041e-01
# X | Test_3 -> R² = -0.0102, MSE = 9.2961e-02
# Y | Test_3 -> R² = -2.3936, MSE = 2.6071e-01
# Theta | Val -> R² = -6.7179, MSE = 2.5194e+00
# X | Val -> R² = -0.0271, MSE = 9.8230e-02
# Y | Val -> R² = -2.2180, MSE = 2.3964e-01
# Theta | LSG_1 -> R² = -1.1018, MSE = 8.7743e-01
# X | LSG_1 -> R² = 0.1184, MSE = 9.0359e-02
# Y | LSG_1 -> R² = -0.1323, MSE = 3.5750e-01
# Theta | LSG_2 -> R² = -5.5765, MSE = 2.3018e+00
# X | LSG_2 -> R² = -0.3022, MSE = 1.1577e-01
# Y | LSG_2 -> R² = -0.0448, MSE = 4.0141e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=4006 salvo.
# Epoch 0 | Train Loss 2.269100 | Val Loss 0.817012
# Epoch 100 | Train Loss 0.814730 | Val Loss 0.628137
# Epoch 200 | Train Loss 0.731379 | Val Loss 0.628147
# Epoch 300 | Train Loss 0.717598 | Val Loss 0.620340
# Epoch 400 | Train Loss 0.707781 | Val Loss 0.615340
# Epoch 500 | Train Loss 0.704070 | Val Loss 0.611611
# Epoch 600 | Train Loss 0.701983 | Val Loss 0.610175
# Epoch 700 | Train Loss 0.699109 | Val Loss 0.606546
# Epoch 800 | Train Loss 0.696537 | Val Loss 0.603711
# Epoch 900 | Train Loss 0.695454 | Val Loss 0.603762
# Epoch 1000 | Train Loss 0.692128 | Val Loss 0.600103
# Epoch 1100 | Train Loss 0.688933 | Val Loss 0.597584
# Epoch 1200 | Train Loss 0.688029 | Val Loss 0.597736
# Epoch 1300 | Train Loss 0.683796 | Val Loss 0.595151
# Early stopping at epoch 1316
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed6134.keras
# weights/model_arch264-128-64_r0.9_seed6134.weights.h5
# Theta | Train_1 -> R² = 0.9405, MSE = 1.3535e-02
# X | Train_1 -> R² = 0.2946, MSE = 7.6070e-02
# Y | Train_1 -> R² = -1.3330, MSE = 1.9552e-01
# Theta | Train_2 -> R² = -2.2557, MSE = 7.4323e-01
# X | Train_2 -> R² = 0.5638, MSE = 3.6754e-02
# Y | Train_2 -> R² = -1.4033, MSE = 2.5878e-01
# Theta | Test_1 -> R² = 0.4379, MSE = 1.2877e-01
# X | Test_1 -> R² = 0.2610, MSE = 7.7430e-02
# Y | Test_1 -> R² = -1.4773, MSE = 2.0305e-01
# Theta | Test_2 -> R² = -1.1903, MSE = 5.1938e-01
# X | Test_2 -> R² = 0.5881, MSE = 3.3893e-02
# Y | Test_2 -> R² = -1.5024, MSE = 2.6561e-01
# Theta | Test_3 -> R² = -0.9757, MSE = 6.4806e-01
# X | Test_3 -> R² = 0.0090, MSE = 9.1198e-02
# Y | Test_3 -> R² = -3.1595, MSE = 3.1955e-01
# Theta | Val -> R² = -8.8780, MSE = 3.2245e+00
# X | Val -> R² = 0.0136, MSE = 9.4339e-02
# Y | Val -> R² = -2.9332, MSE = 2.9290e-01
# Theta | LSG_1 -> R² = -1.3265, MSE = 9.7123e-01
# X | LSG_1 -> R² = 0.0616, MSE = 9.6179e-02
# Y | LSG_1 -> R² = -0.1609, MSE = 3.6653e-01
# Theta | LSG_2 -> R² = -7.6382, MSE = 3.0234e+00
# X | LSG_2 -> R² = -0.1725, MSE = 1.0424e-01
# Y | LSG_2 -> R² = -0.1041, MSE = 4.2421e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=6134 salvo.
# Epoch 0 | Train Loss 3.772297 | Val Loss 0.783989
# Epoch 100 | Train Loss 0.794293 | Val Loss 0.618444
# Epoch 200 | Train Loss 0.728383 | Val Loss 0.614539
# Epoch 300 | Train Loss 0.714975 | Val Loss 0.610441
# Epoch 400 | Train Loss 0.708734 | Val Loss 0.609162
# Epoch 500 | Train Loss 0.706918 | Val Loss 0.609351
# Epoch 600 | Train Loss 0.703628 | Val Loss 0.608531
# Epoch 700 | Train Loss 0.701224 | Val Loss 0.607350
# Early stopping at epoch 705
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed4092.keras
# weights/model_arch264-128-64_r0.9_seed4092.weights.h5
# Theta | Train_1 -> R² = 0.9447, MSE = 1.2577e-02
# X | Train_1 -> R² = 0.2863, MSE = 7.6964e-02
# Y | Train_1 -> R² = -1.3535, MSE = 1.9723e-01
# Theta | Train_2 -> R² = -1.2496, MSE = 5.1356e-01
# X | Train_2 -> R² = 0.7071, MSE = 2.4681e-02
# Y | Train_2 -> R² = -1.5723, MSE = 2.7697e-01
# Theta | Test_1 -> R² = 0.0790, MSE = 2.1098e-01
# X | Test_1 -> R² = 0.1981, MSE = 8.4022e-02
# Y | Test_1 -> R² = -1.5836, MSE = 2.1176e-01
# Theta | Test_2 -> R² = -0.4619, MSE = 3.4666e-01
# X | Test_2 -> R² = 0.7269, MSE = 2.2473e-02
# Y | Test_2 -> R² = -1.6443, MSE = 2.8067e-01
# Theta | Test_3 -> R² = 0.5211, MSE = 1.5709e-01
# X | Test_3 -> R² = -0.2164, MSE = 1.1194e-01
# Y | Test_3 -> R² = -2.7867, MSE = 2.9091e-01
# Theta | Val -> R² = -7.4598, MSE = 2.7615e+00
# X | Val -> R² = -0.1965, MSE = 1.1444e-01
# Y | Val -> R² = -2.5883, MSE = 2.6721e-01
# Theta | LSG_1 -> R² = 0.3218, MSE = 2.8312e-01
# X | LSG_1 -> R² = 0.2527, MSE = 7.6590e-02
# Y | LSG_1 -> R² = -0.2031, MSE = 3.7986e-01
# Theta | LSG_2 -> R² = -1.8424, MSE = 9.9485e-01
# X | LSG_2 -> R² = -0.1002, MSE = 9.7811e-02
# Y | LSG_2 -> R² = -0.1334, MSE = 4.3548e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4092 salvo.
# Epoch 0 | Train Loss 2.281672 | Val Loss 0.835220
# Epoch 100 | Train Loss 0.837898 | Val Loss 0.633041
# Epoch 200 | Train Loss 0.745154 | Val Loss 0.626638
# Epoch 300 | Train Loss 0.716650 | Val Loss 0.620418
# Epoch 400 | Train Loss 0.711833 | Val Loss 0.616600
# Epoch 500 | Train Loss 0.707011 | Val Loss 0.615280
# Epoch 600 | Train Loss 0.752606 | Val Loss 0.613019
# Epoch 700 | Train Loss 0.703088 | Val Loss 0.611006
# Epoch 800 | Train Loss 0.701188 | Val Loss 0.609127
# Epoch 900 | Train Loss 0.718746 | Val Loss 0.606367
# Epoch 1000 | Train Loss 0.698698 | Val Loss 0.606337
# Epoch 1100 | Train Loss 0.696469 | Val Loss 0.603740
# Epoch 1200 | Train Loss 0.694183 | Val Loss 0.601128
# Epoch 1300 | Train Loss 0.693147 | Val Loss 0.600728
# Epoch 1400 | Train Loss 0.690961 | Val Loss 0.598608
# Epoch 1500 | Train Loss 0.687495 | Val Loss 0.596615
# Epoch 1600 | Train Loss 0.687556 | Val Loss 0.598472
# Epoch 1700 | Train Loss 0.682707 | Val Loss 0.594969
# Early stopping at epoch 1730
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed8653.keras
# weights/model_arch264-128-64_r0.9_seed8653.weights.h5
# Theta | Train_1 -> R² = 0.9537, MSE = 1.0538e-02
# X | Train_1 -> R² = 0.2934, MSE = 7.6193e-02
# Y | Train_1 -> R² = -1.3823, MSE = 1.9965e-01
# Theta | Train_2 -> R² = -2.3284, MSE = 7.5984e-01
# X | Train_2 -> R² = 0.5425, MSE = 3.8556e-02
# Y | Train_2 -> R² = -1.3642, MSE = 2.5457e-01
# Theta | Test_1 -> R² = 0.4495, MSE = 1.2612e-01
# X | Test_1 -> R² = 0.2670, MSE = 7.6804e-02
# Y | Test_1 -> R² = -1.4229, MSE = 1.9859e-01
# Theta | Test_2 -> R² = -1.3002, MSE = 5.4544e-01
# X | Test_2 -> R² = 0.5969, MSE = 3.3173e-02
# Y | Test_2 -> R² = -1.3914, MSE = 2.5383e-01
# Theta | Test_3 -> R² = -2.1976, MSE = 1.0489e+00
# X | Test_3 -> R² = -0.0275, MSE = 9.4559e-02
# Y | Test_3 -> R² = -3.1411, MSE = 3.1813e-01
# Theta | Val -> R² = -10.1896, MSE = 3.6526e+00
# X | Val -> R² = 0.0132, MSE = 9.4376e-02
# Y | Val -> R² = -2.9716, MSE = 2.9575e-01
# Theta | LSG_1 -> R² = -3.2408, MSE = 1.7703e+00
# X | LSG_1 -> R² = -0.0396, MSE = 1.0656e-01
# Y | LSG_1 -> R² = -0.1326, MSE = 3.5760e-01
# Theta | LSG_2 -> R² = -12.6558, MSE = 4.7796e+00
# X | LSG_2 -> R² = -0.3490, MSE = 1.1993e-01
# Y | LSG_2 -> R² = -0.0931, MSE = 4.1997e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=8653 salvo.
# Epoch 0 | Train Loss 3.823237 | Val Loss 0.836799
# Epoch 100 | Train Loss 0.775524 | Val Loss 0.637667
# Epoch 200 | Train Loss 0.720450 | Val Loss 0.626678
# Epoch 300 | Train Loss 0.712282 | Val Loss 0.622163
# Epoch 400 | Train Loss 0.708164 | Val Loss 0.618022
# Epoch 500 | Train Loss 0.705895 | Val Loss 0.615194
# Epoch 600 | Train Loss 0.703292 | Val Loss 0.611666
# Epoch 700 | Train Loss 0.702222 | Val Loss 0.608818
# Epoch 800 | Train Loss 0.700119 | Val Loss 0.605975
# Epoch 900 | Train Loss 0.699550 | Val Loss 0.604679
# Epoch 1000 | Train Loss 0.697229 | Val Loss 0.601922
# Epoch 1100 | Train Loss 0.807146 | Val Loss 0.598231
# Epoch 1200 | Train Loss 0.695147 | Val Loss 0.599015
# Early stopping at epoch 1297
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed3163.keras
# weights/model_arch264-128-64_r0.9_seed3163.weights.h5
# Theta | Train_1 -> R² = 0.9566, MSE = 9.8748e-03
# X | Train_1 -> R² = 0.2886, MSE = 7.6711e-02
# Y | Train_1 -> R² = -1.3330, MSE = 1.9552e-01
# Theta | Train_2 -> R² = 0.3195, MSE = 1.5536e-01
# X | Train_2 -> R² = 0.7307, MSE = 2.2692e-02
# Y | Train_2 -> R² = -0.7232, MSE = 1.8555e-01
# Theta | Test_1 -> R² = 0.3607, MSE = 1.4645e-01
# X | Test_1 -> R² = 0.2539, MSE = 7.8180e-02
# Y | Test_1 -> R² = -1.4320, MSE = 1.9934e-01
# Theta | Test_2 -> R² = -0.5138, MSE = 3.5896e-01
# X | Test_2 -> R² = 0.7513, MSE = 2.0463e-02
# Y | Test_2 -> R² = -0.7762, MSE = 1.8853e-01
# Theta | Test_3 -> R² = 0.3194, MSE = 2.2326e-01
# X | Test_3 -> R² = -0.0889, MSE = 1.0020e-01
# Y | Test_3 -> R² = -2.2832, MSE = 2.5223e-01
# Theta | Val -> R² = -5.9612, MSE = 2.2723e+00
# X | Val -> R² = -0.0332, MSE = 9.8819e-02
# Y | Val -> R² = -1.8564, MSE = 2.1271e-01
# Theta | LSG_1 -> R² = 0.3505, MSE = 2.7115e-01
# X | LSG_1 -> R² = 0.0891, MSE = 9.3365e-02
# Y | LSG_1 -> R² = -0.1820, MSE = 3.7321e-01
# Theta | LSG_2 -> R² = -0.3608, MSE = 4.7628e-01
# X | LSG_2 -> R² = -0.3750, MSE = 1.2225e-01
# Y | LSG_2 -> R² = -0.0713, MSE = 4.1161e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=3163 salvo.
# Epoch 0 | Train Loss 4.204685 | Val Loss 0.815389
# Epoch 100 | Train Loss 0.757622 | Val Loss 0.622633
# Epoch 200 | Train Loss 0.720051 | Val Loss 0.614904
# Epoch 300 | Train Loss 0.711668 | Val Loss 0.611753
# Epoch 400 | Train Loss 0.706842 | Val Loss 0.609064
# Epoch 500 | Train Loss 0.752519 | Val Loss 0.607333
# Epoch 600 | Train Loss 0.702742 | Val Loss 0.606153
# Epoch 700 | Train Loss 0.700620 | Val Loss 0.603800
# Epoch 800 | Train Loss 0.699156 | Val Loss 0.602970
# Epoch 900 | Train Loss 0.697610 | Val Loss 0.601806
# Epoch 1000 | Train Loss 0.729633 | Val Loss 0.600398
# Epoch 1100 | Train Loss 0.694492 | Val Loss 0.599057
# Epoch 1200 | Train Loss 0.691379 | Val Loss 0.596516
# Early stopping at epoch 1203
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed4006.keras
# weights/model_arch264-128-64_r0.9_seed4006.weights.h5
# Theta | Train_1 -> R² = 0.9371, MSE = 1.4311e-02
# X | Train_1 -> R² = 0.2754, MSE = 7.8137e-02
# Y | Train_1 -> R² = -1.3599, MSE = 1.9777e-01
# Theta | Train_2 -> R² = -1.7305, MSE = 6.2333e-01
# X | Train_2 -> R² = 0.7267, MSE = 2.3034e-02
# Y | Train_2 -> R² = -1.2397, MSE = 2.4117e-01
# Theta | Test_1 -> R² = 0.3948, MSE = 1.3865e-01
# X | Test_1 -> R² = 0.2314, MSE = 8.0532e-02
# Y | Test_1 -> R² = -1.4959, MSE = 2.0457e-01
# Theta | Test_2 -> R² = -0.6420, MSE = 3.8937e-01
# X | Test_2 -> R² = 0.7397, MSE = 2.1420e-02
# Y | Test_2 -> R² = -1.3551, MSE = 2.4997e-01
# Theta | Test_3 -> R² = 0.1624, MSE = 2.7474e-01
# X | Test_3 -> R² = -0.0135, MSE = 9.3267e-02
# Y | Test_3 -> R² = -2.4006, MSE = 2.6125e-01
# Theta | Val -> R² = -6.5521, MSE = 2.4652e+00
# X | Val -> R² = -0.0197, MSE = 9.7525e-02
# Y | Val -> R² = -2.2188, MSE = 2.3969e-01
# Theta | LSG_1 -> R² = 0.0373, MSE = 4.0190e-01
# X | LSG_1 -> R² = 0.0932, MSE = 9.2945e-02
# Y | LSG_1 -> R² = -0.1776, MSE = 3.7181e-01
# Theta | LSG_2 -> R² = -4.4096, MSE = 1.8934e+00
# X | LSG_2 -> R² = -0.3333, MSE = 1.1854e-01
# Y | LSG_2 -> R² = -0.0195, MSE = 3.9171e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=4006 salvo.
