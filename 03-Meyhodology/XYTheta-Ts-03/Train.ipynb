# %% [markdown]
# - Entradas: "PwmD", "PwmE", "sPwm", "dPwm"
# - Saida: Theta
# - Loss = L_d + L_p

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score
from keras import initializers
import tensorflow as tf
import matplotlib.pyplot as plt
import joblib
import os
TITLES = ["Train_1", "Train_2", "Test_1", "Test_2", "Test_3", "Val", "LSG_1", "LSG_2"]

PREDICTORS = ["PwmD", "PwmE", "sPwm", "dPwm", "SinTheta", "CosTheta"]   
TARGET_INT = ["Theta", "X", "Y"]  
TARGET = ["DeltaTheta", "DeltaX", "DeltaY"]
     
INPUT_SIZE = len(PREDICTORS)  
OUTPUT_SIZE = len(TARGET)   
     
TIME_STEPS = 3
TS = 0.07

# %%
Datasets = []
for i in range(4):
    Dataset = pd.read_excel(f"../../00-RotedData/Data.xlsx", f"D{i+1}")   
    Datasets.append(Dataset)

for i in range(4):   
    Dataset = pd.read_csv(f"../../00-Data/Data{i + 1}.csv")  
    Datasets.append(Dataset)
    
    
for i in range(len(Datasets)):
    Dataset = Datasets[i].copy()

    for var in TARGET_INT:
        Dataset[f"Delta{var}"] = (Dataset[var].shift(-1) - Dataset[var]) / TS
    
    Dataset["sPwm"] = Dataset["PwmD"] + Dataset["PwmE"]
    Dataset["dPwm"] = Dataset["PwmD"] - Dataset["PwmE"]
    Dataset["SinTheta"] = np.sin(Dataset["Theta"])
    Dataset["CosTheta"] = np.cos(Dataset["Theta"])

    Dataset = Dataset.dropna(subset=[f"Delta{var}" for var in TARGET_INT])

    Datasets[i] = Dataset

# %%
NormDatasets = []

SCALER = StandardScaler()
OUT_SCALER = StandardScaler()

Train1 = Datasets[0].copy()
Train1[PREDICTORS] = SCALER.fit_transform(Train1[PREDICTORS])
Train1[TARGET] = OUT_SCALER.fit_transform(Train1[TARGET])
NormDatasets.append(Train1)

Train2 = Datasets[1].copy()
Train2[PREDICTORS] = SCALER.transform(Train2[PREDICTORS])
Train2[TARGET] = OUT_SCALER.transform(Train2[TARGET])
NormDatasets.append(Train2)

# concatena
Train = pd.concat([Train1, Train2], ignore_index=True)

for i in range(6):
    CurrentTestDataset = Datasets[i + 2].copy()
    CurrentTestDataset[PREDICTORS] = SCALER.transform(CurrentTestDataset[PREDICTORS])
    CurrentTestDataset[TARGET] = OUT_SCALER.transform(CurrentTestDataset[TARGET])
    NormDatasets.append(CurrentTestDataset)

# %%
os.makedirs("./scalers", exist_ok=True)
os.makedirs("./Data", exist_ok=True)

with pd.ExcelWriter("./Data/NormDatasets.xlsx", engine="openpyxl") as writer_norm:
    for title, normDataset in zip(TITLES, NormDatasets):
        normDataset.to_excel(writer_norm, sheet_name=title[:31], index=False)

with pd.ExcelWriter("./Data/Datasets.xlsx", engine="openpyxl") as writer:
    for title, Dataset in zip(TITLES, Datasets):
        Dataset.to_excel(writer, sheet_name=title[:31], index=False)
        
joblib.dump(SCALER, "./scalers/scaler.pkl")
joblib.dump(OUT_SCALER, "./scalers/out_scaler.pkl")

mean_tf = tf.constant(OUT_SCALER.mean_[0], dtype=tf.float32)
std_tf  = tf.constant(OUT_SCALER.scale_[0], dtype=tf.float32)

# %%
def CreateSequences(input_data, target_data, timesteps):
    X_seq, Y_seq = [], []
    
    for i in range(timesteps, len(input_data)):
        X_seq.append(input_data.iloc[i-timesteps:i].values)
        Y_seq.append(target_data.iloc[i])
    return np.array(X_seq), np.array(Y_seq)

x_train, y_train = CreateSequences(Train[PREDICTORS], Train[TARGET], TIME_STEPS)

x_val, y_val = CreateSequences((NormDatasets[5])[PREDICTORS], (NormDatasets[5])[TARGET], TIME_STEPS)
print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada: {np.shape(x_val)}")
print(f"Dimensão da saida: {np.shape(y_val)}")
# Out:
# Dimensão da entrada: (1949, 3, 6)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada: (1268, 3, 6)
# Dimensão da saida: (1268, 3)

# %%
Wd_train =  Train["Wd"].values[:len(x_train)]
We_train =  Train["We"].values[:len(x_train)]
q_real = Train[TARGET_INT].values[:len(x_train)]

print(f"Dimensão da entrada: {np.shape(x_train)}")
print(f"Dimensão da saida: {np.shape(y_train)}")

print(f"Dimensão da entrada fisica : {np.shape(Wd_train)}")
print(f"Dimensão da entrada fisica: {np.shape(We_train)}")
# Out:
# Dimensão da entrada: (1949, 3, 6)
# Dimensão da saida: (1949, 3)
# Dimensão da entrada fisica : (1949,)
# Dimensão da entrada fisica: (1949,)

# %% [markdown]
# $$ \dot{\theta} = \frac{R}{2L} (\phi_d - \phi_e) $$
# $$ \dot{x} = \frac{R}{2} (\phi_d + \phi_e) (\cos(\theta))$$
# $$ \dot{y} = \frac{R}{2} (\phi_d + \phi_e) (\sin(\theta)) $$

# %%
R = tf.constant(0.0328, dtype=tf.float32)
L = tf.constant(0.0615, dtype=tf.float32)
dt = tf.constant(TS, dtype=tf.float32)

def CinematicModel(Wd, We, theta_pred):
    dtheta_cin = (R / (2 * L)) * (Wd - We)
    dx_cin = (R / 2) * tf.cos(theta_pred) * (Wd + We)
    dy_cin = (R / 2) * tf.sin(theta_pred) * (Wd + We)
    return [dtheta_cin, dx_cin, dy_cin]

# %%
def NumericalIntegration(dataset, dq):

    q = [None] * OUTPUT_SIZE

    init_vals = np.array([
        dataset[name].iloc[0] for name in TARGET_INT
    ])

    for j in range(OUTPUT_SIZE):
        q[j] = init_vals[j] + np.cumsum(dq[j] * TS)

    return q

def GetCin(dataset): 
    dq = CinematicModel(tf.convert_to_tensor(dataset["Wd"].values, dtype=tf.float32),
                        tf.convert_to_tensor(dataset["We"].values, dtype=tf.float32), 
                        tf.convert_to_tensor(dataset["Theta"].values, dtype=tf.float32))
    q = NumericalIntegration(dataset, dq)
    return np.vstack(q).T

# %%
def BuildRNN(architecture, initializer, regularizer):

    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Input(shape=(TIME_STEPS, INPUT_SIZE)))

    for i, units in enumerate(architecture):

        return_sequences = (i < len(architecture) - 1)

        model.add(
            tf.keras.layers.SimpleRNN(
                units,
                activation='tanh',
                return_sequences=return_sequences,
                kernel_initializer=initializer,
                kernel_regularizer=regularizer,
                recurrent_regularizer=regularizer,
                bias_regularizer=regularizer
            )
        )

    model.add(
        tf.keras.layers.Dense(
            OUTPUT_SIZE,
            activation="linear",
            kernel_initializer=initializer,
            kernel_regularizer=regularizer,
            bias_regularizer=regularizer
        )
    )

    return model

# %%
@tf.function
def train_step(model, optimizer, x, dq, q_real, Wd, We, q0, Ld, Lp):

    with tf.GradientTape() as tape:

        # =========================
        # 1. Forward
        # =========================
        dq_pred = model(x, training=True)

        # =========================
        # 2. Desnormaliza
        # =========================
        dq_pred_denorm = (dq_pred * std_tf) + mean_tf

        dtheta_pred = dq_pred_denorm[:, 0]
        dx_pred     = dq_pred_denorm[:, 1]
        dy_pred     = dq_pred_denorm[:, 2]

        # =========================
        # 3. Integração (estado)
        # =========================
        theta_pred = q0[0] + tf.cumsum(dtheta_pred * dt, axis=0)
        x_pred     = q0[1] + tf.cumsum(dx_pred * dt, axis=0)
        y_pred     = q0[2] + tf.cumsum(dy_pred * dt, axis=0)

        # =========================
        # 4. Estados reais
        # =========================
        theta_real = q_real[:, 0]
        x_real     = q_real[:, 1]
        y_real     = q_real[:, 2]

        # =========================
        # 5. LOSS DE DADOS (θ, x, y)
        # =========================
        loss_theta = tf.reduce_mean((theta_pred - theta_real)**2)
        loss_x     = tf.reduce_mean((x_pred - x_real)**2)
        loss_y     = tf.reduce_mean((y_pred - y_real)**2)
        loss_dq = tf.reduce_mean((dq - dq_pred)**2)

        data_loss = loss_theta + loss_x + loss_y + loss_dq

        # =========================
        # 6. FÍSICA
        # =========================
        physics = tf.stack(CinematicModel(Wd, We, theta_pred), axis=1)

        physics_norm = (physics - mean_tf) / std_tf

        physics_loss = tf.reduce_mean((dq_pred - physics_norm)**2)

        # =========================
        # 7. LOSS TOTAL
        # =========================
        loss = Ld * data_loss + Lp * physics_loss

    gradients = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(gradients, model.trainable_variables))

    return loss

# %%
Wd_train_tf = tf.convert_to_tensor(Wd_train, dtype=tf.float32)
We_train_tf = tf.convert_to_tensor(We_train, dtype=tf.float32)
q0_tf = tf.convert_to_tensor(q_real[0], dtype=tf.float32)
q_real_tf = tf.convert_to_tensor(q_real, dtype=tf.float32)

x_train_tf = tf.convert_to_tensor(x_train, dtype=tf.float32)
y_train_tf = tf.convert_to_tensor(y_train, dtype=tf.float32)

x_val_tf = tf.convert_to_tensor(x_val, dtype=tf.float32)
y_val_tf = tf.convert_to_tensor(y_val, dtype=tf.float32)

# %%
def EarlyStopping(model, best_loss, counter, best_weights, min_delta=1e-3):
    val_pred = model(x_val_tf, training=False)
    val_loss = tf.reduce_mean(tf.square(val_pred - y_val_tf))
    
    if val_loss < (best_loss - min_delta):
        best_loss = val_loss
        counter = 0
        best_weights = model.get_weights()

    else:
        counter += 1

    return best_loss, counter, best_weights, val_loss

def TrainPINN(model, optimizer, Ld, Lp, patience=200, best_loss=np.inf):
    counter = 0
    best_weights = model.get_weights()

    for epoch in range(20000):

        loss = train_step(model, optimizer, x_train_tf, y_train_tf, q_real_tf,
                          Wd_train_tf, We_train_tf, q0_tf, Ld, Lp)
        
        best_loss, counter, best_weights, val_loss =  EarlyStopping(model, best_loss, counter, best_weights)
        
        if counter >= patience:
            print(f"Early stopping at epoch {epoch}")
            model.set_weights(best_weights)
            break

        if epoch % 100 == 0:
            print(f"Epoch {epoch} | Train Loss {loss.numpy():.6f} | Val Loss {val_loss.numpy():.6f}")

# %%
def PlotOut(ax, title, target_name, y_true, y_pred, y_cin):
    time = (np.arange(0, len(y_pred), 1).astype(float) * 0.07).round(5)

    ax.plot(time, y_true, linestyle='-', linewidth=1.5, color='tab:blue', label='Amostras Reais')
    ax.plot(time, y_pred, linestyle='--', linewidth=1.5, color='tab:orange', label='Valores preditos')
    ax.plot(time, y_cin, linestyle=':', linewidth=2, color='tab:green', label='Modelo Cinemático')

    ax.set_title(f'{title} - {target_name}')
    ax.set_xlabel('Tempo [s]')
    ax.set_ylabel(target_name)
    ax.legend()
    ax.grid(True)


def EvalModel(model):
    # n_datasets = len(Datasets)
    n_targets = len(TARGET)
    # fig, axs = plt.subplots(n_datasets, n_targets, figsize=(6 * n_targets, 4 * n_datasets))
    

    # estrutura das métricas
    metrics = {
        name: {
            "R2_Train_1": [], "R2_Train_2": [],
            "R2_Val": [],
            "R2_Test_1": [], "R2_Test_2": [], "R2_Test_3": [],
            "R2_LSG_1": [], "R2_LSG_2": [],
            "MSE_Train_1": [], "MSE_Train_2": [],
            "MSE_Val": [],
            "MSE_Test_1": [], "MSE_Test_2": [], "MSE_Test_3": [],
            "MSE_LSG_1": [], "MSE_LSG_2": [],

        }
        for name in TARGET_INT
    }

    for i, NormDataset in enumerate(NormDatasets):

        x = NormDataset[PREDICTORS] # Normalizado
        y = Datasets[i][TARGET_INT] # Real

        x, y = CreateSequences(x, y, TIME_STEPS)

        # predição da rede
        pred = model(tf.convert_to_tensor(x, dtype=tf.float32)).numpy()

        # desnormalização
        y_pred_diff = OUT_SCALER.inverse_transform(pred)

        # arrays reconstruídos
        y_true = y
        y_pred = np.zeros_like(y_pred_diff)
        y_cin = GetCin(Datasets[i])
        
        y_cin = y_cin[:y_true.shape[0]]

        # valores iniciais reais
        init_vals = np.array([
            Datasets[i][name].iloc[0] for name in TARGET_INT
        ])

        # reconstrução por integração cumulativa
        for j in range(n_targets):
            y_pred[:, j] = init_vals[j] + np.cumsum(y_pred_diff[:, j] * TS)

        # cálculo das métricas
        for j, name in enumerate(TARGET_INT):

            r2 = r2_score(y_true[:, j], y_pred[:, j])
            mse = mean_squared_error(y_true[:, j], y_pred[:, j])

            metrics[name][f"R2_{TITLES[i]}"].append(r2)
            metrics[name][f"MSE_{TITLES[i]}"].append(mse)

            print(f"{name} | {TITLES[i]} -> " f"R² = {r2:.4f}, MSE = {mse:.4e}")

            # # Seleciona o eixo correto (funciona mesmo com 1x1, 1x2 ou 3x2)
            # ax = axs[i][j] if n_datasets > 1 and n_targets > 1 else (
            #     axs[j] if n_targets > 1 else axs[i] if n_datasets > 1 else axs
            # )
            # PlotOut(ax, TITLES[i], name, y_true[:, j], y_pred[:, j], y_cin)

    # plt.tight_layout()

    return metrics

# %%
def to_scalar(x):
    return float(x[0]) if isinstance(x, list) else float(x)

# %%
def UpdateRow(metrics, arch, Ld, Lp, r, seed, excel_file):

    model_name = f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{seed}"

    row = {
        "model": model_name,
        "Neurons": arch,
        "Ld": Ld,
        "Lp": Lp,
        "reg": r,
        "seed": seed,
    }

    for name in TARGET_INT:
        row.update({
            f"R2_Train_1_{name}": to_scalar(metrics[name]["R2_Train_1"]),
            f"MSE_Train_1_{name}": to_scalar(metrics[name]["MSE_Train_1"]),
            f"R2_Train_2_{name}": to_scalar(metrics[name]["R2_Train_2"]),
            f"MSE_Train_2_{name}": to_scalar(metrics[name]["MSE_Train_2"]),
            f"R2_Val_{name}": to_scalar(metrics[name]["R2_Val"]),
            f"MSE_Val_{name}": to_scalar(metrics[name]["MSE_Val"]),
            f"R2_Test_1_{name}": to_scalar(metrics[name]["R2_Test_1"]),
            f"MSE_Test_1_{name}": to_scalar(metrics[name]["MSE_Test_1"]),
            f"R2_Test_2_{name}": to_scalar(metrics[name]["R2_Test_2"]),
            f"MSE_Test_2_{name}": to_scalar(metrics[name]["MSE_Test_2"]),
            f"R2_Test_3_{name}": to_scalar(metrics[name]["R2_Test_3"]),
            f"MSE_Test_3_{name}": to_scalar(metrics[name]["MSE_Test_3"]),
        })

    df = pd.DataFrame([row])

    try:
        old = pd.read_excel(excel_file)
        new_df = pd.concat([old, df], ignore_index=True)
        new_df.to_excel(excel_file, index=False)
    except FileNotFoundError:
        df.to_excel(excel_file, index=False)

    print(f"Modelo {arch} | Ld={Ld} Lp={Lp} r={r} seed={seed} salvo.")

# %%
def ExportModel(model, model_name):

    os.makedirs("weights", exist_ok=True)
    os.makedirs("models", exist_ok=True)

    weights_path = f"weights/{model_name}.weights.h5"
    model_path = f"models/{model_name}.keras"

    model.save_weights(weights_path)
    model.save(model_path)

    print(f"Modelo salvo em:\n{model_path}\n{weights_path}")

# %%
from tensorflow.keras.optimizers import Adam
from itertools import product

N_MODELS = 5
seeds = np.random.choice(range(1, 10000), size=N_MODELS, replace=False)

architectures = [[16],
    [32], [64], [128], [264],
    [8, 4], [16, 8], [32, 16], [64, 32], [128, 64], [264, 128],
    [16, 8, 4], [32, 16, 8], [128, 64, 32], [264, 128, 64]
]

Ld_Lp = [[0.3,0.7], [0.7,0.3]]
r_values = [0.01, 0.9]

results = {}
# produto cartesiano de todos hiperparâmetros
for arch, (Ld, Lp), r in product(architectures, Ld_Lp, r_values):

    for i, s in enumerate(seeds):

        tf.keras.backend.clear_session()

        init = initializers.RandomNormal(seed=int(s))
        reg = tf.keras.regularizers.l2(r)
        model = BuildRNN(arch, init, reg)
        model.build((None, TIME_STEPS, INPUT_SIZE))

        opt = Adam(learning_rate=0.001)
        opt.build(model.trainable_variables)

        TrainPINN(
            model,
            Ld=Ld,
            Lp=Lp,
            optimizer=opt
        )
        ExportModel(model, model_name=f"model_arch{'-'.join(map(str, arch))}_r{r}_seed{s}")
        metrics = EvalModel(model)
        UpdateRow(metrics, arch, Ld, Lp, r, s, excel_file="resultados.xlsx")
# Out:
# Epoch 0 | Train Loss 1.224773 | Val Loss 0.797714
# Epoch 100 | Train Loss 0.610326 | Val Loss 0.671416
# Epoch 200 | Train Loss 0.528488 | Val Loss 0.632637
# Epoch 300 | Train Loss 0.488172 | Val Loss 0.618197
# Epoch 400 | Train Loss 0.478445 | Val Loss 0.615995
# Epoch 500 | Train Loss 0.470396 | Val Loss 0.613094
# Epoch 600 | Train Loss 0.462396 | Val Loss 0.611402
# Epoch 700 | Train Loss 0.454774 | Val Loss 0.611078
# Early stopping at epoch 785
# Modelo salvo em:
# models/model_arch16_r0.01_seed1557.keras
# weights/model_arch16_r0.01_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9431, MSE = 1.2951e-02
# X | Train_1 -> R² = 0.2609, MSE = 7.9700e-02
# Y | Train_1 -> R² = -1.3476, MSE = 1.9674e-01
# Theta | Train_2 -> R² = 0.8907, MSE = 2.4956e-02
# X | Train_2 -> R² = 0.6809, MSE = 2.6888e-02
# Y | Train_2 -> R² = -1.2805, MSE = 2.4555e-01
# Theta | Test_1 -> R² = 0.4128, MSE = 1.3452e-01
# X | Test_1 -> R² = 0.1026, MSE = 9.4031e-02
# Y | Test_1 -> R² = -1.4124, MSE = 1.9773e-01
# Theta | Test_2 -> R² = 0.8285, MSE = 4.0669e-02
# X | Test_2 -> R² = 0.7196, MSE = 2.3076e-02
# Y | Test_2 -> R² = -1.3715, MSE = 2.5172e-01
# Theta | Test_3 -> R² = 0.4346, MSE = 1.8545e-01
# X | Test_3 -> R² = -0.1874, MSE = 1.0927e-01
# Y | Test_3 -> R² = -2.2367, MSE = 2.4866e-01
# Theta | Val -> R² = -5.0385, MSE = 1.9712e+00
# X | Val -> R² = -0.1398, MSE = 1.0901e-01
# Y | Val -> R² = -1.8424, MSE = 2.1166e-01
# Theta | LSG_1 -> R² = -0.5980, MSE = 6.6711e-01
# X | LSG_1 -> R² = -0.0405, MSE = 1.0665e-01
# Y | LSG_1 -> R² = -0.2482, MSE = 3.9409e-01
# Theta | LSG_2 -> R² = -5.2544, MSE = 2.1891e+00
# X | LSG_2 -> R² = -0.2565, MSE = 1.1171e-01
# Y | LSG_2 -> R² = 0.0098, MSE = 3.8046e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1557 salvo.
# Epoch 0 | Train Loss 1.143507 | Val Loss 0.796833
# Epoch 100 | Train Loss 0.586249 | Val Loss 0.648069
# Epoch 200 | Train Loss 0.530299 | Val Loss 0.635768
# Epoch 300 | Train Loss 0.484739 | Val Loss 0.613764
# Epoch 400 | Train Loss 0.462407 | Val Loss 0.603158
# Epoch 500 | Train Loss 0.454096 | Val Loss 0.601665
# Epoch 600 | Train Loss 0.448182 | Val Loss 0.601182
# Epoch 700 | Train Loss 0.443013 | Val Loss 0.601074
# Epoch 800 | Train Loss 0.439545 | Val Loss 0.600813
# Early stopping at epoch 847
# Modelo salvo em:
# models/model_arch16_r0.01_seed9359.keras
# weights/model_arch16_r0.01_seed9359.weights.h5
# Theta | Train_1 -> R² = 0.9534, MSE = 1.0607e-02
# X | Train_1 -> R² = 0.2582, MSE = 7.9991e-02
# Y | Train_1 -> R² = -1.3667, MSE = 1.9834e-01
# Theta | Train_2 -> R² = 0.9108, MSE = 2.0359e-02
# X | Train_2 -> R² = 0.6783, MSE = 2.7106e-02
# Y | Train_2 -> R² = -1.3289, MSE = 2.5077e-01
# Theta | Test_1 -> R² = 0.4672, MSE = 1.2205e-01
# X | Test_1 -> R² = 0.1500, MSE = 8.9064e-02
# Y | Test_1 -> R² = -1.3992, MSE = 1.9665e-01
# Theta | Test_2 -> R² = 0.7366, MSE = 6.2465e-02
# X | Test_2 -> R² = 0.6797, MSE = 2.6362e-02
# Y | Test_2 -> R² = -1.3188, MSE = 2.4612e-01
# Theta | Test_3 -> R² = 0.7866, MSE = 7.0012e-02
# X | Test_3 -> R² = -0.8704, MSE = 1.7213e-01
# Y | Test_3 -> R² = -0.8871, MSE = 1.4497e-01
# Theta | Val -> R² = 0.0628, MSE = 3.0594e-01
# X | Val -> R² = -0.6268, MSE = 1.5558e-01
# Y | Val -> R² = 0.0095, MSE = 7.3764e-02
# Theta | LSG_1 -> R² = 0.6044, MSE = 1.6516e-01
# X | LSG_1 -> R² = 0.1242, MSE = 8.9763e-02
# Y | LSG_1 -> R² = -0.9378, MSE = 6.1183e-01
# Theta | LSG_2 -> R² = -2.1269, MSE = 1.0944e+00
# X | LSG_2 -> R² = -0.3216, MSE = 1.1750e-01
# Y | LSG_2 -> R² = -0.3203, MSE = 5.0727e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=9359 salvo.
# Epoch 0 | Train Loss 1.739309 | Val Loss 0.815570
# Epoch 100 | Train Loss 0.658755 | Val Loss 0.710657
# Epoch 200 | Train Loss 0.553268 | Val Loss 0.634214
# Epoch 300 | Train Loss 0.498176 | Val Loss 0.607669
# Epoch 400 | Train Loss 0.485631 | Val Loss 0.605197
# Epoch 500 | Train Loss 0.477248 | Val Loss 0.602013
# Epoch 600 | Train Loss 0.469323 | Val Loss 0.599498
# Epoch 700 | Train Loss 0.464146 | Val Loss 0.599563
# Early stopping at epoch 771
# Modelo salvo em:
# models/model_arch16_r0.01_seed1170.keras
# weights/model_arch16_r0.01_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9360, MSE = 1.4556e-02
# X | Train_1 -> R² = 0.2358, MSE = 8.2410e-02
# Y | Train_1 -> R² = -1.3615, MSE = 1.9791e-01
# Theta | Train_2 -> R² = 0.8512, MSE = 3.3958e-02
# X | Train_2 -> R² = 0.6421, MSE = 3.0156e-02
# Y | Train_2 -> R² = -1.3226, MSE = 2.5009e-01
# Theta | Test_1 -> R² = 0.4182, MSE = 1.3327e-01
# X | Test_1 -> R² = 0.1775, MSE = 8.6185e-02
# Y | Test_1 -> R² = -1.4849, MSE = 2.0367e-01
# Theta | Test_2 -> R² = 0.8686, MSE = 3.1161e-02
# X | Test_2 -> R² = 0.6424, MSE = 2.9425e-02
# Y | Test_2 -> R² = -1.3393, MSE = 2.4830e-01
# Theta | Test_3 -> R² = 0.1969, MSE = 2.6344e-01
# X | Test_3 -> R² = -1.2989, MSE = 2.1156e-01
# Y | Test_3 -> R² = -0.2598, MSE = 9.6781e-02
# Theta | Val -> R² = -2.6821, MSE = 1.2019e+00
# X | Val -> R² = -0.6424, MSE = 1.5708e-01
# Y | Val -> R² = -0.3670, MSE = 1.0179e-01
# Theta | LSG_1 -> R² = -0.1185, MSE = 4.6691e-01
# X | LSG_1 -> R² = 0.4384, MSE = 5.7559e-02
# Y | LSG_1 -> R² = -0.2453, MSE = 3.9320e-01
# Theta | LSG_2 -> R² = -1.8468, MSE = 9.9638e-01
# X | LSG_2 -> R² = 0.3399, MSE = 5.8683e-02
# Y | LSG_2 -> R² = -0.0077, MSE = 3.8715e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=1170 salvo.
# Epoch 0 | Train Loss 2.321469 | Val Loss 0.816618
# Epoch 100 | Train Loss 0.660956 | Val Loss 0.706104
# Epoch 200 | Train Loss 0.559159 | Val Loss 0.649078
# Epoch 300 | Train Loss 0.523073 | Val Loss 0.635043
# Epoch 400 | Train Loss 0.499194 | Val Loss 0.624413
# Epoch 500 | Train Loss 0.486510 | Val Loss 0.617653
# Epoch 600 | Train Loss 0.480037 | Val Loss 0.614773
# Epoch 700 | Train Loss 0.474619 | Val Loss 0.612964
# Epoch 800 | Train Loss 0.469529 | Val Loss 0.611886
# Epoch 900 | Train Loss 0.464525 | Val Loss 0.611738
# Early stopping at epoch 937
# Modelo salvo em:
# models/model_arch16_r0.01_seed2559.keras
# weights/model_arch16_r0.01_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9294, MSE = 1.6061e-02
# X | Train_1 -> R² = 0.2571, MSE = 8.0112e-02
# Y | Train_1 -> R² = -1.3799, MSE = 1.9945e-01
# Theta | Train_2 -> R² = 0.8792, MSE = 2.7570e-02
# X | Train_2 -> R² = 0.6790, MSE = 2.7047e-02
# Y | Train_2 -> R² = -1.4477, MSE = 2.6356e-01
# Theta | Test_1 -> R² = 0.4022, MSE = 1.3695e-01
# X | Test_1 -> R² = 0.1194, MSE = 9.2273e-02
# Y | Test_1 -> R² = -1.5606, MSE = 2.0988e-01
# Theta | Test_2 -> R² = 0.7855, MSE = 5.0861e-02
# X | Test_2 -> R² = 0.6943, MSE = 2.5159e-02
# Y | Test_2 -> R² = -1.4747, MSE = 2.6267e-01
# Theta | Test_3 -> R² = 0.3096, MSE = 2.2645e-01
# X | Test_3 -> R² = -0.1097, MSE = 1.0213e-01
# Y | Test_3 -> R² = -1.7541, MSE = 2.1158e-01
# Theta | Val -> R² = -7.2335, MSE = 2.6877e+00
# X | Val -> R² = -0.0591, MSE = 1.0129e-01
# Y | Val -> R² = -2.0440, MSE = 2.2668e-01
# Theta | LSG_1 -> R² = -5.0079, MSE = 2.5080e+00
# X | LSG_1 -> R² = 0.0235, MSE = 1.0009e-01
# Y | LSG_1 -> R² = -0.3733, MSE = 4.3360e-01
# Theta | LSG_2 -> R² = -14.7112, MSE = 5.4990e+00
# X | LSG_2 -> R² = -0.3808, MSE = 1.2276e-01
# Y | LSG_2 -> R² = -0.0839, MSE = 4.1645e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=2559 salvo.
# Epoch 0 | Train Loss 2.544082 | Val Loss 0.817454
# Epoch 100 | Train Loss 0.666640 | Val Loss 0.698856
# Epoch 200 | Train Loss 0.563031 | Val Loss 0.642884
# Epoch 300 | Train Loss 0.540142 | Val Loss 0.637865
# Epoch 400 | Train Loss 0.524655 | Val Loss 0.631404
# Epoch 500 | Train Loss 0.506367 | Val Loss 0.622741
# Epoch 600 | Train Loss 0.487972 | Val Loss 0.612057
# Epoch 700 | Train Loss 0.474854 | Val Loss 0.603467
# Epoch 800 | Train Loss 0.466112 | Val Loss 0.600310
# Epoch 900 | Train Loss 0.458726 | Val Loss 0.601578
# Early stopping at epoch 960
# Modelo salvo em:
# models/model_arch16_r0.01_seed611.keras
# weights/model_arch16_r0.01_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9372, MSE = 1.4285e-02
# X | Train_1 -> R² = 0.2466, MSE = 8.1240e-02
# Y | Train_1 -> R² = -1.3872, MSE = 2.0006e-01
# Theta | Train_2 -> R² = 0.8708, MSE = 2.9494e-02
# X | Train_2 -> R² = 0.6560, MSE = 2.8990e-02
# Y | Train_2 -> R² = -1.4308, MSE = 2.6174e-01
# Theta | Test_1 -> R² = 0.4337, MSE = 1.2972e-01
# X | Test_1 -> R² = 0.1217, MSE = 9.2032e-02
# Y | Test_1 -> R² = -1.4982, MSE = 2.0476e-01
# Theta | Test_2 -> R² = 0.8805, MSE = 2.8344e-02
# X | Test_2 -> R² = 0.6695, MSE = 2.7198e-02
# Y | Test_2 -> R² = -1.4282, MSE = 2.5773e-01
# Theta | Test_3 -> R² = 0.8068, MSE = 6.3384e-02
# X | Test_3 -> R² = -0.7654, MSE = 1.6246e-01
# Y | Test_3 -> R² = -0.9908, MSE = 1.5295e-01
# Theta | Val -> R² = -4.6567, MSE = 1.8465e+00
# X | Val -> R² = -0.4460, MSE = 1.3829e-01
# Y | Val -> R² = -0.5956, MSE = 1.1882e-01
# Theta | LSG_1 -> R² = -2.6523, MSE = 1.5247e+00
# X | LSG_1 -> R² = 0.3322, MSE = 6.8449e-02
# Y | LSG_1 -> R² = -0.5788, MSE = 4.9849e-01
# Theta | LSG_2 -> R² = -10.4687, MSE = 4.0141e+00
# X | LSG_2 -> R² = 0.1378, MSE = 7.6654e-02
# Y | LSG_2 -> R² = -0.1632, MSE = 4.4692e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.01 seed=611 salvo.
# Epoch 0 | Train Loss 1.361075 | Val Loss 0.809950
# Epoch 100 | Train Loss 0.637874 | Val Loss 0.679289
# Epoch 200 | Train Loss 0.525793 | Val Loss 0.621595
# Epoch 300 | Train Loss 0.488583 | Val Loss 0.608668
# Epoch 400 | Train Loss 0.482105 | Val Loss 0.608793
# Epoch 500 | Train Loss 0.476613 | Val Loss 0.607853
# Epoch 600 | Train Loss 0.470373 | Val Loss 0.606475
# Epoch 700 | Train Loss 0.464200 | Val Loss 0.605565
# Epoch 800 | Train Loss 0.458325 | Val Loss 0.606159
# Early stopping at epoch 892
# Modelo salvo em:
# models/model_arch16_r0.9_seed1557.keras
# weights/model_arch16_r0.9_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9357, MSE = 1.4623e-02
# X | Train_1 -> R² = 0.2642, MSE = 7.9350e-02
# Y | Train_1 -> R² = -1.3604, MSE = 1.9781e-01
# Theta | Train_2 -> R² = 0.8447, MSE = 3.5454e-02
# X | Train_2 -> R² = 0.6614, MSE = 2.8535e-02
# Y | Train_2 -> R² = -1.2507, MSE = 2.4235e-01
# Theta | Test_1 -> R² = 0.2567, MSE = 1.7028e-01
# X | Test_1 -> R² = 0.1252, MSE = 9.1664e-02
# Y | Test_1 -> R² = -1.4305, MSE = 1.9922e-01
# Theta | Test_2 -> R² = 0.8944, MSE = 2.5031e-02
# X | Test_2 -> R² = 0.6835, MSE = 2.6042e-02
# Y | Test_2 -> R² = -1.2924, MSE = 2.4332e-01
# Theta | Test_3 -> R² = 0.5450, MSE = 1.4924e-01
# X | Test_3 -> R² = -0.2257, MSE = 1.1279e-01
# Y | Test_3 -> R² = -1.0353, MSE = 1.5636e-01
# Theta | Val -> R² = -2.6404, MSE = 1.1883e+00
# X | Val -> R² = 0.0017, MSE = 9.5472e-02
# Y | Val -> R² = -0.9999, MSE = 1.4892e-01
# Theta | LSG_1 -> R² = 0.4552, MSE = 2.2742e-01
# X | LSG_1 -> R² = 0.2554, MSE = 7.6321e-02
# Y | LSG_1 -> R² = -0.4737, MSE = 4.6532e-01
# Theta | LSG_2 -> R² = -0.8058, MSE = 6.3203e-01
# X | LSG_2 -> R² = -0.1554, MSE = 1.0272e-01
# Y | LSG_2 -> R² = -0.0819, MSE = 4.1567e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1557 salvo.
# Epoch 0 | Train Loss 1.099965 | Val Loss 0.779650
# Epoch 100 | Train Loss 0.561076 | Val Loss 0.644812
# Epoch 200 | Train Loss 0.535142 | Val Loss 0.637423
# Epoch 300 | Train Loss 0.497842 | Val Loss 0.622645
# Epoch 400 | Train Loss 0.467052 | Val Loss 0.611245
# Epoch 500 | Train Loss 0.455944 | Val Loss 0.609838
# Epoch 600 | Train Loss 0.448885 | Val Loss 0.610883
# Early stopping at epoch 617
# Modelo salvo em:
# models/model_arch16_r0.9_seed9359.keras
# weights/model_arch16_r0.9_seed9359.weights.h5
# Theta | Train_1 -> R² = 0.9294, MSE = 1.6065e-02
# X | Train_1 -> R² = 0.2334, MSE = 8.2663e-02
# Y | Train_1 -> R² = -1.3568, MSE = 1.9751e-01
# Theta | Train_2 -> R² = 0.8772, MSE = 2.8024e-02
# X | Train_2 -> R² = 0.6525, MSE = 2.9286e-02
# Y | Train_2 -> R² = -1.4196, MSE = 2.6054e-01
# Theta | Test_1 -> R² = 0.3333, MSE = 1.5274e-01
# X | Test_1 -> R² = 0.1746, MSE = 8.6486e-02
# Y | Test_1 -> R² = -1.5322, MSE = 2.0755e-01
# Theta | Test_2 -> R² = 0.8745, MSE = 2.9751e-02
# X | Test_2 -> R² = 0.6806, MSE = 2.6287e-02
# Y | Test_2 -> R² = -1.4354, MSE = 2.5850e-01
# Theta | Test_3 -> R² = 0.7748, MSE = 7.3878e-02
# X | Test_3 -> R² = -0.3617, MSE = 1.2531e-01
# Y | Test_3 -> R² = -1.0707, MSE = 1.5908e-01
# Theta | Val -> R² = -4.9312, MSE = 1.9361e+00
# X | Val -> R² = 0.1052, MSE = 8.5582e-02
# Y | Val -> R² = -1.2257, MSE = 1.6574e-01
# Theta | LSG_1 -> R² = -3.4364, MSE = 1.8520e+00
# X | LSG_1 -> R² = 0.0938, MSE = 9.2879e-02
# Y | LSG_1 -> R² = -0.4367, MSE = 4.5362e-01
# Theta | LSG_2 -> R² = -13.9515, MSE = 5.2331e+00
# X | LSG_2 -> R² = 0.2332, MSE = 6.8173e-02
# Y | LSG_2 -> R² = -0.0598, MSE = 4.0719e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=9359 salvo.
# Epoch 0 | Train Loss 2.058593 | Val Loss 0.806046
# Epoch 100 | Train Loss 0.712202 | Val Loss 0.738402
# Epoch 200 | Train Loss 0.592669 | Val Loss 0.653601
# Epoch 300 | Train Loss 0.518332 | Val Loss 0.612321
# Epoch 400 | Train Loss 0.497636 | Val Loss 0.610345
# Epoch 500 | Train Loss 0.485625 | Val Loss 0.608589
# Epoch 600 | Train Loss 0.474795 | Val Loss 0.605656
# Epoch 700 | Train Loss 0.464988 | Val Loss 0.602932
# Epoch 800 | Train Loss 0.457396 | Val Loss 0.601454
# Epoch 900 | Train Loss 0.451303 | Val Loss 0.600788
# Epoch 1000 | Train Loss 0.451925 | Val Loss 0.600591
# Early stopping at epoch 1057
# Modelo salvo em:
# models/model_arch16_r0.9_seed1170.keras
# weights/model_arch16_r0.9_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9274, MSE = 1.6516e-02
# X | Train_1 -> R² = 0.2290, MSE = 8.3142e-02
# Y | Train_1 -> R² = -1.3657, MSE = 1.9825e-01
# Theta | Train_2 -> R² = 0.7996, MSE = 4.5752e-02
# X | Train_2 -> R² = 0.6450, MSE = 2.9914e-02
# Y | Train_2 -> R² = -1.2791, MSE = 2.4541e-01
# Theta | Test_1 -> R² = 0.4731, MSE = 1.2071e-01
# X | Test_1 -> R² = 0.1380, MSE = 9.0325e-02
# Y | Test_1 -> R² = -1.5398, MSE = 2.0817e-01
# Theta | Test_2 -> R² = 0.8444, MSE = 3.6905e-02
# X | Test_2 -> R² = 0.6568, MSE = 2.8241e-02
# Y | Test_2 -> R² = -1.3649, MSE = 2.5102e-01
# Theta | Test_3 -> R² = -0.0367, MSE = 3.4004e-01
# X | Test_3 -> R² = -0.6691, MSE = 1.5360e-01
# Y | Test_3 -> R² = -1.3420, MSE = 1.7992e-01
# Theta | Val -> R² = -0.5569, MSE = 5.0821e-01
# X | Val -> R² = -0.2329, MSE = 1.1791e-01
# Y | Val -> R² = -1.1982, MSE = 1.6370e-01
# Theta | LSG_1 -> R² = -0.6227, MSE = 6.7741e-01
# X | LSG_1 -> R² = 0.1793, MSE = 8.4121e-02
# Y | LSG_1 -> R² = -0.0493, MSE = 3.3131e-01
# Theta | LSG_2 -> R² = -8.2925, MSE = 3.2524e+00
# X | LSG_2 -> R² = 0.2813, MSE = 6.3898e-02
# Y | LSG_2 -> R² = 0.0646, MSE = 3.5937e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=1170 salvo.
# Epoch 0 | Train Loss 1.841393 | Val Loss 0.809470
# Epoch 100 | Train Loss 0.601932 | Val Loss 0.664409
# Epoch 200 | Train Loss 0.546487 | Val Loss 0.647999
# Epoch 300 | Train Loss 0.523333 | Val Loss 0.640502
# Epoch 400 | Train Loss 0.503137 | Val Loss 0.630801
# Epoch 500 | Train Loss 0.486387 | Val Loss 0.618626
# Epoch 600 | Train Loss 0.474309 | Val Loss 0.607968
# Epoch 700 | Train Loss 0.463579 | Val Loss 0.601104
# Epoch 800 | Train Loss 0.453302 | Val Loss 0.597485
# Epoch 900 | Train Loss 0.446220 | Val Loss 0.599757
# Early stopping at epoch 985
# Modelo salvo em:
# models/model_arch16_r0.9_seed2559.keras
# weights/model_arch16_r0.9_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9461, MSE = 1.2271e-02
# X | Train_1 -> R² = 0.2568, MSE = 8.0143e-02
# Y | Train_1 -> R² = -1.3706, MSE = 1.9867e-01
# Theta | Train_2 -> R² = 0.8982, MSE = 2.3250e-02
# X | Train_2 -> R² = 0.6499, MSE = 2.9505e-02
# Y | Train_2 -> R² = -1.3053, MSE = 2.4823e-01
# Theta | Test_1 -> R² = 0.5685, MSE = 9.8839e-02
# X | Test_1 -> R² = 0.1490, MSE = 8.9171e-02
# Y | Test_1 -> R² = -1.5297, MSE = 2.0735e-01
# Theta | Test_2 -> R² = 0.8871, MSE = 2.6762e-02
# X | Test_2 -> R² = 0.6622, MSE = 2.7795e-02
# Y | Test_2 -> R² = -1.4355, MSE = 2.5851e-01
# Theta | Test_3 -> R² = 0.8244, MSE = 5.7601e-02
# X | Test_3 -> R² = -0.3627, MSE = 1.2541e-01
# Y | Test_3 -> R² = -1.3929, MSE = 1.8383e-01
# Theta | Val -> R² = -2.1555, MSE = 1.0301e+00
# X | Val -> R² = -0.2715, MSE = 1.2160e-01
# Y | Val -> R² = -1.5538, MSE = 1.9017e-01
# Theta | LSG_1 -> R² = -1.0431, MSE = 8.5291e-01
# X | LSG_1 -> R² = -0.0114, MSE = 1.0366e-01
# Y | LSG_1 -> R² = -0.1517, MSE = 3.6363e-01
# Theta | LSG_2 -> R² = -9.5311, MSE = 3.6859e+00
# X | LSG_2 -> R² = 0.3399, MSE = 5.8683e-02
# Y | LSG_2 -> R² = 0.0082, MSE = 3.8104e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=2559 salvo.
# Epoch 0 | Train Loss 1.926884 | Val Loss 0.812716
# Epoch 100 | Train Loss 0.669981 | Val Loss 0.698774
# Epoch 200 | Train Loss 0.555109 | Val Loss 0.637185
# Epoch 300 | Train Loss 0.514526 | Val Loss 0.624684
# Epoch 400 | Train Loss 0.488580 | Val Loss 0.615164
# Epoch 500 | Train Loss 0.476946 | Val Loss 0.611469
# Epoch 600 | Train Loss 0.469503 | Val Loss 0.611576
# Early stopping at epoch 684
# Modelo salvo em:
# models/model_arch16_r0.9_seed611.keras
# weights/model_arch16_r0.9_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9419, MSE = 1.3225e-02
# X | Train_1 -> R² = 0.2623, MSE = 7.9547e-02
# Y | Train_1 -> R² = -1.3690, MSE = 1.9853e-01
# Theta | Train_2 -> R² = 0.8776, MSE = 2.7952e-02
# X | Train_2 -> R² = 0.5952, MSE = 3.4115e-02
# Y | Train_2 -> R² = -1.4554, MSE = 2.6439e-01
# Theta | Test_1 -> R² = 0.4183, MSE = 1.3324e-01
# X | Test_1 -> R² = 0.1524, MSE = 8.8818e-02
# Y | Test_1 -> R² = -1.5296, MSE = 2.0734e-01
# Theta | Test_2 -> R² = 0.9096, MSE = 2.1430e-02
# X | Test_2 -> R² = 0.6019, MSE = 3.2759e-02
# Y | Test_2 -> R² = -1.4354, MSE = 2.5850e-01
# Theta | Test_3 -> R² = 0.6743, MSE = 1.0684e-01
# X | Test_3 -> R² = -0.5206, MSE = 1.3994e-01
# Y | Test_3 -> R² = -1.8106, MSE = 2.1592e-01
# Theta | Val -> R² = -5.1654, MSE = 2.0126e+00
# X | Val -> R² = 0.0001, MSE = 9.5629e-02
# Y | Val -> R² = -1.7036, MSE = 2.0133e-01
# Theta | LSG_1 -> R² = 0.5429, MSE = 1.9083e-01
# X | LSG_1 -> R² = 0.4038, MSE = 6.1105e-02
# Y | LSG_1 -> R² = -0.2115, MSE = 3.8251e-01
# Theta | LSG_2 -> R² = -1.6033, MSE = 9.1116e-01
# X | LSG_2 -> R² = 0.2192, MSE = 6.9419e-02
# Y | LSG_2 -> R² = -0.0515, MSE = 4.0400e-01
# Modelo [16] | Ld=0.3 Lp=0.7 r=0.9 seed=611 salvo.
# Epoch 0 | Train Loss 2.643576 | Val Loss 0.802523
# Epoch 100 | Train Loss 1.080047 | Val Loss 0.688194
# Epoch 200 | Train Loss 0.827775 | Val Loss 0.628224
# Epoch 300 | Train Loss 0.731039 | Val Loss 0.619244
# Epoch 400 | Train Loss 0.720353 | Val Loss 0.619962
# Early stopping at epoch 449
# Modelo salvo em:
# models/model_arch16_r0.01_seed1557.keras
# weights/model_arch16_r0.01_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9313, MSE = 1.5646e-02
# X | Train_1 -> R² = 0.1411, MSE = 9.2618e-02
# Y | Train_1 -> R² = -1.3470, MSE = 1.9668e-01
# Theta | Train_2 -> R² = 0.6408, MSE = 8.2004e-02
# X | Train_2 -> R² = 0.6821, MSE = 2.6787e-02
# Y | Train_2 -> R² = -1.4553, MSE = 2.6438e-01
# Theta | Test_1 -> R² = 0.5191, MSE = 1.1017e-01
# X | Test_1 -> R² = 0.0609, MSE = 9.8404e-02
# Y | Test_1 -> R² = -1.6020, MSE = 2.1327e-01
# Theta | Test_2 -> R² = 0.8732, MSE = 3.0072e-02
# X | Test_2 -> R² = 0.6780, MSE = 2.6496e-02
# Y | Test_2 -> R² = -1.4660, MSE = 2.6175e-01
# Theta | Test_3 -> R² = 0.7189, MSE = 9.2202e-02
# X | Test_3 -> R² = -0.3197, MSE = 1.2145e-01
# Y | Test_3 -> R² = -1.2841, MSE = 1.7548e-01
# Theta | Val -> R² = -7.3343, MSE = 2.7206e+00
# X | Val -> R² = 0.0023, MSE = 9.5416e-02
# Y | Val -> R² = -1.0394, MSE = 1.5187e-01
# Theta | LSG_1 -> R² = -0.2589, MSE = 5.2554e-01
# X | LSG_1 -> R² = -0.1523, MSE = 1.1811e-01
# Y | LSG_1 -> R² = -0.5431, MSE = 4.8722e-01
# Theta | LSG_2 -> R² = -4.7085, MSE = 1.9980e+00
# X | LSG_2 -> R² = 0.0670, MSE = 8.2949e-02
# Y | LSG_2 -> R² = -0.1851, MSE = 4.5532e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1557 salvo.
# Epoch 0 | Train Loss 1.982508 | Val Loss 0.789865
# Epoch 100 | Train Loss 0.923329 | Val Loss 0.655194
# Epoch 200 | Train Loss 0.839931 | Val Loss 0.654508
# Epoch 300 | Train Loss 0.772780 | Val Loss 0.635234
# Epoch 400 | Train Loss 0.724788 | Val Loss 0.619591
# Epoch 500 | Train Loss 0.715704 | Val Loss 0.613599
# Epoch 600 | Train Loss 0.711519 | Val Loss 0.612397
# Epoch 700 | Train Loss 0.709045 | Val Loss 0.612154
# Epoch 800 | Train Loss 0.708206 | Val Loss 0.611823
# Epoch 900 | Train Loss 0.706123 | Val Loss 0.611265
# Early stopping at epoch 916
# Modelo salvo em:
# models/model_arch16_r0.01_seed9359.keras
# weights/model_arch16_r0.01_seed9359.weights.h5
# Theta | Train_1 -> R² = 0.9365, MSE = 1.4462e-02
# X | Train_1 -> R² = 0.2854, MSE = 7.7056e-02
# Y | Train_1 -> R² = -1.3615, MSE = 1.9790e-01
# Theta | Train_2 -> R² = 0.9182, MSE = 1.8677e-02
# X | Train_2 -> R² = 0.6961, MSE = 2.5611e-02
# Y | Train_2 -> R² = -1.2073, MSE = 2.3768e-01
# Theta | Test_1 -> R² = 0.0784, MSE = 2.1113e-01
# X | Test_1 -> R² = 0.1693, MSE = 8.7037e-02
# Y | Test_1 -> R² = -1.4501, MSE = 2.0082e-01
# Theta | Test_2 -> R² = 0.6289, MSE = 8.8005e-02
# X | Test_2 -> R² = 0.7098, MSE = 2.3879e-02
# Y | Test_2 -> R² = -1.1857, MSE = 2.3200e-01
# Theta | Test_3 -> R² = 0.4486, MSE = 1.8087e-01
# X | Test_3 -> R² = -0.0760, MSE = 9.9022e-02
# Y | Test_3 -> R² = -2.3826, MSE = 2.5986e-01
# Theta | Val -> R² = -7.8796, MSE = 2.8986e+00
# X | Val -> R² = 0.1384, MSE = 8.2408e-02
# Y | Val -> R² = -2.1189, MSE = 2.3226e-01
# Theta | LSG_1 -> R² = -0.2173, MSE = 5.0815e-01
# X | LSG_1 -> R² = 0.1770, MSE = 8.4353e-02
# Y | LSG_1 -> R² = -0.4183, MSE = 4.4780e-01
# Theta | LSG_2 -> R² = -5.2130, MSE = 2.1746e+00
# X | LSG_2 -> R² = 0.2374, MSE = 6.7799e-02
# Y | LSG_2 -> R² = -0.1420, MSE = 4.3877e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=9359 salvo.
# Epoch 0 | Train Loss 3.030576 | Val Loss 0.812607
# Epoch 100 | Train Loss 1.110548 | Val Loss 0.706754
# Epoch 200 | Train Loss 0.917203 | Val Loss 0.646100
# Epoch 300 | Train Loss 0.797511 | Val Loss 0.625962
# Epoch 400 | Train Loss 0.740162 | Val Loss 0.620980
# Epoch 500 | Train Loss 0.725229 | Val Loss 0.619251
# Epoch 600 | Train Loss 0.719392 | Val Loss 0.616787
# Epoch 700 | Train Loss 0.715909 | Val Loss 0.614386
# Epoch 800 | Train Loss 0.713488 | Val Loss 0.612381
# Epoch 900 | Train Loss 0.711681 | Val Loss 0.610759
# Epoch 1000 | Train Loss 0.710279 | Val Loss 0.609433
# Epoch 1100 | Train Loss 0.709193 | Val Loss 0.608352
# Epoch 1200 | Train Loss 0.708288 | Val Loss 0.607482
# Epoch 1300 | Train Loss 0.707534 | Val Loss 0.606803
# Epoch 1400 | Train Loss 0.708193 | Val Loss 0.606285
# Epoch 1500 | Train Loss 0.706238 | Val Loss 0.605866
# Early stopping at epoch 1527
# Modelo salvo em:
# models/model_arch16_r0.01_seed1170.keras
# weights/model_arch16_r0.01_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9416, MSE = 1.3284e-02
# X | Train_1 -> R² = 0.2851, MSE = 7.7092e-02
# Y | Train_1 -> R² = -1.3580, MSE = 1.9761e-01
# Theta | Train_2 -> R² = 0.9400, MSE = 1.3705e-02
# X | Train_2 -> R² = 0.6942, MSE = 2.5769e-02
# Y | Train_2 -> R² = -1.1975, MSE = 2.3663e-01
# Theta | Test_1 -> R² = 0.1810, MSE = 1.8761e-01
# X | Test_1 -> R² = 0.1524, MSE = 8.8815e-02
# Y | Test_1 -> R² = -1.4229, MSE = 1.9859e-01
# Theta | Test_2 -> R² = 0.6534, MSE = 8.2199e-02
# X | Test_2 -> R² = 0.7148, MSE = 2.3466e-02
# Y | Test_2 -> R² = -1.2660, MSE = 2.4052e-01
# Theta | Test_3 -> R² = 0.5920, MSE = 1.3382e-01
# X | Test_3 -> R² = -0.3303, MSE = 1.2242e-01
# Y | Test_3 -> R² = -1.1978, MSE = 1.6885e-01
# Theta | Val -> R² = -5.7807, MSE = 2.2134e+00
# X | Val -> R² = -0.3431, MSE = 1.2846e-01
# Y | Val -> R² = -0.9764, MSE = 1.4718e-01
# Theta | LSG_1 -> R² = -0.1948, MSE = 4.9877e-01
# X | LSG_1 -> R² = 0.1885, MSE = 8.3173e-02
# Y | LSG_1 -> R² = -1.1839, MSE = 6.8955e-01
# Theta | LSG_2 -> R² = -4.0561, MSE = 1.7697e+00
# X | LSG_2 -> R² = -0.3797, MSE = 1.2266e-01
# Y | LSG_2 -> R² = -0.4514, MSE = 5.5765e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=1170 salvo.
# Epoch 0 | Train Loss 5.178490 | Val Loss 0.818711
# Epoch 100 | Train Loss 1.109553 | Val Loss 0.712195
# Epoch 200 | Train Loss 0.944836 | Val Loss 0.660225
# Epoch 300 | Train Loss 0.845792 | Val Loss 0.641418
# Epoch 400 | Train Loss 0.804261 | Val Loss 0.642004
# Epoch 500 | Train Loss 0.777562 | Val Loss 0.638382
# Epoch 600 | Train Loss 0.753472 | Val Loss 0.630698
# Epoch 700 | Train Loss 0.733749 | Val Loss 0.623302
# Epoch 800 | Train Loss 0.721925 | Val Loss 0.618763
# Epoch 900 | Train Loss 0.716648 | Val Loss 0.616454
# Epoch 1000 | Train Loss 0.714049 | Val Loss 0.614993
# Epoch 1100 | Train Loss 0.712263 | Val Loss 0.613752
# Epoch 1200 | Train Loss 0.710817 | Val Loss 0.612554
# Epoch 1300 | Train Loss 0.709575 | Val Loss 0.611368
# Epoch 1400 | Train Loss 0.708471 | Val Loss 0.610202
# Epoch 1500 | Train Loss 0.707475 | Val Loss 0.609069
# Epoch 1600 | Train Loss 0.706839 | Val Loss 0.607941
# Epoch 1700 | Train Loss 0.705710 | Val Loss 0.606983
# Epoch 1800 | Train Loss 0.704986 | Val Loss 0.605977
# Epoch 1900 | Train Loss 0.704165 | Val Loss 0.605118
# Epoch 2000 | Train Loss 0.703470 | Val Loss 0.604249
# Epoch 2100 | Train Loss 0.702784 | Val Loss 0.603415
# Epoch 2200 | Train Loss 0.702142 | Val Loss 0.602590
# Epoch 2300 | Train Loss 0.701509 | Val Loss 0.601762
# Epoch 2400 | Train Loss 0.700899 | Val Loss 0.600932
# Epoch 2500 | Train Loss 0.702252 | Val Loss 0.599914
# Epoch 2600 | Train Loss 0.699676 | Val Loss 0.599121
# Epoch 2700 | Train Loss 0.699038 | Val Loss 0.598050
# Epoch 2800 | Train Loss 0.698383 | Val Loss 0.596955
# Epoch 2900 | Train Loss 0.698277 | Val Loss 0.595672
# Epoch 3000 | Train Loss 0.696930 | Val Loss 0.594460
# Epoch 3100 | Train Loss 0.696680 | Val Loss 0.593104
# Epoch 3200 | Train Loss 0.695296 | Val Loss 0.591958
# Epoch 3300 | Train Loss 0.694618 | Val Loss 0.590722
# Epoch 3400 | Train Loss 0.693473 | Val Loss 0.589484
# Epoch 3500 | Train Loss 0.692480 | Val Loss 0.588201
# Epoch 3600 | Train Loss 0.691490 | Val Loss 0.586988
# Epoch 3700 | Train Loss 0.693448 | Val Loss 0.585892
# Epoch 3800 | Train Loss 0.689401 | Val Loss 0.584747
# Epoch 3900 | Train Loss 0.688464 | Val Loss 0.583850
# Epoch 4000 | Train Loss 0.687252 | Val Loss 0.583070
# Epoch 4100 | Train Loss 0.687279 | Val Loss 0.582262
# Epoch 4200 | Train Loss 0.685037 | Val Loss 0.581857
# Epoch 4300 | Train Loss 0.683849 | Val Loss 0.581286
# Epoch 4400 | Train Loss 0.682704 | Val Loss 0.580885
# Early stopping at epoch 4463
# Modelo salvo em:
# models/model_arch16_r0.01_seed2559.keras
# weights/model_arch16_r0.01_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9669, MSE = 7.5272e-03
# X | Train_1 -> R² = 0.2809, MSE = 7.7541e-02
# Y | Train_1 -> R² = -1.3662, MSE = 1.9829e-01
# Theta | Train_2 -> R² = 0.9537, MSE = 1.0564e-02
# X | Train_2 -> R² = 0.6871, MSE = 2.6371e-02
# Y | Train_2 -> R² = -1.2116, MSE = 2.3814e-01
# Theta | Test_1 -> R² = 0.4775, MSE = 1.1970e-01
# X | Test_1 -> R² = 0.2466, MSE = 7.8942e-02
# Y | Test_1 -> R² = -1.3786, MSE = 1.9496e-01
# Theta | Test_2 -> R² = 0.6742, MSE = 7.7262e-02
# X | Test_2 -> R² = 0.6727, MSE = 2.6934e-02
# Y | Test_2 -> R² = -1.1719, MSE = 2.3053e-01
# Theta | Test_3 -> R² = -0.4727, MSE = 4.8305e-01
# X | Test_3 -> R² = -0.7368, MSE = 1.5983e-01
# Y | Test_3 -> R² = -1.6401, MSE = 2.0282e-01
# Theta | Val -> R² = -7.1174, MSE = 2.6498e+00
# X | Val -> R² = -1.2050, MSE = 2.1088e-01
# Y | Val -> R² = -1.1338, MSE = 1.5890e-01
# Theta | LSG_1 -> R² = -3.7032, MSE = 1.9634e+00
# X | LSG_1 -> R² = 0.2110, MSE = 8.0873e-02
# Y | LSG_1 -> R² = -0.2534, MSE = 3.9575e-01
# Theta | LSG_2 -> R² = -9.4270, MSE = 3.6495e+00
# X | LSG_2 -> R² = 0.3396, MSE = 5.8716e-02
# Y | LSG_2 -> R² = 0.0173, MSE = 3.7754e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=2559 salvo.
# Epoch 0 | Train Loss 4.055443 | Val Loss 0.825126
# Epoch 100 | Train Loss 1.058593 | Val Loss 0.697811
# Epoch 200 | Train Loss 0.857045 | Val Loss 0.661145
# Epoch 300 | Train Loss 0.812989 | Val Loss 0.650690
# Epoch 400 | Train Loss 0.771248 | Val Loss 0.636861
# Epoch 500 | Train Loss 0.737191 | Val Loss 0.624961
# Epoch 600 | Train Loss 0.723732 | Val Loss 0.618079
# Epoch 700 | Train Loss 0.717057 | Val Loss 0.614199
# Epoch 800 | Train Loss 0.713029 | Val Loss 0.612040
# Epoch 900 | Train Loss 0.710505 | Val Loss 0.610764
# Epoch 1000 | Train Loss 0.708781 | Val Loss 0.609826
# Epoch 1100 | Train Loss 0.707396 | Val Loss 0.609134
# Epoch 1200 | Train Loss 0.706266 | Val Loss 0.608462
# Epoch 1300 | Train Loss 0.705345 | Val Loss 0.607786
# Epoch 1400 | Train Loss 0.704264 | Val Loss 0.607245
# Epoch 1500 | Train Loss 0.703317 | Val Loss 0.606702
# Epoch 1600 | Train Loss 0.702426 | Val Loss 0.606148
# Early stopping at epoch 1628
# Modelo salvo em:
# models/model_arch16_r0.01_seed611.keras
# weights/model_arch16_r0.01_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9537, MSE = 1.0539e-02
# X | Train_1 -> R² = 0.2780, MSE = 7.7856e-02
# Y | Train_1 -> R² = -1.3525, MSE = 1.9715e-01
# Theta | Train_2 -> R² = 0.9192, MSE = 1.8449e-02
# X | Train_2 -> R² = 0.6887, MSE = 2.6236e-02
# Y | Train_2 -> R² = -1.1944, MSE = 2.3629e-01
# Theta | Test_1 -> R² = 0.1218, MSE = 2.0117e-01
# X | Test_1 -> R² = 0.1996, MSE = 8.3872e-02
# Y | Test_1 -> R² = -1.4191, MSE = 1.9828e-01
# Theta | Test_2 -> R² = 0.6731, MSE = 7.7521e-02
# X | Test_2 -> R² = 0.7223, MSE = 2.2852e-02
# Y | Test_2 -> R² = -1.2384, MSE = 2.3759e-01
# Theta | Test_3 -> R² = 0.3676, MSE = 2.0745e-01
# X | Test_3 -> R² = -0.5136, MSE = 1.3929e-01
# Y | Test_3 -> R² = -1.4300, MSE = 1.8668e-01
# Theta | Val -> R² = -7.8372, MSE = 2.8847e+00
# X | Val -> R² = -0.4634, MSE = 1.3996e-01
# Y | Val -> R² = -1.0116, MSE = 1.4980e-01
# Theta | LSG_1 -> R² = -1.4493, MSE = 1.0225e+00
# X | LSG_1 -> R² = 0.1476, MSE = 8.7362e-02
# Y | LSG_1 -> R² = -0.5591, MSE = 4.9226e-01
# Theta | LSG_2 -> R² = -6.2497, MSE = 2.5374e+00
# X | LSG_2 -> R² = -0.2990, MSE = 1.1549e-01
# Y | LSG_2 -> R² = -0.0920, MSE = 4.1957e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.01 seed=611 salvo.
# Epoch 0 | Train Loss 3.455886 | Val Loss 0.810949
# Epoch 100 | Train Loss 1.151535 | Val Loss 0.713084
# Epoch 200 | Train Loss 0.902121 | Val Loss 0.644398
# Epoch 300 | Train Loss 0.758269 | Val Loss 0.619956
# Epoch 400 | Train Loss 0.734166 | Val Loss 0.618477
# Epoch 500 | Train Loss 0.727346 | Val Loss 0.616023
# Epoch 600 | Train Loss 0.722088 | Val Loss 0.612696
# Epoch 700 | Train Loss 0.717561 | Val Loss 0.609257
# Epoch 800 | Train Loss 0.713906 | Val Loss 0.606182
# Epoch 900 | Train Loss 0.711142 | Val Loss 0.603800
# Epoch 1000 | Train Loss 0.709134 | Val Loss 0.602190
# Epoch 1100 | Train Loss 0.707957 | Val Loss 0.601101
# Epoch 1200 | Train Loss 0.706421 | Val Loss 0.600373
# Epoch 1300 | Train Loss 0.705449 | Val Loss 0.599870
# Epoch 1400 | Train Loss 0.704710 | Val Loss 0.599485
# Early stopping at epoch 1411
# Modelo salvo em:
# models/model_arch16_r0.9_seed1557.keras
# weights/model_arch16_r0.9_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9409, MSE = 1.3444e-02
# X | Train_1 -> R² = 0.2824, MSE = 7.7388e-02
# Y | Train_1 -> R² = -1.3650, MSE = 1.9820e-01
# Theta | Train_2 -> R² = 0.9177, MSE = 1.8787e-02
# X | Train_2 -> R² = 0.7112, MSE = 2.4334e-02
# Y | Train_2 -> R² = -1.2546, MSE = 2.4277e-01
# Theta | Test_1 -> R² = -0.1053, MSE = 2.5320e-01
# X | Test_1 -> R² = 0.2072, MSE = 8.3071e-02
# Y | Test_1 -> R² = -1.3871, MSE = 1.9565e-01
# Theta | Test_2 -> R² = 0.7162, MSE = 6.7293e-02
# X | Test_2 -> R² = 0.7459, MSE = 2.0914e-02
# Y | Test_2 -> R² = -1.3095, MSE = 2.4513e-01
# Theta | Test_3 -> R² = 0.5974, MSE = 1.3204e-01
# X | Test_3 -> R² = -0.4501, MSE = 1.3345e-01
# Y | Test_3 -> R² = -1.3261, MSE = 1.7870e-01
# Theta | Val -> R² = -7.3487, MSE = 2.7253e+00
# X | Val -> R² = -0.4283, MSE = 1.3661e-01
# Y | Val -> R² = -0.9984, MSE = 1.4882e-01
# Theta | LSG_1 -> R² = 0.0557, MSE = 3.9418e-01
# X | LSG_1 -> R² = -0.5068, MSE = 1.5444e-01
# Y | LSG_1 -> R² = -1.7756, MSE = 8.7635e-01
# Theta | LSG_2 -> R² = -0.9748, MSE = 6.9118e-01
# X | LSG_2 -> R² = -1.2425, MSE = 1.9937e-01
# Y | LSG_2 -> R² = -0.7530, MSE = 6.7350e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1557 salvo.
# Epoch 0 | Train Loss 2.880975 | Val Loss 0.793897
# Epoch 100 | Train Loss 0.964912 | Val Loss 0.667362
# Epoch 200 | Train Loss 0.855333 | Val Loss 0.660690
# Epoch 300 | Train Loss 0.801721 | Val Loss 0.644254
# Epoch 400 | Train Loss 0.740777 | Val Loss 0.627735
# Epoch 500 | Train Loss 0.725227 | Val Loss 0.619451
# Epoch 600 | Train Loss 0.718379 | Val Loss 0.615176
# Epoch 700 | Train Loss 0.714043 | Val Loss 0.612976
# Epoch 800 | Train Loss 0.710917 | Val Loss 0.611942
# Epoch 900 | Train Loss 0.708641 | Val Loss 0.611469
# Epoch 1000 | Train Loss 0.708181 | Val Loss 0.611105
# Epoch 1100 | Train Loss 0.705688 | Val Loss 0.610609
# Early stopping at epoch 1149
# Modelo salvo em:
# models/model_arch16_r0.9_seed9359.keras
# weights/model_arch16_r0.9_seed9359.weights.h5
# Theta | Train_1 -> R² = 0.9401, MSE = 1.3633e-02
# X | Train_1 -> R² = 0.2774, MSE = 7.7924e-02
# Y | Train_1 -> R² = -1.3671, MSE = 1.9837e-01
# Theta | Train_2 -> R² = 0.9257, MSE = 1.6959e-02
# X | Train_2 -> R² = 0.6999, MSE = 2.5287e-02
# Y | Train_2 -> R² = -1.2163, MSE = 2.3865e-01
# Theta | Test_1 -> R² = -0.1836, MSE = 2.7114e-01
# X | Test_1 -> R² = 0.1591, MSE = 8.8112e-02
# Y | Test_1 -> R² = -1.4153, MSE = 1.9796e-01
# Theta | Test_2 -> R² = 0.6654, MSE = 7.9335e-02
# X | Test_2 -> R² = 0.7323, MSE = 2.2026e-02
# Y | Test_2 -> R² = -1.2459, MSE = 2.3839e-01
# Theta | Test_3 -> R² = 0.4532, MSE = 1.7937e-01
# X | Test_3 -> R² = -0.3589, MSE = 1.2506e-01
# Y | Test_3 -> R² = -1.8420, MSE = 2.1833e-01
# Theta | Val -> R² = -10.4029, MSE = 3.7223e+00
# X | Val -> R² = -0.4068, MSE = 1.3455e-01
# Y | Val -> R² = -1.2112, MSE = 1.6466e-01
# Theta | LSG_1 -> R² = 0.0198, MSE = 4.0920e-01
# X | LSG_1 -> R² = -0.3306, MSE = 1.3638e-01
# Y | LSG_1 -> R² = -0.8969, MSE = 5.9893e-01
# Theta | LSG_2 -> R² = -3.9866, MSE = 1.7453e+00
# X | LSG_2 -> R² = -0.8502, MSE = 1.6449e-01
# Y | LSG_2 -> R² = -0.3114, MSE = 5.0386e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=9359 salvo.
# Epoch 0 | Train Loss 4.029028 | Val Loss 0.807208
# Epoch 100 | Train Loss 1.179658 | Val Loss 0.734288
# Epoch 200 | Train Loss 0.962153 | Val Loss 0.662223
# Epoch 300 | Train Loss 0.811595 | Val Loss 0.623089
# Epoch 400 | Train Loss 0.756083 | Val Loss 0.623776
# Epoch 500 | Train Loss 0.738834 | Val Loss 0.622340
# Early stopping at epoch 513
# Modelo salvo em:
# models/model_arch16_r0.9_seed1170.keras
# weights/model_arch16_r0.9_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9122, MSE = 1.9979e-02
# X | Train_1 -> R² = 0.0785, MSE = 9.9374e-02
# Y | Train_1 -> R² = -1.3996, MSE = 2.0109e-01
# Theta | Train_2 -> R² = 0.5210, MSE = 1.0934e-01
# X | Train_2 -> R² = 0.5928, MSE = 3.4314e-02
# Y | Train_2 -> R² = -1.6974, MSE = 2.9045e-01
# Theta | Test_1 -> R² = 0.6484, MSE = 8.0535e-02
# X | Test_1 -> R² = 0.0402, MSE = 1.0057e-01
# Y | Test_1 -> R² = -1.6866, MSE = 2.2021e-01
# Theta | Test_2 -> R² = 0.8271, MSE = 4.0991e-02
# X | Test_2 -> R² = 0.5728, MSE = 3.5155e-02
# Y | Test_2 -> R² = -1.6690, MSE = 2.8330e-01
# Theta | Test_3 -> R² = 0.6886, MSE = 1.0216e-01
# X | Test_3 -> R² = -0.4178, MSE = 1.3048e-01
# Y | Test_3 -> R² = -1.6430, MSE = 2.0304e-01
# Theta | Val -> R² = -5.9129, MSE = 2.2566e+00
# X | Val -> R² = -0.2158, MSE = 1.1628e-01
# Y | Val -> R² = -2.0050, MSE = 2.2378e-01
# Theta | LSG_1 -> R² = -0.1937, MSE = 4.9831e-01
# X | LSG_1 -> R² = -0.3579, MSE = 1.3918e-01
# Y | LSG_1 -> R² = -0.0654, MSE = 3.3640e-01
# Theta | LSG_2 -> R² = -4.6796, MSE = 1.9879e+00
# X | LSG_2 -> R² = -0.1161, MSE = 9.9229e-02
# Y | LSG_2 -> R² = 0.0547, MSE = 3.6319e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=1170 salvo.
# Epoch 0 | Train Loss 4.057538 | Val Loss 0.795952
# Epoch 100 | Train Loss 1.100622 | Val Loss 0.707787
# Epoch 200 | Train Loss 0.944621 | Val Loss 0.664678
# Epoch 300 | Train Loss 0.824952 | Val Loss 0.628889
# Epoch 400 | Train Loss 0.757610 | Val Loss 0.613207
# Epoch 500 | Train Loss 0.733531 | Val Loss 0.615162
# Epoch 600 | Train Loss 0.726110 | Val Loss 0.617416
# Early stopping at epoch 606
# Modelo salvo em:
# models/model_arch16_r0.9_seed2559.keras
# weights/model_arch16_r0.9_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9273, MSE = 1.6548e-02
# X | Train_1 -> R² = 0.2418, MSE = 8.1760e-02
# Y | Train_1 -> R² = -1.3310, MSE = 1.9535e-01
# Theta | Train_2 -> R² = 0.5183, MSE = 1.0996e-01
# X | Train_2 -> R² = 0.7017, MSE = 2.5138e-02
# Y | Train_2 -> R² = -1.2959, MSE = 2.4721e-01
# Theta | Test_1 -> R² = 0.5440, MSE = 1.0447e-01
# X | Test_1 -> R² = 0.1972, MSE = 8.4123e-02
# Y | Test_1 -> R² = -1.4977, MSE = 2.0472e-01
# Theta | Test_2 -> R² = 0.7815, MSE = 5.1810e-02
# X | Test_2 -> R² = 0.7457, MSE = 2.0929e-02
# Y | Test_2 -> R² = -1.3583, MSE = 2.5032e-01
# Theta | Test_3 -> R² = 0.5743, MSE = 1.3964e-01
# X | Test_3 -> R² = -0.3454, MSE = 1.2381e-01
# Y | Test_3 -> R² = -1.4976, MSE = 1.9188e-01
# Theta | Val -> R² = -7.0378, MSE = 2.6238e+00
# X | Val -> R² = -0.3985, MSE = 1.3376e-01
# Y | Val -> R² = -0.7107, MSE = 1.2739e-01
# Theta | LSG_1 -> R² = -1.3506, MSE = 9.8127e-01
# X | LSG_1 -> R² = -0.4682, MSE = 1.5048e-01
# Y | LSG_1 -> R² = -0.6783, MSE = 5.2989e-01
# Theta | LSG_2 -> R² = -7.6707, MSE = 3.0348e+00
# X | LSG_2 -> R² = -0.6301, MSE = 1.4492e-01
# Y | LSG_2 -> R² = -0.1755, MSE = 4.5162e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=2559 salvo.
# Epoch 0 | Train Loss 3.921931 | Val Loss 0.810976
# Epoch 100 | Train Loss 0.982477 | Val Loss 0.675299
# Epoch 200 | Train Loss 0.828199 | Val Loss 0.660487
# Epoch 300 | Train Loss 0.768452 | Val Loss 0.648482
# Epoch 400 | Train Loss 0.742070 | Val Loss 0.635495
# Epoch 500 | Train Loss 0.729276 | Val Loss 0.627857
# Epoch 600 | Train Loss 0.720874 | Val Loss 0.622627
# Epoch 700 | Train Loss 0.715210 | Val Loss 0.618940
# Epoch 800 | Train Loss 0.711517 | Val Loss 0.616251
# Epoch 900 | Train Loss 0.709001 | Val Loss 0.614149
# Epoch 1000 | Train Loss 0.707180 | Val Loss 0.612375
# Epoch 1100 | Train Loss 0.705638 | Val Loss 0.611011
# Epoch 1200 | Train Loss 0.704373 | Val Loss 0.609790
# Epoch 1300 | Train Loss 0.703297 | Val Loss 0.608675
# Epoch 1400 | Train Loss 0.702133 | Val Loss 0.607705
# Epoch 1500 | Train Loss 0.701112 | Val Loss 0.606794
# Epoch 1600 | Train Loss 0.700128 | Val Loss 0.605795
# Epoch 1700 | Train Loss 0.699070 | Val Loss 0.605091
# Epoch 1800 | Train Loss 0.698082 | Val Loss 0.604279
# Epoch 1900 | Train Loss 0.696971 | Val Loss 0.603580
# Epoch 2000 | Train Loss 0.695924 | Val Loss 0.602905
# Epoch 2100 | Train Loss 0.694798 | Val Loss 0.602322
# Epoch 2200 | Train Loss 0.693733 | Val Loss 0.601818
# Epoch 2300 | Train Loss 0.692575 | Val Loss 0.601380
# Epoch 2400 | Train Loss 0.691527 | Val Loss 0.601042
# Early stopping at epoch 2465
# Modelo salvo em:
# models/model_arch16_r0.9_seed611.keras
# weights/model_arch16_r0.9_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9564, MSE = 9.9113e-03
# X | Train_1 -> R² = 0.2742, MSE = 7.8269e-02
# Y | Train_1 -> R² = -1.3784, MSE = 1.9932e-01
# Theta | Train_2 -> R² = 0.9526, MSE = 1.0812e-02
# X | Train_2 -> R² = 0.6861, MSE = 2.6455e-02
# Y | Train_2 -> R² = -1.1798, MSE = 2.3471e-01
# Theta | Test_1 -> R² = 0.1180, MSE = 2.0205e-01
# X | Test_1 -> R² = 0.1763, MSE = 8.6305e-02
# Y | Test_1 -> R² = -1.4146, MSE = 1.9791e-01
# Theta | Test_2 -> R² = 0.5016, MSE = 1.1817e-01
# X | Test_2 -> R² = 0.7067, MSE = 2.4139e-02
# Y | Test_2 -> R² = -1.2416, MSE = 2.3793e-01
# Theta | Test_3 -> R² = 0.6893, MSE = 1.0190e-01
# X | Test_3 -> R² = -0.8616, MSE = 1.7132e-01
# Y | Test_3 -> R² = -1.6040, MSE = 2.0005e-01
# Theta | Val -> R² = -3.3801, MSE = 1.4298e+00
# X | Val -> R² = -0.5781, MSE = 1.5093e-01
# Y | Val -> R² = -1.0380, MSE = 1.5176e-01
# Theta | LSG_1 -> R² = -2.4676, MSE = 1.4476e+00
# X | LSG_1 -> R² = 0.4351, MSE = 5.7899e-02
# Y | LSG_1 -> R² = -0.0265, MSE = 3.2411e-01
# Theta | LSG_2 -> R² = -8.5375, MSE = 3.3382e+00
# X | LSG_2 -> R² = 0.1309, MSE = 7.7266e-02
# Y | LSG_2 -> R² = 0.1084, MSE = 3.4256e-01
# Modelo [16] | Ld=0.7 Lp=0.3 r=0.9 seed=611 salvo.
# Epoch 0 | Train Loss 1.460131 | Val Loss 0.788164
# Epoch 100 | Train Loss 0.551348 | Val Loss 0.652278
# Epoch 200 | Train Loss 0.506395 | Val Loss 0.633193
# Epoch 300 | Train Loss 0.471931 | Val Loss 0.607147
# Epoch 400 | Train Loss 0.455642 | Val Loss 0.598562
# Epoch 500 | Train Loss 0.445029 | Val Loss 0.597619
# Epoch 600 | Train Loss 0.438587 | Val Loss 0.599162
# Early stopping at epoch 611
# Modelo salvo em:
# models/model_arch32_r0.01_seed1557.keras
# weights/model_arch32_r0.01_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9384, MSE = 1.4026e-02
# X | Train_1 -> R² = 0.2590, MSE = 7.9911e-02
# Y | Train_1 -> R² = -1.3424, MSE = 1.9630e-01
# Theta | Train_2 -> R² = 0.8288, MSE = 3.9086e-02
# X | Train_2 -> R² = 0.6938, MSE = 2.5799e-02
# Y | Train_2 -> R² = -1.2918, MSE = 2.4678e-01
# Theta | Test_1 -> R² = 0.4298, MSE = 1.3062e-01
# X | Test_1 -> R² = 0.1428, MSE = 8.9817e-02
# Y | Test_1 -> R² = -1.5047, MSE = 2.0529e-01
# Theta | Test_2 -> R² = 0.6608, MSE = 8.0441e-02
# X | Test_2 -> R² = 0.7105, MSE = 2.3823e-02
# Y | Test_2 -> R² = -1.3183, MSE = 2.4607e-01
# Theta | Test_3 -> R² = 0.7715, MSE = 7.4943e-02
# X | Test_3 -> R² = -0.8142, MSE = 1.6696e-01
# Y | Test_3 -> R² = -1.1177, MSE = 1.6269e-01
# Theta | Val -> R² = -2.9009, MSE = 1.2734e+00
# X | Val -> R² = -0.2487, MSE = 1.1942e-01
# Y | Val -> R² = -0.6943, MSE = 1.2617e-01
# Theta | LSG_1 -> R² = 0.3013, MSE = 2.9167e-01
# X | LSG_1 -> R² = 0.2864, MSE = 7.3142e-02
# Y | LSG_1 -> R² = -0.5002, MSE = 4.7366e-01
# Theta | LSG_2 -> R² = -2.0975, MSE = 1.0841e+00
# X | LSG_2 -> R² = 0.0500, MSE = 8.4456e-02
# Y | LSG_2 -> R² = -0.1272, MSE = 4.3309e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1557 salvo.
# Epoch 0 | Train Loss 1.975320 | Val Loss 0.817867
# Epoch 100 | Train Loss 0.575330 | Val Loss 0.648196
# Epoch 200 | Train Loss 0.519863 | Val Loss 0.633196
# Epoch 300 | Train Loss 0.488698 | Val Loss 0.616386
# Epoch 400 | Train Loss 0.473516 | Val Loss 0.606543
# Epoch 500 | Train Loss 0.462557 | Val Loss 0.603281
# Epoch 600 | Train Loss 0.450790 | Val Loss 0.605337
# Early stopping at epoch 669
# Modelo salvo em:
# models/model_arch32_r0.01_seed9359.keras
# weights/model_arch32_r0.01_seed9359.weights.h5
# Theta | Train_1 -> R² = 0.9371, MSE = 1.4326e-02
# X | Train_1 -> R² = 0.2557, MSE = 8.0265e-02
# Y | Train_1 -> R² = -1.3791, MSE = 1.9938e-01
# Theta | Train_2 -> R² = 0.8511, MSE = 3.3990e-02
# X | Train_2 -> R² = 0.6583, MSE = 2.8795e-02
# Y | Train_2 -> R² = -1.3499, MSE = 2.5304e-01
# Theta | Test_1 -> R² = 0.4415, MSE = 1.2794e-01
# X | Test_1 -> R² = 0.1858, MSE = 8.5315e-02
# Y | Test_1 -> R² = -1.5396, MSE = 2.0816e-01
# Theta | Test_2 -> R² = 0.8153, MSE = 4.3791e-02
# X | Test_2 -> R² = 0.6664, MSE = 2.7449e-02
# Y | Test_2 -> R² = -1.3726, MSE = 2.5184e-01
# Theta | Test_3 -> R² = 0.5110, MSE = 1.6039e-01
# X | Test_3 -> R² = -0.7280, MSE = 1.5902e-01
# Y | Test_3 -> R² = -1.3942, MSE = 1.8393e-01
# Theta | Val -> R² = -2.4933, MSE = 1.1403e+00
# X | Val -> R² = -0.1714, MSE = 1.1204e-01
# Y | Val -> R² = -1.0328, MSE = 1.5138e-01
# Theta | LSG_1 -> R² = -0.2152, MSE = 5.0729e-01
# X | LSG_1 -> R² = 0.2661, MSE = 7.5220e-02
# Y | LSG_1 -> R² = -0.2166, MSE = 3.8414e-01
# Theta | LSG_2 -> R² = -6.5077, MSE = 2.6277e+00
# X | LSG_2 -> R² = 0.2148, MSE = 6.9805e-02
# Y | LSG_2 -> R² = -0.0649, MSE = 4.0914e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=9359 salvo.
# Epoch 0 | Train Loss 2.918461 | Val Loss 0.776403
# Epoch 100 | Train Loss 0.581244 | Val Loss 0.655596
# Epoch 200 | Train Loss 0.522944 | Val Loss 0.633888
# Epoch 300 | Train Loss 0.491107 | Val Loss 0.620816
# Epoch 400 | Train Loss 0.474363 | Val Loss 0.611133
# Epoch 500 | Train Loss 0.460577 | Val Loss 0.605296
# Epoch 600 | Train Loss 0.449491 | Val Loss 0.606020
# Early stopping at epoch 698
# Modelo salvo em:
# models/model_arch32_r0.01_seed1170.keras
# weights/model_arch32_r0.01_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9352, MSE = 1.4753e-02
# X | Train_1 -> R² = 0.2180, MSE = 8.4324e-02
# Y | Train_1 -> R² = -1.3696, MSE = 1.9858e-01
# Theta | Train_2 -> R² = 0.8637, MSE = 3.1113e-02
# X | Train_2 -> R² = 0.6315, MSE = 3.1049e-02
# Y | Train_2 -> R² = -1.2890, MSE = 2.4648e-01
# Theta | Test_1 -> R² = 0.3611, MSE = 1.4637e-01
# X | Test_1 -> R² = 0.1215, MSE = 9.2046e-02
# Y | Test_1 -> R² = -1.5078, MSE = 2.0555e-01
# Theta | Test_2 -> R² = 0.8030, MSE = 4.6704e-02
# X | Test_2 -> R² = 0.6460, MSE = 2.9133e-02
# Y | Test_2 -> R² = -1.3117, MSE = 2.4537e-01
# Theta | Test_3 -> R² = 0.7659, MSE = 7.6798e-02
# X | Test_3 -> R² = -0.3799, MSE = 1.2698e-01
# Y | Test_3 -> R² = -1.3553, MSE = 1.8094e-01
# Theta | Val -> R² = -3.9687, MSE = 1.6220e+00
# X | Val -> R² = 0.0859, MSE = 8.7421e-02
# Y | Val -> R² = -0.9361, MSE = 1.4417e-01
# Theta | LSG_1 -> R² = -0.5722, MSE = 6.5633e-01
# X | LSG_1 -> R² = 0.3119, MSE = 7.0531e-02
# Y | LSG_1 -> R² = -0.5036, MSE = 4.7474e-01
# Theta | LSG_2 -> R² = -6.4467, MSE = 2.6064e+00
# X | LSG_2 -> R² = 0.3207, MSE = 6.0389e-02
# Y | LSG_2 -> R² = -0.1744, MSE = 4.5120e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=1170 salvo.
# Epoch 0 | Train Loss 3.124498 | Val Loss 0.784722
# Epoch 100 | Train Loss 0.622560 | Val Loss 0.672094
# Epoch 200 | Train Loss 0.537016 | Val Loss 0.634275
# Epoch 300 | Train Loss 0.503915 | Val Loss 0.623673
# Epoch 400 | Train Loss 0.484490 | Val Loss 0.611445
# Epoch 500 | Train Loss 0.477546 | Val Loss 0.606616
# Epoch 600 | Train Loss 0.471765 | Val Loss 0.604795
# Epoch 700 | Train Loss 0.465922 | Val Loss 0.603588
# Epoch 800 | Train Loss 0.461735 | Val Loss 0.602767
# Epoch 900 | Train Loss 0.454311 | Val Loss 0.602619
# Early stopping at epoch 985
# Modelo salvo em:
# models/model_arch32_r0.01_seed2559.keras
# weights/model_arch32_r0.01_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9437, MSE = 1.2805e-02
# X | Train_1 -> R² = 0.2712, MSE = 7.8590e-02
# Y | Train_1 -> R² = -1.3648, MSE = 1.9818e-01
# Theta | Train_2 -> R² = 0.8960, MSE = 2.3742e-02
# X | Train_2 -> R² = 0.6770, MSE = 2.7222e-02
# Y | Train_2 -> R² = -1.2951, MSE = 2.4713e-01
# Theta | Test_1 -> R² = 0.2782, MSE = 1.6534e-01
# X | Test_1 -> R² = 0.1671, MSE = 8.7276e-02
# Y | Test_1 -> R² = -1.5158, MSE = 2.0621e-01
# Theta | Test_2 -> R² = 0.8423, MSE = 3.7406e-02
# X | Test_2 -> R² = 0.7150, MSE = 2.3455e-02
# Y | Test_2 -> R² = -1.3512, MSE = 2.4956e-01
# Theta | Test_3 -> R² = 0.5253, MSE = 1.5570e-01
# X | Test_3 -> R² = -0.3257, MSE = 1.2200e-01
# Y | Test_3 -> R² = -1.5722, MSE = 1.9761e-01
# Theta | Val -> R² = -6.8472, MSE = 2.5616e+00
# X | Val -> R² = -0.2940, MSE = 1.2376e-01
# Y | Val -> R² = -1.4986, MSE = 1.8607e-01
# Theta | LSG_1 -> R² = -0.1728, MSE = 4.8958e-01
# X | LSG_1 -> R² = 0.2941, MSE = 7.2355e-02
# Y | LSG_1 -> R² = -0.3420, MSE = 4.2372e-01
# Theta | LSG_2 -> R² = -5.2549, MSE = 2.1892e+00
# X | LSG_2 -> R² = -0.0716, MSE = 9.5271e-02
# Y | LSG_2 -> R² = -0.1147, MSE = 4.2828e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=2559 salvo.
# Epoch 0 | Train Loss 2.379134 | Val Loss 0.794944
# Epoch 100 | Train Loss 0.604478 | Val Loss 0.656716
# Epoch 200 | Train Loss 0.521615 | Val Loss 0.624417
# Epoch 300 | Train Loss 0.491096 | Val Loss 0.617640
# Epoch 400 | Train Loss 0.475481 | Val Loss 0.609008
# Epoch 500 | Train Loss 0.463950 | Val Loss 0.601922
# Epoch 600 | Train Loss 0.453044 | Val Loss 0.598561
# Epoch 700 | Train Loss 0.445024 | Val Loss 0.601624
# Early stopping at epoch 749
# Modelo salvo em:
# models/model_arch32_r0.01_seed611.keras
# weights/model_arch32_r0.01_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9449, MSE = 1.2538e-02
# X | Train_1 -> R² = 0.2668, MSE = 7.9063e-02
# Y | Train_1 -> R² = -1.3536, MSE = 1.9724e-01
# Theta | Train_2 -> R² = 0.8883, MSE = 2.5491e-02
# X | Train_2 -> R² = 0.6770, MSE = 2.7221e-02
# Y | Train_2 -> R² = -1.3138, MSE = 2.4915e-01
# Theta | Test_1 -> R² = 0.4532, MSE = 1.2526e-01
# X | Test_1 -> R² = 0.1990, MSE = 8.3931e-02
# Y | Test_1 -> R² = -1.5471, MSE = 2.0877e-01
# Theta | Test_2 -> R² = 0.8582, MSE = 3.3615e-02
# X | Test_2 -> R² = 0.6951, MSE = 2.5089e-02
# Y | Test_2 -> R² = -1.3328, MSE = 2.4761e-01
# Theta | Test_3 -> R² = 0.7965, MSE = 6.6750e-02
# X | Test_3 -> R² = -0.5912, MSE = 1.4643e-01
# Y | Test_3 -> R² = -0.9596, MSE = 1.5054e-01
# Theta | Val -> R² = -4.1215, MSE = 1.6718e+00
# X | Val -> R² = 0.0150, MSE = 9.4206e-02
# Y | Val -> R² = -0.4735, MSE = 1.0973e-01
# Theta | LSG_1 -> R² = 0.0239, MSE = 4.0748e-01
# X | LSG_1 -> R² = 0.4479, MSE = 5.6589e-02
# Y | LSG_1 -> R² = -0.4633, MSE = 4.6201e-01
# Theta | LSG_2 -> R² = -4.6059, MSE = 1.9621e+00
# X | LSG_2 -> R² = 0.2275, MSE = 6.8676e-02
# Y | LSG_2 -> R² = -0.1745, MSE = 4.5125e-01
# Modelo [32] | Ld=0.3 Lp=0.7 r=0.01 seed=611 salvo.
# Epoch 0 | Train Loss 1.376421 | Val Loss 0.805815
# Epoch 100 | Train Loss 0.547101 | Val Loss 0.646445
# Epoch 200 | Train Loss 0.493813 | Val Loss 0.625334
# Epoch 300 | Train Loss 0.477379 | Val Loss 0.615917
# Epoch 400 | Train Loss 0.464744 | Val Loss 0.609905
# Epoch 500 | Train Loss 0.453488 | Val Loss 0.606663
# Epoch 600 | Train Loss 0.445212 | Val Loss 0.607289
# Epoch 700 | Train Loss 0.440021 | Val Loss 0.609936
# Early stopping at epoch 736
# Modelo salvo em:
# models/model_arch32_r0.9_seed1557.keras
# weights/model_arch32_r0.9_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9433, MSE = 1.2904e-02
# X | Train_1 -> R² = 0.2614, MSE = 7.9652e-02
# Y | Train_1 -> R² = -1.3729, MSE = 1.9885e-01
# Theta | Train_2 -> R² = 0.8488, MSE = 3.4507e-02
# X | Train_2 -> R² = 0.6858, MSE = 2.6474e-02
# Y | Train_2 -> R² = -1.3086, MSE = 2.4859e-01
# Theta | Test_1 -> R² = 0.3606, MSE = 1.4647e-01
# X | Test_1 -> R² = 0.1793, MSE = 8.5996e-02
# Y | Test_1 -> R² = -1.5056, MSE = 2.0537e-01
# Theta | Test_2 -> R² = 0.6725, MSE = 7.7660e-02
# X | Test_2 -> R² = 0.7125, MSE = 2.3662e-02
# Y | Test_2 -> R² = -1.3392, MSE = 2.4829e-01
# Theta | Test_3 -> R² = 0.5281, MSE = 1.5480e-01
# X | Test_3 -> R² = -0.6683, MSE = 1.5353e-01
# ...
# Theta | Test_1 -> R² = 0.3608, MSE = 1.4642e-01
# X | Test_1 -> R² = 0.2712, MSE = 7.6365e-02
# Y | Test_1 -> R² = -1.3921, MSE = 1.9607e-01
# Theta | Test_2 -> R² = 0.8140, MSE = 4.4101e-02
# X | Test_2 -> R² = 0.7678, MSE = 1.9108e-02
# Y | Test_2 -> R² = -0.3249, MSE = 1.4063e-01
# Theta | Test_3 -> R² = -2.6104, MSE = 1.1843e+00
# X | Test_3 -> R² = 0.0595, MSE = 8.6550e-02
# Y | Test_3 -> R² = -2.3684, MSE = 2.5877e-01
# Theta | Val -> R² = -11.5624, MSE = 4.1008e+00
# X | Val -> R² = 0.1714, MSE = 7.9249e-02
# Y | Val -> R² = -1.8775, MSE = 2.1428e-01
# Theta | LSG_1 -> R² = -2.9680, MSE = 1.6565e+00
# X | LSG_1 -> R² = 0.1288, MSE = 8.9291e-02
# Y | LSG_1 -> R² = -0.1650, MSE = 3.6783e-01
# Theta | LSG_2 -> R² = -9.5457, MSE = 3.6911e+00
# X | LSG_2 -> R² = 0.1577, MSE = 7.4885e-02
# Y | LSG_2 -> R² = -0.0511, MSE = 4.0386e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=9359 salvo.
# Epoch 0 | Train Loss 5.412452 | Val Loss 0.817994
# Epoch 100 | Train Loss 0.745453 | Val Loss 0.645334
# Epoch 200 | Train Loss 0.730818 | Val Loss 0.624015
# Epoch 300 | Train Loss 0.712033 | Val Loss 0.623894
# Epoch 400 | Train Loss 0.707665 | Val Loss 0.619565
# Epoch 500 | Train Loss 0.705925 | Val Loss 0.618614
# Epoch 600 | Train Loss 0.703103 | Val Loss 0.614184
# Epoch 700 | Train Loss 0.702623 | Val Loss 0.611156
# Epoch 800 | Train Loss 0.699840 | Val Loss 0.608754
# Epoch 900 | Train Loss 0.698625 | Val Loss 0.607827
# Epoch 1000 | Train Loss 0.696481 | Val Loss 0.604707
# Epoch 1100 | Train Loss 0.697073 | Val Loss 0.605823
# Epoch 1200 | Train Loss 0.693593 | Val Loss 0.601420
# Epoch 1300 | Train Loss 0.690848 | Val Loss 0.598373
# Epoch 1400 | Train Loss 0.693122 | Val Loss 0.602840
# Epoch 1500 | Train Loss 0.686953 | Val Loss 0.597190
# Early stopping at epoch 1559
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed1170.keras
# weights/model_arch264-128-64_r0.01_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9342, MSE = 1.4978e-02
# X | Train_1 -> R² = 0.2862, MSE = 7.6970e-02
# Y | Train_1 -> R² = -1.3847, MSE = 1.9984e-01
# Theta | Train_2 -> R² = -3.0672, MSE = 9.2848e-01
# X | Train_2 -> R² = 0.6668, MSE = 2.8076e-02
# Y | Train_2 -> R² = -0.9658, MSE = 2.1167e-01
# Theta | Test_1 -> R² = 0.4471, MSE = 1.2667e-01
# X | Test_1 -> R² = 0.2596, MSE = 7.7583e-02
# Y | Test_1 -> R² = -1.4194, MSE = 1.9830e-01
# Theta | Test_2 -> R² = -1.7020, MSE = 6.4072e-01
# X | Test_2 -> R² = 0.6824, MSE = 2.6138e-02
# Y | Test_2 -> R² = -1.0561, MSE = 2.1824e-01
# Theta | Test_3 -> R² = -1.3683, MSE = 7.7685e-01
# X | Test_3 -> R² = -0.0838, MSE = 9.9737e-02
# Y | Test_3 -> R² = -2.5934, MSE = 2.7606e-01
# Theta | Val -> R² = -10.1637, MSE = 3.6442e+00
# X | Val -> R² = 0.0190, MSE = 9.3824e-02
# Y | Val -> R² = -2.3095, MSE = 2.4645e-01
# Theta | LSG_1 -> R² = -4.4802, MSE = 2.2877e+00
# X | LSG_1 -> R² = -0.2013, MSE = 1.2313e-01
# Y | LSG_1 -> R² = -0.0351, MSE = 3.2681e-01
# Theta | LSG_2 -> R² = -12.8679, MSE = 4.8538e+00
# X | LSG_2 -> R² = -0.7287, MSE = 1.5369e-01
# Y | LSG_2 -> R² = 0.0390, MSE = 3.6924e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=1170 salvo.
# Epoch 0 | Train Loss 3.781648 | Val Loss 0.801644
# Epoch 100 | Train Loss 0.768240 | Val Loss 0.637615
# Epoch 200 | Train Loss 0.720234 | Val Loss 0.617848
# Epoch 300 | Train Loss 0.710152 | Val Loss 0.610556
# Epoch 400 | Train Loss 0.716403 | Val Loss 0.607762
# Epoch 500 | Train Loss 0.703209 | Val Loss 0.605635
# Epoch 600 | Train Loss 0.700712 | Val Loss 0.603232
# Epoch 700 | Train Loss 0.700100 | Val Loss 0.603192
# Epoch 800 | Train Loss 0.697380 | Val Loss 0.600058
# Epoch 900 | Train Loss 0.695563 | Val Loss 0.599026
# Epoch 1000 | Train Loss 0.721754 | Val Loss 0.597346
# Epoch 1100 | Train Loss 0.691486 | Val Loss 0.595499
# Epoch 1200 | Train Loss 0.687919 | Val Loss 0.592846
# Early stopping at epoch 1203
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed2559.keras
# weights/model_arch264-128-64_r0.01_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9342, MSE = 1.4971e-02
# X | Train_1 -> R² = 0.2816, MSE = 7.7471e-02
# Y | Train_1 -> R² = -1.3638, MSE = 1.9810e-01
# Theta | Train_2 -> R² = -1.6829, MSE = 6.1248e-01
# X | Train_2 -> R² = 0.6805, MSE = 2.6927e-02
# Y | Train_2 -> R² = -1.0558, MSE = 2.2137e-01
# Theta | Test_1 -> R² = 0.4671, MSE = 1.2207e-01
# X | Test_1 -> R² = 0.2635, MSE = 7.7167e-02
# Y | Test_1 -> R² = -1.5777, MSE = 2.1128e-01
# Theta | Test_2 -> R² = -0.5756, MSE = 3.7362e-01
# X | Test_2 -> R² = 0.7047, MSE = 2.4299e-02
# Y | Test_2 -> R² = -1.0789, MSE = 2.2066e-01
# Theta | Test_3 -> R² = -0.4660, MSE = 4.8087e-01
# X | Test_3 -> R² = -0.0309, MSE = 9.4866e-02
# Y | Test_3 -> R² = -2.0003, MSE = 2.3049e-01
# Theta | Val -> R² = -6.9699, MSE = 2.6016e+00
# X | Val -> R² = -0.0077, MSE = 9.6372e-02
# Y | Val -> R² = -2.0983, MSE = 2.3072e-01
# Theta | LSG_1 -> R² = 0.4487, MSE = 2.3015e-01
# X | LSG_1 -> R² = -0.0170, MSE = 1.0424e-01
# Y | LSG_1 -> R² = -0.1181, MSE = 3.5303e-01
# Theta | LSG_2 -> R² = -2.1688, MSE = 1.1091e+00
# X | LSG_2 -> R² = -0.2976, MSE = 1.1536e-01
# Y | LSG_2 -> R² = -0.0570, MSE = 4.0611e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=2559 salvo.
# Epoch 0 | Train Loss 5.053032 | Val Loss 0.843030
# Epoch 100 | Train Loss 0.773624 | Val Loss 0.631164
# Epoch 200 | Train Loss 0.726393 | Val Loss 0.623961
# Epoch 300 | Train Loss 0.719979 | Val Loss 0.611716
# Epoch 400 | Train Loss 0.709489 | Val Loss 0.609362
# Epoch 500 | Train Loss 0.706113 | Val Loss 0.606823
# Epoch 600 | Train Loss 0.705022 | Val Loss 0.605923
# Epoch 700 | Train Loss 0.702679 | Val Loss 0.603665
# Early stopping at epoch 732
# Modelo salvo em:
# models/model_arch264-128-64_r0.01_seed611.keras
# weights/model_arch264-128-64_r0.01_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9406, MSE = 1.3513e-02
# X | Train_1 -> R² = 0.2885, MSE = 7.6724e-02
# Y | Train_1 -> R² = -1.3532, MSE = 1.9721e-01
# Theta | Train_2 -> R² = 0.6390, MSE = 8.2410e-02
# X | Train_2 -> R² = 0.6995, MSE = 2.5319e-02
# Y | Train_2 -> R² = -1.2365, MSE = 2.4082e-01
# Theta | Test_1 -> R² = 0.2446, MSE = 1.7304e-01
# X | Test_1 -> R² = 0.2301, MSE = 8.0675e-02
# Y | Test_1 -> R² = -1.6039, MSE = 2.1342e-01
# Theta | Test_2 -> R² = 0.8309, MSE = 4.0090e-02
# X | Test_2 -> R² = 0.7118, MSE = 2.3720e-02
# Y | Test_2 -> R² = -1.3496, MSE = 2.4940e-01
# Theta | Test_3 -> R² = 0.3894, MSE = 2.0030e-01
# X | Test_3 -> R² = -0.1439, MSE = 1.0527e-01
# Y | Test_3 -> R² = -1.8113, MSE = 2.1598e-01
# Theta | Val -> R² = -6.7866, MSE = 2.5418e+00
# X | Val -> R² = -0.1799, MSE = 1.1284e-01
# Y | Val -> R² = -1.9805, MSE = 2.2195e-01
# Theta | LSG_1 -> R² = 0.2928, MSE = 2.9523e-01
# X | LSG_1 -> R² = 0.1534, MSE = 8.6777e-02
# Y | LSG_1 -> R² = -0.1261, MSE = 3.5554e-01
# Theta | LSG_2 -> R² = -3.0606, MSE = 1.4212e+00
# X | LSG_2 -> R² = -0.2653, MSE = 1.1249e-01
# Y | LSG_2 -> R² = -0.0335, MSE = 3.9709e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.01 seed=611 salvo.
# Epoch 0 | Train Loss 9.406008 | Val Loss 0.816660
# Epoch 100 | Train Loss 0.775682 | Val Loss 0.627697
# Epoch 200 | Train Loss 0.726459 | Val Loss 0.620855
# Epoch 300 | Train Loss 0.716801 | Val Loss 0.614194
# Epoch 400 | Train Loss 0.709793 | Val Loss 0.610828
# Early stopping at epoch 458
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed1557.keras
# weights/model_arch264-128-64_r0.9_seed1557.weights.h5
# Theta | Train_1 -> R² = 0.9370, MSE = 1.4336e-02
# X | Train_1 -> R² = 0.2819, MSE = 7.7442e-02
# Y | Train_1 -> R² = -1.3926, MSE = 2.0051e-01
# Theta | Train_2 -> R² = 0.8738, MSE = 2.8805e-02
# X | Train_2 -> R² = 0.6984, MSE = 2.5413e-02
# Y | Train_2 -> R² = -1.1862, MSE = 2.3541e-01
# Theta | Test_1 -> R² = 0.3489, MSE = 1.4916e-01
# X | Test_1 -> R² = 0.1944, MSE = 8.4411e-02
# Y | Test_1 -> R² = -1.6859, MSE = 2.2015e-01
# Theta | Test_2 -> R² = 0.9211, MSE = 1.8715e-02
# X | Test_2 -> R² = 0.7188, MSE = 2.3143e-02
# Y | Test_2 -> R² = -1.2438, MSE = 2.3816e-01
# Theta | Test_3 -> R² = 0.6364, MSE = 1.1928e-01
# X | Test_3 -> R² = -0.1973, MSE = 1.1018e-01
# Y | Test_3 -> R² = -2.2606, MSE = 2.5049e-01
# Theta | Val -> R² = -9.9220, MSE = 3.5653e+00
# X | Val -> R² = 0.0714, MSE = 8.8809e-02
# Y | Val -> R² = -1.9457, MSE = 2.1936e-01
# Theta | LSG_1 -> R² = 0.1876, MSE = 3.3913e-01
# X | LSG_1 -> R² = 0.1028, MSE = 9.1964e-02
# Y | LSG_1 -> R² = -0.2606, MSE = 3.9803e-01
# Theta | LSG_2 -> R² = -3.2372, MSE = 1.4830e+00
# X | LSG_2 -> R² = -0.0540, MSE = 9.3706e-02
# Y | LSG_2 -> R² = -0.1299, MSE = 4.3411e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1557 salvo.
# Epoch 0 | Train Loss 2.545016 | Val Loss 0.839165
# Epoch 100 | Train Loss 0.814982 | Val Loss 0.632677
# Epoch 200 | Train Loss 0.733676 | Val Loss 0.630306
# Epoch 300 | Train Loss 0.718431 | Val Loss 0.615823
# Epoch 400 | Train Loss 0.708585 | Val Loss 0.614788
# Epoch 500 | Train Loss 0.705108 | Val Loss 0.612765
# Epoch 600 | Train Loss 0.705542 | Val Loss 0.611916
# Epoch 700 | Train Loss 0.701633 | Val Loss 0.608923
# Epoch 800 | Train Loss 0.699510 | Val Loss 0.605671
# Epoch 900 | Train Loss 0.699277 | Val Loss 0.603094
# Epoch 1000 | Train Loss 0.701520 | Val Loss 0.598774
# Epoch 1100 | Train Loss 0.694057 | Val Loss 0.598510
# Epoch 1200 | Train Loss 0.690515 | Val Loss 0.594843
# Epoch 1300 | Train Loss 0.691570 | Val Loss 0.595195
# Epoch 1400 | Train Loss 0.684808 | Val Loss 0.591214
# Early stopping at epoch 1447
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed9359.keras
# weights/model_arch264-128-64_r0.9_seed9359.weights.h5
# Theta | Train_1 -> R² = 0.9434, MSE = 1.2875e-02
# X | Train_1 -> R² = 0.3005, MSE = 7.5433e-02
# Y | Train_1 -> R² = -1.3933, MSE = 2.0057e-01
# Theta | Train_2 -> R² = -2.4634, MSE = 7.9064e-01
# X | Train_2 -> R² = 0.6088, MSE = 3.2963e-02
# Y | Train_2 -> R² = -1.2625, MSE = 2.4362e-01
# Theta | Test_1 -> R² = 0.4605, MSE = 1.2358e-01
# X | Test_1 -> R² = 0.2556, MSE = 7.7995e-02
# Y | Test_1 -> R² = -1.5115, MSE = 2.0585e-01
# Theta | Test_2 -> R² = -1.2406, MSE = 5.3131e-01
# X | Test_2 -> R² = 0.6465, MSE = 2.9092e-02
# Y | Test_2 -> R² = -1.3142, MSE = 2.4563e-01
# Theta | Test_3 -> R² = -0.5102, MSE = 4.9536e-01
# X | Test_3 -> R² = -0.1145, MSE = 1.0256e-01
# Y | Test_3 -> R² = -2.2468, MSE = 2.4944e-01
# Theta | Val -> R² = -7.2617, MSE = 2.6969e+00
# X | Val -> R² = -0.0067, MSE = 9.6276e-02
# Y | Val -> R² = -2.0986, MSE = 2.3075e-01
# Theta | LSG_1 -> R² = -1.6181, MSE = 1.0929e+00
# X | LSG_1 -> R² = 0.2585, MSE = 7.5996e-02
# Y | LSG_1 -> R² = -0.0795, MSE = 3.4084e-01
# Theta | LSG_2 -> R² = -7.0991, MSE = 2.8347e+00
# X | LSG_2 -> R² = 0.0666, MSE = 8.2979e-02
# Y | LSG_2 -> R² = -0.0102, MSE = 3.8812e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=9359 salvo.
# Epoch 0 | Train Loss 4.456086 | Val Loss 0.853752
# Epoch 100 | Train Loss 0.829592 | Val Loss 0.627081
# Epoch 200 | Train Loss 0.740905 | Val Loss 0.627028
# Epoch 300 | Train Loss 0.731252 | Val Loss 0.615386
# Epoch 400 | Train Loss 0.712116 | Val Loss 0.616287
# Early stopping at epoch 483
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed1170.keras
# weights/model_arch264-128-64_r0.9_seed1170.weights.h5
# Theta | Train_1 -> R² = 0.9392, MSE = 1.3840e-02
# X | Train_1 -> R² = 0.2846, MSE = 7.7146e-02
# Y | Train_1 -> R² = -1.3806, MSE = 1.9950e-01
# Theta | Train_2 -> R² = 0.4778, MSE = 1.1922e-01
# X | Train_2 -> R² = 0.7014, MSE = 2.5160e-02
# Y | Train_2 -> R² = -1.0937, MSE = 2.2544e-01
# Theta | Test_1 -> R² = 0.2994, MSE = 1.6050e-01
# X | Test_1 -> R² = 0.2389, MSE = 7.9745e-02
# Y | Test_1 -> R² = -1.7343, MSE = 2.2411e-01
# Theta | Test_2 -> R² = 0.3857, MSE = 1.4567e-01
# X | Test_2 -> R² = 0.7003, MSE = 2.4664e-02
# Y | Test_2 -> R² = -1.1211, MSE = 2.2514e-01
# Theta | Test_3 -> R² = 0.7645, MSE = 7.7264e-02
# X | Test_3 -> R² = -0.1017, MSE = 1.0138e-01
# Y | Test_3 -> R² = -2.4368, MSE = 2.6403e-01
# Theta | Val -> R² = -7.3390, MSE = 2.7221e+00
# X | Val -> R² = 0.0986, MSE = 8.6211e-02
# Y | Val -> R² = -2.0892, MSE = 2.3005e-01
# Theta | LSG_1 -> R² = 0.0718, MSE = 3.8747e-01
# X | LSG_1 -> R² = -0.1497, MSE = 1.1784e-01
# Y | LSG_1 -> R² = -0.3274, MSE = 4.1910e-01
# Theta | LSG_2 -> R² = -2.0268, MSE = 1.0594e+00
# X | LSG_2 -> R² = 0.0064, MSE = 8.8337e-02
# Y | LSG_2 -> R² = -0.1852, MSE = 4.5538e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=1170 salvo.
# Epoch 0 | Train Loss 6.843217 | Val Loss 0.836263
# Epoch 100 | Train Loss 0.760091 | Val Loss 0.624927
# Epoch 200 | Train Loss 0.723907 | Val Loss 0.618798
# Epoch 300 | Train Loss 0.713389 | Val Loss 0.612736
# Epoch 400 | Train Loss 0.727434 | Val Loss 0.608885
# Epoch 500 | Train Loss 0.703798 | Val Loss 0.608625
# Epoch 600 | Train Loss 0.701131 | Val Loss 0.605889
# Epoch 700 | Train Loss 0.707664 | Val Loss 0.609244
# Epoch 800 | Train Loss 0.698335 | Val Loss 0.602499
# Early stopping at epoch 871
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed2559.keras
# weights/model_arch264-128-64_r0.9_seed2559.weights.h5
# Theta | Train_1 -> R² = 0.9390, MSE = 1.3874e-02
# X | Train_1 -> R² = 0.2963, MSE = 7.5884e-02
# Y | Train_1 -> R² = -1.3637, MSE = 1.9809e-01
# Theta | Train_2 -> R² = -3.4634, MSE = 1.0189e+00
# X | Train_2 -> R² = 0.7435, MSE = 2.1612e-02
# Y | Train_2 -> R² = -0.8652, MSE = 2.0084e-01
# Theta | Test_1 -> R² = 0.2368, MSE = 1.7484e-01
# X | Test_1 -> R² = 0.2211, MSE = 8.1619e-02
# Y | Test_1 -> R² = -1.6087, MSE = 2.1382e-01
# Theta | Test_2 -> R² = -2.2211, MSE = 7.6383e-01
# X | Test_2 -> R² = 0.7672, MSE = 1.9154e-02
# Y | Test_2 -> R² = -0.9343, MSE = 2.0531e-01
# Theta | Test_3 -> R² = 0.2292, MSE = 2.5284e-01
# X | Test_3 -> R² = 0.0885, MSE = 8.3881e-02
# Y | Test_3 -> R² = -2.2714, MSE = 2.5132e-01
# Theta | Val -> R² = -8.5599, MSE = 3.1207e+00
# X | Val -> R² = 0.0582, MSE = 9.0072e-02
# Y | Val -> R² = -2.5527, MSE = 2.6456e-01
# Theta | LSG_1 -> R² = -1.1926, MSE = 9.1530e-01
# X | LSG_1 -> R² = -0.2602, MSE = 1.2916e-01
# Y | LSG_1 -> R² = -0.2124, MSE = 3.8281e-01
# Theta | LSG_2 -> R² = -7.9164, MSE = 3.1208e+00
# X | LSG_2 -> R² = 0.0057, MSE = 8.8396e-02
# Y | LSG_2 -> R² = -0.1214, MSE = 4.3086e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=2559 salvo.
# Epoch 0 | Train Loss 4.652318 | Val Loss 0.822709
# Epoch 100 | Train Loss 0.795785 | Val Loss 0.622471
# Epoch 200 | Train Loss 0.729673 | Val Loss 0.623200
# Epoch 300 | Train Loss 0.721280 | Val Loss 0.614817
# Epoch 400 | Train Loss 0.709391 | Val Loss 0.613402
# Epoch 500 | Train Loss 0.705724 | Val Loss 0.611549
# Epoch 600 | Train Loss 0.703830 | Val Loss 0.610454
# Epoch 700 | Train Loss 0.701594 | Val Loss 0.607560
# Epoch 800 | Train Loss 0.719412 | Val Loss 0.605419
# Epoch 900 | Train Loss 0.698617 | Val Loss 0.602751
# Epoch 1000 | Train Loss 0.696661 | Val Loss 0.599457
# Epoch 1100 | Train Loss 0.702372 | Val Loss 0.597837
# Epoch 1200 | Train Loss 0.693432 | Val Loss 0.594323
# Epoch 1300 | Train Loss 0.690779 | Val Loss 0.590934
# Epoch 1400 | Train Loss 0.794464 | Val Loss 0.591145
# Epoch 1500 | Train Loss 0.686495 | Val Loss 0.589282
# Epoch 1600 | Train Loss 0.682207 | Val Loss 0.586875
# Epoch 1700 | Train Loss 0.683375 | Val Loss 0.589692
# Epoch 1800 | Train Loss 0.676770 | Val Loss 0.587356
# Early stopping at epoch 1830
# Modelo salvo em:
# models/model_arch264-128-64_r0.9_seed611.keras
# weights/model_arch264-128-64_r0.9_seed611.weights.h5
# Theta | Train_1 -> R² = 0.9386, MSE = 1.3963e-02
# X | Train_1 -> R² = 0.3012, MSE = 7.5353e-02
# Y | Train_1 -> R² = -1.3836, MSE = 1.9976e-01
# Theta | Train_2 -> R² = -3.1871, MSE = 9.5587e-01
# X | Train_2 -> R² = 0.6960, MSE = 2.5617e-02
# Y | Train_2 -> R² = -1.5440, MSE = 2.7393e-01
# Theta | Test_1 -> R² = 0.5996, MSE = 9.1714e-02
# X | Test_1 -> R² = 0.2896, MSE = 7.4441e-02
# Y | Test_1 -> R² = -1.3907, MSE = 1.9595e-01
# Theta | Test_2 -> R² = -2.1901, MSE = 7.5647e-01
# X | Test_2 -> R² = 0.7190, MSE = 2.3123e-02
# Y | Test_2 -> R² = -1.5622, MSE = 2.7196e-01
# Theta | Test_3 -> R² = -3.0162, MSE = 1.3174e+00
# X | Test_3 -> R² = -0.0650, MSE = 9.8011e-02
# Y | Test_3 -> R² = -2.4764, MSE = 2.6707e-01
# Theta | Val -> R² = -9.6575, MSE = 3.4789e+00
# X | Val -> R² = 0.0879, MSE = 8.7230e-02
# Y | Val -> R² = -2.0916, MSE = 2.3022e-01
# Theta | LSG_1 -> R² = -3.9374, MSE = 2.0611e+00
# X | LSG_1 -> R² = -0.1005, MSE = 1.1279e-01
# Y | LSG_1 -> R² = -0.1130, MSE = 3.5141e-01
# Theta | LSG_2 -> R² = -13.2391, MSE = 4.9838e+00
# X | LSG_2 -> R² = -0.6279, MSE = 1.4473e-01
# Y | LSG_2 -> R² = -0.0161, MSE = 3.9040e-01
# Modelo [264, 128, 64] | Ld=0.7 Lp=0.3 r=0.9 seed=611 salvo.
